# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_9.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_9']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.04550652 0.05666987 0.04100726 ... 0.02705087 0.02463705 0.02580466] [0.00701323 0.00701323 0.00701323 ... 0.00701323 0.00701323 0.00701323]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
# chi2/DOF: 0.03454; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
# chi2/DOF: 0.02086; DOF: 1907; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 18; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-52.16239977,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -69        46
#  comp.  1:       -34        59
#  comp.  2:       -28        31
# chi2/DOF: 0.8830; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.326      0.46     -34    59
# Comp:  1                Halpha      1.313      0.46     -34    59
# Comp:  2             [SII]6716     0.9677      0.42     -28    31
# Comp:  2             [SII]6731     0.6306      0.42     -28    31
# Comp:  2              HeII4687      0.000      0.42     -28    31
# Comp:  2               HeI5876      0.000      0.42     -28    31
# Comp:  2          [OIII]5007_d     0.5898      0.53     -28    31
# Comp:  2            [OI]6300_d     0.4186      0.53     -28    31
# Comp:  2           [NII]6583_d     0.6401      0.53     -28    31
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  2.517; gas flux:      1 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  2.444; gas flux:      2 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:   2.18; gas flux:      1 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  1.463; gas flux:      1 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise: 0.9855; gas flux:      1 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.7296; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  1.105; gas flux:      1 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -70       111
#  comp.  1:        -3        49
#  comp.  2:       -22         1
# chi2/DOF: 0.8789; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.137      0.44      -3    49
# Comp:  1                Halpha      1.074      0.44      -3    49
# Comp:  2             [SII]6716     0.8199      0.40     -22     1
# Comp:  2             [SII]6731     0.7150      0.40     -22     1
# Comp:  2              HeII4687     0.2293      0.40     -22     1
# Comp:  2               HeI5876      0.000      0.40     -22     1
# Comp:  2          [OIII]5007_d     0.4575      0.50     -22     1
# Comp:  2            [OI]6300_d     0.3193      0.50     -22     1
# Comp:  2           [NII]6583_d     0.4251      0.50     -22     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        45
#  comp.  1:       -56        64
#  comp.  2:       -36        36
# chi2/DOF: 0.8746; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.482      0.47     -56    64
# Comp:  1                Halpha      1.550      0.47     -56    64
# Comp:  2             [SII]6716      1.082      0.42     -36    36
# Comp:  2             [SII]6731     0.7378      0.42     -36    36
# Comp:  2              HeII4687     0.1528      0.42     -36    36
# Comp:  2               HeI5876     0.6974      0.42     -36    36
# Comp:  2          [OIII]5007_d     0.1872      0.54     -36    36
# Comp:  2            [OI]6300_d     0.1869      0.54     -36    36
# Comp:  2           [NII]6583_d     0.5353      0.54     -36    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        82
#  comp.  1:       -45        89
#  comp.  2:        -9        32
# chi2/DOF: 0.8753; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.243      0.51     -45    89
# Comp:  1                Halpha      1.907      0.51     -45    89
# Comp:  2             [SII]6716      1.035      0.42      -9    32
# Comp:  2             [SII]6731     0.5326      0.42      -9    32
# Comp:  2              HeII4687      0.000      0.42      -9    32
# Comp:  2               HeI5876      0.000      0.42      -9    32
# Comp:  2          [OIII]5007_d     0.8418      0.53      -9    32
# Comp:  2            [OI]6300_d     0.5676      0.53      -9    32
# Comp:  2           [NII]6583_d     0.3809      0.53      -9    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        29
#  comp.  1:       -38        82
#  comp.  2:       -36         9
# chi2/DOF: 0.8754; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.465      0.50     -38    82
# Comp:  1                Halpha      1.616      0.50     -38    82
# Comp:  2             [SII]6716     0.8720      0.40     -36     9
# Comp:  2             [SII]6731     0.4847      0.40     -36     9
# Comp:  2              HeII4687      0.000      0.40     -36     9
# Comp:  2               HeI5876     0.5986      0.40     -36     9
# Comp:  2          [OIII]5007_d     0.3370      0.50     -36     9
# Comp:  2            [OI]6300_d     0.4218      0.50     -36     9
# Comp:  2           [NII]6583_d     0.6268      0.50     -36     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -104        42
#  comp.  1:       -78        91
#  comp.  2:       -35        72
# chi2/DOF: 0.8751; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.783      0.52     -78    91
# Comp:  1                Halpha      1.459      0.52     -78    91
# Comp:  2             [SII]6716      1.307      0.48     -35    72
# Comp:  2             [SII]6731     0.5972      0.48     -35    72
# Comp:  2              HeII4687      0.000      0.48     -35    72
# Comp:  2               HeI5876     0.3022      0.48     -35    72
# Comp:  2          [OIII]5007_d      1.293      0.61     -35    72
# Comp:  2            [OI]6300_d     0.6672      0.61     -35    72
# Comp:  2           [NII]6583_d     0.6572      0.61     -35    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99        36
#  comp.  1:       -81       105
#  comp.  2:       -16         2
# chi2/DOF: 0.8699; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.252      0.54     -81   105
# Comp:  1                Halpha      1.761      0.54     -81   105
# Comp:  2             [SII]6716     0.9151      0.40     -16     2
# Comp:  2             [SII]6731     0.6229      0.40     -16     2
# Comp:  2              HeII4687      0.000      0.40     -16     2
# Comp:  2               HeI5876      0.000      0.40     -16     2
# Comp:  2          [OIII]5007_d     0.3146      0.50     -16     2
# Comp:  2            [OI]6300_d     0.5102      0.50     -16     2
# Comp:  2           [NII]6583_d     0.7740      0.50     -16     2
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80        42
#  comp.  1:       -38        95
#  comp.  2:       -28        40
# chi2/DOF: 0.8795; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.522      0.53     -38    95
# Comp:  1                Halpha      1.867      0.53     -38    95
# Comp:  2             [SII]6716      1.188      0.43     -28    40
# Comp:  2             [SII]6731     0.7333      0.43     -28    40
# Comp:  2              HeII4687      0.000      0.43     -28    40
# Comp:  2               HeI5876      0.000      0.43     -28    40
# Comp:  2          [OIII]5007_d     0.4134      0.54     -28    40
# Comp:  2            [OI]6300_d     0.3101      0.54     -28    40
# Comp:  2           [NII]6583_d     0.6849      0.54     -28    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        39
#  comp.  1:       -30        55
#  comp.  2:       -31        10
# chi2/DOF: 0.8757; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.503      0.45     -30    55
# Comp:  1                Halpha      1.251      0.45     -30    55
# Comp:  2             [SII]6716     0.8348      0.40     -31    10
# Comp:  2             [SII]6731     0.4583      0.40     -31    10
# Comp:  2              HeII4687      0.000      0.40     -31    10
# Comp:  2               HeI5876      0.000      0.40     -31    10
# Comp:  2          [OIII]5007_d     0.2999      0.50     -31    10
# Comp:  2            [OI]6300_d     0.6228      0.50     -31    10
# Comp:  2           [NII]6583_d     0.5103      0.50     -31    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -111         1
#  comp.  1:       -99       102
#  comp.  2:       -17         1
# chi2/DOF: 0.8754; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.001      0.54     -99   102
# Comp:  1                Halpha      2.050      0.54     -99   102
# Comp:  2             [SII]6716     0.7792      0.40     -17     1
# Comp:  2             [SII]6731     0.5616      0.40     -17     1
# Comp:  2              HeII4687      0.000      0.40     -17     1
# Comp:  2               HeI5876    0.07243      0.40     -17     1
# Comp:  2          [OIII]5007_d     0.7245      0.50     -17     1
# Comp:  2            [OI]6300_d     0.6258      0.50     -17     1
# Comp:  2           [NII]6583_d     0.8028      0.50     -17     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85         1
#  comp.  1:       -54        76
#  comp.  2:       -34        13
# chi2/DOF: 0.8746; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.575      0.49     -54    76
# Comp:  1                Halpha      1.616      0.49     -54    76
# Comp:  2             [SII]6716     0.8828      0.40     -34    13
# Comp:  2             [SII]6731     0.7012      0.40     -34    13
# Comp:  2              HeII4687    0.09948      0.40     -34    13
# Comp:  2               HeI5876     0.5552      0.40     -34    13
# Comp:  2          [OIII]5007_d      1.125      0.51     -34    13
# Comp:  2            [OI]6300_d     0.1942      0.51     -34    13
# Comp:  2           [NII]6583_d     0.6598      0.51     -34    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        35
#  comp.  1:       -30        56
#  comp.  2:       -14       102
# chi2/DOF: 0.8739; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.616      0.45     -30    56
# Comp:  1                Halpha      1.385      0.45     -30    56
# Comp:  2             [SII]6716      1.446      0.54     -14   102
# Comp:  2             [SII]6731      1.170      0.54     -14   102
# Comp:  2              HeII4687    0.02385      0.54     -14   102
# Comp:  2               HeI5876      1.155      0.54     -14   102
# Comp:  2          [OIII]5007_d     0.4370      0.68     -14   102
# Comp:  2            [OI]6300_d      1.098      0.68     -14   102
# Comp:  2           [NII]6583_d     0.5105      0.68     -14   102
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -133        76
#  comp.  1:       -18        20
#  comp.  2:       -31        55
# chi2/DOF: 0.8762; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7286      0.41     -18    20
# Comp:  1                Halpha     0.5892      0.41     -18    20
# Comp:  2             [SII]6716      1.166      0.45     -31    55
# Comp:  2             [SII]6731     0.6648      0.45     -31    55
# Comp:  2              HeII4687      0.000      0.45     -31    55
# Comp:  2               HeI5876    0.01515      0.45     -31    55
# Comp:  2          [OIII]5007_d      1.182      0.57     -31    55
# Comp:  2            [OI]6300_d     0.4566      0.57     -31    55
# Comp:  2           [NII]6583_d     0.5560      0.57     -31    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81        32
#  comp.  1:       -62        92
#  comp.  2:       -16         1
# chi2/DOF: 0.8772; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.437      0.52     -62    92
# Comp:  1                Halpha      1.992      0.52     -62    92
# Comp:  2             [SII]6716     0.9807      0.40     -16     1
# Comp:  2             [SII]6731     0.7064      0.40     -16     1
# Comp:  2              HeII4687      0.000      0.40     -16     1
# Comp:  2               HeI5876     0.4212      0.40     -16     1
# Comp:  2          [OIII]5007_d     0.8174      0.50     -16     1
# Comp:  2            [OI]6300_d     0.4288      0.50     -16     1
# Comp:  2           [NII]6583_d     0.7084      0.50     -16     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92         1
#  comp.  1:       -76        92
#  comp.  2:       -48        39
# chi2/DOF: 0.8754; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.935      0.52     -76    92
# Comp:  1                Halpha      2.029      0.52     -76    92
# Comp:  2             [SII]6716      1.076      0.43     -48    39
# Comp:  2             [SII]6731     0.6188      0.43     -48    39
# Comp:  2              HeII4687      0.000      0.43     -48    39
# Comp:  2               HeI5876     0.1917      0.43     -48    39
# Comp:  2          [OIII]5007_d      0.000      0.54     -48    39
# Comp:  2            [OI]6300_d     0.2927      0.54     -48    39
# Comp:  2           [NII]6583_d     0.7931      0.54     -48    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         7
#  comp.  1:       -19        77
#  comp.  2:       -13        39
# chi2/DOF: 0.8765; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.826      0.49     -19    77
# Comp:  1                Halpha      1.434      0.49     -19    77
# Comp:  2             [SII]6716      1.093      0.43     -13    39
# Comp:  2             [SII]6731     0.7997      0.43     -13    39
# Comp:  2              HeII4687    0.01133      0.43     -13    39
# Comp:  2               HeI5876      0.000      0.43     -13    39
# Comp:  2          [OIII]5007_d     0.8997      0.54     -13    39
# Comp:  2            [OI]6300_d     0.4645      0.54     -13    39
# Comp:  2           [NII]6583_d     0.8024      0.54     -13    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76         8
#  comp.  1:       -50        54
#  comp.  2:       -43        74
# chi2/DOF: 0.8794; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9845      0.45     -50    54
# Comp:  1                Halpha      1.068      0.45     -50    54
# Comp:  2             [SII]6716      1.046      0.49     -43    74
# Comp:  2             [SII]6731     0.6251      0.49     -43    74
# Comp:  2              HeII4687      0.000      0.49     -43    74
# Comp:  2               HeI5876     0.1715      0.49     -43    74
# Comp:  2          [OIII]5007_d     0.7260      0.62     -43    74
# Comp:  2            [OI]6300_d     0.7139      0.62     -43    74
# Comp:  2           [NII]6583_d      1.037      0.62     -43    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
#  comp.  1:       -35        76
#  comp.  2:       -13         1
# chi2/DOF: 0.8735; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.961      0.49     -35    76
# Comp:  1                Halpha      1.869      0.49     -35    76
# Comp:  2             [SII]6716     0.8804      0.40     -13     1
# Comp:  2             [SII]6731     0.5800      0.40     -13     1
# Comp:  2              HeII4687    0.06935      0.40     -13     1
# Comp:  2               HeI5876      0.000      0.40     -13     1
# Comp:  2          [OIII]5007_d     0.5292      0.50     -13     1
# Comp:  2            [OI]6300_d     0.3131      0.50     -13     1
# Comp:  2           [NII]6583_d     0.8792      0.50     -13     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        47
#  comp.  1:        -6        46
#  comp.  2:        12       106
# chi2/DOF: 0.8771; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.236      0.44      -6    46
# Comp:  1                Halpha      1.016      0.44      -6    46
# Comp:  2             [SII]6716      1.647      0.55      12   106
# Comp:  2             [SII]6731     0.5582      0.55      12   106
# Comp:  2              HeII4687      0.000      0.55      12   106
# Comp:  2               HeI5876      0.000      0.55      12   106
# Comp:  2          [OIII]5007_d      1.082      0.69      12   106
# Comp:  2            [OI]6300_d      1.075      0.69      12   106
# Comp:  2           [NII]6583_d      1.011      0.69      12   106
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        63
#  comp.  1:       -37        76
#  comp.  2:       -30        41
# chi2/DOF: 0.8777; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.830      0.49     -37    76
# Comp:  1                Halpha      1.691      0.49     -37    76
# Comp:  2             [SII]6716     0.9460      0.43     -30    41
# Comp:  2             [SII]6731     0.8460      0.43     -30    41
# Comp:  2              HeII4687     0.2919      0.43     -30    41
# Comp:  2               HeI5876     0.1217      0.43     -30    41
# Comp:  2          [OIII]5007_d     0.7162      0.54     -30    41
# Comp:  2            [OI]6300_d     0.5643      0.54     -30    41
# Comp:  2           [NII]6583_d     0.7092      0.54     -30    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96        62
#  comp.  1:       -64        73
#  comp.  2:       -34        38
# chi2/DOF: 0.8741; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.444      0.48     -64    73
# Comp:  1                Halpha      1.574      0.48     -64    73
# Comp:  2             [SII]6716      1.063      0.43     -34    38
# Comp:  2             [SII]6731     0.5487      0.43     -34    38
# Comp:  2              HeII4687      0.000      0.43     -34    38
# Comp:  2               HeI5876     0.6107      0.43     -34    38
# Comp:  2          [OIII]5007_d      1.254      0.54     -34    38
# Comp:  2            [OI]6300_d     0.3742      0.54     -34    38
# Comp:  2           [NII]6583_d     0.4590      0.54     -34    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        50
#  comp.  1:       -41        67
#  comp.  2:       -24        62
# chi2/DOF: 0.8792; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.725      0.47     -41    67
# Comp:  1                Halpha      1.550      0.47     -41    67
# Comp:  2             [SII]6716      1.140      0.46     -24    62
# Comp:  2             [SII]6731     0.9472      0.46     -24    62
# Comp:  2              HeII4687     0.3469      0.46     -24    62
# Comp:  2               HeI5876     0.1165      0.46     -24    62
# Comp:  2          [OIII]5007_d     0.6509      0.59     -24    62
# Comp:  2            [OI]6300_d     0.5945      0.59     -24    62
# Comp:  2           [NII]6583_d     0.5560      0.59     -24    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        52
#  comp.  1:       -46        97
#  comp.  2:       -20         1
# chi2/DOF: 0.8781; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.346      0.53     -46    97
# Comp:  1                Halpha      1.792      0.53     -46    97
# Comp:  2             [SII]6716     0.7497      0.40     -20     1
# Comp:  2             [SII]6731     0.5564      0.40     -20     1
# Comp:  2              HeII4687     0.1905      0.40     -20     1
# Comp:  2               HeI5876      0.000      0.40     -20     1
# Comp:  2          [OIII]5007_d     0.4455      0.50     -20     1
# Comp:  2            [OI]6300_d     0.2010      0.50     -20     1
# Comp:  2           [NII]6583_d     0.5649      0.50     -20     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:       -35        99
#  comp.  2:       -37        21
# chi2/DOF: 0.8785; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.017      0.53     -35    99
# Comp:  1                Halpha      1.876      0.53     -35    99
# Comp:  2             [SII]6716     0.9938      0.41     -37    21
# Comp:  2             [SII]6731     0.7589      0.41     -37    21
# Comp:  2              HeII4687      0.000      0.41     -37    21
# Comp:  2               HeI5876      0.000      0.41     -37    21
# Comp:  2          [OIII]5007_d     0.1953      0.51     -37    21
# Comp:  2            [OI]6300_d     0.2520      0.51     -37    21
# Comp:  2           [NII]6583_d     0.7624      0.51     -37    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        89
#  comp.  1:        -4        65
#  comp.  2:       -39        13
# chi2/DOF: 0.8775; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.571      0.47      -4    65
# Comp:  1                Halpha      1.771      0.47      -4    65
# Comp:  2             [SII]6716     0.8569      0.40     -39    13
# Comp:  2             [SII]6731     0.5332      0.40     -39    13
# Comp:  2              HeII4687      0.000      0.40     -39    13
# Comp:  2               HeI5876    0.01911      0.40     -39    13
# Comp:  2          [OIII]5007_d     0.8248      0.51     -39    13
# Comp:  2            [OI]6300_d     0.3585      0.51     -39    13
# Comp:  2           [NII]6583_d     0.7251      0.51     -39    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        62
#  comp.  1:       -38        84
#  comp.  2:       -27         1
# chi2/DOF: 0.8787; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.727      0.50     -38    84
# Comp:  1                Halpha      1.919      0.50     -38    84
# Comp:  2             [SII]6716     0.9897      0.40     -27     1
# Comp:  2             [SII]6731     0.6484      0.40     -27     1
# Comp:  2              HeII4687      0.000      0.40     -27     1
# Comp:  2               HeI5876     0.1311      0.40     -27     1
# Comp:  2          [OIII]5007_d     0.8180      0.50     -27     1
# Comp:  2            [OI]6300_d     0.3590      0.50     -27     1
# Comp:  2           [NII]6583_d     0.5653      0.50     -27     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77        53
#  comp.  1:       -38        32
#  comp.  2:        -5        40
# chi2/DOF: 0.8757; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.543      0.42     -38    32
# Comp:  1                Halpha      1.334      0.42     -38    32
# Comp:  2             [SII]6716     0.8926      0.43      -5    40
# Comp:  2             [SII]6731     0.8015      0.43      -5    40
# Comp:  2              HeII4687      0.000      0.43      -5    40
# Comp:  2               HeI5876      0.000      0.43      -5    40
# Comp:  2          [OIII]5007_d     0.5938      0.54      -5    40
# Comp:  2            [OI]6300_d     0.4028      0.54      -5    40
# Comp:  2           [NII]6583_d     0.5717      0.54      -5    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72        60
#  comp.  1:       -15        80
#  comp.  2:       -38        41
# chi2/DOF: 0.8747; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.619      0.50     -15    80
# Comp:  1                Halpha      1.267      0.50     -15    80
# Comp:  2             [SII]6716     0.9552      0.43     -38    41
# Comp:  2             [SII]6731     0.7739      0.43     -38    41
# Comp:  2              HeII4687     0.1508      0.43     -38    41
# Comp:  2               HeI5876      0.000      0.43     -38    41
# Comp:  2          [OIII]5007_d     0.1398      0.54     -38    41
# Comp:  2            [OI]6300_d     0.1430      0.54     -38    41
# Comp:  2           [NII]6583_d     0.4085      0.54     -38    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -129       140
#  comp.  1:       -65       125
#  comp.  2:       -10        22
# chi2/DOF: 0.8697; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.305      0.58     -65   125
# Comp:  1                Halpha      1.564      0.58     -65   125
# Comp:  2             [SII]6716     0.8604      0.41     -10    22
# Comp:  2             [SII]6731     0.5930      0.41     -10    22
# Comp:  2              HeII4687      0.000      0.41     -10    22
# Comp:  2               HeI5876     0.4361      0.41     -10    22
# Comp:  2          [OIII]5007_d     0.6287      0.52     -10    22
# Comp:  2            [OI]6300_d     0.6029      0.52     -10    22
# Comp:  2           [NII]6583_d     0.5466      0.52     -10    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -91         1
#  comp.  1:       -46        78
#  comp.  2:       -24        67
# chi2/DOF: 0.8765; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.430      0.49     -46    78
# Comp:  1                Halpha      1.454      0.49     -46    78
# Comp:  2             [SII]6716      1.200      0.47     -24    67
# Comp:  2             [SII]6731     0.4848      0.47     -24    67
# Comp:  2              HeII4687      0.000      0.47     -24    67
# Comp:  2               HeI5876     0.6524      0.47     -24    67
# Comp:  2          [OIII]5007_d     0.3237      0.60     -24    67
# Comp:  2            [OI]6300_d     0.8585      0.60     -24    67
# Comp:  2           [NII]6583_d     0.8193      0.60     -24    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99        85
#  comp.  1:       -56        71
#  comp.  2:       -43        36
# chi2/DOF: 0.8779; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.223      0.48     -56    71
# Comp:  1                Halpha      1.518      0.48     -56    71
# Comp:  2             [SII]6716      1.115      0.42     -43    36
# Comp:  2             [SII]6731     0.6817      0.42     -43    36
# Comp:  2              HeII4687    0.08534      0.42     -43    36
# Comp:  2               HeI5876      0.000      0.42     -43    36
# Comp:  2          [OIII]5007_d      1.135      0.54     -43    36
# Comp:  2            [OI]6300_d     0.6725      0.54     -43    36
# Comp:  2           [NII]6583_d     0.6269      0.54     -43    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70        34
#  comp.  1:       -30        66
#  comp.  2:       -24         1
# chi2/DOF: 0.8785; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.490      0.47     -30    66
# Comp:  1                Halpha      1.455      0.47     -30    66
# Comp:  2             [SII]6716     0.9031      0.40     -24     1
# Comp:  2             [SII]6731     0.5408      0.40     -24     1
# Comp:  2              HeII4687      0.000      0.40     -24     1
# Comp:  2               HeI5876      0.000      0.40     -24     1
# Comp:  2          [OIII]5007_d     0.7216      0.50     -24     1
# Comp:  2            [OI]6300_d     0.4839      0.50     -24     1
# Comp:  2           [NII]6583_d     0.6029      0.50     -24     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        90
#  comp.  1:       -10         1
#  comp.  2:       -34         1
# chi2/DOF: 0.8772; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7108      0.40     -10     1
# Comp:  1                Halpha     0.9611      0.40     -10     1
# Comp:  2             [SII]6716     0.8751      0.40     -34     1
# Comp:  2             [SII]6731     0.4881      0.40     -34     1
# Comp:  2              HeII4687     0.1350      0.40     -34     1
# Comp:  2               HeI5876      0.000      0.40     -34     1
# Comp:  2          [OIII]5007_d      1.015      0.50     -34     1
# Comp:  2            [OI]6300_d     0.3322      0.50     -34     1
# Comp:  2           [NII]6583_d     0.7065      0.50     -34     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69        82
#  comp.  1:       -45       100
#  comp.  2:         1        43
# chi2/DOF: 0.8764; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.012      0.53     -45   100
# Comp:  1                Halpha      1.868      0.53     -45   100
# Comp:  2             [SII]6716      1.152      0.43       1    43
# Comp:  2             [SII]6731     0.6308      0.43       1    43
# Comp:  2              HeII4687     0.2761      0.43       1    43
# Comp:  2               HeI5876      0.000      0.43       1    43
# Comp:  2          [OIII]5007_d     0.6589      0.55       1    43
# Comp:  2            [OI]6300_d     0.3191      0.55       1    43
# Comp:  2           [NII]6583_d     0.7155      0.55       1    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        55
#  comp.  1:       -35        55
#  comp.  2:       -19         1
# chi2/DOF: 0.8772; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.329      0.45     -35    55
# Comp:  1                Halpha      1.566      0.45     -35    55
# Comp:  2             [SII]6716     0.9685      0.40     -19     1
# Comp:  2             [SII]6731     0.6716      0.40     -19     1
# Comp:  2              HeII4687     0.1233      0.40     -19     1
# Comp:  2               HeI5876     0.4789      0.40     -19     1
# Comp:  2          [OIII]5007_d     0.6166      0.50     -19     1
# Comp:  2            [OI]6300_d     0.1576      0.50     -19     1
# Comp:  2           [NII]6583_d     0.4736      0.50     -19     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        45
#  comp.  1:       -16        40
#  comp.  2:       -22         1
# chi2/DOF: 0.8721; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.150      0.43     -16    40
# Comp:  1                Halpha      1.149      0.43     -16    40
# Comp:  2             [SII]6716      1.000      0.40     -22     1
# Comp:  2             [SII]6731     0.6099      0.40     -22     1
# Comp:  2              HeII4687     0.1780      0.40     -22     1
# Comp:  2               HeI5876     0.4546      0.40     -22     1
# Comp:  2          [OIII]5007_d      0.000      0.50     -22     1
# Comp:  2            [OI]6300_d     0.4570      0.50     -22     1
# Comp:  2           [NII]6583_d     0.6591      0.50     -22     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        46
#  comp.  1:       -24        69
#  comp.  2:       -28         1
# chi2/DOF: 0.8753; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.699      0.48     -24    69
# Comp:  1                Halpha      1.417      0.48     -24    69
# Comp:  2             [SII]6716     0.9935      0.40     -28     1
# Comp:  2             [SII]6731     0.4685      0.40     -28     1
# Comp:  2              HeII4687     0.3087      0.40     -28     1
# Comp:  2               HeI5876   0.008886      0.40     -28     1
# Comp:  2          [OIII]5007_d     0.3871      0.50     -28     1
# Comp:  2            [OI]6300_d     0.2115      0.50     -28     1
# Comp:  2           [NII]6583_d     0.4898      0.50     -28     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:       -24        35
#  comp.  2:        31        83
# chi2/DOF: 0.8765; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.113      0.42     -24    35
# Comp:  1                Halpha     0.8313      0.42     -24    35
# Comp:  2             [SII]6716      1.071      0.50      31    83
# Comp:  2             [SII]6731     0.6448      0.50      31    83
# Comp:  2              HeII4687      0.000      0.50      31    83
# Comp:  2               HeI5876    0.09239      0.50      31    83
# Comp:  2          [OIII]5007_d     0.6107      0.64      31    83
# Comp:  2            [OI]6300_d     0.4365      0.64      31    83
# Comp:  2           [NII]6583_d      1.046      0.64      31    83
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69        95
#  comp.  1:         7        50
#  comp.  2:       -20        39
# chi2/DOF: 0.8764; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9185      0.44       7    50
# Comp:  1                Halpha     0.8142      0.44       7    50
# Comp:  2             [SII]6716      1.054      0.43     -20    39
# Comp:  2             [SII]6731     0.5887      0.43     -20    39
# Comp:  2              HeII4687      0.000      0.43     -20    39
# Comp:  2               HeI5876      0.000      0.43     -20    39
# Comp:  2          [OIII]5007_d     0.4738      0.54     -20    39
# Comp:  2            [OI]6300_d     0.7537      0.54     -20    39
# Comp:  2           [NII]6583_d     0.7436      0.54     -20    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        46
#  comp.  1:       -16        44
#  comp.  2:       -10        40
# chi2/DOF: 0.8757; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.410      0.43     -16    44
# Comp:  1                Halpha      1.071      0.43     -16    44
# Comp:  2             [SII]6716      1.007      0.43     -10    40
# Comp:  2             [SII]6731     0.9161      0.43     -10    40
# Comp:  2              HeII4687      0.000      0.43     -10    40
# Comp:  2               HeI5876      0.000      0.43     -10    40
# Comp:  2          [OIII]5007_d     0.8415      0.54     -10    40
# Comp:  2            [OI]6300_d     0.6962      0.54     -10    40
# Comp:  2           [NII]6583_d     0.3999      0.54     -10    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -16        74
#  comp.  2:        14        41
# chi2/DOF: 0.8766; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.511      0.49     -16    74
# Comp:  1                Halpha      1.439      0.49     -16    74
# Comp:  2             [SII]6716      1.041      0.43      14    41
# Comp:  2             [SII]6731     0.3899      0.43      14    41
# Comp:  2              HeII4687    0.03874      0.43      14    41
# Comp:  2               HeI5876      0.000      0.43      14    41
# Comp:  2          [OIII]5007_d     0.7530      0.54      14    41
# Comp:  2            [OI]6300_d     0.3052      0.54      14    41
# Comp:  2           [NII]6583_d     0.8187      0.54      14    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        75
#  comp.  1:       -41        79
#  comp.  2:       -23         1
# chi2/DOF: 0.8744; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.810      0.50     -41    79
# Comp:  1                Halpha      1.879      0.50     -41    79
# Comp:  2             [SII]6716     0.8379      0.40     -23     1
# Comp:  2             [SII]6731     0.4795      0.40     -23     1
# Comp:  2              HeII4687      0.000      0.40     -23     1
# Comp:  2               HeI5876      0.000      0.40     -23     1
# Comp:  2          [OIII]5007_d     0.7656      0.50     -23     1
# Comp:  2            [OI]6300_d     0.4003      0.50     -23     1
# Comp:  2           [NII]6583_d     0.5938      0.50     -23     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92        10
#  comp.  1:       -43        66
#  comp.  2:       -39         1
# chi2/DOF: 0.8787; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.587      0.47     -43    66
# Comp:  1                Halpha      1.225      0.47     -43    66
# Comp:  2             [SII]6716     0.9194      0.40     -39     1
# Comp:  2             [SII]6731     0.6673      0.40     -39     1
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.762      0.62     -94   145
# Comp:  1                Halpha      1.510      0.62     -94   145
# Comp:  2             [SII]6716      1.158      0.46      -6    61
# Comp:  2             [SII]6731     0.7729      0.46      -6    61
# Comp:  2              HeII4687     0.1571      0.46      -6    61
# Comp:  2               HeI5876      0.000      0.46      -6    61
# Comp:  2          [OIII]5007_d     0.5579      0.59      -6    61
# Comp:  2            [OI]6300_d     0.7111      0.59      -6    61
# Comp:  2           [NII]6583_d     0.8438      0.59      -6    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         1
#  comp.  1:       -61        70
#  comp.  2:       -34        35
# chi2/DOF: 0.8742; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.917      0.48     -61    70
# Comp:  1                Halpha      1.848      0.48     -61    70
# Comp:  2             [SII]6716      1.098      0.42     -34    35
# Comp:  2             [SII]6731     0.6994      0.42     -34    35
# Comp:  2              HeII4687      0.000      0.42     -34    35
# Comp:  2               HeI5876    0.01857      0.42     -34    35
# Comp:  2          [OIII]5007_d     0.8231      0.53     -34    35
# Comp:  2            [OI]6300_d     0.7099      0.53     -34    35
# Comp:  2           [NII]6583_d     0.4415      0.53     -34    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:       -20        42
#  comp.  2:       -25         1
# chi2/DOF: 0.8757; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.484      0.43     -20    42
# Comp:  1                Halpha      1.436      0.43     -20    42
# Comp:  2             [SII]6716     0.8815      0.40     -25     1
# Comp:  2             [SII]6731     0.7605      0.40     -25     1
# Comp:  2              HeII4687      0.000      0.40     -25     1
# Comp:  2               HeI5876     0.1979      0.40     -25     1
# Comp:  2          [OIII]5007_d     0.4219      0.50     -25     1
# Comp:  2            [OI]6300_d     0.5315      0.50     -25     1
# Comp:  2           [NII]6583_d     0.6834      0.50     -25     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        76
#  comp.  1:       -10        66
#  comp.  2:        -3        49
# chi2/DOF: 0.8759; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.584      0.47     -10    66
# Comp:  1                Halpha      1.411      0.47     -10    66
# Comp:  2             [SII]6716      1.082      0.44      -3    49
# Comp:  2             [SII]6731     0.7330      0.44      -3    49
# Comp:  2              HeII4687      0.000      0.44      -3    49
# Comp:  2               HeI5876     0.5571      0.44      -3    49
# Comp:  2          [OIII]5007_d     0.5520      0.56      -3    49
# Comp:  2            [OI]6300_d     0.3719      0.56      -3    49
# Comp:  2           [NII]6583_d     0.6663      0.56      -3    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -93        26
#  comp.  1:       -59        78
#  comp.  2:       -42        35
# chi2/DOF: 0.8765; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.440      0.49     -59    78
# Comp:  1                Halpha      1.287      0.49     -59    78
# Comp:  2             [SII]6716      1.074      0.42     -42    35
# Comp:  2             [SII]6731     0.6664      0.42     -42    35
# Comp:  2              HeII4687     0.1477      0.42     -42    35
# Comp:  2               HeI5876      0.000      0.42     -42    35
# Comp:  2          [OIII]5007_d    0.01562      0.53     -42    35
# Comp:  2            [OI]6300_d     0.5772      0.53     -42    35
# Comp:  2           [NII]6583_d     0.5908      0.53     -42    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        55
#  comp.  1:       -44        71
#  comp.  2:       -65        93
# chi2/DOF: 0.8797; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.116      0.48     -44    71
# Comp:  1                Halpha      1.336      0.48     -44    71
# Comp:  2             [SII]6716      1.071      0.52     -65    93
# Comp:  2             [SII]6731     0.9020      0.52     -65    93
# Comp:  2              HeII4687      0.000      0.52     -65    93
# Comp:  2               HeI5876      0.000      0.52     -65    93
# Comp:  2          [OIII]5007_d     0.6470      0.66     -65    93
# Comp:  2            [OI]6300_d     0.5725      0.66     -65    93
# Comp:  2           [NII]6583_d      1.031      0.66     -65    93
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        45
#  comp.  1:       -29        60
#  comp.  2:       -33         1
# chi2/DOF: 0.8779; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.274      0.46     -29    60
# Comp:  1                Halpha      1.291      0.46     -29    60
# Comp:  2             [SII]6716     0.9436      0.40     -33     1
# Comp:  2             [SII]6731     0.6158      0.40     -33     1
# Comp:  2              HeII4687      0.000      0.40     -33     1
# Comp:  2               HeI5876      0.000      0.40     -33     1
# Comp:  2          [OIII]5007_d     0.8446      0.50     -33     1
# Comp:  2            [OI]6300_d     0.2826      0.50     -33     1
# Comp:  2           [NII]6583_d     0.3837      0.50     -33     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        48
#  comp.  1:       -33        53
#  comp.  2:       -40        45
# chi2/DOF: 0.8783; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.037      0.45     -33    53
# Comp:  1                Halpha      1.752      0.45     -33    53
# Comp:  2             [SII]6716     0.8676      0.44     -40    45
# Comp:  2             [SII]6731     0.7578      0.44     -40    45
# Comp:  2              HeII4687      0.000      0.44     -40    45
# Comp:  2               HeI5876      0.000      0.44     -40    45
# Comp:  2          [OIII]5007_d     0.8049      0.55     -40    45
# Comp:  2            [OI]6300_d     0.4922      0.55     -40    45
# Comp:  2           [NII]6583_d     0.8732      0.55     -40    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        81
#  comp.  1:       -50       116
#  comp.  2:       -46        45
# chi2/DOF: 0.8784; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.748      0.56     -50   116
# Comp:  1                Halpha      1.567      0.56     -50   116
# Comp:  2             [SII]6716      1.056      0.44     -46    45
# Comp:  2             [SII]6731     0.7725      0.44     -46    45
# Comp:  2              HeII4687      0.000      0.44     -46    45
# Comp:  2               HeI5876      0.000      0.44     -46    45
# Comp:  2          [OIII]5007_d     0.5084      0.55     -46    45
# Comp:  2            [OI]6300_d     0.2364      0.55     -46    45
# Comp:  2           [NII]6583_d     0.5241      0.55     -46    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89         1
#  comp.  1:       -58       103
#  comp.  2:       -48         1
# chi2/DOF: 0.8750; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.525      0.54     -58   103
# Comp:  1                Halpha      1.962      0.54     -58   103
# Comp:  2             [SII]6716     0.8798      0.40     -48     1
# Comp:  2             [SII]6731     0.6479      0.40     -48     1
# Comp:  2              HeII4687    0.02338      0.40     -48     1
# Comp:  2               HeI5876      0.000      0.40     -48     1
# Comp:  2          [OIII]5007_d     0.6731      0.50     -48     1
# Comp:  2            [OI]6300_d     0.2927      0.50     -48     1
# Comp:  2           [NII]6583_d     0.6487      0.50     -48     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        41
#  comp.  1:       -66        84
#  comp.  2:       -41        49
# chi2/DOF: 0.8788; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.750      0.50     -66    84
# Comp:  1                Halpha      1.483      0.50     -66    84
# Comp:  2             [SII]6716      1.151      0.44     -41    49
# Comp:  2             [SII]6731     0.4830      0.44     -41    49
# Comp:  2              HeII4687    0.01234      0.44     -41    49
# Comp:  2               HeI5876     0.4905      0.44     -41    49
# Comp:  2          [OIII]5007_d      1.111      0.56     -41    49
# Comp:  2            [OI]6300_d     0.5477      0.56     -41    49
# Comp:  2           [NII]6583_d     0.5296      0.56     -41    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -90         1
#  comp.  1:       -22         9
#  comp.  2:       -28        38
# chi2/DOF: 0.8770; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8147      0.40     -22     9
# Comp:  1                Halpha     0.8713      0.40     -22     9
# Comp:  2             [SII]6716     0.7979      0.43     -28    38
# Comp:  2             [SII]6731     0.5216      0.43     -28    38
# Comp:  2              HeII4687      0.000      0.43     -28    38
# Comp:  2               HeI5876      0.000      0.43     -28    38
# Comp:  2          [OIII]5007_d      0.000      0.54     -28    38
# Comp:  2            [OI]6300_d     0.3966      0.54     -28    38
# Comp:  2           [NII]6583_d     0.4952      0.54     -28    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:       -16        39
#  comp.  2:       -21        12
# chi2/DOF: 0.8755; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.327      0.43     -16    39
# Comp:  1                Halpha      1.128      0.43     -16    39
# Comp:  2             [SII]6716     0.8971      0.40     -21    12
# Comp:  2             [SII]6731     0.4830      0.40     -21    12
# Comp:  2              HeII4687      0.000      0.40     -21    12
# Comp:  2               HeI5876     0.4977      0.40     -21    12
# Comp:  2          [OIII]5007_d     0.9392      0.51     -21    12
# Comp:  2            [OI]6300_d     0.5456      0.51     -21    12
# Comp:  2           [NII]6583_d     0.7417      0.51     -21    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:       -45        81
#  comp.  2:       -28        30
# chi2/DOF: 0.8789; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.296      0.50     -45    81
# Comp:  1                Halpha      2.051      0.50     -45    81
# Comp:  2             [SII]6716     0.9394      0.42     -28    30
# Comp:  2             [SII]6731     0.7225      0.42     -28    30
# Comp:  2              HeII4687      0.000      0.42     -28    30
# Comp:  2               HeI5876    0.02722      0.42     -28    30
# Comp:  2          [OIII]5007_d     0.6555      0.53     -28    30
# Comp:  2            [OI]6300_d     0.4246      0.53     -28    30
# Comp:  2           [NII]6583_d     0.9200      0.53     -28    30
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.69720337, 0.52113631, 0.25910643, 0.20817083, 0.11151812,
#        0.30691746, 0.38763201, 0.35065296, 0.31056955])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([1.34500917, 1.79783951, 1.35564405, 0.8853373 , 0.        ,
#        0.        , 0.6159646 , 0.55011875, 0.87894794])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_9_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_9", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_9_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_9_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_9_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.045992    0.023841
# 1        Halpha  0.061477    0.017820
# 2     [SII]6716  0.046356    0.008860
# 3     [SII]6731  0.030274    0.007118
# 4      HeII4687  0.000000    0.003813
# 5       HeI5876  0.000000    0.010495
# 6  [OIII]5007_d  0.021063    0.013255
# 7    [OI]6300_d  0.018811    0.011990
# 8   [NII]6583_d  0.030055    0.010620
#           Name      Flux  Error_flux
# 0        Hbeta  0.045992    0.023841
# 1       Halpha  0.061477    0.017820
# 2    [SII]6716  0.046356    0.008860
# 3    [SII]6731  0.030274    0.007118
# 4     HeII4687  0.000000    0.003813
# 5      HeI5876  0.000000    0.010495
# 6   [OIII]4959  0.005266    0.013255
# 7   [OIII]5007  0.015797    0.013255
# 8     [OI]6300  0.014108    0.011990
# 9     [OI]6364  0.004703    0.011990
# 10   [NII]6548  0.007514    0.010620
# 11   [NII]6583  0.022542    0.010620

# %%
np.median(flux_rf_rebin)
# Out:
# 0.0341946797145575
