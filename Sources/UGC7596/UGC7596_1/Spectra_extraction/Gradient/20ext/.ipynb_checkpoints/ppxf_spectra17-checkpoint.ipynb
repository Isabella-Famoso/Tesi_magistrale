# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_17.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_17']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.02906015 0.02604417 0.01740115 ... 0.01473952 0.01672055 0.01253763] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -88         1
# chi2/DOF: 0.09748; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
# chi2/DOF: 0.05537; DOF: 1912; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-72.67192567,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -219       755
#  comp.  1:       -93        44
#  comp.  2:       -86       139
# chi2/DOF: 1.100; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.346      0.65     -93    44
# Comp:  1                Halpha      7.375      0.65     -93    44
# Comp:  2             [SII]6716      4.275      0.91     -86   139
# Comp:  2             [SII]6731      1.138      0.91     -86   139
# Comp:  2              HeII4687      0.000      0.91     -86   139
# Comp:  2               HeI5876      2.365      0.91     -86   139
# Comp:  2          [OIII]5007_d      3.436       1.1     -86   139
# Comp:  2            [OI]6300_d      0.000       1.1     -86   139
# Comp:  2           [NII]6583_d      2.018       1.1     -86   139
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  5.617; gas flux:      4 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  9.354; gas flux:     10 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  2.841; gas flux:      6 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise: 0.7588; gas flux:      2 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:   1.55; gas flux:      3 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:    1.7; gas flux:      4 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  1.011; gas flux:      3 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -607       612
#  comp.  1:       -98        47
#  comp.  2:       -90       123
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.479      0.66     -98    47
# Comp:  1                Halpha      7.317      0.66     -98    47
# Comp:  2             [SII]6716      3.553      0.86     -90   123
# Comp:  2             [SII]6731     0.7399      0.86     -90   123
# Comp:  2              HeII4687      0.000      0.86     -90   123
# Comp:  2               HeI5876      2.486      0.86     -90   123
# Comp:  2          [OIII]5007_d      3.398       1.1     -90   123
# Comp:  2            [OI]6300_d     0.2034       1.1     -90   123
# Comp:  2           [NII]6583_d      1.393       1.1     -90   123
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       114       971
#  comp.  1:       -97        46
#  comp.  2:       -74       152
# chi2/DOF: 1.092; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.937      0.66     -97    46
# Comp:  1                Halpha      7.772      0.66     -97    46
# Comp:  2             [SII]6716      5.841      0.94     -74   152
# Comp:  2             [SII]6731      1.044      0.94     -74   152
# Comp:  2              HeII4687     0.1648      0.94     -74   152
# Comp:  2               HeI5876      3.989      0.94     -74   152
# Comp:  2          [OIII]5007_d      3.825       1.2     -74   152
# Comp:  2            [OI]6300_d      0.000       1.2     -74   152
# Comp:  2           [NII]6583_d      2.203       1.2     -74   152
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -258       488
#  comp.  1:       -89        38
#  comp.  2:      -101       145
# chi2/DOF: 1.091; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.968      0.64     -89    38
# Comp:  1                Halpha      7.485      0.64     -89    38
# Comp:  2             [SII]6716      4.779      0.92    -101   145
# Comp:  2             [SII]6731      1.513      0.92    -101   145
# Comp:  2              HeII4687      0.000      0.92    -101   145
# Comp:  2               HeI5876     0.3937      0.92    -101   145
# Comp:  2          [OIII]5007_d      3.340       1.2    -101   145
# Comp:  2            [OI]6300_d     0.2014       1.2    -101   145
# Comp:  2           [NII]6583_d      2.046       1.2    -101   145
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10       807
#  comp.  1:       -96        49
#  comp.  2:       -77       107
# chi2/DOF: 1.093; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.663      0.66     -96    49
# Comp:  1                Halpha      8.078      0.66     -96    49
# Comp:  2             [SII]6716      3.456      0.82     -77   107
# Comp:  2             [SII]6731      1.337      0.82     -77   107
# Comp:  2              HeII4687     0.5099      0.82     -77   107
# Comp:  2               HeI5876      2.560      0.82     -77   107
# Comp:  2          [OIII]5007_d      3.426       1.0     -77   107
# Comp:  2            [OI]6300_d     0.2480       1.0     -77   107
# Comp:  2           [NII]6583_d      2.507       1.0     -77   107
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -346       652
#  comp.  1:      -106        59
#  comp.  2:       -64       143
# chi2/DOF: 1.089; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.263      0.69    -106    59
# Comp:  1                Halpha      8.418      0.69    -106    59
# Comp:  2             [SII]6716      5.195      0.92     -64   143
# Comp:  2             [SII]6731      1.471      0.92     -64   143
# Comp:  2              HeII4687      0.000      0.92     -64   143
# Comp:  2               HeI5876      2.903      0.92     -64   143
# Comp:  2          [OIII]5007_d      3.667       1.2     -64   143
# Comp:  2            [OI]6300_d      1.189       1.2     -64   143
# Comp:  2           [NII]6583_d      2.761       1.2     -64   143
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -213       757
#  comp.  1:       -93        58
#  comp.  2:       -80       161
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.312      0.68     -93    58
# Comp:  1                Halpha      8.205      0.68     -93    58
# Comp:  2             [SII]6716      4.333      0.96     -80   161
# Comp:  2             [SII]6731      1.817      0.96     -80   161
# Comp:  2              HeII4687      0.000      0.96     -80   161
# Comp:  2               HeI5876      2.415      0.96     -80   161
# Comp:  2          [OIII]5007_d      3.347       1.2     -80   161
# Comp:  2            [OI]6300_d     0.3304       1.2     -80   161
# Comp:  2           [NII]6583_d      1.582       1.2     -80   161
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -295      1000
#  comp.  1:       -92        44
#  comp.  2:       -74        99
# chi2/DOF: 1.090; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.203      0.65     -92    44
# Comp:  1                Halpha      7.528      0.65     -92    44
# Comp:  2             [SII]6716      4.615      0.80     -74    99
# Comp:  2             [SII]6731     0.4698      0.80     -74    99
# Comp:  2              HeII4687      0.000      0.80     -74    99
# Comp:  2               HeI5876      0.000      0.80     -74    99
# Comp:  2          [OIII]5007_d      2.339       1.0     -74    99
# Comp:  2            [OI]6300_d     0.4525       1.0     -74    99
# Comp:  2           [NII]6583_d      2.071       1.0     -74    99
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -235       773
#  comp.  1:      -103        65
#  comp.  2:       -85       114
# chi2/DOF: 1.093; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.381      0.70    -103    65
# Comp:  1                Halpha      8.144      0.70    -103    65
# Comp:  2             [SII]6716      3.660      0.84     -85   114
# Comp:  2             [SII]6731      1.155      0.84     -85   114
# Comp:  2              HeII4687      0.000      0.84     -85   114
# Comp:  2               HeI5876      2.947      0.84     -85   114
# Comp:  2          [OIII]5007_d      2.833       1.1     -85   114
# Comp:  2            [OI]6300_d      0.000       1.1     -85   114
# Comp:  2           [NII]6583_d      2.232       1.1     -85   114
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -312       769
#  comp.  1:       -99        50
#  comp.  2:      -102       165
# chi2/DOF: 1.092; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.550      0.67     -99    50
# Comp:  1                Halpha      7.962      0.67     -99    50
# Comp:  2             [SII]6716      4.187      0.97    -102   165
# Comp:  2             [SII]6731      1.607      0.97    -102   165
# Comp:  2              HeII4687      0.000      0.97    -102   165
# Comp:  2               HeI5876      3.499      0.97    -102   165
# Comp:  2          [OIII]5007_d      3.383       1.2    -102   165
# Comp:  2            [OI]6300_d      0.000       1.2    -102   165
# Comp:  2           [NII]6583_d      2.189       1.2    -102   165
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -601         1
#  comp.  1:       -92        34
#  comp.  2:       -55       132
# chi2/DOF: 1.089; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.345      0.63     -92    34
# Comp:  1                Halpha      7.172      0.63     -92    34
# Comp:  2             [SII]6716      4.195      0.89     -55   132
# Comp:  2             [SII]6731     0.5654      0.89     -55   132
# Comp:  2              HeII4687     0.7250      0.89     -55   132
# Comp:  2               HeI5876      3.454      0.89     -55   132
# Comp:  2          [OIII]5007_d      3.851       1.1     -55   132
# Comp:  2            [OI]6300_d    0.08501       1.1     -55   132
# Comp:  2           [NII]6583_d      1.635       1.1     -55   132
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -509      1000
#  comp.  1:       -95        50
#  comp.  2:       -28       177
# chi2/DOF: 1.091; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.404      0.66     -95    50
# Comp:  1                Halpha      7.509      0.66     -95    50
# Comp:  2             [SII]6716      5.180       1.0     -28   177
# Comp:  2             [SII]6731     0.7187       1.0     -28   177
# Comp:  2              HeII4687      0.000       1.0     -28   177
# Comp:  2               HeI5876      5.037       1.0     -28   177
# Comp:  2          [OIII]5007_d      2.632       1.3     -28   177
# Comp:  2            [OI]6300_d     0.1433       1.3     -28   177
# Comp:  2           [NII]6583_d      2.480       1.3     -28   177
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        95       771
#  comp.  1:       -85        32
#  comp.  2:       -79       122
# chi2/DOF: 1.086; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.544      0.63     -85    32
# Comp:  1                Halpha      6.864      0.63     -85    32
# Comp:  2             [SII]6716      4.419      0.86     -79   122
# Comp:  2             [SII]6731      1.312      0.86     -79   122
# Comp:  2              HeII4687      0.000      0.86     -79   122
# Comp:  2               HeI5876      1.019      0.86     -79   122
# Comp:  2          [OIII]5007_d      3.362       1.1     -79   122
# Comp:  2            [OI]6300_d     0.7423       1.1     -79   122
# Comp:  2           [NII]6583_d      1.840       1.1     -79   122
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        90       688
#  comp.  1:       -89        47
#  comp.  2:       -99       122
# chi2/DOF: 1.091; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.652      0.66     -89    47
# Comp:  1                Halpha      7.676      0.66     -89    47
# Comp:  2             [SII]6716      4.984      0.86     -99   122
# Comp:  2             [SII]6731     0.6061      0.86     -99   122
# Comp:  2              HeII4687      0.000      0.86     -99   122
# Comp:  2               HeI5876      3.600      0.86     -99   122
# Comp:  2          [OIII]5007_d      2.894       1.1     -99   122
# Comp:  2            [OI]6300_d      0.000       1.1     -99   122
# Comp:  2           [NII]6583_d      2.317       1.1     -99   122
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       163       298
#  comp.  1:      -103        59
#  comp.  2:      -127       179
# chi2/DOF: 1.091; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.834      0.69    -103    59
# Comp:  1                Halpha      8.295      0.69    -103    59
# Comp:  2             [SII]6716      4.774       1.0    -127   179
# Comp:  2             [SII]6731      1.210       1.0    -127   179
# Comp:  2              HeII4687     0.3924       1.0    -127   179
# Comp:  2               HeI5876      2.572       1.0    -127   179
# Comp:  2          [OIII]5007_d      4.151       1.3    -127   179
# Comp:  2            [OI]6300_d      1.439       1.3    -127   179
# Comp:  2           [NII]6583_d      2.729       1.3    -127   179
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -547       733
#  comp.  1:      -100        47
#  comp.  2:      -122       136
# chi2/DOF: 1.087; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.365      0.66    -100    47
# Comp:  1                Halpha      7.696      0.66    -100    47
# Comp:  2             [SII]6716      4.702      0.90    -122   136
# Comp:  2             [SII]6731     0.4504      0.90    -122   136
# Comp:  2              HeII4687     0.6004      0.90    -122   136
# Comp:  2               HeI5876      1.911      0.90    -122   136
# Comp:  2          [OIII]5007_d      3.495       1.1    -122   136
# Comp:  2            [OI]6300_d      0.000       1.1    -122   136
# Comp:  2           [NII]6583_d      2.123       1.1    -122   136
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -790      1000
#  comp.  1:       -97        39
#  comp.  2:      -130       126
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.040      0.64     -97    39
# Comp:  1                Halpha      7.125      0.64     -97    39
# Comp:  2             [SII]6716      4.103      0.87    -130   126
# Comp:  2             [SII]6731      1.719      0.87    -130   126
# Comp:  2              HeII4687      0.000      0.87    -130   126
# Comp:  2               HeI5876      1.962      0.87    -130   126
# Comp:  2          [OIII]5007_d      3.245       1.1    -130   126
# Comp:  2            [OI]6300_d      0.000       1.1    -130   126
# Comp:  2           [NII]6583_d      1.978       1.1    -130   126
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37      1000
#  comp.  1:       -97        50
#  comp.  2:      -157       167
# chi2/DOF: 1.091; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.427      0.67     -97    50
# Comp:  1                Halpha      7.977      0.67     -97    50
# Comp:  2             [SII]6716      4.012      0.98    -157   167
# Comp:  2             [SII]6731      2.024      0.98    -157   167
# Comp:  2              HeII4687      0.000      0.98    -157   167
# Comp:  2               HeI5876      2.795      0.98    -157   167
# Comp:  2          [OIII]5007_d      3.162       1.2    -157   167
# Comp:  2            [OI]6300_d      0.000       1.2    -157   167
# Comp:  2           [NII]6583_d      2.391       1.2    -157   167
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -235       674
#  comp.  1:       -96        40
#  comp.  2:      -114       146
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.059      0.64     -96    40
# Comp:  1                Halpha      7.389      0.64     -96    40
# Comp:  2             [SII]6716      5.281      0.92    -114   146
# Comp:  2             [SII]6731      1.458      0.92    -114   146
# Comp:  2              HeII4687      0.000      0.92    -114   146
# Comp:  2               HeI5876      2.334      0.92    -114   146
# Comp:  2          [OIII]5007_d      3.665       1.2    -114   146
# Comp:  2            [OI]6300_d      1.135       1.2    -114   146
# Comp:  2           [NII]6583_d      2.585       1.2    -114   146
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       422      1000
#  comp.  1:       -95        39
#  comp.  2:      -112       157
# chi2/DOF: 1.091; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.475      0.64     -95    39
# Comp:  1                Halpha      7.011      0.64     -95    39
# Comp:  2             [SII]6716      4.248      0.95    -112   157
# Comp:  2             [SII]6731     0.7149      0.95    -112   157
# Comp:  2              HeII4687     0.9159      0.95    -112   157
# Comp:  2               HeI5876     0.9663      0.95    -112   157
# Comp:  2          [OIII]5007_d      3.811       1.2    -112   157
# Comp:  2            [OI]6300_d      0.000       1.2    -112   157
# Comp:  2           [NII]6583_d      1.220       1.2    -112   157
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29       836
#  comp.  1:       -97        49
#  comp.  2:       -68       120
# chi2/DOF: 1.093; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.610      0.66     -97    49
# Comp:  1                Halpha      7.853      0.66     -97    49
# Comp:  2             [SII]6716      3.862      0.86     -68   120
# Comp:  2             [SII]6731     0.9845      0.86     -68   120
# Comp:  2              HeII4687      0.000      0.86     -68   120
# Comp:  2               HeI5876      2.749      0.86     -68   120
# Comp:  2          [OIII]5007_d      3.560       1.1     -68   120
# Comp:  2            [OI]6300_d      0.000       1.1     -68   120
# Comp:  2           [NII]6583_d      1.808       1.1     -68   120
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -353      1000
#  comp.  1:       -85        32
#  comp.  2:       -71       222
# chi2/DOF: 1.092; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.905      0.63     -85    32
# Comp:  1                Halpha      7.068      0.63     -85    32
# Comp:  2             [SII]6716      6.130       1.1     -71   222
# Comp:  2             [SII]6731      0.000       1.1     -71   222
# Comp:  2              HeII4687      1.253       1.1     -71   222
# Comp:  2               HeI5876      2.483       1.1     -71   222
# Comp:  2          [OIII]5007_d      5.151       1.4     -71   222
# Comp:  2            [OI]6300_d     0.4551       1.4     -71   222
# Comp:  2           [NII]6583_d      2.566       1.4     -71   222
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       109       484
#  comp.  1:      -101        48
#  comp.  2:      -209       216
# chi2/DOF: 1.089; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.084      0.66    -101    48
# Comp:  1                Halpha      8.057      0.66    -101    48
# Comp:  2             [SII]6716      3.087       1.1    -209   216
# Comp:  2             [SII]6731      1.732       1.1    -209   216
# Comp:  2              HeII4687     0.5727       1.1    -209   216
# Comp:  2               HeI5876      1.161       1.1    -209   216
# Comp:  2          [OIII]5007_d      5.130       1.4    -209   216
# Comp:  2            [OI]6300_d      3.632       1.4    -209   216
# Comp:  2           [NII]6583_d      3.888       1.4    -209   216
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -380       729
#  comp.  1:       -94        35
#  comp.  2:      -108       117
# chi2/DOF: 1.092; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.653      0.63     -94    35
# Comp:  1                Halpha      7.057      0.63     -94    35
# Comp:  2             [SII]6716      4.828      0.85    -108   117
# Comp:  2             [SII]6731     0.5530      0.85    -108   117
# Comp:  2              HeII4687      0.000      0.85    -108   117
# Comp:  2               HeI5876      2.853      0.85    -108   117
# Comp:  2          [OIII]5007_d      2.683       1.1    -108   117
# Comp:  2            [OI]6300_d      0.000       1.1    -108   117
# Comp:  2           [NII]6583_d      1.443       1.1    -108   117
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -474      1000
#  comp.  1:       -84        32
#  comp.  2:       -71       128
# chi2/DOF: 1.093; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.669      0.63     -84    32
# Comp:  1                Halpha      6.831      0.63     -84    32
# Comp:  2             [SII]6716      4.114      0.88     -71   128
# Comp:  2             [SII]6731      1.415      0.88     -71   128
# Comp:  2              HeII4687      0.000      0.88     -71   128
# Comp:  2               HeI5876      1.656      0.88     -71   128
# Comp:  2          [OIII]5007_d      3.108       1.1     -71   128
# Comp:  2            [OI]6300_d    0.07023       1.1     -71   128
# Comp:  2           [NII]6583_d      1.992       1.1     -71   128
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -252       831
#  comp.  1:       -94        37
#  comp.  2:       -44       127
# chi2/DOF: 1.093; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.648      0.64     -94    37
# Comp:  1                Halpha      7.571      0.64     -94    37
# Comp:  2             [SII]6716      3.440      0.87     -44   127
# Comp:  2             [SII]6731      1.112      0.87     -44   127
# Comp:  2              HeII4687     0.9016      0.87     -44   127
# Comp:  2               HeI5876      2.269      0.87     -44   127
# Comp:  2          [OIII]5007_d      2.559       1.1     -44   127
# Comp:  2            [OI]6300_d     0.9036       1.1     -44   127
# Comp:  2           [NII]6583_d      2.097       1.1     -44   127
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36      1000
#  comp.  1:       -90        41
#  comp.  2:      -701         1
# chi2/DOF: 1.011; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 15; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.431      0.64     -90    41
# Comp:  1                Halpha      7.087      0.64     -90    41
# Comp:  2             [SII]6716      0.000      0.59    -701     1
# Comp:  2             [SII]6731      1.709      0.59    -701     1
# Comp:  2              HeII4687      0.000      0.59    -701     1
# Comp:  2               HeI5876      0.000      0.59    -701     1
# Comp:  2          [OIII]5007_d      0.000      0.75    -701     1
# Comp:  2            [OI]6300_d      10.85      0.75    -701     1
# Comp:  2           [NII]6583_d     0.1876      0.75    -701     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        32       972
#  comp.  1:       -94        42
#  comp.  2:       -50       159
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.424      0.65     -94    42
# Comp:  1                Halpha      6.854      0.65     -94    42
# Comp:  2             [SII]6716      5.162      0.96     -50   159
# Comp:  2             [SII]6731     0.8002      0.96     -50   159
# Comp:  2              HeII4687     0.8834      0.96     -50   159
# Comp:  2               HeI5876      3.985      0.96     -50   159
# Comp:  2          [OIII]5007_d      3.396       1.2     -50   159
# Comp:  2            [OI]6300_d      0.000       1.2     -50   159
# Comp:  2           [NII]6583_d      1.876       1.2     -50   159
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -524       812
#  comp.  1:       -94        40
#  comp.  2:       -93       132
# chi2/DOF: 1.091; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.871      0.64     -94    40
# Comp:  1                Halpha      7.657      0.64     -94    40
# Comp:  2             [SII]6716      4.961      0.89     -93   132
# Comp:  2             [SII]6731      2.116      0.89     -93   132
# Comp:  2              HeII4687      0.000      0.89     -93   132
# Comp:  2               HeI5876      3.996      0.89     -93   132
# Comp:  2          [OIII]5007_d      2.307       1.1     -93   132
# Comp:  2            [OI]6300_d     0.6891       1.1     -93   132
# Comp:  2           [NII]6583_d      2.184       1.1     -93   132
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       436      1000
#  comp.  1:       -97        41
#  comp.  2:       -52       139
# chi2/DOF: 1.090; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.417      0.64     -97    41
# Comp:  1                Halpha      7.382      0.64     -97    41
# Comp:  2             [SII]6716      3.554      0.91     -52   139
# Comp:  2             [SII]6731      1.623      0.91     -52   139
# Comp:  2              HeII4687      0.000      0.91     -52   139
# Comp:  2               HeI5876      3.465      0.91     -52   139
# Comp:  2          [OIII]5007_d      4.634       1.1     -52   139
# Comp:  2            [OI]6300_d      0.000       1.1     -52   139
# Comp:  2           [NII]6583_d      2.404       1.1     -52   139
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -270      1000
#  comp.  1:       -99        47
#  comp.  2:      -145       192
# chi2/DOF: 1.088; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.609      0.66     -99    47
# Comp:  1                Halpha      7.768      0.66     -99    47
# Comp:  2             [SII]6716      6.129       1.0    -145   192
# Comp:  2             [SII]6731     0.8259       1.0    -145   192
# Comp:  2              HeII4687     0.9303       1.0    -145   192
# Comp:  2               HeI5876     0.9485       1.0    -145   192
# Comp:  2          [OIII]5007_d      4.865       1.3    -145   192
# Comp:  2            [OI]6300_d      1.486       1.3    -145   192
# Comp:  2           [NII]6583_d      2.174       1.3    -145   192
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -297       266
#  comp.  1:      -105        63
#  comp.  2:       -88       109
# chi2/DOF: 1.082; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.065      0.70    -105    63
# Comp:  1                Halpha      8.140      0.70    -105    63
# Comp:  2             [SII]6716      3.693      0.82     -88   109
# Comp:  2             [SII]6731      1.744      0.82     -88   109
# Comp:  2              HeII4687      0.000      0.82     -88   109
# Comp:  2               HeI5876     0.1344      0.82     -88   109
# Comp:  2          [OIII]5007_d      2.491       1.0     -88   109
# Comp:  2            [OI]6300_d     0.1941       1.0     -88   109
# Comp:  2           [NII]6583_d      1.330       1.0     -88   109
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37       651
#  comp.  1:       -95        51
#  comp.  2:      -109       126
# chi2/DOF: 1.090; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.010      0.67     -95    51
# Comp:  1                Halpha      7.581      0.67     -95    51
# Comp:  2             [SII]6716      2.932      0.87    -109   126
# Comp:  2             [SII]6731     0.9611      0.87    -109   126
# Comp:  2              HeII4687     0.9961      0.87    -109   126
# Comp:  2               HeI5876      1.150      0.87    -109   126
# Comp:  2          [OIII]5007_d      3.294       1.1    -109   126
# Comp:  2            [OI]6300_d      0.000       1.1    -109   126
# Comp:  2           [NII]6583_d      2.338       1.1    -109   126
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -596       554
#  comp.  1:       -93        44
#  comp.  2:       -64       104
# chi2/DOF: 1.090; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.303      0.65     -93    44
# Comp:  1                Halpha      7.686      0.65     -93    44
# Comp:  2             [SII]6716      3.684      0.81     -64   104
# Comp:  2             [SII]6731      1.416      0.81     -64   104
# Comp:  2              HeII4687     0.2732      0.81     -64   104
# Comp:  2               HeI5876      2.655      0.81     -64   104
# Comp:  2          [OIII]5007_d      2.674       1.0     -64   104
# Comp:  2            [OI]6300_d      0.000       1.0     -64   104
# Comp:  2           [NII]6583_d      2.146       1.0     -64   104
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -539       778
#  comp.  1:       -90        42
#  comp.  2:       -68        93
# chi2/DOF: 1.091; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.388      0.65     -90    42
# Comp:  1                Halpha      7.481      0.65     -90    42
# Comp:  2             [SII]6716      3.803      0.78     -68    93
# Comp:  2             [SII]6731      1.365      0.78     -68    93
# Comp:  2              HeII4687     0.1281      0.78     -68    93
# Comp:  2               HeI5876      3.332      0.78     -68    93
# Comp:  2          [OIII]5007_d      2.708      0.98     -68    93
# Comp:  2            [OI]6300_d    0.05604      0.98     -68    93
# Comp:  2           [NII]6583_d      2.154      0.98     -68    93
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       133      1000
#  comp.  1:       -87        37
#  comp.  2:       -83        86
# chi2/DOF: 1.091; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.050      0.63     -87    37
# Comp:  1                Halpha      7.042      0.63     -87    37
# Comp:  2             [SII]6716      4.326      0.76     -83    86
# Comp:  2             [SII]6731     0.4568      0.76     -83    86
# Comp:  2              HeII4687      0.000      0.76     -83    86
# Comp:  2               HeI5876      3.308      0.76     -83    86
# Comp:  2          [OIII]5007_d      2.212      0.96     -83    86
# Comp:  2            [OI]6300_d      0.000      0.96     -83    86
# Comp:  2           [NII]6583_d      2.082      0.96     -83    86
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -626      1000
#  comp.  1:       -86        25
#  comp.  2:       -75       166
# chi2/DOF: 1.091; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.245      0.61     -86    25
# Comp:  1                Halpha      6.640      0.61     -86    25
# Comp:  2             [SII]6716      5.460      0.98     -75   166
# Comp:  2             [SII]6731      1.551      0.98     -75   166
# Comp:  2              HeII4687     0.6438      0.98     -75   166
# Comp:  2               HeI5876      2.117      0.98     -75   166
# Comp:  2          [OIII]5007_d      3.001       1.2     -75   166
# Comp:  2            [OI]6300_d     0.4279       1.2     -75   166
# Comp:  2           [NII]6583_d      2.207       1.2     -75   166
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -304       707
#  comp.  1:       -87        22
#  comp.  2:       -50       135
# chi2/DOF: 1.095; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.429      0.61     -87    22
# Comp:  1                Halpha      6.619      0.61     -87    22
# Comp:  2             [SII]6716      3.406      0.90     -50   135
# Comp:  2             [SII]6731      1.472      0.90     -50   135
# Comp:  2              HeII4687      0.000      0.90     -50   135
# Comp:  2               HeI5876      1.909      0.90     -50   135
# Comp:  2          [OIII]5007_d      3.857       1.1     -50   135
# Comp:  2            [OI]6300_d      0.000       1.1     -50   135
# Comp:  2           [NII]6583_d      2.323       1.1     -50   135
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -625       665
#  comp.  1:       -89        39
#  comp.  2:      -126       133
# chi2/DOF: 1.092; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 38; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.619      0.64     -89    39
# Comp:  1                Halpha      6.913      0.64     -89    39
# Comp:  2             [SII]6716      4.217      0.89    -126   133
# Comp:  2             [SII]6731      1.133      0.89    -126   133
# Comp:  2              HeII4687      0.000      0.89    -126   133
# Comp:  2               HeI5876      2.892      0.89    -126   133
# Comp:  2          [OIII]5007_d      3.306       1.1    -126   133
# Comp:  2            [OI]6300_d      0.000       1.1    -126   133
# Comp:  2           [NII]6583_d      2.018       1.1    -126   133
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       176      1000
#  comp.  1:       -91        47
#  comp.  2:      -105       145
# chi2/DOF: 1.090; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.090      0.66     -91    47
# Comp:  1                Halpha      6.983      0.66     -91    47
# Comp:  2             [SII]6716      3.136      0.92    -105   145
# Comp:  2             [SII]6731     0.9769      0.92    -105   145
# Comp:  2              HeII4687    0.04496      0.92    -105   145
# Comp:  2               HeI5876      2.149      0.92    -105   145
# Comp:  2          [OIII]5007_d      2.760       1.2    -105   145
# Comp:  2            [OI]6300_d      2.101       1.2    -105   145
# Comp:  2           [NII]6583_d      2.285       1.2    -105   145
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -425       607
#  comp.  1:       -98        52
#  comp.  2:       -92       176
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.650      0.67     -98    52
# Comp:  1                Halpha      7.737      0.67     -98    52
# Comp:  2             [SII]6716      3.942       1.0     -92   176
# Comp:  2             [SII]6731      1.853       1.0     -92   176
# Comp:  2              HeII4687      0.000       1.0     -92   176
# Comp:  2               HeI5876      2.519       1.0     -92   176
# Comp:  2          [OIII]5007_d      2.389       1.3     -92   176
# Comp:  2            [OI]6300_d      0.000       1.3     -92   176
# Comp:  2           [NII]6583_d      2.013       1.3     -92   176
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -679      1000
#  comp.  1:       -85        31
#  comp.  2:      -114       118
# chi2/DOF: 1.089; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.285      0.62     -85    31
# Comp:  1                Halpha      7.045      0.62     -85    31
# Comp:  2             [SII]6716      4.173      0.85    -114   118
# Comp:  2             [SII]6731      1.761      0.85    -114   118
# Comp:  2              HeII4687      0.000      0.85    -114   118
# Comp:  2               HeI5876     0.7213      0.85    -114   118
# Comp:  2          [OIII]5007_d      3.035       1.1    -114   118
# Comp:  2            [OI]6300_d      0.000       1.1    -114   118
# Comp:  2           [NII]6583_d      1.652       1.1    -114   118
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -289      1000
#  comp.  1:       -95        52
#  comp.  2:       -76       158
# chi2/DOF: 1.092; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.725      0.67     -95    52
# Comp:  1                Halpha      7.565      0.67     -95    52
# Comp:  2             [SII]6716      4.426      0.95     -76   158
# Comp:  2             [SII]6731     0.8394      0.95     -76   158
# Comp:  2              HeII4687     0.7027      0.95     -76   158
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.350      0.61     -91    24
# Comp:  1                Halpha      6.929      0.61     -91    24
# Comp:  2             [SII]6716      3.501       1.0     -73   175
# Comp:  2             [SII]6731      1.712       1.0     -73   175
# Comp:  2              HeII4687      1.108       1.0     -73   175
# Comp:  2               HeI5876     0.7971       1.0     -73   175
# Comp:  2          [OIII]5007_d      4.708       1.3     -73   175
# Comp:  2            [OI]6300_d     0.8637       1.3     -73   175
# Comp:  2           [NII]6583_d      2.008       1.3     -73   175
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -127      1000
#  comp.  1:       -92        38
#  comp.  2:       -83       101
# chi2/DOF: 1.093; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.542      0.64     -92    38
# Comp:  1                Halpha      7.456      0.64     -92    38
# Comp:  2             [SII]6716      4.009      0.80     -83   101
# Comp:  2             [SII]6731     0.4202      0.80     -83   101
# Comp:  2              HeII4687      0.000      0.80     -83   101
# Comp:  2               HeI5876      1.376      0.80     -83   101
# Comp:  2          [OIII]5007_d      3.142       1.0     -83   101
# Comp:  2            [OI]6300_d     0.2988       1.0     -83   101
# Comp:  2           [NII]6583_d      1.715       1.0     -83   101
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        87       742
#  comp.  1:       -85        24
#  comp.  2:        26       158
# chi2/DOF: 1.092; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.952      0.61     -85    24
# Comp:  1                Halpha      6.687      0.61     -85    24
# Comp:  2             [SII]6716      4.132      0.96      26   158
# Comp:  2             [SII]6731      1.023      0.96      26   158
# Comp:  2              HeII4687     0.9439      0.96      26   158
# Comp:  2               HeI5876      3.989      0.96      26   158
# Comp:  2          [OIII]5007_d      3.232       1.2      26   158
# Comp:  2            [OI]6300_d      0.000       1.2      26   158
# Comp:  2           [NII]6583_d      1.560       1.2      26   158
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -223       793
#  comp.  1:       -94        47
#  comp.  2:       -43       147
# chi2/DOF: 1.092; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.809      0.66     -94    47
# Comp:  1                Halpha      7.580      0.66     -94    47
# Comp:  2             [SII]6716      4.995      0.93     -43   147
# Comp:  2             [SII]6731     0.9588      0.93     -43   147
# Comp:  2              HeII4687      0.000      0.93     -43   147
# Comp:  2               HeI5876      4.828      0.93     -43   147
# Comp:  2          [OIII]5007_d      3.261       1.2     -43   147
# Comp:  2            [OI]6300_d      0.000       1.2     -43   147
# Comp:  2           [NII]6583_d      2.305       1.2     -43   147
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -559       710
#  comp.  1:       -93        46
#  comp.  2:      -115       148
# chi2/DOF: 1.088; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.409      0.66     -93    46
# Comp:  1                Halpha      7.734      0.66     -93    46
# Comp:  2             [SII]6716      5.553      0.93    -115   148
# Comp:  2             [SII]6731     0.3681      0.93    -115   148
# Comp:  2              HeII4687     0.9020      0.93    -115   148
# Comp:  2               HeI5876      3.010      0.93    -115   148
# Comp:  2          [OIII]5007_d      3.570       1.2    -115   148
# Comp:  2            [OI]6300_d      1.523       1.2    -115   148
# Comp:  2           [NII]6583_d      2.119       1.2    -115   148
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69       671
#  comp.  1:      -103        63
#  comp.  2:       -88       138
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.647      0.70    -103    63
# Comp:  1                Halpha      8.567      0.70    -103    63
# Comp:  2             [SII]6716      3.256      0.90     -88   138
# Comp:  2             [SII]6731     0.9162      0.90     -88   138
# Comp:  2              HeII4687     0.2624      0.90     -88   138
# Comp:  2               HeI5876      3.253      0.90     -88   138
# Comp:  2          [OIII]5007_d      3.462       1.1     -88   138
# Comp:  2            [OI]6300_d     0.3584       1.1     -88   138
# Comp:  2           [NII]6583_d      2.835       1.1     -88   138
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       152      1000
#  comp.  1:       -91        43
#  comp.  2:       -87       134
# chi2/DOF: 1.088; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.399      0.65     -91    43
# Comp:  1                Halpha      7.616      0.65     -91    43
# Comp:  2             [SII]6716      4.405      0.89     -87   134
# Comp:  2             [SII]6731      1.739      0.89     -87   134
# Comp:  2              HeII4687      0.000      0.89     -87   134
# Comp:  2               HeI5876      1.398      0.89     -87   134
# Comp:  2          [OIII]5007_d      2.767       1.1     -87   134
# Comp:  2            [OI]6300_d      0.000       1.1     -87   134
# Comp:  2           [NII]6583_d      2.568       1.1     -87   134
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -520      1000
#  comp.  1:       -95        58
#  comp.  2:      -101       120
# chi2/DOF: 1.092; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.562      0.68     -95    58
# Comp:  1                Halpha      7.865      0.68     -95    58
# Comp:  2             [SII]6716      3.810      0.85    -101   120
# Comp:  2             [SII]6731     0.4769      0.85    -101   120
# Comp:  2              HeII4687     0.1713      0.85    -101   120
# Comp:  2               HeI5876      3.120      0.85    -101   120
# Comp:  2          [OIII]5007_d      3.470       1.1    -101   120
# Comp:  2            [OI]6300_d     0.5042       1.1    -101   120
# Comp:  2           [NII]6583_d      1.847       1.1    -101   120
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14       639
#  comp.  1:       -98        42
#  comp.  2:       -71       139
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.404      0.65     -98    42
# Comp:  1                Halpha      7.739      0.65     -98    42
# Comp:  2             [SII]6716      4.696      0.91     -71   139
# Comp:  2             [SII]6731      1.187      0.91     -71   139
# Comp:  2              HeII4687     0.3963      0.91     -71   139
# Comp:  2               HeI5876      3.156      0.91     -71   139
# Comp:  2          [OIII]5007_d      3.143       1.1     -71   139
# Comp:  2            [OI]6300_d      0.000       1.1     -71   139
# Comp:  2           [NII]6583_d      2.348       1.1     -71   139
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -156       329
#  comp.  1:       -96        44
#  comp.  2:       -39       158
# chi2/DOF: 1.093; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.450      0.65     -96    44
# Comp:  1                Halpha      7.763      0.65     -96    44
# Comp:  2             [SII]6716      4.212      0.96     -39   158
# Comp:  2             [SII]6731     0.8916      0.96     -39   158
# Comp:  2              HeII4687     0.6275      0.96     -39   158
# Comp:  2               HeI5876      2.418      0.96     -39   158
# Comp:  2          [OIII]5007_d      4.444       1.2     -39   158
# Comp:  2            [OI]6300_d     0.4442       1.2     -39   158
# Comp:  2           [NII]6583_d      1.198       1.2     -39   158
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       233       663
#  comp.  1:       -89        26
#  comp.  2:       -67       111
# chi2/DOF: 1.091; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.657      0.61     -89    26
# Comp:  1                Halpha      6.926      0.61     -89    26
# Comp:  2             [SII]6716      4.812      0.83     -67   111
# Comp:  2             [SII]6731      1.514      0.83     -67   111
# Comp:  2              HeII4687     0.5662      0.83     -67   111
# Comp:  2               HeI5876      3.797      0.83     -67   111
# Comp:  2          [OIII]5007_d      3.726       1.0     -67   111
# Comp:  2            [OI]6300_d      0.000       1.0     -67   111
# Comp:  2           [NII]6583_d      1.341       1.0     -67   111
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -185       817
#  comp.  1:       -99        46
#  comp.  2:      -124       142
# chi2/DOF: 1.095; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.762      0.65     -99    46
# Comp:  1                Halpha      7.380      0.65     -99    46
# Comp:  2             [SII]6716      4.221      0.91    -124   142
# Comp:  2             [SII]6731      2.093      0.91    -124   142
# Comp:  2              HeII4687     0.1395      0.91    -124   142
# Comp:  2               HeI5876      2.870      0.91    -124   142
# Comp:  2          [OIII]5007_d      2.850       1.2    -124   142
# Comp:  2            [OI]6300_d      0.000       1.2    -124   142
# Comp:  2           [NII]6583_d      2.241       1.2    -124   142
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53       140
#  comp.  1:       -82        30
#  comp.  2:       -58       122
# chi2/DOF: 1.091; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.040      0.62     -82    30
# Comp:  1                Halpha      7.018      0.62     -82    30
# Comp:  2             [SII]6716      4.022      0.86     -58   122
# Comp:  2             [SII]6731      1.268      0.86     -58   122
# Comp:  2              HeII4687      0.000      0.86     -58   122
# Comp:  2               HeI5876      3.769      0.86     -58   122
# Comp:  2          [OIII]5007_d      3.694       1.1     -58   122
# Comp:  2            [OI]6300_d     0.3769       1.1     -58   122
# Comp:  2           [NII]6583_d      1.954       1.1     -58   122
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        22       665
#  comp.  1:       -98        45
#  comp.  2:       -69       177
# chi2/DOF: 1.093; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.394      0.65     -98    45
# Comp:  1                Halpha      7.686      0.65     -98    45
# Comp:  2             [SII]6716      4.747       1.0     -69   177
# Comp:  2             [SII]6731     0.3864       1.0     -69   177
# Comp:  2              HeII4687     0.5212       1.0     -69   177
# Comp:  2               HeI5876      3.752       1.0     -69   177
# Comp:  2          [OIII]5007_d      3.808       1.3     -69   177
# Comp:  2            [OI]6300_d     0.3563       1.3     -69   177
# Comp:  2           [NII]6583_d      2.037       1.3     -69   177
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.53722232, 0.69282846, 1.20785455, 0.62989105, 0.4429361 ,
#        1.49875824, 0.79726073, 1.23260196, 0.69310972])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 4.40699812, 10.09548473,  5.98900698,  1.59694275,  0.        ,
#         2.89773977,  3.58784403,  0.        ,  2.77146551])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_17_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_17", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_17_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_17_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_17_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.086420    0.010535
# 1        Halpha  0.197970    0.013586
# 2     [SII]6716  0.117443    0.023686
# 3     [SII]6731  0.031316    0.012352
# 4      HeII4687  0.000000    0.008686
# 5       HeI5876  0.056824    0.029390
# 6  [OIII]5007_d  0.070357    0.015634
# 7    [OI]6300_d  0.000000    0.024171
# 8   [NII]6583_d  0.054348    0.013592
#           Name      Flux  Error_flux
# 0        Hbeta  0.086420    0.010535
# 1       Halpha  0.197970    0.013586
# 2    [SII]6716  0.117443    0.023686
# 3    [SII]6731  0.031316    0.012352
# 4     HeII4687  0.000000    0.008686
# 5      HeI5876  0.056824    0.029390
# 6   [OIII]4959  0.017589    0.015634
# 7   [OIII]5007  0.052768    0.015634
# 8     [OI]6300  0.000000    0.024171
# 9     [OI]6364  0.000000    0.024171
# 10   [NII]6548  0.013587    0.013592
# 11   [NII]6583  0.040761    0.013592

# %%
np.median(flux_rf_rebin)
# Out:
# 0.01960977892852225
