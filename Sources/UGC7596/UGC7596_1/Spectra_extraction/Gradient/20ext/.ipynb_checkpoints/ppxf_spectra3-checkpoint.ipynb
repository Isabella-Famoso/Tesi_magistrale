# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.02857312 0.0317457  0.02097683 ... 0.01751543 0.01817175 0.01711254] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -81         1
# chi2/DOF: 0.08200; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -85         1
# chi2/DOF: 0.05106; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-84.76193662,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -75         1
#  comp.  1:       135        72
#  comp.  2:      -109       194
# chi2/DOF: 1.128; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4599      0.68     135    72
# Comp:  1                Halpha      1.460      0.68     135    72
# Comp:  2             [SII]6716    0.06059      0.98    -109   194
# Comp:  2             [SII]6731     0.1686      0.98    -109   194
# Comp:  2              HeII4687      2.938      0.98    -109   194
# Comp:  2               HeI5876     0.6217      0.98    -109   194
# Comp:  2          [OIII]5007_d      2.233       1.2    -109   194
# Comp:  2            [OI]6300_d      0.000       1.2    -109   194
# Comp:  2           [NII]6583_d     0.8508       1.2    -109   194
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise: 0.4785; gas flux:      0 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  1.542; gas flux:      2 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise: 0.03111; gas flux:      0 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise: 0.08684; gas flux:      0 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.517; gas flux:      3 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.3213; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise: 0.8687; gas flux:      2 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise: 0.3278; gas flux:      1 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
#  comp.  1:       152        26
#  comp.  2:      -142       143
# chi2/DOF: 1.122; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2486      0.58     152    26
# Comp:  1                Halpha      1.128      0.58     152    26
# Comp:  2             [SII]6716     0.5089      0.86    -142   143
# Comp:  2             [SII]6731      0.000      0.86    -142   143
# Comp:  2              HeII4687      2.422      0.86    -142   143
# Comp:  2               HeI5876     0.5854      0.86    -142   143
# Comp:  2          [OIII]5007_d      3.066       1.1    -142   143
# Comp:  2            [OI]6300_d     0.2160       1.1    -142   143
# Comp:  2           [NII]6583_d      1.406       1.1    -142   143
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -176        96
#  comp.  1:       160        49
#  comp.  2:      -125       183
# chi2/DOF: 1.116; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1852      0.62     160    49
# Comp:  1                Halpha      1.411      0.62     160    49
# Comp:  2             [SII]6716      0.000      0.96    -125   183
# Comp:  2             [SII]6731      0.000      0.96    -125   183
# Comp:  2              HeII4687      3.426      0.95    -125   183
# Comp:  2               HeI5876      1.872      0.95    -125   183
# Comp:  2          [OIII]5007_d      1.253       1.2    -125   183
# Comp:  2            [OI]6300_d      0.000       1.2    -125   183
# Comp:  2           [NII]6583_d     0.3142       1.2    -125   183
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8       141
#  comp.  1:       121        52
#  comp.  2:      -168         1
# chi2/DOF: 1.116; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 91; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8834      0.63     121    52
# Comp:  1                Halpha      1.952      0.63     121    52
# Comp:  2             [SII]6716      0.000      0.56    -168     1
# Comp:  2             [SII]6731     0.6677      0.56    -168     1
# Comp:  2              HeII4687      2.415      0.56    -168     1
# Comp:  2               HeI5876      0.000      0.56    -168     1
# Comp:  2          [OIII]5007_d     0.5816      0.70    -168     1
# Comp:  2            [OI]6300_d     0.3567      0.70    -168     1
# Comp:  2           [NII]6583_d      0.000      0.70    -168     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -107       289
#  comp.  1:       167        37
#  comp.  2:      -140        72
# chi2/DOF: 1.120; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8499      0.59     167    37
# Comp:  1                Halpha      1.178      0.59     167    37
# Comp:  2             [SII]6716      0.000      0.68    -140    72
# Comp:  2             [SII]6731     0.3454      0.68    -140    72
# Comp:  2              HeII4687      2.613      0.68    -140    72
# Comp:  2               HeI5876      1.086      0.68    -140    72
# Comp:  2          [OIII]5007_d      1.512      0.85    -140    72
# Comp:  2            [OI]6300_d      0.000      0.85    -140    72
# Comp:  2           [NII]6583_d      1.856      0.85    -140    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        59
#  comp.  1:       134        72
#  comp.  2:      -107       197
# chi2/DOF: 1.118; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1622      0.68     134    72
# Comp:  1                Halpha      1.432      0.68     134    72
# Comp:  2             [SII]6716      0.000      0.99    -107   197
# Comp:  2             [SII]6731      1.326      0.99    -107   197
# Comp:  2              HeII4687      3.107      0.99    -107   197
# Comp:  2               HeI5876     0.8971      0.99    -107   197
# Comp:  2          [OIII]5007_d    0.07470       1.2    -107   197
# Comp:  2            [OI]6300_d      1.705       1.2    -107   197
# Comp:  2           [NII]6583_d     0.9343       1.2    -107   197
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77       111
#  comp.  1:       130        69
#  comp.  2:      -107       196
# chi2/DOF: 1.124; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6761      0.67     130    69
# Comp:  1                Halpha      1.746      0.67     130    69
# Comp:  2             [SII]6716      0.000      0.99    -107   196
# Comp:  2             [SII]6731      0.000      0.99    -107   196
# Comp:  2              HeII4687      2.425      0.98    -107   196
# Comp:  2               HeI5876     0.7790      0.98    -107   196
# Comp:  2          [OIII]5007_d      1.014       1.2    -107   196
# Comp:  2            [OI]6300_d     0.2308       1.2    -107   196
# Comp:  2           [NII]6583_d      2.188       1.2    -107   196
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         1
#  comp.  1:       138        72
#  comp.  2:      -133       161
# chi2/DOF: 1.121; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6198      0.68     138    72
# Comp:  1                Halpha      1.625      0.68     138    72
# Comp:  2             [SII]6716     0.1424      0.90    -133   161
# Comp:  2             [SII]6731      0.000      0.90    -133   161
# Comp:  2              HeII4687      4.438      0.90    -133   161
# Comp:  2               HeI5876      0.000      0.90    -133   161
# Comp:  2          [OIII]5007_d      3.054       1.1    -133   161
# Comp:  2            [OI]6300_d      1.038       1.1    -133   161
# Comp:  2           [NII]6583_d      0.000       1.1    -133   161
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:       115        60
#  comp.  2:       -75       151
# chi2/DOF: 1.119; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta    0.09573      0.65     115    60
# Comp:  1                Halpha      1.374      0.65     115    60
# Comp:  2             [SII]6716     0.6096      0.88     -75   151
# Comp:  2             [SII]6731      0.000      0.88     -75   151
# Comp:  2              HeII4687      4.051      0.88     -75   151
# Comp:  2               HeI5876      0.000      0.88     -75   151
# Comp:  2          [OIII]5007_d      2.680       1.1     -75   151
# Comp:  2            [OI]6300_d      0.000       1.1     -75   151
# Comp:  2           [NII]6583_d     0.5980       1.1     -75   151
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         1
#  comp.  1:       142        55
#  comp.  2:       -11        60
# chi2/DOF: 1.118; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.63     142    55
# Comp:  1                Halpha      1.375      0.63     142    55
# Comp:  2             [SII]6716     0.3063      0.65     -11    60
# Comp:  2             [SII]6731     0.6488      0.65     -11    60
# Comp:  2              HeII4687      1.081      0.65     -11    60
# Comp:  2               HeI5876      0.000      0.65     -11    60
# Comp:  2          [OIII]5007_d      0.000      0.82     -11    60
# Comp:  2            [OI]6300_d      0.000      0.82     -11    60
# Comp:  2           [NII]6583_d      1.207      0.82     -11    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83         1
#  comp.  1:       141        84
#  comp.  2:       -45       239
# chi2/DOF: 1.122; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta    0.03879      0.71     141    84
# Comp:  1                Halpha      1.551      0.71     141    84
# Comp:  2             [SII]6716     0.2284       1.1     -45   239
# Comp:  2             [SII]6731     0.7669       1.1     -45   239
# Comp:  2              HeII4687      2.797       1.1     -45   239
# Comp:  2               HeI5876      1.297       1.1     -45   239
# Comp:  2          [OIII]5007_d      2.932       1.4     -45   239
# Comp:  2            [OI]6300_d      2.368       1.4     -45   239
# Comp:  2           [NII]6583_d      0.000       1.4     -45   239
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75         1
#  comp.  1:       152        73
#  comp.  2:       -81       237
# chi2/DOF: 1.118; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.68     152    73
# Comp:  1                Halpha      1.278      0.68     152    73
# Comp:  2             [SII]6716     0.3003       1.1     -81   237
# Comp:  2             [SII]6731     0.1285       1.1     -81   237
# Comp:  2              HeII4687      4.106       1.1     -81   237
# Comp:  2               HeI5876      2.967       1.1     -81   237
# Comp:  2          [OIII]5007_d      4.805       1.4     -81   237
# Comp:  2            [OI]6300_d      0.000       1.4     -81   237
# Comp:  2           [NII]6583_d      0.000       1.4     -81   237
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10       411
#  comp.  1:       155        36
#  comp.  2:       -62        23
# chi2/DOF: 1.118; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7518      0.59     155    36
# Comp:  1                Halpha      1.530      0.59     155    36
# Comp:  2             [SII]6716      0.000      0.57     -62    23
# Comp:  2             [SII]6731     0.5582      0.57     -62    23
# Comp:  2              HeII4687      1.765      0.57     -62    23
# Comp:  2               HeI5876     0.5302      0.57     -62    23
# Comp:  2          [OIII]5007_d     0.2646      0.72     -62    23
# Comp:  2            [OI]6300_d     0.1617      0.72     -62    23
# Comp:  2           [NII]6583_d     0.5569      0.72     -62    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76         1
#  comp.  1:        90        69
#  comp.  2:      -457       695
# chi2/DOF: 1.116; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7808      0.67      90    69
# Comp:  1                Halpha      1.864      0.74      90    69
# Comp:  2             [SII]6716      0.000       3.1    -457   695
# Comp:  2             [SII]6731      0.000       3.1    -457   695
# Comp:  2              HeII4687      5.057       1.8    -457   695
# Comp:  2               HeI5876      1.612       1.8    -457   695
# Comp:  2          [OIII]5007_d      2.843       2.3    -457   695
# Comp:  2            [OI]6300_d      8.463       2.3    -457   695
# Comp:  2           [NII]6583_d      0.000       2.3    -457   695
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -102         1
#  comp.  1:       124        25
#  comp.  2:      -676         1
# chi2/DOF: 0.9945; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 16; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.57     124    25
# Comp:  1                Halpha      1.065      0.61     124    25
# Comp:  2             [SII]6716     0.1849      0.56    -676     1
# Comp:  2             [SII]6731      0.000      0.56    -676     1
# Comp:  2              HeII4687      0.000      0.56    -676     1
# Comp:  2               HeI5876    0.01704      0.56    -676     1
# Comp:  2          [OIII]5007_d     0.6269      0.70    -676     1
# Comp:  2            [OI]6300_d      12.51      0.70    -676     1
# Comp:  2           [NII]6583_d    0.04171      0.74    -676     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        51
#  comp.  1:       100        78
#  comp.  2:      -180        93
# chi2/DOF: 1.118; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.108      0.69     100    78
# Comp:  1                Halpha      1.644      0.69     100    78
# Comp:  2             [SII]6716      0.000      0.73    -180    93
# Comp:  2             [SII]6731      0.000      0.73    -180    93
# Comp:  2              HeII4687      3.127      0.73    -180    93
# Comp:  2               HeI5876     0.8505      0.73    -180    93
# Comp:  2          [OIII]5007_d     0.8064      0.92    -180    93
# Comp:  2            [OI]6300_d      0.000      0.92    -180    93
# Comp:  2           [NII]6583_d      1.913      0.92    -180    93
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100       114
#  comp.  1:       245       267
#  comp.  2:       -29       133
# chi2/DOF: 1.117; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.499       1.1     245   267
# Comp:  1                Halpha      2.908       1.1     245   267
# Comp:  2             [SII]6716     0.5141      0.83     -29   133
# Comp:  2             [SII]6731      1.030      0.83     -29   133
# Comp:  2              HeII4687      2.388      0.83     -29   133
# Comp:  2               HeI5876     0.2956      0.83     -29   133
# Comp:  2          [OIII]5007_d      1.569       1.1     -29   133
# Comp:  2            [OI]6300_d      0.000       1.1     -29   133
# Comp:  2           [NII]6583_d     0.6866       1.1     -29   133
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:       169        80
#  comp.  2:      -103       120
# chi2/DOF: 1.120; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.094      0.70     169    80
# Comp:  1                Halpha      1.720      0.70     169    80
# Comp:  2             [SII]6716     0.2572      0.80    -103   120
# Comp:  2             [SII]6731      1.233      0.80    -103   120
# Comp:  2              HeII4687      2.353      0.80    -103   120
# Comp:  2               HeI5876     0.6047      0.80    -103   120
# Comp:  2          [OIII]5007_d      1.433       1.0    -103   120
# Comp:  2            [OI]6300_d      1.185       1.0    -103   120
# Comp:  2           [NII]6583_d      2.200       1.0    -103   120
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       181       113
#  comp.  2:      -152       129
# chi2/DOF: 1.121; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.125      0.78     181   113
# Comp:  1                Halpha      1.740      0.78     181   113
# Comp:  2             [SII]6716      0.000      0.82    -152   129
# Comp:  2             [SII]6731      0.000      0.82    -152   129
# Comp:  2              HeII4687      2.856      0.82    -152   129
# Comp:  2               HeI5876     0.9272      0.82    -152   129
# Comp:  2          [OIII]5007_d      1.728       1.0    -152   129
# Comp:  2            [OI]6300_d     0.3991       1.0    -152   129
# Comp:  2           [NII]6583_d      0.000       1.0    -152   129
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88         1
#  comp.  1:       184       124
#  comp.  2:       -72       182
# chi2/DOF: 1.121; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.063      0.81     184   124
# Comp:  1                Halpha      1.725      0.81     184   124
# Comp:  2             [SII]6716     0.1167      0.95     -72   182
# Comp:  2             [SII]6731      0.000      0.95     -72   182
# Comp:  2              HeII4687      4.208      0.95     -72   182
# Comp:  2               HeI5876      0.000      0.95     -72   182
# Comp:  2          [OIII]5007_d      4.063       1.2     -72   182
# Comp:  2            [OI]6300_d      0.000       1.2     -72   182
# Comp:  2           [NII]6583_d     0.9537       1.2     -72   182
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70        88
#  comp.  1:       133        94
#  comp.  2:      -106       175
# chi2/DOF: 1.123; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.800      0.73     133    94
# Comp:  1                Halpha      2.074      0.73     133    94
# Comp:  2             [SII]6716     0.1855      0.94    -106   175
# Comp:  2             [SII]6731      0.000      0.94    -106   175
# Comp:  2              HeII4687      2.920      0.93    -106   175
# Comp:  2               HeI5876      1.451      0.93    -106   175
# Comp:  2          [OIII]5007_d     0.6639       1.2    -106   175
# Comp:  2            [OI]6300_d      0.000       1.2    -106   175
# Comp:  2           [NII]6583_d      0.000       1.2    -106   175
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       121       104
#  comp.  2:      -120        76
# chi2/DOF: 1.122; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8662      0.76     121   104
# Comp:  1                Halpha      1.823      0.76     121   104
# Comp:  2             [SII]6716      0.000      0.69    -120    76
# Comp:  2             [SII]6731      0.000      0.69    -120    76
# Comp:  2              HeII4687      2.647      0.69    -120    76
# Comp:  2               HeI5876     0.6725      0.69    -120    76
# Comp:  2          [OIII]5007_d      2.033      0.87    -120    76
# Comp:  2            [OI]6300_d      0.000      0.87    -120    76
# Comp:  2           [NII]6583_d      0.000      0.87    -120    76
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100         1
#  comp.  1:       160        61
#  comp.  2:      -183       195
# chi2/DOF: 1.114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1559      0.65     160    61
# Comp:  1                Halpha      1.132      0.65     160    61
# Comp:  2             [SII]6716     0.6329      0.98    -183   195
# Comp:  2             [SII]6731      1.232      0.98    -183   195
# Comp:  2              HeII4687      3.899      0.98    -183   195
# Comp:  2               HeI5876      0.000      0.98    -183   195
# Comp:  2          [OIII]5007_d      1.888       1.2    -183   195
# Comp:  2            [OI]6300_d      2.429       1.2    -183   195
# Comp:  2           [NII]6583_d     0.7444       1.2    -183   195
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       124        75
#  comp.  2:       -99       212
# chi2/DOF: 1.120; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.68     124    75
# Comp:  1                Halpha      1.610      0.68     124    75
# Comp:  2             [SII]6716      0.000       1.0     -99   212
# Comp:  2             [SII]6731     0.6268       1.0     -99   212
# Comp:  2              HeII4687      3.369       1.0     -99   212
# Comp:  2               HeI5876      0.000       1.0     -99   212
# Comp:  2          [OIII]5007_d      4.307       1.3     -99   212
# Comp:  2            [OI]6300_d      0.000       1.3     -99   212
# Comp:  2           [NII]6583_d     0.8461       1.3     -99   212
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       112        44
#  comp.  2:      -189       104
# chi2/DOF: 1.123; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4087      0.61     112    44
# Comp:  1                Halpha      1.373      0.61     112    44
# Comp:  2             [SII]6716      0.000      0.76    -189   104
# Comp:  2             [SII]6731    0.06051      0.76    -189   104
# Comp:  2              HeII4687      2.905      0.76    -189   104
# Comp:  2               HeI5876     0.2910      0.76    -189   104
# Comp:  2          [OIII]5007_d      1.276      0.96    -189   104
# Comp:  2            [OI]6300_d      0.000      0.96    -189   104
# Comp:  2           [NII]6583_d      2.146      0.96    -189   104
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
#  comp.  1:        68        95
#  comp.  2:      -115       153
# chi2/DOF: 1.122; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.149      0.74      68    95
# Comp:  1                Halpha      1.820      0.74      68    95
# Comp:  2             [SII]6716      0.000      0.88    -115   153
# Comp:  2             [SII]6731     0.4526      0.88    -115   153
# Comp:  2              HeII4687      2.724      0.88    -115   153
# Comp:  2               HeI5876     0.5652      0.88    -115   153
# Comp:  2          [OIII]5007_d      1.147       1.1    -115   153
# Comp:  2            [OI]6300_d      1.566       1.1    -115   153
# Comp:  2           [NII]6583_d     0.7092       1.1    -115   153
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75         1
#  comp.  1:       124       174
#  comp.  2:      -694         1
# chi2/DOF: 1.015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.011      0.93     124   174
# Comp:  1                Halpha      2.631       1.2     124   174
# Comp:  2             [SII]6716      0.000      0.56    -694     1
# Comp:  2             [SII]6731     0.3216      0.56    -694     1
# Comp:  2              HeII4687      0.000      0.56    -694     1
# Comp:  2               HeI5876    0.04675      0.56    -694     1
# Comp:  2          [OIII]5007_d      0.000      0.70    -694     1
# Comp:  2            [OI]6300_d      10.95      0.70    -694     1
# Comp:  2           [NII]6583_d      0.000      0.89    -694     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        42
#  comp.  1:       135        76
#  comp.  2:      -110       195
# chi2/DOF: 1.120; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7583      0.69     135    76
# Comp:  1                Halpha      1.541      0.69     135    76
# Comp:  2             [SII]6716      0.000      0.98    -110   195
# Comp:  2             [SII]6731    0.07932      0.98    -110   195
# Comp:  2              HeII4687      5.396      0.98    -110   195
# Comp:  2               HeI5876      1.078      0.98    -110   195
# Comp:  2          [OIII]5007_d      1.921       1.2    -110   195
# Comp:  2            [OI]6300_d      1.561       1.2    -110   195
# Comp:  2           [NII]6583_d      1.972       1.2    -110   195
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -134        71
#  comp.  1:       138        89
#  comp.  2:       -40       121
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3853      0.72     138    89
# Comp:  1                Halpha      1.773      0.72     138    89
# Comp:  2             [SII]6716     0.2377      0.80     -40   121
# Comp:  2             [SII]6731     0.9029      0.80     -40   121
# Comp:  2              HeII4687      1.673      0.80     -40   121
# Comp:  2               HeI5876      1.763      0.80     -40   121
# Comp:  2          [OIII]5007_d      2.403       1.0     -40   121
# Comp:  2            [OI]6300_d     0.3216       1.0     -40   121
# Comp:  2           [NII]6583_d     0.9376       1.0     -40   121
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68         1
#  comp.  1:       209       338
#  comp.  2:       -11        60
# chi2/DOF: 1.119; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.521       1.3     209   338
# Comp:  1                Halpha      2.832       1.3     209   338
# Comp:  2             [SII]6716    0.04997      0.65     -11    60
# Comp:  2             [SII]6731     0.2532      0.65     -11    60
# Comp:  2              HeII4687      1.107      0.65     -11    60
# Comp:  2               HeI5876      1.586      0.65     -11    60
# Comp:  2          [OIII]5007_d      2.809      0.82     -11    60
# Comp:  2            [OI]6300_d      0.000      0.82     -11    60
# Comp:  2           [NII]6583_d     0.3828      0.82     -11    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         1
#  comp.  1:       163        72
#  comp.  2:       -94       150
# chi2/DOF: 1.122; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3098      0.67     163    72
# Comp:  1                Halpha      1.575      0.67     163    72
# Comp:  2             [SII]6716      0.000      0.87     -94   150
# Comp:  2             [SII]6731      0.000      0.87     -94   150
# Comp:  2              HeII4687      2.856      0.87     -94   150
# Comp:  2               HeI5876      0.000      0.87     -94   150
# Comp:  2          [OIII]5007_d     0.8270       1.1     -94   150
# Comp:  2            [OI]6300_d      0.000       1.1     -94   150
# Comp:  2           [NII]6583_d      1.359       1.1     -94   150
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100         1
#  comp.  1:       111        91
#  comp.  2:        -6       218
# chi2/DOF: 1.118; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.73     111    91
# Comp:  1                Halpha      1.344      0.73     111    91
# Comp:  2             [SII]6716     0.1323       1.0      -6   218
# Comp:  2             [SII]6731      1.249       1.0      -6   218
# Comp:  2              HeII4687      1.328       1.0      -6   218
# Comp:  2               HeI5876      0.000       1.0      -6   218
# Comp:  2          [OIII]5007_d      1.323       1.3      -6   218
# Comp:  2            [OI]6300_d      0.000       1.3      -6   218
# Comp:  2           [NII]6583_d     0.9320       1.3      -6   218
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        50
#  comp.  1:       134       124
#  comp.  2:       -97       210
# chi2/DOF: 1.121; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.907      0.81     134   124
# Comp:  1                Halpha      2.422      0.81     134   124
# Comp:  2             [SII]6716     0.8810       1.0     -97   210
# Comp:  2             [SII]6731      0.000       1.0     -97   210
# Comp:  2              HeII4687      2.990       1.0     -97   210
# Comp:  2               HeI5876      0.000       1.0     -97   210
# Comp:  2          [OIII]5007_d      2.331       1.3     -97   210
# Comp:  2            [OI]6300_d      0.000       1.3     -97   210
# Comp:  2           [NII]6583_d   0.007486       1.3     -97   210
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88        39
#  comp.  1:       113        55
#  comp.  2:      -165       224
# chi2/DOF: 1.123; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4891      0.63     113    55
# Comp:  1                Halpha      1.425      0.63     113    55
# Comp:  2             [SII]6716      0.000       1.1    -165   224
# Comp:  2             [SII]6731      0.000       1.1    -165   224
# Comp:  2              HeII4687      3.723       1.0    -165   224
# Comp:  2               HeI5876      0.000       1.0    -165   224
# Comp:  2          [OIII]5007_d      1.514       1.3    -165   224
# Comp:  2            [OI]6300_d     0.1712       1.3    -165   224
# Comp:  2           [NII]6583_d      1.865       1.3    -165   224
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        22
#  comp.  1:       135        74
#  comp.  2:      -111       193
# chi2/DOF: 1.122; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.044      0.68     135    74
# Comp:  1                Halpha      1.728      0.68     135    74
# Comp:  2             [SII]6716     0.4498      0.98    -111   193
# Comp:  2             [SII]6731     0.5094      0.98    -111   193
# Comp:  2              HeII4687      3.490      0.98    -111   193
# Comp:  2               HeI5876      1.291      0.98    -111   193
# Comp:  2          [OIII]5007_d      1.835       1.2    -111   193
# Comp:  2            [OI]6300_d      1.082       1.2    -111   193
# Comp:  2           [NII]6583_d      1.379       1.2    -111   193
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85         1
#  comp.  1:       102       137
#  comp.  2:       -54       162
# chi2/DOF: 1.120; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8980      0.84     102   137
# Comp:  1                Halpha      2.433      0.84     102   137
# Comp:  2             [SII]6716      0.000      0.91     -54   162
# Comp:  2             [SII]6731      0.000      0.91     -54   162
# Comp:  2              HeII4687      1.702      0.90     -54   162
# Comp:  2               HeI5876      1.018      0.90     -54   162
# Comp:  2          [OIII]5007_d      2.935       1.1     -54   162
# Comp:  2            [OI]6300_d     0.5872       1.1     -54   162
# Comp:  2           [NII]6583_d      1.856       1.1     -54   162
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81         1
#  comp.  1:       151       201
#  comp.  2:      -682         1
# chi2/DOF: 0.9560; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.480      0.99     151   201
# Comp:  1                Halpha      1.985       1.3     151   201
# Comp:  2             [SII]6716      0.000      0.56    -682     1
# Comp:  2             [SII]6731      0.000      0.56    -682     1
# Comp:  2              HeII4687     0.7335      0.56    -682     1
# Comp:  2               HeI5876      0.000      0.56    -682     1
# Comp:  2          [OIII]5007_d      0.000      0.70    -682     1
# Comp:  2            [OI]6300_d      13.47      0.70    -682     1
# Comp:  2           [NII]6583_d     0.4526      0.91    -682     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86         1
#  comp.  1:       132       113
#  comp.  2:      -115       198
# chi2/DOF: 1.122; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta    0.07038      0.78     132   113
# Comp:  1                Halpha      1.602      0.78     132   113
# Comp:  2             [SII]6716    0.04644      0.99    -115   198
# Comp:  2             [SII]6731      0.000      0.99    -115   198
# Comp:  2              HeII4687     0.5390      0.99    -115   198
# Comp:  2               HeI5876     0.2508      0.99    -115   198
# Comp:  2          [OIII]5007_d      2.188       1.2    -115   198
# Comp:  2            [OI]6300_d      0.000       1.2    -115   198
# Comp:  2           [NII]6583_d      0.000       1.2    -115   198
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:       142       129
#  comp.  2:       -49       277
# chi2/DOF: 1.120; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9059      0.82     142   129
# Comp:  1                Halpha      2.086      0.83     142   129
# Comp:  2             [SII]6716    0.08400       1.2     -49   277
# Comp:  2             [SII]6731      0.000       1.2     -49   277
# Comp:  2              HeII4687      2.618       1.2     -49   277
# Comp:  2               HeI5876      0.000       1.2     -49   277
# Comp:  2          [OIII]5007_d      1.862       1.5     -49   277
# Comp:  2            [OI]6300_d      0.000       1.5     -49   277
# Comp:  2           [NII]6583_d      0.000       1.5     -49   277
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        19        98
#  comp.  1:        89       113
#  comp.  2:      -225        90
# chi2/DOF: 1.117; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.574      0.78      89   113
# Comp:  1                Halpha      2.652      0.78      89   113
# Comp:  2             [SII]6716     0.3154      0.72    -225    90
# Comp:  2             [SII]6731      1.012      0.72    -225    90
# Comp:  2              HeII4687      1.025      0.72    -225    90
# Comp:  2               HeI5876     0.6684      0.72    -225    90
# Comp:  2          [OIII]5007_d      1.594      0.91    -225    90
# Comp:  2            [OI]6300_d      1.271      0.91    -225    90
# Comp:  2           [NII]6583_d      1.596      0.91    -225    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        84
#  comp.  1:       134        72
#  comp.  2:      -103       191
# chi2/DOF: 1.122; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.68     134    72
# Comp:  1                Halpha      1.639      0.68     134    72
# Comp:  2             [SII]6716      0.000      0.97    -103   191
# Comp:  2             [SII]6731     0.7867      0.97    -103   191
# Comp:  2              HeII4687      2.029      0.97    -103   191
# Comp:  2               HeI5876      0.000      0.97    -103   191
# Comp:  2          [OIII]5007_d     0.8054       1.2    -103   191
# Comp:  2            [OI]6300_d      0.000       1.2    -103   191
# Comp:  2           [NII]6583_d      0.000       1.2    -103   191
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        56
#  comp.  1:       137        72
#  comp.  2:      -111       197
# chi2/DOF: 1.123; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4661      0.68     137    72
# Comp:  1                Halpha      1.636      0.68     137    72
# Comp:  2             [SII]6716     0.4022      0.99    -111   197
# Comp:  2             [SII]6731     0.9707      0.99    -111   197
# Comp:  2              HeII4687      3.572      0.99    -111   197
# Comp:  2               HeI5876      0.000      0.99    -111   197
# Comp:  2          [OIII]5007_d      1.128       1.2    -111   197
# Comp:  2            [OI]6300_d      0.000       1.2    -111   197
# Comp:  2           [NII]6583_d      0.000       1.2    -111   197
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        44
#  comp.  1:        53       181
#  comp.  2:      -127       219
# chi2/DOF: 1.123; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.076      0.95      53   181
# Comp:  1                Halpha      3.613      0.95      53   181
# Comp:  2             [SII]6716      0.000       1.0    -127   219
# Comp:  2             [SII]6731      0.000       1.0    -127   219
# Comp:  2              HeII4687      3.545       1.0    -127   219
# ...
# chi2/DOF: 1.122; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.68     133    73
# Comp:  1                Halpha      1.352      0.68     133    73
# Comp:  2             [SII]6716      0.000      0.98    -111   193
# Comp:  2             [SII]6731    0.09485      0.98    -111   193
# Comp:  2              HeII4687      3.032      0.98    -111   193
# Comp:  2               HeI5876      0.000      0.98    -111   193
# Comp:  2          [OIII]5007_d      3.016       1.2    -111   193
# Comp:  2            [OI]6300_d      0.000       1.2    -111   193
# Comp:  2           [NII]6583_d      1.921       1.2    -111   193
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        48
#  comp.  1:       137        73
#  comp.  2:      -106       193
# chi2/DOF: 1.124; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8784      0.68     137    73
# Comp:  1                Halpha      1.484      0.68     137    73
# Comp:  2             [SII]6716      0.000      0.98    -106   193
# Comp:  2             [SII]6731     0.2889      0.98    -106   193
# Comp:  2              HeII4687      1.845      0.98    -106   193
# Comp:  2               HeI5876      1.753      0.98    -106   193
# Comp:  2          [OIII]5007_d      2.430       1.2    -106   193
# Comp:  2            [OI]6300_d      0.000       1.2    -106   193
# Comp:  2           [NII]6583_d      1.019       1.2    -106   193
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -124        77
#  comp.  1:       139        41
#  comp.  2:        19       323
# chi2/DOF: 1.118; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4104      0.60     139    41
# Comp:  1                Halpha      1.306      0.60     139    41
# Comp:  2             [SII]6716     0.2056       1.3      19   323
# Comp:  2             [SII]6731     0.1787       1.3      19   323
# Comp:  2              HeII4687      1.828       1.2      19   323
# Comp:  2               HeI5876      1.426       1.2      19   323
# Comp:  2          [OIII]5007_d      4.257       1.6      19   323
# Comp:  2            [OI]6300_d      0.000       1.6      19   323
# Comp:  2           [NII]6583_d      2.802       1.6      19   323
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77        59
#  comp.  1:       134        71
#  comp.  2:      -110       195
# chi2/DOF: 1.121; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9566      0.67     134    71
# Comp:  1                Halpha      1.571      0.67     134    71
# Comp:  2             [SII]6716      0.000      0.99    -110   195
# Comp:  2             [SII]6731      0.000      0.99    -110   195
# Comp:  2              HeII4687      2.122      0.98    -110   195
# Comp:  2               HeI5876     0.2844      0.98    -110   195
# Comp:  2          [OIII]5007_d     0.5967       1.2    -110   195
# Comp:  2            [OI]6300_d      1.138       1.2    -110   195
# Comp:  2           [NII]6583_d      1.917       1.2    -110   195
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:       124        66
#  comp.  2:       -77       140
# chi2/DOF: 1.123; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta   0.007187      0.66     124    66
# Comp:  1                Halpha      1.474      0.66     124    66
# Comp:  2             [SII]6716     0.5852      0.85     -77   140
# Comp:  2             [SII]6731      0.000      0.85     -77   140
# Comp:  2              HeII4687      3.047      0.85     -77   140
# Comp:  2               HeI5876      1.507      0.85     -77   140
# Comp:  2          [OIII]5007_d      1.955       1.1     -77   140
# Comp:  2            [OI]6300_d     0.3918       1.1     -77   140
# Comp:  2           [NII]6583_d     0.5089       1.1     -77   140
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         1
#  comp.  1:       142       102
#  comp.  2:       -37        25
# chi2/DOF: 1.119; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4847      0.75     142   102
# Comp:  1                Halpha      1.776      0.75     142   102
# Comp:  2             [SII]6716      0.000      0.57     -37    25
# Comp:  2             [SII]6731    0.06996      0.57     -37    25
# Comp:  2              HeII4687     0.9105      0.57     -37    25
# Comp:  2               HeI5876      1.149      0.57     -37    25
# Comp:  2          [OIII]5007_d      1.988      0.73     -37    25
# Comp:  2            [OI]6300_d      0.000      0.73     -37    25
# Comp:  2           [NII]6583_d     0.8921      0.73     -37    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84         1
#  comp.  1:       178        86
#  comp.  2:      -153       237
# chi2/DOF: 1.124; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.71     178    86
# Comp:  1                Halpha      1.632      0.71     178    86
# Comp:  2             [SII]6716     0.4019       1.1    -153   237
# Comp:  2             [SII]6731     0.8783       1.1    -153   237
# Comp:  2              HeII4687      2.516       1.1    -153   237
# Comp:  2               HeI5876      1.933       1.1    -153   237
# Comp:  2          [OIII]5007_d      2.090       1.4    -153   237
# Comp:  2            [OI]6300_d      0.000       1.4    -153   237
# Comp:  2           [NII]6583_d      1.834       1.4    -153   237
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        44
#  comp.  1:       135        54
#  comp.  2:       -72         1
# chi2/DOF: 1.124; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2491      0.63     135    54
# Comp:  1                Halpha      1.514      0.63     135    54
# Comp:  2             [SII]6716      0.000      0.56     -72     1
# Comp:  2             [SII]6731      0.000      0.56     -72     1
# Comp:  2              HeII4687      1.778      0.56     -72     1
# Comp:  2               HeI5876      0.000      0.56     -72     1
# Comp:  2          [OIII]5007_d      1.826      0.70     -72     1
# Comp:  2            [OI]6300_d     0.1791      0.70     -72     1
# Comp:  2           [NII]6583_d     0.7169      0.70     -72     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96         1
#  comp.  1:       174       191
#  comp.  2:      -698         1
# chi2/DOF: 0.9860; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 17; Func calls: 128; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.467      0.97     174   191
# Comp:  1                Halpha      1.780       1.3     174   191
# Comp:  2             [SII]6716  7.134e-05      0.56    -698     1
# Comp:  2             [SII]6731     0.1772      0.56    -698     1
# Comp:  2              HeII4687     0.5218      0.56    -698     1
# Comp:  2               HeI5876    0.05674      0.56    -698     1
# Comp:  2          [OIII]5007_d      0.000      0.70    -698     1
# Comp:  2            [OI]6300_d      12.37      0.70    -698     1
# Comp:  2           [NII]6583_d      0.000      0.97    -698     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        18
#  comp.  1:       134        71
#  comp.  2:      -109       195
# chi2/DOF: 1.118; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000      0.67     134    71
# Comp:  1                Halpha      1.088      0.67     134    71
# Comp:  2             [SII]6716      0.000      0.98    -109   195
# Comp:  2             [SII]6731     0.3772      0.98    -109   195
# Comp:  2              HeII4687      4.288      0.98    -109   195
# Comp:  2               HeI5876    0.01951      0.98    -109   195
# Comp:  2          [OIII]5007_d      3.888       1.2    -109   195
# Comp:  2            [OI]6300_d      1.235       1.2    -109   195
# Comp:  2           [NII]6583_d      0.000       1.2    -109   195
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:       113        65
#  comp.  2:      -121       123
# chi2/DOF: 1.118; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1453      0.66     113    65
# Comp:  1                Halpha      1.607      0.66     113    65
# Comp:  2             [SII]6716      0.000      0.81    -121   123
# Comp:  2             [SII]6731     0.5082      0.81    -121   123
# Comp:  2              HeII4687      3.109      0.81    -121   123
# Comp:  2               HeI5876     0.8214      0.81    -121   123
# Comp:  2          [OIII]5007_d      2.131       1.0    -121   123
# Comp:  2            [OI]6300_d     0.8940       1.0    -121   123
# Comp:  2           [NII]6583_d      1.169       1.0    -121   123
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -116         1
#  comp.  1:       143        63
#  comp.  2:        52       156
# chi2/DOF: 1.115; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2041      0.65     143    63
# Comp:  1                Halpha      1.358      0.65     143    63
# Comp:  2             [SII]6716      1.004      0.89      52   156
# Comp:  2             [SII]6731     0.7667      0.89      52   156
# Comp:  2              HeII4687      1.548      0.89      52   156
# Comp:  2               HeI5876      3.385      0.89      52   156
# Comp:  2          [OIII]5007_d      4.384       1.1      52   156
# Comp:  2            [OI]6300_d     0.8483       1.1      52   156
# Comp:  2           [NII]6583_d      2.107       1.1      52   156
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        28
#  comp.  1:       161        31
#  comp.  2:      -114       232
# chi2/DOF: 1.116; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2846      0.58     161    31
# Comp:  1                Halpha     0.9537      0.58     161    31
# Comp:  2             [SII]6716      0.000       1.1    -114   232
# Comp:  2             [SII]6731     0.2171       1.1    -114   232
# Comp:  2              HeII4687      5.943       1.1    -114   232
# Comp:  2               HeI5876      1.701       1.1    -114   232
# Comp:  2          [OIII]5007_d      2.994       1.3    -114   232
# Comp:  2            [OI]6300_d     0.8941       1.3    -114   232
# Comp:  2           [NII]6583_d      0.000       1.3    -114   232
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77        34
#  comp.  1:       134        71
#  comp.  2:      -107       196
# chi2/DOF: 1.120; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3039      0.67     134    71
# Comp:  1                Halpha      1.423      0.67     134    71
# Comp:  2             [SII]6716      0.000      0.99    -107   196
# Comp:  2             [SII]6731     0.2434      0.99    -107   196
# Comp:  2              HeII4687      2.249      0.98    -107   196
# Comp:  2               HeI5876     0.1962      0.98    -107   196
# Comp:  2          [OIII]5007_d      1.475       1.2    -107   196
# Comp:  2            [OI]6300_d     0.3136       1.2    -107   196
# Comp:  2           [NII]6583_d    0.04707       1.2    -107   196
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_3_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_3", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_3_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_3_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_3_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.009769    0.043760
# 1        Halpha  0.041871    0.029332
# 2     [SII]6716  0.001778    0.008567
# 3     [SII]6731  0.004959    0.012519
# 4      HeII4687  0.060157    0.024749
# 5       HeI5876  0.015962    0.021763
# 6  [OIII]5007_d  0.048843    0.028160
# 7    [OI]6300_d  0.000000    0.080165
# 8   [NII]6583_d  0.024476    0.023428
#           Name      Flux  Error_flux
# 0        Hbeta  0.009769    0.043760
# 1       Halpha  0.041871    0.029332
# 2    [SII]6716  0.001778    0.008567
# 3    [SII]6731  0.004959    0.012519
# 4     HeII4687  0.060157    0.024749
# 5      HeI5876  0.015962    0.021763
# 6   [OIII]4959  0.012211    0.028160
# 7   [OIII]5007  0.036632    0.028160
# 8     [OI]6300  0.000000    0.080165
# 9     [OI]6364  0.000000    0.080165
# 10   [NII]6548  0.006119    0.023428
# 11   [NII]6583  0.018357    0.023428

# %%
np.median(flux_rf_rebin)
