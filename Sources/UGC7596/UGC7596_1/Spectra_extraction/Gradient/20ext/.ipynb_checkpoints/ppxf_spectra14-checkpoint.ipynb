# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_14.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_14']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.04569607 0.05906607 0.06212333 ... 0.0344113  0.03834184 0.03571416] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -84         1
# chi2/DOF: 0.02451; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -84         1
# chi2/DOF: 0.01563; DOF: 1919; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-83.98249224,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -76         1
#  comp.  1:       -82        64
#  comp.  2:      -103        40
# chi2/DOF: 1.251; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.181      0.33     -82    64
# Comp:  1                Halpha      13.24      0.33     -82    64
# Comp:  2             [SII]6716      4.243      0.30    -103    40
# Comp:  2             [SII]6731      3.291      0.30    -103    40
# Comp:  2              HeII4687     0.4103      0.30    -103    40
# Comp:  2               HeI5876     0.3169      0.30    -103    40
# Comp:  2          [OIII]5007_d      3.886      0.38    -103    40
# Comp:  2            [OI]6300_d      2.118      0.38    -103    40
# Comp:  2           [NII]6583_d      2.046      0.38    -103    40
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  8.814; gas flux:      4 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  27.91; gas flux:     18 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  9.839; gas flux:      6 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  8.103; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.9965; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.7773; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  7.288; gas flux:      4 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  3.968; gas flux:      3 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  3.686; gas flux:      3 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -78         1
#  comp.  1:       -80        67
#  comp.  2:      -107        40
# chi2/DOF: 1.241; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.557      0.33     -80    67
# Comp:  1                Halpha      13.56      0.33     -80    67
# Comp:  2             [SII]6716      4.238      0.30    -107    40
# Comp:  2             [SII]6731      2.960      0.30    -107    40
# Comp:  2              HeII4687     0.5823      0.30    -107    40
# Comp:  2               HeI5876     0.3576      0.30    -107    40
# Comp:  2          [OIII]5007_d      4.560      0.38    -107    40
# Comp:  2            [OI]6300_d      1.961      0.38    -107    40
# Comp:  2           [NII]6583_d      2.159      0.38    -107    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        18
#  comp.  1:       -82        65
#  comp.  2:      -107        39
# chi2/DOF: 1.239; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.822      0.33     -82    65
# Comp:  1                Halpha      14.10      0.33     -82    65
# Comp:  2             [SII]6716      4.363      0.30    -107    39
# Comp:  2             [SII]6731      3.014      0.30    -107    39
# Comp:  2              HeII4687     0.3927      0.30    -107    39
# Comp:  2               HeI5876     0.4540      0.30    -107    39
# Comp:  2          [OIII]5007_d      3.635      0.38    -107    39
# Comp:  2            [OI]6300_d      2.108      0.38    -107    39
# Comp:  2           [NII]6583_d      1.957      0.38    -107    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89         1
#  comp.  1:       -82        63
#  comp.  2:      -108        49
# chi2/DOF: 1.236; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.865      0.33     -82    63
# Comp:  1                Halpha      13.75      0.33     -82    63
# Comp:  2             [SII]6716      4.380      0.31    -108    49
# Comp:  2             [SII]6731      3.671      0.31    -108    49
# Comp:  2              HeII4687     0.4824      0.31    -108    49
# Comp:  2               HeI5876     0.1460      0.31    -108    49
# Comp:  2          [OIII]5007_d      4.166      0.39    -108    49
# Comp:  2            [OI]6300_d      2.277      0.39    -108    49
# Comp:  2           [NII]6583_d      2.022      0.39    -108    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:       -83        64
#  comp.  2:      -100        48
# chi2/DOF: 1.243; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.221      0.33     -83    64
# Comp:  1                Halpha      13.69      0.33     -83    64
# Comp:  2             [SII]6716      4.354      0.31    -100    48
# Comp:  2             [SII]6731      3.414      0.31    -100    48
# Comp:  2              HeII4687     0.4034      0.31    -100    48
# Comp:  2               HeI5876     0.4028      0.31    -100    48
# Comp:  2          [OIII]5007_d      4.660      0.39    -100    48
# Comp:  2            [OI]6300_d      2.204      0.39    -100    48
# Comp:  2           [NII]6583_d      2.394      0.39    -100    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95        40
#  comp.  1:       -87        70
#  comp.  2:      -102        41
# chi2/DOF: 1.233; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.306      0.34     -87    70
# Comp:  1                Halpha      14.01      0.34     -87    70
# Comp:  2             [SII]6716      4.418      0.30    -102    41
# Comp:  2             [SII]6731      3.581      0.30    -102    41
# Comp:  2              HeII4687     0.3830      0.30    -102    41
# Comp:  2               HeI5876     0.3606      0.30    -102    41
# Comp:  2          [OIII]5007_d      3.486      0.38    -102    41
# Comp:  2            [OI]6300_d      2.341      0.38    -102    41
# Comp:  2           [NII]6583_d      2.124      0.38    -102    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77        18
#  comp.  1:       -82        64
#  comp.  2:      -103        40
# chi2/DOF: 1.242; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.726      0.33     -82    64
# Comp:  1                Halpha      13.61      0.33     -82    64
# Comp:  2             [SII]6716      4.244      0.30    -103    40
# Comp:  2             [SII]6731      3.465      0.30    -103    40
# Comp:  2              HeII4687     0.4216      0.30    -103    40
# Comp:  2               HeI5876     0.4283      0.30    -103    40
# Comp:  2          [OIII]5007_d      4.641      0.38    -103    40
# Comp:  2            [OI]6300_d      2.088      0.38    -103    40
# Comp:  2           [NII]6583_d      2.012      0.38    -103    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85         1
#  comp.  1:       -84        61
#  comp.  2:      -103        49
# chi2/DOF: 1.244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.072      0.33     -84    61
# Comp:  1                Halpha      12.83      0.33     -84    61
# Comp:  2             [SII]6716      4.270      0.31    -103    49
# Comp:  2             [SII]6731      2.995      0.31    -103    49
# Comp:  2              HeII4687     0.3019      0.31    -103    49
# Comp:  2               HeI5876    0.06513      0.31    -103    49
# Comp:  2          [OIII]5007_d      4.663      0.39    -103    49
# Comp:  2            [OI]6300_d      2.136      0.39    -103    49
# Comp:  2           [NII]6583_d      2.049      0.39    -103    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92        76
#  comp.  1:       -84        69
#  comp.  2:       -98        47
# chi2/DOF: 1.238; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.205      0.34     -84    69
# Comp:  1                Halpha      13.31      0.34     -84    69
# Comp:  2             [SII]6716      4.337      0.31     -98    47
# Comp:  2             [SII]6731      3.627      0.31     -98    47
# Comp:  2              HeII4687     0.5296      0.31     -98    47
# Comp:  2               HeI5876     0.6061      0.31     -98    47
# Comp:  2          [OIII]5007_d      4.532      0.39     -98    47
# Comp:  2            [OI]6300_d      2.147      0.39     -98    47
# Comp:  2           [NII]6583_d      1.918      0.39     -98    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -84        72
#  comp.  2:      -100        40
# chi2/DOF: 1.244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.711      0.34     -84    72
# Comp:  1                Halpha      13.68      0.34     -84    72
# Comp:  2             [SII]6716      4.094      0.30    -100    40
# Comp:  2             [SII]6731      3.365      0.30    -100    40
# Comp:  2              HeII4687     0.4591      0.30    -100    40
# Comp:  2               HeI5876     0.6292      0.30    -100    40
# Comp:  2          [OIII]5007_d      3.718      0.38    -100    40
# Comp:  2            [OI]6300_d      2.123      0.38    -100    40
# Comp:  2           [NII]6583_d      2.276      0.38    -100    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        26
#  comp.  1:       -82        64
#  comp.  2:      -103        41
# chi2/DOF: 1.243; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.312      0.33     -82    64
# Comp:  1                Halpha      13.49      0.33     -82    64
# Comp:  2             [SII]6716      4.183      0.30    -103    41
# Comp:  2             [SII]6731      2.952      0.30    -103    41
# Comp:  2              HeII4687     0.5758      0.30    -103    41
# Comp:  2               HeI5876     0.4314      0.30    -103    41
# Comp:  2          [OIII]5007_d      3.718      0.38    -103    41
# Comp:  2            [OI]6300_d      2.259      0.38    -103    41
# Comp:  2           [NII]6583_d      1.896      0.38    -103    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98         1
#  comp.  1:       -83        66
#  comp.  2:      -103        49
# chi2/DOF: 1.239; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.900      0.33     -83    66
# Comp:  1                Halpha      13.79      0.33     -83    66
# Comp:  2             [SII]6716      4.353      0.31    -103    49
# Comp:  2             [SII]6731      3.012      0.31    -103    49
# Comp:  2              HeII4687     0.5101      0.31    -103    49
# Comp:  2               HeI5876     0.3108      0.31    -103    49
# Comp:  2          [OIII]5007_d      4.037      0.40    -103    49
# Comp:  2            [OI]6300_d      2.415      0.40    -103    49
# Comp:  2           [NII]6583_d      2.329      0.40    -103    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78         1
#  comp.  1:       -81        62
#  comp.  2:      -103        44
# chi2/DOF: 1.243; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.408      0.33     -81    62
# Comp:  1                Halpha      12.99      0.33     -81    62
# Comp:  2             [SII]6716      4.330      0.31    -103    44
# Comp:  2             [SII]6731      3.641      0.31    -103    44
# Comp:  2              HeII4687     0.4278      0.31    -103    44
# Comp:  2               HeI5876    0.06184      0.31    -103    44
# Comp:  2          [OIII]5007_d      3.312      0.39    -103    44
# Comp:  2            [OI]6300_d      2.108      0.39    -103    44
# Comp:  2           [NII]6583_d      1.934      0.39    -103    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92         1
#  comp.  1:       -85        62
#  comp.  2:      -105        34
# chi2/DOF: 1.239; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.886      0.33     -85    62
# Comp:  1                Halpha      12.90      0.33     -85    62
# Comp:  2             [SII]6716      4.068      0.30    -105    34
# Comp:  2             [SII]6731      2.804      0.30    -105    34
# Comp:  2              HeII4687     0.3965      0.30    -105    34
# Comp:  2               HeI5876     0.5767      0.30    -105    34
# Comp:  2          [OIII]5007_d      3.741      0.38    -105    34
# Comp:  2            [OI]6300_d      1.897      0.38    -105    34
# Comp:  2           [NII]6583_d      1.690      0.38    -105    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        43
#  comp.  1:       -84        72
#  comp.  2:       -97        36
# chi2/DOF: 1.242; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.011      0.34     -84    72
# Comp:  1                Halpha      13.69      0.34     -84    72
# Comp:  2             [SII]6716      4.229      0.30     -97    36
# Comp:  2             [SII]6731      3.196      0.30     -97    36
# Comp:  2              HeII4687     0.4044      0.30     -97    36
# Comp:  2               HeI5876    0.08070      0.30     -97    36
# Comp:  2          [OIII]5007_d      4.109      0.38     -97    36
# Comp:  2            [OI]6300_d      2.039      0.38     -97    36
# Comp:  2           [NII]6583_d      2.076      0.38     -97    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96        26
#  comp.  1:       -85        68
#  comp.  2:      -103        35
# chi2/DOF: 1.243; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.315      0.34     -85    68
# Comp:  1                Halpha      13.44      0.34     -85    68
# Comp:  2             [SII]6716      4.171      0.30    -103    35
# Comp:  2             [SII]6731      2.809      0.30    -103    35
# Comp:  2              HeII4687     0.3768      0.30    -103    35
# Comp:  2               HeI5876     0.1048      0.30    -103    35
# Comp:  2          [OIII]5007_d      3.825      0.38    -103    35
# Comp:  2            [OI]6300_d      2.162      0.38    -103    35
# Comp:  2           [NII]6583_d      2.323      0.38    -103    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83         1
#  comp.  1:       -83        68
#  comp.  2:      -101        33
# chi2/DOF: 1.244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.608      0.34     -83    68
# Comp:  1                Halpha      13.42      0.34     -83    68
# Comp:  2             [SII]6716      4.132      0.30    -101    33
# Comp:  2             [SII]6731      3.579      0.30    -101    33
# Comp:  2              HeII4687     0.4808      0.30    -101    33
# Comp:  2               HeI5876    0.09651      0.30    -101    33
# Comp:  2          [OIII]5007_d      3.933      0.37    -101    33
# Comp:  2            [OI]6300_d      2.025      0.37    -101    33
# Comp:  2           [NII]6583_d      1.906      0.37    -101    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77        20
#  comp.  1:       -82        64
#  comp.  2:      -103        41
# chi2/DOF: 1.241; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.629      0.33     -82    64
# Comp:  1                Halpha      13.92      0.33     -82    64
# Comp:  2             [SII]6716      4.123      0.30    -103    41
# Comp:  2             [SII]6731      3.699      0.30    -103    41
# Comp:  2              HeII4687     0.5281      0.30    -103    41
# Comp:  2               HeI5876     0.2881      0.30    -103    41
# Comp:  2          [OIII]5007_d      4.609      0.38    -103    41
# Comp:  2            [OI]6300_d      2.128      0.38    -103    41
# Comp:  2           [NII]6583_d      2.352      0.38    -103    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -91         1
#  comp.  1:       -85        66
#  comp.  2:       -96        41
# chi2/DOF: 1.239; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.279      0.33     -85    66
# Comp:  1                Halpha      13.11      0.33     -85    66
# Comp:  2             [SII]6716      4.312      0.30     -96    41
# Comp:  2             [SII]6731      3.397      0.30     -96    41
# Comp:  2              HeII4687     0.4350      0.30     -96    41
# Comp:  2               HeI5876     0.4095      0.30     -96    41
# Comp:  2          [OIII]5007_d      4.130      0.38     -96    41
# Comp:  2            [OI]6300_d      2.386      0.38     -96    41
# Comp:  2           [NII]6583_d      1.878      0.38     -96    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:       -81        67
#  comp.  2:      -102        44
# chi2/DOF: 1.242; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.045      0.33     -81    67
# Comp:  1                Halpha      13.55      0.33     -81    67
# Comp:  2             [SII]6716      4.378      0.31    -102    44
# Comp:  2             [SII]6731      3.041      0.31    -102    44
# Comp:  2              HeII4687     0.4574      0.31    -102    44
# Comp:  2               HeI5876    0.05373      0.31    -102    44
# Comp:  2          [OIII]5007_d      4.484      0.39    -102    44
# Comp:  2            [OI]6300_d      2.120      0.39    -102    44
# Comp:  2           [NII]6583_d      2.114      0.39    -102    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:       -84        63
#  comp.  2:       -99        40
# chi2/DOF: 1.243; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.071      0.33     -84    63
# Comp:  1                Halpha      13.29      0.33     -84    63
# Comp:  2             [SII]6716      4.150      0.30     -99    40
# Comp:  2             [SII]6731      3.169      0.30     -99    40
# Comp:  2              HeII4687     0.3607      0.30     -99    40
# Comp:  2               HeI5876     0.2923      0.30     -99    40
# Comp:  2          [OIII]5007_d      3.614      0.38     -99    40
# Comp:  2            [OI]6300_d      2.044      0.38     -99    40
# Comp:  2           [NII]6583_d      2.005      0.38     -99    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        40
#  comp.  1:       -82        64
#  comp.  2:      -104        40
# chi2/DOF: 1.244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.208      0.33     -82    64
# Comp:  1                Halpha      13.19      0.33     -82    64
# Comp:  2             [SII]6716      4.295      0.30    -104    40
# Comp:  2             [SII]6731      2.859      0.30    -104    40
# Comp:  2              HeII4687     0.4976      0.30    -104    40
# Comp:  2               HeI5876     0.1928      0.30    -104    40
# Comp:  2          [OIII]5007_d      4.073      0.38    -104    40
# Comp:  2            [OI]6300_d      2.176      0.38    -104    40
# Comp:  2           [NII]6583_d      1.576      0.38    -104    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -85        64
#  comp.  2:      -103        33
# chi2/DOF: 1.242; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.843      0.33     -85    64
# Comp:  1                Halpha      13.57      0.33     -85    64
# Comp:  2             [SII]6716      3.938      0.30    -103    33
# Comp:  2             [SII]6731      3.448      0.30    -103    33
# Comp:  2              HeII4687     0.5108      0.30    -103    33
# Comp:  2               HeI5876     0.1571      0.30    -103    33
# Comp:  2          [OIII]5007_d      4.346      0.37    -103    33
# Comp:  2            [OI]6300_d      2.076      0.37    -103    33
# Comp:  2           [NII]6583_d      1.860      0.37    -103    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -91         1
#  comp.  1:       -83        66
#  comp.  2:      -105        41
# chi2/DOF: 1.240; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.244      0.33     -83    66
# Comp:  1                Halpha      13.09      0.33     -83    66
# Comp:  2             [SII]6716      4.138      0.30    -105    41
# Comp:  2             [SII]6731      2.893      0.30    -105    41
# Comp:  2              HeII4687     0.4976      0.30    -105    41
# Comp:  2               HeI5876     0.6228      0.30    -105    41
# Comp:  2          [OIII]5007_d      4.205      0.38    -105    41
# Comp:  2            [OI]6300_d      1.973      0.38    -105    41
# Comp:  2           [NII]6583_d      1.932      0.38    -105    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:       -80        59
#  comp.  2:      -103        37
# chi2/DOF: 1.243; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.113      0.32     -80    59
# Comp:  1                Halpha      12.78      0.32     -80    59
# Comp:  2             [SII]6716      4.061      0.30    -103    37
# Comp:  2             [SII]6731      3.566      0.30    -103    37
# Comp:  2              HeII4687     0.2930      0.30    -103    37
# Comp:  2               HeI5876     0.2180      0.30    -103    37
# Comp:  2          [OIII]5007_d      3.560      0.38    -103    37
# Comp:  2            [OI]6300_d      2.005      0.38    -103    37
# Comp:  2           [NII]6583_d      2.279      0.38    -103    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -83        62
#  comp.  2:      -106        43
# chi2/DOF: 1.245; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.926      0.33     -83    62
# Comp:  1                Halpha      13.31      0.33     -83    62
# Comp:  2             [SII]6716      4.205      0.31    -106    43
# Comp:  2             [SII]6731      3.349      0.31    -106    43
# Comp:  2              HeII4687     0.2623      0.31    -106    43
# Comp:  2               HeI5876     0.3316      0.31    -106    43
# Comp:  2          [OIII]5007_d      4.007      0.39    -106    43
# Comp:  2            [OI]6300_d      2.190      0.39    -106    43
# Comp:  2           [NII]6583_d      2.218      0.39    -106    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        25
#  comp.  1:       -78        66
#  comp.  2:      -111        37
# chi2/DOF: 1.242; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.988      0.33     -78    66
# Comp:  1                Halpha      13.29      0.33     -78    66
# Comp:  2             [SII]6716      4.158      0.30    -111    37
# Comp:  2             [SII]6731      3.370      0.30    -111    37
# Comp:  2              HeII4687     0.3109      0.30    -111    37
# Comp:  2               HeI5876    0.05587      0.30    -111    37
# Comp:  2          [OIII]5007_d      3.527      0.38    -111    37
# Comp:  2            [OI]6300_d      2.140      0.38    -111    37
# Comp:  2           [NII]6583_d      1.911      0.38    -111    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79         1
#  comp.  1:       -82        63
#  comp.  2:      -103        36
# chi2/DOF: 1.242; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.405      0.33     -82    63
# Comp:  1                Halpha      12.86      0.33     -82    63
# Comp:  2             [SII]6716      4.183      0.30    -103    36
# Comp:  2             [SII]6731      2.965      0.30    -103    36
# Comp:  2              HeII4687     0.4185      0.30    -103    36
# Comp:  2               HeI5876     0.4498      0.30    -103    36
# Comp:  2          [OIII]5007_d      4.157      0.38    -103    36
# Comp:  2            [OI]6300_d      1.991      0.38    -103    36
# Comp:  2           [NII]6583_d      2.276      0.38    -103    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -85        61
#  comp.  2:      -106        50
# chi2/DOF: 1.242; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.898      0.33     -85    61
# Comp:  1                Halpha      13.20      0.33     -85    61
# Comp:  2             [SII]6716      4.543      0.31    -106    50
# Comp:  2             [SII]6731      3.893      0.31    -106    50
# Comp:  2              HeII4687     0.5172      0.31    -106    50
# Comp:  2               HeI5876     0.5435      0.31    -106    50
# Comp:  2          [OIII]5007_d      4.587      0.40    -106    50
# Comp:  2            [OI]6300_d      2.219      0.40    -106    50
# Comp:  2           [NII]6583_d      2.267      0.40    -106    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -103        21
#  comp.  1:       -85        63
#  comp.  2:      -105        50
# chi2/DOF: 1.231; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.133      0.33     -85    63
# Comp:  1                Halpha      13.21      0.33     -85    63
# Comp:  2             [SII]6716      4.499      0.31    -105    50
# Comp:  2             [SII]6731      3.881      0.31    -105    50
# Comp:  2              HeII4687     0.3120      0.31    -105    50
# Comp:  2               HeI5876     0.3621      0.31    -105    50
# Comp:  2          [OIII]5007_d      4.405      0.40    -105    50
# Comp:  2            [OI]6300_d      2.064      0.40    -105    50
# Comp:  2           [NII]6583_d      2.010      0.40    -105    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       -83        64
#  comp.  2:      -108        45
# chi2/DOF: 1.244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.662      0.33     -83    64
# Comp:  1                Halpha      13.66      0.33     -83    64
# Comp:  2             [SII]6716      4.503      0.31    -108    45
# Comp:  2             [SII]6731      3.290      0.31    -108    45
# Comp:  2              HeII4687     0.3038      0.31    -108    45
# Comp:  2               HeI5876     0.1253      0.31    -108    45
# Comp:  2          [OIII]5007_d      3.453      0.39    -108    45
# Comp:  2            [OI]6300_d      2.103      0.39    -108    45
# Comp:  2           [NII]6583_d      2.478      0.39    -108    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:       -84        66
#  comp.  2:      -103        40
# chi2/DOF: 1.242; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.949      0.33     -84    66
# Comp:  1                Halpha      13.74      0.33     -84    66
# Comp:  2             [SII]6716      4.291      0.30    -103    40
# Comp:  2             [SII]6731      3.656      0.30    -103    40
# Comp:  2              HeII4687     0.4545      0.30    -103    40
# Comp:  2               HeI5876    0.07913      0.30    -103    40
# Comp:  2          [OIII]5007_d      3.860      0.38    -103    40
# Comp:  2            [OI]6300_d      2.066      0.38    -103    40
# Comp:  2           [NII]6583_d      2.142      0.38    -103    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -107        29
#  comp.  1:       -81        67
#  comp.  2:      -102        57
# chi2/DOF: 1.240; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.061      0.33     -81    67
# Comp:  1                Halpha      13.63      0.33     -81    67
# Comp:  2             [SII]6716      4.486      0.32    -102    57
# Comp:  2             [SII]6731      3.616      0.32    -102    57
# Comp:  2              HeII4687     0.3780      0.32    -102    57
# Comp:  2               HeI5876     0.2367      0.32    -102    57
# Comp:  2          [OIII]5007_d      4.036      0.41    -102    57
# Comp:  2            [OI]6300_d      2.258      0.41    -102    57
# Comp:  2           [NII]6583_d      2.185      0.41    -102    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -115        89
#  comp.  1:       -86        68
#  comp.  2:      -101        44
# chi2/DOF: 1.235; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.647      0.34     -86    68
# Comp:  1                Halpha      13.81      0.34     -86    68
# Comp:  2             [SII]6716      4.153      0.31    -101    44
# Comp:  2             [SII]6731      3.429      0.31    -101    44
# Comp:  2              HeII4687     0.6377      0.31    -101    44
# Comp:  2               HeI5876     0.5381      0.31    -101    44
# Comp:  2          [OIII]5007_d      4.569      0.39    -101    44
# Comp:  2            [OI]6300_d      2.343      0.39    -101    44
# Comp:  2           [NII]6583_d      2.299      0.39    -101    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86         1
#  comp.  1:       -81        61
#  comp.  2:      -109        46
# chi2/DOF: 1.236; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.267      0.33     -81    61
# Comp:  1                Halpha      13.54      0.33     -81    61
# Comp:  2             [SII]6716      4.215      0.31    -109    46
# Comp:  2             [SII]6731      3.449      0.31    -109    46
# Comp:  2              HeII4687     0.3656      0.31    -109    46
# Comp:  2               HeI5876     0.5223      0.31    -109    46
# Comp:  2          [OIII]5007_d      4.132      0.39    -109    46
# Comp:  2            [OI]6300_d      2.284      0.39    -109    46
# Comp:  2           [NII]6583_d      2.082      0.39    -109    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:       -79        65
#  comp.  2:       -98        40
# chi2/DOF: 1.244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.962      0.33     -79    65
# Comp:  1                Halpha      13.20      0.33     -79    65
# Comp:  2             [SII]6716      4.245      0.30     -98    40
# Comp:  2             [SII]6731      2.875      0.30     -98    40
# Comp:  2              HeII4687     0.4314      0.30     -98    40
# Comp:  2               HeI5876     0.5567      0.30     -98    40
# Comp:  2          [OIII]5007_d      4.212      0.38     -98    40
# Comp:  2            [OI]6300_d      2.017      0.38     -98    40
# Comp:  2           [NII]6583_d      1.852      0.38     -98    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        11
#  comp.  1:       -79        65
#  comp.  2:      -106        45
# chi2/DOF: 1.243; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.866      0.33     -79    65
# Comp:  1                Halpha      13.64      0.33     -79    65
# Comp:  2             [SII]6716      4.384      0.31    -106    45
# Comp:  2             [SII]6731      3.712      0.31    -106    45
# Comp:  2              HeII4687     0.5144      0.31    -106    45
# Comp:  2               HeI5876     0.1036      0.31    -106    45
# Comp:  2          [OIII]5007_d      3.658      0.39    -106    45
# Comp:  2            [OI]6300_d      2.134      0.39    -106    45
# Comp:  2           [NII]6583_d      1.830      0.39    -106    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         1
#  comp.  1:       -81        60
#  comp.  2:       -99        33
# chi2/DOF: 1.244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.467      0.33     -81    60
# Comp:  1                Halpha      12.32      0.33     -81    60
# Comp:  2             [SII]6716      3.957      0.30     -99    33
# Comp:  2             [SII]6731      3.530      0.30     -99    33
# Comp:  2              HeII4687     0.4503      0.30     -99    33
# Comp:  2               HeI5876     0.2980      0.30     -99    33
# Comp:  2          [OIII]5007_d      4.054      0.37     -99    33
# Comp:  2            [OI]6300_d      2.010      0.37     -99    33
# Comp:  2           [NII]6583_d      1.553      0.37     -99    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        36
#  comp.  1:       -81        63
#  comp.  2:      -101        36
# chi2/DOF: 1.245; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.942      0.33     -81    63
# Comp:  1                Halpha      12.72      0.33     -81    63
# Comp:  2             [SII]6716      4.123      0.30    -101    36
# Comp:  2             [SII]6731      3.250      0.30    -101    36
# Comp:  2              HeII4687     0.4887      0.30    -101    36
# Comp:  2               HeI5876     0.3625      0.30    -101    36
# Comp:  2          [OIII]5007_d      3.439      0.38    -101    36
# Comp:  2            [OI]6300_d      2.208      0.38    -101    36
# Comp:  2           [NII]6583_d      2.077      0.38    -101    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        25
#  comp.  1:       -82        64
#  comp.  2:      -103        40
# chi2/DOF: 1.243; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.426      0.33     -82    64
# Comp:  1                Halpha      12.74      0.33     -82    64
# Comp:  2             [SII]6716      4.059      0.30    -103    40
# Comp:  2             [SII]6731      3.251      0.30    -103    40
# Comp:  2              HeII4687     0.3876      0.30    -103    40
# Comp:  2               HeI5876     0.3458      0.30    -103    40
# Comp:  2          [OIII]5007_d      4.292      0.38    -103    40
# Comp:  2            [OI]6300_d      2.201      0.38    -103    40
# Comp:  2           [NII]6583_d      1.925      0.38    -103    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:       -82        61
#  comp.  2:      -108        50
# chi2/DOF: 1.242; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.860      0.33     -82    61
# Comp:  1                Halpha      13.25      0.33     -82    61
# Comp:  2             [SII]6716      4.247      0.31    -108    50
# Comp:  2             [SII]6731      3.809      0.31    -108    50
# Comp:  2              HeII4687     0.5518      0.31    -108    50
# Comp:  2               HeI5876     0.3367      0.31    -108    50
# Comp:  2          [OIII]5007_d      4.254      0.40    -108    50
# Comp:  2            [OI]6300_d      2.117      0.40    -108    50
# Comp:  2           [NII]6583_d      1.845      0.40    -108    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        28
#  comp.  1:       -82        64
#  comp.  2:      -104        41
# chi2/DOF: 1.242; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.489      0.33     -82    64
# Comp:  1                Halpha      13.56      0.33     -82    64
# Comp:  2             [SII]6716      4.333      0.30    -104    41
# Comp:  2             [SII]6731      3.786      0.30    -104    41
# Comp:  2              HeII4687     0.3940      0.30    -104    41
# Comp:  2               HeI5876    0.07956      0.30    -104    41
# Comp:  2          [OIII]5007_d      3.968      0.38    -104    41
# Comp:  2            [OI]6300_d      1.998      0.38    -104    41
# Comp:  2           [NII]6583_d      2.169      0.38    -104    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        54
#  comp.  1:       -82        67
#  comp.  2:       -98        20
# chi2/DOF: 1.238; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.324      0.33     -82    67
# Comp:  1                Halpha      13.06      0.33     -82    67
# Comp:  2             [SII]6716      3.860      0.29     -98    20
# Comp:  2             [SII]6731      2.722      0.29     -98    20
# Comp:  2              HeII4687     0.4010      0.29     -98    20
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.096      0.32     -84    59
# Comp:  1                Halpha      12.98      0.32     -84    59
# Comp:  2             [SII]6716      4.116      0.30     -96    40
# Comp:  2             [SII]6731      3.370      0.30     -96    40
# Comp:  2              HeII4687     0.3020      0.30     -96    40
# Comp:  2               HeI5876    0.07932      0.30     -96    40
# Comp:  2          [OIII]5007_d      3.891      0.38     -96    40
# Comp:  2            [OI]6300_d      2.260      0.38     -96    40
# Comp:  2           [NII]6583_d      2.108      0.38     -96    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:       -81        67
#  comp.  2:      -111        47
# chi2/DOF: 1.238; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.397      0.33     -81    67
# Comp:  1                Halpha      13.66      0.33     -81    67
# Comp:  2             [SII]6716      4.380      0.31    -111    47
# Comp:  2             [SII]6731      2.945      0.31    -111    47
# Comp:  2              HeII4687     0.4353      0.31    -111    47
# Comp:  2               HeI5876     0.1072      0.31    -111    47
# Comp:  2          [OIII]5007_d      3.842      0.39    -111    47
# Comp:  2            [OI]6300_d      2.290      0.39    -111    47
# Comp:  2           [NII]6583_d      2.109      0.39    -111    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72        44
#  comp.  1:       -77        65
#  comp.  2:       -99        37
# chi2/DOF: 1.241; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.542      0.33     -77    65
# Comp:  1                Halpha      13.65      0.33     -77    65
# Comp:  2             [SII]6716      4.038      0.30     -99    37
# Comp:  2             [SII]6731      2.849      0.30     -99    37
# Comp:  2              HeII4687     0.4291      0.30     -99    37
# Comp:  2               HeI5876     0.3521      0.30     -99    37
# Comp:  2          [OIII]5007_d      4.323      0.38     -99    37
# Comp:  2            [OI]6300_d      1.996      0.38     -99    37
# Comp:  2           [NII]6583_d      1.670      0.38     -99    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        25
#  comp.  1:       -82        64
#  comp.  2:      -103        40
# chi2/DOF: 1.244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.475      0.33     -82    64
# Comp:  1                Halpha      13.58      0.33     -82    64
# Comp:  2             [SII]6716      4.242      0.30    -103    40
# Comp:  2             [SII]6731      2.955      0.30    -103    40
# Comp:  2              HeII4687     0.2740      0.30    -103    40
# Comp:  2               HeI5876     0.5188      0.30    -103    40
# Comp:  2          [OIII]5007_d      3.649      0.38    -103    40
# Comp:  2            [OI]6300_d      2.008      0.38    -103    40
# Comp:  2           [NII]6583_d      1.964      0.38    -103    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96         1
#  comp.  1:       -86        67
#  comp.  2:      -106        38
# chi2/DOF: 1.239; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.390      0.33     -86    67
# Comp:  1                Halpha      13.39      0.33     -86    67
# Comp:  2             [SII]6716      4.283      0.30    -106    38
# Comp:  2             [SII]6731      3.180      0.30    -106    38
# Comp:  2              HeII4687     0.3928      0.30    -106    38
# Comp:  2               HeI5876     0.4275      0.30    -106    38
# Comp:  2          [OIII]5007_d      4.184      0.38    -106    38
# Comp:  2            [OI]6300_d      2.099      0.38    -106    38
# Comp:  2           [NII]6583_d      2.211      0.38    -106    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        41
#  comp.  1:       -85        67
#  comp.  2:      -103        45
# chi2/DOF: 1.240; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 57; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.594      0.33     -85    67
# Comp:  1                Halpha      13.64      0.33     -85    67
# Comp:  2             [SII]6716      4.307      0.31    -103    45
# Comp:  2             [SII]6731      3.055      0.31    -103    45
# Comp:  2              HeII4687     0.4477      0.31    -103    45
# Comp:  2               HeI5876     0.6395      0.31    -103    45
# Comp:  2          [OIII]5007_d      3.938      0.39    -103    45
# Comp:  2            [OI]6300_d      2.395      0.39    -103    45
# Comp:  2           [NII]6583_d      2.100      0.39    -103    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        51
#  comp.  1:       -83        62
#  comp.  2:      -112        46
# chi2/DOF: 1.243; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.652      0.33     -83    62
# Comp:  1                Halpha      13.09      0.33     -83    62
# Comp:  2             [SII]6716      4.322      0.31    -112    46
# Comp:  2             [SII]6731      3.481      0.31    -112    46
# Comp:  2              HeII4687     0.5329      0.31    -112    46
# Comp:  2               HeI5876     0.3102      0.31    -112    46
# Comp:  2          [OIII]5007_d      3.962      0.39    -112    46
# Comp:  2            [OI]6300_d      2.186      0.39    -112    46
# Comp:  2           [NII]6583_d      2.012      0.39    -112    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
#  comp.  1:       -80        66
#  comp.  2:       -98        25
# chi2/DOF: 1.242; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.570      0.33     -80    66
# Comp:  1                Halpha      13.66      0.33     -80    66
# Comp:  2             [SII]6716      4.027      0.29     -98    25
# Comp:  2             [SII]6731      2.866      0.29     -98    25
# Comp:  2              HeII4687     0.3361      0.29     -98    25
# Comp:  2               HeI5876     0.3284      0.29     -98    25
# Comp:  2          [OIII]5007_d      3.729      0.37     -98    25
# Comp:  2            [OI]6300_d      2.137      0.37     -98    25
# Comp:  2           [NII]6583_d      1.926      0.37     -98    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63         1
#  comp.  1:       -85        67
#  comp.  2:      -108        51
# chi2/DOF: 1.239; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.007      0.33     -85    67
# Comp:  1                Halpha      13.26      0.33     -85    67
# Comp:  2             [SII]6716      4.478      0.31    -108    51
# Comp:  2             [SII]6731      3.095      0.31    -108    51
# Comp:  2              HeII4687     0.4895      0.31    -108    51
# Comp:  2               HeI5876     0.3779      0.31    -108    51
# Comp:  2          [OIII]5007_d      4.428      0.40    -108    51
# Comp:  2            [OI]6300_d      2.115      0.40    -108    51
# Comp:  2           [NII]6583_d      2.474      0.40    -108    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83         1
#  comp.  1:       -87        65
#  comp.  2:       -99        31
# chi2/DOF: 1.244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.896      0.33     -87    65
# Comp:  1                Halpha      13.65      0.33     -87    65
# Comp:  2             [SII]6716      3.962      0.29     -99    31
# Comp:  2             [SII]6731      2.925      0.29     -99    31
# Comp:  2              HeII4687     0.4477      0.29     -99    31
# Comp:  2               HeI5876     0.3064      0.29     -99    31
# Comp:  2          [OIII]5007_d      3.805      0.37     -99    31
# Comp:  2            [OI]6300_d      1.992      0.37     -99    31
# Comp:  2           [NII]6583_d      2.031      0.37     -99    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -110        68
#  comp.  1:       -86        60
#  comp.  2:      -102        39
# chi2/DOF: 1.241; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.313      0.32     -86    60
# Comp:  1                Halpha      12.86      0.32     -86    60
# Comp:  2             [SII]6716      4.114      0.30    -102    39
# Comp:  2             [SII]6731      3.555      0.30    -102    39
# Comp:  2              HeII4687     0.4217      0.30    -102    39
# Comp:  2               HeI5876     0.5739      0.30    -102    39
# Comp:  2          [OIII]5007_d      3.148      0.38    -102    39
# Comp:  2            [OI]6300_d      2.001      0.38    -102    39
# Comp:  2           [NII]6583_d      2.026      0.38    -102    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -101        20
#  comp.  1:       -81        67
#  comp.  2:      -104        47
# chi2/DOF: 1.245; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.222      0.33     -81    67
# Comp:  1                Halpha      13.81      0.33     -81    67
# Comp:  2             [SII]6716      4.369      0.31    -104    47
# Comp:  2             [SII]6731      3.823      0.31    -104    47
# Comp:  2              HeII4687     0.4628      0.31    -104    47
# Comp:  2               HeI5876     0.3346      0.31    -104    47
# Comp:  2          [OIII]5007_d      4.313      0.39    -104    47
# Comp:  2            [OI]6300_d      2.226      0.39    -104    47
# Comp:  2           [NII]6583_d      1.981      0.39    -104    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77        22
#  comp.  1:       -82        64
#  comp.  2:      -103        41
# chi2/DOF: 1.244; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.583      0.33     -82    64
# Comp:  1                Halpha      13.24      0.33     -82    64
# Comp:  2             [SII]6716      4.142      0.30    -103    41
# Comp:  2             [SII]6731      3.318      0.30    -103    41
# Comp:  2              HeII4687     0.3783      0.30    -103    41
# Comp:  2               HeI5876     0.6123      0.30    -103    41
# Comp:  2          [OIII]5007_d      3.803      0.38    -103    41
# Comp:  2            [OI]6300_d      2.183      0.38    -103    41
# Comp:  2           [NII]6583_d      2.512      0.38    -103    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         1
#  comp.  1:       -83        65
#  comp.  2:      -105        39
# chi2/DOF: 1.241; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.935      0.33     -83    65
# Comp:  1                Halpha      13.94      0.33     -83    65
# Comp:  2             [SII]6716      4.106      0.30    -105    39
# Comp:  2             [SII]6731      2.867      0.30    -105    39
# Comp:  2              HeII4687     0.4154      0.30    -105    39
# Comp:  2               HeI5876     0.4681      0.30    -105    39
# Comp:  2          [OIII]5007_d      3.450      0.38    -105    39
# Comp:  2            [OI]6300_d      2.146      0.38    -105    39
# Comp:  2           [NII]6583_d      2.186      0.38    -105    39
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.40872657, 0.46716921, 0.20846447, 0.36905362, 0.07761257,
#        0.21290264, 0.41918863, 0.16329181, 0.28609629])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 4.23899825, 18.12829249,  5.94424828,  4.62022808,  0.40100987,
#         0.3883888 ,  4.05775454,  2.78351   ,  2.80888362])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_14_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_14", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_14_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_14_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_14_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.176201    0.016989
# 1        Halpha  0.753534    0.019419
# 2     [SII]6716  0.247083    0.008665
# 3     [SII]6731  0.192048    0.015340
# 4      HeII4687  0.016669    0.003226
# 5       HeI5876  0.016144    0.008850
# 6  [OIII]5007_d  0.168668    0.017424
# 7    [OI]6300_d  0.115701    0.006788
# 8   [NII]6583_d  0.116756    0.011892
#           Name      Flux  Error_flux
# 0        Hbeta  0.176201    0.016989
# 1       Halpha  0.753534    0.019419
# 2    [SII]6716  0.247083    0.008665
# 3    [SII]6731  0.192048    0.015340
# 4     HeII4687  0.016669    0.003226
# 5      HeI5876  0.016144    0.008850
# 6   [OIII]4959  0.042167    0.017424
# 7   [OIII]5007  0.126501    0.017424
# 8     [OI]6300  0.086776    0.006788
# 9     [OI]6364  0.028925    0.006788
# 10   [NII]6548  0.029189    0.011892
# 11   [NII]6583  0.087567    0.011892

# %%
np.median(flux_rf_rebin)
# Out:
# 0.04156673385488202
