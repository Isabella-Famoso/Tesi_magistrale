# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_20.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_20']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [ 0.01661494 -0.00677664  0.01288237 ...  0.00342289  0.0063424
#   0.01011076] [0.00500945 0.00500945 0.00500945 ... 0.00500945 0.00500945 0.00500945]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
# chi2/DOF: 0.3126; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
# chi2/DOF: 0.1975; DOF: 1915; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-57.69515535,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -328         1
#  comp.  1:       -77        23
#  comp.  2:       -82        50
# chi2/DOF: 1.232; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.03       1.0     -77    23
# Comp:  1                Halpha      21.84       1.0     -77    23
# Comp:  2             [SII]6716      7.474       1.1     -82    50
# Comp:  2             [SII]6731      5.845       1.1     -82    50
# Comp:  2              HeII4687      0.000       1.1     -82    50
# Comp:  2               HeI5876     0.5425       1.1     -82    50
# Comp:  2          [OIII]5007_d      2.497       1.4     -82    50
# Comp:  2            [OI]6300_d      1.067       1.4     -82    50
# Comp:  2           [NII]6583_d      5.116       1.4     -82    50
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  7.731; gas flux:     10 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:     17; gas flux:     30 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  4.894; gas flux:     10 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  3.848; gas flux:      8 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.3417; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  1.164; gas flux:      3 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.5243; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  2.536; gas flux:      7 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -328        54
#  comp.  1:       -77        24
#  comp.  2:       -82        49
# chi2/DOF: 1.226; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.95       1.0     -77    24
# Comp:  1                Halpha      22.01       1.0     -77    24
# Comp:  2             [SII]6716      7.458       1.1     -82    49
# Comp:  2             [SII]6731      5.437       1.1     -82    49
# Comp:  2              HeII4687      1.002       1.1     -82    49
# Comp:  2               HeI5876      1.949       1.1     -82    49
# Comp:  2          [OIII]5007_d      4.162       1.4     -82    49
# Comp:  2            [OI]6300_d     0.7277       1.4     -82    49
# Comp:  2           [NII]6583_d      4.406       1.4     -82    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -353        92
#  comp.  1:       -82        32
#  comp.  2:       -82        59
# chi2/DOF: 1.223; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.77       1.0     -82    32
# Comp:  1                Halpha      23.59       1.0     -82    32
# Comp:  2             [SII]6716      8.455       1.1     -82    59
# Comp:  2             [SII]6731      5.281       1.1     -82    59
# Comp:  2              HeII4687     0.8934       1.1     -82    59
# Comp:  2               HeI5876      1.998       1.1     -82    59
# Comp:  2          [OIII]5007_d     0.6894       1.4     -82    59
# Comp:  2            [OI]6300_d      1.490       1.4     -82    59
# Comp:  2           [NII]6583_d      5.280       1.4     -82    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -493       364
#  comp.  1:       -74        14
#  comp.  2:       -84        47
# chi2/DOF: 1.222; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 60; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.698       1.0     -74    14
# Comp:  1                Halpha      22.16       1.0     -74    14
# Comp:  2             [SII]6716      8.894       1.1     -84    47
# Comp:  2             [SII]6731      6.430       1.1     -84    47
# Comp:  2              HeII4687     0.4627       1.1     -84    47
# Comp:  2               HeI5876      0.000       1.1     -84    47
# Comp:  2          [OIII]5007_d      2.768       1.4     -84    47
# Comp:  2            [OI]6300_d      1.790       1.4     -84    47
# Comp:  2           [NII]6583_d      5.547       1.4     -84    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -279         1
#  comp.  1:       -80        35
#  comp.  2:       -80        55
# chi2/DOF: 1.224; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.17       1.1     -80    35
# Comp:  1                Halpha      23.74       1.1     -80    35
# Comp:  2             [SII]6716      6.224       1.1     -80    55
# Comp:  2             [SII]6731      5.986       1.1     -80    55
# Comp:  2              HeII4687     0.1102       1.1     -80    55
# Comp:  2               HeI5876     0.7764       1.1     -80    55
# Comp:  2          [OIII]5007_d      3.968       1.4     -80    55
# Comp:  2            [OI]6300_d      1.232       1.4     -80    55
# Comp:  2           [NII]6583_d      6.939       1.4     -80    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -323         1
#  comp.  1:       -85        38
#  comp.  2:       -93        52
# chi2/DOF: 1.222; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.29       1.1     -85    38
# Comp:  1                Halpha      23.43       1.1     -85    38
# Comp:  2             [SII]6716      7.311       1.1     -93    52
# Comp:  2             [SII]6731      6.595       1.1     -93    52
# Comp:  2              HeII4687      0.000       1.1     -93    52
# Comp:  2               HeI5876     0.4581       1.1     -93    52
# Comp:  2          [OIII]5007_d      2.579       1.4     -93    52
# Comp:  2            [OI]6300_d      1.384       1.4     -93    52
# Comp:  2           [NII]6583_d      4.828       1.4     -93    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -367         1
#  comp.  1:       -78        39
#  comp.  2:       -82        67
# chi2/DOF: 1.225; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.45       1.1     -78    39
# Comp:  1                Halpha      24.21       1.1     -78    39
# Comp:  2             [SII]6716      6.347       1.2     -82    67
# Comp:  2             [SII]6731      6.363       1.2     -82    67
# Comp:  2              HeII4687     0.2189       1.2     -82    67
# Comp:  2               HeI5876     0.6153       1.2     -82    67
# Comp:  2          [OIII]5007_d      3.251       1.5     -82    67
# Comp:  2            [OI]6300_d      1.499       1.5     -82    67
# Comp:  2           [NII]6583_d      5.911       1.5     -82    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -354         1
#  comp.  1:       -77        15
#  comp.  2:       -88        41
# chi2/DOF: 1.222; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.849       1.0     -77    15
# Comp:  1                Halpha      21.61       1.0     -77    15
# Comp:  2             [SII]6716      7.641       1.1     -88    41
# Comp:  2             [SII]6731      5.044       1.1     -88    41
# Comp:  2              HeII4687      0.000       1.1     -88    41
# Comp:  2               HeI5876      0.000       1.1     -88    41
# Comp:  2          [OIII]5007_d      1.793       1.4     -88    41
# Comp:  2            [OI]6300_d      2.190       1.4     -88    41
# Comp:  2           [NII]6583_d      4.801       1.4     -88    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -406         1
#  comp.  1:       -80        32
#  comp.  2:       -89        45
# chi2/DOF: 1.222; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.20       1.0     -80    32
# Comp:  1                Halpha      21.94       1.0     -80    32
# Comp:  2             [SII]6716      8.679       1.1     -89    45
# Comp:  2             [SII]6731      5.836       1.1     -89    45
# Comp:  2              HeII4687     0.6801       1.1     -89    45
# Comp:  2               HeI5876     0.9576       1.1     -89    45
# Comp:  2          [OIII]5007_d      3.021       1.4     -89    45
# Comp:  2            [OI]6300_d      0.000       1.4     -89    45
# Comp:  2           [NII]6583_d      5.764       1.4     -89    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -357        48
#  comp.  1:       -83        36
#  comp.  2:       -75        58
# chi2/DOF: 1.226; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.76       1.1     -83    36
# Comp:  1                Halpha      23.31       1.1     -83    36
# Comp:  2             [SII]6716      9.669       1.1     -75    58
# Comp:  2             [SII]6731      6.558       1.1     -75    58
# Comp:  2              HeII4687      0.000       1.1     -75    58
# Comp:  2               HeI5876     0.8903       1.1     -75    58
# Comp:  2          [OIII]5007_d      2.281       1.4     -75    58
# Comp:  2            [OI]6300_d     0.4120       1.4     -75    58
# Comp:  2           [NII]6583_d      5.554       1.4     -75    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       426       701
#  comp.  1:       -76        10
#  comp.  2:       -91        58
# chi2/DOF: 1.224; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.954       1.0     -76    10
# Comp:  1                Halpha      22.01       1.0     -76    10
# Comp:  2             [SII]6716      9.440       1.1     -91    58
# Comp:  2             [SII]6731      5.958       1.1     -91    58
# Comp:  2              HeII4687     0.2461       1.1     -91    58
# Comp:  2               HeI5876      1.500       1.1     -91    58
# Comp:  2          [OIII]5007_d      2.540       1.4     -91    58
# Comp:  2            [OI]6300_d      2.986       1.4     -91    58
# Comp:  2           [NII]6583_d      4.561       1.4     -91    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -329       111
#  comp.  1:       -77        24
#  comp.  2:       -83        50
# chi2/DOF: 1.224; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.55       1.0     -77    24
# Comp:  1                Halpha      21.82       1.0     -77    24
# Comp:  2             [SII]6716      5.862       1.1     -83    50
# Comp:  2             [SII]6731      5.735       1.1     -83    50
# Comp:  2              HeII4687     0.4558       1.1     -83    50
# Comp:  2               HeI5876      1.282       1.1     -83    50
# Comp:  2          [OIII]5007_d      2.265       1.4     -83    50
# Comp:  2            [OI]6300_d     0.5806       1.4     -83    50
# Comp:  2           [NII]6583_d      5.727       1.4     -83    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -217        51
#  comp.  1:       -74         1
#  comp.  2:       -76        52
# chi2/DOF: 1.221; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.30      0.99     -74     1
# Comp:  1                Halpha      20.34      0.99     -74     1
# Comp:  2             [SII]6716      6.377       1.1     -76    52
# Comp:  2             [SII]6731      6.410       1.1     -76    52
# Comp:  2              HeII4687     0.1556       1.1     -76    52
# Comp:  2               HeI5876      0.000       1.1     -76    52
# Comp:  2          [OIII]5007_d      2.076       1.4     -76    52
# Comp:  2            [OI]6300_d     0.2096       1.4     -76    52
# Comp:  2           [NII]6583_d      3.888       1.4     -76    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -254       215
#  comp.  1:       -78        16
#  comp.  2:       -91        61
# chi2/DOF: 1.223; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.24       1.0     -78    16
# Comp:  1                Halpha      22.02       1.0     -78    16
# Comp:  2             [SII]6716      8.813       1.2     -91    61
# Comp:  2             [SII]6731      5.319       1.2     -91    61
# Comp:  2              HeII4687      0.000       1.2     -91    61
# Comp:  2               HeI5876      1.493       1.2     -91    61
# Comp:  2          [OIII]5007_d      2.238       1.5     -91    61
# Comp:  2            [OI]6300_d      1.836       1.5     -91    61
# Comp:  2           [NII]6583_d      5.417       1.5     -91    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4       996
#  comp.  1:       -83        39
#  comp.  2:       -82        59
# chi2/DOF: 1.217; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.31       1.1     -83    39
# Comp:  1                Halpha      23.49       1.1     -83    39
# Comp:  2             [SII]6716      5.897       1.1     -82    59
# Comp:  2             [SII]6731      6.677       1.1     -82    59
# Comp:  2              HeII4687      0.000       1.1     -82    59
# Comp:  2               HeI5876     0.7305       1.1     -82    59
# Comp:  2          [OIII]5007_d      2.292       1.5     -82    59
# Comp:  2            [OI]6300_d     0.3951       1.5     -82    59
# Comp:  2           [NII]6583_d      5.170       1.5     -82    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -875       509
#  comp.  1:       -82        31
#  comp.  2:       -84        62
# chi2/DOF: 1.225; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.43       1.0     -82    31
# Comp:  1                Halpha      22.71       1.0     -82    31
# Comp:  2             [SII]6716      7.876       1.2     -84    62
# Comp:  2             [SII]6731      5.774       1.2     -84    62
# Comp:  2              HeII4687      0.000       1.2     -84    62
# Comp:  2               HeI5876     0.6052       1.2     -84    62
# Comp:  2          [OIII]5007_d      1.948       1.5     -84    62
# Comp:  2            [OI]6300_d      1.425       1.5     -84    62
# Comp:  2           [NII]6583_d      5.729       1.5     -84    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -385         1
#  comp.  1:       -79        21
#  comp.  2:       -79        44
# chi2/DOF: 1.223; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.40       1.0     -79    21
# Comp:  1                Halpha      21.75       1.0     -79    21
# Comp:  2             [SII]6716      8.854       1.1     -79    44
# Comp:  2             [SII]6731      6.207       1.1     -79    44
# Comp:  2              HeII4687      0.000       1.1     -79    44
# Comp:  2               HeI5876     0.8317       1.1     -79    44
# Comp:  2          [OIII]5007_d      4.709       1.4     -79    44
# Comp:  2            [OI]6300_d      0.000       1.4     -79    44
# Comp:  2           [NII]6583_d      4.529       1.4     -79    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -772       299
#  comp.  1:       -80        30
#  comp.  2:       -84        76
# chi2/DOF: 1.215; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.850       1.0     -80    30
# Comp:  1                Halpha      23.33       1.0     -80    30
# Comp:  2             [SII]6716      8.930       1.2     -84    76
# Comp:  2             [SII]6731      7.403       1.2     -84    76
# Comp:  2              HeII4687    0.09545       1.2     -84    76
# Comp:  2               HeI5876      2.977       1.2     -84    76
# Comp:  2          [OIII]5007_d      5.020       1.5     -84    76
# Comp:  2            [OI]6300_d      2.986       1.5     -84    76
# Comp:  2           [NII]6583_d      5.698       1.5     -84    76
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -370         1
#  comp.  1:       -78        13
#  comp.  2:       -70        39
# chi2/DOF: 1.222; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.253       1.0     -78    13
# Comp:  1                Halpha      20.71       1.0     -78    13
# Comp:  2             [SII]6716      6.178       1.1     -70    39
# Comp:  2             [SII]6731      5.610       1.1     -70    39
# Comp:  2              HeII4687      0.000       1.1     -70    39
# Comp:  2               HeI5876      1.234       1.1     -70    39
# Comp:  2          [OIII]5007_d      4.802       1.4     -70    39
# Comp:  2            [OI]6300_d      1.892       1.4     -70    39
# Comp:  2           [NII]6583_d      5.682       1.4     -70    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -514      1000
#  comp.  1:       -77        12
#  comp.  2:       -74        41
# chi2/DOF: 1.227; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.872       1.0     -77    12
# Comp:  1                Halpha      21.93       1.0     -77    12
# Comp:  2             [SII]6716      7.107       1.1     -74    41
# Comp:  2             [SII]6731      5.272       1.1     -74    41
# Comp:  2              HeII4687     0.8983       1.1     -74    41
# Comp:  2               HeI5876    0.07129       1.1     -74    41
# Comp:  2          [OIII]5007_d      3.180       1.4     -74    41
# Comp:  2            [OI]6300_d      1.278       1.4     -74    41
# Comp:  2           [NII]6583_d      4.420       1.4     -74    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -316         1
#  comp.  1:       -82        34
#  comp.  2:       -87        17
# chi2/DOF: 1.225; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.58       1.1     -82    34
# Comp:  1                Halpha      22.98       1.1     -82    34
# Comp:  2             [SII]6716      7.777       1.0     -87    17
# Comp:  2             [SII]6731      5.249       1.0     -87    17
# Comp:  2              HeII4687     0.2854       1.0     -87    17
# Comp:  2               HeI5876     0.7138       1.0     -87    17
# Comp:  2          [OIII]5007_d      1.712       1.3     -87    17
# Comp:  2            [OI]6300_d      1.975       1.3     -87    17
# Comp:  2           [NII]6583_d      5.049       1.3     -87    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -277         1
#  comp.  1:       -74        19
#  comp.  2:       -75        60
# chi2/DOF: 1.221; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.24       1.0     -74    19
# Comp:  1                Halpha      22.29       1.0     -74    19
# Comp:  2             [SII]6716      6.792       1.2     -75    60
# Comp:  2             [SII]6731      5.659       1.2     -75    60
# Comp:  2              HeII4687      1.016       1.2     -75    60
# Comp:  2               HeI5876      1.338       1.2     -75    60
# Comp:  2          [OIII]5007_d      1.886       1.5     -75    60
# Comp:  2            [OI]6300_d      1.285       1.5     -75    60
# Comp:  2           [NII]6583_d      4.504       1.5     -75    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -305        51
#  comp.  1:       -86        27
#  comp.  2:       -71        52
# chi2/DOF: 1.223; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.49       1.0     -86    27
# Comp:  1                Halpha      22.67       1.0     -86    27
# Comp:  2             [SII]6716      8.005       1.1     -71    52
# Comp:  2             [SII]6731      6.538       1.1     -71    52
# Comp:  2              HeII4687      1.455       1.1     -71    52
# Comp:  2               HeI5876      0.000       1.1     -71    52
# Comp:  2          [OIII]5007_d      4.486       1.4     -71    52
# Comp:  2            [OI]6300_d      2.037       1.4     -71    52
# Comp:  2           [NII]6583_d      5.644       1.4     -71    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -315         1
#  comp.  1:       -78        19
#  comp.  2:       -93        80
# chi2/DOF: 1.219; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.47       1.0     -78    19
# Comp:  1                Halpha      21.82       1.0     -78    19
# Comp:  2             [SII]6716      9.745       1.2     -93    80
# Comp:  2             [SII]6731      6.605       1.2     -93    80
# Comp:  2              HeII4687      0.000       1.2     -93    80
# Comp:  2               HeI5876      1.210       1.2     -93    80
# Comp:  2          [OIII]5007_d      3.254       1.6     -93    80
# Comp:  2            [OI]6300_d     0.6902       1.6     -93    80
# Comp:  2           [NII]6583_d      4.761       1.6     -93    80
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -342         1
#  comp.  1:       -70        14
#  comp.  2:       -84        36
# chi2/DOF: 1.224; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.13       1.0     -70    14
# Comp:  1                Halpha      21.25       1.0     -70    14
# Comp:  2             [SII]6716      8.784       1.1     -84    36
# Comp:  2             [SII]6731      5.949       1.1     -84    36
# Comp:  2              HeII4687      0.000       1.1     -84    36
# Comp:  2               HeI5876      0.000       1.1     -84    36
# Comp:  2          [OIII]5007_d     0.1969       1.3     -84    36
# Comp:  2            [OI]6300_d     0.4311       1.3     -84    36
# Comp:  2           [NII]6583_d      5.438       1.3     -84    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -295      1000
#  comp.  1:       -81        24
#  comp.  2:       -86        58
# chi2/DOF: 1.222; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.754       1.0     -81    24
# Comp:  1                Halpha      22.32       1.0     -81    24
# Comp:  2             [SII]6716      6.134       1.1     -86    58
# Comp:  2             [SII]6731      6.214       1.1     -86    58
# Comp:  2              HeII4687      0.000       1.1     -86    58
# Comp:  2               HeI5876      0.000       1.1     -86    58
# Comp:  2          [OIII]5007_d      1.731       1.4     -86    58
# Comp:  2            [OI]6300_d      1.537       1.4     -86    58
# Comp:  2           [NII]6583_d      5.504       1.4     -86    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -290      1000
#  comp.  1:       -71         1
#  comp.  2:       -73        46
# chi2/DOF: 1.225; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.119      0.99     -71     1
# Comp:  1                Halpha      20.88      0.99     -71     1
# Comp:  2             [SII]6716      7.645       1.1     -73    46
# Comp:  2             [SII]6731      5.962       1.1     -73    46
# Comp:  2              HeII4687      0.000       1.1     -73    46
# Comp:  2               HeI5876      0.000       1.1     -73    46
# Comp:  2          [OIII]5007_d      1.213       1.4     -73    46
# Comp:  2            [OI]6300_d      2.287       1.4     -73    46
# Comp:  2           [NII]6583_d      4.838       1.4     -73    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -329         1
#  comp.  1:       -75        11
#  comp.  2:       -78        56
# chi2/DOF: 1.225; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.26       1.0     -75    11
# Comp:  1                Halpha      20.24       1.0     -75    11
# Comp:  2             [SII]6716      8.200       1.1     -78    56
# Comp:  2             [SII]6731      5.726       1.1     -78    56
# Comp:  2              HeII4687     0.5148       1.1     -78    56
# Comp:  2               HeI5876     0.4039       1.1     -78    56
# Comp:  2          [OIII]5007_d      3.994       1.4     -78    56
# Comp:  2            [OI]6300_d      1.407       1.4     -78    56
# Comp:  2           [NII]6583_d      4.669       1.4     -78    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -329        20
#  comp.  1:       -77        23
#  comp.  2:       -82        50
# chi2/DOF: 1.225; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.928       1.0     -77    23
# Comp:  1                Halpha      22.44       1.0     -77    23
# Comp:  2             [SII]6716      9.503       1.1     -82    50
# Comp:  2             [SII]6731      6.594       1.1     -82    50
# Comp:  2              HeII4687      0.000       1.1     -82    50
# Comp:  2               HeI5876      2.140       1.1     -82    50
# Comp:  2          [OIII]5007_d      3.511       1.4     -82    50
# Comp:  2            [OI]6300_d     0.8042       1.4     -82    50
# Comp:  2           [NII]6583_d      6.452       1.4     -82    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -370         1
#  comp.  1:       -80        31
#  comp.  2:       -81        54
# chi2/DOF: 1.223; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.77       1.0     -80    31
# Comp:  1                Halpha      23.51       1.0     -80    31
# Comp:  2             [SII]6716      6.899       1.1     -81    54
# Comp:  2             [SII]6731      6.496       1.1     -81    54
# Comp:  2              HeII4687      0.000       1.1     -81    54
# Comp:  2               HeI5876      1.718       1.1     -81    54
# Comp:  2          [OIII]5007_d      3.316       1.4     -81    54
# Comp:  2            [OI]6300_d     0.5069       1.4     -81    54
# Comp:  2           [NII]6583_d      4.812       1.4     -81    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -293         1
#  comp.  1:       -82        33
#  comp.  2:       -98        70
# chi2/DOF: 1.225; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.88       1.1     -82    33
# Comp:  1                Halpha      23.71       1.1     -82    33
# Comp:  2             [SII]6716      8.236       1.2     -98    70
# Comp:  2             [SII]6731      5.868       1.2     -98    70
# Comp:  2              HeII4687     0.3009       1.2     -98    70
# Comp:  2               HeI5876      0.000       1.2     -98    70
# Comp:  2          [OIII]5007_d      1.551       1.5     -98    70
# Comp:  2            [OI]6300_d      0.000       1.5     -98    70
# Comp:  2           [NII]6583_d      5.709       1.5     -98    70
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -362         1
#  comp.  1:       -81        28
#  comp.  2:       -72        54
# chi2/DOF: 1.225; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.03       1.0     -81    28
# Comp:  1                Halpha      21.46       1.0     -81    28
# Comp:  2             [SII]6716      5.941       1.1     -72    54
# Comp:  2             [SII]6731      6.493       1.1     -72    54
# Comp:  2              HeII4687      0.000       1.1     -72    54
# Comp:  2               HeI5876      0.000       1.1     -72    54
# Comp:  2          [OIII]5007_d      1.229       1.4     -72    54
# Comp:  2            [OI]6300_d     0.7835       1.4     -72    54
# Comp:  2           [NII]6583_d      5.070       1.4     -72    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1256         1
#  comp.  1:       -73        31
#  comp.  2:       -81        42
# chi2/DOF: 1.218; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.717       1.0     -73    31
# Comp:  1                Halpha      22.15       1.0     -73    31
# Comp:  2             [SII]6716      6.676       1.1     -81    42
# Comp:  2             [SII]6731      5.568       1.1     -81    42
# Comp:  2              HeII4687    0.08157       1.1     -81    42
# Comp:  2               HeI5876      0.000       1.1     -81    42
# Comp:  2          [OIII]5007_d      2.098       1.4     -81    42
# Comp:  2            [OI]6300_d      1.219       1.4     -81    42
# Comp:  2           [NII]6583_d      4.029       1.4     -81    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -309         1
#  comp.  1:       -80        37
#  comp.  2:       -76        46
# chi2/DOF: 1.226; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.89       1.1     -80    37
# Comp:  1                Halpha      23.52       1.1     -80    37
# Comp:  2             [SII]6716      6.324       1.1     -76    46
# Comp:  2             [SII]6731      5.873       1.1     -76    46
# Comp:  2              HeII4687     0.6022       1.1     -76    46
# Comp:  2               HeI5876    0.09948       1.1     -76    46
# Comp:  2          [OIII]5007_d      3.379       1.4     -76    46
# Comp:  2            [OI]6300_d      2.189       1.4     -76    46
# Comp:  2           [NII]6583_d      6.285       1.4     -76    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -356         1
#  comp.  1:       -74        26
#  comp.  2:       -83        63
# chi2/DOF: 1.214; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.30       1.0     -74    26
# Comp:  1                Halpha      23.12       1.0     -74    26
# Comp:  2             [SII]6716      7.053       1.2     -83    63
# Comp:  2             [SII]6731      6.172       1.2     -83    63
# Comp:  2              HeII4687      1.263       1.2     -83    63
# Comp:  2               HeI5876      1.981       1.2     -83    63
# Comp:  2          [OIII]5007_d     0.7592       1.5     -83    63
# Comp:  2            [OI]6300_d      2.888       1.5     -83    63
# Comp:  2           [NII]6583_d      7.090       1.5     -83    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -440       273
#  comp.  1:       -71         1
#  comp.  2:       -92        38
# chi2/DOF: 1.225; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.225      0.99     -71     1
# Comp:  1                Halpha      21.05      0.99     -71     1
# Comp:  2             [SII]6716      7.097       1.1     -92    38
# Comp:  2             [SII]6731      4.948       1.1     -92    38
# Comp:  2              HeII4687      0.000       1.1     -92    38
# Comp:  2               HeI5876      1.648       1.1     -92    38
# Comp:  2          [OIII]5007_d      2.862       1.3     -92    38
# Comp:  2            [OI]6300_d      1.904       1.3     -92    38
# Comp:  2           [NII]6583_d      5.107       1.3     -92    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        52       331
#  comp.  1:       -71        13
#  comp.  2:       -73        43
# chi2/DOF: 1.220; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.87       1.0     -71    13
# Comp:  1                Halpha      21.72       1.0     -71    13
# Comp:  2             [SII]6716      6.180       1.1     -73    43
# Comp:  2             [SII]6731      5.817       1.1     -73    43
# Comp:  2              HeII4687     0.3065       1.1     -73    43
# Comp:  2               HeI5876     0.3858       1.1     -73    43
# Comp:  2          [OIII]5007_d     0.5548       1.4     -73    43
# Comp:  2            [OI]6300_d      0.000       1.4     -73    43
# Comp:  2           [NII]6583_d      5.200       1.4     -73    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -379         1
#  comp.  1:       -74         1
#  comp.  2:       -71        44
# chi2/DOF: 1.225; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 31; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.583      0.99     -74     1
# Comp:  1                Halpha      20.23      0.99     -74     1
# Comp:  2             [SII]6716      7.758       1.1     -71    44
# Comp:  2             [SII]6731      5.847       1.1     -71    44
# Comp:  2              HeII4687      0.000       1.1     -71    44
# Comp:  2               HeI5876      0.000       1.1     -71    44
# Comp:  2          [OIII]5007_d      4.213       1.4     -71    44
# Comp:  2            [OI]6300_d      2.055       1.4     -71    44
# Comp:  2           [NII]6583_d      4.875       1.4     -71    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -320         1
#  comp.  1:       -72        12
#  comp.  2:       -98        38
# chi2/DOF: 1.219; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.14       1.0     -72    12
# Comp:  1                Halpha      20.68       1.0     -72    12
# Comp:  2             [SII]6716      8.500       1.1     -98    38
# Comp:  2             [SII]6731      5.548       1.1     -98    38
# Comp:  2              HeII4687      0.000       1.1     -98    38
# Comp:  2               HeI5876      1.935       1.1     -98    38
# Comp:  2          [OIII]5007_d      1.320       1.3     -98    38
# Comp:  2            [OI]6300_d     0.7425       1.3     -98    38
# Comp:  2           [NII]6583_d      4.004       1.3     -98    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -307         1
#  comp.  1:       -74         7
#  comp.  2:       -75        29
# chi2/DOF: 1.225; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.25       1.0     -74     7
# Comp:  1                Halpha      20.02       1.0     -74     7
# Comp:  2             [SII]6716      7.056       1.0     -75    29
# Comp:  2             [SII]6731      5.460       1.0     -75    29
# Comp:  2              HeII4687      0.000       1.0     -75    29
# Comp:  2               HeI5876      1.254       1.0     -75    29
# Comp:  2          [OIII]5007_d      2.876       1.3     -75    29
# Comp:  2            [OI]6300_d     0.2720       1.3     -75    29
# Comp:  2           [NII]6583_d      5.175       1.3     -75    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -815      1000
#  comp.  1:       -76        17
#  comp.  2:       -89        55
# chi2/DOF: 1.225; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.239       1.0     -76    17
# Comp:  1                Halpha      22.24       1.0     -76    17
# Comp:  2             [SII]6716      7.044       1.1     -89    55
# Comp:  2             [SII]6731      6.414       1.1     -89    55
# Comp:  2              HeII4687      0.000       1.1     -89    55
# Comp:  2               HeI5876     0.6133       1.1     -89    55
# Comp:  2          [OIII]5007_d      1.209       1.4     -89    55
# Comp:  2            [OI]6300_d     0.8556       1.4     -89    55
# Comp:  2           [NII]6583_d      5.082       1.4     -89    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -323       157
#  comp.  1:       -74        28
#  comp.  2:       -81        53
# chi2/DOF: 1.220; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.90       1.0     -74    28
# Comp:  1                Halpha      23.47       1.0     -74    28
# Comp:  2             [SII]6716      9.464       1.1     -81    53
# Comp:  2             [SII]6731      6.602       1.1     -81    53
# Comp:  2              HeII4687      0.000       1.1     -81    53
# Comp:  2               HeI5876      0.000       1.1     -81    53
# Comp:  2          [OIII]5007_d      1.346       1.4     -81    53
# Comp:  2            [OI]6300_d     0.8683       1.4     -81    53
# Comp:  2           [NII]6583_d      5.052       1.4     -81    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1205       146
#  comp.  1:       -76        27
#  comp.  2:       -70        44
# chi2/DOF: 1.216; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.854       1.0     -76    27
# Comp:  1                Halpha      21.18       1.0     -76    27
# Comp:  2             [SII]6716      6.638       1.1     -70    44
# Comp:  2             [SII]6731      5.258       1.1     -70    44
# Comp:  2              HeII4687      1.184       1.1     -70    44
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.265      0.99     -79     2
# Comp:  1                Halpha      21.46      0.99     -79     2
# Comp:  2             [SII]6716      6.433       1.0     -79    33
# Comp:  2             [SII]6731      5.747       1.0     -79    33
# Comp:  2              HeII4687     0.1023       1.0     -79    33
# Comp:  2               HeI5876      0.000       1.0     -79    33
# Comp:  2          [OIII]5007_d      4.071       1.3     -79    33
# Comp:  2            [OI]6300_d     0.7021       1.3     -79    33
# Comp:  2           [NII]6583_d      3.522       1.3     -79    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -276         1
#  comp.  1:       -79        33
#  comp.  2:       -78        47
# chi2/DOF: 1.222; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.36       1.1     -79    33
# Comp:  1                Halpha      23.58       1.1     -79    33
# Comp:  2             [SII]6716      6.360       1.1     -78    47
# Comp:  2             [SII]6731      5.306       1.1     -78    47
# Comp:  2              HeII4687      0.000       1.1     -78    47
# Comp:  2               HeI5876     0.9570       1.1     -78    47
# Comp:  2          [OIII]5007_d     0.8111       1.4     -78    47
# Comp:  2            [OI]6300_d      1.567       1.4     -78    47
# Comp:  2           [NII]6583_d      5.825       1.4     -78    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -299         1
#  comp.  1:       -71         1
#  comp.  2:       -72        56
# chi2/DOF: 1.221; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.374      0.99     -71     1
# Comp:  1                Halpha      20.93      0.99     -71     1
# Comp:  2             [SII]6716      7.015       1.1     -72    56
# Comp:  2             [SII]6731      5.854       1.1     -72    56
# Comp:  2              HeII4687      0.000       1.1     -72    56
# Comp:  2               HeI5876      0.000       1.1     -72    56
# Comp:  2          [OIII]5007_d      4.551       1.4     -72    56
# Comp:  2            [OI]6300_d     0.9768       1.4     -72    56
# Comp:  2           [NII]6583_d      4.631       1.4     -72    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -300         1
#  comp.  1:       -76        25
#  comp.  2:       -84        63
# chi2/DOF: 1.221; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.41       1.0     -76    25
# Comp:  1                Halpha      22.76       1.0     -76    25
# Comp:  2             [SII]6716      8.258       1.2     -84    63
# Comp:  2             [SII]6731      6.444       1.2     -84    63
# Comp:  2              HeII4687      0.000       1.2     -84    63
# Comp:  2               HeI5876      1.713       1.2     -84    63
# Comp:  2          [OIII]5007_d      1.113       1.5     -84    63
# Comp:  2            [OI]6300_d      1.371       1.5     -84    63
# Comp:  2           [NII]6583_d      5.829       1.5     -84    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -327       108
#  comp.  1:       -77        23
#  comp.  2:       -83        49
# chi2/DOF: 1.223; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.56       1.0     -77    23
# Comp:  1                Halpha      22.44       1.0     -77    23
# Comp:  2             [SII]6716      7.863       1.1     -83    49
# Comp:  2             [SII]6731      5.828       1.1     -83    49
# Comp:  2              HeII4687      0.000       1.1     -83    49
# Comp:  2               HeI5876      1.882       1.1     -83    49
# Comp:  2          [OIII]5007_d      2.921       1.4     -83    49
# Comp:  2            [OI]6300_d      0.000       1.4     -83    49
# Comp:  2           [NII]6583_d      4.541       1.4     -83    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -361         1
#  comp.  1:       -85        37
#  comp.  2:       -65        55
# chi2/DOF: 1.220; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.962       1.1     -85    37
# Comp:  1                Halpha      23.23       1.1     -85    37
# Comp:  2             [SII]6716      7.945       1.1     -65    55
# Comp:  2             [SII]6731      5.711       1.1     -65    55
# Comp:  2              HeII4687      0.000       1.1     -65    55
# Comp:  2               HeI5876      1.195       1.1     -65    55
# Comp:  2          [OIII]5007_d      2.674       1.4     -65    55
# Comp:  2            [OI]6300_d     0.3870       1.4     -65    55
# Comp:  2           [NII]6583_d      6.281       1.4     -65    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -395         1
#  comp.  1:       -78         9
#  comp.  2:       -72        54
# chi2/DOF: 1.223; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.426       1.0     -78     9
# Comp:  1                Halpha      21.30       1.0     -78     9
# Comp:  2             [SII]6716      6.670       1.1     -72    54
# Comp:  2             [SII]6731      5.911       1.1     -72    54
# Comp:  2              HeII4687      0.000       1.1     -72    54
# Comp:  2               HeI5876    0.08519       1.1     -72    54
# Comp:  2          [OIII]5007_d     0.8828       1.4     -72    54
# Comp:  2            [OI]6300_d      3.058       1.4     -72    54
# Comp:  2           [NII]6583_d      6.027       1.4     -72    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -315         1
#  comp.  1:       -75        43
#  comp.  2:       -90        59
# chi2/DOF: 1.221; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.70       1.1     -75    43
# Comp:  1                Halpha      23.53       1.1     -75    43
# Comp:  2             [SII]6716      9.159       1.1     -90    59
# Comp:  2             [SII]6731      5.615       1.1     -90    59
# Comp:  2              HeII4687     0.4627       1.1     -90    59
# Comp:  2               HeI5876      2.117       1.1     -90    59
# Comp:  2          [OIII]5007_d      2.756       1.5     -90    59
# Comp:  2            [OI]6300_d     0.5551       1.5     -90    59
# Comp:  2           [NII]6583_d      4.409       1.5     -90    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92       190
#  comp.  1:       -84        25
#  comp.  2:       -86        58
# chi2/DOF: 1.222; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.997       1.0     -84    25
# Comp:  1                Halpha      22.60       1.0     -84    25
# Comp:  2             [SII]6716      6.670       1.1     -86    58
# Comp:  2             [SII]6731      5.795       1.1     -86    58
# Comp:  2              HeII4687      0.000       1.1     -86    58
# Comp:  2               HeI5876      2.167       1.1     -86    58
# Comp:  2          [OIII]5007_d      3.365       1.4     -86    58
# Comp:  2            [OI]6300_d     0.2647       1.4     -86    58
# Comp:  2           [NII]6583_d      6.738       1.4     -86    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        95       339
#  comp.  1:       -82        26
#  comp.  2:       -85        75
# chi2/DOF: 1.222; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 84; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.710       1.0     -82    26
# Comp:  1                Halpha      22.79       1.0     -82    26
# Comp:  2             [SII]6716      7.707       1.2     -85    75
# Comp:  2             [SII]6731      6.324       1.2     -85    75
# Comp:  2              HeII4687      0.000       1.2     -85    75
# Comp:  2               HeI5876     0.3456       1.2     -85    75
# Comp:  2          [OIII]5007_d      3.954       1.5     -85    75
# Comp:  2            [OI]6300_d      1.679       1.5     -85    75
# Comp:  2           [NII]6583_d      4.593       1.5     -85    75
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -262         1
#  comp.  1:       -80         7
#  comp.  2:       -84        56
# chi2/DOF: 1.223; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.755       1.0     -80     7
# Comp:  1                Halpha      21.52       1.0     -80     7
# Comp:  2             [SII]6716      8.308       1.1     -84    56
# Comp:  2             [SII]6731      6.538       1.1     -84    56
# Comp:  2              HeII4687      0.000       1.1     -84    56
# Comp:  2               HeI5876      2.212       1.1     -84    56
# Comp:  2          [OIII]5007_d      1.828       1.4     -84    56
# Comp:  2            [OI]6300_d      1.559       1.4     -84    56
# Comp:  2           [NII]6583_d      4.268       1.4     -84    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -253         1
#  comp.  1:       -77        30
#  comp.  2:       -79        60
# chi2/DOF: 1.225; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.14       1.0     -77    30
# Comp:  1                Halpha      22.45       1.0     -77    30
# Comp:  2             [SII]6716      8.353       1.2     -79    60
# Comp:  2             [SII]6731      6.591       1.2     -79    60
# Comp:  2              HeII4687      0.000       1.2     -79    60
# Comp:  2               HeI5876      2.162       1.2     -79    60
# Comp:  2          [OIII]5007_d      2.837       1.5     -79    60
# Comp:  2            [OI]6300_d      0.000       1.5     -79    60
# Comp:  2           [NII]6583_d      6.416       1.5     -79    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       264         9
#  comp.  1:       -71         1
#  comp.  2:       -70        63
# chi2/DOF: 1.212; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 76; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.664      0.99     -71     1
# Comp:  1                Halpha      21.01      0.99     -71     1
# Comp:  2             [SII]6716      7.270       1.2     -70    63
# Comp:  2             [SII]6731      6.065       1.2     -70    63
# Comp:  2              HeII4687      0.000       1.2     -70    63
# Comp:  2               HeI5876      2.131       1.2     -70    63
# Comp:  2          [OIII]5007_d     0.2124       1.5     -70    63
# Comp:  2            [OI]6300_d      0.000       1.5     -70    63
# Comp:  2           [NII]6583_d      6.152       1.5     -70    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -326         1
#  comp.  1:       -82        30
#  comp.  2:       -87        66
# chi2/DOF: 1.223; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.46       1.0     -82    30
# Comp:  1                Halpha      23.55       1.0     -82    30
# Comp:  2             [SII]6716      10.23       1.2     -87    66
# Comp:  2             [SII]6731      5.653       1.2     -87    66
# Comp:  2              HeII4687      0.000       1.2     -87    66
# Comp:  2               HeI5876     0.3113       1.2     -87    66
# Comp:  2          [OIII]5007_d      2.435       1.5     -87    66
# Comp:  2            [OI]6300_d      1.340       1.5     -87    66
# Comp:  2           [NII]6583_d      5.948       1.5     -87    66
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.62996521, 1.49697034, 1.42325388, 0.67660972, 0.41108456,
#        1.01963291, 1.25723452, 1.08043309, 1.10988313])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([10.16924324, 29.89902714, 10.47051551,  8.2056809 ,  0.        ,
#         0.66488601,  2.60795366,  1.40189895,  7.02506495])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_20_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_20", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_20_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_20_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_20_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.099329    0.006153
# 1        Halpha  0.292041    0.014622
# 2     [SII]6716  0.102272    0.013902
# 3     [SII]6731  0.080150    0.006609
# 4      HeII4687  0.000000    0.004015
# 5       HeI5876  0.006494    0.009959
# 6  [OIII]5007_d  0.025473    0.012280
# 7    [OI]6300_d  0.013693    0.010553
# 8   [NII]6583_d  0.068618    0.010841
#           Name      Flux  Error_flux
# 0        Hbeta  0.099329    0.006153
# 1       Halpha  0.292041    0.014622
# 2    [SII]6716  0.102272    0.013902
# 3    [SII]6731  0.080150    0.006609
# 4     HeII4687  0.000000    0.004015
# 5      HeI5876  0.006494    0.009959
# 6   [OIII]4959  0.006368    0.012280
# 7   [OIII]5007  0.019105    0.012280
# 8     [OI]6300  0.010270    0.010553
# 9     [OI]6364  0.003423    0.010553
# 10   [NII]6548  0.017154    0.010841
# 11   [NII]6583  0.051463    0.010841

# %%
np.median(flux_rf_rebin)
# Out:
# 0.009767571739583807
