# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_16.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_16']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.03603481 0.02111394 0.04130996 ... 0.01628781 0.01524768 0.01863909] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -115         1
# chi2/DOF: 0.06789; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
#  Best Fit:       Vel     sigma
#  comp.  0:      -102         1
# chi2/DOF: 0.03938; DOF: 1922; degree = 4; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-101.76958956,    0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -100         1
#  comp.  1:       -81        24
#  comp.  2:       -84        29
# chi2/DOF: 1.112; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.66      0.50     -81    24
# Comp:  1                Halpha      37.79      0.50     -81    24
# Comp:  2             [SII]6716      8.871      0.51     -84    29
# Comp:  2             [SII]6731      6.542      0.51     -84    29
# Comp:  2              HeII4687     0.3348      0.51     -84    29
# Comp:  2               HeI5876      0.000      0.51     -84    29
# Comp:  2          [OIII]5007_d      10.35      0.64     -84    29
# Comp:  2            [OI]6300_d     0.9240      0.64     -84    29
# Comp:  2           [NII]6583_d      7.416      0.64     -84    29
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  23.82; gas flux:     14 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  66.03; gas flux:     52 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  14.93; gas flux:     12 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  11.14; gas flux:      9 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.5417; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  12.33; gas flux:     11 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.174; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  9.492; gas flux:     10 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -76         1
#  comp.  1:       -80        30
#  comp.  2:       -80        22
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.84      0.51     -80    30
# Comp:  1                Halpha      38.35      0.51     -80    30
# Comp:  2             [SII]6716      8.785      0.50     -80    22
# Comp:  2             [SII]6731      6.531      0.50     -80    22
# Comp:  2              HeII4687     0.4613      0.50     -80    22
# Comp:  2               HeI5876      0.000      0.50     -80    22
# Comp:  2          [OIII]5007_d      9.082      0.63     -80    22
# Comp:  2            [OI]6300_d      1.303      0.63     -80    22
# Comp:  2           [NII]6583_d      7.514      0.63     -80    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -127        40
#  comp.  1:       -84        31
#  comp.  2:       -80        38
# chi2/DOF: 1.098; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.74      0.51     -84    31
# Comp:  1                Halpha      39.36      0.51     -84    31
# Comp:  2             [SII]6716      9.645      0.52     -80    38
# Comp:  2             [SII]6731      7.017      0.52     -80    38
# Comp:  2              HeII4687     0.3617      0.52     -80    38
# Comp:  2               HeI5876     0.1332      0.52     -80    38
# Comp:  2          [OIII]5007_d      10.54      0.66     -80    38
# Comp:  2            [OI]6300_d     0.2927      0.66     -80    38
# Comp:  2           [NII]6583_d      7.606      0.66     -80    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -141         1
#  comp.  1:       -80        19
#  comp.  2:       -87        29
# chi2/DOF: 1.100; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.60      0.49     -80    19
# Comp:  1                Halpha      37.91      0.49     -80    19
# Comp:  2             [SII]6716      9.854      0.51     -87    29
# Comp:  2             [SII]6731      6.263      0.51     -87    29
# Comp:  2              HeII4687     0.2483      0.51     -87    29
# Comp:  2               HeI5876      0.000      0.51     -87    29
# Comp:  2          [OIII]5007_d      10.37      0.64     -87    29
# Comp:  2            [OI]6300_d     0.5860      0.64     -87    29
# Comp:  2           [NII]6583_d      7.005      0.64     -87    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -144        60
#  comp.  1:       -83        32
#  comp.  2:       -84        47
# chi2/DOF: 1.096; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 38; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.15      0.51     -83    32
# Comp:  1                Halpha      39.43      0.51     -83    32
# Comp:  2             [SII]6716      8.339      0.54     -84    47
# Comp:  2             [SII]6731      6.814      0.54     -84    47
# Comp:  2              HeII4687     0.4484      0.54     -84    47
# Comp:  2               HeI5876     0.5562      0.54     -84    47
# Comp:  2          [OIII]5007_d      9.915      0.68     -84    47
# Comp:  2            [OI]6300_d      1.160      0.68     -84    47
# Comp:  2           [NII]6583_d      7.472      0.68     -84    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -124        66
#  comp.  1:       -84        31
#  comp.  2:       -89        22
# chi2/DOF: 1.089; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.61      0.51     -84    31
# Comp:  1                Halpha      38.99      0.51     -84    31
# Comp:  2             [SII]6716      8.705      0.50     -89    22
# Comp:  2             [SII]6731      6.172      0.50     -89    22
# Comp:  2              HeII4687     0.3700      0.50     -89    22
# Comp:  2               HeI5876     0.1177      0.50     -89    22
# Comp:  2          [OIII]5007_d      9.675      0.63     -89    22
# Comp:  2            [OI]6300_d      1.426      0.63     -89    22
# Comp:  2           [NII]6583_d      7.247      0.63     -89    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -106         1
#  comp.  1:       -82        33
#  comp.  2:       -84        32
# chi2/DOF: 1.098; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.21      0.51     -82    33
# Comp:  1                Halpha      40.10      0.51     -82    33
# Comp:  2             [SII]6716      7.757      0.51     -84    32
# Comp:  2             [SII]6731      7.106      0.51     -84    32
# Comp:  2              HeII4687     0.3252      0.51     -84    32
# Comp:  2               HeI5876      0.000      0.51     -84    32
# Comp:  2          [OIII]5007_d      9.488      0.64     -84    32
# Comp:  2            [OI]6300_d      1.299      0.64     -84    32
# Comp:  2           [NII]6583_d      7.406      0.64     -84    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -354      1000
#  comp.  1:       -80        20
#  comp.  2:       -84        33
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.50      0.49     -80    20
# Comp:  1                Halpha      37.25      0.49     -80    20
# Comp:  2             [SII]6716      9.276      0.51     -84    33
# Comp:  2             [SII]6731      6.185      0.51     -84    33
# Comp:  2              HeII4687     0.3757      0.51     -84    33
# Comp:  2               HeI5876     0.1986      0.51     -84    33
# Comp:  2          [OIII]5007_d      10.56      0.65     -84    33
# Comp:  2            [OI]6300_d     0.6632      0.65     -84    33
# Comp:  2           [NII]6583_d      7.891      0.65     -84    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         6
#  comp.  1:       -82        30
#  comp.  2:       -86        34
# chi2/DOF: 1.097; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.10      0.51     -82    30
# Comp:  1                Halpha      38.25      0.51     -82    30
# Comp:  2             [SII]6716      9.659      0.51     -86    34
# Comp:  2             [SII]6731      6.409      0.51     -86    34
# Comp:  2              HeII4687     0.2258      0.51     -86    34
# Comp:  2               HeI5876    0.05539      0.51     -86    34
# Comp:  2          [OIII]5007_d      9.453      0.65     -86    34
# Comp:  2            [OI]6300_d      1.263      0.65     -86    34
# Comp:  2           [NII]6583_d      7.297      0.65     -86    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -140         1
#  comp.  1:       -84        29
#  comp.  2:       -85        22
# chi2/DOF: 1.096; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.99      0.51     -84    29
# Comp:  1                Halpha      39.10      0.51     -84    29
# Comp:  2             [SII]6716      9.762      0.50     -85    22
# Comp:  2             [SII]6731      6.541      0.50     -85    22
# Comp:  2              HeII4687     0.4293      0.50     -85    22
# Comp:  2               HeI5876     0.2956      0.50     -85    22
# Comp:  2          [OIII]5007_d      10.12      0.63     -85    22
# Comp:  2            [OI]6300_d     0.8714      0.63     -85    22
# Comp:  2           [NII]6583_d      6.998      0.63     -85    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97        64
#  comp.  1:       -80        23
#  comp.  2:       -84        29
# chi2/DOF: 1.098; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.51      0.50     -80    23
# Comp:  1                Halpha      38.51      0.50     -80    23
# Comp:  2             [SII]6716      9.958      0.51     -84    29
# Comp:  2             [SII]6731      6.084      0.51     -84    29
# Comp:  2              HeII4687     0.4001      0.51     -84    29
# Comp:  2               HeI5876     0.1114      0.51     -84    29
# Comp:  2          [OIII]5007_d      11.39      0.64     -84    29
# Comp:  2            [OI]6300_d     0.7824      0.64     -84    29
# Comp:  2           [NII]6583_d      7.654      0.64     -84    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -107         1
#  comp.  1:       -81        32
#  comp.  2:       -87        34
# chi2/DOF: 1.097; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.30      0.51     -81    32
# Comp:  1                Halpha      38.48      0.51     -81    32
# Comp:  2             [SII]6716      7.968      0.51     -87    34
# Comp:  2             [SII]6731      6.287      0.51     -87    34
# Comp:  2              HeII4687     0.4712      0.51     -87    34
# Comp:  2               HeI5876     0.2609      0.51     -87    34
# Comp:  2          [OIII]5007_d      10.70      0.65     -87    34
# Comp:  2            [OI]6300_d      1.257      0.65     -87    34
# Comp:  2           [NII]6583_d      7.444      0.65     -87    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -137         1
#  comp.  1:       -78        16
#  comp.  2:       -83        31
# chi2/DOF: 1.095; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.45      0.49     -78    16
# Comp:  1                Halpha      36.23      0.49     -78    16
# Comp:  2             [SII]6716      8.268      0.51     -83    31
# Comp:  2             [SII]6731      6.370      0.51     -83    31
# Comp:  2              HeII4687     0.4871      0.51     -83    31
# Comp:  2               HeI5876      0.000      0.51     -83    31
# Comp:  2          [OIII]5007_d      11.16      0.64     -83    31
# Comp:  2            [OI]6300_d      1.141      0.64     -83    31
# Comp:  2           [NII]6583_d      7.649      0.64     -83    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -161        31
#  comp.  1:       -81        16
#  comp.  2:       -83        37
# chi2/DOF: 1.100; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.06      0.49     -81    16
# Comp:  1                Halpha      37.37      0.49     -81    16
# Comp:  2             [SII]6716      9.664      0.52     -83    37
# Comp:  2             [SII]6731      6.401      0.52     -83    37
# Comp:  2              HeII4687     0.2807      0.52     -83    37
# Comp:  2               HeI5876     0.3011      0.52     -83    37
# Comp:  2          [OIII]5007_d      10.51      0.65     -83    37
# Comp:  2            [OI]6300_d     0.9108      0.65     -83    37
# Comp:  2           [NII]6583_d      7.478      0.65     -83    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86         1
#  comp.  1:       -84        32
#  comp.  2:       -82        27
# chi2/DOF: 1.095; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.72      0.51     -84    32
# Comp:  1                Halpha      39.46      0.51     -84    32
# Comp:  2             [SII]6716      7.659      0.50     -82    27
# Comp:  2             [SII]6731      6.010      0.50     -82    27
# Comp:  2              HeII4687     0.2612      0.50     -82    27
# Comp:  2               HeI5876      0.000      0.50     -82    27
# Comp:  2          [OIII]5007_d      9.468      0.64     -82    27
# Comp:  2            [OI]6300_d     0.9790      0.64     -82    27
# Comp:  2           [NII]6583_d      7.534      0.64     -82    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -105         1
#  comp.  1:       -84        29
#  comp.  2:       -86        23
# chi2/DOF: 1.097; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.18      0.51     -84    29
# Comp:  1                Halpha      38.98      0.51     -84    29
# Comp:  2             [SII]6716      8.820      0.50     -86    23
# Comp:  2             [SII]6731      5.921      0.50     -86    23
# Comp:  2              HeII4687     0.4863      0.50     -86    23
# Comp:  2               HeI5876      0.000      0.50     -86    23
# Comp:  2          [OIII]5007_d      9.997      0.63     -86    23
# Comp:  2            [OI]6300_d     0.6867      0.63     -86    23
# Comp:  2           [NII]6583_d      7.677      0.63     -86    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:       -81        20
#  comp.  2:       -87        22
# chi2/DOF: 1.104; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.66      0.49     -81    20
# Comp:  1                Halpha      37.50      0.49     -81    20
# Comp:  2             [SII]6716      9.748      0.50     -87    22
# Comp:  2             [SII]6731      6.783      0.50     -87    22
# Comp:  2              HeII4687     0.3721      0.50     -87    22
# Comp:  2               HeI5876      0.000      0.50     -87    22
# Comp:  2          [OIII]5007_d      8.984      0.63     -87    22
# Comp:  2            [OI]6300_d      1.011      0.63     -87    22
# Comp:  2           [NII]6583_d      7.196      0.63     -87    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70        59
#  comp.  1:       -83        33
#  comp.  2:       -85        34
# chi2/DOF: 1.097; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 60; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.47      0.51     -83    33
# Comp:  1                Halpha      39.77      0.51     -83    33
# Comp:  2             [SII]6716      9.059      0.51     -85    34
# Comp:  2             [SII]6731      7.023      0.51     -85    34
# Comp:  2              HeII4687     0.3388      0.51     -85    34
# Comp:  2               HeI5876      0.000      0.51     -85    34
# Comp:  2          [OIII]5007_d      9.871      0.65     -85    34
# Comp:  2            [OI]6300_d     0.7060      0.65     -85    34
# Comp:  2           [NII]6583_d      7.838      0.65     -85    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -107       151
#  comp.  1:       -81        25
#  comp.  2:       -80        29
# chi2/DOF: 1.099; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.73      0.50     -81    25
# Comp:  1                Halpha      37.88      0.50     -81    25
# Comp:  2             [SII]6716      8.192      0.51     -80    29
# Comp:  2             [SII]6731      6.720      0.51     -80    29
# Comp:  2              HeII4687     0.2693      0.51     -80    29
# Comp:  2               HeI5876      0.000      0.51     -80    29
# Comp:  2          [OIII]5007_d      9.173      0.64     -80    29
# Comp:  2            [OI]6300_d     0.9105      0.64     -80    29
# Comp:  2           [NII]6583_d      7.006      0.64     -80    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99        19
#  comp.  1:       -81        24
#  comp.  2:       -84        29
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 15; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.44      0.50     -81    24
# Comp:  1                Halpha      38.39      0.50     -81    24
# Comp:  2             [SII]6716      8.850      0.51     -84    29
# Comp:  2             [SII]6731      6.102      0.51     -84    29
# Comp:  2              HeII4687     0.4678      0.51     -84    29
# Comp:  2               HeI5876      0.000      0.51     -84    29
# Comp:  2          [OIII]5007_d      10.27      0.64     -84    29
# Comp:  2            [OI]6300_d     0.4656      0.64     -84    29
# Comp:  2           [NII]6583_d      7.401      0.64     -84    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -91         1
#  comp.  1:       -83        35
#  comp.  2:       -86        15
# chi2/DOF: 1.098; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.69      0.51     -83    35
# Comp:  1                Halpha      39.56      0.51     -83    35
# Comp:  2             [SII]6716      9.258      0.49     -86    15
# Comp:  2             [SII]6731      5.913      0.49     -86    15
# Comp:  2              HeII4687     0.3240      0.49     -86    15
# Comp:  2               HeI5876     0.2706      0.49     -86    15
# Comp:  2          [OIII]5007_d      10.77      0.62     -86    15
# Comp:  2            [OI]6300_d     0.5414      0.62     -86    15
# Comp:  2           [NII]6583_d      6.871      0.62     -86    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -105         1
#  comp.  1:       -79        20
#  comp.  2:       -81        27
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.71      0.49     -79    20
# Comp:  1                Halpha      37.99      0.49     -79    20
# Comp:  2             [SII]6716      8.146      0.50     -81    27
# Comp:  2             [SII]6731      5.911      0.50     -81    27
# Comp:  2              HeII4687     0.5124      0.50     -81    27
# Comp:  2               HeI5876      0.000      0.50     -81    27
# Comp:  2          [OIII]5007_d      10.39      0.63     -81    27
# Comp:  2            [OI]6300_d     0.8547      0.63     -81    27
# Comp:  2           [NII]6583_d      7.362      0.63     -81    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68         1
#  comp.  1:       -85        29
#  comp.  2:       -81        33
# chi2/DOF: 1.098; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.06      0.51     -85    29
# Comp:  1                Halpha      39.14      0.51     -85    29
# Comp:  2             [SII]6716      8.972      0.51     -81    33
# Comp:  2             [SII]6731      6.344      0.51     -81    33
# Comp:  2              HeII4687     0.6091      0.51     -81    33
# Comp:  2               HeI5876      0.000      0.51     -81    33
# Comp:  2          [OIII]5007_d      9.635      0.65     -81    33
# Comp:  2            [OI]6300_d      1.154      0.65     -81    33
# Comp:  2           [NII]6583_d      7.255      0.65     -81    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87         1
#  comp.  1:       -81        19
#  comp.  2:       -89        40
# chi2/DOF: 1.101; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.36      0.49     -81    19
# Comp:  1                Halpha      37.70      0.49     -81    19
# Comp:  2             [SII]6716      9.769      0.52     -89    40
# Comp:  2             [SII]6731      6.371      0.52     -89    40
# Comp:  2              HeII4687     0.3516      0.52     -89    40
# Comp:  2               HeI5876    0.06827      0.52     -89    40
# Comp:  2          [OIII]5007_d      11.28      0.66     -89    40
# Comp:  2            [OI]6300_d     0.4107      0.66     -89    40
# Comp:  2           [NII]6583_d      7.893      0.66     -89    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -112        31
#  comp.  1:       -76        20
#  comp.  2:       -85        19
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.44      0.49     -76    20
# Comp:  1                Halpha      36.84      0.49     -76    20
# Comp:  2             [SII]6716      9.713      0.49     -85    19
# Comp:  2             [SII]6731      6.658      0.49     -85    19
# Comp:  2              HeII4687     0.1526      0.49     -85    19
# Comp:  2               HeI5876     0.3480      0.49     -85    19
# Comp:  2          [OIII]5007_d      10.88      0.62     -85    19
# Comp:  2            [OI]6300_d     0.6571      0.62     -85    19
# Comp:  2           [NII]6583_d      7.110      0.62     -85    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -140        53
#  comp.  1:       -83        29
#  comp.  2:       -84        35
# chi2/DOF: 1.102; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.61      0.51     -83    29
# Comp:  1                Halpha      38.90      0.51     -83    29
# Comp:  2             [SII]6716      7.979      0.51     -84    35
# Comp:  2             [SII]6731      6.731      0.51     -84    35
# Comp:  2              HeII4687     0.2828      0.51     -84    35
# Comp:  2               HeI5876     0.5302      0.51     -84    35
# Comp:  2          [OIII]5007_d      10.19      0.65     -84    35
# Comp:  2            [OI]6300_d      1.119      0.65     -84    35
# Comp:  2           [NII]6583_d      7.653      0.65     -84    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -492      1000
#  comp.  1:       -78        14
#  comp.  2:       -80        25
# chi2/DOF: 1.101; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.55      0.49     -78    14
# Comp:  1                Halpha      36.22      0.49     -78    14
# Comp:  2             [SII]6716      8.785      0.50     -80    25
# Comp:  2             [SII]6731      6.907      0.50     -80    25
# Comp:  2              HeII4687     0.1686      0.50     -80    25
# Comp:  2               HeI5876      0.000      0.50     -80    25
# Comp:  2          [OIII]5007_d      10.11      0.63     -80    25
# Comp:  2            [OI]6300_d     0.6641      0.63     -80    25
# Comp:  2           [NII]6583_d      7.523      0.63     -80    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -101         1
#  comp.  1:       -79        18
#  comp.  2:       -86        32
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.90      0.49     -79    18
# Comp:  1                Halpha      36.56      0.49     -79    18
# Comp:  2             [SII]6716      9.289      0.51     -86    32
# Comp:  2             [SII]6731      6.742      0.51     -86    32
# Comp:  2              HeII4687     0.4323      0.51     -86    32
# Comp:  2               HeI5876     0.2382      0.51     -86    32
# Comp:  2          [OIII]5007_d      9.505      0.64     -86    32
# Comp:  2            [OI]6300_d      1.145      0.64     -86    32
# Comp:  2           [NII]6583_d      7.672      0.64     -86    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -121       191
#  comp.  1:       -84        30
#  comp.  2:       -90        28
# chi2/DOF: 1.092; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.09      0.51     -84    30
# Comp:  1                Halpha      39.17      0.51     -84    30
# Comp:  2             [SII]6716      9.912      0.50     -90    28
# Comp:  2             [SII]6731      6.902      0.50     -90    28
# Comp:  2              HeII4687     0.2150      0.50     -90    28
# Comp:  2               HeI5876     0.3177      0.50     -90    28
# Comp:  2          [OIII]5007_d      10.51      0.64     -90    28
# Comp:  2            [OI]6300_d     0.9473      0.64     -90    28
# Comp:  2           [NII]6583_d      7.143      0.64     -90    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        32       151
#  comp.  1:       -83        31
#  comp.  2:       -85        29
# chi2/DOF: 1.097; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.48      0.51     -83    31
# Comp:  1                Halpha      39.31      0.51     -83    31
# Comp:  2             [SII]6716      8.293      0.51     -85    29
# Comp:  2             [SII]6731      7.026      0.51     -85    29
# Comp:  2              HeII4687     0.1572      0.51     -85    29
# Comp:  2               HeI5876    0.04704      0.51     -85    29
# Comp:  2          [OIII]5007_d      10.45      0.64     -85    29
# Comp:  2            [OI]6300_d     0.9522      0.64     -85    29
# Comp:  2           [NII]6583_d      7.328      0.64     -85    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77       317
#  comp.  1:       -83        31
#  comp.  2:       -88        26
# chi2/DOF: 1.098; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.06      0.51     -83    31
# Comp:  1                Halpha      39.01      0.51     -83    31
# Comp:  2             [SII]6716      8.807      0.50     -88    26
# Comp:  2             [SII]6731      6.289      0.50     -88    26
# Comp:  2              HeII4687     0.2652      0.50     -88    26
# Comp:  2               HeI5876      0.000      0.50     -88    26
# Comp:  2          [OIII]5007_d      11.07      0.63     -88    26
# Comp:  2            [OI]6300_d      1.059      0.63     -88    26
# Comp:  2           [NII]6583_d      7.455      0.63     -88    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87         1
#  comp.  1:       -83        30
#  comp.  2:       -84        20
# chi2/DOF: 1.101; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.34      0.51     -83    30
# Comp:  1                Halpha      38.26      0.51     -83    30
# Comp:  2             [SII]6716      7.625      0.49     -84    20
# Comp:  2             [SII]6731      6.798      0.49     -84    20
# Comp:  2              HeII4687     0.2012      0.49     -84    20
# Comp:  2               HeI5876    0.08261      0.49     -84    20
# Comp:  2          [OIII]5007_d      9.801      0.62     -84    20
# Comp:  2            [OI]6300_d     0.7300      0.62     -84    20
# Comp:  2           [NII]6583_d      7.054      0.62     -84    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69        61
#  comp.  1:       -79        30
#  comp.  2:       -83        27
# chi2/DOF: 1.101; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.63      0.51     -79    30
# Comp:  1                Halpha      38.21      0.51     -79    30
# Comp:  2             [SII]6716      8.420      0.50     -83    27
# Comp:  2             [SII]6731      6.694      0.50     -83    27
# Comp:  2              HeII4687     0.4623      0.50     -83    27
# Comp:  2               HeI5876      0.000      0.50     -83    27
# Comp:  2          [OIII]5007_d      11.43      0.63     -83    27
# Comp:  2            [OI]6300_d     0.4643      0.63     -83    27
# Comp:  2           [NII]6583_d      7.501      0.63     -83    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -174        60
#  comp.  1:       -83        33
#  comp.  2:       -82        37
# chi2/DOF: 1.093; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.07      0.51     -83    33
# Comp:  1                Halpha      39.54      0.51     -83    33
# Comp:  2             [SII]6716      8.493      0.52     -82    37
# Comp:  2             [SII]6731      7.176      0.52     -82    37
# Comp:  2              HeII4687     0.3788      0.52     -82    37
# Comp:  2               HeI5876     0.3509      0.52     -82    37
# Comp:  2          [OIII]5007_d      9.535      0.65     -82    37
# Comp:  2            [OI]6300_d     0.6403      0.65     -82    37
# Comp:  2           [NII]6583_d      7.472      0.65     -82    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85       142
#  comp.  1:       -79        26
#  comp.  2:       -81        43
# chi2/DOF: 1.100; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.98      0.50     -79    26
# Comp:  1                Halpha      38.33      0.50     -79    26
# Comp:  2             [SII]6716      8.606      0.53     -81    43
# Comp:  2             [SII]6731      7.520      0.53     -81    43
# Comp:  2              HeII4687     0.3924      0.53     -81    43
# Comp:  2               HeI5876     0.1520      0.53     -81    43
# Comp:  2          [OIII]5007_d      10.80      0.67     -81    43
# Comp:  2            [OI]6300_d      1.092      0.67     -81    43
# Comp:  2           [NII]6583_d      7.466      0.67     -81    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -101         1
#  comp.  1:       -78        14
#  comp.  2:       -86        32
# chi2/DOF: 1.096; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.03      0.49     -78    14
# Comp:  1                Halpha      36.82      0.49     -78    14
# Comp:  2             [SII]6716      8.891      0.51     -86    32
# Comp:  2             [SII]6731      6.070      0.51     -86    32
# Comp:  2              HeII4687     0.3928      0.51     -86    32
# Comp:  2               HeI5876     0.3849      0.51     -86    32
# Comp:  2          [OIII]5007_d      9.710      0.64     -86    32
# Comp:  2            [OI]6300_d     0.7299      0.64     -86    32
# Comp:  2           [NII]6583_d      7.566      0.64     -86    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       -77        13
#  comp.  2:       -77        30
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.69      0.49     -77    13
# Comp:  1                Halpha      36.75      0.49     -77    13
# Comp:  2             [SII]6716      8.189      0.51     -77    30
# Comp:  2             [SII]6731      6.918      0.51     -77    30
# Comp:  2              HeII4687     0.4206      0.51     -77    30
# Comp:  2               HeI5876      0.000      0.51     -77    30
# Comp:  2          [OIII]5007_d      10.23      0.64     -77    30
# Comp:  2            [OI]6300_d      1.168      0.64     -77    30
# Comp:  2           [NII]6583_d      7.132      0.64     -77    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -116        57
#  comp.  1:       -79         1
#  comp.  2:       -77        30
# chi2/DOF: 1.093; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.85      0.48     -79     1
# Comp:  1                Halpha      36.22      0.48     -79     1
# Comp:  2             [SII]6716      8.981      0.51     -77    30
# Comp:  2             [SII]6731      6.994      0.51     -77    30
# Comp:  2              HeII4687     0.1618      0.51     -77    30
# Comp:  2               HeI5876     0.4479      0.51     -77    30
# Comp:  2          [OIII]5007_d      9.267      0.64     -77    30
# Comp:  2            [OI]6300_d     0.8764      0.64     -77    30
# Comp:  2           [NII]6583_d      7.306      0.64     -77    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84         1
#  comp.  1:       -77        19
#  comp.  2:       -84        29
# chi2/DOF: 1.101; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.94      0.49     -77    19
# Comp:  1                Halpha      36.56      0.49     -77    19
# Comp:  2             [SII]6716      9.609      0.51     -84    29
# Comp:  2             [SII]6731      6.821      0.51     -84    29
# Comp:  2              HeII4687     0.3429      0.51     -84    29
# Comp:  2               HeI5876      0.000      0.51     -84    29
# Comp:  2          [OIII]5007_d      10.56      0.64     -84    29
# Comp:  2            [OI]6300_d     0.9879      0.64     -84    29
# Comp:  2           [NII]6583_d      7.983      0.64     -84    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1111      1000
#  comp.  1:       -78        16
#  comp.  2:       -83        27
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.22      0.49     -78    16
# Comp:  1                Halpha      35.76      0.49     -78    16
# Comp:  2             [SII]6716      8.772      0.50     -83    27
# Comp:  2             [SII]6731      6.346      0.50     -83    27
# Comp:  2              HeII4687     0.2498      0.50     -83    27
# Comp:  2               HeI5876      0.000      0.50     -83    27
# Comp:  2          [OIII]5007_d      10.32      0.63     -83    27
# Comp:  2            [OI]6300_d      1.424      0.63     -83    27
# Comp:  2           [NII]6583_d      7.070      0.63     -83    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -104         1
#  comp.  1:       -81        21
#  comp.  2:       -83        29
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.72      0.50     -81    21
# Comp:  1                Halpha      37.64      0.50     -81    21
# Comp:  2             [SII]6716      8.431      0.51     -83    29
# Comp:  2             [SII]6731      7.089      0.51     -83    29
# Comp:  2              HeII4687     0.4815      0.51     -83    29
# Comp:  2               HeI5876      0.000      0.51     -83    29
# Comp:  2          [OIII]5007_d      10.12      0.64     -83    29
# Comp:  2            [OI]6300_d     0.9707      0.64     -83    29
# Comp:  2           [NII]6583_d      7.182      0.64     -83    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -181        86
#  comp.  1:       -79        22
#  comp.  2:       -84        23
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.61      0.50     -79    22
# Comp:  1                Halpha      38.25      0.50     -79    22
# Comp:  2             [SII]6716      9.769      0.50     -84    23
# Comp:  2             [SII]6731      6.961      0.50     -84    23
# Comp:  2              HeII4687     0.2979      0.50     -84    23
# Comp:  2               HeI5876      0.000      0.50     -84    23
# Comp:  2          [OIII]5007_d      9.793      0.63     -84    23
# Comp:  2            [OI]6300_d     0.2458      0.63     -84    23
# Comp:  2           [NII]6583_d      7.321      0.63     -84    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -378       785
#  comp.  1:       -80        31
#  comp.  2:       -77        36
# chi2/DOF: 1.100; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.47      0.51     -80    31
# Comp:  1                Halpha      37.83      0.51     -80    31
# Comp:  2             [SII]6716      8.342      0.52     -77    36
# Comp:  2             [SII]6731      6.300      0.52     -77    36
# Comp:  2              HeII4687     0.3442      0.52     -77    36
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.16      0.49     -81    15
# Comp:  1                Halpha      37.83      0.49     -81    15
# Comp:  2             [SII]6716      8.125      0.49     -84    20
# Comp:  2             [SII]6731      6.439      0.49     -84    20
# Comp:  2              HeII4687     0.2575      0.49     -84    20
# Comp:  2               HeI5876    0.07724      0.49     -84    20
# Comp:  2          [OIII]5007_d      10.06      0.62     -84    20
# Comp:  2            [OI]6300_d     0.9504      0.62     -84    20
# Comp:  2           [NII]6583_d      7.715      0.62     -84    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -113        35
#  comp.  1:       -82        28
#  comp.  2:       -82        30
# chi2/DOF: 1.099; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.61      0.50     -82    28
# Comp:  1                Halpha      39.43      0.50     -82    28
# Comp:  2             [SII]6716      8.142      0.51     -82    30
# Comp:  2             [SII]6731      6.099      0.51     -82    30
# Comp:  2              HeII4687     0.4276      0.51     -82    30
# Comp:  2               HeI5876      0.000      0.51     -82    30
# Comp:  2          [OIII]5007_d      11.64      0.64     -82    30
# Comp:  2            [OI]6300_d      1.210      0.64     -82    30
# Comp:  2           [NII]6583_d      7.051      0.64     -82    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        28
#  comp.  1:       -77        12
#  comp.  2:       -80        39
# chi2/DOF: 1.095; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.86      0.49     -77    12
# Comp:  1                Halpha      36.43      0.49     -77    12
# Comp:  2             [SII]6716      8.511      0.52     -80    39
# Comp:  2             [SII]6731      6.364      0.52     -80    39
# Comp:  2              HeII4687     0.4268      0.52     -80    39
# Comp:  2               HeI5876     0.4959      0.52     -80    39
# Comp:  2          [OIII]5007_d      9.816      0.66     -80    39
# Comp:  2            [OI]6300_d     0.9716      0.66     -80    39
# Comp:  2           [NII]6583_d      7.866      0.66     -80    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40       193
#  comp.  1:       -80        23
#  comp.  2:       -87        33
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.08      0.50     -80    23
# Comp:  1                Halpha      37.98      0.50     -80    23
# Comp:  2             [SII]6716      9.013      0.51     -87    33
# Comp:  2             [SII]6731      6.235      0.51     -87    33
# Comp:  2              HeII4687     0.2452      0.51     -87    33
# Comp:  2               HeI5876     0.2588      0.51     -87    33
# Comp:  2          [OIII]5007_d      10.48      0.65     -87    33
# Comp:  2            [OI]6300_d     0.6084      0.65     -87    33
# Comp:  2           [NII]6583_d      7.236      0.65     -87    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -111        93
#  comp.  1:       -82        31
#  comp.  2:       -85        25
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.51      0.51     -82    31
# Comp:  1                Halpha      39.54      0.51     -82    31
# Comp:  2             [SII]6716      9.095      0.50     -85    25
# Comp:  2             [SII]6731      6.047      0.50     -85    25
# Comp:  2              HeII4687     0.5235      0.50     -85    25
# Comp:  2               HeI5876      0.000      0.50     -85    25
# Comp:  2          [OIII]5007_d      9.042      0.63     -85    25
# Comp:  2            [OI]6300_d      1.294      0.63     -85    25
# Comp:  2           [NII]6583_d      7.629      0.63     -85    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -118       169
#  comp.  1:       -85        35
#  comp.  2:       -78        33
# chi2/DOF: 1.091; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.92      0.51     -85    35
# Comp:  1                Halpha      39.48      0.51     -85    35
# Comp:  2             [SII]6716      9.034      0.51     -78    33
# Comp:  2             [SII]6731      6.419      0.51     -78    33
# Comp:  2              HeII4687     0.3508      0.51     -78    33
# Comp:  2               HeI5876     0.1239      0.51     -78    33
# Comp:  2          [OIII]5007_d      10.78      0.65     -78    33
# Comp:  2            [OI]6300_d      1.164      0.65     -78    33
# Comp:  2           [NII]6583_d      7.018      0.65     -78    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80         1
#  comp.  1:       -81        21
#  comp.  2:       -83        34
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 19; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.76      0.50     -81    21
# Comp:  1                Halpha      37.62      0.50     -81    21
# Comp:  2             [SII]6716      8.210      0.51     -83    34
# Comp:  2             [SII]6731      7.142      0.51     -83    34
# Comp:  2              HeII4687     0.2806      0.51     -83    34
# Comp:  2               HeI5876      0.000      0.51     -83    34
# Comp:  2          [OIII]5007_d      11.78      0.65     -83    34
# Comp:  2            [OI]6300_d     0.5789      0.65     -83    34
# Comp:  2           [NII]6583_d      6.875      0.65     -83    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -94       548
#  comp.  1:       -80        34
#  comp.  2:       -87         4
# chi2/DOF: 1.098; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.16      0.51     -80    34
# Comp:  1                Halpha      38.15      0.51     -80    34
# Comp:  2             [SII]6716      9.099      0.48     -87     4
# Comp:  2             [SII]6731      6.275      0.48     -87     4
# Comp:  2              HeII4687     0.4658      0.48     -87     4
# Comp:  2               HeI5876      0.000      0.48     -87     4
# Comp:  2          [OIII]5007_d      9.648      0.61     -87     4
# Comp:  2            [OI]6300_d     0.9722      0.61     -87     4
# Comp:  2           [NII]6583_d      7.110      0.61     -87     4
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        67
#  comp.  1:       -83        27
#  comp.  2:       -82        46
# chi2/DOF: 1.096; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 46; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.57      0.50     -83    27
# Comp:  1                Halpha      39.20      0.50     -83    27
# Comp:  2             [SII]6716      8.600      0.53     -82    46
# Comp:  2             [SII]6731      6.692      0.53     -82    46
# Comp:  2              HeII4687     0.1789      0.53     -82    46
# Comp:  2               HeI5876      0.000      0.53     -82    46
# Comp:  2          [OIII]5007_d      11.26      0.67     -82    46
# Comp:  2            [OI]6300_d      1.103      0.67     -82    46
# Comp:  2           [NII]6583_d      7.404      0.67     -82    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -91        81
#  comp.  1:       -83        27
#  comp.  2:       -82        31
# chi2/DOF: 1.101; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.31      0.50     -83    27
# Comp:  1                Halpha      39.00      0.50     -83    27
# Comp:  2             [SII]6716      8.256      0.51     -82    31
# Comp:  2             [SII]6731      6.913      0.51     -82    31
# Comp:  2              HeII4687     0.4541      0.51     -82    31
# Comp:  2               HeI5876      0.000      0.51     -82    31
# Comp:  2          [OIII]5007_d      10.38      0.64     -82    31
# Comp:  2            [OI]6300_d     0.9493      0.64     -82    31
# Comp:  2           [NII]6583_d      7.529      0.64     -82    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -146        27
#  comp.  1:       -81        17
#  comp.  2:       -85        37
# chi2/DOF: 1.100; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.03      0.49     -81    17
# Comp:  1                Halpha      37.15      0.49     -81    17
# Comp:  2             [SII]6716      9.419      0.52     -85    37
# Comp:  2             [SII]6731      6.601      0.52     -85    37
# Comp:  2              HeII4687     0.4869      0.52     -85    37
# Comp:  2               HeI5876     0.2555      0.52     -85    37
# Comp:  2          [OIII]5007_d      11.70      0.65     -85    37
# Comp:  2            [OI]6300_d     0.7940      0.65     -85    37
# Comp:  2           [NII]6583_d      7.650      0.65     -85    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         1
#  comp.  1:       -81        28
#  comp.  2:       -80        43
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.35      0.50     -81    28
# Comp:  1                Halpha      37.86      0.50     -81    28
# Comp:  2             [SII]6716      9.329      0.53     -80    43
# Comp:  2             [SII]6731      7.511      0.53     -80    43
# Comp:  2              HeII4687     0.2555      0.53     -80    43
# Comp:  2               HeI5876      0.000      0.53     -80    43
# Comp:  2          [OIII]5007_d      10.25      0.67     -80    43
# Comp:  2            [OI]6300_d     0.9437      0.67     -80    43
# Comp:  2           [NII]6583_d      7.176      0.67     -80    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99        35
#  comp.  1:       -78         2
#  comp.  2:       -81        25
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.99      0.48     -78     2
# Comp:  1                Halpha      36.32      0.48     -78     2
# Comp:  2             [SII]6716      8.206      0.50     -81    25
# Comp:  2             [SII]6731      6.686      0.50     -81    25
# Comp:  2              HeII4687     0.2570      0.50     -81    25
# Comp:  2               HeI5876     0.1021      0.50     -81    25
# Comp:  2          [OIII]5007_d      11.03      0.63     -81    25
# Comp:  2            [OI]6300_d      1.266      0.63     -81    25
# Comp:  2           [NII]6583_d      7.152      0.63     -81    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80         1
#  comp.  1:       -84        29
#  comp.  2:       -81        34
# chi2/DOF: 1.099; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.53      0.50     -84    29
# Comp:  1                Halpha      39.15      0.50     -84    29
# Comp:  2             [SII]6716      10.14      0.51     -81    34
# Comp:  2             [SII]6731      6.267      0.51     -81    34
# Comp:  2              HeII4687     0.3552      0.51     -81    34
# Comp:  2               HeI5876     0.3220      0.51     -81    34
# Comp:  2          [OIII]5007_d      10.50      0.65     -81    34
# Comp:  2            [OI]6300_d      1.119      0.65     -81    34
# Comp:  2           [NII]6583_d      7.534      0.65     -81    34
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.71110726, 1.56562307, 0.91234124, 0.53897208, 0.10529741,
#        0.18023352, 0.69338751, 0.41245516, 0.39375357])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([13.85336332, 51.73508849, 12.42762789,  9.1844605 ,  0.32718719,
#         0.        , 10.80398316,  1.21422359, 10.18388047])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_16_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_16", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_16_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_16_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_16_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.333374    0.017112
# 1        Halpha  1.244980    0.037676
# 2     [SII]6716  0.299065    0.021955
# 3     [SII]6731  0.221020    0.012970
# 4      HeII4687  0.007874    0.002534
# 5       HeI5876  0.000000    0.004337
# 6  [OIII]5007_d  0.259993    0.016686
# 7    [OI]6300_d  0.029220    0.009926
# 8   [NII]6583_d  0.245070    0.009475
#           Name      Flux  Error_flux
# 0        Hbeta  0.333374    0.017112
# 1       Halpha  1.244980    0.037676
# 2    [SII]6716  0.299065    0.021955
# 3    [SII]6731  0.221020    0.012970
# 4     HeII4687  0.007874    0.002534
# 5      HeI5876  0.000000    0.004337
# 6   [OIII]4959  0.064998    0.016686
# 7   [OIII]5007  0.194994    0.016686
# 8     [OI]6300  0.021915    0.009926
# 9     [OI]6364  0.007305    0.009926
# 10   [NII]6548  0.061268    0.009475
# 11   [NII]6583  0.183803    0.009475

# %%
np.median(flux_rf_rebin)
# Out:
# 0.024064514740044674
