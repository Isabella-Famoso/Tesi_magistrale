# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_13.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_13']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.05034986 0.05915527 0.0553138  ... 0.02522834 0.03135124 0.03046263] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        14
# chi2/DOF: 0.02473; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
# chi2/DOF: 0.01738; DOF: 1917; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-58.71624685,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         5
#  comp.  1:       -76        57
#  comp.  2:       -94        92
# chi2/DOF: 1.024; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9027      0.35     -76    57
# Comp:  1                Halpha      3.551      0.35     -76    57
# Comp:  2             [SII]6716      1.956      0.40     -94    92
# Comp:  2             [SII]6731     0.9662      0.40     -94    92
# Comp:  2              HeII4687    0.07983      0.40     -94    92
# Comp:  2               HeI5876    0.08351      0.40     -94    92
# Comp:  2          [OIII]5007_d      1.313      0.51     -94    92
# Comp:  2            [OI]6300_d     0.9018      0.51     -94    92
# Comp:  2           [NII]6583_d      1.442      0.51     -94    92
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  1.924; gas flux:      1 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  7.628; gas flux:      5 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:   3.17; gas flux:      3 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  1.593; gas flux:      1 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.1275; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.1343; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   1.61; gas flux:      1 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.119; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  1.775; gas flux:      2 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         1
#  comp.  1:       -69        49
#  comp.  2:       -96        89
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9423      0.34     -69    49
# Comp:  1                Halpha      3.594      0.34     -69    49
# Comp:  2             [SII]6716      2.033      0.40     -96    89
# Comp:  2             [SII]6731      1.100      0.40     -96    89
# Comp:  2              HeII4687     0.2826      0.40     -96    89
# Comp:  2               HeI5876     0.4956      0.40     -96    89
# Comp:  2          [OIII]5007_d      1.387      0.50     -96    89
# Comp:  2            [OI]6300_d      1.134      0.50     -96    89
# Comp:  2           [NII]6583_d      1.234      0.50     -96    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81         1
#  comp.  1:       -80        50
#  comp.  2:       -90        71
# chi2/DOF: 1.018; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.230      0.34     -80    50
# Comp:  1                Halpha      3.644      0.34     -80    50
# Comp:  2             [SII]6716      1.876      0.37     -90    71
# Comp:  2             [SII]6731     0.8809      0.37     -90    71
# Comp:  2              HeII4687    0.01327      0.37     -90    71
# Comp:  2               HeI5876     0.3059      0.37     -90    71
# Comp:  2          [OIII]5007_d      1.194      0.47     -90    71
# Comp:  2            [OI]6300_d     0.5073      0.47     -90    71
# Comp:  2           [NII]6583_d      1.381      0.47     -90    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        46
#  comp.  1:       -74        59
#  comp.  2:      -107        84
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.154      0.36     -74    59
# Comp:  1                Halpha      4.055      0.36     -74    59
# Comp:  2             [SII]6716      1.984      0.39    -107    84
# Comp:  2             [SII]6731     0.8554      0.39    -107    84
# Comp:  2              HeII4687     0.2573      0.39    -107    84
# Comp:  2               HeI5876      0.000      0.39    -107    84
# Comp:  2          [OIII]5007_d      1.336      0.49    -107    84
# Comp:  2            [OI]6300_d     0.8545      0.49    -107    84
# Comp:  2           [NII]6583_d      1.429      0.49    -107    84
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -91        56
#  comp.  1:       -83        73
#  comp.  2:       -65        80
# chi2/DOF: 1.014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.119      0.38     -83    73
# Comp:  1                Halpha      3.843      0.38     -83    73
# Comp:  2             [SII]6716      1.772      0.38     -65    80
# Comp:  2             [SII]6731     0.8302      0.38     -65    80
# Comp:  2              HeII4687     0.2514      0.38     -65    80
# Comp:  2               HeI5876     0.1331      0.38     -65    80
# Comp:  2          [OIII]5007_d      1.609      0.49     -65    80
# Comp:  2            [OI]6300_d     0.9673      0.49     -65    80
# Comp:  2           [NII]6583_d      1.837      0.49     -65    80
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:       -81        56
#  comp.  2:      -114        90
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.256      0.35     -81    56
# Comp:  1                Halpha      3.910      0.35     -81    56
# Comp:  2             [SII]6716      2.281      0.40    -114    90
# Comp:  2             [SII]6731     0.9227      0.40    -114    90
# Comp:  2              HeII4687      0.000      0.40    -114    90
# Comp:  2               HeI5876    0.09898      0.40    -114    90
# Comp:  2          [OIII]5007_d      1.726      0.51    -114    90
# Comp:  2            [OI]6300_d      1.189      0.51    -114    90
# Comp:  2           [NII]6583_d      1.475      0.51    -114    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         1
#  comp.  1:       -79        64
#  comp.  2:       -87        74
# chi2/DOF: 1.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.408      0.36     -79    64
# Comp:  1                Halpha      4.043      0.36     -79    64
# Comp:  2             [SII]6716      1.831      0.38     -87    74
# Comp:  2             [SII]6731     0.8832      0.38     -87    74
# Comp:  2              HeII4687      0.000      0.38     -87    74
# Comp:  2               HeI5876     0.3099      0.38     -87    74
# Comp:  2          [OIII]5007_d      1.443      0.48     -87    74
# Comp:  2            [OI]6300_d     0.8590      0.48     -87    74
# Comp:  2           [NII]6583_d      1.435      0.48     -87    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -94         1
#  comp.  1:       -80        60
#  comp.  2:       -92       107
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.461      0.36     -80    60
# Comp:  1                Halpha      3.910      0.36     -80    60
# Comp:  2             [SII]6716      2.156      0.42     -92   107
# Comp:  2             [SII]6731      1.083      0.42     -92   107
# Comp:  2              HeII4687     0.1580      0.42     -92   107
# Comp:  2               HeI5876      0.000      0.42     -92   107
# Comp:  2          [OIII]5007_d     0.9010      0.54     -92   107
# Comp:  2            [OI]6300_d      1.099      0.54     -92   107
# Comp:  2           [NII]6583_d      1.560      0.54     -92   107
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71         1
#  comp.  1:       -76        52
#  comp.  2:       -92        55
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9527      0.35     -76    52
# Comp:  1                Halpha      3.281      0.35     -76    52
# Comp:  2             [SII]6716      1.410      0.35     -92    55
# Comp:  2             [SII]6731     0.7258      0.35     -92    55
# Comp:  2              HeII4687     0.5114      0.35     -92    55
# Comp:  2               HeI5876     0.4388      0.35     -92    55
# Comp:  2          [OIII]5007_d      1.442      0.44     -92    55
# Comp:  2            [OI]6300_d     0.6928      0.44     -92    55
# Comp:  2           [NII]6583_d      1.281      0.44     -92    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:       -84        58
#  comp.  2:       -97       100
# chi2/DOF: 1.014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.387      0.35     -84    58
# Comp:  1                Halpha      3.942      0.35     -84    58
# Comp:  2             [SII]6716      1.925      0.41     -97   100
# Comp:  2             [SII]6731     0.9927      0.41     -97   100
# Comp:  2              HeII4687    0.05545      0.41     -97   100
# Comp:  2               HeI5876     0.6663      0.41     -97   100
# Comp:  2          [OIII]5007_d      1.413      0.52     -97   100
# Comp:  2            [OI]6300_d     0.8482      0.52     -97   100
# Comp:  2           [NII]6583_d      2.035      0.52     -97   100
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:       -76        64
#  comp.  2:       -74        91
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.026      0.36     -76    64
# Comp:  1                Halpha      4.012      0.36     -76    64
# Comp:  2             [SII]6716      1.691      0.40     -74    91
# Comp:  2             [SII]6731     0.9030      0.40     -74    91
# Comp:  2              HeII4687     0.4987      0.40     -74    91
# Comp:  2               HeI5876     0.4574      0.40     -74    91
# Comp:  2          [OIII]5007_d     0.7182      0.51     -74    91
# Comp:  2            [OI]6300_d     0.9564      0.51     -74    91
# Comp:  2           [NII]6583_d      1.442      0.51     -74    91
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -69        49
#  comp.  2:       -78        88
# chi2/DOF: 1.018; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.731      0.34     -69    49
# Comp:  1                Halpha      3.523      0.34     -69    49
# Comp:  2             [SII]6716      1.935      0.40     -78    88
# Comp:  2             [SII]6731      1.118      0.40     -78    88
# Comp:  2              HeII4687     0.2570      0.40     -78    88
# Comp:  2               HeI5876    0.06678      0.40     -78    88
# Comp:  2          [OIII]5007_d      1.262      0.50     -78    88
# Comp:  2            [OI]6300_d     0.8347      0.50     -78    88
# Comp:  2           [NII]6583_d      1.708      0.50     -78    88
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -74        53
#  comp.  2:       -92       103
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.270      0.35     -74    53
# Comp:  1                Halpha      3.329      0.35     -74    53
# Comp:  2             [SII]6716      2.339      0.42     -92   103
# Comp:  2             [SII]6731      1.059      0.42     -92   103
# Comp:  2              HeII4687     0.2688      0.42     -92   103
# Comp:  2               HeI5876      0.000      0.42     -92   103
# Comp:  2          [OIII]5007_d     0.7277      0.53     -92   103
# Comp:  2            [OI]6300_d     0.7543      0.53     -92   103
# Comp:  2           [NII]6583_d      1.430      0.53     -92   103
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71        94
#  comp.  1:       -82        73
#  comp.  2:       -94        78
# chi2/DOF: 1.013; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8616      0.37     -82    73
# Comp:  1                Halpha      3.825      0.37     -82    73
# Comp:  2             [SII]6716      1.778      0.38     -94    78
# Comp:  2             [SII]6731      1.020      0.38     -94    78
# Comp:  2              HeII4687      0.000      0.38     -94    78
# Comp:  2               HeI5876     0.4895      0.38     -94    78
# Comp:  2          [OIII]5007_d      1.405      0.48     -94    78
# Comp:  2            [OI]6300_d     0.8328      0.48     -94    78
# Comp:  2           [NII]6583_d      1.450      0.48     -94    78
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        31
#  comp.  1:       -84        57
#  comp.  2:       -98        94
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.204      0.35     -84    57
# Comp:  1                Halpha      3.795      0.35     -84    57
# Comp:  2             [SII]6716      2.279      0.41     -98    94
# Comp:  2             [SII]6731      1.007      0.41     -98    94
# Comp:  2              HeII4687     0.4486      0.41     -98    94
# Comp:  2               HeI5876     0.1432      0.41     -98    94
# Comp:  2          [OIII]5007_d      2.109      0.51     -98    94
# Comp:  2            [OI]6300_d     0.7084      0.51     -98    94
# Comp:  2           [NII]6583_d      1.187      0.51     -98    94
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88         1
#  comp.  1:       -82        42
#  comp.  2:       -88       107
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5467      0.33     -82    42
# Comp:  1                Halpha      3.428      0.33     -82    42
# Comp:  2             [SII]6716      2.107      0.42     -88   107
# Comp:  2             [SII]6731      1.249      0.42     -88   107
# Comp:  2              HeII4687     0.3052      0.42     -88   107
# Comp:  2               HeI5876      0.000      0.42     -88   107
# Comp:  2          [OIII]5007_d      1.451      0.54     -88   107
# Comp:  2            [OI]6300_d     0.9382      0.54     -88   107
# Comp:  2           [NII]6583_d      1.538      0.54     -88   107
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78         1
#  comp.  1:       -87        60
#  comp.  2:      -121        94
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8567      0.36     -87    60
# Comp:  1                Halpha      3.829      0.36     -87    60
# Comp:  2             [SII]6716      2.154      0.40    -121    94
# Comp:  2             [SII]6731     0.9081      0.40    -121    94
# Comp:  2              HeII4687      0.000      0.40    -121    94
# Comp:  2               HeI5876     0.1210      0.40    -121    94
# Comp:  2          [OIII]5007_d      1.990      0.51    -121    94
# Comp:  2            [OI]6300_d     0.6794      0.51    -121    94
# Comp:  2           [NII]6583_d      1.519      0.51    -121    94
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86        40
#  comp.  1:       -74        57
#  comp.  2:       -88        76
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8856      0.35     -74    57
# Comp:  1                Halpha      3.620      0.35     -74    57
# Comp:  2             [SII]6716      1.569      0.38     -88    76
# Comp:  2             [SII]6731     0.8455      0.38     -88    76
# Comp:  2              HeII4687     0.4052      0.38     -88    76
# Comp:  2               HeI5876     0.4601      0.38     -88    76
# Comp:  2          [OIII]5007_d      1.287      0.48     -88    76
# Comp:  2            [OI]6300_d     0.9395      0.48     -88    76
# Comp:  2           [NII]6583_d      1.486      0.48     -88    76
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:       -73        55
#  comp.  2:      -103        89
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.545      0.35     -73    55
# Comp:  1                Halpha      3.694      0.35     -73    55
# Comp:  2             [SII]6716      2.147      0.40    -103    89
# Comp:  2             [SII]6731     0.9413      0.40    -103    89
# Comp:  2              HeII4687    0.01181      0.40    -103    89
# Comp:  2               HeI5876     0.2473      0.40    -103    89
# Comp:  2          [OIII]5007_d      1.840      0.50    -103    89
# Comp:  2            [OI]6300_d      1.095      0.50    -103    89
# Comp:  2           [NII]6583_d      1.761      0.50    -103    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:       -83        59
#  comp.  2:       -71       104
# chi2/DOF: 1.018; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.351      0.36     -83    59
# Comp:  1                Halpha      4.064      0.36     -83    59
# Comp:  2             [SII]6716      2.065      0.42     -71   104
# Comp:  2             [SII]6731      1.202      0.42     -71   104
# Comp:  2              HeII4687     0.8460      0.42     -71   104
# Comp:  2               HeI5876      0.000      0.42     -71   104
# Comp:  2          [OIII]5007_d      1.344      0.53     -71   104
# Comp:  2            [OI]6300_d     0.8920      0.53     -71   104
# Comp:  2           [NII]6583_d      1.725      0.53     -71   104
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:       -78        53
#  comp.  2:      -108        99
# chi2/DOF: 1.021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.396      0.35     -78    53
# Comp:  1                Halpha      3.647      0.35     -78    53
# Comp:  2             [SII]6716      1.957      0.41    -108    99
# Comp:  2             [SII]6731     0.9590      0.41    -108    99
# Comp:  2              HeII4687    0.01349      0.41    -108    99
# Comp:  2               HeI5876    0.08971      0.41    -108    99
# Comp:  2          [OIII]5007_d     0.8012      0.52    -108    99
# Comp:  2            [OI]6300_d     0.6855      0.52    -108    99
# Comp:  2           [NII]6583_d      1.596      0.52    -108    99
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98       107
#  comp.  1:       -80        60
#  comp.  2:       -84        90
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.370      0.36     -80    60
# Comp:  1                Halpha      3.726      0.36     -80    60
# Comp:  2             [SII]6716      2.050      0.40     -84    90
# Comp:  2             [SII]6731      1.084      0.40     -84    90
# Comp:  2              HeII4687     0.8171      0.40     -84    90
# Comp:  2               HeI5876      0.000      0.40     -84    90
# Comp:  2          [OIII]5007_d     0.7948      0.50     -84    90
# Comp:  2            [OI]6300_d     0.7213      0.50     -84    90
# Comp:  2           [NII]6583_d     0.9152      0.50     -84    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:       -71        55
#  comp.  2:       -99        95
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9036      0.35     -71    55
# Comp:  1                Halpha      3.522      0.35     -71    55
# Comp:  2             [SII]6716      1.782      0.41     -99    95
# Comp:  2             [SII]6731     0.9165      0.41     -99    95
# Comp:  2              HeII4687     0.3738      0.41     -99    95
# Comp:  2               HeI5876      0.000      0.41     -99    95
# Comp:  2          [OIII]5007_d      2.002      0.51     -99    95
# Comp:  2            [OI]6300_d      1.006      0.51     -99    95
# Comp:  2           [NII]6583_d      1.408      0.51     -99    95
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         1
#  comp.  1:       -81        48
#  comp.  2:       -69        82
# chi2/DOF: 1.013; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9316      0.34     -81    48
# Comp:  1                Halpha      3.695      0.34     -81    48
# Comp:  2             [SII]6716      1.767      0.39     -69    82
# Comp:  2             [SII]6731      1.020      0.39     -69    82
# Comp:  2              HeII4687    0.09441      0.39     -69    82
# Comp:  2               HeI5876     0.6294      0.39     -69    82
# Comp:  2          [OIII]5007_d      1.065      0.49     -69    82
# Comp:  2            [OI]6300_d     0.7228      0.49     -69    82
# Comp:  2           [NII]6583_d      1.426      0.49     -69    82
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:       -72        57
#  comp.  2:       -77       103
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.307      0.35     -72    57
# Comp:  1                Halpha      3.558      0.35     -72    57
# Comp:  2             [SII]6716      1.985      0.42     -77   103
# Comp:  2             [SII]6731      1.032      0.42     -77   103
# Comp:  2              HeII4687      0.000      0.42     -77   103
# Comp:  2               HeI5876      0.000      0.42     -77   103
# Comp:  2          [OIII]5007_d     0.8703      0.53     -77   103
# Comp:  2            [OI]6300_d     0.9193      0.53     -77   103
# Comp:  2           [NII]6583_d      1.706      0.53     -77   103
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        40
#  comp.  1:       -78        56
#  comp.  2:       -97        88
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7246      0.35     -78    56
# Comp:  1                Halpha      3.420      0.35     -78    56
# Comp:  2             [SII]6716      1.972      0.40     -97    88
# Comp:  2             [SII]6731     0.9679      0.40     -97    88
# Comp:  2              HeII4687      0.000      0.40     -97    88
# Comp:  2               HeI5876      0.000      0.40     -97    88
# Comp:  2          [OIII]5007_d      1.181      0.50     -97    88
# Comp:  2            [OI]6300_d      1.188      0.50     -97    88
# Comp:  2           [NII]6583_d      1.373      0.50     -97    88
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83         1
#  comp.  1:       -71        48
#  comp.  2:      -127        96
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6529      0.34     -71    48
# Comp:  1                Halpha      3.415      0.34     -71    48
# Comp:  2             [SII]6716      2.077      0.41    -127    96
# Comp:  2             [SII]6731     0.9467      0.41    -127    96
# Comp:  2              HeII4687      0.000      0.41    -127    96
# Comp:  2               HeI5876      0.000      0.41    -127    96
# Comp:  2          [OIII]5007_d      1.344      0.52    -127    96
# Comp:  2            [OI]6300_d     0.8636      0.52    -127    96
# Comp:  2           [NII]6583_d      1.223      0.52    -127    96
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       -75        59
#  comp.  2:       -95        89
# chi2/DOF: 1.013; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.6316      0.36     -75    59
# Comp:  1                Halpha      3.591      0.36     -75    59
# Comp:  2             [SII]6716      2.054      0.40     -95    89
# Comp:  2             [SII]6731     0.9566      0.40     -95    89
# Comp:  2              HeII4687     0.6971      0.40     -95    89
# Comp:  2               HeI5876      0.000      0.40     -95    89
# Comp:  2          [OIII]5007_d      1.515      0.50     -95    89
# Comp:  2            [OI]6300_d     0.9525      0.50     -95    89
# Comp:  2           [NII]6583_d      1.019      0.50     -95    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:       -77        62
#  comp.  2:       -92        71
# chi2/DOF: 1.018; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.231      0.36     -77    62
# Comp:  1                Halpha      3.763      0.36     -77    62
# Comp:  2             [SII]6716      1.844      0.37     -92    71
# Comp:  2             [SII]6731     0.8969      0.37     -92    71
# Comp:  2              HeII4687      0.000      0.37     -92    71
# Comp:  2               HeI5876     0.4972      0.37     -92    71
# Comp:  2          [OIII]5007_d     0.8292      0.47     -92    71
# Comp:  2            [OI]6300_d     0.7523      0.47     -92    71
# Comp:  2           [NII]6583_d      1.625      0.47     -92    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81        66
#  comp.  1:       -74        50
#  comp.  2:       -86        90
# chi2/DOF: 1.013; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.3221      0.34     -74    50
# Comp:  1                Halpha      3.541      0.34     -74    50
# Comp:  2             [SII]6716      1.947      0.40     -86    90
# Comp:  2             [SII]6731     0.8075      0.40     -86    90
# Comp:  2              HeII4687      0.000      0.40     -86    90
# Comp:  2               HeI5876     0.3106      0.40     -86    90
# Comp:  2          [OIII]5007_d      1.115      0.50     -86    90
# Comp:  2            [OI]6300_d     0.8644      0.50     -86    90
# Comp:  2           [NII]6583_d      1.221      0.50     -86    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        55
#  comp.  1:       -73        60
#  comp.  2:      -102        76
# chi2/DOF: 1.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8769      0.36     -73    60
# Comp:  1                Halpha      3.737      0.36     -73    60
# Comp:  2             [SII]6716      1.996      0.38    -102    76
# Comp:  2             [SII]6731     0.9819      0.38    -102    76
# Comp:  2              HeII4687     0.2247      0.38    -102    76
# Comp:  2               HeI5876      0.000      0.38    -102    76
# Comp:  2          [OIII]5007_d     0.6522      0.48    -102    76
# Comp:  2            [OI]6300_d     0.7239      0.48    -102    76
# Comp:  2           [NII]6583_d      1.354      0.48    -102    76
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99         1
#  comp.  1:       -83        66
#  comp.  2:      -115        98
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.377      0.37     -83    66
# Comp:  1                Halpha      3.567      0.37     -83    66
# Comp:  2             [SII]6716      2.273      0.41    -115    98
# Comp:  2             [SII]6731     0.8420      0.41    -115    98
# Comp:  2              HeII4687      0.000      0.41    -115    98
# Comp:  2               HeI5876      0.000      0.41    -115    98
# Comp:  2          [OIII]5007_d      1.561      0.52    -115    98
# Comp:  2            [OI]6300_d      1.040      0.52    -115    98
# Comp:  2           [NII]6583_d      1.630      0.52    -115    98
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        15
#  comp.  1:       -77        62
#  comp.  2:       -77        98
# chi2/DOF: 1.018; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8674      0.36     -77    62
# Comp:  1                Halpha      3.474      0.36     -77    62
# Comp:  2             [SII]6716      1.791      0.41     -77    98
# Comp:  2             [SII]6731     0.8956      0.41     -77    98
# Comp:  2              HeII4687     0.2849      0.41     -77    98
# Comp:  2               HeI5876      0.000      0.41     -77    98
# Comp:  2          [OIII]5007_d     0.6763      0.52     -77    98
# Comp:  2            [OI]6300_d     0.6953      0.52     -77    98
# Comp:  2           [NII]6583_d      1.257      0.52     -77    98
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        52
#  comp.  1:       -74        62
#  comp.  2:       -81        81
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.066      0.36     -74    62
# Comp:  1                Halpha      3.706      0.36     -74    62
# Comp:  2             [SII]6716      1.925      0.39     -81    81
# Comp:  2             [SII]6731     0.8382      0.39     -81    81
# Comp:  2              HeII4687     0.3740      0.39     -81    81
# Comp:  2               HeI5876    0.05866      0.39     -81    81
# Comp:  2          [OIII]5007_d      1.302      0.49     -81    81
# Comp:  2            [OI]6300_d     0.7624      0.49     -81    81
# Comp:  2           [NII]6583_d      1.209      0.49     -81    81
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        27
#  comp.  1:       -68        57
#  comp.  2:       -71        74
# chi2/DOF: 1.015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.5287      0.35     -68    57
# Comp:  1                Halpha      3.540      0.35     -68    57
# Comp:  2             [SII]6716      1.814      0.38     -71    74
# Comp:  2             [SII]6731     0.8495      0.38     -71    74
# Comp:  2              HeII4687     0.2147      0.38     -71    74
# Comp:  2               HeI5876     0.4521      0.38     -71    74
# Comp:  2          [OIII]5007_d      1.334      0.48     -71    74
# Comp:  2            [OI]6300_d      1.005      0.48     -71    74
# Comp:  2           [NII]6583_d      1.710      0.48     -71    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84         1
#  comp.  1:       -76        70
#  comp.  2:       -72        68
# chi2/DOF: 1.015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.139      0.37     -76    70
# Comp:  1                Halpha      3.848      0.37     -76    70
# Comp:  2             [SII]6716      1.729      0.37     -72    68
# Comp:  2             [SII]6731     0.8569      0.37     -72    68
# Comp:  2              HeII4687      0.000      0.37     -72    68
# Comp:  2               HeI5876     0.5964      0.37     -72    68
# Comp:  2          [OIII]5007_d      1.756      0.47     -72    68
# Comp:  2            [OI]6300_d     0.9161      0.47     -72    68
# Comp:  2           [NII]6583_d      1.121      0.47     -72    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -102        33
#  comp.  1:       -83        66
#  comp.  2:       -84        92
# chi2/DOF: 1.015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7297      0.37     -83    66
# Comp:  1                Halpha      3.599      0.37     -83    66
# Comp:  2             [SII]6716      2.123      0.40     -84    92
# Comp:  2             [SII]6731     0.8915      0.40     -84    92
# Comp:  2              HeII4687    0.02615      0.40     -84    92
# Comp:  2               HeI5876      0.000      0.40     -84    92
# Comp:  2          [OIII]5007_d      1.346      0.51     -84    92
# Comp:  2            [OI]6300_d     0.8580      0.51     -84    92
# Comp:  2           [NII]6583_d      1.423      0.51     -84    92
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79         1
#  comp.  1:       -77        45
#  comp.  2:      -107        85
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.7834      0.34     -77    45
# Comp:  1                Halpha      3.237      0.34     -77    45
# Comp:  2             [SII]6716      1.621      0.39    -107    85
# Comp:  2             [SII]6731     0.9434      0.39    -107    85
# Comp:  2              HeII4687      0.000      0.39    -107    85
# Comp:  2               HeI5876      0.000      0.39    -107    85
# Comp:  2          [OIII]5007_d      1.904      0.49    -107    85
# Comp:  2            [OI]6300_d      1.039      0.49    -107    85
# Comp:  2           [NII]6583_d      1.396      0.49    -107    85
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        29
#  comp.  1:       -71        61
#  comp.  2:       -86        77
# chi2/DOF: 1.010; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.443      0.36     -71    61
# Comp:  1                Halpha      3.908      0.36     -71    61
# Comp:  2             [SII]6716      1.631      0.38     -86    77
# Comp:  2             [SII]6731     0.8637      0.38     -86    77
# Comp:  2              HeII4687     0.1152      0.38     -86    77
# Comp:  2               HeI5876     0.6027      0.38     -86    77
# Comp:  2          [OIII]5007_d      1.336      0.48     -86    77
# Comp:  2            [OI]6300_d     0.8792      0.48     -86    77
# Comp:  2           [NII]6583_d      1.144      0.48     -86    77
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -76        54
#  comp.  2:       -97        99
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.225      0.35     -76    54
# Comp:  1                Halpha      3.515      0.35     -76    54
# Comp:  2             [SII]6716      1.897      0.41     -97    99
# Comp:  2             [SII]6731      1.056      0.41     -97    99
# Comp:  2              HeII4687      0.000      0.41     -97    99
# Comp:  2               HeI5876    0.09723      0.41     -97    99
# Comp:  2          [OIII]5007_d      1.182      0.52     -97    99
# Comp:  2            [OI]6300_d      1.080      0.52     -97    99
# Comp:  2           [NII]6583_d      1.359      0.52     -97    99
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        19
#  comp.  1:       -73        70
#  comp.  2:       -91        84
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.725      0.37     -73    70
# Comp:  1                Halpha      4.263      0.37     -73    70
# Comp:  2             [SII]6716      1.667      0.39     -91    84
# Comp:  2             [SII]6731     0.8196      0.39     -91    84
# Comp:  2              HeII4687    0.03113      0.39     -91    84
# Comp:  2               HeI5876     0.4820      0.39     -91    84
# Comp:  2          [OIII]5007_d      1.021      0.49     -91    84
# Comp:  2            [OI]6300_d      1.088      0.49     -91    84
# Comp:  2           [NII]6583_d      1.366      0.49     -91    84
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74         1
#  comp.  1:       -77        60
#  comp.  2:      -124       104
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.472      0.36     -77    60
# Comp:  1                Halpha      3.936      0.36     -77    60
# Comp:  2             [SII]6716      2.191      0.42    -124   104
# Comp:  2             [SII]6731     0.9871      0.42    -124   104
# Comp:  2              HeII4687     0.1836      0.42    -124   104
# Comp:  2               HeI5876      0.000      0.42    -124   104
# Comp:  2          [OIII]5007_d      1.696      0.53    -124   104
# Comp:  2            [OI]6300_d     0.6170      0.53    -124   104
# Comp:  2           [NII]6583_d      1.538      0.53    -124   104
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77        19
#  comp.  1:       -69        51
#  comp.  2:      -103        74
# chi2/DOF: 1.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.177      0.35     -69    51
# Comp:  1                Halpha      3.478      0.35     -69    51
# Comp:  2             [SII]6716      1.878      0.38    -103    74
# Comp:  2             [SII]6731      1.022      0.38    -103    74
# Comp:  2              HeII4687    0.05598      0.38    -103    74
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.392      0.35     -82    54
# Comp:  1                Halpha      3.932      0.35     -82    54
# Comp:  2             [SII]6716      2.129      0.45     -70   122
# Comp:  2             [SII]6731     0.9888      0.45     -70   122
# Comp:  2              HeII4687     0.6497      0.45     -70   122
# Comp:  2               HeI5876      0.000      0.45     -70   122
# Comp:  2          [OIII]5007_d      1.346      0.56     -70   122
# Comp:  2            [OI]6300_d      1.211      0.56     -70   122
# Comp:  2           [NII]6583_d      1.529      0.56     -70   122
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70        15
#  comp.  1:       -77        51
#  comp.  2:       -97        96
# chi2/DOF: 1.015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.363      0.35     -77    51
# Comp:  1                Halpha      3.841      0.35     -77    51
# Comp:  2             [SII]6716      2.185      0.41     -97    96
# Comp:  2             [SII]6731      1.023      0.41     -97    96
# Comp:  2              HeII4687     0.2101      0.41     -97    96
# Comp:  2               HeI5876      0.000      0.41     -97    96
# Comp:  2          [OIII]5007_d     0.9099      0.52     -97    96
# Comp:  2            [OI]6300_d      1.154      0.52     -97    96
# Comp:  2           [NII]6583_d      1.328      0.52     -97    96
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        24
#  comp.  1:       -65        57
#  comp.  2:       -90        87
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.174      0.35     -65    57
# Comp:  1                Halpha      3.563      0.35     -65    57
# Comp:  2             [SII]6716      1.914      0.39     -90    87
# Comp:  2             [SII]6731      1.043      0.39     -90    87
# Comp:  2              HeII4687     0.2583      0.39     -90    87
# Comp:  2               HeI5876      0.000      0.39     -90    87
# Comp:  2          [OIII]5007_d      1.670      0.50     -90    87
# Comp:  2            [OI]6300_d     0.8420      0.50     -90    87
# Comp:  2           [NII]6583_d      1.361      0.50     -90    87
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        44
#  comp.  1:       -78        65
#  comp.  2:       -82        79
# chi2/DOF: 1.018; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.033      0.36     -78    65
# Comp:  1                Halpha      3.822      0.36     -78    65
# Comp:  2             [SII]6716      1.841      0.38     -82    79
# Comp:  2             [SII]6731     0.9910      0.38     -82    79
# Comp:  2              HeII4687      0.000      0.38     -82    79
# Comp:  2               HeI5876     0.5652      0.38     -82    79
# Comp:  2          [OIII]5007_d      1.253      0.49     -82    79
# Comp:  2            [OI]6300_d     0.5947      0.49     -82    79
# Comp:  2           [NII]6583_d      1.403      0.49     -82    79
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       -71        56
#  comp.  2:       -89       111
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.472      0.35     -71    56
# Comp:  1                Halpha      3.807      0.35     -71    56
# Comp:  2             [SII]6716      2.283      0.43     -89   111
# Comp:  2             [SII]6731      1.093      0.43     -89   111
# Comp:  2              HeII4687     0.7373      0.43     -89   111
# Comp:  2               HeI5876     0.8193      0.43     -89   111
# Comp:  2          [OIII]5007_d      1.576      0.54     -89   111
# Comp:  2            [OI]6300_d      1.431      0.54     -89   111
# Comp:  2           [NII]6583_d      1.526      0.54     -89   111
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:       -76        73
#  comp.  2:      -115       123
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.555      0.38     -76    73
# Comp:  1                Halpha      3.944      0.38     -76    73
# Comp:  2             [SII]6716      2.375      0.45    -115   123
# Comp:  2             [SII]6731      1.206      0.45    -115   123
# Comp:  2              HeII4687      0.000      0.45    -115   123
# Comp:  2               HeI5876     0.4517      0.45    -115   123
# Comp:  2          [OIII]5007_d      1.714      0.56    -115   123
# Comp:  2            [OI]6300_d     0.9581      0.56    -115   123
# Comp:  2           [NII]6583_d      2.165      0.56    -115   123
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:       -78        54
#  comp.  2:      -114        93
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8592      0.35     -78    54
# Comp:  1                Halpha      3.608      0.35     -78    54
# Comp:  2             [SII]6716      2.186      0.40    -114    93
# Comp:  2             [SII]6731     0.8714      0.40    -114    93
# Comp:  2              HeII4687      0.000      0.40    -114    93
# Comp:  2               HeI5876     0.2911      0.40    -114    93
# Comp:  2          [OIII]5007_d     0.8517      0.51    -114    93
# Comp:  2            [OI]6300_d      1.100      0.51    -114    93
# Comp:  2           [NII]6583_d      1.590      0.51    -114    93
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67         1
#  comp.  1:       -67        51
#  comp.  2:       -85        87
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.363      0.35     -67    51
# Comp:  1                Halpha      3.661      0.35     -67    51
# Comp:  2             [SII]6716      1.592      0.40     -85    87
# Comp:  2             [SII]6731     0.9717      0.40     -85    87
# Comp:  2              HeII4687     0.7878      0.40     -85    87
# Comp:  2               HeI5876     0.7064      0.40     -85    87
# Comp:  2          [OIII]5007_d      1.307      0.50     -85    87
# Comp:  2            [OI]6300_d     0.9847      0.50     -85    87
# Comp:  2           [NII]6583_d      1.436      0.50     -85    87
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84         1
#  comp.  1:       -86        55
#  comp.  2:       -85        85
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9526      0.35     -86    55
# Comp:  1                Halpha      3.892      0.35     -86    55
# Comp:  2             [SII]6716      2.076      0.39     -85    85
# Comp:  2             [SII]6731     0.9528      0.39     -85    85
# Comp:  2              HeII4687      0.000      0.39     -85    85
# Comp:  2               HeI5876     0.4678      0.39     -85    85
# Comp:  2          [OIII]5007_d      1.168      0.50     -85    85
# Comp:  2            [OI]6300_d     0.9030      0.50     -85    85
# Comp:  2           [NII]6583_d      1.816      0.50     -85    85
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        41
#  comp.  1:       -77        53
#  comp.  2:       -92        81
# chi2/DOF: 1.019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.069      0.35     -77    53
# Comp:  1                Halpha      3.795      0.35     -77    53
# Comp:  2             [SII]6716      1.782      0.39     -92    81
# Comp:  2             [SII]6731     0.9094      0.39     -92    81
# Comp:  2              HeII4687    0.04796      0.39     -92    81
# Comp:  2               HeI5876    0.06260      0.39     -92    81
# Comp:  2          [OIII]5007_d      1.334      0.49     -92    81
# Comp:  2            [OI]6300_d     0.9247      0.49     -92    81
# Comp:  2           [NII]6583_d      1.048      0.49     -92    81
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72        31
#  comp.  1:       -81        58
#  comp.  2:       -80        87
# chi2/DOF: 1.019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.422      0.35     -81    58
# Comp:  1                Halpha      3.745      0.35     -81    58
# Comp:  2             [SII]6716      1.973      0.39     -80    87
# Comp:  2             [SII]6731     0.8278      0.39     -80    87
# Comp:  2              HeII4687     0.1932      0.39     -80    87
# Comp:  2               HeI5876     0.5651      0.39     -80    87
# Comp:  2          [OIII]5007_d     0.8747      0.50     -80    87
# Comp:  2            [OI]6300_d     0.7296      0.50     -80    87
# Comp:  2           [NII]6583_d      1.235      0.50     -80    87
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80        10
#  comp.  1:       -70        44
#  comp.  2:       -94        63
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.2794      0.34     -70    44
# Comp:  1                Halpha      3.012      0.34     -70    44
# Comp:  2             [SII]6716      1.655      0.36     -94    63
# Comp:  2             [SII]6731     0.7414      0.36     -94    63
# Comp:  2              HeII4687    0.07388      0.36     -94    63
# Comp:  2               HeI5876     0.4664      0.36     -94    63
# Comp:  2          [OIII]5007_d      1.568      0.46     -94    63
# Comp:  2            [OI]6300_d     0.5836      0.46     -94    63
# Comp:  2           [NII]6583_d      1.433      0.46     -94    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        56
#  comp.  1:       -73        54
#  comp.  2:       -87        91
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9651      0.35     -73    54
# Comp:  1                Halpha      3.597      0.35     -73    54
# Comp:  2             [SII]6716      1.840      0.40     -87    91
# Comp:  2             [SII]6731     0.9103      0.40     -87    91
# Comp:  2              HeII4687      0.000      0.40     -87    91
# Comp:  2               HeI5876     0.9787      0.40     -87    91
# Comp:  2          [OIII]5007_d     0.5196      0.51     -87    91
# Comp:  2            [OI]6300_d     0.7371      0.51     -87    91
# Comp:  2           [NII]6583_d      1.964      0.51     -87    91
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:       -78        51
#  comp.  2:       -85        92
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.739      0.35     -78    51
# Comp:  1                Halpha      4.029      0.35     -78    51
# Comp:  2             [SII]6716      1.736      0.40     -85    92
# Comp:  2             [SII]6731      1.043      0.40     -85    92
# Comp:  2              HeII4687     0.2376      0.40     -85    92
# Comp:  2               HeI5876    0.08293      0.40     -85    92
# Comp:  2          [OIII]5007_d      1.343      0.51     -85    92
# Comp:  2            [OI]6300_d      1.227      0.51     -85    92
# Comp:  2           [NII]6583_d      1.949      0.51     -85    92
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.3711944 , 0.36095678, 0.30983824, 0.16040066, 0.23527026,
#        0.34055413, 0.40985386, 0.30001311, 0.34266185])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([0.91529537, 4.86055961, 2.73970089, 1.35642649, 0.07802194,
#        0.10233935, 1.37148703, 1.18505111, 1.97986733])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_13_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_13", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_13_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_13_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_13_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.034648    0.014051
# 1        Halpha  0.183994    0.013664
# 2     [SII]6716  0.103710    0.011729
# 3     [SII]6731  0.051347    0.006072
# 4      HeII4687  0.002953    0.008906
# 5       HeI5876  0.003874    0.012892
# 6  [OIII]5007_d  0.051917    0.015515
# 7    [OI]6300_d  0.044860    0.011357
# 8   [NII]6583_d  0.074947    0.012971
#           Name      Flux  Error_flux
# 0        Hbeta  0.034648    0.014051
# 1       Halpha  0.183994    0.013664
# 2    [SII]6716  0.103710    0.011729
# 3    [SII]6731  0.051347    0.006072
# 4     HeII4687  0.002953    0.008906
# 5      HeI5876  0.003874    0.012892
# 6   [OIII]4959  0.012979    0.015515
# 7   [OIII]5007  0.038938    0.015515
# 8     [OI]6300  0.033645    0.011357
# 9     [OI]6364  0.011215    0.011357
# 10   [NII]6548  0.018737    0.012971
# 11   [NII]6583  0.056210    0.012971

# %%
np.median(flux_rf_rebin)
# Out:
# 0.037854508929317215
