# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/Gradient/redshift_grad.txt", unpack = True)
z = 0.00189 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_2']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.02562966 0.01570156 0.01686229 ... 0.01765765 0.01770521 0.01636911] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -72       126
# chi2/DOF: 0.1021; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 18; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:      -123       157
# chi2/DOF: 0.07055; DOF: 1916; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 18; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-123.35510206,  157.16828145])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -61       134
#  comp.  1:        71       118
#  comp.  2:      -115        87
# chi2/DOF: 1.091; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.741      0.95      71   118
# Comp:  1                Halpha      0.000      0.95      71   118
# Comp:  2             [SII]6716      1.917      0.85    -115    87
# Comp:  2             [SII]6731      0.000      0.85    -115    87
# Comp:  2              HeII4687      1.171      0.85    -115    87
# Comp:  2               HeI5876      0.000      0.85    -115    87
# Comp:  2          [OIII]5007_d      1.237       1.1    -115    87
# Comp:  2            [OI]6300_d     0.4023       1.1    -115    87
# Comp:  2           [NII]6583_d     0.5874       1.1    -115    87
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  1.135; gas flux:      2 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  1.556; gas flux:      3 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.9633; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  0.767; gas flux:      1 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.2451; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise: 0.3532; gas flux:      1 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -89       144
#  comp.  1:       364         1
#  comp.  2:      -132        28
# chi2/DOF: 1.081; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.623      0.66     364     1
# Comp:  1                Halpha    0.03259      0.66     364     1
# Comp:  2             [SII]6716      1.545      0.69    -132    28
# Comp:  2             [SII]6731      0.000      0.69    -132    28
# Comp:  2              HeII4687     0.8612      0.69    -132    28
# Comp:  2               HeI5876     0.4595      0.69    -132    28
# Comp:  2          [OIII]5007_d      1.253      0.87    -132    28
# Comp:  2            [OI]6300_d      1.014      0.87    -132    28
# Comp:  2           [NII]6583_d     0.2687      0.87    -132    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87       206
#  comp.  1:        59         1
#  comp.  2:       -86       115
# chi2/DOF: 1.077; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.566      0.66      59     1
# Comp:  1                Halpha     0.1475      0.66      59     1
# Comp:  2             [SII]6716      1.645      0.94     -86   115
# Comp:  2             [SII]6731      0.000      0.94     -86   115
# Comp:  2              HeII4687      1.899      0.94     -86   115
# Comp:  2               HeI5876      1.551      0.94     -86   115
# Comp:  2          [OIII]5007_d     0.7439       1.2     -86   115
# Comp:  2            [OI]6300_d      0.000       1.2     -86   115
# Comp:  2           [NII]6583_d     0.6982       1.2     -86   115
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -110       193
#  comp.  1:        56        40
#  comp.  2:      -158        99
# chi2/DOF: 1.083; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8426      0.72      56    40
# Comp:  1                Halpha     0.3015      0.72      56    40
# Comp:  2             [SII]6716     0.7029      0.89    -158    99
# Comp:  2             [SII]6731     0.2207      0.89    -158    99
# Comp:  2              HeII4687     0.8329      0.89    -158    99
# Comp:  2               HeI5876      0.000      0.89    -158    99
# Comp:  2          [OIII]5007_d      1.374       1.1    -158    99
# Comp:  2            [OI]6300_d      2.093       1.1    -158    99
# Comp:  2           [NII]6583_d     0.3691       1.1    -158    99
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        86
#  comp.  1:       102       157
#  comp.  2:       -74        58
# chi2/DOF: 1.076; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.503       1.1     102   157
# Comp:  1                Halpha      1.300       1.1     102   157
# Comp:  2             [SII]6716      2.680      0.77     -74    58
# Comp:  2             [SII]6731      0.000      0.77     -74    58
# Comp:  2              HeII4687     0.7328      0.77     -74    58
# Comp:  2               HeI5876      1.617      0.77     -74    58
# Comp:  2          [OIII]5007_d      1.265      0.97     -74    58
# Comp:  2            [OI]6300_d      0.000      0.97     -74    58
# Comp:  2           [NII]6583_d     0.9916      0.97     -74    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -145         1
#  comp.  1:      -169       236
#  comp.  2:       -92        99
# chi2/DOF: 1.078; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.688       1.3    -169   236
# Comp:  1                Halpha      1.096       1.3    -169   236
# Comp:  2             [SII]6716      1.993      0.89     -92    99
# Comp:  2             [SII]6731     0.3600      0.89     -92    99
# Comp:  2              HeII4687      1.266      0.89     -92    99
# Comp:  2               HeI5876     0.4405      0.89     -92    99
# Comp:  2          [OIII]5007_d      1.981       1.1     -92    99
# Comp:  2            [OI]6300_d      2.768       1.1     -92    99
# Comp:  2           [NII]6583_d     0.8390       1.1     -92    99
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        95
#  comp.  1:        99       223
#  comp.  2:      -134        93
# chi2/DOF: 1.083; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.213       1.2      99   223
# Comp:  1                Halpha      1.476       1.2      99   223
# Comp:  2             [SII]6716      3.076      0.87    -134    93
# Comp:  2             [SII]6731      0.000      0.87    -134    93
# Comp:  2              HeII4687      1.505      0.87    -134    93
# Comp:  2               HeI5876     0.3080      0.87    -134    93
# Comp:  2          [OIII]5007_d     0.3932       1.1    -134    93
# Comp:  2            [OI]6300_d      2.055       1.1    -134    93
# Comp:  2           [NII]6583_d     0.4669       1.1    -134    93
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -150        82
#  comp.  1:       -86       320
#  comp.  2:      -192       119
# chi2/DOF: 1.079; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.128       1.5     -86   320
# Comp:  1                Halpha      1.007       1.5     -86   320
# Comp:  2             [SII]6716      1.775      0.95    -192   119
# Comp:  2             [SII]6731     0.3178      0.95    -192   119
# Comp:  2              HeII4687      1.282      0.95    -192   119
# Comp:  2               HeI5876      0.000      0.95    -192   119
# Comp:  2          [OIII]5007_d      1.643       1.2    -192   119
# Comp:  2            [OI]6300_d      2.727       1.2    -192   119
# Comp:  2           [NII]6583_d     0.6871       1.2    -192   119
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -183        53
#  comp.  1:       -26       107
#  comp.  2:        -7         1
# chi2/DOF: 1.082; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 81; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.577      0.91     -26   107
# Comp:  1                Halpha      0.000      0.91     -26   107
# Comp:  2             [SII]6716      1.028      0.66      -7     1
# Comp:  2             [SII]6731      0.000      0.66      -7     1
# Comp:  2              HeII4687     0.2589      0.66      -7     1
# Comp:  2               HeI5876     0.8296      0.66      -7     1
# Comp:  2          [OIII]5007_d     0.3810      0.84      -7     1
# Comp:  2            [OI]6300_d     0.9738      0.84      -7     1
# Comp:  2           [NII]6583_d     0.3169      0.84      -7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72       105
#  comp.  1:       335       110
#  comp.  2:       -77        90
# chi2/DOF: 1.085; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.030      0.92     335   110
# Comp:  1                Halpha     0.3779      0.92     335   110
# Comp:  2             [SII]6716     0.9192      0.86     -77    90
# Comp:  2             [SII]6731      0.000      0.86     -77    90
# Comp:  2              HeII4687      1.281      0.86     -77    90
# Comp:  2               HeI5876     0.4482      0.86     -77    90
# Comp:  2          [OIII]5007_d      1.334       1.1     -77    90
# Comp:  2            [OI]6300_d      0.000       1.1     -77    90
# Comp:  2           [NII]6583_d     0.2466       1.1     -77    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22       139
#  comp.  1:        43       115
#  comp.  2:      -111       111
# chi2/DOF: 1.081; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.573      0.94      43   115
# Comp:  1                Halpha     0.5863      0.94      43   115
# Comp:  2             [SII]6716      1.121      0.92    -111   111
# Comp:  2             [SII]6731     0.3006      0.92    -111   111
# Comp:  2              HeII4687      1.077      0.92    -111   111
# Comp:  2               HeI5876      1.564      0.92    -111   111
# Comp:  2          [OIII]5007_d      1.374       1.2    -111   111
# Comp:  2            [OI]6300_d      2.444       1.2    -111   111
# Comp:  2           [NII]6583_d     0.4915       1.2    -111   111
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        11       108
#  comp.  1:        81        67
#  comp.  2:       -74        75
# chi2/DOF: 1.086; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.470      0.79      81    67
# Comp:  1                Halpha     0.8610      0.79      81    67
# Comp:  2             [SII]6716      2.944      0.82     -74    75
# Comp:  2             [SII]6731     0.6602      0.82     -74    75
# Comp:  2              HeII4687     0.8849      0.82     -74    75
# Comp:  2               HeI5876      1.361      0.82     -74    75
# Comp:  2          [OIII]5007_d     0.4965       1.0     -74    75
# Comp:  2            [OI]6300_d     0.4407       1.0     -74    75
# Comp:  2           [NII]6583_d     0.6635       1.0     -74    75
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -106       137
#  comp.  1:         4       179
#  comp.  2:      -110        78
# chi2/DOF: 1.088; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.874       1.1       4   179
# Comp:  1                Halpha      0.000       1.1       4   179
# Comp:  2             [SII]6716      2.416      0.82    -110    78
# Comp:  2             [SII]6731     0.4275      0.82    -110    78
# Comp:  2              HeII4687      1.038      0.82    -110    78
# Comp:  2               HeI5876      0.000      0.82    -110    78
# Comp:  2          [OIII]5007_d      1.488       1.0    -110    78
# Comp:  2            [OI]6300_d      1.096       1.0    -110    78
# Comp:  2           [NII]6583_d    0.05635       1.0    -110    78
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -154       119
#  comp.  1:       -98        67
#  comp.  2:       -78        69
# chi2/DOF: 1.079; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.450      0.79     -98    67
# Comp:  1                Halpha     0.7378      0.79     -98    67
# Comp:  2             [SII]6716      1.313      0.80     -78    69
# Comp:  2             [SII]6731     0.2132      0.80     -78    69
# Comp:  2              HeII4687      1.156      0.80     -78    69
# Comp:  2               HeI5876      1.627      0.80     -78    69
# Comp:  2          [OIII]5007_d      1.087       1.0     -78    69
# Comp:  2            [OI]6300_d      1.331       1.0     -78    69
# Comp:  2           [NII]6583_d     0.1185       1.0     -78    69
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        92
#  comp.  1:        47        76
#  comp.  2:       -95        50
# chi2/DOF: 1.085; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.919      0.82      47    76
# Comp:  1                Halpha     0.3662      0.82      47    76
# Comp:  2             [SII]6716      2.728      0.74     -95    50
# Comp:  2             [SII]6731     0.2820      0.74     -95    50
# Comp:  2              HeII4687     0.7413      0.74     -95    50
# Comp:  2               HeI5876      0.000      0.74     -95    50
# Comp:  2          [OIII]5007_d     0.7933      0.94     -95    50
# Comp:  2            [OI]6300_d     0.2424      0.94     -95    50
# Comp:  2           [NII]6583_d     0.6211      0.94     -95    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        70        13
#  comp.  1:       115       193
#  comp.  2:      -102       110
# chi2/DOF: 1.074; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.403       1.2     115   193
# Comp:  1                Halpha      2.583       1.2     115   193
# Comp:  2             [SII]6716      2.229      0.92    -102   110
# Comp:  2             [SII]6731     0.5295      0.92    -102   110
# Comp:  2              HeII4687      1.184      0.92    -102   110
# Comp:  2               HeI5876      0.000      0.92    -102   110
# Comp:  2          [OIII]5007_d      1.396       1.2    -102   110
# Comp:  2            [OI]6300_d      0.000       1.2    -102   110
# Comp:  2           [NII]6583_d      1.405       1.2    -102   110
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -215       101
#  comp.  1:       160         1
#  comp.  2:      -328       184
# chi2/DOF: 1.082; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 61; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.245      0.66     160     1
# Comp:  1                Halpha      0.000      0.66     160     1
# Comp:  2             [SII]6716      1.626       1.1    -328   184
# Comp:  2             [SII]6731     0.1483       1.1    -328   184
# Comp:  2              HeII4687      3.199       1.1    -328   184
# Comp:  2               HeI5876     0.3213       1.1    -328   184
# Comp:  2          [OIII]5007_d      1.361       1.4    -328   184
# Comp:  2            [OI]6300_d      0.000       1.4    -328   184
# Comp:  2           [NII]6583_d     0.2307       1.4    -328   184
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34       106
#  comp.  1:        53       139
#  comp.  2:      -191        43
# chi2/DOF: 1.080; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.477       1.0      53   139
# Comp:  1                Halpha     0.1466       1.0      53   139
# Comp:  2             [SII]6716      1.821      0.72    -191    43
# Comp:  2             [SII]6731      0.000      0.72    -191    43
# Comp:  2              HeII4687     0.3856      0.72    -191    43
# Comp:  2               HeI5876     0.3596      0.72    -191    43
# Comp:  2          [OIII]5007_d     0.3705      0.92    -191    43
# Comp:  2            [OI]6300_d      2.293      0.92    -191    43
# Comp:  2           [NII]6583_d     0.8032      0.92    -191    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -47        78
#  comp.  2:      -129        78
# chi2/DOF: 1.083; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.164      0.82     -47    78
# Comp:  1                Halpha      1.290      0.82     -47    78
# Comp:  2             [SII]6716      2.543      0.82    -129    78
# Comp:  2             [SII]6731      0.000      0.82    -129    78
# Comp:  2              HeII4687      1.039      0.82    -129    78
# Comp:  2               HeI5876     0.5009      0.82    -129    78
# Comp:  2          [OIII]5007_d      1.648       1.0    -129    78
# Comp:  2            [OI]6300_d     0.8085       1.0    -129    78
# Comp:  2           [NII]6583_d     0.6449       1.0    -129    78
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         6       145
#  comp.  1:       123        92
#  comp.  2:      -137        21
# chi2/DOF: 1.086; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.749      0.87     123    92
# Comp:  1                Halpha     0.3313      0.87     123    92
# Comp:  2             [SII]6716      1.575      0.68    -137    21
# Comp:  2             [SII]6731    0.06652      0.68    -137    21
# Comp:  2              HeII4687     0.3605      0.68    -137    21
# Comp:  2               HeI5876    0.06817      0.68    -137    21
# Comp:  2          [OIII]5007_d      1.120      0.86    -137    21
# Comp:  2            [OI]6300_d      0.000      0.86    -137    21
# Comp:  2           [NII]6583_d     0.1700      0.86    -137    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21       263
#  comp.  1:       -15       213
#  comp.  2:       -28        52
# chi2/DOF: 1.080; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.425       1.2     -15   213
# Comp:  1                Halpha     0.1711       1.2     -15   213
# Comp:  2             [SII]6716      1.161      0.75     -28    52
# Comp:  2             [SII]6731      0.000      0.75     -28    52
# Comp:  2              HeII4687     0.9273      0.75     -28    52
# Comp:  2               HeI5876      1.978      0.75     -28    52
# Comp:  2          [OIII]5007_d      1.860      0.94     -28    52
# Comp:  2            [OI]6300_d      0.000      0.94     -28    52
# Comp:  2           [NII]6583_d     0.1594      0.94     -28    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        38
#  comp.  1:       153       256
#  comp.  2:      -124         9
# chi2/DOF: 1.084; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.123       1.3     153   256
# Comp:  1                Halpha     0.6233       1.3     153   256
# Comp:  2             [SII]6716      1.988      0.67    -124     9
# Comp:  2             [SII]6731     0.2014      0.67    -124     9
# Comp:  2              HeII4687     0.4148      0.67    -124     9
# Comp:  2               HeI5876      0.000      0.67    -124     9
# Comp:  2          [OIII]5007_d      1.009      0.84    -124     9
# Comp:  2            [OI]6300_d    0.08952      0.84    -124     9
# Comp:  2           [NII]6583_d     0.1987      0.84    -124     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       110       369
#  comp.  1:       273       136
#  comp.  2:      -299       138
# chi2/DOF: 1.075; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.896       1.0     273   136
# Comp:  1                Halpha     0.1653       1.0     273   136
# Comp:  2             [SII]6716      2.177       1.0    -299   138
# Comp:  2             [SII]6731      0.000       1.0    -299   138
# Comp:  2              HeII4687      2.568       1.0    -299   138
# Comp:  2               HeI5876      0.000       1.0    -299   138
# Comp:  2          [OIII]5007_d      1.755       1.3    -299   138
# Comp:  2            [OI]6300_d      3.662       1.3    -299   138
# Comp:  2           [NII]6583_d      1.537       1.3    -299   138
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -170       164
#  comp.  1:        46       129
#  comp.  2:      -103        78
# chi2/DOF: 1.084; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.194      0.98      46   129
# Comp:  1                Halpha      0.000      0.98      46   129
# Comp:  2             [SII]6716      1.490      0.82    -103    78
# Comp:  2             [SII]6731     0.3739      0.82    -103    78
# Comp:  2              HeII4687     0.9433      0.82    -103    78
# Comp:  2               HeI5876     0.1411      0.82    -103    78
# Comp:  2          [OIII]5007_d     0.2999       1.0    -103    78
# Comp:  2            [OI]6300_d      0.000       1.0    -103    78
# Comp:  2           [NII]6583_d     0.3770       1.0    -103    78
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6       134
#  comp.  1:        53       149
#  comp.  2:      -589        83
# chi2/DOF: 0.9224; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.150       1.0      53   149
# Comp:  1                Halpha      1.546       1.1      53   149
# Comp:  2             [SII]6716      0.000      0.84    -589    83
# Comp:  2             [SII]6731     0.4985      0.84    -589    83
# Comp:  2              HeII4687      2.433      0.84    -589    83
# Comp:  2               HeI5876      0.000      0.84    -589    83
# Comp:  2          [OIII]5007_d      0.000       1.1    -589    83
# Comp:  2            [OI]6300_d      20.23       1.1    -589    83
# Comp:  2           [NII]6583_d     0.5315       1.1    -589    83
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -105       379
#  comp.  1:       190       544
#  comp.  2:       -42       162
# chi2/DOF: 1.083; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.281       1.9     190   544
# Comp:  1                Halpha      3.194       2.1     190   544
# Comp:  2             [SII]6716      3.656       1.1     -42   162
# Comp:  2             [SII]6731     0.2333       1.1     -42   162
# Comp:  2              HeII4687      3.153       1.1     -42   162
# Comp:  2               HeI5876      1.010       1.1     -42   162
# Comp:  2          [OIII]5007_d      2.033       1.4     -42   162
# Comp:  2            [OI]6300_d      2.863       1.4     -42   162
# Comp:  2           [NII]6583_d     0.1618       1.5     -42   162
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -139         1
#  comp.  1:        56       102
#  comp.  2:      -164        34
# chi2/DOF: 1.083; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.906      0.90      56   102
# Comp:  1                Halpha      0.000      0.90      56   102
# Comp:  2             [SII]6716      1.603      0.70    -164    34
# Comp:  2             [SII]6731      0.000      0.70    -164    34
# Comp:  2              HeII4687      1.017      0.70    -164    34
# Comp:  2               HeI5876      0.000      0.70    -164    34
# Comp:  2          [OIII]5007_d     0.6945      0.89    -164    34
# Comp:  2            [OI]6300_d      1.588      0.89    -164    34
# Comp:  2           [NII]6583_d     0.1805      0.89    -164    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33        93
#  comp.  1:       198         1
#  comp.  2:      -233         1
# chi2/DOF: 1.080; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 89; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.413      0.66     198     1
# Comp:  1                Halpha      0.000      0.66     198     1
# Comp:  2             [SII]6716     0.5269      0.66    -233     1
# Comp:  2             [SII]6731      0.000      0.66    -233     1
# Comp:  2              HeII4687    0.03693      0.66    -233     1
# Comp:  2               HeI5876      0.000      0.66    -233     1
# Comp:  2          [OIII]5007_d     0.2566      0.84    -233     1
# Comp:  2            [OI]6300_d      2.337      0.84    -233     1
# Comp:  2           [NII]6583_d     0.7291      0.84    -233     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -127        84
#  comp.  1:       -19       249
#  comp.  2:       -39         1
# chi2/DOF: 1.079; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.485       1.3     -19   249
# Comp:  1                Halpha     0.6502       1.3     -19   249
# Comp:  2             [SII]6716     0.5587      0.66     -39     1
# Comp:  2             [SII]6731      0.000      0.66     -39     1
# Comp:  2              HeII4687     0.6253      0.66     -39     1
# Comp:  2               HeI5876      1.680      0.66     -39     1
# Comp:  2          [OIII]5007_d     0.7258      0.84     -39     1
# Comp:  2            [OI]6300_d      1.308      0.84     -39     1
# Comp:  2           [NII]6583_d     0.5116      0.84     -39     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -124        63
#  comp.  1:        63       101
#  comp.  2:       -47        99
# chi2/DOF: 1.078; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.071      0.90      63   101
# Comp:  1                Halpha      0.000      0.90      63   101
# Comp:  2             [SII]6716      2.269      0.89     -47    99
# Comp:  2             [SII]6731      0.000      0.89     -47    99
# Comp:  2              HeII4687      2.153      0.89     -47    99
# Comp:  2               HeI5876      1.474      0.89     -47    99
# Comp:  2          [OIII]5007_d     0.4511       1.1     -47    99
# Comp:  2            [OI]6300_d      0.000       1.1     -47    99
# Comp:  2           [NII]6583_d    0.08936       1.1     -47    99
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        72       220
#  comp.  1:       250       235
#  comp.  2:       -67       110
# chi2/DOF: 1.078; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.435       1.3     250   235
# Comp:  1                Halpha     0.7848       1.3     250   235
# Comp:  2             [SII]6716      2.013      0.92     -67   110
# Comp:  2             [SII]6731     0.1839      0.92     -67   110
# Comp:  2              HeII4687     0.9340      0.92     -67   110
# Comp:  2               HeI5876      0.000      0.92     -67   110
# Comp:  2          [OIII]5007_d      1.361       1.2     -67   110
# Comp:  2            [OI]6300_d      0.000       1.2     -67   110
# Comp:  2           [NII]6583_d      1.148       1.2     -67   110
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18       145
#  comp.  1:        39       161
#  comp.  2:      -617       119
# chi2/DOF: 0.9607; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 93; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.667       1.1      39   161
# Comp:  1                Halpha      2.236       1.2      39   161
# Comp:  2             [SII]6716     0.7872      0.95    -617   119
# Comp:  2             [SII]6731      2.363      0.95    -617   119
# Comp:  2              HeII4687      1.244      0.95    -617   119
# Comp:  2               HeI5876      0.000      0.95    -617   119
# Comp:  2          [OIII]5007_d      0.000       1.2    -617   119
# Comp:  2            [OI]6300_d      20.20       1.2    -617   119
# Comp:  2           [NII]6583_d      1.633       1.3    -617   119
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        78
#  comp.  1:       -48       186
#  comp.  2:       -96       248
# chi2/DOF: 1.081; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.466       1.1     -48   186
# Comp:  1                Halpha      1.161       1.1     -48   186
# Comp:  2             [SII]6716      3.311       1.3     -96   248
# Comp:  2             [SII]6731      0.000       1.3     -96   248
# Comp:  2              HeII4687      3.250       1.3     -96   248
# Comp:  2               HeI5876      0.000       1.3     -96   248
# Comp:  2          [OIII]5007_d      1.573       1.6     -96   248
# Comp:  2            [OI]6300_d     0.1201       1.6     -96   248
# Comp:  2           [NII]6583_d     0.6832       1.6     -96   248
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        71
#  comp.  1:      -100        34
#  comp.  2:      -130        27
# chi2/DOF: 1.083; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.039      0.70    -100    34
# Comp:  1                Halpha      0.000      0.70    -100    34
# Comp:  2             [SII]6716      2.268      0.69    -130    27
# Comp:  2             [SII]6731      0.000      0.69    -130    27
# Comp:  2              HeII4687     0.6914      0.69    -130    27
# Comp:  2               HeI5876     0.2622      0.69    -130    27
# Comp:  2          [OIII]5007_d     0.7315      0.87    -130    27
# Comp:  2            [OI]6300_d    0.07051      0.87    -130    27
# Comp:  2           [NII]6583_d     0.5994      0.87    -130    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -147       154
#  comp.  1:        88       151
#  comp.  2:      -120        35
# chi2/DOF: 1.077; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.4881       1.0      88   151
# Comp:  1                Halpha     0.1166       1.0      88   151
# Comp:  2             [SII]6716      2.315      0.71    -120    35
# Comp:  2             [SII]6731      0.000      0.71    -120    35
# Comp:  2              HeII4687     0.8697      0.71    -120    35
# Comp:  2               HeI5876     0.9583      0.71    -120    35
# Comp:  2          [OIII]5007_d     0.7732      0.89    -120    35
# Comp:  2            [OI]6300_d      1.428      0.89    -120    35
# Comp:  2           [NII]6583_d     0.3441      0.89    -120    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        73
#  comp.  1:        47       258
#  comp.  2:       -68        47
# chi2/DOF: 1.082; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.508       1.3      47   258
# Comp:  1                Halpha      1.829       1.3      47   258
# Comp:  2             [SII]6716      1.586      0.73     -68    47
# Comp:  2             [SII]6731    0.06225      0.73     -68    47
# Comp:  2              HeII4687     0.9316      0.73     -68    47
# Comp:  2               HeI5876      1.960      0.73     -68    47
# Comp:  2          [OIII]5007_d     0.5818      0.93     -68    47
# Comp:  2            [OI]6300_d     0.2015      0.93     -68    47
# Comp:  2           [NII]6583_d     0.5634      0.93     -68    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54       174
#  comp.  1:       -20       309
#  comp.  2:      -126        30
# chi2/DOF: 1.086; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.429       1.4     -20   309
# Comp:  1                Halpha      0.000       1.4     -20   309
# Comp:  2             [SII]6716      2.069      0.69    -126    30
# Comp:  2             [SII]6731      0.000      0.69    -126    30
# Comp:  2              HeII4687      1.521      0.69    -126    30
# Comp:  2               HeI5876     0.1221      0.69    -126    30
# Comp:  2          [OIII]5007_d     0.7969      0.88    -126    30
# Comp:  2            [OI]6300_d     0.2802      0.88    -126    30
# Comp:  2           [NII]6583_d     0.3636      0.88    -126    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6       245
#  comp.  1:       140       111
#  comp.  2:      -142        49
# chi2/DOF: 1.082; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.804      0.93     140   111
# Comp:  1                Halpha     0.4792      0.93     140   111
# Comp:  2             [SII]6716      1.853      0.74    -142    49
# Comp:  2             [SII]6731      0.000      0.74    -142    49
# Comp:  2              HeII4687      1.487      0.74    -142    49
# Comp:  2               HeI5876      0.000      0.74    -142    49
# Comp:  2          [OIII]5007_d      1.609      0.93    -142    49
# Comp:  2            [OI]6300_d     0.7464      0.93    -142    49
# Comp:  2           [NII]6583_d     0.4097      0.93    -142    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -284       154
#  comp.  1:       212         1
#  comp.  2:       -19       145
# chi2/DOF: 1.077; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.1725      0.66     212     1
# Comp:  1                Halpha     0.1595      0.66     212     1
# Comp:  2             [SII]6716      1.738       1.0     -19   145
# Comp:  2             [SII]6731      0.000       1.0     -19   145
# Comp:  2              HeII4687      1.986       1.0     -19   145
# Comp:  2               HeI5876      0.000       1.0     -19   145
# Comp:  2          [OIII]5007_d     0.9730       1.3     -19   145
# Comp:  2            [OI]6300_d      0.000       1.3     -19   145
# Comp:  2           [NII]6583_d      1.502       1.3     -19   145
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71        61
#  comp.  1:       171       207
#  comp.  2:      -225       180
# chi2/DOF: 1.077; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.882       1.2     171   207
# Comp:  1                Halpha     0.8676       1.2     171   207
# Comp:  2             [SII]6716      1.651       1.1    -225   180
# Comp:  2             [SII]6731     0.7756       1.1    -225   180
# Comp:  2              HeII4687      1.895       1.1    -225   180
# Comp:  2               HeI5876      0.000       1.1    -225   180
# Comp:  2          [OIII]5007_d      2.286       1.4    -225   180
# Comp:  2            [OI]6300_d      5.908       1.4    -225   180
# Comp:  2           [NII]6583_d     0.4970       1.4    -225   180
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -113        49
#  comp.  1:       -34        80
#  comp.  2:      -114        77
# chi2/DOF: 1.085; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 59; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.956      0.83     -34    80
# Comp:  1                Halpha      0.000      0.83     -34    80
# Comp:  2             [SII]6716      2.413      0.82    -114    77
# Comp:  2             [SII]6731      0.000      0.82    -114    77
# Comp:  2              HeII4687      1.180      0.82    -114    77
# Comp:  2               HeI5876      0.000      0.82    -114    77
# Comp:  2          [OIII]5007_d     0.9936       1.0    -114    77
# Comp:  2            [OI]6300_d     0.1328       1.0    -114    77
# Comp:  2           [NII]6583_d     0.8392       1.0    -114    77
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37        78
#  comp.  1:       117       195
#  comp.  2:      -608        87
# chi2/DOF: 0.8967; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 93; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.08       1.2     117   195
# Comp:  1                Halpha      1.762       1.4     117   195
# Comp:  2             [SII]6716    0.06739      0.85    -608    87
# Comp:  2             [SII]6731     0.5310      0.85    -608    87
# Comp:  2              HeII4687      2.105      0.85    -608    87
# Comp:  2               HeI5876      0.000      0.85    -608    87
# Comp:  2          [OIII]5007_d      0.000       1.1    -608    87
# Comp:  2            [OI]6300_d      21.44       1.1    -608    87
# Comp:  2           [NII]6583_d      0.000       1.3    -608    87
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -115       145
#  comp.  1:       -36       338
#  comp.  2:      -131        27
# chi2/DOF: 1.084; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.335       1.5     -36   338
# Comp:  1                Halpha      0.000       1.5     -36   338
# Comp:  2             [SII]6716      2.195      0.69    -131    27
# Comp:  2             [SII]6731     0.1997      0.69    -131    27
# Comp:  2              HeII4687      1.076      0.69    -131    27
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.473       1.0      63   135
# Comp:  1                Halpha      0.000       1.0      63   135
# Comp:  2             [SII]6716      2.241      0.77    -128    60
# Comp:  2             [SII]6731      0.000      0.77    -128    60
# Comp:  2              HeII4687      1.101      0.77    -128    60
# Comp:  2               HeI5876      0.000      0.77    -128    60
# Comp:  2          [OIII]5007_d     0.7117      0.97    -128    60
# Comp:  2            [OI]6300_d     0.1779      0.97    -128    60
# Comp:  2           [NII]6583_d     0.4369      0.97    -128    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21       160
#  comp.  1:        76        41
#  comp.  2:      -136        61
# chi2/DOF: 1.085; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.894      0.72      76    41
# Comp:  1                Halpha     0.2407      0.72      76    41
# Comp:  2             [SII]6716      2.227      0.77    -136    61
# Comp:  2             [SII]6731     0.2320      0.77    -136    61
# Comp:  2              HeII4687     0.9655      0.77    -136    61
# Comp:  2               HeI5876      0.000      0.77    -136    61
# Comp:  2          [OIII]5007_d     0.1458      0.98    -136    61
# Comp:  2            [OI]6300_d      1.851      0.98    -136    61
# Comp:  2           [NII]6583_d     0.5237      0.98    -136    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -42       177
#  comp.  2:      -141       102
# chi2/DOF: 1.082; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.153       1.1     -42   177
# Comp:  1                Halpha     0.5599       1.1     -42   177
# Comp:  2             [SII]6716      2.721      0.90    -141   102
# Comp:  2             [SII]6731     0.2948      0.90    -141   102
# Comp:  2              HeII4687      1.265      0.90    -141   102
# Comp:  2               HeI5876      0.000      0.90    -141   102
# Comp:  2          [OIII]5007_d      2.019       1.1    -141   102
# Comp:  2            [OI]6300_d      1.413       1.1    -141   102
# Comp:  2           [NII]6583_d     0.6773       1.1    -141   102
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -167       146
#  comp.  1:      -584       394
#  comp.  2:       -12       104
# chi2/DOF: 1.080; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      0.000       1.6    -584   394
# Comp:  1                Halpha      4.176       1.7    -584   394
# Comp:  2             [SII]6716      2.254      0.90     -12   104
# Comp:  2             [SII]6731     0.6148      0.90     -12   104
# Comp:  2              HeII4687      1.685      0.90     -12   104
# Comp:  2               HeI5876      2.689      0.90     -12   104
# Comp:  2          [OIII]5007_d      1.239       1.1     -12   104
# Comp:  2            [OI]6300_d      0.000       1.1     -12   104
# Comp:  2           [NII]6583_d     0.7939       1.2     -12   104
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82       108
#  comp.  1:       -85        33
#  comp.  2:      -595        84
# chi2/DOF: 0.9316; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.918      0.70     -85    33
# Comp:  1                Halpha     0.5263      0.70     -85    33
# Comp:  2             [SII]6716    0.06385      0.84    -595    84
# Comp:  2             [SII]6731     0.6910      0.84    -595    84
# Comp:  2              HeII4687      0.000      0.84    -595    84
# Comp:  2               HeI5876    0.03449      0.84    -595    84
# Comp:  2          [OIII]5007_d      0.000       1.1    -595    84
# Comp:  2            [OI]6300_d      19.82       1.1    -595    84
# Comp:  2           [NII]6583_d     0.9193       1.1    -595    84
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       208       356
#  comp.  1:       341       176
#  comp.  2:      -265       278
# chi2/DOF: 1.075; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.364       1.1     341   176
# Comp:  1                Halpha     0.3193       1.4     341   176
# Comp:  2             [SII]6716      3.117       1.4    -265   278
# Comp:  2             [SII]6731      0.000       1.4    -265   278
# Comp:  2              HeII4687      3.238       1.4    -265   278
# Comp:  2               HeI5876     0.3308       1.4    -265   278
# Comp:  2          [OIII]5007_d      2.602       1.7    -265   278
# Comp:  2            [OI]6300_d      0.000       1.7    -265   278
# Comp:  2           [NII]6583_d      4.377       2.1    -265   278
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        27       108
#  comp.  1:        45       184
#  comp.  2:      -134        79
# chi2/DOF: 1.078; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.263       1.1      45   184
# Comp:  1                Halpha     0.6130       1.1      45   184
# Comp:  2             [SII]6716      2.394      0.83    -134    79
# Comp:  2             [SII]6731      0.000      0.83    -134    79
# Comp:  2              HeII4687      1.352      0.83    -134    79
# Comp:  2               HeI5876      0.000      0.83    -134    79
# Comp:  2          [OIII]5007_d     0.7851       1.0    -134    79
# Comp:  2            [OI]6300_d      1.275       1.0    -134    79
# Comp:  2           [NII]6583_d     0.9030       1.0    -134    79
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9       132
#  comp.  1:        41        88
#  comp.  2:      -121       145
# chi2/DOF: 1.086; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.213      0.85      41    88
# Comp:  1                Halpha      0.000      0.85      41    88
# Comp:  2             [SII]6716      1.948       1.0    -121   145
# Comp:  2             [SII]6731      0.000       1.0    -121   145
# Comp:  2              HeII4687      0.000       1.0    -121   145
# Comp:  2               HeI5876     0.4640       1.0    -121   145
# Comp:  2          [OIII]5007_d      1.965       1.3    -121   145
# Comp:  2            [OI]6300_d      0.000       1.3    -121   145
# Comp:  2           [NII]6583_d     0.7876       1.3    -121   145
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -134       119
#  comp.  1:      -108       253
#  comp.  2:      -123         1
# chi2/DOF: 1.085; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.431       1.3    -108   253
# Comp:  1                Halpha      1.522       1.3    -108   253
# Comp:  2             [SII]6716      2.095      0.66    -123     1
# Comp:  2             [SII]6731     0.2145      0.66    -123     1
# Comp:  2              HeII4687      1.194      0.66    -123     1
# Comp:  2               HeI5876     0.3483      0.66    -123     1
# Comp:  2          [OIII]5007_d     0.9090      0.84    -123     1
# Comp:  2            [OI]6300_d    0.02125      0.84    -123     1
# Comp:  2           [NII]6583_d     0.7353      0.84    -123     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53       255
#  comp.  1:        -2       132
#  comp.  2:      -124        56
# chi2/DOF: 1.082; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.428      0.99      -2   132
# Comp:  1                Halpha     0.5118      0.99      -2   132
# Comp:  2             [SII]6716      2.424      0.76    -124    56
# Comp:  2             [SII]6731      0.000      0.76    -124    56
# Comp:  2              HeII4687      1.035      0.76    -124    56
# Comp:  2               HeI5876      0.000      0.76    -124    56
# Comp:  2          [OIII]5007_d      1.370      0.96    -124    56
# Comp:  2            [OI]6300_d      1.458      0.96    -124    56
# Comp:  2           [NII]6583_d     0.6113      0.96    -124    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        19       121
#  comp.  1:        89       174
#  comp.  2:       -68       102
# chi2/DOF: 1.078; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.371       1.1      89   174
# Comp:  1                Halpha      2.206       1.1      89   174
# Comp:  2             [SII]6716      1.595      0.90     -68   102
# Comp:  2             [SII]6731   0.003278      0.90     -68   102
# Comp:  2              HeII4687      1.084      0.90     -68   102
# Comp:  2               HeI5876      1.749      0.90     -68   102
# Comp:  2          [OIII]5007_d      1.519       1.1     -68   102
# Comp:  2            [OI]6300_d      0.000       1.1     -68   102
# Comp:  2           [NII]6583_d    0.08553       1.1     -68   102
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -159       150
#  comp.  1:       136        63
#  comp.  2:      -230       135
# chi2/DOF: 1.084; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8055      0.78     136    63
# Comp:  1                Halpha     0.1975      0.78     136    63
# Comp:  2             [SII]6716      2.426       1.0    -230   135
# Comp:  2             [SII]6731    0.04821       1.0    -230   135
# Comp:  2              HeII4687      2.498       1.0    -230   135
# Comp:  2               HeI5876      0.000       1.0    -230   135
# Comp:  2          [OIII]5007_d     0.4329       1.3    -230   135
# Comp:  2            [OI]6300_d      0.000       1.3    -230   135
# Comp:  2           [NII]6583_d     0.7465       1.3    -230   135
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        83
#  comp.  1:         9         5
#  comp.  2:      -104        80
# chi2/DOF: 1.082; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.448      0.66       9     5
# Comp:  1                Halpha     0.6032      0.66       9     5
# Comp:  2             [SII]6716      2.769      0.83    -104    80
# Comp:  2             [SII]6731      0.000      0.83    -104    80
# Comp:  2              HeII4687      1.808      0.83    -104    80
# Comp:  2               HeI5876      1.590      0.83    -104    80
# Comp:  2          [OIII]5007_d      1.226       1.0    -104    80
# Comp:  2            [OI]6300_d      0.000       1.0    -104    80
# Comp:  2           [NII]6583_d     0.9420       1.0    -104    80
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47       415
#  comp.  1:        96        20
#  comp.  2:      -470       219
# chi2/DOF: 1.079; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.619      0.68      96    20
# Comp:  1                Halpha    0.01093      0.69      96    20
# Comp:  2             [SII]6716      2.005       1.2    -470   219
# Comp:  2             [SII]6731      1.300       1.2    -470   219
# Comp:  2              HeII4687      4.770       1.2    -470   219
# Comp:  2               HeI5876      0.000       1.2    -470   219
# Comp:  2          [OIII]5007_d     0.5117       1.6    -470   219
# Comp:  2            [OI]6300_d      0.000       1.6    -470   219
# Comp:  2           [NII]6583_d      2.712       1.6    -470   219
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([4.14663922, 1.58153065, 1.20156122, 0.484252  , 1.14303445,
#        1.04769653, 0.67979531, 4.99168533, 0.79636856])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_11896\2709300755.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(8, 6))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([1.7656633 , 0.        , 2.68578627, 0.        , 1.14416794,
#        0.        , 1.291402  , 0.52860895, 0.80656979])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_2_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_2", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_2_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_2_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_2_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.031024    0.072859
# 1        Halpha  0.000000    0.027788
# 2     [SII]6716  0.047191    0.021112
# 3     [SII]6731  0.000000    0.008509
# 4      HeII4687  0.020104    0.020084
# 5       HeI5876  0.000000    0.018409
# 6  [OIII]5007_d  0.022691    0.011944
# 7    [OI]6300_d  0.009288    0.087706
# 8   [NII]6583_d  0.014172    0.013993
#           Name      Flux  Error_flux
# 0        Hbeta  0.031024    0.072859
# 1       Halpha  0.000000    0.027788
# 2    [SII]6716  0.047191    0.021112
# 3    [SII]6731  0.000000    0.008509
# 4     HeII4687  0.020104    0.020084
# 5      HeI5876  0.000000    0.018409
# 6   [OIII]4959  0.005673    0.011944
# 7   [OIII]5007  0.017018    0.011944
# 8     [OI]6300  0.006966    0.087706
# 9     [OI]6364  0.002322    0.087706
# 10   [NII]6548  0.003543    0.013993
# 11   [NII]6583  0.010629    0.013993

# %%
np.median(flux_rf_rebin)
# Out:
# 0.01757051419956058
