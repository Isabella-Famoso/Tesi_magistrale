# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_7.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_7']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.02102746 0.06229844 0.03937327 ... 0.02323384 0.02335959 0.02480314] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
# chi2/DOF: 0.04096; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
# chi2/DOF: 0.02600; DOF: 1917; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-58.63926059,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -27         1
#  comp.  1:        53        36
#  comp.  2:       -42        61
# chi2/DOF: 1.114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.928      0.41      53    36
# Comp:  1                Halpha     0.8908      0.41      53    36
# Comp:  2             [SII]6716      1.441      0.45     -42    61
# Comp:  2             [SII]6731     0.5243      0.45     -42    61
# Comp:  2              HeII4687     0.2134      0.45     -42    61
# Comp:  2               HeI5876      0.000      0.45     -42    61
# Comp:  2          [OIII]5007_d     0.7380      0.56     -42    61
# Comp:  2            [OI]6300_d      1.155      0.56     -42    61
# Comp:  2           [NII]6583_d     0.2855      0.56     -42    61
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  3.828; gas flux:      2 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  1.798; gas flux:      1 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  2.302; gas flux:      2 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  0.873; gas flux:      1 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.3533; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise: 0.9357; gas flux:      1 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.459; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:   0.35; gas flux:      0 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -18         1
#  comp.  1:        23        53
#  comp.  2:       -42        71
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.219      0.43      23    53
# Comp:  1                Halpha     0.8008      0.43      23    53
# Comp:  2             [SII]6716      1.417      0.46     -42    71
# Comp:  2             [SII]6731     0.3179      0.46     -42    71
# Comp:  2              HeII4687     0.5072      0.46     -42    71
# Comp:  2               HeI5876      0.000      0.46     -42    71
# Comp:  2          [OIII]5007_d      0.000      0.59     -42    71
# Comp:  2            [OI]6300_d      1.230      0.59     -42    71
# Comp:  2           [NII]6583_d    0.06541      0.59     -42    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31         1
#  comp.  1:        61         1
#  comp.  2:       -51        66
# chi2/DOF: 1.102; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.572      0.38      61     1
# Comp:  1                Halpha     0.6466      0.38      61     1
# Comp:  2             [SII]6716      1.929      0.45     -51    66
# Comp:  2             [SII]6731     0.3909      0.45     -51    66
# Comp:  2              HeII4687     0.3191      0.45     -51    66
# Comp:  2               HeI5876     0.2399      0.45     -51    66
# Comp:  2          [OIII]5007_d      1.232      0.57     -51    66
# Comp:  2            [OI]6300_d     0.8612      0.57     -51    66
# Comp:  2           [NII]6583_d     0.1650      0.57     -51    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27         1
#  comp.  1:        53        36
#  comp.  2:       -42        61
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.010      0.41      53    36
# Comp:  1                Halpha     0.9715      0.41      53    36
# Comp:  2             [SII]6716      1.595      0.45     -42    61
# Comp:  2             [SII]6731     0.7351      0.45     -42    61
# Comp:  2              HeII4687    0.09685      0.45     -42    61
# Comp:  2               HeI5876      0.000      0.45     -42    61
# Comp:  2          [OIII]5007_d     0.6400      0.56     -42    61
# Comp:  2            [OI]6300_d      1.291      0.56     -42    61
# Comp:  2           [NII]6583_d     0.5924      0.56     -42    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47         1
#  comp.  1:        62         1
#  comp.  2:       -32        33
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8903      0.38      62     1
# Comp:  1                Halpha     0.7268      0.38      62     1
# Comp:  2             [SII]6716      1.178      0.40     -32    33
# Comp:  2             [SII]6731     0.5306      0.40     -32    33
# Comp:  2              HeII4687    0.05708      0.40     -32    33
# Comp:  2               HeI5876     0.3816      0.40     -32    33
# Comp:  2          [OIII]5007_d      0.000      0.51     -32    33
# Comp:  2            [OI]6300_d     0.9307      0.51     -32    33
# Comp:  2           [NII]6583_d     0.8060      0.51     -32    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        71
#  comp.  1:        34        76
#  comp.  2:       -56       124
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.755      0.47      34    76
# Comp:  1                Halpha      1.401      0.47      34    76
# Comp:  2             [SII]6716      2.124      0.56     -56   124
# Comp:  2             [SII]6731      1.068      0.56     -56   124
# Comp:  2              HeII4687     0.4061      0.56     -56   124
# Comp:  2               HeI5876      0.000      0.56     -56   124
# Comp:  2          [OIII]5007_d     0.8258      0.71     -56   124
# Comp:  2            [OI]6300_d      2.207      0.71     -56   124
# Comp:  2           [NII]6583_d     0.8779      0.71     -56   124
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71       130
#  comp.  1:        83        16
#  comp.  2:       -21       116
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.715      0.39      83    16
# Comp:  1                Halpha     0.7434      0.39      83    16
# Comp:  2             [SII]6716      1.531      0.54     -21   116
# Comp:  2             [SII]6731     0.5709      0.54     -21   116
# Comp:  2              HeII4687     0.4077      0.54     -21   116
# Comp:  2               HeI5876     0.2700      0.54     -21   116
# Comp:  2          [OIII]5007_d      0.000      0.69     -21   116
# Comp:  2            [OI]6300_d      1.955      0.69     -21   116
# Comp:  2           [NII]6583_d     0.3298      0.69     -21   116
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28         1
#  comp.  1:        53        41
#  comp.  2:       -49        68
# chi2/DOF: 1.110; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.685      0.42      53    41
# Comp:  1                Halpha      1.005      0.42      53    41
# Comp:  2             [SII]6716      1.858      0.46     -49    68
# Comp:  2             [SII]6731     0.6126      0.46     -49    68
# Comp:  2              HeII4687     0.2318      0.46     -49    68
# Comp:  2               HeI5876      0.000      0.46     -49    68
# Comp:  2          [OIII]5007_d     0.5123      0.58     -49    68
# Comp:  2            [OI]6300_d      1.294      0.58     -49    68
# Comp:  2           [NII]6583_d    0.09032      0.58     -49    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        66
#  comp.  1:        68         1
#  comp.  2:       -54        61
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.931      0.38      68     1
# Comp:  1                Halpha     0.8802      0.38      68     1
# Comp:  2             [SII]6716      1.277      0.45     -54    61
# Comp:  2             [SII]6731     0.5726      0.45     -54    61
# Comp:  2              HeII4687     0.5309      0.45     -54    61
# Comp:  2               HeI5876     0.6511      0.45     -54    61
# Comp:  2          [OIII]5007_d      0.000      0.56     -54    61
# Comp:  2            [OI]6300_d      1.208      0.56     -54    61
# Comp:  2           [NII]6583_d     0.6406      0.56     -54    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        62
#  comp.  1:        52        37
#  comp.  2:       -40        62
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.807      0.41      52    37
# Comp:  1                Halpha     0.7871      0.41      52    37
# Comp:  2             [SII]6716      1.538      0.45     -40    62
# Comp:  2             [SII]6731     0.6055      0.45     -40    62
# Comp:  2              HeII4687     0.1583      0.45     -40    62
# Comp:  2               HeI5876     0.7431      0.45     -40    62
# Comp:  2          [OIII]5007_d     0.5095      0.57     -40    62
# Comp:  2            [OI]6300_d      1.042      0.57     -40    62
# Comp:  2           [NII]6583_d     0.2724      0.57     -40    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21         1
#  comp.  1:        51        44
#  comp.  2:       -36        74
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.436      0.42      51    44
# Comp:  1                Halpha      1.282      0.42      51    44
# Comp:  2             [SII]6716      1.704      0.47     -36    74
# Comp:  2             [SII]6731     0.6690      0.47     -36    74
# Comp:  2              HeII4687     0.4500      0.47     -36    74
# Comp:  2               HeI5876     0.6495      0.47     -36    74
# Comp:  2          [OIII]5007_d      1.483      0.59     -36    74
# Comp:  2            [OI]6300_d      1.624      0.59     -36    74
# Comp:  2           [NII]6583_d      0.000      0.59     -36    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        62
#  comp.  1:        79         1
#  comp.  2:       -29        99
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.631      0.38      79     1
# Comp:  1                Halpha     0.7889      0.38      79     1
# Comp:  2             [SII]6716      1.587      0.51     -29    99
# Comp:  2             [SII]6731     0.6762      0.51     -29    99
# Comp:  2              HeII4687     0.4473      0.51     -29    99
# Comp:  2               HeI5876      0.000      0.51     -29    99
# Comp:  2          [OIII]5007_d      1.135      0.65     -29    99
# Comp:  2            [OI]6300_d      1.542      0.65     -29    99
# Comp:  2           [NII]6583_d     0.7923      0.65     -29    99
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14         1
#  comp.  1:        63         1
#  comp.  2:       -50        31
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.920      0.38      63     1
# Comp:  1                Halpha     0.9947      0.38      63     1
# Comp:  2             [SII]6716      1.346      0.40     -50    31
# Comp:  2             [SII]6731     0.6060      0.40     -50    31
# Comp:  2              HeII4687     0.4507      0.40     -50    31
# Comp:  2               HeI5876      0.000      0.40     -50    31
# Comp:  2          [OIII]5007_d      1.285      0.51     -50    31
# Comp:  2            [OI]6300_d      1.118      0.51     -50    31
# Comp:  2           [NII]6583_d      0.000      0.51     -50    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:        48         1
#  comp.  2:       -52        37
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.374      0.38      48     1
# Comp:  1                Halpha     0.7561      0.38      48     1
# Comp:  2             [SII]6716      1.593      0.41     -52    37
# Comp:  2             [SII]6731     0.4490      0.41     -52    37
# Comp:  2              HeII4687     0.1839      0.41     -52    37
# Comp:  2               HeI5876     0.4271      0.41     -52    37
# Comp:  2          [OIII]5007_d     0.6815      0.52     -52    37
# Comp:  2            [OI]6300_d      1.387      0.52     -52    37
# Comp:  2           [NII]6583_d     0.2080      0.52     -52    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        36
#  comp.  1:        52        37
#  comp.  2:       -41        62
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.723      0.41      52    37
# Comp:  1                Halpha     0.6885      0.41      52    37
# Comp:  2             [SII]6716      1.319      0.45     -41    62
# Comp:  2             [SII]6731     0.7049      0.45     -41    62
# Comp:  2              HeII4687     0.1951      0.45     -41    62
# Comp:  2               HeI5876      0.000      0.45     -41    62
# Comp:  2          [OIII]5007_d     0.5595      0.57     -41    62
# Comp:  2            [OI]6300_d      1.127      0.57     -41    62
# Comp:  2           [NII]6583_d      0.000      0.57     -41    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28       143
#  comp.  1:        55        40
#  comp.  2:       -43        59
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.753      0.41      55    40
# Comp:  1                Halpha     0.8025      0.41      55    40
# Comp:  2             [SII]6716      1.507      0.44     -43    59
# Comp:  2             [SII]6731     0.7027      0.44     -43    59
# Comp:  2              HeII4687     0.1701      0.44     -43    59
# Comp:  2               HeI5876      0.000      0.44     -43    59
# Comp:  2          [OIII]5007_d     0.4955      0.56     -43    59
# Comp:  2            [OI]6300_d     0.9743      0.56     -43    59
# Comp:  2           [NII]6583_d     0.2651      0.56     -43    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        30
#  comp.  1:        34        98
#  comp.  2:       -37        79
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.165      0.51      34    98
# Comp:  1                Halpha      1.432      0.51      34    98
# Comp:  2             [SII]6716      1.694      0.48     -37    79
# Comp:  2             [SII]6731     0.6996      0.48     -37    79
# Comp:  2              HeII4687     0.2359      0.48     -37    79
# Comp:  2               HeI5876     0.1520      0.48     -37    79
# Comp:  2          [OIII]5007_d     0.1605      0.60     -37    79
# Comp:  2            [OI]6300_d      1.113      0.60     -37    79
# Comp:  2           [NII]6583_d     0.4175      0.60     -37    79
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2         1
#  comp.  1:        63         1
#  comp.  2:       -34        68
# chi2/DOF: 1.101; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.863      0.38      63     1
# Comp:  1                Halpha     0.9708      0.38      63     1
# Comp:  2             [SII]6716      1.374      0.46     -34    68
# Comp:  2             [SII]6731     0.6896      0.46     -34    68
# Comp:  2              HeII4687     0.4493      0.46     -34    68
# Comp:  2               HeI5876      0.000      0.46     -34    68
# Comp:  2          [OIII]5007_d      0.000      0.58     -34    68
# Comp:  2            [OI]6300_d      1.463      0.58     -34    68
# Comp:  2           [NII]6583_d     0.1502      0.58     -34    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
#  comp.  1:        38         1
#  comp.  2:       -42        90
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.673      0.38      38     1
# Comp:  1                Halpha     0.9384      0.38      38     1
# Comp:  2             [SII]6716      1.769      0.50     -42    90
# Comp:  2             [SII]6731     0.5096      0.50     -42    90
# Comp:  2              HeII4687     0.3756      0.50     -42    90
# Comp:  2               HeI5876     0.1191      0.50     -42    90
# Comp:  2          [OIII]5007_d      0.000      0.63     -42    90
# Comp:  2            [OI]6300_d      1.567      0.63     -42    90
# Comp:  2           [NII]6583_d      1.124      0.63     -42    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        42
#  comp.  1:        54        38
#  comp.  2:       -40        63
# chi2/DOF: 1.112; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.947      0.41      54    38
# Comp:  1                Halpha     0.7662      0.41      54    38
# Comp:  2             [SII]6716      1.408      0.45     -40    63
# Comp:  2             [SII]6731     0.4878      0.45     -40    63
# Comp:  2              HeII4687     0.3733      0.45     -40    63
# Comp:  2               HeI5876      0.000      0.45     -40    63
# Comp:  2          [OIII]5007_d     0.6816      0.57     -40    63
# Comp:  2            [OI]6300_d     0.9064      0.57     -40    63
# Comp:  2           [NII]6583_d     0.2559      0.57     -40    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        39
#  comp.  1:        54        36
#  comp.  2:       -41        60
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.411      0.41      54    36
# Comp:  1                Halpha      1.229      0.41      54    36
# Comp:  2             [SII]6716      1.314      0.45     -41    60
# Comp:  2             [SII]6731     0.5793      0.45     -41    60
# Comp:  2              HeII4687     0.3690      0.45     -41    60
# Comp:  2               HeI5876     0.4961      0.45     -41    60
# Comp:  2          [OIII]5007_d      1.042      0.56     -41    60
# Comp:  2            [OI]6300_d      1.132      0.56     -41    60
# Comp:  2           [NII]6583_d     0.7298      0.56     -41    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31       234
#  comp.  1:        93         1
#  comp.  2:       -36        77
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.374      0.38      93     1
# Comp:  1                Halpha     0.6980      0.38      93     1
# Comp:  2             [SII]6716      1.657      0.47     -36    77
# Comp:  2             [SII]6731     0.5453      0.47     -36    77
# Comp:  2              HeII4687     0.4973      0.47     -36    77
# Comp:  2               HeI5876      0.000      0.47     -36    77
# Comp:  2          [OIII]5007_d     0.7428      0.60     -36    77
# Comp:  2            [OI]6300_d      1.465      0.60     -36    77
# Comp:  2           [NII]6583_d     0.1455      0.60     -36    77
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31         1
#  comp.  1:        25        38
#  comp.  2:       -45        43
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.806      0.41      25    38
# Comp:  1                Halpha     0.8315      0.41      25    38
# Comp:  2             [SII]6716      1.133      0.42     -45    43
# Comp:  2             [SII]6731     0.5722      0.42     -45    43
# Comp:  2              HeII4687     0.5184      0.42     -45    43
# Comp:  2               HeI5876      0.000      0.42     -45    43
# Comp:  2          [OIII]5007_d      0.000      0.53     -45    43
# Comp:  2            [OI]6300_d      1.243      0.53     -45    43
# Comp:  2           [NII]6583_d     0.2813      0.53     -45    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        54
#  comp.  1:        54        38
#  comp.  2:       -41        62
# chi2/DOF: 1.097; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.642      0.41      54    38
# Comp:  1                Halpha     0.9269      0.41      54    38
# Comp:  2             [SII]6716      1.777      0.45     -41    62
# Comp:  2             [SII]6731     0.6815      0.45     -41    62
# Comp:  2              HeII4687    0.07061      0.45     -41    62
# Comp:  2               HeI5876     0.6345      0.45     -41    62
# Comp:  2          [OIII]5007_d     0.6710      0.57     -41    62
# Comp:  2            [OI]6300_d     0.7550      0.57     -41    62
# Comp:  2           [NII]6583_d      0.000      0.57     -41    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24         1
#  comp.  1:        61        45
#  comp.  2:       -53        46
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.182      0.42      61    45
# Comp:  1                Halpha     0.9706      0.42      61    45
# Comp:  2             [SII]6716      1.495      0.42     -53    46
# Comp:  2             [SII]6731     0.5750      0.42     -53    46
# Comp:  2              HeII4687      0.000      0.42     -53    46
# Comp:  2               HeI5876      0.000      0.42     -53    46
# Comp:  2          [OIII]5007_d      1.311      0.53     -53    46
# Comp:  2            [OI]6300_d     0.6665      0.53     -53    46
# Comp:  2           [NII]6583_d     0.5326      0.53     -53    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21        78
#  comp.  1:        75        40
#  comp.  2:       -25         1
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.219      0.41      75    40
# Comp:  1                Halpha      1.187      0.41      75    40
# Comp:  2             [SII]6716      1.021      0.38     -25     1
# Comp:  2             [SII]6731     0.3711      0.38     -25     1
# Comp:  2              HeII4687      0.000      0.38     -25     1
# Comp:  2               HeI5876     0.2960      0.38     -25     1
# Comp:  2          [OIII]5007_d     0.8759      0.48     -25     1
# Comp:  2            [OI]6300_d     0.7806      0.48     -25     1
# Comp:  2           [NII]6583_d     0.4088      0.48     -25     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        27         1
#  comp.  1:        51        71
#  comp.  2:       -35        89
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.073      0.46      51    71
# Comp:  1                Halpha      1.556      0.46      51    71
# Comp:  2             [SII]6716      1.466      0.50     -35    89
# Comp:  2             [SII]6731     0.4879      0.50     -35    89
# Comp:  2              HeII4687      0.000      0.50     -35    89
# Comp:  2               HeI5876      0.000      0.50     -35    89
# Comp:  2          [OIII]5007_d      1.061      0.63     -35    89
# Comp:  2            [OI]6300_d      1.659      0.63     -35    89
# Comp:  2           [NII]6583_d     0.3374      0.63     -35    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:         1        96
#  comp.  2:       -67        70
# chi2/DOF: 1.100; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.549      0.51       1    96
# Comp:  1                Halpha      1.426      0.51       1    96
# Comp:  2             [SII]6716      1.746      0.46     -67    70
# Comp:  2             [SII]6731     0.2772      0.46     -67    70
# Comp:  2              HeII4687     0.3806      0.46     -67    70
# Comp:  2               HeI5876     0.1265      0.46     -67    70
# Comp:  2          [OIII]5007_d    0.02266      0.58     -67    70
# Comp:  2            [OI]6300_d      1.594      0.58     -67    70
# Comp:  2           [NII]6583_d     0.1541      0.58     -67    70
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:        69        17
#  comp.  2:       -45        71
# chi2/DOF: 1.109; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 25; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.760      0.39      69    17
# Comp:  1                Halpha      1.099      0.39      69    17
# Comp:  2             [SII]6716      1.704      0.46     -45    71
# Comp:  2             [SII]6731     0.6333      0.46     -45    71
# Comp:  2              HeII4687     0.4036      0.46     -45    71
# Comp:  2               HeI5876     0.3015      0.46     -45    71
# Comp:  2          [OIII]5007_d     0.5858      0.59     -45    71
# Comp:  2            [OI]6300_d      1.289      0.59     -45    71
# Comp:  2           [NII]6583_d      1.025      0.59     -45    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        35
#  comp.  1:        54        39
#  comp.  2:       -41        62
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.088      0.41      54    39
# Comp:  1                Halpha     0.8792      0.41      54    39
# Comp:  2             [SII]6716      1.097      0.45     -41    62
# Comp:  2             [SII]6731     0.3968      0.45     -41    62
# Comp:  2              HeII4687      0.000      0.45     -41    62
# Comp:  2               HeI5876     0.1036      0.45     -41    62
# Comp:  2          [OIII]5007_d     0.8496      0.57     -41    62
# Comp:  2            [OI]6300_d      1.096      0.57     -41    62
# Comp:  2           [NII]6583_d     0.2521      0.57     -41    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        66
#  comp.  1:        52        35
#  comp.  2:       -43        63
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.542      0.41      52    35
# Comp:  1                Halpha     0.6105      0.41      52    35
# Comp:  2             [SII]6716      1.448      0.45     -43    63
# Comp:  2             [SII]6731     0.4374      0.45     -43    63
# Comp:  2              HeII4687     0.2777      0.45     -43    63
# Comp:  2               HeI5876      0.000      0.45     -43    63
# Comp:  2          [OIII]5007_d      1.378      0.57     -43    63
# Comp:  2            [OI]6300_d      1.123      0.57     -43    63
# Comp:  2           [NII]6583_d     0.2064      0.57     -43    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        31
#  comp.  1:        54        37
#  comp.  2:       -41        60
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.979      0.41      54    37
# Comp:  1                Halpha      1.175      0.41      54    37
# Comp:  2             [SII]6716      1.286      0.44     -41    60
# Comp:  2             [SII]6731     0.5624      0.44     -41    60
# Comp:  2              HeII4687      0.000      0.44     -41    60
# Comp:  2               HeI5876      0.000      0.44     -41    60
# Comp:  2          [OIII]5007_d     0.6122      0.56     -41    60
# Comp:  2            [OI]6300_d     0.7988      0.56     -41    60
# Comp:  2           [NII]6583_d     0.2850      0.56     -41    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        42
#  comp.  1:        43        66
#  comp.  2:       -32        44
# chi2/DOF: 1.100; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.047      0.46      43    66
# Comp:  1                Halpha      1.048      0.46      43    66
# Comp:  2             [SII]6716      1.199      0.42     -32    44
# Comp:  2             [SII]6731     0.5234      0.42     -32    44
# Comp:  2              HeII4687     0.1605      0.42     -32    44
# Comp:  2               HeI5876      0.000      0.42     -32    44
# Comp:  2          [OIII]5007_d      1.154      0.53     -32    44
# Comp:  2            [OI]6300_d     0.7295      0.53     -32    44
# Comp:  2           [NII]6583_d      0.000      0.53     -32    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        69
#  comp.  1:        62        33
#  comp.  2:       -32        38
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.924      0.40      62    33
# Comp:  1                Halpha      1.073      0.40      62    33
# Comp:  2             [SII]6716      1.501      0.41     -32    38
# Comp:  2             [SII]6731     0.4381      0.41     -32    38
# Comp:  2              HeII4687     0.3615      0.41     -32    38
# Comp:  2               HeI5876     0.1955      0.41     -32    38
# Comp:  2          [OIII]5007_d      0.000      0.52     -32    38
# Comp:  2            [OI]6300_d      1.051      0.52     -32    38
# Comp:  2           [NII]6583_d     0.8474      0.52     -32    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:        74        26
#  comp.  2:       -35         1
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.928      0.40      74    26
# Comp:  1                Halpha      1.093      0.40      74    26
# Comp:  2             [SII]6716      1.263      0.38     -35     1
# Comp:  2             [SII]6731     0.1860      0.38     -35     1
# Comp:  2              HeII4687     0.2670      0.38     -35     1
# Comp:  2               HeI5876     0.4029      0.38     -35     1
# Comp:  2          [OIII]5007_d     0.9990      0.48     -35     1
# Comp:  2            [OI]6300_d      1.038      0.48     -35     1
# Comp:  2           [NII]6583_d     0.7502      0.48     -35     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        47
#  comp.  1:        52        39
#  comp.  2:       -42        62
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.928      0.41      52    39
# Comp:  1                Halpha     0.7386      0.41      52    39
# Comp:  2             [SII]6716      1.481      0.45     -42    62
# Comp:  2             [SII]6731     0.4137      0.45     -42    62
# Comp:  2              HeII4687     0.3724      0.45     -42    62
# Comp:  2               HeI5876     0.3571      0.45     -42    62
# Comp:  2          [OIII]5007_d     0.4328      0.56     -42    62
# Comp:  2            [OI]6300_d      1.591      0.56     -42    62
# Comp:  2           [NII]6583_d    0.05505      0.56     -42    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18         1
#  comp.  1:        45        44
#  comp.  2:       -27        56
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.975      0.42      45    44
# Comp:  1                Halpha     0.7816      0.42      45    44
# Comp:  2             [SII]6716      1.452      0.44     -27    56
# Comp:  2             [SII]6731     0.3633      0.44     -27    56
# Comp:  2              HeII4687     0.1927      0.44     -27    56
# Comp:  2               HeI5876      0.000      0.44     -27    56
# Comp:  2          [OIII]5007_d      1.249      0.55     -27    56
# Comp:  2            [OI]6300_d      1.101      0.55     -27    56
# Comp:  2           [NII]6583_d     0.6269      0.55     -27    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        25
#  comp.  1:        54        36
#  comp.  2:       -41        62
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.663      0.41      54    36
# Comp:  1                Halpha     0.9049      0.41      54    36
# Comp:  2             [SII]6716      1.301      0.45     -41    62
# Comp:  2             [SII]6731     0.4560      0.45     -41    62
# Comp:  2              HeII4687      0.000      0.45     -41    62
# Comp:  2               HeI5876     0.2071      0.45     -41    62
# Comp:  2          [OIII]5007_d      0.000      0.57     -41    62
# Comp:  2            [OI]6300_d      1.624      0.57     -41    62
# Comp:  2           [NII]6583_d     0.2693      0.57     -41    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:        45        64
#  comp.  2:       -41        71
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.516      0.45      45    64
# Comp:  1                Halpha      1.044      0.45      45    64
# Comp:  2             [SII]6716      1.323      0.46     -41    71
# Comp:  2             [SII]6731     0.3238      0.46     -41    71
# Comp:  2              HeII4687     0.1350      0.46     -41    71
# Comp:  2               HeI5876     0.3843      0.46     -41    71
# Comp:  2          [OIII]5007_d     0.9344      0.58     -41    71
# Comp:  2            [OI]6300_d      1.389      0.58     -41    71
# Comp:  2           [NII]6583_d      0.000      0.58     -41    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29         1
#  comp.  1:        55        68
#  comp.  2:       -38        59
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.108      0.46      55    68
# Comp:  1                Halpha      1.102      0.46      55    68
# Comp:  2             [SII]6716      1.560      0.44     -38    59
# Comp:  2             [SII]6731     0.7754      0.44     -38    59
# Comp:  2              HeII4687   0.002280      0.44     -38    59
# Comp:  2               HeI5876      0.000      0.44     -38    59
# Comp:  2          [OIII]5007_d     0.1937      0.56     -38    59
# Comp:  2            [OI]6300_d      1.259      0.56     -38    59
# Comp:  2           [NII]6583_d     0.6881      0.56     -38    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        47
#  comp.  1:        53        36
#  comp.  2:       -40        62
# chi2/DOF: 1.110; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.247      0.41      53    36
# Comp:  1                Halpha      1.009      0.41      53    36
# Comp:  2             [SII]6716      1.024      0.45     -40    62
# Comp:  2             [SII]6731     0.4029      0.45     -40    62
# Comp:  2              HeII4687     0.1124      0.45     -40    62
# Comp:  2               HeI5876      0.000      0.45     -40    62
# Comp:  2          [OIII]5007_d     0.5918      0.57     -40    62
# Comp:  2            [OI]6300_d     0.9618      0.57     -40    62
# Comp:  2           [NII]6583_d     0.1498      0.57     -40    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17         1
#  comp.  1:        54        33
#  comp.  2:       -35        43
# chi2/DOF: 1.100; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.688      0.40      54    33
# Comp:  1                Halpha     0.9039      0.40      54    33
# Comp:  2             [SII]6716      1.431      0.42     -35    43
# Comp:  2             [SII]6731     0.4471      0.42     -35    43
# Comp:  2              HeII4687    0.08282      0.42     -35    43
# Comp:  2               HeI5876      0.000      0.42     -35    43
# Comp:  2          [OIII]5007_d     0.7926      0.53     -35    43
# Comp:  2            [OI]6300_d     0.8975      0.53     -35    43
# Comp:  2           [NII]6583_d     0.2140      0.53     -35    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27         1
#  comp.  1:        58        23
#  comp.  2:       -23        39
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.979      0.39      58    23
# Comp:  1                Halpha     0.9955      0.39      58    23
# Comp:  2             [SII]6716      1.440      0.41     -23    39
# Comp:  2             [SII]6731     0.4809      0.41     -23    39
# Comp:  2              HeII4687     0.3105      0.41     -23    39
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.100      0.44      53    59
# Comp:  1                Halpha      1.398      0.44      53    59
# Comp:  2             [SII]6716      1.007      0.42     -16    41
# Comp:  2             [SII]6731     0.4345      0.42     -16    41
# Comp:  2              HeII4687     0.3588      0.42     -16    41
# Comp:  2               HeI5876      0.000      0.42     -16    41
# Comp:  2          [OIII]5007_d     0.5328      0.52     -16    41
# Comp:  2            [OI]6300_d      1.056      0.52     -16    41
# Comp:  2           [NII]6583_d      0.000      0.52     -16    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        52
#  comp.  1:        53        38
#  comp.  2:       -42        61
# chi2/DOF: 1.104; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.927      0.41      53    38
# Comp:  1                Halpha     0.6999      0.41      53    38
# Comp:  2             [SII]6716      1.570      0.45     -42    61
# Comp:  2             [SII]6731     0.5023      0.45     -42    61
# Comp:  2              HeII4687     0.2211      0.45     -42    61
# Comp:  2               HeI5876      0.000      0.45     -42    61
# Comp:  2          [OIII]5007_d      1.588      0.56     -42    61
# Comp:  2            [OI]6300_d      1.495      0.56     -42    61
# Comp:  2           [NII]6583_d     0.7860      0.56     -42    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2         1
#  comp.  1:        67        32
#  comp.  2:       -31        29
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.243      0.40      67    32
# Comp:  1                Halpha      1.042      0.40      67    32
# Comp:  2             [SII]6716      1.326      0.40     -31    29
# Comp:  2             [SII]6731     0.4570      0.40     -31    29
# Comp:  2              HeII4687     0.1485      0.40     -31    29
# Comp:  2               HeI5876    0.03117      0.40     -31    29
# Comp:  2          [OIII]5007_d    0.08224      0.51     -31    29
# Comp:  2            [OI]6300_d      1.291      0.51     -31    29
# Comp:  2           [NII]6583_d    0.07303      0.51     -31    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        24
#  comp.  1:        53        37
#  comp.  2:       -41        61
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.377      0.41      53    37
# Comp:  1                Halpha     0.6410      0.41      53    37
# Comp:  2             [SII]6716      1.496      0.45     -41    61
# Comp:  2             [SII]6731     0.6839      0.45     -41    61
# Comp:  2              HeII4687    0.06275      0.45     -41    61
# Comp:  2               HeI5876     0.7268      0.45     -41    61
# Comp:  2          [OIII]5007_d     0.9733      0.56     -41    61
# Comp:  2            [OI]6300_d      1.417      0.56     -41    61
# Comp:  2           [NII]6583_d     0.6473      0.56     -41    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16         1
#  comp.  1:        57        26
#  comp.  2:       -65        72
# chi2/DOF: 1.102; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.016      0.40      57    26
# Comp:  1                Halpha      1.036      0.40      57    26
# Comp:  2             [SII]6716      1.734      0.47     -65    72
# Comp:  2             [SII]6731     0.5474      0.47     -65    72
# Comp:  2              HeII4687     0.6329      0.47     -65    72
# Comp:  2               HeI5876     0.4297      0.47     -65    72
# Comp:  2          [OIII]5007_d     0.1145      0.59     -65    72
# Comp:  2            [OI]6300_d      1.099      0.59     -65    72
# Comp:  2           [NII]6583_d     0.1121      0.59     -65    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:        44         1
#  comp.  2:       -50        67
# chi2/DOF: 1.102; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.894      0.38      44     1
# Comp:  1                Halpha     0.8608      0.38      44     1
# Comp:  2             [SII]6716      1.413      0.46     -50    67
# Comp:  2             [SII]6731     0.5034      0.46     -50    67
# Comp:  2              HeII4687      0.000      0.46     -50    67
# Comp:  2               HeI5876     0.3115      0.46     -50    67
# Comp:  2          [OIII]5007_d     0.8407      0.58     -50    67
# Comp:  2            [OI]6300_d      1.034      0.58     -50    67
# Comp:  2           [NII]6583_d      1.074      0.58     -50    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55         1
#  comp.  1:        62         9
#  comp.  2:       -41        41
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.559      0.38      62     9
# Comp:  1                Halpha     0.7168      0.38      62     9
# Comp:  2             [SII]6716      1.383      0.41     -41    41
# Comp:  2             [SII]6731     0.3141      0.41     -41    41
# Comp:  2              HeII4687     0.1102      0.41     -41    41
# Comp:  2               HeI5876      0.000      0.41     -41    41
# Comp:  2          [OIII]5007_d      1.224      0.52     -41    41
# Comp:  2            [OI]6300_d      1.364      0.52     -41    41
# Comp:  2           [NII]6583_d     0.7950      0.52     -41    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0         1
#  comp.  1:        51         1
#  comp.  2:       -54       121
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.997      0.38      51     1
# Comp:  1                Halpha     0.8563      0.38      51     1
# Comp:  2             [SII]6716      1.467      0.55     -54   121
# Comp:  2             [SII]6731     0.4046      0.55     -54   121
# Comp:  2              HeII4687     0.5723      0.55     -54   121
# Comp:  2               HeI5876     0.2821      0.55     -54   121
# Comp:  2          [OIII]5007_d      1.296      0.70     -54   121
# Comp:  2            [OI]6300_d     0.9953      0.70     -54   121
# Comp:  2           [NII]6583_d      0.000      0.70     -54   121
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10       113
#  comp.  1:        70        74
#  comp.  2:       -39        71
# chi2/DOF: 1.102; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.982      0.47      70    74
# Comp:  1                Halpha      1.441      0.47      70    74
# Comp:  2             [SII]6716      1.768      0.46     -39    71
# Comp:  2             [SII]6731     0.5366      0.46     -39    71
# Comp:  2              HeII4687      0.000      0.46     -39    71
# Comp:  2               HeI5876      0.000      0.46     -39    71
# Comp:  2          [OIII]5007_d     0.7087      0.59     -39    71
# Comp:  2            [OI]6300_d      1.103      0.59     -39    71
# Comp:  2           [NII]6583_d      1.022      0.59     -39    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        39
#  comp.  1:        52        37
#  comp.  2:       -42        59
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.460      0.41      52    37
# Comp:  1                Halpha      1.115      0.41      52    37
# Comp:  2             [SII]6716      1.307      0.44     -42    59
# Comp:  2             [SII]6731     0.2147      0.44     -42    59
# Comp:  2              HeII4687    0.05078      0.44     -42    59
# Comp:  2               HeI5876      0.000      0.44     -42    59
# Comp:  2          [OIII]5007_d     0.6911      0.56     -42    59
# Comp:  2            [OI]6300_d     0.9270      0.56     -42    59
# Comp:  2           [NII]6583_d      0.000      0.56     -42    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22         1
#  comp.  1:        56        47
#  comp.  2:       -56        44
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.482      0.42      56    47
# Comp:  1                Halpha     0.9737      0.42      56    47
# Comp:  2             [SII]6716      1.524      0.42     -56    44
# Comp:  2             [SII]6731     0.5486      0.42     -56    44
# Comp:  2              HeII4687     0.1650      0.42     -56    44
# Comp:  2               HeI5876     0.4425      0.42     -56    44
# Comp:  2          [OIII]5007_d      1.353      0.53     -56    44
# Comp:  2            [OI]6300_d     0.9033      0.53     -56    44
# Comp:  2           [NII]6583_d      0.000      0.53     -56    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        72
#  comp.  1:        44        73
#  comp.  2:       -22        71
# chi2/DOF: 1.104; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.748      0.47      44    73
# Comp:  1                Halpha     0.7565      0.47      44    73
# Comp:  2             [SII]6716      1.437      0.46     -22    71
# Comp:  2             [SII]6731     0.3622      0.46     -22    71
# Comp:  2              HeII4687     0.2097      0.46     -22    71
# Comp:  2               HeI5876      0.000      0.46     -22    71
# Comp:  2          [OIII]5007_d     0.6384      0.59     -22    71
# Comp:  2            [OI]6300_d     0.8510      0.59     -22    71
# Comp:  2           [NII]6583_d     0.9228      0.59     -22    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        31
#  comp.  1:        56         1
#  comp.  2:       -31        38
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.334      0.38      56     1
# Comp:  1                Halpha     0.8538      0.38      56     1
# Comp:  2             [SII]6716      1.281      0.41     -31    38
# Comp:  2             [SII]6731     0.3200      0.41     -31    38
# Comp:  2              HeII4687    0.03533      0.41     -31    38
# Comp:  2               HeI5876     0.6825      0.41     -31    38
# Comp:  2          [OIII]5007_d      1.196      0.52     -31    38
# Comp:  2            [OI]6300_d     0.9945      0.52     -31    38
# Comp:  2           [NII]6583_d     0.4175      0.52     -31    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        52
#  comp.  1:        72        15
#  comp.  2:       -46        62
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 28; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.082      0.39      72    15
# Comp:  1                Halpha     0.9795      0.39      72    15
# Comp:  2             [SII]6716      1.451      0.45     -46    62
# Comp:  2             [SII]6731     0.4000      0.45     -46    62
# Comp:  2              HeII4687     0.1785      0.45     -46    62
# Comp:  2               HeI5876   0.008662      0.45     -46    62
# Comp:  2          [OIII]5007_d      1.140      0.57     -46    62
# Comp:  2            [OI]6300_d      1.081      0.57     -46    62
# Comp:  2           [NII]6583_d     0.1233      0.57     -46    62
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.62046393, 0.33334791, 0.35286121, 0.22636981, 0.18396389,
#        0.31916537, 0.51786928, 0.36588861, 0.41821506])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([1.95533974, 1.21939616, 2.01870529, 0.73612713, 0.20854098,
#        0.        , 0.77074238, 1.51759204, 0.39201719])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_7_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_7", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_7_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_7_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_7_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.059497    0.018879
# 1        Halpha  0.037104    0.010143
# 2     [SII]6716  0.061425    0.010737
# 3     [SII]6731  0.022399    0.006888
# 4      HeII4687  0.006345    0.005598
# 5       HeI5876  0.000000    0.009712
# 6  [OIII]5007_d  0.023452    0.015758
# 7    [OI]6300_d  0.046177    0.011133
# 8   [NII]6583_d  0.011928    0.012725
#           Name      Flux  Error_flux
# 0        Hbeta  0.059497    0.018879
# 1       Halpha  0.037104    0.010143
# 2    [SII]6716  0.061425    0.010737
# 3    [SII]6731  0.022399    0.006888
# 4     HeII4687  0.006345    0.005598
# 5      HeI5876  0.000000    0.009712
# 6   [OIII]4959  0.005863    0.015758
# 7   [OIII]5007  0.017589    0.015758
# 8     [OI]6300  0.034633    0.011133
# 9     [OI]6364  0.011544    0.011133
# 10   [NII]6548  0.002982    0.012725
# 11   [NII]6583  0.008946    0.012725

# %%
np.median(flux_rf_rebin)
# Out:
# 0.030427834906065095
