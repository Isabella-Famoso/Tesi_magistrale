# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_19.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_19']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.01542616 0.00509022 0.0165878  ... 0.01065949 0.01385518 0.01127734] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        72
# chi2/DOF: 0.3788; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        63
# chi2/DOF: 0.1481; DOF: 1919; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 18; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-1.8992082 , 62.58123692])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        53
#  comp.  1:      -109        30
#  comp.  2:      -115        35
# chi2/DOF: 1.755; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 46; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.70       1.0    -109    30
# Comp:  1                Halpha      21.45       1.0    -109    30
# Comp:  2             [SII]6716      7.276       1.0    -115    35
# Comp:  2             [SII]6731      3.317       1.0    -115    35
# Comp:  2              HeII4687      2.451       1.0    -115    35
# Comp:  2               HeI5876      0.000       1.0    -115    35
# Comp:  2          [OIII]5007_d      2.405       1.3    -115    35
# Comp:  2            [OI]6300_d      1.092       1.3    -115    35
# Comp:  2           [NII]6583_d      3.904       1.3    -115    35
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:   10.5; gas flux:     13 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  17.07; gas flux:     29 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  5.913; gas flux:     10 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  2.621; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  2.052; gas flux:      2 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  1.522; gas flux:      3 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.6648; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  2.313; gas flux:      5 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        75
#  comp.  1:      -105        34
#  comp.  2:      -116        38
# chi2/DOF: 1.747; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.47       1.0    -105    34
# Comp:  1                Halpha      22.30       1.0    -105    34
# Comp:  2             [SII]6716      7.335       1.0    -116    38
# Comp:  2             [SII]6731      3.463       1.0    -116    38
# Comp:  2              HeII4687      2.793       1.0    -116    38
# Comp:  2               HeI5876     0.3314       1.0    -116    38
# Comp:  2          [OIII]5007_d      4.615       1.3    -116    38
# Comp:  2            [OI]6300_d      1.280       1.3    -116    38
# Comp:  2           [NII]6583_d      3.219       1.3    -116    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        15        85
#  comp.  1:      -112        25
#  comp.  2:      -127        85
# chi2/DOF: 1.746; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.46       1.0    -112    25
# Comp:  1                Halpha      21.10       1.0    -112    25
# Comp:  2             [SII]6716      8.975       1.2    -127    85
# Comp:  2             [SII]6731      4.087       1.2    -127    85
# Comp:  2              HeII4687      4.087       1.2    -127    85
# Comp:  2               HeI5876      2.020       1.2    -127    85
# Comp:  2          [OIII]5007_d      2.883       1.6    -127    85
# Comp:  2            [OI]6300_d      0.000       1.6    -127    85
# Comp:  2           [NII]6583_d      4.681       1.6    -127    85
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        28
#  comp.  1:      -102        31
#  comp.  2:      -117         1
# chi2/DOF: 1.740; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.61       1.0    -102    31
# Comp:  1                Halpha      23.48       1.0    -102    31
# Comp:  2             [SII]6716      6.928      0.98    -117     1
# Comp:  2             [SII]6731      2.899      0.98    -117     1
# Comp:  2              HeII4687      2.208      0.98    -117     1
# Comp:  2               HeI5876     0.2227      0.98    -117     1
# Comp:  2          [OIII]5007_d      2.238       1.2    -117     1
# Comp:  2            [OI]6300_d     0.7305       1.2    -117     1
# Comp:  2           [NII]6583_d      4.069       1.2    -117     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        39
#  comp.  1:      -109        35
#  comp.  2:      -112        53
# chi2/DOF: 1.747; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.32       1.0    -109    35
# Comp:  1                Halpha      22.20       1.0    -109    35
# Comp:  2             [SII]6716      8.025       1.1    -112    53
# Comp:  2             [SII]6731      3.869       1.1    -112    53
# Comp:  2              HeII4687      2.426       1.1    -112    53
# Comp:  2               HeI5876     0.9433       1.1    -112    53
# Comp:  2          [OIII]5007_d      4.752       1.4    -112    53
# Comp:  2            [OI]6300_d      0.000       1.4    -112    53
# Comp:  2           [NII]6583_d      4.447       1.4    -112    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        78
#  comp.  1:      -113        39
#  comp.  2:      -117         8
# chi2/DOF: 1.731; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.40       1.1    -113    39
# Comp:  1                Halpha      23.48       1.1    -113    39
# Comp:  2             [SII]6716      6.779      0.98    -117     8
# Comp:  2             [SII]6731      2.910      0.98    -117     8
# Comp:  2              HeII4687      2.556      0.98    -117     8
# Comp:  2               HeI5876     0.4436      0.98    -117     8
# Comp:  2          [OIII]5007_d     0.3984       1.2    -117     8
# Comp:  2            [OI]6300_d     0.6229       1.2    -117     8
# Comp:  2           [NII]6583_d      3.868       1.2    -117     8
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15       106
#  comp.  1:      -109        34
#  comp.  2:      -108        48
# chi2/DOF: 1.740; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.75       1.0    -109    34
# Comp:  1                Halpha      22.86       1.0    -109    34
# Comp:  2             [SII]6716      7.339       1.1    -108    48
# Comp:  2             [SII]6731      3.569       1.1    -108    48
# Comp:  2              HeII4687      2.578       1.1    -108    48
# Comp:  2               HeI5876      0.000       1.1    -108    48
# Comp:  2          [OIII]5007_d      6.006       1.4    -108    48
# Comp:  2            [OI]6300_d      2.611       1.4    -108    48
# Comp:  2           [NII]6583_d      4.052       1.4    -108    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        50
#  comp.  1:      -107        29
#  comp.  2:      -120        30
# chi2/DOF: 1.749; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.48       1.0    -107    29
# Comp:  1                Halpha      22.51       1.0    -107    29
# Comp:  2             [SII]6716      6.938       1.0    -120    30
# Comp:  2             [SII]6731      3.529       1.0    -120    30
# Comp:  2              HeII4687      2.516       1.0    -120    30
# Comp:  2               HeI5876      0.000       1.0    -120    30
# Comp:  2          [OIII]5007_d      4.398       1.3    -120    30
# Comp:  2            [OI]6300_d      3.222       1.3    -120    30
# Comp:  2           [NII]6583_d      4.241       1.3    -120    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        71
#  comp.  1:      -112        41
#  comp.  2:      -107        48
# chi2/DOF: 1.745; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.43       1.1    -112    41
# Comp:  1                Halpha      21.88       1.1    -112    41
# Comp:  2             [SII]6716      8.626       1.1    -107    48
# Comp:  2             [SII]6731      3.430       1.1    -107    48
# Comp:  2              HeII4687      2.382       1.1    -107    48
# Comp:  2               HeI5876      0.000       1.1    -107    48
# Comp:  2          [OIII]5007_d      4.293       1.4    -107    48
# Comp:  2            [OI]6300_d      1.452       1.4    -107    48
# Comp:  2           [NII]6583_d      5.193       1.4    -107    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3         1
#  comp.  1:      -109        30
#  comp.  2:      -117         1
# chi2/DOF: 1.749; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.56       1.0    -109    30
# Comp:  1                Halpha      22.54       1.0    -109    30
# Comp:  2             [SII]6716      7.106      0.98    -117     1
# Comp:  2             [SII]6731      3.326      0.98    -117     1
# Comp:  2              HeII4687      2.419      0.98    -117     1
# Comp:  2               HeI5876      0.000      0.98    -117     1
# Comp:  2          [OIII]5007_d      2.343       1.2    -117     1
# Comp:  2            [OI]6300_d      1.476       1.2    -117     1
# Comp:  2           [NII]6583_d      3.568       1.2    -117     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28         1
#  comp.  1:      -107        30
#  comp.  2:      -125        29
# chi2/DOF: 1.743; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.41       1.0    -107    30
# Comp:  1                Halpha      22.85       1.0    -107    30
# Comp:  2             [SII]6716      7.365       1.0    -125    29
# Comp:  2             [SII]6731      3.136       1.0    -125    29
# Comp:  2              HeII4687      2.947       1.0    -125    29
# Comp:  2               HeI5876      1.292       1.0    -125    29
# Comp:  2          [OIII]5007_d     0.6895       1.3    -125    29
# Comp:  2            [OI]6300_d      2.488       1.3    -125    29
# Comp:  2           [NII]6583_d      3.456       1.3    -125    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -136       129
#  comp.  1:      -112        36
#  comp.  2:      -109        53
# chi2/DOF: 1.725; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.37       1.0    -112    36
# Comp:  1                Halpha      21.40       1.0    -112    36
# Comp:  2             [SII]6716      7.961       1.1    -109    53
# Comp:  2             [SII]6731      3.744       1.1    -109    53
# Comp:  2              HeII4687      2.462       1.1    -109    53
# Comp:  2               HeI5876      1.893       1.1    -109    53
# Comp:  2          [OIII]5007_d      2.884       1.4    -109    53
# Comp:  2            [OI]6300_d     0.9709       1.4    -109    53
# Comp:  2           [NII]6583_d      4.641       1.4    -109    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10         1
#  comp.  1:      -103        28
#  comp.  2:      -118         1
# chi2/DOF: 1.733; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.12       1.0    -103    28
# Comp:  1                Halpha      20.25       1.0    -103    28
# Comp:  2             [SII]6716      6.187      0.98    -118     1
# Comp:  2             [SII]6731      2.912      0.98    -118     1
# Comp:  2              HeII4687      2.674      0.98    -118     1
# Comp:  2               HeI5876      1.211      0.98    -118     1
# Comp:  2          [OIII]5007_d      0.000       1.2    -118     1
# Comp:  2            [OI]6300_d      2.242       1.2    -118     1
# Comp:  2           [NII]6583_d      3.656       1.2    -118     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        32
#  comp.  1:      -105        36
#  comp.  2:      -129        51
# chi2/DOF: 1.746; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.50       1.0    -105    36
# Comp:  1                Halpha      23.69       1.0    -105    36
# Comp:  2             [SII]6716      7.771       1.1    -129    51
# Comp:  2             [SII]6731      3.356       1.1    -129    51
# Comp:  2              HeII4687      2.929       1.1    -129    51
# Comp:  2               HeI5876      0.000       1.1    -129    51
# Comp:  2          [OIII]5007_d      2.729       1.4    -129    51
# Comp:  2            [OI]6300_d      1.613       1.4    -129    51
# Comp:  2           [NII]6583_d      4.516       1.4    -129    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        46
#  comp.  1:      -110        36
#  comp.  2:      -102        11
# chi2/DOF: 1.742; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.71       1.0    -110    36
# Comp:  1                Halpha      23.05       1.0    -110    36
# Comp:  2             [SII]6716      6.551      0.98    -102    11
# Comp:  2             [SII]6731      3.033      0.98    -102    11
# Comp:  2              HeII4687      2.089      0.98    -102    11
# Comp:  2               HeI5876      1.489      0.98    -102    11
# Comp:  2          [OIII]5007_d      4.697       1.2    -102    11
# Comp:  2            [OI]6300_d      1.354       1.2    -102    11
# Comp:  2           [NII]6583_d      3.234       1.2    -102    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        62
#  comp.  1:      -108        22
#  comp.  2:      -117        30
# chi2/DOF: 1.747; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.69       1.0    -108    22
# Comp:  1                Halpha      21.75       1.0    -108    22
# Comp:  2             [SII]6716      7.269       1.0    -117    30
# Comp:  2             [SII]6731      3.314       1.0    -117    30
# Comp:  2              HeII4687      2.910       1.0    -117    30
# Comp:  2               HeI5876      1.056       1.0    -117    30
# Comp:  2          [OIII]5007_d      2.875       1.3    -117    30
# Comp:  2            [OI]6300_d     0.3464       1.3    -117    30
# Comp:  2           [NII]6583_d      3.472       1.3    -117    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18         1
#  comp.  1:      -112        36
#  comp.  2:      -112         1
# chi2/DOF: 1.745; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.42       1.0    -112    36
# Comp:  1                Halpha      23.21       1.0    -112    36
# Comp:  2             [SII]6716      7.013      0.98    -112     1
# Comp:  2             [SII]6731      3.103      0.98    -112     1
# Comp:  2              HeII4687      2.140      0.98    -112     1
# Comp:  2               HeI5876      1.399      0.98    -112     1
# Comp:  2          [OIII]5007_d      2.341       1.2    -112     1
# Comp:  2            [OI]6300_d      0.000       1.2    -112     1
# Comp:  2           [NII]6583_d      4.084       1.2    -112     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61       120
#  comp.  1:      -112        31
#  comp.  2:      -126        53
# chi2/DOF: 1.745; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.32       1.0    -112    31
# Comp:  1                Halpha      22.34       1.0    -112    31
# Comp:  2             [SII]6716      8.094       1.1    -126    53
# Comp:  2             [SII]6731      3.387       1.1    -126    53
# Comp:  2              HeII4687      2.300       1.1    -126    53
# Comp:  2               HeI5876     0.6239       1.1    -126    53
# Comp:  2          [OIII]5007_d      4.660       1.4    -126    53
# Comp:  2            [OI]6300_d      3.777       1.4    -126    53
# Comp:  2           [NII]6583_d      4.078       1.4    -126    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        54
#  comp.  1:      -104        14
#  comp.  2:      -120        33
# chi2/DOF: 1.747; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.67      0.99    -104    14
# Comp:  1                Halpha      20.65      0.99    -104    14
# Comp:  2             [SII]6716      6.750       1.0    -120    33
# Comp:  2             [SII]6731      3.317       1.0    -120    33
# Comp:  2              HeII4687      1.926       1.0    -120    33
# Comp:  2               HeI5876     0.1910       1.0    -120    33
# Comp:  2          [OIII]5007_d      2.165       1.3    -120    33
# Comp:  2            [OI]6300_d      0.000       1.3    -120    33
# Comp:  2           [NII]6583_d      4.694       1.3    -120    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        24
#  comp.  1:      -112        33
#  comp.  2:      -120        54
# chi2/DOF: 1.744; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.55       1.0    -112    33
# Comp:  1                Halpha      23.67       1.0    -112    33
# Comp:  2             [SII]6716      7.931       1.1    -120    54
# Comp:  2             [SII]6731      3.463       1.1    -120    54
# Comp:  2              HeII4687      2.571       1.1    -120    54
# Comp:  2               HeI5876      1.186       1.1    -120    54
# Comp:  2          [OIII]5007_d      3.657       1.4    -120    54
# Comp:  2            [OI]6300_d     0.9155       1.4    -120    54
# Comp:  2           [NII]6583_d      4.320       1.4    -120    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1       152
#  comp.  1:      -109        34
#  comp.  2:      -108         1
# chi2/DOF: 1.741; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.41       1.0    -109    34
# Comp:  1                Halpha      21.82       1.0    -109    34
# Comp:  2             [SII]6716      7.383      0.98    -108     1
# Comp:  2             [SII]6731      3.138      0.98    -108     1
# Comp:  2              HeII4687      2.088      0.98    -108     1
# Comp:  2               HeI5876     0.8797      0.98    -108     1
# Comp:  2          [OIII]5007_d     0.4622       1.2    -108     1
# Comp:  2            [OI]6300_d      1.362       1.2    -108     1
# Comp:  2           [NII]6583_d      3.691       1.2    -108     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84       187
#  comp.  1:      -108        23
#  comp.  2:      -119        47
# chi2/DOF: 1.748; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.24       1.0    -108    23
# Comp:  1                Halpha      22.12       1.0    -108    23
# Comp:  2             [SII]6716      7.223       1.1    -119    47
# Comp:  2             [SII]6731      3.344       1.1    -119    47
# Comp:  2              HeII4687      2.662       1.1    -119    47
# Comp:  2               HeI5876      1.959       1.1    -119    47
# Comp:  2          [OIII]5007_d      3.338       1.4    -119    47
# Comp:  2            [OI]6300_d      1.491       1.4    -119    47
# Comp:  2           [NII]6583_d      4.269       1.4    -119    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        48
#  comp.  1:      -112        19
#  comp.  2:      -112         1
# chi2/DOF: 1.747; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.31       1.0    -112    19
# Comp:  1                Halpha      20.82       1.0    -112    19
# Comp:  2             [SII]6716      6.566      0.98    -112     1
# Comp:  2             [SII]6731      2.730      0.98    -112     1
# Comp:  2              HeII4687      2.741      0.98    -112     1
# Comp:  2               HeI5876    0.05613      0.98    -112     1
# Comp:  2          [OIII]5007_d      4.151       1.2    -112     1
# Comp:  2            [OI]6300_d     0.4430       1.2    -112     1
# Comp:  2           [NII]6583_d      3.679       1.2    -112     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:      -108        21
#  comp.  2:      -134        81
# chi2/DOF: 1.741; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.88       1.0    -108    21
# Comp:  1                Halpha      22.23       1.0    -108    21
# Comp:  2             [SII]6716      9.100       1.2    -134    81
# Comp:  2             [SII]6731      3.853       1.2    -134    81
# Comp:  2              HeII4687      2.326       1.2    -134    81
# Comp:  2               HeI5876      0.000       1.2    -134    81
# Comp:  2          [OIII]5007_d      4.839       1.5    -134    81
# Comp:  2            [OI]6300_d     0.4679       1.5    -134    81
# Comp:  2           [NII]6583_d      4.713       1.5    -134    81
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72       212
#  comp.  1:      -108        29
#  comp.  2:      -116         1
# chi2/DOF: 1.748; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.11       1.0    -108    29
# Comp:  1                Halpha      20.33       1.0    -108    29
# Comp:  2             [SII]6716      6.961      0.98    -116     1
# Comp:  2             [SII]6731      2.963      0.98    -116     1
# Comp:  2              HeII4687      2.016      0.98    -116     1
# Comp:  2               HeI5876      0.000      0.98    -116     1
# Comp:  2          [OIII]5007_d      1.004       1.2    -116     1
# Comp:  2            [OI]6300_d      0.000       1.2    -116     1
# Comp:  2           [NII]6583_d      3.154       1.2    -116     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27         1
#  comp.  1:      -108        22
#  comp.  2:      -117        35
# chi2/DOF: 1.748; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.94       1.0    -108    22
# Comp:  1                Halpha      20.98       1.0    -108    22
# Comp:  2             [SII]6716      6.818       1.0    -117    35
# Comp:  2             [SII]6731      3.214       1.0    -117    35
# Comp:  2              HeII4687      2.482       1.0    -117    35
# Comp:  2               HeI5876      0.000       1.0    -117    35
# Comp:  2          [OIII]5007_d      3.093       1.3    -117    35
# Comp:  2            [OI]6300_d      1.996       1.3    -117    35
# Comp:  2           [NII]6583_d      3.829       1.3    -117    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63         1
#  comp.  1:      -104        30
#  comp.  2:      -111         1
# chi2/DOF: 1.744; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.82       1.0    -104    30
# Comp:  1                Halpha      22.76       1.0    -104    30
# Comp:  2             [SII]6716      6.666      0.98    -111     1
# Comp:  2             [SII]6731      3.181      0.98    -111     1
# Comp:  2              HeII4687      1.662      0.98    -111     1
# Comp:  2               HeI5876      0.000      0.98    -111     1
# Comp:  2          [OIII]5007_d      2.049       1.2    -111     1
# Comp:  2            [OI]6300_d     0.4640       1.2    -111     1
# Comp:  2           [NII]6583_d      3.609       1.2    -111     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        14
#  comp.  1:      -110        43
#  comp.  2:      -112         7
# chi2/DOF: 1.745; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.37       1.1    -110    43
# Comp:  1                Halpha      22.40       1.1    -110    43
# Comp:  2             [SII]6716      6.487      0.98    -112     7
# Comp:  2             [SII]6731      3.330      0.98    -112     7
# Comp:  2              HeII4687      2.138      0.98    -112     7
# Comp:  2               HeI5876      0.000      0.98    -112     7
# Comp:  2          [OIII]5007_d      3.120       1.2    -112     7
# Comp:  2            [OI]6300_d      1.760       1.2    -112     7
# Comp:  2           [NII]6583_d      2.887       1.2    -112     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        32
#  comp.  1:      -107        26
#  comp.  2:      -120        61
# chi2/DOF: 1.748; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.49       1.0    -107    26
# Comp:  1                Halpha      21.50       1.0    -107    26
# Comp:  2             [SII]6716      8.747       1.1    -120    61
# Comp:  2             [SII]6731      3.569       1.1    -120    61
# Comp:  2              HeII4687      2.790       1.1    -120    61
# Comp:  2               HeI5876     0.3745       1.1    -120    61
# Comp:  2          [OIII]5007_d      3.978       1.4    -120    61
# Comp:  2            [OI]6300_d      2.477       1.4    -120    61
# Comp:  2           [NII]6583_d      4.258       1.4    -120    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36         1
#  comp.  1:      -106        24
#  comp.  2:      -108        54
# chi2/DOF: 1.741; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.04       1.0    -106    24
# Comp:  1                Halpha      22.50       1.0    -106    24
# Comp:  2             [SII]6716      8.158       1.1    -108    54
# Comp:  2             [SII]6731      3.639       1.1    -108    54
# Comp:  2              HeII4687      2.036       1.1    -108    54
# Comp:  2               HeI5876      1.663       1.1    -108    54
# Comp:  2          [OIII]5007_d      4.620       1.4    -108    54
# Comp:  2            [OI]6300_d     0.8763       1.4    -108    54
# Comp:  2           [NII]6583_d      4.442       1.4    -108    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        54
#  comp.  1:      -110        30
#  comp.  2:      -120        77
# chi2/DOF: 1.746; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.74       1.0    -110    30
# Comp:  1                Halpha      21.96       1.0    -110    30
# Comp:  2             [SII]6716      9.246       1.2    -120    77
# Comp:  2             [SII]6731      3.690       1.2    -120    77
# Comp:  2              HeII4687      2.811       1.2    -120    77
# Comp:  2               HeI5876     0.2531       1.2    -120    77
# Comp:  2          [OIII]5007_d      0.000       1.5    -120    77
# Comp:  2            [OI]6300_d      0.000       1.5    -120    77
# Comp:  2           [NII]6583_d      3.501       1.5    -120    77
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        30
#  comp.  1:      -111        36
#  comp.  2:      -114        14
# chi2/DOF: 1.747; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.48       1.0    -111    36
# Comp:  1                Halpha      21.11       1.0    -111    36
# Comp:  2             [SII]6716      6.411      0.99    -114    14
# Comp:  2             [SII]6731      2.939      0.99    -114    14
# Comp:  2              HeII4687      2.142      0.99    -114    14
# Comp:  2               HeI5876      0.000      0.99    -114    14
# Comp:  2          [OIII]5007_d      3.061       1.2    -114    14
# Comp:  2            [OI]6300_d     0.9424       1.2    -114    14
# Comp:  2           [NII]6583_d      3.702       1.2    -114    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        97
#  comp.  1:      -107        44
#  comp.  2:      -120        53
# chi2/DOF: 1.744; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.91       1.1    -107    44
# Comp:  1                Halpha      21.88       1.1    -107    44
# Comp:  2             [SII]6716      8.314       1.1    -120    53
# Comp:  2             [SII]6731      3.859       1.1    -120    53
# Comp:  2              HeII4687      2.759       1.1    -120    53
# Comp:  2               HeI5876      0.000       1.1    -120    53
# Comp:  2          [OIII]5007_d      1.027       1.4    -120    53
# Comp:  2            [OI]6300_d     0.9939       1.4    -120    53
# Comp:  2           [NII]6583_d      3.780       1.4    -120    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        53
#  comp.  1:      -107        27
#  comp.  2:      -115         1
# chi2/DOF: 1.746; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.80       1.0    -107    27
# Comp:  1                Halpha      21.20       1.0    -107    27
# Comp:  2             [SII]6716      6.133      0.98    -115     1
# Comp:  2             [SII]6731      3.158      0.98    -115     1
# Comp:  2              HeII4687      2.495      0.98    -115     1
# Comp:  2               HeI5876      0.000      0.98    -115     1
# Comp:  2          [OIII]5007_d      5.080       1.2    -115     1
# Comp:  2            [OI]6300_d      0.000       1.2    -115     1
# Comp:  2           [NII]6583_d      3.610       1.2    -115     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38         1
#  comp.  1:      -108        34
#  comp.  2:      -125        34
# chi2/DOF: 1.746; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.91       1.0    -108    34
# Comp:  1                Halpha      21.96       1.0    -108    34
# Comp:  2             [SII]6716      6.917       1.0    -125    34
# Comp:  2             [SII]6731      3.446       1.0    -125    34
# Comp:  2              HeII4687      2.101       1.0    -125    34
# Comp:  2               HeI5876      0.000       1.0    -125    34
# Comp:  2          [OIII]5007_d      3.827       1.3    -125    34
# Comp:  2            [OI]6300_d      2.362       1.3    -125    34
# Comp:  2           [NII]6583_d      4.926       1.3    -125    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        54
#  comp.  1:      -107        38
#  comp.  2:      -111        49
# chi2/DOF: 1.742; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.20       1.0    -107    38
# Comp:  1                Halpha      22.13       1.0    -107    38
# Comp:  2             [SII]6716      7.795       1.1    -111    49
# Comp:  2             [SII]6731      3.425       1.1    -111    49
# Comp:  2              HeII4687      2.703       1.1    -111    49
# Comp:  2               HeI5876     0.1407       1.1    -111    49
# Comp:  2          [OIII]5007_d      4.296       1.4    -111    49
# Comp:  2            [OI]6300_d      2.561       1.4    -111    49
# Comp:  2           [NII]6583_d      4.555       1.4    -111    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        98
#  comp.  1:      -112        38
#  comp.  2:      -124        49
# chi2/DOF: 1.744; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.88       1.0    -112    38
# Comp:  1                Halpha      21.15       1.0    -112    38
# Comp:  2             [SII]6716      7.111       1.1    -124    49
# Comp:  2             [SII]6731      3.138       1.1    -124    49
# Comp:  2              HeII4687      2.971       1.1    -124    49
# Comp:  2               HeI5876     0.9624       1.1    -124    49
# Comp:  2          [OIII]5007_d      2.538       1.4    -124    49
# Comp:  2            [OI]6300_d     0.3955       1.4    -124    49
# Comp:  2           [NII]6583_d      4.181       1.4    -124    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        71
#  comp.  1:      -107        19
#  comp.  2:      -119        48
# chi2/DOF: 1.747; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.59      0.99    -107    19
# Comp:  1                Halpha      21.26      0.99    -107    19
# Comp:  2             [SII]6716      8.041       1.1    -119    48
# Comp:  2             [SII]6731      3.510       1.1    -119    48
# Comp:  2              HeII4687      2.841       1.1    -119    48
# Comp:  2               HeI5876      0.000       1.1    -119    48
# Comp:  2          [OIII]5007_d      2.568       1.4    -119    48
# Comp:  2            [OI]6300_d      1.584       1.4    -119    48
# Comp:  2           [NII]6583_d      4.465       1.4    -119    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22         1
#  comp.  1:      -104        34
#  comp.  2:      -119        44
# chi2/DOF: 1.747; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.11       1.0    -104    34
# Comp:  1                Halpha      21.53       1.0    -104    34
# Comp:  2             [SII]6716      8.198       1.1    -119    44
# Comp:  2             [SII]6731      3.334       1.1    -119    44
# Comp:  2              HeII4687      2.187       1.1    -119    44
# Comp:  2               HeI5876     0.3305       1.1    -119    44
# Comp:  2          [OIII]5007_d      1.499       1.3    -119    44
# Comp:  2            [OI]6300_d      0.000       1.3    -119    44
# Comp:  2           [NII]6583_d      3.559       1.3    -119    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        94
#  comp.  1:      -111        42
#  comp.  2:      -112         1
# chi2/DOF: 1.746; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.66       1.1    -111    42
# Comp:  1                Halpha      22.60       1.1    -111    42
# Comp:  2             [SII]6716      6.607      0.98    -112     1
# Comp:  2             [SII]6731      2.980      0.98    -112     1
# Comp:  2              HeII4687      2.163      0.98    -112     1
# Comp:  2               HeI5876      0.000      0.98    -112     1
# Comp:  2          [OIII]5007_d      3.315       1.2    -112     1
# Comp:  2            [OI]6300_d      1.850       1.2    -112     1
# Comp:  2           [NII]6583_d      4.022       1.2    -112     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        83
#  comp.  1:      -112        40
#  comp.  2:      -132        63
# chi2/DOF: 1.745; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.74       1.1    -112    40
# Comp:  1                Halpha      23.05       1.1    -112    40
# Comp:  2             [SII]6716      8.625       1.1    -132    63
# Comp:  2             [SII]6731      3.600       1.1    -132    63
# Comp:  2              HeII4687      2.997       1.1    -132    63
# Comp:  2               HeI5876      0.000       1.1    -132    63
# Comp:  2          [OIII]5007_d      4.272       1.4    -132    63
# Comp:  2            [OI]6300_d      1.255       1.4    -132    63
# Comp:  2           [NII]6583_d      4.182       1.4    -132    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -153       162
#  comp.  1:      -109        27
#  comp.  2:      -118         1
# chi2/DOF: 1.741; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.27       1.0    -109    27
# Comp:  1                Halpha      22.68       1.0    -109    27
# Comp:  2             [SII]6716      7.116      0.98    -118     1
# Comp:  2             [SII]6731      3.233      0.98    -118     1
# Comp:  2              HeII4687      2.065      0.98    -118     1
# Comp:  2               HeI5876     0.5432      0.98    -118     1
# Comp:  2          [OIII]5007_d      2.753       1.2    -118     1
# Comp:  2            [OI]6300_d     0.6439       1.2    -118     1
# Comp:  2           [NII]6583_d      3.607       1.2    -118     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51         1
#  comp.  1:      -105        31
#  comp.  2:      -110        25
# chi2/DOF: 1.748; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.20       1.0    -105    31
# Comp:  1                Halpha      21.23       1.0    -105    31
# Comp:  2             [SII]6716      6.451       1.0    -110    25
# Comp:  2             [SII]6731      3.323       1.0    -110    25
# Comp:  2              HeII4687      2.627       1.0    -110    25
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.45      0.98    -107    13
# Comp:  1                Halpha      21.47      0.98    -107    13
# Comp:  2             [SII]6716      7.141       1.0    -107    29
# Comp:  2             [SII]6731      3.221       1.0    -107    29
# Comp:  2              HeII4687      2.318       1.0    -107    29
# Comp:  2               HeI5876      0.000       1.0    -107    29
# Comp:  2          [OIII]5007_d      1.370       1.3    -107    29
# Comp:  2            [OI]6300_d      1.166       1.3    -107    29
# Comp:  2           [NII]6583_d      3.501       1.3    -107    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29        82
#  comp.  1:      -108        16
#  comp.  2:      -121        34
# chi2/DOF: 1.742; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.67      0.99    -108    16
# Comp:  1                Halpha      21.45      0.99    -108    16
# Comp:  2             [SII]6716      6.793       1.0    -121    34
# Comp:  2             [SII]6731      3.437       1.0    -121    34
# Comp:  2              HeII4687      2.053       1.0    -121    34
# Comp:  2               HeI5876      1.622       1.0    -121    34
# Comp:  2          [OIII]5007_d      1.558       1.3    -121    34
# Comp:  2            [OI]6300_d      1.395       1.3    -121    34
# Comp:  2           [NII]6583_d      4.324       1.3    -121    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20         1
#  comp.  1:      -105        26
#  comp.  2:      -108        20
# chi2/DOF: 1.748; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.20       1.0    -105    26
# Comp:  1                Halpha      20.48       1.0    -105    26
# Comp:  2             [SII]6716      6.464       1.0    -108    20
# Comp:  2             [SII]6731      3.320       1.0    -108    20
# Comp:  2              HeII4687      2.677       1.0    -108    20
# Comp:  2               HeI5876      0.000       1.0    -108    20
# Comp:  2          [OIII]5007_d      3.357       1.3    -108    20
# Comp:  2            [OI]6300_d      2.931       1.3    -108    20
# Comp:  2           [NII]6583_d      4.429       1.3    -108    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        74
#  comp.  1:      -113        38
#  comp.  2:      -112        28
# chi2/DOF: 1.739; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      14.57       1.0    -113    38
# Comp:  1                Halpha      23.95       1.0    -113    38
# Comp:  2             [SII]6716      7.241       1.0    -112    28
# Comp:  2             [SII]6731      3.341       1.0    -112    28
# Comp:  2              HeII4687      2.360       1.0    -112    28
# Comp:  2               HeI5876    0.07541       1.0    -112    28
# Comp:  2          [OIII]5007_d      1.688       1.3    -112    28
# Comp:  2            [OI]6300_d      1.875       1.3    -112    28
# Comp:  2           [NII]6583_d      3.877       1.3    -112    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100        70
#  comp.  1:      -107        18
#  comp.  2:      -115         9
# chi2/DOF: 1.745; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.27      0.99    -107    18
# Comp:  1                Halpha      21.67      0.99    -107    18
# Comp:  2             [SII]6716      6.439      0.98    -115     9
# Comp:  2             [SII]6731      2.815      0.98    -115     9
# Comp:  2              HeII4687      2.276      0.98    -115     9
# Comp:  2               HeI5876     0.3511      0.98    -115     9
# Comp:  2          [OIII]5007_d      3.915       1.2    -115     9
# Comp:  2            [OI]6300_d     0.8752       1.2    -115     9
# Comp:  2           [NII]6583_d      3.629       1.2    -115     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55         1
#  comp.  1:      -114        38
#  comp.  2:      -103         1
# chi2/DOF: 1.746; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.84       1.0    -114    38
# Comp:  1                Halpha      22.60       1.0    -114    38
# Comp:  2             [SII]6716      6.640      0.98    -103     1
# Comp:  2             [SII]6731      3.208      0.98    -103     1
# Comp:  2              HeII4687      2.288      0.98    -103     1
# Comp:  2               HeI5876      0.000      0.98    -103     1
# Comp:  2          [OIII]5007_d      3.184       1.2    -103     1
# Comp:  2            [OI]6300_d     0.1088       1.2    -103     1
# Comp:  2           [NII]6583_d      4.067       1.2    -103     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        50        26
#  comp.  1:      -111        27
#  comp.  2:      -117        23
# chi2/DOF: 1.746; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.21       1.0    -111    27
# Comp:  1                Halpha      20.70       1.0    -111    27
# Comp:  2             [SII]6716      6.236       1.0    -117    23
# Comp:  2             [SII]6731      3.291       1.0    -117    23
# Comp:  2              HeII4687      2.776       1.0    -117    23
# Comp:  2               HeI5876      0.000       1.0    -117    23
# Comp:  2          [OIII]5007_d      1.938       1.3    -117    23
# Comp:  2            [OI]6300_d      1.630       1.3    -117    23
# Comp:  2           [NII]6583_d      3.614       1.3    -117    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        95
#  comp.  1:      -109        39
#  comp.  2:      -113        58
# chi2/DOF: 1.745; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      15.80       1.0    -109    39
# Comp:  1                Halpha      21.28       1.0    -109    39
# Comp:  2             [SII]6716      8.897       1.1    -113    58
# Comp:  2             [SII]6731      3.458       1.1    -113    58
# Comp:  2              HeII4687      2.486       1.1    -113    58
# Comp:  2               HeI5876     0.5909       1.1    -113    58
# Comp:  2          [OIII]5007_d      1.945       1.4    -113    58
# Comp:  2            [OI]6300_d    0.08186       1.4    -113    58
# Comp:  2           [NII]6583_d      3.993       1.4    -113    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8         1
#  comp.  1:      -107        26
#  comp.  2:      -112        50
# chi2/DOF: 1.741; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.56       1.0    -107    26
# Comp:  1                Halpha      22.52       1.0    -107    26
# Comp:  2             [SII]6716      7.080       1.1    -112    50
# Comp:  2             [SII]6731      3.683       1.1    -112    50
# Comp:  2              HeII4687      2.066       1.1    -112    50
# Comp:  2               HeI5876     0.6280       1.1    -112    50
# Comp:  2          [OIII]5007_d      4.354       1.4    -112    50
# Comp:  2            [OI]6300_d     0.5438       1.4    -112    50
# Comp:  2           [NII]6583_d      4.045       1.4    -112    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47         1
#  comp.  1:      -106         5
#  comp.  2:      -133        74
# chi2/DOF: 1.736; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.22      0.98    -106     5
# Comp:  1                Halpha      21.55      0.98    -106     5
# Comp:  2             [SII]6716      8.213       1.2    -133    74
# Comp:  2             [SII]6731      3.837       1.2    -133    74
# Comp:  2              HeII4687      3.774       1.2    -133    74
# Comp:  2               HeI5876      0.000       1.2    -133    74
# Comp:  2          [OIII]5007_d      1.613       1.5    -133    74
# Comp:  2            [OI]6300_d      1.988       1.5    -133    74
# Comp:  2           [NII]6583_d      3.097       1.5    -133    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        80
#  comp.  1:      -111        19
#  comp.  2:      -122        22
# chi2/DOF: 1.747; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.18      0.99    -111    19
# Comp:  1                Halpha      21.13      0.99    -111    19
# Comp:  2             [SII]6716      6.694       1.0    -122    22
# Comp:  2             [SII]6731      3.023       1.0    -122    22
# Comp:  2              HeII4687      2.649       1.0    -122    22
# Comp:  2               HeI5876     0.1401       1.0    -122    22
# Comp:  2          [OIII]5007_d      0.000       1.3    -122    22
# Comp:  2            [OI]6300_d     0.8265       1.3    -122    22
# Comp:  2           [NII]6583_d      3.573       1.3    -122    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:      -106        31
#  comp.  2:      -121        88
# chi2/DOF: 1.739; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.64       1.0    -106    31
# Comp:  1                Halpha      21.29       1.0    -106    31
# Comp:  2             [SII]6716      9.233       1.3    -121    88
# Comp:  2             [SII]6731      4.213       1.3    -121    88
# Comp:  2              HeII4687      3.527       1.3    -121    88
# Comp:  2               HeI5876      1.027       1.3    -121    88
# Comp:  2          [OIII]5007_d      5.662       1.6    -121    88
# Comp:  2            [OI]6300_d     0.2032       1.6    -121    88
# Comp:  2           [NII]6583_d      4.736       1.6    -121    88
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16         1
#  comp.  1:      -104        22
#  comp.  2:      -123        38
# chi2/DOF: 1.741; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.65       1.0    -104    22
# Comp:  1                Halpha      21.09       1.0    -104    22
# Comp:  2             [SII]6716      7.089       1.0    -123    38
# Comp:  2             [SII]6731      3.506       1.0    -123    38
# Comp:  2              HeII4687      1.816       1.0    -123    38
# Comp:  2               HeI5876     0.2562       1.0    -123    38
# Comp:  2          [OIII]5007_d      2.556       1.3    -123    38
# Comp:  2            [OI]6300_d     0.6073       1.3    -123    38
# Comp:  2           [NII]6583_d      3.577       1.3    -123    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        33
#  comp.  1:      -109        18
#  comp.  2:      -129        74
# chi2/DOF: 1.747; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.58      0.99    -109    18
# Comp:  1                Halpha      22.00      0.99    -109    18
# Comp:  2             [SII]6716      9.257       1.2    -129    74
# Comp:  2             [SII]6731      4.035       1.2    -129    74
# Comp:  2              HeII4687      2.325       1.2    -129    74
# Comp:  2               HeI5876      0.000       1.2    -129    74
# Comp:  2          [OIII]5007_d      1.536       1.5    -129    74
# Comp:  2            [OI]6300_d     0.9567       1.5    -129    74
# Comp:  2           [NII]6583_d      4.380       1.5    -129    74
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([1.16469634, 1.40137199, 1.24960962, 0.44841504, 0.43649213,
#        0.76652685, 1.54231184, 1.2212224 , 0.76484416])

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([12.87543876, 29.36664359, 10.19230893,  4.65619172,  2.39558065,
#         0.        ,  2.51177825,  1.43443846,  5.3613508 ])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_19_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_19", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_19_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_19_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_19_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.153767    0.013910
# 1        Halpha  0.350715    0.016736
# 2     [SII]6716  0.121723    0.014924
# 3     [SII]6731  0.055607    0.005355
# 4      HeII4687  0.028610    0.005213
# 5       HeI5876  0.000000    0.009154
# 6  [OIII]5007_d  0.029997    0.018419
# 7    [OI]6300_d  0.017131    0.014585
# 8   [NII]6583_d  0.064029    0.009134
#           Name      Flux  Error_flux
# 0        Hbeta  0.153767    0.013910
# 1       Halpha  0.350715    0.016736
# 2    [SII]6716  0.121723    0.014924
# 3    [SII]6731  0.055607    0.005355
# 4     HeII4687  0.028610    0.005213
# 5      HeI5876  0.000000    0.009154
# 6   [OIII]4959  0.007499    0.018419
# 7   [OIII]5007  0.022498    0.018419
# 8     [OI]6300  0.012848    0.014585
# 9     [OI]6364  0.004283    0.014585
# 10   [NII]6548  0.016007    0.009134
# 11   [NII]6583  0.048022    0.009134

# %%
np.median(flux_rf_rebin)
# Out:
# 0.011942640942696089
