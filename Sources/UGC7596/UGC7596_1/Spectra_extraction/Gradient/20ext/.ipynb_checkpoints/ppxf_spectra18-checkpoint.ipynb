# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_18.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_18']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.01956643 0.01170049 0.02108278 ... 0.01568095 0.01017865 0.00750139] [0.00701323 0.00701323 0.00701323 ... 0.00701323 0.00701323 0.00701323]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
# chi2/DOF: 0.2857; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -92         1
# chi2/DOF: 0.1051; DOF: 1906; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-92.32925494,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -745      1000
#  comp.  1:      -105        18
#  comp.  2:      -111        93
# chi2/DOF: 1.047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.351       1.0    -105    18
# Comp:  1                Halpha      9.319       1.0    -105    18
# Comp:  2             [SII]6716      3.838       1.3    -111    93
# Comp:  2             [SII]6731      0.000       1.3    -111    93
# Comp:  2              HeII4687      0.000       1.3    -111    93
# Comp:  2               HeI5876     0.4826       1.3    -111    93
# Comp:  2          [OIII]5007_d     0.6274       1.7    -111    93
# Comp:  2            [OI]6300_d      4.140       1.7    -111    93
# Comp:  2           [NII]6583_d      1.535       1.7    -111    93
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:   4.51; gas flux:      4 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  9.191; gas flux:     13 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  2.423; gas flux:      5 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.3103; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise: 0.3042; gas flux:      1 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.983; gas flux:      5 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise: 0.7175; gas flux:      2 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -617       514
#  comp.  1:      -108        25
#  comp.  2:      -115        85
# chi2/DOF: 1.046; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.788       1.0    -108    25
# Comp:  1                Halpha      9.363       1.0    -108    25
# Comp:  2             [SII]6716      3.506       1.3    -115    85
# Comp:  2             [SII]6731      0.000       1.3    -115    85
# Comp:  2              HeII4687      0.000       1.3    -115    85
# Comp:  2               HeI5876      1.309       1.3    -115    85
# Comp:  2          [OIII]5007_d      0.000       1.6    -115    85
# Comp:  2            [OI]6300_d      3.904       1.6    -115    85
# Comp:  2           [NII]6583_d      1.356       1.6    -115    85
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -763      1000
#  comp.  1:      -113        27
#  comp.  2:      -112        87
# chi2/DOF: 1.039; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.561       1.0    -113    27
# Comp:  1                Halpha      9.901       1.0    -113    27
# Comp:  2             [SII]6716      5.022       1.3    -112    87
# Comp:  2             [SII]6731      0.000       1.3    -112    87
# Comp:  2              HeII4687      1.137       1.3    -112    87
# Comp:  2               HeI5876     0.3302       1.3    -112    87
# Comp:  2          [OIII]5007_d     0.9184       1.6    -112    87
# Comp:  2            [OI]6300_d      3.724       1.6    -112    87
# Comp:  2           [NII]6583_d      1.329       1.6    -112    87
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -782      1000
#  comp.  1:      -100         1
#  comp.  2:      -163        83
# chi2/DOF: 1.038; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.511       1.0    -100     1
# Comp:  1                Halpha      9.461       1.0    -100     1
# Comp:  2             [SII]6716      3.142       1.3    -163    83
# Comp:  2             [SII]6731     0.2883       1.3    -163    83
# Comp:  2              HeII4687     0.4685       1.3    -163    83
# Comp:  2               HeI5876      0.000       1.3    -163    83
# Comp:  2          [OIII]5007_d      1.923       1.6    -163    83
# Comp:  2            [OI]6300_d      6.000       1.6    -163    83
# Comp:  2           [NII]6583_d      1.614       1.6    -163    83
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -753      1000
#  comp.  1:      -109         8
#  comp.  2:      -150       108
# chi2/DOF: 1.040; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.131       1.0    -109     8
# Comp:  1                Halpha      9.538       1.0    -109     8
# Comp:  2             [SII]6716      4.136       1.4    -150   108
# Comp:  2             [SII]6731      0.000       1.4    -150   108
# Comp:  2              HeII4687      1.905       1.4    -150   108
# Comp:  2               HeI5876      0.000       1.4    -150   108
# Comp:  2          [OIII]5007_d      1.082       1.7    -150   108
# Comp:  2            [OI]6300_d      2.887       1.7    -150   108
# Comp:  2           [NII]6583_d      2.153       1.7    -150   108
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -821      1000
#  comp.  1:      -113        34
#  comp.  2:      -129       101
# chi2/DOF: 1.040; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.937       1.1    -113    34
# Comp:  1                Halpha      10.66       1.1    -113    34
# Comp:  2             [SII]6716      4.118       1.3    -129   101
# Comp:  2             [SII]6731     0.5525       1.3    -129   101
# Comp:  2              HeII4687      0.000       1.3    -129   101
# Comp:  2               HeI5876      0.000       1.3    -129   101
# Comp:  2          [OIII]5007_d      0.000       1.7    -129   101
# Comp:  2            [OI]6300_d      6.022       1.7    -129   101
# Comp:  2           [NII]6583_d      1.933       1.7    -129   101
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -703      1000
#  comp.  1:      -108        32
#  comp.  2:      -113       107
# chi2/DOF: 1.034; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.714       1.0    -108    32
# Comp:  1                Halpha      10.39       1.0    -108    32
# Comp:  2             [SII]6716      3.249       1.4    -113   107
# Comp:  2             [SII]6731      0.000       1.4    -113   107
# Comp:  2              HeII4687      0.000       1.4    -113   107
# Comp:  2               HeI5876      1.609       1.4    -113   107
# Comp:  2          [OIII]5007_d      0.000       1.7    -113   107
# Comp:  2            [OI]6300_d      5.821       1.7    -113   107
# Comp:  2           [NII]6583_d      1.511       1.7    -113   107
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -559      1000
#  comp.  1:      -103        10
#  comp.  2:      -141        70
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.140       1.0    -103    10
# Comp:  1                Halpha      9.640       1.0    -103    10
# Comp:  2             [SII]6716      3.379       1.2    -141    70
# Comp:  2             [SII]6731      0.000       1.2    -141    70
# Comp:  2              HeII4687     0.1410       1.2    -141    70
# Comp:  2               HeI5876     0.1574       1.2    -141    70
# Comp:  2          [OIII]5007_d      1.984       1.5    -141    70
# Comp:  2            [OI]6300_d      6.151       1.5    -141    70
# Comp:  2           [NII]6583_d      1.829       1.5    -141    70
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -952      1000
#  comp.  1:      -113        40
#  comp.  2:      -111        69
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.070       1.1    -113    40
# Comp:  1                Halpha      9.704       1.1    -113    40
# Comp:  2             [SII]6716      3.432       1.2    -111    69
# Comp:  2             [SII]6731      0.000       1.2    -111    69
# Comp:  2              HeII4687     0.2599       1.2    -111    69
# Comp:  2               HeI5876     0.4245       1.2    -111    69
# Comp:  2          [OIII]5007_d      0.000       1.5    -111    69
# Comp:  2            [OI]6300_d      2.706       1.5    -111    69
# Comp:  2           [NII]6583_d      1.214       1.5    -111    69
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -917       743
#  comp.  1:      -108        15
#  comp.  2:       -96        30
# chi2/DOF: 1.043; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.459       1.0    -108    15
# Comp:  1                Halpha      9.942       1.0    -108    15
# Comp:  2             [SII]6716      2.684       1.0     -96    30
# Comp:  2             [SII]6731      0.000       1.0     -96    30
# Comp:  2              HeII4687      0.000       1.0     -96    30
# Comp:  2               HeI5876     0.6017       1.0     -96    30
# Comp:  2          [OIII]5007_d      0.000       1.3     -96    30
# Comp:  2            [OI]6300_d      2.308       1.3     -96    30
# Comp:  2           [NII]6583_d      1.012       1.3     -96    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -462       776
#  comp.  1:      -102         1
#  comp.  2:      -157        87
# chi2/DOF: 1.039; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.120       1.0    -102     1
# Comp:  1                Halpha      9.549       1.0    -102     1
# Comp:  2             [SII]6716      4.048       1.3    -157    87
# Comp:  2             [SII]6731    0.02067       1.3    -157    87
# Comp:  2              HeII4687      0.000       1.3    -157    87
# Comp:  2               HeI5876    0.07852       1.3    -157    87
# Comp:  2          [OIII]5007_d      3.846       1.6    -157    87
# Comp:  2            [OI]6300_d      7.411       1.6    -157    87
# Comp:  2           [NII]6583_d      1.582       1.6    -157    87
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -833      1000
#  comp.  1:      -110        33
#  comp.  2:      -139        99
# chi2/DOF: 1.043; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.142       1.1    -110    33
# Comp:  1                Halpha      9.485       1.1    -110    33
# Comp:  2             [SII]6716      3.964       1.3    -139    99
# Comp:  2             [SII]6731    0.02876       1.3    -139    99
# Comp:  2              HeII4687     0.7611       1.3    -139    99
# Comp:  2               HeI5876      0.000       1.3    -139    99
# Comp:  2          [OIII]5007_d      1.902       1.7    -139    99
# Comp:  2            [OI]6300_d      2.924       1.7    -139    99
# Comp:  2           [NII]6583_d      2.320       1.7    -139    99
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -942       932
#  comp.  1:       -99         1
#  comp.  2:      -138        92
# chi2/DOF: 1.039; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.835       1.0     -99     1
# Comp:  1                Halpha      8.487       1.0     -99     1
# Comp:  2             [SII]6716      3.215       1.3    -138    92
# Comp:  2             [SII]6731     0.3080       1.3    -138    92
# Comp:  2              HeII4687      0.000       1.3    -138    92
# Comp:  2               HeI5876      0.000       1.3    -138    92
# Comp:  2          [OIII]5007_d      4.122       1.6    -138    92
# Comp:  2            [OI]6300_d      4.295       1.6    -138    92
# Comp:  2           [NII]6583_d      1.133       1.6    -138    92
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -107       403
#  comp.  1:      -101         7
#  comp.  2:      -124        93
# chi2/DOF: 1.036; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.360       1.0    -101     7
# Comp:  1                Halpha      9.765       1.0    -101     7
# Comp:  2             [SII]6716      4.992       1.3    -124    93
# Comp:  2             [SII]6731      0.000       1.3    -124    93
# Comp:  2              HeII4687      0.000       1.3    -124    93
# Comp:  2               HeI5876      1.506       1.3    -124    93
# Comp:  2          [OIII]5007_d      0.000       1.7    -124    93
# Comp:  2            [OI]6300_d      5.531       1.7    -124    93
# Comp:  2           [NII]6583_d      1.449       1.7    -124    93
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -815       833
#  comp.  1:      -112        30
#  comp.  2:      -104        94
# chi2/DOF: 1.043; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.938       1.0    -112    30
# Comp:  1                Halpha      10.40       1.0    -112    30
# Comp:  2             [SII]6716      3.683       1.3    -104    94
# Comp:  2             [SII]6731     0.5885       1.3    -104    94
# Comp:  2              HeII4687     0.4866       1.3    -104    94
# Comp:  2               HeI5876      0.000       1.3    -104    94
# Comp:  2          [OIII]5007_d      0.000       1.7    -104    94
# Comp:  2            [OI]6300_d      3.777       1.7    -104    94
# Comp:  2           [NII]6583_d      1.704       1.7    -104    94
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -734       924
#  comp.  1:      -112        26
#  comp.  2:      -110        80
# chi2/DOF: 1.043; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.137       1.0    -112    26
# Comp:  1                Halpha      10.28       1.0    -112    26
# Comp:  2             [SII]6716      3.840       1.2    -110    80
# Comp:  2             [SII]6731    0.04778       1.2    -110    80
# Comp:  2              HeII4687     0.5435       1.2    -110    80
# Comp:  2               HeI5876     0.7628       1.2    -110    80
# Comp:  2          [OIII]5007_d      0.000       1.6    -110    80
# Comp:  2            [OI]6300_d      4.070       1.6    -110    80
# Comp:  2           [NII]6583_d      1.720       1.6    -110    80
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1134       843
#  comp.  1:      -104         1
#  comp.  2:       -73        65
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.265       1.0    -104     1
# Comp:  1                Halpha      9.353       1.0    -104     1
# Comp:  2             [SII]6716      3.323       1.2     -73    65
# Comp:  2             [SII]6731     0.2259       1.2     -73    65
# Comp:  2              HeII4687      0.000       1.2     -73    65
# Comp:  2               HeI5876     0.2448       1.2     -73    65
# Comp:  2          [OIII]5007_d      0.000       1.5     -73    65
# Comp:  2            [OI]6300_d      2.274       1.5     -73    65
# Comp:  2           [NII]6583_d      1.273       1.5     -73    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1181      1000
#  comp.  1:      -113        34
#  comp.  2:      -144       137
# chi2/DOF: 1.034; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.258       1.1    -113    34
# Comp:  1                Halpha      10.25       1.1    -113    34
# Comp:  2             [SII]6716      4.584       1.5    -144   137
# Comp:  2             [SII]6731     0.6044       1.5    -144   137
# Comp:  2              HeII4687      0.000       1.5    -144   137
# Comp:  2               HeI5876      2.195       1.5    -144   137
# Comp:  2          [OIII]5007_d     0.8672       1.9    -144   137
# Comp:  2            [OI]6300_d      8.443       1.9    -144   137
# Comp:  2           [NII]6583_d      1.761       1.9    -144   137
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1090       634
#  comp.  1:      -106        19
#  comp.  2:      -115       128
# chi2/DOF: 1.039; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 45; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.707       1.0    -106    19
# Comp:  1                Halpha      9.527       1.0    -106    19
# Comp:  2             [SII]6716      5.121       1.5    -115   128
# Comp:  2             [SII]6731      0.000       1.5    -115   128
# Comp:  2              HeII4687      0.000       1.5    -115   128
# Comp:  2               HeI5876      2.028       1.5    -115   128
# Comp:  2          [OIII]5007_d      0.000       1.9    -115   128
# Comp:  2            [OI]6300_d      4.899       1.9    -115   128
# Comp:  2           [NII]6583_d      1.798       1.9    -115   128
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -398      1000
#  comp.  1:      -105         1
#  comp.  2:      -152       129
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.261       1.0    -105     1
# Comp:  1                Halpha      9.470       1.0    -105     1
# Comp:  2             [SII]6716      4.414       1.5    -152   129
# Comp:  2             [SII]6731    0.09943       1.5    -152   129
# Comp:  2              HeII4687      1.877       1.5    -152   129
# Comp:  2               HeI5876     0.1637       1.5    -152   129
# Comp:  2          [OIII]5007_d     0.3706       1.9    -152   129
# Comp:  2            [OI]6300_d      4.261       1.9    -152   129
# Comp:  2           [NII]6583_d      1.694       1.9    -152   129
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -592       952
#  comp.  1:      -113        43
#  comp.  2:      -110         1
# chi2/DOF: 1.038; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.321       1.1    -113    43
# Comp:  1                Halpha      10.54       1.1    -113    43
# Comp:  2             [SII]6716      2.550       1.0    -110     1
# Comp:  2             [SII]6731   0.009077       1.0    -110     1
# Comp:  2              HeII4687      1.282       1.0    -110     1
# Comp:  2               HeI5876     0.1307       1.0    -110     1
# Comp:  2          [OIII]5007_d      1.789       1.3    -110     1
# Comp:  2            [OI]6300_d      3.951       1.3    -110     1
# Comp:  2           [NII]6583_d      1.173       1.3    -110     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1073      1000
#  comp.  1:      -100         1
#  comp.  2:      -164       138
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.342       1.0    -100     1
# Comp:  1                Halpha      9.295       1.0    -100     1
# Comp:  2             [SII]6716      5.087       1.5    -164   138
# Comp:  2             [SII]6731     0.2025       1.5    -164   138
# Comp:  2              HeII4687      1.512       1.5    -164   138
# Comp:  2               HeI5876      0.000       1.5    -164   138
# Comp:  2          [OIII]5007_d      4.643       1.9    -164   138
# Comp:  2            [OI]6300_d      4.537       1.9    -164   138
# Comp:  2           [NII]6583_d      1.589       1.9    -164   138
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -679      1000
#  comp.  1:      -113        22
#  comp.  2:      -157       141
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.601       1.0    -113    22
# Comp:  1                Halpha      9.828       1.0    -113    22
# Comp:  2             [SII]6716      2.411       1.5    -157   141
# Comp:  2             [SII]6731     0.3385       1.5    -157   141
# Comp:  2              HeII4687      0.000       1.5    -157   141
# Comp:  2               HeI5876      0.000       1.5    -157   141
# Comp:  2          [OIII]5007_d      0.000       1.9    -157   141
# Comp:  2            [OI]6300_d      6.892       1.9    -157   141
# Comp:  2           [NII]6583_d      2.631       1.9    -157   141
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1056      1000
#  comp.  1:      -105         1
#  comp.  2:      -113        77
# chi2/DOF: 1.039; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.057       1.0    -105     1
# Comp:  1                Halpha      9.379       1.0    -105     1
# Comp:  2             [SII]6716      4.483       1.2    -113    77
# Comp:  2             [SII]6731      0.000       1.2    -113    77
# Comp:  2              HeII4687      0.000       1.2    -113    77
# Comp:  2               HeI5876     0.8551       1.2    -113    77
# Comp:  2          [OIII]5007_d      2.594       1.6    -113    77
# Comp:  2            [OI]6300_d      2.653       1.6    -113    77
# Comp:  2           [NII]6583_d      1.339       1.6    -113    77
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -582      1000
#  comp.  1:       -96        15
#  comp.  2:      -116        79
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.037       1.0     -96    15
# Comp:  1                Halpha      8.779       1.0     -96    15
# Comp:  2             [SII]6716      3.193       1.2    -116    79
# Comp:  2             [SII]6731      0.000       1.2    -116    79
# Comp:  2              HeII4687     0.8466       1.2    -116    79
# Comp:  2               HeI5876      0.000       1.2    -116    79
# Comp:  2          [OIII]5007_d      1.758       1.6    -116    79
# Comp:  2            [OI]6300_d      2.460       1.6    -116    79
# Comp:  2           [NII]6583_d      2.120       1.6    -116    79
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1153       747
#  comp.  1:      -110         9
#  comp.  2:      -165       108
# chi2/DOF: 1.037; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.266       1.0    -110     9
# Comp:  1                Halpha      9.676       1.0    -110     9
# Comp:  2             [SII]6716      2.890       1.4    -165   108
# Comp:  2             [SII]6731     0.3036       1.4    -165   108
# Comp:  2              HeII4687      1.446       1.4    -165   108
# Comp:  2               HeI5876     0.4567       1.4    -165   108
# Comp:  2          [OIII]5007_d     0.3776       1.7    -165   108
# Comp:  2            [OI]6300_d      7.214       1.7    -165   108
# Comp:  2           [NII]6583_d      1.534       1.7    -165   108
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -972       963
#  comp.  1:      -100        16
#  comp.  2:      -129       139
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.084       1.0    -100    16
# Comp:  1                Halpha      8.947       1.0    -100    16
# Comp:  2             [SII]6716      3.080       1.5    -129   139
# Comp:  2             [SII]6731     0.1177       1.5    -129   139
# Comp:  2              HeII4687      0.000       1.5    -129   139
# Comp:  2               HeI5876      0.000       1.5    -129   139
# Comp:  2          [OIII]5007_d      1.070       1.9    -129   139
# Comp:  2            [OI]6300_d      6.575       1.9    -129   139
# Comp:  2           [NII]6583_d      2.097       1.9    -129   139
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -696      1000
#  comp.  1:      -101         5
#  comp.  2:      -116       104
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.733       1.0    -101     5
# Comp:  1                Halpha      8.754       1.0    -101     5
# Comp:  2             [SII]6716      4.236       1.4    -116   104
# Comp:  2             [SII]6731      0.000       1.4    -116   104
# Comp:  2              HeII4687      1.028       1.4    -116   104
# Comp:  2               HeI5876     0.5201       1.4    -116   104
# Comp:  2          [OIII]5007_d     0.7557       1.7    -116   104
# Comp:  2            [OI]6300_d      5.609       1.7    -116   104
# Comp:  2           [NII]6583_d      1.834       1.7    -116   104
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -797       992
#  comp.  1:      -109        26
#  comp.  2:      -145        81
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.871       1.0    -109    26
# Comp:  1                Halpha      10.06       1.0    -109    26
# Comp:  2             [SII]6716      4.550       1.3    -145    81
# Comp:  2             [SII]6731     0.2374       1.3    -145    81
# Comp:  2              HeII4687      0.000       1.3    -145    81
# Comp:  2               HeI5876     0.9842       1.3    -145    81
# Comp:  2          [OIII]5007_d      2.632       1.6    -145    81
# Comp:  2            [OI]6300_d      5.468       1.6    -145    81
# Comp:  2           [NII]6583_d      1.791       1.6    -145    81
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -723      1000
#  comp.  1:      -112        31
#  comp.  2:      -642       115
# chi2/DOF: 1.029; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 93; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.334       1.0    -112    31
# Comp:  1                Halpha      10.25       1.0    -112    31
# Comp:  2             [SII]6716      1.772       1.4    -642   115
# Comp:  2             [SII]6731      3.118       1.4    -642   115
# Comp:  2              HeII4687      0.000       1.4    -642   115
# Comp:  2               HeI5876     0.4983       1.4    -642   115
# Comp:  2          [OIII]5007_d      2.862       1.8    -642   115
# Comp:  2            [OI]6300_d      10.42       1.8    -642   115
# Comp:  2           [NII]6583_d     0.9673       1.8    -642   115
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -691      1000
#  comp.  1:      -111        28
#  comp.  2:      -144        83
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.751       1.0    -111    28
# Comp:  1                Halpha      9.883       1.0    -111    28
# Comp:  2             [SII]6716      4.775       1.3    -144    83
# Comp:  2             [SII]6731    0.03174       1.3    -144    83
# Comp:  2              HeII4687     0.8802       1.3    -144    83
# Comp:  2               HeI5876      0.000       1.3    -144    83
# Comp:  2          [OIII]5007_d      3.833       1.6    -144    83
# Comp:  2            [OI]6300_d      1.363       1.6    -144    83
# Comp:  2           [NII]6583_d      1.843       1.6    -144    83
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -999       902
#  comp.  1:      -112        34
#  comp.  2:      -119        41
# chi2/DOF: 1.035; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.157       1.1    -112    34
# Comp:  1                Halpha      9.449       1.1    -112    34
# Comp:  2             [SII]6716      2.746       1.1    -119    41
# Comp:  2             [SII]6731      0.000       1.1    -119    41
# Comp:  2              HeII4687     0.3801       1.1    -119    41
# Comp:  2               HeI5876     0.1224       1.1    -119    41
# Comp:  2          [OIII]5007_d      0.000       1.4    -119    41
# Comp:  2            [OI]6300_d      3.860       1.4    -119    41
# Comp:  2           [NII]6583_d     0.9267       1.4    -119    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -622      1000
#  comp.  1:      -108        34
#  comp.  2:      -140        86
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.422       1.1    -108    34
# Comp:  1                Halpha      9.624       1.1    -108    34
# Comp:  2             [SII]6716      3.255       1.3    -140    86
# Comp:  2             [SII]6731      0.000       1.3    -140    86
# Comp:  2              HeII4687     0.6297       1.3    -140    86
# Comp:  2               HeI5876     0.9606       1.3    -140    86
# Comp:  2          [OIII]5007_d      2.464       1.6    -140    86
# Comp:  2            [OI]6300_d      4.193       1.6    -140    86
# Comp:  2           [NII]6583_d      2.382       1.6    -140    86
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1049      1000
#  comp.  1:      -109        27
#  comp.  2:       -76        96
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.061       1.0    -109    27
# Comp:  1                Halpha      9.995       1.0    -109    27
# Comp:  2             [SII]6716      3.497       1.3     -76    96
# Comp:  2             [SII]6731      0.000       1.3     -76    96
# Comp:  2              HeII4687      0.000       1.3     -76    96
# Comp:  2               HeI5876      1.588       1.3     -76    96
# Comp:  2          [OIII]5007_d      0.000       1.7     -76    96
# Comp:  2            [OI]6300_d      3.409       1.7     -76    96
# Comp:  2           [NII]6583_d      2.007       1.7     -76    96
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -596      1000
#  comp.  1:      -106        27
#  comp.  2:      -123        83
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.852       1.0    -106    27
# Comp:  1                Halpha      9.753       1.0    -106    27
# Comp:  2             [SII]6716      4.093       1.3    -123    83
# Comp:  2             [SII]6731      0.000       1.3    -123    83
# Comp:  2              HeII4687      1.610       1.3    -123    83
# Comp:  2               HeI5876     0.8104       1.3    -123    83
# Comp:  2          [OIII]5007_d     0.5388       1.6    -123    83
# Comp:  2            [OI]6300_d      6.125       1.6    -123    83
# Comp:  2           [NII]6583_d      1.434       1.6    -123    83
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1018      1000
#  comp.  1:       -97         1
#  comp.  2:      -153       160
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.168       1.0     -97     1
# Comp:  1                Halpha      8.810       1.0     -97     1
# Comp:  2             [SII]6716      5.261       1.6    -153   160
# Comp:  2             [SII]6731      0.000       1.6    -153   160
# Comp:  2              HeII4687      0.000       1.6    -153   160
# Comp:  2               HeI5876      1.718       1.6    -153   160
# Comp:  2          [OIII]5007_d      0.000       2.0    -153   160
# Comp:  2            [OI]6300_d      6.910       2.0    -153   160
# Comp:  2           [NII]6583_d      1.963       2.0    -153   160
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -876      1000
#  comp.  1:       -99         1
#  comp.  2:      -135       144
# chi2/DOF: 1.044; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.150       1.0     -99     1
# Comp:  1                Halpha      8.289       1.0     -99     1
# Comp:  2             [SII]6716      5.332       1.5    -135   144
# Comp:  2             [SII]6731     0.1393       1.5    -135   144
# Comp:  2              HeII4687      0.000       1.5    -135   144
# Comp:  2               HeI5876     0.7823       1.5    -135   144
# Comp:  2          [OIII]5007_d     0.9922       1.9    -135   144
# Comp:  2            [OI]6300_d      4.449       1.9    -135   144
# Comp:  2           [NII]6583_d     0.7070       1.9    -135   144
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -633      1000
#  comp.  1:       -97         1
#  comp.  2:       -97       136
# chi2/DOF: 1.044; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.658       1.0     -97     1
# Comp:  1                Halpha      8.875       1.0     -97     1
# Comp:  2             [SII]6716      4.666       1.5     -97   136
# Comp:  2             [SII]6731     0.1328       1.5     -97   136
# Comp:  2              HeII4687      0.000       1.5     -97   136
# Comp:  2               HeI5876     0.3204       1.5     -97   136
# Comp:  2          [OIII]5007_d      0.000       1.9     -97   136
# Comp:  2            [OI]6300_d      4.008       1.9     -97   136
# Comp:  2           [NII]6583_d      2.610       1.9     -97   136
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -918      1000
#  comp.  1:       -99        16
#  comp.  2:      -134       113
# chi2/DOF: 1.044; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.962       1.0     -99    16
# Comp:  1                Halpha      9.064       1.0     -99    16
# Comp:  2             [SII]6716      4.680       1.4    -134   113
# Comp:  2             [SII]6731      0.000       1.4    -134   113
# Comp:  2              HeII4687      0.000       1.4    -134   113
# Comp:  2               HeI5876      1.328       1.4    -134   113
# Comp:  2          [OIII]5007_d      1.929       1.8    -134   113
# Comp:  2            [OI]6300_d      1.401       1.8    -134   113
# Comp:  2           [NII]6583_d      2.506       1.8    -134   113
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -994      1000
#  comp.  1:      -100         1
#  comp.  2:      -145       135
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.293       1.0    -100     1
# Comp:  1                Halpha      8.632       1.0    -100     1
# Comp:  2             [SII]6716      3.016       1.5    -145   135
# Comp:  2             [SII]6731     0.4939       1.5    -145   135
# Comp:  2              HeII4687     0.4616       1.5    -145   135
# Comp:  2               HeI5876      1.503       1.5    -145   135
# Comp:  2          [OIII]5007_d     0.1619       1.9    -145   135
# Comp:  2            [OI]6300_d      5.990       1.9    -145   135
# Comp:  2           [NII]6583_d      1.236       1.9    -145   135
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -763      1000
#  comp.  1:      -106        14
#  comp.  2:      -118       149
# chi2/DOF: 1.039; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.170       1.0    -106    14
# Comp:  1                Halpha      9.199       1.0    -106    14
# Comp:  2             [SII]6716      4.359       1.6    -118   149
# Comp:  2             [SII]6731      0.000       1.6    -118   149
# Comp:  2              HeII4687      0.000       1.6    -118   149
# Comp:  2               HeI5876      1.680       1.6    -118   149
# Comp:  2          [OIII]5007_d      0.000       2.0    -118   149
# Comp:  2            [OI]6300_d      2.667       2.0    -118   149
# Comp:  2           [NII]6583_d      2.429       2.0    -118   149
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1165       656
#  comp.  1:       -99         1
#  comp.  2:       -99        53
# chi2/DOF: 1.038; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.861       1.0     -99     1
# Comp:  1                Halpha      9.219       1.0     -99     1
# Comp:  2             [SII]6716      3.273       1.1     -99    53
# Comp:  2             [SII]6731    0.05159       1.1     -99    53
# Comp:  2              HeII4687      0.000       1.1     -99    53
# Comp:  2               HeI5876      0.000       1.1     -99    53
# Comp:  2          [OIII]5007_d      0.000       1.4     -99    53
# Comp:  2            [OI]6300_d      2.472       1.4     -99    53
# Comp:  2           [NII]6583_d      1.149       1.4     -99    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -552      1000
#  comp.  1:      -110        48
#  comp.  2:       -84        42
# chi2/DOF: 1.036; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.473       1.1    -110    48
# Comp:  1                Halpha      10.38       1.1    -110    48
# Comp:  2             [SII]6716      2.988       1.1     -84    42
# Comp:  2             [SII]6731      0.000       1.1     -84    42
# Comp:  2              HeII4687     0.5980       1.1     -84    42
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.547       1.0    -101     1
# Comp:  1                Halpha      9.452       1.0    -101     1
# Comp:  2             [SII]6716      2.551       1.4    -135   116
# Comp:  2             [SII]6731    0.03666       1.4    -135   116
# Comp:  2              HeII4687      1.232       1.4    -135   116
# Comp:  2               HeI5876     0.5825       1.4    -135   116
# Comp:  2          [OIII]5007_d      3.432       1.8    -135   116
# Comp:  2            [OI]6300_d      4.723       1.8    -135   116
# Comp:  2           [NII]6583_d      2.088       1.8    -135   116
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -546       848
#  comp.  1:      -108         8
#  comp.  2:      -152       111
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.246       1.0    -108     8
# Comp:  1                Halpha      9.801       1.0    -108     8
# Comp:  2             [SII]6716      4.655       1.4    -152   111
# Comp:  2             [SII]6731      0.000       1.4    -152   111
# Comp:  2              HeII4687      0.000       1.4    -152   111
# Comp:  2               HeI5876      0.000       1.4    -152   111
# Comp:  2          [OIII]5007_d      2.521       1.8    -152   111
# Comp:  2            [OI]6300_d      5.930       1.8    -152   111
# Comp:  2           [NII]6583_d      1.761       1.8    -152   111
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -695      1000
#  comp.  1:      -100         1
#  comp.  2:       -94        95
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.865       1.0    -100     1
# Comp:  1                Halpha      8.467       1.0    -100     1
# Comp:  2             [SII]6716      3.298       1.3     -94    95
# Comp:  2             [SII]6731      0.000       1.3     -94    95
# Comp:  2              HeII4687      1.269       1.3     -94    95
# Comp:  2               HeI5876     0.1315       1.3     -94    95
# Comp:  2          [OIII]5007_d      0.000       1.7     -94    95
# Comp:  2            [OI]6300_d      5.449       1.7     -94    95
# Comp:  2           [NII]6583_d      1.239       1.7     -94    95
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -517      1000
#  comp.  1:      -104         1
#  comp.  2:      -103        75
# chi2/DOF: 1.040; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.541       1.0    -104     1
# Comp:  1                Halpha      9.271       1.0    -104     1
# Comp:  2             [SII]6716      3.947       1.2    -103    75
# Comp:  2             [SII]6731     0.2705       1.2    -103    75
# Comp:  2              HeII4687     0.6629       1.2    -103    75
# Comp:  2               HeI5876     0.9025       1.2    -103    75
# Comp:  2          [OIII]5007_d     0.1279       1.5    -103    75
# Comp:  2            [OI]6300_d      4.321       1.5    -103    75
# Comp:  2           [NII]6583_d      1.293       1.5    -103    75
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -603      1000
#  comp.  1:      -107        30
#  comp.  2:      -125       101
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.485       1.0    -107    30
# Comp:  1                Halpha      10.55       1.0    -107    30
# Comp:  2             [SII]6716      4.088       1.3    -125   101
# Comp:  2             [SII]6731     0.1380       1.3    -125   101
# Comp:  2              HeII4687     0.8156       1.3    -125   101
# Comp:  2               HeI5876      1.832       1.3    -125   101
# Comp:  2          [OIII]5007_d     0.3121       1.7    -125   101
# Comp:  2            [OI]6300_d      3.487       1.7    -125   101
# Comp:  2           [NII]6583_d      1.814       1.7    -125   101
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -636      1000
#  comp.  1:      -114        43
#  comp.  2:       -67        74
# chi2/DOF: 1.043; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.575       1.1    -114    43
# Comp:  1                Halpha      10.46       1.1    -114    43
# Comp:  2             [SII]6716      2.763       1.2     -67    74
# Comp:  2             [SII]6731      0.000       1.2     -67    74
# Comp:  2              HeII4687     0.2515       1.2     -67    74
# Comp:  2               HeI5876     0.5402       1.2     -67    74
# Comp:  2          [OIII]5007_d      1.205       1.5     -67    74
# Comp:  2            [OI]6300_d      2.451       1.5     -67    74
# Comp:  2           [NII]6583_d      1.229       1.5     -67    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -387       816
#  comp.  1:      -106        24
#  comp.  2:      -109        57
# chi2/DOF: 1.038; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.724       1.0    -106    24
# Comp:  1                Halpha      9.517       1.0    -106    24
# Comp:  2             [SII]6716      3.099       1.1    -109    57
# Comp:  2             [SII]6731      0.000       1.1    -109    57
# Comp:  2              HeII4687      0.000       1.1    -109    57
# Comp:  2               HeI5876     0.8769       1.1    -109    57
# Comp:  2          [OIII]5007_d      2.802       1.4    -109    57
# Comp:  2            [OI]6300_d      5.554       1.4    -109    57
# Comp:  2           [NII]6583_d      1.304       1.4    -109    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -1026      1000
#  comp.  1:      -108        44
#  comp.  2:      -120       121
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.041       1.1    -108    44
# Comp:  1                Halpha      9.961       1.1    -108    44
# Comp:  2             [SII]6716      4.547       1.4    -120   121
# Comp:  2             [SII]6731      0.000       1.4    -120   121
# Comp:  2              HeII4687     0.2145       1.4    -120   121
# Comp:  2               HeI5876      1.164       1.4    -120   121
# Comp:  2          [OIII]5007_d     0.4590       1.8    -120   121
# Comp:  2            [OI]6300_d      2.796       1.8    -120   121
# Comp:  2           [NII]6583_d      1.965       1.8    -120   121
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -891       841
#  comp.  1:      -109        18
#  comp.  2:      -138       112
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.874       1.0    -109    18
# Comp:  1                Halpha      10.09       1.0    -109    18
# Comp:  2             [SII]6716      4.961       1.4    -138   112
# Comp:  2             [SII]6731     0.1782       1.4    -138   112
# Comp:  2              HeII4687      0.000       1.4    -138   112
# Comp:  2               HeI5876     0.5586       1.4    -138   112
# Comp:  2          [OIII]5007_d      4.056       1.8    -138   112
# Comp:  2            [OI]6300_d      1.387       1.8    -138   112
# Comp:  2           [NII]6583_d      2.028       1.8    -138   112
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -608       935
#  comp.  1:      -107        29
#  comp.  2:      -125        64
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.658       1.0    -107    29
# Comp:  1                Halpha      10.54       1.0    -107    29
# Comp:  2             [SII]6716      3.694       1.2    -125    64
# Comp:  2             [SII]6731      0.000       1.2    -125    64
# Comp:  2              HeII4687      0.000       1.2    -125    64
# Comp:  2               HeI5876     0.9344       1.2    -125    64
# Comp:  2          [OIII]5007_d     0.5680       1.5    -125    64
# Comp:  2            [OI]6300_d      5.215       1.5    -125    64
# Comp:  2           [NII]6583_d      2.076       1.5    -125    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -857      1000
#  comp.  1:      -101         1
#  comp.  2:      -292       281
# chi2/DOF: 1.036; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.698       1.0    -101     1
# Comp:  1                Halpha      9.200       1.0    -101     1
# Comp:  2             [SII]6716      3.493       2.2    -292   281
# Comp:  2             [SII]6731     0.5976       2.2    -292   281
# Comp:  2              HeII4687     0.7583       2.1    -292   281
# Comp:  2               HeI5876      1.327       2.1    -292   281
# Comp:  2          [OIII]5007_d      6.358       2.6    -292   281
# Comp:  2            [OI]6300_d      12.85       2.6    -292   281
# Comp:  2           [NII]6583_d      0.000       2.6    -292   281
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -470      1000
#  comp.  1:      -113        36
#  comp.  2:      -108        91
# chi2/DOF: 1.044; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.671       1.1    -113    36
# Comp:  1                Halpha      9.536       1.1    -113    36
# Comp:  2             [SII]6716      3.704       1.3    -108    91
# Comp:  2             [SII]6731      0.000       1.3    -108    91
# Comp:  2              HeII4687      0.000       1.3    -108    91
# Comp:  2               HeI5876     0.8941       1.3    -108    91
# Comp:  2          [OIII]5007_d      0.000       1.6    -108    91
# Comp:  2            [OI]6300_d      3.077       1.6    -108    91
# Comp:  2           [NII]6583_d      1.569       1.6    -108    91
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -599      1000
#  comp.  1:       -97         1
#  comp.  2:      -123       135
# chi2/DOF: 1.043; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.416       1.0     -97     1
# Comp:  1                Halpha      8.857       1.0     -97     1
# Comp:  2             [SII]6716      5.233       1.5    -123   135
# Comp:  2             [SII]6731     0.1318       1.5    -123   135
# Comp:  2              HeII4687      0.000       1.5    -123   135
# Comp:  2               HeI5876      1.491       1.5    -123   135
# Comp:  2          [OIII]5007_d      3.053       1.9    -123   135
# Comp:  2            [OI]6300_d      3.045       1.9    -123   135
# Comp:  2           [NII]6583_d      2.364       1.9    -123   135
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16      1000
#  comp.  1:      -113        30
#  comp.  2:      -130        82
# chi2/DOF: 1.038; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.438       1.0    -113    30
# Comp:  1                Halpha      10.38       1.0    -113    30
# Comp:  2             [SII]6716      4.174       1.3    -130    82
# Comp:  2             [SII]6731      0.000       1.3    -130    82
# Comp:  2              HeII4687      0.000       1.3    -130    82
# Comp:  2               HeI5876     0.6705       1.3    -130    82
# Comp:  2          [OIII]5007_d     0.3250       1.6    -130    82
# Comp:  2            [OI]6300_d      4.824       1.6    -130    82
# Comp:  2           [NII]6583_d      1.773       1.6    -130    82
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.55397175, 0.82419339, 1.38361798, 0.66151166, 0.68363323,
#        0.68732073, 1.38909599, 3.01978935, 0.79695839])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 4.41162871, 12.75597551,  5.37630831,  0.        ,  0.        ,
#         0.59145225,  0.65518778,  5.44051363,  2.10711006])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_18_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_18", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_18_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_18_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_18_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.060235    0.007564
# 1        Halpha  0.174167    0.011253
# 2     [SII]6716  0.073407    0.018892
# 3     [SII]6731  0.000000    0.009032
# 4      HeII4687  0.000000    0.009334
# 5       HeI5876  0.008076    0.009384
# 6  [OIII]5007_d  0.008946    0.018966
# 7    [OI]6300_d  0.074283    0.041231
# 8   [NII]6583_d  0.028770    0.010881
#           Name      Flux  Error_flux
# 0        Hbeta  0.060235    0.007564
# 1       Halpha  0.174167    0.011253
# 2    [SII]6716  0.073407    0.018892
# 3    [SII]6731  0.000000    0.009032
# 4     HeII4687  0.000000    0.009334
# 5      HeI5876  0.008076    0.009384
# 6   [OIII]4959  0.002236    0.018966
# 7   [OIII]5007  0.006709    0.018966
# 8     [OI]6300  0.055712    0.041231
# 9     [OI]6364  0.018571    0.041231
# 10   [NII]6548  0.007192    0.010881
# 11   [NII]6583  0.021577    0.010881

# %%
np.median(flux_rf_rebin)
# Out:
# 0.013653730974935614
