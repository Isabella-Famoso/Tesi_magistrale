# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_1.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/UGC7596/UGC7596_1/Spectra_extraction/Gradient/redshift_grad.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -106         4
# chi2/DOF: 0.1133; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:      -114         1
# chi2/DOF: 0.07904; DOF: 1915; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-114.12392324,    0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -72        80
#  comp.  1:        35       132
#  comp.  2:       -95        42
# chi2/DOF: 0.9599; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.808       1.1      35   132
# Comp:  1                Halpha      0.000       1.1      35   132
# Comp:  2             [SII]6716     0.6670      0.78     -95    42
# Comp:  2             [SII]6731      11.49      0.78     -95    42
# Comp:  2              HeII4687      0.000      0.78     -95    42
# Comp:  2               HeI5876      0.000      0.78     -95    42
# Comp:  2          [OIII]5007_d      1.027      0.98     -95    42
# Comp:  2            [OI]6300_d      0.000      0.98     -95    42
# Comp:  2           [NII]6583_d      0.000      0.98     -95    42
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  1.645; gas flux:      3 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise: 0.7053; gas flux:      1 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  12.64; gas flux:     16 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise: 0.8353; gas flux:      1 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -91       115
#  comp.  1:         8       244
#  comp.  2:       -97        44
# chi2/DOF: 0.9540; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.156       1.4       8   244
# Comp:  1                Halpha      0.000       1.4       8   244
# Comp:  2             [SII]6716     0.7136      0.78     -97    44
# Comp:  2             [SII]6731      11.54      0.78     -97    44
# Comp:  2              HeII4687     0.5788      0.78     -97    44
# Comp:  2               HeI5876      0.000      0.78     -97    44
# Comp:  2          [OIII]5007_d     0.8029      0.99     -97    44
# Comp:  2            [OI]6300_d      1.760      0.99     -97    44
# Comp:  2           [NII]6583_d     0.8851      0.99     -97    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86        45
#  comp.  1:       -48        71
#  comp.  2:       -90        55
# chi2/DOF: 0.9507; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.737      0.87     -48    71
# Comp:  1                Halpha     0.5384      0.87     -48    71
# Comp:  2             [SII]6716     0.6930      0.81     -90    55
# Comp:  2             [SII]6731      12.17      0.81     -90    55
# Comp:  2              HeII4687     0.6575      0.81     -90    55
# Comp:  2               HeI5876     0.8296      0.81     -90    55
# Comp:  2          [OIII]5007_d      1.434       1.0     -90    55
# Comp:  2            [OI]6300_d      0.000       1.0     -90    55
# Comp:  2           [NII]6583_d     0.2930       1.0     -90    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        91
#  comp.  1:       -57       451
#  comp.  2:       -99        35
# chi2/DOF: 0.9530; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.23       1.9     -57   451
# Comp:  1                Halpha      2.163       1.9     -57   451
# Comp:  2             [SII]6716     0.6604      0.76     -99    35
# Comp:  2             [SII]6731      11.06      0.76     -99    35
# Comp:  2              HeII4687      0.000      0.76     -99    35
# Comp:  2               HeI5876      0.000      0.76     -99    35
# Comp:  2          [OIII]5007_d      1.758      0.96     -99    35
# Comp:  2            [OI]6300_d      0.000      0.96     -99    35
# Comp:  2           [NII]6583_d      0.000      0.97     -99    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        39
#  comp.  1:        20       136
#  comp.  2:       -87        60
# chi2/DOF: 0.9521; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.537       1.1      20   136
# Comp:  1                Halpha     0.8857       1.1      20   136
# Comp:  2             [SII]6716     0.8128      0.83     -87    60
# Comp:  2             [SII]6731      12.12      0.83     -87    60
# Comp:  2              HeII4687      0.000      0.83     -87    60
# Comp:  2               HeI5876      1.251      0.83     -87    60
# Comp:  2          [OIII]5007_d     0.8660       1.0     -87    60
# Comp:  2            [OI]6300_d      0.000       1.0     -87    60
# Comp:  2           [NII]6583_d      1.185       1.0     -87    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71        64
#  comp.  1:        75       301
#  comp.  2:      -101        41
# chi2/DOF: 0.9535; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.332       1.5      75   301
# Comp:  1                Halpha     0.6235       1.5      75   301
# Comp:  2             [SII]6716     0.8596      0.78    -101    41
# Comp:  2             [SII]6731      11.45      0.78    -101    41
# Comp:  2              HeII4687      0.000      0.78    -101    41
# Comp:  2               HeI5876     0.2982      0.78    -101    41
# Comp:  2          [OIII]5007_d     0.8214      0.98    -101    41
# Comp:  2            [OI]6300_d      2.203      0.98    -101    41
# Comp:  2           [NII]6583_d      0.000      0.98    -101    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83         1
#  comp.  1:        14       176
#  comp.  2:       -98        43
# chi2/DOF: 0.9533; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.580       1.2      14   176
# Comp:  1                Halpha     0.9352       1.2      14   176
# Comp:  2             [SII]6716     0.5483      0.78     -98    43
# Comp:  2             [SII]6731      11.93      0.78     -98    43
# Comp:  2              HeII4687     0.4548      0.78     -98    43
# Comp:  2               HeI5876      0.000      0.78     -98    43
# Comp:  2          [OIII]5007_d      1.329      0.99     -98    43
# Comp:  2            [OI]6300_d      1.823      0.99     -98    43
# Comp:  2           [NII]6583_d     0.4956      0.99     -98    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        56
#  comp.  1:       -34       185
#  comp.  2:       -94        44
# chi2/DOF: 0.9567; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.286       1.2     -34   185
# Comp:  1                Halpha      0.000       1.2     -34   185
# Comp:  2             [SII]6716     0.5862      0.78     -94    44
# Comp:  2             [SII]6731      11.23      0.78     -94    44
# Comp:  2              HeII4687      0.000      0.78     -94    44
# Comp:  2               HeI5876      0.000      0.78     -94    44
# Comp:  2          [OIII]5007_d      1.301      0.99     -94    44
# Comp:  2            [OI]6300_d      0.000      0.99     -94    44
# Comp:  2           [NII]6583_d      0.000      0.99     -94    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        28
#  comp.  1:        20         1
#  comp.  2:       -93        49
# chi2/DOF: 0.9530; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.8651      0.71      20     1
# Comp:  1                Halpha      0.000      0.71      20     1
# Comp:  2             [SII]6716     0.6459      0.80     -93    49
# Comp:  2             [SII]6731      11.78      0.80     -93    49
# Comp:  2              HeII4687      0.000      0.80     -93    49
# Comp:  2               HeI5876      0.000      0.80     -93    49
# Comp:  2          [OIII]5007_d     0.9221       1.0     -93    49
# Comp:  2            [OI]6300_d      1.375       1.0     -93    49
# Comp:  2           [NII]6583_d      0.000       1.0     -93    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17       149
#  comp.  1:        53       379
#  comp.  2:       -96        31
# chi2/DOF: 0.9534; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.024       1.7      53   379
# Comp:  1                Halpha      2.629       1.7      53   379
# Comp:  2             [SII]6716     0.6543      0.75     -96    31
# Comp:  2             [SII]6731      11.10      0.75     -96    31
# Comp:  2              HeII4687     0.4845      0.75     -96    31
# Comp:  2               HeI5876      0.000      0.75     -96    31
# Comp:  2          [OIII]5007_d      1.533      0.95     -96    31
# Comp:  2            [OI]6300_d      0.000      0.95     -96    31
# Comp:  2           [NII]6583_d      0.000      0.95     -96    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89         1
#  comp.  1:       113        21
#  comp.  2:       -96        35
# chi2/DOF: 0.9466; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.367      0.73     113    21
# Comp:  1                Halpha      0.000      0.73     113    21
# Comp:  2             [SII]6716     0.7084      0.76     -96    35
# Comp:  2             [SII]6731      10.70      0.76     -96    35
# Comp:  2              HeII4687     0.5933      0.76     -96    35
# Comp:  2               HeI5876     0.8042      0.76     -96    35
# Comp:  2          [OIII]5007_d      1.314      0.96     -96    35
# Comp:  2            [OI]6300_d     0.1636      0.96     -96    35
# Comp:  2           [NII]6583_d      0.000      0.96     -96    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -160       133
#  comp.  1:      -153       237
#  comp.  2:       -95        42
# chi2/DOF: 0.9526; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.828       1.4    -153   237
# Comp:  1                Halpha      0.000       1.4    -153   237
# Comp:  2             [SII]6716     0.7105      0.78     -95    42
# Comp:  2             [SII]6731      11.01      0.78     -95    42
# Comp:  2              HeII4687      0.000      0.78     -95    42
# Comp:  2               HeI5876      1.008      0.78     -95    42
# Comp:  2          [OIII]5007_d     0.8202      0.98     -95    42
# Comp:  2            [OI]6300_d      1.023      0.98     -95    42
# Comp:  2           [NII]6583_d    0.01911      0.98     -95    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        96
#  comp.  1:        36       207
#  comp.  2:       -98        43
# chi2/DOF: 0.9526; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.555       1.3      36   207
# Comp:  1                Halpha      1.314       1.3      36   207
# Comp:  2             [SII]6716     0.5348      0.78     -98    43
# Comp:  2             [SII]6731      11.47      0.78     -98    43
# Comp:  2              HeII4687    0.07596      0.78     -98    43
# Comp:  2               HeI5876     0.1883      0.78     -98    43
# Comp:  2          [OIII]5007_d     0.8491      0.98     -98    43
# Comp:  2            [OI]6300_d    0.04812      0.98     -98    43
# Comp:  2           [NII]6583_d      0.000      0.98     -98    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        88
#  comp.  1:        96       132
#  comp.  2:       -90        58
# chi2/DOF: 0.9542; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.404       1.1      96   132
# Comp:  1                Halpha     0.1975       1.1      96   132
# Comp:  2             [SII]6716     0.6088      0.82     -90    58
# Comp:  2             [SII]6731      11.89      0.82     -90    58
# Comp:  2              HeII4687     0.3167      0.82     -90    58
# Comp:  2               HeI5876     0.3351      0.82     -90    58
# Comp:  2          [OIII]5007_d      1.733       1.0     -90    58
# Comp:  2            [OI]6300_d     0.3146       1.0     -90    58
# Comp:  2           [NII]6583_d      0.000       1.0     -90    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83        83
#  comp.  1:      -105       236
#  comp.  2:       -96        34
# chi2/DOF: 0.9508; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.477       1.4    -105   236
# Comp:  1                Halpha      2.002       1.4    -105   236
# Comp:  2             [SII]6716     0.7667      0.76     -96    34
# Comp:  2             [SII]6731      10.81      0.76     -96    34
# Comp:  2              HeII4687      0.000      0.76     -96    34
# Comp:  2               HeI5876    0.07612      0.76     -96    34
# Comp:  2          [OIII]5007_d      1.132      0.96     -96    34
# Comp:  2            [OI]6300_d     0.5615      0.96     -96    34
# Comp:  2           [NII]6583_d     0.5406      0.96     -96    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        53
#  comp.  1:        11        77
#  comp.  2:       -97        34
# chi2/DOF: 0.9532; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 45; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.776      0.88      11    77
# Comp:  1                Halpha      0.000      0.88      11    77
# Comp:  2             [SII]6716     0.7253      0.76     -97    34
# Comp:  2             [SII]6731      10.75      0.76     -97    34
# Comp:  2              HeII4687      0.000      0.76     -97    34
# Comp:  2               HeI5876    0.02702      0.76     -97    34
# Comp:  2          [OIII]5007_d      1.520      0.96     -97    34
# Comp:  2            [OI]6300_d      0.000      0.96     -97    34
# Comp:  2           [NII]6583_d     0.7888      0.96     -97    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        87
#  comp.  1:        71        84
#  comp.  2:       -99        32
# chi2/DOF: 0.9543; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta     0.9473      0.91      71    84
# Comp:  1                Halpha    0.04625      0.91      71    84
# Comp:  2             [SII]6716     0.8006      0.75     -99    32
# Comp:  2             [SII]6731      11.55      0.75     -99    32
# Comp:  2              HeII4687      0.000      0.75     -99    32
# Comp:  2               HeI5876     0.2213      0.75     -99    32
# Comp:  2          [OIII]5007_d     0.4088      0.95     -99    32
# Comp:  2            [OI]6300_d     0.2337      0.95     -99    32
# Comp:  2           [NII]6583_d      0.000      0.95     -99    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89        48
#  comp.  1:       -41       178
#  comp.  2:       -99        32
# chi2/DOF: 0.9545; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.491       1.2     -41   178
# Comp:  1                Halpha     0.5341       1.2     -41   178
# Comp:  2             [SII]6716     0.7283      0.75     -99    32
# Comp:  2             [SII]6731      11.51      0.75     -99    32
# Comp:  2              HeII4687      0.000      0.75     -99    32
# Comp:  2               HeI5876    0.04364      0.75     -99    32
# Comp:  2          [OIII]5007_d      1.447      0.95     -99    32
# Comp:  2            [OI]6300_d      0.000      0.95     -99    32
# Comp:  2           [NII]6583_d     0.6458      0.95     -99    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        24
#  comp.  1:        66         1
#  comp.  2:       -93        47
# chi2/DOF: 0.9523; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.655      0.71      66     1
# Comp:  1                Halpha     0.2243      0.71      66     1
# Comp:  2             [SII]6716     0.6878      0.79     -93    47
# Comp:  2             [SII]6731      11.85      0.79     -93    47
# Comp:  2              HeII4687      0.000      0.79     -93    47
# Comp:  2               HeI5876      0.000      0.79     -93    47
# Comp:  2          [OIII]5007_d     0.4116       1.0     -93    47
# Comp:  2            [OI]6300_d     0.4112       1.0     -93    47
# Comp:  2           [NII]6583_d      0.000       1.0     -93    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         2
#  comp.  1:       -53       176
#  comp.  2:       -96        41
# chi2/DOF: 0.9555; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 24; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.327       1.2     -53   176
# Comp:  1                Halpha     0.8791       1.2     -53   176
# Comp:  2             [SII]6716     0.5991      0.77     -96    41
# Comp:  2             [SII]6731      10.88      0.77     -96    41
# Comp:  2              HeII4687      0.000      0.77     -96    41
# Comp:  2               HeI5876     0.3659      0.77     -96    41
# Comp:  2          [OIII]5007_d     0.7615      0.98     -96    41
# Comp:  2            [OI]6300_d      0.000      0.98     -96    41
# Comp:  2           [NII]6583_d      0.000      0.98     -96    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        80
#  comp.  1:       -12       112
#  comp.  2:       -92        49
# chi2/DOF: 0.9556; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.997       1.0     -12   112
# Comp:  1                Halpha     0.1211       1.0     -12   112
# Comp:  2             [SII]6716     0.8056      0.80     -92    49
# Comp:  2             [SII]6731      11.61      0.80     -92    49
# Comp:  2              HeII4687      0.000      0.80     -92    49
# Comp:  2               HeI5876     0.9805      0.80     -92    49
# Comp:  2          [OIII]5007_d     0.8358       1.0     -92    49
# Comp:  2            [OI]6300_d      0.000       1.0     -92    49
# Comp:  2           [NII]6583_d      0.000       1.0     -92    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54       161
#  comp.  1:        36       326
#  comp.  2:       -97        47
# chi2/DOF: 0.9529; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.94       1.6      36   326
# Comp:  1                Halpha      1.081       1.6      36   326
# Comp:  2             [SII]6716     0.7078      0.79     -97    47
# Comp:  2             [SII]6731      11.36      0.79     -97    47
# Comp:  2              HeII4687      0.000      0.79     -97    47
# Comp:  2               HeI5876     0.5365      0.79     -97    47
# Comp:  2          [OIII]5007_d     0.8167       1.0     -97    47
# Comp:  2            [OI]6300_d     0.4127       1.0     -97    47
# Comp:  2           [NII]6583_d      0.000       1.0     -97    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        27
#  comp.  1:        15       146
#  comp.  2:       -99        44
# chi2/DOF: 0.9534; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.764       1.1      15   146
# Comp:  1                Halpha     0.2571       1.1      15   146
# Comp:  2             [SII]6716     0.3558      0.78     -99    44
# Comp:  2             [SII]6731      11.44      0.78     -99    44
# Comp:  2              HeII4687     0.1465      0.78     -99    44
# Comp:  2               HeI5876      0.000      0.78     -99    44
# Comp:  2          [OIII]5007_d     0.5815      0.99     -99    44
# Comp:  2            [OI]6300_d     0.9179      0.99     -99    44
# Comp:  2           [NII]6583_d      0.000      0.99     -99    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100       104
#  comp.  1:       -68       238
#  comp.  2:       -97        33
# chi2/DOF: 0.9546; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.54       1.4     -68   238
# Comp:  1                Halpha      1.381       1.4     -68   238
# Comp:  2             [SII]6716     0.6491      0.75     -97    33
# Comp:  2             [SII]6731      10.64      0.75     -97    33
# Comp:  2              HeII4687      0.000      0.75     -97    33
# Comp:  2               HeI5876      0.000      0.75     -97    33
# Comp:  2          [OIII]5007_d      1.047      0.95     -97    33
# Comp:  2            [OI]6300_d      0.000      0.95     -97    33
# Comp:  2           [NII]6583_d      0.000      0.95     -97    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        70
#  comp.  1:         4       216
#  comp.  2:       -98        38
# chi2/DOF: 0.9547; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.122       1.3       4   216
# Comp:  1                Halpha      1.750       1.3       4   216
# Comp:  2             [SII]6716     0.6087      0.77     -98    38
# Comp:  2             [SII]6731      11.66      0.77     -98    38
# Comp:  2              HeII4687      0.000      0.77     -98    38
# Comp:  2               HeI5876      0.000      0.77     -98    38
# Comp:  2          [OIII]5007_d      1.252      0.97     -98    38
# Comp:  2            [OI]6300_d      0.000      0.97     -98    38
# Comp:  2           [NII]6583_d      1.239      0.97     -98    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92       129
#  comp.  1:        25       121
#  comp.  2:       -95        45
# chi2/DOF: 0.9499; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.548       1.0      25   121
# Comp:  1                Halpha     0.6853       1.0      25   121
# Comp:  2             [SII]6716     0.5657      0.78     -95    45
# Comp:  2             [SII]6731      11.57      0.78     -95    45
# Comp:  2              HeII4687      0.000      0.78     -95    45
# Comp:  2               HeI5876     0.1694      0.78     -95    45
# Comp:  2          [OIII]5007_d      1.433      0.99     -95    45
# Comp:  2            [OI]6300_d     0.2174      0.99     -95    45
# Comp:  2           [NII]6583_d     0.4572      0.99     -95    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        76
#  comp.  1:       -43       162
#  comp.  2:       -99        39
# chi2/DOF: 0.9529; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.776       1.2     -43   162
# Comp:  1                Halpha      0.000       1.2     -43   162
# Comp:  2             [SII]6716     0.6440      0.77     -99    39
# Comp:  2             [SII]6731      11.71      0.77     -99    39
# Comp:  2              HeII4687      0.000      0.77     -99    39
# Comp:  2               HeI5876      0.000      0.77     -99    39
# Comp:  2          [OIII]5007_d      1.813      0.97     -99    39
# Comp:  2            [OI]6300_d     0.8488      0.97     -99    39
# Comp:  2           [NII]6583_d      0.000      0.97     -99    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        39       244
#  comp.  1:       183       222
#  comp.  2:       -96        33
# chi2/DOF: 0.9513; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.625       1.3     183   222
# Comp:  1                Halpha      1.345       1.3     183   222
# Comp:  2             [SII]6716     0.5429      0.76     -96    33
# Comp:  2             [SII]6731      11.02      0.76     -96    33
# Comp:  2              HeII4687      0.000      0.76     -96    33
# Comp:  2               HeI5876      0.000      0.76     -96    33
# Comp:  2          [OIII]5007_d     0.7262      0.95     -96    33
# Comp:  2            [OI]6300_d     0.7662      0.95     -96    33
# Comp:  2           [NII]6583_d     0.8509      0.95     -96    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92       127
#  comp.  1:        63       101
#  comp.  2:       -98        43
# chi2/DOF: 0.9535; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.370      0.97      63   101
# Comp:  1                Halpha     0.6814      0.97      63   101
# Comp:  2             [SII]6716     0.7692      0.78     -98    43
# Comp:  2             [SII]6731      11.85      0.78     -98    43
# Comp:  2              HeII4687     0.6189      0.78     -98    43
# Comp:  2               HeI5876     0.3763      0.78     -98    43
# Comp:  2          [OIII]5007_d      1.375      0.98     -98    43
# Comp:  2            [OI]6300_d     0.1529      0.98     -98    43
# Comp:  2           [NII]6583_d     0.7269      0.98     -98    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        59
#  comp.  1:        49        96
#  comp.  2:       -95        42
# chi2/DOF: 0.9528; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.930      0.95      49    96
# Comp:  1                Halpha     0.1936      0.95      49    96
# Comp:  2             [SII]6716     0.7581      0.78     -95    42
# Comp:  2             [SII]6731      11.93      0.78     -95    42
# Comp:  2              HeII4687      0.000      0.78     -95    42
# Comp:  2               HeI5876     0.6584      0.78     -95    42
# Comp:  2          [OIII]5007_d     0.8643      0.98     -95    42
# Comp:  2            [OI]6300_d     0.6381      0.98     -95    42
# Comp:  2           [NII]6583_d      0.000      0.98     -95    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        48
#  comp.  1:        -7       269
#  comp.  2:       -98        50
# chi2/DOF: 0.9523; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.789       1.5      -7   269
# Comp:  1                Halpha      0.000       1.5      -7   269
# Comp:  2             [SII]6716     0.9096      0.80     -98    50
# Comp:  2             [SII]6731      11.97      0.80     -98    50
# Comp:  2              HeII4687      0.000      0.80     -98    50
# Comp:  2               HeI5876      0.000      0.80     -98    50
# Comp:  2          [OIII]5007_d      1.548       1.0     -98    50
# Comp:  2            [OI]6300_d     0.1225       1.0     -98    50
# Comp:  2           [NII]6583_d      1.148       1.0     -98    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16       139
#  comp.  1:        22       216
#  comp.  2:       -98        37
# chi2/DOF: 0.9534; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.497       1.3      22   216
# Comp:  1                Halpha      1.951       1.3      22   216
# Comp:  2             [SII]6716     0.5935      0.77     -98    37
# Comp:  2             [SII]6731      11.61      0.77     -98    37
# Comp:  2              HeII4687     0.7809      0.77     -98    37
# Comp:  2               HeI5876      0.000      0.77     -98    37
# Comp:  2          [OIII]5007_d      1.417      0.97     -98    37
# Comp:  2            [OI]6300_d      0.000      0.97     -98    37
# Comp:  2           [NII]6583_d      0.000      0.97     -98    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        45
#  comp.  1:        44       155
#  comp.  2:       -92        39
# chi2/DOF: 0.9518; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.606       1.1      44   155
# Comp:  1                Halpha     0.6224       1.1      44   155
# Comp:  2             [SII]6716     0.6137      0.77     -92    39
# Comp:  2             [SII]6731      11.42      0.77     -92    39
# Comp:  2              HeII4687   0.005343      0.77     -92    39
# Comp:  2               HeI5876      0.000      0.77     -92    39
# Comp:  2          [OIII]5007_d      1.202      0.97     -92    39
# Comp:  2            [OI]6300_d      0.000      0.97     -92    39
# Comp:  2           [NII]6583_d      0.000      0.97     -92    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95        59
#  comp.  1:        51        58
#  comp.  2:       -90        53
# chi2/DOF: 0.9557; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.592      0.82      51    58
# Comp:  1                Halpha      0.000      0.82      51    58
# Comp:  2             [SII]6716     0.6006      0.81     -90    53
# Comp:  2             [SII]6731      12.21      0.81     -90    53
# Comp:  2              HeII4687     0.6646      0.81     -90    53
# Comp:  2               HeI5876      0.000      0.81     -90    53
# Comp:  2          [OIII]5007_d      1.183       1.0     -90    53
# Comp:  2            [OI]6300_d    0.03290       1.0     -90    53
# Comp:  2           [NII]6583_d     0.8380       1.0     -90    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74       131
#  comp.  1:        80       176
#  comp.  2:       -92        50
# chi2/DOF: 0.9524; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.374       1.2      80   176
# Comp:  1                Halpha     0.4160       1.2      80   176
# Comp:  2             [SII]6716     0.5811      0.80     -92    50
# Comp:  2             [SII]6731      12.29      0.80     -92    50
# Comp:  2              HeII4687      0.000      0.80     -92    50
# Comp:  2               HeI5876     0.6606      0.80     -92    50
# Comp:  2          [OIII]5007_d      2.014       1.0     -92    50
# Comp:  2            [OI]6300_d    0.01292       1.0     -92    50
# Comp:  2           [NII]6583_d      0.000       1.0     -92    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92       111
#  comp.  1:        22       224
#  comp.  2:       -94        48
# chi2/DOF: 0.9448; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.670       1.3      22   224
# Comp:  1                Halpha      1.660       1.3      22   224
# Comp:  2             [SII]6716     0.8239      0.79     -94    48
# Comp:  2             [SII]6731      11.41      0.79     -94    48
# Comp:  2              HeII4687     0.5218      0.79     -94    48
# Comp:  2               HeI5876     0.6963      0.79     -94    48
# Comp:  2          [OIII]5007_d      1.288       1.0     -94    48
# Comp:  2            [OI]6300_d      0.000       1.0     -94    48
# Comp:  2           [NII]6583_d     0.4755       1.0     -94    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        70
#  comp.  1:        18       107
#  comp.  2:       -97        44
# chi2/DOF: 0.9515; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.691      0.99      18   107
# Comp:  1                Halpha     0.3838      0.99      18   107
# Comp:  2             [SII]6716     0.5677      0.78     -97    44
# Comp:  2             [SII]6731      12.01      0.78     -97    44
# Comp:  2              HeII4687      1.339      0.78     -97    44
# Comp:  2               HeI5876      0.000      0.78     -97    44
# Comp:  2          [OIII]5007_d      1.273      0.99     -97    44
# Comp:  2            [OI]6300_d      1.095      0.99     -97    44
# Comp:  2           [NII]6583_d      0.000      0.99     -97    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83       117
#  comp.  1:       -35       221
#  comp.  2:       -96        55
# chi2/DOF: 0.9517; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.888       1.3     -35   221
# Comp:  1                Halpha     0.9616       1.3     -35   221
# Comp:  2             [SII]6716     0.7971      0.82     -96    55
# Comp:  2             [SII]6731      12.84      0.82     -96    55
# Comp:  2              HeII4687     0.7415      0.82     -96    55
# Comp:  2               HeI5876    0.06866      0.82     -96    55
# Comp:  2          [OIII]5007_d      0.000       1.0     -96    55
# Comp:  2            [OI]6300_d     0.8827       1.0     -96    55
# Comp:  2           [NII]6583_d      0.000       1.0     -96    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -152        85
#  comp.  1:       -95       159
#  comp.  2:       -91        53
# chi2/DOF: 0.9497; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.342       1.2     -95   159
# Comp:  1                Halpha      0.000       1.2     -95   159
# Comp:  2             [SII]6716     0.8577      0.81     -91    53
# Comp:  2             [SII]6731      12.14      0.81     -91    53
# Comp:  2              HeII4687     0.3542      0.81     -91    53
# Comp:  2               HeI5876      0.000      0.81     -91    53
# Comp:  2          [OIII]5007_d      1.207       1.0     -91    53
# Comp:  2            [OI]6300_d     0.5709       1.0     -91    53
# Comp:  2           [NII]6583_d    0.03859       1.0     -91    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        70       178
#  comp.  1:       245       204
#  comp.  2:      -100        41
# chi2/DOF: 0.9464; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 66; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.757       1.3     245   204
# Comp:  1                Halpha      2.329       1.3     245   204
# Comp:  2             [SII]6716     0.4864      0.78    -100    41
# Comp:  2             [SII]6731      11.40      0.78    -100    41
# Comp:  2              HeII4687     0.7285      0.78    -100    41
# Comp:  2               HeI5876      0.000      0.78    -100    41
# Comp:  2          [OIII]5007_d     0.7724      0.98    -100    41
# Comp:  2            [OI]6300_d      2.072      0.98    -100    41
# Comp:  2           [NII]6583_d     0.3762      0.98    -100    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -111         1
#  comp.  1:      -192       340
#  comp.  2:       -95        39
# chi2/DOF: 0.9548; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.228       1.6    -192   340
# Comp:  1                Halpha      3.369       1.6    -192   340
# Comp:  2             [SII]6716     0.7374      0.77     -95    39
# Comp:  2             [SII]6731      11.79      0.77     -95    39
# Comp:  2              HeII4687     0.1804      0.77     -95    39
# Comp:  2               HeI5876      0.000      0.77     -95    39
# Comp:  2          [OIII]5007_d      1.629      0.97     -95    39
# Comp:  2            [OI]6300_d    0.02465      0.97     -95    39
# Comp:  2           [NII]6583_d      0.000      0.98     -95    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        96
#  comp.  1:        36       221
#  comp.  2:       -95        42
# chi2/DOF: 0.9482; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.887       1.3      36   221
# Comp:  1                Halpha     0.6056       1.3      36   221
# Comp:  2             [SII]6716     0.7258      0.78     -95    42
# Comp:  2             [SII]6731      12.02      0.78     -95    42
# Comp:  2              HeII4687      0.000      0.78     -95    42
# Comp:  2               HeI5876      0.000      0.78     -95    42
# Comp:  2          [OIII]5007_d      1.455      0.98     -95    42
# Comp:  2            [OI]6300_d      0.000      0.98     -95    42
# Comp:  2           [NII]6583_d      0.000      0.98     -95    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        77
#  comp.  1:        59        61
#  comp.  2:       -92        43
# chi2/DOF: 0.9535; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.657      0.83      59    61
# Comp:  1                Halpha      0.000      0.83      59    61
# Comp:  2             [SII]6716     0.3369      0.78     -92    43
# Comp:  2             [SII]6731      11.11      0.78     -92    43
# Comp:  2              HeII4687     0.5322      0.78     -92    43
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.714      0.95      86    95
# Comp:  1                Halpha     0.9109      0.95      86    95
# Comp:  2             [SII]6716     0.6869      0.77     -94    40
# Comp:  2             [SII]6731      11.40      0.77     -94    40
# Comp:  2              HeII4687      0.000      0.77     -94    40
# Comp:  2               HeI5876      0.000      0.77     -94    40
# Comp:  2          [OIII]5007_d     0.2653      0.98     -94    40
# Comp:  2            [OI]6300_d      0.000      0.98     -94    40
# Comp:  2           [NII]6583_d      0.000      0.98     -94    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86       114
#  comp.  1:       -26       158
#  comp.  2:       -95        47
# chi2/DOF: 0.9534; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.118       1.1     -26   158
# Comp:  1                Halpha      1.278       1.1     -26   158
# Comp:  2             [SII]6716     0.5591      0.79     -95    47
# Comp:  2             [SII]6731      11.31      0.79     -95    47
# Comp:  2              HeII4687      0.000      0.79     -95    47
# Comp:  2               HeI5876     0.3173      0.79     -95    47
# Comp:  2          [OIII]5007_d      1.860       1.0     -95    47
# Comp:  2            [OI]6300_d      1.942       1.0     -95    47
# Comp:  2           [NII]6583_d     0.3105       1.0     -95    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -115       153
#  comp.  1:        90       107
#  comp.  2:       -94        40
# chi2/DOF: 0.9501; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.486      0.98      90   107
# Comp:  1                Halpha      0.000      0.98      90   107
# Comp:  2             [SII]6716     0.4268      0.77     -94    40
# Comp:  2             [SII]6731      10.88      0.77     -94    40
# Comp:  2              HeII4687      0.000      0.77     -94    40
# Comp:  2               HeI5876      0.000      0.77     -94    40
# Comp:  2          [OIII]5007_d     0.6848      0.98     -94    40
# Comp:  2            [OI]6300_d     0.2430      0.98     -94    40
# Comp:  2           [NII]6583_d      0.000      0.98     -94    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        74
#  comp.  1:        -7       203
#  comp.  2:       -95        34
# chi2/DOF: 0.9528; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.951       1.3      -7   203
# Comp:  1                Halpha   0.003005       1.3      -7   203
# Comp:  2             [SII]6716     0.6609      0.76     -95    34
# Comp:  2             [SII]6731      10.68      0.76     -95    34
# Comp:  2              HeII4687      0.000      0.76     -95    34
# Comp:  2               HeI5876     0.5501      0.76     -95    34
# Comp:  2          [OIII]5007_d      1.590      0.96     -95    34
# Comp:  2            [OI]6300_d      0.000      0.96     -95    34
# Comp:  2           [NII]6583_d      0.000      0.96     -95    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71        54
#  comp.  1:        41        72
#  comp.  2:      -102        38
# chi2/DOF: 0.9524; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 31; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.121      0.87      41    72
# Comp:  1                Halpha      0.000      0.87      41    72
# Comp:  2             [SII]6716     0.6401      0.77    -102    38
# Comp:  2             [SII]6731      11.25      0.77    -102    38
# Comp:  2              HeII4687      0.000      0.77    -102    38
# Comp:  2               HeI5876      0.000      0.77    -102    38
# Comp:  2          [OIII]5007_d     0.7040      0.97    -102    38
# Comp:  2            [OI]6300_d     0.8126      0.97    -102    38
# Comp:  2           [NII]6583_d      0.000      0.97    -102    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        71
#  comp.  1:       108       153
#  comp.  2:       -94        45
# chi2/DOF: 0.9522; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.092       1.1     108   153
# Comp:  1                Halpha      0.000       1.1     108   153
# Comp:  2             [SII]6716     0.6706      0.79     -94    45
# Comp:  2             [SII]6731      11.40      0.79     -94    45
# Comp:  2              HeII4687     0.6204      0.79     -94    45
# Comp:  2               HeI5876    0.03246      0.79     -94    45
# Comp:  2          [OIII]5007_d     0.5207      0.99     -94    45
# Comp:  2            [OI]6300_d   0.005945      0.99     -94    45
# Comp:  2           [NII]6583_d      0.000      0.99     -94    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        95
#  comp.  1:        60       103
#  comp.  2:       -96        40
# chi2/DOF: 0.9546; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.738      0.97      60   103
# Comp:  1                Halpha     0.5389      0.97      60   103
# Comp:  2             [SII]6716     0.5525      0.77     -96    40
# Comp:  2             [SII]6731      11.80      0.77     -96    40
# Comp:  2              HeII4687     0.3197      0.77     -96    40
# Comp:  2               HeI5876      0.000      0.77     -96    40
# Comp:  2          [OIII]5007_d      1.797      0.97     -96    40
# Comp:  2            [OI]6300_d      0.000      0.97     -96    40
# Comp:  2           [NII]6583_d      0.000      0.97     -96    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -90        59
#  comp.  1:       -87       322
#  comp.  2:       -97        32
# chi2/DOF: 0.9522; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.313       1.6     -87   322
# Comp:  1                Halpha      1.173       1.6     -87   322
# Comp:  2             [SII]6716     0.7707      0.75     -97    32
# Comp:  2             [SII]6731      11.03      0.75     -97    32
# Comp:  2              HeII4687      0.000      0.75     -97    32
# Comp:  2               HeI5876     0.2314      0.75     -97    32
# Comp:  2          [OIII]5007_d     0.3676      0.95     -97    32
# Comp:  2            [OI]6300_d      0.000      0.95     -97    32
# Comp:  2           [NII]6583_d      0.000      0.95     -97    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54       211
#  comp.  1:        80       109
#  comp.  2:       -90        60
# chi2/DOF: 0.9540; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.547      0.99      80   109
# Comp:  1                Halpha      0.000      0.99      80   109
# Comp:  2             [SII]6716     0.5795      0.83     -90    60
# Comp:  2             [SII]6731      11.96      0.83     -90    60
# Comp:  2              HeII4687      0.000      0.83     -90    60
# Comp:  2               HeI5876      0.000      0.83     -90    60
# Comp:  2          [OIII]5007_d     0.7518       1.0     -90    60
# Comp:  2            [OI]6300_d    0.08726       1.0     -90    60
# Comp:  2           [NII]6583_d      1.027       1.0     -90    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18       183
#  comp.  1:       128        67
#  comp.  2:       -92        40
# chi2/DOF: 0.9555; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.166      0.85     128    67
# Comp:  1                Halpha     0.9218      0.85     128    67
# Comp:  2             [SII]6716     0.3830      0.77     -92    40
# Comp:  2             [SII]6731      11.33      0.77     -92    40
# Comp:  2              HeII4687     0.2269      0.77     -92    40
# Comp:  2               HeI5876      0.000      0.77     -92    40
# Comp:  2          [OIII]5007_d     0.2825      0.97     -92    40
# Comp:  2            [OI]6300_d     0.6115      0.97     -92    40
# Comp:  2           [NII]6583_d      0.000      0.97     -92    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        75
#  comp.  1:        75       168
#  comp.  2:       -95        43
# chi2/DOF: 0.9545; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.280       1.2      75   168
# Comp:  1                Halpha     0.9596       1.2      75   168
# Comp:  2             [SII]6716     0.5800      0.78     -95    43
# Comp:  2             [SII]6731      11.58      0.78     -95    43
# Comp:  2              HeII4687      0.000      0.78     -95    43
# Comp:  2               HeI5876     0.6137      0.78     -95    43
# Comp:  2          [OIII]5007_d     0.8431      0.99     -95    43
# Comp:  2            [OI]6300_d      0.000      0.99     -95    43
# Comp:  2           [NII]6583_d      0.000      0.99     -95    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89        86
#  comp.  1:        70       140
#  comp.  2:       -93        46
# chi2/DOF: 0.9543; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.425       1.1      70   140
# Comp:  1                Halpha      0.000       1.1      70   140
# Comp:  2             [SII]6716     0.6585      0.79     -93    46
# Comp:  2             [SII]6731      12.14      0.79     -93    46
# Comp:  2              HeII4687      0.000      0.79     -93    46
# Comp:  2               HeI5876      0.000      0.79     -93    46
# Comp:  2          [OIII]5007_d      1.159       1.0     -93    46
# Comp:  2            [OI]6300_d      0.000       1.0     -93    46
# Comp:  2           [NII]6583_d      0.000       1.0     -93    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        36
#  comp.  1:        17        52
#  comp.  2:       -93        44
# chi2/DOF: 0.9542; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.907      0.80      17    52
# Comp:  1                Halpha      0.000      0.80      17    52
# Comp:  2             [SII]6716     0.4651      0.78     -93    44
# Comp:  2             [SII]6731      11.68      0.78     -93    44
# Comp:  2              HeII4687      0.000      0.78     -93    44
# Comp:  2               HeI5876     0.4863      0.78     -93    44
# Comp:  2          [OIII]5007_d      1.977      0.99     -93    44
# Comp:  2            [OI]6300_d   0.008106      0.99     -93    44
# Comp:  2           [NII]6583_d     0.5790      0.99     -93    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17       144
#  comp.  1:       117       128
#  comp.  2:       -93        45
# chi2/DOF: 0.9540; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.836       1.1     117   128
# Comp:  1                Halpha     0.8235       1.1     117   128
# Comp:  2             [SII]6716     0.6345      0.79     -93    45
# Comp:  2             [SII]6731      11.28      0.79     -93    45
# Comp:  2              HeII4687     0.1611      0.79     -93    45
# Comp:  2               HeI5876      0.000      0.79     -93    45
# Comp:  2          [OIII]5007_d      1.341      0.99     -93    45
# Comp:  2            [OI]6300_d      0.000      0.99     -93    45
# Comp:  2           [NII]6583_d     0.1159      0.99     -93    45
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([3.80731389, 1.35271858, 0.18232947, 0.66068287, 0.3490873 ,
#        0.40480638, 0.4909882 , 0.73100355, 0.47586939])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_7616\2709300755.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(8, 6))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 2.84727503,  0.        ,  0.93443066, 16.13753675,  0.        ,
#         0.        ,  1.07282221,  0.        ,  0.        ])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_1_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_1", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_1_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_1_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_1_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.046402    0.062048
# 1        Halpha  0.000000    0.022045
# 2     [SII]6716  0.015228    0.002971
# 3     [SII]6731  0.262995    0.010767
# 4      HeII4687  0.000000    0.005689
# 5       HeI5876  0.000000    0.006597
# 6  [OIII]5007_d  0.017484    0.008002
# 7    [OI]6300_d  0.000000    0.011913
# 8   [NII]6583_d  0.000000    0.007755
#           Name      Flux  Error_flux
# 0        Hbeta  0.046402    0.062048
# 1       Halpha  0.000000    0.022045
# 2    [SII]6716  0.015228    0.002971
# 3    [SII]6731  0.262995    0.010767
# 4     HeII4687  0.000000    0.005689
# 5      HeI5876  0.000000    0.006597
# 6   [OIII]4959  0.004371    0.008002
# 7   [OIII]5007  0.013113    0.008002
# 8     [OI]6300  0.000000    0.011913
# 9     [OI]6364  0.000000    0.011913
# 10   [NII]6548  0.000000    0.007755
# 11   [NII]6583  0.000000    0.007755

# %%
np.median(flux_rf_rebin)
# Out:
# 0.016297082283322162
