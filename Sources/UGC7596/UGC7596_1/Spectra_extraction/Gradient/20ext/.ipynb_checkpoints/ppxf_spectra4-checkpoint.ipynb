# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_4.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC5058/FORS2.2022-01-28T08_17_47.181/Spectra_extraction/Gradient/redshift_grad.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_4']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -25         1
# chi2/DOF: 0.05940; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -29         1
# chi2/DOF: 0.03990; DOF: 1915; degree = 4; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-28.96064929,   0.62529643])

# %%
z
# Out:
# 0.00189

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        27
#  comp.  1:       197       231
#  comp.  2:      -117       171
# chi2/DOF: 1.118; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.108      0.92     197   231
# Comp:  1                Halpha      2.875      0.92     197   231
# Comp:  2             [SII]6716     0.6414      0.80    -117   171
# Comp:  2             [SII]6731      1.231      0.80    -117   171
# Comp:  2              HeII4687      1.135      0.80    -117   171
# Comp:  2               HeI5876      0.000      0.80    -117   171
# Comp:  2          [OIII]5007_d      1.730       1.0    -117   171
# Comp:  2            [OI]6300_d      2.745       1.0    -117   171
# Comp:  2           [NII]6583_d     0.6409       1.0    -117   171
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  3.059; gas flux:      6 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  1.443; gas flux:      4 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise: 0.4224; gas flux:      1 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise: 0.8043; gas flux:      2 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.7506; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise: 0.8603; gas flux:      2 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.354; gas flux:      4 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise: 0.3158; gas flux:      1 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        61
#  comp.  1:       118       206
#  comp.  2:       106       208
# chi2/DOF: 1.109; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.032      0.87     118   206
# Comp:  1                Halpha      3.313      0.87     118   206
# Comp:  2             [SII]6716     0.4612      0.88     106   208
# Comp:  2             [SII]6731      1.066      0.88     106   208
# Comp:  2              HeII4687      1.875      0.87     106   208
# Comp:  2               HeI5876      0.000      0.87     106   208
# Comp:  2          [OIII]5007_d     0.7131       1.1     106   208
# Comp:  2            [OI]6300_d      3.512       1.1     106   208
# Comp:  2           [NII]6583_d     0.5890       1.1     106   208
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2         1
#  comp.  1:       122       210
#  comp.  2:       -17        89
# chi2/DOF: 1.094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.867      0.88     122   210
# Comp:  1                Halpha      3.760      0.88     122   210
# Comp:  2             [SII]6716     0.6802      0.62     -17    89
# Comp:  2             [SII]6731     0.8750      0.62     -17    89
# Comp:  2              HeII4687     0.5254      0.62     -17    89
# Comp:  2               HeI5876      1.418      0.62     -17    89
# Comp:  2          [OIII]5007_d      2.802      0.79     -17    89
# Comp:  2            [OI]6300_d      1.158      0.79     -17    89
# Comp:  2           [NII]6583_d     0.3211      0.79     -17    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        25
#  comp.  1:       163       219
#  comp.  2:      -208        35
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 60; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.901      0.90     163   219
# Comp:  1                Halpha      2.687      0.90     163   219
# Comp:  2             [SII]6716     0.4349      0.51    -208    35
# Comp:  2             [SII]6731     0.5675      0.51    -208    35
# Comp:  2              HeII4687     0.7514      0.51    -208    35
# Comp:  2               HeI5876      0.000      0.51    -208    35
# Comp:  2          [OIII]5007_d      0.000      0.65    -208    35
# Comp:  2            [OI]6300_d      2.560      0.65    -208    35
# Comp:  2           [NII]6583_d     0.3323      0.65    -208    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        41
#  comp.  1:       187       225
#  comp.  2:       -92       125
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.875      0.91     187   225
# Comp:  1                Halpha      3.245      0.91     187   225
# Comp:  2             [SII]6716     0.4807      0.70     -92   125
# Comp:  2             [SII]6731      1.130      0.70     -92   125
# Comp:  2              HeII4687     0.8823      0.70     -92   125
# Comp:  2               HeI5876     0.8898      0.70     -92   125
# Comp:  2          [OIII]5007_d   0.006206      0.89     -92   125
# Comp:  2            [OI]6300_d      1.513      0.89     -92   125
# Comp:  2           [NII]6583_d      1.810      0.89     -92   125
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24         1
#  comp.  1:       182       237
#  comp.  2:      -114       132
# chi2/DOF: 1.112; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.517      0.93     182   237
# Comp:  1                Halpha      3.000      0.93     182   237
# Comp:  2             [SII]6716      1.157      0.72    -114   132
# Comp:  2             [SII]6731      1.175      0.72    -114   132
# Comp:  2              HeII4687      2.308      0.72    -114   132
# Comp:  2               HeI5876    0.06600      0.72    -114   132
# Comp:  2          [OIII]5007_d      1.267      0.91    -114   132
# Comp:  2            [OI]6300_d      3.050      0.91    -114   132
# Comp:  2           [NII]6583_d     0.4401      0.91    -114   132
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38         1
#  comp.  1:       189       173
#  comp.  2:      -181       168
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.807      0.80     189   173
# Comp:  1                Halpha      2.022      0.81     189   173
# Comp:  2             [SII]6716     0.6108      0.80    -181   168
# Comp:  2             [SII]6731      1.433      0.80    -181   168
# Comp:  2              HeII4687      1.404      0.80    -181   168
# Comp:  2               HeI5876      0.000      0.80    -181   168
# Comp:  2          [OIII]5007_d      0.000       1.0    -181   168
# Comp:  2            [OI]6300_d      3.866       1.0    -181   168
# Comp:  2           [NII]6583_d      0.000       1.0    -181   168
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        52
#  comp.  1:        90       223
#  comp.  2:      -146       130
# chi2/DOF: 1.101; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.081      0.90      90   223
# Comp:  1                Halpha      4.554      0.90      90   223
# Comp:  2             [SII]6716     0.8870      0.71    -146   130
# Comp:  2             [SII]6731     0.7679      0.71    -146   130
# Comp:  2              HeII4687      1.480      0.71    -146   130
# Comp:  2               HeI5876     0.1544      0.71    -146   130
# Comp:  2          [OIII]5007_d     0.8067      0.90    -146   130
# Comp:  2            [OI]6300_d      4.822      0.90    -146   130
# Comp:  2           [NII]6583_d      1.559      0.90    -146   130
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        52
#  comp.  1:       240       226
#  comp.  2:       -75        35
# chi2/DOF: 1.104; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.472      0.91     240   226
# Comp:  1                Halpha      2.881      0.91     240   226
# Comp:  2             [SII]6716     0.1278      0.51     -75    35
# Comp:  2             [SII]6731     0.5225      0.51     -75    35
# Comp:  2              HeII4687     0.9647      0.51     -75    35
# Comp:  2               HeI5876      0.000      0.51     -75    35
# Comp:  2          [OIII]5007_d     0.3247      0.65     -75    35
# Comp:  2            [OI]6300_d      1.467      0.65     -75    35
# Comp:  2           [NII]6583_d     0.4813      0.65     -75    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92       111
#  comp.  1:       -22       340
#  comp.  2:      -167       145
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      20.45       1.1     -22   340
# Comp:  1                Halpha      6.982       1.1     -22   340
# Comp:  2             [SII]6716    0.08338      0.75    -167   145
# Comp:  2             [SII]6731      1.324      0.75    -167   145
# Comp:  2              HeII4687      1.015      0.75    -167   145
# Comp:  2               HeI5876      0.000      0.75    -167   145
# Comp:  2          [OIII]5007_d      1.381      0.94    -167   145
# Comp:  2            [OI]6300_d      1.508      0.94    -167   145
# Comp:  2           [NII]6583_d      1.248      0.95    -167   145
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100        76
#  comp.  1:        43       338
#  comp.  2:      -160        84
# chi2/DOF: 1.100; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.64       1.1      43   338
# Comp:  1                Halpha      5.587       1.1      43   338
# Comp:  2             [SII]6716     0.5456      0.61    -160    84
# Comp:  2             [SII]6731     0.6589      0.61    -160    84
# Comp:  2              HeII4687     0.5054      0.61    -160    84
# Comp:  2               HeI5876     0.7607      0.61    -160    84
# Comp:  2          [OIII]5007_d     0.4361      0.77    -160    84
# Comp:  2            [OI]6300_d      4.164      0.77    -160    84
# Comp:  2           [NII]6583_d      0.000      0.78    -160    84
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70       108
#  comp.  1:       193       204
#  comp.  2:      -150       158
# chi2/DOF: 1.104; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.817      0.87     193   204
# Comp:  1                Halpha      2.702      0.87     193   204
# Comp:  2             [SII]6716     0.9283      0.77    -150   158
# Comp:  2             [SII]6731     0.9369      0.77    -150   158
# Comp:  2              HeII4687      1.495      0.77    -150   158
# Comp:  2               HeI5876      1.294      0.77    -150   158
# Comp:  2          [OIII]5007_d      2.632      0.98    -150   158
# Comp:  2            [OI]6300_d      1.004      0.98    -150   158
# Comp:  2           [NII]6583_d      2.439      0.98    -150   158
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15         1
#  comp.  1:       185       254
#  comp.  2:      -694         1
# chi2/DOF: 0.9495; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 93; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.458      0.96     185   254
# Comp:  1                Halpha      3.767       1.2     185   254
# Comp:  2             [SII]6716     0.1393      0.48    -694     1
# Comp:  2             [SII]6731     0.4315      0.48    -694     1
# Comp:  2              HeII4687     0.2648      0.48    -694     1
# Comp:  2               HeI5876  3.714e-05      0.48    -694     1
# Comp:  2          [OIII]5007_d      0.000      0.61    -694     1
# Comp:  2            [OI]6300_d      12.11      0.61    -694     1
# Comp:  2           [NII]6583_d      0.000      0.79    -694     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        17
#  comp.  1:       167       224
#  comp.  2:      -136        94
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.755      0.90     167   224
# Comp:  1                Halpha      2.860      0.90     167   224
# Comp:  2             [SII]6716     0.8266      0.63    -136    94
# Comp:  2             [SII]6731     0.8466      0.63    -136    94
# Comp:  2              HeII4687     0.8428      0.63    -136    94
# Comp:  2               HeI5876     0.5784      0.63    -136    94
# Comp:  2          [OIII]5007_d      1.326      0.80    -136    94
# Comp:  2            [OI]6300_d      3.256      0.80    -136    94
# Comp:  2           [NII]6583_d     0.4644      0.80    -136    94
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -104         1
#  comp.  1:       217       218
#  comp.  2:      -690         1
# chi2/DOF: 1.001; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.587      0.89     217   218
# Comp:  1                Halpha      2.703       1.2     217   218
# Comp:  2             [SII]6716      0.000      0.48    -690     1
# Comp:  2             [SII]6731     0.6079      0.48    -690     1
# Comp:  2              HeII4687      0.000      0.48    -690     1
# Comp:  2               HeI5876    0.05110      0.48    -690     1
# Comp:  2          [OIII]5007_d      0.000      0.61    -690     1
# Comp:  2            [OI]6300_d      9.872      0.61    -690     1
# Comp:  2           [NII]6583_d     0.1590      0.84    -690     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        15
#  comp.  1:        74       230
#  comp.  2:      -151        87
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.11      0.92      74   230
# Comp:  1                Halpha      3.747      0.92      74   230
# Comp:  2             [SII]6716     0.8586      0.62    -151    87
# Comp:  2             [SII]6731     0.7697      0.62    -151    87
# Comp:  2              HeII4687     0.7813      0.62    -151    87
# Comp:  2               HeI5876      1.276      0.62    -151    87
# Comp:  2          [OIII]5007_d     0.8911      0.78    -151    87
# Comp:  2            [OI]6300_d      2.086      0.78    -151    87
# Comp:  2           [NII]6583_d      1.042      0.78    -151    87
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
#  comp.  1:       232       316
#  comp.  2:      -155        60
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.441       1.1     232   316
# Comp:  1                Halpha      3.087       1.1     232   316
# Comp:  2             [SII]6716     0.4704      0.56    -155    60
# Comp:  2             [SII]6731     0.9814      0.56    -155    60
# Comp:  2              HeII4687      1.138      0.56    -155    60
# Comp:  2               HeI5876     0.1480      0.56    -155    60
# Comp:  2          [OIII]5007_d      1.341      0.71    -155    60
# Comp:  2            [OI]6300_d      0.000      0.71    -155    60
# Comp:  2           [NII]6583_d      0.000      0.72    -155    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        98
#  comp.  1:       210       236
#  comp.  2:      -182       110
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.013      0.93     210   236
# Comp:  1                Halpha      3.657      0.93     210   236
# Comp:  2             [SII]6716     0.3016      0.67    -182   110
# Comp:  2             [SII]6731      1.209      0.67    -182   110
# Comp:  2              HeII4687      1.684      0.67    -182   110
# Comp:  2               HeI5876      0.000      0.67    -182   110
# Comp:  2          [OIII]5007_d      0.000      0.85    -182   110
# Comp:  2            [OI]6300_d      4.454      0.85    -182   110
# Comp:  2           [NII]6583_d     0.7701      0.85    -182   110
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18         1
#  comp.  1:       118       208
#  comp.  2:       -91       172
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.53      0.87     118   208
# Comp:  1                Halpha      4.138      0.88     118   208
# Comp:  2             [SII]6716      1.055      0.80     -91   172
# Comp:  2             [SII]6731      1.534      0.80     -91   172
# Comp:  2              HeII4687      2.524      0.80     -91   172
# Comp:  2               HeI5876      0.000      0.80     -91   172
# Comp:  2          [OIII]5007_d      1.137       1.0     -91   172
# Comp:  2            [OI]6300_d      2.743       1.0     -91   172
# Comp:  2           [NII]6583_d      1.614       1.0     -91   172
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11         1
#  comp.  1:       256       226
#  comp.  2:      -586         1
# chi2/DOF: 1.081; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 97; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.566      0.91     256   226
# Comp:  1                Halpha      2.474       1.2     256   226
# Comp:  2             [SII]6716    0.04728      0.48    -586     1
# Comp:  2             [SII]6731     0.1778      0.48    -586     1
# Comp:  2              HeII4687      0.000      0.48    -586     1
# Comp:  2               HeI5876     0.3403      0.48    -586     1
# Comp:  2          [OIII]5007_d      0.000      0.61    -586     1
# Comp:  2            [OI]6300_d      5.422      0.61    -586     1
# Comp:  2           [NII]6583_d      0.000      0.78    -586     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        52
#  comp.  1:       185       265
#  comp.  2:       -34       168
# chi2/DOF: 1.112; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.311      0.98     185   265
# Comp:  1                Halpha      4.000      0.98     185   265
# Comp:  2             [SII]6716      1.199      0.80     -34   168
# Comp:  2             [SII]6731      1.275      0.80     -34   168
# Comp:  2              HeII4687      1.640      0.79     -34   168
# Comp:  2               HeI5876      1.174      0.79     -34   168
# Comp:  2          [OIII]5007_d     0.3523       1.0     -34   168
# Comp:  2            [OI]6300_d      2.560       1.0     -34   168
# Comp:  2           [NII]6583_d      1.851       1.0     -34   168
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65       124
#  comp.  1:       160       199
#  comp.  2:      -127       141
# chi2/DOF: 1.113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.680      0.86     160   199
# Comp:  1                Halpha      2.855      0.86     160   199
# Comp:  2             [SII]6716     0.8219      0.74    -127   141
# Comp:  2             [SII]6731     0.8919      0.74    -127   141
# Comp:  2              HeII4687     0.3108      0.74    -127   141
# Comp:  2               HeI5876     0.1292      0.74    -127   141
# Comp:  2          [OIII]5007_d      1.407      0.93    -127   141
# Comp:  2            [OI]6300_d      2.391      0.93    -127   141
# Comp:  2           [NII]6583_d     0.1844      0.93    -127   141
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28         1
#  comp.  1:       144       185
#  comp.  2:      -225       192
# chi2/DOF: 1.109; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.151      0.83     144   185
# Comp:  1                Halpha      2.824      0.83     144   185
# Comp:  2             [SII]6716      0.000      0.85    -225   192
# Comp:  2             [SII]6731     0.7969      0.85    -225   192
# Comp:  2              HeII4687     0.5284      0.84    -225   192
# Comp:  2               HeI5876      0.000      0.84    -225   192
# Comp:  2          [OIII]5007_d      1.486       1.1    -225   192
# Comp:  2            [OI]6300_d      4.573       1.1    -225   192
# Comp:  2           [NII]6583_d      1.648       1.1    -225   192
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        82
#  comp.  1:       190       262
#  comp.  2:      -147       217
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.890      0.97     190   262
# Comp:  1                Halpha      3.806       1.0     190   262
# Comp:  2             [SII]6716     0.9993      0.90    -147   217
# Comp:  2             [SII]6731      1.048      0.90    -147   217
# Comp:  2              HeII4687      2.424      0.89    -147   217
# Comp:  2               HeI5876      0.000      0.89    -147   217
# Comp:  2          [OIII]5007_d      2.937       1.1    -147   217
# Comp:  2            [OI]6300_d      1.005       1.1    -147   217
# Comp:  2           [NII]6583_d    0.02023       1.2    -147   217
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28        33
#  comp.  1:       206       209
#  comp.  2:      -678         1
# chi2/DOF: 0.9760; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.951      0.88     206   209
# Comp:  1                Halpha      3.496       1.2     206   209
# Comp:  2             [SII]6716     0.1053      0.48    -678     1
# Comp:  2             [SII]6731     0.1821      0.48    -678     1
# Comp:  2              HeII4687      0.000      0.48    -678     1
# Comp:  2               HeI5876      0.000      0.48    -678     1
# Comp:  2          [OIII]5007_d      0.000      0.61    -678     1
# Comp:  2            [OI]6300_d      10.81      0.61    -678     1
# Comp:  2           [NII]6583_d      0.000      0.83    -678     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6         7
#  comp.  1:       156       185
#  comp.  2:      -157       151
# chi2/DOF: 1.101; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.979      0.83     156   185
# Comp:  1                Halpha      3.541      0.83     156   185
# Comp:  2             [SII]6716     0.4135      0.76    -157   151
# Comp:  2             [SII]6731      1.264      0.76    -157   151
# Comp:  2              HeII4687      1.863      0.76    -157   151
# Comp:  2               HeI5876     0.5545      0.76    -157   151
# Comp:  2          [OIII]5007_d      0.000      0.96    -157   151
# Comp:  2            [OI]6300_d      4.917      0.96    -157   151
# Comp:  2           [NII]6583_d     0.2587      0.96    -157   151
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       135       129
#  comp.  1:       232       194
#  comp.  2:      -694         1
# chi2/DOF: 0.9648; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.709      0.85     232   194
# Comp:  1                Halpha      3.633       1.2     232   194
# Comp:  2             [SII]6716    0.05555      0.48    -694     1
# Comp:  2             [SII]6731      0.000      0.48    -694     1
# Comp:  2              HeII4687      0.000      0.48    -694     1
# Comp:  2               HeI5876    0.08448      0.48    -694     1
# Comp:  2          [OIII]5007_d     0.4716      0.61    -694     1
# Comp:  2            [OI]6300_d      10.99      0.61    -694     1
# Comp:  2           [NII]6583_d     0.1130      0.88    -694     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12       108
#  comp.  1:       177       202
#  comp.  2:      -165        78
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.353      0.86     177   202
# Comp:  1                Halpha      2.758      0.86     177   202
# Comp:  2             [SII]6716     0.6525      0.60    -165    78
# Comp:  2             [SII]6731     0.7658      0.60    -165    78
# Comp:  2              HeII4687      1.292      0.60    -165    78
# Comp:  2               HeI5876      0.000      0.60    -165    78
# Comp:  2          [OIII]5007_d     0.7156      0.75    -165    78
# Comp:  2            [OI]6300_d      2.596      0.75    -165    78
# Comp:  2           [NII]6583_d      0.000      0.76    -165    78
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38       166
#  comp.  1:       102       290
#  comp.  2:      -111       175
# chi2/DOF: 1.100; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      16.20       1.0     102   290
# Comp:  1                Halpha      6.624       1.0     102   290
# Comp:  2             [SII]6716     0.9183      0.81    -111   175
# Comp:  2             [SII]6731      1.618      0.81    -111   175
# Comp:  2              HeII4687      1.357      0.81    -111   175
# Comp:  2               HeI5876     0.6609      0.81    -111   175
# Comp:  2          [OIII]5007_d     0.1579       1.0    -111   175
# Comp:  2            [OI]6300_d      4.182       1.0    -111   175
# Comp:  2           [NII]6583_d      2.226       1.0    -111   175
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13         1
#  comp.  1:       215       298
#  comp.  2:      -342       445
# chi2/DOF: 1.099; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.800       1.0     215   298
# Comp:  1                Halpha      3.223       1.5     215   298
# Comp:  2             [SII]6716      0.000       1.6    -342   445
# Comp:  2             [SII]6731      2.529       1.6    -342   445
# Comp:  2              HeII4687      4.758       1.3    -342   445
# Comp:  2               HeI5876     0.9427       1.3    -342   445
# Comp:  2          [OIII]5007_d      2.614       1.6    -342   445
# Comp:  2            [OI]6300_d      7.780       1.6    -342   445
# Comp:  2           [NII]6583_d      0.000       2.3    -342   445
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        99
#  comp.  1:       145       174
#  comp.  2:      -225       327
# chi2/DOF: 1.109; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.888      0.81     145   174
# Comp:  1                Halpha      2.621      0.84     145   174
# Comp:  2             [SII]6716     0.4621       1.2    -225   327
# Comp:  2             [SII]6731      2.091       1.2    -225   327
# Comp:  2              HeII4687      1.117       1.1    -225   327
# Comp:  2               HeI5876      0.000       1.1    -225   327
# Comp:  2          [OIII]5007_d      2.226       1.4    -225   327
# Comp:  2            [OI]6300_d      2.966       1.4    -225   327
# Comp:  2           [NII]6583_d      2.653       1.4    -225   327
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        82
#  comp.  1:       175       226
#  comp.  2:      -509       395
# chi2/DOF: 1.097; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.139      0.91     175   226
# Comp:  1                Halpha      3.170       1.4     175   226
# Comp:  2             [SII]6716     0.3841       1.4    -509   395
# Comp:  2             [SII]6731      1.772       1.4    -509   395
# Comp:  2              HeII4687     0.7751       1.2    -509   395
# Comp:  2               HeI5876      1.709       1.2    -509   395
# Comp:  2          [OIII]5007_d      2.524       1.5    -509   395
# Comp:  2            [OI]6300_d      10.06       1.5    -509   395
# Comp:  2           [NII]6583_d      0.000       2.3    -509   395
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        42
#  comp.  1:       124       380
#  comp.  2:      -696         1
# chi2/DOF: 0.9927; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.35       1.2     124   380
# Comp:  1                Halpha      4.790       1.4     124   380
# Comp:  2             [SII]6716     0.1866      0.48    -696     1
# Comp:  2             [SII]6731    0.09590      0.48    -696     1
# Comp:  2              HeII4687     0.5734      0.48    -696     1
# Comp:  2               HeI5876      0.000      0.48    -696     1
# Comp:  2          [OIII]5007_d      0.000      0.61    -696     1
# Comp:  2            [OI]6300_d      10.12      0.61    -696     1
# Comp:  2           [NII]6583_d    0.08665      0.71    -696     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        82
#  comp.  1:        79       246
#  comp.  2:      -116       136
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.78      0.94      79   246
# Comp:  1                Halpha      4.429      0.95      79   246
# Comp:  2             [SII]6716     0.6155      0.73    -116   136
# Comp:  2             [SII]6731      1.371      0.73    -116   136
# Comp:  2              HeII4687     0.3551      0.73    -116   136
# Comp:  2               HeI5876      0.000      0.73    -116   136
# Comp:  2          [OIII]5007_d      0.000      0.92    -116   136
# Comp:  2            [OI]6300_d     0.6542      0.92    -116   136
# Comp:  2           [NII]6583_d      1.716      0.92    -116   136
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36        75
#  comp.  1:       124       246
#  comp.  2:      -104       102
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.944      0.95     124   246
# Comp:  1                Halpha      4.195      0.95     124   246
# Comp:  2             [SII]6716     0.6014      0.65    -104   102
# Comp:  2             [SII]6731      1.222      0.65    -104   102
# Comp:  2              HeII4687      1.013      0.65    -104   102
# Comp:  2               HeI5876     0.1247      0.65    -104   102
# Comp:  2          [OIII]5007_d      1.065      0.82    -104   102
# Comp:  2            [OI]6300_d      3.970      0.82    -104   102
# Comp:  2           [NII]6583_d      1.200      0.82    -104   102
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        46
#  comp.  1:       102       340
#  comp.  2:      -143       148
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.495       1.1     102   340
# Comp:  1                Halpha      4.171       1.1     102   340
# Comp:  2             [SII]6716     0.7276      0.75    -143   148
# Comp:  2             [SII]6731     0.9134      0.75    -143   148
# Comp:  2              HeII4687     0.7915      0.75    -143   148
# Comp:  2               HeI5876     0.3365      0.75    -143   148
# Comp:  2          [OIII]5007_d      1.787      0.95    -143   148
# Comp:  2            [OI]6300_d      4.636      0.95    -143   148
# Comp:  2           [NII]6583_d      0.000      0.97    -143   148
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        10
#  comp.  1:       136       240
#  comp.  2:      -694         1
# chi2/DOF: 0.9774; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 17; Func calls: 121; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.647      0.93     136   240
# Comp:  1                Halpha      3.501       1.2     136   240
# Comp:  2             [SII]6716     0.1741      0.48    -694     1
# Comp:  2             [SII]6731     0.3848      0.48    -694     1
# Comp:  2              HeII4687     0.3629      0.48    -694     1
# Comp:  2               HeI5876  0.0008993      0.48    -694     1
# Comp:  2          [OIII]5007_d     0.1273      0.61    -694     1
# Comp:  2            [OI]6300_d      10.73      0.61    -694     1
# Comp:  2           [NII]6583_d    0.05135      0.77    -694     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75       136
#  comp.  1:        54       450
#  comp.  2:      -127       110
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      13.74       1.3      54   450
# Comp:  1                Halpha      6.644       1.3      54   450
# Comp:  2             [SII]6716     0.1883      0.67    -127   110
# Comp:  2             [SII]6731      1.431      0.67    -127   110
# Comp:  2              HeII4687     0.7213      0.67    -127   110
# Comp:  2               HeI5876     0.6822      0.67    -127   110
# Comp:  2          [OIII]5007_d      1.761      0.85    -127   110
# Comp:  2            [OI]6300_d      1.818      0.85    -127   110
# Comp:  2           [NII]6583_d      0.000      0.87    -127   110
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        32
#  comp.  1:       157       197
#  comp.  2:       -89       204
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.647      0.85     157   197
# Comp:  1                Halpha      3.230      0.85     157   197
# Comp:  2             [SII]6716     0.7671      0.87     -89   204
# Comp:  2             [SII]6731      1.437      0.87     -89   204
# Comp:  2              HeII4687      1.703      0.87     -89   204
# Comp:  2               HeI5876      0.000      0.87     -89   204
# Comp:  2          [OIII]5007_d      2.254       1.1     -89   204
# Comp:  2            [OI]6300_d     0.4479       1.1     -89   204
# Comp:  2           [NII]6583_d      1.999       1.1     -89   204
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15         8
#  comp.  1:       104       188
#  comp.  2:      -224       234
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 31; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.458      0.84     104   188
# Comp:  1                Halpha      3.250      0.84     104   188
# Comp:  2             [SII]6716      0.000      0.94    -224   234
# Comp:  2             [SII]6731      1.449      0.94    -224   234
# Comp:  2              HeII4687      1.578      0.92    -224   234
# Comp:  2               HeI5876      0.000      0.92    -224   234
# Comp:  2          [OIII]5007_d      1.285       1.2    -224   234
# Comp:  2            [OI]6300_d      6.112       1.2    -224   234
# Comp:  2           [NII]6583_d     0.2423       1.2    -224   234
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:       146       218
#  comp.  2:      -150       116
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.553      0.89     146   218
# Comp:  1                Halpha      2.725      0.89     146   218
# Comp:  2             [SII]6716     0.1932      0.68    -150   116
# Comp:  2             [SII]6731      1.293      0.68    -150   116
# Comp:  2              HeII4687      1.144      0.68    -150   116
# Comp:  2               HeI5876      0.000      0.68    -150   116
# Comp:  2          [OIII]5007_d   0.004240      0.86    -150   116
# Comp:  2            [OI]6300_d      1.142      0.86    -150   116
# Comp:  2           [NII]6583_d     0.6463      0.86    -150   116
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16       132
#  comp.  1:       139       234
#  comp.  2:      -687         1
# chi2/DOF: 0.9430; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 20; Func calls: 148; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.571      0.92     139   234
# Comp:  1                Halpha      3.236       1.2     139   234
# Comp:  2             [SII]6716    0.07563      0.48    -687     1
# Comp:  2             [SII]6731   0.007513      0.48    -687     1
# Comp:  2              HeII4687      0.000      0.48    -687     1
# Comp:  2               HeI5876      0.000      0.48    -687     1
# Comp:  2          [OIII]5007_d     0.3348      0.61    -687     1
# Comp:  2            [OI]6300_d      11.71      0.61    -687     1
# Comp:  2           [NII]6583_d     0.1967      0.77    -687     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25         1
#  comp.  1:        78       225
#  comp.  2:      -292       276
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      8.741      0.91      78   225
# Comp:  1                Halpha      3.672      0.95      78   225
# Comp:  2             [SII]6716      0.000       1.0    -292   276
# Comp:  2             [SII]6731      2.201       1.0    -292   276
# Comp:  2              HeII4687      0.000       1.0    -292   276
# ...
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.987      0.91     219   227
# Comp:  1                Halpha      3.341      0.92     219   227
# Comp:  2             [SII]6716     0.4986      0.92     -76   226
# Comp:  2             [SII]6731      1.356      0.92     -76   226
# Comp:  2              HeII4687      3.112      0.91     -76   226
# Comp:  2               HeI5876      0.000      0.91     -76   226
# Comp:  2          [OIII]5007_d      4.114       1.1     -76   226
# Comp:  2            [OI]6300_d      3.385       1.1     -76   226
# Comp:  2           [NII]6583_d     0.1576       1.2     -76   226
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4       185
#  comp.  1:       190       227
#  comp.  2:      -460       378
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.471      0.91     190   227
# Comp:  1                Halpha      1.857       1.3     190   227
# Comp:  2             [SII]6716      0.000       1.3    -460   378
# Comp:  2             [SII]6731      2.452       1.3    -460   378
# Comp:  2              HeII4687      0.000       1.2    -460   378
# Comp:  2               HeI5876     0.7968       1.2    -460   378
# Comp:  2          [OIII]5007_d      3.649       1.5    -460   378
# Comp:  2            [OI]6300_d      7.439       1.5    -460   378
# Comp:  2           [NII]6583_d      1.974       2.1    -460   378
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:       206       140
#  comp.  2:       -26       166
# chi2/DOF: 1.104; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.658      0.74     206   140
# Comp:  1                Halpha      2.168      0.74     206   140
# Comp:  2             [SII]6716     0.6347      0.79     -26   166
# Comp:  2             [SII]6731      1.380      0.79     -26   166
# Comp:  2              HeII4687      2.903      0.79     -26   166
# Comp:  2               HeI5876     0.3615      0.79     -26   166
# Comp:  2          [OIII]5007_d      0.000       1.0     -26   166
# Comp:  2            [OI]6300_d      2.914       1.0     -26   166
# Comp:  2           [NII]6583_d     0.6838       1.0     -26   166
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        94
#  comp.  1:       169       223
#  comp.  2:      -157       163
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.908      0.90     169   223
# Comp:  1                Halpha      3.215      0.91     169   223
# Comp:  2             [SII]6716     0.7037      0.79    -157   163
# Comp:  2             [SII]6731      1.055      0.79    -157   163
# Comp:  2              HeII4687    0.05515      0.79    -157   163
# Comp:  2               HeI5876    0.06195      0.79    -157   163
# Comp:  2          [OIII]5007_d      2.360      0.99    -157   163
# Comp:  2            [OI]6300_d      3.535      0.99    -157   163
# Comp:  2           [NII]6583_d      1.957       1.0    -157   163
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        84
#  comp.  1:       182       187
#  comp.  2:       104       393
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 61; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.053      0.83     182   187
# Comp:  1                Halpha      2.988      0.85     182   187
# Comp:  2             [SII]6716     0.8948       1.4     104   393
# Comp:  2             [SII]6731      1.760       1.4     104   393
# Comp:  2              HeII4687      1.811       1.2     104   393
# Comp:  2               HeI5876     0.2971       1.2     104   393
# Comp:  2          [OIII]5007_d      2.975       1.5     104   393
# Comp:  2            [OI]6300_d      3.846       1.5     104   393
# Comp:  2           [NII]6583_d      1.654       1.5     104   393
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18         1
#  comp.  1:       106       238
#  comp.  2:       -31       141
# chi2/DOF: 1.106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.46      0.93     106   238
# Comp:  1                Halpha      3.784      0.93     106   238
# Comp:  2             [SII]6716    0.02711      0.74     -31   141
# Comp:  2             [SII]6731     0.7543      0.74     -31   141
# Comp:  2              HeII4687     0.4569      0.74     -31   141
# Comp:  2               HeI5876     0.2370      0.74     -31   141
# Comp:  2          [OIII]5007_d      2.765      0.93     -31   141
# Comp:  2            [OI]6300_d      2.557      0.93     -31   141
# Comp:  2           [NII]6583_d     0.4683      0.93     -31   141
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:       110       200
#  comp.  2:      -332         1
# chi2/DOF: 1.103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 89; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      7.271      0.86     110   200
# Comp:  1                Halpha      3.644      0.86     110   200
# Comp:  2             [SII]6716     0.2974      0.48    -332     1
# Comp:  2             [SII]6731     0.3411      0.48    -332     1
# Comp:  2              HeII4687     0.7917      0.48    -332     1
# Comp:  2               HeI5876      0.000      0.48    -332     1
# Comp:  2          [OIII]5007_d      1.228      0.61    -332     1
# Comp:  2            [OI]6300_d      1.631      0.61    -332     1
# Comp:  2           [NII]6583_d      0.000      0.61    -332     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        79
#  comp.  1:       237       204
#  comp.  2:       -49        39
# chi2/DOF: 1.107; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 67; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.708      0.87     237   204
# Comp:  1                Halpha      1.975      0.87     237   204
# Comp:  2             [SII]6716     0.4313      0.52     -49    39
# Comp:  2             [SII]6731     0.6585      0.52     -49    39
# Comp:  2              HeII4687      1.224      0.52     -49    39
# Comp:  2               HeI5876     0.4261      0.52     -49    39
# Comp:  2          [OIII]5007_d      0.000      0.66     -49    39
# Comp:  2            [OI]6300_d      1.450      0.66     -49    39
# Comp:  2           [NII]6583_d     0.7748      0.66     -49    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32         1
#  comp.  1:       119       230
#  comp.  2:      -694         1
# chi2/DOF: 1.009; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      9.411      0.91     119   230
# Comp:  1                Halpha      3.255       1.1     119   230
# Comp:  2             [SII]6716      0.000      0.48    -694     1
# Comp:  2             [SII]6731     0.5464      0.48    -694     1
# Comp:  2              HeII4687     0.3486      0.48    -694     1
# Comp:  2               HeI5876     0.1344      0.48    -694     1
# Comp:  2          [OIII]5007_d    0.09957      0.61    -694     1
# Comp:  2            [OI]6300_d      9.309      0.61    -694     1
# Comp:  2           [NII]6583_d     0.2707      0.76    -694     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        29
#  comp.  1:        63       257
#  comp.  2:      -100       111
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.46      0.96      63   257
# Comp:  1                Halpha      4.111      0.96      63   257
# Comp:  2             [SII]6716     0.8953      0.67    -100   111
# Comp:  2             [SII]6731      1.007      0.67    -100   111
# Comp:  2              HeII4687      1.135      0.67    -100   111
# Comp:  2               HeI5876     0.1806      0.67    -100   111
# Comp:  2          [OIII]5007_d      1.677      0.85    -100   111
# Comp:  2            [OI]6300_d      3.370      0.85    -100   111
# Comp:  2           [NII]6583_d     0.6963      0.85    -100   111
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:       171       284
#  comp.  2:      -216       145
# chi2/DOF: 1.108; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      11.26       1.0     171   284
# Comp:  1                Halpha      3.665       1.0     171   284
# Comp:  2             [SII]6716     0.2300      0.75    -216   145
# Comp:  2             [SII]6731      1.031      0.75    -216   145
# Comp:  2              HeII4687      1.163      0.75    -216   145
# Comp:  2               HeI5876      0.000      0.75    -216   145
# Comp:  2          [OIII]5007_d      1.084      0.94    -216   145
# Comp:  2            [OI]6300_d      3.375      0.94    -216   145
# Comp:  2           [NII]6583_d     0.6687      0.97    -216   145
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        31
#  comp.  1:       130       202
#  comp.  2:      -115       173
# chi2/DOF: 1.105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.409      0.86     130   202
# Comp:  1                Halpha      2.921      0.86     130   202
# Comp:  2             [SII]6716      1.461      0.81    -115   173
# Comp:  2             [SII]6731      1.344      0.81    -115   173
# Comp:  2              HeII4687     0.3158      0.81    -115   173
# Comp:  2               HeI5876      1.739      0.81    -115   173
# Comp:  2          [OIII]5007_d     0.5704       1.0    -115   173
# Comp:  2            [OI]6300_d      4.208       1.0    -115   173
# Comp:  2           [NII]6583_d     0.4897       1.0    -115   173
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:       102       252
#  comp.  2:      -118       119
# chi2/DOF: 1.112; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      10.73      0.96     102   252
# Comp:  1                Halpha      4.356      0.96     102   252
# Comp:  2             [SII]6716     0.3742      0.69    -118   119
# Comp:  2             [SII]6731      1.120      0.69    -118   119
# Comp:  2              HeII4687      1.140      0.69    -118   119
# Comp:  2               HeI5876      0.000      0.69    -118   119
# Comp:  2          [OIII]5007_d      1.884      0.87    -118   119
# Comp:  2            [OI]6300_d     0.4012      0.87    -118   119
# Comp:  2           [NII]6583_d      1.913      0.87    -118   119
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        32
#  comp.  1:       170       367
#  comp.  2:      -695         1
# chi2/DOF: 0.9894; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      12.77       1.1     170   367
# Comp:  1                Halpha      5.093       1.4     170   367
# Comp:  2             [SII]6716      0.000      0.48    -695     1
# Comp:  2             [SII]6731    0.01196      0.48    -695     1
# Comp:  2              HeII4687      0.000      0.48    -695     1
# Comp:  2               HeI5876      0.000      0.48    -695     1
# Comp:  2          [OIII]5007_d    0.01975      0.61    -695     1
# Comp:  2            [OI]6300_d      10.24      0.61    -695     1
# Comp:  2           [NII]6583_d     0.2305      0.73    -695     1
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_4_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_4", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_4_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_4_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_4_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
