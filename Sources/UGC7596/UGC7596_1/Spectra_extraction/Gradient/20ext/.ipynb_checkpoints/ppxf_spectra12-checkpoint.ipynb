# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_12.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_12']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.02253574 0.02114611 0.02936896 ... 0.02119649 0.02060275 0.02099583] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -62        42
# chi2/DOF: 0.03756; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        38
# chi2/DOF: 0.02559; DOF: 1918; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-60.10825592,  37.79963716])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        46
#  comp.  1:       -64        85
#  comp.  2:       -42        25
# chi2/DOF: 1.019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.903      0.48     -64    85
# Comp:  1                Halpha      2.405      0.48     -64    85
# Comp:  2             [SII]6716     0.5409      0.39     -42    25
# Comp:  2             [SII]6731     0.6887      0.39     -42    25
# Comp:  2              HeII4687      0.000      0.39     -42    25
# Comp:  2               HeI5876      0.000      0.39     -42    25
# Comp:  2          [OIII]5007_d      1.834      0.49     -42    25
# Comp:  2            [OI]6300_d   0.002740      0.49     -42    25
# Comp:  2           [NII]6583_d      1.128      0.49     -42    25
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:   2.63; gas flux:      2 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  3.375; gas flux:      3 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  1.057; gas flux:      1 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  1.436; gas flux:      1 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  2.937; gas flux:      2 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.004363; gas flux:      0 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:   1.71; gas flux:      2 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        54
#  comp.  1:       -54       111
#  comp.  2:       -31         7
# chi2/DOF: 1.009; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.516      0.53     -54   111
# Comp:  1                Halpha      3.162      0.53     -54   111
# Comp:  2             [SII]6716     0.5628      0.38     -31     7
# Comp:  2             [SII]6731     0.5481      0.38     -31     7
# Comp:  2              HeII4687     0.6972      0.38     -31     7
# Comp:  2               HeI5876     0.2559      0.38     -31     7
# Comp:  2          [OIII]5007_d      1.854      0.48     -31     7
# Comp:  2            [OI]6300_d     0.4483      0.48     -31     7
# Comp:  2           [NII]6583_d      1.001      0.48     -31     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        24
#  comp.  1:       -70        67
#  comp.  2:       -49        25
# chi2/DOF: 1.011; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.308      0.45     -70    67
# Comp:  1                Halpha      3.192      0.45     -70    67
# Comp:  2             [SII]6716     0.8947      0.39     -49    25
# Comp:  2             [SII]6731     0.5726      0.39     -49    25
# Comp:  2              HeII4687     0.3353      0.39     -49    25
# Comp:  2               HeI5876     0.5163      0.39     -49    25
# Comp:  2          [OIII]5007_d      1.764      0.49     -49    25
# Comp:  2            [OI]6300_d      0.000      0.49     -49    25
# Comp:  2           [NII]6583_d     0.9173      0.49     -49    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        57
#  comp.  1:       -68        54
#  comp.  2:       -29        16
# chi2/DOF: 1.014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.477      0.43     -68    54
# Comp:  1                Halpha      2.104      0.43     -68    54
# Comp:  2             [SII]6716     0.6222      0.38     -29    16
# Comp:  2             [SII]6731     0.8429      0.38     -29    16
# Comp:  2              HeII4687      0.000      0.38     -29    16
# Comp:  2               HeI5876      0.000      0.38     -29    16
# Comp:  2          [OIII]5007_d      1.635      0.49     -29    16
# Comp:  2            [OI]6300_d      0.000      0.49     -29    16
# Comp:  2           [NII]6583_d      1.433      0.49     -29    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        60
#  comp.  1:       -70       106
#  comp.  2:       -47         1
# chi2/DOF: 1.010; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.733      0.52     -70   106
# Comp:  1                Halpha      3.268      0.52     -70   106
# Comp:  2             [SII]6716     0.5430      0.38     -47     1
# Comp:  2             [SII]6731     0.6809      0.38     -47     1
# Comp:  2              HeII4687      0.000      0.38     -47     1
# Comp:  2               HeI5876     0.4560      0.38     -47     1
# Comp:  2          [OIII]5007_d      1.858      0.48     -47     1
# Comp:  2            [OI]6300_d      0.000      0.48     -47     1
# Comp:  2           [NII]6583_d      1.451      0.48     -47     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        35
#  comp.  1:       -90        86
#  comp.  2:       -49        46
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.551      0.48     -90    86
# Comp:  1                Halpha      2.681      0.48     -90    86
# Comp:  2             [SII]6716     0.8779      0.42     -49    46
# Comp:  2             [SII]6731     0.9699      0.42     -49    46
# Comp:  2              HeII4687      0.000      0.42     -49    46
# Comp:  2               HeI5876      0.000      0.42     -49    46
# Comp:  2          [OIII]5007_d      1.968      0.53     -49    46
# Comp:  2            [OI]6300_d     0.3948      0.53     -49    46
# Comp:  2           [NII]6583_d      1.319      0.53     -49    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        45
#  comp.  1:       -71        97
#  comp.  2:       -49         1
# chi2/DOF: 1.015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.963      0.50     -71    97
# Comp:  1                Halpha      3.075      0.50     -71    97
# Comp:  2             [SII]6716     0.5067      0.38     -49     1
# Comp:  2             [SII]6731     0.6199      0.38     -49     1
# Comp:  2              HeII4687     0.1342      0.38     -49     1
# Comp:  2               HeI5876    0.07055      0.38     -49     1
# Comp:  2          [OIII]5007_d      1.862      0.48     -49     1
# Comp:  2            [OI]6300_d     0.3442      0.48     -49     1
# Comp:  2           [NII]6583_d     0.8176      0.48     -49     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84        54
#  comp.  1:       -80        75
#  comp.  2:       -26        44
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.958      0.47     -80    75
# Comp:  1                Halpha      2.260      0.47     -80    75
# Comp:  2             [SII]6716      1.129      0.41     -26    44
# Comp:  2             [SII]6731     0.7159      0.41     -26    44
# Comp:  2              HeII4687      0.000      0.41     -26    44
# Comp:  2               HeI5876      0.000      0.41     -26    44
# Comp:  2          [OIII]5007_d      1.852      0.52     -26    44
# Comp:  2            [OI]6300_d     0.2412      0.52     -26    44
# Comp:  2           [NII]6583_d     0.8717      0.52     -26    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        60
#  comp.  1:       -89       111
#  comp.  2:       -42        40
# chi2/DOF: 1.008; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.370      0.53     -89   111
# Comp:  1                Halpha      3.048      0.53     -89   111
# Comp:  2             [SII]6716     0.1618      0.41     -42    40
# Comp:  2             [SII]6731     0.7892      0.41     -42    40
# Comp:  2              HeII4687     0.4586      0.41     -42    40
# Comp:  2               HeI5876      0.000      0.41     -42    40
# Comp:  2          [OIII]5007_d      2.183      0.52     -42    40
# Comp:  2            [OI]6300_d     0.5601      0.52     -42    40
# Comp:  2           [NII]6583_d      1.108      0.52     -42    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        57
#  comp.  1:       -69       135
#  comp.  2:       -30        13
# chi2/DOF: 1.014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.474      0.57     -69   135
# Comp:  1                Halpha      3.424      0.57     -69   135
# Comp:  2             [SII]6716     0.3950      0.38     -30    13
# Comp:  2             [SII]6731     0.8128      0.38     -30    13
# Comp:  2              HeII4687      0.000      0.38     -30    13
# Comp:  2               HeI5876      0.000      0.38     -30    13
# Comp:  2          [OIII]5007_d      1.749      0.48     -30    13
# Comp:  2            [OI]6300_d      0.000      0.48     -30    13
# Comp:  2           [NII]6583_d      1.590      0.48     -30    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -76        84
#  comp.  2:       -16        52
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.532      0.48     -76    84
# Comp:  1                Halpha      2.583      0.48     -76    84
# Comp:  2             [SII]6716     0.7940      0.43     -16    52
# Comp:  2             [SII]6731     0.7863      0.43     -16    52
# Comp:  2              HeII4687     0.7147      0.43     -16    52
# Comp:  2               HeI5876     0.3676      0.43     -16    52
# Comp:  2          [OIII]5007_d      2.044      0.54     -16    52
# Comp:  2            [OI]6300_d      0.000      0.54     -16    52
# Comp:  2           [NII]6583_d      1.142      0.54     -16    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        51
#  comp.  1:       -62        68
#  comp.  2:       -39        21
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.454      0.45     -62    68
# Comp:  1                Halpha      2.250      0.45     -62    68
# Comp:  2             [SII]6716     0.7929      0.39     -39    21
# Comp:  2             [SII]6731     0.6769      0.39     -39    21
# Comp:  2              HeII4687      0.000      0.39     -39    21
# Comp:  2               HeI5876     0.4703      0.39     -39    21
# Comp:  2          [OIII]5007_d      1.745      0.49     -39    21
# Comp:  2            [OI]6300_d      0.000      0.49     -39    21
# Comp:  2           [NII]6583_d      1.188      0.49     -39    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:       -55        71
#  comp.  2:       -34        28
# chi2/DOF: 1.010; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.224      0.46     -55    71
# Comp:  1                Halpha      2.200      0.46     -55    71
# Comp:  2             [SII]6716     0.9783      0.39     -34    28
# Comp:  2             [SII]6731     0.8223      0.39     -34    28
# Comp:  2              HeII4687     0.3400      0.39     -34    28
# Comp:  2               HeI5876     0.2135      0.39     -34    28
# Comp:  2          [OIII]5007_d      1.875      0.50     -34    28
# Comp:  2            [OI]6300_d     0.1814      0.50     -34    28
# Comp:  2           [NII]6583_d      1.260      0.50     -34    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        47
#  comp.  1:       -60       108
#  comp.  2:       -46         1
# chi2/DOF: 1.011; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.805      0.52     -60   108
# Comp:  1                Halpha      2.798      0.52     -60   108
# Comp:  2             [SII]6716     0.8188      0.38     -46     1
# Comp:  2             [SII]6731     0.5584      0.38     -46     1
# Comp:  2              HeII4687      0.000      0.38     -46     1
# Comp:  2               HeI5876     0.2702      0.38     -46     1
# Comp:  2          [OIII]5007_d      1.663      0.48     -46     1
# Comp:  2            [OI]6300_d      0.000      0.48     -46     1
# Comp:  2           [NII]6583_d     0.7694      0.48     -46     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        40
#  comp.  1:       -93       127
#  comp.  2:       -40        69
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.267      0.56     -93   127
# Comp:  1                Halpha      3.302      0.56     -93   127
# Comp:  2             [SII]6716     0.8164      0.45     -40    69
# Comp:  2             [SII]6731     0.9798      0.45     -40    69
# Comp:  2              HeII4687      0.000      0.45     -40    69
# Comp:  2               HeI5876     0.3468      0.45     -40    69
# Comp:  2          [OIII]5007_d      2.315      0.57     -40    69
# Comp:  2            [OI]6300_d     0.1957      0.57     -40    69
# Comp:  2           [NII]6583_d      1.095      0.57     -40    69
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        43
#  comp.  1:       -82        71
#  comp.  2:       -47        36
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.032      0.46     -82    71
# Comp:  1                Halpha      2.644      0.46     -82    71
# Comp:  2             [SII]6716     0.6614      0.40     -47    36
# Comp:  2             [SII]6731     0.7180      0.40     -47    36
# Comp:  2              HeII4687      0.000      0.40     -47    36
# Comp:  2               HeI5876     0.3386      0.40     -47    36
# Comp:  2          [OIII]5007_d      1.826      0.51     -47    36
# Comp:  2            [OI]6300_d      0.000      0.51     -47    36
# Comp:  2           [NII]6583_d      1.256      0.51     -47    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:       -68        92
#  comp.  2:       -50        34
# chi2/DOF: 1.013; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.319      0.50     -68    92
# Comp:  1                Halpha      2.896      0.50     -68    92
# Comp:  2             [SII]6716     0.3692      0.40     -50    34
# Comp:  2             [SII]6731     0.8608      0.40     -50    34
# Comp:  2              HeII4687      0.000      0.40     -50    34
# Comp:  2               HeI5876     0.4765      0.40     -50    34
# Comp:  2          [OIII]5007_d      1.994      0.51     -50    34
# Comp:  2            [OI]6300_d      0.000      0.51     -50    34
# Comp:  2           [NII]6583_d      1.144      0.51     -50    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        57
#  comp.  1:       -55       121
#  comp.  2:       -35         1
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.928      0.55     -55   121
# Comp:  1                Halpha      3.535      0.55     -55   121
# Comp:  2             [SII]6716     0.3531      0.38     -35     1
# Comp:  2             [SII]6731     0.8379      0.38     -35     1
# Comp:  2              HeII4687     0.4084      0.38     -35     1
# Comp:  2               HeI5876     0.2797      0.38     -35     1
# Comp:  2          [OIII]5007_d      1.863      0.48     -35     1
# Comp:  2            [OI]6300_d     0.2443      0.48     -35     1
# Comp:  2           [NII]6583_d      1.152      0.48     -35     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        81
#  comp.  1:       -43        96
#  comp.  2:       -36        21
# chi2/DOF: 1.015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.452      0.50     -43    96
# Comp:  1                Halpha      2.185      0.50     -43    96
# Comp:  2             [SII]6716      1.020      0.39     -36    21
# Comp:  2             [SII]6731     0.7653      0.39     -36    21
# Comp:  2              HeII4687      0.000      0.39     -36    21
# Comp:  2               HeI5876    0.06945      0.39     -36    21
# Comp:  2          [OIII]5007_d      1.925      0.49     -36    21
# Comp:  2            [OI]6300_d      0.000      0.49     -36    21
# Comp:  2           [NII]6583_d      1.478      0.49     -36    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        81
#  comp.  1:       -86       131
#  comp.  2:       -30        47
# chi2/DOF: 1.010; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.356      0.56     -86   131
# Comp:  1                Halpha      3.703      0.56     -86   131
# Comp:  2             [SII]6716     0.6156      0.42     -30    47
# Comp:  2             [SII]6731     0.6168      0.42     -30    47
# Comp:  2              HeII4687     0.6360      0.42     -30    47
# Comp:  2               HeI5876     0.1128      0.42     -30    47
# Comp:  2          [OIII]5007_d      2.086      0.53     -30    47
# Comp:  2            [OI]6300_d      0.000      0.53     -30    47
# Comp:  2           [NII]6583_d      1.610      0.53     -30    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -71        86
#  comp.  2:       -41        24
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.738      0.48     -71    86
# Comp:  1                Halpha      3.250      0.48     -71    86
# Comp:  2             [SII]6716     0.3951      0.39     -41    24
# Comp:  2             [SII]6731     0.7513      0.39     -41    24
# Comp:  2              HeII4687     0.2693      0.39     -41    24
# Comp:  2               HeI5876     0.4432      0.39     -41    24
# Comp:  2          [OIII]5007_d      1.815      0.49     -41    24
# Comp:  2            [OI]6300_d      0.000      0.49     -41    24
# Comp:  2           [NII]6583_d      1.245      0.49     -41    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        43
#  comp.  1:       -63        61
#  comp.  2:       -46        25
# chi2/DOF: 1.014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.779      0.44     -63    61
# Comp:  1                Halpha      2.332      0.44     -63    61
# Comp:  2             [SII]6716     0.9068      0.39     -46    25
# Comp:  2             [SII]6731     0.5423      0.39     -46    25
# Comp:  2              HeII4687     0.6352      0.39     -46    25
# Comp:  2               HeI5876     0.3973      0.39     -46    25
# Comp:  2          [OIII]5007_d      1.835      0.49     -46    25
# Comp:  2            [OI]6300_d      0.000      0.49     -46    25
# Comp:  2           [NII]6583_d     0.7061      0.49     -46    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        65
#  comp.  1:       -79        89
#  comp.  2:       -49        17
# chi2/DOF: 1.014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.392      0.49     -79    89
# Comp:  1                Halpha      2.683      0.49     -79    89
# Comp:  2             [SII]6716     0.3190      0.38     -49    17
# Comp:  2             [SII]6731     0.7945      0.38     -49    17
# Comp:  2              HeII4687     0.6413      0.38     -49    17
# Comp:  2               HeI5876      0.000      0.38     -49    17
# Comp:  2          [OIII]5007_d      1.835      0.49     -49    17
# Comp:  2            [OI]6300_d      0.000      0.49     -49    17
# Comp:  2           [NII]6583_d      1.062      0.49     -49    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97         1
#  comp.  1:       -89        73
#  comp.  2:       -36        21
# chi2/DOF: 1.002; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.484      0.46     -89    73
# Comp:  1                Halpha      2.329      0.46     -89    73
# Comp:  2             [SII]6716     0.7951      0.39     -36    21
# Comp:  2             [SII]6731     0.6829      0.39     -36    21
# Comp:  2              HeII4687      0.000      0.39     -36    21
# Comp:  2               HeI5876      0.000      0.39     -36    21
# Comp:  2          [OIII]5007_d      1.627      0.49     -36    21
# Comp:  2            [OI]6300_d      0.000      0.49     -36    21
# Comp:  2           [NII]6583_d     0.7730      0.49     -36    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        28
#  comp.  1:       -42        46
#  comp.  2:       -37        26
# chi2/DOF: 1.014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.348      0.42     -42    46
# Comp:  1                Halpha      2.072      0.42     -42    46
# Comp:  2             [SII]6716     0.6460      0.39     -37    26
# Comp:  2             [SII]6731     0.8137      0.39     -37    26
# Comp:  2              HeII4687      0.000      0.39     -37    26
# Comp:  2               HeI5876      0.000      0.39     -37    26
# Comp:  2          [OIII]5007_d      1.990      0.50     -37    26
# Comp:  2            [OI]6300_d      0.000      0.50     -37    26
# Comp:  2           [NII]6583_d      1.393      0.50     -37    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:       -71        67
#  comp.  2:       -47         1
# chi2/DOF: 1.013; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.508      0.45     -71    67
# Comp:  1                Halpha      2.597      0.45     -71    67
# Comp:  2             [SII]6716     0.5109      0.38     -47     1
# Comp:  2             [SII]6731     0.6343      0.38     -47     1
# Comp:  2              HeII4687      0.000      0.38     -47     1
# Comp:  2               HeI5876      0.000      0.38     -47     1
# Comp:  2          [OIII]5007_d      1.631      0.48     -47     1
# Comp:  2            [OI]6300_d     0.3262      0.48     -47     1
# Comp:  2           [NII]6583_d      1.406      0.48     -47     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        15
#  comp.  1:       -44        65
#  comp.  2:       -46         1
# chi2/DOF: 1.013; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.788      0.45     -44    65
# Comp:  1                Halpha      2.234      0.45     -44    65
# Comp:  2             [SII]6716     0.3255      0.38     -46     1
# Comp:  2             [SII]6731     0.6124      0.38     -46     1
# Comp:  2              HeII4687      0.000      0.38     -46     1
# Comp:  2               HeI5876      0.000      0.38     -46     1
# Comp:  2          [OIII]5007_d      1.849      0.48     -46     1
# Comp:  2            [OI]6300_d      0.000      0.48     -46     1
# Comp:  2           [NII]6583_d     0.8681      0.48     -46     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        60
#  comp.  1:       -50       115
#  comp.  2:       -38        26
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.775      0.54     -50   115
# Comp:  1                Halpha      2.401      0.54     -50   115
# Comp:  2             [SII]6716     0.8001      0.39     -38    26
# Comp:  2             [SII]6731     0.6015      0.39     -38    26
# Comp:  2              HeII4687     0.4805      0.39     -38    26
# Comp:  2               HeI5876      0.000      0.39     -38    26
# Comp:  2          [OIII]5007_d      2.010      0.49     -38    26
# Comp:  2            [OI]6300_d     0.2861      0.49     -38    26
# Comp:  2           [NII]6583_d      1.182      0.49     -38    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        57
#  comp.  1:       -68        61
#  comp.  2:       -38         1
# chi2/DOF: 1.011; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.529      0.44     -68    61
# Comp:  1                Halpha      2.412      0.44     -68    61
# Comp:  2             [SII]6716     0.3751      0.38     -38     1
# Comp:  2             [SII]6731     0.7507      0.38     -38     1
# Comp:  2              HeII4687     0.1515      0.38     -38     1
# Comp:  2               HeI5876     0.2818      0.38     -38     1
# Comp:  2          [OIII]5007_d      1.869      0.48     -38     1
# Comp:  2            [OI]6300_d     0.4074      0.48     -38     1
# Comp:  2           [NII]6583_d      1.314      0.48     -38     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        46
#  comp.  1:       -67        89
#  comp.  2:       -38        36
# chi2/DOF: 1.009; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.626      0.49     -67    89
# Comp:  1                Halpha      2.854      0.49     -67    89
# Comp:  2             [SII]6716     0.3446      0.40     -38    36
# Comp:  2             [SII]6731     0.8452      0.40     -38    36
# Comp:  2              HeII4687      0.000      0.40     -38    36
# Comp:  2               HeI5876     0.7597      0.40     -38    36
# Comp:  2          [OIII]5007_d      2.074      0.51     -38    36
# Comp:  2            [OI]6300_d      0.000      0.51     -38    36
# Comp:  2           [NII]6583_d      1.220      0.51     -38    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       -75        67
#  comp.  2:       -44         1
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.049      0.45     -75    67
# Comp:  1                Halpha      2.621      0.45     -75    67
# Comp:  2             [SII]6716     0.4840      0.38     -44     1
# Comp:  2             [SII]6731     0.5901      0.38     -44     1
# Comp:  2              HeII4687     0.2829      0.38     -44     1
# Comp:  2               HeI5876      0.000      0.38     -44     1
# Comp:  2          [OIII]5007_d      1.553      0.48     -44     1
# Comp:  2            [OI]6300_d      0.000      0.48     -44     1
# Comp:  2           [NII]6583_d      1.175      0.48     -44     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:       -93       108
#  comp.  2:       -46        19
# chi2/DOF: 1.010; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.049      0.52     -93   108
# Comp:  1                Halpha      2.617      0.52     -93   108
# Comp:  2             [SII]6716     0.5282      0.39     -46    19
# Comp:  2             [SII]6731     0.7641      0.39     -46    19
# Comp:  2              HeII4687      0.000      0.39     -46    19
# Comp:  2               HeI5876      0.000      0.39     -46    19
# Comp:  2          [OIII]5007_d      1.724      0.49     -46    19
# Comp:  2            [OI]6300_d     0.1015      0.49     -46    19
# Comp:  2           [NII]6583_d      1.565      0.49     -46    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        60
#  comp.  1:       -51       123
#  comp.  2:       -20        32
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.508      0.55     -51   123
# Comp:  1                Halpha      3.441      0.55     -51   123
# Comp:  2             [SII]6716     0.2964      0.40     -20    32
# Comp:  2             [SII]6731     0.7128      0.40     -20    32
# Comp:  2              HeII4687     0.3361      0.40     -20    32
# Comp:  2               HeI5876      0.000      0.40     -20    32
# Comp:  2          [OIII]5007_d      1.912      0.50     -20    32
# Comp:  2            [OI]6300_d      0.000      0.50     -20    32
# Comp:  2           [NII]6583_d     0.8711      0.50     -20    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        39
#  comp.  1:       -68        68
#  comp.  2:       -37         1
# chi2/DOF: 1.009; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.527      0.45     -68    68
# Comp:  1                Halpha      2.286      0.45     -68    68
# Comp:  2             [SII]6716     0.9243      0.38     -37     1
# Comp:  2             [SII]6731     0.6493      0.38     -37     1
# Comp:  2              HeII4687     0.6113      0.38     -37     1
# Comp:  2               HeI5876      0.000      0.38     -37     1
# Comp:  2          [OIII]5007_d      1.743      0.48     -37     1
# Comp:  2            [OI]6300_d      0.000      0.48     -37     1
# Comp:  2           [NII]6583_d      1.203      0.48     -37     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        25
#  comp.  1:       -55        63
#  comp.  2:       -31         1
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.150      0.44     -55    63
# Comp:  1                Halpha      2.587      0.44     -55    63
# Comp:  2             [SII]6716     0.9604      0.38     -31     1
# Comp:  2             [SII]6731     0.5872      0.38     -31     1
# Comp:  2              HeII4687     0.3157      0.38     -31     1
# Comp:  2               HeI5876     0.4372      0.38     -31     1
# Comp:  2          [OIII]5007_d      1.804      0.48     -31     1
# Comp:  2            [OI]6300_d     0.3965      0.48     -31     1
# Comp:  2           [NII]6583_d      1.459      0.48     -31     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87        56
#  comp.  1:       -66        85
#  comp.  2:       -38        24
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.556      0.48     -66    85
# Comp:  1                Halpha      2.227      0.48     -66    85
# Comp:  2             [SII]6716     0.7085      0.39     -38    24
# Comp:  2             [SII]6731     0.5699      0.39     -38    24
# Comp:  2              HeII4687     0.3230      0.39     -38    24
# Comp:  2               HeI5876     0.2600      0.39     -38    24
# Comp:  2          [OIII]5007_d      1.790      0.49     -38    24
# Comp:  2            [OI]6300_d      0.000      0.49     -38    24
# Comp:  2           [NII]6583_d     0.7653      0.49     -38    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72        75
#  comp.  1:       -60       122
#  comp.  2:       -32        39
# chi2/DOF: 1.009; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.326      0.55     -60   122
# Comp:  1                Halpha      3.684      0.55     -60   122
# Comp:  2             [SII]6716     0.9437      0.41     -32    39
# Comp:  2             [SII]6731     0.8024      0.41     -32    39
# Comp:  2              HeII4687     0.4676      0.41     -32    39
# Comp:  2               HeI5876     0.4734      0.41     -32    39
# Comp:  2          [OIII]5007_d      1.805      0.51     -32    39
# Comp:  2            [OI]6300_d     0.1481      0.51     -32    39
# Comp:  2           [NII]6583_d      1.048      0.51     -32    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        46
#  comp.  1:       -64        58
#  comp.  2:       -62        40
# chi2/DOF: 1.013; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.206      0.44     -64    58
# Comp:  1                Halpha      1.844      0.44     -64    58
# Comp:  2             [SII]6716     0.3265      0.41     -62    40
# Comp:  2             [SII]6731     0.7964      0.41     -62    40
# Comp:  2              HeII4687      0.000      0.41     -62    40
# Comp:  2               HeI5876      0.000      0.41     -62    40
# Comp:  2          [OIII]5007_d      1.976      0.52     -62    40
# Comp:  2            [OI]6300_d      0.000      0.52     -62    40
# Comp:  2           [NII]6583_d     0.8352      0.52     -62    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87        65
#  comp.  1:       -77       104
#  comp.  2:       -46         1
# chi2/DOF: 1.013; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.658      0.52     -77   104
# Comp:  1                Halpha      2.191      0.52     -77   104
# Comp:  2             [SII]6716     0.3514      0.38     -46     1
# Comp:  2             [SII]6731     0.6766      0.38     -46     1
# Comp:  2              HeII4687      0.000      0.38     -46     1
# Comp:  2               HeI5876    0.07494      0.38     -46     1
# Comp:  2          [OIII]5007_d      1.501      0.48     -46     1
# Comp:  2            [OI]6300_d      0.000      0.48     -46     1
# Comp:  2           [NII]6583_d     0.7978      0.48     -46     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        45
#  comp.  1:       -70        80
#  comp.  2:       -44        22
# chi2/DOF: 1.010; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 9; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.313      0.47     -70    80
# Comp:  1                Halpha      2.353      0.47     -70    80
# Comp:  2             [SII]6716     0.6198      0.39     -44    22
# Comp:  2             [SII]6731     0.7837      0.39     -44    22
# Comp:  2              HeII4687      0.000      0.39     -44    22
# Comp:  2               HeI5876    0.09669      0.39     -44    22
# Comp:  2          [OIII]5007_d      1.820      0.49     -44    22
# Comp:  2            [OI]6300_d     0.3069      0.49     -44    22
# Comp:  2           [NII]6583_d      1.129      0.49     -44    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        43
#  comp.  1:       -83        97
#  comp.  2:       -43        38
# chi2/DOF: 1.014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.879      0.50     -83    97
# Comp:  1                Halpha      2.991      0.50     -83    97
# Comp:  2             [SII]6716     0.3169      0.41     -43    38
# Comp:  2             [SII]6731     0.8286      0.41     -43    38
# Comp:  2              HeII4687      0.000      0.41     -43    38
# Comp:  2               HeI5876      0.000      0.41     -43    38
# Comp:  2          [OIII]5007_d      1.707      0.51     -43    38
# Comp:  2            [OI]6300_d     0.1218      0.51     -43    38
# Comp:  2           [NII]6583_d     0.7824      0.51     -43    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85        53
#  comp.  1:       -71        71
#  comp.  2:       -46        18
# chi2/DOF: 1.014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.243      0.46     -71    71
# Comp:  1                Halpha      2.770      0.46     -71    71
# Comp:  2             [SII]6716     0.4421      0.39     -46    18
# Comp:  2             [SII]6731     0.8432      0.39     -46    18
# Comp:  2              HeII4687      0.000      0.39     -46    18
# Comp:  2               HeI5876      0.000      0.39     -46    18
# Comp:  2          [OIII]5007_d      1.568      0.49     -46    18
# Comp:  2            [OI]6300_d      0.000      0.49     -46    18
# Comp:  2           [NII]6583_d      1.294      0.49     -46    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        67
#  comp.  1:       -49       113
#  comp.  2:       -42         1
# chi2/DOF: 1.011; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.768      0.53     -49   113
# Comp:  1                Halpha      2.303      0.53     -49   113
# Comp:  2             [SII]6716     0.7513      0.38     -42     1
# Comp:  2             [SII]6731     0.5950      0.38     -42     1
# Comp:  2              HeII4687     0.3432      0.38     -42     1
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.188      0.45     -68    68
# Comp:  1                Halpha      2.419      0.45     -68    68
# Comp:  2             [SII]6716     0.3364      0.40     -33    29
# Comp:  2             [SII]6731     0.6919      0.40     -33    29
# Comp:  2              HeII4687     0.3447      0.40     -33    29
# Comp:  2               HeI5876      0.000      0.40     -33    29
# Comp:  2          [OIII]5007_d      1.993      0.50     -33    29
# Comp:  2            [OI]6300_d    0.07167      0.50     -33    29
# Comp:  2           [NII]6583_d     0.8785      0.50     -33    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        36
#  comp.  1:       -63        87
#  comp.  2:       -34         1
# chi2/DOF: 1.009; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.278      0.49     -63    87
# Comp:  1                Halpha      3.216      0.49     -63    87
# Comp:  2             [SII]6716     0.9670      0.38     -34     1
# Comp:  2             [SII]6731     0.6039      0.38     -34     1
# Comp:  2              HeII4687      0.000      0.38     -34     1
# Comp:  2               HeI5876     0.2475      0.38     -34     1
# Comp:  2          [OIII]5007_d      1.411      0.48     -34     1
# Comp:  2            [OI]6300_d      0.000      0.48     -34     1
# Comp:  2           [NII]6583_d      1.425      0.48     -34     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        60
#  comp.  1:       -34        76
#  comp.  2:       -43         1
# chi2/DOF: 1.011; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.370      0.47     -34    76
# Comp:  1                Halpha      2.390      0.47     -34    76
# Comp:  2             [SII]6716     0.7270      0.38     -43     1
# Comp:  2             [SII]6731     0.5919      0.38     -43     1
# Comp:  2              HeII4687      0.000      0.38     -43     1
# Comp:  2               HeI5876    0.03141      0.38     -43     1
# Comp:  2          [OIII]5007_d      1.965      0.48     -43     1
# Comp:  2            [OI]6300_d     0.3552      0.48     -43     1
# Comp:  2           [NII]6583_d     0.7900      0.48     -43     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        48
#  comp.  1:       -63       101
#  comp.  2:       -38        30
# chi2/DOF: 1.009; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.805      0.51     -63   101
# Comp:  1                Halpha      3.581      0.51     -63   101
# Comp:  2             [SII]6716     0.6234      0.40     -38    30
# Comp:  2             [SII]6731     0.7437      0.40     -38    30
# Comp:  2              HeII4687      0.000      0.40     -38    30
# Comp:  2               HeI5876     0.1892      0.40     -38    30
# Comp:  2          [OIII]5007_d      1.861      0.50     -38    30
# Comp:  2            [OI]6300_d      0.000      0.50     -38    30
# Comp:  2           [NII]6583_d      1.146      0.50     -38    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        59
#  comp.  1:       -56        93
#  comp.  2:       -37        34
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.958      0.50     -56    93
# Comp:  1                Halpha      2.439      0.50     -56    93
# Comp:  2             [SII]6716     0.9865      0.40     -37    34
# Comp:  2             [SII]6731     0.7437      0.40     -37    34
# Comp:  2              HeII4687     0.5082      0.40     -37    34
# Comp:  2               HeI5876    0.09976      0.40     -37    34
# Comp:  2          [OIII]5007_d      1.900      0.51     -37    34
# Comp:  2            [OI]6300_d      0.000      0.51     -37    34
# Comp:  2           [NII]6583_d      1.203      0.51     -37    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        28
#  comp.  1:       -75       126
#  comp.  2:       -35        42
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.039      0.55     -75   126
# Comp:  1                Halpha      3.717      0.55     -75   126
# Comp:  2             [SII]6716     0.3269      0.41     -35    42
# Comp:  2             [SII]6731     0.6779      0.41     -35    42
# Comp:  2              HeII4687      0.000      0.41     -35    42
# Comp:  2               HeI5876      0.000      0.41     -35    42
# Comp:  2          [OIII]5007_d      1.929      0.52     -35    42
# Comp:  2            [OI]6300_d    0.05297      0.52     -35    42
# Comp:  2           [NII]6583_d      1.643      0.52     -35    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        54
#  comp.  1:       -70        80
#  comp.  2:       -36        19
# chi2/DOF: 1.015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.126      0.47     -70    80
# Comp:  1                Halpha      2.712      0.47     -70    80
# Comp:  2             [SII]6716     0.7599      0.39     -36    19
# Comp:  2             [SII]6731     0.6633      0.39     -36    19
# Comp:  2              HeII4687      0.000      0.39     -36    19
# Comp:  2               HeI5876      0.000      0.39     -36    19
# Comp:  2          [OIII]5007_d      1.662      0.49     -36    19
# Comp:  2            [OI]6300_d      0.000      0.49     -36    19
# Comp:  2           [NII]6583_d      1.495      0.49     -36    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29         1
#  comp.  1:       -40        69
#  comp.  2:       -52        55
# chi2/DOF: 1.013; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.188      0.45     -40    69
# Comp:  1                Halpha      2.233      0.45     -40    69
# Comp:  2             [SII]6716     0.1210      0.43     -52    55
# Comp:  2             [SII]6731     0.6676      0.43     -52    55
# Comp:  2              HeII4687     0.6108      0.43     -52    55
# Comp:  2               HeI5876    0.08188      0.43     -52    55
# Comp:  2          [OIII]5007_d      2.205      0.54     -52    55
# Comp:  2            [OI]6300_d      0.000      0.54     -52    55
# Comp:  2           [NII]6583_d      1.069      0.54     -52    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        33
#  comp.  1:       -68        89
#  comp.  2:       -32        15
# chi2/DOF: 1.010; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      2.810      0.49     -68    89
# Comp:  1                Halpha      2.928      0.49     -68    89
# Comp:  2             [SII]6716     0.9183      0.38     -32    15
# Comp:  2             [SII]6731     0.5139      0.38     -32    15
# Comp:  2              HeII4687      0.000      0.38     -32    15
# Comp:  2               HeI5876     0.2440      0.38     -32    15
# Comp:  2          [OIII]5007_d      1.921      0.48     -32    15
# Comp:  2            [OI]6300_d      0.000      0.48     -32    15
# Comp:  2           [NII]6583_d      1.344      0.48     -32    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:       -63        78
#  comp.  2:       -41         1
# chi2/DOF: 1.014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.598      0.47     -63    78
# Comp:  1                Halpha      2.246      0.47     -63    78
# Comp:  2             [SII]6716     0.7067      0.38     -41     1
# Comp:  2             [SII]6731     0.5368      0.38     -41     1
# Comp:  2              HeII4687      0.000      0.38     -41     1
# Comp:  2               HeI5876      0.000      0.38     -41     1
# Comp:  2          [OIII]5007_d      1.974      0.48     -41     1
# Comp:  2            [OI]6300_d     0.2479      0.48     -41     1
# Comp:  2           [NII]6583_d     0.9847      0.48     -41     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        61
#  comp.  1:       -67        65
#  comp.  2:       -27        52
# chi2/DOF: 1.014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.809      0.45     -67    65
# Comp:  1                Halpha      2.438      0.45     -67    65
# Comp:  2             [SII]6716      1.140      0.43     -27    52
# Comp:  2             [SII]6731     0.8975      0.43     -27    52
# Comp:  2              HeII4687      0.000      0.43     -27    52
# Comp:  2               HeI5876     0.3299      0.43     -27    52
# Comp:  2          [OIII]5007_d      1.996      0.54     -27    52
# Comp:  2            [OI]6300_d      0.000      0.54     -27    52
# Comp:  2           [NII]6583_d      1.421      0.54     -27    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        32
#  comp.  1:       -65        82
#  comp.  2:       -40         2
# chi2/DOF: 1.012; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.009      0.48     -65    82
# Comp:  1                Halpha      2.827      0.48     -65    82
# Comp:  2             [SII]6716     0.3755      0.38     -40     2
# Comp:  2             [SII]6731     0.7264      0.38     -40     2
# Comp:  2              HeII4687      0.000      0.38     -40     2
# Comp:  2               HeI5876     0.2475      0.38     -40     2
# Comp:  2          [OIII]5007_d      1.809      0.48     -40     2
# Comp:  2            [OI]6300_d    0.09902      0.48     -40     2
# Comp:  2           [NII]6583_d      1.387      0.48     -40     2
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        40
#  comp.  1:       -46        52
#  comp.  2:       -41         1
# chi2/DOF: 1.010; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.663      0.43     -46    52
# Comp:  1                Halpha      2.162      0.43     -46    52
# Comp:  2             [SII]6716     0.7500      0.38     -41     1
# Comp:  2             [SII]6731     0.6824      0.38     -41     1
# Comp:  2              HeII4687      0.000      0.38     -41     1
# Comp:  2               HeI5876     0.1375      0.38     -41     1
# Comp:  2          [OIII]5007_d      1.643      0.48     -41     1
# Comp:  2            [OI]6300_d     0.3367      0.48     -41     1
# Comp:  2           [NII]6583_d      1.448      0.48     -41     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66        66
#  comp.  1:       -75        62
#  comp.  2:       -38        36
# chi2/DOF: 1.014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      1.288      0.44     -75    62
# Comp:  1                Halpha      2.353      0.44     -75    62
# Comp:  2             [SII]6716     0.4606      0.40     -38    36
# Comp:  2             [SII]6731     0.6874      0.40     -38    36
# Comp:  2              HeII4687      0.000      0.40     -38    36
# Comp:  2               HeI5876      0.000      0.40     -38    36
# Comp:  2          [OIII]5007_d      1.748      0.51     -38    36
# Comp:  2            [OI]6300_d     0.2741      0.51     -38    36
# Comp:  2           [NII]6583_d      1.361      0.51     -38    36
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.78314455, 0.66094668, 0.3856429 , 0.17287616, 0.23332459,
#        0.21997407, 0.21080706, 0.18814011, 0.35201344])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([1.92925858, 3.29167709, 0.75774911, 0.9668537 , 0.        ,
#        0.        , 1.91552574, 0.00360084, 1.54916105])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_12_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_12", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_12_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_12_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_12_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.059375    0.024102
# 1        Halpha  0.101305    0.020341
# 2     [SII]6716  0.023321    0.011869
# 3     [SII]6731  0.029756    0.005320
# 4      HeII4687  0.000000    0.007181
# 5       HeI5876  0.000000    0.006770
# 6  [OIII]5007_d  0.058952    0.006488
# 7    [OI]6300_d  0.000111    0.005790
# 8   [NII]6583_d  0.047677    0.010834
#           Name      Flux  Error_flux
# 0        Hbeta  0.059375    0.024102
# 1       Halpha  0.101305    0.020341
# 2    [SII]6716  0.023321    0.011869
# 3    [SII]6731  0.029756    0.005320
# 4     HeII4687  0.000000    0.007181
# 5      HeI5876  0.000000    0.006770
# 6   [OIII]4959  0.014738    0.006488
# 7   [OIII]5007  0.044214    0.006488
# 8     [OI]6300  0.000083    0.005790
# 9     [OI]6364  0.000028    0.005790
# 10   [NII]6548  0.011919    0.010834
# 11   [NII]6583  0.035758    0.010834

# %%
np.median(flux_rf_rebin)
# Out:
# 0.03077602991889404
