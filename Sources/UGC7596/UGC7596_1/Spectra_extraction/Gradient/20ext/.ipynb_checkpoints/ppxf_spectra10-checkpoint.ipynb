# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_10.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.00189
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_10']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4443.30215892 4444.779367   4446.25657507 ... 7080.11857589 7081.59578397
#  7083.07299204] [0.03167471 0.04458115 0.05200991 ... 0.03014027 0.02720575 0.02651566] [0.00601134 0.00601134 0.00601134 ... 0.00601134 0.00601134 0.00601134]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.22165108 2.22238968 2.22312829 ... 3.54005929 3.54079789 3.5415365 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
# chi2/DOF: 0.03504; DOF: 1942; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
# chi2/DOF: 0.02534; DOF: 1918; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-56.6807547 ,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        24
#  comp.  1:       -74       110
#  comp.  2:       -66        63
# chi2/DOF: 1.000; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.389      0.54     -74   110
# Comp:  1                Halpha      4.209      0.54     -74   110
# Comp:  2             [SII]6716      1.898      0.45     -66    63
# Comp:  2             [SII]6731     0.9409      0.45     -66    63
# Comp:  2              HeII4687    0.02029      0.45     -66    63
# Comp:  2               HeI5876      0.000      0.45     -66    63
# Comp:  2          [OIII]5007_d      1.688      0.57     -66    63
# Comp:  2            [OI]6300_d      1.007      0.57     -66    63
# Comp:  2           [NII]6583_d   0.005262      0.57     -66    63
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  5.193; gas flux:      4 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  5.003; gas flux:      6 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  3.178; gas flux:      3 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  1.532; gas flux:      1 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  0.034; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  2.096; gas flux:      2 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.211; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise: 0.006563; gas flux:      0 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:       -98       130
#  comp.  2:       -74        88
# chi2/DOF: 0.9908; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.492      0.57     -98   130
# Comp:  1                Halpha      4.145      0.57     -98   130
# Comp:  2             [SII]6716      2.009      0.50     -74    88
# Comp:  2             [SII]6731      1.179      0.50     -74    88
# Comp:  2              HeII4687   0.003462      0.50     -74    88
# Comp:  2               HeI5876    0.07771      0.50     -74    88
# Comp:  2          [OIII]5007_d      2.882      0.63     -74    88
# Comp:  2            [OI]6300_d     0.4707      0.63     -74    88
# Comp:  2           [NII]6583_d     0.3899      0.63     -74    88
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43         1
#  comp.  1:       -67       114
#  comp.  2:       -77        89
# chi2/DOF: 0.9902; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.067      0.54     -67   114
# Comp:  1                Halpha      5.197      0.54     -67   114
# Comp:  2             [SII]6716      2.433      0.50     -77    89
# Comp:  2             [SII]6731     0.6968      0.50     -77    89
# Comp:  2              HeII4687     0.4000      0.50     -77    89
# Comp:  2               HeI5876     0.6463      0.50     -77    89
# Comp:  2          [OIII]5007_d      1.188      0.63     -77    89
# Comp:  2            [OI]6300_d      1.667      0.63     -77    89
# Comp:  2           [NII]6583_d      0.000      0.63     -77    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        38
#  comp.  1:       -62       110
#  comp.  2:      -107       117
# chi2/DOF: 0.9871; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.224      0.54     -62   110
# Comp:  1                Halpha      3.749      0.54     -62   110
# Comp:  2             [SII]6716      2.450      0.55    -107   117
# Comp:  2             [SII]6731      1.458      0.55    -107   117
# Comp:  2              HeII4687      0.000      0.55    -107   117
# Comp:  2               HeI5876      0.000      0.55    -107   117
# Comp:  2          [OIII]5007_d      3.596      0.69    -107   117
# Comp:  2            [OI]6300_d      1.669      0.69    -107   117
# Comp:  2           [NII]6583_d      0.000      0.69    -107   117
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        27
#  comp.  1:       -99       138
#  comp.  2:       -72        58
# chi2/DOF: 0.9890; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.170      0.59     -99   138
# Comp:  1                Halpha      5.715      0.59     -99   138
# Comp:  2             [SII]6716      1.831      0.44     -72    58
# Comp:  2             [SII]6731     0.9351      0.44     -72    58
# Comp:  2              HeII4687      0.000      0.44     -72    58
# Comp:  2               HeI5876     0.5851      0.44     -72    58
# Comp:  2          [OIII]5007_d      2.227      0.56     -72    58
# Comp:  2            [OI]6300_d      1.111      0.56     -72    58
# Comp:  2           [NII]6583_d     0.6127      0.56     -72    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
#  comp.  1:       -69       121
#  comp.  2:       -70        73
# chi2/DOF: 0.9869; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.989      0.56     -69   121
# Comp:  1                Halpha      4.951      0.56     -69   121
# Comp:  2             [SII]6716      2.362      0.47     -70    73
# Comp:  2             [SII]6731      1.446      0.47     -70    73
# Comp:  2              HeII4687      0.000      0.47     -70    73
# Comp:  2               HeI5876   0.007867      0.47     -70    73
# Comp:  2          [OIII]5007_d      1.543      0.59     -70    73
# Comp:  2            [OI]6300_d     0.8293      0.59     -70    73
# Comp:  2           [NII]6583_d     0.1502      0.59     -70    73
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        24
#  comp.  1:       -73       111
#  comp.  2:       -78        76
# chi2/DOF: 0.9924; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.186      0.54     -73   111
# Comp:  1                Halpha      4.784      0.54     -73   111
# Comp:  2             [SII]6716      1.757      0.48     -78    76
# Comp:  2             [SII]6731     0.6289      0.48     -78    76
# Comp:  2              HeII4687     0.3133      0.48     -78    76
# Comp:  2               HeI5876     0.3942      0.48     -78    76
# Comp:  2          [OIII]5007_d      2.639      0.60     -78    76
# Comp:  2            [OI]6300_d     0.7206      0.60     -78    76
# Comp:  2           [NII]6583_d   0.008066      0.60     -78    76
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25         8
#  comp.  1:       -55       121
#  comp.  2:       -70        71
# chi2/DOF: 0.9905; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.873      0.56     -55   121
# Comp:  1                Halpha      4.310      0.56     -55   121
# Comp:  2             [SII]6716      2.166      0.47     -70    71
# Comp:  2             [SII]6731     0.8147      0.47     -70    71
# Comp:  2              HeII4687    0.07872      0.47     -70    71
# Comp:  2               HeI5876      0.000      0.47     -70    71
# Comp:  2          [OIII]5007_d      2.450      0.59     -70    71
# Comp:  2            [OI]6300_d      1.373      0.59     -70    71
# Comp:  2           [NII]6583_d      0.000      0.59     -70    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        66
#  comp.  1:       -92       125
#  comp.  2:       -58        30
# chi2/DOF: 0.9912; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.032      0.56     -92   125
# Comp:  1                Halpha      5.295      0.56     -92   125
# Comp:  2             [SII]6716      1.580      0.40     -58    30
# Comp:  2             [SII]6731     0.8057      0.40     -58    30
# Comp:  2              HeII4687    0.04650      0.40     -58    30
# Comp:  2               HeI5876    0.02711      0.40     -58    30
# Comp:  2          [OIII]5007_d      1.754      0.51     -58    30
# Comp:  2            [OI]6300_d     0.5004      0.51     -58    30
# Comp:  2           [NII]6583_d     0.1831      0.51     -58    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:       -82       133
#  comp.  2:       -60        65
# chi2/DOF: 0.9938; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.681      0.58     -82   133
# Comp:  1                Halpha      5.398      0.58     -82   133
# Comp:  2             [SII]6716      1.808      0.46     -60    65
# Comp:  2             [SII]6731     0.9759      0.46     -60    65
# Comp:  2              HeII4687      0.000      0.46     -60    65
# Comp:  2               HeI5876     0.4681      0.46     -60    65
# Comp:  2          [OIII]5007_d      1.675      0.58     -60    65
# Comp:  2            [OI]6300_d      1.111      0.58     -60    65
# Comp:  2           [NII]6583_d      0.000      0.58     -60    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:       -79       108
#  comp.  2:       -65        86
# chi2/DOF: 0.9937; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.086      0.53     -79   108
# Comp:  1                Halpha      3.182      0.53     -79   108
# Comp:  2             [SII]6716      1.928      0.49     -65    86
# Comp:  2             [SII]6731      1.380      0.49     -65    86
# Comp:  2              HeII4687     0.1370      0.49     -65    86
# Comp:  2               HeI5876     0.8131      0.49     -65    86
# Comp:  2          [OIII]5007_d      2.291      0.62     -65    86
# Comp:  2            [OI]6300_d      1.704      0.62     -65    86
# Comp:  2           [NII]6583_d      0.000      0.62     -65    86
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        21
#  comp.  1:       -89       111
#  comp.  2:       -34        62
# chi2/DOF: 0.9915; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.825      0.54     -89   111
# Comp:  1                Halpha      4.989      0.54     -89   111
# Comp:  2             [SII]6716      2.001      0.45     -34    62
# Comp:  2             [SII]6731      1.614      0.45     -34    62
# Comp:  2              HeII4687      0.000      0.45     -34    62
# Comp:  2               HeI5876     0.5741      0.45     -34    62
# Comp:  2          [OIII]5007_d      1.481      0.57     -34    62
# Comp:  2            [OI]6300_d     0.9698      0.57     -34    62
# Comp:  2           [NII]6583_d     0.1109      0.57     -34    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        29
#  comp.  1:       -60        90
#  comp.  2:       -79       129
# chi2/DOF: 0.9828; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.976      0.50     -60    90
# Comp:  1                Halpha      4.249      0.50     -60    90
# Comp:  2             [SII]6716      2.834      0.57     -79   129
# Comp:  2             [SII]6731      2.161      0.57     -79   129
# Comp:  2              HeII4687     0.5562      0.57     -79   129
# Comp:  2               HeI5876      0.000      0.57     -79   129
# Comp:  2          [OIII]5007_d      2.497      0.72     -79   129
# Comp:  2            [OI]6300_d      1.047      0.72     -79   129
# Comp:  2           [NII]6583_d      0.000      0.72     -79   129
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        55
#  comp.  1:       -76       148
#  comp.  2:       -65        36
# chi2/DOF: 0.9917; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.186      0.60     -76   148
# Comp:  1                Halpha      4.523      0.60     -76   148
# Comp:  2             [SII]6716      1.779      0.41     -65    36
# Comp:  2             [SII]6731     0.8253      0.41     -65    36
# Comp:  2              HeII4687      0.000      0.41     -65    36
# Comp:  2               HeI5876     0.5984      0.41     -65    36
# Comp:  2          [OIII]5007_d      1.657      0.52     -65    36
# Comp:  2            [OI]6300_d     0.9003      0.52     -65    36
# Comp:  2           [NII]6583_d      0.000      0.52     -65    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        18
#  comp.  1:       -99       132
#  comp.  2:       -57        45
# chi2/DOF: 0.9946; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.339      0.57     -99   132
# Comp:  1                Halpha      4.796      0.57     -99   132
# Comp:  2             [SII]6716      1.889      0.42     -57    45
# Comp:  2             [SII]6731      1.122      0.42     -57    45
# Comp:  2              HeII4687      0.000      0.42     -57    45
# Comp:  2               HeI5876   0.008416      0.42     -57    45
# Comp:  2          [OIII]5007_d      1.207      0.54     -57    45
# Comp:  2            [OI]6300_d     0.8366      0.54     -57    45
# Comp:  2           [NII]6583_d      0.000      0.54     -57    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        18
#  comp.  1:       -66       104
#  comp.  2:       -60        49
# chi2/DOF: 0.9932; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.213      0.53     -66   104
# Comp:  1                Halpha      4.366      0.53     -66   104
# Comp:  2             [SII]6716      1.994      0.43     -60    49
# Comp:  2             [SII]6731      1.329      0.43     -60    49
# Comp:  2              HeII4687      0.000      0.43     -60    49
# Comp:  2               HeI5876      0.000      0.43     -60    49
# Comp:  2          [OIII]5007_d      1.495      0.54     -60    49
# Comp:  2            [OI]6300_d      1.327      0.54     -60    49
# Comp:  2           [NII]6583_d     0.3415      0.54     -60    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -61       102
#  comp.  2:       -59        46
# chi2/DOF: 0.9947; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.338      0.52     -61   102
# Comp:  1                Halpha      3.916      0.52     -61   102
# Comp:  2             [SII]6716      1.778      0.42     -59    46
# Comp:  2             [SII]6731     0.9371      0.42     -59    46
# Comp:  2              HeII4687      0.000      0.42     -59    46
# Comp:  2               HeI5876    0.01093      0.42     -59    46
# Comp:  2          [OIII]5007_d      1.981      0.54     -59    46
# Comp:  2            [OI]6300_d     0.6848      0.54     -59    46
# Comp:  2           [NII]6583_d      0.000      0.54     -59    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47         1
#  comp.  1:       -90       107
#  comp.  2:       -83       114
# chi2/DOF: 0.9898; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.818      0.53     -90   107
# Comp:  1                Halpha      4.478      0.53     -90   107
# Comp:  2             [SII]6716      2.013      0.54     -83   114
# Comp:  2             [SII]6731      1.333      0.54     -83   114
# Comp:  2              HeII4687      0.000      0.54     -83   114
# Comp:  2               HeI5876    0.02957      0.54     -83   114
# Comp:  2          [OIII]5007_d      3.394      0.69     -83   114
# Comp:  2            [OI]6300_d      1.714      0.69     -83   114
# Comp:  2           [NII]6583_d     0.1046      0.69     -83   114
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        12
#  comp.  1:       -87       144
#  comp.  2:       -49        48
# chi2/DOF: 0.9905; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.859      0.60     -87   144
# Comp:  1                Halpha      5.209      0.60     -87   144
# Comp:  2             [SII]6716      2.069      0.43     -49    48
# Comp:  2             [SII]6731     0.3912      0.43     -49    48
# Comp:  2              HeII4687    0.01199      0.43     -49    48
# Comp:  2               HeI5876     0.2037      0.43     -49    48
# Comp:  2          [OIII]5007_d      2.146      0.54     -49    48
# Comp:  2            [OI]6300_d      1.266      0.54     -49    48
# Comp:  2           [NII]6583_d     0.4360      0.54     -49    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        51
#  comp.  1:       -66       127
#  comp.  2:       -56        87
# chi2/DOF: 0.9933; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.060      0.57     -66   127
# Comp:  1                Halpha      4.214      0.57     -66   127
# Comp:  2             [SII]6716      2.146      0.50     -56    87
# Comp:  2             [SII]6731      1.770      0.50     -56    87
# Comp:  2              HeII4687    0.07499      0.50     -56    87
# Comp:  2               HeI5876      0.000      0.50     -56    87
# Comp:  2          [OIII]5007_d      2.107      0.63     -56    87
# Comp:  2            [OI]6300_d      1.713      0.63     -56    87
# Comp:  2           [NII]6583_d      0.000      0.63     -56    87
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41         1
#  comp.  1:       -64        92
#  comp.  2:       -38        61
# chi2/DOF: 0.9887; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.591      0.50     -64    92
# Comp:  1                Halpha      4.451      0.50     -64    92
# Comp:  2             [SII]6716      1.929      0.45     -38    61
# Comp:  2             [SII]6731     0.5857      0.45     -38    61
# Comp:  2              HeII4687     0.2222      0.45     -38    61
# Comp:  2               HeI5876     0.9833      0.45     -38    61
# Comp:  2          [OIII]5007_d      1.914      0.57     -38    61
# Comp:  2            [OI]6300_d     0.9856      0.57     -38    61
# Comp:  2           [NII]6583_d     0.3697      0.57     -38    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        45
#  comp.  1:       -71       107
#  comp.  2:       -61       103
# chi2/DOF: 0.9891; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.647      0.53     -71   107
# Comp:  1                Halpha      3.751      0.53     -71   107
# Comp:  2             [SII]6716      2.440      0.52     -61   103
# Comp:  2             [SII]6731      1.686      0.52     -61   103
# Comp:  2              HeII4687      0.000      0.52     -61   103
# Comp:  2               HeI5876      0.000      0.52     -61   103
# Comp:  2          [OIII]5007_d      1.963      0.66     -61   103
# Comp:  2            [OI]6300_d      1.436      0.66     -61   103
# Comp:  2           [NII]6583_d     0.2423      0.66     -61   103
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:       -93       113
#  comp.  2:       -64        82
# chi2/DOF: 0.9942; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.233      0.54     -93   113
# Comp:  1                Halpha      4.987      0.54     -93   113
# Comp:  2             [SII]6716      1.687      0.49     -64    82
# Comp:  2             [SII]6731      1.614      0.49     -64    82
# Comp:  2              HeII4687     0.2642      0.49     -64    82
# Comp:  2               HeI5876      0.000      0.49     -64    82
# Comp:  2          [OIII]5007_d      2.479      0.61     -64    82
# Comp:  2            [OI]6300_d     0.9895      0.61     -64    82
# Comp:  2           [NII]6583_d     0.1136      0.61     -64    82
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42         1
#  comp.  1:       -65       123
#  comp.  2:       -74        73
# chi2/DOF: 0.9897; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 18/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.305      0.56     -65   123
# Comp:  1                Halpha      4.328      0.56     -65   123
# Comp:  2             [SII]6716      2.024      0.47     -74    73
# Comp:  2             [SII]6731      1.370      0.47     -74    73
# Comp:  2              HeII4687    0.07579      0.47     -74    73
# Comp:  2               HeI5876     0.5570      0.47     -74    73
# Comp:  2          [OIII]5007_d      2.408      0.59     -74    73
# Comp:  2            [OI]6300_d      1.370      0.59     -74    73
# Comp:  2           [NII]6583_d      0.000      0.59     -74    73
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:       -70        90
#  comp.  2:       -32        62
# chi2/DOF: 0.9942; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.119      0.50     -70    90
# Comp:  1                Halpha      3.800      0.50     -70    90
# Comp:  2             [SII]6716      1.816      0.45     -32    62
# Comp:  2             [SII]6731      1.224      0.45     -32    62
# Comp:  2              HeII4687      0.000      0.45     -32    62
# Comp:  2               HeI5876      0.000      0.45     -32    62
# Comp:  2          [OIII]5007_d      1.355      0.57     -32    62
# Comp:  2            [OI]6300_d     0.9427      0.57     -32    62
# Comp:  2           [NII]6583_d     0.3443      0.57     -32    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        30
#  comp.  1:       -66        98
#  comp.  2:       -90        77
# chi2/DOF: 0.9909; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.319      0.52     -66    98
# Comp:  1                Halpha      4.795      0.52     -66    98
# Comp:  2             [SII]6716      1.901      0.48     -90    77
# Comp:  2             [SII]6731      1.153      0.48     -90    77
# Comp:  2              HeII4687      0.000      0.48     -90    77
# Comp:  2               HeI5876      0.000      0.48     -90    77
# Comp:  2          [OIII]5007_d      2.275      0.60     -90    77
# Comp:  2            [OI]6300_d      1.452      0.60     -90    77
# Comp:  2           [NII]6583_d     0.3089      0.60     -90    77
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        64
#  comp.  1:       -52       139
#  comp.  2:       -49       112
# chi2/DOF: 0.9910; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.874      0.59     -52   139
# Comp:  1                Halpha      3.942      0.59     -52   139
# Comp:  2             [SII]6716      2.254      0.54     -49   112
# Comp:  2             [SII]6731      1.812      0.54     -49   112
# Comp:  2              HeII4687      0.000      0.54     -49   112
# Comp:  2               HeI5876      0.000      0.54     -49   112
# Comp:  2          [OIII]5007_d      1.980      0.68     -49   112
# Comp:  2            [OI]6300_d      1.137      0.68     -49   112
# Comp:  2           [NII]6583_d     0.1542      0.68     -49   112
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        46
#  comp.  1:       -66       100
#  comp.  2:       -64        90
# chi2/DOF: 0.9955; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.495      0.52     -66   100
# Comp:  1                Halpha      3.435      0.52     -66   100
# Comp:  2             [SII]6716      2.313      0.50     -64    90
# Comp:  2             [SII]6731      1.335      0.50     -64    90
# Comp:  2              HeII4687      0.000      0.50     -64    90
# Comp:  2               HeI5876      0.000      0.50     -64    90
# Comp:  2          [OIII]5007_d      2.371      0.63     -64    90
# Comp:  2            [OI]6300_d      1.044      0.63     -64    90
# Comp:  2           [NII]6583_d     0.6965      0.63     -64    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        26
#  comp.  1:       -78        98
#  comp.  2:       -71       102
# chi2/DOF: 0.9902; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.944      0.52     -78    98
# Comp:  1                Halpha      4.594      0.52     -78    98
# Comp:  2             [SII]6716      2.367      0.52     -71   102
# Comp:  2             [SII]6731      1.547      0.52     -71   102
# Comp:  2              HeII4687     0.2962      0.52     -71   102
# Comp:  2               HeI5876     0.6887      0.52     -71   102
# Comp:  2          [OIII]5007_d      2.669      0.66     -71   102
# Comp:  2            [OI]6300_d      1.266      0.66     -71   102
# Comp:  2           [NII]6583_d     0.8619      0.66     -71   102
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        72
#  comp.  1:       -78        98
#  comp.  2:      -100       108
# chi2/DOF: 0.9911; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.790      0.52     -78    98
# Comp:  1                Halpha      3.813      0.52     -78    98
# Comp:  2             [SII]6716      2.064      0.53    -100   108
# Comp:  2             [SII]6731     0.5625      0.53    -100   108
# Comp:  2              HeII4687      0.000      0.53    -100   108
# Comp:  2               HeI5876     0.5293      0.53    -100   108
# Comp:  2          [OIII]5007_d      2.724      0.67    -100   108
# Comp:  2            [OI]6300_d     0.7031      0.67    -100   108
# Comp:  2           [NII]6583_d      0.000      0.67    -100   108
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        63
#  comp.  1:       -89       131
#  comp.  2:       -88        79
# chi2/DOF: 0.9952; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.985      0.57     -89   131
# Comp:  1                Halpha      4.883      0.57     -89   131
# Comp:  2             [SII]6716      2.310      0.48     -88    79
# Comp:  2             [SII]6731     0.9875      0.48     -88    79
# Comp:  2              HeII4687    0.02669      0.48     -88    79
# Comp:  2               HeI5876      0.000      0.48     -88    79
# Comp:  2          [OIII]5007_d      1.517      0.61     -88    79
# Comp:  2            [OI]6300_d     0.8038      0.61     -88    79
# Comp:  2           [NII]6583_d     0.5886      0.61     -88    79
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        33
#  comp.  1:       -98       127
#  comp.  2:       -61        74
# chi2/DOF: 0.9910; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.398      0.57     -98   127
# Comp:  1                Halpha      5.761      0.57     -98   127
# Comp:  2             [SII]6716      2.111      0.47     -61    74
# Comp:  2             [SII]6731      1.319      0.47     -61    74
# Comp:  2              HeII4687    0.09843      0.47     -61    74
# Comp:  2               HeI5876      0.000      0.47     -61    74
# Comp:  2          [OIII]5007_d      1.622      0.60     -61    74
# Comp:  2            [OI]6300_d     0.9403      0.60     -61    74
# Comp:  2           [NII]6583_d      0.000      0.60     -61    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        35
#  comp.  1:       -64       109
#  comp.  2:       -70        63
# chi2/DOF: 0.9877; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.676      0.54     -64   109
# Comp:  1                Halpha      5.306      0.54     -64   109
# Comp:  2             [SII]6716      1.667      0.45     -70    63
# Comp:  2             [SII]6731     0.3264      0.45     -70    63
# Comp:  2              HeII4687     0.1577      0.45     -70    63
# Comp:  2               HeI5876      0.000      0.45     -70    63
# Comp:  2          [OIII]5007_d      1.925      0.57     -70    63
# Comp:  2            [OI]6300_d      1.256      0.57     -70    63
# Comp:  2           [NII]6583_d      0.000      0.57     -70    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
#  comp.  1:       -68        96
#  comp.  2:       -56        78
# chi2/DOF: 0.9869; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.357      0.51     -68    96
# Comp:  1                Halpha      4.732      0.51     -68    96
# Comp:  2             [SII]6716      2.047      0.48     -56    78
# Comp:  2             [SII]6731     0.6128      0.48     -56    78
# Comp:  2              HeII4687     0.1194      0.48     -56    78
# Comp:  2               HeI5876      0.000      0.48     -56    78
# Comp:  2          [OIII]5007_d      2.689      0.61     -56    78
# Comp:  2            [OI]6300_d      1.290      0.61     -56    78
# Comp:  2           [NII]6583_d     0.9665      0.61     -56    78
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        45
#  comp.  1:       -62        81
#  comp.  2:       -70        69
# chi2/DOF: 0.9923; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.617      0.48     -62    81
# Comp:  1                Halpha      4.093      0.48     -62    81
# Comp:  2             [SII]6716      1.942      0.46     -70    69
# Comp:  2             [SII]6731     0.8478      0.46     -70    69
# Comp:  2              HeII4687      0.000      0.46     -70    69
# Comp:  2               HeI5876     0.5473      0.46     -70    69
# Comp:  2          [OIII]5007_d      1.823      0.59     -70    69
# Comp:  2            [OI]6300_d      1.353      0.59     -70    69
# Comp:  2           [NII]6583_d      0.000      0.59     -70    69
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        46
#  comp.  1:       -57       111
#  comp.  2:       -63        15
# chi2/DOF: 0.9894; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.455      0.54     -57   111
# Comp:  1                Halpha      4.184      0.54     -57   111
# Comp:  2             [SII]6716      1.700      0.39     -63    15
# Comp:  2             [SII]6731     0.7601      0.39     -63    15
# Comp:  2              HeII4687    0.05377      0.39     -63    15
# Comp:  2               HeI5876     0.8649      0.39     -63    15
# Comp:  2          [OIII]5007_d      1.467      0.49     -63    15
# Comp:  2            [OI]6300_d      1.257      0.49     -63    15
# Comp:  2           [NII]6583_d     0.1269      0.49     -63    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        35
#  comp.  1:       -70        87
#  comp.  2:       -78        68
# chi2/DOF: 0.9914; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.315      0.49     -70    87
# Comp:  1                Halpha      3.992      0.49     -70    87
# Comp:  2             [SII]6716      2.090      0.46     -78    68
# Comp:  2             [SII]6731     0.4673      0.46     -78    68
# Comp:  2              HeII4687     0.2211      0.46     -78    68
# Comp:  2               HeI5876      0.000      0.46     -78    68
# Comp:  2          [OIII]5007_d     0.9992      0.58     -78    68
# Comp:  2            [OI]6300_d     0.4171      0.58     -78    68
# Comp:  2           [NII]6583_d      0.000      0.58     -78    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        32
#  comp.  1:       -68       109
#  comp.  2:       -49         7
# chi2/DOF: 0.9897; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.414      0.54     -68   109
# Comp:  1                Halpha      4.315      0.54     -68   109
# Comp:  2             [SII]6716      1.449      0.39     -49     7
# Comp:  2             [SII]6731     0.4698      0.39     -49     7
# Comp:  2              HeII4687    0.06200      0.39     -49     7
# Comp:  2               HeI5876      0.000      0.39     -49     7
# Comp:  2          [OIII]5007_d      1.615      0.49     -49     7
# Comp:  2            [OI]6300_d     0.9988      0.49     -49     7
# Comp:  2           [NII]6583_d      0.000      0.49     -49     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66       101
#  comp.  1:       -84       121
#  comp.  2:       -65       112
# chi2/DOF: 0.9921; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.524      0.56     -84   121
# Comp:  1                Halpha      3.297      0.56     -84   121
# Comp:  2             [SII]6716      2.198      0.54     -65   112
# Comp:  2             [SII]6731     0.6340      0.54     -65   112
# Comp:  2              HeII4687      0.000      0.54     -65   112
# Comp:  2               HeI5876     0.3168      0.54     -65   112
# Comp:  2          [OIII]5007_d      1.884      0.68     -65   112
# Comp:  2            [OI]6300_d     0.9160      0.68     -65   112
# Comp:  2           [NII]6583_d    0.01971      0.68     -65   112
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:       -69       110
#  comp.  2:       -39        67
# chi2/DOF: 0.9916; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.065      0.54     -69   110
# Comp:  1                Halpha      3.766      0.54     -69   110
# Comp:  2             [SII]6716      1.801      0.46     -39    67
# Comp:  2             [SII]6731      1.726      0.46     -39    67
# Comp:  2              HeII4687      0.000      0.46     -39    67
# Comp:  2               HeI5876      0.000      0.46     -39    67
# Comp:  2          [OIII]5007_d      2.211      0.58     -39    67
# Comp:  2            [OI]6300_d     0.6143      0.58     -39    67
# Comp:  2           [NII]6583_d     0.2771      0.58     -39    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54        41
#  comp.  1:       -80       113
#  comp.  2:       -63        88
# chi2/DOF: 0.9873; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.814      0.54     -80   113
# Comp:  1                Halpha      4.871      0.54     -80   113
# Comp:  2             [SII]6716      1.951      0.50     -63    88
# Comp:  2             [SII]6731     0.5395      0.50     -63    88
# Comp:  2              HeII4687      0.000      0.50     -63    88
# Comp:  2               HeI5876      0.000      0.50     -63    88
# Comp:  2          [OIII]5007_d      2.264      0.63     -63    88
# Comp:  2            [OI]6300_d      1.032      0.63     -63    88
# Comp:  2           [NII]6583_d      0.000      0.63     -63    88
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       -78       127
#  comp.  2:       -82        55
# chi2/DOF: 0.9912; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.222      0.57     -78   127
# Comp:  1                Halpha      3.690      0.57     -78   127
# Comp:  2             [SII]6716      1.925      0.44     -82    55
# Comp:  2             [SII]6731     0.6175      0.44     -82    55
# Comp:  2              HeII4687      0.000      0.44     -82    55
# Comp:  2               HeI5876      0.000      0.44     -82    55
# Comp:  2          [OIII]5007_d      1.663      0.55     -82    55
# Comp:  2            [OI]6300_d      1.216      0.55     -82    55
# Comp:  2           [NII]6583_d      0.000      0.55     -82    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        53
#  comp.  1:       -59       114
#  comp.  2:       -61         1
# chi2/DOF: 0.9926; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.446      0.54     -59   114
# Comp:  1                Halpha      4.144      0.54     -59   114
# Comp:  2             [SII]6716      1.529      0.39     -61     1
# Comp:  2             [SII]6731     0.7258      0.39     -61     1
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.493      0.48     -63    81
# Comp:  1                Halpha      3.248      0.48     -63    81
# Comp:  2             [SII]6716      1.981      0.53     -52   106
# Comp:  2             [SII]6731      1.416      0.53     -52   106
# Comp:  2              HeII4687     0.2876      0.53     -52   106
# Comp:  2               HeI5876      0.000      0.53     -52   106
# Comp:  2          [OIII]5007_d      1.913      0.67     -52   106
# Comp:  2            [OI]6300_d      1.335      0.67     -52   106
# Comp:  2           [NII]6583_d      0.000      0.67     -52   106
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        43
#  comp.  1:       -63       106
#  comp.  2:       -76        77
# chi2/DOF: 0.9927; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.261      0.53     -63   106
# Comp:  1                Halpha      4.249      0.53     -63   106
# Comp:  2             [SII]6716      2.191      0.48     -76    77
# Comp:  2             [SII]6731     0.7320      0.48     -76    77
# Comp:  2              HeII4687      0.000      0.48     -76    77
# Comp:  2               HeI5876      0.000      0.48     -76    77
# Comp:  2          [OIII]5007_d      1.634      0.60     -76    77
# Comp:  2            [OI]6300_d     0.8754      0.60     -76    77
# Comp:  2           [NII]6583_d     0.6602      0.60     -76    77
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        27
#  comp.  1:       -55        86
#  comp.  2:       -52        78
# chi2/DOF: 0.9941; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.332      0.49     -55    86
# Comp:  1                Halpha      4.384      0.49     -55    86
# Comp:  2             [SII]6716      1.885      0.48     -52    78
# Comp:  2             [SII]6731      1.656      0.48     -52    78
# Comp:  2              HeII4687      0.000      0.48     -52    78
# Comp:  2               HeI5876      0.000      0.48     -52    78
# Comp:  2          [OIII]5007_d      2.406      0.61     -52    78
# Comp:  2            [OI]6300_d      1.331      0.61     -52    78
# Comp:  2           [NII]6583_d      0.000      0.61     -52    78
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69         1
#  comp.  1:       -98       134
#  comp.  2:       -54        74
# chi2/DOF: 0.9889; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.354      0.58     -98   134
# Comp:  1                Halpha      4.398      0.58     -98   134
# Comp:  2             [SII]6716      2.127      0.47     -54    74
# Comp:  2             [SII]6731      1.471      0.47     -54    74
# Comp:  2              HeII4687      0.000      0.47     -54    74
# Comp:  2               HeI5876     0.8139      0.47     -54    74
# Comp:  2          [OIII]5007_d      1.433      0.60     -54    74
# Comp:  2            [OI]6300_d      1.351      0.60     -54    74
# Comp:  2           [NII]6583_d     0.4381      0.60     -54    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        48
#  comp.  1:       -66       139
#  comp.  2:       -74        67
# chi2/DOF: 0.9861; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.365      0.59     -66   139
# Comp:  1                Halpha      5.095      0.59     -66   139
# Comp:  2             [SII]6716      2.232      0.46     -74    67
# Comp:  2             [SII]6731      1.334      0.46     -74    67
# Comp:  2              HeII4687     0.1848      0.46     -74    67
# Comp:  2               HeI5876     0.4009      0.46     -74    67
# Comp:  2          [OIII]5007_d      1.722      0.58     -74    67
# Comp:  2            [OI]6300_d     0.6756      0.58     -74    67
# Comp:  2           [NII]6583_d    0.08198      0.58     -74    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:       -83       103
#  comp.  2:       -60        25
# chi2/DOF: 0.9891; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.639      0.52     -83   103
# Comp:  1                Halpha      4.617      0.52     -83   103
# Comp:  2             [SII]6716      1.561      0.40     -60    25
# Comp:  2             [SII]6731     0.8354      0.40     -60    25
# Comp:  2              HeII4687    0.08561      0.40     -60    25
# Comp:  2               HeI5876     0.1403      0.40     -60    25
# Comp:  2          [OIII]5007_d      1.313      0.50     -60    25
# Comp:  2            [OI]6300_d      1.106      0.50     -60    25
# Comp:  2           [NII]6583_d     0.2412      0.50     -60    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:       -58        72
#  comp.  2:       -87        86
# chi2/DOF: 0.9857; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.453      0.47     -58    72
# Comp:  1                Halpha      3.962      0.47     -58    72
# Comp:  2             [SII]6716      2.194      0.49     -87    86
# Comp:  2             [SII]6731     0.6573      0.49     -87    86
# Comp:  2              HeII4687      0.000      0.49     -87    86
# Comp:  2               HeI5876      0.000      0.49     -87    86
# Comp:  2          [OIII]5007_d      2.223      0.62     -87    86
# Comp:  2            [OI]6300_d      1.641      0.62     -87    86
# Comp:  2           [NII]6583_d     0.2121      0.62     -87    86
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:       -81       123
#  comp.  2:       -51        14
# chi2/DOF: 0.9919; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.820      0.56     -81   123
# Comp:  1                Halpha      4.569      0.56     -81   123
# Comp:  2             [SII]6716      1.430      0.39     -51    14
# Comp:  2             [SII]6731     0.8142      0.39     -51    14
# Comp:  2              HeII4687      0.000      0.39     -51    14
# Comp:  2               HeI5876     0.2647      0.39     -51    14
# Comp:  2          [OIII]5007_d      1.410      0.49     -51    14
# Comp:  2            [OI]6300_d     0.9611      0.49     -51    14
# Comp:  2           [NII]6583_d      0.000      0.49     -51    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
#  comp.  1:       -79       106
#  comp.  2:      -104        86
# chi2/DOF: 0.9930; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.520      0.53     -79   106
# Comp:  1                Halpha      4.821      0.53     -79   106
# Comp:  2             [SII]6716      2.158      0.49    -104    86
# Comp:  2             [SII]6731      1.133      0.49    -104    86
# Comp:  2              HeII4687      0.000      0.49    -104    86
# Comp:  2               HeI5876     0.4626      0.49    -104    86
# Comp:  2          [OIII]5007_d      2.425      0.62    -104    86
# Comp:  2            [OI]6300_d     0.6191      0.62    -104    86
# Comp:  2           [NII]6583_d     0.5890      0.62    -104    86
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        48
#  comp.  1:       -80       111
#  comp.  2:       -55         1
# chi2/DOF: 0.9926; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      5.185      0.54     -80   111
# Comp:  1                Halpha      4.644      0.54     -80   111
# Comp:  2             [SII]6716      1.610      0.39     -55     1
# Comp:  2             [SII]6731     0.5021      0.39     -55     1
# Comp:  2              HeII4687      0.000      0.39     -55     1
# Comp:  2               HeI5876      0.000      0.39     -55     1
# Comp:  2          [OIII]5007_d      1.677      0.49     -55     1
# Comp:  2            [OI]6300_d     0.6557      0.49     -55     1
# Comp:  2           [NII]6583_d      0.000      0.49     -55     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:       -63        79
#  comp.  2:       -65        18
# chi2/DOF: 0.9909; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.086      0.48     -63    79
# Comp:  1                Halpha      3.778      0.48     -63    79
# Comp:  2             [SII]6716      1.732      0.39     -65    18
# Comp:  2             [SII]6731     0.7743      0.39     -65    18
# Comp:  2              HeII4687      0.000      0.39     -65    18
# Comp:  2               HeI5876     0.6821      0.39     -65    18
# Comp:  2          [OIII]5007_d     0.9740      0.50     -65    18
# Comp:  2            [OI]6300_d     0.7552      0.50     -65    18
# Comp:  2           [NII]6583_d      0.000      0.50     -65    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        43
#  comp.  1:       -76        95
#  comp.  2:       -84        61
# chi2/DOF: 0.9947; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      3.095      0.51     -76    95
# Comp:  1                Halpha      4.244      0.51     -76    95
# Comp:  2             [SII]6716      1.804      0.45     -84    61
# Comp:  2             [SII]6731     0.6969      0.45     -84    61
# Comp:  2              HeII4687     0.1000      0.45     -84    61
# Comp:  2               HeI5876     0.2232      0.45     -84    61
# Comp:  2          [OIII]5007_d      1.474      0.57     -84    61
# Comp:  2            [OI]6300_d     0.9356      0.57     -84    61
# Comp:  2           [NII]6583_d     0.1827      0.57     -84    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       -74       118
#  comp.  2:       -55        71
# chi2/DOF: 0.9912; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      6.100      0.55     -74   118
# Comp:  1                Halpha      3.898      0.55     -74   118
# Comp:  2             [SII]6716      1.858      0.47     -55    71
# Comp:  2             [SII]6731     0.2901      0.47     -55    71
# Comp:  2              HeII4687      0.000      0.47     -55    71
# Comp:  2               HeI5876      1.293      0.47     -55    71
# Comp:  2          [OIII]5007_d      1.759      0.59     -55    71
# Comp:  2            [OI]6300_d     0.7169      0.59     -55    71
# Comp:  2           [NII]6583_d    0.03043      0.59     -55    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42         1
#  comp.  1:       -69        98
#  comp.  2:       -78        29
# chi2/DOF: 0.9918; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      4.699      0.52     -69    98
# Comp:  1                Halpha      4.132      0.52     -69    98
# Comp:  2             [SII]6716      1.654      0.40     -78    29
# Comp:  2             [SII]6731     0.9017      0.40     -78    29
# Comp:  2              HeII4687    0.03578      0.40     -78    29
# Comp:  2               HeI5876      0.000      0.40     -78    29
# Comp:  2          [OIII]5007_d      1.134      0.51     -78    29
# Comp:  2            [OI]6300_d      1.001      0.51     -78    29
# Comp:  2           [NII]6583_d      0.000      0.51     -78    29
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([1.16424271, 0.91293089, 0.38818998, 0.54966496, 0.12237636,
#        0.40675459, 0.61951874, 0.4145262 , 0.30773477])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([4.45014449, 5.76120303, 2.65925358, 1.32089368, 0.01982538,
#        0.        , 1.76272135, 1.32294462, 0.00722578])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_10_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_10", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_10_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_10_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_10_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0         Hbeta  0.134451    0.035175
# 1        Halpha  0.174062    0.027582
# 2     [SII]6716  0.080343    0.011728
# 3     [SII]6731  0.039908    0.016607
# 4      HeII4687  0.000599    0.003697
# 5       HeI5876  0.000000    0.012289
# 6  [OIII]5007_d  0.053257    0.018717
# 7    [OI]6300_d  0.039970    0.012524
# 8   [NII]6583_d  0.000218    0.009298
#           Name      Flux  Error_flux
# 0        Hbeta  0.134451    0.035175
# 1       Halpha  0.174062    0.027582
# 2    [SII]6716  0.080343    0.011728
# 3    [SII]6731  0.039908    0.016607
# 4     HeII4687  0.000599    0.003697
# 5      HeI5876  0.000000    0.012289
# 6   [OIII]4959  0.013314    0.018717
# 7   [OIII]5007  0.039943    0.018717
# 8     [OI]6300  0.029977    0.012524
# 9     [OI]6364  0.009992    0.012524
# 10   [NII]6548  0.000055    0.009298
# 11   [NII]6583  0.000164    0.009298

# %%
np.median(flux_rf_rebin)
# Out:
# 0.03021279162357864
