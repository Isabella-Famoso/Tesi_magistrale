# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum2s_1', unpack = True)
z = 0.0238 
wv_rf = wv/(1+z)
flux_rf = flux*(1+z)
error_rf = error*(1+z)
error = np.ones(len(flux))*0.04
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4200.76186755 4202.20746239 4203.65305724 ... 6928.59933581 6930.04493065
#  6931.49052549] [1.2108123  0.43234511 0.36346934 ... 0.21623486 0.23290377 0.21900096] [0.040952 0.040952 0.040952 ... 0.040952 0.040952 0.040952]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.10038093 2.10110373 2.10182653 ... 3.46429967 3.46502247 3.46574526]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3343, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3343, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3343, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         7       200
# chi2/DOF: 0.01598; DOF: 2076; degree = 4; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 5; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -83        57
# chi2/DOF: 0.008764; DOF: 2021; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-82.82207953,  57.04233344])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets =False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp =  ppxf(templates, galaxy, error_gal, velscale, start, moments=moments, #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), 
          regul=0, reg_dim=reg_dim, component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -170         1
#  comp.  1:       -35        32
#  comp.  2:       -32        40
# chi2/DOF: 1.971; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.85      0.27     -35    32
# Comp:  1                 Hbeta      47.46      0.27     -35    32
# Comp:  1                Halpha      155.2      0.27     -35    32
# Comp:  2             [SII]6716      13.50      0.27     -32    40
# Comp:  2             [SII]6731      11.69      0.27     -32    40
# Comp:  2              HeII4687     0.4498      0.27     -32    40
# Comp:  2               HeI5876      6.119      0.27     -32    40
# Comp:  2          [OIII]5007_d      82.13      0.35     -32    40
# Comp:  2            [OI]6300_d      1.983      0.35     -32    40
# Comp:  2           [NII]6583_d      44.12      0.35     -32    40
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Regularization

# %%
#Rescale del noise in modo che chi2/N=1 
noise_rescale = error_gal*np.sqrt(pp.chi2); #rescale_noise = noise*np.sqrt(Chi**2/DOF)

#Again ppxf without regul but with noise rescaled
pp_no_reg = ppxf(templates, galaxy, noise_rescale, velscale, start, moments=moments, #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), 
          regul=0, reg_dim=reg_dim, component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
light_weights_no = pp_no_reg.weights[~gas_component]       # Exclude weights of the gas templates
light_weights_no = light_weights_no.reshape(reg_dim)        # Reshape to (n_ages, n_metal)
age = sps.mean_age_metal(light_weights_no);
ML = sps.mass_to_light(light_weights_no, band="SDSS/r", redshift=z);
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -170         1
#  comp.  1:       -35        32
#  comp.  2:       -32        40
# chi2/DOF: 1.000; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.85      0.37     -35    32
# Comp:  1                 Hbeta      47.46      0.37     -35    32
# Comp:  1                Halpha      155.2      0.37     -35    32
# Comp:  2             [SII]6716      13.50      0.38     -32    40
# Comp:  2             [SII]6731      11.69      0.38     -32    40
# Comp:  2              HeII4687     0.4498      0.38     -32    40
# Comp:  2               HeI5876      6.119      0.38     -32    40
# Comp:  2          [OIII]5007_d      82.13      0.48     -32    40
# Comp:  2            [OI]6300_d      1.983      0.48     -32    40
# Comp:  2           [NII]6583_d      44.12      0.48     -32    40
# -----------------------------------------------------------------
# Weighted <lg_age> [yr]: 9.50
# Weighted <[M/H]>: -1.71
# (M*/L)=1.033 (SDSS/r at z=0.0238)

# %%
#pp with regul 
regul_err = 0.001
pp_reg = ppxf(templates, galaxy, noise_rescale, velscale, start, moments=moments, #We put what we had set here to do the ppxf procedure
        degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), 
        regul=1/regul_err, reg_dim=reg_dim, component=component,
        gas_component=gas_component, gas_names=gas_names,
        gas_reddening=gas_reddening)

print(f"Desired Delta Chi^2: {np.sqrt(2*galaxy.size):#.4g}")
print(f"Current Delta Chi^2: {(pp_reg.chi2 - 1)*galaxy.size:#.4g}")

light_weights = pp_reg.weights[~gas_component]       # Exclude weights of the gas templates
light_weights = light_weights.reshape(reg_dim)        # Reshape to (n_ages, n_metal)
sps.mean_age_metal(light_weights);
sps.mass_to_light(light_weights, band="SDSS/r", redshift=z);
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -106      1000
#  comp.  1:       -35        32
#  comp.  2:       -32        40
# chi2/DOF: 1.005; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.48      0.37     -35    32
# Comp:  1                 Hbeta      47.06      0.37     -35    32
# Comp:  1                Halpha      154.8      0.37     -35    32
# Comp:  2             [SII]6716      13.48      0.38     -32    40
# Comp:  2             [SII]6731      11.69      0.38     -32    40
# Comp:  2              HeII4687     0.4516      0.38     -32    40
# Comp:  2               HeI5876      6.136      0.38     -32    40
# Comp:  2          [OIII]5007_d      82.14      0.48     -32    40
# Comp:  2            [OI]6300_d      1.976      0.48     -32    40
# Comp:  2           [NII]6583_d      44.14      0.48     -32    40
# -----------------------------------------------------------------
# Desired Delta Chi^2: 69.31
# Current Delta Chi^2: 12.51
# Weighted <lg_age> [yr]: 8.28
# Weighted <[M/H]>: -0.218
# (M*/L)=0.2462 (SDSS/r at z=0.0238)

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  73.93; gas flux:     18 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  180.2; gas flux:     47 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  584.8; gas flux:    208 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  46.55; gas flux:     18 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  41.87; gas flux:     16 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.499; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  20.48; gas flux:      7 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  211.5; gas flux:     84 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  5.397; gas flux:      3 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  118.8; gas flux:     59 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -103      1000
#  comp.  1:       -32        28
#  comp.  2:       -33        42
# chi2/DOF: 1.740; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.15      0.46     -32    28
# Comp:  1                 Hbeta      49.48      0.40     -32    28
# Comp:  1                Halpha      153.1      0.52     -32    28
# Comp:  2             [SII]6716      13.20      0.19     -33    42
# Comp:  2             [SII]6731      11.70      0.19     -33    42
# Comp:  2              HeII4687     0.2293      0.28     -33    42
# Comp:  2               HeI5876      6.269      0.20     -33    42
# Comp:  2          [OIII]5007_d      84.42      0.52     -33    42
# Comp:  2            [OI]6300_d      2.213      0.19     -33    42
# Comp:  2           [NII]6583_d      42.36      0.33     -33    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -170       735
#  comp.  1:       -33        30
#  comp.  2:       -32        25
# chi2/DOF: 1.756; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.72      0.47     -33    30
# Comp:  1                 Hbeta      45.98      0.40     -33    30
# Comp:  1                Halpha      153.9      0.52     -33    30
# Comp:  2             [SII]6716      12.45      0.19     -32    25
# Comp:  2             [SII]6731      10.31      0.18     -32    25
# Comp:  2              HeII4687     0.4722      0.27     -32    25
# Comp:  2               HeI5876      6.136      0.19     -32    25
# Comp:  2          [OIII]5007_d      79.42      0.51     -32    25
# Comp:  2            [OI]6300_d      1.773      0.18     -32    25
# Comp:  2           [NII]6583_d      41.73      0.32     -32    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        39       755
#  comp.  1:       -31        13
#  comp.  2:       -29        34
# chi2/DOF: 1.637; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.57      0.45     -31    13
# Comp:  1                 Hbeta      46.01      0.39     -31    13
# Comp:  1                Halpha      152.9      0.51     -31    13
# Comp:  2             [SII]6716      11.63      0.19     -29    34
# Comp:  2             [SII]6731      12.17      0.18     -29    34
# Comp:  2              HeII4687     0.4152      0.27     -29    34
# Comp:  2               HeI5876      6.544      0.19     -29    34
# Comp:  2          [OIII]5007_d      79.84      0.51     -29    34
# Comp:  2            [OI]6300_d      1.911      0.18     -29    34
# Comp:  2           [NII]6583_d      42.12      0.32     -29    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -509      1000
#  comp.  1:       -35        34
#  comp.  2:       -33        26
# chi2/DOF: 1.600; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.26      0.47     -35    34
# Comp:  1                 Hbeta      47.27      0.41     -35    34
# Comp:  1                Halpha      151.9      0.52     -35    34
# Comp:  2             [SII]6716      12.08      0.19     -33    26
# Comp:  2             [SII]6731      12.12      0.18     -33    26
# Comp:  2              HeII4687     0.2312      0.27     -33    26
# Comp:  2               HeI5876      5.833      0.19     -33    26
# Comp:  2          [OIII]5007_d      77.70      0.51     -33    26
# Comp:  2            [OI]6300_d      2.057      0.18     -33    26
# Comp:  2           [NII]6583_d      40.77      0.32     -33    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0       702
#  comp.  1:       -34        33
#  comp.  2:       -34        39
# chi2/DOF: 1.662; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.88      0.47     -34    33
# Comp:  1                 Hbeta      44.48      0.40     -34    33
# Comp:  1                Halpha      156.9      0.52     -34    33
# Comp:  2             [SII]6716      12.99      0.19     -34    39
# Comp:  2             [SII]6731      11.94      0.19     -34    39
# Comp:  2              HeII4687     0.4524      0.28     -34    39
# Comp:  2               HeI5876      5.684      0.19     -34    39
# Comp:  2          [OIII]5007_d      82.79      0.52     -34    39
# Comp:  2            [OI]6300_d      2.020      0.19     -34    39
# Comp:  2           [NII]6583_d      42.40      0.33     -34    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -170         1
#  comp.  1:       -34        23
#  comp.  2:       -36        21
# chi2/DOF: 1.687; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 15; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.44      0.46     -34    23
# Comp:  1                 Hbeta      47.11      0.40     -34    23
# Comp:  1                Halpha      152.6      0.51     -34    23
# Comp:  2             [SII]6716      13.08      0.19     -36    21
# Comp:  2             [SII]6731      10.94      0.18     -36    21
# Comp:  2              HeII4687     0.4167      0.26     -36    21
# Comp:  2               HeI5876      5.713      0.18     -36    21
# Comp:  2          [OIII]5007_d      73.29      0.50     -36    21
# Comp:  2            [OI]6300_d      1.666      0.18     -36    21
# Comp:  2           [NII]6583_d      42.00      0.32     -36    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -822      1000
#  comp.  1:       -28        20
#  comp.  2:       -36        30
# chi2/DOF: 1.587; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.04      0.46     -28    20
# Comp:  1                 Hbeta      44.05      0.40     -28    20
# Comp:  1                Halpha      144.9      0.51     -28    20
# Comp:  2             [SII]6716      12.43      0.19     -36    30
# Comp:  2             [SII]6731      11.80      0.18     -36    30
# Comp:  2              HeII4687     0.1976      0.27     -36    30
# Comp:  2               HeI5876      5.249      0.19     -36    30
# Comp:  2          [OIII]5007_d      77.18      0.51     -36    30
# Comp:  2            [OI]6300_d      2.014      0.18     -36    30
# Comp:  2           [NII]6583_d      42.97      0.32     -36    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15      1000
#  comp.  1:       -30        10
#  comp.  2:       -31        39
# chi2/DOF: 1.582; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.47      0.45     -30    10
# Comp:  1                 Hbeta      45.06      0.39     -30    10
# Comp:  1                Halpha      147.2      0.51     -30    10
# Comp:  2             [SII]6716      11.88      0.19     -31    39
# Comp:  2             [SII]6731      11.64      0.19     -31    39
# Comp:  2              HeII4687     0.3712      0.28     -31    39
# Comp:  2               HeI5876      6.224      0.19     -31    39
# Comp:  2          [OIII]5007_d      80.38      0.52     -31    39
# Comp:  2            [OI]6300_d      1.807      0.19     -31    39
# Comp:  2           [NII]6583_d      43.57      0.33     -31    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -200         1
#  comp.  1:       -33        19
#  comp.  2:       -31        35
# chi2/DOF: 1.686; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.41      0.45     -33    19
# Comp:  1                 Hbeta      51.60      0.39     -33    19
# Comp:  1                Halpha      156.4      0.51     -33    19
# Comp:  2             [SII]6716      12.69      0.19     -31    35
# Comp:  2             [SII]6731      11.17      0.18     -31    35
# Comp:  2              HeII4687     0.4290      0.27     -31    35
# Comp:  2               HeI5876      5.517      0.19     -31    35
# Comp:  2          [OIII]5007_d      82.92      0.51     -31    35
# Comp:  2            [OI]6300_d      2.121      0.18     -31    35
# Comp:  2           [NII]6583_d      42.59      0.32     -31    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -444      1000
#  comp.  1:       -32        21
#  comp.  2:       -28        33
# chi2/DOF: 1.676; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.64      0.46     -32    21
# Comp:  1                 Hbeta      42.81      0.40     -32    21
# Comp:  1                Halpha      150.8      0.51     -32    21
# Comp:  2             [SII]6716      13.09      0.19     -28    33
# Comp:  2             [SII]6731      12.40      0.18     -28    33
# Comp:  2              HeII4687     0.4726      0.27     -28    33
# Comp:  2               HeI5876      5.337      0.19     -28    33
# Comp:  2          [OIII]5007_d      85.14      0.51     -28    33
# Comp:  2            [OI]6300_d      1.842      0.18     -28    33
# Comp:  2           [NII]6583_d      42.38      0.32     -28    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       157       861
#  comp.  1:       -34        31
#  comp.  2:       -35        41
# chi2/DOF: 1.668; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.85      0.47     -34    31
# Comp:  1                 Hbeta      51.29      0.40     -34    31
# Comp:  1                Halpha      154.3      0.52     -34    31
# Comp:  2             [SII]6716      12.61      0.19     -35    41
# Comp:  2             [SII]6731      10.58      0.19     -35    41
# Comp:  2              HeII4687     0.1831      0.28     -35    41
# Comp:  2               HeI5876      6.189      0.19     -35    41
# Comp:  2          [OIII]5007_d      84.28      0.52     -35    41
# Comp:  2            [OI]6300_d      1.943      0.19     -35    41
# Comp:  2           [NII]6583_d      43.42      0.33     -35    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -440       429
#  comp.  1:       -34        22
#  comp.  2:       -34        39
# chi2/DOF: 1.749; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.06      0.46     -34    22
# Comp:  1                 Hbeta      42.96      0.40     -34    22
# Comp:  1                Halpha      151.6      0.51     -34    22
# Comp:  2             [SII]6716      13.27      0.19     -34    39
# Comp:  2             [SII]6731      10.75      0.19     -34    39
# Comp:  2              HeII4687     0.4741      0.28     -34    39
# Comp:  2               HeI5876      6.408      0.19     -34    39
# Comp:  2          [OIII]5007_d      82.15      0.52     -34    39
# Comp:  2            [OI]6300_d      1.820      0.19     -34    39
# Comp:  2           [NII]6583_d      43.49      0.33     -34    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99      1000
#  comp.  1:       -36        35
#  comp.  2:       -30        35
# chi2/DOF: 1.505; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.79      0.47     -36    35
# Comp:  1                 Hbeta      44.42      0.41     -36    35
# Comp:  1                Halpha      150.4      0.52     -36    35
# Comp:  2             [SII]6716      11.52      0.19     -30    35
# Comp:  2             [SII]6731      10.64      0.18     -30    35
# Comp:  2              HeII4687     0.3528      0.27     -30    35
# Comp:  2               HeI5876      6.149      0.19     -30    35
# Comp:  2          [OIII]5007_d      82.28      0.51     -30    35
# Comp:  2            [OI]6300_d      2.009      0.18     -30    35
# Comp:  2           [NII]6583_d      44.34      0.32     -30    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        59       526
#  comp.  1:       -34        27
#  comp.  2:       -29        32
# chi2/DOF: 1.770; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.33      0.46     -34    27
# Comp:  1                 Hbeta      49.42      0.40     -34    27
# Comp:  1                Halpha      151.3      0.52     -34    27
# Comp:  2             [SII]6716      12.89      0.19     -29    32
# Comp:  2             [SII]6731      10.39      0.18     -29    32
# Comp:  2              HeII4687     0.2348      0.27     -29    32
# Comp:  2               HeI5876      6.454      0.19     -29    32
# Comp:  2          [OIII]5007_d      83.72      0.51     -29    32
# Comp:  2            [OI]6300_d      1.824      0.18     -29    32
# Comp:  2           [NII]6583_d      41.39      0.32     -29    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -237         1
#  comp.  1:       -35        22
#  comp.  2:       -36        31
# chi2/DOF: 1.714; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.06      0.46     -35    22
# Comp:  1                 Hbeta      42.93      0.40     -35    22
# Comp:  1                Halpha      151.5      0.51     -35    22
# Comp:  2             [SII]6716      13.13      0.19     -36    31
# Comp:  2             [SII]6731      11.31      0.18     -36    31
# Comp:  2              HeII4687     0.6950      0.27     -36    31
# Comp:  2               HeI5876      5.532      0.19     -36    31
# Comp:  2          [OIII]5007_d      82.94      0.51     -36    31
# Comp:  2            [OI]6300_d      1.832      0.18     -36    31
# Comp:  2           [NII]6583_d      42.93      0.32     -36    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -545       946
#  comp.  1:       -31        22
#  comp.  2:       -35        27
# chi2/DOF: 1.772; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.20      0.46     -31    22
# Comp:  1                 Hbeta      48.99      0.40     -31    22
# Comp:  1                Halpha      153.2      0.51     -31    22
# Comp:  2             [SII]6716      11.97      0.19     -35    27
# Comp:  2             [SII]6731      11.90      0.18     -35    27
# Comp:  2              HeII4687     0.3673      0.27     -35    27
# Comp:  2               HeI5876      5.869      0.19     -35    27
# Comp:  2          [OIII]5007_d      78.64      0.51     -35    27
# Comp:  2            [OI]6300_d      1.757      0.18     -35    27
# Comp:  2           [NII]6583_d      42.77      0.32     -35    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -160       944
#  comp.  1:       -33        26
#  comp.  2:       -39        35
# chi2/DOF: 1.585; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.06      0.46     -33    26
# Comp:  1                 Hbeta      39.58      0.40     -33    26
# Comp:  1                Halpha      150.6      0.52     -33    26
# Comp:  2             [SII]6716      11.63      0.19     -39    35
# Comp:  2             [SII]6731      12.04      0.19     -39    35
# Comp:  2              HeII4687     0.1880      0.27     -39    35
# Comp:  2               HeI5876      6.119      0.19     -39    35
# Comp:  2          [OIII]5007_d      77.05      0.51     -39    35
# Comp:  2            [OI]6300_d      1.815      0.18     -39    35
# Comp:  2           [NII]6583_d      40.62      0.32     -39    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11       113
#  comp.  1:       -33        34
#  comp.  2:       -33        36
# chi2/DOF: 1.579; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 69; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.43      0.47     -33    34
# Comp:  1                 Hbeta      54.53      0.41     -33    34
# Comp:  1                Halpha      153.3      0.52     -33    34
# Comp:  2             [SII]6716      11.50      0.19     -33    36
# Comp:  2             [SII]6731      10.52      0.18     -33    36
# Comp:  2              HeII4687     0.4059      0.27     -33    36
# Comp:  2               HeI5876      6.115      0.19     -33    36
# Comp:  2          [OIII]5007_d      82.54      0.52     -33    36
# Comp:  2            [OI]6300_d      2.175      0.18     -33    36
# Comp:  2           [NII]6583_d      42.11      0.32     -33    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45      1000
#  comp.  1:       -28        16
#  comp.  2:       -37        30
# chi2/DOF: 1.547; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.60      0.45     -28    16
# Comp:  1                 Hbeta      44.88      0.39     -28    16
# Comp:  1                Halpha      149.9      0.51     -28    16
# Comp:  2             [SII]6716      13.44      0.19     -37    30
# Comp:  2             [SII]6731      12.24      0.18     -37    30
# Comp:  2              HeII4687     0.1874      0.27     -37    30
# Comp:  2               HeI5876      6.037      0.19     -37    30
# Comp:  2          [OIII]5007_d      74.44      0.51     -37    30
# Comp:  2            [OI]6300_d      2.104      0.18     -37    30
# Comp:  2           [NII]6583_d      42.19      0.32     -37    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        95      1000
#  comp.  1:       -34        19
#  comp.  2:       -32        23
# chi2/DOF: 1.632; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.29      0.45     -34    19
# Comp:  1                 Hbeta      39.83      0.39     -34    19
# Comp:  1                Halpha      155.3      0.51     -34    19
# Comp:  2             [SII]6716      12.29      0.19     -32    23
# Comp:  2             [SII]6731      11.25      0.18     -32    23
# Comp:  2              HeII4687     0.2043      0.27     -32    23
# Comp:  2               HeI5876      6.252      0.19     -32    23
# Comp:  2          [OIII]5007_d      77.40      0.50     -32    23
# Comp:  2            [OI]6300_d      2.031      0.18     -32    23
# Comp:  2           [NII]6583_d      42.41      0.32     -32    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -616       888
#  comp.  1:       -32        15
#  comp.  2:       -35        27
# chi2/DOF: 1.691; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.93      0.45     -32    15
# Comp:  1                 Hbeta      47.85      0.39     -32    15
# Comp:  1                Halpha      149.5      0.51     -32    15
# Comp:  2             [SII]6716      12.58      0.19     -35    27
# Comp:  2             [SII]6731      11.10      0.18     -35    27
# Comp:  2              HeII4687     0.4377      0.27     -35    27
# Comp:  2               HeI5876      6.437      0.19     -35    27
# Comp:  2          [OIII]5007_d      78.20      0.51     -35    27
# Comp:  2            [OI]6300_d      1.812      0.18     -35    27
# Comp:  2           [NII]6583_d      43.38      0.32     -35    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       151       872
#  comp.  1:       -33        17
#  comp.  2:       -30        35
# chi2/DOF: 1.661; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.27      0.45     -33    17
# Comp:  1                 Hbeta      48.61      0.39     -33    17
# Comp:  1                Halpha      155.3      0.51     -33    17
# Comp:  2             [SII]6716      14.15      0.19     -30    35
# Comp:  2             [SII]6731      10.30      0.18     -30    35
# Comp:  2              HeII4687     0.4551      0.27     -30    35
# Comp:  2               HeI5876      6.515      0.19     -30    35
# Comp:  2          [OIII]5007_d      83.89      0.52     -30    35
# Comp:  2            [OI]6300_d      1.729      0.18     -30    35
# Comp:  2           [NII]6583_d      42.04      0.32     -30    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -165       647
#  comp.  1:       -34        19
#  comp.  2:       -37        29
# chi2/DOF: 1.656; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.00      0.46     -34    19
# Comp:  1                 Hbeta      42.07      0.39     -34    19
# Comp:  1                Halpha      156.2      0.51     -34    19
# Comp:  2             [SII]6716      11.48      0.19     -37    29
# Comp:  2             [SII]6731      11.40      0.18     -37    29
# Comp:  2              HeII4687     0.1790      0.27     -37    29
# Comp:  2               HeI5876      5.491      0.19     -37    29
# Comp:  2          [OIII]5007_d      77.21      0.51     -37    29
# Comp:  2            [OI]6300_d      1.732      0.18     -37    29
# Comp:  2           [NII]6583_d      43.76      0.32     -37    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -242      1000
#  comp.  1:       -37        34
#  comp.  2:       -35        29
# chi2/DOF: 1.469; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.94      0.47     -37    34
# Comp:  1                 Hbeta      44.09      0.40     -37    34
# Comp:  1                Halpha      155.7      0.52     -37    34
# Comp:  2             [SII]6716      14.18      0.19     -35    29
# Comp:  2             [SII]6731      10.46      0.18     -35    29
# Comp:  2              HeII4687     0.4613      0.27     -35    29
# Comp:  2               HeI5876      6.139      0.19     -35    29
# Comp:  2          [OIII]5007_d      80.96      0.51     -35    29
# Comp:  2            [OI]6300_d      1.766      0.18     -35    29
# Comp:  2           [NII]6583_d      43.51      0.32     -35    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -208       704
#  comp.  1:       -34        35
#  comp.  2:       -31        30
# chi2/DOF: 1.652; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.01      0.47     -34    35
# Comp:  1                 Hbeta      46.54      0.41     -34    35
# Comp:  1                Halpha      152.8      0.52     -34    35
# Comp:  2             [SII]6716      13.02      0.19     -31    30
# Comp:  2             [SII]6731      11.90      0.18     -31    30
# Comp:  2              HeII4687     0.3634      0.27     -31    30
# Comp:  2               HeI5876      6.186      0.19     -31    30
# Comp:  2          [OIII]5007_d      79.02      0.51     -31    30
# Comp:  2            [OI]6300_d      1.803      0.18     -31    30
# Comp:  2           [NII]6583_d      41.49      0.32     -31    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56       860
#  comp.  1:       -31        21
#  comp.  2:       -31        37
# chi2/DOF: 1.697; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.92      0.46     -31    21
# Comp:  1                 Hbeta      43.55      0.40     -31    21
# Comp:  1                Halpha      150.8      0.51     -31    21
# Comp:  2             [SII]6716      14.38      0.19     -31    37
# Comp:  2             [SII]6731      11.07      0.19     -31    37
# Comp:  2              HeII4687     0.6692      0.28     -31    37
# Comp:  2               HeI5876      5.117      0.19     -31    37
# Comp:  2          [OIII]5007_d      85.74      0.52     -31    37
# Comp:  2            [OI]6300_d      2.120      0.19     -31    37
# Comp:  2           [NII]6583_d      41.10      0.33     -31    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       356       279
#  comp.  1:       -34        34
#  comp.  2:       -33        26
# chi2/DOF: 1.624; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.96      0.47     -34    34
# Comp:  1                 Hbeta      44.94      0.40     -34    34
# Comp:  1                Halpha      156.8      0.52     -34    34
# Comp:  2             [SII]6716      11.41      0.19     -33    26
# Comp:  2             [SII]6731      10.79      0.18     -33    26
# Comp:  2              HeII4687     0.6694      0.27     -33    26
# Comp:  2               HeI5876      5.671      0.19     -33    26
# Comp:  2          [OIII]5007_d      79.47      0.51     -33    26
# Comp:  2            [OI]6300_d      1.917      0.18     -33    26
# Comp:  2           [NII]6583_d      41.71      0.32     -33    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -735       258
#  comp.  1:       -30        12
#  comp.  2:       -31        39
# chi2/DOF: 1.545; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.88      0.45     -30    12
# Comp:  1                 Hbeta      46.44      0.39     -30    12
# Comp:  1                Halpha      147.3      0.51     -30    12
# Comp:  2             [SII]6716      14.01      0.19     -31    39
# Comp:  2             [SII]6731      11.48      0.19     -31    39
# Comp:  2              HeII4687     0.3651      0.28     -31    39
# Comp:  2               HeI5876      5.494      0.19     -31    39
# Comp:  2          [OIII]5007_d      87.33      0.52     -31    39
# Comp:  2            [OI]6300_d      2.112      0.19     -31    39
# Comp:  2           [NII]6583_d      42.41      0.33     -31    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30       199
#  comp.  1:       -31        26
#  comp.  2:       -31        32
# chi2/DOF: 1.762; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.93      0.46     -31    26
# Comp:  1                 Hbeta      46.43      0.40     -31    26
# Comp:  1                Halpha      148.1      0.52     -31    26
# Comp:  2             [SII]6716      11.57      0.19     -31    32
# Comp:  2             [SII]6731      12.30      0.18     -31    32
# Comp:  2              HeII4687     0.2456      0.27     -31    32
# Comp:  2               HeI5876      6.560      0.19     -31    32
# Comp:  2          [OIII]5007_d      82.77      0.51     -31    32
# Comp:  2            [OI]6300_d      2.103      0.18     -31    32
# Comp:  2           [NII]6583_d      43.56      0.32     -31    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67       206
#  comp.  1:       -34        34
#  comp.  2:       -30        34
# chi2/DOF: 1.620; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.84      0.47     -34    34
# Comp:  1                 Hbeta      51.88      0.40     -34    34
# Comp:  1                Halpha      152.0      0.52     -34    34
# Comp:  2             [SII]6716      13.87      0.19     -30    34
# Comp:  2             [SII]6731      10.22      0.18     -30    34
# Comp:  2              HeII4687     0.7087      0.27     -30    34
# Comp:  2               HeI5876      6.026      0.19     -30    34
# Comp:  2          [OIII]5007_d      78.44      0.51     -30    34
# Comp:  2            [OI]6300_d      1.877      0.18     -30    34
# Comp:  2           [NII]6583_d      42.77      0.32     -30    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82       853
#  comp.  1:       -30        22
#  comp.  2:       -31        33
# chi2/DOF: 1.639; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.53      0.46     -30    22
# Comp:  1                 Hbeta      53.25      0.40     -30    22
# Comp:  1                Halpha      153.2      0.51     -30    22
# Comp:  2             [SII]6716      12.13      0.19     -31    33
# Comp:  2             [SII]6731      11.43      0.18     -31    33
# Comp:  2              HeII4687     0.4833      0.27     -31    33
# Comp:  2               HeI5876      6.682      0.19     -31    33
# Comp:  2          [OIII]5007_d      86.31      0.51     -31    33
# Comp:  2            [OI]6300_d      2.101      0.18     -31    33
# Comp:  2           [NII]6583_d      43.61      0.32     -31    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -406      1000
#  comp.  1:       -36        31
#  comp.  2:       -34        42
# chi2/DOF: 1.520; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.59      0.47     -36    31
# Comp:  1                 Hbeta      43.97      0.40     -36    31
# Comp:  1                Halpha      159.0      0.52     -36    31
# Comp:  2             [SII]6716      14.06      0.19     -34    42
# Comp:  2             [SII]6731      12.41      0.19     -34    42
# Comp:  2              HeII4687     0.4713      0.28     -34    42
# Comp:  2               HeI5876      6.225      0.19     -34    42
# Comp:  2          [OIII]5007_d      85.59      0.52     -34    42
# Comp:  2            [OI]6300_d      1.893      0.19     -34    42
# Comp:  2           [NII]6583_d      43.31      0.33     -34    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -380       727
#  comp.  1:       -31        30
#  comp.  2:       -38        36
# chi2/DOF: 1.584; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.35      0.47     -31    30
# Comp:  1                 Hbeta      53.11      0.40     -31    30
# Comp:  1                Halpha      149.2      0.52     -31    30
# Comp:  2             [SII]6716      11.71      0.19     -38    36
# Comp:  2             [SII]6731      11.62      0.19     -38    36
# Comp:  2              HeII4687     0.2105      0.28     -38    36
# Comp:  2               HeI5876      5.234      0.19     -38    36
# Comp:  2          [OIII]5007_d      77.82      0.51     -38    36
# Comp:  2            [OI]6300_d      1.938      0.18     -38    36
# Comp:  2           [NII]6583_d      42.77      0.32     -38    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -178       478
#  comp.  1:       -35        33
#  comp.  2:       -35        26
# chi2/DOF: 1.639; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.17      0.47     -35    33
# Comp:  1                 Hbeta      47.54      0.40     -35    33
# Comp:  1                Halpha      150.3      0.52     -35    33
# Comp:  2             [SII]6716      12.14      0.19     -35    26
# Comp:  2             [SII]6731      12.22      0.18     -35    26
# Comp:  2              HeII4687     0.2584      0.27     -35    26
# Comp:  2               HeI5876      5.456      0.19     -35    26
# Comp:  2          [OIII]5007_d      81.93      0.51     -35    26
# Comp:  2            [OI]6300_d      2.132      0.18     -35    26
# Comp:  2           [NII]6583_d      41.77      0.32     -35    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -194       372
#  comp.  1:       -29        11
#  comp.  2:       -32        39
# chi2/DOF: 1.543; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.86      0.45     -29    11
# Comp:  1                 Hbeta      46.19      0.39     -29    11
# Comp:  1                Halpha      149.2      0.51     -29    11
# Comp:  2             [SII]6716      13.50      0.19     -32    39
# Comp:  2             [SII]6731      11.77      0.19     -32    39
# Comp:  2              HeII4687     0.1882      0.28     -32    39
# Comp:  2               HeI5876      5.655      0.19     -32    39
# Comp:  2          [OIII]5007_d      82.43      0.52     -32    39
# Comp:  2            [OI]6300_d      1.850      0.19     -32    39
# Comp:  2           [NII]6583_d      43.32      0.33     -32    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -160      1000
#  comp.  1:       -28        22
#  comp.  2:       -36        24
# chi2/DOF: 1.445; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.06      0.46     -28    22
# Comp:  1                 Hbeta      40.19      0.40     -28    22
# Comp:  1                Halpha      145.9      0.51     -28    22
# Comp:  2             [SII]6716      13.10      0.19     -36    24
# Comp:  2             [SII]6731      10.07      0.18     -36    24
# Comp:  2              HeII4687     0.2688      0.27     -36    24
# Comp:  2               HeI5876      5.474      0.19     -36    24
# Comp:  2          [OIII]5007_d      78.54      0.50     -36    24
# Comp:  2            [OI]6300_d      1.734      0.18     -36    24
# Comp:  2           [NII]6583_d      43.23      0.32     -36    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -209         1
#  comp.  1:       -34        23
#  comp.  2:       -30        32
# chi2/DOF: 1.670; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.40      0.46     -34    23
# Comp:  1                 Hbeta      49.61      0.40     -34    23
# Comp:  1                Halpha      152.6      0.51     -34    23
# Comp:  2             [SII]6716      14.15      0.19     -30    32
# Comp:  2             [SII]6731      11.95      0.18     -30    32
# Comp:  2              HeII4687     0.4168      0.27     -30    32
# Comp:  2               HeI5876      5.601      0.19     -30    32
# Comp:  2          [OIII]5007_d      84.97      0.51     -30    32
# Comp:  2            [OI]6300_d      1.729      0.18     -30    32
# Comp:  2           [NII]6583_d      41.89      0.32     -30    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -108       774
#  comp.  1:       -30        20
#  comp.  2:       -33        29
# chi2/DOF: 1.647; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.79      0.46     -30    20
# Comp:  1                 Hbeta      40.20      0.40     -30    20
# Comp:  1                Halpha      150.5      0.51     -30    20
# Comp:  2             [SII]6716      11.50      0.19     -33    29
# Comp:  2             [SII]6731      12.36      0.18     -33    29
# Comp:  2              HeII4687     0.6570      0.27     -33    29
# Comp:  2               HeI5876      5.436      0.19     -33    29
# Comp:  2          [OIII]5007_d      78.75      0.51     -33    29
# Comp:  2            [OI]6300_d      2.024      0.18     -33    29
# Comp:  2           [NII]6583_d      41.86      0.32     -33    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69       148
#  comp.  1:       -35        34
#  comp.  2:       -29        32
# chi2/DOF: 1.547; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.18      0.47     -35    34
# Comp:  1                 Hbeta      48.71      0.41     -35    34
# Comp:  1                Halpha      157.6      0.52     -35    34
# Comp:  2             [SII]6716      12.69      0.19     -29    32
# Comp:  2             [SII]6731      10.90      0.18     -29    32
# Comp:  2              HeII4687     0.5197      0.27     -29    32
# Comp:  2               HeI5876      5.765      0.19     -29    32
# Comp:  2          [OIII]5007_d      77.25      0.51     -29    32
# Comp:  2            [OI]6300_d      1.739      0.18     -29    32
# Comp:  2           [NII]6583_d      42.12      0.32     -29    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -653      1000
#  comp.  1:       -30        14
#  comp.  2:       -34        28
# chi2/DOF: 1.539; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.64      0.45     -30    14
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -146       375
#  comp.  1:       -29        14
#  comp.  2:       -37        34
# chi2/DOF: 1.455; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.58      0.45     -29    14
# Comp:  1                 Hbeta      51.18      0.39     -29    14
# Comp:  1                Halpha      149.7      0.51     -29    14
# Comp:  2             [SII]6716      11.33      0.19     -37    34
# Comp:  2             [SII]6731      12.00      0.18     -37    34
# Comp:  2              HeII4687     0.4863      0.27     -37    34
# Comp:  2               HeI5876      6.150      0.19     -37    34
# Comp:  2          [OIII]5007_d      78.78      0.51     -37    34
# Comp:  2            [OI]6300_d      2.036      0.18     -37    34
# Comp:  2           [NII]6583_d      44.24      0.32     -37    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -500      1000
#  comp.  1:       -29        12
#  comp.  2:       -32        39
# chi2/DOF: 1.547; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.42      0.45     -29    12
# Comp:  1                 Hbeta      42.09      0.39     -29    12
# Comp:  1                Halpha      147.3      0.51     -29    12
# Comp:  2             [SII]6716      12.47      0.19     -32    39
# Comp:  2             [SII]6731      11.13      0.19     -32    39
# Comp:  2              HeII4687     0.3084      0.28     -32    39
# Comp:  2               HeI5876      5.953      0.19     -32    39
# Comp:  2          [OIII]5007_d      81.06      0.52     -32    39
# Comp:  2            [OI]6300_d      2.267      0.19     -32    39
# Comp:  2           [NII]6583_d      45.39      0.33     -32    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -531      1000
#  comp.  1:       -36        31
#  comp.  2:       -35        24
# chi2/DOF: 1.538; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.58      0.47     -36    31
# Comp:  1                 Hbeta      49.94      0.40     -36    31
# Comp:  1                Halpha      156.4      0.52     -36    31
# Comp:  2             [SII]6716      13.81      0.19     -35    24
# Comp:  2             [SII]6731      11.10      0.18     -35    24
# Comp:  2              HeII4687     0.3479      0.27     -35    24
# Comp:  2               HeI5876      6.442      0.19     -35    24
# Comp:  2          [OIII]5007_d      76.15      0.50     -35    24
# Comp:  2            [OI]6300_d      1.817      0.18     -35    24
# Comp:  2           [NII]6583_d      43.61      0.32     -35    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -176      1000
#  comp.  1:       -32        21
#  comp.  2:       -33        27
# chi2/DOF: 1.679; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.19      0.46     -32    21
# Comp:  1                 Hbeta      40.18      0.40     -32    21
# Comp:  1                Halpha      157.8      0.51     -32    21
# Comp:  2             [SII]6716      12.50      0.19     -33    27
# Comp:  2             [SII]6731      10.76      0.18     -33    27
# Comp:  2              HeII4687     0.2870      0.27     -33    27
# Comp:  2               HeI5876      5.774      0.19     -33    27
# Comp:  2          [OIII]5007_d      78.07      0.51     -33    27
# Comp:  2            [OI]6300_d      2.080      0.18     -33    27
# Comp:  2           [NII]6583_d      40.92      0.32     -33    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        89      1000
#  comp.  1:       -32        30
#  comp.  2:       -30        35
# chi2/DOF: 1.659; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.07      0.47     -32    30
# Comp:  1                 Hbeta      43.40      0.40     -32    30
# Comp:  1                Halpha      153.8      0.52     -32    30
# Comp:  2             [SII]6716      11.12      0.19     -30    35
# Comp:  2             [SII]6731      12.41      0.18     -30    35
# Comp:  2              HeII4687     0.1348      0.27     -30    35
# Comp:  2               HeI5876      6.224      0.19     -30    35
# Comp:  2          [OIII]5007_d      86.48      0.51     -30    35
# Comp:  2            [OI]6300_d      2.011      0.18     -30    35
# Comp:  2           [NII]6583_d      41.57      0.32     -30    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -134       418
#  comp.  1:       -35        34
#  comp.  2:       -30        27
# chi2/DOF: 1.534; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.29      0.47     -35    34
# Comp:  1                 Hbeta      47.40      0.40     -35    34
# Comp:  1                Halpha      155.9      0.52     -35    34
# Comp:  2             [SII]6716      13.90      0.19     -30    27
# Comp:  2             [SII]6731      12.13      0.18     -30    27
# Comp:  2              HeII4687     0.2345      0.27     -30    27
# Comp:  2               HeI5876      6.059      0.19     -30    27
# Comp:  2          [OIII]5007_d      79.15      0.51     -30    27
# Comp:  2            [OI]6300_d      2.104      0.18     -30    27
# Comp:  2           [NII]6583_d      41.67      0.32     -30    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -185         1
#  comp.  1:       -31        20
#  comp.  2:       -30        35
# chi2/DOF: 1.645; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.03      0.46     -31    20
# Comp:  1                 Hbeta      43.70      0.40     -31    20
# Comp:  1                Halpha      149.2      0.51     -31    20
# Comp:  2             [SII]6716      14.40      0.19     -30    35
# Comp:  2             [SII]6731      11.59      0.18     -30    35
# Comp:  2              HeII4687     0.2299      0.27     -30    35
# Comp:  2               HeI5876      5.891      0.19     -30    35
# Comp:  2          [OIII]5007_d      78.26      0.52     -30    35
# Comp:  2            [OI]6300_d      2.057      0.18     -30    35
# Comp:  2           [NII]6583_d      42.18      0.32     -30    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       212         1
#  comp.  1:       -31        29
#  comp.  2:       -30        37
# chi2/DOF: 1.769; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.21      0.47     -31    29
# Comp:  1                 Hbeta      47.03      0.40     -31    29
# Comp:  1                Halpha      153.5      0.52     -31    29
# Comp:  2             [SII]6716      12.47      0.19     -30    37
# Comp:  2             [SII]6731      12.44      0.18     -30    37
# Comp:  2              HeII4687     0.5039      0.28     -30    37
# Comp:  2               HeI5876      5.565      0.19     -30    37
# Comp:  2          [OIII]5007_d      80.53      0.52     -30    37
# Comp:  2            [OI]6300_d      1.844      0.19     -30    37
# Comp:  2           [NII]6583_d      43.06      0.32     -30    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       452      1000
#  comp.  1:       -33        27
#  comp.  2:       -36        31
# chi2/DOF: 1.773; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.48      0.46     -33    27
# Comp:  1                 Hbeta      43.76      0.40     -33    27
# Comp:  1                Halpha      156.9      0.52     -33    27
# Comp:  2             [SII]6716      12.26      0.19     -36    31
# Comp:  2             [SII]6731      11.53      0.18     -36    31
# Comp:  2              HeII4687     0.4881      0.27     -36    31
# Comp:  2               HeI5876      6.112      0.19     -36    31
# Comp:  2          [OIII]5007_d      82.64      0.51     -36    31
# Comp:  2            [OI]6300_d      1.919      0.18     -36    31
# Comp:  2           [NII]6583_d      43.29      0.32     -36    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -787      1000
#  comp.  1:       -33        24
#  comp.  2:       -32        32
# chi2/DOF: 1.819; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.12      0.46     -33    24
# Comp:  1                 Hbeta      46.19      0.40     -33    24
# Comp:  1                Halpha      153.1      0.52     -33    24
# Comp:  2             [SII]6716      12.92      0.19     -32    32
# Comp:  2             [SII]6731      12.44      0.18     -32    32
# Comp:  2              HeII4687     0.2875      0.27     -32    32
# Comp:  2               HeI5876      6.218      0.19     -32    32
# Comp:  2          [OIII]5007_d      79.28      0.51     -32    32
# Comp:  2            [OI]6300_d      1.977      0.18     -32    32
# Comp:  2           [NII]6583_d      44.60      0.32     -32    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       118      1000
#  comp.  1:       -34        33
#  comp.  2:       -29        34
# chi2/DOF: 1.661; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.27      0.47     -34    33
# Comp:  1                 Hbeta      44.41      0.40     -34    33
# Comp:  1                Halpha      155.1      0.52     -34    33
# Comp:  2             [SII]6716      11.32      0.19     -29    34
# Comp:  2             [SII]6731      11.09      0.18     -29    34
# Comp:  2              HeII4687     0.4788      0.27     -29    34
# Comp:  2               HeI5876      6.491      0.19     -29    34
# Comp:  2          [OIII]5007_d      80.44      0.51     -29    34
# Comp:  2            [OI]6300_d      1.844      0.18     -29    34
# Comp:  2           [NII]6583_d      44.07      0.32     -29    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       186      1000
#  comp.  1:       -33        21
#  comp.  2:       -32        34
# chi2/DOF: 1.721; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.88      0.46     -33    21
# Comp:  1                 Hbeta      49.85      0.40     -33    21
# Comp:  1                Halpha      157.9      0.51     -33    21
# Comp:  2             [SII]6716      14.12      0.19     -32    34
# Comp:  2             [SII]6731      11.17      0.18     -32    34
# Comp:  2              HeII4687     0.6103      0.27     -32    34
# Comp:  2               HeI5876      5.360      0.19     -32    34
# Comp:  2          [OIII]5007_d      80.05      0.51     -32    34
# Comp:  2            [OI]6300_d      2.105      0.18     -32    34
# Comp:  2           [NII]6583_d      41.44      0.32     -32    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -603      1000
#  comp.  1:       -37        34
#  comp.  2:       -34        26
# chi2/DOF: 1.452; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.16      0.47     -37    34
# Comp:  1                 Hbeta      44.07      0.40     -37    34
# Comp:  1                Halpha      155.7      0.52     -37    34
# Comp:  2             [SII]6716      13.10      0.19     -34    26
# Comp:  2             [SII]6731      10.37      0.18     -34    26
# Comp:  2              HeII4687     0.4217      0.27     -34    26
# Comp:  2               HeI5876      5.447      0.19     -34    26
# Comp:  2          [OIII]5007_d      75.00      0.51     -34    26
# Comp:  2            [OI]6300_d      2.068      0.18     -34    26
# Comp:  2           [NII]6583_d      41.55      0.32     -34    26
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([2.06653706, 4.05739782, 5.50242641, 1.37850447, 0.90740367,
#        0.15004237, 0.61758556, 3.94331054, 0.18961317, 1.51368828])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 18.03264796,  47.14599332, 208.31198263,  17.90177686,
#         15.85442196,   0.41975497,   7.30687035,  84.00501802,
#          2.55630554,  58.72383525])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_1_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_1", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_1_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_1_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_1_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0        Hgamma   5.653740    0.647917
# 1         Hbeta  14.781589    1.272108
# 2        Halpha  65.311638    1.725165
# 3     [SII]6716   5.612708    0.432200
# 4     [SII]6731   4.970805    0.284496
# 5      HeII4687   0.131605    0.047042
# 6       HeI5876   2.290908    0.193630
# 7  [OIII]5007_d  26.337925    1.236338
# 8    [OI]6300_d   0.801473    0.059449
# 9   [NII]6583_d  18.411566    0.474584
#           Name       Flux  Error_flux
# 0       Hgamma   5.653740    0.647917
# 1        Hbeta  14.781589    1.272108
# 2       Halpha  65.311638    1.725165
# 3    [SII]6716   5.612708    0.432200
# 4    [SII]6731   4.970805    0.284496
# 5     HeII4687   0.131605    0.047042
# 6      HeI5876   2.290908    0.193630
# 7   [OIII]4959   6.584481    1.236338
# 8   [OIII]5007  19.753443    1.236338
# 9     [OI]6300   0.601105    0.059449
# 10    [OI]6364   0.200368    0.059449
# 11   [NII]6548   4.602892    0.474584
# 12   [NII]6583  13.808675    0.474584

# %%
np.median(flux_rf_rebin)
# Out:
# 0.31352799178036483
