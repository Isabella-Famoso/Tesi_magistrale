# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error_1 = np.loadtxt('Spectrum1s_1', unpack = True)
z = 0.0238 
wv_rf = wv/(1+z)
flux_rf = flux*(1+z)
#error = np.sqrt(error_1**2+0.04**2+(0.04*flux)**2)
error = np.ones(len(flux))*0.03
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4200.76186755 4202.20746239 4203.65305724 ... 6928.59933581 6930.04493065
#  6931.49052549] [0.73814474 0.26100745 0.19840427 ... 0.13799802 0.14482466 0.14082947] [0.030714 0.030714 0.030714 ... 0.030714 0.030714 0.030714]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.10038093 2.10110373 2.10182653 ... 3.46429967 3.46502247 3.46574526]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3343, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       108       573
# chi2/DOF: 0.01974; DOF: 2076; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -53       117
# chi2/DOF: 0.01143; DOF: 2014; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# [3.75949928 2.90860849 1.32935626 ... 0.69672506 0.72349662 0.72553486]
# [1.56483355 1.56411768 1.56338784 ... 0.75651019 0.75711935 0.75778014]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp_no_reg = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments, #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), 
          regul=0, reg_dim=reg_dim, component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)

#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -387       156
#  comp.  1:       -33        31
#  comp.  2:       -30        39
# chi2/DOF: 1.690; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 46; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.78      0.32     -33    31
# Comp:  1                 Hbeta      50.54      0.32     -33    31
# Comp:  1                Halpha      170.2      0.32     -33    31
# Comp:  2             [SII]6716      14.15      0.33     -30    39
# Comp:  2             [SII]6731      12.32      0.33     -30    39
# Comp:  2              HeII4687     0.5554      0.33     -30    39
# Comp:  2               HeI5876      6.839      0.33     -30    39
# Comp:  2          [OIII]5007_d      89.87      0.41     -30    39
# Comp:  2            [OI]6300_d      2.190      0.41     -30    39
# Comp:  2           [NII]6583_d      47.90      0.41     -30    39
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp_no_reg.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Regularization

# %%
#Rescale del noise in modo che chi2/N=1 
noise_rescale = error_gal*np.sqrt(pp_no_reg.chi2); #rescale_noise = noise*np.sqrt(Chi**2/DOF)

#Again ppxf without regul but with noise rescaled
pp_no_reg = ppxf(templates, galaxy, noise_rescale, velscale, start, moments=moments, #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), 
          regul=0, reg_dim=reg_dim, component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
light_weights_no = pp_no_reg.weights[~gas_component]       # Exclude weights of the gas templates
light_weights_no = light_weights_no.reshape(reg_dim)        # Reshape to (n_ages, n_metal)
age = sps.mean_age_metal(light_weights_no);
ML = sps.mass_to_light(light_weights_no, band="SDSS/r", redshift=z);
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -387       156
#  comp.  1:       -33        31
#  comp.  2:       -30        39
# chi2/DOF: 1.000; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 46; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.78      0.41     -33    31
# Comp:  1                 Hbeta      50.54      0.41     -33    31
# Comp:  1                Halpha      170.2      0.41     -33    31
# Comp:  2             [SII]6716      14.15      0.42     -30    39
# Comp:  2             [SII]6731      12.32      0.42     -30    39
# Comp:  2              HeII4687     0.5554      0.42     -30    39
# Comp:  2               HeI5876      6.839      0.42     -30    39
# Comp:  2          [OIII]5007_d      89.87      0.54     -30    39
# Comp:  2            [OI]6300_d      2.190      0.54     -30    39
# Comp:  2           [NII]6583_d      47.90      0.54     -30    39
# -----------------------------------------------------------------
# Weighted <lg_age> [yr]: 8.24
# Weighted <[M/H]>: -1.30
# (M*/L)=0.1887 (SDSS/r at z=0.0238)

# %%
def analyze_ppxf_weights(light_weights, reg_dim, sps, plot=True):
    """
    +-
    Analizza e visualizza i template weights di pPXF
    
    Parameters:
    - light_weights: array dei pesi dei template stellari (escludendo gas)
    - reg_dim: dimensioni della griglia (n_ages, n_metallicities)  
    - sps: oggetto sps_lib con le informazioni sui template
    - plot: se fare i plot o no
    """
    
    print("=== ANALISI TEMPLATE WEIGHTS ===\n")
    
    # Verifica dimensioni
    n_ages, n_metals = reg_dim
    print(f"Griglia template: {n_ages} età × {n_metals} metallicità")
    print(f"Peso totale: {np.sum(light_weights):.4f}")
    print(f"Pesi non-zero: {np.sum(light_weights > 0.001)}/{light_weights.size}")
    print(f"Peso massimo: {np.max(light_weights):.4f}")
    print(f"Peso mediano (non-zero): {np.median(light_weights[light_weights > 0.001]):.4f}")
    
    if plot:
        fig, axes = plt.subplots(2, 2, figsize=(15, 10))
        
        # 1. HEATMAP DEI PESI
        im1 = axes[0,0].imshow(light_weights, aspect='auto', origin='lower', cmap='viridis')
        axes[0,0].set_title('Template Weights (Age vs Metallicity)')
        axes[0,0].set_xlabel('Metallicity index')
        axes[0,0].set_ylabel('Age index')
        plt.colorbar(im1, ax=axes[0,0])
        
        # 2. PROIEZIONE SULLE ETÀ
        age_weights = np.sum(light_weights, axis=1)  # Somma su metallicità
        axes[0,1].plot(range(n_ages), age_weights, 'o-')
        axes[0,1].set_title('Distribuzione in Età')
        axes[0,1].set_xlabel('Age index')
        axes[0,1].set_ylabel('Peso cumulativo')
        axes[0,1].grid(True)
        
        # 3. PROIEZIONE SULLE METALLICITÀ
        metal_weights = np.sum(light_weights, axis=0)  # Somma su età
        axes[1,0].plot(range(n_metals), metal_weights, 'o-')
        axes[1,0].set_title('Distribuzione in Metallicità')
        axes[1,0].set_xlabel('Metallicity index')
        axes[1,0].set_ylabel('Peso cumulativo')
        axes[1,0].grid(True)
        
        # 4. ISTOGRAMMA DEI PESI
        axes[1,1].hist(light_weights.flatten(), bins=50, alpha=0.7)
        axes[1,1].set_xlabel('Peso del template')
        axes[1,1].set_ylabel('Frequenza')
        axes[1,1].set_title('Distribuzione dei pesi')
        axes[1,1].set_yscale('log')
        
        plt.tight_layout()
        plt.show()

# %%
analyze_ppxf_weights(light_weights_no, reg_dim, sps, plot=True)
# Out:
# === ANALISI TEMPLATE WEIGHTS ===
#
# Griglia template: 25 età × 6 metallicità
# Peso totale: 0.3248
# Pesi non-zero: 4/150
# Peso massimo: 0.1151
# Peso mediano (non-zero): 0.0843
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#pp with regul 
regul_err = 0.01
pp_reg = ppxf(templates, galaxy, noise_rescale, velscale, start, moments=moments, #We put what we had set here to do the ppxf procedure
        degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), 
        regul=1/regul_err, reg_dim=reg_dim, component=component,
        gas_component=gas_component, gas_names=gas_names,
        gas_reddening=gas_reddening)

print(f"Desired Delta Chi^2: {np.sqrt(2*galaxy.size):#.4g}")
print(f"Current Delta Chi^2: {(pp_reg.chi2 - 1)*galaxy.size:#.4g}")

light_weights = pp_reg.weights[~gas_component]       # Exclude weights of the gas templates
light_weights = light_weights.reshape(reg_dim)        # Reshape to (n_ages, n_metal)
sps.mean_age_metal(light_weights);
sps.mass_to_light(light_weights, band="SDSS/r", redshift=z);
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -717       346
#  comp.  1:       -33        31
#  comp.  2:       -30        39
# chi2/DOF: 1.000; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.56      0.41     -33    31
# Comp:  1                 Hbeta      50.38      0.41     -33    31
# Comp:  1                Halpha      170.1      0.41     -33    31
# Comp:  2             [SII]6716      14.14      0.42     -30    39
# Comp:  2             [SII]6731      12.32      0.42     -30    39
# Comp:  2              HeII4687     0.5565      0.42     -30    39
# Comp:  2               HeI5876      6.877      0.42     -30    39
# Comp:  2          [OIII]5007_d      89.87      0.54     -30    39
# Comp:  2            [OI]6300_d      2.190      0.54     -30    39
# Comp:  2           [NII]6583_d      47.90      0.54     -30    39
# -----------------------------------------------------------------
# Desired Delta Chi^2: 69.31
# Current Delta Chi^2: 0.5003
# Weighted <lg_age> [yr]: 7.96
# Weighted <[M/H]>: -0.706
# (M*/L)=0.1703 (SDSS/r at z=0.0238)

# %% [markdown]
# Anche con una regolarizzazione di 100, 1000 o 10000 il chi quadro non aumenta -> la regolarizzazione non è necessaria, i risultati sono quelli di pp_no_reg

# %%
analyze_ppxf_weights(light_weights, reg_dim, sps, plot=True)
# Out:
# === ANALISI TEMPLATE WEIGHTS ===
#
# Griglia template: 25 età × 6 metallicità
# Peso totale: 0.3301
# Pesi non-zero: 38/150
# Peso massimo: 0.0189
# Peso mediano (non-zero): 0.0076
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
d1 = {'Age': [age[0]], '[M/H]': [age[1]], 'Mass to light ratio': [ML]}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum1s_1_galaxy.csv")

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp_no_reg.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp_no_reg.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp_no_reg.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  64.81; gas flux:     20 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  157.2; gas flux:     51 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  524.2; gas flux:    233 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  41.33; gas flux:     20 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  36.34; gas flux:     17 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.572; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  19.03; gas flux:      8 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  186.9; gas flux:     94 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  4.826; gas flux:      3 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  106.3; gas flux:     66 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp_no_reg.bestfit.copy()
resid = galaxy - bestfit0
start = pp_no_reg.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp_no_reg.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -518        51
#  comp.  1:       -33        30
#  comp.  2:       -33        48
# chi2/DOF: 1.526; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.88      0.32     -33    30
# Comp:  1                 Hbeta      52.33      0.32     -33    30
# Comp:  1                Halpha      169.8      0.32     -33    30
# Comp:  2             [SII]6716      14.72      0.34     -33    48
# Comp:  2             [SII]6731      12.92      0.34     -33    48
# Comp:  2              HeII4687     0.3908      0.34     -33    48
# Comp:  2               HeI5876      7.192      0.34     -33    48
# Comp:  2          [OIII]5007_d      95.37      0.42     -33    48
# Comp:  2            [OI]6300_d      2.440      0.42     -33    48
# Comp:  2           [NII]6583_d      47.17      0.42     -33    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -327       116
#  comp.  1:       -34        35
#  comp.  2:       -29        24
# chi2/DOF: 1.401; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      27.41      0.32     -34    35
# Comp:  1                 Hbeta      50.73      0.32     -34    35
# Comp:  1                Halpha      173.5      0.32     -34    35
# Comp:  2             [SII]6716      13.33      0.31     -29    24
# Comp:  2             [SII]6731      10.76      0.31     -29    24
# Comp:  2              HeII4687     0.6067      0.31     -29    24
# Comp:  2               HeI5876      6.821      0.31     -29    24
# Comp:  2          [OIII]5007_d      88.23      0.39     -29    24
# Comp:  2            [OI]6300_d      1.977      0.39     -29    24
# Comp:  2           [NII]6583_d      45.42      0.39     -29    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -324       113
#  comp.  1:       -34        28
#  comp.  2:       -27        38
# chi2/DOF: 1.565; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.60      0.32     -34    28
# Comp:  1                 Hbeta      50.33      0.32     -34    28
# Comp:  1                Halpha      171.6      0.32     -34    28
# Comp:  2             [SII]6716      12.79      0.33     -27    38
# Comp:  2             [SII]6731      13.28      0.33     -27    38
# Comp:  2              HeII4687     0.5249      0.33     -27    38
# Comp:  2               HeI5876      7.390      0.33     -27    38
# Comp:  2          [OIII]5007_d      89.34      0.41     -27    38
# Comp:  2            [OI]6300_d      2.135      0.41     -27    38
# Comp:  2           [NII]6583_d      47.15      0.41     -27    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        83         1
#  comp.  1:       -33        34
#  comp.  2:       -31        34
# chi2/DOF: 1.513; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.13      0.32     -33    34
# Comp:  1                 Hbeta      52.32      0.32     -33    34
# Comp:  1                Halpha      169.8      0.32     -33    34
# Comp:  2             [SII]6716      13.44      0.32     -31    34
# Comp:  2             [SII]6731      13.30      0.32     -31    34
# Comp:  2              HeII4687     0.3107      0.32     -31    34
# Comp:  2               HeI5876      6.711      0.32     -31    34
# Comp:  2          [OIII]5007_d      87.49      0.41     -31    34
# Comp:  2            [OI]6300_d      2.407      0.41     -31    34
# Comp:  2           [NII]6583_d      44.51      0.41     -31    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -675       233
#  comp.  1:       -32        31
#  comp.  2:       -31        51
# chi2/DOF: 1.522; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.67      0.32     -32    31
# Comp:  1                 Hbeta      48.56      0.32     -32    31
# Comp:  1                Halpha      170.2      0.32     -32    31
# Comp:  2             [SII]6716      14.74      0.34     -31    51
# Comp:  2             [SII]6731      13.37      0.34     -31    51
# Comp:  2              HeII4687     0.6121      0.34     -31    51
# Comp:  2               HeI5876      6.775      0.34     -31    51
# Comp:  2          [OIII]5007_d      92.63      0.43     -31    51
# Comp:  2            [OI]6300_d      2.397      0.43     -31    51
# Comp:  2           [NII]6583_d      49.46      0.43     -31    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -374       123
#  comp.  1:       -34        28
#  comp.  2:       -34        25
# chi2/DOF: 1.447; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      25.34      0.32     -34    28
# Comp:  1                 Hbeta      50.45      0.32     -34    28
# Comp:  1                Halpha      169.2      0.32     -34    28
# Comp:  2             [SII]6716      14.09      0.31     -34    25
# Comp:  2             [SII]6731      11.79      0.31     -34    25
# Comp:  2              HeII4687     0.5787      0.31     -34    25
# Comp:  2               HeI5876      6.499      0.31     -34    25
# Comp:  2          [OIII]5007_d      82.98      0.40     -34    25
# Comp:  2            [OI]6300_d      1.771      0.40     -34    25
# Comp:  2           [NII]6583_d      46.96      0.40     -34    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -425         1
#  comp.  1:       -32        32
#  comp.  2:       -35        32
# chi2/DOF: 1.488; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.91      0.32     -32    32
# Comp:  1                 Hbeta      49.23      0.32     -32    32
# Comp:  1                Halpha      168.1      0.32     -32    32
# Comp:  2             [SII]6716      13.46      0.32     -35    32
# Comp:  2             [SII]6731      12.67      0.32     -35    32
# Comp:  2              HeII4687     0.3447      0.32     -35    32
# Comp:  2               HeI5876      6.018      0.32     -35    32
# Comp:  2          [OIII]5007_d      85.66      0.40     -35    32
# Comp:  2            [OI]6300_d      2.230      0.40     -35    32
# Comp:  2           [NII]6583_d      46.85      0.40     -35    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -401       178
#  comp.  1:       -32        27
#  comp.  2:       -30        48
# chi2/DOF: 1.528; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.19      0.31     -32    27
# Comp:  1                 Hbeta      49.28      0.31     -32    27
# Comp:  1                Halpha      167.6      0.31     -32    27
# Comp:  2             [SII]6716      13.38      0.34     -30    48
# Comp:  2             [SII]6731      12.87      0.34     -30    48
# Comp:  2              HeII4687     0.4431      0.34     -30    48
# Comp:  2               HeI5876      7.213      0.34     -30    48
# Comp:  2          [OIII]5007_d      90.19      0.43     -30    48
# Comp:  2            [OI]6300_d      2.036      0.43     -30    48
# Comp:  2           [NII]6583_d      49.73      0.43     -30    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -248       187
#  comp.  1:       -34        26
#  comp.  2:       -25        39
# chi2/DOF: 1.402; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.09      0.31     -34    26
# Comp:  1                 Hbeta      55.76      0.31     -34    26
# Comp:  1                Halpha      170.3      0.31     -34    26
# Comp:  2             [SII]6716      14.08      0.33     -25    39
# Comp:  2             [SII]6731      11.99      0.33     -25    39
# Comp:  2              HeII4687     0.5245      0.33     -25    39
# Comp:  2               HeI5876      6.361      0.33     -25    39
# Comp:  2          [OIII]5007_d      90.84      0.41     -25    39
# Comp:  2            [OI]6300_d      2.318      0.41     -25    39
# Comp:  2           [NII]6583_d      47.61      0.41     -25    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -484       100
#  comp.  1:       -32        28
#  comp.  2:       -24        35
# chi2/DOF: 1.325; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.45      0.32     -32    28
# Comp:  1                 Hbeta      45.87      0.32     -32    28
# Comp:  1                Halpha      168.0      0.32     -32    28
# Comp:  2             [SII]6716      14.23      0.32     -24    35
# Comp:  2             [SII]6731      13.48      0.32     -24    35
# Comp:  2              HeII4687     0.5467      0.32     -24    35
# Comp:  2               HeI5876      6.133      0.32     -24    35
# Comp:  2          [OIII]5007_d      94.04      0.41     -24    35
# Comp:  2            [OI]6300_d      2.107      0.41     -24    35
# Comp:  2           [NII]6583_d      47.00      0.41     -24    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -538       112
#  comp.  1:       -32        30
#  comp.  2:       -33        47
# chi2/DOF: 1.503; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 45; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.80      0.32     -32    30
# Comp:  1                 Hbeta      55.06      0.32     -32    30
# Comp:  1                Halpha      169.2      0.32     -32    30
# Comp:  2             [SII]6716      14.14      0.34     -33    47
# Comp:  2             [SII]6731      11.58      0.34     -33    47
# Comp:  2              HeII4687     0.2914      0.34     -33    47
# Comp:  2               HeI5876      7.103      0.34     -33    47
# Comp:  2          [OIII]5007_d      94.75      0.42     -33    47
# Comp:  2            [OI]6300_d      2.279      0.42     -33    47
# Comp:  2           [NII]6583_d      48.67      0.42     -33    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -240         1
#  comp.  1:       -34        31
#  comp.  2:       -27        43
# chi2/DOF: 1.447; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 60; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      26.71      0.32     -34    31
# Comp:  1                 Hbeta      46.34      0.32     -34    31
# Comp:  1                Halpha      170.4      0.32     -34    31
# Comp:  2             [SII]6716      14.64      0.33     -27    43
# Comp:  2             [SII]6731      11.65      0.33     -27    43
# Comp:  2              HeII4687     0.5810      0.33     -27    43
# Comp:  2               HeI5876      7.219      0.33     -27    43
# Comp:  2          [OIII]5007_d      91.34      0.42     -27    43
# Comp:  2            [OI]6300_d      2.096      0.42     -27    43
# Comp:  2           [NII]6583_d      48.67      0.42     -27    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -546         1
#  comp.  1:       -34        35
#  comp.  2:       -27        44
# chi2/DOF: 1.425; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.65      0.32     -34    35
# Comp:  1                 Hbeta      47.19      0.32     -34    35
# Comp:  1                Halpha      169.1      0.32     -34    35
# Comp:  2             [SII]6716      12.99      0.33     -27    44
# Comp:  2             [SII]6731      11.64      0.33     -27    44
# Comp:  2              HeII4687     0.4263      0.33     -27    44
# Comp:  2               HeI5876      7.096      0.33     -27    44
# Comp:  2          [OIII]5007_d      93.42      0.42     -27    44
# Comp:  2            [OI]6300_d      2.302      0.42     -27    44
# Comp:  2           [NII]6583_d      51.31      0.42     -27    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78         1
#  comp.  1:       -35        32
#  comp.  2:       -26        35
# chi2/DOF: 1.459; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.08      0.32     -35    32
# Comp:  1                 Hbeta      55.59      0.32     -35    32
# Comp:  1                Halpha      172.3      0.32     -35    32
# Comp:  2             [SII]6716      14.13      0.32     -26    35
# Comp:  2             [SII]6731      11.09      0.32     -26    35
# Comp:  2              HeII4687     0.4264      0.32     -26    35
# Comp:  2               HeI5876      7.321      0.32     -26    35
# Comp:  2          [OIII]5007_d      93.65      0.41     -26    35
# Comp:  2            [OI]6300_d      2.013      0.41     -26    35
# Comp:  2           [NII]6583_d      45.08      0.41     -26    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -506       119
#  comp.  1:       -35        30
#  comp.  2:       -36        35
# chi2/DOF: 1.390; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.81      0.32     -35    30
# Comp:  1                 Hbeta      46.47      0.32     -35    30
# Comp:  1                Halpha      170.0      0.32     -35    30
# Comp:  2             [SII]6716      14.32      0.32     -36    35
# Comp:  2             [SII]6731      12.33      0.32     -36    35
# Comp:  2              HeII4687     0.8336      0.32     -36    35
# Comp:  2               HeI5876      6.412      0.32     -36    35
# Comp:  2          [OIII]5007_d      93.47      0.41     -36    35
# Comp:  2            [OI]6300_d      2.073      0.41     -36    35
# Comp:  2           [NII]6583_d      47.83      0.41     -36    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -588         1
#  comp.  1:       -32        28
#  comp.  2:       -33        34
# chi2/DOF: 1.556; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.33      0.32     -32    28
# Comp:  1                 Hbeta      52.17      0.32     -32    28
# Comp:  1                Halpha      168.1      0.32     -32    28
# Comp:  2             [SII]6716      13.33      0.32     -33    34
# Comp:  2             [SII]6731      12.84      0.32     -33    34
# Comp:  2              HeII4687     0.4351      0.32     -33    34
# Comp:  2               HeI5876      6.726      0.32     -33    34
# Comp:  2          [OIII]5007_d      87.83      0.41     -33    34
# Comp:  2            [OI]6300_d      2.012      0.41     -33    34
# Comp:  2           [NII]6583_d      47.80      0.41     -33    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        77         1
#  comp.  1:       -33        31
#  comp.  2:       -38        41
# chi2/DOF: 1.235; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.54      0.32     -33    31
# Comp:  1                 Hbeta      44.70      0.32     -33    31
# Comp:  1                Halpha      170.4      0.32     -33    31
# Comp:  2             [SII]6716      12.80      0.33     -38    41
# Comp:  2             [SII]6731      13.33      0.33     -38    41
# Comp:  2              HeII4687     0.3631      0.33     -38    41
# Comp:  2               HeI5876      7.060      0.33     -38    41
# Comp:  2          [OIII]5007_d      85.69      0.42     -38    41
# Comp:  2            [OI]6300_d      2.033      0.42     -38    41
# Comp:  2           [NII]6583_d      45.11      0.42     -38    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96         1
#  comp.  1:       -32        32
#  comp.  2:       -32        43
# chi2/DOF: 1.365; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.69      0.32     -32    32
# Comp:  1                 Hbeta      58.14      0.32     -32    32
# Comp:  1                Halpha      168.5      0.32     -32    32
# Comp:  2             [SII]6716      12.76      0.33     -32    43
# Comp:  2             [SII]6731      11.39      0.33     -32    43
# Comp:  2              HeII4687     0.5703      0.33     -32    43
# Comp:  2               HeI5876      7.079      0.33     -32    43
# Comp:  2          [OIII]5007_d      93.21      0.42     -32    43
# Comp:  2            [OI]6300_d      2.443      0.42     -32    43
# Comp:  2           [NII]6583_d      47.11      0.42     -32    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -160       140
#  comp.  1:       -32        28
#  comp.  2:       -34        36
# chi2/DOF: 1.448; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.46      0.32     -32    28
# Comp:  1                 Hbeta      50.08      0.32     -32    28
# Comp:  1                Halpha      168.8      0.32     -32    28
# Comp:  2             [SII]6716      14.68      0.32     -34    36
# Comp:  2             [SII]6731      13.24      0.32     -34    36
# Comp:  2              HeII4687     0.3072      0.32     -34    36
# Comp:  2               HeI5876      6.919      0.32     -34    36
# Comp:  2          [OIII]5007_d      82.05      0.41     -34    36
# Comp:  2            [OI]6300_d      2.382      0.41     -34    36
# Comp:  2           [NII]6583_d      47.00      0.41     -34    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -386       908
#  comp.  1:       -34        28
#  comp.  2:       -30        23
# chi2/DOF: 1.314; DOF: 2397; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.94      0.32     -34    28
# Comp:  1                 Hbeta      43.80      0.32     -34    28
# Comp:  1                Halpha      171.3      0.32     -34    28
# Comp:  2             [SII]6716      13.30      0.31     -30    23
# Comp:  2             [SII]6731      11.97      0.31     -30    23
# Comp:  2              HeII4687     0.3696      0.31     -30    23
# Comp:  2               HeI5876      6.928      0.31     -30    23
# Comp:  2          [OIII]5007_d      87.13      0.39     -30    23
# Comp:  2            [OI]6300_d      2.179      0.39     -30    23
# Comp:  2           [NII]6583_d      45.97      0.39     -30    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -292       185
#  comp.  1:       -34        30
#  comp.  2:       -30        32
# chi2/DOF: 1.572; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.64      0.32     -34    30
# Comp:  1                 Hbeta      52.19      0.32     -34    30
# Comp:  1                Halpha      170.9      0.32     -34    30
# Comp:  2             [SII]6716      13.73      0.32     -30    32
# Comp:  2             [SII]6731      12.02      0.32     -30    32
# Comp:  2              HeII4687     0.6014      0.32     -30    32
# Comp:  2               HeI5876      7.269      0.32     -30    32
# Comp:  2          [OIII]5007_d      86.24      0.40     -30    32
# Comp:  2            [OI]6300_d      1.998      0.40     -30    32
# Comp:  2           [NII]6583_d      48.01      0.40     -30    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -144         1
#  comp.  1:       -34        26
#  comp.  2:       -26        37
# chi2/DOF: 1.431; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.19      0.31     -34    26
# Comp:  1                 Hbeta      53.61      0.31     -34    26
# Comp:  1                Halpha      170.7      0.31     -34    26
# Comp:  2             [SII]6716      15.63      0.32     -26    37
# Comp:  2             [SII]6731      11.24      0.32     -26    37
# Comp:  2              HeII4687     0.6049      0.32     -26    37
# Comp:  2               HeI5876      7.305      0.32     -26    37
# Comp:  2          [OIII]5007_d      93.98      0.41     -26    37
# Comp:  2            [OI]6300_d      1.903      0.41     -26    37
# Comp:  2           [NII]6583_d      46.09      0.41     -26    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        43         1
#  comp.  1:       -34        26
#  comp.  2:       -35        40
# chi2/DOF: 1.360; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.29      0.31     -34    26
# Comp:  1                 Hbeta      46.42      0.31     -34    26
# Comp:  1                Halpha      171.0      0.31     -34    26
# Comp:  2             [SII]6716      12.76      0.33     -35    40
# Comp:  2             [SII]6731      12.42      0.33     -35    40
# Comp:  2              HeII4687     0.3427      0.33     -35    40
# Comp:  2               HeI5876      6.477      0.33     -35    40
# Comp:  2          [OIII]5007_d      85.69      0.41     -35    40
# Comp:  2            [OI]6300_d      1.969      0.41     -35    40
# Comp:  2           [NII]6583_d      50.10      0.41     -35    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -885       421
#  comp.  1:       -35        33
#  comp.  2:       -34        34
# chi2/DOF: 1.387; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      25.26      0.32     -35    33
# Comp:  1                 Hbeta      46.96      0.32     -35    33
# Comp:  1                Halpha      171.7      0.32     -35    33
# Comp:  2             [SII]6716      15.44      0.32     -34    34
# Comp:  2             [SII]6731      11.08      0.32     -34    34
# Comp:  2              HeII4687     0.6374      0.32     -34    34
# Comp:  2               HeI5876      6.966      0.32     -34    34
# Comp:  2          [OIII]5007_d      92.54      0.41     -34    34
# Comp:  2            [OI]6300_d      1.982      0.41     -34    34
# Comp:  2           [NII]6583_d      48.15      0.41     -34    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -432         1
#  comp.  1:       -33        33
#  comp.  2:       -28        35
# chi2/DOF: 1.597; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.93      0.32     -33    33
# Comp:  1                 Hbeta      50.20      0.32     -33    33
# Comp:  1                Halpha      168.4      0.32     -33    33
# Comp:  2             [SII]6716      14.14      0.32     -28    35
# Comp:  2             [SII]6731      12.78      0.32     -28    35
# Comp:  2              HeII4687     0.4578      0.32     -28    35
# Comp:  2               HeI5876      6.955      0.32     -28    35
# Comp:  2          [OIII]5007_d      88.35      0.41     -28    35
# Comp:  2            [OI]6300_d      1.925      0.41     -28    35
# Comp:  2           [NII]6583_d      46.14      0.41     -28    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -423       160
#  comp.  1:       -31        29
#  comp.  2:       -28        45
# chi2/DOF: 1.442; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.37      0.32     -31    29
# Comp:  1                 Hbeta      48.08      0.32     -31    29
# Comp:  1                Halpha      168.3      0.32     -31    29
# Comp:  2             [SII]6716      16.22      0.33     -28    45
# Comp:  2             [SII]6731      12.48      0.33     -28    45
# Comp:  2              HeII4687     0.7201      0.33     -28    45
# Comp:  2               HeI5876      6.015      0.33     -28    45
# Comp:  2          [OIII]5007_d      95.07      0.42     -28    45
# Comp:  2            [OI]6300_d      2.476      0.42     -28    45
# Comp:  2           [NII]6583_d      46.01      0.42     -28    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -546        44
#  comp.  1:       -33        32
#  comp.  2:       -31        35
# chi2/DOF: 1.588; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.97      0.32     -33    32
# Comp:  1                 Hbeta      47.32      0.32     -33    32
# Comp:  1                Halpha      170.7      0.32     -33    32
# Comp:  2             [SII]6716      12.60      0.32     -31    35
# Comp:  2             [SII]6731      11.79      0.32     -31    35
# Comp:  2              HeII4687     0.7236      0.32     -31    35
# Comp:  2               HeI5876      6.625      0.32     -31    35
# Comp:  2          [OIII]5007_d      88.52      0.41     -31    35
# Comp:  2            [OI]6300_d      2.120      0.41     -31    35
# Comp:  2           [NII]6583_d      46.39      0.41     -31    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -698         1
#  comp.  1:       -33        27
#  comp.  2:       -26        48
# chi2/DOF: 1.477; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.39      0.32     -33    27
# Comp:  1                 Hbeta      50.54      0.32     -33    27
# Comp:  1                Halpha      167.8      0.32     -33    27
# Comp:  2             [SII]6716      15.96      0.34     -26    48
# Comp:  2             [SII]6731      12.71      0.34     -26    48
# Comp:  2              HeII4687     0.4342      0.34     -26    48
# Comp:  2               HeI5876      6.484      0.34     -26    48
# Comp:  2          [OIII]5007_d      96.77      0.43     -26    48
# Comp:  2            [OI]6300_d      2.472      0.43     -26    48
# Comp:  2           [NII]6583_d      49.13      0.43     -26    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -398       198
#  comp.  1:       -32        30
#  comp.  2:       -26        37
# chi2/DOF: 1.525; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.76      0.32     -32    30
# Comp:  1                 Hbeta      49.96      0.32     -32    30
# Comp:  1                Halpha      166.5      0.32     -32    30
# Comp:  2             [SII]6716      12.66      0.32     -26    37
# Comp:  2             [SII]6731      13.57      0.32     -26    37
# Comp:  2              HeII4687     0.3530      0.32     -26    37
# Comp:  2               HeI5876      7.444      0.32     -26    37
# Comp:  2          [OIII]5007_d      90.28      0.41     -26    37
# Comp:  2            [OI]6300_d      2.374      0.41     -26    37
# Comp:  2           [NII]6583_d      47.82      0.41     -26    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42         1
#  comp.  1:       -32        33
#  comp.  2:       -27        46
# chi2/DOF: 1.398; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.00      0.32     -32    33
# Comp:  1                 Hbeta      56.62      0.32     -32    33
# Comp:  1                Halpha      169.1      0.32     -32    33
# Comp:  2             [SII]6716      15.71      0.33     -27    46
# Comp:  2             [SII]6731      11.20      0.33     -27    46
# Comp:  2              HeII4687     0.8149      0.33     -27    46
# Comp:  2               HeI5876      7.152      0.33     -27    46
# Comp:  2          [OIII]5007_d      88.96      0.42     -27    46
# Comp:  2            [OI]6300_d      2.178      0.42     -27    46
# Comp:  2           [NII]6583_d      49.19      0.42     -27    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -304         1
#  comp.  1:       -31        29
#  comp.  2:       -30        39
# chi2/DOF: 1.265; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.41      0.32     -31    29
# Comp:  1                 Hbeta      57.26      0.32     -31    29
# Comp:  1                Halpha      168.5      0.32     -31    29
# Comp:  2             [SII]6716      13.60      0.33     -30    39
# Comp:  2             [SII]6731      12.63      0.33     -30    39
# Comp:  2              HeII4687     0.6549      0.33     -30    39
# Comp:  2               HeI5876      7.554      0.33     -30    39
# Comp:  2          [OIII]5007_d      97.33      0.41     -30    39
# Comp:  2            [OI]6300_d      2.361      0.41     -30    39
# Comp:  2           [NII]6583_d      49.68      0.41     -30    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -535         1
#  comp.  1:       -34        33
#  comp.  2:       -33        49
# chi2/DOF: 1.468; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 60; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.71      0.32     -34    33
# Comp:  1                 Hbeta      48.65      0.32     -34    33
# Comp:  1                Halpha      174.0      0.32     -34    33
# Comp:  2             [SII]6716      16.02      0.34     -33    49
# Comp:  2             [SII]6731      13.84      0.34     -33    49
# Comp:  2              HeII4687     0.6063      0.34     -33    49
# Comp:  2               HeI5876      7.172      0.34     -33    49
# Comp:  2          [OIII]5007_d      96.28      0.43     -33    49
# Comp:  2            [OI]6300_d      2.198      0.43     -33    49
# Comp:  2           [NII]6583_d      49.81      0.43     -33    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -138         1
#  comp.  1:       -32        34
#  comp.  2:       -37        43
# chi2/DOF: 1.276; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      25.22      0.32     -32    34
# Comp:  1                 Hbeta      58.13      0.32     -32    34
# Comp:  1                Halpha      169.5      0.32     -32    34
# Comp:  2             [SII]6716      12.89      0.33     -37    43
# Comp:  2             [SII]6731      12.78      0.33     -37    43
# Comp:  2              HeII4687     0.3915      0.33     -37    43
# Comp:  2               HeI5876      6.193      0.33     -37    43
# Comp:  2          [OIII]5007_d      86.36      0.42     -37    43
# Comp:  2            [OI]6300_d      2.273      0.42     -37    43
# Comp:  2           [NII]6583_d      48.32      0.42     -37    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -113         1
#  comp.  1:       -32        32
#  comp.  2:       -35        28
# chi2/DOF: 1.406; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      26.60      0.32     -32    32
# Comp:  1                 Hbeta      51.26      0.32     -32    32
# Comp:  1                Halpha      168.0      0.32     -32    32
# Comp:  2             [SII]6716      13.19      0.32     -35    28
# Comp:  2             [SII]6731      13.09      0.32     -35    28
# Comp:  2              HeII4687     0.4715      0.32     -35    28
# Comp:  2               HeI5876      6.255      0.32     -35    28
# Comp:  2          [OIII]5007_d      91.49      0.40     -35    28
# Comp:  2            [OI]6300_d      2.331      0.40     -35    28
# Comp:  2           [NII]6583_d      45.91      0.40     -35    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        89
#  comp.  1:       -32        27
#  comp.  2:       -29        45
# chi2/DOF: 1.544; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 57; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.81      0.31     -32    27
# Comp:  1                 Hbeta      51.32      0.31     -32    27
# Comp:  1                Halpha      168.7      0.31     -32    27
# Comp:  2             [SII]6716      15.03      0.33     -29    45
# Comp:  2             [SII]6731      13.01      0.33     -29    45
# Comp:  2              HeII4687     0.3717      0.33     -29    45
# Comp:  2               HeI5876      6.598      0.33     -29    45
# Comp:  2          [OIII]5007_d      92.59      0.42     -29    45
# Comp:  2            [OI]6300_d      2.110      0.42     -29    45
# Comp:  2           [NII]6583_d      49.60      0.42     -29    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -397        87
#  comp.  1:       -32        32
#  comp.  2:       -32        26
# chi2/DOF: 1.235; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 52; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      26.56      0.32     -32    32
# Comp:  1                 Hbeta      44.04      0.32     -32    32
# Comp:  1                Halpha      167.9      0.32     -32    32
# Comp:  2             [SII]6716      14.13      0.31     -32    26
# Comp:  2             [SII]6731      10.89      0.31     -32    26
# Comp:  2              HeII4687     0.4250      0.31     -32    26
# Comp:  2               HeI5876      6.225      0.31     -32    26
# Comp:  2          [OIII]5007_d      88.53      0.40     -32    26
# Comp:  2            [OI]6300_d      1.909      0.40     -32    26
# Comp:  2           [NII]6583_d      47.45      0.40     -32    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -330       134
#  comp.  1:       -35        29
#  comp.  2:       -27        40
# chi2/DOF: 1.365; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      26.38      0.32     -35    29
# Comp:  1                 Hbeta      52.65      0.32     -35    29
# Comp:  1                Halpha      169.4      0.32     -35    29
# Comp:  2             [SII]6716      15.80      0.33     -27    40
# Comp:  2             [SII]6731      13.34      0.33     -27    40
# Comp:  2              HeII4687     0.5696      0.33     -27    40
# Comp:  2               HeI5876      6.537      0.33     -27    40
# Comp:  2          [OIII]5007_d      96.96      0.41     -27    40
# Comp:  2            [OI]6300_d      1.913      0.41     -27    40
# Comp:  2           [NII]6583_d      46.66      0.41     -27    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -244         1
#  comp.  1:       -34        32
#  comp.  2:       -30        27
# chi2/DOF: 1.389; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 52; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.54      0.32     -34    32
# Comp:  1                 Hbeta      44.24      0.32     -34    32
# Comp:  1                Halpha      171.5      0.32     -34    32
# Comp:  2             [SII]6716      12.31      0.32     -30    27
# Comp:  2             [SII]6731      13.15      0.32     -30    27
# Comp:  2              HeII4687     0.6585      0.32     -30    27
# Comp:  2               HeI5876      6.178      0.32     -30    27
# Comp:  2          [OIII]5007_d      88.33      0.40     -30    27
# Comp:  2            [OI]6300_d      2.187      0.40     -30    27
# Comp:  2           [NII]6583_d      45.63      0.40     -30    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -276       265
#  comp.  1:       -35        34
#  comp.  2:       -24        40
# chi2/DOF: 1.484; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.46      0.32     -35    34
# Comp:  1                 Hbeta      52.20      0.32     -35    34
# Comp:  1                Halpha      173.0      0.32     -35    34
# Comp:  2             [SII]6716      14.09      0.33     -24    40
# Comp:  2             [SII]6731      12.04      0.33     -24    40
# Comp:  2              HeII4687     0.6709      0.33     -24    40
# Comp:  2               HeI5876      6.679      0.33     -24    40
# Comp:  2          [OIII]5007_d      85.16      0.41     -24    40
# Comp:  2            [OI]6300_d      1.963      0.41     -24    40
# Comp:  2           [NII]6583_d      48.03      0.41     -24    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -368       130
#  comp.  1:       -33        29
#  comp.  2:       -31        32
# chi2/DOF: 1.354; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.39      0.32     -33    29
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2         1
#  comp.  1:       -32        27
#  comp.  2:       -37        40
# chi2/DOF: 1.312; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 75; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.46      0.31     -32    27
# Comp:  1                 Hbeta      57.11      0.31     -32    27
# Comp:  1                Halpha      168.3      0.31     -32    27
# Comp:  2             [SII]6716      12.57      0.33     -37    40
# Comp:  2             [SII]6731      13.07      0.33     -37    40
# Comp:  2              HeII4687     0.7183      0.33     -37    40
# Comp:  2               HeI5876      7.241      0.33     -37    40
# Comp:  2          [OIII]5007_d      90.11      0.41     -37    40
# Comp:  2            [OI]6300_d      2.253      0.41     -37    40
# Comp:  2           [NII]6583_d      50.29      0.41     -37    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3        82
#  comp.  1:       -32        28
#  comp.  2:       -29        44
# chi2/DOF: 1.522; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.32      0.32     -32    28
# Comp:  1                 Hbeta      48.74      0.32     -32    28
# Comp:  1                Halpha      168.7      0.32     -32    28
# Comp:  2             [SII]6716      13.93      0.33     -29    44
# Comp:  2             [SII]6731      12.20      0.33     -29    44
# Comp:  2              HeII4687     0.4301      0.33     -29    44
# Comp:  2               HeI5876      6.831      0.33     -29    44
# Comp:  2          [OIII]5007_d      91.32      0.42     -29    44
# Comp:  2            [OI]6300_d      2.586      0.42     -29    44
# Comp:  2           [NII]6583_d      51.78      0.42     -29    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        46         1
#  comp.  1:       -35        32
#  comp.  2:       -34        30
# chi2/DOF: 1.498; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.72      0.32     -35    32
# Comp:  1                 Hbeta      54.04      0.32     -35    32
# Comp:  1                Halpha      172.3      0.32     -35    32
# Comp:  2             [SII]6716      15.07      0.32     -34    30
# Comp:  2             [SII]6731      12.01      0.32     -34    30
# Comp:  2              HeII4687     0.4123      0.32     -34    30
# Comp:  2               HeI5876      7.296      0.32     -34    30
# Comp:  2          [OIII]5007_d      85.30      0.40     -34    30
# Comp:  2            [OI]6300_d      1.962      0.40     -34    30
# Comp:  2           [NII]6583_d      47.66      0.40     -34    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -619         1
#  comp.  1:       -34        28
#  comp.  2:       -31        34
# chi2/DOF: 1.444; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 75; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.95      0.32     -34    28
# Comp:  1                 Hbeta      43.98      0.32     -34    28
# Comp:  1                Halpha      171.7      0.32     -34    28
# Comp:  2             [SII]6716      13.75      0.32     -31    34
# Comp:  2             [SII]6731      11.73      0.32     -31    34
# Comp:  2              HeII4687     0.4617      0.32     -31    34
# Comp:  2               HeI5876      6.741      0.32     -31    34
# Comp:  2          [OIII]5007_d      87.76      0.41     -31    34
# Comp:  2            [OI]6300_d      2.410      0.41     -31    34
# Comp:  2           [NII]6583_d      45.09      0.41     -31    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -112         1
#  comp.  1:       -34        35
#  comp.  2:       -27        43
# chi2/DOF: 1.478; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      26.43      0.32     -34    35
# Comp:  1                 Hbeta      49.32      0.32     -34    35
# Comp:  1                Halpha      173.9      0.32     -34    35
# Comp:  2             [SII]6716      12.53      0.33     -27    43
# Comp:  2             [SII]6731      13.58      0.33     -27    43
# Comp:  2              HeII4687     0.2872      0.33     -27    43
# Comp:  2               HeI5876      7.207      0.33     -27    43
# Comp:  2          [OIII]5007_d      94.83      0.42     -27    43
# Comp:  2            [OI]6300_d      2.275      0.42     -27    43
# Comp:  2           [NII]6583_d      46.63      0.42     -27    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -129        45
#  comp.  1:       -35        34
#  comp.  2:       -28        25
# chi2/DOF: 1.415; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.25      0.32     -35    34
# Comp:  1                 Hbeta      51.83      0.32     -35    34
# Comp:  1                Halpha      172.3      0.32     -35    34
# Comp:  2             [SII]6716      14.96      0.31     -28    25
# Comp:  2             [SII]6731      12.71      0.31     -28    25
# Comp:  2              HeII4687     0.4374      0.31     -28    25
# Comp:  2               HeI5876      6.747      0.31     -28    25
# Comp:  2          [OIII]5007_d      88.18      0.40     -28    25
# Comp:  2            [OI]6300_d      2.237      0.40     -28    25
# Comp:  2           [NII]6583_d      45.15      0.40     -28    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -158       164
#  comp.  1:       -34        31
#  comp.  2:       -25        43
# chi2/DOF: 1.397; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.66      0.32     -34    31
# Comp:  1                 Hbeta      49.24      0.32     -34    31
# Comp:  1                Halpha      171.1      0.32     -34    31
# Comp:  2             [SII]6716      16.19      0.33     -25    43
# Comp:  2             [SII]6731      12.79      0.33     -25    43
# Comp:  2              HeII4687     0.4847      0.33     -25    43
# Comp:  2               HeI5876      6.809      0.33     -25    43
# Comp:  2          [OIII]5007_d      86.62      0.42     -25    43
# Comp:  2            [OI]6300_d      2.300      0.42     -25    43
# Comp:  2           [NII]6583_d      47.91      0.42     -25    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       193         1
#  comp.  1:       -32        33
#  comp.  2:       -26        43
# chi2/DOF: 1.538; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 69; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.58      0.32     -32    33
# Comp:  1                 Hbeta      51.18      0.32     -32    33
# Comp:  1                Halpha      171.3      0.32     -32    33
# Comp:  2             [SII]6716      14.04      0.33     -26    43
# Comp:  2             [SII]6731      13.61      0.33     -26    43
# Comp:  2              HeII4687     0.6174      0.33     -26    43
# Comp:  2               HeI5876      6.448      0.33     -26    43
# Comp:  2          [OIII]5007_d      87.25      0.42     -26    43
# Comp:  2            [OI]6300_d      2.053      0.42     -26    43
# Comp:  2           [NII]6583_d      48.79      0.42     -26    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -385         1
#  comp.  1:       -34        34
#  comp.  2:       -36        35
# chi2/DOF: 1.447; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.52      0.32     -34    34
# Comp:  1                 Hbeta      49.00      0.32     -34    34
# Comp:  1                Halpha      175.3      0.32     -34    34
# Comp:  2             [SII]6716      13.47      0.32     -36    35
# Comp:  2             [SII]6731      12.25      0.32     -36    35
# Comp:  2              HeII4687     0.6805      0.32     -36    35
# Comp:  2               HeI5876      7.024      0.32     -36    35
# Comp:  2          [OIII]5007_d      93.27      0.41     -36    35
# Comp:  2            [OI]6300_d      2.092      0.41     -36    35
# Comp:  2           [NII]6583_d      47.97      0.41     -36    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -442       169
#  comp.  1:       -34        33
#  comp.  2:       -29        40
# chi2/DOF: 1.595; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.77      0.32     -34    33
# Comp:  1                 Hbeta      51.01      0.32     -34    33
# Comp:  1                Halpha      171.7      0.32     -34    33
# Comp:  2             [SII]6716      14.37      0.33     -29    40
# Comp:  2             [SII]6731      13.75      0.33     -29    40
# Comp:  2              HeII4687     0.4166      0.33     -29    40
# Comp:  2               HeI5876      7.125      0.33     -29    40
# Comp:  2          [OIII]5007_d      89.81      0.41     -29    40
# Comp:  2            [OI]6300_d      2.239      0.41     -29    40
# Comp:  2           [NII]6583_d      50.86      0.41     -29    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52       271
#  comp.  1:       -32        31
#  comp.  2:       -27        40
# chi2/DOF: 1.559; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.23      0.32     -32    31
# Comp:  1                 Hbeta      48.64      0.32     -32    31
# Comp:  1                Halpha      169.5      0.32     -32    31
# Comp:  2             [SII]6716      12.58      0.33     -27    40
# Comp:  2             [SII]6731      11.98      0.33     -27    40
# Comp:  2              HeII4687     0.7391      0.33     -27    40
# Comp:  2               HeI5876      7.377      0.33     -27    40
# Comp:  2          [OIII]5007_d      90.31      0.41     -27    40
# Comp:  2            [OI]6300_d      1.987      0.41     -27    40
# Comp:  2           [NII]6583_d      49.76      0.41     -27    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -265         1
#  comp.  1:       -34        28
#  comp.  2:       -29        40
# chi2/DOF: 1.533; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.35      0.32     -34    28
# Comp:  1                 Hbeta      53.07      0.32     -34    28
# Comp:  1                Halpha      172.0      0.32     -34    28
# Comp:  2             [SII]6716      15.71      0.33     -29    40
# Comp:  2             [SII]6731      12.31      0.33     -29    40
# Comp:  2              HeII4687     0.6790      0.33     -29    40
# Comp:  2               HeI5876      6.243      0.33     -29    40
# Comp:  2          [OIII]5007_d      89.94      0.41     -29    40
# Comp:  2            [OI]6300_d      2.371      0.41     -29    40
# Comp:  2           [NII]6583_d      45.53      0.41     -29    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -549         1
#  comp.  1:       -35        34
#  comp.  2:       -32        28
# chi2/DOF: 1.408; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      25.49      0.32     -35    34
# Comp:  1                 Hbeta      47.09      0.32     -35    34
# Comp:  1                Halpha      172.0      0.32     -35    34
# Comp:  2             [SII]6716      14.01      0.32     -32    28
# Comp:  2             [SII]6731      10.88      0.32     -32    28
# Comp:  2              HeII4687     0.4752      0.32     -32    28
# Comp:  2               HeI5876      6.201      0.32     -32    28
# Comp:  2          [OIII]5007_d      84.23      0.40     -32    28
# Comp:  2            [OI]6300_d      2.205      0.40     -32    28
# Comp:  2           [NII]6583_d      45.95      0.40     -32    28
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([2.33772071, 4.12284764, 3.03310055, 1.60402818, 1.09179293,
#        0.13620806, 0.65695214, 4.62940644, 0.24196661, 2.42227864])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_14740\2709300755.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(8, 6))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 19.72904188,  51.24963375, 232.98768234,  19.81387911,
#         17.28832605,   0.54421037,   8.37664175,  93.84354296,
#          2.87868348,  65.76410351])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum1s_1_gas_ppxf.csv", index= False)

process_ppxf_results(pp_no_reg, gas_names, spectrum_name="Spectrum1s_1", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp_no_reg.sol[0][0], pp_no_reg.sol[1][0], pp_no_reg.sol[2][0]], 'Sigma': [pp_no_reg.sol[0][1], pp_no_reg.sol[1][1], pp_no_reg.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum1s_1_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum1s_1_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum1s_1_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0        Hgamma   3.873625    0.458991
# 1         Hbeta  10.062417    0.809485
# 2        Halpha  45.745090    0.595523
# 3     [SII]6716   3.890282    0.314937
# 4     [SII]6731   3.394411    0.214364
# 5      HeII4687   0.106851    0.026743
# 6       HeI5876   1.644680    0.128987
# 7  [OIII]5007_d  18.425357    0.908943
# 8    [OI]6300_d   0.565204    0.047508
# 9   [NII]6583_d  12.912206    0.475593
#           Name       Flux  Error_flux
# 0       Hgamma   3.873625    0.458991
# 1        Hbeta  10.062417    0.809485
# 2       Halpha  45.745090    0.595523
# 3    [SII]6716   3.890282    0.314937
# 4    [SII]6731   3.394411    0.214364
# 5     HeII4687   0.106851    0.026743
# 6      HeI5876   1.644680    0.128987
# 7   [OIII]4959   4.606339    0.908943
# 8   [OIII]5007  13.819018    0.908943
# 9     [OI]6300   0.423903    0.047508
# 10    [OI]6364   0.141301    0.047508
# 11   [NII]6548   3.228051    0.475593
# 12   [NII]6583   9.684154    0.475593

# %%
np.median(flux_rf_rebin)
# Out:
# 0.19634123812611057
