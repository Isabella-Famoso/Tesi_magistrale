# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
sps_name = 'emiles'
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
R = 2000 #risoluzione FORS2
c = 299792.458  # speed of light in km/s
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = True #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.
z = 0.0238

# %%
for i in range(1, 5):
    wv, flux, error = np.loadtxt(f"Spectrum_sx_{i}.txt", unpack = True) 
    wv_rf = wv/(1+z)
    flux_rf = flux*(1+z)
    error_rf = error*(1+z)

    velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
    flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
    norm = np.median(flux_rf_rebin)
    galaxy = flux_rf_rebin/norm #Normalization
    error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
    error_gal = error_rf_rebin/norm

    fwhm_gal = (wv_rf/R)
    fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
    sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

    reg_dim = sps.templates.shape[1:]
    stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
    ln_lam_pop_stars = sps.ln_lam_temp

    mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
    stars_templates = stars_templates[mask, :]
    lam_temp = sps.lam_temp
    lam_temp = lam_temp[mask]

    stars_templates /= np.median(stars_templates, axis=0)
    ln_lam_pop_stars = ln_lam_pop_stars[mask]

    lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
    mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)

    start = [20, 180.] 
    pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)

    lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
    gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)

    templates = np.column_stack([stars_templates, gas_templates])
    start = [20, 180.] 
    results = [pp_stars.sol[0], pp_stars.sol[1]]
    n_temps = stars_templates.shape[1]
    n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
    n_balmer = len(gas_names) - n_forbidden

    component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

    gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.
    moments = [2, 2, 2]
    start = [results, start, start]
    gas_reddening = 0 if tie_balmer else None

    pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)

    pp.plot()


    real_flux = np.zeros(len(gas_names))
    dlam = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        #print(dlam)
        real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
        print(f"{gas_names[kk]:12s}, gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")

    bestfit0 = pp.bestfit.copy()
    resid = galaxy - bestfit0
    start = pp.sol.copy()  

    np.random.seed(123)

    plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
    plt.subplots_adjust(hspace=0.04)
    plt.subplots_adjust(wspace=0.02)
    
    nboot = 500
    flux_i = np.empty((nboot, pp.gas_flux.size))
    for j in range(nboot):
    
        galaxy1 = bootstrap_residuals(bestfit0, resid)
    
        pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
              degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
              gas_component=gas_component, gas_names=gas_names,
              gas_reddening=gas_reddening, bias = 0)
    
        real_flux_b = np.zeros(len(gas_names))
        for kk in range(len(gas_names)):
            dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
            real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
        flux_i[j] = real_flux_b
    
    flux_err_boot = flux_i.std(axis=0)

    d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
    df1 = pd.DataFrame(data=d1)
    df1.to_csv(f"Spectrum_sx_{i}_gas_ppxf.csv", index= False)

    process_ppxf_results(pp, gas_names, spectrum_name=f"Spectrum_sx_{i}", output_dir="./")

    d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
    df3 = pd.DataFrame(data=d3)
    df3.to_csv(f"Spectrum_sx_{i}_kin.csv", index= False)

    read = pd.read_csv(f"Spectrum_sx_{i}_gas_ppxf.csv")
    print(read)
    read2 = pd.read_csv(f"Spectrum_sx_{i}_gas_exp.csv")
    print(read2)
# Out:
# C:\Users\ISAFA\anaconda3\Lib\site-packages\capfit\capfit.py:799: RuntimeWarning: invalid value encountered in scalar divide
#   ratio = actred/prered
#  Best Fit:       Vel     sigma
#  comp.  0:        20       180
# chi2/DOF: 0.03438; DOF: 2078; degree = 4; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 5; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 0/150
#  Best Fit:       Vel     sigma
#  comp.  0:       342       216
# chi2/DOF: 0.02452; DOF: 2023; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 18; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6731_d1' '[SII]6731_d2' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       386       812
#  comp.  1:       -36        28
#  comp.  2:       -37        34
# chi2/DOF: 1.030; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.48      0.77     -36    28
# Comp:  1                 Hbeta      41.76      0.61     -36    28
# Comp:  1                Halpha      115.5      0.67     -36    28
# Comp:  2          [SII]6731_d1      3.524      0.73     -37    34
# Comp:  2          [SII]6731_d2      18.72      0.79     -37    34
# Comp:  2              HeII4687    0.04082      0.49     -37    34
# Comp:  2               HeI5876      5.151      0.32     -37    34
# Comp:  2          [OIII]5007_d      67.53      0.76     -37    34
# Comp:  2            [OI]6300_d      1.423      0.32     -37    34
# Comp:  2           [NII]6583_d      34.13      0.47     -37    34
# -----------------------------------------------------------------
# Hgamma      , gas flux:     17 ergs/(cm^2 s)
# Hbeta       , gas flux:     42 ergs/(cm^2 s)
# Halpha      , gas flux:    158 ergs/(cm^2 s)
# [SII]6731_d1, gas flux:      5 ergs/(cm^2 s)
# [SII]6731_d2, gas flux:     26 ergs/(cm^2 s)
# HeII4687    , gas flux:      0 ergs/(cm^2 s)
# HeI5876     , gas flux:      6 ergs/(cm^2 s)
# [OIII]5007_d, gas flux:     71 ergs/(cm^2 s)
# [OI]6300_d  , gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d , gas flux:     47 ergs/(cm^2 s)
#  Best Fit:       Vel     sigma
#  comp.  0:       636      1000
#  comp.  1:       -35        31
#  comp.  2:       -39        41
# chi2/DOF: 0.9923; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.46      0.77     -35    31
# Comp:  1                 Hbeta      43.77      0.61     -35    31
# Comp:  1                Halpha      116.3      0.67     -35    31
# Comp:  2          [SII]6731_d1      3.719      0.75     -39    41
# Comp:  2          [SII]6731_d2      19.00      0.80     -39    41
# Comp:  2              HeII4687     0.1418      0.50     -39    41
# Comp:  2               HeI5876      5.310      0.32     -39    41
# Comp:  2          [OIII]5007_d      70.77      0.77     -39    41
# Comp:  2            [OI]6300_d      1.501      0.32     -39    41
# Comp:  2           [NII]6583_d      33.76      0.47     -39    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       578       879
#  comp.  1:       -37        33
#  comp.  2:       -36        28
# chi2/DOF: 0.9909; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.01      0.78     -37    33
# Comp:  1                 Hbeta      41.46      0.61     -37    33
# Comp:  1                Halpha      116.8      0.68     -37    33
# Comp:  2          [SII]6731_d1      1.834      0.72     -36    28
# Comp:  2          [SII]6731_d2      19.40      0.78     -36    28
# Comp:  2              HeII4687      0.000      0.48     -36    28
# Comp:  2               HeI5876      5.292      0.31     -36    28
# Comp:  2          [OIII]5007_d      66.38      0.75     -36    28
# Comp:  2            [OI]6300_d      1.236      0.31     -36    28
# Comp:  2           [NII]6583_d      33.66      0.46     -36    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       457       894
#  comp.  1:       -35        16
#  comp.  2:       -35        34
# chi2/DOF: 0.9483; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.20      0.75     -35    16
# Comp:  1                 Hbeta      41.10      0.59     -35    16
# Comp:  1                Halpha      115.1      0.67     -35    16
# Comp:  2          [SII]6731_d1      6.926      0.73     -35    34
# Comp:  2          [SII]6731_d2      15.01      0.79     -35    34
# Comp:  2              HeII4687  0.0008840      0.49     -35    34
# Comp:  2               HeI5876      5.717      0.32     -35    34
# Comp:  2          [OIII]5007_d      66.93      0.76     -35    34
# Comp:  2            [OI]6300_d      1.400      0.32     -35    34
# Comp:  2           [NII]6583_d      33.76      0.47     -35    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       258      1000
#  comp.  1:       -39        39
#  comp.  2:       -36        29
# chi2/DOF: 0.9356; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.26      0.79     -39    39
# Comp:  1                 Hbeta      43.39      0.62     -39    39
# Comp:  1                Halpha      116.4      0.68     -39    39
# Comp:  2          [SII]6731_d1      5.966      0.73     -36    29
# Comp:  2          [SII]6731_d2      16.54      0.78     -36    29
# Comp:  2              HeII4687     0.2452      0.48     -36    29
# Comp:  2               HeI5876      5.141      0.31     -36    29
# Comp:  2          [OIII]5007_d      66.15      0.75     -36    29
# Comp:  2            [OI]6300_d      1.184      0.31     -36    29
# Comp:  2           [NII]6583_d      33.07      0.46     -36    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       595       437
#  comp.  1:       -38        37
#  comp.  2:       -39        40
# chi2/DOF: 0.9493; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.05      0.78     -38    37
# Comp:  1                 Hbeta      40.62      0.62     -38    37
# Comp:  1                Halpha      119.8      0.68     -38    37
# Comp:  2          [SII]6731_d1      4.384      0.75     -39    40
# Comp:  2          [SII]6731_d2      18.64      0.80     -39    40
# Comp:  2              HeII4687    0.06834      0.50     -39    40
# Comp:  2               HeI5876      4.990      0.32     -39    40
# Comp:  2          [OIII]5007_d      70.29      0.77     -39    40
# Comp:  2            [OI]6300_d      1.356      0.32     -39    40
# Comp:  2           [NII]6583_d      34.35      0.47     -39    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       191       635
#  comp.  1:       -38        25
#  comp.  2:       -40        23
# chi2/DOF: 0.9784; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.64      0.76     -38    25
# Comp:  1                 Hbeta      41.78      0.60     -38    25
# Comp:  1                Halpha      115.2      0.67     -38    25
# Comp:  2          [SII]6731_d1      2.232      0.72     -40    23
# Comp:  2          [SII]6731_d2      19.94      0.77     -40    23
# Comp:  2              HeII4687    0.01519      0.47     -40    23
# Comp:  2               HeI5876      4.793      0.31     -40    23
# Comp:  2          [OIII]5007_d      62.66      0.74     -40    23
# Comp:  2            [OI]6300_d      1.490      0.31     -40    23
# Comp:  2           [NII]6583_d      33.64      0.46     -40    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       566       793
#  comp.  1:       -32        25
#  comp.  2:       -40        33
# chi2/DOF: 0.9363; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.76      0.76     -32    25
# Comp:  1                 Hbeta      40.02      0.60     -32    25
# Comp:  1                Halpha      110.1      0.67     -32    25
# Comp:  2          [SII]6731_d1      5.113      0.73     -40    33
# Comp:  2          [SII]6731_d2      17.50      0.79     -40    33
# Comp:  2              HeII4687     0.2825      0.49     -40    33
# Comp:  2               HeI5876      4.624      0.31     -40    33
# Comp:  2          [OIII]5007_d      65.78      0.76     -40    33
# Comp:  2            [OI]6300_d      1.583      0.32     -40    33
# Comp:  2           [NII]6583_d      34.48      0.47     -40    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       630       929
#  comp.  1:       -34        16
#  comp.  2:       -37        38
# chi2/DOF: 0.9284; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.74      0.75     -34    16
# Comp:  1                 Hbeta      40.08      0.59     -34    16
# Comp:  1                Halpha      111.3      0.66     -34    16
# Comp:  2          [SII]6731_d1      5.346      0.74     -37    38
# Comp:  2          [SII]6731_d2      16.16      0.79     -37    38
# Comp:  2              HeII4687    0.06363      0.49     -37    38
# Comp:  2               HeI5876      5.484      0.32     -37    38
# Comp:  2          [OIII]5007_d      67.48      0.76     -37    38
# Comp:  2            [OI]6300_d      1.491      0.32     -37    38
# Comp:  2           [NII]6583_d      34.43      0.47     -37    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       367       965
#  comp.  1:       -37        21
#  comp.  2:       -36        35
# chi2/DOF: 0.9636; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.51      0.75     -37    21
# Comp:  1                 Hbeta      45.69      0.60     -37    21
# Comp:  1                Halpha      117.8      0.67     -37    21
# Comp:  2          [SII]6731_d1      3.476      0.74     -36    35
# Comp:  2          [SII]6731_d2      18.83      0.79     -36    35
# Comp:  2              HeII4687    0.01666      0.49     -36    35
# Comp:  2               HeI5876      4.625      0.32     -36    35
# Comp:  2          [OIII]5007_d      69.28      0.76     -36    35
# Comp:  2            [OI]6300_d      1.531      0.32     -36    35
# Comp:  2           [NII]6583_d      34.14      0.47     -36    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       583      1000
#  comp.  1:       -36        25
#  comp.  2:       -33        33
# chi2/DOF: 0.9741; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.94      0.76     -36    25
# Comp:  1                 Hbeta      38.10      0.60     -36    25
# Comp:  1                Halpha      114.5      0.67     -36    25
# Comp:  2          [SII]6731_d1      5.177      0.73     -33    33
# Comp:  2          [SII]6731_d2      18.19      0.78     -33    33
# Comp:  2              HeII4687      0.000      0.49     -33    33
# Comp:  2               HeI5876      4.490      0.32     -33    33
# Comp:  2          [OIII]5007_d      70.14      0.76     -33    33
# Comp:  2            [OI]6300_d      1.229      0.32     -33    33
# Comp:  2           [NII]6583_d      33.76      0.47     -33    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       433       350
#  comp.  1:       -39        35
#  comp.  2:       -39        42
# chi2/DOF: 0.9486; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.33      0.78     -39    35
# Comp:  1                 Hbeta      46.33      0.62     -39    35
# Comp:  1                Halpha      117.7      0.68     -39    35
# Comp:  2          [SII]6731_d1      2.260      0.75     -39    42
# Comp:  2          [SII]6731_d2      19.25      0.80     -39    42
# Comp:  2              HeII4687     0.2188      0.50     -39    42
# Comp:  2               HeI5876      5.321      0.32     -39    42
# Comp:  2          [OIII]5007_d      69.97      0.77     -39    42
# Comp:  2            [OI]6300_d      1.259      0.32     -39    42
# Comp:  2           [NII]6583_d      35.17      0.47     -39    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        59       831
#  comp.  1:       -38        26
#  comp.  2:       -37        41
# chi2/DOF: 0.9771; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.23      0.76     -38    26
# Comp:  1                 Hbeta      38.30      0.60     -38    26
# Comp:  1                Halpha      115.1      0.67     -38    26
# Comp:  2          [SII]6731_d1      2.035      0.75     -37    41
# Comp:  2          [SII]6731_d2      20.12      0.80     -37    41
# Comp:  2              HeII4687    0.01833      0.50     -37    41
# Comp:  2               HeI5876      5.432      0.32     -37    41
# Comp:  2          [OIII]5007_d      70.13      0.77     -37    41
# Comp:  2            [OI]6300_d      1.279      0.32     -37    41
# Comp:  2           [NII]6583_d      35.09      0.47     -37    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       498       417
#  comp.  1:       -41        38
#  comp.  2:       -34        36
# chi2/DOF: 0.8911; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.48      0.78     -41    38
# Comp:  1                 Hbeta      40.19      0.62     -41    38
# Comp:  1                Halpha      114.8      0.68     -41    38
# Comp:  2          [SII]6731_d1      4.006      0.74     -34    36
# Comp:  2          [SII]6731_d2      16.41      0.79     -34    36
# Comp:  2              HeII4687    0.07883      0.49     -34    36
# Comp:  2               HeI5876      5.485      0.32     -34    36
# Comp:  2          [OIII]5007_d      69.40      0.76     -34    36
# Comp:  2            [OI]6300_d      1.363      0.32     -34    36
# Comp:  2           [NII]6583_d      35.26      0.47     -34    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       365       274
#  comp.  1:       -38        29
#  comp.  2:       -34        33
# chi2/DOF: 0.9907; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.05      0.77     -38    29
# Comp:  1                 Hbeta      44.32      0.61     -38    29
# Comp:  1                Halpha      114.5      0.67     -38    29
# Comp:  2          [SII]6731_d1      1.771      0.73     -34    33
# Comp:  2          [SII]6731_d2      19.81      0.78     -34    33
# Comp:  2              HeII4687     0.2938      0.49     -34    33
# Comp:  2               HeI5876      5.675      0.31     -34    33
# Comp:  2          [OIII]5007_d      70.60      0.76     -34    33
# Comp:  2            [OI]6300_d      1.426      0.32     -34    33
# Comp:  2           [NII]6583_d      33.15      0.47     -34    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       215       900
#  comp.  1:       -40        25
#  comp.  2:       -41        31
# chi2/DOF: 0.9723; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.55      0.76     -40    25
# Comp:  1                 Hbeta      38.75      0.60     -40    25
# Comp:  1                Halpha      114.8      0.67     -40    25
# Comp:  2          [SII]6731_d1      2.984      0.73     -41    31
# Comp:  2          [SII]6731_d2      19.52      0.78     -41    31
# Comp:  2              HeII4687      0.000      0.48     -41    31
# Comp:  2               HeI5876      4.680      0.31     -41    31
# Comp:  2          [OIII]5007_d      69.01      0.75     -41    31
# Comp:  2            [OI]6300_d      1.334      0.31     -41    31
# Comp:  2           [NII]6583_d      34.33      0.46     -41    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       322       537
#  comp.  1:       -36        25
#  comp.  2:       -40        25
# chi2/DOF: 0.9830; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.66      0.76     -36    25
# Comp:  1                 Hbeta      43.95      0.60     -36    25
# Comp:  1                Halpha      116.3      0.67     -36    25
# Comp:  2          [SII]6731_d1      5.875      0.72     -40    25
# Comp:  2          [SII]6731_d2      15.95      0.77     -40    25
# Comp:  2              HeII4687     0.1439      0.48     -40    25
# Comp:  2               HeI5876      5.110      0.31     -40    25
# Comp:  2          [OIII]5007_d      66.06      0.74     -40    25
# Comp:  2            [OI]6300_d      1.327      0.31     -40    25
# Comp:  2           [NII]6583_d      33.68      0.46     -40    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       437       753
#  comp.  1:       -37        30
#  comp.  2:       -44        33
# chi2/DOF: 0.9340; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.41      0.77     -37    30
# Comp:  1                 Hbeta      35.59      0.61     -37    30
# Comp:  1                Halpha      114.3      0.67     -37    30
# Comp:  2          [SII]6731_d1      6.407      0.73     -44    33
# Comp:  2          [SII]6731_d2      15.39      0.79     -44    33
# Comp:  2              HeII4687     0.1848      0.49     -44    33
# Comp:  2               HeI5876      5.267      0.31     -44    33
# Comp:  2          [OIII]5007_d      65.15      0.75     -44    33
# Comp:  2            [OI]6300_d      1.518      0.32     -44    33
# Comp:  2           [NII]6583_d      32.50      0.47     -44    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       166         1
#  comp.  1:       -37        38
#  comp.  2:       -38        35
# chi2/DOF: 0.9268; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 97; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.29      0.79     -37    38
# Comp:  1                 Hbeta      48.42      0.62     -37    38
# Comp:  1                Halpha      117.0      0.68     -37    38
# Comp:  2          [SII]6731_d1      3.605      0.74     -38    35
# Comp:  2          [SII]6731_d2      16.78      0.79     -38    35
# Comp:  2              HeII4687     0.1048      0.49     -38    35
# Comp:  2               HeI5876      5.149      0.32     -38    35
# Comp:  2          [OIII]5007_d      68.81      0.76     -38    35
# Comp:  2            [OI]6300_d      1.435      0.32     -38    35
# Comp:  2           [NII]6583_d      33.55      0.47     -38    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       263       850
#  comp.  1:       -32        21
#  comp.  2:       -42        32
# chi2/DOF: 0.9153; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.46      0.76     -32    21
# Comp:  1                 Hbeta      40.54      0.60     -32    21
# Comp:  1                Halpha      113.5      0.67     -32    21
# Comp:  2          [SII]6731_d1      4.392      0.73     -42    32
# Comp:  2          [SII]6731_d2      19.36      0.78     -42    32
# Comp:  2              HeII4687     0.1700      0.49     -42    32
# Comp:  2               HeI5876      5.251      0.31     -42    32
# Comp:  2          [OIII]5007_d      63.58      0.75     -42    32
# Comp:  2            [OI]6300_d      1.451      0.31     -42    32
# Comp:  2           [NII]6583_d      33.76      0.46     -42    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       322       665
#  comp.  1:       -38        22
#  comp.  2:       -37        21
# chi2/DOF: 0.9415; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.01      0.75     -38    22
# Comp:  1                 Hbeta      36.08      0.60     -38    22
# Comp:  1                Halpha      117.5      0.67     -38    22
# Comp:  2          [SII]6731_d1      3.942      0.71     -37    21
# Comp:  2          [SII]6731_d2      17.46      0.77     -37    21
# Comp:  2              HeII4687     0.2173      0.47     -37    21
# Comp:  2               HeI5876      5.170      0.31     -37    21
# Comp:  2          [OIII]5007_d      65.00      0.74     -37    21
# Comp:  2            [OI]6300_d      1.518      0.31     -37    21
# Comp:  2           [NII]6583_d      33.24      0.46     -37    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       295       895
#  comp.  1:       -35        18
#  comp.  2:       -40        27
# chi2/DOF: 0.9584; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.55      0.75     -35    18
# Comp:  1                 Hbeta      42.58      0.60     -35    18
# Comp:  1                Halpha      113.1      0.67     -35    18
# Comp:  2          [SII]6731_d1      3.810      0.72     -40    27
# Comp:  2          [SII]6731_d2      17.99      0.78     -40    27
# Comp:  2              HeII4687    0.02077      0.48     -40    27
# Comp:  2               HeI5876      5.550      0.31     -40    27
# Comp:  2          [OIII]5007_d      65.72      0.75     -40    27
# Comp:  2            [OI]6300_d      1.366      0.31     -40    27
# Comp:  2           [NII]6583_d      34.18      0.46     -40    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       485       657
#  comp.  1:       -37        20
#  comp.  2:       -35        35
# chi2/DOF: 0.9491; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.72      0.75     -37    20
# Comp:  1                 Hbeta      43.59      0.60     -37    20
# Comp:  1                Halpha      117.5      0.67     -37    20
# Comp:  2          [SII]6731_d1      0.000      0.73     -35    35
# Comp:  2          [SII]6731_d2      22.82      0.79     -35    35
# Comp:  2              HeII4687    0.08655      0.49     -35    35
# Comp:  2               HeI5876      5.358      0.32     -35    35
# Comp:  2          [OIII]5007_d      70.29      0.76     -35    35
# Comp:  2            [OI]6300_d      1.422      0.32     -35    35
# Comp:  2           [NII]6583_d      33.65      0.47     -35    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        79       853
#  comp.  1:       -38        22
#  comp.  2:       -41        30
# chi2/DOF: 0.9487; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.77      0.75     -38    22
# Comp:  1                 Hbeta      37.48      0.60     -38    22
# Comp:  1                Halpha      118.0      0.67     -38    22
# Comp:  2          [SII]6731_d1      5.466      0.73     -41    30
# Comp:  2          [SII]6731_d2      15.80      0.78     -41    30
# Comp:  2              HeII4687     0.2513      0.48     -41    30
# Comp:  2               HeI5876      4.722      0.31     -41    30
# Comp:  2          [OIII]5007_d      64.64      0.75     -41    30
# Comp:  2            [OI]6300_d      1.378      0.31     -41    30
# Comp:  2           [NII]6583_d      34.63      0.46     -41    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       293       578
#  comp.  1:       -41        37
#  comp.  2:       -39        29
# chi2/DOF: 0.8810; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.82      0.78     -41    37
# Comp:  1                 Hbeta      39.81      0.62     -41    37
# Comp:  1                Halpha      118.6      0.68     -41    37
# Comp:  2          [SII]6731_d1      0.000      0.73     -39    29
# Comp:  2          [SII]6731_d2      22.80      0.78     -39    29
# Comp:  2              HeII4687    0.03060      0.48     -39    29
# Comp:  2               HeI5876      5.148      0.31     -39    29
# Comp:  2          [OIII]5007_d      68.52      0.75     -39    29
# Comp:  2            [OI]6300_d      1.393      0.31     -39    29
# Comp:  2           [NII]6583_d      34.07      0.46     -39    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        55
#  comp.  1:       -38        39
#  comp.  2:       -37        30
# chi2/DOF: 0.9396; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.27      0.79     -38    39
# Comp:  1                 Hbeta      42.80      0.62     -38    39
# Comp:  1                Halpha      117.2      0.68     -38    39
# Comp:  2          [SII]6731_d1      4.334      0.73     -37    30
# Comp:  2          [SII]6731_d2      18.82      0.78     -37    30
# Comp:  2              HeII4687    0.05461      0.48     -37    30
# Comp:  2               HeI5876      5.431      0.31     -37    30
# Comp:  2          [OIII]5007_d      65.64      0.75     -37    30
# Comp:  2            [OI]6300_d      1.597      0.31     -37    30
# Comp:  2           [NII]6583_d      33.33      0.46     -37    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       663       554
#  comp.  1:       -35        25
#  comp.  2:       -36        37
# chi2/DOF: 0.9717; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.19      0.76     -35    25
# Comp:  1                 Hbeta      39.11      0.60     -35    25
# Comp:  1                Halpha      114.3      0.67     -35    25
# Comp:  2          [SII]6731_d1     0.7997      0.74     -36    37
# Comp:  2          [SII]6731_d2      22.70      0.79     -36    37
# Comp:  2              HeII4687      0.000      0.49     -36    37
# Comp:  2               HeI5876      4.413      0.32     -36    37
# Comp:  2          [OIII]5007_d      71.14      0.76     -36    37
# Comp:  2            [OI]6300_d      1.440      0.32     -36    37
# Comp:  2           [NII]6583_d      33.26      0.47     -36    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       626       650
#  comp.  1:       -39        37
#  comp.  2:       -37        29
# chi2/DOF: 0.9404; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.39      0.78     -39    37
# Comp:  1                 Hbeta      40.44      0.62     -39    37
# Comp:  1                Halpha      119.6      0.68     -39    37
# Comp:  2          [SII]6731_d1      4.611      0.73     -37    29
# Comp:  2          [SII]6731_d2      16.05      0.78     -37    29
# Comp:  2              HeII4687      0.000      0.48     -37    29
# Comp:  2               HeI5876      4.769      0.31     -37    29
# Comp:  2          [OIII]5007_d      67.34      0.75     -37    29
# Comp:  2            [OI]6300_d      1.422      0.31     -37    29
# Comp:  2           [NII]6583_d      33.60      0.46     -37    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       526       969
#  comp.  1:       -34        18
#  comp.  2:       -35        42
# chi2/DOF: 0.9278; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.55      0.75     -34    18
# Comp:  1                 Hbeta      41.48      0.60     -34    18
# Comp:  1                Halpha      111.4      0.67     -34    18
# Comp:  2          [SII]6731_d1      2.435      0.75     -35    42
# Comp:  2          [SII]6731_d2      21.49      0.80     -35    42
# Comp:  2              HeII4687    0.02381      0.50     -35    42
# Comp:  2               HeI5876      4.945      0.32     -35    42
# Comp:  2          [OIII]5007_d      73.14      0.77     -35    42
# Comp:  2            [OI]6300_d      1.307      0.33     -35    42
# Comp:  2           [NII]6583_d      34.17      0.47     -35    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3       261
#  comp.  1:       -35        30
#  comp.  2:       -36        33
# chi2/DOF: 0.9887; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 95; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.21      0.77     -35    30
# Comp:  1                 Hbeta      41.92      0.61     -35    30
# Comp:  1                Halpha      112.8      0.67     -35    30
# Comp:  2          [SII]6731_d1      6.951      0.73     -36    33
# Comp:  2          [SII]6731_d2      15.20      0.79     -36    33
# Comp:  2              HeII4687     0.1858      0.49     -36    33
# Comp:  2               HeI5876      5.623      0.31     -36    33
# Comp:  2          [OIII]5007_d      68.97      0.76     -36    33
# Comp:  2            [OI]6300_d      1.460      0.32     -36    33
# Comp:  2           [NII]6583_d      34.66      0.47     -36    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:       -38        37
#  comp.  2:       -34        35
# chi2/DOF: 0.9287; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.00      0.78     -38    37
# Comp:  1                 Hbeta      47.88      0.62     -38    37
# Comp:  1                Halpha      116.5      0.68     -38    37
# Comp:  2          [SII]6731_d1      0.000      0.73     -34    35
# Comp:  2          [SII]6731_d2      22.39      0.79     -34    35
# Comp:  2              HeII4687      0.000      0.49     -34    35
# Comp:  2               HeI5876      5.280      0.32     -34    35
# Comp:  2          [OIII]5007_d      66.27      0.76     -34    35
# Comp:  2            [OI]6300_d      1.357      0.32     -34    35
# Comp:  2           [NII]6583_d      34.12      0.47     -34    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       111       672
#  comp.  1:       -34        26
#  comp.  2:       -35        35
# chi2/DOF: 0.9452; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.50      0.76     -34    26
# Comp:  1                 Hbeta      47.70      0.60     -34    26
# Comp:  1                Halpha      116.2      0.67     -34    26
# Comp:  2          [SII]6731_d1      4.546      0.73     -35    35
# Comp:  2          [SII]6731_d2      17.07      0.79     -35    35
# Comp:  2              HeII4687    0.05427      0.49     -35    35
# Comp:  2               HeI5876      5.776      0.32     -35    35
# Comp:  2          [OIII]5007_d      72.06      0.76     -35    35
# Comp:  2            [OI]6300_d      1.502      0.32     -35    35
# Comp:  2           [NII]6583_d      34.99      0.47     -35    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       583      1000
#  comp.  1:       -40        35
#  comp.  2:       -39        41
# chi2/DOF: 0.9116; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.93      0.78     -40    35
# Comp:  1                 Hbeta      40.18      0.62     -40    35
# Comp:  1                Halpha      121.1      0.68     -40    35
# Comp:  2          [SII]6731_d1      3.799      0.75     -39    41
# Comp:  2          [SII]6731_d2      20.75      0.80     -39    41
# Comp:  2              HeII4687    0.03429      0.50     -39    41
# Comp:  2               HeI5876      5.257      0.32     -39    41
# Comp:  2          [OIII]5007_d      71.13      0.77     -39    41
# Comp:  2            [OI]6300_d      1.375      0.32     -39    41
# Comp:  2           [NII]6583_d      34.56      0.47     -39    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
#  comp.  1:       -34        35
#  comp.  2:       -44        35
# chi2/DOF: 0.9210; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 15; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.95      0.78     -34    35
# Comp:  1                 Hbeta      48.81      0.62     -34    35
# Comp:  1                Halpha      114.2      0.68     -34    35
# Comp:  2          [SII]6731_d1      5.455      0.74     -44    35
# Comp:  2          [SII]6731_d2      16.14      0.79     -44    35
# Comp:  2              HeII4687     0.2085      0.49     -44    35
# Comp:  2               HeI5876      4.614      0.32     -44    35
# Comp:  2          [OIII]5007_d      65.67      0.76     -44    35
# Comp:  2            [OI]6300_d      1.279      0.32     -44    35
# Comp:  2           [NII]6583_d      34.23      0.47     -44    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        73       152
#  comp.  1:       -39        36
#  comp.  2:       -39        26
# chi2/DOF: 0.9552; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.35      0.78     -39    36
# Comp:  1                 Hbeta      42.72      0.62     -39    36
# Comp:  1                Halpha      114.9      0.68     -39    36
# Comp:  2          [SII]6731_d1      6.145      0.72     -39    26
# Comp:  2          [SII]6731_d2      16.26      0.78     -39    26
# Comp:  2              HeII4687     0.1960      0.48     -39    26
# Comp:  2               HeI5876      4.880      0.31     -39    26
# Comp:  2          [OIII]5007_d      67.95      0.75     -39    26
# Comp:  2            [OI]6300_d      1.345      0.31     -39    26
# Comp:  2           [NII]6583_d      33.29      0.46     -39    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        96      1000
#  comp.  1:       -32        17
#  comp.  2:       -37        40
# chi2/DOF: 0.9170; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.33      0.75     -32    17
# Comp:  1                 Hbeta      40.79      0.59     -32    17
# Comp:  1                Halpha      112.9      0.66     -32    17
# Comp:  2          [SII]6731_d1      3.127      0.75     -37    40
# Comp:  2          [SII]6731_d2      20.34      0.80     -37    40
# Comp:  2              HeII4687     0.2846      0.50     -37    40
# Comp:  2               HeI5876      4.807      0.32     -37    40
# Comp:  2          [OIII]5007_d      69.54      0.77     -37    40
# Comp:  2            [OI]6300_d      1.349      0.32     -37    40
# Comp:  2           [NII]6583_d      34.57      0.47     -37    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       427       309
#  comp.  1:       -32        25
#  comp.  2:       -40        28
# chi2/DOF: 0.8932; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.37      0.76     -32    25
# Comp:  1                 Hbeta      35.92      0.60     -32    25
# Comp:  1                Halpha      110.6      0.67     -32    25
# Comp:  2          [SII]6731_d1     0.7115      0.73     -40    28
# Comp:  2          [SII]6731_d2      20.97      0.78     -40    28
# Comp:  2              HeII4687     0.1338      0.48     -40    28
# Comp:  2               HeI5876      4.841      0.31     -40    28
# Comp:  2          [OIII]5007_d      67.47      0.75     -40    28
# Comp:  2            [OI]6300_d      1.425      0.31     -40    28
# Comp:  2           [NII]6583_d      34.56      0.46     -40    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       245       705
#  comp.  1:       -38        26
#  comp.  2:       -34        33
# chi2/DOF: 0.9588; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.54      0.76     -38    26
# Comp:  1                 Hbeta      44.07      0.60     -38    26
# Comp:  1                Halpha      115.5      0.67     -38    26
# Comp:  2          [SII]6731_d1      2.880      0.73     -34    33
# Comp:  2          [SII]6731_d2      21.48      0.78     -34    33
# Comp:  2              HeII4687     0.1254      0.49     -34    33
# Comp:  2               HeI5876      4.942      0.32     -34    33
# Comp:  2          [OIII]5007_d      71.46      0.76     -34    33
# Comp:  2            [OI]6300_d      1.566      0.32     -34    33
# Comp:  2           [NII]6583_d      33.32      0.47     -34    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       321      1000
#  comp.  1:       -34        23
#  comp.  2:       -38        32
# chi2/DOF: 0.9445; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.26      0.76     -34    23
# Comp:  1                 Hbeta      35.83      0.60     -34    23
# Comp:  1                Halpha      113.9      0.67     -34    23
# Comp:  2          [SII]6731_d1      7.391      0.73     -38    32
# Comp:  2          [SII]6731_d2      14.77      0.78     -38    32
# Comp:  2              HeII4687      0.000      0.48     -38    32
# Comp:  2               HeI5876      4.880      0.31     -38    32
# Comp:  2          [OIII]5007_d      66.77      0.75     -38    32
# Comp:  2            [OI]6300_d      1.459      0.31     -38    32
# Comp:  2           [NII]6583_d      33.55      0.46     -38    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26       354
#  comp.  1:       -39        39
#  comp.  2:       -34        31
# chi2/DOF: 0.9110; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.49      0.79     -39    39
# Comp:  1                 Hbeta      44.08      0.62     -39    39
# Comp:  1                Halpha      120.4      0.68     -39    39
# Comp:  2          [SII]6731_d1      2.879      0.73     -34    31
# Comp:  2          [SII]6731_d2      18.88      0.78     -34    31
# Comp:  2              HeII4687      0.000      0.48     -34    31
# Comp:  2               HeI5876      4.941      0.31     -34    31
# Comp:  2          [OIII]5007_d      64.17      0.75     -34    31
# Comp:  2            [OI]6300_d      1.365      0.31     -34    31
# Comp:  2           [NII]6583_d      33.49      0.46     -34    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       827      1000
#  comp.  1:       -34        18
#  comp.  2:       -39        28
# chi2/DOF: 0.9118; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.81      0.75     -34    18
# Comp:  1                 Hbeta      36.91      0.60     -34    18
# Comp:  1                Halpha      111.4      0.67     -34    18
# Comp:  2          [SII]6731_d1      3.482      0.73     -39    28
# Comp:  2          [SII]6731_d2      18.15      0.78     -39    28
# Comp:  2              HeII4687      0.000      0.48     -39    28
# Comp:  2               HeI5876      5.338      0.31     -39    28
# Comp:  2          [OIII]5007_d      61.42      0.75     -39    28
# Comp:  2            [OI]6300_d      1.267      0.31     -39    28
# Comp:  2           [NII]6583_d      34.87      0.46     -39    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       185      1000
#  comp.  1:       -38        22
#  comp.  2:       -34        42
# chi2/DOF: 0.9528; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.40      0.75     -38    22
# Comp:  1                 Hbeta      41.81      0.60     -38    22
# Comp:  1                Halpha      117.7      0.67     -38    22
# Comp:  2          [SII]6731_d1      1.692      0.75     -34    42
# Comp:  2          [SII]6731_d2      22.47      0.80     -34    42
# Comp:  2              HeII4687    0.06592      0.50     -34    42
# Comp:  2               HeI5876      5.855      0.32     -34    42
# Comp:  2          [OIII]5007_d      72.58      0.77     -34    42
# Comp:  2            [OI]6300_d      1.558      0.32     -34    42
# Comp:  2           [NII]6583_d      34.27      0.47     -34    42
# -----------------------------------------------------------------
