# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum2s_1', unpack = True)
z = 0.0238 
wv_rf = wv/(1+z)
flux_rf = flux*(1+z)
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4200.76186755 4202.20746239 4203.65305724 ... 6928.59933581 6930.04493065
#  6931.49052549] [1.2108123  0.43234511 0.36346934 ... 0.21623486 0.23290377 0.21900096] [0.07981983 0.0779285  0.0754925  ... 0.01798021 0.01808298 0.01796174]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
galaxy = flux_rf_rebin/np.median(flux_rf_rebin) #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/np.median(error_rf_rebin)

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.10038093 2.10110373 2.10182653 ... 3.46429967 3.46502247 3.46574526]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3343, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3343, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3343, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         7       200
# chi2/DOF: 0.01598; DOF: 2076; degree = 4; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 5; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -83        57
# chi2/DOF: 0.008764; DOF: 2021; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-82.82207953,  57.04233344])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = True #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6731_d1' '[SII]6731_d2' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])  # forbidden lines contain "[*]"
n_balmer = len(gas_names) - n_forbidden

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -168         1
#  comp.  1:       -33        25
#  comp.  2:       -31        36
# chi2/DOF: 0.01492; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.19       5.1     -33    25
# Comp:  1                 Hbeta      46.86       4.4     -33    25
# Comp:  1                Halpha      152.6       5.7     -33    25
# Comp:  1          [SII]6731_d1      4.663       5.2     -33    25
# Comp:  1          [SII]6731_d2      19.11       5.6     -33    25
# Comp:  2              HeII4687     0.4376       3.1     -31    36
# Comp:  2               HeI5876      6.002       2.1     -31    36
# Comp:  2          [OIII]5007_d      81.06       5.7     -31    36
# Comp:  2            [OI]6300_d      1.979       2.1     -31    36
# Comp:  2           [NII]6583_d      42.84       3.6     -31    36
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  74.82; gas flux:     18 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:    182; gas flux:     48 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  586.9; gas flux:    209 ergs/(cm^2 s)
# [SII]6731_d1 - Amplitude/Noise:  12.58; gas flux:      7 ergs/(cm^2 s)
# [SII]6731_d2 - Amplitude/Noise:  42.81; gas flux:     27 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.518; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  20.52; gas flux:      7 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  208.3; gas flux:     85 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  5.389; gas flux:      3 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  117.3; gas flux:     59 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 200
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -226       150
#  comp.  1:       -33        28
#  comp.  2:       -31        45
# chi2/DOF: 0.01361; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.17       5.2     -33    28
# Comp:  1                 Hbeta      49.67       4.5     -33    28
# Comp:  1                Halpha      153.6       5.7     -33    28
# Comp:  1          [SII]6731_d1      4.218       5.2     -33    28
# Comp:  1          [SII]6731_d2      19.93       5.6     -33    28
# Comp:  2              HeII4687     0.2336       3.1     -31    45
# Comp:  2               HeI5876      6.323       2.2     -31    45
# Comp:  2          [OIII]5007_d      84.59       5.8     -31    45
# Comp:  2            [OI]6300_d      2.246       2.1     -31    45
# Comp:  2           [NII]6583_d      42.06       3.7     -31    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -154        30
#  comp.  1:       -33        31
#  comp.  2:       -30        26
# chi2/DOF: 0.01365; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      25.47       5.2     -33    31
# Comp:  1                 Hbeta      46.46       4.5     -33    31
# Comp:  1                Halpha      153.8       5.7     -33    31
# Comp:  1          [SII]6731_d1      3.834       5.2     -33    31
# Comp:  1          [SII]6731_d2      19.23       5.6     -33    31
# Comp:  2              HeII4687     0.4523       3.0     -30    26
# Comp:  2               HeI5876      6.108       2.1     -30    26
# Comp:  2          [OIII]5007_d      80.74       5.6     -30    26
# Comp:  2            [OI]6300_d      1.845       2.0     -30    26
# Comp:  2           [NII]6583_d      41.65       3.6     -30    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -185         1
#  comp.  1:       -32        16
#  comp.  2:       -27        35
# chi2/DOF: 0.01293; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.14       5.0     -32    16
# Comp:  1                 Hbeta      46.73       4.4     -32    16
# Comp:  1                Halpha      154.1       5.7     -32    16
# Comp:  1          [SII]6731_d1      7.887       5.1     -32    16
# Comp:  1          [SII]6731_d2      15.45       5.5     -32    16
# Comp:  2              HeII4687     0.3920       3.0     -27    35
# Comp:  2               HeI5876      6.506       2.1     -27    35
# Comp:  2          [OIII]5007_d      79.91       5.7     -27    35
# Comp:  2            [OI]6300_d      1.963       2.1     -27    35
# Comp:  2           [NII]6583_d      41.96       3.6     -27    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53       138
#  comp.  1:       -35        33
#  comp.  2:       -32        29
# chi2/DOF: 0.01279; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.94       5.2     -35    33
# Comp:  1                 Hbeta      47.56       4.5     -35    33
# Comp:  1                Halpha      151.8       5.7     -35    33
# Comp:  1          [SII]6731_d1      6.982       5.2     -35    33
# Comp:  1          [SII]6731_d2      17.54       5.6     -35    33
# Comp:  2              HeII4687     0.2322       3.0     -32    29
# Comp:  2               HeI5876      5.842       2.1     -32    29
# Comp:  2          [OIII]5007_d      78.33       5.7     -32    29
# Comp:  2            [OI]6300_d      2.116       2.0     -32    29
# Comp:  2           [NII]6583_d      39.95       3.6     -32    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97       198
#  comp.  1:       -34        32
#  comp.  2:       -31        44
# chi2/DOF: 0.01310; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.19       5.2     -34    32
# Comp:  1                 Hbeta      44.69       4.5     -34    32
# Comp:  1                Halpha      157.2       5.7     -34    32
# Comp:  1          [SII]6731_d1      5.320       5.2     -34    32
# Comp:  1          [SII]6731_d2      19.14       5.6     -34    32
# Comp:  2              HeII4687     0.4703       3.1     -31    44
# Comp:  2               HeI5876      5.748       2.2     -31    44
# Comp:  2          [OIII]5007_d      82.86       5.8     -31    44
# Comp:  2            [OI]6300_d      2.091       2.1     -31    44
# Comp:  2           [NII]6583_d      42.33       3.7     -31    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -174         1
#  comp.  1:       -34        23
#  comp.  2:       -34        25
# chi2/DOF: 0.01351; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.54       5.1     -34    23
# Comp:  1                 Hbeta      47.29       4.4     -34    23
# Comp:  1                Halpha      152.9       5.7     -34    23
# Comp:  1          [SII]6731_d1      3.983       5.2     -34    23
# Comp:  1          [SII]6731_d2      19.88       5.5     -34    23
# Comp:  2              HeII4687     0.4001       3.0     -34    25
# Comp:  2               HeI5876      5.835       2.1     -34    25
# Comp:  2          [OIII]5007_d      74.60       5.6     -34    25
# Comp:  2            [OI]6300_d      1.676       2.0     -34    25
# Comp:  2           [NII]6583_d      42.62       3.5     -34    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -181         1
#  comp.  1:       -30        21
#  comp.  2:       -36        34
# chi2/DOF: 0.01254; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.44       5.1     -30    21
# Comp:  1                 Hbeta      44.54       4.4     -30    21
# Comp:  1                Halpha      145.7       5.7     -30    21
# Comp:  1          [SII]6731_d1      6.486       5.1     -30    21
# Comp:  1          [SII]6731_d2      17.46       5.5     -30    21
# Comp:  2              HeII4687     0.1970       3.0     -36    34
# Comp:  2               HeI5876      5.314       2.1     -36    34
# Comp:  2          [OIII]5007_d      78.42       5.7     -36    34
# Comp:  2            [OI]6300_d      2.035       2.0     -36    34
# Comp:  2           [NII]6583_d      42.80       3.6     -36    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -184         1
#  comp.  1:       -31        12
#  comp.  2:       -30        41
# chi2/DOF: 0.01284; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.60       5.0     -31    12
# Comp:  1                 Hbeta      45.39       4.3     -31    12
# Comp:  1                Halpha      148.4       5.7     -31    12
# Comp:  1          [SII]6731_d1      6.376       5.1     -31    12
# Comp:  1          [SII]6731_d2      16.17       5.5     -31    12
# Comp:  2              HeII4687     0.3682       3.1     -30    41
# Comp:  2               HeI5876      6.183       2.2     -30    41
# Comp:  2          [OIII]5007_d      79.74       5.8     -30    41
# Comp:  2            [OI]6300_d      1.844       2.1     -30    41
# Comp:  2           [NII]6583_d      43.72       3.6     -30    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -193         1
#  comp.  1:       -34        20
#  comp.  2:       -30        36
# chi2/DOF: 0.01334; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.79       5.1     -34    20
# Comp:  1                 Hbeta      52.12       4.4     -34    20
# Comp:  1                Halpha      156.8       5.7     -34    20
# Comp:  1          [SII]6731_d1      5.397       5.1     -34    20
# Comp:  1          [SII]6731_d2      17.97       5.5     -34    20
# Comp:  2              HeII4687     0.3984       3.1     -30    36
# Comp:  2               HeI5876      5.650       2.1     -30    36
# Comp:  2          [OIII]5007_d      82.98       5.7     -30    36
# Comp:  2            [OI]6300_d      2.104       2.1     -30    36
# Comp:  2           [NII]6583_d      42.53       3.6     -30    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -205         1
#  comp.  1:       -33        22
#  comp.  2:       -24        34
# chi2/DOF: 0.01277; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.99       5.1     -33    22
# Comp:  1                 Hbeta      43.25       4.4     -33    22
# Comp:  1                Halpha      152.0       5.7     -33    22
# Comp:  1          [SII]6731_d1      6.001       5.1     -33    22
# Comp:  1          [SII]6731_d2      19.08       5.5     -33    22
# Comp:  2              HeII4687     0.4468       3.0     -24    34
# Comp:  2               HeI5876      5.397       2.1     -24    34
# Comp:  2          [OIII]5007_d      85.38       5.7     -24    34
# Comp:  2            [OI]6300_d      1.854       2.0     -24    34
# Comp:  2           [NII]6583_d      42.29       3.6     -24    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        52       219
#  comp.  1:       -35        30
#  comp.  2:       -34        43
# chi2/DOF: 0.01323; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.12       5.2     -35    30
# Comp:  1                 Hbeta      51.82       4.5     -35    30
# Comp:  1                Halpha      155.0       5.7     -35    30
# Comp:  1          [SII]6731_d1      3.214       5.2     -35    30
# Comp:  1          [SII]6731_d2      19.60       5.6     -35    30
# Comp:  2              HeII4687     0.1779       3.1     -34    43
# Comp:  2               HeI5876      6.208       2.2     -34    43
# Comp:  2          [OIII]5007_d      84.33       5.8     -34    43
# Comp:  2            [OI]6300_d      1.988       2.1     -34    43
# Comp:  2           [NII]6583_d      42.77       3.6     -34    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -190         1
#  comp.  1:       -35        23
#  comp.  2:       -32        41
# chi2/DOF: 0.01368; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.67       5.1     -35    23
# Comp:  1                 Hbeta      43.45       4.4     -35    23
# Comp:  1                Halpha      151.9       5.7     -35    23
# Comp:  1          [SII]6731_d1      2.764       5.2     -35    23
# Comp:  1          [SII]6731_d2      20.90       5.5     -35    23
# Comp:  2              HeII4687     0.4453       3.1     -32    41
# Comp:  2               HeI5876      6.393       2.2     -32    41
# Comp:  2          [OIII]5007_d      82.41       5.8     -32    41
# Comp:  2            [OI]6300_d      1.897       2.1     -32    41
# Comp:  2           [NII]6583_d      43.27       3.6     -32    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7       187
#  comp.  1:       -36        34
#  comp.  2:       -28        37
# chi2/DOF: 0.01204; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.99       5.2     -36    34
# Comp:  1                 Hbeta      44.40       4.5     -36    34
# Comp:  1                Halpha      151.0       5.7     -36    34
# Comp:  1          [SII]6731_d1      5.321       5.3     -36    34
# Comp:  1          [SII]6731_d2      17.18       5.6     -36    34
# Comp:  2              HeII4687     0.3335       3.1     -28    37
# Comp:  2               HeI5876      6.097       2.1     -28    37
# Comp:  2          [OIII]5007_d      82.32       5.7     -28    37
# Comp:  2            [OI]6300_d      2.066       2.1     -28    37
# Comp:  2           [NII]6583_d      44.98       3.6     -28    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100         1
#  comp.  1:       -35        26
#  comp.  2:       -28        32
# chi2/DOF: 0.01372; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.12       5.1     -35    26
# Comp:  1                 Hbeta      50.20       4.4     -35    26
# Comp:  1                Halpha      151.5       5.7     -35    26
# Comp:  1          [SII]6731_d1      2.548       5.2     -35    26
# Comp:  1          [SII]6731_d2      20.81       5.6     -35    26
# Comp:  2              HeII4687     0.2260       3.0     -28    32
# Comp:  2               HeI5876      6.430       2.1     -28    32
# Comp:  2          [OIII]5007_d      84.06       5.7     -28    32
# Comp:  2            [OI]6300_d      1.858       2.0     -28    32
# Comp:  2           [NII]6583_d      40.40       3.6     -28    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -205         1
#  comp.  1:       -35        22
#  comp.  2:       -36        33
# chi2/DOF: 0.01324; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.22       5.1     -35    22
# Comp:  1                 Hbeta      42.92       4.4     -35    22
# Comp:  1                Halpha      151.5       5.7     -35    22
# Comp:  1          [SII]6731_d1      3.912       5.1     -35    22
# Comp:  1          [SII]6731_d2      19.84       5.5     -35    22
# Comp:  2              HeII4687     0.6805       3.0     -36    33
# Comp:  2               HeI5876      5.669       2.1     -36    33
# Comp:  2          [OIII]5007_d      83.98       5.7     -36    33
# Comp:  2            [OI]6300_d      1.885       2.0     -36    33
# Comp:  2           [NII]6583_d      42.98       3.6     -36    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -189         1
#  comp.  1:       -32        22
#  comp.  2:       -33        32
# chi2/DOF: 0.01403; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.55       5.1     -32    22
# Comp:  1                 Hbeta      49.36       4.4     -32    22
# Comp:  1                Halpha      153.8       5.7     -32    22
# Comp:  1          [SII]6731_d1      7.032       5.1     -32    22
# Comp:  1          [SII]6731_d2      17.22       5.5     -32    22
# Comp:  2              HeII4687     0.3599       3.0     -33    32
# Comp:  2               HeI5876      5.906       2.1     -33    32
# Comp:  2          [OIII]5007_d      79.05       5.7     -33    32
# Comp:  2            [OI]6300_d      1.821       2.0     -33    32
# Comp:  2           [NII]6583_d      43.48       3.6     -33    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28        90
#  comp.  1:       -34        25
#  comp.  2:       -38        40
# chi2/DOF: 0.01213; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.87       5.1     -34    25
# Comp:  1                 Hbeta      40.11       4.4     -34    25
# Comp:  1                Halpha      151.7       5.7     -34    25
# Comp:  1          [SII]6731_d1      7.781       5.2     -34    25
# Comp:  1          [SII]6731_d2      15.27       5.6     -34    25
# Comp:  2              HeII4687     0.1770       3.1     -38    40
# Comp:  2               HeI5876      6.203       2.1     -38    40
# Comp:  2          [OIII]5007_d      77.60       5.8     -38    40
# Comp:  2            [OI]6300_d      1.858       2.1     -38    40
# Comp:  2           [NII]6583_d      40.06       3.6     -38    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -125         1
#  comp.  1:       -34        33
#  comp.  2:       -31        39
# chi2/DOF: 0.01252; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.75       5.2     -34    33
# Comp:  1                 Hbeta      54.88       4.5     -34    33
# Comp:  1                Halpha      153.4       5.7     -34    33
# Comp:  1          [SII]6731_d1      5.144       5.2     -34    33
# Comp:  1          [SII]6731_d2      16.79       5.6     -34    33
# Comp:  2              HeII4687     0.4058       3.1     -31    39
# Comp:  2               HeI5876      6.246       2.2     -31    39
# Comp:  2          [OIII]5007_d      82.66       5.8     -31    39
# Comp:  2            [OI]6300_d      2.175       2.1     -31    39
# Comp:  2           [NII]6583_d      42.16       3.6     -31    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -163         1
#  comp.  1:       -30        19
#  comp.  2:       -35        32
# chi2/DOF: 0.01278; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.02       5.1     -30    19
# Comp:  1                 Hbeta      45.40       4.4     -30    19
# Comp:  1                Halpha      150.9       5.7     -30    19
# Comp:  1          [SII]6731_d1      6.335       5.1     -30    19
# Comp:  1          [SII]6731_d2      18.48       5.5     -30    19
# Comp:  2              HeII4687     0.1746       3.0     -35    32
# Comp:  2               HeI5876      6.073       2.1     -35    32
# Comp:  2          [OIII]5007_d      75.04       5.7     -35    32
# Comp:  2            [OI]6300_d      2.147       2.0     -35    32
# Comp:  2           [NII]6583_d      41.87       3.6     -35    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -187         1
#  comp.  1:       -34        18
#  comp.  2:       -30        28
# chi2/DOF: 0.01286; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.61       5.0     -34    18
# Comp:  1                 Hbeta      40.09       4.4     -34    18
# Comp:  1                Halpha      155.3       5.7     -34    18
# Comp:  1          [SII]6731_d1      4.467       5.1     -34    18
# Comp:  1          [SII]6731_d2      19.17       5.5     -34    18
# Comp:  2              HeII4687     0.1726       3.0     -30    28
# Comp:  2               HeI5876      6.354       2.1     -30    28
# Comp:  2          [OIII]5007_d      78.94       5.6     -30    28
# Comp:  2            [OI]6300_d      2.025       2.0     -30    28
# Comp:  2           [NII]6583_d      42.87       3.6     -30    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -191         1
#  comp.  1:       -34        15
#  comp.  2:       -31        34
# chi2/DOF: 0.01338; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.23       5.0     -34    15
# Comp:  1                 Hbeta      48.32       4.4     -34    15
# Comp:  1                Halpha      149.3       5.7     -34    15
# Comp:  1          [SII]6731_d1      3.961       5.1     -34    15
# Comp:  1          [SII]6731_d2      19.46       5.5     -34    15
# Comp:  2              HeII4687     0.4181       3.0     -31    34
# Comp:  2               HeI5876      6.475       2.1     -31    34
# Comp:  2          [OIII]5007_d      79.59       5.7     -31    34
# Comp:  2            [OI]6300_d      1.872       2.0     -31    34
# Comp:  2           [NII]6583_d      44.10       3.6     -31    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -174        14
#  comp.  1:       -34        16
#  comp.  2:       -28        40
# chi2/DOF: 0.01288; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.52       5.0     -34    16
# Comp:  1                 Hbeta      49.20       4.4     -34    16
# Comp:  1                Halpha      155.4       5.7     -34    16
# Comp:  1          [SII]6731_d1     0.8440       5.1     -34    16
# Comp:  1          [SII]6731_d2      22.69       5.5     -34    16
# Comp:  2              HeII4687     0.4434       3.1     -28    40
# Comp:  2               HeI5876      6.617       2.2     -28    40
# Comp:  2          [OIII]5007_d      85.15       5.8     -28    40
# Comp:  2            [OI]6300_d      1.774       2.1     -28    40
# Comp:  2           [NII]6583_d      42.05       3.6     -28    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -198         1
#  comp.  1:       -34        21
#  comp.  2:       -34        33
# chi2/DOF: 0.01299; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.53       5.1     -34    21
# Comp:  1                 Hbeta      42.43       4.4     -34    21
# Comp:  1                Halpha      156.9       5.7     -34    21
# Comp:  1          [SII]6731_d1      7.120       5.1     -34    21
# Comp:  1          [SII]6731_d2      15.47       5.5     -34    21
# Comp:  2              HeII4687     0.1544       3.0     -34    33
# Comp:  2               HeI5876      5.559       2.1     -34    33
# Comp:  2          [OIII]5007_d      77.35       5.7     -34    33
# Comp:  2            [OI]6300_d      1.778       2.0     -34    33
# Comp:  2           [NII]6583_d      44.18       3.6     -34    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        94
#  comp.  1:       -36        33
#  comp.  2:       -33        32
# chi2/DOF: 0.01180; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.52       5.2     -36    33
# Comp:  1                 Hbeta      44.18       4.5     -36    33
# Comp:  1                Halpha      155.9       5.7     -36    33
# Comp:  1          [SII]6731_d1      1.805       5.3     -36    33
# Comp:  1          [SII]6731_d2      22.98       5.6     -36    33
# Comp:  2              HeII4687     0.4617       3.0     -33    32
# Comp:  2               HeI5876      6.198       2.1     -33    32
# Comp:  2          [OIII]5007_d      82.27       5.7     -33    32
# Comp:  2            [OI]6300_d      1.848       2.0     -33    32
# Comp:  2           [NII]6583_d      43.89       3.6     -33    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -147        21
#  comp.  1:       -35        34
#  comp.  2:       -28        32
# chi2/DOF: 0.01280; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.77       5.2     -35    34
# Comp:  1                 Hbeta      47.02       4.5     -35    34
# Comp:  1                Halpha      153.2       5.7     -35    34
# Comp:  1          [SII]6731_d1      6.526       5.3     -35    34
# Comp:  1          [SII]6731_d2      18.82       5.7     -35    34
# Comp:  2              HeII4687     0.3573       3.0     -28    32
# Comp:  2               HeI5876      6.203       2.1     -28    32
# Comp:  2          [OIII]5007_d      79.68       5.7     -28    32
# Comp:  2            [OI]6300_d      1.813       2.0     -28    32
# Comp:  2           [NII]6583_d      41.10       3.6     -28    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -184         1
#  comp.  1:       -32        21
#  comp.  2:       -30        39
# chi2/DOF: 0.01334; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.42       5.1     -32    21
# Comp:  1                 Hbeta      44.20       4.4     -32    21
# Comp:  1                Halpha      151.8       5.7     -32    21
# Comp:  1          [SII]6731_d1      1.897       5.1     -32    21
# Comp:  1          [SII]6731_d2      22.72       5.5     -32    21
# Comp:  2              HeII4687     0.6417       3.1     -30    39
# Comp:  2               HeI5876      5.222       2.2     -30    39
# Comp:  2          [OIII]5007_d      85.58       5.8     -30    39
# Comp:  2            [OI]6300_d      2.167       2.1     -30    39
# Comp:  2           [NII]6583_d      40.20       3.6     -30    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16       302
#  comp.  1:       -35        33
#  comp.  2:       -31        29
# chi2/DOF: 0.01280; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.03       5.2     -35    33
# Comp:  1                 Hbeta      44.85       4.5     -35    33
# Comp:  1                Halpha      157.0       5.7     -35    33
# Comp:  1          [SII]6731_d1      5.791       5.2     -35    33
# Comp:  1          [SII]6731_d2      17.10       5.6     -35    33
# Comp:  2              HeII4687     0.6850       3.0     -31    29
# Comp:  2               HeI5876      5.774       2.1     -31    29
# Comp:  2          [OIII]5007_d      79.74       5.7     -31    29
# Comp:  2            [OI]6300_d      1.948       2.0     -31    29
# Comp:  2           [NII]6583_d      41.46       3.6     -31    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -186        21
#  comp.  1:       -32        13
#  comp.  2:       -27        42
# chi2/DOF: 0.01230; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.20       5.0     -32    13
# Comp:  1                 Hbeta      47.00       4.4     -32    13
# Comp:  1                Halpha      148.6       5.7     -32    13
# Comp:  1          [SII]6731_d1      3.122       5.1     -32    13
# Comp:  1          [SII]6731_d2      21.42       5.5     -32    13
# Comp:  2              HeII4687     0.3495       3.1     -27    42
# Comp:  2               HeI5876      5.435       2.2     -27    42
# Comp:  2          [OIII]5007_d      87.33       5.8     -27    42
# Comp:  2            [OI]6300_d      2.182       2.1     -27    42
# Comp:  2           [NII]6583_d      42.74       3.6     -27    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -183         1
#  comp.  1:       -32        26
#  comp.  2:       -30        34
# chi2/DOF: 0.01395; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.74       5.1     -32    26
# Comp:  1                 Hbeta      46.45       4.4     -32    26
# Comp:  1                Halpha      149.3       5.7     -32    26
# Comp:  1          [SII]6731_d1      8.155       5.2     -32    26
# Comp:  1          [SII]6731_d2      15.20       5.6     -32    26
# Comp:  2              HeII4687     0.1957       3.0     -30    34
# Comp:  2               HeI5876      6.587       2.1     -30    34
# Comp:  2          [OIII]5007_d      82.57       5.7     -30    34
# Comp:  2            [OI]6300_d      2.084       2.0     -30    34
# Comp:  2           [NII]6583_d      43.15       3.6     -30    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -130         1
#  comp.  1:       -35        32
#  comp.  2:       -27        39
# chi2/DOF: 0.01272; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.24       5.2     -35    32
# Comp:  1                 Hbeta      52.15       4.5     -35    32
# Comp:  1                Halpha      151.7       5.7     -35    32
# Comp:  1          [SII]6731_d1      1.699       5.2     -35    32
# Comp:  1          [SII]6731_d2      22.54       5.6     -35    32
# Comp:  2              HeII4687     0.7291       3.1     -27    39
# Comp:  2               HeI5876      6.212       2.2     -27    39
# Comp:  2          [OIII]5007_d      78.60       5.8     -27    39
# Comp:  2            [OI]6300_d      1.960       2.1     -27    39
# Comp:  2           [NII]6583_d      43.43       3.6     -27    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -166         1
#  comp.  1:       -31        23
#  comp.  2:       -31        34
# chi2/DOF: 0.01278; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.82       5.1     -31    23
# Comp:  1                 Hbeta      53.82       4.4     -31    23
# Comp:  1                Halpha      153.9       5.7     -31    23
# Comp:  1          [SII]6731_d1      4.870       5.1     -31    23
# Comp:  1          [SII]6731_d2      18.35       5.5     -31    23
# Comp:  2              HeII4687     0.4748       3.0     -31    34
# Comp:  2               HeI5876      6.632       2.1     -31    34
# Comp:  2          [OIII]5007_d      86.53       5.7     -31    34
# Comp:  2            [OI]6300_d      2.101       2.0     -31    34
# Comp:  2           [NII]6583_d      43.84       3.6     -31    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -190        74
#  comp.  1:       -36        29
#  comp.  2:       -32        46
# chi2/DOF: 0.01212; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.52       5.2     -36    29
# Comp:  1                 Hbeta      43.96       4.5     -36    29
# Comp:  1                Halpha      158.6       5.7     -36    29
# Comp:  1          [SII]6731_d1      4.893       5.2     -36    29
# Comp:  1          [SII]6731_d2      21.10       5.6     -36    29
# Comp:  2              HeII4687     0.5125       3.2     -32    46
# Comp:  2               HeI5876      6.319       2.2     -32    46
# Comp:  2          [OIII]5007_d      86.21       5.8     -32    46
# Comp:  2            [OI]6300_d      1.956       2.1     -32    46
# Comp:  2           [NII]6583_d      43.81       3.7     -32    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -123         1
#  comp.  1:       -32        31
#  comp.  2:       -36        39
# chi2/DOF: 0.01240; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.90       5.2     -32    31
# Comp:  1                 Hbeta      54.40       4.5     -32    31
# Comp:  1                Halpha      150.2       5.7     -32    31
# Comp:  1          [SII]6731_d1      6.585       5.2     -32    31
# Comp:  1          [SII]6731_d2      16.13       5.6     -32    31
# Comp:  2              HeII4687     0.1930       3.1     -36    39
# Comp:  2               HeI5876      5.394       2.1     -36    39
# Comp:  2          [OIII]5007_d      77.89       5.8     -36    39
# Comp:  2            [OI]6300_d      2.029       2.1     -36    39
# Comp:  2           [NII]6583_d      42.77       3.6     -36    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -125         1
#  comp.  1:       -35        32
#  comp.  2:       -35        25
# chi2/DOF: 0.01257; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.81       5.2     -35    32
# Comp:  1                 Hbeta      48.17       4.5     -35    32
# Comp:  1                Halpha      150.9       5.7     -35    32
# Comp:  1          [SII]6731_d1      7.144       5.2     -35    32
# Comp:  1          [SII]6731_d2      17.73       5.6     -35    32
# Comp:  2              HeII4687     0.2503       3.0     -35    25
# Comp:  2               HeI5876      5.455       2.1     -35    25
# Comp:  2          [OIII]5007_d      82.46       5.6     -35    25
# Comp:  2            [OI]6300_d      2.128       2.0     -35    25
# Comp:  2           [NII]6583_d      41.52       3.5     -35    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -178         1
#  comp.  1:       -31        13
#  comp.  2:       -29        43
# chi2/DOF: 0.01235; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.57       5.0     -31    13
# Comp:  1                 Hbeta      46.94       4.4     -31    13
# Comp:  1                Halpha      149.9       5.7     -31    13
# Comp:  1          [SII]6731_d1      4.302       5.1     -31    13
# Comp:  1          [SII]6731_d2      19.34       5.5     -31    13
# Comp:  2              HeII4687     0.1569       3.1     -29    43
# Comp:  2               HeI5876      5.786       2.2     -29    43
# Comp:  2          [OIII]5007_d      83.47       5.8     -29    43
# Comp:  2            [OI]6300_d      1.908       2.1     -29    43
# Comp:  2           [NII]6583_d      43.97       3.6     -29    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -195         1
#  comp.  1:       -30        22
#  comp.  2:       -34        28
# chi2/DOF: 0.01185; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.36       5.1     -30    22
# Comp:  1                 Hbeta      40.60       4.4     -30    22
# Comp:  1                Halpha      146.8       5.7     -30    22
# Comp:  1          [SII]6731_d1      2.056       5.1     -30    22
# Comp:  1          [SII]6731_d2      20.64       5.5     -30    22
# Comp:  2              HeII4687     0.2381       3.0     -34    28
# Comp:  2               HeI5876      5.521       2.1     -34    28
# Comp:  2          [OIII]5007_d      80.29       5.6     -34    28
# Comp:  2            [OI]6300_d      1.803       2.0     -34    28
# Comp:  2           [NII]6583_d      43.38       3.6     -34    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -201         1
#  comp.  1:       -34        23
#  comp.  2:       -26        35
# chi2/DOF: 0.01314; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.60       5.1     -34    23
# Comp:  1                 Hbeta      49.74       4.4     -34    23
# Comp:  1                Halpha      152.9       5.7     -34    23
# Comp:  1          [SII]6731_d1      4.315       5.2     -34    23
# Comp:  1          [SII]6731_d2      21.21       5.5     -34    23
# Comp:  2              HeII4687     0.3867       3.0     -26    35
# Comp:  2               HeI5876      5.733       2.1     -26    35
# Comp:  2          [OIII]5007_d      85.68       5.7     -26    35
# Comp:  2            [OI]6300_d      1.775       2.1     -26    35
# Comp:  2           [NII]6583_d      42.04       3.6     -26    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -208         1
#  comp.  1:       -31        22
#  comp.  2:       -30        31
# chi2/DOF: 0.01315; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.09       5.1     -31    22
# Comp:  1                 Hbeta      40.66       4.4     -31    22
# Comp:  1                Halpha      150.7       5.7     -31    22
# Comp:  1          [SII]6731_d1      8.130       5.1     -31    22
# Comp:  1          [SII]6731_d2      15.48       5.5     -31    22
# Comp:  2              HeII4687     0.6469       3.0     -30    31
# Comp:  2               HeI5876      5.477       2.1     -30    31
# Comp:  2          [OIII]5007_d      80.10       5.7     -30    31
# Comp:  2            [OI]6300_d      2.038       2.0     -30    31
# Comp:  2           [NII]6583_d      41.88       3.6     -30    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -171        38
#  comp.  1:       -36        33
#  comp.  2:       -26        38
# chi2/DOF: 0.01237; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.28       5.2     -36    33
# Comp:  1                 Hbeta      48.62       4.5     -36    33
# Comp:  1                Halpha      157.0       5.7     -36    33
# Comp:  1          [SII]6731_d1      4.247       5.3     -36    33
# Comp:  1          [SII]6731_d2      19.65       5.6     -36    33
# Comp:  2              HeII4687     0.5381       3.1     -26    38
# Comp:  2               HeI5876      5.928       2.2     -26    38
# Comp:  2          [OIII]5007_d      77.38       5.8     -26    38
# Comp:  2            [OI]6300_d      1.772       2.1     -26    38
# Comp:  2           [NII]6583_d      42.93       3.6     -26    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -206         1
#  comp.  1:       -32        15
#  comp.  2:       -32        31
# chi2/DOF: 0.01214; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
#  Best Fit:       Vel     sigma
#  comp.  0:      -186         1
#  comp.  1:       -33        22
#  comp.  2:       -29        37
# chi2/DOF: 0.01376; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.38       5.1     -33    22
# Comp:  1                 Hbeta      46.44       4.4     -33    22
# Comp:  1                Halpha      151.8       5.7     -33    22
# Comp:  1          [SII]6731_d1      4.505       5.1     -33    22
# Comp:  1          [SII]6731_d2      19.64       5.5     -33    22
# Comp:  2              HeII4687     0.4876       3.1     -29    37
# Comp:  2               HeI5876      5.626       2.1     -29    37
# Comp:  2          [OIII]5007_d      87.07       5.7     -29    37
# Comp:  2            [OI]6300_d      2.086       2.1     -29    37
# Comp:  2           [NII]6583_d      45.66       3.6     -29    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -175         1
#  comp.  1:       -31        23
#  comp.  2:       -32        37
# chi2/DOF: 0.01372; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.65       5.1     -31    23
# Comp:  1                 Hbeta      51.51       4.4     -31    23
# Comp:  1                Halpha      154.0       5.7     -31    23
# Comp:  1          [SII]6731_d1      3.161       5.1     -31    23
# Comp:  1          [SII]6731_d2      20.07       5.5     -31    23
# Comp:  2              HeII4687     0.4091       3.1     -32    37
# Comp:  2               HeI5876      6.158       2.1     -32    37
# Comp:  2          [OIII]5007_d      81.95       5.7     -32    37
# Comp:  2            [OI]6300_d      1.958       2.1     -32    37
# Comp:  2           [NII]6583_d      44.56       3.6     -32    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -182         1
#  comp.  1:       -32        20
#  comp.  2:       -35        32
# chi2/DOF: 0.01363; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.76       5.1     -32    20
# Comp:  1                 Hbeta      45.45       4.4     -32    20
# Comp:  1                Halpha      152.4       5.7     -32    20
# Comp:  1          [SII]6731_d1      6.468       5.1     -32    20
# Comp:  1          [SII]6731_d2      15.80       5.5     -32    20
# Comp:  2              HeII4687     0.2427       3.0     -35    32
# Comp:  2               HeI5876      5.055       2.1     -35    32
# Comp:  2          [OIII]5007_d      75.80       5.7     -35    32
# Comp:  2            [OI]6300_d      1.699       2.0     -35    32
# Comp:  2           [NII]6583_d      41.06       3.6     -35    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -199         1
#  comp.  1:       -32        15
#  comp.  2:       -29        33
# chi2/DOF: 0.01320; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.84       5.0     -32    15
# Comp:  1                 Hbeta      48.83       4.4     -32    15
# Comp:  1                Halpha      149.9       5.7     -32    15
# Comp:  1          [SII]6731_d1      2.593       5.1     -32    15
# Comp:  1          [SII]6731_d2      19.94       5.5     -32    15
# Comp:  2              HeII4687     0.2428       3.0     -29    33
# Comp:  2               HeI5876      5.961       2.1     -29    33
# Comp:  2          [OIII]5007_d      80.88       5.7     -29    33
# Comp:  2            [OI]6300_d      1.936       2.0     -29    33
# Comp:  2           [NII]6583_d      43.33       3.6     -29    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -171         1
#  comp.  1:       -34        21
#  comp.  2:       -35        31
# chi2/DOF: 0.01350; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.01       5.1     -34    21
# Comp:  1                 Hbeta      49.04       4.4     -34    21
# Comp:  1                Halpha      152.5       5.7     -34    21
# Comp:  1          [SII]6731_d1      4.545       5.1     -34    21
# Comp:  1          [SII]6731_d2      18.35       5.5     -34    21
# Comp:  2              HeII4687     0.1899       3.0     -35    31
# Comp:  2               HeI5876      6.306       2.1     -35    31
# Comp:  2          [OIII]5007_d      76.42       5.7     -35    31
# Comp:  2            [OI]6300_d      2.181       2.0     -35    31
# Comp:  2           [NII]6583_d      42.44       3.6     -35    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -195         1
#  comp.  1:       -33        18
#  comp.  2:       -30        37
# chi2/DOF: 0.01284; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.19       5.1     -33    18
# Comp:  1                 Hbeta      50.30       4.4     -33    18
# Comp:  1                Halpha      156.6       5.7     -33    18
# Comp:  1          [SII]6731_d1      2.914       5.1     -33    18
# Comp:  1          [SII]6731_d2      21.83       5.5     -33    18
# Comp:  2              HeII4687     0.2137       3.1     -30    37
# Comp:  2               HeI5876      5.025       2.1     -30    37
# Comp:  2          [OIII]5007_d      85.65       5.7     -30    37
# Comp:  2            [OI]6300_d      2.086       2.1     -30    37
# Comp:  2           [NII]6583_d      43.88       3.6     -30    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -156         1
#  comp.  1:       -32        16
#  comp.  2:       -30        31
# chi2/DOF: 0.01315; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.12       5.0     -32    16
# Comp:  1                 Hbeta      43.37       4.4     -32    16
# Comp:  1                Halpha      148.3       5.7     -32    16
# Comp:  1          [SII]6731_d1      2.691       5.1     -32    16
# Comp:  1          [SII]6731_d2      21.68       5.5     -32    16
# Comp:  2              HeII4687     0.6861       3.0     -30    31
# Comp:  2               HeI5876      6.064       2.1     -30    31
# Comp:  2          [OIII]5007_d      76.63       5.7     -30    31
# Comp:  2            [OI]6300_d      1.876       2.0     -30    31
# Comp:  2           [NII]6583_d      44.73       3.6     -30    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -191         1
#  comp.  1:       -34        17
#  comp.  2:       -32        39
# chi2/DOF: 0.01332; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.22       5.0     -34    17
# Comp:  1                 Hbeta      46.53       4.4     -34    17
# Comp:  1                Halpha      155.3       5.7     -34    17
# Comp:  1          [SII]6731_d1      1.593       5.1     -34    17
# Comp:  1          [SII]6731_d2      22.34       5.5     -34    17
# Comp:  2              HeII4687     0.4716       3.1     -32    39
# Comp:  2               HeI5876      6.388       2.1     -32    39
# Comp:  2          [OIII]5007_d      76.57       5.8     -32    39
# Comp:  2            [OI]6300_d      1.740       2.1     -32    39
# Comp:  2           [NII]6583_d      41.43       3.6     -32    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -208         1
#  comp.  1:       -33        23
#  comp.  2:       -29        31
# chi2/DOF: 0.01364; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.96       5.1     -33    23
# Comp:  1                 Hbeta      42.94       4.4     -33    23
# Comp:  1                Halpha      152.9       5.7     -33    23
# Comp:  1          [SII]6731_d1      7.873       5.1     -33    23
# Comp:  1          [SII]6731_d2      15.49       5.5     -33    23
# Comp:  2              HeII4687     0.6785       3.0     -29    31
# Comp:  2               HeI5876      5.282       2.1     -29    31
# Comp:  2          [OIII]5007_d      83.75       5.7     -29    31
# Comp:  2            [OI]6300_d      1.936       2.0     -29    31
# Comp:  2           [NII]6583_d      42.28       3.6     -29    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -186         1
#  comp.  1:       -30        19
#  comp.  2:       -35        27
# chi2/DOF: 0.01233; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.27       5.1     -30    19
# Comp:  1                 Hbeta      43.98       4.4     -30    19
# Comp:  1                Halpha      154.0       5.7     -30    19
# Comp:  1          [SII]6731_d1      7.330       5.1     -30    19
# Comp:  1          [SII]6731_d2      16.92       5.5     -30    19
# Comp:  2              HeII4687     0.4512       3.0     -35    27
# Comp:  2               HeI5876      5.391       2.1     -35    27
# Comp:  2          [OIII]5007_d      82.64       5.6     -35    27
# Comp:  2            [OI]6300_d      1.805       2.0     -35    27
# Comp:  2           [NII]6583_d      43.19       3.6     -35    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -175         1
#  comp.  1:       -33        20
#  comp.  2:       -34        33
# chi2/DOF: 0.01297; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.14       5.1     -33    20
# Comp:  1                 Hbeta      53.02       4.4     -33    20
# Comp:  1                Halpha      151.8       5.7     -33    20
# Comp:  1          [SII]6731_d1      6.414       5.1     -33    20
# Comp:  1          [SII]6731_d2      16.18       5.5     -33    20
# Comp:  2              HeII4687     0.6367       3.0     -34    33
# Comp:  2               HeI5876      6.868       2.1     -34    33
# Comp:  2          [OIII]5007_d      78.89       5.7     -34    33
# Comp:  2            [OI]6300_d      1.987       2.0     -34    33
# Comp:  2           [NII]6583_d      42.94       3.6     -34    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -188         1
#  comp.  1:       -34        21
#  comp.  2:       -32        40
# chi2/DOF: 0.01331; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.54       5.1     -34    21
# Comp:  1                 Hbeta      46.33       4.4     -34    21
# Comp:  1                Halpha      147.7       5.7     -34    21
# Comp:  1          [SII]6731_d1      2.978       5.1     -34    21
# Comp:  1          [SII]6731_d2      20.19       5.5     -34    21
# Comp:  2              HeII4687     0.4482       3.1     -32    40
# Comp:  2               HeI5876      5.519       2.2     -32    40
# Comp:  2          [OIII]5007_d      76.36       5.8     -32    40
# Comp:  2            [OI]6300_d      1.792       2.1     -32    40
# Comp:  2           [NII]6583_d      42.32       3.6     -32    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89         1
#  comp.  1:       -33        28
#  comp.  2:       -31        43
# chi2/DOF: 0.01347; DOF: 2396; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.20       5.2     -33    28
# Comp:  1                 Hbeta      51.13       4.5     -33    28
# Comp:  1                Halpha      148.8       5.7     -33    28
# Comp:  1          [SII]6731_d1      3.901       5.2     -33    28
# Comp:  1          [SII]6731_d2      17.84       5.6     -33    28
# Comp:  2              HeII4687     0.4083       3.1     -31    43
# Comp:  2               HeI5876      6.050       2.2     -31    43
# Comp:  2          [OIII]5007_d      82.21       5.8     -31    43
# Comp:  2            [OI]6300_d      1.990       2.1     -31    43
# Comp:  2           [NII]6583_d      45.58       3.6     -31    43
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*np.median(flux_rf_rebin)
        error = flux_err_boot[i]*np.median(error_rf_rebin)
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 18.27613892,  47.51166191, 208.9069644 ,   6.53272656,
#         26.82922914,   0.42770294,   7.35544888,  84.64728203,
#          2.60120434,  58.82858078])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*np.median(flux_rf_rebin), 'Error flux': flux_err_boot*np.median(error_rf_rebin)}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_1_gas_ppxf.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_1", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_1_kin.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_1_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_1_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0        Hgamma   5.730081    0.056809
# 1         Hbeta  14.896236    0.109881
# 2        Halpha  65.498181    0.143022
# 3  [SII]6731_d1   2.048193    0.074586
# 4  [SII]6731_d2   8.411714    0.088841
# 5      HeII4687   0.134097    0.004561
# 6       HeI5876   2.306139    0.016195
# 7  [OIII]5007_d  26.539292    0.111215
# 8    [OI]6300_d   0.815550    0.005336
# 9   [NII]6583_d  18.444407    0.055114
#             Name       Flux  Error_flux
# 0         Hgamma   5.730081    0.056809
# 1          Hbeta  14.896236    0.109881
# 2         Halpha  65.498181    0.143022
# 3   [SII]6731_d1   2.048193    0.074586
# 4   [SII]6731_d2   8.411714    0.088841
# 5       HeII4687   0.134097    0.004561
# 6        HeI5876   2.306139    0.016195
# 7     [OIII]4959   6.634823    0.111215
# 8     [OIII]5007  19.904469    0.111215
# 9       [OI]6300   0.611663    0.005336
# 10      [OI]6364   0.203888    0.005336
# 11     [NII]6548   4.611102    0.055114
# 12     [NII]6583  13.833305    0.055114

# %%
np.median(flux_rf_rebin)
# Out:
# 0.31352799178036483
