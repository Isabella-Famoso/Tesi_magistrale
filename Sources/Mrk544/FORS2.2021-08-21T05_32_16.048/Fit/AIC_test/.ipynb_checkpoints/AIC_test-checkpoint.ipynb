# %%
# %matplotlib widget

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_544/FORS2.2021-08-21T05_32_16.048/Reduced/Mrk-544_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_544/FORS2.2021-08-21T05_32_16.048/Reduced/Mrk-544_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     365   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        46   (2094, 964)   float32

# %%
image_cut = image[55:155, 0:1890]
image_error_cut = image_error[55:155, 0:1890]

# %%
wavelengths = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wavelengths, y)
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
z = 0.0238
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_544/FORS2.2021-08-21T05_32_16.048/Reduced/PSF/Real_seeing_Mrk544.txt")
sigma = seeing[0] / 2.35

# %%
l_HA
# Out:
# 6719.1994

# %%
#Ogni punto del flusso è il risultato della somma di 20 lunghezze d'onda 
mask_HA = (wavelengths > l_HA-8)*(wavelengths < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

#Define the function for the aic
#Per l'AIC test usiamo il chi quadro perchè il numero di conteggi è elevato (S/N grande) 
#quindi Poisson --> Gauss
#def chi_quad(x, y, y_err, params):
#    return np.sum((((y - model_convolved(x, *params)) / y_err)**2))
    
def AIC(x, y, chi, params): #k=number of model parameter, N=number of data points
    return chi + 2*len(params) +((2*len(params)*(len(params)+1))/(len(y)-len(params)-1))

def BIC(x, y, chi, params):
        return chi + len(params)*np.log(len(y))
    
def sersic_1d_convolved(x, I_e, r_e, n, x_0):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def save_params(params_curve, covariance, radial_profile, radial_profile_error, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, chi2

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params) 
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 0.1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (30, 40),   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params1 = result.x

print("Optimize parameters with differential_evolution:", best_params1)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 204.297631850992
# differential_evolution step 2: f(x)= 144.71421839234273
# differential_evolution step 3: f(x)= 126.42067511621255
# differential_evolution step 4: f(x)= 126.42067511621255
# differential_evolution step 5: f(x)= 118.75045030101298
# differential_evolution step 6: f(x)= 118.75045030101298
# differential_evolution step 7: f(x)= 117.90770285035144
# differential_evolution step 8: f(x)= 117.44847508951604
# differential_evolution step 9: f(x)= 117.44847508951604
# differential_evolution step 10: f(x)= 115.8745512159165
# differential_evolution step 11: f(x)= 115.8745512159165
# differential_evolution step 12: f(x)= 115.8745512159165
# differential_evolution step 13: f(x)= 112.74244606700634
# differential_evolution step 14: f(x)= 112.74244606700634
# differential_evolution step 15: f(x)= 112.74244606700634
# differential_evolution step 16: f(x)= 108.57071315035549
# differential_evolution step 17: f(x)= 108.57071315035549
# differential_evolution step 18: f(x)= 108.57071315035549
# differential_evolution step 19: f(x)= 108.38103685503361
# differential_evolution step 20: f(x)= 108.27032892366917
# differential_evolution step 21: f(x)= 108.27032892366917
# differential_evolution step 22: f(x)= 107.45193502527856
# differential_evolution step 23: f(x)= 107.45193502527856
# differential_evolution step 24: f(x)= 107.39081801125396
# differential_evolution step 25: f(x)= 107.39081801125396
# differential_evolution step 26: f(x)= 107.39081801125396
# differential_evolution step 27: f(x)= 107.00636418444051
# differential_evolution step 28: f(x)= 106.88149711039868
# differential_evolution step 29: f(x)= 106.88149711039868
# differential_evolution step 30: f(x)= 106.76418404959317
# differential_evolution step 31: f(x)= 106.76418404959317
# differential_evolution step 32: f(x)= 106.62194438080095
# differential_evolution step 33: f(x)= 106.62194438080095
# differential_evolution step 34: f(x)= 106.58427841555722
# differential_evolution step 35: f(x)= 106.51651426368849
# differential_evolution step 36: f(x)= 106.51651426368849
# differential_evolution step 37: f(x)= 106.51651426368849
# differential_evolution step 38: f(x)= 106.51651426368849
# differential_evolution step 39: f(x)= 106.47156950375393
# differential_evolution step 40: f(x)= 106.47156950375393
# differential_evolution step 41: f(x)= 106.47156950375393
# differential_evolution step 42: f(x)= 106.47156950375393
# differential_evolution step 43: f(x)= 106.47156950375393
# differential_evolution step 44: f(x)= 106.47153288190302
# differential_evolution step 45: f(x)= 106.4597960073657
# differential_evolution step 46: f(x)= 106.436373356117
# differential_evolution step 47: f(x)= 106.436373356117
# differential_evolution step 48: f(x)= 106.436373356117
# differential_evolution step 49: f(x)= 106.436373356117
# differential_evolution step 50: f(x)= 106.436373356117
# differential_evolution step 51: f(x)= 106.436373356117
# differential_evolution step 52: f(x)= 106.436373356117
# differential_evolution step 53: f(x)= 106.436373356117
# differential_evolution step 54: f(x)= 106.43345313082763
# differential_evolution step 55: f(x)= 106.42271414218752
# differential_evolution step 56: f(x)= 106.42271414218752
# differential_evolution step 57: f(x)= 106.42271414218752
# differential_evolution step 58: f(x)= 106.42271414218752
# differential_evolution step 59: f(x)= 106.42271414218752
# differential_evolution step 60: f(x)= 106.42271414218752
# differential_evolution step 61: f(x)= 106.42271414218752
# differential_evolution step 62: f(x)= 106.42271414218752
# differential_evolution step 63: f(x)= 106.42271414218752
# differential_evolution step 64: f(x)= 106.42118656125966
# differential_evolution step 65: f(x)= 106.42118656125966
# differential_evolution step 66: f(x)= 106.42067993096165
# differential_evolution step 67: f(x)= 106.42046533402096
# differential_evolution step 68: f(x)= 106.4203294113049
# differential_evolution step 69: f(x)= 106.42014269342987
# differential_evolution step 70: f(x)= 106.41922197228966
# differential_evolution step 71: f(x)= 106.41922197228966
# differential_evolution step 72: f(x)= 106.41849534870248
# differential_evolution step 73: f(x)= 106.41849534870248
# differential_evolution step 74: f(x)= 106.41835562643531
# differential_evolution step 75: f(x)= 106.41776988172322
# differential_evolution step 76: f(x)= 106.41776988172322
# differential_evolution step 77: f(x)= 106.41769963889806
# differential_evolution step 78: f(x)= 106.41769963889806
# differential_evolution step 79: f(x)= 106.41769963889806
# differential_evolution step 80: f(x)= 106.41769963889806
# differential_evolution step 81: f(x)= 106.41769963889806
# differential_evolution step 82: f(x)= 106.41769963889806
# differential_evolution step 83: f(x)= 106.41769963889806
# differential_evolution step 84: f(x)= 106.41766573252906
# differential_evolution step 85: f(x)= 106.41766573252906
# differential_evolution step 86: f(x)= 106.41764532143637
# differential_evolution step 87: f(x)= 106.41759011161571
# differential_evolution step 88: f(x)= 106.41759011161571
# differential_evolution step 89: f(x)= 106.41759011161571
# differential_evolution step 90: f(x)= 106.41759011161571
# differential_evolution step 91: f(x)= 106.41758576627345
# differential_evolution step 92: f(x)= 106.41758576627345
# differential_evolution step 93: f(x)= 106.41758576627345
# differential_evolution step 94: f(x)= 106.41758576627345
# differential_evolution step 95: f(x)= 106.41758576627345
# differential_evolution step 96: f(x)= 106.41758576627345
# differential_evolution step 97: f(x)= 106.41758576627345
# differential_evolution step 98: f(x)= 106.41758576627345
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [ 0.1        50.          3.54687319 36.47830824]
# Chi quadro minimo: 106.41757813444178

# %%
aic = np.zeros(6)
bic = np.zeros(6)
chi_quadr = np.zeros(6)
chi_quadro = np.zeros(6)
red_chi = np.zeros(6)

params_curve_1, covariance_1 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params1,
                                         sigma = radial_profile_error_HA, maxfev= 10000)

print("Optimize parameters with curve fit:")

chi_quadr[0], red_chi[0] = save_params(params_curve_1, covariance_1, radial_profile_HA, radial_profile_error_HA, x_axes, 1, line_name="One", 
                                           output_prefix="fit")

aic[0] = AIC(x_axes, radial_profile_HA, chi_quadr[0], params_curve_1)
bic[0] = BIC(x_axes, radial_profile_HA, chi_quadr[0], params_curve_1)
print(aic[0], chi_quadro[0], bic[0], len(params_curve_1))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_1)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_1), 'b--', label='Sérsic 1')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)
plt.savefig('AIC_1')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.1343, r_e=51.3328, n=3.1384, x_0=36.7782
# [ 0.13878808 37.75384972  0.82162051  0.22817212]
# 455.00566941012
# 463.42672204169895 0.0 473.42635015407234 4
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 0.1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (33, 38),   # x_0: posizione da 0 a 100   # x_0: posizione da 0 a 100
    
    (0, 0.1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (55, 65),   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params2 = result.x

print("Optimize parameters with differential_evolution:", best_params2)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 135.9610366119951
# differential_evolution step 2: f(x)= 128.55560953914002
# differential_evolution step 3: f(x)= 112.45022719987159
# differential_evolution step 4: f(x)= 112.45022719987159
# differential_evolution step 5: f(x)= 105.26951100740098
# differential_evolution step 6: f(x)= 105.26951100740098
# differential_evolution step 7: f(x)= 84.38681664957039
# differential_evolution step 8: f(x)= 49.45427155191304
# differential_evolution step 9: f(x)= 49.45427155191304
# differential_evolution step 10: f(x)= 49.45427155191304
# differential_evolution step 11: f(x)= 43.07408289838062
# differential_evolution step 12: f(x)= 43.07408289838062
# differential_evolution step 13: f(x)= 43.07408289838062
# differential_evolution step 14: f(x)= 43.07408289838062
# differential_evolution step 15: f(x)= 43.07408289838062
# differential_evolution step 16: f(x)= 43.07408289838062
# differential_evolution step 17: f(x)= 41.49943991511028
# differential_evolution step 18: f(x)= 41.49943991511028
# differential_evolution step 19: f(x)= 36.90167382431524
# differential_evolution step 20: f(x)= 36.90167382431524
# differential_evolution step 21: f(x)= 36.90167382431524
# differential_evolution step 22: f(x)= 36.90167382431524
# differential_evolution step 23: f(x)= 33.83359744192836
# differential_evolution step 24: f(x)= 33.83359744192836
# differential_evolution step 25: f(x)= 29.07298602904923
# differential_evolution step 26: f(x)= 29.07298602904923
# differential_evolution step 27: f(x)= 29.07298602904923
# differential_evolution step 28: f(x)= 29.07298602904923
# differential_evolution step 29: f(x)= 29.07298602904923
# differential_evolution step 30: f(x)= 29.07298602904923
# differential_evolution step 31: f(x)= 28.11529513734517
# differential_evolution step 32: f(x)= 27.89747070347308
# differential_evolution step 33: f(x)= 27.22740576337205
# differential_evolution step 34: f(x)= 26.570290872799244
# differential_evolution step 35: f(x)= 26.570290872799244
# differential_evolution step 36: f(x)= 26.570290872799244
# differential_evolution step 37: f(x)= 25.424161120077237
# differential_evolution step 38: f(x)= 24.694334899539253
# differential_evolution step 39: f(x)= 24.694334899539253
# differential_evolution step 40: f(x)= 24.694334899539253
# differential_evolution step 41: f(x)= 24.694334899539253
# differential_evolution step 42: f(x)= 24.694334899539253
# differential_evolution step 43: f(x)= 24.694334899539253
# differential_evolution step 44: f(x)= 24.694334899539253
# differential_evolution step 45: f(x)= 24.694334899539253
# differential_evolution step 46: f(x)= 24.694334899539253
# differential_evolution step 47: f(x)= 24.694334899539253
# differential_evolution step 48: f(x)= 24.694334899539253
# differential_evolution step 49: f(x)= 24.694334899539253
# differential_evolution step 50: f(x)= 24.694334899539253
# differential_evolution step 51: f(x)= 24.694334899539253
# differential_evolution step 52: f(x)= 24.694334899539253
# differential_evolution step 53: f(x)= 24.694334899539253
# differential_evolution step 54: f(x)= 24.694334899539253
# differential_evolution step 55: f(x)= 24.694334899539253
# differential_evolution step 56: f(x)= 24.694334899539253
# differential_evolution step 57: f(x)= 24.54843755889781
# differential_evolution step 58: f(x)= 24.54843755889781
# differential_evolution step 59: f(x)= 24.38379383954922
# differential_evolution step 60: f(x)= 24.38379383954922
# differential_evolution step 61: f(x)= 24.38379383954922
# differential_evolution step 62: f(x)= 24.36289223407054
# differential_evolution step 63: f(x)= 24.36289223407054
# differential_evolution step 64: f(x)= 24.36289223407054
# differential_evolution step 65: f(x)= 24.34481790800628
# differential_evolution step 66: f(x)= 24.34481790800628
# differential_evolution step 67: f(x)= 24.34481790800628
# differential_evolution step 68: f(x)= 24.34481790800628
# differential_evolution step 69: f(x)= 24.34481790800628
# differential_evolution step 70: f(x)= 24.344188264704623
# differential_evolution step 71: f(x)= 24.272625321374896
# differential_evolution step 72: f(x)= 24.272625321374896
# differential_evolution step 73: f(x)= 24.26196630452224
# differential_evolution step 74: f(x)= 24.26196630452224
# differential_evolution step 75: f(x)= 24.26196630452224
# differential_evolution step 76: f(x)= 24.26196630452224
# differential_evolution step 77: f(x)= 24.26196630452224
# differential_evolution step 78: f(x)= 24.24278096135304
# differential_evolution step 79: f(x)= 24.24278096135304
# differential_evolution step 80: f(x)= 24.24278096135304
# differential_evolution step 81: f(x)= 24.213510247858824
# differential_evolution step 82: f(x)= 24.213510247858824
# differential_evolution step 83: f(x)= 24.213510247858824
# differential_evolution step 84: f(x)= 24.213510247858824
# differential_evolution step 85: f(x)= 24.213510247858824
# differential_evolution step 86: f(x)= 24.213510247858824
# differential_evolution step 87: f(x)= 24.213510247858824
# differential_evolution step 88: f(x)= 24.213510247858824
# differential_evolution step 89: f(x)= 24.213510247858824
# differential_evolution step 90: f(x)= 24.20140068841272
# differential_evolution step 91: f(x)= 24.20140068841272
# differential_evolution step 92: f(x)= 24.179581168719817
# differential_evolution step 93: f(x)= 24.179581168719817
# differential_evolution step 94: f(x)= 24.173315940642055
# differential_evolution step 95: f(x)= 24.15866516168258
# differential_evolution step 96: f(x)= 24.15866516168258
# differential_evolution step 97: f(x)= 24.15866516168258
# differential_evolution step 98: f(x)= 24.15866516168258
# differential_evolution step 99: f(x)= 24.15866516168258
# differential_evolution step 100: f(x)= 24.15866516168258
# differential_evolution step 101: f(x)= 24.15866516168258
# differential_evolution step 102: f(x)= 24.15866516168258
# differential_evolution step 103: f(x)= 24.15866516168258
# differential_evolution step 104: f(x)= 24.15866516168258
# differential_evolution step 105: f(x)= 24.15866516168258
# differential_evolution step 106: f(x)= 24.15866516168258
# differential_evolution step 107: f(x)= 24.15866516168258
# differential_evolution step 108: f(x)= 24.15866516168258
# differential_evolution step 109: f(x)= 24.15866516168258
# differential_evolution step 110: f(x)= 24.15866516168258
# differential_evolution step 111: f(x)= 24.15866516168258
# differential_evolution step 112: f(x)= 24.15866516168258
# differential_evolution step 113: f(x)= 24.15866516168258
# differential_evolution step 114: f(x)= 24.15866516168258
# differential_evolution step 115: f(x)= 24.15866516168258
# differential_evolution step 116: f(x)= 24.15866516168258
# differential_evolution step 117: f(x)= 24.15866516168258
# differential_evolution step 118: f(x)= 24.139166547335027
# differential_evolution step 119: f(x)= 24.139166547335027
# differential_evolution step 120: f(x)= 24.139166547335027
# differential_evolution step 121: f(x)= 24.139166547335027
# differential_evolution step 122: f(x)= 24.139166547335027
# differential_evolution step 123: f(x)= 24.133725590626273
# differential_evolution step 124: f(x)= 24.133725590626273
# differential_evolution step 125: f(x)= 24.133725590626273
# differential_evolution step 126: f(x)= 24.133725590626273
# differential_evolution step 127: f(x)= 24.133725590626273
# differential_evolution step 128: f(x)= 24.133725590626273
# differential_evolution step 129: f(x)= 24.133505433194962
# differential_evolution step 130: f(x)= 24.133505433194962
# differential_evolution step 131: f(x)= 24.133505433194962
# differential_evolution step 132: f(x)= 24.133505433194962
# differential_evolution step 133: f(x)= 24.133505433194962
# differential_evolution step 134: f(x)= 24.133505433194962
# differential_evolution step 135: f(x)= 24.133505433194962
# differential_evolution step 136: f(x)= 24.133505433194962
# differential_evolution step 137: f(x)= 24.133505433194962
# differential_evolution step 138: f(x)= 24.133505433194962
# differential_evolution step 139: f(x)= 24.133505433194962
# differential_evolution step 140: f(x)= 24.121180594132337
# differential_evolution step 141: f(x)= 24.121180594132337
# differential_evolution step 142: f(x)= 24.121180594132337
# differential_evolution step 143: f(x)= 24.121180594132337
# differential_evolution step 144: f(x)= 24.11878205342225
# differential_evolution step 145: f(x)= 24.11878205342225
# differential_evolution step 146: f(x)= 24.11878205342225
# differential_evolution step 147: f(x)= 24.11878205342225
# differential_evolution step 148: f(x)= 24.118750953987316
# differential_evolution step 149: f(x)= 24.118750953987316
# differential_evolution step 150: f(x)= 24.118107172712648
# differential_evolution step 151: f(x)= 24.118107172712648
# differential_evolution step 152: f(x)= 24.118107172712648
# differential_evolution step 153: f(x)= 24.116454563197138
# differential_evolution step 154: f(x)= 24.110273483227648
# differential_evolution step 155: f(x)= 24.103527444292546
# differential_evolution step 156: f(x)= 24.103527444292546
# differential_evolution step 157: f(x)= 24.103527444292546
# differential_evolution step 158: f(x)= 24.103527444292546
# differential_evolution step 159: f(x)= 24.092199357885388
# differential_evolution step 160: f(x)= 24.092199357885388
# differential_evolution step 161: f(x)= 24.092199357885388
# differential_evolution step 162: f(x)= 24.092199357885388
# differential_evolution step 163: f(x)= 24.092199357885388
# differential_evolution step 164: f(x)= 24.092199357885388
# differential_evolution step 165: f(x)= 24.092199357885388
# differential_evolution step 166: f(x)= 24.092199357885388
# differential_evolution step 167: f(x)= 24.09071173505206
# differential_evolution step 168: f(x)= 24.087351332113784
# differential_evolution step 169: f(x)= 24.087351332113784
# differential_evolution step 170: f(x)= 24.087351332113784
# differential_evolution step 171: f(x)= 24.087351332113784
# differential_evolution step 172: f(x)= 24.087351332113784
# differential_evolution step 173: f(x)= 24.087351332113784
# differential_evolution step 174: f(x)= 24.087351332113784
# differential_evolution step 175: f(x)= 24.087351332113784
# differential_evolution step 176: f(x)= 24.086925624786765
# differential_evolution step 177: f(x)= 24.086925624786765
# differential_evolution step 178: f(x)= 24.086925624786765
# differential_evolution step 179: f(x)= 24.086925624786765
# differential_evolution step 180: f(x)= 24.08212492507244
# differential_evolution step 181: f(x)= 24.08212492507244
# differential_evolution step 182: f(x)= 24.08212492507244
# differential_evolution step 183: f(x)= 24.08212492507244
# differential_evolution step 184: f(x)= 24.074779063730233
# differential_evolution step 185: f(x)= 24.074779063730233
# differential_evolution step 186: f(x)= 24.074779063730233
# differential_evolution step 187: f(x)= 24.074779063730233
# differential_evolution step 188: f(x)= 24.074779063730233
# differential_evolution step 189: f(x)= 24.074779063730233
# differential_evolution step 190: f(x)= 24.074779063730233
# differential_evolution step 191: f(x)= 24.074779063730233
# differential_evolution step 192: f(x)= 24.074779063730233
# differential_evolution step 193: f(x)= 24.074779063730233
# differential_evolution step 194: f(x)= 24.074779063730233
# differential_evolution step 195: f(x)= 24.074779063730233
# differential_evolution step 196: f(x)= 24.074779063730233
# differential_evolution step 197: f(x)= 24.074613693790393
# differential_evolution step 198: f(x)= 24.074613693790393
# differential_evolution step 199: f(x)= 24.074613693790393
# differential_evolution step 200: f(x)= 24.073929741517183
# differential_evolution step 201: f(x)= 24.073929741517183
# differential_evolution step 202: f(x)= 24.073929741517183
# differential_evolution step 203: f(x)= 24.073929741517183
# differential_evolution step 204: f(x)= 24.073929741517183
# differential_evolution step 205: f(x)= 24.071980575985133
# differential_evolution step 206: f(x)= 24.071980575985133
# differential_evolution step 207: f(x)= 24.071980575985133
# differential_evolution step 208: f(x)= 24.071980575985133
# differential_evolution step 209: f(x)= 24.071980575985133
# differential_evolution step 210: f(x)= 24.071977505741625
# differential_evolution step 211: f(x)= 24.06992195263851
# differential_evolution step 212: f(x)= 24.06992195263851
# differential_evolution step 213: f(x)= 24.06992195263851
# differential_evolution step 214: f(x)= 24.06992195263851
# differential_evolution step 215: f(x)= 24.06992195263851
# differential_evolution step 216: f(x)= 24.06821544761592
# differential_evolution step 217: f(x)= 24.067606974938617
# differential_evolution step 218: f(x)= 24.06659202702432
# differential_evolution step 219: f(x)= 24.06659202702432
# differential_evolution step 220: f(x)= 24.06659202702432
# differential_evolution step 221: f(x)= 24.06659202702432
# differential_evolution step 222: f(x)= 24.06659202702432
# differential_evolution step 223: f(x)= 24.06659202702432
# differential_evolution step 224: f(x)= 24.065685144873086
# differential_evolution step 225: f(x)= 24.065685144873086
# differential_evolution step 226: f(x)= 24.065685144873086
# differential_evolution step 227: f(x)= 24.065685144873086
# differential_evolution step 228: f(x)= 24.065685144873086
# differential_evolution step 229: f(x)= 24.06413560109087
# differential_evolution step 230: f(x)= 24.06413560109087
# differential_evolution step 231: f(x)= 24.064075021348565
# differential_evolution step 232: f(x)= 24.064075021348565
# differential_evolution step 233: f(x)= 24.064075021348565
# differential_evolution step 234: f(x)= 24.064075021348565
# differential_evolution step 235: f(x)= 24.064075021348565
# differential_evolution step 236: f(x)= 24.064075021348565
# differential_evolution step 237: f(x)= 24.064075021348565
# differential_evolution step 238: f(x)= 24.064075021348565
# differential_evolution step 239: f(x)= 24.064075021348565
# differential_evolution step 240: f(x)= 24.064075021348565
# differential_evolution step 241: f(x)= 24.064041717533183
# differential_evolution step 242: f(x)= 24.064041717533183
# differential_evolution step 243: f(x)= 24.063967428499808
# differential_evolution step 244: f(x)= 24.063967428499808
# differential_evolution step 245: f(x)= 24.063967428499808
# differential_evolution step 246: f(x)= 24.063415503808976
# differential_evolution step 247: f(x)= 24.063415503808976
# differential_evolution step 248: f(x)= 24.063415503808976
# differential_evolution step 249: f(x)= 24.063358296362534
# differential_evolution step 250: f(x)= 24.063358296362534
# differential_evolution step 251: f(x)= 24.063339118747514
# differential_evolution step 252: f(x)= 24.063339118747514
# differential_evolution step 253: f(x)= 24.063339118747514
# differential_evolution step 254: f(x)= 24.063156065173704
# differential_evolution step 255: f(x)= 24.063095345287724
# differential_evolution step 256: f(x)= 24.063095345287724
# differential_evolution step 257: f(x)= 24.062820561695247
# differential_evolution step 258: f(x)= 24.062820561695247
# differential_evolution step 259: f(x)= 24.062820561695247
# differential_evolution step 260: f(x)= 24.062820561695247
# differential_evolution step 261: f(x)= 24.062820561695247
# differential_evolution step 262: f(x)= 24.062820561695247
# differential_evolution step 263: f(x)= 24.062820561695247
# differential_evolution step 264: f(x)= 24.062820561695247
# differential_evolution step 265: f(x)= 24.0627882606795
# differential_evolution step 266: f(x)= 24.0627882606795
# differential_evolution step 267: f(x)= 24.062494976173408
# differential_evolution step 268: f(x)= 24.062494976173408
# differential_evolution step 269: f(x)= 24.062494976173408
# differential_evolution step 270: f(x)= 24.062494976173408
# differential_evolution step 271: f(x)= 24.062494976173408
# differential_evolution step 272: f(x)= 24.062396420876418
# differential_evolution step 273: f(x)= 24.062396420876418
# differential_evolution step 274: f(x)= 24.062396420876418
# differential_evolution step 275: f(x)= 24.062396420876418
# differential_evolution step 276: f(x)= 24.062396420876418
# differential_evolution step 277: f(x)= 24.062396420876418
# differential_evolution step 278: f(x)= 24.062373629049098
# differential_evolution step 279: f(x)= 24.062373629049098
# differential_evolution step 280: f(x)= 24.062373629049098
# differential_evolution step 281: f(x)= 24.06236622951127
# differential_evolution step 282: f(x)= 24.06232579304076
# differential_evolution step 283: f(x)= 24.06232579304076
# differential_evolution step 284: f(x)= 24.06232579304076
# differential_evolution step 285: f(x)= 24.062298120885902
# differential_evolution step 286: f(x)= 24.06226397853315
# differential_evolution step 287: f(x)= 24.06226397853315
# differential_evolution step 288: f(x)= 24.06226397853315
# differential_evolution step 289: f(x)= 24.06226397853315
# differential_evolution step 290: f(x)= 24.06226228016164
# differential_evolution step 291: f(x)= 24.06226228016164
# differential_evolution step 292: f(x)= 24.06224418454182
# differential_evolution step 293: f(x)= 24.06224418454182
# differential_evolution step 294: f(x)= 24.06224418454182
# differential_evolution step 295: f(x)= 24.06218488123132
# differential_evolution step 296: f(x)= 24.06218488123132
# differential_evolution step 297: f(x)= 24.062132057971006
# differential_evolution step 298: f(x)= 24.062132057971006
# differential_evolution step 299: f(x)= 24.062132057971006
# differential_evolution step 300: f(x)= 24.062132057971006
# differential_evolution step 301: f(x)= 24.062132057971006
# differential_evolution step 302: f(x)= 24.062132057971006
# differential_evolution step 303: f(x)= 24.062113224698265
# differential_evolution step 304: f(x)= 24.062081400123773
# differential_evolution step 305: f(x)= 24.062081400123773
# differential_evolution step 306: f(x)= 24.06207057644432
# differential_evolution step 307: f(x)= 24.062062178702213
# differential_evolution step 308: f(x)= 24.062062178702213
# differential_evolution step 309: f(x)= 24.062062178702213
# differential_evolution step 310: f(x)= 24.062062178702213
# differential_evolution step 311: f(x)= 24.062062178702213
# differential_evolution step 312: f(x)= 24.06205063953339
# differential_evolution step 313: f(x)= 24.06205063953339
# differential_evolution step 314: f(x)= 24.06205043309548
# differential_evolution step 315: f(x)= 24.06205043309548
# differential_evolution step 316: f(x)= 24.06205043309548
# differential_evolution step 317: f(x)= 24.06205043309548
# differential_evolution step 318: f(x)= 24.06205043309548
# differential_evolution step 319: f(x)= 24.06205043309548
# differential_evolution step 320: f(x)= 24.062048015289815
# differential_evolution step 321: f(x)= 24.062048015289815
# differential_evolution step 322: f(x)= 24.062048015289815
# differential_evolution step 323: f(x)= 24.06203935595216
# differential_evolution step 324: f(x)= 24.06203935595216
# differential_evolution step 325: f(x)= 24.06203935595216
# differential_evolution step 326: f(x)= 24.06203872477019
# differential_evolution step 327: f(x)= 24.06203872477019
# differential_evolution step 328: f(x)= 24.06203872477019
# differential_evolution step 329: f(x)= 24.06203872477019
# differential_evolution step 330: f(x)= 24.06203872477019
# differential_evolution step 331: f(x)= 24.062037941907274
# differential_evolution step 332: f(x)= 24.062037941907274
# differential_evolution step 333: f(x)= 24.062037941907274
# differential_evolution step 334: f(x)= 24.062037941907274
# differential_evolution step 335: f(x)= 24.062037941907274
# differential_evolution step 336: f(x)= 24.062037941907274
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [9.99999909e-02 4.99999964e+01 3.52714375e+00 3.64531218e+01
#  2.70260736e-02 4.99998584e+01 3.94402538e+00 5.95881470e+01]
# Chi quadro minimo: 24.062037941907274

# %%
# Plots:
params_curve_2, covariance_2 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params2, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[1], red_chi[1] = save_params(params_curve_2, covariance_2, radial_profile_HA, radial_profile_error_HA,
    x_axes, 2, line_name="Two", output_prefix="fit")

aic[1] = AIC(x_axes, radial_profile_HA, chi_quadr[1], params_curve_2)
bic[1] = BIC(x_axes, radial_profile_HA, chi_quadr[1], params_curve_2)
print(aic[1], chi_quadr[1], bic[1], len(params_curve_2))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_2)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_2[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_2[4:8]), 'g--', label='Sérsic 2')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_2')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16324\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16324\72937070.py:8: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.2491, r_e=25.6544, n=2.8336, x_0=36.6255
# Sérsic 2: I_e=0.0169, r_e=73.7034, n=4.2628, x_0=59.5881
# [1.76281115e-01 1.34636709e+01 5.51691303e-01 1.07080192e-01
#  1.07135382e-01 3.20843722e+02 6.46243540e+00 8.54701715e-04]
# 115.42387854366442
# 133.006296126082 115.42387854366442 152.26524003156914 8
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 0.1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (33, 38),   # x_0: posizione da 0 a 100   # x_0: posizione da 0 a 100
    
    (0, 0.1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (55, 65),

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (68, 73),   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params3 = result.x

print("Optimize parameters with differential_evolution:", best_params3)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 233.11467629904578
# differential_evolution step 2: f(x)= 177.00496180978777
# differential_evolution step 3: f(x)= 177.00496180978777
# differential_evolution step 4: f(x)= 118.63490505430191
# differential_evolution step 5: f(x)= 107.40615596345458
# differential_evolution step 6: f(x)= 92.72727525306925
# differential_evolution step 7: f(x)= 92.72727525306925
# differential_evolution step 8: f(x)= 92.72727525306925
# differential_evolution step 9: f(x)= 92.72727525306925
# differential_evolution step 10: f(x)= 87.08882849606756
# differential_evolution step 11: f(x)= 72.93352185840031
# differential_evolution step 12: f(x)= 62.7336730373447
# differential_evolution step 13: f(x)= 57.08470052291808
# differential_evolution step 14: f(x)= 57.08470052291808
# differential_evolution step 15: f(x)= 57.08470052291808
# differential_evolution step 16: f(x)= 57.08470052291808
# differential_evolution step 17: f(x)= 57.08470052291808
# differential_evolution step 18: f(x)= 53.17206720919201
# differential_evolution step 19: f(x)= 53.17206720919201
# differential_evolution step 20: f(x)= 38.70642670404508
# differential_evolution step 21: f(x)= 38.295163419485526
# differential_evolution step 22: f(x)= 38.295163419485526
# differential_evolution step 23: f(x)= 38.295163419485526
# differential_evolution step 24: f(x)= 33.36391523607439
# differential_evolution step 25: f(x)= 33.36391523607439
# differential_evolution step 26: f(x)= 33.36391523607439
# differential_evolution step 27: f(x)= 33.36391523607439
# differential_evolution step 28: f(x)= 33.36391523607439
# differential_evolution step 29: f(x)= 33.36391523607439
# differential_evolution step 30: f(x)= 29.66452724017836
# differential_evolution step 31: f(x)= 29.66452724017836
# differential_evolution step 32: f(x)= 29.66452724017836
# differential_evolution step 33: f(x)= 27.502463869617905
# differential_evolution step 34: f(x)= 27.502463869617905
# differential_evolution step 35: f(x)= 27.502463869617905
# differential_evolution step 36: f(x)= 27.502463869617905
# differential_evolution step 37: f(x)= 27.502463869617905
# differential_evolution step 38: f(x)= 27.502463869617905
# differential_evolution step 39: f(x)= 27.502463869617905
# differential_evolution step 40: f(x)= 25.785980829145377
# differential_evolution step 41: f(x)= 25.785980829145377
# differential_evolution step 42: f(x)= 25.785980829145377
# differential_evolution step 43: f(x)= 25.785980829145377
# differential_evolution step 44: f(x)= 25.785980829145377
# differential_evolution step 45: f(x)= 25.785980829145377
# differential_evolution step 46: f(x)= 25.785980829145377
# differential_evolution step 47: f(x)= 25.785980829145377
# differential_evolution step 48: f(x)= 25.785980829145377
# differential_evolution step 49: f(x)= 25.785980829145377
# differential_evolution step 50: f(x)= 25.785980829145377
# differential_evolution step 51: f(x)= 25.785980829145377
# differential_evolution step 52: f(x)= 25.785980829145377
# differential_evolution step 53: f(x)= 24.523097861018975
# differential_evolution step 54: f(x)= 24.523097861018975
# differential_evolution step 55: f(x)= 24.08467850355596
# differential_evolution step 56: f(x)= 24.08467850355596
# differential_evolution step 57: f(x)= 24.08467850355596
# differential_evolution step 58: f(x)= 24.08467850355596
# differential_evolution step 59: f(x)= 24.08467850355596
# differential_evolution step 60: f(x)= 23.317123750664848
# differential_evolution step 61: f(x)= 23.317123750664848
# differential_evolution step 62: f(x)= 23.317123750664848
# differential_evolution step 63: f(x)= 23.317123750664848
# differential_evolution step 64: f(x)= 22.82591812783944
# differential_evolution step 65: f(x)= 22.82591812783944
# differential_evolution step 66: f(x)= 22.82591812783944
# differential_evolution step 67: f(x)= 22.82591812783944
# differential_evolution step 68: f(x)= 22.40530508939484
# differential_evolution step 69: f(x)= 22.40530508939484
# differential_evolution step 70: f(x)= 22.40530508939484
# differential_evolution step 71: f(x)= 22.40530508939484
# differential_evolution step 72: f(x)= 22.05474971170217
# differential_evolution step 73: f(x)= 21.175598589088242
# differential_evolution step 74: f(x)= 21.175598589088242
# differential_evolution step 75: f(x)= 21.175598589088242
# differential_evolution step 76: f(x)= 21.175598589088242
# differential_evolution step 77: f(x)= 21.175598589088242
# differential_evolution step 78: f(x)= 21.175598589088242
# differential_evolution step 79: f(x)= 21.175598589088242
# differential_evolution step 80: f(x)= 21.175598589088242
# differential_evolution step 81: f(x)= 21.175598589088242
# differential_evolution step 82: f(x)= 21.175598589088242
# differential_evolution step 83: f(x)= 21.175598589088242
# differential_evolution step 84: f(x)= 20.888474834910898
# differential_evolution step 85: f(x)= 20.888474834910898
# differential_evolution step 86: f(x)= 20.888474834910898
# differential_evolution step 87: f(x)= 20.888474834910898
# differential_evolution step 88: f(x)= 20.888474834910898
# differential_evolution step 89: f(x)= 20.888474834910898
# differential_evolution step 90: f(x)= 20.888474834910898
# differential_evolution step 91: f(x)= 20.888474834910898
# differential_evolution step 92: f(x)= 20.888474834910898
# differential_evolution step 93: f(x)= 20.888474834910898
# differential_evolution step 94: f(x)= 20.888474834910898
# differential_evolution step 95: f(x)= 20.888474834910898
# differential_evolution step 96: f(x)= 20.888474834910898
# differential_evolution step 97: f(x)= 20.888474834910898
# differential_evolution step 98: f(x)= 20.888474834910898
# differential_evolution step 99: f(x)= 20.888474834910898
# differential_evolution step 100: f(x)= 20.888474834910898
# differential_evolution step 101: f(x)= 20.888474834910898
# differential_evolution step 102: f(x)= 20.888474834910898
# differential_evolution step 103: f(x)= 20.644546637931967
# differential_evolution step 104: f(x)= 20.644546637931967
# differential_evolution step 105: f(x)= 20.644546637931967
# differential_evolution step 106: f(x)= 20.644546637931967
# differential_evolution step 107: f(x)= 20.644546637931967
# differential_evolution step 108: f(x)= 20.644546637931967
# differential_evolution step 109: f(x)= 20.644546637931967
# differential_evolution step 110: f(x)= 20.644546637931967
# differential_evolution step 111: f(x)= 20.644546637931967
# differential_evolution step 112: f(x)= 20.447618302414085
# differential_evolution step 113: f(x)= 20.447618302414085
# differential_evolution step 114: f(x)= 20.447618302414085
# differential_evolution step 115: f(x)= 20.447618302414085
# differential_evolution step 116: f(x)= 20.447618302414085
# differential_evolution step 117: f(x)= 20.447618302414085
# differential_evolution step 118: f(x)= 20.447618302414085
# differential_evolution step 119: f(x)= 20.361163340556335
# differential_evolution step 120: f(x)= 20.361163340556335
# differential_evolution step 121: f(x)= 20.361163340556335
# differential_evolution step 122: f(x)= 20.361163340556335
# differential_evolution step 123: f(x)= 20.361163340556335
# differential_evolution step 124: f(x)= 20.361163340556335
# differential_evolution step 125: f(x)= 20.361163340556335
# differential_evolution step 126: f(x)= 20.361163340556335
# differential_evolution step 127: f(x)= 20.361163340556335
# differential_evolution step 128: f(x)= 20.361163340556335
# differential_evolution step 129: f(x)= 20.361163340556335
# differential_evolution step 130: f(x)= 20.361163340556335
# differential_evolution step 131: f(x)= 20.361163340556335
# differential_evolution step 132: f(x)= 20.361163340556335
# differential_evolution step 133: f(x)= 20.361163340556335
# differential_evolution step 134: f(x)= 20.361163340556335
# differential_evolution step 135: f(x)= 20.361163340556335
# differential_evolution step 136: f(x)= 20.361163340556335
# differential_evolution step 137: f(x)= 20.3182091219766
# differential_evolution step 138: f(x)= 20.3182091219766
# differential_evolution step 139: f(x)= 20.3182091219766
# differential_evolution step 140: f(x)= 20.3182091219766
# differential_evolution step 141: f(x)= 20.3182091219766
# differential_evolution step 142: f(x)= 20.3182091219766
# differential_evolution step 143: f(x)= 20.3182091219766
# differential_evolution step 144: f(x)= 20.3182091219766
# differential_evolution step 145: f(x)= 20.3182091219766
# differential_evolution step 146: f(x)= 20.3182091219766
# differential_evolution step 147: f(x)= 20.3182091219766
# differential_evolution step 148: f(x)= 20.3182091219766
# differential_evolution step 149: f(x)= 20.3182091219766
# differential_evolution step 150: f(x)= 20.3182091219766
# differential_evolution step 151: f(x)= 20.301929267438886
# differential_evolution step 152: f(x)= 20.301929267438886
# differential_evolution step 153: f(x)= 20.26147864867096
# differential_evolution step 154: f(x)= 20.26147864867096
# differential_evolution step 155: f(x)= 20.26147864867096
# differential_evolution step 156: f(x)= 20.26147864867096
# differential_evolution step 157: f(x)= 20.26147864867096
# differential_evolution step 158: f(x)= 20.26147864867096
# differential_evolution step 159: f(x)= 20.26147864867096
# differential_evolution step 160: f(x)= 20.26147864867096
# differential_evolution step 161: f(x)= 20.26147864867096
# differential_evolution step 162: f(x)= 20.26147864867096
# differential_evolution step 163: f(x)= 20.234011394571336
# differential_evolution step 164: f(x)= 20.234011394571336
# differential_evolution step 165: f(x)= 20.234011394571336
# differential_evolution step 166: f(x)= 20.234011394571336
# differential_evolution step 167: f(x)= 20.234011394571336
# differential_evolution step 168: f(x)= 20.234011394571336
# differential_evolution step 169: f(x)= 20.234011394571336
# differential_evolution step 170: f(x)= 20.234011394571336
# differential_evolution step 171: f(x)= 20.234011394571336
# differential_evolution step 172: f(x)= 20.234011394571336
# differential_evolution step 173: f(x)= 20.234011394571336
# differential_evolution step 174: f(x)= 20.234011394571336
# differential_evolution step 175: f(x)= 20.22556842061836
# differential_evolution step 176: f(x)= 20.22556842061836
# differential_evolution step 177: f(x)= 20.22556842061836
# differential_evolution step 178: f(x)= 20.221366003971607
# differential_evolution step 179: f(x)= 20.221366003971607
# differential_evolution step 180: f(x)= 20.221366003971607
# differential_evolution step 181: f(x)= 20.200785209467753
# differential_evolution step 182: f(x)= 20.200785209467753
# differential_evolution step 183: f(x)= 20.200785209467753
# differential_evolution step 184: f(x)= 20.1949877727744
# differential_evolution step 185: f(x)= 20.194192092429883
# differential_evolution step 186: f(x)= 20.194192092429883
# differential_evolution step 187: f(x)= 20.194192092429883
# differential_evolution step 188: f(x)= 20.194192092429883
# differential_evolution step 189: f(x)= 20.194192092429883
# differential_evolution step 190: f(x)= 20.18101324413686
# differential_evolution step 191: f(x)= 20.18101324413686
# differential_evolution step 192: f(x)= 20.18101324413686
# differential_evolution step 193: f(x)= 20.18101324413686
# differential_evolution step 194: f(x)= 20.18101324413686
# differential_evolution step 195: f(x)= 20.18101324413686
# differential_evolution step 196: f(x)= 20.18101324413686
# differential_evolution step 197: f(x)= 20.18101324413686
# differential_evolution step 198: f(x)= 20.18101324413686
# differential_evolution step 199: f(x)= 20.18101324413686
# differential_evolution step 200: f(x)= 20.18101324413686
# differential_evolution step 201: f(x)= 20.18101324413686
# differential_evolution step 202: f(x)= 20.18101324413686
# differential_evolution step 203: f(x)= 20.18101324413686
# differential_evolution step 204: f(x)= 20.17574021469265
# differential_evolution step 205: f(x)= 20.17574021469265
# differential_evolution step 206: f(x)= 20.17574021469265
# differential_evolution step 207: f(x)= 20.17574021469265
# differential_evolution step 208: f(x)= 20.17574021469265
# differential_evolution step 209: f(x)= 20.17574021469265
# differential_evolution step 210: f(x)= 20.17574021469265
# differential_evolution step 211: f(x)= 20.17574021469265
# differential_evolution step 212: f(x)= 20.17574021469265
# differential_evolution step 213: f(x)= 20.17574021469265
# differential_evolution step 214: f(x)= 20.17574021469265
# differential_evolution step 215: f(x)= 20.17574021469265
# differential_evolution step 216: f(x)= 20.17574021469265
# differential_evolution step 217: f(x)= 20.17574021469265
# differential_evolution step 218: f(x)= 20.17574021469265
# differential_evolution step 219: f(x)= 20.17574021469265
# differential_evolution step 220: f(x)= 20.174205748594407
# differential_evolution step 221: f(x)= 20.174205748594407
# differential_evolution step 222: f(x)= 20.174205748594407
# differential_evolution step 223: f(x)= 20.174205748594407
# differential_evolution step 224: f(x)= 20.174205748594407
# differential_evolution step 225: f(x)= 20.174205748594407
# differential_evolution step 226: f(x)= 20.17354077885902
# differential_evolution step 227: f(x)= 20.17354077885902
# differential_evolution step 228: f(x)= 20.17354077885902
# differential_evolution step 229: f(x)= 20.17354077885902
# differential_evolution step 230: f(x)= 20.17354077885902
# differential_evolution step 231: f(x)= 20.17354077885902
# differential_evolution step 232: f(x)= 20.165540403934692
# differential_evolution step 233: f(x)= 20.165540403934692
# differential_evolution step 234: f(x)= 20.165540403934692
# differential_evolution step 235: f(x)= 20.165540403934692
# differential_evolution step 236: f(x)= 20.165540403934692
# differential_evolution step 237: f(x)= 20.165540403934692
# differential_evolution step 238: f(x)= 20.165540403934692
# differential_evolution step 239: f(x)= 20.165540403934692
# differential_evolution step 240: f(x)= 20.158481695950464
# differential_evolution step 241: f(x)= 20.158481695950464
# differential_evolution step 242: f(x)= 20.158481695950464
# differential_evolution step 243: f(x)= 20.158481695950464
# differential_evolution step 244: f(x)= 20.158481695950464
# differential_evolution step 245: f(x)= 20.158481695950464
# differential_evolution step 246: f(x)= 20.158481695950464
# differential_evolution step 247: f(x)= 20.158481695950464
# differential_evolution step 248: f(x)= 20.15415646504453
# differential_evolution step 249: f(x)= 20.15415646504453
# differential_evolution step 250: f(x)= 20.15415646504453
# differential_evolution step 251: f(x)= 20.15415646504453
# differential_evolution step 252: f(x)= 20.15415646504453
# differential_evolution step 253: f(x)= 20.15415646504453
# differential_evolution step 254: f(x)= 20.152871986447053
# differential_evolution step 255: f(x)= 20.152871986447053
# differential_evolution step 256: f(x)= 20.152871986447053
# differential_evolution step 257: f(x)= 20.152871986447053
# differential_evolution step 258: f(x)= 20.152871986447053
# differential_evolution step 259: f(x)= 20.152871986447053
# differential_evolution step 260: f(x)= 20.14975597156237
# differential_evolution step 261: f(x)= 20.14975597156237
# differential_evolution step 262: f(x)= 20.148886356733883
# differential_evolution step 263: f(x)= 20.148886356733883
# differential_evolution step 264: f(x)= 20.148886356733883
# differential_evolution step 265: f(x)= 20.148886356733883
# differential_evolution step 266: f(x)= 20.148886356733883
# differential_evolution step 267: f(x)= 20.14389251801066
# differential_evolution step 268: f(x)= 20.138017637398622
# differential_evolution step 269: f(x)= 20.138017637398622
# differential_evolution step 270: f(x)= 20.138017637398622
# differential_evolution step 271: f(x)= 20.138017637398622
# differential_evolution step 272: f(x)= 20.138017637398622
# differential_evolution step 273: f(x)= 20.138017637398622
# differential_evolution step 274: f(x)= 20.138017637398622
# differential_evolution step 275: f(x)= 20.138017637398622
# differential_evolution step 276: f(x)= 20.138017637398622
# differential_evolution step 277: f(x)= 20.138017637398622
# differential_evolution step 278: f(x)= 20.138017637398622
# differential_evolution step 279: f(x)= 20.138017637398622
# differential_evolution step 280: f(x)= 20.138017637398622
# differential_evolution step 281: f(x)= 20.138017637398622
# differential_evolution step 282: f(x)= 20.138017637398622
# differential_evolution step 283: f(x)= 20.138017637398622
# differential_evolution step 284: f(x)= 20.138017637398622
# differential_evolution step 285: f(x)= 20.138017637398622
# differential_evolution step 286: f(x)= 20.138017637398622
# differential_evolution step 287: f(x)= 20.138017637398622
# differential_evolution step 288: f(x)= 20.138017637398622
# differential_evolution step 289: f(x)= 20.138017637398622
# differential_evolution step 290: f(x)= 20.138017637398622
# differential_evolution step 291: f(x)= 20.138017637398622
# differential_evolution step 292: f(x)= 20.136435669496684
# differential_evolution step 293: f(x)= 20.136435669496684
# differential_evolution step 294: f(x)= 20.136435669496684
# differential_evolution step 295: f(x)= 20.136435669496684
# differential_evolution step 296: f(x)= 20.136435669496684
# differential_evolution step 297: f(x)= 20.136435669496684
# differential_evolution step 298: f(x)= 20.136435669496684
# differential_evolution step 299: f(x)= 20.136435669496684
# differential_evolution step 300: f(x)= 20.136435669496684
# differential_evolution step 301: f(x)= 20.136435669496684
# differential_evolution step 302: f(x)= 20.136435669496684
# differential_evolution step 303: f(x)= 20.136435669496684
# differential_evolution step 304: f(x)= 20.136435669496684
# differential_evolution step 305: f(x)= 20.136435669496684
# differential_evolution step 306: f(x)= 20.136435669496684
# differential_evolution step 307: f(x)= 20.13095008855928
# differential_evolution step 308: f(x)= 20.13095008855928
# differential_evolution step 309: f(x)= 20.13095008855928
# differential_evolution step 310: f(x)= 20.13095008855928
# differential_evolution step 311: f(x)= 20.13095008855928
# differential_evolution step 312: f(x)= 20.13095008855928
# differential_evolution step 313: f(x)= 20.13095008855928
# differential_evolution step 314: f(x)= 20.13095008855928
# differential_evolution step 315: f(x)= 20.13095008855928
# differential_evolution step 316: f(x)= 20.13095008855928
# differential_evolution step 317: f(x)= 20.13095008855928
# differential_evolution step 318: f(x)= 20.13095008855928
# differential_evolution step 319: f(x)= 20.13095008855928
# differential_evolution step 320: f(x)= 20.13095008855928
# differential_evolution step 321: f(x)= 20.13095008855928
# differential_evolution step 322: f(x)= 20.13095008855928
# differential_evolution step 323: f(x)= 20.13095008855928
# differential_evolution step 324: f(x)= 20.13095008855928
# differential_evolution step 325: f(x)= 20.13095008855928
# differential_evolution step 326: f(x)= 20.13095008855928
# differential_evolution step 327: f(x)= 20.13095008855928
# differential_evolution step 328: f(x)= 20.13095008855928
# differential_evolution step 329: f(x)= 20.13095008855928
# differential_evolution step 330: f(x)= 20.13095008855928
# differential_evolution step 331: f(x)= 20.13095008855928
# differential_evolution step 332: f(x)= 20.13095008855928
# differential_evolution step 333: f(x)= 20.13095008855928
# differential_evolution step 334: f(x)= 20.13095008855928
# differential_evolution step 335: f(x)= 20.13095008855928
# differential_evolution step 336: f(x)= 20.13095008855928
# differential_evolution step 337: f(x)= 20.13095008855928
# differential_evolution step 338: f(x)= 20.13095008855928
# differential_evolution step 339: f(x)= 20.13095008855928
# differential_evolution step 340: f(x)= 20.13095008855928
# differential_evolution step 341: f(x)= 20.13095008855928
# differential_evolution step 342: f(x)= 20.13095008855928
# differential_evolution step 343: f(x)= 20.13095008855928
# differential_evolution step 344: f(x)= 20.13095008855928
# differential_evolution step 345: f(x)= 20.13095008855928
# differential_evolution step 346: f(x)= 20.13095008855928
# differential_evolution step 347: f(x)= 20.13095008855928
# differential_evolution step 348: f(x)= 20.13095008855928
# differential_evolution step 349: f(x)= 20.13095008855928
# differential_evolution step 350: f(x)= 20.13095008855928
# differential_evolution step 351: f(x)= 20.13095008855928
# differential_evolution step 352: f(x)= 20.13095008855928
# differential_evolution step 353: f(x)= 20.13095008855928
# differential_evolution step 354: f(x)= 20.13095008855928
# differential_evolution step 355: f(x)= 20.13095008855928
# differential_evolution step 356: f(x)= 20.13095008855928
# differential_evolution step 357: f(x)= 20.13095008855928
# differential_evolution step 358: f(x)= 20.13095008855928
# differential_evolution step 359: f(x)= 20.13095008855928
# differential_evolution step 360: f(x)= 20.13095008855928
# differential_evolution step 361: f(x)= 20.13095008855928
# differential_evolution step 362: f(x)= 20.13095008855928
# differential_evolution step 363: f(x)= 20.13095008855928
# differential_evolution step 364: f(x)= 20.13095008855928
# differential_evolution step 365: f(x)= 20.13095008855928
# differential_evolution step 366: f(x)= 20.13095008855928
# differential_evolution step 367: f(x)= 20.13095008855928
# differential_evolution step 368: f(x)= 20.13095008855928
# differential_evolution step 369: f(x)= 20.13095008855928
# differential_evolution step 370: f(x)= 20.13095008855928
# differential_evolution step 371: f(x)= 20.13095008855928
# differential_evolution step 372: f(x)= 20.13095008855928
# differential_evolution step 373: f(x)= 20.13095008855928
# differential_evolution step 374: f(x)= 20.13095008855928
# differential_evolution step 375: f(x)= 20.13095008855928
# differential_evolution step 376: f(x)= 20.13095008855928
# differential_evolution step 377: f(x)= 20.13095008855928
# differential_evolution step 378: f(x)= 20.13095008855928
# differential_evolution step 379: f(x)= 20.13095008855928
# differential_evolution step 380: f(x)= 20.13095008855928
# differential_evolution step 381: f(x)= 20.13095008855928
# differential_evolution step 382: f(x)= 20.13095008855928
# differential_evolution step 383: f(x)= 20.13095008855928
# differential_evolution step 384: f(x)= 20.13095008855928
# differential_evolution step 385: f(x)= 20.13095008855928
# differential_evolution step 386: f(x)= 20.13095008855928
# differential_evolution step 387: f(x)= 20.13095008855928
# differential_evolution step 388: f(x)= 20.13095008855928
# differential_evolution step 389: f(x)= 20.13095008855928
# differential_evolution step 390: f(x)= 20.13095008855928
# differential_evolution step 391: f(x)= 20.13095008855928
# differential_evolution step 392: f(x)= 20.13095008855928
# differential_evolution step 393: f(x)= 20.13095008855928
# differential_evolution step 394: f(x)= 20.13095008855928
# differential_evolution step 395: f(x)= 20.13095008855928
# differential_evolution step 396: f(x)= 20.13095008855928
# differential_evolution step 397: f(x)= 20.13095008855928
# differential_evolution step 398: f(x)= 20.13095008855928
# differential_evolution step 399: f(x)= 20.13095008855928
# differential_evolution step 400: f(x)= 20.13095008855928
# differential_evolution step 401: f(x)= 20.13095008855928
# differential_evolution step 402: f(x)= 20.13095008855928
# differential_evolution step 403: f(x)= 20.13095008855928
# differential_evolution step 404: f(x)= 20.13095008855928
# differential_evolution step 405: f(x)= 20.13095008855928
# differential_evolution step 406: f(x)= 20.13095008855928
# differential_evolution step 407: f(x)= 20.13095008855928
# differential_evolution step 408: f(x)= 20.13095008855928
# differential_evolution step 409: f(x)= 20.13095008855928
# differential_evolution step 410: f(x)= 20.13095008855928
# differential_evolution step 411: f(x)= 20.13095008855928
# differential_evolution step 412: f(x)= 20.13095008855928
# differential_evolution step 413: f(x)= 20.13095008855928
# differential_evolution step 414: f(x)= 20.13095008855928
# differential_evolution step 415: f(x)= 20.13095008855928
# differential_evolution step 416: f(x)= 20.13095008855928
# differential_evolution step 417: f(x)= 20.130022935768103
# differential_evolution step 418: f(x)= 20.130022935768103
# differential_evolution step 419: f(x)= 20.130022935768103
# differential_evolution step 420: f(x)= 20.130022935768103
# differential_evolution step 421: f(x)= 20.130022935768103
# differential_evolution step 422: f(x)= 20.130022935768103
# differential_evolution step 423: f(x)= 20.130022935768103
# differential_evolution step 424: f(x)= 20.130022935768103
# differential_evolution step 425: f(x)= 20.130022935768103
# differential_evolution step 426: f(x)= 20.130022935768103
# differential_evolution step 427: f(x)= 20.130022935768103
# differential_evolution step 428: f(x)= 20.130022935768103
# differential_evolution step 429: f(x)= 20.130022935768103
# differential_evolution step 430: f(x)= 20.130022935768103
# differential_evolution step 431: f(x)= 20.130022935768103
# differential_evolution step 432: f(x)= 20.130022935768103
# differential_evolution step 433: f(x)= 20.130022935768103
# differential_evolution step 434: f(x)= 20.130022935768103
# differential_evolution step 435: f(x)= 20.130022935768103
# differential_evolution step 436: f(x)= 20.130022935768103
# differential_evolution step 437: f(x)= 20.130022935768103
# differential_evolution step 438: f(x)= 20.130022935768103
# differential_evolution step 439: f(x)= 20.130022935768103
# differential_evolution step 440: f(x)= 20.130022935768103
# differential_evolution step 441: f(x)= 20.130022935768103
# differential_evolution step 442: f(x)= 20.130022935768103
# differential_evolution step 443: f(x)= 20.130022935768103
# differential_evolution step 444: f(x)= 20.130022935768103
# differential_evolution step 445: f(x)= 20.130022935768103
# differential_evolution step 446: f(x)= 20.130022935768103
# differential_evolution step 447: f(x)= 20.130022935768103
# differential_evolution step 448: f(x)= 20.130022935768103
# differential_evolution step 449: f(x)= 20.130022935768103
# differential_evolution step 450: f(x)= 20.130022935768103
# differential_evolution step 451: f(x)= 20.130022935768103
# differential_evolution step 452: f(x)= 20.130022935768103
# differential_evolution step 453: f(x)= 20.130022935768103
# differential_evolution step 454: f(x)= 20.130022935768103
# differential_evolution step 455: f(x)= 20.130022935768103
# differential_evolution step 456: f(x)= 20.130022935768103
# differential_evolution step 457: f(x)= 20.130022935768103
# differential_evolution step 458: f(x)= 20.130022935768103
# differential_evolution step 459: f(x)= 20.130022935768103
# differential_evolution step 460: f(x)= 20.130022935768103
# differential_evolution step 461: f(x)= 20.130022935768103
# differential_evolution step 462: f(x)= 20.130022935768103
# differential_evolution step 463: f(x)= 20.128823768106095
# differential_evolution step 464: f(x)= 20.128823768106095
# differential_evolution step 465: f(x)= 20.128823768106095
# differential_evolution step 466: f(x)= 20.128823768106095
# differential_evolution step 467: f(x)= 20.128823768106095
# differential_evolution step 468: f(x)= 20.128823768106095
# differential_evolution step 469: f(x)= 20.128823768106095
# differential_evolution step 470: f(x)= 20.128823768106095
# differential_evolution step 471: f(x)= 20.128823768106095
# differential_evolution step 472: f(x)= 20.128823768106095
# differential_evolution step 473: f(x)= 20.1283769464983
# differential_evolution step 474: f(x)= 20.1283769464983
# differential_evolution step 475: f(x)= 20.1283769464983
# differential_evolution step 476: f(x)= 20.1283769464983
# differential_evolution step 477: f(x)= 20.1283769464983
# differential_evolution step 478: f(x)= 20.1283769464983
# differential_evolution step 479: f(x)= 20.1283769464983
# differential_evolution step 480: f(x)= 20.1283769464983
# differential_evolution step 481: f(x)= 20.1283769464983
# differential_evolution step 482: f(x)= 20.1283769464983
# differential_evolution step 483: f(x)= 20.1283769464983
# differential_evolution step 484: f(x)= 20.1283769464983
# differential_evolution step 485: f(x)= 20.1283769464983
# differential_evolution step 486: f(x)= 20.1283769464983
# differential_evolution step 487: f(x)= 20.1283769464983
# differential_evolution step 488: f(x)= 20.12633127923089
# differential_evolution step 489: f(x)= 20.12633127923089
# differential_evolution step 490: f(x)= 20.12633127923089
# differential_evolution step 491: f(x)= 20.12633127923089
# differential_evolution step 492: f(x)= 20.12633127923089
# differential_evolution step 493: f(x)= 20.12633127923089
# differential_evolution step 494: f(x)= 20.12633127923089
# differential_evolution step 495: f(x)= 20.12633127923089
# differential_evolution step 496: f(x)= 20.12633127923089
# differential_evolution step 497: f(x)= 20.12633127923089
# differential_evolution step 498: f(x)= 20.12633127923089
# differential_evolution step 499: f(x)= 20.12633127923089
# differential_evolution step 500: f(x)= 20.12633127923089
# differential_evolution step 501: f(x)= 20.12633127923089
# differential_evolution step 502: f(x)= 20.12633127923089
# differential_evolution step 503: f(x)= 20.12633127923089
# differential_evolution step 504: f(x)= 20.12633127923089
# differential_evolution step 505: f(x)= 20.12633127923089
# differential_evolution step 506: f(x)= 20.12633127923089
# differential_evolution step 507: f(x)= 20.12633127923089
# differential_evolution step 508: f(x)= 20.12633127923089
# differential_evolution step 509: f(x)= 20.12633127923089
# differential_evolution step 510: f(x)= 20.12633127923089
# differential_evolution step 511: f(x)= 20.12633127923089
# differential_evolution step 512: f(x)= 20.12633127923089
# differential_evolution step 513: f(x)= 20.12633127923089
# differential_evolution step 514: f(x)= 20.12633127923089
# differential_evolution step 515: f(x)= 20.12633127923089
# differential_evolution step 516: f(x)= 20.12633127923089
# differential_evolution step 517: f(x)= 20.12633127923089
# differential_evolution step 518: f(x)= 20.12633127923089
# differential_evolution step 519: f(x)= 20.12633127923089
# differential_evolution step 520: f(x)= 20.12633127923089
# differential_evolution step 521: f(x)= 20.12633127923089
# differential_evolution step 522: f(x)= 20.12633127923089
# differential_evolution step 523: f(x)= 20.12633127923089
# differential_evolution step 524: f(x)= 20.12633127923089
# differential_evolution step 525: f(x)= 20.12633127923089
# differential_evolution step 526: f(x)= 20.12633127923089
# differential_evolution step 527: f(x)= 20.12633127923089
# differential_evolution step 528: f(x)= 20.12633127923089
# differential_evolution step 529: f(x)= 20.12633127923089
# differential_evolution step 530: f(x)= 20.12633127923089
# differential_evolution step 531: f(x)= 20.12633127923089
# differential_evolution step 532: f(x)= 20.12633127923089
# differential_evolution step 533: f(x)= 20.12633127923089
# differential_evolution step 534: f(x)= 20.12633127923089
# differential_evolution step 535: f(x)= 20.12633127923089
# differential_evolution step 536: f(x)= 20.12633127923089
# differential_evolution step 537: f(x)= 20.12633127923089
# differential_evolution step 538: f(x)= 20.12633127923089
# differential_evolution step 539: f(x)= 20.12633127923089
# differential_evolution step 540: f(x)= 20.12633127923089
# differential_evolution step 541: f(x)= 20.12633127923089
# differential_evolution step 542: f(x)= 20.12633127923089
# differential_evolution step 543: f(x)= 20.12633127923089
# differential_evolution step 544: f(x)= 20.12633127923089
# differential_evolution step 545: f(x)= 20.12633127923089
# differential_evolution step 546: f(x)= 20.12633127923089
# differential_evolution step 547: f(x)= 20.12633127923089
# differential_evolution step 548: f(x)= 20.12633127923089
# differential_evolution step 549: f(x)= 20.12633127923089
# differential_evolution step 550: f(x)= 20.12633127923089
# differential_evolution step 551: f(x)= 20.12633127923089
# differential_evolution step 552: f(x)= 20.12633127923089
# differential_evolution step 553: f(x)= 20.12633127923089
# differential_evolution step 554: f(x)= 20.12633127923089
# differential_evolution step 555: f(x)= 20.12633127923089
# differential_evolution step 556: f(x)= 20.12633127923089
# differential_evolution step 557: f(x)= 20.12633127923089
# differential_evolution step 558: f(x)= 20.12633127923089
# differential_evolution step 559: f(x)= 20.12633127923089
# differential_evolution step 560: f(x)= 20.12633127923089
# differential_evolution step 561: f(x)= 20.12633127923089
# differential_evolution step 562: f(x)= 20.12633127923089
# differential_evolution step 563: f(x)= 20.12633127923089
# differential_evolution step 564: f(x)= 20.12633127923089
# differential_evolution step 565: f(x)= 20.12633127923089
# differential_evolution step 566: f(x)= 20.12633127923089
# differential_evolution step 567: f(x)= 20.12633127923089
# differential_evolution step 568: f(x)= 20.12633127923089
# differential_evolution step 569: f(x)= 20.12633127923089
# differential_evolution step 570: f(x)= 20.12633127923089
# differential_evolution step 571: f(x)= 20.12633127923089
# differential_evolution step 572: f(x)= 20.12633127923089
# differential_evolution step 573: f(x)= 20.12633127923089
# differential_evolution step 574: f(x)= 20.12633127923089
# differential_evolution step 575: f(x)= 20.12633127923089
# differential_evolution step 576: f(x)= 20.12633127923089
# differential_evolution step 577: f(x)= 20.12633127923089
# differential_evolution step 578: f(x)= 20.12633127923089
# differential_evolution step 579: f(x)= 20.12633127923089
# differential_evolution step 580: f(x)= 20.12633127923089
# differential_evolution step 581: f(x)= 20.12633127923089
# differential_evolution step 582: f(x)= 20.12633127923089
# differential_evolution step 583: f(x)= 20.12633127923089
# differential_evolution step 584: f(x)= 20.12633127923089
# differential_evolution step 585: f(x)= 20.12633127923089
# differential_evolution step 586: f(x)= 20.12458242943678
# differential_evolution step 587: f(x)= 20.12159523846846
# differential_evolution step 588: f(x)= 20.12159523846846
# differential_evolution step 589: f(x)= 20.12159523846846
# differential_evolution step 590: f(x)= 20.12159523846846
# differential_evolution step 591: f(x)= 20.12159523846846
# differential_evolution step 592: f(x)= 20.12159523846846
# differential_evolution step 593: f(x)= 20.12159523846846
# differential_evolution step 594: f(x)= 20.121156610653
# differential_evolution step 595: f(x)= 20.121156610653
# differential_evolution step 596: f(x)= 20.121156610653
# differential_evolution step 597: f(x)= 20.121156610653
# differential_evolution step 598: f(x)= 20.121156610653
# differential_evolution step 599: f(x)= 20.121156610653
# differential_evolution step 600: f(x)= 20.121156610653
# differential_evolution step 601: f(x)= 20.121156610653
# differential_evolution step 602: f(x)= 20.121156610653
# differential_evolution step 603: f(x)= 20.121156610653
# differential_evolution step 604: f(x)= 20.121156610653
# differential_evolution step 605: f(x)= 20.121156610653
# differential_evolution step 606: f(x)= 20.121156610653
# differential_evolution step 607: f(x)= 20.121156610653
# differential_evolution step 608: f(x)= 20.121156610653
# differential_evolution step 609: f(x)= 20.121156610653
# differential_evolution step 610: f(x)= 20.121156610653
# differential_evolution step 611: f(x)= 20.121156610653
# differential_evolution step 612: f(x)= 20.121156610653
# differential_evolution step 613: f(x)= 20.121156610653
# differential_evolution step 614: f(x)= 20.121156610653
# differential_evolution step 615: f(x)= 20.121156610653
# differential_evolution step 616: f(x)= 20.121156610653
# differential_evolution step 617: f(x)= 20.121156610653
# differential_evolution step 618: f(x)= 20.121156610653
# differential_evolution step 619: f(x)= 20.121156610653
# differential_evolution step 620: f(x)= 20.121156610653
# differential_evolution step 621: f(x)= 20.121156610653
# differential_evolution step 622: f(x)= 20.121156610653
# differential_evolution step 623: f(x)= 20.121156610653
# differential_evolution step 624: f(x)= 20.121156610653
# differential_evolution step 625: f(x)= 20.121156610653
# differential_evolution step 626: f(x)= 20.121156610653
# differential_evolution step 627: f(x)= 20.121156610653
# differential_evolution step 628: f(x)= 20.121156610653
# differential_evolution step 629: f(x)= 20.121156610653
# differential_evolution step 630: f(x)= 20.121156610653
# differential_evolution step 631: f(x)= 20.121156610653
# differential_evolution step 632: f(x)= 20.121156610653
# differential_evolution step 633: f(x)= 20.121156610653
# differential_evolution step 634: f(x)= 20.121156610653
# differential_evolution step 635: f(x)= 20.121156610653
# differential_evolution step 636: f(x)= 20.121156610653
# differential_evolution step 637: f(x)= 20.121156610653
# differential_evolution step 638: f(x)= 20.121156610653
# differential_evolution step 639: f(x)= 20.121156610653
# differential_evolution step 640: f(x)= 20.121156610653
# differential_evolution step 641: f(x)= 20.121156610653
# differential_evolution step 642: f(x)= 20.121156610653
# differential_evolution step 643: f(x)= 20.121156610653
# differential_evolution step 644: f(x)= 20.121156610653
# differential_evolution step 645: f(x)= 20.121156610653
# differential_evolution step 646: f(x)= 20.121156610653
# differential_evolution step 647: f(x)= 20.121156610653
# differential_evolution step 648: f(x)= 20.121156610653
# differential_evolution step 649: f(x)= 20.121156610653
# differential_evolution step 650: f(x)= 20.121156610653
# differential_evolution step 651: f(x)= 20.121156610653
# differential_evolution step 652: f(x)= 20.121156610653
# differential_evolution step 653: f(x)= 20.121156610653
# differential_evolution step 654: f(x)= 20.121156610653
# differential_evolution step 655: f(x)= 20.121156610653
# differential_evolution step 656: f(x)= 20.12099393768909
# differential_evolution step 657: f(x)= 20.12099393768909
# differential_evolution step 658: f(x)= 20.12099393768909
# differential_evolution step 659: f(x)= 20.12099393768909
# differential_evolution step 660: f(x)= 20.12099393768909
# differential_evolution step 661: f(x)= 20.12099393768909
# differential_evolution step 662: f(x)= 20.12099393768909
# differential_evolution step 663: f(x)= 20.12099393768909
# differential_evolution step 664: f(x)= 20.12099393768909
# differential_evolution step 665: f(x)= 20.12099393768909
# differential_evolution step 666: f(x)= 20.12099393768909
# differential_evolution step 667: f(x)= 20.12099393768909
# differential_evolution step 668: f(x)= 20.12099393768909
# differential_evolution step 669: f(x)= 20.12004455279377
# differential_evolution step 670: f(x)= 20.12004455279377
# differential_evolution step 671: f(x)= 20.12004455279377
# differential_evolution step 672: f(x)= 20.11942713106225
# differential_evolution step 673: f(x)= 20.11942713106225
# differential_evolution step 674: f(x)= 20.11699733170869
# differential_evolution step 675: f(x)= 20.11699733170869
# differential_evolution step 676: f(x)= 20.11699733170869
# differential_evolution step 677: f(x)= 20.11699733170869
# differential_evolution step 678: f(x)= 20.11699733170869
# differential_evolution step 679: f(x)= 20.11699733170869
# differential_evolution step 680: f(x)= 20.11699733170869
# differential_evolution step 681: f(x)= 20.11699733170869
# differential_evolution step 682: f(x)= 20.11699733170869
# differential_evolution step 683: f(x)= 20.11699733170869
# differential_evolution step 684: f(x)= 20.116545022802292
# differential_evolution step 685: f(x)= 20.116545022802292
# differential_evolution step 686: f(x)= 20.116545022802292
# differential_evolution step 687: f(x)= 20.116545022802292
# differential_evolution step 688: f(x)= 20.116545022802292
# differential_evolution step 689: f(x)= 20.116545022802292
# differential_evolution step 690: f(x)= 20.116545022802292
# differential_evolution step 691: f(x)= 20.116545022802292
# differential_evolution step 692: f(x)= 20.116545022802292
# differential_evolution step 693: f(x)= 20.116545022802292
# differential_evolution step 694: f(x)= 20.116545022802292
# differential_evolution step 695: f(x)= 20.116545022802292
# differential_evolution step 696: f(x)= 20.116545022802292
# differential_evolution step 697: f(x)= 20.116545022802292
# differential_evolution step 698: f(x)= 20.116545022802292
# differential_evolution step 699: f(x)= 20.116545022802292
# differential_evolution step 700: f(x)= 20.116545022802292
# differential_evolution step 701: f(x)= 20.116545022802292
# differential_evolution step 702: f(x)= 20.115872199394957
# differential_evolution step 703: f(x)= 20.115872199394957
# differential_evolution step 704: f(x)= 20.115872199394957
# differential_evolution step 705: f(x)= 20.115872199394957
# differential_evolution step 706: f(x)= 20.115872199394957
# differential_evolution step 707: f(x)= 20.115872199394957
# differential_evolution step 708: f(x)= 20.115872199394957
# differential_evolution step 709: f(x)= 20.115872199394957
# differential_evolution step 710: f(x)= 20.115872199394957
# differential_evolution step 711: f(x)= 20.115872199394957
# differential_evolution step 712: f(x)= 20.115872199394957
# differential_evolution step 713: f(x)= 20.115872199394957
# differential_evolution step 714: f(x)= 20.115872199394957
# differential_evolution step 715: f(x)= 20.115872199394957
# differential_evolution step 716: f(x)= 20.115872199394957
# differential_evolution step 717: f(x)= 20.115872199394957
# differential_evolution step 718: f(x)= 20.115872199394957
# differential_evolution step 719: f(x)= 20.115872199394957
# differential_evolution step 720: f(x)= 20.115872199394957
# differential_evolution step 721: f(x)= 20.115872199394957
# differential_evolution step 722: f(x)= 20.115872199394957
# differential_evolution step 723: f(x)= 20.115872199394957
# differential_evolution step 724: f(x)= 20.115872199394957
# differential_evolution step 725: f(x)= 20.115872199394957
# differential_evolution step 726: f(x)= 20.115872199394957
# differential_evolution step 727: f(x)= 20.115872199394957
# differential_evolution step 728: f(x)= 20.115872199394957
# differential_evolution step 729: f(x)= 20.115872199394957
# differential_evolution step 730: f(x)= 20.115872199394957
# differential_evolution step 731: f(x)= 20.115872199394957
# differential_evolution step 732: f(x)= 20.115872199394957
# differential_evolution step 733: f(x)= 20.115872199394957
# differential_evolution step 734: f(x)= 20.115872199394957
# differential_evolution step 735: f(x)= 20.115244530096106
# differential_evolution step 736: f(x)= 20.114565095580897
# differential_evolution step 737: f(x)= 20.114565095580897
# differential_evolution step 738: f(x)= 20.114565095580897
# differential_evolution step 739: f(x)= 20.114565095580897
# differential_evolution step 740: f(x)= 20.114565095580897
# differential_evolution step 741: f(x)= 20.114565095580897
# differential_evolution step 742: f(x)= 20.114565095580897
# differential_evolution step 743: f(x)= 20.114565095580897
# differential_evolution step 744: f(x)= 20.114565095580897
# differential_evolution step 745: f(x)= 20.114565095580897
# differential_evolution step 746: f(x)= 20.114565095580897
# differential_evolution step 747: f(x)= 20.114565095580897
# differential_evolution step 748: f(x)= 20.114565095580897
# differential_evolution step 749: f(x)= 20.114565095580897
# differential_evolution step 750: f(x)= 20.114565095580897
# differential_evolution step 751: f(x)= 20.114565095580897
# differential_evolution step 752: f(x)= 20.114565095580897
# differential_evolution step 753: f(x)= 20.114565095580897
# differential_evolution step 754: f(x)= 20.1143270002908
# differential_evolution step 755: f(x)= 20.1143270002908
# differential_evolution step 756: f(x)= 20.1143270002908
# differential_evolution step 757: f(x)= 20.1143270002908
# differential_evolution step 758: f(x)= 20.1143270002908
# differential_evolution step 759: f(x)= 20.1143270002908
# differential_evolution step 760: f(x)= 20.1143270002908
# differential_evolution step 761: f(x)= 20.1143270002908
# differential_evolution step 762: f(x)= 20.1143270002908
# differential_evolution step 763: f(x)= 20.1143270002908
# differential_evolution step 764: f(x)= 20.1143270002908
# differential_evolution step 765: f(x)= 20.113407737728885
# differential_evolution step 766: f(x)= 20.113407737728885
# differential_evolution step 767: f(x)= 20.113407737728885
# differential_evolution step 768: f(x)= 20.113407737728885
# differential_evolution step 769: f(x)= 20.113407737728885
# differential_evolution step 770: f(x)= 20.113407737728885
# differential_evolution step 771: f(x)= 20.113407737728885
# differential_evolution step 772: f(x)= 20.113407737728885
# differential_evolution step 773: f(x)= 20.113407737728885
# differential_evolution step 774: f(x)= 20.113407737728885
# differential_evolution step 775: f(x)= 20.113407737728885
# differential_evolution step 776: f(x)= 20.113407737728885
# differential_evolution step 777: f(x)= 20.113407737728885
# differential_evolution step 778: f(x)= 20.113407737728885
# differential_evolution step 779: f(x)= 20.113115687795883
# differential_evolution step 780: f(x)= 20.113115687795883
# differential_evolution step 781: f(x)= 20.113115687795883
# differential_evolution step 782: f(x)= 20.113115687795883
# differential_evolution step 783: f(x)= 20.113115687795883
# differential_evolution step 784: f(x)= 20.113115687795883
# differential_evolution step 785: f(x)= 20.113115687795883
# differential_evolution step 786: f(x)= 20.113115687795883
# differential_evolution step 787: f(x)= 20.113115687795883
# differential_evolution step 788: f(x)= 20.113115687795883
# differential_evolution step 789: f(x)= 20.113115687795883
# differential_evolution step 790: f(x)= 20.113115687795883
# differential_evolution step 791: f(x)= 20.113115687795883
# differential_evolution step 792: f(x)= 20.113115687795883
# differential_evolution step 793: f(x)= 20.113115687795883
# differential_evolution step 794: f(x)= 20.113115687795883
# differential_evolution step 795: f(x)= 20.112807152966308
# differential_evolution step 796: f(x)= 20.112807152966308
# differential_evolution step 797: f(x)= 20.112807152966308
# differential_evolution step 798: f(x)= 20.112807152966308
# differential_evolution step 799: f(x)= 20.112807152966308
# differential_evolution step 800: f(x)= 20.112807152966308
# differential_evolution step 801: f(x)= 20.112807152966308
# differential_evolution step 802: f(x)= 20.112807152966308
# differential_evolution step 803: f(x)= 20.112807152966308
# differential_evolution step 804: f(x)= 20.112807152966308
# differential_evolution step 805: f(x)= 20.112807152966308
# differential_evolution step 806: f(x)= 20.112807152966308
# differential_evolution step 807: f(x)= 20.112494907212803
# differential_evolution step 808: f(x)= 20.112494907212803
# differential_evolution step 809: f(x)= 20.112494907212803
# differential_evolution step 810: f(x)= 20.112494907212803
# differential_evolution step 811: f(x)= 20.112494907212803
# differential_evolution step 812: f(x)= 20.112494907212803
# differential_evolution step 813: f(x)= 20.112494907212803
# differential_evolution step 814: f(x)= 20.112494907212803
# differential_evolution step 815: f(x)= 20.112494907212803
# differential_evolution step 816: f(x)= 20.112494907212803
# differential_evolution step 817: f(x)= 20.112494907212803
# differential_evolution step 818: f(x)= 20.112494907212803
# differential_evolution step 819: f(x)= 20.112494907212803
# differential_evolution step 820: f(x)= 20.112494907212803
# differential_evolution step 821: f(x)= 20.112494907212803
# differential_evolution step 822: f(x)= 20.11242272672509
# differential_evolution step 823: f(x)= 20.11242272672509
# differential_evolution step 824: f(x)= 20.11242272672509
# differential_evolution step 825: f(x)= 20.11242272672509
# differential_evolution step 826: f(x)= 20.11242272672509
# differential_evolution step 827: f(x)= 20.11242272672509
# differential_evolution step 828: f(x)= 20.11242272672509
# differential_evolution step 829: f(x)= 20.11242272672509
# differential_evolution step 830: f(x)= 20.11242272672509
# differential_evolution step 831: f(x)= 20.11242272672509
# differential_evolution step 832: f(x)= 20.11242272672509
# differential_evolution step 833: f(x)= 20.11242272672509
# differential_evolution step 834: f(x)= 20.11242272672509
# differential_evolution step 835: f(x)= 20.11242272672509
# differential_evolution step 836: f(x)= 20.11242272672509
# differential_evolution step 837: f(x)= 20.11242272672509
# differential_evolution step 838: f(x)= 20.11242272672509
# differential_evolution step 839: f(x)= 20.11242272672509
# differential_evolution step 840: f(x)= 20.11242272672509
# differential_evolution step 841: f(x)= 20.11242272672509
# differential_evolution step 842: f(x)= 20.11242272672509
# differential_evolution step 843: f(x)= 20.11242272672509
# differential_evolution step 844: f(x)= 20.11242272672509
# differential_evolution step 845: f(x)= 20.11242272672509
# differential_evolution step 846: f(x)= 20.11242272672509
# differential_evolution step 847: f(x)= 20.1118437281576
# differential_evolution step 848: f(x)= 20.1118437281576
# differential_evolution step 849: f(x)= 20.1118437281576
# differential_evolution step 850: f(x)= 20.1118437281576
# differential_evolution step 851: f(x)= 20.1118437281576
# differential_evolution step 852: f(x)= 20.1118437281576
# differential_evolution step 853: f(x)= 20.1118437281576
# differential_evolution step 854: f(x)= 20.1118437281576
# differential_evolution step 855: f(x)= 20.1118437281576
# differential_evolution step 856: f(x)= 20.11092356253291
# differential_evolution step 857: f(x)= 20.11092356253291
# differential_evolution step 858: f(x)= 20.11092356253291
# differential_evolution step 859: f(x)= 20.11092356253291
# differential_evolution step 860: f(x)= 20.11092356253291
# differential_evolution step 861: f(x)= 20.11092356253291
# differential_evolution step 862: f(x)= 20.11092356253291
# differential_evolution step 863: f(x)= 20.11092356253291
# differential_evolution step 864: f(x)= 20.11092356253291
# differential_evolution step 865: f(x)= 20.11092356253291
# differential_evolution step 866: f(x)= 20.11092356253291
# differential_evolution step 867: f(x)= 20.11092356253291
# differential_evolution step 868: f(x)= 20.11092356253291
# differential_evolution step 869: f(x)= 20.11092356253291
# differential_evolution step 870: f(x)= 20.11092356253291
# differential_evolution step 871: f(x)= 20.11092356253291
# differential_evolution step 872: f(x)= 20.11092356253291
# differential_evolution step 873: f(x)= 20.11092356253291
# differential_evolution step 874: f(x)= 20.11092356253291
# differential_evolution step 875: f(x)= 20.11092356253291
# differential_evolution step 876: f(x)= 20.11092356253291
# differential_evolution step 877: f(x)= 20.11055940735169
# differential_evolution step 878: f(x)= 20.11055940735169
# differential_evolution step 879: f(x)= 20.11055940735169
# differential_evolution step 880: f(x)= 20.110400517349824
# differential_evolution step 881: f(x)= 20.110400517349824
# differential_evolution step 882: f(x)= 20.110222508815518
# differential_evolution step 883: f(x)= 20.110222508815518
# differential_evolution step 884: f(x)= 20.110222508815518
# differential_evolution step 885: f(x)= 20.110222508815518
# differential_evolution step 886: f(x)= 20.110222508815518
# differential_evolution step 887: f(x)= 20.109956720803236
# differential_evolution step 888: f(x)= 20.109956720803236
# differential_evolution step 889: f(x)= 20.109956720803236
# differential_evolution step 890: f(x)= 20.109956720803236
# differential_evolution step 891: f(x)= 20.109956720803236
# differential_evolution step 892: f(x)= 20.109956720803236
# differential_evolution step 893: f(x)= 20.109956720803236
# differential_evolution step 894: f(x)= 20.10944803782819
# differential_evolution step 895: f(x)= 20.10944803782819
# differential_evolution step 896: f(x)= 20.10944803782819
# differential_evolution step 897: f(x)= 20.10944803782819
# differential_evolution step 898: f(x)= 20.10944803782819
# differential_evolution step 899: f(x)= 20.10944803782819
# differential_evolution step 900: f(x)= 20.10944803782819
# differential_evolution step 901: f(x)= 20.109236946008473
# differential_evolution step 902: f(x)= 20.109236946008473
# differential_evolution step 903: f(x)= 20.109236946008473
# differential_evolution step 904: f(x)= 20.109236946008473
# differential_evolution step 905: f(x)= 20.109236946008473
# differential_evolution step 906: f(x)= 20.108922747492617
# differential_evolution step 907: f(x)= 20.108922747492617
# differential_evolution step 908: f(x)= 20.108922747492617
# differential_evolution step 909: f(x)= 20.108650078653806
# differential_evolution step 910: f(x)= 20.108650078653806
# differential_evolution step 911: f(x)= 20.108650078653806
# differential_evolution step 912: f(x)= 20.108650078653806
# differential_evolution step 913: f(x)= 20.108650078653806
# differential_evolution step 914: f(x)= 20.10842013220436
# differential_evolution step 915: f(x)= 20.10842013220436
# differential_evolution step 916: f(x)= 20.10842013220436
# differential_evolution step 917: f(x)= 20.10842013220436
# differential_evolution step 918: f(x)= 20.10842013220436
# differential_evolution step 919: f(x)= 20.107940023714285
# differential_evolution step 920: f(x)= 20.107940023714285
# differential_evolution step 921: f(x)= 20.107940023714285
# differential_evolution step 922: f(x)= 20.107940023714285
# differential_evolution step 923: f(x)= 20.107940023714285
# differential_evolution step 924: f(x)= 20.107940023714285
# differential_evolution step 925: f(x)= 20.107940023714285
# differential_evolution step 926: f(x)= 20.107940023714285
# differential_evolution step 927: f(x)= 20.107940023714285
# differential_evolution step 928: f(x)= 20.107940023714285
# differential_evolution step 929: f(x)= 20.107940023714285
# differential_evolution step 930: f(x)= 20.107940023714285
# differential_evolution step 931: f(x)= 20.107940023714285
# differential_evolution step 932: f(x)= 20.107940023714285
# differential_evolution step 933: f(x)= 20.107940023714285
# differential_evolution step 934: f(x)= 20.107940023714285
# differential_evolution step 935: f(x)= 20.107940023714285
# differential_evolution step 936: f(x)= 20.107857883029723
# differential_evolution step 937: f(x)= 20.10771314114867
# differential_evolution step 938: f(x)= 20.10771314114867
# differential_evolution step 939: f(x)= 20.10771314114867
# differential_evolution step 940: f(x)= 20.107528329716942
# differential_evolution step 941: f(x)= 20.107528329716942
# differential_evolution step 942: f(x)= 20.107122453227333
# differential_evolution step 943: f(x)= 20.107122453227333
# differential_evolution step 944: f(x)= 20.106734703128314
# differential_evolution step 945: f(x)= 20.106734703128314
# differential_evolution step 946: f(x)= 20.106734703128314
# differential_evolution step 947: f(x)= 20.106734703128314
# differential_evolution step 948: f(x)= 20.106734703128314
# differential_evolution step 949: f(x)= 20.106560182175198
# differential_evolution step 950: f(x)= 20.106560182175198
# differential_evolution step 951: f(x)= 20.106560182175198
# differential_evolution step 952: f(x)= 20.106560182175198
# differential_evolution step 953: f(x)= 20.106560182175198
# differential_evolution step 954: f(x)= 20.106560182175198
# differential_evolution step 955: f(x)= 20.106560182175198
# differential_evolution step 956: f(x)= 20.106560182175198
# differential_evolution step 957: f(x)= 20.106560182175198
# differential_evolution step 958: f(x)= 20.106560182175198
# differential_evolution step 959: f(x)= 20.106560182175198
# differential_evolution step 960: f(x)= 20.106560182175198
# differential_evolution step 961: f(x)= 20.106560182175198
# differential_evolution step 962: f(x)= 20.106560182175198
# differential_evolution step 963: f(x)= 20.106560182175198
# differential_evolution step 964: f(x)= 20.106560182175198
# differential_evolution step 965: f(x)= 20.106560182175198
# differential_evolution step 966: f(x)= 20.106560182175198
# differential_evolution step 967: f(x)= 20.106560182175198
# differential_evolution step 968: f(x)= 20.106560182175198
# differential_evolution step 969: f(x)= 20.106560182175198
# differential_evolution step 970: f(x)= 20.106560182175198
# differential_evolution step 971: f(x)= 20.106560182175198
# differential_evolution step 972: f(x)= 20.106560182175198
# differential_evolution step 973: f(x)= 20.106560182175198
# differential_evolution step 974: f(x)= 20.106560182175198
# differential_evolution step 975: f(x)= 20.106560182175198
# differential_evolution step 976: f(x)= 20.106560182175198
# differential_evolution step 977: f(x)= 20.106560182175198
# differential_evolution step 978: f(x)= 20.106560182175198
# differential_evolution step 979: f(x)= 20.106560182175198
# differential_evolution step 980: f(x)= 20.106560182175198
# differential_evolution step 981: f(x)= 20.106560182175198
# differential_evolution step 982: f(x)= 20.106560182175198
# differential_evolution step 983: f(x)= 20.106560182175198
# differential_evolution step 984: f(x)= 20.106560182175198
# differential_evolution step 985: f(x)= 20.106560182175198
# differential_evolution step 986: f(x)= 20.106560182175198
# differential_evolution step 987: f(x)= 20.10655596293337
# differential_evolution step 988: f(x)= 20.10655596293337
# differential_evolution step 989: f(x)= 20.10655596293337
# differential_evolution step 990: f(x)= 20.10655596293337
# differential_evolution step 991: f(x)= 20.10655596293337
# differential_evolution step 992: f(x)= 20.10655596293337
# differential_evolution step 993: f(x)= 20.10655596293337
# differential_evolution step 994: f(x)= 20.10655596293337
# differential_evolution step 995: f(x)= 20.10655596293337
# differential_evolution step 996: f(x)= 20.10655596293337
# differential_evolution step 997: f(x)= 20.10655596293337
# differential_evolution step 998: f(x)= 20.10655596293337
# differential_evolution step 999: f(x)= 20.1063709376874
# differential_evolution step 1000: f(x)= 20.1063709376874
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [9.99999031e-02 4.99995811e+01 3.49193629e+00 3.64286241e+01
#  2.47224220e-02 1.91150361e+01 4.68353208e+00 5.95881471e+01
#  3.48346529e-01 3.05354221e+01 1.00037474e-01 6.80019200e+01]
# Chi quadro minimo: 20.10628164586378

# %%
# Plots:
params_curve_3, covariance_3 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params3, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[2], red_chi[2] = save_params(params_curve_3, covariance_3, radial_profile_HA, radial_profile_error_HA,x_axes, 3,  
                                       line_name="Three", output_prefix="fit")

aic[2] = AIC(x_axes, radial_profile_HA, chi_quadr[2], params_curve_3)
bic[2] = BIC(x_axes, radial_profile_HA, chi_quadr[2], params_curve_3)
print(aic[2], chi_quadr[2], bic[2], len(params_curve_3))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_3)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[8:12]), 'm--', label='Sérsic 3')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_3')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16324\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16324\111436280.py:9: RuntimeWarning: overflow encountered in exp
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16324\3846609059.py:9: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.1258, r_e=38.5023, n=3.4355, x_0=36.4835
# Sérsic 2: I_e=0.0263, r_e=10.8447, n=4.9633, x_0=59.5881
# Sérsic 3: I_e=0.3426, r_e=19.8889, n=0.0529, x_0=57.8422
# [1.17936106e-01 2.44074297e+01 1.30713304e+00 4.08430501e-01
#  7.17926195e-01 1.86256884e+02 3.96696681e+01 1.89236309e-01
#  1.04914447e+00 1.26127667e+01 1.12197691e-01 1.17463534e+01]
# 95.32582697778936
# 122.91203387434109 95.32582697778936 150.58786920964647 12
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16324\1721072346.py:17: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (20, 40),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (40, 50),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (50, 70),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (70, 80)
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params4 = result.x

print("Optimize parameters with differential_evolution:", best_params4)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 8116.83931831717
# differential_evolution step 2: f(x)= 2287.7880382797694
# differential_evolution step 3: f(x)= 1023.7403176852763
# differential_evolution step 4: f(x)= 1023.7403176852763
# differential_evolution step 5: f(x)= 1023.7403176852763
# differential_evolution step 6: f(x)= 809.0176046107388
# differential_evolution step 7: f(x)= 569.171134139561
# differential_evolution step 8: f(x)= 569.171134139561
# differential_evolution step 9: f(x)= 569.171134139561
# differential_evolution step 10: f(x)= 569.171134139561
# differential_evolution step 11: f(x)= 569.171134139561
# differential_evolution step 12: f(x)= 569.171134139561
# differential_evolution step 13: f(x)= 438.47943471203416
# differential_evolution step 14: f(x)= 438.47943471203416
# differential_evolution step 15: f(x)= 196.21751291922246
# differential_evolution step 16: f(x)= 196.21751291922246
# differential_evolution step 17: f(x)= 183.8644557867526
# differential_evolution step 18: f(x)= 183.8644557867526
# differential_evolution step 19: f(x)= 183.8644557867526
# differential_evolution step 20: f(x)= 183.8644557867526
# differential_evolution step 21: f(x)= 183.8644557867526
# differential_evolution step 22: f(x)= 183.8644557867526
# differential_evolution step 23: f(x)= 183.8644557867526
# differential_evolution step 24: f(x)= 122.28014281320985
# differential_evolution step 25: f(x)= 122.28014281320985
# differential_evolution step 26: f(x)= 122.28014281320985
# differential_evolution step 27: f(x)= 122.28014281320985
# differential_evolution step 28: f(x)= 122.28014281320985
# differential_evolution step 29: f(x)= 122.28014281320985
# differential_evolution step 30: f(x)= 122.28014281320985
# differential_evolution step 31: f(x)= 122.28014281320985
# differential_evolution step 32: f(x)= 122.28014281320985
# differential_evolution step 33: f(x)= 122.28014281320985
# differential_evolution step 34: f(x)= 120.56469924772188
# differential_evolution step 35: f(x)= 120.56469924772188
# differential_evolution step 36: f(x)= 120.56469924772188
# differential_evolution step 37: f(x)= 120.56469924772188
# differential_evolution step 38: f(x)= 120.56469924772188
# differential_evolution step 39: f(x)= 120.56469924772188
# differential_evolution step 40: f(x)= 120.56469924772188
# differential_evolution step 41: f(x)= 71.23113983954259
# differential_evolution step 42: f(x)= 71.23113983954259
# differential_evolution step 43: f(x)= 71.23113983954259
# differential_evolution step 44: f(x)= 71.23113983954259
# differential_evolution step 45: f(x)= 71.23113983954259
# differential_evolution step 46: f(x)= 71.23113983954259
# differential_evolution step 47: f(x)= 69.81575942966111
# differential_evolution step 48: f(x)= 69.81575942966111
# differential_evolution step 49: f(x)= 67.20718446127071
# differential_evolution step 50: f(x)= 57.66643829643426
# differential_evolution step 51: f(x)= 57.66643829643426
# differential_evolution step 52: f(x)= 57.66643829643426
# differential_evolution step 53: f(x)= 57.66643829643426
# differential_evolution step 54: f(x)= 57.66643829643426
# differential_evolution step 55: f(x)= 51.841964520095694
# differential_evolution step 56: f(x)= 51.841964520095694
# differential_evolution step 57: f(x)= 26.679001291789458
# differential_evolution step 58: f(x)= 26.679001291789458
# differential_evolution step 59: f(x)= 26.679001291789458
# differential_evolution step 60: f(x)= 26.679001291789458
# differential_evolution step 61: f(x)= 22.66407360385789
# differential_evolution step 62: f(x)= 22.66407360385789
# differential_evolution step 63: f(x)= 22.66407360385789
# differential_evolution step 64: f(x)= 22.66407360385789
# differential_evolution step 65: f(x)= 22.66407360385789
# differential_evolution step 66: f(x)= 22.66407360385789
# differential_evolution step 67: f(x)= 21.700008778098994
# differential_evolution step 68: f(x)= 21.700008778098994
# differential_evolution step 69: f(x)= 16.12824441586257
# differential_evolution step 70: f(x)= 16.12824441586257
# differential_evolution step 71: f(x)= 16.12824441586257
# differential_evolution step 72: f(x)= 16.12824441586257
# differential_evolution step 73: f(x)= 16.12824441586257
# differential_evolution step 74: f(x)= 16.12824441586257
# differential_evolution step 75: f(x)= 16.12824441586257
# differential_evolution step 76: f(x)= 16.12824441586257
# differential_evolution step 77: f(x)= 16.12824441586257
# differential_evolution step 78: f(x)= 13.843420426989645
# differential_evolution step 79: f(x)= 13.843420426989645
# differential_evolution step 80: f(x)= 13.843420426989645
# differential_evolution step 81: f(x)= 10.108770736708744
# differential_evolution step 82: f(x)= 10.108770736708744
# differential_evolution step 83: f(x)= 10.108770736708744
# differential_evolution step 84: f(x)= 7.365356608585294
# differential_evolution step 85: f(x)= 7.365356608585294
# differential_evolution step 86: f(x)= 7.365356608585294
# differential_evolution step 87: f(x)= 7.365356608585294
# differential_evolution step 88: f(x)= 7.365356608585294
# differential_evolution step 89: f(x)= 7.365356608585294
# differential_evolution step 90: f(x)= 7.365356608585294
# differential_evolution step 91: f(x)= 7.365356608585294
# differential_evolution step 92: f(x)= 7.365356608585294
# differential_evolution step 93: f(x)= 7.365356608585294
# differential_evolution step 94: f(x)= 7.365356608585294
# differential_evolution step 95: f(x)= 7.365356608585294
# differential_evolution step 96: f(x)= 7.365356608585294
# differential_evolution step 97: f(x)= 7.365356608585294
# differential_evolution step 98: f(x)= 7.365356608585294
# differential_evolution step 99: f(x)= 7.365356608585294
# differential_evolution step 100: f(x)= 7.365356608585294
# differential_evolution step 101: f(x)= 7.365356608585294
# differential_evolution step 102: f(x)= 6.90254144304517
# differential_evolution step 103: f(x)= 6.90254144304517
# differential_evolution step 104: f(x)= 5.699360554860428
# differential_evolution step 105: f(x)= 5.699360554860428
# differential_evolution step 106: f(x)= 5.184012213477745
# differential_evolution step 107: f(x)= 5.184012213477745
# differential_evolution step 108: f(x)= 5.003200448311993
# differential_evolution step 109: f(x)= 5.003200448311993
# differential_evolution step 110: f(x)= 4.175424520980685
# differential_evolution step 111: f(x)= 4.175424520980685
# differential_evolution step 112: f(x)= 3.9044054736231906
# differential_evolution step 113: f(x)= 3.6888787202694586
# differential_evolution step 114: f(x)= 3.6888787202694586
# differential_evolution step 115: f(x)= 3.6888787202694586
# differential_evolution step 116: f(x)= 3.6888787202694586
# differential_evolution step 117: f(x)= 3.6888787202694586
# differential_evolution step 118: f(x)= 3.6888787202694586
# differential_evolution step 119: f(x)= 3.6888787202694586
# differential_evolution step 120: f(x)= 3.6888787202694586
# differential_evolution step 121: f(x)= 3.6888787202694586
# differential_evolution step 122: f(x)= 3.6888787202694586
# differential_evolution step 123: f(x)= 3.545000366691407
# differential_evolution step 124: f(x)= 3.545000366691407
# differential_evolution step 125: f(x)= 3.545000366691407
# differential_evolution step 126: f(x)= 3.545000366691407
# differential_evolution step 127: f(x)= 3.442537925101588
# differential_evolution step 128: f(x)= 3.442537925101588
# differential_evolution step 129: f(x)= 3.442537925101588
# differential_evolution step 130: f(x)= 3.442537925101588
# differential_evolution step 131: f(x)= 3.442537925101588
# differential_evolution step 132: f(x)= 3.442537925101588
# differential_evolution step 133: f(x)= 3.442537925101588
# differential_evolution step 134: f(x)= 3.442537925101588
# differential_evolution step 135: f(x)= 3.442537925101588
# differential_evolution step 136: f(x)= 3.442537925101588
# differential_evolution step 137: f(x)= 3.442537925101588
# differential_evolution step 138: f(x)= 3.217165359917616
# differential_evolution step 139: f(x)= 3.217165359917616
# differential_evolution step 140: f(x)= 3.1878923081756336
# differential_evolution step 141: f(x)= 2.9623579419348607
# differential_evolution step 142: f(x)= 2.9623579419348607
# differential_evolution step 143: f(x)= 2.9623579419348607
# differential_evolution step 144: f(x)= 2.9623579419348607
# differential_evolution step 145: f(x)= 2.9623579419348607
# differential_evolution step 146: f(x)= 2.9623579419348607
# differential_evolution step 147: f(x)= 2.9623579419348607
# differential_evolution step 148: f(x)= 2.9623579419348607
# differential_evolution step 149: f(x)= 2.9623579419348607
# differential_evolution step 150: f(x)= 2.841626066748042
# differential_evolution step 151: f(x)= 2.841626066748042
# differential_evolution step 152: f(x)= 2.841626066748042
# differential_evolution step 153: f(x)= 2.841626066748042
# differential_evolution step 154: f(x)= 2.841626066748042
# differential_evolution step 155: f(x)= 2.841626066748042
# differential_evolution step 156: f(x)= 2.841626066748042
# differential_evolution step 157: f(x)= 2.841626066748042
# differential_evolution step 158: f(x)= 2.841626066748042
# differential_evolution step 159: f(x)= 2.841626066748042
# differential_evolution step 160: f(x)= 2.656763503682444
# differential_evolution step 161: f(x)= 2.656763503682444
# differential_evolution step 162: f(x)= 2.656763503682444
# differential_evolution step 163: f(x)= 2.656763503682444
# differential_evolution step 164: f(x)= 2.656763503682444
# differential_evolution step 165: f(x)= 2.656763503682444
# differential_evolution step 166: f(x)= 2.656763503682444
# differential_evolution step 167: f(x)= 2.656763503682444
# differential_evolution step 168: f(x)= 2.656763503682444
# differential_evolution step 169: f(x)= 2.656763503682444
# differential_evolution step 170: f(x)= 2.6428388063638772
# differential_evolution step 171: f(x)= 2.6428388063638772
# differential_evolution step 172: f(x)= 2.6428388063638772
# differential_evolution step 173: f(x)= 2.6428388063638772
# differential_evolution step 174: f(x)= 2.3869873536660373
# differential_evolution step 175: f(x)= 2.3869873536660373
# differential_evolution step 176: f(x)= 2.3869873536660373
# differential_evolution step 177: f(x)= 2.3869873536660373
# differential_evolution step 178: f(x)= 2.3869873536660373
# differential_evolution step 179: f(x)= 2.3869873536660373
# differential_evolution step 180: f(x)= 2.3869873536660373
# differential_evolution step 181: f(x)= 2.3869873536660373
# differential_evolution step 182: f(x)= 2.3869873536660373
# differential_evolution step 183: f(x)= 2.3869873536660373
# differential_evolution step 184: f(x)= 2.3869873536660373
# differential_evolution step 185: f(x)= 2.3869873536660373
# differential_evolution step 186: f(x)= 2.3869873536660373
# differential_evolution step 187: f(x)= 2.3869873536660373
# differential_evolution step 188: f(x)= 2.3091519775014078
# differential_evolution step 189: f(x)= 2.3091519775014078
# differential_evolution step 190: f(x)= 2.3091519775014078
# differential_evolution step 191: f(x)= 2.3091519775014078
# differential_evolution step 192: f(x)= 2.3091519775014078
# differential_evolution step 193: f(x)= 2.3091519775014078
# differential_evolution step 194: f(x)= 2.3091519775014078
# differential_evolution step 195: f(x)= 2.3091519775014078
# differential_evolution step 196: f(x)= 2.3091519775014078
# differential_evolution step 197: f(x)= 2.3091519775014078
# differential_evolution step 198: f(x)= 2.3091519775014078
# differential_evolution step 199: f(x)= 2.3091519775014078
# differential_evolution step 200: f(x)= 2.3091519775014078
# differential_evolution step 201: f(x)= 2.187513039040194
# differential_evolution step 202: f(x)= 2.187513039040194
# differential_evolution step 203: f(x)= 2.187513039040194
# differential_evolution step 204: f(x)= 2.187513039040194
# differential_evolution step 205: f(x)= 2.187513039040194
# differential_evolution step 206: f(x)= 2.187513039040194
# differential_evolution step 207: f(x)= 2.187513039040194
# differential_evolution step 208: f(x)= 2.187513039040194
# differential_evolution step 209: f(x)= 2.187513039040194
# differential_evolution step 210: f(x)= 2.187513039040194
# differential_evolution step 211: f(x)= 2.187513039040194
# differential_evolution step 212: f(x)= 2.187513039040194
# differential_evolution step 213: f(x)= 2.187513039040194
# differential_evolution step 214: f(x)= 2.187513039040194
# differential_evolution step 215: f(x)= 2.187513039040194
# differential_evolution step 216: f(x)= 2.187513039040194
# differential_evolution step 217: f(x)= 2.187513039040194
# differential_evolution step 218: f(x)= 2.1094110655359493
# differential_evolution step 219: f(x)= 2.1094110655359493
# differential_evolution step 220: f(x)= 2.1094110655359493
# differential_evolution step 221: f(x)= 2.1094110655359493
# differential_evolution step 222: f(x)= 2.1094110655359493
# differential_evolution step 223: f(x)= 2.1094110655359493
# differential_evolution step 224: f(x)= 2.1094110655359493
# differential_evolution step 225: f(x)= 2.1094110655359493
# differential_evolution step 226: f(x)= 2.1094110655359493
# differential_evolution step 227: f(x)= 2.1094110655359493
# differential_evolution step 228: f(x)= 2.1094110655359493
# differential_evolution step 229: f(x)= 2.1094110655359493
# differential_evolution step 230: f(x)= 2.103463592357408
# differential_evolution step 231: f(x)= 2.103463592357408
# differential_evolution step 232: f(x)= 2.087182494490559
# differential_evolution step 233: f(x)= 2.087182494490559
# differential_evolution step 234: f(x)= 2.087182494490559
# differential_evolution step 235: f(x)= 2.087182494490559
# differential_evolution step 236: f(x)= 2.087182494490559
# differential_evolution step 237: f(x)= 2.087182494490559
# differential_evolution step 238: f(x)= 2.0179100699181585
# differential_evolution step 239: f(x)= 2.0179100699181585
# differential_evolution step 240: f(x)= 2.0179100699181585
# differential_evolution step 241: f(x)= 2.0179100699181585
# differential_evolution step 242: f(x)= 2.0179100699181585
# differential_evolution step 243: f(x)= 2.0179100699181585
# differential_evolution step 244: f(x)= 2.0179100699181585
# differential_evolution step 245: f(x)= 2.0179100699181585
# differential_evolution step 246: f(x)= 2.0179100699181585
# differential_evolution step 247: f(x)= 2.0179100699181585
# differential_evolution step 248: f(x)= 2.0179100699181585
# differential_evolution step 249: f(x)= 2.0179100699181585
# differential_evolution step 250: f(x)= 2.0179100699181585
# differential_evolution step 251: f(x)= 2.0179100699181585
# differential_evolution step 252: f(x)= 2.0179100699181585
# differential_evolution step 253: f(x)= 2.0179100699181585
# differential_evolution step 254: f(x)= 2.0179100699181585
# differential_evolution step 255: f(x)= 1.9735939368668027
# differential_evolution step 256: f(x)= 1.9735939368668027
# differential_evolution step 257: f(x)= 1.9735939368668027
# differential_evolution step 258: f(x)= 1.8872166418493856
# differential_evolution step 259: f(x)= 1.8872166418493856
# differential_evolution step 260: f(x)= 1.8872166418493856
# differential_evolution step 261: f(x)= 1.8872166418493856
# differential_evolution step 262: f(x)= 1.8872166418493856
# differential_evolution step 263: f(x)= 1.8872166418493856
# differential_evolution step 264: f(x)= 1.8872166418493856
# differential_evolution step 265: f(x)= 1.8872166418493856
# differential_evolution step 266: f(x)= 1.8872166418493856
# differential_evolution step 267: f(x)= 1.8872166418493856
# differential_evolution step 268: f(x)= 1.8872166418493856
# differential_evolution step 269: f(x)= 1.8872166418493856
# differential_evolution step 270: f(x)= 1.8872166418493856
# differential_evolution step 271: f(x)= 1.8872166418493856
# differential_evolution step 272: f(x)= 1.8872166418493856
# differential_evolution step 273: f(x)= 1.8872166418493856
# differential_evolution step 274: f(x)= 1.8872166418493856
# differential_evolution step 275: f(x)= 1.8872166418493856
# differential_evolution step 276: f(x)= 1.8872166418493856
# differential_evolution step 277: f(x)= 1.8872166418493856
# differential_evolution step 278: f(x)= 1.8872166418493856
# differential_evolution step 279: f(x)= 1.8872166418493856
# differential_evolution step 280: f(x)= 1.8872166418493856
# differential_evolution step 281: f(x)= 1.8872166418493856
# differential_evolution step 282: f(x)= 1.8576980826677711
# differential_evolution step 283: f(x)= 1.8576980826677711
# differential_evolution step 284: f(x)= 1.8576980826677711
# differential_evolution step 285: f(x)= 1.8576980826677711
# differential_evolution step 286: f(x)= 1.8576980826677711
# differential_evolution step 287: f(x)= 1.8576980826677711
# differential_evolution step 288: f(x)= 1.8576980826677711
# differential_evolution step 289: f(x)= 1.8576980826677711
# differential_evolution step 290: f(x)= 1.8576980826677711
# differential_evolution step 291: f(x)= 1.8576980826677711
# differential_evolution step 292: f(x)= 1.8576980826677711
# differential_evolution step 293: f(x)= 1.8576980826677711
# differential_evolution step 294: f(x)= 1.841390523723868
# differential_evolution step 295: f(x)= 1.841390523723868
# differential_evolution step 296: f(x)= 1.841390523723868
# differential_evolution step 297: f(x)= 1.841390523723868
# differential_evolution step 298: f(x)= 1.841390523723868
# differential_evolution step 299: f(x)= 1.841390523723868
# differential_evolution step 300: f(x)= 1.841390523723868
# differential_evolution step 301: f(x)= 1.7893850917305296
# differential_evolution step 302: f(x)= 1.7893850917305296
# differential_evolution step 303: f(x)= 1.7893850917305296
# differential_evolution step 304: f(x)= 1.7893850917305296
# differential_evolution step 305: f(x)= 1.7893850917305296
# differential_evolution step 306: f(x)= 1.7893850917305296
# differential_evolution step 307: f(x)= 1.7893850917305296
# differential_evolution step 308: f(x)= 1.7893850917305296
# differential_evolution step 309: f(x)= 1.7893850917305296
# differential_evolution step 310: f(x)= 1.7893850917305296
# differential_evolution step 311: f(x)= 1.7893850917305296
# differential_evolution step 312: f(x)= 1.7823242526200234
# differential_evolution step 313: f(x)= 1.7823242526200234
# differential_evolution step 314: f(x)= 1.7823242526200234
# differential_evolution step 315: f(x)= 1.7823242526200234
# differential_evolution step 316: f(x)= 1.7823242526200234
# differential_evolution step 317: f(x)= 1.7823242526200234
# differential_evolution step 318: f(x)= 1.7631709214364448
# differential_evolution step 319: f(x)= 1.7631709214364448
# differential_evolution step 320: f(x)= 1.7631709214364448
# differential_evolution step 321: f(x)= 1.7631709214364448
# differential_evolution step 322: f(x)= 1.7631709214364448
# differential_evolution step 323: f(x)= 1.7631709214364448
# differential_evolution step 324: f(x)= 1.7380632744202802
# differential_evolution step 325: f(x)= 1.7236145002976344
# differential_evolution step 326: f(x)= 1.7236145002976344
# differential_evolution step 327: f(x)= 1.6963347651918537
# differential_evolution step 328: f(x)= 1.6963347651918537
# differential_evolution step 329: f(x)= 1.6963347651918537
# differential_evolution step 330: f(x)= 1.6933611860613609
# differential_evolution step 331: f(x)= 1.6933611860613609
# differential_evolution step 332: f(x)= 1.6933611860613609
# differential_evolution step 333: f(x)= 1.6933611860613609
# differential_evolution step 334: f(x)= 1.6933611860613609
# differential_evolution step 335: f(x)= 1.6933611860613609
# differential_evolution step 336: f(x)= 1.6933611860613609
# differential_evolution step 337: f(x)= 1.6933611860613609
# differential_evolution step 338: f(x)= 1.6933611860613609
# differential_evolution step 339: f(x)= 1.6933611860613609
# differential_evolution step 340: f(x)= 1.6933611860613609
# differential_evolution step 341: f(x)= 1.6933611860613609
# differential_evolution step 342: f(x)= 1.6933611860613609
# differential_evolution step 343: f(x)= 1.6933611860613609
# differential_evolution step 344: f(x)= 1.6933611860613609
# differential_evolution step 345: f(x)= 1.6933611860613609
# differential_evolution step 346: f(x)= 1.6933611860613609
# differential_evolution step 347: f(x)= 1.6933611860613609
# differential_evolution step 348: f(x)= 1.6933611860613609
# differential_evolution step 349: f(x)= 1.6903958956590832
# differential_evolution step 350: f(x)= 1.6903958956590832
# differential_evolution step 351: f(x)= 1.6903958956590832
# differential_evolution step 352: f(x)= 1.6825624695386807
# differential_evolution step 353: f(x)= 1.6825624695386807
# differential_evolution step 354: f(x)= 1.6825624695386807
# differential_evolution step 355: f(x)= 1.6825624695386807
# differential_evolution step 356: f(x)= 1.6825624695386807
# differential_evolution step 357: f(x)= 1.6825624695386807
# differential_evolution step 358: f(x)= 1.6825624695386807
# differential_evolution step 359: f(x)= 1.6825624695386807
# differential_evolution step 360: f(x)= 1.6825624695386807
# differential_evolution step 361: f(x)= 1.6825624695386807
# differential_evolution step 362: f(x)= 1.6560289508277901
# differential_evolution step 363: f(x)= 1.6560289508277901
# differential_evolution step 364: f(x)= 1.6226647189061447
# differential_evolution step 365: f(x)= 1.6226647189061447
# differential_evolution step 366: f(x)= 1.6226647189061447
# differential_evolution step 367: f(x)= 1.6226647189061447
# differential_evolution step 368: f(x)= 1.6226647189061447
# differential_evolution step 369: f(x)= 1.6226647189061447
# differential_evolution step 370: f(x)= 1.6226647189061447
# differential_evolution step 371: f(x)= 1.6226647189061447
# differential_evolution step 372: f(x)= 1.590145328646057
# differential_evolution step 373: f(x)= 1.590145328646057
# differential_evolution step 374: f(x)= 1.590145328646057
# differential_evolution step 375: f(x)= 1.5857141583574943
# differential_evolution step 376: f(x)= 1.5857141583574943
# differential_evolution step 377: f(x)= 1.5857141583574943
# differential_evolution step 378: f(x)= 1.5857141583574943
# differential_evolution step 379: f(x)= 1.5857141583574943
# differential_evolution step 380: f(x)= 1.5857141583574943
# differential_evolution step 381: f(x)= 1.5857141583574943
# differential_evolution step 382: f(x)= 1.5857141583574943
# differential_evolution step 383: f(x)= 1.5857141583574943
# differential_evolution step 384: f(x)= 1.5857141583574943
# differential_evolution step 385: f(x)= 1.5857141583574943
# differential_evolution step 386: f(x)= 1.5857141583574943
# differential_evolution step 387: f(x)= 1.5857141583574943
# differential_evolution step 388: f(x)= 1.5857141583574943
# differential_evolution step 389: f(x)= 1.5857141583574943
# differential_evolution step 390: f(x)= 1.5857141583574943
# differential_evolution step 391: f(x)= 1.5857141583574943
# differential_evolution step 392: f(x)= 1.5857141583574943
# differential_evolution step 393: f(x)= 1.5857141583574943
# differential_evolution step 394: f(x)= 1.5857141583574943
# differential_evolution step 395: f(x)= 1.5857141583574943
# differential_evolution step 396: f(x)= 1.5857141583574943
# differential_evolution step 397: f(x)= 1.5857141583574943
# differential_evolution step 398: f(x)= 1.5857141583574943
# differential_evolution step 399: f(x)= 1.5857141583574943
# differential_evolution step 400: f(x)= 1.5857141583574943
# differential_evolution step 401: f(x)= 1.5857141583574943
# differential_evolution step 402: f(x)= 1.5857141583574943
# differential_evolution step 403: f(x)= 1.5857141583574943
# differential_evolution step 404: f(x)= 1.5831930548496487
# differential_evolution step 405: f(x)= 1.5831930548496487
# differential_evolution step 406: f(x)= 1.5831930548496487
# differential_evolution step 407: f(x)= 1.5831930548496487
# differential_evolution step 408: f(x)= 1.5831930548496487
# differential_evolution step 409: f(x)= 1.5831930548496487
# differential_evolution step 410: f(x)= 1.5831930548496487
# differential_evolution step 411: f(x)= 1.5831930548496487
# differential_evolution step 412: f(x)= 1.5831930548496487
# differential_evolution step 413: f(x)= 1.5831930548496487
# differential_evolution step 414: f(x)= 1.5831930548496487
# differential_evolution step 415: f(x)= 1.5831930548496487
# differential_evolution step 416: f(x)= 1.5831930548496487
# differential_evolution step 417: f(x)= 1.5831930548496487
# differential_evolution step 418: f(x)= 1.5831930548496487
# differential_evolution step 419: f(x)= 1.5831930548496487
# differential_evolution step 420: f(x)= 1.5831930548496487
# differential_evolution step 421: f(x)= 1.5831930548496487
# differential_evolution step 422: f(x)= 1.5831930548496487
# differential_evolution step 423: f(x)= 1.5831930548496487
# differential_evolution step 424: f(x)= 1.5831930548496487
# differential_evolution step 425: f(x)= 1.5831930548496487
# differential_evolution step 426: f(x)= 1.5831930548496487
# differential_evolution step 427: f(x)= 1.5831930548496487
# differential_evolution step 428: f(x)= 1.5831930548496487
# differential_evolution step 429: f(x)= 1.5831930548496487
# differential_evolution step 430: f(x)= 1.5831930548496487
# differential_evolution step 431: f(x)= 1.5831930548496487
# differential_evolution step 432: f(x)= 1.5831930548496487
# differential_evolution step 433: f(x)= 1.5831930548496487
# differential_evolution step 434: f(x)= 1.5831930548496487
# differential_evolution step 435: f(x)= 1.5831930548496487
# differential_evolution step 436: f(x)= 1.5831930548496487
# differential_evolution step 437: f(x)= 1.5831930548496487
# differential_evolution step 438: f(x)= 1.5831930548496487
# differential_evolution step 439: f(x)= 1.555111900440456
# differential_evolution step 440: f(x)= 1.555111900440456
# differential_evolution step 441: f(x)= 1.555111900440456
# differential_evolution step 442: f(x)= 1.555111900440456
# differential_evolution step 443: f(x)= 1.555111900440456
# differential_evolution step 444: f(x)= 1.555111900440456
# differential_evolution step 445: f(x)= 1.555111900440456
# differential_evolution step 446: f(x)= 1.555111900440456
# differential_evolution step 447: f(x)= 1.555111900440456
# differential_evolution step 448: f(x)= 1.555111900440456
# differential_evolution step 449: f(x)= 1.555111900440456
# differential_evolution step 450: f(x)= 1.555111900440456
# differential_evolution step 451: f(x)= 1.555111900440456
# differential_evolution step 452: f(x)= 1.555111900440456
# differential_evolution step 453: f(x)= 1.5524625690314946
# differential_evolution step 454: f(x)= 1.5438129321798033
# differential_evolution step 455: f(x)= 1.5438129321798033
# differential_evolution step 456: f(x)= 1.5438129321798033
# differential_evolution step 457: f(x)= 1.5438129321798033
# differential_evolution step 458: f(x)= 1.5438129321798033
# differential_evolution step 459: f(x)= 1.5438129321798033
# differential_evolution step 460: f(x)= 1.5438129321798033
# differential_evolution step 461: f(x)= 1.5438129321798033
# differential_evolution step 462: f(x)= 1.5438129321798033
# differential_evolution step 463: f(x)= 1.543650060694827
# differential_evolution step 464: f(x)= 1.543650060694827
# differential_evolution step 465: f(x)= 1.5385206732926942
# differential_evolution step 466: f(x)= 1.5385206732926942
# differential_evolution step 467: f(x)= 1.5385206732926942
# differential_evolution step 468: f(x)= 1.5385206732926942
# differential_evolution step 469: f(x)= 1.5355181439902137
# differential_evolution step 470: f(x)= 1.5355181439902137
# differential_evolution step 471: f(x)= 1.5355181439902137
# differential_evolution step 472: f(x)= 1.5355181439902137
# differential_evolution step 473: f(x)= 1.517258254445302
# differential_evolution step 474: f(x)= 1.517258254445302
# differential_evolution step 475: f(x)= 1.517258254445302
# differential_evolution step 476: f(x)= 1.517258254445302
# differential_evolution step 477: f(x)= 1.517258254445302
# differential_evolution step 478: f(x)= 1.517258254445302
# differential_evolution step 479: f(x)= 1.5150720348500284
# differential_evolution step 480: f(x)= 1.5150720348500284
# differential_evolution step 481: f(x)= 1.5150720348500284
# differential_evolution step 482: f(x)= 1.5150720348500284
# differential_evolution step 483: f(x)= 1.5150720348500284
# differential_evolution step 484: f(x)= 1.5150720348500284
# differential_evolution step 485: f(x)= 1.5150720348500284
# differential_evolution step 486: f(x)= 1.5150720348500284
# differential_evolution step 487: f(x)= 1.5150720348500284
# differential_evolution step 488: f(x)= 1.5150720348500284
# differential_evolution step 489: f(x)= 1.5150720348500284
# differential_evolution step 490: f(x)= 1.5150720348500284
# differential_evolution step 491: f(x)= 1.5150720348500284
# differential_evolution step 492: f(x)= 1.5150720348500284
# differential_evolution step 493: f(x)= 1.5150720348500284
# differential_evolution step 494: f(x)= 1.5150720348500284
# differential_evolution step 495: f(x)= 1.5150720348500284
# differential_evolution step 496: f(x)= 1.5150720348500284
# differential_evolution step 497: f(x)= 1.5150720348500284
# differential_evolution step 498: f(x)= 1.5150720348500284
# differential_evolution step 499: f(x)= 1.5150720348500284
# differential_evolution step 500: f(x)= 1.5150720348500284
# differential_evolution step 501: f(x)= 1.5150720348500284
# differential_evolution step 502: f(x)= 1.5150720348500284
# differential_evolution step 503: f(x)= 1.5128575308841332
# differential_evolution step 504: f(x)= 1.5128575308841332
# differential_evolution step 505: f(x)= 1.511239562089564
# differential_evolution step 506: f(x)= 1.511239562089564
# differential_evolution step 507: f(x)= 1.5106031556538722
# differential_evolution step 508: f(x)= 1.504546479140222
# differential_evolution step 509: f(x)= 1.504546479140222
# differential_evolution step 510: f(x)= 1.504546479140222
# differential_evolution step 511: f(x)= 1.504546479140222
# differential_evolution step 512: f(x)= 1.504546479140222
# differential_evolution step 513: f(x)= 1.504546479140222
# differential_evolution step 514: f(x)= 1.5014547088887333
# differential_evolution step 515: f(x)= 1.5014547088887333
# differential_evolution step 516: f(x)= 1.5014547088887333
# differential_evolution step 517: f(x)= 1.5014547088887333
# differential_evolution step 518: f(x)= 1.5014547088887333
# differential_evolution step 519: f(x)= 1.5014547088887333
# differential_evolution step 520: f(x)= 1.4982012007663013
# differential_evolution step 521: f(x)= 1.4982012007663013
# differential_evolution step 522: f(x)= 1.4887153473283663
# differential_evolution step 523: f(x)= 1.4887153473283663
# differential_evolution step 524: f(x)= 1.4887153473283663
# differential_evolution step 525: f(x)= 1.4887153473283663
# differential_evolution step 526: f(x)= 1.4887153473283663
# differential_evolution step 527: f(x)= 1.4716588371950359
# differential_evolution step 528: f(x)= 1.4716588371950359
# differential_evolution step 529: f(x)= 1.4716588371950359
# differential_evolution step 530: f(x)= 1.4716588371950359
# differential_evolution step 531: f(x)= 1.4716588371950359
# differential_evolution step 532: f(x)= 1.4716588371950359
# differential_evolution step 533: f(x)= 1.4716588371950359
# differential_evolution step 534: f(x)= 1.4716588371950359
# differential_evolution step 535: f(x)= 1.4716588371950359
# differential_evolution step 536: f(x)= 1.4716588371950359
# differential_evolution step 537: f(x)= 1.4716588371950359
# differential_evolution step 538: f(x)= 1.4716588371950359
# differential_evolution step 539: f(x)= 1.4716588371950359
# differential_evolution step 540: f(x)= 1.4716588371950359
# differential_evolution step 541: f(x)= 1.4716588371950359
# differential_evolution step 542: f(x)= 1.4716588371950359
# differential_evolution step 543: f(x)= 1.4716588371950359
# differential_evolution step 544: f(x)= 1.4716588371950359
# differential_evolution step 545: f(x)= 1.4716588371950359
# differential_evolution step 546: f(x)= 1.4716588371950359
# differential_evolution step 547: f(x)= 1.4716588371950359
# differential_evolution step 548: f(x)= 1.4716588371950359
# differential_evolution step 549: f(x)= 1.4716588371950359
# differential_evolution step 550: f(x)= 1.4716588371950359
# differential_evolution step 551: f(x)= 1.4716588371950359
# differential_evolution step 552: f(x)= 1.4716588371950359
# differential_evolution step 553: f(x)= 1.4590661869575423
# differential_evolution step 554: f(x)= 1.4590661869575423
# differential_evolution step 555: f(x)= 1.4537630224467946
# differential_evolution step 556: f(x)= 1.4537630224467946
# differential_evolution step 557: f(x)= 1.4537630224467946
# differential_evolution step 558: f(x)= 1.4537630224467946
# differential_evolution step 559: f(x)= 1.4537630224467946
# differential_evolution step 560: f(x)= 1.4537630224467946
# differential_evolution step 561: f(x)= 1.4537630224467946
# differential_evolution step 562: f(x)= 1.4537630224467946
# differential_evolution step 563: f(x)= 1.4537630224467946
# differential_evolution step 564: f(x)= 1.4537630224467946
# differential_evolution step 565: f(x)= 1.4537630224467946
# differential_evolution step 566: f(x)= 1.4537630224467946
# differential_evolution step 567: f(x)= 1.4537630224467946
# differential_evolution step 568: f(x)= 1.4537630224467946
# differential_evolution step 569: f(x)= 1.4537630224467946
# differential_evolution step 570: f(x)= 1.4537630224467946
# differential_evolution step 571: f(x)= 1.4537630224467946
# differential_evolution step 572: f(x)= 1.4537630224467946
# differential_evolution step 573: f(x)= 1.4537630224467946
# differential_evolution step 574: f(x)= 1.4537630224467946
# differential_evolution step 575: f(x)= 1.4537630224467946
# differential_evolution step 576: f(x)= 1.4537630224467946
# differential_evolution step 577: f(x)= 1.4537630224467946
# differential_evolution step 578: f(x)= 1.4537630224467946
# differential_evolution step 579: f(x)= 1.4537630224467946
# differential_evolution step 580: f(x)= 1.4537630224467946
# differential_evolution step 581: f(x)= 1.4537630224467946
# differential_evolution step 582: f(x)= 1.4433940946781147
# differential_evolution step 583: f(x)= 1.4433940946781147
# differential_evolution step 584: f(x)= 1.4433940946781147
# differential_evolution step 585: f(x)= 1.4433940946781147
# differential_evolution step 586: f(x)= 1.4433940946781147
# differential_evolution step 587: f(x)= 1.4433940946781147
# differential_evolution step 588: f(x)= 1.4433940946781147
# differential_evolution step 589: f(x)= 1.4433940946781147
# differential_evolution step 590: f(x)= 1.4433940946781147
# differential_evolution step 591: f(x)= 1.4433940946781147
# differential_evolution step 592: f(x)= 1.4433940946781147
# differential_evolution step 593: f(x)= 1.4433940946781147
# differential_evolution step 594: f(x)= 1.4433940946781147
# differential_evolution step 595: f(x)= 1.4433940946781147
# differential_evolution step 596: f(x)= 1.4433940946781147
# differential_evolution step 597: f(x)= 1.4433940946781147
# differential_evolution step 598: f(x)= 1.4433940946781147
# differential_evolution step 599: f(x)= 1.4433940946781147
# differential_evolution step 600: f(x)= 1.4433940946781147
# differential_evolution step 601: f(x)= 1.4433940946781147
# differential_evolution step 602: f(x)= 1.4433940946781147
# differential_evolution step 603: f(x)= 1.4341578597680809
# differential_evolution step 604: f(x)= 1.4341578597680809
# differential_evolution step 605: f(x)= 1.4341578597680809
# differential_evolution step 606: f(x)= 1.4341578597680809
# differential_evolution step 607: f(x)= 1.4341578597680809
# differential_evolution step 608: f(x)= 1.4341578597680809
# differential_evolution step 609: f(x)= 1.4341578597680809
# differential_evolution step 610: f(x)= 1.4341578597680809
# differential_evolution step 611: f(x)= 1.4341578597680809
# differential_evolution step 612: f(x)= 1.4341578597680809
# differential_evolution step 613: f(x)= 1.4341578597680809
# differential_evolution step 614: f(x)= 1.4341578597680809
# differential_evolution step 615: f(x)= 1.4341578597680809
# differential_evolution step 616: f(x)= 1.4341578597680809
# differential_evolution step 617: f(x)= 1.4341578597680809
# differential_evolution step 618: f(x)= 1.4341578597680809
# differential_evolution step 619: f(x)= 1.4341578597680809
# differential_evolution step 620: f(x)= 1.4341578597680809
# differential_evolution step 621: f(x)= 1.4341578597680809
# differential_evolution step 622: f(x)= 1.4341578597680809
# differential_evolution step 623: f(x)= 1.4341578597680809
# differential_evolution step 624: f(x)= 1.4341578597680809
# differential_evolution step 625: f(x)= 1.4341578597680809
# differential_evolution step 626: f(x)= 1.4341578597680809
# differential_evolution step 627: f(x)= 1.4341578597680809
# differential_evolution step 628: f(x)= 1.4341578597680809
# differential_evolution step 629: f(x)= 1.4341578597680809
# differential_evolution step 630: f(x)= 1.4341578597680809
# differential_evolution step 631: f(x)= 1.4315294526535665
# differential_evolution step 632: f(x)= 1.4315294526535665
# differential_evolution step 633: f(x)= 1.4315294526535665
# differential_evolution step 634: f(x)= 1.4315294526535665
# differential_evolution step 635: f(x)= 1.4315294526535665
# differential_evolution step 636: f(x)= 1.4315294526535665
# differential_evolution step 637: f(x)= 1.4315294526535665
# differential_evolution step 638: f(x)= 1.4315294526535665
# differential_evolution step 639: f(x)= 1.4315294526535665
# differential_evolution step 640: f(x)= 1.4315294526535665
# differential_evolution step 641: f(x)= 1.4315294526535665
# differential_evolution step 642: f(x)= 1.4315294526535665
# differential_evolution step 643: f(x)= 1.4315294526535665
# differential_evolution step 644: f(x)= 1.4315294526535665
# differential_evolution step 645: f(x)= 1.4315294526535665
# differential_evolution step 646: f(x)= 1.4315294526535665
# differential_evolution step 647: f(x)= 1.4315294526535665
# differential_evolution step 648: f(x)= 1.4284516761726611
# differential_evolution step 649: f(x)= 1.4284516761726611
# differential_evolution step 650: f(x)= 1.4284516761726611
# differential_evolution step 651: f(x)= 1.4284516761726611
# differential_evolution step 652: f(x)= 1.4284516761726611
# differential_evolution step 653: f(x)= 1.4284516761726611
# differential_evolution step 654: f(x)= 1.4269819987135282
# differential_evolution step 655: f(x)= 1.4269819987135282
# differential_evolution step 656: f(x)= 1.4269819987135282
# differential_evolution step 657: f(x)= 1.4269819987135282
# differential_evolution step 658: f(x)= 1.4269819987135282
# differential_evolution step 659: f(x)= 1.4269819987135282
# differential_evolution step 660: f(x)= 1.4269819987135282
# differential_evolution step 661: f(x)= 1.4269819987135282
# differential_evolution step 662: f(x)= 1.4269819987135282
# differential_evolution step 663: f(x)= 1.4269819987135282
# differential_evolution step 664: f(x)= 1.4269819987135282
# differential_evolution step 665: f(x)= 1.4269819987135282
# differential_evolution step 666: f(x)= 1.4269819987135282
# differential_evolution step 667: f(x)= 1.4269819987135282
# differential_evolution step 668: f(x)= 1.4269819987135282
# differential_evolution step 669: f(x)= 1.4269819987135282
# differential_evolution step 670: f(x)= 1.422982470176318
# differential_evolution step 671: f(x)= 1.422982470176318
# differential_evolution step 672: f(x)= 1.422982470176318
# differential_evolution step 673: f(x)= 1.422982470176318
# differential_evolution step 674: f(x)= 1.422982470176318
# differential_evolution step 675: f(x)= 1.422982470176318
# differential_evolution step 676: f(x)= 1.422982470176318
# differential_evolution step 677: f(x)= 1.422982470176318
# differential_evolution step 678: f(x)= 1.422982470176318
# differential_evolution step 679: f(x)= 1.422982470176318
# differential_evolution step 680: f(x)= 1.422982470176318
# differential_evolution step 681: f(x)= 1.4175025224311233
# differential_evolution step 682: f(x)= 1.4175025224311233
# differential_evolution step 683: f(x)= 1.4093924414533618
# differential_evolution step 684: f(x)= 1.4093924414533618
# differential_evolution step 685: f(x)= 1.4093924414533618
# differential_evolution step 686: f(x)= 1.4093924414533618
# differential_evolution step 687: f(x)= 1.4093924414533618
# differential_evolution step 688: f(x)= 1.4093924414533618
# differential_evolution step 689: f(x)= 1.4093924414533618
# differential_evolution step 690: f(x)= 1.4093924414533618
# differential_evolution step 691: f(x)= 1.4093924414533618
# differential_evolution step 692: f(x)= 1.4093924414533618
# differential_evolution step 693: f(x)= 1.4093924414533618
# differential_evolution step 694: f(x)= 1.4093924414533618
# differential_evolution step 695: f(x)= 1.4093924414533618
# differential_evolution step 696: f(x)= 1.4093924414533618
# differential_evolution step 697: f(x)= 1.4093924414533618
# differential_evolution step 698: f(x)= 1.4093924414533618
# differential_evolution step 699: f(x)= 1.4093924414533618
# differential_evolution step 700: f(x)= 1.4093924414533618
# differential_evolution step 701: f(x)= 1.4093924414533618
# differential_evolution step 702: f(x)= 1.4093924414533618
# differential_evolution step 703: f(x)= 1.4093924414533618
# differential_evolution step 704: f(x)= 1.4093924414533618
# differential_evolution step 705: f(x)= 1.4093924414533618
# differential_evolution step 706: f(x)= 1.4093924414533618
# differential_evolution step 707: f(x)= 1.4093924414533618
# differential_evolution step 708: f(x)= 1.4093924414533618
# differential_evolution step 709: f(x)= 1.4093924414533618
# differential_evolution step 710: f(x)= 1.4093924414533618
# differential_evolution step 711: f(x)= 1.4093924414533618
# differential_evolution step 712: f(x)= 1.4093924414533618
# differential_evolution step 713: f(x)= 1.4093924414533618
# differential_evolution step 714: f(x)= 1.4093924414533618
# differential_evolution step 715: f(x)= 1.4093924414533618
# differential_evolution step 716: f(x)= 1.4093924414533618
# differential_evolution step 717: f(x)= 1.4093924414533618
# differential_evolution step 718: f(x)= 1.4093924414533618
# differential_evolution step 719: f(x)= 1.4093924414533618
# differential_evolution step 720: f(x)= 1.4093924414533618
# differential_evolution step 721: f(x)= 1.4093924414533618
# differential_evolution step 722: f(x)= 1.4093924414533618
# differential_evolution step 723: f(x)= 1.4093924414533618
# differential_evolution step 724: f(x)= 1.4093924414533618
# differential_evolution step 725: f(x)= 1.4078250434306239
# differential_evolution step 726: f(x)= 1.4078250434306239
# differential_evolution step 727: f(x)= 1.4078250434306239
# differential_evolution step 728: f(x)= 1.4078250434306239
# differential_evolution step 729: f(x)= 1.4078250434306239
# differential_evolution step 730: f(x)= 1.403843523885739
# differential_evolution step 731: f(x)= 1.403843523885739
# differential_evolution step 732: f(x)= 1.403843523885739
# differential_evolution step 733: f(x)= 1.403843523885739
# differential_evolution step 734: f(x)= 1.403843523885739
# differential_evolution step 735: f(x)= 1.403843523885739
# differential_evolution step 736: f(x)= 1.403843523885739
# differential_evolution step 737: f(x)= 1.403843523885739
# differential_evolution step 738: f(x)= 1.403843523885739
# differential_evolution step 739: f(x)= 1.403843523885739
# differential_evolution step 740: f(x)= 1.403843523885739
# differential_evolution step 741: f(x)= 1.403843523885739
# differential_evolution step 742: f(x)= 1.403843523885739
# differential_evolution step 743: f(x)= 1.403843523885739
# differential_evolution step 744: f(x)= 1.403843523885739
# differential_evolution step 745: f(x)= 1.403843523885739
# differential_evolution step 746: f(x)= 1.403843523885739
# differential_evolution step 747: f(x)= 1.403843523885739
# differential_evolution step 748: f(x)= 1.403843523885739
# differential_evolution step 749: f(x)= 1.403843523885739
# differential_evolution step 750: f(x)= 1.403843523885739
# differential_evolution step 751: f(x)= 1.403843523885739
# differential_evolution step 752: f(x)= 1.403843523885739
# differential_evolution step 753: f(x)= 1.403843523885739
# differential_evolution step 754: f(x)= 1.403843523885739
# differential_evolution step 755: f(x)= 1.403843523885739
# differential_evolution step 756: f(x)= 1.4009010844955592
# differential_evolution step 757: f(x)= 1.4009010844955592
# differential_evolution step 758: f(x)= 1.400252539155624
# differential_evolution step 759: f(x)= 1.400252539155624
# differential_evolution step 760: f(x)= 1.400252539155624
# differential_evolution step 761: f(x)= 1.400252539155624
# differential_evolution step 762: f(x)= 1.400252539155624
# differential_evolution step 763: f(x)= 1.400252539155624
# differential_evolution step 764: f(x)= 1.400252539155624
# differential_evolution step 765: f(x)= 1.3936142990042157
# differential_evolution step 766: f(x)= 1.3908651874411777
# differential_evolution step 767: f(x)= 1.3908651874411777
# differential_evolution step 768: f(x)= 1.3908651874411777
# differential_evolution step 769: f(x)= 1.3908651874411777
# differential_evolution step 770: f(x)= 1.3908651874411777
# differential_evolution step 771: f(x)= 1.3908651874411777
# differential_evolution step 772: f(x)= 1.3908651874411777
# differential_evolution step 773: f(x)= 1.3908651874411777
# differential_evolution step 774: f(x)= 1.3908651874411777
# differential_evolution step 775: f(x)= 1.3908651874411777
# differential_evolution step 776: f(x)= 1.3908651874411777
# differential_evolution step 777: f(x)= 1.3908651874411777
# differential_evolution step 778: f(x)= 1.3908651874411777
# differential_evolution step 779: f(x)= 1.3908651874411777
# differential_evolution step 780: f(x)= 1.3908651874411777
# differential_evolution step 781: f(x)= 1.3908651874411777
# differential_evolution step 782: f(x)= 1.3908651874411777
# differential_evolution step 783: f(x)= 1.3884081527147305
# differential_evolution step 784: f(x)= 1.3884081527147305
# differential_evolution step 785: f(x)= 1.3884081527147305
# differential_evolution step 786: f(x)= 1.3884081527147305
# differential_evolution step 787: f(x)= 1.3884081527147305
# differential_evolution step 788: f(x)= 1.3884081527147305
# differential_evolution step 789: f(x)= 1.3884081527147305
# differential_evolution step 790: f(x)= 1.3884081527147305
# differential_evolution step 791: f(x)= 1.3884081527147305
# differential_evolution step 792: f(x)= 1.3884081527147305
# differential_evolution step 793: f(x)= 1.3884081527147305
# differential_evolution step 794: f(x)= 1.3884081527147305
# differential_evolution step 795: f(x)= 1.3884081527147305
# differential_evolution step 796: f(x)= 1.3884081527147305
# differential_evolution step 797: f(x)= 1.3884081527147305
# differential_evolution step 798: f(x)= 1.3884081527147305
# differential_evolution step 799: f(x)= 1.3884081527147305
# differential_evolution step 800: f(x)= 1.3884081527147305
# differential_evolution step 801: f(x)= 1.3884081527147305
# differential_evolution step 802: f(x)= 1.3884081527147305
# differential_evolution step 803: f(x)= 1.3884081527147305
# differential_evolution step 804: f(x)= 1.3884081527147305
# differential_evolution step 805: f(x)= 1.3884081527147305
# differential_evolution step 806: f(x)= 1.3884081527147305
# differential_evolution step 807: f(x)= 1.3884081527147305
# differential_evolution step 808: f(x)= 1.3884081527147305
# differential_evolution step 809: f(x)= 1.3884081527147305
# differential_evolution step 810: f(x)= 1.3884081527147305
# differential_evolution step 811: f(x)= 1.3850399786107122
# differential_evolution step 812: f(x)= 1.3850399786107122
# differential_evolution step 813: f(x)= 1.3850399786107122
# differential_evolution step 814: f(x)= 1.3844896622305451
# differential_evolution step 815: f(x)= 1.384005255261174
# differential_evolution step 816: f(x)= 1.384005255261174
# differential_evolution step 817: f(x)= 1.384005255261174
# differential_evolution step 818: f(x)= 1.384005255261174
# differential_evolution step 819: f(x)= 1.3798211484043121
# differential_evolution step 820: f(x)= 1.3798211484043121
# differential_evolution step 821: f(x)= 1.3798211484043121
# differential_evolution step 822: f(x)= 1.3798211484043121
# differential_evolution step 823: f(x)= 1.3798211484043121
# differential_evolution step 824: f(x)= 1.3798211484043121
# differential_evolution step 825: f(x)= 1.3798211484043121
# differential_evolution step 826: f(x)= 1.3798211484043121
# differential_evolution step 827: f(x)= 1.3798211484043121
# differential_evolution step 828: f(x)= 1.3793925377812655
# differential_evolution step 829: f(x)= 1.3793925377812655
# differential_evolution step 830: f(x)= 1.3793925377812655
# differential_evolution step 831: f(x)= 1.3793925377812655
# differential_evolution step 832: f(x)= 1.3793925377812655
# differential_evolution step 833: f(x)= 1.3793925377812655
# differential_evolution step 834: f(x)= 1.3793925377812655
# differential_evolution step 835: f(x)= 1.3793925377812655
# differential_evolution step 836: f(x)= 1.3793925377812655
# differential_evolution step 837: f(x)= 1.3793925377812655
# differential_evolution step 838: f(x)= 1.3650250069979677
# differential_evolution step 839: f(x)= 1.3650250069979677
# differential_evolution step 840: f(x)= 1.3650250069979677
# differential_evolution step 841: f(x)= 1.3650250069979677
# differential_evolution step 842: f(x)= 1.3650250069979677
# differential_evolution step 843: f(x)= 1.3650250069979677
# differential_evolution step 844: f(x)= 1.3650250069979677
# differential_evolution step 845: f(x)= 1.3650250069979677
# differential_evolution step 846: f(x)= 1.3650250069979677
# differential_evolution step 847: f(x)= 1.3650250069979677
# differential_evolution step 848: f(x)= 1.3650250069979677
# differential_evolution step 849: f(x)= 1.3650250069979677
# differential_evolution step 850: f(x)= 1.3650250069979677
# differential_evolution step 851: f(x)= 1.3650250069979677
# differential_evolution step 852: f(x)= 1.3650250069979677
# differential_evolution step 853: f(x)= 1.3650250069979677
# differential_evolution step 854: f(x)= 1.3650250069979677
# differential_evolution step 855: f(x)= 1.3650250069979677
# differential_evolution step 856: f(x)= 1.3650250069979677
# differential_evolution step 857: f(x)= 1.3650250069979677
# differential_evolution step 858: f(x)= 1.3650250069979677
# differential_evolution step 859: f(x)= 1.3650250069979677
# differential_evolution step 860: f(x)= 1.3650250069979677
# differential_evolution step 861: f(x)= 1.3650250069979677
# differential_evolution step 862: f(x)= 1.3650250069979677
# differential_evolution step 863: f(x)= 1.3650250069979677
# differential_evolution step 864: f(x)= 1.3650250069979677
# differential_evolution step 865: f(x)= 1.3650250069979677
# differential_evolution step 866: f(x)= 1.3650250069979677
# differential_evolution step 867: f(x)= 1.3650250069979677
# differential_evolution step 868: f(x)= 1.3650250069979677
# differential_evolution step 869: f(x)= 1.3650250069979677
# differential_evolution step 870: f(x)= 1.3650250069979677
# differential_evolution step 871: f(x)= 1.3650250069979677
# differential_evolution step 872: f(x)= 1.3650250069979677
# differential_evolution step 873: f(x)= 1.3650250069979677
# differential_evolution step 874: f(x)= 1.3650250069979677
# differential_evolution step 875: f(x)= 1.3650250069979677
# differential_evolution step 876: f(x)= 1.3650250069979677
# differential_evolution step 877: f(x)= 1.3650250069979677
# differential_evolution step 878: f(x)= 1.3650250069979677
# differential_evolution step 879: f(x)= 1.3650250069979677
# differential_evolution step 880: f(x)= 1.3650250069979677
# differential_evolution step 881: f(x)= 1.3641671255266241
# differential_evolution step 882: f(x)= 1.3641671255266241
# differential_evolution step 883: f(x)= 1.3641671255266241
# differential_evolution step 884: f(x)= 1.3641671255266241
# differential_evolution step 885: f(x)= 1.3641671255266241
# differential_evolution step 886: f(x)= 1.3641671255266241
# differential_evolution step 887: f(x)= 1.3641671255266241
# differential_evolution step 888: f(x)= 1.3641671255266241
# differential_evolution step 889: f(x)= 1.3641671255266241
# differential_evolution step 890: f(x)= 1.3641671255266241
# differential_evolution step 891: f(x)= 1.3641671255266241
# differential_evolution step 892: f(x)= 1.3641671255266241
# differential_evolution step 893: f(x)= 1.3641671255266241
# differential_evolution step 894: f(x)= 1.3641671255266241
# differential_evolution step 895: f(x)= 1.3641671255266241
# differential_evolution step 896: f(x)= 1.3641671255266241
# differential_evolution step 897: f(x)= 1.3641671255266241
# differential_evolution step 898: f(x)= 1.3641671255266241
# differential_evolution step 899: f(x)= 1.3641671255266241
# differential_evolution step 900: f(x)= 1.3627022605258143
# differential_evolution step 901: f(x)= 1.3627022605258143
# differential_evolution step 902: f(x)= 1.3627022605258143
# differential_evolution step 903: f(x)= 1.3627022605258143
# differential_evolution step 904: f(x)= 1.3627022605258143
# differential_evolution step 905: f(x)= 1.3627022605258143
# differential_evolution step 906: f(x)= 1.3598040247047276
# differential_evolution step 907: f(x)= 1.3596643260248193
# differential_evolution step 908: f(x)= 1.3596643260248193
# differential_evolution step 909: f(x)= 1.3596643260248193
# differential_evolution step 910: f(x)= 1.3596643260248193
# differential_evolution step 911: f(x)= 1.3596643260248193
# differential_evolution step 912: f(x)= 1.3596643260248193
# differential_evolution step 913: f(x)= 1.3596643260248193
# differential_evolution step 914: f(x)= 1.3596643260248193
# differential_evolution step 915: f(x)= 1.3596643260248193
# differential_evolution step 916: f(x)= 1.3547761972774648
# differential_evolution step 917: f(x)= 1.3547761972774648
# differential_evolution step 918: f(x)= 1.3510409561598709
# differential_evolution step 919: f(x)= 1.3510409561598709
# differential_evolution step 920: f(x)= 1.3510409561598709
# differential_evolution step 921: f(x)= 1.3510409561598709
# differential_evolution step 922: f(x)= 1.3510409561598709
# differential_evolution step 923: f(x)= 1.3510409561598709
# differential_evolution step 924: f(x)= 1.3510409561598709
# differential_evolution step 925: f(x)= 1.3510409561598709
# differential_evolution step 926: f(x)= 1.3510409561598709
# differential_evolution step 927: f(x)= 1.3510409561598709
# differential_evolution step 928: f(x)= 1.3510409561598709
# differential_evolution step 929: f(x)= 1.3510409561598709
# differential_evolution step 930: f(x)= 1.3510409561598709
# differential_evolution step 931: f(x)= 1.3510409561598709
# differential_evolution step 932: f(x)= 1.3510409561598709
# differential_evolution step 933: f(x)= 1.3510409561598709
# differential_evolution step 934: f(x)= 1.3510409561598709
# differential_evolution step 935: f(x)= 1.3510409561598709
# differential_evolution step 936: f(x)= 1.3510409561598709
# differential_evolution step 937: f(x)= 1.3492224751535769
# differential_evolution step 938: f(x)= 1.3492224751535769
# differential_evolution step 939: f(x)= 1.3492224751535769
# differential_evolution step 940: f(x)= 1.3492224751535769
# differential_evolution step 941: f(x)= 1.3492224751535769
# differential_evolution step 942: f(x)= 1.3492224751535769
# differential_evolution step 943: f(x)= 1.3491452726810051
# differential_evolution step 944: f(x)= 1.346346525652573
# differential_evolution step 945: f(x)= 1.3443672136302944
# differential_evolution step 946: f(x)= 1.3443672136302944
# differential_evolution step 947: f(x)= 1.3443672136302944
# differential_evolution step 948: f(x)= 1.3443672136302944
# differential_evolution step 949: f(x)= 1.3443672136302944
# differential_evolution step 950: f(x)= 1.3398686440151164
# differential_evolution step 951: f(x)= 1.3398686440151164
# differential_evolution step 952: f(x)= 1.3398686440151164
# differential_evolution step 953: f(x)= 1.3398686440151164
# differential_evolution step 954: f(x)= 1.3398686440151164
# differential_evolution step 955: f(x)= 1.3398686440151164
# differential_evolution step 956: f(x)= 1.3398686440151164
# differential_evolution step 957: f(x)= 1.3398686440151164
# differential_evolution step 958: f(x)= 1.3398686440151164
# differential_evolution step 959: f(x)= 1.3398686440151164
# differential_evolution step 960: f(x)= 1.3398686440151164
# differential_evolution step 961: f(x)= 1.3398686440151164
# differential_evolution step 962: f(x)= 1.3398686440151164
# differential_evolution step 963: f(x)= 1.3398686440151164
# differential_evolution step 964: f(x)= 1.3398686440151164
# differential_evolution step 965: f(x)= 1.3392379002942287
# differential_evolution step 966: f(x)= 1.3392379002942287
# differential_evolution step 967: f(x)= 1.3392379002942287
# differential_evolution step 968: f(x)= 1.3392379002942287
# differential_evolution step 969: f(x)= 1.3392379002942287
# differential_evolution step 970: f(x)= 1.337404669439877
# differential_evolution step 971: f(x)= 1.337404669439877
# differential_evolution step 972: f(x)= 1.3340063203303192
# differential_evolution step 973: f(x)= 1.3340063203303192
# differential_evolution step 974: f(x)= 1.3340063203303192
# differential_evolution step 975: f(x)= 1.3340063203303192
# differential_evolution step 976: f(x)= 1.3340063203303192
# differential_evolution step 977: f(x)= 1.3340063203303192
# differential_evolution step 978: f(x)= 1.3340063203303192
# differential_evolution step 979: f(x)= 1.3340063203303192
# differential_evolution step 980: f(x)= 1.3340063203303192
# differential_evolution step 981: f(x)= 1.3340063203303192
# differential_evolution step 982: f(x)= 1.3340063203303192
# differential_evolution step 983: f(x)= 1.3340063203303192
# differential_evolution step 984: f(x)= 1.3340063203303192
# differential_evolution step 985: f(x)= 1.3340063203303192
# differential_evolution step 986: f(x)= 1.3340063203303192
# differential_evolution step 987: f(x)= 1.3340063203303192
# differential_evolution step 988: f(x)= 1.3340063203303192
# differential_evolution step 989: f(x)= 1.3340063203303192
# differential_evolution step 990: f(x)= 1.3340063203303192
# differential_evolution step 991: f(x)= 1.3340063203303192
# differential_evolution step 992: f(x)= 1.3340063203303192
# differential_evolution step 993: f(x)= 1.3340063203303192
# differential_evolution step 994: f(x)= 1.3340063203303192
# differential_evolution step 995: f(x)= 1.3340063203303192
# differential_evolution step 996: f(x)= 1.3340063203303192
# differential_evolution step 997: f(x)= 1.3340063203303192
# differential_evolution step 998: f(x)= 1.3340063203303192
# differential_evolution step 999: f(x)= 1.3340063203303192
# differential_evolution step 1000: f(x)= 1.3340063203303192
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [ 0.79925137  9.1872053   1.95875555 36.1684056   0.22177782 11.33434195
#   1.80448029 41.98704294  0.27531156  6.09118404  2.55157464 59.53865633
#   0.08360424 23.55768344  1.37793768 71.5684351 ]
# Chi quadro minimo: 1.3340063203303192

# %%
# Plots:
params_curve_4, covariance_4 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params4, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[3], red_chi[3] = save_params(params_curve_4, covariance_4, radial_profile_HA, radial_profile_error_HA, x_axes, 4, line_name="Four", output_prefix="fit")

aic[3] = AIC(x_axes, radial_profile_HA, chi_quadr[3], params_curve_4)
bic[3] = BIC(x_axes, radial_profile_HA, chi_quadr[3], params_curve_4)
print(aic[3], chi_quadr[3], bic[3], len(params_curve_4))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_4)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[12:16]), color='orange', linestyle='--', label='Sérsic 4')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_4')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16324\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16324\1747244794.py:10: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.9665, r_e=8.4074, n=1.8048, x_0=36.1970
# Sérsic 2: I_e=0.2393, r_e=8.9609, n=1.7869, x_0=42.1719
# Sérsic 3: I_e=0.1617, r_e=10.0411, n=2.8657, x_0=59.5386
# Sérsic 4: I_e=0.0439, r_e=34.7665, n=1.7951, x_0=72.1090
# [1.86873576e-01 1.36372102e+00 1.43170543e-01 4.78192644e-02
#  3.55380734e-01 1.22086516e+01 1.03576715e+00 1.62609977e-01
#  9.56717124e-01 3.96934942e+01 6.70518937e+00 2.46809075e-03
#  4.28297223e-02 2.21314217e+01 5.70049593e-01 4.75697696e-01]
# 8.730336866903267
# 47.28455373437315 8.730336866903267 82.41305984271274 16
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =  [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (20, 40),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (40, 50),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (50, 70),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (70, 80),
    
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (19, 21),   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params5 = result.x

print("Optimize parameters with differential_evolution:", best_params5)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 40607.254850374455
# differential_evolution step 2: f(x)= 37956.17186481341
# differential_evolution step 3: f(x)= 37956.17186481341
# differential_evolution step 4: f(x)= 7013.925771013001
# differential_evolution step 5: f(x)= 4527.106897956232
# differential_evolution step 6: f(x)= 975.3778585023368
# differential_evolution step 7: f(x)= 975.3778585023368
# differential_evolution step 8: f(x)= 975.3778585023368
# differential_evolution step 9: f(x)= 975.3778585023368
# differential_evolution step 10: f(x)= 975.3778585023368
# differential_evolution step 11: f(x)= 975.3778585023368
# differential_evolution step 12: f(x)= 975.3778585023368
# differential_evolution step 13: f(x)= 975.3778585023368
# differential_evolution step 14: f(x)= 975.3778585023368
# differential_evolution step 15: f(x)= 975.3778585023368
# differential_evolution step 16: f(x)= 867.8798610566614
# differential_evolution step 17: f(x)= 734.9301076829197
# differential_evolution step 18: f(x)= 734.9301076829197
# differential_evolution step 19: f(x)= 734.9301076829197
# differential_evolution step 20: f(x)= 734.9301076829197
# differential_evolution step 21: f(x)= 201.12163609968556
# differential_evolution step 22: f(x)= 201.12163609968556
# differential_evolution step 23: f(x)= 201.12163609968556
# differential_evolution step 24: f(x)= 201.12163609968556
# differential_evolution step 25: f(x)= 201.12163609968556
# differential_evolution step 26: f(x)= 201.12163609968556
# differential_evolution step 27: f(x)= 201.12163609968556
# differential_evolution step 28: f(x)= 201.12163609968556
# differential_evolution step 29: f(x)= 201.12163609968556
# differential_evolution step 30: f(x)= 201.12163609968556
# differential_evolution step 31: f(x)= 201.12163609968556
# differential_evolution step 32: f(x)= 201.12163609968556
# differential_evolution step 33: f(x)= 138.71383601949722
# differential_evolution step 34: f(x)= 138.71383601949722
# differential_evolution step 35: f(x)= 125.61007680535816
# differential_evolution step 36: f(x)= 125.61007680535816
# differential_evolution step 37: f(x)= 118.0465856893776
# differential_evolution step 38: f(x)= 118.0465856893776
# differential_evolution step 39: f(x)= 118.0465856893776
# differential_evolution step 40: f(x)= 118.0465856893776
# differential_evolution step 41: f(x)= 118.0465856893776
# differential_evolution step 42: f(x)= 118.0465856893776
# differential_evolution step 43: f(x)= 118.0465856893776
# differential_evolution step 44: f(x)= 118.0465856893776
# differential_evolution step 45: f(x)= 118.0465856893776
# differential_evolution step 46: f(x)= 118.0465856893776
# differential_evolution step 47: f(x)= 118.0465856893776
# differential_evolution step 48: f(x)= 118.0465856893776
# differential_evolution step 49: f(x)= 118.0465856893776
# differential_evolution step 50: f(x)= 77.688548382093
# differential_evolution step 51: f(x)= 77.688548382093
# differential_evolution step 52: f(x)= 77.688548382093
# differential_evolution step 53: f(x)= 77.688548382093
# differential_evolution step 54: f(x)= 77.688548382093
# differential_evolution step 55: f(x)= 77.688548382093
# differential_evolution step 56: f(x)= 77.688548382093
# differential_evolution step 57: f(x)= 77.688548382093
# differential_evolution step 58: f(x)= 77.688548382093
# differential_evolution step 59: f(x)= 77.688548382093
# differential_evolution step 60: f(x)= 77.688548382093
# differential_evolution step 61: f(x)= 77.688548382093
# differential_evolution step 62: f(x)= 77.688548382093
# differential_evolution step 63: f(x)= 77.688548382093
# differential_evolution step 64: f(x)= 77.688548382093
# differential_evolution step 65: f(x)= 73.61455363577834
# differential_evolution step 66: f(x)= 73.61455363577834
# differential_evolution step 67: f(x)= 73.61455363577834
# differential_evolution step 68: f(x)= 73.61455363577834
# differential_evolution step 69: f(x)= 73.61455363577834
# differential_evolution step 70: f(x)= 73.61455363577834
# differential_evolution step 71: f(x)= 73.61455363577834
# differential_evolution step 72: f(x)= 73.61455363577834
# differential_evolution step 73: f(x)= 73.61455363577834
# differential_evolution step 74: f(x)= 73.61455363577834
# differential_evolution step 75: f(x)= 73.61455363577834
# differential_evolution step 76: f(x)= 73.61455363577834
# differential_evolution step 77: f(x)= 73.61455363577834
# differential_evolution step 78: f(x)= 73.61455363577834
# differential_evolution step 79: f(x)= 62.245478159282065
# differential_evolution step 80: f(x)= 62.18585641552464
# differential_evolution step 81: f(x)= 50.39348964364972
# differential_evolution step 82: f(x)= 50.39348964364972
# differential_evolution step 83: f(x)= 46.693839153062065
# differential_evolution step 84: f(x)= 46.693839153062065
# differential_evolution step 85: f(x)= 46.693839153062065
# differential_evolution step 86: f(x)= 46.693839153062065
# differential_evolution step 87: f(x)= 46.693839153062065
# differential_evolution step 88: f(x)= 46.693839153062065
# differential_evolution step 89: f(x)= 46.693839153062065
# differential_evolution step 90: f(x)= 46.693839153062065
# differential_evolution step 91: f(x)= 46.693839153062065
# differential_evolution step 92: f(x)= 46.693839153062065
# differential_evolution step 93: f(x)= 46.693839153062065
# differential_evolution step 94: f(x)= 46.693839153062065
# differential_evolution step 95: f(x)= 46.693839153062065
# differential_evolution step 96: f(x)= 37.112021686920436
# differential_evolution step 97: f(x)= 37.112021686920436
# differential_evolution step 98: f(x)= 37.112021686920436
# differential_evolution step 99: f(x)= 37.112021686920436
# differential_evolution step 100: f(x)= 37.112021686920436
# differential_evolution step 101: f(x)= 37.112021686920436
# differential_evolution step 102: f(x)= 37.112021686920436
# differential_evolution step 103: f(x)= 37.112021686920436
# differential_evolution step 104: f(x)= 37.112021686920436
# differential_evolution step 105: f(x)= 37.112021686920436
# differential_evolution step 106: f(x)= 31.693229405169134
# differential_evolution step 107: f(x)= 31.693229405169134
# differential_evolution step 108: f(x)= 31.693229405169134
# differential_evolution step 109: f(x)= 31.693229405169134
# differential_evolution step 110: f(x)= 27.41541665206984
# differential_evolution step 111: f(x)= 27.41541665206984
# differential_evolution step 112: f(x)= 27.41541665206984
# differential_evolution step 113: f(x)= 27.41541665206984
# differential_evolution step 114: f(x)= 27.41541665206984
# differential_evolution step 115: f(x)= 27.41541665206984
# differential_evolution step 116: f(x)= 27.41541665206984
# differential_evolution step 117: f(x)= 27.41541665206984
# differential_evolution step 118: f(x)= 27.41541665206984
# differential_evolution step 119: f(x)= 27.41541665206984
# differential_evolution step 120: f(x)= 27.41541665206984
# differential_evolution step 121: f(x)= 27.41541665206984
# differential_evolution step 122: f(x)= 27.41541665206984
# differential_evolution step 123: f(x)= 27.41541665206984
# differential_evolution step 124: f(x)= 27.41541665206984
# differential_evolution step 125: f(x)= 27.41541665206984
# differential_evolution step 126: f(x)= 27.41541665206984
# differential_evolution step 127: f(x)= 27.41541665206984
# differential_evolution step 128: f(x)= 23.19601816262847
# differential_evolution step 129: f(x)= 23.19601816262847
# differential_evolution step 130: f(x)= 23.19601816262847
# differential_evolution step 131: f(x)= 22.251193529255577
# differential_evolution step 132: f(x)= 22.251193529255577
# differential_evolution step 133: f(x)= 22.251193529255577
# differential_evolution step 134: f(x)= 22.251193529255577
# differential_evolution step 135: f(x)= 22.251193529255577
# differential_evolution step 136: f(x)= 22.251193529255577
# differential_evolution step 137: f(x)= 22.251193529255577
# differential_evolution step 138: f(x)= 18.78725282848136
# differential_evolution step 139: f(x)= 18.78725282848136
# differential_evolution step 140: f(x)= 18.78725282848136
# differential_evolution step 141: f(x)= 18.78725282848136
# differential_evolution step 142: f(x)= 18.78725282848136
# differential_evolution step 143: f(x)= 18.78725282848136
# differential_evolution step 144: f(x)= 18.78725282848136
# differential_evolution step 145: f(x)= 18.78725282848136
# differential_evolution step 146: f(x)= 18.78725282848136
# differential_evolution step 147: f(x)= 18.78725282848136
# differential_evolution step 148: f(x)= 18.78725282848136
# differential_evolution step 149: f(x)= 18.78725282848136
# differential_evolution step 150: f(x)= 18.78725282848136
# differential_evolution step 151: f(x)= 18.78725282848136
# differential_evolution step 152: f(x)= 18.78725282848136
# differential_evolution step 153: f(x)= 18.78725282848136
# differential_evolution step 154: f(x)= 18.78725282848136
# differential_evolution step 155: f(x)= 18.78725282848136
# differential_evolution step 156: f(x)= 18.78725282848136
# differential_evolution step 157: f(x)= 18.78725282848136
# differential_evolution step 158: f(x)= 14.027820533564869
# differential_evolution step 159: f(x)= 14.027820533564869
# differential_evolution step 160: f(x)= 14.027820533564869
# differential_evolution step 161: f(x)= 14.027820533564869
# differential_evolution step 162: f(x)= 14.027820533564869
# differential_evolution step 163: f(x)= 14.027820533564869
# differential_evolution step 164: f(x)= 14.027820533564869
# differential_evolution step 165: f(x)= 14.027820533564869
# differential_evolution step 166: f(x)= 14.027820533564869
# differential_evolution step 167: f(x)= 14.027820533564869
# differential_evolution step 168: f(x)= 14.027820533564869
# differential_evolution step 169: f(x)= 13.352473179612787
# differential_evolution step 170: f(x)= 13.352473179612787
# differential_evolution step 171: f(x)= 13.352473179612787
# differential_evolution step 172: f(x)= 13.352473179612787
# differential_evolution step 173: f(x)= 13.352473179612787
# differential_evolution step 174: f(x)= 13.352473179612787
# differential_evolution step 175: f(x)= 13.352473179612787
# differential_evolution step 176: f(x)= 13.352473179612787
# differential_evolution step 177: f(x)= 13.352473179612787
# differential_evolution step 178: f(x)= 13.332886605498818
# differential_evolution step 179: f(x)= 13.332886605498818
# differential_evolution step 180: f(x)= 11.506762844238622
# differential_evolution step 181: f(x)= 10.967599589189694
# differential_evolution step 182: f(x)= 8.154508776075975
# differential_evolution step 183: f(x)= 8.154508776075975
# differential_evolution step 184: f(x)= 8.154508776075975
# differential_evolution step 185: f(x)= 8.154508776075975
# differential_evolution step 186: f(x)= 8.154508776075975
# differential_evolution step 187: f(x)= 8.154508776075975
# differential_evolution step 188: f(x)= 8.154508776075975
# differential_evolution step 189: f(x)= 8.154508776075975
# differential_evolution step 190: f(x)= 7.319103087285133
# differential_evolution step 191: f(x)= 7.319103087285133
# differential_evolution step 192: f(x)= 7.319103087285133
# differential_evolution step 193: f(x)= 7.319103087285133
# differential_evolution step 194: f(x)= 7.319103087285133
# differential_evolution step 195: f(x)= 7.319103087285133
# differential_evolution step 196: f(x)= 7.319103087285133
# differential_evolution step 197: f(x)= 7.319103087285133
# differential_evolution step 198: f(x)= 7.319103087285133
# differential_evolution step 199: f(x)= 7.319103087285133
# differential_evolution step 200: f(x)= 6.9026165576221645
# differential_evolution step 201: f(x)= 6.9026165576221645
# differential_evolution step 202: f(x)= 6.9026165576221645
# differential_evolution step 203: f(x)= 6.9026165576221645
# differential_evolution step 204: f(x)= 6.9026165576221645
# differential_evolution step 205: f(x)= 6.832397372064738
# differential_evolution step 206: f(x)= 6.832397372064738
# differential_evolution step 207: f(x)= 6.832397372064738
# differential_evolution step 208: f(x)= 6.832397372064738
# differential_evolution step 209: f(x)= 6.832397372064738
# differential_evolution step 210: f(x)= 6.832397372064738
# differential_evolution step 211: f(x)= 4.4368912268274245
# differential_evolution step 212: f(x)= 4.4368912268274245
# differential_evolution step 213: f(x)= 4.4368912268274245
# differential_evolution step 214: f(x)= 4.4368912268274245
# differential_evolution step 215: f(x)= 4.4368912268274245
# differential_evolution step 216: f(x)= 4.4368912268274245
# differential_evolution step 217: f(x)= 4.4368912268274245
# differential_evolution step 218: f(x)= 4.4368912268274245
# differential_evolution step 219: f(x)= 4.4368912268274245
# differential_evolution step 220: f(x)= 4.4368912268274245
# differential_evolution step 221: f(x)= 4.4368912268274245
# differential_evolution step 222: f(x)= 4.4368912268274245
# differential_evolution step 223: f(x)= 4.4368912268274245
# differential_evolution step 224: f(x)= 4.4368912268274245
# differential_evolution step 225: f(x)= 4.4368912268274245
# differential_evolution step 226: f(x)= 4.4368912268274245
# differential_evolution step 227: f(x)= 4.4368912268274245
# differential_evolution step 228: f(x)= 4.4368912268274245
# differential_evolution step 229: f(x)= 4.4368912268274245
# differential_evolution step 230: f(x)= 4.4368912268274245
# differential_evolution step 231: f(x)= 3.4834341994404316
# differential_evolution step 232: f(x)= 3.4834341994404316
# differential_evolution step 233: f(x)= 3.4834341994404316
# differential_evolution step 234: f(x)= 3.4834341994404316
# differential_evolution step 235: f(x)= 3.4834341994404316
# differential_evolution step 236: f(x)= 3.4834341994404316
# differential_evolution step 237: f(x)= 3.4834341994404316
# differential_evolution step 238: f(x)= 3.4834341994404316
# differential_evolution step 239: f(x)= 3.4834341994404316
# differential_evolution step 240: f(x)= 3.4834341994404316
# differential_evolution step 241: f(x)= 3.4834341994404316
# differential_evolution step 242: f(x)= 3.4834341994404316
# differential_evolution step 243: f(x)= 3.4834341994404316
# differential_evolution step 244: f(x)= 2.9342276736220194
# differential_evolution step 245: f(x)= 2.9342276736220194
# differential_evolution step 246: f(x)= 2.9342276736220194
# differential_evolution step 247: f(x)= 2.9342276736220194
# differential_evolution step 248: f(x)= 2.888977965898194
# differential_evolution step 249: f(x)= 2.888977965898194
# differential_evolution step 250: f(x)= 2.871533483087535
# differential_evolution step 251: f(x)= 2.871533483087535
# differential_evolution step 252: f(x)= 2.871533483087535
# differential_evolution step 253: f(x)= 2.871533483087535
# differential_evolution step 254: f(x)= 2.706841792280052
# differential_evolution step 255: f(x)= 2.706841792280052
# differential_evolution step 256: f(x)= 2.706841792280052
# differential_evolution step 257: f(x)= 2.627567769002072
# differential_evolution step 258: f(x)= 2.5692309106532285
# differential_evolution step 259: f(x)= 2.5692309106532285
# differential_evolution step 260: f(x)= 2.5692309106532285
# differential_evolution step 261: f(x)= 2.5692309106532285
# differential_evolution step 262: f(x)= 2.5692309106532285
# differential_evolution step 263: f(x)= 2.5692309106532285
# differential_evolution step 264: f(x)= 2.5692309106532285
# differential_evolution step 265: f(x)= 2.4328530169371847
# differential_evolution step 266: f(x)= 2.4328530169371847
# differential_evolution step 267: f(x)= 2.3502206765202107
# differential_evolution step 268: f(x)= 2.3502206765202107
# differential_evolution step 269: f(x)= 2.3502206765202107
# differential_evolution step 270: f(x)= 2.3502206765202107
# differential_evolution step 271: f(x)= 2.3502206765202107
# differential_evolution step 272: f(x)= 2.3502206765202107
# differential_evolution step 273: f(x)= 2.3502206765202107
# differential_evolution step 274: f(x)= 2.3502206765202107
# differential_evolution step 275: f(x)= 2.3502206765202107
# differential_evolution step 276: f(x)= 2.3502206765202107
# differential_evolution step 277: f(x)= 2.1815083192675253
# differential_evolution step 278: f(x)= 2.1815083192675253
# differential_evolution step 279: f(x)= 2.131828211430638
# differential_evolution step 280: f(x)= 2.131828211430638
# differential_evolution step 281: f(x)= 2.131828211430638
# differential_evolution step 282: f(x)= 2.131828211430638
# differential_evolution step 283: f(x)= 2.131828211430638
# differential_evolution step 284: f(x)= 2.131828211430638
# differential_evolution step 285: f(x)= 2.131828211430638
# differential_evolution step 286: f(x)= 2.131828211430638
# differential_evolution step 287: f(x)= 2.131828211430638
# differential_evolution step 288: f(x)= 2.131828211430638
# differential_evolution step 289: f(x)= 2.131828211430638
# differential_evolution step 290: f(x)= 2.131828211430638
# differential_evolution step 291: f(x)= 2.131828211430638
# differential_evolution step 292: f(x)= 2.131828211430638
# differential_evolution step 293: f(x)= 2.131828211430638
# differential_evolution step 294: f(x)= 2.131828211430638
# differential_evolution step 295: f(x)= 2.131828211430638
# differential_evolution step 296: f(x)= 2.131828211430638
# differential_evolution step 297: f(x)= 2.131828211430638
# differential_evolution step 298: f(x)= 2.131828211430638
# differential_evolution step 299: f(x)= 2.131828211430638
# differential_evolution step 300: f(x)= 2.131828211430638
# differential_evolution step 301: f(x)= 2.131828211430638
# differential_evolution step 302: f(x)= 2.131828211430638
# differential_evolution step 303: f(x)= 2.131828211430638
# differential_evolution step 304: f(x)= 2.131828211430638
# differential_evolution step 305: f(x)= 2.131828211430638
# differential_evolution step 306: f(x)= 2.131828211430638
# differential_evolution step 307: f(x)= 2.131828211430638
# differential_evolution step 308: f(x)= 2.131828211430638
# differential_evolution step 309: f(x)= 2.131828211430638
# differential_evolution step 310: f(x)= 2.067500508039289
# differential_evolution step 311: f(x)= 2.067500508039289
# differential_evolution step 312: f(x)= 2.067500508039289
# differential_evolution step 313: f(x)= 2.067500508039289
# differential_evolution step 314: f(x)= 2.067500508039289
# differential_evolution step 315: f(x)= 2.067500508039289
# differential_evolution step 316: f(x)= 2.067500508039289
# differential_evolution step 317: f(x)= 2.041074269133968
# differential_evolution step 318: f(x)= 2.041074269133968
# differential_evolution step 319: f(x)= 2.041074269133968
# differential_evolution step 320: f(x)= 2.041074269133968
# differential_evolution step 321: f(x)= 2.041074269133968
# differential_evolution step 322: f(x)= 2.041074269133968
# differential_evolution step 323: f(x)= 2.041074269133968
# differential_evolution step 324: f(x)= 2.0402798168564176
# differential_evolution step 325: f(x)= 2.0402798168564176
# differential_evolution step 326: f(x)= 2.0402798168564176
# differential_evolution step 327: f(x)= 2.0402798168564176
# differential_evolution step 328: f(x)= 2.0402798168564176
# differential_evolution step 329: f(x)= 2.0402798168564176
# differential_evolution step 330: f(x)= 2.0402798168564176
# differential_evolution step 331: f(x)= 2.0402798168564176
# differential_evolution step 332: f(x)= 2.0402798168564176
# differential_evolution step 333: f(x)= 2.0402798168564176
# differential_evolution step 334: f(x)= 1.9792746682000903
# differential_evolution step 335: f(x)= 1.9792746682000903
# differential_evolution step 336: f(x)= 1.9792746682000903
# differential_evolution step 337: f(x)= 1.9792746682000903
# differential_evolution step 338: f(x)= 1.9792746682000903
# differential_evolution step 339: f(x)= 1.9792746682000903
# differential_evolution step 340: f(x)= 1.9792746682000903
# differential_evolution step 341: f(x)= 1.914533385434037
# differential_evolution step 342: f(x)= 1.914533385434037
# differential_evolution step 343: f(x)= 1.914533385434037
# differential_evolution step 344: f(x)= 1.914533385434037
# differential_evolution step 345: f(x)= 1.914533385434037
# differential_evolution step 346: f(x)= 1.914533385434037
# differential_evolution step 347: f(x)= 1.914533385434037
# differential_evolution step 348: f(x)= 1.8368573252654146
# differential_evolution step 349: f(x)= 1.8368573252654146
# differential_evolution step 350: f(x)= 1.8368573252654146
# differential_evolution step 351: f(x)= 1.8368573252654146
# differential_evolution step 352: f(x)= 1.8368573252654146
# differential_evolution step 353: f(x)= 1.8368573252654146
# differential_evolution step 354: f(x)= 1.8368573252654146
# differential_evolution step 355: f(x)= 1.8153433751050516
# differential_evolution step 356: f(x)= 1.8153433751050516
# differential_evolution step 357: f(x)= 1.8153433751050516
# differential_evolution step 358: f(x)= 1.8153433751050516
# differential_evolution step 359: f(x)= 1.8153433751050516
# differential_evolution step 360: f(x)= 1.8153433751050516
# differential_evolution step 361: f(x)= 1.8153433751050516
# differential_evolution step 362: f(x)= 1.8153433751050516
# differential_evolution step 363: f(x)= 1.8153433751050516
# differential_evolution step 364: f(x)= 1.8153433751050516
# differential_evolution step 365: f(x)= 1.8153433751050516
# differential_evolution step 366: f(x)= 1.8153433751050516
# differential_evolution step 367: f(x)= 1.8153433751050516
# differential_evolution step 368: f(x)= 1.8153433751050516
# differential_evolution step 369: f(x)= 1.8153433751050516
# differential_evolution step 370: f(x)= 1.8153433751050516
# differential_evolution step 371: f(x)= 1.8153433751050516
# differential_evolution step 372: f(x)= 1.7284975963176301
# differential_evolution step 373: f(x)= 1.7284975963176301
# differential_evolution step 374: f(x)= 1.7284975963176301
# differential_evolution step 375: f(x)= 1.7284975963176301
# differential_evolution step 376: f(x)= 1.7284975963176301
# differential_evolution step 377: f(x)= 1.7284975963176301
# differential_evolution step 378: f(x)= 1.7284975963176301
# differential_evolution step 379: f(x)= 1.7284975963176301
# differential_evolution step 380: f(x)= 1.7284975963176301
# differential_evolution step 381: f(x)= 1.7284975963176301
# differential_evolution step 382: f(x)= 1.7284975963176301
# differential_evolution step 383: f(x)= 1.7284975963176301
# differential_evolution step 384: f(x)= 1.7284975963176301
# differential_evolution step 385: f(x)= 1.7284975963176301
# differential_evolution step 386: f(x)= 1.72826849794261
# differential_evolution step 387: f(x)= 1.72826849794261
# differential_evolution step 388: f(x)= 1.72826849794261
# differential_evolution step 389: f(x)= 1.72826849794261
# differential_evolution step 390: f(x)= 1.72826849794261
# differential_evolution step 391: f(x)= 1.72826849794261
# differential_evolution step 392: f(x)= 1.72826849794261
# differential_evolution step 393: f(x)= 1.6600694510047298
# differential_evolution step 394: f(x)= 1.6600694510047298
# differential_evolution step 395: f(x)= 1.6600694510047298
# differential_evolution step 396: f(x)= 1.6600694510047298
# differential_evolution step 397: f(x)= 1.6600694510047298
# differential_evolution step 398: f(x)= 1.6600694510047298
# differential_evolution step 399: f(x)= 1.6600694510047298
# differential_evolution step 400: f(x)= 1.6600694510047298
# differential_evolution step 401: f(x)= 1.6600694510047298
# differential_evolution step 402: f(x)= 1.6600694510047298
# differential_evolution step 403: f(x)= 1.6600694510047298
# differential_evolution step 404: f(x)= 1.6600694510047298
# differential_evolution step 405: f(x)= 1.6600694510047298
# differential_evolution step 406: f(x)= 1.6600694510047298
# differential_evolution step 407: f(x)= 1.6600694510047298
# differential_evolution step 408: f(x)= 1.6600694510047298
# differential_evolution step 409: f(x)= 1.6600694510047298
# differential_evolution step 410: f(x)= 1.6600694510047298
# differential_evolution step 411: f(x)= 1.6600694510047298
# differential_evolution step 412: f(x)= 1.6600694510047298
# differential_evolution step 413: f(x)= 1.6600694510047298
# differential_evolution step 414: f(x)= 1.6600694510047298
# differential_evolution step 415: f(x)= 1.6600694510047298
# differential_evolution step 416: f(x)= 1.6600694510047298
# differential_evolution step 417: f(x)= 1.6600694510047298
# differential_evolution step 418: f(x)= 1.6600694510047298
# differential_evolution step 419: f(x)= 1.65435174695423
# differential_evolution step 420: f(x)= 1.65435174695423
# differential_evolution step 421: f(x)= 1.65435174695423
# differential_evolution step 422: f(x)= 1.65435174695423
# differential_evolution step 423: f(x)= 1.65435174695423
# differential_evolution step 424: f(x)= 1.6321775345485643
# differential_evolution step 425: f(x)= 1.6321775345485643
# differential_evolution step 426: f(x)= 1.6321775345485643
# differential_evolution step 427: f(x)= 1.6321775345485643
# differential_evolution step 428: f(x)= 1.6321775345485643
# differential_evolution step 429: f(x)= 1.6321775345485643
# differential_evolution step 430: f(x)= 1.6321775345485643
# differential_evolution step 431: f(x)= 1.6321775345485643
# differential_evolution step 432: f(x)= 1.6321775345485643
# differential_evolution step 433: f(x)= 1.6321775345485643
# differential_evolution step 434: f(x)= 1.6321775345485643
# differential_evolution step 435: f(x)= 1.6321775345485643
# differential_evolution step 436: f(x)= 1.6321775345485643
# differential_evolution step 437: f(x)= 1.6321775345485643
# differential_evolution step 438: f(x)= 1.591650775334658
# differential_evolution step 439: f(x)= 1.591650775334658
# differential_evolution step 440: f(x)= 1.591650775334658
# differential_evolution step 441: f(x)= 1.535822682253692
# differential_evolution step 442: f(x)= 1.535822682253692
# differential_evolution step 443: f(x)= 1.5142412406896186
# differential_evolution step 444: f(x)= 1.5142412406896186
# differential_evolution step 445: f(x)= 1.5142412406896186
# differential_evolution step 446: f(x)= 1.5142412406896186
# differential_evolution step 447: f(x)= 1.5142412406896186
# differential_evolution step 448: f(x)= 1.5142412406896186
# differential_evolution step 449: f(x)= 1.5142412406896186
# differential_evolution step 450: f(x)= 1.5142412406896186
# differential_evolution step 451: f(x)= 1.5142412406896186
# differential_evolution step 452: f(x)= 1.5142412406896186
# differential_evolution step 453: f(x)= 1.5142412406896186
# differential_evolution step 454: f(x)= 1.5142412406896186
# differential_evolution step 455: f(x)= 1.5142412406896186
# differential_evolution step 456: f(x)= 1.5142412406896186
# differential_evolution step 457: f(x)= 1.5142412406896186
# differential_evolution step 458: f(x)= 1.5142412406896186
# differential_evolution step 459: f(x)= 1.5142412406896186
# differential_evolution step 460: f(x)= 1.5142412406896186
# differential_evolution step 461: f(x)= 1.5142412406896186
# differential_evolution step 462: f(x)= 1.4986601507734303
# differential_evolution step 463: f(x)= 1.4986601507734303
# differential_evolution step 464: f(x)= 1.4986601507734303
# differential_evolution step 465: f(x)= 1.4986601507734303
# differential_evolution step 466: f(x)= 1.4986601507734303
# differential_evolution step 467: f(x)= 1.4986601507734303
# differential_evolution step 468: f(x)= 1.4986601507734303
# differential_evolution step 469: f(x)= 1.4986601507734303
# differential_evolution step 470: f(x)= 1.4986601507734303
# differential_evolution step 471: f(x)= 1.4986601507734303
# differential_evolution step 472: f(x)= 1.4986601507734303
# differential_evolution step 473: f(x)= 1.4986601507734303
# differential_evolution step 474: f(x)= 1.4986601507734303
# differential_evolution step 475: f(x)= 1.4986601507734303
# differential_evolution step 476: f(x)= 1.4986601507734303
# differential_evolution step 477: f(x)= 1.4986601507734303
# differential_evolution step 478: f(x)= 1.4986601507734303
# differential_evolution step 479: f(x)= 1.4986601507734303
# differential_evolution step 480: f(x)= 1.4986601507734303
# differential_evolution step 481: f(x)= 1.4986601507734303
# differential_evolution step 482: f(x)= 1.4986601507734303
# differential_evolution step 483: f(x)= 1.4986601507734303
# differential_evolution step 484: f(x)= 1.4986601507734303
# differential_evolution step 485: f(x)= 1.4986601507734303
# differential_evolution step 486: f(x)= 1.4986601507734303
# differential_evolution step 487: f(x)= 1.4986601507734303
# differential_evolution step 488: f(x)= 1.4931238544407326
# differential_evolution step 489: f(x)= 1.4931238544407326
# differential_evolution step 490: f(x)= 1.4931238544407326
# differential_evolution step 491: f(x)= 1.4931238544407326
# differential_evolution step 492: f(x)= 1.4931238544407326
# differential_evolution step 493: f(x)= 1.4931238544407326
# differential_evolution step 494: f(x)= 1.4931238544407326
# differential_evolution step 495: f(x)= 1.4931238544407326
# differential_evolution step 496: f(x)= 1.4931238544407326
# differential_evolution step 497: f(x)= 1.4931238544407326
# differential_evolution step 498: f(x)= 1.4931238544407326
# differential_evolution step 499: f(x)= 1.4931238544407326
# differential_evolution step 500: f(x)= 1.4931238544407326
# differential_evolution step 501: f(x)= 1.4931238544407326
# differential_evolution step 502: f(x)= 1.4931238544407326
# differential_evolution step 503: f(x)= 1.4931238544407326
# differential_evolution step 504: f(x)= 1.4931238544407326
# differential_evolution step 505: f(x)= 1.4931238544407326
# differential_evolution step 506: f(x)= 1.4931238544407326
# differential_evolution step 507: f(x)= 1.4931238544407326
# differential_evolution step 508: f(x)= 1.4931238544407326
# differential_evolution step 509: f(x)= 1.4931238544407326
# differential_evolution step 510: f(x)= 1.4931238544407326
# differential_evolution step 511: f(x)= 1.4931238544407326
# differential_evolution step 512: f(x)= 1.4931238544407326
# differential_evolution step 513: f(x)= 1.4931238544407326
# differential_evolution step 514: f(x)= 1.4931238544407326
# differential_evolution step 515: f(x)= 1.4931238544407326
# differential_evolution step 516: f(x)= 1.4931238544407326
# differential_evolution step 517: f(x)= 1.4931238544407326
# differential_evolution step 518: f(x)= 1.4931238544407326
# differential_evolution step 519: f(x)= 1.4931238544407326
# differential_evolution step 520: f(x)= 1.4931238544407326
# differential_evolution step 521: f(x)= 1.4834564349374086
# differential_evolution step 522: f(x)= 1.4834564349374086
# differential_evolution step 523: f(x)= 1.4834564349374086
# differential_evolution step 524: f(x)= 1.4834564349374086
# differential_evolution step 525: f(x)= 1.4834564349374086
# differential_evolution step 526: f(x)= 1.4834564349374086
# differential_evolution step 527: f(x)= 1.4834564349374086
# differential_evolution step 528: f(x)= 1.4834564349374086
# differential_evolution step 529: f(x)= 1.4834564349374086
# differential_evolution step 530: f(x)= 1.4834564349374086
# differential_evolution step 531: f(x)= 1.4834564349374086
# differential_evolution step 532: f(x)= 1.4834564349374086
# differential_evolution step 533: f(x)= 1.4834564349374086
# differential_evolution step 534: f(x)= 1.4834564349374086
# differential_evolution step 535: f(x)= 1.4834564349374086
# differential_evolution step 536: f(x)= 1.4834564349374086
# differential_evolution step 537: f(x)= 1.4834564349374086
# differential_evolution step 538: f(x)= 1.4834564349374086
# differential_evolution step 539: f(x)= 1.4834564349374086
# differential_evolution step 540: f(x)= 1.4610470257017585
# differential_evolution step 541: f(x)= 1.4610470257017585
# differential_evolution step 542: f(x)= 1.4610470257017585
# differential_evolution step 543: f(x)= 1.4610470257017585
# differential_evolution step 544: f(x)= 1.4610470257017585
# differential_evolution step 545: f(x)= 1.4211082241743664
# differential_evolution step 546: f(x)= 1.4211082241743664
# differential_evolution step 547: f(x)= 1.4211082241743664
# differential_evolution step 548: f(x)= 1.4211082241743664
# differential_evolution step 549: f(x)= 1.4211082241743664
# differential_evolution step 550: f(x)= 1.4211082241743664
# differential_evolution step 551: f(x)= 1.4211082241743664
# differential_evolution step 552: f(x)= 1.4211082241743664
# differential_evolution step 553: f(x)= 1.4211082241743664
# differential_evolution step 554: f(x)= 1.4211082241743664
# differential_evolution step 555: f(x)= 1.4211082241743664
# differential_evolution step 556: f(x)= 1.4211082241743664
# differential_evolution step 557: f(x)= 1.4211082241743664
# differential_evolution step 558: f(x)= 1.4211082241743664
# differential_evolution step 559: f(x)= 1.4211082241743664
# differential_evolution step 560: f(x)= 1.4211082241743664
# differential_evolution step 561: f(x)= 1.4211082241743664
# differential_evolution step 562: f(x)= 1.4211082241743664
# differential_evolution step 563: f(x)= 1.4211082241743664
# differential_evolution step 564: f(x)= 1.4211082241743664
# differential_evolution step 565: f(x)= 1.4211082241743664
# differential_evolution step 566: f(x)= 1.4211082241743664
# differential_evolution step 567: f(x)= 1.4211082241743664
# differential_evolution step 568: f(x)= 1.4211082241743664
# differential_evolution step 569: f(x)= 1.4211082241743664
# differential_evolution step 570: f(x)= 1.4211082241743664
# differential_evolution step 571: f(x)= 1.4211082241743664
# differential_evolution step 572: f(x)= 1.4211082241743664
# differential_evolution step 573: f(x)= 1.4195647988700195
# differential_evolution step 574: f(x)= 1.4195647988700195
# differential_evolution step 575: f(x)= 1.4195647988700195
# differential_evolution step 576: f(x)= 1.4195647988700195
# differential_evolution step 577: f(x)= 1.4195647988700195
# differential_evolution step 578: f(x)= 1.4195647988700195
# differential_evolution step 579: f(x)= 1.4195647988700195
# differential_evolution step 580: f(x)= 1.4195647988700195
# differential_evolution step 581: f(x)= 1.4195647988700195
# differential_evolution step 582: f(x)= 1.4195647988700195
# differential_evolution step 583: f(x)= 1.4195647988700195
# differential_evolution step 584: f(x)= 1.4195647988700195
# differential_evolution step 585: f(x)= 1.4195647988700195
# differential_evolution step 586: f(x)= 1.4195647988700195
# differential_evolution step 587: f(x)= 1.4195647988700195
# differential_evolution step 588: f(x)= 1.4195647988700195
# differential_evolution step 589: f(x)= 1.4195647988700195
# differential_evolution step 590: f(x)= 1.4195647988700195
# differential_evolution step 591: f(x)= 1.4195647988700195
# differential_evolution step 592: f(x)= 1.4195647988700195
# differential_evolution step 593: f(x)= 1.4195647988700195
# differential_evolution step 594: f(x)= 1.4195647988700195
# differential_evolution step 595: f(x)= 1.3905781452190127
# differential_evolution step 596: f(x)= 1.3905781452190127
# differential_evolution step 597: f(x)= 1.3905781452190127
# differential_evolution step 598: f(x)= 1.3905781452190127
# differential_evolution step 599: f(x)= 1.3905781452190127
# differential_evolution step 600: f(x)= 1.3905781452190127
# differential_evolution step 601: f(x)= 1.3905781452190127
# differential_evolution step 602: f(x)= 1.3905781452190127
# differential_evolution step 603: f(x)= 1.3905781452190127
# differential_evolution step 604: f(x)= 1.3905781452190127
# differential_evolution step 605: f(x)= 1.3905781452190127
# differential_evolution step 606: f(x)= 1.3905781452190127
# differential_evolution step 607: f(x)= 1.3905781452190127
# differential_evolution step 608: f(x)= 1.3905781452190127
# differential_evolution step 609: f(x)= 1.3905781452190127
# differential_evolution step 610: f(x)= 1.3905781452190127
# differential_evolution step 611: f(x)= 1.3905781452190127
# differential_evolution step 612: f(x)= 1.3905781452190127
# differential_evolution step 613: f(x)= 1.3905781452190127
# differential_evolution step 614: f(x)= 1.3905781452190127
# differential_evolution step 615: f(x)= 1.3905781452190127
# differential_evolution step 616: f(x)= 1.3905781452190127
# differential_evolution step 617: f(x)= 1.3905781452190127
# differential_evolution step 618: f(x)= 1.3905781452190127
# differential_evolution step 619: f(x)= 1.3905781452190127
# differential_evolution step 620: f(x)= 1.3905318389426309
# differential_evolution step 621: f(x)= 1.3905318389426309
# differential_evolution step 622: f(x)= 1.3905318389426309
# differential_evolution step 623: f(x)= 1.3905318389426309
# differential_evolution step 624: f(x)= 1.3905318389426309
# differential_evolution step 625: f(x)= 1.3905318389426309
# differential_evolution step 626: f(x)= 1.3905318389426309
# differential_evolution step 627: f(x)= 1.3905318389426309
# differential_evolution step 628: f(x)= 1.3905318389426309
# differential_evolution step 629: f(x)= 1.3905318389426309
# differential_evolution step 630: f(x)= 1.3905318389426309
# differential_evolution step 631: f(x)= 1.3905318389426309
# differential_evolution step 632: f(x)= 1.3905318389426309
# differential_evolution step 633: f(x)= 1.3905318389426309
# differential_evolution step 634: f(x)= 1.3905318389426309
# differential_evolution step 635: f(x)= 1.3905318389426309
# differential_evolution step 636: f(x)= 1.3905318389426309
# differential_evolution step 637: f(x)= 1.3905318389426309
# differential_evolution step 638: f(x)= 1.3905318389426309
# differential_evolution step 639: f(x)= 1.3905318389426309
# differential_evolution step 640: f(x)= 1.3905318389426309
# differential_evolution step 641: f(x)= 1.3843076504883463
# differential_evolution step 642: f(x)= 1.3843076504883463
# differential_evolution step 643: f(x)= 1.3843076504883463
# differential_evolution step 644: f(x)= 1.3843076504883463
# differential_evolution step 645: f(x)= 1.3843076504883463
# differential_evolution step 646: f(x)= 1.3843076504883463
# differential_evolution step 647: f(x)= 1.3843076504883463
# differential_evolution step 648: f(x)= 1.3843076504883463
# differential_evolution step 649: f(x)= 1.3843076504883463
# differential_evolution step 650: f(x)= 1.3843076504883463
# differential_evolution step 651: f(x)= 1.3843076504883463
# differential_evolution step 652: f(x)= 1.3843076504883463
# differential_evolution step 653: f(x)= 1.3843076504883463
# differential_evolution step 654: f(x)= 1.3843076504883463
# differential_evolution step 655: f(x)= 1.3843076504883463
# differential_evolution step 656: f(x)= 1.3843076504883463
# differential_evolution step 657: f(x)= 1.3843076504883463
# differential_evolution step 658: f(x)= 1.3843076504883463
# differential_evolution step 659: f(x)= 1.3843076504883463
# differential_evolution step 660: f(x)= 1.3843076504883463
# differential_evolution step 661: f(x)= 1.3843076504883463
# differential_evolution step 662: f(x)= 1.3843076504883463
# differential_evolution step 663: f(x)= 1.3723945982015078
# differential_evolution step 664: f(x)= 1.3723945982015078
# differential_evolution step 665: f(x)= 1.3723945982015078
# differential_evolution step 666: f(x)= 1.3723945982015078
# differential_evolution step 667: f(x)= 1.3723945982015078
# differential_evolution step 668: f(x)= 1.3723945982015078
# differential_evolution step 669: f(x)= 1.3723945982015078
# differential_evolution step 670: f(x)= 1.3723945982015078
# differential_evolution step 671: f(x)= 1.3723945982015078
# differential_evolution step 672: f(x)= 1.3723945982015078
# differential_evolution step 673: f(x)= 1.3723945982015078
# differential_evolution step 674: f(x)= 1.3723945982015078
# differential_evolution step 675: f(x)= 1.3723945982015078
# differential_evolution step 676: f(x)= 1.3723945982015078
# differential_evolution step 677: f(x)= 1.3723945982015078
# differential_evolution step 678: f(x)= 1.3723945982015078
# differential_evolution step 679: f(x)= 1.3723945982015078
# differential_evolution step 680: f(x)= 1.3723945982015078
# differential_evolution step 681: f(x)= 1.3723945982015078
# differential_evolution step 682: f(x)= 1.3723945982015078
# differential_evolution step 683: f(x)= 1.3723945982015078
# differential_evolution step 684: f(x)= 1.3723945982015078
# differential_evolution step 685: f(x)= 1.3723945982015078
# differential_evolution step 686: f(x)= 1.3723945982015078
# differential_evolution step 687: f(x)= 1.3723945982015078
# differential_evolution step 688: f(x)= 1.3723945982015078
# differential_evolution step 689: f(x)= 1.3723945982015078
# differential_evolution step 690: f(x)= 1.3723945982015078
# differential_evolution step 691: f(x)= 1.3723945982015078
# differential_evolution step 692: f(x)= 1.3723945982015078
# differential_evolution step 693: f(x)= 1.3723945982015078
# differential_evolution step 694: f(x)= 1.3723945982015078
# differential_evolution step 695: f(x)= 1.3723945982015078
# differential_evolution step 696: f(x)= 1.3723945982015078
# differential_evolution step 697: f(x)= 1.3723945982015078
# differential_evolution step 698: f(x)= 1.3723945982015078
# differential_evolution step 699: f(x)= 1.3723945982015078
# differential_evolution step 700: f(x)= 1.3723945982015078
# differential_evolution step 701: f(x)= 1.3723945982015078
# differential_evolution step 702: f(x)= 1.3723945982015078
# differential_evolution step 703: f(x)= 1.3723945982015078
# differential_evolution step 704: f(x)= 1.3723945982015078
# differential_evolution step 705: f(x)= 1.3710397706464945
# differential_evolution step 706: f(x)= 1.3710397706464945
# differential_evolution step 707: f(x)= 1.3710397706464945
# differential_evolution step 708: f(x)= 1.3710397706464945
# differential_evolution step 709: f(x)= 1.3710397706464945
# differential_evolution step 710: f(x)= 1.3710397706464945
# differential_evolution step 711: f(x)= 1.3710397706464945
# differential_evolution step 712: f(x)= 1.3710397706464945
# differential_evolution step 713: f(x)= 1.3710397706464945
# differential_evolution step 714: f(x)= 1.3710397706464945
# differential_evolution step 715: f(x)= 1.3710397706464945
# differential_evolution step 716: f(x)= 1.3710397706464945
# differential_evolution step 717: f(x)= 1.3710397706464945
# differential_evolution step 718: f(x)= 1.3710397706464945
# differential_evolution step 719: f(x)= 1.3710397706464945
# differential_evolution step 720: f(x)= 1.3710397706464945
# differential_evolution step 721: f(x)= 1.3710397706464945
# differential_evolution step 722: f(x)= 1.3707254120065897
# differential_evolution step 723: f(x)= 1.3611084344953952
# differential_evolution step 724: f(x)= 1.3611084344953952
# differential_evolution step 725: f(x)= 1.3611084344953952
# differential_evolution step 726: f(x)= 1.3611084344953952
# differential_evolution step 727: f(x)= 1.3611084344953952
# differential_evolution step 728: f(x)= 1.3611084344953952
# differential_evolution step 729: f(x)= 1.3611084344953952
# differential_evolution step 730: f(x)= 1.3611084344953952
# differential_evolution step 731: f(x)= 1.3611084344953952
# differential_evolution step 732: f(x)= 1.3611084344953952
# differential_evolution step 733: f(x)= 1.3611084344953952
# differential_evolution step 734: f(x)= 1.3611084344953952
# differential_evolution step 735: f(x)= 1.3611084344953952
# differential_evolution step 736: f(x)= 1.3611084344953952
# differential_evolution step 737: f(x)= 1.3580414798499671
# differential_evolution step 738: f(x)= 1.3580414798499671
# differential_evolution step 739: f(x)= 1.3576986963059199
# differential_evolution step 740: f(x)= 1.3576986963059199
# differential_evolution step 741: f(x)= 1.3576986963059199
# differential_evolution step 742: f(x)= 1.3576986963059199
# differential_evolution step 743: f(x)= 1.3576986963059199
# differential_evolution step 744: f(x)= 1.3576986963059199
# differential_evolution step 745: f(x)= 1.3576986963059199
# differential_evolution step 746: f(x)= 1.3576986963059199
# differential_evolution step 747: f(x)= 1.3576986963059199
# differential_evolution step 748: f(x)= 1.3576986963059199
# differential_evolution step 749: f(x)= 1.3576986963059199
# differential_evolution step 750: f(x)= 1.3576986963059199
# differential_evolution step 751: f(x)= 1.3576986963059199
# differential_evolution step 752: f(x)= 1.3576986963059199
# differential_evolution step 753: f(x)= 1.3576986963059199
# differential_evolution step 754: f(x)= 1.3576986963059199
# differential_evolution step 755: f(x)= 1.3576986963059199
# differential_evolution step 756: f(x)= 1.3572473662634583
# differential_evolution step 757: f(x)= 1.3572473662634583
# differential_evolution step 758: f(x)= 1.3572473662634583
# differential_evolution step 759: f(x)= 1.3572473662634583
# differential_evolution step 760: f(x)= 1.3567601987587146
# differential_evolution step 761: f(x)= 1.3567601987587146
# differential_evolution step 762: f(x)= 1.3567601987587146
# differential_evolution step 763: f(x)= 1.3567601987587146
# differential_evolution step 764: f(x)= 1.3567601987587146
# differential_evolution step 765: f(x)= 1.3567601987587146
# differential_evolution step 766: f(x)= 1.3567601987587146
# differential_evolution step 767: f(x)= 1.3567601987587146
# differential_evolution step 768: f(x)= 1.3468464691891289
# differential_evolution step 769: f(x)= 1.3468464691891289
# differential_evolution step 770: f(x)= 1.3468464691891289
# differential_evolution step 771: f(x)= 1.3468464691891289
# differential_evolution step 772: f(x)= 1.3468464691891289
# differential_evolution step 773: f(x)= 1.3468464691891289
# differential_evolution step 774: f(x)= 1.3468464691891289
# differential_evolution step 775: f(x)= 1.3468464691891289
# differential_evolution step 776: f(x)= 1.3468464691891289
# differential_evolution step 777: f(x)= 1.3468464691891289
# differential_evolution step 778: f(x)= 1.3468464691891289
# differential_evolution step 779: f(x)= 1.3468464691891289
# differential_evolution step 780: f(x)= 1.3468464691891289
# differential_evolution step 781: f(x)= 1.3468464691891289
# differential_evolution step 782: f(x)= 1.3468464691891289
# differential_evolution step 783: f(x)= 1.3468464691891289
# differential_evolution step 784: f(x)= 1.3468464691891289
# differential_evolution step 785: f(x)= 1.3468464691891289
# differential_evolution step 786: f(x)= 1.3468464691891289
# differential_evolution step 787: f(x)= 1.3468464691891289
# differential_evolution step 788: f(x)= 1.3468464691891289
# differential_evolution step 789: f(x)= 1.3468464691891289
# differential_evolution step 790: f(x)= 1.3468464691891289
# differential_evolution step 791: f(x)= 1.3468464691891289
# differential_evolution step 792: f(x)= 1.3468464691891289
# differential_evolution step 793: f(x)= 1.3468464691891289
# differential_evolution step 794: f(x)= 1.345258359194916
# differential_evolution step 795: f(x)= 1.345258359194916
# differential_evolution step 796: f(x)= 1.3445245550325058
# differential_evolution step 797: f(x)= 1.3436467629995559
# differential_evolution step 798: f(x)= 1.342425770231738
# differential_evolution step 799: f(x)= 1.338074475202694
# differential_evolution step 800: f(x)= 1.338074475202694
# differential_evolution step 801: f(x)= 1.338074475202694
# differential_evolution step 802: f(x)= 1.338074475202694
# differential_evolution step 803: f(x)= 1.338074475202694
# differential_evolution step 804: f(x)= 1.338074475202694
# differential_evolution step 805: f(x)= 1.338074475202694
# differential_evolution step 806: f(x)= 1.338074475202694
# differential_evolution step 807: f(x)= 1.338074475202694
# differential_evolution step 808: f(x)= 1.3316656791927972
# differential_evolution step 809: f(x)= 1.3316656791927972
# differential_evolution step 810: f(x)= 1.3316656791927972
# differential_evolution step 811: f(x)= 1.3316656791927972
# differential_evolution step 812: f(x)= 1.3316656791927972
# differential_evolution step 813: f(x)= 1.3316656791927972
# differential_evolution step 814: f(x)= 1.3316656791927972
# differential_evolution step 815: f(x)= 1.3316656791927972
# differential_evolution step 816: f(x)= 1.3316656791927972
# differential_evolution step 817: f(x)= 1.3316656791927972
# differential_evolution step 818: f(x)= 1.3316656791927972
# differential_evolution step 819: f(x)= 1.3316656791927972
# differential_evolution step 820: f(x)= 1.3316656791927972
# differential_evolution step 821: f(x)= 1.3316656791927972
# differential_evolution step 822: f(x)= 1.3316656791927972
# differential_evolution step 823: f(x)= 1.3316656791927972
# differential_evolution step 824: f(x)= 1.3316656791927972
# differential_evolution step 825: f(x)= 1.3316656791927972
# differential_evolution step 826: f(x)= 1.3316656791927972
# differential_evolution step 827: f(x)= 1.3316656791927972
# differential_evolution step 828: f(x)= 1.3254333479951061
# differential_evolution step 829: f(x)= 1.3254333479951061
# differential_evolution step 830: f(x)= 1.3254333479951061
# differential_evolution step 831: f(x)= 1.3254333479951061
# differential_evolution step 832: f(x)= 1.3254333479951061
# differential_evolution step 833: f(x)= 1.3254333479951061
# differential_evolution step 834: f(x)= 1.3254333479951061
# differential_evolution step 835: f(x)= 1.3254333479951061
# differential_evolution step 836: f(x)= 1.3254333479951061
# differential_evolution step 837: f(x)= 1.3254333479951061
# differential_evolution step 838: f(x)= 1.3254333479951061
# differential_evolution step 839: f(x)= 1.3254333479951061
# differential_evolution step 840: f(x)= 1.3254333479951061
# differential_evolution step 841: f(x)= 1.3254333479951061
# differential_evolution step 842: f(x)= 1.3254333479951061
# differential_evolution step 843: f(x)= 1.3254333479951061
# differential_evolution step 844: f(x)= 1.3254333479951061
# differential_evolution step 845: f(x)= 1.3254333479951061
# differential_evolution step 846: f(x)= 1.3254333479951061
# differential_evolution step 847: f(x)= 1.3254333479951061
# differential_evolution step 848: f(x)= 1.3254333479951061
# differential_evolution step 849: f(x)= 1.3254333479951061
# differential_evolution step 850: f(x)= 1.3254333479951061
# differential_evolution step 851: f(x)= 1.3254333479951061
# differential_evolution step 852: f(x)= 1.3254333479951061
# differential_evolution step 853: f(x)= 1.3254333479951061
# differential_evolution step 854: f(x)= 1.3254333479951061
# differential_evolution step 855: f(x)= 1.3254333479951061
# differential_evolution step 856: f(x)= 1.3254333479951061
# differential_evolution step 857: f(x)= 1.3254333479951061
# differential_evolution step 858: f(x)= 1.3254333479951061
# differential_evolution step 859: f(x)= 1.3254333479951061
# differential_evolution step 860: f(x)= 1.3254333479951061
# differential_evolution step 861: f(x)= 1.3254333479951061
# differential_evolution step 862: f(x)= 1.3254333479951061
# differential_evolution step 863: f(x)= 1.3221662800179774
# differential_evolution step 864: f(x)= 1.3221662800179774
# differential_evolution step 865: f(x)= 1.3221662800179774
# differential_evolution step 866: f(x)= 1.3221662800179774
# differential_evolution step 867: f(x)= 1.3196745091521593
# differential_evolution step 868: f(x)= 1.3196745091521593
# differential_evolution step 869: f(x)= 1.3196745091521593
# differential_evolution step 870: f(x)= 1.3196745091521593
# differential_evolution step 871: f(x)= 1.3196745091521593
# differential_evolution step 872: f(x)= 1.3196745091521593
# differential_evolution step 873: f(x)= 1.3196745091521593
# differential_evolution step 874: f(x)= 1.3196745091521593
# differential_evolution step 875: f(x)= 1.3196745091521593
# differential_evolution step 876: f(x)= 1.3196745091521593
# differential_evolution step 877: f(x)= 1.3196745091521593
# differential_evolution step 878: f(x)= 1.3196745091521593
# differential_evolution step 879: f(x)= 1.3196745091521593
# differential_evolution step 880: f(x)= 1.3196745091521593
# differential_evolution step 881: f(x)= 1.3196745091521593
# differential_evolution step 882: f(x)= 1.3196745091521593
# differential_evolution step 883: f(x)= 1.3196745091521593
# differential_evolution step 884: f(x)= 1.3194811163863625
# differential_evolution step 885: f(x)= 1.3194811163863625
# differential_evolution step 886: f(x)= 1.3189912144259803
# differential_evolution step 887: f(x)= 1.3189912144259803
# differential_evolution step 888: f(x)= 1.3177386917801348
# differential_evolution step 889: f(x)= 1.3177386917801348
# differential_evolution step 890: f(x)= 1.3177386917801348
# differential_evolution step 891: f(x)= 1.3151417143862436
# differential_evolution step 892: f(x)= 1.3151417143862436
# differential_evolution step 893: f(x)= 1.3151417143862436
# differential_evolution step 894: f(x)= 1.3151417143862436
# differential_evolution step 895: f(x)= 1.3151417143862436
# differential_evolution step 896: f(x)= 1.3151417143862436
# differential_evolution step 897: f(x)= 1.3151417143862436
# differential_evolution step 898: f(x)= 1.3151417143862436
# differential_evolution step 899: f(x)= 1.30954792900841
# differential_evolution step 900: f(x)= 1.30954792900841
# differential_evolution step 901: f(x)= 1.30954792900841
# differential_evolution step 902: f(x)= 1.30954792900841
# differential_evolution step 903: f(x)= 1.30954792900841
# differential_evolution step 904: f(x)= 1.30954792900841
# differential_evolution step 905: f(x)= 1.3077671257098304
# differential_evolution step 906: f(x)= 1.3077671257098304
# differential_evolution step 907: f(x)= 1.3077671257098304
# differential_evolution step 908: f(x)= 1.3077671257098304
# differential_evolution step 909: f(x)= 1.3077671257098304
# differential_evolution step 910: f(x)= 1.3077671257098304
# differential_evolution step 911: f(x)= 1.3077671257098304
# differential_evolution step 912: f(x)= 1.3077671257098304
# differential_evolution step 913: f(x)= 1.3077671257098304
# differential_evolution step 914: f(x)= 1.3041537470523683
# differential_evolution step 915: f(x)= 1.3041537470523683
# differential_evolution step 916: f(x)= 1.3041537470523683
# differential_evolution step 917: f(x)= 1.3041537470523683
# differential_evolution step 918: f(x)= 1.3041537470523683
# differential_evolution step 919: f(x)= 1.3041537470523683
# differential_evolution step 920: f(x)= 1.3041537470523683
# differential_evolution step 921: f(x)= 1.3041537470523683
# differential_evolution step 922: f(x)= 1.3041537470523683
# differential_evolution step 923: f(x)= 1.3041537470523683
# differential_evolution step 924: f(x)= 1.3041537470523683
# differential_evolution step 925: f(x)= 1.3041537470523683
# differential_evolution step 926: f(x)= 1.3041537470523683
# differential_evolution step 927: f(x)= 1.3041537470523683
# differential_evolution step 928: f(x)= 1.3041537470523683
# differential_evolution step 929: f(x)= 1.3041537470523683
# differential_evolution step 930: f(x)= 1.3041537470523683
# differential_evolution step 931: f(x)= 1.3029186518295615
# differential_evolution step 932: f(x)= 1.3029186518295615
# differential_evolution step 933: f(x)= 1.3029186518295615
# differential_evolution step 934: f(x)= 1.3029186518295615
# differential_evolution step 935: f(x)= 1.3029186518295615
# differential_evolution step 936: f(x)= 1.2950011006378512
# differential_evolution step 937: f(x)= 1.2950011006378512
# differential_evolution step 938: f(x)= 1.2950011006378512
# differential_evolution step 939: f(x)= 1.2950011006378512
# differential_evolution step 940: f(x)= 1.2950011006378512
# differential_evolution step 941: f(x)= 1.2950011006378512
# differential_evolution step 942: f(x)= 1.2950011006378512
# differential_evolution step 943: f(x)= 1.2950011006378512
# differential_evolution step 944: f(x)= 1.2950011006378512
# differential_evolution step 945: f(x)= 1.2950011006378512
# differential_evolution step 946: f(x)= 1.2950011006378512
# differential_evolution step 947: f(x)= 1.2950011006378512
# differential_evolution step 948: f(x)= 1.2950011006378512
# differential_evolution step 949: f(x)= 1.2950011006378512
# differential_evolution step 950: f(x)= 1.2950011006378512
# differential_evolution step 951: f(x)= 1.2950011006378512
# differential_evolution step 952: f(x)= 1.2950011006378512
# differential_evolution step 953: f(x)= 1.2950011006378512
# differential_evolution step 954: f(x)= 1.2950011006378512
# differential_evolution step 955: f(x)= 1.2950011006378512
# differential_evolution step 956: f(x)= 1.2950011006378512
# differential_evolution step 957: f(x)= 1.2950011006378512
# differential_evolution step 958: f(x)= 1.2950011006378512
# differential_evolution step 959: f(x)= 1.2950011006378512
# differential_evolution step 960: f(x)= 1.2941128351098237
# differential_evolution step 961: f(x)= 1.2941128351098237
# differential_evolution step 962: f(x)= 1.2941128351098237
# differential_evolution step 963: f(x)= 1.2941128351098237
# differential_evolution step 964: f(x)= 1.2941128351098237
# differential_evolution step 965: f(x)= 1.2941128351098237
# differential_evolution step 966: f(x)= 1.2941128351098237
# differential_evolution step 967: f(x)= 1.2941128351098237
# differential_evolution step 968: f(x)= 1.2941128351098237
# differential_evolution step 969: f(x)= 1.2941128351098237
# differential_evolution step 970: f(x)= 1.2941128351098237
# differential_evolution step 971: f(x)= 1.2941128351098237
# differential_evolution step 972: f(x)= 1.2928215677923636
# differential_evolution step 973: f(x)= 1.2928215677923636
# differential_evolution step 974: f(x)= 1.2928215677923636
# differential_evolution step 975: f(x)= 1.2928215677923636
# differential_evolution step 976: f(x)= 1.2928215677923636
# differential_evolution step 977: f(x)= 1.2928215677923636
# differential_evolution step 978: f(x)= 1.2928215677923636
# differential_evolution step 979: f(x)= 1.2928215677923636
# differential_evolution step 980: f(x)= 1.2928215677923636
# differential_evolution step 981: f(x)= 1.2928215677923636
# differential_evolution step 982: f(x)= 1.2928215677923636
# differential_evolution step 983: f(x)= 1.2834234992053948
# differential_evolution step 984: f(x)= 1.2834234992053948
# differential_evolution step 985: f(x)= 1.2834234992053948
# differential_evolution step 986: f(x)= 1.2834234992053948
# differential_evolution step 987: f(x)= 1.2834234992053948
# differential_evolution step 988: f(x)= 1.2834234992053948
# differential_evolution step 989: f(x)= 1.2834234992053948
# differential_evolution step 990: f(x)= 1.2834234992053948
# differential_evolution step 991: f(x)= 1.2834234992053948
# differential_evolution step 992: f(x)= 1.2834234992053948
# differential_evolution step 993: f(x)= 1.2834234992053948
# differential_evolution step 994: f(x)= 1.2834234992053948
# differential_evolution step 995: f(x)= 1.2834234992053948
# differential_evolution step 996: f(x)= 1.2834234992053948
# differential_evolution step 997: f(x)= 1.2834234992053948
# differential_evolution step 998: f(x)= 1.2834234992053948
# differential_evolution step 999: f(x)= 1.2834234992053948
# differential_evolution step 1000: f(x)= 1.2834234992053948
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [6.93750652e-01 1.02855820e+01 2.05726085e+00 3.61526164e+01
#  4.30896889e-01 6.91783384e+00 1.34137885e+00 4.19188968e+01
#  2.20275662e-01 7.43257665e+00 2.73177993e+00 5.95533078e+01
#  7.94072442e-02 2.37101631e+01 1.41619573e+00 7.17965374e+01
#  7.89515192e-04 2.14464366e+00 5.72983499e-01 1.98295067e+01]
# Chi quadro minimo: 1.2834234992053948

# %%
# Plots:
params_curve_5, covariance_5 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params5, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[4], red_chi[4] = save_params(params_curve_5, covariance_5, radial_profile_HA, radial_profile_error_HA, x_axes, 5, line_name="Five", output_prefix="fit")

aic[4] = AIC(x_axes, radial_profile_HA, chi_quadr[4], params_curve_5)
bic[4] = BIC(x_axes, radial_profile_HA, chi_quadr[4], params_curve_5)
print(aic[4], chi_quadr[4], bic[4], len(params_curve_5))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_5)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[16:20]),  linestyle='--', label='Sérsic 5')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)
plt.savefig('AIC_5')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16324\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16324\3428358457.py:11: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.9844, r_e=8.2937, n=1.7912, x_0=36.1847
# Sérsic 2: I_e=0.3377, r_e=7.0811, n=1.5338, x_0=42.1453
# Sérsic 3: I_e=0.1272, r_e=12.2313, n=3.0367, x_0=59.5634
# Sérsic 4: I_e=0.0420, r_e=34.7843, n=1.8178, x_0=72.1711
# Sérsic 5: I_e=0.0044, r_e=0.1989, n=6.9577, x_0=19.5824
# [2.11028621e-01 1.29063626e+00 1.62959916e-01 4.76827772e-02
#  3.07169545e-01 5.73615788e+00 6.45608796e-01 1.70423562e-01
#  7.30794517e-01 4.74920904e+01 6.30695876e+00 2.10949803e-03
#  3.56247807e-02 2.47258225e+01 5.28601140e-01 4.33829142e-01
#  1.52395953e+02 2.75383346e+03 7.15979896e+04 1.15690652e+01]
# 8.344937015860484
# 58.977848408265544 8.344937015860484 100.44834073562232 20
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20]) +
        sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =[
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (20, 40),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (40, 50),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (50, 70),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (70, 80),
    
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (19, 21),   # x_0: posizione da 0 a 100   # x_0: posizione da 0 a 100

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100)   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params6 = result.x

print("Optimize parameters with differential_evolution:", best_params6)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 139613.3047562003
# differential_evolution step 2: f(x)= 87471.36396383896
# differential_evolution step 3: f(x)= 10346.846559848242
# differential_evolution step 4: f(x)= 9442.03810331519
# differential_evolution step 5: f(x)= 9442.03810331519
# differential_evolution step 6: f(x)= 9442.03810331519
# differential_evolution step 7: f(x)= 9442.03810331519
# differential_evolution step 8: f(x)= 6041.280288755239
# differential_evolution step 9: f(x)= 6041.280288755239
# differential_evolution step 10: f(x)= 6041.280288755239
# differential_evolution step 11: f(x)= 6041.280288755239
# differential_evolution step 12: f(x)= 6041.280288755239
# differential_evolution step 13: f(x)= 6041.280288755239
# differential_evolution step 14: f(x)= 850.2005050727046
# differential_evolution step 15: f(x)= 850.2005050727046
# differential_evolution step 16: f(x)= 850.2005050727046
# differential_evolution step 17: f(x)= 850.2005050727046
# differential_evolution step 18: f(x)= 850.2005050727046
# differential_evolution step 19: f(x)= 850.2005050727046
# differential_evolution step 20: f(x)= 850.2005050727046
# differential_evolution step 21: f(x)= 850.2005050727046
# differential_evolution step 22: f(x)= 589.114456337419
# differential_evolution step 23: f(x)= 589.114456337419
# differential_evolution step 24: f(x)= 589.114456337419
# differential_evolution step 25: f(x)= 589.114456337419
# differential_evolution step 26: f(x)= 589.114456337419
# differential_evolution step 27: f(x)= 589.114456337419
# differential_evolution step 28: f(x)= 589.114456337419
# differential_evolution step 29: f(x)= 589.114456337419
# differential_evolution step 30: f(x)= 562.1198709425174
# differential_evolution step 31: f(x)= 562.1198709425174
# differential_evolution step 32: f(x)= 437.29547388866666
# differential_evolution step 33: f(x)= 379.3347708991613
# differential_evolution step 34: f(x)= 379.3347708991613
# differential_evolution step 35: f(x)= 379.3347708991613
# differential_evolution step 36: f(x)= 229.80099756366036
# differential_evolution step 37: f(x)= 229.80099756366036
# differential_evolution step 38: f(x)= 160.2438212561749
# differential_evolution step 39: f(x)= 160.2438212561749
# differential_evolution step 40: f(x)= 160.2438212561749
# differential_evolution step 41: f(x)= 160.2438212561749
# differential_evolution step 42: f(x)= 160.2438212561749
# differential_evolution step 43: f(x)= 160.2438212561749
# differential_evolution step 44: f(x)= 160.2438212561749
# differential_evolution step 45: f(x)= 160.2438212561749
# differential_evolution step 46: f(x)= 160.2438212561749
# differential_evolution step 47: f(x)= 160.2438212561749
# differential_evolution step 48: f(x)= 160.2438212561749
# differential_evolution step 49: f(x)= 160.2438212561749
# differential_evolution step 50: f(x)= 160.2438212561749
# differential_evolution step 51: f(x)= 160.2438212561749
# differential_evolution step 52: f(x)= 160.2438212561749
# differential_evolution step 53: f(x)= 160.2438212561749
# differential_evolution step 54: f(x)= 160.2438212561749
# differential_evolution step 55: f(x)= 133.19868567182303
# differential_evolution step 56: f(x)= 133.19868567182303
# differential_evolution step 57: f(x)= 133.19868567182303
# differential_evolution step 58: f(x)= 133.19868567182303
# differential_evolution step 59: f(x)= 133.19868567182303
# differential_evolution step 60: f(x)= 128.6731647932584
# differential_evolution step 61: f(x)= 128.6731647932584
# differential_evolution step 62: f(x)= 111.70692676303446
# differential_evolution step 63: f(x)= 111.70692676303446
# differential_evolution step 64: f(x)= 111.70692676303446
# differential_evolution step 65: f(x)= 111.70692676303446
# differential_evolution step 66: f(x)= 111.70692676303446
# differential_evolution step 67: f(x)= 111.70692676303446
# differential_evolution step 68: f(x)= 111.70692676303446
# differential_evolution step 69: f(x)= 111.70692676303446
# differential_evolution step 70: f(x)= 111.70692676303446
# differential_evolution step 71: f(x)= 111.70692676303446
# differential_evolution step 72: f(x)= 111.70692676303446
# differential_evolution step 73: f(x)= 111.70692676303446
# differential_evolution step 74: f(x)= 109.59662301540752
# differential_evolution step 75: f(x)= 109.59662301540752
# differential_evolution step 76: f(x)= 109.59662301540752
# differential_evolution step 77: f(x)= 103.54302226145938
# differential_evolution step 78: f(x)= 103.54302226145938
# differential_evolution step 79: f(x)= 83.00500571728018
# differential_evolution step 80: f(x)= 83.00500571728018
# differential_evolution step 81: f(x)= 83.00500571728018
# differential_evolution step 82: f(x)= 83.00500571728018
# differential_evolution step 83: f(x)= 83.00500571728018
# differential_evolution step 84: f(x)= 83.00500571728018
# differential_evolution step 85: f(x)= 76.1133675102293
# differential_evolution step 86: f(x)= 76.1133675102293
# differential_evolution step 87: f(x)= 76.1133675102293
# differential_evolution step 88: f(x)= 76.1133675102293
# differential_evolution step 89: f(x)= 65.95229387364131
# differential_evolution step 90: f(x)= 65.95229387364131
# differential_evolution step 91: f(x)= 54.542423577796804
# differential_evolution step 92: f(x)= 54.542423577796804
# differential_evolution step 93: f(x)= 54.542423577796804
# differential_evolution step 94: f(x)= 54.542423577796804
# differential_evolution step 95: f(x)= 54.542423577796804
# differential_evolution step 96: f(x)= 54.542423577796804
# differential_evolution step 97: f(x)= 54.542423577796804
# differential_evolution step 98: f(x)= 54.542423577796804
# differential_evolution step 99: f(x)= 34.63312842695212
# differential_evolution step 100: f(x)= 34.63312842695212
# differential_evolution step 101: f(x)= 34.63312842695212
# differential_evolution step 102: f(x)= 34.63312842695212
# differential_evolution step 103: f(x)= 34.63312842695212
# differential_evolution step 104: f(x)= 34.63312842695212
# differential_evolution step 105: f(x)= 34.63312842695212
# differential_evolution step 106: f(x)= 34.63312842695212
# differential_evolution step 107: f(x)= 34.63312842695212
# differential_evolution step 108: f(x)= 34.63312842695212
# differential_evolution step 109: f(x)= 34.63312842695212
# differential_evolution step 110: f(x)= 34.63312842695212
# differential_evolution step 111: f(x)= 34.63312842695212
# differential_evolution step 112: f(x)= 34.63312842695212
# differential_evolution step 113: f(x)= 34.26396510626984
# differential_evolution step 114: f(x)= 28.736945804953365
# differential_evolution step 115: f(x)= 28.736945804953365
# differential_evolution step 116: f(x)= 28.736945804953365
# differential_evolution step 117: f(x)= 28.736945804953365
# differential_evolution step 118: f(x)= 28.736945804953365
# differential_evolution step 119: f(x)= 28.736945804953365
# differential_evolution step 120: f(x)= 26.76686991658352
# differential_evolution step 121: f(x)= 26.76686991658352
# differential_evolution step 122: f(x)= 26.76686991658352
# differential_evolution step 123: f(x)= 26.76686991658352
# differential_evolution step 124: f(x)= 26.76686991658352
# differential_evolution step 125: f(x)= 26.76686991658352
# differential_evolution step 126: f(x)= 25.106515989276826
# differential_evolution step 127: f(x)= 25.106515989276826
# differential_evolution step 128: f(x)= 25.106515989276826
# differential_evolution step 129: f(x)= 23.683500143700385
# differential_evolution step 130: f(x)= 23.683500143700385
# differential_evolution step 131: f(x)= 23.683500143700385
# differential_evolution step 132: f(x)= 23.683500143700385
# differential_evolution step 133: f(x)= 23.683500143700385
# differential_evolution step 134: f(x)= 23.683500143700385
# differential_evolution step 135: f(x)= 23.683500143700385
# differential_evolution step 136: f(x)= 23.683500143700385
# differential_evolution step 137: f(x)= 14.513799114476829
# differential_evolution step 138: f(x)= 14.513799114476829
# differential_evolution step 139: f(x)= 14.513799114476829
# differential_evolution step 140: f(x)= 14.513799114476829
# differential_evolution step 141: f(x)= 14.513799114476829
# differential_evolution step 142: f(x)= 14.513799114476829
# differential_evolution step 143: f(x)= 14.513799114476829
# differential_evolution step 144: f(x)= 10.878993528099443
# differential_evolution step 145: f(x)= 10.878993528099443
# differential_evolution step 146: f(x)= 10.878993528099443
# differential_evolution step 147: f(x)= 10.878993528099443
# differential_evolution step 148: f(x)= 8.340324381978169
# differential_evolution step 149: f(x)= 8.340324381978169
# differential_evolution step 150: f(x)= 8.340324381978169
# differential_evolution step 151: f(x)= 8.340324381978169
# differential_evolution step 152: f(x)= 8.340324381978169
# differential_evolution step 153: f(x)= 8.340324381978169
# differential_evolution step 154: f(x)= 8.340324381978169
# differential_evolution step 155: f(x)= 8.320748227632064
# differential_evolution step 156: f(x)= 8.320748227632064
# differential_evolution step 157: f(x)= 8.320748227632064
# differential_evolution step 158: f(x)= 8.320748227632064
# differential_evolution step 159: f(x)= 8.320748227632064
# differential_evolution step 160: f(x)= 8.320748227632064
# differential_evolution step 161: f(x)= 8.320748227632064
# differential_evolution step 162: f(x)= 8.320748227632064
# differential_evolution step 163: f(x)= 8.320748227632064
# differential_evolution step 164: f(x)= 8.320748227632064
# differential_evolution step 165: f(x)= 8.320748227632064
# differential_evolution step 166: f(x)= 8.320748227632064
# differential_evolution step 167: f(x)= 8.320748227632064
# differential_evolution step 168: f(x)= 8.320748227632064
# differential_evolution step 169: f(x)= 8.320748227632064
# differential_evolution step 170: f(x)= 8.320748227632064
# differential_evolution step 171: f(x)= 8.320748227632064
# differential_evolution step 172: f(x)= 8.320748227632064
# differential_evolution step 173: f(x)= 8.320748227632064
# differential_evolution step 174: f(x)= 8.320748227632064
# differential_evolution step 175: f(x)= 8.320748227632064
# differential_evolution step 176: f(x)= 8.320748227632064
# differential_evolution step 177: f(x)= 8.320748227632064
# differential_evolution step 178: f(x)= 8.320748227632064
# differential_evolution step 179: f(x)= 8.320748227632064
# differential_evolution step 180: f(x)= 8.320748227632064
# differential_evolution step 181: f(x)= 5.219274459259883
# differential_evolution step 182: f(x)= 5.219274459259883
# differential_evolution step 183: f(x)= 5.219274459259883
# differential_evolution step 184: f(x)= 5.219274459259883
# differential_evolution step 185: f(x)= 5.219274459259883
# differential_evolution step 186: f(x)= 5.219274459259883
# differential_evolution step 187: f(x)= 5.219274459259883
# differential_evolution step 188: f(x)= 5.219274459259883
# differential_evolution step 189: f(x)= 5.219274459259883
# differential_evolution step 190: f(x)= 5.219274459259883
# differential_evolution step 191: f(x)= 5.219274459259883
# differential_evolution step 192: f(x)= 5.219274459259883
# differential_evolution step 193: f(x)= 5.219274459259883
# differential_evolution step 194: f(x)= 5.219274459259883
# differential_evolution step 195: f(x)= 5.219274459259883
# differential_evolution step 196: f(x)= 5.219274459259883
# differential_evolution step 197: f(x)= 5.219274459259883
# differential_evolution step 198: f(x)= 5.219274459259883
# differential_evolution step 199: f(x)= 5.219274459259883
# differential_evolution step 200: f(x)= 5.219274459259883
# differential_evolution step 201: f(x)= 5.219274459259883
# differential_evolution step 202: f(x)= 4.506932898388479
# differential_evolution step 203: f(x)= 4.506932898388479
# differential_evolution step 204: f(x)= 4.506932898388479
# differential_evolution step 205: f(x)= 4.506932898388479
# differential_evolution step 206: f(x)= 4.506932898388479
# differential_evolution step 207: f(x)= 4.506932898388479
# differential_evolution step 208: f(x)= 4.506932898388479
# differential_evolution step 209: f(x)= 4.506932898388479
# differential_evolution step 210: f(x)= 3.4553829251912473
# differential_evolution step 211: f(x)= 3.4553829251912473
# differential_evolution step 212: f(x)= 3.4553829251912473
# differential_evolution step 213: f(x)= 3.4553829251912473
# differential_evolution step 214: f(x)= 3.4553829251912473
# differential_evolution step 215: f(x)= 3.4553829251912473
# differential_evolution step 216: f(x)= 3.4553829251912473
# differential_evolution step 217: f(x)= 3.4553829251912473
# differential_evolution step 218: f(x)= 3.4553829251912473
# differential_evolution step 219: f(x)= 3.4553829251912473
# differential_evolution step 220: f(x)= 3.4050211446054517
# differential_evolution step 221: f(x)= 3.4050211446054517
# differential_evolution step 222: f(x)= 3.1031987993237258
# differential_evolution step 223: f(x)= 3.1031987993237258
# differential_evolution step 224: f(x)= 3.1031987993237258
# differential_evolution step 225: f(x)= 3.1031987993237258
# differential_evolution step 226: f(x)= 3.1031987993237258
# differential_evolution step 227: f(x)= 3.1031987993237258
# differential_evolution step 228: f(x)= 3.1031987993237258
# differential_evolution step 229: f(x)= 3.1031987993237258
# differential_evolution step 230: f(x)= 3.1031987993237258
# differential_evolution step 231: f(x)= 3.1031987993237258
# differential_evolution step 232: f(x)= 3.1031987993237258
# differential_evolution step 233: f(x)= 2.605619947463415
# differential_evolution step 234: f(x)= 2.605619947463415
# differential_evolution step 235: f(x)= 2.605619947463415
# differential_evolution step 236: f(x)= 2.2525572617347023
# differential_evolution step 237: f(x)= 2.2525572617347023
# differential_evolution step 238: f(x)= 2.2525572617347023
# differential_evolution step 239: f(x)= 2.2525572617347023
# differential_evolution step 240: f(x)= 2.2525572617347023
# differential_evolution step 241: f(x)= 1.4704021582086197
# differential_evolution step 242: f(x)= 1.4704021582086197
# differential_evolution step 243: f(x)= 1.4704021582086197
# differential_evolution step 244: f(x)= 1.4704021582086197
# differential_evolution step 245: f(x)= 1.4704021582086197
# differential_evolution step 246: f(x)= 1.4704021582086197
# differential_evolution step 247: f(x)= 1.4704021582086197
# differential_evolution step 248: f(x)= 1.4704021582086197
# differential_evolution step 249: f(x)= 1.4704021582086197
# differential_evolution step 250: f(x)= 1.4704021582086197
# differential_evolution step 251: f(x)= 1.4704021582086197
# differential_evolution step 252: f(x)= 1.4704021582086197
# differential_evolution step 253: f(x)= 1.4704021582086197
# differential_evolution step 254: f(x)= 1.4704021582086197
# differential_evolution step 255: f(x)= 1.4704021582086197
# differential_evolution step 256: f(x)= 1.4704021582086197
# differential_evolution step 257: f(x)= 1.4704021582086197
# differential_evolution step 258: f(x)= 1.4704021582086197
# differential_evolution step 259: f(x)= 1.4704021582086197
# differential_evolution step 260: f(x)= 1.4704021582086197
# differential_evolution step 261: f(x)= 1.4704021582086197
# differential_evolution step 262: f(x)= 1.4704021582086197
# differential_evolution step 263: f(x)= 1.4704021582086197
# differential_evolution step 264: f(x)= 1.4704021582086197
# differential_evolution step 265: f(x)= 1.4704021582086197
# differential_evolution step 266: f(x)= 1.4704021582086197
# differential_evolution step 267: f(x)= 1.4704021582086197
# differential_evolution step 268: f(x)= 1.4704021582086197
# differential_evolution step 269: f(x)= 1.4704021582086197
# differential_evolution step 270: f(x)= 1.4704021582086197
# differential_evolution step 271: f(x)= 1.4704021582086197
# differential_evolution step 272: f(x)= 1.4704021582086197
# differential_evolution step 273: f(x)= 1.4704021582086197
# differential_evolution step 274: f(x)= 1.4704021582086197
# differential_evolution step 275: f(x)= 1.4704021582086197
# differential_evolution step 276: f(x)= 1.4704021582086197
# differential_evolution step 277: f(x)= 1.4704021582086197
# differential_evolution step 278: f(x)= 1.4704021582086197
# differential_evolution step 279: f(x)= 1.4704021582086197
# differential_evolution step 280: f(x)= 1.4704021582086197
# differential_evolution step 281: f(x)= 1.4704021582086197
# differential_evolution step 282: f(x)= 1.4704021582086197
# differential_evolution step 283: f(x)= 1.4704021582086197
# differential_evolution step 284: f(x)= 1.4704021582086197
# differential_evolution step 285: f(x)= 1.4704021582086197
# differential_evolution step 286: f(x)= 1.4704021582086197
# differential_evolution step 287: f(x)= 1.4704021582086197
# differential_evolution step 288: f(x)= 1.4704021582086197
# differential_evolution step 289: f(x)= 1.4704021582086197
# differential_evolution step 290: f(x)= 1.4704021582086197
# differential_evolution step 291: f(x)= 1.4704021582086197
# differential_evolution step 292: f(x)= 1.4704021582086197
# differential_evolution step 293: f(x)= 1.469939517948001
# differential_evolution step 294: f(x)= 1.469939517948001
# differential_evolution step 295: f(x)= 1.469939517948001
# differential_evolution step 296: f(x)= 1.469939517948001
# differential_evolution step 297: f(x)= 1.469939517948001
# differential_evolution step 298: f(x)= 1.469939517948001
# differential_evolution step 299: f(x)= 1.469939517948001
# differential_evolution step 300: f(x)= 1.469939517948001
# differential_evolution step 301: f(x)= 1.4286416476356285
# differential_evolution step 302: f(x)= 1.4286416476356285
# differential_evolution step 303: f(x)= 1.4286416476356285
# differential_evolution step 304: f(x)= 1.4286416476356285
# differential_evolution step 305: f(x)= 1.4286416476356285
# differential_evolution step 306: f(x)= 1.4286416476356285
# differential_evolution step 307: f(x)= 1.3947709993117157
# differential_evolution step 308: f(x)= 1.3947709993117157
# differential_evolution step 309: f(x)= 1.3947709993117157
# differential_evolution step 310: f(x)= 1.3947709993117157
# differential_evolution step 311: f(x)= 1.3947709993117157
# differential_evolution step 312: f(x)= 1.3947709993117157
# differential_evolution step 313: f(x)= 1.3947709993117157
# differential_evolution step 314: f(x)= 1.3947709993117157
# differential_evolution step 315: f(x)= 1.3947709993117157
# differential_evolution step 316: f(x)= 1.3947709993117157
# differential_evolution step 317: f(x)= 1.3947709993117157
# differential_evolution step 318: f(x)= 1.3947709993117157
# differential_evolution step 319: f(x)= 1.3947709993117157
# differential_evolution step 320: f(x)= 1.3947709993117157
# differential_evolution step 321: f(x)= 1.3947709993117157
# differential_evolution step 322: f(x)= 1.3947709993117157
# differential_evolution step 323: f(x)= 1.3947709993117157
# differential_evolution step 324: f(x)= 1.3947709993117157
# differential_evolution step 325: f(x)= 1.3947709993117157
# differential_evolution step 326: f(x)= 1.3947709993117157
# differential_evolution step 327: f(x)= 1.3946338712265802
# differential_evolution step 328: f(x)= 1.3946338712265802
# differential_evolution step 329: f(x)= 1.3946338712265802
# differential_evolution step 330: f(x)= 1.3946338712265802
# differential_evolution step 331: f(x)= 1.3946338712265802
# differential_evolution step 332: f(x)= 1.3946338712265802
# differential_evolution step 333: f(x)= 1.3946338712265802
# differential_evolution step 334: f(x)= 1.3946338712265802
# differential_evolution step 335: f(x)= 1.3946338712265802
# differential_evolution step 336: f(x)= 1.3946338712265802
# differential_evolution step 337: f(x)= 1.3946338712265802
# differential_evolution step 338: f(x)= 1.3946338712265802
# differential_evolution step 339: f(x)= 1.3946338712265802
# differential_evolution step 340: f(x)= 1.3946338712265802
# differential_evolution step 341: f(x)= 1.3946338712265802
# differential_evolution step 342: f(x)= 1.3946338712265802
# differential_evolution step 343: f(x)= 1.3946338712265802
# differential_evolution step 344: f(x)= 1.3946338712265802
# differential_evolution step 345: f(x)= 1.3946338712265802
# differential_evolution step 346: f(x)= 1.3946338712265802
# differential_evolution step 347: f(x)= 1.3946338712265802
# differential_evolution step 348: f(x)= 1.3691305198346775
# differential_evolution step 349: f(x)= 1.3691305198346775
# differential_evolution step 350: f(x)= 1.3691305198346775
# differential_evolution step 351: f(x)= 1.3691305198346775
# differential_evolution step 352: f(x)= 1.3637389856865418
# differential_evolution step 353: f(x)= 1.3637389856865418
# differential_evolution step 354: f(x)= 1.3637389856865418
# differential_evolution step 355: f(x)= 1.3637389856865418
# differential_evolution step 356: f(x)= 1.3327566209076256
# differential_evolution step 357: f(x)= 1.3327566209076256
# differential_evolution step 358: f(x)= 1.3327566209076256
# differential_evolution step 359: f(x)= 1.3327566209076256
# differential_evolution step 360: f(x)= 1.3327566209076256
# differential_evolution step 361: f(x)= 1.3327566209076256
# differential_evolution step 362: f(x)= 1.3327566209076256
# differential_evolution step 363: f(x)= 1.3327566209076256
# differential_evolution step 364: f(x)= 1.3327566209076256
# differential_evolution step 365: f(x)= 1.3327566209076256
# differential_evolution step 366: f(x)= 1.3327566209076256
# differential_evolution step 367: f(x)= 1.3327566209076256
# differential_evolution step 368: f(x)= 1.3327566209076256
# differential_evolution step 369: f(x)= 1.3327566209076256
# differential_evolution step 370: f(x)= 1.3327566209076256
# differential_evolution step 371: f(x)= 1.3327566209076256
# differential_evolution step 372: f(x)= 1.3327566209076256
# differential_evolution step 373: f(x)= 1.3327566209076256
# differential_evolution step 374: f(x)= 1.3327566209076256
# differential_evolution step 375: f(x)= 1.3327566209076256
# differential_evolution step 376: f(x)= 1.3327566209076256
# differential_evolution step 377: f(x)= 1.3327566209076256
# differential_evolution step 378: f(x)= 1.3327566209076256
# differential_evolution step 379: f(x)= 1.3327566209076256
# differential_evolution step 380: f(x)= 1.3327566209076256
# differential_evolution step 381: f(x)= 1.3327566209076256
# differential_evolution step 382: f(x)= 1.3327566209076256
# differential_evolution step 383: f(x)= 1.3327566209076256
# differential_evolution step 384: f(x)= 1.3327566209076256
# differential_evolution step 385: f(x)= 1.3327566209076256
# differential_evolution step 386: f(x)= 1.3327566209076256
# differential_evolution step 387: f(x)= 1.3327566209076256
# differential_evolution step 388: f(x)= 1.3327566209076256
# differential_evolution step 389: f(x)= 1.3327566209076256
# differential_evolution step 390: f(x)= 1.2780716845060471
# differential_evolution step 391: f(x)= 1.2780716845060471
# differential_evolution step 392: f(x)= 1.2780716845060471
# differential_evolution step 393: f(x)= 1.2780716845060471
# differential_evolution step 394: f(x)= 1.2780716845060471
# differential_evolution step 395: f(x)= 1.2780716845060471
# differential_evolution step 396: f(x)= 1.2780716845060471
# differential_evolution step 397: f(x)= 1.2780716845060471
# differential_evolution step 398: f(x)= 1.2780716845060471
# differential_evolution step 399: f(x)= 1.2780716845060471
# differential_evolution step 400: f(x)= 1.2780716845060471
# differential_evolution step 401: f(x)= 1.2780716845060471
# differential_evolution step 402: f(x)= 1.2780716845060471
# differential_evolution step 403: f(x)= 1.2780716845060471
# differential_evolution step 404: f(x)= 1.2780716845060471
# differential_evolution step 405: f(x)= 1.2780716845060471
# differential_evolution step 406: f(x)= 1.2780716845060471
# differential_evolution step 407: f(x)= 1.2780716845060471
# differential_evolution step 408: f(x)= 1.2780716845060471
# differential_evolution step 409: f(x)= 1.2780716845060471
# differential_evolution step 410: f(x)= 1.2780716845060471
# differential_evolution step 411: f(x)= 1.2780716845060471
# differential_evolution step 412: f(x)= 1.2780716845060471
# differential_evolution step 413: f(x)= 1.2780716845060471
# differential_evolution step 414: f(x)= 1.2780716845060471
# differential_evolution step 415: f(x)= 1.2780716845060471
# differential_evolution step 416: f(x)= 1.2780716845060471
# differential_evolution step 417: f(x)= 1.2780716845060471
# differential_evolution step 418: f(x)= 1.2780716845060471
# differential_evolution step 419: f(x)= 1.2780716845060471
# differential_evolution step 420: f(x)= 1.2687639014435181
# differential_evolution step 421: f(x)= 1.2687639014435181
# differential_evolution step 422: f(x)= 1.262649100783789
# differential_evolution step 423: f(x)= 1.2455076367458602
# differential_evolution step 424: f(x)= 1.2455076367458602
# differential_evolution step 425: f(x)= 1.2455076367458602
# differential_evolution step 426: f(x)= 1.2455076367458602
# differential_evolution step 427: f(x)= 1.2455076367458602
# differential_evolution step 428: f(x)= 1.2455076367458602
# differential_evolution step 429: f(x)= 1.2455076367458602
# differential_evolution step 430: f(x)= 1.2455076367458602
# differential_evolution step 431: f(x)= 1.2455076367458602
# differential_evolution step 432: f(x)= 1.2455076367458602
# differential_evolution step 433: f(x)= 1.2455076367458602
# differential_evolution step 434: f(x)= 1.2455076367458602
# differential_evolution step 435: f(x)= 1.2455076367458602
# differential_evolution step 436: f(x)= 1.2455076367458602
# differential_evolution step 437: f(x)= 1.2455076367458602
# differential_evolution step 438: f(x)= 1.2455076367458602
# differential_evolution step 439: f(x)= 1.2455076367458602
# differential_evolution step 440: f(x)= 1.2455076367458602
# differential_evolution step 441: f(x)= 1.2455076367458602
# differential_evolution step 442: f(x)= 1.2455076367458602
# differential_evolution step 443: f(x)= 1.2455076367458602
# differential_evolution step 444: f(x)= 1.2455076367458602
# differential_evolution step 445: f(x)= 1.2455076367458602
# differential_evolution step 446: f(x)= 1.2455076367458602
# differential_evolution step 447: f(x)= 1.2455076367458602
# differential_evolution step 448: f(x)= 1.2455076367458602
# differential_evolution step 449: f(x)= 1.2455076367458602
# differential_evolution step 450: f(x)= 1.2455076367458602
# differential_evolution step 451: f(x)= 1.2455076367458602
# differential_evolution step 452: f(x)= 1.2455076367458602
# differential_evolution step 453: f(x)= 1.2341800206225815
# differential_evolution step 454: f(x)= 1.2341800206225815
# differential_evolution step 455: f(x)= 1.2341800206225815
# differential_evolution step 456: f(x)= 1.2341800206225815
# differential_evolution step 457: f(x)= 1.2341800206225815
# differential_evolution step 458: f(x)= 1.2341800206225815
# differential_evolution step 459: f(x)= 1.2341800206225815
# differential_evolution step 460: f(x)= 1.2341800206225815
# differential_evolution step 461: f(x)= 1.2341800206225815
# differential_evolution step 462: f(x)= 1.2341800206225815
# differential_evolution step 463: f(x)= 1.2341800206225815
# differential_evolution step 464: f(x)= 1.2341800206225815
# differential_evolution step 465: f(x)= 1.2341800206225815
# differential_evolution step 466: f(x)= 1.2341800206225815
# differential_evolution step 467: f(x)= 1.2341800206225815
# differential_evolution step 468: f(x)= 1.2341800206225815
# differential_evolution step 469: f(x)= 1.2341800206225815
# differential_evolution step 470: f(x)= 1.2341800206225815
# differential_evolution step 471: f(x)= 1.2341800206225815
# differential_evolution step 472: f(x)= 1.2341800206225815
# differential_evolution step 473: f(x)= 1.2341800206225815
# differential_evolution step 474: f(x)= 1.2341800206225815
# differential_evolution step 475: f(x)= 1.2316712941749997
# differential_evolution step 476: f(x)= 1.2316712941749997
# differential_evolution step 477: f(x)= 1.2316712941749997
# differential_evolution step 478: f(x)= 1.2316712941749997
# differential_evolution step 479: f(x)= 1.2316712941749997
# differential_evolution step 480: f(x)= 1.2316712941749997
# differential_evolution step 481: f(x)= 1.2316712941749997
# differential_evolution step 482: f(x)= 1.2316712941749997
# differential_evolution step 483: f(x)= 1.2316712941749997
# differential_evolution step 484: f(x)= 1.2316712941749997
# differential_evolution step 485: f(x)= 1.2316712941749997
# differential_evolution step 486: f(x)= 1.2316712941749997
# differential_evolution step 487: f(x)= 1.2316712941749997
# differential_evolution step 488: f(x)= 1.2316712941749997
# differential_evolution step 489: f(x)= 1.2316712941749997
# differential_evolution step 490: f(x)= 1.2316712941749997
# differential_evolution step 491: f(x)= 1.2316712941749997
# differential_evolution step 492: f(x)= 1.2316712941749997
# differential_evolution step 493: f(x)= 1.211457190470094
# differential_evolution step 494: f(x)= 1.211457190470094
# differential_evolution step 495: f(x)= 1.211457190470094
# differential_evolution step 496: f(x)= 1.211457190470094
# differential_evolution step 497: f(x)= 1.211457190470094
# differential_evolution step 498: f(x)= 1.211457190470094
# differential_evolution step 499: f(x)= 1.211457190470094
# differential_evolution step 500: f(x)= 1.211457190470094
# differential_evolution step 501: f(x)= 1.211457190470094
# differential_evolution step 502: f(x)= 1.211457190470094
# differential_evolution step 503: f(x)= 1.211457190470094
# differential_evolution step 504: f(x)= 1.211457190470094
# differential_evolution step 505: f(x)= 1.211457190470094
# differential_evolution step 506: f(x)= 1.211457190470094
# differential_evolution step 507: f(x)= 1.211457190470094
# differential_evolution step 508: f(x)= 1.211457190470094
# differential_evolution step 509: f(x)= 1.211457190470094
# differential_evolution step 510: f(x)= 1.211457190470094
# differential_evolution step 511: f(x)= 1.211457190470094
# differential_evolution step 512: f(x)= 1.211457190470094
# differential_evolution step 513: f(x)= 1.211457190470094
# differential_evolution step 514: f(x)= 1.2080928196568057
# differential_evolution step 515: f(x)= 1.2080928196568057
# differential_evolution step 516: f(x)= 1.2080928196568057
# differential_evolution step 517: f(x)= 1.2080928196568057
# differential_evolution step 518: f(x)= 1.2080928196568057
# differential_evolution step 519: f(x)= 1.2080928196568057
# differential_evolution step 520: f(x)= 1.2080928196568057
# differential_evolution step 521: f(x)= 1.2080928196568057
# differential_evolution step 522: f(x)= 1.2080928196568057
# differential_evolution step 523: f(x)= 1.2080928196568057
# differential_evolution step 524: f(x)= 1.1999660675851547
# differential_evolution step 525: f(x)= 1.1843514125220689
# differential_evolution step 526: f(x)= 1.1843514125220689
# differential_evolution step 527: f(x)= 1.1843514125220689
# differential_evolution step 528: f(x)= 1.1843514125220689
# differential_evolution step 529: f(x)= 1.1843514125220689
# differential_evolution step 530: f(x)= 1.1843514125220689
# differential_evolution step 531: f(x)= 1.1843514125220689
# differential_evolution step 532: f(x)= 1.1843514125220689
# differential_evolution step 533: f(x)= 1.1843514125220689
# differential_evolution step 534: f(x)= 1.1843514125220689
# differential_evolution step 535: f(x)= 1.1843514125220689
# differential_evolution step 536: f(x)= 1.1843514125220689
# differential_evolution step 537: f(x)= 1.1843514125220689
# differential_evolution step 538: f(x)= 1.1843514125220689
# differential_evolution step 539: f(x)= 1.1843514125220689
# differential_evolution step 540: f(x)= 1.1843514125220689
# differential_evolution step 541: f(x)= 1.1843514125220689
# differential_evolution step 542: f(x)= 1.1843514125220689
# differential_evolution step 543: f(x)= 1.1843514125220689
# differential_evolution step 544: f(x)= 1.1843514125220689
# differential_evolution step 545: f(x)= 1.1843514125220689
# differential_evolution step 546: f(x)= 1.1843514125220689
# differential_evolution step 547: f(x)= 1.1843514125220689
# differential_evolution step 548: f(x)= 1.1843514125220689
# differential_evolution step 549: f(x)= 1.1843514125220689
# differential_evolution step 550: f(x)= 1.1843514125220689
# differential_evolution step 551: f(x)= 1.1843514125220689
# differential_evolution step 552: f(x)= 1.1843514125220689
# differential_evolution step 553: f(x)= 1.1843514125220689
# differential_evolution step 554: f(x)= 1.1843514125220689
# differential_evolution step 555: f(x)= 1.1843514125220689
# differential_evolution step 556: f(x)= 1.1843514125220689
# differential_evolution step 557: f(x)= 1.1843514125220689
# differential_evolution step 558: f(x)= 1.1843514125220689
# differential_evolution step 559: f(x)= 1.1843514125220689
# differential_evolution step 560: f(x)= 1.1843514125220689
# differential_evolution step 561: f(x)= 1.1843514125220689
# differential_evolution step 562: f(x)= 1.1843514125220689
# differential_evolution step 563: f(x)= 1.151341406678802
# differential_evolution step 564: f(x)= 1.151341406678802
# differential_evolution step 565: f(x)= 1.151341406678802
# differential_evolution step 566: f(x)= 1.151341406678802
# differential_evolution step 567: f(x)= 1.151341406678802
# differential_evolution step 568: f(x)= 1.151341406678802
# differential_evolution step 569: f(x)= 1.151341406678802
# differential_evolution step 570: f(x)= 1.151341406678802
# differential_evolution step 571: f(x)= 1.151341406678802
# differential_evolution step 572: f(x)= 1.151341406678802
# differential_evolution step 573: f(x)= 1.151341406678802
# differential_evolution step 574: f(x)= 1.151341406678802
# differential_evolution step 575: f(x)= 1.151341406678802
# differential_evolution step 576: f(x)= 1.151341406678802
# differential_evolution step 577: f(x)= 1.151341406678802
# differential_evolution step 578: f(x)= 1.151341406678802
# differential_evolution step 579: f(x)= 1.151341406678802
# differential_evolution step 580: f(x)= 1.151341406678802
# differential_evolution step 581: f(x)= 1.151341406678802
# differential_evolution step 582: f(x)= 1.151341406678802
# differential_evolution step 583: f(x)= 1.151341406678802
# differential_evolution step 584: f(x)= 1.151341406678802
# differential_evolution step 585: f(x)= 1.151341406678802
# differential_evolution step 586: f(x)= 1.133161680100144
# differential_evolution step 587: f(x)= 1.133161680100144
# differential_evolution step 588: f(x)= 1.133161680100144
# differential_evolution step 589: f(x)= 1.133161680100144
# differential_evolution step 590: f(x)= 1.133161680100144
# differential_evolution step 591: f(x)= 1.133161680100144
# differential_evolution step 592: f(x)= 1.133161680100144
# differential_evolution step 593: f(x)= 1.133161680100144
# differential_evolution step 594: f(x)= 1.133161680100144
# differential_evolution step 595: f(x)= 1.133161680100144
# differential_evolution step 596: f(x)= 1.133161680100144
# differential_evolution step 597: f(x)= 1.132935539833329
# differential_evolution step 598: f(x)= 1.132935539833329
# differential_evolution step 599: f(x)= 1.132935539833329
# differential_evolution step 600: f(x)= 1.132935539833329
# differential_evolution step 601: f(x)= 1.132935539833329
# differential_evolution step 602: f(x)= 1.132935539833329
# differential_evolution step 603: f(x)= 1.132935539833329
# differential_evolution step 604: f(x)= 1.132935539833329
# differential_evolution step 605: f(x)= 1.132935539833329
# differential_evolution step 606: f(x)= 1.132935539833329
# differential_evolution step 607: f(x)= 1.132935539833329
# differential_evolution step 608: f(x)= 1.132935539833329
# differential_evolution step 609: f(x)= 1.132935539833329
# differential_evolution step 610: f(x)= 1.132935539833329
# differential_evolution step 611: f(x)= 1.132935539833329
# differential_evolution step 612: f(x)= 1.132935539833329
# differential_evolution step 613: f(x)= 1.132935539833329
# differential_evolution step 614: f(x)= 1.132935539833329
# differential_evolution step 615: f(x)= 1.132935539833329
# differential_evolution step 616: f(x)= 1.132935539833329
# differential_evolution step 617: f(x)= 1.132935539833329
# differential_evolution step 618: f(x)= 1.132935539833329
# differential_evolution step 619: f(x)= 1.132935539833329
# differential_evolution step 620: f(x)= 1.132935539833329
# differential_evolution step 621: f(x)= 1.132935539833329
# differential_evolution step 622: f(x)= 1.132935539833329
# differential_evolution step 623: f(x)= 1.132935539833329
# differential_evolution step 624: f(x)= 1.132935539833329
# differential_evolution step 625: f(x)= 1.132935539833329
# differential_evolution step 626: f(x)= 1.132935539833329
# differential_evolution step 627: f(x)= 1.132935539833329
# differential_evolution step 628: f(x)= 1.132935539833329
# differential_evolution step 629: f(x)= 1.132935539833329
# differential_evolution step 630: f(x)= 1.132935539833329
# differential_evolution step 631: f(x)= 1.132935539833329
# differential_evolution step 632: f(x)= 1.132935539833329
# differential_evolution step 633: f(x)= 1.132935539833329
# differential_evolution step 634: f(x)= 1.132935539833329
# differential_evolution step 635: f(x)= 1.132935539833329
# differential_evolution step 636: f(x)= 1.132935539833329
# differential_evolution step 637: f(x)= 1.132935539833329
# differential_evolution step 638: f(x)= 1.102243929442195
# differential_evolution step 639: f(x)= 1.102243929442195
# differential_evolution step 640: f(x)= 1.102243929442195
# differential_evolution step 641: f(x)= 1.102243929442195
# differential_evolution step 642: f(x)= 1.102243929442195
# differential_evolution step 643: f(x)= 1.102243929442195
# differential_evolution step 644: f(x)= 1.102243929442195
# differential_evolution step 645: f(x)= 1.102243929442195
# differential_evolution step 646: f(x)= 1.102243929442195
# differential_evolution step 647: f(x)= 1.102243929442195
# differential_evolution step 648: f(x)= 1.102243929442195
# differential_evolution step 649: f(x)= 1.102243929442195
# differential_evolution step 650: f(x)= 1.102243929442195
# differential_evolution step 651: f(x)= 1.102243929442195
# differential_evolution step 652: f(x)= 1.102243929442195
# differential_evolution step 653: f(x)= 1.102243929442195
# differential_evolution step 654: f(x)= 1.102243929442195
# differential_evolution step 655: f(x)= 1.102243929442195
# differential_evolution step 656: f(x)= 1.102243929442195
# differential_evolution step 657: f(x)= 1.102243929442195
# differential_evolution step 658: f(x)= 1.102243929442195
# differential_evolution step 659: f(x)= 1.102243929442195
# differential_evolution step 660: f(x)= 1.102243929442195
# differential_evolution step 661: f(x)= 1.102243929442195
# differential_evolution step 662: f(x)= 1.102243929442195
# differential_evolution step 663: f(x)= 1.102243929442195
# differential_evolution step 664: f(x)= 1.102243929442195
# differential_evolution step 665: f(x)= 1.102243929442195
# differential_evolution step 666: f(x)= 1.102243929442195
# differential_evolution step 667: f(x)= 1.102243929442195
# differential_evolution step 668: f(x)= 1.102243929442195
# differential_evolution step 669: f(x)= 1.0859469454623019
# differential_evolution step 670: f(x)= 1.0859469454623019
# differential_evolution step 671: f(x)= 1.0859469454623019
# differential_evolution step 672: f(x)= 1.0859469454623019
# differential_evolution step 673: f(x)= 1.0859469454623019
# differential_evolution step 674: f(x)= 1.0859469454623019
# differential_evolution step 675: f(x)= 1.0859469454623019
# differential_evolution step 676: f(x)= 1.0859469454623019
# differential_evolution step 677: f(x)= 1.0859469454623019
# differential_evolution step 678: f(x)= 1.0859469454623019
# differential_evolution step 679: f(x)= 1.0859469454623019
# differential_evolution step 680: f(x)= 1.0859469454623019
# differential_evolution step 681: f(x)= 1.0859469454623019
# differential_evolution step 682: f(x)= 1.0859469454623019
# differential_evolution step 683: f(x)= 1.0859469454623019
# differential_evolution step 684: f(x)= 1.0859469454623019
# differential_evolution step 685: f(x)= 1.0859469454623019
# differential_evolution step 686: f(x)= 1.0859469454623019
# differential_evolution step 687: f(x)= 1.0859469454623019
# differential_evolution step 688: f(x)= 1.0859469454623019
# differential_evolution step 689: f(x)= 1.0859469454623019
# differential_evolution step 690: f(x)= 1.0859469454623019
# differential_evolution step 691: f(x)= 1.0859469454623019
# differential_evolution step 692: f(x)= 1.0859469454623019
# differential_evolution step 693: f(x)= 1.0859469454623019
# differential_evolution step 694: f(x)= 1.0810631243180628
# differential_evolution step 695: f(x)= 1.0810631243180628
# differential_evolution step 696: f(x)= 1.0810631243180628
# differential_evolution step 697: f(x)= 1.0810631243180628
# differential_evolution step 698: f(x)= 1.0810631243180628
# differential_evolution step 699: f(x)= 1.0810631243180628
# differential_evolution step 700: f(x)= 1.0810631243180628
# differential_evolution step 701: f(x)= 1.0810631243180628
# differential_evolution step 702: f(x)= 1.0810631243180628
# differential_evolution step 703: f(x)= 1.0810631243180628
# differential_evolution step 704: f(x)= 1.0810631243180628
# differential_evolution step 705: f(x)= 1.0810631243180628
# differential_evolution step 706: f(x)= 1.0810631243180628
# differential_evolution step 707: f(x)= 1.0810631243180628
# differential_evolution step 708: f(x)= 1.0810631243180628
# differential_evolution step 709: f(x)= 1.0810631243180628
# differential_evolution step 710: f(x)= 1.0810631243180628
# differential_evolution step 711: f(x)= 1.0810631243180628
# differential_evolution step 712: f(x)= 1.0810631243180628
# differential_evolution step 713: f(x)= 1.0810631243180628
# differential_evolution step 714: f(x)= 1.0810631243180628
# differential_evolution step 715: f(x)= 1.0810631243180628
# differential_evolution step 716: f(x)= 1.0810631243180628
# differential_evolution step 717: f(x)= 1.0810631243180628
# differential_evolution step 718: f(x)= 1.0810631243180628
# differential_evolution step 719: f(x)= 1.0810631243180628
# differential_evolution step 720: f(x)= 1.0810631243180628
# differential_evolution step 721: f(x)= 1.0810631243180628
# differential_evolution step 722: f(x)= 1.0810631243180628
# differential_evolution step 723: f(x)= 1.0810631243180628
# differential_evolution step 724: f(x)= 1.0810631243180628
# differential_evolution step 725: f(x)= 1.0810631243180628
# differential_evolution step 726: f(x)= 1.0810631243180628
# differential_evolution step 727: f(x)= 1.0810631243180628
# differential_evolution step 728: f(x)= 1.0810631243180628
# differential_evolution step 729: f(x)= 1.0810631243180628
# differential_evolution step 730: f(x)= 1.0810631243180628
# differential_evolution step 731: f(x)= 1.0810631243180628
# differential_evolution step 732: f(x)= 1.0810631243180628
# differential_evolution step 733: f(x)= 1.0810631243180628
# differential_evolution step 734: f(x)= 1.0810631243180628
# differential_evolution step 735: f(x)= 1.0810631243180628
# differential_evolution step 736: f(x)= 1.0810631243180628
# differential_evolution step 737: f(x)= 1.0810631243180628
# differential_evolution step 738: f(x)= 1.0810631243180628
# differential_evolution step 739: f(x)= 1.0810631243180628
# differential_evolution step 740: f(x)= 1.0810631243180628
# differential_evolution step 741: f(x)= 1.0810631243180628
# differential_evolution step 742: f(x)= 1.0810631243180628
# differential_evolution step 743: f(x)= 1.0810631243180628
# differential_evolution step 744: f(x)= 1.0810631243180628
# differential_evolution step 745: f(x)= 1.0786550442836775
# differential_evolution step 746: f(x)= 1.0786550442836775
# differential_evolution step 747: f(x)= 1.0786550442836775
# differential_evolution step 748: f(x)= 1.0786550442836775
# differential_evolution step 749: f(x)= 1.0786550442836775
# differential_evolution step 750: f(x)= 1.0786550442836775
# differential_evolution step 751: f(x)= 1.0786550442836775
# differential_evolution step 752: f(x)= 1.0786550442836775
# differential_evolution step 753: f(x)= 1.0786550442836775
# differential_evolution step 754: f(x)= 1.0786550442836775
# differential_evolution step 755: f(x)= 1.0786550442836775
# differential_evolution step 756: f(x)= 1.0786550442836775
# differential_evolution step 757: f(x)= 1.0786550442836775
# differential_evolution step 758: f(x)= 1.0786550442836775
# differential_evolution step 759: f(x)= 1.0786550442836775
# differential_evolution step 760: f(x)= 1.0786550442836775
# differential_evolution step 761: f(x)= 1.0786550442836775
# differential_evolution step 762: f(x)= 1.0786550442836775
# differential_evolution step 763: f(x)= 1.0786550442836775
# differential_evolution step 764: f(x)= 1.0786550442836775
# differential_evolution step 765: f(x)= 1.0786550442836775
# differential_evolution step 766: f(x)= 1.0786550442836775
# differential_evolution step 767: f(x)= 1.0786550442836775
# differential_evolution step 768: f(x)= 1.0786550442836775
# differential_evolution step 769: f(x)= 1.0786550442836775
# differential_evolution step 770: f(x)= 1.0732670269312923
# differential_evolution step 771: f(x)= 1.067365731560927
# differential_evolution step 772: f(x)= 1.067365731560927
# differential_evolution step 773: f(x)= 1.067365731560927
# differential_evolution step 774: f(x)= 1.067365731560927
# differential_evolution step 775: f(x)= 1.067365731560927
# differential_evolution step 776: f(x)= 1.067365731560927
# differential_evolution step 777: f(x)= 1.067365731560927
# differential_evolution step 778: f(x)= 1.067365731560927
# differential_evolution step 779: f(x)= 1.067365731560927
# differential_evolution step 780: f(x)= 1.067365731560927
# differential_evolution step 781: f(x)= 1.067365731560927
# differential_evolution step 782: f(x)= 1.067365731560927
# differential_evolution step 783: f(x)= 1.067365731560927
# differential_evolution step 784: f(x)= 1.067365731560927
# differential_evolution step 785: f(x)= 1.067365731560927
# differential_evolution step 786: f(x)= 1.067365731560927
# differential_evolution step 787: f(x)= 1.0660908865358507
# differential_evolution step 788: f(x)= 1.0660908865358507
# differential_evolution step 789: f(x)= 1.0660908865358507
# differential_evolution step 790: f(x)= 1.0660908865358507
# differential_evolution step 791: f(x)= 1.0660908865358507
# differential_evolution step 792: f(x)= 1.0660908865358507
# differential_evolution step 793: f(x)= 1.0660908865358507
# differential_evolution step 794: f(x)= 1.0660908865358507
# differential_evolution step 795: f(x)= 1.0660908865358507
# differential_evolution step 796: f(x)= 1.0660908865358507
# differential_evolution step 797: f(x)= 1.0660908865358507
# differential_evolution step 798: f(x)= 1.0660908865358507
# differential_evolution step 799: f(x)= 1.0660908865358507
# differential_evolution step 800: f(x)= 1.0660908865358507
# differential_evolution step 801: f(x)= 1.0660908865358507
# differential_evolution step 802: f(x)= 1.0660908865358507
# differential_evolution step 803: f(x)= 1.0660908865358507
# differential_evolution step 804: f(x)= 1.0660908865358507
# differential_evolution step 805: f(x)= 1.0660908865358507
# differential_evolution step 806: f(x)= 1.0660908865358507
# differential_evolution step 807: f(x)= 1.0660908865358507
# differential_evolution step 808: f(x)= 1.0660908865358507
# differential_evolution step 809: f(x)= 1.0660908865358507
# differential_evolution step 810: f(x)= 1.0660908865358507
# differential_evolution step 811: f(x)= 1.0660908865358507
# differential_evolution step 812: f(x)= 1.0660908865358507
# differential_evolution step 813: f(x)= 1.0660908865358507
# differential_evolution step 814: f(x)= 1.0660908865358507
# differential_evolution step 815: f(x)= 1.0660908865358507
# differential_evolution step 816: f(x)= 1.0660908865358507
# differential_evolution step 817: f(x)= 1.0660908865358507
# differential_evolution step 818: f(x)= 1.0660908865358507
# differential_evolution step 819: f(x)= 1.0660908865358507
# differential_evolution step 820: f(x)= 1.0660908865358507
# differential_evolution step 821: f(x)= 1.0660908865358507
# differential_evolution step 822: f(x)= 1.0660908865358507
# differential_evolution step 823: f(x)= 1.0660908865358507
# differential_evolution step 824: f(x)= 1.0660908865358507
# differential_evolution step 825: f(x)= 1.0660908865358507
# differential_evolution step 826: f(x)= 1.0660908865358507
# differential_evolution step 827: f(x)= 1.0660908865358507
# differential_evolution step 828: f(x)= 1.0660908865358507
# differential_evolution step 829: f(x)= 1.0660908865358507
# differential_evolution step 830: f(x)= 1.0660908865358507
# differential_evolution step 831: f(x)= 1.0660908865358507
# differential_evolution step 832: f(x)= 1.0660908865358507
# differential_evolution step 833: f(x)= 1.0594926845482469
# differential_evolution step 834: f(x)= 1.0594926845482469
# differential_evolution step 835: f(x)= 1.0594926845482469
# differential_evolution step 836: f(x)= 1.0594926845482469
# differential_evolution step 837: f(x)= 1.0594926845482469
# differential_evolution step 838: f(x)= 1.0594926845482469
# differential_evolution step 839: f(x)= 1.0563076470989725
# differential_evolution step 840: f(x)= 1.0563076470989725
# differential_evolution step 841: f(x)= 1.0563076470989725
# differential_evolution step 842: f(x)= 1.0563076470989725
# differential_evolution step 843: f(x)= 1.0563076470989725
# differential_evolution step 844: f(x)= 1.0563076470989725
# differential_evolution step 845: f(x)= 1.0563076470989725
# differential_evolution step 846: f(x)= 1.0563076470989725
# differential_evolution step 847: f(x)= 1.0563076470989725
# differential_evolution step 848: f(x)= 1.0563076470989725
# differential_evolution step 849: f(x)= 1.0563076470989725
# differential_evolution step 850: f(x)= 1.0563076470989725
# differential_evolution step 851: f(x)= 1.047762626656197
# differential_evolution step 852: f(x)= 1.047762626656197
# differential_evolution step 853: f(x)= 1.047762626656197
# differential_evolution step 854: f(x)= 1.047762626656197
# differential_evolution step 855: f(x)= 1.047762626656197
# differential_evolution step 856: f(x)= 1.047762626656197
# differential_evolution step 857: f(x)= 1.047762626656197
# differential_evolution step 858: f(x)= 1.047762626656197
# differential_evolution step 859: f(x)= 1.047762626656197
# differential_evolution step 860: f(x)= 1.047762626656197
# differential_evolution step 861: f(x)= 1.047762626656197
# differential_evolution step 862: f(x)= 1.047762626656197
# differential_evolution step 863: f(x)= 1.047762626656197
# differential_evolution step 864: f(x)= 1.047762626656197
# differential_evolution step 865: f(x)= 1.047762626656197
# differential_evolution step 866: f(x)= 1.047762626656197
# differential_evolution step 867: f(x)= 1.047762626656197
# differential_evolution step 868: f(x)= 1.047762626656197
# differential_evolution step 869: f(x)= 1.047762626656197
# differential_evolution step 870: f(x)= 1.047762626656197
# differential_evolution step 871: f(x)= 1.047762626656197
# differential_evolution step 872: f(x)= 1.047762626656197
# differential_evolution step 873: f(x)= 1.047762626656197
# differential_evolution step 874: f(x)= 1.047762626656197
# differential_evolution step 875: f(x)= 1.047762626656197
# differential_evolution step 876: f(x)= 1.047762626656197
# differential_evolution step 877: f(x)= 1.047762626656197
# differential_evolution step 878: f(x)= 1.047762626656197
# differential_evolution step 879: f(x)= 1.047762626656197
# differential_evolution step 880: f(x)= 1.047762626656197
# differential_evolution step 881: f(x)= 1.047762626656197
# differential_evolution step 882: f(x)= 1.047762626656197
# differential_evolution step 883: f(x)= 1.047762626656197
# differential_evolution step 884: f(x)= 1.047762626656197
# differential_evolution step 885: f(x)= 1.047762626656197
# differential_evolution step 886: f(x)= 1.047762626656197
# differential_evolution step 887: f(x)= 1.047762626656197
# differential_evolution step 888: f(x)= 1.047762626656197
# differential_evolution step 889: f(x)= 1.047762626656197
# differential_evolution step 890: f(x)= 1.047762626656197
# differential_evolution step 891: f(x)= 1.047762626656197
# differential_evolution step 892: f(x)= 1.047762626656197
# differential_evolution step 893: f(x)= 1.047762626656197
# differential_evolution step 894: f(x)= 1.047762626656197
# differential_evolution step 895: f(x)= 1.047762626656197
# differential_evolution step 896: f(x)= 1.047762626656197
# differential_evolution step 897: f(x)= 1.047762626656197
# differential_evolution step 898: f(x)= 1.047762626656197
# differential_evolution step 899: f(x)= 1.047762626656197
# differential_evolution step 900: f(x)= 1.047762626656197
# differential_evolution step 901: f(x)= 1.047762626656197
# differential_evolution step 902: f(x)= 1.047762626656197
# differential_evolution step 903: f(x)= 1.047762626656197
# differential_evolution step 904: f(x)= 1.047762626656197
# differential_evolution step 905: f(x)= 1.047762626656197
# differential_evolution step 906: f(x)= 1.047762626656197
# differential_evolution step 907: f(x)= 1.047762626656197
# differential_evolution step 908: f(x)= 1.047762626656197
# differential_evolution step 909: f(x)= 1.047762626656197
# differential_evolution step 910: f(x)= 1.047762626656197
# differential_evolution step 911: f(x)= 1.047762626656197
# differential_evolution step 912: f(x)= 1.047762626656197
# differential_evolution step 913: f(x)= 1.0455677488214392
# differential_evolution step 914: f(x)= 1.0455677488214392
# differential_evolution step 915: f(x)= 1.0455677488214392
# differential_evolution step 916: f(x)= 1.0455677488214392
# differential_evolution step 917: f(x)= 1.0405873780548616
# differential_evolution step 918: f(x)= 1.0405873780548616
# differential_evolution step 919: f(x)= 1.0405873780548616
# differential_evolution step 920: f(x)= 1.0405873780548616
# differential_evolution step 921: f(x)= 1.0405873780548616
# differential_evolution step 922: f(x)= 1.0359254477116577
# differential_evolution step 923: f(x)= 1.0359254477116577
# differential_evolution step 924: f(x)= 1.0359254477116577
# differential_evolution step 925: f(x)= 1.0359254477116577
# differential_evolution step 926: f(x)= 1.0359254477116577
# differential_evolution step 927: f(x)= 1.0359254477116577
# differential_evolution step 928: f(x)= 1.0359254477116577
# differential_evolution step 929: f(x)= 1.0359254477116577
# differential_evolution step 930: f(x)= 1.0359254477116577
# differential_evolution step 931: f(x)= 1.0359254477116577
# differential_evolution step 932: f(x)= 1.0359254477116577
# differential_evolution step 933: f(x)= 1.0336572076124644
# differential_evolution step 934: f(x)= 1.0336572076124644
# differential_evolution step 935: f(x)= 1.0336572076124644
# differential_evolution step 936: f(x)= 1.0336572076124644
# differential_evolution step 937: f(x)= 1.0336572076124644
# differential_evolution step 938: f(x)= 1.0336572076124644
# differential_evolution step 939: f(x)= 1.0336572076124644
# differential_evolution step 940: f(x)= 1.0336572076124644
# differential_evolution step 941: f(x)= 1.0336572076124644
# differential_evolution step 942: f(x)= 1.0330274790582894
# differential_evolution step 943: f(x)= 1.0330274790582894
# differential_evolution step 944: f(x)= 1.0330274790582894
# differential_evolution step 945: f(x)= 1.0330274790582894
# differential_evolution step 946: f(x)= 1.0330274790582894
# differential_evolution step 947: f(x)= 1.0330274790582894
# differential_evolution step 948: f(x)= 1.0330274790582894
# differential_evolution step 949: f(x)= 1.0330274790582894
# differential_evolution step 950: f(x)= 1.0330274790582894
# differential_evolution step 951: f(x)= 1.0330274790582894
# differential_evolution step 952: f(x)= 1.0244745505115853
# differential_evolution step 953: f(x)= 1.0244745505115853
# differential_evolution step 954: f(x)= 1.010627788328622
# differential_evolution step 955: f(x)= 1.010627788328622
# differential_evolution step 956: f(x)= 1.010627788328622
# differential_evolution step 957: f(x)= 1.010627788328622
# differential_evolution step 958: f(x)= 1.010627788328622
# differential_evolution step 959: f(x)= 1.010627788328622
# differential_evolution step 960: f(x)= 1.010627788328622
# differential_evolution step 961: f(x)= 1.010627788328622
# differential_evolution step 962: f(x)= 1.010627788328622
# differential_evolution step 963: f(x)= 1.010627788328622
# differential_evolution step 964: f(x)= 1.010627788328622
# differential_evolution step 965: f(x)= 1.010627788328622
# differential_evolution step 966: f(x)= 1.010627788328622
# differential_evolution step 967: f(x)= 1.010627788328622
# differential_evolution step 968: f(x)= 1.010627788328622
# differential_evolution step 969: f(x)= 1.010627788328622
# differential_evolution step 970: f(x)= 1.010627788328622
# differential_evolution step 971: f(x)= 1.010627788328622
# differential_evolution step 972: f(x)= 1.010627788328622
# differential_evolution step 973: f(x)= 1.010627788328622
# differential_evolution step 974: f(x)= 1.010627788328622
# differential_evolution step 975: f(x)= 1.010627788328622
# differential_evolution step 976: f(x)= 1.010627788328622
# differential_evolution step 977: f(x)= 1.010627788328622
# differential_evolution step 978: f(x)= 1.010627788328622
# differential_evolution step 979: f(x)= 1.010627788328622
# differential_evolution step 980: f(x)= 1.010627788328622
# differential_evolution step 981: f(x)= 1.010627788328622
# differential_evolution step 982: f(x)= 1.010627788328622
# differential_evolution step 983: f(x)= 1.010627788328622
# differential_evolution step 984: f(x)= 1.010627788328622
# differential_evolution step 985: f(x)= 1.010627788328622
# differential_evolution step 986: f(x)= 1.010627788328622
# differential_evolution step 987: f(x)= 1.010627788328622
# differential_evolution step 988: f(x)= 1.010627788328622
# differential_evolution step 989: f(x)= 1.010627788328622
# differential_evolution step 990: f(x)= 1.010627788328622
# differential_evolution step 991: f(x)= 1.010627788328622
# differential_evolution step 992: f(x)= 1.010627788328622
# differential_evolution step 993: f(x)= 1.010627788328622
# differential_evolution step 994: f(x)= 1.010627788328622
# differential_evolution step 995: f(x)= 1.010627788328622
# differential_evolution step 996: f(x)= 1.010627788328622
# differential_evolution step 997: f(x)= 1.010627788328622
# differential_evolution step 998: f(x)= 1.010627788328622
# differential_evolution step 999: f(x)= 1.010627788328622
# differential_evolution step 1000: f(x)= 1.010627788328622
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [7.81164727e-01 9.73392705e+00 1.96881952e+00 3.61576272e+01
#  5.46122928e-01 5.34653493e+00 1.18542970e+00 4.20723801e+01
#  1.87143927e-01 7.42848884e+00 2.95352214e+00 5.95633908e+01
#  1.08968356e-01 1.87556075e+01 1.23909177e+00 7.17190708e+01
#  5.52295900e-03 4.37056948e+01 3.68746776e-01 1.95738159e+01
#  7.61214602e-02 1.50836589e+00 2.23757313e+00 5.38718558e+01]
# Chi quadro minimo: 0.9968567791855533

# %%
# Plots:
params_curve_6, covariance_6 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params6, 
                                         sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[5], red_chi[5] = save_params(params_curve_6, covariance_6, radial_profile_HA, radial_profile_error_HA, x_axes, 6, line_name="Six", output_prefix="fit")

aic[5] = AIC(x_axes, radial_profile_HA, chi_quadr[5], params_curve_6)
bic[5] = BIC(x_axes, radial_profile_HA, chi_quadr[5], params_curve_6)
print(aic[5], chi_quadr[5], bic[5], len(best_params6))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_6)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[16:20]),  linestyle='--', label='Sérsic 5')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[20:24]),  linestyle='--', label='Sérsic 6')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)

ax[1].plot(x_axes, radial_profile_HA - y_fit)

plt.savefig('AIC_6')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16324\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16324\1779277057.py:12: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16324\111436280.py:9: RuntimeWarning: overflow encountered in multiply
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_16324\1557636815.py:2: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_curve_6, covariance_6 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params6,
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.9016, r_e=9.1546, n=1.8537, x_0=36.1687
# Sérsic 2: I_e=0.8061, r_e=3.6785, n=0.9166, x_0=42.1785
# Sérsic 3: I_e=0.1563, r_e=9.1906, n=3.0104, x_0=59.5634
# Sérsic 4: I_e=0.0731, r_e=24.4911, n=1.4897, x_0=71.8497
# Sérsic 5: I_e=0.0041, r_e=111.9109, n=-0.0136, x_0=69.3989
# Sérsic 6: I_e=0.1657, r_e=1.9186, n=0.9060, x_0=53.3781
# [inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf
#  inf inf inf inf inf inf]
# 6.879846839008756
# 70.87984683900876 6.879846839008756 117.40393130272295 24
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Plot AIC vs N 
n = [1, 2, 3, 4, 5, 6]

fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('AIC')
ax1.set_title('N vs AIC')
ax1.plot(n, aic, marker = 'o')
plt.savefig('AIC_vs_N')
np.savetxt('AIC', aic)
np.savetxt('Reduced_chi', red_chi)

#Plot AIC vs N 
n = [1, 2, 3, 4, 5, 6]

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('BIC')
ax2.set_title('N vs BIC')
ax2.plot(n, bic, marker = 'o')
plt.savefig('BIC_vs_N')
np.savetxt('BIC', aic)

fig3 = plt.figure(figsize=(8,6))
ax3 = fig3.gca()
ax3.grid(alpha=0.3, c = 'grey')
ax3.set_xlabel('N')
ax3.set_ylabel('Reduced $\chi$')
ax3.set_title('N vs Reduced $\chi$')
ax3.plot(n, red_chi, marker = 'o')
plt.savefig('Reduced_chi_vs_N')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('log(AIC)')
ax1.set_title('N vs AIC')
ax1.plot(n, np.log10(aic), marker = 'o')
plt.savefig('AIC_vs_N_log')

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('log(BIC)')
ax2.set_title('N vs BIC')
ax2.plot(n, np.log10(bic), marker = 'o')
plt.savefig('BIC_vs_N_log')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
