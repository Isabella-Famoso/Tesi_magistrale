# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_center_1.txt', unpack = True)
z = 0.01505
wv_rf = wv/(1+z)
flux_rf = flux*(1+z)
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4236.9735481  4238.43160435 4239.88966061 ... 6988.32569824 6989.78375449
#  6991.24181075] [0.66588813 0.28026127 0.21029064 ... 0.15301142 0.15747921 0.14060282] [0.05963103 0.05844244 0.05622137 ... 0.01349751 0.01346883 0.01316281]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314346257

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.11848677 2.1192158  2.11994483 ... 3.49416285 3.49489188 3.49562091]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3334, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3334, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -49       420
# chi2/DOF: 0.01938; DOF: 2076; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 19; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:      -271         1
# chi2/DOF: 0.01154; DOF: 2025; degree = 4; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 36; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-270.83614883,    0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = True #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6731_d1' '[SII]6731_d2' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
#n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
#n_balmer = len(gas_names) - n_forbidden
n_lines = len(gas_names)

# %%
n_lines
# Out:
# 10

# %%
#component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.
component = [0]*n_temps + [1]*n_lines
gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
#moments = [2, 2, 2]
#start = [results, start, start]
#gas_reddening = 0 if tie_balmer else None

moments = [2, 2]
start = [results, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       491      1000
#  comp.  1:      -301        27
# chi2/DOF: 1.019; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.77      0.56    -301    27
# Comp:  1                 Hbeta      24.77      0.43    -301    27
# Comp:  1                Halpha      79.63      0.49    -301    27
# Comp:  1          [SII]6731_d1     0.2552      0.56    -301    27
# Comp:  1          [SII]6731_d2      18.58      0.61    -301    27
# Comp:  1              HeII4687      0.000      0.32    -301    27
# Comp:  1               HeI5876      3.061      0.22    -301    27
# Comp:  1          [OIII]5007_d      43.48      0.53    -301    27
# Comp:  1            [OI]6300_d     0.8231      0.22    -301    27
# Comp:  1           [NII]6583_d      22.04      0.32    -301    27
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights
plt.figure(figsize = (8, 6))
plt.plot(wv_rf_rebin, pp.bestfit, label = 'bestfit')
plt.plot(wv_rf_rebin, pp.galaxy, label = 'dati')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  33.58; gas flux:     10 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  73.48; gas flux:     25 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  237.3; gas flux:    109 ergs/(cm^2 s)
# [SII]6731_d1 - Amplitude/Noise: 0.5293; gas flux:      0 ergs/(cm^2 s)
# [SII]6731_d2 - Amplitude/Noise:  33.23; gas flux:     26 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:   9.69; gas flux:      4 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  103.9; gas flux:     45 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.895; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  48.57; gas flux:     30 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       385       985
#  comp.  1:      -302        23
# chi2/DOF: 0.9929; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.86      0.55    -302    23
# Comp:  1                 Hbeta      25.70      0.42    -302    23
# Comp:  1                Halpha      79.06      0.49    -302    23
# Comp:  1          [SII]6731_d1     0.1611      0.55    -302    23
# Comp:  1          [SII]6731_d2      18.37      0.61    -302    23
# Comp:  1              HeII4687      0.000      0.32    -302    23
# Comp:  1               HeI5876      2.992      0.21    -302    23
# Comp:  1          [OIII]5007_d      42.66      0.53    -302    23
# Comp:  1            [OI]6300_d     0.9794      0.22    -302    23
# Comp:  1           [NII]6583_d      22.19      0.32    -302    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       146      1000
#  comp.  1:      -300        24
# chi2/DOF: 0.9973; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.14      0.55    -300    24
# Comp:  1                 Hbeta      25.12      0.42    -300    24
# Comp:  1                Halpha      78.26      0.49    -300    24
# Comp:  1          [SII]6731_d1     0.5581      0.56    -300    24
# Comp:  1          [SII]6731_d2      17.98      0.61    -300    24
# Comp:  1              HeII4687      0.000      0.32    -300    24
# Comp:  1               HeI5876      3.267      0.21    -300    24
# Comp:  1          [OIII]5007_d      43.85      0.53    -300    24
# Comp:  1            [OI]6300_d     0.6109      0.22    -300    24
# Comp:  1           [NII]6583_d      22.52      0.32    -300    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       495       668
#  comp.  1:      -300        22
# chi2/DOF: 0.9572; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.97      0.55    -300    22
# Comp:  1                 Hbeta      24.88      0.42    -300    22
# Comp:  1                Halpha      78.52      0.49    -300    22
# Comp:  1          [SII]6731_d1      0.000      0.55    -300    22
# Comp:  1          [SII]6731_d2      18.84      0.61    -300    22
# Comp:  1              HeII4687      0.000      0.32    -300    22
# Comp:  1               HeI5876      2.831      0.21    -300    22
# Comp:  1          [OIII]5007_d      38.05      0.53    -300    22
# Comp:  1            [OI]6300_d      1.134      0.22    -300    22
# Comp:  1           [NII]6583_d      22.39      0.32    -300    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       688       651
#  comp.  1:      -299        33
# chi2/DOF: 0.9815; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.15      0.56    -299    33
# Comp:  1                 Hbeta      25.16      0.43    -299    33
# Comp:  1                Halpha      81.45      0.49    -299    33
# Comp:  1          [SII]6731_d1     0.8868      0.57    -299    33
# Comp:  1          [SII]6731_d2      17.91      0.62    -299    33
# Comp:  1              HeII4687    0.08941      0.33    -299    33
# Comp:  1               HeI5876      3.037      0.22    -299    33
# Comp:  1          [OIII]5007_d      42.95      0.54    -299    33
# Comp:  1            [OI]6300_d      1.047      0.22    -299    33
# Comp:  1           [NII]6583_d      21.75      0.33    -299    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       429      1000
#  comp.  1:      -301        25
# chi2/DOF: 0.9940; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.097      0.55    -301    25
# Comp:  1                 Hbeta      25.99      0.42    -301    25
# Comp:  1                Halpha      79.65      0.49    -301    25
# Comp:  1          [SII]6731_d1      0.000      0.56    -301    25
# Comp:  1          [SII]6731_d2      18.91      0.61    -301    25
# Comp:  1              HeII4687      0.000      0.32    -301    25
# Comp:  1               HeI5876      3.186      0.21    -301    25
# Comp:  1          [OIII]5007_d      42.63      0.53    -301    25
# Comp:  1            [OI]6300_d      1.056      0.22    -301    25
# Comp:  1           [NII]6583_d      21.24      0.32    -301    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       423      1000
#  comp.  1:      -301        26
# chi2/DOF: 1.009; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.27      0.56    -301    26
# Comp:  1                 Hbeta      24.49      0.43    -301    26
# Comp:  1                Halpha      80.39      0.49    -301    26
# Comp:  1          [SII]6731_d1     0.8288      0.56    -301    26
# Comp:  1          [SII]6731_d2      17.82      0.61    -301    26
# Comp:  1              HeII4687      0.000      0.32    -301    26
# Comp:  1               HeI5876      3.282      0.22    -301    26
# Comp:  1          [OIII]5007_d      42.80      0.53    -301    26
# Comp:  1            [OI]6300_d     0.7266      0.22    -301    26
# Comp:  1           [NII]6583_d      22.88      0.32    -301    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       674      1000
#  comp.  1:      -299        30
# chi2/DOF: 0.9511; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.14      0.56    -299    30
# Comp:  1                 Hbeta      23.09      0.43    -299    30
# Comp:  1                Halpha      79.59      0.49    -299    30
# Comp:  1          [SII]6731_d1    0.04284      0.56    -299    30
# Comp:  1          [SII]6731_d2      18.87      0.62    -299    30
# Comp:  1              HeII4687      0.000      0.33    -299    30
# Comp:  1               HeI5876      2.922      0.22    -299    30
# Comp:  1          [OIII]5007_d      38.12      0.54    -299    30
# Comp:  1            [OI]6300_d     0.5664      0.22    -299    30
# Comp:  1           [NII]6583_d      22.18      0.33    -299    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       690       987
#  comp.  1:      -302        26
# chi2/DOF: 1.002; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.41      0.55    -302    26
# Comp:  1                 Hbeta      24.23      0.42    -302    26
# Comp:  1                Halpha      79.05      0.49    -302    26
# Comp:  1          [SII]6731_d1     0.1933      0.56    -302    26
# Comp:  1          [SII]6731_d2      18.61      0.61    -302    26
# Comp:  1              HeII4687    0.04656      0.32    -302    26
# Comp:  1               HeI5876      2.973      0.21    -302    26
# Comp:  1          [OIII]5007_d      42.56      0.53    -302    26
# Comp:  1            [OI]6300_d     0.8975      0.22    -302    26
# Comp:  1           [NII]6583_d      22.72      0.32    -302    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       466       774
#  comp.  1:      -301        29
# chi2/DOF: 0.9442; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      13.03      0.56    -301    29
# Comp:  1                 Hbeta      22.90      0.43    -301    29
# Comp:  1                Halpha      81.03      0.49    -301    29
# Comp:  1          [SII]6731_d1      0.000      0.56    -301    29
# Comp:  1          [SII]6731_d2      18.66      0.62    -301    29
# Comp:  1              HeII4687     0.1395      0.33    -301    29
# Comp:  1               HeI5876      3.135      0.22    -301    29
# Comp:  1          [OIII]5007_d      49.10      0.54    -301    29
# Comp:  1            [OI]6300_d     0.8780      0.22    -301    29
# Comp:  1           [NII]6583_d      22.79      0.33    -301    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       838       995
#  comp.  1:      -300        31
# chi2/DOF: 0.9961; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.18      0.56    -300    31
# Comp:  1                 Hbeta      24.56      0.43    -300    31
# Comp:  1                Halpha      79.87      0.49    -300    31
# Comp:  1          [SII]6731_d1      0.000      0.56    -300    31
# Comp:  1          [SII]6731_d2      19.48      0.62    -300    31
# Comp:  1              HeII4687      0.000      0.33    -300    31
# Comp:  1               HeI5876      2.864      0.22    -300    31
# Comp:  1          [OIII]5007_d      44.70      0.54    -300    31
# Comp:  1            [OI]6300_d     0.9684      0.22    -300    31
# Comp:  1           [NII]6583_d      22.86      0.33    -300    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       150       747
#  comp.  1:      -299        30
# chi2/DOF: 0.9698; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.59      0.56    -299    30
# Comp:  1                 Hbeta      25.39      0.43    -299    30
# Comp:  1                Halpha      80.28      0.49    -299    30
# Comp:  1          [SII]6731_d1     0.5089      0.56    -299    30
# Comp:  1          [SII]6731_d2      18.56      0.62    -299    30
# Comp:  1              HeII4687    0.09154      0.33    -299    30
# Comp:  1               HeI5876      3.097      0.22    -299    30
# Comp:  1          [OIII]5007_d      39.74      0.54    -299    30
# Comp:  1            [OI]6300_d      1.019      0.22    -299    30
# Comp:  1           [NII]6583_d      22.21      0.33    -299    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       175      1000
#  comp.  1:      -301        32
# chi2/DOF: 0.9810; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 17; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.14      0.56    -301    32
# Comp:  1                 Hbeta      28.05      0.43    -301    32
# Comp:  1                Halpha      79.68      0.49    -301    32
# Comp:  1          [SII]6731_d1      0.000      0.56    -301    32
# Comp:  1          [SII]6731_d2      19.24      0.62    -301    32
# Comp:  1              HeII4687     0.1403      0.33    -301    32
# Comp:  1               HeI5876      3.129      0.22    -301    32
# Comp:  1          [OIII]5007_d      44.72      0.54    -301    32
# Comp:  1            [OI]6300_d     0.8374      0.22    -301    32
# Comp:  1           [NII]6583_d      22.50      0.33    -301    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        52       995
#  comp.  1:      -300        30
# chi2/DOF: 1.003; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.79      0.56    -300    30
# Comp:  1                 Hbeta      25.54      0.43    -300    30
# Comp:  1                Halpha      80.43      0.49    -300    30
# Comp:  1          [SII]6731_d1     0.3294      0.56    -300    30
# Comp:  1          [SII]6731_d2      18.73      0.62    -300    30
# Comp:  1              HeII4687      0.000      0.33    -300    30
# Comp:  1               HeI5876      3.094      0.22    -300    30
# Comp:  1          [OIII]5007_d      43.83      0.54    -300    30
# Comp:  1            [OI]6300_d      1.093      0.22    -300    30
# Comp:  1           [NII]6583_d      22.32      0.33    -300    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       505      1000
#  comp.  1:      -299        29
# chi2/DOF: 0.9967; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.72      0.56    -299    29
# Comp:  1                 Hbeta      26.09      0.43    -299    29
# Comp:  1                Halpha      81.77      0.49    -299    29
# Comp:  1          [SII]6731_d1     0.6621      0.56    -299    29
# Comp:  1          [SII]6731_d2      17.92      0.62    -299    29
# Comp:  1              HeII4687    0.02307      0.33    -299    29
# Comp:  1               HeI5876      3.122      0.22    -299    29
# Comp:  1          [OIII]5007_d      43.58      0.54    -299    29
# Comp:  1            [OI]6300_d      1.090      0.22    -299    29
# Comp:  1           [NII]6583_d      22.35      0.33    -299    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       689       904
#  comp.  1:      -301        21
# chi2/DOF: 0.9512; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 17; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.721      0.55    -301    21
# Comp:  1                 Hbeta      22.68      0.42    -301    21
# Comp:  1                Halpha      78.43      0.49    -301    21
# Comp:  1          [SII]6731_d1     0.4139      0.55    -301    21
# Comp:  1          [SII]6731_d2      18.38      0.61    -301    21
# Comp:  1              HeII4687    0.09590      0.32    -301    21
# Comp:  1               HeI5876      2.988      0.21    -301    21
# Comp:  1          [OIII]5007_d      47.72      0.53    -301    21
# Comp:  1            [OI]6300_d     0.8204      0.22    -301    21
# Comp:  1           [NII]6583_d      21.62      0.32    -301    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       556      1000
#  comp.  1:      -300        25
# chi2/DOF: 0.9495; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      12.21      0.55    -300    25
# Comp:  1                 Hbeta      27.15      0.42    -300    25
# Comp:  1                Halpha      79.56      0.49    -300    25
# Comp:  1          [SII]6731_d1    0.05025      0.56    -300    25
# Comp:  1          [SII]6731_d2      19.28      0.61    -300    25
# Comp:  1              HeII4687    0.06359      0.32    -300    25
# Comp:  1               HeI5876      3.003      0.21    -300    25
# Comp:  1          [OIII]5007_d      38.08      0.53    -300    25
# Comp:  1            [OI]6300_d     0.7536      0.22    -300    25
# Comp:  1           [NII]6583_d      22.48      0.32    -300    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       310       749
#  comp.  1:      -302        25
# chi2/DOF: 0.9845; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.056      0.55    -302    25
# Comp:  1                 Hbeta      26.54      0.42    -302    25
# Comp:  1                Halpha      79.03      0.49    -302    25
# Comp:  1          [SII]6731_d1     0.4959      0.56    -302    25
# Comp:  1          [SII]6731_d2      18.24      0.61    -302    25
# Comp:  1              HeII4687    0.02786      0.32    -302    25
# Comp:  1               HeI5876      3.227      0.21    -302    25
# Comp:  1          [OIII]5007_d      43.48      0.53    -302    25
# Comp:  1            [OI]6300_d     0.9552      0.22    -302    25
# Comp:  1           [NII]6583_d      22.07      0.32    -302    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       511      1000
#  comp.  1:      -301        23
# chi2/DOF: 0.9531; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.43      0.55    -301    23
# Comp:  1                 Hbeta      24.74      0.42    -301    23
# Comp:  1                Halpha      77.39      0.49    -301    23
# Comp:  1          [SII]6731_d1     0.2875      0.55    -301    23
# Comp:  1          [SII]6731_d2      18.27      0.61    -301    23
# Comp:  1              HeII4687    0.02844      0.32    -301    23
# Comp:  1               HeI5876      3.017      0.21    -301    23
# Comp:  1          [OIII]5007_d      37.76      0.53    -301    23
# Comp:  1            [OI]6300_d     0.7440      0.22    -301    23
# Comp:  1           [NII]6583_d      21.93      0.32    -301    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       417      1000
#  comp.  1:      -302        22
# chi2/DOF: 0.9544; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.653      0.55    -302    22
# Comp:  1                 Hbeta      24.39      0.42    -302    22
# Comp:  1                Halpha      78.62      0.49    -302    22
# Comp:  1          [SII]6731_d1     0.5945      0.55    -302    22
# Comp:  1          [SII]6731_d2      17.92      0.61    -302    22
# Comp:  1              HeII4687      0.000      0.32    -302    22
# Comp:  1               HeI5876      3.004      0.21    -302    22
# Comp:  1          [OIII]5007_d      48.10      0.53    -302    22
# Comp:  1            [OI]6300_d      1.033      0.22    -302    22
# Comp:  1           [NII]6583_d      22.73      0.32    -302    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       474       928
#  comp.  1:      -300        32
# chi2/DOF: 0.9856; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 17; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.48      0.56    -300    32
# Comp:  1                 Hbeta      23.12      0.43    -300    32
# Comp:  1                Halpha      80.19      0.49    -300    32
# Comp:  1          [SII]6731_d1     0.4363      0.57    -300    32
# Comp:  1          [SII]6731_d2      18.76      0.62    -300    32
# Comp:  1              HeII4687     0.1730      0.33    -300    32
# Comp:  1               HeI5876      3.072      0.22    -300    32
# Comp:  1          [OIII]5007_d      43.80      0.54    -300    32
# Comp:  1            [OI]6300_d     0.5850      0.22    -300    32
# Comp:  1           [NII]6583_d      22.12      0.33    -300    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       285      1000
#  comp.  1:      -299        29
# chi2/DOF: 0.9848; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.395      0.56    -299    29
# Comp:  1                 Hbeta      22.95      0.43    -299    29
# Comp:  1                Halpha      80.65      0.49    -299    29
# Comp:  1          [SII]6731_d1     0.2844      0.56    -299    29
# Comp:  1          [SII]6731_d2      18.76      0.62    -299    29
# Comp:  1              HeII4687    0.07870      0.33    -299    29
# Comp:  1               HeI5876      3.210      0.22    -299    29
# Comp:  1          [OIII]5007_d      43.23      0.54    -299    29
# Comp:  1            [OI]6300_d     0.6260      0.22    -299    29
# Comp:  1           [NII]6583_d      21.90      0.33    -299    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       488      1000
#  comp.  1:      -302        24
# chi2/DOF: 0.9995; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.31      0.55    -302    24
# Comp:  1                 Hbeta      24.81      0.42    -302    24
# Comp:  1                Halpha      80.45      0.49    -302    24
# Comp:  1          [SII]6731_d1     0.9071      0.56    -302    24
# Comp:  1          [SII]6731_d2      17.64      0.61    -302    24
# Comp:  1              HeII4687      0.000      0.32    -302    24
# Comp:  1               HeI5876      2.960      0.21    -302    24
# Comp:  1          [OIII]5007_d      42.99      0.53    -302    24
# Comp:  1            [OI]6300_d      1.114      0.22    -302    24
# Comp:  1           [NII]6583_d      21.64      0.32    -302    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       636      1000
#  comp.  1:      -299        29
# chi2/DOF: 1.002; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.69      0.56    -299    29
# Comp:  1                 Hbeta      24.25      0.43    -299    29
# Comp:  1                Halpha      79.34      0.49    -299    29
# Comp:  1          [SII]6731_d1     0.2326      0.56    -299    29
# Comp:  1          [SII]6731_d2      18.50      0.62    -299    29
# Comp:  1              HeII4687      0.000      0.33    -299    29
# Comp:  1               HeI5876      3.087      0.22    -299    29
# Comp:  1          [OIII]5007_d      43.44      0.54    -299    29
# Comp:  1            [OI]6300_d     0.9185      0.22    -299    29
# Comp:  1           [NII]6583_d      22.90      0.33    -299    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       517      1000
#  comp.  1:      -303        25
# chi2/DOF: 0.9871; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.876      0.55    -303    25
# Comp:  1                 Hbeta      24.43      0.42    -303    25
# Comp:  1                Halpha      77.48      0.49    -303    25
# Comp:  1          [SII]6731_d1    0.09905      0.56    -303    25
# Comp:  1          [SII]6731_d2      18.65      0.61    -303    25
# Comp:  1              HeII4687      0.000      0.32    -303    25
# Comp:  1               HeI5876      3.066      0.21    -303    25
# Comp:  1          [OIII]5007_d      42.53      0.53    -303    25
# Comp:  1            [OI]6300_d     0.8078      0.22    -303    25
# Comp:  1           [NII]6583_d      22.52      0.32    -303    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       520      1000
#  comp.  1:      -300        28
# chi2/DOF: 0.9675; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.750      0.56    -300    28
# Comp:  1                 Hbeta      23.21      0.43    -300    28
# Comp:  1                Halpha      80.06      0.49    -300    28
# Comp:  1          [SII]6731_d1      0.000      0.56    -300    28
# Comp:  1          [SII]6731_d2      19.04      0.61    -300    28
# Comp:  1              HeII4687      0.000      0.33    -300    28
# Comp:  1               HeI5876      2.930      0.22    -300    28
# Comp:  1          [OIII]5007_d      48.64      0.54    -300    28
# Comp:  1            [OI]6300_d     0.9298      0.22    -300    28
# Comp:  1           [NII]6583_d      22.54      0.32    -300    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       612      1000
#  comp.  1:      -300        27
# chi2/DOF: 0.9532; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.90      0.56    -300    27
# Comp:  1                 Hbeta      22.92      0.43    -300    27
# Comp:  1                Halpha      79.90      0.49    -300    27
# Comp:  1          [SII]6731_d1     0.2259      0.56    -300    27
# Comp:  1          [SII]6731_d2      18.37      0.61    -300    27
# Comp:  1              HeII4687    0.06990      0.32    -300    27
# Comp:  1               HeI5876      3.058      0.22    -300    27
# Comp:  1          [OIII]5007_d      49.32      0.53    -300    27
# Comp:  1            [OI]6300_d     0.8065      0.22    -300    27
# Comp:  1           [NII]6583_d      22.22      0.32    -300    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       377      1000
#  comp.  1:      -300        25
# chi2/DOF: 0.9659; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.83      0.55    -300    25
# Comp:  1                 Hbeta      23.27      0.42    -300    25
# Comp:  1                Halpha      80.46      0.49    -300    25
# Comp:  1          [SII]6731_d1     0.1643      0.56    -300    25
# Comp:  1          [SII]6731_d2      18.37      0.61    -300    25
# Comp:  1              HeII4687      0.000      0.32    -300    25
# Comp:  1               HeI5876      3.075      0.21    -300    25
# Comp:  1          [OIII]5007_d      38.34      0.53    -300    25
# Comp:  1            [OI]6300_d      1.163      0.22    -300    25
# Comp:  1           [NII]6583_d      22.49      0.32    -300    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       542      1000
#  comp.  1:      -301        22
# chi2/DOF: 0.9979; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.66      0.55    -301    22
# Comp:  1                 Hbeta      25.21      0.42    -301    22
# Comp:  1                Halpha      78.90      0.49    -301    22
# Comp:  1          [SII]6731_d1    0.02548      0.55    -301    22
# Comp:  1          [SII]6731_d2      18.82      0.61    -301    22
# Comp:  1              HeII4687      0.000      0.32    -301    22
# Comp:  1               HeI5876      2.939      0.21    -301    22
# Comp:  1          [OIII]5007_d      44.12      0.53    -301    22
# Comp:  1            [OI]6300_d     0.6490      0.22    -301    22
# Comp:  1           [NII]6583_d      21.30      0.32    -301    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       442       956
#  comp.  1:      -299        29
# chi2/DOF: 0.9984; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.86      0.56    -299    29
# Comp:  1                 Hbeta      26.69      0.43    -299    29
# Comp:  1                Halpha      78.74      0.49    -299    29
# Comp:  1          [SII]6731_d1     0.4451      0.56    -299    29
# Comp:  1          [SII]6731_d2      18.60      0.61    -299    29
# Comp:  1              HeII4687      0.000      0.33    -299    29
# Comp:  1               HeI5876      3.127      0.22    -299    29
# Comp:  1          [OIII]5007_d      43.93      0.54    -299    29
# Comp:  1            [OI]6300_d     0.9106      0.22    -299    29
# Comp:  1           [NII]6583_d      22.06      0.32    -299    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       396      1000
#  comp.  1:      -302        24
# chi2/DOF: 1.000; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.458      0.55    -302    24
# Comp:  1                 Hbeta      24.72      0.42    -302    24
# Comp:  1                Halpha      79.03      0.49    -302    24
# Comp:  1          [SII]6731_d1     0.5125      0.56    -302    24
# Comp:  1          [SII]6731_d2      18.23      0.61    -302    24
# Comp:  1              HeII4687      0.000      0.32    -302    24
# Comp:  1               HeI5876      3.128      0.21    -302    24
# Comp:  1          [OIII]5007_d      43.69      0.53    -302    24
# Comp:  1            [OI]6300_d     0.9599      0.22    -302    24
# Comp:  1           [NII]6583_d      21.34      0.32    -302    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       504       928
#  comp.  1:      -303        23
# chi2/DOF: 0.9412; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.21      0.55    -303    23
# Comp:  1                 Hbeta      26.72      0.42    -303    23
# Comp:  1                Halpha      78.89      0.49    -303    23
# Comp:  1          [SII]6731_d1     0.3393      0.55    -303    23
# Comp:  1          [SII]6731_d2      18.48      0.61    -303    23
# Comp:  1              HeII4687     0.1311      0.32    -303    23
# Comp:  1               HeI5876      2.988      0.21    -303    23
# Comp:  1          [OIII]5007_d      48.11      0.53    -303    23
# Comp:  1            [OI]6300_d     0.5164      0.22    -303    23
# Comp:  1           [NII]6583_d      22.15      0.32    -303    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       681       740
#  comp.  1:      -301        28
# chi2/DOF: 0.9478; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.14      0.56    -301    28
# Comp:  1                 Hbeta      27.07      0.43    -301    28
# Comp:  1                Halpha      81.60      0.49    -301    28
# Comp:  1          [SII]6731_d1     0.1770      0.56    -301    28
# Comp:  1          [SII]6731_d2      18.58      0.61    -301    28
# Comp:  1              HeII4687      0.000      0.33    -301    28
# Comp:  1               HeI5876      3.177      0.22    -301    28
# Comp:  1          [OIII]5007_d      49.02      0.54    -301    28
# Comp:  1            [OI]6300_d      1.098      0.22    -301    28
# Comp:  1           [NII]6583_d      21.95      0.32    -301    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       457       989
#  comp.  1:      -300        27
# chi2/DOF: 0.9700; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.19      0.56    -300    27
# Comp:  1                 Hbeta      23.74      0.43    -300    27
# Comp:  1                Halpha      78.76      0.49    -300    27
# Comp:  1          [SII]6731_d1     0.3759      0.56    -300    27
# Comp:  1          [SII]6731_d2      18.29      0.61    -300    27
# Comp:  1              HeII4687      0.000      0.32    -300    27
# Comp:  1               HeI5876      3.039      0.22    -300    27
# Comp:  1          [OIII]5007_d      38.19      0.53    -300    27
# Comp:  1            [OI]6300_d      1.022      0.22    -300    27
# Comp:  1           [NII]6583_d      22.16      0.32    -300    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       504      1000
#  comp.  1:      -300        31
# chi2/DOF: 0.9835; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      12.40      0.56    -300    31
# Comp:  1                 Hbeta      27.34      0.43    -300    31
# Comp:  1                Halpha      80.60      0.49    -300    31
# Comp:  1          [SII]6731_d1    0.09712      0.56    -300    31
# Comp:  1          [SII]6731_d2      18.93      0.62    -300    31
# Comp:  1              HeII4687     0.1032      0.33    -300    31
# Comp:  1               HeI5876      2.865      0.22    -300    31
# Comp:  1          [OIII]5007_d      44.17      0.54    -300    31
# Comp:  1            [OI]6300_d     0.7647      0.22    -300    31
# Comp:  1           [NII]6583_d      22.70      0.33    -300    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       527      1000
#  comp.  1:      -302        23
# chi2/DOF: 0.9619; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.91      0.55    -302    23
# Comp:  1                 Hbeta      24.63      0.42    -302    23
# Comp:  1                Halpha      78.65      0.49    -302    23
# Comp:  1          [SII]6731_d1     0.7298      0.55    -302    23
# Comp:  1          [SII]6731_d2      17.80      0.61    -302    23
# Comp:  1              HeII4687    0.04835      0.32    -302    23
# Comp:  1               HeI5876      3.026      0.21    -302    23
# Comp:  1          [OIII]5007_d      48.28      0.53    -302    23
# Comp:  1            [OI]6300_d     0.7601      0.22    -302    23
# Comp:  1           [NII]6583_d      21.90      0.32    -302    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       399       999
#  comp.  1:      -303        27
# chi2/DOF: 0.9676; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.942      0.56    -303    27
# Comp:  1                 Hbeta      27.30      0.43    -303    27
# Comp:  1                Halpha      77.77      0.49    -303    27
# Comp:  1          [SII]6731_d1      0.000      0.56    -303    27
# Comp:  1          [SII]6731_d2      19.25      0.61    -303    27
# Comp:  1              HeII4687      0.000      0.32    -303    27
# Comp:  1               HeI5876      2.847      0.22    -303    27
# Comp:  1          [OIII]5007_d      43.35      0.53    -303    27
# Comp:  1            [OI]6300_d     0.9116      0.22    -303    27
# Comp:  1           [NII]6583_d      22.74      0.32    -303    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       271       929
#  comp.  1:      -301        25
# chi2/DOF: 1.002; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.189      0.55    -301    25
# Comp:  1                 Hbeta      23.17      0.42    -301    25
# Comp:  1                Halpha      80.29      0.49    -301    25
# Comp:  1          [SII]6731_d1     0.4628      0.56    -301    25
# Comp:  1          [SII]6731_d2      18.34      0.61    -301    25
# Comp:  1              HeII4687      0.000      0.32    -301    25
# Comp:  1               HeI5876      3.197      0.21    -301    25
# Comp:  1          [OIII]5007_d      43.39      0.53    -301    25
# Comp:  1            [OI]6300_d     0.7749      0.22    -301    25
# Comp:  1           [NII]6583_d      21.99      0.32    -301    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       551      1000
#  comp.  1:      -297        31
# chi2/DOF: 0.9250; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      12.43      0.56    -297    31
# Comp:  1                 Hbeta      23.06      0.43    -297    31
# Comp:  1                Halpha      81.18      0.49    -297    31
# Comp:  1          [SII]6731_d1     0.5060      0.56    -297    31
# Comp:  1          [SII]6731_d2      18.53      0.62    -297    31
# Comp:  1              HeII4687      0.000      0.33    -297    31
# Comp:  1               HeI5876      3.156      0.22    -297    31
# Comp:  1          [OIII]5007_d      38.86      0.54    -297    31
# Comp:  1            [OI]6300_d     0.6745      0.22    -297    31
# Comp:  1           [NII]6583_d      21.52      0.33    -297    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       563       993
#  comp.  1:      -301        24
# chi2/DOF: 0.9687; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.40      0.55    -301    24
# Comp:  1                 Hbeta      25.15      0.42    -301    24
# Comp:  1                Halpha      79.36      0.49    -301    24
# Comp:  1          [SII]6731_d1     0.2078      0.55    -301    24
# Comp:  1          [SII]6731_d2      18.41      0.61    -301    24
# Comp:  1              HeII4687     0.1736      0.32    -301    24
# Comp:  1               HeI5876      3.021      0.21    -301    24
# Comp:  1          [OIII]5007_d      38.12      0.53    -301    24
# Comp:  1            [OI]6300_d     0.7099      0.22    -301    24
# Comp:  1           [NII]6583_d      21.94      0.32    -301    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       167      1000
#  comp.  1:      -300        29
# chi2/DOF: 0.9561; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.611      0.56    -300    29
# Comp:  1                 Hbeta      22.42      0.43    -300    29
# Comp:  1                Halpha      81.29      0.49    -300    29
# Comp:  1          [SII]6731_d1     0.5863      0.56    -300    29
# Comp:  1          [SII]6731_d2      17.90      0.62    -300    29
# Comp:  1              HeII4687      0.000      0.33    -300    29
# Comp:  1               HeI5876      3.030      0.22    -300    29
# Comp:  1          [OIII]5007_d      48.18      0.54    -300    29
# Comp:  1            [OI]6300_d      1.075      0.22    -300    29
# Comp:  1           [NII]6583_d      22.15      0.33    -300    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       513      1000
#  comp.  1:      -303        24
# chi2/DOF: 0.9413; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.37      0.55    -303    24
# ...
# Comp:  1          [SII]6731_d2      17.90      0.61    -301    23
# Comp:  1              HeII4687    0.05405      0.32    -301    23
# Comp:  1               HeI5876      2.926      0.21    -301    23
# Comp:  1          [OIII]5007_d      38.37      0.53    -301    23
# Comp:  1            [OI]6300_d      1.041      0.22    -301    23
# Comp:  1           [NII]6583_d      22.14      0.32    -301    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       438       808
#  comp.  1:      -303        26
# chi2/DOF: 0.9360; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.72      0.55    -303    26
# Comp:  1                 Hbeta      27.29      0.42    -303    26
# Comp:  1                Halpha      78.48      0.49    -303    26
# Comp:  1          [SII]6731_d1     0.1102      0.56    -303    26
# Comp:  1          [SII]6731_d2      18.69      0.61    -303    26
# Comp:  1              HeII4687    0.02467      0.32    -303    26
# Comp:  1               HeI5876      3.188      0.21    -303    26
# Comp:  1          [OIII]5007_d      48.87      0.53    -303    26
# Comp:  1            [OI]6300_d     0.9507      0.22    -303    26
# Comp:  1           [NII]6583_d      21.87      0.32    -303    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       504       789
#  comp.  1:      -299        32
# chi2/DOF: 0.9569; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.34      0.56    -299    32
# Comp:  1                 Hbeta      24.36      0.43    -299    32
# Comp:  1                Halpha      80.58      0.49    -299    32
# Comp:  1          [SII]6731_d1     0.9955      0.56    -299    32
# Comp:  1          [SII]6731_d2      17.75      0.62    -299    32
# Comp:  1              HeII4687      0.000      0.33    -299    32
# Comp:  1               HeI5876      3.200      0.22    -299    32
# Comp:  1          [OIII]5007_d      38.97      0.54    -299    32
# Comp:  1            [OI]6300_d     0.6739      0.22    -299    32
# Comp:  1           [NII]6583_d      22.28      0.33    -299    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       953       962
#  comp.  1:      -301        23
# chi2/DOF: 0.9892; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      12.11      0.55    -301    23
# Comp:  1                 Hbeta      26.38      0.42    -301    23
# Comp:  1                Halpha      78.84      0.49    -301    23
# Comp:  1          [SII]6731_d1      0.000      0.55    -301    23
# Comp:  1          [SII]6731_d2      19.05      0.61    -301    23
# Comp:  1              HeII4687    0.05542      0.32    -301    23
# Comp:  1               HeI5876      2.893      0.21    -301    23
# Comp:  1          [OIII]5007_d      43.51      0.53    -301    23
# Comp:  1            [OI]6300_d     0.7253      0.22    -301    23
# Comp:  1           [NII]6583_d      22.53      0.32    -301    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       394      1000
#  comp.  1:      -301        30
# chi2/DOF: 0.9951; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.79      0.56    -301    30
# Comp:  1                 Hbeta      26.40      0.43    -301    30
# Comp:  1                Halpha      81.17      0.49    -301    30
# Comp:  1          [SII]6731_d1     0.9850      0.56    -301    30
# Comp:  1          [SII]6731_d2      17.70      0.62    -301    30
# Comp:  1              HeII4687      0.000      0.33    -301    30
# Comp:  1               HeI5876      3.234      0.22    -301    30
# Comp:  1          [OIII]5007_d      43.54      0.54    -301    30
# Comp:  1            [OI]6300_d     0.7987      0.22    -301    30
# Comp:  1           [NII]6583_d      22.56      0.33    -301    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       586      1000
#  comp.  1:      -299        30
# chi2/DOF: 0.9908; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.78      0.56    -299    30
# Comp:  1                 Hbeta      26.07      0.43    -299    30
# Comp:  1                Halpha      81.90      0.49    -299    30
# Comp:  1          [SII]6731_d1     0.5743      0.56    -299    30
# Comp:  1          [SII]6731_d2      18.00      0.62    -299    30
# Comp:  1              HeII4687      0.000      0.33    -299    30
# Comp:  1               HeI5876      2.987      0.22    -299    30
# Comp:  1          [OIII]5007_d      43.32      0.54    -299    30
# Comp:  1            [OI]6300_d     0.9556      0.22    -299    30
# Comp:  1           [NII]6583_d      22.14      0.33    -299    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       363      1000
#  comp.  1:      -301        31
# chi2/DOF: 0.9580; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.53      0.56    -301    31
# Comp:  1                 Hbeta      24.11      0.43    -301    31
# Comp:  1                Halpha      80.64      0.49    -301    31
# Comp:  1          [SII]6731_d1     0.1668      0.56    -301    31
# Comp:  1          [SII]6731_d2      18.73      0.62    -301    31
# Comp:  1              HeII4687      0.000      0.33    -301    31
# Comp:  1               HeI5876      3.083      0.22    -301    31
# Comp:  1          [OIII]5007_d      49.37      0.54    -301    31
# Comp:  1            [OI]6300_d      1.045      0.22    -301    31
# Comp:  1           [NII]6583_d      22.33      0.33    -301    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       465       836
#  comp.  1:      -302        22
# chi2/DOF: 0.9619; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.81      0.55    -302    22
# Comp:  1                 Hbeta      24.46      0.42    -302    22
# Comp:  1                Halpha      78.86      0.49    -302    22
# Comp:  1          [SII]6731_d1     0.2904      0.55    -302    22
# Comp:  1          [SII]6731_d2      18.29      0.61    -302    22
# Comp:  1              HeII4687    0.07469      0.32    -302    22
# Comp:  1               HeI5876      3.229      0.21    -302    22
# Comp:  1          [OIII]5007_d      47.83      0.53    -302    22
# Comp:  1            [OI]6300_d     0.6987      0.22    -302    22
# Comp:  1           [NII]6583_d      21.21      0.32    -302    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       571      1000
#  comp.  1:      -301        27
# chi2/DOF: 0.9996; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.61      0.56    -301    27
# Comp:  1                 Hbeta      26.81      0.43    -301    27
# Comp:  1                Halpha      78.66      0.49    -301    27
# Comp:  1          [SII]6731_d1      0.000      0.56    -301    27
# Comp:  1          [SII]6731_d2      19.30      0.61    -301    27
# Comp:  1              HeII4687      0.000      0.32    -301    27
# Comp:  1               HeI5876      2.979      0.22    -301    27
# Comp:  1          [OIII]5007_d      43.49      0.53    -301    27
# Comp:  1            [OI]6300_d      1.004      0.22    -301    27
# Comp:  1           [NII]6583_d      21.44      0.32    -301    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       979      1000
#  comp.  1:      -299        28
# chi2/DOF: 0.9493; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.821      0.56    -299    28
# Comp:  1                 Hbeta      25.17      0.43    -299    28
# Comp:  1                Halpha      80.75      0.49    -299    28
# Comp:  1          [SII]6731_d1     0.1712      0.56    -299    28
# Comp:  1          [SII]6731_d2      18.60      0.61    -299    28
# Comp:  1              HeII4687      0.000      0.33    -299    28
# Comp:  1               HeI5876      3.278      0.22    -299    28
# Comp:  1          [OIII]5007_d      38.02      0.54    -299    28
# Comp:  1            [OI]6300_d     0.9432      0.22    -299    28
# Comp:  1           [NII]6583_d      22.53      0.32    -299    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       237       927
#  comp.  1:      -299        30
# chi2/DOF: 0.9483; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.878      0.56    -299    30
# Comp:  1                 Hbeta      27.29      0.43    -299    30
# Comp:  1                Halpha      80.54      0.49    -299    30
# Comp:  1          [SII]6731_d1     0.3465      0.56    -299    30
# Comp:  1          [SII]6731_d2      18.66      0.62    -299    30
# Comp:  1              HeII4687      0.000      0.33    -299    30
# Comp:  1               HeI5876      3.048      0.22    -299    30
# Comp:  1          [OIII]5007_d      38.80      0.54    -299    30
# Comp:  1            [OI]6300_d     0.7813      0.22    -299    30
# Comp:  1           [NII]6583_d      21.23      0.33    -299    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       290       492
#  comp.  1:      -303        24
# chi2/DOF: 0.9448; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.85      0.55    -303    24
# Comp:  1                 Hbeta      24.21      0.42    -303    24
# Comp:  1                Halpha      79.05      0.49    -303    24
# Comp:  1          [SII]6731_d1     0.3847      0.56    -303    24
# Comp:  1          [SII]6731_d2      18.47      0.61    -303    24
# Comp:  1              HeII4687    0.07262      0.32    -303    24
# Comp:  1               HeI5876      3.208      0.21    -303    24
# Comp:  1          [OIII]5007_d      48.95      0.53    -303    24
# Comp:  1            [OI]6300_d     0.8327      0.22    -303    24
# Comp:  1           [NII]6583_d      21.99      0.32    -303    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       310      1000
#  comp.  1:      -300        30
# chi2/DOF: 0.9678; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.92      0.56    -300    30
# Comp:  1                 Hbeta      27.08      0.43    -300    30
# Comp:  1                Halpha      79.13      0.49    -300    30
# Comp:  1          [SII]6731_d1     0.3711      0.56    -300    30
# Comp:  1          [SII]6731_d2      18.55      0.62    -300    30
# Comp:  1              HeII4687    0.07651      0.33    -300    30
# Comp:  1               HeI5876      3.119      0.22    -300    30
# Comp:  1          [OIII]5007_d      39.24      0.54    -300    30
# Comp:  1            [OI]6300_d     0.9034      0.22    -300    30
# Comp:  1           [NII]6583_d      22.00      0.33    -300    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       335      1000
#  comp.  1:      -301        29
# chi2/DOF: 0.9624; DOF: 2398; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 12; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.36      0.56    -301    29
# Comp:  1                 Hbeta      22.95      0.43    -301    29
# Comp:  1                Halpha      80.40      0.49    -301    29
# Comp:  1          [SII]6731_d1     0.9388      0.56    -301    29
# Comp:  1          [SII]6731_d2      17.66      0.62    -301    29
# Comp:  1              HeII4687      0.000      0.33    -301    29
# Comp:  1               HeI5876      3.013      0.22    -301    29
# Comp:  1          [OIII]5007_d      48.77      0.54    -301    29
# Comp:  1            [OI]6300_d     0.5640      0.22    -301    29
# Comp:  1           [NII]6583_d      21.78      0.33    -301    29
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.97048808, 1.59169587, 1.57316625, 0.38271677, 0.67994043,
#        0.0535483 , 0.16082698, 3.78916308, 0.20238513, 0.60633729])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([  9.75035264,  25.11769564, 109.00579465,   0.35754357,
#         26.08399   ,   0.        ,   3.75143075,  45.40400759,
#          1.08168646,  30.26081326])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum_center_1_gas_ppxf_prova.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_center_1_prova", output_dir="./")

d3 = {'Component': [0, 1], 'Vel': [pp.sol[0][0], pp.sol[1][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum_center_1_kin_prova.csv", index= False)

# %%
read = pd.read_csv("Spectrum_center_1_gas_ppxf_prova.csv")
print(read)
read2 = pd.read_csv("Spectrum_center_1_prova_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0        Hgamma   1.846346    0.183774
# 1         Hbeta   4.756337    0.301407
# 2        Halpha  20.641553    0.297898
# 3  [SII]6731_d1   0.067705    0.072472
# 4  [SII]6731_d2   4.939316    0.128755
# 5      HeII4687   0.000000    0.010140
# 6       HeI5876   0.710378    0.030455
# 7  [OIII]5007_d   8.597793    0.717523
# 8    [OI]6300_d   0.204830    0.038324
# 9   [NII]6583_d   5.730247    0.114817
#             Name       Flux  Error_flux
# 0         Hgamma   1.846346    0.183774
# 1          Hbeta   4.756337    0.301407
# 2         Halpha  20.641553    0.297898
# 3   [SII]6731_d1   0.067705    0.072472
# 4   [SII]6731_d2   4.939316    0.128755
# 5       HeII4687   0.000000    0.010140
# 6        HeI5876   0.710378    0.030455
# 7     [OIII]4959   2.149448    0.717523
# 8     [OIII]5007   6.448345    0.717523
# 9       [OI]6300   0.153623    0.038324
# 10      [OI]6364   0.051208    0.038324
# 11     [NII]6548   1.432562    0.114817
# 12     [NII]6583   4.297686    0.114817

# %%
np.median(flux_rf_rebin)

# %%
 norm
