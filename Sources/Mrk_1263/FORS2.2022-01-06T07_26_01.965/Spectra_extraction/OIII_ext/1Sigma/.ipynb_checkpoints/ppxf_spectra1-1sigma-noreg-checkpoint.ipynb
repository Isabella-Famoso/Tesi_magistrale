# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_1s_1.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_1263/FORS2.2022-01-06T07_26_01.965/Spectra_extraction/redshift.txt") 
z = red[0][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_1s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.21714496 2.21788182 2.21861868 ... 3.53170494 3.5324418  3.53317866]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3136, 150)

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3136, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3136, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -161        51
# chi2/DOF: 0.01511; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:      -120        32
# chi2/DOF: 0.005482; DOF: 1884; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# [1.10911    1.16426921 1.24476299 ... 0.85095759 1.23119025 1.23367223]
# [1.36967089 1.38260333 1.3978395  ... 0.59750725 0.59439135 0.59365925]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-120.04790443,   31.90173612])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -95        39
#  comp.  1:         9        27
#  comp.  2:         6        43
# chi2/DOF: 15.81; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 38; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      176.0      0.26       9    27
# Comp:  1                Halpha      318.8      0.26       9    27
# Comp:  2             [SII]6716      18.41      0.28       6    43
# Comp:  2             [SII]6731      13.87      0.28       6    43
# Comp:  2              HeII4687     0.4300      0.28       6    43
# Comp:  2               HeI5876      16.46      0.28       6    43
# Comp:  2          [OIII]5007_d      1253.      0.35       6    43
# Comp:  2            [OI]6300_d      5.279      0.35       6    43
# Comp:  2           [NII]6583_d      14.24      0.35       6    43
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  706.2; gas flux:    178 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:   1310; gas flux:    436 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  68.58; gas flux:     26 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  50.75; gas flux:     19 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.583; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  60.14; gas flux:     20 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   3356; gas flux:   1308 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  14.28; gas flux:      7 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  39.75; gas flux:     20 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        12         1
#  comp.  1:         8        21
#  comp.  2:         7        44
# chi2/DOF: 13.85; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      164.6      0.26       8    21
# Comp:  1                Halpha      314.2      0.26       8    21
# Comp:  2             [SII]6716      17.41      0.28       7    44
# Comp:  2             [SII]6731      13.89      0.28       7    44
# Comp:  2              HeII4687     0.5010      0.28       7    44
# Comp:  2               HeI5876      15.34      0.28       7    44
# Comp:  2          [OIII]5007_d      1256.      0.35       7    44
# Comp:  2            [OI]6300_d      5.843      0.35       7    44
# Comp:  2           [NII]6583_d      14.16      0.35       7    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       118         1
#  comp.  1:        10        29
#  comp.  2:         8        41
# chi2/DOF: 12.68; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      173.4      0.27      10    29
# Comp:  1                Halpha      322.0      0.27      10    29
# Comp:  2             [SII]6716      20.48      0.28       8    41
# Comp:  2             [SII]6731      13.62      0.28       8    41
# Comp:  2              HeII4687     0.4571      0.28       8    41
# Comp:  2               HeI5876      15.33      0.28       8    41
# Comp:  2          [OIII]5007_d      1260.      0.35       8    41
# Comp:  2            [OI]6300_d      4.533      0.35       8    41
# Comp:  2           [NII]6583_d      14.46      0.35       8    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96         1
#  comp.  1:        10        31
#  comp.  2:         6        41
# chi2/DOF: 12.41; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      169.2      0.27      10    31
# Comp:  1                Halpha      319.9      0.27      10    31
# Comp:  2             [SII]6716      17.47      0.28       6    41
# Comp:  2             [SII]6731      14.80      0.28       6    41
# Comp:  2              HeII4687      0.000      0.28       6    41
# Comp:  2               HeI5876      16.86      0.28       6    41
# Comp:  2          [OIII]5007_d      1260.      0.35       6    41
# Comp:  2            [OI]6300_d      4.401      0.35       6    41
# Comp:  2           [NII]6583_d      13.42      0.35       6    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3         1
#  comp.  1:         9        33
#  comp.  2:         5        43
# chi2/DOF: 14.36; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      177.3      0.27       9    33
# Comp:  1                Halpha      326.5      0.27       9    33
# Comp:  2             [SII]6716      16.59      0.28       5    43
# Comp:  2             [SII]6731      14.00      0.28       5    43
# Comp:  2              HeII4687     0.2304      0.28       5    43
# Comp:  2               HeI5876      16.39      0.28       5    43
# Comp:  2          [OIII]5007_d      1246.      0.35       5    43
# Comp:  2            [OI]6300_d      5.871      0.35       5    43
# Comp:  2           [NII]6583_d      14.04      0.35       5    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       110         1
#  comp.  1:         9        29
#  comp.  2:         8        42
# chi2/DOF: 13.22; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 45; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      182.3      0.27       9    29
# Comp:  1                Halpha      319.4      0.27       9    29
# Comp:  2             [SII]6716      20.79      0.28       8    42
# Comp:  2             [SII]6731      13.39      0.28       8    42
# Comp:  2              HeII4687     0.3459      0.28       8    42
# Comp:  2               HeI5876      16.97      0.28       8    42
# Comp:  2          [OIII]5007_d      1252.      0.35       8    42
# Comp:  2            [OI]6300_d      5.193      0.35       8    42
# Comp:  2           [NII]6583_d      13.90      0.35       8    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -126       100
#  comp.  1:         9        25
#  comp.  2:         6        42
# chi2/DOF: 13.19; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      171.4      0.26       9    25
# Comp:  1                Halpha      316.7      0.26       9    25
# Comp:  2             [SII]6716      17.61      0.28       6    42
# Comp:  2             [SII]6731      13.12      0.28       6    42
# Comp:  2              HeII4687     0.5064      0.28       6    42
# Comp:  2               HeI5876      14.77      0.28       6    42
# Comp:  2          [OIII]5007_d      1223.      0.35       6    42
# Comp:  2            [OI]6300_d      5.403      0.35       6    42
# Comp:  2           [NII]6583_d      13.61      0.35       6    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       159         1
#  comp.  1:         9        15
#  comp.  2:         5        45
# chi2/DOF: 13.40; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 91; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      166.4      0.26       9    15
# Comp:  1                Halpha      311.2      0.26       9    15
# Comp:  2             [SII]6716      21.12      0.28       5    45
# Comp:  2             [SII]6731      14.02      0.28       5    45
# Comp:  2              HeII4687     0.5754      0.28       5    45
# Comp:  2               HeI5876      16.55      0.28       5    45
# Comp:  2          [OIII]5007_d      1261.      0.35       5    45
# Comp:  2            [OI]6300_d      5.172      0.35       5    45
# Comp:  2           [NII]6583_d      14.45      0.35       5    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -117         1
#  comp.  1:         7        13
#  comp.  2:         7        45
# chi2/DOF: 12.76; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      175.2      0.26       7    13
# Comp:  1                Halpha      312.7      0.26       7    13
# Comp:  2             [SII]6716      21.00      0.28       7    45
# Comp:  2             [SII]6731      13.11      0.28       7    45
# Comp:  2              HeII4687     0.4937      0.28       7    45
# Comp:  2               HeI5876      17.12      0.28       7    45
# Comp:  2          [OIII]5007_d      1248.      0.35       7    45
# Comp:  2            [OI]6300_d      4.530      0.35       7    45
# Comp:  2           [NII]6583_d      14.56      0.35       7    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       116         1
#  comp.  1:        11        30
#  comp.  2:         6        41
# chi2/DOF: 14.17; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 60; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      180.8      0.27      11    30
# Comp:  1                Halpha      325.4      0.27      11    30
# Comp:  2             [SII]6716      20.71      0.28       6    41
# Comp:  2             [SII]6731      12.78      0.28       6    41
# Comp:  2              HeII4687    0.09653      0.28       6    41
# Comp:  2               HeI5876      18.06      0.28       6    41
# Comp:  2          [OIII]5007_d      1253.      0.35       6    41
# Comp:  2            [OI]6300_d      5.205      0.35       6    41
# Comp:  2           [NII]6583_d      14.44      0.35       6    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41         1
#  comp.  1:         9        21
#  comp.  2:         6        39
# chi2/DOF: 11.49; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      182.6      0.26       9    21
# Comp:  1                Halpha      306.3      0.26       9    21
# Comp:  2             [SII]6716      17.55      0.27       6    39
# Comp:  2             [SII]6731      14.18      0.27       6    39
# Comp:  2              HeII4687     0.8312      0.27       6    39
# Comp:  2               HeI5876      17.80      0.27       6    39
# Comp:  2          [OIII]5007_d      1248.      0.35       6    39
# Comp:  2            [OI]6300_d      4.524      0.35       6    39
# Comp:  2           [NII]6583_d      14.94      0.35       6    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        92         1
#  comp.  1:         9        27
#  comp.  2:         8        41
# chi2/DOF: 12.35; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      182.3      0.26       9    27
# Comp:  1                Halpha      322.2      0.26       9    27
# Comp:  2             [SII]6716      20.67      0.28       8    41
# Comp:  2             [SII]6731      12.48      0.28       8    41
# Comp:  2              HeII4687     0.5022      0.28       8    41
# Comp:  2               HeI5876      17.78      0.28       8    41
# Comp:  2          [OIII]5007_d      1266.      0.35       8    41
# Comp:  2            [OI]6300_d      5.029      0.35       8    41
# Comp:  2           [NII]6583_d      15.16      0.35       8    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:        13        37
#  comp.  2:         7        46
# chi2/DOF: 8.372; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      181.0      0.27      13    37
# Comp:  1                Halpha      332.3      0.27      13    37
# Comp:  2             [SII]6716      19.66      0.28       7    46
# Comp:  2             [SII]6731      12.87      0.28       7    46
# Comp:  2              HeII4687    0.09617      0.28       7    46
# Comp:  2               HeI5876      18.51      0.28       7    46
# Comp:  2          [OIII]5007_d      1293.      0.35       7    46
# Comp:  2            [OI]6300_d      5.277      0.35       7    46
# Comp:  2           [NII]6583_d      14.20      0.35       7    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        49         1
#  comp.  1:         7        18
#  comp.  2:         7        42
# chi2/DOF: 13.16; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      168.9      0.26       7    18
# Comp:  1                Halpha      308.8      0.26       7    18
# Comp:  2             [SII]6716      19.11      0.28       7    42
# Comp:  2             [SII]6731      14.98      0.28       7    42
# Comp:  2              HeII4687     0.1814      0.28       7    42
# Comp:  2               HeI5876      17.07      0.28       7    42
# Comp:  2          [OIII]5007_d      1248.      0.35       7    42
# Comp:  2            [OI]6300_d      4.495      0.35       7    42
# Comp:  2           [NII]6583_d      14.58      0.35       7    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       134         1
#  comp.  1:        11        30
#  comp.  2:         5        42
# chi2/DOF: 12.45; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      169.8      0.27      11    30
# Comp:  1                Halpha      328.4      0.27      11    30
# Comp:  2             [SII]6716      19.22      0.28       5    42
# Comp:  2             [SII]6731      13.37      0.28       5    42
# Comp:  2              HeII4687     0.3564      0.28       5    42
# Comp:  2               HeI5876      16.35      0.28       5    42
# Comp:  2          [OIII]5007_d      1234.      0.35       5    42
# Comp:  2            [OI]6300_d      5.234      0.35       5    42
# Comp:  2           [NII]6583_d      14.22      0.35       5    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -158         7
#  comp.  1:         8        27
#  comp.  2:         4        47
# chi2/DOF: 11.53; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      186.1      0.26       8    27
# Comp:  1                Halpha      314.7      0.26       8    27
# Comp:  2             [SII]6716      16.97      0.28       4    47
# Comp:  2             [SII]6731      12.94      0.28       4    47
# Comp:  2              HeII4687     0.2292      0.28       4    47
# Comp:  2               HeI5876      16.04      0.28       4    47
# Comp:  2          [OIII]5007_d      1270.      0.36       4    47
# Comp:  2            [OI]6300_d      5.143      0.36       4    47
# Comp:  2           [NII]6583_d      15.46      0.36       4    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -173         1
#  comp.  1:         8        23
#  comp.  2:         5        46
# chi2/DOF: 13.15; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      181.0      0.26       8    23
# Comp:  1                Halpha      310.7      0.26       8    23
# Comp:  2             [SII]6716      17.90      0.28       5    46
# Comp:  2             [SII]6731      13.74      0.28       5    46
# Comp:  2              HeII4687     0.1476      0.28       5    46
# Comp:  2               HeI5876      17.69      0.28       5    46
# Comp:  2          [OIII]5007_d      1274.      0.35       5    46
# Comp:  2            [OI]6300_d      5.149      0.35       5    46
# Comp:  2           [NII]6583_d      14.34      0.35       5    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -223        34
#  comp.  1:        11        25
#  comp.  2:         8        41
# chi2/DOF: 13.32; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      175.5      0.26      11    25
# Comp:  1                Halpha      317.0      0.26      11    25
# Comp:  2             [SII]6716      18.06      0.28       8    41
# Comp:  2             [SII]6731      13.46      0.28       8    41
# Comp:  2              HeII4687     0.2623      0.28       8    41
# Comp:  2               HeI5876      14.71      0.28       8    41
# Comp:  2          [OIII]5007_d      1245.      0.35       8    41
# Comp:  2            [OI]6300_d      6.118      0.35       8    41
# Comp:  2           [NII]6583_d      14.29      0.35       8    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:        12        35
#  comp.  2:         5        42
# chi2/DOF: 10.26; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      193.9      0.27      12    35
# Comp:  1                Halpha      333.0      0.27      12    35
# Comp:  2             [SII]6716      18.22      0.28       5    42
# Comp:  2             [SII]6731      12.64      0.28       5    42
# Comp:  2              HeII4687     0.1701      0.28       5    42
# Comp:  2               HeI5876      17.85      0.28       5    42
# Comp:  2          [OIII]5007_d      1223.      0.35       5    42
# Comp:  2            [OI]6300_d      6.049      0.35       5    42
# Comp:  2           [NII]6583_d      13.99      0.35       5    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95        39
#  comp.  1:         9        23
#  comp.  2:         6        45
# chi2/DOF: 14.21; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      183.3      0.26       9    23
# Comp:  1                Halpha      308.5      0.26       9    23
# Comp:  2             [SII]6716      18.26      0.28       6    45
# Comp:  2             [SII]6731      15.12      0.28       6    45
# Comp:  2              HeII4687     0.1428      0.28       6    45
# Comp:  2               HeI5876      17.67      0.28       6    45
# Comp:  2          [OIII]5007_d      1264.      0.35       6    45
# Comp:  2            [OI]6300_d      5.535      0.35       6    45
# Comp:  2           [NII]6583_d      14.69      0.35       6    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:        13        34
#  comp.  2:         7        45
# chi2/DOF: 11.41; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      181.8      0.27      13    34
# Comp:  1                Halpha      331.9      0.27      13    34
# Comp:  2             [SII]6716      17.59      0.28       7    45
# Comp:  2             [SII]6731      13.96      0.28       7    45
# Comp:  2              HeII4687     0.2861      0.28       7    45
# Comp:  2               HeI5876      17.22      0.28       7    45
# Comp:  2          [OIII]5007_d      1243.      0.35       7    45
# Comp:  2            [OI]6300_d      5.448      0.35       7    45
# Comp:  2           [NII]6583_d      15.32      0.35       7    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -138         1
#  comp.  1:        12        36
#  comp.  2:         8        45
# chi2/DOF: 11.29; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      193.0      0.27      12    36
# Comp:  1                Halpha      336.9      0.27      12    36
# Comp:  2             [SII]6716      17.61      0.28       8    45
# Comp:  2             [SII]6731      13.21      0.28       8    45
# Comp:  2              HeII4687     0.1013      0.28       8    45
# Comp:  2               HeI5876      16.00      0.28       8    45
# Comp:  2          [OIII]5007_d      1259.      0.35       8    45
# Comp:  2            [OI]6300_d      6.118      0.35       8    45
# Comp:  2           [NII]6583_d      13.74      0.35       8    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -194         1
#  comp.  1:         9        26
#  comp.  2:         6        39
# chi2/DOF: 10.99; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      175.9      0.26       9    26
# Comp:  1                Halpha      313.5      0.26       9    26
# Comp:  2             [SII]6716      17.27      0.27       6    39
# Comp:  2             [SII]6731      12.82      0.27       6    39
# Comp:  2              HeII4687     0.4418      0.27       6    39
# Comp:  2               HeI5876      16.65      0.27       6    39
# Comp:  2          [OIII]5007_d      1211.      0.35       6    39
# Comp:  2            [OI]6300_d      4.365      0.35       6    39
# Comp:  2           [NII]6583_d      13.50      0.35       6    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        49         1
#  comp.  1:         8        18
#  comp.  2:         6        45
# chi2/DOF: 12.93; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      165.7      0.26       8    18
# Comp:  1                Halpha      315.2      0.26       8    18
# Comp:  2             [SII]6716      15.80      0.28       6    45
# Comp:  2             [SII]6731      14.79      0.28       6    45
# Comp:  2              HeII4687     0.4892      0.28       6    45
# Comp:  2               HeI5876      15.37      0.28       6    45
# Comp:  2          [OIII]5007_d      1248.      0.35       6    45
# Comp:  2            [OI]6300_d      4.611      0.35       6    45
# Comp:  2           [NII]6583_d      13.67      0.35       6    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -159         1
#  comp.  1:        11        33
#  comp.  2:         6        42
# chi2/DOF: 12.35; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      191.1      0.27      11    33
# Comp:  1                Halpha      325.0      0.27      11    33
# Comp:  2             [SII]6716      18.78      0.28       6    42
# Comp:  2             [SII]6731      14.79      0.28       6    42
# Comp:  2              HeII4687     0.6372      0.28       6    42
# Comp:  2               HeI5876      15.78      0.28       6    42
# Comp:  2          [OIII]5007_d      1226.      0.35       6    42
# Comp:  2            [OI]6300_d      6.155      0.35       6    42
# Comp:  2           [NII]6583_d      13.98      0.35       6    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        83         1
#  comp.  1:         7        16
#  comp.  2:         6        41
# chi2/DOF: 12.61; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      163.2      0.26       7    16
# Comp:  1                Halpha      307.2      0.26       7    16
# Comp:  2             [SII]6716      19.07      0.28       6    41
# Comp:  2             [SII]6731      14.47      0.28       6    41
# Comp:  2              HeII4687     0.6781      0.28       6    41
# Comp:  2               HeI5876      16.28      0.28       6    41
# Comp:  2          [OIII]5007_d      1256.      0.35       6    41
# Comp:  2            [OI]6300_d      5.257      0.35       6    41
# Comp:  2           [NII]6583_d      14.01      0.35       6    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -254        40
#  comp.  1:         6        12
#  comp.  2:         7        43
# chi2/DOF: 12.98; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      171.3      0.26       6    12
# Comp:  1                Halpha      305.0      0.26       6    12
# Comp:  2             [SII]6716      17.47      0.28       7    43
# Comp:  2             [SII]6731      14.79      0.28       7    43
# Comp:  2              HeII4687     0.7985      0.28       7    43
# Comp:  2               HeI5876      16.88      0.28       7    43
# Comp:  2          [OIII]5007_d      1255.      0.35       7    43
# Comp:  2            [OI]6300_d      5.118      0.35       7    43
# Comp:  2           [NII]6583_d      13.69      0.35       7    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:         7        21
#  comp.  2:         8        44
# chi2/DOF: 11.23; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      164.0      0.26       7    21
# Comp:  1                Halpha      314.8      0.26       7    21
# Comp:  2             [SII]6716      20.32      0.28       8    44
# Comp:  2             [SII]6731      14.32      0.28       8    44
# Comp:  2              HeII4687     0.2637      0.28       8    44
# Comp:  2               HeI5876      16.86      0.28       8    44
# Comp:  2          [OIII]5007_d      1241.      0.35       8    44
# Comp:  2            [OI]6300_d      6.197      0.35       8    44
# Comp:  2           [NII]6583_d      14.18      0.35       8    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -180         1
#  comp.  1:         8        23
#  comp.  2:         7        46
# chi2/DOF: 13.89; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      174.9      0.26       8    23
# Comp:  1                Halpha      314.0      0.26       8    23
# Comp:  2             [SII]6716      18.50      0.28       7    46
# Comp:  2             [SII]6731      15.24      0.28       7    46
# Comp:  2              HeII4687    0.09957      0.28       7    46
# Comp:  2               HeI5876      14.82      0.28       7    46
# Comp:  2          [OIII]5007_d      1254.      0.35       7    46
# Comp:  2            [OI]6300_d      5.441      0.35       7    46
# Comp:  2           [NII]6583_d      14.66      0.35       7    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:         8        24
#  comp.  2:         7        44
# chi2/DOF: 14.13; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      172.1      0.26       8    24
# Comp:  1                Halpha      312.6      0.26       8    24
# Comp:  2             [SII]6716      19.40      0.28       7    44
# Comp:  2             [SII]6731      13.99      0.28       7    44
# Comp:  2              HeII4687     0.1786      0.28       7    44
# Comp:  2               HeI5876      18.13      0.28       7    44
# Comp:  2          [OIII]5007_d      1238.      0.35       7    44
# Comp:  2            [OI]6300_d      4.483      0.35       7    44
# Comp:  2           [NII]6583_d      14.15      0.35       7    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -129         1
#  comp.  1:         9        26
#  comp.  2:         6        45
# chi2/DOF: 15.25; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      176.0      0.26       9    26
# Comp:  1                Halpha      321.0      0.26       9    26
# Comp:  2             [SII]6716      16.67      0.28       6    45
# Comp:  2             [SII]6731      14.06      0.28       6    45
# Comp:  2              HeII4687     0.4845      0.28       6    45
# Comp:  2               HeI5876      16.48      0.28       6    45
# Comp:  2          [OIII]5007_d      1260.      0.35       6    45
# Comp:  2            [OI]6300_d      5.633      0.35       6    45
# Comp:  2           [NII]6583_d      14.45      0.35       6    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       165         1
#  comp.  1:         8        17
#  comp.  2:         6        41
# chi2/DOF: 13.12; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      173.9      0.26       8    17
# Comp:  1                Halpha      310.2      0.26       8    17
# Comp:  2             [SII]6716      20.07      0.28       6    41
# Comp:  2             [SII]6731      14.21      0.28       6    41
# Comp:  2              HeII4687     0.6014      0.28       6    41
# Comp:  2               HeI5876      17.98      0.28       6    41
# Comp:  2          [OIII]5007_d      1235.      0.35       6    41
# Comp:  2            [OI]6300_d      5.241      0.35       6    41
# Comp:  2           [NII]6583_d      14.32      0.35       6    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:         9        26
#  comp.  2:         6        38
# chi2/DOF: 12.40; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      176.8      0.26       9    26
# Comp:  1                Halpha      315.5      0.26       9    26
# Comp:  2             [SII]6716      19.10      0.27       6    38
# Comp:  2             [SII]6731      13.64      0.27       6    38
# Comp:  2              HeII4687      0.000      0.27       6    38
# Comp:  2               HeI5876      17.29      0.27       6    38
# Comp:  2          [OIII]5007_d      1241.      0.35       6    38
# Comp:  2            [OI]6300_d      4.509      0.35       6    38
# Comp:  2           [NII]6583_d      15.14      0.35       6    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -137         1
#  comp.  1:         7        25
#  comp.  2:         6        46
# chi2/DOF: 13.74; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      180.7      0.26       7    25
# Comp:  1                Halpha      315.9      0.26       7    25
# Comp:  2             [SII]6716      19.39      0.28       6    46
# Comp:  2             [SII]6731      12.81      0.28       6    46
# Comp:  2              HeII4687     0.3099      0.28       6    46
# Comp:  2               HeI5876      14.88      0.28       6    46
# Comp:  2          [OIII]5007_d      1263.      0.35       6    46
# Comp:  2            [OI]6300_d      6.268      0.35       6    46
# Comp:  2           [NII]6583_d      14.58      0.35       6    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       110         1
#  comp.  1:        10        31
#  comp.  2:         6        42
# chi2/DOF: 14.77; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      175.1      0.27      10    31
# Comp:  1                Halpha      321.5      0.27      10    31
# Comp:  2             [SII]6716      19.02      0.28       6    42
# Comp:  2             [SII]6731      14.65      0.28       6    42
# Comp:  2              HeII4687     0.5253      0.28       6    42
# Comp:  2               HeI5876      17.69      0.28       6    42
# Comp:  2          [OIII]5007_d      1245.      0.35       6    42
# Comp:  2            [OI]6300_d      4.961      0.35       6    42
# Comp:  2           [NII]6583_d      15.13      0.35       6    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:        13        34
#  comp.  2:         5        41
# chi2/DOF: 11.61; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      182.6      0.27      13    34
# Comp:  1                Halpha      332.7      0.27      13    34
# Comp:  2             [SII]6716      20.79      0.28       5    41
# Comp:  2             [SII]6731      13.81      0.28       5    41
# Comp:  2              HeII4687     0.1285      0.28       5    41
# Comp:  2               HeI5876      16.26      0.28       5    41
# Comp:  2          [OIII]5007_d      1236.      0.35       5    41
# Comp:  2            [OI]6300_d      5.441      0.35       5    41
# Comp:  2           [NII]6583_d      14.91      0.35       5    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -115         1
#  comp.  1:         6        17
#  comp.  2:         7        46
# chi2/DOF: 11.65; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      176.1      0.26       6    17
# Comp:  1                Halpha      310.6      0.26       6    17
# Comp:  2             [SII]6716      19.40      0.28       7    46
# Comp:  2             [SII]6731      14.30      0.28       7    46
# Comp:  2              HeII4687      0.000      0.28       7    46
# Comp:  2               HeI5876      15.57      0.28       7    46
# Comp:  2          [OIII]5007_d      1258.      0.35       7    46
# Comp:  2            [OI]6300_d      5.244      0.35       7    46
# Comp:  2           [NII]6583_d      15.25      0.35       7    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -180         1
#  comp.  1:         9        16
#  comp.  2:         7        48
# chi2/DOF: 11.44; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      165.0      0.26       9    16
# Comp:  1                Halpha      311.2      0.26       9    16
# Comp:  2             [SII]6716      20.54      0.28       7    48
# Comp:  2             [SII]6731      14.48      0.28       7    48
# Comp:  2              HeII4687     0.6722      0.28       7    48
# Comp:  2               HeI5876      17.29      0.28       7    48
# Comp:  2          [OIII]5007_d      1268.      0.36       7    48
# Comp:  2            [OI]6300_d      5.463      0.36       7    48
# Comp:  2           [NII]6583_d      14.56      0.36       7    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -107         1
#  comp.  1:         9        27
#  comp.  2:         5        43
# chi2/DOF: 15.04; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      177.2      0.26       9    27
# Comp:  1                Halpha      312.3      0.26       9    27
# Comp:  2             [SII]6716      19.14      0.28       5    43
# Comp:  2             [SII]6731      13.82      0.28       5    43
# Comp:  2              HeII4687     0.4549      0.28       5    43
# Comp:  2               HeI5876      15.45      0.28       5    43
# Comp:  2          [OIII]5007_d      1254.      0.35       5    43
# Comp:  2            [OI]6300_d      5.400      0.35       5    43
# Comp:  2           [NII]6583_d      14.34      0.35       5    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -121       385
#  comp.  1:        10        25
#  comp.  2:         8        43
# chi2/DOF: 14.34; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      171.7      0.26      10    25
# Comp:  1                Halpha      314.8      0.26      10    25
# Comp:  2             [SII]6716      20.13      0.28       8    43
# Comp:  2             [SII]6731      13.73      0.28       8    43
# Comp:  2              HeII4687     0.3201      0.28       8    43
# Comp:  2               HeI5876      15.33      0.28       8    43
# Comp:  2          [OIII]5007_d      1259.      0.35       8    43
# Comp:  2            [OI]6300_d      6.020      0.35       8    43
# Comp:  2           [NII]6583_d      13.68      0.35       8    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        12
#  comp.  1:        13        34
#  comp.  2:         6        46
# chi2/DOF: 11.50; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 25; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      191.8      0.27      13    34
# Comp:  1                Halpha      333.0      0.27      13    34
# Comp:  2             [SII]6716      17.97      0.28       6    46
# Comp:  2             [SII]6731      12.96      0.28       6    46
# Comp:  2              HeII4687    0.05254      0.28       6    46
# Comp:  2               HeI5876      17.18      0.28       6    46
# Comp:  2          [OIII]5007_d      1276.      0.35       6    46
# Comp:  2            [OI]6300_d      6.221      0.35       6    46
# Comp:  2           [NII]6583_d      14.87      0.35       6    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        89         1
#  comp.  1:        10        31
#  comp.  2:         8        41
# chi2/DOF: 13.98; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 14; Func calls: 104; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      175.1      0.27      10    31
# Comp:  1                Halpha      324.0      0.27      10    31
# Comp:  2             [SII]6716      20.10      0.28       8    41
# Comp:  2             [SII]6731      13.53      0.28       8    41
# Comp:  2              HeII4687     0.2376      0.28       8    41
# Comp:  2               HeI5876      14.54      0.28       8    41
# Comp:  2          [OIII]5007_d      1243.      0.35       8    41
# Comp:  2            [OI]6300_d      5.259      0.35       8    41
# Comp:  2           [NII]6583_d      14.13      0.35       8    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -123         1
#  comp.  1:        10        26
#  comp.  2:         7        46
# chi2/DOF: 14.42; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      175.8      0.26      10    26
# Comp:  1                Halpha      320.7      0.26      10    26
# Comp:  2             [SII]6716      16.99      0.28       7    46
# Comp:  2             [SII]6731      13.23      0.28       7    46
# Comp:  2              HeII4687     0.5903      0.28       7    46
# Comp:  2               HeI5876      16.16      0.28       7    46
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      171.9      0.27       9    32
# Comp:  1                Halpha      328.8      0.27       9    32
# Comp:  2             [SII]6716      16.47      0.28       5    41
# Comp:  2             [SII]6731      14.52      0.28       5    41
# Comp:  2              HeII4687     0.3883      0.28       5    41
# Comp:  2               HeI5876      16.89      0.28       5    41
# Comp:  2          [OIII]5007_d      1238.      0.35       5    41
# Comp:  2            [OI]6300_d      5.248      0.35       5    41
# Comp:  2           [NII]6583_d      13.39      0.35       5    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        74
#  comp.  1:         6        16
#  comp.  2:         5        46
# chi2/DOF: 10.51; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      173.1      0.26       6    16
# Comp:  1                Halpha      307.0      0.26       6    16
# Comp:  2             [SII]6716      17.74      0.28       5    46
# Comp:  2             [SII]6731      14.44      0.28       5    46
# Comp:  2              HeII4687     0.7874      0.28       5    46
# Comp:  2               HeI5876      17.24      0.28       5    46
# Comp:  2          [OIII]5007_d      1244.      0.35       5    46
# Comp:  2            [OI]6300_d      5.335      0.35       5    46
# Comp:  2           [NII]6583_d      13.66      0.35       5    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92         1
#  comp.  1:         9        19
#  comp.  2:         6        44
# chi2/DOF: 14.55; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      166.0      0.26       9    19
# Comp:  1                Halpha      310.4      0.26       9    19
# Comp:  2             [SII]6716      18.41      0.28       6    44
# Comp:  2             [SII]6731      15.10      0.28       6    44
# Comp:  2              HeII4687     0.6610      0.28       6    44
# Comp:  2               HeI5876      17.10      0.28       6    44
# Comp:  2          [OIII]5007_d      1263.      0.35       6    44
# Comp:  2            [OI]6300_d      4.521      0.35       6    44
# Comp:  2           [NII]6583_d      15.40      0.35       6    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       125         1
#  comp.  1:         9        22
#  comp.  2:         5        46
# chi2/DOF: 13.67; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      180.2      0.26       9    22
# Comp:  1                Halpha      310.2      0.26       9    22
# Comp:  2             [SII]6716      19.92      0.28       5    46
# Comp:  2             [SII]6731      13.88      0.28       5    46
# Comp:  2              HeII4687    0.08540      0.28       5    46
# Comp:  2               HeI5876      17.86      0.28       5    46
# Comp:  2          [OIII]5007_d      1272.      0.35       5    46
# Comp:  2            [OI]6300_d      5.208      0.35       5    46
# Comp:  2           [NII]6583_d      14.05      0.35       5    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81         1
#  comp.  1:         8        15
#  comp.  2:         4        39
# chi2/DOF: 9.808; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      175.0      0.26       8    15
# Comp:  1                Halpha      313.6      0.26       8    15
# Comp:  2             [SII]6716      17.21      0.27       4    39
# Comp:  2             [SII]6731      14.70      0.27       4    39
# Comp:  2              HeII4687     0.2833      0.27       4    39
# Comp:  2               HeI5876      16.85      0.27       4    39
# Comp:  2          [OIII]5007_d      1223.      0.35       4    39
# Comp:  2            [OI]6300_d      5.134      0.35       4    39
# Comp:  2           [NII]6583_d      14.25      0.35       4    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       131         1
#  comp.  1:        12        30
#  comp.  2:         5        40
# chi2/DOF: 12.20; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      173.3      0.27      12    30
# Comp:  1                Halpha      324.9      0.27      12    30
# Comp:  2             [SII]6716      15.55      0.27       5    40
# Comp:  2             [SII]6731      13.29      0.27       5    40
# Comp:  2              HeII4687     0.6157      0.27       5    40
# Comp:  2               HeI5876      17.37      0.27       5    40
# Comp:  2          [OIII]5007_d      1249.      0.35       5    40
# Comp:  2            [OI]6300_d      5.717      0.35       5    40
# Comp:  2           [NII]6583_d      15.01      0.35       5    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       104         1
#  comp.  1:         9        30
#  comp.  2:         7        40
# chi2/DOF: 12.21; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      185.1      0.27       9    30
# Comp:  1                Halpha      326.0      0.27       9    30
# Comp:  2             [SII]6716      17.70      0.28       7    40
# Comp:  2             [SII]6731      12.49      0.28       7    40
# Comp:  2              HeII4687     0.5077      0.28       7    40
# Comp:  2               HeI5876      16.73      0.28       7    40
# Comp:  2          [OIII]5007_d      1218.      0.35       7    40
# Comp:  2            [OI]6300_d      5.029      0.35       7    40
# Comp:  2           [NII]6583_d      15.37      0.35       7    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -140         1
#  comp.  1:        12        37
#  comp.  2:         8        47
# chi2/DOF: 9.863; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      182.7      0.27      12    37
# Comp:  1                Halpha      337.6      0.27      12    37
# Comp:  2             [SII]6716      16.91      0.28       8    47
# Comp:  2             [SII]6731      14.41      0.28       8    47
# Comp:  2              HeII4687     0.3806      0.28       8    47
# Comp:  2               HeI5876      17.87      0.28       8    47
# Comp:  2          [OIII]5007_d      1254.      0.36       8    47
# Comp:  2            [OI]6300_d      5.451      0.36       8    47
# Comp:  2           [NII]6583_d      15.03      0.36       8    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -129         1
#  comp.  1:        13        34
#  comp.  2:         6        47
# chi2/DOF: 10.90; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      188.3      0.27      13    34
# Comp:  1                Halpha      328.8      0.27      13    34
# Comp:  2             [SII]6716      18.92      0.28       6    47
# Comp:  2             [SII]6731      13.02      0.28       6    47
# Comp:  2              HeII4687     0.3699      0.28       6    47
# Comp:  2               HeI5876      14.41      0.28       6    47
# Comp:  2          [OIII]5007_d      1279.      0.36       6    47
# Comp:  2            [OI]6300_d      4.521      0.36       6    47
# Comp:  2           [NII]6583_d      15.00      0.36       6    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -183         1
#  comp.  1:        11        24
#  comp.  2:         5        43
# chi2/DOF: 13.50; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      178.0      0.26      11    24
# Comp:  1                Halpha      321.5      0.26      11    24
# Comp:  2             [SII]6716      19.96      0.28       5    43
# Comp:  2             [SII]6731      13.94      0.28       5    43
# Comp:  2              HeII4687     0.2428      0.28       5    43
# Comp:  2               HeI5876      14.89      0.28       5    43
# Comp:  2          [OIII]5007_d      1233.      0.35       5    43
# Comp:  2            [OI]6300_d      5.970      0.35       5    43
# Comp:  2           [NII]6583_d      14.45      0.35       5    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       123         1
#  comp.  1:        12        30
#  comp.  2:         4        41
# chi2/DOF: 12.05; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      170.2      0.27      12    30
# Comp:  1                Halpha      327.8      0.27      12    30
# Comp:  2             [SII]6716      17.48      0.28       4    41
# Comp:  2             [SII]6731      12.51      0.28       4    41
# Comp:  2              HeII4687     0.1045      0.28       4    41
# Comp:  2               HeI5876      16.46      0.28       4    41
# Comp:  2          [OIII]5007_d      1235.      0.35       4    41
# Comp:  2            [OI]6300_d      5.039      0.35       4    41
# Comp:  2           [NII]6583_d      14.36      0.35       4    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17         1
#  comp.  1:         9        24
#  comp.  2:         8        47
# chi2/DOF: 10.98; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      181.6      0.26       9    24
# Comp:  1                Halpha      319.5      0.26       9    24
# Comp:  2             [SII]6716      20.70      0.28       8    47
# Comp:  2             [SII]6731      14.31      0.28       8    47
# Comp:  2              HeII4687     0.3338      0.28       8    47
# Comp:  2               HeI5876      16.54      0.28       8    47
# Comp:  2          [OIII]5007_d      1282.      0.36       8    47
# Comp:  2            [OI]6300_d      6.123      0.36       8    47
# Comp:  2           [NII]6583_d      14.38      0.36       8    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       136         1
#  comp.  1:        12        33
#  comp.  2:         6        44
# chi2/DOF: 14.06; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      172.3      0.27      12    33
# Comp:  1                Halpha      328.9      0.27      12    33
# Comp:  2             [SII]6716      18.73      0.28       6    44
# Comp:  2             [SII]6731      12.67      0.28       6    44
# Comp:  2              HeII4687     0.8127      0.28       6    44
# Comp:  2               HeI5876      16.28      0.28       6    44
# Comp:  2          [OIII]5007_d      1258.      0.35       6    44
# Comp:  2            [OI]6300_d      4.576      0.35       6    44
# Comp:  2           [NII]6583_d      14.26      0.35       6    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        57       598
#  comp.  1:         9        16
#  comp.  2:         6        44
# chi2/DOF: 14.42; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      165.6      0.26       9    16
# Comp:  1                Halpha      311.1      0.26       9    16
# Comp:  2             [SII]6716      16.96      0.28       6    44
# Comp:  2             [SII]6731      14.29      0.28       6    44
# Comp:  2              HeII4687     0.3935      0.28       6    44
# Comp:  2               HeI5876      16.58      0.28       6    44
# Comp:  2          [OIII]5007_d      1254.      0.35       6    44
# Comp:  2            [OI]6300_d      4.661      0.35       6    44
# Comp:  2           [NII]6583_d      14.58      0.35       6    44
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([ 7.44543477, 12.01015019,  1.91729067,  1.04615651,  0.22915677,
#         1.37533564, 16.50729359,  0.72457746,  0.79157488])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum1s_1_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum1s_1_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum1s_1_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum1s_1_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum1s_1_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
