# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3s_3.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_1263/FORS2.2022-01-06T07_26_01.965/Spectra_extraction/redshift.txt") 
z = red[2][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_3s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.00423

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.2172112  2.21794808 2.21868496 ... 3.53181044 3.53254732 3.53328421]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        28         1
# chi2/DOF: 0.003968; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:        36         1
# chi2/DOF: 0.002712; DOF: 1899; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([35.64269907,  0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:        16        24
#  comp.  2:        21        49
# chi2/DOF: 4.087; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.91      0.18      16    24
# Comp:  1                Halpha      81.84      0.18      16    24
# Comp:  2             [SII]6716      7.735      0.19      21    49
# Comp:  2             [SII]6731      5.487      0.19      21    49
# Comp:  2              HeII4687     0.3283      0.19      21    49
# Comp:  2               HeI5876      3.570      0.19      21    49
# Comp:  2          [OIII]5007_d      198.2      0.25      21    49
# Comp:  2            [OI]6300_d      1.972      0.25      21    49
# Comp:  2           [NII]6583_d      5.049      0.25      21    49
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:    350; gas flux:     60 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  495.8; gas flux:    112 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  40.02; gas flux:     11 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  27.56; gas flux:      8 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.696; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  18.36; gas flux:      4 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  753.8; gas flux:    207 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  7.302; gas flux:      3 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  19.46; gas flux:      7 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -95        45
#  comp.  1:         7        18
#  comp.  2:        22        52
# chi2/DOF: 2.755; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.30      0.18       7    18
# Comp:  1                Halpha      79.49      0.18       7    18
# Comp:  2             [SII]6716      7.351      0.20      22    52
# Comp:  2             [SII]6731      5.555      0.20      22    52
# Comp:  2              HeII4687     0.3702      0.20      22    52
# Comp:  2               HeI5876      3.393      0.20      22    52
# Comp:  2          [OIII]5007_d      200.8      0.25      22    52
# Comp:  2            [OI]6300_d      2.114      0.25      22    52
# Comp:  2           [NII]6583_d      5.475      0.25      22    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23         1
#  comp.  1:        23        17
#  comp.  2:        23        49
# chi2/DOF: 2.952; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.93      0.18      23    17
# Comp:  1                Halpha      82.09      0.18      23    17
# Comp:  2             [SII]6716      9.317      0.19      23    49
# Comp:  2             [SII]6731      5.416      0.19      23    49
# Comp:  2              HeII4687     0.4493      0.19      23    49
# Comp:  2               HeI5876      3.546      0.19      23    49
# Comp:  2          [OIII]5007_d      201.7      0.25      23    49
# Comp:  2            [OI]6300_d      2.015      0.25      23    49
# Comp:  2           [NII]6583_d      5.448      0.25      23    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53       116
#  comp.  1:        17        26
#  comp.  2:        19        46
# chi2/DOF: 3.775; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.74      0.18      17    26
# Comp:  1                Halpha      79.99      0.18      17    26
# Comp:  2             [SII]6716      7.094      0.19      19    46
# Comp:  2             [SII]6731      6.102      0.19      19    46
# Comp:  2              HeII4687     0.1128      0.19      19    46
# Comp:  2               HeI5876      3.414      0.19      19    46
# Comp:  2          [OIII]5007_d      197.2      0.24      19    46
# Comp:  2            [OI]6300_d      1.751      0.24      19    46
# Comp:  2           [NII]6583_d      4.559      0.24      19    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:        12        38
#  comp.  2:        20        50
# chi2/DOF: 2.778; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      69.26      0.19      12    38
# Comp:  1                Halpha      89.51      0.19      12    38
# Comp:  2             [SII]6716      6.533      0.20      20    50
# Comp:  2             [SII]6731      5.157      0.20      20    50
# Comp:  2              HeII4687     0.1573      0.20      20    50
# Comp:  2               HeI5876      3.626      0.20      20    50
# Comp:  2          [OIII]5007_d      198.0      0.25      20    50
# Comp:  2            [OI]6300_d      2.113      0.25      20    50
# Comp:  2           [NII]6583_d      4.740      0.25      20    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       116         1
#  comp.  1:        15        37
#  comp.  2:        23        50
# chi2/DOF: 3.388; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      62.06      0.19      15    37
# Comp:  1                Halpha      83.89      0.19      15    37
# Comp:  2             [SII]6716      9.288      0.20      23    50
# Comp:  2             [SII]6731      4.999      0.20      23    50
# Comp:  2              HeII4687     0.4014      0.20      23    50
# Comp:  2               HeI5876      3.711      0.20      23    50
# Comp:  2          [OIII]5007_d      199.3      0.25      23    50
# Comp:  2            [OI]6300_d      2.034      0.25      23    50
# Comp:  2           [NII]6583_d      4.787      0.25      23    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85         1
#  comp.  1:        15         9
#  comp.  2:        19        47
# chi2/DOF: 3.189; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      52.07      0.18      15     9
# Comp:  1                Halpha      78.80      0.18      15     9
# Comp:  2             [SII]6716      6.947      0.19      19    47
# Comp:  2             [SII]6731      4.879      0.19      19    47
# Comp:  2              HeII4687     0.4002      0.19      19    47
# Comp:  2               HeI5876      3.267      0.19      19    47
# Comp:  2          [OIII]5007_d      192.5      0.24      19    47
# Comp:  2            [OI]6300_d      1.919      0.24      19    47
# Comp:  2           [NII]6583_d      4.493      0.24      19    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36       121
#  comp.  1:        16         1
#  comp.  2:        20        50
# chi2/DOF: 3.051; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      61.69      0.17      16     1
# Comp:  1                Halpha      76.20      0.17      16     1
# Comp:  2             [SII]6716      9.321      0.20      20    50
# Comp:  2             [SII]6731      5.124      0.20      20    50
# Comp:  2              HeII4687     0.4338      0.20      20    50
# Comp:  2               HeI5876      3.528      0.20      20    50
# Comp:  2          [OIII]5007_d      198.2      0.25      20    50
# Comp:  2            [OI]6300_d      1.922      0.25      20    50
# Comp:  2           [NII]6583_d      4.582      0.25      20    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -94         1
#  comp.  1:        10        16
#  comp.  2:        22        49
# chi2/DOF: 2.983; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      62.34      0.18      10    16
# Comp:  1                Halpha      81.44      0.18      10    16
# Comp:  2             [SII]6716      9.458      0.19      22    49
# Comp:  2             [SII]6731      5.258      0.19      22    49
# Comp:  2              HeII4687     0.3377      0.19      22    49
# Comp:  2               HeI5876      3.621      0.19      22    49
# Comp:  2          [OIII]5007_d      198.0      0.25      22    49
# Comp:  2            [OI]6300_d      1.795      0.25      22    49
# Comp:  2           [NII]6583_d      5.137      0.25      22    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:        18        25
#  comp.  2:        19        45
# chi2/DOF: 2.933; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      53.58      0.18      18    25
# Comp:  1                Halpha      79.45      0.18      18    25
# Comp:  2             [SII]6716      9.146      0.19      19    45
# Comp:  2             [SII]6731      5.160      0.19      19    45
# Comp:  2              HeII4687      0.000      0.19      19    45
# Comp:  2               HeI5876      3.787      0.19      19    45
# Comp:  2          [OIII]5007_d      196.3      0.24      19    45
# Comp:  2            [OI]6300_d      1.922      0.24      19    45
# Comp:  2           [NII]6583_d      4.872      0.24      19    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:        25         1
#  comp.  2:        19        46
# chi2/DOF: 2.185; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.02      0.17      25     1
# Comp:  1                Halpha      76.63      0.17      25     1
# Comp:  2             [SII]6716      7.163      0.19      19    46
# Comp:  2             [SII]6731      5.602      0.19      19    46
# Comp:  2              HeII4687     0.6712      0.19      19    46
# Comp:  2               HeI5876      3.929      0.19      19    46
# Comp:  2          [OIII]5007_d      196.2      0.24      19    46
# Comp:  2            [OI]6300_d      1.712      0.24      19    46
# Comp:  2           [NII]6583_d      5.409      0.24      19    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43         1
#  comp.  1:        20        17
#  comp.  2:        23        49
# chi2/DOF: 3.205; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.64      0.18      20    17
# Comp:  1                Halpha      85.02      0.18      20    17
# Comp:  2             [SII]6716      9.266      0.19      23    49
# Comp:  2             [SII]6731      4.382      0.19      23    49
# Comp:  2              HeII4687     0.4820      0.19      23    49
# Comp:  2               HeI5876      3.884      0.19      23    49
# Comp:  2          [OIII]5007_d      202.1      0.25      23    49
# Comp:  2            [OI]6300_d      2.024      0.25      23    49
# Comp:  2           [NII]6583_d      5.488      0.25      23    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25         1
#  comp.  1:        20        33
#  comp.  2:        24        54
# chi2/DOF: 2.697; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 38; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      56.43      0.18      20    33
# Comp:  1                Halpha      81.10      0.18      20    33
# Comp:  2             [SII]6716      8.407      0.20      24    54
# Comp:  2             [SII]6731      4.449      0.20      24    54
# Comp:  2              HeII4687     0.2013      0.20      24    54
# Comp:  2               HeI5876      4.137      0.20      24    54
# Comp:  2          [OIII]5007_d      207.2      0.25      24    54
# Comp:  2            [OI]6300_d      2.095      0.25      24    54
# Comp:  2           [NII]6583_d      5.332      0.25      24    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        91
#  comp.  1:        13        21
#  comp.  2:        21        48
# chi2/DOF: 3.359; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      64.82      0.18      13    21
# Comp:  1                Halpha      82.69      0.18      13    21
# Comp:  2             [SII]6716      8.066      0.19      21    48
# Comp:  2             [SII]6731      6.563      0.19      21    48
# Comp:  2              HeII4687     0.2177      0.19      21    48
# Comp:  2               HeI5876      3.678      0.19      21    48
# Comp:  2          [OIII]5007_d      195.9      0.25      21    48
# Comp:  2            [OI]6300_d      1.980      0.25      21    48
# Comp:  2           [NII]6583_d      4.781      0.25      21    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:        18        19
#  comp.  2:        18        45
# chi2/DOF: 2.959; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      52.64      0.18      18    19
# Comp:  1                Halpha      80.04      0.18      18    19
# Comp:  2             [SII]6716      8.215      0.19      18    45
# Comp:  2             [SII]6731      5.226      0.19      18    45
# Comp:  2              HeII4687     0.2718      0.19      18    45
# Comp:  2               HeI5876      3.562      0.19      18    45
# Comp:  2          [OIII]5007_d      192.9      0.24      18    45
# Comp:  2            [OI]6300_d      1.965      0.24      18    45
# Comp:  2           [NII]6583_d      5.356      0.24      18    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100        50
#  comp.  1:        11        36
#  comp.  2:        20        52
# chi2/DOF: 2.512; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      67.77      0.19      11    36
# Comp:  1                Halpha      87.19      0.19      11    36
# Comp:  2             [SII]6716      6.668      0.20      20    52
# Comp:  2             [SII]6731      4.873      0.20      20    52
# Comp:  2              HeII4687     0.1855      0.20      20    52
# Comp:  2               HeI5876      3.428      0.20      20    52
# Comp:  2          [OIII]5007_d      201.4      0.25      20    52
# Comp:  2            [OI]6300_d      1.852      0.25      20    52
# Comp:  2           [NII]6583_d      5.742      0.25      20    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -121         1
#  comp.  1:        11        25
#  comp.  2:        21        50
# chi2/DOF: 3.625; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      59.43      0.18      11    25
# Comp:  1                Halpha      82.91      0.18      11    25
# Comp:  2             [SII]6716      7.048      0.20      21    50
# Comp:  2             [SII]6731      5.029      0.20      21    50
# Comp:  2              HeII4687    0.04690      0.20      21    50
# Comp:  2               HeI5876      3.629      0.20      21    50
# Comp:  2          [OIII]5007_d      200.5      0.25      21    50
# Comp:  2            [OI]6300_d      1.987      0.25      21    50
# Comp:  2           [NII]6583_d      4.816      0.25      21    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -144        89
#  comp.  1:        17        15
#  comp.  2:        23        48
# chi2/DOF: 3.064; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      63.12      0.18      17    15
# Comp:  1                Halpha      76.77      0.18      17    15
# Comp:  2             [SII]6716      7.829      0.19      23    48
# Comp:  2             [SII]6731      5.007      0.19      23    48
# Comp:  2              HeII4687     0.2523      0.19      23    48
# Comp:  2               HeI5876      3.260      0.19      23    48
# Comp:  2          [OIII]5007_d      198.2      0.25      23    48
# Comp:  2            [OI]6300_d      2.094      0.25      23    48
# Comp:  2           [NII]6583_d      4.470      0.25      23    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:        18        36
#  comp.  2:        19        46
# chi2/DOF: 3.355; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      62.54      0.19      18    36
# Comp:  1                Halpha      86.46      0.19      18    36
# Comp:  2             [SII]6716      7.628      0.19      19    46
# Comp:  2             [SII]6731      4.377      0.19      19    46
# Comp:  2              HeII4687     0.1863      0.19      19    46
# Comp:  2               HeI5876      3.931      0.19      19    46
# Comp:  2          [OIII]5007_d      191.7      0.24      19    46
# Comp:  2            [OI]6300_d      1.877      0.24      19    46
# Comp:  2           [NII]6583_d      5.026      0.24      19    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5         1
#  comp.  1:        23        16
#  comp.  2:        20        49
# chi2/DOF: 3.381; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.28      0.18      23    16
# Comp:  1                Halpha      78.22      0.18      23    16
# Comp:  2             [SII]6716      7.614      0.19      20    49
# Comp:  2             [SII]6731      6.148      0.19      20    49
# Comp:  2              HeII4687    0.05977      0.19      20    49
# Comp:  2               HeI5876      3.721      0.19      20    49
# Comp:  2          [OIII]5007_d      198.2      0.25      20    49
# Comp:  2            [OI]6300_d      1.854      0.25      20    49
# Comp:  2           [NII]6583_d      4.889      0.25      20    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47         1
#  comp.  1:        17        35
#  comp.  2:        21        50
# chi2/DOF: 3.097; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      68.73      0.19      17    35
# Comp:  1                Halpha      83.33      0.19      17    35
# Comp:  2             [SII]6716      7.327      0.20      21    50
# Comp:  2             [SII]6731      5.821      0.20      21    50
# Comp:  2              HeII4687     0.2397      0.20      21    50
# Comp:  2               HeI5876      3.820      0.20      21    50
# Comp:  2          [OIII]5007_d      196.7      0.25      21    50
# Comp:  2            [OI]6300_d      1.952      0.25      21    50
# Comp:  2           [NII]6583_d      5.695      0.25      21    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -104         1
#  comp.  1:        12        39
#  comp.  2:        23        52
# chi2/DOF: 2.320; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      68.68      0.19      12    39
# Comp:  1                Halpha      89.24      0.19      12    39
# Comp:  2             [SII]6716      7.392      0.20      23    52
# Comp:  2             [SII]6731      5.423      0.20      23    52
# Comp:  2              HeII4687    0.04750      0.20      23    52
# Comp:  2               HeI5876      3.648      0.20      23    52
# Comp:  2          [OIII]5007_d      202.0      0.25      23    52
# Comp:  2            [OI]6300_d      1.966      0.25      23    52
# Comp:  2           [NII]6583_d      5.034      0.25      23    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42       146
#  comp.  1:        17        27
#  comp.  2:        19        43
# chi2/DOF: 2.789; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      65.13      0.18      17    27
# Comp:  1                Halpha      81.89      0.18      17    27
# Comp:  2             [SII]6716      6.992      0.19      19    43
# Comp:  2             [SII]6731      4.809      0.19      19    43
# Comp:  2              HeII4687     0.3648      0.19      19    43
# Comp:  2               HeI5876      3.577      0.19      19    43
# Comp:  2          [OIII]5007_d      189.2      0.24      19    43
# Comp:  2            [OI]6300_d      1.742      0.24      19    43
# Comp:  2           [NII]6583_d      4.224      0.24      19    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59         1
#  comp.  1:        16         1
#  comp.  2:        20        49
# chi2/DOF: 3.383; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.37      0.17      16     1
# Comp:  1                Halpha      80.87      0.17      16     1
# Comp:  2             [SII]6716      6.179      0.19      20    49
# Comp:  2             [SII]6731      6.058      0.19      20    49
# Comp:  2              HeII4687     0.3257      0.19      20    49
# Comp:  2               HeI5876      3.430      0.19      20    49
# Comp:  2          [OIII]5007_d      196.9      0.25      20    49
# Comp:  2            [OI]6300_d      1.981      0.25      20    49
# Comp:  2           [NII]6583_d      5.341      0.25      20    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -119        37
#  comp.  1:        16        34
#  comp.  2:        20        47
# chi2/DOF: 2.935; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 16; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.61      0.19      16    34
# Comp:  1                Halpha      86.23      0.19      16    34
# Comp:  2             [SII]6716      7.703      0.19      20    47
# Comp:  2             [SII]6731      6.113      0.19      20    47
# Comp:  2              HeII4687     0.6129      0.19      20    47
# Comp:  2               HeI5876      3.268      0.19      20    47
# Comp:  2          [OIII]5007_d      193.5      0.24      20    47
# Comp:  2            [OI]6300_d      2.040      0.24      20    47
# Comp:  2           [NII]6583_d      5.257      0.24      20    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23       377
#  comp.  1:        15         1
#  comp.  2:        20        47
# chi2/DOF: 3.682; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      55.83      0.17      15     1
# Comp:  1                Halpha      77.78      0.17      15     1
# Comp:  2             [SII]6716      8.048      0.19      20    47
# Comp:  2             [SII]6731      6.001      0.19      20    47
# Comp:  2              HeII4687     0.6157      0.19      20    47
# Comp:  2               HeI5876      3.516      0.19      20    47
# Comp:  2          [OIII]5007_d      197.9      0.24      20    47
# Comp:  2            [OI]6300_d      1.912      0.24      20    47
# Comp:  2           [NII]6583_d      5.686      0.24      20    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       155         1
#  comp.  1:        13        24
#  comp.  2:        22        50
# chi2/DOF: 3.583; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.99      0.18      13    24
# Comp:  1                Halpha      81.26      0.18      13    24
# Comp:  2             [SII]6716      7.160      0.20      22    50
# Comp:  2             [SII]6731      5.759      0.20      22    50
# Comp:  2              HeII4687     0.6498      0.20      22    50
# Comp:  2               HeI5876      3.605      0.20      22    50
# Comp:  2          [OIII]5007_d      199.0      0.25      22    50
# Comp:  2            [OI]6300_d      2.083      0.25      22    50
# Comp:  2           [NII]6583_d      4.469      0.25      22    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51         1
#  comp.  1:        11        20
#  comp.  2:        24        52
# chi2/DOF: 2.783; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      52.72      0.18      11    20
# Comp:  1                Halpha      81.67      0.18      11    20
# Comp:  2             [SII]6716      8.979      0.20      24    52
# Comp:  2             [SII]6731      5.692      0.20      24    52
# Comp:  2              HeII4687     0.2082      0.20      24    52
# Comp:  2               HeI5876      3.784      0.20      24    52
# Comp:  2          [OIII]5007_d      199.6      0.25      24    52
# Comp:  2            [OI]6300_d      2.134      0.25      24    52
# Comp:  2           [NII]6583_d      5.033      0.25      24    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -133        54
#  comp.  1:        14        24
#  comp.  2:        22        50
# chi2/DOF: 3.014; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      64.78      0.18      14    24
# Comp:  1                Halpha      84.64      0.18      14    24
# Comp:  2             [SII]6716      7.696      0.20      22    50
# Comp:  2             [SII]6731      6.620      0.20      22    50
# Comp:  2              HeII4687    0.09550      0.20      22    50
# Comp:  2               HeI5876      3.261      0.20      22    50
# Comp:  2          [OIII]5007_d      198.1      0.25      22    50
# Comp:  2            [OI]6300_d      1.847      0.25      22    50
# Comp:  2           [NII]6583_d      4.734      0.25      22    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        74
#  comp.  1:        13        29
#  comp.  2:        20        49
# chi2/DOF: 3.674; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      60.46      0.18      13    29
# Comp:  1                Halpha      82.29      0.18      13    29
# Comp:  2             [SII]6716      8.495      0.19      20    49
# Comp:  2             [SII]6731      5.524      0.19      20    49
# Comp:  2              HeII4687     0.2022      0.19      20    49
# Comp:  2               HeI5876      3.705      0.19      20    49
# Comp:  2          [OIII]5007_d      195.5      0.25      20    49
# Comp:  2            [OI]6300_d      1.977      0.25      20    49
# Comp:  2           [NII]6583_d      5.214      0.25      20    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92         1
#  comp.  1:        10        31
#  comp.  2:        22        51
# chi2/DOF: 2.615; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      67.20      0.18      10    31
# Comp:  1                Halpha      85.82      0.18      10    31
# Comp:  2             [SII]6716      6.738      0.20      22    51
# Comp:  2             [SII]6731      5.967      0.20      22    51
# Comp:  2              HeII4687     0.2966      0.20      22    51
# Comp:  2               HeI5876      3.611      0.20      22    51
# Comp:  2          [OIII]5007_d      200.6      0.25      22    51
# Comp:  2            [OI]6300_d      2.194      0.25      22    51
# Comp:  2           [NII]6583_d      5.175      0.25      22    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        85        45
#  comp.  1:        10        27
#  comp.  2:        19        45
# chi2/DOF: 2.808; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 85; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      59.84      0.18      10    27
# Comp:  1                Halpha      78.03      0.18      10    27
# Comp:  2             [SII]6716      8.782      0.19      19    45
# Comp:  2             [SII]6731      5.927      0.19      19    45
# Comp:  2              HeII4687     0.5190      0.19      19    45
# Comp:  2               HeI5876      3.848      0.19      19    45
# Comp:  2          [OIII]5007_d      193.3      0.24      19    45
# Comp:  2            [OI]6300_d      2.126      0.24      19    45
# Comp:  2           [NII]6583_d      5.252      0.24      19    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43         1
#  comp.  1:        23         3
#  comp.  2:        19        44
# chi2/DOF: 2.206; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      50.45      0.17      23     3
# Comp:  1                Halpha      77.66      0.17      23     3
# Comp:  2             [SII]6716      8.209      0.19      19    44
# Comp:  2             [SII]6731      5.021      0.19      19    44
# Comp:  2              HeII4687      0.000      0.19      19    44
# Comp:  2               HeI5876      3.620      0.19      19    44
# Comp:  2          [OIII]5007_d      194.2      0.24      19    44
# Comp:  2            [OI]6300_d      1.844      0.24      19    44
# Comp:  2           [NII]6583_d      5.679      0.24      19    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:        14        27
#  comp.  2:        21        53
# chi2/DOF: 3.178; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      53.86      0.18      14    27
# Comp:  1                Halpha      87.15      0.18      14    27
# Comp:  2             [SII]6716      8.447      0.20      21    53
# Comp:  2             [SII]6731      4.510      0.20      21    53
# Comp:  2              HeII4687     0.1076      0.20      21    53
# Comp:  2               HeI5876      3.375      0.20      21    53
# Comp:  2          [OIII]5007_d      201.7      0.25      21    53
# Comp:  2            [OI]6300_d      2.049      0.25      21    53
# Comp:  2           [NII]6583_d      5.528      0.25      21    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23         1
#  comp.  1:        24        21
#  comp.  2:        20        48
# chi2/DOF: 3.137; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      59.59      0.18      24    21
# Comp:  1                Halpha      80.73      0.18      24    21
# Comp:  2             [SII]6716      8.377      0.19      20    48
# Comp:  2             [SII]6731      6.048      0.19      20    48
# Comp:  2              HeII4687     0.5573      0.19      20    48
# Comp:  2               HeI5876      3.922      0.19      20    48
# Comp:  2          [OIII]5007_d      196.8      0.24      20    48
# Comp:  2            [OI]6300_d      1.711      0.24      20    48
# Comp:  2           [NII]6583_d      4.963      0.24      20    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63         1
#  comp.  1:        16        34
#  comp.  2:        18        45
# chi2/DOF: 2.792; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      68.47      0.19      16    34
# Comp:  1                Halpha      83.34      0.19      16    34
# Comp:  2             [SII]6716      9.121      0.19      18    45
# Comp:  2             [SII]6731      5.049      0.19      18    45
# Comp:  2              HeII4687    0.04056      0.19      18    45
# Comp:  2               HeI5876      3.519      0.19      18    45
# Comp:  2          [OIII]5007_d      193.0      0.24      18    45
# Comp:  2            [OI]6300_d      2.035      0.24      18    45
# Comp:  2           [NII]6583_d      5.399      0.24      18    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69         1
#  comp.  1:        10        29
#  comp.  2:        23        53
# chi2/DOF: 2.625; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.19      0.18      10    29
# Comp:  1                Halpha      87.80      0.18      10    29
# Comp:  2             [SII]6716      8.596      0.20      23    53
# Comp:  2             [SII]6731      5.697      0.20      23    53
# Comp:  2              HeII4687      0.000      0.20      23    53
# Comp:  2               HeI5876      3.398      0.20      23    53
# Comp:  2          [OIII]5007_d      202.2      0.25      23    53
# Comp:  2            [OI]6300_d      1.938      0.25      23    53
# Comp:  2           [NII]6583_d      5.688      0.25      23    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:        21         1
#  comp.  2:        22        52
# chi2/DOF: 2.520; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.43      0.17      21     1
# Comp:  1                Halpha      76.82      0.17      21     1
# Comp:  2             [SII]6716      9.065      0.20      22    52
# Comp:  2             [SII]6731      5.693      0.20      22    52
# Comp:  2              HeII4687     0.5071      0.20      22    52
# Comp:  2               HeI5876      3.716      0.20      22    52
# Comp:  2          [OIII]5007_d      200.7      0.25      22    52
# Comp:  2            [OI]6300_d      2.220      0.25      22    52
# Comp:  2           [NII]6583_d      4.611      0.25      22    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        61
#  comp.  1:        17        30
#  comp.  2:        20        47
# chi2/DOF: 3.195; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      67.09      0.18      17    30
# Comp:  1                Halpha      81.12      0.18      17    30
# Comp:  2             [SII]6716      8.226      0.19      20    47
# Comp:  2             [SII]6731      5.760      0.19      20    47
# Comp:  2              HeII4687     0.3492      0.19      20    47
# Comp:  2               HeI5876      3.413      0.19      20    47
# Comp:  2          [OIII]5007_d      197.4      0.24      20    47
# Comp:  2            [OI]6300_d      1.971      0.24      20    47
# Comp:  2           [NII]6583_d      4.816      0.24      20    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31         1
#  comp.  1:        18        15
#  comp.  2:        23        51
# chi2/DOF: 3.198; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      52.37      0.18      18    15
# Comp:  1                Halpha      75.92      0.18      18    15
# Comp:  2             [SII]6716      8.936      0.20      23    51
# Comp:  2             [SII]6731      5.464      0.20      23    51
# Comp:  2              HeII4687     0.1566      0.20      23    51
# Comp:  2               HeI5876      3.526      0.20      23    51
# Comp:  2          [OIII]5007_d      200.2      0.25      23    51
# Comp:  2            [OI]6300_d      2.117      0.25      23    51
# Comp:  2           [NII]6583_d      5.105      0.25      23    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:        23        25
#  comp.  2:        21        51
# chi2/DOF: 3.240; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 46; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      60.58      0.18      23    25
# Comp:  1                Halpha      81.45      0.18      23    25
# Comp:  2             [SII]6716      7.230      0.20      21    51
# Comp:  2             [SII]6731      4.843      0.20      21    51
# Comp:  2              HeII4687    0.04246      0.20      21    51
# Comp:  2               HeI5876      3.818      0.20      21    51
# Comp:  2          [OIII]5007_d      202.3      0.25      21    51
# Comp:  2            [OI]6300_d      2.164      0.25      21    51
# Comp:  2           [NII]6583_d      5.112      0.25      21    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63         1
#  comp.  1:        21        20
#  comp.  2:        21        48
# chi2/DOF: 3.472; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.98      0.18      21    20
# Comp:  1                Halpha      83.85      0.18      21    20
# Comp:  2             [SII]6716      8.717      0.19      21    48
# Comp:  2             [SII]6731      5.355      0.19      21    48
# Comp:  2              HeII4687     0.2217      0.19      21    48
# Comp:  2               HeI5876      3.222      0.19      21    48
# Comp:  2          [OIII]5007_d      195.5      0.24      21    48
# Comp:  2            [OI]6300_d      2.040      0.24      21    48
# Comp:  2           [NII]6583_d      4.612      0.24      21    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -105        32
#  comp.  1:        12        23
#  comp.  2:        22        53
# chi2/DOF: 2.877; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      64.77      0.18      12    23
# Comp:  1                Halpha      82.55      0.18      12    23
# Comp:  2             [SII]6716      6.774      0.20      22    53
# Comp:  2             [SII]6731      5.439      0.20      22    53
# Comp:  2              HeII4687     0.5424      0.20      22    53
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      63.07      0.19      10    37
# Comp:  1                Halpha      90.79      0.19      10    37
# Comp:  2             [SII]6716      6.432      0.19      19    46
# Comp:  2             [SII]6731      5.567      0.19      19    46
# Comp:  2              HeII4687     0.3455      0.19      19    46
# Comp:  2               HeI5876      3.727      0.19      19    46
# Comp:  2          [OIII]5007_d      195.2      0.24      19    46
# Comp:  2            [OI]6300_d      1.872      0.24      19    46
# Comp:  2           [NII]6583_d      4.730      0.24      19    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84        74
#  comp.  1:        10        19
#  comp.  2:        20        51
# chi2/DOF: 3.343; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.91      0.18      10    19
# Comp:  1                Halpha      82.06      0.18      10    19
# Comp:  2             [SII]6716      7.403      0.20      20    51
# Comp:  2             [SII]6731      5.711      0.20      20    51
# Comp:  2              HeII4687     0.6240      0.20      20    51
# Comp:  2               HeI5876      3.686      0.20      20    51
# Comp:  2          [OIII]5007_d      196.2      0.25      20    51
# Comp:  2            [OI]6300_d      2.179      0.25      20    51
# Comp:  2           [NII]6583_d      5.131      0.25      20    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14         1
#  comp.  1:        20         1
#  comp.  2:        22        51
# chi2/DOF: 3.348; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      56.64      0.17      20     1
# Comp:  1                Halpha      74.91      0.17      20     1
# Comp:  2             [SII]6716      7.787      0.20      22    51
# Comp:  2             [SII]6731      6.257      0.20      22    51
# Comp:  2              HeII4687     0.4163      0.20      22    51
# Comp:  2               HeI5876      3.734      0.20      22    51
# Comp:  2          [OIII]5007_d      202.2      0.25      22    51
# Comp:  2            [OI]6300_d      2.019      0.25      22    51
# Comp:  2           [NII]6583_d      5.989      0.25      22    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -112        65
#  comp.  1:        16        15
#  comp.  2:        21        50
# chi2/DOF: 3.847; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.07      0.18      16    15
# Comp:  1                Halpha      78.89      0.18      16    15
# Comp:  2             [SII]6716      8.989      0.20      21    50
# Comp:  2             [SII]6731      5.909      0.20      21    50
# Comp:  2              HeII4687    0.07304      0.20      21    50
# Comp:  2               HeI5876      3.704      0.20      21    50
# Comp:  2          [OIII]5007_d      201.5      0.25      21    50
# Comp:  2            [OI]6300_d      1.799      0.25      21    50
# Comp:  2           [NII]6583_d      4.997      0.25      21    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:        16         1
#  comp.  2:        17        43
# chi2/DOF: 2.850; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      56.46      0.17      16     1
# Comp:  1                Halpha      80.76      0.17      16     1
# Comp:  2             [SII]6716      7.173      0.19      17    43
# Comp:  2             [SII]6731      6.355      0.19      17    43
# Comp:  2              HeII4687     0.1828      0.19      17    43
# Comp:  2               HeI5876      3.737      0.19      17    43
# Comp:  2          [OIII]5007_d      191.4      0.24      17    43
# Comp:  2            [OI]6300_d      1.880      0.24      17    43
# Comp:  2           [NII]6583_d      5.472      0.24      17    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:        24         1
#  comp.  2:        18        45
# chi2/DOF: 2.322; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.12      0.17      24     1
# Comp:  1                Halpha      75.44      0.17      24     1
# Comp:  2             [SII]6716      6.045      0.19      18    45
# Comp:  2             [SII]6731      5.209      0.19      18    45
# Comp:  2              HeII4687     0.4445      0.19      18    45
# Comp:  2               HeI5876      3.797      0.19      18    45
# Comp:  2          [OIII]5007_d      193.9      0.24      18    45
# Comp:  2            [OI]6300_d      1.894      0.24      18    45
# Comp:  2           [NII]6583_d      5.253      0.24      18    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        99
#  comp.  1:        13        37
#  comp.  2:        20        45
# chi2/DOF: 2.324; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      67.61      0.19      13    37
# Comp:  1                Halpha      90.85      0.19      13    37
# Comp:  2             [SII]6716      7.629      0.19      20    45
# Comp:  2             [SII]6731      4.726      0.19      20    45
# Comp:  2              HeII4687     0.4045      0.19      20    45
# Comp:  2               HeI5876      3.549      0.19      20    45
# Comp:  2          [OIII]5007_d      192.0      0.24      20    45
# Comp:  2            [OI]6300_d      1.900      0.24      20    45
# Comp:  2           [NII]6583_d      5.950      0.24      20    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51         1
#  comp.  1:        17        33
#  comp.  2:        23        52
# chi2/DOF: 3.575; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      61.53      0.18      17    33
# Comp:  1                Halpha      87.72      0.18      17    33
# Comp:  2             [SII]6716      6.646      0.20      23    52
# Comp:  2             [SII]6731      5.683      0.20      23    52
# Comp:  2              HeII4687     0.3539      0.20      23    52
# Comp:  2               HeI5876      3.737      0.20      23    52
# Comp:  2          [OIII]5007_d      199.7      0.25      23    52
# Comp:  2            [OI]6300_d      2.003      0.25      23    52
# Comp:  2           [NII]6583_d      4.770      0.25      23    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -117         1
#  comp.  1:        16        30
#  comp.  2:        22        54
# chi2/DOF: 3.418; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      59.77      0.18      16    30
# Comp:  1                Halpha      78.50      0.18      16    30
# Comp:  2             [SII]6716      7.713      0.20      22    54
# Comp:  2             [SII]6731      4.935      0.20      22    54
# Comp:  2              HeII4687     0.3263      0.20      22    54
# Comp:  2               HeI5876      3.126      0.20      22    54
# Comp:  2          [OIII]5007_d      204.4      0.25      22    54
# Comp:  2            [OI]6300_d      1.957      0.25      22    54
# Comp:  2           [NII]6583_d      5.060      0.25      22    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
#  comp.  1:        23         1
#  comp.  2:        19        48
# chi2/DOF: 2.787; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      56.66      0.17      23     1
# Comp:  1                Halpha      77.48      0.17      23     1
# Comp:  2             [SII]6716      8.773      0.19      19    48
# Comp:  2             [SII]6731      5.541      0.19      19    48
# Comp:  2              HeII4687    0.08455      0.19      19    48
# Comp:  2               HeI5876      3.383      0.19      19    48
# Comp:  2          [OIII]5007_d      194.8      0.25      19    48
# Comp:  2            [OI]6300_d      1.982      0.25      19    48
# Comp:  2           [NII]6583_d      5.397      0.25      19    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        61
#  comp.  1:        14        20
#  comp.  2:        18        45
# chi2/DOF: 3.487; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.83      0.18      14    20
# Comp:  1                Halpha      78.42      0.18      14    20
# Comp:  2             [SII]6716      7.068      0.19      18    45
# Comp:  2             [SII]6731      4.288      0.19      18    45
# Comp:  2              HeII4687    0.06710      0.19      18    45
# Comp:  2               HeI5876      3.445      0.19      18    45
# Comp:  2          [OIII]5007_d      193.3      0.24      18    45
# Comp:  2            [OI]6300_d      1.972      0.24      18    45
# Comp:  2           [NII]6583_d      4.931      0.24      18    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -120        47
#  comp.  1:         9        21
#  comp.  2:        24        55
# chi2/DOF: 2.598; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.57      0.18       9    21
# Comp:  1                Halpha      82.00      0.18       9    21
# Comp:  2             [SII]6716      8.996      0.20      24    55
# Comp:  2             [SII]6731      6.073      0.20      24    55
# Comp:  2              HeII4687     0.1773      0.20      24    55
# Comp:  2               HeI5876      3.524      0.20      24    55
# Comp:  2          [OIII]5007_d      205.6      0.25      24    55
# Comp:  2            [OI]6300_d      2.252      0.25      24    55
# Comp:  2           [NII]6583_d      5.755      0.25      24    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:        19        24
#  comp.  2:        22        51
# chi2/DOF: 3.163; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      53.22      0.18      19    24
# Comp:  1                Halpha      79.02      0.18      19    24
# Comp:  2             [SII]6716      7.736      0.20      22    51
# Comp:  2             [SII]6731      4.446      0.20      22    51
# Comp:  2              HeII4687     0.7128      0.20      22    51
# Comp:  2               HeI5876      3.571      0.20      22    51
# Comp:  2          [OIII]5007_d      200.7      0.25      22    51
# Comp:  2            [OI]6300_d      1.944      0.25      22    51
# Comp:  2           [NII]6583_d      5.175      0.25      22    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54       310
#  comp.  1:        15         3
#  comp.  2:        20        48
# chi2/DOF: 3.108; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      61.38      0.17      15     3
# Comp:  1                Halpha      75.84      0.17      15     3
# Comp:  2             [SII]6716      6.466      0.19      20    48
# Comp:  2             [SII]6731      6.065      0.19      20    48
# Comp:  2              HeII4687     0.3152      0.19      20    48
# Comp:  2               HeI5876      3.521      0.19      20    48
# Comp:  2          [OIII]5007_d      197.1      0.24      20    48
# Comp:  2            [OI]6300_d      1.871      0.24      20    48
# Comp:  2           [NII]6583_d      5.344      0.24      20    48
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([5.10960465, 5.47624144, 1.24426776, 0.79087074, 0.19298902,
#        0.26230093, 3.72740641, 0.17336339, 0.59675477])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 59.73007531, 112.02261247,  10.83634012,   7.70282449,
#          0.32087801,   4.37569137, 207.00095192,   2.59158522,
#          6.93287731])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum3s_3_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum3s_3_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum3s_3_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum3s_3_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum3s_3_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0         Hbeta  14.640507    1.252421
# 1        Halpha  27.457991    1.342288
# 2     [SII]6716   2.656108    0.304984
# 3     [SII]6731   1.888048    0.193851
# 4      HeII4687   0.078651    0.047304
# 5       HeI5876   1.072531    0.064293
# 6  [OIII]5007_d  50.738240    0.913629
# 7    [OI]6300_d   0.635226    0.042493
# 8   [NII]6583_d   1.699325    0.146271
#           Name       Flux  Error_flux
# 0        Hbeta  14.640507    1.252421
# 1       Halpha  27.457991    1.342288
# 2    [SII]6716   2.656108    0.304984
# 3    [SII]6731   1.888048    0.193851
# 4     HeII4687   0.078651    0.047304
# 5      HeI5876   1.072531    0.064293
# 6   [OIII]4959  12.684560    0.913629
# 7   [OIII]5007  38.053680    0.913629
# 8     [OI]6300   0.476420    0.042493
# 9     [OI]6364   0.158807    0.042493
# 10   [NII]6548   0.424831    0.146271
# 11   [NII]6583   1.274494    0.146271

# %%
np.median(flux_rf_rebin)
# Out:
# 0.24511114330880235
