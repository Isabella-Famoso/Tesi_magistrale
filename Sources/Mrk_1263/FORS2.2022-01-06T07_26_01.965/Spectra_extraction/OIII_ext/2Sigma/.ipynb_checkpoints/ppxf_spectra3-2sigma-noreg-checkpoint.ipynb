# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_3.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_1263/FORS2.2022-01-06T07_26_01.965/Spectra_extraction/redshift.txt")  
z = red[2][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.00423

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.2172112  2.21794808 2.21868496 ... 3.53181044 3.53254732 3.53328421]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        20         1
# chi2/DOF: 0.005010; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:        31         1
# chi2/DOF: 0.003498; DOF: 1894; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150

# %%
pp_stars.sol

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")

# %%
dlam

# %%
line_wave

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -114         9
#  comp.  1:        11        15
#  comp.  2:        18        52
# chi2/DOF: 2.976; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      73.01      0.19      11    15
# Comp:  1                Halpha      84.83      0.19      11    15
# Comp:  2             [SII]6716      7.087      0.21      18    52
# Comp:  2             [SII]6731      5.558      0.21      18    52
# Comp:  2              HeII4687     0.4761      0.21      18    52
# Comp:  2               HeI5876      3.354      0.21      18    52
# Comp:  2          [OIII]5007_d      199.7      0.27      18    52
# Comp:  2            [OI]6300_d      2.086      0.27      18    52
# Comp:  2           [NII]6583_d      5.293      0.27      18    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28       110
#  comp.  1:        16         3
#  comp.  2:        17        52
# chi2/DOF: 4.035; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      63.92      0.19      16     3
# Comp:  1                Halpha      78.09      0.19      16     3
# Comp:  2             [SII]6716      9.603      0.21      17    52
# Comp:  2             [SII]6731      6.164      0.21      17    52
# Comp:  2              HeII4687     0.5633      0.21      17    52
# Comp:  2               HeI5876      3.353      0.21      17    52
# Comp:  2          [OIII]5007_d      201.5      0.27      17    52
# Comp:  2            [OI]6300_d      2.080      0.27      17    52
# Comp:  2           [NII]6583_d      5.585      0.27      17    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
#  comp.  1:        16        29
#  comp.  2:        17        46
# chi2/DOF: 3.146; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      61.98      0.20      16    29
# Comp:  1                Halpha      93.35      0.20      16    29
# Comp:  2             [SII]6716      8.970      0.21      17    46
# Comp:  2             [SII]6731      6.092      0.21      17    46
# Comp:  2              HeII4687     0.5773      0.21      17    46
# Comp:  2               HeI5876      3.623      0.21      17    46
# Comp:  2          [OIII]5007_d      195.6      0.26      17    46
# Comp:  2            [OI]6300_d      1.748      0.26      17    46
# Comp:  2           [NII]6583_d      4.420      0.26      17    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -90        93
#  comp.  1:        19        12
#  comp.  2:        17        51
# chi2/DOF: 3.214; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      72.61      0.19      19    12
# Comp:  1                Halpha      78.70      0.19      19    12
# Comp:  2             [SII]6716      6.639      0.21      17    51
# Comp:  2             [SII]6731      5.053      0.21      17    51
# Comp:  2              HeII4687      0.000      0.21      17    51
# Comp:  2               HeI5876      3.257      0.21      17    51
# Comp:  2          [OIII]5007_d      200.3      0.27      17    51
# Comp:  2            [OI]6300_d      1.761      0.27      17    51
# Comp:  2           [NII]6583_d      5.192      0.27      17    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32         1
#  comp.  1:        18        16
#  comp.  2:        18        50
# chi2/DOF: 3.967; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.85      0.19      18    16
# Comp:  1                Halpha      89.29      0.19      18    16
# Comp:  2             [SII]6716      9.043      0.21      18    50
# Comp:  2             [SII]6731      6.111      0.21      18    50
# Comp:  2              HeII4687     0.1191      0.21      18    50
# Comp:  2               HeI5876      3.630      0.21      18    50
# Comp:  2          [OIII]5007_d      199.0      0.27      18    50
# Comp:  2            [OI]6300_d      1.883      0.27      18    50
# Comp:  2           [NII]6583_d      4.266      0.27      18    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97         3
#  comp.  1:        17         1
#  comp.  2:        18        53
# chi2/DOF: 3.429; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      70.04      0.19      17     1
# Comp:  1                Halpha      78.18      0.19      17     1
# Comp:  2             [SII]6716      7.004      0.21      18    53
# Comp:  2             [SII]6731      6.057      0.21      18    53
# Comp:  2              HeII4687     0.6935      0.21      18    53
# Comp:  2               HeI5876      3.241      0.21      18    53
# Comp:  2          [OIII]5007_d      200.1      0.27      18    53
# Comp:  2            [OI]6300_d      2.119      0.27      18    53
# Comp:  2           [NII]6583_d      4.807      0.27      18    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:         8        25
#  comp.  2:        19        54
# chi2/DOF: 2.240; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      76.43      0.19       8    25
# Comp:  1                Halpha      88.96      0.19       8    25
# Comp:  2             [SII]6716      7.535      0.21      19    54
# Comp:  2             [SII]6731      5.742      0.21      19    54
# Comp:  2              HeII4687     0.1495      0.21      19    54
# Comp:  2               HeI5876      3.587      0.21      19    54
# Comp:  2          [OIII]5007_d      200.9      0.27      19    54
# Comp:  2            [OI]6300_d      1.945      0.27      19    54
# Comp:  2           [NII]6583_d      4.631      0.27      19    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:        16        32
#  comp.  2:        18        51
# chi2/DOF: 3.310; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      64.11      0.20      16    32
# Comp:  1                Halpha      91.65      0.20      16    32
# Comp:  2             [SII]6716      7.641      0.21      18    51
# Comp:  2             [SII]6731      6.198      0.21      18    51
# Comp:  2              HeII4687      0.000      0.21      18    51
# Comp:  2               HeI5876      3.754      0.21      18    51
# Comp:  2          [OIII]5007_d      201.3      0.27      18    51
# Comp:  2            [OI]6300_d      1.942      0.27      18    51
# Comp:  2           [NII]6583_d      6.135      0.27      18    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        73
#  comp.  1:         7        30
#  comp.  2:        18        53
# chi2/DOF: 2.481; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 68; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      71.84      0.20       7    30
# Comp:  1                Halpha      89.74      0.20       7    30
# Comp:  2             [SII]6716      6.599      0.21      18    53
# Comp:  2             [SII]6731      5.966      0.21      18    53
# Comp:  2              HeII4687     0.1406      0.21      18    53
# Comp:  2               HeI5876      3.885      0.21      18    53
# Comp:  2          [OIII]5007_d      199.2      0.27      18    53
# Comp:  2            [OI]6300_d      2.208      0.27      18    53
# Comp:  2           [NII]6583_d      5.254      0.27      18    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71        78
#  comp.  1:        21        16
#  comp.  2:        15        47
# chi2/DOF: 3.281; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      72.98      0.19      21    16
# Comp:  1                Halpha      83.46      0.19      21    16
# Comp:  2             [SII]6716      7.500      0.21      15    47
# Comp:  2             [SII]6731      6.107      0.21      15    47
# Comp:  2              HeII4687     0.1835      0.21      15    47
# Comp:  2               HeI5876      3.101      0.21      15    47
# Comp:  2          [OIII]5007_d      194.9      0.26      15    47
# Comp:  2            [OI]6300_d      2.039      0.26      15    47
# Comp:  2           [NII]6583_d      4.415      0.26      15    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:        13        27
#  comp.  2:        18        49
# chi2/DOF: 3.434; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      61.40      0.20      13    27
# Comp:  1                Halpha      87.22      0.20      13    27
# Comp:  2             [SII]6716      6.809      0.21      18    49
# Comp:  2             [SII]6731      5.534      0.21      18    49
# Comp:  2              HeII4687     0.3395      0.21      18    49
# Comp:  2               HeI5876      3.849      0.21      18    49
# Comp:  2          [OIII]5007_d      199.7      0.26      18    49
# Comp:  2            [OI]6300_d      1.980      0.26      18    49
# Comp:  2           [NII]6583_d      6.123      0.26      18    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -103        68
#  comp.  1:         7        30
#  comp.  2:        16        45
# chi2/DOF: 2.233; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 95; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      68.32      0.20       7    30
# Comp:  1                Halpha      92.00      0.20       7    30
# Comp:  2             [SII]6716      8.333      0.21      16    45
# Comp:  2             [SII]6731      4.621      0.21      16    45
# Comp:  2              HeII4687     0.1189      0.21      16    45
# Comp:  2               HeI5876      3.084      0.21      16    45
# Comp:  2          [OIII]5007_d      194.9      0.26      16    45
# Comp:  2            [OI]6300_d      1.963      0.26      16    45
# Comp:  2           [NII]6583_d      5.063      0.26      16    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73         1
#  comp.  1:         9        39
#  comp.  2:        19        50
# chi2/DOF: 1.908; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 61; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      81.34      0.20       9    39
# Comp:  1                Halpha      90.81      0.20       9    39
# Comp:  2             [SII]6716      8.758      0.21      19    50
# Comp:  2             [SII]6731      5.790      0.21      19    50
# Comp:  2              HeII4687      0.000      0.21      19    50
# Comp:  2               HeI5876      3.634      0.21      19    50
# Comp:  2          [OIII]5007_d      196.9      0.27      19    50
# Comp:  2            [OI]6300_d      1.996      0.27      19    50
# Comp:  2           [NII]6583_d      5.620      0.27      19    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54       105
#  comp.  1:        16         2
#  comp.  2:        19        51
# chi2/DOF: 4.060; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      63.72      0.19      16     2
# Comp:  1                Halpha      77.87      0.19      16     2
# Comp:  2             [SII]6716      7.590      0.21      19    51
# Comp:  2             [SII]6731      6.017      0.21      19    51
# Comp:  2              HeII4687      0.000      0.21      19    51
# Comp:  2               HeI5876      3.185      0.21      19    51
# Comp:  2          [OIII]5007_d      200.2      0.27      19    51
# Comp:  2            [OI]6300_d      2.194      0.27      19    51
# Comp:  2           [NII]6583_d      5.240      0.27      19    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24         1
#  comp.  1:        20         1
#  comp.  2:        14        44
# chi2/DOF: 3.061; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.43      0.19      20     1
# Comp:  1                Halpha      80.69      0.19      20     1
# Comp:  2             [SII]6716      6.318      0.21      14    44
# Comp:  2             [SII]6731      5.564      0.21      14    44
# Comp:  2              HeII4687      0.000      0.21      14    44
# Comp:  2               HeI5876      3.486      0.21      14    44
# Comp:  2          [OIII]5007_d      191.4      0.26      14    44
# Comp:  2            [OI]6300_d      2.138      0.26      14    44
# Comp:  2           [NII]6583_d      5.593      0.26      14    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17       105
#  comp.  1:        13        37
#  comp.  2:        18        49
# chi2/DOF: 2.061; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      78.28      0.20      13    37
# Comp:  1                Halpha      95.62      0.20      13    37
# Comp:  2             [SII]6716      8.449      0.21      18    49
# Comp:  2             [SII]6731      5.889      0.21      18    49
# Comp:  2              HeII4687     0.2144      0.21      18    49
# Comp:  2               HeI5876      3.465      0.21      18    49
# Comp:  2          [OIII]5007_d      199.4      0.27      18    49
# Comp:  2            [OI]6300_d      1.711      0.27      18    49
# Comp:  2           [NII]6583_d      6.020      0.27      18    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:        22         1
#  comp.  2:        16        47
# chi2/DOF: 2.813; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      67.15      0.19      22     1
# Comp:  1                Halpha      79.59      0.19      22     1
# Comp:  2             [SII]6716      6.979      0.21      16    47
# Comp:  2             [SII]6731      5.459      0.21      16    47
# Comp:  2              HeII4687     0.2047      0.21      16    47
# Comp:  2               HeI5876      3.597      0.21      16    47
# Comp:  2          [OIII]5007_d      191.6      0.26      16    47
# Comp:  2            [OI]6300_d      1.907      0.26      16    47
# Comp:  2           [NII]6583_d      5.014      0.26      16    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:        17         1
#  comp.  2:        17        51
# chi2/DOF: 3.535; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      70.07      0.19      17     1
# Comp:  1                Halpha      77.97      0.19      17     1
# Comp:  2             [SII]6716      8.029      0.21      17    51
# Comp:  2             [SII]6731      5.277      0.21      17    51
# Comp:  2              HeII4687     0.1368      0.21      17    51
# Comp:  2               HeI5876      3.405      0.21      17    51
# Comp:  2          [OIII]5007_d      196.9      0.27      17    51
# Comp:  2            [OI]6300_d      2.085      0.27      17    51
# Comp:  2           [NII]6583_d      5.533      0.27      17    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16         1
#  comp.  1:        23        13
#  comp.  2:        15        45
# chi2/DOF: 2.945; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 45; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.37      0.19      23    13
# Comp:  1                Halpha      84.37      0.19      23    13
# Comp:  2             [SII]6716      8.930      0.21      15    45
# Comp:  2             [SII]6731      4.931      0.21      15    45
# Comp:  2              HeII4687     0.2484      0.21      15    45
# Comp:  2               HeI5876      3.814      0.21      15    45
# Comp:  2          [OIII]5007_d      192.7      0.26      15    45
# Comp:  2            [OI]6300_d      1.686      0.26      15    45
# Comp:  2           [NII]6583_d      4.902      0.26      15    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
#  comp.  1:        20         7
#  comp.  2:        17        51
# chi2/DOF: 4.080; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      64.96      0.19      20     7
# Comp:  1                Halpha      85.10      0.19      20     7
# Comp:  2             [SII]6716      7.692      0.21      17    51
# Comp:  2             [SII]6731      5.241      0.21      17    51
# Comp:  2              HeII4687     0.5918      0.21      17    51
# Comp:  2               HeI5876      3.712      0.21      17    51
# Comp:  2          [OIII]5007_d      198.2      0.27      17    51
# Comp:  2            [OI]6300_d      1.869      0.27      17    51
# Comp:  2           [NII]6583_d      5.287      0.27      17    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:        24         1
#  comp.  2:        17        52
# chi2/DOF: 2.519; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      65.76      0.19      24     1
# Comp:  1                Halpha      75.91      0.19      24     1
# Comp:  2             [SII]6716      8.700      0.21      17    52
# Comp:  2             [SII]6731      5.170      0.21      17    52
# Comp:  2              HeII4687     0.5223      0.21      17    52
# Comp:  2               HeI5876      3.421      0.21      17    52
# Comp:  2          [OIII]5007_d      198.6      0.27      17    52
# Comp:  2            [OI]6300_d      1.757      0.27      17    52
# Comp:  2           [NII]6583_d      4.824      0.27      17    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -124         1
#  comp.  1:         8        23
#  comp.  2:        18        48
# chi2/DOF: 3.363; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      68.39      0.19       8    23
# Comp:  1                Halpha      83.91      0.19       8    23
# Comp:  2             [SII]6716      8.368      0.21      18    48
# Comp:  2             [SII]6731      5.093      0.21      18    48
# Comp:  2              HeII4687     0.5318      0.21      18    48
# Comp:  2               HeI5876      3.282      0.21      18    48
# Comp:  2          [OIII]5007_d      195.5      0.26      18    48
# Comp:  2            [OI]6300_d      2.000      0.26      18    48
# Comp:  2           [NII]6583_d      4.911      0.26      18    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42         1
#  comp.  1:        14        22
#  comp.  2:        17        50
# chi2/DOF: 3.334; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      60.13      0.19      14    22
# Comp:  1                Halpha      87.92      0.19      14    22
# Comp:  2             [SII]6716      7.960      0.21      17    50
# Comp:  2             [SII]6731      5.455      0.21      17    50
# Comp:  2              HeII4687     0.3168      0.21      17    50
# Comp:  2               HeI5876      3.467      0.21      17    50
# Comp:  2          [OIII]5007_d      198.0      0.27      17    50
# Comp:  2            [OI]6300_d      2.061      0.27      17    50
# Comp:  2           [NII]6583_d      4.883      0.27      17    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32       113
#  comp.  1:        14        17
#  comp.  2:        17        47
# chi2/DOF: 3.467; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      73.66      0.19      14    17
# Comp:  1                Halpha      81.07      0.19      14    17
# Comp:  2             [SII]6716      7.196      0.21      17    47
# Comp:  2             [SII]6731      5.398      0.21      17    47
# Comp:  2              HeII4687      0.000      0.21      17    47
# Comp:  2               HeI5876      3.364      0.21      17    47
# Comp:  2          [OIII]5007_d      192.6      0.26      17    47
# Comp:  2            [OI]6300_d      1.840      0.26      17    47
# Comp:  2           [NII]6583_d      5.786      0.26      17    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        23       115
#  comp.  1:        16        36
#  comp.  2:        16        47
# chi2/DOF: 3.737; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 73; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      70.91      0.20      16    36
# Comp:  1                Halpha      86.13      0.20      16    36
# Comp:  2             [SII]6716      9.358      0.21      16    47
# Comp:  2             [SII]6731      5.795      0.21      16    47
# Comp:  2              HeII4687      0.000      0.21      16    47
# Comp:  2               HeI5876      3.658      0.21      16    47
# Comp:  2          [OIII]5007_d      194.2      0.26      16    47
# Comp:  2            [OI]6300_d      1.910      0.26      16    47
# Comp:  2           [NII]6583_d      4.638      0.26      16    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:        13        30
#  comp.  2:        16        50
# chi2/DOF: 3.262; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      60.25      0.20      13    30
# Comp:  1                Halpha      87.84      0.20      13    30
# Comp:  2             [SII]6716      7.924      0.21      16    50
# Comp:  2             [SII]6731      5.656      0.21      16    50
# Comp:  2              HeII4687      0.000      0.21      16    50
# Comp:  2               HeI5876      3.149      0.21      16    50
# Comp:  2          [OIII]5007_d      198.0      0.27      16    50
# Comp:  2            [OI]6300_d      1.779      0.27      16    50
# Comp:  2           [NII]6583_d      5.149      0.27      16    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:        19         1
#  comp.  2:        17        46
# chi2/DOF: 2.776; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.71      0.19      19     1
# Comp:  1                Halpha      79.10      0.19      19     1
# Comp:  2             [SII]6716      8.007      0.21      17    46
# Comp:  2             [SII]6731      4.694      0.21      17    46
# Comp:  2              HeII4687      0.000      0.21      17    46
# Comp:  2               HeI5876      3.498      0.21      17    46
# Comp:  2          [OIII]5007_d      197.3      0.26      17    46
# Comp:  2            [OI]6300_d      2.012      0.26      17    46
# Comp:  2           [NII]6583_d      5.261      0.26      17    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:        24         1
#  comp.  2:        15        50
# chi2/DOF: 2.698; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.16      0.19      24     1
# Comp:  1                Halpha      79.34      0.19      24     1
# Comp:  2             [SII]6716      8.410      0.21      15    50
# Comp:  2             [SII]6731      5.040      0.21      15    50
# Comp:  2              HeII4687      0.000      0.21      15    50
# Comp:  2               HeI5876      3.520      0.21      15    50
# Comp:  2          [OIII]5007_d      194.1      0.27      15    50
# Comp:  2            [OI]6300_d      2.177      0.27      15    50
# Comp:  2           [NII]6583_d      5.783      0.27      15    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:        16         1
#  comp.  2:        17        51
# chi2/DOF: 3.673; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.83      0.19      16     1
# Comp:  1                Halpha      85.17      0.19      16     1
# Comp:  2             [SII]6716      8.147      0.21      17    51
# Comp:  2             [SII]6731      5.708      0.21      17    51
# Comp:  2              HeII4687      0.000      0.21      17    51
# Comp:  2               HeI5876      3.555      0.21      17    51
# Comp:  2          [OIII]5007_d      196.4      0.27      17    51
# Comp:  2            [OI]6300_d      1.876      0.27      17    51
# Comp:  2           [NII]6583_d      5.129      0.27      17    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -116         1
#  comp.  1:         8        17
#  comp.  2:        15        48
# chi2/DOF: 3.233; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.79      0.19       8    17
# Comp:  1                Halpha      85.78      0.19       8    17
# Comp:  2             [SII]6716      8.436      0.21      15    48
# Comp:  2             [SII]6731      6.559      0.21      15    48
# Comp:  2              HeII4687     0.3842      0.21      15    48
# Comp:  2               HeI5876      3.522      0.21      15    48
# Comp:  2          [OIII]5007_d      195.8      0.26      15    48
# Comp:  2            [OI]6300_d      2.104      0.26      15    48
# Comp:  2           [NII]6583_d      5.715      0.26      15    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63       150
#  comp.  1:        19         1
#  comp.  2:        17        50
# chi2/DOF: 3.712; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      70.43      0.19      19     1
# Comp:  1                Halpha      81.42      0.19      19     1
# Comp:  2             [SII]6716      8.103      0.21      17    50
# Comp:  2             [SII]6731      5.556      0.21      17    50
# Comp:  2              HeII4687    0.03835      0.21      17    50
# Comp:  2               HeI5876      3.523      0.21      17    50
# Comp:  2          [OIII]5007_d      200.2      0.27      17    50
# Comp:  2            [OI]6300_d      1.991      0.27      17    50
# Comp:  2           [NII]6583_d      5.478      0.27      17    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
#  comp.  1:        20        31
#  comp.  2:        17        49
# chi2/DOF: 3.746; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      71.58      0.20      20    31
# Comp:  1                Halpha      91.40      0.20      20    31
# Comp:  2             [SII]6716      6.916      0.21      17    49
# Comp:  2             [SII]6731      6.082      0.21      17    49
# Comp:  2              HeII4687      0.000      0.21      17    49
# Comp:  2               HeI5876      4.047      0.21      17    49
# Comp:  2          [OIII]5007_d      197.0      0.26      17    49
# Comp:  2            [OI]6300_d      1.626      0.26      17    49
# Comp:  2           [NII]6583_d      4.768      0.26      17    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:        19         1
#  comp.  2:        18        53
# chi2/DOF: 3.946; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.18      0.19      19     1
# Comp:  1                Halpha      85.19      0.19      19     1
# Comp:  2             [SII]6716      7.684      0.21      18    53
# Comp:  2             [SII]6731      5.653      0.21      18    53
# Comp:  2              HeII4687     0.6471      0.21      18    53
# Comp:  2               HeI5876      3.469      0.21      18    53
# Comp:  2          [OIII]5007_d      202.2      0.27      18    53
# Comp:  2            [OI]6300_d      1.890      0.27      18    53
# Comp:  2           [NII]6583_d      5.083      0.27      18    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:        16         1
#  comp.  2:        16        49
# chi2/DOF: 3.460; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      59.18      0.19      16     1
# Comp:  1                Halpha      84.08      0.19      16     1
# Comp:  2             [SII]6716      7.624      0.21      16    49
# Comp:  2             [SII]6731      5.504      0.21      16    49
# Comp:  2              HeII4687     0.2464      0.21      16    49
# Comp:  2               HeI5876      3.242      0.21      16    49
# Comp:  2          [OIII]5007_d      193.4      0.26      16    49
# Comp:  2            [OI]6300_d      1.780      0.26      16    49
# Comp:  2           [NII]6583_d      5.968      0.26      16    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21         1
#  comp.  1:        20         1
#  comp.  2:        16        50
# chi2/DOF: 3.167; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.75      0.19      20     1
# Comp:  1                Halpha      82.87      0.19      20     1
# Comp:  2             [SII]6716      7.341      0.21      16    50
# Comp:  2             [SII]6731      5.428      0.21      16    50
# Comp:  2              HeII4687      0.000      0.21      16    50
# Comp:  2               HeI5876      3.150      0.21      16    50
# Comp:  2          [OIII]5007_d      194.6      0.27      16    50
# Comp:  2            [OI]6300_d      1.758      0.27      16    50
# Comp:  2           [NII]6583_d      5.605      0.27      16    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51       147
#  comp.  1:        11        33
#  comp.  2:        16        48
# chi2/DOF: 3.304; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      70.69      0.20      11    33
# Comp:  1                Halpha      81.79      0.20      11    33
# Comp:  2             [SII]6716      7.884      0.21      16    48
# Comp:  2             [SII]6731      5.854      0.21      16    48
# Comp:  2              HeII4687      0.000      0.21      16    48
# Comp:  2               HeI5876      3.362      0.21      16    48
# Comp:  2          [OIII]5007_d      197.2      0.26      16    48
# Comp:  2            [OI]6300_d      1.966      0.26      16    48
# Comp:  2           [NII]6583_d      5.454      0.26      16    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68         1
#  comp.  1:        16         1
#  comp.  2:        16        51
# chi2/DOF: 3.392; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.38      0.19      16     1
# Comp:  1                Halpha      83.87      0.19      16     1
# Comp:  2             [SII]6716      9.110      0.21      16    51
# Comp:  2             [SII]6731      6.315      0.21      16    51
# Comp:  2              HeII4687    0.01476      0.21      16    51
# Comp:  2               HeI5876      3.307      0.21      16    51
# Comp:  2          [OIII]5007_d      196.0      0.27      16    51
# Comp:  2            [OI]6300_d      2.137      0.27      16    51
# Comp:  2           [NII]6583_d      5.589      0.27      16    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89         1
#  comp.  1:        15         1
#  comp.  2:        17        49
# chi2/DOF: 3.719; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      58.21      0.19      15     1
# Comp:  1                Halpha      80.84      0.19      15     1
# Comp:  2             [SII]6716      9.074      0.21      17    49
# Comp:  2             [SII]6731      5.160      0.21      17    49
# Comp:  2              HeII4687      0.000      0.21      17    49
# Comp:  2               HeI5876      3.040      0.21      17    49
# Comp:  2          [OIII]5007_d      198.6      0.27      17    49
# Comp:  2            [OI]6300_d      1.910      0.27      17    49
# Comp:  2           [NII]6583_d      4.340      0.27      17    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        83
#  comp.  1:         7        28
#  comp.  2:        18        51
# chi2/DOF: 2.154; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      70.86      0.20       7    28
# Comp:  1                Halpha      92.14      0.20       7    28
# Comp:  2             [SII]6716      8.550      0.21      18    51
# Comp:  2             [SII]6731      5.199      0.21      18    51
# Comp:  2              HeII4687     0.1311      0.21      18    51
# Comp:  2               HeI5876      3.204      0.21      18    51
# Comp:  2          [OIII]5007_d      198.8      0.27      18    51
# Comp:  2            [OI]6300_d      2.016      0.27      18    51
# Comp:  2           [NII]6583_d      5.410      0.27      18    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49         1
#  comp.  1:        25         1
#  comp.  2:        15        45
# chi2/DOF: 2.425; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      67.83      0.19      25     1
# Comp:  1                Halpha      80.41      0.19      25     1
# Comp:  2             [SII]6716      9.308      0.21      15    45
# Comp:  2             [SII]6731      5.806      0.21      15    45
# Comp:  2              HeII4687      0.000      0.21      15    45
# Comp:  2               HeI5876      3.552      0.21      15    45
# Comp:  2          [OIII]5007_d      193.3      0.26      15    45
# Comp:  2            [OI]6300_d      1.897      0.26      15    45
# Comp:  2           [NII]6583_d      5.366      0.26      15    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -119         1
#  comp.  1:         5        31
#  comp.  2:        18        51
# chi2/DOF: 2.196; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      69.62      0.20       5    31
# Comp:  1                Halpha      86.87      0.20       5    31
# Comp:  2             [SII]6716      8.703      0.21      18    51
# Comp:  2             [SII]6731      5.925      0.21      18    51
# Comp:  2              HeII4687      0.000      0.21      18    51
# Comp:  2               HeI5876      3.157      0.21      18    51
# Comp:  2          [OIII]5007_d      199.8      0.27      18    51
# Comp:  2            [OI]6300_d      2.005      0.27      18    51
# Comp:  2           [NII]6583_d      5.330      0.27      18    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7         1
#  comp.  1:        23        22
#  comp.  2:        17        52
# chi2/DOF: 3.063; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      59.18      0.19      23    22
# Comp:  1                Halpha      82.66      0.19      23    22
# Comp:  2             [SII]6716      8.107      0.21      17    52
# Comp:  2             [SII]6731      5.072      0.21      17    52
# Comp:  2              HeII4687     0.6066      0.21      17    52
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      72.12      0.20       9    34
# Comp:  1                Halpha      94.76      0.20       9    34
# Comp:  2             [SII]6716      6.780      0.21      16    47
# Comp:  2             [SII]6731      5.784      0.21      16    47
# Comp:  2              HeII4687     0.1681      0.21      16    47
# Comp:  2               HeI5876      3.687      0.21      16    47
# Comp:  2          [OIII]5007_d      194.1      0.26      16    47
# Comp:  2            [OI]6300_d      1.820      0.26      16    47
# Comp:  2           [NII]6583_d      4.896      0.26      16    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -116         1
#  comp.  1:        10        17
#  comp.  2:        16        51
# chi2/DOF: 3.668; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      65.29      0.19      10    17
# Comp:  1                Halpha      84.53      0.19      10    17
# Comp:  2             [SII]6716      7.711      0.21      16    51
# Comp:  2             [SII]6731      5.945      0.21      16    51
# Comp:  2              HeII4687     0.5402      0.21      16    51
# Comp:  2               HeI5876      3.615      0.21      16    51
# Comp:  2          [OIII]5007_d      195.4      0.27      16    51
# Comp:  2            [OI]6300_d      2.126      0.27      16    51
# Comp:  2           [NII]6583_d      5.329      0.27      16    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12         1
#  comp.  1:        21         1
#  comp.  2:        18        50
# chi2/DOF: 3.580; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 45; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      65.90      0.19      21     1
# Comp:  1                Halpha      76.72      0.19      21     1
# Comp:  2             [SII]6716      8.003      0.21      18    50
# Comp:  2             [SII]6731      6.358      0.21      18    50
# Comp:  2              HeII4687     0.1859      0.21      18    50
# Comp:  2               HeI5876      3.635      0.21      18    50
# Comp:  2          [OIII]5007_d      199.1      0.27      18    50
# Comp:  2            [OI]6300_d      1.872      0.27      18    50
# Comp:  2           [NII]6583_d      6.185      0.27      18    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -128         1
#  comp.  1:        16         1
#  comp.  2:        17        51
# chi2/DOF: 4.261; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      63.53      0.19      16     1
# Comp:  1                Halpha      80.70      0.19      16     1
# Comp:  2             [SII]6716      9.203      0.21      17    51
# Comp:  2             [SII]6731      5.981      0.21      17    51
# Comp:  2              HeII4687      0.000      0.21      17    51
# Comp:  2               HeI5876      3.620      0.21      17    51
# Comp:  2          [OIII]5007_d      199.8      0.27      17    51
# Comp:  2            [OI]6300_d      1.743      0.27      17    51
# Comp:  2           [NII]6583_d      5.207      0.27      17    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:        18         1
#  comp.  2:        14        44
# chi2/DOF: 3.613; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      64.61      0.19      18     1
# Comp:  1                Halpha      84.56      0.19      18     1
# Comp:  2             [SII]6716      7.500      0.21      14    44
# Comp:  2             [SII]6731      6.445      0.21      14    44
# Comp:  2              HeII4687      0.000      0.21      14    44
# Comp:  2               HeI5876      3.697      0.21      14    44
# Comp:  2          [OIII]5007_d      190.8      0.26      14    44
# Comp:  2            [OI]6300_d      1.835      0.26      14    44
# Comp:  2           [NII]6583_d      5.708      0.26      14    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42         1
#  comp.  1:        25         1
#  comp.  2:        15        45
# chi2/DOF: 2.355; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.44      0.19      25     1
# Comp:  1                Halpha      76.99      0.19      25     1
# Comp:  2             [SII]6716      6.435      0.21      15    45
# Comp:  2             [SII]6731      5.369      0.21      15    45
# Comp:  2              HeII4687     0.2547      0.21      15    45
# Comp:  2               HeI5876      3.782      0.21      15    45
# Comp:  2          [OIII]5007_d      194.1      0.26      15    45
# Comp:  2            [OI]6300_d      1.918      0.26      15    45
# Comp:  2           [NII]6583_d      5.540      0.26      15    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12       100
#  comp.  1:        12        35
#  comp.  2:        16        46
# chi2/DOF: 2.183; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      76.90      0.20      12    35
# Comp:  1                Halpha      95.01      0.20      12    35
# Comp:  2             [SII]6716      7.895      0.21      16    46
# Comp:  2             [SII]6731      4.935      0.21      16    46
# Comp:  2              HeII4687     0.2144      0.21      16    46
# Comp:  2               HeI5876      3.489      0.21      16    46
# Comp:  2          [OIII]5007_d      191.8      0.26      16    46
# Comp:  2            [OI]6300_d      1.875      0.26      16    46
# Comp:  2           [NII]6583_d      6.131      0.26      16    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42         1
#  comp.  1:        17        25
#  comp.  2:        18        53
# chi2/DOF: 4.077; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 45; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      68.34      0.19      17    25
# Comp:  1                Halpha      89.64      0.19      17    25
# Comp:  2             [SII]6716      6.962      0.21      18    53
# Comp:  2             [SII]6731      5.868      0.21      18    53
# Comp:  2              HeII4687     0.1942      0.21      18    53
# Comp:  2               HeI5876      3.652      0.21      18    53
# Comp:  2          [OIII]5007_d      198.9      0.27      18    53
# Comp:  2            [OI]6300_d      1.871      0.27      18    53
# Comp:  2           [NII]6583_d      4.934      0.27      18    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -111         1
#  comp.  1:        15        22
#  comp.  2:        18        54
# chi2/DOF: 3.770; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.17      0.19      15    22
# Comp:  1                Halpha      78.06      0.19      15    22
# Comp:  2             [SII]6716      8.048      0.21      18    54
# Comp:  2             [SII]6731      5.116      0.21      18    54
# Comp:  2              HeII4687    0.08589      0.21      18    54
# Comp:  2               HeI5876      2.976      0.21      18    54
# Comp:  2          [OIII]5007_d      202.0      0.27      18    54
# Comp:  2            [OI]6300_d      1.853      0.27      18    54
# Comp:  2           [NII]6583_d      5.251      0.27      18    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37         1
#  comp.  1:        24         1
#  comp.  2:        16        48
# chi2/DOF: 2.864; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      65.45      0.19      24     1
# Comp:  1                Halpha      80.26      0.19      24     1
# Comp:  2             [SII]6716      8.977      0.21      16    48
# Comp:  2             [SII]6731      5.669      0.21      16    48
# Comp:  2              HeII4687      0.000      0.21      16    48
# Comp:  2               HeI5876      3.332      0.21      16    48
# Comp:  2          [OIII]5007_d      193.4      0.26      16    48
# Comp:  2            [OI]6300_d      1.970      0.26      16    48
# Comp:  2           [NII]6583_d      5.660      0.26      16    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -101        43
#  comp.  1:        14         8
#  comp.  2:        15        46
# chi2/DOF: 3.960; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      65.23      0.19      14     8
# Comp:  1                Halpha      79.09      0.19      14     8
# Comp:  2             [SII]6716      7.393      0.21      15    46
# Comp:  2             [SII]6731      4.582      0.21      15    46
# Comp:  2              HeII4687      0.000      0.21      15    46
# Comp:  2               HeI5876      3.351      0.21      15    46
# Comp:  2          [OIII]5007_d      192.2      0.26      15    46
# Comp:  2            [OI]6300_d      1.960      0.26      15    46
# Comp:  2           [NII]6583_d      5.133      0.26      15    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -126        19
#  comp.  1:         8        12
#  comp.  2:        19        55
# chi2/DOF: 2.860; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      65.09      0.19       8    12
# Comp:  1                Halpha      84.25      0.19       8    12
# Comp:  2             [SII]6716      9.230      0.21      19    55
# Comp:  2             [SII]6731      6.170      0.21      19    55
# Comp:  2              HeII4687      0.000      0.21      19    55
# Comp:  2               HeI5876      3.381      0.21      19    55
# Comp:  2          [OIII]5007_d      203.2      0.27      19    55
# Comp:  2            [OI]6300_d      2.263      0.27      19    55
# Comp:  2           [NII]6583_d      5.895      0.27      19    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22         1
#  comp.  1:        20        13
#  comp.  2:        17        51
# chi2/DOF: 3.421; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      59.29      0.19      20    13
# Comp:  1                Halpha      78.49      0.19      20    13
# Comp:  2             [SII]6716      8.018      0.21      17    51
# Comp:  2             [SII]6731      4.722      0.21      17    51
# Comp:  2              HeII4687     0.7479      0.21      17    51
# Comp:  2               HeI5876      3.493      0.21      17    51
# Comp:  2          [OIII]5007_d      198.7      0.27      17    51
# Comp:  2            [OI]6300_d      1.755      0.27      17    51
# Comp:  2           [NII]6583_d      5.257      0.27      17    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23       236
#  comp.  1:        16         1
#  comp.  2:        16        49
# chi2/DOF: 3.315; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      71.58      0.19      16     1
# Comp:  1                Halpha      78.34      0.19      16     1
# Comp:  2             [SII]6716      6.877      0.21      16    49
# Comp:  2             [SII]6731      6.179      0.21      16    49
# Comp:  2              HeII4687     0.1082      0.21      16    49
# Comp:  2               HeI5876      3.383      0.21      16    49
# Comp:  2          [OIII]5007_d      196.8      0.27      16    49
# Comp:  2            [OI]6300_d      1.757      0.27      16    49
# Comp:  2           [NII]6583_d      5.609      0.27      16    49
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([5.98925969, 6.32341209, 1.17051401, 0.71337853, 0.22094157,
#        0.29171748, 3.02346744, 0.20791162, 0.58451347])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([6.69990411e+01, 1.14244065e+02, 1.11981119e+01, 7.92901282e+00,
#        1.16978955e-01, 4.27103018e+00, 2.05569808e+02, 2.48055303e+00,
#        7.16556634e+00])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_3_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_3_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_3_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_3_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_3_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0         Hbeta  11.769673    1.052129
# 1        Halpha  20.069172    1.110829
# 2     [SII]6716   1.967164    0.205623
# 3     [SII]6731   1.392884    0.125319
# 4      HeII4687   0.020550    0.038813
# 5       HeI5876   0.750289    0.051246
# 6  [OIII]5007_d  36.112299    0.531130
# 7    [OI]6300_d   0.435757    0.036524
# 8   [NII]6583_d   1.258770    0.102681
#           Name       Flux  Error_flux
# 0        Hbeta  11.769673    1.052129
# 1       Halpha  20.069172    1.110829
# 2    [SII]6716   1.967164    0.205623
# 3    [SII]6731   1.392884    0.125319
# 4     HeII4687   0.020550    0.038813
# 5      HeI5876   0.750289    0.051246
# 6   [OIII]4959   9.028075    0.531130
# 7   [OIII]5007  27.084224    0.531130
# 8     [OI]6300   0.326818    0.036524
# 9     [OI]6364   0.108939    0.036524
# 10   [NII]6548   0.314692    0.102681
# 11   [NII]6583   0.944077    0.102681

# %%
np.median(flux_rf_rebin)
# Out:
# 0.17566927183926104
