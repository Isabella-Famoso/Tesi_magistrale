# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_4.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_1263/FORS2.2022-01-06T07_26_01.965/Spectra_extraction/redshift.txt")   
z = red[3][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_4']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.2165626  2.21729952 2.21803643 ... 3.53195112 3.53268804 3.53342495]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3137, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3137, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3137, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
# C:\Users\ISAFA\anaconda3\Lib\site-packages\capfit\capfit.py:799: RuntimeWarning: invalid value encountered in scalar divide
#   ratio = actred/prered
#  Best Fit:       Vel     sigma
#  comp.  0:        20       180
# chi2/DOF: 0.003446; DOF: 1944; degree = 4; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 5; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 0/150
#  Best Fit:       Vel     sigma
#  comp.  0:        20       180
# chi2/DOF: 0.001261; DOF: 1892; degree = 4; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 5; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 0/150
# [1.71348384 1.71721203 1.72266454 ... 0.55643004 0.88873411 1.01792451]
# [1.76064999 1.759833   1.75901615 ... 0.50787975 0.50756687 0.50725412]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([ 20., 180.])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        12
#  comp.  1:        15        31
#  comp.  2:        11        45
# chi2/DOF: 63.89; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      85.54      0.17      15    31
# Comp:  1                Halpha      208.7      0.17      15    31
# Comp:  2             [SII]6716      9.942      0.18      11    45
# Comp:  2             [SII]6731      6.735      0.18      11    45
# Comp:  2              HeII4687     0.5663      0.18      11    45
# Comp:  2               HeI5876      8.919      0.18      11    45
# Comp:  2          [OIII]5007_d      641.0      0.23      11    45
# Comp:  2            [OI]6300_d      2.115      0.23      11    45
# Comp:  2           [NII]6583_d      6.392      0.23      11    45
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  698.3; gas flux:     87 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:   1667; gas flux:    286 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  75.37; gas flux:     14 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  49.96; gas flux:      9 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  4.408; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  69.68; gas flux:     11 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   3772; gas flux:    669 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  12.05; gas flux:      3 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  35.45; gas flux:      9 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       164         1
#  comp.  1:        14        30
#  comp.  2:        18        56
# chi2/DOF: 36.30; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      90.76      0.17      14    30
# Comp:  1                Halpha      210.3      0.17      14    30
# Comp:  2             [SII]6716      10.88      0.19      18    56
# Comp:  2             [SII]6731      7.012      0.19      18    56
# Comp:  2              HeII4687     0.4401      0.19      18    56
# Comp:  2               HeI5876      8.233      0.19      18    56
# Comp:  2          [OIII]5007_d      686.5      0.24      18    56
# Comp:  2            [OI]6300_d      2.232      0.24      18    56
# Comp:  2           [NII]6583_d      6.803      0.24      18    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        12
#  comp.  1:        15        37
#  comp.  2:        15        42
# chi2/DOF: 51.86; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      95.23      0.18      15    37
# Comp:  1                Halpha      211.6      0.18      15    37
# Comp:  2             [SII]6716      10.05      0.18      15    42
# Comp:  2             [SII]6731      6.714      0.18      15    42
# Comp:  2              HeII4687     0.5053      0.18      15    42
# Comp:  2               HeI5876      9.232      0.18      15    42
# Comp:  2          [OIII]5007_d      609.1      0.23      15    42
# Comp:  2            [OI]6300_d      1.808      0.23      15    42
# Comp:  2           [NII]6583_d      6.622      0.23      15    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -256        20
#  comp.  1:        16        33
#  comp.  2:        22        55
# chi2/DOF: 23.66; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      82.19      0.17      16    33
# Comp:  1                Halpha      208.2      0.17      16    33
# Comp:  2             [SII]6716      9.609      0.19      22    55
# Comp:  2             [SII]6731      6.970      0.19      22    55
# Comp:  2              HeII4687     0.3489      0.19      22    55
# Comp:  2               HeI5876      9.084      0.19      22    55
# Comp:  2          [OIII]5007_d      664.7      0.24      22    55
# Comp:  2            [OI]6300_d      1.627      0.24      22    55
# Comp:  2           [NII]6583_d      6.241      0.24      22    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       137         1
#  comp.  1:        14        32
#  comp.  2:         1        38
# chi2/DOF: 14.52; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      93.39      0.17      14    32
# Comp:  1                Halpha      212.9      0.17      14    32
# Comp:  2             [SII]6716      9.350      0.18       1    38
# Comp:  2             [SII]6731      6.435      0.18       1    38
# Comp:  2              HeII4687     0.3970      0.18       1    38
# Comp:  2               HeI5876      7.943      0.18       1    38
# Comp:  2          [OIII]5007_d      582.4      0.22       1    38
# Comp:  2            [OI]6300_d      2.341      0.22       1    38
# Comp:  2           [NII]6583_d      6.370      0.22       1    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        12
#  comp.  1:        15        29
#  comp.  2:        15        42
# chi2/DOF: 55.51; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      81.78      0.17      15    29
# Comp:  1                Halpha      207.7      0.17      15    29
# Comp:  2             [SII]6716      9.250      0.18      15    42
# Comp:  2             [SII]6731      6.593      0.18      15    42
# Comp:  2              HeII4687     0.3805      0.18      15    42
# Comp:  2               HeI5876      8.720      0.18      15    42
# Comp:  2          [OIII]5007_d      611.9      0.23      15    42
# Comp:  2            [OI]6300_d      1.667      0.23      15    42
# Comp:  2           [NII]6583_d      6.014      0.23      15    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       149         1
#  comp.  1:        13        34
#  comp.  2:        13        54
# chi2/DOF: 30.49; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      94.17      0.17      13    34
# Comp:  1                Halpha      214.1      0.17      13    34
# Comp:  2             [SII]6716      10.02      0.19      13    54
# Comp:  2             [SII]6731      6.581      0.19      13    54
# Comp:  2              HeII4687     0.3634      0.19      13    54
# Comp:  2               HeI5876      9.926      0.19      13    54
# Comp:  2          [OIII]5007_d      605.9      0.24      13    54
# Comp:  2            [OI]6300_d      1.913      0.24      13    54
# Comp:  2           [NII]6583_d      6.979      0.24      13    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -113         1
#  comp.  1:        15        29
#  comp.  2:         7        54
# chi2/DOF: 44.11; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      91.96      0.17      15    29
# Comp:  1                Halpha      205.9      0.17      15    29
# Comp:  2             [SII]6716      10.32      0.19       7    54
# Comp:  2             [SII]6731      6.989      0.19       7    54
# Comp:  2              HeII4687     0.6105      0.19       7    54
# Comp:  2               HeI5876      8.903      0.19       7    54
# Comp:  2          [OIII]5007_d      635.3      0.24       7    54
# Comp:  2            [OI]6300_d      2.696      0.24       7    54
# Comp:  2           [NII]6583_d      6.788      0.24       7    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100         1
#  comp.  1:        13        31
#  comp.  2:         4        42
# chi2/DOF: 17.86; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      89.13      0.17      13    31
# Comp:  1                Halpha      211.5      0.17      13    31
# Comp:  2             [SII]6716      9.948      0.18       4    42
# Comp:  2             [SII]6731      6.646      0.18       4    42
# Comp:  2              HeII4687     0.3459      0.18       4    42
# Comp:  2               HeI5876      8.847      0.18       4    42
# Comp:  2          [OIII]5007_d      571.9      0.23       4    42
# Comp:  2            [OI]6300_d      2.105      0.23       4    42
# Comp:  2           [NII]6583_d      6.205      0.23       4    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       103         1
#  comp.  1:        16        24
#  comp.  2:        13        44
# chi2/DOF: 61.65; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      89.54      0.17      16    24
# Comp:  1                Halpha      202.9      0.17      16    24
# Comp:  2             [SII]6716      9.374      0.18      13    44
# Comp:  2             [SII]6731      6.439      0.18      13    44
# Comp:  2              HeII4687     0.3392      0.18      13    44
# Comp:  2               HeI5876      9.363      0.18      13    44
# Comp:  2          [OIII]5007_d      630.4      0.23      13    44
# Comp:  2            [OI]6300_d      1.867      0.23      13    44
# Comp:  2           [NII]6583_d      6.298      0.23      13    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       155         1
#  comp.  1:        14        34
#  comp.  2:        11        34
# chi2/DOF: 28.80; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      83.96      0.17      14    34
# Comp:  1                Halpha      209.6      0.17      14    34
# Comp:  2             [SII]6716      9.558      0.17      11    34
# Comp:  2             [SII]6731      6.385      0.17      11    34
# Comp:  2              HeII4687     0.3743      0.17      11    34
# Comp:  2               HeI5876      8.454      0.17      11    34
# Comp:  2          [OIII]5007_d      668.2      0.22      11    34
# Comp:  2            [OI]6300_d      2.466      0.22      11    34
# Comp:  2           [NII]6583_d      6.237      0.22      11    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       158       699
#  comp.  1:        13        30
#  comp.  2:         5        41
# chi2/DOF: 17.19; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      89.70      0.17      13    30
# Comp:  1                Halpha      207.8      0.17      13    30
# Comp:  2             [SII]6716      10.95      0.18       5    41
# Comp:  2             [SII]6731      6.358      0.18       5    41
# Comp:  2              HeII4687     0.4797      0.18       5    41
# Comp:  2               HeI5876      8.933      0.18       5    41
# Comp:  2          [OIII]5007_d      567.6      0.23       5    41
# Comp:  2            [OI]6300_d      2.081      0.23       5    41
# Comp:  2           [NII]6583_d      6.641      0.23       5    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       857       636
#  comp.  1:        16        30
#  comp.  2:        15        36
# chi2/DOF: 42.63; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 38; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      83.20      0.17      16    30
# Comp:  1                Halpha      205.3      0.17      16    30
# Comp:  2             [SII]6716      10.30      0.18      15    36
# Comp:  2             [SII]6731      6.926      0.18      15    36
# Comp:  2              HeII4687     0.4787      0.18      15    36
# Comp:  2               HeI5876      8.746      0.18      15    36
# Comp:  2          [OIII]5007_d      652.9      0.22      15    36
# Comp:  2            [OI]6300_d      2.101      0.22      15    36
# Comp:  2           [NII]6583_d      6.469      0.22      15    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -136       711
#  comp.  1:        16        25
#  comp.  2:         9        47
# chi2/DOF: 61.04; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      79.38      0.17      16    25
# Comp:  1                Halpha      205.5      0.17      16    25
# Comp:  2             [SII]6716      10.55      0.18       9    47
# Comp:  2             [SII]6731      7.022      0.18       9    47
# Comp:  2              HeII4687     0.7094      0.18       9    47
# Comp:  2               HeI5876      8.788      0.18       9    47
# Comp:  2          [OIII]5007_d      655.3      0.23       9    47
# Comp:  2            [OI]6300_d      2.570      0.23       9    47
# Comp:  2           [NII]6583_d      6.242      0.23       9    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -115         1
#  comp.  1:        16        26
#  comp.  2:         8        56
# chi2/DOF: 45.46; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      87.79      0.17      16    26
# Comp:  1                Halpha      208.0      0.17      16    26
# Comp:  2             [SII]6716      10.16      0.19       8    56
# Comp:  2             [SII]6731      7.295      0.19       8    56
# Comp:  2              HeII4687     0.5110      0.19       8    56
# Comp:  2               HeI5876      9.316      0.19       8    56
# Comp:  2          [OIII]5007_d      642.3      0.24       8    56
# Comp:  2            [OI]6300_d      2.103      0.24       8    56
# Comp:  2           [NII]6583_d      6.611      0.24       8    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        91         1
#  comp.  1:        16        26
#  comp.  2:        20        48
# chi2/DOF: 18.18; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      89.82      0.17      16    26
# Comp:  1                Halpha      208.6      0.17      16    26
# Comp:  2             [SII]6716      10.28      0.18      20    48
# Comp:  2             [SII]6731      6.812      0.18      20    48
# Comp:  2              HeII4687     0.2556      0.18      20    48
# Comp:  2               HeI5876      9.737      0.18      20    48
# Comp:  2          [OIII]5007_d      697.5      0.23      20    48
# Comp:  2            [OI]6300_d      2.230      0.23      20    48
# Comp:  2           [NII]6583_d      6.931      0.23      20    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       180         1
#  comp.  1:        15        29
#  comp.  2:        21        45
# chi2/DOF: 18.98; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 60; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      79.16      0.17      15    29
# Comp:  1                Halpha      209.7      0.17      15    29
# Comp:  2             [SII]6716      9.445      0.18      21    45
# Comp:  2             [SII]6731      6.902      0.18      21    45
# Comp:  2              HeII4687     0.6287      0.18      21    45
# Comp:  2               HeI5876      8.710      0.18      21    45
# Comp:  2          [OIII]5007_d      679.2      0.23      21    45
# Comp:  2            [OI]6300_d      2.267      0.23      21    45
# Comp:  2           [NII]6583_d      6.356      0.23      21    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        12
#  comp.  1:        15        33
#  comp.  2:        12        43
# chi2/DOF: 61.30; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      94.15      0.17      15    33
# Comp:  1                Halpha      212.4      0.17      15    33
# Comp:  2             [SII]6716      9.475      0.18      12    43
# Comp:  2             [SII]6731      6.469      0.18      12    43
# Comp:  2              HeII4687     0.5348      0.18      12    43
# Comp:  2               HeI5876      9.501      0.18      12    43
# Comp:  2          [OIII]5007_d      627.5      0.23      12    43
# Comp:  2            [OI]6300_d      2.218      0.23      12    43
# Comp:  2           [NII]6583_d      6.189      0.23      12    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:        14        26
#  comp.  2:        20        47
# chi2/DOF: 24.46; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      88.24      0.17      14    26
# Comp:  1                Halpha      204.3      0.17      14    26
# Comp:  2             [SII]6716      8.658      0.18      20    47
# Comp:  2             [SII]6731      7.015      0.18      20    47
# Comp:  2              HeII4687     0.4644      0.18      20    47
# Comp:  2               HeI5876      8.887      0.18      20    47
# Comp:  2          [OIII]5007_d      689.8      0.23      20    47
# Comp:  2            [OI]6300_d      1.986      0.23      20    47
# Comp:  2           [NII]6583_d      6.351      0.23      20    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       155         1
#  comp.  1:        14        26
#  comp.  2:         1        40
# chi2/DOF: 24.48; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      92.47      0.17      14    26
# Comp:  1                Halpha      206.0      0.17      14    26
# Comp:  2             [SII]6716      10.92      0.18       1    40
# Comp:  2             [SII]6731      6.428      0.18       1    40
# Comp:  2              HeII4687     0.4411      0.18       1    40
# Comp:  2               HeI5876      8.253      0.18       1    40
# Comp:  2          [OIII]5007_d      593.2      0.22       1    40
# Comp:  2            [OI]6300_d      1.886      0.22       1    40
# Comp:  2           [NII]6583_d      6.252      0.22       1    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        56        73
#  comp.  1:        16        23
#  comp.  2:         6        55
# chi2/DOF: 41.61; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      80.79      0.17      16    23
# Comp:  1                Halpha      203.4      0.17      16    23
# Comp:  2             [SII]6716      9.200      0.19       6    55
# Comp:  2             [SII]6731      6.923      0.19       6    55
# Comp:  2              HeII4687     0.4928      0.19       6    55
# Comp:  2               HeI5876      9.306      0.19       6    55
# Comp:  2          [OIII]5007_d      638.9      0.24       6    55
# Comp:  2            [OI]6300_d      2.215      0.24       6    55
# Comp:  2           [NII]6583_d      6.762      0.24       6    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       121         1
#  comp.  1:        13        24
#  comp.  2:         6        38
# chi2/DOF: 7.461; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 66; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      91.17      0.17      13    24
# Comp:  1                Halpha      205.2      0.17      13    24
# Comp:  2             [SII]6716      10.81      0.18       6    38
# Comp:  2             [SII]6731      6.229      0.18       6    38
# Comp:  2              HeII4687     0.3648      0.18       6    38
# Comp:  2               HeI5876      8.920      0.18       6    38
# Comp:  2          [OIII]5007_d      556.2      0.22       6    38
# Comp:  2            [OI]6300_d      1.874      0.22       6    38
# Comp:  2           [NII]6583_d      6.264      0.22       6    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       271         1
#  comp.  1:        15        30
#  comp.  2:        16        31
# chi2/DOF: 36.53; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      90.26      0.17      15    30
# Comp:  1                Halpha      209.4      0.17      15    30
# Comp:  2             [SII]6716      9.641      0.17      16    31
# Comp:  2             [SII]6731      6.518      0.17      16    31
# Comp:  2              HeII4687     0.5333      0.17      16    31
# Comp:  2               HeI5876      8.016      0.17      16    31
# Comp:  2          [OIII]5007_d      636.0      0.22      16    31
# Comp:  2            [OI]6300_d      2.024      0.22      16    31
# Comp:  2           [NII]6583_d      5.882      0.22      16    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       669       186
#  comp.  1:        16        30
#  comp.  2:         6        41
# chi2/DOF: 20.19; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 87; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      83.72      0.17      16    30
# Comp:  1                Halpha      208.2      0.17      16    30
# Comp:  2             [SII]6716      10.20      0.18       6    41
# Comp:  2             [SII]6731      6.730      0.18       6    41
# Comp:  2              HeII4687     0.4024      0.18       6    41
# Comp:  2               HeI5876      9.002      0.18       6    41
# Comp:  2          [OIII]5007_d      568.1      0.22       6    41
# Comp:  2            [OI]6300_d      1.847      0.22       6    41
# Comp:  2           [NII]6583_d      6.862      0.22       6    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        12
#  comp.  1:        16        31
#  comp.  2:         7        55
# chi2/DOF: 42.51; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      93.50      0.17      16    31
# Comp:  1                Halpha      210.4      0.17      16    31
# Comp:  2             [SII]6716      10.33      0.19       7    55
# Comp:  2             [SII]6731      6.631      0.19       7    55
# Comp:  2              HeII4687     0.5763      0.19       7    55
# Comp:  2               HeI5876      9.329      0.19       7    55
# Comp:  2          [OIII]5007_d      631.9      0.24       7    55
# Comp:  2            [OI]6300_d      2.176      0.24       7    55
# Comp:  2           [NII]6583_d      6.631      0.24       7    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43       754
#  comp.  1:        16        32
#  comp.  2:        16        43
# chi2/DOF: 54.85; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      90.46      0.17      16    32
# Comp:  1                Halpha      207.8      0.17      16    32
# Comp:  2             [SII]6716      9.498      0.18      16    43
# Comp:  2             [SII]6731      6.528      0.18      16    43
# Comp:  2              HeII4687     0.4611      0.18      16    43
# Comp:  2               HeI5876      9.049      0.18      16    43
# Comp:  2          [OIII]5007_d      618.3      0.23      16    43
# Comp:  2            [OI]6300_d      2.201      0.23      16    43
# Comp:  2           [NII]6583_d      6.438      0.23      16    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        59         1
#  comp.  1:        14        36
#  comp.  2:         3        26
# chi2/DOF: 20.13; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      83.67      0.18      14    36
# Comp:  1                Halpha      211.8      0.18      14    36
# Comp:  2             [SII]6716      10.32      0.17       3    26
# Comp:  2             [SII]6731      6.005      0.17       3    26
# Comp:  2              HeII4687     0.5014      0.17       3    26
# Comp:  2               HeI5876      8.291      0.17       3    26
# Comp:  2          [OIII]5007_d      609.1      0.22       3    26
# Comp:  2            [OI]6300_d      2.365      0.22       3    26
# Comp:  2           [NII]6583_d      6.285      0.22       3    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -138         1
#  comp.  1:        15        31
#  comp.  2:        12        54
# chi2/DOF: 34.39; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      84.71      0.17      15    31
# Comp:  1                Halpha      210.6      0.17      15    31
# Comp:  2             [SII]6716      11.37      0.19      12    54
# Comp:  2             [SII]6731      7.285      0.19      12    54
# Comp:  2              HeII4687     0.7134      0.19      12    54
# Comp:  2               HeI5876      9.549      0.19      12    54
# Comp:  2          [OIII]5007_d      609.9      0.24      12    54
# Comp:  2            [OI]6300_d      2.580      0.24      12    54
# Comp:  2           [NII]6583_d      6.442      0.24      12    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88         1
#  comp.  1:        16        37
#  comp.  2:         8        55
# chi2/DOF: 43.70; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      84.21      0.18      16    37
# Comp:  1                Halpha      213.9      0.18      16    37
# Comp:  2             [SII]6716      10.30      0.19       8    55
# Comp:  2             [SII]6731      6.696      0.19       8    55
# Comp:  2              HeII4687     0.5048      0.19       8    55
# Comp:  2               HeI5876      9.123      0.19       8    55
# Comp:  2          [OIII]5007_d      633.4      0.24       8    55
# Comp:  2            [OI]6300_d      2.325      0.24       8    55
# Comp:  2           [NII]6583_d      6.991      0.24       8    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28         1
#  comp.  1:        16        26
#  comp.  2:         1        28
# chi2/DOF: 11.97; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      78.22      0.17      16    26
# Comp:  1                Halpha      206.1      0.17      16    26
# Comp:  2             [SII]6716      8.440      0.17       1    28
# Comp:  2             [SII]6731      6.642      0.17       1    28
# Comp:  2              HeII4687     0.5117      0.17       1    28
# Comp:  2               HeI5876      9.067      0.17       1    28
# Comp:  2          [OIII]5007_d      619.7      0.22       1    28
# Comp:  2            [OI]6300_d      1.697      0.22       1    28
# Comp:  2           [NII]6583_d      6.217      0.22       1    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       108       125
#  comp.  1:        16        36
#  comp.  2:        11        45
# chi2/DOF: 62.16; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      80.82      0.18      16    36
# Comp:  1                Halpha      213.6      0.18      16    36
# Comp:  2             [SII]6716      9.503      0.18      11    45
# Comp:  2             [SII]6731      6.809      0.18      11    45
# Comp:  2              HeII4687     0.5309      0.18      11    45
# Comp:  2               HeI5876      8.739      0.18      11    45
# Comp:  2          [OIII]5007_d      631.6      0.23      11    45
# Comp:  2            [OI]6300_d      1.766      0.23      11    45
# Comp:  2           [NII]6583_d      6.360      0.23      11    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        91         1
#  comp.  1:        14        26
#  comp.  2:         7        56
# chi2/DOF: 42.50; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      81.61      0.17      14    26
# Comp:  1                Halpha      205.9      0.17      14    26
# Comp:  2             [SII]6716      10.19      0.19       7    56
# Comp:  2             [SII]6731      6.998      0.19       7    56
# Comp:  2              HeII4687     0.4906      0.19       7    56
# Comp:  2               HeI5876      8.513      0.19       7    56
# Comp:  2          [OIII]5007_d      640.2      0.24       7    56
# Comp:  2            [OI]6300_d      1.730      0.24       7    56
# Comp:  2           [NII]6583_d      6.650      0.24       7    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -107       510
#  comp.  1:        15        31
#  comp.  2:        11        58
# chi2/DOF: 26.69; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      88.44      0.17      15    31
# Comp:  1                Halpha      207.7      0.17      15    31
# Comp:  2             [SII]6716      9.362      0.19      11    58
# Comp:  2             [SII]6731      6.565      0.19      11    58
# Comp:  2              HeII4687     0.4382      0.19      11    58
# Comp:  2               HeI5876      10.03      0.19      11    58
# Comp:  2          [OIII]5007_d      615.7      0.24      11    58
# Comp:  2            [OI]6300_d      1.793      0.24      11    58
# Comp:  2           [NII]6583_d      6.592      0.24      11    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        61       463
#  comp.  1:        16        36
#  comp.  2:         2        29
# chi2/DOF: 16.78; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      85.86      0.18      16    36
# Comp:  1                Halpha      214.5      0.18      16    36
# Comp:  2             [SII]6716      9.280      0.17       2    29
# Comp:  2             [SII]6731      6.377      0.17       2    29
# Comp:  2              HeII4687     0.5971      0.17       2    29
# Comp:  2               HeI5876      8.828      0.17       2    29
# Comp:  2          [OIII]5007_d      614.6      0.22       2    29
# Comp:  2            [OI]6300_d      1.899      0.22       2    29
# Comp:  2           [NII]6583_d      6.335      0.22       2    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36       248
#  comp.  1:        15        30
#  comp.  2:         7        46
# chi2/DOF: 52.56; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      84.18      0.17      15    30
# Comp:  1                Halpha      209.6      0.17      15    30
# Comp:  2             [SII]6716      10.30      0.18       7    46
# Comp:  2             [SII]6731      7.106      0.18       7    46
# Comp:  2              HeII4687     0.6036      0.18       7    46
# Comp:  2               HeI5876      8.126      0.18       7    46
# Comp:  2          [OIII]5007_d      670.8      0.23       7    46
# Comp:  2            [OI]6300_d      1.875      0.23       7    46
# Comp:  2           [NII]6583_d      6.430      0.23       7    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        12
#  comp.  1:        15        30
#  comp.  2:        15        49
# chi2/DOF: 15.14; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      91.33      0.17      15    30
# Comp:  1                Halpha      208.5      0.17      15    30
# Comp:  2             [SII]6716      10.11      0.18      15    49
# Comp:  2             [SII]6731      6.532      0.18      15    49
# Comp:  2              HeII4687     0.7494      0.18      15    49
# Comp:  2               HeI5876      8.861      0.18      15    49
# Comp:  2          [OIII]5007_d      721.3      0.23      15    49
# Comp:  2            [OI]6300_d      1.984      0.23      15    49
# Comp:  2           [NII]6583_d      6.398      0.23      15    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8         1
#  comp.  1:        13        30
#  comp.  2:         0        42
# chi2/DOF: 17.80; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      92.28      0.17      13    30
# Comp:  1                Halpha      210.6      0.17      13    30
# Comp:  2             [SII]6716      8.825      0.18       0    42
# Comp:  2             [SII]6731      6.917      0.18       0    42
# Comp:  2              HeII4687     0.4378      0.18       0    42
# Comp:  2               HeI5876      9.459      0.18       0    42
# Comp:  2          [OIII]5007_d      594.9      0.23       0    42
# Comp:  2            [OI]6300_d      2.374      0.23       0    42
# Comp:  2           [NII]6583_d      6.372      0.23       0    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -839         1
#  comp.  1:        13        34
#  comp.  2:         8        44
# chi2/DOF: 55.95; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      92.44      0.17      13    34
# Comp:  1                Halpha      208.5      0.17      13    34
# Comp:  2             [SII]6716      9.829      0.18       8    44
# Comp:  2             [SII]6731      6.470      0.18       8    44
# Comp:  2              HeII4687     0.6717      0.18       8    44
# Comp:  2               HeI5876      9.186      0.18       8    44
# Comp:  2          [OIII]5007_d      661.7      0.23       8    44
# Comp:  2            [OI]6300_d      2.003      0.23       8    44
# Comp:  2           [NII]6583_d      6.358      0.23       8    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       175         1
#  comp.  1:        17        26
#  comp.  2:        11        34
# chi2/DOF: 28.48; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      80.17      0.17      17    26
# Comp:  1                Halpha      204.4      0.17      17    26
# Comp:  2             [SII]6716      9.561      0.17      11    34
# Comp:  2             [SII]6731      6.823      0.17      11    34
# Comp:  2              HeII4687     0.3988      0.17      11    34
# Comp:  2               HeI5876      8.427      0.17      11    34
# Comp:  2          [OIII]5007_d      669.3      0.22      11    34
# Comp:  2            [OI]6300_d      1.771      0.22      11    34
# Comp:  2           [NII]6583_d      6.510      0.22      11    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       154         1
#  comp.  1:        14        33
#  comp.  2:        15        46
# chi2/DOF: 56.92; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      95.04      0.17      14    33
# Comp:  1                Halpha      212.5      0.17      14    33
# Comp:  2             [SII]6716      11.13      0.18      15    46
# Comp:  2             [SII]6731      6.754      0.18      15    46
# Comp:  2              HeII4687     0.4739      0.18      15    46
# Comp:  2               HeI5876      9.753      0.18      15    46
# Comp:  2          [OIII]5007_d      626.5      0.23      15    46
# Comp:  2            [OI]6300_d      2.600      0.23      15    46
# Comp:  2           [NII]6583_d      6.772      0.23      15    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       153         1
#  comp.  1:        13        32
#  comp.  2:        16        49
# chi2/DOF: 15.35; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 73; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      91.78      0.17      13    32
# Comp:  1                Halpha      208.2      0.17      13    32
# Comp:  2             [SII]6716      9.244      0.18      16    49
# Comp:  2             [SII]6731      6.820      0.18      16    49
# Comp:  2              HeII4687     0.7068      0.18      16    49
# Comp:  2               HeI5876      10.19      0.18      16    49
# Comp:  2          [OIII]5007_d      716.7      0.23      16    49
# Comp:  2            [OI]6300_d      2.023      0.23      16    49
# Comp:  2           [NII]6583_d      6.359      0.23      16    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       151         1
#  comp.  1:        14        31
#  comp.  2:        11        34
# chi2/DOF: 28.60; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 69; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      89.92      0.17      14    31
# Comp:  1                Halpha      210.2      0.17      14    31
# Comp:  2             [SII]6716      8.655      0.17      11    34
# Comp:  2             [SII]6731      6.120      0.17      11    34
# Comp:  2              HeII4687     0.5664      0.17      11    34
# Comp:  2               HeI5876      9.091      0.17      11    34
# Comp:  2          [OIII]5007_d      666.7      0.22      11    34
# Comp:  2            [OI]6300_d      1.888      0.22      11    34
# Comp:  2           [NII]6583_d      6.317      0.22      11    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39       284
#  comp.  1:        17        31
#  comp.  2:        15        35
# chi2/DOF: 45.79; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      82.70      0.17      17    31
# Comp:  1                Halpha      211.2      0.17      17    31
# Comp:  2             [SII]6716      9.137      0.17      15    35
# Comp:  2             [SII]6731      6.238      0.17      15    35
# Comp:  2              HeII4687     0.5458      0.17      15    35
# Comp:  2               HeI5876      8.994      0.17      15    35
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      87.61      0.17      15    24
# Comp:  1                Halpha      203.3      0.17      15    24
# Comp:  2             [SII]6716      10.05      0.18      12    46
# Comp:  2             [SII]6731      6.485      0.18      12    46
# Comp:  2              HeII4687     0.5406      0.18      12    46
# Comp:  2               HeI5876      8.256      0.18      12    46
# Comp:  2          [OIII]5007_d      636.1      0.23      12    46
# Comp:  2            [OI]6300_d      2.514      0.23      12    46
# Comp:  2           [NII]6583_d      6.841      0.23      12    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       141         1
#  comp.  1:        15        32
#  comp.  2:        16        32
# chi2/DOF: 36.65; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 84; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      91.20      0.17      15    32
# Comp:  1                Halpha      209.9      0.17      15    32
# Comp:  2             [SII]6716      8.965      0.17      16    32
# Comp:  2             [SII]6731      6.420      0.17      16    32
# Comp:  2              HeII4687     0.4729      0.17      16    32
# Comp:  2               HeI5876      8.485      0.17      16    32
# Comp:  2          [OIII]5007_d      644.1      0.22      16    32
# Comp:  2            [OI]6300_d      1.784      0.22      16    32
# Comp:  2           [NII]6583_d      6.594      0.22      16    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -123         1
#  comp.  1:        13        29
#  comp.  2:        13        54
# chi2/DOF: 35.34; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      91.15      0.17      13    29
# Comp:  1                Halpha      208.0      0.17      13    29
# Comp:  2             [SII]6716      11.18      0.19      13    54
# Comp:  2             [SII]6731      6.994      0.19      13    54
# Comp:  2              HeII4687     0.6420      0.19      13    54
# Comp:  2               HeI5876      9.332      0.19      13    54
# Comp:  2          [OIII]5007_d      610.9      0.24      13    54
# Comp:  2            [OI]6300_d      2.514      0.24      13    54
# Comp:  2           [NII]6583_d      6.502      0.24      13    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        12
#  comp.  1:        14        30
#  comp.  2:        11        45
# chi2/DOF: 63.38; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      90.25      0.17      14    30
# Comp:  1                Halpha      206.5      0.17      14    30
# Comp:  2             [SII]6716      9.945      0.18      11    45
# Comp:  2             [SII]6731      6.747      0.18      11    45
# Comp:  2              HeII4687     0.5245      0.18      11    45
# Comp:  2               HeI5876      8.673      0.18      11    45
# Comp:  2          [OIII]5007_d      641.2      0.23      11    45
# Comp:  2            [OI]6300_d      2.240      0.23      11    45
# Comp:  2           [NII]6583_d      6.524      0.23      11    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14        94
#  comp.  1:        14        25
#  comp.  2:        -1        41
# chi2/DOF: 12.80; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      89.44      0.17      14    25
# Comp:  1                Halpha      207.9      0.17      14    25
# Comp:  2             [SII]6716      10.17      0.18      -1    41
# Comp:  2             [SII]6731      6.207      0.18      -1    41
# Comp:  2              HeII4687     0.5581      0.18      -1    41
# Comp:  2               HeI5876      8.722      0.18      -1    41
# Comp:  2          [OIII]5007_d      597.0      0.23      -1    41
# Comp:  2            [OI]6300_d      1.949      0.23      -1    41
# Comp:  2           [NII]6583_d      6.648      0.23      -1    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -130       340
#  comp.  1:        14        27
#  comp.  2:        16        58
# chi2/DOF: 31.41; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      91.69      0.17      14    27
# Comp:  1                Halpha      205.9      0.17      14    27
# Comp:  2             [SII]6716      10.38      0.19      16    58
# Comp:  2             [SII]6731      7.468      0.19      16    58
# Comp:  2              HeII4687     0.5668      0.19      16    58
# Comp:  2               HeI5876      9.114      0.19      16    58
# Comp:  2          [OIII]5007_d      701.0      0.24      16    58
# Comp:  2            [OI]6300_d      2.769      0.24      16    58
# Comp:  2           [NII]6583_d      7.188      0.24      16    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21         1
#  comp.  1:        16        27
#  comp.  2:        11        46
# chi2/DOF: 63.10; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      82.46      0.17      16    27
# Comp:  1                Halpha      205.2      0.17      16    27
# Comp:  2             [SII]6716      9.325      0.18      11    46
# Comp:  2             [SII]6731      6.877      0.18      11    46
# Comp:  2              HeII4687     0.4272      0.18      11    46
# Comp:  2               HeI5876      9.557      0.18      11    46
# Comp:  2          [OIII]5007_d      643.3      0.23      11    46
# Comp:  2            [OI]6300_d      2.655      0.23      11    46
# Comp:  2           [NII]6583_d      6.323      0.23      11    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       150         1
#  comp.  1:        14        32
#  comp.  2:        11        35
# chi2/DOF: 29.80; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 61; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      90.47      0.17      14    32
# Comp:  1                Halpha      209.7      0.17      14    32
# Comp:  2             [SII]6716      9.734      0.17      11    35
# Comp:  2             [SII]6731      6.316      0.17      11    35
# Comp:  2              HeII4687     0.5401      0.17      11    35
# Comp:  2               HeI5876      8.809      0.17      11    35
# Comp:  2          [OIII]5007_d      669.1      0.22      11    35
# Comp:  2            [OI]6300_d      1.932      0.22      11    35
# Comp:  2           [NII]6583_d      6.639      0.22      11    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        67        96
#  comp.  1:        16        28
#  comp.  2:        14        46
# chi2/DOF: 58.13; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      89.86      0.17      16    28
# Comp:  1                Halpha      208.4      0.17      16    28
# Comp:  2             [SII]6716      10.35      0.18      14    46
# Comp:  2             [SII]6731      6.713      0.18      14    46
# Comp:  2              HeII4687     0.5845      0.18      14    46
# Comp:  2               HeI5876      8.589      0.18      14    46
# Comp:  2          [OIII]5007_d      625.0      0.23      14    46
# Comp:  2            [OI]6300_d      2.112      0.23      14    46
# Comp:  2           [NII]6583_d      6.544      0.23      14    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95       496
#  comp.  1:        16        29
#  comp.  2:        16        48
# chi2/DOF: 17.59; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      80.99      0.17      16    29
# Comp:  1                Halpha      208.6      0.17      16    29
# Comp:  2             [SII]6716      9.835      0.18      16    48
# Comp:  2             [SII]6731      6.892      0.18      16    48
# Comp:  2              HeII4687     0.7053      0.18      16    48
# Comp:  2               HeI5876      8.211      0.18      16    48
# Comp:  2          [OIII]5007_d      714.5      0.23      16    48
# Comp:  2            [OI]6300_d      1.957      0.23      16    48
# Comp:  2           [NII]6583_d      6.597      0.23      16    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26      1000
#  comp.  1:        15        28
#  comp.  2:        10        46
# chi2/DOF: 62.76; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      89.80      0.17      15    28
# Comp:  1                Halpha      207.3      0.17      15    28
# Comp:  2             [SII]6716      8.916      0.18      10    46
# Comp:  2             [SII]6731      6.969      0.18      10    46
# Comp:  2              HeII4687     0.4576      0.18      10    46
# Comp:  2               HeI5876      8.932      0.18      10    46
# Comp:  2          [OIII]5007_d      643.2      0.23      10    46
# Comp:  2            [OI]6300_d      1.783      0.23      10    46
# Comp:  2           [NII]6583_d      6.139      0.23      10    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -193        53
#  comp.  1:        15        27
#  comp.  2:        14        45
# chi2/DOF: 58.78; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      89.92      0.17      15    27
# Comp:  1                Halpha      208.1      0.17      15    27
# Comp:  2             [SII]6716      9.965      0.18      14    45
# Comp:  2             [SII]6731      7.144      0.18      14    45
# Comp:  2              HeII4687     0.6686      0.18      14    45
# Comp:  2               HeI5876      8.783      0.18      14    45
# Comp:  2          [OIII]5007_d      623.8      0.23      14    45
# Comp:  2            [OI]6300_d      1.593      0.23      14    45
# Comp:  2           [NII]6583_d      6.560      0.23      14    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       137         1
#  comp.  1:        15        32
#  comp.  2:        12        33
# chi2/DOF: 31.73; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      93.75      0.17      15    32
# Comp:  1                Halpha      210.2      0.17      15    32
# Comp:  2             [SII]6716      8.747      0.17      12    33
# Comp:  2             [SII]6731      6.498      0.17      12    33
# Comp:  2              HeII4687     0.5030      0.17      12    33
# Comp:  2               HeI5876      9.031      0.17      12    33
# Comp:  2          [OIII]5007_d      661.1      0.22      12    33
# Comp:  2            [OI]6300_d      2.298      0.22      12    33
# Comp:  2           [NII]6583_d      6.200      0.22      12    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86       181
#  comp.  1:        18        30
#  comp.  2:        11        56
# chi2/DOF: 32.26; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      80.44      0.17      18    30
# Comp:  1                Halpha      206.4      0.17      18    30
# Comp:  2             [SII]6716      9.913      0.19      11    56
# Comp:  2             [SII]6731      6.990      0.19      11    56
# Comp:  2              HeII4687     0.5103      0.19      11    56
# Comp:  2               HeI5876      9.146      0.19      11    56
# Comp:  2          [OIII]5007_d      615.5      0.24      11    56
# Comp:  2            [OI]6300_d      2.188      0.24      11    56
# Comp:  2           [NII]6583_d      6.629      0.24      11    56
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([ 4.66350111,  3.90359246,  0.96767854,  0.44370925,  0.11375272,
#         0.71575877, 40.13115601,  0.35622512,  0.42819107])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([8.67345748e+01, 2.85702589e+02, 1.39281189e+01, 9.45515686e+00,
#        5.53416931e-01, 1.09300225e+01, 6.69420401e+02, 2.77975593e+00,
#        8.77680918e+00])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_4_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_4_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_4_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_4_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_4_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name        Flux  Error flux
# 0         Hbeta   35.923435    1.931513
# 1        Halpha  118.331339    1.616777
# 2     [SII]6716    5.768701    0.400790
# 3     [SII]6731    3.916105    0.183774
# 4      HeII4687    0.229212    0.047114
# 5       HeI5876    4.526960    0.296451
# 6  [OIII]5007_d  277.258293   16.621387
# 7    [OI]6300_d    1.151310    0.147540
# 8   [NII]6583_d    3.635149    0.177347
#           Name        Flux  Error_flux
# 0        Hbeta   35.923435    1.931513
# 1       Halpha  118.331339    1.616777
# 2    [SII]6716    5.768701    0.400790
# 3    [SII]6731    3.916105    0.183774
# 4     HeII4687    0.229212    0.047114
# 5      HeI5876    4.526960    0.296451
# 6   [OIII]4959   69.314573   16.621387
# 7   [OIII]5007  207.943720   16.621387
# 8     [OI]6300    0.863482    0.147540
# 9     [OI]6364    0.287827    0.147540
# 10   [NII]6548    0.908787    0.177347
# 11   [NII]6583    2.726362    0.177347

# %%
np.median(flux_rf_rebin)
# Out:
# 0.4141766407853959
