# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_2.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_1263/FORS2.2022-01-06T07_26_01.965/Spectra_extraction/redshift.txt")   
z = red[1][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_2']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4434.20161708 4435.67530967 4437.14900227 ... 7063.26920779 7064.74290039
#  7066.21659298] [0.20241037 0.18526855 0.23979063 ... 0.14429702 0.14957186 0.12324985] [0.01305564 0.01305564 0.01305564 ... 0.01305564 0.01305564 0.01305564]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.21710081 2.21783765 2.2185745  ... 3.5316346  3.53237145 3.5331083 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3136, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3136, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3136, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -4         1
# chi2/DOF: 0.004711; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:         5         1
# chi2/DOF: 0.003381; DOF: 1895; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([4.89135863, 0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -314       364
#  comp.  1:        11        29
#  comp.  2:        22        45
# chi2/DOF: 6.238; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.39      0.16      11    29
# Comp:  1                Halpha      98.66      0.16      11    29
# Comp:  2             [SII]6716      7.122      0.17      22    45
# Comp:  2             [SII]6731      5.145      0.17      22    45
# Comp:  2              HeII4687     0.4534      0.17      22    45
# Comp:  2               HeI5876      4.085      0.17      22    45
# Comp:  2          [OIII]5007_d      223.8      0.22      22    45
# Comp:  2            [OI]6300_d      1.853      0.22      22    45
# Comp:  2           [NII]6583_d      4.773      0.22      22    45
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  208.5; gas flux:     41 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  528.3; gas flux:    135 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  33.89; gas flux:     10 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  24.09; gas flux:      7 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  2.219; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  20.07; gas flux:      5 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  829.1; gas flux:    234 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  6.658; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:   16.6; gas flux:      7 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -323       468
#  comp.  1:         8        25
#  comp.  2:        24        52
# chi2/DOF: 5.173; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      37.18      0.16       8    25
# Comp:  1                Halpha      97.71      0.16       8    25
# Comp:  2             [SII]6716      6.553      0.18      24    52
# Comp:  2             [SII]6731      5.248      0.18      24    52
# Comp:  2              HeII4687     0.5425      0.18      24    52
# Comp:  2               HeI5876      4.134      0.18      24    52
# Comp:  2          [OIII]5007_d      231.3      0.22      24    52
# Comp:  2            [OI]6300_d      2.023      0.22      24    52
# Comp:  2           [NII]6583_d      5.033      0.22      24    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       111         1
#  comp.  1:        11        28
#  comp.  2:        26        44
# chi2/DOF: 4.651; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      38.02      0.16      11    28
# Comp:  1                Halpha      98.83      0.16      11    28
# Comp:  2             [SII]6716      8.820      0.17      26    44
# Comp:  2             [SII]6731      5.127      0.17      26    44
# Comp:  2              HeII4687     0.4961      0.17      26    44
# Comp:  2               HeI5876      3.828      0.17      26    44
# Comp:  2          [OIII]5007_d      231.7      0.22      26    44
# Comp:  2            [OI]6300_d      1.886      0.22      26    44
# Comp:  2           [NII]6583_d      4.992      0.22      26    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -152       585
#  comp.  1:        12        32
#  comp.  2:        17        41
# chi2/DOF: 4.759; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      37.91      0.16      12    32
# Comp:  1                Halpha      98.86      0.16      12    32
# Comp:  2             [SII]6716      6.352      0.17      17    41
# Comp:  2             [SII]6731      5.722      0.17      17    41
# Comp:  2              HeII4687     0.4637      0.17      17    41
# Comp:  2               HeI5876      4.117      0.17      17    41
# Comp:  2          [OIII]5007_d      223.0      0.21      17    41
# Comp:  2            [OI]6300_d      1.670      0.21      17    41
# Comp:  2           [NII]6583_d      4.261      0.21      17    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33        70
#  comp.  1:        10        36
#  comp.  2:        22        44
# chi2/DOF: 5.845; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.17      0.17      10    36
# Comp:  1                Halpha      101.8      0.17      10    36
# Comp:  2             [SII]6716      5.937      0.17      22    44
# Comp:  2             [SII]6731      5.005      0.17      22    44
# Comp:  2              HeII4687     0.3745      0.17      22    44
# Comp:  2               HeI5876      3.983      0.17      22    44
# Comp:  2          [OIII]5007_d      221.0      0.22      22    44
# Comp:  2            [OI]6300_d      1.934      0.22      22    44
# Comp:  2           [NII]6583_d      4.518      0.22      22    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       141         1
#  comp.  1:        10        30
#  comp.  2:        27        46
# chi2/DOF: 5.135; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 61; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.17      0.16      10    30
# Comp:  1                Halpha      98.68      0.16      10    30
# Comp:  2             [SII]6716      8.875      0.17      27    46
# Comp:  2             [SII]6731      4.993      0.17      27    46
# Comp:  2              HeII4687     0.5156      0.17      27    46
# Comp:  2               HeI5876      4.228      0.17      27    46
# Comp:  2          [OIII]5007_d      227.0      0.22      27    46
# Comp:  2            [OI]6300_d      1.991      0.22      27    46
# Comp:  2           [NII]6583_d      4.221      0.22      27    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -487       356
#  comp.  1:        11        27
#  comp.  2:        20        41
# chi2/DOF: 4.968; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.67      0.16      11    27
# Comp:  1                Halpha      97.96      0.16      11    27
# Comp:  2             [SII]6716      6.586      0.17      20    41
# Comp:  2             [SII]6731      4.451      0.17      20    41
# Comp:  2              HeII4687     0.2981      0.17      20    41
# Comp:  2               HeI5876      3.874      0.17      20    41
# Comp:  2          [OIII]5007_d      211.4      0.21      20    41
# Comp:  2            [OI]6300_d      1.697      0.21      20    41
# Comp:  2           [NII]6583_d      4.181      0.21      20    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -180       427
#  comp.  1:         9        15
#  comp.  2:        21        47
# chi2/DOF: 5.503; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.77      0.16       9    15
# Comp:  1                Halpha      95.27      0.16       9    15
# Comp:  2             [SII]6716      8.852      0.17      21    47
# Comp:  2             [SII]6731      4.915      0.17      21    47
# Comp:  2              HeII4687     0.4047      0.17      21    47
# Comp:  2               HeI5876      3.983      0.17      21    47
# Comp:  2          [OIII]5007_d      223.6      0.22      21    47
# Comp:  2            [OI]6300_d      1.908      0.22      21    47
# Comp:  2           [NII]6583_d      4.516      0.22      21    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -133       432
#  comp.  1:         7        18
#  comp.  2:        24        44
# chi2/DOF: 5.531; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.35      0.16       7    18
# Comp:  1                Halpha      97.06      0.16       7    18
# Comp:  2             [SII]6716      8.921      0.17      24    44
# Comp:  2             [SII]6731      4.624      0.17      24    44
# Comp:  2              HeII4687     0.5783      0.17      24    44
# Comp:  2               HeI5876      4.279      0.17      24    44
# Comp:  2          [OIII]5007_d      223.5      0.22      24    44
# Comp:  2            [OI]6300_d      1.663      0.22      24    44
# Comp:  2           [NII]6583_d      4.818      0.22      24    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -139       493
#  comp.  1:        12        27
#  comp.  2:        19        36
# chi2/DOF: 4.839; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.47      0.16      12    27
# Comp:  1                Halpha      98.54      0.16      12    27
# Comp:  2             [SII]6716      8.538      0.17      19    36
# Comp:  2             [SII]6731      4.515      0.17      19    36
# Comp:  2              HeII4687     0.3535      0.17      19    36
# Comp:  2               HeI5876      4.267      0.17      19    36
# Comp:  2          [OIII]5007_d      217.7      0.21      19    36
# Comp:  2            [OI]6300_d      1.837      0.21      19    36
# Comp:  2           [NII]6583_d      4.627      0.21      19    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -243        10
#  comp.  1:        11        23
#  comp.  2:        19        45
# chi2/DOF: 5.419; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.64      0.16      11    23
# Comp:  1                Halpha      94.68      0.16      11    23
# Comp:  2             [SII]6716      6.523      0.17      19    45
# Comp:  2             [SII]6731      5.241      0.17      19    45
# Comp:  2              HeII4687     0.5717      0.17      19    45
# Comp:  2               HeI5876      4.301      0.17      19    45
# Comp:  2          [OIII]5007_d      223.6      0.22      19    45
# Comp:  2            [OI]6300_d      1.672      0.22      19    45
# Comp:  2           [NII]6583_d      5.154      0.22      19    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        94         1
#  comp.  1:        10        28
#  comp.  2:        26        45
# chi2/DOF: 4.911; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 61; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.46      0.16      10    28
# Comp:  1                Halpha      100.0      0.16      10    28
# Comp:  2             [SII]6716      8.822      0.17      26    45
# Comp:  2             [SII]6731      4.265      0.17      26    45
# Comp:  2              HeII4687     0.4276      0.17      26    45
# Comp:  2               HeI5876      4.205      0.17      26    45
# Comp:  2          [OIII]5007_d      232.5      0.22      26    45
# Comp:  2            [OI]6300_d      1.936      0.22      26    45
# Comp:  2           [NII]6583_d      5.333      0.22      26    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -412       335
#  comp.  1:        16        37
#  comp.  2:        27        50
# chi2/DOF: 3.053; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.49      0.17      16    37
# Comp:  1                Halpha      101.8      0.17      16    37
# Comp:  2             [SII]6716      8.113      0.17      27    50
# Comp:  2             [SII]6731      4.324      0.17      27    50
# Comp:  2              HeII4687     0.6088      0.17      27    50
# Comp:  2               HeI5876      4.542      0.17      27    50
# Comp:  2          [OIII]5007_d      239.4      0.22      27    50
# Comp:  2            [OI]6300_d      1.959      0.22      27    50
# Comp:  2           [NII]6583_d      4.697      0.22      27    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -245       501
#  comp.  1:         7        21
#  comp.  2:        23        39
# chi2/DOF: 5.051; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      37.29      0.16       7    21
# Comp:  1                Halpha      95.67      0.16       7    21
# Comp:  2             [SII]6716      7.475      0.17      23    39
# Comp:  2             [SII]6731      5.943      0.17      23    39
# Comp:  2              HeII4687     0.4841      0.17      23    39
# Comp:  2               HeI5876      4.071      0.17      23    39
# Comp:  2          [OIII]5007_d      214.4      0.21      23    39
# Comp:  2            [OI]6300_d      1.842      0.21      23    39
# Comp:  2           [NII]6583_d      4.749      0.21      23    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -176       434
#  comp.  1:        12        27
#  comp.  2:        17        36
# chi2/DOF: 3.845; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.34      0.16      12    27
# Comp:  1                Halpha      99.43      0.16      12    27
# Comp:  2             [SII]6716      7.313      0.17      17    36
# Comp:  2             [SII]6731      4.926      0.17      17    36
# Comp:  2              HeII4687     0.2857      0.17      17    36
# Comp:  2               HeI5876      3.941      0.17      17    36
# Comp:  2          [OIII]5007_d      212.0      0.21      17    36
# Comp:  2            [OI]6300_d      1.899      0.21      17    36
# Comp:  2           [NII]6583_d      4.847      0.21      17    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -407       457
#  comp.  1:         9        33
#  comp.  2:        21        50
# chi2/DOF: 5.301; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.15      0.17       9    33
# Comp:  1                Halpha      99.08      0.17       9    33
# Comp:  2             [SII]6716      6.172      0.17      21    50
# Comp:  2             [SII]6731      4.663      0.17      21    50
# Comp:  2              HeII4687     0.5655      0.17      21    50
# Comp:  2               HeI5876      4.184      0.17      21    50
# Comp:  2          [OIII]5007_d      229.5      0.22      21    50
# Comp:  2            [OI]6300_d      1.754      0.22      21    50
# Comp:  2           [NII]6583_d      5.561      0.22      21    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -357       302
#  comp.  1:         9        27
#  comp.  2:        22        44
# chi2/DOF: 5.770; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      43.98      0.16       9    27
# Comp:  1                Halpha      97.17      0.16       9    27
# Comp:  2             [SII]6716      6.671      0.17      22    44
# Comp:  2             [SII]6731      4.980      0.17      22    44
# Comp:  2              HeII4687     0.3239      0.17      22    44
# Comp:  2               HeI5876      4.244      0.17      22    44
# Comp:  2          [OIII]5007_d      226.7      0.22      22    44
# Comp:  2            [OI]6300_d      1.817      0.22      22    44
# Comp:  2           [NII]6583_d      4.662      0.22      22    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -315        72
#  comp.  1:        12        28
#  comp.  2:        25        44
# chi2/DOF: 5.652; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.13      0.16      12    28
# Comp:  1                Halpha      98.03      0.16      12    28
# Comp:  2             [SII]6716      7.199      0.17      25    44
# Comp:  2             [SII]6731      5.002      0.17      25    44
# Comp:  2              HeII4687     0.3787      0.17      25    44
# Comp:  2               HeI5876      3.834      0.17      25    44
# Comp:  2          [OIII]5007_d      226.4      0.22      25    44
# Comp:  2            [OI]6300_d      1.953      0.22      25    44
# Comp:  2           [NII]6583_d      4.333      0.22      25    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95         1
#  comp.  1:        12        36
#  comp.  2:        18        43
# chi2/DOF: 4.111; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.35      0.17      12    36
# Comp:  1                Halpha      102.5      0.17      12    36
# Comp:  2             [SII]6716      7.065      0.17      18    43
# Comp:  2             [SII]6731      4.253      0.17      18    43
# Comp:  2              HeII4687     0.5177      0.17      18    43
# Comp:  2               HeI5876      4.183      0.17      18    43
# Comp:  2          [OIII]5007_d      212.8      0.22      18    43
# Comp:  2            [OI]6300_d      1.796      0.22      18    43
# Comp:  2           [NII]6583_d      4.461      0.22      18    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -704       325
#  comp.  1:        11        25
#  comp.  2:        22        42
# chi2/DOF: 5.850; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.69      0.16      11    25
# Comp:  1                Halpha      95.31      0.16      11    25
# Comp:  2             [SII]6716      6.873      0.17      22    42
# Comp:  2             [SII]6731      5.727      0.17      22    42
# Comp:  2              HeII4687     0.3180      0.17      22    42
# Comp:  2               HeI5876      4.148      0.17      22    42
# Comp:  2          [OIII]5007_d      221.9      0.21      22    42
# Comp:  2            [OI]6300_d      1.821      0.21      22    42
# Comp:  2           [NII]6583_d      4.586      0.21      22    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -460       315
#  comp.  1:        14        34
#  comp.  2:        25        42
# chi2/DOF: 5.321; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.16      0.17      14    34
# Comp:  1                Halpha      101.2      0.17      14    34
# Comp:  2             [SII]6716      6.359      0.17      25    42
# Comp:  2             [SII]6731      5.238      0.17      25    42
# Comp:  2              HeII4687     0.5343      0.17      25    42
# Comp:  2               HeI5876      4.237      0.17      25    42
# Comp:  2          [OIII]5007_d      217.4      0.21      25    42
# Comp:  2            [OI]6300_d      1.804      0.21      25    42
# Comp:  2           [NII]6583_d      5.366      0.21      25    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -198         1
#  comp.  1:        12        39
#  comp.  2:        26        51
# chi2/DOF: 3.956; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      46.45      0.17      12    39
# Comp:  1                Halpha      104.5      0.17      12    39
# Comp:  2             [SII]6716      6.602      0.18      26    51
# Comp:  2             [SII]6731      4.896      0.18      26    51
# Comp:  2              HeII4687     0.4883      0.18      26    51
# Comp:  2               HeI5876      4.074      0.18      26    51
# Comp:  2          [OIII]5007_d      233.8      0.22      26    51
# Comp:  2            [OI]6300_d      1.825      0.22      26    51
# Comp:  2           [NII]6583_d      4.485      0.22      26    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -284        39
#  comp.  1:        11        30
#  comp.  2:        19        36
# chi2/DOF: 3.501; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.59      0.16      11    30
# Comp:  1                Halpha      97.73      0.16      11    30
# Comp:  2             [SII]6716      6.541      0.17      19    36
# Comp:  2             [SII]6731      4.319      0.17      19    36
# Comp:  2              HeII4687     0.3650      0.17      19    36
# Comp:  2               HeI5876      3.967      0.17      19    36
# Comp:  2          [OIII]5007_d      205.9      0.21      19    36
# Comp:  2            [OI]6300_d      1.634      0.21      19    36
# Comp:  2           [NII]6583_d      3.915      0.21      19    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -145       276
#  comp.  1:         9        22
#  comp.  2:        22        43
# chi2/DOF: 5.659; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.23      0.16       9    22
# Comp:  1                Halpha      97.82      0.16       9    22
# Comp:  2             [SII]6716      5.355      0.17      22    43
# Comp:  2             [SII]6731      5.741      0.17      22    43
# Comp:  2              HeII4687     0.5073      0.17      22    43
# Comp:  2               HeI5876      3.865      0.17      22    43
# Comp:  2          [OIII]5007_d      220.6      0.22      22    43
# Comp:  2            [OI]6300_d      1.883      0.22      22    43
# Comp:  2           [NII]6583_d      4.491      0.22      22    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -219       482
#  comp.  1:        12        35
#  comp.  2:        20        40
# chi2/DOF: 4.938; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.72      0.17      12    35
# Comp:  1                Halpha      100.9      0.17      12    35
# Comp:  2             [SII]6716      7.205      0.17      20    40
# Comp:  2             [SII]6731      5.873      0.17      20    40
# Comp:  2              HeII4687     0.5833      0.17      20    40
# Comp:  2               HeI5876      3.972      0.17      20    40
# Comp:  2          [OIII]5007_d      213.7      0.21      20    40
# Comp:  2            [OI]6300_d      1.908      0.21      20    40
# Comp:  2           [NII]6583_d      4.621      0.21      20    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -332       460
#  comp.  1:         9        20
#  comp.  2:        19        41
# chi2/DOF: 5.294; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.82      0.16       9    20
# Comp:  1                Halpha      95.21      0.16       9    20
# Comp:  2             [SII]6716      7.597      0.17      19    41
# Comp:  2             [SII]6731      5.690      0.17      19    41
# Comp:  2              HeII4687     0.5744      0.17      19    41
# Comp:  2               HeI5876      4.137      0.17      19    41
# Comp:  2          [OIII]5007_d      222.3      0.21      19    41
# Comp:  2            [OI]6300_d      1.790      0.21      19    41
# Comp:  2           [NII]6583_d      4.969      0.21      19    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       169         1
#  comp.  1:         8        18
#  comp.  2:        26        43
# chi2/DOF: 4.836; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.30      0.16       8    18
# Comp:  1                Halpha      95.15      0.16       8    18
# Comp:  2             [SII]6716      6.768      0.17      26    43
# Comp:  2             [SII]6731      5.645      0.17      26    43
# Comp:  2              HeII4687     0.5511      0.17      26    43
# Comp:  2               HeI5876      4.029      0.17      26    43
# Comp:  2          [OIII]5007_d      224.1      0.22      26    43
# Comp:  2            [OI]6300_d      1.993      0.22      26    43
# Comp:  2           [NII]6583_d      4.031      0.22      26    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       151         1
#  comp.  1:         8        24
#  comp.  2:        28        51
# chi2/DOF: 3.770; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.79      0.16       8    24
# Comp:  1                Halpha      97.79      0.16       8    24
# Comp:  2             [SII]6716      8.368      0.18      28    51
# Comp:  2             [SII]6731      5.285      0.18      28    51
# Comp:  2              HeII4687     0.5773      0.18      28    51
# Comp:  2               HeI5876      4.167      0.18      28    51
# Comp:  2          [OIII]5007_d      228.3      0.22      28    51
# Comp:  2            [OI]6300_d      2.029      0.22      28    51
# Comp:  2           [NII]6583_d      4.786      0.22      28    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -261       456
#  comp.  1:         9        28
#  comp.  2:        25        40
# chi2/DOF: 5.497; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.26      0.16       9    28
# Comp:  1                Halpha      98.04      0.16       9    28
# Comp:  2             [SII]6716      6.858      0.17      25    40
# Comp:  2             [SII]6731      5.985      0.17      25    40
# Comp:  2              HeII4687     0.4347      0.17      25    40
# Comp:  2               HeI5876      3.761      0.17      25    40
# Comp:  2          [OIII]5007_d      218.7      0.21      25    40
# Comp:  2            [OI]6300_d      1.804      0.21      25    40
# Comp:  2           [NII]6583_d      4.466      0.21      25    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -392       242
#  comp.  1:        10        27
#  comp.  2:        21        46
# chi2/DOF: 5.591; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.81      0.16      10    27
# Comp:  1                Halpha      96.81      0.16      10    27
# Comp:  2             [SII]6716      7.635      0.17      21    46
# Comp:  2             [SII]6731      5.214      0.17      21    46
# Comp:  2              HeII4687     0.2465      0.17      21    46
# Comp:  2               HeI5876      4.446      0.17      21    46
# Comp:  2          [OIII]5007_d      217.9      0.22      21    46
# Comp:  2            [OI]6300_d      1.873      0.22      21    46
# Comp:  2           [NII]6583_d      4.963      0.22      21    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -359        78
#  comp.  1:        10        29
#  comp.  2:        25        47
# chi2/DOF: 5.705; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.36      0.16      10    29
# Comp:  1                Halpha      99.44      0.16      10    29
# Comp:  2             [SII]6716      6.111      0.17      25    47
# Comp:  2             [SII]6731      5.511      0.17      25    47
# Comp:  2              HeII4687     0.2530      0.17      25    47
# Comp:  2               HeI5876      4.060      0.17      25    47
# Comp:  2          [OIII]5007_d      228.5      0.22      25    47
# Comp:  2            [OI]6300_d      1.970      0.22      25    47
# Comp:  2           [NII]6583_d      4.736      0.22      25    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       152         1
#  comp.  1:         9        20
#  comp.  2:        18        40
# chi2/DOF: 4.460; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.50      0.16       9    20
# Comp:  1                Halpha      95.67      0.16       9    20
# Comp:  2             [SII]6716      8.140      0.17      18    40
# Comp:  2             [SII]6731      5.267      0.17      18    40
# Comp:  2              HeII4687     0.5269      0.17      18    40
# Comp:  2               HeI5876      4.152      0.17      18    40
# Comp:  2          [OIII]5007_d      215.1      0.21      18    40
# Comp:  2            [OI]6300_d      1.884      0.21      18    40
# Comp:  2           [NII]6583_d      4.732      0.21      18    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       115         1
#  comp.  1:        12        26
#  comp.  2:        18        38
# chi2/DOF: 4.864; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 16; Func calls: 119; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.95      0.16      12    26
# Comp:  1                Halpha      97.60      0.16      12    26
# Comp:  2             [SII]6716      7.365      0.17      18    38
# Comp:  2             [SII]6731      4.847      0.17      18    38
# Comp:  2              HeII4687     0.3720      0.17      18    38
# Comp:  2               HeI5876      4.115      0.17      18    38
# Comp:  2          [OIII]5007_d      216.9      0.21      18    38
# Comp:  2            [OI]6300_d      1.732      0.21      18    38
# Comp:  2           [NII]6583_d      5.477      0.21      18    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -476       434
#  comp.  1:         9        30
#  comp.  2:        23        51
# chi2/DOF: 5.551; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      43.12      0.16       9    30
# Comp:  1                Halpha      99.13      0.16       9    30
# Comp:  2             [SII]6716      8.037      0.18      23    51
# Comp:  2             [SII]6731      4.430      0.18      23    51
# Comp:  2              HeII4687     0.3815      0.18      23    51
# Comp:  2               HeI5876      3.988      0.18      23    51
# Comp:  2          [OIII]5007_d      229.4      0.22      23    51
# Comp:  2            [OI]6300_d      1.883      0.22      23    51
# Comp:  2           [NII]6583_d      5.104      0.22      23    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86       663
#  comp.  1:        11        29
#  comp.  2:        19        44
# chi2/DOF: 5.486; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.85      0.16      11    29
# Comp:  1                Halpha      97.78      0.16      11    29
# Comp:  2             [SII]6716      7.560      0.17      19    44
# Comp:  2             [SII]6731      5.904      0.17      19    44
# Comp:  2              HeII4687     0.5950      0.17      19    44
# Comp:  2               HeI5876      4.275      0.17      19    44
# Comp:  2          [OIII]5007_d      220.5      0.22      19    44
# Comp:  2            [OI]6300_d      1.667      0.22      19    44
# Comp:  2           [NII]6583_d      5.086      0.22      19    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -303       182
#  comp.  1:        14        34
#  comp.  2:        16        42
# chi2/DOF: 3.939; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.32      0.17      14    34
# Comp:  1                Halpha      101.2      0.17      14    34
# Comp:  2             [SII]6716      8.708      0.17      16    42
# Comp:  2             [SII]6731      4.907      0.17      16    42
# Comp:  2              HeII4687     0.2852      0.17      16    42
# Comp:  2               HeI5876      4.092      0.17      16    42
# Comp:  2          [OIII]5007_d      215.1      0.21      16    42
# Comp:  2            [OI]6300_d      1.858      0.21      16    42
# Comp:  2           [NII]6583_d      5.245      0.21      16    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -247       418
#  comp.  1:         6        23
#  comp.  2:        26        51
# chi2/DOF: 4.260; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.63      0.16       6    23
# Comp:  1                Halpha      97.26      0.16       6    23
# Comp:  2             [SII]6716      7.727      0.18      26    51
# Comp:  2             [SII]6731      5.259      0.18      26    51
# Comp:  2              HeII4687     0.3412      0.18      26    51
# Comp:  2               HeI5876      3.949      0.18      26    51
# Comp:  2          [OIII]5007_d      234.2      0.22      26    51
# Comp:  2            [OI]6300_d      1.727      0.22      26    51
# Comp:  2           [NII]6583_d      5.539      0.22      26    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -225       422
#  comp.  1:        10        17
#  comp.  2:        25        47
# chi2/DOF: 5.370; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      35.94      0.16      10    17
# Comp:  1                Halpha      95.84      0.16      10    17
# Comp:  2             [SII]6716      8.339      0.17      25    47
# Comp:  2             [SII]6731      5.202      0.17      25    47
# Comp:  2              HeII4687     0.5209      0.17      25    47
# Comp:  2               HeI5876      4.160      0.17      25    47
# Comp:  2          [OIII]5007_d      225.8      0.22      25    47
# Comp:  2            [OI]6300_d      1.942      0.22      25    47
# Comp:  2           [NII]6583_d      4.408      0.22      25    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -237        39
#  comp.  1:        11        31
#  comp.  2:        20        44
# chi2/DOF: 5.849; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.96      0.16      11    31
# Comp:  1                Halpha      97.21      0.16      11    31
# Comp:  2             [SII]6716      7.784      0.17      20    44
# Comp:  2             [SII]6731      5.247      0.17      20    44
# Comp:  2              HeII4687     0.3895      0.17      20    44
# Comp:  2               HeI5876      3.743      0.17      20    44
# Comp:  2          [OIII]5007_d      224.2      0.22      20    44
# Comp:  2            [OI]6300_d      1.939      0.22      20    44
# Comp:  2           [NII]6583_d      4.629      0.22      20    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -348        71
#  comp.  1:        12        26
#  comp.  2:        26        48
# chi2/DOF: 5.389; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 35; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.66      0.16      12    26
# Comp:  1                Halpha      96.58      0.16      12    26
# Comp:  2             [SII]6716      8.329      0.17      26    48
# Comp:  2             [SII]6731      5.382      0.17      26    48
# Comp:  2              HeII4687     0.3582      0.17      26    48
# Comp:  2               HeI5876      3.800      0.17      26    48
# Comp:  2          [OIII]5007_d      229.8      0.22      26    48
# Comp:  2            [OI]6300_d      1.998      0.22      26    48
# Comp:  2           [NII]6583_d      4.547      0.22      26    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -374       305
#  comp.  1:        15        35
#  comp.  2:        22        46
# chi2/DOF: 5.232; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      44.49      0.17      15    35
# Comp:  1                Halpha      101.9      0.17      15    35
# Comp:  2             [SII]6716      6.522      0.17      22    46
# Comp:  2             [SII]6731      4.608      0.17      22    46
# Comp:  2              HeII4687     0.3090      0.17      22    46
# Comp:  2               HeI5876      4.225      0.17      22    46
# Comp:  2          [OIII]5007_d      230.5      0.22      22    46
# Comp:  2            [OI]6300_d      2.057      0.22      22    46
# Comp:  2           [NII]6583_d      5.107      0.22      22    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -168       395
#  comp.  1:        11        32
#  comp.  2:        22        41
# chi2/DOF: 5.581; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      37.35      0.16      11    32
# Comp:  1                Halpha      100.2      0.16      11    32
# Comp:  2             [SII]6716      8.086      0.17      22    41
# Comp:  2             [SII]6731      4.939      0.17      22    41
# Comp:  2              HeII4687     0.3096      0.17      22    41
# Comp:  2               HeI5876      3.653      0.17      22    41
# Comp:  2          [OIII]5007_d      216.4      0.21      22    41
# Comp:  2            [OI]6300_d      1.935      0.21      22    41
# Comp:  2           [NII]6583_d      4.394      0.21      22    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -583       318
#  comp.  1:        11        31
#  comp.  2:        24        51
# chi2/DOF: 5.488; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.67      0.16      11    31
# Comp:  1                Halpha      100.2      0.16      11    31
# Comp:  2             [SII]6716      6.290      0.18      24    51
# Comp:  2             [SII]6731      4.917      0.18      24    51
# Comp:  2              HeII4687     0.5836      0.18      24    51
# ...
# chi2/DOF: 5.303; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.01      0.16       8    21
# Comp:  1                Halpha      94.77      0.16       8    21
# Comp:  2             [SII]6716      7.680      0.17      26    43
# Comp:  2             [SII]6731      5.109      0.17      26    43
# Comp:  2              HeII4687     0.3553      0.17      26    43
# Comp:  2               HeI5876      4.090      0.17      26    43
# Comp:  2          [OIII]5007_d      222.8      0.22      26    43
# Comp:  2            [OI]6300_d      1.979      0.22      26    43
# Comp:  2           [NII]6583_d      5.017      0.22      26    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10       638
#  comp.  1:        11        32
#  comp.  2:        19        41
# chi2/DOF: 5.668; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.99      0.16      11    32
# Comp:  1                Halpha      100.1      0.16      11    32
# Comp:  2             [SII]6716      6.429      0.17      19    41
# Comp:  2             [SII]6731      5.219      0.17      19    41
# Comp:  2              HeII4687     0.5230      0.17      19    41
# Comp:  2               HeI5876      3.902      0.17      19    41
# Comp:  2          [OIII]5007_d      221.8      0.21      19    41
# Comp:  2            [OI]6300_d      1.720      0.21      19    41
# Comp:  2           [NII]6583_d      4.614      0.21      19    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -313       519
#  comp.  1:         9        16
#  comp.  2:        22        47
# chi2/DOF: 5.271; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      38.36      0.16       9    16
# Comp:  1                Halpha      93.50      0.16       9    16
# Comp:  2             [SII]6716      7.655      0.17      22    47
# Comp:  2             [SII]6731      4.995      0.17      22    47
# Comp:  2              HeII4687     0.4740      0.17      22    47
# Comp:  2               HeI5876      4.215      0.17      22    47
# Comp:  2          [OIII]5007_d      219.2      0.22      22    47
# Comp:  2            [OI]6300_d      1.834      0.22      22    47
# Comp:  2           [NII]6583_d      5.610      0.22      22    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        98         1
#  comp.  1:         8        19
#  comp.  2:        19        39
# chi2/DOF: 5.077; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.25      0.16       8    19
# Comp:  1                Halpha      96.80      0.16       8    19
# Comp:  2             [SII]6716      5.807      0.17      19    39
# Comp:  2             [SII]6731      5.684      0.17      19    39
# Comp:  2              HeII4687     0.2562      0.17      19    39
# Comp:  2               HeI5876      4.250      0.17      19    39
# Comp:  2          [OIII]5007_d      218.4      0.21      19    39
# Comp:  2            [OI]6300_d      1.794      0.21      19    39
# Comp:  2           [NII]6583_d      5.170      0.21      19    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -554       409
#  comp.  1:        13        32
#  comp.  2:        25        51
# chi2/DOF: 3.765; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      43.54      0.16      13    32
# Comp:  1                Halpha      101.7      0.16      13    32
# Comp:  2             [SII]6716      8.373      0.18      25    51
# Comp:  2             [SII]6731      5.640      0.18      25    51
# Comp:  2              HeII4687     0.5014      0.18      25    51
# Comp:  2               HeI5876      4.410      0.18      25    51
# Comp:  2          [OIII]5007_d      240.9      0.22      25    51
# Comp:  2            [OI]6300_d      2.016      0.22      25    51
# Comp:  2           [NII]6583_d      5.152      0.22      25    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -322        70
#  comp.  1:        11        27
#  comp.  2:        19        41
# chi2/DOF: 4.724; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      44.11      0.16      11    27
# Comp:  1                Halpha      96.72      0.16      11    27
# Comp:  2             [SII]6716      5.799      0.17      19    41
# Comp:  2             [SII]6731      5.792      0.17      19    41
# Comp:  2              HeII4687     0.3250      0.17      19    41
# Comp:  2               HeI5876      4.249      0.17      19    41
# Comp:  2          [OIII]5007_d      212.8      0.21      19    41
# Comp:  2            [OI]6300_d      1.673      0.21      19    41
# Comp:  2           [NII]6583_d      4.765      0.21      19    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       144         1
#  comp.  1:        12        32
#  comp.  2:        23        39
# chi2/DOF: 5.453; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 74; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      37.61      0.16      12    32
# Comp:  1                Halpha      102.2      0.16      12    32
# Comp:  2             [SII]6716      8.005      0.17      23    39
# Comp:  2             [SII]6731      5.000      0.17      23    39
# Comp:  2              HeII4687     0.4983      0.17      23    39
# Comp:  2               HeI5876      4.255      0.17      23    39
# Comp:  2          [OIII]5007_d      220.4      0.21      23    39
# Comp:  2            [OI]6300_d      1.933      0.21      23    39
# Comp:  2           [NII]6583_d      4.799      0.21      23    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -553       329
#  comp.  1:         9        26
#  comp.  2:        27        50
# chi2/DOF: 4.724; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      43.69      0.16       9    26
# Comp:  1                Halpha      98.62      0.16       9    26
# Comp:  2             [SII]6716      8.350      0.17      27    50
# Comp:  2             [SII]6731      5.196      0.17      27    50
# Comp:  2              HeII4687     0.6119      0.17      27    50
# Comp:  2               HeI5876      4.460      0.17      27    50
# Comp:  2          [OIII]5007_d      222.9      0.22      27    50
# Comp:  2            [OI]6300_d      1.789      0.22      27    50
# Comp:  2           [NII]6583_d      5.078      0.22      27    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -315       175
#  comp.  1:        15        35
#  comp.  2:        27        51
# chi2/DOF: 3.742; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      44.09      0.17      15    35
# Comp:  1                Halpha      100.8      0.17      15    35
# Comp:  2             [SII]6716      9.074      0.18      27    51
# Comp:  2             [SII]6731      4.598      0.18      27    51
# Comp:  2              HeII4687     0.5666      0.18      27    51
# Comp:  2               HeI5876      4.014      0.18      27    51
# Comp:  2          [OIII]5007_d      233.9      0.22      27    51
# Comp:  2            [OI]6300_d      1.922      0.22      27    51
# Comp:  2           [NII]6583_d      4.437      0.22      27    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -189         1
#  comp.  1:        16        37
#  comp.  2:        28        44
# chi2/DOF: 4.007; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.69      0.17      16    37
# Comp:  1                Halpha      101.7      0.17      16    37
# Comp:  2             [SII]6716      7.261      0.17      28    44
# Comp:  2             [SII]6731      4.189      0.17      28    44
# Comp:  2              HeII4687     0.4071      0.17      28    44
# Comp:  2               HeI5876      3.728      0.17      28    44
# Comp:  2          [OIII]5007_d      224.3      0.22      28    44
# Comp:  2            [OI]6300_d      1.713      0.22      28    44
# Comp:  2           [NII]6583_d      5.265      0.22      28    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        98         1
#  comp.  1:        12        30
#  comp.  2:        25        50
# chi2/DOF: 5.169; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 68; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.57      0.16      12    30
# Comp:  1                Halpha      101.0      0.16      12    30
# Comp:  2             [SII]6716      7.084      0.17      25    50
# Comp:  2             [SII]6731      5.791      0.17      25    50
# Comp:  2              HeII4687     0.5874      0.17      25    50
# Comp:  2               HeI5876      4.134      0.17      25    50
# Comp:  2          [OIII]5007_d      222.8      0.22      25    50
# Comp:  2            [OI]6300_d      1.715      0.22      25    50
# Comp:  2           [NII]6583_d      5.547      0.22      25    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -606       255
#  comp.  1:        10        29
#  comp.  2:        19        41
# chi2/DOF: 5.495; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.05      0.16      10    29
# Comp:  1                Halpha      98.46      0.16      10    29
# Comp:  2             [SII]6716      5.254      0.17      19    41
# Comp:  2             [SII]6731      5.120      0.17      19    41
# Comp:  2              HeII4687     0.4966      0.17      19    41
# Comp:  2               HeI5876      3.946      0.17      19    41
# Comp:  2          [OIII]5007_d      215.6      0.21      19    41
# Comp:  2            [OI]6300_d      1.853      0.21      19    41
# Comp:  2           [NII]6583_d      4.822      0.21      19    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -197       456
#  comp.  1:        13        35
#  comp.  2:        24        38
# chi2/DOF: 5.176; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      45.35      0.17      13    35
# Comp:  1                Halpha      99.77      0.17      13    35
# Comp:  2             [SII]6716      7.045      0.17      24    38
# Comp:  2             [SII]6731      4.675      0.17      24    38
# Comp:  2              HeII4687     0.5361      0.17      24    38
# Comp:  2               HeI5876      3.843      0.17      24    38
# Comp:  2          [OIII]5007_d      218.3      0.21      24    38
# Comp:  2            [OI]6300_d      1.869      0.21      24    38
# Comp:  2           [NII]6583_d      4.804      0.21      24    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -531       359
#  comp.  1:        11        26
#  comp.  2:        24        54
# chi2/DOF: 4.632; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.60      0.16      11    26
# Comp:  1                Halpha      98.54      0.16      11    26
# Comp:  2             [SII]6716      8.439      0.18      24    54
# Comp:  2             [SII]6731      6.032      0.18      24    54
# Comp:  2              HeII4687     0.3829      0.18      24    54
# Comp:  2               HeI5876      4.435      0.18      24    54
# Comp:  2          [OIII]5007_d      237.9      0.22      24    54
# Comp:  2            [OI]6300_d      1.953      0.22      24    54
# Comp:  2           [NII]6583_d      5.066      0.22      24    54
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_2_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_2_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_2_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_2_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_2_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
