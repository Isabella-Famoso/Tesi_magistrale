# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_1.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_1263/FORS2.2022-01-06T07_26_01.965/Spectra_extraction/redshift.txt")  
z = red[0][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.21714496 2.21788182 2.21861868 ... 3.53170494 3.5324418  3.53317866]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3136, 150)

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3136, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3136, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -112         1
# chi2/DOF: 0.01192; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -97         1
# chi2/DOF: 0.003840; DOF: 1885; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# [1.49538585 1.47057883 1.43437797 ... 0.84980205 1.28722782 1.32108379]
# [1.44826949 1.4584939  1.47177    ... 0.61911885 0.61616046 0.61582435]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-97.41994014,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:         9        26
#  comp.  2:         6        44
# chi2/DOF: 18.82; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      165.2      0.23       9    26
# Comp:  1                Halpha      314.5      0.23       9    26
# Comp:  2             [SII]6716      18.91      0.24       6    44
# Comp:  2             [SII]6731      14.11      0.24       6    44
# Comp:  2              HeII4687     0.5224      0.24       6    44
# Comp:  2               HeI5876      15.22      0.24       6    44
# Comp:  2          [OIII]5007_d      1153.      0.30       6    44
# Comp:  2            [OI]6300_d      5.370      0.30       6    44
# Comp:  2           [NII]6583_d      14.02      0.30       6    44
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  799.1; gas flux:    168 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:   1557; gas flux:    431 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  84.52; gas flux:     26 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  61.94; gas flux:     20 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  2.307; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  66.72; gas flux:     19 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   3705; gas flux:   1204 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  17.44; gas flux:      7 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  46.95; gas flux:     19 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        23
#  comp.  1:         8        20
#  comp.  2:         7        44
# chi2/DOF: 16.47; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 30; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      154.0      0.22       8    20
# Comp:  1                Halpha      309.8      0.22       8    20
# Comp:  2             [SII]6716      17.76      0.24       7    44
# Comp:  2             [SII]6731      14.19      0.24       7    44
# Comp:  2              HeII4687     0.5150      0.24       7    44
# Comp:  2               HeI5876      14.06      0.24       7    44
# Comp:  2          [OIII]5007_d      1155.      0.30       7    44
# Comp:  2            [OI]6300_d      5.938      0.30       7    44
# Comp:  2           [NII]6583_d      13.83      0.30       7    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       116         1
#  comp.  1:        10        29
#  comp.  2:         8        41
# chi2/DOF: 15.08; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      162.9      0.23      10    29
# Comp:  1                Halpha      317.9      0.23      10    29
# Comp:  2             [SII]6716      20.93      0.24       8    41
# Comp:  2             [SII]6731      13.87      0.24       8    41
# Comp:  2              HeII4687     0.3172      0.24       8    41
# Comp:  2               HeI5876      14.13      0.24       8    41
# Comp:  2          [OIII]5007_d      1160.      0.30       8    41
# Comp:  2            [OI]6300_d      4.724      0.30       8    41
# Comp:  2           [NII]6583_d      14.25      0.30       8    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83         1
#  comp.  1:        10        30
#  comp.  2:         6        41
# chi2/DOF: 14.73; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      158.6      0.23      10    30
# Comp:  1                Halpha      315.2      0.23      10    30
# Comp:  2             [SII]6716      17.94      0.24       6    41
# Comp:  2             [SII]6731      15.16      0.24       6    41
# Comp:  2              HeII4687     0.3521      0.24       6    41
# Comp:  2               HeI5876      15.65      0.24       6    41
# Comp:  2          [OIII]5007_d      1159.      0.30       6    41
# Comp:  2            [OI]6300_d      4.570      0.30       6    41
# Comp:  2           [NII]6583_d      13.33      0.30       6    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0         1
#  comp.  1:         9        33
#  comp.  2:         5        44
# chi2/DOF: 17.02; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      165.8      0.23       9    33
# Comp:  1                Halpha      321.5      0.23       9    33
# Comp:  2             [SII]6716      17.17      0.24       5    44
# Comp:  2             [SII]6731      14.40      0.24       5    44
# Comp:  2              HeII4687     0.4761      0.24       5    44
# Comp:  2               HeI5876      15.14      0.24       5    44
# Comp:  2          [OIII]5007_d      1147.      0.30       5    44
# Comp:  2            [OI]6300_d      5.927      0.30       5    44
# Comp:  2           [NII]6583_d      13.88      0.30       5    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       110         1
#  comp.  1:         9        29
#  comp.  2:         8        43
# chi2/DOF: 15.79; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      171.4      0.23       9    29
# Comp:  1                Halpha      314.8      0.23       9    29
# Comp:  2             [SII]6716      21.29      0.24       8    43
# Comp:  2             [SII]6731      13.72      0.24       8    43
# Comp:  2              HeII4687     0.3033      0.24       8    43
# Comp:  2               HeI5876      15.64      0.24       8    43
# Comp:  2          [OIII]5007_d      1152.      0.30       8    43
# Comp:  2            [OI]6300_d      5.232      0.30       8    43
# Comp:  2           [NII]6583_d      13.65      0.30       8    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -93       134
#  comp.  1:        10        24
#  comp.  2:         6        42
# chi2/DOF: 15.75; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      160.7      0.23      10    24
# Comp:  1                Halpha      312.1      0.23      10    24
# Comp:  2             [SII]6716      18.34      0.24       6    42
# Comp:  2             [SII]6731      13.33      0.24       6    42
# Comp:  2              HeII4687     0.6221      0.24       6    42
# Comp:  2               HeI5876      13.44      0.24       6    42
# Comp:  2          [OIII]5007_d      1124.      0.30       6    42
# Comp:  2            [OI]6300_d      5.484      0.30       6    42
# Comp:  2           [NII]6583_d      13.36      0.30       6    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       160         1
#  comp.  1:         9        14
#  comp.  2:         5        45
# chi2/DOF: 15.77; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      155.6      0.22       9    14
# Comp:  1                Halpha      307.5      0.22       9    14
# Comp:  2             [SII]6716      21.61      0.24       5    45
# Comp:  2             [SII]6731      14.45      0.24       5    45
# Comp:  2              HeII4687     0.6453      0.24       5    45
# Comp:  2               HeI5876      15.38      0.24       5    45
# Comp:  2          [OIII]5007_d      1160.      0.30       5    45
# Comp:  2            [OI]6300_d      5.260      0.30       5    45
# Comp:  2           [NII]6583_d      14.33      0.30       5    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       132       521
#  comp.  1:         8        12
#  comp.  2:         7        45
# chi2/DOF: 15.01; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      164.2      0.22       8    12
# Comp:  1                Halpha      308.6      0.22       8    12
# Comp:  2             [SII]6716      21.39      0.24       7    45
# Comp:  2             [SII]6731      13.23      0.24       7    45
# Comp:  2              HeII4687     0.5042      0.24       7    45
# Comp:  2               HeI5876      15.89      0.24       7    45
# Comp:  2          [OIII]5007_d      1148.      0.30       7    45
# Comp:  2            [OI]6300_d      4.562      0.30       7    45
# Comp:  2           [NII]6583_d      14.47      0.30       7    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       118         1
#  comp.  1:        11        30
#  comp.  2:         6        41
# chi2/DOF: 16.77; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      170.5      0.23      11    30
# Comp:  1                Halpha      321.8      0.23      11    30
# Comp:  2             [SII]6716      21.20      0.24       6    41
# Comp:  2             [SII]6731      12.82      0.24       6    41
# Comp:  2              HeII4687     0.5452      0.24       6    41
# Comp:  2               HeI5876      16.82      0.24       6    41
# Comp:  2          [OIII]5007_d      1153.      0.30       6    41
# Comp:  2            [OI]6300_d      5.243      0.30       6    41
# Comp:  2           [NII]6583_d      14.22      0.30       6    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12         1
#  comp.  1:         9        20
#  comp.  2:         5        39
# chi2/DOF: 13.54; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      171.7      0.22       9    20
# Comp:  1                Halpha      301.6      0.22       9    20
# Comp:  2             [SII]6716      18.00      0.24       5    39
# Comp:  2             [SII]6731      14.49      0.24       5    39
# Comp:  2              HeII4687     0.4683      0.24       5    39
# Comp:  2               HeI5876      16.58      0.24       5    39
# Comp:  2          [OIII]5007_d      1147.      0.30       5    39
# Comp:  2            [OI]6300_d      4.640      0.30       5    39
# Comp:  2           [NII]6583_d      14.71      0.30       5    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        99         1
#  comp.  1:         9        26
#  comp.  2:         8        42
# chi2/DOF: 14.86; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      171.2      0.23       9    26
# Comp:  1                Halpha      317.4      0.23       9    26
# Comp:  2             [SII]6716      21.15      0.24       8    42
# Comp:  2             [SII]6731      12.72      0.24       8    42
# Comp:  2              HeII4687     0.4188      0.24       8    42
# Comp:  2               HeI5876      16.58      0.24       8    42
# Comp:  2          [OIII]5007_d      1165.      0.30       8    42
# Comp:  2            [OI]6300_d      5.178      0.30       8    42
# Comp:  2           [NII]6583_d      14.93      0.30       8    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       453      1000
#  comp.  1:        14        36
#  comp.  2:         7        46
# chi2/DOF: 9.675; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      167.3      0.23      14    36
# Comp:  1                Halpha      326.8      0.23      14    36
# Comp:  2             [SII]6716      20.29      0.24       7    46
# Comp:  2             [SII]6731      13.23      0.24       7    46
# Comp:  2              HeII4687     0.4255      0.24       7    46
# Comp:  2               HeI5876      17.11      0.24       7    46
# Comp:  2          [OIII]5007_d      1190.      0.31       7    46
# Comp:  2            [OI]6300_d      5.409      0.31       7    46
# Comp:  2           [NII]6583_d      13.91      0.31       7    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        49         1
#  comp.  1:         7        18
#  comp.  2:         7        43
# chi2/DOF: 15.42; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      157.9      0.22       7    18
# Comp:  1                Halpha      303.8      0.22       7    18
# Comp:  2             [SII]6716      19.72      0.24       7    43
# Comp:  2             [SII]6731      15.17      0.24       7    43
# Comp:  2              HeII4687     0.2746      0.24       7    43
# Comp:  2               HeI5876      15.84      0.24       7    43
# Comp:  2          [OIII]5007_d      1148.      0.30       7    43
# Comp:  2            [OI]6300_d      4.687      0.30       7    43
# Comp:  2           [NII]6583_d      14.48      0.30       7    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:        11        29
#  comp.  2:         5        42
# chi2/DOF: 14.78; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      158.4      0.23      11    29
# Comp:  1                Halpha      324.0      0.23      11    29
# Comp:  2             [SII]6716      19.60      0.24       5    42
# Comp:  2             [SII]6731      13.52      0.24       5    42
# Comp:  2              HeII4687     0.6242      0.24       5    42
# Comp:  2               HeI5876      15.12      0.24       5    42
# Comp:  2          [OIII]5007_d      1137.      0.30       5    42
# Comp:  2            [OI]6300_d      5.380      0.30       5    42
# Comp:  2           [NII]6583_d      13.83      0.30       5    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        90       800
#  comp.  1:         8        26
#  comp.  2:         4        47
# chi2/DOF: 13.80; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      174.0      0.23       8    26
# Comp:  1                Halpha      309.0      0.23       8    26
# Comp:  2             [SII]6716      17.64      0.24       4    47
# Comp:  2             [SII]6731      13.16      0.24       4    47
# Comp:  2              HeII4687     0.5347      0.24       4    47
# Comp:  2               HeI5876      14.91      0.24       4    47
# Comp:  2          [OIII]5007_d      1169.      0.31       4    47
# Comp:  2            [OI]6300_d      5.265      0.31       4    47
# Comp:  2           [NII]6583_d      15.26      0.31       4    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -165         1
#  comp.  1:         8        22
#  comp.  2:         5        46
# chi2/DOF: 15.47; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      169.9      0.22       8    22
# Comp:  1                Halpha      305.5      0.22       8    22
# Comp:  2             [SII]6716      18.65      0.24       5    46
# Comp:  2             [SII]6731      14.00      0.24       5    46
# Comp:  2              HeII4687     0.6252      0.24       5    46
# Comp:  2               HeI5876      16.51      0.24       5    46
# Comp:  2          [OIII]5007_d      1172.      0.31       5    46
# Comp:  2            [OI]6300_d      5.350      0.31       5    46
# Comp:  2           [NII]6583_d      14.21      0.31       5    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -134         1
#  comp.  1:        11        24
#  comp.  2:         8        41
# chi2/DOF: 15.97; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      164.3      0.23      11    24
# Comp:  1                Halpha      313.1      0.23      11    24
# Comp:  2             [SII]6716      18.50      0.24       8    41
# Comp:  2             [SII]6731      13.78      0.24       8    41
# Comp:  2              HeII4687     0.5453      0.24       8    41
# Comp:  2               HeI5876      13.38      0.24       8    41
# Comp:  2          [OIII]5007_d      1145.      0.30       8    41
# Comp:  2            [OI]6300_d      6.093      0.30       8    41
# Comp:  2           [NII]6583_d      14.20      0.30       8    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
#  comp.  1:        12        35
#  comp.  2:         5        42
# chi2/DOF: 12.00; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 60; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      182.3      0.23      12    35
# Comp:  1                Halpha      328.4      0.23      12    35
# Comp:  2             [SII]6716      18.70      0.24       5    42
# Comp:  2             [SII]6731      12.94      0.24       5    42
# Comp:  2              HeII4687     0.3600      0.24       5    42
# Comp:  2               HeI5876      16.63      0.24       5    42
# Comp:  2          [OIII]5007_d      1124.      0.30       5    42
# Comp:  2            [OI]6300_d      5.915      0.30       5    42
# Comp:  2           [NII]6583_d      13.72      0.30       5    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      1940       443
#  comp.  1:         8        23
#  comp.  2:         6        45
# chi2/DOF: 16.71; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      172.3      0.23       8    23
# Comp:  1                Halpha      303.9      0.23       8    23
# Comp:  2             [SII]6716      18.69      0.24       6    45
# Comp:  2             [SII]6731      15.48      0.24       6    45
# Comp:  2              HeII4687     0.5512      0.24       6    45
# Comp:  2               HeI5876      16.47      0.24       6    45
# Comp:  2          [OIII]5007_d      1163.      0.30       6    45
# Comp:  2            [OI]6300_d      5.474      0.30       6    45
# Comp:  2           [NII]6583_d      14.47      0.30       6    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39       998
#  comp.  1:        13        34
#  comp.  2:         7        46
# chi2/DOF: 13.42; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      169.1      0.23      13    34
# Comp:  1                Halpha      327.1      0.23      13    34
# Comp:  2             [SII]6716      17.89      0.24       7    46
# Comp:  2             [SII]6731      14.07      0.24       7    46
# Comp:  2              HeII4687     0.4173      0.24       7    46
# Comp:  2               HeI5876      15.90      0.24       7    46
# Comp:  2          [OIII]5007_d      1144.      0.31       7    46
# Comp:  2            [OI]6300_d      5.501      0.31       7    46
# Comp:  2           [NII]6583_d      15.07      0.31       7    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -175       371
#  comp.  1:        12        35
#  comp.  2:         8        46
# chi2/DOF: 13.20; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      180.4      0.23      12    35
# Comp:  1                Halpha      332.1      0.23      12    35
# Comp:  2             [SII]6716      17.94      0.24       8    46
# Comp:  2             [SII]6731      13.34      0.24       8    46
# Comp:  2              HeII4687     0.5192      0.24       8    46
# Comp:  2               HeI5876      14.80      0.24       8    46
# Comp:  2          [OIII]5007_d      1158.      0.31       8    46
# Comp:  2            [OI]6300_d      6.012      0.31       8    46
# Comp:  2           [NII]6583_d      13.69      0.31       8    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -217         1
#  comp.  1:         9        25
#  comp.  2:         6        40
# chi2/DOF: 13.04; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      164.5      0.23       9    25
# Comp:  1                Halpha      308.8      0.23       9    25
# Comp:  2             [SII]6716      17.91      0.24       6    40
# Comp:  2             [SII]6731      12.96      0.24       6    40
# Comp:  2              HeII4687     0.6259      0.24       6    40
# Comp:  2               HeI5876      15.48      0.24       6    40
# Comp:  2          [OIII]5007_d      1113.      0.30       6    40
# Comp:  2            [OI]6300_d      4.517      0.30       6    40
# Comp:  2           [NII]6583_d      13.38      0.30       6    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17         1
#  comp.  1:         8        18
#  comp.  2:         6        46
# chi2/DOF: 15.47; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      155.3      0.22       8    18
# Comp:  1                Halpha      311.3      0.22       8    18
# Comp:  2             [SII]6716      16.34      0.24       6    46
# Comp:  2             [SII]6731      15.13      0.24       6    46
# Comp:  2              HeII4687     0.4994      0.24       6    46
# Comp:  2               HeI5876      14.08      0.24       6    46
# Comp:  2          [OIII]5007_d      1148.      0.31       6    46
# Comp:  2            [OI]6300_d      4.791      0.31       6    46
# Comp:  2           [NII]6583_d      13.33      0.31       6    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -222       537
#  comp.  1:        11        32
#  comp.  2:         6        43
# chi2/DOF: 14.83; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      178.5      0.23      11    32
# Comp:  1                Halpha      318.8      0.23      11    32
# Comp:  2             [SII]6716      19.38      0.24       6    43
# Comp:  2             [SII]6731      15.14      0.24       6    43
# Comp:  2              HeII4687     0.6590      0.24       6    43
# Comp:  2               HeI5876      14.78      0.24       6    43
# Comp:  2          [OIII]5007_d      1129.      0.30       6    43
# Comp:  2            [OI]6300_d      6.093      0.30       6    43
# Comp:  2           [NII]6583_d      13.86      0.30       6    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        77         1
#  comp.  1:         7        15
#  comp.  2:         6        41
# chi2/DOF: 14.70; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      152.7      0.22       7    15
# Comp:  1                Halpha      302.8      0.22       7    15
# Comp:  2             [SII]6716      19.62      0.24       6    41
# Comp:  2             [SII]6731      14.72      0.24       6    41
# Comp:  2              HeII4687     0.3800      0.24       6    41
# Comp:  2               HeI5876      15.07      0.24       6    41
# Comp:  2          [OIII]5007_d      1155.      0.30       6    41
# Comp:  2            [OI]6300_d      5.303      0.30       6    41
# Comp:  2           [NII]6583_d      13.64      0.30       6    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       198         1
#  comp.  1:         7        12
#  comp.  2:         7        44
# chi2/DOF: 14.96; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 93; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      161.7      0.22       7    12
# Comp:  1                Halpha      301.7      0.22       7    12
# Comp:  2             [SII]6716      18.15      0.24       7    44
# Comp:  2             [SII]6731      15.25      0.24       7    44
# Comp:  2              HeII4687     0.6173      0.24       7    44
# Comp:  2               HeI5876      15.65      0.24       7    44
# Comp:  2          [OIII]5007_d      1155.      0.30       7    44
# Comp:  2            [OI]6300_d      5.326      0.30       7    44
# Comp:  2           [NII]6583_d      13.63      0.30       7    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:         7        21
#  comp.  2:         8        45
# chi2/DOF: 13.46; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      153.9      0.22       7    21
# Comp:  1                Halpha      310.7      0.22       7    21
# Comp:  2             [SII]6716      20.73      0.24       8    45
# Comp:  2             [SII]6731      14.60      0.24       8    45
# Comp:  2              HeII4687     0.3414      0.24       8    45
# Comp:  2               HeI5876      15.68      0.24       8    45
# Comp:  2          [OIII]5007_d      1142.      0.30       8    45
# Comp:  2            [OI]6300_d      6.184      0.30       8    45
# Comp:  2           [NII]6583_d      14.09      0.30       8    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -180         1
#  comp.  1:         8        22
#  comp.  2:         7        46
# chi2/DOF: 16.34; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      163.4      0.23       8    22
# Comp:  1                Halpha      308.9      0.23       8    22
# Comp:  2             [SII]6716      18.95      0.24       7    46
# Comp:  2             [SII]6731      15.41      0.24       7    46
# Comp:  2              HeII4687     0.4002      0.24       7    46
# Comp:  2               HeI5876      13.60      0.24       7    46
# Comp:  2          [OIII]5007_d      1154.      0.31       7    46
# Comp:  2            [OI]6300_d      5.416      0.31       7    46
# Comp:  2           [NII]6583_d      14.49      0.31       7    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:         8        23
#  comp.  2:         7        44
# chi2/DOF: 16.67; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      161.2      0.23       8    23
# Comp:  1                Halpha      308.0      0.23       8    23
# Comp:  2             [SII]6716      19.64      0.24       7    44
# Comp:  2             [SII]6731      14.22      0.24       7    44
# Comp:  2              HeII4687     0.5689      0.24       7    44
# Comp:  2               HeI5876      16.89      0.24       7    44
# Comp:  2          [OIII]5007_d      1138.      0.30       7    44
# Comp:  2            [OI]6300_d      4.745      0.30       7    44
# Comp:  2           [NII]6583_d      13.95      0.30       7    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -122         1
#  comp.  1:         9        25
#  comp.  2:         6        45
# chi2/DOF: 18.13; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      164.6      0.23       9    25
# Comp:  1                Halpha      316.7      0.23       9    25
# Comp:  2             [SII]6716      17.19      0.24       6    45
# Comp:  2             [SII]6731      14.10      0.24       6    45
# Comp:  2              HeII4687     0.7586      0.24       6    45
# Comp:  2               HeI5876      15.24      0.24       6    45
# Comp:  2          [OIII]5007_d      1160.      0.30       6    45
# Comp:  2            [OI]6300_d      5.746      0.30       6    45
# Comp:  2           [NII]6583_d      14.10      0.30       6    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       166         1
#  comp.  1:         8        17
#  comp.  2:         6        41
# chi2/DOF: 15.55; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      163.4      0.22       8    17
# Comp:  1                Halpha      306.4      0.22       8    17
# Comp:  2             [SII]6716      20.47      0.24       6    41
# Comp:  2             [SII]6731      14.42      0.24       6    41
# Comp:  2              HeII4687     0.4943      0.24       6    41
# Comp:  2               HeI5876      16.84      0.24       6    41
# Comp:  2          [OIII]5007_d      1136.      0.30       6    41
# Comp:  2            [OI]6300_d      5.422      0.30       6    41
# Comp:  2           [NII]6583_d      14.10      0.30       6    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51         1
#  comp.  1:         9        26
#  comp.  2:         6        39
# chi2/DOF: 14.86; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      166.5      0.23       9    26
# Comp:  1                Halpha      311.0      0.23       9    26
# Comp:  2             [SII]6716      19.41      0.24       6    39
# Comp:  2             [SII]6731      14.00      0.24       6    39
# Comp:  2              HeII4687     0.4014      0.24       6    39
# Comp:  2               HeI5876      16.13      0.24       6    39
# Comp:  2          [OIII]5007_d      1141.      0.30       6    39
# Comp:  2            [OI]6300_d      4.640      0.30       6    39
# Comp:  2           [NII]6583_d      14.83      0.30       6    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       403       865
#  comp.  1:         7        24
#  comp.  2:         6        46
# chi2/DOF: 16.22; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      169.7      0.23       7    24
# Comp:  1                Halpha      310.8      0.23       7    24
# Comp:  2             [SII]6716      19.94      0.24       6    46
# Comp:  2             [SII]6731      13.08      0.24       6    46
# Comp:  2              HeII4687     0.6960      0.24       6    46
# Comp:  2               HeI5876      13.72      0.24       6    46
# Comp:  2          [OIII]5007_d      1163.      0.31       6    46
# Comp:  2            [OI]6300_d      6.154      0.31       6    46
# Comp:  2           [NII]6583_d      14.33      0.31       6    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        73       705
#  comp.  1:        10        30
#  comp.  2:         6        42
# chi2/DOF: 17.55; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      160.8      0.23      10    30
# Comp:  1                Halpha      315.1      0.23      10    30
# Comp:  2             [SII]6716      19.30      0.24       6    42
# Comp:  2             [SII]6731      15.05      0.24       6    42
# Comp:  2              HeII4687     0.5221      0.24       6    42
# Comp:  2               HeI5876      16.49      0.24       6    42
# Comp:  2          [OIII]5007_d      1146.      0.30       6    42
# Comp:  2            [OI]6300_d      5.079      0.30       6    42
# Comp:  2           [NII]6583_d      15.13      0.30       6    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
#  comp.  1:        13        34
#  comp.  2:         5        41
# chi2/DOF: 13.50; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      171.1      0.23      13    34
# Comp:  1                Halpha      328.8      0.23      13    34
# Comp:  2             [SII]6716      21.26      0.24       5    41
# Comp:  2             [SII]6731      14.23      0.24       5    41
# Comp:  2              HeII4687     0.6112      0.24       5    41
# Comp:  2               HeI5876      14.94      0.24       5    41
# Comp:  2          [OIII]5007_d      1136.      0.30       5    41
# Comp:  2            [OI]6300_d      5.553      0.30       5    41
# Comp:  2           [NII]6583_d      14.72      0.30       5    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -108         1
#  comp.  1:         6        16
#  comp.  2:         7        46
# chi2/DOF: 13.69; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      165.2      0.22       6    16
# Comp:  1                Halpha      306.0      0.22       6    16
# Comp:  2             [SII]6716      19.66      0.24       7    46
# Comp:  2             [SII]6731      14.63      0.24       7    46
# Comp:  2              HeII4687     0.5844      0.24       7    46
# Comp:  2               HeI5876      14.32      0.24       7    46
# Comp:  2          [OIII]5007_d      1158.      0.31       7    46
# Comp:  2            [OI]6300_d      5.361      0.31       7    46
# Comp:  2           [NII]6583_d      15.06      0.31       7    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26       710
#  comp.  1:         9        15
#  comp.  2:         7        48
# chi2/DOF: 13.50; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      154.7      0.22       9    15
# Comp:  1                Halpha      307.7      0.22       9    15
# Comp:  2             [SII]6716      20.96      0.24       7    48
# Comp:  2             [SII]6731      14.86      0.24       7    48
# Comp:  2              HeII4687     0.6106      0.24       7    48
# Comp:  2               HeI5876      16.23      0.24       7    48
# Comp:  2          [OIII]5007_d      1167.      0.31       7    48
# Comp:  2            [OI]6300_d      5.527      0.31       7    48
# Comp:  2           [NII]6583_d      14.64      0.31       7    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -110         1
#  comp.  1:         9        27
#  comp.  2:         5        43
# chi2/DOF: 17.82; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      165.9      0.23       9    27
# Comp:  1                Halpha      307.4      0.23       9    27
# Comp:  2             [SII]6716      19.64      0.24       5    43
# Comp:  2             [SII]6731      13.91      0.24       5    43
# Comp:  2              HeII4687     0.6535      0.24       5    43
# Comp:  2               HeI5876      14.23      0.24       5    43
# Comp:  2          [OIII]5007_d      1153.      0.30       5    43
# Comp:  2            [OI]6300_d      5.393      0.30       5    43
# Comp:  2           [NII]6583_d      14.11      0.30       5    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48       260
#  comp.  1:        10        25
#  comp.  2:         8        43
# chi2/DOF: 17.14; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      161.3      0.23      10    25
# Comp:  1                Halpha      310.8      0.23      10    25
# Comp:  2             [SII]6716      20.46      0.24       8    43
# Comp:  2             [SII]6731      13.90      0.24       8    43
# Comp:  2              HeII4687     0.6351      0.24       8    43
# Comp:  2               HeI5876      14.06      0.24       8    43
# Comp:  2          [OIII]5007_d      1157.      0.30       8    43
# Comp:  2            [OI]6300_d      6.070      0.30       8    43
# Comp:  2           [NII]6583_d      13.25      0.30       8    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:        13        34
#  comp.  2:         6        47
# chi2/DOF: 13.33; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      180.3      0.23      13    34
# Comp:  1                Halpha      329.1      0.23      13    34
# Comp:  2             [SII]6716      18.46      0.24       6    47
# Comp:  2             [SII]6731      13.15      0.24       6    47
# Comp:  2              HeII4687     0.5175      0.24       6    47
# Comp:  2               HeI5876      15.98      0.24       6    47
# Comp:  2          [OIII]5007_d      1175.      0.31       6    47
# Comp:  2            [OI]6300_d      6.265      0.31       6    47
# Comp:  2           [NII]6583_d      14.65      0.31       6    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -93       604
#  comp.  1:        10        30
#  comp.  2:         8        42
# chi2/DOF: 16.67; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      160.9      0.23      10    30
# Comp:  1                Halpha      317.4      0.23      10    30
# Comp:  2             [SII]6716      20.57      0.24       8    42
# Comp:  2             [SII]6731      13.76      0.24       8    42
# Comp:  2              HeII4687     0.7160      0.24       8    42
# Comp:  2               HeI5876      13.15      0.24       8    42
# Comp:  2          [OIII]5007_d      1143.      0.30       8    42
# Comp:  2            [OI]6300_d      5.332      0.30       8    42
# Comp:  2           [NII]6583_d      14.10      0.30       8    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80        27
#  comp.  1:        10        25
#  comp.  2:         7        46
# chi2/DOF: 17.18; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      164.4      0.23      10    25
# Comp:  1                Halpha      316.3      0.23      10    25
# Comp:  2             [SII]6716      17.67      0.24       7    46
# Comp:  2             [SII]6731      13.32      0.24       7    46
# Comp:  2              HeII4687     0.4125      0.24       7    46
# Comp:  2               HeI5876      14.93      0.24       7    46
# ...
#  comp.  2:         7        44
# chi2/DOF: 17.19; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      170.1      0.23       8    23
# Comp:  1                Halpha      304.2      0.23       8    23
# Comp:  2             [SII]6716      19.66      0.24       7    44
# Comp:  2             [SII]6731      15.12      0.24       7    44
# Comp:  2              HeII4687     0.6961      0.24       7    44
# Comp:  2               HeI5876      16.83      0.24       7    44
# Comp:  2          [OIII]5007_d      1160.      0.30       7    44
# Comp:  2            [OI]6300_d      4.913      0.30       7    44
# Comp:  2           [NII]6583_d      13.54      0.30       7    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       163         1
#  comp.  1:         9        30
#  comp.  2:         6        42
# chi2/DOF: 16.35; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      159.3      0.23       9    30
# Comp:  1                Halpha      316.9      0.23       9    30
# Comp:  2             [SII]6716      17.35      0.24       6    42
# Comp:  2             [SII]6731      15.22      0.24       6    42
# Comp:  2              HeII4687     0.3989      0.24       6    42
# Comp:  2               HeI5876      17.46      0.24       6    42
# Comp:  2          [OIII]5007_d      1162.      0.30       6    42
# Comp:  2            [OI]6300_d      4.602      0.30       6    42
# Comp:  2           [NII]6583_d      14.38      0.30       6    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       122         1
#  comp.  1:        10        33
#  comp.  2:         6        43
# chi2/DOF: 15.29; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 19; Func calls: 140; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      162.2      0.23      10    33
# Comp:  1                Halpha      326.9      0.23      10    33
# Comp:  2             [SII]6716      19.08      0.24       6    43
# Comp:  2             [SII]6731      13.62      0.24       6    43
# Comp:  2              HeII4687     0.4842      0.24       6    43
# Comp:  2               HeI5876      15.37      0.24       6    43
# Comp:  2          [OIII]5007_d      1133.      0.30       6    43
# Comp:  2            [OI]6300_d      5.306      0.30       6    43
# Comp:  2           [NII]6583_d      13.73      0.30       6    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         8
#  comp.  1:        10        34
#  comp.  2:         5        45
# chi2/DOF: 14.16; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      160.7      0.23      10    34
# Comp:  1                Halpha      327.3      0.23      10    34
# Comp:  2             [SII]6716      20.84      0.24       5    45
# Comp:  2             [SII]6731      13.19      0.24       5    45
# Comp:  2              HeII4687     0.3662      0.24       5    45
# Comp:  2               HeI5876      14.84      0.24       5    45
# Comp:  2          [OIII]5007_d      1175.      0.30       5    45
# Comp:  2            [OI]6300_d      5.953      0.30       5    45
# Comp:  2           [NII]6583_d      13.33      0.30       5    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -105         1
#  comp.  1:        12        33
#  comp.  2:         5        45
# chi2/DOF: 14.91; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      176.5      0.23      12    33
# Comp:  1                Halpha      325.2      0.23      12    33
# Comp:  2             [SII]6716      21.56      0.24       5    45
# Comp:  2             [SII]6731      13.82      0.24       5    45
# Comp:  2              HeII4687     0.4333      0.24       5    45
# Comp:  2               HeI5876      14.18      0.24       5    45
# Comp:  2          [OIII]5007_d      1161.      0.30       5    45
# Comp:  2            [OI]6300_d      4.746      0.30       5    45
# Comp:  2           [NII]6583_d      13.53      0.30       5    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15         1
#  comp.  1:         9        28
#  comp.  2:         5        45
# chi2/DOF: 17.61; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      168.1      0.23       9    28
# Comp:  1                Halpha      316.9      0.23       9    28
# Comp:  2             [SII]6716      18.13      0.24       5    45
# Comp:  2             [SII]6731      14.39      0.24       5    45
# Comp:  2              HeII4687     0.4804      0.24       5    45
# Comp:  2               HeI5876      14.28      0.24       5    45
# Comp:  2          [OIII]5007_d      1164.      0.30       5    45
# Comp:  2            [OI]6300_d      5.264      0.30       5    45
# Comp:  2           [NII]6583_d      14.82      0.30       5    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -145         1
#  comp.  1:         9        25
#  comp.  2:         7        44
# chi2/DOF: 17.13; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      174.4      0.23       9    25
# Comp:  1                Halpha      313.5      0.23       9    25
# Comp:  2             [SII]6716      19.28      0.24       7    44
# Comp:  2             [SII]6731      14.30      0.24       7    44
# Comp:  2              HeII4687     0.5809      0.24       7    44
# Comp:  2               HeI5876      16.25      0.24       7    44
# Comp:  2          [OIII]5007_d      1157.      0.30       7    44
# Comp:  2            [OI]6300_d      5.345      0.30       7    44
# Comp:  2           [NII]6583_d      14.49      0.30       7    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        99         1
#  comp.  1:         9        28
#  comp.  2:         8        45
# chi2/DOF: 15.07; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      169.7      0.23       9    28
# Comp:  1                Halpha      315.8      0.23       9    28
# Comp:  2             [SII]6716      17.97      0.24       8    45
# Comp:  2             [SII]6731      14.01      0.24       8    45
# Comp:  2              HeII4687     0.4761      0.24       8    45
# Comp:  2               HeI5876      15.31      0.24       8    45
# Comp:  2          [OIII]5007_d      1142.      0.30       8    45
# Comp:  2            [OI]6300_d      4.486      0.30       8    45
# Comp:  2           [NII]6583_d      14.84      0.30       8    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10      1000
#  comp.  1:        14        35
#  comp.  2:         9        44
# chi2/DOF: 12.51; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      166.8      0.23      14    35
# Comp:  1                Halpha      324.6      0.23      14    35
# Comp:  2             [SII]6716      16.48      0.24       9    44
# Comp:  2             [SII]6731      13.80      0.24       9    44
# Comp:  2              HeII4687     0.5706      0.24       9    44
# Comp:  2               HeI5876      14.52      0.24       9    44
# Comp:  2          [OIII]5007_d      1156.      0.30       9    44
# Comp:  2            [OI]6300_d      5.897      0.30       9    44
# Comp:  2           [NII]6583_d      13.95      0.30       9    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -140         1
#  comp.  1:        12        34
#  comp.  2:         5        44
# chi2/DOF: 16.51; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 69; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      166.6      0.23      12    34
# Comp:  1                Halpha      321.6      0.23      12    34
# Comp:  2             [SII]6716      19.28      0.24       5    44
# Comp:  2             [SII]6731      13.06      0.24       5    44
# Comp:  2              HeII4687     0.5945      0.24       5    44
# Comp:  2               HeI5876      15.65      0.24       5    44
# Comp:  2          [OIII]5007_d      1152.      0.30       5    44
# Comp:  2            [OI]6300_d      4.794      0.30       5    44
# Comp:  2           [NII]6583_d      13.32      0.30       5    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -124         1
#  comp.  1:        12        33
#  comp.  2:         6        39
# chi2/DOF: 12.13; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      178.8      0.23      12    33
# Comp:  1                Halpha      325.3      0.23      12    33
# Comp:  2             [SII]6716      19.44      0.24       6    39
# Comp:  2             [SII]6731      13.13      0.24       6    39
# Comp:  2              HeII4687     0.5902      0.24       6    39
# Comp:  2               HeI5876      13.36      0.24       6    39
# Comp:  2          [OIII]5007_d      1143.      0.30       6    39
# Comp:  2            [OI]6300_d      6.131      0.30       6    39
# Comp:  2           [NII]6583_d      14.32      0.30       6    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       166         1
#  comp.  1:         9        13
#  comp.  2:         5        43
# chi2/DOF: 15.80; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      165.0      0.22       9    13
# Comp:  1                Halpha      303.9      0.22       9    13
# Comp:  2             [SII]6716      17.97      0.24       5    43
# Comp:  2             [SII]6731      15.22      0.24       5    43
# Comp:  2              HeII4687     0.6635      0.24       5    43
# Comp:  2               HeI5876      13.45      0.24       5    43
# Comp:  2          [OIII]5007_d      1151.      0.30       5    43
# Comp:  2            [OI]6300_d      5.892      0.30       5    43
# Comp:  2           [NII]6583_d      15.03      0.30       5    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -158         1
#  comp.  1:        13        34
#  comp.  2:         8        46
# chi2/DOF: 13.02; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      176.0      0.23      13    34
# Comp:  1                Halpha      328.2      0.23      13    34
# Comp:  2             [SII]6716      18.15      0.24       8    46
# Comp:  2             [SII]6731      14.40      0.24       8    46
# Comp:  2              HeII4687     0.4067      0.24       8    46
# Comp:  2               HeI5876      14.89      0.24       8    46
# Comp:  2          [OIII]5007_d      1176.      0.31       8    46
# Comp:  2            [OI]6300_d      4.554      0.31       8    46
# Comp:  2           [NII]6583_d      14.26      0.31       8    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26      1000
#  comp.  1:         6        17
#  comp.  2:         3        42
# chi2/DOF: 10.94; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      155.1      0.22       6    17
# Comp:  1                Halpha      306.2      0.22       6    17
# Comp:  2             [SII]6716      21.16      0.24       3    42
# Comp:  2             [SII]6731      12.87      0.24       3    42
# Comp:  2              HeII4687     0.6323      0.24       3    42
# Comp:  2               HeI5876      16.18      0.24       3    42
# Comp:  2          [OIII]5007_d      1142.      0.30       3    42
# Comp:  2            [OI]6300_d      5.324      0.30       3    42
# Comp:  2           [NII]6583_d      13.11      0.30       3    42
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_1_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_1_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_1_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_1_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_1_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
