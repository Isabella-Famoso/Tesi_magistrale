# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_5.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_1263/FORS2.2022-01-06T07_26_01.965/Spectra_extraction/redshift.txt") 
z = red[4][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_5']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4433.12520539 4434.59903006 4436.07285474 ... 7063.90224957 7065.37607425
#  7066.84989892] [0.368978   0.33900499 0.3602187  ... 0.11464409 0.13630546 0.0881881 ] [0.02309637 0.02309637 0.02309637 ... 0.02309637 0.02309637 0.02309637]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.2165626  2.21729952 2.21803643 ... 3.53195112 3.53268804 3.53342495]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3137, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3137, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3137, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
# C:\Users\ISAFA\anaconda3\Lib\site-packages\capfit\capfit.py:799: RuntimeWarning: invalid value encountered in scalar divide
#   ratio = actred/prered
#  Best Fit:       Vel     sigma
#  comp.  0:        20       180
# chi2/DOF: 0.01127; DOF: 1944; degree = 4; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 5; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 0/150
#  Best Fit:       Vel     sigma
#  comp.  0:        20       180
# chi2/DOF: 0.004822; DOF: 1896; degree = 4; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 5; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 0/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([ 20., 180.])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -168         1
#  comp.  1:         7        32
#  comp.  2:         8        47
# chi2/DOF: 27.12; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      129.7      0.34       7    32
# Comp:  1                Halpha      254.0      0.34       7    32
# Comp:  2             [SII]6716      16.22      0.36       8    47
# Comp:  2             [SII]6731      11.43      0.36       8    47
# Comp:  2              HeII4687     0.7723      0.36       8    47
# Comp:  2               HeI5876      11.45      0.36       8    47
# Comp:  2          [OIII]5007_d      820.0      0.45       8    47
# Comp:  2            [OI]6300_d      4.344      0.45       8    47
# Comp:  2           [NII]6583_d      9.961      0.45       8    47
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  512.3; gas flux:    131 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:   1053; gas flux:    348 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  61.75; gas flux:     23 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  41.82; gas flux:     16 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  3.003; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  44.61; gas flux:     14 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   2399; gas flux:    856 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  12.22; gas flux:      6 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  27.85; gas flux:     14 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -142         1
#  comp.  1:         4        28
#  comp.  2:        15        58
# chi2/DOF: 15.04; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      133.6      0.33       4    28
# Comp:  1                Halpha      254.0      0.33       4    28
# Comp:  2             [SII]6716      16.89      0.37      15    58
# Comp:  2             [SII]6731      11.94      0.37      15    58
# Comp:  2              HeII4687     0.8847      0.37      15    58
# Comp:  2               HeI5876      10.64      0.37      15    58
# Comp:  2          [OIII]5007_d      878.7      0.47      15    58
# Comp:  2            [OI]6300_d      4.666      0.47      15    58
# Comp:  2           [NII]6583_d      10.11      0.47      15    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -262        23
#  comp.  1:         8        40
#  comp.  2:        12        45
# chi2/DOF: 22.41; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      148.8      0.35       8    40
# Comp:  1                Halpha      255.3      0.35       8    40
# Comp:  2             [SII]6716      15.26      0.35      12    45
# Comp:  2             [SII]6731      11.08      0.35      12    45
# Comp:  2              HeII4687     0.7963      0.35      12    45
# Comp:  2               HeI5876      11.97      0.35      12    45
# Comp:  2          [OIII]5007_d      785.2      0.45      12    45
# Comp:  2            [OI]6300_d      3.649      0.45      12    45
# Comp:  2           [NII]6583_d      10.07      0.45      12    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -202        45
#  comp.  1:         9        38
#  comp.  2:        18        57
# chi2/DOF: 10.63; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      124.7      0.34       9    38
# Comp:  1                Halpha      250.9      0.34       9    38
# Comp:  2             [SII]6716      16.57      0.37      18    57
# Comp:  2             [SII]6731      11.43      0.37      18    57
# Comp:  2              HeII4687      1.118      0.37      18    57
# Comp:  2               HeI5876      11.13      0.37      18    57
# Comp:  2          [OIII]5007_d      855.4      0.47      18    57
# Comp:  2            [OI]6300_d      3.462      0.47      18    57
# Comp:  2           [NII]6583_d      10.04      0.47      18    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       129         1
#  comp.  1:         6        31
#  comp.  2:        -2        40
# chi2/DOF: 6.246; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      143.0      0.34       6    31
# Comp:  1                Halpha      261.5      0.34       6    31
# Comp:  2             [SII]6716      14.90      0.35      -2    40
# Comp:  2             [SII]6731      10.75      0.35      -2    40
# Comp:  2              HeII4687     0.5972      0.35      -2    40
# Comp:  2               HeI5876      10.09      0.35      -2    40
# Comp:  2          [OIII]5007_d      745.8      0.44      -2    40
# Comp:  2            [OI]6300_d      4.633      0.44      -2    40
# Comp:  2           [NII]6583_d      9.871      0.44      -2    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -234         1
#  comp.  1:         8        27
#  comp.  2:        11        45
# chi2/DOF: 24.08; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      117.8      0.33       8    27
# Comp:  1                Halpha      252.8      0.33       8    27
# Comp:  2             [SII]6716      15.93      0.35      11    45
# Comp:  2             [SII]6731      11.80      0.35      11    45
# Comp:  2              HeII4687     0.4447      0.35      11    45
# Comp:  2               HeI5876      11.31      0.35      11    45
# Comp:  2          [OIII]5007_d      787.6      0.45      11    45
# Comp:  2            [OI]6300_d      3.421      0.45      11    45
# Comp:  2           [NII]6583_d      9.321      0.45      11    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       134         1
#  comp.  1:         4        33
#  comp.  2:         9        56
# chi2/DOF: 13.29; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      144.3      0.34       4    33
# Comp:  1                Halpha      260.8      0.34       4    33
# Comp:  2             [SII]6716      16.33      0.37       9    56
# Comp:  2             [SII]6731      11.06      0.37       9    56
# Comp:  2              HeII4687     0.7056      0.37       9    56
# Comp:  2               HeI5876      13.09      0.37       9    56
# Comp:  2          [OIII]5007_d      780.6      0.47       9    56
# Comp:  2            [OI]6300_d      3.705      0.47       9    56
# Comp:  2           [NII]6583_d      10.89      0.47       9    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -111         1
#  comp.  1:         9        30
#  comp.  2:         5        55
# chi2/DOF: 19.48; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      139.4      0.34       9    30
# Comp:  1                Halpha      248.4      0.34       9    30
# Comp:  2             [SII]6716      16.71      0.37       5    55
# Comp:  2             [SII]6731      11.31      0.37       5    55
# Comp:  2              HeII4687     0.9478      0.37       5    55
# Comp:  2               HeI5876      10.87      0.37       5    55
# Comp:  2          [OIII]5007_d      810.0      0.46       5    55
# Comp:  2            [OI]6300_d      5.395      0.46       5    55
# Comp:  2           [NII]6583_d      10.14      0.46       5    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -146       651
#  comp.  1:         5        29
#  comp.  2:         2        44
# chi2/DOF: 8.002; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      135.0      0.34       5    29
# Comp:  1                Halpha      258.6      0.34       5    29
# Comp:  2             [SII]6716      16.13      0.35       2    44
# Comp:  2             [SII]6731      10.85      0.35       2    44
# Comp:  2              HeII4687     0.8828      0.35       2    44
# Comp:  2               HeI5876      11.53      0.35       2    44
# Comp:  2          [OIII]5007_d      733.5      0.44       2    44
# Comp:  2            [OI]6300_d      4.405      0.44       2    44
# Comp:  2           [NII]6583_d      9.713      0.44       2    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -122         1
#  comp.  1:         8        24
#  comp.  2:        10        46
# chi2/DOF: 25.78; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      138.5      0.33       8    24
# Comp:  1                Halpha      240.6      0.33       8    24
# Comp:  2             [SII]6716      16.52      0.35      10    46
# Comp:  2             [SII]6731      10.89      0.35      10    46
# Comp:  2              HeII4687     0.9892      0.35      10    46
# Comp:  2               HeI5876      12.02      0.35      10    46
# Comp:  2          [OIII]5007_d      811.3      0.45      10    46
# Comp:  2            [OI]6300_d      3.985      0.45      10    46
# Comp:  2           [NII]6583_d      10.14      0.45      10    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       146         1
#  comp.  1:         6        35
#  comp.  2:         9        37
# chi2/DOF: 13.25; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      123.7      0.34       6    35
# Comp:  1                Halpha      250.9      0.34       6    35
# Comp:  2             [SII]6716      15.61      0.34       9    37
# Comp:  2             [SII]6731      10.82      0.34       9    37
# Comp:  2              HeII4687     0.9610      0.34       9    37
# Comp:  2               HeI5876      11.43      0.34       9    37
# Comp:  2          [OIII]5007_d      852.9      0.43       9    37
# Comp:  2            [OI]6300_d      5.053      0.43       9    37
# Comp:  2           [NII]6583_d      10.04      0.43       9    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       119       578
#  comp.  1:         5        29
#  comp.  2:         2        43
# chi2/DOF: 8.592; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      134.2      0.34       5    29
# Comp:  1                Halpha      249.8      0.34       5    29
# Comp:  2             [SII]6716      17.25      0.35       2    43
# Comp:  2             [SII]6731      11.11      0.35       2    43
# Comp:  2              HeII4687     0.8229      0.35       2    43
# Comp:  2               HeI5876      11.50      0.35       2    43
# Comp:  2          [OIII]5007_d      732.0      0.44       2    43
# Comp:  2            [OI]6300_d      4.548      0.44       2    43
# Comp:  2           [NII]6583_d      10.62      0.44       2    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -249         1
#  comp.  1:         8        30
#  comp.  2:        12        38
# chi2/DOF: 18.22; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      123.7      0.34       8    30
# Comp:  1                Halpha      244.1      0.34       8    30
# Comp:  2             [SII]6716      17.09      0.35      12    38
# Comp:  2             [SII]6731      10.85      0.35      12    38
# Comp:  2              HeII4687     0.8888      0.35      12    38
# Comp:  2               HeI5876      11.05      0.35      12    38
# Comp:  2          [OIII]5007_d      835.6      0.44      12    38
# Comp:  2            [OI]6300_d      4.298      0.44      12    38
# Comp:  2           [NII]6583_d      9.729      0.44      12    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -229       531
#  comp.  1:         9        21
#  comp.  2:         7        48
# chi2/DOF: 25.86; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      117.5      0.33       9    21
# Comp:  1                Halpha      249.5      0.33       9    21
# Comp:  2             [SII]6716      15.93      0.36       7    48
# Comp:  2             [SII]6731      11.89      0.36       7    48
# Comp:  2              HeII4687      1.123      0.36       7    48
# Comp:  2               HeI5876      11.60      0.36       7    48
# Comp:  2          [OIII]5007_d      832.6      0.45       7    48
# Comp:  2            [OI]6300_d      5.079      0.45       7    48
# Comp:  2           [NII]6583_d      9.770      0.45       7    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -128         1
#  comp.  1:         9        26
#  comp.  2:         5        57
# chi2/DOF: 19.29; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      134.3      0.33       9    26
# Comp:  1                Halpha      255.5      0.33       9    26
# Comp:  2             [SII]6716      17.72      0.37       5    57
# Comp:  2             [SII]6731      12.40      0.37       5    57
# Comp:  2              HeII4687     0.6743      0.37       5    57
# Comp:  2               HeI5876      12.11      0.37       5    57
# Comp:  2          [OIII]5007_d      820.2      0.47       5    57
# Comp:  2            [OI]6300_d      4.477      0.47       5    57
# Comp:  2           [NII]6583_d      10.64      0.47       5    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -115         1
#  comp.  1:         9        26
#  comp.  2:        17        50
# chi2/DOF: 7.693; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      134.9      0.33       9    26
# Comp:  1                Halpha      255.5      0.33       9    26
# Comp:  2             [SII]6716      17.21      0.36      17    50
# Comp:  2             [SII]6731      11.18      0.36      17    50
# Comp:  2              HeII4687     0.7187      0.36      17    50
# Comp:  2               HeI5876      11.85      0.36      17    50
# Comp:  2          [OIII]5007_d      893.1      0.46      17    50
# Comp:  2            [OI]6300_d      4.696      0.46      17    50
# Comp:  2           [NII]6583_d      10.38      0.46      17    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       165         1
#  comp.  1:         7        28
#  comp.  2:        19        48
# chi2/DOF: 8.135; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 68; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      116.4      0.34       7    28
# Comp:  1                Halpha      256.8      0.34       7    28
# Comp:  2             [SII]6716      16.65      0.36      19    48
# Comp:  2             [SII]6731      11.88      0.36      19    48
# Comp:  2              HeII4687     0.8387      0.36      19    48
# Comp:  2               HeI5876      11.44      0.36      19    48
# Comp:  2          [OIII]5007_d      873.6      0.45      19    48
# Comp:  2            [OI]6300_d      4.770      0.45      19    48
# Comp:  2           [NII]6583_d      10.11      0.45      19    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -177         1
#  comp.  1:         9        34
#  comp.  2:         9        46
# chi2/DOF: 25.52; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      146.2      0.34       9    34
# Comp:  1                Halpha      263.6      0.34       9    34
# Comp:  2             [SII]6716      16.72      0.36       9    46
# Comp:  2             [SII]6731      10.97      0.36       9    46
# Comp:  2              HeII4687     0.9754      0.36       9    46
# Comp:  2               HeI5876      12.06      0.36       9    46
# Comp:  2          [OIII]5007_d      807.8      0.45       9    46
# Comp:  2            [OI]6300_d      4.412      0.45       9    46
# Comp:  2           [NII]6583_d      10.10      0.45       9    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96         1
#  comp.  1:         6        27
#  comp.  2:        17        49
# chi2/DOF: 10.10; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      135.7      0.33       6    27
# Comp:  1                Halpha      244.7      0.33       6    27
# Comp:  2             [SII]6716      14.62      0.36      17    49
# Comp:  2             [SII]6731      11.61      0.36      17    49
# Comp:  2              HeII4687     0.5388      0.36      17    49
# Comp:  2               HeI5876      11.19      0.36      17    49
# Comp:  2          [OIII]5007_d      883.7      0.45      17    49
# Comp:  2            [OI]6300_d      4.027      0.45      17    49
# Comp:  2           [NII]6583_d      10.21      0.45      17    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22       571
#  comp.  1:         6        23
#  comp.  2:        -1        41
# chi2/DOF: 9.642; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      140.2      0.33       6    23
# Comp:  1                Halpha      246.3      0.33       6    23
# Comp:  2             [SII]6716      17.19      0.35      -1    41
# Comp:  2             [SII]6731      11.32      0.35      -1    41
# Comp:  2              HeII4687     0.7633      0.35      -1    41
# Comp:  2               HeI5876      10.30      0.35      -1    41
# Comp:  2          [OIII]5007_d      756.9      0.44      -1    41
# Comp:  2            [OI]6300_d      3.975      0.44      -1    41
# Comp:  2           [NII]6583_d      10.10      0.44      -1    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       136         1
#  comp.  1:        10        22
#  comp.  2:         4        56
# chi2/DOF: 18.11; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 59; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      120.5      0.33      10    22
# Comp:  1                Halpha      244.4      0.33      10    22
# Comp:  2             [SII]6716      15.42      0.37       4    56
# Comp:  2             [SII]6731      11.63      0.37       4    56
# Comp:  2              HeII4687     0.9751      0.37       4    56
# Comp:  2               HeI5876      11.55      0.37       4    56
# Comp:  2          [OIII]5007_d      815.3      0.46       4    56
# Comp:  2            [OI]6300_d      4.736      0.46       4    56
# Comp:  2           [NII]6583_d      10.87      0.46       4    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       101         1
#  comp.  1:         5        18
#  comp.  2:         2        41
# chi2/DOF: 3.423; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 68; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      138.3      0.33       5    18
# Comp:  1                Halpha      244.6      0.33       5    18
# Comp:  2             [SII]6716      17.05      0.35       2    41
# Comp:  2             [SII]6731      11.09      0.35       2    41
# Comp:  2              HeII4687     0.3826      0.35       2    41
# Comp:  2               HeI5876      11.61      0.35       2    41
# Comp:  2          [OIII]5007_d      717.2      0.44       2    41
# Comp:  2            [OI]6300_d      3.701      0.44       2    41
# Comp:  2           [NII]6583_d      9.952      0.44       2    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -277         1
#  comp.  1:         8        30
#  comp.  2:        13        35
# chi2/DOF: 17.27; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      140.3      0.34       8    30
# Comp:  1                Halpha      256.5      0.34       8    30
# Comp:  2             [SII]6716      15.75      0.34      13    35
# Comp:  2             [SII]6731      10.64      0.34      13    35
# Comp:  2              HeII4687     0.8531      0.34      13    35
# Comp:  2               HeI5876      10.76      0.34      13    35
# Comp:  2          [OIII]5007_d      816.9      0.43      13    35
# Comp:  2            [OI]6300_d      4.041      0.43      13    35
# Comp:  2           [NII]6583_d      9.347      0.43      13    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -196         1
#  comp.  1:        10        30
#  comp.  2:         2        43
# chi2/DOF: 8.879; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      124.4      0.34      10    30
# Comp:  1                Halpha      255.4      0.34      10    30
# Comp:  2             [SII]6716      16.94      0.35       2    43
# Comp:  2             [SII]6731      11.06      0.35       2    43
# Comp:  2              HeII4687      1.012      0.35       2    43
# Comp:  2               HeI5876      11.33      0.35       2    43
# Comp:  2          [OIII]5007_d      731.4      0.44       2    43
# Comp:  2            [OI]6300_d      3.889      0.44       2    43
# Comp:  2           [NII]6583_d      10.23      0.44       2    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -157         1
#  comp.  1:        10        32
#  comp.  2:         5        56
# chi2/DOF: 17.70; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      145.1      0.34      10    32
# Comp:  1                Halpha      259.5      0.34      10    32
# Comp:  2             [SII]6716      16.96      0.37       5    56
# Comp:  2             [SII]6731      11.76      0.37       5    56
# Comp:  2              HeII4687     0.7614      0.37       5    56
# Comp:  2               HeI5876      11.48      0.37       5    56
# Comp:  2          [OIII]5007_d      808.0      0.47       5    56
# Comp:  2            [OI]6300_d      4.516      0.47       5    56
# Comp:  2           [NII]6583_d      10.33      0.47       5    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -198         1
#  comp.  1:         8        33
#  comp.  2:        12        46
# chi2/DOF: 24.25; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      135.7      0.34       8    33
# Comp:  1                Halpha      248.6      0.34       8    33
# Comp:  2             [SII]6716      15.16      0.35      12    46
# Comp:  2             [SII]6731      10.95      0.35      12    46
# Comp:  2              HeII4687     0.6582      0.35      12    46
# Comp:  2               HeI5876      11.69      0.35      12    46
# Comp:  2          [OIII]5007_d      795.7      0.45      12    46
# Comp:  2            [OI]6300_d      4.280      0.45      12    46
# Comp:  2           [NII]6583_d      9.913      0.45      12    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       183      1000
#  comp.  1:         6        37
#  comp.  2:         1        30
# chi2/DOF: 9.957; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      121.5      0.34       6    37
# Comp:  1                Halpha      257.9      0.34       6    37
# Comp:  2             [SII]6716      16.29      0.34       1    30
# Comp:  2             [SII]6731      11.06      0.34       1    30
# Comp:  2              HeII4687     0.4712      0.34       1    30
# Comp:  2               HeI5876      10.80      0.34       1    30
# Comp:  2          [OIII]5007_d      779.0      0.42       1    30
# Comp:  2            [OI]6300_d      4.530      0.42       1    30
# Comp:  2           [NII]6583_d      9.780      0.42       1    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -151         1
#  comp.  1:         8        33
#  comp.  2:         9        57
# chi2/DOF: 15.53; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      129.7      0.34       8    33
# Comp:  1                Halpha      258.5      0.34       8    33
# Comp:  2             [SII]6716      18.05      0.37       9    57
# Comp:  2             [SII]6731      12.46      0.37       9    57
# Comp:  2              HeII4687      1.087      0.37       9    57
# Comp:  2               HeI5876      12.31      0.37       9    57
# Comp:  2          [OIII]5007_d      786.6      0.47       9    57
# Comp:  2            [OI]6300_d      5.132      0.47       9    57
# Comp:  2           [NII]6583_d      10.35      0.47       9    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -123         1
#  comp.  1:         8        43
#  comp.  2:         6        57
# chi2/DOF: 18.55; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      129.0      0.35       8    43
# Comp:  1                Halpha      262.7      0.35       8    43
# Comp:  2             [SII]6716      16.87      0.37       6    57
# Comp:  2             [SII]6731      11.33      0.37       6    57
# Comp:  2              HeII4687     0.6367      0.37       6    57
# Comp:  2               HeI5876      12.20      0.37       6    57
# Comp:  2          [OIII]5007_d      811.9      0.47       6    57
# Comp:  2            [OI]6300_d      4.668      0.47       6    57
# Comp:  2           [NII]6583_d      10.58      0.47       6    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -179         1
#  comp.  1:         9        24
#  comp.  2:        -1        30
# chi2/DOF: 5.831; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      113.6      0.33       9    24
# Comp:  1                Halpha      250.9      0.33       9    24
# Comp:  2             [SII]6716      14.48      0.34      -1    30
# Comp:  2             [SII]6731      10.42      0.34      -1    30
# Comp:  2              HeII4687     0.6368      0.34      -1    30
# Comp:  2               HeI5876      11.09      0.34      -1    30
# Comp:  2          [OIII]5007_d      789.1      0.43      -1    30
# Comp:  2            [OI]6300_d      3.608      0.43      -1    30
# Comp:  2           [NII]6583_d      9.318      0.43      -1    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -169       100
#  comp.  1:         9        40
#  comp.  2:         9        47
# chi2/DOF: 25.69; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      120.2      0.35       9    40
# Comp:  1                Halpha      264.0      0.35       9    40
# Comp:  2             [SII]6716      15.11      0.36       9    47
# Comp:  2             [SII]6731      11.42      0.36       9    47
# Comp:  2              HeII4687     0.9837      0.36       9    47
# Comp:  2               HeI5876      11.69      0.36       9    47
# Comp:  2          [OIII]5007_d      810.3      0.45       9    47
# Comp:  2            [OI]6300_d      3.896      0.45       9    47
# Comp:  2           [NII]6583_d      10.16      0.45       9    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        80         1
#  comp.  1:         6        23
#  comp.  2:         5        57
# chi2/DOF: 18.59; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      118.4      0.33       6    23
# Comp:  1                Halpha      247.0      0.33       6    23
# Comp:  2             [SII]6716      16.60      0.37       5    57
# Comp:  2             [SII]6731      11.89      0.37       5    57
# Comp:  2              HeII4687      1.058      0.37       5    57
# Comp:  2               HeI5876      11.57      0.37       5    57
# Comp:  2          [OIII]5007_d      816.0      0.47       5    57
# Comp:  2            [OI]6300_d      3.609      0.47       5    57
# Comp:  2           [NII]6583_d      10.19      0.47       5    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -138         1
#  comp.  1:         7        31
#  comp.  2:         8        59
# chi2/DOF: 12.69; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      135.9      0.34       7    31
# Comp:  1                Halpha      250.9      0.34       7    31
# Comp:  2             [SII]6716      16.15      0.37       8    59
# Comp:  2             [SII]6731      12.11      0.37       8    59
# Comp:  2              HeII4687     0.6964      0.37       8    59
# Comp:  2               HeI5876      12.66      0.37       8    59
# Comp:  2          [OIII]5007_d      788.8      0.47       8    59
# Comp:  2            [OI]6300_d      3.969      0.47       8    59
# Comp:  2           [NII]6583_d      10.07      0.47       8    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        54         1
#  comp.  1:        10        38
#  comp.  2:        -0        30
# chi2/DOF: 8.287; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      128.1      0.35      10    38
# Comp:  1                Halpha      265.8      0.35      10    38
# Comp:  2             [SII]6716      15.16      0.34      -0    30
# Comp:  2             [SII]6731      10.65      0.34      -0    30
# Comp:  2              HeII4687     0.7946      0.34      -0    30
# Comp:  2               HeI5876      11.31      0.34      -0    30
# Comp:  2          [OIII]5007_d      782.5      0.43      -0    30
# Comp:  2            [OI]6300_d      4.020      0.43      -0    30
# Comp:  2           [NII]6583_d      9.514      0.43      -0    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -142         1
#  comp.  1:         8        31
#  comp.  2:         5        47
# chi2/DOF: 23.16; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      125.1      0.34       8    31
# Comp:  1                Halpha      258.7      0.34       8    31
# Comp:  2             [SII]6716      15.66      0.36       5    47
# Comp:  2             [SII]6731      11.51      0.36       5    47
# Comp:  2              HeII4687     0.9969      0.36       5    47
# Comp:  2               HeI5876      10.99      0.36       5    47
# Comp:  2          [OIII]5007_d      853.6      0.45       5    47
# Comp:  2            [OI]6300_d      4.046      0.45       5    47
# Comp:  2           [NII]6583_d      10.21      0.45       5    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -160         1
#  comp.  1:         7        28
#  comp.  2:        13        51
# chi2/DOF: 6.766; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      138.0      0.33       7    28
# Comp:  1                Halpha      250.9      0.33       7    28
# Comp:  2             [SII]6716      16.53      0.36      13    51
# Comp:  2             [SII]6731      11.48      0.36      13    51
# Comp:  2              HeII4687     0.6500      0.36      13    51
# Comp:  2               HeI5876      11.07      0.36      13    51
# Comp:  2          [OIII]5007_d      918.6      0.46      13    51
# Comp:  2            [OI]6300_d      4.076      0.46      13    51
# Comp:  2           [NII]6583_d      9.991      0.46      13    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16         1
#  comp.  1:         4        30
#  comp.  2:        -2        42
# chi2/DOF: 7.814; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      144.1      0.34       4    30
# Comp:  1                Halpha      256.4      0.34       4    30
# Comp:  2             [SII]6716      15.09      0.35      -2    42
# Comp:  2             [SII]6731      11.33      0.35      -2    42
# Comp:  2              HeII4687     0.9243      0.35      -2    42
# Comp:  2               HeI5876      12.31      0.35      -2    42
# Comp:  2          [OIII]5007_d      757.0      0.44      -2    42
# Comp:  2            [OI]6300_d      4.607      0.44      -2    42
# Comp:  2           [NII]6583_d      10.15      0.44      -2    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        78       934
#  comp.  1:         5        33
#  comp.  2:         6        46
# chi2/DOF: 23.87; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      139.9      0.34       5    33
# Comp:  1                Halpha      247.3      0.34       5    33
# Comp:  2             [SII]6716      16.05      0.36       6    46
# Comp:  2             [SII]6731      10.96      0.36       6    46
# Comp:  2              HeII4687     0.7881      0.36       6    46
# Comp:  2               HeI5876      11.99      0.36       6    46
# Comp:  2          [OIII]5007_d      844.9      0.45       6    46
# Comp:  2            [OI]6300_d      3.920      0.45       6    46
# Comp:  2           [NII]6583_d      9.984      0.45       6    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -120       228
#  comp.  1:        11        26
#  comp.  2:         8        37
# chi2/DOF: 12.77; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      119.1      0.33      11    26
# Comp:  1                Halpha      246.6      0.33      11    26
# Comp:  2             [SII]6716      15.55      0.34       8    37
# Comp:  2             [SII]6731      11.29      0.34       8    37
# Comp:  2              HeII4687     0.9899      0.34       8    37
# Comp:  2               HeI5876      11.28      0.34       8    37
# Comp:  2          [OIII]5007_d      854.3      0.43       8    37
# Comp:  2            [OI]6300_d      3.827      0.43       8    37
# Comp:  2           [NII]6583_d      9.871      0.43       8    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       131         1
#  comp.  1:         7        34
#  comp.  2:        12        48
# chi2/DOF: 24.22; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 69; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      147.7      0.34       7    34
# Comp:  1                Halpha      258.1      0.34       7    34
# Comp:  2             [SII]6716      17.60      0.36      12    48
# Comp:  2             [SII]6731      10.98      0.36      12    48
# Comp:  2              HeII4687     0.9144      0.36      12    48
# Comp:  2               HeI5876      12.43      0.36      12    48
# Comp:  2          [OIII]5007_d      801.8      0.45      12    48
# Comp:  2            [OI]6300_d      5.174      0.45      12    48
# Comp:  2           [NII]6583_d      10.44      0.45      12    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       134         1
#  comp.  1:         4        31
#  comp.  2:        14        50
# chi2/DOF: 7.484; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 100; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      138.6      0.34       4    31
# Comp:  1                Halpha      247.8      0.34       4    31
# Comp:  2             [SII]6716      15.91      0.36      14    50
# Comp:  2             [SII]6731      11.45      0.36      14    50
# Comp:  2              HeII4687      1.096      0.36      14    50
# Comp:  2               HeI5876      13.02      0.36      14    50
# Comp:  2          [OIII]5007_d      910.4      0.46      14    50
# Comp:  2            [OI]6300_d      4.184      0.46      14    50
# Comp:  2           [NII]6583_d      10.48      0.46      14    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       144         1
#  comp.  1:         6        32
#  comp.  2:         9        36
# chi2/DOF: 13.49; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 68; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      139.6      0.34       6    32
# Comp:  1                Halpha      256.2      0.34       6    32
# Comp:  2             [SII]6716      14.87      0.34       9    36
# Comp:  2             [SII]6731      10.87      0.34       9    36
# Comp:  2              HeII4687     0.7224      0.34       9    36
# Comp:  2               HeI5876      11.29      0.34       9    36
# Comp:  2          [OIII]5007_d      850.4      0.43       9    36
# Comp:  2            [OI]6300_d      3.919      0.43       9    36
# Comp:  2           [NII]6583_d      10.05      0.43       9    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -218         1
#  comp.  1:        11        34
#  comp.  2:        13        38
# chi2/DOF: 19.10; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      127.5      0.34      11    34
# Comp:  1                Halpha      263.1      0.34      11    34
# Comp:  2             [SII]6716      14.61      0.34      13    38
# Comp:  2             [SII]6731      11.06      0.34      13    38
# Comp:  2              HeII4687     0.7303      0.34      13    38
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      131.8      0.33       7    21
# Comp:  1                Halpha      240.2      0.33       7    21
# Comp:  2             [SII]6716      16.29      0.36       9    48
# Comp:  2             [SII]6731      11.33      0.36       9    48
# Comp:  2              HeII4687     0.3716      0.36       9    48
# Comp:  2               HeI5876      10.44      0.36       9    48
# Comp:  2          [OIII]5007_d      815.2      0.45       9    48
# Comp:  2            [OI]6300_d      5.158      0.45       9    48
# Comp:  2           [NII]6583_d      10.46      0.45       9    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       141         1
#  comp.  1:         7        32
#  comp.  2:        13        36
# chi2/DOF: 17.10; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      140.8      0.34       7    32
# Comp:  1                Halpha      251.5      0.34       7    32
# Comp:  2             [SII]6716      14.38      0.34      13    36
# Comp:  2             [SII]6731      10.77      0.34      13    36
# Comp:  2              HeII4687     0.6396      0.34      13    36
# Comp:  2               HeI5876      11.36      0.34      13    36
# Comp:  2          [OIII]5007_d      826.4      0.43      13    36
# Comp:  2            [OI]6300_d      3.790      0.43      13    36
# Comp:  2           [NII]6583_d      10.13      0.43      13    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -123         1
#  comp.  1:         4        25
#  comp.  2:         9        56
# chi2/DOF: 15.87; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      137.2      0.33       4    25
# Comp:  1                Halpha      249.9      0.33       4    25
# Comp:  2             [SII]6716      17.25      0.37       9    56
# Comp:  2             [SII]6731      11.84      0.37       9    56
# Comp:  2              HeII4687     0.5605      0.37       9    56
# Comp:  2               HeI5876      12.27      0.37       9    56
# Comp:  2          [OIII]5007_d      787.8      0.46       9    56
# Comp:  2            [OI]6300_d      4.871      0.46       9    56
# Comp:  2           [NII]6583_d      9.910      0.46       9    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -172         1
#  comp.  1:         4        30
#  comp.  2:         8        47
# chi2/DOF: 26.53; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      134.7      0.34       4    30
# Comp:  1                Halpha      245.9      0.34       4    30
# Comp:  2             [SII]6716      16.23      0.36       8    47
# Comp:  2             [SII]6731      11.59      0.36       8    47
# Comp:  2              HeII4687     0.8962      0.36       8    47
# Comp:  2               HeI5876      11.40      0.36       8    47
# Comp:  2          [OIII]5007_d      819.4      0.45       8    47
# Comp:  2            [OI]6300_d      4.515      0.45       8    47
# Comp:  2           [NII]6583_d      10.09      0.45       8    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -125         1
#  comp.  1:         6        24
#  comp.  2:        -3        42
# chi2/DOF: 6.192; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      134.5      0.33       6    24
# Comp:  1                Halpha      255.0      0.33       6    24
# Comp:  2             [SII]6716      16.74      0.35      -3    42
# Comp:  2             [SII]6731      11.43      0.35      -3    42
# Comp:  2              HeII4687     0.6294      0.35      -3    42
# Comp:  2               HeI5876      10.84      0.35      -3    42
# Comp:  2          [OIII]5007_d      759.4      0.44      -3    42
# Comp:  2            [OI]6300_d      4.046      0.44      -3    42
# Comp:  2           [NII]6583_d      10.06      0.44      -3    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -141         1
#  comp.  1:         7        28
#  comp.  2:        14        60
# chi2/DOF: 13.58; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      142.4      0.33       7    28
# Comp:  1                Halpha      250.0      0.33       7    28
# Comp:  2             [SII]6716      16.95      0.37      14    60
# Comp:  2             [SII]6731      11.66      0.37      14    60
# Comp:  2              HeII4687     0.5324      0.37      14    60
# Comp:  2               HeI5876      11.09      0.37      14    60
# Comp:  2          [OIII]5007_d      892.8      0.47      14    60
# Comp:  2            [OI]6300_d      5.480      0.47      14    60
# Comp:  2           [NII]6583_d      10.70      0.47      14    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        32       130
#  comp.  1:         8        29
#  comp.  2:         8        48
# chi2/DOF: 26.70; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      126.2      0.34       8    29
# Comp:  1                Halpha      246.9      0.34       8    29
# Comp:  2             [SII]6716      14.84      0.36       8    48
# Comp:  2             [SII]6731      11.21      0.36       8    48
# Comp:  2              HeII4687     0.7825      0.36       8    48
# Comp:  2               HeI5876      11.78      0.36       8    48
# Comp:  2          [OIII]5007_d      822.4      0.45       8    48
# Comp:  2            [OI]6300_d      5.418      0.45       8    48
# Comp:  2           [NII]6583_d      9.973      0.45       8    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        25       104
#  comp.  1:         5        35
#  comp.  2:         9        37
# chi2/DOF: 14.04; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      141.0      0.34       5    35
# Comp:  1                Halpha      253.6      0.34       5    35
# Comp:  2             [SII]6716      16.24      0.34       9    37
# Comp:  2             [SII]6731      11.23      0.34       9    37
# Comp:  2              HeII4687     0.6573      0.34       9    37
# Comp:  2               HeI5876      10.96      0.34       9    37
# Comp:  2          [OIII]5007_d      853.5      0.43       9    37
# Comp:  2            [OI]6300_d      3.993      0.43       9    37
# Comp:  2           [NII]6583_d      10.39      0.43       9    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -133         1
#  comp.  1:         9        30
#  comp.  2:        11        48
# chi2/DOF: 24.93; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      136.7      0.34       9    30
# Comp:  1                Halpha      254.4      0.34       9    30
# Comp:  2             [SII]6716      15.68      0.36      11    48
# Comp:  2             [SII]6731      10.92      0.36      11    48
# Comp:  2              HeII4687      1.021      0.36      11    48
# Comp:  2               HeI5876      10.63      0.36      11    48
# Comp:  2          [OIII]5007_d      800.3      0.45      11    48
# Comp:  2            [OI]6300_d      4.293      0.45      11    48
# Comp:  2           [NII]6583_d      10.31      0.45      11    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -158         1
#  comp.  1:         9        30
#  comp.  2:        14        50
# chi2/DOF: 7.605; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      121.8      0.34       9    30
# Comp:  1                Halpha      258.2      0.34       9    30
# Comp:  2             [SII]6716      16.15      0.36      14    50
# Comp:  2             [SII]6731      11.19      0.36      14    50
# Comp:  2              HeII4687      1.084      0.36      14    50
# Comp:  2               HeI5876      11.14      0.36      14    50
# Comp:  2          [OIII]5007_d      912.3      0.45      14    50
# Comp:  2            [OI]6300_d      3.995      0.45      14    50
# Comp:  2           [NII]6583_d      9.968      0.45      14    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -179         1
#  comp.  1:         7        29
#  comp.  2:         7        47
# chi2/DOF: 26.37; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      140.3      0.34       7    29
# Comp:  1                Halpha      252.2      0.34       7    29
# Comp:  2             [SII]6716      15.05      0.36       7    47
# Comp:  2             [SII]6731      11.29      0.36       7    47
# Comp:  2              HeII4687     0.7304      0.36       7    47
# Comp:  2               HeI5876      11.41      0.36       7    47
# Comp:  2          [OIII]5007_d      819.2      0.45       7    47
# Comp:  2            [OI]6300_d      3.767      0.45       7    47
# Comp:  2           [NII]6583_d      9.697      0.45       7    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -169         1
#  comp.  1:         8        27
#  comp.  2:        11        47
# chi2/DOF: 24.76; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      139.6      0.33       8    27
# Comp:  1                Halpha      255.7      0.33       8    27
# Comp:  2             [SII]6716      16.24      0.36      11    47
# Comp:  2             [SII]6731      11.26      0.36      11    47
# Comp:  2              HeII4687     0.3873      0.36      11    47
# Comp:  2               HeI5876      11.07      0.36      11    47
# Comp:  2          [OIII]5007_d      798.9      0.45      11    47
# Comp:  2            [OI]6300_d      3.333      0.45      11    47
# Comp:  2           [NII]6583_d      10.17      0.45      11    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -143         1
#  comp.  1:         7        34
#  comp.  2:         9        36
# chi2/DOF: 14.49; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      140.5      0.34       7    34
# Comp:  1                Halpha      251.7      0.34       7    34
# Comp:  2             [SII]6716      15.04      0.34       9    36
# Comp:  2             [SII]6731      11.01      0.34       9    36
# Comp:  2              HeII4687     0.9912      0.34       9    36
# Comp:  2               HeI5876      11.83      0.34       9    36
# Comp:  2          [OIII]5007_d      844.3      0.43       9    36
# Comp:  2            [OI]6300_d      4.620      0.43       9    36
# Comp:  2           [NII]6583_d      9.726      0.43       9    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -120         1
#  comp.  1:        11        33
#  comp.  2:         8        57
# chi2/DOF: 15.19; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      122.1      0.34      11    33
# Comp:  1                Halpha      248.7      0.34      11    33
# Comp:  2             [SII]6716      15.71      0.37       8    57
# Comp:  2             [SII]6731      11.68      0.37       8    57
# Comp:  2              HeII4687      1.141      0.37       8    57
# Comp:  2               HeI5876      12.17      0.37       8    57
# Comp:  2          [OIII]5007_d      789.9      0.47       8    57
# Comp:  2            [OI]6300_d      4.347      0.47       8    57
# Comp:  2           [NII]6583_d      10.25      0.47       8    57
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([ 8.90645759,  7.99950139,  1.31600567,  0.66276442,  0.19957327,
#         0.89682942, 49.78708784,  0.65186096,  0.57315856])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([1.31495380e+02, 3.47638460e+02, 2.27182586e+01, 1.60492043e+01,
#        7.54748191e-01, 1.40288613e+01, 8.56335120e+02, 5.70814114e+00,
#        1.36774710e+01])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_5_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_5_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_5_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_5_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_5_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name        Flux  Error flux
# 0         Hbeta   18.297682    1.239340
# 1        Halpha   48.374156    1.113137
# 2     [SII]6716    3.161263    0.183123
# 3     [SII]6731    2.233259    0.092224
# 4      HeII4687    0.105024    0.027771
# 5       HeI5876    1.952127    0.124794
# 6  [OIII]5007_d  119.159682    6.927911
# 7    [OI]6300_d    0.794292    0.090707
# 8   [NII]6583_d    1.903230    0.079755
#           Name       Flux  Error_flux
# 0        Hbeta  18.297682    1.239340
# 1       Halpha  48.374156    1.113137
# 2    [SII]6716   3.161263    0.183123
# 3    [SII]6731   2.233259    0.092224
# 4     HeII4687   0.105024    0.027771
# 5      HeI5876   1.952127    0.124794
# 6   [OIII]4959  29.789921    6.927911
# 7   [OIII]5007  89.369762    6.927911
# 8     [OI]6300   0.595719    0.090707
# 9     [OI]6364   0.198573    0.090707
# 10   [NII]6548   0.475808    0.079755
# 11   [NII]6583   1.427423    0.079755

# %%
np.median(flux_rf_rebin)
# Out:
# 0.13915075972616267
