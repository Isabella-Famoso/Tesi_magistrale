# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_2.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_1263/FORS2.2022-01-06T07_26_01.965/Spectra_extraction/redshift.txt")   
z = red[1][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_2']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4434.20161708 4435.67530967 4437.14900227 ... 7063.26920779 7064.74290039
#  7066.21659298] [0.15082705 0.16326935 0.20254611 ... 0.13423156 0.14773643 0.13548344] [0.01405992 0.01405992 0.01405992 ... 0.01405992 0.01405992 0.01405992]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.21710081 2.21783765 2.2185745  ... 3.5316346  3.53237145 3.5331083 ]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3136, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3136, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3136, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -31         1
# chi2/DOF: 0.006723; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -20         1
# chi2/DOF: 0.004667; DOF: 1905; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-19.71929106,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
#  comp.  1:        17        23
#  comp.  2:        18        45
# chi2/DOF: 3.131; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.45      0.20      17    23
# Comp:  1                Halpha      116.3      0.20      17    23
# Comp:  2             [SII]6716      9.315      0.21      18    45
# Comp:  2             [SII]6731      6.311      0.21      18    45
# Comp:  2              HeII4687      0.000      0.21      18    45
# Comp:  2               HeI5876      4.451      0.21      18    45
# Comp:  2          [OIII]5007_d      206.2      0.27      18    45
# Comp:  2            [OI]6300_d      2.362      0.27      18    45
# Comp:  2           [NII]6583_d      5.917      0.27      18    45
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:    183; gas flux:     41 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  553.8; gas flux:    159 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  39.44; gas flux:     13 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  25.61; gas flux:      9 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:   19.3; gas flux:      5 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  670.8; gas flux:    215 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  7.379; gas flux:      3 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  18.39; gas flux:      8 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:        17        21
#  comp.  2:        20        51
# chi2/DOF: 2.761; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      38.75      0.20      17    21
# Comp:  1                Halpha      115.8      0.20      17    21
# Comp:  2             [SII]6716      8.756      0.22      20    51
# Comp:  2             [SII]6731      6.435      0.22      20    51
# Comp:  2              HeII4687      0.000      0.22      20    51
# Comp:  2               HeI5876      4.273      0.22      20    51
# Comp:  2          [OIII]5007_d      211.9      0.27      20    51
# Comp:  2            [OI]6300_d      2.605      0.27      20    51
# Comp:  2           [NII]6583_d      6.081      0.27      20    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       145        62
#  comp.  1:        16        23
#  comp.  2:        22        44
# chi2/DOF: 2.448; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      38.29      0.20      16    23
# Comp:  1                Halpha      116.2      0.20      16    23
# Comp:  2             [SII]6716      10.70      0.21      22    44
# Comp:  2             [SII]6731      6.293      0.21      22    44
# Comp:  2              HeII4687      0.000      0.21      22    44
# Comp:  2               HeI5876      4.143      0.21      22    44
# Comp:  2          [OIII]5007_d      212.3      0.27      22    44
# Comp:  2            [OI]6300_d      2.413      0.27      22    44
# Comp:  2           [NII]6583_d      6.106      0.27      22    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        57
#  comp.  1:        18        28
#  comp.  2:        14        41
# chi2/DOF: 2.330; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.83      0.20      18    28
# Comp:  1                Halpha      115.5      0.20      18    28
# Comp:  2             [SII]6716      8.543      0.21      14    41
# Comp:  2             [SII]6731      6.617      0.21      14    41
# Comp:  2              HeII4687      0.000      0.21      14    41
# Comp:  2               HeI5876      4.588      0.21      14    41
# Comp:  2          [OIII]5007_d      206.2      0.26      14    41
# Comp:  2            [OI]6300_d      1.959      0.26      14    41
# Comp:  2           [NII]6583_d      5.575      0.26      14    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        43
#  comp.  1:        16        31
#  comp.  2:        18        45
# chi2/DOF: 2.784; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 28; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      38.44      0.20      16    31
# Comp:  1                Halpha      117.4      0.20      16    31
# Comp:  2             [SII]6716      8.378      0.21      18    45
# Comp:  2             [SII]6731      6.369      0.21      18    45
# Comp:  2              HeII4687    0.01392      0.21      18    45
# Comp:  2               HeI5876      4.390      0.21      18    45
# Comp:  2          [OIII]5007_d      203.9      0.27      18    45
# Comp:  2            [OI]6300_d      2.642      0.27      18    45
# Comp:  2           [NII]6583_d      5.818      0.27      18    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       123         1
#  comp.  1:        17        24
#  comp.  2:        23        46
# chi2/DOF: 2.522; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 68; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.91      0.20      17    24
# Comp:  1                Halpha      114.6      0.20      17    24
# Comp:  2             [SII]6716      10.82      0.21      23    46
# Comp:  2             [SII]6731      6.408      0.21      23    46
# Comp:  2              HeII4687      0.000      0.21      23    46
# Comp:  2               HeI5876      4.709      0.21      23    46
# Comp:  2          [OIII]5007_d      208.6      0.27      23    46
# Comp:  2            [OI]6300_d      2.483      0.27      23    46
# Comp:  2           [NII]6583_d      5.586      0.27      23    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:        17        21
#  comp.  2:        17        42
# chi2/DOF: 2.520; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.97      0.20      17    21
# Comp:  1                Halpha      115.8      0.20      17    21
# Comp:  2             [SII]6716      9.005      0.21      17    42
# Comp:  2             [SII]6731      5.723      0.21      17    42
# Comp:  2              HeII4687      0.000      0.21      17    42
# Comp:  2               HeI5876      4.076      0.21      17    42
# Comp:  2          [OIII]5007_d      195.5      0.26      17    42
# Comp:  2            [OI]6300_d      2.214      0.26      17    42
# Comp:  2           [NII]6583_d      5.434      0.26      17    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35       124
#  comp.  1:        16         7
#  comp.  2:        17        47
# chi2/DOF: 2.619; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.24      0.19      16     7
# Comp:  1                Halpha      114.9      0.19      16     7
# Comp:  2             [SII]6716      10.87      0.21      17    47
# Comp:  2             [SII]6731      6.261      0.21      17    47
# Comp:  2              HeII4687    0.04209      0.21      17    47
# Comp:  2               HeI5876      4.369      0.21      17    47
# Comp:  2          [OIII]5007_d      206.8      0.27      17    47
# Comp:  2            [OI]6300_d      2.343      0.27      17    47
# Comp:  2           [NII]6583_d      5.855      0.27      17    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3        64
#  comp.  1:        15        11
#  comp.  2:        20        46
# chi2/DOF: 2.692; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      38.86      0.19      15    11
# Comp:  1                Halpha      116.3      0.19      15    11
# Comp:  2             [SII]6716      10.87      0.21      20    46
# Comp:  2             [SII]6731      5.763      0.21      20    46
# Comp:  2              HeII4687      0.000      0.21      20    46
# Comp:  2               HeI5876      4.781      0.21      20    46
# Comp:  2          [OIII]5007_d      205.2      0.27      20    46
# Comp:  2            [OI]6300_d      2.006      0.27      20    46
# Comp:  2           [NII]6583_d      5.879      0.27      20    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35        68
#  comp.  1:        18        23
#  comp.  2:        16        37
# chi2/DOF: 2.448; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.43      0.20      18    23
# Comp:  1                Halpha      117.0      0.20      18    23
# Comp:  2             [SII]6716      10.50      0.20      16    37
# Comp:  2             [SII]6731      5.604      0.20      16    37
# Comp:  2              HeII4687      0.000      0.20      16    37
# Comp:  2               HeI5876      4.746      0.20      16    37
# Comp:  2          [OIII]5007_d      201.6      0.26      16    37
# Comp:  2            [OI]6300_d      2.485      0.26      16    37
# Comp:  2           [NII]6583_d      5.620      0.26      16    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2         1
#  comp.  1:        16        20
#  comp.  2:        16        45
# chi2/DOF: 2.668; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.59      0.20      16    20
# Comp:  1                Halpha      111.7      0.20      16    20
# Comp:  2             [SII]6716      8.729      0.21      16    45
# Comp:  2             [SII]6731      6.282      0.21      16    45
# Comp:  2              HeII4687      0.000      0.21      16    45
# Comp:  2               HeI5876      4.863      0.21      16    45
# Comp:  2          [OIII]5007_d      206.9      0.27      16    45
# Comp:  2            [OI]6300_d      2.001      0.27      16    45
# Comp:  2           [NII]6583_d      6.225      0.27      16    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        83
#  comp.  1:        15        23
#  comp.  2:        21        45
# chi2/DOF: 2.468; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.30      0.20      15    23
# Comp:  1                Halpha      116.8      0.20      15    23
# Comp:  2             [SII]6716      10.83      0.21      21    45
# Comp:  2             [SII]6731      5.832      0.21      21    45
# Comp:  2              HeII4687      0.000      0.21      21    45
# Comp:  2               HeI5876      4.788      0.21      21    45
# Comp:  2          [OIII]5007_d      213.3      0.27      21    45
# Comp:  2            [OI]6300_d      2.475      0.27      21    45
# Comp:  2           [NII]6583_d      6.247      0.27      21    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        64
#  comp.  1:        21        31
#  comp.  2:        23        50
# chi2/DOF: 1.560; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      43.14      0.20      21    31
# Comp:  1                Halpha      119.5      0.20      21    31
# Comp:  2             [SII]6716      10.30      0.21      23    50
# Comp:  2             [SII]6731      5.886      0.21      23    50
# Comp:  2              HeII4687      0.000      0.21      23    50
# Comp:  2               HeI5876      4.958      0.21      23    50
# Comp:  2          [OIII]5007_d      219.4      0.27      23    50
# Comp:  2            [OI]6300_d      2.470      0.27      23    50
# Comp:  2           [NII]6583_d      5.757      0.27      23    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33         1
#  comp.  1:        14        18
#  comp.  2:        19        40
# chi2/DOF: 2.424; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      37.05      0.19      14    18
# Comp:  1                Halpha      112.2      0.19      14    18
# Comp:  2             [SII]6716      9.704      0.21      19    40
# Comp:  2             [SII]6731      6.711      0.21      19    40
# Comp:  2              HeII4687      0.000      0.21      19    40
# Comp:  2               HeI5876      4.432      0.21      19    40
# Comp:  2          [OIII]5007_d      199.0      0.26      19    40
# Comp:  2            [OI]6300_d      2.208      0.26      19    40
# Comp:  2           [NII]6583_d      5.916      0.26      19    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36         1
#  comp.  1:        18        20
#  comp.  2:        14        38
# chi2/DOF: 2.138; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.06      0.20      18    20
# Comp:  1                Halpha      118.4      0.20      18    20
# Comp:  2             [SII]6716      9.317      0.21      14    38
# Comp:  2             [SII]6731      6.208      0.21      14    38
# Comp:  2              HeII4687    0.04252      0.21      14    38
# Comp:  2               HeI5876      4.296      0.21      14    38
# Comp:  2          [OIII]5007_d      196.7      0.26      14    38
# Comp:  2            [OI]6300_d      2.459      0.26      14    38
# Comp:  2           [NII]6583_d      5.845      0.26      14    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98        29
#  comp.  1:        15        28
#  comp.  2:        16        50
# chi2/DOF: 2.646; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.27      0.20      15    28
# Comp:  1                Halpha      114.9      0.20      15    28
# Comp:  2             [SII]6716      8.567      0.21      16    50
# Comp:  2             [SII]6731      6.067      0.21      16    50
# Comp:  2              HeII4687      0.000      0.21      16    50
# Comp:  2               HeI5876      4.435      0.21      16    50
# Comp:  2          [OIII]5007_d      211.2      0.27      16    50
# Comp:  2            [OI]6300_d      2.071      0.27      16    50
# Comp:  2           [NII]6583_d      6.420      0.27      16    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -139       459
#  comp.  1:        15        22
#  comp.  2:        18        45
# chi2/DOF: 2.818; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.98      0.20      15    22
# Comp:  1                Halpha      112.7      0.20      15    22
# Comp:  2             [SII]6716      9.075      0.21      18    45
# Comp:  2             [SII]6731      6.427      0.21      18    45
# Comp:  2              HeII4687    0.09353      0.21      18    45
# Comp:  2               HeI5876      4.741      0.21      18    45
# Comp:  2          [OIII]5007_d      209.2      0.27      18    45
# Comp:  2            [OI]6300_d      2.336      0.27      18    45
# Comp:  2           [NII]6583_d      5.972      0.27      18    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58         1
#  comp.  1:        18        20
#  comp.  2:        22        44
# chi2/DOF: 2.742; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.15      0.20      18    20
# Comp:  1                Halpha      117.1      0.20      18    20
# Comp:  2             [SII]6716      9.267      0.21      22    44
# Comp:  2             [SII]6731      6.422      0.21      22    44
# Comp:  2              HeII4687    0.01725      0.21      22    44
# Comp:  2               HeI5876      4.131      0.21      22    44
# Comp:  2          [OIII]5007_d      207.6      0.26      22    44
# Comp:  2            [OI]6300_d      2.462      0.26      22    44
# Comp:  2           [NII]6583_d      5.712      0.26      22    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:        18        29
#  comp.  2:        15        44
# chi2/DOF: 2.201; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      43.18      0.20      18    29
# Comp:  1                Halpha      119.3      0.20      18    29
# Comp:  2             [SII]6716      9.293      0.21      15    44
# Comp:  2             [SII]6731      5.852      0.21      15    44
# Comp:  2              HeII4687    0.03482      0.21      15    44
# Comp:  2               HeI5876      4.759      0.21      15    44
# Comp:  2          [OIII]5007_d      197.1      0.27      15    44
# Comp:  2            [OI]6300_d      2.408      0.27      15    44
# Comp:  2           [NII]6583_d      5.751      0.27      15    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11         1
#  comp.  1:        15        22
#  comp.  2:        19        44
# chi2/DOF: 2.871; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.63      0.20      15    22
# Comp:  1                Halpha      112.1      0.20      15    22
# Comp:  2             [SII]6716      9.142      0.21      19    44
# Comp:  2             [SII]6731      6.685      0.21      19    44
# Comp:  2              HeII4687    0.04327      0.21      19    44
# Comp:  2               HeI5876      4.659      0.21      19    44
# Comp:  2          [OIII]5007_d      205.5      0.26      19    44
# Comp:  2            [OI]6300_d      2.290      0.26      19    44
# Comp:  2           [NII]6583_d      5.752      0.26      19    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13         1
#  comp.  1:        19        24
#  comp.  2:        21        44
# chi2/DOF: 2.623; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.59      0.20      19    24
# Comp:  1                Halpha      119.3      0.20      19    24
# Comp:  2             [SII]6716      8.605      0.21      21    44
# Comp:  2             [SII]6731      6.281      0.21      21    44
# Comp:  2              HeII4687      0.000      0.21      21    44
# Comp:  2               HeI5876      4.678      0.21      21    44
# Comp:  2          [OIII]5007_d      200.6      0.26      21    44
# Comp:  2            [OI]6300_d      2.385      0.26      21    44
# Comp:  2           [NII]6583_d      6.305      0.26      21    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -126        95
#  comp.  1:        19        29
#  comp.  2:        22        51
# chi2/DOF: 2.172; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.31      0.20      19    29
# Comp:  1                Halpha      122.1      0.20      19    29
# Comp:  2             [SII]6716      8.843      0.22      22    51
# Comp:  2             [SII]6731      6.061      0.22      22    51
# Comp:  2              HeII4687    0.09685      0.22      22    51
# Comp:  2               HeI5876      4.409      0.22      22    51
# Comp:  2          [OIII]5007_d      213.4      0.27      22    51
# Comp:  2            [OI]6300_d      2.458      0.27      22    51
# Comp:  2           [NII]6583_d      5.823      0.27      22    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
#  comp.  1:        16        23
#  comp.  2:        16        37
# chi2/DOF: 1.897; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.67      0.20      16    23
# Comp:  1                Halpha      115.0      0.20      16    23
# Comp:  2             [SII]6716      8.834      0.21      16    37
# Comp:  2             [SII]6731      5.584      0.21      16    37
# Comp:  2              HeII4687    0.03468      0.21      16    37
# Comp:  2               HeI5876      4.385      0.21      16    37
# Comp:  2          [OIII]5007_d      191.1      0.26      16    37
# Comp:  2            [OI]6300_d      1.901      0.26      16    37
# Comp:  2           [NII]6583_d      5.365      0.26      16    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:        16        18
#  comp.  2:        18        45
# chi2/DOF: 2.817; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.78      0.19      16    18
# Comp:  1                Halpha      117.2      0.19      16    18
# Comp:  2             [SII]6716      7.752      0.21      18    45
# Comp:  2             [SII]6731      6.839      0.21      18    45
# Comp:  2              HeII4687    0.02304      0.21      18    45
# Comp:  2               HeI5876      4.230      0.21      18    45
# Comp:  2          [OIII]5007_d      203.4      0.27      18    45
# Comp:  2            [OI]6300_d      2.368      0.27      18    45
# Comp:  2           [NII]6583_d      5.658      0.27      18    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -101        64
#  comp.  1:        17        29
#  comp.  2:        17        41
# chi2/DOF: 2.558; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.71      0.20      17    29
# Comp:  1                Halpha      116.3      0.20      17    29
# Comp:  2             [SII]6716      9.362      0.21      17    41
# Comp:  2             [SII]6731      6.858      0.21      17    41
# Comp:  2              HeII4687      0.000      0.21      17    41
# Comp:  2               HeI5876      4.307      0.21      17    41
# Comp:  2          [OIII]5007_d      196.6      0.26      17    41
# Comp:  2            [OI]6300_d      2.590      0.26      17    41
# Comp:  2           [NII]6583_d      5.721      0.26      17    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16         1
#  comp.  1:        15        15
#  comp.  2:        16        41
# chi2/DOF: 2.683; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      38.84      0.19      15    15
# Comp:  1                Halpha      113.5      0.19      15    15
# Comp:  2             [SII]6716      9.784      0.21      16    41
# Comp:  2             [SII]6731      6.679      0.21      16    41
# Comp:  2              HeII4687      0.000      0.21      16    41
# Comp:  2               HeI5876      4.462      0.21      16    41
# Comp:  2          [OIII]5007_d      205.2      0.26      16    41
# Comp:  2            [OI]6300_d      2.276      0.26      16    41
# Comp:  2           [NII]6583_d      5.953      0.26      16    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       177         1
#  comp.  1:        14        10
#  comp.  2:        22        44
# chi2/DOF: 2.381; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.11      0.19      14    10
# Comp:  1                Halpha      112.5      0.19      14    10
# Comp:  2             [SII]6716      9.073      0.21      22    44
# Comp:  2             [SII]6731      6.856      0.21      22    44
# Comp:  2              HeII4687    0.01474      0.21      22    44
# Comp:  2               HeI5876      4.472      0.21      22    44
# Comp:  2          [OIII]5007_d      206.3      0.26      22    44
# Comp:  2            [OI]6300_d      2.478      0.26      22    44
# Comp:  2           [NII]6583_d      5.619      0.26      22    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       145         1
#  comp.  1:        16        20
#  comp.  2:        24        51
# chi2/DOF: 2.122; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.77      0.20      16    20
# Comp:  1                Halpha      115.7      0.20      16    20
# Comp:  2             [SII]6716      10.34      0.21      24    51
# Comp:  2             [SII]6731      6.376      0.21      24    51
# Comp:  2              HeII4687      0.000      0.21      24    51
# Comp:  2               HeI5876      4.599      0.21      24    51
# Comp:  2          [OIII]5007_d      208.9      0.27      24    51
# Comp:  2            [OI]6300_d      2.539      0.27      24    51
# Comp:  2           [NII]6583_d      6.172      0.27      24    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        79
#  comp.  1:        15        19
#  comp.  2:        21        42
# chi2/DOF: 2.727; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.13      0.20      15    19
# Comp:  1                Halpha      114.4      0.20      15    19
# Comp:  2             [SII]6716      9.102      0.21      21    42
# Comp:  2             [SII]6731      6.749      0.21      21    42
# Comp:  2              HeII4687   0.009476      0.21      21    42
# Comp:  2               HeI5876      4.009      0.21      21    42
# Comp:  2          [OIII]5007_d      201.4      0.26      21    42
# Comp:  2            [OI]6300_d      2.247      0.26      21    42
# Comp:  2           [NII]6583_d      5.817      0.26      21    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:        15        18
#  comp.  2:        17        47
# chi2/DOF: 2.715; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.44      0.19      15    18
# Comp:  1                Halpha      114.1      0.19      15    18
# Comp:  2             [SII]6716      9.601      0.21      17    47
# Comp:  2             [SII]6731      6.382      0.21      17    47
# Comp:  2              HeII4687      0.000      0.21      17    47
# Comp:  2               HeI5876      4.909      0.21      17    47
# Comp:  2          [OIII]5007_d      201.1      0.27      17    47
# Comp:  2            [OI]6300_d      2.234      0.27      17    47
# Comp:  2           [NII]6583_d      5.957      0.27      17    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53         1
#  comp.  1:        16        19
#  comp.  2:        21        48
# chi2/DOF: 2.831; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.28      0.20      16    19
# Comp:  1                Halpha      117.5      0.20      16    19
# Comp:  2             [SII]6716      8.433      0.21      21    48
# Comp:  2             [SII]6731      6.499      0.21      21    48
# Comp:  2              HeII4687    0.05279      0.21      21    48
# Comp:  2               HeI5876      4.455      0.21      21    48
# Comp:  2          [OIII]5007_d      210.1      0.27      21    48
# Comp:  2            [OI]6300_d      2.544      0.27      21    48
# Comp:  2           [NII]6583_d      5.819      0.27      21    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       108        49
#  comp.  1:        17        14
#  comp.  2:        15        40
# chi2/DOF: 2.447; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 93; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.72      0.19      17    14
# Comp:  1                Halpha      114.0      0.19      17    14
# Comp:  2             [SII]6716      10.05      0.21      15    40
# Comp:  2             [SII]6731      6.163      0.21      15    40
# Comp:  2              HeII4687      0.000      0.21      15    40
# Comp:  2               HeI5876      4.731      0.21      15    40
# Comp:  2          [OIII]5007_d      199.2      0.26      15    40
# Comp:  2            [OI]6300_d      2.433      0.26      15    40
# Comp:  2           [NII]6583_d      5.934      0.26      15    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32         1
#  comp.  1:        16        23
#  comp.  2:        15        38
# chi2/DOF: 2.519; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.76      0.20      16    23
# Comp:  1                Halpha      114.0      0.20      16    23
# Comp:  2             [SII]6716      9.349      0.21      15    38
# Comp:  2             [SII]6731      6.137      0.21      15    38
# Comp:  2              HeII4687    0.01288      0.21      15    38
# Comp:  2               HeI5876      4.641      0.21      15    38
# Comp:  2          [OIII]5007_d      201.1      0.26      15    38
# Comp:  2            [OI]6300_d      2.018      0.26      15    38
# Comp:  2           [NII]6583_d      6.263      0.26      15    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82         8
#  comp.  1:        15        25
#  comp.  2:        19        51
# chi2/DOF: 2.658; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      44.07      0.20      15    25
# Comp:  1                Halpha      116.4      0.20      15    25
# Comp:  2             [SII]6716      10.17      0.22      19    51
# Comp:  2             [SII]6731      5.994      0.22      19    51
# Comp:  2              HeII4687    0.01230      0.22      19    51
# Comp:  2               HeI5876      4.122      0.22      19    51
# Comp:  2          [OIII]5007_d      210.6      0.27      19    51
# Comp:  2            [OI]6300_d      2.528      0.27      19    51
# Comp:  2           [NII]6583_d      6.189      0.27      19    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       204       643
#  comp.  1:        16        26
#  comp.  2:        16        44
# chi2/DOF: 2.755; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      37.68      0.20      16    26
# Comp:  1                Halpha      114.4      0.20      16    26
# Comp:  2             [SII]6716      9.464      0.21      16    44
# Comp:  2             [SII]6731      6.965      0.21      16    44
# Comp:  2              HeII4687    0.01899      0.21      16    44
# Comp:  2               HeI5876      4.756      0.21      16    44
# Comp:  2          [OIII]5007_d      203.1      0.26      16    44
# Comp:  2            [OI]6300_d      2.019      0.26      16    44
# Comp:  2           [NII]6583_d      6.252      0.26      16    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14         1
#  comp.  1:        19        24
#  comp.  2:        13        42
# chi2/DOF: 2.098; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.14      0.20      19    24
# Comp:  1                Halpha      119.7      0.20      19    24
# Comp:  2             [SII]6716      10.69      0.21      13    42
# Comp:  2             [SII]6731      6.216      0.21      13    42
# Comp:  2              HeII4687    0.04111      0.21      13    42
# Comp:  2               HeI5876      4.484      0.21      13    42
# Comp:  2          [OIII]5007_d      199.7      0.26      13    42
# Comp:  2            [OI]6300_d      2.369      0.26      13    42
# Comp:  2           [NII]6583_d      6.189      0.26      13    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21       345
#  comp.  1:        13        19
#  comp.  2:        22        52
# chi2/DOF: 2.236; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      38.39      0.20      13    19
# Comp:  1                Halpha      114.7      0.20      13    19
# Comp:  2             [SII]6716      9.701      0.22      22    52
# Comp:  2             [SII]6731      6.335      0.22      22    52
# Comp:  2              HeII4687    0.07786      0.22      22    52
# Comp:  2               HeI5876      4.338      0.22      22    52
# Comp:  2          [OIII]5007_d      213.5      0.27      22    52
# Comp:  2            [OI]6300_d      2.223      0.27      22    52
# Comp:  2           [NII]6583_d      6.480      0.27      22    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49       354
#  comp.  1:        16        15
#  comp.  2:        21        49
# chi2/DOF: 2.732; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.94      0.19      16    15
# Comp:  1                Halpha      116.2      0.19      16    15
# Comp:  2             [SII]6716      10.35      0.21      21    49
# Comp:  2             [SII]6731      6.314      0.21      21    49
# Comp:  2              HeII4687    0.03739      0.21      21    49
# Comp:  2               HeI5876      4.687      0.21      21    49
# Comp:  2          [OIII]5007_d      208.0      0.27      21    49
# Comp:  2            [OI]6300_d      2.506      0.27      21    49
# Comp:  2           [NII]6583_d      5.833      0.27      21    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80        33
#  comp.  1:        16        27
#  comp.  2:        16        45
# chi2/DOF: 2.824; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.42      0.20      16    27
# Comp:  1                Halpha      113.9      0.20      16    27
# Comp:  2             [SII]6716      9.930      0.21      16    45
# Comp:  2             [SII]6731      6.262      0.21      16    45
# Comp:  2              HeII4687      0.000      0.21      16    45
# Comp:  2               HeI5876      4.223      0.21      16    45
# Comp:  2          [OIII]5007_d      206.9      0.27      16    45
# Comp:  2            [OI]6300_d      2.466      0.27      16    45
# Comp:  2           [NII]6583_d      5.768      0.27      16    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8         1
#  comp.  1:        18        20
#  comp.  2:        22        48
# chi2/DOF: 2.690; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.65      0.20      18    20
# Comp:  1                Halpha      114.7      0.20      18    20
# Comp:  2             [SII]6716      10.35      0.21      22    48
# Comp:  2             [SII]6731      6.677      0.21      22    48
# Comp:  2              HeII4687    0.09884      0.21      22    48
# Comp:  2               HeI5876      4.147      0.21      22    48
# Comp:  2          [OIII]5007_d      211.2      0.27      22    48
# Comp:  2            [OI]6300_d      2.659      0.27      22    48
# Comp:  2           [NII]6583_d      5.674      0.27      22    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38         1
#  comp.  1:        19        28
#  comp.  2:        18        48
# chi2/DOF: 2.640; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.70      0.20      19    28
# Comp:  1                Halpha      121.0      0.20      19    28
# Comp:  2             [SII]6716      8.801      0.21      18    48
# Comp:  2             [SII]6731      6.035      0.21      18    48
# Comp:  2              HeII4687      0.000      0.21      18    48
# Comp:  2               HeI5876      4.530      0.21      18    48
# Comp:  2          [OIII]5007_d      212.0      0.27      18    48
# Comp:  2            [OI]6300_d      2.731      0.27      18    48
# Comp:  2           [NII]6583_d      6.086      0.27      18    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        60         1
#  comp.  1:        17        30
#  comp.  2:        19        41
# chi2/DOF: 2.692; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.51      0.20      17    30
# Comp:  1                Halpha      117.3      0.20      17    30
# Comp:  2             [SII]6716      10.07      0.21      19    41
# Comp:  2             [SII]6731      6.070      0.21      19    41
# Comp:  2              HeII4687      0.000      0.21      19    41
# Comp:  2               HeI5876      4.046      0.21      19    41
# Comp:  2          [OIII]5007_d      200.1      0.26      19    41
# Comp:  2            [OI]6300_d      2.550      0.26      19    41
# Comp:  2           [NII]6583_d      5.795      0.26      19    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:        17        22
#  comp.  2:        20        52
# chi2/DOF: 2.713; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.56      0.20      17    22
# Comp:  1                Halpha      118.5      0.20      17    22
# Comp:  2             [SII]6716      8.733      0.22      20    52
# Comp:  2             [SII]6731      6.040      0.22      20    52
# Comp:  2              HeII4687      0.000      0.22      20    52
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.17      0.20      16    28
# Comp:  1                Halpha      118.8      0.20      16    28
# Comp:  2             [SII]6716      8.221      0.21      15    41
# Comp:  2             [SII]6731      6.679      0.21      15    41
# Comp:  2              HeII4687      0.000      0.21      15    41
# Comp:  2               HeI5876      4.537      0.21      15    41
# Comp:  2          [OIII]5007_d      200.6      0.26      15    41
# Comp:  2            [OI]6300_d      2.252      0.26      15    41
# Comp:  2           [NII]6583_d      5.520      0.26      15    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        67
#  comp.  1:        14        21
#  comp.  2:        18        49
# chi2/DOF: 2.547; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.29      0.20      14    21
# Comp:  1                Halpha      113.2      0.20      14    21
# Comp:  2             [SII]6716      8.778      0.21      18    49
# Comp:  2             [SII]6731      6.355      0.21      18    49
# Comp:  2              HeII4687      0.000      0.21      18    49
# Comp:  2               HeI5876      4.694      0.21      18    49
# Comp:  2          [OIII]5007_d      202.7      0.27      18    49
# Comp:  2            [OI]6300_d      2.658      0.27      18    49
# Comp:  2           [NII]6583_d      5.651      0.27      18    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       107        35
#  comp.  1:        17        17
#  comp.  2:        20        50
# chi2/DOF: 2.576; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      38.15      0.19      17    17
# Comp:  1                Halpha      114.6      0.19      17    17
# Comp:  2             [SII]6716      9.415      0.21      20    50
# Comp:  2             [SII]6731      6.921      0.21      20    50
# Comp:  2              HeII4687    0.03343      0.21      20    50
# Comp:  2               HeI5876      4.795      0.21      20    50
# Comp:  2          [OIII]5007_d      214.5      0.27      20    50
# Comp:  2            [OI]6300_d      2.360      0.27      20    50
# Comp:  2           [NII]6583_d      6.636      0.27      20    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
#  comp.  1:        16        20
#  comp.  2:        17        46
# chi2/DOF: 2.876; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      42.86      0.20      16    20
# Comp:  1                Halpha      114.3      0.20      16    20
# Comp:  2             [SII]6716      10.10      0.21      17    46
# Comp:  2             [SII]6731      6.402      0.21      17    46
# Comp:  2              HeII4687     0.1002      0.21      17    46
# Comp:  2               HeI5876      4.747      0.21      17    46
# Comp:  2          [OIII]5007_d      210.5      0.27      17    46
# Comp:  2            [OI]6300_d      2.232      0.27      17    46
# Comp:  2           [NII]6583_d      5.794      0.27      17    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38       103
#  comp.  1:        15        18
#  comp.  2:        13        37
# chi2/DOF: 1.749; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.15      0.19      15    18
# Comp:  1                Halpha      117.3      0.19      15    18
# Comp:  2             [SII]6716      8.428      0.21      13    37
# Comp:  2             [SII]6731      6.524      0.21      13    37
# Comp:  2              HeII4687    0.02581      0.21      13    37
# Comp:  2               HeI5876      4.465      0.21      13    37
# Comp:  2          [OIII]5007_d      196.2      0.26      13    37
# Comp:  2            [OI]6300_d      2.121      0.26      13    37
# Comp:  2           [NII]6583_d      5.798      0.26      13    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       106         1
#  comp.  1:        20        27
#  comp.  2:        15        37
# chi2/DOF: 2.145; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 67; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      38.75      0.20      20    27
# Comp:  1                Halpha      118.6      0.20      20    27
# Comp:  2             [SII]6716      7.559      0.20      15    37
# Comp:  2             [SII]6731      6.242      0.20      15    37
# Comp:  2              HeII4687      0.000      0.20      15    37
# Comp:  2               HeI5876      4.606      0.20      15    37
# Comp:  2          [OIII]5007_d      199.1      0.26      15    37
# Comp:  2            [OI]6300_d      2.210      0.26      15    37
# Comp:  2           [NII]6583_d      6.071      0.26      15    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        74
#  comp.  1:        15        27
#  comp.  2:        17        38
# chi2/DOF: 2.288; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.43      0.20      15    27
# Comp:  1                Halpha      118.7      0.20      15    27
# Comp:  2             [SII]6716      8.910      0.21      17    38
# Comp:  2             [SII]6731      5.783      0.21      17    38
# Comp:  2              HeII4687      0.000      0.21      17    38
# Comp:  2               HeI5876      4.434      0.21      17    38
# Comp:  2          [OIII]5007_d      194.1      0.26      17    38
# Comp:  2            [OI]6300_d      2.209      0.26      17    38
# Comp:  2           [NII]6583_d      6.313      0.26      17    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84        71
#  comp.  1:        19        30
#  comp.  2:        23        45
# chi2/DOF: 2.372; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      41.52      0.20      19    30
# Comp:  1                Halpha      122.6      0.20      19    30
# Comp:  2             [SII]6716      8.433      0.21      23    45
# Comp:  2             [SII]6731      6.224      0.21      23    45
# Comp:  2              HeII4687      0.000      0.21      23    45
# Comp:  2               HeI5876      4.829      0.21      23    45
# Comp:  2          [OIII]5007_d      203.3      0.27      23    45
# Comp:  2            [OI]6300_d      2.245      0.27      23    45
# Comp:  2           [NII]6583_d      5.934      0.27      23    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        34
#  comp.  1:        21        29
#  comp.  2:        21        51
# chi2/DOF: 2.132; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 82; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      44.56      0.20      21    29
# Comp:  1                Halpha      119.1      0.20      21    29
# Comp:  2             [SII]6716      9.512      0.21      21    51
# Comp:  2             [SII]6731      6.161      0.21      21    51
# Comp:  2              HeII4687    0.07701      0.21      21    51
# Comp:  2               HeI5876      4.046      0.21      21    51
# Comp:  2          [OIII]5007_d      215.4      0.27      21    51
# Comp:  2            [OI]6300_d      2.132      0.27      21    51
# Comp:  2           [NII]6583_d      6.054      0.27      21    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       177         1
#  comp.  1:        18        20
#  comp.  2:        17        48
# chi2/DOF: 2.629; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      39.18      0.20      18    20
# Comp:  1                Halpha      118.2      0.20      18    20
# Comp:  2             [SII]6716      10.13      0.21      17    48
# Comp:  2             [SII]6731      6.497      0.21      17    48
# Comp:  2              HeII4687    0.09590      0.21      17    48
# Comp:  2               HeI5876      4.088      0.21      17    48
# Comp:  2          [OIII]5007_d      203.0      0.27      17    48
# Comp:  2            [OI]6300_d      2.440      0.27      17    48
# Comp:  2           [NII]6583_d      6.155      0.27      17    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:        19        23
#  comp.  2:        13        42
# chi2/DOF: 1.982; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      38.91      0.20      19    23
# Comp:  1                Halpha      119.2      0.20      19    23
# Comp:  2             [SII]6716      8.521      0.21      13    42
# Comp:  2             [SII]6731      5.678      0.21      13    42
# Comp:  2              HeII4687    0.03385      0.21      13    42
# Comp:  2               HeI5876      4.387      0.21      13    42
# Comp:  2          [OIII]5007_d      200.6      0.26      13    42
# Comp:  2            [OI]6300_d      2.243      0.26      13    42
# Comp:  2           [NII]6583_d      5.819      0.26      13    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:        17        21
#  comp.  2:        24        52
# chi2/DOF: 1.738; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      43.41      0.20      17    21
# Comp:  1                Halpha      118.5      0.20      17    21
# Comp:  2             [SII]6716      10.45      0.22      24    52
# Comp:  2             [SII]6731      6.253      0.22      24    52
# Comp:  2              HeII4687    0.06390      0.22      24    52
# Comp:  2               HeI5876      4.575      0.22      24    52
# Comp:  2          [OIII]5007_d      217.0      0.27      24    52
# Comp:  2            [OI]6300_d      2.721      0.27      24    52
# Comp:  2           [NII]6583_d      6.148      0.27      24    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       128         1
#  comp.  1:        19        28
#  comp.  2:        21        47
# chi2/DOF: 2.789; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 83; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      40.48      0.20      19    28
# Comp:  1                Halpha      118.8      0.20      19    28
# Comp:  2             [SII]6716      9.509      0.21      21    47
# Comp:  2             [SII]6731      5.939      0.21      21    47
# Comp:  2              HeII4687      0.000      0.21      21    47
# Comp:  2               HeI5876      4.350      0.21      21    47
# Comp:  2          [OIII]5007_d      210.3      0.27      21    47
# Comp:  2            [OI]6300_d      2.348      0.27      21    47
# Comp:  2           [NII]6583_d      6.028      0.27      21    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23         1
#  comp.  1:        17        13
#  comp.  2:        18        41
# chi2/DOF: 2.687; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      36.19      0.19      17    13
# Comp:  1                Halpha      115.8      0.19      17    13
# Comp:  2             [SII]6716      8.404      0.21      18    41
# Comp:  2             [SII]6731      6.262      0.21      18    41
# Comp:  2              HeII4687      0.000      0.21      18    41
# Comp:  2               HeI5876      4.399      0.21      18    41
# Comp:  2          [OIII]5007_d      202.4      0.26      18    41
# Comp:  2            [OI]6300_d      2.065      0.26      18    41
# Comp:  2           [NII]6583_d      5.779      0.26      18    41
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([2.04089761, 3.38466977, 1.10672533, 0.50624287, 0.02696455,
#        0.33642633, 6.48352845, 0.25666897, 0.37884222])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 41.01563254, 159.14568716,  13.04865456,   8.8595408 ,
#          0.        ,   5.45529702, 215.34888911,   3.10425397,
#          8.12553369])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_2_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_2_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_2_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_2_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_2_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0         Hbeta   5.836919    0.290439
# 1        Halpha  22.647964    0.481671
# 2     [SII]6716   1.856949    0.157498
# 3     [SII]6731   1.260798    0.072043
# 4      HeII4687   0.000000    0.003837
# 5       HeI5876   0.776341    0.047877
# 6  [OIII]5007_d  30.646221    0.922669
# 7    [OI]6300_d   0.441765    0.036526
# 8   [NII]6583_d   1.156342    0.053913
#           Name       Flux  Error_flux
# 0        Hbeta   5.836919    0.290439
# 1       Halpha  22.647964    0.481671
# 2    [SII]6716   1.856949    0.157498
# 3    [SII]6731   1.260798    0.072043
# 4     HeII4687   0.000000    0.003837
# 5      HeI5876   0.776341    0.047877
# 6   [OIII]4959   7.661555    0.922669
# 7   [OIII]5007  22.984666    0.922669
# 8     [OI]6300   0.331324    0.036526
# 9     [OI]6364   0.110441    0.036526
# 10   [NII]6548   0.289085    0.053913
# 11   [NII]6583   0.867256    0.053913

# %%
np.median(flux_rf_rebin)
# Out:
# 0.1423096299202942
