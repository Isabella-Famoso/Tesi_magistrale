# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_1.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_1263/FORS2.2022-01-06T07_26_01.965/Spectra_extraction/redshift.txt")  
z = red[0][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.21714496 2.21788182 2.21861868 ... 3.53170494 3.5324418  3.53317866]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3136, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3136, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3136, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -129         2
# chi2/DOF: 0.01139; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 31; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -97         1
# chi2/DOF: 0.004056; DOF: 1892; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# [1.33631574 1.30595968 1.26166113 ... 0.99489259 1.50124998 1.51288821]
# [1.28085685 1.29323194 1.30686134 ... 0.65199499 0.6484655  0.64829422]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-97.47713331,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
#  comp.  1:         9        23
#  comp.  2:         5        44
# chi2/DOF: 13.63; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      141.9      0.24       9    23
# Comp:  1                Halpha      368.7      0.24       9    23
# Comp:  2             [SII]6716      22.89      0.26       5    44
# Comp:  2             [SII]6731      17.08      0.26       5    44
# Comp:  2              HeII4687     0.2705      0.26       5    44
# Comp:  2               HeI5876      16.18      0.26       5    44
# Comp:  2          [OIII]5007_d      1021.      0.32       5    44
# Comp:  2            [OI]6300_d      6.764      0.32       5    44
# Comp:  2           [NII]6583_d      16.64      0.32       5    44
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:    675; gas flux:    144 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:   1794; gas flux:    505 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  98.88; gas flux:     32 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  72.68; gas flux:     24 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.151; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  68.34; gas flux:     20 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   3157; gas flux:   1066 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  21.32; gas flux:      9 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  53.92; gas flux:     23 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        19        43
#  comp.  1:         8        18
#  comp.  2:         6        44
# chi2/DOF: 12.08; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      132.3      0.24       8    18
# Comp:  1                Halpha      364.5      0.24       8    18
# Comp:  2             [SII]6716      21.47      0.26       6    44
# Comp:  2             [SII]6731      17.27      0.26       6    44
# Comp:  2              HeII4687     0.2640      0.26       6    44
# Comp:  2               HeI5876      14.89      0.26       6    44
# Comp:  2          [OIII]5007_d      1023.      0.32       6    44
# Comp:  2            [OI]6300_d      7.298      0.32       6    44
# Comp:  2           [NII]6583_d      16.27      0.32       6    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       117         1
#  comp.  1:         9        26
#  comp.  2:         6        42
# chi2/DOF: 11.44; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      139.7      0.24       9    26
# Comp:  1                Halpha      372.5      0.24       9    26
# Comp:  2             [SII]6716      25.07      0.25       6    42
# Comp:  2             [SII]6731      16.81      0.25       6    42
# Comp:  2              HeII4687     0.1570      0.25       6    42
# Comp:  2               HeI5876      14.98      0.25       6    42
# Comp:  2          [OIII]5007_d      1025.      0.32       6    42
# Comp:  2            [OI]6300_d      5.944      0.32       6    42
# Comp:  2           [NII]6583_d      16.72      0.32       6    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66       490
#  comp.  1:         9        28
#  comp.  2:         5        41
# chi2/DOF: 10.75; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      135.2      0.24       9    28
# Comp:  1                Halpha      367.3      0.24       9    28
# Comp:  2             [SII]6716      21.75      0.25       5    41
# Comp:  2             [SII]6731      18.61      0.25       5    41
# Comp:  2              HeII4687     0.2955      0.25       5    41
# Comp:  2               HeI5876      16.83      0.25       5    41
# Comp:  2          [OIII]5007_d      1025.      0.32       5    41
# Comp:  2            [OI]6300_d      5.841      0.32       5    41
# Comp:  2           [NII]6583_d      16.17      0.32       5    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4         1
#  comp.  1:         8        31
#  comp.  2:         4        44
# chi2/DOF: 11.82; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      142.7      0.25       8    31
# Comp:  1                Halpha      374.4      0.25       8    31
# Comp:  2             [SII]6716      21.08      0.26       4    44
# Comp:  2             [SII]6731      17.63      0.26       4    44
# Comp:  2              HeII4687     0.2705      0.26       4    44
# Comp:  2               HeI5876      16.09      0.26       4    44
# Comp:  2          [OIII]5007_d      1017.      0.32       4    44
# Comp:  2            [OI]6300_d      7.372      0.32       4    44
# Comp:  2           [NII]6583_d      16.63      0.32       4    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       112         1
#  comp.  1:         8        28
#  comp.  2:         7        43
# chi2/DOF: 11.37; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      148.4      0.24       8    28
# Comp:  1                Halpha      368.6      0.24       8    28
# Comp:  2             [SII]6716      25.59      0.25       7    43
# Comp:  2             [SII]6731      16.60      0.25       7    43
# Comp:  2              HeII4687     0.1093      0.25       7    43
# Comp:  2               HeI5876      16.54      0.25       7    43
# Comp:  2          [OIII]5007_d      1021.      0.32       7    43
# Comp:  2            [OI]6300_d      6.580      0.32       7    43
# Comp:  2           [NII]6583_d      16.23      0.32       7    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       115      1000
#  comp.  1:         9        20
#  comp.  2:         5        43
# chi2/DOF: 11.89; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      137.2      0.24       9    20
# Comp:  1                Halpha      365.2      0.24       9    20
# Comp:  2             [SII]6716      22.47      0.25       5    43
# Comp:  2             [SII]6731      16.13      0.25       5    43
# Comp:  2              HeII4687     0.3270      0.25       5    43
# Comp:  2               HeI5876      14.33      0.25       5    43
# Comp:  2          [OIII]5007_d      999.4      0.32       5    43
# Comp:  2            [OI]6300_d      6.956      0.32       5    43
# Comp:  2           [NII]6583_d      15.97      0.32       5    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       157         1
#  comp.  1:         9        10
#  comp.  2:         4        46
# chi2/DOF: 10.85; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 57; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      133.9      0.23       9    10
# Comp:  1                Halpha      364.2      0.23       9    10
# Comp:  2             [SII]6716      25.98      0.26       4    46
# Comp:  2             [SII]6731      17.66      0.26       4    46
# Comp:  2              HeII4687     0.3321      0.26       4    46
# Comp:  2               HeI5876      16.42      0.26       4    46
# Comp:  2          [OIII]5007_d      1029.      0.32       4    46
# Comp:  2            [OI]6300_d      6.546      0.32       4    46
# Comp:  2           [NII]6583_d      17.16      0.32       4    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       119         1
#  comp.  1:         8         9
#  comp.  2:         6        45
# chi2/DOF: 10.72; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 76; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      144.2      0.23       8     9
# Comp:  1                Halpha      366.1      0.23       8     9
# Comp:  2             [SII]6716      25.54      0.26       6    45
# Comp:  2             [SII]6731      15.86      0.26       6    45
# Comp:  2              HeII4687     0.1916      0.26       6    45
# Comp:  2               HeI5876      16.98      0.26       6    45
# Comp:  2          [OIII]5007_d      1017.      0.32       6    45
# Comp:  2            [OI]6300_d      5.895      0.32       6    45
# Comp:  2           [NII]6583_d      16.89      0.32       6    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       122         1
#  comp.  1:        11        30
#  comp.  2:         5        42
# chi2/DOF: 11.82; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      148.4      0.24      11    30
# Comp:  1                Halpha      379.5      0.24      11    30
# Comp:  2             [SII]6716      25.57      0.25       5    42
# Comp:  2             [SII]6731      15.42      0.25       5    42
# Comp:  2              HeII4687     0.2813      0.25       5    42
# Comp:  2               HeI5876      17.90      0.25       5    42
# Comp:  2          [OIII]5007_d      1022.      0.32       5    42
# Comp:  2            [OI]6300_d      6.588      0.32       5    42
# Comp:  2           [NII]6583_d      16.88      0.32       5    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:         7        16
#  comp.  2:         5        40
# chi2/DOF: 9.150; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      148.1      0.24       7    16
# Comp:  1                Halpha      352.3      0.24       7    16
# Comp:  2             [SII]6716      21.83      0.25       5    40
# Comp:  2             [SII]6731      17.70      0.25       5    40
# Comp:  2              HeII4687     0.1858      0.25       5    40
# Comp:  2               HeI5876      17.66      0.25       5    40
# Comp:  2          [OIII]5007_d      1015.      0.32       5    40
# Comp:  2            [OI]6300_d      5.928      0.32       5    40
# Comp:  2           [NII]6583_d      17.39      0.32       5    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       102         1
#  comp.  1:         8        23
#  comp.  2:         6        42
# chi2/DOF: 11.11; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      147.9      0.24       8    23
# Comp:  1                Halpha      371.1      0.24       8    23
# Comp:  2             [SII]6716      25.44      0.25       6    42
# Comp:  2             [SII]6731      15.36      0.25       6    42
# Comp:  2              HeII4687     0.1317      0.25       6    42
# Comp:  2               HeI5876      17.64      0.25       6    42
# Comp:  2          [OIII]5007_d      1030.      0.32       6    42
# Comp:  2            [OI]6300_d      6.418      0.32       6    42
# Comp:  2           [NII]6583_d      17.59      0.32       6    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       478      1000
#  comp.  1:        12        33
#  comp.  2:         6        47
# chi2/DOF: 6.806; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      142.9      0.25      12    33
# Comp:  1                Halpha      382.4      0.25      12    33
# Comp:  2             [SII]6716      24.60      0.26       6    47
# Comp:  2             [SII]6731      15.97      0.26       6    47
# Comp:  2              HeII4687     0.2517      0.26       6    47
# Comp:  2               HeI5876      18.18      0.26       6    47
# Comp:  2          [OIII]5007_d      1052.      0.33       6    47
# Comp:  2            [OI]6300_d      6.769      0.33       6    47
# Comp:  2           [NII]6583_d      16.22      0.33       6    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        56         1
#  comp.  1:         6        15
#  comp.  2:         6        43
# chi2/DOF: 10.51; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      135.9      0.24       6    15
# Comp:  1                Halpha      354.6      0.24       6    15
# Comp:  2             [SII]6716      23.93      0.25       6    43
# Comp:  2             [SII]6731      18.39      0.25       6    43
# Comp:  2              HeII4687     0.1113      0.25       6    43
# Comp:  2               HeI5876      16.87      0.25       6    43
# Comp:  2          [OIII]5007_d      1020.      0.32       6    43
# Comp:  2            [OI]6300_d      5.853      0.32       6    43
# Comp:  2           [NII]6583_d      17.27      0.32       6    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       136         1
#  comp.  1:        11        28
#  comp.  2:         4        43
# chi2/DOF: 10.25; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 100; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      136.8      0.24      11    28
# Comp:  1                Halpha      383.6      0.24      11    28
# Comp:  2             [SII]6716      23.51      0.25       4    43
# Comp:  2             [SII]6731      16.22      0.25       4    43
# Comp:  2              HeII4687     0.2524      0.25       4    43
# Comp:  2               HeI5876      16.05      0.25       4    43
# Comp:  2          [OIII]5007_d      1008.      0.32       4    43
# Comp:  2            [OI]6300_d      6.605      0.32       4    43
# Comp:  2           [NII]6583_d      16.32      0.32       4    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:         6        23
#  comp.  2:         3        47
# chi2/DOF: 9.525; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      150.5      0.24       6    23
# Comp:  1                Halpha      360.9      0.24       6    23
# Comp:  2             [SII]6716      21.64      0.26       3    47
# Comp:  2             [SII]6731      15.78      0.26       3    47
# Comp:  2              HeII4687     0.1623      0.26       3    47
# Comp:  2               HeI5876      15.66      0.26       3    47
# Comp:  2          [OIII]5007_d      1034.      0.33       3    47
# Comp:  2            [OI]6300_d      6.722      0.33       3    47
# Comp:  2           [NII]6583_d      17.86      0.33       3    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -162         1
#  comp.  1:         6        17
#  comp.  2:         4        46
# chi2/DOF: 10.54; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      145.7      0.24       6    17
# Comp:  1                Halpha      355.4      0.24       6    17
# Comp:  2             [SII]6716      22.85      0.26       4    46
# Comp:  2             [SII]6731      16.85      0.26       4    46
# Comp:  2              HeII4687     0.3084      0.26       4    46
# Comp:  2               HeI5876      17.58      0.26       4    46
# Comp:  2          [OIII]5007_d      1037.      0.32       4    46
# Comp:  2            [OI]6300_d      6.628      0.32       4    46
# Comp:  2           [NII]6583_d      16.96      0.32       4    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -112         1
#  comp.  1:        10        18
#  comp.  2:         7        41
# chi2/DOF: 11.43; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 31; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      139.9      0.24      10    18
# Comp:  1                Halpha      368.3      0.24      10    18
# Comp:  2             [SII]6716      22.27      0.25       7    41
# Comp:  2             [SII]6731      16.63      0.25       7    41
# Comp:  2              HeII4687     0.2198      0.25       7    41
# Comp:  2               HeI5876      14.17      0.25       7    41
# Comp:  2          [OIII]5007_d      1015.      0.32       7    41
# Comp:  2            [OI]6300_d      7.667      0.32       7    41
# Comp:  2           [NII]6583_d      17.06      0.32       7    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56         1
#  comp.  1:        11        32
#  comp.  2:         4        42
# chi2/DOF: 8.446; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      157.3      0.25      11    32
# Comp:  1                Halpha      383.9      0.25      11    32
# Comp:  2             [SII]6716      22.64      0.25       4    42
# Comp:  2             [SII]6731      15.63      0.25       4    42
# Comp:  2              HeII4687     0.1643      0.25       4    42
# Comp:  2               HeI5876      17.62      0.25       4    42
# Comp:  2          [OIII]5007_d      998.2      0.32       4    42
# Comp:  2            [OI]6300_d      7.559      0.32       4    42
# Comp:  2           [NII]6583_d      16.28      0.32       4    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54         1
#  comp.  1:         7        20
#  comp.  2:         5        45
# chi2/DOF: 11.20; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      148.8      0.24       7    20
# Comp:  1                Halpha      355.6      0.24       7    20
# Comp:  2             [SII]6716      22.66      0.26       5    45
# Comp:  2             [SII]6731      18.91      0.26       5    45
# Comp:  2              HeII4687     0.3307      0.26       5    45
# Comp:  2               HeI5876      17.55      0.26       5    45
# Comp:  2          [OIII]5007_d      1031.      0.32       5    45
# Comp:  2            [OI]6300_d      7.034      0.32       5    45
# Comp:  2           [NII]6583_d      17.11      0.32       5    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74      1000
#  comp.  1:        12        30
#  comp.  2:         5        46
# chi2/DOF: 9.493; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      144.4      0.24      12    30
# Comp:  1                Halpha      384.5      0.24      12    30
# Comp:  2             [SII]6716      21.64      0.26       5    46
# Comp:  2             [SII]6731      16.90      0.26       5    46
# Comp:  2              HeII4687     0.2336      0.26       5    46
# Comp:  2               HeI5876      16.88      0.26       5    46
# Comp:  2          [OIII]5007_d      1015.      0.33       5    46
# Comp:  2            [OI]6300_d      7.050      0.33       5    46
# Comp:  2           [NII]6583_d      17.71      0.33       5    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -210       359
#  comp.  1:        11        32
#  comp.  2:         6        45
# chi2/DOF: 9.053; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      154.7      0.25      11    32
# Comp:  1                Halpha      389.1      0.25      11    32
# Comp:  2             [SII]6716      21.67      0.26       6    45
# Comp:  2             [SII]6731      16.03      0.26       6    45
# Comp:  2              HeII4687     0.3449      0.26       6    45
# Comp:  2               HeI5876      15.67      0.26       6    45
# Comp:  2          [OIII]5007_d      1024.      0.32       6    45
# Comp:  2            [OI]6300_d      7.630      0.32       6    45
# Comp:  2           [NII]6583_d      16.14      0.32       6    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -208         1
#  comp.  1:         7        19
#  comp.  2:         4        40
# chi2/DOF: 9.998; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      140.0      0.24       7    19
# Comp:  1                Halpha      361.6      0.24       7    19
# Comp:  2             [SII]6716      21.88      0.25       4    40
# Comp:  2             [SII]6731      15.59      0.25       4    40
# Comp:  2              HeII4687     0.2898      0.25       4    40
# Comp:  2               HeI5876      16.47      0.25       4    40
# Comp:  2          [OIII]5007_d      990.3      0.32       4    40
# Comp:  2            [OI]6300_d      5.793      0.32       4    40
# Comp:  2           [NII]6583_d      16.12      0.32       4    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        75         1
#  comp.  1:         8        14
#  comp.  2:         4        46
# chi2/DOF: 10.97; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      133.7      0.24       8    14
# Comp:  1                Halpha      367.7      0.24       8    14
# Comp:  2             [SII]6716      20.02      0.26       4    46
# Comp:  2             [SII]6731      18.39      0.26       4    46
# Comp:  2              HeII4687     0.3173      0.26       4    46
# Comp:  2               HeI5876      14.92      0.26       4    46
# Comp:  2          [OIII]5007_d      1017.      0.32       4    46
# Comp:  2            [OI]6300_d      6.071      0.32       4    46
# Comp:  2           [NII]6583_d      15.74      0.32       4    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -266       484
#  comp.  1:         9        29
#  comp.  2:         5        43
# chi2/DOF: 10.97; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      153.3      0.24       9    29
# Comp:  1                Halpha      369.6      0.24       9    29
# Comp:  2             [SII]6716      23.54      0.25       5    43
# Comp:  2             [SII]6731      18.40      0.25       5    43
# Comp:  2              HeII4687     0.3336      0.25       5    43
# Comp:  2               HeI5876      15.63      0.25       5    43
# Comp:  2          [OIII]5007_d      1002.      0.32       5    43
# Comp:  2            [OI]6300_d      7.623      0.32       5    43
# Comp:  2           [NII]6583_d      16.15      0.32       5    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        77         1
#  comp.  1:         6         9
#  comp.  2:         5        42
# chi2/DOF: 10.18; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      130.2      0.23       6     9
# Comp:  1                Halpha      355.7      0.23       6     9
# Comp:  2             [SII]6716      23.86      0.25       5    42
# Comp:  2             [SII]6731      17.88      0.25       5    42
# Comp:  2              HeII4687     0.1717      0.25       5    42
# Comp:  2               HeI5876      16.07      0.25       5    42
# Comp:  2          [OIII]5007_d      1023.      0.32       5    42
# Comp:  2            [OI]6300_d      6.706      0.32       5    42
# Comp:  2           [NII]6583_d      15.92      0.32       5    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       192         1
#  comp.  1:         6         9
#  comp.  2:         5        44
# chi2/DOF: 10.26; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 84; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      139.6      0.23       6     9
# Comp:  1                Halpha      356.2      0.23       6     9
# Comp:  2             [SII]6716      22.22      0.26       5    44
# Comp:  2             [SII]6731      18.63      0.26       5    44
# Comp:  2              HeII4687     0.3023      0.26       5    44
# Comp:  2               HeI5876      16.66      0.26       5    44
# Comp:  2          [OIII]5007_d      1025.      0.32       5    44
# Comp:  2            [OI]6300_d      6.562      0.32       5    44
# Comp:  2           [NII]6583_d      16.49      0.32       5    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        30
#  comp.  1:         7        20
#  comp.  2:         7        44
# chi2/DOF: 10.80; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      132.7      0.24       7    20
# Comp:  1                Halpha      366.4      0.24       7    20
# Comp:  2             [SII]6716      24.81      0.26       7    44
# Comp:  2             [SII]6731      17.77      0.26       7    44
# Comp:  2              HeII4687     0.1647      0.26       7    44
# Comp:  2               HeI5876      16.63      0.26       7    44
# Comp:  2          [OIII]5007_d      1012.      0.32       7    44
# Comp:  2            [OI]6300_d      7.765      0.32       7    44
# Comp:  2           [NII]6583_d      16.88      0.32       7    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -181         1
#  comp.  1:         7        15
#  comp.  2:         5        46
# chi2/DOF: 11.39; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      138.6      0.24       7    15
# Comp:  1                Halpha      359.9      0.24       7    15
# Comp:  2             [SII]6716      22.95      0.26       5    46
# Comp:  2             [SII]6731      18.66      0.26       5    46
# Comp:  2              HeII4687     0.2515      0.26       5    46
# Comp:  2               HeI5876      14.49      0.26       5    46
# Comp:  2          [OIII]5007_d      1025.      0.33       5    46
# Comp:  2            [OI]6300_d      6.897      0.33       5    46
# Comp:  2           [NII]6583_d      17.28      0.33       5    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51         1
#  comp.  1:         7        17
#  comp.  2:         5        44
# chi2/DOF: 11.79; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      136.3      0.24       7    17
# Comp:  1                Halpha      360.3      0.24       7    17
# Comp:  2             [SII]6716      23.41      0.26       5    44
# Comp:  2             [SII]6731      17.17      0.26       5    44
# Comp:  2              HeII4687     0.2255      0.26       5    44
# Comp:  2               HeI5876      17.96      0.26       5    44
# Comp:  2          [OIII]5007_d      1010.      0.32       5    44
# Comp:  2            [OI]6300_d      5.811      0.32       5    44
# Comp:  2           [NII]6583_d      16.44      0.32       5    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -123         1
#  comp.  1:         8        20
#  comp.  2:         5        45
# chi2/DOF: 12.76; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      140.4      0.24       8    20
# Comp:  1                Halpha      372.3      0.24       8    20
# Comp:  2             [SII]6716      20.93      0.26       5    45
# Comp:  2             [SII]6731      16.88      0.26       5    45
# Comp:  2              HeII4687     0.3506      0.26       5    45
# Comp:  2               HeI5876      16.17      0.26       5    45
# Comp:  2          [OIII]5007_d      1026.      0.32       5    45
# Comp:  2            [OI]6300_d      7.145      0.32       5    45
# Comp:  2           [NII]6583_d      16.58      0.32       5    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       156         1
#  comp.  1:         8        17
#  comp.  2:         5        41
# chi2/DOF: 11.80; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      142.3      0.24       8    17
# Comp:  1                Halpha      363.1      0.24       8    17
# Comp:  2             [SII]6716      24.59      0.25       5    41
# Comp:  2             [SII]6731      17.56      0.25       5    41
# Comp:  2              HeII4687     0.2431      0.25       5    41
# Comp:  2               HeI5876      17.99      0.25       5    41
# Comp:  2          [OIII]5007_d      1007.      0.32       5    41
# Comp:  2            [OI]6300_d      6.802      0.32       5    41
# Comp:  2           [NII]6583_d      16.80      0.32       5    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       120         1
#  comp.  1:         9        25
#  comp.  2:         5        39
# chi2/DOF: 10.89; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      146.0      0.24       9    25
# Comp:  1                Halpha      365.0      0.24       9    25
# Comp:  2             [SII]6716      23.30      0.25       5    39
# Comp:  2             [SII]6731      17.09      0.25       5    39
# Comp:  2              HeII4687     0.2315      0.25       5    39
# Comp:  2               HeI5876      17.31      0.25       5    39
# Comp:  2          [OIII]5007_d      1011.      0.32       5    39
# Comp:  2            [OI]6300_d      5.889      0.32       5    39
# Comp:  2           [NII]6583_d      17.51      0.32       5    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       675      1000
#  comp.  1:         6        19
#  comp.  2:         4        47
# chi2/DOF: 10.97; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      145.4      0.24       6    19
# Comp:  1                Halpha      363.5      0.24       6    19
# Comp:  2             [SII]6716      24.09      0.26       4    47
# Comp:  2             [SII]6731      15.73      0.26       4    47
# Comp:  2              HeII4687     0.3576      0.26       4    47
# Comp:  2               HeI5876      14.51      0.26       4    47
# Comp:  2          [OIII]5007_d      1030.      0.33       4    47
# Comp:  2            [OI]6300_d      7.815      0.33       4    47
# Comp:  2           [NII]6583_d      16.89      0.33       4    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        39       654
#  comp.  1:         8        29
#  comp.  2:         5        43
# chi2/DOF: 12.33; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      138.9      0.24       8    29
# Comp:  1                Halpha      368.9      0.24       8    29
# Comp:  2             [SII]6716      23.11      0.25       5    43
# Comp:  2             [SII]6731      18.30      0.25       5    43
# Comp:  2              HeII4687     0.2798      0.25       5    43
# Comp:  2               HeI5876      17.54      0.25       5    43
# Comp:  2          [OIII]5007_d      1015.      0.32       5    43
# Comp:  2            [OI]6300_d      6.516      0.32       5    43
# Comp:  2           [NII]6583_d      17.95      0.32       5    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9      1000
#  comp.  1:        12        30
#  comp.  2:         4        41
# chi2/DOF: 9.641; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      144.4      0.24      12    30
# Comp:  1                Halpha      384.4      0.24      12    30
# Comp:  2             [SII]6716      25.43      0.25       4    41
# Comp:  2             [SII]6731      17.38      0.25       4    41
# Comp:  2              HeII4687     0.3766      0.25       4    41
# Comp:  2               HeI5876      15.88      0.25       4    41
# Comp:  2          [OIII]5007_d      1007.      0.32       4    41
# Comp:  2            [OI]6300_d      6.976      0.32       4    41
# Comp:  2           [NII]6583_d      17.41      0.32       4    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -109         1
#  comp.  1:         5        12
#  comp.  2:         6        46
# chi2/DOF: 9.687; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      142.8      0.24       5    12
# Comp:  1                Halpha      359.8      0.24       5    12
# Comp:  2             [SII]6716      23.48      0.26       6    46
# Comp:  2             [SII]6731      17.89      0.26       6    46
# Comp:  2              HeII4687     0.3105      0.26       6    46
# Comp:  2               HeI5876      15.26      0.26       6    46
# Comp:  2          [OIII]5007_d      1024.      0.33       6    46
# Comp:  2            [OI]6300_d      6.784      0.33       6    46
# Comp:  2           [NII]6583_d      17.83      0.33       6    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33       881
#  comp.  1:         9        11
#  comp.  2:         5        48
# chi2/DOF: 10.02; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      133.1      0.23       9    11
# Comp:  1                Halpha      364.3      0.23       9    11
# Comp:  2             [SII]6716      25.09      0.26       5    48
# Comp:  2             [SII]6731      18.14      0.26       5    48
# Comp:  2              HeII4687     0.3087      0.26       5    48
# Comp:  2               HeI5876      17.23      0.26       5    48
# Comp:  2          [OIII]5007_d      1034.      0.33       5    48
# Comp:  2            [OI]6300_d      6.942      0.33       5    48
# Comp:  2           [NII]6583_d      17.59      0.33       5    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100         1
#  comp.  1:         7        23
#  comp.  2:         4        43
# chi2/DOF: 12.33; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      141.7      0.24       7    23
# Comp:  1                Halpha      358.5      0.24       7    23
# Comp:  2             [SII]6716      23.71      0.25       4    43
# Comp:  2             [SII]6731      16.71      0.25       4    43
# Comp:  2              HeII4687     0.2894      0.25       4    43
# Comp:  2               HeI5876      15.13      0.25       4    43
# Comp:  2          [OIII]5007_d      1020.      0.32       4    43
# Comp:  2            [OI]6300_d      6.709      0.32       4    43
# Comp:  2           [NII]6583_d      16.78      0.32       4    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4       367
#  comp.  1:         9        22
#  comp.  2:         6        43
# chi2/DOF: 12.52; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 31; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      138.1      0.24       9    22
# Comp:  1                Halpha      365.6      0.24       9    22
# Comp:  2             [SII]6716      24.46      0.25       6    43
# Comp:  2             [SII]6731      16.66      0.25       6    43
# Comp:  2              HeII4687     0.3701      0.25       6    43
# Comp:  2               HeI5876      14.98      0.25       6    43
# Comp:  2          [OIII]5007_d      1025.      0.32       6    43
# Comp:  2            [OI]6300_d      7.462      0.32       6    43
# Comp:  2           [NII]6583_d      15.50      0.32       6    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        14
#  comp.  1:        12        31
#  comp.  2:         5        47
# chi2/DOF: 9.101; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      155.2      0.24      12    31
# Comp:  1                Halpha      386.6      0.24      12    31
# Comp:  2             [SII]6716      22.38      0.26       5    47
# Comp:  2             [SII]6731      15.80      0.26       5    47
# Comp:  2              HeII4687     0.2742      0.26       5    47
# Comp:  2               HeI5876      16.99      0.26       5    47
# Comp:  2          [OIII]5007_d      1038.      0.33       5    47
# Comp:  2            [OI]6300_d      7.728      0.33       5    47
# Comp:  2           [NII]6583_d      17.22      0.33       5    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -125       604
#  comp.  1:         9        28
#  comp.  2:         6        42
# chi2/DOF: 11.96; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      138.5      0.24       9    28
# Comp:  1                Halpha      369.3      0.24       9    28
# Comp:  2             [SII]6716      24.77      0.25       6    42
# Comp:  2             [SII]6731      16.62      0.25       6    42
# Comp:  2              HeII4687     0.3482      0.25       6    42
# Comp:  2               HeI5876      13.94      0.25       6    42
# Comp:  2          [OIII]5007_d      1015.      0.32       6    42
# Comp:  2            [OI]6300_d      6.655      0.32       6    42
# Comp:  2           [NII]6583_d      16.83      0.32       6    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        28
#  comp.  1:         9        19
#  comp.  2:         5        46
# chi2/DOF: 12.16; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      139.9      0.24       9    19
# Comp:  1                Halpha      371.0      0.24       9    19
# Comp:  2             [SII]6716      21.63      0.26       5    46
# Comp:  2             [SII]6731      16.01      0.26       5    46
# Comp:  2              HeII4687     0.1548      0.26       5    46
# Comp:  2               HeI5876      15.90      0.26       5    46
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      135.7      0.24       8    29
# Comp:  1                Halpha      377.3      0.24       8    29
# Comp:  2             [SII]6716      20.90      0.25       4    42
# Comp:  2             [SII]6731      18.37      0.25       4    42
# Comp:  2              HeII4687     0.3339      0.25       4    42
# Comp:  2               HeI5876      16.84      0.25       4    42
# Comp:  2          [OIII]5007_d      1009.      0.32       4    42
# Comp:  2            [OI]6300_d      6.607      0.32       4    42
# Comp:  2           [NII]6583_d      15.72      0.32       4    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       101         1
#  comp.  1:         6        14
#  comp.  2:         4        46
# chi2/DOF: 8.843; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      141.4      0.24       6    14
# Comp:  1                Halpha      354.2      0.24       6    14
# Comp:  2             [SII]6716      21.86      0.26       4    46
# Comp:  2             [SII]6731      18.05      0.26       4    46
# Comp:  2              HeII4687     0.2338      0.26       4    46
# Comp:  2               HeI5876      17.13      0.26       4    46
# Comp:  2          [OIII]5007_d      1015.      0.33       4    46
# Comp:  2            [OI]6300_d      6.686      0.33       4    46
# Comp:  2           [NII]6583_d      15.84      0.33       4    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        27        99
#  comp.  1:         8        19
#  comp.  2:         5        44
# chi2/DOF: 12.91; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      135.9      0.24       8    19
# Comp:  1                Halpha      363.5      0.24       8    19
# Comp:  2             [SII]6716      22.85      0.26       5    44
# Comp:  2             [SII]6731      18.86      0.26       5    44
# Comp:  2              HeII4687     0.3468      0.26       5    44
# Comp:  2               HeI5876      16.99      0.26       5    44
# Comp:  2          [OIII]5007_d      1026.      0.32       5    44
# Comp:  2            [OI]6300_d      5.894      0.32       5    44
# Comp:  2           [NII]6583_d      17.77      0.32       5    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32         1
#  comp.  1:         7        14
#  comp.  2:         4        46
# chi2/DOF: 11.26; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      144.4      0.24       7    14
# Comp:  1                Halpha      357.6      0.24       7    14
# Comp:  2             [SII]6716      24.15      0.26       4    46
# Comp:  2             [SII]6731      16.69      0.26       4    46
# Comp:  2              HeII4687     0.2838      0.26       4    46
# Comp:  2               HeI5876      17.76      0.26       4    46
# Comp:  2          [OIII]5007_d      1035.      0.33       4    46
# Comp:  2            [OI]6300_d      6.666      0.33       4    46
# Comp:  2           [NII]6583_d      16.24      0.33       4    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       156         1
#  comp.  1:         8        12
#  comp.  2:         3        40
# chi2/DOF: 8.895; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      143.5      0.24       8    12
# Comp:  1                Halpha      367.1      0.24       8    12
# Comp:  2             [SII]6716      21.30      0.25       3    40
# Comp:  2             [SII]6731      18.19      0.25       3    40
# Comp:  2              HeII4687     0.2494      0.25       3    40
# Comp:  2               HeI5876      16.69      0.25       3    40
# Comp:  2          [OIII]5007_d      997.6      0.32       3    40
# Comp:  2            [OI]6300_d      6.720      0.32       3    40
# Comp:  2           [NII]6583_d      16.46      0.32       3    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       132         1
#  comp.  1:        12        29
#  comp.  2:         4        41
# chi2/DOF: 10.08; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 61; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      140.3      0.24      12    29
# Comp:  1                Halpha      377.1      0.24      12    29
# Comp:  2             [SII]6716      19.76      0.25       4    41
# Comp:  2             [SII]6731      16.27      0.25       4    41
# Comp:  2              HeII4687     0.2847      0.25       4    41
# Comp:  2               HeI5876      17.16      0.25       4    41
# Comp:  2          [OIII]5007_d      1019.      0.32       4    41
# Comp:  2            [OI]6300_d      7.345      0.32       4    41
# Comp:  2           [NII]6583_d      17.55      0.32       4    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        96         1
#  comp.  1:         8        27
#  comp.  2:         5        41
# chi2/DOF: 10.99; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      150.1      0.24       8    27
# Comp:  1                Halpha      375.9      0.24       8    27
# Comp:  2             [SII]6716      21.89      0.25       5    41
# Comp:  2             [SII]6731      15.25      0.25       5    41
# Comp:  2              HeII4687     0.2609      0.25       5    41
# Comp:  2               HeI5876      16.43      0.25       5    41
# Comp:  2          [OIII]5007_d      994.8      0.32       5    41
# Comp:  2            [OI]6300_d      6.611      0.32       5    41
# Comp:  2           [NII]6583_d      17.54      0.32       5    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       448      1000
#  comp.  1:        11        32
#  comp.  2:         6        47
# chi2/DOF: 8.186; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      145.0      0.25      11    32
# Comp:  1                Halpha      388.6      0.25      11    32
# Comp:  2             [SII]6716      21.41      0.26       6    47
# Comp:  2             [SII]6731      17.91      0.26       6    47
# Comp:  2              HeII4687     0.2790      0.26       6    47
# Comp:  2               HeI5876      17.66      0.26       6    47
# Comp:  2          [OIII]5007_d      1024.      0.33       6    47
# Comp:  2            [OI]6300_d      6.922      0.33       6    47
# Comp:  2           [NII]6583_d      17.97      0.33       6    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -139         1
#  comp.  1:        12        31
#  comp.  2:         5        48
# chi2/DOF: 8.760; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      151.5      0.24      12    31
# Comp:  1                Halpha      379.1      0.24      12    31
# Comp:  2             [SII]6716      23.67      0.26       5    48
# Comp:  2             [SII]6731      15.71      0.26       5    48
# Comp:  2              HeII4687     0.2598      0.26       5    48
# Comp:  2               HeI5876      13.94      0.26       5    48
# Comp:  2          [OIII]5007_d      1040.      0.33       5    48
# Comp:  2            [OI]6300_d      6.056      0.33       5    48
# Comp:  2           [NII]6583_d      17.47      0.33       5    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       183         1
#  comp.  1:        11        23
#  comp.  2:         4        43
# chi2/DOF: 10.94; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      147.1      0.24      11    23
# Comp:  1                Halpha      377.7      0.24      11    23
# Comp:  2             [SII]6716      24.26      0.25       4    43
# Comp:  2             [SII]6731      17.16      0.25       4    43
# Comp:  2              HeII4687     0.3552      0.25       4    43
# Comp:  2               HeI5876      14.50      0.25       4    43
# Comp:  2          [OIII]5007_d      1006.      0.32       4    43
# Comp:  2            [OI]6300_d      7.574      0.32       4    43
# Comp:  2           [NII]6583_d      16.94      0.32       4    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        50
#  comp.  1:        11        26
#  comp.  2:         3        42
# chi2/DOF: 9.867; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 36; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      134.5      0.24      11    26
# Comp:  1                Halpha      380.4      0.24      11    26
# Comp:  2             [SII]6716      21.89      0.25       3    42
# Comp:  2             [SII]6731      15.53      0.25       3    42
# Comp:  2              HeII4687     0.2804      0.25       3    42
# Comp:  2               HeI5876      16.06      0.25       3    42
# Comp:  2          [OIII]5007_d      1005.      0.32       3    42
# Comp:  2            [OI]6300_d      6.661      0.32       3    42
# Comp:  2           [NII]6583_d      16.50      0.32       3    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24         1
#  comp.  1:         9        18
#  comp.  2:         6        48
# chi2/DOF: 9.887; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 24; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      145.6      0.24       9    18
# Comp:  1                Halpha      370.1      0.24       9    18
# Comp:  2             [SII]6716      25.42      0.26       6    48
# Comp:  2             [SII]6731      17.49      0.26       6    48
# Comp:  2              HeII4687     0.3666      0.26       6    48
# Comp:  2               HeI5876      16.24      0.26       6    48
# Comp:  2          [OIII]5007_d      1044.      0.33       6    48
# Comp:  2            [OI]6300_d      7.553      0.33       6    48
# Comp:  2           [NII]6583_d      16.37      0.33       6    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       138         1
#  comp.  1:        11        32
#  comp.  2:         5        45
# chi2/DOF: 10.81; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 93; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      139.7      0.25      11    32
# Comp:  1                Halpha      382.4      0.25      11    32
# Comp:  2             [SII]6716      23.58      0.26       5    45
# Comp:  2             [SII]6731      15.59      0.26       5    45
# Comp:  2              HeII4687     0.2012      0.26       5    45
# Comp:  2               HeI5876      16.01      0.26       5    45
# Comp:  2          [OIII]5007_d      1024.      0.32       5    45
# Comp:  2            [OI]6300_d      6.068      0.32       5    45
# Comp:  2           [NII]6583_d      16.65      0.32       5    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       274      1000
#  comp.  1:         9        11
#  comp.  2:         4        44
# chi2/DOF: 11.78; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      132.8      0.23       9    11
# Comp:  1                Halpha      363.9      0.23       9    11
# Comp:  2             [SII]6716      21.78      0.26       4    44
# Comp:  2             [SII]6731      17.52      0.26       4    44
# Comp:  2              HeII4687     0.2607      0.26       4    44
# Comp:  2               HeI5876      16.31      0.26       4    44
# Comp:  2          [OIII]5007_d      1023.      0.32       4    44
# Comp:  2            [OI]6300_d      6.169      0.32       4    44
# Comp:  2           [NII]6583_d      16.83      0.32       4    44
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([ 6.23638595, 13.57582554,  2.03812385,  1.46248092,  0.0751939 ,
#         1.49556935, 12.33802701,  0.7715745 ,  0.90144452])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_1_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_1_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_1_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_1_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_1_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
