# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_5.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_1263/FORS2.2022-01-06T07_26_01.965/Spectra_extraction/redshift.txt") 
z = red[4][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_5']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4433.12520539 4434.59903006 4436.07285474 ... 7063.90224957 7065.37607425
#  7066.84989892] [0.69072006 0.67204621 0.73216258 ... 0.23795453 0.27251054 0.19705633] [0.03916341 0.03916341 0.03916341 ... 0.03916341 0.03916341 0.03916341]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.2165626  2.21729952 2.21803643 ... 3.53195112 3.53268804 3.53342495]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3137, 150)

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3137, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3137, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
# C:\Users\ISAFA\anaconda3\Lib\site-packages\capfit\capfit.py:799: RuntimeWarning: invalid value encountered in scalar divide
#   ratio = actred/prered
#  Best Fit:       Vel     sigma
#  comp.  0:        20       180
# chi2/DOF: 0.006387; DOF: 1944; degree = 4; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 5; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 0/150
#  Best Fit:       Vel     sigma
#  comp.  0:        20       180
# chi2/DOF: 0.002067; DOF: 1872; degree = 4; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 5; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 0/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([ 20., 180.])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -182         1
#  comp.  1:        11        34
#  comp.  2:        11        47
# chi2/DOF: 30.36; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      111.1      0.28      11    34
# Comp:  1                Halpha      211.1      0.28      11    34
# Comp:  2             [SII]6716      12.18      0.30      11    47
# Comp:  2             [SII]6731      8.588      0.30      11    47
# Comp:  2              HeII4687     0.6845      0.30      11    47
# Comp:  2               HeI5876      9.239      0.30      11    47
# Comp:  2          [OIII]5007_d      720.7      0.37      11    47
# Comp:  2            [OI]6300_d      3.169      0.37      11    47
# Comp:  2           [NII]6583_d      7.673      0.37      11    47
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  635.1; gas flux:    113 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:   1222; gas flux:    289 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  66.25; gas flux:     17 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  45.82; gas flux:     12 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  3.824; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  51.79; gas flux:     11 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   3044; gas flux:    753 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  12.97; gas flux:      4 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  30.56; gas flux:     11 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -153         1
#  comp.  1:         9        32
#  comp.  2:        18        58
# chi2/DOF: 17.07; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      114.3      0.28       9    32
# Comp:  1                Halpha      212.7      0.28       9    32
# Comp:  2             [SII]6716      12.94      0.31      18    58
# Comp:  2             [SII]6731      8.969      0.31      18    58
# Comp:  2              HeII4687     0.6827      0.31      18    58
# Comp:  2               HeI5876      8.501      0.31      18    58
# Comp:  2          [OIII]5007_d      772.3      0.39      18    58
# Comp:  2            [OI]6300_d      3.390      0.39      18    58
# Comp:  2           [NII]6583_d      7.859      0.39      18    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -236         1
#  comp.  1:        13        42
#  comp.  2:        15        44
# chi2/DOF: 24.91; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      126.9      0.29      13    42
# Comp:  1                Halpha      213.1      0.29      13    42
# Comp:  2             [SII]6716      11.82      0.29      15    44
# Comp:  2             [SII]6731      8.419      0.29      15    44
# Comp:  2              HeII4687     0.6292      0.29      15    44
# Comp:  2               HeI5876      9.583      0.29      15    44
# Comp:  2          [OIII]5007_d      687.2      0.37      15    44
# Comp:  2            [OI]6300_d      2.690      0.37      15    44
# Comp:  2           [NII]6583_d      7.849      0.37      15    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -215         1
#  comp.  1:        13        39
#  comp.  2:        22        57
# chi2/DOF: 11.93; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      106.6      0.29      13    39
# Comp:  1                Halpha      208.1      0.29      13    39
# Comp:  2             [SII]6716      12.17      0.31      22    57
# Comp:  2             [SII]6731      8.693      0.31      22    57
# Comp:  2              HeII4687     0.6614      0.31      22    57
# Comp:  2               HeI5876      9.342      0.31      22    57
# Comp:  2          [OIII]5007_d      749.8      0.39      22    57
# Comp:  2            [OI]6300_d      2.536      0.39      22    57
# Comp:  2           [NII]6583_d      7.637      0.39      22    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       132         1
#  comp.  1:        10        33
#  comp.  2:         1        41
# chi2/DOF: 6.764; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 68; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      121.6      0.28      10    33
# Comp:  1                Halpha      216.7      0.28      10    33
# Comp:  2             [SII]6716      11.32      0.29       1    41
# Comp:  2             [SII]6731      8.149      0.29       1    41
# Comp:  2              HeII4687     0.5390      0.29       1    41
# Comp:  2               HeI5876      8.249      0.29       1    41
# Comp:  2          [OIII]5007_d      654.9      0.37       1    41
# Comp:  2            [OI]6300_d      3.431      0.37       1    41
# Comp:  2           [NII]6583_d      7.699      0.37       1    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -248         1
#  comp.  1:        12        32
#  comp.  2:        14        44
# chi2/DOF: 26.72; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      102.3      0.28      12    32
# Comp:  1                Halpha      210.8      0.28      12    32
# Comp:  2             [SII]6716      11.69      0.29      14    44
# Comp:  2             [SII]6731      8.656      0.29      14    44
# Comp:  2              HeII4687     0.4638      0.29      14    44
# Comp:  2               HeI5876      9.075      0.29      14    44
# Comp:  2          [OIII]5007_d      689.5      0.37      14    44
# Comp:  2            [OI]6300_d      2.476      0.37      14    44
# Comp:  2           [NII]6583_d      7.186      0.37      14    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       146         1
#  comp.  1:         8        35
#  comp.  2:        13        56
# chi2/DOF: 14.49; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 69; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      122.5      0.29       8    35
# Comp:  1                Halpha      216.6      0.29       8    35
# Comp:  2             [SII]6716      12.26      0.31      13    56
# Comp:  2             [SII]6731      8.308      0.31      13    56
# Comp:  2              HeII4687     0.5007      0.31      13    56
# Comp:  2               HeI5876      10.34      0.31      13    56
# Comp:  2          [OIII]5007_d      684.4      0.39      13    56
# Comp:  2            [OI]6300_d      2.817      0.39      13    56
# Comp:  2           [NII]6583_d      8.446      0.39      13    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -126         1
#  comp.  1:        12        34
#  comp.  2:         8        56
# chi2/DOF: 21.24; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      119.6      0.28      12    34
# Comp:  1                Halpha      206.6      0.28      12    34
# Comp:  2             [SII]6716      12.59      0.31       8    56
# Comp:  2             [SII]6731      8.689      0.31       8    56
# Comp:  2              HeII4687     0.8412      0.31       8    56
# Comp:  2               HeI5876      9.173      0.31       8    56
# Comp:  2          [OIII]5007_d      713.2      0.39       8    56
# Comp:  2            [OI]6300_d      3.995      0.39       8    56
# Comp:  2           [NII]6583_d      8.008      0.39       8    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -119       699
#  comp.  1:         9        31
#  comp.  2:         5        44
# chi2/DOF: 8.555; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      115.8      0.28       9    31
# Comp:  1                Halpha      213.2      0.28       9    31
# Comp:  2             [SII]6716      12.16      0.29       5    44
# Comp:  2             [SII]6731      8.311      0.29       5    44
# Comp:  2              HeII4687     0.6372      0.29       5    44
# Comp:  2               HeI5876      9.363      0.29       5    44
# Comp:  2          [OIII]5007_d      643.6      0.37       5    44
# Comp:  2            [OI]6300_d      3.171      0.37       5    44
# Comp:  2           [NII]6583_d      7.528      0.37       5    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -115        47
#  comp.  1:        12        27
#  comp.  2:        13        46
# chi2/DOF: 29.09; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 36; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      118.1      0.28      12    27
# Comp:  1                Halpha      200.9      0.28      12    27
# Comp:  2             [SII]6716      11.99      0.30      13    46
# Comp:  2             [SII]6731      8.139      0.30      13    46
# Comp:  2              HeII4687     0.6250      0.30      13    46
# Comp:  2               HeI5876      9.636      0.30      13    46
# Comp:  2          [OIII]5007_d      712.2      0.37      13    46
# Comp:  2            [OI]6300_d      2.904      0.37      13    46
# Comp:  2           [NII]6583_d      7.644      0.37      13    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       149         1
#  comp.  1:        10        37
#  comp.  2:        11        36
# chi2/DOF: 14.14; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      105.6      0.29      10    37
# Comp:  1                Halpha      208.6      0.29      10    37
# Comp:  2             [SII]6716      11.68      0.29      11    36
# Comp:  2             [SII]6731      8.122      0.29      11    36
# Comp:  2              HeII4687     0.6402      0.29      11    36
# Comp:  2               HeI5876      8.881      0.29      11    36
# Comp:  2          [OIII]5007_d      749.5      0.36      11    36
# Comp:  2            [OI]6300_d      3.652      0.36      11    36
# Comp:  2           [NII]6583_d      7.668      0.36      11    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       109       660
#  comp.  1:         8        31
#  comp.  2:         5        43
# chi2/DOF: 9.019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      114.2      0.28       8    31
# Comp:  1                Halpha      206.3      0.28       8    31
# Comp:  2             [SII]6716      13.13      0.29       5    43
# Comp:  2             [SII]6731      8.256      0.29       5    43
# Comp:  2              HeII4687     0.7113      0.29       5    43
# Comp:  2               HeI5876      9.346      0.29       5    43
# Comp:  2          [OIII]5007_d      641.8      0.37       5    43
# Comp:  2            [OI]6300_d      3.202      0.37       5    43
# Comp:  2           [NII]6583_d      8.197      0.37       5    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -257         1
#  comp.  1:        12        35
#  comp.  2:        15        37
# chi2/DOF: 19.96; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      107.0      0.28      12    35
# Comp:  1                Halpha      204.7      0.28      12    35
# Comp:  2             [SII]6716      12.71      0.29      15    37
# Comp:  2             [SII]6731      8.440      0.29      15    37
# Comp:  2              HeII4687     0.6619      0.29      15    37
# Comp:  2               HeI5876      9.035      0.29      15    37
# Comp:  2          [OIII]5007_d      734.0      0.36      15    37
# Comp:  2            [OI]6300_d      3.069      0.36      15    37
# Comp:  2           [NII]6583_d      7.622      0.36      15    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -210       586
#  comp.  1:        13        26
#  comp.  2:        10        48
# chi2/DOF: 29.20; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      101.8      0.28      13    26
# Comp:  1                Halpha      207.5      0.28      13    26
# Comp:  2             [SII]6716      12.37      0.30      10    48
# Comp:  2             [SII]6731      8.966      0.30      10    48
# Comp:  2              HeII4687     0.9376      0.30      10    48
# Comp:  2               HeI5876      9.208      0.30      10    48
# Comp:  2          [OIII]5007_d      732.3      0.38      10    48
# Comp:  2            [OI]6300_d      3.789      0.38      10    48
# Comp:  2           [NII]6583_d      7.489      0.38      10    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -178       434
#  comp.  1:        13        30
#  comp.  2:         8        58
# chi2/DOF: 21.15; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      114.6      0.28      13    30
# Comp:  1                Halpha      213.0      0.28      13    30
# Comp:  2             [SII]6716      12.94      0.31       8    58
# Comp:  2             [SII]6731      9.380      0.31       8    58
# Comp:  2              HeII4687     0.8481      0.31       8    58
# Comp:  2               HeI5876      9.843      0.31       8    58
# Comp:  2          [OIII]5007_d      722.3      0.39       8    58
# Comp:  2            [OI]6300_d      3.149      0.39       8    58
# Comp:  2           [NII]6583_d      8.206      0.39       8    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -122         1
#  comp.  1:        13        30
#  comp.  2:        20        49
# chi2/DOF: 8.612; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      115.4      0.28      13    30
# Comp:  1                Halpha      213.1      0.28      13    30
# Comp:  2             [SII]6716      12.70      0.30      20    49
# Comp:  2             [SII]6731      8.491      0.30      20    49
# Comp:  2              HeII4687     0.4314      0.30      20    49
# Comp:  2               HeI5876      9.769      0.30      20    49
# Comp:  2          [OIII]5007_d      784.5      0.38      20    49
# Comp:  2            [OI]6300_d      3.381      0.38      20    49
# Comp:  2           [NII]6583_d      8.045      0.38      20    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       163         1
#  comp.  1:        11        31
#  comp.  2:        21        47
# chi2/DOF: 8.959; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 14; Func calls: 100; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      99.70      0.28      11    31
# Comp:  1                Halpha      212.2      0.28      11    31
# Comp:  2             [SII]6716      12.05      0.30      21    47
# Comp:  2             [SII]6731      8.868      0.30      21    47
# Comp:  2              HeII4687     0.8095      0.30      21    47
# Comp:  2               HeI5876      9.048      0.30      21    47
# Comp:  2          [OIII]5007_d      766.6      0.37      21    47
# Comp:  2            [OI]6300_d      3.420      0.37      21    47
# Comp:  2           [NII]6583_d      7.697      0.37      21    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -188         1
#  comp.  1:        13        38
#  comp.  2:        12        46
# chi2/DOF: 28.71; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      125.4      0.29      13    38
# Comp:  1                Halpha      219.6      0.29      13    38
# Comp:  2             [SII]6716      12.16      0.30      12    46
# Comp:  2             [SII]6731      8.210      0.30      12    46
# Comp:  2              HeII4687     0.7265      0.30      12    46
# Comp:  2               HeI5876      9.830      0.30      12    46
# Comp:  2          [OIII]5007_d      709.6      0.37      12    46
# Comp:  2            [OI]6300_d      3.257      0.37      12    46
# Comp:  2           [NII]6583_d      7.625      0.37      12    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        85       132
#  comp.  1:        10        29
#  comp.  2:        20        48
# chi2/DOF: 11.04; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 69; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      115.8      0.28      10    29
# Comp:  1                Halpha      203.6      0.28      10    29
# Comp:  2             [SII]6716      10.79      0.30      20    48
# Comp:  2             [SII]6731      8.801      0.30      20    48
# Comp:  2              HeII4687     0.5468      0.30      20    48
# Comp:  2               HeI5876      9.140      0.30      20    48
# Comp:  2          [OIII]5007_d      776.5      0.38      20    48
# Comp:  2            [OI]6300_d      2.979      0.38      20    48
# Comp:  2           [NII]6583_d      7.787      0.38      20    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        67       700
#  comp.  1:        10        27
#  comp.  2:         1        42
# chi2/DOF: 10.97; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      119.6      0.28      10    27
# Comp:  1                Halpha      205.7      0.28      10    27
# Comp:  2             [SII]6716      13.10      0.29       1    42
# Comp:  2             [SII]6731      8.404      0.29       1    42
# Comp:  2              HeII4687     0.7603      0.29       1    42
# Comp:  2               HeI5876      8.593      0.29       1    42
# Comp:  2          [OIII]5007_d      665.5      0.37       1    42
# Comp:  2            [OI]6300_d      2.873      0.37       1    42
# Comp:  2           [NII]6583_d      7.727      0.37       1    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       135         1
#  comp.  1:        13        25
#  comp.  2:         7        56
# chi2/DOF: 19.79; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      103.4      0.28      13    25
# Comp:  1                Halpha      202.7      0.28      13    25
# Comp:  2             [SII]6716      11.49      0.31       7    56
# Comp:  2             [SII]6731      8.767      0.31       7    56
# Comp:  2              HeII4687     0.7844      0.31       7    56
# Comp:  2               HeI5876      9.559      0.31       7    56
# Comp:  2          [OIII]5007_d      717.4      0.39       7    56
# Comp:  2            [OI]6300_d      3.358      0.39       7    56
# Comp:  2           [NII]6583_d      8.286      0.39       7    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -203         1
#  comp.  1:         8        21
#  comp.  2:         5        41
# chi2/DOF: 3.407; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      114.1      0.27       8    21
# Comp:  1                Halpha      202.3      0.27       8    21
# Comp:  2             [SII]6716      12.95      0.29       5    41
# Comp:  2             [SII]6731      8.145      0.29       5    41
# Comp:  2              HeII4687     0.4915      0.29       5    41
# Comp:  2               HeI5876      9.084      0.29       5    41
# Comp:  2          [OIII]5007_d      627.5      0.37       5    41
# Comp:  2            [OI]6300_d      2.801      0.37       5    41
# Comp:  2           [NII]6583_d      7.281      0.37       5    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -275         1
#  comp.  1:        12        32
#  comp.  2:        16        33
# chi2/DOF: 18.07; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      119.8      0.28      12    32
# Comp:  1                Halpha      211.9      0.28      12    32
# Comp:  2             [SII]6716      11.78      0.28      16    33
# Comp:  2             [SII]6731      8.127      0.28      16    33
# Comp:  2              HeII4687     0.6354      0.28      16    33
# Comp:  2               HeI5876      8.399      0.28      16    33
# Comp:  2          [OIII]5007_d      715.9      0.36      16    33
# Comp:  2            [OI]6300_d      2.963      0.36      16    33
# Comp:  2           [NII]6583_d      7.146      0.36      16    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -201         1
#  comp.  1:        13        35
#  comp.  2:         5        43
# chi2/DOF: 9.544; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      107.3      0.28      13    35
# Comp:  1                Halpha      212.7      0.28      13    35
# Comp:  2             [SII]6716      12.62      0.29       5    43
# Comp:  2             [SII]6731      8.375      0.29       5    43
# Comp:  2              HeII4687     0.7216      0.29       5    43
# Comp:  2               HeI5876      9.294      0.29       5    43
# Comp:  2          [OIII]5007_d      641.0      0.37       5    43
# Comp:  2            [OI]6300_d      2.839      0.37       5    43
# Comp:  2           [NII]6583_d      7.969      0.37       5    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -160         1
#  comp.  1:        14        37
#  comp.  2:         8        57
# chi2/DOF: 19.29; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      124.8      0.29      14    37
# Comp:  1                Halpha      217.1      0.29      14    37
# Comp:  2             [SII]6716      12.75      0.31       8    57
# Comp:  2             [SII]6731      8.655      0.31       8    57
# Comp:  2              HeII4687     0.6170      0.31       8    57
# Comp:  2               HeI5876      9.622      0.31       8    57
# Comp:  2          [OIII]5007_d      711.4      0.39       8    57
# Comp:  2            [OI]6300_d      3.274      0.39       8    57
# Comp:  2           [NII]6583_d      8.022      0.39       8    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -214        27
#  comp.  1:        12        38
#  comp.  2:        15        45
# chi2/DOF: 26.79; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      117.3      0.29      12    38
# Comp:  1                Halpha      209.7      0.29      12    38
# Comp:  2             [SII]6716      11.48      0.29      15    45
# Comp:  2             [SII]6731      8.193      0.29      15    45
# Comp:  2              HeII4687     0.5291      0.29      15    45
# Comp:  2               HeI5876      9.254      0.29      15    45
# Comp:  2          [OIII]5007_d      697.1      0.37      15    45
# Comp:  2            [OI]6300_d      3.146      0.37      15    45
# Comp:  2           [NII]6583_d      7.638      0.37      15    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -206         1
#  comp.  1:        10        39
#  comp.  2:         3        30
# chi2/DOF: 10.76; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      104.7      0.29      10    39
# Comp:  1                Halpha      212.9      0.29      10    39
# Comp:  2             [SII]6716      12.37      0.28       3    30
# Comp:  2             [SII]6731      8.011      0.28       3    30
# Comp:  2              HeII4687     0.4886      0.28       3    30
# Comp:  2               HeI5876      8.615      0.28       3    30
# Comp:  2          [OIII]5007_d      684.5      0.35       3    30
# Comp:  2            [OI]6300_d      3.377      0.35       3    30
# Comp:  2           [NII]6583_d      7.633      0.35       3    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -152         1
#  comp.  1:        12        36
#  comp.  2:        12        57
# chi2/DOF: 16.46; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      110.7      0.29      12    36
# Comp:  1                Halpha      215.7      0.29      12    36
# Comp:  2             [SII]6716      13.67      0.31      12    57
# Comp:  2             [SII]6731      9.347      0.31      12    57
# Comp:  2              HeII4687     0.9114      0.31      12    57
# Comp:  2               HeI5876      9.906      0.31      12    57
# Comp:  2          [OIII]5007_d      690.3      0.39      12    57
# Comp:  2            [OI]6300_d      3.799      0.39      12    57
# Comp:  2           [NII]6583_d      7.852      0.39      12    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -444       325
#  comp.  1:        14        43
#  comp.  2:         9        57
# chi2/DOF: 20.30; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      108.6      0.29      14    43
# Comp:  1                Halpha      216.1      0.29      14    43
# Comp:  2             [SII]6716      12.63      0.31       9    57
# Comp:  2             [SII]6731      8.566      0.31       9    57
# Comp:  2              HeII4687     0.5770      0.31       9    57
# Comp:  2               HeI5876      9.727      0.31       9    57
# Comp:  2          [OIII]5007_d      714.9      0.39       9    57
# Comp:  2            [OI]6300_d      3.420      0.39       9    57
# Comp:  2           [NII]6583_d      8.435      0.39       9    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -185         1
#  comp.  1:        13        29
#  comp.  2:         2        30
# chi2/DOF: 6.441; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      98.75      0.28      13    29
# Comp:  1                Halpha      209.2      0.28      13    29
# Comp:  2             [SII]6716      10.66      0.28       2    30
# Comp:  2             [SII]6731      8.131      0.28       2    30
# Comp:  2              HeII4687     0.5375      0.28       2    30
# Comp:  2               HeI5876      9.311      0.28       2    30
# Comp:  2          [OIII]5007_d      694.2      0.35       2    30
# Comp:  2            [OI]6300_d      2.582      0.35       2    30
# Comp:  2           [NII]6583_d      7.359      0.35       2    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -199        63
#  comp.  1:        13        43
#  comp.  2:        12        47
# chi2/DOF: 28.96; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      103.7      0.29      13    43
# Comp:  1                Halpha      218.7      0.29      13    43
# Comp:  2             [SII]6716      11.48      0.30      12    47
# Comp:  2             [SII]6731      8.644      0.30      12    47
# Comp:  2              HeII4687     0.7721      0.30      12    47
# Comp:  2               HeI5876      9.109      0.30      12    47
# Comp:  2          [OIII]5007_d      712.3      0.37      12    47
# Comp:  2            [OI]6300_d      2.735      0.37      12    47
# Comp:  2           [NII]6583_d      7.788      0.37      12    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        77         1
#  comp.  1:        10        28
#  comp.  2:         8        57
# chi2/DOF: 20.24; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      101.8      0.28      10    28
# Comp:  1                Halpha      206.5      0.28      10    28
# Comp:  2             [SII]6716      12.47      0.31       8    57
# Comp:  2             [SII]6731      8.910      0.31       8    57
# Comp:  2              HeII4687     0.8088      0.31       8    57
# Comp:  2               HeI5876      8.950      0.31       8    57
# Comp:  2          [OIII]5007_d      718.6      0.39       8    57
# Comp:  2            [OI]6300_d      2.624      0.39       8    57
# Comp:  2           [NII]6583_d      7.915      0.39       8    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -151         1
#  comp.  1:        11        34
#  comp.  2:        12        59
# chi2/DOF: 13.20; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      116.8      0.28      11    34
# Comp:  1                Halpha      208.1      0.28      11    34
# Comp:  2             [SII]6716      11.87      0.31      12    59
# Comp:  2             [SII]6731      8.788      0.31      12    59
# Comp:  2              HeII4687     0.5380      0.31      12    59
# Comp:  2               HeI5876      10.36      0.31      12    59
# Comp:  2          [OIII]5007_d      693.3      0.39      12    59
# Comp:  2            [OI]6300_d      2.786      0.39      12    59
# Comp:  2           [NII]6583_d      7.865      0.39      12    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -247         1
#  comp.  1:        14        41
#  comp.  2:         2        31
# chi2/DOF: 8.788; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      109.7      0.29      14    41
# Comp:  1                Halpha      220.4      0.29      14    41
# Comp:  2             [SII]6716      11.38      0.28       2    31
# Comp:  2             [SII]6731      8.080      0.28       2    31
# Comp:  2              HeII4687     0.6581      0.28       2    31
# Comp:  2               HeI5876      9.126      0.28       2    31
# Comp:  2          [OIII]5007_d      688.4      0.36       2    31
# Comp:  2            [OI]6300_d      2.851      0.36       2    31
# Comp:  2           [NII]6583_d      7.516      0.36       2    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -134         1
#  comp.  1:        12        34
#  comp.  2:         8        48
# chi2/DOF: 25.66; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      107.4      0.28      12    34
# Comp:  1                Halpha      214.0      0.28      12    34
# Comp:  2             [SII]6716      12.18      0.30       8    48
# Comp:  2             [SII]6731      8.859      0.30       8    48
# Comp:  2              HeII4687     0.8744      0.30       8    48
# Comp:  2               HeI5876      8.499      0.30       8    48
# Comp:  2          [OIII]5007_d      752.9      0.38       8    48
# Comp:  2            [OI]6300_d      2.916      0.38       8    48
# Comp:  2           [NII]6583_d      7.790      0.38       8    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -160         1
#  comp.  1:        11        33
#  comp.  2:        16        50
# chi2/DOF: 7.158; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      119.1      0.28      11    33
# Comp:  1                Halpha      211.1      0.28      11    33
# Comp:  2             [SII]6716      12.40      0.30      16    50
# Comp:  2             [SII]6731      8.486      0.30      16    50
# Comp:  2              HeII4687     0.7590      0.30      16    50
# Comp:  2               HeI5876      9.134      0.30      16    50
# Comp:  2          [OIII]5007_d      809.0      0.38      16    50
# Comp:  2            [OI]6300_d      3.003      0.38      16    50
# Comp:  2           [NII]6583_d      7.657      0.38      16    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6         1
#  comp.  1:         8        31
#  comp.  2:         1        43
# chi2/DOF: 8.357; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      121.8      0.28       8    31
# Comp:  1                Halpha      211.5      0.28       8    31
# Comp:  2             [SII]6716      11.13      0.29       1    43
# Comp:  2             [SII]6731      8.651      0.29       1    43
# Comp:  2              HeII4687     0.6821      0.29       1    43
# Comp:  2               HeI5876      9.867      0.29       1    43
# Comp:  2          [OIII]5007_d      665.6      0.37       1    43
# Comp:  2            [OI]6300_d      3.527      0.37       1    43
# Comp:  2           [NII]6583_d      7.785      0.37       1    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31      1000
#  comp.  1:         9        36
#  comp.  2:         9        47
# chi2/DOF: 26.74; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      119.9      0.29       9    36
# Comp:  1                Halpha      205.9      0.29       9    36
# Comp:  2             [SII]6716      12.08      0.30       9    47
# Comp:  2             [SII]6731      8.248      0.30       9    47
# Comp:  2              HeII4687     0.7048      0.30       9    47
# Comp:  2               HeI5876      9.481      0.30       9    47
# Comp:  2          [OIII]5007_d      744.7      0.37       9    47
# Comp:  2            [OI]6300_d      2.964      0.37       9    47
# Comp:  2           [NII]6583_d      7.672      0.37       9    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       181         1
#  comp.  1:        14        30
#  comp.  2:        11        36
# chi2/DOF: 13.59; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 74; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      102.8      0.28      14    30
# Comp:  1                Halpha      205.4      0.28      14    30
# Comp:  2             [SII]6716      11.65      0.29      11    36
# Comp:  2             [SII]6731      8.570      0.29      11    36
# Comp:  2              HeII4687     0.6822      0.29      11    36
# Comp:  2               HeI5876      8.761      0.29      11    36
# Comp:  2          [OIII]5007_d      751.2      0.36      11    36
# Comp:  2            [OI]6300_d      2.710      0.36      11    36
# Comp:  2           [NII]6583_d      7.712      0.36      11    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       142         1
#  comp.  1:        11        36
#  comp.  2:        15        47
# chi2/DOF: 27.04; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      125.3      0.29      11    36
# Comp:  1                Halpha      215.1      0.29      11    36
# Comp:  2             [SII]6716      13.30      0.30      15    47
# Comp:  2             [SII]6731      8.367      0.30      15    47
# Comp:  2              HeII4687     0.7025      0.30      15    47
# Comp:  2               HeI5876      10.10      0.30      15    47
# Comp:  2          [OIII]5007_d      703.4      0.38      15    47
# Comp:  2            [OI]6300_d      3.811      0.38      15    47
# Comp:  2           [NII]6583_d      8.151      0.38      15    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       141         1
#  comp.  1:         8        33
#  comp.  2:        17        50
# chi2/DOF: 7.911; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      117.6      0.28       8    33
# Comp:  1                Halpha      205.7      0.28       8    33
# Comp:  2             [SII]6716      11.69      0.30      17    50
# Comp:  2             [SII]6731      8.651      0.30      17    50
# Comp:  2              HeII4687     0.9141      0.30      17    50
# Comp:  2               HeI5876      10.56      0.30      17    50
# Comp:  2          [OIII]5007_d      802.4      0.38      17    50
# Comp:  2            [OI]6300_d      3.042      0.38      17    50
# Comp:  2           [NII]6583_d      7.860      0.38      17    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       145         1
#  comp.  1:        10        33
#  comp.  2:        11        36
# chi2/DOF: 14.18; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      118.4      0.28      10    33
# Comp:  1                Halpha      210.7      0.28      10    33
# Comp:  2             [SII]6716      10.91      0.29      11    36
# Comp:  2             [SII]6731      7.965      0.29      11    36
# Comp:  2              HeII4687     0.7457      0.29      11    36
# Comp:  2               HeI5876      9.358      0.29      11    36
# Comp:  2          [OIII]5007_d      747.1      0.36      11    36
# Comp:  2            [OI]6300_d      2.866      0.36      11    36
# Comp:  2           [NII]6583_d      7.690      0.36      11    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -238         1
#  comp.  1:        16        37
#  comp.  2:        15        37
# chi2/DOF: 20.90; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      109.8      0.29      16    37
# Comp:  1                Halpha      218.9      0.29      16    37
# Comp:  2             [SII]6716      11.03      0.29      15    37
# Comp:  2             [SII]6731      8.102      0.29      15    37
# Comp:  2              HeII4687     0.6190      0.29      15    37
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      112.8      0.28      10    26
# Comp:  1                Halpha      201.0      0.28      10    26
# Comp:  2             [SII]6716      12.26      0.30      12    48
# Comp:  2             [SII]6731      8.381      0.30      12    48
# Comp:  2              HeII4687     0.4869      0.30      12    48
# Comp:  2               HeI5876      8.546      0.30      12    48
# Comp:  2          [OIII]5007_d      717.3      0.38      12    48
# Comp:  2            [OI]6300_d      3.726      0.38      12    48
# Comp:  2           [NII]6583_d      8.165      0.38      12    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       143         1
#  comp.  1:        12        34
#  comp.  2:        16        35
# chi2/DOF: 18.28; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      120.3      0.28      12    34
# Comp:  1                Halpha      210.0      0.28      12    34
# Comp:  2             [SII]6716      10.86      0.28      16    35
# Comp:  2             [SII]6731      8.109      0.28      16    35
# Comp:  2              HeII4687     0.6032      0.28      16    35
# Comp:  2               HeI5876      8.857      0.28      16    35
# Comp:  2          [OIII]5007_d      724.9      0.36      16    35
# Comp:  2            [OI]6300_d      2.701      0.36      16    35
# Comp:  2           [NII]6583_d      7.913      0.36      16    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -144       908
#  comp.  1:         8        30
#  comp.  2:        13        56
# chi2/DOF: 17.21; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      117.7      0.28       8    30
# Comp:  1                Halpha      208.2      0.28       8    30
# Comp:  2             [SII]6716      13.18      0.31      13    56
# Comp:  2             [SII]6731      8.943      0.31      13    56
# Comp:  2              HeII4687     0.6615      0.31      13    56
# Comp:  2               HeI5876      9.890      0.31      13    56
# Comp:  2          [OIII]5007_d      690.6      0.39      13    56
# Comp:  2            [OI]6300_d      3.628      0.39      13    56
# Comp:  2           [NII]6583_d      7.834      0.39      13    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -192         1
#  comp.  1:         9        34
#  comp.  2:        11        47
# chi2/DOF: 29.82; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      115.8      0.28       9    34
# Comp:  1                Halpha      205.3      0.28       9    34
# Comp:  2             [SII]6716      12.18      0.30      11    47
# Comp:  2             [SII]6731      8.658      0.30      11    47
# Comp:  2              HeII4687     0.7004      0.30      11    47
# Comp:  2               HeI5876      9.043      0.30      11    47
# Comp:  2          [OIII]5007_d      720.1      0.38      11    47
# Comp:  2            [OI]6300_d      3.306      0.38      11    47
# Comp:  2           [NII]6583_d      7.809      0.38      11    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -116         1
#  comp.  1:        10        27
#  comp.  2:        -1        43
# chi2/DOF: 6.659; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      115.1      0.28      10    27
# Comp:  1                Halpha      211.0      0.28      10    27
# Comp:  2             [SII]6716      12.51      0.29      -1    43
# Comp:  2             [SII]6731      8.276      0.29      -1    43
# Comp:  2              HeII4687     0.6184      0.29      -1    43
# Comp:  2               HeI5876      8.937      0.29      -1    43
# Comp:  2          [OIII]5007_d      668.0      0.37      -1    43
# Comp:  2            [OI]6300_d      2.989      0.37      -1    43
# Comp:  2           [NII]6583_d      7.830      0.37      -1    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -142         1
#  comp.  1:        10        30
#  comp.  2:        17        59
# chi2/DOF: 14.98; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      120.8      0.28      10    30
# Comp:  1                Halpha      206.3      0.28      10    30
# Comp:  2             [SII]6716      12.67      0.31      17    59
# Comp:  2             [SII]6731      9.061      0.31      17    59
# Comp:  2              HeII4687     0.5852      0.31      17    59
# Comp:  2               HeI5876      9.328      0.31      17    59
# Comp:  2          [OIII]5007_d      785.6      0.39      17    59
# Comp:  2            [OI]6300_d      4.047      0.39      17    59
# Comp:  2           [NII]6583_d      8.395      0.39      17    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       119        46
#  comp.  1:        12        31
#  comp.  2:        11        48
# chi2/DOF: 29.90; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      107.6      0.28      12    31
# Comp:  1                Halpha      204.8      0.28      12    31
# Comp:  2             [SII]6716      11.24      0.30      11    48
# Comp:  2             [SII]6731      8.568      0.30      11    48
# Comp:  2              HeII4687     0.6410      0.30      11    48
# Comp:  2               HeI5876      9.758      0.30      11    48
# Comp:  2          [OIII]5007_d      722.5      0.38      11    48
# Comp:  2            [OI]6300_d      3.940      0.38      11    48
# Comp:  2           [NII]6583_d      7.609      0.38      11    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48        90
#  comp.  1:         9        36
#  comp.  2:        11        36
# chi2/DOF: 14.93; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 57; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      119.4      0.29       9    36
# Comp:  1                Halpha      209.6      0.29       9    36
# Comp:  2             [SII]6716      12.03      0.29      11    36
# Comp:  2             [SII]6731      8.241      0.29      11    36
# Comp:  2              HeII4687     0.6672      0.29      11    36
# Comp:  2               HeI5876      9.134      0.29      11    36
# Comp:  2          [OIII]5007_d      750.1      0.36      11    36
# Comp:  2            [OI]6300_d      2.874      0.36      11    36
# Comp:  2           [NII]6583_d      7.990      0.36      11    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       187         1
#  comp.  1:        13        33
#  comp.  2:        14        48
# chi2/DOF: 27.76; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 67; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      117.2      0.28      13    33
# Comp:  1                Halpha      211.7      0.28      13    33
# Comp:  2             [SII]6716      12.10      0.30      14    48
# Comp:  2             [SII]6731      8.366      0.30      14    48
# Comp:  2              HeII4687     0.8420      0.30      14    48
# Comp:  2               HeI5876      8.772      0.30      14    48
# Comp:  2          [OIII]5007_d      702.3      0.38      14    48
# Comp:  2            [OI]6300_d      3.153      0.38      14    48
# Comp:  2           [NII]6583_d      7.946      0.38      14    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -166         1
#  comp.  1:        13        34
#  comp.  2:        16        49
# chi2/DOF: 8.169; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      104.8      0.28      13    34
# Comp:  1                Halpha      213.9      0.28      13    34
# Comp:  2             [SII]6716      12.09      0.30      16    49
# Comp:  2             [SII]6731      8.575      0.30      16    49
# Comp:  2              HeII4687     0.8793      0.30      16    49
# Comp:  2               HeI5876      8.576      0.30      16    49
# Comp:  2          [OIII]5007_d      803.0      0.38      16    49
# Comp:  2            [OI]6300_d      2.949      0.38      16    49
# Comp:  2           [NII]6583_d      7.828      0.38      16    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -185         1
#  comp.  1:        11        32
#  comp.  2:        10        47
# chi2/DOF: 29.59; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      120.3      0.28      11    32
# Comp:  1                Halpha      210.2      0.28      11    32
# Comp:  2             [SII]6716      11.17      0.30      10    47
# Comp:  2             [SII]6731      8.672      0.30      10    47
# Comp:  2              HeII4687     0.5344      0.30      10    47
# Comp:  2               HeI5876      9.224      0.30      10    47
# Comp:  2          [OIII]5007_d      719.8      0.37      10    47
# Comp:  2            [OI]6300_d      2.727      0.37      10    47
# Comp:  2           [NII]6583_d      7.371      0.37      10    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -184       504
#  comp.  1:        12        29
#  comp.  2:        14        46
# chi2/DOF: 27.76; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      118.8      0.28      12    29
# Comp:  1                Halpha      210.9      0.28      12    29
# Comp:  2             [SII]6716      12.15      0.30      14    46
# Comp:  2             [SII]6731      8.764      0.30      14    46
# Comp:  2              HeII4687     0.7258      0.30      14    46
# Comp:  2               HeI5876      9.190      0.30      14    46
# Comp:  2          [OIII]5007_d      700.3      0.37      14    46
# Comp:  2            [OI]6300_d      2.460      0.37      14    46
# Comp:  2           [NII]6583_d      7.916      0.37      14    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       123         1
#  comp.  1:        12        38
#  comp.  2:        12        35
# chi2/DOF: 15.06; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 85; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      123.6      0.29      12    38
# Comp:  1                Halpha      213.1      0.29      12    38
# Comp:  2             [SII]6716      11.02      0.28      12    35
# Comp:  2             [SII]6731      8.244      0.28      12    35
# Comp:  2              HeII4687     0.7028      0.28      12    35
# Comp:  2               HeI5876      9.478      0.28      12    35
# Comp:  2          [OIII]5007_d      742.1      0.36      12    35
# Comp:  2            [OI]6300_d      3.366      0.36      12    35
# Comp:  2           [NII]6583_d      7.658      0.36      12    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -122         1
#  comp.  1:        15        37
#  comp.  2:        11        58
# chi2/DOF: 16.04; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      105.9      0.29      15    37
# Comp:  1                Halpha      209.5      0.29      15    37
# Comp:  2             [SII]6716      11.97      0.31      11    58
# Comp:  2             [SII]6731      8.850      0.31      11    58
# Comp:  2              HeII4687     0.7963      0.31      11    58
# Comp:  2               HeI5876      9.536      0.31      11    58
# Comp:  2          [OIII]5007_d      694.4      0.39      11    58
# Comp:  2            [OI]6300_d      3.241      0.39      11    58
# Comp:  2           [NII]6583_d      7.927      0.39      11    58
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([ 7.30749288,  6.18404815,  1.00451229,  0.47673917,  0.1168819 ,
#         0.7172779 , 44.37071995,  0.49612212,  0.47396695])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_1440\2709300755.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(8, 6))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([1.12623396e+02, 2.88985032e+02, 1.70579861e+01, 1.20568770e+01,
#        6.68986132e-01, 1.13220440e+01, 7.52627278e+02, 4.16424094e+00,
#        1.05367754e+01])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_5_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_5_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_5_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_5_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_5_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name        Flux  Error flux
# 0         Hbeta   31.886983    2.068965
# 1        Halpha   81.820130    1.750885
# 2     [SII]6716    4.829616    0.284407
# 3     [SII]6731    3.413655    0.134979
# 4      HeII4687    0.189410    0.033093
# 5       HeI5876    3.205602    0.203082
# 6  [OIII]5007_d  213.090835   12.562651
# 7    [OI]6300_d    1.179019    0.140467
# 8   [NII]6583_d    2.983270    0.134194
#           Name        Flux  Error_flux
# 0        Hbeta   31.886983    2.068965
# 1       Halpha   81.820130    1.750885
# 2    [SII]6716    4.829616    0.284407
# 3    [SII]6731    3.413655    0.134979
# 4     HeII4687    0.189410    0.033093
# 5      HeI5876    3.205602    0.203082
# 6   [OIII]4959   53.272709   12.562651
# 7   [OIII]5007  159.818126   12.562651
# 8     [OI]6300    0.884264    0.140467
# 9     [OI]6364    0.294755    0.140467
# 10   [NII]6548    0.745817    0.134194
# 11   [NII]6583    2.237452    0.134194

# %%
np.median(flux_rf_rebin)
# Out:
# 0.2831293010907849
