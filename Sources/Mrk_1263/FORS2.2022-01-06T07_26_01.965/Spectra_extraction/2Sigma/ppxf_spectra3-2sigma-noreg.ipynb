# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_3.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_1263/FORS2.2022-01-06T07_26_01.965/Spectra_extraction/redshift.txt")  
z = red[2][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.00423

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.2172112  2.21794808 2.21868496 ... 3.53181044 3.53254732 3.53328421]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3135, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3135, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        20         1
# chi2/DOF: 0.004384; DOF: 1941; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:        35         1
# chi2/DOF: 0.003270; DOF: 1901; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([35.11111593,  0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       285         1
#  comp.  1:        18        20
#  comp.  2:        27        47
# chi2/DOF: 5.845; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      55.67      0.17      18    20
# Comp:  1                Halpha      86.37      0.17      18    20
# Comp:  2             [SII]6716      7.266      0.19      27    47
# Comp:  2             [SII]6731      5.138      0.19      27    47
# Comp:  2              HeII4687     0.3911      0.19      27    47
# Comp:  2               HeI5876      3.490      0.19      27    47
# Comp:  2          [OIII]5007_d      204.5      0.24      27    47
# Comp:  2            [OI]6300_d      1.624      0.24      27    47
# Comp:  2           [NII]6583_d      4.563      0.24      27    47
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  307.6; gas flux:     56 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  488.9; gas flux:    118 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  34.72; gas flux:     10 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  23.47; gas flux:      7 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.887; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  16.82; gas flux:      4 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:    734; gas flux:    214 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  5.506; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  16.13; gas flux:      6 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       391         1
#  comp.  1:         8        15
#  comp.  2:        28        52
# chi2/DOF: 3.941; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      56.45      0.17       8    15
# Comp:  1                Halpha      84.66      0.17       8    15
# Comp:  2             [SII]6716      6.830      0.19      28    52
# Comp:  2             [SII]6731      5.231      0.19      28    52
# Comp:  2              HeII4687     0.4206      0.19      28    52
# Comp:  2               HeI5876      3.411      0.19      28    52
# Comp:  2          [OIII]5007_d      208.7      0.24      28    52
# Comp:  2            [OI]6300_d      1.819      0.24      28    52
# Comp:  2           [NII]6583_d      5.067      0.24      28    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       257         1
#  comp.  1:        26         1
#  comp.  2:        30        47
# chi2/DOF: 4.141; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      53.98      0.17      26     1
# Comp:  1                Halpha      85.63      0.17      26     1
# Comp:  2             [SII]6716      9.031      0.19      30    47
# Comp:  2             [SII]6731      5.118      0.19      30    47
# Comp:  2              HeII4687     0.5758      0.19      30    47
# Comp:  2               HeI5876      3.260      0.19      30    47
# Comp:  2          [OIII]5007_d      209.8      0.24      30    47
# Comp:  2            [OI]6300_d      1.722      0.24      30    47
# Comp:  2           [NII]6583_d      4.695      0.24      30    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       469        58
#  comp.  1:        18        23
#  comp.  2:        24        44
# chi2/DOF: 5.332; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      56.39      0.17      18    23
# Comp:  1                Halpha      84.69      0.17      18    23
# Comp:  2             [SII]6716      6.592      0.19      24    44
# Comp:  2             [SII]6731      5.871      0.19      24    44
# Comp:  2              HeII4687      0.000      0.19      24    44
# Comp:  2               HeI5876      3.470      0.19      24    44
# Comp:  2          [OIII]5007_d      203.9      0.23      24    44
# Comp:  2            [OI]6300_d      1.340      0.23      24    44
# Comp:  2           [NII]6583_d      3.820      0.23      24    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        79         1
#  comp.  1:        14        35
#  comp.  2:        27        47
# chi2/DOF: 4.115; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      67.82      0.18      14    35
# Comp:  1                Halpha      95.29      0.18      14    35
# Comp:  2             [SII]6716      5.953      0.19      27    47
# Comp:  2             [SII]6731      4.893      0.19      27    47
# Comp:  2              HeII4687    0.01650      0.19      27    47
# Comp:  2               HeI5876      3.550      0.19      27    47
# Comp:  2          [OIII]5007_d      203.3      0.24      27    47
# Comp:  2            [OI]6300_d      1.788      0.24      27    47
# Comp:  2           [NII]6583_d      4.222      0.24      27    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       167         1
#  comp.  1:        16        35
#  comp.  2:        30        48
# chi2/DOF: 4.926; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 83; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      60.06      0.18      16    35
# Comp:  1                Halpha      89.44      0.18      16    35
# Comp:  2             [SII]6716      9.026      0.19      30    48
# Comp:  2             [SII]6731      4.763      0.19      30    48
# Comp:  2              HeII4687     0.4945      0.19      30    48
# Comp:  2               HeI5876      3.645      0.19      30    48
# Comp:  2          [OIII]5007_d      206.3      0.24      30    48
# Comp:  2            [OI]6300_d      1.881      0.24      30    48
# Comp:  2           [NII]6583_d      4.186      0.24      30    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88         1
#  comp.  1:        16         1
#  comp.  2:        25        45
# chi2/DOF: 4.526; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 83; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      49.54      0.17      16     1
# Comp:  1                Halpha      84.16      0.17      16     1
# Comp:  2             [SII]6716      6.468      0.19      25    45
# Comp:  2             [SII]6731      4.445      0.19      25    45
# Comp:  2              HeII4687     0.3679      0.19      25    45
# Comp:  2               HeI5876      3.251      0.19      25    45
# Comp:  2          [OIII]5007_d      196.6      0.24      25    45
# Comp:  2            [OI]6300_d      1.486      0.24      25    45
# Comp:  2           [NII]6583_d      3.992      0.24      25    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       166         1
#  comp.  1:        17         1
#  comp.  2:        26        48
# chi2/DOF: 4.533; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      61.11      0.17      17     1
# Comp:  1                Halpha      81.49      0.17      17     1
# Comp:  2             [SII]6716      9.006      0.19      26    48
# Comp:  2             [SII]6731      4.865      0.19      26    48
# Comp:  2              HeII4687     0.5306      0.19      26    48
# Comp:  2               HeI5876      3.486      0.19      26    48
# Comp:  2          [OIII]5007_d      204.1      0.24      26    48
# Comp:  2            [OI]6300_d      1.722      0.24      26    48
# Comp:  2           [NII]6583_d      4.116      0.24      26    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       330       515
#  comp.  1:        11        14
#  comp.  2:        28        48
# chi2/DOF: 4.298; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      61.30      0.17      11    14
# Comp:  1                Halpha      86.92      0.17      11    14
# Comp:  2             [SII]6716      9.168      0.19      28    48
# Comp:  2             [SII]6731      4.774      0.19      28    48
# Comp:  2              HeII4687     0.3598      0.19      28    48
# Comp:  2               HeI5876      3.694      0.19      28    48
# Comp:  2          [OIII]5007_d      204.6      0.24      28    48
# Comp:  2            [OI]6300_d      1.445      0.24      28    48
# Comp:  2           [NII]6583_d      5.011      0.24      28    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       284         1
#  comp.  1:        21        14
#  comp.  2:        25        42
# chi2/DOF: 4.033; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      47.40      0.17      21    14
# Comp:  1                Halpha      81.79      0.17      21    14
# Comp:  2             [SII]6716      8.750      0.18      25    42
# Comp:  2             [SII]6731      4.626      0.18      25    42
# Comp:  2              HeII4687      0.000      0.18      25    42
# Comp:  2               HeI5876      3.689      0.18      25    42
# Comp:  2          [OIII]5007_d      201.2      0.23      25    42
# Comp:  2            [OI]6300_d      1.694      0.23      25    42
# Comp:  2           [NII]6583_d      4.366      0.23      25    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
#  comp.  1:        27         1
#  comp.  2:        25        46
# chi2/DOF: 3.259; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 17; Func calls: 127; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      56.71      0.17      27     1
# Comp:  1                Halpha      82.22      0.17      27     1
# Comp:  2             [SII]6716      6.703      0.19      25    46
# Comp:  2             [SII]6731      5.307      0.19      25    46
# Comp:  2              HeII4687     0.9399      0.19      25    46
# Comp:  2               HeI5876      3.934      0.19      25    46
# Comp:  2          [OIII]5007_d      203.4      0.24      25    46
# Comp:  2            [OI]6300_d      1.402      0.24      25    46
# Comp:  2           [NII]6583_d      5.017      0.24      25    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       267         1
#  comp.  1:        22        10
#  comp.  2:        30        48
# chi2/DOF: 4.638; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      53.70      0.17      22    10
# Comp:  1                Halpha      89.74      0.17      22    10
# Comp:  2             [SII]6716      8.954      0.19      30    48
# Comp:  2             [SII]6731      4.046      0.19      30    48
# Comp:  2              HeII4687     0.7085      0.19      30    48
# Comp:  2               HeI5876      3.640      0.19      30    48
# Comp:  2          [OIII]5007_d      210.2      0.24      30    48
# Comp:  2            [OI]6300_d      1.756      0.24      30    48
# Comp:  2           [NII]6583_d      5.089      0.24      30    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       333         1
#  comp.  1:        22        27
#  comp.  2:        31        52
# chi2/DOF: 3.854; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      51.02      0.18      22    27
# Comp:  1                Halpha      84.22      0.18      22    27
# Comp:  2             [SII]6716      8.013      0.19      31    52
# Comp:  2             [SII]6731      4.084      0.19      31    52
# Comp:  2              HeII4687     0.3848      0.19      31    52
# Comp:  2               HeI5876      3.873      0.19      31    52
# Comp:  2          [OIII]5007_d      215.1      0.24      31    52
# Comp:  2            [OI]6300_d      1.738      0.24      31    52
# Comp:  2           [NII]6583_d      4.728      0.24      31    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       102         1
#  comp.  1:        15        18
#  comp.  2:        28        44
# chi2/DOF: 4.733; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      63.85      0.17      15    18
# Comp:  1                Halpha      88.56      0.17      15    18
# Comp:  2             [SII]6716      7.593      0.19      28    44
# Comp:  2             [SII]6731      6.180      0.19      28    44
# Comp:  2              HeII4687     0.2297      0.19      28    44
# Comp:  2               HeI5876      3.668      0.19      28    44
# Comp:  2          [OIII]5007_d      199.9      0.24      28    44
# Comp:  2            [OI]6300_d      1.669      0.24      28    44
# Comp:  2           [NII]6583_d      4.404      0.24      28    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       138       177
#  comp.  1:        20         1
#  comp.  2:        23        41
# chi2/DOF: 3.959; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      47.80      0.17      20     1
# Comp:  1                Halpha      83.17      0.17      20     1
# Comp:  2             [SII]6716      7.737      0.18      23    41
# Comp:  2             [SII]6731      4.827      0.18      23    41
# Comp:  2              HeII4687     0.3168      0.18      23    41
# Comp:  2               HeI5876      3.463      0.18      23    41
# Comp:  2          [OIII]5007_d      196.9      0.23      23    41
# Comp:  2            [OI]6300_d      1.739      0.23      23    41
# Comp:  2           [NII]6583_d      4.808      0.23      23    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       207       393
#  comp.  1:        13        36
#  comp.  2:        26        51
# chi2/DOF: 3.445; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      67.00      0.18      13    36
# Comp:  1                Halpha      93.51      0.18      13    36
# Comp:  2             [SII]6716      6.167      0.19      26    51
# Comp:  2             [SII]6731      4.487      0.19      26    51
# Comp:  2              HeII4687     0.2942      0.19      26    51
# Comp:  2               HeI5876      3.435      0.19      26    51
# Comp:  2          [OIII]5007_d      208.2      0.24      26    51
# Comp:  2            [OI]6300_d      1.426      0.24      26    51
# Comp:  2           [NII]6583_d      5.435      0.24      26    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       125       417
#  comp.  1:        13        23
#  comp.  2:        27        48
# chi2/DOF: 5.281; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.65      0.17      13    23
# Comp:  1                Halpha      88.67      0.17      13    23
# Comp:  2             [SII]6716      6.558      0.19      27    48
# Comp:  2             [SII]6731      4.765      0.19      27    48
# Comp:  2              HeII4687      0.000      0.19      27    48
# Comp:  2               HeI5876      3.662      0.19      27    48
# Comp:  2          [OIII]5007_d      207.3      0.24      27    48
# Comp:  2            [OI]6300_d      1.608      0.24      27    48
# Comp:  2           [NII]6583_d      4.339      0.24      27    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       282         1
#  comp.  1:        19        10
#  comp.  2:        29        46
# chi2/DOF: 4.440; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      62.03      0.17      19    10
# Comp:  1                Halpha      81.57      0.17      19    10
# Comp:  2             [SII]6716      7.398      0.19      29    46
# Comp:  2             [SII]6731      4.769      0.19      29    46
# Comp:  2              HeII4687     0.3357      0.19      29    46
# Comp:  2               HeI5876      3.191      0.19      29    46
# Comp:  2          [OIII]5007_d      205.3      0.24      29    46
# Comp:  2            [OI]6300_d      1.721      0.24      29    46
# Comp:  2           [NII]6583_d      3.911      0.24      29    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       243         1
#  comp.  1:        20        33
#  comp.  2:        24        45
# chi2/DOF: 4.810; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.79      0.18      20    33
# Comp:  1                Halpha      90.79      0.18      20    33
# Comp:  2             [SII]6716      7.176      0.19      24    45
# Comp:  2             [SII]6731      4.034      0.19      24    45
# Comp:  2              HeII4687     0.3485      0.19      24    45
# Comp:  2               HeI5876      3.625      0.19      24    45
# Comp:  2          [OIII]5007_d      196.8      0.24      24    45
# Comp:  2            [OI]6300_d      1.541      0.24      24    45
# Comp:  2           [NII]6583_d      4.310      0.24      24    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       774         1
#  comp.  1:        25         2
#  comp.  2:        27        46
# chi2/DOF: 4.805; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      54.60      0.17      25     2
# Comp:  1                Halpha      82.12      0.17      25     2
# Comp:  2             [SII]6716      7.079      0.19      27    46
# Comp:  2             [SII]6731      5.863      0.19      27    46
# Comp:  2              HeII4687      0.000      0.19      27    46
# Comp:  2               HeI5876      3.675      0.19      27    46
# Comp:  2          [OIII]5007_d      204.1      0.24      27    46
# Comp:  2            [OI]6300_d      1.533      0.24      27    46
# Comp:  2           [NII]6583_d      4.488      0.24      27    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       203         1
#  comp.  1:        19        32
#  comp.  2:        29        47
# chi2/DOF: 4.452; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.11      0.18      19    32
# Comp:  1                Halpha      87.72      0.18      19    32
# Comp:  2             [SII]6716      6.730      0.19      29    47
# Comp:  2             [SII]6731      5.363      0.19      29    47
# Comp:  2              HeII4687     0.3411      0.19      29    47
# Comp:  2               HeI5876      3.638      0.19      29    47
# Comp:  2          [OIII]5007_d      201.3      0.24      29    47
# Comp:  2            [OI]6300_d      1.505      0.24      29    47
# Comp:  2           [NII]6583_d      5.207      0.24      29    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       292         1
#  comp.  1:        14        36
#  comp.  2:        30        52
# chi2/DOF: 3.317; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.10      0.18      14    36
# Comp:  1                Halpha      94.03      0.18      14    36
# Comp:  2             [SII]6716      6.856      0.19      30    52
# Comp:  2             [SII]6731      4.932      0.19      30    52
# Comp:  2              HeII4687      0.000      0.19      30    52
# Comp:  2               HeI5876      3.514      0.19      30    52
# Comp:  2          [OIII]5007_d      210.5      0.24      30    52
# Comp:  2            [OI]6300_d      1.660      0.24      30    52
# Comp:  2           [NII]6583_d      4.395      0.24      30    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       226         1
#  comp.  1:        19        25
#  comp.  2:        24        41
# chi2/DOF: 3.850; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      64.46      0.18      19    25
# Comp:  1                Halpha      87.59      0.18      19    25
# Comp:  2             [SII]6716      6.492      0.18      24    41
# Comp:  2             [SII]6731      4.353      0.18      24    41
# Comp:  2              HeII4687     0.4441      0.18      24    41
# Comp:  2               HeI5876      3.531      0.18      24    41
# Comp:  2          [OIII]5007_d      192.8      0.23      24    41
# Comp:  2            [OI]6300_d      1.432      0.23      24    41
# Comp:  2           [NII]6583_d      3.633      0.23      24    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       208         1
#  comp.  1:        18         1
#  comp.  2:        27        47
# chi2/DOF: 5.139; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      53.81      0.17      18     1
# Comp:  1                Halpha      86.05      0.17      18     1
# Comp:  2             [SII]6716      5.569      0.19      27    47
# Comp:  2             [SII]6731      5.798      0.19      27    47
# Comp:  2              HeII4687     0.3649      0.19      27    47
# Comp:  2               HeI5876      3.289      0.19      27    47
# Comp:  2          [OIII]5007_d      202.8      0.24      27    47
# Comp:  2            [OI]6300_d      1.640      0.24      27    47
# Comp:  2           [NII]6583_d      4.730      0.24      27    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       150       465
#  comp.  1:        18        33
#  comp.  2:        26        44
# chi2/DOF: 4.053; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.31      0.18      18    33
# Comp:  1                Halpha      92.52      0.18      18    33
# Comp:  2             [SII]6716      7.286      0.19      26    44
# Comp:  2             [SII]6731      5.878      0.19      26    44
# Comp:  2              HeII4687     0.9473      0.19      26    44
# Comp:  2               HeI5876      3.317      0.19      26    44
# Comp:  2          [OIII]5007_d      197.9      0.23      26    44
# Comp:  2            [OI]6300_d      1.762      0.23      26    44
# Comp:  2           [NII]6583_d      4.867      0.23      26    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       234       191
#  comp.  1:        17         1
#  comp.  2:        26        45
# chi2/DOF: 5.341; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      55.18      0.17      17     1
# Comp:  1                Halpha      83.80      0.17      17     1
# Comp:  2             [SII]6716      7.637      0.19      26    45
# Comp:  2             [SII]6731      5.702      0.19      26    45
# Comp:  2              HeII4687     0.8423      0.19      26    45
# Comp:  2               HeI5876      3.488      0.19      26    45
# Comp:  2          [OIII]5007_d      203.7      0.24      26    45
# Comp:  2            [OI]6300_d      1.580      0.24      26    45
# Comp:  2           [NII]6583_d      5.107      0.24      26    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       397       167
#  comp.  1:        13        22
#  comp.  2:        30        47
# chi2/DOF: 5.316; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      56.29      0.17      13    22
# Comp:  1                Halpha      86.51      0.17      13    22
# Comp:  2             [SII]6716      6.684      0.19      30    47
# Comp:  2             [SII]6731      5.563      0.19      30    47
# Comp:  2              HeII4687     0.9209      0.19      30    47
# Comp:  2               HeI5876      3.611      0.19      30    47
# Comp:  2          [OIII]5007_d      204.8      0.24      30    47
# Comp:  2            [OI]6300_d      1.838      0.24      30    47
# Comp:  2           [NII]6583_d      3.734      0.24      30    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:        12        16
#  comp.  2:        31        52
# chi2/DOF: 3.769; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 61; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      49.66      0.17      12    16
# Comp:  1                Halpha      86.87      0.17      12    16
# Comp:  2             [SII]6716      8.631      0.19      31    52
# Comp:  2             [SII]6731      5.350      0.19      31    52
# Comp:  2              HeII4687     0.2998      0.19      31    52
# Comp:  2               HeI5876      3.782      0.19      31    52
# Comp:  2          [OIII]5007_d      206.7      0.24      31    52
# Comp:  2            [OI]6300_d      1.677      0.24      31    52
# Comp:  2           [NII]6583_d      4.392      0.24      31    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       365       402
#  comp.  1:        15        23
#  comp.  2:        29        46
# chi2/DOF: 4.221; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      64.32      0.17      15    23
# Comp:  1                Halpha      90.90      0.17      15    23
# Comp:  2             [SII]6716      7.156      0.19      29    46
# Comp:  2             [SII]6731      6.267      0.19      29    46
# Comp:  2              HeII4687      0.000      0.19      29    46
# Comp:  2               HeI5876      3.148      0.19      29    46
# Comp:  2          [OIII]5007_d      202.7      0.24      29    46
# Comp:  2            [OI]6300_d      1.618      0.24      29    46
# Comp:  2           [NII]6583_d      4.227      0.24      29    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       494       280
#  comp.  1:        15        28
#  comp.  2:        26        48
# chi2/DOF: 5.300; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      59.13      0.18      15    28
# Comp:  1                Halpha      87.88      0.18      15    28
# Comp:  2             [SII]6716      8.050      0.19      26    48
# Comp:  2             [SII]6731      5.191      0.19      26    48
# Comp:  2              HeII4687     0.2242      0.19      26    48
# Comp:  2               HeI5876      3.839      0.19      26    48
# Comp:  2          [OIII]5007_d      201.0      0.24      26    48
# Comp:  2            [OI]6300_d      1.635      0.24      26    48
# Comp:  2           [NII]6583_d      4.882      0.24      26    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -141         1
#  comp.  1:        11        29
#  comp.  2:        29        49
# chi2/DOF: 3.725; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.16      0.18      11    29
# Comp:  1                Halpha      91.46      0.18      11    29
# Comp:  2             [SII]6716      6.182      0.19      29    49
# Comp:  2             [SII]6731      5.525      0.19      29    49
# Comp:  2              HeII4687     0.2906      0.19      29    49
# Comp:  2               HeI5876      3.570      0.19      29    49
# Comp:  2          [OIII]5007_d      207.3      0.24      29    49
# Comp:  2            [OI]6300_d      1.744      0.24      29    49
# Comp:  2           [NII]6583_d      4.842      0.24      29    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       531       264
#  comp.  1:        11        24
#  comp.  2:        24        43
# chi2/DOF: 4.189; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      56.91      0.17      11    24
# Comp:  1                Halpha      82.17      0.17      11    24
# Comp:  2             [SII]6716      8.449      0.19      24    43
# Comp:  2             [SII]6731      5.521      0.19      24    43
# Comp:  2              HeII4687     0.7722      0.19      24    43
# Comp:  2               HeI5876      3.776      0.19      24    43
# Comp:  2          [OIII]5007_d      198.6      0.23      24    43
# Comp:  2            [OI]6300_d      1.707      0.23      24    43
# Comp:  2           [NII]6583_d      4.687      0.23      24    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        63        77
#  comp.  1:        25         1
#  comp.  2:        24        42
# chi2/DOF: 2.992; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 50; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      48.74      0.17      25     1
# Comp:  1                Halpha      83.53      0.17      25     1
# Comp:  2             [SII]6716      7.751      0.18      24    42
# Comp:  2             [SII]6731      4.760      0.18      24    42
# Comp:  2              HeII4687      0.000      0.18      24    42
# Comp:  2               HeI5876      3.669      0.18      24    42
# Comp:  2          [OIII]5007_d      199.7      0.23      24    42
# Comp:  2            [OI]6300_d      1.442      0.23      24    42
# Comp:  2           [NII]6583_d      5.477      0.23      24    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       358         1
#  comp.  1:        16        24
#  comp.  2:        28        51
# chi2/DOF: 4.619; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      49.48      0.17      16    24
# Comp:  1                Halpha      92.17      0.17      16    24
# Comp:  2             [SII]6716      8.039      0.19      28    51
# Comp:  2             [SII]6731      4.165      0.19      28    51
# Comp:  2              HeII4687   0.006321      0.19      28    51
# Comp:  2               HeI5876      3.194      0.19      28    51
# Comp:  2          [OIII]5007_d      208.0      0.24      28    51
# Comp:  2            [OI]6300_d      1.645      0.24      28    51
# Comp:  2           [NII]6583_d      4.857      0.24      28    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        93        63
#  comp.  1:        26        10
#  comp.  2:        25        46
# chi2/DOF: 4.463; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      55.84      0.17      26    10
# Comp:  1                Halpha      84.51      0.17      26    10
# Comp:  2             [SII]6716      7.916      0.19      25    46
# Comp:  2             [SII]6731      5.775      0.19      25    46
# Comp:  2              HeII4687     0.8102      0.19      25    46
# Comp:  2               HeI5876      3.784      0.19      25    46
# Comp:  2          [OIII]5007_d      202.4      0.24      25    46
# Comp:  2            [OI]6300_d      1.256      0.24      25    46
# Comp:  2           [NII]6583_d      4.550      0.24      25    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        89       172
#  comp.  1:        18        31
#  comp.  2:        23        44
# chi2/DOF: 3.911; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.65      0.18      18    31
# Comp:  1                Halpha      87.80      0.18      18    31
# Comp:  2             [SII]6716      8.793      0.19      23    44
# Comp:  2             [SII]6731      4.789      0.19      23    44
# Comp:  2              HeII4687      0.000      0.19      23    44
# Comp:  2               HeI5876      3.506      0.19      23    44
# Comp:  2          [OIII]5007_d      198.6      0.23      23    44
# Comp:  2            [OI]6300_d      1.542      0.23      23    44
# Comp:  2           [NII]6583_d      5.063      0.23      23    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        82       112
#  comp.  1:        12        26
#  comp.  2:        30        52
# chi2/DOF: 3.735; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      64.21      0.18      12    26
# Comp:  1                Halpha      93.46      0.18      12    26
# Comp:  2             [SII]6716      8.157      0.19      30    52
# Comp:  2             [SII]6731      5.371      0.19      30    52
# Comp:  2              HeII4687      0.000      0.19      30    52
# Comp:  2               HeI5876      3.358      0.19      30    52
# Comp:  2          [OIII]5007_d      210.6      0.24      30    52
# Comp:  2            [OI]6300_d      1.527      0.24      30    52
# Comp:  2           [NII]6583_d      5.329      0.24      30    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43         1
#  comp.  1:        23         1
#  comp.  2:        29        50
# chi2/DOF: 3.929; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 14; Func calls: 108; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      56.22      0.17      23     1
# Comp:  1                Halpha      82.29      0.17      23     1
# Comp:  2             [SII]6716      8.679      0.19      29    50
# Comp:  2             [SII]6731      5.341      0.19      29    50
# Comp:  2              HeII4687     0.6907      0.19      29    50
# Comp:  2               HeI5876      3.669      0.19      29    50
# Comp:  2          [OIII]5007_d      206.9      0.24      29    50
# Comp:  2            [OI]6300_d      1.820      0.24      29    50
# Comp:  2           [NII]6583_d      4.205      0.24      29    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       186         1
#  comp.  1:        19        29
#  comp.  2:        25        46
# chi2/DOF: 4.574; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      65.68      0.18      19    29
# Comp:  1                Halpha      86.38      0.18      19    29
# Comp:  2             [SII]6716      7.826      0.19      25    46
# Comp:  2             [SII]6731      5.329      0.19      25    46
# Comp:  2              HeII4687     0.4699      0.19      25    46
# Comp:  2               HeI5876      3.198      0.19      25    46
# Comp:  2          [OIII]5007_d      204.5      0.24      25    46
# Comp:  2            [OI]6300_d      1.769      0.24      25    46
# Comp:  2           [NII]6583_d      4.519      0.24      25    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       266         1
#  comp.  1:        21         1
#  comp.  2:        29        50
# chi2/DOF: 4.486; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      48.79      0.17      21     1
# Comp:  1                Halpha      79.75      0.17      21     1
# Comp:  2             [SII]6716      8.551      0.19      29    50
# Comp:  2             [SII]6731      5.133      0.19      29    50
# Comp:  2              HeII4687   0.002902      0.19      29    50
# Comp:  2               HeI5876      3.323      0.19      29    50
# Comp:  2          [OIII]5007_d      208.2      0.24      29    50
# Comp:  2            [OI]6300_d      1.824      0.24      29    50
# Comp:  2           [NII]6583_d      4.565      0.24      29    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       302         1
#  comp.  1:        26        16
#  comp.  2:        27        49
# chi2/DOF: 4.665; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      55.52      0.17      26    16
# Comp:  1                Halpha      84.09      0.17      26    16
# Comp:  2             [SII]6716      6.712      0.19      27    49
# Comp:  2             [SII]6731      4.417      0.19      27    49
# Comp:  2              HeII4687      0.000      0.19      27    49
# Comp:  2               HeI5876      3.680      0.19      27    49
# Comp:  2          [OIII]5007_d      209.7      0.24      27    49
# Comp:  2            [OI]6300_d      1.796      0.24      27    49
# Comp:  2           [NII]6583_d      4.758      0.24      27    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:        22        15
#  comp.  2:        27        45
# chi2/DOF: 5.013; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      56.27      0.17      22    15
# Comp:  1                Halpha      89.04      0.17      22    15
# Comp:  2             [SII]6716      8.336      0.19      27    45
# Comp:  2             [SII]6731      4.966      0.19      27    45
# Comp:  2              HeII4687     0.3040      0.19      27    45
# Comp:  2               HeI5876      3.144      0.19      27    45
# Comp:  2          [OIII]5007_d      200.4      0.24      27    45
# Comp:  2            [OI]6300_d      1.755      0.24      27    45
# Comp:  2           [NII]6583_d      4.016      0.24      27    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       367         1
#  comp.  1:        13        23
#  comp.  2:        28        52
# chi2/DOF: 4.038; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 46; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      64.03      0.17      13    23
# Comp:  1                Halpha      88.19      0.17      13    23
# Comp:  2             [SII]6716      6.237      0.19      28    52
# Comp:  2             [SII]6731      4.948      0.19      28    52
# Comp:  2              HeII4687     0.8259      0.19      28    52
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      62.04      0.18      11    36
# Comp:  1                Halpha      97.47      0.18      11    36
# Comp:  2             [SII]6716      5.853      0.19      25    44
# Comp:  2             [SII]6731      5.396      0.19      25    44
# Comp:  2              HeII4687     0.3466      0.19      25    44
# Comp:  2               HeI5876      3.692      0.19      25    44
# Comp:  2          [OIII]5007_d      200.4      0.23      25    44
# Comp:  2            [OI]6300_d      1.570      0.23      25    44
# Comp:  2           [NII]6583_d      4.237      0.23      25    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       106         1
#  comp.  1:        12        18
#  comp.  2:        26        50
# chi2/DOF: 4.779; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 82; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.03      0.17      12    18
# Comp:  1                Halpha      88.13      0.17      12    18
# Comp:  2             [SII]6716      6.885      0.19      26    50
# Comp:  2             [SII]6731      5.380      0.19      26    50
# Comp:  2              HeII4687     0.7918      0.19      26    50
# Comp:  2               HeI5876      3.738      0.19      26    50
# Comp:  2          [OIII]5007_d      201.4      0.24      26    50
# Comp:  2            [OI]6300_d      1.862      0.24      26    50
# Comp:  2           [NII]6583_d      4.676      0.24      26    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       275         1
#  comp.  1:        21         1
#  comp.  2:        29        51
# chi2/DOF: 4.741; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      53.83      0.17      21     1
# Comp:  1                Halpha      79.78      0.17      21     1
# Comp:  2             [SII]6716      7.331      0.19      29    51
# Comp:  2             [SII]6731      6.027      0.19      29    51
# Comp:  2              HeII4687     0.4345      0.19      29    51
# Comp:  2               HeI5876      3.571      0.19      29    51
# Comp:  2          [OIII]5007_d      211.0      0.24      29    51
# Comp:  2            [OI]6300_d      1.708      0.24      29    51
# Comp:  2           [NII]6583_d      5.692      0.24      29    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       437         1
#  comp.  1:        18        12
#  comp.  2:        27        48
# chi2/DOF: 5.598; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      55.48      0.17      18    12
# Comp:  1                Halpha      84.18      0.17      18    12
# Comp:  2             [SII]6716      8.581      0.19      27    48
# Comp:  2             [SII]6731      5.475      0.19      27    48
# Comp:  2              HeII4687      0.000      0.19      27    48
# Comp:  2               HeI5876      3.729      0.19      27    48
# Comp:  2          [OIII]5007_d      208.4      0.24      27    48
# Comp:  2            [OI]6300_d      1.529      0.24      27    48
# Comp:  2           [NII]6583_d      4.507      0.24      27    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:        17         1
#  comp.  2:        23        40
# chi2/DOF: 3.957; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 75; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      55.23      0.17      17     1
# Comp:  1                Halpha      86.88      0.17      17     1
# Comp:  2             [SII]6716      6.635      0.18      23    40
# Comp:  2             [SII]6731      5.961      0.18      23    40
# Comp:  2              HeII4687     0.2317      0.18      23    40
# Comp:  2               HeI5876      3.664      0.18      23    40
# Comp:  2          [OIII]5007_d      195.9      0.23      23    40
# Comp:  2            [OI]6300_d      1.400      0.23      23    40
# Comp:  2           [NII]6583_d      5.152      0.23      23    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:        25         1
#  comp.  2:        24        41
# chi2/DOF: 3.309; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 67; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      55.84      0.17      25     1
# Comp:  1                Halpha      80.81      0.17      25     1
# Comp:  2             [SII]6716      5.449      0.18      24    41
# Comp:  2             [SII]6731      4.829      0.18      24    41
# Comp:  2              HeII4687     0.4341      0.18      24    41
# Comp:  2               HeI5876      3.828      0.18      24    41
# Comp:  2          [OIII]5007_d      198.2      0.23      24    41
# Comp:  2            [OI]6300_d      1.501      0.23      24    41
# Comp:  2           [NII]6583_d      4.843      0.23      24    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       166         1
#  comp.  1:        13        36
#  comp.  2:        26        42
# chi2/DOF: 3.261; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 81; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.37      0.18      13    36
# Comp:  1                Halpha      97.00      0.18      13    36
# Comp:  2             [SII]6716      7.123      0.18      26    42
# Comp:  2             [SII]6731      4.304      0.18      26    42
# Comp:  2              HeII4687     0.3684      0.18      26    42
# Comp:  2               HeI5876      3.542      0.18      26    42
# Comp:  2          [OIII]5007_d      196.2      0.23      26    42
# Comp:  2            [OI]6300_d      1.468      0.23      26    42
# Comp:  2           [NII]6583_d      5.630      0.23      26    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       307         1
#  comp.  1:        19        30
#  comp.  2:        30        49
# chi2/DOF: 5.162; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.58      0.18      19    30
# Comp:  1                Halpha      92.06      0.18      19    30
# Comp:  2             [SII]6716      6.045      0.19      30    49
# Comp:  2             [SII]6731      5.315      0.19      30    49
# Comp:  2              HeII4687     0.4629      0.19      30    49
# Comp:  2               HeI5876      3.699      0.19      30    49
# Comp:  2          [OIII]5007_d      204.5      0.24      30    49
# Comp:  2            [OI]6300_d      1.639      0.24      30    49
# Comp:  2           [NII]6583_d      4.146      0.24      30    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        97       528
#  comp.  1:        18        26
#  comp.  2:        29        52
# chi2/DOF: 4.910; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.75      0.18      18    26
# Comp:  1                Halpha      82.90      0.18      18    26
# Comp:  2             [SII]6716      7.256      0.19      29    52
# Comp:  2             [SII]6731      4.538      0.19      29    52
# Comp:  2              HeII4687     0.2956      0.19      29    52
# Comp:  2               HeI5876      3.103      0.19      29    52
# Comp:  2          [OIII]5007_d      212.3      0.24      29    52
# Comp:  2            [OI]6300_d      1.543      0.24      29    52
# Comp:  2           [NII]6583_d      4.662      0.24      29    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       213         1
#  comp.  1:        25         1
#  comp.  2:        25        48
# chi2/DOF: 4.157; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      53.92      0.17      25     1
# Comp:  1                Halpha      82.44      0.17      25     1
# Comp:  2             [SII]6716      8.417      0.19      25    48
# Comp:  2             [SII]6731      5.254      0.19      25    48
# Comp:  2              HeII4687      0.000      0.19      25    48
# Comp:  2               HeI5876      3.249      0.19      25    48
# Comp:  2          [OIII]5007_d      201.1      0.24      25    48
# Comp:  2            [OI]6300_d      1.605      0.24      25    48
# Comp:  2           [NII]6583_d      4.830      0.24      25    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       419       108
#  comp.  1:        15        16
#  comp.  2:        22        43
# chi2/DOF: 4.842; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      55.93      0.17      15    16
# Comp:  1                Halpha      83.05      0.17      15    16
# Comp:  2             [SII]6716      6.536      0.19      22    43
# Comp:  2             [SII]6731      3.946      0.19      22    43
# Comp:  2              HeII4687      0.000      0.19      22    43
# Comp:  2               HeI5876      3.466      0.19      22    43
# Comp:  2          [OIII]5007_d      199.0      0.23      22    43
# Comp:  2            [OI]6300_d      1.482      0.23      22    43
# Comp:  2           [NII]6583_d      4.455      0.23      22    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       279       351
#  comp.  1:        10        21
#  comp.  2:        32        54
# chi2/DOF: 3.598; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      57.44      0.17      10    21
# Comp:  1                Halpha      87.78      0.17      10    21
# Comp:  2             [SII]6716      8.608      0.19      32    54
# Comp:  2             [SII]6731      5.626      0.19      32    54
# Comp:  2              HeII4687      0.000      0.19      32    54
# Comp:  2               HeI5876      3.545      0.19      32    54
# Comp:  2          [OIII]5007_d      213.5      0.24      32    54
# Comp:  2            [OI]6300_d      1.998      0.24      32    54
# Comp:  2           [NII]6583_d      5.348      0.24      32    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       130         1
#  comp.  1:        21        17
#  comp.  2:        28        49
# chi2/DOF: 4.426; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      49.29      0.17      21    17
# Comp:  1                Halpha      82.61      0.17      21    17
# Comp:  2             [SII]6716      7.262      0.19      28    49
# Comp:  2             [SII]6731      4.064      0.19      28    49
# Comp:  2              HeII4687     0.9871      0.19      28    49
# Comp:  2               HeI5876      3.524      0.19      28    49
# Comp:  2          [OIII]5007_d      207.6      0.24      28    49
# Comp:  2            [OI]6300_d      1.584      0.24      28    49
# Comp:  2           [NII]6583_d      4.667      0.24      28    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       307       108
#  comp.  1:        16         1
#  comp.  2:        26        44
# chi2/DOF: 4.595; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      61.00      0.17      16     1
# Comp:  1                Halpha      81.17      0.17      16     1
# Comp:  2             [SII]6716      5.944      0.19      26    44
# Comp:  2             [SII]6731      5.618      0.19      26    44
# Comp:  2              HeII4687     0.3643      0.19      26    44
# Comp:  2               HeI5876      3.431      0.19      26    44
# Comp:  2          [OIII]5007_d      202.0      0.24      26    44
# Comp:  2            [OI]6300_d      1.503      0.24      26    44
# Comp:  2           [NII]6583_d      4.938      0.24      26    44
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([5.83874719, 5.80441676, 1.34625049, 0.82085191, 0.30153262,
#        0.28159263, 4.99284184, 0.18624078, 0.70594398])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_3_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_3_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_3_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_3_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_3_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
