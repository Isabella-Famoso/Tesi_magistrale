# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_4.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_1263/FORS2.2022-01-06T07_26_01.965/Spectra_extraction/redshift.txt")   
z = red[3][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_4']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.2165626  2.21729952 2.21803643 ... 3.53195112 3.53268804 3.53342495]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3137, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3137, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3137, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
# C:\Users\ISAFA\anaconda3\Lib\site-packages\capfit\capfit.py:799: RuntimeWarning: invalid value encountered in scalar divide
#   ratio = actred/prered
#  Best Fit:       Vel     sigma
#  comp.  0:        20       180
# chi2/DOF: 0.003593; DOF: 1944; degree = 4; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 5; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 0/150
#  Best Fit:       Vel     sigma
#  comp.  0:        20       180
# chi2/DOF: 0.001406; DOF: 1904; degree = 4; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 5; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 0/150
# [1.23846502 1.22555808 1.2066816  ... 0.69589165 1.13093876 1.27810238]
# [1.19982957 1.19981858 1.1998072  ... 0.62957203 0.62928116 0.62899044]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([ 20., 180.])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:        10        28
#  comp.  2:         6        46
# chi2/DOF: 89.70; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      69.38      0.12      10    28
# Comp:  1                Halpha      260.7      0.12      10    28
# Comp:  2             [SII]6716      11.21      0.13       6    46
# Comp:  2             [SII]6731      7.827      0.13       6    46
# Comp:  2              HeII4687     0.4541      0.13       6    46
# Comp:  2               HeI5876      9.754      0.13       6    46
# Comp:  2          [OIII]5007_d      572.6      0.17       6    46
# Comp:  2            [OI]6300_d      2.291      0.17       6    46
# Comp:  2           [NII]6583_d      7.329      0.17       6    46
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hbeta        - Amplitude/Noise:  550.4; gas flux:     70 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:   2128; gas flux:    357 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  83.99; gas flux:     16 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  55.54; gas flux:     11 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  3.464; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:   74.5; gas flux:     12 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   3275; gas flux:    598 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  12.53; gas flux:      3 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  40.41; gas flux:     10 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([1.01395952, 1.36884942, 1.40089107, 1.4038896 , 0.97732735,
#        1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4861.33297684, 6562.81902144, 6716.43970813, 6730.81584054,
#        4685.70352776, 5875.61444265, 5006.8433303 , 6300.29755334,
#        6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       151         1
#  comp.  1:         9        25
#  comp.  2:        13        57
# chi2/DOF: 50.82; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      73.78      0.12       9    25
# Comp:  1                Halpha      259.5      0.12       9    25
# Comp:  2             [SII]6716      12.10      0.14      13    57
# Comp:  2             [SII]6731      8.166      0.14      13    57
# Comp:  2              HeII4687     0.3244      0.14      13    57
# Comp:  2               HeI5876      8.945      0.14      13    57
# Comp:  2          [OIII]5007_d      611.9      0.17      13    57
# Comp:  2            [OI]6300_d      2.407      0.17      13    57
# Comp:  2           [NII]6583_d      7.693      0.17      13    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:         9        32
#  comp.  2:        10        45
# chi2/DOF: 75.22; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      77.15      0.13       9    32
# Comp:  1                Halpha      261.9      0.13       9    32
# Comp:  2             [SII]6716      11.06      0.13      10    45
# Comp:  2             [SII]6731      7.776      0.13      10    45
# Comp:  2              HeII4687     0.4336      0.13      10    45
# Comp:  2               HeI5876      10.23      0.13      10    45
# Comp:  2          [OIII]5007_d      548.9      0.17      10    45
# Comp:  2            [OI]6300_d      2.016      0.17      10    45
# Comp:  2           [NII]6583_d      7.493      0.17      10    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95       934
#  comp.  1:        10        32
#  comp.  2:        16        57
# chi2/DOF: 34.08; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.19      0.13      10    32
# Comp:  1                Halpha      261.5      0.13      10    32
# Comp:  2             [SII]6716      11.14      0.14      16    57
# Comp:  2             [SII]6731      8.065      0.14      16    57
# Comp:  2              HeII4687     0.4724      0.14      16    57
# Comp:  2               HeI5876      9.692      0.14      16    57
# Comp:  2          [OIII]5007_d      595.7      0.17      16    57
# Comp:  2            [OI]6300_d      1.971      0.17      16    57
# Comp:  2           [NII]6583_d      7.254      0.17      16    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       127         1
#  comp.  1:         9        30
#  comp.  2:        -3        38
# chi2/DOF: 21.61; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      76.45      0.13       9    30
# Comp:  1                Halpha      264.2      0.13       9    30
# Comp:  2             [SII]6716      10.41      0.13      -3    38
# Comp:  2             [SII]6731      7.390      0.13      -3    38
# Comp:  2              HeII4687     0.1324      0.13      -3    38
# Comp:  2               HeI5876      8.485      0.13      -3    38
# Comp:  2          [OIII]5007_d      522.2      0.16      -3    38
# Comp:  2            [OI]6300_d      2.373      0.16      -3    38
# Comp:  2           [NII]6583_d      7.174      0.16      -3    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:        12        23
#  comp.  2:         9        44
# chi2/DOF: 79.51; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      65.51      0.12      12    23
# Comp:  1                Halpha      257.2      0.12      12    23
# Comp:  2             [SII]6716      10.74      0.13       9    44
# Comp:  2             [SII]6731      7.845      0.13       9    44
# Comp:  2              HeII4687    0.06102      0.13       9    44
# Comp:  2               HeI5876      9.612      0.13       9    44
# Comp:  2          [OIII]5007_d      551.4      0.17       9    44
# Comp:  2            [OI]6300_d      1.956      0.17       9    44
# Comp:  2           [NII]6583_d      7.046      0.17       9    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       145         1
#  comp.  1:         7        33
#  comp.  2:         7        55
# chi2/DOF: 44.71; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 59; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      77.51      0.13       7    33
# Comp:  1                Halpha      267.1      0.13       7    33
# Comp:  2             [SII]6716      11.24      0.14       7    55
# Comp:  2             [SII]6731      7.622      0.14       7    55
# Comp:  2              HeII4687     0.2535      0.14       7    55
# Comp:  2               HeI5876      10.99      0.14       7    55
# Comp:  2          [OIII]5007_d      544.4      0.17       7    55
# Comp:  2            [OI]6300_d      2.099      0.17       7    55
# Comp:  2           [NII]6583_d      7.895      0.17       7    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -2001         1
#  comp.  1:        12        24
#  comp.  2:         2        54
# chi2/DOF: 64.88; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      74.15      0.12      12    24
# Comp:  1                Halpha      257.1      0.12      12    24
# Comp:  2             [SII]6716      11.50      0.14       2    54
# Comp:  2             [SII]6731      7.918      0.14       2    54
# Comp:  2              HeII4687     0.4425      0.14       2    54
# Comp:  2               HeI5876      9.348      0.14       2    54
# Comp:  2          [OIII]5007_d      564.9      0.17       2    54
# Comp:  2            [OI]6300_d      2.629      0.17       2    54
# Comp:  2           [NII]6583_d      7.616      0.17       2    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98         1
#  comp.  1:         8        32
#  comp.  2:        -0        42
# chi2/DOF: 26.21; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      73.28      0.13       8    32
# Comp:  1                Halpha      268.6      0.13       8    32
# Comp:  2             [SII]6716      11.11      0.13      -0    42
# Comp:  2             [SII]6731      7.605      0.13      -0    42
# Comp:  2              HeII4687     0.3619      0.13      -0    42
# Comp:  2               HeI5876      9.627      0.13      -0    42
# Comp:  2          [OIII]5007_d      513.6      0.16      -0    42
# Comp:  2            [OI]6300_d      2.325      0.16      -0    42
# Comp:  2           [NII]6583_d      7.125      0.16      -0    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26         1
#  comp.  1:        11        21
#  comp.  2:         8        46
# chi2/DOF: 85.87; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      72.86      0.12      11    21
# Comp:  1                Halpha      253.7      0.12      11    21
# Comp:  2             [SII]6716      10.92      0.13       8    46
# Comp:  2             [SII]6731      7.512      0.13       8    46
# Comp:  2              HeII4687     0.3939      0.13       8    46
# Comp:  2               HeI5876      10.30      0.13       8    46
# Comp:  2          [OIII]5007_d      564.6      0.17       8    46
# Comp:  2            [OI]6300_d      2.111      0.17       8    46
# Comp:  2           [NII]6583_d      7.329      0.17       8    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       157         1
#  comp.  1:         9        31
#  comp.  2:         7        37
# chi2/DOF: 43.87; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      68.43      0.13       9    31
# Comp:  1                Halpha      262.3      0.13       9    31
# Comp:  2             [SII]6716      10.92      0.13       7    37
# Comp:  2             [SII]6731      7.441      0.13       7    37
# Comp:  2              HeII4687     0.4338      0.13       7    37
# Comp:  2               HeI5876      9.552      0.13       7    37
# Comp:  2          [OIII]5007_d      597.0      0.16       7    37
# Comp:  2            [OI]6300_d      2.571      0.16       7    37
# Comp:  2           [NII]6583_d      7.176      0.16       7    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       230       615
#  comp.  1:         9        30
#  comp.  2:         0        42
# chi2/DOF: 25.74; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      73.69      0.13       9    30
# Comp:  1                Halpha      263.1      0.13       9    30
# Comp:  2             [SII]6716      12.24      0.13       0    42
# Comp:  2             [SII]6731      7.426      0.13       0    42
# Comp:  2              HeII4687     0.3418      0.13       0    42
# Comp:  2               HeI5876      9.691      0.13       0    42
# Comp:  2          [OIII]5007_d      510.6      0.16       0    42
# Comp:  2            [OI]6300_d      2.299      0.16       0    42
# Comp:  2           [NII]6583_d      7.500      0.16       0    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       237      1000
#  comp.  1:        11        23
#  comp.  2:        11        38
# chi2/DOF: 61.43; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.70      0.12      11    23
# Comp:  1                Halpha      254.5      0.12      11    23
# Comp:  2             [SII]6716      11.76      0.13      11    38
# Comp:  2             [SII]6731      7.898      0.13      11    38
# Comp:  2              HeII4687     0.4228      0.13      11    38
# Comp:  2               HeI5876      9.501      0.13      11    38
# Comp:  2          [OIII]5007_d      583.0      0.16      11    38
# Comp:  2            [OI]6300_d      2.323      0.16      11    38
# Comp:  2           [NII]6583_d      7.390      0.16      11    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -246       657
#  comp.  1:        12        21
#  comp.  2:         5        48
# chi2/DOF: 84.50; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      63.95      0.12      12    21
# Comp:  1                Halpha      256.5      0.12      12    21
# Comp:  2             [SII]6716      11.56      0.13       5    48
# Comp:  2             [SII]6731      8.149      0.13       5    48
# Comp:  2              HeII4687     0.6751      0.13       5    48
# Comp:  2               HeI5876      9.742      0.13       5    48
# Comp:  2          [OIII]5007_d      584.5      0.17       5    48
# Comp:  2            [OI]6300_d      2.563      0.17       5    48
# Comp:  2           [NII]6583_d      7.164      0.17       5    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43       704
#  comp.  1:        11        20
#  comp.  2:         3        55
# chi2/DOF: 65.40; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      70.49      0.12      11    20
# Comp:  1                Halpha      255.6      0.12      11    20
# Comp:  2             [SII]6716      11.71      0.14       3    55
# Comp:  2             [SII]6731      8.520      0.14       3    55
# Comp:  2              HeII4687     0.3670      0.14       3    55
# Comp:  2               HeI5876      10.36      0.14       3    55
# Comp:  2          [OIII]5007_d      573.4      0.17       3    55
# Comp:  2            [OI]6300_d      2.322      0.17       3    55
# Comp:  2           [NII]6583_d      7.868      0.17       3    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       103         1
#  comp.  1:        12        20
#  comp.  2:        15        50
# chi2/DOF: 24.98; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      71.99      0.12      12    20
# Comp:  1                Halpha      256.2      0.12      12    20
# Comp:  2             [SII]6716      11.85      0.13      15    50
# Comp:  2             [SII]6731      7.895      0.13      15    50
# Comp:  2              HeII4687     0.3509      0.13      15    50
# Comp:  2               HeI5876      10.37      0.13      15    50
# Comp:  2          [OIII]5007_d      621.8      0.17      15    50
# Comp:  2            [OI]6300_d      2.387      0.17      15    50
# Comp:  2           [NII]6583_d      7.708      0.17      15    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       183         1
#  comp.  1:        10        29
#  comp.  2:        17        48
# chi2/DOF: 28.52; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      64.54      0.12      10    29
# Comp:  1                Halpha      263.4      0.12      10    29
# Comp:  2             [SII]6716      11.05      0.13      17    48
# Comp:  2             [SII]6731      8.128      0.13      17    48
# Comp:  2              HeII4687     0.3608      0.13      17    48
# Comp:  2               HeI5876      9.715      0.13      17    48
# Comp:  2          [OIII]5007_d      607.3      0.17      17    48
# Comp:  2            [OI]6300_d      2.458      0.17      17    48
# Comp:  2           [NII]6583_d      7.377      0.17      17    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:        10        26
#  comp.  2:         7        45
# chi2/DOF: 86.45; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      75.68      0.12      10    26
# Comp:  1                Halpha      261.6      0.12      10    26
# Comp:  2             [SII]6716      10.97      0.13       7    45
# Comp:  2             [SII]6731      7.509      0.13       7    45
# Comp:  2              HeII4687     0.4694      0.13       7    45
# Comp:  2               HeI5876      10.33      0.13       7    45
# Comp:  2          [OIII]5007_d      561.5      0.17       7    45
# Comp:  2            [OI]6300_d      2.393      0.17       7    45
# Comp:  2           [NII]6583_d      7.204      0.17       7    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4       131
#  comp.  1:        10        25
#  comp.  2:        15        49
# chi2/DOF: 36.33; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 43; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      72.21      0.12      10    25
# Comp:  1                Halpha      258.6      0.12      10    25
# Comp:  2             [SII]6716      9.859      0.13      15    49
# Comp:  2             [SII]6731      8.133      0.13      15    49
# Comp:  2              HeII4687     0.1369      0.13      15    49
# Comp:  2               HeI5876      9.644      0.13      15    49
# Comp:  2          [OIII]5007_d      614.9      0.17      15    49
# Comp:  2            [OI]6300_d      2.137      0.17      15    49
# Comp:  2           [NII]6583_d      7.395      0.17      15    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       141         1
#  comp.  1:        11        22
#  comp.  2:        -3        40
# chi2/DOF: 34.13; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      75.30      0.12      11    22
# Comp:  1                Halpha      255.2      0.12      11    22
# Comp:  2             [SII]6716      12.16      0.13      -3    40
# Comp:  2             [SII]6731      7.544      0.13      -3    40
# Comp:  2              HeII4687     0.1818      0.13      -3    40
# Comp:  2               HeI5876      8.770      0.13      -3    40
# Comp:  2          [OIII]5007_d      531.7      0.16      -3    40
# Comp:  2            [OI]6300_d      2.135      0.16      -3    40
# Comp:  2           [NII]6583_d      7.204      0.16      -3    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        86        44
#  comp.  1:        12        21
#  comp.  2:         1        54
# chi2/DOF: 61.56; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      65.52      0.12      12    21
# Comp:  1                Halpha      256.2      0.12      12    21
# Comp:  2             [SII]6716      10.43      0.14       1    54
# Comp:  2             [SII]6731      8.004      0.14       1    54
# Comp:  2              HeII4687     0.3986      0.14       1    54
# Comp:  2               HeI5876      9.751      0.14       1    54
# Comp:  2          [OIII]5007_d      569.2      0.17       1    54
# Comp:  2            [OI]6300_d      2.448      0.17       1    54
# Comp:  2           [NII]6583_d      7.657      0.17       1    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       122         1
#  comp.  1:        10        22
#  comp.  2:         1        40
# chi2/DOF: 14.04; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      74.84      0.12      10    22
# Comp:  1                Halpha      255.5      0.12      10    22
# Comp:  2             [SII]6716      12.13      0.13       1    40
# Comp:  2             [SII]6731      7.385      0.13       1    40
# Comp:  2              HeII4687     0.2135      0.13       1    40
# Comp:  2               HeI5876      9.724      0.13       1    40
# Comp:  2          [OIII]5007_d      502.8      0.16       1    40
# Comp:  2            [OI]6300_d      2.078      0.16       1    40
# Comp:  2           [NII]6583_d      7.221      0.16       1    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        19         1
#  comp.  1:        10        30
#  comp.  2:        12        35
# chi2/DOF: 58.19; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      73.61      0.13      10    30
# Comp:  1                Halpha      263.4      0.13      10    30
# Comp:  2             [SII]6716      11.00      0.13      12    35
# Comp:  2             [SII]6731      7.526      0.13      12    35
# Comp:  2              HeII4687     0.5711      0.13      12    35
# Comp:  2               HeI5876      9.049      0.13      12    35
# Comp:  2          [OIII]5007_d      571.6      0.16      12    35
# Comp:  2            [OI]6300_d      2.159      0.16      12    35
# Comp:  2           [NII]6583_d      6.932      0.16      12    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       658       187
#  comp.  1:        12        23
#  comp.  2:         1        41
# chi2/DOF: 30.15; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 85; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.97      0.12      12    23
# Comp:  1                Halpha      257.4      0.12      12    23
# Comp:  2             [SII]6716      11.62      0.13       1    41
# Comp:  2             [SII]6731      7.714      0.13       1    41
# Comp:  2              HeII4687     0.4930      0.13       1    41
# Comp:  2               HeI5876      9.685      0.13       1    41
# Comp:  2          [OIII]5007_d      511.9      0.16       1    41
# Comp:  2            [OI]6300_d      2.073      0.16       1    41
# Comp:  2           [NII]6583_d      7.717      0.16       1    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:        11        23
#  comp.  2:         2        54
# chi2/DOF: 62.29; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      74.95      0.12      11    23
# Comp:  1                Halpha      257.1      0.12      11    23
# Comp:  2             [SII]6716      11.56      0.14       2    54
# Comp:  2             [SII]6731      7.747      0.14       2    54
# Comp:  2              HeII4687     0.6176      0.14       2    54
# Comp:  2               HeI5876      9.863      0.14       2    54
# Comp:  2          [OIII]5007_d      563.1      0.17       2    54
# Comp:  2            [OI]6300_d      2.385      0.17       2    54
# Comp:  2           [NII]6583_d      7.483      0.17       2    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       113       907
#  comp.  1:        11        23
#  comp.  2:        10        46
# chi2/DOF: 78.42; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      72.25      0.12      11    23
# Comp:  1                Halpha      254.2      0.12      11    23
# Comp:  2             [SII]6716      10.71      0.13      10    46
# Comp:  2             [SII]6731      7.610      0.13      10    46
# Comp:  2              HeII4687     0.3094      0.13      10    46
# Comp:  2               HeI5876      10.00      0.13      10    46
# Comp:  2          [OIII]5007_d      556.4      0.17      10    46
# Comp:  2            [OI]6300_d      2.328      0.17      10    46
# Comp:  2           [NII]6583_d      7.323      0.17      10    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47         1
#  comp.  1:         8        34
#  comp.  2:        -1        28
# chi2/DOF: 28.99; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      68.18      0.13       8    34
# Comp:  1                Halpha      269.0      0.13       8    34
# Comp:  2             [SII]6716      11.53      0.12      -1    28
# Comp:  2             [SII]6731      7.185      0.12      -1    28
# Comp:  2              HeII4687     0.2239      0.12      -1    28
# Comp:  2               HeI5876      9.151      0.12      -1    28
# Comp:  2          [OIII]5007_d      545.1      0.16      -1    28
# Comp:  2            [OI]6300_d      2.411      0.16      -1    28
# Comp:  2           [NII]6583_d      7.087      0.16      -1    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -248       589
#  comp.  1:         9        26
#  comp.  2:         6        54
# chi2/DOF: 53.13; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      68.44      0.12       9    26
# Comp:  1                Halpha      259.5      0.12       9    26
# Comp:  2             [SII]6716      12.64      0.14       6    54
# Comp:  2             [SII]6731      8.504      0.14       6    54
# Comp:  2              HeII4687     0.8692      0.14       6    54
# Comp:  2               HeI5876      10.58      0.14       6    54
# Comp:  2          [OIII]5007_d      546.4      0.17       6    54
# Comp:  2            [OI]6300_d      2.608      0.17       6    54
# Comp:  2           [NII]6583_d      7.598      0.17       6    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89         1
#  comp.  1:         8        35
#  comp.  2:         3        54
# chi2/DOF: 63.54; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      67.60      0.13       8    35
# Comp:  1                Halpha      267.3      0.13       8    35
# Comp:  2             [SII]6716      11.53      0.14       3    54
# Comp:  2             [SII]6731      7.676      0.14       3    54
# Comp:  2              HeII4687     0.4102      0.14       3    54
# Comp:  2               HeI5876      10.19      0.14       3    54
# Comp:  2          [OIII]5007_d      563.6      0.17       3    54
# Comp:  2            [OI]6300_d      2.406      0.17       3    54
# Comp:  2           [NII]6583_d      7.815      0.17       3    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:        12        21
#  comp.  2:        -3        29
# chi2/DOF: 17.15; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 3
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      62.58      0.12      12    21
# Comp:  1                Halpha      256.1      0.12      12    21
# Comp:  2             [SII]6716      9.629      0.13      -3    29
# Comp:  2             [SII]6731      7.520      0.13      -3    29
# Comp:  2              HeII4687     0.4247      0.13      -3    29
# Comp:  2               HeI5876      9.629      0.13      -3    29
# Comp:  2          [OIII]5007_d      552.3      0.16      -3    29
# Comp:  2            [OI]6300_d      1.985      0.16      -3    29
# Comp:  2           [NII]6583_d      6.983      0.16      -3    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:         9        33
#  comp.  2:         7        45
# chi2/DOF: 86.40; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      64.92      0.13       9    33
# Comp:  1                Halpha      267.5      0.13       9    33
# Comp:  2             [SII]6716      10.65      0.13       7    45
# Comp:  2             [SII]6731      7.853      0.13       7    45
# Comp:  2              HeII4687     0.4497      0.13       7    45
# Comp:  2               HeI5876      9.838      0.13       7    45
# Comp:  2          [OIII]5007_d      562.9      0.17       7    45
# Comp:  2            [OI]6300_d      2.094      0.17       7    45
# Comp:  2           [NII]6583_d      7.225      0.17       7    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        82         1
#  comp.  1:        11        22
#  comp.  2:         3        55
# chi2/DOF: 63.27; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.18      0.12      11    22
# Comp:  1                Halpha      255.3      0.12      11    22
# Comp:  2             [SII]6716      11.46      0.14       3    55
# Comp:  2             [SII]6731      8.125      0.14       3    55
# Comp:  2              HeII4687     0.4334      0.14       3    55
# Comp:  2               HeI5876      9.505      0.14       3    55
# Comp:  2          [OIII]5007_d      569.2      0.17       3    55
# Comp:  2            [OI]6300_d      2.040      0.17       3    55
# Comp:  2           [NII]6583_d      7.608      0.17       3    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:        10        29
#  comp.  2:         6        57
# chi2/DOF: 41.99; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      71.74      0.12      10    29
# Comp:  1                Halpha      261.8      0.12      10    29
# Comp:  2             [SII]6716      10.65      0.14       6    57
# Comp:  2             [SII]6731      7.791      0.14       6    57
# Comp:  2              HeII4687     0.3136      0.14       6    57
# Comp:  2               HeI5876      10.83      0.14       6    57
# Comp:  2          [OIII]5007_d      550.1      0.17       6    57
# Comp:  2            [OI]6300_d      2.150      0.17       6    57
# Comp:  2           [NII]6583_d      7.616      0.17       6    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        51         1
#  comp.  1:        10        32
#  comp.  2:        -2        29
# chi2/DOF: 25.91; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      69.16      0.13      10    32
# Comp:  1                Halpha      264.9      0.13      10    32
# Comp:  2             [SII]6716      10.35      0.12      -2    29
# Comp:  2             [SII]6731      7.314      0.12      -2    29
# Comp:  2              HeII4687     0.6706      0.12      -2    29
# Comp:  2               HeI5876      9.687      0.12      -2    29
# Comp:  2          [OIII]5007_d      547.5      0.16      -2    29
# Comp:  2            [OI]6300_d      2.137      0.16      -2    29
# Comp:  2           [NII]6583_d      6.979      0.16      -2    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -2001         1
#  comp.  1:        10        27
#  comp.  2:         3        46
# chi2/DOF: 75.85; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      68.04      0.12      10    27
# Comp:  1                Halpha      262.6      0.12      10    27
# Comp:  2             [SII]6716      11.21      0.13       3    46
# Comp:  2             [SII]6731      8.101      0.13       3    46
# Comp:  2              HeII4687     0.5316      0.13       3    46
# Comp:  2               HeI5876      9.204      0.13       3    46
# Comp:  2          [OIII]5007_d      595.0      0.17       3    46
# Comp:  2            [OI]6300_d      2.127      0.17       3    46
# Comp:  2           [NII]6583_d      7.330      0.17       3    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       995      1000
#  comp.  1:        10        23
#  comp.  2:        11        50
# chi2/DOF: 23.69; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      73.42      0.12      10    23
# Comp:  1                Halpha      254.8      0.12      10    23
# Comp:  2             [SII]6716      11.39      0.13      11    50
# Comp:  2             [SII]6731      7.632      0.13      11    50
# Comp:  2              HeII4687     0.5881      0.13      11    50
# Comp:  2               HeI5876      9.436      0.13      11    50
# Comp:  2          [OIII]5007_d      639.3      0.17      11    50
# Comp:  2            [OI]6300_d      2.181      0.17      11    50
# Comp:  2           [NII]6583_d      7.369      0.17      11    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3         1
#  comp.  1:         8        33
#  comp.  2:        -4        41
# chi2/DOF: 25.85; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      76.82      0.13       8    33
# Comp:  1                Halpha      267.6      0.13       8    33
# Comp:  2             [SII]6716      10.05      0.13      -4    41
# Comp:  2             [SII]6731      7.990      0.13      -4    41
# Comp:  2              HeII4687     0.5045      0.13      -4    41
# Comp:  2               HeI5876      10.37      0.13      -4    41
# Comp:  2          [OIII]5007_d      531.8      0.16      -4    41
# Comp:  2            [OI]6300_d      2.348      0.16      -4    41
# Comp:  2           [NII]6583_d      7.342      0.16      -4    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       745      1000
#  comp.  1:         9        32
#  comp.  2:         4        44
# chi2/DOF: 78.51; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      75.13      0.13       9    32
# Comp:  1                Halpha      261.6      0.13       9    32
# Comp:  2             [SII]6716      10.95      0.13       4    44
# Comp:  2             [SII]6731      7.434      0.13       4    44
# Comp:  2              HeII4687     0.5876      0.13       4    44
# Comp:  2               HeI5876      10.12      0.13       4    44
# Comp:  2          [OIII]5007_d      588.5      0.17       4    44
# Comp:  2            [OI]6300_d      2.103      0.17       4    44
# Comp:  2           [NII]6583_d      7.336      0.17       4    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       188         1
#  comp.  1:        12        22
#  comp.  2:         7        37
# chi2/DOF: 43.21; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      64.48      0.12      12    22
# Comp:  1                Halpha      256.0      0.12      12    22
# Comp:  2             [SII]6716      10.75      0.13       7    37
# Comp:  2             [SII]6731      7.961      0.13       7    37
# Comp:  2              HeII4687     0.4662      0.13       7    37
# Comp:  2               HeI5876      9.524      0.13       7    37
# Comp:  2          [OIII]5007_d      597.3      0.16       7    37
# Comp:  2            [OI]6300_d      2.123      0.16       7    37
# Comp:  2           [NII]6583_d      7.391      0.16       7    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       121       514
#  comp.  1:         9        30
#  comp.  2:        10        47
# chi2/DOF: 80.83; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      76.28      0.13       9    30
# Comp:  1                Halpha      261.8      0.13       9    30
# Comp:  2             [SII]6716      12.55      0.13      10    47
# Comp:  2             [SII]6731      7.800      0.13      10    47
# Comp:  2              HeII4687     0.5071      0.13      10    47
# Comp:  2               HeI5876      10.51      0.13      10    47
# Comp:  2          [OIII]5007_d      562.3      0.17      10    47
# Comp:  2            [OI]6300_d      2.607      0.17      10    47
# Comp:  2           [NII]6583_d      7.540      0.17      10    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        43      1000
#  comp.  1:         9        30
#  comp.  2:        12        50
# chi2/DOF: 23.70; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      73.08      0.13       9    30
# Comp:  1                Halpha      260.3      0.13       9    30
# Comp:  2             [SII]6716      10.55      0.13      12    50
# Comp:  2             [SII]6731      7.881      0.13      12    50
# Comp:  2              HeII4687     0.7119      0.13      12    50
# Comp:  2               HeI5876      11.09      0.13      12    50
# Comp:  2          [OIII]5007_d      635.5      0.17      12    50
# Comp:  2            [OI]6300_d      2.203      0.17      12    50
# Comp:  2           [NII]6583_d      7.222      0.17      12    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       159         1
#  comp.  1:         9        32
#  comp.  2:         7        36
# chi2/DOF: 43.18; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 94; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      74.12      0.13       9    32
# Comp:  1                Halpha      268.2      0.13       9    32
# Comp:  2             [SII]6716      9.947      0.13       7    36
# Comp:  2             [SII]6731      7.273      0.13       7    36
# Comp:  2              HeII4687     0.2955      0.13       7    36
# Comp:  2               HeI5876      9.794      0.13       7    36
# Comp:  2          [OIII]5007_d      596.1      0.16       7    36
# Comp:  2            [OI]6300_d      2.096      0.16       7    36
# Comp:  2           [NII]6583_d      7.319      0.16       7    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         6         1
#  comp.  1:        11        25
#  comp.  2:        11        38
# chi2/DOF: 67.62; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      66.06      0.12      11    25
# Comp:  1                Halpha      261.1      0.12      11    25
# Comp:  2             [SII]6716      10.34      0.13      11    38
# Comp:  2             [SII]6731      7.410      0.13      11    38
# Comp:  2              HeII4687     0.4623      0.13      11    38
# Comp:  2               HeI5876      10.09      0.13      11    38
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      71.39      0.12      11    21
# Comp:  1                Halpha      254.2      0.12      11    21
# Comp:  2             [SII]6716      11.34      0.13       7    47
# Comp:  2             [SII]6731      7.640      0.13       7    47
# Comp:  2              HeII4687     0.2542      0.13       7    47
# Comp:  2               HeI5876      8.805      0.13       7    47
# Comp:  2          [OIII]5007_d      566.3      0.17       7    47
# Comp:  2            [OI]6300_d      2.644      0.17       7    47
# Comp:  2           [NII]6583_d      7.685      0.17       7    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       142         1
#  comp.  1:        10        30
#  comp.  2:        11        36
# chi2/DOF: 56.32; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      74.04      0.13      10    30
# Comp:  1                Halpha      261.2      0.13      10    30
# Comp:  2             [SII]6716      10.16      0.13      11    36
# Comp:  2             [SII]6731      7.493      0.13      11    36
# Comp:  2              HeII4687     0.3544      0.13      11    36
# Comp:  2               HeI5876      9.551      0.13      11    36
# Comp:  2          [OIII]5007_d      578.0      0.16      11    36
# Comp:  2            [OI]6300_d      2.071      0.16      11    36
# Comp:  2           [NII]6583_d      7.371      0.16      11    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -248      1000
#  comp.  1:         9        26
#  comp.  2:         7        55
# chi2/DOF: 53.00; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 25; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      74.07      0.12       9    26
# Comp:  1                Halpha      259.9      0.12       9    26
# Comp:  2             [SII]6716      12.42      0.14       7    55
# Comp:  2             [SII]6731      8.150      0.14       7    55
# Comp:  2              HeII4687     0.5238      0.14       7    55
# Comp:  2               HeI5876      10.57      0.14       7    55
# Comp:  2          [OIII]5007_d      548.6      0.17       7    55
# Comp:  2            [OI]6300_d      2.459      0.17       7    55
# Comp:  2           [NII]6583_d      7.533      0.17       7    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:         9        27
#  comp.  2:         6        46
# chi2/DOF: 89.12; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      73.23      0.12       9    27
# Comp:  1                Halpha      259.4      0.12       9    27
# Comp:  2             [SII]6716      11.31      0.13       6    46
# Comp:  2             [SII]6731      7.900      0.13       6    46
# Comp:  2              HeII4687     0.6004      0.13       6    46
# Comp:  2               HeI5876      9.636      0.13       6    46
# Comp:  2          [OIII]5007_d      573.3      0.17       6    46
# Comp:  2            [OI]6300_d      2.366      0.17       6    46
# Comp:  2           [NII]6583_d      7.535      0.17       6    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        97
#  comp.  1:        10        24
#  comp.  2:        -5        40
# chi2/DOF: 19.76; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      73.13      0.12      10    24
# Comp:  1                Halpha      261.5      0.12      10    24
# Comp:  2             [SII]6716      11.55      0.13      -5    40
# Comp:  2             [SII]6731      7.418      0.13      -5    40
# Comp:  2              HeII4687     0.4513      0.13      -5    40
# Comp:  2               HeI5876      9.355      0.13      -5    40
# Comp:  2          [OIII]5007_d      533.6      0.16      -5    40
# Comp:  2            [OI]6300_d      2.135      0.16      -5    40
# Comp:  2           [NII]6583_d      7.438      0.16      -5    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26       272
#  comp.  1:        10        26
#  comp.  2:        11        59
# chi2/DOF: 45.97; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      75.59      0.12      10    26
# Comp:  1                Halpha      261.2      0.12      10    26
# Comp:  2             [SII]6716      11.71      0.14      11    59
# Comp:  2             [SII]6731      8.476      0.14      11    59
# Comp:  2              HeII4687     0.1739      0.14      11    59
# Comp:  2               HeI5876      9.581      0.14      11    59
# Comp:  2          [OIII]5007_d      623.2      0.17      11    59
# Comp:  2            [OI]6300_d      2.804      0.17      11    59
# Comp:  2           [NII]6583_d      8.087      0.17      11    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:        10        26
#  comp.  2:         6        48
# chi2/DOF: 88.73; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      67.18      0.12      10    26
# Comp:  1                Halpha      259.5      0.12      10    26
# Comp:  2             [SII]6716      10.43      0.13       6    48
# Comp:  2             [SII]6731      7.894      0.13       6    48
# Comp:  2              HeII4687     0.2671      0.13       6    48
# Comp:  2               HeI5876      10.26      0.13       6    48
# Comp:  2          [OIII]5007_d      575.5      0.17       6    48
# Comp:  2            [OI]6300_d      2.719      0.17       6    48
# Comp:  2           [NII]6583_d      7.232      0.17       6    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       159         1
#  comp.  1:         8        33
#  comp.  2:         7        37
# chi2/DOF: 44.06; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 93; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      74.42      0.13       8    33
# Comp:  1                Halpha      266.5      0.13       8    33
# Comp:  2             [SII]6716      11.17      0.13       7    37
# Comp:  2             [SII]6731      7.538      0.13       7    37
# Comp:  2              HeII4687     0.4206      0.13       7    37
# Comp:  2               HeI5876      9.373      0.13       7    37
# Comp:  2          [OIII]5007_d      597.9      0.16       7    37
# Comp:  2            [OI]6300_d      2.159      0.16       7    37
# Comp:  2           [NII]6583_d      7.531      0.16       7    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4       135
#  comp.  1:        10        25
#  comp.  2:         9        48
# chi2/DOF: 82.48; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      72.64      0.12      10    25
# Comp:  1                Halpha      260.7      0.12      10    25
# Comp:  2             [SII]6716      11.41      0.13       9    48
# Comp:  2             [SII]6731      7.712      0.13       9    48
# Comp:  2              HeII4687     0.7033      0.13       9    48
# Comp:  2               HeI5876      9.208      0.13       9    48
# Comp:  2          [OIII]5007_d      560.3      0.17       9    48
# Comp:  2            [OI]6300_d      2.263      0.17       9    48
# Comp:  2           [NII]6583_d      7.501      0.17       9    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5      1000
#  comp.  1:        11        25
#  comp.  2:        11        49
# chi2/DOF: 27.02; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      65.12      0.12      11    25
# Comp:  1                Halpha      261.3      0.12      11    25
# Comp:  2             [SII]6716      11.07      0.13      11    49
# Comp:  2             [SII]6731      7.897      0.13      11    49
# Comp:  2              HeII4687     0.7990      0.13      11    49
# Comp:  2               HeI5876      9.324      0.13      11    49
# Comp:  2          [OIII]5007_d      634.9      0.17      11    49
# Comp:  2            [OI]6300_d      2.184      0.17      11    49
# Comp:  2           [NII]6583_d      7.513      0.17      11    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:     -2001         1
#  comp.  1:        10        25
#  comp.  2:         5        47
# chi2/DOF: 88.33; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      72.87      0.12      10    25
# Comp:  1                Halpha      259.1      0.12      10    25
# Comp:  2             [SII]6716      10.19      0.13       5    47
# Comp:  2             [SII]6731      7.982      0.13       5    47
# Comp:  2              HeII4687     0.4838      0.13       5    47
# Comp:  2               HeI5876      9.772      0.13       5    47
# Comp:  2          [OIII]5007_d      574.5      0.17       5    47
# Comp:  2            [OI]6300_d      2.059      0.17       5    47
# Comp:  2           [NII]6583_d      7.150      0.17       5    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0         1
#  comp.  1:        10        25
#  comp.  2:         9        47
# chi2/DOF: 83.37; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      72.70      0.12      10    25
# Comp:  1                Halpha      261.4      0.12      10    25
# Comp:  2             [SII]6716      11.14      0.13       9    47
# Comp:  2             [SII]6731      8.141      0.13       9    47
# Comp:  2              HeII4687     0.4072      0.13       9    47
# Comp:  2               HeI5876      9.515      0.13       9    47
# Comp:  2          [OIII]5007_d      560.2      0.17       9    47
# Comp:  2            [OI]6300_d      1.956      0.17       9    47
# Comp:  2           [NII]6583_d      7.533      0.17       9    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       129         1
#  comp.  1:         9        27
#  comp.  2:         7        36
# chi2/DOF: 50.38; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      75.46      0.12       9    27
# Comp:  1                Halpha      259.6      0.12       9    27
# Comp:  2             [SII]6716      10.04      0.13       7    36
# Comp:  2             [SII]6731      7.605      0.13       7    36
# Comp:  2              HeII4687     0.4329      0.13       7    36
# Comp:  2               HeI5876      10.11      0.13       7    36
# Comp:  2          [OIII]5007_d      590.4      0.16       7    36
# Comp:  2            [OI]6300_d      2.422      0.16       7    36
# Comp:  2           [NII]6583_d      7.221      0.16       7    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11         1
#  comp.  1:        12        22
#  comp.  2:         6        55
# chi2/DOF: 48.59; DOF: 2231; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/159
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                 Hbeta      63.95      0.12      12    22
# Comp:  1                Halpha      253.4      0.12      12    22
# Comp:  2             [SII]6716      11.05      0.14       6    55
# Comp:  2             [SII]6731      8.014      0.14       6    55
# Comp:  2              HeII4687     0.5874      0.14       6    55
# Comp:  2               HeI5876      10.23      0.14       6    55
# Comp:  2          [OIII]5007_d      549.1      0.17       6    55
# Comp:  2            [OI]6300_d      2.342      0.17       6    55
# Comp:  2           [NII]6583_d      7.654      0.17       6    55
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([ 4.06195475,  6.11010382,  1.00353828,  0.44468744,  0.15648051,
#         0.77600666, 34.12378882,  0.25913125,  0.40473811])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([7.03476599e+01, 3.56809746e+02, 1.57001008e+01, 1.09885715e+01,
#        4.43808687e-01, 1.19532625e+01, 5.97958603e+02, 3.01085035e+00,
#        1.00637844e+01])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_4_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_4_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_4_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_4_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_4_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name        Flux  Error flux
# 0         Hbeta   25.190503    1.454529
# 1        Halpha  127.768526    2.187942
# 2     [SII]6716    5.621984    0.359353
# 3     [SII]6731    3.934852    0.159236
# 4      HeII4687    0.158922    0.056033
# 5       HeI5876    4.280294    0.277877
# 6  [OIII]5007_d  214.120523   12.219246
# 7    [OI]6300_d    1.078143    0.092791
# 8   [NII]6583_d    3.603699    0.144931
#           Name        Flux  Error_flux
# 0        Hbeta   25.190503    1.454529
# 1       Halpha  127.768526    2.187942
# 2    [SII]6716    5.621984    0.359353
# 3    [SII]6731    3.934852    0.159236
# 4     HeII4687    0.158922    0.056033
# 5      HeI5876    4.280294    0.277877
# 6   [OIII]4959   53.530131   12.219246
# 7   [OIII]5007  160.590392   12.219246
# 8     [OI]6300    0.808607    0.092791
# 9     [OI]6364    0.269536    0.092791
# 10   [NII]6548    0.900925    0.144931
# 11   [NII]6583    2.702774    0.144931

# %%
np.median(flux_rf_rebin)
# Out:
# 0.35808586349943966
