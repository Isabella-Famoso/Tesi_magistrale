# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_1s_3.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/Spectra_extraction/redshift.txt") 
z = red[2][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_1s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.03156

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15846873 2.15918609 2.15990345 ... 3.43823917 3.43895653 3.43967389]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3161, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         7        76
# chi2/DOF: 0.002309; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:        11        73
# chi2/DOF: 0.001933; DOF: 1886; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([11.10985035, 73.49712505])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        71
#  comp.  1:        -2         9
#  comp.  2:         0        22
# chi2/DOF: 1.001; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.996      0.11      -2     9
# Comp:  1                 Hbeta      10.41      0.11      -2     9
# Comp:  1                Halpha      36.01      0.11      -2     9
# Comp:  2             [SII]6716      5.738      0.11       0    22
# Comp:  2             [SII]6731      4.039      0.11       0    22
# Comp:  2              HeII4687      0.000      0.11       0    22
# Comp:  2               HeI5876      1.360      0.11       0    22
# Comp:  2          [OIII]5007_d      3.498      0.15       0    22
# Comp:  2            [OI]6300_d     0.9103      0.15       0    22
# Comp:  2           [NII]6583_d      15.40      0.15       0    22
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  30.13; gas flux:      4 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  78.76; gas flux:     11 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  257.5; gas flux:     49 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  39.65; gas flux:      8 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  29.77; gas flux:      6 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  10.08; gas flux:      2 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  19.85; gas flux:      4 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  5.128; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  82.37; gas flux:     21 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        89
#  comp.  1:        -2         1
#  comp.  2:         1        26
# chi2/DOF: 0.9277; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.590      0.11      -2     1
# Comp:  1                 Hbeta      10.56      0.11      -2     1
# Comp:  1                Halpha      36.73      0.11      -2     1
# Comp:  2             [SII]6716      5.488      0.12       1    26
# Comp:  2             [SII]6731      4.242      0.12       1    26
# Comp:  2              HeII4687    0.04781      0.12       1    26
# Comp:  2               HeI5876      1.514      0.12       1    26
# Comp:  2          [OIII]5007_d      3.413      0.15       1    26
# Comp:  2            [OI]6300_d     0.9805      0.15       1    26
# Comp:  2           [NII]6583_d      15.82      0.15       1    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        62
#  comp.  1:        -3        12
#  comp.  2:        -0        27
# chi2/DOF: 0.9089; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.423      0.11      -3    12
# Comp:  1                 Hbeta      9.209      0.11      -3    12
# Comp:  1                Halpha      36.96      0.11      -3    12
# Comp:  2             [SII]6716      5.820      0.12      -0    27
# Comp:  2             [SII]6731      4.158      0.12      -0    27
# Comp:  2              HeII4687    0.02751      0.12      -0    27
# Comp:  2               HeI5876      1.348      0.12      -0    27
# Comp:  2          [OIII]5007_d      3.670      0.15      -0    27
# Comp:  2            [OI]6300_d     0.9186      0.15      -0    27
# Comp:  2           [NII]6583_d      15.71      0.15      -0    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        65
#  comp.  1:        -2         6
#  comp.  2:        -1        18
# chi2/DOF: 0.8855; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.012      0.11      -2     6
# Comp:  1                 Hbeta      11.94      0.11      -2     6
# Comp:  1                Halpha      36.22      0.11      -2     6
# Comp:  2             [SII]6716      5.515      0.11      -1    18
# Comp:  2             [SII]6731      3.923      0.11      -1    18
# Comp:  2              HeII4687      0.000      0.11      -1    18
# Comp:  2               HeI5876      1.471      0.11      -1    18
# Comp:  2          [OIII]5007_d      3.313      0.14      -1    18
# Comp:  2            [OI]6300_d     0.9178      0.14      -1    18
# Comp:  2           [NII]6583_d      15.19      0.14      -1    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        30
#  comp.  1:        -2        14
#  comp.  2:        -1        12
# chi2/DOF: 0.9720; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.732      0.11      -2    14
# Comp:  1                 Hbeta      10.65      0.11      -2    14
# Comp:  1                Halpha      36.34      0.11      -2    14
# Comp:  2             [SII]6716      5.644      0.11      -1    12
# Comp:  2             [SII]6731      3.990      0.11      -1    12
# Comp:  2              HeII4687    0.07843      0.11      -1    12
# Comp:  2               HeI5876      1.458      0.11      -1    12
# Comp:  2          [OIII]5007_d      3.156      0.14      -1    12
# Comp:  2            [OI]6300_d     0.9274      0.14      -1    12
# Comp:  2           [NII]6583_d      15.00      0.14      -1    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        76
#  comp.  1:        -1         1
#  comp.  2:         1        24
# chi2/DOF: 0.9185; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.894      0.11      -1     1
# Comp:  1                 Hbeta      8.991      0.11      -1     1
# Comp:  1                Halpha      35.66      0.11      -1     1
# Comp:  2             [SII]6716      6.043      0.12       1    24
# Comp:  2             [SII]6731      4.344      0.12       1    24
# Comp:  2              HeII4687      0.000      0.12       1    24
# Comp:  2               HeI5876      1.513      0.12       1    24
# Comp:  2          [OIII]5007_d      3.709      0.15       1    24
# Comp:  2            [OI]6300_d     0.9656      0.15       1    24
# Comp:  2           [NII]6583_d      15.56      0.15       1    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10        81
#  comp.  1:        -2        11
#  comp.  2:         0        29
# chi2/DOF: 0.8762; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.254      0.11      -2    11
# Comp:  1                 Hbeta      9.737      0.11      -2    11
# Comp:  1                Halpha      35.63      0.11      -2    11
# Comp:  2             [SII]6716      6.250      0.12       0    29
# Comp:  2             [SII]6731      4.401      0.12       0    29
# Comp:  2              HeII4687      0.000      0.12       0    29
# Comp:  2               HeI5876      1.415      0.12       0    29
# Comp:  2          [OIII]5007_d      3.699      0.15       0    29
# Comp:  2            [OI]6300_d     0.8525      0.15       0    29
# Comp:  2           [NII]6583_d      15.75      0.15       0    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        77
#  comp.  1:         0         9
#  comp.  2:         0        14
# chi2/DOF: 0.8971; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.154      0.11       0     9
# Comp:  1                 Hbeta      11.63      0.11       0     9
# Comp:  1                Halpha      36.08      0.11       0     9
# Comp:  2             [SII]6716      5.493      0.11       0    14
# Comp:  2             [SII]6731      3.742      0.11       0    14
# Comp:  2              HeII4687      0.000      0.11       0    14
# Comp:  2               HeI5876      1.329      0.11       0    14
# Comp:  2          [OIII]5007_d      3.371      0.14       0    14
# Comp:  2            [OI]6300_d     0.8691      0.14       0    14
# Comp:  2           [NII]6583_d      14.98      0.14       0    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        85
#  comp.  1:         1         6
#  comp.  2:         1        18
# chi2/DOF: 0.9111; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.775      0.11       1     6
# Comp:  1                 Hbeta      11.00      0.11       1     6
# Comp:  1                Halpha      35.67      0.11       1     6
# Comp:  2             [SII]6716      5.391      0.11       1    18
# Comp:  2             [SII]6731      3.718      0.11       1    18
# Comp:  2              HeII4687    0.03557      0.11       1    18
# Comp:  2               HeI5876      1.378      0.11       1    18
# Comp:  2          [OIII]5007_d      3.387      0.14       1    18
# Comp:  2            [OI]6300_d     0.8807      0.14       1    18
# Comp:  2           [NII]6583_d      15.27      0.14       1    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        19        54
#  comp.  1:        -3        19
#  comp.  2:         2        23
# chi2/DOF: 0.8725; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.034      0.11      -3    19
# Comp:  1                 Hbeta      9.595      0.11      -3    19
# Comp:  1                Halpha      35.82      0.11      -3    19
# Comp:  2             [SII]6716      5.603      0.12       2    23
# Comp:  2             [SII]6731      4.019      0.12       2    23
# Comp:  2              HeII4687    0.06754      0.12       2    23
# Comp:  2               HeI5876      1.416      0.12       2    23
# Comp:  2          [OIII]5007_d      3.927      0.15       2    23
# Comp:  2            [OI]6300_d     0.8821      0.15       2    23
# Comp:  2           [NII]6583_d      15.43      0.15       2    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9       109
#  comp.  1:        -3         1
#  comp.  2:        -1        23
# chi2/DOF: 0.8982; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.629      0.11      -3     1
# Comp:  1                 Hbeta      9.205      0.11      -3     1
# Comp:  1                Halpha      35.93      0.11      -3     1
# Comp:  2             [SII]6716      6.165      0.12      -1    23
# Comp:  2             [SII]6731      4.296      0.12      -1    23
# Comp:  2              HeII4687      0.000      0.12      -1    23
# Comp:  2               HeI5876      1.518      0.12      -1    23
# Comp:  2          [OIII]5007_d      3.617      0.15      -1    23
# Comp:  2            [OI]6300_d     0.8559      0.15      -1    23
# Comp:  2           [NII]6583_d      15.41      0.15      -1    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        73
#  comp.  1:        -2         1
#  comp.  2:         2        23
# chi2/DOF: 0.9081; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.837      0.11      -2     1
# Comp:  1                 Hbeta      9.583      0.11      -2     1
# Comp:  1                Halpha      36.76      0.11      -2     1
# Comp:  2             [SII]6716      5.889      0.12       2    23
# Comp:  2             [SII]6731      3.968      0.12       2    23
# Comp:  2              HeII4687    0.03985      0.12       2    23
# Comp:  2               HeI5876      1.345      0.12       2    23
# Comp:  2          [OIII]5007_d      3.473      0.15       2    23
# Comp:  2            [OI]6300_d     0.9208      0.15       2    23
# Comp:  2           [NII]6583_d      15.50      0.15       2    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        65
#  comp.  1:        -2         6
#  comp.  2:        -1        17
# chi2/DOF: 0.9308; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.581      0.11      -2     6
# Comp:  1                 Hbeta      11.44      0.11      -2     6
# Comp:  1                Halpha      36.83      0.11      -2     6
# Comp:  2             [SII]6716      5.385      0.11      -1    17
# Comp:  2             [SII]6731      3.800      0.11      -1    17
# Comp:  2              HeII4687      0.000      0.11      -1    17
# Comp:  2               HeI5876      1.349      0.11      -1    17
# Comp:  2          [OIII]5007_d      3.565      0.14      -1    17
# Comp:  2            [OI]6300_d     0.8886      0.14      -1    17
# Comp:  2           [NII]6583_d      15.05      0.14      -1    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        97
#  comp.  1:        -1         1
#  comp.  2:        -2        23
# chi2/DOF: 0.9622; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.142      0.11      -1     1
# Comp:  1                 Hbeta      10.86      0.11      -1     1
# Comp:  1                Halpha      35.85      0.11      -1     1
# Comp:  2             [SII]6716      5.886      0.12      -2    23
# Comp:  2             [SII]6731      3.860      0.12      -2    23
# Comp:  2              HeII4687      0.000      0.12      -2    23
# Comp:  2               HeI5876      1.343      0.12      -2    23
# Comp:  2          [OIII]5007_d      3.796      0.15      -2    23
# Comp:  2            [OI]6300_d     0.9428      0.15      -2    23
# Comp:  2           [NII]6583_d      15.44      0.15      -2    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        39
#  comp.  1:        -2        21
#  comp.  2:         3        27
# chi2/DOF: 0.8907; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.391      0.11      -2    21
# Comp:  1                 Hbeta      11.80      0.11      -2    21
# Comp:  1                Halpha      36.12      0.11      -2    21
# Comp:  2             [SII]6716      5.499      0.12       3    27
# Comp:  2             [SII]6731      4.100      0.12       3    27
# Comp:  2              HeII4687      0.000      0.12       3    27
# Comp:  2               HeI5876      1.435      0.12       3    27
# Comp:  2          [OIII]5007_d      3.481      0.15       3    27
# Comp:  2            [OI]6300_d     0.9830      0.15       3    27
# Comp:  2           [NII]6583_d      15.73      0.15       3    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        61
#  comp.  1:        -2         6
#  comp.  2:        -0         7
# chi2/DOF: 0.9510; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.017      0.11      -2     6
# Comp:  1                 Hbeta      10.46      0.11      -2     6
# Comp:  1                Halpha      35.10      0.11      -2     6
# Comp:  2             [SII]6716      5.168      0.11      -0     7
# Comp:  2             [SII]6731      3.626      0.11      -0     7
# Comp:  2              HeII4687      0.000      0.11      -0     7
# Comp:  2               HeI5876      1.295      0.11      -0     7
# Comp:  2          [OIII]5007_d      3.205      0.14      -0     7
# Comp:  2            [OI]6300_d     0.8991      0.14      -0     7
# Comp:  2           [NII]6583_d      14.90      0.14      -0     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15       111
#  comp.  1:        -1         1
#  comp.  2:        -0        13
# chi2/DOF: 0.9247; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.443      0.11      -1     1
# Comp:  1                 Hbeta      10.96      0.11      -1     1
# Comp:  1                Halpha      35.88      0.11      -1     1
# Comp:  2             [SII]6716      5.807      0.11      -0    13
# Comp:  2             [SII]6731      3.899      0.11      -0    13
# Comp:  2              HeII4687    0.01039      0.11      -0    13
# Comp:  2               HeI5876      1.319      0.11      -0    13
# Comp:  2          [OIII]5007_d      3.426      0.14      -0    13
# Comp:  2            [OI]6300_d     0.9058      0.14      -0    13
# Comp:  2           [NII]6583_d      14.98      0.14      -0    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        88
#  comp.  1:        -1         1
#  comp.  2:        -2        18
# chi2/DOF: 0.8881; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.086      0.11      -1     1
# Comp:  1                 Hbeta      11.82      0.11      -1     1
# Comp:  1                Halpha      36.94      0.11      -1     1
# Comp:  2             [SII]6716      5.808      0.11      -2    18
# Comp:  2             [SII]6731      4.148      0.11      -2    18
# Comp:  2              HeII4687    0.04648      0.11      -2    18
# Comp:  2               HeI5876      1.493      0.11      -2    18
# Comp:  2          [OIII]5007_d      3.605      0.14      -2    18
# Comp:  2            [OI]6300_d     0.8977      0.14      -2    18
# Comp:  2           [NII]6583_d      15.36      0.14      -2    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        80
#  comp.  1:        -1         1
#  comp.  2:        -1        24
# chi2/DOF: 0.9195; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.507      0.11      -1     1
# Comp:  1                 Hbeta      10.03      0.11      -1     1
# Comp:  1                Halpha      36.65      0.11      -1     1
# Comp:  2             [SII]6716      5.819      0.12      -1    24
# Comp:  2             [SII]6731      4.023      0.12      -1    24
# Comp:  2              HeII4687      0.000      0.12      -1    24
# Comp:  2               HeI5876      1.511      0.12      -1    24
# Comp:  2          [OIII]5007_d      3.961      0.15      -1    24
# Comp:  2            [OI]6300_d     0.9031      0.15      -1    24
# Comp:  2           [NII]6583_d      15.39      0.15      -1    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3        88
#  comp.  1:        -0        17
#  comp.  2:        -2        19
# chi2/DOF: 0.9576; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.630      0.11      -0    17
# Comp:  1                 Hbeta      10.08      0.11      -0    17
# Comp:  1                Halpha      36.26      0.11      -0    17
# Comp:  2             [SII]6716      5.831      0.11      -2    19
# Comp:  2             [SII]6731      4.011      0.11      -2    19
# Comp:  2              HeII4687      0.000      0.11      -2    19
# Comp:  2               HeI5876      1.224      0.11      -2    19
# Comp:  2          [OIII]5007_d      3.406      0.14      -2    19
# Comp:  2            [OI]6300_d     0.8680      0.14      -2    19
# Comp:  2           [NII]6583_d      15.27      0.14      -2    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        82
#  comp.  1:        -2         1
#  comp.  2:         0        25
# chi2/DOF: 0.9395; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.296      0.11      -2     1
# Comp:  1                 Hbeta      11.00      0.11      -2     1
# Comp:  1                Halpha      36.82      0.11      -2     1
# Comp:  2             [SII]6716      5.886      0.12       0    25
# Comp:  2             [SII]6731      4.239      0.12       0    25
# Comp:  2              HeII4687   0.003012      0.12       0    25
# Comp:  2               HeI5876      1.242      0.12       0    25
# Comp:  2          [OIII]5007_d      3.267      0.15       0    25
# Comp:  2            [OI]6300_d     0.9058      0.15       0    25
# Comp:  2           [NII]6583_d      15.65      0.15       0    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        80
#  comp.  1:        -3         1
#  comp.  2:         1        21
# chi2/DOF: 0.9407; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.017      0.11      -3     1
# Comp:  1                 Hbeta      10.90      0.11      -3     1
# Comp:  1                Halpha      36.26      0.11      -3     1
# Comp:  2             [SII]6716      5.446      0.11       1    21
# Comp:  2             [SII]6731      4.044      0.11       1    21
# Comp:  2              HeII4687      0.000      0.11       1    21
# Comp:  2               HeI5876      1.383      0.11       1    21
# Comp:  2          [OIII]5007_d      3.919      0.14       1    21
# Comp:  2            [OI]6300_d     0.9175      0.14       1    21
# Comp:  2           [NII]6583_d      15.41      0.14       1    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        83
#  comp.  1:        -2         1
#  comp.  2:         2        25
# chi2/DOF: 0.8892; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.946      0.11      -2     1
# Comp:  1                 Hbeta      9.640      0.11      -2     1
# Comp:  1                Halpha      36.76      0.11      -2     1
# Comp:  2             [SII]6716      5.491      0.12       2    25
# Comp:  2             [SII]6731      4.372      0.12       2    25
# Comp:  2              HeII4687    0.04117      0.12       2    25
# Comp:  2               HeI5876      1.211      0.12       2    25
# Comp:  2          [OIII]5007_d      3.827      0.15       2    25
# Comp:  2            [OI]6300_d     0.9594      0.15       2    25
# Comp:  2           [NII]6583_d      15.62      0.15       2    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        52
#  comp.  1:        -2         7
#  comp.  2:         3        27
# chi2/DOF: 0.9456; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.734      0.11      -2     7
# Comp:  1                 Hbeta      10.55      0.11      -2     7
# Comp:  1                Halpha      36.81      0.11      -2     7
# Comp:  2             [SII]6716      5.566      0.12       3    27
# Comp:  2             [SII]6731      4.237      0.12       3    27
# Comp:  2              HeII4687      0.000      0.12       3    27
# Comp:  2               HeI5876      1.519      0.12       3    27
# Comp:  2          [OIII]5007_d      4.032      0.15       3    27
# Comp:  2            [OI]6300_d     0.9125      0.15       3    27
# Comp:  2           [NII]6583_d      15.58      0.15       3    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        85
#  comp.  1:         1         1
#  comp.  2:         2        28
# chi2/DOF: 0.8981; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.349      0.11       1     1
# Comp:  1                 Hbeta      11.26      0.11       1     1
# Comp:  1                Halpha      35.73      0.11       1     1
# Comp:  2             [SII]6716      5.839      0.12       2    28
# Comp:  2             [SII]6731      4.005      0.12       2    28
# Comp:  2              HeII4687   0.004908      0.12       2    28
# Comp:  2               HeI5876      1.509      0.12       2    28
# Comp:  2          [OIII]5007_d      3.648      0.15       2    28
# Comp:  2            [OI]6300_d     0.9243      0.15       2    28
# Comp:  2           [NII]6583_d      15.62      0.15       2    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5       109
#  comp.  1:        -3         1
#  comp.  2:         1        27
# chi2/DOF: 0.8796; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.694      0.11      -3     1
# Comp:  1                 Hbeta      9.392      0.11      -3     1
# Comp:  1                Halpha      36.85      0.11      -3     1
# Comp:  2             [SII]6716      5.593      0.12       1    27
# Comp:  2             [SII]6731      4.174      0.12       1    27
# Comp:  2              HeII4687    0.05626      0.12       1    27
# Comp:  2               HeI5876      1.269      0.12       1    27
# Comp:  2          [OIII]5007_d      3.424      0.15       1    27
# Comp:  2            [OI]6300_d     0.8874      0.15       1    27
# Comp:  2           [NII]6583_d      15.95      0.15       1    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        58
#  comp.  1:        -0        20
#  comp.  2:        -3        13
# chi2/DOF: 0.9266; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.728      0.11      -0    20
# Comp:  1                 Hbeta      10.30      0.11      -0    20
# Comp:  1                Halpha      36.54      0.11      -0    20
# Comp:  2             [SII]6716      5.905      0.11      -3    13
# Comp:  2             [SII]6731      4.053      0.11      -3    13
# Comp:  2              HeII4687     0.1253      0.11      -3    13
# Comp:  2               HeI5876      1.216      0.11      -3    13
# Comp:  2          [OIII]5007_d      3.545      0.14      -3    13
# Comp:  2            [OI]6300_d     0.8877      0.14      -3    13
# Comp:  2           [NII]6583_d      15.08      0.14      -3    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        67
#  comp.  1:        -2         7
#  comp.  2:         3        26
# chi2/DOF: 0.9018; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.911      0.11      -2     7
# Comp:  1                 Hbeta      11.82      0.11      -2     7
# Comp:  1                Halpha      36.16      0.11      -2     7
# Comp:  2             [SII]6716      5.669      0.12       3    26
# Comp:  2             [SII]6731      4.241      0.12       3    26
# Comp:  2              HeII4687    0.09591      0.12       3    26
# Comp:  2               HeI5876      1.257      0.12       3    26
# Comp:  2          [OIII]5007_d      3.655      0.15       3    26
# Comp:  2            [OI]6300_d     0.9192      0.15       3    26
# Comp:  2           [NII]6583_d      15.72      0.15       3    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        68
#  comp.  1:        -1        15
#  comp.  2:         2        27
# chi2/DOF: 0.9476; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.014      0.11      -1    15
# Comp:  1                 Hbeta      10.45      0.11      -1    15
# Comp:  1                Halpha      35.47      0.11      -1    15
# Comp:  2             [SII]6716      6.222      0.12       2    27
# Comp:  2             [SII]6731      3.762      0.12       2    27
# Comp:  2              HeII4687    0.01293      0.12       2    27
# Comp:  2               HeI5876      1.372      0.12       2    27
# Comp:  2          [OIII]5007_d      3.403      0.15       2    27
# Comp:  2            [OI]6300_d     0.8845      0.15       2    27
# Comp:  2           [NII]6583_d      15.62      0.15       2    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3        41
#  comp.  1:        -2        20
#  comp.  2:         1        25
# chi2/DOF: 0.8849; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.147      0.11      -2    20
# Comp:  1                 Hbeta      11.98      0.11      -2    20
# Comp:  1                Halpha      35.93      0.11      -2    20
# Comp:  2             [SII]6716      5.669      0.12       1    25
# Comp:  2             [SII]6731      4.106      0.12       1    25
# Comp:  2              HeII4687    0.05983      0.12       1    25
# Comp:  2               HeI5876      1.364      0.12       1    25
# Comp:  2          [OIII]5007_d      3.871      0.15       1    25
# Comp:  2            [OI]6300_d     0.8666      0.15       1    25
# Comp:  2           [NII]6583_d      15.51      0.15       1    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        69
#  comp.  1:        -4        14
#  comp.  2:         1        28
# chi2/DOF: 0.9493; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.495      0.11      -4    14
# Comp:  1                 Hbeta      10.82      0.11      -4    14
# Comp:  1                Halpha      36.61      0.11      -4    14
# Comp:  2             [SII]6716      6.121      0.12       1    28
# Comp:  2             [SII]6731      4.132      0.12       1    28
# Comp:  2              HeII4687      0.000      0.12       1    28
# Comp:  2               HeI5876      1.276      0.12       1    28
# Comp:  2          [OIII]5007_d      3.717      0.15       1    28
# Comp:  2            [OI]6300_d     0.9272      0.15       1    28
# Comp:  2           [NII]6583_d      15.78      0.15       1    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        66
#  comp.  1:         1         6
#  comp.  2:         2        25
# chi2/DOF: 0.9470; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.904      0.11       1     6
# Comp:  1                 Hbeta      9.864      0.11       1     6
# Comp:  1                Halpha      35.66      0.11       1     6
# Comp:  2             [SII]6716      5.746      0.12       2    25
# Comp:  2             [SII]6731      3.957      0.12       2    25
# Comp:  2              HeII4687      0.000      0.12       2    25
# Comp:  2               HeI5876      1.351      0.12       2    25
# Comp:  2          [OIII]5007_d      3.630      0.15       2    25
# Comp:  2            [OI]6300_d     0.9120      0.15       2    25
# Comp:  2           [NII]6583_d      15.42      0.15       2    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        48
#  comp.  1:        -3        15
#  comp.  2:        -1        16
# chi2/DOF: 0.8925; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.698      0.11      -3    15
# Comp:  1                 Hbeta      9.230      0.11      -3    15
# Comp:  1                Halpha      35.48      0.11      -3    15
# Comp:  2             [SII]6716      5.922      0.11      -1    16
# Comp:  2             [SII]6731      3.964      0.11      -1    16
# Comp:  2              HeII4687    0.04393      0.11      -1    16
# Comp:  2               HeI5876      1.331      0.11      -1    16
# Comp:  2          [OIII]5007_d      3.678      0.14      -1    16
# Comp:  2            [OI]6300_d     0.9175      0.14      -1    16
# Comp:  2           [NII]6583_d      15.09      0.14      -1    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        70
#  comp.  1:        -2         1
#  comp.  2:         2        22
# chi2/DOF: 0.8983; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.125      0.11      -2     1
# Comp:  1                 Hbeta      11.91      0.11      -2     1
# Comp:  1                Halpha      36.09      0.11      -2     1
# Comp:  2             [SII]6716      6.050      0.11       2    22
# Comp:  2             [SII]6731      4.093      0.11       2    22
# Comp:  2              HeII4687    0.05977      0.11       2    22
# Comp:  2               HeI5876      1.374      0.11       2    22
# Comp:  2          [OIII]5007_d      3.189      0.15       2    22
# Comp:  2            [OI]6300_d     0.8899      0.15       2    22
# Comp:  2           [NII]6583_d      15.57      0.15       2    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        99
#  comp.  1:        -1        12
#  comp.  2:        -0        23
# chi2/DOF: 0.9013; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.831      0.11      -1    12
# Comp:  1                 Hbeta      11.83      0.11      -1    12
# Comp:  1                Halpha      35.54      0.11      -1    12
# Comp:  2             [SII]6716      5.656      0.12      -0    23
# Comp:  2             [SII]6731      4.376      0.12      -0    23
# Comp:  2              HeII4687    0.01643      0.12      -0    23
# Comp:  2               HeI5876      1.378      0.12      -0    23
# Comp:  2          [OIII]5007_d      3.392      0.15      -0    23
# Comp:  2            [OI]6300_d     0.9003      0.15      -0    23
# Comp:  2           [NII]6583_d      15.36      0.15      -0    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        77
#  comp.  1:        -2         9
#  comp.  2:         2        19
# chi2/DOF: 0.9064; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.456      0.11      -2     9
# Comp:  1                 Hbeta      9.551      0.11      -2     9
# Comp:  1                Halpha      35.28      0.11      -2     9
# Comp:  2             [SII]6716      5.607      0.11       2    19
# Comp:  2             [SII]6731      3.923      0.11       2    19
# Comp:  2              HeII4687      0.000      0.11       2    19
# Comp:  2               HeI5876      1.334      0.11       2    19
# Comp:  2          [OIII]5007_d      3.429      0.14       2    19
# Comp:  2            [OI]6300_d     0.8837      0.14       2    19
# Comp:  2           [NII]6583_d      15.17      0.14       2    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        69
#  comp.  1:         0         1
#  comp.  2:         2        23
# chi2/DOF: 0.8882; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.995      0.11       0     1
# Comp:  1                 Hbeta      11.69      0.11       0     1
# Comp:  1                Halpha      35.77      0.11       0     1
# Comp:  2             [SII]6716      5.658      0.12       2    23
# Comp:  2             [SII]6731      4.225      0.12       2    23
# Comp:  2              HeII4687    0.08846      0.12       2    23
# Comp:  2               HeI5876      1.508      0.12       2    23
# Comp:  2          [OIII]5007_d      3.499      0.15       2    23
# Comp:  2            [OI]6300_d     0.9117      0.15       2    23
# Comp:  2           [NII]6583_d      15.48      0.15       2    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        56
#  comp.  1:        -1        16
#  comp.  2:        -1         7
# chi2/DOF: 0.9175; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.073      0.11      -1    16
# Comp:  1                 Hbeta      11.67      0.11      -1    16
# Comp:  1                Halpha      36.28      0.11      -1    16
# Comp:  2             [SII]6716      5.605      0.11      -1     7
# Comp:  2             [SII]6731      3.659      0.11      -1     7
# Comp:  2              HeII4687    0.04407      0.11      -1     7
# Comp:  2               HeI5876      1.309      0.11      -1     7
# Comp:  2          [OIII]5007_d      3.555      0.14      -1     7
# Comp:  2            [OI]6300_d     0.8836      0.14      -1     7
# Comp:  2           [NII]6583_d      14.71      0.14      -1     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        53
#  comp.  1:        -1        16
#  comp.  2:         0        25
# chi2/DOF: 0.9536; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.786      0.11      -1    16
# Comp:  1                 Hbeta      10.24      0.11      -1    16
# Comp:  1                Halpha      36.24      0.11      -1    16
# Comp:  2             [SII]6716      6.077      0.12       0    25
# Comp:  2             [SII]6731      4.270      0.12       0    25
# Comp:  2              HeII4687      0.000      0.12       0    25
# Comp:  2               HeI5876      1.287      0.12       0    25
# Comp:  2          [OIII]5007_d      3.441      0.15       0    25
# Comp:  2            [OI]6300_d     0.9278      0.15       0    25
# Comp:  2           [NII]6583_d      15.54      0.15       0    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        13        56
#  comp.  1:        -1        18
#  comp.  2:        -0        23
# chi2/DOF: 0.9560; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.006      0.11      -1    18
# Comp:  1                 Hbeta      10.71      0.11      -1    18
# Comp:  1                Halpha      36.61      0.11      -1    18
# Comp:  2             [SII]6716      5.657      0.12      -0    23
# Comp:  2             [SII]6731      3.782      0.12      -0    23
# Comp:  2              HeII4687      0.000      0.12      -0    23
# Comp:  2               HeI5876      1.240      0.12      -0    23
# Comp:  2          [OIII]5007_d      3.737      0.15      -0    23
# Comp:  2            [OI]6300_d     0.8955      0.15      -0    23
# Comp:  2           [NII]6583_d      15.38      0.15      -0    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14        60
#  comp.  1:        -2        17
#  comp.  2:        -1        22
# chi2/DOF: 0.8895; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10        90
#  comp.  1:        -1         1
#  comp.  2:        -0        22
# chi2/DOF: 0.9597; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.339      0.11      -1     1
# Comp:  1                 Hbeta      11.02      0.11      -1     1
# Comp:  1                Halpha      36.02      0.11      -1     1
# Comp:  2             [SII]6716      5.931      0.12      -0    22
# Comp:  2             [SII]6731      3.801      0.12      -0    22
# Comp:  2              HeII4687      0.000      0.12      -0    22
# Comp:  2               HeI5876      1.374      0.12      -0    22
# Comp:  2          [OIII]5007_d      3.464      0.15      -0    22
# Comp:  2            [OI]6300_d     0.8768      0.15      -0    22
# Comp:  2           [NII]6583_d      15.59      0.15      -0    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        72
#  comp.  1:        -1        14
#  comp.  2:         0        16
# chi2/DOF: 0.9496; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.903      0.11      -1    14
# Comp:  1                 Hbeta      10.34      0.11      -1    14
# Comp:  1                Halpha      35.32      0.11      -1    14
# Comp:  2             [SII]6716      5.539      0.11       0    16
# Comp:  2             [SII]6731      4.285      0.11       0    16
# Comp:  2              HeII4687      0.000      0.11       0    16
# Comp:  2               HeI5876      1.226      0.11       0    16
# Comp:  2          [OIII]5007_d      3.391      0.14       0    16
# Comp:  2            [OI]6300_d     0.8992      0.14       0    16
# Comp:  2           [NII]6583_d      15.14      0.14       0    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        65
#  comp.  1:        -4        16
#  comp.  2:         1        19
# chi2/DOF: 0.9467; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.569      0.11      -4    16
# Comp:  1                 Hbeta      10.22      0.11      -4    16
# Comp:  1                Halpha      36.56      0.11      -4    16
# Comp:  2             [SII]6716      5.988      0.11       1    19
# Comp:  2             [SII]6731      4.093      0.11       1    19
# Comp:  2              HeII4687      0.000      0.11       1    19
# Comp:  2               HeI5876      1.393      0.11       1    19
# Comp:  2          [OIII]5007_d      3.151      0.14       1    19
# Comp:  2            [OI]6300_d     0.8979      0.14       1    19
# Comp:  2           [NII]6583_d      15.28      0.14       1    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        78
#  comp.  1:        -4        17
#  comp.  2:         0        20
# chi2/DOF: 0.9225; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.561      0.11      -4    17
# Comp:  1                 Hbeta      10.22      0.11      -4    17
# Comp:  1                Halpha      36.60      0.11      -4    17
# Comp:  2             [SII]6716      5.383      0.11       0    20
# Comp:  2             [SII]6731      4.052      0.11       0    20
# Comp:  2              HeII4687     0.1139      0.11       0    20
# Comp:  2               HeI5876      1.391      0.11       0    20
# Comp:  2          [OIII]5007_d      3.302      0.14       0    20
# Comp:  2            [OI]6300_d     0.8464      0.14       0    20
# Comp:  2           [NII]6583_d      15.12      0.14       0    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        67
#  comp.  1:        -2         1
#  comp.  2:         2        20
# chi2/DOF: 0.9243; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.187      0.11      -2     1
# Comp:  1                 Hbeta      9.434      0.11      -2     1
# Comp:  1                Halpha      36.57      0.11      -2     1
# Comp:  2             [SII]6716      5.466      0.11       2    20
# Comp:  2             [SII]6731      4.088      0.11       2    20
# Comp:  2              HeII4687    0.09934      0.11       2    20
# Comp:  2               HeI5876      1.230      0.11       2    20
# Comp:  2          [OIII]5007_d      3.624      0.14       2    20
# Comp:  2            [OI]6300_d     0.9074      0.14       2    20
# Comp:  2           [NII]6583_d      15.45      0.14       2    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        68
#  comp.  1:        -4         1
#  comp.  2:        -3        16
# chi2/DOF: 0.9305; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.353      0.11      -4     1
# Comp:  1                 Hbeta      9.547      0.11      -4     1
# Comp:  1                Halpha      35.95      0.11      -4     1
# Comp:  2             [SII]6716      5.931      0.11      -3    16
# Comp:  2             [SII]6731      3.839      0.11      -3    16
# Comp:  2              HeII4687     0.1007      0.11      -3    16
# Comp:  2               HeI5876      1.199      0.11      -3    16
# Comp:  2          [OIII]5007_d      3.749      0.14      -3    16
# Comp:  2            [OI]6300_d     0.8989      0.14      -3    16
# Comp:  2           [NII]6583_d      15.18      0.14      -3    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        25        71
#  comp.  1:        -2        20
#  comp.  2:         1        27
# chi2/DOF: 0.8765; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.993      0.11      -2    20
# Comp:  1                 Hbeta      12.17      0.11      -2    20
# Comp:  1                Halpha      36.08      0.11      -2    20
# Comp:  2             [SII]6716      6.105      0.12       1    27
# Comp:  2             [SII]6731      4.089      0.12       1    27
# Comp:  2              HeII4687      0.000      0.12       1    27
# Comp:  2               HeI5876      1.292      0.12       1    27
# Comp:  2          [OIII]5007_d      3.535      0.15       1    27
# Comp:  2            [OI]6300_d     0.9095      0.15       1    27
# Comp:  2           [NII]6583_d      15.72      0.15       1    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        74
#  comp.  1:        -1         1
#  comp.  2:        -1        19
# chi2/DOF: 0.9067; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.723      0.11      -1     1
# Comp:  1                 Hbeta      11.55      0.11      -1     1
# Comp:  1                Halpha      36.87      0.11      -1     1
# Comp:  2             [SII]6716      5.510      0.11      -1    19
# Comp:  2             [SII]6731      3.732      0.11      -1    19
# Comp:  2              HeII4687    0.02131      0.11      -1    19
# Comp:  2               HeI5876      1.487      0.11      -1    19
# Comp:  2          [OIII]5007_d      3.519      0.14      -1    19
# Comp:  2            [OI]6300_d     0.9303      0.14      -1    19
# Comp:  2           [NII]6583_d      15.19      0.14      -1    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30       101
#  comp.  1:        -1        12
#  comp.  2:         0        27
# chi2/DOF: 0.9541; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.966      0.11      -1    12
# Comp:  1                 Hbeta      10.02      0.11      -1    12
# Comp:  1                Halpha      35.30      0.11      -1    12
# Comp:  2             [SII]6716      5.663      0.12       0    27
# Comp:  2             [SII]6731      4.240      0.12       0    27
# Comp:  2              HeII4687      0.000      0.12       0    27
# Comp:  2               HeI5876      1.516      0.12       0    27
# Comp:  2          [OIII]5007_d      3.641      0.15       0    27
# Comp:  2            [OI]6300_d     0.9292      0.15       0    27
# Comp:  2           [NII]6583_d      15.56      0.15       0    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        76
#  comp.  1:         1         1
#  comp.  2:        -2        25
# chi2/DOF: 0.8717; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.618      0.11       1     1
# Comp:  1                 Hbeta      11.70      0.11       1     1
# Comp:  1                Halpha      35.83      0.11       1     1
# Comp:  2             [SII]6716      5.568      0.12      -2    25
# Comp:  2             [SII]6731      4.081      0.12      -2    25
# Comp:  2              HeII4687      0.000      0.12      -2    25
# Comp:  2               HeI5876      1.258      0.12      -2    25
# Comp:  2          [OIII]5007_d      3.577      0.15      -2    25
# Comp:  2            [OI]6300_d     0.9272      0.15      -2    25
# Comp:  2           [NII]6583_d      15.37      0.15      -2    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        77
#  comp.  1:        -2         9
#  comp.  2:        -2        23
# chi2/DOF: 0.9533; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.436      0.11      -2     9
# Comp:  1                 Hbeta      10.81      0.11      -2     9
# Comp:  1                Halpha      35.48      0.11      -2     9
# Comp:  2             [SII]6716      5.378      0.12      -2    23
# Comp:  2             [SII]6731      3.834      0.12      -2    23
# Comp:  2              HeII4687    0.04206      0.12      -2    23
# Comp:  2               HeI5876      1.240      0.12      -2    23
# Comp:  2          [OIII]5007_d      3.675      0.15      -2    23
# Comp:  2            [OI]6300_d     0.8861      0.15      -2    23
# Comp:  2           [NII]6583_d      15.43      0.15      -2    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2        66
#  comp.  1:        -1         1
#  comp.  2:        -0        24
# chi2/DOF: 0.9432; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.695      0.11      -1     1
# Comp:  1                 Hbeta      10.96      0.11      -1     1
# Comp:  1                Halpha      34.97      0.11      -1     1
# Comp:  2             [SII]6716      5.629      0.12      -0    24
# Comp:  2             [SII]6731      4.362      0.12      -0    24
# Comp:  2              HeII4687      0.000      0.12      -0    24
# Comp:  2               HeI5876      1.377      0.12      -0    24
# Comp:  2          [OIII]5007_d      3.670      0.15      -0    24
# Comp:  2            [OI]6300_d     0.9082      0.15      -0    24
# Comp:  2           [NII]6583_d      15.62      0.15      -0    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        53
#  comp.  1:        -2        17
#  comp.  2:         0        25
# chi2/DOF: 0.9096; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.704      0.11      -2    17
# Comp:  1                 Hbeta      10.35      0.11      -2    17
# Comp:  1                Halpha      37.32      0.11      -2    17
# Comp:  2             [SII]6716      5.626      0.12       0    25
# Comp:  2             [SII]6731      3.820      0.12       0    25
# Comp:  2              HeII4687    0.05337      0.12       0    25
# Comp:  2               HeI5876      1.494      0.12       0    25
# Comp:  2          [OIII]5007_d      3.082      0.15       0    25
# Comp:  2            [OI]6300_d     0.9202      0.15       0    25
# Comp:  2           [NII]6583_d      15.83      0.15       0    25
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.47862039, 0.84558774, 0.7485388 , 0.35730867, 0.26378926,
#        0.03928223, 0.11809179, 0.24164566, 0.04189034, 0.35650732])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum1s_3_gas_ppxf_noreg.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum1s_3_noreg", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum1s_3_kin_noreg.csv", index=True)

# %%
read = pd.read_csv("Spectrum1s_3_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum1s_3_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
