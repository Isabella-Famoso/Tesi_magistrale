# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_19.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_19']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4314.03901503 4315.47324864 4316.90748224 ... 6874.1460011  6875.58023471
#  6877.01446832] [0.00729852 0.00244975 0.01369403 ... 0.01306271 0.01559988 0.01186334] [0.00619146 0.00619146 0.00619146 ... 0.00619146 0.00619146 0.00619146]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -14       202
# chi2/DOF: 0.2829; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:         4       160
# chi2/DOF: 0.1777; DOF: 1883; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([  4.49139516, 160.24142113])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        35       266
#  comp.  1:      -100       181
#  comp.  2:       -71       182
# chi2/DOF: 0.7825; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       1.9    -100   181
# Comp:  1                 Hbeta      3.367       1.9    -100   181
# Comp:  1                Halpha      7.265       1.9    -100   181
# Comp:  2             [SII]6716      3.019       2.0     -71   182
# Comp:  2             [SII]6731      3.192       2.0     -71   182
# Comp:  2              HeII4687      0.000       2.0     -71   182
# Comp:  2               HeI5876      0.000       2.0     -71   182
# Comp:  2          [OIII]5007_d      3.219       2.5     -71   182
# Comp:  2            [OI]6300_d      5.467       2.5     -71   182
# Comp:  2           [NII]6583_d      7.831       2.5     -71   182
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise: 0.9961; gas flux:      3 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  2.159; gas flux:     10 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise: 0.8854; gas flux:      4 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise: 0.9435; gas flux:      4 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise: 0.7153; gas flux:      3 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.217; gas flux:      7 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  1.734; gas flux:     11 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        38       248
#  comp.  1:       -98       211
#  comp.  2:       -68       157
# chi2/DOF: 0.7759; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       2.1     -98   211
# Comp:  1                 Hbeta      4.900       2.1     -98   211
# Comp:  1                Halpha      8.548       2.1     -98   211
# Comp:  2             [SII]6716      2.437       1.8     -68   157
# Comp:  2             [SII]6731      7.010       1.8     -68   157
# Comp:  2              HeII4687      2.152       1.8     -68   157
# Comp:  2               HeI5876      0.000       1.8     -68   157
# Comp:  2          [OIII]5007_d      1.716       2.3     -68   157
# Comp:  2            [OI]6300_d      5.729       2.3     -68   157
# Comp:  2           [NII]6583_d      7.681       2.3     -68   157
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46       169
#  comp.  1:      -100       205
#  comp.  2:       -49       113
# chi2/DOF: 0.7733; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.257       2.1    -100   205
# Comp:  1                 Hbeta      5.145       2.1    -100   205
# Comp:  1                Halpha      8.530       2.1    -100   205
# Comp:  2             [SII]6716      1.649       1.6     -49   113
# Comp:  2             [SII]6731      4.884       1.6     -49   113
# Comp:  2              HeII4687      0.000       1.6     -49   113
# Comp:  2               HeI5876     0.2931       1.6     -49   113
# Comp:  2          [OIII]5007_d      5.212       2.0     -49   113
# Comp:  2            [OI]6300_d      4.738       2.0     -49   113
# Comp:  2           [NII]6583_d      6.294       2.0     -49   113
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        91       230
#  comp.  1:       -75       150
#  comp.  2:      -159       240
# chi2/DOF: 0.7776; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       1.8     -75   150
# Comp:  1                 Hbeta      3.356       1.8     -75   150
# Comp:  1                Halpha      7.098       1.8     -75   150
# Comp:  2             [SII]6716      1.893       2.3    -159   240
# Comp:  2             [SII]6731      4.317       2.3    -159   240
# Comp:  2              HeII4687      0.000       2.2    -159   240
# Comp:  2               HeI5876      0.000       2.2    -159   240
# Comp:  2          [OIII]5007_d      1.588       2.8    -159   240
# Comp:  2            [OI]6300_d      4.055       2.8    -159   240
# Comp:  2           [NII]6583_d      9.763       2.8    -159   240
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8       240
#  comp.  1:      -141       186
#  comp.  2:      -127       103
# chi2/DOF: 0.7741; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.178       2.0    -141   186
# Comp:  1                 Hbeta      4.331       2.0    -141   186
# Comp:  1                Halpha      8.880       2.0    -141   186
# Comp:  2             [SII]6716      1.494       1.6    -127   103
# Comp:  2             [SII]6731      2.219       1.6    -127   103
# Comp:  2              HeII4687      1.855       1.6    -127   103
# Comp:  2               HeI5876     0.1183       1.6    -127   103
# Comp:  2          [OIII]5007_d      5.193       2.0    -127   103
# Comp:  2            [OI]6300_d      6.270       2.0    -127   103
# Comp:  2           [NII]6583_d      5.736       2.0    -127   103
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        57       274
#  comp.  1:      -115       184
#  comp.  2:       -60       137
# chi2/DOF: 0.7726; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       2.0    -115   184
# Comp:  1                 Hbeta      1.906       2.0    -115   184
# Comp:  1                Halpha      7.068       2.0    -115   184
# Comp:  2             [SII]6716      1.914       1.7     -60   137
# Comp:  2             [SII]6731      6.005       1.7     -60   137
# Comp:  2              HeII4687      0.000       1.7     -60   137
# Comp:  2               HeI5876     0.6452       1.7     -60   137
# Comp:  2          [OIII]5007_d      6.750       2.2     -60   137
# Comp:  2            [OI]6300_d      4.023       2.2     -60   137
# Comp:  2           [NII]6583_d      6.754       2.2     -60   137
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        53       307
#  comp.  1:       -91       132
#  comp.  2:      -166       146
# chi2/DOF: 0.7711; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.2579       1.7     -91   132
# Comp:  1                 Hbeta      2.484       1.7     -91   132
# Comp:  1                Halpha      7.068       1.7     -91   132
# Comp:  2             [SII]6716      0.000       1.8    -166   146
# Comp:  2             [SII]6731      8.280       1.8    -166   146
# Comp:  2              HeII4687     0.1279       1.8    -166   146
# Comp:  2               HeI5876     0.4140       1.8    -166   146
# Comp:  2          [OIII]5007_d    0.03388       2.2    -166   146
# Comp:  2            [OI]6300_d      8.445       2.2    -166   146
# Comp:  2           [NII]6583_d      6.863       2.2    -166   146
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31       210
#  comp.  1:       -18       204
#  comp.  2:       -59       135
# chi2/DOF: 0.7754; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.873       2.1     -18   204
# Comp:  1                 Hbeta      7.638       2.1     -18   204
# Comp:  1                Halpha      9.051       2.1     -18   204
# Comp:  2             [SII]6716      2.765       1.7     -59   135
# Comp:  2             [SII]6731      4.669       1.7     -59   135
# Comp:  2              HeII4687      0.000       1.7     -59   135
# Comp:  2               HeI5876      0.000       1.7     -59   135
# Comp:  2          [OIII]5007_d      0.000       2.2     -59   135
# Comp:  2            [OI]6300_d      9.112       2.2     -59   135
# Comp:  2           [NII]6583_d      6.767       2.2     -59   135
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33       393
#  comp.  1:      -103       157
#  comp.  2:       -22       213
# chi2/DOF: 0.7622; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       1.8    -103   157
# Comp:  1                 Hbeta      5.803       1.8    -103   157
# Comp:  1                Halpha      7.667       1.8    -103   157
# Comp:  2             [SII]6716      2.559       2.1     -22   213
# Comp:  2             [SII]6731      12.02       2.1     -22   213
# Comp:  2              HeII4687     0.9730       2.1     -22   213
# Comp:  2               HeI5876      3.165       2.1     -22   213
# Comp:  2          [OIII]5007_d      4.888       2.7     -22   213
# Comp:  2            [OI]6300_d      0.000       2.7     -22   213
# Comp:  2           [NII]6583_d      8.168       2.7     -22   213
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74       361
#  comp.  1:       -55       275
#  comp.  2:       -45       202
# chi2/DOF: 0.7715; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 46; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.853       2.4     -55   275
# Comp:  1                 Hbeta      11.57       2.4     -55   275
# Comp:  1                Halpha      11.85       2.4     -55   275
# Comp:  2             [SII]6716      5.667       2.1     -45   202
# Comp:  2             [SII]6731      3.070       2.1     -45   202
# Comp:  2              HeII4687      0.000       2.1     -45   202
# Comp:  2               HeI5876     0.8150       2.1     -45   202
# Comp:  2          [OIII]5007_d      0.000       2.6     -45   202
# Comp:  2            [OI]6300_d      11.77       2.6     -45   202
# Comp:  2           [NII]6583_d      9.074       2.6     -45   202
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21       164
#  comp.  1:       -50       211
#  comp.  2:      -102       157
# chi2/DOF: 0.7780; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       2.1     -50   211
# Comp:  1                 Hbeta      5.526       2.1     -50   211
# Comp:  1                Halpha      7.864       2.1     -50   211
# Comp:  2             [SII]6716      3.227       1.8    -102   157
# Comp:  2             [SII]6731      1.890       1.8    -102   157
# Comp:  2              HeII4687      0.000       1.8    -102   157
# Comp:  2               HeI5876      0.000       1.8    -102   157
# Comp:  2          [OIII]5007_d      3.580       2.3    -102   157
# Comp:  2            [OI]6300_d      5.634       2.3    -102   157
# Comp:  2           [NII]6583_d      6.234       2.3    -102   157
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100       207
#  comp.  1:      -138       177
#  comp.  2:       -50       155
# chi2/DOF: 0.7707; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3902       1.9    -138   177
# Comp:  1                 Hbeta      4.940       1.9    -138   177
# Comp:  1                Halpha      7.998       1.9    -138   177
# Comp:  2             [SII]6716      4.820       1.8     -50   155
# Comp:  2             [SII]6731      4.747       1.8     -50   155
# Comp:  2              HeII4687      2.241       1.8     -50   155
# Comp:  2               HeI5876      1.077       1.8     -50   155
# Comp:  2          [OIII]5007_d      7.538       2.3     -50   155
# Comp:  2            [OI]6300_d      9.846       2.3     -50   155
# Comp:  2           [NII]6583_d      8.363       2.3     -50   155
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -151       295
#  comp.  1:       -82       196
#  comp.  2:         6       173
# chi2/DOF: 0.7759; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6486       2.0     -82   196
# Comp:  1                 Hbeta      5.303       2.0     -82   196
# Comp:  1                Halpha      9.367       2.0     -82   196
# Comp:  2             [SII]6716      5.101       1.9       6   173
# Comp:  2             [SII]6731      3.579       1.9       6   173
# Comp:  2              HeII4687     0.3776       1.9       6   173
# Comp:  2               HeI5876      1.528       1.9       6   173
# Comp:  2          [OIII]5007_d      4.672       2.4       6   173
# Comp:  2            [OI]6300_d      5.401       2.4       6   173
# Comp:  2           [NII]6583_d      7.145       2.4       6   173
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        94       191
#  comp.  1:       -17       237
#  comp.  2:      -145       148
# chi2/DOF: 0.7761; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.045       2.2     -17   237
# Comp:  1                 Hbeta      7.696       2.2     -17   237
# Comp:  1                Halpha      13.13       2.2     -17   237
# Comp:  2             [SII]6716      3.432       1.8    -145   148
# Comp:  2             [SII]6731      3.388       1.8    -145   148
# Comp:  2              HeII4687      0.000       1.8    -145   148
# Comp:  2               HeI5876      1.120       1.8    -145   148
# Comp:  2          [OIII]5007_d     0.1840       2.3    -145   148
# Comp:  2            [OI]6300_d      6.367       2.3    -145   148
# Comp:  2           [NII]6583_d      7.106       2.3    -145   148
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -134       351
#  comp.  1:      -137       233
#  comp.  2:      -137       210
# chi2/DOF: 0.7732; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.700       2.2    -137   233
# Comp:  1                 Hbeta      8.327       2.2    -137   233
# Comp:  1                Halpha      9.392       2.2    -137   233
# Comp:  2             [SII]6716      5.036       2.1    -137   210
# Comp:  2             [SII]6731      0.000       2.1    -137   210
# Comp:  2              HeII4687      0.000       2.1    -137   210
# Comp:  2               HeI5876     0.7378       2.1    -137   210
# Comp:  2          [OIII]5007_d      4.193       2.6    -137   210
# Comp:  2            [OI]6300_d      7.307       2.6    -137   210
# Comp:  2           [NII]6583_d      9.023       2.6    -137   210
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        90       241
#  comp.  1:       -88       198
#  comp.  2:        -5         1
# chi2/DOF: 0.7744; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1388       2.0     -88   198
# Comp:  1                 Hbeta      2.088       2.0     -88   198
# Comp:  1                Halpha      8.239       2.0     -88   198
# Comp:  2             [SII]6716      1.866       1.1      -5     1
# Comp:  2             [SII]6731      4.612       1.1      -5     1
# Comp:  2              HeII4687      0.000       1.1      -5     1
# Comp:  2               HeI5876      0.000       1.1      -5     1
# Comp:  2          [OIII]5007_d      3.604       1.4      -5     1
# Comp:  2            [OI]6300_d      0.000       1.4      -5     1
# Comp:  2           [NII]6583_d      2.456       1.4      -5     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        79       200
#  comp.  1:       -37       269
#  comp.  2:       -22       126
# chi2/DOF: 0.7735; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma    0.09188       2.3     -37   269
# Comp:  1                 Hbeta      7.991       2.3     -37   269
# Comp:  1                Halpha      11.23       2.3     -37   269
# Comp:  2             [SII]6716      2.292       1.7     -22   126
# Comp:  2             [SII]6731      8.147       1.7     -22   126
# Comp:  2              HeII4687      0.000       1.7     -22   126
# Comp:  2               HeI5876     0.7592       1.7     -22   126
# Comp:  2          [OIII]5007_d     0.6023       2.1     -22   126
# Comp:  2            [OI]6300_d      4.363       2.1     -22   126
# Comp:  2           [NII]6583_d      6.592       2.1     -22   126
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24       229
#  comp.  1:      -101       157
#  comp.  2:       -37       128
# chi2/DOF: 0.7747; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       1.8    -101   157
# Comp:  1                 Hbeta      3.296       1.8    -101   157
# Comp:  1                Halpha      6.419       1.8    -101   157
# Comp:  2             [SII]6716      1.954       1.7     -37   128
# Comp:  2             [SII]6731      5.379       1.7     -37   128
# Comp:  2              HeII4687      0.000       1.7     -37   128
# Comp:  2               HeI5876      0.000       1.7     -37   128
# Comp:  2          [OIII]5007_d      1.683       2.1     -37   128
# Comp:  2            [OI]6300_d      5.607       2.1     -37   128
# Comp:  2           [NII]6583_d      7.265       2.1     -37   128
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       188       352
#  comp.  1:       -59       169
#  comp.  2:        21       214
# chi2/DOF: 0.7713; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.170       1.9     -59   169
# Comp:  1                 Hbeta      2.631       1.9     -59   169
# Comp:  1                Halpha      7.698       1.9     -59   169
# Comp:  2             [SII]6716      5.056       2.1      21   214
# Comp:  2             [SII]6731      0.000       2.1      21   214
# Comp:  2              HeII4687      0.000       2.1      21   214
# Comp:  2               HeI5876     0.6418       2.1      21   214
# Comp:  2          [OIII]5007_d      4.197       2.7      21   214
# Comp:  2            [OI]6300_d      10.02       2.7      21   214
# Comp:  2           [NII]6583_d      8.275       2.7      21   214
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12       277
#  comp.  1:       -85       216
#  comp.  2:       -86       176
# chi2/DOF: 0.7749; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.158       2.1     -85   216
# Comp:  1                 Hbeta      7.440       2.1     -85   216
# Comp:  1                Halpha      9.461       2.1     -85   216
# Comp:  2             [SII]6716      4.824       1.9     -86   176
# Comp:  2             [SII]6731      4.742       1.9     -86   176
# Comp:  2              HeII4687      1.152       1.9     -86   176
# Comp:  2               HeI5876      0.000       1.9     -86   176
# Comp:  2          [OIII]5007_d      0.000       2.4     -86   176
# Comp:  2            [OI]6300_d      9.969       2.4     -86   176
# Comp:  2           [NII]6583_d      7.830       2.4     -86   176
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        46       211
#  comp.  1:       -56       178
#  comp.  2:       -87       195
# chi2/DOF: 0.7708; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.987       1.9     -56   178
# Comp:  1                 Hbeta      6.896       1.9     -56   178
# Comp:  1                Halpha      7.975       1.9     -56   178
# Comp:  2             [SII]6716      2.847       2.0     -87   195
# Comp:  2             [SII]6731      8.486       2.0     -87   195
# Comp:  2              HeII4687      1.491       2.0     -87   195
# Comp:  2               HeI5876      2.468       2.0     -87   195
# Comp:  2          [OIII]5007_d      0.000       2.5     -87   195
# Comp:  2            [OI]6300_d      10.70       2.5     -87   195
# Comp:  2           [NII]6583_d      9.076       2.5     -87   195
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35       320
#  comp.  1:       -67       271
#  comp.  2:       -48        90
# chi2/DOF: 0.7756; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.391       2.3     -67   271
# Comp:  1                 Hbeta      6.149       2.3     -67   271
# Comp:  1                Halpha      9.879       2.3     -67   271
# Comp:  2             [SII]6716      2.168       1.5     -48    90
# Comp:  2             [SII]6731      4.762       1.5     -48    90
# Comp:  2              HeII4687      0.000       1.5     -48    90
# Comp:  2               HeI5876      0.000       1.5     -48    90
# Comp:  2          [OIII]5007_d      3.827       1.9     -48    90
# Comp:  2            [OI]6300_d      2.482       1.9     -48    90
# Comp:  2           [NII]6583_d      6.032       1.9     -48    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29       221
#  comp.  1:      -124       171
#  comp.  2:       -65       230
# chi2/DOF: 0.7765; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.519       1.9    -124   171
# Comp:  1                 Hbeta      4.625       1.9    -124   171
# Comp:  1                Halpha      7.078       1.9    -124   171
# Comp:  2             [SII]6716      5.532       2.2     -65   230
# Comp:  2             [SII]6731      1.366       2.2     -65   230
# Comp:  2              HeII4687      1.669       2.2     -65   230
# Comp:  2               HeI5876      1.499       2.2     -65   230
# Comp:  2          [OIII]5007_d      1.952       2.7     -65   230
# Comp:  2            [OI]6300_d      4.867       2.7     -65   230
# Comp:  2           [NII]6583_d      9.875       2.7     -65   230
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70       204
#  comp.  1:       -89       197
#  comp.  2:       -98       204
# chi2/DOF: 0.7732; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.789       2.0     -89   197
# Comp:  1                 Hbeta      9.153       2.0     -89   197
# Comp:  1                Halpha      9.483       2.0     -89   197
# Comp:  2             [SII]6716      5.156       2.1     -98   204
# Comp:  2             [SII]6731      3.039       2.1     -98   204
# Comp:  2              HeII4687      0.000       2.1     -98   204
# Comp:  2               HeI5876      0.000       2.1     -98   204
# Comp:  2          [OIII]5007_d     0.5245       2.6     -98   204
# Comp:  2            [OI]6300_d      3.630       2.6     -98   204
# Comp:  2           [NII]6583_d      7.833       2.6     -98   204
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        77       184
#  comp.  1:       -65       137
#  comp.  2:       -26        88
# chi2/DOF: 0.7647; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.633       1.7     -65   137
# Comp:  1                 Hbeta      2.328       1.7     -65   137
# Comp:  1                Halpha      6.328       1.7     -65   137
# Comp:  2             [SII]6716      3.870       1.5     -26    88
# Comp:  2             [SII]6731      5.829       1.5     -26    88
# Comp:  2              HeII4687     0.8846       1.5     -26    88
# Comp:  2               HeI5876     0.2301       1.5     -26    88
# Comp:  2          [OIII]5007_d      8.066       1.9     -26    88
# Comp:  2            [OI]6300_d      3.716       1.9     -26    88
# Comp:  2           [NII]6583_d      5.345       1.9     -26    88
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26       186
#  comp.  1:       -45       181
#  comp.  2:       -88       149
# chi2/DOF: 0.7736; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       2.0     -45   181
# Comp:  1                 Hbeta      4.105       2.0     -45   181
# Comp:  1                Halpha      7.839       2.0     -45   181
# Comp:  2             [SII]6716      2.615       1.8     -88   149
# Comp:  2             [SII]6731      4.398       1.8     -88   149
# Comp:  2              HeII4687      2.061       1.8     -88   149
# Comp:  2               HeI5876     0.7897       1.8     -88   149
# Comp:  2          [OIII]5007_d      0.000       2.3     -88   149
# Comp:  2            [OI]6300_d      5.971       2.3     -88   149
# Comp:  2           [NII]6583_d      7.452       2.3     -88   149
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        64       287
#  comp.  1:      -102       159
#  comp.  2:       -88       211
# chi2/DOF: 0.7753; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       1.8    -102   159
# Comp:  1                 Hbeta      2.548       1.8    -102   159
# Comp:  1                Halpha      6.710       1.8    -102   159
# Comp:  2             [SII]6716      4.418       2.1     -88   211
# Comp:  2             [SII]6731      2.460       2.1     -88   211
# Comp:  2              HeII4687      3.826       2.1     -88   211
# Comp:  2               HeI5876      1.085       2.1     -88   211
# Comp:  2          [OIII]5007_d     0.6500       2.6     -88   211
# Comp:  2            [OI]6300_d      3.228       2.6     -88   211
# Comp:  2           [NII]6583_d      8.862       2.6     -88   211
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       174       288
#  comp.  1:       -81       223
#  comp.  2:      -144       144
# chi2/DOF: 0.7746; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       2.1     -81   223
# Comp:  1                 Hbeta      2.606       2.1     -81   223
# Comp:  1                Halpha      9.737       2.1     -81   223
# Comp:  2             [SII]6716      2.108       1.8    -144   144
# Comp:  2             [SII]6731      6.945       1.8    -144   144
# Comp:  2              HeII4687      0.000       1.8    -144   144
# Comp:  2               HeI5876     0.4272       1.8    -144   144
# Comp:  2          [OIII]5007_d      1.830       2.2    -144   144
# Comp:  2            [OI]6300_d      5.898       2.2    -144   144
# Comp:  2           [NII]6583_d      7.262       2.2    -144   144
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        55       305
#  comp.  1:       -43       214
#  comp.  2:       -26        87
# chi2/DOF: 0.7720; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.116       2.1     -43   214
# Comp:  1                 Hbeta      8.259       2.1     -43   214
# Comp:  1                Halpha      10.08       2.1     -43   214
# Comp:  2             [SII]6716      1.192       1.5     -26    87
# Comp:  2             [SII]6731      3.414       1.5     -26    87
# Comp:  2              HeII4687      0.000       1.5     -26    87
# Comp:  2               HeI5876      0.000       1.5     -26    87
# Comp:  2          [OIII]5007_d      4.936       1.9     -26    87
# Comp:  2            [OI]6300_d      7.286       1.9     -26    87
# Comp:  2           [NII]6583_d      5.894       1.9     -26    87
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        24       287
#  comp.  1:      -100       246
#  comp.  2:       -86       141
# chi2/DOF: 0.7711; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.791       2.2    -100   246
# Comp:  1                 Hbeta      7.597       2.2    -100   246
# Comp:  1                Halpha      9.662       2.2    -100   246
# Comp:  2             [SII]6716      2.843       1.8     -86   141
# Comp:  2             [SII]6731     0.6060       1.8     -86   141
# Comp:  2              HeII4687      0.000       1.8     -86   141
# Comp:  2               HeI5876      0.000       1.8     -86   141
# Comp:  2          [OIII]5007_d      7.719       2.2     -86   141
# Comp:  2            [OI]6300_d      7.911       2.2     -86   141
# Comp:  2           [NII]6583_d      6.878       2.2     -86   141
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       154       157
#  comp.  1:       -28       220
#  comp.  2:      -108       183
# chi2/DOF: 0.7702; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8750       2.1     -28   220
# Comp:  1                 Hbeta      5.475       2.1     -28   220
# Comp:  1                Halpha      7.991       2.1     -28   220
# Comp:  2             [SII]6716      2.264       2.0    -108   183
# Comp:  2             [SII]6731      8.232       2.0    -108   183
# Comp:  2              HeII4687      0.000       2.0    -108   183
# Comp:  2               HeI5876    0.07567       2.0    -108   183
# Comp:  2          [OIII]5007_d      8.851       2.5    -108   183
# Comp:  2            [OI]6300_d      3.135       2.5    -108   183
# Comp:  2           [NII]6583_d      8.001       2.5    -108   183
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20       342
#  comp.  1:       -63       209
#  comp.  2:       -29       120
# chi2/DOF: 0.7750; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.454       2.1     -63   209
# Comp:  1                 Hbeta      4.946       2.1     -63   209
# Comp:  1                Halpha      8.044       2.1     -63   209
# Comp:  2             [SII]6716      2.056       1.6     -29   120
# Comp:  2             [SII]6731      0.000       1.6     -29   120
# Comp:  2              HeII4687      1.004       1.6     -29   120
# Comp:  2               HeI5876      0.000       1.6     -29   120
# Comp:  2          [OIII]5007_d      4.851       2.1     -29   120
# Comp:  2            [OI]6300_d     0.6008       2.1     -29   120
# Comp:  2           [NII]6583_d      6.023       2.1     -29   120
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35       241
#  comp.  1:      -128       190
#  comp.  2:       -67       136
# chi2/DOF: 0.7728; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.473       2.0    -128   190
# Comp:  1                 Hbeta      4.404       2.0    -128   190
# Comp:  1                Halpha      8.171       2.0    -128   190
# Comp:  2             [SII]6716      2.480       1.7     -67   136
# Comp:  2             [SII]6731      6.938       1.7     -67   136
# Comp:  2              HeII4687      1.281       1.7     -67   136
# Comp:  2               HeI5876      0.000       1.7     -67   136
# Comp:  2          [OIII]5007_d      3.566       2.2     -67   136
# Comp:  2            [OI]6300_d      2.854       2.2     -67   136
# Comp:  2           [NII]6583_d      8.453       2.2     -67   136
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -94       235
#  comp.  1:      -106       223
#  comp.  2:       -88       173
# chi2/DOF: 0.7703; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 38; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.237       2.1    -106   223
# Comp:  1                 Hbeta      6.859       2.1    -106   223
# Comp:  1                Halpha      8.919       2.1    -106   223
# Comp:  2             [SII]6716      2.904       1.9     -88   173
# Comp:  2             [SII]6731      7.616       1.9     -88   173
# Comp:  2              HeII4687      0.000       1.9     -88   173
# Comp:  2               HeI5876      0.000       1.9     -88   173
# Comp:  2          [OIII]5007_d      0.000       2.4     -88   173
# Comp:  2            [OI]6300_d      11.40       2.4     -88   173
# Comp:  2           [NII]6583_d      8.583       2.4     -88   173
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1       235
#  comp.  1:      -111       146
#  comp.  2:        51       246
# chi2/DOF: 0.7765; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       1.8    -111   146
# Comp:  1                 Hbeta      2.251       1.8    -111   146
# Comp:  1                Halpha      6.113       1.8    -111   146
# Comp:  2             [SII]6716      3.583       2.3      51   246
# Comp:  2             [SII]6731      4.441       2.3      51   246
# Comp:  2              HeII4687      0.000       2.2      51   246
# Comp:  2               HeI5876      0.000       2.2      51   246
# Comp:  2          [OIII]5007_d      3.665       2.8      51   246
# Comp:  2            [OI]6300_d      8.945       2.8      51   246
# Comp:  2           [NII]6583_d      7.360       2.8      51   246
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       113       397
#  comp.  1:       -97       211
#  comp.  2:       -74       171
# chi2/DOF: 0.7731; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.839       2.1     -97   211
# Comp:  1                 Hbeta      4.610       2.1     -97   211
# Comp:  1                Halpha      7.635       2.1     -97   211
# Comp:  2             [SII]6716      2.402       1.9     -74   171
# Comp:  2             [SII]6731      6.131       1.9     -74   171
# Comp:  2              HeII4687     0.9910       1.9     -74   171
# Comp:  2               HeI5876      0.000       1.9     -74   171
# Comp:  2          [OIII]5007_d      2.358       2.4     -74   171
# Comp:  2            [OI]6300_d      0.000       2.4     -74   171
# Comp:  2           [NII]6583_d      7.790       2.4     -74   171
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36       206
#  comp.  1:       -77       190
#  comp.  2:       -96       162
# chi2/DOF: 0.7771; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       2.0     -77   190
# Comp:  1                 Hbeta      4.186       2.0     -77   190
# Comp:  1                Halpha      7.850       2.0     -77   190
# Comp:  2             [SII]6716      3.616       1.9     -96   162
# Comp:  2             [SII]6731      2.105       1.9     -96   162
# Comp:  2              HeII4687      0.000       1.9     -96   162
# Comp:  2               HeI5876      0.000       1.9     -96   162
# Comp:  2          [OIII]5007_d      2.081       2.3     -96   162
# Comp:  2            [OI]6300_d      9.118       2.3     -96   162
# Comp:  2           [NII]6583_d      6.469       2.3     -96   162
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       100        98
#  comp.  1:      -127       154
#  comp.  2:       -22        19
# chi2/DOF: 0.7671; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6388       1.8    -127   154
# Comp:  1                 Hbeta      2.823       1.8    -127   154
# Comp:  1                Halpha      6.841       1.8    -127   154
# Comp:  2             [SII]6716      1.187       1.2     -22    19
# Comp:  2             [SII]6731      4.779       1.2     -22    19
# Comp:  2              HeII4687     0.8140       1.2     -22    19
# Comp:  2               HeI5876      0.000       1.2     -22    19
# Comp:  2          [OIII]5007_d      0.000       1.5     -22    19
# Comp:  2            [OI]6300_d      1.073       1.5     -22    19
# Comp:  2           [NII]6583_d      3.594       1.5     -22    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       123       349
#  comp.  1:      -121       219
#  comp.  2:      -155       163
# chi2/DOF: 0.7744; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       2.1    -121   219
# Comp:  1                 Hbeta      4.526       2.1    -121   219
# Comp:  1                Halpha      7.314       2.1    -121   219
# Comp:  2             [SII]6716      4.640       1.9    -155   163
# Comp:  2             [SII]6731      3.305       1.9    -155   163
# Comp:  2              HeII4687      1.516       1.9    -155   163
# Comp:  2               HeI5876     0.8867       1.9    -155   163
# Comp:  2          [OIII]5007_d      1.298       2.4    -155   163
# Comp:  2            [OI]6300_d      1.470       2.4    -155   163
# Comp:  2           [NII]6583_d      9.363       2.4    -155   163
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47       242
#  comp.  1:       -99       169
#  comp.  2:       -85       151
# chi2/DOF: 0.7751; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.229       1.9     -99   169
# Comp:  1                 Hbeta      2.250       1.9     -99   169
# Comp:  1                Halpha      6.263       1.9     -99   169
# Comp:  2             [SII]6716      1.843       1.8     -85   151
# Comp:  2             [SII]6731      3.680       1.8     -85   151
# Comp:  2              HeII4687      0.000       1.8     -85   151
# Comp:  2               HeI5876     0.3929       1.8     -85   151
# Comp:  2          [OIII]5007_d      1.030       2.3     -85   151
# Comp:  2            [OI]6300_d      8.643       2.3     -85   151
# Comp:  2           [NII]6583_d      6.937       2.3     -85   151
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39       236
#  comp.  1:      -100       164
#  comp.  2:        20       193
# chi2/DOF: 0.7728; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       108       319
#  comp.  1:       -85       139
#  comp.  2:      -166       172
# chi2/DOF: 0.7757; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       1.7     -85   139
# Comp:  1                 Hbeta     0.7689       1.7     -85   139
# Comp:  1                Halpha      5.378       1.7     -85   139
# Comp:  2             [SII]6716      3.010       1.9    -166   172
# Comp:  2             [SII]6731      7.616       1.9    -166   172
# Comp:  2              HeII4687      1.728       1.9    -166   172
# Comp:  2               HeI5876     0.2585       1.9    -166   172
# Comp:  2          [OIII]5007_d      4.113       2.4    -166   172
# Comp:  2            [OI]6300_d      5.140       2.4    -166   172
# Comp:  2           [NII]6583_d      7.603       2.4    -166   172
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        23       175
#  comp.  1:       -89       148
#  comp.  2:      -175       265
# chi2/DOF: 0.7738; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7297       1.8     -89   148
# Comp:  1                 Hbeta      3.755       1.8     -89   148
# Comp:  1                Halpha      7.665       1.8     -89   148
# Comp:  2             [SII]6716      5.002       2.4    -175   265
# Comp:  2             [SII]6731      1.620       2.4    -175   265
# Comp:  2              HeII4687      1.086       2.3    -175   265
# Comp:  2               HeI5876      2.139       2.3    -175   265
# Comp:  2          [OIII]5007_d     0.8667       2.9    -175   265
# Comp:  2            [OI]6300_d      4.245       2.9    -175   265
# Comp:  2           [NII]6583_d      9.268       2.9    -175   265
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37       358
#  comp.  1:       -94       201
#  comp.  2:       -14       206
# chi2/DOF: 0.7791; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       2.0     -94   201
# Comp:  1                 Hbeta      4.393       2.0     -94   201
# Comp:  1                Halpha      9.784       2.0     -94   201
# Comp:  2             [SII]6716      3.268       2.1     -14   206
# Comp:  2             [SII]6731      3.366       2.1     -14   206
# Comp:  2              HeII4687      0.000       2.1     -14   206
# Comp:  2               HeI5876      0.000       2.1     -14   206
# Comp:  2          [OIII]5007_d      4.339       2.6     -14   206
# Comp:  2            [OI]6300_d      4.486       2.6     -14   206
# Comp:  2           [NII]6583_d      10.06       2.6     -14   206
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7       307
#  comp.  1:      -102       215
#  comp.  2:       -84       175
# chi2/DOF: 0.7730; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.858       2.1    -102   215
# Comp:  1                 Hbeta      4.264       2.1    -102   215
# Comp:  1                Halpha      9.182       2.1    -102   215
# Comp:  2             [SII]6716      3.076       1.9     -84   175
# Comp:  2             [SII]6731      4.744       1.9     -84   175
# Comp:  2              HeII4687      0.000       1.9     -84   175
# Comp:  2               HeI5876      0.000       1.9     -84   175
# Comp:  2          [OIII]5007_d      9.054       2.4     -84   175
# Comp:  2            [OI]6300_d    0.05626       2.4     -84   175
# Comp:  2           [NII]6583_d      7.047       2.4     -84   175
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        52       161
#  comp.  1:       -36       163
#  comp.  2:       -50       199
# chi2/DOF: 0.7762; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.146       1.9     -36   163
# Comp:  1                 Hbeta      5.308       1.9     -36   163
# Comp:  1                Halpha      8.307       1.9     -36   163
# Comp:  2             [SII]6716      1.377       2.0     -50   199
# Comp:  2             [SII]6731      5.379       2.0     -50   199
# Comp:  2              HeII4687      0.000       2.0     -50   199
# Comp:  2               HeI5876      0.000       2.0     -50   199
# Comp:  2          [OIII]5007_d      6.839       2.6     -50   199
# Comp:  2            [OI]6300_d      2.800       2.6     -50   199
# Comp:  2           [NII]6583_d      10.67       2.6     -50   199
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42       255
#  comp.  1:       -83       208
#  comp.  2:      -138       191
# chi2/DOF: 0.7733; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       2.1     -83   208
# Comp:  1                 Hbeta      6.881       2.1     -83   208
# Comp:  1                Halpha      11.47       2.1     -83   208
# Comp:  2             [SII]6716      2.588       2.0    -138   191
# Comp:  2             [SII]6731      0.000       2.0    -138   191
# Comp:  2              HeII4687      1.057       2.0    -138   191
# Comp:  2               HeI5876     0.8779       2.0    -138   191
# Comp:  2          [OIII]5007_d      3.629       2.5    -138   191
# Comp:  2            [OI]6300_d      3.253       2.5    -138   191
# Comp:  2           [NII]6583_d      8.805       2.5    -138   191
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14       254
#  comp.  1:      -112       195
#  comp.  2:       -25       189
# chi2/DOF: 0.7705; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.110       2.0    -112   195
# Comp:  1                 Hbeta      7.059       2.0    -112   195
# Comp:  1                Halpha      8.074       2.0    -112   195
# Comp:  2             [SII]6716      2.080       2.0     -25   189
# Comp:  2             [SII]6731      6.024       2.0     -25   189
# Comp:  2              HeII4687      0.000       2.0     -25   189
# Comp:  2               HeI5876      0.000       2.0     -25   189
# Comp:  2          [OIII]5007_d      7.266       2.5     -25   189
# Comp:  2            [OI]6300_d      0.000       2.5     -25   189
# Comp:  2           [NII]6583_d      5.955       2.5     -25   189
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47       495
#  comp.  1:       -96       205
#  comp.  2:       -95       140
# chi2/DOF: 0.7748; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8510       2.1     -96   205
# Comp:  1                 Hbeta      5.924       2.1     -96   205
# Comp:  1                Halpha      9.822       2.1     -96   205
# Comp:  2             [SII]6716      4.414       1.7     -95   140
# Comp:  2             [SII]6731     0.5374       1.7     -95   140
# Comp:  2              HeII4687    0.02159       1.7     -95   140
# Comp:  2               HeI5876     0.7629       1.7     -95   140
# Comp:  2          [OIII]5007_d    0.05626       2.2     -95   140
# Comp:  2            [OI]6300_d     0.8537       2.2     -95   140
# Comp:  2           [NII]6583_d      7.497       2.2     -95   140
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8       719
#  comp.  1:      -106       198
#  comp.  2:       -77       271
# chi2/DOF: 0.7721; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.505       2.0    -106   198
# Comp:  1                 Hbeta      4.620       2.0    -106   198
# Comp:  1                Halpha      6.590       2.0    -106   198
# Comp:  2             [SII]6716      4.279       2.4     -77   271
# Comp:  2             [SII]6731      7.769       2.4     -77   271
# Comp:  2              HeII4687      0.000       2.3     -77   271
# Comp:  2               HeI5876      2.524       2.3     -77   271
# Comp:  2          [OIII]5007_d      4.025       3.0     -77   271
# Comp:  2            [OI]6300_d      11.22       3.0     -77   271
# Comp:  2           [NII]6583_d      8.541       3.0     -77   271
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       170       298
#  comp.  1:      -107       136
#  comp.  2:      -148       194
# chi2/DOF: 0.7755; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       1.7    -107   136
# Comp:  1                 Hbeta      2.536       1.7    -107   136
# Comp:  1                Halpha      6.389       1.7    -107   136
# Comp:  2             [SII]6716      3.249       2.0    -148   194
# Comp:  2             [SII]6731      6.200       2.0    -148   194
# Comp:  2              HeII4687      2.361       2.0    -148   194
# Comp:  2               HeI5876      0.000       2.0    -148   194
# Comp:  2          [OIII]5007_d     0.9417       2.5    -148   194
# Comp:  2            [OI]6300_d      5.162       2.5    -148   194
# Comp:  2           [NII]6583_d      8.885       2.5    -148   194
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2       191
#  comp.  1:      -107       176
#  comp.  2:      -111       164
# chi2/DOF: 0.7751; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000       1.9    -107   176
# Comp:  1                 Hbeta      4.960       1.9    -107   176
# Comp:  1                Halpha      7.747       1.9    -107   176
# Comp:  2             [SII]6716      4.703       1.9    -111   164
# Comp:  2             [SII]6731      0.000       1.9    -111   164
# Comp:  2              HeII4687     0.4409       1.9    -111   164
# Comp:  2               HeI5876      0.000       1.9    -111   164
# Comp:  2          [OIII]5007_d      2.030       2.4    -111   164
# Comp:  2            [OI]6300_d      5.265       2.4    -111   164
# Comp:  2           [NII]6583_d      7.440       2.4    -111   164
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -127       247
#  comp.  1:      -115       176
#  comp.  2:       -39       237
# chi2/DOF: 0.7753; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.795       1.9    -115   176
# Comp:  1                 Hbeta      5.389       1.9    -115   176
# Comp:  1                Halpha      7.329       1.9    -115   176
# Comp:  2             [SII]6716      3.874       2.2     -39   237
# Comp:  2             [SII]6731      5.519       2.2     -39   237
# Comp:  2              HeII4687      0.000       2.2     -39   237
# Comp:  2               HeI5876     0.9081       2.2     -39   237
# Comp:  2          [OIII]5007_d      6.622       2.8     -39   237
# Comp:  2            [OI]6300_d      8.482       2.8     -39   237
# Comp:  2           [NII]6583_d      11.56       2.8     -39   237
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54       158
#  comp.  1:       -58       204
#  comp.  2:      -162       121
# chi2/DOF: 0.7731; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.015       2.1     -58   204
# Comp:  1                 Hbeta      7.363       2.1     -58   204
# Comp:  1                Halpha      9.140       2.1     -58   204
# Comp:  2             [SII]6716      1.160       1.6    -162   121
# Comp:  2             [SII]6731      4.548       1.6    -162   121
# Comp:  2              HeII4687     0.4913       1.6    -162   121
# Comp:  2               HeI5876      0.000       1.6    -162   121
# Comp:  2          [OIII]5007_d     0.8776       2.1    -162   121
# Comp:  2            [OI]6300_d      1.198       2.1    -162   121
# Comp:  2           [NII]6583_d      5.936       2.1    -162   121
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([4.21724309, 3.76649446, 2.83988704, 1.93409961, 3.94744324,
#        0.7774791 , 0.80887275, 2.8090849 , 4.34371639, 2.57405008])

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 0.        ,  3.41364117,  9.94416228,  4.22980273,  4.48057325,
#         0.        ,  0.        ,  3.3621154 ,  7.18382544, 10.75281184])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_19_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_19", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_19_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_19_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_19_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0        Hgamma  0.000000    0.044232
# 1         Hbeta  0.035804    0.039504
# 2        Halpha  0.104298    0.029786
# 3     [SII]6716  0.044364    0.020286
# 4     [SII]6731  0.046994    0.041402
# 5      HeII4687  0.000000    0.008155
# 6       HeI5876  0.000000    0.008484
# 7  [OIII]5007_d  0.035263    0.029463
# 8    [OI]6300_d  0.075347    0.045559
# 9   [NII]6583_d  0.112780    0.026998
#           Name      Flux  Error_flux
# 0       Hgamma  0.000000    0.044232
# 1        Hbeta  0.035804    0.039504
# 2       Halpha  0.104298    0.029786
# 3    [SII]6716  0.044364    0.020286
# 4    [SII]6731  0.046994    0.041402
# 5     HeII4687  0.000000    0.008155
# 6      HeI5876  0.000000    0.008484
# 7   [OIII]4959  0.008816    0.029463
# 8   [OIII]5007  0.026447    0.029463
# 9     [OI]6300  0.056510    0.045559
# 10    [OI]6364  0.018837    0.045559
# 11   [NII]6548  0.028195    0.026998
# 12   [NII]6583  0.084585    0.026998

# %%
np.median(flux_rf_rebin)
# Out:
# 0.01048839836959537
