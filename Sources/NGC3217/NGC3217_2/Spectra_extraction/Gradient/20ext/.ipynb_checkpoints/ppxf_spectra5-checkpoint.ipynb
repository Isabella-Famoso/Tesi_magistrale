# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_5.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC5058/FORS2.2022-01-28T08_17_47.181/Spectra_extraction/Gradient/redshift_grad.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_5']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4314.03901503 4315.47324864 4316.90748224 ... 6874.1460011  6875.58023471
#  6877.01446832] [0.04643947 0.05099981 0.041547   ... 0.03803973 0.04121944 0.04263735] [0.00722337 0.00722337 0.00722337 ... 0.00722337 0.00722337 0.00722337]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        63
# chi2/DOF: 0.02008; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        70
# chi2/DOF: 0.01290; DOF: 1886; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-14.24235454,  70.13441039])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        96
#  comp.  1:       -28        58
#  comp.  2:        -6        97
# chi2/DOF: 0.7753; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.853      0.35     -28    58
# Comp:  1                 Hbeta      1.262      0.35     -28    58
# Comp:  1                Halpha      3.263      0.35     -28    58
# Comp:  2             [SII]6716      1.549      0.40      -6    97
# Comp:  2             [SII]6731      1.453      0.40      -6    97
# Comp:  2              HeII4687     0.5207      0.40      -6    97
# Comp:  2               HeI5876      0.000      0.40      -6    97
# Comp:  2          [OIII]5007_d      1.613      0.50      -6    97
# Comp:  2            [OI]6300_d      1.379      0.50      -6    97
# Comp:  2           [NII]6583_d      2.309      0.50      -6    97
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  4.615; gas flux:      2 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  2.975; gas flux:      1 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:   7.95; gas flux:      4 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  2.857; gas flux:      2 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  2.734; gas flux:      2 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.9585; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   2.27; gas flux:      2 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.955; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  3.239; gas flux:      3 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        75
#  comp.  1:       -24        59
#  comp.  2:       -28       128
# chi2/DOF: 0.7697; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 18/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.044      0.35     -24    59
# Comp:  1                 Hbeta      1.338      0.35     -24    59
# Comp:  1                Halpha      3.321      0.35     -24    59
# Comp:  2             [SII]6716      1.482      0.44     -28   128
# Comp:  2             [SII]6731      2.032      0.44     -28   128
# Comp:  2              HeII4687     0.4371      0.44     -28   128
# Comp:  2               HeI5876    0.05387      0.44     -28   128
# Comp:  2          [OIII]5007_d      1.982      0.56     -28   128
# Comp:  2            [OI]6300_d      1.803      0.56     -28   128
# Comp:  2           [NII]6583_d      2.469      0.56     -28   128
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25       107
#  comp.  1:       -25        69
#  comp.  2:       -15        95
# chi2/DOF: 0.7686; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.661      0.36     -25    69
# Comp:  1                 Hbeta      1.734      0.36     -25    69
# Comp:  1                Halpha      3.595      0.36     -25    69
# Comp:  2             [SII]6716      1.219      0.40     -15    95
# Comp:  2             [SII]6731      1.488      0.40     -15    95
# Comp:  2              HeII4687      0.000      0.40     -15    95
# Comp:  2               HeI5876      0.000      0.40     -15    95
# Comp:  2          [OIII]5007_d      1.599      0.50     -15    95
# Comp:  2            [OI]6300_d      1.618      0.50     -15    95
# Comp:  2           [NII]6583_d      2.693      0.50     -15    95
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        75
#  comp.  1:       -28        55
#  comp.  2:        -0        97
# chi2/DOF: 0.7695; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.137      0.34     -28    55
# Comp:  1                 Hbeta      1.567      0.34     -28    55
# Comp:  1                Halpha      3.242      0.34     -28    55
# Comp:  2             [SII]6716      1.475      0.40      -0    97
# Comp:  2             [SII]6731      1.116      0.40      -0    97
# Comp:  2              HeII4687     0.1792      0.40      -0    97
# Comp:  2               HeI5876   0.003110      0.40      -0    97
# Comp:  2          [OIII]5007_d      1.924      0.50      -0    97
# Comp:  2            [OI]6300_d      1.443      0.50      -0    97
# Comp:  2           [NII]6583_d      2.462      0.50      -0    97
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        90
#  comp.  1:       -26        64
#  comp.  2:       -31        98
# chi2/DOF: 0.7704; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.269      0.35     -26    64
# Comp:  1                 Hbeta      1.420      0.35     -26    64
# Comp:  1                Halpha      3.427      0.35     -26    64
# Comp:  2             [SII]6716      1.265      0.40     -31    98
# Comp:  2             [SII]6731      1.137      0.40     -31    98
# Comp:  2              HeII4687     0.6632      0.40     -31    98
# Comp:  2               HeI5876    0.03411      0.40     -31    98
# Comp:  2          [OIII]5007_d      1.215      0.51     -31    98
# Comp:  2            [OI]6300_d      1.907      0.51     -31    98
# Comp:  2           [NII]6583_d      2.460      0.51     -31    98
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        55
#  comp.  1:       -32        52
#  comp.  2:       -32        92
# chi2/DOF: 0.7676; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.113      0.34     -32    52
# Comp:  1                 Hbeta      1.560      0.34     -32    52
# Comp:  1                Halpha      3.358      0.34     -32    52
# Comp:  2             [SII]6716      1.549      0.39     -32    92
# Comp:  2             [SII]6731      1.417      0.39     -32    92
# Comp:  2              HeII4687     0.4381      0.39     -32    92
# Comp:  2               HeI5876     0.1067      0.39     -32    92
# Comp:  2          [OIII]5007_d      1.562      0.50     -32    92
# Comp:  2            [OI]6300_d      1.534      0.50     -32    92
# Comp:  2           [NII]6583_d      1.916      0.50     -32    92
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21       116
#  comp.  1:       -27        55
#  comp.  2:       -18       109
# chi2/DOF: 0.7711; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.871      0.34     -27    55
# Comp:  1                 Hbeta      1.150      0.34     -27    55
# Comp:  1                Halpha      3.276      0.34     -27    55
# Comp:  2             [SII]6716      1.415      0.42     -18   109
# Comp:  2             [SII]6731      1.975      0.42     -18   109
# Comp:  2              HeII4687     0.6633      0.42     -18   109
# Comp:  2               HeI5876      0.000      0.42     -18   109
# Comp:  2          [OIII]5007_d      1.877      0.53     -18   109
# Comp:  2            [OI]6300_d      1.546      0.53     -18   109
# Comp:  2           [NII]6583_d      2.588      0.53     -18   109
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39       107
#  comp.  1:       -32        51
#  comp.  2:         8       101
# chi2/DOF: 0.7699; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.932      0.34     -32    51
# Comp:  1                 Hbeta      1.127      0.34     -32    51
# Comp:  1                Halpha      3.227      0.34     -32    51
# Comp:  2             [SII]6716      1.391      0.40       8   101
# Comp:  2             [SII]6731      1.917      0.40       8   101
# Comp:  2              HeII4687     0.5196      0.40       8   101
# Comp:  2               HeI5876      0.000      0.40       8   101
# Comp:  2          [OIII]5007_d      1.720      0.51       8   101
# Comp:  2            [OI]6300_d      1.764      0.51       8   101
# Comp:  2           [NII]6583_d      2.577      0.51       8   101
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        68
#  comp.  1:       -23        55
#  comp.  2:        33       125
# chi2/DOF: 0.7663; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.669      0.34     -23    55
# Comp:  1                 Hbeta      1.184      0.34     -23    55
# Comp:  1                Halpha      3.207      0.34     -23    55
# Comp:  2             [SII]6716      1.177      0.44      33   125
# Comp:  2             [SII]6731      2.441      0.44      33   125
# Comp:  2              HeII4687    0.09118      0.44      33   125
# Comp:  2               HeI5876    0.02150      0.44      33   125
# Comp:  2          [OIII]5007_d      1.547      0.55      33   125
# Comp:  2            [OI]6300_d     0.9788      0.55      33   125
# Comp:  2           [NII]6583_d      2.428      0.55      33   125
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        74
#  comp.  1:       -23        59
#  comp.  2:        -4       107
# chi2/DOF: 0.7682; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.492      0.35     -23    59
# Comp:  1                 Hbeta      1.684      0.35     -23    59
# Comp:  1                Halpha      3.310      0.35     -23    59
# Comp:  2             [SII]6716      2.119      0.41      -4   107
# Comp:  2             [SII]6731      1.863      0.41      -4   107
# Comp:  2              HeII4687     0.5285      0.41      -4   107
# Comp:  2               HeI5876     0.2455      0.41      -4   107
# Comp:  2          [OIII]5007_d      1.843      0.52      -4   107
# Comp:  2            [OI]6300_d      2.348      0.52      -4   107
# Comp:  2           [NII]6583_d      2.863      0.52      -4   107
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9       120
#  comp.  1:       -26        69
#  comp.  2:       -19       107
# chi2/DOF: 0.7688; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.342      0.36     -26    69
# Comp:  1                 Hbeta      1.913      0.36     -26    69
# Comp:  1                Halpha      3.383      0.36     -26    69
# Comp:  2             [SII]6716      1.548      0.41     -19   107
# Comp:  2             [SII]6731      1.025      0.41     -19   107
# Comp:  2              HeII4687     0.4862      0.41     -19   107
# Comp:  2               HeI5876      0.000      0.41     -19   107
# Comp:  2          [OIII]5007_d      1.730      0.52     -19   107
# Comp:  2            [OI]6300_d      1.801      0.52     -19   107
# Comp:  2           [NII]6583_d      2.557      0.52     -19   107
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        81
#  comp.  1:       -25        64
#  comp.  2:       -25       110
# chi2/DOF: 0.7707; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.064      0.35     -25    64
# Comp:  1                 Hbeta      1.300      0.35     -25    64
# Comp:  1                Halpha      3.642      0.35     -25    64
# Comp:  2             [SII]6716      1.964      0.42     -25   110
# Comp:  2             [SII]6731      1.805      0.42     -25   110
# Comp:  2              HeII4687     0.4253      0.42     -25   110
# Comp:  2               HeI5876    0.02518      0.42     -25   110
# Comp:  2          [OIII]5007_d      1.573      0.53     -25   110
# Comp:  2            [OI]6300_d      2.229      0.53     -25   110
# Comp:  2           [NII]6583_d      2.770      0.53     -25   110
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        94
#  comp.  1:       -31        61
#  comp.  2:        26        94
# chi2/DOF: 0.7665; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.189      0.35     -31    61
# Comp:  1                 Hbeta      1.769      0.35     -31    61
# Comp:  1                Halpha      3.448      0.35     -31    61
# Comp:  2             [SII]6716      1.615      0.39      26    94
# Comp:  2             [SII]6731      1.456      0.39      26    94
# Comp:  2              HeII4687      0.000      0.39      26    94
# Comp:  2               HeI5876     0.1731      0.39      26    94
# Comp:  2          [OIII]5007_d      1.518      0.50      26    94
# Comp:  2            [OI]6300_d      1.263      0.50      26    94
# Comp:  2           [NII]6583_d      2.244      0.50      26    94
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        87
#  comp.  1:       -21        59
#  comp.  2:        -9       126
# chi2/DOF: 0.7676; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.885      0.35     -21    59
# Comp:  1                 Hbeta      1.557      0.35     -21    59
# Comp:  1                Halpha      3.435      0.35     -21    59
# Comp:  2             [SII]6716      1.700      0.44      -9   126
# Comp:  2             [SII]6731      2.169      0.44      -9   126
# Comp:  2              HeII4687      1.361      0.44      -9   126
# Comp:  2               HeI5876    0.02997      0.44      -9   126
# Comp:  2          [OIII]5007_d      1.853      0.56      -9   126
# Comp:  2            [OI]6300_d      1.882      0.56      -9   126
# Comp:  2           [NII]6583_d      2.977      0.56      -9   126
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        84
#  comp.  1:       -34        46
#  comp.  2:       -10        73
# chi2/DOF: 0.7663; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.454      0.33     -34    46
# Comp:  1                 Hbeta     0.7749      0.33     -34    46
# Comp:  1                Halpha      3.131      0.33     -34    46
# Comp:  2             [SII]6716      1.729      0.37     -10    73
# Comp:  2             [SII]6731      1.077      0.37     -10    73
# Comp:  2              HeII4687     0.7740      0.37     -10    73
# Comp:  2               HeI5876      0.000      0.37     -10    73
# Comp:  2          [OIII]5007_d      1.383      0.46     -10    73
# Comp:  2            [OI]6300_d      1.332      0.46     -10    73
# Comp:  2           [NII]6583_d      1.901      0.46     -10    73
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        54
#  comp.  1:       -26        56
#  comp.  2:         0        94
# chi2/DOF: 0.7670; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.874      0.34     -26    56
# Comp:  1                 Hbeta      1.343      0.34     -26    56
# Comp:  1                Halpha      3.384      0.34     -26    56
# Comp:  2             [SII]6716      1.457      0.40       0    94
# Comp:  2             [SII]6731      1.869      0.40       0    94
# Comp:  2              HeII4687     0.5391      0.40       0    94
# Comp:  2               HeI5876     0.1379      0.40       0    94
# Comp:  2          [OIII]5007_d      1.748      0.50       0    94
# Comp:  2            [OI]6300_d      1.369      0.50       0    94
# Comp:  2           [NII]6583_d      2.004      0.50       0    94
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        63
#  comp.  1:       -25        56
#  comp.  2:        12        97
# chi2/DOF: 0.7667; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.860      0.34     -25    56
# Comp:  1                 Hbeta      1.433      0.34     -25    56
# Comp:  1                Halpha      3.221      0.34     -25    56
# Comp:  2             [SII]6716      1.480      0.40      12    97
# Comp:  2             [SII]6731      2.162      0.40      12    97
# Comp:  2              HeII4687     0.3293      0.40      12    97
# Comp:  2               HeI5876      0.000      0.40      12    97
# Comp:  2          [OIII]5007_d      1.657      0.50      12    97
# Comp:  2            [OI]6300_d      1.670      0.50      12    97
# Comp:  2           [NII]6583_d      2.082      0.50      12    97
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        90
#  comp.  1:       -32        61
#  comp.  2:         6       118
# chi2/DOF: 0.7689; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.653      0.35     -32    61
# Comp:  1                 Hbeta      1.205      0.35     -32    61
# Comp:  1                Halpha      3.504      0.35     -32    61
# Comp:  2             [SII]6716      2.043      0.43       6   118
# Comp:  2             [SII]6731      1.751      0.43       6   118
# Comp:  2              HeII4687     0.3515      0.43       6   118
# Comp:  2               HeI5876      0.000      0.43       6   118
# Comp:  2          [OIII]5007_d      1.717      0.54       6   118
# Comp:  2            [OI]6300_d      1.915      0.54       6   118
# Comp:  2           [NII]6583_d      2.911      0.54       6   118
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32       103
#  comp.  1:       -28        59
#  comp.  2:        33        99
# chi2/DOF: 0.7664; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.228      0.35     -28    59
# Comp:  1                 Hbeta      1.378      0.35     -28    59
# Comp:  1                Halpha      3.361      0.35     -28    59
# Comp:  2             [SII]6716      1.984      0.40      33    99
# Comp:  2             [SII]6731      1.509      0.40      33    99
# Comp:  2              HeII4687     0.8624      0.40      33    99
# Comp:  2               HeI5876      0.000      0.40      33    99
# Comp:  2          [OIII]5007_d      1.716      0.51      33    99
# Comp:  2            [OI]6300_d      1.443      0.51      33    99
# Comp:  2           [NII]6583_d      2.169      0.51      33    99
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        83
#  comp.  1:       -30        58
#  comp.  2:        -1       120
# chi2/DOF: 0.7685; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.801      0.35     -30    58
# Comp:  1                 Hbeta      1.213      0.35     -30    58
# Comp:  1                Halpha      3.278      0.35     -30    58
# Comp:  2             [SII]6716      2.004      0.43      -1   120
# Comp:  2             [SII]6731      2.016      0.43      -1   120
# Comp:  2              HeII4687     0.6673      0.43      -1   120
# Comp:  2               HeI5876      0.000      0.43      -1   120
# Comp:  2          [OIII]5007_d      1.964      0.54      -1   120
# Comp:  2            [OI]6300_d      1.949      0.54      -1   120
# Comp:  2           [NII]6583_d      2.166      0.54      -1   120
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        71
#  comp.  1:       -33        65
#  comp.  2:        -8       119
# chi2/DOF: 0.7685; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.525      0.36     -33    65
# Comp:  1                 Hbeta      2.073      0.36     -33    65
# Comp:  1                Halpha      3.721      0.36     -33    65
# Comp:  2             [SII]6716      1.542      0.43      -8   119
# Comp:  2             [SII]6731      2.020      0.43      -8   119
# Comp:  2              HeII4687      0.000      0.43      -8   119
# Comp:  2               HeI5876    0.07344      0.43      -8   119
# Comp:  2          [OIII]5007_d      1.714      0.54      -8   119
# Comp:  2            [OI]6300_d      2.108      0.54      -8   119
# Comp:  2           [NII]6583_d      2.520      0.54      -8   119
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        70
#  comp.  1:       -26        63
#  comp.  2:       -27        96
# chi2/DOF: 0.7681; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.453      0.35     -26    63
# Comp:  1                 Hbeta      1.527      0.35     -26    63
# Comp:  1                Halpha      3.738      0.35     -26    63
# Comp:  2             [SII]6716      1.928      0.40     -27    96
# Comp:  2             [SII]6731      1.500      0.40     -27    96
# Comp:  2              HeII4687     0.3923      0.40     -27    96
# Comp:  2               HeI5876      0.000      0.40     -27    96
# Comp:  2          [OIII]5007_d      1.378      0.50     -27    96
# Comp:  2            [OI]6300_d      1.031      0.50     -27    96
# Comp:  2           [NII]6583_d      2.638      0.50     -27    96
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12       100
#  comp.  1:       -26        63
#  comp.  2:        -9        87
# chi2/DOF: 0.7695; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.473      0.35     -26    63
# Comp:  1                 Hbeta      1.394      0.35     -26    63
# Comp:  1                Halpha      3.575      0.35     -26    63
# Comp:  2             [SII]6716      1.661      0.38      -9    87
# Comp:  2             [SII]6731      1.115      0.38      -9    87
# Comp:  2              HeII4687     0.3934      0.38      -9    87
# Comp:  2               HeI5876     0.3769      0.38      -9    87
# Comp:  2          [OIII]5007_d      1.894      0.49      -9    87
# Comp:  2            [OI]6300_d     0.8787      0.49      -9    87
# Comp:  2           [NII]6583_d      2.573      0.49      -9    87
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27       109
#  comp.  1:       -31        59
#  comp.  2:        -5       111
# chi2/DOF: 0.7645; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.956      0.35     -31    59
# Comp:  1                 Hbeta      1.290      0.35     -31    59
# Comp:  1                Halpha      3.699      0.35     -31    59
# Comp:  2             [SII]6716      1.995      0.42      -5   111
# Comp:  2             [SII]6731      1.620      0.42      -5   111
# Comp:  2              HeII4687     0.3525      0.42      -5   111
# Comp:  2               HeI5876      0.000      0.42      -5   111
# Comp:  2          [OIII]5007_d      1.923      0.53      -5   111
# Comp:  2            [OI]6300_d      1.053      0.53      -5   111
# Comp:  2           [NII]6583_d      2.760      0.53      -5   111
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        94
#  comp.  1:       -26        63
#  comp.  2:        14       102
# chi2/DOF: 0.7644; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.532      0.35     -26    63
# Comp:  1                 Hbeta      1.768      0.35     -26    63
# Comp:  1                Halpha      3.429      0.35     -26    63
# Comp:  2             [SII]6716      1.763      0.41      14   102
# Comp:  2             [SII]6731      1.971      0.41      14   102
# Comp:  2              HeII4687      0.000      0.41      14   102
# Comp:  2               HeI5876      0.000      0.41      14   102
# Comp:  2          [OIII]5007_d      1.328      0.51      14   102
# Comp:  2            [OI]6300_d      1.552      0.51      14   102
# Comp:  2           [NII]6583_d      2.600      0.51      14   102
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        78
#  comp.  1:       -28        61
#  comp.  2:       -30       101
# chi2/DOF: 0.7669; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.693      0.35     -28    61
# Comp:  1                 Hbeta      1.738      0.35     -28    61
# Comp:  1                Halpha      3.662      0.35     -28    61
# Comp:  2             [SII]6716      1.258      0.41     -30   101
# Comp:  2             [SII]6731      1.636      0.41     -30   101
# Comp:  2              HeII4687     0.2914      0.41     -30   101
# Comp:  2               HeI5876    0.05762      0.41     -30   101
# Comp:  2          [OIII]5007_d      1.830      0.51     -30   101
# Comp:  2            [OI]6300_d      1.655      0.51     -30   101
# Comp:  2           [NII]6583_d      2.530      0.51     -30   101
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6       115
#  comp.  1:       -19        59
#  comp.  2:        -8       121
# chi2/DOF: 0.7688; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.952      0.35     -19    59
# Comp:  1                 Hbeta      1.584      0.35     -19    59
# Comp:  1                Halpha      3.681      0.35     -19    59
# Comp:  2             [SII]6716      1.856      0.43      -8   121
# Comp:  2             [SII]6731      1.129      0.43      -8   121
# Comp:  2              HeII4687     0.7016      0.43      -8   121
# Comp:  2               HeI5876      0.000      0.43      -8   121
# Comp:  2          [OIII]5007_d      2.269      0.55      -8   121
# Comp:  2            [OI]6300_d      1.382      0.55      -8   121
# Comp:  2           [NII]6583_d      2.814      0.55      -8   121
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        81
#  comp.  1:       -25        59
#  comp.  2:       -18       123
# chi2/DOF: 0.7721; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.989      0.35     -25    59
# Comp:  1                 Hbeta      1.327      0.35     -25    59
# Comp:  1                Halpha      3.208      0.35     -25    59
# Comp:  2             [SII]6716      1.492      0.44     -18   123
# Comp:  2             [SII]6731      1.234      0.44     -18   123
# Comp:  2              HeII4687     0.6174      0.44     -18   123
# Comp:  2               HeI5876      0.000      0.44     -18   123
# Comp:  2          [OIII]5007_d      2.013      0.55     -18   123
# Comp:  2            [OI]6300_d      1.975      0.55     -18   123
# Comp:  2           [NII]6583_d      2.435      0.55     -18   123
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38       117
#  comp.  1:       -27        57
#  comp.  2:        -6        89
# chi2/DOF: 0.7668; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.687      0.34     -27    57
# Comp:  1                 Hbeta      1.128      0.34     -27    57
# Comp:  1                Halpha      3.128      0.34     -27    57
# Comp:  2             [SII]6716      1.401      0.39      -6    89
# Comp:  2             [SII]6731      1.480      0.39      -6    89
# Comp:  2              HeII4687     0.9655      0.39      -6    89
# Comp:  2               HeI5876     0.1323      0.39      -6    89
# Comp:  2          [OIII]5007_d      1.409      0.49      -6    89
# Comp:  2            [OI]6300_d      1.807      0.49      -6    89
# Comp:  2           [NII]6583_d      2.767      0.49      -6    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16        44
#  comp.  1:       -20        59
#  comp.  2:        -1       105
# chi2/DOF: 0.7633; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.825      0.35     -20    59
# Comp:  1                 Hbeta      1.585      0.35     -20    59
# Comp:  1                Halpha      3.525      0.35     -20    59
# Comp:  2             [SII]6716      1.442      0.41      -1   105
# Comp:  2             [SII]6731      1.489      0.41      -1   105
# Comp:  2              HeII4687     0.6394      0.41      -1   105
# Comp:  2               HeI5876      0.000      0.41      -1   105
# Comp:  2          [OIII]5007_d      1.390      0.52      -1   105
# Comp:  2            [OI]6300_d      1.485      0.52      -1   105
# Comp:  2           [NII]6583_d      2.568      0.52      -1   105
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        85
#  comp.  1:       -28        61
#  comp.  2:        -0       110
# chi2/DOF: 0.7699; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.638      0.35     -28    61
# Comp:  1                 Hbeta      1.599      0.35     -28    61
# Comp:  1                Halpha      3.184      0.35     -28    61
# Comp:  2             [SII]6716      1.635      0.42      -0   110
# Comp:  2             [SII]6731      1.477      0.42      -0   110
# Comp:  2              HeII4687     0.3260      0.42      -0   110
# Comp:  2               HeI5876     0.2070      0.42      -0   110
# Comp:  2          [OIII]5007_d      1.730      0.53      -0   110
# Comp:  2            [OI]6300_d      1.256      0.53      -0   110
# Comp:  2           [NII]6583_d      2.079      0.53      -0   110
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        85
#  comp.  1:       -30        64
#  comp.  2:        -1       117
# chi2/DOF: 0.7707; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.247      0.35     -30    64
# Comp:  1                 Hbeta      1.570      0.35     -30    64
# Comp:  1                Halpha      3.512      0.35     -30    64
# Comp:  2             [SII]6716      1.246      0.43      -1   117
# Comp:  2             [SII]6731      1.237      0.43      -1   117
# Comp:  2              HeII4687     0.8640      0.43      -1   117
# Comp:  2               HeI5876     0.1876      0.43      -1   117
# Comp:  2          [OIII]5007_d      1.578      0.54      -1   117
# Comp:  2            [OI]6300_d     0.8391      0.54      -1   117
# Comp:  2           [NII]6583_d      2.051      0.54      -1   117
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30       121
#  comp.  1:       -33        69
#  comp.  2:       -19        74
# chi2/DOF: 0.7702; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.668      0.36     -33    69
# Comp:  1                 Hbeta      1.629      0.36     -33    69
# Comp:  1                Halpha      3.369      0.36     -33    69
# Comp:  2             [SII]6716      1.607      0.37     -19    74
# Comp:  2             [SII]6731      1.508      0.37     -19    74
# Comp:  2              HeII4687     0.7681      0.37     -19    74
# Comp:  2               HeI5876      0.000      0.37     -19    74
# Comp:  2          [OIII]5007_d      1.350      0.46     -19    74
# Comp:  2            [OI]6300_d      1.193      0.46     -19    74
# Comp:  2           [NII]6583_d      2.324      0.46     -19    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21       143
#  comp.  1:       -25        73
#  comp.  2:       -13       111
# chi2/DOF: 0.7701; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 19/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.084      0.37     -25    73
# Comp:  1                 Hbeta      1.269      0.37     -25    73
# Comp:  1                Halpha      3.627      0.37     -25    73
# Comp:  2             [SII]6716      1.909      0.42     -13   111
# Comp:  2             [SII]6731      2.167      0.42     -13   111
# Comp:  2              HeII4687     0.3064      0.42     -13   111
# Comp:  2               HeI5876     0.1248      0.42     -13   111
# Comp:  2          [OIII]5007_d      2.103      0.53     -13   111
# Comp:  2            [OI]6300_d      1.888      0.53     -13   111
# Comp:  2           [NII]6583_d      2.667      0.53     -13   111
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        72
#  comp.  1:       -29        63
#  comp.  2:        31        97
# chi2/DOF: 0.7648; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.307      0.35     -29    63
# Comp:  1                 Hbeta      1.800      0.35     -29    63
# Comp:  1                Halpha      3.489      0.35     -29    63
# Comp:  2             [SII]6716      1.881      0.40      31    97
# Comp:  2             [SII]6731      1.467      0.40      31    97
# Comp:  2              HeII4687      0.000      0.40      31    97
# Comp:  2               HeI5876     0.1055      0.40      31    97
# Comp:  2          [OIII]5007_d      1.868      0.50      31    97
# Comp:  2            [OI]6300_d      1.648      0.50      31    97
# Comp:  2           [NII]6583_d      1.900      0.50      31    97
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        55
#  comp.  1:       -27        47
#  comp.  2:         7       107
# chi2/DOF: 0.7691; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.990      0.33     -27    47
# Comp:  1                 Hbeta     0.8932      0.33     -27    47
# Comp:  1                Halpha      3.003      0.33     -27    47
# Comp:  2             [SII]6716      1.595      0.41       7   107
# Comp:  2             [SII]6731      1.895      0.41       7   107
# Comp:  2              HeII4687     0.1892      0.41       7   107
# Comp:  2               HeI5876      0.000      0.41       7   107
# Comp:  2          [OIII]5007_d      1.828      0.52       7   107
# Comp:  2            [OI]6300_d     0.9676      0.52       7   107
# Comp:  2           [NII]6583_d      2.366      0.52       7   107
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        98
#  comp.  1:       -28        57
#  comp.  2:       -25       130
# chi2/DOF: 0.7691; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.386      0.34     -28    57
# Comp:  1                 Hbeta      1.254      0.34     -28    57
# Comp:  1                Halpha      3.218      0.34     -28    57
# Comp:  2             [SII]6716      1.561      0.45     -25   130
# Comp:  2             [SII]6731      1.556      0.45     -25   130
# Comp:  2              HeII4687     0.6643      0.45     -25   130
# Comp:  2               HeI5876     0.1455      0.45     -25   130
# Comp:  2          [OIII]5007_d      1.638      0.56     -25   130
# Comp:  2            [OI]6300_d      2.246      0.56     -25   130
# Comp:  2           [NII]6583_d      1.823      0.56     -25   130
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        85
#  comp.  1:       -27        63
#  comp.  2:         0        90
# chi2/DOF: 0.7705; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.902      0.35     -27    63
# Comp:  1                 Hbeta      1.173      0.35     -27    63
# Comp:  1                Halpha      3.473      0.35     -27    63
# Comp:  2             [SII]6716      1.532      0.39       0    90
# Comp:  2             [SII]6731      1.963      0.39       0    90
# Comp:  2              HeII4687     0.8436      0.39       0    90
# Comp:  2               HeI5876      0.000      0.39       0    90
# Comp:  2          [OIII]5007_d      1.571      0.49       0    90
# Comp:  2            [OI]6300_d     0.9592      0.49       0    90
# Comp:  2           [NII]6583_d      2.777      0.49       0    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        78
#  comp.  1:       -30        62
#  comp.  2:       -20        92
# chi2/DOF: 0.7699; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.613      0.35     -30    62
# Comp:  1                 Hbeta      1.317      0.35     -30    62
# Comp:  1                Halpha      3.506      0.35     -30    62
# Comp:  2             [SII]6716      1.539      0.39     -20    92
# Comp:  2             [SII]6731      1.534      0.39     -20    92
# Comp:  2              HeII4687     0.8310      0.39     -20    92
# Comp:  2               HeI5876    0.03365      0.39     -20    92
# Comp:  2          [OIII]5007_d      1.883      0.50     -20    92
# Comp:  2            [OI]6300_d     0.8128      0.50     -20    92
# Comp:  2           [NII]6583_d      2.223      0.50     -20    92
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        53
#  comp.  1:       -24        60
#  comp.  2:        -1       108
# chi2/DOF: 0.7675; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.360      0.35     -24    60
# Comp:  1                 Hbeta      1.747      0.35     -24    60
# Comp:  1                Halpha      3.579      0.35     -24    60
# Comp:  2             [SII]6716      1.404      0.41      -1   108
# Comp:  2             [SII]6731      1.135      0.41      -1   108
# Comp:  2              HeII4687     0.8817      0.41      -1   108
# Comp:  2               HeI5876    0.09987      0.41      -1   108
# Comp:  2          [OIII]5007_d      2.051      0.52      -1   108
# Comp:  2            [OI]6300_d      2.178      0.52      -1   108
# Comp:  2           [NII]6583_d      2.761      0.52      -1   108
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3       139
#  comp.  1:       -25        57
#  comp.  2:        27       104
# chi2/DOF: 0.7668; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        37
#  comp.  1:       -34        51
#  comp.  2:       -18        90
# chi2/DOF: 0.7679; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.625      0.34     -34    51
# Comp:  1                 Hbeta      1.379      0.34     -34    51
# Comp:  1                Halpha      3.172      0.34     -34    51
# Comp:  2             [SII]6716      1.767      0.39     -18    90
# Comp:  2             [SII]6731      1.538      0.39     -18    90
# Comp:  2              HeII4687      0.000      0.39     -18    90
# Comp:  2               HeI5876   0.003044      0.39     -18    90
# Comp:  2          [OIII]5007_d      1.364      0.49     -18    90
# Comp:  2            [OI]6300_d      1.400      0.49     -18    90
# Comp:  2           [NII]6583_d      2.143      0.49     -18    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        22       103
#  comp.  1:       -20        58
#  comp.  2:        15       115
# chi2/DOF: 0.7663; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.865      0.35     -20    58
# Comp:  1                 Hbeta      1.176      0.35     -20    58
# Comp:  1                Halpha      3.019      0.35     -20    58
# Comp:  2             [SII]6716      1.067      0.42      15   115
# Comp:  2             [SII]6731      1.431      0.42      15   115
# Comp:  2              HeII4687     0.9238      0.42      15   115
# Comp:  2               HeI5876     0.2236      0.42      15   115
# Comp:  2          [OIII]5007_d      2.070      0.54      15   115
# Comp:  2            [OI]6300_d     0.8886      0.54      15   115
# Comp:  2           [NII]6583_d      2.274      0.54      15   115
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        59
#  comp.  1:       -36        58
#  comp.  2:        16       125
# chi2/DOF: 0.7671; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.615      0.35     -36    58
# Comp:  1                 Hbeta      1.493      0.35     -36    58
# Comp:  1                Halpha      3.354      0.35     -36    58
# Comp:  2             [SII]6716      1.953      0.44      16   125
# Comp:  2             [SII]6731      2.143      0.44      16   125
# Comp:  2              HeII4687      1.209      0.44      16   125
# Comp:  2               HeI5876      0.000      0.44      16   125
# Comp:  2          [OIII]5007_d      1.499      0.55      16   125
# Comp:  2            [OI]6300_d      1.696      0.55      16   125
# Comp:  2           [NII]6583_d      3.189      0.55      16   125
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32       125
#  comp.  1:       -25        53
#  comp.  2:         3        72
# chi2/DOF: 0.7681; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.127      0.34     -25    53
# Comp:  1                 Hbeta      1.015      0.34     -25    53
# Comp:  1                Halpha      3.051      0.34     -25    53
# Comp:  2             [SII]6716      1.433      0.36       3    72
# Comp:  2             [SII]6731     0.9652      0.36       3    72
# Comp:  2              HeII4687     0.6219      0.36       3    72
# Comp:  2               HeI5876     0.1407      0.36       3    72
# Comp:  2          [OIII]5007_d      1.182      0.46       3    72
# Comp:  2            [OI]6300_d     0.8375      0.46       3    72
# Comp:  2           [NII]6583_d      1.788      0.46       3    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        62
#  comp.  1:       -25        52
#  comp.  2:         8        85
# chi2/DOF: 0.7653; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.336      0.34     -25    52
# Comp:  1                 Hbeta      1.327      0.34     -25    52
# Comp:  1                Halpha      3.188      0.34     -25    52
# Comp:  2             [SII]6716      1.529      0.38       8    85
# Comp:  2             [SII]6731      1.441      0.38       8    85
# Comp:  2              HeII4687     0.5744      0.38       8    85
# Comp:  2               HeI5876     0.2754      0.38       8    85
# Comp:  2          [OIII]5007_d      1.331      0.48       8    85
# Comp:  2            [OI]6300_d     0.9514      0.48       8    85
# Comp:  2           [NII]6583_d      2.588      0.48       8    85
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        73
#  comp.  1:       -26        58
#  comp.  2:       -35        78
# chi2/DOF: 0.7668; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.824      0.35     -26    58
# Comp:  1                 Hbeta      1.271      0.35     -26    58
# Comp:  1                Halpha      3.055      0.35     -26    58
# Comp:  2             [SII]6716      1.073      0.37     -35    78
# Comp:  2             [SII]6731      1.142      0.37     -35    78
# Comp:  2              HeII4687     0.4653      0.37     -35    78
# Comp:  2               HeI5876      0.000      0.37     -35    78
# Comp:  2          [OIII]5007_d      1.501      0.47     -35    78
# Comp:  2            [OI]6300_d      1.331      0.47     -35    78
# Comp:  2           [NII]6583_d      1.849      0.47     -35    78
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55       112
#  comp.  1:       -36        52
#  comp.  2:        -5        72
# chi2/DOF: 0.7691; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.728      0.34     -36    52
# Comp:  1                 Hbeta     0.9708      0.34     -36    52
# Comp:  1                Halpha      3.091      0.34     -36    52
# Comp:  2             [SII]6716      1.498      0.36      -5    72
# Comp:  2             [SII]6731      1.404      0.36      -5    72
# Comp:  2              HeII4687     0.5881      0.36      -5    72
# Comp:  2               HeI5876    0.08162      0.36      -5    72
# Comp:  2          [OIII]5007_d      1.276      0.46      -5    72
# Comp:  2            [OI]6300_d     0.8376      0.46      -5    72
# Comp:  2           [NII]6583_d      1.856      0.46      -5    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        95
#  comp.  1:       -34        62
#  comp.  2:        -4       102
# chi2/DOF: 0.7690; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.647      0.35     -34    62
# Comp:  1                 Hbeta      1.292      0.35     -34    62
# Comp:  1                Halpha      3.488      0.35     -34    62
# Comp:  2             [SII]6716      1.993      0.41      -4   102
# Comp:  2             [SII]6731      1.325      0.41      -4   102
# Comp:  2              HeII4687     0.6426      0.41      -4   102
# Comp:  2               HeI5876      0.000      0.41      -4   102
# Comp:  2          [OIII]5007_d      1.671      0.51      -4   102
# Comp:  2            [OI]6300_d     0.7590      0.51      -4   102
# Comp:  2           [NII]6583_d      2.740      0.51      -4   102
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21       107
#  comp.  1:       -28        67
#  comp.  2:        13       108
# chi2/DOF: 0.7695; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.143      0.36     -28    67
# Comp:  1                 Hbeta      1.433      0.36     -28    67
# Comp:  1                Halpha      3.374      0.36     -28    67
# Comp:  2             [SII]6716      1.393      0.41      13   108
# Comp:  2             [SII]6731      2.072      0.41      13   108
# Comp:  2              HeII4687     0.9924      0.41      13   108
# Comp:  2               HeI5876    0.04573      0.41      13   108
# Comp:  2          [OIII]5007_d      1.528      0.52      13   108
# Comp:  2            [OI]6300_d      1.831      0.52      13   108
# Comp:  2           [NII]6583_d      2.157      0.52      13   108
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        54
#  comp.  1:       -33        52
#  comp.  2:       -15        78
# chi2/DOF: 0.7683; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.286      0.34     -33    52
# Comp:  1                 Hbeta      1.631      0.34     -33    52
# Comp:  1                Halpha      3.336      0.34     -33    52
# Comp:  2             [SII]6716      1.452      0.37     -15    78
# Comp:  2             [SII]6731      1.255      0.37     -15    78
# Comp:  2              HeII4687    0.08342      0.37     -15    78
# Comp:  2               HeI5876    0.03107      0.37     -15    78
# Comp:  2          [OIII]5007_d      1.872      0.47     -15    78
# Comp:  2            [OI]6300_d      1.478      0.47     -15    78
# Comp:  2           [NII]6583_d      2.087      0.47     -15    78
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53       122
#  comp.  1:       -38        72
#  comp.  2:       -21       114
# chi2/DOF: 0.7670; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.757      0.36     -38    72
# Comp:  1                 Hbeta      1.189      0.36     -38    72
# Comp:  1                Halpha      3.510      0.36     -38    72
# Comp:  2             [SII]6716      1.632      0.42     -21   114
# Comp:  2             [SII]6731      1.494      0.42     -21   114
# Comp:  2              HeII4687     0.2319      0.42     -21   114
# Comp:  2               HeI5876     0.1817      0.42     -21   114
# Comp:  2          [OIII]5007_d      1.710      0.53     -21   114
# Comp:  2            [OI]6300_d      1.637      0.53     -21   114
# Comp:  2           [NII]6583_d      2.729      0.53     -21   114
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        87
#  comp.  1:       -33        57
#  comp.  2:         0       116
# chi2/DOF: 0.7698; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.222      0.34     -33    57
# Comp:  1                 Hbeta      1.559      0.34     -33    57
# Comp:  1                Halpha      3.466      0.34     -33    57
# Comp:  2             [SII]6716      1.542      0.43       0   116
# Comp:  2             [SII]6731      1.949      0.43       0   116
# Comp:  2              HeII4687     0.9019      0.43       0   116
# Comp:  2               HeI5876      0.000      0.43       0   116
# Comp:  2          [OIII]5007_d      1.459      0.54       0   116
# Comp:  2            [OI]6300_d      2.130      0.54       0   116
# Comp:  2           [NII]6583_d      2.669      0.54       0   116
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        31
#  comp.  1:       -19        55
#  comp.  2:       -19        65
# chi2/DOF: 0.7616; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.779      0.34     -19    55
# Comp:  1                 Hbeta      1.701      0.34     -19    55
# Comp:  1                Halpha      3.533      0.34     -19    55
# Comp:  2             [SII]6716      1.052      0.35     -19    65
# Comp:  2             [SII]6731      1.069      0.35     -19    65
# Comp:  2              HeII4687     0.6109      0.35     -19    65
# Comp:  2               HeI5876     0.2645      0.35     -19    65
# Comp:  2          [OIII]5007_d      1.436      0.45     -19    65
# Comp:  2            [OI]6300_d      1.133      0.45     -19    65
# Comp:  2           [NII]6583_d      2.443      0.45     -19    65
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.31280107, 0.26116223, 0.25589493, 0.3754459 , 0.55528345,
#        0.35282171, 0.113606  , 0.25702931, 0.53043799, 0.43316518])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_5_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_5", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_5_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_5_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_5_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
