# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_13.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_13']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4314.03901503 4315.47324864 4316.90748224 ... 6874.1460011  6875.58023471
#  6877.01446832] [0.1539124  0.13326414 0.12018722 ... 0.10426721 0.1047502  0.11375579] [0.01135101 0.01135101 0.01135101 ... 0.01135101 0.01135101 0.01135101]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -105        71
# chi2/DOF: 0.006469; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
#  Best Fit:       Vel     sigma
#  comp.  0:      -111        75
# chi2/DOF: 0.003210; DOF: 1868; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-110.57347248,   75.13224723])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -102        80
#  comp.  1:      -101        33
#  comp.  2:      -102        39
# chi2/DOF: 0.6652; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7424      0.19    -101    33
# Comp:  1                 Hbeta      2.148      0.19    -101    33
# Comp:  1                Halpha      8.373      0.19    -101    33
# Comp:  2             [SII]6716      2.530      0.20    -102    39
# Comp:  2             [SII]6731      1.703      0.20    -102    39
# Comp:  2              HeII4687      0.000      0.20    -102    39
# Comp:  2               HeI5876      0.000      0.20    -102    39
# Comp:  2          [OIII]5007_d      1.809      0.25    -102    39
# Comp:  2            [OI]6300_d     0.8220      0.25    -102    39
# Comp:  2           [NII]6583_d      4.747      0.25    -102    39
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  4.252; gas flux:      1 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  11.88; gas flux:      2 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  47.58; gas flux:     11 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  13.93; gas flux:      4 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  9.084; gas flux:      2 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  7.279; gas flux:      2 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  3.224; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  19.47; gas flux:      7 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -110        69
#  comp.  1:      -101        31
#  comp.  2:      -103        46
# chi2/DOF: 0.6588; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8610      0.19    -101    31
# Comp:  1                 Hbeta      2.107      0.19    -101    31
# Comp:  1                Halpha      8.179      0.19    -101    31
# Comp:  2             [SII]6716      2.674      0.20    -103    46
# Comp:  2             [SII]6731      1.862      0.20    -103    46
# Comp:  2              HeII4687    0.05419      0.20    -103    46
# Comp:  2               HeI5876    0.02114      0.20    -103    46
# Comp:  2          [OIII]5007_d      2.087      0.26    -103    46
# Comp:  2            [OI]6300_d     0.8573      0.26    -103    46
# Comp:  2           [NII]6583_d      4.803      0.26    -103    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98        78
#  comp.  1:      -101        34
#  comp.  2:      -101        39
# chi2/DOF: 0.6606; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7223      0.20    -101    34
# Comp:  1                 Hbeta      2.012      0.20    -101    34
# Comp:  1                Halpha      8.340      0.20    -101    34
# Comp:  2             [SII]6716      2.519      0.20    -101    39
# Comp:  2             [SII]6731      1.916      0.20    -101    39
# Comp:  2              HeII4687      0.000      0.20    -101    39
# Comp:  2               HeI5876    0.04423      0.20    -101    39
# Comp:  2          [OIII]5007_d      1.838      0.25    -101    39
# Comp:  2            [OI]6300_d     0.8690      0.25    -101    39
# Comp:  2           [NII]6583_d      4.705      0.25    -101    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -91        67
#  comp.  1:      -101        34
#  comp.  2:      -106        33
# chi2/DOF: 0.6582; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9329      0.19    -101    34
# Comp:  1                 Hbeta      2.055      0.19    -101    34
# Comp:  1                Halpha      8.348      0.19    -101    34
# Comp:  2             [SII]6716      2.376      0.19    -106    33
# Comp:  2             [SII]6731      1.555      0.19    -106    33
# Comp:  2              HeII4687      0.000      0.19    -106    33
# Comp:  2               HeI5876    0.04622      0.19    -106    33
# Comp:  2          [OIII]5007_d      1.795      0.25    -106    33
# Comp:  2            [OI]6300_d     0.9288      0.25    -106    33
# Comp:  2           [NII]6583_d      4.591      0.25    -106    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100        83
#  comp.  1:      -102        37
#  comp.  2:      -101        40
# chi2/DOF: 0.6593; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6308      0.20    -102    37
# Comp:  1                 Hbeta      2.052      0.20    -102    37
# Comp:  1                Halpha      8.419      0.20    -102    37
# Comp:  2             [SII]6716      2.451      0.20    -101    40
# Comp:  2             [SII]6731      1.784      0.20    -101    40
# Comp:  2              HeII4687      0.000      0.20    -101    40
# Comp:  2               HeI5876    0.02873      0.20    -101    40
# Comp:  2          [OIII]5007_d      1.836      0.25    -101    40
# Comp:  2            [OI]6300_d      1.005      0.25    -101    40
# Comp:  2           [NII]6583_d      4.823      0.25    -101    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -103        64
#  comp.  1:      -102        34
#  comp.  2:      -103        38
# chi2/DOF: 0.6581; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7741      0.19    -102    34
# Comp:  1                 Hbeta      2.000      0.19    -102    34
# Comp:  1                Halpha      8.395      0.19    -102    34
# Comp:  2             [SII]6716      2.424      0.20    -103    38
# Comp:  2             [SII]6731      1.892      0.20    -103    38
# Comp:  2              HeII4687      0.000      0.20    -103    38
# Comp:  2               HeI5876      0.000      0.20    -103    38
# Comp:  2          [OIII]5007_d      2.115      0.25    -103    38
# Comp:  2            [OI]6300_d     0.8396      0.25    -103    38
# Comp:  2           [NII]6583_d      4.648      0.25    -103    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -115        78
#  comp.  1:      -103        36
#  comp.  2:      -105        40
# chi2/DOF: 0.6579; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7068      0.20    -103    36
# Comp:  1                 Hbeta      2.095      0.20    -103    36
# Comp:  1                Halpha      8.421      0.20    -103    36
# Comp:  2             [SII]6716      2.497      0.20    -105    40
# Comp:  2             [SII]6731      1.951      0.20    -105    40
# Comp:  2              HeII4687    0.07862      0.20    -105    40
# Comp:  2               HeI5876    0.03789      0.20    -105    40
# Comp:  2          [OIII]5007_d      1.803      0.25    -105    40
# Comp:  2            [OI]6300_d     0.8750      0.25    -105    40
# Comp:  2           [NII]6583_d      4.693      0.25    -105    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -104        57
#  comp.  1:      -103        33
#  comp.  2:      -102        37
# chi2/DOF: 0.6591; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7144      0.19    -103    33
# Comp:  1                 Hbeta      2.167      0.19    -103    33
# Comp:  1                Halpha      8.273      0.19    -103    33
# Comp:  2             [SII]6716      2.576      0.20    -102    37
# Comp:  2             [SII]6731      1.565      0.20    -102    37
# Comp:  2              HeII4687   0.008384      0.20    -102    37
# Comp:  2               HeI5876   0.003730      0.20    -102    37
# Comp:  2          [OIII]5007_d      1.943      0.25    -102    37
# Comp:  2            [OI]6300_d     0.7881      0.25    -102    37
# Comp:  2           [NII]6583_d      4.645      0.25    -102    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -103        92
#  comp.  1:      -102        37
#  comp.  2:       -99        35
# chi2/DOF: 0.6596; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9201      0.20    -102    37
# Comp:  1                 Hbeta      2.109      0.20    -102    37
# Comp:  1                Halpha      8.477      0.20    -102    37
# Comp:  2             [SII]6716      2.526      0.20     -99    35
# Comp:  2             [SII]6731      1.923      0.20     -99    35
# Comp:  2              HeII4687    0.02828      0.20     -99    35
# Comp:  2               HeI5876    0.02225      0.20     -99    35
# Comp:  2          [OIII]5007_d      2.014      0.25     -99    35
# Comp:  2            [OI]6300_d     0.8154      0.25     -99    35
# Comp:  2           [NII]6583_d      4.728      0.25     -99    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -103        73
#  comp.  1:      -101        32
#  comp.  2:      -103        37
# chi2/DOF: 0.6623; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6934      0.19    -101    32
# Comp:  1                 Hbeta      2.002      0.19    -101    32
# Comp:  1                Halpha      8.310      0.19    -101    32
# Comp:  2             [SII]6716      2.565      0.20    -103    37
# Comp:  2             [SII]6731      1.821      0.20    -103    37
# Comp:  2              HeII4687  0.0008646      0.20    -103    37
# Comp:  2               HeI5876   0.006487      0.20    -103    37
# Comp:  2          [OIII]5007_d      1.501      0.25    -103    37
# Comp:  2            [OI]6300_d     0.8854      0.25    -103    37
# Comp:  2           [NII]6583_d      4.735      0.25    -103    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99       101
#  comp.  1:      -102        35
#  comp.  2:      -102        42
# chi2/DOF: 0.6587; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6827      0.20    -102    35
# Comp:  1                 Hbeta      2.194      0.20    -102    35
# Comp:  1                Halpha      8.469      0.20    -102    35
# Comp:  2             [SII]6716      2.517      0.20    -102    42
# Comp:  2             [SII]6731      1.611      0.20    -102    42
# Comp:  2              HeII4687    0.04415      0.20    -102    42
# Comp:  2               HeI5876    0.03319      0.20    -102    42
# Comp:  2          [OIII]5007_d      1.953      0.25    -102    42
# Comp:  2            [OI]6300_d      1.005      0.25    -102    42
# Comp:  2           [NII]6583_d      4.770      0.25    -102    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83        68
#  comp.  1:      -100        33
#  comp.  2:      -103        42
# chi2/DOF: 0.6606; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8466      0.19    -100    33
# Comp:  1                 Hbeta      2.362      0.19    -100    33
# Comp:  1                Halpha      8.446      0.19    -100    33
# Comp:  2             [SII]6716      2.563      0.20    -103    42
# Comp:  2             [SII]6731      1.645      0.20    -103    42
# Comp:  2              HeII4687      0.000      0.20    -103    42
# Comp:  2               HeI5876   0.001740      0.20    -103    42
# Comp:  2          [OIII]5007_d      1.637      0.25    -103    42
# Comp:  2            [OI]6300_d     0.9350      0.25    -103    42
# Comp:  2           [NII]6583_d      4.721      0.25    -103    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -90        86
#  comp.  1:      -102        35
#  comp.  2:      -100        39
# chi2/DOF: 0.6613; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7296      0.20    -102    35
# Comp:  1                 Hbeta      2.126      0.20    -102    35
# Comp:  1                Halpha      8.447      0.20    -102    35
# Comp:  2             [SII]6716      2.666      0.20    -100    39
# Comp:  2             [SII]6731      1.552      0.20    -100    39
# Comp:  2              HeII4687      0.000      0.20    -100    39
# Comp:  2               HeI5876   0.006894      0.20    -100    39
# Comp:  2          [OIII]5007_d      1.932      0.25    -100    39
# Comp:  2            [OI]6300_d     0.8372      0.25    -100    39
# Comp:  2           [NII]6583_d      4.826      0.25    -100    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -105        99
#  comp.  1:      -102        35
#  comp.  2:      -103        37
# chi2/DOF: 0.6587; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9183      0.20    -102    35
# Comp:  1                 Hbeta      2.190      0.20    -102    35
# Comp:  1                Halpha      8.458      0.20    -102    35
# Comp:  2             [SII]6716      2.544      0.20    -103    37
# Comp:  2             [SII]6731      1.695      0.20    -103    37
# Comp:  2              HeII4687    0.07468      0.20    -103    37
# Comp:  2               HeI5876    0.02282      0.20    -103    37
# Comp:  2          [OIII]5007_d      1.485      0.25    -103    37
# Comp:  2            [OI]6300_d     0.8286      0.25    -103    37
# Comp:  2           [NII]6583_d      4.832      0.25    -103    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -115        71
#  comp.  1:      -102        35
#  comp.  2:      -100        48
# chi2/DOF: 0.6583; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9040      0.20    -102    35
# Comp:  1                 Hbeta      2.140      0.20    -102    35
# Comp:  1                Halpha      8.480      0.20    -102    35
# Comp:  2             [SII]6716      2.586      0.20    -100    48
# Comp:  2             [SII]6731      1.753      0.20    -100    48
# Comp:  2              HeII4687    0.02482      0.20    -100    48
# Comp:  2               HeI5876    0.03547      0.20    -100    48
# Comp:  2          [OIII]5007_d      1.567      0.26    -100    48
# Comp:  2            [OI]6300_d     0.7760      0.26    -100    48
# Comp:  2           [NII]6583_d      4.914      0.26    -100    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -104        78
#  comp.  1:      -102        34
#  comp.  2:      -102        41
# chi2/DOF: 0.6582; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.051      0.20    -102    34
# Comp:  1                 Hbeta      2.288      0.20    -102    34
# Comp:  1                Halpha      8.577      0.20    -102    34
# Comp:  2             [SII]6716      2.694      0.20    -102    41
# Comp:  2             [SII]6731      1.749      0.20    -102    41
# Comp:  2              HeII4687    0.04758      0.20    -102    41
# Comp:  2               HeI5876    0.03320      0.20    -102    41
# Comp:  2          [OIII]5007_d      2.083      0.25    -102    41
# Comp:  2            [OI]6300_d     0.7628      0.25    -102    41
# Comp:  2           [NII]6583_d      4.843      0.25    -102    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -107        92
#  comp.  1:      -101        33
#  comp.  2:      -100        43
# chi2/DOF: 0.6595; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 18/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.071      0.19    -101    33
# Comp:  1                 Hbeta      2.284      0.19    -101    33
# Comp:  1                Halpha      8.577      0.19    -101    33
# Comp:  2             [SII]6716      2.654      0.20    -100    43
# Comp:  2             [SII]6731      1.773      0.20    -100    43
# Comp:  2              HeII4687      0.000      0.20    -100    43
# Comp:  2               HeI5876    0.07013      0.20    -100    43
# Comp:  2          [OIII]5007_d      1.627      0.25    -100    43
# Comp:  2            [OI]6300_d     0.8080      0.25    -100    43
# Comp:  2           [NII]6583_d      4.938      0.25    -100    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100        49
#  comp.  1:      -103        35
#  comp.  2:      -101        41
# chi2/DOF: 0.6566; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.019      0.20    -103    35
# Comp:  1                 Hbeta      2.226      0.20    -103    35
# Comp:  1                Halpha      8.397      0.20    -103    35
# Comp:  2             [SII]6716      2.412      0.20    -101    41
# Comp:  2             [SII]6731      1.881      0.20    -101    41
# Comp:  2              HeII4687      0.000      0.20    -101    41
# Comp:  2               HeI5876    0.01115      0.20    -101    41
# Comp:  2          [OIII]5007_d      1.600      0.25    -101    41
# Comp:  2            [OI]6300_d      1.062      0.25    -101    41
# Comp:  2           [NII]6583_d      4.789      0.25    -101    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -108        78
#  comp.  1:      -101        36
#  comp.  2:      -104        35
# chi2/DOF: 0.6610; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7988      0.20    -101    36
# Comp:  1                 Hbeta      2.142      0.20    -101    36
# Comp:  1                Halpha      8.619      0.20    -101    36
# Comp:  2             [SII]6716      2.491      0.20    -104    35
# Comp:  2             [SII]6731      1.632      0.20    -104    35
# Comp:  2              HeII4687    0.02094      0.20    -104    35
# Comp:  2               HeI5876    0.01966      0.20    -104    35
# Comp:  2          [OIII]5007_d      1.593      0.25    -104    35
# Comp:  2            [OI]6300_d     0.6543      0.25    -104    35
# Comp:  2           [NII]6583_d      4.756      0.25    -104    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -112        60
#  comp.  1:      -101        30
#  comp.  2:      -100        37
# chi2/DOF: 0.6590; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 18/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8666      0.19    -101    30
# Comp:  1                 Hbeta      2.470      0.19    -101    30
# Comp:  1                Halpha      8.426      0.19    -101    30
# Comp:  2             [SII]6716      2.428      0.20    -100    37
# Comp:  2             [SII]6731      1.768      0.20    -100    37
# Comp:  2              HeII4687    0.03424      0.20    -100    37
# Comp:  2               HeI5876    0.03490      0.20    -100    37
# Comp:  2          [OIII]5007_d      1.849      0.25    -100    37
# Comp:  2            [OI]6300_d     0.9188      0.25    -100    37
# Comp:  2           [NII]6583_d      4.744      0.25    -100    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86        83
#  comp.  1:      -101        33
#  comp.  2:      -101        47
# chi2/DOF: 0.6591; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6328      0.19    -101    33
# Comp:  1                 Hbeta      2.152      0.19    -101    33
# Comp:  1                Halpha      8.395      0.19    -101    33
# Comp:  2             [SII]6716      2.643      0.20    -101    47
# Comp:  2             [SII]6731      1.954      0.20    -101    47
# Comp:  2              HeII4687      0.000      0.20    -101    47
# Comp:  2               HeI5876      0.000      0.20    -101    47
# Comp:  2          [OIII]5007_d      2.059      0.26    -101    47
# Comp:  2            [OI]6300_d     0.9956      0.26    -101    47
# Comp:  2           [NII]6583_d      5.029      0.26    -101    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85        56
#  comp.  1:      -102        35
#  comp.  2:      -100        41
# chi2/DOF: 0.6606; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8979      0.20    -102    35
# Comp:  1                 Hbeta      2.379      0.20    -102    35
# Comp:  1                Halpha      8.534      0.20    -102    35
# Comp:  2             [SII]6716      2.430      0.20    -100    41
# Comp:  2             [SII]6731      1.839      0.20    -100    41
# Comp:  2              HeII4687      0.000      0.20    -100    41
# Comp:  2               HeI5876    0.03903      0.20    -100    41
# Comp:  2          [OIII]5007_d      1.817      0.25    -100    41
# Comp:  2            [OI]6300_d     0.7127      0.25    -100    41
# Comp:  2           [NII]6583_d      4.827      0.25    -100    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -103        87
#  comp.  1:      -101        32
#  comp.  2:      -106        48
# chi2/DOF: 0.6597; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7322      0.19    -101    32
# Comp:  1                 Hbeta      2.200      0.19    -101    32
# Comp:  1                Halpha      8.345      0.19    -101    32
# Comp:  2             [SII]6716      2.563      0.20    -106    48
# Comp:  2             [SII]6731      1.663      0.20    -106    48
# Comp:  2              HeII4687    0.01206      0.20    -106    48
# Comp:  2               HeI5876    0.01420      0.20    -106    48
# Comp:  2          [OIII]5007_d      2.044      0.26    -106    48
# Comp:  2            [OI]6300_d     0.9436      0.26    -106    48
# Comp:  2           [NII]6583_d      4.899      0.26    -106    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96        66
#  comp.  1:      -103        37
#  comp.  2:      -101        37
# chi2/DOF: 0.6589; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.061      0.20    -103    37
# Comp:  1                 Hbeta      2.502      0.20    -103    37
# Comp:  1                Halpha      8.613      0.20    -103    37
# Comp:  2             [SII]6716      2.424      0.20    -101    37
# Comp:  2             [SII]6731      1.551      0.20    -101    37
# Comp:  2              HeII4687      0.000      0.20    -101    37
# Comp:  2               HeI5876    0.01640      0.20    -101    37
# Comp:  2          [OIII]5007_d      1.873      0.25    -101    37
# Comp:  2            [OI]6300_d     0.8280      0.25    -101    37
# Comp:  2           [NII]6583_d      4.826      0.25    -101    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -116        81
#  comp.  1:      -102        35
#  comp.  2:      -100        38
# chi2/DOF: 0.6595; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7375      0.20    -102    35
# Comp:  1                 Hbeta      2.182      0.20    -102    35
# Comp:  1                Halpha      8.372      0.20    -102    35
# Comp:  2             [SII]6716      2.588      0.20    -100    38
# Comp:  2             [SII]6731      1.825      0.20    -100    38
# Comp:  2              HeII4687      0.000      0.20    -100    38
# Comp:  2               HeI5876   0.005728      0.20    -100    38
# Comp:  2          [OIII]5007_d      1.760      0.25    -100    38
# Comp:  2            [OI]6300_d     0.6268      0.25    -100    38
# Comp:  2           [NII]6583_d      4.811      0.25    -100    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -103       103
#  comp.  1:      -103        36
#  comp.  2:      -102        39
# chi2/DOF: 0.6600; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8584      0.20    -103    36
# Comp:  1                 Hbeta      2.037      0.20    -103    36
# Comp:  1                Halpha      8.404      0.20    -103    36
# Comp:  2             [SII]6716      2.583      0.20    -102    39
# Comp:  2             [SII]6731      1.730      0.20    -102    39
# Comp:  2              HeII4687      0.000      0.20    -102    39
# Comp:  2               HeI5876    0.01572      0.20    -102    39
# Comp:  2          [OIII]5007_d      1.863      0.25    -102    39
# Comp:  2            [OI]6300_d     0.8700      0.25    -102    39
# Comp:  2           [NII]6583_d      4.658      0.25    -102    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97        76
#  comp.  1:      -102        35
#  comp.  2:      -103        43
# chi2/DOF: 0.6590; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8668      0.20    -102    35
# Comp:  1                 Hbeta      2.008      0.20    -102    35
# Comp:  1                Halpha      8.405      0.20    -102    35
# Comp:  2             [SII]6716      2.658      0.20    -103    43
# Comp:  2             [SII]6731      1.584      0.20    -103    43
# Comp:  2              HeII4687    0.01882      0.20    -103    43
# Comp:  2               HeI5876   0.005229      0.20    -103    43
# Comp:  2          [OIII]5007_d      1.817      0.25    -103    43
# Comp:  2            [OI]6300_d     0.7400      0.25    -103    43
# Comp:  2           [NII]6583_d      4.893      0.25    -103    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -93        60
#  comp.  1:      -100        31
#  comp.  2:      -104        43
# chi2/DOF: 0.6593; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7819      0.19    -100    31
# Comp:  1                 Hbeta      1.969      0.19    -100    31
# Comp:  1                Halpha      8.269      0.19    -100    31
# Comp:  2             [SII]6716      2.493      0.20    -104    43
# Comp:  2             [SII]6731      1.969      0.20    -104    43
# Comp:  2              HeII4687      0.000      0.20    -104    43
# Comp:  2               HeI5876    0.04467      0.20    -104    43
# Comp:  2          [OIII]5007_d      1.678      0.25    -104    43
# Comp:  2            [OI]6300_d     0.8268      0.25    -104    43
# Comp:  2           [NII]6583_d      4.809      0.25    -104    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -114        89
#  comp.  1:      -102        31
#  comp.  2:      -101        39
# chi2/DOF: 0.6609; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.5263      0.19    -102    31
# Comp:  1                 Hbeta      2.102      0.19    -102    31
# Comp:  1                Halpha      8.162      0.19    -102    31
# Comp:  2             [SII]6716      2.434      0.20    -101    39
# Comp:  2             [SII]6731      1.738      0.20    -101    39
# Comp:  2              HeII4687    0.07886      0.20    -101    39
# Comp:  2               HeI5876      0.000      0.20    -101    39
# Comp:  2          [OIII]5007_d      1.687      0.25    -101    39
# Comp:  2            [OI]6300_d     0.9372      0.25    -101    39
# Comp:  2           [NII]6583_d      4.790      0.25    -101    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99        53
#  comp.  1:      -101        33
#  comp.  2:      -103        39
# chi2/DOF: 0.6572; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.082      0.19    -101    33
# Comp:  1                 Hbeta      2.550      0.19    -101    33
# Comp:  1                Halpha      8.498      0.19    -101    33
# Comp:  2             [SII]6716      2.487      0.20    -103    39
# Comp:  2             [SII]6731      1.496      0.20    -103    39
# Comp:  2              HeII4687   0.002324      0.20    -103    39
# Comp:  2               HeI5876      0.000      0.20    -103    39
# Comp:  2          [OIII]5007_d      1.657      0.25    -103    39
# Comp:  2            [OI]6300_d     0.9219      0.25    -103    39
# Comp:  2           [NII]6583_d      4.765      0.25    -103    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -111        90
#  comp.  1:      -102        36
#  comp.  2:      -102        41
# chi2/DOF: 0.6602; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7085      0.20    -102    36
# Comp:  1                 Hbeta      2.151      0.20    -102    36
# Comp:  1                Halpha      8.478      0.20    -102    36
# Comp:  2             [SII]6716      2.545      0.20    -102    41
# Comp:  2             [SII]6731      1.755      0.20    -102    41
# Comp:  2              HeII4687      0.000      0.20    -102    41
# Comp:  2               HeI5876      0.000      0.20    -102    41
# Comp:  2          [OIII]5007_d      1.681      0.25    -102    41
# Comp:  2            [OI]6300_d     0.9254      0.25    -102    41
# Comp:  2           [NII]6583_d      4.898      0.25    -102    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -109        63
#  comp.  1:      -102        31
#  comp.  2:      -103        32
# chi2/DOF: 0.6600; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8135      0.19    -102    31
# Comp:  1                 Hbeta      2.119      0.19    -102    31
# Comp:  1                Halpha      8.301      0.19    -102    31
# Comp:  2             [SII]6716      2.559      0.19    -103    32
# Comp:  2             [SII]6731      1.544      0.19    -103    32
# Comp:  2              HeII4687    0.05124      0.19    -103    32
# Comp:  2               HeI5876      0.000      0.19    -103    32
# Comp:  2          [OIII]5007_d      2.040      0.24    -103    32
# Comp:  2            [OI]6300_d     0.8665      0.24    -103    32
# Comp:  2           [NII]6583_d      4.495      0.24    -103    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -106        70
#  comp.  1:      -102        32
#  comp.  2:      -101        39
# chi2/DOF: 0.6596; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7274      0.19    -102    32
# Comp:  1                 Hbeta      2.255      0.19    -102    32
# Comp:  1                Halpha      8.327      0.19    -102    32
# Comp:  2             [SII]6716      2.444      0.20    -101    39
# Comp:  2             [SII]6731      1.856      0.20    -101    39
# Comp:  2              HeII4687    0.04461      0.20    -101    39
# Comp:  2               HeI5876    0.02081      0.20    -101    39
# Comp:  2          [OIII]5007_d      1.645      0.25    -101    39
# Comp:  2            [OI]6300_d     0.8976      0.25    -101    39
# Comp:  2           [NII]6583_d      4.697      0.25    -101    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96        87
#  comp.  1:      -102        35
#  comp.  2:      -103        36
# chi2/DOF: 0.6590; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.5458      0.20    -102    35
# Comp:  1                 Hbeta      1.990      0.20    -102    35
# Comp:  1                Halpha      8.387      0.20    -102    35
# Comp:  2             [SII]6716      2.522      0.20    -103    36
# Comp:  2             [SII]6731      1.810      0.20    -103    36
# Comp:  2              HeII4687      0.000      0.20    -103    36
# Comp:  2               HeI5876      0.000      0.20    -103    36
# Comp:  2          [OIII]5007_d      1.920      0.25    -103    36
# Comp:  2            [OI]6300_d     0.8136      0.25    -103    36
# Comp:  2           [NII]6583_d      4.642      0.25    -103    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        79
#  comp.  1:      -101        34
#  comp.  2:      -104        30
# chi2/DOF: 0.6571; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7486      0.20    -101    34
# Comp:  1                 Hbeta      2.182      0.20    -101    34
# Comp:  1                Halpha      8.391      0.20    -101    34
# Comp:  2             [SII]6716      2.401      0.19    -104    30
# Comp:  2             [SII]6731      1.498      0.19    -104    30
# Comp:  2              HeII4687      0.000      0.19    -104    30
# Comp:  2               HeI5876   0.004484      0.19    -104    30
# Comp:  2          [OIII]5007_d      1.567      0.24    -104    30
# Comp:  2            [OI]6300_d     0.7799      0.24    -104    30
# Comp:  2           [NII]6583_d      4.629      0.24    -104    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -94        79
#  comp.  1:      -100        32
#  comp.  2:      -103        40
# chi2/DOF: 0.6588; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9081      0.19    -100    32
# Comp:  1                 Hbeta      2.215      0.19    -100    32
# Comp:  1                Halpha      8.433      0.19    -100    32
# Comp:  2             [SII]6716      2.472      0.20    -103    40
# Comp:  2             [SII]6731      1.913      0.20    -103    40
# Comp:  2              HeII4687      0.000      0.20    -103    40
# Comp:  2               HeI5876   0.004425      0.20    -103    40
# Comp:  2          [OIII]5007_d      1.629      0.25    -103    40
# Comp:  2            [OI]6300_d     0.6635      0.25    -103    40
# Comp:  2           [NII]6583_d      4.677      0.25    -103    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83        58
#  comp.  1:      -101        32
#  comp.  2:      -102        38
# chi2/DOF: 0.6590; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7891      0.19    -101    32
# Comp:  1                 Hbeta      1.908      0.19    -101    32
# Comp:  1                Halpha      8.232      0.19    -101    32
# Comp:  2             [SII]6716      2.479      0.20    -102    38
# Comp:  2             [SII]6731      1.766      0.20    -102    38
# Comp:  2              HeII4687   0.002428      0.20    -102    38
# Comp:  2               HeI5876      0.000      0.20    -102    38
# Comp:  2          [OIII]5007_d      1.927      0.25    -102    38
# Comp:  2            [OI]6300_d      1.015      0.25    -102    38
# Comp:  2           [NII]6583_d      4.801      0.25    -102    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96        70
#  comp.  1:      -100        31
#  comp.  2:       -98        35
# chi2/DOF: 0.6575; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 18/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9005      0.19    -100    31
# Comp:  1                 Hbeta      2.192      0.19    -100    31
# Comp:  1                Halpha      8.462      0.19    -100    31
# Comp:  2             [SII]6716      2.555      0.20     -98    35
# Comp:  2             [SII]6731      1.771      0.20     -98    35
# Comp:  2              HeII4687    0.04515      0.20     -98    35
# Comp:  2               HeI5876    0.03952      0.20     -98    35
# Comp:  2          [OIII]5007_d      1.928      0.25     -98    35
# Comp:  2            [OI]6300_d     0.6194      0.25     -98    35
# Comp:  2           [NII]6583_d      4.796      0.25     -98    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98        45
#  comp.  1:      -101        30
#  comp.  2:      -104        37
# chi2/DOF: 0.6606; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7443      0.19    -101    30
# Comp:  1                 Hbeta      2.031      0.19    -101    30
# Comp:  1                Halpha      8.231      0.19    -101    30
# Comp:  2             [SII]6716      2.537      0.20    -104    37
# Comp:  2             [SII]6731      1.846      0.20    -104    37
# Comp:  2              HeII4687    0.04450      0.20    -104    37
# Comp:  2               HeI5876    0.02544      0.20    -104    37
# Comp:  2          [OIII]5007_d      1.605      0.25    -104    37
# Comp:  2            [OI]6300_d     0.7686      0.25    -104    37
# Comp:  2           [NII]6583_d      4.745      0.25    -104    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89        89
#  comp.  1:      -100        33
#  comp.  2:      -101        41
# chi2/DOF: 0.6593; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8479      0.19    -100    33
# Comp:  1                 Hbeta      2.424      0.19    -100    33
# Comp:  1                Halpha      8.416      0.19    -100    33
# Comp:  2             [SII]6716      2.504      0.20    -101    41
# Comp:  2             [SII]6731      1.859      0.20    -101    41
# Comp:  2              HeII4687      0.000      0.20    -101    41
# Comp:  2               HeI5876    0.03886      0.20    -101    41
# Comp:  2          [OIII]5007_d      1.588      0.25    -101    41
# Comp:  2            [OI]6300_d      1.060      0.25    -101    41
# Comp:  2           [NII]6583_d      4.846      0.25    -101    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -106        75
#  comp.  1:      -102        37
#  comp.  2:      -102        46
# chi2/DOF: 0.6577; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# Comp:  2           [NII]6583_d      4.843      0.25    -103    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -111        85
#  comp.  1:      -100        29
#  comp.  2:      -103        46
# chi2/DOF: 0.6604; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6187      0.19    -100    29
# Comp:  1                 Hbeta      1.916      0.19    -100    29
# Comp:  1                Halpha      8.144      0.19    -100    29
# Comp:  2             [SII]6716      2.575      0.20    -103    46
# Comp:  2             [SII]6731      1.690      0.20    -103    46
# Comp:  2              HeII4687      0.000      0.20    -103    46
# Comp:  2               HeI5876      0.000      0.20    -103    46
# Comp:  2          [OIII]5007_d      1.873      0.26    -103    46
# Comp:  2            [OI]6300_d     0.7539      0.26    -103    46
# Comp:  2           [NII]6583_d      4.953      0.26    -103    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95        79
#  comp.  1:      -102        34
#  comp.  2:      -103        40
# chi2/DOF: 0.6610; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7422      0.20    -102    34
# Comp:  1                 Hbeta      2.263      0.20    -102    34
# Comp:  1                Halpha      8.365      0.20    -102    34
# Comp:  2             [SII]6716      2.622      0.20    -103    40
# Comp:  2             [SII]6731      1.734      0.20    -103    40
# Comp:  2              HeII4687      0.000      0.20    -103    40
# Comp:  2               HeI5876      0.000      0.20    -103    40
# Comp:  2          [OIII]5007_d      1.906      0.25    -103    40
# Comp:  2            [OI]6300_d     0.9845      0.25    -103    40
# Comp:  2           [NII]6583_d      4.800      0.25    -103    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97        77
#  comp.  1:      -101        34
#  comp.  2:      -102        40
# chi2/DOF: 0.6587; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8756      0.20    -101    34
# Comp:  1                 Hbeta      2.029      0.20    -101    34
# Comp:  1                Halpha      8.419      0.20    -101    34
# Comp:  2             [SII]6716      2.614      0.20    -102    40
# Comp:  2             [SII]6731      1.757      0.20    -102    40
# Comp:  2              HeII4687      0.000      0.20    -102    40
# Comp:  2               HeI5876      0.000      0.20    -102    40
# Comp:  2          [OIII]5007_d      1.876      0.25    -102    40
# Comp:  2            [OI]6300_d     0.8358      0.25    -102    40
# Comp:  2           [NII]6583_d      4.709      0.25    -102    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -108        79
#  comp.  1:      -103        38
#  comp.  2:      -101        37
# chi2/DOF: 0.6613; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9878      0.20    -103    38
# Comp:  1                 Hbeta      2.292      0.20    -103    38
# Comp:  1                Halpha      8.655      0.20    -103    38
# Comp:  2             [SII]6716      2.583      0.20    -101    37
# Comp:  2             [SII]6731      1.589      0.20    -101    37
# Comp:  2              HeII4687      0.000      0.20    -101    37
# Comp:  2               HeI5876  0.0007600      0.20    -101    37
# Comp:  2          [OIII]5007_d      1.976      0.25    -101    37
# Comp:  2            [OI]6300_d     0.7354      0.25    -101    37
# Comp:  2           [NII]6583_d      4.676      0.25    -101    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -109        85
#  comp.  1:      -101        32
#  comp.  2:      -102        45
# chi2/DOF: 0.6599; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9892      0.19    -101    32
# Comp:  1                 Hbeta      2.288      0.19    -101    32
# Comp:  1                Halpha      8.453      0.19    -101    32
# Comp:  2             [SII]6716      2.509      0.20    -102    45
# Comp:  2             [SII]6731      1.809      0.20    -102    45
# Comp:  2              HeII4687    0.03073      0.20    -102    45
# Comp:  2               HeI5876    0.02943      0.20    -102    45
# Comp:  2          [OIII]5007_d      1.752      0.26    -102    45
# Comp:  2            [OI]6300_d     0.7178      0.26    -102    45
# Comp:  2           [NII]6583_d      4.982      0.26    -102    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -112        88
#  comp.  1:      -102        37
#  comp.  2:      -102        36
# chi2/DOF: 0.6603; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8303      0.20    -102    37
# Comp:  1                 Hbeta      2.075      0.20    -102    37
# Comp:  1                Halpha      8.466      0.20    -102    37
# Comp:  2             [SII]6716      2.545      0.20    -102    36
# Comp:  2             [SII]6731      1.543      0.20    -102    36
# Comp:  2              HeII4687      0.000      0.20    -102    36
# Comp:  2               HeI5876    0.04211      0.20    -102    36
# Comp:  2          [OIII]5007_d      1.712      0.25    -102    36
# Comp:  2            [OI]6300_d     0.7464      0.25    -102    36
# Comp:  2           [NII]6583_d      4.682      0.25    -102    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -107        89
#  comp.  1:      -101        32
#  comp.  2:      -104        32
# chi2/DOF: 0.6601; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6271      0.19    -101    32
# Comp:  1                 Hbeta      1.946      0.19    -101    32
# Comp:  1                Halpha      8.252      0.19    -101    32
# Comp:  2             [SII]6716      2.375      0.19    -104    32
# Comp:  2             [SII]6731      1.784      0.19    -104    32
# Comp:  2              HeII4687   0.005585      0.19    -104    32
# Comp:  2               HeI5876      0.000      0.19    -104    32
# Comp:  2          [OIII]5007_d      1.942      0.24    -104    32
# Comp:  2            [OI]6300_d     0.6795      0.24    -104    32
# Comp:  2           [NII]6583_d      4.551      0.24    -104    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97       100
#  comp.  1:      -101        34
#  comp.  2:      -104        37
# chi2/DOF: 0.6583; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9736      0.19    -101    34
# Comp:  1                 Hbeta      2.266      0.19    -101    34
# Comp:  1                Halpha      8.557      0.19    -101    34
# Comp:  2             [SII]6716      2.428      0.20    -104    37
# Comp:  2             [SII]6731      1.736      0.20    -104    37
# Comp:  2              HeII4687    0.03184      0.20    -104    37
# Comp:  2               HeI5876    0.02274      0.20    -104    37
# Comp:  2          [OIII]5007_d      1.760      0.25    -104    37
# Comp:  2            [OI]6300_d     0.6390      0.25    -104    37
# Comp:  2           [NII]6583_d      4.738      0.25    -104    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -109        81
#  comp.  1:      -100        30
#  comp.  2:      -103        42
# chi2/DOF: 0.6607; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8083      0.19    -100    30
# Comp:  1                 Hbeta      2.301      0.19    -100    30
# Comp:  1                Halpha      8.308      0.19    -100    30
# Comp:  2             [SII]6716      2.526      0.20    -103    42
# Comp:  2             [SII]6731      1.655      0.20    -103    42
# Comp:  2              HeII4687      0.000      0.20    -103    42
# Comp:  2               HeI5876      0.000      0.20    -103    42
# Comp:  2          [OIII]5007_d      1.920      0.25    -103    42
# Comp:  2            [OI]6300_d     0.9453      0.25    -103    42
# Comp:  2           [NII]6583_d      4.683      0.25    -103    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -104        63
#  comp.  1:      -102        33
#  comp.  2:       -99        42
# chi2/DOF: 0.6618; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9153      0.19    -102    33
# Comp:  1                 Hbeta      2.281      0.19    -102    33
# Comp:  1                Halpha      8.449      0.19    -102    33
# Comp:  2             [SII]6716      2.524      0.20     -99    42
# Comp:  2             [SII]6731      1.715      0.20     -99    42
# Comp:  2              HeII4687    0.04806      0.20     -99    42
# Comp:  2               HeI5876    0.03011      0.20     -99    42
# Comp:  2          [OIII]5007_d      1.747      0.25     -99    42
# Comp:  2            [OI]6300_d     0.8403      0.25     -99    42
# Comp:  2           [NII]6583_d      4.797      0.25     -99    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -93        66
#  comp.  1:      -102        32
#  comp.  2:      -100        37
# chi2/DOF: 0.6603; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9296      0.19    -102    32
# Comp:  1                 Hbeta      2.236      0.19    -102    32
# Comp:  1                Halpha      8.445      0.19    -102    32
# Comp:  2             [SII]6716      2.493      0.20    -100    37
# Comp:  2             [SII]6731      1.685      0.20    -100    37
# Comp:  2              HeII4687    0.03009      0.20    -100    37
# Comp:  2               HeI5876    0.01207      0.20    -100    37
# Comp:  2          [OIII]5007_d      1.970      0.25    -100    37
# Comp:  2            [OI]6300_d     0.8622      0.25    -100    37
# Comp:  2           [NII]6583_d      4.732      0.25    -100    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -109        92
#  comp.  1:      -102        36
#  comp.  2:       -99        31
# chi2/DOF: 0.6566; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9382      0.20    -102    36
# Comp:  1                 Hbeta      2.129      0.20    -102    36
# Comp:  1                Halpha      8.514      0.20    -102    36
# Comp:  2             [SII]6716      2.525      0.19     -99    31
# Comp:  2             [SII]6731      1.675      0.19     -99    31
# Comp:  2              HeII4687    0.05569      0.19     -99    31
# Comp:  2               HeI5876   0.009922      0.19     -99    31
# Comp:  2          [OIII]5007_d      1.768      0.24     -99    31
# Comp:  2            [OI]6300_d     0.8327      0.24     -99    31
# Comp:  2           [NII]6583_d      4.658      0.24     -99    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97        77
#  comp.  1:      -102        35
#  comp.  2:      -105        40
# chi2/DOF: 0.6598; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8388      0.20    -102    35
# Comp:  1                 Hbeta      2.289      0.20    -102    35
# Comp:  1                Halpha      8.426      0.20    -102    35
# Comp:  2             [SII]6716      2.489      0.20    -105    40
# Comp:  2             [SII]6731      1.829      0.20    -105    40
# Comp:  2              HeII4687    0.02900      0.20    -105    40
# Comp:  2               HeI5876    0.01641      0.20    -105    40
# Comp:  2          [OIII]5007_d      1.619      0.25    -105    40
# Comp:  2            [OI]6300_d     0.8943      0.25    -105    40
# Comp:  2           [NII]6583_d      4.822      0.25    -105    40
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_13_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_13", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_13_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_13_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_13_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
