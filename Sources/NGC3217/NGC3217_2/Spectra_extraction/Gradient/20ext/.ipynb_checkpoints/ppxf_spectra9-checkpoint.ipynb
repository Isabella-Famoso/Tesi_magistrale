# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_9.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_9']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4314.03901503 4315.47324864 4316.90748224 ... 6874.1460011  6875.58023471
#  6877.01446832] [0.15997095 0.19701766 0.16114094 ... 0.22143737 0.213975   0.21059985] [0.01341483 0.01341483 0.01341483 ... 0.01341483 0.01341483 0.01341483]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        61
# chi2/DOF: 0.002455; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        57
# chi2/DOF: 0.001629; DOF: 1875; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-19.42457297,  56.94009312])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        53
#  comp.  1:       -37        25
#  comp.  2:       -36        50
# chi2/DOF: 1.065; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.650      0.13     -37    25
# Comp:  1                 Hbeta      4.412      0.13     -37    25
# Comp:  1                Halpha      23.84      0.13     -37    25
# Comp:  2             [SII]6716      5.270      0.14     -36    50
# Comp:  2             [SII]6731      3.794      0.14     -36    50
# Comp:  2              HeII4687     0.1588      0.14     -36    50
# Comp:  2               HeI5876     0.5225      0.14     -36    50
# Comp:  2          [OIII]5007_d      2.427      0.18     -36    50
# Comp:  2            [OI]6300_d      1.424      0.18     -36    50
# Comp:  2           [NII]6583_d      12.93      0.18     -36    50
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  13.67; gas flux:      1 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  34.92; gas flux:      4 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:    195; gas flux:     33 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  37.24; gas flux:      7 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  25.85; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.126; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  3.698; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  12.75; gas flux:      3 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  7.132; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  67.85; gas flux:     18 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        35
#  comp.  1:       -39        21
#  comp.  2:       -29        71
# chi2/DOF: 1.002; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.759      0.13     -39    21
# Comp:  1                 Hbeta      4.517      0.13     -39    21
# Comp:  1                Halpha      23.65      0.13     -39    21
# Comp:  2             [SII]6716      6.353      0.15     -29    71
# Comp:  2             [SII]6731      3.963      0.15     -29    71
# Comp:  2              HeII4687    0.07008      0.15     -29    71
# Comp:  2               HeI5876     0.5930      0.15     -29    71
# Comp:  2          [OIII]5007_d      2.579      0.19     -29    71
# Comp:  2            [OI]6300_d      1.558      0.19     -29    71
# Comp:  2           [NII]6583_d      13.88      0.19     -29    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        66
#  comp.  1:       -37        22
#  comp.  2:       -30        60
# chi2/DOF: 1.024; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.736      0.13     -37    22
# Comp:  1                 Hbeta      4.464      0.13     -37    22
# Comp:  1                Halpha      24.19      0.13     -37    22
# Comp:  2             [SII]6716      6.219      0.15     -30    60
# Comp:  2             [SII]6731      3.948      0.15     -30    60
# Comp:  2              HeII4687    0.04061      0.15     -30    60
# Comp:  2               HeI5876     0.5779      0.15     -30    60
# Comp:  2          [OIII]5007_d      2.541      0.18     -30    60
# Comp:  2            [OI]6300_d      1.493      0.18     -30    60
# Comp:  2           [NII]6583_d      13.83      0.18     -30    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        49
#  comp.  1:       -39        25
#  comp.  2:       -33        56
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.740      0.13     -39    25
# Comp:  1                 Hbeta      4.398      0.13     -39    25
# Comp:  1                Halpha      23.49      0.13     -39    25
# Comp:  2             [SII]6716      5.630      0.14     -33    56
# Comp:  2             [SII]6731      4.154      0.14     -33    56
# Comp:  2              HeII4687     0.1442      0.14     -33    56
# Comp:  2               HeI5876     0.6252      0.14     -33    56
# Comp:  2          [OIII]5007_d      2.491      0.18     -33    56
# Comp:  2            [OI]6300_d      1.410      0.18     -33    56
# Comp:  2           [NII]6583_d      13.65      0.18     -33    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        52
#  comp.  1:       -37        24
#  comp.  2:       -34        55
# chi2/DOF: 1.054; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.547      0.13     -37    24
# Comp:  1                 Hbeta      3.997      0.13     -37    24
# Comp:  1                Halpha      23.74      0.13     -37    24
# Comp:  2             [SII]6716      5.652      0.14     -34    55
# Comp:  2             [SII]6731      3.887      0.14     -34    55
# Comp:  2              HeII4687     0.1320      0.14     -34    55
# Comp:  2               HeI5876     0.6094      0.14     -34    55
# Comp:  2          [OIII]5007_d      2.403      0.18     -34    55
# Comp:  2            [OI]6300_d      1.449      0.18     -34    55
# Comp:  2           [NII]6583_d      13.28      0.18     -34    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        42
#  comp.  1:       -35        24
#  comp.  2:       -36        55
# chi2/DOF: 1.046; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.688      0.13     -35    24
# Comp:  1                 Hbeta      4.569      0.13     -35    24
# Comp:  1                Halpha      24.28      0.13     -35    24
# Comp:  2             [SII]6716      5.559      0.14     -36    55
# Comp:  2             [SII]6731      3.849      0.14     -36    55
# Comp:  2              HeII4687     0.2055      0.14     -36    55
# Comp:  2               HeI5876     0.4986      0.14     -36    55
# Comp:  2          [OIII]5007_d      2.499      0.18     -36    55
# Comp:  2            [OI]6300_d      1.546      0.18     -36    55
# Comp:  2           [NII]6583_d      13.03      0.18     -36    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        59
#  comp.  1:       -36        29
#  comp.  2:       -38        53
# chi2/DOF: 1.043; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.635      0.13     -36    29
# Comp:  1                 Hbeta      4.442      0.13     -36    29
# Comp:  1                Halpha      24.29      0.13     -36    29
# Comp:  2             [SII]6716      5.404      0.14     -38    53
# Comp:  2             [SII]6731      3.706      0.14     -38    53
# Comp:  2              HeII4687     0.1930      0.14     -38    53
# Comp:  2               HeI5876     0.5184      0.14     -38    53
# Comp:  2          [OIII]5007_d      2.557      0.18     -38    53
# Comp:  2            [OI]6300_d      1.402      0.18     -38    53
# Comp:  2           [NII]6583_d      13.43      0.18     -38    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        59
#  comp.  1:       -35        25
#  comp.  2:       -34        48
# chi2/DOF: 1.046; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.374      0.13     -35    25
# Comp:  1                 Hbeta      4.538      0.13     -35    25
# Comp:  1                Halpha      24.13      0.13     -35    25
# Comp:  2             [SII]6716      5.420      0.14     -34    48
# Comp:  2             [SII]6731      3.856      0.14     -34    48
# Comp:  2              HeII4687     0.1617      0.14     -34    48
# Comp:  2               HeI5876     0.4984      0.14     -34    48
# Comp:  2          [OIII]5007_d      2.446      0.18     -34    48
# Comp:  2            [OI]6300_d      1.405      0.18     -34    48
# Comp:  2           [NII]6583_d      13.35      0.18     -34    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        39
#  comp.  1:       -37        21
#  comp.  2:       -34        57
# chi2/DOF: 1.039; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.884      0.13     -37    21
# Comp:  1                 Hbeta      4.524      0.13     -37    21
# Comp:  1                Halpha      24.06      0.13     -37    21
# Comp:  2             [SII]6716      5.541      0.14     -34    57
# Comp:  2             [SII]6731      3.625      0.14     -34    57
# Comp:  2              HeII4687     0.1098      0.14     -34    57
# Comp:  2               HeI5876     0.5330      0.14     -34    57
# Comp:  2          [OIII]5007_d      2.502      0.18     -34    57
# Comp:  2            [OI]6300_d      1.411      0.18     -34    57
# Comp:  2           [NII]6583_d      12.78      0.18     -34    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        53
#  comp.  1:       -39        24
#  comp.  2:       -38        42
# chi2/DOF: 1.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.550      0.13     -39    24
# Comp:  1                 Hbeta      4.492      0.13     -39    24
# Comp:  1                Halpha      23.37      0.13     -39    24
# Comp:  2             [SII]6716      4.674      0.14     -38    42
# Comp:  2             [SII]6731      3.474      0.14     -38    42
# Comp:  2              HeII4687     0.1938      0.14     -38    42
# Comp:  2               HeI5876     0.5222      0.14     -38    42
# Comp:  2          [OIII]5007_d      2.357      0.17     -38    42
# Comp:  2            [OI]6300_d      1.421      0.17     -38    42
# Comp:  2           [NII]6583_d      12.78      0.17     -38    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        63
#  comp.  1:       -36        30
#  comp.  2:       -37        49
# chi2/DOF: 1.032; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.863      0.13     -36    30
# Comp:  1                 Hbeta      4.908      0.13     -36    30
# Comp:  1                Halpha      23.80      0.13     -36    30
# Comp:  2             [SII]6716      5.309      0.14     -37    49
# Comp:  2             [SII]6731      4.231      0.14     -37    49
# Comp:  2              HeII4687     0.1599      0.14     -37    49
# Comp:  2               HeI5876     0.6068      0.14     -37    49
# Comp:  2          [OIII]5007_d      2.434      0.18     -37    49
# Comp:  2            [OI]6300_d      1.442      0.18     -37    49
# Comp:  2           [NII]6583_d      12.94      0.18     -37    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        52
#  comp.  1:       -37        20
#  comp.  2:       -38        49
# chi2/DOF: 1.043; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.736      0.13     -37    20
# Comp:  1                 Hbeta      4.297      0.13     -37    20
# Comp:  1                Halpha      23.88      0.13     -37    20
# Comp:  2             [SII]6716      4.936      0.14     -38    49
# Comp:  2             [SII]6731      3.813      0.14     -38    49
# Comp:  2              HeII4687     0.1137      0.14     -38    49
# Comp:  2               HeI5876     0.4578      0.14     -38    49
# Comp:  2          [OIII]5007_d      2.441      0.18     -38    49
# Comp:  2            [OI]6300_d      1.432      0.18     -38    49
# Comp:  2           [NII]6583_d      13.29      0.18     -38    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        47
#  comp.  1:       -35        30
#  comp.  2:       -36        46
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.752      0.13     -35    30
# Comp:  1                 Hbeta      4.729      0.13     -35    30
# Comp:  1                Halpha      24.32      0.13     -35    30
# Comp:  2             [SII]6716      5.041      0.14     -36    46
# Comp:  2             [SII]6731      4.089      0.14     -36    46
# Comp:  2              HeII4687    0.05753      0.14     -36    46
# Comp:  2               HeI5876     0.5237      0.14     -36    46
# Comp:  2          [OIII]5007_d      2.387      0.18     -36    46
# Comp:  2            [OI]6300_d      1.384      0.18     -36    46
# Comp:  2           [NII]6583_d      12.50      0.18     -36    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        81
#  comp.  1:       -35        30
#  comp.  2:       -34        43
# chi2/DOF: 1.027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.669      0.13     -35    30
# Comp:  1                 Hbeta      4.486      0.13     -35    30
# Comp:  1                Halpha      24.21      0.13     -35    30
# Comp:  2             [SII]6716      4.991      0.14     -34    43
# Comp:  2             [SII]6731      3.476      0.14     -34    43
# Comp:  2              HeII4687     0.2559      0.14     -34    43
# Comp:  2               HeI5876     0.4571      0.14     -34    43
# Comp:  2          [OIII]5007_d      2.342      0.17     -34    43
# Comp:  2            [OI]6300_d      1.429      0.17     -34    43
# Comp:  2           [NII]6583_d      12.87      0.17     -34    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        52
#  comp.  1:       -36        26
#  comp.  2:       -37        58
# chi2/DOF: 1.038; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.625      0.13     -36    26
# Comp:  1                 Hbeta      4.316      0.13     -36    26
# Comp:  1                Halpha      24.40      0.13     -36    26
# Comp:  2             [SII]6716      5.694      0.14     -37    58
# Comp:  2             [SII]6731      4.270      0.14     -37    58
# Comp:  2              HeII4687     0.2703      0.14     -37    58
# Comp:  2               HeI5876     0.4900      0.14     -37    58
# Comp:  2          [OIII]5007_d      2.427      0.18     -37    58
# Comp:  2            [OI]6300_d      1.499      0.18     -37    58
# Comp:  2           [NII]6583_d      12.92      0.18     -37    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        46
#  comp.  1:       -36        21
#  comp.  2:       -37        38
# chi2/DOF: 1.039; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.827      0.13     -36    21
# Comp:  1                 Hbeta      4.499      0.13     -36    21
# Comp:  1                Halpha      23.87      0.13     -36    21
# Comp:  2             [SII]6716      4.984      0.14     -37    38
# Comp:  2             [SII]6731      3.384      0.14     -37    38
# Comp:  2              HeII4687     0.1590      0.14     -37    38
# Comp:  2               HeI5876     0.5839      0.14     -37    38
# Comp:  2          [OIII]5007_d      2.356      0.17     -37    38
# Comp:  2            [OI]6300_d      1.425      0.17     -37    38
# Comp:  2           [NII]6583_d      11.95      0.17     -37    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        49
#  comp.  1:       -35        27
#  comp.  2:       -36        47
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.920      0.13     -35    27
# Comp:  1                 Hbeta      4.327      0.13     -35    27
# Comp:  1                Halpha      23.94      0.13     -35    27
# Comp:  2             [SII]6716      4.870      0.14     -36    47
# Comp:  2             [SII]6731      3.510      0.14     -36    47
# Comp:  2              HeII4687     0.1181      0.14     -36    47
# Comp:  2               HeI5876     0.6280      0.14     -36    47
# Comp:  2          [OIII]5007_d      2.455      0.18     -36    47
# Comp:  2            [OI]6300_d      1.480      0.18     -36    47
# Comp:  2           [NII]6583_d      12.49      0.18     -36    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        39
#  comp.  1:       -37        19
#  comp.  2:       -42        44
# chi2/DOF: 1.021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.843      0.13     -37    19
# Comp:  1                 Hbeta      4.216      0.13     -37    19
# Comp:  1                Halpha      23.75      0.13     -37    19
# Comp:  2             [SII]6716      4.982      0.14     -42    44
# Comp:  2             [SII]6731      3.754      0.14     -42    44
# Comp:  2              HeII4687     0.1275      0.14     -42    44
# Comp:  2               HeI5876     0.5825      0.14     -42    44
# Comp:  2          [OIII]5007_d      2.365      0.17     -42    44
# Comp:  2            [OI]6300_d      1.312      0.17     -42    44
# Comp:  2           [NII]6583_d      12.85      0.17     -42    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        59
#  comp.  1:       -36        29
#  comp.  2:       -35        42
# chi2/DOF: 1.033; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.552      0.13     -36    29
# Comp:  1                 Hbeta      4.439      0.13     -36    29
# Comp:  1                Halpha      23.74      0.13     -36    29
# Comp:  2             [SII]6716      4.594      0.14     -35    42
# Comp:  2             [SII]6731      3.780      0.14     -35    42
# Comp:  2              HeII4687     0.2438      0.14     -35    42
# Comp:  2               HeI5876     0.5991      0.14     -35    42
# Comp:  2          [OIII]5007_d      2.390      0.17     -35    42
# Comp:  2            [OI]6300_d      1.485      0.17     -35    42
# Comp:  2           [NII]6583_d      12.50      0.17     -35    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        48
#  comp.  1:       -36        25
#  comp.  2:       -36        42
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.450      0.13     -36    25
# Comp:  1                 Hbeta      4.549      0.13     -36    25
# Comp:  1                Halpha      23.67      0.13     -36    25
# Comp:  2             [SII]6716      5.064      0.14     -36    42
# Comp:  2             [SII]6731      3.467      0.14     -36    42
# Comp:  2              HeII4687     0.1353      0.14     -36    42
# Comp:  2               HeI5876     0.4922      0.14     -36    42
# Comp:  2          [OIII]5007_d      2.365      0.17     -36    42
# Comp:  2            [OI]6300_d      1.373      0.17     -36    42
# Comp:  2           [NII]6583_d      12.55      0.17     -36    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        22
#  comp.  1:       -36        24
#  comp.  2:       -32        68
# chi2/DOF: 1.019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.566      0.13     -36    24
# Comp:  1                 Hbeta      4.470      0.13     -36    24
# Comp:  1                Halpha      23.60      0.13     -36    24
# Comp:  2             [SII]6716      6.202      0.15     -32    68
# Comp:  2             [SII]6731      3.781      0.15     -32    68
# Comp:  2              HeII4687    0.09154      0.15     -32    68
# Comp:  2               HeI5876     0.5206      0.15     -32    68
# Comp:  2          [OIII]5007_d      2.651      0.19     -32    68
# Comp:  2            [OI]6300_d      1.520      0.19     -32    68
# Comp:  2           [NII]6583_d      13.16      0.19     -32    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        54
#  comp.  1:       -37        21
#  comp.  2:       -39        43
# chi2/DOF: 1.043; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.653      0.13     -37    21
# Comp:  1                 Hbeta      4.193      0.13     -37    21
# Comp:  1                Halpha      23.89      0.13     -37    21
# Comp:  2             [SII]6716      4.938      0.14     -39    43
# Comp:  2             [SII]6731      3.618      0.14     -39    43
# Comp:  2              HeII4687     0.2036      0.14     -39    43
# Comp:  2               HeI5876     0.5534      0.14     -39    43
# Comp:  2          [OIII]5007_d      2.369      0.17     -39    43
# Comp:  2            [OI]6300_d      1.466      0.17     -39    43
# Comp:  2           [NII]6583_d      12.52      0.17     -39    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        56
#  comp.  1:       -37        19
#  comp.  2:       -33        65
# chi2/DOF: 1.018; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.582      0.13     -37    19
# Comp:  1                 Hbeta      4.019      0.13     -37    19
# Comp:  1                Halpha      23.71      0.13     -37    19
# Comp:  2             [SII]6716      5.815      0.15     -33    65
# Comp:  2             [SII]6731      3.973      0.15     -33    65
# Comp:  2              HeII4687    0.06790      0.15     -33    65
# Comp:  2               HeI5876     0.5424      0.15     -33    65
# Comp:  2          [OIII]5007_d      2.599      0.19     -33    65
# Comp:  2            [OI]6300_d      1.426      0.19     -33    65
# Comp:  2           [NII]6583_d      14.08      0.19     -33    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        52
#  comp.  1:       -36        27
#  comp.  2:       -38        41
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.662      0.13     -36    27
# Comp:  1                 Hbeta      4.414      0.13     -36    27
# Comp:  1                Halpha      24.45      0.13     -36    27
# Comp:  2             [SII]6716      5.237      0.14     -38    41
# Comp:  2             [SII]6731      3.890      0.14     -38    41
# Comp:  2              HeII4687     0.1105      0.14     -38    41
# Comp:  2               HeI5876     0.5046      0.14     -38    41
# Comp:  2          [OIII]5007_d      2.413      0.17     -38    41
# Comp:  2            [OI]6300_d      1.320      0.17     -38    41
# Comp:  2           [NII]6583_d      12.54      0.17     -38    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        60
#  comp.  1:       -37        25
#  comp.  2:       -38        42
# chi2/DOF: 1.045; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.463      0.13     -37    25
# Comp:  1                 Hbeta      4.803      0.13     -37    25
# Comp:  1                Halpha      23.88      0.13     -37    25
# Comp:  2             [SII]6716      5.096      0.14     -38    42
# Comp:  2             [SII]6731      3.523      0.14     -38    42
# Comp:  2              HeII4687    0.09100      0.14     -38    42
# Comp:  2               HeI5876     0.5125      0.14     -38    42
# Comp:  2          [OIII]5007_d      2.302      0.17     -38    42
# Comp:  2            [OI]6300_d      1.357      0.17     -38    42
# Comp:  2           [NII]6583_d      12.60      0.17     -38    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        38
#  comp.  1:       -36        24
#  comp.  2:       -38        45
# chi2/DOF: 1.052; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.112      0.13     -36    24
# Comp:  1                 Hbeta      4.645      0.13     -36    24
# Comp:  1                Halpha      23.81      0.13     -36    24
# Comp:  2             [SII]6716      5.230      0.14     -38    45
# Comp:  2             [SII]6731      3.495      0.14     -38    45
# Comp:  2              HeII4687    0.06943      0.14     -38    45
# Comp:  2               HeI5876     0.4712      0.14     -38    45
# Comp:  2          [OIII]5007_d      2.425      0.18     -38    45
# Comp:  2            [OI]6300_d      1.388      0.18     -38    45
# Comp:  2           [NII]6583_d      13.09      0.18     -38    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        57
#  comp.  1:       -37        21
#  comp.  2:       -39        42
# chi2/DOF: 1.035; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.942      0.13     -37    21
# Comp:  1                 Hbeta      4.535      0.13     -37    21
# Comp:  1                Halpha      24.10      0.13     -37    21
# Comp:  2             [SII]6716      5.185      0.14     -39    42
# Comp:  2             [SII]6731      4.084      0.14     -39    42
# Comp:  2              HeII4687     0.1076      0.14     -39    42
# Comp:  2               HeI5876     0.5117      0.14     -39    42
# Comp:  2          [OIII]5007_d      2.410      0.17     -39    42
# Comp:  2            [OI]6300_d      1.437      0.17     -39    42
# Comp:  2           [NII]6583_d      12.50      0.17     -39    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        57
#  comp.  1:       -37        31
#  comp.  2:       -36        51
# chi2/DOF: 1.043; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.879      0.13     -37    31
# Comp:  1                 Hbeta      4.693      0.13     -37    31
# Comp:  1                Halpha      24.07      0.13     -37    31
# Comp:  2             [SII]6716      5.266      0.14     -36    51
# Comp:  2             [SII]6731      3.928      0.14     -36    51
# Comp:  2              HeII4687     0.1670      0.14     -36    51
# Comp:  2               HeI5876     0.5720      0.14     -36    51
# Comp:  2          [OIII]5007_d      2.431      0.18     -36    51
# Comp:  2            [OI]6300_d      1.462      0.18     -36    51
# Comp:  2           [NII]6583_d      13.03      0.18     -36    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        68
#  comp.  1:       -36        29
#  comp.  2:       -35        55
# chi2/DOF: 1.050; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.695      0.13     -36    29
# Comp:  1                 Hbeta      4.568      0.13     -36    29
# Comp:  1                Halpha      24.32      0.13     -36    29
# Comp:  2             [SII]6716      5.385      0.14     -35    55
# Comp:  2             [SII]6731      3.959      0.14     -35    55
# Comp:  2              HeII4687     0.2263      0.14     -35    55
# Comp:  2               HeI5876     0.5035      0.14     -35    55
# Comp:  2          [OIII]5007_d      2.477      0.18     -35    55
# Comp:  2            [OI]6300_d      1.359      0.18     -35    55
# Comp:  2           [NII]6583_d      13.57      0.18     -35    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33         1
#  comp.  1:       -38        21
#  comp.  2:       -32        54
# chi2/DOF: 1.041; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.692      0.13     -38    21
# Comp:  1                 Hbeta      4.229      0.13     -38    21
# Comp:  1                Halpha      23.40      0.13     -38    21
# Comp:  2             [SII]6716      5.731      0.14     -32    54
# Comp:  2             [SII]6731      3.909      0.14     -32    54
# Comp:  2              HeII4687     0.1540      0.14     -32    54
# Comp:  2               HeI5876     0.4141      0.14     -32    54
# Comp:  2          [OIII]5007_d      2.396      0.18     -32    54
# Comp:  2            [OI]6300_d      1.353      0.18     -32    54
# Comp:  2           [NII]6583_d      13.52      0.18     -32    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        57
#  comp.  1:       -38        25
#  comp.  2:       -39        45
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.841      0.13     -38    25
# Comp:  1                 Hbeta      4.586      0.13     -38    25
# Comp:  1                Halpha      24.00      0.13     -38    25
# Comp:  2             [SII]6716      5.363      0.14     -39    45
# Comp:  2             [SII]6731      3.808      0.14     -39    45
# Comp:  2              HeII4687    0.09995      0.14     -39    45
# Comp:  2               HeI5876     0.4853      0.14     -39    45
# Comp:  2          [OIII]5007_d      2.369      0.18     -39    45
# Comp:  2            [OI]6300_d      1.317      0.18     -39    45
# Comp:  2           [NII]6583_d      12.48      0.18     -39    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        56
#  comp.  1:       -35        24
#  comp.  2:       -34        61
# chi2/DOF: 1.031; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.858      0.13     -35    24
# Comp:  1                 Hbeta      4.661      0.13     -35    24
# Comp:  1                Halpha      24.32      0.13     -35    24
# Comp:  2             [SII]6716      5.636      0.15     -34    61
# Comp:  2             [SII]6731      4.183      0.15     -34    61
# Comp:  2              HeII4687     0.1408      0.15     -34    61
# Comp:  2               HeI5876     0.5067      0.15     -34    61
# Comp:  2          [OIII]5007_d      2.575      0.19     -34    61
# Comp:  2            [OI]6300_d      1.367      0.19     -34    61
# Comp:  2           [NII]6583_d      13.22      0.19     -34    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        54
#  comp.  1:       -38        23
#  comp.  2:       -33        65
# chi2/DOF: 1.003; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.662      0.13     -38    23
# Comp:  1                 Hbeta      4.648      0.13     -38    23
# Comp:  1                Halpha      23.06      0.13     -38    23
# Comp:  2             [SII]6716      5.481      0.15     -33    65
# Comp:  2             [SII]6731      3.649      0.15     -33    65
# Comp:  2              HeII4687     0.2100      0.15     -33    65
# Comp:  2               HeI5876     0.5910      0.15     -33    65
# Comp:  2          [OIII]5007_d      2.497      0.19     -33    65
# Comp:  2            [OI]6300_d      1.468      0.19     -33    65
# Comp:  2           [NII]6583_d      14.26      0.19     -33    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        54
#  comp.  1:       -38        21
#  comp.  2:       -39        42
# chi2/DOF: 1.019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.744      0.13     -38    21
# Comp:  1                 Hbeta      4.352      0.13     -38    21
# Comp:  1                Halpha      23.47      0.13     -38    21
# Comp:  2             [SII]6716      4.930      0.14     -39    42
# Comp:  2             [SII]6731      3.529      0.14     -39    42
# Comp:  2              HeII4687     0.1231      0.14     -39    42
# Comp:  2               HeI5876     0.5176      0.14     -39    42
# Comp:  2          [OIII]5007_d      2.343      0.17     -39    42
# Comp:  2            [OI]6300_d      1.388      0.17     -39    42
# Comp:  2           [NII]6583_d      13.03      0.17     -39    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        43
#  comp.  1:       -37        21
#  comp.  2:       -34        40
# chi2/DOF: 1.035; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 18/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.619      0.13     -37    21
# Comp:  1                 Hbeta      4.499      0.13     -37    21
# Comp:  1                Halpha      23.44      0.13     -37    21
# Comp:  2             [SII]6716      4.607      0.14     -34    40
# Comp:  2             [SII]6731      3.960      0.14     -34    40
# Comp:  2              HeII4687    0.07217      0.14     -34    40
# Comp:  2               HeI5876     0.4608      0.14     -34    40
# Comp:  2          [OIII]5007_d      2.388      0.17     -34    40
# Comp:  2            [OI]6300_d      1.338      0.17     -34    40
# Comp:  2           [NII]6583_d      12.27      0.17     -34    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        59
#  comp.  1:       -35        27
#  comp.  2:       -39        46
# chi2/DOF: 1.030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.704      0.13     -35    27
# Comp:  1                 Hbeta      4.303      0.13     -35    27
# Comp:  1                Halpha      24.10      0.13     -35    27
# Comp:  2             [SII]6716      5.361      0.14     -39    46
# Comp:  2             [SII]6731      3.612      0.14     -39    46
# Comp:  2              HeII4687     0.1038      0.14     -39    46
# Comp:  2               HeI5876     0.5190      0.14     -39    46
# Comp:  2          [OIII]5007_d      2.411      0.18     -39    46
# Comp:  2            [OI]6300_d      1.494      0.18     -39    46
# Comp:  2           [NII]6583_d      12.95      0.18     -39    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        49
#  comp.  1:       -37        23
#  comp.  2:       -31        58
# chi2/DOF: 1.031; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.809      0.13     -37    23
# Comp:  1                 Hbeta      4.270      0.13     -37    23
# Comp:  1                Halpha      24.06      0.13     -37    23
# Comp:  2             [SII]6716      5.744      0.15     -31    58
# Comp:  2             [SII]6731      3.759      0.15     -31    58
# Comp:  2              HeII4687     0.2264      0.15     -31    58
# Comp:  2               HeI5876     0.5244      0.15     -31    58
# Comp:  2          [OIII]5007_d      2.562      0.18     -31    58
# Comp:  2            [OI]6300_d      1.395      0.18     -31    58
# Comp:  2           [NII]6583_d      12.81      0.18     -31    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        62
#  comp.  1:       -36        23
#  comp.  2:       -29        61
# chi2/DOF: 1.034; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.951      0.13     -36    23
# Comp:  1                 Hbeta      4.186      0.13     -36    23
# Comp:  1                Halpha      23.72      0.13     -36    23
# Comp:  2             [SII]6716      5.748      0.15     -29    61
# Comp:  2             [SII]6731      3.705      0.15     -29    61
# Comp:  2              HeII4687     0.1525      0.15     -29    61
# Comp:  2               HeI5876     0.5692      0.15     -29    61
# Comp:  2          [OIII]5007_d      2.487      0.19     -29    61
# Comp:  2            [OI]6300_d      1.563      0.19     -29    61
# Comp:  2           [NII]6583_d      13.65      0.19     -29    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        45
#  comp.  1:       -37        19
#  comp.  2:       -33        55
# chi2/DOF: 1.030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.020      0.13     -37    19
# Comp:  1                 Hbeta      4.388      0.13     -37    19
# Comp:  1                Halpha      23.93      0.13     -37    19
# Comp:  2             [SII]6716      5.664      0.14     -33    55
# Comp:  2             [SII]6731      3.455      0.14     -33    55
# Comp:  2              HeII4687     0.1652      0.14     -33    55
# Comp:  2               HeI5876     0.6177      0.14     -33    55
# Comp:  2          [OIII]5007_d      2.431      0.18     -33    55
# Comp:  2            [OI]6300_d      1.484      0.18     -33    55
# Comp:  2           [NII]6583_d      13.16      0.18     -33    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        44
#  comp.  1:       -37        24
#  comp.  2:       -34        46
# chi2/DOF: 1.056; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.576      0.13     -37    24
# Comp:  1                 Hbeta      4.416      0.13     -37    24
# Comp:  1                Halpha      23.69      0.13     -37    24
# Comp:  2             [SII]6716      5.468      0.14     -34    46
# Comp:  2             [SII]6731      3.742      0.14     -34    46
# Comp:  2              HeII4687     0.2489      0.14     -34    46
# Comp:  2               HeI5876     0.6143      0.14     -34    46
# Comp:  2          [OIII]5007_d      2.360      0.18     -34    46
# Comp:  2            [OI]6300_d      1.389      0.18     -34    46
# Comp:  2           [NII]6583_d      12.85      0.18     -34    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        59
#  comp.  1:       -37        28
#  comp.  2:       -39        39
# chi2/DOF: 1.030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.676      0.13     -37    28
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        45
#  comp.  1:       -38        26
#  comp.  2:       -34        48
# chi2/DOF: 1.054; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.746      0.13     -38    26
# Comp:  1                 Hbeta      4.402      0.13     -38    26
# Comp:  1                Halpha      24.00      0.13     -38    26
# Comp:  2             [SII]6716      5.001      0.14     -34    48
# Comp:  2             [SII]6731      3.684      0.14     -34    48
# Comp:  2              HeII4687    0.07107      0.14     -34    48
# Comp:  2               HeI5876     0.4288      0.14     -34    48
# Comp:  2          [OIII]5007_d      2.476      0.18     -34    48
# Comp:  2            [OI]6300_d      1.465      0.18     -34    48
# Comp:  2           [NII]6583_d      12.64      0.18     -34    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        55
#  comp.  1:       -38        25
#  comp.  2:       -21        73
# chi2/DOF: 0.9751; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.644      0.13     -38    25
# Comp:  1                 Hbeta      4.502      0.13     -38    25
# Comp:  1                Halpha      23.43      0.13     -38    25
# Comp:  2             [SII]6716      6.653      0.15     -21    73
# Comp:  2             [SII]6731      4.082      0.15     -21    73
# Comp:  2              HeII4687     0.1851      0.15     -21    73
# Comp:  2               HeI5876     0.5528      0.15     -21    73
# Comp:  2          [OIII]5007_d      2.632      0.19     -21    73
# Comp:  2            [OI]6300_d      1.527      0.19     -21    73
# Comp:  2           [NII]6583_d      13.97      0.19     -21    73
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        47
#  comp.  1:       -36        27
#  comp.  2:       -35        57
# chi2/DOF: 1.051; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.964      0.13     -36    27
# Comp:  1                 Hbeta      4.720      0.13     -36    27
# Comp:  1                Halpha      24.00      0.13     -36    27
# Comp:  2             [SII]6716      5.221      0.14     -35    57
# Comp:  2             [SII]6731      3.854      0.14     -35    57
# Comp:  2              HeII4687     0.2688      0.14     -35    57
# Comp:  2               HeI5876     0.6048      0.14     -35    57
# Comp:  2          [OIII]5007_d      2.444      0.18     -35    57
# Comp:  2            [OI]6300_d      1.555      0.18     -35    57
# Comp:  2           [NII]6583_d      13.54      0.18     -35    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        52
#  comp.  1:       -36        30
#  comp.  2:       -38        32
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.751      0.13     -36    30
# Comp:  1                 Hbeta      4.303      0.13     -36    30
# Comp:  1                Halpha      24.41      0.13     -36    30
# Comp:  2             [SII]6716      4.694      0.13     -38    32
# Comp:  2             [SII]6731      3.859      0.13     -38    32
# Comp:  2              HeII4687     0.1860      0.13     -38    32
# Comp:  2               HeI5876     0.4284      0.13     -38    32
# Comp:  2          [OIII]5007_d      2.267      0.17     -38    32
# Comp:  2            [OI]6300_d      1.292      0.17     -38    32
# Comp:  2           [NII]6583_d      12.11      0.17     -38    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        63
#  comp.  1:       -36        29
#  comp.  2:       -38        50
# chi2/DOF: 1.050; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.747      0.13     -36    29
# Comp:  1                 Hbeta      4.595      0.13     -36    29
# Comp:  1                Halpha      24.30      0.13     -36    29
# Comp:  2             [SII]6716      5.110      0.14     -38    50
# Comp:  2             [SII]6731      3.925      0.14     -38    50
# Comp:  2              HeII4687     0.1975      0.14     -38    50
# Comp:  2               HeI5876     0.5356      0.14     -38    50
# Comp:  2          [OIII]5007_d      2.377      0.18     -38    50
# Comp:  2            [OI]6300_d      1.530      0.18     -38    50
# Comp:  2           [NII]6583_d      13.38      0.18     -38    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        35
#  comp.  1:       -36        28
#  comp.  2:       -34        63
# chi2/DOF: 1.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.887      0.13     -36    28
# Comp:  1                 Hbeta      4.950      0.13     -36    28
# Comp:  1                Halpha      23.66      0.13     -36    28
# Comp:  2             [SII]6716      6.274      0.15     -34    63
# Comp:  2             [SII]6731      3.951      0.15     -34    63
# Comp:  2              HeII4687     0.2210      0.15     -34    63
# Comp:  2               HeI5876     0.5746      0.15     -34    63
# Comp:  2          [OIII]5007_d      2.587      0.19     -34    63
# Comp:  2            [OI]6300_d      1.548      0.19     -34    63
# Comp:  2           [NII]6583_d      13.53      0.19     -34    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        51
#  comp.  1:       -35        25
#  comp.  2:       -40        38
# chi2/DOF: 1.031; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.900      0.13     -35    25
# Comp:  1                 Hbeta      4.373      0.13     -35    25
# Comp:  1                Halpha      24.31      0.13     -35    25
# Comp:  2             [SII]6716      4.876      0.14     -40    38
# Comp:  2             [SII]6731      3.755      0.14     -40    38
# Comp:  2              HeII4687     0.2109      0.14     -40    38
# Comp:  2               HeI5876     0.4855      0.14     -40    38
# Comp:  2          [OIII]5007_d      2.374      0.17     -40    38
# Comp:  2            [OI]6300_d      1.387      0.17     -40    38
# Comp:  2           [NII]6583_d      12.50      0.17     -40    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        40
#  comp.  1:       -34        30
#  comp.  2:       -40        39
# chi2/DOF: 1.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.882      0.13     -34    30
# Comp:  1                 Hbeta      4.569      0.13     -34    30
# Comp:  1                Halpha      24.24      0.13     -34    30
# Comp:  2             [SII]6716      4.582      0.14     -40    39
# Comp:  2             [SII]6731      3.893      0.14     -40    39
# Comp:  2              HeII4687     0.1235      0.14     -40    39
# Comp:  2               HeI5876     0.4732      0.14     -40    39
# Comp:  2          [OIII]5007_d      2.330      0.17     -40    39
# Comp:  2            [OI]6300_d      1.439      0.17     -40    39
# Comp:  2           [NII]6583_d      12.43      0.17     -40    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        59
#  comp.  1:       -38        27
#  comp.  2:       -35        50
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.833      0.13     -38    27
# Comp:  1                 Hbeta      4.960      0.13     -38    27
# Comp:  1                Halpha      24.25      0.13     -38    27
# Comp:  2             [SII]6716      5.491      0.14     -35    50
# Comp:  2             [SII]6731      3.378      0.14     -35    50
# Comp:  2              HeII4687     0.2254      0.14     -35    50
# Comp:  2               HeI5876     0.4941      0.14     -35    50
# Comp:  2          [OIII]5007_d      2.375      0.18     -35    50
# Comp:  2            [OI]6300_d      1.382      0.18     -35    50
# Comp:  2           [NII]6583_d      12.28      0.18     -35    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        61
#  comp.  1:       -37        28
#  comp.  2:       -34        61
# chi2/DOF: 1.033; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.601      0.13     -37    28
# Comp:  1                 Hbeta      4.487      0.13     -37    28
# Comp:  1                Halpha      23.64      0.13     -37    28
# Comp:  2             [SII]6716      6.118      0.15     -34    61
# Comp:  2             [SII]6731      4.151      0.15     -34    61
# Comp:  2              HeII4687    0.07088      0.15     -34    61
# Comp:  2               HeI5876     0.5373      0.15     -34    61
# Comp:  2          [OIII]5007_d      2.526      0.19     -34    61
# Comp:  2            [OI]6300_d      1.426      0.19     -34    61
# Comp:  2           [NII]6583_d      13.69      0.19     -34    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        68
#  comp.  1:       -36        29
#  comp.  2:       -31        55
# chi2/DOF: 1.040; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.981      0.13     -36    29
# Comp:  1                 Hbeta      4.474      0.13     -36    29
# Comp:  1                Halpha      23.72      0.13     -36    29
# Comp:  2             [SII]6716      5.631      0.14     -31    55
# Comp:  2             [SII]6731      3.852      0.14     -31    55
# Comp:  2              HeII4687    0.06340      0.14     -31    55
# Comp:  2               HeI5876     0.5294      0.14     -31    55
# Comp:  2          [OIII]5007_d      2.420      0.18     -31    55
# Comp:  2            [OI]6300_d      1.483      0.18     -31    55
# Comp:  2           [NII]6583_d      13.54      0.18     -31    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        39
#  comp.  1:       -36        21
#  comp.  2:       -42        38
# chi2/DOF: 1.025; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.555      0.13     -36    21
# Comp:  1                 Hbeta      4.574      0.13     -36    21
# Comp:  1                Halpha      23.95      0.13     -36    21
# Comp:  2             [SII]6716      5.317      0.14     -42    38
# Comp:  2             [SII]6731      3.749      0.14     -42    38
# Comp:  2              HeII4687     0.2201      0.14     -42    38
# Comp:  2               HeI5876     0.4694      0.14     -42    38
# Comp:  2          [OIII]5007_d      2.293      0.17     -42    38
# Comp:  2            [OI]6300_d      1.360      0.17     -42    38
# Comp:  2           [NII]6583_d      12.61      0.17     -42    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        56
#  comp.  1:       -37        24
#  comp.  2:       -28        65
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.629      0.13     -37    24
# Comp:  1                 Hbeta      4.336      0.13     -37    24
# Comp:  1                Halpha      23.89      0.13     -37    24
# Comp:  2             [SII]6716      6.255      0.15     -28    65
# Comp:  2             [SII]6731      3.924      0.15     -28    65
# Comp:  2              HeII4687     0.1705      0.15     -28    65
# Comp:  2               HeI5876     0.4870      0.15     -28    65
# Comp:  2          [OIII]5007_d      2.487      0.19     -28    65
# Comp:  2            [OI]6300_d      1.551      0.19     -28    65
# Comp:  2           [NII]6583_d      13.94      0.19     -28    65
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.14938047, 0.20660397, 0.46522489, 0.61405145, 0.35848901,
#        0.06697792, 0.06375322, 0.09400793, 0.09151998, 0.78045475])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 1.49405803,  4.47393479, 32.6362312 ,  7.38279036,  5.32671113,
#         0.15516487,  0.64034026,  2.53460963,  1.87126769, 17.75616475])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_9_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_9", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_9_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_9_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_9_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0        Hgamma  0.308301    0.030825
# 1         Hbeta  0.923203    0.042633
# 2        Halpha  6.734537    0.096000
# 3     [SII]6716  1.523450    0.126710
# 4     [SII]6731  1.099175    0.073975
# 5      HeII4687  0.032019    0.013821
# 6       HeI5876  0.132135    0.013156
# 7  [OIII]5007_d  0.523021    0.019399
# 8    [OI]6300_d  0.386139    0.018885
# 9   [NII]6583_d  3.664012    0.161048
#           Name      Flux  Error_flux
# 0       Hgamma  0.308301    0.030825
# 1        Hbeta  0.923203    0.042633
# 2       Halpha  6.734537    0.096000
# 3    [SII]6716  1.523450    0.126710
# 4    [SII]6731  1.099175    0.073975
# 5     HeII4687  0.032019    0.013821
# 6      HeI5876  0.132135    0.013156
# 7   [OIII]4959  0.130755    0.019399
# 8   [OIII]5007  0.392265    0.019399
# 9     [OI]6300  0.289604    0.018885
# 10    [OI]6364  0.096535    0.018885
# 11   [NII]6548  0.916003    0.161048
# 12   [NII]6583  2.748009    0.161048

# %%
np.median(flux_rf_rebin)
# Out:
# 0.20635155469770566
