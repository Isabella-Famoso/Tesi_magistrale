# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_11.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_11']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4314.03901503 4315.47324864 4316.90748224 ... 6874.1460011  6875.58023471
#  6877.01446832] [0.35063828 0.38169455 0.37899665 ... 0.2664251  0.26539661 0.26807966] [0.01547865 0.01547865 0.01547865 ... 0.01547865 0.01547865 0.01547865]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -77        64
# chi2/DOF: 0.001289; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        62
# chi2/DOF: 0.0009457; DOF: 1880; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-72.56451304,  62.17528151])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -89        66
#  comp.  1:       -86        31
#  comp.  2:       -88        41
# chi2/DOF: 0.7497; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.651     0.099     -86    31
# Comp:  1                 Hbeta      10.57     0.099     -86    31
# Comp:  1                Halpha      32.05     0.099     -86    31
# Comp:  2             [SII]6716      5.058      0.10     -88    41
# Comp:  2             [SII]6731      3.658      0.10     -88    41
# Comp:  2              HeII4687      0.000      0.10     -88    41
# Comp:  2               HeI5876      1.283      0.10     -88    41
# Comp:  2          [OIII]5007_d      3.423      0.13     -88    41
# Comp:  2            [OI]6300_d      1.003      0.13     -88    41
# Comp:  2           [NII]6583_d      14.39      0.13     -88    41
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  47.79; gas flux:      4 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  102.8; gas flux:     11 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:    316; gas flux:     44 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  48.16; gas flux:      7 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  33.58; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  12.55; gas flux:      2 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  25.18; gas flux:      4 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  7.092; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  100.3; gas flux:     20 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -87        43
#  comp.  1:       -86        29
#  comp.  2:       -87        44
# chi2/DOF: 0.7217; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.591     0.098     -86    29
# Comp:  1                 Hbeta      9.884     0.098     -86    29
# Comp:  1                Halpha      31.98     0.098     -86    29
# Comp:  2             [SII]6716      5.157      0.10     -87    44
# Comp:  2             [SII]6731      3.667      0.10     -87    44
# Comp:  2              HeII4687      0.000      0.10     -87    44
# Comp:  2               HeI5876      1.240      0.10     -87    44
# Comp:  2          [OIII]5007_d      3.674      0.13     -87    44
# Comp:  2            [OI]6300_d      1.039      0.13     -87    44
# Comp:  2           [NII]6583_d      14.64      0.13     -87    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        66
#  comp.  1:       -86        29
#  comp.  2:       -87        40
# chi2/DOF: 0.7338; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.957     0.098     -86    29
# Comp:  1                 Hbeta      10.40     0.098     -86    29
# Comp:  1                Halpha      32.03     0.098     -86    29
# Comp:  2             [SII]6716      5.034      0.10     -87    40
# Comp:  2             [SII]6731      3.797      0.10     -87    40
# Comp:  2              HeII4687      0.000      0.10     -87    40
# Comp:  2               HeI5876      1.372      0.10     -87    40
# Comp:  2          [OIII]5007_d      3.515      0.13     -87    40
# Comp:  2            [OI]6300_d      1.046      0.13     -87    40
# Comp:  2           [NII]6583_d      14.23      0.13     -87    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        58
#  comp.  1:       -86        30
#  comp.  2:       -90        41
# chi2/DOF: 0.6941; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.646     0.099     -86    30
# Comp:  1                 Hbeta      10.26     0.099     -86    30
# Comp:  1                Halpha      32.06     0.099     -86    30
# Comp:  2             [SII]6716      4.925      0.10     -90    41
# Comp:  2             [SII]6731      3.702      0.10     -90    41
# Comp:  2              HeII4687      0.000      0.10     -90    41
# Comp:  2               HeI5876      1.307      0.10     -90    41
# Comp:  2          [OIII]5007_d      3.249      0.13     -90    41
# Comp:  2            [OI]6300_d      1.047      0.13     -90    41
# Comp:  2           [NII]6583_d      14.27      0.13     -90    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -102        58
#  comp.  1:       -87        31
#  comp.  2:       -88        40
# chi2/DOF: 0.7199; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.436     0.099     -87    31
# Comp:  1                 Hbeta      9.900     0.099     -87    31
# Comp:  1                Halpha      32.05     0.099     -87    31
# Comp:  2             [SII]6716      5.005      0.10     -88    40
# Comp:  2             [SII]6731      3.653      0.10     -88    40
# Comp:  2              HeII4687      0.000      0.10     -88    40
# Comp:  2               HeI5876      1.122      0.10     -88    40
# Comp:  2          [OIII]5007_d      3.633      0.13     -88    40
# Comp:  2            [OI]6300_d      1.089      0.13     -88    40
# Comp:  2           [NII]6583_d      14.29      0.13     -88    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -90        53
#  comp.  1:       -85        32
#  comp.  2:       -87        40
# chi2/DOF: 0.7043; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.099     0.099     -85    32
# Comp:  1                 Hbeta      10.32     0.099     -85    32
# Comp:  1                Halpha      32.13     0.099     -85    32
# Comp:  2             [SII]6716      4.904      0.10     -87    40
# Comp:  2             [SII]6731      3.758      0.10     -87    40
# Comp:  2              HeII4687    0.05926      0.10     -87    40
# Comp:  2               HeI5876      1.211      0.10     -87    40
# Comp:  2          [OIII]5007_d      3.684      0.13     -87    40
# Comp:  2            [OI]6300_d      1.039      0.13     -87    40
# Comp:  2           [NII]6583_d      14.15      0.13     -87    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86        57
#  comp.  1:       -87        33
#  comp.  2:       -88        41
# chi2/DOF: 0.7127; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.824      0.10     -87    33
# Comp:  1                 Hbeta      10.07      0.10     -87    33
# Comp:  1                Halpha      32.42      0.10     -87    33
# Comp:  2             [SII]6716      5.011      0.10     -88    41
# Comp:  2             [SII]6731      3.795      0.10     -88    41
# Comp:  2              HeII4687    0.03890      0.10     -88    41
# Comp:  2               HeI5876      1.425      0.10     -88    41
# Comp:  2          [OIII]5007_d      3.398      0.13     -88    41
# Comp:  2            [OI]6300_d      1.020      0.13     -88    41
# Comp:  2           [NII]6583_d      14.37      0.13     -88    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -90        67
#  comp.  1:       -87        34
#  comp.  2:       -88        39
# chi2/DOF: 0.7213; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.379      0.10     -87    34
# Comp:  1                 Hbeta      11.07      0.10     -87    34
# Comp:  1                Halpha      32.28      0.10     -87    34
# Comp:  2             [SII]6716      5.122      0.10     -88    39
# Comp:  2             [SII]6731      3.649      0.10     -88    39
# Comp:  2              HeII4687    0.04830      0.10     -88    39
# Comp:  2               HeI5876      1.455      0.10     -88    39
# Comp:  2          [OIII]5007_d      3.316      0.13     -88    39
# Comp:  2            [OI]6300_d     0.9896      0.13     -88    39
# Comp:  2           [NII]6583_d      14.15      0.13     -88    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -90        64
#  comp.  1:       -87        30
#  comp.  2:       -86        38
# chi2/DOF: 0.7042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.833     0.099     -87    30
# Comp:  1                 Hbeta      9.660     0.099     -87    30
# Comp:  1                Halpha      32.11     0.099     -87    30
# Comp:  2             [SII]6716      5.067      0.10     -86    38
# Comp:  2             [SII]6731      3.751      0.10     -86    38
# Comp:  2              HeII4687      0.000      0.10     -86    38
# Comp:  2               HeI5876      1.270      0.10     -86    38
# Comp:  2          [OIII]5007_d      3.513      0.13     -86    38
# Comp:  2            [OI]6300_d     0.9977      0.13     -86    38
# Comp:  2           [NII]6583_d      14.29      0.13     -86    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        81
#  comp.  1:       -86        30
#  comp.  2:       -88        39
# chi2/DOF: 0.7020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.868     0.099     -86    30
# Comp:  1                 Hbeta      10.64     0.099     -86    30
# Comp:  1                Halpha      32.33     0.099     -86    30
# Comp:  2             [SII]6716      5.029      0.10     -88    39
# Comp:  2             [SII]6731      3.604      0.10     -88    39
# Comp:  2              HeII4687    0.06087      0.10     -88    39
# Comp:  2               HeI5876      1.342      0.10     -88    39
# Comp:  2          [OIII]5007_d      3.150      0.13     -88    39
# Comp:  2            [OI]6300_d      1.024      0.13     -88    39
# Comp:  2           [NII]6583_d      14.28      0.13     -88    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        57
#  comp.  1:       -86        35
#  comp.  2:       -86        40
# chi2/DOF: 0.6874; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.159      0.10     -86    35
# Comp:  1                 Hbeta      11.91      0.10     -86    35
# Comp:  1                Halpha      32.56      0.10     -86    35
# Comp:  2             [SII]6716      5.033      0.10     -86    40
# Comp:  2             [SII]6731      3.607      0.10     -86    40
# Comp:  2              HeII4687      0.000      0.10     -86    40
# Comp:  2               HeI5876      1.194      0.10     -86    40
# Comp:  2          [OIII]5007_d      3.651      0.13     -86    40
# Comp:  2            [OI]6300_d      1.090      0.13     -86    40
# Comp:  2           [NII]6583_d      14.37      0.13     -86    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        75
#  comp.  1:       -86        29
#  comp.  2:       -88        42
# chi2/DOF: 0.6620; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.273     0.098     -86    29
# Comp:  1                 Hbeta      11.24     0.098     -86    29
# Comp:  1                Halpha      31.96     0.098     -86    29
# Comp:  2             [SII]6716      5.052      0.10     -88    42
# Comp:  2             [SII]6731      3.641      0.10     -88    42
# Comp:  2              HeII4687      0.000      0.10     -88    42
# Comp:  2               HeI5876      1.403      0.10     -88    42
# Comp:  2          [OIII]5007_d      3.373      0.13     -88    42
# Comp:  2            [OI]6300_d      1.044      0.13     -88    42
# Comp:  2           [NII]6583_d      14.29      0.13     -88    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99        70
#  comp.  1:       -87        31
#  comp.  2:       -87        41
# chi2/DOF: 0.7227; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.672     0.099     -87    31
# Comp:  1                 Hbeta      11.14     0.099     -87    31
# Comp:  1                Halpha      32.22     0.099     -87    31
# Comp:  2             [SII]6716      5.180      0.10     -87    41
# Comp:  2             [SII]6731      3.687      0.10     -87    41
# Comp:  2              HeII4687      0.000      0.10     -87    41
# Comp:  2               HeI5876      1.340      0.10     -87    41
# Comp:  2          [OIII]5007_d      3.667      0.13     -87    41
# Comp:  2            [OI]6300_d     0.9816      0.13     -87    41
# Comp:  2           [NII]6583_d      14.43      0.13     -87    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        70
#  comp.  1:       -86        33
#  comp.  2:       -89        42
# chi2/DOF: 0.6898; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.722     0.099     -86    33
# Comp:  1                 Hbeta      10.27     0.099     -86    33
# Comp:  1                Halpha      32.13     0.099     -86    33
# Comp:  2             [SII]6716      5.149      0.10     -89    42
# Comp:  2             [SII]6731      3.471      0.10     -89    42
# Comp:  2              HeII4687    0.04278      0.10     -89    42
# Comp:  2               HeI5876      1.391      0.10     -89    42
# Comp:  2          [OIII]5007_d      3.161      0.13     -89    42
# Comp:  2            [OI]6300_d      1.060      0.13     -89    42
# Comp:  2           [NII]6583_d      14.55      0.13     -89    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -106        55
#  comp.  1:       -85        33
#  comp.  2:       -87        44
# chi2/DOF: 0.7050; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.666      0.10     -85    33
# Comp:  1                 Hbeta      10.11      0.10     -85    33
# Comp:  1                Halpha      32.64      0.10     -85    33
# Comp:  2             [SII]6716      5.102      0.10     -87    44
# Comp:  2             [SII]6731      3.955      0.10     -87    44
# Comp:  2              HeII4687    0.06915      0.10     -87    44
# Comp:  2               HeI5876      1.168      0.10     -87    44
# Comp:  2          [OIII]5007_d      3.241      0.13     -87    44
# Comp:  2            [OI]6300_d     0.9667      0.13     -87    44
# Comp:  2           [NII]6583_d      14.59      0.13     -87    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        62
#  comp.  1:       -86        29
#  comp.  2:       -88        42
# chi2/DOF: 0.6954; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.422     0.098     -86    29
# Comp:  1                 Hbeta      10.73     0.098     -86    29
# Comp:  1                Halpha      32.07     0.098     -86    29
# Comp:  2             [SII]6716      5.165      0.10     -88    42
# Comp:  2             [SII]6731      3.659      0.10     -88    42
# Comp:  2              HeII4687    0.01370      0.10     -88    42
# Comp:  2               HeI5876      1.166      0.10     -88    42
# Comp:  2          [OIII]5007_d      3.655      0.13     -88    42
# Comp:  2            [OI]6300_d     0.9770      0.13     -88    42
# Comp:  2           [NII]6583_d      14.51      0.13     -88    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89        61
#  comp.  1:       -86        31
#  comp.  2:       -88        42
# chi2/DOF: 0.6896; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.946     0.099     -86    31
# Comp:  1                 Hbeta      9.552     0.099     -86    31
# Comp:  1                Halpha      31.87     0.099     -86    31
# Comp:  2             [SII]6716      5.139      0.10     -88    42
# Comp:  2             [SII]6731      3.658      0.10     -88    42
# Comp:  2              HeII4687      0.000      0.10     -88    42
# Comp:  2               HeI5876      1.255      0.10     -88    42
# Comp:  2          [OIII]5007_d      3.175      0.13     -88    42
# Comp:  2            [OI]6300_d      1.047      0.13     -88    42
# Comp:  2           [NII]6583_d      14.69      0.13     -88    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87        61
#  comp.  1:       -86        30
#  comp.  2:       -88        44
# chi2/DOF: 0.7080; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.941     0.099     -86    30
# Comp:  1                 Hbeta      9.758     0.099     -86    30
# Comp:  1                Halpha      31.71     0.099     -86    30
# Comp:  2             [SII]6716      4.985      0.10     -88    44
# Comp:  2             [SII]6731      3.833      0.10     -88    44
# Comp:  2              HeII4687      0.000      0.10     -88    44
# Comp:  2               HeI5876      1.210      0.10     -88    44
# Comp:  2          [OIII]5007_d      3.250      0.13     -88    44
# Comp:  2            [OI]6300_d      1.080      0.13     -88    44
# Comp:  2           [NII]6583_d      14.53      0.13     -88    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        71
#  comp.  1:       -85        34
#  comp.  2:       -89        40
# chi2/DOF: 0.6795; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.688      0.10     -85    34
# Comp:  1                 Hbeta      9.966      0.10     -85    34
# Comp:  1                Halpha      32.52      0.10     -85    34
# Comp:  2             [SII]6716      5.034      0.10     -89    40
# Comp:  2             [SII]6731      3.641      0.10     -89    40
# Comp:  2              HeII4687    0.03801      0.10     -89    40
# Comp:  2               HeI5876      1.323      0.10     -89    40
# Comp:  2          [OIII]5007_d      3.459      0.13     -89    40
# Comp:  2            [OI]6300_d     0.9271      0.13     -89    40
# Comp:  2           [NII]6583_d      14.50      0.13     -89    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95        66
#  comp.  1:       -86        29
#  comp.  2:       -87        38
# chi2/DOF: 0.7140; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.276     0.098     -86    29
# Comp:  1                 Hbeta      10.60     0.098     -86    29
# Comp:  1                Halpha      31.43     0.098     -86    29
# Comp:  2             [SII]6716      4.936      0.10     -87    38
# Comp:  2             [SII]6731      3.559      0.10     -87    38
# Comp:  2              HeII4687      0.000      0.10     -87    38
# Comp:  2               HeI5876      1.388      0.10     -87    38
# Comp:  2          [OIII]5007_d      3.180      0.13     -87    38
# Comp:  2            [OI]6300_d      1.001      0.13     -87    38
# Comp:  2           [NII]6583_d      14.25      0.13     -87    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98        53
#  comp.  1:       -87        29
#  comp.  2:       -88        43
# chi2/DOF: 0.7090; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.463     0.098     -87    29
# Comp:  1                 Hbeta      11.06     0.098     -87    29
# Comp:  1                Halpha      31.55     0.098     -87    29
# Comp:  2             [SII]6716      5.152      0.10     -88    43
# Comp:  2             [SII]6731      3.874      0.10     -88    43
# Comp:  2              HeII4687      0.000      0.10     -88    43
# Comp:  2               HeI5876      1.296      0.10     -88    43
# Comp:  2          [OIII]5007_d      3.513      0.13     -88    43
# Comp:  2            [OI]6300_d      1.030      0.13     -88    43
# Comp:  2           [NII]6583_d      14.62      0.13     -88    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83        60
#  comp.  1:       -86        30
#  comp.  2:       -87        44
# chi2/DOF: 0.7275; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.818     0.099     -86    30
# Comp:  1                 Hbeta      11.01     0.099     -86    30
# Comp:  1                Halpha      32.00     0.099     -86    30
# Comp:  2             [SII]6716      4.981      0.10     -87    44
# Comp:  2             [SII]6731      3.859      0.10     -87    44
# Comp:  2              HeII4687    0.08134      0.10     -87    44
# Comp:  2               HeI5876      1.145      0.10     -87    44
# Comp:  2          [OIII]5007_d      3.479      0.13     -87    44
# Comp:  2            [OI]6300_d     0.9620      0.13     -87    44
# Comp:  2           [NII]6583_d      14.59      0.13     -87    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83        73
#  comp.  1:       -86        30
#  comp.  2:       -89        44
# chi2/DOF: 0.7258; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.568     0.099     -86    30
# Comp:  1                 Hbeta      9.994     0.099     -86    30
# Comp:  1                Halpha      31.90     0.099     -86    30
# Comp:  2             [SII]6716      5.057      0.10     -89    44
# Comp:  2             [SII]6731      3.727      0.10     -89    44
# Comp:  2              HeII4687      0.000      0.10     -89    44
# Comp:  2               HeI5876      1.341      0.10     -89    44
# Comp:  2          [OIII]5007_d      3.421      0.13     -89    44
# Comp:  2            [OI]6300_d      1.031      0.13     -89    44
# Comp:  2           [NII]6583_d      14.46      0.13     -89    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96        61
#  comp.  1:       -87        33
#  comp.  2:       -87        40
# chi2/DOF: 0.6771; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.727      0.10     -87    33
# Comp:  1                 Hbeta      11.37      0.10     -87    33
# Comp:  1                Halpha      32.58      0.10     -87    33
# Comp:  2             [SII]6716      4.994      0.10     -87    40
# Comp:  2             [SII]6731      3.481      0.10     -87    40
# Comp:  2              HeII4687      0.000      0.10     -87    40
# Comp:  2               HeI5876      1.238      0.10     -87    40
# Comp:  2          [OIII]5007_d      3.233      0.13     -87    40
# Comp:  2            [OI]6300_d     0.9570      0.13     -87    40
# Comp:  2           [NII]6583_d      14.39      0.13     -87    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96        58
#  comp.  1:       -87        28
#  comp.  2:       -87        41
# chi2/DOF: 0.7127; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.472     0.098     -87    28
# Comp:  1                 Hbeta      11.09     0.098     -87    28
# Comp:  1                Halpha      31.80     0.098     -87    28
# Comp:  2             [SII]6716      5.083      0.10     -87    41
# Comp:  2             [SII]6731      3.808      0.10     -87    41
# Comp:  2              HeII4687      0.000      0.10     -87    41
# Comp:  2               HeI5876      1.176      0.10     -87    41
# Comp:  2          [OIII]5007_d      3.609      0.13     -87    41
# Comp:  2            [OI]6300_d     0.9187      0.13     -87    41
# Comp:  2           [NII]6583_d      14.40      0.13     -87    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70        72
#  comp.  1:       -87        31
#  comp.  2:       -89        43
# chi2/DOF: 0.7211; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.144     0.099     -87    31
# Comp:  1                 Hbeta      10.45     0.099     -87    31
# Comp:  1                Halpha      32.02     0.099     -87    31
# Comp:  2             [SII]6716      5.208      0.10     -89    43
# Comp:  2             [SII]6731      3.685      0.10     -89    43
# Comp:  2              HeII4687      0.000      0.10     -89    43
# Comp:  2               HeI5876      1.442      0.10     -89    43
# Comp:  2          [OIII]5007_d      3.516      0.13     -89    43
# Comp:  2            [OI]6300_d      1.068      0.13     -89    43
# Comp:  2           [NII]6583_d      14.38      0.13     -89    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        76
#  comp.  1:       -87        29
#  comp.  2:       -87        44
# chi2/DOF: 0.6916; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.292     0.098     -87    29
# Comp:  1                 Hbeta      10.42     0.098     -87    29
# Comp:  1                Halpha      32.35     0.098     -87    29
# Comp:  2             [SII]6716      5.121      0.10     -87    44
# Comp:  2             [SII]6731      3.713      0.10     -87    44
# Comp:  2              HeII4687      0.000      0.10     -87    44
# Comp:  2               HeI5876      1.107      0.10     -87    44
# Comp:  2          [OIII]5007_d      3.345      0.13     -87    44
# Comp:  2            [OI]6300_d      1.003      0.13     -87    44
# Comp:  2           [NII]6583_d      14.61      0.13     -87    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -90        73
#  comp.  1:       -86        32
#  comp.  2:       -87        40
# chi2/DOF: 0.6980; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.549     0.099     -86    32
# Comp:  1                 Hbeta      9.560     0.099     -86    32
# Comp:  1                Halpha      32.28     0.099     -86    32
# Comp:  2             [SII]6716      5.006      0.10     -87    40
# Comp:  2             [SII]6731      3.787      0.10     -87    40
# Comp:  2              HeII4687      0.000      0.10     -87    40
# Comp:  2               HeI5876      1.286      0.10     -87    40
# Comp:  2          [OIII]5007_d      3.334      0.13     -87    40
# Comp:  2            [OI]6300_d     0.9952      0.13     -87    40
# Comp:  2           [NII]6583_d      14.29      0.13     -87    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        67
#  comp.  1:       -87        31
#  comp.  2:       -87        43
# chi2/DOF: 0.6562; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.413     0.099     -87    31
# Comp:  1                 Hbeta      11.32     0.099     -87    31
# Comp:  1                Halpha      32.29     0.099     -87    31
# Comp:  2             [SII]6716      5.040      0.10     -87    43
# Comp:  2             [SII]6731      3.848      0.10     -87    43
# Comp:  2              HeII4687    0.03563      0.10     -87    43
# Comp:  2               HeI5876      1.230      0.10     -87    43
# Comp:  2          [OIII]5007_d      3.566      0.13     -87    43
# Comp:  2            [OI]6300_d      1.049      0.13     -87    43
# Comp:  2           [NII]6583_d      14.55      0.13     -87    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83        50
#  comp.  1:       -86        32
#  comp.  2:       -89        41
# chi2/DOF: 0.7030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.769     0.099     -86    32
# Comp:  1                 Hbeta      11.03     0.099     -86    32
# Comp:  1                Halpha      32.10     0.099     -86    32
# Comp:  2             [SII]6716      5.085      0.10     -89    41
# Comp:  2             [SII]6731      3.534      0.10     -89    41
# Comp:  2              HeII4687      0.000      0.10     -89    41
# Comp:  2               HeI5876      1.285      0.10     -89    41
# Comp:  2          [OIII]5007_d      3.357      0.13     -89    41
# Comp:  2            [OI]6300_d      1.021      0.13     -89    41
# Comp:  2           [NII]6583_d      14.42      0.13     -89    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        72
#  comp.  1:       -86        32
#  comp.  2:       -87        42
# chi2/DOF: 0.7134; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.118     0.099     -86    32
# Comp:  1                 Hbeta      11.08     0.099     -86    32
# Comp:  1                Halpha      32.52     0.099     -86    32
# Comp:  2             [SII]6716      5.073      0.10     -87    42
# Comp:  2             [SII]6731      3.667      0.10     -87    42
# Comp:  2              HeII4687      0.000      0.10     -87    42
# Comp:  2               HeI5876      1.364      0.10     -87    42
# Comp:  2          [OIII]5007_d      3.461      0.13     -87    42
# Comp:  2            [OI]6300_d      1.037      0.13     -87    42
# Comp:  2           [NII]6583_d      14.51      0.13     -87    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71        73
#  comp.  1:       -85        31
#  comp.  2:       -88        39
# chi2/DOF: 0.6823; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.157     0.099     -85    31
# Comp:  1                 Hbeta      10.53     0.099     -85    31
# Comp:  1                Halpha      32.05     0.099     -85    31
# Comp:  2             [SII]6716      5.091      0.10     -88    39
# Comp:  2             [SII]6731      3.681      0.10     -88    39
# Comp:  2              HeII4687      0.000      0.10     -88    39
# Comp:  2               HeI5876      1.208      0.10     -88    39
# Comp:  2          [OIII]5007_d      3.657      0.13     -88    39
# Comp:  2            [OI]6300_d     0.9869      0.13     -88    39
# Comp:  2           [NII]6583_d      14.21      0.13     -88    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98        61
#  comp.  1:       -86        31
#  comp.  2:       -88        42
# chi2/DOF: 0.6775; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.772     0.099     -86    31
# Comp:  1                 Hbeta      11.10     0.099     -86    31
# Comp:  1                Halpha      31.84     0.099     -86    31
# Comp:  2             [SII]6716      4.961      0.10     -88    42
# Comp:  2             [SII]6731      3.812      0.10     -88    42
# Comp:  2              HeII4687    0.07255      0.10     -88    42
# Comp:  2               HeI5876      1.197      0.10     -88    42
# Comp:  2          [OIII]5007_d      3.433      0.13     -88    42
# Comp:  2            [OI]6300_d      1.048      0.13     -88    42
# Comp:  2           [NII]6583_d      14.37      0.13     -88    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        77
#  comp.  1:       -86        33
#  comp.  2:       -88        40
# chi2/DOF: 0.6633; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.287     0.099     -86    33
# Comp:  1                 Hbeta      10.36     0.099     -86    33
# Comp:  1                Halpha      32.49     0.099     -86    33
# Comp:  2             [SII]6716      5.035      0.10     -88    40
# Comp:  2             [SII]6731      3.596      0.10     -88    40
# Comp:  2              HeII4687      0.000      0.10     -88    40
# Comp:  2               HeI5876      1.273      0.10     -88    40
# Comp:  2          [OIII]5007_d      3.491      0.13     -88    40
# Comp:  2            [OI]6300_d     0.9708      0.13     -88    40
# Comp:  2           [NII]6583_d      14.22      0.13     -88    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86        66
#  comp.  1:       -85        32
#  comp.  2:       -89        38
# chi2/DOF: 0.7080; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.748     0.099     -85    32
# Comp:  1                 Hbeta      10.19     0.099     -85    32
# Comp:  1                Halpha      32.00     0.099     -85    32
# Comp:  2             [SII]6716      4.958      0.10     -89    38
# Comp:  2             [SII]6731      3.577      0.10     -89    38
# Comp:  2              HeII4687      0.000      0.10     -89    38
# Comp:  2               HeI5876      1.375      0.10     -89    38
# Comp:  2          [OIII]5007_d      3.360      0.13     -89    38
# Comp:  2            [OI]6300_d     0.9464      0.13     -89    38
# Comp:  2           [NII]6583_d      14.20      0.13     -89    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81        72
#  comp.  1:       -85        32
#  comp.  2:       -88        42
# chi2/DOF: 0.7081; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.518     0.099     -85    32
# Comp:  1                 Hbeta      10.03     0.099     -85    32
# Comp:  1                Halpha      32.06     0.099     -85    32
# Comp:  2             [SII]6716      5.076      0.10     -88    42
# Comp:  2             [SII]6731      3.813      0.10     -88    42
# Comp:  2              HeII4687      0.000      0.10     -88    42
# Comp:  2               HeI5876      1.386      0.10     -88    42
# Comp:  2          [OIII]5007_d      3.283      0.13     -88    42
# Comp:  2            [OI]6300_d     0.9994      0.13     -88    42
# Comp:  2           [NII]6583_d      14.49      0.13     -88    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -101        40
#  comp.  1:       -86        30
#  comp.  2:       -90        43
# chi2/DOF: 0.7262; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.837     0.099     -86    30
# Comp:  1                 Hbeta      10.26     0.099     -86    30
# Comp:  1                Halpha      32.17     0.099     -86    30
# Comp:  2             [SII]6716      5.097      0.10     -90    43
# Comp:  2             [SII]6731      3.693      0.10     -90    43
# Comp:  2              HeII4687    0.06565      0.10     -90    43
# Comp:  2               HeI5876      1.404      0.10     -90    43
# Comp:  2          [OIII]5007_d      3.631      0.13     -90    43
# Comp:  2            [OI]6300_d      1.090      0.13     -90    43
# Comp:  2           [NII]6583_d      14.57      0.13     -90    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -101        79
#  comp.  1:       -86        29
#  comp.  2:       -87        40
# chi2/DOF: 0.6810; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.748     0.098     -86    29
# Comp:  1                 Hbeta      9.551     0.098     -86    29
# Comp:  1                Halpha      31.61     0.098     -86    29
# Comp:  2             [SII]6716      5.058      0.10     -87    40
# Comp:  2             [SII]6731      3.680      0.10     -87    40
# Comp:  2              HeII4687      0.000      0.10     -87    40
# Comp:  2               HeI5876      1.177      0.10     -87    40
# Comp:  2          [OIII]5007_d      3.236      0.13     -87    40
# Comp:  2            [OI]6300_d     0.9026      0.13     -87    40
# Comp:  2           [NII]6583_d      14.45      0.13     -87    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        68
#  comp.  1:       -85        28
#  comp.  2:       -90        42
# chi2/DOF: 0.7015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.045     0.098     -85    28
# Comp:  1                 Hbeta      10.24     0.098     -85    28
# Comp:  1                Halpha      31.70     0.098     -85    28
# Comp:  2             [SII]6716      5.089      0.10     -90    42
# Comp:  2             [SII]6731      3.609      0.10     -90    42
# Comp:  2              HeII4687      0.000      0.10     -90    42
# Comp:  2               HeI5876      1.353      0.10     -90    42
# Comp:  2          [OIII]5007_d      3.395      0.13     -90    42
# Comp:  2            [OI]6300_d     0.9733      0.13     -90    42
# Comp:  2           [NII]6583_d      14.35      0.13     -90    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77        72
#  comp.  1:       -86        32
#  comp.  2:       -88        43
# chi2/DOF: 0.7011; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.794     0.099     -86    32
# Comp:  1                 Hbeta      10.89     0.099     -86    32
# Comp:  1                Halpha      32.14     0.099     -86    32
# Comp:  2             [SII]6716      5.088      0.10     -88    43
# Comp:  2             [SII]6731      3.875      0.10     -88    43
# Comp:  2              HeII4687    0.07499      0.10     -88    43
# Comp:  2               HeI5876      1.258      0.10     -88    43
# Comp:  2          [OIII]5007_d      3.203      0.13     -88    43
# Comp:  2            [OI]6300_d      1.103      0.13     -88    43
# Comp:  2           [NII]6583_d      14.54      0.13     -88    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        65
#  comp.  1:       -86        35
#  comp.  2:       -86        41
# chi2/DOF: 0.6873; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81        74
#  comp.  1:       -86        33
#  comp.  2:       -86        42
# chi2/DOF: 0.6781; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.226      0.10     -86    33
# Comp:  1                 Hbeta      11.63      0.10     -86    33
# Comp:  1                Halpha      32.54      0.10     -86    33
# Comp:  2             [SII]6716      4.957      0.10     -86    42
# Comp:  2             [SII]6731      3.629      0.10     -86    42
# Comp:  2              HeII4687      0.000      0.10     -86    42
# Comp:  2               HeI5876      1.238      0.10     -86    42
# Comp:  2          [OIII]5007_d      3.725      0.13     -86    42
# Comp:  2            [OI]6300_d      1.018      0.13     -86    42
# Comp:  2           [NII]6583_d      14.40      0.13     -86    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99        55
#  comp.  1:       -86        32
#  comp.  2:       -89        40
# chi2/DOF: 0.7071; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.688     0.099     -86    32
# Comp:  1                 Hbeta      9.787     0.099     -86    32
# Comp:  1                Halpha      32.34     0.099     -86    32
# Comp:  2             [SII]6716      5.154      0.10     -89    40
# Comp:  2             [SII]6731      3.460      0.10     -89    40
# Comp:  2              HeII4687      0.000      0.10     -89    40
# Comp:  2               HeI5876      1.340      0.10     -89    40
# Comp:  2          [OIII]5007_d      3.264      0.13     -89    40
# Comp:  2            [OI]6300_d     0.9657      0.13     -89    40
# Comp:  2           [NII]6583_d      14.42      0.13     -89    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        49
#  comp.  1:       -84        33
#  comp.  2:       -88        42
# chi2/DOF: 0.7138; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.196     0.099     -84    33
# Comp:  1                 Hbeta      10.27     0.099     -84    33
# Comp:  1                Halpha      32.30     0.099     -84    33
# Comp:  2             [SII]6716      5.067      0.10     -88    42
# Comp:  2             [SII]6731      3.493      0.10     -88    42
# Comp:  2              HeII4687    0.02197      0.10     -88    42
# Comp:  2               HeI5876      1.381      0.10     -88    42
# Comp:  2          [OIII]5007_d      3.470      0.13     -88    42
# Comp:  2            [OI]6300_d      1.029      0.13     -88    42
# Comp:  2           [NII]6583_d      14.43      0.13     -88    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -94        61
#  comp.  1:       -86        32
#  comp.  2:       -88        43
# chi2/DOF: 0.7079; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.385     0.099     -86    32
# Comp:  1                 Hbeta      9.884     0.099     -86    32
# Comp:  1                Halpha      32.30     0.099     -86    32
# Comp:  2             [SII]6716      5.015      0.10     -88    43
# Comp:  2             [SII]6731      3.845      0.10     -88    43
# Comp:  2              HeII4687    0.04071      0.10     -88    43
# Comp:  2               HeI5876      1.314      0.10     -88    43
# Comp:  2          [OIII]5007_d      3.454      0.13     -88    43
# Comp:  2            [OI]6300_d      1.023      0.13     -88    43
# Comp:  2           [NII]6583_d      14.41      0.13     -88    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92        55
#  comp.  1:       -86        32
#  comp.  2:       -88        42
# chi2/DOF: 0.6861; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.138     0.099     -86    32
# Comp:  1                 Hbeta      11.56     0.099     -86    32
# Comp:  1                Halpha      32.38     0.099     -86    32
# Comp:  2             [SII]6716      4.917      0.10     -88    42
# Comp:  2             [SII]6731      3.825      0.10     -88    42
# Comp:  2              HeII4687    0.04673      0.10     -88    42
# Comp:  2               HeI5876      1.426      0.10     -88    42
# Comp:  2          [OIII]5007_d      3.489      0.13     -88    42
# Comp:  2            [OI]6300_d     0.8953      0.13     -88    42
# Comp:  2           [NII]6583_d      14.29      0.13     -88    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        75
#  comp.  1:       -86        33
#  comp.  2:       -88        43
# chi2/DOF: 0.6997; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.097     0.099     -86    33
# Comp:  1                 Hbeta      11.75     0.099     -86    33
# Comp:  1                Halpha      32.22     0.099     -86    33
# Comp:  2             [SII]6716      5.083      0.10     -88    43
# Comp:  2             [SII]6731      3.522      0.10     -88    43
# Comp:  2              HeII4687    0.09041      0.10     -88    43
# Comp:  2               HeI5876      1.210      0.10     -88    43
# Comp:  2          [OIII]5007_d      3.326      0.13     -88    43
# Comp:  2            [OI]6300_d      1.019      0.13     -88    43
# Comp:  2           [NII]6583_d      14.47      0.13     -88    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88        64
#  comp.  1:       -86        32
#  comp.  2:       -88        38
# chi2/DOF: 0.6843; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.324     0.099     -86    32
# Comp:  1                 Hbeta      11.42     0.099     -86    32
# Comp:  1                Halpha      32.47     0.099     -86    32
# Comp:  2             [SII]6716      4.847      0.10     -88    38
# Comp:  2             [SII]6731      3.775      0.10     -88    38
# Comp:  2              HeII4687    0.04151      0.10     -88    38
# Comp:  2               HeI5876      1.308      0.10     -88    38
# Comp:  2          [OIII]5007_d      3.352      0.13     -88    38
# Comp:  2            [OI]6300_d     0.9421      0.13     -88    38
# Comp:  2           [NII]6583_d      14.13      0.13     -88    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100        70
#  comp.  1:       -86        33
#  comp.  2:       -88        40
# chi2/DOF: 0.6751; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.678      0.10     -86    33
# Comp:  1                 Hbeta      10.96      0.10     -86    33
# Comp:  1                Halpha      31.99      0.10     -86    33
# Comp:  2             [SII]6716      5.077      0.10     -88    40
# Comp:  2             [SII]6731      3.522      0.10     -88    40
# Comp:  2              HeII4687      0.000      0.10     -88    40
# Comp:  2               HeI5876      1.208      0.10     -88    40
# Comp:  2          [OIII]5007_d      3.469      0.13     -88    40
# Comp:  2            [OI]6300_d     0.9729      0.13     -88    40
# Comp:  2           [NII]6583_d      14.34      0.13     -88    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85        81
#  comp.  1:       -85        31
#  comp.  2:       -86        39
# chi2/DOF: 0.6832; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.038     0.099     -85    31
# Comp:  1                 Hbeta      10.91     0.099     -85    31
# Comp:  1                Halpha      32.36     0.099     -85    31
# Comp:  2             [SII]6716      5.002      0.10     -86    39
# Comp:  2             [SII]6731      3.587      0.10     -86    39
# Comp:  2              HeII4687    0.07339      0.10     -86    39
# Comp:  2               HeI5876      1.330      0.10     -86    39
# Comp:  2          [OIII]5007_d      3.556      0.13     -86    39
# Comp:  2            [OI]6300_d      1.092      0.13     -86    39
# Comp:  2           [NII]6583_d      14.42      0.13     -86    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100        51
#  comp.  1:       -85        33
#  comp.  2:       -88        41
# chi2/DOF: 0.6831; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.546      0.10     -85    33
# Comp:  1                 Hbeta      11.53      0.10     -85    33
# Comp:  1                Halpha      32.26      0.10     -85    33
# Comp:  2             [SII]6716      4.968      0.10     -88    41
# Comp:  2             [SII]6731      3.844      0.10     -88    41
# Comp:  2              HeII4687      0.000      0.10     -88    41
# Comp:  2               HeI5876      1.456      0.10     -88    41
# Comp:  2          [OIII]5007_d      3.210      0.13     -88    41
# Comp:  2            [OI]6300_d     0.9966      0.13     -88    41
# Comp:  2           [NII]6583_d      14.34      0.13     -88    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97        53
#  comp.  1:       -85        36
#  comp.  2:       -89        37
# chi2/DOF: 0.6917; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.239      0.10     -85    36
# Comp:  1                 Hbeta      10.33      0.10     -85    36
# Comp:  1                Halpha      32.57      0.10     -85    36
# Comp:  2             [SII]6716      5.020      0.10     -89    37
# Comp:  2             [SII]6731      3.593      0.10     -89    37
# Comp:  2              HeII4687      0.000      0.10     -89    37
# Comp:  2               HeI5876      1.381      0.10     -89    37
# Comp:  2          [OIII]5007_d      3.557      0.13     -89    37
# Comp:  2            [OI]6300_d      1.049      0.13     -89    37
# Comp:  2           [NII]6583_d      14.08      0.13     -89    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81        81
#  comp.  1:       -86        27
#  comp.  2:       -87        43
# chi2/DOF: 0.6988; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.262     0.098     -86    27
# Comp:  1                 Hbeta      11.16     0.098     -86    27
# Comp:  1                Halpha      31.52     0.098     -86    27
# Comp:  2             [SII]6716      5.080      0.10     -87    43
# Comp:  2             [SII]6731      3.525      0.10     -87    43
# Comp:  2              HeII4687    0.02850      0.10     -87    43
# Comp:  2               HeI5876      1.200      0.10     -87    43
# Comp:  2          [OIII]5007_d      3.391      0.13     -87    43
# Comp:  2            [OI]6300_d      1.073      0.13     -87    43
# Comp:  2           [NII]6583_d      14.49      0.13     -87    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74        71
#  comp.  1:       -86        29
#  comp.  2:       -87        38
# chi2/DOF: 0.7029; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.785     0.098     -86    29
# Comp:  1                 Hbeta      10.59     0.098     -86    29
# Comp:  1                Halpha      32.11     0.098     -86    29
# Comp:  2             [SII]6716      5.097      0.10     -87    38
# Comp:  2             [SII]6731      3.588      0.10     -87    38
# Comp:  2              HeII4687      0.000      0.10     -87    38
# Comp:  2               HeI5876      1.440      0.10     -87    38
# Comp:  2          [OIII]5007_d      3.577      0.13     -87    38
# Comp:  2            [OI]6300_d     0.9954      0.13     -87    38
# Comp:  2           [NII]6583_d      14.25      0.13     -87    38
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.62511789, 0.60805256, 0.36944434, 0.11249436, 0.20135512,
#        0.03069143, 0.11324432, 0.16547278, 0.05996879, 0.23038424])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 4.21043623, 10.71945807, 43.87080565,  7.08586791,  5.13510585,
#         0.        ,  1.57181517,  3.57515462,  1.31829352, 19.75702238])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_11_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_11", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_11_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_11_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_11_gas_exp.csv")
print(read2)
# Out:
#            Line       Flux  Error flux
# 0        Hgamma   1.340937    0.199087
# 1         Hbeta   3.413925    0.193652
# 2        Halpha  13.971942    0.117660
# 3     [SII]6716   2.256702    0.035827
# 4     [SII]6731   1.635425    0.064127
# 5      HeII4687   0.000000    0.009775
# 6       HeI5876   0.500591    0.036066
# 7  [OIII]5007_d   1.138613    0.052700
# 8    [OI]6300_d   0.419849    0.019099
# 9   [NII]6583_d   6.292202    0.073373
#           Name       Flux  Error_flux
# 0       Hgamma   1.340937    0.199087
# 1        Hbeta   3.413925    0.193652
# 2       Halpha  13.971942    0.117660
# 3    [SII]6716   2.256702    0.035827
# 4    [SII]6731   1.635425    0.064127
# 5     HeII4687   0.000000    0.009775
# 6      HeI5876   0.500591    0.036066
# 7   [OIII]4959   0.284653    0.052700
# 8   [OIII]5007   0.853959    0.052700
# 9     [OI]6300   0.314887    0.019099
# 10    [OI]6364   0.104962    0.019099
# 11   [NII]6548   1.573050    0.073373
# 12   [NII]6583   4.719151    0.073373

# %%
np.median(flux_rf_rebin)
# Out:
# 0.31847926003377713
