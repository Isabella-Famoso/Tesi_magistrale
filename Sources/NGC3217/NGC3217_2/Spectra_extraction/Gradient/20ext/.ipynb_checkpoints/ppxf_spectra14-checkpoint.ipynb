# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_14.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_14']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4314.03901503 4315.47324864 4316.90748224 ... 6874.1460011  6875.58023471
#  6877.01446832] [0.12094966 0.12627412 0.14107443 ... 0.09582879 0.0934594  0.08681642] [0.00825528 0.00825528 0.00825528 ... 0.00825528 0.00825528 0.00825528]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -121        37
# chi2/DOF: 0.004374; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:      -116        29
# chi2/DOF: 0.003333; DOF: 1887; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-115.93482331,   29.44729039])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -135        36
#  comp.  1:      -103        12
#  comp.  2:      -105        19
# chi2/DOF: 0.8289; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.909      0.14    -103    12
# Comp:  1                 Hbeta      5.067      0.14    -103    12
# Comp:  1                Halpha      16.04      0.14    -103    12
# Comp:  2             [SII]6716      3.125      0.14    -105    19
# Comp:  2             [SII]6731      1.874      0.14    -105    19
# Comp:  2              HeII4687      0.000      0.14    -105    19
# Comp:  2               HeI5876     0.4379      0.14    -105    19
# Comp:  2          [OIII]5007_d      4.195      0.18    -105    19
# Comp:  2            [OI]6300_d     0.9318      0.18    -105    19
# Comp:  2           [NII]6583_d      6.562      0.18    -105    19
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  11.75; gas flux:      2 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  30.13; gas flux:      5 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  98.17; gas flux:     22 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  18.81; gas flux:      4 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  10.93; gas flux:      3 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  2.588; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  18.11; gas flux:      4 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  3.987; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  29.45; gas flux:      9 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -128        18
#  comp.  1:      -102        17
#  comp.  2:      -104        26
# chi2/DOF: 0.8135; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.093      0.14    -102    17
# Comp:  1                 Hbeta      4.702      0.14    -102    17
# Comp:  1                Halpha      16.17      0.14    -102    17
# Comp:  2             [SII]6716      3.331      0.15    -104    26
# Comp:  2             [SII]6731      1.934      0.15    -104    26
# Comp:  2              HeII4687    0.06622      0.15    -104    26
# Comp:  2               HeI5876     0.4554      0.15    -104    26
# Comp:  2          [OIII]5007_d      4.316      0.18    -104    26
# Comp:  2            [OI]6300_d     0.8347      0.18    -104    26
# Comp:  2           [NII]6583_d      6.632      0.18    -104    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -128        27
#  comp.  1:      -102         1
#  comp.  2:      -107        22
# chi2/DOF: 0.8146; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.867      0.14    -102     1
# Comp:  1                 Hbeta      4.999      0.14    -102     1
# Comp:  1                Halpha      15.74      0.14    -102     1
# Comp:  2             [SII]6716      3.115      0.15    -107    22
# Comp:  2             [SII]6731      2.010      0.15    -107    22
# Comp:  2              HeII4687      0.000      0.15    -107    22
# Comp:  2               HeI5876     0.4834      0.15    -107    22
# Comp:  2          [OIII]5007_d      3.588      0.18    -107    22
# Comp:  2            [OI]6300_d     0.9041      0.18    -107    22
# Comp:  2           [NII]6583_d      6.490      0.18    -107    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -139        15
#  comp.  1:      -101        18
#  comp.  2:      -109        21
# chi2/DOF: 0.8039; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.611      0.14    -101    18
# Comp:  1                 Hbeta      5.239      0.14    -101    18
# Comp:  1                Halpha      16.35      0.14    -101    18
# Comp:  2             [SII]6716      3.145      0.14    -109    21
# Comp:  2             [SII]6731      1.816      0.14    -109    21
# Comp:  2              HeII4687      0.000      0.14    -109    21
# Comp:  2               HeI5876     0.5687      0.14    -109    21
# Comp:  2          [OIII]5007_d      3.649      0.18    -109    21
# Comp:  2            [OI]6300_d      1.077      0.18    -109    21
# Comp:  2           [NII]6583_d      6.566      0.18    -109    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -146        36
#  comp.  1:      -104        11
#  comp.  2:      -107        12
# chi2/DOF: 0.8133; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.948      0.14    -104    11
# Comp:  1                 Hbeta      4.598      0.14    -104    11
# Comp:  1                Halpha      16.04      0.14    -104    11
# Comp:  2             [SII]6716      2.954      0.14    -107    12
# Comp:  2             [SII]6731      1.932      0.14    -107    12
# Comp:  2              HeII4687    0.06169      0.14    -107    12
# Comp:  2               HeI5876     0.4878      0.14    -107    12
# Comp:  2          [OIII]5007_d      4.702      0.18    -107    12
# Comp:  2            [OI]6300_d      1.065      0.18    -107    12
# Comp:  2           [NII]6583_d      6.454      0.18    -107    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -147         1
#  comp.  1:      -103         1
#  comp.  2:      -101        23
# chi2/DOF: 0.8114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.117      0.14    -103     1
# Comp:  1                 Hbeta      5.050      0.14    -103     1
# Comp:  1                Halpha      15.86      0.14    -103     1
# Comp:  2             [SII]6716      3.090      0.15    -101    23
# Comp:  2             [SII]6731      2.030      0.15    -101    23
# Comp:  2              HeII4687      0.000      0.15    -101    23
# Comp:  2               HeI5876     0.4229      0.15    -101    23
# Comp:  2          [OIII]5007_d      3.640      0.18    -101    23
# Comp:  2            [OI]6300_d     0.9456      0.18    -101    23
# Comp:  2           [NII]6583_d      6.587      0.18    -101    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -140        31
#  comp.  1:      -104         6
#  comp.  2:      -106        23
# chi2/DOF: 0.8130; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.895      0.14    -104     6
# Comp:  1                 Hbeta      4.468      0.14    -104     6
# Comp:  1                Halpha      15.95      0.14    -104     6
# Comp:  2             [SII]6716      3.131      0.15    -106    23
# Comp:  2             [SII]6731      2.051      0.15    -106    23
# Comp:  2              HeII4687    0.08942      0.15    -106    23
# Comp:  2               HeI5876     0.3387      0.15    -106    23
# Comp:  2          [OIII]5007_d      4.218      0.18    -106    23
# Comp:  2            [OI]6300_d     0.9950      0.18    -106    23
# Comp:  2           [NII]6583_d      6.616      0.18    -106    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -139        46
#  comp.  1:      -105         1
#  comp.  2:      -108        23
# chi2/DOF: 0.8109; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.854      0.14    -105     1
# Comp:  1                 Hbeta      5.064      0.14    -105     1
# Comp:  1                Halpha      15.88      0.14    -105     1
# Comp:  2             [SII]6716      3.178      0.15    -108    23
# Comp:  2             [SII]6731      1.774      0.15    -108    23
# Comp:  2              HeII4687    0.04868      0.15    -108    23
# Comp:  2               HeI5876     0.4131      0.15    -108    23
# Comp:  2          [OIII]5007_d      3.683      0.18    -108    23
# Comp:  2            [OI]6300_d     0.7895      0.18    -108    23
# Comp:  2           [NII]6583_d      6.617      0.18    -108    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -121        19
#  comp.  1:      -104         3
#  comp.  2:      -101        15
# chi2/DOF: 0.8011; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.134      0.14    -104     3
# Comp:  1                 Hbeta      4.590      0.14    -104     3
# Comp:  1                Halpha      15.87      0.14    -104     3
# Comp:  2             [SII]6716      3.021      0.14    -101    15
# Comp:  2             [SII]6731      2.017      0.14    -101    15
# Comp:  2              HeII4687    0.04428      0.14    -101    15
# Comp:  2               HeI5876     0.4313      0.14    -101    15
# Comp:  2          [OIII]5007_d      3.585      0.18    -101    15
# Comp:  2            [OI]6300_d      1.025      0.18    -101    15
# Comp:  2           [NII]6583_d      6.568      0.18    -101    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -118        44
#  comp.  1:      -101        22
#  comp.  2:      -105         1
# chi2/DOF: 0.8081; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.256      0.14    -101    22
# Comp:  1                 Hbeta      5.325      0.14    -101    22
# Comp:  1                Halpha      16.64      0.14    -101    22
# Comp:  2             [SII]6716      3.057      0.14    -105     1
# Comp:  2             [SII]6731      1.921      0.14    -105     1
# Comp:  2              HeII4687      0.000      0.14    -105     1
# Comp:  2               HeI5876     0.4575      0.14    -105     1
# Comp:  2          [OIII]5007_d      4.732      0.18    -105     1
# Comp:  2            [OI]6300_d     0.9056      0.18    -105     1
# Comp:  2           [NII]6583_d      6.176      0.18    -105     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -123        48
#  comp.  1:      -102        15
#  comp.  2:      -105        21
# chi2/DOF: 0.8094; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.202      0.14    -102    15
# Comp:  1                 Hbeta      5.871      0.14    -102    15
# Comp:  1                Halpha      16.46      0.14    -102    15
# Comp:  2             [SII]6716      2.990      0.14    -105    21
# Comp:  2             [SII]6731      1.748      0.14    -105    21
# Comp:  2              HeII4687     0.2407      0.14    -105    21
# Comp:  2               HeI5876     0.5333      0.14    -105    21
# Comp:  2          [OIII]5007_d      4.333      0.18    -105    21
# Comp:  2            [OI]6300_d      1.156      0.18    -105    21
# Comp:  2           [NII]6583_d      6.608      0.18    -105    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -129        39
#  comp.  1:      -104         1
#  comp.  2:      -101        21
# chi2/DOF: 0.8105; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.621      0.14    -104     1
# Comp:  1                 Hbeta      5.286      0.14    -104     1
# Comp:  1                Halpha      15.86      0.14    -104     1
# Comp:  2             [SII]6716      3.161      0.14    -101    21
# Comp:  2             [SII]6731      1.826      0.14    -101    21
# Comp:  2              HeII4687      0.000      0.14    -101    21
# Comp:  2               HeI5876     0.3607      0.14    -101    21
# Comp:  2          [OIII]5007_d      4.405      0.18    -101    21
# Comp:  2            [OI]6300_d     0.9362      0.18    -101    21
# Comp:  2           [NII]6583_d      6.390      0.18    -101    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -134        46
#  comp.  1:      -104         1
#  comp.  2:      -104        17
# chi2/DOF: 0.8128; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.006      0.14    -104     1
# Comp:  1                 Hbeta      5.692      0.14    -104     1
# Comp:  1                Halpha      16.04      0.14    -104     1
# Comp:  2             [SII]6716      3.084      0.14    -104    17
# Comp:  2             [SII]6731      1.775      0.14    -104    17
# Comp:  2              HeII4687      0.000      0.14    -104    17
# Comp:  2               HeI5876     0.4398      0.14    -104    17
# Comp:  2          [OIII]5007_d      4.137      0.18    -104    17
# Comp:  2            [OI]6300_d     0.9224      0.18    -104    17
# Comp:  2           [NII]6583_d      6.569      0.18    -104    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -135        22
#  comp.  1:      -104         1
#  comp.  2:      -108         5
# chi2/DOF: 0.8119; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.524      0.14    -104     1
# Comp:  1                 Hbeta      4.938      0.14    -104     1
# Comp:  1                Halpha      16.04      0.14    -104     1
# Comp:  2             [SII]6716      2.977      0.14    -108     5
# Comp:  2             [SII]6731      1.782      0.14    -108     5
# Comp:  2              HeII4687     0.2117      0.14    -108     5
# Comp:  2               HeI5876     0.3425      0.14    -108     5
# Comp:  2          [OIII]5007_d      4.709      0.18    -108     5
# Comp:  2            [OI]6300_d     0.9146      0.18    -108     5
# Comp:  2           [NII]6583_d      6.518      0.18    -108     5
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -133        33
#  comp.  1:      -104         8
#  comp.  2:      -103        11
# chi2/DOF: 0.8109; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.735      0.14    -104     8
# Comp:  1                 Hbeta      4.497      0.14    -104     8
# Comp:  1                Halpha      15.89      0.14    -104     8
# Comp:  2             [SII]6716      3.071      0.14    -103    11
# Comp:  2             [SII]6731      1.910      0.14    -103    11
# Comp:  2              HeII4687      0.000      0.14    -103    11
# Comp:  2               HeI5876     0.3627      0.14    -103    11
# Comp:  2          [OIII]5007_d      4.584      0.18    -103    11
# Comp:  2            [OI]6300_d     0.8503      0.18    -103    11
# Comp:  2           [NII]6583_d      6.452      0.18    -103    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -131        25
#  comp.  1:      -104         2
#  comp.  2:      -107        28
# chi2/DOF: 0.8135; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.022      0.14    -104     2
# Comp:  1                 Hbeta      5.060      0.14    -104     2
# Comp:  1                Halpha      16.02      0.14    -104     2
# Comp:  2             [SII]6716      3.263      0.15    -107    28
# Comp:  2             [SII]6731      1.930      0.15    -107    28
# Comp:  2              HeII4687     0.2612      0.15    -107    28
# Comp:  2               HeI5876     0.5305      0.15    -107    28
# Comp:  2          [OIII]5007_d      4.371      0.19    -107    28
# Comp:  2            [OI]6300_d     0.8544      0.19    -107    28
# Comp:  2           [NII]6583_d      7.019      0.19    -107    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -133        60
#  comp.  1:      -104         2
#  comp.  2:      -104        19
# chi2/DOF: 0.8106; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.788      0.14    -104     2
# Comp:  1                 Hbeta      4.311      0.14    -104     2
# Comp:  1                Halpha      15.95      0.14    -104     2
# Comp:  2             [SII]6716      3.155      0.14    -104    19
# Comp:  2             [SII]6731      1.876      0.14    -104    19
# Comp:  2              HeII4687      0.000      0.14    -104    19
# Comp:  2               HeI5876     0.5406      0.14    -104    19
# Comp:  2          [OIII]5007_d      4.285      0.18    -104    19
# Comp:  2            [OI]6300_d     0.9456      0.18    -104    19
# Comp:  2           [NII]6583_d      6.840      0.18    -104    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -136        25
#  comp.  1:      -104         1
#  comp.  2:      -102        14
# chi2/DOF: 0.8128; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.009      0.14    -104     1
# Comp:  1                 Hbeta      4.536      0.14    -104     1
# Comp:  1                Halpha      15.80      0.14    -104     1
# Comp:  2             [SII]6716      3.141      0.14    -102    14
# Comp:  2             [SII]6731      2.002      0.14    -102    14
# Comp:  2              HeII4687      0.000      0.14    -102    14
# Comp:  2               HeI5876     0.5295      0.14    -102    14
# Comp:  2          [OIII]5007_d      4.115      0.18    -102    14
# Comp:  2            [OI]6300_d      1.080      0.18    -102    14
# Comp:  2           [NII]6583_d      6.298      0.18    -102    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -132        47
#  comp.  1:      -102        19
#  comp.  2:      -104        17
# chi2/DOF: 0.8052; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.882      0.14    -102    19
# Comp:  1                 Hbeta      4.478      0.14    -102    19
# Comp:  1                Halpha      16.41      0.14    -102    19
# Comp:  2             [SII]6716      3.096      0.14    -104    17
# Comp:  2             [SII]6731      1.846      0.14    -104    17
# Comp:  2              HeII4687      0.000      0.14    -104    17
# Comp:  2               HeI5876     0.5929      0.14    -104    17
# Comp:  2          [OIII]5007_d      4.666      0.18    -104    17
# Comp:  2            [OI]6300_d     0.8083      0.18    -104    17
# Comp:  2           [NII]6583_d      6.862      0.18    -104    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -147        46
#  comp.  1:      -104         1
#  comp.  2:      -100        17
# chi2/DOF: 0.8129; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.752      0.14    -104     1
# Comp:  1                 Hbeta      4.944      0.14    -104     1
# Comp:  1                Halpha      15.87      0.14    -104     1
# Comp:  2             [SII]6716      3.073      0.14    -100    17
# Comp:  2             [SII]6731      1.890      0.14    -100    17
# Comp:  2              HeII4687      0.000      0.14    -100    17
# Comp:  2               HeI5876     0.3653      0.14    -100    17
# Comp:  2          [OIII]5007_d      3.576      0.18    -100    17
# Comp:  2            [OI]6300_d     0.9828      0.18    -100    17
# Comp:  2           [NII]6583_d      6.645      0.18    -100    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -140        39
#  comp.  1:      -103         1
#  comp.  2:      -104        21
# chi2/DOF: 0.8114; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.843      0.14    -103     1
# Comp:  1                 Hbeta      5.567      0.14    -103     1
# Comp:  1                Halpha      15.93      0.14    -103     1
# Comp:  2             [SII]6716      3.264      0.14    -104    21
# Comp:  2             [SII]6731      2.040      0.14    -104    21
# Comp:  2              HeII4687      0.000      0.14    -104    21
# Comp:  2               HeI5876     0.4322      0.14    -104    21
# Comp:  2          [OIII]5007_d      4.074      0.18    -104    21
# Comp:  2            [OI]6300_d      1.032      0.18    -104    21
# Comp:  2           [NII]6583_d      6.606      0.18    -104    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -140        43
#  comp.  1:      -104         1
#  comp.  2:      -103        11
# chi2/DOF: 0.8146; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.788      0.14    -104     1
# Comp:  1                 Hbeta      5.085      0.14    -104     1
# Comp:  1                Halpha      15.86      0.14    -104     1
# Comp:  2             [SII]6716      3.007      0.14    -103    11
# Comp:  2             [SII]6731      1.978      0.14    -103    11
# Comp:  2              HeII4687      0.000      0.14    -103    11
# Comp:  2               HeI5876     0.4825      0.14    -103    11
# Comp:  2          [OIII]5007_d      4.816      0.18    -103    11
# Comp:  2            [OI]6300_d     0.8142      0.18    -103    11
# Comp:  2           [NII]6583_d      6.255      0.18    -103    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -134         1
#  comp.  1:      -104         7
#  comp.  2:      -106        22
# chi2/DOF: 0.8073; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.715      0.14    -104     7
# Comp:  1                 Hbeta      4.338      0.14    -104     7
# Comp:  1                Halpha      15.91      0.14    -104     7
# Comp:  2             [SII]6716      3.112      0.15    -106    22
# Comp:  2             [SII]6731      1.887      0.15    -106    22
# Comp:  2              HeII4687    0.09096      0.15    -106    22
# Comp:  2               HeI5876     0.4571      0.15    -106    22
# Comp:  2          [OIII]5007_d      3.702      0.18    -106    22
# Comp:  2            [OI]6300_d      1.004      0.18    -106    22
# Comp:  2           [NII]6583_d      6.399      0.18    -106    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -141        40
#  comp.  1:      -104         1
#  comp.  2:      -103        14
# chi2/DOF: 0.8096; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.119      0.14    -104     1
# Comp:  1                 Hbeta      5.026      0.14    -104     1
# Comp:  1                Halpha      15.77      0.14    -104     1
# Comp:  2             [SII]6716      3.062      0.14    -103    14
# Comp:  2             [SII]6731      1.709      0.14    -103    14
# Comp:  2              HeII4687      0.000      0.14    -103    14
# Comp:  2               HeI5876     0.4139      0.14    -103    14
# Comp:  2          [OIII]5007_d      3.617      0.18    -103    14
# Comp:  2            [OI]6300_d     0.8664      0.18    -103    14
# Comp:  2           [NII]6583_d      6.329      0.18    -103    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -136        15
#  comp.  1:      -103         1
#  comp.  2:      -101        16
# chi2/DOF: 0.8113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.075      0.14    -103     1
# Comp:  1                 Hbeta      5.596      0.14    -103     1
# Comp:  1                Halpha      15.77      0.14    -103     1
# Comp:  2             [SII]6716      3.141      0.14    -101    16
# Comp:  2             [SII]6731      2.026      0.14    -101    16
# Comp:  2              HeII4687      0.000      0.14    -101    16
# Comp:  2               HeI5876     0.3843      0.14    -101    16
# Comp:  2          [OIII]5007_d      4.287      0.18    -101    16
# Comp:  2            [OI]6300_d     0.7760      0.18    -101    16
# Comp:  2           [NII]6583_d      6.373      0.18    -101    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -125        45
#  comp.  1:      -103         3
#  comp.  2:      -105        26
# chi2/DOF: 0.8173; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.052      0.14    -103     3
# Comp:  1                 Hbeta      5.106      0.14    -103     3
# Comp:  1                Halpha      16.12      0.14    -103     3
# Comp:  2             [SII]6716      3.128      0.15    -105    26
# Comp:  2             [SII]6731      1.945      0.15    -105    26
# Comp:  2              HeII4687      0.000      0.15    -105    26
# Comp:  2               HeI5876     0.3980      0.15    -105    26
# Comp:  2          [OIII]5007_d      4.126      0.19    -105    26
# Comp:  2            [OI]6300_d     0.9512      0.19    -105    26
# Comp:  2           [NII]6583_d      6.488      0.19    -105    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -124        35
#  comp.  1:      -104         1
#  comp.  2:      -104        21
# chi2/DOF: 0.8122; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.066      0.14    -104     1
# Comp:  1                 Hbeta      4.964      0.14    -104     1
# Comp:  1                Halpha      15.82      0.14    -104     1
# Comp:  2             [SII]6716      3.281      0.14    -104    21
# Comp:  2             [SII]6731      1.795      0.14    -104    21
# Comp:  2              HeII4687      0.000      0.14    -104    21
# Comp:  2               HeI5876     0.4886      0.14    -104    21
# Comp:  2          [OIII]5007_d      3.486      0.18    -104    21
# Comp:  2            [OI]6300_d     0.7997      0.18    -104    21
# Comp:  2           [NII]6583_d      6.377      0.18    -104    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -128        34
#  comp.  1:      -102        20
#  comp.  2:      -104         1
# chi2/DOF: 0.8047; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.064      0.14    -102    20
# Comp:  1                 Hbeta      4.596      0.14    -102    20
# Comp:  1                Halpha      16.41      0.14    -102    20
# Comp:  2             [SII]6716      2.909      0.14    -104     1
# Comp:  2             [SII]6731      1.960      0.14    -104     1
# Comp:  2              HeII4687      0.000      0.14    -104     1
# Comp:  2               HeI5876     0.5467      0.14    -104     1
# Comp:  2          [OIII]5007_d      4.584      0.18    -104     1
# Comp:  2            [OI]6300_d     0.9100      0.18    -104     1
# Comp:  2           [NII]6583_d      6.386      0.18    -104     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -127        38
#  comp.  1:      -105         4
#  comp.  2:      -103        18
# chi2/DOF: 0.8082; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.714      0.14    -105     4
# Comp:  1                 Hbeta      5.263      0.14    -105     4
# Comp:  1                Halpha      16.00      0.14    -105     4
# Comp:  2             [SII]6716      2.972      0.14    -103    18
# Comp:  2             [SII]6731      1.905      0.14    -103    18
# Comp:  2              HeII4687     0.2107      0.14    -103    18
# Comp:  2               HeI5876     0.3800      0.14    -103    18
# Comp:  2          [OIII]5007_d      4.451      0.18    -103    18
# Comp:  2            [OI]6300_d     0.9840      0.18    -103    18
# Comp:  2           [NII]6583_d      6.399      0.18    -103    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -132        27
#  comp.  1:      -103        18
#  comp.  2:      -106        18
# chi2/DOF: 0.8194; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.933      0.14    -103    18
# Comp:  1                 Hbeta      5.194      0.14    -103    18
# Comp:  1                Halpha      16.34      0.14    -103    18
# Comp:  2             [SII]6716      3.130      0.14    -106    18
# Comp:  2             [SII]6731      1.746      0.14    -106    18
# Comp:  2              HeII4687      0.000      0.14    -106    18
# Comp:  2               HeI5876     0.3282      0.14    -106    18
# Comp:  2          [OIII]5007_d      4.317      0.18    -106    18
# Comp:  2            [OI]6300_d     0.9872      0.18    -106    18
# Comp:  2           [NII]6583_d      6.568      0.18    -106    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -142        21
#  comp.  1:      -103        15
#  comp.  2:      -100        21
# chi2/DOF: 0.8126; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.496      0.14    -103    15
# Comp:  1                 Hbeta      5.529      0.14    -103    15
# Comp:  1                Halpha      16.18      0.14    -103    15
# Comp:  2             [SII]6716      3.152      0.14    -100    21
# Comp:  2             [SII]6731      1.910      0.14    -100    21
# Comp:  2              HeII4687      0.000      0.14    -100    21
# Comp:  2               HeI5876     0.3498      0.14    -100    21
# Comp:  2          [OIII]5007_d      4.247      0.18    -100    21
# Comp:  2            [OI]6300_d      1.018      0.18    -100    21
# Comp:  2           [NII]6583_d      6.741      0.18    -100    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -128        54
#  comp.  1:      -103         1
#  comp.  2:      -104        22
# chi2/DOF: 0.8150; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.547      0.14    -103     1
# Comp:  1                 Hbeta      5.047      0.14    -103     1
# Comp:  1                Halpha      15.84      0.14    -103     1
# Comp:  2             [SII]6716      3.119      0.15    -104    22
# Comp:  2             [SII]6731      1.890      0.15    -104    22
# Comp:  2              HeII4687    0.03955      0.15    -104    22
# Comp:  2               HeI5876     0.4147      0.15    -104    22
# Comp:  2          [OIII]5007_d      4.370      0.18    -104    22
# Comp:  2            [OI]6300_d      1.069      0.18    -104    22
# Comp:  2           [NII]6583_d      6.532      0.18    -104    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -151        23
#  comp.  1:      -103        16
#  comp.  2:      -103        18
# chi2/DOF: 0.8037; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.455      0.14    -103    16
# Comp:  1                 Hbeta      5.461      0.14    -103    16
# Comp:  1                Halpha      16.27      0.14    -103    16
# Comp:  2             [SII]6716      3.040      0.14    -103    18
# Comp:  2             [SII]6731      2.000      0.14    -103    18
# Comp:  2              HeII4687     0.1184      0.14    -103    18
# Comp:  2               HeI5876     0.5269      0.14    -103    18
# Comp:  2          [OIII]5007_d      4.848      0.18    -103    18
# Comp:  2            [OI]6300_d      1.017      0.18    -103    18
# Comp:  2           [NII]6583_d      6.318      0.18    -103    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -125        48
#  comp.  1:      -103        18
#  comp.  2:      -105        21
# chi2/DOF: 0.8033; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.595      0.14    -103    18
# Comp:  1                 Hbeta      4.747      0.14    -103    18
# Comp:  1                Halpha      16.46      0.14    -103    18
# Comp:  2             [SII]6716      3.144      0.14    -105    21
# Comp:  2             [SII]6731      1.907      0.14    -105    21
# Comp:  2              HeII4687      0.000      0.14    -105    21
# Comp:  2               HeI5876     0.4219      0.14    -105    21
# Comp:  2          [OIII]5007_d      4.111      0.18    -105    21
# Comp:  2            [OI]6300_d     0.8843      0.18    -105    21
# Comp:  2           [NII]6583_d      6.418      0.18    -105    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -125        58
#  comp.  1:      -102        20
#  comp.  2:      -106        11
# chi2/DOF: 0.8043; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.559      0.14    -102    20
# Comp:  1                 Hbeta      5.064      0.14    -102    20
# Comp:  1                Halpha      16.42      0.14    -102    20
# Comp:  2             [SII]6716      3.160      0.14    -106    11
# Comp:  2             [SII]6731      1.733      0.14    -106    11
# Comp:  2              HeII4687      0.000      0.14    -106    11
# Comp:  2               HeI5876     0.3489      0.14    -106    11
# Comp:  2          [OIII]5007_d      4.665      0.18    -106    11
# Comp:  2            [OI]6300_d     0.9218      0.18    -106    11
# Comp:  2           [NII]6583_d      6.688      0.18    -106    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -134         1
#  comp.  1:      -104         8
#  comp.  2:      -101        16
# chi2/DOF: 0.8142; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.077      0.14    -104     8
# Comp:  1                 Hbeta      4.634      0.14    -104     8
# Comp:  1                Halpha      16.07      0.14    -104     8
# Comp:  2             [SII]6716      3.063      0.14    -101    16
# Comp:  2             [SII]6731      1.995      0.14    -101    16
# Comp:  2              HeII4687      0.000      0.14    -101    16
# Comp:  2               HeI5876     0.4903      0.14    -101    16
# Comp:  2          [OIII]5007_d      4.296      0.18    -101    16
# Comp:  2            [OI]6300_d     0.9250      0.18    -101    16
# Comp:  2           [NII]6583_d      6.528      0.18    -101    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -139         1
#  comp.  1:      -104         9
#  comp.  2:      -107        25
# chi2/DOF: 0.8155; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.079      0.14    -104     9
# Comp:  1                 Hbeta      5.216      0.14    -104     9
# Comp:  1                Halpha      16.10      0.14    -104     9
# Comp:  2             [SII]6716      3.024      0.15    -107    25
# Comp:  2             [SII]6731      1.960      0.15    -107    25
# Comp:  2              HeII4687    0.01630      0.15    -107    25
# Comp:  2               HeI5876     0.4940      0.15    -107    25
# Comp:  2          [OIII]5007_d      4.298      0.18    -107    25
# Comp:  2            [OI]6300_d      1.123      0.18    -107    25
# Comp:  2           [NII]6583_d      6.963      0.18    -107    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -137        43
#  comp.  1:      -104        11
#  comp.  2:      -105        18
# chi2/DOF: 0.8070; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.520      0.14    -104    11
# Comp:  1                 Hbeta      4.528      0.14    -104    11
# Comp:  1                Halpha      16.13      0.14    -104    11
# Comp:  2             [SII]6716      3.252      0.14    -105    18
# Comp:  2             [SII]6731      1.918      0.14    -105    18
# Comp:  2              HeII4687    0.04940      0.14    -105    18
# Comp:  2               HeI5876     0.4140      0.14    -105    18
# Comp:  2          [OIII]5007_d      3.562      0.18    -105    18
# Comp:  2            [OI]6300_d     0.8655      0.18    -105    18
# Comp:  2           [NII]6583_d      6.596      0.18    -105    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -137         8
#  comp.  1:      -103         1
#  comp.  2:      -105        11
# chi2/DOF: 0.8140; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.377      0.14    -103     1
# Comp:  1                 Hbeta      4.951      0.14    -103     1
# Comp:  1                Halpha      15.83      0.14    -103     1
# Comp:  2             [SII]6716      3.085      0.14    -105    11
# Comp:  2             [SII]6731      1.942      0.14    -105    11
# Comp:  2              HeII4687      0.000      0.14    -105    11
# Comp:  2               HeI5876     0.4748      0.14    -105    11
# Comp:  2          [OIII]5007_d      4.624      0.18    -105    11
# Comp:  2            [OI]6300_d     0.9028      0.18    -105    11
# Comp:  2           [NII]6583_d      6.306      0.18    -105    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -124        35
#  comp.  1:      -103        15
#  comp.  2:      -108        10
# chi2/DOF: 0.8098; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.582      0.14    -103    15
# Comp:  1                 Hbeta      5.163      0.14    -103    15
# Comp:  1                Halpha      16.15      0.14    -103    15
# Comp:  2             [SII]6716      3.068      0.14    -108    10
# Comp:  2             [SII]6731      1.978      0.14    -108    10
# Comp:  2              HeII4687      0.000      0.14    -108    10
# Comp:  2               HeI5876     0.5409      0.14    -108    10
# Comp:  2          [OIII]5007_d      4.782      0.18    -108    10
# Comp:  2            [OI]6300_d      1.068      0.18    -108    10
# Comp:  2           [NII]6583_d      6.472      0.18    -108    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -132        46
#  comp.  1:      -101        19
#  comp.  2:      -105        25
# chi2/DOF: 0.8079; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -135        51
#  comp.  1:      -101        18
#  comp.  2:      -105        22
# chi2/DOF: 0.8081; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.775      0.14    -101    18
# Comp:  1                 Hbeta      5.909      0.14    -101    18
# Comp:  1                Halpha      16.23      0.14    -101    18
# Comp:  2             [SII]6716      3.067      0.14    -105    22
# Comp:  2             [SII]6731      1.889      0.14    -105    22
# Comp:  2              HeII4687      0.000      0.14    -105    22
# Comp:  2               HeI5876     0.4399      0.14    -105    22
# Comp:  2          [OIII]5007_d      4.114      0.18    -105    22
# Comp:  2            [OI]6300_d     0.8984      0.18    -105    22
# Comp:  2           [NII]6583_d      6.723      0.18    -105    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -150        56
#  comp.  1:      -102        21
#  comp.  2:      -108        18
# chi2/DOF: 0.8077; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.889      0.14    -102    21
# Comp:  1                 Hbeta      4.576      0.14    -102    21
# Comp:  1                Halpha      16.44      0.14    -102    21
# Comp:  2             [SII]6716      3.171      0.14    -108    18
# Comp:  2             [SII]6731      1.809      0.14    -108    18
# Comp:  2              HeII4687      0.000      0.14    -108    18
# Comp:  2               HeI5876     0.4567      0.14    -108    18
# Comp:  2          [OIII]5007_d      4.112      0.18    -108    18
# Comp:  2            [OI]6300_d     0.9095      0.18    -108    18
# Comp:  2           [NII]6583_d      6.838      0.18    -108    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -144        38
#  comp.  1:      -103        19
#  comp.  2:      -106        11
# chi2/DOF: 0.8124; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.085      0.14    -103    19
# Comp:  1                 Hbeta      5.147      0.14    -103    19
# Comp:  1                Halpha      16.47      0.14    -103    19
# Comp:  2             [SII]6716      3.186      0.14    -106    11
# Comp:  2             [SII]6731      1.710      0.14    -106    11
# Comp:  2              HeII4687     0.1856      0.14    -106    11
# Comp:  2               HeI5876     0.4766      0.14    -106    11
# Comp:  2          [OIII]5007_d      4.807      0.18    -106    11
# Comp:  2            [OI]6300_d     0.8915      0.18    -106    11
# Comp:  2           [NII]6583_d      6.268      0.18    -106    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -136        29
#  comp.  1:      -104         8
#  comp.  2:      -104        22
# chi2/DOF: 0.8139; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.838      0.14    -104     8
# Comp:  1                 Hbeta      4.484      0.14    -104     8
# Comp:  1                Halpha      15.93      0.14    -104     8
# Comp:  2             [SII]6716      2.981      0.15    -104    22
# Comp:  2             [SII]6731      1.895      0.15    -104    22
# Comp:  2              HeII4687   0.004221      0.15    -104    22
# Comp:  2               HeI5876     0.3153      0.15    -104    22
# Comp:  2          [OIII]5007_d      4.315      0.18    -104    22
# Comp:  2            [OI]6300_d      1.040      0.18    -104    22
# Comp:  2           [NII]6583_d      6.622      0.18    -104    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -129        46
#  comp.  1:      -103         1
#  comp.  2:      -104         5
# chi2/DOF: 0.8066; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.498      0.14    -103     1
# Comp:  1                 Hbeta      5.376      0.14    -103     1
# Comp:  1                Halpha      15.88      0.14    -103     1
# Comp:  2             [SII]6716      2.971      0.14    -104     5
# Comp:  2             [SII]6731      1.863      0.14    -104     5
# Comp:  2              HeII4687    0.04630      0.14    -104     5
# Comp:  2               HeI5876     0.5144      0.14    -104     5
# Comp:  2          [OIII]5007_d      4.674      0.18    -104     5
# Comp:  2            [OI]6300_d     0.7445      0.18    -104     5
# Comp:  2           [NII]6583_d      6.149      0.18    -104     5
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -130        44
#  comp.  1:      -101        15
#  comp.  2:      -103        16
# chi2/DOF: 0.8102; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.191      0.14    -101    15
# Comp:  1                 Hbeta      5.893      0.14    -101    15
# Comp:  1                Halpha      16.32      0.14    -101    15
# Comp:  2             [SII]6716      3.086      0.14    -103    16
# Comp:  2             [SII]6731      1.787      0.14    -103    16
# Comp:  2              HeII4687      0.000      0.14    -103    16
# Comp:  2               HeI5876     0.3999      0.14    -103    16
# Comp:  2          [OIII]5007_d      4.258      0.18    -103    16
# Comp:  2            [OI]6300_d     0.9622      0.18    -103    16
# Comp:  2           [NII]6583_d      6.506      0.18    -103    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -158        36
#  comp.  1:      -105         1
#  comp.  2:      -104         1
# chi2/DOF: 0.8005; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.386      0.14    -105     1
# Comp:  1                 Hbeta      5.172      0.14    -105     1
# Comp:  1                Halpha      15.86      0.14    -105     1
# Comp:  2             [SII]6716      2.955      0.14    -104     1
# Comp:  2             [SII]6731      1.830      0.14    -104     1
# Comp:  2              HeII4687    0.02953      0.14    -104     1
# Comp:  2               HeI5876     0.2931      0.14    -104     1
# Comp:  2          [OIII]5007_d      4.750      0.18    -104     1
# Comp:  2            [OI]6300_d     0.8609      0.18    -104     1
# Comp:  2           [NII]6583_d      6.222      0.18    -104     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -133        43
#  comp.  1:      -104         5
#  comp.  2:      -106        13
# chi2/DOF: 0.8155; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.484      0.14    -104     5
# Comp:  1                 Hbeta      5.098      0.14    -104     5
# Comp:  1                Halpha      16.00      0.14    -104     5
# Comp:  2             [SII]6716      3.117      0.14    -106    13
# Comp:  2             [SII]6731      1.710      0.14    -106    13
# Comp:  2              HeII4687    0.07206      0.14    -106    13
# Comp:  2               HeI5876     0.4143      0.14    -106    13
# Comp:  2          [OIII]5007_d      4.008      0.18    -106    13
# Comp:  2            [OI]6300_d     0.8625      0.18    -106    13
# Comp:  2           [NII]6583_d      6.292      0.18    -106    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -127        27
#  comp.  1:      -103        17
#  comp.  2:      -105        22
# chi2/DOF: 0.8136; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.857      0.14    -103    17
# Comp:  1                 Hbeta      5.379      0.14    -103    17
# Comp:  1                Halpha      16.20      0.14    -103    17
# Comp:  2             [SII]6716      3.003      0.15    -105    22
# Comp:  2             [SII]6731      1.947      0.15    -105    22
# Comp:  2              HeII4687    0.03051      0.15    -105    22
# Comp:  2               HeI5876     0.4935      0.15    -105    22
# Comp:  2          [OIII]5007_d      4.154      0.18    -105    22
# Comp:  2            [OI]6300_d      1.109      0.18    -105    22
# Comp:  2           [NII]6583_d      6.834      0.18    -105    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -135         1
#  comp.  1:      -102        19
#  comp.  2:      -103        22
# chi2/DOF: 0.8020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.587      0.14    -102    19
# Comp:  1                 Hbeta      5.942      0.14    -102    19
# Comp:  1                Halpha      16.59      0.14    -102    19
# Comp:  2             [SII]6716      3.237      0.15    -103    22
# Comp:  2             [SII]6731      1.966      0.15    -103    22
# Comp:  2              HeII4687      0.000      0.15    -103    22
# Comp:  2               HeI5876     0.4133      0.15    -103    22
# Comp:  2          [OIII]5007_d      3.614      0.18    -103    22
# Comp:  2            [OI]6300_d     0.9161      0.18    -103    22
# Comp:  2           [NII]6583_d      6.587      0.18    -103    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -144        28
#  comp.  1:      -102        20
#  comp.  2:      -107        13
# chi2/DOF: 0.8092; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.090      0.14    -102    20
# Comp:  1                 Hbeta      4.823      0.14    -102    20
# Comp:  1                Halpha      16.59      0.14    -102    20
# Comp:  2             [SII]6716      3.042      0.14    -107    13
# Comp:  2             [SII]6731      1.793      0.14    -107    13
# Comp:  2              HeII4687      0.000      0.14    -107    13
# Comp:  2               HeI5876     0.4929      0.14    -107    13
# Comp:  2          [OIII]5007_d      4.189      0.18    -107    13
# Comp:  2            [OI]6300_d     0.8656      0.18    -107    13
# Comp:  2           [NII]6583_d      6.265      0.18    -107    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -128        51
#  comp.  1:      -103         1
#  comp.  2:      -102        15
# chi2/DOF: 0.8121; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.875      0.14    -103     1
# Comp:  1                 Hbeta      5.608      0.14    -103     1
# Comp:  1                Halpha      15.85      0.14    -103     1
# Comp:  2             [SII]6716      2.985      0.14    -102    15
# Comp:  2             [SII]6731      1.715      0.14    -102    15
# Comp:  2              HeII4687     0.1846      0.14    -102    15
# Comp:  2               HeI5876     0.3956      0.14    -102    15
# Comp:  2          [OIII]5007_d      4.344      0.18    -102    15
# Comp:  2            [OI]6300_d      1.080      0.18    -102    15
# Comp:  2           [NII]6583_d      6.354      0.18    -102    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -135         1
#  comp.  1:      -102         1
#  comp.  2:      -106        15
# chi2/DOF: 0.8187; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.990      0.14    -102     1
# Comp:  1                 Hbeta      5.151      0.14    -102     1
# Comp:  1                Halpha      15.85      0.14    -102     1
# Comp:  2             [SII]6716      3.160      0.14    -106    15
# Comp:  2             [SII]6731      1.958      0.14    -106    15
# Comp:  2              HeII4687    0.05113      0.14    -106    15
# Comp:  2               HeI5876     0.4077      0.14    -106    15
# Comp:  2          [OIII]5007_d      4.069      0.18    -106    15
# Comp:  2            [OI]6300_d     0.8555      0.18    -106    15
# Comp:  2           [NII]6583_d      6.323      0.18    -106    15
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.3041299 , 0.41668058, 0.33114418, 0.12351116, 0.14416048,
#        0.06504873, 0.09453221, 0.4194113 , 0.13673861, 0.28159584])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_14_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_14", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_14_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_14_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_14_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
