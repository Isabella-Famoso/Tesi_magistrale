# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_8.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_8']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4314.03901503 4315.47324864 4316.90748224 ... 6874.1460011  6875.58023471
#  6877.01446832] [0.12112148 0.10106379 0.11591559 ... 0.14716676 0.14503348 0.14044156] [0.01135101 0.01135101 0.01135101 ... 0.01135101 0.01135101 0.01135101]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        47
# chi2/DOF: 0.005196; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        43
# chi2/DOF: 0.003666; DOF: 1877; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-32.69344538,  42.8129041 ])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        46
#  comp.  1:       -13         9
#  comp.  2:       -14        27
# chi2/DOF: 0.9382; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.391      0.14     -13     9
# Comp:  1                 Hbeta      7.215      0.14     -13     9
# Comp:  1                Halpha      21.43      0.14     -13     9
# Comp:  2             [SII]6716      4.071      0.15     -14    27
# Comp:  2             [SII]6731      3.209      0.15     -14    27
# Comp:  2              HeII4687      0.000      0.15     -14    27
# Comp:  2               HeI5876     0.6523      0.15     -14    27
# Comp:  2          [OIII]5007_d      5.671      0.19     -14    27
# Comp:  2            [OI]6300_d      1.430      0.19     -14    27
# Comp:  2           [NII]6583_d      9.274      0.19     -14    27
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  19.09; gas flux:      3 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  41.83; gas flux:      7 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  118.2; gas flux:     29 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  20.93; gas flux:      6 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  17.46; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  3.578; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  23.78; gas flux:      6 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  5.945; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  36.63; gas flux:     13 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        42
#  comp.  1:       -13         7
#  comp.  2:       -17        28
# chi2/DOF: 0.9234; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.606      0.14     -13     7
# Comp:  1                 Hbeta      7.652      0.14     -13     7
# Comp:  1                Halpha      21.37      0.14     -13     7
# Comp:  2             [SII]6716      4.111      0.15     -17    28
# Comp:  2             [SII]6731      3.228      0.15     -17    28
# Comp:  2              HeII4687      0.000      0.15     -17    28
# Comp:  2               HeI5876     0.6650      0.15     -17    28
# Comp:  2          [OIII]5007_d      5.406      0.19     -17    28
# Comp:  2            [OI]6300_d      1.427      0.19     -17    28
# Comp:  2           [NII]6583_d      9.328      0.19     -17    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        40
#  comp.  1:       -13         1
#  comp.  2:       -14        28
# chi2/DOF: 0.9247; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.505      0.14     -13     1
# Comp:  1                 Hbeta      7.241      0.14     -13     1
# Comp:  1                Halpha      21.71      0.14     -13     1
# Comp:  2             [SII]6716      4.090      0.15     -14    28
# Comp:  2             [SII]6731      3.193      0.15     -14    28
# Comp:  2              HeII4687      0.000      0.15     -14    28
# Comp:  2               HeI5876     0.6430      0.15     -14    28
# Comp:  2          [OIII]5007_d      5.812      0.19     -14    28
# Comp:  2            [OI]6300_d      1.473      0.19     -14    28
# Comp:  2           [NII]6583_d      9.123      0.19     -14    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        43
#  comp.  1:       -13        16
#  comp.  2:       -14        25
# chi2/DOF: 0.9196; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.290      0.14     -13    16
# Comp:  1                 Hbeta      7.786      0.14     -13    16
# Comp:  1                Halpha      21.26      0.14     -13    16
# Comp:  2             [SII]6716      4.010      0.15     -14    25
# Comp:  2             [SII]6731      3.170      0.15     -14    25
# Comp:  2              HeII4687      0.000      0.15     -14    25
# Comp:  2               HeI5876     0.5973      0.15     -14    25
# Comp:  2          [OIII]5007_d      6.017      0.19     -14    25
# Comp:  2            [OI]6300_d      1.364      0.19     -14    25
# Comp:  2           [NII]6583_d      9.086      0.19     -14    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        23
#  comp.  1:       -13         1
#  comp.  2:       -15        28
# chi2/DOF: 0.9071; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.293      0.14     -13     1
# Comp:  1                 Hbeta      6.206      0.14     -13     1
# Comp:  1                Halpha      21.34      0.14     -13     1
# Comp:  2             [SII]6716      4.054      0.15     -15    28
# Comp:  2             [SII]6731      3.221      0.15     -15    28
# Comp:  2              HeII4687      0.000      0.15     -15    28
# Comp:  2               HeI5876     0.6501      0.15     -15    28
# Comp:  2          [OIII]5007_d      5.370      0.19     -15    28
# Comp:  2            [OI]6300_d      1.563      0.19     -15    28
# Comp:  2           [NII]6583_d      9.242      0.19     -15    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        73
#  comp.  1:       -14         1
#  comp.  2:       -13        29
# chi2/DOF: 0.9152; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.115      0.14     -14     1
# Comp:  1                 Hbeta      7.801      0.14     -14     1
# Comp:  1                Halpha      21.67      0.14     -14     1
# Comp:  2             [SII]6716      4.086      0.15     -13    29
# Comp:  2             [SII]6731      3.214      0.15     -13    29
# Comp:  2              HeII4687    0.01240      0.15     -13    29
# Comp:  2               HeI5876     0.6883      0.15     -13    29
# Comp:  2          [OIII]5007_d      5.975      0.19     -13    29
# Comp:  2            [OI]6300_d      1.453      0.19     -13    29
# Comp:  2           [NII]6583_d      9.482      0.19     -13    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        10
#  comp.  1:       -13         1
#  comp.  2:       -14        27
# chi2/DOF: 0.9288; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.238      0.14     -13     1
# Comp:  1                 Hbeta      7.395      0.14     -13     1
# Comp:  1                Halpha      21.41      0.14     -13     1
# Comp:  2             [SII]6716      4.077      0.15     -14    27
# Comp:  2             [SII]6731      3.188      0.15     -14    27
# Comp:  2              HeII4687    0.08313      0.15     -14    27
# Comp:  2               HeI5876     0.6493      0.15     -14    27
# Comp:  2          [OIII]5007_d      5.996      0.19     -14    27
# Comp:  2            [OI]6300_d      1.386      0.19     -14    27
# Comp:  2           [NII]6583_d      9.340      0.19     -14    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        56
#  comp.  1:       -12         1
#  comp.  2:       -16        24
# chi2/DOF: 0.9227; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.610      0.14     -12     1
# Comp:  1                 Hbeta      7.491      0.14     -12     1
# Comp:  1                Halpha      21.57      0.14     -12     1
# Comp:  2             [SII]6716      4.023      0.15     -16    24
# Comp:  2             [SII]6731      3.153      0.15     -16    24
# Comp:  2              HeII4687    0.07240      0.15     -16    24
# Comp:  2               HeI5876     0.6496      0.15     -16    24
# Comp:  2          [OIII]5007_d      5.470      0.19     -16    24
# Comp:  2            [OI]6300_d      1.536      0.19     -16    24
# Comp:  2           [NII]6583_d      9.089      0.19     -16    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        75
#  comp.  1:       -13         1
#  comp.  2:       -15        29
# chi2/DOF: 0.9207; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.050      0.14     -13     1
# Comp:  1                 Hbeta      7.614      0.14     -13     1
# Comp:  1                Halpha      21.65      0.14     -13     1
# Comp:  2             [SII]6716      4.098      0.15     -15    29
# Comp:  2             [SII]6731      3.199      0.15     -15    29
# Comp:  2              HeII4687      0.000      0.15     -15    29
# Comp:  2               HeI5876     0.6420      0.15     -15    29
# Comp:  2          [OIII]5007_d      5.635      0.19     -15    29
# Comp:  2            [OI]6300_d      1.274      0.19     -15    29
# Comp:  2           [NII]6583_d      9.334      0.19     -15    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        41
#  comp.  1:       -14         1
#  comp.  2:       -14        26
# chi2/DOF: 0.9197; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.449      0.14     -14     1
# Comp:  1                 Hbeta      7.790      0.14     -14     1
# Comp:  1                Halpha      20.96      0.14     -14     1
# Comp:  2             [SII]6716      4.016      0.15     -14    26
# Comp:  2             [SII]6731      3.174      0.15     -14    26
# Comp:  2              HeII4687     0.1072      0.15     -14    26
# Comp:  2               HeI5876     0.6353      0.15     -14    26
# Comp:  2          [OIII]5007_d      5.788      0.19     -14    26
# Comp:  2            [OI]6300_d      1.492      0.19     -14    26
# Comp:  2           [NII]6583_d      9.078      0.19     -14    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        44
#  comp.  1:       -12        15
#  comp.  2:       -15        28
# chi2/DOF: 0.9101; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.546      0.14     -12    15
# Comp:  1                 Hbeta      8.306      0.14     -12    15
# Comp:  1                Halpha      21.28      0.14     -12    15
# Comp:  2             [SII]6716      4.039      0.15     -15    28
# Comp:  2             [SII]6731      3.182      0.15     -15    28
# Comp:  2              HeII4687     0.1174      0.15     -15    28
# Comp:  2               HeI5876     0.6399      0.15     -15    28
# Comp:  2          [OIII]5007_d      5.679      0.19     -15    28
# Comp:  2            [OI]6300_d      1.360      0.19     -15    28
# Comp:  2           [NII]6583_d      9.177      0.19     -15    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4        88
#  comp.  1:       -13         1
#  comp.  2:       -13        29
# chi2/DOF: 0.9015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.503      0.14     -13     1
# Comp:  1                 Hbeta      6.260      0.14     -13     1
# Comp:  1                Halpha      21.68      0.14     -13     1
# Comp:  2             [SII]6716      4.056      0.15     -13    29
# Comp:  2             [SII]6731      3.204      0.15     -13    29
# Comp:  2              HeII4687      0.000      0.15     -13    29
# Comp:  2               HeI5876     0.6969      0.15     -13    29
# Comp:  2          [OIII]5007_d      5.683      0.19     -13    29
# Comp:  2            [OI]6300_d      1.544      0.19     -13    29
# Comp:  2           [NII]6583_d      9.436      0.19     -13    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        24
#  comp.  1:       -11        15
#  comp.  2:       -15        27
# chi2/DOF: 0.9071; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.767      0.14     -11    15
# Comp:  1                 Hbeta      8.285      0.14     -11    15
# Comp:  1                Halpha      21.73      0.14     -11    15
# Comp:  2             [SII]6716      4.063      0.15     -15    27
# Comp:  2             [SII]6731      3.195      0.15     -15    27
# Comp:  2              HeII4687      0.000      0.15     -15    27
# Comp:  2               HeI5876     0.6182      0.15     -15    27
# Comp:  2          [OIII]5007_d      5.676      0.19     -15    27
# Comp:  2            [OI]6300_d      1.464      0.19     -15    27
# Comp:  2           [NII]6583_d      9.169      0.19     -15    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16         1
#  comp.  1:       -12        11
#  comp.  2:       -13        26
# chi2/DOF: 0.9192; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.806      0.14     -12    11
# Comp:  1                 Hbeta      7.837      0.14     -12    11
# Comp:  1                Halpha      21.50      0.14     -12    11
# Comp:  2             [SII]6716      4.079      0.15     -13    26
# Comp:  2             [SII]6731      3.229      0.15     -13    26
# Comp:  2              HeII4687     0.1567      0.15     -13    26
# Comp:  2               HeI5876     0.7009      0.15     -13    26
# Comp:  2          [OIII]5007_d      5.783      0.19     -13    26
# Comp:  2            [OI]6300_d      1.339      0.19     -13    26
# Comp:  2           [NII]6583_d      9.068      0.19     -13    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18        75
#  comp.  1:       -13         1
#  comp.  2:       -13        29
# chi2/DOF: 0.9150; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.104      0.14     -13     1
# Comp:  1                 Hbeta      6.584      0.14     -13     1
# Comp:  1                Halpha      21.69      0.14     -13     1
# Comp:  2             [SII]6716      4.152      0.15     -13    29
# Comp:  2             [SII]6731      3.288      0.15     -13    29
# Comp:  2              HeII4687    0.06882      0.15     -13    29
# Comp:  2               HeI5876     0.6910      0.15     -13    29
# Comp:  2          [OIII]5007_d      5.823      0.19     -13    29
# Comp:  2            [OI]6300_d      1.457      0.19     -13    29
# Comp:  2           [NII]6583_d      9.442      0.19     -13    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        60
#  comp.  1:       -13         8
#  comp.  2:       -13        29
# chi2/DOF: 0.9182; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.521      0.14     -13     8
# Comp:  1                 Hbeta      7.826      0.14     -13     8
# Comp:  1                Halpha      21.80      0.14     -13     8
# Comp:  2             [SII]6716      4.121      0.15     -13    29
# Comp:  2             [SII]6731      3.234      0.15     -13    29
# Comp:  2              HeII4687    0.08567      0.15     -13    29
# Comp:  2               HeI5876     0.6385      0.15     -13    29
# Comp:  2          [OIII]5007_d      5.900      0.19     -13    29
# Comp:  2            [OI]6300_d      1.447      0.19     -13    29
# Comp:  2           [NII]6583_d      9.463      0.19     -13    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        42
#  comp.  1:       -12         1
#  comp.  2:       -15        24
# chi2/DOF: 0.9312; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.477      0.14     -12     1
# Comp:  1                 Hbeta      7.404      0.14     -12     1
# Comp:  1                Halpha      21.46      0.14     -12     1
# Comp:  2             [SII]6716      4.031      0.15     -15    24
# Comp:  2             [SII]6731      3.169      0.15     -15    24
# Comp:  2              HeII4687      0.000      0.15     -15    24
# Comp:  2               HeI5876     0.5960      0.15     -15    24
# Comp:  2          [OIII]5007_d      5.554      0.19     -15    24
# Comp:  2            [OI]6300_d      1.541      0.19     -15    24
# Comp:  2           [NII]6583_d      9.133      0.19     -15    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        23
#  comp.  1:       -13         1
#  comp.  2:       -14        30
# chi2/DOF: 0.9294; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.287      0.14     -13     1
# Comp:  1                 Hbeta      7.297      0.14     -13     1
# Comp:  1                Halpha      21.73      0.14     -13     1
# Comp:  2             [SII]6716      4.091      0.15     -14    30
# Comp:  2             [SII]6731      3.223      0.15     -14    30
# Comp:  2              HeII4687      0.000      0.15     -14    30
# Comp:  2               HeI5876     0.6452      0.15     -14    30
# Comp:  2          [OIII]5007_d      5.645      0.19     -14    30
# Comp:  2            [OI]6300_d      1.476      0.19     -14    30
# Comp:  2           [NII]6583_d      9.337      0.19     -14    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        41
#  comp.  1:       -12        15
#  comp.  2:       -15        24
# chi2/DOF: 0.9276; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.731      0.14     -12    15
# Comp:  1                 Hbeta      7.507      0.14     -12    15
# Comp:  1                Halpha      21.36      0.14     -12    15
# Comp:  2             [SII]6716      4.018      0.15     -15    24
# Comp:  2             [SII]6731      3.187      0.15     -15    24
# Comp:  2              HeII4687    0.04662      0.15     -15    24
# Comp:  2               HeI5876     0.6500      0.15     -15    24
# Comp:  2          [OIII]5007_d      5.353      0.19     -15    24
# Comp:  2            [OI]6300_d      1.524      0.19     -15    24
# Comp:  2           [NII]6583_d      9.204      0.19     -15    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36         1
#  comp.  1:       -11        14
#  comp.  2:       -16        25
# chi2/DOF: 0.9182; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.466      0.14     -11    14
# Comp:  1                 Hbeta      7.734      0.14     -11    14
# Comp:  1                Halpha      21.70      0.14     -11    14
# Comp:  2             [SII]6716      4.002      0.15     -16    25
# Comp:  2             [SII]6731      3.152      0.15     -16    25
# Comp:  2              HeII4687      0.000      0.15     -16    25
# Comp:  2               HeI5876     0.6557      0.15     -16    25
# Comp:  2          [OIII]5007_d      5.514      0.19     -16    25
# Comp:  2            [OI]6300_d      1.370      0.19     -16    25
# Comp:  2           [NII]6583_d      9.189      0.19     -16    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        37
#  comp.  1:       -12         9
#  comp.  2:       -15        28
# chi2/DOF: 0.9277; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.337      0.14     -12     9
# Comp:  1                 Hbeta      7.716      0.14     -12     9
# Comp:  1                Halpha      21.48      0.14     -12     9
# Comp:  2             [SII]6716      4.122      0.15     -15    28
# Comp:  2             [SII]6731      3.225      0.15     -15    28
# Comp:  2              HeII4687      0.000      0.15     -15    28
# Comp:  2               HeI5876     0.6750      0.15     -15    28
# Comp:  2          [OIII]5007_d      5.677      0.19     -15    28
# Comp:  2            [OI]6300_d      1.513      0.19     -15    28
# Comp:  2           [NII]6583_d      9.333      0.19     -15    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        57
#  comp.  1:       -13        12
#  comp.  2:       -14        30
# chi2/DOF: 0.9046; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.194      0.14     -13    12
# Comp:  1                 Hbeta      6.290      0.14     -13    12
# Comp:  1                Halpha      21.90      0.14     -13    12
# Comp:  2             [SII]6716      4.112      0.15     -14    30
# Comp:  2             [SII]6731      3.231      0.15     -14    30
# Comp:  2              HeII4687   0.004785      0.15     -14    30
# Comp:  2               HeI5876     0.5941      0.15     -14    30
# Comp:  2          [OIII]5007_d      5.577      0.19     -14    30
# Comp:  2            [OI]6300_d      1.330      0.19     -14    30
# Comp:  2           [NII]6583_d      9.353      0.19     -14    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4         7
#  comp.  1:       -13         1
#  comp.  2:       -14        25
# chi2/DOF: 0.9071; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.361      0.14     -13     1
# Comp:  1                 Hbeta      6.231      0.14     -13     1
# Comp:  1                Halpha      21.66      0.14     -13     1
# Comp:  2             [SII]6716      4.084      0.15     -14    25
# Comp:  2             [SII]6731      3.238      0.15     -14    25
# Comp:  2              HeII4687      0.000      0.15     -14    25
# Comp:  2               HeI5876     0.6791      0.15     -14    25
# Comp:  2          [OIII]5007_d      5.859      0.19     -14    25
# Comp:  2            [OI]6300_d      1.303      0.19     -14    25
# Comp:  2           [NII]6583_d      9.101      0.19     -14    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        15
#  comp.  1:       -13         1
#  comp.  2:       -14        29
# chi2/DOF: 0.9187; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.208      0.14     -13     1
# Comp:  1                 Hbeta      6.682      0.14     -13     1
# Comp:  1                Halpha      21.74      0.14     -13     1
# Comp:  2             [SII]6716      4.164      0.15     -14    29
# Comp:  2             [SII]6731      3.293      0.15     -14    29
# Comp:  2              HeII4687      0.000      0.15     -14    29
# Comp:  2               HeI5876     0.6363      0.15     -14    29
# Comp:  2          [OIII]5007_d      5.698      0.19     -14    29
# Comp:  2            [OI]6300_d      1.446      0.19     -14    29
# Comp:  2           [NII]6583_d      9.360      0.19     -14    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        85
#  comp.  1:       -12         1
#  comp.  2:       -12        31
# chi2/DOF: 0.9104; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.453      0.14     -12     1
# Comp:  1                 Hbeta      8.112      0.14     -12     1
# Comp:  1                Halpha      21.34      0.14     -12     1
# Comp:  2             [SII]6716      4.135      0.15     -12    31
# Comp:  2             [SII]6731      3.225      0.15     -12    31
# Comp:  2              HeII4687      0.000      0.15     -12    31
# Comp:  2               HeI5876     0.6458      0.15     -12    31
# Comp:  2          [OIII]5007_d      5.936      0.19     -12    31
# Comp:  2            [OI]6300_d      1.489      0.19     -12    31
# Comp:  2           [NII]6583_d      9.370      0.19     -12    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2        43
#  comp.  1:       -12         9
#  comp.  2:       -12        29
# chi2/DOF: 0.9191; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.205      0.14     -12     9
# Comp:  1                 Hbeta      7.847      0.14     -12     9
# Comp:  1                Halpha      21.49      0.14     -12     9
# Comp:  2             [SII]6716      4.118      0.15     -12    29
# Comp:  2             [SII]6731      3.217      0.15     -12    29
# Comp:  2              HeII4687      0.000      0.15     -12    29
# Comp:  2               HeI5876     0.6961      0.15     -12    29
# Comp:  2          [OIII]5007_d      6.045      0.19     -12    29
# Comp:  2            [OI]6300_d      1.389      0.19     -12    29
# Comp:  2           [NII]6583_d      9.430      0.19     -12    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        73
#  comp.  1:       -14         1
#  comp.  2:       -13        31
# chi2/DOF: 0.9139; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.615      0.14     -14     1
# Comp:  1                 Hbeta      8.003      0.14     -14     1
# Comp:  1                Halpha      21.79      0.14     -14     1
# Comp:  2             [SII]6716      4.147      0.15     -13    31
# Comp:  2             [SII]6731      3.258      0.15     -13    31
# Comp:  2              HeII4687      0.000      0.15     -13    31
# Comp:  2               HeI5876     0.6804      0.15     -13    31
# Comp:  2          [OIII]5007_d      6.006      0.19     -13    31
# Comp:  2            [OI]6300_d      1.503      0.19     -13    31
# Comp:  2           [NII]6583_d      9.386      0.19     -13    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        33
#  comp.  1:       -11        19
#  comp.  2:       -14        26
# chi2/DOF: 0.9156; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.815      0.15     -11    19
# Comp:  1                 Hbeta      7.840      0.15     -11    19
# Comp:  1                Halpha      21.53      0.15     -11    19
# Comp:  2             [SII]6716      4.079      0.15     -14    26
# Comp:  2             [SII]6731      3.208      0.15     -14    26
# Comp:  2              HeII4687      0.000      0.15     -14    26
# Comp:  2               HeI5876     0.6371      0.15     -14    26
# Comp:  2          [OIII]5007_d      5.833      0.19     -14    26
# Comp:  2            [OI]6300_d      1.383      0.19     -14    26
# Comp:  2           [NII]6583_d      9.191      0.19     -14    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16        33
#  comp.  1:       -12         1
#  comp.  2:       -15        26
# chi2/DOF: 0.9260; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.567      0.14     -12     1
# Comp:  1                 Hbeta      7.233      0.14     -12     1
# Comp:  1                Halpha      21.34      0.14     -12     1
# Comp:  2             [SII]6716      4.040      0.15     -15    26
# Comp:  2             [SII]6731      3.186      0.15     -15    26
# Comp:  2              HeII4687    0.09532      0.15     -15    26
# Comp:  2               HeI5876     0.6640      0.15     -15    26
# Comp:  2          [OIII]5007_d      5.284      0.19     -15    26
# Comp:  2            [OI]6300_d      1.515      0.19     -15    26
# Comp:  2           [NII]6583_d      9.116      0.19     -15    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        14
#  comp.  1:       -12        19
#  comp.  2:       -14        26
# chi2/DOF: 0.9174; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.401      0.15     -12    19
# Comp:  1                 Hbeta      6.718      0.15     -12    19
# Comp:  1                Halpha      21.75      0.15     -12    19
# Comp:  2             [SII]6716      4.035      0.15     -14    26
# Comp:  2             [SII]6731      3.199      0.15     -14    26
# Comp:  2              HeII4687      0.000      0.15     -14    26
# Comp:  2               HeI5876     0.6948      0.15     -14    26
# Comp:  2          [OIII]5007_d      5.657      0.19     -14    26
# Comp:  2            [OI]6300_d      1.344      0.19     -14    26
# Comp:  2           [NII]6583_d      9.117      0.19     -14    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        66
#  comp.  1:       -15         1
#  comp.  2:       -13        28
# chi2/DOF: 0.9103; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.414      0.14     -15     1
# Comp:  1                 Hbeta      7.989      0.14     -15     1
# Comp:  1                Halpha      21.45      0.14     -15     1
# Comp:  2             [SII]6716      4.105      0.15     -13    28
# Comp:  2             [SII]6731      3.235      0.15     -13    28
# Comp:  2              HeII4687      0.000      0.15     -13    28
# Comp:  2               HeI5876     0.6676      0.15     -13    28
# Comp:  2          [OIII]5007_d      5.877      0.19     -13    28
# Comp:  2            [OI]6300_d      1.335      0.19     -13    28
# Comp:  2           [NII]6583_d      9.495      0.19     -13    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        21        59
#  comp.  1:       -14         1
#  comp.  2:       -13        29
# chi2/DOF: 0.9120; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.628      0.14     -14     1
# Comp:  1                 Hbeta      7.945      0.14     -14     1
# Comp:  1                Halpha      21.81      0.14     -14     1
# Comp:  2             [SII]6716      4.101      0.15     -13    29
# Comp:  2             [SII]6731      3.249      0.15     -13    29
# Comp:  2              HeII4687      0.000      0.15     -13    29
# Comp:  2               HeI5876     0.6562      0.15     -13    29
# Comp:  2          [OIII]5007_d      5.938      0.19     -13    29
# Comp:  2            [OI]6300_d      1.254      0.19     -13    29
# Comp:  2           [NII]6583_d      9.530      0.19     -13    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        86
#  comp.  1:       -13         2
#  comp.  2:       -15        24
# chi2/DOF: 0.9074; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.246      0.14     -13     2
# Comp:  1                 Hbeta      8.035      0.14     -13     2
# Comp:  1                Halpha      20.90      0.14     -13     2
# Comp:  2             [SII]6716      3.991      0.15     -15    24
# Comp:  2             [SII]6731      3.142      0.15     -15    24
# Comp:  2              HeII4687    0.07299      0.15     -15    24
# Comp:  2               HeI5876     0.6159      0.15     -15    24
# Comp:  2          [OIII]5007_d      5.378      0.19     -15    24
# Comp:  2            [OI]6300_d      1.398      0.19     -15    24
# Comp:  2           [NII]6583_d      9.165      0.19     -15    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        35
#  comp.  1:       -13        11
#  comp.  2:       -13        28
# chi2/DOF: 0.9339; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.428      0.14     -13    11
# Comp:  1                 Hbeta      7.274      0.14     -13    11
# Comp:  1                Halpha      21.46      0.14     -13    11
# Comp:  2             [SII]6716      4.102      0.15     -13    28
# Comp:  2             [SII]6731      3.219      0.15     -13    28
# Comp:  2              HeII4687      0.000      0.15     -13    28
# Comp:  2               HeI5876     0.6743      0.15     -13    28
# Comp:  2          [OIII]5007_d      5.849      0.19     -13    28
# Comp:  2            [OI]6300_d      1.363      0.19     -13    28
# Comp:  2           [NII]6583_d      9.388      0.19     -13    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21         1
#  comp.  1:       -13        16
#  comp.  2:       -14        22
# chi2/DOF: 0.9072; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.275      0.14     -13    16
# Comp:  1                 Hbeta      8.214      0.14     -13    16
# Comp:  1                Halpha      21.57      0.14     -13    16
# Comp:  2             [SII]6716      3.973      0.15     -14    22
# Comp:  2             [SII]6731      3.135      0.15     -14    22
# Comp:  2              HeII4687      0.000      0.15     -14    22
# Comp:  2               HeI5876     0.6748      0.15     -14    22
# Comp:  2          [OIII]5007_d      5.794      0.19     -14    22
# Comp:  2            [OI]6300_d      1.495      0.19     -14    22
# Comp:  2           [NII]6583_d      9.100      0.19     -14    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8        49
#  comp.  1:       -13         1
#  comp.  2:       -14        25
# chi2/DOF: 0.9085; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.714      0.14     -13     1
# Comp:  1                 Hbeta      6.479      0.14     -13     1
# Comp:  1                Halpha      21.46      0.14     -13     1
# Comp:  2             [SII]6716      4.041      0.15     -14    25
# Comp:  2             [SII]6731      3.171      0.15     -14    25
# Comp:  2              HeII4687      0.000      0.15     -14    25
# Comp:  2               HeI5876     0.6251      0.15     -14    25
# Comp:  2          [OIII]5007_d      5.822      0.19     -14    25
# Comp:  2            [OI]6300_d      1.372      0.19     -14    25
# Comp:  2           [NII]6583_d      9.328      0.19     -14    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        57
#  comp.  1:       -12        16
#  comp.  2:       -13        27
# chi2/DOF: 0.9257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.282      0.15     -12    16
# Comp:  1                 Hbeta      7.160      0.15     -12    16
# Comp:  1                Halpha      22.00      0.15     -12    16
# Comp:  2             [SII]6716      4.091      0.15     -13    27
# Comp:  2             [SII]6731      3.244      0.15     -13    27
# Comp:  2              HeII4687     0.1033      0.15     -13    27
# Comp:  2               HeI5876     0.6274      0.15     -13    27
# Comp:  2          [OIII]5007_d      5.442      0.19     -13    27
# Comp:  2            [OI]6300_d      1.457      0.19     -13    27
# Comp:  2           [NII]6583_d      9.371      0.19     -13    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        84
#  comp.  1:       -12         1
#  comp.  2:       -16        25
# chi2/DOF: 0.9098; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.255      0.14     -12     1
# Comp:  1                 Hbeta      6.233      0.14     -12     1
# Comp:  1                Halpha      21.33      0.14     -12     1
# Comp:  2             [SII]6716      4.115      0.15     -16    25
# Comp:  2             [SII]6731      3.252      0.15     -16    25
# Comp:  2              HeII4687      0.000      0.15     -16    25
# Comp:  2               HeI5876     0.6541      0.15     -16    25
# Comp:  2          [OIII]5007_d      5.592      0.19     -16    25
# Comp:  2            [OI]6300_d      1.343      0.19     -16    25
# Comp:  2           [NII]6583_d      9.153      0.19     -16    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        82
#  comp.  1:       -14         1
#  comp.  2:       -12        27
# chi2/DOF: 0.9185; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.280      0.14     -14     1
# Comp:  1                 Hbeta      6.948      0.14     -14     1
# Comp:  1                Halpha      21.72      0.14     -14     1
# Comp:  2             [SII]6716      4.092      0.15     -12    27
# Comp:  2             [SII]6731      3.222      0.15     -12    27
# Comp:  2              HeII4687      0.000      0.15     -12    27
# Comp:  2               HeI5876     0.6446      0.15     -12    27
# Comp:  2          [OIII]5007_d      5.826      0.19     -12    27
# Comp:  2            [OI]6300_d      1.401      0.19     -12    27
# Comp:  2           [NII]6583_d      9.321      0.19     -12    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        15
#  comp.  1:       -14         1
#  comp.  2:       -14        24
# chi2/DOF: 0.9282; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.683      0.14     -14     1
# Comp:  1                 Hbeta      7.206      0.14     -14     1
# Comp:  1                Halpha      21.26      0.14     -14     1
# Comp:  2             [SII]6716      4.061      0.15     -14    24
# Comp:  2             [SII]6731      3.169      0.15     -14    24
# Comp:  2              HeII4687    0.05676      0.15     -14    24
# Comp:  2               HeI5876     0.5968      0.15     -14    24
# Comp:  2          [OIII]5007_d      5.741      0.19     -14    24
# Comp:  2            [OI]6300_d      1.440      0.19     -14    24
# Comp:  2           [NII]6583_d      8.977      0.19     -14    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        84
#  comp.  1:       -14         1
#  comp.  2:       -13        26
# chi2/DOF: 0.9151; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        29
#  comp.  1:       -15         1
#  comp.  2:       -16        25
# chi2/DOF: 0.9173; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.174      0.14     -15     1
# Comp:  1                 Hbeta      6.806      0.14     -15     1
# Comp:  1                Halpha      21.35      0.14     -15     1
# Comp:  2             [SII]6716      4.057      0.15     -16    25
# Comp:  2             [SII]6731      3.200      0.15     -16    25
# Comp:  2              HeII4687      0.000      0.15     -16    25
# Comp:  2               HeI5876     0.6907      0.15     -16    25
# Comp:  2          [OIII]5007_d      5.523      0.19     -16    25
# Comp:  2            [OI]6300_d      1.471      0.19     -16    25
# Comp:  2           [NII]6583_d      9.221      0.19     -16    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15         1
#  comp.  1:       -12         8
#  comp.  2:       -14        25
# chi2/DOF: 0.9219; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.332      0.14     -12     8
# Comp:  1                 Hbeta      7.636      0.14     -12     8
# Comp:  1                Halpha      21.07      0.14     -12     8
# Comp:  2             [SII]6716      4.122      0.15     -14    25
# Comp:  2             [SII]6731      3.255      0.15     -14    25
# Comp:  2              HeII4687      0.000      0.15     -14    25
# Comp:  2               HeI5876     0.6349      0.15     -14    25
# Comp:  2          [OIII]5007_d      6.056      0.19     -14    25
# Comp:  2            [OI]6300_d      1.300      0.19     -14    25
# Comp:  2           [NII]6583_d      9.270      0.19     -14    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18         1
#  comp.  1:       -13        14
#  comp.  2:       -16        25
# chi2/DOF: 0.9053; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.201      0.14     -13    14
# Comp:  1                 Hbeta      8.244      0.14     -13    14
# Comp:  1                Halpha      21.53      0.14     -13    14
# Comp:  2             [SII]6716      4.010      0.15     -16    25
# Comp:  2             [SII]6731      3.185      0.15     -16    25
# Comp:  2              HeII4687    0.09174      0.15     -16    25
# Comp:  2               HeI5876     0.6190      0.15     -16    25
# Comp:  2          [OIII]5007_d      5.348      0.19     -16    25
# Comp:  2            [OI]6300_d      1.532      0.19     -16    25
# Comp:  2           [NII]6583_d      9.035      0.19     -16    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        25
#  comp.  1:       -12        15
#  comp.  2:       -12        26
# chi2/DOF: 0.9022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.795      0.14     -12    15
# Comp:  1                 Hbeta      6.332      0.14     -12    15
# Comp:  1                Halpha      21.63      0.14     -12    15
# Comp:  2             [SII]6716      4.000      0.15     -12    26
# Comp:  2             [SII]6731      3.139      0.15     -12    26
# Comp:  2              HeII4687    0.06991      0.15     -12    26
# Comp:  2               HeI5876     0.7003      0.15     -12    26
# Comp:  2          [OIII]5007_d      5.736      0.19     -12    26
# Comp:  2            [OI]6300_d      1.290      0.19     -12    26
# Comp:  2           [NII]6583_d      9.228      0.19     -12    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        56
#  comp.  1:       -12         1
#  comp.  2:       -16        26
# chi2/DOF: 0.9233; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.461      0.14     -12     1
# Comp:  1                 Hbeta      6.634      0.14     -12     1
# Comp:  1                Halpha      21.35      0.14     -12     1
# Comp:  2             [SII]6716      4.050      0.15     -16    26
# Comp:  2             [SII]6731      3.171      0.15     -16    26
# Comp:  2              HeII4687     0.1029      0.15     -16    26
# Comp:  2               HeI5876     0.6285      0.15     -16    26
# Comp:  2          [OIII]5007_d      5.420      0.19     -16    26
# Comp:  2            [OI]6300_d      1.398      0.19     -16    26
# Comp:  2           [NII]6583_d      9.045      0.19     -16    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        65
#  comp.  1:       -13         1
#  comp.  2:       -15        27
# chi2/DOF: 0.9054; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.544      0.14     -13     1
# Comp:  1                 Hbeta      8.183      0.14     -13     1
# Comp:  1                Halpha      21.01      0.14     -13     1
# Comp:  2             [SII]6716      4.124      0.15     -15    27
# Comp:  2             [SII]6731      3.253      0.15     -15    27
# Comp:  2              HeII4687    0.07059      0.15     -15    27
# Comp:  2               HeI5876     0.6655      0.15     -15    27
# Comp:  2          [OIII]5007_d      5.567      0.19     -15    27
# Comp:  2            [OI]6300_d      1.463      0.19     -15    27
# Comp:  2           [NII]6583_d      9.519      0.19     -15    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27         1
#  comp.  1:       -14         1
#  comp.  2:       -12        28
# chi2/DOF: 0.8988; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.159      0.14     -14     1
# Comp:  1                 Hbeta      6.267      0.14     -14     1
# Comp:  1                Halpha      21.62      0.14     -14     1
# Comp:  2             [SII]6716      4.030      0.15     -12    28
# Comp:  2             [SII]6731      3.140      0.15     -12    28
# Comp:  2              HeII4687    0.05711      0.15     -12    28
# Comp:  2               HeI5876     0.6766      0.15     -12    28
# Comp:  2          [OIII]5007_d      5.724      0.19     -12    28
# Comp:  2            [OI]6300_d      1.381      0.19     -12    28
# Comp:  2           [NII]6583_d      9.272      0.19     -12    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        55
#  comp.  1:       -11        17
#  comp.  2:       -13        31
# chi2/DOF: 0.9132; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.334      0.15     -11    17
# Comp:  1                 Hbeta      6.625      0.15     -11    17
# Comp:  1                Halpha      21.71      0.15     -11    17
# Comp:  2             [SII]6716      4.141      0.15     -13    31
# Comp:  2             [SII]6731      3.309      0.15     -13    31
# Comp:  2              HeII4687      0.000      0.15     -13    31
# Comp:  2               HeI5876     0.7245      0.15     -13    31
# Comp:  2          [OIII]5007_d      6.118      0.19     -13    31
# Comp:  2            [OI]6300_d      1.363      0.19     -13    31
# Comp:  2           [NII]6583_d      9.343      0.19     -13    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        59
#  comp.  1:       -14         1
#  comp.  2:       -13        27
# chi2/DOF: 0.9277; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.538      0.14     -14     1
# Comp:  1                 Hbeta      7.607      0.14     -14     1
# Comp:  1                Halpha      21.29      0.14     -14     1
# Comp:  2             [SII]6716      4.051      0.15     -13    27
# Comp:  2             [SII]6731      3.197      0.15     -13    27
# Comp:  2              HeII4687    0.09951      0.15     -13    27
# Comp:  2               HeI5876     0.6884      0.15     -13    27
# Comp:  2          [OIII]5007_d      5.689      0.19     -13    27
# Comp:  2            [OI]6300_d      1.463      0.19     -13    27
# Comp:  2           [NII]6583_d      9.337      0.19     -13    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        41
#  comp.  1:       -13         9
#  comp.  2:       -15        26
# chi2/DOF: 0.9268; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.679      0.14     -13     9
# Comp:  1                 Hbeta      7.141      0.14     -13     9
# Comp:  1                Halpha      21.03      0.14     -13     9
# Comp:  2             [SII]6716      4.057      0.15     -15    26
# Comp:  2             [SII]6731      3.181      0.15     -15    26
# Comp:  2              HeII4687      0.000      0.15     -15    26
# Comp:  2               HeI5876     0.6172      0.15     -15    26
# Comp:  2          [OIII]5007_d      5.800      0.19     -15    26
# Comp:  2            [OI]6300_d      1.499      0.19     -15    26
# Comp:  2           [NII]6583_d      9.265      0.19     -15    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        27        75
#  comp.  1:       -13         8
#  comp.  2:       -14        26
# chi2/DOF: 0.9148; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.083      0.14     -13     8
# Comp:  1                 Hbeta      6.674      0.14     -13     8
# Comp:  1                Halpha      20.97      0.14     -13     8
# Comp:  2             [SII]6716      4.025      0.15     -14    26
# Comp:  2             [SII]6731      3.163      0.15     -14    26
# Comp:  2              HeII4687      0.000      0.15     -14    26
# Comp:  2               HeI5876     0.6233      0.15     -14    26
# Comp:  2          [OIII]5007_d      5.812      0.19     -14    26
# Comp:  2            [OI]6300_d      1.394      0.19     -14    26
# Comp:  2           [NII]6583_d      9.116      0.19     -14    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        52
#  comp.  1:       -12         9
#  comp.  2:       -13        30
# chi2/DOF: 0.9209; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.840      0.14     -12     9
# Comp:  1                 Hbeta      7.874      0.14     -12     9
# Comp:  1                Halpha      21.83      0.14     -12     9
# Comp:  2             [SII]6716      4.100      0.15     -13    30
# Comp:  2             [SII]6731      3.224      0.15     -13    30
# Comp:  2              HeII4687     0.1059      0.15     -13    30
# Comp:  2               HeI5876     0.6716      0.15     -13    30
# Comp:  2          [OIII]5007_d      5.792      0.19     -13    30
# Comp:  2            [OI]6300_d      1.559      0.19     -13    30
# Comp:  2           [NII]6583_d      9.345      0.19     -13    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        13        59
#  comp.  1:       -13         1
#  comp.  2:       -14        28
# chi2/DOF: 0.9217; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.593      0.14     -13     1
# Comp:  1                 Hbeta      6.919      0.14     -13     1
# Comp:  1                Halpha      21.48      0.14     -13     1
# Comp:  2             [SII]6716      4.133      0.15     -14    28
# Comp:  2             [SII]6731      3.257      0.15     -14    28
# Comp:  2              HeII4687      0.000      0.15     -14    28
# Comp:  2               HeI5876     0.7111      0.15     -14    28
# Comp:  2          [OIII]5007_d      5.849      0.19     -14    28
# Comp:  2            [OI]6300_d      1.514      0.19     -14    28
# Comp:  2           [NII]6583_d      9.235      0.19     -14    28
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.2089695 , 0.63845993, 0.39287613, 0.05937176, 0.05118086,
#        0.04916576, 0.03712803, 0.2200848 , 0.11086666, 0.17087651])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 3.069559  ,  7.31601121, 29.33913051,  5.70269333,  4.50525636,
#         0.        ,  0.79936323,  5.92228104,  1.87923335, 12.73410104])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_8_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_8", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_8_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_8_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_8_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0        Hgamma  0.472258    0.032150
# 1         Hbeta  1.125582    0.098228
# 2        Halpha  4.513882    0.060445
# 3     [SII]6716  0.877370    0.009134
# 4     [SII]6731  0.693142    0.007874
# 5      HeII4687  0.000000    0.007564
# 6       HeI5876  0.122984    0.005712
# 7  [OIII]5007_d  0.911154    0.033860
# 8    [OI]6300_d  0.289124    0.017057
# 9   [NII]6583_d  1.959166    0.026290
#           Name      Flux  Error_flux
# 0       Hgamma  0.472258    0.032150
# 1        Hbeta  1.125582    0.098228
# 2       Halpha  4.513882    0.060445
# 3    [SII]6716  0.877370    0.009134
# 4    [SII]6731  0.693142    0.007874
# 5     HeII4687  0.000000    0.007564
# 6      HeI5876  0.122984    0.005712
# 7   [OIII]4959  0.227789    0.033860
# 8   [OIII]5007  0.683366    0.033860
# 9     [OI]6300  0.216843    0.017057
# 10    [OI]6364  0.072281    0.017057
# 11   [NII]6548  0.489792    0.026290
# 12   [NII]6583  1.469375    0.026290

# %%
np.median(flux_rf_rebin)
# Out:
# 0.15385193328265673
