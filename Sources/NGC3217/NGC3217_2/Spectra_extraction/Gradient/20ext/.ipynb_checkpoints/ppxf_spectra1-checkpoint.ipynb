# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_1.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_1/Spectra_extraction/Gradient/redshift.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4314.03901503 4315.47324864 4316.90748224 ... 6874.1460011  6875.58023471
#  6877.01446832] [-0.00209118 -0.00562903  0.00573803 ...  0.00824501  0.01042704
#   0.01264705] [0.00515955 0.00515955 0.00515955 ... 0.00515955 0.00515955 0.00515955]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -79       125
# chi2/DOF: 0.2066; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
# chi2/DOF: 0.1516; DOF: 1880; degree = 4; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 24; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-34.24692917,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        17         1
#  comp.  1:       321       587
#  comp.  2:        97         1
# chi2/DOF: 0.8878; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.25       2.7     321   587
# Comp:  1                 Hbeta      9.053       2.7     321   587
# Comp:  1                Halpha      5.112       2.8     321   587
# Comp:  2             [SII]6716    0.04522      0.92      97     1
# Comp:  2             [SII]6731      2.368      0.92      97     1
# Comp:  2              HeII4687      0.000      0.92      97     1
# Comp:  2               HeI5876    0.06964      0.92      97     1
# Comp:  2          [OIII]5007_d      2.767       1.2      97     1
# Comp:  2            [OI]6300_d      2.902       1.2      97     1
# Comp:  2           [NII]6583_d      0.000       1.2      97     1
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  2.339; gas flux:     20 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  0.952; gas flux:      9 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise: 0.5375; gas flux:      7 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise: 0.04124; gas flux:      0 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  1.989; gas flux:      3 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.06522; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  1.936; gas flux:      3 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.896; gas flux:      4 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        32       105
#  comp.  1:       631       254
#  comp.  2:       121        67
# chi2/DOF: 0.8727; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 92; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.393       1.8     631   254
# Comp:  1                 Hbeta     0.9069       1.8     631   254
# Comp:  1                Halpha      1.324       1.9     631   254
# Comp:  2             [SII]6716    0.01782       1.1     121    67
# Comp:  2             [SII]6731      6.623       1.1     121    67
# Comp:  2              HeII4687     0.6670       1.1     121    67
# Comp:  2               HeI5876      0.000       1.1     121    67
# Comp:  2          [OIII]5007_d      3.272       1.4     121    67
# Comp:  2            [OI]6300_d      3.566       1.4     121    67
# Comp:  2           [NII]6583_d     0.5590       1.4     121    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        90        58
#  comp.  1:       349       252
#  comp.  2:        76         1
# chi2/DOF: 0.8775; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.882       1.8     349   252
# Comp:  1                 Hbeta      6.709       1.8     349   252
# Comp:  1                Halpha      3.984       1.8     349   252
# Comp:  2             [SII]6716      0.000      0.92      76     1
# Comp:  2             [SII]6731      3.889      0.92      76     1
# Comp:  2              HeII4687     0.7953      0.92      76     1
# Comp:  2               HeI5876      0.000      0.92      76     1
# Comp:  2          [OIII]5007_d      2.574       1.2      76     1
# Comp:  2            [OI]6300_d      2.778       1.2      76     1
# Comp:  2           [NII]6583_d      1.058       1.2      76     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28         1
#  comp.  1:       388       471
#  comp.  2:       140         1
# chi2/DOF: 0.8751; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.08       2.5     388   471
# Comp:  1                 Hbeta      4.617       2.5     388   471
# Comp:  1                Halpha      5.147       2.5     388   471
# Comp:  2             [SII]6716    0.03968      0.92     140     1
# Comp:  2             [SII]6731      5.175      0.92     140     1
# Comp:  2              HeII4687     0.3601      0.92     140     1
# Comp:  2               HeI5876      0.000      0.92     140     1
# Comp:  2          [OIII]5007_d      1.749       1.2     140     1
# Comp:  2            [OI]6300_d      3.273       1.2     140     1
# Comp:  2           [NII]6583_d      0.000       1.2     140     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        23       369
#  comp.  1:       308       573
#  comp.  2:       123        19
# chi2/DOF: 0.8796; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      26.98       2.7     308   573
# Comp:  1                 Hbeta      13.99       2.7     308   573
# Comp:  1                Halpha      8.358       2.8     308   573
# Comp:  2             [SII]6716      0.000      0.94     123    19
# Comp:  2             [SII]6731      1.546      0.94     123    19
# Comp:  2              HeII4687     0.1786      0.94     123    19
# Comp:  2               HeI5876     0.2184      0.94     123    19
# Comp:  2          [OIII]5007_d      2.843       1.2     123    19
# Comp:  2            [OI]6300_d      3.065       1.2     123    19
# Comp:  2           [NII]6583_d     0.1609       1.2     123    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26        37
#  comp.  1:       460       488
#  comp.  2:        67         1
# chi2/DOF: 0.8770; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.94       2.5     460   488
# Comp:  1                 Hbeta      3.757       2.5     460   488
# Comp:  1                Halpha      1.075       2.6     460   488
# Comp:  2             [SII]6716      0.000      0.92      67     1
# Comp:  2             [SII]6731      3.589      0.92      67     1
# Comp:  2              HeII4687     0.2592      0.92      67     1
# Comp:  2               HeI5876     0.6503      0.92      67     1
# Comp:  2          [OIII]5007_d      2.264       1.2      67     1
# Comp:  2            [OI]6300_d      2.914       1.2      67     1
# Comp:  2           [NII]6583_d      0.000       1.2      67     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        98
#  comp.  1:       251       434
#  comp.  2:        49       152
# chi2/DOF: 0.8779; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 84; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      24.22       2.4     251   434
# Comp:  1                 Hbeta      7.367       2.4     251   434
# Comp:  1                Halpha      6.220       2.4     251   434
# Comp:  2             [SII]6716      0.000       1.5      49   152
# Comp:  2             [SII]6731      4.181       1.5      49   152
# Comp:  2              HeII4687      1.227       1.5      49   152
# Comp:  2               HeI5876     0.8717       1.5      49   152
# Comp:  2          [OIII]5007_d      3.640       1.8      49   152
# Comp:  2            [OI]6300_d      5.682       1.8      49   152
# Comp:  2           [NII]6583_d      2.065       1.9      49   152
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37       113
#  comp.  1:       212       482
#  comp.  2:       118        29
# chi2/DOF: 0.8773; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      32.34       2.5     212   482
# Comp:  1                 Hbeta      15.72       2.5     212   482
# Comp:  1                Halpha      8.005       2.5     212   482
# Comp:  2             [SII]6716     0.3160      0.96     118    29
# Comp:  2             [SII]6731      5.395      0.96     118    29
# Comp:  2              HeII4687     0.3909      0.96     118    29
# Comp:  2               HeI5876     0.2426      0.96     118    29
# Comp:  2          [OIII]5007_d      3.634       1.2     118    29
# Comp:  2            [OI]6300_d      3.642       1.2     118    29
# Comp:  2           [NII]6583_d     0.1680       1.2     118    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -112       362
#  comp.  1:         1       731
#  comp.  2:       121        77
# chi2/DOF: 0.8712; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 13; Func calls: 99; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      58.30       3.0       1   731
# Comp:  1                 Hbeta      28.31       3.1       1   731
# Comp:  1                Halpha      9.403       3.2       1   731
# Comp:  2             [SII]6716      0.000       1.1     121    77
# Comp:  2             [SII]6731      6.547       1.1     121    77
# Comp:  2              HeII4687     0.7549       1.1     121    77
# Comp:  2               HeI5876      1.334       1.1     121    77
# Comp:  2          [OIII]5007_d      2.590       1.4     121    77
# Comp:  2            [OI]6300_d      2.888       1.4     121    77
# Comp:  2           [NII]6583_d      0.000       1.5     121    77
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7         1
#  comp.  1:       214       635
#  comp.  2:       123        23
# chi2/DOF: 0.8825; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      37.87       2.8     214   635
# Comp:  1                 Hbeta      14.72       2.8     214   635
# Comp:  1                Halpha      10.73       2.9     214   635
# Comp:  2             [SII]6716     0.1086      0.94     123    23
# Comp:  2             [SII]6731      1.557      0.94     123    23
# Comp:  2              HeII4687    0.04287      0.94     123    23
# Comp:  2               HeI5876      0.000      0.94     123    23
# Comp:  2          [OIII]5007_d      3.216       1.2     123    23
# Comp:  2            [OI]6300_d      2.217       1.2     123    23
# Comp:  2           [NII]6583_d    0.03916       1.2     123    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       102        46
#  comp.  1:       254       455
#  comp.  2:        11       154
# chi2/DOF: 0.8724; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 68; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      32.21       2.4     254   455
# Comp:  1                 Hbeta      18.31       2.4     254   455
# Comp:  1                Halpha      8.394       2.6     254   455
# Comp:  2             [SII]6716      0.000       1.5      11   154
# Comp:  2             [SII]6731      2.270       1.5      11   154
# Comp:  2              HeII4687      2.444       1.5      11   154
# Comp:  2               HeI5876      0.000       1.5      11   154
# Comp:  2          [OIII]5007_d      3.455       1.8      11   154
# Comp:  2            [OI]6300_d      6.270       1.8      11   154
# Comp:  2           [NII]6583_d      1.305       1.9      11   154
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34         1
#  comp.  1:       365       597
#  comp.  2:        83         1
# chi2/DOF: 0.8829; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      21.38       2.8     365   597
# Comp:  1                 Hbeta      9.414       2.8     365   597
# Comp:  1                Halpha      7.781       2.9     365   597
# Comp:  2             [SII]6716     0.3776      0.92      83     1
# Comp:  2             [SII]6731      3.594      0.92      83     1
# Comp:  2              HeII4687     0.7385      0.92      83     1
# Comp:  2               HeI5876     0.6775      0.92      83     1
# Comp:  2          [OIII]5007_d      3.131       1.2      83     1
# Comp:  2            [OI]6300_d      2.996       1.2      83     1
# Comp:  2           [NII]6583_d      0.000       1.2      83     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12        54
#  comp.  1:       301      1000
#  comp.  2:       114        46
# chi2/DOF: 0.8762; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      34.70       3.5     301  1000
# Comp:  1                 Hbeta      11.98       3.6     301  1000
# Comp:  1                Halpha      9.549       3.8     301  1000
# Comp:  2             [SII]6716     0.3709       1.0     114    46
# Comp:  2             [SII]6731      5.886       1.0     114    46
# Comp:  2              HeII4687     0.6820       1.0     114    46
# Comp:  2               HeI5876     0.3103       1.0     114    46
# Comp:  2          [OIII]5007_d      3.817       1.3     114    46
# Comp:  2            [OI]6300_d      2.633       1.3     114    46
# Comp:  2           [NII]6583_d      0.000       1.4     114    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47       110
#  comp.  1:       405       521
#  comp.  2:       132        62
# chi2/DOF: 0.8835; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.98       2.6     405   521
# Comp:  1                 Hbeta      9.290       2.6     405   521
# Comp:  1                Halpha      6.030       2.7     405   521
# Comp:  2             [SII]6716     0.1020       1.1     132    62
# Comp:  2             [SII]6731      2.595       1.1     132    62
# Comp:  2              HeII4687      0.000       1.1     132    62
# Comp:  2               HeI5876     0.1442       1.1     132    62
# Comp:  2          [OIII]5007_d      3.351       1.4     132    62
# Comp:  2            [OI]6300_d      3.243       1.4     132    62
# Comp:  2           [NII]6583_d     0.3205       1.4     132    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9        60
#  comp.  1:       508       607
#  comp.  2:        78         1
# chi2/DOF: 0.8793; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      19.51       2.8     508   607
# Comp:  1                 Hbeta     0.3355       2.8     508   607
# Comp:  1                Halpha      7.702       3.0     508   607
# Comp:  2             [SII]6716     0.3702      0.92      78     1
# Comp:  2             [SII]6731      3.863      0.92      78     1
# Comp:  2              HeII4687      0.000      0.92      78     1
# Comp:  2               HeI5876     0.4585      0.92      78     1
# Comp:  2          [OIII]5007_d      2.629       1.2      78     1
# Comp:  2            [OI]6300_d      2.900       1.2      78     1
# Comp:  2           [NII]6583_d      0.000       1.2      78     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18        56
#  comp.  1:       251       291
#  comp.  2:        89        62
# chi2/DOF: 0.8763; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.77       1.9     251   291
# Comp:  1                 Hbeta      5.130       1.9     251   291
# Comp:  1                Halpha      2.933       1.9     251   291
# Comp:  2             [SII]6716     0.1410       1.1      89    62
# Comp:  2             [SII]6731      3.031       1.1      89    62
# Comp:  2              HeII4687      1.352       1.1      89    62
# Comp:  2               HeI5876      0.000       1.1      89    62
# Comp:  2          [OIII]5007_d      2.902       1.4      89    62
# Comp:  2            [OI]6300_d      3.747       1.4      89    62
# Comp:  2           [NII]6583_d      0.000       1.4      89    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        46
#  comp.  1:       215       526
#  comp.  2:       122        32
# chi2/DOF: 0.8781; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 79; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      26.34       2.6     215   526
# Comp:  1                 Hbeta      9.113       2.6     215   526
# Comp:  1                Halpha      9.323       2.6     215   526
# Comp:  2             [SII]6716     0.2737      0.97     122    32
# Comp:  2             [SII]6731      5.412      0.97     122    32
# Comp:  2              HeII4687     0.1917      0.97     122    32
# Comp:  2               HeI5876    0.06545      0.97     122    32
# Comp:  2          [OIII]5007_d      3.204       1.2     122    32
# Comp:  2            [OI]6300_d      3.315       1.2     122    32
# Comp:  2           [NII]6583_d     0.2777       1.2     122    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3         1
#  comp.  1:       476       782
#  comp.  2:       126        70
# chi2/DOF: 0.8757; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      28.85       3.2     476   782
# Comp:  1                 Hbeta      10.94       3.2     476   782
# Comp:  1                Halpha      7.349       3.5     476   782
# Comp:  2             [SII]6716     0.2040       1.1     126    70
# Comp:  2             [SII]6731      6.800       1.1     126    70
# Comp:  2              HeII4687     0.3021       1.1     126    70
# Comp:  2               HeI5876      0.000       1.1     126    70
# Comp:  2          [OIII]5007_d      3.871       1.4     126    70
# Comp:  2            [OI]6300_d      3.567       1.4     126    70
# Comp:  2           [NII]6583_d      0.000       1.5     126    70
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9         1
#  comp.  1:       168       497
#  comp.  2:       133        18
# chi2/DOF: 0.8806; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      27.88       2.5     168   497
# Comp:  1                 Hbeta      15.04       2.5     168   497
# Comp:  1                Halpha      5.187       2.6     168   497
# Comp:  2             [SII]6716      0.000      0.93     133    18
# Comp:  2             [SII]6731      1.907      0.93     133    18
# Comp:  2              HeII4687      0.000      0.93     133    18
# Comp:  2               HeI5876     0.2080      0.93     133    18
# Comp:  2          [OIII]5007_d      3.097       1.2     133    18
# Comp:  2            [OI]6300_d      2.932       1.2     133    18
# Comp:  2           [NII]6583_d     0.6260       1.2     133    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        26
#  comp.  1:       389       599
#  comp.  2:        96        80
# chi2/DOF: 0.8788; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 57; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      31.44       2.8     389   599
# Comp:  1                 Hbeta      4.550       2.8     389   599
# Comp:  1                Halpha      4.073       3.0     389   599
# Comp:  2             [SII]6716      0.000       1.1      96    80
# Comp:  2             [SII]6731      3.310       1.1      96    80
# Comp:  2              HeII4687      0.000       1.1      96    80
# Comp:  2               HeI5876      0.000       1.1      96    80
# Comp:  2          [OIII]5007_d      4.287       1.5      96    80
# Comp:  2            [OI]6300_d      4.011       1.5      96    80
# Comp:  2           [NII]6583_d      0.000       1.6      96    80
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       141        62
#  comp.  1:       333       223
#  comp.  2:        88       168
# chi2/DOF: 0.8667; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 14; Func calls: 106; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.13       1.7     333   223
# Comp:  1                 Hbeta      8.910       1.7     333   223
# Comp:  1                Halpha      4.225       1.7     333   223
# Comp:  2             [SII]6716     0.8091       1.5      88   168
# Comp:  2             [SII]6731      5.909       1.5      88   168
# Comp:  2              HeII4687     0.5901       1.5      88   168
# Comp:  2               HeI5876      2.115       1.5      88   168
# Comp:  2          [OIII]5007_d      2.406       1.9      88   168
# Comp:  2            [OI]6300_d      3.955       1.9      88   168
# Comp:  2           [NII]6583_d     0.1610       1.9      88   168
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:       494       222
#  comp.  2:        82         1
# chi2/DOF: 0.8721; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.477       1.7     494   222
# Comp:  1                 Hbeta      2.460       1.7     494   222
# Comp:  1                Halpha      4.422       1.7     494   222
# Comp:  2             [SII]6716     0.1918      0.92      82     1
# Comp:  2             [SII]6731      3.965      0.92      82     1
# Comp:  2              HeII4687     0.6310      0.92      82     1
# Comp:  2               HeI5876      0.000      0.92      82     1
# Comp:  2          [OIII]5007_d      2.661       1.2      82     1
# Comp:  2            [OI]6300_d      3.335       1.2      82     1
# Comp:  2           [NII]6583_d     0.3440       1.2      82     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       271       526
#  comp.  2:        86        35
# chi2/DOF: 0.8786; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.92       2.6     271   526
# Comp:  1                 Hbeta      8.672       2.6     271   526
# Comp:  1                Halpha      6.241       2.7     271   526
# Comp:  2             [SII]6716     0.1647      0.97      86    35
# Comp:  2             [SII]6731      0.000      0.97      86    35
# Comp:  2              HeII4687     0.1742      0.97      86    35
# Comp:  2               HeI5876     0.2058      0.97      86    35
# Comp:  2          [OIII]5007_d      3.299       1.2      86    35
# Comp:  2            [OI]6300_d      3.875       1.2      86    35
# Comp:  2           [NII]6583_d     0.4401       1.3      86    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98       150
#  comp.  1:       256       762
#  comp.  2:       132         1
# chi2/DOF: 0.8707; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.006       3.1     256   762
# Comp:  1                 Hbeta      1.873       3.1     256   762
# Comp:  1                Halpha      7.019       3.3     256   762
# Comp:  2             [SII]6716     0.1704      0.92     132     1
# Comp:  2             [SII]6731      4.954      0.92     132     1
# Comp:  2              HeII4687      0.000      0.92     132     1
# Comp:  2               HeI5876     0.2808      0.92     132     1
# Comp:  2          [OIII]5007_d      2.521       1.2     132     1
# Comp:  2            [OI]6300_d      3.237       1.2     132     1
# Comp:  2           [NII]6583_d      0.000       1.2     132     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        75        49
#  comp.  1:       604       643
#  comp.  2:       172       165
# chi2/DOF: 0.8705; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      13.41       2.9     604   643
# Comp:  1                 Hbeta      4.598       2.9     604   643
# Comp:  1                Halpha      9.624       3.5     604   643
# Comp:  2             [SII]6716     0.4732       1.5     172   165
# Comp:  2             [SII]6731      6.935       1.5     172   165
# Comp:  2              HeII4687     0.4611       1.5     172   165
# Comp:  2               HeI5876     0.4131       1.5     172   165
# Comp:  2          [OIII]5007_d      4.726       1.9     172   165
# Comp:  2            [OI]6300_d      2.665       1.9     172   165
# Comp:  2           [NII]6583_d      0.000       2.3     172   165
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        54        69
#  comp.  1:       388       683
#  comp.  2:        85        47
# chi2/DOF: 0.8752; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      32.94       3.0     388   683
# Comp:  1                 Hbeta      14.92       3.0     388   683
# Comp:  1                Halpha      8.249       3.2     388   683
# Comp:  2             [SII]6716      0.000       1.0      85    47
# Comp:  2             [SII]6731      1.213       1.0      85    47
# Comp:  2              HeII4687      1.016       1.0      85    47
# Comp:  2               HeI5876     0.9072       1.0      85    47
# Comp:  2          [OIII]5007_d      3.605       1.3      85    47
# Comp:  2            [OI]6300_d      3.998       1.3      85    47
# Comp:  2           [NII]6583_d      0.000       1.4      85    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3         1
#  comp.  1:       379       460
#  comp.  2:        40         1
# chi2/DOF: 0.8765; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.51       2.4     379   460
# Comp:  1                 Hbeta      3.453       2.4     379   460
# Comp:  1                Halpha      10.07       2.5     379   460
# Comp:  2             [SII]6716     0.4217      0.92      40     1
# Comp:  2             [SII]6731      2.764      0.92      40     1
# Comp:  2              HeII4687     0.6471      0.92      40     1
# Comp:  2               HeI5876     0.2298      0.92      40     1
# Comp:  2          [OIII]5007_d      2.169       1.2      40     1
# Comp:  2            [OI]6300_d      2.600       1.2      40     1
# Comp:  2           [NII]6583_d     0.2701       1.2      40     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        15         1
#  comp.  1:       326       586
#  comp.  2:        95        43
# chi2/DOF: 0.8777; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      25.88       2.7     326   586
# Comp:  1                 Hbeta      2.359       2.7     326   586
# Comp:  1                Halpha      3.480       2.9     326   586
# Comp:  2             [SII]6716      0.000       1.0      95    43
# Comp:  2             [SII]6731      1.069       1.0      95    43
# Comp:  2              HeII4687      0.000       1.0      95    43
# Comp:  2               HeI5876     0.6746       1.0      95    43
# Comp:  2          [OIII]5007_d      3.173       1.3      95    43
# Comp:  2            [OI]6300_d      3.469       1.3      95    43
# Comp:  2           [NII]6583_d     0.2879       1.3      95    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        25
#  comp.  1:       270       777
#  comp.  2:        78         1
# chi2/DOF: 0.8780; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      35.75       3.1     270   777
# Comp:  1                 Hbeta      4.347       3.1     270   777
# Comp:  1                Halpha      9.987       3.3     270   777
# Comp:  2             [SII]6716     0.2053      0.92      78     1
# Comp:  2             [SII]6731      3.697      0.92      78     1
# Comp:  2              HeII4687      0.000      0.92      78     1
# Comp:  2               HeI5876     0.4498      0.92      78     1
# Comp:  2          [OIII]5007_d      2.841       1.2      78     1
# Comp:  2            [OI]6300_d      2.386       1.2      78     1
# Comp:  2           [NII]6583_d    0.08569       1.2      78     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:       451       410
#  comp.  2:        97        49
# chi2/DOF: 0.8770; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.03       2.3     451   410
# Comp:  1                 Hbeta      7.367       2.3     451   410
# Comp:  1                Halpha      2.866       2.4     451   410
# Comp:  2             [SII]6716     0.1030       1.0      97    49
# Comp:  2             [SII]6731      1.481       1.0      97    49
# Comp:  2              HeII4687      0.000       1.0      97    49
# Comp:  2               HeI5876     0.2841       1.0      97    49
# Comp:  2          [OIII]5007_d      2.474       1.3      97    49
# Comp:  2            [OI]6300_d      3.288       1.3      97    49
# Comp:  2           [NII]6583_d     0.5105       1.3      97    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3         1
#  comp.  1:       286       583
#  comp.  2:        74         1
# chi2/DOF: 0.8768; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      31.79       2.7     286   583
# Comp:  1                 Hbeta      15.28       2.7     286   583
# Comp:  1                Halpha      7.601       2.8     286   583
# Comp:  2             [SII]6716     0.1006      0.92      74     1
# Comp:  2             [SII]6731      3.780      0.92      74     1
# Comp:  2              HeII4687      0.000      0.92      74     1
# Comp:  2               HeI5876     0.2143      0.92      74     1
# Comp:  2          [OIII]5007_d      2.814       1.2      74     1
# Comp:  2            [OI]6300_d      3.343       1.2      74     1
# Comp:  2           [NII]6583_d      0.000       1.2      74     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16        59
#  comp.  1:       323       588
#  comp.  2:        97         7
# chi2/DOF: 0.8802; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      26.62       2.7     323   588
# Comp:  1                 Hbeta      5.762       2.7     323   588
# Comp:  1                Halpha      5.961       2.8     323   588
# Comp:  2             [SII]6716      0.000      0.92      97     7
# Comp:  2             [SII]6731      3.902      0.92      97     7
# Comp:  2              HeII4687      0.000      0.92      97     7
# Comp:  2               HeI5876    0.01791      0.92      97     7
# Comp:  2          [OIII]5007_d      2.601       1.2      97     7
# Comp:  2            [OI]6300_d      3.504       1.2      97     7
# Comp:  2           [NII]6583_d      0.000       1.2      97     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26       225
#  comp.  1:       267       622
#  comp.  2:        89         1
# chi2/DOF: 0.8802; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      26.69       2.8     267   622
# Comp:  1                 Hbeta      16.19       2.8     267   622
# Comp:  1                Halpha      8.680       2.9     267   622
# Comp:  2             [SII]6716     0.2130      0.92      89     1
# Comp:  2             [SII]6731     0.9838      0.92      89     1
# Comp:  2              HeII4687     0.7701      0.92      89     1
# Comp:  2               HeI5876      0.000      0.92      89     1
# Comp:  2          [OIII]5007_d      3.361       1.2      89     1
# Comp:  2            [OI]6300_d      2.833       1.2      89     1
# Comp:  2           [NII]6583_d     0.2561       1.2      89     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        48
#  comp.  1:        72       538
#  comp.  2:        72         1
# chi2/DOF: 0.8711; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.80       2.6      72   538
# Comp:  1                 Hbeta      11.20       2.6      72   538
# Comp:  1                Halpha      6.721       2.7      72   538
# Comp:  2             [SII]6716    0.06849      0.92      72     1
# Comp:  2             [SII]6731      3.614      0.92      72     1
# Comp:  2              HeII4687      0.000      0.92      72     1
# Comp:  2               HeI5876    0.03936      0.92      72     1
# Comp:  2          [OIII]5007_d      2.604       1.2      72     1
# Comp:  2            [OI]6300_d      2.794       1.2      72     1
# Comp:  2           [NII]6583_d      0.000       1.2      72     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28         1
#  comp.  1:       464       453
#  comp.  2:       125        66
# chi2/DOF: 0.8727; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.599       2.4     464   453
# Comp:  1                 Hbeta      8.370       2.4     464   453
# Comp:  1                Halpha      1.597       2.5     464   453
# Comp:  2             [SII]6716   0.004877       1.1     125    66
# Comp:  2             [SII]6731      6.570       1.1     125    66
# Comp:  2              HeII4687      1.614       1.1     125    66
# Comp:  2               HeI5876     0.3237       1.1     125    66
# Comp:  2          [OIII]5007_d      2.942       1.4     125    66
# Comp:  2            [OI]6300_d      3.055       1.4     125    66
# Comp:  2           [NII]6583_d      0.000       1.4     125    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        41
#  comp.  1:       297       581
#  comp.  2:       110        84
# chi2/DOF: 0.8803; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      25.63       2.7     297   581
# Comp:  1                 Hbeta      8.243       2.7     297   581
# Comp:  1                Halpha      6.276       2.9     297   581
# Comp:  2             [SII]6716      0.000       1.2     110    84
# Comp:  2             [SII]6731      3.841       1.2     110    84
# Comp:  2              HeII4687     0.7978       1.2     110    84
# Comp:  2               HeI5876     0.1159       1.2     110    84
# Comp:  2          [OIII]5007_d      3.546       1.5     110    84
# Comp:  2            [OI]6300_d      4.796       1.5     110    84
# Comp:  2           [NII]6583_d      0.000       1.6     110    84
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        94         1
#  comp.  1:       251       379
#  comp.  2:       146         1
# chi2/DOF: 0.8726; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.28       2.2     251   379
# Comp:  1                 Hbeta      7.871       2.2     251   379
# Comp:  1                Halpha      2.384       2.2     251   379
# Comp:  2             [SII]6716    0.04301      0.92     146     1
# Comp:  2             [SII]6731      4.999      0.92     146     1
# Comp:  2              HeII4687     0.2745      0.92     146     1
# Comp:  2               HeI5876      0.000      0.92     146     1
# Comp:  2          [OIII]5007_d      2.340       1.2     146     1
# Comp:  2            [OI]6300_d      2.037       1.2     146     1
# Comp:  2           [NII]6583_d      0.000       1.2     146     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16         1
#  comp.  1:       314       585
#  comp.  2:        96        48
# chi2/DOF: 0.8823; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.25       2.7     314   585
# Comp:  1                 Hbeta      6.377       2.7     314   585
# Comp:  1                Halpha      7.150       2.9     314   585
# Comp:  2             [SII]6716     0.5537       1.0      96    48
# Comp:  2             [SII]6731      3.226       1.0      96    48
# Comp:  2              HeII4687      0.000       1.0      96    48
# Comp:  2               HeI5876     0.1369       1.0      96    48
# Comp:  2          [OIII]5007_d      2.659       1.3      96    48
# Comp:  2            [OI]6300_d      4.091       1.3      96    48
# Comp:  2           [NII]6583_d     0.2415       1.3      96    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37       184
#  comp.  1:       332       535
#  comp.  2:        79        45
# chi2/DOF: 0.8721; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      41.41       2.6     332   535
# Comp:  1                 Hbeta      16.13       2.6     332   535
# Comp:  1                Halpha      7.089       2.7     332   535
# Comp:  2             [SII]6716   0.004739       1.0      79    45
# Comp:  2             [SII]6731      0.000       1.0      79    45
# Comp:  2              HeII4687      0.000       1.0      79    45
# Comp:  2               HeI5876    0.03022       1.0      79    45
# Comp:  2          [OIII]5007_d      2.814       1.3      79    45
# Comp:  2            [OI]6300_d      3.646       1.3      79    45
# Comp:  2           [NII]6583_d      0.000       1.3      79    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20         1
#  comp.  1:       228       529
#  comp.  2:        45         1
# chi2/DOF: 0.8774; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      25.25       2.6     228   529
# Comp:  1                 Hbeta      12.76       2.6     228   529
# Comp:  1                Halpha      5.584       2.7     228   529
# Comp:  2             [SII]6716      0.000      0.92      45     1
# Comp:  2             [SII]6731      2.429      0.92      45     1
# Comp:  2              HeII4687      0.000      0.92      45     1
# Comp:  2               HeI5876      0.000      0.92      45     1
# Comp:  2          [OIII]5007_d      2.645       1.2      45     1
# Comp:  2            [OI]6300_d      1.822       1.2      45     1
# Comp:  2           [NII]6583_d     0.4317       1.2      45     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        25         1
#  comp.  1:       177       858
#  comp.  2:       105        49
# chi2/DOF: 0.8743; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        19         1
#  comp.  1:       514       503
#  comp.  2:        94        37
# chi2/DOF: 0.8814; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.57       2.5     514   503
# Comp:  1                 Hbeta      7.869       2.5     514   503
# Comp:  1                Halpha     0.7694       2.7     514   503
# Comp:  2             [SII]6716      0.000      0.98      94    37
# Comp:  2             [SII]6731      2.538      0.98      94    37
# Comp:  2              HeII4687     0.8241      0.98      94    37
# Comp:  2               HeI5876     0.6345      0.98      94    37
# Comp:  2          [OIII]5007_d      2.463       1.2      94    37
# Comp:  2            [OI]6300_d      3.149       1.2      94    37
# Comp:  2           [NII]6583_d     0.6316       1.3      94    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         5         1
#  comp.  1:        91       413
#  comp.  2:       118        58
# chi2/DOF: 0.8696; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.65       2.3      91   413
# Comp:  1                 Hbeta      13.95       2.3      91   413
# Comp:  1                Halpha      7.433       2.3      91   413
# Comp:  2             [SII]6716    0.04378       1.1     118    58
# Comp:  2             [SII]6731      2.082       1.1     118    58
# Comp:  2              HeII4687      0.000       1.1     118    58
# Comp:  2               HeI5876     0.6239       1.1     118    58
# Comp:  2          [OIII]5007_d      2.950       1.3     118    58
# Comp:  2            [OI]6300_d      4.556       1.3     118    58
# Comp:  2           [NII]6583_d      0.000       1.3     118    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29         1
#  comp.  1:       311       584
#  comp.  2:       144         1
# chi2/DOF: 0.8754; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      28.30       2.7     311   584
# Comp:  1                 Hbeta      10.34       2.7     311   584
# Comp:  1                Halpha      5.491       2.8     311   584
# Comp:  2             [SII]6716     0.2656      0.92     144     1
# Comp:  2             [SII]6731      5.138      0.92     144     1
# Comp:  2              HeII4687      0.000      0.92     144     1
# Comp:  2               HeI5876      0.000      0.92     144     1
# Comp:  2          [OIII]5007_d      2.583       1.2     144     1
# Comp:  2            [OI]6300_d      2.476       1.2     144     1
# Comp:  2           [NII]6583_d     0.1242       1.2     144     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42         1
#  comp.  1:       345       510
#  comp.  2:        66        26
# chi2/DOF: 0.8828; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      22.02       2.6     345   510
# Comp:  1                 Hbeta      12.37       2.6     345   510
# Comp:  1                Halpha      3.903       2.6     345   510
# Comp:  2             [SII]6716      0.000      0.95      66    26
# Comp:  2             [SII]6731      3.984      0.95      66    26
# Comp:  2              HeII4687      0.000      0.95      66    26
# Comp:  2               HeI5876     0.4566      0.95      66    26
# Comp:  2          [OIII]5007_d      2.315       1.2      66    26
# Comp:  2            [OI]6300_d      3.195       1.2      66    26
# Comp:  2           [NII]6583_d      0.000       1.2      66    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4         1
#  comp.  1:       336       756
#  comp.  2:        75         1
# chi2/DOF: 0.8756; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 38; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      37.42       3.1     336   756
# Comp:  1                 Hbeta      12.97       3.1     336   756
# Comp:  1                Halpha      6.816       3.3     336   756
# Comp:  2             [SII]6716      0.000      0.92      75     1
# Comp:  2             [SII]6731      3.538      0.92      75     1
# Comp:  2              HeII4687      0.000      0.92      75     1
# Comp:  2               HeI5876     0.2694      0.92      75     1
# Comp:  2          [OIII]5007_d      2.658       1.2      75     1
# Comp:  2            [OI]6300_d      3.613       1.2      75     1
# Comp:  2           [NII]6583_d     0.2178       1.2      75     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:       543       726
#  comp.  2:       115         1
# chi2/DOF: 0.8753; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.49       3.0     543   726
# Comp:  1                 Hbeta      6.100       3.0     543   726
# Comp:  1                Halpha      6.676       3.3     543   726
# Comp:  2             [SII]6716      0.000      0.92     115     1
# Comp:  2             [SII]6731      0.000      0.92     115     1
# Comp:  2              HeII4687     0.1707      0.92     115     1
# Comp:  2               HeI5876     0.1679      0.92     115     1
# Comp:  2          [OIII]5007_d      3.057       1.2     115     1
# Comp:  2            [OI]6300_d      3.367       1.2     115     1
# Comp:  2           [NII]6583_d      0.000       1.2     115     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18        36
#  comp.  1:       316       582
#  comp.  2:        96         1
# chi2/DOF: 0.8795; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      26.21       2.7     316   582
# Comp:  1                 Hbeta      4.314       2.7     316   582
# Comp:  1                Halpha      2.629       2.8     316   582
# Comp:  2             [SII]6716      0.000      0.92      96     1
# Comp:  2             [SII]6731      3.305      0.92      96     1
# Comp:  2              HeII4687      0.000      0.92      96     1
# Comp:  2               HeI5876      0.000      0.92      96     1
# Comp:  2          [OIII]5007_d      2.897       1.2      96     1
# Comp:  2            [OI]6300_d      3.611       1.2      96     1
# Comp:  2           [NII]6583_d      0.000       1.2      96     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        65       194
#  comp.  1:       481       470
#  comp.  2:       131         1
# chi2/DOF: 0.8769; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.25       2.5     481   470
# Comp:  1                 Hbeta      5.512       2.5     481   470
# Comp:  1                Halpha      4.899       2.5     481   470
# Comp:  2             [SII]6716     0.2594      0.92     131     1
# Comp:  2             [SII]6731      4.860      0.92     131     1
# Comp:  2              HeII4687      0.000      0.92     131     1
# Comp:  2               HeI5876     0.3425      0.92     131     1
# Comp:  2          [OIII]5007_d      2.565       1.2     131     1
# Comp:  2            [OI]6300_d      2.728       1.2     131     1
# Comp:  2           [NII]6583_d      0.000       1.2     131     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26       158
#  comp.  1:        96       499
#  comp.  2:       143         1
# chi2/DOF: 0.8736; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 31; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      47.28       2.5      96   499
# Comp:  1                 Hbeta      24.59       2.5      96   499
# Comp:  1                Halpha      8.419       2.6      96   499
# Comp:  2             [SII]6716     0.1925      0.92     143     1
# Comp:  2             [SII]6731      4.923      0.92     143     1
# Comp:  2              HeII4687      0.000      0.92     143     1
# Comp:  2               HeI5876     0.3366      0.92     143     1
# Comp:  2          [OIII]5007_d      3.214       1.2     143     1
# Comp:  2            [OI]6300_d      2.517       1.2     143     1
# Comp:  2           [NII]6583_d      0.000       1.2     143     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29         1
#  comp.  1:       204       526
#  comp.  2:        56         1
# chi2/DOF: 0.8810; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      20.35       2.6     204   526
# Comp:  1                 Hbeta      13.96       2.6     204   526
# Comp:  1                Halpha      3.651       2.7     204   526
# Comp:  2             [SII]6716    0.05885      0.92      56     1
# Comp:  2             [SII]6731      2.051      0.92      56     1
# Comp:  2              HeII4687     0.3212      0.92      56     1
# Comp:  2               HeI5876      0.000      0.92      56     1
# Comp:  2          [OIII]5007_d      2.696       1.2      56     1
# Comp:  2            [OI]6300_d      2.326       1.2      56     1
# Comp:  2           [NII]6583_d      0.000       1.2      56     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17        43
#  comp.  1:       311       582
#  comp.  2:        97        18
# chi2/DOF: 0.8828; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.89       2.7     311   582
# Comp:  1                 Hbeta      12.56       2.7     311   582
# Comp:  1                Halpha      5.502       2.8     311   582
# Comp:  2             [SII]6716      0.000      0.93      97    18
# Comp:  2             [SII]6731      1.161      0.93      97    18
# Comp:  2              HeII4687     0.3443      0.93      97    18
# Comp:  2               HeI5876    0.01821      0.93      97    18
# Comp:  2          [OIII]5007_d      2.817       1.2      97    18
# Comp:  2            [OI]6300_d      2.790       1.2      97    18
# Comp:  2           [NII]6583_d      0.000       1.2      97    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:      -125       775
#  comp.  2:       145         1
# chi2/DOF: 0.8700; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 76; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      39.31       3.1    -125   775
# Comp:  1                 Hbeta      17.35       3.1    -125   775
# Comp:  1                Halpha      9.491       3.2    -125   775
# Comp:  2             [SII]6716    0.03373      0.92     145     1
# Comp:  2             [SII]6731      5.134      0.92     145     1
# Comp:  2              HeII4687      0.000      0.92     145     1
# Comp:  2               HeI5876     0.5193      0.92     145     1
# Comp:  2          [OIII]5007_d      2.289       1.2     145     1
# Comp:  2            [OI]6300_d      2.392       1.2     145     1
# Comp:  2           [NII]6583_d      0.000       1.2     145     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        55         1
#  comp.  1:       189       533
#  comp.  2:       111         1
# chi2/DOF: 0.8775; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      26.42       2.6     189   533
# Comp:  1                 Hbeta      18.36       2.6     189   533
# Comp:  1                Halpha      11.35       2.7     189   533
# Comp:  2             [SII]6716     0.2020      0.92     111     1
# Comp:  2             [SII]6731      0.000      0.92     111     1
# Comp:  2              HeII4687      0.000      0.92     111     1
# Comp:  2               HeI5876    0.03341      0.92     111     1
# Comp:  2          [OIII]5007_d      3.359       1.2     111     1
# Comp:  2            [OI]6300_d      3.193       1.2     111     1
# Comp:  2           [NII]6583_d     0.3924       1.2     111     1
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([9.19821275, 6.23113854, 3.8350052 , 0.25486227, 2.78076279,
#        0.40499978, 0.33541013, 0.54960451, 0.91190407, 0.44963182])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([20.14367217,  9.17963132,  6.99705843,  0.06335503,  3.32457403,
#         0.        ,  0.08534837,  2.89008062,  3.81294895,  0.        ])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_1_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_1", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_1_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_1_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_1_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0        Hgamma  0.219620    0.100285
# 1         Hbeta  0.100083    0.067936
# 2        Halpha  0.076287    0.041812
# 3     [SII]6716  0.000691    0.002779
# 4     [SII]6731  0.036247    0.030318
# 5      HeII4687  0.000000    0.004416
# 6       HeI5876  0.000931    0.003657
# 7  [OIII]5007_d  0.031510    0.005992
# 8    [OI]6300_d  0.041571    0.009942
# 9   [NII]6583_d  0.000000    0.004902
#           Name      Flux  Error_flux
# 0       Hgamma  0.219620    0.100285
# 1        Hbeta  0.100083    0.067936
# 2       Halpha  0.076287    0.041812
# 3    [SII]6716  0.000691    0.002779
# 4    [SII]6731  0.036247    0.030318
# 5     HeII4687  0.000000    0.004416
# 6      HeI5876  0.000931    0.003657
# 7   [OIII]4959  0.007877    0.005992
# 8   [OIII]5007  0.023632    0.005992
# 9     [OI]6300  0.031179    0.009942
# 10    [OI]6364  0.010393    0.009942
# 11   [NII]6548  0.000000    0.004902
# 12   [NII]6583  0.000000    0.004902

# %%
np.median(flux_rf_rebin)
# Out:
# 0.010902681246655242
