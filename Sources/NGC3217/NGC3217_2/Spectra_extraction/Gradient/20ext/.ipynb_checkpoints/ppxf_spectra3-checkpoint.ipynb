# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4314.03901503 4315.47324864 4316.90748224 ... 6874.1460011  6875.58023471
#  6877.01446832] [0.01164807 0.01533273 0.01133399 ... 0.02168856 0.02117491 0.02603242] [0.00722337 0.00722337 0.00722337 ... 0.00722337 0.00722337 0.00722337]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        89
# chi2/DOF: 0.08613; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        73
# chi2/DOF: 0.04208; DOF: 1869; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-48.55871403,  73.42275291])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         2        50
#  comp.  1:       -28        47
#  comp.  2:       -17        79
# chi2/DOF: 0.8075; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.68     -28    47
# Comp:  1                 Hbeta      1.270      0.68     -28    47
# Comp:  1                Halpha      4.686      0.68     -28    47
# Comp:  2             [SII]6716      1.603      0.76     -17    79
# Comp:  2             [SII]6731      1.318      0.76     -17    79
# Comp:  2              HeII4687      0.000      0.76     -17    79
# Comp:  2               HeI5876      0.000      0.76     -17    79
# Comp:  2          [OIII]5007_d      2.093      0.96     -17    79
# Comp:  2            [OI]6300_d     0.3229      0.96     -17    79
# Comp:  2           [NII]6583_d      2.963      0.96     -17    79
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  1.717; gas flux:      1 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:   6.59; gas flux:      6 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  1.766; gas flux:      2 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:   1.47; gas flux:      2 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   1.79; gas flux:      2 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.2735; gas flux:      0 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  2.438; gas flux:      4 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -5         1
#  comp.  1:       -31        48
#  comp.  2:       -26        89
# chi2/DOF: 0.8033; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.68     -31    48
# Comp:  1                 Hbeta      1.704      0.68     -31    48
# Comp:  1                Halpha      4.569      0.68     -31    48
# Comp:  2             [SII]6716      1.336      0.79     -26    89
# Comp:  2             [SII]6731      1.592      0.79     -26    89
# Comp:  2              HeII4687      0.000      0.79     -26    89
# Comp:  2               HeI5876      0.000      0.79     -26    89
# Comp:  2          [OIII]5007_d      2.388       1.0     -26    89
# Comp:  2            [OI]6300_d     0.4109       1.0     -26    89
# Comp:  2           [NII]6583_d      2.952       1.0     -26    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        25       105
#  comp.  1:       -26        46
#  comp.  2:       -36        54
# chi2/DOF: 0.8028; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.67     -26    46
# Comp:  1                 Hbeta     0.8380      0.67     -26    46
# Comp:  1                Halpha      4.528      0.67     -26    46
# Comp:  2             [SII]6716      1.347      0.69     -36    54
# Comp:  2             [SII]6731      1.811      0.69     -36    54
# Comp:  2              HeII4687      0.000      0.69     -36    54
# Comp:  2               HeI5876     0.8375      0.69     -36    54
# Comp:  2          [OIII]5007_d      1.322      0.88     -36    54
# Comp:  2            [OI]6300_d    0.02945      0.88     -36    54
# Comp:  2           [NII]6583_d      2.438      0.88     -36    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48        73
#  comp.  1:       -21        63
#  comp.  2:       -15       121
# chi2/DOF: 0.8011; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.72     -21    63
# Comp:  1                 Hbeta      1.683      0.72     -21    63
# Comp:  1                Halpha      4.834      0.72     -21    63
# Comp:  2             [SII]6716      1.767      0.88     -15   121
# Comp:  2             [SII]6731      1.246      0.88     -15   121
# Comp:  2              HeII4687      0.000      0.88     -15   121
# Comp:  2               HeI5876     0.2058      0.88     -15   121
# Comp:  2          [OIII]5007_d      1.516       1.1     -15   121
# Comp:  2            [OI]6300_d      1.986       1.1     -15   121
# Comp:  2           [NII]6583_d      3.037       1.1     -15   121
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23         1
#  comp.  1:       -29        40
#  comp.  2:       -33        81
# chi2/DOF: 0.8011; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.66     -29    40
# Comp:  1                 Hbeta      1.192      0.66     -29    40
# Comp:  1                Halpha      4.372      0.66     -29    40
# Comp:  2             [SII]6716      1.545      0.77     -33    81
# Comp:  2             [SII]6731     0.9128      0.77     -33    81
# Comp:  2              HeII4687      0.000      0.77     -33    81
# Comp:  2               HeI5876      0.000      0.77     -33    81
# Comp:  2          [OIII]5007_d      2.719      0.97     -33    81
# Comp:  2            [OI]6300_d      1.638      0.97     -33    81
# Comp:  2           [NII]6583_d      2.738      0.97     -33    81
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9        19
#  comp.  1:       -26        46
#  comp.  2:       -14        75
# chi2/DOF: 0.8002; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.67     -26    46
# Comp:  1                 Hbeta      1.796      0.67     -26    46
# Comp:  1                Halpha      5.050      0.67     -26    46
# Comp:  2             [SII]6716      1.683      0.75     -14    75
# Comp:  2             [SII]6731      1.827      0.75     -14    75
# Comp:  2              HeII4687     0.2209      0.75     -14    75
# Comp:  2               HeI5876     0.4030      0.75     -14    75
# Comp:  2          [OIII]5007_d      2.286      0.95     -14    75
# Comp:  2            [OI]6300_d      0.000      0.95     -14    75
# Comp:  2           [NII]6583_d      2.881      0.95     -14    75
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2         1
#  comp.  1:       -26        57
#  comp.  2:       -60       139
# chi2/DOF: 0.7997; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.127      0.70     -26    57
# Comp:  1                 Hbeta      2.721      0.70     -26    57
# Comp:  1                Halpha      5.196      0.70     -26    57
# Comp:  2             [SII]6716      2.008      0.93     -60   139
# Comp:  2             [SII]6731      3.297      0.93     -60   139
# Comp:  2              HeII4687     0.2849      0.93     -60   139
# Comp:  2               HeI5876     0.6297      0.93     -60   139
# Comp:  2          [OIII]5007_d      1.744       1.2     -60   139
# Comp:  2            [OI]6300_d      2.030       1.2     -60   139
# Comp:  2           [NII]6583_d      2.879       1.2     -60   139
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        13         1
#  comp.  1:       -28        40
#  comp.  2:        15        68
# chi2/DOF: 0.8003; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.66     -28    40
# Comp:  1                 Hbeta      1.295      0.66     -28    40
# Comp:  1                Halpha      4.463      0.66     -28    40
# Comp:  2             [SII]6716      1.216      0.73      15    68
# Comp:  2             [SII]6731      1.692      0.73      15    68
# Comp:  2              HeII4687     0.3930      0.73      15    68
# Comp:  2               HeI5876     0.5339      0.73      15    68
# Comp:  2          [OIII]5007_d      1.229      0.92      15    68
# Comp:  2            [OI]6300_d     0.9659      0.92      15    68
# Comp:  2           [NII]6583_d      2.586      0.92      15    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29       100
#  comp.  1:       -29        43
#  comp.  2:       -30        84
# chi2/DOF: 0.8001; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.67     -29    43
# Comp:  1                 Hbeta      1.442      0.67     -29    43
# Comp:  1                Halpha      4.776      0.67     -29    43
# Comp:  2             [SII]6716      1.670      0.78     -30    84
# Comp:  2             [SII]6731      2.442      0.78     -30    84
# Comp:  2              HeII4687      0.000      0.78     -30    84
# Comp:  2               HeI5876      1.107      0.78     -30    84
# Comp:  2          [OIII]5007_d      1.859      0.98     -30    84
# Comp:  2            [OI]6300_d     0.2081      0.98     -30    84
# Comp:  2           [NII]6583_d      3.156      0.98     -30    84
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8         1
#  comp.  1:       -28        39
#  comp.  2:       -42       116
# chi2/DOF: 0.8025; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.66     -28    39
# Comp:  1                 Hbeta      1.492      0.66     -28    39
# Comp:  1                Halpha      4.528      0.66     -28    39
# Comp:  2             [SII]6716      2.097      0.87     -42   116
# Comp:  2             [SII]6731      1.660      0.87     -42   116
# Comp:  2              HeII4687     0.1368      0.87     -42   116
# Comp:  2               HeI5876      1.215      0.87     -42   116
# Comp:  2          [OIII]5007_d      2.556       1.1     -42   116
# Comp:  2            [OI]6300_d      1.428       1.1     -42   116
# Comp:  2           [NII]6583_d      3.599       1.1     -42   116
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        17         1
#  comp.  1:       -28        40
#  comp.  2:       -36        79
# chi2/DOF: 0.8027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.66     -28    40
# Comp:  1                 Hbeta     0.7603      0.66     -28    40
# Comp:  1                Halpha      4.276      0.66     -28    40
# Comp:  2             [SII]6716      1.509      0.76     -36    79
# Comp:  2             [SII]6731      1.362      0.76     -36    79
# Comp:  2              HeII4687    0.03127      0.76     -36    79
# Comp:  2               HeI5876      0.000      0.76     -36    79
# Comp:  2          [OIII]5007_d      1.900      0.96     -36    79
# Comp:  2            [OI]6300_d      1.363      0.96     -36    79
# Comp:  2           [NII]6583_d      2.688      0.96     -36    79
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        96
#  comp.  1:       -38        58
#  comp.  2:       -20        98
# chi2/DOF: 0.8018; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8931      0.70     -38    58
# Comp:  1                 Hbeta      1.369      0.70     -38    58
# Comp:  1                Halpha      5.129      0.70     -38    58
# Comp:  2             [SII]6716      1.773      0.82     -20    98
# Comp:  2             [SII]6731      1.603      0.82     -20    98
# Comp:  2              HeII4687     0.3820      0.82     -20    98
# Comp:  2               HeI5876     0.7235      0.82     -20    98
# Comp:  2          [OIII]5007_d      3.347       1.0     -20    98
# Comp:  2            [OI]6300_d      1.173       1.0     -20    98
# Comp:  2           [NII]6583_d      2.740       1.0     -20    98
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        29
#  comp.  1:       -24        40
#  comp.  2:       -10        87
# chi2/DOF: 0.7997; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma    0.03575      0.66     -24    40
# Comp:  1                 Hbeta      1.385      0.66     -24    40
# Comp:  1                Halpha      4.949      0.66     -24    40
# Comp:  2             [SII]6716      1.919      0.78     -10    87
# Comp:  2             [SII]6731      1.511      0.78     -10    87
# Comp:  2              HeII4687     0.1787      0.78     -10    87
# Comp:  2               HeI5876      0.000      0.78     -10    87
# Comp:  2          [OIII]5007_d      2.047      0.99     -10    87
# Comp:  2            [OI]6300_d      0.000      0.99     -10    87
# Comp:  2           [NII]6583_d      3.857      0.99     -10    87
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        56
#  comp.  1:       -31        49
#  comp.  2:       -36        94
# chi2/DOF: 0.8044; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1132      0.68     -31    49
# Comp:  1                 Hbeta      1.670      0.68     -31    49
# Comp:  1                Halpha      5.057      0.68     -31    49
# Comp:  2             [SII]6716      1.868      0.81     -36    94
# Comp:  2             [SII]6731      1.050      0.81     -36    94
# Comp:  2              HeII4687      0.000      0.81     -36    94
# Comp:  2               HeI5876     0.7161      0.81     -36    94
# Comp:  2          [OIII]5007_d      2.476       1.0     -36    94
# Comp:  2            [OI]6300_d    0.06003       1.0     -36    94
# Comp:  2           [NII]6583_d      3.486       1.0     -36    94
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        93
#  comp.  1:       -28        46
#  comp.  2:        -7        55
# chi2/DOF: 0.8030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3733      0.67     -28    46
# Comp:  1                 Hbeta      1.494      0.67     -28    46
# Comp:  1                Halpha      4.742      0.67     -28    46
# Comp:  2             [SII]6716      1.328      0.70      -7    55
# Comp:  2             [SII]6731      1.582      0.70      -7    55
# Comp:  2              HeII4687      0.000      0.70      -7    55
# Comp:  2               HeI5876     0.2481      0.70      -7    55
# Comp:  2          [OIII]5007_d      1.739      0.88      -7    55
# Comp:  2            [OI]6300_d     0.3658      0.88      -7    55
# Comp:  2           [NII]6583_d      2.959      0.88      -7    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26        59
#  comp.  1:       -23        66
#  comp.  2:         1        72
# chi2/DOF: 0.8010; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 31; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.285      0.73     -23    66
# Comp:  1                 Hbeta      2.525      0.73     -23    66
# Comp:  1                Halpha      5.459      0.73     -23    66
# Comp:  2             [SII]6716      1.588      0.74       1    72
# Comp:  2             [SII]6731      1.796      0.74       1    72
# Comp:  2              HeII4687     0.2122      0.74       1    72
# Comp:  2               HeI5876      0.000      0.74       1    72
# Comp:  2          [OIII]5007_d      2.149      0.94       1    72
# Comp:  2            [OI]6300_d      0.000      0.94       1    72
# Comp:  2           [NII]6583_d      3.242      0.94       1    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4       104
#  comp.  1:       -31        44
#  comp.  2:       -18        85
# chi2/DOF: 0.8003; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.67     -31    44
# Comp:  1                 Hbeta      1.297      0.67     -31    44
# Comp:  1                Halpha      4.693      0.67     -31    44
# Comp:  2             [SII]6716      1.949      0.78     -18    85
# Comp:  2             [SII]6731      1.863      0.78     -18    85
# Comp:  2              HeII4687     0.1374      0.78     -18    85
# Comp:  2               HeI5876    0.03560      0.78     -18    85
# Comp:  2          [OIII]5007_d      1.833      0.99     -18    85
# Comp:  2            [OI]6300_d     0.1790      0.99     -18    85
# Comp:  2           [NII]6583_d      3.332      0.99     -18    85
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8        42
#  comp.  1:       -30        58
#  comp.  2:       -24        74
# chi2/DOF: 0.8015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9025      0.70     -30    58
# Comp:  1                 Hbeta      2.251      0.70     -30    58
# Comp:  1                Halpha      5.192      0.70     -30    58
# Comp:  2             [SII]6716      1.704      0.75     -24    74
# Comp:  2             [SII]6731      1.839      0.75     -24    74
# Comp:  2              HeII4687      0.000      0.75     -24    74
# Comp:  2               HeI5876      0.000      0.75     -24    74
# Comp:  2          [OIII]5007_d      1.938      0.94     -24    74
# Comp:  2            [OI]6300_d      1.574      0.94     -24    74
# Comp:  2           [NII]6583_d      2.823      0.94     -24    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:       -36        41
#  comp.  2:       -39       122
# chi2/DOF: 0.8024; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma    0.05413      0.66     -36    41
# Comp:  1                 Hbeta      1.644      0.66     -36    41
# Comp:  1                Halpha      4.525      0.66     -36    41
# Comp:  2             [SII]6716      2.159      0.89     -39   122
# Comp:  2             [SII]6731      1.828      0.89     -39   122
# Comp:  2              HeII4687      0.000      0.89     -39   122
# Comp:  2               HeI5876     0.3631      0.89     -39   122
# Comp:  2          [OIII]5007_d      2.929       1.1     -39   122
# Comp:  2            [OI]6300_d      0.000       1.1     -39   122
# Comp:  2           [NII]6583_d      3.361       1.1     -39   122
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18         1
#  comp.  1:       -26        44
#  comp.  2:        -1       104
# chi2/DOF: 0.8019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.67     -26    44
# Comp:  1                 Hbeta      1.259      0.67     -26    44
# Comp:  1                Halpha      4.612      0.67     -26    44
# Comp:  2             [SII]6716      1.561      0.83      -1   104
# Comp:  2             [SII]6731      1.877      0.83      -1   104
# Comp:  2              HeII4687      0.000      0.83      -1   104
# Comp:  2               HeI5876     0.4908      0.83      -1   104
# Comp:  2          [OIII]5007_d      1.853       1.1      -1   104
# Comp:  2            [OI]6300_d      1.833       1.1      -1   104
# Comp:  2           [NII]6583_d      3.260       1.1      -1   104
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3         1
#  comp.  1:       -25        51
#  comp.  2:       -21       122
# chi2/DOF: 0.7994; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3885      0.69     -25    51
# Comp:  1                 Hbeta      1.827      0.69     -25    51
# Comp:  1                Halpha      5.164      0.69     -25    51
# Comp:  2             [SII]6716      1.602      0.88     -21   122
# Comp:  2             [SII]6731      2.830      0.88     -21   122
# Comp:  2              HeII4687     0.8015      0.88     -21   122
# Comp:  2               HeI5876      1.334      0.88     -21   122
# Comp:  2          [OIII]5007_d      1.991       1.1     -21   122
# Comp:  2            [OI]6300_d      1.393       1.1     -21   122
# Comp:  2           [NII]6583_d      4.340       1.1     -21   122
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22         1
#  comp.  1:       -29        44
#  comp.  2:       -34        64
# chi2/DOF: 0.7997; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.67     -29    44
# Comp:  1                 Hbeta     0.7992      0.67     -29    44
# Comp:  1                Halpha      4.604      0.67     -29    44
# Comp:  2             [SII]6716      1.669      0.72     -34    64
# Comp:  2             [SII]6731      1.672      0.72     -34    64
# Comp:  2              HeII4687     0.2310      0.72     -34    64
# Comp:  2               HeI5876      0.000      0.72     -34    64
# Comp:  2          [OIII]5007_d      2.560      0.91     -34    64
# Comp:  2            [OI]6300_d      0.000      0.91     -34    64
# Comp:  2           [NII]6583_d      3.262      0.91     -34    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21         1
#  comp.  1:       -33        45
#  comp.  2:       -36        97
# chi2/DOF: 0.8017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.67     -33    45
# Comp:  1                 Hbeta      1.687      0.67     -33    45
# Comp:  1                Halpha      5.165      0.67     -33    45
# Comp:  2             [SII]6716      1.523      0.81     -36    97
# Comp:  2             [SII]6731      1.295      0.81     -36    97
# Comp:  2              HeII4687      0.000      0.81     -36    97
# Comp:  2               HeI5876      1.250      0.81     -36    97
# Comp:  2          [OIII]5007_d      1.316       1.0     -36    97
# Comp:  2            [OI]6300_d      1.252       1.0     -36    97
# Comp:  2           [NII]6583_d      2.681       1.0     -36    97
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48         1
#  comp.  1:       -19        42
#  comp.  2:       -15       147
# chi2/DOF: 0.7997; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.2887      0.66     -19    42
# Comp:  1                 Hbeta      1.094      0.66     -19    42
# Comp:  1                Halpha      4.412      0.66     -19    42
# Comp:  2             [SII]6716      1.822      0.95     -15   147
# Comp:  2             [SII]6731      1.527      0.95     -15   147
# Comp:  2              HeII4687      0.000      0.95     -15   147
# Comp:  2               HeI5876      0.000      0.95     -15   147
# Comp:  2          [OIII]5007_d      1.752       1.2     -15   147
# Comp:  2            [OI]6300_d      0.000       1.2     -15   147
# Comp:  2           [NII]6583_d      4.496       1.2     -15   147
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        94
#  comp.  1:       -28        40
#  comp.  2:         1        89
# chi2/DOF: 0.7982; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.66     -28    40
# Comp:  1                 Hbeta      1.011      0.66     -28    40
# Comp:  1                Halpha      4.596      0.66     -28    40
# Comp:  2             [SII]6716      1.870      0.79       1    89
# Comp:  2             [SII]6731      2.357      0.79       1    89
# Comp:  2              HeII4687     0.2661      0.79       1    89
# Comp:  2               HeI5876      0.000      0.79       1    89
# Comp:  2          [OIII]5007_d      3.039       1.0       1    89
# Comp:  2            [OI]6300_d      0.000       1.0       1    89
# Comp:  2           [NII]6583_d      3.206       1.0       1    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        14
#  comp.  1:       -38        44
#  comp.  2:        -4        25
# chi2/DOF: 0.7989; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.67     -38    44
# Comp:  1                 Hbeta      1.538      0.67     -38    44
# Comp:  1                Halpha      4.737      0.67     -38    44
# Comp:  2             [SII]6716     0.9969      0.63      -4    25
# Comp:  2             [SII]6731      1.378      0.63      -4    25
# Comp:  2              HeII4687     0.1206      0.63      -4    25
# Comp:  2               HeI5876     0.7222      0.63      -4    25
# Comp:  2          [OIII]5007_d     0.8825      0.80      -4    25
# Comp:  2            [OI]6300_d      0.000      0.80      -4    25
# Comp:  2           [NII]6583_d      1.938      0.80      -4    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        57        34
#  comp.  1:       -19        39
#  comp.  2:        -3       103
# chi2/DOF: 0.8019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 25; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1515      0.66     -19    39
# Comp:  1                 Hbeta      1.108      0.66     -19    39
# Comp:  1                Halpha      4.276      0.66     -19    39
# Comp:  2             [SII]6716      1.824      0.83      -3   103
# Comp:  2             [SII]6731      1.265      0.83      -3   103
# Comp:  2              HeII4687     0.4798      0.83      -3   103
# Comp:  2               HeI5876      0.000      0.83      -3   103
# Comp:  2          [OIII]5007_d      1.185       1.0      -3   103
# Comp:  2            [OI]6300_d      0.000       1.0      -3   103
# Comp:  2           [NII]6583_d      3.808       1.0      -3   103
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        32         1
#  comp.  1:       -17        47
#  comp.  2:       -41        91
# chi2/DOF: 0.8018; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.4746      0.68     -17    47
# Comp:  1                 Hbeta      1.916      0.68     -17    47
# Comp:  1                Halpha      4.909      0.68     -17    47
# Comp:  2             [SII]6716      1.577      0.80     -41    91
# Comp:  2             [SII]6731      1.954      0.80     -41    91
# Comp:  2              HeII4687      0.000      0.80     -41    91
# Comp:  2               HeI5876     0.1709      0.80     -41    91
# Comp:  2          [OIII]5007_d      1.664       1.0     -41    91
# Comp:  2            [OI]6300_d      1.341       1.0     -41    91
# Comp:  2           [NII]6583_d      2.796       1.0     -41    91
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        59
#  comp.  1:       -28        49
#  comp.  2:       -35        54
# chi2/DOF: 0.8026; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7191      0.68     -28    49
# Comp:  1                 Hbeta      1.630      0.68     -28    49
# Comp:  1                Halpha      4.925      0.68     -28    49
# Comp:  2             [SII]6716      1.584      0.69     -35    54
# Comp:  2             [SII]6731      1.982      0.69     -35    54
# Comp:  2              HeII4687      0.000      0.69     -35    54
# Comp:  2               HeI5876      0.000      0.69     -35    54
# Comp:  2          [OIII]5007_d      2.278      0.88     -35    54
# Comp:  2            [OI]6300_d      1.724      0.88     -35    54
# Comp:  2           [NII]6583_d      2.974      0.88     -35    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        25        38
#  comp.  1:       -20        59
#  comp.  2:       -37        84
# chi2/DOF: 0.8017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.159      0.71     -20    59
# Comp:  1                 Hbeta      1.936      0.71     -20    59
# Comp:  1                Halpha      5.325      0.71     -20    59
# Comp:  2             [SII]6716      1.441      0.78     -37    84
# Comp:  2             [SII]6731     0.7957      0.78     -37    84
# Comp:  2              HeII4687      0.000      0.78     -37    84
# Comp:  2               HeI5876      0.000      0.78     -37    84
# Comp:  2          [OIII]5007_d      3.002      0.98     -37    84
# Comp:  2            [OI]6300_d      1.745      0.98     -37    84
# Comp:  2           [NII]6583_d      2.906      0.98     -37    84
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        90        39
#  comp.  1:        -9        49
#  comp.  2:       -23        69
# chi2/DOF: 0.7969; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3827      0.68      -9    49
# Comp:  1                 Hbeta      1.400      0.68      -9    49
# Comp:  1                Halpha      4.571      0.68      -9    49
# Comp:  2             [SII]6716      1.508      0.73     -23    69
# Comp:  2             [SII]6731      1.272      0.73     -23    69
# Comp:  2              HeII4687      0.000      0.73     -23    69
# Comp:  2               HeI5876     0.8066      0.73     -23    69
# Comp:  2          [OIII]5007_d      2.715      0.93     -23    69
# Comp:  2            [OI]6300_d      1.057      0.93     -23    69
# Comp:  2           [NII]6583_d      2.772      0.93     -23    69
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        96       213
#  comp.  1:       -33        54
#  comp.  2:       -14       107
# chi2/DOF: 0.8002; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.69     -33    54
# Comp:  1                 Hbeta      1.172      0.69     -33    54
# Comp:  1                Halpha      4.699      0.69     -33    54
# Comp:  2             [SII]6716      1.857      0.84     -14   107
# Comp:  2             [SII]6731      1.110      0.84     -14   107
# Comp:  2              HeII4687      0.000      0.84     -14   107
# Comp:  2               HeI5876      0.000      0.84     -14   107
# Comp:  2          [OIII]5007_d      2.393       1.1     -14   107
# Comp:  2            [OI]6300_d      1.326       1.1     -14   107
# Comp:  2           [NII]6583_d      3.305       1.1     -14   107
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30       137
#  comp.  1:       -35        53
#  comp.  2:       -34        67
# chi2/DOF: 0.8014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma    0.02433      0.69     -35    53
# Comp:  1                 Hbeta      1.135      0.69     -35    53
# Comp:  1                Halpha      4.789      0.69     -35    53
# Comp:  2             [SII]6716      1.477      0.73     -34    67
# Comp:  2             [SII]6731      1.848      0.73     -34    67
# Comp:  2              HeII4687     0.1053      0.73     -34    67
# Comp:  2               HeI5876      0.000      0.73     -34    67
# Comp:  2          [OIII]5007_d      2.827      0.92     -34    67
# Comp:  2            [OI]6300_d     0.6164      0.92     -34    67
# Comp:  2           [NII]6583_d      2.289      0.92     -34    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        45       129
#  comp.  1:       -31        55
#  comp.  2:         1        51
# chi2/DOF: 0.8014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.70     -31    55
# Comp:  1                 Hbeta      1.310      0.70     -31    55
# Comp:  1                Halpha      4.535      0.70     -31    55
# Comp:  2             [SII]6716      1.623      0.69       1    51
# Comp:  2             [SII]6731      1.691      0.69       1    51
# Comp:  2              HeII4687      0.000      0.69       1    51
# Comp:  2               HeI5876      0.000      0.69       1    51
# Comp:  2          [OIII]5007_d      1.127      0.87       1    51
# Comp:  2            [OI]6300_d     0.4123      0.87       1    51
# Comp:  2           [NII]6583_d      2.210      0.87       1    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30         1
#  comp.  1:       -25        58
#  comp.  2:        -5        92
# chi2/DOF: 0.7989; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.70     -25    58
# Comp:  1                 Hbeta      1.496      0.70     -25    58
# Comp:  1                Halpha      4.988      0.70     -25    58
# Comp:  2             [SII]6716      2.089      0.80      -5    92
# Comp:  2             [SII]6731      1.619      0.80      -5    92
# Comp:  2              HeII4687     0.4683      0.80      -5    92
# Comp:  2               HeI5876     0.5529      0.80      -5    92
# Comp:  2          [OIII]5007_d      2.497       1.0      -5    92
# Comp:  2            [OI]6300_d     0.2889       1.0      -5    92
# Comp:  2           [NII]6583_d      3.365       1.0      -5    92
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        75
#  comp.  1:       -34        50
#  comp.  2:        -0       118
# chi2/DOF: 0.7967; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.68     -34    50
# Comp:  1                 Hbeta      1.773      0.68     -34    50
# Comp:  1                Halpha      5.360      0.68     -34    50
# Comp:  2             [SII]6716      1.681      0.87      -0   118
# Comp:  2             [SII]6731      2.488      0.87      -0   118
# Comp:  2              HeII4687    0.09759      0.87      -0   118
# Comp:  2               HeI5876      0.000      0.87      -0   118
# Comp:  2          [OIII]5007_d      2.620       1.1      -0   118
# Comp:  2            [OI]6300_d      0.000       1.1      -0   118
# Comp:  2           [NII]6583_d      2.969       1.1      -0   118
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18        41
#  comp.  1:       -21        46
#  comp.  2:       -90       105
# chi2/DOF: 0.8000; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.5209      0.67     -21    46
# Comp:  1                 Hbeta      1.438      0.67     -21    46
# Comp:  1                Halpha      4.904      0.67     -21    46
# Comp:  2             [SII]6716      1.487      0.84     -90   105
# Comp:  2             [SII]6731     0.9251      0.84     -90   105
# Comp:  2              HeII4687     0.1469      0.84     -90   105
# Comp:  2               HeI5876    0.07148      0.84     -90   105
# Comp:  2          [OIII]5007_d      1.946       1.1     -90   105
# Comp:  2            [OI]6300_d      2.915       1.1     -90   105
# Comp:  2           [NII]6583_d      3.367       1.1     -90   105
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -35        38
#  comp.  2:         4        75
# chi2/DOF: 0.8021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.66     -35    38
# Comp:  1                 Hbeta     0.8165      0.66     -35    38
# Comp:  1                Halpha      4.559      0.66     -35    38
# Comp:  2             [SII]6716      1.612      0.75       4    75
# Comp:  2             [SII]6731      1.876      0.75       4    75
# Comp:  2              HeII4687      0.000      0.75       4    75
# Comp:  2               HeI5876    0.03942      0.75       4    75
# Comp:  2          [OIII]5007_d      1.818      0.95       4    75
# Comp:  2            [OI]6300_d      0.000      0.95       4    75
# Comp:  2           [NII]6583_d      3.218      0.95       4    75
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        29
#  comp.  1:       -35        48
#  comp.  2:       -44        81
# chi2/DOF: 0.7997; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.5147      0.68     -35    48
# Comp:  1                 Hbeta      1.152      0.68     -35    48
# Comp:  1                Halpha      4.673      0.68     -35    48
# Comp:  2             [SII]6716      1.358      0.77     -44    81
# Comp:  2             [SII]6731      1.519      0.77     -44    81
# Comp:  2              HeII4687      0.000      0.77     -44    81
# Comp:  2               HeI5876      1.118      0.77     -44    81
# Comp:  2          [OIII]5007_d      1.565      0.97     -44    81
# Comp:  2            [OI]6300_d      0.000      0.97     -44    81
# Comp:  2           [NII]6583_d      3.032      0.97     -44    81
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3         6
#  comp.  1:       -26        46
#  comp.  2:       -46        72
# chi2/DOF: 0.8022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.5423      0.67     -26    46
# Comp:  1                 Hbeta      2.016      0.67     -26    46
# Comp:  1                Halpha      5.236      0.67     -26    46
# Comp:  2             [SII]6716      1.424      0.74     -46    72
# Comp:  2             [SII]6731      1.639      0.74     -46    72
# Comp:  2              HeII4687    0.06023      0.74     -46    72
# Comp:  2               HeI5876     0.2284      0.74     -46    72
# Comp:  2          [OIII]5007_d      2.338      0.94     -46    72
# Comp:  2            [OI]6300_d      1.604      0.94     -46    72
# Comp:  2           [NII]6583_d      3.073      0.94     -46    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        11       100
#  comp.  1:       -32        63
#  comp.  2:         7        68
# chi2/DOF: 0.8014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21         1
#  comp.  1:       -31        44
#  comp.  2:         8        76
# chi2/DOF: 0.8000; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.5440      0.67     -31    44
# Comp:  1                 Hbeta      1.282      0.67     -31    44
# Comp:  1                Halpha      4.864      0.67     -31    44
# Comp:  2             [SII]6716      1.668      0.75       8    76
# Comp:  2             [SII]6731      1.552      0.75       8    76
# Comp:  2              HeII4687     0.2506      0.75       8    76
# Comp:  2               HeI5876    0.03712      0.75       8    76
# Comp:  2          [OIII]5007_d      1.995      0.95       8    76
# Comp:  2            [OI]6300_d     0.3464      0.95       8    76
# Comp:  2           [NII]6583_d      2.881      0.95       8    76
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35        87
#  comp.  1:       -24        50
#  comp.  2:       -28        98
# chi2/DOF: 0.8024; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.68     -24    50
# Comp:  1                 Hbeta      1.766      0.68     -24    50
# Comp:  1                Halpha      4.734      0.68     -24    50
# Comp:  2             [SII]6716      1.404      0.82     -28    98
# Comp:  2             [SII]6731     0.6815      0.82     -28    98
# Comp:  2              HeII4687      0.000      0.82     -28    98
# Comp:  2               HeI5876      1.181      0.82     -28    98
# Comp:  2          [OIII]5007_d      2.172       1.0     -28    98
# Comp:  2            [OI]6300_d     0.5602       1.0     -28    98
# Comp:  2           [NII]6583_d      3.140       1.0     -28    98
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42         1
#  comp.  1:       -38        51
#  comp.  2:       -26        80
# chi2/DOF: 0.7995; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6703      0.69     -38    51
# Comp:  1                 Hbeta      1.942      0.69     -38    51
# Comp:  1                Halpha      5.021      0.69     -38    51
# Comp:  2             [SII]6716      1.716      0.76     -26    80
# Comp:  2             [SII]6731     0.9151      0.76     -26    80
# Comp:  2              HeII4687      0.000      0.76     -26    80
# Comp:  2               HeI5876      0.000      0.76     -26    80
# Comp:  2          [OIII]5007_d      3.070      0.96     -26    80
# Comp:  2            [OI]6300_d      0.000      0.96     -26    80
# Comp:  2           [NII]6583_d      3.204      0.96     -26    80
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        52
#  comp.  1:       -29        43
#  comp.  2:       -16        59
# chi2/DOF: 0.8026; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma    0.01931      0.67     -29    43
# Comp:  1                 Hbeta      1.465      0.67     -29    43
# Comp:  1                Halpha      4.640      0.67     -29    43
# Comp:  2             [SII]6716      1.606      0.71     -16    59
# Comp:  2             [SII]6731      1.514      0.71     -16    59
# Comp:  2              HeII4687      0.000      0.71     -16    59
# Comp:  2               HeI5876     0.1492      0.71     -16    59
# Comp:  2          [OIII]5007_d      2.145      0.89     -16    59
# Comp:  2            [OI]6300_d     0.7232      0.89     -16    59
# Comp:  2           [NII]6583_d      2.649      0.89     -16    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         6         1
#  comp.  1:       -22        39
#  comp.  2:       -12        60
# chi2/DOF: 0.7975; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.66     -22    39
# Comp:  1                 Hbeta      1.251      0.66     -22    39
# Comp:  1                Halpha      5.046      0.66     -22    39
# Comp:  2             [SII]6716      1.599      0.71     -12    60
# Comp:  2             [SII]6731      1.880      0.71     -12    60
# Comp:  2              HeII4687     0.1066      0.71     -12    60
# Comp:  2               HeI5876     0.1866      0.71     -12    60
# Comp:  2          [OIII]5007_d      2.658      0.89     -12    60
# Comp:  2            [OI]6300_d      0.000      0.89     -12    60
# Comp:  2           [NII]6583_d      2.781      0.89     -12    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33        54
#  comp.  1:       -29        53
#  comp.  2:       -26        72
# chi2/DOF: 0.8018; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6878      0.69     -29    53
# Comp:  1                 Hbeta      1.460      0.69     -29    53
# Comp:  1                Halpha      4.735      0.69     -29    53
# Comp:  2             [SII]6716      1.434      0.74     -26    72
# Comp:  2             [SII]6731     0.3807      0.74     -26    72
# Comp:  2              HeII4687     0.4989      0.74     -26    72
# Comp:  2               HeI5876     0.1495      0.74     -26    72
# Comp:  2          [OIII]5007_d      2.043      0.94     -26    72
# Comp:  2            [OI]6300_d      0.000      0.94     -26    72
# Comp:  2           [NII]6583_d      2.636      0.94     -26    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8        42
#  comp.  1:       -25        39
#  comp.  2:       -27        88
# chi2/DOF: 0.8008; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.2664      0.66     -25    39
# Comp:  1                 Hbeta      1.445      0.66     -25    39
# Comp:  1                Halpha      4.630      0.66     -25    39
# Comp:  2             [SII]6716      1.563      0.79     -27    88
# Comp:  2             [SII]6731      1.787      0.79     -27    88
# Comp:  2              HeII4687      0.000      0.79     -27    88
# Comp:  2               HeI5876    0.03882      0.79     -27    88
# Comp:  2          [OIII]5007_d      3.101      0.99     -27    88
# Comp:  2            [OI]6300_d      0.000      0.99     -27    88
# Comp:  2           [NII]6583_d      3.023      0.99     -27    88
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       105         1
#  comp.  1:       -21        56
#  comp.  2:         5       106
# chi2/DOF: 0.7977; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.70     -21    56
# Comp:  1                 Hbeta     0.3969      0.70     -21    56
# Comp:  1                Halpha      4.584      0.70     -21    56
# Comp:  2             [SII]6716      2.088      0.84       5   106
# Comp:  2             [SII]6731     0.7893      0.84       5   106
# Comp:  2              HeII4687      0.000      0.84       5   106
# Comp:  2               HeI5876      0.000      0.84       5   106
# Comp:  2          [OIII]5007_d      2.072       1.1       5   106
# Comp:  2            [OI]6300_d      0.000       1.1       5   106
# Comp:  2           [NII]6583_d      3.948       1.1       5   106
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14        98
#  comp.  1:       -25        45
#  comp.  2:       -45        94
# chi2/DOF: 0.8007; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma    0.01851      0.67     -25    45
# Comp:  1                 Hbeta      1.142      0.67     -25    45
# Comp:  1                Halpha      4.630      0.67     -25    45
# Comp:  2             [SII]6716      1.348      0.81     -45    94
# Comp:  2             [SII]6731      1.336      0.81     -45    94
# Comp:  2              HeII4687    0.02113      0.81     -45    94
# Comp:  2               HeI5876     0.9400      0.81     -45    94
# Comp:  2          [OIII]5007_d      1.628       1.0     -45    94
# Comp:  2            [OI]6300_d      2.028       1.0     -45    94
# Comp:  2           [NII]6583_d      3.474       1.0     -45    94
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0         1
#  comp.  1:       -26        44
#  comp.  2:       -21        55
# chi2/DOF: 0.8025; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.2320      0.67     -26    44
# Comp:  1                 Hbeta      1.711      0.67     -26    44
# Comp:  1                Halpha      5.302      0.67     -26    44
# Comp:  2             [SII]6716      1.147      0.70     -21    55
# Comp:  2             [SII]6731      1.781      0.70     -21    55
# Comp:  2              HeII4687      0.000      0.70     -21    55
# Comp:  2               HeI5876     0.7537      0.70     -21    55
# Comp:  2          [OIII]5007_d      1.484      0.88     -21    55
# Comp:  2            [OI]6300_d     0.9983      0.88     -21    55
# Comp:  2           [NII]6583_d      2.407      0.88     -21    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18        87
#  comp.  1:       -31        53
#  comp.  2:       -32        97
# chi2/DOF: 0.8042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.2928      0.69     -31    53
# Comp:  1                 Hbeta      1.483      0.69     -31    53
# Comp:  1                Halpha      4.903      0.69     -31    53
# Comp:  2             [SII]6716      1.648      0.81     -32    97
# Comp:  2             [SII]6731      1.616      0.81     -32    97
# Comp:  2              HeII4687     0.3115      0.81     -32    97
# Comp:  2               HeI5876      0.000      0.81     -32    97
# Comp:  2          [OIII]5007_d      2.284       1.0     -32    97
# Comp:  2            [OI]6300_d     0.2315       1.0     -32    97
# Comp:  2           [NII]6583_d      3.399       1.0     -32    97
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3         1
#  comp.  1:       -22        64
#  comp.  2:       -25        74
# chi2/DOF: 0.7997; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.413      0.72     -22    64
# Comp:  1                 Hbeta      2.858      0.72     -22    64
# Comp:  1                Halpha      6.152      0.72     -22    64
# Comp:  2             [SII]6716      1.549      0.75     -25    74
# Comp:  2             [SII]6731     0.8042      0.75     -25    74
# Comp:  2              HeII4687      0.000      0.75     -25    74
# Comp:  2               HeI5876      0.000      0.75     -25    74
# Comp:  2          [OIII]5007_d      2.696      0.95     -25    74
# Comp:  2            [OI]6300_d      1.399      0.95     -25    74
# Comp:  2           [NII]6583_d      3.073      0.95     -25    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        16
#  comp.  1:       -24        46
#  comp.  2:       -37        67
# chi2/DOF: 0.8026; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3281      0.67     -24    46
# Comp:  1                 Hbeta      1.894      0.67     -24    46
# Comp:  1                Halpha      5.330      0.67     -24    46
# Comp:  2             [SII]6716      1.329      0.73     -37    67
# Comp:  2             [SII]6731      1.076      0.73     -37    67
# Comp:  2              HeII4687      0.000      0.73     -37    67
# Comp:  2               HeI5876     0.8327      0.73     -37    67
# Comp:  2          [OIII]5007_d      1.999      0.92     -37    67
# Comp:  2            [OI]6300_d      0.000      0.92     -37    67
# Comp:  2           [NII]6583_d      3.172      0.92     -37    67
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.38595332, 0.4655012 , 0.45220001, 0.40243784, 0.8720928 ,
#        0.1680655 , 0.4511956 , 0.53660006, 1.08304741, 0.61927873])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([0.        , 1.28733938, 6.41495539, 2.24606356, 1.84992631,
#        0.        , 0.        , 2.18603526, 0.42437208, 4.06928274])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_3_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_3", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_3_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_3_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_3_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0        Hgamma  0.000000    0.008845
# 1         Hbeta  0.029503    0.010668
# 2        Halpha  0.147017    0.010363
# 3     [SII]6716  0.051475    0.009223
# 4     [SII]6731  0.042396    0.019986
# 5      HeII4687  0.000000    0.003852
# 6       HeI5876  0.000000    0.010340
# 7  [OIII]5007_d  0.050099    0.012298
# 8    [OI]6300_d  0.009726    0.024821
# 9   [NII]6583_d  0.093259    0.014193
#           Name      Flux  Error_flux
# 0       Hgamma  0.000000    0.008845
# 1        Hbeta  0.029503    0.010668
# 2       Halpha  0.147017    0.010363
# 3    [SII]6716  0.051475    0.009223
# 4    [SII]6731  0.042396    0.019986
# 5     HeII4687  0.000000    0.003852
# 6      HeI5876  0.000000    0.010340
# 7   [OIII]4959  0.012525    0.012298
# 8   [OIII]5007  0.037574    0.012298
# 9     [OI]6300  0.007294    0.024821
# 10    [OI]6364  0.002431    0.024821
# 11   [NII]6548  0.023315    0.014193
# 12   [NII]6583  0.069944    0.014193

# %%
np.median(flux_rf_rebin)
# Out:
# 0.022917796954497187
