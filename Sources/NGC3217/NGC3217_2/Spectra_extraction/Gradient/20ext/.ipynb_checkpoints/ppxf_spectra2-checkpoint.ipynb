# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_2']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4314.03901503 4315.47324864 4316.90748224 ... 6874.1460011  6875.58023471
#  6877.01446832] [0.01168313 0.01410463 0.01663378 ... 0.01173343 0.0084545  0.00840688] [0.00619146 0.00619146 0.00619146 ... 0.00619146 0.00619146 0.00619146]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        97
# chi2/DOF: 0.1982; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        64
# chi2/DOF: 0.07374; DOF: 1872; degree = 4; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 8; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-8.61383258, 64.46538891])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        82
#  comp.  1:       -48       241
#  comp.  2:       -77        89
# chi2/DOF: 1.270; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.24       1.4     -48   241
# Comp:  1                 Hbeta      7.932       1.4     -48   241
# Comp:  1                Halpha      2.245       1.4     -48   241
# Comp:  2             [SII]6716      0.000      0.95     -77    89
# Comp:  2             [SII]6731      0.000      0.95     -77    89
# Comp:  2              HeII4687      0.000      0.95     -77    89
# Comp:  2               HeI5876     0.6230      0.95     -77    89
# Comp:  2          [OIII]5007_d      1.232       1.2     -77    89
# Comp:  2            [OI]6300_d      1.469       1.2     -77    89
# Comp:  2           [NII]6583_d      0.000       1.2     -77    89
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  3.939; gas flux:     10 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  2.782; gas flux:      8 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  0.788; gas flux:      3 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.4886; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise: 0.7315; gas flux:      1 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.8682; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        64
#  comp.  1:       -51       148
#  comp.  2:       246       282
# chi2/DOF: 1.256; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.149       1.1     -51   148
# Comp:  1                 Hbeta      4.720       1.1     -51   148
# Comp:  1                Halpha      1.853       1.2     -51   148
# Comp:  2             [SII]6716      0.000       1.6     246   282
# Comp:  2             [SII]6731      5.988       1.6     246   282
# Comp:  2              HeII4687      2.533       1.5     246   282
# Comp:  2               HeI5876      0.000       1.5     246   282
# Comp:  2          [OIII]5007_d      2.223       1.9     246   282
# Comp:  2            [OI]6300_d      1.120       1.9     246   282
# Comp:  2           [NII]6583_d     0.8232       2.0     246   282
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45       105
#  comp.  1:       -33       245
#  comp.  2:      -161       208
# chi2/DOF: 1.259; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.66       1.4     -33   245
# Comp:  1                 Hbeta      8.538       1.4     -33   245
# Comp:  1                Halpha      2.466       1.4     -33   245
# Comp:  2             [SII]6716      2.945       1.3    -161   208
# Comp:  2             [SII]6731      1.061       1.3    -161   208
# Comp:  2              HeII4687     0.9434       1.3    -161   208
# Comp:  2               HeI5876      1.593       1.3    -161   208
# Comp:  2          [OIII]5007_d      1.869       1.7    -161   208
# Comp:  2            [OI]6300_d      5.491       1.7    -161   208
# Comp:  2           [NII]6583_d     0.5928       1.7    -161   208
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63       287
#  comp.  1:        11       261
#  comp.  2:      -118         1
# chi2/DOF: 1.260; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.097       1.5      11   261
# Comp:  1                 Hbeta      8.022       1.5      11   261
# Comp:  1                Halpha      2.877       1.5      11   261
# Comp:  2             [SII]6716      1.411      0.73    -118     1
# Comp:  2             [SII]6731      0.000      0.73    -118     1
# Comp:  2              HeII4687     0.5314      0.73    -118     1
# Comp:  2               HeI5876     0.5990      0.73    -118     1
# Comp:  2          [OIII]5007_d      1.004      0.92    -118     1
# Comp:  2            [OI]6300_d      2.047      0.92    -118     1
# Comp:  2           [NII]6583_d      0.000      0.92    -118     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        32        68
#  comp.  1:        35       190
#  comp.  2:      -143        90
# chi2/DOF: 1.259; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.744       1.3      35   190
# Comp:  1                 Hbeta      4.499       1.3      35   190
# Comp:  1                Halpha      2.631       1.3      35   190
# Comp:  2             [SII]6716      0.000      0.95    -143    90
# Comp:  2             [SII]6731     0.5788      0.95    -143    90
# Comp:  2              HeII4687      0.000      0.95    -143    90
# Comp:  2               HeI5876     0.3063      0.95    -143    90
# Comp:  2          [OIII]5007_d      1.436       1.2    -143    90
# Comp:  2            [OI]6300_d      3.750       1.2    -143    90
# Comp:  2           [NII]6583_d      0.000       1.2    -143    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        50
#  comp.  1:       -49       181
#  comp.  2:       -85        42
# chi2/DOF: 1.251; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.71       1.2     -49   181
# Comp:  1                 Hbeta      7.395       1.2     -49   181
# Comp:  1                Halpha      0.000       1.2     -49   181
# Comp:  2             [SII]6716     0.3960      0.80     -85    42
# Comp:  2             [SII]6731     0.5397      0.80     -85    42
# Comp:  2              HeII4687      0.000      0.80     -85    42
# Comp:  2               HeI5876     0.5612      0.80     -85    42
# Comp:  2          [OIII]5007_d      2.495       1.0     -85    42
# Comp:  2            [OI]6300_d      1.839       1.0     -85    42
# Comp:  2           [NII]6583_d      0.000       1.0     -85    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        70
#  comp.  1:       -52       229
#  comp.  2:      -148       137
# chi2/DOF: 1.251; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.505       1.4     -52   229
# Comp:  1                 Hbeta      5.797       1.4     -52   229
# Comp:  1                Halpha      1.993       1.4     -52   229
# Comp:  2             [SII]6716     0.5837       1.1    -148   137
# Comp:  2             [SII]6731      1.067       1.1    -148   137
# Comp:  2              HeII4687      0.000       1.1    -148   137
# Comp:  2               HeI5876      1.184       1.1    -148   137
# Comp:  2          [OIII]5007_d      1.522       1.4    -148   137
# Comp:  2            [OI]6300_d      4.867       1.4    -148   137
# Comp:  2           [NII]6583_d      0.000       1.4    -148   137
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84        72
#  comp.  1:      -111       263
#  comp.  2:       -99       153
# chi2/DOF: 1.257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.73       1.5    -111   263
# Comp:  1                 Hbeta      11.24       1.5    -111   263
# Comp:  1                Halpha      2.927       1.5    -111   263
# Comp:  2             [SII]6716      0.000       1.2     -99   153
# Comp:  2             [SII]6731      2.205       1.2     -99   153
# Comp:  2              HeII4687     0.1356       1.2     -99   153
# Comp:  2               HeI5876      1.783       1.2     -99   153
# Comp:  2          [OIII]5007_d      1.374       1.5     -99   153
# Comp:  2            [OI]6300_d      3.634       1.5     -99   153
# Comp:  2           [NII]6583_d      0.000       1.5     -99   153
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59       105
#  comp.  1:       -73       159
#  comp.  2:        61       125
# chi2/DOF: 1.261; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.178       1.2     -73   159
# Comp:  1                 Hbeta      4.988       1.2     -73   159
# Comp:  1                Halpha      2.042       1.2     -73   159
# Comp:  2             [SII]6716      0.000       1.1      61   125
# Comp:  2             [SII]6731      3.348       1.1      61   125
# Comp:  2              HeII4687     0.9069       1.1      61   125
# Comp:  2               HeI5876     0.7967       1.1      61   125
# Comp:  2          [OIII]5007_d      1.638       1.3      61   125
# Comp:  2            [OI]6300_d     0.9770       1.3      61   125
# Comp:  2           [NII]6583_d     0.6376       1.3      61   125
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -111       145
#  comp.  1:      -106       162
#  comp.  2:      -158        46
# chi2/DOF: 1.260; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.651       1.2    -106   162
# Comp:  1                 Hbeta      5.667       1.2    -106   162
# Comp:  1                Halpha      3.415       1.2    -106   162
# Comp:  2             [SII]6716      0.000      0.81    -158    46
# Comp:  2             [SII]6731      0.000      0.81    -158    46
# Comp:  2              HeII4687      1.417      0.81    -158    46
# Comp:  2               HeI5876     0.6955      0.81    -158    46
# Comp:  2          [OIII]5007_d     0.1081       1.0    -158    46
# Comp:  2            [OI]6300_d      2.957       1.0    -158    46
# Comp:  2           [NII]6583_d      1.117       1.0    -158    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        38
#  comp.  1:      -103       318
#  comp.  2:      -165       117
# chi2/DOF: 1.260; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.80       1.6    -103   318
# Comp:  1                 Hbeta      9.328       1.6    -103   318
# Comp:  1                Halpha      2.742       1.6    -103   318
# Comp:  2             [SII]6716     0.2831       1.0    -165   117
# Comp:  2             [SII]6731      0.000       1.0    -165   117
# Comp:  2              HeII4687     0.5302       1.0    -165   117
# Comp:  2               HeI5876     0.6752       1.0    -165   117
# Comp:  2          [OIII]5007_d      2.068       1.3    -165   117
# Comp:  2            [OI]6300_d      4.411       1.3    -165   117
# Comp:  2           [NII]6583_d      0.000       1.3    -165   117
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72        79
#  comp.  1:      -101       328
#  comp.  2:      -127        82
# chi2/DOF: 1.255; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      18.27       1.6    -101   328
# Comp:  1                 Hbeta      15.93       1.6    -101   328
# Comp:  1                Halpha      4.507       1.6    -101   328
# Comp:  2             [SII]6716      0.000      0.92    -127    82
# Comp:  2             [SII]6731      0.000      0.92    -127    82
# Comp:  2              HeII4687      0.000      0.92    -127    82
# Comp:  2               HeI5876     0.7103      0.92    -127    82
# Comp:  2          [OIII]5007_d      1.218       1.2    -127    82
# Comp:  2            [OI]6300_d      3.449       1.2    -127    82
# Comp:  2           [NII]6583_d      0.000       1.2    -127    82
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:       -84       223
#  comp.  2:       -57       140
# chi2/DOF: 1.261; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      13.74       1.4     -84   223
# Comp:  1                 Hbeta      8.476       1.4     -84   223
# Comp:  1                Halpha      3.834       1.4     -84   223
# Comp:  2             [SII]6716      0.000       1.1     -57   140
# Comp:  2             [SII]6731     0.9636       1.1     -57   140
# Comp:  2              HeII4687      2.660       1.1     -57   140
# Comp:  2               HeI5876     0.4154       1.1     -57   140
# Comp:  2          [OIII]5007_d      1.967       1.4     -57   140
# Comp:  2            [OI]6300_d     0.6458       1.4     -57   140
# Comp:  2           [NII]6583_d      1.592       1.4     -57   140
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65         1
#  comp.  1:       -31       222
#  comp.  2:      -215       147
# chi2/DOF: 1.249; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.53       1.4     -31   222
# Comp:  1                 Hbeta      11.69       1.4     -31   222
# Comp:  1                Halpha      3.718       1.4     -31   222
# Comp:  2             [SII]6716      0.000       1.1    -215   147
# Comp:  2             [SII]6731      0.000       1.1    -215   147
# Comp:  2              HeII4687      0.000       1.1    -215   147
# Comp:  2               HeI5876     0.8493       1.1    -215   147
# Comp:  2          [OIII]5007_d      1.330       1.4    -215   147
# Comp:  2            [OI]6300_d      4.857       1.4    -215   147
# Comp:  2           [NII]6583_d      0.000       1.4    -215   147
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -72         1
#  comp.  1:      -106       226
#  comp.  2:        -0         1
# chi2/DOF: 1.252; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.524       1.4    -106   226
# Comp:  1                 Hbeta      7.639       1.4    -106   226
# Comp:  1                Halpha      4.319       1.4    -106   226
# Comp:  2             [SII]6716     0.4630      0.73      -0     1
# Comp:  2             [SII]6731     0.8823      0.73      -0     1
# Comp:  2              HeII4687      0.000      0.73      -0     1
# Comp:  2               HeI5876     0.4399      0.73      -0     1
# Comp:  2          [OIII]5007_d    0.04594      0.92      -0     1
# Comp:  2            [OI]6300_d      1.359      0.92      -0     1
# Comp:  2           [NII]6583_d      1.122      0.92      -0     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        57
#  comp.  1:       -21       181
#  comp.  2:       -62        15
# chi2/DOF: 1.257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      12.34       1.2     -21   181
# Comp:  1                 Hbeta      8.159       1.2     -21   181
# Comp:  1                Halpha      2.980       1.2     -21   181
# Comp:  2             [SII]6716      0.000      0.74     -62    15
# Comp:  2             [SII]6731      1.466      0.74     -62    15
# Comp:  2              HeII4687      0.000      0.74     -62    15
# Comp:  2               HeI5876     0.2125      0.74     -62    15
# Comp:  2          [OIII]5007_d      1.737      0.94     -62    15
# Comp:  2            [OI]6300_d      1.309      0.94     -62    15
# Comp:  2           [NII]6583_d     0.5475      0.94     -62    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70         1
#  comp.  1:       -24       132
#  comp.  2:       -14       125
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.681       1.1     -24   132
# Comp:  1                 Hbeta      4.081       1.1     -24   132
# Comp:  1                Halpha     0.9191       1.1     -24   132
# Comp:  2             [SII]6716     0.9857       1.1     -14   125
# Comp:  2             [SII]6731      3.491       1.1     -14   125
# Comp:  2              HeII4687      0.000       1.1     -14   125
# Comp:  2               HeI5876      1.002       1.1     -14   125
# Comp:  2          [OIII]5007_d      0.000       1.3     -14   125
# Comp:  2            [OI]6300_d      1.827       1.3     -14   125
# Comp:  2           [NII]6583_d     0.3918       1.3     -14   125
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        42
#  comp.  1:       -29       180
#  comp.  2:       -66        26
# chi2/DOF: 1.262; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.563       1.2     -29   180
# Comp:  1                 Hbeta      5.029       1.2     -29   180
# Comp:  1                Halpha      0.000       1.2     -29   180
# Comp:  2             [SII]6716      1.223      0.76     -66    26
# Comp:  2             [SII]6731     0.9631      0.76     -66    26
# Comp:  2              HeII4687     0.1996      0.76     -66    26
# Comp:  2               HeI5876     0.2803      0.76     -66    26
# Comp:  2          [OIII]5007_d    0.07735      0.96     -66    26
# Comp:  2            [OI]6300_d      3.296      0.96     -66    26
# Comp:  2           [NII]6583_d     0.2242      0.96     -66    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -128        23
#  comp.  1:      -158       242
#  comp.  2:      -100        98
# chi2/DOF: 1.260; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      10.14       1.4    -158   242
# Comp:  1                 Hbeta      7.515       1.4    -158   242
# Comp:  1                Halpha      2.238       1.4    -158   242
# Comp:  2             [SII]6716      0.000      0.98    -100    98
# Comp:  2             [SII]6731      0.000      0.98    -100    98
# Comp:  2              HeII4687     0.5457      0.98    -100    98
# Comp:  2               HeI5876     0.9905      0.98    -100    98
# Comp:  2          [OIII]5007_d     0.6663       1.2    -100    98
# Comp:  2            [OI]6300_d      0.000       1.2    -100    98
# Comp:  2           [NII]6583_d      0.000       1.2    -100    98
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52       239
#  comp.  1:        40       273
#  comp.  2:       -77       223
# chi2/DOF: 1.259; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.99       1.5      40   273
# Comp:  1                 Hbeta      10.94       1.5      40   273
# Comp:  1                Halpha      3.144       1.5      40   273
# Comp:  2             [SII]6716      0.000       1.4     -77   223
# Comp:  2             [SII]6731      1.558       1.4     -77   223
# Comp:  2              HeII4687      0.000       1.4     -77   223
# Comp:  2               HeI5876      1.323       1.4     -77   223
# Comp:  2          [OIII]5007_d     0.8749       1.7     -77   223
# Comp:  2            [OI]6300_d      4.563       1.7     -77   223
# Comp:  2           [NII]6583_d     0.4355       1.7     -77   223
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81         1
#  comp.  1:       -15       214
#  comp.  2:       -19       196
# chi2/DOF: 1.255; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.252       1.3     -15   214
# Comp:  1                 Hbeta      4.767       1.3     -15   214
# Comp:  1                Halpha      1.217       1.3     -15   214
# Comp:  2             [SII]6716      0.000       1.3     -19   196
# Comp:  2             [SII]6731      3.940       1.3     -19   196
# Comp:  2              HeII4687     0.9680       1.3     -19   196
# Comp:  2               HeI5876      1.019       1.3     -19   196
# Comp:  2          [OIII]5007_d     0.8957       1.6     -19   196
# Comp:  2            [OI]6300_d      4.659       1.6     -19   196
# Comp:  2           [NII]6583_d      3.289       1.6     -19   196
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85        91
#  comp.  1:      -106       273
#  comp.  2:       -32         4
# chi2/DOF: 1.258; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.24       1.5    -106   273
# Comp:  1                 Hbeta      11.47       1.5    -106   273
# Comp:  1                Halpha      2.999       1.5    -106   273
# Comp:  2             [SII]6716      1.048      0.73     -32     4
# Comp:  2             [SII]6731      1.487      0.73     -32     4
# Comp:  2              HeII4687      0.000      0.73     -32     4
# Comp:  2               HeI5876     0.4450      0.73     -32     4
# Comp:  2          [OIII]5007_d      1.454      0.93     -32     4
# Comp:  2            [OI]6300_d      0.000      0.93     -32     4
# Comp:  2           [NII]6583_d      1.119      0.93     -32     4
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48       100
#  comp.  1:        78       234
#  comp.  2:      -278         1
# chi2/DOF: 1.257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.33       1.4      78   234
# Comp:  1                 Hbeta      8.920       1.4      78   234
# Comp:  1                Halpha      2.509       1.4      78   234
# Comp:  2             [SII]6716      1.206      0.73    -278     1
# Comp:  2             [SII]6731      1.464      0.73    -278     1
# Comp:  2              HeII4687      0.000      0.73    -278     1
# Comp:  2               HeI5876     0.2127      0.73    -278     1
# Comp:  2          [OIII]5007_d      0.000      0.92    -278     1
# Comp:  2            [OI]6300_d      1.825      0.92    -278     1
# Comp:  2           [NII]6583_d      0.000      0.93    -278     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -117        42
#  comp.  1:      -151       265
#  comp.  2:       -25         1
# chi2/DOF: 1.260; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 34; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      13.01       1.5    -151   265
# Comp:  1                 Hbeta      9.491       1.5    -151   265
# Comp:  1                Halpha      3.828       1.5    -151   265
# Comp:  2             [SII]6716     0.2388      0.73     -25     1
# Comp:  2             [SII]6731      0.000      0.73     -25     1
# Comp:  2              HeII4687     0.5544      0.73     -25     1
# Comp:  2               HeI5876     0.3462      0.73     -25     1
# Comp:  2          [OIII]5007_d     0.2746      0.92     -25     1
# Comp:  2            [OI]6300_d      1.522      0.92     -25     1
# Comp:  2           [NII]6583_d     0.3490      0.92     -25     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -108        52
#  comp.  1:      -129       169
#  comp.  2:        39        93
# chi2/DOF: 1.257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.675       1.2    -129   169
# Comp:  1                 Hbeta      4.310       1.2    -129   169
# Comp:  1                Halpha      2.199       1.2    -129   169
# Comp:  2             [SII]6716      0.000      0.96      39    93
# Comp:  2             [SII]6731      2.061      0.96      39    93
# Comp:  2              HeII4687      1.247      0.96      39    93
# Comp:  2               HeI5876     0.9977      0.96      39    93
# Comp:  2          [OIII]5007_d      2.311       1.2      39    93
# Comp:  2            [OI]6300_d      2.059       1.2      39    93
# Comp:  2           [NII]6583_d     0.5158       1.2      39    93
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77         1
#  comp.  1:       -58       200
#  comp.  2:      -137       103
# chi2/DOF: 1.263; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.91       1.3     -58   200
# Comp:  1                 Hbeta      6.696       1.3     -58   200
# Comp:  1                Halpha      2.632       1.3     -58   200
# Comp:  2             [SII]6716      0.000       1.0    -137   103
# Comp:  2             [SII]6731      1.215       1.0    -137   103
# Comp:  2              HeII4687     0.4216       1.0    -137   103
# Comp:  2               HeI5876      1.164       1.0    -137   103
# Comp:  2          [OIII]5007_d      1.030       1.3    -137   103
# Comp:  2            [OI]6300_d      3.766       1.3    -137   103
# Comp:  2           [NII]6583_d      0.000       1.3    -137   103
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        86
#  comp.  1:       -64       194
#  comp.  2:      -128         1
# chi2/DOF: 1.264; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.828       1.3     -64   194
# Comp:  1                 Hbeta      5.391       1.3     -64   194
# Comp:  1                Halpha      2.590       1.3     -64   194
# Comp:  2             [SII]6716    0.07032      0.73    -128     1
# Comp:  2             [SII]6731     0.1508      0.73    -128     1
# Comp:  2              HeII4687      0.000      0.73    -128     1
# Comp:  2               HeI5876     0.1837      0.73    -128     1
# Comp:  2          [OIII]5007_d     0.6747      0.92    -128     1
# Comp:  2            [OI]6300_d      1.178      0.92    -128     1
# Comp:  2           [NII]6583_d     0.8065      0.92    -128     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:       -24       213
#  comp.  2:      -173        72
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.424       1.3     -24   213
# Comp:  1                 Hbeta      6.560       1.3     -24   213
# Comp:  1                Halpha      3.654       1.3     -24   213
# Comp:  2             [SII]6716      0.000      0.89    -173    72
# Comp:  2             [SII]6731     0.5461      0.89    -173    72
# Comp:  2              HeII4687      0.000      0.89    -173    72
# Comp:  2               HeI5876     0.6451      0.89    -173    72
# Comp:  2          [OIII]5007_d     0.2604       1.1    -173    72
# Comp:  2            [OI]6300_d      2.909       1.1    -173    72
# Comp:  2           [NII]6583_d      0.000       1.1    -173    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -93         8
#  comp.  1:      -154       159
#  comp.  2:       -50        49
# chi2/DOF: 1.261; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.137       1.2    -154   159
# Comp:  1                 Hbeta      4.228       1.2    -154   159
# Comp:  1                Halpha      3.682       1.2    -154   159
# Comp:  2             [SII]6716     0.8084      0.82     -50    49
# Comp:  2             [SII]6731     0.4984      0.82     -50    49
# Comp:  2              HeII4687      0.000      0.82     -50    49
# Comp:  2               HeI5876    0.04604      0.82     -50    49
# Comp:  2          [OIII]5007_d     0.8622       1.0     -50    49
# Comp:  2            [OI]6300_d      3.091       1.0     -50    49
# Comp:  2           [NII]6583_d     0.6088       1.0     -50    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        14
#  comp.  1:       -19       161
#  comp.  2:      -114         1
# chi2/DOF: 1.257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 45; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.605       1.2     -19   161
# Comp:  1                 Hbeta      6.894       1.2     -19   161
# Comp:  1                Halpha      2.021       1.2     -19   161
# Comp:  2             [SII]6716      1.069      0.73    -114     1
# Comp:  2             [SII]6731      0.000      0.73    -114     1
# Comp:  2              HeII4687     0.6900      0.73    -114     1
# Comp:  2               HeI5876     0.3955      0.73    -114     1
# Comp:  2          [OIII]5007_d      1.119      0.92    -114     1
# Comp:  2            [OI]6300_d      2.762      0.92    -114     1
# Comp:  2           [NII]6583_d     0.1140      0.92    -114     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        92
#  comp.  1:       -41       179
#  comp.  2:       -91         2
# chi2/DOF: 1.263; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.788       1.2     -41   179
# Comp:  1                 Hbeta      5.541       1.2     -41   179
# Comp:  1                Halpha      2.368       1.2     -41   179
# Comp:  2             [SII]6716      1.097      0.73     -91     2
# Comp:  2             [SII]6731      1.224      0.73     -91     2
# Comp:  2              HeII4687     0.8555      0.73     -91     2
# Comp:  2               HeI5876     0.6189      0.73     -91     2
# Comp:  2          [OIII]5007_d      1.341      0.92     -91     2
# Comp:  2            [OI]6300_d      2.313      0.92     -91     2
# Comp:  2           [NII]6583_d     0.3550      0.92     -91     2
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -119         1
#  comp.  1:       -76       199
#  comp.  2:      -138       106
# chi2/DOF: 1.250; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.851       1.3     -76   199
# Comp:  1                 Hbeta      6.223       1.3     -76   199
# Comp:  1                Halpha      0.000       1.3     -76   199
# Comp:  2             [SII]6716      0.000       1.0    -138   106
# Comp:  2             [SII]6731      0.000       1.0    -138   106
# Comp:  2              HeII4687     0.8603       1.0    -138   106
# Comp:  2               HeI5876     0.2717       1.0    -138   106
# Comp:  2          [OIII]5007_d      2.301       1.3    -138   106
# Comp:  2            [OI]6300_d      1.042       1.3    -138   106
# Comp:  2           [NII]6583_d      0.000       1.3    -138   106
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100        91
#  comp.  1:       -79       193
#  comp.  2:       -21         1
# chi2/DOF: 1.256; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.783       1.3     -79   193
# Comp:  1                 Hbeta      8.035       1.3     -79   193
# Comp:  1                Halpha      2.477       1.3     -79   193
# Comp:  2             [SII]6716     0.8900      0.73     -21     1
# Comp:  2             [SII]6731      1.641      0.73     -21     1
# Comp:  2              HeII4687      0.000      0.73     -21     1
# Comp:  2               HeI5876     0.4007      0.73     -21     1
# Comp:  2          [OIII]5007_d      1.435      0.92     -21     1
# Comp:  2            [OI]6300_d     0.8639      0.92     -21     1
# Comp:  2           [NII]6583_d      0.000      0.92     -21     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -86        46
#  comp.  1:      -115       223
#  comp.  2:      -185       127
# chi2/DOF: 1.260; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      14.03       1.4    -115   223
# Comp:  1                 Hbeta      8.337       1.4    -115   223
# Comp:  1                Halpha      3.314       1.4    -115   223
# Comp:  2             [SII]6716      0.000       1.1    -185   127
# Comp:  2             [SII]6731     0.8021       1.1    -185   127
# Comp:  2              HeII4687     0.9813       1.1    -185   127
# Comp:  2               HeI5876     0.3576       1.1    -185   127
# Comp:  2          [OIII]5007_d      1.378       1.4    -185   127
# Comp:  2            [OI]6300_d      4.626       1.4    -185   127
# Comp:  2           [NII]6583_d      0.000       1.4    -185   127
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       -33       162
#  comp.  2:        96        76
# chi2/DOF: 1.259; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.770       1.2     -33   162
# Comp:  1                 Hbeta      6.195       1.2     -33   162
# Comp:  1                Halpha      2.540       1.2     -33   162
# Comp:  2             [SII]6716      1.131      0.90      96    76
# Comp:  2             [SII]6731      1.745      0.90      96    76
# Comp:  2              HeII4687      1.279      0.90      96    76
# Comp:  2               HeI5876     0.6716      0.90      96    76
# Comp:  2          [OIII]5007_d     0.2907       1.1      96    76
# Comp:  2            [OI]6300_d      2.385       1.1      96    76
# Comp:  2           [NII]6583_d      0.000       1.1      96    76
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       -23       198
#  comp.  2:       113       181
# chi2/DOF: 1.258; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.613       1.3     -23   198
# Comp:  1                 Hbeta      8.824       1.3     -23   198
# Comp:  1                Halpha      1.083       1.3     -23   198
# Comp:  2             [SII]6716      1.168       1.2     113   181
# Comp:  2             [SII]6731      2.157       1.2     113   181
# Comp:  2              HeII4687      1.335       1.2     113   181
# Comp:  2               HeI5876     0.8725       1.2     113   181
# Comp:  2          [OIII]5007_d      1.954       1.6     113   181
# Comp:  2            [OI]6300_d      0.000       1.6     113   181
# Comp:  2           [NII]6583_d      0.000       1.6     113   181
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61        75
#  comp.  1:       -88       203
#  comp.  2:      -136       136
# chi2/DOF: 1.260; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      12.52       1.3     -88   203
# Comp:  1                 Hbeta      7.381       1.3     -88   203
# Comp:  1                Halpha      2.922       1.3     -88   203
# Comp:  2             [SII]6716      0.000       1.1    -136   136
# Comp:  2             [SII]6731      0.000       1.1    -136   136
# Comp:  2              HeII4687      0.000       1.1    -136   136
# Comp:  2               HeI5876     0.8385       1.1    -136   136
# Comp:  2          [OIII]5007_d      1.796       1.4    -136   136
# Comp:  2            [OI]6300_d      5.945       1.4    -136   136
# Comp:  2           [NII]6583_d      0.000       1.4    -136   136
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77        70
#  comp.  1:       -14       178
#  comp.  2:       -21        30
# chi2/DOF: 1.258; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.533       1.2     -14   178
# Comp:  1                 Hbeta      6.308       1.2     -14   178
# Comp:  1                Halpha      1.373       1.2     -14   178
# Comp:  2             [SII]6716     0.3998      0.77     -21    30
# Comp:  2             [SII]6731      1.874      0.77     -21    30
# Comp:  2              HeII4687      0.000      0.77     -21    30
# Comp:  2               HeI5876     0.8685      0.77     -21    30
# Comp:  2          [OIII]5007_d     0.7942      0.97     -21    30
# Comp:  2            [OI]6300_d      0.000      0.97     -21    30
# Comp:  2           [NII]6583_d     0.2769      0.97     -21    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89        89
#  comp.  1:       -41       224
#  comp.  2:       -99        71
# chi2/DOF: 1.260; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      12.29       1.4     -41   224
# Comp:  1                 Hbeta      8.250       1.4     -41   224
# Comp:  1                Halpha     0.5141       1.4     -41   224
# Comp:  2             [SII]6716      0.000      0.89     -99    71
# Comp:  2             [SII]6731      0.000      0.89     -99    71
# Comp:  2              HeII4687      0.000      0.89     -99    71
# Comp:  2               HeI5876      1.143      0.89     -99    71
# Comp:  2          [OIII]5007_d     0.3719       1.1     -99    71
# Comp:  2            [OI]6300_d      0.000       1.1     -99    71
# Comp:  2           [NII]6583_d     0.8306       1.1     -99    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        76
#  comp.  1:       -56       280
#  comp.  2:      -123       113
# chi2/DOF: 1.254; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.43       1.5     -56   280
# Comp:  1                 Hbeta      12.00       1.5     -56   280
# Comp:  1                Halpha      1.848       1.5     -56   280
# Comp:  2             [SII]6716     0.4077       1.0    -123   113
# Comp:  2             [SII]6731    0.09741       1.0    -123   113
# Comp:  2              HeII4687     0.2590       1.0    -123   113
# Comp:  2               HeI5876     0.4901       1.0    -123   113
# Comp:  2          [OIII]5007_d     0.4446       1.3    -123   113
# Comp:  2            [OI]6300_d      4.928       1.3    -123   113
# Comp:  2           [NII]6583_d     0.6939       1.3    -123   113
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        69
#  comp.  1:       -94       170
#  comp.  2:      -116       196
# chi2/DOF: 1.257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.395       1.2     -94   170
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        61
#  comp.  1:       -20       226
#  comp.  2:       -37         1
# chi2/DOF: 1.260; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.344       1.4     -20   226
# Comp:  1                 Hbeta      7.015       1.4     -20   226
# Comp:  1                Halpha      1.481       1.4     -20   226
# Comp:  2             [SII]6716     0.9865      0.73     -37     1
# Comp:  2             [SII]6731      1.457      0.73     -37     1
# Comp:  2              HeII4687     0.7462      0.73     -37     1
# Comp:  2               HeI5876     0.3078      0.73     -37     1
# Comp:  2          [OIII]5007_d      1.528      0.92     -37     1
# Comp:  2            [OI]6300_d     0.3837      0.92     -37     1
# Comp:  2           [NII]6583_d     0.1915      0.92     -37     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8       107
#  comp.  1:        33       264
#  comp.  2:       -88         1
# chi2/DOF: 1.257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      16.38       1.5      33   264
# Comp:  1                 Hbeta      11.93       1.5      33   264
# Comp:  1                Halpha      5.040       1.5      33   264
# Comp:  2             [SII]6716      0.000      0.73     -88     1
# Comp:  2             [SII]6731     0.3253      0.73     -88     1
# Comp:  2              HeII4687      0.000      0.73     -88     1
# Comp:  2               HeI5876     0.6379      0.73     -88     1
# Comp:  2          [OIII]5007_d     0.8855      0.92     -88     1
# Comp:  2            [OI]6300_d    0.09166      0.92     -88     1
# Comp:  2           [NII]6583_d     0.4796      0.92     -88     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        88
#  comp.  1:       -27       246
#  comp.  2:       -26        75
# chi2/DOF: 1.264; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      15.16       1.4     -27   246
# Comp:  1                 Hbeta      10.25       1.4     -27   246
# Comp:  1                Halpha      2.965       1.4     -27   246
# Comp:  2             [SII]6716      0.000      0.90     -26    75
# Comp:  2             [SII]6731      0.000      0.90     -26    75
# Comp:  2              HeII4687      0.000      0.90     -26    75
# Comp:  2               HeI5876     0.8508      0.90     -26    75
# Comp:  2          [OIII]5007_d      1.790       1.1     -26    75
# Comp:  2            [OI]6300_d     0.4213       1.1     -26    75
# Comp:  2           [NII]6583_d      1.077       1.1     -26    75
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -155       201
#  comp.  1:      -149       390
#  comp.  2:         2       147
# chi2/DOF: 1.257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.67       1.8    -149   390
# Comp:  1                 Hbeta      17.68       1.8    -149   390
# Comp:  1                Halpha      6.916       1.8    -149   390
# Comp:  2             [SII]6716     0.1117       1.1       2   147
# Comp:  2             [SII]6731      0.000       1.1       2   147
# Comp:  2              HeII4687      0.000       1.1       2   147
# Comp:  2               HeI5876     0.3911       1.1       2   147
# Comp:  2          [OIII]5007_d      2.351       1.4       2   147
# Comp:  2            [OI]6300_d      0.000       1.4       2   147
# Comp:  2           [NII]6583_d      0.000       1.5       2   147
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88        98
#  comp.  1:       -85       232
#  comp.  2:       -65        51
# chi2/DOF: 1.260; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      13.85       1.4     -85   232
# Comp:  1                 Hbeta      11.95       1.4     -85   232
# Comp:  1                Halpha      2.742       1.4     -85   232
# Comp:  2             [SII]6716     0.4970      0.82     -65    51
# Comp:  2             [SII]6731    0.07331      0.82     -65    51
# Comp:  2              HeII4687     0.2753      0.82     -65    51
# Comp:  2               HeI5876     0.5874      0.82     -65    51
# Comp:  2          [OIII]5007_d      1.484       1.0     -65    51
# Comp:  2            [OI]6300_d      0.000       1.0     -65    51
# Comp:  2           [NII]6583_d     0.4351       1.0     -65    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         5        39
#  comp.  1:       -32       225
#  comp.  2:      -172        48
# chi2/DOF: 1.247; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.521       1.4     -32   225
# Comp:  1                 Hbeta      6.023       1.4     -32   225
# Comp:  1                Halpha      1.458       1.4     -32   225
# Comp:  2             [SII]6716      2.570      0.81    -172    48
# Comp:  2             [SII]6731     0.6141      0.81    -172    48
# Comp:  2              HeII4687      0.000      0.81    -172    48
# Comp:  2               HeI5876     0.3731      0.81    -172    48
# Comp:  2          [OIII]5007_d      1.091       1.0    -172    48
# Comp:  2            [OI]6300_d     0.9636       1.0    -172    48
# Comp:  2           [NII]6583_d     0.3341       1.0    -172    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -66         1
#  comp.  1:       -90       160
#  comp.  2:        62       261
# chi2/DOF: 1.259; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.595       1.2     -90   160
# Comp:  1                 Hbeta      6.583       1.2     -90   160
# Comp:  1                Halpha      1.158       1.2     -90   160
# Comp:  2             [SII]6716      2.550       1.5      62   261
# Comp:  2             [SII]6731      2.178       1.5      62   261
# Comp:  2              HeII4687      0.000       1.5      62   261
# Comp:  2               HeI5876     0.9188       1.5      62   261
# Comp:  2          [OIII]5007_d      1.921       1.9      62   261
# Comp:  2            [OI]6300_d      0.000       1.9      62   261
# Comp:  2           [NII]6583_d     0.5306       1.9      62   261
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92         1
#  comp.  1:       -45       175
#  comp.  2:       -37       134
# chi2/DOF: 1.258; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.84       1.2     -45   175
# Comp:  1                 Hbeta      8.035       1.2     -45   175
# Comp:  1                Halpha      2.547       1.2     -45   175
# Comp:  2             [SII]6716    0.03576       1.1     -37   134
# Comp:  2             [SII]6731      0.000       1.1     -37   134
# Comp:  2              HeII4687    0.04482       1.1     -37   134
# Comp:  2               HeI5876     0.8260       1.1     -37   134
# Comp:  2          [OIII]5007_d      1.745       1.4     -37   134
# Comp:  2            [OI]6300_d      0.000       1.4     -37   134
# Comp:  2           [NII]6583_d      1.794       1.4     -37   134
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        82
#  comp.  1:        11       212
#  comp.  2:      -160       138
# chi2/DOF: 1.258; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.99       1.3      11   212
# Comp:  1                 Hbeta      8.056       1.3      11   212
# Comp:  1                Halpha      1.825       1.3      11   212
# Comp:  2             [SII]6716     0.5092       1.1    -160   138
# Comp:  2             [SII]6731      1.430       1.1    -160   138
# Comp:  2              HeII4687      0.000       1.1    -160   138
# Comp:  2               HeI5876      1.104       1.1    -160   138
# Comp:  2          [OIII]5007_d      1.149       1.4    -160   138
# Comp:  2            [OI]6300_d      4.688       1.4    -160   138
# Comp:  2           [NII]6583_d     0.3490       1.4    -160   138
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        72
#  comp.  1:       -53       202
#  comp.  2:       -79         2
# chi2/DOF: 1.252; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      17.64       1.3     -53   202
# Comp:  1                 Hbeta      12.03       1.3     -53   202
# Comp:  1                Halpha      3.045       1.3     -53   202
# Comp:  2             [SII]6716     0.6592      0.73     -79     2
# Comp:  2             [SII]6731      0.000      0.73     -79     2
# Comp:  2              HeII4687     0.7096      0.73     -79     2
# Comp:  2               HeI5876     0.9850      0.73     -79     2
# Comp:  2          [OIII]5007_d     0.5207      0.92     -79     2
# Comp:  2            [OI]6300_d      2.242      0.92     -79     2
# Comp:  2           [NII]6583_d      0.000      0.92     -79     2
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23       199
#  comp.  1:       -29       298
#  comp.  2:      -169        97
# chi2/DOF: 1.257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      23.23       1.6     -29   298
# Comp:  1                 Hbeta      17.79       1.6     -29   298
# Comp:  1                Halpha      4.723       1.6     -29   298
# Comp:  2             [SII]6716      0.000      0.97    -169    97
# Comp:  2             [SII]6731      0.000      0.97    -169    97
# Comp:  2              HeII4687      0.000      0.97    -169    97
# Comp:  2               HeI5876     0.7903      0.97    -169    97
# Comp:  2          [OIII]5007_d      1.890       1.2    -169    97
# Comp:  2            [OI]6300_d      3.842       1.2    -169    97
# Comp:  2           [NII]6583_d      1.461       1.2    -169    97
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        55
#  comp.  1:       -77       234
#  comp.  2:       -83        11
# chi2/DOF: 1.255; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      11.98       1.4     -77   234
# Comp:  1                 Hbeta      8.547       1.4     -77   234
# Comp:  1                Halpha      2.081       1.4     -77   234
# Comp:  2             [SII]6716     0.5071      0.74     -83    11
# Comp:  2             [SII]6731      0.000      0.74     -83    11
# Comp:  2              HeII4687      0.000      0.74     -83    11
# Comp:  2               HeI5876     0.1638      0.74     -83    11
# Comp:  2          [OIII]5007_d      1.395      0.93     -83    11
# Comp:  2            [OI]6300_d      2.483      0.93     -83    11
# Comp:  2           [NII]6583_d      0.000      0.93     -83    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        37
#  comp.  1:      -126       217
#  comp.  2:       -43         1
# chi2/DOF: 1.257; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.053       1.4    -126   217
# Comp:  1                 Hbeta      5.995       1.4    -126   217
# Comp:  1                Halpha      2.547       1.4    -126   217
# Comp:  2             [SII]6716      0.000      0.73     -43     1
# Comp:  2             [SII]6731      0.000      0.73     -43     1
# Comp:  2              HeII4687     0.1750      0.73     -43     1
# Comp:  2               HeI5876     0.6102      0.73     -43     1
# Comp:  2          [OIII]5007_d      2.017      0.92     -43     1
# Comp:  2            [OI]6300_d     0.8277      0.92     -43     1
# Comp:  2           [NII]6583_d     0.4433      0.92     -43     1
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([3.8798606 , 2.96226396, 1.75987396, 2.11651646, 1.65665396,
#        0.7094368 , 0.50631151, 0.85208564, 2.05319701, 1.0989473 ])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([10.17245547,  8.04305072,  3.07319003,  0.        ,  0.        ,
#         0.        ,  0.7635428 ,  1.28709766,  1.93054278,  0.        ])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_2_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_2", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_2_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_2_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_2_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0        Hgamma  0.166694    0.063578
# 1         Hbeta  0.131800    0.048542
# 2        Halpha  0.050360    0.028839
# 3     [SII]6716  0.000000    0.034683
# 4     [SII]6731  0.000000    0.027147
# 5      HeII4687  0.000000    0.011625
# 6       HeI5876  0.012512    0.008297
# 7  [OIII]5007_d  0.021091    0.013963
# 8    [OI]6300_d  0.031635    0.033645
# 9   [NII]6583_d  0.000000    0.018008
#           Name      Flux  Error_flux
# 0       Hgamma  0.166694    0.063578
# 1        Hbeta  0.131800    0.048542
# 2       Halpha  0.050360    0.028839
# 3    [SII]6716  0.000000    0.034683
# 4    [SII]6731  0.000000    0.027147
# 5     HeII4687  0.000000    0.011625
# 6      HeI5876  0.012512    0.008297
# 7   [OIII]4959  0.005273    0.013963
# 8   [OIII]5007  0.015819    0.013963
# 9     [OI]6300  0.023726    0.033645
# 10    [OI]6364  0.007909    0.033645
# 11   [NII]6548  0.000000    0.018008
# 12   [NII]6583  0.000000    0.018008

# %%
np.median(flux_rf_rebin)
# Out:
# 0.01638675568274118
