# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_4.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC5058/FORS2.2022-01-28T08_17_47.181/Spectra_extraction/Gradient/redshift_grad.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_4']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -15         1
# chi2/DOF: 0.04456; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -11         7
# chi2/DOF: 0.02486; DOF: 1873; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-11.26903515,   7.19655657])

# %%
z
# Out:
# 0.03191

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -16         1
#  comp.  1:       -30        44
#  comp.  2:       -99        38
# chi2/DOF: 0.7600; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.2415      0.50     -30    44
# Comp:  1                 Hbeta      1.743      0.50     -30    44
# Comp:  1                Halpha      3.371      0.50     -30    44
# Comp:  2             [SII]6716     0.3801      0.49     -99    38
# Comp:  2             [SII]6731      0.000      0.49     -99    38
# Comp:  2              HeII4687      1.061      0.49     -99    38
# Comp:  2               HeI5876    0.07475      0.49     -99    38
# Comp:  2          [OIII]5007_d      1.966      0.62     -99    38
# Comp:  2            [OI]6300_d     0.9983      0.62     -99    38
# Comp:  2           [NII]6583_d      1.806      0.62     -99    38
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise: 0.4656; gas flux:      0 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  3.162; gas flux:      2 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:   6.35; gas flux:      5 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise: 0.7599; gas flux:      1 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  2.129; gas flux:      1 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise: 0.1494; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  2.909; gas flux:      2 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  1.404; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  2.677; gas flux:      2 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -29         1
#  comp.  1:       -31        28
#  comp.  2:      -107        61
# chi2/DOF: 0.7570; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1696      0.47     -31    28
# Comp:  1                 Hbeta      1.217      0.47     -31    28
# Comp:  1                Halpha      3.008      0.47     -31    28
# Comp:  2             [SII]6716     0.5437      0.53    -107    61
# Comp:  2             [SII]6731    0.09096      0.53    -107    61
# Comp:  2              HeII4687      1.186      0.53    -107    61
# Comp:  2               HeI5876    0.05791      0.53    -107    61
# Comp:  2          [OIII]5007_d      2.382      0.67    -107    61
# Comp:  2            [OI]6300_d      1.159      0.67    -107    61
# Comp:  2           [NII]6583_d      1.997      0.67    -107    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        55
#  comp.  1:       -30        44
#  comp.  2:       -98        40
# chi2/DOF: 0.7542; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8667      0.50     -30    44
# Comp:  1                 Hbeta      1.959      0.50     -30    44
# Comp:  1                Halpha      3.191      0.50     -30    44
# Comp:  2             [SII]6716     0.3842      0.49     -98    40
# Comp:  2             [SII]6731      0.000      0.49     -98    40
# Comp:  2              HeII4687      1.163      0.49     -98    40
# Comp:  2               HeI5876     0.2947      0.49     -98    40
# Comp:  2          [OIII]5007_d      2.471      0.62     -98    40
# Comp:  2            [OI]6300_d     0.8804      0.62     -98    40
# Comp:  2           [NII]6583_d      1.756      0.62     -98    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        31
#  comp.  1:       -30        43
#  comp.  2:       -99        38
# chi2/DOF: 0.7554; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.5345      0.49     -30    43
# Comp:  1                 Hbeta      1.690      0.49     -30    43
# Comp:  1                Halpha      3.332      0.49     -30    43
# Comp:  2             [SII]6716     0.6095      0.49     -99    38
# Comp:  2             [SII]6731      0.000      0.49     -99    38
# Comp:  2              HeII4687      1.138      0.49     -99    38
# Comp:  2               HeI5876     0.1944      0.49     -99    38
# Comp:  2          [OIII]5007_d      1.486      0.61     -99    38
# Comp:  2            [OI]6300_d     0.9214      0.61     -99    38
# Comp:  2           [NII]6583_d      1.536      0.61     -99    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18         1
#  comp.  1:       -29        49
#  comp.  2:       -89        67
# chi2/DOF: 0.7500; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.035      0.51     -29    49
# Comp:  1                 Hbeta      1.984      0.51     -29    49
# Comp:  1                Halpha      3.612      0.51     -29    49
# Comp:  2             [SII]6716     0.3848      0.54     -89    67
# Comp:  2             [SII]6731      0.000      0.54     -89    67
# Comp:  2              HeII4687      1.070      0.54     -89    67
# Comp:  2               HeI5876     0.1111      0.54     -89    67
# Comp:  2          [OIII]5007_d      2.585      0.68     -89    67
# Comp:  2            [OI]6300_d      2.139      0.68     -89    67
# Comp:  2           [NII]6583_d      2.185      0.68     -89    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        26
#  comp.  1:       -28        39
#  comp.  2:      -110        73
# chi2/DOF: 0.7544; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1138      0.49     -28    39
# Comp:  1                 Hbeta      1.548      0.49     -28    39
# Comp:  1                Halpha      3.196      0.49     -28    39
# Comp:  2             [SII]6716     0.6894      0.55    -110    73
# Comp:  2             [SII]6731      0.000      0.55    -110    73
# Comp:  2              HeII4687      1.195      0.55    -110    73
# Comp:  2               HeI5876     0.2588      0.55    -110    73
# Comp:  2          [OIII]5007_d      2.991      0.70    -110    73
# Comp:  2            [OI]6300_d      1.150      0.70    -110    73
# Comp:  2           [NII]6583_d      1.773      0.70    -110    73
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27         1
#  comp.  1:       -31        45
#  comp.  2:      -132        61
# chi2/DOF: 0.7544; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.4803      0.50     -31    45
# Comp:  1                 Hbeta      1.438      0.50     -31    45
# Comp:  1                Halpha      3.333      0.50     -31    45
# Comp:  2             [SII]6716     0.5724      0.53    -132    61
# Comp:  2             [SII]6731      0.000      0.53    -132    61
# Comp:  2              HeII4687     0.9280      0.53    -132    61
# Comp:  2               HeI5876     0.1231      0.53    -132    61
# Comp:  2          [OIII]5007_d      2.070      0.67    -132    61
# Comp:  2            [OI]6300_d      1.121      0.67    -132    61
# Comp:  2           [NII]6583_d      1.654      0.67    -132    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        63
#  comp.  1:       -29        57
#  comp.  2:       -97        25
# chi2/DOF: 0.7547; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.5699      0.52     -29    57
# Comp:  1                 Hbeta      2.038      0.52     -29    57
# Comp:  1                Halpha      3.568      0.52     -29    57
# Comp:  2             [SII]6716     0.2421      0.47     -97    25
# Comp:  2             [SII]6731     0.1475      0.47     -97    25
# Comp:  2              HeII4687      1.229      0.47     -97    25
# Comp:  2               HeI5876     0.2826      0.47     -97    25
# Comp:  2          [OIII]5007_d      1.741      0.59     -97    25
# Comp:  2            [OI]6300_d     0.7955      0.59     -97    25
# Comp:  2           [NII]6583_d      1.687      0.59     -97    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        43
#  comp.  1:       -30        44
#  comp.  2:       -98        37
# chi2/DOF: 0.7562; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 1; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.5892      0.50     -30    44
# Comp:  1                 Hbeta      1.620      0.50     -30    44
# Comp:  1                Halpha      3.498      0.50     -30    44
# Comp:  2             [SII]6716     0.1786      0.49     -98    37
# Comp:  2             [SII]6731      0.000      0.49     -98    37
# Comp:  2              HeII4687      1.060      0.49     -98    37
# Comp:  2               HeI5876    0.06010      0.49     -98    37
# Comp:  2          [OIII]5007_d      2.029      0.61     -98    37
# Comp:  2            [OI]6300_d     0.7624      0.61     -98    37
# Comp:  2           [NII]6583_d      1.891      0.61     -98    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       -31        41
#  comp.  2:      -109        71
# chi2/DOF: 0.7554; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.49     -31    41
# Comp:  1                 Hbeta      1.546      0.49     -31    41
# Comp:  1                Halpha      3.373      0.49     -31    41
# Comp:  2             [SII]6716     0.6815      0.55    -109    71
# Comp:  2             [SII]6731      0.000      0.55    -109    71
# Comp:  2              HeII4687      1.191      0.55    -109    71
# Comp:  2               HeI5876     0.2131      0.55    -109    71
# Comp:  2          [OIII]5007_d      1.643      0.69    -109    71
# Comp:  2            [OI]6300_d      1.610      0.69    -109    71
# Comp:  2           [NII]6583_d      2.577      0.69    -109    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12         1
#  comp.  1:       -28        53
#  comp.  2:      -120        89
# chi2/DOF: 0.7538; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8608      0.51     -28    53
# Comp:  1                 Hbeta      2.395      0.51     -28    53
# Comp:  1                Halpha      3.765      0.51     -28    53
# Comp:  2             [SII]6716     0.4604      0.59    -120    89
# Comp:  2             [SII]6731      0.000      0.59    -120    89
# Comp:  2              HeII4687      1.236      0.59    -120    89
# Comp:  2               HeI5876     0.1899      0.59    -120    89
# Comp:  2          [OIII]5007_d      2.932      0.74    -120    89
# Comp:  2            [OI]6300_d      2.144      0.74    -120    89
# Comp:  2           [NII]6583_d      2.322      0.74    -120    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        91
#  comp.  1:       -40        52
#  comp.  2:       -96        68
# chi2/DOF: 0.7525; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.51     -40    52
# Comp:  1                 Hbeta      1.559      0.51     -40    52
# Comp:  1                Halpha      3.148      0.51     -40    52
# Comp:  2             [SII]6716     0.4287      0.54     -96    68
# Comp:  2             [SII]6731     0.1539      0.54     -96    68
# Comp:  2              HeII4687     0.9306      0.54     -96    68
# Comp:  2               HeI5876     0.1689      0.54     -96    68
# Comp:  2          [OIII]5007_d      2.289      0.69     -96    68
# Comp:  2            [OI]6300_d      1.210      0.69     -96    68
# Comp:  2           [NII]6583_d      2.003      0.69     -96    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        13
#  comp.  1:       -40        55
#  comp.  2:      -102        72
# chi2/DOF: 0.7530; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3349      0.52     -40    55
# Comp:  1                 Hbeta      1.984      0.52     -40    55
# Comp:  1                Halpha      3.304      0.52     -40    55
# Comp:  2             [SII]6716     0.1934      0.55    -102    72
# Comp:  2             [SII]6731      0.000      0.55    -102    72
# Comp:  2              HeII4687      1.227      0.55    -102    72
# Comp:  2               HeI5876     0.1465      0.55    -102    72
# Comp:  2          [OIII]5007_d      2.872      0.69    -102    72
# Comp:  2            [OI]6300_d     0.5297      0.69    -102    72
# Comp:  2           [NII]6583_d      2.380      0.69    -102    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17         1
#  comp.  1:       -25        48
#  comp.  2:       -95        57
# chi2/DOF: 0.7544; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.5305      0.50     -25    48
# Comp:  1                 Hbeta      1.871      0.50     -25    48
# Comp:  1                Halpha      3.285      0.50     -25    48
# Comp:  2             [SII]6716     0.3359      0.52     -95    57
# Comp:  2             [SII]6731     0.2594      0.52     -95    57
# Comp:  2              HeII4687      1.119      0.52     -95    57
# Comp:  2               HeI5876     0.1159      0.52     -95    57
# Comp:  2          [OIII]5007_d      1.580      0.66     -95    57
# Comp:  2            [OI]6300_d      1.156      0.66     -95    57
# Comp:  2           [NII]6583_d      2.240      0.66     -95    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0         1
#  comp.  1:       -25        55
#  comp.  2:       -91        48
# chi2/DOF: 0.7552; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1720      0.52     -25    55
# Comp:  1                 Hbeta      1.516      0.52     -25    55
# Comp:  1                Halpha      3.683      0.52     -25    55
# Comp:  2             [SII]6716     0.2609      0.50     -91    48
# Comp:  2             [SII]6731      0.000      0.50     -91    48
# Comp:  2              HeII4687      1.221      0.50     -91    48
# Comp:  2               HeI5876    0.01713      0.50     -91    48
# Comp:  2          [OIII]5007_d      1.668      0.63     -91    48
# Comp:  2            [OI]6300_d     0.7461      0.63     -91    48
# Comp:  2           [NII]6583_d      1.980      0.63     -91    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26         1
#  comp.  1:       -33        29
#  comp.  2:       -90        41
# chi2/DOF: 0.7560; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1819      0.47     -33    29
# Comp:  1                 Hbeta      1.550      0.47     -33    29
# Comp:  1                Halpha      3.050      0.47     -33    29
# Comp:  2             [SII]6716     0.3123      0.49     -90    41
# Comp:  2             [SII]6731     0.2306      0.49     -90    41
# Comp:  2              HeII4687      1.006      0.49     -90    41
# Comp:  2               HeI5876    0.02663      0.49     -90    41
# Comp:  2          [OIII]5007_d      2.166      0.62     -90    41
# Comp:  2            [OI]6300_d     0.6052      0.62     -90    41
# Comp:  2           [NII]6583_d      1.378      0.62     -90    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       -24        48
#  comp.  2:      -106        59
# chi2/DOF: 0.7551; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3418      0.50     -24    48
# Comp:  1                 Hbeta      1.303      0.50     -24    48
# Comp:  1                Halpha      3.395      0.50     -24    48
# Comp:  2             [SII]6716     0.8063      0.52    -106    59
# Comp:  2             [SII]6731     0.5051      0.52    -106    59
# Comp:  2              HeII4687      1.173      0.52    -106    59
# Comp:  2               HeI5876    0.07771      0.52    -106    59
# Comp:  2          [OIII]5007_d      1.516      0.66    -106    59
# Comp:  2            [OI]6300_d      1.536      0.66    -106    59
# Comp:  2           [NII]6583_d      1.996      0.66    -106    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24         1
#  comp.  1:       -28        27
#  comp.  2:      -101        35
# chi2/DOF: 0.7556; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6406      0.47     -28    27
# Comp:  1                 Hbeta      1.720      0.47     -28    27
# Comp:  1                Halpha      3.368      0.47     -28    27
# Comp:  2             [SII]6716     0.6243      0.48    -101    35
# Comp:  2             [SII]6731      0.000      0.48    -101    35
# Comp:  2              HeII4687      1.077      0.48    -101    35
# Comp:  2               HeI5876    0.04890      0.48    -101    35
# Comp:  2          [OIII]5007_d      1.789      0.61    -101    35
# Comp:  2            [OI]6300_d     0.8381      0.61    -101    35
# Comp:  2           [NII]6583_d      2.182      0.61    -101    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28         1
#  comp.  1:       -29        46
#  comp.  2:       -84         1
# chi2/DOF: 0.7563; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.50     -29    46
# Comp:  1                 Hbeta      1.323      0.50     -29    46
# Comp:  1                Halpha      3.350      0.50     -29    46
# Comp:  2             [SII]6716     0.4541      0.45     -84     1
# Comp:  2             [SII]6731      0.000      0.45     -84     1
# Comp:  2              HeII4687      1.089      0.45     -84     1
# Comp:  2               HeI5876     0.1467      0.45     -84     1
# Comp:  2          [OIII]5007_d      2.034      0.57     -84     1
# Comp:  2            [OI]6300_d      1.223      0.57     -84     1
# Comp:  2           [NII]6583_d      1.530      0.57     -84     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         5         1
#  comp.  1:       -19        46
#  comp.  2:      -106         1
# chi2/DOF: 0.7558; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.5591      0.50     -19    46
# Comp:  1                 Hbeta      1.970      0.50     -19    46
# Comp:  1                Halpha      3.387      0.50     -19    46
# Comp:  2             [SII]6716     0.1246      0.45    -106     1
# Comp:  2             [SII]6731    0.09791      0.45    -106     1
# Comp:  2              HeII4687     0.9573      0.45    -106     1
# Comp:  2               HeI5876     0.1385      0.45    -106     1
# Comp:  2          [OIII]5007_d      1.417      0.57    -106     1
# Comp:  2            [OI]6300_d     0.6344      0.57    -106     1
# Comp:  2           [NII]6583_d      1.732      0.57    -106     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        56
#  comp.  1:       -31        47
#  comp.  2:      -111        52
# chi2/DOF: 0.7531; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3628      0.50     -31    47
# Comp:  1                 Hbeta      2.127      0.50     -31    47
# Comp:  1                Halpha      3.522      0.50     -31    47
# Comp:  2             [SII]6716     0.4536      0.51    -111    52
# Comp:  2             [SII]6731     0.1658      0.51    -111    52
# Comp:  2              HeII4687      1.094      0.51    -111    52
# Comp:  2               HeI5876    0.07244      0.51    -111    52
# Comp:  2          [OIII]5007_d      2.021      0.64    -111    52
# Comp:  2            [OI]6300_d      1.001      0.64    -111    52
# Comp:  2           [NII]6583_d      2.283      0.64    -111    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        18
#  comp.  1:       -35        41
#  comp.  2:       -90        41
# chi2/DOF: 0.7574; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 27; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.49     -35    41
# Comp:  1                 Hbeta      1.387      0.49     -35    41
# Comp:  1                Halpha      3.066      0.49     -35    41
# Comp:  2             [SII]6716     0.4793      0.49     -90    41
# Comp:  2             [SII]6731      0.000      0.49     -90    41
# Comp:  2              HeII4687      1.099      0.49     -90    41
# Comp:  2               HeI5876      0.000      0.49     -90    41
# Comp:  2          [OIII]5007_d      1.731      0.62     -90    41
# Comp:  2            [OI]6300_d     0.6427      0.62     -90    41
# Comp:  2           [NII]6583_d      2.319      0.62     -90    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16         1
#  comp.  1:       -28        31
#  comp.  2:      -123        44
# chi2/DOF: 0.7557; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1829      0.48     -28    31
# Comp:  1                 Hbeta      1.278      0.48     -28    31
# Comp:  1                Halpha      3.220      0.48     -28    31
# Comp:  2             [SII]6716     0.3840      0.50    -123    44
# Comp:  2             [SII]6731    0.03068      0.50    -123    44
# Comp:  2              HeII4687      1.046      0.50    -123    44
# Comp:  2               HeI5876     0.1136      0.50    -123    44
# Comp:  2          [OIII]5007_d      1.977      0.63    -123    44
# Comp:  2            [OI]6300_d      1.458      0.63    -123    44
# Comp:  2           [NII]6583_d      1.998      0.63    -123    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        52
#  comp.  1:       -30        45
#  comp.  2:       -99        38
# chi2/DOF: 0.7541; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1462      0.50     -30    45
# Comp:  1                 Hbeta      1.406      0.50     -30    45
# Comp:  1                Halpha      3.216      0.50     -30    45
# Comp:  2             [SII]6716     0.2163      0.49     -99    38
# Comp:  2             [SII]6731     0.1160      0.49     -99    38
# Comp:  2              HeII4687      1.148      0.49     -99    38
# Comp:  2               HeI5876      0.000      0.49     -99    38
# Comp:  2          [OIII]5007_d      1.465      0.61     -99    38
# Comp:  2            [OI]6300_d     0.6377      0.61     -99    38
# Comp:  2           [NII]6583_d      2.444      0.61     -99    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        50
#  comp.  1:       -35        46
#  comp.  2:      -100        63
# chi2/DOF: 0.7554; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1231      0.50     -35    46
# Comp:  1                 Hbeta      2.101      0.50     -35    46
# Comp:  1                Halpha      3.506      0.50     -35    46
# Comp:  2             [SII]6716     0.5137      0.53    -100    63
# Comp:  2             [SII]6731    0.08901      0.53    -100    63
# Comp:  2              HeII4687      1.173      0.53    -100    63
# Comp:  2               HeI5876  0.0006748      0.53    -100    63
# Comp:  2          [OIII]5007_d      2.755      0.67    -100    63
# Comp:  2            [OI]6300_d     0.4338      0.67    -100    63
# Comp:  2           [NII]6583_d      2.624      0.67    -100    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        76
#  comp.  1:       -25        50
#  comp.  2:      -125        41
# chi2/DOF: 0.7508; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9481      0.51     -25    50
# Comp:  1                 Hbeta      2.003      0.51     -25    50
# Comp:  1                Halpha      3.346      0.51     -25    50
# Comp:  2             [SII]6716      0.000      0.49    -125    41
# Comp:  2             [SII]6731     0.1875      0.49    -125    41
# Comp:  2              HeII4687     0.9668      0.49    -125    41
# Comp:  2               HeI5876     0.3658      0.49    -125    41
# Comp:  2          [OIII]5007_d      2.036      0.62    -125    41
# Comp:  2            [OI]6300_d      1.042      0.62    -125    41
# Comp:  2           [NII]6583_d      2.018      0.62    -125    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32         1
#  comp.  1:       -38        45
#  comp.  2:      -110        27
# chi2/DOF: 0.7560; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1933      0.50     -38    45
# Comp:  1                 Hbeta      1.730      0.50     -38    45
# Comp:  1                Halpha      3.377      0.50     -38    45
# Comp:  2             [SII]6716     0.6530      0.47    -110    27
# Comp:  2             [SII]6731     0.2027      0.47    -110    27
# Comp:  2              HeII4687     0.9126      0.47    -110    27
# Comp:  2               HeI5876      0.000      0.47    -110    27
# Comp:  2          [OIII]5007_d      1.747      0.60    -110    27
# Comp:  2            [OI]6300_d      1.112      0.60    -110    27
# Comp:  2           [NII]6583_d      2.314      0.60    -110    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2         1
#  comp.  1:       -23        61
#  comp.  2:      -124        40
# chi2/DOF: 0.7557; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9691      0.53     -23    61
# Comp:  1                 Hbeta      2.180      0.53     -23    61
# Comp:  1                Halpha      3.928      0.53     -23    61
# Comp:  2             [SII]6716     0.1629      0.49    -124    40
# Comp:  2             [SII]6731      0.000      0.49    -124    40
# Comp:  2              HeII4687      1.085      0.49    -124    40
# Comp:  2               HeI5876     0.1584      0.49    -124    40
# Comp:  2          [OIII]5007_d      2.057      0.62    -124    40
# Comp:  2            [OI]6300_d      1.538      0.62    -124    40
# Comp:  2           [NII]6583_d      1.759      0.62    -124    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        31
#  comp.  1:       -35        67
#  comp.  2:       -96        65
# chi2/DOF: 0.7544; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6859      0.54     -35    67
# Comp:  1                 Hbeta      2.172      0.54     -35    67
# Comp:  1                Halpha      3.860      0.54     -35    67
# Comp:  2             [SII]6716     0.3190      0.54     -96    65
# Comp:  2             [SII]6731      0.000      0.54     -96    65
# Comp:  2              HeII4687      1.239      0.54     -96    65
# Comp:  2               HeI5876      0.000      0.54     -96    65
# Comp:  2          [OIII]5007_d      2.770      0.68     -96    65
# Comp:  2            [OI]6300_d      1.160      0.68     -96    65
# Comp:  2           [NII]6583_d      2.790      0.68     -96    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9         1
#  comp.  1:       -22        46
#  comp.  2:       -77        23
# chi2/DOF: 0.7544; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9231      0.50     -22    46
# Comp:  1                 Hbeta      1.914      0.50     -22    46
# Comp:  1                Halpha      3.426      0.50     -22    46
# Comp:  2             [SII]6716     0.1069      0.47     -77    23
# Comp:  2             [SII]6731     0.1579      0.47     -77    23
# Comp:  2              HeII4687      1.136      0.47     -77    23
# Comp:  2               HeI5876    0.02800      0.47     -77    23
# Comp:  2          [OIII]5007_d      2.061      0.59     -77    23
# Comp:  2            [OI]6300_d     0.4436      0.59     -77    23
# Comp:  2           [NII]6583_d      1.782      0.59     -77    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12         1
#  comp.  1:       -27        54
#  comp.  2:      -108         1
# chi2/DOF: 0.7550; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6542      0.52     -27    54
# Comp:  1                 Hbeta      2.239      0.52     -27    54
# Comp:  1                Halpha      3.634      0.52     -27    54
# Comp:  2             [SII]6716     0.3893      0.45    -108     1
# Comp:  2             [SII]6731     0.2330      0.45    -108     1
# Comp:  2              HeII4687      1.092      0.45    -108     1
# Comp:  2               HeI5876     0.1425      0.45    -108     1
# Comp:  2          [OIII]5007_d      1.910      0.57    -108     1
# Comp:  2            [OI]6300_d     0.9150      0.57    -108     1
# Comp:  2           [NII]6583_d      1.654      0.57    -108     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        62
#  comp.  1:       -26        43
#  comp.  2:      -121        68
# chi2/DOF: 0.7556; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1885      0.49     -26    43
# Comp:  1                 Hbeta      1.871      0.49     -26    43
# Comp:  1                Halpha      3.416      0.49     -26    43
# Comp:  2             [SII]6716     0.4636      0.54    -121    68
# Comp:  2             [SII]6731      0.000      0.54    -121    68
# Comp:  2              HeII4687      1.224      0.54    -121    68
# Comp:  2               HeI5876      0.000      0.54    -121    68
# Comp:  2          [OIII]5007_d      2.460      0.68    -121    68
# Comp:  2            [OI]6300_d      1.205      0.68    -121    68
# Comp:  2           [NII]6583_d      1.781      0.68    -121    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8         1
#  comp.  1:       -28        44
#  comp.  2:       -99        46
# chi2/DOF: 0.7556; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1307      0.50     -28    44
# Comp:  1                 Hbeta      1.807      0.50     -28    44
# Comp:  1                Halpha      3.099      0.50     -28    44
# Comp:  2             [SII]6716     0.4528      0.50     -99    46
# Comp:  2             [SII]6731   0.009286      0.50     -99    46
# Comp:  2              HeII4687      1.036      0.50     -99    46
# Comp:  2               HeI5876    0.01324      0.50     -99    46
# Comp:  2          [OIII]5007_d      1.971      0.63     -99    46
# Comp:  2            [OI]6300_d      1.440      0.63     -99    46
# Comp:  2           [NII]6583_d      2.102      0.63     -99    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        62
#  comp.  1:       -30        43
#  comp.  2:      -100        40
# chi2/DOF: 0.7529; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6075      0.49     -30    43
# Comp:  1                 Hbeta      1.516      0.49     -30    43
# Comp:  1                Halpha      3.219      0.49     -30    43
# Comp:  2             [SII]6716     0.2879      0.49    -100    40
# Comp:  2             [SII]6731     0.2110      0.49    -100    40
# Comp:  2              HeII4687      1.107      0.49    -100    40
# Comp:  2               HeI5876    0.08431      0.49    -100    40
# Comp:  2          [OIII]5007_d      2.104      0.62    -100    40
# Comp:  2            [OI]6300_d     0.6267      0.62    -100    40
# Comp:  2           [NII]6583_d      1.917      0.62    -100    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        24
#  comp.  1:       -29        43
#  comp.  2:       -99        38
# chi2/DOF: 0.7556; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3470      0.50     -29    43
# Comp:  1                 Hbeta      1.699      0.50     -29    43
# Comp:  1                Halpha      3.354      0.50     -29    43
# Comp:  2             [SII]6716     0.5603      0.49     -99    38
# Comp:  2             [SII]6731      0.000      0.49     -99    38
# Comp:  2              HeII4687     0.9908      0.49     -99    38
# Comp:  2               HeI5876     0.1125      0.49     -99    38
# Comp:  2          [OIII]5007_d      2.123      0.61     -99    38
# Comp:  2            [OI]6300_d      1.103      0.61     -99    38
# Comp:  2           [NII]6583_d      1.437      0.61     -99    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       -24        48
#  comp.  2:      -132         1
# chi2/DOF: 0.7550; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma   0.006745      0.50     -24    48
# Comp:  1                 Hbeta      1.446      0.50     -24    48
# Comp:  1                Halpha      3.189      0.50     -24    48
# Comp:  2             [SII]6716     0.2511      0.45    -132     1
# Comp:  2             [SII]6731      0.000      0.45    -132     1
# Comp:  2              HeII4687     0.8272      0.45    -132     1
# Comp:  2               HeI5876     0.2014      0.45    -132     1
# Comp:  2          [OIII]5007_d      1.645      0.57    -132     1
# Comp:  2            [OI]6300_d      1.349      0.57    -132     1
# Comp:  2           [NII]6583_d      1.650      0.57    -132     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -69         1
#  comp.  1:       -46        55
#  comp.  2:      -129        90
# chi2/DOF: 0.7496; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7194      0.52     -46    55
# Comp:  1                 Hbeta      1.782      0.52     -46    55
# Comp:  1                Halpha      3.503      0.52     -46    55
# Comp:  2             [SII]6716      0.000      0.59    -129    90
# Comp:  2             [SII]6731      0.000      0.59    -129    90
# Comp:  2              HeII4687      1.341      0.59    -129    90
# Comp:  2               HeI5876    0.01248      0.59    -129    90
# Comp:  2          [OIII]5007_d      2.839      0.74    -129    90
# Comp:  2            [OI]6300_d      1.977      0.74    -129    90
# Comp:  2           [NII]6583_d      1.745      0.74    -129    90
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34         1
#  comp.  1:       -36        49
#  comp.  2:       -88        22
# chi2/DOF: 0.7534; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.4452      0.50     -36    49
# Comp:  1                 Hbeta      1.580      0.50     -36    49
# Comp:  1                Halpha      3.255      0.50     -36    49
# Comp:  2             [SII]6716     0.7152      0.47     -88    22
# Comp:  2             [SII]6731     0.3279      0.47     -88    22
# Comp:  2              HeII4687      1.073      0.47     -88    22
# Comp:  2               HeI5876    0.03929      0.47     -88    22
# Comp:  2          [OIII]5007_d      1.402      0.59     -88    22
# Comp:  2            [OI]6300_d     0.8389      0.59     -88    22
# Comp:  2           [NII]6583_d      2.016      0.59     -88    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       -27        26
#  comp.  2:      -111        44
# chi2/DOF: 0.7541; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3736      0.47     -27    26
# Comp:  1                 Hbeta      1.595      0.47     -27    26
# Comp:  1                Halpha      3.098      0.47     -27    26
# Comp:  2             [SII]6716     0.1536      0.50    -111    44
# Comp:  2             [SII]6731    0.03131      0.50    -111    44
# Comp:  2              HeII4687     0.9734      0.50    -111    44
# Comp:  2               HeI5876     0.2953      0.50    -111    44
# Comp:  2          [OIII]5007_d      2.036      0.63    -111    44
# Comp:  2            [OI]6300_d     0.7782      0.63    -111    44
# Comp:  2           [NII]6583_d      2.125      0.63    -111    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:       -23        38
#  comp.  2:       -83        57
# chi2/DOF: 0.7542; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.4229      0.49     -23    38
# Comp:  1                 Hbeta      1.605      0.49     -23    38
# Comp:  1                Halpha      3.249      0.49     -23    38
# Comp:  2             [SII]6716     0.3026      0.52     -83    57
# Comp:  2             [SII]6731      0.000      0.52     -83    57
# Comp:  2              HeII4687      1.325      0.52     -83    57
# Comp:  2               HeI5876     0.1057      0.52     -83    57
# Comp:  2          [OIII]5007_d      1.459      0.66     -83    57
# Comp:  2            [OI]6300_d      1.155      0.66     -83    57
# Comp:  2           [NII]6583_d      2.120      0.66     -83    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        57
#  comp.  1:       -23        49
#  comp.  2:      -117        80
# chi2/DOF: 0.7550; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# Comp:  2           [NII]6583_d      2.169      0.64    -103    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55         1
#  comp.  1:       -33        33
#  comp.  2:      -102        69
# chi2/DOF: 0.7521; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.48     -33    33
# Comp:  1                 Hbeta      1.601      0.48     -33    33
# Comp:  1                Halpha      3.241      0.48     -33    33
# Comp:  2             [SII]6716     0.3460      0.54    -102    69
# Comp:  2             [SII]6731      0.000      0.54    -102    69
# Comp:  2              HeII4687      1.242      0.54    -102    69
# Comp:  2               HeI5876     0.3060      0.54    -102    69
# Comp:  2          [OIII]5007_d      2.206      0.69    -102    69
# Comp:  2            [OI]6300_d      1.219      0.69    -102    69
# Comp:  2           [NII]6583_d      1.785      0.69    -102    69
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:       -33        51
#  comp.  2:       -75        32
# chi2/DOF: 0.7543; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.4768      0.51     -33    51
# Comp:  1                 Hbeta      2.280      0.51     -33    51
# Comp:  1                Halpha      3.718      0.51     -33    51
# Comp:  2             [SII]6716     0.5806      0.48     -75    32
# Comp:  2             [SII]6731     0.2588      0.48     -75    32
# Comp:  2              HeII4687     0.9176      0.48     -75    32
# Comp:  2               HeI5876      0.000      0.48     -75    32
# Comp:  2          [OIII]5007_d      2.171      0.60     -75    32
# Comp:  2            [OI]6300_d      1.105      0.60     -75    32
# Comp:  2           [NII]6583_d      1.178      0.60     -75    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10         1
#  comp.  1:       -29        53
#  comp.  2:       -89        57
# chi2/DOF: 0.7550; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.027      0.51     -29    53
# Comp:  1                 Hbeta      2.625      0.51     -29    53
# Comp:  1                Halpha      3.579      0.51     -29    53
# Comp:  2             [SII]6716     0.4086      0.52     -89    57
# Comp:  2             [SII]6731     0.1672      0.52     -89    57
# Comp:  2              HeII4687      1.213      0.52     -89    57
# Comp:  2               HeI5876      0.000      0.52     -89    57
# Comp:  2          [OIII]5007_d      1.884      0.66     -89    57
# Comp:  2            [OI]6300_d     0.9660      0.66     -89    57
# Comp:  2           [NII]6583_d      2.057      0.66     -89    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4         1
#  comp.  1:       -24        50
#  comp.  2:      -122        66
# chi2/DOF: 0.7551; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.122      0.51     -24    50
# Comp:  1                 Hbeta      2.338      0.51     -24    50
# Comp:  1                Halpha      3.848      0.51     -24    50
# Comp:  2             [SII]6716     0.6967      0.54    -122    66
# Comp:  2             [SII]6731      0.000      0.54    -122    66
# Comp:  2              HeII4687      1.103      0.54    -122    66
# Comp:  2               HeI5876     0.2495      0.54    -122    66
# Comp:  2          [OIII]5007_d      2.141      0.68    -122    66
# Comp:  2            [OI]6300_d     0.9724      0.68    -122    66
# Comp:  2           [NII]6583_d      1.505      0.68    -122    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:       -24        48
#  comp.  2:       -84        38
# chi2/DOF: 0.7570; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 18; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.2166      0.50     -24    48
# Comp:  1                 Hbeta      1.671      0.50     -24    48
# Comp:  1                Halpha      3.334      0.50     -24    48
# Comp:  2             [SII]6716     0.5798      0.49     -84    38
# Comp:  2             [SII]6731      0.000      0.49     -84    38
# Comp:  2              HeII4687     0.9366      0.49     -84    38
# Comp:  2               HeI5876    0.04671      0.49     -84    38
# Comp:  2          [OIII]5007_d      1.570      0.61     -84    38
# Comp:  2            [OI]6300_d     0.7286      0.61     -84    38
# Comp:  2           [NII]6583_d      1.629      0.61     -84    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18       132
#  comp.  1:       -30        44
#  comp.  2:       -99        41
# chi2/DOF: 0.7548; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma    0.05314      0.50     -30    44
# Comp:  1                 Hbeta      1.327      0.50     -30    44
# Comp:  1                Halpha      3.183      0.50     -30    44
# Comp:  2             [SII]6716     0.4736      0.49     -99    41
# Comp:  2             [SII]6731     0.2887      0.49     -99    41
# Comp:  2              HeII4687      1.101      0.49     -99    41
# Comp:  2               HeI5876      0.000      0.49     -99    41
# Comp:  2          [OIII]5007_d      2.277      0.62     -99    41
# Comp:  2            [OI]6300_d     0.7267      0.62     -99    41
# Comp:  2           [NII]6583_d      1.890      0.62     -99    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:       -30        38
#  comp.  2:       -99        54
# chi2/DOF: 0.7536; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.49     -30    38
# Comp:  1                 Hbeta      1.457      0.49     -30    38
# Comp:  1                Halpha      3.120      0.49     -30    38
# Comp:  2             [SII]6716     0.7083      0.51     -99    54
# Comp:  2             [SII]6731      0.000      0.51     -99    54
# Comp:  2              HeII4687      1.309      0.51     -99    54
# Comp:  2               HeI5876    0.04138      0.51     -99    54
# Comp:  2          [OIII]5007_d      1.708      0.65     -99    54
# Comp:  2            [OI]6300_d     0.8619      0.65     -99    54
# Comp:  2           [NII]6583_d      2.595      0.65     -99    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        50
#  comp.  1:       -30        43
#  comp.  2:       -99        39
# chi2/DOF: 0.7524; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.50     -30    43
# Comp:  1                 Hbeta      1.569      0.50     -30    43
# Comp:  1                Halpha      3.104      0.50     -30    43
# Comp:  2             [SII]6716     0.2909      0.49     -99    39
# Comp:  2             [SII]6731     0.2460      0.49     -99    39
# Comp:  2              HeII4687      1.191      0.49     -99    39
# Comp:  2               HeI5876      0.000      0.49     -99    39
# Comp:  2          [OIII]5007_d      2.209      0.62     -99    39
# Comp:  2            [OI]6300_d      1.597      0.62     -99    39
# Comp:  2           [NII]6583_d      2.119      0.62     -99    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        18
#  comp.  1:       -33        24
#  comp.  2:       -97        45
# chi2/DOF: 0.7535; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3015      0.47     -33    24
# Comp:  1                 Hbeta      1.471      0.47     -33    24
# Comp:  1                Halpha      2.887      0.47     -33    24
# Comp:  2             [SII]6716     0.7383      0.50     -97    45
# Comp:  2             [SII]6731     0.2228      0.50     -97    45
# Comp:  2              HeII4687      1.147      0.50     -97    45
# Comp:  2               HeI5876      0.000      0.50     -97    45
# Comp:  2          [OIII]5007_d      2.469      0.63     -97    45
# Comp:  2            [OI]6300_d     0.9843      0.63     -97    45
# Comp:  2           [NII]6583_d      2.035      0.63     -97    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        63
#  comp.  1:       -46        60
#  comp.  2:      -101        33
# chi2/DOF: 0.7543; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3595      0.53     -46    60
# Comp:  1                 Hbeta      1.842      0.53     -46    60
# Comp:  1                Halpha      3.600      0.53     -46    60
# Comp:  2             [SII]6716     0.3378      0.48    -101    33
# Comp:  2             [SII]6731     0.1336      0.48    -101    33
# Comp:  2              HeII4687      1.039      0.48    -101    33
# Comp:  2               HeI5876      0.000      0.48    -101    33
# Comp:  2          [OIII]5007_d      2.223      0.61    -101    33
# Comp:  2            [OI]6300_d      1.270      0.61    -101    33
# Comp:  2           [NII]6583_d      2.118      0.61    -101    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        62
#  comp.  1:       -26        30
#  comp.  2:       -78        60
# chi2/DOF: 0.7555; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma    0.08742      0.48     -26    30
# Comp:  1                 Hbeta      1.595      0.48     -26    30
# Comp:  1                Halpha      3.056      0.48     -26    30
# Comp:  2             [SII]6716      0.000      0.53     -78    60
# Comp:  2             [SII]6731     0.2643      0.53     -78    60
# Comp:  2              HeII4687      1.197      0.53     -78    60
# Comp:  2               HeI5876    0.02977      0.53     -78    60
# Comp:  2          [OIII]5007_d      2.305      0.66     -78    60
# Comp:  2            [OI]6300_d      1.141      0.66     -78    60
# Comp:  2           [NII]6583_d      2.240      0.66     -78    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        13
#  comp.  1:       -30        51
#  comp.  2:       -72         9
# chi2/DOF: 0.7527; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 33; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.4394      0.51     -30    51
# Comp:  1                 Hbeta      1.666      0.51     -30    51
# Comp:  1                Halpha      3.335      0.51     -30    51
# Comp:  2             [SII]6716     0.4897      0.46     -72     9
# Comp:  2             [SII]6731      0.000      0.46     -72     9
# Comp:  2              HeII4687     0.8002      0.46     -72     9
# Comp:  2               HeI5876    0.01494      0.46     -72     9
# Comp:  2          [OIII]5007_d      2.002      0.57     -72     9
# Comp:  2            [OI]6300_d     0.6354      0.57     -72     9
# Comp:  2           [NII]6583_d      1.576      0.57     -72     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        29
#  comp.  1:       -35        48
#  comp.  2:      -128        60
# chi2/DOF: 0.7519; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 31; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3209      0.50     -35    48
# Comp:  1                 Hbeta      1.811      0.50     -35    48
# Comp:  1                Halpha      3.346      0.50     -35    48
# Comp:  2             [SII]6716     0.1063      0.53    -128    60
# Comp:  2             [SII]6731     0.2249      0.53    -128    60
# Comp:  2              HeII4687     0.9709      0.53    -128    60
# Comp:  2               HeI5876    0.07494      0.53    -128    60
# Comp:  2          [OIII]5007_d      2.140      0.66    -128    60
# Comp:  2            [OI]6300_d      1.376      0.66    -128    60
# Comp:  2           [NII]6583_d      1.928      0.66    -128    60
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_4_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_4", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_4_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_4_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_4_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
