# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_10.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_10']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4314.03901503 4315.47324864 4316.90748224 ... 6874.1460011  6875.58023471
#  6877.01446832] [0.61089835 0.61102414 0.66083811 ... 0.57868832 0.5860426  0.58129128] [0.02786157 0.02786157 0.02786157 ... 0.02786157 0.02786157 0.02786157]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        83
# chi2/DOF: 0.0007438; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        80
# chi2/DOF: 0.0004480; DOF: 1875; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-39.25678837,  80.39103   ])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        69
#  comp.  1:       -34        34
#  comp.  2:       -37        48
# chi2/DOF: 0.6907; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.087     0.085     -34    34
# Comp:  1                 Hbeta      7.655     0.085     -34    34
# Comp:  1                Halpha      26.42     0.085     -34    34
# Comp:  2             [SII]6716      4.689     0.089     -37    48
# Comp:  2             [SII]6731      3.687     0.089     -37    48
# Comp:  2              HeII4687      0.000     0.089     -37    48
# Comp:  2               HeI5876     0.6862     0.089     -37    48
# Comp:  2          [OIII]5007_d      2.629      0.11     -37    48
# Comp:  2            [OI]6300_d     0.9274      0.11     -37    48
# Comp:  2           [NII]6583_d      14.54      0.11     -37    48
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:   42.8; gas flux:      3 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  100.8; gas flux:      8 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  360.2; gas flux:     36 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:     59; gas flux:      7 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  44.82; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  8.625; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  24.48; gas flux:      3 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:   8.29; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:    136; gas flux:     20 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        62
#  comp.  1:       -35        32
#  comp.  2:       -37        46
# chi2/DOF: 0.6513; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.087     0.084     -35    32
# Comp:  1                 Hbeta      7.975     0.084     -35    32
# Comp:  1                Halpha      25.79     0.084     -35    32
# Comp:  2             [SII]6716      4.601     0.088     -37    46
# Comp:  2             [SII]6731      3.655     0.088     -37    46
# Comp:  2              HeII4687      0.000     0.088     -37    46
# Comp:  2               HeI5876     0.6720     0.088     -37    46
# Comp:  2          [OIII]5007_d      2.564      0.11     -37    46
# Comp:  2            [OI]6300_d     0.8832      0.11     -37    46
# Comp:  2           [NII]6583_d      14.56      0.11     -37    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        69
#  comp.  1:       -34        29
#  comp.  2:       -36        47
# chi2/DOF: 0.6454; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.172     0.084     -34    29
# Comp:  1                 Hbeta      7.410     0.084     -34    29
# Comp:  1                Halpha      26.42     0.084     -34    29
# Comp:  2             [SII]6716      4.604     0.089     -36    47
# Comp:  2             [SII]6731      3.660     0.089     -36    47
# Comp:  2              HeII4687      0.000     0.089     -36    47
# Comp:  2               HeI5876     0.7641     0.089     -36    47
# Comp:  2          [OIII]5007_d      2.800      0.11     -36    47
# Comp:  2            [OI]6300_d     0.8737      0.11     -36    47
# Comp:  2           [NII]6583_d      14.26      0.11     -36    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        58
#  comp.  1:       -35        35
#  comp.  2:       -37        46
# chi2/DOF: 0.5422; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.950     0.085     -35    35
# Comp:  1                 Hbeta      8.802     0.085     -35    35
# Comp:  1                Halpha      25.72     0.085     -35    35
# Comp:  2             [SII]6716      4.649     0.088     -37    46
# Comp:  2             [SII]6731      3.756     0.088     -37    46
# Comp:  2              HeII4687      0.000     0.088     -37    46
# Comp:  2               HeI5876     0.7366     0.088     -37    46
# Comp:  2          [OIII]5007_d      2.529      0.11     -37    46
# Comp:  2            [OI]6300_d     0.9111      0.11     -37    46
# Comp:  2           [NII]6583_d      14.17      0.11     -37    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2        68
#  comp.  1:       -33        34
#  comp.  2:       -36        49
# chi2/DOF: 0.6294; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.804     0.085     -33    34
# Comp:  1                 Hbeta      6.689     0.085     -33    34
# Comp:  1                Halpha      26.35     0.085     -33    34
# Comp:  2             [SII]6716      4.715     0.089     -36    49
# Comp:  2             [SII]6731      3.746     0.089     -36    49
# Comp:  2              HeII4687      0.000     0.089     -36    49
# Comp:  2               HeI5876     0.6935     0.089     -36    49
# Comp:  2          [OIII]5007_d      2.764      0.11     -36    49
# Comp:  2            [OI]6300_d     0.9292      0.11     -36    49
# Comp:  2           [NII]6583_d      14.51      0.11     -36    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        84
#  comp.  1:       -33        33
#  comp.  2:       -37        50
# chi2/DOF: 0.5618; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.226     0.085     -33    33
# Comp:  1                 Hbeta      8.944     0.085     -33    33
# Comp:  1                Halpha      27.19     0.085     -33    33
# Comp:  2             [SII]6716      4.739     0.090     -37    50
# Comp:  2             [SII]6731      3.691     0.090     -37    50
# Comp:  2              HeII4687    0.03319     0.090     -37    50
# Comp:  2               HeI5876     0.6316     0.090     -37    50
# Comp:  2          [OIII]5007_d      2.891      0.11     -37    50
# Comp:  2            [OI]6300_d     0.9017      0.11     -37    50
# Comp:  2           [NII]6583_d      14.73      0.11     -37    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        69
#  comp.  1:       -32        35
#  comp.  2:       -37        47
# chi2/DOF: 0.6373; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.803     0.085     -32    35
# Comp:  1                 Hbeta      8.035     0.085     -32    35
# Comp:  1                Halpha      26.60     0.085     -32    35
# Comp:  2             [SII]6716      4.670     0.089     -37    47
# Comp:  2             [SII]6731      3.578     0.089     -37    47
# Comp:  2              HeII4687   0.008212     0.089     -37    47
# Comp:  2               HeI5876     0.7372     0.089     -37    47
# Comp:  2          [OIII]5007_d      2.398      0.11     -37    47
# Comp:  2            [OI]6300_d     0.9158      0.11     -37    47
# Comp:  2           [NII]6583_d      14.64      0.11     -37    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        71
#  comp.  1:       -33        34
#  comp.  2:       -38        46
# chi2/DOF: 0.6371; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.186     0.085     -33    34
# Comp:  1                 Hbeta      7.719     0.085     -33    34
# Comp:  1                Halpha      27.15     0.085     -33    34
# Comp:  2             [SII]6716      4.603     0.088     -38    46
# Comp:  2             [SII]6731      3.632     0.088     -38    46
# Comp:  2              HeII4687    0.06270     0.088     -38    46
# Comp:  2               HeI5876     0.7369     0.088     -38    46
# Comp:  2          [OIII]5007_d      2.391      0.11     -38    46
# Comp:  2            [OI]6300_d     0.8450      0.11     -38    46
# Comp:  2           [NII]6583_d      14.30      0.11     -38    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        74
#  comp.  1:       -33        29
#  comp.  2:       -38        50
# chi2/DOF: 0.6291; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.069     0.084     -33    29
# Comp:  1                 Hbeta      8.012     0.084     -33    29
# Comp:  1                Halpha      26.55     0.084     -33    29
# Comp:  2             [SII]6716      4.698     0.090     -38    50
# Comp:  2             [SII]6731      3.601     0.090     -38    50
# Comp:  2              HeII4687      0.000     0.090     -38    50
# Comp:  2               HeI5876     0.7294     0.090     -38    50
# Comp:  2          [OIII]5007_d      2.723      0.11     -38    50
# Comp:  2            [OI]6300_d     0.9843      0.11     -38    50
# Comp:  2           [NII]6583_d      14.73      0.11     -38    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        67
#  comp.  1:       -36        34
#  comp.  2:       -37        48
# chi2/DOF: 0.5434; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.337     0.085     -36    34
# Comp:  1                 Hbeta      9.048     0.085     -36    34
# Comp:  1                Halpha      25.71     0.085     -36    34
# Comp:  2             [SII]6716      4.752     0.089     -37    48
# Comp:  2             [SII]6731      3.621     0.089     -37    48
# Comp:  2              HeII4687    0.06088     0.089     -37    48
# Comp:  2               HeI5876     0.6952     0.089     -37    48
# Comp:  2          [OIII]5007_d      2.503      0.11     -37    48
# Comp:  2            [OI]6300_d     0.9053      0.11     -37    48
# Comp:  2           [NII]6583_d      14.45      0.11     -37    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        66
#  comp.  1:       -35        38
#  comp.  2:       -37        49
# chi2/DOF: 0.6113; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.326     0.086     -35    38
# Comp:  1                 Hbeta      8.774     0.086     -35    38
# Comp:  1                Halpha      26.46     0.086     -35    38
# Comp:  2             [SII]6716      4.694     0.089     -37    49
# Comp:  2             [SII]6731      3.746     0.089     -37    49
# Comp:  2              HeII4687    0.04085     0.089     -37    49
# Comp:  2               HeI5876     0.7071     0.089     -37    49
# Comp:  2          [OIII]5007_d      2.678      0.11     -37    49
# Comp:  2            [OI]6300_d     0.9485      0.11     -37    49
# Comp:  2           [NII]6583_d      14.66      0.11     -37    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        77
#  comp.  1:       -34        31
#  comp.  2:       -37        50
# chi2/DOF: 0.5574; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.284     0.084     -34    31
# Comp:  1                 Hbeta      6.488     0.084     -34    31
# Comp:  1                Halpha      26.90     0.084     -34    31
# Comp:  2             [SII]6716      4.758     0.089     -37    50
# Comp:  2             [SII]6731      3.664     0.089     -37    50
# Comp:  2              HeII4687      0.000     0.089     -37    50
# Comp:  2               HeI5876     0.6827     0.089     -37    50
# Comp:  2          [OIII]5007_d      2.949      0.11     -37    50
# Comp:  2            [OI]6300_d     0.8787      0.11     -37    50
# Comp:  2           [NII]6583_d      14.56      0.11     -37    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        77
#  comp.  1:       -31        35
#  comp.  2:       -38        49
# chi2/DOF: 0.5830; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.540     0.085     -31    35
# Comp:  1                 Hbeta      8.735     0.085     -31    35
# Comp:  1                Halpha      26.82     0.085     -31    35
# Comp:  2             [SII]6716      4.679     0.089     -38    49
# Comp:  2             [SII]6731      3.765     0.089     -38    49
# Comp:  2              HeII4687      0.000     0.089     -38    49
# Comp:  2               HeI5876     0.6842     0.089     -38    49
# Comp:  2          [OIII]5007_d      2.685      0.11     -38    49
# Comp:  2            [OI]6300_d     0.9790      0.11     -38    49
# Comp:  2           [NII]6583_d      14.61      0.11     -38    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        66
#  comp.  1:       -33        38
#  comp.  2:       -37        48
# chi2/DOF: 0.5596; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.299     0.086     -33    38
# Comp:  1                 Hbeta      9.056     0.086     -33    38
# Comp:  1                Halpha      27.19     0.086     -33    38
# Comp:  2             [SII]6716      4.688     0.089     -37    48
# Comp:  2             [SII]6731      3.627     0.089     -37    48
# Comp:  2              HeII4687    0.06230     0.089     -37    48
# Comp:  2               HeI5876     0.6894     0.089     -37    48
# Comp:  2          [OIII]5007_d      2.489      0.11     -37    48
# Comp:  2            [OI]6300_d     0.9023      0.11     -37    48
# Comp:  2           [NII]6583_d      14.47      0.11     -37    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        75
#  comp.  1:       -33        33
#  comp.  2:       -37        50
# chi2/DOF: 0.5836; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.201     0.085     -33    33
# Comp:  1                 Hbeta      6.998     0.085     -33    33
# Comp:  1                Halpha      27.01     0.085     -33    33
# Comp:  2             [SII]6716      4.819     0.089     -37    50
# Comp:  2             [SII]6731      3.836     0.089     -37    50
# Comp:  2              HeII4687    0.03109     0.089     -37    50
# Comp:  2               HeI5876     0.6670     0.089     -37    50
# Comp:  2          [OIII]5007_d      2.540      0.11     -37    50
# Comp:  2            [OI]6300_d     0.9155      0.11     -37    50
# Comp:  2           [NII]6583_d      14.73      0.11     -37    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        59
#  comp.  1:       -34        35
#  comp.  2:       -36        46
# chi2/DOF: 0.5567; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.187     0.085     -34    35
# Comp:  1                 Hbeta      8.851     0.085     -34    35
# Comp:  1                Halpha      27.11     0.085     -34    35
# Comp:  2             [SII]6716      4.636     0.088     -36    46
# Comp:  2             [SII]6731      3.578     0.088     -36    46
# Comp:  2              HeII4687    0.04959     0.088     -36    46
# Comp:  2               HeI5876     0.6975     0.088     -36    46
# Comp:  2          [OIII]5007_d      2.706      0.11     -36    46
# Comp:  2            [OI]6300_d     0.8753      0.11     -36    46
# Comp:  2           [NII]6583_d      14.45      0.11     -36    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        75
#  comp.  1:       -33        36
#  comp.  2:       -37        47
# chi2/DOF: 0.6458; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.392     0.085     -33    36
# Comp:  1                 Hbeta      8.415     0.085     -33    36
# Comp:  1                Halpha      27.20     0.085     -33    36
# Comp:  2             [SII]6716      4.665     0.088     -37    47
# Comp:  2             [SII]6731      3.556     0.088     -37    47
# Comp:  2              HeII4687      0.000     0.088     -37    47
# Comp:  2               HeI5876     0.7881     0.088     -37    47
# Comp:  2          [OIII]5007_d      2.526      0.11     -37    47
# Comp:  2            [OI]6300_d     0.8783      0.11     -37    47
# Comp:  2           [NII]6583_d      14.55      0.11     -37    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        52
#  comp.  1:       -34        32
#  comp.  2:       -36        51
# chi2/DOF: 0.6333; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.900     0.084     -34    32
# Comp:  1                 Hbeta      7.930     0.084     -34    32
# Comp:  1                Halpha      26.86     0.084     -34    32
# Comp:  2             [SII]6716      4.815     0.090     -36    51
# Comp:  2             [SII]6731      3.713     0.090     -36    51
# Comp:  2              HeII4687      0.000     0.090     -36    51
# Comp:  2               HeI5876     0.7163     0.090     -36    51
# Comp:  2          [OIII]5007_d      2.542      0.11     -36    51
# Comp:  2            [OI]6300_d     0.9088      0.11     -36    51
# Comp:  2           [NII]6583_d      14.65      0.11     -36    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        79
#  comp.  1:       -35        39
#  comp.  2:       -37        46
# chi2/DOF: 0.6479; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.545     0.086     -35    39
# Comp:  1                 Hbeta      8.483     0.086     -35    39
# Comp:  1                Halpha      26.72     0.086     -35    39
# Comp:  2             [SII]6716      4.709     0.088     -37    46
# Comp:  2             [SII]6731      3.673     0.088     -37    46
# Comp:  2              HeII4687    0.03315     0.088     -37    46
# Comp:  2               HeI5876     0.7934     0.088     -37    46
# Comp:  2          [OIII]5007_d      2.644      0.11     -37    46
# Comp:  2            [OI]6300_d     0.9153      0.11     -37    46
# Comp:  2           [NII]6583_d      14.55      0.11     -37    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        57
#  comp.  1:       -33        35
#  comp.  2:       -39        48
# chi2/DOF: 0.6628; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.996     0.085     -33    35
# Comp:  1                 Hbeta      7.848     0.085     -33    35
# Comp:  1                Halpha      26.81     0.085     -33    35
# Comp:  2             [SII]6716      4.748     0.089     -39    48
# Comp:  2             [SII]6731      3.566     0.089     -39    48
# Comp:  2              HeII4687      0.000     0.089     -39    48
# Comp:  2               HeI5876     0.7585     0.089     -39    48
# Comp:  2          [OIII]5007_d      2.362      0.11     -39    48
# Comp:  2            [OI]6300_d     0.9230      0.11     -39    48
# Comp:  2           [NII]6583_d      14.65      0.11     -39    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        58
#  comp.  1:       -33        34
#  comp.  2:       -38        48
# chi2/DOF: 0.6143; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.909     0.085     -33    34
# Comp:  1                 Hbeta      8.437     0.085     -33    34
# Comp:  1                Halpha      26.66     0.085     -33    34
# Comp:  2             [SII]6716      4.637     0.089     -38    48
# Comp:  2             [SII]6731      3.601     0.089     -38    48
# Comp:  2              HeII4687   0.007677     0.089     -38    48
# Comp:  2               HeI5876     0.7022     0.089     -38    48
# Comp:  2          [OIII]5007_d      2.297      0.11     -38    48
# Comp:  2            [OI]6300_d     0.9075      0.11     -38    48
# Comp:  2           [NII]6583_d      14.60      0.11     -38    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        78
#  comp.  1:       -34        34
#  comp.  2:       -37        49
# chi2/DOF: 0.5668; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.995     0.085     -34    34
# Comp:  1                 Hbeta      6.490     0.085     -34    34
# Comp:  1                Halpha      27.10     0.085     -34    34
# Comp:  2             [SII]6716      4.734     0.089     -37    49
# Comp:  2             [SII]6731      3.664     0.089     -37    49
# Comp:  2              HeII4687    0.02394     0.089     -37    49
# Comp:  2               HeI5876     0.7066     0.089     -37    49
# Comp:  2          [OIII]5007_d      2.699      0.11     -37    49
# Comp:  2            [OI]6300_d     0.9150      0.11     -37    49
# Comp:  2           [NII]6583_d      14.56      0.11     -37    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        62
#  comp.  1:       -35        34
#  comp.  2:       -37        49
# chi2/DOF: 0.6202; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.878     0.085     -35    34
# Comp:  1                 Hbeta      6.856     0.085     -35    34
# Comp:  1                Halpha      27.01     0.085     -35    34
# Comp:  2             [SII]6716      4.733     0.089     -37    49
# Comp:  2             [SII]6731      3.708     0.089     -37    49
# Comp:  2              HeII4687      0.000     0.089     -37    49
# Comp:  2               HeI5876     0.6904     0.089     -37    49
# Comp:  2          [OIII]5007_d      2.544      0.11     -37    49
# Comp:  2            [OI]6300_d     0.9803      0.11     -37    49
# Comp:  2           [NII]6583_d      14.49      0.11     -37    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        72
#  comp.  1:       -33        33
#  comp.  2:       -38        50
# chi2/DOF: 0.5810; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.780     0.085     -33    33
# Comp:  1                 Hbeta      6.411     0.085     -33    33
# Comp:  1                Halpha      26.78     0.085     -33    33
# Comp:  2             [SII]6716      4.760     0.090     -38    50
# Comp:  2             [SII]6731      3.836     0.090     -38    50
# Comp:  2              HeII4687      0.000     0.090     -38    50
# Comp:  2               HeI5876     0.6811     0.090     -38    50
# Comp:  2          [OIII]5007_d      2.379      0.11     -38    50
# Comp:  2            [OI]6300_d     0.9515      0.11     -38    50
# Comp:  2           [NII]6583_d      14.73      0.11     -38    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        77
#  comp.  1:       -32        29
#  comp.  2:       -37        51
# chi2/DOF: 0.5934; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.247     0.084     -32    29
# Comp:  1                 Hbeta      8.410     0.084     -32    29
# Comp:  1                Halpha      26.09     0.084     -32    29
# Comp:  2             [SII]6716      4.678     0.090     -37    51
# Comp:  2             [SII]6731      3.602     0.090     -37    51
# Comp:  2              HeII4687      0.000     0.090     -37    51
# Comp:  2               HeI5876     0.7217     0.090     -37    51
# Comp:  2          [OIII]5007_d      3.058      0.11     -37    51
# Comp:  2            [OI]6300_d     0.9276      0.11     -37    51
# Comp:  2           [NII]6583_d      14.76      0.11     -37    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        64
#  comp.  1:       -34        36
#  comp.  2:       -37        51
# chi2/DOF: 0.5734; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.938     0.085     -34    36
# Comp:  1                 Hbeta      8.903     0.085     -34    36
# Comp:  1                Halpha      26.94     0.085     -34    36
# Comp:  2             [SII]6716      4.668     0.090     -37    51
# Comp:  2             [SII]6731      3.610     0.090     -37    51
# Comp:  2              HeII4687      0.000     0.090     -37    51
# Comp:  2               HeI5876     0.6874     0.090     -37    51
# Comp:  2          [OIII]5007_d      2.413      0.11     -37    51
# Comp:  2            [OI]6300_d     0.9104      0.11     -37    51
# Comp:  2           [NII]6583_d      14.63      0.11     -37    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        81
#  comp.  1:       -33        29
#  comp.  2:       -36        50
# chi2/DOF: 0.5655; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.353     0.084     -33    29
# Comp:  1                 Hbeta      8.771     0.084     -33    29
# Comp:  1                Halpha      26.52     0.084     -33    29
# Comp:  2             [SII]6716      4.649     0.090     -36    50
# Comp:  2             [SII]6731      3.796     0.090     -36    50
# Comp:  2              HeII4687      0.000     0.090     -36    50
# Comp:  2               HeI5876     0.6396     0.090     -36    50
# Comp:  2          [OIII]5007_d      2.546      0.11     -36    50
# Comp:  2            [OI]6300_d     0.9049      0.11     -36    50
# Comp:  2           [NII]6583_d      14.65      0.11     -36    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        71
#  comp.  1:       -33        37
#  comp.  2:       -37        51
# chi2/DOF: 0.6405; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.293     0.086     -33    37
# Comp:  1                 Hbeta      8.000     0.086     -33    37
# Comp:  1                Halpha      26.08     0.086     -33    37
# Comp:  2             [SII]6716      4.748     0.090     -37    51
# Comp:  2             [SII]6731      3.717     0.090     -37    51
# Comp:  2              HeII4687      0.000     0.090     -37    51
# Comp:  2               HeI5876     0.6939     0.090     -37    51
# Comp:  2          [OIII]5007_d      2.568      0.11     -37    51
# Comp:  2            [OI]6300_d     0.8832      0.11     -37    51
# Comp:  2           [NII]6583_d      14.71      0.11     -37    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        70
#  comp.  1:       -31        35
#  comp.  2:       -38        48
# chi2/DOF: 0.6449; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.209     0.085     -31    35
# Comp:  1                 Hbeta      7.783     0.085     -31    35
# Comp:  1                Halpha      26.56     0.085     -31    35
# Comp:  2             [SII]6716      4.745     0.089     -38    48
# Comp:  2             [SII]6731      3.656     0.089     -38    48
# Comp:  2              HeII4687      0.000     0.089     -38    48
# Comp:  2               HeI5876     0.5980     0.089     -38    48
# Comp:  2          [OIII]5007_d      2.865      0.11     -38    48
# Comp:  2            [OI]6300_d     0.9194      0.11     -38    48
# Comp:  2           [NII]6583_d      14.56      0.11     -38    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        48
#  comp.  1:       -37        35
#  comp.  2:       -37        47
# chi2/DOF: 0.5734; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.797     0.085     -37    35
# Comp:  1                 Hbeta      6.498     0.085     -37    35
# Comp:  1                Halpha      26.41     0.085     -37    35
# Comp:  2             [SII]6716      4.662     0.089     -37    47
# Comp:  2             [SII]6731      3.686     0.089     -37    47
# Comp:  2              HeII4687      0.000     0.089     -37    47
# Comp:  2               HeI5876     0.6137     0.089     -37    47
# Comp:  2          [OIII]5007_d      2.965      0.11     -37    47
# Comp:  2            [OI]6300_d     0.8986      0.11     -37    47
# Comp:  2           [NII]6583_d      14.35      0.11     -37    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        81
#  comp.  1:       -34        31
#  comp.  2:       -36        50
# chi2/DOF: 0.6273; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.095     0.084     -34    31
# Comp:  1                 Hbeta      8.425     0.084     -34    31
# Comp:  1                Halpha      25.91     0.084     -34    31
# Comp:  2             [SII]6716      4.725     0.089     -36    50
# Comp:  2             [SII]6731      3.709     0.089     -36    50
# Comp:  2              HeII4687      0.000     0.089     -36    50
# Comp:  2               HeI5876     0.6719     0.089     -36    50
# Comp:  2          [OIII]5007_d      2.980      0.11     -36    50
# Comp:  2            [OI]6300_d     0.9087      0.11     -36    50
# Comp:  2           [NII]6583_d      14.76      0.11     -36    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        77
#  comp.  1:       -34        34
#  comp.  2:       -37        49
# chi2/DOF: 0.5565; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.197     0.085     -34    34
# Comp:  1                 Hbeta      8.875     0.085     -34    34
# Comp:  1                Halpha      27.18     0.085     -34    34
# Comp:  2             [SII]6716      4.672     0.089     -37    49
# Comp:  2             [SII]6731      3.815     0.089     -37    49
# Comp:  2              HeII4687      0.000     0.089     -37    49
# Comp:  2               HeI5876     0.5821     0.089     -37    49
# Comp:  2          [OIII]5007_d      2.729      0.11     -37    49
# Comp:  2            [OI]6300_d     0.9800      0.11     -37    49
# Comp:  2           [NII]6583_d      14.72      0.11     -37    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        83
#  comp.  1:       -37        34
#  comp.  2:       -37        48
# chi2/DOF: 0.5897; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.918     0.085     -37    34
# Comp:  1                 Hbeta      8.384     0.085     -37    34
# Comp:  1                Halpha      25.83     0.085     -37    34
# Comp:  2             [SII]6716      4.717     0.089     -37    48
# Comp:  2             [SII]6731      3.541     0.089     -37    48
# Comp:  2              HeII4687    0.01772     0.089     -37    48
# Comp:  2               HeI5876     0.6952     0.089     -37    48
# Comp:  2          [OIII]5007_d      2.687      0.11     -37    48
# Comp:  2            [OI]6300_d     0.9785      0.11     -37    48
# Comp:  2           [NII]6583_d      14.48      0.11     -37    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        68
#  comp.  1:       -37        36
#  comp.  2:       -37        50
# chi2/DOF: 0.6337; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.064     0.085     -37    36
# Comp:  1                 Hbeta      8.020     0.085     -37    36
# Comp:  1                Halpha      26.43     0.085     -37    36
# Comp:  2             [SII]6716      4.750     0.090     -37    50
# Comp:  2             [SII]6731      3.603     0.090     -37    50
# Comp:  2              HeII4687      0.000     0.090     -37    50
# Comp:  2               HeI5876     0.5987     0.090     -37    50
# Comp:  2          [OIII]5007_d      2.430      0.11     -37    50
# Comp:  2            [OI]6300_d     0.8726      0.11     -37    50
# Comp:  2           [NII]6583_d      14.71      0.11     -37    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        57
#  comp.  1:       -37        35
#  comp.  2:       -37        46
# chi2/DOF: 0.5561; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.929     0.085     -37    35
# Comp:  1                 Hbeta      8.880     0.085     -37    35
# Comp:  1                Halpha      26.42     0.085     -37    35
# Comp:  2             [SII]6716      4.649     0.088     -37    46
# Comp:  2             [SII]6731      3.690     0.088     -37    46
# Comp:  2              HeII4687  0.0009833     0.088     -37    46
# Comp:  2               HeI5876     0.6788     0.088     -37    46
# Comp:  2          [OIII]5007_d      2.568      0.11     -37    46
# Comp:  2            [OI]6300_d     0.9502      0.11     -37    46
# Comp:  2           [NII]6583_d      14.37      0.11     -37    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        67
#  comp.  1:       -34        36
#  comp.  2:       -38        47
# chi2/DOF: 0.6185; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.294     0.085     -34    36
# Comp:  1                 Hbeta      6.963     0.085     -34    36
# Comp:  1                Halpha      27.04     0.085     -34    36
# Comp:  2             [SII]6716      4.696     0.089     -38    47
# Comp:  2             [SII]6731      3.581     0.089     -38    47
# Comp:  2              HeII4687      0.000     0.089     -38    47
# Comp:  2               HeI5876     0.6774     0.089     -38    47
# Comp:  2          [OIII]5007_d      2.680      0.11     -38    47
# Comp:  2            [OI]6300_d     0.9449      0.11     -38    47
# Comp:  2           [NII]6583_d      14.61      0.11     -38    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        62
#  comp.  1:       -33        31
#  comp.  2:       -36        49
# chi2/DOF: 0.6603; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.060     0.084     -33    31
# Comp:  1                 Hbeta      7.498     0.084     -33    31
# Comp:  1                Halpha      26.68     0.084     -33    31
# Comp:  2             [SII]6716      4.726     0.089     -36    49
# Comp:  2             [SII]6731      3.724     0.089     -36    49
# Comp:  2              HeII4687    0.06079     0.089     -36    49
# Comp:  2               HeI5876     0.6762     0.089     -36    49
# Comp:  2          [OIII]5007_d      2.554      0.11     -36    49
# Comp:  2            [OI]6300_d     0.9066      0.11     -36    49
# Comp:  2           [NII]6583_d      14.62      0.11     -36    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        74
#  comp.  1:       -35        35
#  comp.  2:       -37        47
# chi2/DOF: 0.6264; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.088     0.085     -35    35
# Comp:  1                 Hbeta      6.892     0.085     -35    35
# Comp:  1                Halpha      26.82     0.085     -35    35
# Comp:  2             [SII]6716      4.666     0.088     -37    47
# Comp:  2             [SII]6731      3.588     0.088     -37    47
# Comp:  2              HeII4687      0.000     0.088     -37    47
# Comp:  2               HeI5876     0.7207     0.088     -37    47
# Comp:  2          [OIII]5007_d      2.378      0.11     -37    47
# Comp:  2            [OI]6300_d     0.9156      0.11     -37    47
# Comp:  2           [NII]6583_d      14.42      0.11     -37    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        70
#  comp.  1:       -35        31
#  comp.  2:       -37        50
# chi2/DOF: 0.6453; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.996     0.084     -35    31
# Comp:  1                 Hbeta      7.497     0.084     -35    31
# Comp:  1                Halpha      26.86     0.084     -35    31
# Comp:  2             [SII]6716      4.691     0.090     -37    50
# Comp:  2             [SII]6731      3.652     0.090     -37    50
# Comp:  2              HeII4687      0.000     0.090     -37    50
# Comp:  2               HeI5876     0.7596     0.090     -37    50
# Comp:  2          [OIII]5007_d      2.575      0.11     -37    50
# Comp:  2            [OI]6300_d     0.9982      0.11     -37    50
# Comp:  2           [NII]6583_d      14.55      0.11     -37    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        62
#  comp.  1:       -35        35
#  comp.  2:       -37        47
# chi2/DOF: 0.6774; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.196     0.085     -35    35
# Comp:  1                 Hbeta      7.855     0.085     -35    35
# Comp:  1                Halpha      26.46     0.085     -35    35
# Comp:  2             [SII]6716      4.647     0.089     -37    47
# Comp:  2             [SII]6731      3.685     0.089     -37    47
# Comp:  2              HeII4687    0.03863     0.089     -37    47
# Comp:  2               HeI5876     0.7525     0.089     -37    47
# Comp:  2          [OIII]5007_d      2.502      0.11     -37    47
# Comp:  2            [OI]6300_d     0.9434      0.11     -37    47
# Comp:  2           [NII]6583_d      14.30      0.11     -37    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        71
#  comp.  1:       -36        37
#  comp.  2:       -37        47
# chi2/DOF: 0.5524; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        65
#  comp.  1:       -35        32
#  comp.  2:       -37        46
# chi2/DOF: 0.6611; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.848     0.084     -35    32
# Comp:  1                 Hbeta      7.197     0.084     -35    32
# Comp:  1                Halpha      25.89     0.084     -35    32
# Comp:  2             [SII]6716      4.701     0.088     -37    46
# Comp:  2             [SII]6731      3.649     0.088     -37    46
# Comp:  2              HeII4687    0.01637     0.088     -37    46
# Comp:  2               HeI5876     0.6545     0.088     -37    46
# Comp:  2          [OIII]5007_d      2.594      0.11     -37    46
# Comp:  2            [OI]6300_d     0.9252      0.11     -37    46
# Comp:  2           [NII]6583_d      14.42      0.11     -37    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        69
#  comp.  1:       -35        33
#  comp.  2:       -37        46
# chi2/DOF: 0.6391; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.116     0.085     -35    33
# Comp:  1                 Hbeta      7.965     0.085     -35    33
# Comp:  1                Halpha      25.60     0.085     -35    33
# Comp:  2             [SII]6716      4.569     0.088     -37    46
# Comp:  2             [SII]6731      3.704     0.088     -37    46
# Comp:  2              HeII4687      0.000     0.088     -37    46
# Comp:  2               HeI5876     0.6867     0.088     -37    46
# Comp:  2          [OIII]5007_d      2.382      0.11     -37    46
# Comp:  2            [OI]6300_d     0.9458      0.11     -37    46
# Comp:  2           [NII]6583_d      14.42      0.11     -37    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        71
#  comp.  1:       -36        36
#  comp.  2:       -37        48
# chi2/DOF: 0.6056; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.171     0.085     -36    36
# Comp:  1                 Hbeta      8.843     0.085     -36    36
# Comp:  1                Halpha      26.60     0.085     -36    36
# Comp:  2             [SII]6716      4.689     0.089     -37    48
# Comp:  2             [SII]6731      3.660     0.089     -37    48
# Comp:  2              HeII4687    0.01457     0.089     -37    48
# Comp:  2               HeI5876     0.7629     0.089     -37    48
# Comp:  2          [OIII]5007_d      2.718      0.11     -37    48
# Comp:  2            [OI]6300_d     0.9538      0.11     -37    48
# Comp:  2           [NII]6583_d      14.38      0.11     -37    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        66
#  comp.  1:       -32        37
#  comp.  2:       -36        48
# chi2/DOF: 0.5895; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.214     0.085     -32    37
# Comp:  1                 Hbeta      6.822     0.085     -32    37
# Comp:  1                Halpha      26.74     0.085     -32    37
# Comp:  2             [SII]6716      4.717     0.089     -36    48
# Comp:  2             [SII]6731      3.719     0.089     -36    48
# Comp:  2              HeII4687    0.01767     0.089     -36    48
# Comp:  2               HeI5876     0.6076     0.089     -36    48
# Comp:  2          [OIII]5007_d      2.940      0.11     -36    48
# Comp:  2            [OI]6300_d     0.9743      0.11     -36    48
# Comp:  2           [NII]6583_d      14.42      0.11     -36    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        74
#  comp.  1:       -32        33
#  comp.  2:       -38        48
# chi2/DOF: 0.5406; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.528     0.085     -32    33
# Comp:  1                 Hbeta      6.805     0.085     -32    33
# Comp:  1                Halpha      26.66     0.085     -32    33
# Comp:  2             [SII]6716      4.714     0.089     -38    48
# Comp:  2             [SII]6731      3.628     0.089     -38    48
# Comp:  2              HeII4687    0.05367     0.089     -38    48
# Comp:  2               HeI5876     0.6670     0.089     -38    48
# Comp:  2          [OIII]5007_d      2.722      0.11     -38    48
# Comp:  2            [OI]6300_d     0.9203      0.11     -38    48
# Comp:  2           [NII]6583_d      14.34      0.11     -38    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        63
#  comp.  1:       -35        36
#  comp.  2:       -37        50
# chi2/DOF: 0.6150; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.399     0.085     -35    36
# Comp:  1                 Hbeta      8.848     0.085     -35    36
# Comp:  1                Halpha      26.31     0.085     -35    36
# Comp:  2             [SII]6716      4.681     0.089     -37    50
# Comp:  2             [SII]6731      3.768     0.089     -37    50
# Comp:  2              HeII4687    0.06185     0.089     -37    50
# Comp:  2               HeI5876     0.7501     0.089     -37    50
# Comp:  2          [OIII]5007_d      2.661      0.11     -37    50
# Comp:  2            [OI]6300_d     0.9266      0.11     -37    50
# Comp:  2           [NII]6583_d      14.75      0.11     -37    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        84
#  comp.  1:       -34        34
#  comp.  2:       -38        49
# chi2/DOF: 0.5364; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.309     0.085     -34    34
# Comp:  1                 Hbeta      6.801     0.085     -34    34
# Comp:  1                Halpha      27.31     0.085     -34    34
# Comp:  2             [SII]6716      4.710     0.089     -38    49
# Comp:  2             [SII]6731      3.637     0.089     -38    49
# Comp:  2              HeII4687    0.02644     0.089     -38    49
# Comp:  2               HeI5876     0.7028     0.089     -38    49
# Comp:  2          [OIII]5007_d      2.791      0.11     -38    49
# Comp:  2            [OI]6300_d     0.9220      0.11     -38    49
# Comp:  2           [NII]6583_d      14.56      0.11     -38    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        60
#  comp.  1:       -33        39
#  comp.  2:       -37        50
# chi2/DOF: 0.5691; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.957     0.086     -33    39
# Comp:  1                 Hbeta      6.632     0.086     -33    39
# Comp:  1                Halpha      27.26     0.086     -33    39
# Comp:  2             [SII]6716      4.815     0.090     -37    50
# Comp:  2             [SII]6731      3.854     0.090     -37    50
# Comp:  2              HeII4687      0.000     0.090     -37    50
# Comp:  2               HeI5876     0.6604     0.090     -37    50
# Comp:  2          [OIII]5007_d      2.457      0.11     -37    50
# Comp:  2            [OI]6300_d     0.9600      0.11     -37    50
# Comp:  2           [NII]6583_d      14.66      0.11     -37    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        71
#  comp.  1:       -34        31
#  comp.  2:       -37        46
# chi2/DOF: 0.6642; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.325     0.084     -34    31
# Comp:  1                 Hbeta      7.722     0.084     -34    31
# Comp:  1                Halpha      26.01     0.084     -34    31
# Comp:  2             [SII]6716      4.626     0.088     -37    46
# Comp:  2             [SII]6731      3.548     0.088     -37    46
# Comp:  2              HeII4687    0.06448     0.088     -37    46
# Comp:  2               HeI5876     0.6921     0.088     -37    46
# Comp:  2          [OIII]5007_d      2.603      0.11     -37    46
# Comp:  2            [OI]6300_d     0.8936      0.11     -37    46
# Comp:  2           [NII]6583_d      14.55      0.11     -37    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        78
#  comp.  1:       -36        36
#  comp.  2:       -39        46
# chi2/DOF: 0.6404; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.355     0.085     -36    36
# Comp:  1                 Hbeta      7.265     0.085     -36    36
# Comp:  1                Halpha      26.23     0.085     -36    36
# Comp:  2             [SII]6716      4.624     0.088     -39    46
# Comp:  2             [SII]6731      3.638     0.088     -39    46
# Comp:  2              HeII4687      0.000     0.088     -39    46
# Comp:  2               HeI5876     0.7198     0.088     -39    46
# Comp:  2          [OIII]5007_d      2.472      0.11     -39    46
# Comp:  2            [OI]6300_d     0.8842      0.11     -39    46
# Comp:  2           [NII]6583_d      14.51      0.11     -39    46
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        82
#  comp.  1:       -36        37
#  comp.  2:       -38        48
# chi2/DOF: 0.5863; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.197     0.086     -36    37
# Comp:  1                 Hbeta      7.042     0.086     -36    37
# Comp:  1                Halpha      26.40     0.086     -36    37
# Comp:  2             [SII]6716      4.602     0.089     -38    48
# Comp:  2             [SII]6731      3.659     0.089     -38    48
# Comp:  2              HeII4687   0.004444     0.089     -38    48
# Comp:  2               HeI5876     0.6625     0.089     -38    48
# Comp:  2          [OIII]5007_d      2.716      0.11     -38    48
# Comp:  2            [OI]6300_d     0.8892      0.11     -38    48
# Comp:  2           [NII]6583_d      14.38      0.11     -38    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        67
#  comp.  1:       -33        33
#  comp.  2:       -37        48
# chi2/DOF: 0.5963; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.159     0.085     -33    33
# Comp:  1                 Hbeta      8.580     0.085     -33    33
# Comp:  1                Halpha      27.00     0.085     -33    33
# Comp:  2             [SII]6716      4.668     0.089     -37    48
# Comp:  2             [SII]6731      3.680     0.089     -37    48
# Comp:  2              HeII4687   0.004782     0.089     -37    48
# Comp:  2               HeI5876     0.6179     0.089     -37    48
# Comp:  2          [OIII]5007_d      2.993      0.11     -37    48
# Comp:  2            [OI]6300_d     0.9309      0.11     -37    48
# Comp:  2           [NII]6583_d      14.56      0.11     -37    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        73
#  comp.  1:       -33        31
#  comp.  2:       -37        48
# chi2/DOF: 0.6600; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.359     0.084     -33    31
# Comp:  1                 Hbeta      7.705     0.084     -33    31
# Comp:  1                Halpha      26.31     0.084     -33    31
# Comp:  2             [SII]6716      4.588     0.089     -37    48
# Comp:  2             [SII]6731      3.713     0.089     -37    48
# Comp:  2              HeII4687      0.000     0.089     -37    48
# Comp:  2               HeI5876     0.6775     0.089     -37    48
# Comp:  2          [OIII]5007_d      2.690      0.11     -37    48
# Comp:  2            [OI]6300_d     0.9295      0.11     -37    48
# Comp:  2           [NII]6583_d      14.50      0.11     -37    48
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.17720084, 0.79901321, 0.6351708 , 0.0866113 , 0.11485617,
#        0.02238262, 0.06167062, 0.1919363 , 0.04821484, 0.18529107])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 2.79511217,  7.76171891, 36.16261616,  6.56884683,  5.1768206 ,
#         0.        ,  0.84099128,  2.74502715,  1.21865314, 19.96204407])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_10_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_10", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_10_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_10_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_10_gas_exp.csv")
print(read2)
# Out:
#            Line       Flux  Error flux
# 0        Hgamma   1.885534    0.119537
# 1         Hbeta   5.235920    0.539000
# 2        Halpha  24.394670    0.428475
# 3     [SII]6716   4.431230    0.058426
# 4     [SII]6731   3.492193    0.077480
# 5      HeII4687   0.000000    0.015099
# 6       HeI5876   0.567318    0.041602
# 7  [OIII]5007_d   1.851747    0.129477
# 8    [OI]6300_d   0.822082    0.032525
# 9   [NII]6583_d  13.466047    0.124994
#           Name       Flux  Error_flux
# 0       Hgamma   1.885534    0.119537
# 1        Hbeta   5.235920    0.539000
# 2       Halpha  24.394670    0.428475
# 3    [SII]6716   4.431230    0.058426
# 4    [SII]6731   3.492193    0.077480
# 5     HeII4687   0.000000    0.015099
# 6      HeI5876   0.567318    0.041602
# 7   [OIII]4959   0.462937    0.129477
# 8   [OIII]5007   1.388811    0.129477
# 9     [OI]6300   0.616562    0.032525
# 10    [OI]6364   0.205521    0.032525
# 11   [NII]6548   3.366512    0.124994
# 12   [NII]6583  10.099535    0.124994

# %%
np.median(flux_rf_rebin)
# Out:
# 0.6745825668166134
