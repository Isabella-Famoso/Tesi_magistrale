# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3s_2.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/Spectra_extraction/redshift.txt") 
z = red[1][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_3s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_2']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4316.35165261 4317.78617815 4319.22070369 ... 6875.54521663 6876.97974217
#  6878.41426771] [0.7510282  0.82227848 0.82213016 ... 0.6749761  0.68588817 0.68133435] [0.0330144 0.0330144 0.0330144 ... 0.0330144 0.0330144 0.0330144]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15817583 2.15889309 2.15961035 ... 3.43777261 3.43848987 3.43920713]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3160, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3160, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3160, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        20        80
# chi2/DOF: 0.0006850; DOF: 1909; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/150
#  Best Fit:       Vel     sigma
#  comp.  0:        18        79
# chi2/DOF: 0.0003900; DOF: 1871; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/150

# %%
pp_stars.sol

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")

# %%
dlam

# %%
line_wave

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        41        69
#  comp.  1:        21        38
#  comp.  2:        24        37
# chi2/DOF: 0.5095; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.249     0.084      21    38
# Comp:  1                 Hbeta      8.368     0.084      21    38
# Comp:  1                Halpha      26.51     0.084      21    38
# Comp:  2             [SII]6716      4.546     0.084      24    37
# Comp:  2             [SII]6731      3.559     0.084      24    37
# Comp:  2              HeII4687      0.000     0.084      24    37
# Comp:  2               HeI5876     0.5847     0.084      24    37
# Comp:  2          [OIII]5007_d      2.855      0.11      24    37
# Comp:  2            [OI]6300_d     0.8228      0.11      24    37
# Comp:  2           [NII]6583_d      13.74      0.11      24    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37        80
#  comp.  1:        24        33
#  comp.  2:        26        37
# chi2/DOF: 0.5399; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.294     0.083      24    33
# Comp:  1                 Hbeta      7.861     0.083      24    33
# Comp:  1                Halpha      26.03     0.083      24    33
# Comp:  2             [SII]6716      4.533     0.084      26    37
# Comp:  2             [SII]6731      3.476     0.084      26    37
# Comp:  2              HeII4687    0.03395     0.084      26    37
# Comp:  2               HeI5876     0.6463     0.084      26    37
# Comp:  2          [OIII]5007_d      2.466      0.11      26    37
# Comp:  2            [OI]6300_d     0.8151      0.11      26    37
# Comp:  2           [NII]6583_d      14.01      0.11      26    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35        59
#  comp.  1:        24        36
#  comp.  2:        23        43
# chi2/DOF: 0.5051; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.476     0.084      24    36
# Comp:  1                 Hbeta      7.311     0.084      24    36
# Comp:  1                Halpha      26.32     0.084      24    36
# Comp:  2             [SII]6716      4.567     0.086      23    43
# Comp:  2             [SII]6731      3.561     0.086      23    43
# Comp:  2              HeII4687      0.000     0.086      23    43
# Comp:  2               HeI5876     0.7268     0.086      23    43
# Comp:  2          [OIII]5007_d      2.579      0.11      23    43
# Comp:  2            [OI]6300_d     0.8600      0.11      23    43
# Comp:  2           [NII]6583_d      14.23      0.11      23    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        39        68
#  comp.  1:        23        32
#  comp.  2:        27        41
# chi2/DOF: 0.5089; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.339     0.083      23    32
# Comp:  1                 Hbeta      7.414     0.083      23    32
# Comp:  1                Halpha      26.04     0.083      23    32
# Comp:  2             [SII]6716      4.692     0.085      27    41
# Comp:  2             [SII]6731      3.398     0.085      27    41
# Comp:  2              HeII4687      0.000     0.085      27    41
# Comp:  2               HeI5876     0.5890     0.085      27    41
# Comp:  2          [OIII]5007_d      2.959      0.11      27    41
# Comp:  2            [OI]6300_d     0.8226      0.11      27    41
# Comp:  2           [NII]6583_d      14.26      0.11      27    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37        66
#  comp.  1:        23        35
#  comp.  2:        26        41
# chi2/DOF: 0.5410; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.570     0.083      23    35
# Comp:  1                 Hbeta      8.470     0.083      23    35
# Comp:  1                Halpha      26.43     0.083      23    35
# Comp:  2             [SII]6716      4.625     0.085      26    41
# Comp:  2             [SII]6731      3.456     0.085      26    41
# Comp:  2              HeII4687    0.01941     0.085      26    41
# Comp:  2               HeI5876     0.6161     0.085      26    41
# Comp:  2          [OIII]5007_d      2.300      0.11      26    41
# Comp:  2            [OI]6300_d     0.8466      0.11      26    41
# Comp:  2           [NII]6583_d      14.26      0.11      26    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        66
#  comp.  1:        23        36
#  comp.  2:        24        40
# chi2/DOF: 0.5337; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.535     0.084      23    36
# Comp:  1                 Hbeta      8.637     0.084      23    36
# Comp:  1                Halpha      26.45     0.084      23    36
# Comp:  2             [SII]6716      4.469     0.085      24    40
# Comp:  2             [SII]6731      3.391     0.085      24    40
# Comp:  2              HeII4687      0.000     0.085      24    40
# Comp:  2               HeI5876     0.6483     0.085      24    40
# Comp:  2          [OIII]5007_d      2.620      0.11      24    40
# Comp:  2            [OI]6300_d     0.8277      0.11      24    40
# Comp:  2           [NII]6583_d      14.21      0.11      24    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        64
#  comp.  1:        22        36
#  comp.  2:        24        36
# chi2/DOF: 0.5348; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.446     0.084      22    36
# Comp:  1                 Hbeta      7.976     0.084      22    36
# Comp:  1                Halpha      26.55     0.084      22    36
# Comp:  2             [SII]6716      4.626     0.084      24    36
# Comp:  2             [SII]6731      3.362     0.084      24    36
# Comp:  2              HeII4687      0.000     0.084      24    36
# Comp:  2               HeI5876     0.6421     0.084      24    36
# Comp:  2          [OIII]5007_d      2.834      0.11      24    36
# Comp:  2            [OI]6300_d     0.8367      0.11      24    36
# Comp:  2           [NII]6583_d      13.79      0.11      24    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        43        65
#  comp.  1:        22        37
#  comp.  2:        25        41
# chi2/DOF: 0.5241; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.508     0.084      22    37
# Comp:  1                 Hbeta      8.434     0.084      22    37
# Comp:  1                Halpha      26.65     0.084      22    37
# Comp:  2             [SII]6716      4.588     0.085      25    41
# Comp:  2             [SII]6731      3.444     0.085      25    41
# Comp:  2              HeII4687      0.000     0.085      25    41
# Comp:  2               HeI5876     0.5937     0.085      25    41
# Comp:  2          [OIII]5007_d      2.209      0.11      25    41
# Comp:  2            [OI]6300_d     0.8828      0.11      25    41
# Comp:  2           [NII]6583_d      14.22      0.11      25    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37        73
#  comp.  1:        23        34
#  comp.  2:        24        41
# chi2/DOF: 0.5381; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.289     0.083      23    34
# Comp:  1                 Hbeta      8.404     0.083      23    34
# Comp:  1                Halpha      26.13     0.083      23    34
# Comp:  2             [SII]6716      4.497     0.085      24    41
# Comp:  2             [SII]6731      3.600     0.085      24    41
# Comp:  2              HeII4687      0.000     0.085      24    41
# Comp:  2               HeI5876     0.7101     0.085      24    41
# Comp:  2          [OIII]5007_d      2.955      0.11      24    41
# Comp:  2            [OI]6300_d     0.8545      0.11      24    41
# Comp:  2           [NII]6583_d      14.06      0.11      24    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        39        75
#  comp.  1:        22        34
#  comp.  2:        23        42
# chi2/DOF: 0.4984; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.104     0.083      22    34
# Comp:  1                 Hbeta      8.822     0.083      22    34
# Comp:  1                Halpha      26.23     0.083      22    34
# Comp:  2             [SII]6716      4.533     0.085      23    42
# Comp:  2             [SII]6731      3.449     0.085      23    42
# Comp:  2              HeII4687    0.05531     0.085      23    42
# Comp:  2               HeI5876     0.6331     0.085      23    42
# Comp:  2          [OIII]5007_d      2.861      0.11      23    42
# Comp:  2            [OI]6300_d     0.8947      0.11      23    42
# Comp:  2           [NII]6583_d      14.27      0.11      23    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47        66
#  comp.  1:        23        37
#  comp.  2:        21        39
# chi2/DOF: 0.5167; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.142     0.084      23    37
# Comp:  1                 Hbeta      7.829     0.084      23    37
# Comp:  1                Halpha      26.42     0.084      23    37
# Comp:  2             [SII]6716      4.573     0.084      21    39
# Comp:  2             [SII]6731      3.232     0.084      21    39
# Comp:  2              HeII4687      0.000     0.084      21    39
# Comp:  2               HeI5876     0.6640     0.084      21    39
# Comp:  2          [OIII]5007_d      2.741      0.11      21    39
# Comp:  2            [OI]6300_d     0.8587      0.11      21    39
# Comp:  2           [NII]6583_d      13.90      0.11      21    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        42        74
#  comp.  1:        23        32
#  comp.  2:        22        42
# chi2/DOF: 0.5087; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.502     0.083      23    32
# Comp:  1                 Hbeta      8.669     0.083      23    32
# Comp:  1                Halpha      26.04     0.083      23    32
# Comp:  2             [SII]6716      4.439     0.085      22    42
# Comp:  2             [SII]6731      3.364     0.085      22    42
# Comp:  2              HeII4687    0.01194     0.085      22    42
# Comp:  2               HeI5876     0.6662     0.085      22    42
# Comp:  2          [OIII]5007_d      2.585      0.11      22    42
# Comp:  2            [OI]6300_d     0.8310      0.11      22    42
# Comp:  2           [NII]6583_d      14.22      0.11      22    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36        60
#  comp.  1:        22        36
#  comp.  2:        24        41
# chi2/DOF: 0.5341; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.200     0.084      22    36
# Comp:  1                 Hbeta      7.939     0.084      22    36
# Comp:  1                Halpha      26.28     0.084      22    36
# Comp:  2             [SII]6716      4.510     0.085      24    41
# Comp:  2             [SII]6731      3.291     0.085      24    41
# Comp:  2              HeII4687      0.000     0.085      24    41
# Comp:  2               HeI5876     0.6941     0.085      24    41
# Comp:  2          [OIII]5007_d      2.947      0.11      24    41
# Comp:  2            [OI]6300_d     0.8643      0.11      24    41
# Comp:  2           [NII]6583_d      14.14      0.11      24    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29        74
#  comp.  1:        23        33
#  comp.  2:        24        41
# chi2/DOF: 0.5161; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.122     0.083      23    33
# Comp:  1                 Hbeta      7.516     0.083      23    33
# Comp:  1                Halpha      26.08     0.083      23    33
# Comp:  2             [SII]6716      4.488     0.085      24    41
# Comp:  2             [SII]6731      3.234     0.085      24    41
# Comp:  2              HeII4687    0.02382     0.085      24    41
# Comp:  2               HeI5876     0.7683     0.085      24    41
# Comp:  2          [OIII]5007_d      2.543      0.11      24    41
# Comp:  2            [OI]6300_d     0.8284      0.11      24    41
# Comp:  2           [NII]6583_d      14.34      0.11      24    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34        70
#  comp.  1:        22        36
#  comp.  2:        24        41
# chi2/DOF: 0.5290; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.445     0.084      22    36
# Comp:  1                 Hbeta      7.801     0.084      22    36
# Comp:  1                Halpha      26.35     0.084      22    36
# Comp:  2             [SII]6716      4.713     0.085      24    41
# Comp:  2             [SII]6731      3.421     0.085      24    41
# Comp:  2              HeII4687      0.000     0.085      24    41
# Comp:  2               HeI5876     0.6655     0.085      24    41
# Comp:  2          [OIII]5007_d      2.183      0.11      24    41
# Comp:  2            [OI]6300_d     0.8659      0.11      24    41
# Comp:  2           [NII]6583_d      14.37      0.11      24    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33        65
#  comp.  1:        23        34
#  comp.  2:        22        41
# chi2/DOF: 0.5385; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.253     0.083      23    34
# Comp:  1                 Hbeta      8.006     0.083      23    34
# Comp:  1                Halpha      26.13     0.083      23    34
# Comp:  2             [SII]6716      4.652     0.085      22    41
# Comp:  2             [SII]6731      3.233     0.085      22    41
# Comp:  2              HeII4687   0.007780     0.085      22    41
# Comp:  2               HeI5876     0.7518     0.085      22    41
# Comp:  2          [OIII]5007_d      2.591      0.11      22    41
# Comp:  2            [OI]6300_d     0.8719      0.11      22    41
# Comp:  2           [NII]6583_d      14.10      0.11      22    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35        64
#  comp.  1:        22        35
#  comp.  2:        23        37
# chi2/DOF: 0.5405; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.374     0.084      22    35
# Comp:  1                 Hbeta      8.381     0.084      22    35
# Comp:  1                Halpha      26.17     0.084      22    35
# Comp:  2             [SII]6716      4.407     0.084      23    37
# Comp:  2             [SII]6731      3.414     0.084      23    37
# Comp:  2              HeII4687      0.000     0.084      23    37
# Comp:  2               HeI5876     0.5942     0.084      23    37
# Comp:  2          [OIII]5007_d      2.601      0.11      23    37
# Comp:  2            [OI]6300_d     0.8548      0.11      23    37
# Comp:  2           [NII]6583_d      13.85      0.11      23    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        66
#  comp.  1:        22        39
#  comp.  2:        26        41
# chi2/DOF: 0.5164; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.343     0.084      22    39
# Comp:  1                 Hbeta      7.827     0.084      22    39
# Comp:  1                Halpha      26.70     0.084      22    39
# Comp:  2             [SII]6716      4.603     0.085      26    41
# Comp:  2             [SII]6731      3.490     0.085      26    41
# Comp:  2              HeII4687      0.000     0.085      26    41
# Comp:  2               HeI5876     0.6629     0.085      26    41
# Comp:  2          [OIII]5007_d      2.465      0.11      26    41
# Comp:  2            [OI]6300_d     0.8507      0.11      26    41
# Comp:  2           [NII]6583_d      14.10      0.11      26    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33        79
#  comp.  1:        24        35
#  comp.  2:        24        37
# chi2/DOF: 0.5363; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.590     0.083      24    35
# Comp:  1                 Hbeta      8.205     0.083      24    35
# Comp:  1                Halpha      26.28     0.083      24    35
# Comp:  2             [SII]6716      4.501     0.084      24    37
# Comp:  2             [SII]6731      3.291     0.084      24    37
# Comp:  2              HeII4687      0.000     0.084      24    37
# Comp:  2               HeI5876     0.6426     0.084      24    37
# Comp:  2          [OIII]5007_d      2.533      0.11      24    37
# Comp:  2            [OI]6300_d     0.8382      0.11      24    37
# Comp:  2           [NII]6583_d      13.68      0.11      24    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34        72
#  comp.  1:        24        33
#  comp.  2:        25        36
# chi2/DOF: 0.5244; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.178     0.083      24    33
# Comp:  1                 Hbeta      8.411     0.083      24    33
# Comp:  1                Halpha      26.03     0.083      24    33
# Comp:  2             [SII]6716      4.627     0.084      25    36
# Comp:  2             [SII]6731      3.276     0.084      25    36
# Comp:  2              HeII4687      0.000     0.084      25    36
# Comp:  2               HeI5876     0.6693     0.084      25    36
# Comp:  2          [OIII]5007_d      2.814      0.11      25    36
# Comp:  2            [OI]6300_d     0.8325      0.11      25    36
# Comp:  2           [NII]6583_d      13.65      0.11      25    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28        69
#  comp.  1:        23        33
#  comp.  2:        24        45
# chi2/DOF: 0.5283; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.461     0.083      23    33
# Comp:  1                 Hbeta      8.108     0.083      23    33
# Comp:  1                Halpha      26.21     0.083      23    33
# Comp:  2             [SII]6716      4.647     0.086      24    45
# Comp:  2             [SII]6731      3.545     0.086      24    45
# Comp:  2              HeII4687    0.02759     0.086      24    45
# Comp:  2               HeI5876     0.7572     0.086      24    45
# Comp:  2          [OIII]5007_d      2.291      0.11      24    45
# Comp:  2            [OI]6300_d     0.8480      0.11      24    45
# Comp:  2           [NII]6583_d      14.33      0.11      24    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        79
#  comp.  1:        24        31
#  comp.  2:        25        39
# chi2/DOF: 0.5216; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.336     0.083      24    31
# Comp:  1                 Hbeta      8.336     0.083      24    31
# Comp:  1                Halpha      26.03     0.083      24    31
# Comp:  2             [SII]6716      4.593     0.085      25    39
# Comp:  2             [SII]6731      3.494     0.085      25    39
# Comp:  2              HeII4687    0.04148     0.085      25    39
# Comp:  2               HeI5876     0.6487     0.085      25    39
# Comp:  2          [OIII]5007_d      2.203      0.11      25    39
# Comp:  2            [OI]6300_d     0.8361      0.11      25    39
# Comp:  2           [NII]6583_d      14.04      0.11      25    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36        68
#  comp.  1:        23        39
#  comp.  2:        26        41
# chi2/DOF: 0.5027; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.537     0.085      23    39
# Comp:  1                 Hbeta      8.678     0.085      23    39
# Comp:  1                Halpha      26.75     0.085      23    39
# Comp:  2             [SII]6716      4.638     0.085      26    41
# Comp:  2             [SII]6731      3.498     0.085      26    41
# Comp:  2              HeII4687    0.02450     0.085      26    41
# Comp:  2               HeI5876     0.6711     0.085      26    41
# Comp:  2          [OIII]5007_d      2.204      0.11      26    41
# Comp:  2            [OI]6300_d     0.8738      0.11      26    41
# Comp:  2           [NII]6583_d      14.22      0.11      26    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        40        61
#  comp.  1:        21        38
#  comp.  2:        23        43
# chi2/DOF: 0.5134; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.285     0.084      21    38
# Comp:  1                 Hbeta      8.194     0.084      21    38
# Comp:  1                Halpha      26.61     0.084      21    38
# Comp:  2             [SII]6716      4.542     0.086      23    43
# Comp:  2             [SII]6731      3.523     0.086      23    43
# Comp:  2              HeII4687      0.000     0.086      23    43
# Comp:  2               HeI5876     0.6702     0.086      23    43
# Comp:  2          [OIII]5007_d      2.185      0.11      23    43
# Comp:  2            [OI]6300_d     0.8459      0.11      23    43
# Comp:  2           [NII]6583_d      14.35      0.11      23    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        79
#  comp.  1:        23        33
#  comp.  2:        22        40
# chi2/DOF: 0.5355; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.455     0.083      23    33
# Comp:  1                 Hbeta      7.807     0.083      23    33
# Comp:  1                Halpha      26.07     0.083      23    33
# Comp:  2             [SII]6716      4.452     0.085      22    40
# Comp:  2             [SII]6731      3.372     0.085      22    40
# Comp:  2              HeII4687      0.000     0.085      22    40
# Comp:  2               HeI5876     0.6381     0.085      22    40
# Comp:  2          [OIII]5007_d      2.507      0.11      22    40
# Comp:  2            [OI]6300_d     0.8348      0.11      22    40
# Comp:  2           [NII]6583_d      14.12      0.11      22    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        27        71
#  comp.  1:        23        34
#  comp.  2:        24        35
# chi2/DOF: 0.5378; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.390     0.083      23    34
# Comp:  1                 Hbeta      7.914     0.083      23    34
# Comp:  1                Halpha      26.13     0.083      23    34
# Comp:  2             [SII]6716      4.491     0.084      24    35
# Comp:  2             [SII]6731      3.349     0.084      24    35
# Comp:  2              HeII4687    0.03447     0.084      24    35
# Comp:  2               HeI5876     0.6039     0.084      24    35
# Comp:  2          [OIII]5007_d      2.303      0.11      24    35
# Comp:  2            [OI]6300_d     0.8136      0.11      24    35
# Comp:  2           [NII]6583_d      13.72      0.11      24    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37        71
#  comp.  1:        23        34
#  comp.  2:        24        45
# chi2/DOF: 0.5175; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.207     0.083      23    34
# Comp:  1                 Hbeta      8.632     0.083      23    34
# Comp:  1                Halpha      26.10     0.083      23    34
# Comp:  2             [SII]6716      4.666     0.086      24    45
# Comp:  2             [SII]6731      3.455     0.086      24    45
# Comp:  2              HeII4687      0.000     0.086      24    45
# Comp:  2               HeI5876     0.6843     0.086      24    45
# Comp:  2          [OIII]5007_d      2.487      0.11      24    45
# Comp:  2            [OI]6300_d     0.8344      0.11      24    45
# Comp:  2           [NII]6583_d      14.56      0.11      24    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37        76
#  comp.  1:        22        35
#  comp.  2:        27        41
# chi2/DOF: 0.5110; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.173     0.083      22    35
# Comp:  1                 Hbeta      8.673     0.083      22    35
# Comp:  1                Halpha      26.21     0.083      22    35
# Comp:  2             [SII]6716      4.464     0.085      27    41
# Comp:  2             [SII]6731      3.364     0.085      27    41
# Comp:  2              HeII4687    0.03111     0.085      27    41
# Comp:  2               HeI5876     0.6224     0.085      27    41
# Comp:  2          [OIII]5007_d      2.294      0.11      27    41
# Comp:  2            [OI]6300_d     0.8518      0.11      27    41
# Comp:  2           [NII]6583_d      14.21      0.11      27    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        44        66
#  comp.  1:        22        39
#  comp.  2:        26        38
# chi2/DOF: 0.5211; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.597     0.084      22    39
# Comp:  1                 Hbeta      8.047     0.084      22    39
# Comp:  1                Halpha      26.77     0.084      22    39
# Comp:  2             [SII]6716      4.672     0.084      26    38
# Comp:  2             [SII]6731      3.412     0.084      26    38
# Comp:  2              HeII4687  0.0001778     0.084      26    38
# Comp:  2               HeI5876     0.6608     0.084      26    38
# Comp:  2          [OIII]5007_d      2.593      0.11      26    38
# Comp:  2            [OI]6300_d     0.8328      0.11      26    38
# Comp:  2           [NII]6583_d      13.92      0.11      26    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26        74
#  comp.  1:        24        32
#  comp.  2:        24        43
# chi2/DOF: 0.4946; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.297     0.083      24    32
# Comp:  1                 Hbeta      7.558     0.083      24    32
# Comp:  1                Halpha      25.96     0.083      24    32
# Comp:  2             [SII]6716      4.602     0.086      24    43
# Comp:  2             [SII]6731      3.452     0.086      24    43
# Comp:  2              HeII4687    0.02043     0.086      24    43
# Comp:  2               HeI5876     0.7298     0.086      24    43
# Comp:  2          [OIII]5007_d      2.992      0.11      24    43
# Comp:  2            [OI]6300_d     0.8343      0.11      24    43
# Comp:  2           [NII]6583_d      14.33      0.11      24    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        25        70
#  comp.  1:        22        36
#  comp.  2:        25        39
# chi2/DOF: 0.5305; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.480     0.084      22    36
# Comp:  1                 Hbeta      7.830     0.084      22    36
# Comp:  1                Halpha      26.40     0.084      22    36
# Comp:  2             [SII]6716      4.656     0.085      25    39
# Comp:  2             [SII]6731      3.448     0.085      25    39
# Comp:  2              HeII4687    0.02224     0.085      25    39
# Comp:  2               HeI5876     0.6724     0.085      25    39
# Comp:  2          [OIII]5007_d      2.376      0.11      25    39
# Comp:  2            [OI]6300_d     0.8100      0.11      25    39
# Comp:  2           [NII]6583_d      13.97      0.11      25    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        78
#  comp.  1:        23        32
#  comp.  2:        23        35
# chi2/DOF: 0.4909; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.372     0.083      23    32
# Comp:  1                 Hbeta      7.331     0.083      23    32
# Comp:  1                Halpha      26.02     0.083      23    32
# Comp:  2             [SII]6716      4.447     0.083      23    35
# Comp:  2             [SII]6731      3.196     0.083      23    35
# Comp:  2              HeII4687      0.000     0.083      23    35
# Comp:  2               HeI5876     0.6118     0.083      23    35
# Comp:  2          [OIII]5007_d      2.491      0.11      23    35
# Comp:  2            [OI]6300_d     0.8303      0.11      23    35
# Comp:  2           [NII]6583_d      13.50      0.11      23    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29        71
#  comp.  1:        23        37
#  comp.  2:        25        37
# chi2/DOF: 0.5275; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.500     0.084      23    37
# Comp:  1                 Hbeta      8.399     0.084      23    37
# Comp:  1                Halpha      26.66     0.084      23    37
# Comp:  2             [SII]6716      4.499     0.084      25    37
# Comp:  2             [SII]6731      3.164     0.084      25    37
# Comp:  2              HeII4687      0.000     0.084      25    37
# Comp:  2               HeI5876     0.6892     0.084      25    37
# Comp:  2          [OIII]5007_d      2.812      0.11      25    37
# Comp:  2            [OI]6300_d     0.8506      0.11      25    37
# Comp:  2           [NII]6583_d      13.97      0.11      25    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        43        66
#  comp.  1:        23        35
#  comp.  2:        21        39
# chi2/DOF: 0.5300; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.489     0.083      23    35
# Comp:  1                 Hbeta      8.362     0.083      23    35
# Comp:  1                Halpha      26.38     0.083      23    35
# Comp:  2             [SII]6716      4.458     0.085      21    39
# Comp:  2             [SII]6731      3.448     0.085      21    39
# Comp:  2              HeII4687      0.000     0.085      21    39
# Comp:  2               HeI5876     0.6861     0.085      21    39
# Comp:  2          [OIII]5007_d      2.967      0.11      21    39
# Comp:  2            [OI]6300_d     0.8894      0.11      21    39
# Comp:  2           [NII]6583_d      14.01      0.11      21    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        43        70
#  comp.  1:        22        37
#  comp.  2:        24        40
# chi2/DOF: 0.5367; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.228     0.084      22    37
# Comp:  1                 Hbeta      8.123     0.084      22    37
# Comp:  1                Halpha      26.42     0.084      22    37
# Comp:  2             [SII]6716      4.592     0.085      24    40
# Comp:  2             [SII]6731      3.389     0.085      24    40
# Comp:  2              HeII4687      0.000     0.085      24    40
# Comp:  2               HeI5876     0.7135     0.085      24    40
# Comp:  2          [OIII]5007_d      2.612      0.11      24    40
# Comp:  2            [OI]6300_d     0.8338      0.11      24    40
# Comp:  2           [NII]6583_d      14.32      0.11      24    40
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.15279289, 0.43503344, 0.33694626, 0.1367535 , 0.14448864,
#        0.0187072 , 0.0680755 , 0.23297262, 0.02924603, 0.34128782])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 3.00710154,  8.18538239, 35.85994311,  6.42483495,  4.8014329 ,
#         0.        ,  0.81684902,  2.69398515,  1.12058947, 19.34254478])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum3s_2_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum3s_2_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum3s_2_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum3s_2_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum3s_2_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0        Hgamma   2.450750    0.124524
# 1         Hbeta   6.670983    0.354547
# 2        Halpha  29.225401    0.274607
# 3     [SII]6716   5.236159    0.111452
# 4     [SII]6731   3.913107    0.117756
# 5      HeII4687   0.000000    0.015246
# 6       HeI5876   0.665722    0.055481
# 7  [OIII]5007_d   2.195564    0.189870
# 8    [OI]6300_d   0.913266    0.023835
# 9   [NII]6583_d  15.763930    0.278145
#           Name       Flux  Error_flux
# 0       Hgamma   2.450750    0.124524
# 1        Hbeta   6.670983    0.354547
# 2       Halpha  29.225401    0.274607
# 3    [SII]6716   5.236159    0.111452
# 4    [SII]6731   3.913107    0.117756
# 5     HeII4687   0.000000    0.015246
# 6      HeI5876   0.665722    0.055481
# 7   [OIII]4959   0.548891    0.189870
# 8   [OIII]5007   1.646673    0.189870
# 9     [OI]6300   0.684950    0.023835
# 10    [OI]6364   0.228317    0.023835
# 11   [NII]6548   3.940982    0.278145
# 12   [NII]6583  11.822947    0.278145

# %%
np.median(flux_rf_rebin)
# Out:
# 0.814987369966507
