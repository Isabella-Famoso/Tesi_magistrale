# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3s_3.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/Spectra_extraction/redshift.txt") 
z = red[2][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_3s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.03156

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15846873 2.15918609 2.15990345 ... 3.43823917 3.43895653 3.43967389]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3161, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         3        75
# chi2/DOF: 0.001446; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/150
#  Best Fit:       Vel     sigma
#  comp.  0:         8        71
# chi2/DOF: 0.0009711; DOF: 1878; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([ 7.79359359, 70.50302531])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        72
#  comp.  1:        -0        18
#  comp.  2:         1        23
# chi2/DOF: 0.8914; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.007      0.10      -0    18
# Comp:  1                 Hbeta      10.40      0.10      -0    18
# Comp:  1                Halpha      31.69      0.10      -0    18
# Comp:  2             [SII]6716      5.075      0.10       1    23
# Comp:  2             [SII]6731      3.569      0.10       1    23
# Comp:  2              HeII4687   0.005608      0.10       1    23
# Comp:  2               HeI5876      1.218      0.10       1    23
# Comp:  2          [OIII]5007_d      3.671      0.13       1    23
# Comp:  2            [OI]6300_d     0.9791      0.13       1    23
# Comp:  2           [NII]6583_d      13.95      0.13       1    23
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  41.07; gas flux:      4 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  108.6; gas flux:     11 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  314.8; gas flux:     43 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  48.61; gas flux:      7 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  36.81; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.05701; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  12.53; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  28.96; gas flux:      4 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  7.705; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  104.7; gas flux:     19 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        77
#  comp.  1:        -0        10
#  comp.  2:         1        28
# chi2/DOF: 0.8062; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.545     0.098      -0    10
# Comp:  1                 Hbeta      10.40     0.098      -0    10
# Comp:  1                Halpha      31.97     0.098      -0    10
# Comp:  2             [SII]6716      4.878      0.10       1    28
# Comp:  2             [SII]6731      3.729      0.10       1    28
# Comp:  2              HeII4687    0.02243      0.10       1    28
# Comp:  2               HeI5876      1.359      0.10       1    28
# Comp:  2          [OIII]5007_d      3.672      0.13       1    28
# Comp:  2            [OI]6300_d      1.056      0.13       1    28
# Comp:  2           [NII]6583_d      14.29      0.13       1    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        67
#  comp.  1:        -1        22
#  comp.  2:         1        27
# chi2/DOF: 0.7877; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.511      0.10      -1    22
# Comp:  1                 Hbeta      9.431      0.10      -1    22
# Comp:  1                Halpha      32.75      0.10      -1    22
# Comp:  2             [SII]6716      5.140      0.10       1    27
# Comp:  2             [SII]6731      3.653      0.10       1    27
# Comp:  2              HeII4687    0.03946      0.10       1    27
# Comp:  2               HeI5876      1.167      0.10       1    27
# Comp:  2          [OIII]5007_d      3.784      0.13       1    27
# Comp:  2            [OI]6300_d     0.9670      0.13       1    27
# Comp:  2           [NII]6583_d      14.26      0.13       1    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45        73
#  comp.  1:         0        18
#  comp.  2:        -0        22
# chi2/DOF: 0.7802; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.052      0.10       0    18
# Comp:  1                 Hbeta      11.81      0.10       0    18
# Comp:  1                Halpha      32.03      0.10       0    18
# Comp:  2             [SII]6716      4.927      0.10      -0    22
# Comp:  2             [SII]6731      3.478      0.10      -0    22
# Comp:  2              HeII4687    0.01801      0.10      -0    22
# Comp:  2               HeI5876      1.330      0.10      -0    22
# Comp:  2          [OIII]5007_d      3.517      0.13      -0    22
# Comp:  2            [OI]6300_d     0.9713      0.13      -0    22
# Comp:  2           [NII]6583_d      13.84      0.13      -0    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        47
#  comp.  1:         1        21
#  comp.  2:        -1        18
# chi2/DOF: 0.8647; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.633      0.10       1    21
# Comp:  1                 Hbeta      10.47      0.10       1    21
# Comp:  1                Halpha      31.85      0.10       1    21
# Comp:  2             [SII]6716      5.029      0.10      -1    18
# Comp:  2             [SII]6731      3.565      0.10      -1    18
# Comp:  2              HeII4687    0.02898      0.10      -1    18
# Comp:  2               HeI5876      1.314      0.10      -1    18
# Comp:  2          [OIII]5007_d      3.473      0.13      -1    18
# Comp:  2            [OI]6300_d     0.9493      0.13      -1    18
# Comp:  2           [NII]6583_d      13.63      0.13      -1    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        77
#  comp.  1:         1        11
#  comp.  2:         2        26
# chi2/DOF: 0.8008; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.844     0.098       1    11
# Comp:  1                 Hbeta      9.049     0.098       1    11
# Comp:  1                Halpha      31.06     0.098       1    11
# Comp:  2             [SII]6716      5.339      0.10       2    26
# Comp:  2             [SII]6731      3.833      0.10       2    26
# Comp:  2              HeII4687      0.000      0.10       2    26
# Comp:  2               HeI5876      1.305      0.10       2    26
# Comp:  2          [OIII]5007_d      3.735      0.13       2    26
# Comp:  2            [OI]6300_d      1.049      0.13       2    26
# Comp:  2           [NII]6583_d      14.02      0.13       2    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7        85
#  comp.  1:        -0        17
#  comp.  2:         1        28
# chi2/DOF: 0.7511; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.144     0.099      -0    17
# Comp:  1                 Hbeta      9.763     0.099      -0    17
# Comp:  1                Halpha      31.13     0.099      -0    17
# Comp:  2             [SII]6716      5.586      0.10       1    28
# Comp:  2             [SII]6731      3.849      0.10       1    28
# Comp:  2              HeII4687      0.000      0.10       1    28
# Comp:  2               HeI5876      1.174      0.10       1    28
# Comp:  2          [OIII]5007_d      3.865      0.13       1    28
# Comp:  2            [OI]6300_d     0.9340      0.13       1    28
# Comp:  2           [NII]6583_d      14.28      0.13       1    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        78
#  comp.  1:         2        16
#  comp.  2:         2        17
# chi2/DOF: 0.7690; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.137     0.099       2    16
# Comp:  1                 Hbeta      11.51     0.099       2    16
# Comp:  1                Halpha      31.45     0.099       2    16
# Comp:  2             [SII]6716      4.886     0.099       2    17
# Comp:  2             [SII]6731      3.331     0.099       2    17
# Comp:  2              HeII4687      0.000     0.099       2    17
# Comp:  2               HeI5876      1.156     0.099       2    17
# Comp:  2          [OIII]5007_d      3.511      0.13       2    17
# Comp:  2            [OI]6300_d     0.9540      0.13       2    17
# Comp:  2           [NII]6583_d      13.55      0.13       2    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        83
#  comp.  1:         3        17
#  comp.  2:         3        20
# chi2/DOF: 0.7743; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.760     0.099       3    17
# Comp:  1                 Hbeta      10.99     0.099       3    17
# Comp:  1                Halpha      31.38     0.099       3    17
# Comp:  2             [SII]6716      4.785      0.10       3    20
# Comp:  2             [SII]6731      3.322      0.10       3    20
# Comp:  2              HeII4687    0.02353      0.10       3    20
# Comp:  2               HeI5876      1.196      0.10       3    20
# Comp:  2          [OIII]5007_d      3.554      0.13       3    20
# Comp:  2            [OI]6300_d     0.9214      0.13       3    20
# Comp:  2           [NII]6583_d      13.78      0.13       3    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        11        67
#  comp.  1:        -1        26
#  comp.  2:         3        24
# chi2/DOF: 0.7654; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.998      0.10      -1    26
# Comp:  1                 Hbeta      9.783      0.10      -1    26
# Comp:  1                Halpha      31.68      0.10      -1    26
# Comp:  2             [SII]6716      4.983      0.10       3    24
# Comp:  2             [SII]6731      3.556      0.10       3    24
# Comp:  2              HeII4687    0.03374      0.10       3    24
# Comp:  2               HeI5876      1.175      0.10       3    24
# Comp:  2          [OIII]5007_d      3.973      0.13       3    24
# Comp:  2            [OI]6300_d      1.008      0.13       3    24
# Comp:  2           [NII]6583_d      14.01      0.13       3    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        93
#  comp.  1:        -1        11
#  comp.  2:         0        25
# chi2/DOF: 0.7826; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.413     0.098      -1    11
# Comp:  1                 Hbeta      9.104     0.098      -1    11
# Comp:  1                Halpha      31.41     0.098      -1    11
# Comp:  2             [SII]6716      5.538      0.10       0    25
# Comp:  2             [SII]6731      3.767      0.10       0    25
# Comp:  2              HeII4687   0.006828      0.10       0    25
# Comp:  2               HeI5876      1.322      0.10       0    25
# Comp:  2          [OIII]5007_d      3.790      0.13       0    25
# Comp:  2            [OI]6300_d     0.9548      0.13       0    25
# Comp:  2           [NII]6583_d      14.02      0.13       0    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        75
#  comp.  1:        -0        14
#  comp.  2:         3        23
# chi2/DOF: 0.7865; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.791     0.099      -0    14
# Comp:  1                 Hbeta      9.517     0.099      -0    14
# Comp:  1                Halpha      32.26     0.099      -0    14
# Comp:  2             [SII]6716      5.198      0.10       3    23
# Comp:  2             [SII]6731      3.491      0.10       3    23
# Comp:  2              HeII4687    0.03666      0.10       3    23
# Comp:  2               HeI5876      1.209      0.10       3    23
# Comp:  2          [OIII]5007_d      3.632      0.13       3    23
# Comp:  2            [OI]6300_d     0.9732      0.13       3    23
# Comp:  2           [NII]6583_d      14.02      0.13       3    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        70
#  comp.  1:        -1        16
#  comp.  2:         1        19
# chi2/DOF: 0.8128; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.464     0.099      -1    16
# Comp:  1                 Hbeta      11.32     0.099      -1    16
# Comp:  1                Halpha      32.29     0.099      -1    16
# Comp:  2             [SII]6716      4.665      0.10       1    19
# Comp:  2             [SII]6731      3.378      0.10       1    19
# Comp:  2              HeII4687      0.000      0.10       1    19
# Comp:  2               HeI5876      1.202      0.10       1    19
# Comp:  2          [OIII]5007_d      3.729      0.13       1    19
# Comp:  2            [OI]6300_d     0.9415      0.13       1    19
# Comp:  2           [NII]6583_d      13.59      0.13       1    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        81
#  comp.  1:         2        14
#  comp.  2:        -1        25
# chi2/DOF: 0.8500; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.115     0.099       2    14
# Comp:  1                 Hbeta      10.66     0.099       2    14
# Comp:  1                Halpha      31.46     0.099       2    14
# Comp:  2             [SII]6716      5.201      0.10      -1    25
# Comp:  2             [SII]6731      3.437      0.10      -1    25
# Comp:  2              HeII4687    0.03053      0.10      -1    25
# Comp:  2               HeI5876      1.266      0.10      -1    25
# Comp:  2          [OIII]5007_d      3.836      0.13      -1    25
# Comp:  2            [OI]6300_d     0.9620      0.13      -1    25
# Comp:  2           [NII]6583_d      14.07      0.13      -1    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        51
#  comp.  1:         1        27
#  comp.  2:         4        27
# chi2/DOF: 0.7695; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.447      0.10       1    27
# Comp:  1                 Hbeta      11.81      0.10       1    27
# Comp:  1                Halpha      31.89      0.10       1    27
# Comp:  2             [SII]6716      4.768      0.10       4    27
# Comp:  2             [SII]6731      3.626      0.10       4    27
# Comp:  2              HeII4687      0.000      0.10       4    27
# Comp:  2               HeI5876      1.213      0.10       4    27
# Comp:  2          [OIII]5007_d      3.687      0.13       4    27
# Comp:  2            [OI]6300_d      1.051      0.13       4    27
# Comp:  2           [NII]6583_d      14.13      0.13       4    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        69
#  comp.  1:         0        14
#  comp.  2:         1        15
# chi2/DOF: 0.8331; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.985     0.099       0    14
# Comp:  1                 Hbeta      10.39     0.099       0    14
# Comp:  1                Halpha      30.69     0.099       0    14
# Comp:  2             [SII]6716      4.513     0.099       1    15
# Comp:  2             [SII]6731      3.243     0.099       1    15
# Comp:  2              HeII4687      0.000     0.099       1    15
# Comp:  2               HeI5876      1.228     0.099       1    15
# Comp:  2          [OIII]5007_d      3.542      0.13       1    15
# Comp:  2            [OI]6300_d     0.9277      0.13       1    15
# Comp:  2           [NII]6583_d      13.51      0.13       1    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        96
#  comp.  1:         1         5
#  comp.  2:         1        14
# chi2/DOF: 0.8019; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.289     0.098       1     5
# Comp:  1                 Hbeta      10.58     0.098       1     5
# Comp:  1                Halpha      31.05     0.098       1     5
# Comp:  2             [SII]6716      5.217     0.099       1    14
# Comp:  2             [SII]6731      3.441     0.099       1    14
# Comp:  2              HeII4687    0.01162     0.099       1    14
# Comp:  2               HeI5876      1.232     0.099       1    14
# Comp:  2          [OIII]5007_d      3.600      0.12       1    14
# Comp:  2            [OI]6300_d     0.9768      0.12       1    14
# Comp:  2           [NII]6583_d      13.56      0.12       1    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        85
#  comp.  1:         1        12
#  comp.  2:        -1        21
# chi2/DOF: 0.7638; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.972     0.099       1    12
# Comp:  1                 Hbeta      11.65     0.099       1    12
# Comp:  1                Halpha      32.34     0.099       1    12
# Comp:  2             [SII]6716      5.263      0.10      -1    21
# Comp:  2             [SII]6731      3.662      0.10      -1    21
# Comp:  2              HeII4687    0.02178      0.10      -1    21
# Comp:  2               HeI5876      1.347      0.10      -1    21
# Comp:  2          [OIII]5007_d      3.777      0.13      -1    21
# Comp:  2            [OI]6300_d     0.9688      0.13      -1    21
# Comp:  2           [NII]6583_d      13.91      0.13      -1    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        74
#  comp.  1:         1        15
#  comp.  2:         0        26
# chi2/DOF: 0.8058; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.474     0.099       1    15
# Comp:  1                 Hbeta      10.17     0.099       1    15
# Comp:  1                Halpha      32.30     0.099       1    15
# Comp:  2             [SII]6716      5.166      0.10       0    26
# Comp:  2             [SII]6731      3.571      0.10       0    26
# Comp:  2              HeII4687      0.000      0.10       0    26
# Comp:  2               HeI5876      1.342      0.10       0    26
# Comp:  2          [OIII]5007_d      4.004      0.13       0    26
# Comp:  2            [OI]6300_d     0.9491      0.13       0    26
# Comp:  2           [NII]6583_d      13.98      0.13       0    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        78
#  comp.  1:         1        23
#  comp.  2:        -1        22
# chi2/DOF: 0.8547; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.591      0.10       1    23
# Comp:  1                 Hbeta      10.23      0.10       1    23
# Comp:  1                Halpha      31.89      0.10       1    23
# Comp:  2             [SII]6716      5.273      0.10      -1    22
# Comp:  2             [SII]6731      3.558      0.10      -1    22
# Comp:  2              HeII4687  0.0006232      0.10      -1    22
# Comp:  2               HeI5876      1.147      0.10      -1    22
# Comp:  2          [OIII]5007_d      3.615      0.13      -1    22
# Comp:  2            [OI]6300_d     0.9728      0.13      -1    22
# Comp:  2           [NII]6583_d      13.94      0.13      -1    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        68
#  comp.  1:        -1         1
#  comp.  2:         1        26
# chi2/DOF: 0.8068; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.026     0.098      -1     1
# Comp:  1                 Hbeta      10.52     0.098      -1     1
# Comp:  1                Halpha      31.80     0.098      -1     1
# Comp:  2             [SII]6716      5.316      0.10       1    26
# Comp:  2             [SII]6731      3.744      0.10       1    26
# Comp:  2              HeII4687      0.000      0.10       1    26
# Comp:  2               HeI5876      1.132      0.10       1    26
# Comp:  2          [OIII]5007_d      3.586      0.13       1    26
# Comp:  2            [OI]6300_d     0.9769      0.13       1    26
# Comp:  2           [NII]6583_d      14.19      0.13       1    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        80
#  comp.  1:        -1        10
#  comp.  2:         3        21
# chi2/DOF: 0.8328; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.787     0.098      -1    10
# Comp:  1                 Hbeta      10.62     0.098      -1    10
# Comp:  1                Halpha      31.68     0.098      -1    10
# Comp:  2             [SII]6716      4.823      0.10       3    21
# Comp:  2             [SII]6731      3.565      0.10       3    21
# Comp:  2              HeII4687    0.02134      0.10       3    21
# Comp:  2               HeI5876      1.223      0.10       3    21
# Comp:  2          [OIII]5007_d      3.943      0.13       3    21
# Comp:  2            [OI]6300_d     0.9807      0.13       3    21
# Comp:  2           [NII]6583_d      13.97      0.13       3    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        73
#  comp.  1:        -0         8
#  comp.  2:         3        24
# chi2/DOF: 0.7601; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.732     0.098      -0     8
# Comp:  1                 Hbeta      9.354     0.098      -0     8
# Comp:  1                Halpha      31.97     0.098      -0     8
# Comp:  2             [SII]6716      4.857      0.10       3    24
# Comp:  2             [SII]6731      3.828      0.10       3    24
# Comp:  2              HeII4687    0.04660      0.10       3    24
# Comp:  2               HeI5876      1.147      0.10       3    24
# Comp:  2          [OIII]5007_d      3.807      0.13       3    24
# Comp:  2            [OI]6300_d     0.9760      0.13       3    24
# Comp:  2           [NII]6583_d      14.08      0.13       3    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        63
#  comp.  1:        -1        19
#  comp.  2:         4        27
# chi2/DOF: 0.8258; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.711      0.10      -1    19
# Comp:  1                 Hbeta      10.61      0.10      -1    19
# Comp:  1                Halpha      32.61      0.10      -1    19
# Comp:  2             [SII]6716      4.819      0.10       4    27
# Comp:  2             [SII]6731      3.696      0.10       4    27
# Comp:  2              HeII4687      0.000      0.10       4    27
# Comp:  2               HeI5876      1.272      0.10       4    27
# Comp:  2          [OIII]5007_d      4.093      0.13       4    27
# Comp:  2            [OI]6300_d      1.015      0.13       4    27
# Comp:  2           [NII]6583_d      14.02      0.13       4    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        89
#  comp.  1:         3        16
#  comp.  2:         4        27
# chi2/DOF: 0.7767; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.352     0.099       3    16
# Comp:  1                 Hbeta      11.20     0.099       3    16
# Comp:  1                Halpha      31.50     0.099       3    16
# Comp:  2             [SII]6716      5.137      0.10       4    27
# Comp:  2             [SII]6731      3.529      0.10       4    27
# Comp:  2              HeII4687   0.001110      0.10       4    27
# Comp:  2               HeI5876      1.314      0.10       4    27
# Comp:  2          [OIII]5007_d      3.711      0.13       4    27
# Comp:  2            [OI]6300_d     0.9676      0.13       4    27
# Comp:  2           [NII]6583_d      14.07      0.13       4    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        92
#  comp.  1:        -1         4
#  comp.  2:         1        29
# chi2/DOF: 0.7558; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.468     0.098      -1     4
# Comp:  1                 Hbeta      9.215     0.098      -1     4
# Comp:  1                Halpha      31.79     0.098      -1     4
# Comp:  2             [SII]6716      4.960      0.10       1    29
# Comp:  2             [SII]6731      3.699      0.10       1    29
# Comp:  2              HeII4687    0.04816      0.10       1    29
# Comp:  2               HeI5876      1.175      0.10       1    29
# Comp:  2          [OIII]5007_d      3.710      0.13       1    29
# Comp:  2            [OI]6300_d      1.006      0.13       1    29
# Comp:  2           [NII]6583_d      14.42      0.13       1    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        67
#  comp.  1:         2        28
#  comp.  2:        -2        18
# chi2/DOF: 0.7960; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.823      0.10       2    28
# Comp:  1                 Hbeta      10.51      0.10       2    28
# Comp:  1                Halpha      32.38      0.10       2    28
# Comp:  2             [SII]6716      5.338      0.10      -2    18
# Comp:  2             [SII]6731      3.596      0.10      -2    18
# Comp:  2              HeII4687    0.03779      0.10      -2    18
# Comp:  2               HeI5876      1.107      0.10      -2    18
# Comp:  2          [OIII]5007_d      3.708      0.13      -2    18
# Comp:  2            [OI]6300_d     0.9671      0.13      -2    18
# Comp:  2           [NII]6583_d      13.75      0.13      -2    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        74
#  comp.  1:        -0        15
#  comp.  2:         4        25
# chi2/DOF: 0.7847; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.953     0.099      -0    15
# Comp:  1                 Hbeta      11.64     0.099      -0    15
# Comp:  1                Halpha      31.68     0.099      -0    15
# Comp:  2             [SII]6716      5.006      0.10       4    25
# Comp:  2             [SII]6731      3.696      0.10       4    25
# Comp:  2              HeII4687    0.04418      0.10       4    25
# Comp:  2               HeI5876      1.137      0.10       4    25
# Comp:  2          [OIII]5007_d      3.704      0.13       4    25
# Comp:  2            [OI]6300_d      1.025      0.13       4    25
# Comp:  2           [NII]6583_d      14.16      0.13       4    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        59
#  comp.  1:         2        22
#  comp.  2:         3        25
# chi2/DOF: 0.8249; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.999      0.10       2    22
# Comp:  1                 Hbeta      10.47      0.10       2    22
# Comp:  1                Halpha      31.27      0.10       2    22
# Comp:  2             [SII]6716      5.534      0.10       3    25
# Comp:  2             [SII]6731      3.312      0.10       3    25
# Comp:  2              HeII4687   0.008390      0.10       3    25
# Comp:  2               HeI5876      1.231      0.10       3    25
# Comp:  2          [OIII]5007_d      3.536      0.13       3    25
# Comp:  2            [OI]6300_d     0.9241      0.13       3    25
# Comp:  2           [NII]6583_d      14.06      0.13       3    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        50
#  comp.  1:         0        26
#  comp.  2:         2        26
# chi2/DOF: 0.7712; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.104      0.10       0    26
# Comp:  1                 Hbeta      11.80      0.10       0    26
# Comp:  1                Halpha      31.64      0.10       0    26
# Comp:  2             [SII]6716      5.022      0.10       2    26
# Comp:  2             [SII]6731      3.637      0.10       2    26
# Comp:  2              HeII4687    0.03275      0.10       2    26
# Comp:  2               HeI5876      1.304      0.10       2    26
# Comp:  2          [OIII]5007_d      3.896      0.13       2    26
# Comp:  2            [OI]6300_d     0.9388      0.13       2    26
# Comp:  2           [NII]6583_d      14.07      0.13       2    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        69
#  comp.  1:        -3        20
#  comp.  2:         1        29
# chi2/DOF: 0.8342; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.542      0.10      -3    20
# Comp:  1                 Hbeta      10.78      0.10      -3    20
# Comp:  1                Halpha      32.06      0.10      -3    20
# Comp:  2             [SII]6716      5.387      0.10       1    29
# Comp:  2             [SII]6731      3.660      0.10       1    29
# Comp:  2              HeII4687      0.000      0.10       1    29
# Comp:  2               HeI5876      1.153      0.10       1    29
# Comp:  2          [OIII]5007_d      3.876      0.13       1    29
# Comp:  2            [OI]6300_d     0.9953      0.13       1    29
# Comp:  2           [NII]6583_d      14.32      0.13       1    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        67
#  comp.  1:         2        16
#  comp.  2:         4        25
# chi2/DOF: 0.8422; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.891     0.099       2    16
# Comp:  1                 Hbeta      9.991     0.099       2    16
# Comp:  1                Halpha      31.31     0.099       2    16
# Comp:  2             [SII]6716      5.065      0.10       4    25
# Comp:  2             [SII]6731      3.488      0.10       4    25
# Comp:  2              HeII4687      0.000      0.10       4    25
# Comp:  2               HeI5876      1.259      0.10       4    25
# Comp:  2          [OIII]5007_d      3.821      0.13       4    25
# Comp:  2            [OI]6300_d     0.9542      0.13       4    25
# Comp:  2           [NII]6583_d      13.97      0.13       4    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        58
#  comp.  1:        -1        24
#  comp.  2:         0        19
# chi2/DOF: 0.7794; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.637      0.10      -1    24
# Comp:  1                 Hbeta      9.359      0.10      -1    24
# Comp:  1                Halpha      31.42      0.10      -1    24
# Comp:  2             [SII]6716      5.236      0.10       0    19
# Comp:  2             [SII]6731      3.510      0.10       0    19
# Comp:  2              HeII4687    0.01981      0.10       0    19
# Comp:  2               HeI5876      1.163      0.10       0    19
# Comp:  2          [OIII]5007_d      3.761      0.13       0    19
# Comp:  2            [OI]6300_d     0.9903      0.13       0    19
# Comp:  2           [NII]6583_d      13.68      0.13       0    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        78
#  comp.  1:        -0        14
#  comp.  2:         3        22
# chi2/DOF: 0.7783; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.110     0.099      -0    14
# Comp:  1                 Hbeta      11.68     0.099      -0    14
# Comp:  1                Halpha      31.67     0.099      -0    14
# Comp:  2             [SII]6716      5.428      0.10       3    22
# Comp:  2             [SII]6731      3.590      0.10       3    22
# Comp:  2              HeII4687    0.03080      0.10       3    22
# Comp:  2               HeI5876      1.228      0.10       3    22
# Comp:  2          [OIII]5007_d      3.474      0.13       3    22
# Comp:  2            [OI]6300_d     0.9611      0.13       3    22
# Comp:  2           [NII]6583_d      14.00      0.13       3    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        96
#  comp.  1:         2        19
#  comp.  2:         1        26
# chi2/DOF: 0.7812; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.738      0.10       2    19
# Comp:  1                 Hbeta      11.60      0.10       2    19
# Comp:  1                Halpha      31.25      0.10       2    19
# Comp:  2             [SII]6716      5.041      0.10       1    26
# Comp:  2             [SII]6731      3.862      0.10       1    26
# Comp:  2              HeII4687      0.000      0.10       1    26
# Comp:  2               HeI5876      1.155      0.10       1    26
# Comp:  2          [OIII]5007_d      3.567      0.13       1    26
# Comp:  2            [OI]6300_d     0.9652      0.13       1    26
# Comp:  2           [NII]6583_d      13.96      0.13       1    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        78
#  comp.  1:        -1        15
#  comp.  2:         3        20
# chi2/DOF: 0.7884; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.402     0.099      -1    15
# Comp:  1                 Hbeta      9.561     0.099      -1    15
# Comp:  1                Halpha      30.78     0.099      -1    15
# Comp:  2             [SII]6716      4.966      0.10       3    20
# Comp:  2             [SII]6731      3.469      0.10       3    20
# Comp:  2              HeII4687      0.000      0.10       3    20
# Comp:  2               HeI5876      1.251      0.10       3    20
# Comp:  2          [OIII]5007_d      3.578      0.13       3    20
# Comp:  2            [OI]6300_d     0.9376      0.13       3    20
# Comp:  2           [NII]6583_d      13.69      0.13       3    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        78
#  comp.  1:         2        16
#  comp.  2:         3        24
# chi2/DOF: 0.7753; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.019     0.099       2    16
# Comp:  1                 Hbeta      11.54     0.099       2    16
# Comp:  1                Halpha      31.53     0.099       2    16
# Comp:  2             [SII]6716      5.019      0.10       3    24
# Comp:  2             [SII]6731      3.704      0.10       3    24
# Comp:  2              HeII4687    0.02410      0.10       3    24
# Comp:  2               HeI5876      1.352      0.10       3    24
# Comp:  2          [OIII]5007_d      3.718      0.13       3    24
# Comp:  2            [OI]6300_d      1.019      0.13       3    24
# Comp:  2           [NII]6583_d      14.00      0.13       3    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        66
#  comp.  1:         1        22
#  comp.  2:         0        12
# chi2/DOF: 0.8133; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.099      0.10       1    22
# Comp:  1                 Hbeta      11.54      0.10       1    22
# Comp:  1                Halpha      31.77      0.10       1    22
# Comp:  2             [SII]6716      4.966     0.099       0    12
# Comp:  2             [SII]6731      3.277     0.099       0    12
# Comp:  2              HeII4687    0.02530     0.099       0    12
# Comp:  2               HeI5876      1.232     0.099       0    12
# Comp:  2          [OIII]5007_d      3.692      0.12       0    12
# Comp:  2            [OI]6300_d     0.9437      0.12       0    12
# Comp:  2           [NII]6583_d      13.39      0.12       0    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        58
#  comp.  1:         1        24
#  comp.  2:         2        26
# chi2/DOF: 0.8426; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.806      0.10       1    24
# Comp:  1                 Hbeta      10.44      0.10       1    24
# Comp:  1                Halpha      31.89      0.10       1    24
# Comp:  2             [SII]6716      5.477      0.10       2    26
# Comp:  2             [SII]6731      3.759      0.10       2    26
# Comp:  2              HeII4687      0.000      0.10       2    26
# Comp:  2               HeI5876      1.179      0.10       2    26
# Comp:  2          [OIII]5007_d      3.602      0.13       2    26
# Comp:  2            [OI]6300_d     0.9492      0.13       2    26
# Comp:  2           [NII]6583_d      14.09      0.13       2    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        63
#  comp.  1:         1        24
#  comp.  2:         1        25
# chi2/DOF: 0.8520; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.880      0.10       1    24
# Comp:  1                 Hbeta      10.68      0.10       1    24
# Comp:  1                Halpha      32.07      0.10       1    24
# Comp:  2             [SII]6716      5.046      0.10       1    25
# Comp:  2             [SII]6731      3.370      0.10       1    25
# Comp:  2              HeII4687    0.01918      0.10       1    25
# Comp:  2               HeI5876      1.166      0.10       1    25
# Comp:  2          [OIII]5007_d      3.764      0.13       1    25
# Comp:  2            [OI]6300_d      1.002      0.13       1    25
# Comp:  2           [NII]6583_d      13.94      0.13       1    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        11        62
#  comp.  1:        -0        23
#  comp.  2:         0        25
# chi2/DOF: 0.7758; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        92
#  comp.  1:         1        12
#  comp.  2:         1        25
# chi2/DOF: 0.8451; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.244     0.099       1    12
# Comp:  1                 Hbeta      10.73     0.099       1    12
# Comp:  1                Halpha      31.49     0.099       1    12
# Comp:  2             [SII]6716      5.277      0.10       1    25
# Comp:  2             [SII]6731      3.413      0.10       1    25
# Comp:  2              HeII4687   0.007632      0.10       1    25
# Comp:  2               HeI5876      1.231      0.10       1    25
# Comp:  2          [OIII]5007_d      3.629      0.13       1    25
# Comp:  2            [OI]6300_d     0.9410      0.13       1    25
# Comp:  2           [NII]6583_d      14.12      0.13       1    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        77
#  comp.  1:         1        20
#  comp.  2:         1        20
# chi2/DOF: 0.8389; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.934      0.10       1    20
# Comp:  1                 Hbeta      10.43      0.10       1    20
# Comp:  1                Halpha      31.00      0.10       1    20
# Comp:  2             [SII]6716      4.945      0.10       1    20
# Comp:  2             [SII]6731      3.790      0.10       1    20
# Comp:  2              HeII4687      0.000      0.10       1    20
# Comp:  2               HeI5876      1.139      0.10       1    20
# Comp:  2          [OIII]5007_d      3.585      0.13       1    20
# Comp:  2            [OI]6300_d     0.9374      0.13       1    20
# Comp:  2           [NII]6583_d      13.74      0.13       1    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        67
#  comp.  1:        -2        22
#  comp.  2:         2        20
# chi2/DOF: 0.8370; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.599      0.10      -2    22
# Comp:  1                 Hbeta      10.41      0.10      -2    22
# Comp:  1                Halpha      32.13      0.10      -2    22
# Comp:  2             [SII]6716      5.398      0.10       2    20
# Comp:  2             [SII]6731      3.616      0.10       2    20
# Comp:  2              HeII4687   0.002559      0.10       2    20
# Comp:  2               HeI5876      1.192      0.10       2    20
# Comp:  2          [OIII]5007_d      3.410      0.13       2    20
# Comp:  2            [OI]6300_d     0.9141      0.13       2    20
# Comp:  2           [NII]6583_d      13.78      0.13       2    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        74
#  comp.  1:        -2        23
#  comp.  2:         1        21
# chi2/DOF: 0.8055; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.598      0.10      -2    23
# Comp:  1                 Hbeta      10.41      0.10      -2    23
# Comp:  1                Halpha      32.13      0.10      -2    23
# Comp:  2             [SII]6716      4.655      0.10       1    21
# Comp:  2             [SII]6731      3.586      0.10       1    21
# Comp:  2              HeII4687    0.05260      0.10       1    21
# Comp:  2               HeI5876      1.178      0.10       1    21
# Comp:  2          [OIII]5007_d      3.495      0.13       1    21
# Comp:  2            [OI]6300_d     0.9352      0.13       1    21
# Comp:  2           [NII]6583_d      13.67      0.13       1    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        71
#  comp.  1:        -1         9
#  comp.  2:         3        22
# chi2/DOF: 0.7982; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.132     0.098      -1     9
# Comp:  1                 Hbeta      9.291     0.098      -1     9
# Comp:  1                Halpha      31.79     0.098      -1     9
# Comp:  2             [SII]6716      4.764      0.10       3    22
# Comp:  2             [SII]6731      3.606      0.10       3    22
# Comp:  2              HeII4687    0.04651      0.10       3    22
# Comp:  2               HeI5876      1.138      0.10       3    22
# Comp:  2          [OIII]5007_d      3.781      0.13       3    22
# Comp:  2            [OI]6300_d     0.9055      0.13       3    22
# Comp:  2           [NII]6583_d      13.93      0.13       3    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        67
#  comp.  1:        -2        15
#  comp.  2:        -2        20
# chi2/DOF: 0.8220; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.450     0.099      -2    15
# Comp:  1                 Hbeta      9.578     0.099      -2    15
# Comp:  1                Halpha      31.68     0.099      -2    15
# Comp:  2             [SII]6716      5.348      0.10      -2    20
# Comp:  2             [SII]6731      3.440      0.10      -2    20
# Comp:  2              HeII4687    0.01354      0.10      -2    20
# Comp:  2               HeI5876      1.124      0.10      -2    20
# Comp:  2          [OIII]5007_d      3.804      0.13      -2    20
# Comp:  2            [OI]6300_d     0.9902      0.13      -2    20
# Comp:  2           [NII]6583_d      13.80      0.13      -2    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18        70
#  comp.  1:         0        25
#  comp.  2:         2        28
# chi2/DOF: 0.7671; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.957      0.10       0    25
# Comp:  1                 Hbeta      12.02      0.10       0    25
# Comp:  1                Halpha      31.65      0.10       0    25
# Comp:  2             [SII]6716      5.374      0.10       2    28
# Comp:  2             [SII]6731      3.614      0.10       2    28
# Comp:  2              HeII4687   0.005577      0.10       2    28
# Comp:  2               HeI5876      1.185      0.10       2    28
# Comp:  2          [OIII]5007_d      3.659      0.13       2    28
# Comp:  2            [OI]6300_d     0.9265      0.13       2    28
# Comp:  2           [NII]6583_d      14.26      0.13       2    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        74
#  comp.  1:         0        12
#  comp.  2:         1        20
# chi2/DOF: 0.7886; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.713     0.099       0    12
# Comp:  1                 Hbeta      11.43     0.099       0    12
# Comp:  1                Halpha      32.20     0.099       0    12
# Comp:  2             [SII]6716      4.852      0.10       1    20
# Comp:  2             [SII]6731      3.319      0.10       1    20
# Comp:  2              HeII4687    0.02374      0.10       1    20
# Comp:  2               HeI5876      1.290      0.10       1    20
# Comp:  2          [OIII]5007_d      3.661      0.13       1    20
# Comp:  2            [OI]6300_d      1.016      0.13       1    20
# Comp:  2           [NII]6583_d      13.76      0.13       1    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        83
#  comp.  1:         1        20
#  comp.  2:         1        27
# chi2/DOF: 0.8480; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.028      0.10       1    20
# Comp:  1                 Hbeta      10.20      0.10       1    20
# Comp:  1                Halpha      31.09      0.10       1    20
# Comp:  2             [SII]6716      4.879      0.10       1    27
# Comp:  2             [SII]6731      3.692      0.10       1    27
# Comp:  2              HeII4687      0.000      0.10       1    27
# Comp:  2               HeI5876      1.268      0.10       1    27
# Comp:  2          [OIII]5007_d      3.724      0.13       1    27
# Comp:  2            [OI]6300_d     0.9477      0.13       1    27
# Comp:  2           [NII]6583_d      14.05      0.13       1    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        76
#  comp.  1:         2        14
#  comp.  2:        -1        27
# chi2/DOF: 0.7523; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.531     0.099       2    14
# Comp:  1                 Hbeta      11.61     0.099       2    14
# Comp:  1                Halpha      31.41     0.099       2    14
# Comp:  2             [SII]6716      4.859      0.10      -1    27
# Comp:  2             [SII]6731      3.607      0.10      -1    27
# Comp:  2              HeII4687      0.000      0.10      -1    27
# Comp:  2               HeI5876      1.183      0.10      -1    27
# Comp:  2          [OIII]5007_d      3.763      0.13      -1    27
# Comp:  2            [OI]6300_d      1.034      0.13      -1    27
# Comp:  2           [NII]6583_d      14.02      0.13      -1    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        77
#  comp.  1:         1        18
#  comp.  2:        -0        26
# chi2/DOF: 0.8414; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.357     0.099       1    18
# Comp:  1                 Hbeta      10.72     0.099       1    18
# Comp:  1                Halpha      31.19     0.099       1    18
# Comp:  2             [SII]6716      4.688      0.10      -0    26
# Comp:  2             [SII]6731      3.440      0.10      -0    26
# Comp:  2              HeII4687    0.02024      0.10      -0    26
# Comp:  2               HeI5876      1.147      0.10      -0    26
# Comp:  2          [OIII]5007_d      3.843      0.13      -0    26
# Comp:  2            [OI]6300_d     0.9757      0.13      -0    26
# Comp:  2           [NII]6583_d      13.99      0.13      -0    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2        73
#  comp.  1:         1        16
#  comp.  2:         1        27
# chi2/DOF: 0.8412; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.732     0.099       1    16
# Comp:  1                 Hbeta      10.87     0.099       1    16
# Comp:  1                Halpha      30.98     0.099       1    16
# Comp:  2             [SII]6716      5.016      0.10       1    27
# Comp:  2             [SII]6731      3.852      0.10       1    27
# Comp:  2              HeII4687      0.000      0.10       1    27
# Comp:  2               HeI5876      1.293      0.10       1    27
# Comp:  2          [OIII]5007_d      3.860      0.13       1    27
# Comp:  2            [OI]6300_d      1.020      0.13       1    27
# Comp:  2           [NII]6583_d      14.16      0.13       1    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        63
#  comp.  1:        -0        24
#  comp.  2:         1        26
# chi2/DOF: 0.7910; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.792      0.10      -0    24
# Comp:  1                 Hbeta      10.42      0.10      -0    24
# Comp:  1                Halpha      32.93      0.10      -0    24
# Comp:  2             [SII]6716      4.970      0.10       1    26
# Comp:  2             [SII]6731      3.406      0.10       1    26
# Comp:  2              HeII4687   0.002170      0.10       1    26
# Comp:  2               HeI5876      1.335      0.10       1    26
# Comp:  2          [OIII]5007_d      3.357      0.13       1    26
# Comp:  2            [OI]6300_d     0.9993      0.13       1    26
# Comp:  2           [NII]6583_d      14.29      0.13       1    26
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.48363874, 0.76899907, 0.67432464, 0.37413675, 0.20908131,
#        0.01860888, 0.08163821, 0.17037457, 0.04768152, 0.30065597])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([3.62743074e+00, 1.05462099e+01, 4.33810650e+01, 7.10997605e+00,
#        5.01084198e+00, 5.48058849e-03, 1.49317653e+00, 3.83316010e+00,
#        1.28667094e+00, 1.91618768e+01])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum3s_3_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum3s_3_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum3s_3_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum3s_3_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum3s_3_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0        Hgamma   1.260294    0.168033
# 1         Hbeta   3.664116    0.267177
# 2        Halpha  15.072074    0.234284
# 3     [SII]6716   2.470250    0.129988
# 4     [SII]6731   1.740939    0.072642
# 5      HeII4687   0.001904    0.006465
# 6       HeI5876   0.518781    0.028364
# 7  [OIII]5007_d   1.331772    0.059194
# 8    [OI]6300_d   0.447034    0.016566
# 9   [NII]6583_d   6.657495    0.104458
#           Name       Flux  Error_flux
# 0       Hgamma   1.260294    0.168033
# 1        Hbeta   3.664116    0.267177
# 2       Halpha  15.072074    0.234284
# 3    [SII]6716   2.470250    0.129988
# 4    [SII]6731   1.740939    0.072642
# 5     HeII4687   0.001904    0.006465
# 6      HeI5876   0.518781    0.028364
# 7   [OIII]4959   0.332943    0.059194
# 8   [OIII]5007   0.998829    0.059194
# 9     [OI]6300   0.335275    0.016566
# 10    [OI]6364   0.111758    0.016566
# 11   [NII]6548   1.664374    0.104458
# 12   [NII]6583   4.993121    0.104458

# %%
np.median(flux_rf_rebin)
# Out:
# 0.3474343896577466
