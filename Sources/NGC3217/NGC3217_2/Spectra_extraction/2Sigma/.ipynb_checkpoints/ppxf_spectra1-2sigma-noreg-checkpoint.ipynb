# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_1.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/Spectra_extraction/redshift.txt")     
z = red[0][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15798757 2.15870478 2.15942198 ... 3.43747274 3.43818994 3.43890714]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3161, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        28        60
# chi2/DOF: 0.007066; DOF: 1909; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:        38        47
# chi2/DOF: 0.005538; DOF: 1880; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# [0.71052616 0.72755728 0.75241076 ... 1.06426422 1.16768881 1.19750462]
# [0.72192088 0.73960263 0.75092143 ... 1.14943823 1.15020931 1.15107647]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([37.73755249, 47.08526423])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        78
#  comp.  1:         4        11
#  comp.  2:        10         1
# chi2/DOF: 1.199; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.227      0.15       4    11
# Comp:  1                 Hbeta      8.904      0.15       4    11
# Comp:  1                Halpha      45.24      0.15       4    11
# Comp:  2             [SII]6716      6.336      0.15      10     1
# Comp:  2             [SII]6731      5.064      0.15      10     1
# Comp:  2              HeII4687     0.1089      0.15      10     1
# Comp:  2               HeI5876      1.363      0.15      10     1
# Comp:  2          [OIII]5007_d      8.348      0.19      10     1
# Comp:  2            [OI]6300_d      1.438      0.19      10     1
# Comp:  2           [NII]6583_d      16.41      0.19      10     1
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:   14.3; gas flux:      3 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:   43.5; gas flux:      9 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:    214; gas flux:     62 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  30.46; gas flux:      9 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  25.29; gas flux:      7 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.4907; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:    6.2; gas flux:      2 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  29.88; gas flux:      9 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:    5.4; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  60.82; gas flux:     23 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -27       106
#  comp.  1:         5         3
#  comp.  2:         6        12
# chi2/DOF: 1.089; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.002      0.15       5     3
# Comp:  1                 Hbeta      7.687      0.15       5     3
# Comp:  1                Halpha      43.67      0.15       5     3
# Comp:  2             [SII]6716      6.336      0.15       6    12
# Comp:  2             [SII]6731      5.431      0.15       6    12
# Comp:  2              HeII4687     0.2964      0.15       6    12
# Comp:  2               HeI5876      1.482      0.15       6    12
# Comp:  2          [OIII]5007_d      9.045      0.19       6    12
# Comp:  2            [OI]6300_d      1.356      0.19       6    12
# Comp:  2           [NII]6583_d      16.32      0.19       6    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        81
#  comp.  1:         7         1
#  comp.  2:         7        13
# chi2/DOF: 1.093; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.021      0.15       7     1
# Comp:  1                 Hbeta      10.11      0.15       7     1
# Comp:  1                Halpha      44.94      0.15       7     1
# Comp:  2             [SII]6716      6.423      0.15       7    13
# Comp:  2             [SII]6731      4.874      0.15       7    13
# Comp:  2              HeII4687     0.3470      0.15       7    13
# Comp:  2               HeI5876     0.9610      0.15       7    13
# Comp:  2          [OIII]5007_d      9.396      0.19       7    13
# Comp:  2            [OI]6300_d      1.771      0.19       7    13
# Comp:  2           [NII]6583_d      16.79      0.19       7    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -111        41
#  comp.  1:         5         1
#  comp.  2:        11         1
# chi2/DOF: 1.141; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.241      0.15       5     1
# Comp:  1                 Hbeta      8.872      0.15       5     1
# Comp:  1                Halpha      45.94      0.15       5     1
# Comp:  2             [SII]6716      6.314      0.15      11     1
# Comp:  2             [SII]6731      5.088      0.15      11     1
# Comp:  2              HeII4687     0.3229      0.15      11     1
# Comp:  2               HeI5876      1.244      0.15      11     1
# Comp:  2          [OIII]5007_d      7.344      0.19      11     1
# Comp:  2            [OI]6300_d      1.314      0.19      11     1
# Comp:  2           [NII]6583_d      16.35      0.19      11     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26         1
#  comp.  1:         6        17
#  comp.  2:         9         1
# chi2/DOF: 1.136; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.104      0.15       6    17
# Comp:  1                 Hbeta      10.39      0.15       6    17
# Comp:  1                Halpha      45.87      0.15       6    17
# Comp:  2             [SII]6716      6.372      0.15       9     1
# Comp:  2             [SII]6731      5.069      0.15       9     1
# Comp:  2              HeII4687     0.1947      0.15       9     1
# Comp:  2               HeI5876      1.258      0.15       9     1
# Comp:  2          [OIII]5007_d      8.890      0.19       9     1
# Comp:  2            [OI]6300_d      1.237      0.19       9     1
# Comp:  2           [NII]6583_d      16.33      0.19       9     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        89
#  comp.  1:         4        18
#  comp.  2:        11         1
# chi2/DOF: 1.142; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.239      0.15       4    18
# Comp:  1                 Hbeta      8.788      0.15       4    18
# Comp:  1                Halpha      44.60      0.15       4    18
# Comp:  2             [SII]6716      6.393      0.15      11     1
# Comp:  2             [SII]6731      5.147      0.15      11     1
# Comp:  2              HeII4687      0.000      0.15      11     1
# Comp:  2               HeI5876      1.451      0.15      11     1
# Comp:  2          [OIII]5007_d      7.881      0.19      11     1
# Comp:  2            [OI]6300_d      1.171      0.19      11     1
# Comp:  2           [NII]6583_d      15.82      0.19      11     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        74
#  comp.  1:         2        17
#  comp.  2:        10         1
# chi2/DOF: 1.142; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.316      0.15       2    17
# Comp:  1                 Hbeta      9.031      0.15       2    17
# Comp:  1                Halpha      45.99      0.15       2    17
# Comp:  2             [SII]6716      6.152      0.15      10     1
# Comp:  2             [SII]6731      5.106      0.15      10     1
# Comp:  2              HeII4687      0.000      0.15      10     1
# Comp:  2               HeI5876      1.004      0.15      10     1
# Comp:  2          [OIII]5007_d      8.410      0.19      10     1
# Comp:  2            [OI]6300_d      1.284      0.19      10     1
# Comp:  2           [NII]6583_d      16.34      0.19      10     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26       118
#  comp.  1:         4        20
#  comp.  2:        13        16
# chi2/DOF: 1.120; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.088      0.16       4    20
# Comp:  1                 Hbeta      7.933      0.16       4    20
# Comp:  1                Halpha      44.84      0.16       4    20
# Comp:  2             [SII]6716      6.399      0.15      13    16
# Comp:  2             [SII]6731      4.891      0.15      13    16
# Comp:  2              HeII4687      0.000      0.15      13    16
# Comp:  2               HeI5876      1.169      0.15      13    16
# Comp:  2          [OIII]5007_d      8.588      0.19      13    16
# Comp:  2            [OI]6300_d      1.591      0.19      13    16
# Comp:  2           [NII]6583_d      16.71      0.19      13    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8       108
#  comp.  1:         5        17
#  comp.  2:        13         1
# chi2/DOF: 1.148; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.379      0.15       5    17
# Comp:  1                 Hbeta      7.997      0.15       5    17
# Comp:  1                Halpha      45.81      0.15       5    17
# Comp:  2             [SII]6716      6.235      0.15      13     1
# Comp:  2             [SII]6731      4.940      0.15      13     1
# Comp:  2              HeII4687     0.1316      0.15      13     1
# Comp:  2               HeI5876      1.383      0.15      13     1
# Comp:  2          [OIII]5007_d      7.956      0.19      13     1
# Comp:  2            [OI]6300_d      1.530      0.19      13     1
# Comp:  2           [NII]6583_d      16.08      0.19      13     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42         1
#  comp.  1:         3        14
#  comp.  2:         9         1
# chi2/DOF: 1.118; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.206      0.15       3    14
# Comp:  1                 Hbeta      10.11      0.15       3    14
# Comp:  1                Halpha      46.88      0.15       3    14
# Comp:  2             [SII]6716      6.260      0.15       9     1
# Comp:  2             [SII]6731      5.034      0.15       9     1
# Comp:  2              HeII4687    0.07082      0.15       9     1
# Comp:  2               HeI5876      1.151      0.15       9     1
# Comp:  2          [OIII]5007_d      8.785      0.19       9     1
# Comp:  2            [OI]6300_d      1.018      0.19       9     1
# Comp:  2           [NII]6583_d      16.51      0.19       9     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        59
#  comp.  1:         4         1
#  comp.  2:         9         1
# chi2/DOF: 1.143; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.588      0.15       4     1
# Comp:  1                 Hbeta      8.920      0.15       4     1
# Comp:  1                Halpha      46.16      0.15       4     1
# Comp:  2             [SII]6716      6.182      0.15       9     1
# Comp:  2             [SII]6731      5.094      0.15       9     1
# Comp:  2              HeII4687    0.05173      0.15       9     1
# Comp:  2               HeI5876      1.258      0.15       9     1
# Comp:  2          [OIII]5007_d      8.816      0.19       9     1
# Comp:  2            [OI]6300_d      1.432      0.19       9     1
# Comp:  2           [NII]6583_d      16.62      0.19       9     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        78
#  comp.  1:         7         4
#  comp.  2:        10         1
# chi2/DOF: 1.140; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.177      0.15       7     4
# Comp:  1                 Hbeta      9.917      0.15       7     4
# Comp:  1                Halpha      44.87      0.15       7     4
# Comp:  2             [SII]6716      6.356      0.15      10     1
# Comp:  2             [SII]6731      5.037      0.15      10     1
# Comp:  2              HeII4687     0.2552      0.15      10     1
# Comp:  2               HeI5876      1.395      0.15      10     1
# Comp:  2          [OIII]5007_d      7.809      0.19      10     1
# Comp:  2            [OI]6300_d      1.306      0.19      10     1
# Comp:  2           [NII]6583_d      16.27      0.19      10     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84       104
#  comp.  1:         5         5
#  comp.  2:         8         1
# chi2/DOF: 1.109; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.523      0.15       5     5
# Comp:  1                 Hbeta      7.768      0.15       5     5
# Comp:  1                Halpha      43.56      0.15       5     5
# Comp:  2             [SII]6716      6.613      0.15       8     1
# Comp:  2             [SII]6731      4.810      0.15       8     1
# Comp:  2              HeII4687     0.1632      0.15       8     1
# Comp:  2               HeI5876      1.332      0.15       8     1
# Comp:  2          [OIII]5007_d      8.805      0.19       8     1
# Comp:  2            [OI]6300_d      1.638      0.19       8     1
# Comp:  2           [NII]6583_d      16.13      0.19       8     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        76
#  comp.  1:         5        16
#  comp.  2:        11         1
# chi2/DOF: 1.175; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.280      0.15       5    16
# Comp:  1                 Hbeta      8.931      0.15       5    16
# Comp:  1                Halpha      45.76      0.15       5    16
# Comp:  2             [SII]6716      6.337      0.15      11     1
# Comp:  2             [SII]6731      4.785      0.15      11     1
# Comp:  2              HeII4687    0.09033      0.15      11     1
# Comp:  2               HeI5876      1.368      0.15      11     1
# Comp:  2          [OIII]5007_d      7.841      0.19      11     1
# Comp:  2            [OI]6300_d      1.629      0.19      11     1
# Comp:  2           [NII]6583_d      16.63      0.19      11     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26       133
#  comp.  1:         3        15
#  comp.  2:        11         1
# chi2/DOF: 1.125; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.117      0.15       3    15
# Comp:  1                 Hbeta      9.089      0.15       3    15
# Comp:  1                Halpha      46.95      0.15       3    15
# Comp:  2             [SII]6716      6.584      0.15      11     1
# Comp:  2             [SII]6731      5.113      0.15      11     1
# Comp:  2              HeII4687     0.3684      0.15      11     1
# Comp:  2               HeI5876     0.9800      0.15      11     1
# Comp:  2          [OIII]5007_d      7.930      0.19      11     1
# Comp:  2            [OI]6300_d      1.705      0.19      11     1
# Comp:  2           [NII]6583_d      15.88      0.19      11     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        60
#  comp.  1:         2        20
#  comp.  2:         8         1
# chi2/DOF: 1.131; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.314      0.15       2    20
# Comp:  1                 Hbeta      9.351      0.15       2    20
# Comp:  1                Halpha      46.29      0.15       2    20
# Comp:  2             [SII]6716      6.487      0.15       8     1
# Comp:  2             [SII]6731      5.005      0.15       8     1
# Comp:  2              HeII4687     0.1926      0.15       8     1
# Comp:  2               HeI5876      1.421      0.15       8     1
# Comp:  2          [OIII]5007_d      8.855      0.19       8     1
# Comp:  2            [OI]6300_d      1.668      0.19       8     1
# Comp:  2           [NII]6583_d      16.34      0.19       8     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        67
#  comp.  1:         5        15
#  comp.  2:         8         1
# chi2/DOF: 1.154; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.471      0.15       5    15
# Comp:  1                 Hbeta      9.073      0.15       5    15
# Comp:  1                Halpha      44.38      0.15       5    15
# Comp:  2             [SII]6716      6.121      0.15       8     1
# Comp:  2             [SII]6731      5.325      0.15       8     1
# Comp:  2              HeII4687     0.1447      0.15       8     1
# Comp:  2               HeI5876      1.528      0.15       8     1
# Comp:  2          [OIII]5007_d      8.839      0.19       8     1
# Comp:  2            [OI]6300_d      1.213      0.19       8     1
# Comp:  2           [NII]6583_d      16.68      0.19       8     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        87
#  comp.  1:         6         1
#  comp.  2:         8        10
# chi2/DOF: 1.134; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.269      0.15       6     1
# Comp:  1                 Hbeta      7.837      0.15       6     1
# Comp:  1                Halpha      44.76      0.15       6     1
# Comp:  2             [SII]6716      6.160      0.15       8    10
# Comp:  2             [SII]6731      5.408      0.15       8    10
# Comp:  2              HeII4687    0.08745      0.15       8    10
# Comp:  2               HeI5876      1.250      0.15       8    10
# Comp:  2          [OIII]5007_d      9.005      0.19       8    10
# Comp:  2            [OI]6300_d      1.489      0.19       8    10
# Comp:  2           [NII]6583_d      16.49      0.19       8    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        90
#  comp.  1:         7         1
#  comp.  2:        12         1
# chi2/DOF: 1.115; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.079      0.15       7     1
# Comp:  1                 Hbeta      7.722      0.15       7     1
# Comp:  1                Halpha      44.89      0.15       7     1
# Comp:  2             [SII]6716      6.346      0.15      12     1
# Comp:  2             [SII]6731      5.354      0.15      12     1
# Comp:  2              HeII4687     0.1941      0.15      12     1
# Comp:  2               HeI5876      1.452      0.15      12     1
# Comp:  2          [OIII]5007_d      8.327      0.19      12     1
# Comp:  2            [OI]6300_d      1.209      0.19      12     1
# Comp:  2           [NII]6583_d      16.58      0.19      12     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        73
#  comp.  1:         5        14
#  comp.  2:        10        15
# chi2/DOF: 1.131; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.399      0.15       5    14
# Comp:  1                 Hbeta      7.705      0.15       5    14
# Comp:  1                Halpha      44.27      0.15       5    14
# Comp:  2             [SII]6716      6.135      0.15      10    15
# Comp:  2             [SII]6731      5.101      0.15      10    15
# Comp:  2              HeII4687      0.000      0.15      10    15
# Comp:  2               HeI5876      1.675      0.15      10    15
# Comp:  2          [OIII]5007_d      8.040      0.19      10    15
# Comp:  2            [OI]6300_d      1.614      0.19      10    15
# Comp:  2           [NII]6583_d      16.80      0.19      10    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39       103
#  comp.  1:         5         1
#  comp.  2:         8        17
# chi2/DOF: 1.114; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.244      0.15       5     1
# Comp:  1                 Hbeta      9.152      0.15       5     1
# Comp:  1                Halpha      43.65      0.15       5     1
# Comp:  2             [SII]6716      6.254      0.15       8    17
# Comp:  2             [SII]6731      5.476      0.15       8    17
# Comp:  2              HeII4687     0.1053      0.15       8    17
# Comp:  2               HeI5876      1.326      0.15       8    17
# Comp:  2          [OIII]5007_d      9.194      0.19       8    17
# Comp:  2            [OI]6300_d      1.753      0.19       8    17
# Comp:  2           [NII]6583_d      16.84      0.19       8    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        79
#  comp.  1:         4         1
#  comp.  2:        10        17
# chi2/DOF: 1.146; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.503      0.15       4     1
# Comp:  1                 Hbeta      9.072      0.15       4     1
# Comp:  1                Halpha      46.25      0.15       4     1
# Comp:  2             [SII]6716      6.436      0.15      10    17
# Comp:  2             [SII]6731      5.162      0.15      10    17
# Comp:  2              HeII4687     0.1026      0.15      10    17
# Comp:  2               HeI5876      1.361      0.15      10    17
# Comp:  2          [OIII]5007_d      8.469      0.19      10    17
# Comp:  2            [OI]6300_d      1.368      0.19      10    17
# Comp:  2           [NII]6583_d      17.16      0.19      10    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46       108
#  comp.  1:         7         1
#  comp.  2:         9         1
# chi2/DOF: 1.148; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.419      0.15       7     1
# Comp:  1                 Hbeta      8.555      0.15       7     1
# Comp:  1                Halpha      44.72      0.15       7     1
# Comp:  2             [SII]6716      6.285      0.15       9     1
# Comp:  2             [SII]6731      5.122      0.15       9     1
# Comp:  2              HeII4687     0.3035      0.15       9     1
# Comp:  2               HeI5876      1.444      0.15       9     1
# Comp:  2          [OIII]5007_d      7.768      0.19       9     1
# Comp:  2            [OI]6300_d      1.486      0.19       9     1
# Comp:  2           [NII]6583_d      16.29      0.19       9     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56        51
#  comp.  1:         7         1
#  comp.  2:        10         1
# chi2/DOF: 1.101; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.228      0.15       7     1
# Comp:  1                 Hbeta      10.23      0.15       7     1
# Comp:  1                Halpha      44.83      0.15       7     1
# Comp:  2             [SII]6716      6.617      0.15      10     1
# Comp:  2             [SII]6731      5.333      0.15      10     1
# Comp:  2              HeII4687     0.1681      0.15      10     1
# Comp:  2               HeI5876      1.039      0.15      10     1
# Comp:  2          [OIII]5007_d      8.729      0.19      10     1
# Comp:  2            [OI]6300_d      1.184      0.19      10     1
# Comp:  2           [NII]6583_d      16.02      0.19      10     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        29        79
#  comp.  1:         6         5
#  comp.  2:         9         1
# chi2/DOF: 1.143; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.395      0.15       6     5
# Comp:  1                 Hbeta      7.832      0.15       6     5
# Comp:  1                Halpha      45.12      0.15       6     5
# Comp:  2             [SII]6716      6.395      0.15       9     1
# Comp:  2             [SII]6731      5.314      0.15       9     1
# Comp:  2              HeII4687     0.1439      0.15       9     1
# Comp:  2               HeI5876      1.040      0.15       9     1
# Comp:  2          [OIII]5007_d      7.486      0.19       9     1
# Comp:  2            [OI]6300_d      1.493      0.19       9     1
# Comp:  2           [NII]6583_d      16.35      0.19       9     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        74
#  comp.  1:         5        12
#  comp.  2:         8        22
# chi2/DOF: 1.134; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.091      0.15       5    12
# Comp:  1                 Hbeta      8.721      0.15       5    12
# Comp:  1                Halpha      43.89      0.15       5    12
# Comp:  2             [SII]6716      6.402      0.16       8    22
# Comp:  2             [SII]6731      4.999      0.16       8    22
# Comp:  2              HeII4687     0.2676      0.16       8    22
# Comp:  2               HeI5876      1.698      0.16       8    22
# Comp:  2          [OIII]5007_d      9.524      0.20       8    22
# Comp:  2            [OI]6300_d      1.450      0.20       8    22
# Comp:  2           [NII]6583_d      16.56      0.20       8    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        32
#  comp.  1:         7        12
#  comp.  2:        10         1
# chi2/DOF: 1.157; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.835      0.15       7    12
# Comp:  1                 Hbeta      9.075      0.15       7    12
# Comp:  1                Halpha      45.46      0.15       7    12
# Comp:  2             [SII]6716      6.136      0.15      10     1
# Comp:  2             [SII]6731      4.907      0.15      10     1
# Comp:  2              HeII4687     0.1692      0.15      10     1
# Comp:  2               HeI5876      1.521      0.15      10     1
# Comp:  2          [OIII]5007_d      8.280      0.19      10     1
# Comp:  2            [OI]6300_d      1.094      0.19      10     1
# Comp:  2           [NII]6583_d      16.59      0.19      10     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        50
#  comp.  1:         3        13
#  comp.  2:         9        18
# chi2/DOF: 1.169; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.229      0.15       3    13
# Comp:  1                 Hbeta      9.090      0.15       3    13
# Comp:  1                Halpha      45.33      0.15       3    13
# Comp:  2             [SII]6716      6.382      0.15       9    18
# Comp:  2             [SII]6731      5.444      0.15       9    18
# Comp:  2              HeII4687    0.05904      0.15       9    18
# Comp:  2               HeI5876      1.520      0.15       9    18
# Comp:  2          [OIII]5007_d      8.000      0.20       9    18
# Comp:  2            [OI]6300_d      1.639      0.20       9    18
# Comp:  2           [NII]6583_d      16.69      0.20       9    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -49        69
#  comp.  1:         3        12
#  comp.  2:         8         1
# chi2/DOF: 1.106; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.188      0.15       3    12
# Comp:  1                 Hbeta      7.692      0.15       3    12
# Comp:  1                Halpha      46.75      0.15       3    12
# Comp:  2             [SII]6716      6.144      0.15       8     1
# Comp:  2             [SII]6731      4.991      0.15       8     1
# Comp:  2              HeII4687     0.1186      0.15       8     1
# Comp:  2               HeI5876      1.391      0.15       8     1
# Comp:  2          [OIII]5007_d      8.002      0.19       8     1
# Comp:  2            [OI]6300_d      1.515      0.19       8     1
# Comp:  2           [NII]6583_d      16.22      0.19       8     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        17
#  comp.  1:         3        12
#  comp.  2:        10         1
# chi2/DOF: 1.141; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.456      0.15       3    12
# Comp:  1                 Hbeta      8.975      0.15       3    12
# Comp:  1                Halpha      46.56      0.15       3    12
# Comp:  2             [SII]6716      6.300      0.15      10     1
# Comp:  2             [SII]6731      5.052      0.15      10     1
# Comp:  2              HeII4687    0.02307      0.15      10     1
# Comp:  2               HeI5876      1.760      0.15      10     1
# Comp:  2          [OIII]5007_d      8.349      0.19      10     1
# Comp:  2            [OI]6300_d      1.294      0.19      10     1
# Comp:  2           [NII]6583_d      16.52      0.19      10     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        71
#  comp.  1:         4        17
#  comp.  2:         8         1
# chi2/DOF: 1.147; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.156      0.15       4    17
# Comp:  1                 Hbeta      10.18      0.15       4    17
# Comp:  1                Halpha      45.64      0.15       4    17
# Comp:  2             [SII]6716      6.449      0.15       8     1
# Comp:  2             [SII]6731      5.085      0.15       8     1
# Comp:  2              HeII4687     0.1141      0.15       8     1
# Comp:  2               HeI5876      1.290      0.15       8     1
# Comp:  2          [OIII]5007_d      8.905      0.19       8     1
# Comp:  2            [OI]6300_d     0.9812      0.19       8     1
# Comp:  2           [NII]6583_d      16.49      0.19       8     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        77
#  comp.  1:         5        17
#  comp.  2:         9         1
# chi2/DOF: 1.126; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.390      0.15       5    17
# Comp:  1                 Hbeta      7.930      0.15       5    17
# Comp:  1                Halpha      44.70      0.15       5    17
# Comp:  2             [SII]6716      6.239      0.15       9     1
# Comp:  2             [SII]6731      5.275      0.15       9     1
# Comp:  2              HeII4687     0.1342      0.15       9     1
# Comp:  2               HeI5876      1.509      0.15       9     1
# Comp:  2          [OIII]5007_d      8.706      0.19       9     1
# Comp:  2            [OI]6300_d      1.567      0.19       9     1
# Comp:  2           [NII]6583_d      16.55      0.19       9     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        56
#  comp.  1:         3         1
#  comp.  2:        12        13
# chi2/DOF: 1.139; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 69; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.581      0.15       3     1
# Comp:  1                 Hbeta      8.830      0.15       3     1
# Comp:  1                Halpha      46.25      0.15       3     1
# Comp:  2             [SII]6716      6.436      0.15      12    13
# Comp:  2             [SII]6731      5.087      0.15      12    13
# Comp:  2              HeII4687      0.000      0.15      12    13
# Comp:  2               HeI5876      1.234      0.15      12    13
# Comp:  2          [OIII]5007_d      7.788      0.19      12    13
# Comp:  2            [OI]6300_d      1.671      0.19      12    13
# Comp:  2           [NII]6583_d      16.72      0.19      12    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24       120
#  comp.  1:         3         4
#  comp.  2:         9         6
# chi2/DOF: 1.145; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.257      0.15       3     4
# Comp:  1                 Hbeta      7.812      0.15       3     4
# Comp:  1                Halpha      44.87      0.15       3     4
# Comp:  2             [SII]6716      6.205      0.15       9     6
# Comp:  2             [SII]6731      4.838      0.15       9     6
# Comp:  2              HeII4687     0.2993      0.15       9     6
# Comp:  2               HeI5876      1.605      0.15       9     6
# Comp:  2          [OIII]5007_d      8.864      0.19       9     6
# Comp:  2            [OI]6300_d      1.740      0.19       9     6
# Comp:  2           [NII]6583_d      15.95      0.19       9     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        54
#  comp.  1:         3        13
#  comp.  2:        11         1
# chi2/DOF: 1.111; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.468      0.15       3    13
# Comp:  1                 Hbeta      7.942      0.15       3    13
# Comp:  1                Halpha      46.89      0.15       3    13
# Comp:  2             [SII]6716      6.354      0.15      11     1
# Comp:  2             [SII]6731      5.182      0.15      11     1
# Comp:  2              HeII4687     0.1536      0.15      11     1
# Comp:  2               HeI5876     0.9778      0.15      11     1
# Comp:  2          [OIII]5007_d      8.262      0.19      11     1
# Comp:  2            [OI]6300_d      1.780      0.19      11     1
# Comp:  2           [NII]6583_d      16.49      0.19      11     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26       100
#  comp.  1:         2        20
#  comp.  2:        11         1
# chi2/DOF: 1.122; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.294      0.16       2    20
# Comp:  1                 Hbeta      10.06      0.16       2    20
# Comp:  1                Halpha      46.16      0.16       2    20
# Comp:  2             [SII]6716      6.327      0.15      11     1
# Comp:  2             [SII]6731      5.285      0.15      11     1
# Comp:  2              HeII4687     0.1735      0.15      11     1
# Comp:  2               HeI5876      1.359      0.15      11     1
# Comp:  2          [OIII]5007_d      7.822      0.19      11     1
# Comp:  2            [OI]6300_d      1.285      0.19      11     1
# Comp:  2           [NII]6583_d      16.27      0.19      11     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -54       143
#  comp.  1:         6         7
#  comp.  2:        10        15
# chi2/DOF: 1.168; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.361      0.15       6     7
# Comp:  1                 Hbeta      9.015      0.15       6     7
# Comp:  1                Halpha      45.02      0.15       6     7
# Comp:  2             [SII]6716      6.430      0.15      10    15
# Comp:  2             [SII]6731      5.414      0.15      10    15
# Comp:  2              HeII4687     0.1963      0.15      10    15
# Comp:  2               HeI5876      1.464      0.15      10    15
# Comp:  2          [OIII]5007_d      9.020      0.19      10    15
# Comp:  2            [OI]6300_d      1.210      0.19      10    15
# Comp:  2           [NII]6583_d      16.49      0.19      10    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28         1
#  comp.  1:         4        20
#  comp.  2:        10         1
# chi2/DOF: 1.117; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.447      0.15       4    20
# Comp:  1                 Hbeta      7.729      0.15       4    20
# Comp:  1                Halpha      44.80      0.15       4    20
# Comp:  2             [SII]6716      6.445      0.15      10     1
# Comp:  2             [SII]6731      5.065      0.15      10     1
# Comp:  2              HeII4687     0.3132      0.15      10     1
# Comp:  2               HeI5876      1.383      0.15      10     1
# Comp:  2          [OIII]5007_d      8.820      0.19      10     1
# Comp:  2            [OI]6300_d      1.302      0.19      10     1
# Comp:  2           [NII]6583_d      16.70      0.19      10     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64        92
#  comp.  1:         5        18
#  comp.  2:        10         1
# chi2/DOF: 1.148; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.201      0.15       5    18
# Comp:  1                 Hbeta      9.199      0.15       5    18
# Comp:  1                Halpha      44.66      0.15       5    18
# Comp:  2             [SII]6716      6.134      0.15      10     1
# Comp:  2             [SII]6731      5.371      0.15      10     1
# Comp:  2              HeII4687    0.09491      0.15      10     1
# Comp:  2               HeI5876      1.472      0.15      10     1
# Comp:  2          [OIII]5007_d      8.352      0.19      10     1
# Comp:  2            [OI]6300_d      1.267      0.19      10     1
# Comp:  2           [NII]6583_d      16.55      0.19      10     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        70
#  comp.  1:         4        20
#  comp.  2:        13         1
# chi2/DOF: 1.107; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.420      0.15       4    20
# Comp:  1                 Hbeta      7.983      0.15       4    20
# Comp:  1                Halpha      44.92      0.15       4    20
# Comp:  2             [SII]6716      6.269      0.15      13     1
# Comp:  2             [SII]6731      4.979      0.15      13     1
# Comp:  2              HeII4687    0.08991      0.15      13     1
# Comp:  2               HeI5876      1.489      0.15      13     1
# Comp:  2          [OIII]5007_d      7.922      0.19      13     1
# Comp:  2            [OI]6300_d      1.480      0.19      13     1
# Comp:  2           [NII]6583_d      16.25      0.19      13     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        54
#  comp.  1:         2         9
#  comp.  2:        10        12
# chi2/DOF: 1.124; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.438      0.15       2     9
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -65        52
#  comp.  1:         5        16
#  comp.  2:        13         4
# chi2/DOF: 1.168; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.477      0.15       5    16
# Comp:  1                 Hbeta      8.854      0.15       5    16
# Comp:  1                Halpha      45.71      0.15       5    16
# Comp:  2             [SII]6716      6.411      0.15      13     4
# Comp:  2             [SII]6731      5.082      0.15      13     4
# Comp:  2              HeII4687     0.2989      0.15      13     4
# Comp:  2               HeI5876      1.328      0.15      13     4
# Comp:  2          [OIII]5007_d      7.842      0.19      13     4
# Comp:  2            [OI]6300_d      1.737      0.19      13     4
# Comp:  2           [NII]6583_d      16.28      0.19      13     4
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        21
#  comp.  1:         2        21
#  comp.  2:        11         1
# chi2/DOF: 1.135; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.092      0.16       2    21
# Comp:  1                 Hbeta      9.162      0.16       2    21
# Comp:  1                Halpha      46.33      0.16       2    21
# Comp:  2             [SII]6716      6.311      0.15      11     1
# Comp:  2             [SII]6731      5.142      0.15      11     1
# Comp:  2              HeII4687      0.000      0.15      11     1
# Comp:  2               HeI5876      1.485      0.15      11     1
# Comp:  2          [OIII]5007_d      7.781      0.19      11     1
# Comp:  2            [OI]6300_d      1.286      0.19      11     1
# Comp:  2           [NII]6583_d      16.46      0.19      11     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30       144
#  comp.  1:         2        11
#  comp.  2:        10         1
# chi2/DOF: 1.130; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.323      0.15       2    11
# Comp:  1                 Hbeta      7.667      0.15       2    11
# Comp:  1                Halpha      45.12      0.15       2    11
# Comp:  2             [SII]6716      6.080      0.15      10     1
# Comp:  2             [SII]6731      4.809      0.15      10     1
# Comp:  2              HeII4687     0.1117      0.15      10     1
# Comp:  2               HeI5876      1.160      0.15      10     1
# Comp:  2          [OIII]5007_d      8.416      0.19      10     1
# Comp:  2            [OI]6300_d      1.615      0.19      10     1
# Comp:  2           [NII]6583_d      16.20      0.19      10     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        45
#  comp.  1:         2        10
#  comp.  2:        10         1
# chi2/DOF: 1.126; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.081      0.15       2    10
# Comp:  1                 Hbeta      7.756      0.15       2    10
# Comp:  1                Halpha      45.12      0.15       2    10
# Comp:  2             [SII]6716      6.480      0.15      10     1
# Comp:  2             [SII]6731      5.086      0.15      10     1
# Comp:  2              HeII4687     0.2696      0.15      10     1
# Comp:  2               HeI5876      1.181      0.15      10     1
# Comp:  2          [OIII]5007_d      7.450      0.19      10     1
# Comp:  2            [OI]6300_d      1.379      0.19      10     1
# Comp:  2           [NII]6583_d      16.20      0.19      10     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78       118
#  comp.  1:         7        13
#  comp.  2:        11        16
# chi2/DOF: 1.101; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.381      0.15       7    13
# Comp:  1                 Hbeta      9.977      0.15       7    13
# Comp:  1                Halpha      44.14      0.15       7    13
# Comp:  2             [SII]6716      6.633      0.15      11    16
# Comp:  2             [SII]6731      4.963      0.15      11    16
# Comp:  2              HeII4687    0.08176      0.15      11    16
# Comp:  2               HeI5876      1.686      0.15      11    16
# Comp:  2          [OIII]5007_d      8.753      0.19      11    16
# Comp:  2            [OI]6300_d      1.458      0.19      11    16
# Comp:  2           [NII]6583_d      16.68      0.19      11    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        32
#  comp.  1:         4         1
#  comp.  2:        15         1
# chi2/DOF: 1.115; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.981      0.15       4     1
# Comp:  1                 Hbeta      9.852      0.15       4     1
# Comp:  1                Halpha      46.01      0.15       4     1
# Comp:  2             [SII]6716      6.114      0.15      15     1
# Comp:  2             [SII]6731      4.815      0.15      15     1
# Comp:  2              HeII4687     0.1778      0.15      15     1
# Comp:  2               HeI5876      1.472      0.15      15     1
# Comp:  2          [OIII]5007_d      7.895      0.19      15     1
# Comp:  2            [OI]6300_d      1.382      0.19      15     1
# Comp:  2           [NII]6583_d      16.51      0.19      15     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4        67
#  comp.  1:         2        21
#  comp.  2:         9         1
# chi2/DOF: 1.112; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.658      0.16       2    21
# Comp:  1                 Hbeta      8.083      0.16       2    21
# Comp:  1                Halpha      46.33      0.16       2    21
# Comp:  2             [SII]6716      6.440      0.15       9     1
# Comp:  2             [SII]6731      5.066      0.15       9     1
# Comp:  2              HeII4687    0.05724      0.15       9     1
# Comp:  2               HeI5876      1.511      0.15       9     1
# Comp:  2          [OIII]5007_d      8.387      0.19       9     1
# Comp:  2            [OI]6300_d      1.421      0.19       9     1
# Comp:  2           [NII]6583_d      16.42      0.19       9     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22       140
#  comp.  1:         6         7
#  comp.  2:         7        10
# chi2/DOF: 1.114; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.999      0.15       6     7
# Comp:  1                 Hbeta      7.876      0.15       6     7
# Comp:  1                Halpha      43.82      0.15       6     7
# Comp:  2             [SII]6716      6.322      0.15       7    10
# Comp:  2             [SII]6731      5.085      0.15       7    10
# Comp:  2              HeII4687     0.2971      0.15       7    10
# Comp:  2               HeI5876      1.277      0.15       7    10
# Comp:  2          [OIII]5007_d      8.873      0.19       7    10
# Comp:  2            [OI]6300_d      1.072      0.19       7    10
# Comp:  2           [NII]6583_d      16.91      0.19       7    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38       124
#  comp.  1:         3        14
#  comp.  2:        11         2
# chi2/DOF: 1.081; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.383      0.15       3    14
# Comp:  1                 Hbeta      7.671      0.15       3    14
# Comp:  1                Halpha      46.73      0.15       3    14
# Comp:  2             [SII]6716      6.519      0.15      11     2
# Comp:  2             [SII]6731      5.261      0.15      11     2
# Comp:  2              HeII4687     0.2333      0.15      11     2
# Comp:  2               HeI5876      1.286      0.15      11     2
# Comp:  2          [OIII]5007_d      7.518      0.19      11     2
# Comp:  2            [OI]6300_d      1.451      0.19      11     2
# Comp:  2           [NII]6583_d      16.18      0.19      11     2
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        91
#  comp.  1:         5        15
#  comp.  2:         8         1
# chi2/DOF: 1.151; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.003      0.15       5    15
# Comp:  1                 Hbeta      9.289      0.15       5    15
# Comp:  1                Halpha      44.29      0.15       5    15
# Comp:  2             [SII]6716      6.552      0.15       8     1
# Comp:  2             [SII]6731      4.835      0.15       8     1
# Comp:  2              HeII4687    0.05361      0.15       8     1
# Comp:  2               HeI5876      1.453      0.15       8     1
# Comp:  2          [OIII]5007_d      8.442      0.19       8     1
# Comp:  2            [OI]6300_d      1.254      0.19       8     1
# Comp:  2           [NII]6583_d      16.50      0.19       8     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        93
#  comp.  1:         3        14
#  comp.  2:        10         1
# chi2/DOF: 1.112; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.062      0.15       3    14
# Comp:  1                 Hbeta      9.124      0.15       3    14
# Comp:  1                Halpha      47.01      0.15       3    14
# Comp:  2             [SII]6716      6.469      0.15      10     1
# Comp:  2             [SII]6731      4.764      0.15      10     1
# Comp:  2              HeII4687    0.04641      0.15      10     1
# Comp:  2               HeI5876      1.648      0.15      10     1
# Comp:  2          [OIII]5007_d      9.405      0.19      10     1
# Comp:  2            [OI]6300_d      1.860      0.19      10     1
# Comp:  2           [NII]6583_d      16.27      0.19      10     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        91
#  comp.  1:         4        10
#  comp.  2:         7         1
# chi2/DOF: 1.107; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.563      0.15       4    10
# Comp:  1                 Hbeta      10.39      0.15       4    10
# Comp:  1                Halpha      46.89      0.15       4    10
# Comp:  2             [SII]6716      6.262      0.15       7     1
# Comp:  2             [SII]6731      5.099      0.15       7     1
# Comp:  2              HeII4687    0.07590      0.15       7     1
# Comp:  2               HeI5876      1.578      0.15       7     1
# Comp:  2          [OIII]5007_d      8.885      0.19       7     1
# Comp:  2            [OI]6300_d      1.832      0.19       7     1
# Comp:  2           [NII]6583_d      16.18      0.19       7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        13
#  comp.  1:         7        11
#  comp.  2:         8        19
# chi2/DOF: 1.150; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.904      0.15       7    11
# Comp:  1                 Hbeta      8.744      0.15       7    11
# Comp:  1                Halpha      45.12      0.15       7    11
# Comp:  2             [SII]6716      6.430      0.15       8    19
# Comp:  2             [SII]6731      5.133      0.15       8    19
# Comp:  2              HeII4687      0.000      0.15       8    19
# Comp:  2               HeI5876      1.250      0.15       8    19
# Comp:  2          [OIII]5007_d      8.138      0.20       8    19
# Comp:  2            [OI]6300_d      1.353      0.20       8    19
# Comp:  2           [NII]6583_d      16.53      0.20       8    19
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.21256239, 0.89276378, 1.16427196, 0.23077025, 0.27069381,
#        0.10870148, 0.26417461, 0.60188003, 0.28075112, 0.46316867])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 2.92112723,  9.02856928, 61.92938688,  8.87607111,  7.10886773,
#         0.10643537,  1.67039676,  8.7184124 ,  1.88970313, 22.5382903 ])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_1_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_1_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_1_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_1_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_1_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0        Hgamma  0.346544    0.025217
# 1         Hbeta  1.071093    0.105912
# 2        Halpha  7.346917    0.138122
# 3     [SII]6716  1.053002    0.027377
# 4     [SII]6731  0.843352    0.032113
# 5      HeII4687  0.012627    0.012896
# 6       HeI5876  0.198165    0.031340
# 7  [OIII]5007_d  1.034298    0.071403
# 8    [OI]6300_d  0.224183    0.033307
# 9   [NII]6583_d  2.673802    0.054947
#           Name      Flux  Error_flux
# 0       Hgamma  0.346544    0.025217
# 1        Hbeta  1.071093    0.105912
# 2       Halpha  7.346917    0.138122
# 3    [SII]6716  1.053002    0.027377
# 4    [SII]6731  0.843352    0.032113
# 5     HeII4687  0.012627    0.012896
# 6      HeI5876  0.198165    0.031340
# 7   [OIII]4959  0.258575    0.071403
# 8   [OIII]5007  0.775724    0.071403
# 9     [OI]6300  0.168137    0.033307
# 10    [OI]6364  0.056046    0.033307
# 11   [NII]6548  0.668451    0.054947
# 12   [NII]6583  2.005352    0.054947

# %%
np.median(flux_rf_rebin)
# Out:
# 0.11863376943667293
