# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_2.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/Spectra_extraction/redshift.txt") 
z = red[1][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_2']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4316.35165261 4317.78617815 4319.22070369 ... 6875.54521663 6876.97974217
#  6878.41426771] [0.51776087 0.54091906 0.55380054 ... 0.45345543 0.45753888 0.45707131] [0.0237291 0.0237291 0.0237291 ... 0.0237291 0.0237291 0.0237291]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15817583 2.15889309 2.15961035 ... 3.43777261 3.43848987 3.43920713]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3160, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3160, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3160, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        22        85
# chi2/DOF: 0.0007931; DOF: 1909; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/150
#  Best Fit:       Vel     sigma
#  comp.  0:        23        83
# chi2/DOF: 0.0005003; DOF: 1876; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([22.78437688, 82.58168883])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        39        70
#  comp.  1:        26        36
#  comp.  2:        28        42
# chi2/DOF: 0.6040; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.181     0.087      26    36
# Comp:  1                 Hbeta      7.988     0.087      26    36
# Comp:  1                Halpha      25.94     0.087      26    36
# Comp:  2             [SII]6716      4.523     0.089      28    42
# Comp:  2             [SII]6731      3.460     0.089      28    42
# Comp:  2              HeII4687      0.000     0.089      28    42
# Comp:  2               HeI5876     0.6680     0.089      28    42
# Comp:  2          [OIII]5007_d      2.553      0.11      28    42
# Comp:  2            [OI]6300_d     0.8450      0.11      28    42
# Comp:  2           [NII]6583_d      14.07      0.11      28    42
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  39.46; gas flux:      3 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  104.1; gas flux:      8 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:    327; gas flux:     36 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  54.39; gas flux:      6 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  43.59; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:   8.18; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  24.05; gas flux:      3 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:   8.06; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  130.7; gas flux:     19 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        41        63
#  comp.  1:        26        34
#  comp.  2:        25        42
# chi2/DOF: 0.5762; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.086     0.087      26    34
# Comp:  1                 Hbeta      8.268     0.087      26    34
# Comp:  1                Halpha      25.62     0.087      26    34
# Comp:  2             [SII]6716      4.489     0.089      25    42
# Comp:  2             [SII]6731      3.631     0.089      25    42
# Comp:  2              HeII4687    0.03905     0.089      25    42
# Comp:  2               HeI5876     0.7460     0.089      25    42
# Comp:  2          [OIII]5007_d      2.850      0.11      25    42
# Comp:  2            [OI]6300_d     0.8616      0.11      25    42
# Comp:  2           [NII]6583_d      13.93      0.11      25    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        46        89
#  comp.  1:        27        31
#  comp.  2:        28        44
# chi2/DOF: 0.5577; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.026     0.086      27    31
# Comp:  1                 Hbeta      8.164     0.086      27    31
# Comp:  1                Halpha      25.57     0.086      27    31
# Comp:  2             [SII]6716      4.553     0.090      28    44
# Comp:  2             [SII]6731      3.373     0.090      28    44
# Comp:  2              HeII4687    0.03515     0.090      28    44
# Comp:  2               HeI5876     0.5670     0.090      28    44
# Comp:  2          [OIII]5007_d      2.798      0.11      28    44
# Comp:  2            [OI]6300_d     0.8706      0.11      28    44
# Comp:  2           [NII]6583_d      14.16      0.11      28    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41        70
#  comp.  1:        26        34
#  comp.  2:        30        40
# chi2/DOF: 0.5683; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.126     0.087      26    34
# Comp:  1                 Hbeta      7.368     0.087      26    34
# Comp:  1                Halpha      25.65     0.087      26    34
# Comp:  2             [SII]6716      4.473     0.088      30    40
# Comp:  2             [SII]6731      3.491     0.088      30    40
# Comp:  2              HeII4687      0.000     0.088      30    40
# Comp:  2               HeI5876     0.6890     0.088      30    40
# Comp:  2          [OIII]5007_d      2.282      0.11      30    40
# Comp:  2            [OI]6300_d     0.8357      0.11      30    40
# Comp:  2           [NII]6583_d      14.01      0.11      30    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34        79
#  comp.  1:        26        37
#  comp.  2:        29        37
# chi2/DOF: 0.5746; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.285     0.088      26    37
# Comp:  1                 Hbeta      7.823     0.088      26    37
# Comp:  1                Halpha      26.22     0.088      26    37
# Comp:  2             [SII]6716      4.460     0.088      29    37
# Comp:  2             [SII]6731      3.323     0.088      29    37
# Comp:  2              HeII4687    0.04500     0.088      29    37
# Comp:  2               HeI5876     0.7114     0.088      29    37
# Comp:  2          [OIII]5007_d      2.781      0.11      29    37
# Comp:  2            [OI]6300_d     0.8049      0.11      29    37
# Comp:  2           [NII]6583_d      13.94      0.11      29    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36        71
#  comp.  1:        26        37
#  comp.  2:        26        38
# chi2/DOF: 0.5630; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.142     0.087      26    37
# Comp:  1                 Hbeta      8.576     0.087      26    37
# Comp:  1                Halpha      26.07     0.087      26    37
# Comp:  2             [SII]6716      4.417     0.088      26    38
# Comp:  2             [SII]6731      3.440     0.088      26    38
# Comp:  2              HeII4687   0.009204     0.088      26    38
# Comp:  2               HeI5876     0.7380     0.088      26    38
# Comp:  2          [OIII]5007_d      2.157      0.11      26    38
# Comp:  2            [OI]6300_d     0.8095      0.11      26    38
# Comp:  2           [NII]6583_d      13.57      0.11      26    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38        77
#  comp.  1:        26        37
#  comp.  2:        30        40
# chi2/DOF: 0.5691; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.557     0.088      26    37
# Comp:  1                 Hbeta      8.771     0.088      26    37
# Comp:  1                Halpha      26.38     0.088      26    37
# Comp:  2             [SII]6716      4.405     0.089      30    40
# Comp:  2             [SII]6731      3.459     0.089      30    40
# Comp:  2              HeII4687      0.000     0.089      30    40
# Comp:  2               HeI5876     0.5872     0.089      30    40
# Comp:  2          [OIII]5007_d      2.589      0.11      30    40
# Comp:  2            [OI]6300_d     0.8117      0.11      30    40
# Comp:  2           [NII]6583_d      13.62      0.11      30    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        32        82
#  comp.  1:        26        38
#  comp.  2:        31        45
# chi2/DOF: 0.5440; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.502     0.088      26    38
# Comp:  1                 Hbeta      7.782     0.088      26    38
# Comp:  1                Halpha      26.55     0.088      26    38
# Comp:  2             [SII]6716      4.581     0.090      31    45
# Comp:  2             [SII]6731      3.415     0.090      31    45
# Comp:  2              HeII4687      0.000     0.090      31    45
# Comp:  2               HeI5876     0.6127     0.090      31    45
# Comp:  2          [OIII]5007_d      2.569      0.11      31    45
# Comp:  2            [OI]6300_d     0.8563      0.11      31    45
# Comp:  2           [NII]6583_d      14.40      0.11      31    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        74
#  comp.  1:        27        40
#  comp.  2:        30        41
# chi2/DOF: 0.5543; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.360     0.088      27    40
# Comp:  1                 Hbeta      7.638     0.088      27    40
# Comp:  1                Halpha      26.50     0.088      27    40
# Comp:  2             [SII]6716      4.543     0.089      30    41
# Comp:  2             [SII]6731      3.382     0.089      30    41
# Comp:  2              HeII4687    0.03995     0.089      30    41
# Comp:  2               HeI5876     0.6849     0.089      30    41
# Comp:  2          [OIII]5007_d      2.138      0.11      30    41
# Comp:  2            [OI]6300_d     0.8251      0.11      30    41
# Comp:  2           [NII]6583_d      14.02      0.11      30    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        71
#  comp.  1:        25        37
#  comp.  2:        27        45
# chi2/DOF: 0.5839; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.507     0.087      25    37
# Comp:  1                 Hbeta      8.353     0.087      25    37
# Comp:  1                Halpha      26.14     0.087      25    37
# Comp:  2             [SII]6716      4.464     0.090      27    45
# Comp:  2             [SII]6731      3.576     0.090      27    45
# Comp:  2              HeII4687      0.000     0.090      27    45
# Comp:  2               HeI5876     0.5986     0.090      27    45
# Comp:  2          [OIII]5007_d      2.505      0.11      27    45
# Comp:  2            [OI]6300_d     0.8185      0.11      27    45
# Comp:  2           [NII]6583_d      14.31      0.11      27    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33        69
#  comp.  1:        27        31
#  comp.  2:        27        38
# chi2/DOF: 0.5456; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.198     0.086      27    31
# Comp:  1                 Hbeta      8.311     0.086      27    31
# Comp:  1                Halpha      25.33     0.086      27    31
# Comp:  2             [SII]6716      4.385     0.088      27    38
# Comp:  2             [SII]6731      3.442     0.088      27    38
# Comp:  2              HeII4687      0.000     0.088      27    38
# Comp:  2               HeI5876     0.7074     0.088      27    38
# Comp:  2          [OIII]5007_d      2.373      0.11      27    38
# Comp:  2            [OI]6300_d     0.8056      0.11      27    38
# Comp:  2           [NII]6583_d      13.74      0.11      27    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        49        64
#  comp.  1:        26        37
#  comp.  2:        28        40
# chi2/DOF: 0.5574; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.063     0.087      26    37
# Comp:  1                 Hbeta      8.730     0.087      26    37
# Comp:  1                Halpha      25.99     0.087      26    37
# Comp:  2             [SII]6716      4.440     0.089      28    40
# Comp:  2             [SII]6731      3.419     0.089      28    40
# Comp:  2              HeII4687    0.03562     0.089      28    40
# Comp:  2               HeI5876     0.6579     0.089      28    40
# Comp:  2          [OIII]5007_d      2.160      0.11      28    40
# Comp:  2            [OI]6300_d     0.8299      0.11      28    40
# Comp:  2           [NII]6583_d      13.73      0.11      28    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        74
#  comp.  1:        28        31
#  comp.  2:        26        37
# chi2/DOF: 0.5215; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.452     0.086      28    31
# Comp:  1                 Hbeta      7.313     0.086      28    31
# Comp:  1                Halpha      25.51     0.086      28    31
# Comp:  2             [SII]6716      4.586     0.088      26    37
# Comp:  2             [SII]6731      3.259     0.088      26    37
# Comp:  2              HeII4687    0.02244     0.088      26    37
# Comp:  2               HeI5876     0.6530     0.088      26    37
# Comp:  2          [OIII]5007_d      2.896      0.11      26    37
# Comp:  2            [OI]6300_d     0.8364      0.11      26    37
# Comp:  2           [NII]6583_d      13.72      0.11      26    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38        76
#  comp.  1:        26        40
#  comp.  2:        29        41
# chi2/DOF: 0.5618; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.411     0.089      26    40
# Comp:  1                 Hbeta      8.723     0.089      26    40
# Comp:  1                Halpha      26.64     0.089      26    40
# Comp:  2             [SII]6716      4.511     0.089      29    41
# Comp:  2             [SII]6731      3.282     0.089      29    41
# Comp:  2              HeII4687      0.000     0.089      29    41
# Comp:  2               HeI5876     0.6649     0.089      29    41
# Comp:  2          [OIII]5007_d      2.198      0.11      29    41
# Comp:  2            [OI]6300_d     0.8546      0.11      29    41
# Comp:  2           [NII]6583_d      13.97      0.11      29    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34        63
#  comp.  1:        26        38
#  comp.  2:        27        37
# chi2/DOF: 0.5311; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.234     0.088      26    38
# Comp:  1                 Hbeta      7.096     0.088      26    38
# Comp:  1                Halpha      26.26     0.088      26    38
# Comp:  2             [SII]6716      4.601     0.088      27    37
# Comp:  2             [SII]6731      3.333     0.088      27    37
# Comp:  2              HeII4687    0.01035     0.088      27    37
# Comp:  2               HeI5876     0.5701     0.088      27    37
# Comp:  2          [OIII]5007_d      2.142      0.11      27    37
# Comp:  2            [OI]6300_d     0.8580      0.11      27    37
# Comp:  2           [NII]6583_d      13.73      0.11      27    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38        67
#  comp.  1:        27        38
#  comp.  2:        29        39
# chi2/DOF: 0.5810; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.102     0.088      27    38
# Comp:  1                 Hbeta      8.138     0.088      27    38
# Comp:  1                Halpha      26.43     0.088      27    38
# Comp:  2             [SII]6716      4.523     0.088      29    39
# Comp:  2             [SII]6731      3.461     0.088      29    39
# Comp:  2              HeII4687    0.02955     0.088      29    39
# Comp:  2               HeI5876     0.6712     0.088      29    39
# Comp:  2          [OIII]5007_d      2.861      0.11      29    39
# Comp:  2            [OI]6300_d     0.8229      0.11      29    39
# Comp:  2           [NII]6583_d      14.07      0.11      29    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36        64
#  comp.  1:        26        36
#  comp.  2:        29        39
# chi2/DOF: 0.5821; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.455     0.087      26    36
# Comp:  1                 Hbeta      8.529     0.087      26    36
# Comp:  1                Halpha      26.13     0.087      26    36
# Comp:  2             [SII]6716      4.376     0.088      29    39
# Comp:  2             [SII]6731      3.546     0.088      29    39
# Comp:  2              HeII4687    0.02369     0.088      29    39
# Comp:  2               HeI5876     0.6900     0.088      29    39
# Comp:  2          [OIII]5007_d      2.877      0.11      29    39
# Comp:  2            [OI]6300_d     0.8250      0.11      29    39
# Comp:  2           [NII]6583_d      14.02      0.11      29    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26        73
#  comp.  1:        28        33
#  comp.  2:        26        44
# chi2/DOF: 0.5290; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.638     0.086      28    33
# Comp:  1                 Hbeta      7.525     0.086      28    33
# Comp:  1                Halpha      25.65     0.086      28    33
# Comp:  2             [SII]6716      4.463     0.090      26    44
# Comp:  2             [SII]6731      3.641     0.090      26    44
# Comp:  2              HeII4687      0.000     0.090      26    44
# Comp:  2               HeI5876     0.7409     0.090      26    44
# Comp:  2          [OIII]5007_d      2.924      0.11      26    44
# Comp:  2            [OI]6300_d     0.8329      0.11      26    44
# Comp:  2           [NII]6583_d      14.20      0.11      26    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37        71
#  comp.  1:        28        35
#  comp.  2:        30        43
# chi2/DOF: 0.5684; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.281     0.087      28    35
# Comp:  1                 Hbeta      8.005     0.087      28    35
# Comp:  1                Halpha      25.83     0.087      28    35
# Comp:  2             [SII]6716      4.470     0.089      30    43
# Comp:  2             [SII]6731      3.660     0.089      30    43
# Comp:  2              HeII4687    0.01284     0.089      30    43
# Comp:  2               HeI5876     0.7486     0.089      30    43
# Comp:  2          [OIII]5007_d      2.604      0.11      30    43
# Comp:  2            [OI]6300_d     0.8361      0.11      30    43
# Comp:  2           [NII]6583_d      14.31      0.11      30    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        71
#  comp.  1:        27        35
#  comp.  2:        31        45
# chi2/DOF: 0.5752; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.739     0.087      27    35
# Comp:  1                 Hbeta      8.136     0.087      27    35
# Comp:  1                Halpha      26.14     0.087      27    35
# Comp:  2             [SII]6716      4.458     0.090      31    45
# Comp:  2             [SII]6731      3.567     0.090      31    45
# Comp:  2              HeII4687      0.000     0.090      31    45
# Comp:  2               HeI5876     0.7314     0.090      31    45
# Comp:  2          [OIII]5007_d      2.680      0.11      31    45
# Comp:  2            [OI]6300_d     0.8773      0.11      31    45
# Comp:  2           [NII]6583_d      14.13      0.11      31    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48        71
#  comp.  1:        27        33
#  comp.  2:        27        45
# chi2/DOF: 0.5680; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.895     0.086      27    33
# Comp:  1                 Hbeta      8.207     0.086      27    33
# Comp:  1                Halpha      25.56     0.086      27    33
# Comp:  2             [SII]6716      4.544     0.090      27    45
# Comp:  2             [SII]6731      3.643     0.090      27    45
# Comp:  2              HeII4687    0.04061     0.090      27    45
# Comp:  2               HeI5876     0.5927     0.090      27    45
# Comp:  2          [OIII]5007_d      2.898      0.11      27    45
# Comp:  2            [OI]6300_d     0.8780      0.11      27    45
# Comp:  2           [NII]6583_d      14.08      0.11      27    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        32        76
#  comp.  1:        28        32
#  comp.  2:        30        50
# chi2/DOF: 0.5442; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.516     0.086      28    32
# Comp:  1                 Hbeta      8.007     0.086      28    32
# Comp:  1                Halpha      25.57     0.086      28    32
# Comp:  2             [SII]6716      4.752     0.091      30    50
# Comp:  2             [SII]6731      3.481     0.091      30    50
# Comp:  2              HeII4687      0.000     0.091      30    50
# Comp:  2               HeI5876     0.6892     0.091      30    50
# Comp:  2          [OIII]5007_d      2.761      0.12      30    50
# Comp:  2            [OI]6300_d     0.8783      0.12      30    50
# Comp:  2           [NII]6583_d      14.63      0.12      30    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38        57
#  comp.  1:        27        35
#  comp.  2:        25        42
# chi2/DOF: 0.5228; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.000     0.087      27    35
# Comp:  1                 Hbeta      8.850     0.087      27    35
# Comp:  1                Halpha      25.65     0.087      27    35
# Comp:  2             [SII]6716      4.551     0.089      25    42
# Comp:  2             [SII]6731      3.407     0.089      25    42
# Comp:  2              HeII4687   0.009952     0.089      25    42
# Comp:  2               HeI5876     0.6078     0.089      25    42
# Comp:  2          [OIII]5007_d      2.281      0.11      25    42
# Comp:  2            [OI]6300_d     0.8580      0.11      25    42
# Comp:  2           [NII]6583_d      13.86      0.11      25    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28        66
#  comp.  1:        28        32
#  comp.  2:        26        40
# chi2/DOF: 0.5481; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.558     0.086      28    32
# Comp:  1                 Hbeta      7.871     0.086      28    32
# Comp:  1                Halpha      25.67     0.086      28    32
# Comp:  2             [SII]6716      4.585     0.088      26    40
# Comp:  2             [SII]6731      3.494     0.088      26    40
# Comp:  2              HeII4687    0.01541     0.088      26    40
# Comp:  2               HeI5876     0.6502     0.088      26    40
# Comp:  2          [OIII]5007_d      2.513      0.11      26    40
# Comp:  2            [OI]6300_d     0.8375      0.11      26    40
# Comp:  2           [NII]6583_d      13.75      0.11      26    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        71
#  comp.  1:        27        36
#  comp.  2:        28        39
# chi2/DOF: 0.5645; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.157     0.087      27    36
# Comp:  1                 Hbeta      7.468     0.087      27    36
# Comp:  1                Halpha      26.09     0.087      27    36
# Comp:  2             [SII]6716      4.473     0.088      28    39
# Comp:  2             [SII]6731      3.468     0.088      28    39
# Comp:  2              HeII4687    0.01929     0.088      28    39
# Comp:  2               HeI5876     0.6389     0.088      28    39
# Comp:  2          [OIII]5007_d      2.374      0.11      28    39
# Comp:  2            [OI]6300_d     0.8451      0.11      28    39
# Comp:  2           [NII]6583_d      13.60      0.11      28    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33        77
#  comp.  1:        27        33
#  comp.  2:        27        43
# chi2/DOF: 0.5629; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.152     0.087      27    33
# Comp:  1                 Hbeta      8.665     0.087      27    33
# Comp:  1                Halpha      25.73     0.087      27    33
# Comp:  2             [SII]6716      4.457     0.089      27    43
# Comp:  2             [SII]6731      3.435     0.089      27    43
# Comp:  2              HeII4687    0.05195     0.089      27    43
# Comp:  2               HeI5876     0.7126     0.089      27    43
# Comp:  2          [OIII]5007_d      2.716      0.11      27    43
# Comp:  2            [OI]6300_d     0.8476      0.11      27    43
# Comp:  2           [NII]6583_d      14.17      0.11      27    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        37        73
#  comp.  1:        27        36
#  comp.  2:        28        41
# chi2/DOF: 0.5843; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.025     0.087      27    36
# Comp:  1                 Hbeta      7.662     0.087      27    36
# Comp:  1                Halpha      26.10     0.087      27    36
# Comp:  2             [SII]6716      4.386     0.089      28    41
# Comp:  2             [SII]6731      3.432     0.089      28    41
# Comp:  2              HeII4687    0.04708     0.089      28    41
# Comp:  2               HeI5876     0.6231     0.089      28    41
# Comp:  2          [OIII]5007_d      2.526      0.11      28    41
# Comp:  2            [OI]6300_d     0.8115      0.11      28    41
# Comp:  2           [NII]6583_d      14.24      0.11      28    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        49        61
#  comp.  1:        25        35
#  comp.  2:        26        45
# chi2/DOF: 0.5622; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.959     0.087      25    35
# Comp:  1                 Hbeta      7.303     0.087      25    35
# Comp:  1                Halpha      25.74     0.087      25    35
# Comp:  2             [SII]6716      4.439     0.090      26    45
# Comp:  2             [SII]6731      3.632     0.090      26    45
# Comp:  2              HeII4687      0.000     0.090      26    45
# Comp:  2               HeI5876     0.6369     0.090      26    45
# Comp:  2          [OIII]5007_d      2.317      0.11      26    45
# Comp:  2            [OI]6300_d     0.8913      0.11      26    45
# Comp:  2           [NII]6583_d      14.08      0.11      26    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        45        73
#  comp.  1:        25        40
#  comp.  2:        28        39
# chi2/DOF: 0.5618; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.234     0.088      25    40
# Comp:  1                 Hbeta      8.424     0.088      25    40
# Comp:  1                Halpha      26.42     0.088      25    40
# Comp:  2             [SII]6716      4.392     0.088      28    39
# Comp:  2             [SII]6731      3.337     0.088      28    39
# Comp:  2              HeII4687    0.05048     0.088      28    39
# Comp:  2               HeI5876     0.6453     0.088      28    39
# Comp:  2          [OIII]5007_d      2.660      0.11      28    39
# Comp:  2            [OI]6300_d     0.8184      0.11      28    39
# Comp:  2           [NII]6583_d      13.61      0.11      28    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        39        62
#  comp.  1:        25        39
#  comp.  2:        30        40
# chi2/DOF: 0.5541; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.234     0.088      25    39
# Comp:  1                 Hbeta      7.462     0.088      25    39
# Comp:  1                Halpha      26.20     0.088      25    39
# Comp:  2             [SII]6716      4.475     0.088      30    40
# Comp:  2             [SII]6731      3.435     0.088      30    40
# Comp:  2              HeII4687      0.000     0.088      30    40
# Comp:  2               HeI5876     0.7551     0.088      30    40
# Comp:  2          [OIII]5007_d      2.648      0.11      30    40
# Comp:  2            [OI]6300_d     0.8093      0.11      30    40
# Comp:  2           [NII]6583_d      13.91      0.11      30    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        38        66
#  comp.  1:        28        35
#  comp.  2:        30        38
# chi2/DOF: 0.5735; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.312     0.087      28    35
# Comp:  1                 Hbeta      7.786     0.087      28    35
# Comp:  1                Halpha      25.98     0.087      28    35
# Comp:  2             [SII]6716      4.531     0.088      30    38
# Comp:  2             [SII]6731      3.312     0.088      30    38
# Comp:  2              HeII4687      0.000     0.088      30    38
# Comp:  2               HeI5876     0.5924     0.088      30    38
# Comp:  2          [OIII]5007_d      2.915      0.11      30    38
# Comp:  2            [OI]6300_d     0.7920      0.11      30    38
# Comp:  2           [NII]6583_d      13.86      0.11      30    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41        66
#  comp.  1:        27        36
#  comp.  2:        30        40
# chi2/DOF: 0.5921; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.160     0.087      27    36
# Comp:  1                 Hbeta      7.868     0.087      27    36
# Comp:  1                Halpha      26.08     0.087      27    36
# Comp:  2             [SII]6716      4.324     0.088      30    40
# Comp:  2             [SII]6731      3.518     0.088      30    40
# Comp:  2              HeII4687   0.009642     0.088      30    40
# Comp:  2               HeI5876     0.6822     0.088      30    40
# Comp:  2          [OIII]5007_d      2.440      0.11      30    40
# Comp:  2            [OI]6300_d     0.8258      0.11      30    40
# Comp:  2           [NII]6583_d      13.84      0.11      30    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33        66
#  comp.  1:        26        34
#  comp.  2:        29        47
# chi2/DOF: 0.5658; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.536     0.087      26    34
# Comp:  1                 Hbeta      8.570     0.087      26    34
# Comp:  1                Halpha      25.87     0.087      26    34
# Comp:  2             [SII]6716      4.562     0.090      29    47
# Comp:  2             [SII]6731      3.620     0.090      29    47
# Comp:  2              HeII4687   0.002355     0.090      29    47
# Comp:  2               HeI5876     0.6208     0.090      29    47
# Comp:  2          [OIII]5007_d      2.299      0.11      29    47
# Comp:  2            [OI]6300_d     0.8924      0.11      29    47
# Comp:  2           [NII]6583_d      14.69      0.11      29    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        43        63
#  comp.  1:        27        35
#  comp.  2:        28        43
# chi2/DOF: 0.5886; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.916     0.087      27    35
# Comp:  1                 Hbeta      7.723     0.087      27    35
# Comp:  1                Halpha      25.77     0.087      27    35
# Comp:  2             [SII]6716      4.520     0.089      28    43
# Comp:  2             [SII]6731      3.359     0.089      28    43
# Comp:  2              HeII4687    0.04746     0.089      28    43
# Comp:  2               HeI5876     0.6983     0.089      28    43
# Comp:  2          [OIII]5007_d      2.850      0.11      28    43
# Comp:  2            [OI]6300_d     0.8702      0.11      28    43
# Comp:  2           [NII]6583_d      13.95      0.11      28    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47        69
#  comp.  1:        25        40
#  comp.  2:        30        42
# chi2/DOF: 0.5674; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.481     0.088      25    40
# Comp:  1                 Hbeta      7.924     0.088      25    40
# Comp:  1                Halpha      26.51     0.088      25    40
# Comp:  2             [SII]6716      4.571     0.089      30    42
# Comp:  2             [SII]6731      3.528     0.089      30    42
# Comp:  2              HeII4687    0.02300     0.089      30    42
# Comp:  2               HeI5876     0.5789     0.089      30    42
# Comp:  2          [OIII]5007_d      2.546      0.11      30    42
# Comp:  2            [OI]6300_d     0.8757      0.11      30    42
# Comp:  2           [NII]6583_d      14.26      0.11      30    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        76
#  comp.  1:        25        36
#  comp.  2:        29        43
# chi2/DOF: 0.5728; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.653     0.087      25    36
# Comp:  1                 Hbeta      8.546     0.087      25    36
# Comp:  1                Halpha      26.34     0.087      25    36
# Comp:  2             [SII]6716      4.557     0.089      29    43
# Comp:  2             [SII]6731      3.587     0.089      29    43
# Comp:  2              HeII4687   0.009629     0.089      29    43
# Comp:  2               HeI5876     0.6972     0.089      29    43
# Comp:  2          [OIII]5007_d      2.120      0.11      29    43
# Comp:  2            [OI]6300_d     0.8314      0.11      29    43
# Comp:  2           [NII]6583_d      14.03      0.11      29    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        44        70
#  comp.  1:        25        36
#  comp.  2:        30        48
# chi2/DOF: 0.5525; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.215     0.087      25    36
# Comp:  1                 Hbeta      7.374     0.087      25    36
# Comp:  1                Halpha      25.95     0.087      25    36
# Comp:  2             [SII]6716      4.683     0.091      30    48
# Comp:  2             [SII]6731      3.734     0.091      30    48
# Comp:  2              HeII4687    0.06002     0.091      30    48
# Comp:  2               HeI5876     0.7435     0.091      30    48
# Comp:  2          [OIII]5007_d      2.968      0.11      30    48
# Comp:  2            [OI]6300_d     0.8772      0.11      30    48
# Comp:  2           [NII]6583_d      14.46      0.11      30    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35        70
#  comp.  1:        26        40
#  comp.  2:        29        40
# chi2/DOF: 0.5762; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.361     0.088      26    40
# Comp:  1                 Hbeta      7.976     0.088      26    40
# Comp:  1                Halpha      26.49     0.088      26    40
# Comp:  2             [SII]6716      4.600     0.088      29    40
# Comp:  2             [SII]6731      3.392     0.088      29    40
# Comp:  2              HeII4687    0.03824     0.088      29    40
# Comp:  2               HeI5876     0.6702     0.088      29    40
# Comp:  2          [OIII]5007_d      2.394      0.11      29    40
# Comp:  2            [OI]6300_d     0.8228      0.11      29    40
# Comp:  2           [NII]6583_d      13.96      0.11      29    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        32        73
#  comp.  1:        26        35
#  comp.  2:        29        41
# chi2/DOF: 0.5654; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.757     0.087      26    35
# Comp:  1                 Hbeta      7.898     0.087      26    35
# Comp:  1                Halpha      26.10     0.087      26    35
# Comp:  2             [SII]6716      4.376     0.089      29    41
# Comp:  2             [SII]6731      3.591     0.089      29    41
# Comp:  2              HeII4687      0.000     0.089      29    41
# Comp:  2               HeI5876     0.6915     0.089      29    41
# Comp:  2          [OIII]5007_d      2.599      0.11      29    41
# Comp:  2            [OI]6300_d     0.8243      0.11      29    41
# Comp:  2           [NII]6583_d      13.95      0.11      29    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        36        67
#  comp.  1:        25        39
#  comp.  2:        28        42
# chi2/DOF: 0.5710; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.523     0.088      25    39
# Comp:  1                 Hbeta      8.547     0.088      25    39
# Comp:  1                Halpha      26.53     0.088      25    39
# Comp:  2             [SII]6716      4.451     0.089      28    42
# Comp:  2             [SII]6731      3.423     0.089      28    42
# Comp:  2              HeII4687      0.000     0.089      28    42
# Comp:  2               HeI5876     0.6122     0.089      28    42
# Comp:  2          [OIII]5007_d      2.244      0.11      28    42
# Comp:  2            [OI]6300_d     0.8574      0.11      28    42
# Comp:  2           [NII]6583_d      14.08      0.11      28    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33        73
#  comp.  1:        26        36
#  comp.  2:        28        44
# chi2/DOF: 0.5822; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        39        69
#  comp.  1:        26        41
#  comp.  2:        30        44
# chi2/DOF: 0.5455; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.369     0.089      26    41
# Comp:  1                 Hbeta      8.646     0.089      26    41
# Comp:  1                Halpha      26.60     0.089      26    41
# Comp:  2             [SII]6716      4.556     0.090      30    44
# Comp:  2             [SII]6731      3.580     0.090      30    44
# Comp:  2              HeII4687    0.01028     0.090      30    44
# Comp:  2               HeI5876     0.6753     0.090      30    44
# Comp:  2          [OIII]5007_d      2.178      0.11      30    44
# Comp:  2            [OI]6300_d     0.8742      0.11      30    44
# Comp:  2           [NII]6583_d      14.25      0.11      30    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        45        61
#  comp.  1:        24        39
#  comp.  2:        28        44
# chi2/DOF: 0.5562; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.170     0.088      24    39
# Comp:  1                 Hbeta      8.107     0.088      24    39
# Comp:  1                Halpha      26.38     0.088      24    39
# Comp:  2             [SII]6716      4.476     0.090      28    44
# Comp:  2             [SII]6731      3.542     0.090      28    44
# Comp:  2              HeII4687      0.000     0.090      28    44
# Comp:  2               HeI5876     0.6844     0.090      28    44
# Comp:  2          [OIII]5007_d      2.171      0.11      28    44
# Comp:  2            [OI]6300_d     0.8289      0.11      28    44
# Comp:  2           [NII]6583_d      14.42      0.11      28    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        34        74
#  comp.  1:        27        33
#  comp.  2:        25        41
# chi2/DOF: 0.5810; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.363     0.086      27    33
# Comp:  1                 Hbeta      7.860     0.086      27    33
# Comp:  1                Halpha      25.66     0.086      27    33
# Comp:  2             [SII]6716      4.356     0.089      25    41
# Comp:  2             [SII]6731      3.406     0.089      25    41
# Comp:  2              HeII4687      0.000     0.089      25    41
# Comp:  2               HeI5876     0.6444     0.089      25    41
# Comp:  2          [OIII]5007_d      2.502      0.11      25    41
# Comp:  2            [OI]6300_d     0.8164      0.11      25    41
# Comp:  2           [NII]6583_d      14.12      0.11      25    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        74
#  comp.  1:        27        34
#  comp.  2:        27        36
# chi2/DOF: 0.5845; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.281     0.087      27    34
# Comp:  1                 Hbeta      7.961     0.087      27    34
# Comp:  1                Halpha      25.73     0.087      27    34
# Comp:  2             [SII]6716      4.435     0.087      27    36
# Comp:  2             [SII]6731      3.370     0.087      27    36
# Comp:  2              HeII4687    0.04175     0.087      27    36
# Comp:  2               HeI5876     0.5942     0.087      27    36
# Comp:  2          [OIII]5007_d      2.315      0.11      27    36
# Comp:  2            [OI]6300_d     0.7927      0.11      27    36
# Comp:  2           [NII]6583_d      13.68      0.11      27    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        43        70
#  comp.  1:        27        35
#  comp.  2:        28        47
# chi2/DOF: 0.5633; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.969     0.087      27    35
# Comp:  1                 Hbeta      8.562     0.087      27    35
# Comp:  1                Halpha      25.84     0.087      27    35
# Comp:  2             [SII]6716      4.605     0.091      28    47
# Comp:  2             [SII]6731      3.508     0.091      28    47
# Comp:  2              HeII4687      0.000     0.091      28    47
# Comp:  2               HeI5876     0.7090     0.091      28    47
# Comp:  2          [OIII]5007_d      2.451      0.11      28    47
# Comp:  2            [OI]6300_d     0.8298      0.11      28    47
# Comp:  2           [NII]6583_d      14.57      0.11      28    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        41        75
#  comp.  1:        25        35
#  comp.  2:        31        42
# chi2/DOF: 0.5542; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.943     0.087      25    35
# Comp:  1                 Hbeta      8.550     0.087      25    35
# Comp:  1                Halpha      25.77     0.087      25    35
# Comp:  2             [SII]6716      4.407     0.089      31    42
# Comp:  2             [SII]6731      3.424     0.089      31    42
# Comp:  2              HeII4687    0.03537     0.089      31    42
# Comp:  2               HeI5876     0.6267     0.089      31    42
# Comp:  2          [OIII]5007_d      2.267      0.11      31    42
# Comp:  2            [OI]6300_d     0.8568      0.11      31    42
# Comp:  2           [NII]6583_d      14.31      0.11      31    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        48        65
#  comp.  1:        26        40
#  comp.  2:        30        40
# chi2/DOF: 0.5675; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.490     0.088      26    40
# Comp:  1                 Hbeta      7.961     0.088      26    40
# Comp:  1                Halpha      26.59     0.088      26    40
# Comp:  2             [SII]6716      4.580     0.088      30    40
# Comp:  2             [SII]6731      3.455     0.088      30    40
# Comp:  2              HeII4687      0.000     0.088      30    40
# Comp:  2               HeI5876     0.6853     0.088      30    40
# Comp:  2          [OIII]5007_d      2.587      0.11      30    40
# Comp:  2            [OI]6300_d     0.8179      0.11      30    40
# Comp:  2           [NII]6583_d      13.89      0.11      30    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        26        74
#  comp.  1:        29        33
#  comp.  2:        28        44
# chi2/DOF: 0.5328; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.124     0.086      29    33
# Comp:  1                 Hbeta      7.508     0.086      29    33
# Comp:  1                Halpha      25.75     0.086      29    33
# Comp:  2             [SII]6716      4.575     0.090      28    44
# Comp:  2             [SII]6731      3.516     0.090      28    44
# Comp:  2              HeII4687   0.006677     0.090      28    44
# Comp:  2               HeI5876     0.7295     0.090      28    44
# Comp:  2          [OIII]5007_d      2.960      0.11      28    44
# Comp:  2            [OI]6300_d     0.8188      0.11      28    44
# Comp:  2           [NII]6583_d      14.41      0.11      28    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        30        69
#  comp.  1:        26        37
#  comp.  2:        29        41
# chi2/DOF: 0.5839; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.361     0.088      26    37
# Comp:  1                 Hbeta      7.927     0.088      26    37
# Comp:  1                Halpha      26.14     0.088      26    37
# Comp:  2             [SII]6716      4.584     0.089      29    41
# Comp:  2             [SII]6731      3.472     0.089      29    41
# Comp:  2              HeII4687   0.007564     0.089      29    41
# Comp:  2               HeI5876     0.6614     0.089      29    41
# Comp:  2          [OIII]5007_d      2.371      0.11      29    41
# Comp:  2            [OI]6300_d     0.7929      0.11      29    41
# Comp:  2           [NII]6583_d      14.00      0.11      29    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        35        79
#  comp.  1:        26        34
#  comp.  2:        26        35
# chi2/DOF: 0.5270; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.284     0.087      26    34
# Comp:  1                 Hbeta      7.085     0.087      26    34
# Comp:  1                Halpha      25.83     0.087      26    34
# Comp:  2             [SII]6716      4.354     0.087      26    35
# Comp:  2             [SII]6731      3.216     0.087      26    35
# Comp:  2              HeII4687      0.000     0.087      26    35
# Comp:  2               HeI5876     0.6146     0.087      26    35
# Comp:  2          [OIII]5007_d      2.473      0.11      26    35
# Comp:  2            [OI]6300_d     0.8309      0.11      26    35
# Comp:  2           [NII]6583_d      13.44      0.11      26    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        31        72
#  comp.  1:        27        38
#  comp.  2:        29        38
# chi2/DOF: 0.5730; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.416     0.088      27    38
# Comp:  1                 Hbeta      8.335     0.088      27    38
# Comp:  1                Halpha      26.47     0.088      27    38
# Comp:  2             [SII]6716      4.456     0.088      29    38
# Comp:  2             [SII]6731      3.205     0.088      29    38
# Comp:  2              HeII4687      0.000     0.088      29    38
# Comp:  2               HeI5876     0.7118     0.088      29    38
# Comp:  2          [OIII]5007_d      2.740      0.11      29    38
# Comp:  2            [OI]6300_d     0.8305      0.11      29    38
# Comp:  2           [NII]6583_d      14.07      0.11      29    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47        64
#  comp.  1:        26        37
#  comp.  2:        25        40
# chi2/DOF: 0.5776; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.429     0.088      26    37
# Comp:  1                 Hbeta      8.178     0.088      26    37
# Comp:  1                Halpha      26.27     0.088      26    37
# Comp:  2             [SII]6716      4.382     0.088      25    40
# Comp:  2             [SII]6731      3.457     0.088      25    40
# Comp:  2              HeII4687      0.000     0.088      25    40
# Comp:  2               HeI5876     0.6839     0.088      25    40
# Comp:  2          [OIII]5007_d      2.915      0.11      25    40
# Comp:  2            [OI]6300_d     0.8677      0.11      25    40
# Comp:  2           [NII]6583_d      13.99      0.11      25    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        50        71
#  comp.  1:        26        38
#  comp.  2:        28        42
# chi2/DOF: 0.5871; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.049     0.088      26    38
# Comp:  1                 Hbeta      8.006     0.088      26    38
# Comp:  1                Halpha      26.08     0.088      26    38
# Comp:  2             [SII]6716      4.570     0.089      28    42
# Comp:  2             [SII]6731      3.453     0.089      28    42
# Comp:  2              HeII4687      0.000     0.089      28    42
# Comp:  2               HeI5876     0.7106     0.089      28    42
# Comp:  2          [OIII]5007_d      2.632      0.11      28    42
# Comp:  2            [OI]6300_d     0.8329      0.11      28    42
# Comp:  2           [NII]6583_d      14.28      0.11      28    42
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.18324197, 0.51023003, 0.40976076, 0.14252748, 0.14404522,
#        0.01837804, 0.07114172, 0.22929163, 0.03000636, 0.39966001])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 2.87976946,  8.09970591, 35.50563059,  6.33658344,  4.85814644,
#         0.        ,  0.81868831,  2.66645762,  1.11041044, 19.32352751])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_2_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_2_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_2_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_2_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_2_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0        Hgamma   1.618470    0.102985
# 1         Hbeta   4.552147    0.286756
# 2        Halpha  19.954658    0.230291
# 3     [SII]6716   3.561248    0.080102
# 4     [SII]6731   2.730346    0.080955
# 5      HeII4687   0.000000    0.010329
# 6       HeI5876   0.460114    0.039983
# 7  [OIII]5007_d   1.498586    0.128865
# 8    [OI]6300_d   0.624066    0.016864
# 9   [NII]6583_d  10.860091    0.224614
#           Name       Flux  Error_flux
# 0       Hgamma   1.618470    0.102985
# 1        Hbeta   4.552147    0.286756
# 2       Halpha  19.954658    0.230291
# 3    [SII]6716   3.561248    0.080102
# 4    [SII]6731   2.730346    0.080955
# 5     HeII4687   0.000000    0.010329
# 6      HeI5876   0.460114    0.039983
# 7   [OIII]4959   0.374647    0.128865
# 8   [OIII]5007   1.123940    0.128865
# 9     [OI]6300   0.468050    0.016864
# 10    [OI]6364   0.156017    0.016864
# 11   [NII]6548   2.715023    0.224614
# 12   [NII]6583   8.145068    0.224614

# %%
np.median(flux_rf_rebin)
# Out:
# 0.5620138936962233
