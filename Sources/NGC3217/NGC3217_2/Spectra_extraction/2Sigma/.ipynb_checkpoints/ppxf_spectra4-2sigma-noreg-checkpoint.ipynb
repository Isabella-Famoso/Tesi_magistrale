# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_4.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/Spectra_extraction/redshift.txt")   
z = red[3][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_4']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15781412 2.1585315  2.15924888 ... 3.43833917 3.43905655 3.43977393]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        23
# chi2/DOF: 0.005044; DOF: 1909; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
#  Best Fit:       Vel     sigma
#  comp.  0:        -6         1
# chi2/DOF: 0.003933; DOF: 1881; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
# [1.05820556 1.07482121 1.09912172 ... 0.73786563 0.83262204 0.83118629]
# [1.13778976 1.17217292 1.19663322 ... 0.79473364 0.79946408 0.7987821 ]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-5.87132519,  0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        33
#  comp.  1:         8         8
#  comp.  2:         5        11
# chi2/DOF: 0.7737; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.555      0.16       8     8
# Comp:  1                 Hbeta      4.613      0.16       8     8
# Comp:  1                Halpha      16.00      0.16       8     8
# Comp:  2             [SII]6716      3.127      0.16       5    11
# Comp:  2             [SII]6731      2.097      0.16       5    11
# Comp:  2              HeII4687      0.000      0.16       5    11
# Comp:  2               HeI5876     0.4480      0.16       5    11
# Comp:  2          [OIII]5007_d      3.996      0.20       5    11
# Comp:  2            [OI]6300_d     0.7487      0.20       5    11
# Comp:  2           [NII]6583_d      6.636      0.20       5    11
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  8.934; gas flux:      1 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  25.62; gas flux:      5 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  91.48; gas flux:     22 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  17.88; gas flux:      4 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  11.63; gas flux:      3 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  2.507; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  16.28; gas flux:      4 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  3.047; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  28.32; gas flux:      9 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        13
#  comp.  1:         8        17
#  comp.  2:         6        20
# chi2/DOF: 0.7604; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.793      0.16       8    17
# Comp:  1                 Hbeta      4.387      0.16       8    17
# Comp:  1                Halpha      16.22      0.16       8    17
# Comp:  2             [SII]6716      3.353      0.16       6    20
# Comp:  2             [SII]6731      2.159      0.16       6    20
# Comp:  2              HeII4687    0.09003      0.16       6    20
# Comp:  2               HeI5876     0.4791      0.16       6    20
# Comp:  2          [OIII]5007_d      4.114      0.20       6    20
# Comp:  2            [OI]6300_d     0.6278      0.20       6    20
# Comp:  2           [NII]6583_d      6.694      0.20       6    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        33
#  comp.  1:         7         1
#  comp.  2:         2        20
# chi2/DOF: 0.7615; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.544      0.16       7     1
# Comp:  1                 Hbeta      4.608      0.16       7     1
# Comp:  1                Halpha      15.78      0.16       7     1
# Comp:  2             [SII]6716      3.169      0.16       2    20
# Comp:  2             [SII]6731      2.273      0.16       2    20
# Comp:  2              HeII4687      0.000      0.16       2    20
# Comp:  2               HeI5876     0.4820      0.16       2    20
# Comp:  2          [OIII]5007_d      3.378      0.20       2    20
# Comp:  2            [OI]6300_d     0.6792      0.20       2    20
# Comp:  2           [NII]6583_d      6.599      0.20       2    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28         1
#  comp.  1:         9        17
#  comp.  2:        -0        11
# chi2/DOF: 0.7529; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.194      0.16       9    17
# Comp:  1                 Hbeta      4.844      0.16       9    17
# Comp:  1                Halpha      16.37      0.16       9    17
# Comp:  2             [SII]6716      3.167      0.16      -0    11
# Comp:  2             [SII]6731      2.050      0.16      -0    11
# Comp:  2              HeII4687      0.000      0.16      -0    11
# Comp:  2               HeI5876     0.5744      0.16      -0    11
# Comp:  2          [OIII]5007_d      3.343      0.20      -0    11
# Comp:  2            [OI]6300_d     0.8858      0.20      -0    11
# Comp:  2           [NII]6583_d      6.558      0.20      -0    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:         7         7
#  comp.  2:         4         2
# chi2/DOF: 0.7597; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.638      0.16       7     7
# Comp:  1                 Hbeta      4.195      0.16       7     7
# Comp:  1                Halpha      16.02      0.16       7     7
# Comp:  2             [SII]6716      2.949      0.16       4     2
# Comp:  2             [SII]6731      2.159      0.16       4     2
# Comp:  2              HeII4687    0.08342      0.16       4     2
# Comp:  2               HeI5876     0.5436      0.16       4     2
# Comp:  2          [OIII]5007_d      4.635      0.20       4     2
# Comp:  2            [OI]6300_d     0.9532      0.20       4     2
# Comp:  2           [NII]6583_d      6.553      0.20       4     2
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30         1
#  comp.  1:         7         1
#  comp.  2:         9        19
# chi2/DOF: 0.7597; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.748      0.16       7     1
# Comp:  1                 Hbeta      4.674      0.16       7     1
# Comp:  1                Halpha      15.91      0.16       7     1
# Comp:  2             [SII]6716      3.099      0.16       9    19
# Comp:  2             [SII]6731      2.262      0.16       9    19
# Comp:  2              HeII4687      0.000      0.16       9    19
# Comp:  2               HeI5876     0.4167      0.16       9    19
# Comp:  2          [OIII]5007_d      3.454      0.20       9    19
# Comp:  2            [OI]6300_d     0.7247      0.20       9    19
# Comp:  2           [NII]6583_d      6.646      0.20       9    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        28
#  comp.  1:         7         1
#  comp.  2:         4        15
# chi2/DOF: 0.7627; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.564      0.16       7     1
# Comp:  1                 Hbeta      4.079      0.16       7     1
# Comp:  1                Halpha      15.95      0.16       7     1
# Comp:  2             [SII]6716      3.132      0.16       4    15
# Comp:  2             [SII]6731      2.265      0.16       4    15
# Comp:  2              HeII4687    0.08788      0.16       4    15
# Comp:  2               HeI5876     0.3349      0.16       4    15
# Comp:  2          [OIII]5007_d      3.890      0.20       4    15
# Comp:  2            [OI]6300_d     0.7942      0.20       4    15
# Comp:  2           [NII]6583_d      6.617      0.20       4    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        49
#  comp.  1:         5         1
#  comp.  2:         0        14
# chi2/DOF: 0.7569; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.486      0.16       5     1
# Comp:  1                 Hbeta      4.604      0.16       5     1
# Comp:  1                Halpha      15.90      0.16       5     1
# Comp:  2             [SII]6716      3.192      0.16       0    14
# Comp:  2             [SII]6731      2.003      0.16       0    14
# Comp:  2              HeII4687    0.05061      0.16       0    14
# Comp:  2               HeI5876     0.3924      0.16       0    14
# Comp:  2          [OIII]5007_d      3.319      0.20       0    14
# Comp:  2            [OI]6300_d     0.5871      0.20       0    14
# Comp:  2           [NII]6583_d      6.631      0.20       0    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15         1
#  comp.  1:         6         1
#  comp.  2:         9         9
# chi2/DOF: 0.7517; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.800      0.16       6     1
# Comp:  1                 Hbeta      4.201      0.16       6     1
# Comp:  1                Halpha      15.85      0.16       6     1
# Comp:  2             [SII]6716      3.027      0.16       9     9
# Comp:  2             [SII]6731      2.245      0.16       9     9
# Comp:  2              HeII4687    0.06187      0.16       9     9
# Comp:  2               HeI5876     0.4335      0.16       9     9
# Comp:  2          [OIII]5007_d      3.414      0.20       9     9
# Comp:  2            [OI]6300_d     0.8462      0.20       9     9
# Comp:  2           [NII]6583_d      6.714      0.20       9     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        44
#  comp.  1:         9        21
#  comp.  2:         5         1
# chi2/DOF: 0.7576; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.824      0.16       9    21
# Comp:  1                 Hbeta      4.828      0.16       9    21
# Comp:  1                Halpha      16.58      0.16       9    21
# Comp:  2             [SII]6716      3.110      0.16       5     1
# Comp:  2             [SII]6731      2.169      0.16       5     1
# Comp:  2              HeII4687    0.03144      0.16       5     1
# Comp:  2               HeI5876     0.4453      0.16       5     1
# Comp:  2          [OIII]5007_d      4.603      0.20       5     1
# Comp:  2            [OI]6300_d     0.7413      0.20       5     1
# Comp:  2           [NII]6583_d      6.341      0.20       5     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        33
#  comp.  1:         8        13
#  comp.  2:         5        16
# chi2/DOF: 0.7582; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.857      0.16       8    13
# Comp:  1                 Hbeta      5.413      0.16       8    13
# Comp:  1                Halpha      16.50      0.16       8    13
# Comp:  2             [SII]6716      2.997      0.16       5    16
# Comp:  2             [SII]6731      1.987      0.16       5    16
# Comp:  2              HeII4687     0.2907      0.16       5    16
# Comp:  2               HeI5876     0.5707      0.16       5    16
# Comp:  2          [OIII]5007_d      4.086      0.20       5    16
# Comp:  2            [OI]6300_d     0.9799      0.20       5    16
# Comp:  2           [NII]6583_d      6.680      0.20       5    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        57
#  comp.  1:         6         1
#  comp.  2:         9        15
# chi2/DOF: 0.7575; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.303      0.16       6     1
# Comp:  1                 Hbeta      4.792      0.16       6     1
# Comp:  1                Halpha      15.92      0.16       6     1
# Comp:  2             [SII]6716      3.169      0.16       9    15
# Comp:  2             [SII]6731      2.048      0.16       9    15
# Comp:  2              HeII4687      0.000      0.16       9    15
# Comp:  2               HeI5876     0.3358      0.16       9    15
# Comp:  2          [OIII]5007_d      4.332      0.20       9    15
# Comp:  2            [OI]6300_d     0.7464      0.20       9    15
# Comp:  2           [NII]6583_d      6.401      0.20       9    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        45
#  comp.  1:         7         1
#  comp.  2:         6        10
# chi2/DOF: 0.7619; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.592      0.16       7     1
# Comp:  1                 Hbeta      5.182      0.16       7     1
# Comp:  1                Halpha      16.06      0.16       7     1
# Comp:  2             [SII]6716      3.088      0.16       6    10
# Comp:  2             [SII]6731      2.004      0.16       6    10
# Comp:  2              HeII4687      0.000      0.16       6    10
# Comp:  2               HeI5876     0.4587      0.16       6    10
# Comp:  2          [OIII]5007_d      3.873      0.20       6    10
# Comp:  2            [OI]6300_d     0.7963      0.20       6    10
# Comp:  2           [NII]6583_d      6.687      0.20       6    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        20
#  comp.  1:         7         1
#  comp.  2:         1         1
# chi2/DOF: 0.7598; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.353      0.16       7     1
# Comp:  1                 Hbeta      4.660      0.16       7     1
# Comp:  1                Halpha      16.15      0.16       7     1
# Comp:  2             [SII]6716      3.007      0.16       1     1
# Comp:  2             [SII]6731      2.026      0.16       1     1
# Comp:  2              HeII4687     0.2397      0.16       1     1
# Comp:  2               HeI5876     0.3485      0.16       1     1
# Comp:  2          [OIII]5007_d      4.626      0.20       1     1
# Comp:  2            [OI]6300_d     0.7215      0.20       1     1
# Comp:  2           [NII]6583_d      6.693      0.20       1     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        30
#  comp.  1:         6         1
#  comp.  2:         7         1
# chi2/DOF: 0.7589; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.437      0.16       6     1
# Comp:  1                 Hbeta      4.091      0.16       6     1
# Comp:  1                Halpha      15.84      0.16       6     1
# Comp:  2             [SII]6716      3.089      0.16       7     1
# Comp:  2             [SII]6731      2.152      0.16       7     1
# Comp:  2              HeII4687      0.000      0.16       7     1
# Comp:  2               HeI5876     0.3880      0.16       7     1
# Comp:  2          [OIII]5007_d      4.419      0.20       7     1
# Comp:  2            [OI]6300_d     0.6539      0.20       7     1
# Comp:  2           [NII]6583_d      6.537      0.20       7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16         1
#  comp.  1:         6         1
#  comp.  2:         2        24
# chi2/DOF: 0.7584; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.803      0.16       6     1
# Comp:  1                 Hbeta      4.749      0.16       6     1
# Comp:  1                Halpha      16.09      0.16       6     1
# Comp:  2             [SII]6716      3.287      0.16       2    24
# Comp:  2             [SII]6731      2.161      0.16       2    24
# Comp:  2              HeII4687     0.2874      0.16       2    24
# Comp:  2               HeI5876     0.5929      0.16       2    24
# Comp:  2          [OIII]5007_d      4.188      0.20       2    24
# Comp:  2            [OI]6300_d     0.5936      0.20       2    24
# Comp:  2           [NII]6583_d      7.157      0.20       2    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        50
#  comp.  1:         6         1
#  comp.  2:         5        11
# chi2/DOF: 0.7612; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.484      0.16       6     1
# Comp:  1                 Hbeta      3.951      0.16       6     1
# Comp:  1                Halpha      16.04      0.16       6     1
# Comp:  2             [SII]6716      3.171      0.16       5    11
# Comp:  2             [SII]6731      2.092      0.16       5    11
# Comp:  2              HeII4687      0.000      0.16       5    11
# Comp:  2               HeI5876     0.5662      0.16       5    11
# Comp:  2          [OIII]5007_d      4.098      0.20       5    11
# Comp:  2            [OI]6300_d     0.7861      0.20       5    11
# Comp:  2           [NII]6583_d      6.971      0.20       5    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        14
#  comp.  1:         6         1
#  comp.  2:         8         3
# chi2/DOF: 0.7608; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.602      0.16       6     1
# Comp:  1                 Hbeta      4.136      0.16       6     1
# Comp:  1                Halpha      15.85      0.16       6     1
# Comp:  2             [SII]6716      3.150      0.16       8     3
# Comp:  2             [SII]6731      2.223      0.16       8     3
# Comp:  2              HeII4687      0.000      0.16       8     3
# Comp:  2               HeI5876     0.5475      0.16       8     3
# Comp:  2          [OIII]5007_d      3.909      0.20       8     3
# Comp:  2            [OI]6300_d     0.9283      0.20       8     3
# Comp:  2           [NII]6583_d      6.328      0.20       8     3
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        48
#  comp.  1:         8        16
#  comp.  2:         5         6
# chi2/DOF: 0.7537; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.574      0.16       8    16
# Comp:  1                 Hbeta      4.116      0.16       8    16
# Comp:  1                Halpha      16.45      0.16       8    16
# Comp:  2             [SII]6716      3.102      0.16       5     6
# Comp:  2             [SII]6731      2.065      0.16       5     6
# Comp:  2              HeII4687    0.01275      0.16       5     6
# Comp:  2               HeI5876     0.5993      0.16       5     6
# Comp:  2          [OIII]5007_d      4.535      0.20       5     6
# Comp:  2            [OI]6300_d     0.6616      0.20       5     6
# Comp:  2           [NII]6583_d      6.977      0.20       5     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        44
#  comp.  1:         7         1
#  comp.  2:         9         4
# chi2/DOF: 0.7609; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.460      0.16       7     1
# Comp:  1                 Hbeta      4.556      0.16       7     1
# Comp:  1                Halpha      15.97      0.16       7     1
# Comp:  2             [SII]6716      3.061      0.16       9     4
# Comp:  2             [SII]6731      2.107      0.16       9     4
# Comp:  2              HeII4687      0.000      0.16       9     4
# Comp:  2               HeI5876     0.3688      0.16       9     4
# Comp:  2          [OIII]5007_d      3.283      0.20       9     4
# Comp:  2            [OI]6300_d     0.7810      0.20       9     4
# Comp:  2           [NII]6583_d      6.747      0.20       9     4
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        34
#  comp.  1:         8         1
#  comp.  2:         5        12
# chi2/DOF: 0.7596; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.517      0.16       8     1
# Comp:  1                 Hbeta      5.119      0.16       8     1
# Comp:  1                Halpha      16.01      0.16       8     1
# Comp:  2             [SII]6716      3.273      0.16       5    12
# Comp:  2             [SII]6731      2.254      0.16       5    12
# Comp:  2              HeII4687      0.000      0.16       5    12
# Comp:  2               HeI5876     0.4449      0.16       5    12
# Comp:  2          [OIII]5007_d      3.743      0.20       5    12
# Comp:  2            [OI]6300_d     0.8637      0.20       5    12
# Comp:  2           [NII]6583_d      6.674      0.20       5    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        42
#  comp.  1:         6         1
#  comp.  2:         7         1
# chi2/DOF: 0.7573; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.397      0.16       6     1
# Comp:  1                 Hbeta      4.593      0.16       6     1
# Comp:  1                Halpha      15.87      0.16       6     1
# Comp:  2             [SII]6716      3.019      0.16       7     1
# Comp:  2             [SII]6731      2.210      0.16       7     1
# Comp:  2              HeII4687      0.000      0.16       7     1
# Comp:  2               HeI5876     0.5372      0.16       7     1
# Comp:  2          [OIII]5007_d      4.802      0.20       7     1
# Comp:  2            [OI]6300_d     0.5881      0.20       7     1
# Comp:  2           [NII]6583_d      6.369      0.20       7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        10
#  comp.  1:         6         1
#  comp.  2:         4        13
# chi2/DOF: 0.7555; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.442      0.16       6     1
# Comp:  1                 Hbeta      3.983      0.16       6     1
# Comp:  1                Halpha      15.91      0.16       6     1
# Comp:  2             [SII]6716      3.093      0.16       4    13
# Comp:  2             [SII]6731      2.103      0.16       4    13
# Comp:  2              HeII4687     0.1025      0.16       4    13
# Comp:  2               HeI5876     0.4494      0.16       4    13
# Comp:  2          [OIII]5007_d      3.381      0.20       4    13
# Comp:  2            [OI]6300_d     0.8348      0.20       4    13
# Comp:  2           [NII]6583_d      6.371      0.20       4    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        46
#  comp.  1:         6         1
#  comp.  2:         7         1
# chi2/DOF: 0.7550; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.698      0.16       6     1
# Comp:  1                 Hbeta      4.580      0.16       6     1
# Comp:  1                Halpha      15.74      0.16       6     1
# Comp:  2             [SII]6716      3.065      0.16       7     1
# Comp:  2             [SII]6731      1.948      0.16       7     1
# Comp:  2              HeII4687      0.000      0.16       7     1
# Comp:  2               HeI5876     0.4457      0.16       7     1
# Comp:  2          [OIII]5007_d      3.314      0.20       7     1
# Comp:  2            [OI]6300_d     0.7135      0.20       7     1
# Comp:  2           [NII]6583_d      6.443      0.20       7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        10
#  comp.  1:         8         1
#  comp.  2:        10        10
# chi2/DOF: 0.7599; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.712      0.16       8     1
# Comp:  1                 Hbeta      5.163      0.16       8     1
# Comp:  1                Halpha      15.85      0.16       8     1
# Comp:  2             [SII]6716      3.152      0.16      10    10
# Comp:  2             [SII]6731      2.245      0.16      10    10
# Comp:  2              HeII4687      0.000      0.16      10    10
# Comp:  2               HeI5876     0.4014      0.16      10    10
# Comp:  2          [OIII]5007_d      4.205      0.20      10    10
# Comp:  2            [OI]6300_d     0.5860      0.20      10    10
# Comp:  2           [NII]6583_d      6.500      0.20      10    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        47
#  comp.  1:         7         1
#  comp.  2:         5        19
# chi2/DOF: 0.7618; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.679      0.16       7     1
# Comp:  1                 Hbeta      4.732      0.16       7     1
# Comp:  1                Halpha      16.24      0.16       7     1
# Comp:  2             [SII]6716      3.099      0.16       5    19
# Comp:  2             [SII]6731      2.153      0.16       5    19
# Comp:  2              HeII4687      0.000      0.16       5    19
# Comp:  2               HeI5876     0.3672      0.16       5    19
# Comp:  2          [OIII]5007_d      3.773      0.20       5    19
# Comp:  2            [OI]6300_d     0.7073      0.20       5    19
# Comp:  2           [NII]6583_d      6.432      0.20       5    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        23
#  comp.  1:         6         1
#  comp.  2:         5        15
# chi2/DOF: 0.7566; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.695      0.16       6     1
# Comp:  1                 Hbeta      4.581      0.16       6     1
# Comp:  1                Halpha      15.84      0.16       6     1
# Comp:  2             [SII]6716      3.311      0.16       5    15
# Comp:  2             [SII]6731      2.028      0.16       5    15
# Comp:  2              HeII4687      0.000      0.16       5    15
# Comp:  2               HeI5876     0.5331      0.16       5    15
# Comp:  2          [OIII]5007_d      3.143      0.20       5    15
# Comp:  2            [OI]6300_d     0.5860      0.20       5    15
# Comp:  2           [NII]6583_d      6.449      0.20       5    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        25
#  comp.  1:         8        19
#  comp.  2:         6         1
# chi2/DOF: 0.7557; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.728      0.16       8    19
# Comp:  1                 Hbeta      4.229      0.16       8    19
# Comp:  1                Halpha      16.41      0.16       8    19
# Comp:  2             [SII]6716      2.935      0.16       6     1
# Comp:  2             [SII]6731      2.215      0.16       6     1
# Comp:  2              HeII4687      0.000      0.16       6     1
# Comp:  2               HeI5876     0.5734      0.16       6     1
# Comp:  2          [OIII]5007_d      4.402      0.20       6     1
# Comp:  2            [OI]6300_d     0.7026      0.20       6     1
# Comp:  2           [NII]6583_d      6.507      0.20       6     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        28
#  comp.  1:         6         1
#  comp.  2:         7         1
# chi2/DOF: 0.7598; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.369      0.16       6     1
# Comp:  1                 Hbeta      4.788      0.16       6     1
# Comp:  1                Halpha      16.00      0.16       6     1
# Comp:  2             [SII]6716      2.934      0.16       7     1
# Comp:  2             [SII]6731      2.108      0.16       7     1
# Comp:  2              HeII4687     0.2418      0.16       7     1
# Comp:  2               HeI5876     0.4132      0.16       7     1
# Comp:  2          [OIII]5007_d      4.268      0.20       7     1
# Comp:  2            [OI]6300_d     0.8508      0.20       7     1
# Comp:  2           [NII]6583_d      6.431      0.20       7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        33
#  comp.  1:         7        17
#  comp.  2:         4         5
# chi2/DOF: 0.7648; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.584      0.16       7    17
# Comp:  1                 Hbeta      4.757      0.16       7    17
# Comp:  1                Halpha      16.33      0.16       7    17
# Comp:  2             [SII]6716      3.119      0.16       4     5
# Comp:  2             [SII]6731      1.962      0.16       4     5
# Comp:  2              HeII4687      0.000      0.16       4     5
# Comp:  2               HeI5876     0.3191      0.16       4     5
# Comp:  2          [OIII]5007_d      4.239      0.20       4     5
# Comp:  2            [OI]6300_d     0.7818      0.20       4     5
# Comp:  2           [NII]6583_d      6.647      0.20       4     5
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31         1
#  comp.  1:         7        14
#  comp.  2:        10        17
# chi2/DOF: 0.7604; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.255      0.16       7    14
# Comp:  1                 Hbeta      5.082      0.16       7    14
# Comp:  1                Halpha      16.10      0.16       7    14
# Comp:  2             [SII]6716      3.169      0.16      10    17
# Comp:  2             [SII]6731      2.150      0.16      10    17
# Comp:  2              HeII4687      0.000      0.16      10    17
# Comp:  2               HeI5876     0.3457      0.16      10    17
# Comp:  2          [OIII]5007_d      4.200      0.20      10    17
# Comp:  2            [OI]6300_d     0.8305      0.20      10    17
# Comp:  2           [NII]6583_d      6.851      0.20      10    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        44
#  comp.  1:         7         1
#  comp.  2:         6        18
# chi2/DOF: 0.7648; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.309      0.16       7     1
# Comp:  1                 Hbeta      4.649      0.16       7     1
# Comp:  1                Halpha      15.86      0.16       7     1
# Comp:  2             [SII]6716      3.123      0.16       6    18
# Comp:  2             [SII]6731      2.115      0.16       6    18
# Comp:  2              HeII4687    0.06827      0.16       6    18
# Comp:  2               HeI5876     0.4490      0.16       6    18
# Comp:  2          [OIII]5007_d      4.202      0.20       6    18
# Comp:  2            [OI]6300_d     0.8840      0.20       6    18
# Comp:  2           [NII]6583_d      6.606      0.20       6    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:         8        15
#  comp.  2:         7        10
# chi2/DOF: 0.7487; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.186      0.16       8    15
# Comp:  1                 Hbeta      5.050      0.16       8    15
# Comp:  1                Halpha      16.32      0.16       8    15
# Comp:  2             [SII]6716      3.041      0.16       7    10
# Comp:  2             [SII]6731      2.220      0.16       7    10
# Comp:  2              HeII4687     0.1104      0.16       7    10
# Comp:  2               HeI5876     0.5546      0.16       7    10
# Comp:  2          [OIII]5007_d      4.803      0.20       7    10
# Comp:  2            [OI]6300_d     0.9046      0.20       7    10
# Comp:  2           [NII]6583_d      6.333      0.20       7    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        43
#  comp.  1:         7        16
#  comp.  2:         5        11
# chi2/DOF: 0.7518; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.251      0.16       7    16
# Comp:  1                 Hbeta      4.333      0.16       7    16
# Comp:  1                Halpha      16.42      0.16       7    16
# Comp:  2             [SII]6716      3.147      0.16       5    11
# Comp:  2             [SII]6731      2.128      0.16       5    11
# Comp:  2              HeII4687      0.000      0.16       5    11
# Comp:  2               HeI5876     0.4234      0.16       5    11
# Comp:  2          [OIII]5007_d      3.732      0.20       5    11
# Comp:  2            [OI]6300_d     0.6359      0.20       5    11
# Comp:  2           [NII]6583_d      6.423      0.20       5    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        65
#  comp.  1:         8        18
#  comp.  2:         4         1
# chi2/DOF: 0.7542; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.306      0.16       8    18
# Comp:  1                 Hbeta      4.657      0.16       8    18
# Comp:  1                Halpha      16.37      0.16       8    18
# Comp:  2             [SII]6716      3.200      0.16       4     1
# Comp:  2             [SII]6731      1.968      0.16       4     1
# Comp:  2              HeII4687      0.000      0.16       4     1
# Comp:  2               HeI5876     0.3496      0.16       4     1
# Comp:  2          [OIII]5007_d      4.438      0.20       4     1
# Comp:  2            [OI]6300_d     0.7877      0.20       4     1
# Comp:  2           [NII]6583_d      6.849      0.20       4     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        27
#  comp.  1:         6         1
#  comp.  2:         8         1
# chi2/DOF: 0.7614; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.647      0.16       6     1
# Comp:  1                 Hbeta      4.184      0.16       6     1
# Comp:  1                Halpha      16.10      0.16       6     1
# Comp:  2             [SII]6716      3.039      0.16       8     1
# Comp:  2             [SII]6731      2.197      0.16       8     1
# Comp:  2              HeII4687      0.000      0.16       8     1
# Comp:  2               HeI5876     0.4750      0.16       8     1
# Comp:  2          [OIII]5007_d      4.110      0.20       8     1
# Comp:  2            [OI]6300_d     0.7281      0.20       8     1
# Comp:  2           [NII]6583_d      6.557      0.20       8     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27         6
#  comp.  1:         6         5
#  comp.  2:         3        17
# chi2/DOF: 0.7618; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.743      0.16       6     5
# Comp:  1                 Hbeta      4.790      0.16       6     5
# Comp:  1                Halpha      16.06      0.16       6     5
# Comp:  2             [SII]6716      2.996      0.16       3    17
# Comp:  2             [SII]6731      2.185      0.16       3    17
# Comp:  2              HeII4687    0.04234      0.16       3    17
# Comp:  2               HeI5876     0.4825      0.16       3    17
# Comp:  2          [OIII]5007_d      4.039      0.20       3    17
# Comp:  2            [OI]6300_d     0.9733      0.20       3    17
# Comp:  2           [NII]6583_d      7.038      0.20       3    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        47
#  comp.  1:         7         6
#  comp.  2:         3        11
# chi2/DOF: 0.7560; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.262      0.16       7     6
# Comp:  1                 Hbeta      4.141      0.16       7     6
# Comp:  1                Halpha      16.16      0.16       7     6
# Comp:  2             [SII]6716      3.263      0.16       3    11
# Comp:  2             [SII]6731      2.120      0.16       3    11
# Comp:  2              HeII4687    0.07496      0.16       3    11
# Comp:  2               HeI5876     0.4276      0.16       3    11
# Comp:  2          [OIII]5007_d      3.330      0.20       3    11
# Comp:  2            [OI]6300_d     0.6406      0.20       3    11
# Comp:  2           [NII]6583_d      6.724      0.20       3    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        28
#  comp.  1:         7         1
#  comp.  2:         5         1
# chi2/DOF: 0.7629; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.153      0.16       7     1
# Comp:  1                 Hbeta      4.540      0.16       7     1
# Comp:  1                Halpha      15.85      0.16       7     1
# Comp:  2             [SII]6716      3.106      0.16       5     1
# Comp:  2             [SII]6731      2.178      0.16       5     1
# Comp:  2              HeII4687      0.000      0.16       5     1
# Comp:  2               HeI5876     0.4698      0.16       5     1
# Comp:  2          [OIII]5007_d      4.443      0.20       5     1
# Comp:  2            [OI]6300_d     0.7453      0.20       5     1
# Comp:  2           [NII]6583_d      6.404      0.20       5     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        31
#  comp.  1:         7        14
#  comp.  2:         1         1
# chi2/DOF: 0.7580; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.293      0.16       7    14
# Comp:  1                 Hbeta      4.750      0.16       7    14
# Comp:  1                Halpha      16.18      0.16       7    14
# Comp:  2             [SII]6716      3.100      0.16       1     1
# Comp:  2             [SII]6731      2.218      0.16       1     1
# Comp:  2              HeII4687      0.000      0.16       1     1
# Comp:  2               HeI5876     0.5652      0.16       1     1
# Comp:  2          [OIII]5007_d      4.637      0.20       1     1
# Comp:  2            [OI]6300_d     0.9236      0.20       1     1
# Comp:  2           [NII]6583_d      6.619      0.20       1     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        38
#  comp.  1:         9        17
#  comp.  2:         4        21
# chi2/DOF: 0.7573; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        46
#  comp.  1:         9        17
#  comp.  2:         5        19
# chi2/DOF: 0.7583; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.531      0.16       9    17
# Comp:  1                 Hbeta      5.461      0.16       9    17
# Comp:  1                Halpha      16.21      0.16       9    17
# Comp:  2             [SII]6716      3.076      0.16       5    19
# Comp:  2             [SII]6731      2.126      0.16       5    19
# Comp:  2              HeII4687      0.000      0.16       5    19
# Comp:  2               HeI5876     0.4527      0.16       5    19
# Comp:  2          [OIII]5007_d      3.911      0.20       5    19
# Comp:  2            [OI]6300_d     0.7254      0.20       5    19
# Comp:  2           [NII]6583_d      6.879      0.20       5    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        55
#  comp.  1:         9        19
#  comp.  2:         1         7
# chi2/DOF: 0.7568; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.555      0.16       9    19
# Comp:  1                 Hbeta      4.206      0.16       9    19
# Comp:  1                Halpha      16.46      0.16       9    19
# Comp:  2             [SII]6716      3.179      0.16       1     7
# Comp:  2             [SII]6731      2.031      0.16       1     7
# Comp:  2              HeII4687      0.000      0.16       1     7
# Comp:  2               HeI5876     0.4406      0.16       1     7
# Comp:  2          [OIII]5007_d      3.884      0.20       1     7
# Comp:  2            [OI]6300_d     0.7191      0.20       1     7
# Comp:  2           [NII]6583_d      6.936      0.20       1     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24         1
#  comp.  1:         7        16
#  comp.  2:         5         1
# chi2/DOF: 0.7572; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.767      0.16       7    16
# Comp:  1                 Hbeta      4.750      0.16       7    16
# Comp:  1                Halpha      16.43      0.16       7    16
# Comp:  2             [SII]6716      3.228      0.16       5     1
# Comp:  2             [SII]6731      1.941      0.16       5     1
# Comp:  2              HeII4687     0.2246      0.16       5     1
# Comp:  2               HeI5876     0.5028      0.16       5     1
# Comp:  2          [OIII]5007_d      4.781      0.20       5     1
# Comp:  2            [OI]6300_d     0.7562      0.20       5     1
# Comp:  2           [NII]6583_d      6.373      0.20       5     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        14
#  comp.  1:         7         2
#  comp.  2:         6        17
# chi2/DOF: 0.7626; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.571      0.16       7     2
# Comp:  1                 Hbeta      4.089      0.16       7     2
# Comp:  1                Halpha      15.93      0.16       7     2
# Comp:  2             [SII]6716      2.976      0.16       6    17
# Comp:  2             [SII]6731      2.128      0.16       6    17
# Comp:  2              HeII4687    0.02592      0.16       6    17
# Comp:  2               HeI5876     0.2974      0.16       6    17
# Comp:  2          [OIII]5007_d      4.183      0.20       6    17
# Comp:  2            [OI]6300_d     0.8764      0.20       6    17
# Comp:  2           [NII]6583_d      6.741      0.20       6    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        42
#  comp.  1:         7         1
#  comp.  2:         7         1
# chi2/DOF: 0.7522; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.120      0.16       7     1
# Comp:  1                 Hbeta      4.963      0.16       7     1
# Comp:  1                Halpha      15.98      0.16       7     1
# Comp:  2             [SII]6716      3.012      0.16       7     1
# Comp:  2             [SII]6731      2.114      0.16       7     1
# Comp:  2              HeII4687    0.07679      0.16       7     1
# Comp:  2               HeI5876     0.5160      0.16       7     1
# Comp:  2          [OIII]5007_d      4.679      0.20       7     1
# Comp:  2            [OI]6300_d     0.5681      0.20       7     1
# Comp:  2           [NII]6583_d      6.241      0.20       7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        46
#  comp.  1:         9        14
#  comp.  2:         7         1
# chi2/DOF: 0.7580; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.837      0.16       9    14
# Comp:  1                 Hbeta      5.443      0.16       9    14
# Comp:  1                Halpha      16.40      0.16       9    14
# Comp:  2             [SII]6716      3.074      0.16       7     1
# Comp:  2             [SII]6731      2.001      0.16       7     1
# Comp:  2              HeII4687      0.000      0.16       7     1
# Comp:  2               HeI5876     0.4164      0.16       7     1
# Comp:  2          [OIII]5007_d      4.057      0.20       7     1
# Comp:  2            [OI]6300_d     0.7860      0.20       7     1
# Comp:  2           [NII]6583_d      6.518      0.20       7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        30
#  comp.  1:         5         1
#  comp.  2:         6         1
# chi2/DOF: 0.7498; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.966      0.16       5     1
# Comp:  1                 Hbeta      4.717      0.16       5     1
# Comp:  1                Halpha      15.90      0.16       5     1
# Comp:  2             [SII]6716      2.994      0.16       6     1
# Comp:  2             [SII]6731      2.072      0.16       6     1
# Comp:  2              HeII4687    0.04036      0.16       6     1
# Comp:  2               HeI5876     0.3151      0.16       6     1
# Comp:  2          [OIII]5007_d      4.700      0.20       6     1
# Comp:  2            [OI]6300_d     0.6854      0.20       6     1
# Comp:  2           [NII]6583_d      6.375      0.20       6     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        60
#  comp.  1:         6         1
#  comp.  2:         3         1
# chi2/DOF: 0.7631; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.217      0.16       6     1
# Comp:  1                 Hbeta      4.669      0.16       6     1
# Comp:  1                Halpha      16.07      0.16       6     1
# Comp:  2             [SII]6716      3.134      0.16       3     1
# Comp:  2             [SII]6731      1.941      0.16       3     1
# Comp:  2              HeII4687     0.1081      0.16       3     1
# Comp:  2               HeI5876     0.4201      0.16       3     1
# Comp:  2          [OIII]5007_d      3.737      0.20       3     1
# Comp:  2            [OI]6300_d     0.6734      0.20       3     1
# Comp:  2           [NII]6583_d      6.397      0.20       3     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        24
#  comp.  1:         7        16
#  comp.  2:         5        20
# chi2/DOF: 0.7591; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.634      0.16       7    16
# Comp:  1                 Hbeta      4.989      0.16       7    16
# Comp:  1                Halpha      16.24      0.16       7    16
# Comp:  2             [SII]6716      3.012      0.16       5    20
# Comp:  2             [SII]6731      2.186      0.16       5    20
# Comp:  2              HeII4687    0.03997      0.16       5    20
# Comp:  2               HeI5876     0.4766      0.16       5    20
# Comp:  2          [OIII]5007_d      3.961      0.20       5    20
# Comp:  2            [OI]6300_d     0.9597      0.20       5    20
# Comp:  2           [NII]6583_d      7.065      0.20       5    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17         2
#  comp.  1:         9        17
#  comp.  2:         7        12
# chi2/DOF: 0.7506; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.183      0.16       9    17
# Comp:  1                 Hbeta      5.480      0.16       9    17
# Comp:  1                Halpha      16.61      0.16       9    17
# Comp:  2             [SII]6716      3.222      0.16       7    12
# Comp:  2             [SII]6731      2.169      0.16       7    12
# Comp:  2              HeII4687      0.000      0.16       7    12
# Comp:  2               HeI5876     0.3787      0.16       7    12
# Comp:  2          [OIII]5007_d      3.289      0.20       7    12
# Comp:  2            [OI]6300_d     0.7635      0.20       7    12
# Comp:  2           [NII]6583_d      6.576      0.20       7    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        29
#  comp.  1:         8        17
#  comp.  2:         3         1
# chi2/DOF: 0.7573; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.706      0.16       8    17
# Comp:  1                 Hbeta      4.340      0.16       8    17
# Comp:  1                Halpha      16.53      0.16       8    17
# Comp:  2             [SII]6716      3.075      0.16       3     1
# Comp:  2             [SII]6731      2.039      0.16       3     1
# Comp:  2              HeII4687      0.000      0.16       3     1
# Comp:  2               HeI5876     0.4948      0.16       3     1
# Comp:  2          [OIII]5007_d      4.015      0.20       3     1
# Comp:  2            [OI]6300_d     0.6679      0.20       3     1
# Comp:  2           [NII]6583_d      6.360      0.20       3     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        47
#  comp.  1:         7         1
#  comp.  2:         8         7
# chi2/DOF: 0.7589; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.598      0.16       7     1
# Comp:  1                 Hbeta      5.202      0.16       7     1
# Comp:  1                Halpha      15.90      0.16       7     1
# Comp:  2             [SII]6716      2.971      0.16       8     7
# Comp:  2             [SII]6731      1.938      0.16       8     7
# Comp:  2              HeII4687     0.2328      0.16       8     7
# Comp:  2               HeI5876     0.4305      0.16       8     7
# Comp:  2          [OIII]5007_d      4.272      0.20       8     7
# Comp:  2            [OI]6300_d     0.9377      0.20       8     7
# Comp:  2           [NII]6583_d      6.385      0.20       8     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        37
#  comp.  1:         8         1
#  comp.  2:         4         9
# chi2/DOF: 0.7657; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.628      0.16       8     1
# Comp:  1                 Hbeta      4.736      0.16       8     1
# Comp:  1                Halpha      15.92      0.16       8     1
# Comp:  2             [SII]6716      3.178      0.16       4     9
# Comp:  2             [SII]6731      2.188      0.16       4     9
# Comp:  2              HeII4687    0.08946      0.16       4     9
# Comp:  2               HeI5876     0.3713      0.16       4     9
# Comp:  2          [OIII]5007_d      3.908      0.20       4     9
# Comp:  2            [OI]6300_d     0.7125      0.20       4     9
# Comp:  2           [NII]6583_d      6.461      0.20       4     9
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.2602769 , 0.39038463, 0.30431682, 0.13156863, 0.14278673,
#        0.0734457 , 0.106293  , 0.48671327, 0.15978007, 0.3118963 ])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 1.40803489,  4.67712463, 21.90701876,  4.38112722,  2.94340764,
#         0.        ,  0.54902964,  4.17301429,  0.98380955,  9.11265252])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_4_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_4_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_4_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_4_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_4_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0        Hgamma  0.126609    0.023404
# 1         Hbeta  0.420562    0.035103
# 2        Halpha  1.969857    0.027364
# 3     [SII]6716  0.393947    0.011831
# 4     [SII]6731  0.264668    0.012839
# 5      HeII4687  0.000000    0.006604
# 6       HeI5876  0.049368    0.009558
# 7  [OIII]5007_d  0.375233    0.043765
# 8    [OI]6300_d  0.088463    0.014367
# 9   [NII]6583_d  0.819401    0.028045
#           Name      Flux  Error_flux
# 0       Hgamma  0.126609    0.023404
# 1        Hbeta  0.420562    0.035103
# 2       Halpha  1.969857    0.027364
# 3    [SII]6716  0.393947    0.011831
# 4    [SII]6731  0.264668    0.012839
# 5     HeII4687  0.000000    0.006604
# 6      HeI5876  0.049368    0.009558
# 7   [OIII]4959  0.093808    0.043765
# 8   [OIII]5007  0.281425    0.043765
# 9     [OI]6300  0.066347    0.014367
# 10    [OI]6364  0.022116    0.014367
# 11   [NII]6548  0.204850    0.028045
# 12   [NII]6583  0.614550    0.028045

# %%
np.median(flux_rf_rebin)
# Out:
# 0.0899189901928523
