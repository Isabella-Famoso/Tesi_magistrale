# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_3.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/Spectra_extraction/redshift.txt")   
z = red[2][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.03156

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15846873 2.15918609 2.15990345 ... 3.43823917 3.43895653 3.43967389]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3161, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         4        69
# chi2/DOF: 0.001847; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/150
#  Best Fit:       Vel     sigma
#  comp.  0:         7        63
# chi2/DOF: 0.001538; DOF: 1893; degree = 4; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 11; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([ 7.0165839 , 63.04512729])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        61
#  comp.  1:        -4        11
#  comp.  2:        -2        19
# chi2/DOF: 0.9611; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.846      0.10      -4    11
# Comp:  1                 Hbeta      10.37      0.10      -4    11
# Comp:  1                Halpha      33.55      0.10      -4    11
# Comp:  2             [SII]6716      5.391      0.11      -2    19
# Comp:  2             [SII]6731      3.816      0.11      -2    19
# Comp:  2              HeII4687      0.000      0.11      -2    19
# Comp:  2               HeI5876      1.196      0.11      -2    19
# Comp:  2          [OIII]5007_d      3.629      0.13      -2    19
# Comp:  2            [OI]6300_d     0.8745      0.13      -2    19
# Comp:  2           [NII]6583_d      14.57      0.13      -2    19
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  32.94; gas flux:      3 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  87.54; gas flux:     11 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  269.8; gas flux:     46 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  43.09; gas flux:      8 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  31.88; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  10.19; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   23.6; gas flux:      4 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:    5.6; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  87.89; gas flux:     20 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        80
#  comp.  1:        -4         1
#  comp.  2:        -2        23
# chi2/DOF: 0.8936; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.386      0.10      -4     1
# Comp:  1                 Hbeta      10.44      0.10      -4     1
# Comp:  1                Halpha      34.06      0.10      -4     1
# Comp:  2             [SII]6716      5.162      0.11      -2    23
# Comp:  2             [SII]6731      3.973      0.11      -2    23
# Comp:  2              HeII4687    0.03767      0.11      -2    23
# Comp:  2               HeI5876      1.363      0.11      -2    23
# Comp:  2          [OIII]5007_d      3.504      0.14      -2    23
# Comp:  2            [OI]6300_d     0.9644      0.14      -2    23
# Comp:  2           [NII]6583_d      14.91      0.14      -2    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        61
#  comp.  1:        -5        15
#  comp.  2:        -2        23
# chi2/DOF: 0.8644; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.255      0.11      -5    15
# Comp:  1                 Hbeta      9.282      0.11      -5    15
# Comp:  1                Halpha      34.55      0.11      -5    15
# Comp:  2             [SII]6716      5.458      0.11      -2    23
# Comp:  2             [SII]6731      3.929      0.11      -2    23
# Comp:  2              HeII4687      0.000      0.11      -2    23
# Comp:  2               HeI5876      1.157      0.11      -2    23
# Comp:  2          [OIII]5007_d      3.749      0.14      -2    23
# Comp:  2            [OI]6300_d     0.8923      0.14      -2    23
# Comp:  2           [NII]6583_d      14.89      0.14      -2    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50        69
#  comp.  1:        -4         9
#  comp.  2:        -3        16
# chi2/DOF: 0.8519; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.837      0.10      -4     9
# Comp:  1                 Hbeta      11.82      0.10      -4     9
# Comp:  1                Halpha      33.79      0.10      -4     9
# Comp:  2             [SII]6716      5.202      0.11      -3    16
# Comp:  2             [SII]6731      3.703      0.11      -3    16
# Comp:  2              HeII4687      0.000      0.11      -3    16
# Comp:  2               HeI5876      1.333      0.11      -3    16
# Comp:  2          [OIII]5007_d      3.473      0.13      -3    16
# Comp:  2            [OI]6300_d     0.8965      0.13      -3    16
# Comp:  2           [NII]6583_d      14.37      0.13      -3    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        27
#  comp.  1:        -3        14
#  comp.  2:        -4         9
# chi2/DOF: 0.9342; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.503      0.11      -3    14
# Comp:  1                 Hbeta      10.49      0.11      -3    14
# Comp:  1                Halpha      33.74      0.11      -3    14
# Comp:  2             [SII]6716      5.322      0.10      -4     9
# Comp:  2             [SII]6731      3.795      0.10      -4     9
# Comp:  2              HeII4687    0.08130      0.10      -4     9
# Comp:  2               HeI5876      1.322      0.10      -4     9
# Comp:  2          [OIII]5007_d      3.294      0.13      -4     9
# Comp:  2            [OI]6300_d     0.8760      0.13      -4     9
# Comp:  2           [NII]6583_d      14.17      0.13      -4     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        71
#  comp.  1:        -3         1
#  comp.  2:        -2        22
# chi2/DOF: 0.8717; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.712      0.10      -3     1
# Comp:  1                 Hbeta      9.032      0.10      -3     1
# Comp:  1                Halpha      33.16      0.10      -3     1
# Comp:  2             [SII]6716      5.690      0.11      -2    22
# Comp:  2             [SII]6731      4.109      0.11      -2    22
# Comp:  2              HeII4687   0.007667      0.11      -2    22
# Comp:  2               HeI5876      1.387      0.11      -2    22
# Comp:  2          [OIII]5007_d      3.843      0.14      -2    22
# Comp:  2            [OI]6300_d     0.9402      0.14      -2    22
# Comp:  2           [NII]6583_d      14.68      0.14      -2    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         8        73
#  comp.  1:        -4         9
#  comp.  2:        -2        25
# chi2/DOF: 0.8315; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.099      0.10      -4     9
# Comp:  1                 Hbeta      9.706      0.10      -4     9
# Comp:  1                Halpha      33.09      0.10      -4     9
# Comp:  2             [SII]6716      5.894      0.11      -2    25
# Comp:  2             [SII]6731      4.136      0.11      -2    25
# Comp:  2              HeII4687   0.003790      0.11      -2    25
# Comp:  2               HeI5876      1.247      0.11      -2    25
# Comp:  2          [OIII]5007_d      3.831      0.14      -2    25
# Comp:  2            [OI]6300_d     0.7948      0.14      -2    25
# Comp:  2           [NII]6583_d      14.89      0.14      -2    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        64
#  comp.  1:        -1         7
#  comp.  2:        -2        11
# chi2/DOF: 0.8470; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.930      0.10      -1     7
# Comp:  1                 Hbeta      11.48      0.10      -1     7
# Comp:  1                Halpha      33.46      0.10      -1     7
# Comp:  2             [SII]6716      5.181      0.10      -2    11
# Comp:  2             [SII]6731      3.572      0.10      -2    11
# Comp:  2              HeII4687      0.000      0.10      -2    11
# Comp:  2               HeI5876      1.155      0.10      -2    11
# Comp:  2          [OIII]5007_d      3.478      0.13      -2    11
# Comp:  2            [OI]6300_d     0.8412      0.13      -2    11
# Comp:  2           [NII]6583_d      14.16      0.13      -2    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        68
#  comp.  1:        -1         6
#  comp.  2:        -1        14
# chi2/DOF: 0.8581; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.616      0.10      -1     6
# Comp:  1                 Hbeta      10.90      0.10      -1     6
# Comp:  1                Halpha      33.16      0.10      -1     6
# Comp:  2             [SII]6716      5.069      0.11      -1    14
# Comp:  2             [SII]6731      3.539      0.11      -1    14
# Comp:  2              HeII4687    0.06003      0.11      -1    14
# Comp:  2               HeI5876      1.238      0.11      -1    14
# Comp:  2          [OIII]5007_d      3.560      0.13      -1    14
# Comp:  2            [OI]6300_d     0.8017      0.13      -1    14
# Comp:  2           [NII]6583_d      14.38      0.13      -1    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        18        50
#  comp.  1:        -5        20
#  comp.  2:        -0        20
# chi2/DOF: 0.8381; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.915      0.11      -5    20
# Comp:  1                 Hbeta      9.625      0.11      -5    20
# Comp:  1                Halpha      33.45      0.11      -5    20
# Comp:  2             [SII]6716      5.280      0.11      -0    20
# Comp:  2             [SII]6731      3.801      0.11      -0    20
# Comp:  2              HeII4687    0.03110      0.11      -0    20
# Comp:  2               HeI5876      1.247      0.11      -0    20
# Comp:  2          [OIII]5007_d      4.033      0.13      -0    20
# Comp:  2            [OI]6300_d     0.8871      0.13      -0    20
# Comp:  2           [NII]6583_d      14.64      0.13      -0    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        93
#  comp.  1:        -5         1
#  comp.  2:        -3        20
# chi2/DOF: 0.8574; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.457      0.10      -5     1
# Comp:  1                 Hbeta      9.182      0.10      -5     1
# Comp:  1                Halpha      33.41      0.10      -5     1
# Comp:  2             [SII]6716      5.824      0.11      -3    20
# Comp:  2             [SII]6731      4.037      0.11      -3    20
# Comp:  2              HeII4687      0.000      0.11      -3    20
# Comp:  2               HeI5876      1.396      0.11      -3    20
# Comp:  2          [OIII]5007_d      3.739      0.13      -3    20
# Comp:  2            [OI]6300_d     0.8176      0.13      -3    20
# Comp:  2           [NII]6583_d      14.65      0.13      -3    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        68
#  comp.  1:        -4         1
#  comp.  2:        -0        19
# chi2/DOF: 0.8680; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.678      0.10      -4     1
# Comp:  1                 Hbeta      9.586      0.10      -4     1
# Comp:  1                Halpha      34.13      0.10      -4     1
# Comp:  2             [SII]6716      5.532      0.11      -0    19
# Comp:  2             [SII]6731      3.738      0.11      -0    19
# Comp:  2              HeII4687    0.03955      0.11      -0    19
# Comp:  2               HeI5876      1.178      0.11      -0    19
# Comp:  2          [OIII]5007_d      3.647      0.13      -0    19
# Comp:  2            [OI]6300_d     0.8634      0.13      -0    19
# Comp:  2           [NII]6583_d      14.68      0.13      -0    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        57
#  comp.  1:        -4        11
#  comp.  2:        -3        13
# chi2/DOF: 0.8896; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.441      0.10      -4    11
# Comp:  1                 Hbeta      11.39      0.10      -4    11
# Comp:  1                Halpha      34.37      0.10      -4    11
# Comp:  2             [SII]6716      5.012      0.11      -3    13
# Comp:  2             [SII]6731      3.615      0.11      -3    13
# Comp:  2              HeII4687      0.000      0.11      -3    13
# Comp:  2               HeI5876      1.185      0.11      -3    13
# Comp:  2          [OIII]5007_d      3.640      0.13      -3    13
# Comp:  2            [OI]6300_d     0.8333      0.13      -3    13
# Comp:  2           [NII]6583_d      14.20      0.13      -3    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        76
#  comp.  1:        -2         1
#  comp.  2:        -4        20
# chi2/DOF: 0.9159; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.001      0.10      -2     1
# Comp:  1                 Hbeta      10.77      0.10      -2     1
# Comp:  1                Halpha      33.34      0.10      -2     1
# Comp:  2             [SII]6716      5.526      0.11      -4    20
# Comp:  2             [SII]6731      3.679      0.11      -4    20
# Comp:  2              HeII4687      0.000      0.11      -4    20
# Comp:  2               HeI5876      1.158      0.11      -4    20
# Comp:  2          [OIII]5007_d      3.936      0.13      -4    20
# Comp:  2            [OI]6300_d     0.8767      0.13      -4    20
# Comp:  2           [NII]6583_d      14.64      0.13      -4    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        39
#  comp.  1:        -3        22
#  comp.  2:         0        24
# chi2/DOF: 0.8499; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.250      0.11      -3    22
# Comp:  1                 Hbeta      11.74      0.11      -3    22
# Comp:  1                Halpha      33.75      0.11      -3    22
# Comp:  2             [SII]6716      5.135      0.11       0    24
# Comp:  2             [SII]6731      3.885      0.11       0    24
# Comp:  2              HeII4687      0.000      0.11       0    24
# Comp:  2               HeI5876      1.280      0.11       0    24
# Comp:  2          [OIII]5007_d      3.666      0.14       0    24
# Comp:  2            [OI]6300_d     0.9912      0.14       0    24
# Comp:  2           [NII]6583_d      14.81      0.14       0    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        59
#  comp.  1:        -3         1
#  comp.  2:        -3         2
# chi2/DOF: 0.9101; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.831      0.10      -3     1
# Comp:  1                 Hbeta      10.35      0.10      -3     1
# Comp:  1                Halpha      32.59      0.10      -3     1
# Comp:  2             [SII]6716      4.846      0.10      -3     2
# Comp:  2             [SII]6731      3.455      0.10      -3     2
# Comp:  2              HeII4687      0.000      0.10      -3     2
# Comp:  2               HeI5876      1.125      0.10      -3     2
# Comp:  2          [OIII]5007_d      3.320      0.13      -3     2
# Comp:  2            [OI]6300_d     0.8271      0.13      -3     2
# Comp:  2           [NII]6583_d      14.10      0.13      -3     2
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        99
#  comp.  1:        -3         1
#  comp.  2:        -2         6
# chi2/DOF: 0.8831; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.363      0.10      -3     1
# Comp:  1                 Hbeta      10.91      0.10      -3     1
# Comp:  1                Halpha      33.46      0.10      -3     1
# Comp:  2             [SII]6716      5.491      0.10      -2     6
# Comp:  2             [SII]6731      3.666      0.10      -2     6
# Comp:  2              HeII4687   0.002919      0.10      -2     6
# Comp:  2               HeI5876      1.136      0.10      -2     6
# Comp:  2          [OIII]5007_d      3.493      0.13      -2     6
# Comp:  2            [OI]6300_d     0.8708      0.13      -2     6
# Comp:  2           [NII]6583_d      14.19      0.13      -2     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        79
#  comp.  1:        -3         1
#  comp.  2:        -4        15
# chi2/DOF: 0.8468; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.919      0.10      -3     1
# Comp:  1                 Hbeta      11.70      0.10      -3     1
# Comp:  1                Halpha      34.31      0.10      -3     1
# Comp:  2             [SII]6716      5.518      0.11      -4    15
# Comp:  2             [SII]6731      3.896      0.11      -4    15
# Comp:  2              HeII4687    0.01936      0.11      -4    15
# Comp:  2               HeI5876      1.361      0.11      -4    15
# Comp:  2          [OIII]5007_d      3.711      0.13      -4    15
# Comp:  2            [OI]6300_d     0.8391      0.13      -4    15
# Comp:  2           [NII]6583_d      14.51      0.13      -4    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        59
#  comp.  1:        -3         1
#  comp.  2:        -3        21
# chi2/DOF: 0.8833; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.351      0.10      -3     1
# Comp:  1                 Hbeta      9.996      0.10      -3     1
# Comp:  1                Halpha      34.04      0.10      -3     1
# Comp:  2             [SII]6716      5.477      0.11      -3    21
# Comp:  2             [SII]6731      3.787      0.11      -3    21
# Comp:  2              HeII4687      0.000      0.11      -3    21
# Comp:  2               HeI5876      1.356      0.11      -3    21
# Comp:  2          [OIII]5007_d      4.067      0.13      -3    21
# Comp:  2            [OI]6300_d     0.8365      0.13      -3    21
# Comp:  2           [NII]6583_d      14.54      0.13      -3    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        80
#  comp.  1:        -3        19
#  comp.  2:        -4        16
# chi2/DOF: 0.9178; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.576      0.11      -3    19
# Comp:  1                 Hbeta      10.17      0.11      -3    19
# Comp:  1                Halpha      34.02      0.11      -3    19
# Comp:  2             [SII]6716      5.531      0.11      -4    16
# Comp:  2             [SII]6731      3.798      0.11      -4    16
# Comp:  2              HeII4687    0.02300      0.11      -4    16
# Comp:  2               HeI5876      1.069      0.11      -4    16
# Comp:  2          [OIII]5007_d      3.571      0.13      -4    16
# Comp:  2            [OI]6300_d     0.8665      0.13      -4    16
# Comp:  2           [NII]6583_d      14.50      0.13      -4    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        71
#  comp.  1:        -4         1
#  comp.  2:        -2        22
# chi2/DOF: 0.9018; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.087      0.10      -4     1
# Comp:  1                 Hbeta      10.88      0.10      -4     1
# Comp:  1                Halpha      34.19      0.10      -4     1
# Comp:  2             [SII]6716      5.575      0.11      -2    22
# Comp:  2             [SII]6731      3.983      0.11      -2    22
# Comp:  2              HeII4687    0.02860      0.11      -2    22
# Comp:  2               HeI5876      1.067      0.11      -2    22
# Comp:  2          [OIII]5007_d      3.384      0.14      -2    22
# Comp:  2            [OI]6300_d     0.8709      0.14      -2    22
# Comp:  2           [NII]6583_d      14.84      0.14      -2    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        77
#  comp.  1:        -5         1
#  comp.  2:        -1        16
# chi2/DOF: 0.9007; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.862      0.10      -5     1
# Comp:  1                 Hbeta      10.79      0.10      -5     1
# Comp:  1                Halpha      33.74      0.10      -5     1
# Comp:  2             [SII]6716      5.111      0.11      -1    16
# Comp:  2             [SII]6731      3.812      0.11      -1    16
# Comp:  2              HeII4687      0.000      0.11      -1    16
# Comp:  2               HeI5876      1.212      0.11      -1    16
# Comp:  2          [OIII]5007_d      4.010      0.13      -1    16
# Comp:  2            [OI]6300_d     0.8906      0.13      -1    16
# Comp:  2           [NII]6583_d      14.59      0.13      -1    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        74
#  comp.  1:        -4         1
#  comp.  2:        -0        21
# chi2/DOF: 0.8486; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.732      0.10      -4     1
# Comp:  1                 Hbeta      9.616      0.10      -4     1
# Comp:  1                Halpha      34.17      0.10      -4     1
# Comp:  2             [SII]6716      5.153      0.11      -0    21
# Comp:  2             [SII]6731      4.110      0.11      -0    21
# Comp:  2              HeII4687      0.000      0.11      -0    21
# Comp:  2               HeI5876      1.016      0.11      -0    21
# Comp:  2          [OIII]5007_d      3.937      0.13      -0    21
# Comp:  2            [OI]6300_d     0.9034      0.13      -0    21
# Comp:  2           [NII]6583_d      14.77      0.13      -0    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        44
#  comp.  1:        -5        12
#  comp.  2:         0        25
# chi2/DOF: 0.9046; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.704      0.11      -5    12
# Comp:  1                 Hbeta      10.59      0.11      -5    12
# Comp:  1                Halpha      34.43      0.11      -5    12
# Comp:  2             [SII]6716      5.191      0.11       0    25
# Comp:  2             [SII]6731      3.954      0.11       0    25
# Comp:  2              HeII4687      0.000      0.11       0    25
# Comp:  2               HeI5876      1.376      0.11       0    25
# Comp:  2          [OIII]5007_d      4.172      0.14       0    25
# Comp:  2            [OI]6300_d     0.8984      0.14       0    25
# Comp:  2           [NII]6583_d      14.68      0.14       0    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        79
#  comp.  1:        -1         7
#  comp.  2:         0        24
# chi2/DOF: 0.8632; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.144      0.10      -1     7
# Comp:  1                 Hbeta      11.19      0.10      -1     7
# Comp:  1                Halpha      33.40      0.10      -1     7
# Comp:  2             [SII]6716      5.472      0.11       0    24
# Comp:  2             [SII]6731      3.762      0.11       0    24
# Comp:  2              HeII4687      0.000      0.11       0    24
# Comp:  2               HeI5876      1.346      0.11       0    24
# Comp:  2          [OIII]5007_d      3.793      0.14       0    24
# Comp:  2            [OI]6300_d     0.8556      0.14       0    24
# Comp:  2           [NII]6583_d      14.74      0.14       0    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        94
#  comp.  1:        -4         1
#  comp.  2:        -2        25
# chi2/DOF: 0.8435; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.474      0.10      -4     1
# Comp:  1                 Hbeta      9.385      0.10      -4     1
# Comp:  1                Halpha      34.15      0.10      -4     1
# Comp:  2             [SII]6716      5.265      0.11      -2    25
# Comp:  2             [SII]6731      3.974      0.11      -2    25
# Comp:  2              HeII4687    0.05077      0.11      -2    25
# Comp:  2               HeI5876      1.104      0.11      -2    25
# Comp:  2          [OIII]5007_d      3.529      0.14      -2    25
# Comp:  2            [OI]6300_d     0.8809      0.14      -2    25
# Comp:  2           [NII]6583_d      15.06      0.14      -2    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        50
#  comp.  1:        -3        22
#  comp.  2:        -5         8
# chi2/DOF: 0.8764; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.567      0.11      -3    22
# Comp:  1                 Hbeta      10.32      0.11      -3    22
# Comp:  1                Halpha      34.28      0.11      -3    22
# Comp:  2             [SII]6716      5.599      0.10      -5     8
# Comp:  2             [SII]6731      3.852      0.10      -5     8
# Comp:  2              HeII4687    0.09631      0.10      -5     8
# Comp:  2               HeI5876      1.045      0.10      -5     8
# Comp:  2          [OIII]5007_d      3.678      0.13      -5     8
# Comp:  2            [OI]6300_d     0.8508      0.13      -5     8
# Comp:  2           [NII]6583_d      14.30      0.13      -5     8
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        65
#  comp.  1:        -4         5
#  comp.  2:         0        23
# chi2/DOF: 0.8602; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.680      0.10      -4     5
# Comp:  1                 Hbeta      11.65      0.10      -4     5
# Comp:  1                Halpha      33.51      0.10      -4     5
# Comp:  2             [SII]6716      5.329      0.11       0    23
# Comp:  2             [SII]6731      3.960      0.11       0    23
# Comp:  2              HeII4687    0.05169      0.11       0    23
# Comp:  2               HeI5876      1.082      0.11       0    23
# Comp:  2          [OIII]5007_d      3.795      0.14       0    23
# Comp:  2            [OI]6300_d     0.9244      0.14       0    23
# Comp:  2           [NII]6583_d      14.87      0.14       0    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        54
#  comp.  1:        -3        14
#  comp.  2:        -1        23
# chi2/DOF: 0.9084; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.824      0.11      -3    14
# Comp:  1                 Hbeta      10.39      0.11      -3    14
# Comp:  1                Halpha      33.00      0.11      -3    14
# Comp:  2             [SII]6716      5.858      0.11      -1    23
# Comp:  2             [SII]6731      3.550      0.11      -1    23
# Comp:  2              HeII4687    0.04654      0.11      -1    23
# Comp:  2               HeI5876      1.205      0.11      -1    23
# Comp:  2          [OIII]5007_d      3.531      0.14      -1    23
# Comp:  2            [OI]6300_d     0.8415      0.14      -1    23
# Comp:  2           [NII]6583_d      14.72      0.14      -1    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7        35
#  comp.  1:        -4        20
#  comp.  2:        -1        23
# chi2/DOF: 0.8465; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.994      0.11      -4    20
# Comp:  1                 Hbeta      11.85      0.11      -4    20
# Comp:  1                Halpha      33.51      0.11      -4    20
# Comp:  2             [SII]6716      5.330      0.11      -1    23
# Comp:  2             [SII]6731      3.891      0.11      -1    23
# Comp:  2              HeII4687    0.03150      0.11      -1    23
# Comp:  2               HeI5876      1.200      0.11      -1    23
# Comp:  2          [OIII]5007_d      3.947      0.14      -1    23
# Comp:  2            [OI]6300_d     0.8003      0.14      -1    23
# Comp:  2           [NII]6583_d      14.69      0.14      -1    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        60
#  comp.  1:        -6        14
#  comp.  2:        -2        26
# chi2/DOF: 0.9132; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.420      0.11      -6    14
# Comp:  1                 Hbeta      10.79      0.11      -6    14
# Comp:  1                Halpha      34.01      0.11      -6    14
# Comp:  2             [SII]6716      5.741      0.11      -2    26
# Comp:  2             [SII]6731      3.918      0.11      -2    26
# Comp:  2              HeII4687      0.000      0.11      -2    26
# Comp:  2               HeI5876      1.095      0.11      -2    26
# Comp:  2          [OIII]5007_d      3.813      0.14      -2    26
# Comp:  2            [OI]6300_d     0.8671      0.14      -2    26
# Comp:  2           [NII]6583_d      14.93      0.14      -2    26
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_3_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_3_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_3_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_3_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_3_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
