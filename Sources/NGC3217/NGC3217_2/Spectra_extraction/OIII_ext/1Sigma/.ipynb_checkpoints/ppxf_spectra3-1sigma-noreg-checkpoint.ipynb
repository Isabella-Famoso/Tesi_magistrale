# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_1s_3.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/Spectra_extraction/redshift.txt") 
z = red[2][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_1s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.03156

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15846873 2.15918609 2.15990345 ... 3.43823917 3.43895653 3.43967389]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3161, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        81
# chi2/DOF: 0.003688; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        74
# chi2/DOF: 0.002114; DOF: 1876; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-11.62135184,  74.09472722])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        65
#  comp.  1:       -10        14
#  comp.  2:        -8        10
# chi2/DOF: 0.7978; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.637      0.14     -10    14
# Comp:  1                 Hbeta      10.01      0.14     -10    14
# Comp:  1                Halpha      26.13      0.14     -10    14
# Comp:  2             [SII]6716      4.390      0.14      -8    10
# Comp:  2             [SII]6731      3.085      0.14      -8    10
# Comp:  2              HeII4687      0.000      0.14      -8    10
# Comp:  2               HeI5876     0.7642      0.14      -8    10
# Comp:  2          [OIII]5007_d      4.051      0.18      -8    10
# Comp:  2            [OI]6300_d     0.9915      0.18      -8    10
# Comp:  2           [NII]6583_d      11.81      0.18      -8    10
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  27.23; gas flux:      3 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  69.88; gas flux:     10 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  186.8; gas flux:     36 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:     32; gas flux:      6 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  22.12; gas flux:      4 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  5.841; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   23.4; gas flux:      4 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  5.499; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  62.11; gas flux:     16 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        70
#  comp.  1:       -10        10
#  comp.  2:        -9        17
# chi2/DOF: 0.7762; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.160      0.14     -10    10
# Comp:  1                 Hbeta      10.07      0.14     -10    10
# Comp:  1                Halpha      26.38      0.14     -10    10
# Comp:  2             [SII]6716      4.232      0.14      -9    17
# Comp:  2             [SII]6731      3.121      0.14      -9    17
# Comp:  2              HeII4687      0.000      0.14      -9    17
# Comp:  2               HeI5876     0.9674      0.14      -9    17
# Comp:  2          [OIII]5007_d      4.018      0.18      -9    17
# Comp:  2            [OI]6300_d      1.108      0.18      -9    17
# Comp:  2           [NII]6583_d      12.03      0.18      -9    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        64
#  comp.  1:       -12        22
#  comp.  2:        -8        13
# chi2/DOF: 0.7507; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.997      0.14     -12    22
# Comp:  1                 Hbeta      9.297      0.14     -12    22
# Comp:  1                Halpha      27.18      0.14     -12    22
# Comp:  2             [SII]6716      4.424      0.14      -8    13
# Comp:  2             [SII]6731      3.145      0.14      -8    13
# Comp:  2              HeII4687    0.01079      0.14      -8    13
# Comp:  2               HeI5876     0.6820      0.14      -8    13
# Comp:  2          [OIII]5007_d      4.053      0.18      -8    13
# Comp:  2            [OI]6300_d     0.9508      0.18      -8    13
# Comp:  2           [NII]6583_d      12.13      0.18      -8    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        73
#  comp.  1:        -9        15
#  comp.  2:        -9        13
# chi2/DOF: 0.7594; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.508      0.14      -9    15
# Comp:  1                 Hbeta      11.17      0.14      -9    15
# Comp:  1                Halpha      26.41      0.14      -9    15
# Comp:  2             [SII]6716      4.308      0.14      -9    13
# Comp:  2             [SII]6731      2.976      0.14      -9    13
# Comp:  2              HeII4687    0.02052      0.14      -9    13
# Comp:  2               HeI5876     0.9604      0.14      -9    13
# Comp:  2          [OIII]5007_d      4.035      0.18      -9    13
# Comp:  2            [OI]6300_d     0.9957      0.18      -9    13
# Comp:  2           [NII]6583_d      11.76      0.18      -9    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -32        54
#  comp.  1:       -10        16
#  comp.  2:       -10         1
# chi2/DOF: 0.7846; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.254      0.14     -10    16
# Comp:  1                 Hbeta      10.00      0.14     -10    16
# Comp:  1                Halpha      26.16      0.14     -10    16
# Comp:  2             [SII]6716      4.384      0.14     -10     1
# Comp:  2             [SII]6731      3.164      0.14     -10     1
# Comp:  2              HeII4687    0.02072      0.14     -10     1
# Comp:  2               HeI5876     0.9329      0.14     -10     1
# Comp:  2          [OIII]5007_d      3.907      0.18     -10     1
# Comp:  2            [OI]6300_d     0.9255      0.18     -10     1
# Comp:  2           [NII]6583_d      11.52      0.18     -10     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        75
#  comp.  1:        -9         1
#  comp.  2:        -8        17
# chi2/DOF: 0.7548; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.455      0.14      -9     1
# Comp:  1                 Hbeta      8.906      0.14      -9     1
# Comp:  1                Halpha      25.63      0.14      -9     1
# Comp:  2             [SII]6716      4.645      0.14      -8    17
# Comp:  2             [SII]6731      3.366      0.14      -8    17
# Comp:  2              HeII4687    0.03460      0.14      -8    17
# Comp:  2               HeI5876      1.039      0.14      -8    17
# Comp:  2          [OIII]5007_d      4.136      0.18      -8    17
# Comp:  2            [OI]6300_d      1.128      0.18      -8    17
# Comp:  2           [NII]6583_d      11.78      0.18      -8    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        80
#  comp.  1:       -10         1
#  comp.  2:        -8        17
# chi2/DOF: 0.7378; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.804      0.14     -10     1
# Comp:  1                 Hbeta      9.422      0.14     -10     1
# Comp:  1                Halpha      25.54      0.14     -10     1
# Comp:  2             [SII]6716      4.939      0.14      -8    17
# Comp:  2             [SII]6731      3.341      0.14      -8    17
# Comp:  2              HeII4687    0.02572      0.14      -8    17
# Comp:  2               HeI5876     0.8136      0.14      -8    17
# Comp:  2          [OIII]5007_d      4.254      0.18      -8    17
# Comp:  2            [OI]6300_d     0.9483      0.18      -8    17
# Comp:  2           [NII]6583_d      12.14      0.18      -8    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        64
#  comp.  1:        -7         3
#  comp.  2:        -7         1
# chi2/DOF: 0.7404; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.498      0.14      -7     3
# Comp:  1                 Hbeta      10.74      0.14      -7     3
# Comp:  1                Halpha      25.63      0.14      -7     3
# Comp:  2             [SII]6716      4.284      0.14      -7     1
# Comp:  2             [SII]6731      2.959      0.14      -7     1
# Comp:  2              HeII4687    0.01375      0.14      -7     1
# Comp:  2               HeI5876     0.7110      0.14      -7     1
# Comp:  2          [OIII]5007_d      3.884      0.18      -7     1
# Comp:  2            [OI]6300_d     0.9786      0.18      -7     1
# Comp:  2           [NII]6583_d      11.48      0.18      -7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        62
#  comp.  1:        -7        10
#  comp.  2:        -7         2
# chi2/DOF: 0.7317; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.394      0.14      -7    10
# Comp:  1                 Hbeta      10.47      0.14      -7    10
# Comp:  1                Halpha      25.80      0.14      -7    10
# Comp:  2             [SII]6716      4.151      0.14      -7     2
# Comp:  2             [SII]6731      2.919      0.14      -7     2
# Comp:  2              HeII4687    0.04613      0.14      -7     2
# Comp:  2               HeI5876     0.8745      0.14      -7     2
# Comp:  2          [OIII]5007_d      4.101      0.18      -7     2
# Comp:  2            [OI]6300_d     0.8679      0.18      -7     2
# Comp:  2           [NII]6583_d      11.53      0.18      -7     2
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7        58
#  comp.  1:       -11        21
#  comp.  2:        -6        15
# chi2/DOF: 0.7597; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.729      0.14     -11    21
# Comp:  1                 Hbeta      9.486      0.14     -11    21
# Comp:  1                Halpha      26.22      0.14     -11    21
# Comp:  2             [SII]6716      4.339      0.14      -6    15
# Comp:  2             [SII]6731      3.078      0.14      -6    15
# Comp:  2              HeII4687      0.000      0.14      -6    15
# Comp:  2               HeI5876     0.7970      0.14      -6    15
# Comp:  2          [OIII]5007_d      4.246      0.18      -6    15
# Comp:  2            [OI]6300_d      1.122      0.18      -6    15
# Comp:  2           [NII]6583_d      12.01      0.18      -6    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        75
#  comp.  1:       -11         1
#  comp.  2:        -8        13
# chi2/DOF: 0.7580; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.197      0.14     -11     1
# Comp:  1                 Hbeta      8.944      0.14     -11     1
# Comp:  1                Halpha      25.91      0.14     -11     1
# Comp:  2             [SII]6716      4.905      0.14      -8    13
# Comp:  2             [SII]6731      3.221      0.14      -8    13
# Comp:  2              HeII4687    0.01197      0.14      -8    13
# Comp:  2               HeI5876      1.048      0.14      -8    13
# Comp:  2          [OIII]5007_d      4.135      0.18      -8    13
# Comp:  2            [OI]6300_d     0.9741      0.18      -8    13
# Comp:  2           [NII]6583_d      12.07      0.18      -8    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        74
#  comp.  1:        -9         1
#  comp.  2:        -7         3
# chi2/DOF: 0.7534; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.367      0.14      -9     1
# Comp:  1                 Hbeta      9.311      0.14      -9     1
# Comp:  1                Halpha      26.24      0.14      -9     1
# Comp:  2             [SII]6716      4.462      0.14      -7     3
# Comp:  2             [SII]6731      2.940      0.14      -7     3
# Comp:  2              HeII4687    0.02808      0.14      -7     3
# Comp:  2               HeI5876     0.7352      0.14      -7     3
# Comp:  2          [OIII]5007_d      4.160      0.18      -7     3
# Comp:  2            [OI]6300_d     0.9935      0.18      -7     3
# Comp:  2           [NII]6583_d      11.87      0.18      -7     3
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        57
#  comp.  1:       -11        20
#  comp.  2:        -8         1
# chi2/DOF: 0.7586; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.295      0.14     -11    20
# Comp:  1                 Hbeta      11.06      0.14     -11    20
# Comp:  1                Halpha      26.99      0.14     -11    20
# Comp:  2             [SII]6716      3.943      0.14      -8     1
# Comp:  2             [SII]6731      2.979      0.14      -8     1
# Comp:  2              HeII4687   0.003394      0.14      -8     1
# Comp:  2               HeI5876     0.7685      0.14      -8     1
# Comp:  2          [OIII]5007_d      3.967      0.18      -8     1
# Comp:  2            [OI]6300_d     0.9210      0.18      -8     1
# Comp:  2           [NII]6583_d      11.44      0.18      -8     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        56
#  comp.  1:        -8         1
#  comp.  2:       -10        12
# chi2/DOF: 0.7656; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.828      0.14      -8     1
# Comp:  1                 Hbeta      10.34      0.14      -8     1
# Comp:  1                Halpha      25.87      0.14      -8     1
# Comp:  2             [SII]6716      4.491      0.14     -10    12
# Comp:  2             [SII]6731      3.016      0.14     -10    12
# Comp:  2              HeII4687   0.004029      0.14     -10    12
# Comp:  2               HeI5876     0.6926      0.14     -10    12
# Comp:  2          [OIII]5007_d      4.216      0.18     -10    12
# Comp:  2            [OI]6300_d     0.9403      0.18     -10    12
# Comp:  2           [NII]6583_d      12.03      0.18     -10    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        48
#  comp.  1:        -9        24
#  comp.  2:        -7        19
# chi2/DOF: 0.7546; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.088      0.15      -9    24
# Comp:  1                 Hbeta      11.32      0.15      -9    24
# Comp:  1                Halpha      26.54      0.15      -9    24
# Comp:  2             [SII]6716      4.022      0.14      -7    19
# Comp:  2             [SII]6731      3.139      0.14      -7    19
# Comp:  2              HeII4687      0.000      0.14      -7    19
# Comp:  2               HeI5876     0.8616      0.14      -7    19
# Comp:  2          [OIII]5007_d      4.243      0.18      -7    19
# Comp:  2            [OI]6300_d      1.109      0.18      -7    19
# Comp:  2           [NII]6583_d      11.79      0.18      -7    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        74
#  comp.  1:        -9         1
#  comp.  2:        -9         1
# chi2/DOF: 0.7647; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.564      0.14      -9     1
# Comp:  1                 Hbeta      9.923      0.14      -9     1
# Comp:  1                Halpha      25.33      0.14      -9     1
# Comp:  2             [SII]6716      3.848      0.14      -9     1
# Comp:  2             [SII]6731      2.821      0.14      -9     1
# Comp:  2              HeII4687    0.02702      0.14      -9     1
# Comp:  2               HeI5876     0.6852      0.14      -9     1
# Comp:  2          [OIII]5007_d      3.883      0.18      -9     1
# Comp:  2            [OI]6300_d     0.9083      0.18      -9     1
# Comp:  2           [NII]6583_d      11.47      0.18      -9     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        88
#  comp.  1:       -10         1
#  comp.  2:        -7         1
# chi2/DOF: 0.7628; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.213      0.14     -10     1
# Comp:  1                 Hbeta      10.42      0.14     -10     1
# Comp:  1                Halpha      26.09      0.14     -10     1
# Comp:  2             [SII]6716      4.678      0.14      -7     1
# Comp:  2             [SII]6731      2.949      0.14      -7     1
# Comp:  2              HeII4687      0.000      0.14      -7     1
# Comp:  2               HeI5876     0.6690      0.14      -7     1
# Comp:  2          [OIII]5007_d      3.857      0.18      -7     1
# Comp:  2            [OI]6300_d      1.007      0.18      -7     1
# Comp:  2           [NII]6583_d      11.72      0.18      -7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        91
#  comp.  1:        -9        13
#  comp.  2:       -10         4
# chi2/DOF: 0.7535; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.529      0.14      -9    13
# Comp:  1                 Hbeta      11.14      0.14      -9    13
# Comp:  1                Halpha      26.75      0.14      -9    13
# Comp:  2             [SII]6716      4.694      0.14     -10     4
# Comp:  2             [SII]6731      3.074      0.14     -10     4
# Comp:  2              HeII4687      0.000      0.14     -10     4
# Comp:  2               HeI5876     0.9661      0.14     -10     4
# Comp:  2          [OIII]5007_d      4.084      0.18     -10     4
# Comp:  2            [OI]6300_d     0.9593      0.18     -10     4
# Comp:  2           [NII]6583_d      11.75      0.18     -10     4
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        64
#  comp.  1:        -9        14
#  comp.  2:        -9        18
# chi2/DOF: 0.7710; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.194      0.14      -9    14
# Comp:  1                 Hbeta      9.921      0.14      -9    14
# Comp:  1                Halpha      26.73      0.14      -9    14
# Comp:  2             [SII]6716      4.494      0.14      -9    18
# Comp:  2             [SII]6731      3.029      0.14      -9    18
# Comp:  2              HeII4687    0.02929      0.14      -9    18
# Comp:  2               HeI5876     0.9468      0.14      -9    18
# Comp:  2          [OIII]5007_d      4.279      0.18      -9    18
# Comp:  2            [OI]6300_d     0.9414      0.18      -9    18
# Comp:  2           [NII]6583_d      11.84      0.18      -9    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        76
#  comp.  1:       -11        26
#  comp.  2:       -10         6
# chi2/DOF: 0.7679; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.641      0.15     -11    26
# Comp:  1                 Hbeta      10.23      0.15     -11    26
# Comp:  1                Halpha      27.02      0.15     -11    26
# Comp:  2             [SII]6716      4.705      0.14     -10     6
# Comp:  2             [SII]6731      3.095      0.14     -10     6
# Comp:  2              HeII4687    0.04136      0.14     -10     6
# Comp:  2               HeI5876     0.6619      0.14     -10     6
# Comp:  2          [OIII]5007_d      4.153      0.18     -10     6
# Comp:  2            [OI]6300_d      1.009      0.18     -10     6
# Comp:  2           [NII]6583_d      11.93      0.18     -10     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        59
#  comp.  1:       -11         1
#  comp.  2:        -9        14
# chi2/DOF: 0.7744; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.667      0.14     -11     1
# Comp:  1                 Hbeta      10.15      0.14     -11     1
# Comp:  1                Halpha      26.25      0.14     -11     1
# Comp:  2             [SII]6716      4.717      0.14      -9    14
# Comp:  2             [SII]6731      3.195      0.14      -9    14
# Comp:  2              HeII4687      0.000      0.14      -9    14
# Comp:  2               HeI5876     0.6072      0.14      -9    14
# Comp:  2          [OIII]5007_d      3.914      0.18      -9    14
# Comp:  2            [OI]6300_d     0.9950      0.18      -9    14
# Comp:  2           [NII]6583_d      12.10      0.18      -9    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        83
#  comp.  1:       -11         1
#  comp.  2:        -7         1
# chi2/DOF: 0.7757; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.575      0.14     -11     1
# Comp:  1                 Hbeta      10.22      0.14     -11     1
# Comp:  1                Halpha      26.17      0.14     -11     1
# Comp:  2             [SII]6716      4.179      0.14      -7     1
# Comp:  2             [SII]6731      3.078      0.14      -7     1
# Comp:  2              HeII4687      0.000      0.14      -7     1
# Comp:  2               HeI5876     0.7707      0.14      -7     1
# Comp:  2          [OIII]5007_d      4.193      0.18      -7     1
# Comp:  2            [OI]6300_d      1.011      0.18      -7     1
# Comp:  2           [NII]6583_d      11.95      0.18      -7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        70
#  comp.  1:       -11         1
#  comp.  2:        -6         6
# chi2/DOF: 0.7528; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.291      0.14     -11     1
# Comp:  1                 Hbeta      9.244      0.14     -11     1
# Comp:  1                Halpha      26.40      0.14     -11     1
# Comp:  2             [SII]6716      4.183      0.14      -6     6
# Comp:  2             [SII]6731      3.299      0.14      -6     6
# Comp:  2              HeII4687   0.003812      0.14      -6     6
# Comp:  2               HeI5876     0.5034      0.14      -6     6
# Comp:  2          [OIII]5007_d      4.147      0.18      -6     6
# Comp:  2            [OI]6300_d     0.9407      0.18      -6     6
# Comp:  2           [NII]6583_d      11.94      0.18      -6     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        55
#  comp.  1:       -12        21
#  comp.  2:        -7        18
# chi2/DOF: 0.7654; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.710      0.14     -12    21
# Comp:  1                 Hbeta      10.36      0.14     -12    21
# Comp:  1                Halpha      27.12      0.14     -12    21
# Comp:  2             [SII]6716      4.051      0.14      -7    18
# Comp:  2             [SII]6731      3.077      0.14      -7    18
# Comp:  2              HeII4687    0.01639      0.14      -7    18
# Comp:  2               HeI5876     0.9791      0.14      -7    18
# Comp:  2          [OIII]5007_d      4.404      0.18      -7    18
# Comp:  2            [OI]6300_d      1.102      0.18      -7    18
# Comp:  2           [NII]6583_d      11.71      0.18      -7    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        86
#  comp.  1:        -8        16
#  comp.  2:        -5        10
# chi2/DOF: 0.7596; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.818      0.14      -8    16
# Comp:  1                 Hbeta      10.78      0.14      -8    16
# Comp:  1                Halpha      26.38      0.14      -8    16
# Comp:  2             [SII]6716      4.400      0.14      -5    10
# Comp:  2             [SII]6731      2.953      0.14      -5    10
# Comp:  2              HeII4687      0.000      0.14      -5    10
# Comp:  2               HeI5876     0.9070      0.14      -5    10
# Comp:  2          [OIII]5007_d      4.154      0.18      -5    10
# Comp:  2            [OI]6300_d     0.9292      0.18      -5    10
# Comp:  2           [NII]6583_d      11.85      0.18      -5    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        77
#  comp.  1:       -10         1
#  comp.  2:        -9        21
# chi2/DOF: 0.7527; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.009      0.14     -10     1
# Comp:  1                 Hbeta      9.170      0.14     -10     1
# Comp:  1                Halpha      26.14      0.14     -10     1
# Comp:  2             [SII]6716      4.316      0.14      -9    21
# Comp:  2             [SII]6731      3.284      0.14      -9    21
# Comp:  2              HeII4687    0.03001      0.14      -9    21
# Comp:  2               HeI5876     0.6769      0.14      -9    21
# Comp:  2          [OIII]5007_d      4.043      0.18      -9    21
# Comp:  2            [OI]6300_d      1.077      0.18      -9    21
# Comp:  2           [NII]6583_d      12.16      0.18      -9    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        62
#  comp.  1:       -11        29
#  comp.  2:       -11         1
# chi2/DOF: 0.7380; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.422      0.15     -11    29
# Comp:  1                 Hbeta      10.30      0.15     -11    29
# Comp:  1                Halpha      27.40      0.15     -11    29
# Comp:  2             [SII]6716      4.775      0.14     -11     1
# Comp:  2             [SII]6731      3.147      0.14     -11     1
# Comp:  2              HeII4687      0.000      0.14     -11     1
# Comp:  2               HeI5876     0.6039      0.14     -11     1
# Comp:  2          [OIII]5007_d      4.131      0.18     -11     1
# Comp:  2            [OI]6300_d      1.002      0.18     -11     1
# Comp:  2           [NII]6583_d      11.73      0.18     -11     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        79
#  comp.  1:        -9         1
#  comp.  2:        -5        13
# chi2/DOF: 0.7467; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.269      0.14      -9     1
# Comp:  1                 Hbeta      10.85      0.14      -9     1
# Comp:  1                Halpha      25.65      0.14      -9     1
# Comp:  2             [SII]6716      4.336      0.14      -5    13
# Comp:  2             [SII]6731      3.080      0.14      -5    13
# Comp:  2              HeII4687      0.000      0.14      -5    13
# Comp:  2               HeI5876     0.5991      0.14      -5    13
# Comp:  2          [OIII]5007_d      4.114      0.18      -5    13
# Comp:  2            [OI]6300_d      1.099      0.18      -5    13
# Comp:  2           [NII]6583_d      12.03      0.18      -5    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        51
#  comp.  1:        -8        15
#  comp.  2:        -6         1
# chi2/DOF: 0.7665; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.539      0.14      -8    15
# Comp:  1                 Hbeta      10.07      0.14      -8    15
# Comp:  1                Halpha      25.71      0.14      -8    15
# Comp:  2             [SII]6716      4.856      0.14      -6     1
# Comp:  2             [SII]6731      2.818      0.14      -6     1
# Comp:  2              HeII4687    0.03140      0.14      -6     1
# Comp:  2               HeI5876     0.7760      0.14      -6     1
# Comp:  2          [OIII]5007_d      3.982      0.18      -6     1
# Comp:  2            [OI]6300_d     0.9063      0.18      -6     1
# Comp:  2           [NII]6583_d      11.82      0.18      -6     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        47
#  comp.  1:        -9        23
#  comp.  2:        -7        16
# chi2/DOF: 0.7554; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.740      0.14      -9    23
# Comp:  1                 Hbeta      11.29      0.14      -9    23
# Comp:  1                Halpha      26.26      0.14      -9    23
# Comp:  2             [SII]6716      4.357      0.14      -7    16
# Comp:  2             [SII]6731      3.214      0.14      -7    16
# Comp:  2              HeII4687      0.000      0.14      -7    16
# Comp:  2               HeI5876     0.7594      0.14      -7    16
# Comp:  2          [OIII]5007_d      4.061      0.18      -7    16
# Comp:  2            [OI]6300_d     0.9477      0.18      -7    16
# Comp:  2           [NII]6583_d      12.03      0.18      -7    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        58
#  comp.  1:       -12        11
#  comp.  2:        -9        18
# chi2/DOF: 0.7760; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.274      0.14     -12    11
# Comp:  1                 Hbeta      10.34      0.14     -12    11
# Comp:  1                Halpha      26.13      0.14     -12    11
# Comp:  2             [SII]6716      4.646      0.14      -9    18
# Comp:  2             [SII]6731      3.231      0.14      -9    18
# Comp:  2              HeII4687      0.000      0.14      -9    18
# Comp:  2               HeI5876     0.6266      0.14      -9    18
# Comp:  2          [OIII]5007_d      4.147      0.18      -9    18
# Comp:  2            [OI]6300_d      1.007      0.18      -9    18
# Comp:  2           [NII]6583_d      12.14      0.18      -9    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        57
#  comp.  1:        -9        14
#  comp.  2:        -6        14
# chi2/DOF: 0.7827; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.452      0.14      -9    14
# Comp:  1                 Hbeta      9.667      0.14      -9    14
# Comp:  1                Halpha      26.04      0.14      -9    14
# Comp:  2             [SII]6716      4.374      0.14      -6    14
# Comp:  2             [SII]6731      2.947      0.14      -6    14
# Comp:  2              HeII4687      0.000      0.14      -6    14
# Comp:  2               HeI5876     0.6814      0.14      -6    14
# Comp:  2          [OIII]5007_d      4.148      0.18      -6    14
# Comp:  2            [OI]6300_d     0.9438      0.18      -6    14
# Comp:  2           [NII]6583_d      11.87      0.18      -6    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        59
#  comp.  1:       -13        24
#  comp.  2:        -9         3
# chi2/DOF: 0.7454; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.559      0.15     -13    24
# Comp:  1                 Hbeta      9.309      0.15     -13    24
# Comp:  1                Halpha      26.52      0.15     -13    24
# Comp:  2             [SII]6716      4.535      0.14      -9     3
# Comp:  2             [SII]6731      3.039      0.14      -9     3
# Comp:  2              HeII4687      0.000      0.14      -9     3
# Comp:  2               HeI5876     0.7031      0.14      -9     3
# Comp:  2          [OIII]5007_d      4.261      0.18      -9     3
# Comp:  2            [OI]6300_d      1.039      0.18      -9     3
# Comp:  2           [NII]6583_d      11.60      0.18      -9     3
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        66
#  comp.  1:       -10        11
#  comp.  2:        -7         5
# chi2/DOF: 0.7577; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.410      0.14     -10    11
# Comp:  1                 Hbeta      11.01      0.14     -10    11
# Comp:  1                Halpha      26.15      0.14     -10    11
# Comp:  2             [SII]6716      4.794      0.14      -7     5
# Comp:  2             [SII]6731      3.101      0.14      -7     5
# Comp:  2              HeII4687      0.000      0.14      -7     5
# Comp:  2               HeI5876     0.7666      0.14      -7     5
# Comp:  2          [OIII]5007_d      3.787      0.18      -7     5
# Comp:  2            [OI]6300_d     0.9958      0.18      -7     5
# Comp:  2           [NII]6583_d      11.65      0.18      -7     5
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        91
#  comp.  1:        -8         9
#  comp.  2:        -8        18
# chi2/DOF: 0.7437; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.447      0.14      -8     9
# Comp:  1                 Hbeta      10.88      0.14      -8     9
# Comp:  1                Halpha      25.52      0.14      -8     9
# Comp:  2             [SII]6716      4.404      0.14      -8    18
# Comp:  2             [SII]6731      3.374      0.14      -8    18
# Comp:  2              HeII4687      0.000      0.14      -8    18
# Comp:  2               HeI5876     0.7914      0.14      -8    18
# Comp:  2          [OIII]5007_d      3.975      0.18      -8    18
# Comp:  2            [OI]6300_d     0.9644      0.18      -8    18
# Comp:  2           [NII]6583_d      11.81      0.18      -8    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        78
#  comp.  1:       -11         1
#  comp.  2:        -6        10
# chi2/DOF: 0.7500; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.974      0.14     -11     1
# Comp:  1                 Hbeta      9.351      0.14     -11     1
# Comp:  1                Halpha      25.44      0.14     -11     1
# Comp:  2             [SII]6716      4.308      0.14      -6    10
# Comp:  2             [SII]6731      2.948      0.14      -6    10
# Comp:  2              HeII4687  0.0002250      0.14      -6    10
# Comp:  2               HeI5876     0.6952      0.14      -6    10
# Comp:  2          [OIII]5007_d      4.155      0.18      -6    10
# Comp:  2            [OI]6300_d     0.9312      0.18      -6    10
# Comp:  2           [NII]6583_d      11.60      0.18      -6    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        72
#  comp.  1:        -8        15
#  comp.  2:        -7        15
# chi2/DOF: 0.7605; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.701      0.14      -8    15
# Comp:  1                 Hbeta      11.10      0.14      -8    15
# Comp:  1                Halpha      26.41      0.14      -8    15
# Comp:  2             [SII]6716      4.359      0.14      -7    15
# Comp:  2             [SII]6731      3.101      0.14      -7    15
# Comp:  2              HeII4687      0.000      0.14      -7    15
# Comp:  2               HeI5876     0.9759      0.14      -7    15
# Comp:  2          [OIII]5007_d      4.036      0.18      -7    15
# Comp:  2            [OI]6300_d      1.107      0.18      -7    15
# Comp:  2           [NII]6583_d      11.77      0.18      -7    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        73
#  comp.  1:        -9        20
#  comp.  2:        -9         1
# chi2/DOF: 0.7626; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.708      0.14      -9    20
# Comp:  1                 Hbeta      11.06      0.14      -9    20
# Comp:  1                Halpha      26.27      0.14      -9    20
# Comp:  2             [SII]6716      4.376      0.14      -9     1
# Comp:  2             [SII]6731      2.937      0.14      -9     1
# Comp:  2              HeII4687      0.000      0.14      -9     1
# Comp:  2               HeI5876     0.6894      0.14      -9     1
# Comp:  2          [OIII]5007_d      4.055      0.18      -9     1
# Comp:  2            [OI]6300_d     0.9535      0.18      -9     1
# Comp:  2           [NII]6583_d      11.63      0.18      -9     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        58
#  comp.  1:       -11        26
#  comp.  2:        -7        14
# chi2/DOF: 0.7550; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.861      0.15     -11    26
# Comp:  1                 Hbeta      10.37      0.15     -11    26
# Comp:  1                Halpha      27.01      0.15     -11    26
# Comp:  2             [SII]6716      4.841      0.14      -7    14
# Comp:  2             [SII]6731      3.188      0.14      -7    14
# Comp:  2              HeII4687    0.01227      0.14      -7    14
# Comp:  2               HeI5876     0.6986      0.14      -7    14
# Comp:  2          [OIII]5007_d      3.991      0.18      -7    14
# Comp:  2            [OI]6300_d     0.9412      0.18      -7    14
# Comp:  2           [NII]6583_d      11.96      0.18      -7    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        55
#  comp.  1:       -10        21
#  comp.  2:        -8        17
# chi2/DOF: 0.7805; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.659      0.14     -10    21
# Comp:  1                 Hbeta      10.36      0.14     -10    21
# Comp:  1                Halpha      26.54      0.14     -10    21
# Comp:  2             [SII]6716      4.411      0.14      -8    17
# Comp:  2             [SII]6731      2.907      0.14      -8    17
# Comp:  2              HeII4687      0.000      0.14      -8    17
# Comp:  2               HeI5876     0.5058      0.14      -8    17
# Comp:  2          [OIII]5007_d      4.150      0.18      -8    17
# Comp:  2            [OI]6300_d      1.044      0.18      -8    17
# Comp:  2           [NII]6583_d      11.79      0.18      -8    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        58
#  comp.  1:       -12        25
#  comp.  2:        -9        17
# chi2/DOF: 0.7452; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# Comp:  2           [NII]6583_d      11.61      0.18      -9     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        56
#  comp.  1:       -12        14
#  comp.  2:        -8        20
# chi2/DOF: 0.7448; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.179      0.14     -12    14
# Comp:  1                 Hbeta      8.913      0.14     -12    14
# Comp:  1                Halpha      26.03      0.14     -12    14
# Comp:  2             [SII]6716      4.155      0.14      -8    20
# Comp:  2             [SII]6731      3.095      0.14      -8    20
# Comp:  2              HeII4687  0.0004682      0.14      -8    20
# Comp:  2               HeI5876     0.5627      0.14      -8    20
# Comp:  2          [OIII]5007_d      3.939      0.18      -8    20
# Comp:  2            [OI]6300_d     0.9941      0.18      -8    20
# Comp:  2           [NII]6583_d      11.85      0.18      -8    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        62
#  comp.  1:        -9        22
#  comp.  2:       -12        10
# chi2/DOF: 0.7537; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.282      0.14      -9    22
# Comp:  1                 Hbeta      11.32      0.14      -9    22
# Comp:  1                Halpha      26.23      0.14      -9    22
# Comp:  2             [SII]6716      4.441      0.14     -12    10
# Comp:  2             [SII]6731      3.147      0.14     -12    10
# Comp:  2              HeII4687      0.000      0.14     -12    10
# Comp:  2               HeI5876     0.7824      0.14     -12    10
# Comp:  2          [OIII]5007_d      4.018      0.18     -12    10
# Comp:  2            [OI]6300_d     0.9697      0.18     -12    10
# Comp:  2           [NII]6583_d      11.80      0.18     -12    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        97
#  comp.  1:        -9        10
#  comp.  2:       -11        10
# chi2/DOF: 0.7577; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.914      0.14      -9    10
# Comp:  1                 Hbeta      11.05      0.14      -9    10
# Comp:  1                Halpha      26.09      0.14      -9    10
# Comp:  2             [SII]6716      4.466      0.14     -11    10
# Comp:  2             [SII]6731      2.960      0.14     -11    10
# Comp:  2              HeII4687      0.000      0.14     -11    10
# Comp:  2               HeI5876     0.7478      0.14     -11    10
# Comp:  2          [OIII]5007_d      4.306      0.18     -11    10
# Comp:  2            [OI]6300_d      1.082      0.18     -11    10
# Comp:  2           [NII]6583_d      12.07      0.18     -11    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        83
#  comp.  1:       -12        21
#  comp.  2:        -9         1
# chi2/DOF: 0.7749; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.368      0.14     -12    21
# Comp:  1                 Hbeta      10.39      0.14     -12    21
# Comp:  1                Halpha      26.76      0.14     -12    21
# Comp:  2             [SII]6716      3.856      0.14      -9     1
# Comp:  2             [SII]6731      2.955      0.14      -9     1
# Comp:  2              HeII4687      0.000      0.14      -9     1
# Comp:  2               HeI5876     0.8384      0.14      -9     1
# Comp:  2          [OIII]5007_d      4.103      0.18      -9     1
# Comp:  2            [OI]6300_d      1.090      0.18      -9     1
# Comp:  2           [NII]6583_d      11.84      0.18      -9     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        78
#  comp.  1:        -9        13
#  comp.  2:        -9        15
# chi2/DOF: 0.7720; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.260      0.14      -9    13
# Comp:  1                 Hbeta      10.30      0.14      -9    13
# Comp:  1                Halpha      26.35      0.14      -9    13
# Comp:  2             [SII]6716      4.568      0.14      -9    15
# Comp:  2             [SII]6731      3.016      0.14      -9    15
# Comp:  2              HeII4687      0.000      0.14      -9    15
# Comp:  2               HeI5876     0.7145      0.14      -9    15
# Comp:  2          [OIII]5007_d      4.184      0.18      -9    15
# Comp:  2            [OI]6300_d      1.090      0.18      -9    15
# Comp:  2           [NII]6583_d      12.10      0.18      -9    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        66
#  comp.  1:       -13        17
#  comp.  2:       -10         9
# chi2/DOF: 0.7634; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.889      0.14     -13    17
# Comp:  1                 Hbeta      10.62      0.14     -13    17
# Comp:  1                Halpha      26.56      0.14     -13    17
# Comp:  2             [SII]6716      4.359      0.14     -10     9
# Comp:  2             [SII]6731      3.166      0.14     -10     9
# Comp:  2              HeII4687      0.000      0.14     -10     9
# Comp:  2               HeI5876      1.063      0.14     -10     9
# Comp:  2          [OIII]5007_d      4.178      0.18     -10     9
# Comp:  2            [OI]6300_d     0.9095      0.18     -10     9
# Comp:  2           [NII]6583_d      11.75      0.18     -10     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        68
#  comp.  1:       -11        21
#  comp.  2:       -10         1
# chi2/DOF: 0.7615; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.236      0.14     -11    21
# Comp:  1                 Hbeta      9.127      0.14     -11    21
# Comp:  1                Halpha      26.11      0.14     -11    21
# Comp:  2             [SII]6716      4.489      0.14     -10     1
# Comp:  2             [SII]6731      2.924      0.14     -10     1
# Comp:  2              HeII4687      0.000      0.14     -10     1
# Comp:  2               HeI5876     0.7652      0.14     -10     1
# Comp:  2          [OIII]5007_d      3.995      0.18     -10     1
# Comp:  2            [OI]6300_d     0.9592      0.18     -10     1
# Comp:  2           [NII]6583_d      11.46      0.18     -10     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        83
#  comp.  1:       -10        12
#  comp.  2:       -10         1
# chi2/DOF: 0.7761; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.656      0.14     -10    12
# Comp:  1                 Hbeta      9.281      0.14     -10    12
# Comp:  1                Halpha      26.18      0.14     -10    12
# Comp:  2             [SII]6716      4.458      0.14     -10     1
# Comp:  2             [SII]6731      3.091      0.14     -10     1
# Comp:  2              HeII4687      0.000      0.14     -10     1
# Comp:  2               HeI5876     0.9713      0.14     -10     1
# Comp:  2          [OIII]5007_d      4.170      0.18     -10     1
# Comp:  2            [OI]6300_d      1.053      0.18     -10     1
# Comp:  2           [NII]6583_d      11.67      0.18     -10     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        66
#  comp.  1:       -10        17
#  comp.  2:        -6        22
# chi2/DOF: 0.7822; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.294      0.14     -10    17
# Comp:  1                 Hbeta      10.30      0.14     -10    17
# Comp:  1                Halpha      26.19      0.14     -10    17
# Comp:  2             [SII]6716      4.464      0.14      -6    22
# Comp:  2             [SII]6731      2.890      0.14      -6    22
# Comp:  2              HeII4687      0.000      0.14      -6    22
# Comp:  2               HeI5876     0.8782      0.14      -6    22
# Comp:  2          [OIII]5007_d      4.194      0.18      -6    22
# Comp:  2            [OI]6300_d      1.075      0.18      -6    22
# Comp:  2           [NII]6583_d      11.95      0.18      -6    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        72
#  comp.  1:        -9         9
#  comp.  2:        -9         1
# chi2/DOF: 0.7696; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.043      0.14      -9     9
# Comp:  1                 Hbeta      9.835      0.14      -9     9
# Comp:  1                Halpha      25.90      0.14      -9     9
# Comp:  2             [SII]6716      3.924      0.14      -9     1
# Comp:  2             [SII]6731      2.978      0.14      -9     1
# Comp:  2              HeII4687   0.009447      0.14      -9     1
# Comp:  2               HeI5876     0.5448      0.14      -9     1
# Comp:  2          [OIII]5007_d      3.935      0.18      -9     1
# Comp:  2            [OI]6300_d     0.8719      0.18      -9     1
# Comp:  2           [NII]6583_d      11.57      0.18      -9     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        91
#  comp.  1:        -9        14
#  comp.  2:        -7         4
# chi2/DOF: 0.7748; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.912      0.14      -9    14
# Comp:  1                 Hbeta      9.856      0.14      -9    14
# Comp:  1                Halpha      26.18      0.14      -9    14
# Comp:  2             [SII]6716      4.246      0.14      -7     4
# Comp:  2             [SII]6731      3.090      0.14      -7     4
# Comp:  2              HeII4687    0.01773      0.14      -7     4
# Comp:  2               HeI5876     0.9556      0.14      -7     4
# Comp:  2          [OIII]5007_d      3.967      0.18      -7     4
# Comp:  2            [OI]6300_d     0.9871      0.18      -7     4
# Comp:  2           [NII]6583_d      11.60      0.18      -7     4
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        52
#  comp.  1:        -9         1
#  comp.  2:        -8        22
# chi2/DOF: 0.7608; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.877      0.14      -9     1
# Comp:  1                 Hbeta      10.83      0.14      -9     1
# Comp:  1                Halpha      25.74      0.14      -9     1
# Comp:  2             [SII]6716      4.087      0.14      -8    22
# Comp:  2             [SII]6731      3.271      0.14      -8    22
# Comp:  2              HeII4687   0.008047      0.14      -8    22
# Comp:  2               HeI5876     0.7695      0.14      -8    22
# Comp:  2          [OIII]5007_d      4.231      0.18      -8    22
# Comp:  2            [OI]6300_d     0.9590      0.18      -8    22
# Comp:  2           [NII]6583_d      12.27      0.18      -8    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        56
#  comp.  1:       -13        24
#  comp.  2:        -8         1
# chi2/DOF: 0.7392; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.335      0.15     -13    24
# Comp:  1                 Hbeta      9.280      0.15     -13    24
# Comp:  1                Halpha      26.89      0.15     -13    24
# Comp:  2             [SII]6716      4.176      0.14      -8     1
# Comp:  2             [SII]6731      3.072      0.14      -8     1
# Comp:  2              HeII4687   0.001062      0.14      -8     1
# Comp:  2               HeI5876      1.010      0.14      -8     1
# Comp:  2          [OIII]5007_d      4.120      0.18      -8     1
# Comp:  2            [OI]6300_d     0.9875      0.18      -8     1
# Comp:  2           [NII]6583_d      11.65      0.18      -8     1
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum1s_3_gas_ppxf_noreg.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum1s_3_noreg", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum1s_3_kin_noreg.csv", index=True)

# %%
read = pd.read_csv("Spectrum1s_3_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum1s_3_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
