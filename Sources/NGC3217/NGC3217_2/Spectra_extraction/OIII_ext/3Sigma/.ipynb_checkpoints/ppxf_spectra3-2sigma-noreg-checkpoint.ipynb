# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3s_3.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/Spectra_extraction/redshift.txt") 
z = red[2][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_3s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.03156

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15846873 2.15918609 2.15990345 ... 3.43823917 3.43895653 3.43967389]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3161, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        79
# chi2/DOF: 0.001926; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/150
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        71
# chi2/DOF: 0.001081; DOF: 1871; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-2.61614642, 70.77566406])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        73
#  comp.  1:        -6        12
#  comp.  2:        -4        19
# chi2/DOF: 0.7693; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.813      0.11      -6    12
# Comp:  1                 Hbeta      9.868      0.11      -6    12
# Comp:  1                Halpha      29.35      0.11      -6    12
# Comp:  2             [SII]6716      4.847      0.11      -4    19
# Comp:  2             [SII]6731      3.416      0.11      -4    19
# Comp:  2              HeII4687    0.02135      0.11      -4    19
# Comp:  2               HeI5876     0.9651      0.11      -4    19
# Comp:  2          [OIII]5007_d      3.762      0.14      -4    19
# Comp:  2            [OI]6300_d     0.9373      0.14      -4    19
# Comp:  2           [NII]6583_d      12.91      0.14      -4    19
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:   38.9; gas flux:      3 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  97.47; gas flux:     10 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  282.7; gas flux:     40 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  46.43; gas flux:      7 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  33.56; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.2149; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  9.798; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  29.06; gas flux:      4 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  7.076; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  91.28; gas flux:     18 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        81
#  comp.  1:        -6         1
#  comp.  2:        -4        24
# chi2/DOF: 0.7295; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.334      0.11      -6     1
# Comp:  1                 Hbeta      9.873      0.11      -6     1
# Comp:  1                Halpha      29.61      0.11      -6     1
# Comp:  2             [SII]6716      4.665      0.12      -4    24
# Comp:  2             [SII]6731      3.546      0.12      -4    24
# Comp:  2              HeII4687    0.01925      0.12      -4    24
# Comp:  2               HeI5876      1.123      0.12      -4    24
# Comp:  2          [OIII]5007_d      3.669      0.15      -4    24
# Comp:  2            [OI]6300_d      1.028      0.15      -4    24
# Comp:  2           [NII]6583_d      13.21      0.15      -4    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        71
#  comp.  1:        -7        17
#  comp.  2:        -4        23
# chi2/DOF: 0.6957; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.155      0.11      -7    17
# Comp:  1                 Hbeta      8.783      0.11      -7    17
# Comp:  1                Halpha      30.15      0.11      -7    17
# Comp:  2             [SII]6716      4.903      0.12      -4    23
# Comp:  2             [SII]6731      3.509      0.12      -4    23
# Comp:  2              HeII4687    0.04905      0.12      -4    23
# Comp:  2               HeI5876     0.9370      0.12      -4    23
# Comp:  2          [OIII]5007_d      3.849      0.15      -4    23
# Comp:  2            [OI]6300_d     0.9003      0.15      -4    23
# Comp:  2           [NII]6583_d      13.23      0.15      -4    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        72
#  comp.  1:        -6        10
#  comp.  2:        -5        17
# chi2/DOF: 0.6913; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.659      0.11      -6    10
# Comp:  1                 Hbeta      11.19      0.11      -6    10
# Comp:  1                Halpha      29.50      0.11      -6    10
# Comp:  2             [SII]6716      4.695      0.11      -5    17
# Comp:  2             [SII]6731      3.312      0.11      -5    17
# Comp:  2              HeII4687    0.01750      0.11      -5    17
# Comp:  2               HeI5876      1.108      0.11      -5    17
# Comp:  2          [OIII]5007_d      3.637      0.14      -5    17
# Comp:  2            [OI]6300_d     0.9285      0.14      -5    17
# Comp:  2           [NII]6583_d      12.76      0.14      -5    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        50
#  comp.  1:        -6        16
#  comp.  2:        -6        11
# chi2/DOF: 0.7508; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.637      0.11      -6    16
# Comp:  1                 Hbeta      10.07      0.11      -6    16
# Comp:  1                Halpha      29.59      0.11      -6    16
# Comp:  2             [SII]6716      4.802      0.11      -6    11
# Comp:  2             [SII]6731      3.429      0.11      -6    11
# Comp:  2              HeII4687    0.03861      0.11      -6    11
# Comp:  2               HeI5876      1.089      0.11      -6    11
# Comp:  2          [OIII]5007_d      3.476      0.14      -6    11
# Comp:  2            [OI]6300_d     0.9232      0.14      -6    11
# Comp:  2           [NII]6583_d      12.56      0.14      -6    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        79
#  comp.  1:        -5         1
#  comp.  2:        -4        23
# chi2/DOF: 0.7010; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.624      0.11      -5     1
# Comp:  1                 Hbeta      8.547      0.11      -5     1
# Comp:  1                Halpha      28.89      0.11      -5     1
# Comp:  2             [SII]6716      5.123      0.12      -4    23
# Comp:  2             [SII]6731      3.714      0.12      -4    23
# Comp:  2              HeII4687   0.005430      0.12      -4    23
# Comp:  2               HeI5876      1.201      0.12      -4    23
# Comp:  2          [OIII]5007_d      3.949      0.15      -4    23
# Comp:  2            [OI]6300_d      1.046      0.15      -4    23
# Comp:  2           [NII]6583_d      12.96      0.15      -4    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        85
#  comp.  1:        -6         7
#  comp.  2:        -4        25
# chi2/DOF: 0.6754; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.923      0.11      -6     7
# Comp:  1                 Hbeta      9.091      0.11      -6     7
# Comp:  1                Halpha      28.86      0.11      -6     7
# Comp:  2             [SII]6716      5.365      0.12      -4    25
# Comp:  2             [SII]6731      3.723      0.12      -4    25
# Comp:  2              HeII4687      0.000      0.12      -4    25
# Comp:  2               HeI5876      1.042      0.12      -4    25
# Comp:  2          [OIII]5007_d      3.960      0.15      -4    25
# Comp:  2            [OI]6300_d     0.8938      0.15      -4    25
# Comp:  2           [NII]6583_d      13.23      0.15      -4    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        75
#  comp.  1:        -3         7
#  comp.  2:        -3        11
# chi2/DOF: 0.6906; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.705      0.11      -3     7
# Comp:  1                 Hbeta      10.73      0.11      -3     7
# Comp:  1                Halpha      29.13      0.11      -3     7
# Comp:  2             [SII]6716      4.670      0.11      -3    11
# Comp:  2             [SII]6731      3.206      0.11      -3    11
# Comp:  2              HeII4687      0.000      0.11      -3    11
# Comp:  2               HeI5876     0.9375      0.11      -3    11
# Comp:  2          [OIII]5007_d      3.598      0.14      -3    11
# Comp:  2            [OI]6300_d     0.9034      0.14      -3    11
# Comp:  2           [NII]6583_d      12.52      0.14      -3    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        78
#  comp.  1:        -3         8
#  comp.  2:        -3        15
# chi2/DOF: 0.6911; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.557      0.11      -3     8
# Comp:  1                 Hbeta      10.30      0.11      -3     8
# Comp:  1                Halpha      28.99      0.11      -3     8
# Comp:  2             [SII]6716      4.577      0.11      -3    15
# Comp:  2             [SII]6731      3.180      0.11      -3    15
# Comp:  2              HeII4687    0.03347      0.11      -3    15
# Comp:  2               HeI5876      1.063      0.11      -3    15
# Comp:  2          [OIII]5007_d      3.713      0.14      -3    15
# Comp:  2            [OI]6300_d     0.8757      0.14      -3    15
# Comp:  2           [NII]6583_d      12.71      0.14      -3    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         6        63
#  comp.  1:        -7        20
#  comp.  2:        -2        21
# chi2/DOF: 0.6837; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.811      0.11      -7    20
# Comp:  1                 Hbeta      9.049      0.11      -7    20
# Comp:  1                Halpha      29.27      0.11      -7    20
# Comp:  2             [SII]6716      4.762      0.11      -2    21
# Comp:  2             [SII]6731      3.415      0.11      -2    21
# Comp:  2              HeII4687    0.04354      0.11      -2    21
# Comp:  2               HeI5876      1.042      0.11      -2    21
# Comp:  2          [OIII]5007_d      4.114      0.15      -2    21
# Comp:  2            [OI]6300_d     0.9758      0.15      -2    21
# Comp:  2           [NII]6583_d      13.02      0.15      -2    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        93
#  comp.  1:        -7         1
#  comp.  2:        -5        20
# chi2/DOF: 0.6922; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.369      0.11      -7     1
# Comp:  1                 Hbeta      8.662      0.11      -7     1
# Comp:  1                Halpha      29.13      0.11      -7     1
# Comp:  2             [SII]6716      5.295      0.11      -5    20
# Comp:  2             [SII]6731      3.608      0.11      -5    20
# Comp:  2              HeII4687  0.0005787      0.11      -5    20
# Comp:  2               HeI5876      1.201      0.11      -5    20
# Comp:  2          [OIII]5007_d      3.871      0.14      -5    20
# Comp:  2            [OI]6300_d     0.9206      0.14      -5    20
# Comp:  2           [NII]6583_d      13.03      0.14      -5    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        77
#  comp.  1:        -6         1
#  comp.  2:        -2        17
# chi2/DOF: 0.7118; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.449      0.11      -6     1
# Comp:  1                 Hbeta      9.146      0.11      -6     1
# Comp:  1                Halpha      29.65      0.11      -6     1
# Comp:  2             [SII]6716      4.941      0.11      -2    17
# Comp:  2             [SII]6731      3.312      0.11      -2    17
# Comp:  2              HeII4687    0.04210      0.11      -2    17
# Comp:  2               HeI5876     0.9365      0.11      -2    17
# Comp:  2          [OIII]5007_d      3.788      0.14      -2    17
# Comp:  2            [OI]6300_d     0.9557      0.14      -2    17
# Comp:  2           [NII]6583_d      12.96      0.14      -2    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        63
#  comp.  1:        -6        14
#  comp.  2:        -4        13
# chi2/DOF: 0.7218; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.408      0.11      -6    14
# Comp:  1                 Hbeta      10.81      0.11      -6    14
# Comp:  1                Halpha      30.06      0.11      -6    14
# Comp:  2             [SII]6716      4.451      0.11      -4    13
# Comp:  2             [SII]6731      3.244      0.11      -4    13
# Comp:  2              HeII4687      0.000      0.11      -4    13
# Comp:  2               HeI5876     0.9643      0.11      -4    13
# Comp:  2          [OIII]5007_d      3.762      0.14      -4    13
# Comp:  2            [OI]6300_d     0.9094      0.14      -4    13
# Comp:  2           [NII]6583_d      12.52      0.14      -4    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        79
#  comp.  1:        -4         1
#  comp.  2:        -6        19
# chi2/DOF: 0.7296; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.940      0.11      -4     1
# Comp:  1                 Hbeta      10.36      0.11      -4     1
# Comp:  1                Halpha      29.12      0.11      -4     1
# Comp:  2             [SII]6716      4.963      0.11      -6    19
# Comp:  2             [SII]6731      3.285      0.11      -6    19
# Comp:  2              HeII4687    0.02936      0.11      -6    19
# Comp:  2               HeI5876     0.8852      0.11      -6    19
# Comp:  2          [OIII]5007_d      3.998      0.14      -6    19
# Comp:  2            [OI]6300_d     0.9327      0.14      -6    19
# Comp:  2           [NII]6583_d      13.01      0.14      -6    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        48
#  comp.  1:        -5        22
#  comp.  2:        -2        24
# chi2/DOF: 0.6988; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.222      0.12      -5    22
# Comp:  1                 Hbeta      11.07      0.12      -5    22
# Comp:  1                Halpha      29.56      0.12      -5    22
# Comp:  2             [SII]6716      4.554      0.12      -2    24
# Comp:  2             [SII]6731      3.477      0.12      -2    24
# Comp:  2              HeII4687      0.000      0.12      -2    24
# Comp:  2               HeI5876      1.080      0.12      -2    24
# Comp:  2          [OIII]5007_d      3.845      0.15      -2    24
# Comp:  2            [OI]6300_d      1.006      0.15      -2    24
# Comp:  2           [NII]6583_d      13.03      0.15      -2    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        69
#  comp.  1:        -5         1
#  comp.  2:        -5         6
# chi2/DOF: 0.7283; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.747      0.11      -5     1
# Comp:  1                 Hbeta      9.850      0.11      -5     1
# Comp:  1                Halpha      28.54      0.11      -5     1
# Comp:  2             [SII]6716      4.300      0.11      -5     6
# Comp:  2             [SII]6731      3.080      0.11      -5     6
# Comp:  2              HeII4687      0.000      0.11      -5     6
# Comp:  2               HeI5876     0.8613      0.11      -5     6
# Comp:  2          [OIII]5007_d      3.496      0.14      -5     6
# Comp:  2            [OI]6300_d     0.9206      0.14      -5     6
# Comp:  2           [NII]6583_d      12.45      0.14      -5     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17       100
#  comp.  1:        -5         1
#  comp.  2:        -4         3
# chi2/DOF: 0.7096; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.392      0.11      -5     1
# Comp:  1                 Hbeta      10.49      0.11      -5     1
# Comp:  1                Halpha      29.26      0.11      -5     1
# Comp:  2             [SII]6716      5.002      0.11      -4     3
# Comp:  2             [SII]6731      3.255      0.11      -4     3
# Comp:  2              HeII4687    0.02139      0.11      -4     3
# Comp:  2               HeI5876     0.8573      0.11      -4     3
# Comp:  2          [OIII]5007_d      3.606      0.14      -4     3
# Comp:  2            [OI]6300_d     0.9442      0.14      -4     3
# Comp:  2           [NII]6583_d      12.57      0.14      -4     3
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        91
#  comp.  1:        -5         1
#  comp.  2:        -6        16
# chi2/DOF: 0.6916; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.691      0.11      -5     1
# Comp:  1                 Hbeta      10.95      0.11      -5     1
# Comp:  1                Halpha      29.87      0.11      -5     1
# Comp:  2             [SII]6716      5.055      0.11      -6    16
# Comp:  2             [SII]6731      3.479      0.11      -6    16
# Comp:  2              HeII4687    0.03044      0.11      -6    16
# Comp:  2               HeI5876      1.120      0.11      -6    16
# Comp:  2          [OIII]5007_d      3.833      0.14      -6    16
# Comp:  2            [OI]6300_d     0.9205      0.14      -6    16
# Comp:  2           [NII]6583_d      12.87      0.14      -6    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        74
#  comp.  1:        -5         7
#  comp.  2:        -5        23
# chi2/DOF: 0.7168; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.318      0.11      -5     7
# Comp:  1                 Hbeta      9.423      0.11      -5     7
# Comp:  1                Halpha      29.74      0.11      -5     7
# Comp:  2             [SII]6716      4.958      0.12      -5    23
# Comp:  2             [SII]6731      3.396      0.12      -5    23
# Comp:  2              HeII4687    0.01046      0.12      -5    23
# Comp:  2               HeI5876      1.131      0.12      -5    23
# Comp:  2          [OIII]5007_d      4.151      0.15      -5    23
# Comp:  2            [OI]6300_d     0.9125      0.15      -5    23
# Comp:  2           [NII]6583_d      12.93      0.15      -5    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        89
#  comp.  1:        -5        21
#  comp.  2:        -6        17
# chi2/DOF: 0.7312; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.618      0.12      -5    21
# Comp:  1                 Hbeta      9.647      0.12      -5    21
# Comp:  1                Halpha      29.86      0.12      -5    21
# Comp:  2             [SII]6716      5.070      0.11      -6    17
# Comp:  2             [SII]6731      3.417      0.11      -6    17
# Comp:  2              HeII4687    0.02307      0.11      -6    17
# Comp:  2               HeI5876     0.8530      0.11      -6    17
# Comp:  2          [OIII]5007_d      3.740      0.14      -6    17
# Comp:  2            [OI]6300_d     0.8897      0.14      -6    17
# Comp:  2           [NII]6583_d      12.93      0.14      -6    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        79
#  comp.  1:        -6         1
#  comp.  2:        -4        22
# chi2/DOF: 0.7281; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.920      0.11      -6     1
# Comp:  1                 Hbeta      10.37      0.11      -6     1
# Comp:  1                Halpha      29.73      0.11      -6     1
# Comp:  2             [SII]6716      5.099      0.12      -4    22
# Comp:  2             [SII]6731      3.582      0.12      -4    22
# Comp:  2              HeII4687   0.007809      0.12      -4    22
# Comp:  2               HeI5876     0.8212      0.12      -4    22
# Comp:  2          [OIII]5007_d      3.545      0.15      -4    22
# Comp:  2            [OI]6300_d     0.9321      0.15      -4    22
# Comp:  2           [NII]6583_d      13.18      0.15      -4    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        87
#  comp.  1:        -7         1
#  comp.  2:        -3        15
# chi2/DOF: 0.7268; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.804      0.11      -7     1
# Comp:  1                 Hbeta      10.21      0.11      -7     1
# Comp:  1                Halpha      29.47      0.11      -7     1
# Comp:  2             [SII]6716      4.596      0.11      -3    15
# Comp:  2             [SII]6731      3.406      0.11      -3    15
# Comp:  2              HeII4687    0.02635      0.11      -3    15
# Comp:  2               HeI5876     0.9682      0.11      -3    15
# Comp:  2          [OIII]5007_d      4.069      0.14      -3    15
# Comp:  2            [OI]6300_d     0.9186      0.14      -3    15
# Comp:  2           [NII]6583_d      12.95      0.14      -3    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        78
#  comp.  1:        -6         1
#  comp.  2:        -2        20
# chi2/DOF: 0.6968; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.520      0.11      -6     1
# Comp:  1                 Hbeta      9.169      0.11      -6     1
# Comp:  1                Halpha      29.73      0.11      -6     1
# Comp:  2             [SII]6716      4.629      0.11      -2    20
# Comp:  2             [SII]6731      3.686      0.11      -2    20
# Comp:  2              HeII4687    0.05496      0.11      -2    20
# Comp:  2               HeI5876     0.7382      0.11      -2    20
# Comp:  2          [OIII]5007_d      3.988      0.14      -2    20
# Comp:  2            [OI]6300_d     0.9379      0.14      -2    20
# Comp:  2           [NII]6583_d      13.07      0.14      -2    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        58
#  comp.  1:        -7        14
#  comp.  2:        -2        25
# chi2/DOF: 0.7280; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.657      0.11      -7    14
# Comp:  1                 Hbeta      10.02      0.11      -7    14
# Comp:  1                Halpha      30.05      0.11      -7    14
# Comp:  2             [SII]6716      4.593      0.12      -2    25
# Comp:  2             [SII]6731      3.528      0.12      -2    25
# Comp:  2              HeII4687      0.000      0.12      -2    25
# Comp:  2               HeI5876      1.178      0.12      -2    25
# Comp:  2          [OIII]5007_d      4.251      0.15      -2    25
# Comp:  2            [OI]6300_d      1.003      0.15      -2    25
# Comp:  2           [NII]6583_d      12.95      0.15      -2    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        89
#  comp.  1:        -3        11
#  comp.  2:        -2        23
# chi2/DOF: 0.7037; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.085      0.11      -3    11
# Comp:  1                 Hbeta      10.60      0.11      -3    11
# Comp:  1                Halpha      29.30      0.11      -3    11
# Comp:  2             [SII]6716      4.899      0.12      -2    23
# Comp:  2             [SII]6731      3.335      0.12      -2    23
# Comp:  2              HeII4687    0.02061      0.12      -2    23
# Comp:  2               HeI5876      1.095      0.12      -2    23
# Comp:  2          [OIII]5007_d      3.907      0.15      -2    23
# Comp:  2            [OI]6300_d     0.9342      0.15      -2    23
# Comp:  2           [NII]6583_d      13.04      0.15      -2    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        90
#  comp.  1:        -6         1
#  comp.  2:        -4        26
# chi2/DOF: 0.6867; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.305      0.11      -6     1
# Comp:  1                 Hbeta      8.862      0.11      -6     1
# Comp:  1                Halpha      29.67      0.11      -6     1
# Comp:  2             [SII]6716      4.762      0.12      -4    26
# Comp:  2             [SII]6731      3.585      0.12      -4    26
# Comp:  2              HeII4687    0.04943      0.12      -4    26
# Comp:  2               HeI5876     0.8780      0.12      -4    26
# Comp:  2          [OIII]5007_d      3.696      0.15      -4    26
# Comp:  2            [OI]6300_d     0.9858      0.15      -4    26
# Comp:  2           [NII]6583_d      13.34      0.15      -4    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        59
#  comp.  1:        -5        24
#  comp.  2:        -7        10
# chi2/DOF: 0.7012; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.591      0.12      -5    24
# Comp:  1                 Hbeta      9.745      0.12      -5    24
# Comp:  1                Halpha      30.12      0.12      -5    24
# Comp:  2             [SII]6716      5.126      0.11      -7    10
# Comp:  2             [SII]6731      3.455      0.11      -7    10
# Comp:  2              HeII4687    0.05296      0.11      -7    10
# Comp:  2               HeI5876     0.8226      0.11      -7    10
# Comp:  2          [OIII]5007_d      3.809      0.14      -7    10
# Comp:  2            [OI]6300_d     0.9564      0.14      -7    10
# Comp:  2           [NII]6583_d      12.67      0.14      -7    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        77
#  comp.  1:        -6         4
#  comp.  2:        -1        21
# chi2/DOF: 0.6912; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.514      0.11      -6     4
# Comp:  1                 Hbeta      11.04      0.11      -6     4
# Comp:  1                Halpha      29.19      0.11      -6     4
# Comp:  2             [SII]6716      4.780      0.12      -1    21
# Comp:  2             [SII]6731      3.518      0.12      -1    21
# Comp:  2              HeII4687    0.06099      0.12      -1    21
# Comp:  2               HeI5876     0.8384      0.12      -1    21
# Comp:  2          [OIII]5007_d      3.897      0.15      -1    21
# Comp:  2            [OI]6300_d     0.9688      0.15      -1    21
# Comp:  2           [NII]6583_d      13.16      0.15      -1    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        68
#  comp.  1:        -5        15
#  comp.  2:        -3        20
# chi2/DOF: 0.7333; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.736      0.11      -5    15
# Comp:  1                 Hbeta      9.844      0.11      -5    15
# Comp:  1                Halpha      28.88      0.11      -5    15
# Comp:  2             [SII]6716      5.309      0.11      -3    20
# Comp:  2             [SII]6731      3.145      0.11      -3    20
# Comp:  2              HeII4687    0.02789      0.11      -3    20
# Comp:  2               HeI5876     0.9732      0.11      -3    20
# Comp:  2          [OIII]5007_d      3.650      0.15      -3    20
# Comp:  2            [OI]6300_d     0.8669      0.15      -3    20
# Comp:  2           [NII]6583_d      13.00      0.15      -3    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        46
#  comp.  1:        -6        20
#  comp.  2:        -3        22
# chi2/DOF: 0.6914; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.992      0.11      -6    20
# Comp:  1                 Hbeta      11.30      0.11      -6    20
# Comp:  1                Halpha      29.39      0.11      -6    20
# Comp:  2             [SII]6716      4.791      0.12      -3    22
# Comp:  2             [SII]6731      3.509      0.12      -3    22
# Comp:  2              HeII4687    0.04890      0.12      -3    22
# Comp:  2               HeI5876     0.9341      0.12      -3    22
# Comp:  2          [OIII]5007_d      4.001      0.15      -3    22
# Comp:  2            [OI]6300_d     0.9134      0.15      -3    22
# Comp:  2           [NII]6583_d      13.04      0.15      -3    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        71
#  comp.  1:        -8        14
#  comp.  2:        -4        25
# chi2/DOF: 0.7389; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.371      0.11      -8    14
# Comp:  1                 Hbeta      10.28      0.11      -8    14
# Comp:  1                Halpha      29.71      0.11      -8    14
# Comp:  2             [SII]6716      5.147      0.12      -4    25
# Comp:  2             [SII]6731      3.530      0.12      -4    25
# Comp:  2              HeII4687   0.005240      0.12      -4    25
# Comp:  2               HeI5876     0.8432      0.12      -4    25
# Comp:  2          [OIII]5007_d      3.920      0.15      -4    25
# Comp:  2            [OI]6300_d     0.9733      0.15      -4    25
# Comp:  2           [NII]6583_d      13.26      0.15      -4    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        68
#  comp.  1:        -4        11
#  comp.  2:        -2        21
# chi2/DOF: 0.7355; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.647      0.11      -4    11
# Comp:  1                 Hbeta      9.273      0.11      -4    11
# Comp:  1                Halpha      29.08      0.11      -4    11
# Comp:  2             [SII]6716      4.841      0.12      -2    21
# Comp:  2             [SII]6731      3.309      0.12      -2    21
# Comp:  2              HeII4687    0.01439      0.12      -2    21
# Comp:  2               HeI5876     0.8932      0.12      -2    21
# Comp:  2          [OIII]5007_d      3.893      0.15      -2    21
# Comp:  2            [OI]6300_d     0.8932      0.15      -2    21
# Comp:  2           [NII]6583_d      12.95      0.15      -2    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        61
#  comp.  1:        -7        20
#  comp.  2:        -5        14
# chi2/DOF: 0.6864; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.602      0.11      -7    20
# Comp:  1                 Hbeta      8.886      0.11      -7    20
# Comp:  1                Halpha      29.29      0.11      -7    20
# Comp:  2             [SII]6716      4.998      0.11      -5    14
# Comp:  2             [SII]6731      3.355      0.11      -5    14
# Comp:  2              HeII4687    0.03695      0.11      -5    14
# Comp:  2               HeI5876     0.9223      0.11      -5    14
# Comp:  2          [OIII]5007_d      3.968      0.14      -5    14
# Comp:  2            [OI]6300_d     0.9541      0.14      -5    14
# Comp:  2           [NII]6583_d      12.64      0.14      -5    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        72
#  comp.  1:        -6         5
#  comp.  2:        -2        18
# chi2/DOF: 0.6905; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.623      0.11      -6     5
# Comp:  1                 Hbeta      11.08      0.11      -6     5
# Comp:  1                Halpha      29.30      0.11      -6     5
# Comp:  2             [SII]6716      5.204      0.11      -2    18
# Comp:  2             [SII]6731      3.462      0.11      -2    18
# Comp:  2              HeII4687    0.03014      0.11      -2    18
# Comp:  2               HeI5876     0.9702      0.11      -2    18
# Comp:  2          [OIII]5007_d      3.439      0.14      -2    18
# Comp:  2            [OI]6300_d     0.9156      0.14      -2    18
# Comp:  2           [NII]6583_d      12.89      0.14      -2    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        98
#  comp.  1:        -4        12
#  comp.  2:        -4        22
# chi2/DOF: 0.6887; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.679      0.11      -4    12
# Comp:  1                 Hbeta      11.12      0.11      -4    12
# Comp:  1                Halpha      28.93      0.11      -4    12
# Comp:  2             [SII]6716      4.814      0.12      -4    22
# Comp:  2             [SII]6731      3.732      0.12      -4    22
# Comp:  2              HeII4687    0.01894      0.12      -4    22
# Comp:  2               HeI5876      1.022      0.12      -4    22
# Comp:  2          [OIII]5007_d      3.655      0.15      -4    22
# Comp:  2            [OI]6300_d     0.9060      0.15      -4    22
# Comp:  2           [NII]6583_d      12.88      0.15      -4    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        79
#  comp.  1:        -6         1
#  comp.  2:        -2        16
# chi2/DOF: 0.6952; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.127      0.11      -6     1
# Comp:  1                 Hbeta      8.963      0.11      -6     1
# Comp:  1                Halpha      28.61      0.11      -6     1
# Comp:  2             [SII]6716      4.733      0.11      -2    16
# Comp:  2             [SII]6731      3.289      0.11      -2    16
# Comp:  2              HeII4687      0.000      0.11      -2    16
# Comp:  2               HeI5876     0.8966      0.11      -2    16
# Comp:  2          [OIII]5007_d      3.759      0.14      -2    16
# Comp:  2            [OI]6300_d     0.8932      0.14      -2    16
# Comp:  2           [NII]6583_d      12.65      0.14      -2    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        76
#  comp.  1:        -4         9
#  comp.  2:        -2        21
# chi2/DOF: 0.6938; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.820      0.11      -4     9
# Comp:  1                 Hbeta      11.05      0.11      -4     9
# Comp:  1                Halpha      29.28      0.11      -4     9
# Comp:  2             [SII]6716      4.792      0.12      -2    21
# Comp:  2             [SII]6731      3.529      0.12      -2    21
# Comp:  2              HeII4687    0.03446      0.12      -2    21
# Comp:  2               HeI5876      1.127      0.12      -2    21
# Comp:  2          [OIII]5007_d      3.761      0.15      -2    21
# Comp:  2            [OI]6300_d     0.9922      0.15      -2    21
# Comp:  2           [NII]6583_d      12.94      0.15      -2    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        64
#  comp.  1:        -5        18
#  comp.  2:        -5         1
# chi2/DOF: 0.7036; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.861      0.11      -5    18
# Comp:  1                 Hbeta      11.04      0.11      -5    18
# Comp:  1                Halpha      29.51      0.11      -5    18
# Comp:  2             [SII]6716      4.758      0.11      -5     1
# Comp:  2             [SII]6731      3.139      0.11      -5     1
# Comp:  2              HeII4687    0.02173      0.11      -5     1
# Comp:  2               HeI5876     0.8658      0.11      -5     1
# Comp:  2          [OIII]5007_d      3.789      0.14      -5     1
# Comp:  2            [OI]6300_d     0.9011      0.14      -5     1
# Comp:  2           [NII]6583_d      12.45      0.14      -5     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        65
#  comp.  1:        -6        21
#  comp.  2:        -4        22
# chi2/DOF: 0.7243; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.749      0.12      -6    21
# Comp:  1                 Hbeta      9.725      0.12      -6    21
# Comp:  1                Halpha      29.79      0.12      -6    21
# Comp:  2             [SII]6716      5.238      0.12      -4    22
# Comp:  2             [SII]6731      3.593      0.12      -4    22
# Comp:  2              HeII4687  0.0002198      0.12      -4    22
# Comp:  2               HeI5876     0.9033      0.12      -4    22
# Comp:  2          [OIII]5007_d      3.694      0.15      -4    22
# Comp:  2            [OI]6300_d     0.9343      0.15      -4    22
# Comp:  2           [NII]6583_d      13.06      0.15      -4    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        61
#  comp.  1:        -5        20
#  comp.  2:        -4        21
# chi2/DOF: 0.7395; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.824      0.11      -5    20
# Comp:  1                 Hbeta      10.15      0.11      -5    20
# Comp:  1                Halpha      29.82      0.11      -5    20
# Comp:  2             [SII]6716      4.815      0.12      -4    21
# Comp:  2             [SII]6731      3.203      0.12      -4    21
# Comp:  2              HeII4687    0.02295      0.12      -4    21
# Comp:  2               HeI5876     0.7604      0.12      -4    21
# Comp:  2          [OIII]5007_d      3.950      0.15      -4    21
# Comp:  2            [OI]6300_d     0.9618      0.15      -4    21
# Comp:  2           [NII]6583_d      12.86      0.15      -4    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        59
#  comp.  1:        -6        20
#  comp.  2:        -5        20
# chi2/DOF: 0.6887; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        85
#  comp.  1:        -5         1
#  comp.  2:        -5        21
# chi2/DOF: 0.7275; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.148      0.11      -5     1
# Comp:  1                 Hbeta      10.55      0.11      -5     1
# Comp:  1                Halpha      29.28      0.11      -5     1
# Comp:  2             [SII]6716      5.030      0.12      -5    21
# Comp:  2             [SII]6731      3.261      0.12      -5    21
# Comp:  2              HeII4687    0.02118      0.12      -5    21
# Comp:  2               HeI5876     0.9755      0.12      -5    21
# Comp:  2          [OIII]5007_d      3.773      0.15      -5    21
# Comp:  2            [OI]6300_d     0.8586      0.15      -5    21
# Comp:  2           [NII]6583_d      13.04      0.15      -5    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        73
#  comp.  1:        -5        13
#  comp.  2:        -4        16
# chi2/DOF: 0.7417; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.694      0.11      -5    13
# Comp:  1                 Hbeta      9.788      0.11      -5    13
# Comp:  1                Halpha      28.75      0.11      -5    13
# Comp:  2             [SII]6716      4.719      0.11      -4    16
# Comp:  2             [SII]6731      3.661      0.11      -4    16
# Comp:  2              HeII4687      0.000      0.11      -4    16
# Comp:  2               HeI5876     0.8390      0.11      -4    16
# Comp:  2          [OIII]5007_d      3.768      0.14      -4    16
# Comp:  2            [OI]6300_d     0.9288      0.14      -4    16
# Comp:  2           [NII]6583_d      12.73      0.14      -4    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        63
#  comp.  1:        -8        18
#  comp.  2:        -3        15
# chi2/DOF: 0.7321; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.333      0.11      -8    18
# Comp:  1                 Hbeta      9.671      0.11      -8    18
# Comp:  1                Halpha      29.74      0.11      -8    18
# Comp:  2             [SII]6716      5.173      0.11      -3    15
# Comp:  2             [SII]6731      3.505      0.11      -3    15
# Comp:  2              HeII4687    0.01543      0.11      -3    15
# Comp:  2               HeI5876      1.048      0.11      -3    15
# Comp:  2          [OIII]5007_d      3.454      0.14      -3    15
# Comp:  2            [OI]6300_d     0.8794      0.14      -3    15
# Comp:  2           [NII]6583_d      12.73      0.14      -3    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        65
#  comp.  1:        -7        18
#  comp.  2:        -4        17
# chi2/DOF: 0.7191; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.442      0.11      -7    18
# Comp:  1                 Hbeta      9.634      0.11      -7    18
# Comp:  1                Halpha      29.70      0.11      -7    18
# Comp:  2             [SII]6716      4.451      0.11      -4    17
# Comp:  2             [SII]6731      3.461      0.11      -4    17
# Comp:  2              HeII4687    0.05386      0.11      -4    17
# Comp:  2               HeI5876      1.030      0.11      -4    17
# Comp:  2          [OIII]5007_d      3.619      0.14      -4    17
# Comp:  2            [OI]6300_d     0.8958      0.14      -4    17
# Comp:  2           [NII]6583_d      12.61      0.14      -4    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        71
#  comp.  1:        -7         1
#  comp.  2:        -3        17
# chi2/DOF: 0.7206; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.926      0.11      -7     1
# Comp:  1                 Hbeta      9.029      0.11      -7     1
# Comp:  1                Halpha      29.54      0.11      -7     1
# Comp:  2             [SII]6716      4.514      0.11      -3    17
# Comp:  2             [SII]6731      3.465      0.11      -3    17
# Comp:  2              HeII4687    0.04831      0.11      -3    17
# Comp:  2               HeI5876     0.8398      0.11      -3    17
# Comp:  2          [OIII]5007_d      3.862      0.14      -3    17
# Comp:  2            [OI]6300_d     0.8537      0.14      -3    17
# Comp:  2           [NII]6583_d      12.88      0.14      -3    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        71
#  comp.  1:        -7         1
#  comp.  2:        -7        14
# chi2/DOF: 0.7197; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.102      0.11      -7     1
# Comp:  1                 Hbeta      9.132      0.11      -7     1
# Comp:  1                Halpha      29.14      0.11      -7     1
# Comp:  2             [SII]6716      5.128      0.11      -7    14
# Comp:  2             [SII]6731      3.310      0.11      -7    14
# Comp:  2              HeII4687    0.03291      0.11      -7    14
# Comp:  2               HeI5876     0.7288      0.11      -7    14
# Comp:  2          [OIII]5007_d      4.020      0.14      -7    14
# Comp:  2            [OI]6300_d     0.9609      0.14      -7    14
# Comp:  2           [NII]6583_d      12.70      0.14      -7    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         5        60
#  comp.  1:        -6        20
#  comp.  2:        -4        24
# chi2/DOF: 0.6868; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.613      0.11      -6    20
# Comp:  1                 Hbeta      11.43      0.11      -6    20
# Comp:  1                Halpha      29.43      0.11      -6    20
# Comp:  2             [SII]6716      5.122      0.12      -4    24
# Comp:  2             [SII]6731      3.452      0.12      -4    24
# Comp:  2              HeII4687   0.007872      0.12      -4    24
# Comp:  2               HeI5876     0.8883      0.12      -4    24
# Comp:  2          [OIII]5007_d      3.741      0.15      -4    24
# Comp:  2            [OI]6300_d     0.9093      0.15      -4    24
# Comp:  2           [NII]6583_d      13.20      0.15      -4    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48        67
#  comp.  1:        -5         3
#  comp.  2:        -4        14
# chi2/DOF: 0.7064; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.359      0.11      -5     3
# Comp:  1                 Hbeta      10.72      0.11      -5     3
# Comp:  1                Halpha      29.78      0.11      -5     3
# Comp:  2             [SII]6716      4.654      0.11      -4    14
# Comp:  2             [SII]6731      3.180      0.11      -4    14
# Comp:  2              HeII4687    0.02234      0.11      -4    14
# Comp:  2               HeI5876      1.171      0.11      -4    14
# Comp:  2          [OIII]5007_d      3.649      0.14      -4    14
# Comp:  2            [OI]6300_d      1.009      0.14      -4    14
# Comp:  2           [NII]6583_d      12.78      0.14      -4    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        80
#  comp.  1:        -5        11
#  comp.  2:        -4        23
# chi2/DOF: 0.7386; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.729      0.11      -5    11
# Comp:  1                 Hbeta      9.386      0.11      -5    11
# Comp:  1                Halpha      28.71      0.11      -5    11
# Comp:  2             [SII]6716      4.638      0.12      -4    23
# Comp:  2             [SII]6731      3.509      0.12      -4    23
# Comp:  2              HeII4687   0.002450      0.12      -4    23
# Comp:  2               HeI5876      1.165      0.12      -4    23
# Comp:  2          [OIII]5007_d      3.920      0.15      -4    23
# Comp:  2            [OI]6300_d     0.8955      0.15      -4    23
# Comp:  2           [NII]6583_d      12.94      0.15      -4    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        75
#  comp.  1:        -4         7
#  comp.  2:        -6        23
# chi2/DOF: 0.6874; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.507      0.11      -4     7
# Comp:  1                 Hbeta      10.93      0.11      -4     7
# Comp:  1                Halpha      29.26      0.11      -4     7
# Comp:  2             [SII]6716      4.621      0.12      -6    23
# Comp:  2             [SII]6731      3.460      0.12      -6    23
# Comp:  2              HeII4687      0.000      0.12      -6    23
# Comp:  2               HeI5876     0.7922      0.12      -6    23
# Comp:  2          [OIII]5007_d      3.870      0.15      -6    23
# Comp:  2            [OI]6300_d     0.9945      0.15      -6    23
# Comp:  2           [NII]6583_d      13.02      0.15      -6    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        79
#  comp.  1:        -5         6
#  comp.  2:        -6        23
# chi2/DOF: 0.7333; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.042      0.11      -5     6
# Comp:  1                 Hbeta      10.05      0.11      -5     6
# Comp:  1                Halpha      28.78      0.11      -5     6
# Comp:  2             [SII]6716      4.478      0.12      -6    23
# Comp:  2             [SII]6731      3.320      0.12      -6    23
# Comp:  2              HeII4687    0.03726      0.12      -6    23
# Comp:  2               HeI5876     0.8615      0.12      -6    23
# Comp:  2          [OIII]5007_d      3.872      0.15      -6    23
# Comp:  2            [OI]6300_d     0.9120      0.15      -6    23
# Comp:  2           [NII]6583_d      12.90      0.15      -6    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        77
#  comp.  1:        -6         3
#  comp.  2:        -5        23
# chi2/DOF: 0.7331; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.402      0.11      -6     3
# Comp:  1                 Hbeta      10.41      0.11      -6     3
# Comp:  1                Halpha      28.68      0.11      -6     3
# Comp:  2             [SII]6716      4.787      0.12      -5    23
# Comp:  2             [SII]6731      3.728      0.12      -5    23
# Comp:  2              HeII4687   0.004569      0.12      -5    23
# Comp:  2               HeI5876     0.9097      0.12      -5    23
# Comp:  2          [OIII]5007_d      3.919      0.15      -5    23
# Comp:  2            [OI]6300_d     0.9668      0.15      -5    23
# Comp:  2           [NII]6583_d      13.12      0.15      -5    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        73
#  comp.  1:        -6        20
#  comp.  2:        -4        22
# chi2/DOF: 0.7083; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.453      0.11      -6    20
# Comp:  1                 Hbeta      9.840      0.11      -6    20
# Comp:  1                Halpha      30.25      0.11      -6    20
# Comp:  2             [SII]6716      4.752      0.12      -4    22
# Comp:  2             [SII]6731      3.252      0.12      -4    22
# Comp:  2              HeII4687    0.03472      0.12      -4    22
# Comp:  2               HeI5876      1.129      0.12      -4    22
# Comp:  2          [OIII]5007_d      3.384      0.15      -4    22
# Comp:  2            [OI]6300_d     0.9630      0.15      -4    22
# Comp:  2           [NII]6583_d      13.19      0.15      -4    22
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.40708652, 0.7539933 , 0.55276458, 0.37095707, 0.2119928 ,
#        0.02025625, 0.15642908, 0.20213839, 0.05103978, 0.28830113])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([3.45170702e+00, 1.00056617e+01, 4.01712385e+01, 6.79022868e+00,
#        4.79586381e+00, 2.08706975e-02, 1.18277623e+00, 3.92902696e+00,
#        1.23171318e+00, 1.77287258e+01])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum3s_3_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum3s_3_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum3s_3_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum3s_3_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum3s_3_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name       Flux  Error flux
# 0        Hgamma   1.105289    0.130355
# 1         Hbeta   3.203965    0.241440
# 2        Halpha  12.863442    0.177004
# 3     [SII]6716   2.174335    0.118786
# 4     [SII]6731   1.535709    0.067883
# 5      HeII4687   0.006683    0.006486
# 6       HeI5876   0.378743    0.050091
# 7  [OIII]5007_d   1.258134    0.064728
# 8    [OI]6300_d   0.394413    0.016344
# 9   [NII]6583_d   5.677008    0.092318
#           Name       Flux  Error_flux
# 0       Hgamma   1.105289    0.130355
# 1        Hbeta   3.203965    0.241440
# 2       Halpha  12.863442    0.177004
# 3    [SII]6716   2.174335    0.118786
# 4    [SII]6731   1.535709    0.067883
# 5     HeII4687   0.006683    0.006486
# 6      HeI5876   0.378743    0.050091
# 7   [OIII]4959   0.314534    0.064728
# 8   [OIII]5007   0.943601    0.064728
# 9     [OI]6300   0.295810    0.016344
# 10    [OI]6364   0.098603    0.016344
# 11   [NII]6548   1.419252    0.092318
# 12   [NII]6583   4.257756    0.092318

# %%
np.median(flux_rf_rebin)
# Out:
# 0.320215217851414
