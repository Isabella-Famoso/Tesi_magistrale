# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_4.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/Spectra_extraction/redshift.txt")   
z = red[3][0] 
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_4']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15781412 2.1585315  2.15924888 ... 3.43833917 3.43905655 3.43977393]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:         3        33
# chi2/DOF: 0.004666; DOF: 1909; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
#  Best Fit:       Vel     sigma
#  comp.  0:         5        12
# chi2/DOF: 0.003704; DOF: 1889; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
# [1.14308282 1.09911838 1.03482008 ... 0.78041965 0.87978503 0.85899611]
# [1.07649763 1.11864934 1.14625004 ... 0.82370995 0.82631563 0.82694738]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([ 4.74170572, 12.44832553])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        36
#  comp.  1:         6        11
#  comp.  2:         4        24
# chi2/DOF: 0.8049; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.180      0.15       6    11
# Comp:  1                 Hbeta      3.172      0.15       6    11
# Comp:  1                Halpha      13.50      0.15       6    11
# Comp:  2             [SII]6716      2.873      0.15       4    24
# Comp:  2             [SII]6731      2.015      0.15       4    24
# Comp:  2              HeII4687      0.000      0.15       4    24
# Comp:  2               HeI5876     0.2489      0.15       4    24
# Comp:  2          [OIII]5007_d      2.714      0.19       4    24
# Comp:  2            [OI]6300_d     0.8859      0.19       4    24
# Comp:  2           [NII]6583_d      6.343      0.19       4    24
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  7.078; gas flux:      1 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:   18.5; gas flux:      3 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  80.84; gas flux:     18 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  16.47; gas flux:      4 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  11.28; gas flux:      3 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  1.394; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  11.08; gas flux:      3 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:   3.65; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:   27.2; gas flux:      9 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        30
#  comp.  1:         6        18
#  comp.  2:         6        27
# chi2/DOF: 0.7956; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 19/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.400      0.15       6    18
# Comp:  1                 Hbeta      3.191      0.15       6    18
# Comp:  1                Halpha      13.70      0.15       6    18
# Comp:  2             [SII]6716      3.044      0.15       6    27
# Comp:  2             [SII]6731      2.041      0.15       6    27
# Comp:  2              HeII4687     0.1689      0.15       6    27
# Comp:  2               HeI5876     0.2345      0.15       6    27
# Comp:  2          [OIII]5007_d      2.675      0.19       6    27
# Comp:  2            [OI]6300_d     0.7359      0.19       6    27
# Comp:  2           [NII]6583_d      6.364      0.19       6    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2        23
#  comp.  1:         6         1
#  comp.  2:        -0        28
# chi2/DOF: 0.7924; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.017      0.14       6     1
# Comp:  1                 Hbeta      3.016      0.14       6     1
# Comp:  1                Halpha      13.16      0.14       6     1
# Comp:  2             [SII]6716      2.887      0.15      -0    28
# Comp:  2             [SII]6731      2.128      0.15      -0    28
# Comp:  2              HeII4687      0.000      0.15      -0    28
# Comp:  2               HeI5876     0.2948      0.15      -0    28
# Comp:  2          [OIII]5007_d      2.181      0.19      -0    28
# Comp:  2            [OI]6300_d     0.7870      0.19      -0    28
# Comp:  2           [NII]6583_d      6.231      0.19      -0    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        10
#  comp.  1:         8        17
#  comp.  2:        -2        23
# chi2/DOF: 0.7863; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.759      0.15       8    17
# Comp:  1                 Hbeta      3.392      0.15       8    17
# Comp:  1                Halpha      13.80      0.15       8    17
# Comp:  2             [SII]6716      2.822      0.15      -2    23
# Comp:  2             [SII]6731      1.947      0.15      -2    23
# Comp:  2              HeII4687      0.000      0.15      -2    23
# Comp:  2               HeI5876     0.3495      0.15      -2    23
# Comp:  2          [OIII]5007_d      2.205      0.19      -2    23
# Comp:  2            [OI]6300_d      1.104      0.19      -2    23
# Comp:  2           [NII]6583_d      6.201      0.19      -2    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        16
#  comp.  1:         6         9
#  comp.  2:         2        19
# chi2/DOF: 0.7922; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.299      0.15       6     9
# Comp:  1                 Hbeta      3.018      0.15       6     9
# Comp:  1                Halpha      13.53      0.15       6     9
# Comp:  2             [SII]6716      2.672      0.15       2    19
# Comp:  2             [SII]6731      2.031      0.15       2    19
# Comp:  2              HeII4687     0.1633      0.15       2    19
# Comp:  2               HeI5876     0.2626      0.15       2    19
# Comp:  2          [OIII]5007_d      3.215      0.19       2    19
# Comp:  2            [OI]6300_d      1.097      0.19       2    19
# Comp:  2           [NII]6583_d      6.216      0.19       2    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        31
#  comp.  1:         6         1
#  comp.  2:         8        25
# chi2/DOF: 0.7926; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.274      0.14       6     1
# Comp:  1                 Hbeta      3.152      0.14       6     1
# Comp:  1                Halpha      13.35      0.14       6     1
# Comp:  2             [SII]6716      2.736      0.15       8    25
# Comp:  2             [SII]6731      2.102      0.15       8    25
# Comp:  2              HeII4687      0.000      0.15       8    25
# Comp:  2               HeI5876     0.2351      0.15       8    25
# Comp:  2          [OIII]5007_d      2.127      0.19       8    25
# Comp:  2            [OI]6300_d     0.7705      0.19       8    25
# Comp:  2           [NII]6583_d      6.288      0.19       8    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        40
#  comp.  1:         6         9
#  comp.  2:         5        25
# chi2/DOF: 0.7954; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.270      0.15       6     9
# Comp:  1                 Hbeta      3.006      0.15       6     9
# Comp:  1                Halpha      13.55      0.15       6     9
# Comp:  2             [SII]6716      2.858      0.15       5    25
# Comp:  2             [SII]6731      2.153      0.15       5    25
# Comp:  2              HeII4687     0.1163      0.15       5    25
# Comp:  2               HeI5876     0.1916      0.15       5    25
# Comp:  2          [OIII]5007_d      2.560      0.19       5    25
# Comp:  2            [OI]6300_d     0.9850      0.19       5    25
# Comp:  2           [NII]6583_d      6.375      0.19       5    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        41
#  comp.  1:         4         1
#  comp.  2:        -0        27
# chi2/DOF: 0.7866; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.252      0.14       4     1
# Comp:  1                 Hbeta      3.257      0.14       4     1
# Comp:  1                Halpha      13.42      0.14       4     1
# Comp:  2             [SII]6716      3.010      0.15      -0    27
# Comp:  2             [SII]6731      1.963      0.15      -0    27
# Comp:  2              HeII4687  0.0009168      0.15      -0    27
# Comp:  2               HeI5876     0.2762      0.15      -0    27
# Comp:  2          [OIII]5007_d      2.068      0.19      -0    27
# Comp:  2            [OI]6300_d     0.5691      0.19      -0    27
# Comp:  2           [NII]6583_d      6.362      0.19      -0    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:         5         3
#  comp.  2:         7        24
# chi2/DOF: 0.7862; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.382      0.14       5     3
# Comp:  1                 Hbeta      3.040      0.14       5     3
# Comp:  1                Halpha      13.33      0.14       5     3
# Comp:  2             [SII]6716      2.842      0.15       7    24
# Comp:  2             [SII]6731      2.134      0.15       7    24
# Comp:  2              HeII4687     0.1660      0.15       7    24
# Comp:  2               HeI5876     0.2405      0.15       7    24
# Comp:  2          [OIII]5007_d      2.322      0.19       7    24
# Comp:  2            [OI]6300_d      1.184      0.19       7    24
# Comp:  2           [NII]6583_d      6.420      0.19       7    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10        43
#  comp.  1:         8        21
#  comp.  2:         3         6
# chi2/DOF: 0.7901; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.477      0.15       8    21
# Comp:  1                 Hbeta      3.322      0.15       8    21
# Comp:  1                Halpha      13.95      0.15       8    21
# Comp:  2             [SII]6716      2.804      0.15       3     6
# Comp:  2             [SII]6731      2.023      0.15       3     6
# Comp:  2              HeII4687    0.01186      0.15       3     6
# Comp:  2               HeI5876     0.2833      0.15       3     6
# Comp:  2          [OIII]5007_d      3.212      0.18       3     6
# Comp:  2            [OI]6300_d     0.7468      0.18       3     6
# Comp:  2           [NII]6583_d      5.921      0.18       3     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        44
#  comp.  1:         7        15
#  comp.  2:         5        24
# chi2/DOF: 0.7900; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.334      0.15       7    15
# Comp:  1                 Hbeta      3.602      0.15       7    15
# Comp:  1                Halpha      13.90      0.15       7    15
# Comp:  2             [SII]6716      2.760      0.15       5    24
# Comp:  2             [SII]6731      1.921      0.15       5    24
# Comp:  2              HeII4687     0.3721      0.15       5    24
# Comp:  2               HeI5876     0.3255      0.15       5    24
# Comp:  2          [OIII]5007_d      2.599      0.19       5    24
# Comp:  2            [OI]6300_d      1.199      0.19       5    24
# Comp:  2           [NII]6583_d      6.330      0.19       5    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        65
#  comp.  1:         5         1
#  comp.  2:         6        25
# chi2/DOF: 0.7921; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9359      0.14       5     1
# Comp:  1                 Hbeta      3.276      0.14       5     1
# Comp:  1                Halpha      13.37      0.14       5     1
# Comp:  2             [SII]6716      2.883      0.15       6    25
# Comp:  2             [SII]6731      1.964      0.15       6    25
# Comp:  2              HeII4687      0.000      0.15       6    25
# Comp:  2               HeI5876     0.1946      0.15       6    25
# Comp:  2          [OIII]5007_d      2.913      0.19       6    25
# Comp:  2            [OI]6300_d     0.7444      0.19       6    25
# Comp:  2           [NII]6583_d      6.090      0.19       6    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        48
#  comp.  1:         6         5
#  comp.  2:         6        13
# chi2/DOF: 0.7949; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.209      0.15       6     5
# Comp:  1                 Hbeta      3.483      0.15       6     5
# Comp:  1                Halpha      13.54      0.15       6     5
# Comp:  2             [SII]6716      2.836      0.15       6    13
# Comp:  2             [SII]6731      1.872      0.15       6    13
# Comp:  2              HeII4687      0.000      0.15       6    13
# Comp:  2               HeI5876     0.2491      0.15       6    13
# Comp:  2          [OIII]5007_d      2.477      0.18       6    13
# Comp:  2            [OI]6300_d     0.9565      0.18       6    13
# Comp:  2           [NII]6583_d      6.218      0.18       6    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        35
#  comp.  1:         5         2
#  comp.  2:        -0        13
# chi2/DOF: 0.7900; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.063      0.14       5     2
# Comp:  1                 Hbeta      3.210      0.14       5     2
# Comp:  1                Halpha      13.64      0.14       5     2
# Comp:  2             [SII]6716      2.790      0.15      -0    13
# Comp:  2             [SII]6731      1.947      0.15      -0    13
# Comp:  2              HeII4687     0.3094      0.15      -0    13
# Comp:  2               HeI5876     0.2084      0.15      -0    13
# Comp:  2          [OIII]5007_d      3.256      0.18      -0    13
# Comp:  2            [OI]6300_d     0.7952      0.18      -0    13
# Comp:  2           [NII]6583_d      6.256      0.18      -0    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        29
#  comp.  1:         5         5
#  comp.  2:         6        24
# chi2/DOF: 0.7918; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.170      0.15       5     5
# Comp:  1                 Hbeta      2.886      0.15       5     5
# Comp:  1                Halpha      13.30      0.15       5     5
# Comp:  2             [SII]6716      2.828      0.15       6    24
# Comp:  2             [SII]6731      2.083      0.15       6    24
# Comp:  2              HeII4687      0.000      0.15       6    24
# Comp:  2               HeI5876     0.1933      0.15       6    24
# Comp:  2          [OIII]5007_d      3.206      0.19       6    24
# Comp:  2            [OI]6300_d     0.7129      0.19       6    24
# Comp:  2           [NII]6583_d      6.323      0.19       6    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        22
#  comp.  1:         4         3
#  comp.  2:         2        31
# chi2/DOF: 0.7880; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.261      0.14       4     3
# Comp:  1                 Hbeta      3.243      0.14       4     3
# Comp:  1                Halpha      13.54      0.14       4     3
# Comp:  2             [SII]6716      3.073      0.15       2    31
# Comp:  2             [SII]6731      2.076      0.15       2    31
# Comp:  2              HeII4687     0.2921      0.15       2    31
# Comp:  2               HeI5876     0.2973      0.15       2    31
# Comp:  2          [OIII]5007_d      2.757      0.19       2    31
# Comp:  2            [OI]6300_d     0.5856      0.19       2    31
# Comp:  2           [NII]6583_d      6.838      0.19       2    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        34
#  comp.  1:         5         1
#  comp.  2:         3        24
# chi2/DOF: 0.7960; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.156      0.14       5     1
# Comp:  1                 Hbeta      2.790      0.14       5     1
# Comp:  1                Halpha      13.52      0.14       5     1
# Comp:  2             [SII]6716      2.967      0.15       3    24
# Comp:  2             [SII]6731      2.026      0.15       3    24
# Comp:  2              HeII4687      0.000      0.15       3    24
# Comp:  2               HeI5876     0.2951      0.15       3    24
# Comp:  2          [OIII]5007_d      2.858      0.19       3    24
# Comp:  2            [OI]6300_d     0.7433      0.19       3    24
# Comp:  2           [NII]6583_d      6.657      0.19       3    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        30
#  comp.  1:         5         1
#  comp.  2:         6        23
# chi2/DOF: 0.7947; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.239      0.14       5     1
# Comp:  1                 Hbeta      3.014      0.14       5     1
# Comp:  1                Halpha      13.37      0.14       5     1
# Comp:  2             [SII]6716      2.830      0.15       6    23
# Comp:  2             [SII]6731      2.110      0.15       6    23
# Comp:  2              HeII4687      0.000      0.15       6    23
# Comp:  2               HeI5876     0.3255      0.15       6    23
# Comp:  2          [OIII]5007_d      2.782      0.19       6    23
# Comp:  2            [OI]6300_d      1.065      0.19       6    23
# Comp:  2           [NII]6583_d      6.020      0.19       6    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2        36
#  comp.  1:         7        17
#  comp.  2:         3        21
# chi2/DOF: 0.7881; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.309      0.15       7    17
# Comp:  1                 Hbeta      2.912      0.15       7    17
# Comp:  1                Halpha      13.89      0.15       7    17
# Comp:  2             [SII]6716      2.855      0.15       3    21
# Comp:  2             [SII]6731      1.992      0.15       3    21
# Comp:  2              HeII4687    0.01489      0.15       3    21
# Comp:  2               HeI5876     0.3444      0.15       3    21
# Comp:  2          [OIII]5007_d      3.237      0.19       3    21
# Comp:  2            [OI]6300_d     0.6855      0.19       3    21
# Comp:  2           [NII]6583_d      6.666      0.19       3    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        39
#  comp.  1:         6         1
#  comp.  2:         8        25
# chi2/DOF: 0.7963; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.293      0.14       6     1
# Comp:  1                 Hbeta      3.236      0.14       6     1
# Comp:  1                Halpha      13.54      0.14       6     1
# Comp:  2             [SII]6716      2.770      0.15       8    25
# Comp:  2             [SII]6731      2.033      0.15       8    25
# Comp:  2              HeII4687      0.000      0.15       8    25
# Comp:  2               HeI5876     0.2121      0.15       8    25
# Comp:  2          [OIII]5007_d      2.214      0.19       8    25
# Comp:  2            [OI]6300_d     0.9596      0.19       8    25
# Comp:  2           [NII]6583_d      6.493      0.19       8    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        30
#  comp.  1:         7         1
#  comp.  2:         6        23
# chi2/DOF: 0.7963; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.230      0.14       7     1
# Comp:  1                 Hbeta      3.442      0.14       7     1
# Comp:  1                Halpha      13.51      0.14       7     1
# Comp:  2             [SII]6716      2.992      0.15       6    23
# Comp:  2             [SII]6731      2.132      0.15       6    23
# Comp:  2              HeII4687      0.000      0.15       6    23
# Comp:  2               HeI5876     0.2497      0.15       6    23
# Comp:  2          [OIII]5007_d      2.516      0.19       6    23
# Comp:  2            [OI]6300_d     0.9266      0.19       6    23
# Comp:  2           [NII]6583_d      6.374      0.19       6    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        41
#  comp.  1:         5         1
#  comp.  2:         5        21
# chi2/DOF: 0.7909; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.069      0.14       5     1
# Comp:  1                 Hbeta      3.154      0.14       5     1
# Comp:  1                Halpha      13.36      0.14       5     1
# Comp:  2             [SII]6716      2.714      0.15       5    21
# Comp:  2             [SII]6731      2.096      0.15       5    21
# Comp:  2              HeII4687      0.000      0.15       5    21
# Comp:  2               HeI5876     0.2542      0.15       5    21
# Comp:  2          [OIII]5007_d      3.462      0.19       5    21
# Comp:  2            [OI]6300_d     0.7385      0.19       5    21
# Comp:  2           [NII]6583_d      6.070      0.19       5    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2         1
#  comp.  1:         5         3
#  comp.  2:         3        27
# chi2/DOF: 0.7858; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.215      0.14       5     3
# Comp:  1                 Hbeta      2.850      0.14       5     3
# Comp:  1                Halpha      13.41      0.14       5     3
# Comp:  2             [SII]6716      2.807      0.15       3    27
# Comp:  2             [SII]6731      2.018      0.15       3    27
# Comp:  2              HeII4687     0.1603      0.15       3    27
# Comp:  2               HeI5876     0.2864      0.15       3    27
# Comp:  2          [OIII]5007_d      2.111      0.19       3    27
# Comp:  2            [OI]6300_d      1.217      0.19       3    27
# Comp:  2           [NII]6583_d      6.081      0.19       3    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        38
#  comp.  1:         5         3
#  comp.  2:         6        22
# chi2/DOF: 0.7930; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.341      0.14       5     3
# Comp:  1                 Hbeta      3.224      0.14       5     3
# Comp:  1                Halpha      13.25      0.14       5     3
# Comp:  2             [SII]6716      2.787      0.15       6    22
# Comp:  2             [SII]6731      1.913      0.15       6    22
# Comp:  2              HeII4687      0.000      0.15       6    22
# Comp:  2               HeI5876     0.2185      0.15       6    22
# Comp:  2          [OIII]5007_d      2.198      0.19       6    22
# Comp:  2            [OI]6300_d     0.9240      0.19       6    22
# Comp:  2           [NII]6583_d      6.137      0.19       6    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        28
#  comp.  1:         6         1
#  comp.  2:         8        19
# chi2/DOF: 0.7952; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.333      0.14       6     1
# Comp:  1                 Hbeta      3.456      0.14       6     1
# Comp:  1                Halpha      13.37      0.14       6     1
# Comp:  2             [SII]6716      2.891      0.15       8    19
# Comp:  2             [SII]6731      2.096      0.15       8    19
# Comp:  2              HeII4687      0.000      0.15       8    19
# Comp:  2               HeI5876     0.1927      0.15       8    19
# Comp:  2          [OIII]5007_d      2.820      0.19       8    19
# Comp:  2            [OI]6300_d     0.6194      0.19       8    19
# Comp:  2           [NII]6583_d      6.111      0.19       8    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        27
#  comp.  1:         6         2
#  comp.  2:         5        29
# chi2/DOF: 0.7904; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.236      0.14       6     2
# Comp:  1                 Hbeta      3.296      0.14       6     2
# Comp:  1                Halpha      13.71      0.14       6     2
# Comp:  2             [SII]6716      2.928      0.15       5    29
# Comp:  2             [SII]6731      2.077      0.15       5    29
# Comp:  2              HeII4687   0.003842      0.15       5    29
# Comp:  2               HeI5876     0.2610      0.15       5    29
# Comp:  2          [OIII]5007_d      2.488      0.19       5    29
# Comp:  2            [OI]6300_d     0.8187      0.19       5    29
# Comp:  2           [NII]6583_d      6.147      0.19       5    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        34
#  comp.  1:         5         1
#  comp.  2:         4        28
# chi2/DOF: 0.7911; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.144      0.14       5     1
# Comp:  1                 Hbeta      3.091      0.14       5     1
# Comp:  1                Halpha      13.31      0.14       5     1
# Comp:  2             [SII]6716      3.075      0.15       4    28
# Comp:  2             [SII]6731      1.982      0.15       4    28
# Comp:  2              HeII4687      0.000      0.15       4    28
# Comp:  2               HeI5876     0.2512      0.15       4    28
# Comp:  2          [OIII]5007_d      2.082      0.19       4    28
# Comp:  2            [OI]6300_d     0.6725      0.19       4    28
# Comp:  2           [NII]6583_d      6.185      0.19       4    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4        26
#  comp.  1:         7        19
#  comp.  2:         6        10
# chi2/DOF: 0.7924; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.256      0.15       7    19
# Comp:  1                 Hbeta      3.015      0.15       7    19
# Comp:  1                Halpha      13.83      0.15       7    19
# Comp:  2             [SII]6716      2.635      0.15       6    10
# Comp:  2             [SII]6731      2.058      0.15       6    10
# Comp:  2              HeII4687      0.000      0.15       6    10
# Comp:  2               HeI5876     0.3268      0.15       6    10
# Comp:  2          [OIII]5007_d      3.024      0.18       6    10
# Comp:  2            [OI]6300_d     0.7800      0.18       6    10
# Comp:  2           [NII]6583_d      6.112      0.18       6    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        33
#  comp.  1:         5         6
#  comp.  2:         6        16
# chi2/DOF: 0.7939; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9858      0.15       5     6
# Comp:  1                 Hbeta      3.266      0.15       5     6
# Comp:  1                Halpha      13.45      0.15       5     6
# Comp:  2             [SII]6716      2.667      0.15       6    16
# Comp:  2             [SII]6731      2.000      0.15       6    16
# Comp:  2              HeII4687     0.2728      0.15       6    16
# Comp:  2               HeI5876     0.1989      0.15       6    16
# Comp:  2          [OIII]5007_d      2.745      0.19       6    16
# Comp:  2            [OI]6300_d     0.9950      0.19       6    16
# Comp:  2           [NII]6583_d      6.074      0.19       6    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:         6        17
#  comp.  2:         2        24
# chi2/DOF: 0.7955; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.259      0.15       6    17
# Comp:  1                 Hbeta      3.403      0.15       6    17
# Comp:  1                Halpha      13.82      0.15       6    17
# Comp:  2             [SII]6716      2.867      0.15       2    24
# Comp:  2             [SII]6731      1.923      0.15       2    24
# Comp:  2              HeII4687      0.000      0.15       2    24
# Comp:  2               HeI5876     0.2077      0.15       2    24
# Comp:  2          [OIII]5007_d      2.928      0.19       2    24
# Comp:  2            [OI]6300_d     0.9380      0.19       2    24
# Comp:  2           [NII]6583_d      6.374      0.19       2    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        29
#  comp.  1:         6        15
#  comp.  2:         8        32
# chi2/DOF: 0.7962; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9231      0.15       6    15
# Comp:  1                 Hbeta      3.378      0.15       6    15
# Comp:  1                Halpha      13.56      0.15       6    15
# Comp:  2             [SII]6716      2.967      0.15       8    32
# Comp:  2             [SII]6731      2.099      0.15       8    32
# Comp:  2              HeII4687      0.000      0.15       8    32
# Comp:  2               HeI5876     0.2146      0.15       8    32
# Comp:  2          [OIII]5007_d      2.992      0.19       8    32
# Comp:  2            [OI]6300_d      1.090      0.19       8    32
# Comp:  2           [NII]6583_d      6.633      0.19       8    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        38
#  comp.  1:         5         1
#  comp.  2:         7        24
# chi2/DOF: 0.7929; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.019      0.14       5     1
# Comp:  1                 Hbeta      3.243      0.14       5     1
# Comp:  1                Halpha      13.39      0.14       5     1
# Comp:  2             [SII]6716      2.899      0.15       7    24
# Comp:  2             [SII]6731      2.000      0.15       7    24
# Comp:  2              HeII4687     0.2027      0.15       7    24
# Comp:  2               HeI5876     0.2185      0.15       7    24
# Comp:  2          [OIII]5007_d      2.742      0.19       7    24
# Comp:  2            [OI]6300_d      1.227      0.19       7    24
# Comp:  2           [NII]6583_d      6.274      0.19       7    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        45
#  comp.  1:         7        17
#  comp.  2:         5        23
# chi2/DOF: 0.7843; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9357      0.15       7    17
# Comp:  1                 Hbeta      3.481      0.15       7    17
# Comp:  1                Halpha      13.87      0.15       7    17
# Comp:  2             [SII]6716      2.729      0.15       5    23
# Comp:  2             [SII]6731      2.097      0.15       5    23
# Comp:  2              HeII4687    0.05140      0.15       5    23
# Comp:  2               HeI5876     0.3106      0.15       5    23
# Comp:  2          [OIII]5007_d      3.453      0.19       5    23
# Comp:  2            [OI]6300_d      1.173      0.19       5    23
# Comp:  2           [NII]6583_d      6.001      0.19       5    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        39
#  comp.  1:         6        16
#  comp.  2:         4        23
# chi2/DOF: 0.7905; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9079      0.15       6    16
# Comp:  1                 Hbeta      3.075      0.15       6    16
# Comp:  1                Halpha      13.78      0.15       6    16
# Comp:  2             [SII]6716      2.887      0.15       4    23
# Comp:  2             [SII]6731      2.053      0.15       4    23
# Comp:  2              HeII4687      0.000      0.15       4    23
# Comp:  2               HeI5876     0.2288      0.15       4    23
# Comp:  2          [OIII]5007_d      2.429      0.19       4    23
# Comp:  2            [OI]6300_d     0.6825      0.19       4    23
# Comp:  2           [NII]6583_d      6.129      0.19       4    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7        50
#  comp.  1:         6        18
#  comp.  2:         4         6
# chi2/DOF: 0.7861; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.061      0.15       6    18
# Comp:  1                 Hbeta      3.254      0.15       6    18
# Comp:  1                Halpha      13.78      0.15       6    18
# Comp:  2             [SII]6716      2.865      0.15       4     6
# Comp:  2             [SII]6731      1.869      0.15       4     6
# Comp:  2              HeII4687      0.000      0.15       4     6
# Comp:  2               HeI5876     0.2087      0.15       4     6
# Comp:  2          [OIII]5007_d      3.011      0.18       4     6
# Comp:  2            [OI]6300_d     0.9826      0.18       4     6
# Comp:  2           [NII]6583_d      6.390      0.18       4     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -15        31
#  comp.  1:         5         6
#  comp.  2:         9        21
# chi2/DOF: 0.7954; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.287      0.15       5     6
# Comp:  1                 Hbeta      2.934      0.15       5     6
# Comp:  1                Halpha      13.59      0.15       5     6
# Comp:  2             [SII]6716      2.802      0.15       9    21
# Comp:  2             [SII]6731      2.101      0.15       9    21
# Comp:  2              HeII4687      0.000      0.15       9    21
# Comp:  2               HeI5876     0.2822      0.15       9    21
# Comp:  2          [OIII]5007_d      2.745      0.19       9    21
# Comp:  2            [OI]6300_d     0.8964      0.19       9    21
# Comp:  2           [NII]6583_d      6.262      0.19       9    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        15
#  comp.  1:         5        10
#  comp.  2:         3        25
# chi2/DOF: 0.7939; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.508      0.15       5    10
# Comp:  1                 Hbeta      3.509      0.15       5    10
# Comp:  1                Halpha      13.66      0.15       5    10
# Comp:  2             [SII]6716      2.758      0.15       3    25
# Comp:  2             [SII]6731      2.077      0.15       3    25
# Comp:  2              HeII4687      0.000      0.15       3    25
# Comp:  2               HeI5876     0.3171      0.15       3    25
# Comp:  2          [OIII]5007_d      2.625      0.19       3    25
# Comp:  2            [OI]6300_d      1.106      0.19       3    25
# Comp:  2           [NII]6583_d      6.666      0.19       3    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        44
#  comp.  1:         6         6
#  comp.  2:         2        24
# chi2/DOF: 0.7891; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9426      0.15       6     6
# Comp:  1                 Hbeta      2.883      0.15       6     6
# Comp:  1                Halpha      13.59      0.15       6     6
# Comp:  2             [SII]6716      2.994      0.15       2    24
# Comp:  2             [SII]6731      2.051      0.15       2    24
# Comp:  2              HeII4687     0.1818      0.15       2    24
# Comp:  2               HeI5876     0.2251      0.15       2    24
# Comp:  2          [OIII]5007_d      2.270      0.19       2    24
# Comp:  2            [OI]6300_d     0.7558      0.19       2    24
# Comp:  2           [NII]6583_d      6.379      0.19       2    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        38
#  comp.  1:         5         1
#  comp.  2:         5         8
# chi2/DOF: 0.7939; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8682      0.14       5     1
# Comp:  1                 Hbeta      3.151      0.14       5     1
# Comp:  1                Halpha      13.41      0.14       5     1
# Comp:  2             [SII]6716      2.827      0.15       5     8
# Comp:  2             [SII]6731      2.047      0.15       5     8
# Comp:  2              HeII4687    0.02122      0.15       5     8
# Comp:  2               HeI5876     0.2876      0.15       5     8
# Comp:  2          [OIII]5007_d      3.011      0.18       5     8
# Comp:  2            [OI]6300_d     0.9696      0.18       5     8
# Comp:  2           [NII]6583_d      6.013      0.18       5     8
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3        31
#  comp.  1:         6        15
#  comp.  2:        -0        20
# chi2/DOF: 0.7908; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.072      0.15       6    15
# Comp:  1                 Hbeta      3.348      0.15       6    15
# Comp:  1                Halpha      13.67      0.15       6    15
# Comp:  2             [SII]6716      2.822      0.15      -0    20
# Comp:  2             [SII]6731      2.090      0.15      -0    20
# Comp:  2              HeII4687      0.000      0.15      -0    20
# Comp:  2               HeI5876     0.2977      0.15      -0    20
# Comp:  2          [OIII]5007_d      3.332      0.19      -0    20
# Comp:  2            [OI]6300_d      1.042      0.19      -0    20
# Comp:  2           [NII]6583_d      6.285      0.19      -0    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        49
#  comp.  1:         8        18
#  comp.  2:         4        30
# chi2/DOF: 0.7858; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# Comp:  2           [NII]6583_d      6.428      0.19       2    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         1        24
#  comp.  1:         5         6
#  comp.  2:         3        26
# chi2/DOF: 0.7868; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.343      0.15       5     6
# Comp:  1                 Hbeta      3.525      0.15       5     6
# Comp:  1                Halpha      13.40      0.15       5     6
# Comp:  2             [SII]6716      3.016      0.15       3    26
# Comp:  2             [SII]6731      1.934      0.15       3    26
# Comp:  2              HeII4687      0.000      0.15       3    26
# Comp:  2               HeI5876     0.1613      0.15       3    26
# Comp:  2          [OIII]5007_d      3.478      0.19       3    26
# Comp:  2            [OI]6300_d     0.9776      0.19       3    26
# Comp:  2           [NII]6583_d      6.530      0.19       3    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        50
#  comp.  1:         6         1
#  comp.  2:        -1        27
# chi2/DOF: 0.7886; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9055      0.14       6     1
# Comp:  1                 Hbeta      3.184      0.14       6     1
# Comp:  1                Halpha      13.45      0.14       6     1
# Comp:  2             [SII]6716      2.996      0.15      -1    27
# Comp:  2             [SII]6731      1.965      0.15      -1    27
# Comp:  2              HeII4687      0.000      0.15      -1    27
# Comp:  2               HeI5876     0.3200      0.15      -1    27
# Comp:  2          [OIII]5007_d      2.792      0.19      -1    27
# Comp:  2            [OI]6300_d     0.8820      0.19      -1    27
# Comp:  2           [NII]6583_d      6.427      0.19      -1    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        43
#  comp.  1:         5         3
#  comp.  2:         5        20
# chi2/DOF: 0.7905; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.133      0.14       5     3
# Comp:  1                 Hbeta      3.094      0.14       5     3
# Comp:  1                Halpha      13.38      0.14       5     3
# Comp:  2             [SII]6716      2.729      0.15       5    20
# Comp:  2             [SII]6731      2.015      0.15       5    20
# Comp:  2              HeII4687      0.000      0.15       5    20
# Comp:  2               HeI5876     0.1903      0.15       5    20
# Comp:  2          [OIII]5007_d      2.155      0.19       5    20
# Comp:  2            [OI]6300_d     0.8655      0.19       5    20
# Comp:  2           [NII]6583_d      6.003      0.19       5    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        58
#  comp.  1:         6        12
#  comp.  2:         0        27
# chi2/DOF: 0.7943; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9045      0.15       6    12
# Comp:  1                 Hbeta      3.209      0.15       6    12
# Comp:  1                Halpha      13.47      0.15       6    12
# Comp:  2             [SII]6716      2.931      0.15       0    27
# Comp:  2             [SII]6731      2.158      0.15       0    27
# Comp:  2              HeII4687    0.06080      0.15       0    27
# Comp:  2               HeI5876     0.2043      0.15       0    27
# Comp:  2          [OIII]5007_d      2.756      0.19       0    27
# Comp:  2            [OI]6300_d     0.7268      0.19       0    27
# Comp:  2           [NII]6583_d      6.417      0.19       0    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        53
#  comp.  1:         7        18
#  comp.  2:         4        23
# chi2/DOF: 0.7923; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.309      0.15       7    18
# Comp:  1                 Hbeta      3.153      0.15       7    18
# Comp:  1                Halpha      13.70      0.15       7    18
# Comp:  2             [SII]6716      2.808      0.15       4    23
# Comp:  2             [SII]6731      2.028      0.15       4    23
# Comp:  2              HeII4687     0.2046      0.15       4    23
# Comp:  2               HeI5876     0.2012      0.15       4    23
# Comp:  2          [OIII]5007_d      2.792      0.19       4    23
# Comp:  2            [OI]6300_d     0.5244      0.19       4    23
# Comp:  2           [NII]6583_d      6.383      0.19       4    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        51
#  comp.  1:         6        17
#  comp.  2:         7        28
# chi2/DOF: 0.7867; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.258      0.15       6    17
# Comp:  1                 Hbeta      3.166      0.15       6    17
# Comp:  1                Halpha      13.73      0.15       6    17
# Comp:  2             [SII]6716      2.957      0.15       7    28
# Comp:  2             [SII]6731      1.996      0.15       7    28
# Comp:  2              HeII4687     0.2064      0.15       7    28
# Comp:  2               HeI5876     0.2497      0.15       7    28
# Comp:  2          [OIII]5007_d      2.102      0.19       7    28
# Comp:  2            [OI]6300_d      1.249      0.19       7    28
# Comp:  2           [NII]6583_d      6.422      0.19       7    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        55
#  comp.  1:         6         1
#  comp.  2:         7        28
# chi2/DOF: 0.7892; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.551      0.14       6     1
# Comp:  1                 Hbeta      3.437      0.14       6     1
# Comp:  1                Halpha      13.57      0.14       6     1
# Comp:  2             [SII]6716      2.857      0.15       7    28
# Comp:  2             [SII]6731      2.090      0.15       7    28
# Comp:  2              HeII4687    0.01797      0.15       7    28
# Comp:  2               HeI5876     0.3757      0.15       7    28
# Comp:  2          [OIII]5007_d      3.344      0.19       7    28
# Comp:  2            [OI]6300_d     0.7340      0.19       7    28
# Comp:  2           [NII]6583_d      6.451      0.19       7    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14        52
#  comp.  1:         8        15
#  comp.  2:         2        28
# chi2/DOF: 0.7957; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.347      0.15       8    15
# Comp:  1                 Hbeta      3.405      0.15       8    15
# Comp:  1                Halpha      13.79      0.15       8    15
# Comp:  2             [SII]6716      2.874      0.15       2    28
# Comp:  2             [SII]6731      2.040      0.15       2    28
# Comp:  2              HeII4687    0.03227      0.15       2    28
# Comp:  2               HeI5876     0.2928      0.15       2    28
# Comp:  2          [OIII]5007_d      2.809      0.19       2    28
# Comp:  2            [OI]6300_d     0.9468      0.19       2    28
# Comp:  2           [NII]6583_d      6.474      0.19       2    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        33
#  comp.  1:         7        17
#  comp.  2:         4        24
# chi2/DOF: 0.7974; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.015      0.15       7    17
# Comp:  1                 Hbeta      3.288      0.15       7    17
# Comp:  1                Halpha      13.59      0.15       7    17
# Comp:  2             [SII]6716      2.880      0.15       4    24
# Comp:  2             [SII]6731      2.115      0.15       4    24
# Comp:  2              HeII4687      0.000      0.15       4    24
# Comp:  2               HeI5876     0.2910      0.15       4    24
# Comp:  2          [OIII]5007_d      2.717      0.19       4    24
# Comp:  2            [OI]6300_d     0.8697      0.19       4    24
# Comp:  2           [NII]6583_d      6.198      0.19       4    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        19
#  comp.  1:         8        18
#  comp.  2:         1        23
# chi2/DOF: 0.7869; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.226      0.15       8    18
# Comp:  1                 Hbeta      3.102      0.15       8    18
# Comp:  1                Halpha      13.63      0.15       8    18
# Comp:  2             [SII]6716      2.942      0.15       1    23
# Comp:  2             [SII]6731      1.992      0.15       1    23
# Comp:  2              HeII4687     0.2668      0.15       1    23
# Comp:  2               HeI5876     0.2673      0.15       1    23
# Comp:  2          [OIII]5007_d      2.036      0.19       1    23
# Comp:  2            [OI]6300_d     0.5472      0.19       1    23
# Comp:  2           [NII]6583_d      6.247      0.19       1    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10         1
#  comp.  1:         5         1
#  comp.  2:        -2        24
# chi2/DOF: 0.7900; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.8105      0.14       5     1
# Comp:  1                 Hbeta      2.939      0.14       5     1
# Comp:  1                Halpha      13.30      0.14       5     1
# Comp:  2             [SII]6716      2.969      0.15      -2    24
# Comp:  2             [SII]6731      1.881      0.15      -2    24
# Comp:  2              HeII4687      0.000      0.15      -2    24
# Comp:  2               HeI5876     0.2055      0.15      -2    24
# Comp:  2          [OIII]5007_d      2.641      0.19      -2    24
# Comp:  2            [OI]6300_d     0.7703      0.19      -2    24
# Comp:  2           [NII]6583_d      6.377      0.19      -2    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        45
#  comp.  1:         5         1
#  comp.  2:         0        28
# chi2/DOF: 0.7846; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.302      0.14       5     1
# Comp:  1                 Hbeta      3.258      0.14       5     1
# Comp:  1                Halpha      13.41      0.14       5     1
# Comp:  2             [SII]6716      2.966      0.15       0    28
# Comp:  2             [SII]6731      2.073      0.15       0    28
# Comp:  2              HeII4687     0.1893      0.15       0    28
# Comp:  2               HeI5876     0.2873      0.15       0    28
# Comp:  2          [OIII]5007_d      3.416      0.19       0    28
# Comp:  2            [OI]6300_d     0.5158      0.19       0    28
# Comp:  2           [NII]6583_d      6.560      0.19       0    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5         1
#  comp.  1:         7        17
#  comp.  2:         6        27
# chi2/DOF: 0.7890; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.9715      0.15       7    17
# Comp:  1                 Hbeta      3.274      0.15       7    17
# Comp:  1                Halpha      13.70      0.15       7    17
# Comp:  2             [SII]6716      2.901      0.15       6    27
# Comp:  2             [SII]6731      1.872      0.15       6    27
# Comp:  2              HeII4687    0.04086      0.15       6    27
# Comp:  2               HeI5876     0.2283      0.15       6    27
# Comp:  2          [OIII]5007_d      2.238      0.19       6    27
# Comp:  2            [OI]6300_d     0.9124      0.19       6    27
# Comp:  2           [NII]6583_d      6.678      0.19       6    27
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_4_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_4_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_4_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_4_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_4_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
