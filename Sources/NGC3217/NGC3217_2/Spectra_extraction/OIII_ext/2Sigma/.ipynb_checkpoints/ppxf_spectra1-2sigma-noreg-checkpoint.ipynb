# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")
    print(pp.galaxy)
    print(pp.bestfit)
    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_1.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/Spectra_extraction/redshift.txt")     
z = red[0][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_1']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15798757 2.15870478 2.15942198 ... 3.43747274 3.43818994 3.43890714]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3161, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        17       380
# chi2/DOF: 0.007454; DOF: 1909; degree = 4; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/150
#  Best Fit:       Vel     sigma
#  comp.  0:        -1       482
# chi2/DOF: 0.005852; DOF: 1882; degree = 4; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# [0.51516462 0.53199666 0.55655963 ... 0.95939991 0.99785227 1.02250955]
# [0.65185316 0.64789889 0.64277422 ... 1.07756897 1.07771653 1.07785572]

# %%
pp_stars.sol

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")

# %%
dlam

# %%
line_wave

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -46        67
#  comp.  1:         8        12
#  comp.  2:        12         1
# chi2/DOF: 1.252; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.179      0.15       8    12
# Comp:  1                 Hbeta      8.030      0.15       8    12
# Comp:  1                Halpha      30.92      0.15       8    12
# Comp:  2             [SII]6716      4.735      0.15      12     1
# Comp:  2             [SII]6731      3.583      0.15      12     1
# Comp:  2              HeII4687    0.07262      0.15      12     1
# Comp:  2               HeI5876      1.101      0.15      12     1
# Comp:  2          [OIII]5007_d      7.366      0.19      12     1
# Comp:  2            [OI]6300_d      1.323      0.19      12     1
# Comp:  2           [NII]6583_d      11.47      0.19      12     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:         7         1
#  comp.  2:        10         9
# chi2/DOF: 1.221; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 40; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.165      0.15       7     1
# Comp:  1                 Hbeta      6.906      0.15       7     1
# Comp:  1                Halpha      30.62      0.15       7     1
# Comp:  2             [SII]6716      4.787      0.15      10     9
# Comp:  2             [SII]6731      3.660      0.15      10     9
# Comp:  2              HeII4687     0.1843      0.15      10     9
# Comp:  2               HeI5876     0.9880      0.15      10     9
# Comp:  2          [OIII]5007_d      7.648      0.19      10     9
# Comp:  2            [OI]6300_d      1.034      0.19      10     9
# Comp:  2           [NII]6583_d      11.63      0.19      10     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46       104
#  comp.  1:        10         1
#  comp.  2:        11         1
# chi2/DOF: 1.224; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.004      0.15      10     1
# Comp:  1                 Hbeta      7.870      0.15      10     1
# Comp:  1                Halpha      29.80      0.15      10     1
# Comp:  2             [SII]6716      4.332      0.15      11     1
# Comp:  2             [SII]6731      3.789      0.15      11     1
# Comp:  2              HeII4687    0.07892      0.15      11     1
# Comp:  2               HeI5876      1.018      0.15      11     1
# Comp:  2          [OIII]5007_d      6.968      0.19      11     1
# Comp:  2            [OI]6300_d      1.315      0.19      11     1
# Comp:  2           [NII]6583_d      11.26      0.19      11     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38         1
#  comp.  1:         8        16
#  comp.  2:        10         8
# chi2/DOF: 1.236; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.895      0.15       8    16
# Comp:  1                 Hbeta      8.028      0.15       8    16
# Comp:  1                Halpha      31.15      0.15       8    16
# Comp:  2             [SII]6716      4.875      0.15      10     8
# Comp:  2             [SII]6731      3.876      0.15      10     8
# Comp:  2              HeII4687     0.1973      0.15      10     8
# Comp:  2               HeI5876      1.084      0.15      10     8
# Comp:  2          [OIII]5007_d      7.614      0.19      10     8
# Comp:  2            [OI]6300_d      1.437      0.19      10     8
# Comp:  2           [NII]6583_d      11.54      0.19      10     8
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        24
#  comp.  1:         8         1
#  comp.  2:        13         1
# chi2/DOF: 1.215; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.262      0.15       8     1
# Comp:  1                 Hbeta      6.858      0.15       8     1
# Comp:  1                Halpha      31.32      0.15       8     1
# Comp:  2             [SII]6716      4.777      0.15      13     1
# Comp:  2             [SII]6731      3.422      0.15      13     1
# Comp:  2              HeII4687     0.1813      0.15      13     1
# Comp:  2               HeI5876     0.9334      0.15      13     1
# Comp:  2          [OIII]5007_d      7.096      0.19      13     1
# Comp:  2            [OI]6300_d      1.223      0.19      13     1
# Comp:  2           [NII]6583_d      11.39      0.19      13     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        79
#  comp.  1:         9        10
#  comp.  2:        14         1
# chi2/DOF: 1.237; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.072      0.15       9    10
# Comp:  1                 Hbeta      7.950      0.15       9    10
# Comp:  1                Halpha      29.95      0.15       9    10
# Comp:  2             [SII]6716      4.478      0.15      14     1
# Comp:  2             [SII]6731      3.484      0.15      14     1
# Comp:  2              HeII4687     0.1421      0.15      14     1
# Comp:  2               HeI5876      1.078      0.15      14     1
# Comp:  2          [OIII]5007_d      7.342      0.19      14     1
# Comp:  2            [OI]6300_d     0.9480      0.19      14     1
# Comp:  2           [NII]6583_d      11.37      0.19      14     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:        10        16
#  comp.  2:        11        15
# chi2/DOF: 1.225; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.371      0.15      10    16
# Comp:  1                 Hbeta      7.879      0.15      10    16
# Comp:  1                Halpha      30.20      0.15      10    16
# Comp:  2             [SII]6716      4.678      0.15      11    15
# Comp:  2             [SII]6731      3.924      0.15      11    15
# Comp:  2              HeII4687     0.1727      0.15      11    15
# Comp:  2               HeI5876     0.9297      0.15      11    15
# Comp:  2          [OIII]5007_d      7.023      0.19      11    15
# Comp:  2            [OI]6300_d      1.532      0.19      11    15
# Comp:  2           [NII]6583_d      11.83      0.19      11    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        43
#  comp.  1:        10         1
#  comp.  2:        14        17
# chi2/DOF: 1.227; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.319      0.15      10     1
# Comp:  1                 Hbeta      7.887      0.15      10     1
# Comp:  1                Halpha      29.72      0.15      10     1
# Comp:  2             [SII]6716      4.709      0.15      14    17
# Comp:  2             [SII]6731      3.478      0.15      14    17
# Comp:  2              HeII4687    0.06790      0.15      14    17
# Comp:  2               HeI5876     0.9689      0.15      14    17
# Comp:  2          [OIII]5007_d      7.013      0.19      14    17
# Comp:  2            [OI]6300_d      1.187      0.19      14    17
# Comp:  2           [NII]6583_d      11.60      0.19      14    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        44
#  comp.  1:         7        18
#  comp.  2:        10         6
# chi2/DOF: 1.222; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.129      0.15       7    18
# Comp:  1                 Hbeta      7.905      0.15       7    18
# Comp:  1                Halpha      32.09      0.15       7    18
# Comp:  2             [SII]6716      4.527      0.15      10     6
# Comp:  2             [SII]6731      3.439      0.15      10     6
# Comp:  2              HeII4687    0.05888      0.15      10     6
# Comp:  2               HeI5876     0.9452      0.15      10     6
# Comp:  2          [OIII]5007_d      6.921      0.19      10     6
# Comp:  2            [OI]6300_d     0.8528      0.19      10     6
# Comp:  2           [NII]6583_d      11.34      0.19      10     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        40
#  comp.  1:        10        18
#  comp.  2:        11        12
# chi2/DOF: 1.236; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.704      0.15      10    18
# Comp:  1                 Hbeta      7.909      0.15      10    18
# Comp:  1                Halpha      31.17      0.15      10    18
# Comp:  2             [SII]6716      4.709      0.15      11    12
# Comp:  2             [SII]6731      3.710      0.15      11    12
# Comp:  2              HeII4687     0.2063      0.15      11    12
# Comp:  2               HeI5876      1.058      0.15      11    12
# Comp:  2          [OIII]5007_d      7.851      0.19      11    12
# Comp:  2            [OI]6300_d      1.355      0.19      11    12
# Comp:  2           [NII]6583_d      11.50      0.19      11    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41         1
#  comp.  1:         8        15
#  comp.  2:        10         1
# chi2/DOF: 1.229; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.370      0.15       8    15
# Comp:  1                 Hbeta      8.922      0.15       8    15
# Comp:  1                Halpha      31.10      0.15       8    15
# Comp:  2             [SII]6716      4.671      0.15      10     1
# Comp:  2             [SII]6731      3.454      0.15      10     1
# Comp:  2              HeII4687    0.04310      0.15      10     1
# Comp:  2               HeI5876      1.090      0.15      10     1
# Comp:  2          [OIII]5007_d      7.044      0.19      10     1
# Comp:  2            [OI]6300_d      1.033      0.19      10     1
# Comp:  2           [NII]6583_d      11.32      0.19      10     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28       149
#  comp.  1:         8         5
#  comp.  2:        13         9
# chi2/DOF: 1.202; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.621      0.15       8     5
# Comp:  1                 Hbeta      6.696      0.15       8     5
# Comp:  1                Halpha      31.35      0.15       8     5
# Comp:  2             [SII]6716      4.609      0.15      13     9
# Comp:  2             [SII]6731      3.720      0.15      13     9
# Comp:  2              HeII4687    0.08386      0.15      13     9
# Comp:  2               HeI5876      1.147      0.15      13     9
# Comp:  2          [OIII]5007_d      6.374      0.19      13     9
# Comp:  2            [OI]6300_d     0.8434      0.19      13     9
# Comp:  2           [NII]6583_d      11.53      0.19      13     9
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -104       127
#  comp.  1:         6        13
#  comp.  2:        14        10
# chi2/DOF: 1.218; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.236      0.15       6    13
# Comp:  1                 Hbeta      7.846      0.15       6    13
# Comp:  1                Halpha      31.74      0.15       6    13
# Comp:  2             [SII]6716      4.442      0.15      14    10
# Comp:  2             [SII]6731      3.471      0.15      14    10
# Comp:  2              HeII4687     0.1963      0.15      14    10
# Comp:  2               HeI5876      1.161      0.15      14    10
# Comp:  2          [OIII]5007_d      7.827      0.19      14    10
# Comp:  2            [OI]6300_d      1.250      0.19      14    10
# Comp:  2           [NII]6583_d      11.70      0.19      14    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -62         1
#  comp.  1:        10         1
#  comp.  2:        14         8
# chi2/DOF: 1.207; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.991      0.15      10     1
# Comp:  1                 Hbeta      6.813      0.15      10     1
# Comp:  1                Halpha      30.49      0.15      10     1
# Comp:  2             [SII]6716      4.761      0.15      14     8
# Comp:  2             [SII]6731      3.619      0.15      14     8
# Comp:  2              HeII4687     0.1856      0.15      14     8
# Comp:  2               HeI5876      1.113      0.15      14     8
# Comp:  2          [OIII]5007_d      6.860      0.19      14     8
# Comp:  2            [OI]6300_d      1.151      0.19      14     8
# Comp:  2           [NII]6583_d      11.33      0.19      14     8
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -105        99
#  comp.  1:        10         1
#  comp.  2:        11         1
# chi2/DOF: 1.223; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.137      0.15      10     1
# Comp:  1                 Hbeta      7.637      0.15      10     1
# Comp:  1                Halpha      29.67      0.15      10     1
# Comp:  2             [SII]6716      4.360      0.15      11     1
# Comp:  2             [SII]6731      3.685      0.15      11     1
# Comp:  2              HeII4687    0.07485      0.15      11     1
# Comp:  2               HeI5876      1.050      0.15      11     1
# Comp:  2          [OIII]5007_d      7.673      0.19      11     1
# Comp:  2            [OI]6300_d      1.069      0.19      11     1
# Comp:  2           [NII]6583_d      11.30      0.19      11     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        53
#  comp.  1:         9        16
#  comp.  2:        11        12
# chi2/DOF: 1.207; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.773      0.15       9    16
# Comp:  1                 Hbeta      9.024      0.15       9    16
# Comp:  1                Halpha      30.37      0.15       9    16
# Comp:  2             [SII]6716      4.601      0.15      11    12
# Comp:  2             [SII]6731      3.847      0.15      11    12
# Comp:  2              HeII4687    0.03387      0.15      11    12
# Comp:  2               HeI5876     0.9933      0.15      11    12
# Comp:  2          [OIII]5007_d      7.639      0.19      11    12
# Comp:  2            [OI]6300_d      1.193      0.19      11    12
# Comp:  2           [NII]6583_d      11.72      0.19      11    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        35
#  comp.  1:         8        10
#  comp.  2:        11        19
# chi2/DOF: 1.248; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.285      0.15       8    10
# Comp:  1                 Hbeta      7.828      0.15       8    10
# Comp:  1                Halpha      30.82      0.15       8    10
# Comp:  2             [SII]6716      4.835      0.15      11    19
# Comp:  2             [SII]6731      3.508      0.15      11    19
# Comp:  2              HeII4687    0.05904      0.15      11    19
# Comp:  2               HeI5876      1.097      0.15      11    19
# Comp:  2          [OIII]5007_d      7.144      0.19      11    19
# Comp:  2            [OI]6300_d      1.584      0.19      11    19
# Comp:  2           [NII]6583_d      11.76      0.19      11    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        84
#  comp.  1:        10        18
#  comp.  2:        15         1
# chi2/DOF: 1.220; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.524      0.15      10    18
# Comp:  1                 Hbeta      8.018      0.15      10    18
# Comp:  1                Halpha      30.49      0.15      10    18
# Comp:  2             [SII]6716      4.389      0.15      15     1
# Comp:  2             [SII]6731      3.861      0.15      15     1
# Comp:  2              HeII4687     0.1021      0.15      15     1
# Comp:  2               HeI5876      1.059      0.15      15     1
# Comp:  2          [OIII]5007_d      6.357      0.19      15     1
# Comp:  2            [OI]6300_d      1.057      0.19      15     1
# Comp:  2           [NII]6583_d      11.27      0.19      15     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60       100
#  comp.  1:        10         1
#  comp.  2:        15         1
# chi2/DOF: 1.210; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.973      0.15      10     1
# Comp:  1                 Hbeta      6.772      0.15      10     1
# Comp:  1                Halpha      30.48      0.15      10     1
# Comp:  2             [SII]6716      4.802      0.15      15     1
# Comp:  2             [SII]6731      3.891      0.15      15     1
# Comp:  2              HeII4687     0.1034      0.15      15     1
# Comp:  2               HeI5876      1.171      0.15      15     1
# Comp:  2          [OIII]5007_d      7.262      0.19      15     1
# Comp:  2            [OI]6300_d      1.224      0.19      15     1
# Comp:  2           [NII]6583_d      11.65      0.19      15     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -61         1
#  comp.  1:        11         1
#  comp.  2:        10        14
# chi2/DOF: 1.198; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.102      0.15      11     1
# Comp:  1                 Hbeta      8.710      0.15      11     1
# Comp:  1                Halpha      30.41      0.15      11     1
# Comp:  2             [SII]6716      4.361      0.15      10    14
# Comp:  2             [SII]6731      3.589      0.15      10    14
# Comp:  2              HeII4687    0.08152      0.15      10    14
# Comp:  2               HeI5876      1.028      0.15      10    14
# Comp:  2          [OIII]5007_d      7.731      0.19      10    14
# Comp:  2            [OI]6300_d     0.9627      0.19      10    14
# Comp:  2           [NII]6583_d      11.39      0.19      10    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39        60
#  comp.  1:        11        11
#  comp.  2:        12         5
# chi2/DOF: 1.219; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.377      0.15      11    11
# Comp:  1                 Hbeta      8.005      0.15      11    11
# Comp:  1                Halpha      30.09      0.15      11    11
# Comp:  2             [SII]6716      4.565      0.15      12     5
# Comp:  2             [SII]6731      3.855      0.15      12     5
# Comp:  2              HeII4687    0.06199      0.15      12     5
# Comp:  2               HeI5876      1.015      0.15      12     5
# Comp:  2          [OIII]5007_d      7.094      0.19      12     5
# Comp:  2            [OI]6300_d      1.191      0.19      12     5
# Comp:  2           [NII]6583_d      11.61      0.19      12     5
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        59
#  comp.  1:         8        12
#  comp.  2:        15        11
# chi2/DOF: 1.249; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.322      0.15       8    12
# Comp:  1                 Hbeta      7.907      0.15       8    12
# Comp:  1                Halpha      30.97      0.15       8    12
# Comp:  2             [SII]6716      4.535      0.15      15    11
# Comp:  2             [SII]6731      3.530      0.15      15    11
# Comp:  2              HeII4687     0.1926      0.15      15    11
# Comp:  2               HeI5876     0.9788      0.15      15    11
# Comp:  2          [OIII]5007_d      7.154      0.19      15    11
# Comp:  2            [OI]6300_d      1.680      0.19      15    11
# Comp:  2           [NII]6583_d      11.74      0.19      15    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -56       111
#  comp.  1:         6        14
#  comp.  2:         9         1
# chi2/DOF: 1.204; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.086      0.15       6    14
# Comp:  1                 Hbeta      7.033      0.15       6    14
# Comp:  1                Halpha      31.24      0.15       6    14
# Comp:  2             [SII]6716      4.663      0.15       9     1
# Comp:  2             [SII]6731      3.707      0.15       9     1
# Comp:  2              HeII4687     0.1678      0.15       9     1
# Comp:  2               HeI5876      1.105      0.15       9     1
# Comp:  2          [OIII]5007_d      7.853      0.19       9     1
# Comp:  2            [OI]6300_d      1.291      0.19       9     1
# Comp:  2           [NII]6583_d      11.50      0.19       9     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1        39
#  comp.  1:         9        10
#  comp.  2:        13         1
# chi2/DOF: 1.241; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.090      0.15       9    10
# Comp:  1                 Hbeta      7.956      0.15       9    10
# Comp:  1                Halpha      31.52      0.15       9    10
# Comp:  2             [SII]6716      4.717      0.15      13     1
# Comp:  2             [SII]6731      3.401      0.15      13     1
# Comp:  2              HeII4687     0.1164      0.15      13     1
# Comp:  2               HeI5876      1.062      0.15      13     1
# Comp:  2          [OIII]5007_d      7.032      0.19      13     1
# Comp:  2            [OI]6300_d      1.310      0.19      13     1
# Comp:  2           [NII]6583_d      11.47      0.19      13     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        41
#  comp.  1:         8         2
#  comp.  2:        11        19
# chi2/DOF: 1.209; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.914      0.15       8     2
# Comp:  1                 Hbeta      8.892      0.15       8     2
# Comp:  1                Halpha      31.40      0.15       8     2
# Comp:  2             [SII]6716      5.001      0.15      11    19
# Comp:  2             [SII]6731      3.775      0.15      11    19
# Comp:  2              HeII4687    0.03818      0.15      11    19
# Comp:  2               HeI5876      1.101      0.15      11    19
# Comp:  2          [OIII]5007_d      7.717      0.19      11    19
# Comp:  2            [OI]6300_d      1.199      0.19      11    19
# Comp:  2           [NII]6583_d      11.96      0.19      11    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        83
#  comp.  1:         6        21
#  comp.  2:        17        16
# chi2/DOF: 1.197; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.149      0.15       6    21
# Comp:  1                 Hbeta      7.135      0.15       6    21
# Comp:  1                Halpha      31.69      0.15       6    21
# Comp:  2             [SII]6716      4.752      0.15      17    16
# Comp:  2             [SII]6731      3.679      0.15      17    16
# Comp:  2              HeII4687    0.08113      0.15      17    16
# Comp:  2               HeI5876     0.9505      0.15      17    16
# Comp:  2          [OIII]5007_d      6.825      0.19      17    16
# Comp:  2            [OI]6300_d      1.271      0.19      17    16
# Comp:  2           [NII]6583_d      11.91      0.19      17    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:         9        11
#  comp.  2:        12         1
# chi2/DOF: 1.238; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.482      0.15       9    11
# Comp:  1                 Hbeta      7.906      0.15       9    11
# Comp:  1                Halpha      31.61      0.15       9    11
# Comp:  2             [SII]6716      4.813      0.15      12     1
# Comp:  2             [SII]6731      3.619      0.15      12     1
# Comp:  2              HeII4687     0.1095      0.15      12     1
# Comp:  2               HeI5876      1.132      0.15      12     1
# Comp:  2          [OIII]5007_d      7.432      0.19      12     1
# Comp:  2            [OI]6300_d      1.301      0.19      12     1
# Comp:  2           [NII]6583_d      11.28      0.19      12     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        84
#  comp.  1:        10         1
#  comp.  2:        12         1
# chi2/DOF: 1.216; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.808      0.15      10     1
# Comp:  1                 Hbeta      6.749      0.15      10     1
# Comp:  1                Halpha      30.35      0.15      10     1
# Comp:  2             [SII]6716      4.392      0.15      12     1
# Comp:  2             [SII]6731      3.584      0.15      12     1
# Comp:  2              HeII4687    0.09560      0.15      12     1
# Comp:  2               HeI5876      1.094      0.15      12     1
# Comp:  2          [OIII]5007_d      7.830      0.19      12     1
# Comp:  2            [OI]6300_d      1.098      0.19      12     1
# Comp:  2           [NII]6583_d      11.37      0.19      12     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -68        46
#  comp.  1:         8        12
#  comp.  2:        14         1
# chi2/DOF: 1.245; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.177      0.15       8    12
# Comp:  1                 Hbeta      8.068      0.15       8    12
# Comp:  1                Halpha      30.96      0.15       8    12
# Comp:  2             [SII]6716      4.374      0.15      14     1
# Comp:  2             [SII]6731      3.651      0.15      14     1
# Comp:  2              HeII4687    0.09265      0.15      14     1
# Comp:  2               HeI5876     0.9494      0.15      14     1
# Comp:  2          [OIII]5007_d      7.479      0.19      14     1
# Comp:  2            [OI]6300_d      1.285      0.19      14     1
# Comp:  2           [NII]6583_d      11.42      0.19      14     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        81
#  comp.  1:         8         9
#  comp.  2:        11         1
# chi2/DOF: 1.209; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.294      0.15       8     9
# Comp:  1                 Hbeta      8.864      0.15       8     9
# Comp:  1                Halpha      31.60      0.15       8     9
# Comp:  2             [SII]6716      4.557      0.15      11     1
# Comp:  2             [SII]6731      3.431      0.15      11     1
# Comp:  2              HeII4687     0.1174      0.15      11     1
# Comp:  2               HeI5876     0.9040      0.15      11     1
# Comp:  2          [OIII]5007_d      7.873      0.19      11     1
# Comp:  2            [OI]6300_d      1.224      0.19      11     1
# Comp:  2           [NII]6583_d      11.23      0.19      11     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        72
#  comp.  1:         7        12
#  comp.  2:        12         1
# chi2/DOF: 1.245; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.446      0.15       7    12
# Comp:  1                 Hbeta      7.805      0.15       7    12
# Comp:  1                Halpha      30.82      0.15       7    12
# Comp:  2             [SII]6716      4.463      0.15      12     1
# Comp:  2             [SII]6731      3.561      0.15      12     1
# Comp:  2              HeII4687    0.03440      0.15      12     1
# Comp:  2               HeI5876      1.187      0.15      12     1
# Comp:  2          [OIII]5007_d      7.054      0.19      12     1
# Comp:  2            [OI]6300_d      1.112      0.19      12     1
# Comp:  2           [NII]6583_d      11.27      0.19      12     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        23         1
#  comp.  1:         9         6
#  comp.  2:        13         1
# chi2/DOF: 1.224; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.461      0.15       9     6
# Comp:  1                 Hbeta      6.977      0.15       9     6
# Comp:  1                Halpha      30.66      0.15       9     6
# Comp:  2             [SII]6716      4.622      0.15      13     1
# Comp:  2             [SII]6731      3.373      0.15      13     1
# Comp:  2              HeII4687    0.08391      0.15      13     1
# Comp:  2               HeI5876      1.048      0.15      13     1
# Comp:  2          [OIII]5007_d      6.832      0.19      13     1
# Comp:  2            [OI]6300_d     0.9925      0.19      13     1
# Comp:  2           [NII]6583_d      11.18      0.19      13     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14        34
#  comp.  1:         7        13
#  comp.  2:        12        21
# chi2/DOF: 1.200; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.963      0.15       7    13
# Comp:  1                 Hbeta      8.120      0.15       7    13
# Comp:  1                Halpha      31.87      0.15       7    13
# Comp:  2             [SII]6716      4.799      0.15      12    21
# Comp:  2             [SII]6731      3.474      0.15      12    21
# Comp:  2              HeII4687     0.1466      0.15      12    21
# Comp:  2               HeI5876      1.214      0.15      12    21
# Comp:  2          [OIII]5007_d      8.125      0.19      12    21
# Comp:  2            [OI]6300_d      1.259      0.19      12    21
# Comp:  2           [NII]6583_d      11.80      0.19      12    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88       107
#  comp.  1:        10        15
#  comp.  2:        15         1
# chi2/DOF: 1.211; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.196      0.15      10    15
# Comp:  1                 Hbeta      8.932      0.15      10    15
# Comp:  1                Halpha      30.25      0.15      10    15
# Comp:  2             [SII]6716      4.703      0.15      15     1
# Comp:  2             [SII]6731      3.465      0.15      15     1
# Comp:  2              HeII4687    0.05197      0.15      15     1
# Comp:  2               HeI5876      1.117      0.15      15     1
# Comp:  2          [OIII]5007_d      6.661      0.19      15     1
# Comp:  2            [OI]6300_d      1.477      0.19      15     1
# Comp:  2           [NII]6583_d      11.45      0.19      15     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        30
#  comp.  1:         8        22
#  comp.  2:        14         1
# chi2/DOF: 1.204; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.573      0.15       8    22
# Comp:  1                 Hbeta      7.158      0.15       8    22
# Comp:  1                Halpha      30.86      0.15       8    22
# Comp:  2             [SII]6716      4.616      0.15      14     1
# Comp:  2             [SII]6731      3.433      0.15      14     1
# Comp:  2              HeII4687     0.1187      0.15      14     1
# Comp:  2               HeI5876      1.023      0.15      14     1
# Comp:  2          [OIII]5007_d      6.656      0.19      14     1
# Comp:  2            [OI]6300_d     0.9314      0.19      14     1
# Comp:  2           [NII]6583_d      11.55      0.19      14     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75         1
#  comp.  1:         7        17
#  comp.  2:        14         1
# chi2/DOF: 1.217; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.533      0.15       7    17
# Comp:  1                 Hbeta      9.300      0.15       7    17
# Comp:  1                Halpha      31.46      0.15       7    17
# Comp:  2             [SII]6716      4.392      0.15      14     1
# Comp:  2             [SII]6731      3.583      0.15      14     1
# Comp:  2              HeII4687     0.1711      0.15      14     1
# Comp:  2               HeI5876      1.077      0.15      14     1
# Comp:  2          [OIII]5007_d      7.049      0.19      14     1
# Comp:  2            [OI]6300_d      1.242      0.19      14     1
# Comp:  2           [NII]6583_d      11.30      0.19      14     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81         1
#  comp.  1:        11         1
#  comp.  2:        15        20
# chi2/DOF: 1.210; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.102      0.15      11     1
# Comp:  1                 Hbeta      6.665      0.15      11     1
# Comp:  1                Halpha      30.38      0.15      11     1
# Comp:  2             [SII]6716      4.614      0.15      15    20
# Comp:  2             [SII]6731      3.552      0.15      15    20
# Comp:  2              HeII4687     0.1556      0.15      15    20
# Comp:  2               HeI5876      1.272      0.15      15    20
# Comp:  2          [OIII]5007_d      7.350      0.19      15    20
# Comp:  2            [OI]6300_d      1.046      0.19      15    20
# Comp:  2           [NII]6583_d      12.03      0.19      15    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37       105
#  comp.  1:         8         1
#  comp.  2:        12        21
# chi2/DOF: 1.219; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.262      0.15       8     1
# Comp:  1                 Hbeta      7.834      0.15       8     1
# Comp:  1                Halpha      31.33      0.15       8     1
# Comp:  2             [SII]6716      4.559      0.15      12    21
# Comp:  2             [SII]6731      3.625      0.15      12    21
# Comp:  2              HeII4687     0.1264      0.15      12    21
# Comp:  2               HeI5876     0.9016      0.15      12    21
# Comp:  2          [OIII]5007_d      7.192      0.19      12    21
# Comp:  2            [OI]6300_d      1.322      0.19      12    21
# Comp:  2           [NII]6583_d      11.99      0.19      12    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74       149
#  comp.  1:        11         1
#  comp.  2:        12        16
# chi2/DOF: 1.229; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 55; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.841      0.15      11     1
# Comp:  1                 Hbeta      7.748      0.15      11     1
# Comp:  1                Halpha      30.42      0.15      11     1
# Comp:  2             [SII]6716      4.663      0.15      12    16
# Comp:  2             [SII]6731      3.925      0.15      12    16
# Comp:  2              HeII4687     0.1908      0.15      12    16
# Comp:  2               HeI5876     0.9717      0.15      12    16
# Comp:  2          [OIII]5007_d      7.292      0.19      12    16
# Comp:  2            [OI]6300_d      1.453      0.19      12    16
# Comp:  2           [NII]6583_d      11.36      0.19      12    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70        33
#  comp.  1:        10        17
#  comp.  2:        10        21
# chi2/DOF: 1.220; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.132      0.15      10    17
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        54
#  comp.  1:         9        15
#  comp.  2:        15         1
# chi2/DOF: 1.245; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.529      0.15       9    15
# Comp:  1                 Hbeta      7.905      0.15       9    15
# Comp:  1                Halpha      31.01      0.15       9    15
# Comp:  2             [SII]6716      4.678      0.15      15     1
# Comp:  2             [SII]6731      3.622      0.15      15     1
# Comp:  2              HeII4687     0.1602      0.15      15     1
# Comp:  2               HeI5876      1.032      0.15      15     1
# Comp:  2          [OIII]5007_d      6.712      0.19      15     1
# Comp:  2            [OI]6300_d      1.539      0.19      15     1
# Comp:  2           [NII]6583_d      11.57      0.19      15     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        24
#  comp.  1:         7        22
#  comp.  2:        14         1
# chi2/DOF: 1.220; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.107      0.15       7    22
# Comp:  1                 Hbeta      8.230      0.15       7    22
# Comp:  1                Halpha      31.83      0.15       7    22
# Comp:  2             [SII]6716      4.533      0.15      14     1
# Comp:  2             [SII]6731      3.712      0.15      14     1
# Comp:  2              HeII4687    0.05601      0.15      14     1
# Comp:  2               HeI5876      1.065      0.15      14     1
# Comp:  2          [OIII]5007_d      6.637      0.19      14     1
# Comp:  2            [OI]6300_d      1.118      0.19      14     1
# Comp:  2           [NII]6583_d      11.57      0.19      14     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3       182
#  comp.  1:         7        13
#  comp.  2:        11        12
# chi2/DOF: 1.219; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.346      0.15       7    13
# Comp:  1                 Hbeta      6.932      0.15       7    13
# Comp:  1                Halpha      30.92      0.15       7    13
# Comp:  2             [SII]6716      4.396      0.15      11    12
# Comp:  2             [SII]6731      3.452      0.15      11    12
# Comp:  2              HeII4687     0.1396      0.15      11    12
# Comp:  2               HeI5876     0.9617      0.15      11    12
# Comp:  2          [OIII]5007_d      7.285      0.19      11    12
# Comp:  2            [OI]6300_d      1.458      0.19      11    12
# Comp:  2           [NII]6583_d      11.37      0.19      11    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12        49
#  comp.  1:         7        11
#  comp.  2:        13         1
# chi2/DOF: 1.219; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.152      0.15       7    11
# Comp:  1                 Hbeta      7.006      0.15       7    11
# Comp:  1                Halpha      30.91      0.15       7    11
# Comp:  2             [SII]6716      4.681      0.15      13     1
# Comp:  2             [SII]6731      3.680      0.15      13     1
# Comp:  2              HeII4687     0.1630      0.15      13     1
# Comp:  2               HeI5876     0.9988      0.15      13     1
# Comp:  2          [OIII]5007_d      6.525      0.19      13     1
# Comp:  2            [OI]6300_d      1.282      0.19      13     1
# Comp:  2           [NII]6583_d      11.31      0.19      13     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58       180
#  comp.  1:        11        10
#  comp.  2:        14        13
# chi2/DOF: 1.197; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.118      0.15      11    10
# Comp:  1                 Hbeta      8.796      0.15      11    10
# Comp:  1                Halpha      29.94      0.15      11    10
# Comp:  2             [SII]6716      4.800      0.15      14    13
# Comp:  2             [SII]6731      3.536      0.15      14    13
# Comp:  2              HeII4687     0.1392      0.15      14    13
# Comp:  2               HeI5876      1.145      0.15      14    13
# Comp:  2          [OIII]5007_d      7.313      0.19      14    13
# Comp:  2            [OI]6300_d      1.241      0.19      14    13
# Comp:  2           [NII]6583_d      11.79      0.19      14    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        56
#  comp.  1:         8         1
#  comp.  2:        18         1
# chi2/DOF: 1.203; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.837      0.15       8     1
# Comp:  1                 Hbeta      8.825      0.15       8     1
# Comp:  1                Halpha      31.31      0.15       8     1
# Comp:  2             [SII]6716      4.342      0.15      18     1
# Comp:  2             [SII]6731      3.416      0.15      18     1
# Comp:  2              HeII4687     0.1770      0.15      18     1
# Comp:  2               HeI5876      1.093      0.15      18     1
# Comp:  2          [OIII]5007_d      6.720      0.19      18     1
# Comp:  2            [OI]6300_d      1.182      0.19      18     1
# Comp:  2           [NII]6583_d      11.61      0.19      18     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        46         1
#  comp.  1:         6        20
#  comp.  2:        13         1
# chi2/DOF: 1.200; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.685      0.15       6    20
# Comp:  1                 Hbeta      7.155      0.15       6    20
# Comp:  1                Halpha      31.61      0.15       6    20
# Comp:  2             [SII]6716      4.730      0.15      13     1
# Comp:  2             [SII]6731      3.653      0.15      13     1
# Comp:  2              HeII4687     0.1143      0.15      13     1
# Comp:  2               HeI5876      1.105      0.15      13     1
# Comp:  2          [OIII]5007_d      7.194      0.19      13     1
# Comp:  2            [OI]6300_d      1.262      0.19      13     1
# Comp:  2           [NII]6583_d      11.47      0.19      13     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19       118
#  comp.  1:        10         4
#  comp.  2:        10        12
# chi2/DOF: 1.202; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.811      0.15      10     4
# Comp:  1                 Hbeta      6.794      0.15      10     4
# Comp:  1                Halpha      29.78      0.15      10     4
# Comp:  2             [SII]6716      4.525      0.15      10    12
# Comp:  2             [SII]6731      3.633      0.15      10    12
# Comp:  2              HeII4687     0.1821      0.15      10    12
# Comp:  2               HeI5876      1.024      0.15      10    12
# Comp:  2          [OIII]5007_d      7.627      0.19      10    12
# Comp:  2            [OI]6300_d     0.8905      0.19      10    12
# Comp:  2           [NII]6583_d      11.72      0.19      10    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10         1
#  comp.  1:         7        16
#  comp.  2:        14         1
# chi2/DOF: 1.176; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.492      0.15       7    16
# Comp:  1                 Hbeta      7.012      0.15       7    16
# Comp:  1                Halpha      31.96      0.15       7    16
# Comp:  2             [SII]6716      4.762      0.15      14     1
# Comp:  2             [SII]6731      3.805      0.15      14     1
# Comp:  2              HeII4687     0.1804      0.15      14     1
# Comp:  2               HeI5876      1.093      0.15      14     1
# Comp:  2          [OIII]5007_d      6.549      0.19      14     1
# Comp:  2            [OI]6300_d      1.302      0.19      14     1
# Comp:  2           [NII]6583_d      11.22      0.19      14     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41        60
#  comp.  1:         9        17
#  comp.  2:        11         2
# chi2/DOF: 1.233; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.163      0.15       9    17
# Comp:  1                 Hbeta      8.083      0.15       9    17
# Comp:  1                Halpha      30.49      0.15       9    17
# Comp:  2             [SII]6716      4.785      0.15      11     2
# Comp:  2             [SII]6731      3.492      0.15      11     2
# Comp:  2              HeII4687    0.09343      0.15      11     2
# Comp:  2               HeI5876      1.097      0.15      11     2
# Comp:  2          [OIII]5007_d      7.230      0.19      11     2
# Comp:  2            [OI]6300_d      1.054      0.19      11     2
# Comp:  2           [NII]6583_d      11.37      0.19      11     2
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9        71
#  comp.  1:         7        13
#  comp.  2:        12         1
# chi2/DOF: 1.207; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.960      0.15       7    13
# Comp:  1                 Hbeta      8.038      0.15       7    13
# Comp:  1                Halpha      31.91      0.15       7    13
# Comp:  2             [SII]6716      4.654      0.15      12     1
# Comp:  2             [SII]6731      3.407      0.15      12     1
# Comp:  2              HeII4687    0.09763      0.15      12     1
# Comp:  2               HeI5876      1.132      0.15      12     1
# Comp:  2          [OIII]5007_d      7.997      0.19      12     1
# Comp:  2            [OI]6300_d      1.619      0.19      12     1
# Comp:  2           [NII]6583_d      11.39      0.19      12     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        87
#  comp.  1:         8        12
#  comp.  2:         9         1
# chi2/DOF: 1.200; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.618      0.15       8    12
# Comp:  1                 Hbeta      9.138      0.15       8    12
# Comp:  1                Halpha      31.96      0.15       8    12
# Comp:  2             [SII]6716      4.471      0.15       9     1
# Comp:  2             [SII]6731      3.660      0.15       9     1
# Comp:  2              HeII4687    0.08695      0.15       9     1
# Comp:  2               HeI5876      1.176      0.15       9     1
# Comp:  2          [OIII]5007_d      7.545      0.19       9     1
# Comp:  2            [OI]6300_d      1.627      0.19       9     1
# Comp:  2           [NII]6583_d      11.29      0.19       9     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         9         1
#  comp.  1:        11         9
#  comp.  2:        11        20
# chi2/DOF: 1.232; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      2.821      0.15      11     9
# Comp:  1                 Hbeta      7.740      0.15      11     9
# Comp:  1                Halpha      30.54      0.15      11     9
# Comp:  2             [SII]6716      4.610      0.15      11    20
# Comp:  2             [SII]6731      3.692      0.15      11    20
# Comp:  2              HeII4687    0.09235      0.15      11    20
# Comp:  2               HeI5876      1.022      0.15      11    20
# Comp:  2          [OIII]5007_d      7.076      0.19      11    20
# Comp:  2            [OI]6300_d      1.115      0.19      11    20
# Comp:  2           [NII]6583_d      11.75      0.19      11    20
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.23661914, 0.7731394 , 0.79469609, 0.21298674, 0.2192919 ,
#        0.04868456, 0.1030437 , 0.48123696, 0.2601423 , 0.30148122])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 2.87109439,  7.99780609, 42.24913654,  6.40605357,  5.10875766,
#         0.11431195,  1.28603827,  7.46192609,  1.62315828, 15.7394637 ])

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_1_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_1_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_1_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_1_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_1_noreg_gas_exp.csv")
print(read2)
# Out:
#            Name      Flux  Error flux
# 0        Hgamma  0.428863    0.035344
# 1         Hbeta  1.194655    0.115486
# 2        Halpha  6.310872    0.118706
# 3     [SII]6716  0.956890    0.031814
# 4     [SII]6731  0.763109    0.032756
# 5      HeII4687  0.017075    0.007272
# 6       HeI5876  0.192099    0.015392
# 7  [OIII]5007_d  1.114609    0.071884
# 8    [OI]6300_d  0.242456    0.038858
# 9   [NII]6583_d  2.351048    0.045033
#           Name      Flux  Error_flux
# 0       Hgamma  0.428863    0.035344
# 1        Hbeta  1.194655    0.115486
# 2       Halpha  6.310872    0.118706
# 3    [SII]6716  0.956890    0.031814
# 4    [SII]6731  0.763109    0.032756
# 5     HeII4687  0.017075    0.007272
# 6      HeI5876  0.192099    0.015392
# 7   [OIII]4959  0.278652    0.071884
# 8   [OIII]5007  0.835957    0.071884
# 9     [OI]6300  0.181842    0.038858
# 10    [OI]6364  0.060614    0.038858
# 11   [NII]6548  0.587762    0.045033
# 12   [NII]6583  1.763286    0.045033

# %%
np.median(flux_rf_rebin)
# Out:
# 0.14937279865768824
