# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_2s_3.txt', unpack = True)
red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/Spectra_extraction/redshift.txt")   
z = red[2][0] 
wv_mask = wv > 4452
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_2s_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
z
# Out:
# 0.03156

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15846873 2.15918609 2.15990345 ... 3.43823917 3.43895653 3.43967389]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3161, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3161, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        82
# chi2/DOF: 0.002394; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/150
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        76
# chi2/DOF: 0.001548; DOF: 1880; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 9/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-6.4248039 , 75.59706351])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        70
#  comp.  1:        -8        10
#  comp.  2:        -7        13
# chi2/DOF: 0.7942; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.615      0.12      -8    10
# Comp:  1                 Hbeta      9.976      0.12      -8    10
# Comp:  1                Halpha      28.93      0.12      -8    10
# Comp:  2             [SII]6716      4.778      0.12      -7    13
# Comp:  2             [SII]6731      3.365      0.12      -7    13
# Comp:  2              HeII4687    0.02268      0.12      -7    13
# Comp:  2               HeI5876     0.8887      0.12      -7    13
# Comp:  2          [OIII]5007_d      3.892      0.15      -7    13
# Comp:  2            [OI]6300_d     0.9352      0.15      -7    13
# Comp:  2           [NII]6583_d      12.80      0.15      -7    13
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  31.18; gas flux:      3 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:   81.7; gas flux:     10 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  236.6; gas flux:     40 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  39.38; gas flux:      7 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  27.73; gas flux:      5 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.1954; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  7.713; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  25.59; gas flux:      4 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  5.945; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  75.99; gas flux:     18 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        79
#  comp.  1:        -8         1
#  comp.  2:        -7        20
# chi2/DOF: 0.7604; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.187      0.12      -8     1
# Comp:  1                 Hbeta      10.05      0.12      -8     1
# Comp:  1                Halpha      29.29      0.12      -8     1
# Comp:  2             [SII]6716      4.578      0.12      -7    20
# Comp:  2             [SII]6731      3.437      0.12      -7    20
# Comp:  2              HeII4687    0.01305      0.12      -7    20
# Comp:  2               HeI5876      1.056      0.12      -7    20
# Comp:  2          [OIII]5007_d      3.793      0.16      -7    20
# Comp:  2            [OI]6300_d      1.059      0.16      -7    20
# Comp:  2           [NII]6583_d      13.09      0.16      -7    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        63
#  comp.  1:       -10        17
#  comp.  2:        -6        18
# chi2/DOF: 0.7290; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.930      0.12     -10    17
# Comp:  1                 Hbeta      9.024      0.12     -10    17
# Comp:  1                Halpha      29.86      0.12     -10    17
# Comp:  2             [SII]6716      4.828      0.12      -6    18
# Comp:  2             [SII]6731      3.455      0.12      -6    18
# Comp:  2              HeII4687    0.06978      0.12      -6    18
# Comp:  2               HeI5876     0.8315      0.12      -6    18
# Comp:  2          [OIII]5007_d      3.967      0.15      -6    18
# Comp:  2            [OI]6300_d     0.8953      0.15      -6    18
# Comp:  2           [NII]6583_d      13.17      0.15      -6    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47        80
#  comp.  1:        -8         9
#  comp.  2:        -7        13
# chi2/DOF: 0.7312; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.498      0.12      -8     9
# Comp:  1                 Hbeta      11.31      0.12      -8     9
# Comp:  1                Halpha      29.15      0.12      -8     9
# Comp:  2             [SII]6716      4.643      0.12      -7    13
# Comp:  2             [SII]6731      3.250      0.12      -7    13
# Comp:  2              HeII4687      0.000      0.12      -7    13
# Comp:  2               HeI5876      1.039      0.12      -7    13
# Comp:  2          [OIII]5007_d      3.805      0.15      -7    13
# Comp:  2            [OI]6300_d     0.9486      0.15      -7    13
# Comp:  2           [NII]6583_d      12.65      0.15      -7    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        51
#  comp.  1:        -8        13
#  comp.  2:        -8         1
# chi2/DOF: 0.7793; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.330      0.12      -8    13
# Comp:  1                 Hbeta      10.05      0.12      -8    13
# Comp:  1                Halpha      29.02      0.12      -8    13
# Comp:  2             [SII]6716      4.750      0.12      -8     1
# Comp:  2             [SII]6731      3.410      0.12      -8     1
# Comp:  2              HeII4687    0.08313      0.12      -8     1
# Comp:  2               HeI5876      1.024      0.12      -8     1
# Comp:  2          [OIII]5007_d      3.615      0.15      -8     1
# Comp:  2            [OI]6300_d     0.8866      0.15      -8     1
# Comp:  2           [NII]6583_d      12.47      0.15      -8     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        78
#  comp.  1:        -7         1
#  comp.  2:        -6        19
# chi2/DOF: 0.7333; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.537      0.12      -7     1
# Comp:  1                 Hbeta      8.818      0.12      -7     1
# Comp:  1                Halpha      28.62      0.12      -7     1
# Comp:  2             [SII]6716      5.065      0.12      -6    19
# Comp:  2             [SII]6731      3.652      0.12      -6    19
# Comp:  2              HeII4687   0.006542      0.12      -6    19
# Comp:  2               HeI5876      1.171      0.12      -6    19
# Comp:  2          [OIII]5007_d      4.077      0.16      -6    19
# Comp:  2            [OI]6300_d      1.078      0.16      -6    19
# Comp:  2           [NII]6583_d      12.82      0.16      -6    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        79
#  comp.  1:        -8         1
#  comp.  2:        -6        21
# chi2/DOF: 0.7144; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.775      0.12      -8     1
# Comp:  1                 Hbeta      9.297      0.12      -8     1
# Comp:  1                Halpha      28.47      0.12      -8     1
# Comp:  2             [SII]6716      5.336      0.12      -6    21
# Comp:  2             [SII]6731      3.663      0.12      -6    21
# Comp:  2              HeII4687   0.003423      0.12      -6    21
# Comp:  2               HeI5876     0.9916      0.12      -6    21
# Comp:  2          [OIII]5007_d      4.086      0.16      -6    21
# Comp:  2            [OI]6300_d     0.8966      0.16      -6    21
# Comp:  2           [NII]6583_d      13.13      0.16      -6    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        67
#  comp.  1:        -5         1
#  comp.  2:        -6         1
# chi2/DOF: 0.7210; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.486      0.12      -5     1
# Comp:  1                 Hbeta      10.80      0.12      -5     1
# Comp:  1                Halpha      28.66      0.12      -5     1
# Comp:  2             [SII]6716      4.622      0.12      -6     1
# Comp:  2             [SII]6731      3.200      0.12      -6     1
# Comp:  2              HeII4687      0.000      0.12      -6     1
# Comp:  2               HeI5876     0.8493      0.12      -6     1
# Comp:  2          [OIII]5007_d      3.730      0.15      -6     1
# Comp:  2            [OI]6300_d     0.9052      0.15      -6     1
# Comp:  2           [NII]6583_d      12.38      0.15      -6     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        71
#  comp.  1:        -5         4
#  comp.  2:        -5         6
# chi2/DOF: 0.7194; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.410      0.12      -5     4
# Comp:  1                 Hbeta      10.42      0.12      -5     4
# Comp:  1                Halpha      28.58      0.12      -5     4
# Comp:  2             [SII]6716      4.494      0.12      -5     6
# Comp:  2             [SII]6731      3.155      0.12      -5     6
# Comp:  2              HeII4687    0.03312      0.12      -5     6
# Comp:  2               HeI5876      1.030      0.12      -5     6
# Comp:  2          [OIII]5007_d      3.856      0.15      -5     6
# Comp:  2            [OI]6300_d     0.8257      0.15      -5     6
# Comp:  2           [NII]6583_d      12.52      0.15      -5     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        10        62
#  comp.  1:        -9        18
#  comp.  2:        -5        16
# chi2/DOF: 0.7281; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.696      0.12      -9    18
# Comp:  1                 Hbeta      9.264      0.12      -9    18
# Comp:  1                Halpha      28.89      0.12      -9    18
# Comp:  2             [SII]6716      4.699      0.12      -5    16
# Comp:  2             [SII]6731      3.357      0.12      -5    16
# Comp:  2              HeII4687    0.06531      0.12      -5    16
# Comp:  2               HeI5876     0.9868      0.12      -5    16
# Comp:  2          [OIII]5007_d      4.242      0.15      -5    16
# Comp:  2            [OI]6300_d      1.049      0.15      -5    16
# Comp:  2           [NII]6583_d      12.98      0.15      -5    16
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        93
#  comp.  1:        -9         1
#  comp.  2:        -7        15
# chi2/DOF: 0.7304; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.292      0.12      -9     1
# Comp:  1                 Hbeta      8.896      0.12      -9     1
# Comp:  1                Halpha      28.86      0.12      -9     1
# Comp:  2             [SII]6716      5.263      0.12      -7    15
# Comp:  2             [SII]6731      3.534      0.12      -7    15
# Comp:  2              HeII4687      0.000      0.12      -7    15
# Comp:  2               HeI5876      1.170      0.12      -7    15
# Comp:  2          [OIII]5007_d      3.977      0.15      -7    15
# Comp:  2            [OI]6300_d     0.8830      0.15      -7    15
# Comp:  2           [NII]6583_d      13.02      0.15      -7    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        77
#  comp.  1:        -8         1
#  comp.  2:        -5        12
# chi2/DOF: 0.7401; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.413      0.12      -8     1
# Comp:  1                 Hbeta      9.360      0.12      -8     1
# Comp:  1                Halpha      29.32      0.12      -8     1
# Comp:  2             [SII]6716      4.881      0.12      -5    12
# Comp:  2             [SII]6731      3.242      0.12      -5    12
# Comp:  2              HeII4687    0.04336      0.12      -5    12
# Comp:  2               HeI5876     0.8517      0.12      -5    12
# Comp:  2          [OIII]5007_d      3.926      0.15      -5    12
# Comp:  2            [OI]6300_d     0.9531      0.15      -5    12
# Comp:  2           [NII]6583_d      12.85      0.15      -5    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        68
#  comp.  1:        -8        15
#  comp.  2:        -7         2
# chi2/DOF: 0.7468; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.176      0.12      -8    15
# Comp:  1                 Hbeta      10.92      0.12      -8    15
# Comp:  1                Halpha      29.74      0.12      -8    15
# Comp:  2             [SII]6716      4.348      0.12      -7     2
# Comp:  2             [SII]6731      3.224      0.12      -7     2
# Comp:  2              HeII4687      0.000      0.12      -7     2
# Comp:  2               HeI5876     0.8895      0.12      -7     2
# Comp:  2          [OIII]5007_d      3.866      0.15      -7     2
# Comp:  2            [OI]6300_d     0.8649      0.15      -7     2
# Comp:  2           [NII]6583_d      12.38      0.15      -7     2
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        71
#  comp.  1:        -6         1
#  comp.  2:        -9        15
# chi2/DOF: 0.7596; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.833      0.12      -6     1
# Comp:  1                 Hbeta      10.48      0.12      -6     1
# Comp:  1                Halpha      28.80      0.12      -6     1
# Comp:  2             [SII]6716      4.895      0.12      -9    15
# Comp:  2             [SII]6731      3.272      0.12      -9    15
# Comp:  2              HeII4687    0.04142      0.12      -9    15
# Comp:  2               HeI5876     0.7711      0.12      -9    15
# Comp:  2          [OIII]5007_d      4.160      0.15      -9    15
# Comp:  2            [OI]6300_d     0.9265      0.15      -9    15
# Comp:  2           [NII]6583_d      12.92      0.15      -9    15
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        54
#  comp.  1:        -7        21
#  comp.  2:        -5        21
# chi2/DOF: 0.7365; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.983      0.12      -7    21
# Comp:  1                 Hbeta      11.14      0.12      -7    21
# Comp:  1                Halpha      29.18      0.12      -7    21
# Comp:  2             [SII]6716      4.454      0.12      -5    21
# Comp:  2             [SII]6731      3.430      0.12      -5    21
# Comp:  2              HeII4687      0.000      0.12      -5    21
# Comp:  2               HeI5876      1.022      0.12      -5    21
# Comp:  2          [OIII]5007_d      3.988      0.16      -5    21
# Comp:  2            [OI]6300_d      1.056      0.16      -5    21
# Comp:  2           [NII]6583_d      12.88      0.16      -5    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        73
#  comp.  1:        -7         1
#  comp.  2:        -7         1
# chi2/DOF: 0.7585; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.615      0.12      -7     1
# Comp:  1                 Hbeta      9.939      0.12      -7     1
# Comp:  1                Halpha      28.21      0.12      -7     1
# Comp:  2             [SII]6716      4.241      0.12      -7     1
# Comp:  2             [SII]6731      3.068      0.12      -7     1
# Comp:  2              HeII4687      0.000      0.12      -7     1
# Comp:  2               HeI5876     0.7655      0.12      -7     1
# Comp:  2          [OIII]5007_d      3.631      0.15      -7     1
# Comp:  2            [OI]6300_d     0.8682      0.15      -7     1
# Comp:  2           [NII]6583_d      12.42      0.15      -7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        99
#  comp.  1:        -8         1
#  comp.  2:        -6         1
# chi2/DOF: 0.7481; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.259      0.12      -8     1
# Comp:  1                 Hbeta      10.62      0.12      -8     1
# Comp:  1                Halpha      29.02      0.12      -8     1
# Comp:  2             [SII]6716      4.990      0.12      -6     1
# Comp:  2             [SII]6731      3.215      0.12      -6     1
# Comp:  2              HeII4687    0.03425      0.12      -6     1
# Comp:  2               HeI5876     0.7585      0.12      -6     1
# Comp:  2          [OIII]5007_d      3.735      0.15      -6     1
# Comp:  2            [OI]6300_d     0.9382      0.15      -6     1
# Comp:  2           [NII]6583_d      12.61      0.15      -6     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        86
#  comp.  1:        -7         1
#  comp.  2:        -9         7
# chi2/DOF: 0.7333; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.484      0.12      -7     1
# Comp:  1                 Hbeta      11.06      0.12      -7     1
# Comp:  1                Halpha      29.50      0.12      -7     1
# Comp:  2             [SII]6716      5.002      0.12      -9     7
# Comp:  2             [SII]6731      3.375      0.12      -9     7
# Comp:  2              HeII4687    0.05095      0.12      -9     7
# Comp:  2               HeI5876      1.064      0.12      -9     7
# Comp:  2          [OIII]5007_d      3.963      0.15      -9     7
# Comp:  2            [OI]6300_d     0.8740      0.15      -9     7
# Comp:  2           [NII]6583_d      12.75      0.15      -9     7
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        64
#  comp.  1:        -7         6
#  comp.  2:        -7        19
# chi2/DOF: 0.7515; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.155      0.12      -7     6
# Comp:  1                 Hbeta      9.634      0.12      -7     6
# Comp:  1                Halpha      29.40      0.12      -7     6
# Comp:  2             [SII]6716      4.888      0.12      -7    19
# Comp:  2             [SII]6731      3.318      0.12      -7    19
# Comp:  2              HeII4687      0.000      0.12      -7    19
# Comp:  2               HeI5876      1.047      0.12      -7    19
# Comp:  2          [OIII]5007_d      4.283      0.16      -7    19
# Comp:  2            [OI]6300_d     0.9069      0.16      -7    19
# Comp:  2           [NII]6583_d      12.78      0.16      -7    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        91
#  comp.  1:        -8        22
#  comp.  2:        -8        11
# chi2/DOF: 0.7570; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.503      0.12      -8    22
# Comp:  1                 Hbeta      9.947      0.12      -8    22
# Comp:  1                Halpha      29.71      0.12      -8    22
# Comp:  2             [SII]6716      5.026      0.12      -8    11
# Comp:  2             [SII]6731      3.367      0.12      -8    11
# Comp:  2              HeII4687    0.01705      0.12      -8    11
# Comp:  2               HeI5876     0.7834      0.12      -8    11
# Comp:  2          [OIII]5007_d      3.933      0.15      -8    11
# Comp:  2            [OI]6300_d     0.9392      0.15      -8    11
# Comp:  2           [NII]6583_d      12.82      0.15      -8    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        69
#  comp.  1:        -8         1
#  comp.  2:        -7        17
# chi2/DOF: 0.7631; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.821      0.12      -8     1
# Comp:  1                 Hbeta      10.47      0.12      -8     1
# Comp:  1                Halpha      29.41      0.12      -8     1
# Comp:  2             [SII]6716      5.046      0.12      -7    17
# Comp:  2             [SII]6731      3.492      0.12      -7    17
# Comp:  2              HeII4687   0.005931      0.12      -7    17
# Comp:  2               HeI5876     0.7522      0.12      -7    17
# Comp:  2          [OIII]5007_d      3.678      0.15      -7    17
# Comp:  2            [OI]6300_d     0.9384      0.15      -7    17
# Comp:  2           [NII]6583_d      13.14      0.15      -7    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        88
#  comp.  1:        -9         1
#  comp.  2:        -5         4
# chi2/DOF: 0.7615; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.647      0.12      -9     1
# Comp:  1                 Hbeta      10.32      0.12      -9     1
# Comp:  1                Halpha      29.12      0.12      -9     1
# Comp:  2             [SII]6716      4.508      0.12      -5     4
# Comp:  2             [SII]6731      3.349      0.12      -5     4
# Comp:  2              HeII4687    0.02219      0.12      -5     4
# Comp:  2               HeI5876     0.8962      0.12      -5     4
# Comp:  2          [OIII]5007_d      4.185      0.15      -5     4
# Comp:  2            [OI]6300_d     0.9510      0.15      -5     4
# Comp:  2           [NII]6583_d      12.85      0.15      -5     4
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        74
#  comp.  1:        -8         1
#  comp.  2:        -5        13
# chi2/DOF: 0.7312; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.400      0.12      -8     1
# Comp:  1                 Hbeta      9.363      0.12      -8     1
# Comp:  1                Halpha      29.44      0.12      -8     1
# Comp:  2             [SII]6716      4.534      0.12      -5    13
# Comp:  2             [SII]6731      3.605      0.12      -5    13
# Comp:  2              HeII4687    0.06680      0.12      -5    13
# Comp:  2               HeI5876     0.6214      0.12      -5    13
# Comp:  2          [OIII]5007_d      4.109      0.15      -5    13
# Comp:  2            [OI]6300_d     0.9113      0.15      -5    13
# Comp:  2           [NII]6583_d      12.98      0.15      -5    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        56
#  comp.  1:        -9        15
#  comp.  2:        -5        21
# chi2/DOF: 0.7556; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.609      0.12      -9    15
# Comp:  1                 Hbeta      10.21      0.12      -9    15
# Comp:  1                Halpha      29.79      0.12      -9    15
# Comp:  2             [SII]6716      4.507      0.12      -5    21
# Comp:  2             [SII]6731      3.417      0.12      -5    21
# Comp:  2              HeII4687      0.000      0.12      -5    21
# Comp:  2               HeI5876      1.133      0.12      -5    21
# Comp:  2          [OIII]5007_d      4.369      0.16      -5    21
# Comp:  2            [OI]6300_d      1.041      0.16      -5    21
# Comp:  2           [NII]6583_d      12.78      0.16      -5    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -36        88
#  comp.  1:        -6        10
#  comp.  2:        -4        17
# chi2/DOF: 0.7415; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.796      0.12      -6    10
# Comp:  1                 Hbeta      10.69      0.12      -6    10
# Comp:  1                Halpha      29.00      0.12      -6    10
# Comp:  2             [SII]6716      4.823      0.12      -4    17
# Comp:  2             [SII]6731      3.260      0.12      -4    17
# Comp:  2              HeII4687    0.02667      0.12      -4    17
# Comp:  2               HeI5876      1.012      0.12      -4    17
# Comp:  2          [OIII]5007_d      4.047      0.15      -4    17
# Comp:  2            [OI]6300_d     0.8779      0.15      -4    17
# Comp:  2           [NII]6583_d      12.89      0.15      -4    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        88
#  comp.  1:        -8         1
#  comp.  2:        -7        22
# chi2/DOF: 0.7325; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.086      0.12      -8     1
# Comp:  1                 Hbeta      9.097      0.12      -8     1
# Comp:  1                Halpha      29.27      0.12      -8     1
# Comp:  2             [SII]6716      4.682      0.12      -7    22
# Comp:  2             [SII]6731      3.558      0.12      -7    22
# Comp:  2              HeII4687    0.04374      0.12      -7    22
# Comp:  2               HeI5876     0.8182      0.12      -7    22
# Comp:  2          [OIII]5007_d      3.819      0.16      -7    22
# Comp:  2            [OI]6300_d     0.9904      0.16      -7    22
# Comp:  2           [NII]6583_d      13.21      0.16      -7    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        65
#  comp.  1:        -8        25
#  comp.  2:       -10         1
# chi2/DOF: 0.7263; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.378      0.12      -8    25
# Comp:  1                 Hbeta      9.976      0.12      -8    25
# Comp:  1                Halpha      29.92      0.12      -8    25
# Comp:  2             [SII]6716      5.100      0.12     -10     1
# Comp:  2             [SII]6731      3.427      0.12     -10     1
# Comp:  2              HeII4687    0.08213      0.12     -10     1
# Comp:  2               HeI5876     0.7515      0.12     -10     1
# Comp:  2          [OIII]5007_d      3.954      0.15     -10     1
# Comp:  2            [OI]6300_d     0.9325      0.15     -10     1
# Comp:  2           [NII]6583_d      12.65      0.15     -10     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -34        79
#  comp.  1:        -7         1
#  comp.  2:        -4        17
# chi2/DOF: 0.7268; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.337      0.12      -7     1
# Comp:  1                 Hbeta      11.12      0.12      -7     1
# Comp:  1                Halpha      28.78      0.12      -7     1
# Comp:  2             [SII]6716      4.711      0.12      -4    17
# Comp:  2             [SII]6731      3.407      0.12      -4    17
# Comp:  2              HeII4687    0.07973      0.12      -4    17
# Comp:  2               HeI5876     0.7558      0.12      -4    17
# Comp:  2          [OIII]5007_d      4.042      0.15      -4    17
# Comp:  2            [OI]6300_d      1.016      0.15      -4    17
# Comp:  2           [NII]6583_d      13.09      0.15      -4    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        62
#  comp.  1:        -7        12
#  comp.  2:        -5        14
# chi2/DOF: 0.7611; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.572      0.12      -7    12
# Comp:  1                 Hbeta      10.05      0.12      -7    12
# Comp:  1                Halpha      28.46      0.12      -7    12
# Comp:  2             [SII]6716      5.259      0.12      -5    14
# Comp:  2             [SII]6731      3.099      0.12      -5    14
# Comp:  2              HeII4687    0.02818      0.12      -5    14
# Comp:  2               HeI5876     0.8967      0.12      -5    14
# Comp:  2          [OIII]5007_d      3.818      0.15      -5    14
# Comp:  2            [OI]6300_d     0.8614      0.15      -5    14
# Comp:  2           [NII]6583_d      12.83      0.15      -5    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        44
#  comp.  1:        -8        19
#  comp.  2:        -5        19
# chi2/DOF: 0.7272; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.796      0.12      -8    19
# Comp:  1                 Hbeta      11.41      0.12      -8    19
# Comp:  1                Halpha      29.01      0.12      -8    19
# Comp:  2             [SII]6716      4.729      0.12      -5    19
# Comp:  2             [SII]6731      3.477      0.12      -5    19
# Comp:  2              HeII4687    0.07577      0.12      -5    19
# Comp:  2               HeI5876     0.8379      0.12      -5    19
# Comp:  2          [OIII]5007_d      4.099      0.15      -5    19
# Comp:  2            [OI]6300_d     0.8672      0.15      -5    19
# Comp:  2           [NII]6583_d      12.98      0.15      -5    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        66
#  comp.  1:       -10        10
#  comp.  2:        -7        22
# chi2/DOF: 0.7688; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.152      0.12     -10    10
# Comp:  1                 Hbeta      10.25      0.12     -10    10
# Comp:  1                Halpha      29.10      0.12     -10    10
# Comp:  2             [SII]6716      5.097      0.12      -7    22
# Comp:  2             [SII]6731      3.504      0.12      -7    22
# Comp:  2              HeII4687    0.01335      0.12      -7    22
# Comp:  2               HeI5876     0.7734      0.12      -7    22
# Comp:  2          [OIII]5007_d      4.072      0.16      -7    22
# Comp:  2            [OI]6300_d     0.9626      0.16      -7    22
# Comp:  2           [NII]6583_d      13.14      0.16      -7    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        60
#  comp.  1:        -6        10
#  comp.  2:        -4        17
# chi2/DOF: 0.7683; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.511      0.12      -6    10
# Comp:  1                 Hbeta      9.509      0.12      -6    10
# Comp:  1                Halpha      28.83      0.12      -6    10
# Comp:  2             [SII]6716      4.767      0.12      -4    17
# Comp:  2             [SII]6731      3.230      0.12      -4    17
# Comp:  2              HeII4687    0.02282      0.12      -4    17
# Comp:  2               HeI5876     0.7760      0.12      -4    17
# Comp:  2          [OIII]5007_d      3.990      0.15      -4    17
# Comp:  2            [OI]6300_d     0.8951      0.15      -4    17
# Comp:  2           [NII]6583_d      12.82      0.15      -4    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        61
#  comp.  1:       -10        19
#  comp.  2:        -8         6
# chi2/DOF: 0.7199; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.477      0.12     -10    19
# Comp:  1                 Hbeta      9.050      0.12     -10    19
# Comp:  1                Halpha      29.01      0.12     -10    19
# Comp:  2             [SII]6716      4.946      0.12      -8     6
# Comp:  2             [SII]6731      3.309      0.12      -8     6
# Comp:  2              HeII4687    0.06594      0.12      -8     6
# Comp:  2               HeI5876     0.8478      0.12      -8     6
# Comp:  2          [OIII]5007_d      4.127      0.15      -8     6
# Comp:  2            [OI]6300_d     0.9767      0.15      -8     6
# Comp:  2           [NII]6583_d      12.57      0.15      -8     6
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        69
#  comp.  1:        -8         4
#  comp.  2:        -5        13
# chi2/DOF: 0.7309; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.440      0.12      -8     4
# Comp:  1                 Hbeta      11.17      0.12      -8     4
# Comp:  1                Halpha      28.96      0.12      -8     4
# Comp:  2             [SII]6716      5.161      0.12      -5    13
# Comp:  2             [SII]6731      3.408      0.12      -5    13
# Comp:  2              HeII4687    0.03958      0.12      -5    13
# Comp:  2               HeI5876     0.8886      0.12      -5    13
# Comp:  2          [OIII]5007_d      3.559      0.15      -5    13
# Comp:  2            [OI]6300_d     0.9223      0.15      -5    13
# Comp:  2           [NII]6583_d      12.71      0.15      -5    13
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -29        97
#  comp.  1:        -6         6
#  comp.  2:        -7        19
# chi2/DOF: 0.7215; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.457      0.12      -6     6
# Comp:  1                 Hbeta      11.08      0.12      -6     6
# Comp:  1                Halpha      28.39      0.12      -6     6
# Comp:  2             [SII]6716      4.762      0.12      -7    19
# Comp:  2             [SII]6731      3.673      0.12      -7    19
# Comp:  2              HeII4687    0.04439      0.12      -7    19
# Comp:  2               HeI5876     0.9706      0.12      -7    19
# Comp:  2          [OIII]5007_d      3.814      0.16      -7    19
# Comp:  2            [OI]6300_d     0.9003      0.16      -7    19
# Comp:  2           [NII]6583_d      12.78      0.16      -7    19
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2        82
#  comp.  1:        -8         1
#  comp.  2:        -5        12
# chi2/DOF: 0.7304; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.982      0.12      -8     1
# Comp:  1                 Hbeta      9.227      0.12      -8     1
# Comp:  1                Halpha      28.32      0.12      -8     1
# Comp:  2             [SII]6716      4.677      0.12      -5    12
# Comp:  2             [SII]6731      3.226      0.12      -5    12
# Comp:  2              HeII4687      0.000      0.12      -5    12
# Comp:  2               HeI5876     0.7830      0.12      -5    12
# Comp:  2          [OIII]5007_d      3.917      0.15      -5    12
# Comp:  2            [OI]6300_d     0.8910      0.15      -5    12
# Comp:  2           [NII]6583_d      12.53      0.15      -5    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19        78
#  comp.  1:        -6         7
#  comp.  2:        -5        17
# chi2/DOF: 0.7344; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.650      0.12      -6     7
# Comp:  1                 Hbeta      11.14      0.12      -6     7
# Comp:  1                Halpha      29.03      0.12      -6     7
# Comp:  2             [SII]6716      4.735      0.12      -5    17
# Comp:  2             [SII]6731      3.429      0.12      -5    17
# Comp:  2              HeII4687    0.06917      0.12      -5    17
# Comp:  2               HeI5876      1.065      0.12      -5    17
# Comp:  2          [OIII]5007_d      3.910      0.15      -5    17
# Comp:  2            [OI]6300_d      1.039      0.15      -5    17
# Comp:  2           [NII]6583_d      12.77      0.15      -5    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4        75
#  comp.  1:        -7        17
#  comp.  2:        -7         1
# chi2/DOF: 0.7363; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.680      0.12      -7    17
# Comp:  1                 Hbeta      11.15      0.12      -7    17
# Comp:  1                Halpha      29.17      0.12      -7    17
# Comp:  2             [SII]6716      4.734      0.12      -7     1
# Comp:  2             [SII]6731      3.151      0.12      -7     1
# Comp:  2              HeII4687    0.01648      0.12      -7     1
# Comp:  2               HeI5876     0.7607      0.12      -7     1
# Comp:  2          [OIII]5007_d      3.910      0.15      -7     1
# Comp:  2            [OI]6300_d     0.8933      0.15      -7     1
# Comp:  2           [NII]6583_d      12.49      0.15      -7     1
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        72
#  comp.  1:        -8        22
#  comp.  2:        -6        17
# chi2/DOF: 0.7502; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.682      0.12      -8    22
# Comp:  1                 Hbeta      10.03      0.12      -8    22
# Comp:  1                Halpha      29.63      0.12      -8    22
# Comp:  2             [SII]6716      5.196      0.12      -6    17
# Comp:  2             [SII]6731      3.497      0.12      -6    17
# Comp:  2              HeII4687      0.000      0.12      -6    17
# Comp:  2               HeI5876     0.8311      0.12      -6    17
# Comp:  2          [OIII]5007_d      3.819      0.15      -6    17
# Comp:  2            [OI]6300_d     0.9179      0.15      -6    17
# Comp:  2           [NII]6583_d      12.95      0.15      -6    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        58
#  comp.  1:        -7        19
#  comp.  2:        -6        18
# chi2/DOF: 0.7681; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.650      0.12      -7    19
# Comp:  1                 Hbeta      10.32      0.12      -7    19
# Comp:  1                Halpha      29.43      0.12      -7    19
# Comp:  2             [SII]6716      4.757      0.12      -6    18
# Comp:  2             [SII]6731      3.164      0.12      -6    18
# Comp:  2              HeII4687    0.01684      0.12      -6    18
# Comp:  2               HeI5876     0.6344      0.12      -6    18
# Comp:  2          [OIII]5007_d      4.073      0.15      -6    18
# Comp:  2            [OI]6300_d     0.9808      0.15      -6    18
# Comp:  2           [NII]6583_d      12.76      0.15      -6    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        57
#  comp.  1:        -9        21
#  comp.  2:        -8        16
# chi2/DOF: 0.7191; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# Comp:  2           [NII]6583_d      13.06      0.16      -7    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2       104
#  comp.  1:        -8         1
#  comp.  2:        -6        11
# chi2/DOF: 0.7326; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.366      0.12      -8     1
# Comp:  1                 Hbeta      10.62      0.12      -8     1
# Comp:  1                Halpha      29.51      0.12      -8     1
# Comp:  2             [SII]6716      5.078      0.12      -6    11
# Comp:  2             [SII]6731      3.290      0.12      -6    11
# Comp:  2              HeII4687      0.000      0.12      -6    11
# Comp:  2               HeI5876     0.7485      0.12      -6    11
# Comp:  2          [OIII]5007_d      3.612      0.15      -6    11
# Comp:  2            [OI]6300_d     0.9176      0.15      -6    11
# Comp:  2           [NII]6583_d      12.63      0.15      -6    11
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28         1
#  comp.  1:        -8        17
#  comp.  2:        -6        20
# chi2/DOF: 0.7325; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.242      0.12      -8    17
# Comp:  1                 Hbeta      11.09      0.12      -8    17
# Comp:  1                Halpha      29.27      0.12      -8    17
# Comp:  2             [SII]6716      4.579      0.12      -6    20
# Comp:  2             [SII]6731      3.504      0.12      -6    20
# Comp:  2              HeII4687    0.08839      0.12      -6    20
# Comp:  2               HeI5876     0.7539      0.12      -6    20
# Comp:  2          [OIII]5007_d      3.809      0.16      -6    20
# Comp:  2            [OI]6300_d     0.9488      0.16      -6    20
# Comp:  2           [NII]6583_d      12.76      0.16      -6    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        91
#  comp.  1:        -7         1
#  comp.  2:        -7        12
# chi2/DOF: 0.7456; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.001      0.12      -7     1
# Comp:  1                 Hbeta      10.79      0.12      -7     1
# Comp:  1                Halpha      28.84      0.12      -7     1
# Comp:  2             [SII]6716      4.493      0.12      -7    12
# Comp:  2             [SII]6731      3.240      0.12      -7    12
# Comp:  2              HeII4687      0.000      0.12      -7    12
# Comp:  2               HeI5876     0.9873      0.12      -7    12
# Comp:  2          [OIII]5007_d      3.883      0.15      -7    12
# Comp:  2            [OI]6300_d     0.8824      0.15      -7    12
# Comp:  2           [NII]6583_d      12.69      0.15      -7    12
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9        52
#  comp.  1:        -9         9
#  comp.  2:        -6        14
# chi2/DOF: 0.7366; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.329      0.12      -9     9
# Comp:  1                 Hbeta      9.314      0.12      -9     9
# Comp:  1                Halpha      29.37      0.12      -9     9
# Comp:  2             [SII]6716      5.234      0.12      -6    14
# Comp:  2             [SII]6731      3.390      0.12      -6    14
# Comp:  2              HeII4687    0.07143      0.12      -6    14
# Comp:  2               HeI5876     0.7688      0.12      -6    14
# Comp:  2          [OIII]5007_d      3.992      0.15      -6    14
# Comp:  2            [OI]6300_d      1.009      0.15      -6    14
# Comp:  2           [NII]6583_d      12.84      0.15      -6    14
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11        69
#  comp.  1:        -8        13
#  comp.  2:        -7        10
# chi2/DOF: 0.7358; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.222      0.12      -8    13
# Comp:  1                 Hbeta      11.18      0.12      -8    13
# Comp:  1                Halpha      29.45      0.12      -8    13
# Comp:  2             [SII]6716      4.775      0.12      -7    10
# Comp:  2             [SII]6731      3.300      0.12      -7    10
# Comp:  2              HeII4687    0.03556      0.12      -7    10
# Comp:  2               HeI5876     0.8625      0.12      -7    10
# Comp:  2          [OIII]5007_d      3.798      0.15      -7    10
# Comp:  2            [OI]6300_d     0.9843      0.15      -7    10
# Comp:  2           [NII]6583_d      12.85      0.15      -7    10
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2        84
#  comp.  1:        -9         1
#  comp.  2:        -7        18
# chi2/DOF: 0.7217; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.455      0.12      -9     1
# Comp:  1                 Hbeta      9.184      0.12      -9     1
# Comp:  1                Halpha      29.41      0.12      -9     1
# Comp:  2             [SII]6716      5.043      0.12      -7    18
# Comp:  2             [SII]6731      3.512      0.12      -7    18
# Comp:  2              HeII4687    0.02668      0.12      -7    18
# Comp:  2               HeI5876      1.019      0.12      -7    18
# Comp:  2          [OIII]5007_d      3.989      0.15      -7    18
# Comp:  2            [OI]6300_d     0.9701      0.15      -7    18
# Comp:  2           [NII]6583_d      12.79      0.15      -7    18
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        87
#  comp.  1:        -8        22
#  comp.  2:        -7        21
# chi2/DOF: 0.7462; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.009      0.12      -8    22
# Comp:  1                 Hbeta      10.05      0.12      -8    22
# Comp:  1                Halpha      29.12      0.12      -8    22
# Comp:  2             [SII]6716      4.752      0.12      -7    21
# Comp:  2             [SII]6731      3.382      0.12      -7    21
# Comp:  2              HeII4687      0.000      0.12      -7    21
# Comp:  2               HeI5876      1.041      0.12      -7    21
# Comp:  2          [OIII]5007_d      3.879      0.16      -7    21
# Comp:  2            [OI]6300_d      1.027      0.16      -7    21
# Comp:  2           [NII]6583_d      12.97      0.16      -7    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        70
#  comp.  1:        -5         2
#  comp.  2:        -8         8
# chi2/DOF: 0.7346; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.335      0.12      -5     2
# Comp:  1                 Hbeta      10.70      0.12      -5     2
# Comp:  1                Halpha      28.66      0.12      -5     2
# Comp:  2             [SII]6716      4.747      0.12      -8     8
# Comp:  2             [SII]6731      3.328      0.12      -8     8
# Comp:  2              HeII4687    0.04620      0.12      -8     8
# Comp:  2               HeI5876      1.001      0.12      -8     8
# Comp:  2          [OIII]5007_d      3.671      0.15      -8     8
# Comp:  2            [OI]6300_d     0.9685      0.15      -8     8
# Comp:  2           [NII]6583_d      12.41      0.15      -8     8
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14        65
#  comp.  1:        -8         1
#  comp.  2:        -7        21
# chi2/DOF: 0.7289; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.305      0.12      -8     1
# Comp:  1                 Hbeta      8.999      0.12      -8     1
# Comp:  1                Halpha      28.79      0.12      -8     1
# Comp:  2             [SII]6716      5.107      0.12      -7    21
# Comp:  2             [SII]6731      3.483      0.12      -7    21
# Comp:  2              HeII4687      0.000      0.12      -7    21
# Comp:  2               HeI5876     0.7617      0.12      -7    21
# Comp:  2          [OIII]5007_d      4.073      0.16      -7    21
# Comp:  2            [OI]6300_d     0.9259      0.16      -7    21
# Comp:  2           [NII]6583_d      13.32      0.16      -7    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -30        64
#  comp.  1:        -8        16
#  comp.  2:        -5        17
# chi2/DOF: 0.7529; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.701      0.12      -8    16
# Comp:  1                 Hbeta      11.08      0.12      -8    16
# Comp:  1                Halpha      29.25      0.12      -8    16
# Comp:  2             [SII]6716      4.742      0.12      -5    17
# Comp:  2             [SII]6731      3.400      0.12      -5    17
# Comp:  2              HeII4687   0.004140      0.12      -5    17
# Comp:  2               HeI5876     0.8207      0.12      -5    17
# Comp:  2          [OIII]5007_d      4.080      0.15      -5    17
# Comp:  2            [OI]6300_d     0.9319      0.15      -5    17
# Comp:  2           [NII]6583_d      13.13      0.15      -5    17
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        55
#  comp.  1:        -8         1
#  comp.  2:        -7         5
# chi2/DOF: 0.7334; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.353      0.12      -8     1
# Comp:  1                 Hbeta      9.246      0.12      -8     1
# Comp:  1                Halpha      28.29      0.12      -8     1
# Comp:  2             [SII]6716      5.209      0.12      -7     5
# Comp:  2             [SII]6731      3.394      0.12      -7     5
# Comp:  2              HeII4687     0.1048      0.12      -7     5
# Comp:  2               HeI5876     0.6527      0.12      -7     5
# Comp:  2          [OIII]5007_d      3.799      0.15      -7     5
# Comp:  2            [OI]6300_d     0.8037      0.15      -7     5
# Comp:  2           [NII]6583_d      12.40      0.15      -7     5
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        48
#  comp.  1:        -8        21
#  comp.  2:        -6        20
# chi2/DOF: 0.7463; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.363      0.12      -8    21
# Comp:  1                 Hbeta      9.713      0.12      -8    21
# Comp:  1                Halpha      30.09      0.12      -8    21
# Comp:  2             [SII]6716      5.096      0.12      -6    20
# Comp:  2             [SII]6731      3.403      0.12      -6    20
# Comp:  2              HeII4687      0.000      0.12      -6    20
# Comp:  2               HeI5876     0.8140      0.12      -6    20
# Comp:  2          [OIII]5007_d      4.085      0.16      -6    20
# Comp:  2            [OI]6300_d     0.9940      0.16      -6    20
# Comp:  2           [NII]6583_d      13.02      0.16      -6    20
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        49
#  comp.  1:        -9        11
#  comp.  2:        -7        16
# chi2/DOF: 0.7600; DOF: 2229; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.536      0.12      -9    11
# Comp:  1                 Hbeta      10.22      0.12      -9    11
# Comp:  1                Halpha      29.74      0.12      -9    11
# Comp:  2             [SII]6716      5.052      0.12      -7    16
# Comp:  2             [SII]6731      3.383      0.12      -7    16
# Comp:  2              HeII4687      0.000      0.12      -7    16
# Comp:  2               HeI5876      1.006      0.12      -7    16
# Comp:  2          [OIII]5007_d      3.987      0.15      -7    16
# Comp:  2            [OI]6300_d      1.027      0.15      -7    16
# Comp:  2           [NII]6583_d      12.82      0.15      -7    16
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Name': gas_names, 'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Spectrum2s_3_gas_ppxf_noreg.csv", index= False)

process_ppxf_results(pp, gas_names, spectrum_name="Spectrum2s_3_noreg", output_dir="./")

d3 = {'Component': [0, 1, 2], 'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3)
df3.to_csv("Spectrum2s_3_kin_noreg.csv", index= False)

# %%
read = pd.read_csv("Spectrum2s_3_gas_ppxf_noreg.csv")
print(read)
read2 = pd.read_csv("Spectrum2s_3_noreg_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
