# %%
# %matplotlib widget

# %% [markdown]
# Per ogni sorgente modificare:
# - z e controllare che lambda lines corrisponda
# - sigma e seeing
# - n_component
# - regione estrazione cielo
# - taglio immagine in y
# - funzioni di plot e model_convolved
# - bounds_HA (ampiezza dell'intervallo sulle x è +- la metà del seeing) e bounds
# - salvataggio fit

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd
import os

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/NGC-3217_2_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/NGC-3217_2_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     359   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        40   (2094, 964)   float32

# %%
image_cut = image[67:167, 0:1890]
image_error_cut = image_error[67:167, 0:1890]

# %%
wv = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10,8))
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin=np.percentile(image_cut, 15), vmax=np.percentile(image_cut, 90))
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Redshift or the lines in air

# %%
z = 0.03191
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/PSF/Real_seeing_NGC3217_2.txt")
sigmas = seeing / 2.35
print(sigmas)
# Out:
# [0.82805206 0.93317351 0.82656693 0.81685935 0.93037569 0.84425532]

# %% [markdown]
# ## Sky lines

# %%
hdul2 = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/NGC-3217_2_MAPPED_FLUX_ALL_SCI_LSS_U1.fits")
hdul2.info()
image2 = hdul2[0].data
image_cut2 = image2[67:167, 0:1890]

x_grid, y_grid = np.meshgrid(wv, y)
plt.figure(figsize=(10, 6))
plt.pcolormesh(x_grid, y_grid, image_cut2, shading='gouraud')#, vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/NGC-3217_2_MAPPED_FLUX_ALL_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     359   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        40   (2094, 964)   float32
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mask_sky = (y > 10)*(y < 20)
mask_wv = wv > 4451
image_sky = image_cut2[np.ix_(mask_sky, mask_wv)]
radial_profile_sky = np.sum(image_sky, axis = 0)
plt.figure(figsize=(10, 6))
plt.plot(wv[mask_wv], radial_profile_sky)

plt.grid()
plt.title(r'Sky lines')

plt.savefig('Sky_lines')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## H$\alpha$

# %%
mask_HA = (wv > l_HA-8)*(wv < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

sky_err = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_2/Propag_errori/Sky_errors.txt")
real_errors_HA = np.sqrt(radial_profile_error_HA**2+(sky_err[2])**2+(0.04*radial_profile_HA)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')

# %%
n_component = 4

def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

def model_convolved(x, sigma, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16])#+
        #sersic_1d(x_hr, *params[16:20]) #+
        #sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs, sigma):
    y_model = model_convolved(x, sigma, *params)
    return np.sum((y_obs - y_model)**2)

def sersic_1d_convolved(x, I_e, r_e, n, x_0, sigma):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def plot_curve(x_axes, params_curve, radial_profile, radial_profile_err, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].errorbar(x_axes, radial_profile, radial_profile_err, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24], sigma), color = 'purple', linestyle='--', label='Sérsic 6')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[24:28], sigma), color = 'deeppink', linestyle='--', label='Sérsic 7')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 8)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_err, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24], sigma), color = 'purple', linestyle='--', label='Sérsic 6')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[24:28], sigma), color = 'deeppink', linestyle='--', label='Sérsic 7')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0, 8)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

bounds_HA = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (30, 38),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (40, 50),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (50, 55),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (65, 75)   
]

def save_params(params_curve, covariance, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, sigma, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, dof, chi2

def save_params_diff(params_curve, radial_profile, radial_profile_error, sigma, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    param_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    
    output_dir = "Diff_params"
    os.makedirs(output_dir, exist_ok=True)

    # Salva file CSV nella cartella Diff_params
    if line_name:
        param_filename = os.path.join(output_dir, f"{line_name}_{output_prefix}_diff.csv")
    
    df_params.to_csv(param_filename, float_format='%.4f')

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 1047.3094787149676
# differential_evolution step 2: f(x)= 823.9253112880334
# differential_evolution step 3: f(x)= 823.9253112880334
# differential_evolution step 4: f(x)= 823.9253112880334
# differential_evolution step 5: f(x)= 823.9253112880334
# differential_evolution step 6: f(x)= 823.9253112880334
# differential_evolution step 7: f(x)= 823.9253112880334
# differential_evolution step 8: f(x)= 823.9253112880334
# differential_evolution step 9: f(x)= 823.9253112880334
# differential_evolution step 10: f(x)= 823.9253112880334
# differential_evolution step 11: f(x)= 823.9253112880334
# differential_evolution step 12: f(x)= 633.4709930728487
# differential_evolution step 13: f(x)= 633.4709930728487
# differential_evolution step 14: f(x)= 633.4709930728487
# differential_evolution step 15: f(x)= 633.4709930728487
# differential_evolution step 16: f(x)= 633.4709930728487
# differential_evolution step 17: f(x)= 211.95607947524286
# differential_evolution step 18: f(x)= 211.95607947524286
# differential_evolution step 19: f(x)= 204.94693562010215
# differential_evolution step 20: f(x)= 204.94693562010215
# differential_evolution step 21: f(x)= 204.94693562010215
# differential_evolution step 22: f(x)= 204.94693562010215
# differential_evolution step 23: f(x)= 204.94693562010215
# differential_evolution step 24: f(x)= 204.94693562010215
# differential_evolution step 25: f(x)= 204.94693562010215
# differential_evolution step 26: f(x)= 204.94693562010215
# differential_evolution step 27: f(x)= 100.4685307813701
# differential_evolution step 28: f(x)= 100.4685307813701
# differential_evolution step 29: f(x)= 100.4685307813701
# differential_evolution step 30: f(x)= 100.4685307813701
# differential_evolution step 31: f(x)= 100.4685307813701
# differential_evolution step 32: f(x)= 93.95142852375479
# differential_evolution step 33: f(x)= 93.95142852375479
# differential_evolution step 34: f(x)= 93.95142852375479
# differential_evolution step 35: f(x)= 93.95142852375479
# differential_evolution step 36: f(x)= 93.95142852375479
# differential_evolution step 37: f(x)= 90.74898057453304
# differential_evolution step 38: f(x)= 90.74898057453304
# differential_evolution step 39: f(x)= 90.74898057453304
# differential_evolution step 40: f(x)= 90.74898057453304
# differential_evolution step 41: f(x)= 38.145504965823235
# differential_evolution step 42: f(x)= 38.145504965823235
# differential_evolution step 43: f(x)= 38.145504965823235
# differential_evolution step 44: f(x)= 38.145504965823235
# differential_evolution step 45: f(x)= 38.145504965823235
# differential_evolution step 46: f(x)= 38.145504965823235
# differential_evolution step 47: f(x)= 38.145504965823235
# differential_evolution step 48: f(x)= 38.145504965823235
# differential_evolution step 49: f(x)= 38.145504965823235
# differential_evolution step 50: f(x)= 38.145504965823235
# differential_evolution step 51: f(x)= 38.145504965823235
# differential_evolution step 52: f(x)= 34.374298865266034
# differential_evolution step 53: f(x)= 34.374298865266034
# differential_evolution step 54: f(x)= 34.374298865266034
# differential_evolution step 55: f(x)= 34.374298865266034
# differential_evolution step 56: f(x)= 34.374298865266034
# differential_evolution step 57: f(x)= 34.374298865266034
# differential_evolution step 58: f(x)= 20.660371640669553
# differential_evolution step 59: f(x)= 20.660371640669553
# differential_evolution step 60: f(x)= 20.660371640669553
# differential_evolution step 61: f(x)= 20.660371640669553
# differential_evolution step 62: f(x)= 20.660371640669553
# differential_evolution step 63: f(x)= 20.660371640669553
# differential_evolution step 64: f(x)= 14.001779398628308
# differential_evolution step 65: f(x)= 14.001779398628308
# differential_evolution step 66: f(x)= 14.001779398628308
# differential_evolution step 67: f(x)= 14.001779398628308
# differential_evolution step 68: f(x)= 14.001779398628308
# differential_evolution step 69: f(x)= 14.001779398628308
# differential_evolution step 70: f(x)= 14.001779398628308
# differential_evolution step 71: f(x)= 13.902258698607202
# differential_evolution step 72: f(x)= 13.902258698607202
# differential_evolution step 73: f(x)= 13.902258698607202
# differential_evolution step 74: f(x)= 10.742938721148292
# differential_evolution step 75: f(x)= 10.742938721148292
# differential_evolution step 76: f(x)= 10.689493341168246
# differential_evolution step 77: f(x)= 10.689493341168246
# differential_evolution step 78: f(x)= 10.689493341168246
# differential_evolution step 79: f(x)= 10.11158359134937
# differential_evolution step 80: f(x)= 10.11158359134937
# differential_evolution step 81: f(x)= 10.11158359134937
# differential_evolution step 82: f(x)= 10.11158359134937
# differential_evolution step 83: f(x)= 10.11158359134937
# differential_evolution step 84: f(x)= 10.11158359134937
# differential_evolution step 85: f(x)= 10.11158359134937
# differential_evolution step 86: f(x)= 10.11158359134937
# differential_evolution step 87: f(x)= 10.11158359134937
# differential_evolution step 88: f(x)= 10.11158359134937
# differential_evolution step 89: f(x)= 10.11158359134937
# differential_evolution step 90: f(x)= 6.799513013662215
# differential_evolution step 91: f(x)= 6.799513013662215
# differential_evolution step 92: f(x)= 6.799513013662215
# differential_evolution step 93: f(x)= 6.799513013662215
# differential_evolution step 94: f(x)= 6.799513013662215
# differential_evolution step 95: f(x)= 6.799513013662215
# differential_evolution step 96: f(x)= 6.557756082583339
# differential_evolution step 97: f(x)= 4.626479147531654
# differential_evolution step 98: f(x)= 4.626479147531654
# differential_evolution step 99: f(x)= 4.502316494396574
# differential_evolution step 100: f(x)= 4.502316494396574
# differential_evolution step 101: f(x)= 4.012978507981297
# differential_evolution step 102: f(x)= 4.012978507981297
# differential_evolution step 103: f(x)= 4.012978507981297
# differential_evolution step 104: f(x)= 4.012978507981297
# differential_evolution step 105: f(x)= 4.012978507981297
# differential_evolution step 106: f(x)= 4.012978507981297
# differential_evolution step 107: f(x)= 4.012978507981297
# differential_evolution step 108: f(x)= 4.012978507981297
# differential_evolution step 109: f(x)= 4.012978507981297
# differential_evolution step 110: f(x)= 4.012978507981297
# differential_evolution step 111: f(x)= 4.012978507981297
# differential_evolution step 112: f(x)= 4.012978507981297
# differential_evolution step 113: f(x)= 4.012978507981297
# differential_evolution step 114: f(x)= 4.012978507981297
# differential_evolution step 115: f(x)= 3.459027167473291
# differential_evolution step 116: f(x)= 3.459027167473291
# differential_evolution step 117: f(x)= 3.4532517841521493
# differential_evolution step 118: f(x)= 3.37648488956633
# differential_evolution step 119: f(x)= 3.37648488956633
# differential_evolution step 120: f(x)= 3.37648488956633
# differential_evolution step 121: f(x)= 3.37648488956633
# differential_evolution step 122: f(x)= 3.260986759899928
# differential_evolution step 123: f(x)= 3.260986759899928
# differential_evolution step 124: f(x)= 3.1236857802329903
# differential_evolution step 125: f(x)= 2.8056090190175134
# differential_evolution step 126: f(x)= 2.8056090190175134
# differential_evolution step 127: f(x)= 2.8056090190175134
# differential_evolution step 128: f(x)= 2.8056090190175134
# differential_evolution step 129: f(x)= 2.698422827414808
# differential_evolution step 130: f(x)= 2.698422827414808
# differential_evolution step 131: f(x)= 2.297998729299297
# differential_evolution step 132: f(x)= 2.297998729299297
# differential_evolution step 133: f(x)= 2.297998729299297
# differential_evolution step 134: f(x)= 2.297998729299297
# differential_evolution step 135: f(x)= 2.297998729299297
# differential_evolution step 136: f(x)= 2.297998729299297
# differential_evolution step 137: f(x)= 2.297998729299297
# differential_evolution step 138: f(x)= 2.297998729299297
# differential_evolution step 139: f(x)= 2.297998729299297
# differential_evolution step 140: f(x)= 2.297998729299297
# differential_evolution step 141: f(x)= 2.026065828681129
# differential_evolution step 142: f(x)= 2.026065828681129
# differential_evolution step 143: f(x)= 2.026065828681129
# differential_evolution step 144: f(x)= 2.026065828681129
# differential_evolution step 145: f(x)= 2.026065828681129
# differential_evolution step 146: f(x)= 2.008873101437641
# differential_evolution step 147: f(x)= 2.008873101437641
# differential_evolution step 148: f(x)= 1.8496342671866632
# differential_evolution step 149: f(x)= 1.8496342671866632
# differential_evolution step 150: f(x)= 1.8496342671866632
# differential_evolution step 151: f(x)= 1.8496342671866632
# differential_evolution step 152: f(x)= 1.8496342671866632
# differential_evolution step 153: f(x)= 1.8496342671866632
# differential_evolution step 154: f(x)= 1.8225779066304064
# differential_evolution step 155: f(x)= 1.7559355005052832
# differential_evolution step 156: f(x)= 1.7559355005052832
# differential_evolution step 157: f(x)= 1.734371267390036
# differential_evolution step 158: f(x)= 1.6784054950555265
# differential_evolution step 159: f(x)= 1.6784054950555265
# differential_evolution step 160: f(x)= 1.5653788110680975
# differential_evolution step 161: f(x)= 1.5653788110680975
# differential_evolution step 162: f(x)= 1.5653788110680975
# differential_evolution step 163: f(x)= 1.5653788110680975
# differential_evolution step 164: f(x)= 1.5044729443287412
# differential_evolution step 165: f(x)= 1.5044729443287412
# differential_evolution step 166: f(x)= 1.3160882974890937
# differential_evolution step 167: f(x)= 1.2366528824960468
# differential_evolution step 168: f(x)= 1.2366528824960468
# differential_evolution step 169: f(x)= 1.2366528824960468
# differential_evolution step 170: f(x)= 1.2366528824960468
# differential_evolution step 171: f(x)= 1.2366528824960468
# differential_evolution step 172: f(x)= 1.2366528824960468
# differential_evolution step 173: f(x)= 1.2366528824960468
# differential_evolution step 174: f(x)= 1.2366528824960468
# differential_evolution step 175: f(x)= 1.2366528824960468
# differential_evolution step 176: f(x)= 1.2366528824960468
# differential_evolution step 177: f(x)= 1.2366528824960468
# differential_evolution step 178: f(x)= 0.9881905903036267
# differential_evolution step 179: f(x)= 0.9881905903036267
# differential_evolution step 180: f(x)= 0.9881905903036267
# differential_evolution step 181: f(x)= 0.9881905903036267
# differential_evolution step 182: f(x)= 0.9881905903036267
# differential_evolution step 183: f(x)= 0.9881905903036267
# differential_evolution step 184: f(x)= 0.9881905903036267
# differential_evolution step 185: f(x)= 0.9881905903036267
# differential_evolution step 186: f(x)= 0.9881905903036267
# differential_evolution step 187: f(x)= 0.9881905903036267
# differential_evolution step 188: f(x)= 0.9881905903036267
# differential_evolution step 189: f(x)= 0.9823386491895336
# differential_evolution step 190: f(x)= 0.9823386491895336
# differential_evolution step 191: f(x)= 0.9823386491895336
# differential_evolution step 192: f(x)= 0.8147318594348802
# differential_evolution step 193: f(x)= 0.810839335249866
# differential_evolution step 194: f(x)= 0.810839335249866
# differential_evolution step 195: f(x)= 0.810839335249866
# differential_evolution step 196: f(x)= 0.810839335249866
# differential_evolution step 197: f(x)= 0.810839335249866
# differential_evolution step 198: f(x)= 0.810839335249866
# differential_evolution step 199: f(x)= 0.810839335249866
# differential_evolution step 200: f(x)= 0.810839335249866
# differential_evolution step 201: f(x)= 0.810839335249866
# differential_evolution step 202: f(x)= 0.810839335249866
# differential_evolution step 203: f(x)= 0.810839335249866
# differential_evolution step 204: f(x)= 0.761109703959162
# differential_evolution step 205: f(x)= 0.761109703959162
# differential_evolution step 206: f(x)= 0.761109703959162
# differential_evolution step 207: f(x)= 0.761109703959162
# differential_evolution step 208: f(x)= 0.6555007016359915
# differential_evolution step 209: f(x)= 0.6555007016359915
# differential_evolution step 210: f(x)= 0.6555007016359915
# differential_evolution step 211: f(x)= 0.6555007016359915
# differential_evolution step 212: f(x)= 0.6555007016359915
# differential_evolution step 213: f(x)= 0.6555007016359915
# differential_evolution step 214: f(x)= 0.6555007016359915
# differential_evolution step 215: f(x)= 0.6555007016359915
# differential_evolution step 216: f(x)= 0.6555007016359915
# differential_evolution step 217: f(x)= 0.6555007016359915
# differential_evolution step 218: f(x)= 0.6555007016359915
# differential_evolution step 219: f(x)= 0.6555007016359915
# differential_evolution step 220: f(x)= 0.6555007016359915
# differential_evolution step 221: f(x)= 0.6555007016359915
# differential_evolution step 222: f(x)= 0.6555007016359915
# differential_evolution step 223: f(x)= 0.6555007016359915
# differential_evolution step 224: f(x)= 0.6555007016359915
# differential_evolution step 225: f(x)= 0.6555007016359915
# differential_evolution step 226: f(x)= 0.6555007016359915
# differential_evolution step 227: f(x)= 0.6555007016359915
# differential_evolution step 228: f(x)= 0.6555007016359915
# differential_evolution step 229: f(x)= 0.6353336464413372
# differential_evolution step 230: f(x)= 0.6353336464413372
# differential_evolution step 231: f(x)= 0.6353336464413372
# differential_evolution step 232: f(x)= 0.6353336464413372
# differential_evolution step 233: f(x)= 0.6353336464413372
# differential_evolution step 234: f(x)= 0.6353336464413372
# differential_evolution step 235: f(x)= 0.6353336464413372
# differential_evolution step 236: f(x)= 0.6353336464413372
# differential_evolution step 237: f(x)= 0.6353336464413372
# differential_evolution step 238: f(x)= 0.6353336464413372
# differential_evolution step 239: f(x)= 0.6353336464413372
# differential_evolution step 240: f(x)= 0.6247416754903642
# differential_evolution step 241: f(x)= 0.6247416754903642
# differential_evolution step 242: f(x)= 0.6247416754903642
# differential_evolution step 243: f(x)= 0.6247416754903642
# differential_evolution step 244: f(x)= 0.6247416754903642
# differential_evolution step 245: f(x)= 0.6150924098258497
# differential_evolution step 246: f(x)= 0.6150924098258497
# differential_evolution step 247: f(x)= 0.6068962852203349
# differential_evolution step 248: f(x)= 0.6068962852203349
# differential_evolution step 249: f(x)= 0.6068962852203349
# differential_evolution step 250: f(x)= 0.6068962852203349
# differential_evolution step 251: f(x)= 0.6068962852203349
# differential_evolution step 252: f(x)= 0.6068962852203349
# differential_evolution step 253: f(x)= 0.5915809781604303
# differential_evolution step 254: f(x)= 0.5915809781604303
# differential_evolution step 255: f(x)= 0.525116772644699
# differential_evolution step 256: f(x)= 0.525116772644699
# differential_evolution step 257: f(x)= 0.5021984522423378
# differential_evolution step 258: f(x)= 0.5021984522423378
# differential_evolution step 259: f(x)= 0.5021984522423378
# differential_evolution step 260: f(x)= 0.5021984522423378
# differential_evolution step 261: f(x)= 0.5021984522423378
# differential_evolution step 262: f(x)= 0.5021984522423378
# differential_evolution step 263: f(x)= 0.5021984522423378
# differential_evolution step 264: f(x)= 0.5021984522423378
# differential_evolution step 265: f(x)= 0.5021984522423378
# differential_evolution step 266: f(x)= 0.5021984522423378
# differential_evolution step 267: f(x)= 0.5021984522423378
# differential_evolution step 268: f(x)= 0.5021984522423378
# differential_evolution step 269: f(x)= 0.5021984522423378
# differential_evolution step 270: f(x)= 0.5021984522423378
# differential_evolution step 271: f(x)= 0.5021984522423378
# differential_evolution step 272: f(x)= 0.5021984522423378
# differential_evolution step 273: f(x)= 0.5021984522423378
# differential_evolution step 274: f(x)= 0.5021984522423378
# differential_evolution step 275: f(x)= 0.5021984522423378
# differential_evolution step 276: f(x)= 0.5021984522423378
# differential_evolution step 277: f(x)= 0.5021984522423378
# differential_evolution step 278: f(x)= 0.5021984522423378
# differential_evolution step 279: f(x)= 0.5021984522423378
# differential_evolution step 280: f(x)= 0.5021984522423378
# differential_evolution step 281: f(x)= 0.5021984522423378
# differential_evolution step 282: f(x)= 0.5021984522423378
# differential_evolution step 283: f(x)= 0.5021984522423378
# differential_evolution step 284: f(x)= 0.5005566006869515
# differential_evolution step 285: f(x)= 0.5005566006869515
# differential_evolution step 286: f(x)= 0.5005566006869515
# differential_evolution step 287: f(x)= 0.5005566006869515
# differential_evolution step 288: f(x)= 0.5005566006869515
# differential_evolution step 289: f(x)= 0.5005566006869515
# differential_evolution step 290: f(x)= 0.5005566006869515
# differential_evolution step 291: f(x)= 0.5005566006869515
# differential_evolution step 292: f(x)= 0.5005566006869515
# differential_evolution step 293: f(x)= 0.5005566006869515
# differential_evolution step 294: f(x)= 0.5005566006869515
# differential_evolution step 295: f(x)= 0.4765321119745869
# differential_evolution step 296: f(x)= 0.4696857668097928
# differential_evolution step 297: f(x)= 0.4696857668097928
# differential_evolution step 298: f(x)= 0.4696857668097928
# differential_evolution step 299: f(x)= 0.4696857668097928
# differential_evolution step 300: f(x)= 0.4696857668097928
# differential_evolution step 301: f(x)= 0.4696857668097928
# differential_evolution step 302: f(x)= 0.4696857668097928
# differential_evolution step 303: f(x)= 0.4696857668097928
# differential_evolution step 304: f(x)= 0.4696857668097928
# differential_evolution step 305: f(x)= 0.4696857668097928
# differential_evolution step 306: f(x)= 0.4696857668097928
# differential_evolution step 307: f(x)= 0.4696857668097928
# differential_evolution step 308: f(x)= 0.4696857668097928
# differential_evolution step 309: f(x)= 0.4696857668097928
# differential_evolution step 310: f(x)= 0.4696857668097928
# differential_evolution step 311: f(x)= 0.4696857668097928
# differential_evolution step 312: f(x)= 0.4696857668097928
# differential_evolution step 313: f(x)= 0.4696857668097928
# differential_evolution step 314: f(x)= 0.4696857668097928
# differential_evolution step 315: f(x)= 0.4696857668097928
# differential_evolution step 316: f(x)= 0.46963565742807567
# differential_evolution step 317: f(x)= 0.46963565742807567
# differential_evolution step 318: f(x)= 0.46520710358445033
# differential_evolution step 319: f(x)= 0.46520710358445033
# differential_evolution step 320: f(x)= 0.46520710358445033
# differential_evolution step 321: f(x)= 0.46520710358445033
# differential_evolution step 322: f(x)= 0.46520710358445033
# differential_evolution step 323: f(x)= 0.451547902333387
# differential_evolution step 324: f(x)= 0.451547902333387
# differential_evolution step 325: f(x)= 0.451547902333387
# differential_evolution step 326: f(x)= 0.451547902333387
# differential_evolution step 327: f(x)= 0.451547902333387
# differential_evolution step 328: f(x)= 0.451547902333387
# differential_evolution step 329: f(x)= 0.451547902333387
# differential_evolution step 330: f(x)= 0.4501699231410581
# differential_evolution step 331: f(x)= 0.4501699231410581
# differential_evolution step 332: f(x)= 0.4501699231410581
# differential_evolution step 333: f(x)= 0.4501699231410581
# differential_evolution step 334: f(x)= 0.4501699231410581
# differential_evolution step 335: f(x)= 0.4501699231410581
# differential_evolution step 336: f(x)= 0.4501699231410581
# differential_evolution step 337: f(x)= 0.4477234433108652
# differential_evolution step 338: f(x)= 0.4477234433108652
# differential_evolution step 339: f(x)= 0.4477234433108652
# differential_evolution step 340: f(x)= 0.4477234433108652
# differential_evolution step 341: f(x)= 0.4477234433108652
# differential_evolution step 342: f(x)= 0.4477234433108652
# differential_evolution step 343: f(x)= 0.4477234433108652
# differential_evolution step 344: f(x)= 0.4477234433108652
# differential_evolution step 345: f(x)= 0.4477234433108652
# differential_evolution step 346: f(x)= 0.4477234433108652
# differential_evolution step 347: f(x)= 0.4477234433108652
# differential_evolution step 348: f(x)= 0.4477234433108652
# differential_evolution step 349: f(x)= 0.4477234433108652
# differential_evolution step 350: f(x)= 0.4477234433108652
# differential_evolution step 351: f(x)= 0.4477234433108652
# differential_evolution step 352: f(x)= 0.4477234433108652
# differential_evolution step 353: f(x)= 0.4477234433108652
# differential_evolution step 354: f(x)= 0.4477234433108652
# differential_evolution step 355: f(x)= 0.44721186515063194
# differential_evolution step 356: f(x)= 0.44721186515063194
# differential_evolution step 357: f(x)= 0.44721186515063194
# differential_evolution step 358: f(x)= 0.44721186515063194
# differential_evolution step 359: f(x)= 0.44340462560058735
# differential_evolution step 360: f(x)= 0.44340462560058735
# differential_evolution step 361: f(x)= 0.43611969206445067
# differential_evolution step 362: f(x)= 0.43482312731324757
# differential_evolution step 363: f(x)= 0.43482312731324757
# differential_evolution step 364: f(x)= 0.43482312731324757
# differential_evolution step 365: f(x)= 0.43482312731324757
# differential_evolution step 366: f(x)= 0.43482312731324757
# differential_evolution step 367: f(x)= 0.43482312731324757
# differential_evolution step 368: f(x)= 0.43309602121092283
# differential_evolution step 369: f(x)= 0.4268760974953624
# differential_evolution step 370: f(x)= 0.4268760974953624
# differential_evolution step 371: f(x)= 0.4268760974953624
# differential_evolution step 372: f(x)= 0.4268760974953624
# differential_evolution step 373: f(x)= 0.422403403670718
# differential_evolution step 374: f(x)= 0.422403403670718
# differential_evolution step 375: f(x)= 0.422403403670718
# differential_evolution step 376: f(x)= 0.422403403670718
# differential_evolution step 377: f(x)= 0.422403403670718
# differential_evolution step 378: f(x)= 0.422403403670718
# differential_evolution step 379: f(x)= 0.422403403670718
# differential_evolution step 380: f(x)= 0.4202413624180845
# differential_evolution step 381: f(x)= 0.4202413624180845
# differential_evolution step 382: f(x)= 0.4202413624180845
# differential_evolution step 383: f(x)= 0.4202413624180845
# differential_evolution step 384: f(x)= 0.4202413624180845
# differential_evolution step 385: f(x)= 0.4202413624180845
# differential_evolution step 386: f(x)= 0.4202413624180845
# differential_evolution step 387: f(x)= 0.4202413624180845
# differential_evolution step 388: f(x)= 0.4202413624180845
# differential_evolution step 389: f(x)= 0.4202413624180845
# differential_evolution step 390: f(x)= 0.4202413624180845
# differential_evolution step 391: f(x)= 0.4189193229800633
# differential_evolution step 392: f(x)= 0.4189193229800633
# differential_evolution step 393: f(x)= 0.4189193229800633
# differential_evolution step 394: f(x)= 0.4189193229800633
# differential_evolution step 395: f(x)= 0.4189193229800633
# differential_evolution step 396: f(x)= 0.4189193229800633
# differential_evolution step 397: f(x)= 0.4189193229800633
# differential_evolution step 398: f(x)= 0.4189193229800633
# differential_evolution step 399: f(x)= 0.4189193229800633
# differential_evolution step 400: f(x)= 0.4189193229800633
# differential_evolution step 401: f(x)= 0.4189193229800633
# differential_evolution step 402: f(x)= 0.4189193229800633
# differential_evolution step 403: f(x)= 0.4189193229800633
# differential_evolution step 404: f(x)= 0.4189193229800633
# differential_evolution step 405: f(x)= 0.4189193229800633
# differential_evolution step 406: f(x)= 0.4189193229800633
# differential_evolution step 407: f(x)= 0.4189193229800633
# differential_evolution step 408: f(x)= 0.4189193229800633
# differential_evolution step 409: f(x)= 0.4189193229800633
# differential_evolution step 410: f(x)= 0.4189193229800633
# differential_evolution step 411: f(x)= 0.4189193229800633
# differential_evolution step 412: f(x)= 0.4189193229800633
# differential_evolution step 413: f(x)= 0.4189193229800633
# differential_evolution step 414: f(x)= 0.40799231759776555
# differential_evolution step 415: f(x)= 0.40799231759776555
# differential_evolution step 416: f(x)= 0.40799231759776555
# differential_evolution step 417: f(x)= 0.40799231759776555
# differential_evolution step 418: f(x)= 0.40799231759776555
# differential_evolution step 419: f(x)= 0.40799231759776555
# differential_evolution step 420: f(x)= 0.40799231759776555
# differential_evolution step 421: f(x)= 0.40799231759776555
# differential_evolution step 422: f(x)= 0.40799231759776555
# differential_evolution step 423: f(x)= 0.40799231759776555
# differential_evolution step 424: f(x)= 0.40799231759776555
# differential_evolution step 425: f(x)= 0.40799231759776555
# differential_evolution step 426: f(x)= 0.40799231759776555
# differential_evolution step 427: f(x)= 0.40799231759776555
# differential_evolution step 428: f(x)= 0.40799231759776555
# differential_evolution step 429: f(x)= 0.40799231759776555
# differential_evolution step 430: f(x)= 0.40661753597774575
# differential_evolution step 431: f(x)= 0.40661753597774575
# differential_evolution step 432: f(x)= 0.40661753597774575
# differential_evolution step 433: f(x)= 0.40661753597774575
# differential_evolution step 434: f(x)= 0.40661753597774575
# differential_evolution step 435: f(x)= 0.40661753597774575
# differential_evolution step 436: f(x)= 0.40661753597774575
# differential_evolution step 437: f(x)= 0.40661753597774575
# differential_evolution step 438: f(x)= 0.40661753597774575
# differential_evolution step 439: f(x)= 0.40661753597774575
# differential_evolution step 440: f(x)= 0.40661753597774575
# differential_evolution step 441: f(x)= 0.40661753597774575
# differential_evolution step 442: f(x)= 0.40661753597774575
# differential_evolution step 443: f(x)= 0.40661753597774575
# differential_evolution step 444: f(x)= 0.40661753597774575
# differential_evolution step 445: f(x)= 0.40661753597774575
# differential_evolution step 446: f(x)= 0.40661753597774575
# differential_evolution step 447: f(x)= 0.40661753597774575
# differential_evolution step 448: f(x)= 0.40473706261858194
# differential_evolution step 449: f(x)= 0.40473706261858194
# differential_evolution step 450: f(x)= 0.40473706261858194
# differential_evolution step 451: f(x)= 0.40473706261858194
# differential_evolution step 452: f(x)= 0.40473706261858194
# differential_evolution step 453: f(x)= 0.40473706261858194
# differential_evolution step 454: f(x)= 0.3926687036899544
# differential_evolution step 455: f(x)= 0.3926687036899544
# differential_evolution step 456: f(x)= 0.3926687036899544
# differential_evolution step 457: f(x)= 0.3926687036899544
# differential_evolution step 458: f(x)= 0.3926687036899544
# differential_evolution step 459: f(x)= 0.3926687036899544
# differential_evolution step 460: f(x)= 0.3926687036899544
# differential_evolution step 461: f(x)= 0.3926687036899544
# differential_evolution step 462: f(x)= 0.3926687036899544
# differential_evolution step 463: f(x)= 0.3926687036899544
# differential_evolution step 464: f(x)= 0.3926687036899544
# differential_evolution step 465: f(x)= 0.3926687036899544
# differential_evolution step 466: f(x)= 0.39069503500975794
# differential_evolution step 467: f(x)= 0.39069503500975794
# differential_evolution step 468: f(x)= 0.39069503500975794
# differential_evolution step 469: f(x)= 0.39069503500975794
# differential_evolution step 470: f(x)= 0.39069503500975794
# differential_evolution step 471: f(x)= 0.39069503500975794
# differential_evolution step 472: f(x)= 0.38769960497285433
# differential_evolution step 473: f(x)= 0.38769960497285433
# differential_evolution step 474: f(x)= 0.38769960497285433
# differential_evolution step 475: f(x)= 0.38769960497285433
# differential_evolution step 476: f(x)= 0.38769960497285433
# differential_evolution step 477: f(x)= 0.38769960497285433
# differential_evolution step 478: f(x)= 0.38695155416395
# differential_evolution step 479: f(x)= 0.38695155416395
# differential_evolution step 562: f(x)= 0.3643985194200185
# differential_evolution step 563: f(x)= 0.3643985194200185
# differential_evolution step 564: f(x)= 0.3643985194200185
# differential_evolution step 565: f(x)= 0.3643985194200185
# differential_evolution step 566: f(x)= 0.3643985194200185
# differential_evolution step 567: f(x)= 0.3643985194200185
# differential_evolution step 568: f(x)= 0.3643985194200185
# differential_evolution step 569: f(x)= 0.3643985194200185
# differential_evolution step 570: f(x)= 0.3643985194200185
# differential_evolution step 571: f(x)= 0.3643985194200185
# differential_evolution step 572: f(x)= 0.3643985194200185
# differential_evolution step 573: f(x)= 0.3643985194200185
# differential_evolution step 574: f(x)= 0.3641940720725462
# differential_evolution step 575: f(x)= 0.3641940720725462
# differential_evolution step 576: f(x)= 0.3641940720725462
# differential_evolution step 577: f(x)= 0.3641940720725462
# differential_evolution step 578: f(x)= 0.3641940720725462
# differential_evolution step 579: f(x)= 0.3641940720725462
# differential_evolution step 580: f(x)= 0.3641940720725462
# differential_evolution step 581: f(x)= 0.3641940720725462
# differential_evolution step 582: f(x)= 0.3641940720725462
# differential_evolution step 583: f(x)= 0.3641940720725462
# differential_evolution step 584: f(x)= 0.3641940720725462
# differential_evolution step 585: f(x)= 0.3641940720725462
# differential_evolution step 586: f(x)= 0.3641940720725462
# differential_evolution step 587: f(x)= 0.3641940720725462
# differential_evolution step 588: f(x)= 0.3641940720725462
# differential_evolution step 589: f(x)= 0.3641940720725462
# differential_evolution step 590: f(x)= 0.3641940720725462
# differential_evolution step 591: f(x)= 0.36176349004336616
# differential_evolution step 592: f(x)= 0.35752069942432035
# differential_evolution step 593: f(x)= 0.35752069942432035
# differential_evolution step 594: f(x)= 0.35752069942432035
# differential_evolution step 595: f(x)= 0.35752069942432035
# differential_evolution step 596: f(x)= 0.35752069942432035
# differential_evolution step 597: f(x)= 0.35752069942432035
# differential_evolution step 598: f(x)= 0.35752069942432035
# differential_evolution step 599: f(x)= 0.35752069942432035
# differential_evolution step 600: f(x)= 0.35752069942432035
# differential_evolution step 601: f(x)= 0.35752069942432035
# differential_evolution step 602: f(x)= 0.35752069942432035
# differential_evolution step 603: f(x)= 0.35752069942432035
# differential_evolution step 604: f(x)= 0.35752069942432035
# differential_evolution step 605: f(x)= 0.35499815304842375
# differential_evolution step 606: f(x)= 0.35499815304842375
# differential_evolution step 607: f(x)= 0.35499815304842375
# differential_evolution step 608: f(x)= 0.35499815304842375
# differential_evolution step 609: f(x)= 0.35499815304842375
# differential_evolution step 610: f(x)= 0.35499815304842375
# differential_evolution step 611: f(x)= 0.35499815304842375
# differential_evolution step 612: f(x)= 0.35499815304842375
# differential_evolution step 613: f(x)= 0.35499815304842375
# differential_evolution step 614: f(x)= 0.35499815304842375
# differential_evolution step 615: f(x)= 0.35499815304842375
# differential_evolution step 616: f(x)= 0.35499815304842375
# differential_evolution step 617: f(x)= 0.35499815304842375
# differential_evolution step 618: f(x)= 0.35499815304842375
# differential_evolution step 619: f(x)= 0.35499815304842375
# differential_evolution step 620: f(x)= 0.35499815304842375
# differential_evolution step 621: f(x)= 0.35499815304842375
# differential_evolution step 622: f(x)= 0.35499815304842375
# differential_evolution step 623: f(x)= 0.35499815304842375
# differential_evolution step 624: f(x)= 0.35499815304842375
# differential_evolution step 625: f(x)= 0.35499815304842375
# differential_evolution step 626: f(x)= 0.35499815304842375
# differential_evolution step 627: f(x)= 0.35499815304842375
# differential_evolution step 628: f(x)= 0.3539541065494506
# differential_evolution step 629: f(x)= 0.3539541065494506
# differential_evolution step 630: f(x)= 0.3539541065494506
# differential_evolution step 631: f(x)= 0.3539541065494506
# differential_evolution step 632: f(x)= 0.3539541065494506
# differential_evolution step 633: f(x)= 0.3539541065494506
# differential_evolution step 634: f(x)= 0.3539541065494506
# differential_evolution step 635: f(x)= 0.353144908409745
# differential_evolution step 636: f(x)= 0.353144908409745
# differential_evolution step 637: f(x)= 0.353144908409745
# differential_evolution step 638: f(x)= 0.353144908409745
# differential_evolution step 639: f(x)= 0.353144908409745
# differential_evolution step 640: f(x)= 0.353144908409745
# differential_evolution step 641: f(x)= 0.353144908409745
# differential_evolution step 642: f(x)= 0.353144908409745
# differential_evolution step 643: f(x)= 0.353144908409745
# differential_evolution step 644: f(x)= 0.353144908409745
# differential_evolution step 645: f(x)= 0.353144908409745
# differential_evolution step 646: f(x)= 0.353144908409745
# differential_evolution step 647: f(x)= 0.353144908409745
# differential_evolution step 648: f(x)= 0.353144908409745
# differential_evolution step 649: f(x)= 0.351562295004535
# differential_evolution step 650: f(x)= 0.351562295004535
# differential_evolution step 651: f(x)= 0.351562295004535
# differential_evolution step 652: f(x)= 0.351562295004535
# differential_evolution step 653: f(x)= 0.351562295004535
# differential_evolution step 654: f(x)= 0.351562295004535
# differential_evolution step 655: f(x)= 0.351562295004535
# differential_evolution step 656: f(x)= 0.351562295004535
# differential_evolution step 657: f(x)= 0.351562295004535
# differential_evolution step 658: f(x)= 0.351562295004535
# differential_evolution step 659: f(x)= 0.351562295004535
# differential_evolution step 660: f(x)= 0.351562295004535
# differential_evolution step 661: f(x)= 0.351562295004535
# differential_evolution step 662: f(x)= 0.351562295004535
# differential_evolution step 663: f(x)= 0.351562295004535
# differential_evolution step 664: f(x)= 0.351562295004535
# differential_evolution step 665: f(x)= 0.351562295004535
# differential_evolution step 666: f(x)= 0.351562295004535
# differential_evolution step 667: f(x)= 0.351562295004535
# differential_evolution step 668: f(x)= 0.351562295004535
# differential_evolution step 669: f(x)= 0.351562295004535
# differential_evolution step 670: f(x)= 0.351562295004535
# differential_evolution step 671: f(x)= 0.3513840023711551
# differential_evolution step 672: f(x)= 0.3513840023711551
# differential_evolution step 673: f(x)= 0.3513840023711551
# differential_evolution step 674: f(x)= 0.3513840023711551
# differential_evolution step 675: f(x)= 0.3513840023711551
# differential_evolution step 676: f(x)= 0.3513840023711551
# differential_evolution step 677: f(x)= 0.3506798896759325
# differential_evolution step 678: f(x)= 0.3506798896759325
# differential_evolution step 679: f(x)= 0.3506798896759325
# differential_evolution step 680: f(x)= 0.3506798896759325
# differential_evolution step 681: f(x)= 0.3506798896759325
# differential_evolution step 682: f(x)= 0.3506798896759325
# differential_evolution step 683: f(x)= 0.3506798896759325
# differential_evolution step 684: f(x)= 0.3506798896759325
# differential_evolution step 685: f(x)= 0.3506798896759325
# differential_evolution step 686: f(x)= 0.3506798896759325
# differential_evolution step 687: f(x)= 0.3506798896759325
# differential_evolution step 688: f(x)= 0.3506798896759325
# differential_evolution step 689: f(x)= 0.3506798896759325
# differential_evolution step 690: f(x)= 0.3506798896759325
# differential_evolution step 691: f(x)= 0.3506798896759325
# differential_evolution step 692: f(x)= 0.35055107910758676
# differential_evolution step 693: f(x)= 0.35055107910758676
# differential_evolution step 694: f(x)= 0.35055107910758676
# differential_evolution step 695: f(x)= 0.35055107910758676
# differential_evolution step 696: f(x)= 0.35055107910758676
# differential_evolution step 697: f(x)= 0.35055107910758676
# differential_evolution step 698: f(x)= 0.35055107910758676
# differential_evolution step 699: f(x)= 0.35055107910758676
# differential_evolution step 700: f(x)= 0.34845231968595336
# differential_evolution step 701: f(x)= 0.34845231968595336
# differential_evolution step 702: f(x)= 0.34845231968595336
# differential_evolution step 703: f(x)= 0.34845231968595336
# differential_evolution step 704: f(x)= 0.34845231968595336
# differential_evolution step 705: f(x)= 0.34845231968595336
# differential_evolution step 706: f(x)= 0.34845231968595336
# differential_evolution step 707: f(x)= 0.34845231968595336
# differential_evolution step 708: f(x)= 0.34845231968595336
# differential_evolution step 709: f(x)= 0.34845231968595336
# differential_evolution step 710: f(x)= 0.34845231968595336
# differential_evolution step 711: f(x)= 0.34845231968595336
# differential_evolution step 712: f(x)= 0.34845231968595336
# differential_evolution step 713: f(x)= 0.3474137593455753
# differential_evolution step 714: f(x)= 0.3474137593455753
# differential_evolution step 715: f(x)= 0.3474137593455753
# differential_evolution step 716: f(x)= 0.3474137593455753
# differential_evolution step 717: f(x)= 0.3474137593455753
# differential_evolution step 718: f(x)= 0.3474137593455753
# differential_evolution step 719: f(x)= 0.3474137593455753
# differential_evolution step 720: f(x)= 0.3474137593455753
# differential_evolution step 721: f(x)= 0.3474137593455753
# differential_evolution step 722: f(x)= 0.3474137593455753
# differential_evolution step 723: f(x)= 0.3474137593455753
# differential_evolution step 724: f(x)= 0.3474137593455753
# differential_evolution step 725: f(x)= 0.3474137593455753
# differential_evolution step 726: f(x)= 0.3474137593455753
# differential_evolution step 727: f(x)= 0.3474137593455753
# differential_evolution step 728: f(x)= 0.3474137593455753
# differential_evolution step 729: f(x)= 0.3474137593455753
# differential_evolution step 730: f(x)= 0.34707677382237034
# differential_evolution step 731: f(x)= 0.34707677382237034
# differential_evolution step 732: f(x)= 0.34707677382237034
# differential_evolution step 733: f(x)= 0.34707677382237034
# differential_evolution step 734: f(x)= 0.34707677382237034
# differential_evolution step 735: f(x)= 0.34707677382237034
# differential_evolution step 736: f(x)= 0.34707677382237034
# differential_evolution step 737: f(x)= 0.34707677382237034
# differential_evolution step 738: f(x)= 0.3455560168997835
# differential_evolution step 739: f(x)= 0.3455560168997835
# differential_evolution step 740: f(x)= 0.3455560168997835
# differential_evolution step 741: f(x)= 0.3455560168997835
# differential_evolution step 742: f(x)= 0.3455560168997835
# differential_evolution step 743: f(x)= 0.3455560168997835
# differential_evolution step 744: f(x)= 0.3455560168997835
# differential_evolution step 745: f(x)= 0.3455560168997835
# differential_evolution step 746: f(x)= 0.3455560168997835
# differential_evolution step 747: f(x)= 0.34424705686854257
# differential_evolution step 748: f(x)= 0.34424705686854257
# differential_evolution step 749: f(x)= 0.34424705686854257
# differential_evolution step 750: f(x)= 0.34424705686854257
# differential_evolution step 751: f(x)= 0.34424705686854257
# differential_evolution step 752: f(x)= 0.34424705686854257
# differential_evolution step 753: f(x)= 0.34424705686854257
# differential_evolution step 754: f(x)= 0.34424705686854257
# differential_evolution step 755: f(x)= 0.34424705686854257
# differential_evolution step 756: f(x)= 0.34424705686854257
# differential_evolution step 757: f(x)= 0.34424705686854257
# differential_evolution step 758: f(x)= 0.34424705686854257
# differential_evolution step 759: f(x)= 0.34424705686854257
# differential_evolution step 760: f(x)= 0.34424705686854257
# differential_evolution step 761: f(x)= 0.34424705686854257
# differential_evolution step 762: f(x)= 0.34424705686854257
# differential_evolution step 763: f(x)= 0.34424705686854257
# differential_evolution step 764: f(x)= 0.34424705686854257
# differential_evolution step 765: f(x)= 0.34424705686854257
# differential_evolution step 766: f(x)= 0.34424705686854257
# differential_evolution step 767: f(x)= 0.34424705686854257
# differential_evolution step 768: f(x)= 0.34424705686854257
# differential_evolution step 769: f(x)= 0.34424705686854257
# differential_evolution step 770: f(x)= 0.34424705686854257
# differential_evolution step 771: f(x)= 0.34424705686854257
# differential_evolution step 772: f(x)= 0.34424705686854257
# differential_evolution step 773: f(x)= 0.34424705686854257
# differential_evolution step 774: f(x)= 0.34424705686854257
# differential_evolution step 775: f(x)= 0.34424705686854257
# differential_evolution step 776: f(x)= 0.34424705686854257
# differential_evolution step 777: f(x)= 0.34424705686854257
# differential_evolution step 778: f(x)= 0.34424705686854257
# differential_evolution step 779: f(x)= 0.34424705686854257
# differential_evolution step 780: f(x)= 0.34424705686854257
# differential_evolution step 781: f(x)= 0.341908878456115
# differential_evolution step 782: f(x)= 0.341908878456115
# differential_evolution step 783: f(x)= 0.341908878456115
# differential_evolution step 784: f(x)= 0.341908878456115
# differential_evolution step 785: f(x)= 0.341908878456115
# differential_evolution step 786: f(x)= 0.341908878456115
# differential_evolution step 787: f(x)= 0.341908878456115
# differential_evolution step 788: f(x)= 0.341908878456115
# differential_evolution step 789: f(x)= 0.341908878456115
# differential_evolution step 790: f(x)= 0.341908878456115
# differential_evolution step 791: f(x)= 0.341908878456115
# differential_evolution step 792: f(x)= 0.341908878456115
# differential_evolution step 793: f(x)= 0.34154597200058884
# differential_evolution step 794: f(x)= 0.34154597200058884
# differential_evolution step 795: f(x)= 0.34154597200058884
# differential_evolution step 796: f(x)= 0.34127189755239745
# differential_evolution step 797: f(x)= 0.34127189755239745
# differential_evolution step 798: f(x)= 0.34127189755239745
# differential_evolution step 799: f(x)= 0.34127189755239745
# differential_evolution step 800: f(x)= 0.34127189755239745
# differential_evolution step 801: f(x)= 0.34127189755239745
# differential_evolution step 802: f(x)= 0.34127189755239745
# differential_evolution step 803: f(x)= 0.34127189755239745
# differential_evolution step 804: f(x)= 0.34127189755239745
# differential_evolution step 805: f(x)= 0.34127189755239745
# differential_evolution step 806: f(x)= 0.34127189755239745
# differential_evolution step 807: f(x)= 0.34127189755239745
# differential_evolution step 808: f(x)= 0.34127189755239745
# differential_evolution step 809: f(x)= 0.34127189755239745
# differential_evolution step 810: f(x)= 0.34127189755239745
# differential_evolution step 811: f(x)= 0.34127189755239745
# differential_evolution step 812: f(x)= 0.34127189755239745
# differential_evolution step 813: f(x)= 0.34115904577310124
# differential_evolution step 814: f(x)= 0.34115904577310124
# differential_evolution step 815: f(x)= 0.34084842438703783
# differential_evolution step 816: f(x)= 0.34084842438703783
# differential_evolution step 817: f(x)= 0.34084842438703783
# differential_evolution step 818: f(x)= 0.34084842438703783
# differential_evolution step 819: f(x)= 0.34084842438703783
# differential_evolution step 820: f(x)= 0.34084842438703783
# differential_evolution step 821: f(x)= 0.34084842438703783
# differential_evolution step 822: f(x)= 0.34084842438703783
# differential_evolution step 823: f(x)= 0.34084842438703783
# differential_evolution step 824: f(x)= 0.34084842438703783
# differential_evolution step 825: f(x)= 0.34084463651326424
# differential_evolution step 826: f(x)= 0.34084463651326424
# differential_evolution step 827: f(x)= 0.34084463651326424
# differential_evolution step 828: f(x)= 0.34084463651326424
# differential_evolution step 829: f(x)= 0.34084463651326424
# differential_evolution step 830: f(x)= 0.34084463651326424
# differential_evolution step 831: f(x)= 0.34084463651326424
# differential_evolution step 832: f(x)= 0.34084463651326424
# differential_evolution step 833: f(x)= 0.34084463651326424
# differential_evolution step 834: f(x)= 0.34084463651326424
# differential_evolution step 835: f(x)= 0.34084463651326424
# differential_evolution step 836: f(x)= 0.34084463651326424
# differential_evolution step 837: f(x)= 0.33986578396505757
# differential_evolution step 838: f(x)= 0.33986578396505757
# differential_evolution step 839: f(x)= 0.33986578396505757
# differential_evolution step 840: f(x)= 0.33986578396505757
# differential_evolution step 841: f(x)= 0.33986578396505757
# differential_evolution step 842: f(x)= 0.33986578396505757
# differential_evolution step 843: f(x)= 0.33986578396505757
# differential_evolution step 844: f(x)= 0.33986578396505757
# differential_evolution step 845: f(x)= 0.33986578396505757
# differential_evolution step 846: f(x)= 0.33986578396505757
# differential_evolution step 847: f(x)= 0.33986578396505757
# differential_evolution step 848: f(x)= 0.33986578396505757
# differential_evolution step 849: f(x)= 0.33986578396505757
# differential_evolution step 850: f(x)= 0.3376594053560359
# differential_evolution step 851: f(x)= 0.3376594053560359
# differential_evolution step 852: f(x)= 0.3376594053560359
# differential_evolution step 853: f(x)= 0.3376594053560359
# differential_evolution step 854: f(x)= 0.3376594053560359
# differential_evolution step 855: f(x)= 0.3371461075116632
# differential_evolution step 856: f(x)= 0.3371461075116632
# differential_evolution step 857: f(x)= 0.3371461075116632
# differential_evolution step 858: f(x)= 0.3371461075116632
# differential_evolution step 859: f(x)= 0.3371461075116632
# differential_evolution step 860: f(x)= 0.3371461075116632
# differential_evolution step 861: f(x)= 0.33642615200211995
# differential_evolution step 862: f(x)= 0.33642615200211995
# differential_evolution step 863: f(x)= 0.33642615200211995
# differential_evolution step 864: f(x)= 0.33642615200211995
# differential_evolution step 865: f(x)= 0.33642615200211995
# differential_evolution step 866: f(x)= 0.33642615200211995
# differential_evolution step 867: f(x)= 0.33642615200211995
# differential_evolution step 868: f(x)= 0.33642615200211995
# differential_evolution step 869: f(x)= 0.33642615200211995
# differential_evolution step 870: f(x)= 0.33642615200211995
# differential_evolution step 871: f(x)= 0.33642615200211995
# differential_evolution step 872: f(x)= 0.33642615200211995
# differential_evolution step 873: f(x)= 0.33642615200211995
# differential_evolution step 874: f(x)= 0.33642615200211995
# differential_evolution step 875: f(x)= 0.33642615200211995
# differential_evolution step 876: f(x)= 0.33642615200211995
# differential_evolution step 877: f(x)= 0.33642615200211995
# differential_evolution step 878: f(x)= 0.3353018865296471
# differential_evolution step 879: f(x)= 0.3353018865296471
# differential_evolution step 880: f(x)= 0.3353018865296471
# differential_evolution step 881: f(x)= 0.3353018865296471
# differential_evolution step 882: f(x)= 0.3353018865296471
# differential_evolution step 883: f(x)= 0.3353018865296471
# differential_evolution step 884: f(x)= 0.3353018865296471
# differential_evolution step 885: f(x)= 0.33456750299085875
# differential_evolution step 886: f(x)= 0.33456750299085875
# differential_evolution step 887: f(x)= 0.33456750299085875
# differential_evolution step 888: f(x)= 0.3344254555830654
# differential_evolution step 889: f(x)= 0.3344254555830654
# differential_evolution step 890: f(x)= 0.33395807282088824
# differential_evolution step 891: f(x)= 0.33395807282088824
# differential_evolution step 892: f(x)= 0.33395807282088824
# differential_evolution step 893: f(x)= 0.33395807282088824
# differential_evolution step 894: f(x)= 0.33395807282088824
# differential_evolution step 895: f(x)= 0.33395807282088824
# differential_evolution step 896: f(x)= 0.33395807282088824
# differential_evolution step 897: f(x)= 0.33395807282088824
# differential_evolution step 898: f(x)= 0.33395807282088824
# differential_evolution step 899: f(x)= 0.33395807282088824
# differential_evolution step 900: f(x)= 0.33395807282088824
# differential_evolution step 901: f(x)= 0.33395807282088824
# differential_evolution step 902: f(x)= 0.33395807282088824
# differential_evolution step 903: f(x)= 0.33395807282088824
# differential_evolution step 904: f(x)= 0.33395807282088824
# differential_evolution step 905: f(x)= 0.33395807282088824
# differential_evolution step 906: f(x)= 0.33395807282088824
# differential_evolution step 907: f(x)= 0.33395807282088824
# differential_evolution step 908: f(x)= 0.33395807282088824
# differential_evolution step 909: f(x)= 0.33395807282088824
# differential_evolution step 910: f(x)= 0.33395807282088824
# differential_evolution step 911: f(x)= 0.33395807282088824
# differential_evolution step 912: f(x)= 0.33395807282088824
# differential_evolution step 913: f(x)= 0.33395807282088824
# differential_evolution step 914: f(x)= 0.33395807282088824
# differential_evolution step 915: f(x)= 0.33395807282088824
# differential_evolution step 916: f(x)= 0.33395807282088824
# differential_evolution step 917: f(x)= 0.3334967960307674
# differential_evolution step 918: f(x)= 0.3334967960307674
# differential_evolution step 919: f(x)= 0.3334967960307674
# differential_evolution step 920: f(x)= 0.3334967960307674
# differential_evolution step 921: f(x)= 0.3334967960307674
# differential_evolution step 922: f(x)= 0.3334967960307674
# differential_evolution step 923: f(x)= 0.3334967960307674
# differential_evolution step 924: f(x)= 0.3334967960307674
# differential_evolution step 925: f(x)= 0.3334967960307674
# differential_evolution step 926: f(x)= 0.33291573239046773
# differential_evolution step 927: f(x)= 0.33291573239046773
# differential_evolution step 928: f(x)= 0.33291573239046773
# differential_evolution step 929: f(x)= 0.33291573239046773
# differential_evolution step 930: f(x)= 0.33291573239046773
# differential_evolution step 931: f(x)= 0.33291573239046773
# differential_evolution step 932: f(x)= 0.33291573239046773
# differential_evolution step 933: f(x)= 0.33291573239046773
# differential_evolution step 934: f(x)= 0.33291573239046773
# differential_evolution step 935: f(x)= 0.33291573239046773
# differential_evolution step 936: f(x)= 0.33291573239046773
# differential_evolution step 937: f(x)= 0.33291573239046773
# differential_evolution step 938: f(x)= 0.33291573239046773
# differential_evolution step 939: f(x)= 0.33291573239046773
# differential_evolution step 940: f(x)= 0.33291573239046773
# differential_evolution step 941: f(x)= 0.33291573239046773
# differential_evolution step 942: f(x)= 0.33291573239046773
# differential_evolution step 943: f(x)= 0.33291573239046773
# differential_evolution step 944: f(x)= 0.33291573239046773
# differential_evolution step 945: f(x)= 0.33291573239046773
# differential_evolution step 946: f(x)= 0.33291573239046773
# differential_evolution step 947: f(x)= 0.33291573239046773
# differential_evolution step 948: f(x)= 0.33291573239046773
# differential_evolution step 949: f(x)= 0.33291573239046773
# differential_evolution step 950: f(x)= 0.33291573239046773
# differential_evolution step 951: f(x)= 0.33291573239046773
# differential_evolution step 952: f(x)= 0.33291573239046773
# differential_evolution step 953: f(x)= 0.33291573239046773
# differential_evolution step 954: f(x)= 0.33291573239046773
# differential_evolution step 955: f(x)= 0.33291573239046773
# differential_evolution step 956: f(x)= 0.33291573239046773
# differential_evolution step 957: f(x)= 0.33291573239046773
# differential_evolution step 958: f(x)= 0.33291573239046773
# differential_evolution step 959: f(x)= 0.33291573239046773
# differential_evolution step 960: f(x)= 0.33291573239046773
# differential_evolution step 961: f(x)= 0.33291573239046773
# differential_evolution step 962: f(x)= 0.33291573239046773
# differential_evolution step 963: f(x)= 0.33291573239046773
# differential_evolution step 964: f(x)= 0.33291573239046773
# differential_evolution step 965: f(x)= 0.33291573239046773
# differential_evolution step 966: f(x)= 0.33291573239046773
# differential_evolution step 967: f(x)= 0.3313010509064135
# differential_evolution step 968: f(x)= 0.3313010509064135
# differential_evolution step 969: f(x)= 0.3313010509064135
# differential_evolution step 970: f(x)= 0.3313010509064135
# differential_evolution step 971: f(x)= 0.3313010509064135
# differential_evolution step 972: f(x)= 0.3313010509064135
# differential_evolution step 973: f(x)= 0.3313010509064135
# differential_evolution step 974: f(x)= 0.3313010509064135
# differential_evolution step 975: f(x)= 0.3313010509064135
# differential_evolution step 976: f(x)= 0.32992841647824744
# differential_evolution step 977: f(x)= 0.32992841647824744
# differential_evolution step 978: f(x)= 0.32992841647824744
# differential_evolution step 979: f(x)= 0.32992841647824744
# differential_evolution step 980: f(x)= 0.32992841647824744
# differential_evolution step 981: f(x)= 0.32992841647824744
# differential_evolution step 982: f(x)= 0.32992841647824744
# differential_evolution step 983: f(x)= 0.32992841647824744
# differential_evolution step 984: f(x)= 0.32992841647824744
# differential_evolution step 985: f(x)= 0.32992841647824744
# differential_evolution step 986: f(x)= 0.32992841647824744
# differential_evolution step 987: f(x)= 0.32992841647824744
# differential_evolution step 988: f(x)= 0.32992841647824744
# differential_evolution step 989: f(x)= 0.32992841647824744
# differential_evolution step 990: f(x)= 0.32992841647824744
# differential_evolution step 991: f(x)= 0.32992841647824744
# differential_evolution step 992: f(x)= 0.32992841647824744
# differential_evolution step 993: f(x)= 0.32992841647824744
# differential_evolution step 994: f(x)= 0.32992841647824744
# differential_evolution step 995: f(x)= 0.32992841647824744
# differential_evolution step 996: f(x)= 0.32992841647824744
# differential_evolution step 997: f(x)= 0.32992841647824744
# differential_evolution step 998: f(x)= 0.32992841647824744
# differential_evolution step 999: f(x)= 0.3290642944207282
# differential_evolution step 1000: f(x)= 0.3290642944207282
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.3399, r_e=3.8676, n=1.3171, x_0=34.0449
# Sérsic 2: I_e=0.8079, r_e=8.2262, n=1.3864, x_0=48.0222
# Sérsic 3: I_e=1.2003, r_e=1.5350, n=0.1404, x_0=54.1241
# Sérsic 4: I_e=0.0194, r_e=49.0467, n=2.1173, x_0=67.1388
# Chi quadro minimo: 0.3229473397786803
# False

# %%
save_params_diff(best_params, radial_profile_HA, real_errors_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha_diff", output_prefix="fit")

plot_diff(x_axes, best_params, radial_profile_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_diff')
# Out:
# Sérsic 1: I_e=0.3399, r_e=3.8676, n=1.3171, x_0=34.0449
# Sérsic 2: I_e=0.8079, r_e=8.2262, n=1.3864, x_0=48.0222
# Sérsic 3: I_e=1.2003, r_e=1.5350, n=0.1404, x_0=54.1241
# Sérsic 4: I_e=0.0194, r_e=49.0467, n=2.1173, x_0=67.1388
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#lower_bounds, upper_bounds = zip(*bounds)
#bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HA, covariance_HA = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes, radial_profile_HA, p0=result.x, 
                                           sigma = real_errors_HA)#, bounds = bounds_list, maxfev= 10000)

print("Optimize parameters with curve fit:")

chi2_reduced_HA, dof_HA, chi2_HA = save_params(params_curve_HA, covariance_HA, radial_profile_HA, real_errors_HA, sigmas[0],
    x_axes, n_component, line_name="Halpha", output_prefix="fit")
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_4612\568277273.py:11: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_4612\568277273.py:24: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.3798, r_e=3.1140, n=1.2682, x_0=34.0566
# Sérsic 2: I_e=0.4419, r_e=12.2571, n=1.8282, x_0=47.8854
# Sérsic 3: I_e=0.7651, r_e=1.9739, n=0.5429, x_0=53.8421
# Sérsic 4: I_e=0.0075, r_e=72.4043, n=2.7278, x_0=67.2779
# [9.50437395e-02 5.24409835e-01 1.99822231e-01 5.45329555e-02
#  6.29772774e-02 1.31376902e+00 1.06545945e-01 6.56015113e-02
#  1.60649426e-01 2.40728815e-01 1.64845370e-01 1.39679372e-01
#  5.79351357e-03 4.91884603e+01 5.29514935e-01 1.58086603e-01]
# 1.08342220424617

# %%
plot_curve(x_axes, params_curve_HA, radial_profile_HA, real_errors_HA, sigmas[0], r"Radial profile H$\alpha$")
plt.savefig('Radial_profile_Halpha_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fit_HA = pd.read_csv("Halpha_fit.csv", index_col=0)
x_0_HA = fit_HA.iloc[3].values
bounds =  [
    (0, 5),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 10),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-(seeing[-1]/2), x_0_HA[0]+(seeing[-1]/2)),   # x_0: posizione da 0 a 100

    (0, 5),
    (0, 50),
    (0.1, 10),
    (x_0_HA[1]-(seeing[-1]/2), x_0_HA[1]+(seeing[-1]/2)),

    (0, 5),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-(seeing[-1]/2), x_0_HA[2]+(seeing[-1]/2)),

    (0, 5),
    (0, 50),
    (0.1, 10),
    (x_0_HA[3]-(seeing[-1]/2), x_0_HA[3]+(seeing[-1]/2))
]

# %% [markdown]
# ## H$\beta$

# %%
mask_HB = (wv > l_HB-8)*(wv < l_HB+8)
image_HB = image_cut[:, mask_HB] 
image_error_HB = image_error_cut[:, mask_HB]
radial_profile_HB = np.sum(image_HB, axis = 1)
radial_profile_error_HB = np.sqrt(np.sum(image_error_HB**2, axis = 1))
real_errors_HB = np.sqrt(radial_profile_error_HB**2+(sky_err[2])**2+(0.04*radial_profile_HB)**2)

plt.figure(figsize=(10, 6))
x_axes = np.arange(0, 100, 1)
plt.plot(x_axes, radial_profile_HB)
plt.plot(x_axes, radial_profile_error_HB)
plt.plot(x_axes, radial_profile_HA)
plt.title(r'H$\beta$')
# Out:
# Text(0.5, 1.0, 'H$\\beta$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 10),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (27, 29),   # x_0: circa la posizione di Halpha

    (0, 5),
    (0, 3),
    (0.1, 10),
    (48, 50),

    (0, 5),
    (0, 3),
    (0.1, 10),
    (51, 53),

    (0, 20),
    (0, 7),
    (0.1, 10),
    (59, 61),

    (0, 20),
    (0, 5),
    (0.1, 10),
    (71, 73),
]

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HB, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 16.189296916463356
# differential_evolution step 2: f(x)= 16.189296916463356
# differential_evolution step 3: f(x)= 16.189296916463356
# differential_evolution step 4: f(x)= 16.189296916463356
# differential_evolution step 5: f(x)= 16.189296916463356
# differential_evolution step 6: f(x)= 16.189296916463356
# differential_evolution step 7: f(x)= 16.189296916463356
# differential_evolution step 8: f(x)= 16.189296916463356
# differential_evolution step 9: f(x)= 16.189296916463356
# differential_evolution step 10: f(x)= 16.189296916463356
# differential_evolution step 11: f(x)= 16.189296916463356
# differential_evolution step 12: f(x)= 16.189296916463356
# differential_evolution step 13: f(x)= 16.189296916463356
# differential_evolution step 14: f(x)= 16.189296916463356
# differential_evolution step 15: f(x)= 16.078417281445393
# differential_evolution step 16: f(x)= 16.078417281445393
# differential_evolution step 17: f(x)= 16.078417281445393
# differential_evolution step 18: f(x)= 16.078417281445393
# differential_evolution step 19: f(x)= 16.078417281445393
# differential_evolution step 20: f(x)= 14.619932149300752
# differential_evolution step 21: f(x)= 14.619932149300752
# differential_evolution step 22: f(x)= 14.137528228633059
# differential_evolution step 23: f(x)= 13.642579034104235
# differential_evolution step 24: f(x)= 13.642579034104235
# differential_evolution step 25: f(x)= 10.738200858145523
# differential_evolution step 26: f(x)= 10.738200858145523
# differential_evolution step 27: f(x)= 10.738200858145523
# differential_evolution step 28: f(x)= 9.29475795645879
# differential_evolution step 29: f(x)= 9.29475795645879
# differential_evolution step 30: f(x)= 7.775603963879573
# differential_evolution step 31: f(x)= 7.775603963879573
# differential_evolution step 32: f(x)= 7.775603963879573
# differential_evolution step 33: f(x)= 7.775603963879573
# differential_evolution step 34: f(x)= 7.775603963879573
# differential_evolution step 35: f(x)= 5.189200406136822
# differential_evolution step 36: f(x)= 5.189200406136822
# differential_evolution step 37: f(x)= 5.189200406136822
# differential_evolution step 38: f(x)= 5.189200406136822
# differential_evolution step 39: f(x)= 5.189200406136822
# differential_evolution step 40: f(x)= 5.189200406136822
# differential_evolution step 41: f(x)= 5.189200406136822
# differential_evolution step 42: f(x)= 5.189200406136822
# differential_evolution step 43: f(x)= 5.189200406136822
# differential_evolution step 44: f(x)= 5.189200406136822
# differential_evolution step 45: f(x)= 5.189200406136822
# differential_evolution step 46: f(x)= 5.189200406136822
# differential_evolution step 47: f(x)= 5.189200406136822
# differential_evolution step 48: f(x)= 5.189200406136822
# differential_evolution step 49: f(x)= 5.189200406136822
# differential_evolution step 50: f(x)= 5.189200406136822
# differential_evolution step 51: f(x)= 4.737641182608777
# differential_evolution step 52: f(x)= 4.737641182608777
# differential_evolution step 53: f(x)= 4.737641182608777
# differential_evolution step 54: f(x)= 4.737641182608777
# differential_evolution step 55: f(x)= 4.737641182608777
# differential_evolution step 56: f(x)= 4.737641182608777
# differential_evolution step 57: f(x)= 4.737641182608777
# differential_evolution step 58: f(x)= 4.737641182608777
# differential_evolution step 59: f(x)= 3.991315070986434
# differential_evolution step 60: f(x)= 3.991315070986434
# differential_evolution step 61: f(x)= 3.991315070986434
# differential_evolution step 62: f(x)= 3.6739036046417612
# differential_evolution step 63: f(x)= 3.6739036046417612
# differential_evolution step 64: f(x)= 3.6739036046417612
# differential_evolution step 65: f(x)= 3.6739036046417612
# differential_evolution step 66: f(x)= 3.6739036046417612
# differential_evolution step 67: f(x)= 3.6739036046417612
# differential_evolution step 68: f(x)= 3.6739036046417612
# differential_evolution step 69: f(x)= 3.6739036046417612
# differential_evolution step 70: f(x)= 3.6739036046417612
# differential_evolution step 71: f(x)= 3.6739036046417612
# differential_evolution step 72: f(x)= 3.6739036046417612
# differential_evolution step 73: f(x)= 3.0106268666971645
# differential_evolution step 74: f(x)= 3.0106268666971645
# differential_evolution step 75: f(x)= 2.8459146681418543
# differential_evolution step 76: f(x)= 2.824809050326766
# differential_evolution step 77: f(x)= 2.824809050326766
# differential_evolution step 78: f(x)= 2.824809050326766
# differential_evolution step 79: f(x)= 2.824809050326766
# differential_evolution step 80: f(x)= 2.824809050326766
# differential_evolution step 81: f(x)= 2.824809050326766
# differential_evolution step 82: f(x)= 2.824809050326766
# differential_evolution step 83: f(x)= 2.638976490009824
# differential_evolution step 84: f(x)= 2.638976490009824
# differential_evolution step 85: f(x)= 2.638976490009824
# differential_evolution step 86: f(x)= 2.638976490009824
# differential_evolution step 87: f(x)= 2.638976490009824
# differential_evolution step 88: f(x)= 2.580361847280143
# differential_evolution step 89: f(x)= 2.580361847280143
# differential_evolution step 90: f(x)= 2.580361847280143
# differential_evolution step 91: f(x)= 2.580361847280143
# differential_evolution step 92: f(x)= 2.580361847280143
# differential_evolution step 93: f(x)= 2.580361847280143
# differential_evolution step 94: f(x)= 2.580361847280143
# differential_evolution step 95: f(x)= 2.580361847280143
# differential_evolution step 96: f(x)= 2.580361847280143
# differential_evolution step 97: f(x)= 2.580361847280143
# differential_evolution step 98: f(x)= 2.580361847280143
# differential_evolution step 99: f(x)= 2.580361847280143
# differential_evolution step 100: f(x)= 2.543551901215939
# differential_evolution step 101: f(x)= 2.2161637820966607
# differential_evolution step 102: f(x)= 2.2161637820966607
# differential_evolution step 103: f(x)= 2.2161637820966607
# differential_evolution step 104: f(x)= 2.2161637820966607
# differential_evolution step 105: f(x)= 2.2161637820966607
# differential_evolution step 106: f(x)= 2.2161637820966607
# differential_evolution step 107: f(x)= 2.2161637820966607
# differential_evolution step 108: f(x)= 2.2161637820966607
# differential_evolution step 109: f(x)= 2.2161637820966607
# differential_evolution step 110: f(x)= 2.1901445703673166
# differential_evolution step 111: f(x)= 2.0759433692406435
# differential_evolution step 112: f(x)= 2.0759433692406435
# differential_evolution step 113: f(x)= 2.0759433692406435
# differential_evolution step 114: f(x)= 2.0759433692406435
# differential_evolution step 115: f(x)= 2.0759433692406435
# differential_evolution step 116: f(x)= 2.0497941212494415
# differential_evolution step 117: f(x)= 2.0497941212494415
# differential_evolution step 118: f(x)= 2.0497941212494415
# differential_evolution step 119: f(x)= 2.0497941212494415
# differential_evolution step 120: f(x)= 2.0497941212494415
# differential_evolution step 121: f(x)= 2.0497941212494415
# differential_evolution step 122: f(x)= 2.0497941212494415
# differential_evolution step 123: f(x)= 2.0497941212494415
# differential_evolution step 124: f(x)= 1.9620280836469977
# differential_evolution step 125: f(x)= 1.8520802898737831
# differential_evolution step 126: f(x)= 1.8520802898737831
# differential_evolution step 127: f(x)= 1.8520802898737831
# differential_evolution step 128: f(x)= 1.8520802898737831
# differential_evolution step 129: f(x)= 1.8520802898737831
# differential_evolution step 130: f(x)= 1.8520802898737831
# differential_evolution step 131: f(x)= 1.8520802898737831
# differential_evolution step 132: f(x)= 1.8520802898737831
# differential_evolution step 133: f(x)= 1.7078455194477655
# differential_evolution step 134: f(x)= 1.7078455194477655
# differential_evolution step 135: f(x)= 1.703582327871087
# differential_evolution step 136: f(x)= 1.6733377548907564
# differential_evolution step 137: f(x)= 1.6733377548907564
# differential_evolution step 138: f(x)= 1.6733377548907564
# differential_evolution step 139: f(x)= 1.6733377548907564
# differential_evolution step 140: f(x)= 1.6733377548907564
# differential_evolution step 141: f(x)= 1.6188816499108973
# differential_evolution step 142: f(x)= 1.6188816499108973
# differential_evolution step 143: f(x)= 1.6188816499108973
# differential_evolution step 144: f(x)= 1.6188816499108973
# differential_evolution step 145: f(x)= 1.6188816499108973
# differential_evolution step 146: f(x)= 1.6188816499108973
# differential_evolution step 147: f(x)= 1.6188816499108973
# differential_evolution step 148: f(x)= 1.6161408825793873
# differential_evolution step 149: f(x)= 1.564152175987948
# differential_evolution step 150: f(x)= 1.564152175987948
# differential_evolution step 151: f(x)= 1.564152175987948
# differential_evolution step 152: f(x)= 1.564152175987948
# differential_evolution step 153: f(x)= 1.564152175987948
# differential_evolution step 154: f(x)= 1.546692573609109
# differential_evolution step 155: f(x)= 1.546692573609109
# differential_evolution step 156: f(x)= 1.5083913931043091
# differential_evolution step 157: f(x)= 1.503473391556855
# differential_evolution step 158: f(x)= 1.503473391556855
# differential_evolution step 159: f(x)= 1.503473391556855
# differential_evolution step 160: f(x)= 1.503473391556855
# differential_evolution step 161: f(x)= 1.503473391556855
# differential_evolution step 162: f(x)= 1.503473391556855
# differential_evolution step 163: f(x)= 1.503473391556855
# differential_evolution step 164: f(x)= 1.503473391556855
# differential_evolution step 165: f(x)= 1.4597115332590402
# differential_evolution step 166: f(x)= 1.4597115332590402
# differential_evolution step 167: f(x)= 1.4597115332590402
# differential_evolution step 168: f(x)= 1.4597115332590402
# differential_evolution step 169: f(x)= 1.4597115332590402
# differential_evolution step 170: f(x)= 1.4597115332590402
# differential_evolution step 171: f(x)= 1.4597115332590402
# differential_evolution step 172: f(x)= 1.4345261102705698
# differential_evolution step 173: f(x)= 1.4345261102705698
# differential_evolution step 174: f(x)= 1.4249031573358821
# differential_evolution step 175: f(x)= 1.4249031573358821
# differential_evolution step 176: f(x)= 1.415249717493855
# differential_evolution step 177: f(x)= 1.397099779288996
# differential_evolution step 178: f(x)= 1.397099779288996
# differential_evolution step 179: f(x)= 1.397099779288996
# differential_evolution step 180: f(x)= 1.397099779288996
# differential_evolution step 181: f(x)= 1.397099779288996
# differential_evolution step 182: f(x)= 1.397099779288996
# differential_evolution step 183: f(x)= 1.3934932612701063
# differential_evolution step 184: f(x)= 1.3934932612701063
# differential_evolution step 185: f(x)= 1.3934932612701063
# differential_evolution step 186: f(x)= 1.3934932612701063
# differential_evolution step 187: f(x)= 1.3894016942285545
# differential_evolution step 188: f(x)= 1.3860410923034705
# differential_evolution step 189: f(x)= 1.3860410923034705
# differential_evolution step 190: f(x)= 1.3860410923034705
# differential_evolution step 191: f(x)= 1.3860410923034705
# differential_evolution step 192: f(x)= 1.3807177242669362
# differential_evolution step 193: f(x)= 1.3807177242669362
# differential_evolution step 194: f(x)= 1.3807177242669362
# differential_evolution step 195: f(x)= 1.3798439488562684
# differential_evolution step 196: f(x)= 1.3798439488562684
# differential_evolution step 197: f(x)= 1.368634387131795
# differential_evolution step 198: f(x)= 1.368634387131795
# differential_evolution step 199: f(x)= 1.368634387131795
# differential_evolution step 200: f(x)= 1.368634387131795
# differential_evolution step 201: f(x)= 1.368634387131795
# differential_evolution step 202: f(x)= 1.368634387131795
# differential_evolution step 203: f(x)= 1.368634387131795
# differential_evolution step 204: f(x)= 1.368634387131795
# differential_evolution step 205: f(x)= 1.368634387131795
# differential_evolution step 206: f(x)= 1.368634387131795
# differential_evolution step 207: f(x)= 1.3533087732631535
# differential_evolution step 208: f(x)= 1.3533087732631535
# differential_evolution step 209: f(x)= 1.3533087732631535
# differential_evolution step 210: f(x)= 1.3533087732631535
# differential_evolution step 211: f(x)= 1.3533087732631535
# differential_evolution step 212: f(x)= 1.3533087732631535
# differential_evolution step 213: f(x)= 1.3533087732631535
# differential_evolution step 214: f(x)= 1.3533087732631535
# differential_evolution step 215: f(x)= 1.3533087732631535
# differential_evolution step 216: f(x)= 1.3533087732631535
# differential_evolution step 217: f(x)= 1.3533087732631535
# differential_evolution step 218: f(x)= 1.3533087732631535
# differential_evolution step 219: f(x)= 1.3533087732631535
# differential_evolution step 220: f(x)= 1.3533087732631535
# differential_evolution step 221: f(x)= 1.3533087732631535
# differential_evolution step 222: f(x)= 1.3434164869471243
# differential_evolution step 223: f(x)= 1.3434164869471243
# differential_evolution step 224: f(x)= 1.3434164869471243
# differential_evolution step 225: f(x)= 1.3434164869471243
# differential_evolution step 226: f(x)= 1.3412672909101566
# differential_evolution step 227: f(x)= 1.3412672909101566
# differential_evolution step 228: f(x)= 1.3412672909101566
# differential_evolution step 229: f(x)= 1.33421926662266
# differential_evolution step 230: f(x)= 1.33421926662266
# differential_evolution step 231: f(x)= 1.33421926662266
# differential_evolution step 232: f(x)= 1.33421926662266
# differential_evolution step 233: f(x)= 1.33421926662266
# differential_evolution step 234: f(x)= 1.33421926662266
# differential_evolution step 235: f(x)= 1.33421926662266
# differential_evolution step 236: f(x)= 1.33421926662266
# differential_evolution step 237: f(x)= 1.33421926662266
# differential_evolution step 238: f(x)= 1.33421926662266
# differential_evolution step 239: f(x)= 1.3294037913234555
# differential_evolution step 240: f(x)= 1.321923941682287
# differential_evolution step 241: f(x)= 1.321923941682287
# differential_evolution step 242: f(x)= 1.3201706518797593
# differential_evolution step 243: f(x)= 1.3201706518797593
# differential_evolution step 244: f(x)= 1.3201706518797593
# differential_evolution step 245: f(x)= 1.3201706518797593
# differential_evolution step 246: f(x)= 1.3201706518797593
# differential_evolution step 247: f(x)= 1.3201706518797593
# differential_evolution step 248: f(x)= 1.3189815294440033
# differential_evolution step 249: f(x)= 1.3189815294440033
# differential_evolution step 250: f(x)= 1.3162970649570866
# differential_evolution step 251: f(x)= 1.3162970649570866
# differential_evolution step 252: f(x)= 1.3162970649570866
# differential_evolution step 253: f(x)= 1.3162970649570866
# differential_evolution step 254: f(x)= 1.3161153725664179
# differential_evolution step 255: f(x)= 1.3161153725664179
# differential_evolution step 256: f(x)= 1.3161153725664179
# differential_evolution step 257: f(x)= 1.3161153725664179
# differential_evolution step 258: f(x)= 1.3151917373987645
# differential_evolution step 259: f(x)= 1.3151917373987645
# differential_evolution step 260: f(x)= 1.3151917373987645
# differential_evolution step 261: f(x)= 1.3150135316896678
# differential_evolution step 262: f(x)= 1.3150135316896678
# differential_evolution step 263: f(x)= 1.3133923031055812
# differential_evolution step 264: f(x)= 1.311037267410126
# differential_evolution step 265: f(x)= 1.311037267410126
# differential_evolution step 266: f(x)= 1.311037267410126
# differential_evolution step 267: f(x)= 1.3091980081665098
# differential_evolution step 268: f(x)= 1.3091980081665098
# differential_evolution step 269: f(x)= 1.3091980081665098
# differential_evolution step 270: f(x)= 1.3091980081665098
# differential_evolution step 271: f(x)= 1.3091980081665098
# differential_evolution step 272: f(x)= 1.3091980081665098
# differential_evolution step 273: f(x)= 1.3091980081665098
# differential_evolution step 274: f(x)= 1.3086562942745255
# differential_evolution step 275: f(x)= 1.3086562942745255
# differential_evolution step 276: f(x)= 1.3086562942745255
# differential_evolution step 277: f(x)= 1.3074745246174269
# differential_evolution step 278: f(x)= 1.3074745246174269
# differential_evolution step 279: f(x)= 1.3074745246174269
# differential_evolution step 280: f(x)= 1.3074745246174269
# differential_evolution step 281: f(x)= 1.3074745246174269
# differential_evolution step 282: f(x)= 1.3052674601305214
# differential_evolution step 283: f(x)= 1.3052674601305214
# differential_evolution step 284: f(x)= 1.3052674601305214
# differential_evolution step 285: f(x)= 1.3043421656188108
# differential_evolution step 286: f(x)= 1.3043421656188108
# differential_evolution step 287: f(x)= 1.3043421656188108
# differential_evolution step 288: f(x)= 1.3043421656188108
# differential_evolution step 289: f(x)= 1.3043421656188108
# differential_evolution step 290: f(x)= 1.3043421656188108
# differential_evolution step 291: f(x)= 1.3043421656188108
# differential_evolution step 292: f(x)= 1.3043421656188108
# differential_evolution step 293: f(x)= 1.3043421656188108
# differential_evolution step 294: f(x)= 1.3043421656188108
# differential_evolution step 295: f(x)= 1.3043421656188108
# differential_evolution step 296: f(x)= 1.3029282122963706
# differential_evolution step 297: f(x)= 1.3029282122963706
# differential_evolution step 298: f(x)= 1.3029282122963706
# differential_evolution step 299: f(x)= 1.3029282122963706
# differential_evolution step 300: f(x)= 1.3029282122963706
# differential_evolution step 301: f(x)= 1.3029282122963706
# differential_evolution step 302: f(x)= 1.3029282122963706
# differential_evolution step 303: f(x)= 1.3029282122963706
# differential_evolution step 304: f(x)= 1.3029282122963706
# differential_evolution step 305: f(x)= 1.3029282122963706
# differential_evolution step 306: f(x)= 1.3029282122963706
# differential_evolution step 307: f(x)= 1.3029282122963706
# differential_evolution step 308: f(x)= 1.3029282122963706
# differential_evolution step 309: f(x)= 1.3029282122963706
# differential_evolution step 310: f(x)= 1.3029282122963706
# differential_evolution step 311: f(x)= 1.3017174752394756
# differential_evolution step 312: f(x)= 1.3017174752394756
# differential_evolution step 313: f(x)= 1.3017174752394756
# differential_evolution step 314: f(x)= 1.3017174752394756
# differential_evolution step 315: f(x)= 1.3017174752394756
# differential_evolution step 316: f(x)= 1.3017174752394756
# differential_evolution step 317: f(x)= 1.3017174752394756
# differential_evolution step 318: f(x)= 1.3017174752394756
# differential_evolution step 319: f(x)= 1.3017174752394756
# differential_evolution step 320: f(x)= 1.3017174752394756
# differential_evolution step 321: f(x)= 1.3017174752394756
# differential_evolution step 322: f(x)= 1.301450522715137
# differential_evolution step 323: f(x)= 1.301450522715137
# differential_evolution step 324: f(x)= 1.3011313981669173
# differential_evolution step 325: f(x)= 1.3011313981669173
# differential_evolution step 326: f(x)= 1.3011313981669173
# differential_evolution step 327: f(x)= 1.3011313981669173
# differential_evolution step 328: f(x)= 1.3011313981669173
# differential_evolution step 329: f(x)= 1.3011313981669173
# differential_evolution step 330: f(x)= 1.3011313981669173
# differential_evolution step 331: f(x)= 1.3011313981669173
# differential_evolution step 332: f(x)= 1.3011313981669173
# differential_evolution step 333: f(x)= 1.3010751070091102
# differential_evolution step 334: f(x)= 1.299927802058629
# differential_evolution step 335: f(x)= 1.299927802058629
# differential_evolution step 336: f(x)= 1.299927802058629
# differential_evolution step 337: f(x)= 1.299927802058629
# differential_evolution step 338: f(x)= 1.299927802058629
# differential_evolution step 339: f(x)= 1.299927802058629
# differential_evolution step 340: f(x)= 1.299927802058629
# differential_evolution step 341: f(x)= 1.299927802058629
# differential_evolution step 342: f(x)= 1.299927802058629
# differential_evolution step 343: f(x)= 1.299927802058629
# differential_evolution step 344: f(x)= 1.299927802058629
# differential_evolution step 345: f(x)= 1.299927802058629
# differential_evolution step 346: f(x)= 1.299927802058629
# differential_evolution step 347: f(x)= 1.299927802058629
# differential_evolution step 348: f(x)= 1.299927802058629
# differential_evolution step 349: f(x)= 1.299927802058629
# differential_evolution step 350: f(x)= 1.299927802058629
# differential_evolution step 351: f(x)= 1.299927802058629
# differential_evolution step 352: f(x)= 1.299927802058629
# differential_evolution step 353: f(x)= 1.299927802058629
# differential_evolution step 354: f(x)= 1.299927802058629
# differential_evolution step 355: f(x)= 1.299927802058629
# differential_evolution step 356: f(x)= 1.299927802058629
# differential_evolution step 357: f(x)= 1.299927802058629
# differential_evolution step 358: f(x)= 1.299927802058629
# differential_evolution step 359: f(x)= 1.299927802058629
# differential_evolution step 360: f(x)= 1.299927802058629
# differential_evolution step 361: f(x)= 1.299927802058629
# differential_evolution step 362: f(x)= 1.299927802058629
# differential_evolution step 363: f(x)= 1.299927802058629
# differential_evolution step 364: f(x)= 1.299927802058629
# differential_evolution step 365: f(x)= 1.299927802058629
# differential_evolution step 366: f(x)= 1.299927802058629
# differential_evolution step 367: f(x)= 1.299927802058629
# differential_evolution step 368: f(x)= 1.299927802058629
# differential_evolution step 369: f(x)= 1.299927802058629
# differential_evolution step 370: f(x)= 1.299927802058629
# differential_evolution step 371: f(x)= 1.299927802058629
# differential_evolution step 372: f(x)= 1.299927802058629
# differential_evolution step 373: f(x)= 1.299927802058629
# differential_evolution step 374: f(x)= 1.299927802058629
# differential_evolution step 375: f(x)= 1.299927802058629
# differential_evolution step 376: f(x)= 1.299927802058629
# differential_evolution step 377: f(x)= 1.299927802058629
# differential_evolution step 378: f(x)= 1.299927802058629
# differential_evolution step 379: f(x)= 1.299927802058629
# differential_evolution step 380: f(x)= 1.299927802058629
# differential_evolution step 381: f(x)= 1.299927802058629
# differential_evolution step 382: f(x)= 1.299927802058629
# differential_evolution step 383: f(x)= 1.299927802058629
# differential_evolution step 384: f(x)= 1.299927802058629
# differential_evolution step 385: f(x)= 1.299927802058629
# differential_evolution step 386: f(x)= 1.299927802058629
# differential_evolution step 387: f(x)= 1.299927802058629
# differential_evolution step 388: f(x)= 1.299927802058629
# differential_evolution step 389: f(x)= 1.2996570201570505
# differential_evolution step 390: f(x)= 1.2996570201570505
# differential_evolution step 391: f(x)= 1.2996570201570505
# differential_evolution step 392: f(x)= 1.2996570201570505
# differential_evolution step 393: f(x)= 1.2995557951757626
# differential_evolution step 394: f(x)= 1.2995557951757626
# differential_evolution step 395: f(x)= 1.2995557951757626
# differential_evolution step 396: f(x)= 1.2995557951757626
# differential_evolution step 397: f(x)= 1.2995557951757626
# differential_evolution step 398: f(x)= 1.2995557951757626
# differential_evolution step 399: f(x)= 1.2995557951757626
# differential_evolution step 400: f(x)= 1.2995557951757626
# differential_evolution step 401: f(x)= 1.2995557951757626
# differential_evolution step 402: f(x)= 1.2995557951757626
# differential_evolution step 403: f(x)= 1.2995557951757626
# differential_evolution step 404: f(x)= 1.2995557951757626
# differential_evolution step 405: f(x)= 1.2995557951757626
# differential_evolution step 406: f(x)= 1.2995557951757626
# differential_evolution step 407: f(x)= 1.2995557951757626
# differential_evolution step 408: f(x)= 1.2995557951757626
# differential_evolution step 409: f(x)= 1.2995557951757626
# differential_evolution step 410: f(x)= 1.299446943380188
# differential_evolution step 411: f(x)= 1.299446943380188
# differential_evolution step 412: f(x)= 1.299446943380188
# differential_evolution step 413: f(x)= 1.299446943380188
# differential_evolution step 414: f(x)= 1.2993900118773072
# differential_evolution step 415: f(x)= 1.2993900118773072
# differential_evolution step 416: f(x)= 1.2993900118773072
# differential_evolution step 417: f(x)= 1.2993900118773072
# differential_evolution step 418: f(x)= 1.2993900118773072
# differential_evolution step 419: f(x)= 1.2993900118773072
# differential_evolution step 420: f(x)= 1.2993345246666395
# differential_evolution step 421: f(x)= 1.2993345246666395
# differential_evolution step 422: f(x)= 1.2993345246666395
# differential_evolution step 423: f(x)= 1.2993011898615021
# differential_evolution step 424: f(x)= 1.2993011898615021
# differential_evolution step 425: f(x)= 1.299277223561927
# differential_evolution step 426: f(x)= 1.299277223561927
# differential_evolution step 427: f(x)= 1.299277223561927
# differential_evolution step 428: f(x)= 1.2992421726127146
# differential_evolution step 429: f(x)= 1.2992421726127146
# differential_evolution step 430: f(x)= 1.2992421726127146
# differential_evolution step 431: f(x)= 1.2992421726127146
# differential_evolution step 432: f(x)= 1.2992149462277103
# differential_evolution step 433: f(x)= 1.2992149462277103
# differential_evolution step 434: f(x)= 1.2992149462277103
# differential_evolution step 435: f(x)= 1.2992149462277103
# differential_evolution step 436: f(x)= 1.2992149462277103
# differential_evolution step 437: f(x)= 1.2991991276323556
# differential_evolution step 438: f(x)= 1.2991991276323556
# differential_evolution step 439: f(x)= 1.2991991276323556
# differential_evolution step 440: f(x)= 1.2991991276323556
# differential_evolution step 441: f(x)= 1.2991991276323556
# differential_evolution step 442: f(x)= 1.2991991276323556
# differential_evolution step 443: f(x)= 1.2991991276323556
# differential_evolution step 444: f(x)= 1.2991991276323556
# differential_evolution step 445: f(x)= 1.2991781488698988
# differential_evolution step 446: f(x)= 1.2991781488698988
# differential_evolution step 447: f(x)= 1.2991781488698988
# differential_evolution step 448: f(x)= 1.299176254833308
# differential_evolution step 449: f(x)= 1.299176254833308
# differential_evolution step 450: f(x)= 1.299176254833308
# differential_evolution step 451: f(x)= 1.299176254833308
# differential_evolution step 452: f(x)= 1.2991214758270553
# differential_evolution step 453: f(x)= 1.2991192562792253
# differential_evolution step 454: f(x)= 1.2991164754152966
# differential_evolution step 455: f(x)= 1.2991164754152966
# differential_evolution step 456: f(x)= 1.2991164754152966
# differential_evolution step 457: f(x)= 1.2991164754152966
# differential_evolution step 458: f(x)= 1.2990782565299495
# differential_evolution step 459: f(x)= 1.2990782565299495
# differential_evolution step 460: f(x)= 1.2990782565299495
# differential_evolution step 461: f(x)= 1.2990782565299495
# differential_evolution step 462: f(x)= 1.299062576039592
# differential_evolution step 463: f(x)= 1.299062576039592
# differential_evolution step 464: f(x)= 1.299062576039592
# differential_evolution step 465: f(x)= 1.299062576039592
# differential_evolution step 466: f(x)= 1.299062576039592
# differential_evolution step 467: f(x)= 1.299062576039592
# differential_evolution step 468: f(x)= 1.299062576039592
# differential_evolution step 469: f(x)= 1.2990523355703378
# differential_evolution step 470: f(x)= 1.2990523355703378
# differential_evolution step 471: f(x)= 1.2990523355703378
# differential_evolution step 472: f(x)= 1.2990523355703378
# differential_evolution step 473: f(x)= 1.2990523355703378
# differential_evolution step 474: f(x)= 1.2990523355703378
# differential_evolution step 475: f(x)= 1.2990523355703378
# differential_evolution step 476: f(x)= 1.2990483783193607
# differential_evolution step 477: f(x)= 1.2990483783193607
# differential_evolution step 478: f(x)= 1.2990483783193607
# differential_evolution step 479: f(x)= 1.2990483783193607
# differential_evolution step 480: f(x)= 1.2990483783193607
# differential_evolution step 481: f(x)= 1.2990388221330156
# differential_evolution step 482: f(x)= 1.2990388221330156
# differential_evolution step 483: f(x)= 1.2990388221330156
# differential_evolution step 484: f(x)= 1.2990388221330156
# differential_evolution step 485: f(x)= 1.2990388221330156
# differential_evolution step 486: f(x)= 1.2990388221330156
# differential_evolution step 487: f(x)= 1.2990388221330156
# differential_evolution step 488: f(x)= 1.2990388221330156
# differential_evolution step 489: f(x)= 1.2990388221330156
# differential_evolution step 490: f(x)= 1.2990388221330156
# differential_evolution step 491: f(x)= 1.2990388221330156
# differential_evolution step 492: f(x)= 1.2990382169149604
# differential_evolution step 493: f(x)= 1.2990284916417547
# differential_evolution step 494: f(x)= 1.2990284916417547
# differential_evolution step 495: f(x)= 1.2990100779734082
# differential_evolution step 496: f(x)= 1.2990100779734082
# differential_evolution step 497: f(x)= 1.2990100779734082
# differential_evolution step 498: f(x)= 1.2990100779734082
# differential_evolution step 499: f(x)= 1.2990100779734082
# differential_evolution step 500: f(x)= 1.2990100779734082
# differential_evolution step 501: f(x)= 1.2990100779734082
# differential_evolution step 502: f(x)= 1.2990100779734082
# differential_evolution step 503: f(x)= 1.2990100779734082
# differential_evolution step 504: f(x)= 1.2990100779734082
# differential_evolution step 505: f(x)= 1.2990100779734082
# differential_evolution step 506: f(x)= 1.2990100779734082
# differential_evolution step 507: f(x)= 1.2990100779734082
# differential_evolution step 508: f(x)= 1.299008722668082
# differential_evolution step 509: f(x)= 1.299003123215463
# differential_evolution step 510: f(x)= 1.2989996191809918
# differential_evolution step 511: f(x)= 1.2989996191809918
# differential_evolution step 512: f(x)= 1.2989996191809918
# differential_evolution step 513: f(x)= 1.2989996191809918
# differential_evolution step 514: f(x)= 1.2989996191809918
# differential_evolution step 515: f(x)= 1.298998089522288
# differential_evolution step 516: f(x)= 1.298998089522288
# differential_evolution step 517: f(x)= 1.29898966387253
# differential_evolution step 518: f(x)= 1.29898966387253
# differential_evolution step 519: f(x)= 1.29898966387253
# differential_evolution step 520: f(x)= 1.29898966387253
# differential_evolution step 521: f(x)= 1.29898966387253
# differential_evolution step 522: f(x)= 1.29898966387253
# differential_evolution step 523: f(x)= 1.2989846670123857
# differential_evolution step 524: f(x)= 1.2989846670123857
# differential_evolution step 525: f(x)= 1.2989846670123857
# differential_evolution step 526: f(x)= 1.2989846670123857
# differential_evolution step 527: f(x)= 1.2989846670123857
# differential_evolution step 528: f(x)= 1.2989846670123857
# differential_evolution step 529: f(x)= 1.2989846670123857
# differential_evolution step 530: f(x)= 1.2989846670123857
# differential_evolution step 531: f(x)= 1.2989846670123857
# differential_evolution step 532: f(x)= 1.2989818411574572
# differential_evolution step 533: f(x)= 1.2989818411574572
# differential_evolution step 534: f(x)= 1.2989818411574572
# differential_evolution step 535: f(x)= 1.2989818411574572
# differential_evolution step 536: f(x)= 1.2989818411574572
# differential_evolution step 537: f(x)= 1.2989818411574572
# differential_evolution step 538: f(x)= 1.2989818411574572
# differential_evolution step 539: f(x)= 1.2989818411574572
# differential_evolution step 540: f(x)= 1.2989818411574572
# differential_evolution step 541: f(x)= 1.2989818411574572
# differential_evolution step 542: f(x)= 1.2989818411574572
# differential_evolution step 543: f(x)= 1.2989818411574572
# differential_evolution step 544: f(x)= 1.2989818411574572
# differential_evolution step 545: f(x)= 1.2989818411574572
# differential_evolution step 546: f(x)= 1.2989818411574572
# differential_evolution step 547: f(x)= 1.2989818411574572
# differential_evolution step 548: f(x)= 1.2989818411574572
# differential_evolution step 549: f(x)= 1.2989785572304926
# differential_evolution step 550: f(x)= 1.2989785572304926
# differential_evolution step 551: f(x)= 1.2989785572304926
# differential_evolution step 552: f(x)= 1.2989785572304926
# differential_evolution step 553: f(x)= 1.2989785572304926
# differential_evolution step 554: f(x)= 1.2989785572304926
# differential_evolution step 555: f(x)= 1.2989785572304926
# differential_evolution step 556: f(x)= 1.2989785572304926
# differential_evolution step 557: f(x)= 1.2989785572304926
# differential_evolution step 558: f(x)= 1.2989785572304926
# differential_evolution step 559: f(x)= 1.2989785572304926
# differential_evolution step 560: f(x)= 1.2989785572304926
# differential_evolution step 561: f(x)= 1.2989785572304926
# differential_evolution step 562: f(x)= 1.2989785572304926
# differential_evolution step 563: f(x)= 1.2989785572304926
# differential_evolution step 564: f(x)= 1.2989785572304926
# differential_evolution step 565: f(x)= 1.2989741391478016
# differential_evolution step 566: f(x)= 1.2989741391478016
# differential_evolution step 567: f(x)= 1.2989741391478016
# differential_evolution step 568: f(x)= 1.2989741391478016
# differential_evolution step 569: f(x)= 1.2989741391478016
# differential_evolution step 570: f(x)= 1.2989741391478016
# differential_evolution step 571: f(x)= 1.2989741391478016
# differential_evolution step 572: f(x)= 1.2989741391478016
# differential_evolution step 573: f(x)= 1.2989741391478016
# differential_evolution step 574: f(x)= 1.2989741391478016
# differential_evolution step 575: f(x)= 1.2989741297543753
# differential_evolution step 576: f(x)= 1.2989741297543753
# differential_evolution step 577: f(x)= 1.2989741297543753
# differential_evolution step 578: f(x)= 1.2989741297543753
# differential_evolution step 579: f(x)= 1.2989741297543753
# differential_evolution step 580: f(x)= 1.2989735250239307
# differential_evolution step 581: f(x)= 1.2989735250239307
# differential_evolution step 582: f(x)= 1.2989735250239307
# differential_evolution step 583: f(x)= 1.2989732375941805
# differential_evolution step 584: f(x)= 1.2989732375941805
# differential_evolution step 585: f(x)= 1.2989732375941805
# differential_evolution step 586: f(x)= 1.2989732375941805
# differential_evolution step 587: f(x)= 1.2989732375941805
# differential_evolution step 588: f(x)= 1.2989732375941805
# differential_evolution step 589: f(x)= 1.2989688635675307
# differential_evolution step 590: f(x)= 1.2989688635675307
# differential_evolution step 591: f(x)= 1.2989688635675307
# differential_evolution step 592: f(x)= 1.2989688635675307
# differential_evolution step 593: f(x)= 1.2989688635675307
# differential_evolution step 594: f(x)= 1.2989688635675307
# differential_evolution step 595: f(x)= 1.2989688635675307
# differential_evolution step 596: f(x)= 1.298968059113528
# differential_evolution step 597: f(x)= 1.298968059113528
# differential_evolution step 598: f(x)= 1.298968059113528
# differential_evolution step 599: f(x)= 1.2989648507071625
# differential_evolution step 600: f(x)= 1.2989648507071625
# differential_evolution step 601: f(x)= 1.2989648507071625
# differential_evolution step 602: f(x)= 1.2989648507071625
# differential_evolution step 603: f(x)= 1.2989648507071625
# differential_evolution step 604: f(x)= 1.298964273923109
# differential_evolution step 605: f(x)= 1.298964273923109
# differential_evolution step 606: f(x)= 1.298964273923109
# differential_evolution step 607: f(x)= 1.298964273923109
# differential_evolution step 608: f(x)= 1.298964273923109
# differential_evolution step 609: f(x)= 1.298964273923109
# differential_evolution step 610: f(x)= 1.298964273923109
# differential_evolution step 611: f(x)= 1.298964273923109
# differential_evolution step 612: f(x)= 1.298964273923109
# differential_evolution step 613: f(x)= 1.298964273923109
# differential_evolution step 614: f(x)= 1.2989637295980971
# differential_evolution step 615: f(x)= 1.2989637295980971
# differential_evolution step 616: f(x)= 1.2989637295980971
# differential_evolution step 617: f(x)= 1.2989637295980971
# differential_evolution step 618: f(x)= 1.2989637295980971
# differential_evolution step 619: f(x)= 1.2989637295980971
# differential_evolution step 620: f(x)= 1.2989637295980971
# differential_evolution step 621: f(x)= 1.2989636848480561
# differential_evolution step 622: f(x)= 1.2989636848480561
# differential_evolution step 623: f(x)= 1.2989636848480561
# differential_evolution step 624: f(x)= 1.2989636848480561
# differential_evolution step 625: f(x)= 1.2989636848480561
# differential_evolution step 626: f(x)= 1.2989636848480561
# differential_evolution step 627: f(x)= 1.2989636848480561
# differential_evolution step 628: f(x)= 1.2989636848480561
# differential_evolution step 629: f(x)= 1.2989636848480561
# differential_evolution step 630: f(x)= 1.2989636848480561
# differential_evolution step 631: f(x)= 1.2989636308052637
# differential_evolution step 632: f(x)= 1.2989636251022596
# differential_evolution step 633: f(x)= 1.2989636251022596
# differential_evolution step 634: f(x)= 1.2989636251022596
# differential_evolution step 635: f(x)= 1.2989636251022596
# differential_evolution step 636: f(x)= 1.2989636251022596
# differential_evolution step 637: f(x)= 1.2989636251022596
# differential_evolution step 638: f(x)= 1.2989636251022596
# differential_evolution step 639: f(x)= 1.2989636251022596
# differential_evolution step 640: f(x)= 1.2989636251022596
# differential_evolution step 641: f(x)= 1.2989636251022596
# differential_evolution step 642: f(x)= 1.2989636251022596
# differential_evolution step 643: f(x)= 1.2989636251022596
# differential_evolution step 644: f(x)= 1.2989636251022596
# differential_evolution step 645: f(x)= 1.298963624481535
# differential_evolution step 646: f(x)= 1.298963624481535
# differential_evolution step 647: f(x)= 1.298963624481535
# differential_evolution step 648: f(x)= 1.298963624481535
# differential_evolution step 649: f(x)= 1.298961767099568
# differential_evolution step 650: f(x)= 1.298961767099568
# differential_evolution step 651: f(x)= 1.298961767099568
# differential_evolution step 652: f(x)= 1.298961767099568
# differential_evolution step 653: f(x)= 1.298961767099568
# differential_evolution step 654: f(x)= 1.298961767099568
# differential_evolution step 655: f(x)= 1.298961767099568
# differential_evolution step 656: f(x)= 1.2989610743284385
# differential_evolution step 657: f(x)= 1.2989610743284385
# differential_evolution step 658: f(x)= 1.2989610743284385
# differential_evolution step 659: f(x)= 1.2989609681735008
# differential_evolution step 660: f(x)= 1.2989609681735008
# differential_evolution step 661: f(x)= 1.2989609681735008
# differential_evolution step 662: f(x)= 1.2989609681735008
# differential_evolution step 663: f(x)= 1.2989609681735008
# differential_evolution step 664: f(x)= 1.2989608066337148
# differential_evolution step 665: f(x)= 1.2989608066337148
# differential_evolution step 666: f(x)= 1.2989608066337148
# differential_evolution step 667: f(x)= 1.2989608066337148
# differential_evolution step 668: f(x)= 1.2989608066337148
# differential_evolution step 669: f(x)= 1.2989608066337148
# differential_evolution step 670: f(x)= 1.2989606699027147
# differential_evolution step 671: f(x)= 1.2989606699027147
# differential_evolution step 672: f(x)= 1.2989606699027147
# differential_evolution step 673: f(x)= 1.2989606699027147
# differential_evolution step 674: f(x)= 1.2989606699027147
# differential_evolution step 675: f(x)= 1.2989606699027147
# differential_evolution step 676: f(x)= 1.2989606699027147
# differential_evolution step 677: f(x)= 1.2989606699027147
# differential_evolution step 678: f(x)= 1.2989606699027147
# differential_evolution step 679: f(x)= 1.2989606699027147
# differential_evolution step 680: f(x)= 1.2989606699027147
# differential_evolution step 681: f(x)= 1.2989606699027147
# differential_evolution step 682: f(x)= 1.2989606699027147
# differential_evolution step 683: f(x)= 1.2989603213282508
# differential_evolution step 684: f(x)= 1.2989603213282508
# differential_evolution step 685: f(x)= 1.2989601966028277
# differential_evolution step 686: f(x)= 1.2989601966028277
# differential_evolution step 687: f(x)= 1.2989601966028277
# differential_evolution step 688: f(x)= 1.2989601966028277
# differential_evolution step 689: f(x)= 1.2989601966028277
# differential_evolution step 690: f(x)= 1.298960055757823
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.2616, r_e=10.0000, n=0.1934, x_0=29.0000
# Sérsic 2: I_e=0.8233, r_e=3.0000, n=0.9546, x_0=48.0752
# Sérsic 3: I_e=0.5789, r_e=3.0000, n=0.1799, x_0=53.0000
# Sérsic 4: I_e=0.2966, r_e=7.0000, n=0.2192, x_0=61.0000
# Chi quadro minimo: 1.2989581696958257
# True

# %%
save_params_diff(best_params, radial_profile_HB, real_errors_HB, sigmas[1],
    x_axes, n_component, line_name="HBeta", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_diff')
# Out:
# Sérsic 1: I_e=0.2616, r_e=10.0000, n=0.1934, x_0=29.0000
# Sérsic 2: I_e=0.8233, r_e=3.0000, n=0.9546, x_0=48.0752
# Sérsic 3: I_e=0.5789, r_e=3.0000, n=0.1799, x_0=53.0000
# Sérsic 4: I_e=0.2966, r_e=7.0000, n=0.2192, x_0=61.0000
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 10),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (27, 29),   # x_0: circa la posizione di Halpha

    (0, 5),
    (0, 10),
    (0.1, 10),
    (48, 50),

    (0, 5),
    (0, 3),
    (0.1, 10),
    (51, 53),

    (0, 20),
    (0, 10),
    (0.1, 10),
    (59, 61),

    (0, 20),
    (0, 7),
    (0.1, 10),
    (71, 73),
]
#lower_bounds, upper_bounds = zip(*bounds)
#bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_HB, covariance_HB = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), x_axes, radial_profile_HB, p0=result.x, sigma = real_errors_HB)#, bounds = bounds_list, maxfev = 10000)

print("Optimize parameters with curve fit:")
chi2_reduced_HB, dof_HB, chi2_HB = save_params(params_curve_HB, covariance_HB, radial_profile_HB, real_errors_HB, sigmas[1],
    x_axes, n_component, line_name="Hbeta", output_prefix="fit")
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_4612\568277273.py:11: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_4612\568277273.py:24: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.0163, r_e=44.5503, n=2.3221, x_0=35.3518
# Sérsic 2: I_e=0.4042, r_e=5.4300, n=1.4374, x_0=48.4350
# Sérsic 3: I_e=0.3170, r_e=2.8020, n=0.5958, x_0=54.6599
# Sérsic 4: I_e=0.0390, r_e=19.5170, n=1.3224, x_0=66.9276
# [inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf
#  inf inf]
# 0.3362416082749038
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_4612\541453802.py:29: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_curve_HB, covariance_HB = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), x_axes, radial_profile_HB, p0=result.x, sigma = real_errors_HB)#, bounds = bounds_list, maxfev = 10000)

# %%
# Plots:
plot_curve(x_axes, params_curve_HB, radial_profile_HB, real_errors_HB, sigmas[1], r"Radial profile H$\beta$")
plt.savefig('Radial_profile_Hbeta_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [NII]

# %%
mask_NII = (wv > l_NII-8)*(wv < l_NII+8)
image_NII = image_cut[:, mask_NII]
image_error_NII = image_error_cut[:, mask_NII]
radial_profile_NII = np.sum(image_NII, axis = 1)
radial_profile_error_NII = np.sqrt(np.sum(image_error_NII**2, axis = 1))
real_errors_NII = np.sqrt(radial_profile_error_NII**2+(sky_err[2])**2+(0.04*radial_profile_NII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_NII)
plt.plot(x_axes, radial_profile_error_NII)
plt.plot(x_axes, radial_profile_HA)
plt.title(r'[NII]')
# Out:
# Text(0.5, 1.0, '[NII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_NII, sigmas[2])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 2548.3037261142445
# differential_evolution step 2: f(x)= 1124.0743214438996
# differential_evolution step 3: f(x)= 1124.0743214438996
# differential_evolution step 4: f(x)= 616.4609845903091
# differential_evolution step 5: f(x)= 318.3856614766611
# differential_evolution step 6: f(x)= 103.60965355796958
# differential_evolution step 7: f(x)= 103.60965355796958
# differential_evolution step 8: f(x)= 103.60965355796958
# differential_evolution step 9: f(x)= 103.60965355796958
# differential_evolution step 10: f(x)= 103.60965355796958
# differential_evolution step 11: f(x)= 103.60965355796958
# differential_evolution step 12: f(x)= 103.60965355796958
# differential_evolution step 13: f(x)= 103.60965355796958
# differential_evolution step 14: f(x)= 103.60965355796958
# differential_evolution step 15: f(x)= 103.60965355796958
# differential_evolution step 16: f(x)= 103.60965355796958
# differential_evolution step 17: f(x)= 38.35943793171668
# differential_evolution step 18: f(x)= 38.35943793171668
# differential_evolution step 19: f(x)= 38.35943793171668
# differential_evolution step 20: f(x)= 22.313227819838538
# differential_evolution step 21: f(x)= 22.313227819838538
# differential_evolution step 22: f(x)= 22.313227819838538
# differential_evolution step 23: f(x)= 22.313227819838538
# differential_evolution step 24: f(x)= 22.313227819838538
# differential_evolution step 25: f(x)= 22.313227819838538
# differential_evolution step 26: f(x)= 22.313227819838538
# differential_evolution step 27: f(x)= 22.313227819838538
# differential_evolution step 28: f(x)= 18.167601928714298
# differential_evolution step 29: f(x)= 18.167601928714298
# differential_evolution step 30: f(x)= 18.167601928714298
# differential_evolution step 31: f(x)= 18.167601928714298
# differential_evolution step 32: f(x)= 18.167601928714298
# differential_evolution step 33: f(x)= 8.467078208462237
# differential_evolution step 34: f(x)= 8.467078208462237
# differential_evolution step 35: f(x)= 8.467078208462237
# differential_evolution step 36: f(x)= 8.467078208462237
# differential_evolution step 37: f(x)= 8.467078208462237
# differential_evolution step 38: f(x)= 8.467078208462237
# differential_evolution step 39: f(x)= 8.467078208462237
# KeyboardInterrupt

# %%
save_params_diff(best_params, radial_profile_NII, real_errors_NII, sigmas[2],
    x_axes, n_component, line_name="NII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_diff')

# %%
bounds = [
    (0, 1),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 5),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-(seeing[-1]/2), x_0_HA[0]+(seeing[-1]/2)),   # x_0: posizione da 0 a 100

    (0, 1),
    (0, 20),
    (0.1, 10),
    (x_0_HA[1]-(seeing[-1]/2), x_0_HA[1]+(seeing[-1]/2)),

    (0, 1),
    (0, 5),
    (0.1, 10),
    (x_0_HA[2]-(seeing[-1]/2), x_0_HA[2]+(seeing[-1]/2)),

    (0, 1),
    (40, 60),
    (0.1, 10),
    (x_0_HA[3]-(seeing[-1]/2), x_0_HA[3]+(seeing[-1]/2))
]
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_NII, covariance_NII = curve_fit(lambda x, *params: model_convolved(x, sigmas[2], *params), x_axes, radial_profile_NII, 
                                             p0=result.x, sigma = real_errors_NII, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_NII, dof_NII, chi2_NII = save_params(params_curve_NII, covariance_NII, radial_profile_NII, real_errors_NII, sigmas[2],
    x_axes, n_component, line_name="NII", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.0702, r_e=4.9985, n=1.7661, x_0=34.3829
# Sérsic 2: I_e=0.1412, r_e=19.9999, n=2.2425, x_0=47.7924
# Sérsic 3: I_e=0.2799, r_e=2.1406, n=0.5554, x_0=54.0239
# Sérsic 4: I_e=0.0059, r_e=59.1569, n=2.4188, x_0=66.2859
# [4.98449610e-02 2.78364398e+00 5.27918921e-01 7.24555238e-02
#  2.98845392e-02 3.71459101e+00 1.49369588e-01 4.98358635e-02
#  7.76635082e-02 3.71219176e-01 2.09493918e-01 1.64499226e-01
#  5.56935667e-03 5.42533746e+01 6.27106006e-01 2.23640290e-01]
# 0.6360978019109853

# %%
plot_curve(x_axes, params_curve_NII, radial_profile_NII, real_errors_NII, sigmas[2], r"Radial profile [NII]")
plt.savefig('Radial_profile_NII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [SII]

# %%
mask_SII = (wv > l_SII-8)*(wv < l_SII+8)
image_SII = image_cut[:, mask_SII] 
image_error_SII = image_error_cut[:, mask_SII]
radial_profile_SII = np.sum(image_SII, axis = 1)
radial_profile_error_SII = np.sqrt(np.sum(image_error_SII**2, axis = 1))
real_errors_SII = np.sqrt(radial_profile_error_SII**2+(sky_err[2])**2+(0.04*radial_profile_SII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_SII)
plt.plot(x_axes, radial_profile_error_SII)
plt.title(r'[SII]')
# Out:
# Text(0.5, 1.0, '[SII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = [
    (0, 5),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 10),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (x_0_HA[0]-(seeing[-1]/2), x_0_HA[0]+(seeing[-1]/2)),   # x_0: posizione da 0 a 100

    (0, 5),
    (0, 50),
    (0.1, 10),
    (x_0_HA[1]-(seeing[-1]/2), x_0_HA[1]+(seeing[-1]/2)),

    (0, 5),
    (0, 50),
    (0.1, 10),
    (x_0_HA[2]-(seeing[-1]/2), x_0_HA[2]+(seeing[-1]/2)),

    (0, 5),
    (0, 50),
    (0.1, 10),
    (x_0_HA[3]-(seeing[-1]/2), x_0_HA[3]+(seeing[-1]/2))
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_SII, sigmas[3])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 3372.389493811377
# differential_evolution step 2: f(x)= 679.1936591455955
# differential_evolution step 3: f(x)= 510.55201317211163
# differential_evolution step 4: f(x)= 510.55201317211163
# differential_evolution step 5: f(x)= 151.90929354386168
# differential_evolution step 6: f(x)= 79.9756861028566
# differential_evolution step 7: f(x)= 79.9756861028566
# differential_evolution step 8: f(x)= 79.9756861028566
# differential_evolution step 9: f(x)= 79.9756861028566
# differential_evolution step 10: f(x)= 79.9756861028566
# differential_evolution step 11: f(x)= 33.355798897078856
# differential_evolution step 12: f(x)= 10.936075772639885
# differential_evolution step 13: f(x)= 10.936075772639885
# differential_evolution step 14: f(x)= 10.936075772639885
# differential_evolution step 15: f(x)= 10.936075772639885
# differential_evolution step 16: f(x)= 10.936075772639885
# differential_evolution step 17: f(x)= 10.936075772639885
# differential_evolution step 18: f(x)= 10.936075772639885
# differential_evolution step 19: f(x)= 10.936075772639885
# differential_evolution step 20: f(x)= 7.966156067868775
# differential_evolution step 21: f(x)= 7.966156067868775
# differential_evolution step 22: f(x)= 7.966156067868775
# differential_evolution step 23: f(x)= 7.966156067868775
# differential_evolution step 24: f(x)= 7.388156383356441
# differential_evolution step 25: f(x)= 6.71562053430102
# differential_evolution step 26: f(x)= 6.71562053430102
# differential_evolution step 27: f(x)= 5.429075477508132
# differential_evolution step 28: f(x)= 5.429075477508132
# differential_evolution step 29: f(x)= 4.261121898186556
# differential_evolution step 30: f(x)= 4.261121898186556
# differential_evolution step 31: f(x)= 2.471631593884307
# differential_evolution step 32: f(x)= 2.471631593884307
# differential_evolution step 33: f(x)= 2.471631593884307
# differential_evolution step 34: f(x)= 1.8589097780324928
# differential_evolution step 35: f(x)= 1.8589097780324928
# differential_evolution step 36: f(x)= 1.8589097780324928
# differential_evolution step 37: f(x)= 1.8589097780324928
# differential_evolution step 38: f(x)= 1.8589097780324928
# differential_evolution step 39: f(x)= 1.8589097780324928
# differential_evolution step 40: f(x)= 1.8589097780324928
# differential_evolution step 41: f(x)= 1.8589097780324928
# differential_evolution step 42: f(x)= 1.8589097780324928
# differential_evolution step 43: f(x)= 1.8589097780324928
# differential_evolution step 44: f(x)= 1.515496624296652
# differential_evolution step 45: f(x)= 1.515496624296652
# differential_evolution step 46: f(x)= 1.515496624296652
# differential_evolution step 47: f(x)= 1.515496624296652
# differential_evolution step 48: f(x)= 1.515496624296652
# differential_evolution step 49: f(x)= 1.515496624296652
# differential_evolution step 50: f(x)= 1.515496624296652
# differential_evolution step 51: f(x)= 1.515496624296652
# differential_evolution step 52: f(x)= 1.515496624296652
# differential_evolution step 53: f(x)= 1.1746095182284517
# differential_evolution step 54: f(x)= 1.1746095182284517
# differential_evolution step 55: f(x)= 1.1746095182284517
# differential_evolution step 56: f(x)= 1.1746095182284517
# differential_evolution step 57: f(x)= 1.1746095182284517
# differential_evolution step 58: f(x)= 1.1746095182284517
# differential_evolution step 59: f(x)= 1.1746095182284517
# differential_evolution step 60: f(x)= 1.1746095182284517
# differential_evolution step 61: f(x)= 1.1746095182284517
# differential_evolution step 62: f(x)= 1.1746095182284517
# differential_evolution step 63: f(x)= 1.1746095182284517
# differential_evolution step 64: f(x)= 1.1746095182284517
# differential_evolution step 65: f(x)= 1.1746095182284517
# differential_evolution step 66: f(x)= 1.1746095182284517
# differential_evolution step 67: f(x)= 1.1746095182284517
# differential_evolution step 68: f(x)= 1.1746095182284517
# differential_evolution step 69: f(x)= 1.067520097571056
# differential_evolution step 70: f(x)= 0.7460568606655281
# differential_evolution step 71: f(x)= 0.7460568606655281
# differential_evolution step 72: f(x)= 0.7460568606655281
# differential_evolution step 73: f(x)= 0.7254377828642529
# differential_evolution step 74: f(x)= 0.7254377828642529
# differential_evolution step 75: f(x)= 0.7254377828642529
# differential_evolution step 76: f(x)= 0.7254377828642529
# differential_evolution step 77: f(x)= 0.7254377828642529
# differential_evolution step 78: f(x)= 0.7254377828642529
# differential_evolution step 79: f(x)= 0.7254377828642529
# differential_evolution step 80: f(x)= 0.7254377828642529
# differential_evolution step 81: f(x)= 0.7254377828642529
# differential_evolution step 82: f(x)= 0.7254377828642529
# differential_evolution step 83: f(x)= 0.7254377828642529
# differential_evolution step 84: f(x)= 0.7254377828642529
# differential_evolution step 85: f(x)= 0.7254377828642529
# differential_evolution step 86: f(x)= 0.5938498170942645
# differential_evolution step 87: f(x)= 0.5938498170942645
# differential_evolution step 88: f(x)= 0.5938498170942645
# differential_evolution step 89: f(x)= 0.5938498170942645
# differential_evolution step 90: f(x)= 0.5938498170942645
# differential_evolution step 91: f(x)= 0.5938498170942645
# differential_evolution step 92: f(x)= 0.5938498170942645
# differential_evolution step 93: f(x)= 0.5904610680788417
# differential_evolution step 94: f(x)= 0.5904610680788417
# differential_evolution step 95: f(x)= 0.5904610680788417
# differential_evolution step 96: f(x)= 0.5347275505514798
# differential_evolution step 97: f(x)= 0.5347275505514798
# differential_evolution step 98: f(x)= 0.5347275505514798
# differential_evolution step 99: f(x)= 0.5347275505514798
# differential_evolution step 100: f(x)= 0.5347275505514798
# differential_evolution step 101: f(x)= 0.5347275505514798
# differential_evolution step 102: f(x)= 0.5313663281528631
# differential_evolution step 103: f(x)= 0.5313663281528631
# differential_evolution step 104: f(x)= 0.5313663281528631
# differential_evolution step 105: f(x)= 0.5313663281528631
# differential_evolution step 106: f(x)= 0.5155216006192019
# differential_evolution step 107: f(x)= 0.47824526427125763
# differential_evolution step 108: f(x)= 0.45709004846136136
# differential_evolution step 109: f(x)= 0.43994176854891826
# differential_evolution step 110: f(x)= 0.43994176854891826
# differential_evolution step 111: f(x)= 0.43994176854891826
# differential_evolution step 112: f(x)= 0.43994176854891826
# differential_evolution step 113: f(x)= 0.43994176854891826
# differential_evolution step 114: f(x)= 0.43994176854891826
# differential_evolution step 115: f(x)= 0.43994176854891826
# differential_evolution step 116: f(x)= 0.43994176854891826
# differential_evolution step 117: f(x)= 0.43994176854891826
# differential_evolution step 118: f(x)= 0.4374956645921875
# differential_evolution step 119: f(x)= 0.4374956645921875
# differential_evolution step 120: f(x)= 0.4374956645921875
# differential_evolution step 121: f(x)= 0.4374956645921875
# differential_evolution step 122: f(x)= 0.4374956645921875
# differential_evolution step 123: f(x)= 0.4374956645921875
# differential_evolution step 124: f(x)= 0.4374956645921875
# differential_evolution step 125: f(x)= 0.4374956645921875
# differential_evolution step 126: f(x)= 0.4374956645921875
# differential_evolution step 127: f(x)= 0.42937229154583667
# differential_evolution step 128: f(x)= 0.42937229154583667
# differential_evolution step 129: f(x)= 0.42937229154583667
# differential_evolution step 130: f(x)= 0.4225432489041869
# differential_evolution step 131: f(x)= 0.4225432489041869
# differential_evolution step 132: f(x)= 0.4225432489041869
# differential_evolution step 133: f(x)= 0.4225432489041869
# differential_evolution step 134: f(x)= 0.4173383572032004
# differential_evolution step 135: f(x)= 0.4173383572032004
# differential_evolution step 136: f(x)= 0.4173383572032004
# differential_evolution step 137: f(x)= 0.4173383572032004
# differential_evolution step 138: f(x)= 0.4173383572032004
# differential_evolution step 139: f(x)= 0.4173383572032004
# differential_evolution step 140: f(x)= 0.4173383572032004
# differential_evolution step 141: f(x)= 0.4173383572032004
# differential_evolution step 142: f(x)= 0.4173383572032004
# differential_evolution step 143: f(x)= 0.41309207496149997
# differential_evolution step 144: f(x)= 0.41309207496149997
# differential_evolution step 145: f(x)= 0.39035212361251515
# differential_evolution step 146: f(x)= 0.39035212361251515
# differential_evolution step 147: f(x)= 0.39035212361251515
# differential_evolution step 148: f(x)= 0.39035212361251515
# differential_evolution step 149: f(x)= 0.39035212361251515
# differential_evolution step 150: f(x)= 0.39035212361251515
# differential_evolution step 151: f(x)= 0.39035212361251515
# differential_evolution step 152: f(x)= 0.39035212361251515
# differential_evolution step 153: f(x)= 0.39035212361251515
# differential_evolution step 154: f(x)= 0.39035212361251515
# differential_evolution step 155: f(x)= 0.39035212361251515
# differential_evolution step 156: f(x)= 0.39035212361251515
# differential_evolution step 157: f(x)= 0.39035212361251515
# differential_evolution step 158: f(x)= 0.39035212361251515
# differential_evolution step 159: f(x)= 0.39035212361251515
# differential_evolution step 160: f(x)= 0.39035212361251515
# differential_evolution step 161: f(x)= 0.39035212361251515
# differential_evolution step 162: f(x)= 0.39035212361251515
# differential_evolution step 163: f(x)= 0.385904240703808
# differential_evolution step 164: f(x)= 0.385904240703808
# differential_evolution step 165: f(x)= 0.385904240703808
# differential_evolution step 166: f(x)= 0.385904240703808
# differential_evolution step 167: f(x)= 0.37399507279915106
# differential_evolution step 168: f(x)= 0.37399507279915106
# differential_evolution step 169: f(x)= 0.37399507279915106
# differential_evolution step 170: f(x)= 0.37399507279915106
# differential_evolution step 171: f(x)= 0.37399507279915106
# differential_evolution step 172: f(x)= 0.37399507279915106
# differential_evolution step 173: f(x)= 0.37399507279915106
# differential_evolution step 174: f(x)= 0.37399507279915106
# differential_evolution step 175: f(x)= 0.37399507279915106
# differential_evolution step 176: f(x)= 0.37399507279915106
# differential_evolution step 177: f(x)= 0.37399507279915106
# differential_evolution step 178: f(x)= 0.37399507279915106
# differential_evolution step 179: f(x)= 0.37399507279915106
# differential_evolution step 180: f(x)= 0.37399507279915106
# differential_evolution step 181: f(x)= 0.37399507279915106
# differential_evolution step 182: f(x)= 0.37399507279915106
# differential_evolution step 183: f(x)= 0.37399507279915106
# differential_evolution step 184: f(x)= 0.37399507279915106
# differential_evolution step 185: f(x)= 0.37399507279915106
# differential_evolution step 186: f(x)= 0.37399507279915106
# differential_evolution step 187: f(x)= 0.37399507279915106
# differential_evolution step 188: f(x)= 0.3643679466071695
# differential_evolution step 189: f(x)= 0.3643679466071695
# differential_evolution step 190: f(x)= 0.3643679466071695
# differential_evolution step 191: f(x)= 0.3643679466071695
# differential_evolution step 192: f(x)= 0.3643679466071695
# differential_evolution step 193: f(x)= 0.3643679466071695
# differential_evolution step 194: f(x)= 0.3643679466071695
# differential_evolution step 195: f(x)= 0.3643679466071695
# differential_evolution step 196: f(x)= 0.3643679466071695
# differential_evolution step 197: f(x)= 0.3643679466071695
# differential_evolution step 198: f(x)= 0.3643679466071695
# differential_evolution step 199: f(x)= 0.3643679466071695
# differential_evolution step 200: f(x)= 0.3643679466071695
# differential_evolution step 201: f(x)= 0.3643679466071695
# differential_evolution step 202: f(x)= 0.3643679466071695
# differential_evolution step 203: f(x)= 0.3643679466071695
# differential_evolution step 204: f(x)= 0.3643679466071695
# differential_evolution step 205: f(x)= 0.3643679466071695
# differential_evolution step 206: f(x)= 0.35977322374665577
# differential_evolution step 207: f(x)= 0.35977322374665577
# differential_evolution step 208: f(x)= 0.35977322374665577
# differential_evolution step 209: f(x)= 0.35977322374665577
# differential_evolution step 210: f(x)= 0.3585296325372488
# differential_evolution step 211: f(x)= 0.3585296325372488
# differential_evolution step 212: f(x)= 0.3585296325372488
# differential_evolution step 213: f(x)= 0.3585296325372488
# differential_evolution step 214: f(x)= 0.3585296325372488
# differential_evolution step 215: f(x)= 0.3585296325372488
# differential_evolution step 216: f(x)= 0.3585296325372488
# differential_evolution step 217: f(x)= 0.3585296325372488
# differential_evolution step 218: f(x)= 0.3585296325372488
# differential_evolution step 219: f(x)= 0.3585296325372488
# differential_evolution step 220: f(x)= 0.3585296325372488
# differential_evolution step 221: f(x)= 0.3585296325372488
# differential_evolution step 222: f(x)= 0.3585296325372488
# differential_evolution step 223: f(x)= 0.3585296325372488
# differential_evolution step 224: f(x)= 0.3585296325372488
# differential_evolution step 225: f(x)= 0.3585296325372488
# differential_evolution step 226: f(x)= 0.35793754938873595
# differential_evolution step 227: f(x)= 0.35793754938873595
# differential_evolution step 228: f(x)= 0.35793754938873595
# differential_evolution step 229: f(x)= 0.35728758294409274
# differential_evolution step 230: f(x)= 0.35728758294409274
# differential_evolution step 231: f(x)= 0.35728758294409274
# differential_evolution step 232: f(x)= 0.35614020032870414
# differential_evolution step 233: f(x)= 0.3557394166639004
# differential_evolution step 234: f(x)= 0.3557394166639004
# differential_evolution step 235: f(x)= 0.3557394166639004
# differential_evolution step 236: f(x)= 0.35494921241990224
# differential_evolution step 237: f(x)= 0.35455383589999817
# differential_evolution step 238: f(x)= 0.35455383589999817
# differential_evolution step 239: f(x)= 0.35315016459434007
# differential_evolution step 240: f(x)= 0.35315016459434007
# differential_evolution step 241: f(x)= 0.35315016459434007
# differential_evolution step 242: f(x)= 0.35315016459434007
# differential_evolution step 243: f(x)= 0.35315016459434007
# differential_evolution step 244: f(x)= 0.35315016459434007
# differential_evolution step 245: f(x)= 0.35315016459434007
# differential_evolution step 246: f(x)= 0.35315016459434007
# differential_evolution step 247: f(x)= 0.35315016459434007
# differential_evolution step 248: f(x)= 0.35315016459434007
# differential_evolution step 249: f(x)= 0.35315016459434007
# differential_evolution step 250: f(x)= 0.35315016459434007
# differential_evolution step 251: f(x)= 0.35315016459434007
# differential_evolution step 252: f(x)= 0.35315016459434007
# differential_evolution step 253: f(x)= 0.3524328181036519
# differential_evolution step 254: f(x)= 0.3524328181036519
# differential_evolution step 255: f(x)= 0.35179479265306784
# differential_evolution step 256: f(x)= 0.35036908462399463
# differential_evolution step 257: f(x)= 0.35036908462399463
# differential_evolution step 258: f(x)= 0.348878615366992
# differential_evolution step 259: f(x)= 0.3482225328450858
# differential_evolution step 260: f(x)= 0.3482225328450858
# differential_evolution step 261: f(x)= 0.3482225328450858
# differential_evolution step 262: f(x)= 0.3482225328450858
# differential_evolution step 263: f(x)= 0.3482225328450858
# differential_evolution step 264: f(x)= 0.3482225328450858
# differential_evolution step 265: f(x)= 0.3482225328450858
# differential_evolution step 266: f(x)= 0.3482225328450858
# differential_evolution step 267: f(x)= 0.3473504234496624
# differential_evolution step 268: f(x)= 0.3473504234496624
# differential_evolution step 269: f(x)= 0.3473504234496624
# differential_evolution step 270: f(x)= 0.34616342920604243
# differential_evolution step 271: f(x)= 0.34616342920604243
# differential_evolution step 272: f(x)= 0.3461157268226295
# differential_evolution step 273: f(x)= 0.345836536356633
# differential_evolution step 274: f(x)= 0.345836536356633
# differential_evolution step 275: f(x)= 0.345836536356633
# differential_evolution step 276: f(x)= 0.345836536356633
# differential_evolution step 277: f(x)= 0.345836536356633
# differential_evolution step 278: f(x)= 0.345836536356633
# differential_evolution step 279: f(x)= 0.345836536356633
# differential_evolution step 280: f(x)= 0.345154419651696
# differential_evolution step 281: f(x)= 0.345154419651696
# differential_evolution step 282: f(x)= 0.345154419651696
# differential_evolution step 283: f(x)= 0.345154419651696
# differential_evolution step 284: f(x)= 0.345154419651696
# differential_evolution step 285: f(x)= 0.34386898210552236
# differential_evolution step 286: f(x)= 0.34386898210552236
# differential_evolution step 287: f(x)= 0.34386898210552236
# differential_evolution step 288: f(x)= 0.34386898210552236
# differential_evolution step 289: f(x)= 0.343221882607817
# differential_evolution step 290: f(x)= 0.3426038754863632
# differential_evolution step 291: f(x)= 0.3426038754863632
# differential_evolution step 292: f(x)= 0.3426038754863632
# differential_evolution step 293: f(x)= 0.3426038754863632
# differential_evolution step 294: f(x)= 0.3426038754863632
# differential_evolution step 295: f(x)= 0.3426038754863632
# differential_evolution step 296: f(x)= 0.3426038754863632
# differential_evolution step 297: f(x)= 0.3424212259535903
# differential_evolution step 298: f(x)= 0.3424212259535903
# differential_evolution step 299: f(x)= 0.3424212259535903
# differential_evolution step 300: f(x)= 0.3424212259535903
# differential_evolution step 301: f(x)= 0.3424212259535903
# differential_evolution step 302: f(x)= 0.3424212259535903
# differential_evolution step 303: f(x)= 0.3424212259535903
# differential_evolution step 304: f(x)= 0.3424212259535903
# differential_evolution step 305: f(x)= 0.3424212259535903
# differential_evolution step 306: f(x)= 0.3424212259535903
# differential_evolution step 307: f(x)= 0.3424212259535903
# differential_evolution step 308: f(x)= 0.3424212259535903
# differential_evolution step 309: f(x)= 0.3424212259535903
# differential_evolution step 310: f(x)= 0.3424212259535903
# differential_evolution step 311: f(x)= 0.3424212259535903
# differential_evolution step 312: f(x)= 0.33851054109998036
# differential_evolution step 313: f(x)= 0.33851054109998036
# differential_evolution step 314: f(x)= 0.33851054109998036
# differential_evolution step 315: f(x)= 0.33851054109998036
# differential_evolution step 316: f(x)= 0.33851054109998036
# differential_evolution step 317: f(x)= 0.33851054109998036
# differential_evolution step 318: f(x)= 0.33851054109998036
# differential_evolution step 319: f(x)= 0.33851054109998036
# differential_evolution step 320: f(x)= 0.33851054109998036
# differential_evolution step 321: f(x)= 0.33851054109998036
# differential_evolution step 322: f(x)= 0.33851054109998036
# differential_evolution step 323: f(x)= 0.33851054109998036
# differential_evolution step 324: f(x)= 0.33851054109998036
# differential_evolution step 325: f(x)= 0.33851054109998036
# differential_evolution step 326: f(x)= 0.33851054109998036
# differential_evolution step 327: f(x)= 0.33851054109998036
# differential_evolution step 328: f(x)= 0.33851054109998036
# differential_evolution step 329: f(x)= 0.33851054109998036
# differential_evolution step 330: f(x)= 0.33851054109998036
# differential_evolution step 331: f(x)= 0.33842917596047095
# differential_evolution step 332: f(x)= 0.33842917596047095
# differential_evolution step 333: f(x)= 0.33842917596047095
# differential_evolution step 334: f(x)= 0.33842917596047095
# differential_evolution step 335: f(x)= 0.33842917596047095
# differential_evolution step 336: f(x)= 0.33842917596047095
# differential_evolution step 337: f(x)= 0.33842917596047095
# differential_evolution step 338: f(x)= 0.33842917596047095
# differential_evolution step 339: f(x)= 0.33842917596047095
# differential_evolution step 340: f(x)= 0.33842917596047095
# differential_evolution step 341: f(x)= 0.3375959133381115
# differential_evolution step 342: f(x)= 0.3375959133381115
# differential_evolution step 343: f(x)= 0.3374650218527631
# differential_evolution step 344: f(x)= 0.3374650218527631
# differential_evolution step 345: f(x)= 0.3374650218527631
# differential_evolution step 346: f(x)= 0.3374650218527631
# differential_evolution step 347: f(x)= 0.3374650218527631
# differential_evolution step 348: f(x)= 0.3374650218527631
# differential_evolution step 349: f(x)= 0.3374650218527631
# differential_evolution step 350: f(x)= 0.3374650218527631
# differential_evolution step 351: f(x)= 0.3374650218527631
# differential_evolution step 352: f(x)= 0.3374650218527631
# differential_evolution step 353: f(x)= 0.3374650218527631
# differential_evolution step 354: f(x)= 0.3374650218527631
# differential_evolution step 355: f(x)= 0.3374650218527631
# differential_evolution step 356: f(x)= 0.3374650218527631
# differential_evolution step 357: f(x)= 0.3354466319213146
# differential_evolution step 358: f(x)= 0.3354466319213146
# differential_evolution step 359: f(x)= 0.3354466319213146
# differential_evolution step 360: f(x)= 0.3354466319213146
# differential_evolution step 361: f(x)= 0.3354466319213146
# differential_evolution step 362: f(x)= 0.3354466319213146
# differential_evolution step 363: f(x)= 0.3354466319213146
# differential_evolution step 364: f(x)= 0.3354466319213146
# differential_evolution step 365: f(x)= 0.3354466319213146
# differential_evolution step 366: f(x)= 0.33535623211661203
# differential_evolution step 367: f(x)= 0.33535623211661203
# differential_evolution step 368: f(x)= 0.33535623211661203
# differential_evolution step 369: f(x)= 0.33450130836155595
# differential_evolution step 370: f(x)= 0.3343480054673607
# differential_evolution step 371: f(x)= 0.3343480054673607
# differential_evolution step 372: f(x)= 0.3343480054673607
# differential_evolution step 373: f(x)= 0.33203616939113817
# differential_evolution step 374: f(x)= 0.33203616939113817
# differential_evolution step 375: f(x)= 0.3315039926835966
# differential_evolution step 376: f(x)= 0.3315039926835966
# differential_evolution step 377: f(x)= 0.3312774748755183
# differential_evolution step 378: f(x)= 0.3312774748755183
# differential_evolution step 379: f(x)= 0.3306176998520838
# differential_evolution step 380: f(x)= 0.3306176998520838
# differential_evolution step 381: f(x)= 0.3306176998520838
# differential_evolution step 382: f(x)= 0.3306176998520838
# differential_evolution step 383: f(x)= 0.3306176998520838
# differential_evolution step 384: f(x)= 0.3306176998520838
# differential_evolution step 385: f(x)= 0.3306176998520838
# differential_evolution step 386: f(x)= 0.3306176998520838
# differential_evolution step 387: f(x)= 0.3306176998520838
# differential_evolution step 388: f(x)= 0.3306176998520838
# differential_evolution step 389: f(x)= 0.3306176998520838
# differential_evolution step 390: f(x)= 0.3306176998520838
# differential_evolution step 391: f(x)= 0.3306176998520838
# differential_evolution step 392: f(x)= 0.3306176998520838
# differential_evolution step 393: f(x)= 0.3304469625111924
# differential_evolution step 394: f(x)= 0.3304469625111924
# differential_evolution step 395: f(x)= 0.3304469625111924
# differential_evolution step 396: f(x)= 0.3304469625111924
# differential_evolution step 397: f(x)= 0.3304469625111924
# differential_evolution step 398: f(x)= 0.3304469625111924
# differential_evolution step 399: f(x)= 0.3304469625111924
# differential_evolution step 400: f(x)= 0.3304469625111924
# differential_evolution step 401: f(x)= 0.3304469625111924
# differential_evolution step 402: f(x)= 0.32882124318715583
# differential_evolution step 403: f(x)= 0.32882124318715583
# differential_evolution step 404: f(x)= 0.32882124318715583
# differential_evolution step 405: f(x)= 0.32441750208896025
# differential_evolution step 406: f(x)= 0.32441750208896025
# differential_evolution step 407: f(x)= 0.3232670203880032
# differential_evolution step 408: f(x)= 0.3232670203880032
# differential_evolution step 409: f(x)= 0.32244379562214703
# differential_evolution step 410: f(x)= 0.3223236415518074
# differential_evolution step 411: f(x)= 0.3213559639276545
# differential_evolution step 412: f(x)= 0.31743662198688805
# differential_evolution step 413: f(x)= 0.31743662198688805
# differential_evolution step 414: f(x)= 0.31743662198688805
# differential_evolution step 415: f(x)= 0.31743662198688805
# differential_evolution step 416: f(x)= 0.31743662198688805
# differential_evolution step 417: f(x)= 0.31743662198688805
# differential_evolution step 418: f(x)= 0.31743662198688805
# differential_evolution step 419: f(x)= 0.3171953917883487
# differential_evolution step 420: f(x)= 0.3171953917883487
# differential_evolution step 421: f(x)= 0.3171953917883487
# differential_evolution step 422: f(x)= 0.3153854851938555
# differential_evolution step 423: f(x)= 0.31468032881947183
# differential_evolution step 424: f(x)= 0.31468032881947183
# differential_evolution step 425: f(x)= 0.31468032881947183
# differential_evolution step 426: f(x)= 0.31468032881947183
# differential_evolution step 427: f(x)= 0.31075525213528404
# differential_evolution step 428: f(x)= 0.31075525213528404
# differential_evolution step 429: f(x)= 0.31040962434612773
# differential_evolution step 430: f(x)= 0.31016400572084746
# differential_evolution step 431: f(x)= 0.3038366891502972
# differential_evolution step 432: f(x)= 0.3038366891502972
# differential_evolution step 433: f(x)= 0.3038366891502972
# differential_evolution step 434: f(x)= 0.3038366891502972
# differential_evolution step 435: f(x)= 0.3029599057051957
# differential_evolution step 436: f(x)= 0.30049718620687155
# differential_evolution step 437: f(x)= 0.29719195992740655
# differential_evolution step 438: f(x)= 0.29719195992740655
# differential_evolution step 439: f(x)= 0.29719195992740655
# differential_evolution step 440: f(x)= 0.29719195992740655
# differential_evolution step 441: f(x)= 0.29719195992740655
# differential_evolution step 442: f(x)= 0.29719195992740655
# differential_evolution step 443: f(x)= 0.29719195992740655
# differential_evolution step 444: f(x)= 0.2965848667554583
# differential_evolution step 445: f(x)= 0.2965848667554583
# differential_evolution step 446: f(x)= 0.2965848667554583
# differential_evolution step 447: f(x)= 0.2965848667554583
# differential_evolution step 448: f(x)= 0.2965848667554583
# differential_evolution step 449: f(x)= 0.2965848667554583
# differential_evolution step 450: f(x)= 0.2965848667554583
# differential_evolution step 451: f(x)= 0.2947928749841075
# differential_evolution step 452: f(x)= 0.2947928749841075
# differential_evolution step 453: f(x)= 0.2947928749841075
# differential_evolution step 454: f(x)= 0.2947928749841075
# differential_evolution step 455: f(x)= 0.2947928749841075
# differential_evolution step 456: f(x)= 0.2947928749841075
# differential_evolution step 457: f(x)= 0.2947928749841075
# differential_evolution step 458: f(x)= 0.2947928749841075
# differential_evolution step 459: f(x)= 0.2947928749841075
# differential_evolution step 460: f(x)= 0.2947928749841075
# differential_evolution step 461: f(x)= 0.2947928749841075
# differential_evolution step 462: f(x)= 0.2944555844283635
# differential_evolution step 463: f(x)= 0.2944555844283635
# differential_evolution step 464: f(x)= 0.2937664884494869
# differential_evolution step 465: f(x)= 0.2937664884494869
# differential_evolution step 466: f(x)= 0.2937664884494869
# differential_evolution step 467: f(x)= 0.2937664884494869
# differential_evolution step 468: f(x)= 0.2937664884494869
# differential_evolution step 469: f(x)= 0.2937664884494869
# differential_evolution step 470: f(x)= 0.2937664884494869
# differential_evolution step 471: f(x)= 0.2937664884494869
# differential_evolution step 472: f(x)= 0.2937664884494869
# differential_evolution step 473: f(x)= 0.2937664884494869
# differential_evolution step 474: f(x)= 0.2937664884494869
# differential_evolution step 475: f(x)= 0.2937664884494869
# differential_evolution step 476: f(x)= 0.2937664884494869
# differential_evolution step 477: f(x)= 0.2937664884494869
# differential_evolution step 478: f(x)= 0.2937664884494869
# differential_evolution step 479: f(x)= 0.2937664884494869
# differential_evolution step 480: f(x)= 0.2937664884494869
# differential_evolution step 481: f(x)= 0.2937664884494869
# differential_evolution step 482: f(x)= 0.2937664884494869
# differential_evolution step 483: f(x)= 0.2937664884494869
# differential_evolution step 484: f(x)= 0.2937664884494869
# differential_evolution step 485: f(x)= 0.29299618637875086
# differential_evolution step 486: f(x)= 0.29299618637875086
# differential_evolution step 487: f(x)= 0.29299618637875086
# differential_evolution step 488: f(x)= 0.29299618637875086
# differential_evolution step 489: f(x)= 0.29299618637875086
# differential_evolution step 490: f(x)= 0.29299618637875086
# differential_evolution step 491: f(x)= 0.2929817988857827
# differential_evolution step 492: f(x)= 0.2922810076253421
# differential_evolution step 493: f(x)= 0.2918389393075448
# differential_evolution step 494: f(x)= 0.2918389393075448
# differential_evolution step 495: f(x)= 0.2918389393075448
# differential_evolution step 496: f(x)= 0.2918389393075448
# differential_evolution step 497: f(x)= 0.2918389393075448
# differential_evolution step 498: f(x)= 0.2918389393075448
# differential_evolution step 499: f(x)= 0.2918389393075448
# differential_evolution step 500: f(x)= 0.2918389393075448
# differential_evolution step 501: f(x)= 0.2918389393075448
# differential_evolution step 502: f(x)= 0.2918389393075448
# differential_evolution step 503: f(x)= 0.2918389393075448
# differential_evolution step 504: f(x)= 0.2918389393075448
# differential_evolution step 505: f(x)= 0.2918389393075448
# differential_evolution step 506: f(x)= 0.2918389393075448
# differential_evolution step 507: f(x)= 0.2912565924058775
# differential_evolution step 508: f(x)= 0.2912565924058775
# differential_evolution step 509: f(x)= 0.2912565924058775
# differential_evolution step 510: f(x)= 0.2912565924058775
# differential_evolution step 511: f(x)= 0.2912565924058775
# differential_evolution step 512: f(x)= 0.2912565924058775
# differential_evolution step 513: f(x)= 0.29118279000764846
# differential_evolution step 514: f(x)= 0.29118279000764846
# differential_evolution step 515: f(x)= 0.29118279000764846
# differential_evolution step 516: f(x)= 0.29118279000764846
# differential_evolution step 517: f(x)= 0.29118279000764846
# differential_evolution step 518: f(x)= 0.29118279000764846
# differential_evolution step 519: f(x)= 0.29118279000764846
# differential_evolution step 520: f(x)= 0.29118279000764846
# differential_evolution step 521: f(x)= 0.29118279000764846
# differential_evolution step 522: f(x)= 0.29118279000764846
# differential_evolution step 523: f(x)= 0.2908611206484545
# differential_evolution step 524: f(x)= 0.2908611206484545
# differential_evolution step 525: f(x)= 0.2908611206484545
# differential_evolution step 526: f(x)= 0.2908611206484545
# differential_evolution step 527: f(x)= 0.2908611206484545
# differential_evolution step 528: f(x)= 0.2908611206484545
# differential_evolution step 529: f(x)= 0.2908611206484545
# differential_evolution step 530: f(x)= 0.2908611206484545
# differential_evolution step 531: f(x)= 0.2908611206484545
# differential_evolution step 532: f(x)= 0.2908611206484545
# differential_evolution step 533: f(x)= 0.2908611206484545
# differential_evolution step 534: f(x)= 0.2908611206484545
# differential_evolution step 535: f(x)= 0.2908611206484545
# differential_evolution step 536: f(x)= 0.2908611206484545
# differential_evolution step 537: f(x)= 0.2908611206484545
# differential_evolution step 538: f(x)= 0.2908611206484545
# differential_evolution step 539: f(x)= 0.2908611206484545
# differential_evolution step 540: f(x)= 0.2908611206484545
# differential_evolution step 541: f(x)= 0.2908611206484545
# differential_evolution step 542: f(x)= 0.2908611206484545
# differential_evolution step 543: f(x)= 0.2908611206484545
# differential_evolution step 544: f(x)= 0.2908611206484545
# differential_evolution step 545: f(x)= 0.2908611206484545
# differential_evolution step 546: f(x)= 0.2908611206484545
# differential_evolution step 547: f(x)= 0.2908611206484545
# differential_evolution step 548: f(x)= 0.2908611206484545
# differential_evolution step 549: f(x)= 0.2908611206484545
# differential_evolution step 550: f(x)= 0.2908611206484545
# differential_evolution step 551: f(x)= 0.2908611206484545
# differential_evolution step 552: f(x)= 0.2907718716676775
# differential_evolution step 553: f(x)= 0.2907718716676775
# differential_evolution step 554: f(x)= 0.2907718716676775
# differential_evolution step 555: f(x)= 0.2907718716676775
# differential_evolution step 556: f(x)= 0.2903663805149261
# differential_evolution step 557: f(x)= 0.2903663805149261
# differential_evolution step 558: f(x)= 0.2903663805149261
# differential_evolution step 559: f(x)= 0.2903663805149261
# differential_evolution step 560: f(x)= 0.2903663805149261
# differential_evolution step 561: f(x)= 0.2903663805149261
# differential_evolution step 562: f(x)= 0.2903663805149261
# differential_evolution step 563: f(x)= 0.2903663805149261
# differential_evolution step 564: f(x)= 0.2903663805149261
# differential_evolution step 565: f(x)= 0.2903663805149261
# differential_evolution step 566: f(x)= 0.2903663805149261
# differential_evolution step 567: f(x)= 0.2903663805149261
# differential_evolution step 568: f(x)= 0.2902883211305916
# differential_evolution step 569: f(x)= 0.2902071488777998
# differential_evolution step 570: f(x)= 0.2902071488777998
# differential_evolution step 571: f(x)= 0.2902071488777998
# differential_evolution step 572: f(x)= 0.2900414700592527
# differential_evolution step 573: f(x)= 0.2900414700592527
# differential_evolution step 574: f(x)= 0.2900414700592527
# differential_evolution step 575: f(x)= 0.2900414700592527
# differential_evolution step 576: f(x)= 0.2900414700592527
# differential_evolution step 577: f(x)= 0.2900414700592527
# differential_evolution step 578: f(x)= 0.2900414700592527
# differential_evolution step 579: f(x)= 0.2900414700592527
# differential_evolution step 580: f(x)= 0.2900414700592527
# differential_evolution step 581: f(x)= 0.2900414700592527
# differential_evolution step 582: f(x)= 0.2900414700592527
# differential_evolution step 583: f(x)= 0.2900414700592527
# differential_evolution step 584: f(x)= 0.2900414700592527
# differential_evolution step 585: f(x)= 0.2900414700592527
# differential_evolution step 586: f(x)= 0.2900414700592527
# differential_evolution step 587: f(x)= 0.2900414700592527
# differential_evolution step 588: f(x)= 0.289881656724437
# differential_evolution step 589: f(x)= 0.289881656724437
# differential_evolution step 590: f(x)= 0.289881656724437
# differential_evolution step 591: f(x)= 0.289881656724437
# differential_evolution step 592: f(x)= 0.289881656724437
# differential_evolution step 593: f(x)= 0.289881656724437
# differential_evolution step 594: f(x)= 0.289881656724437
# differential_evolution step 595: f(x)= 0.289881656724437
# differential_evolution step 596: f(x)= 0.289881656724437
# differential_evolution step 597: f(x)= 0.289881656724437
# differential_evolution step 598: f(x)= 0.289881656724437
# differential_evolution step 599: f(x)= 0.289881656724437
# differential_evolution step 600: f(x)= 0.289881656724437
# differential_evolution step 601: f(x)= 0.289881656724437
# differential_evolution step 602: f(x)= 0.289881656724437
# differential_evolution step 603: f(x)= 0.289881656724437
# differential_evolution step 604: f(x)= 0.289881656724437
# differential_evolution step 605: f(x)= 0.289881656724437
# differential_evolution step 606: f(x)= 0.289881656724437
# differential_evolution step 607: f(x)= 0.289881656724437
# differential_evolution step 608: f(x)= 0.289881656724437
# differential_evolution step 609: f(x)= 0.289881656724437
# differential_evolution step 610: f(x)= 0.289881656724437
# differential_evolution step 611: f(x)= 0.289881656724437
# differential_evolution step 612: f(x)= 0.289881656724437
# differential_evolution step 613: f(x)= 0.289881656724437
# differential_evolution step 614: f(x)= 0.289881656724437
# differential_evolution step 615: f(x)= 0.289881656724437
# differential_evolution step 616: f(x)= 0.289881656724437
# differential_evolution step 617: f(x)= 0.289881656724437
# differential_evolution step 618: f(x)= 0.289881656724437
# differential_evolution step 619: f(x)= 0.289881656724437
# differential_evolution step 620: f(x)= 0.289881656724437
# differential_evolution step 621: f(x)= 0.289881656724437
# differential_evolution step 622: f(x)= 0.289881656724437
# differential_evolution step 623: f(x)= 0.289881656724437
# differential_evolution step 624: f(x)= 0.289881656724437
# differential_evolution step 625: f(x)= 0.289881656724437
# differential_evolution step 626: f(x)= 0.289881656724437
# differential_evolution step 627: f(x)= 0.289881656724437
# differential_evolution step 628: f(x)= 0.289881656724437
# differential_evolution step 629: f(x)= 0.289881656724437
# differential_evolution step 630: f(x)= 0.2898383452005304
# differential_evolution step 631: f(x)= 0.2898383452005304
# differential_evolution step 632: f(x)= 0.2896644968732806
# differential_evolution step 633: f(x)= 0.2896644968732806
# differential_evolution step 634: f(x)= 0.2896644968732806
# differential_evolution step 635: f(x)= 0.2896644968732806
# differential_evolution step 636: f(x)= 0.28961882929497096
# differential_evolution step 637: f(x)= 0.28961882929497096
# differential_evolution step 638: f(x)= 0.28955152708133164
# differential_evolution step 639: f(x)= 0.28955152708133164
# differential_evolution step 640: f(x)= 0.289514229220408
# differential_evolution step 641: f(x)= 0.289514229220408
# differential_evolution step 642: f(x)= 0.289514229220408
# differential_evolution step 643: f(x)= 0.289514229220408
# differential_evolution step 644: f(x)= 0.289514229220408
# differential_evolution step 645: f(x)= 0.28946380243079556
# differential_evolution step 646: f(x)= 0.28946380243079556
# differential_evolution step 647: f(x)= 0.28946380243079556
# differential_evolution step 648: f(x)= 0.289446073863208
# differential_evolution step 649: f(x)= 0.289446073863208
# differential_evolution step 650: f(x)= 0.289446073863208
# differential_evolution step 651: f(x)= 0.289446073863208
# differential_evolution step 652: f(x)= 0.289446073863208
# differential_evolution step 653: f(x)= 0.289446073863208
# differential_evolution step 654: f(x)= 0.28940485423167484
# differential_evolution step 655: f(x)= 0.28940485423167484
# differential_evolution step 656: f(x)= 0.28940485423167484
# differential_evolution step 657: f(x)= 0.28940485423167484
# differential_evolution step 658: f(x)= 0.28940485423167484
# differential_evolution step 659: f(x)= 0.28940485423167484
# differential_evolution step 660: f(x)= 0.28940485423167484
# differential_evolution step 661: f(x)= 0.28940485423167484
# differential_evolution step 662: f(x)= 0.28940485423167484
# differential_evolution step 663: f(x)= 0.28940485423167484
# differential_evolution step 664: f(x)= 0.28940485423167484
# differential_evolution step 665: f(x)= 0.2893988681254184
# differential_evolution step 666: f(x)= 0.2893988681254184
# differential_evolution step 667: f(x)= 0.2893988681254184
# differential_evolution step 668: f(x)= 0.2893988681254184
# differential_evolution step 669: f(x)= 0.2893988681254184
# differential_evolution step 670: f(x)= 0.2893187578909283
# differential_evolution step 671: f(x)= 0.2893187578909283
# differential_evolution step 672: f(x)= 0.2893187578909283
# differential_evolution step 673: f(x)= 0.28930483837061427
# differential_evolution step 674: f(x)= 0.28927372599313667
# differential_evolution step 675: f(x)= 0.28927372599313667
# differential_evolution step 676: f(x)= 0.28927372599313667
# differential_evolution step 677: f(x)= 0.28927372599313667
# differential_evolution step 678: f(x)= 0.28927372599313667
# differential_evolution step 679: f(x)= 0.28927372599313667
# differential_evolution step 680: f(x)= 0.28927372599313667
# differential_evolution step 681: f(x)= 0.28927372599313667
# differential_evolution step 682: f(x)= 0.28927372599313667
# differential_evolution step 683: f(x)= 0.28927372599313667
# differential_evolution step 684: f(x)= 0.28927372599313667
# differential_evolution step 685: f(x)= 0.28927372599313667
# differential_evolution step 686: f(x)= 0.28927372599313667
# differential_evolution step 687: f(x)= 0.28925606773051116
# differential_evolution step 688: f(x)= 0.28925606773051116
# differential_evolution step 689: f(x)= 0.28925526157706744
# differential_evolution step 690: f(x)= 0.28925526157706744
# differential_evolution step 691: f(x)= 0.2892228733736944
# differential_evolution step 692: f(x)= 0.2892228733736944
# differential_evolution step 693: f(x)= 0.2891298464582177
# differential_evolution step 694: f(x)= 0.2891298464582177
# differential_evolution step 695: f(x)= 0.2891298464582177
# differential_evolution step 696: f(x)= 0.2891298464582177
# differential_evolution step 697: f(x)= 0.2891298464582177
# differential_evolution step 698: f(x)= 0.2891298464582177
# differential_evolution step 699: f(x)= 0.2891298464582177
# differential_evolution step 700: f(x)= 0.2891298464582177
# differential_evolution step 701: f(x)= 0.2891298464582177
# differential_evolution step 702: f(x)= 0.2891298464582177
# differential_evolution step 703: f(x)= 0.2891298464582177
# differential_evolution step 704: f(x)= 0.2891298464582177
# differential_evolution step 705: f(x)= 0.28911170917037293
# differential_evolution step 706: f(x)= 0.2890575332880154
# differential_evolution step 707: f(x)= 0.2890575332880154
# differential_evolution step 708: f(x)= 0.2890575332880154
# differential_evolution step 709: f(x)= 0.2890575332880154
# differential_evolution step 710: f(x)= 0.2890575332880154
# differential_evolution step 711: f(x)= 0.2890575332880154
# differential_evolution step 712: f(x)= 0.2890575332880154
# differential_evolution step 713: f(x)= 0.28905108557941694
# differential_evolution step 714: f(x)= 0.28905108557941694
# differential_evolution step 715: f(x)= 0.28905108557941694
# differential_evolution step 716: f(x)= 0.28896020141922013
# differential_evolution step 717: f(x)= 0.28896020141922013
# differential_evolution step 718: f(x)= 0.28896020141922013
# differential_evolution step 719: f(x)= 0.28896020141922013
# differential_evolution step 720: f(x)= 0.2889289230785134
# differential_evolution step 721: f(x)= 0.288760887158839
# differential_evolution step 722: f(x)= 0.2887483339714971
# differential_evolution step 723: f(x)= 0.2887483339714971
# differential_evolution step 724: f(x)= 0.2887483339714971
# differential_evolution step 725: f(x)= 0.2887483339714971
# differential_evolution step 726: f(x)= 0.2887483339714971
# differential_evolution step 727: f(x)= 0.2887483339714971
# differential_evolution step 728: f(x)= 0.28871346935732894
# differential_evolution step 729: f(x)= 0.28871346935732894
# differential_evolution step 730: f(x)= 0.28871346935732894
# differential_evolution step 731: f(x)= 0.28871346935732894
# differential_evolution step 732: f(x)= 0.28871346935732894
# differential_evolution step 733: f(x)= 0.2886665258796398
# differential_evolution step 734: f(x)= 0.2886665258796398
# differential_evolution step 735: f(x)= 0.2886665258796398
# differential_evolution step 736: f(x)= 0.2886665258796398
# differential_evolution step 737: f(x)= 0.28861208340114824
# differential_evolution step 738: f(x)= 0.28861208340114824
# differential_evolution step 739: f(x)= 0.28861208340114824
# differential_evolution step 740: f(x)= 0.2885992499166967
# differential_evolution step 741: f(x)= 0.2885992499166967
# differential_evolution step 742: f(x)= 0.2885992499166967
# differential_evolution step 743: f(x)= 0.2885590103131859
# differential_evolution step 744: f(x)= 0.2885590103131859
# differential_evolution step 745: f(x)= 0.2885335188089878
# differential_evolution step 746: f(x)= 0.2885335188089878
# differential_evolution step 747: f(x)= 0.28840200672473637
# differential_evolution step 748: f(x)= 0.28840200672473637
# differential_evolution step 749: f(x)= 0.28840200672473637
# differential_evolution step 750: f(x)= 0.28835664619769136
# differential_evolution step 751: f(x)= 0.28835664619769136
# differential_evolution step 752: f(x)= 0.2880303921179903
# differential_evolution step 753: f(x)= 0.2880303921179903
# differential_evolution step 754: f(x)= 0.2880303921179903
# differential_evolution step 755: f(x)= 0.2880303921179903
# differential_evolution step 756: f(x)= 0.2880303921179903
# differential_evolution step 757: f(x)= 0.2880303921179903
# differential_evolution step 758: f(x)= 0.2880303921179903
# differential_evolution step 759: f(x)= 0.2880303921179903
# differential_evolution step 760: f(x)= 0.2880303921179903
# differential_evolution step 761: f(x)= 0.2879647188165597
# differential_evolution step 762: f(x)= 0.2879647188165597
# differential_evolution step 763: f(x)= 0.2879647188165597
# differential_evolution step 764: f(x)= 0.2879647188165597
# differential_evolution step 765: f(x)= 0.2879647188165597
# differential_evolution step 766: f(x)= 0.2879647188165597
# differential_evolution step 767: f(x)= 0.2879647188165597
# differential_evolution step 768: f(x)= 0.2879647188165597
# differential_evolution step 769: f(x)= 0.2879647188165597
# differential_evolution step 770: f(x)= 0.2879647188165597
# differential_evolution step 771: f(x)= 0.2879647188165597
# differential_evolution step 772: f(x)= 0.2879647188165597
# differential_evolution step 773: f(x)= 0.2879647188165597
# differential_evolution step 774: f(x)= 0.2878841873851256
# differential_evolution step 775: f(x)= 0.2878841873851256
# differential_evolution step 776: f(x)= 0.2878841873851256
# differential_evolution step 777: f(x)= 0.2878841873851256
# differential_evolution step 778: f(x)= 0.2878841873851256
# differential_evolution step 779: f(x)= 0.28770017886729865
# differential_evolution step 780: f(x)= 0.28770017886729865
# differential_evolution step 781: f(x)= 0.28770017886729865
# differential_evolution step 782: f(x)= 0.28770017886729865
# differential_evolution step 783: f(x)= 0.28770017886729865
# differential_evolution step 784: f(x)= 0.28770017886729865
# differential_evolution step 785: f(x)= 0.28770017886729865
# differential_evolution step 786: f(x)= 0.28770017886729865
# differential_evolution step 787: f(x)= 0.28759080398621406
# differential_evolution step 788: f(x)= 0.2873146869005244
# differential_evolution step 789: f(x)= 0.2873146869005244
# differential_evolution step 790: f(x)= 0.2873146869005244
# differential_evolution step 791: f(x)= 0.2873146869005244
# differential_evolution step 792: f(x)= 0.2873146869005244
# differential_evolution step 793: f(x)= 0.2873146869005244
# differential_evolution step 794: f(x)= 0.2873146869005244
# differential_evolution step 795: f(x)= 0.2873146869005244
# differential_evolution step 796: f(x)= 0.2873146869005244
# differential_evolution step 797: f(x)= 0.2873146869005244
# differential_evolution step 798: f(x)= 0.2873146869005244
# differential_evolution step 799: f(x)= 0.2873146869005244
# differential_evolution step 800: f(x)= 0.2873146869005244
# differential_evolution step 801: f(x)= 0.2872795728582087
# differential_evolution step 802: f(x)= 0.2872795728582087
# differential_evolution step 803: f(x)= 0.2872795728582087
# differential_evolution step 804: f(x)= 0.2871994367005368
# differential_evolution step 805: f(x)= 0.2871994367005368
# differential_evolution step 806: f(x)= 0.2871994367005368
# differential_evolution step 807: f(x)= 0.2871994367005368
# differential_evolution step 808: f(x)= 0.2871994367005368
# differential_evolution step 809: f(x)= 0.2871994367005368
# differential_evolution step 810: f(x)= 0.2871994367005368
# differential_evolution step 811: f(x)= 0.2871994367005368
# differential_evolution step 812: f(x)= 0.2871994367005368
# differential_evolution step 813: f(x)= 0.2871994367005368
# differential_evolution step 814: f(x)= 0.2871994367005368
# differential_evolution step 815: f(x)= 0.2871994367005368
# differential_evolution step 816: f(x)= 0.2871994367005368
# differential_evolution step 817: f(x)= 0.2871994367005368
# differential_evolution step 818: f(x)= 0.2871994367005368
# differential_evolution step 819: f(x)= 0.2871994367005368
# differential_evolution step 820: f(x)= 0.2871994367005368
# differential_evolution step 821: f(x)= 0.28708745059773194
# differential_evolution step 822: f(x)= 0.28708745059773194
# differential_evolution step 823: f(x)= 0.28708745059773194
# differential_evolution step 824: f(x)= 0.28708745059773194
# differential_evolution step 825: f(x)= 0.28708745059773194
# differential_evolution step 826: f(x)= 0.28708745059773194
# differential_evolution step 827: f(x)= 0.28708745059773194
# differential_evolution step 828: f(x)= 0.28708745059773194
# differential_evolution step 829: f(x)= 0.28708745059773194
# differential_evolution step 830: f(x)= 0.28708745059773194
# differential_evolution step 831: f(x)= 0.28708745059773194
# differential_evolution step 832: f(x)= 0.28708745059773194
# differential_evolution step 833: f(x)= 0.28708745059773194
# differential_evolution step 834: f(x)= 0.28708745059773194
# differential_evolution step 835: f(x)= 0.28708745059773194
# differential_evolution step 836: f(x)= 0.28701233103869767
# differential_evolution step 837: f(x)= 0.28701233103869767
# differential_evolution step 838: f(x)= 0.28701233103869767
# differential_evolution step 839: f(x)= 0.28701233103869767
# differential_evolution step 840: f(x)= 0.28701233103869767
# differential_evolution step 841: f(x)= 0.28701233103869767
# differential_evolution step 842: f(x)= 0.28692166258313
# differential_evolution step 843: f(x)= 0.2865735089367314
# differential_evolution step 844: f(x)= 0.2865735089367314
# differential_evolution step 845: f(x)= 0.2865735089367314
# differential_evolution step 846: f(x)= 0.2865735089367314
# differential_evolution step 847: f(x)= 0.2865735089367314
# differential_evolution step 848: f(x)= 0.2865735089367314
# differential_evolution step 849: f(x)= 0.2865735089367314
# differential_evolution step 850: f(x)= 0.2865735089367314
# differential_evolution step 851: f(x)= 0.2865735089367314
# differential_evolution step 852: f(x)= 0.2865735089367314
# differential_evolution step 853: f(x)= 0.2865735089367314
# differential_evolution step 854: f(x)= 0.2865735089367314
# differential_evolution step 855: f(x)= 0.2865735089367314
# differential_evolution step 856: f(x)= 0.2864956202545901
# differential_evolution step 857: f(x)= 0.2864956202545901
# differential_evolution step 858: f(x)= 0.2864956202545901
# differential_evolution step 859: f(x)= 0.2864956202545901
# differential_evolution step 860: f(x)= 0.2864956202545901
# differential_evolution step 861: f(x)= 0.2864956202545901
# differential_evolution step 862: f(x)= 0.2864744402445328
# differential_evolution step 863: f(x)= 0.28630198185701317
# differential_evolution step 864: f(x)= 0.28630198185701317
# differential_evolution step 865: f(x)= 0.28630198185701317
# differential_evolution step 866: f(x)= 0.28630198185701317
# differential_evolution step 867: f(x)= 0.28630198185701317
# differential_evolution step 868: f(x)= 0.28619435919605646
# differential_evolution step 869: f(x)= 0.28619435919605646
# differential_evolution step 870: f(x)= 0.28619435919605646
# differential_evolution step 871: f(x)= 0.28619435919605646
# differential_evolution step 872: f(x)= 0.28619435919605646
# differential_evolution step 873: f(x)= 0.28604140553023216
# differential_evolution step 874: f(x)= 0.28604140553023216
# differential_evolution step 875: f(x)= 0.2859380973766511
# differential_evolution step 876: f(x)= 0.28587097390965177
# differential_evolution step 877: f(x)= 0.2856271414846737
# differential_evolution step 878: f(x)= 0.2856271414846737
# differential_evolution step 879: f(x)= 0.2856271414846737
# differential_evolution step 880: f(x)= 0.2856271414846737
# differential_evolution step 881: f(x)= 0.2856271414846737
# differential_evolution step 882: f(x)= 0.2856271414846737
# differential_evolution step 883: f(x)= 0.2856271414846737
# differential_evolution step 884: f(x)= 0.28552383178441504
# differential_evolution step 885: f(x)= 0.28552383178441504
# differential_evolution step 886: f(x)= 0.28552383178441504
# differential_evolution step 887: f(x)= 0.28552383178441504
# differential_evolution step 888: f(x)= 0.2854621929119391
# differential_evolution step 889: f(x)= 0.2854621929119391
# differential_evolution step 890: f(x)= 0.2850854758936989
# differential_evolution step 891: f(x)= 0.2850854758936989
# differential_evolution step 892: f(x)= 0.28454153074484334
# differential_evolution step 893: f(x)= 0.28454153074484334
# differential_evolution step 894: f(x)= 0.28454153074484334
# differential_evolution step 895: f(x)= 0.28454153074484334
# differential_evolution step 896: f(x)= 0.28454153074484334
# differential_evolution step 897: f(x)= 0.28454153074484334
# differential_evolution step 898: f(x)= 0.28454153074484334
# differential_evolution step 899: f(x)= 0.28454153074484334
# differential_evolution step 900: f(x)= 0.28454153074484334
# differential_evolution step 901: f(x)= 0.28454153074484334
# differential_evolution step 902: f(x)= 0.2845289560659687
# differential_evolution step 903: f(x)= 0.2844883478219924
# differential_evolution step 904: f(x)= 0.2844883478219924
# differential_evolution step 905: f(x)= 0.28429455939256304
# differential_evolution step 906: f(x)= 0.28429455939256304
# differential_evolution step 907: f(x)= 0.28429455939256304
# differential_evolution step 908: f(x)= 0.28429455939256304
# differential_evolution step 909: f(x)= 0.28429455939256304
# differential_evolution step 910: f(x)= 0.28429455939256304
# differential_evolution step 911: f(x)= 0.2841015517108964
# differential_evolution step 912: f(x)= 0.2841015517108964
# differential_evolution step 913: f(x)= 0.2841015517108964
# differential_evolution step 914: f(x)= 0.2841015517108964
# differential_evolution step 915: f(x)= 0.2841015517108964
# differential_evolution step 916: f(x)= 0.283498710008821
# differential_evolution step 917: f(x)= 0.283498710008821
# differential_evolution step 918: f(x)= 0.283498710008821
# differential_evolution step 919: f(x)= 0.28341251840177945
# differential_evolution step 920: f(x)= 0.28341251840177945
# differential_evolution step 921: f(x)= 0.28341251840177945
# differential_evolution step 922: f(x)= 0.28341251840177945
# differential_evolution step 923: f(x)= 0.28341251840177945
# differential_evolution step 924: f(x)= 0.28341251840177945
# differential_evolution step 925: f(x)= 0.2830402813419093
# differential_evolution step 926: f(x)= 0.2830402813419093
# differential_evolution step 927: f(x)= 0.2830402813419093
# differential_evolution step 928: f(x)= 0.2830402813419093
# differential_evolution step 929: f(x)= 0.2830402813419093
# differential_evolution step 930: f(x)= 0.2830402813419093
# differential_evolution step 931: f(x)= 0.2830402813419093
# differential_evolution step 932: f(x)= 0.2830402813419093
# differential_evolution step 933: f(x)= 0.2829514817599379
# differential_evolution step 934: f(x)= 0.2827965597928222
# differential_evolution step 935: f(x)= 0.2822415940205501
# differential_evolution step 936: f(x)= 0.28090559177497043
# differential_evolution step 937: f(x)= 0.28090559177497043
# differential_evolution step 938: f(x)= 0.28031448692789723
# differential_evolution step 939: f(x)= 0.28031448692789723
# differential_evolution step 940: f(x)= 0.28031448692789723
# differential_evolution step 941: f(x)= 0.28031448692789723
# differential_evolution step 942: f(x)= 0.28031448692789723
# differential_evolution step 943: f(x)= 0.28031448692789723
# differential_evolution step 944: f(x)= 0.28031448692789723
# differential_evolution step 945: f(x)= 0.28031448692789723
# differential_evolution step 946: f(x)= 0.28031448692789723
# differential_evolution step 947: f(x)= 0.28031448692789723
# differential_evolution step 948: f(x)= 0.28031448692789723
# differential_evolution step 949: f(x)= 0.28031448692789723
# differential_evolution step 950: f(x)= 0.279732049009019
# differential_evolution step 951: f(x)= 0.279732049009019
# differential_evolution step 952: f(x)= 0.279732049009019
# differential_evolution step 953: f(x)= 0.279732049009019
# differential_evolution step 954: f(x)= 0.279732049009019
# differential_evolution step 955: f(x)= 0.279732049009019
# differential_evolution step 956: f(x)= 0.279732049009019
# differential_evolution step 957: f(x)= 0.279732049009019
# differential_evolution step 958: f(x)= 0.279732049009019
# differential_evolution step 959: f(x)= 0.279732049009019
# differential_evolution step 960: f(x)= 0.279732049009019
# differential_evolution step 961: f(x)= 0.279732049009019
# differential_evolution step 962: f(x)= 0.279732049009019
# differential_evolution step 963: f(x)= 0.27965339587865456
# differential_evolution step 964: f(x)= 0.27965339587865456
# differential_evolution step 965: f(x)= 0.27941579779139075
# differential_evolution step 966: f(x)= 0.27941579779139075
# differential_evolution step 967: f(x)= 0.2790680623460311
# differential_evolution step 968: f(x)= 0.2790680623460311
# differential_evolution step 969: f(x)= 0.2790680623460311
# differential_evolution step 970: f(x)= 0.2790680623460311
# differential_evolution step 971: f(x)= 0.2790680623460311
# differential_evolution step 972: f(x)= 0.2790680623460311
# differential_evolution step 973: f(x)= 0.2790680623460311
# differential_evolution step 974: f(x)= 0.2786134896237705
# differential_evolution step 975: f(x)= 0.2786134896237705
# differential_evolution step 976: f(x)= 0.2786134896237705
# differential_evolution step 977: f(x)= 0.2785496809435231
# differential_evolution step 978: f(x)= 0.2779880775227227
# differential_evolution step 979: f(x)= 0.2779880775227227
# differential_evolution step 980: f(x)= 0.2779880775227227
# differential_evolution step 981: f(x)= 0.2779880775227227
# differential_evolution step 982: f(x)= 0.2779880775227227
# differential_evolution step 983: f(x)= 0.2779880775227227
# differential_evolution step 984: f(x)= 0.2779880775227227
# differential_evolution step 985: f(x)= 0.2779880775227227
# differential_evolution step 986: f(x)= 0.2779880775227227
# differential_evolution step 987: f(x)= 0.2779880775227227
# differential_evolution step 988: f(x)= 0.2778037552534782
# differential_evolution step 989: f(x)= 0.2778037552534782
# differential_evolution step 990: f(x)= 0.2774489688010113
# differential_evolution step 991: f(x)= 0.2774489688010113
# differential_evolution step 992: f(x)= 0.2765297171116425
# differential_evolution step 993: f(x)= 0.2765297171116425
# differential_evolution step 994: f(x)= 0.2765297171116425
# differential_evolution step 995: f(x)= 0.2765297171116425
# differential_evolution step 996: f(x)= 0.2765297171116425
# differential_evolution step 997: f(x)= 0.2765297171116425
# differential_evolution step 998: f(x)= 0.2765297171116425
# differential_evolution step 999: f(x)= 0.2765297171116425
# differential_evolution step 1000: f(x)= 0.2765297171116425
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.3462, r_e=1.1888, n=0.3253, x_0=34.6386
# Sérsic 2: I_e=0.1054, r_e=26.7695, n=2.0032, x_0=47.7517
# Sérsic 3: I_e=0.2063, r_e=1.2901, n=0.1000, x_0=54.3941
# Sérsic 4: I_e=0.0748, r_e=3.2563, n=0.4146, x_0=66.9803
# Chi quadro minimo: 0.2728568866521021
# False

# %%
save_params_diff(best_params, radial_profile_SII, real_errors_SII, sigmas[3],
    x_axes, n_component, line_name="SII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_diff')
# Out:
# Sérsic 1: I_e=0.3462, r_e=1.1888, n=0.3253, x_0=34.6386
# Sérsic 2: I_e=0.1054, r_e=26.7695, n=2.0032, x_0=47.7517
# Sérsic 3: I_e=0.2063, r_e=1.2901, n=0.1000, x_0=54.3941
# Sérsic 4: I_e=0.0748, r_e=3.2563, n=0.4146, x_0=66.9803
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#lower_bounds, upper_bounds = zip(*bounds)
#bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_SII, covariance_SII = curve_fit(lambda x, *params: model_convolved(x, sigmas[3], *params), x_axes, 
                                             radial_profile_SII, p0=result.x, sigma = real_errors_SII)#, bounds = bounds_list)

print("Optimize parameters with curve fit:")
chi2_reduced_SII, dof_SII, chi2_SII = save_params(params_curve_SII, covariance_SII, radial_profile_SII, real_errors_SII, sigmas[3],
    x_axes, n_component, line_name="SII", output_prefix="fit")
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_4612\568277273.py:11: RuntimeWarning: overflow encountered in exp
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\anaconda3\Lib\site-packages\scipy\signal\_signaltools.py:568: RuntimeWarning: invalid value encountered in multiply
#   ret = ifft(sp1 * sp2, fshape, axes=axes)
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_4612\568277273.py:24: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.2755, r_e=1.3905, n=0.4907, x_0=34.5914
# Sérsic 2: I_e=0.0931, r_e=27.7161, n=2.1071, x_0=47.7143
# Sérsic 3: I_e=0.0532, r_e=1.7647, n=0.0344, x_0=54.3412
# Sérsic 4: I_e=0.0176, r_e=10.2545, n=1.4280, x_0=66.4728
# [1.51971781e-01 3.05488738e-01 4.34568434e-01 1.30143761e-01
#  1.55204100e-02 3.42602253e+00 1.26076291e-01 7.64069951e-02
#  1.86300835e+01 7.96910875e+00 3.68068972e+00 2.75030632e-01
#  2.37685104e-02 1.13932231e+01 9.24867301e-01 5.08533510e-01]
# 1.3378969139757981

# %%
# Plots:
plot_curve(x_axes, params_curve_SII, radial_profile_SII, real_errors_SII, sigmas[3], r"Radial profile [SII]")
plt.savefig('Radial_profile_SII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## [OIII]

# %%
mask_OIII = (wv > l_OIII-8)*(wv < l_OIII+8)
image_OIII = image_cut[:, mask_OIII] 
image_error_OIII = image_error_cut[:, mask_OIII]
radial_profile_OIII = np.sum(image_OIII, axis = 1)
radial_profile_error_OIII = np.sqrt(np.sum(image_error_OIII**2, axis = 1))
real_errors_OIII = np.sqrt(radial_profile_error_OIII**2+(sky_err[2])**2+(0.04*radial_profile_OIII)**2)

plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_OIII)
plt.plot(x_axes, radial_profile_error_OIII)
plt.plot(x_axes, radial_profile_HB)
plt.title(r'[OIII]')
# Out:
# Text(0.5, 1.0, '[OIII]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds =bounds_HA
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_OIII, sigmas[4])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 41035.18315948665
# differential_evolution step 2: f(x)= 28939.279798602343
# differential_evolution step 3: f(x)= 22985.11094409717
# differential_evolution step 4: f(x)= 20350.993518043204
# differential_evolution step 5: f(x)= 6045.862488441353
# differential_evolution step 6: f(x)= 6045.862488441353
# differential_evolution step 7: f(x)= 5035.496106949828
# differential_evolution step 8: f(x)= 3649.4020890702336
# differential_evolution step 9: f(x)= 3649.4020890702336
# differential_evolution step 10: f(x)= 3649.4020890702336
# differential_evolution step 11: f(x)= 3641.3274617483203
# differential_evolution step 12: f(x)= 739.237958632181
# differential_evolution step 13: f(x)= 382.2976199375914
# differential_evolution step 14: f(x)= 382.2976199375914
# differential_evolution step 15: f(x)= 382.2976199375914
# differential_evolution step 16: f(x)= 382.2976199375914
# differential_evolution step 17: f(x)= 382.2976199375914
# differential_evolution step 18: f(x)= 382.2976199375914
# differential_evolution step 19: f(x)= 382.2976199375914
# differential_evolution step 20: f(x)= 382.2976199375914
# differential_evolution step 21: f(x)= 382.2976199375914
# differential_evolution step 22: f(x)= 176.63869898564096
# differential_evolution step 23: f(x)= 176.63869898564096
# differential_evolution step 24: f(x)= 176.63869898564096
# differential_evolution step 25: f(x)= 176.63869898564096
# differential_evolution step 26: f(x)= 175.02495073984022
# differential_evolution step 27: f(x)= 72.28599769671402
# differential_evolution step 28: f(x)= 72.28599769671402
# differential_evolution step 29: f(x)= 68.73898675272385
# differential_evolution step 30: f(x)= 65.5019674499236
# differential_evolution step 31: f(x)= 65.5019674499236
# differential_evolution step 32: f(x)= 46.44689356720505
# differential_evolution step 33: f(x)= 46.44689356720505
# differential_evolution step 34: f(x)= 38.7043358388109
# differential_evolution step 35: f(x)= 16.766281796604527
# differential_evolution step 36: f(x)= 14.158731654013762
# differential_evolution step 37: f(x)= 14.158731654013762
# differential_evolution step 38: f(x)= 14.158731654013762
# differential_evolution step 39: f(x)= 13.802611598418434
# differential_evolution step 40: f(x)= 13.802611598418434
# differential_evolution step 41: f(x)= 11.736534753778276
# differential_evolution step 42: f(x)= 11.736534753778276
# differential_evolution step 43: f(x)= 11.736534753778276
# differential_evolution step 44: f(x)= 10.067746088269129
# differential_evolution step 45: f(x)= 10.067746088269129
# differential_evolution step 46: f(x)= 9.13820856155902
# differential_evolution step 47: f(x)= 4.671868440467369
# differential_evolution step 48: f(x)= 4.671868440467369
# differential_evolution step 49: f(x)= 4.671868440467369
# differential_evolution step 50: f(x)= 4.671868440467369
# differential_evolution step 51: f(x)= 4.671868440467369
# differential_evolution step 52: f(x)= 4.671868440467369
# differential_evolution step 53: f(x)= 4.671868440467369
# differential_evolution step 54: f(x)= 4.671868440467369
# differential_evolution step 55: f(x)= 4.671868440467369
# differential_evolution step 56: f(x)= 4.671868440467369
# differential_evolution step 57: f(x)= 4.671868440467369
# differential_evolution step 58: f(x)= 4.671868440467369
# differential_evolution step 59: f(x)= 4.671868440467369
# differential_evolution step 60: f(x)= 4.671868440467369
# differential_evolution step 61: f(x)= 4.671868440467369
# differential_evolution step 62: f(x)= 3.584376559226941
# differential_evolution step 63: f(x)= 2.0969746547863006
# differential_evolution step 64: f(x)= 2.0969746547863006
# differential_evolution step 65: f(x)= 2.0969746547863006
# differential_evolution step 66: f(x)= 2.0969746547863006
# differential_evolution step 67: f(x)= 2.0969746547863006
# differential_evolution step 68: f(x)= 1.4934581149600983
# differential_evolution step 69: f(x)= 1.4934581149600983
# differential_evolution step 70: f(x)= 1.4934581149600983
# differential_evolution step 71: f(x)= 1.4934581149600983
# differential_evolution step 72: f(x)= 1.4934581149600983
# differential_evolution step 73: f(x)= 1.4934581149600983
# differential_evolution step 74: f(x)= 1.4934581149600983
# differential_evolution step 75: f(x)= 1.4934581149600983
# differential_evolution step 76: f(x)= 1.4934581149600983
# differential_evolution step 77: f(x)= 1.4934581149600983
# differential_evolution step 78: f(x)= 0.9902130550254359
# differential_evolution step 79: f(x)= 0.9902130550254359
# differential_evolution step 80: f(x)= 0.9902130550254359
# differential_evolution step 81: f(x)= 0.9902130550254359
# differential_evolution step 82: f(x)= 0.9902130550254359
# differential_evolution step 83: f(x)= 0.9902130550254359
# differential_evolution step 84: f(x)= 0.9902130550254359
# differential_evolution step 85: f(x)= 0.9902130550254359
# differential_evolution step 86: f(x)= 0.9902130550254359
# differential_evolution step 87: f(x)= 0.9902130550254359
# differential_evolution step 88: f(x)= 0.9902130550254359
# differential_evolution step 89: f(x)= 0.9902130550254359
# differential_evolution step 90: f(x)= 0.9902130550254359
# differential_evolution step 91: f(x)= 0.9902130550254359
# differential_evolution step 92: f(x)= 0.9902130550254359
# differential_evolution step 93: f(x)= 0.9902130550254359
# differential_evolution step 94: f(x)= 0.9902130550254359
# differential_evolution step 95: f(x)= 0.9902130550254359
# differential_evolution step 96: f(x)= 0.9902130550254359
# differential_evolution step 97: f(x)= 0.9902130550254359
# differential_evolution step 98: f(x)= 0.9902130550254359
# differential_evolution step 99: f(x)= 0.9902130550254359
# differential_evolution step 100: f(x)= 0.6587101407955663
# differential_evolution step 101: f(x)= 0.6587101407955663
# differential_evolution step 102: f(x)= 0.6587101407955663
# differential_evolution step 103: f(x)= 0.6587101407955663
# differential_evolution step 104: f(x)= 0.6587101407955663
# differential_evolution step 105: f(x)= 0.6587101407955663
# differential_evolution step 106: f(x)= 0.6587101407955663
# differential_evolution step 107: f(x)= 0.6587101407955663
# differential_evolution step 108: f(x)= 0.5060945746252365
# differential_evolution step 109: f(x)= 0.5060945746252365
# differential_evolution step 110: f(x)= 0.5060945746252365
# differential_evolution step 111: f(x)= 0.5060945746252365
# differential_evolution step 112: f(x)= 0.5060945746252365
# differential_evolution step 113: f(x)= 0.5060945746252365
# differential_evolution step 114: f(x)= 0.5060945746252365
# differential_evolution step 115: f(x)= 0.5060945746252365
# differential_evolution step 116: f(x)= 0.5060945746252365
# differential_evolution step 117: f(x)= 0.5060945746252365
# differential_evolution step 118: f(x)= 0.5060945746252365
# differential_evolution step 119: f(x)= 0.5060945746252365
# differential_evolution step 120: f(x)= 0.5017495964029083
# differential_evolution step 121: f(x)= 0.5017495964029083
# differential_evolution step 122: f(x)= 0.5017495964029083
# differential_evolution step 123: f(x)= 0.5017495964029083
# differential_evolution step 124: f(x)= 0.5017495964029083
# differential_evolution step 125: f(x)= 0.5017495964029083
# differential_evolution step 126: f(x)= 0.5017495964029083
# differential_evolution step 127: f(x)= 0.4981239143493621
# differential_evolution step 128: f(x)= 0.46721734169319834
# differential_evolution step 129: f(x)= 0.46721734169319834
# differential_evolution step 130: f(x)= 0.46721734169319834
# differential_evolution step 131: f(x)= 0.46721734169319834
# differential_evolution step 132: f(x)= 0.46721734169319834
# differential_evolution step 133: f(x)= 0.46721734169319834
# differential_evolution step 134: f(x)= 0.46721734169319834
# differential_evolution step 135: f(x)= 0.46721734169319834
# differential_evolution step 136: f(x)= 0.46721734169319834
# differential_evolution step 137: f(x)= 0.42323112538406427
# differential_evolution step 138: f(x)= 0.38460743786716806
# differential_evolution step 139: f(x)= 0.38460743786716806
# differential_evolution step 140: f(x)= 0.38460743786716806
# differential_evolution step 141: f(x)= 0.38460743786716806
# differential_evolution step 142: f(x)= 0.37814682098220337
# differential_evolution step 143: f(x)= 0.37814682098220337
# differential_evolution step 144: f(x)= 0.37520275235379213
# differential_evolution step 145: f(x)= 0.37520275235379213
# differential_evolution step 146: f(x)= 0.37520275235379213
# differential_evolution step 147: f(x)= 0.37520275235379213
# differential_evolution step 148: f(x)= 0.37520275235379213
# differential_evolution step 149: f(x)= 0.3450610212891103
# differential_evolution step 150: f(x)= 0.3450610212891103
# differential_evolution step 151: f(x)= 0.3450610212891103
# differential_evolution step 152: f(x)= 0.3450610212891103
# differential_evolution step 153: f(x)= 0.3450610212891103
# differential_evolution step 154: f(x)= 0.3450610212891103
# differential_evolution step 155: f(x)= 0.3154656132196262
# differential_evolution step 156: f(x)= 0.3154656132196262
# differential_evolution step 157: f(x)= 0.3154656132196262
# differential_evolution step 158: f(x)= 0.3130244965590035
# differential_evolution step 159: f(x)= 0.3130244965590035
# differential_evolution step 160: f(x)= 0.3130244965590035
# differential_evolution step 161: f(x)= 0.3130244965590035
# differential_evolution step 162: f(x)= 0.3130244965590035
# differential_evolution step 163: f(x)= 0.3130244965590035
# differential_evolution step 164: f(x)= 0.3130244965590035
# differential_evolution step 165: f(x)= 0.3130244965590035
# differential_evolution step 166: f(x)= 0.3130244965590035
# differential_evolution step 167: f(x)= 0.3130244965590035
# differential_evolution step 168: f(x)= 0.3130244965590035
# differential_evolution step 169: f(x)= 0.3130244965590035
# differential_evolution step 170: f(x)= 0.27985163202735736
# differential_evolution step 171: f(x)= 0.27985163202735736
# differential_evolution step 172: f(x)= 0.27985163202735736
# differential_evolution step 173: f(x)= 0.27985163202735736
# differential_evolution step 174: f(x)= 0.27985163202735736
# differential_evolution step 175: f(x)= 0.2772846969400632
# differential_evolution step 176: f(x)= 0.2772846969400632
# differential_evolution step 177: f(x)= 0.2772846969400632
# differential_evolution step 178: f(x)= 0.2772846969400632
# differential_evolution step 179: f(x)= 0.27005450579516677
# differential_evolution step 180: f(x)= 0.27005450579516677
# differential_evolution step 181: f(x)= 0.27005450579516677
# differential_evolution step 182: f(x)= 0.27005450579516677
# differential_evolution step 183: f(x)= 0.27005450579516677
# differential_evolution step 184: f(x)= 0.27005450579516677
# differential_evolution step 185: f(x)= 0.27005450579516677
# differential_evolution step 186: f(x)= 0.27005450579516677
# differential_evolution step 187: f(x)= 0.24804540138784895
# differential_evolution step 188: f(x)= 0.24804540138784895
# differential_evolution step 189: f(x)= 0.24804540138784895
# differential_evolution step 190: f(x)= 0.24804540138784895
# differential_evolution step 191: f(x)= 0.24804540138784895
# differential_evolution step 192: f(x)= 0.24804540138784895
# differential_evolution step 193: f(x)= 0.24804540138784895
# differential_evolution step 194: f(x)= 0.24804540138784895
# differential_evolution step 195: f(x)= 0.24804540138784895
# differential_evolution step 196: f(x)= 0.24804540138784895
# differential_evolution step 197: f(x)= 0.24804540138784895
# differential_evolution step 198: f(x)= 0.2471186846252809
# differential_evolution step 199: f(x)= 0.2471186846252809
# differential_evolution step 200: f(x)= 0.2471186846252809
# differential_evolution step 201: f(x)= 0.2471186846252809
# differential_evolution step 202: f(x)= 0.2471186846252809
# differential_evolution step 203: f(x)= 0.2471186846252809
# differential_evolution step 204: f(x)= 0.23125157570354254
# differential_evolution step 205: f(x)= 0.23125157570354254
# differential_evolution step 206: f(x)= 0.23125157570354254
# differential_evolution step 207: f(x)= 0.23081428869543166
# differential_evolution step 208: f(x)= 0.23081428869543166
# differential_evolution step 209: f(x)= 0.23081428869543166
# differential_evolution step 210: f(x)= 0.23081428869543166
# differential_evolution step 211: f(x)= 0.23081428869543166
# differential_evolution step 212: f(x)= 0.23081428869543166
# differential_evolution step 213: f(x)= 0.23081428869543166
# differential_evolution step 214: f(x)= 0.23081428869543166
# differential_evolution step 215: f(x)= 0.23081428869543166
# differential_evolution step 216: f(x)= 0.23081428869543166
# differential_evolution step 217: f(x)= 0.2262649285770626
# differential_evolution step 218: f(x)= 0.2262649285770626
# differential_evolution step 219: f(x)= 0.2262649285770626
# differential_evolution step 220: f(x)= 0.2262649285770626
# differential_evolution step 221: f(x)= 0.2262649285770626
# differential_evolution step 222: f(x)= 0.2262649285770626
# differential_evolution step 223: f(x)= 0.2262649285770626
# differential_evolution step 224: f(x)= 0.2262649285770626
# differential_evolution step 225: f(x)= 0.2262649285770626
# differential_evolution step 226: f(x)= 0.2262649285770626
# differential_evolution step 227: f(x)= 0.2262649285770626
# differential_evolution step 228: f(x)= 0.2262649285770626
# differential_evolution step 229: f(x)= 0.2262649285770626
# differential_evolution step 230: f(x)= 0.2262649285770626
# differential_evolution step 231: f(x)= 0.2262649285770626
# differential_evolution step 232: f(x)= 0.2262649285770626
# differential_evolution step 233: f(x)= 0.2262649285770626
# differential_evolution step 234: f(x)= 0.2262649285770626
# differential_evolution step 235: f(x)= 0.2262649285770626
# differential_evolution step 236: f(x)= 0.21758853325176852
# differential_evolution step 237: f(x)= 0.21758853325176852
# differential_evolution step 238: f(x)= 0.21758853325176852
# differential_evolution step 239: f(x)= 0.21508034355353156
# differential_evolution step 240: f(x)= 0.2112213895811974
# differential_evolution step 241: f(x)= 0.2112213895811974
# differential_evolution step 242: f(x)= 0.2112213895811974
# differential_evolution step 243: f(x)= 0.2112213895811974
# differential_evolution step 244: f(x)= 0.2112213895811974
# differential_evolution step 245: f(x)= 0.2112213895811974
# differential_evolution step 246: f(x)= 0.2112213895811974
# differential_evolution step 247: f(x)= 0.2112213895811974
# differential_evolution step 248: f(x)= 0.2112213895811974
# differential_evolution step 249: f(x)= 0.2112213895811974
# differential_evolution step 250: f(x)= 0.211109570436669
# differential_evolution step 251: f(x)= 0.211109570436669
# differential_evolution step 252: f(x)= 0.211109570436669
# differential_evolution step 253: f(x)= 0.20971874942664973
# differential_evolution step 254: f(x)= 0.20918047064013698
# differential_evolution step 255: f(x)= 0.20918047064013698
# differential_evolution step 256: f(x)= 0.20918047064013698
# differential_evolution step 257: f(x)= 0.2081362053249044
# differential_evolution step 258: f(x)= 0.20688630710147024
# differential_evolution step 259: f(x)= 0.20688630710147024
# differential_evolution step 260: f(x)= 0.20688630710147024
# differential_evolution step 261: f(x)= 0.20688630710147024
# differential_evolution step 262: f(x)= 0.2018009455993963
# differential_evolution step 263: f(x)= 0.2018009455993963
# differential_evolution step 264: f(x)= 0.2018009455993963
# differential_evolution step 265: f(x)= 0.2018009455993963
# differential_evolution step 266: f(x)= 0.2018009455993963
# differential_evolution step 267: f(x)= 0.2018009455993963
# differential_evolution step 268: f(x)= 0.2018009455993963
# differential_evolution step 269: f(x)= 0.2018009455993963
# differential_evolution step 270: f(x)= 0.2018009455993963
# differential_evolution step 271: f(x)= 0.2018009455993963
# differential_evolution step 272: f(x)= 0.2018009455993963
# differential_evolution step 273: f(x)= 0.2018009455993963
# differential_evolution step 274: f(x)= 0.2018009455993963
# differential_evolution step 275: f(x)= 0.2018009455993963
# differential_evolution step 276: f(x)= 0.20168479946125736
# differential_evolution step 277: f(x)= 0.20118565915165165
# differential_evolution step 278: f(x)= 0.20118565915165165
# differential_evolution step 279: f(x)= 0.20118565915165165
# differential_evolution step 280: f(x)= 0.20118565915165165
# differential_evolution step 281: f(x)= 0.20118565915165165
# differential_evolution step 282: f(x)= 0.20118565915165165
# differential_evolution step 283: f(x)= 0.20118565915165165
# differential_evolution step 284: f(x)= 0.20118565915165165
# differential_evolution step 285: f(x)= 0.20118565915165165
# differential_evolution step 286: f(x)= 0.20118565915165165
# differential_evolution step 287: f(x)= 0.20118565915165165
# differential_evolution step 288: f(x)= 0.20118565915165165
# differential_evolution step 289: f(x)= 0.20118565915165165
# differential_evolution step 290: f(x)= 0.20118565915165165
# differential_evolution step 291: f(x)= 0.20118565915165165
# differential_evolution step 292: f(x)= 0.20118565915165165
# differential_evolution step 293: f(x)= 0.20118565915165165
# differential_evolution step 294: f(x)= 0.20118565915165165
# differential_evolution step 295: f(x)= 0.20118565915165165
# differential_evolution step 296: f(x)= 0.2008354590135754
# differential_evolution step 297: f(x)= 0.1990037446294056
# differential_evolution step 298: f(x)= 0.1990037446294056
# differential_evolution step 299: f(x)= 0.1990037446294056
# differential_evolution step 300: f(x)= 0.1990037446294056
# differential_evolution step 301: f(x)= 0.1990037446294056
# differential_evolution step 302: f(x)= 0.19683871466233177
# differential_evolution step 303: f(x)= 0.19683871466233177
# differential_evolution step 304: f(x)= 0.19650405815194597
# differential_evolution step 305: f(x)= 0.19650405815194597
# differential_evolution step 306: f(x)= 0.19650405815194597
# differential_evolution step 307: f(x)= 0.19650405815194597
# differential_evolution step 308: f(x)= 0.19587211435069515
# differential_evolution step 309: f(x)= 0.19587211435069515
# differential_evolution step 310: f(x)= 0.19587211435069515
# differential_evolution step 311: f(x)= 0.19587211435069515
# differential_evolution step 312: f(x)= 0.19587211435069515
# differential_evolution step 313: f(x)= 0.19587211435069515
# differential_evolution step 314: f(x)= 0.19587211435069515
# differential_evolution step 315: f(x)= 0.19587211435069515
# differential_evolution step 316: f(x)= 0.19587211435069515
# differential_evolution step 317: f(x)= 0.19587211435069515
# differential_evolution step 318: f(x)= 0.19587211435069515
# differential_evolution step 319: f(x)= 0.19587211435069515
# differential_evolution step 320: f(x)= 0.19587211435069515
# differential_evolution step 321: f(x)= 0.19587211435069515
# differential_evolution step 322: f(x)= 0.19551629348008956
# differential_evolution step 323: f(x)= 0.19551629348008956
# differential_evolution step 324: f(x)= 0.19551629348008956
# differential_evolution step 325: f(x)= 0.19551629348008956
# differential_evolution step 326: f(x)= 0.19544137763864444
# differential_evolution step 327: f(x)= 0.19498395731478396
# differential_evolution step 328: f(x)= 0.19498395731478396
# differential_evolution step 329: f(x)= 0.1918627276789267
# differential_evolution step 330: f(x)= 0.1918627276789267
# differential_evolution step 331: f(x)= 0.1918627276789267
# differential_evolution step 332: f(x)= 0.1918627276789267
# differential_evolution step 333: f(x)= 0.1918627276789267
# differential_evolution step 334: f(x)= 0.1918627276789267
# differential_evolution step 335: f(x)= 0.1918627276789267
# differential_evolution step 336: f(x)= 0.19099246486646484
# differential_evolution step 337: f(x)= 0.19099246486646484
# differential_evolution step 338: f(x)= 0.19099246486646484
# differential_evolution step 339: f(x)= 0.19099246486646484
# differential_evolution step 340: f(x)= 0.19099246486646484
# differential_evolution step 341: f(x)= 0.19099246486646484
# differential_evolution step 342: f(x)= 0.19099246486646484
# differential_evolution step 343: f(x)= 0.19099246486646484
# differential_evolution step 344: f(x)= 0.19099246486646484
# differential_evolution step 345: f(x)= 0.19014734165579125
# differential_evolution step 346: f(x)= 0.19014734165579125
# differential_evolution step 347: f(x)= 0.19014734165579125
# differential_evolution step 348: f(x)= 0.19014734165579125
# differential_evolution step 349: f(x)= 0.19014734165579125
# differential_evolution step 350: f(x)= 0.19014734165579125
# differential_evolution step 351: f(x)= 0.18834327574871712
# differential_evolution step 352: f(x)= 0.18748036616160238
# differential_evolution step 353: f(x)= 0.18748036616160238
# differential_evolution step 354: f(x)= 0.18748027838782638
# differential_evolution step 355: f(x)= 0.18748027838782638
# differential_evolution step 356: f(x)= 0.18748027838782638
# differential_evolution step 357: f(x)= 0.18748027838782638
# differential_evolution step 358: f(x)= 0.18748027838782638
# differential_evolution step 359: f(x)= 0.18748027838782638
# differential_evolution step 360: f(x)= 0.18748027838782638
# differential_evolution step 361: f(x)= 0.18748027838782638
# differential_evolution step 362: f(x)= 0.18748027838782638
# differential_evolution step 363: f(x)= 0.18611228905345767
# differential_evolution step 364: f(x)= 0.18611228905345767
# differential_evolution step 365: f(x)= 0.18611228905345767
# differential_evolution step 366: f(x)= 0.18611228905345767
# differential_evolution step 367: f(x)= 0.18611228905345767
# differential_evolution step 368: f(x)= 0.18611228905345767
# differential_evolution step 369: f(x)= 0.18611228905345767
# differential_evolution step 370: f(x)= 0.18611228905345767
# differential_evolution step 371: f(x)= 0.18611228905345767
# differential_evolution step 372: f(x)= 0.18611228905345767
# differential_evolution step 373: f(x)= 0.18611228905345767
# differential_evolution step 374: f(x)= 0.18611228905345767
# differential_evolution step 375: f(x)= 0.18611228905345767
# differential_evolution step 376: f(x)= 0.18611228905345767
# differential_evolution step 377: f(x)= 0.18611228905345767
# differential_evolution step 378: f(x)= 0.18611228905345767
# differential_evolution step 379: f(x)= 0.18611228905345767
# differential_evolution step 380: f(x)= 0.18611228905345767
# differential_evolution step 381: f(x)= 0.18611228905345767
# differential_evolution step 382: f(x)= 0.18611228905345767
# differential_evolution step 383: f(x)= 0.18611228905345767
# differential_evolution step 384: f(x)= 0.18611228905345767
# differential_evolution step 385: f(x)= 0.18611228905345767
# differential_evolution step 386: f(x)= 0.18563266024378083
# differential_evolution step 387: f(x)= 0.18563266024378083
# differential_evolution step 388: f(x)= 0.18563266024378083
# differential_evolution step 389: f(x)= 0.18563266024378083
# differential_evolution step 390: f(x)= 0.18563266024378083
# differential_evolution step 391: f(x)= 0.18563266024378083
# differential_evolution step 392: f(x)= 0.18563266024378083
# differential_evolution step 393: f(x)= 0.18557042449253858
# differential_evolution step 394: f(x)= 0.18557042449253858
# differential_evolution step 395: f(x)= 0.18557042449253858
# differential_evolution step 396: f(x)= 0.18557042449253858
# differential_evolution step 397: f(x)= 0.18557042449253858
# differential_evolution step 398: f(x)= 0.18557042449253858
# differential_evolution step 399: f(x)= 0.18557042449253858
# differential_evolution step 400: f(x)= 0.18557042449253858
# differential_evolution step 401: f(x)= 0.18557042449253858
# differential_evolution step 402: f(x)= 0.18488113840626494
# differential_evolution step 403: f(x)= 0.18488113840626494
# differential_evolution step 404: f(x)= 0.18488113840626494
# differential_evolution step 405: f(x)= 0.18488113840626494
# differential_evolution step 406: f(x)= 0.18488113840626494
# differential_evolution step 407: f(x)= 0.18488113840626494
# differential_evolution step 408: f(x)= 0.18488113840626494
# differential_evolution step 409: f(x)= 0.18488113840626494
# differential_evolution step 410: f(x)= 0.18488113840626494
# differential_evolution step 411: f(x)= 0.18488113840626494
# differential_evolution step 412: f(x)= 0.18488113840626494
# differential_evolution step 413: f(x)= 0.18488113840626494
# differential_evolution step 414: f(x)= 0.18488113840626494
# differential_evolution step 415: f(x)= 0.18488113840626494
# differential_evolution step 416: f(x)= 0.18488113840626494
# differential_evolution step 417: f(x)= 0.1843783391488568
# differential_evolution step 418: f(x)= 0.1843783391488568
# differential_evolution step 419: f(x)= 0.18422786653787881
# differential_evolution step 420: f(x)= 0.18422786653787881
# differential_evolution step 421: f(x)= 0.18422786653787881
# differential_evolution step 422: f(x)= 0.18422786653787881
# differential_evolution step 423: f(x)= 0.18422786653787881
# differential_evolution step 424: f(x)= 0.18422786653787881
# differential_evolution step 425: f(x)= 0.18422786653787881
# differential_evolution step 426: f(x)= 0.18406500288919855
# differential_evolution step 427: f(x)= 0.18406500288919855
# differential_evolution step 428: f(x)= 0.18406500288919855
# differential_evolution step 429: f(x)= 0.18406500288919855
# differential_evolution step 430: f(x)= 0.18406500288919855
# differential_evolution step 431: f(x)= 0.18406500288919855
# differential_evolution step 432: f(x)= 0.18406500288919855
# differential_evolution step 433: f(x)= 0.18406500288919855
# differential_evolution step 434: f(x)= 0.18406500288919855
# differential_evolution step 435: f(x)= 0.18406500288919855
# differential_evolution step 436: f(x)= 0.18406500288919855
# differential_evolution step 437: f(x)= 0.18406500288919855
# differential_evolution step 438: f(x)= 0.18406500288919855
# differential_evolution step 439: f(x)= 0.18406500288919855
# differential_evolution step 440: f(x)= 0.18406500288919855
# differential_evolution step 441: f(x)= 0.18406500288919855
# differential_evolution step 442: f(x)= 0.18406500288919855
# differential_evolution step 443: f(x)= 0.18406500288919855
# differential_evolution step 444: f(x)= 0.18406500288919855
# differential_evolution step 445: f(x)= 0.18406500288919855
# differential_evolution step 446: f(x)= 0.18406500288919855
# differential_evolution step 447: f(x)= 0.18406500288919855
# differential_evolution step 448: f(x)= 0.18406500288919855
# differential_evolution step 449: f(x)= 0.18406500288919855
# differential_evolution step 450: f(x)= 0.18400193491558253
# differential_evolution step 451: f(x)= 0.18400193491558253
# differential_evolution step 452: f(x)= 0.18400193491558253
# differential_evolution step 453: f(x)= 0.18400193491558253
# differential_evolution step 454: f(x)= 0.18400193491558253
# differential_evolution step 455: f(x)= 0.18400193491558253
# differential_evolution step 456: f(x)= 0.18400193491558253
# differential_evolution step 457: f(x)= 0.18399216143438732
# differential_evolution step 458: f(x)= 0.18399216143438732
# differential_evolution step 459: f(x)= 0.18399216143438732
# differential_evolution step 460: f(x)= 0.18399216143438732
# differential_evolution step 461: f(x)= 0.18399216143438732
# differential_evolution step 462: f(x)= 0.18399216143438732
# differential_evolution step 463: f(x)= 0.18385961643214302
# differential_evolution step 464: f(x)= 0.18385961643214302
# differential_evolution step 465: f(x)= 0.18356041068244508
# differential_evolution step 466: f(x)= 0.18356041068244508
# differential_evolution step 467: f(x)= 0.18356041068244508
# differential_evolution step 468: f(x)= 0.18356041068244508
# differential_evolution step 469: f(x)= 0.18356041068244508
# differential_evolution step 470: f(x)= 0.18356041068244508
# differential_evolution step 471: f(x)= 0.18356041068244508
# differential_evolution step 472: f(x)= 0.18356041068244508
# differential_evolution step 473: f(x)= 0.18356041068244508
# differential_evolution step 474: f(x)= 0.18356041068244508
# differential_evolution step 475: f(x)= 0.18356041068244508
# differential_evolution step 476: f(x)= 0.18356041068244508
# differential_evolution step 477: f(x)= 0.18356041068244508
# differential_evolution step 478: f(x)= 0.18356041068244508
# differential_evolution step 479: f(x)= 0.18356041068244508
# differential_evolution step 480: f(x)= 0.18356041068244508
# differential_evolution step 481: f(x)= 0.18356041068244508
# differential_evolution step 482: f(x)= 0.18356041068244508
# differential_evolution step 483: f(x)= 0.18356041068244508
# differential_evolution step 484: f(x)= 0.18356041068244508
# differential_evolution step 485: f(x)= 0.18356041068244508
# differential_evolution step 486: f(x)= 0.18356041068244508
# differential_evolution step 487: f(x)= 0.18356041068244508
# differential_evolution step 488: f(x)= 0.18356041068244508
# differential_evolution step 489: f(x)= 0.18356041068244508
# differential_evolution step 490: f(x)= 0.18356041068244508
# differential_evolution step 491: f(x)= 0.18314787546032577
# differential_evolution step 492: f(x)= 0.18314787546032577
# differential_evolution step 493: f(x)= 0.18314787546032577
# differential_evolution step 494: f(x)= 0.18314787546032577
# differential_evolution step 495: f(x)= 0.18309179518840268
# differential_evolution step 496: f(x)= 0.18309179518840268
# differential_evolution step 497: f(x)= 0.18309179518840268
# differential_evolution step 498: f(x)= 0.18287782195459834
# differential_evolution step 499: f(x)= 0.18287782195459834
# differential_evolution step 500: f(x)= 0.18287782195459834
# differential_evolution step 501: f(x)= 0.18287782195459834
# differential_evolution step 502: f(x)= 0.18287782195459834
# differential_evolution step 503: f(x)= 0.18287782195459834
# differential_evolution step 504: f(x)= 0.18287782195459834
# differential_evolution step 505: f(x)= 0.18287782195459834
# differential_evolution step 506: f(x)= 0.18287782195459834
# differential_evolution step 507: f(x)= 0.18287782195459834
# differential_evolution step 508: f(x)= 0.18287782195459834
# differential_evolution step 509: f(x)= 0.18287782195459834
# differential_evolution step 510: f(x)= 0.18287782195459834
# differential_evolution step 511: f(x)= 0.18287782195459834
# differential_evolution step 512: f(x)= 0.18287627186052627
# differential_evolution step 513: f(x)= 0.18260009613707937
# differential_evolution step 514: f(x)= 0.18260009613707937
# differential_evolution step 515: f(x)= 0.18260009613707937
# differential_evolution step 516: f(x)= 0.18260009613707937
# differential_evolution step 517: f(x)= 0.18260009613707937
# differential_evolution step 518: f(x)= 0.18260009613707937
# differential_evolution step 519: f(x)= 0.18260009613707937
# differential_evolution step 520: f(x)= 0.18236481803006696
# differential_evolution step 521: f(x)= 0.18236481803006696
# differential_evolution step 522: f(x)= 0.18236481803006696
# differential_evolution step 523: f(x)= 0.18236481803006696
# differential_evolution step 524: f(x)= 0.18236481803006696
# differential_evolution step 525: f(x)= 0.18236481803006696
# differential_evolution step 526: f(x)= 0.18214476723008666
# differential_evolution step 527: f(x)= 0.18214476723008666
# differential_evolution step 528: f(x)= 0.18214476723008666
# differential_evolution step 529: f(x)= 0.18214476723008666
# differential_evolution step 530: f(x)= 0.18214476723008666
# differential_evolution step 531: f(x)= 0.18214476723008666
# differential_evolution step 532: f(x)= 0.18214476723008666
# differential_evolution step 533: f(x)= 0.18214476723008666
# differential_evolution step 534: f(x)= 0.18214476723008666
# differential_evolution step 535: f(x)= 0.18214476723008666
# differential_evolution step 536: f(x)= 0.18214476723008666
# differential_evolution step 537: f(x)= 0.18214476723008666
# differential_evolution step 538: f(x)= 0.18214476723008666
# differential_evolution step 539: f(x)= 0.18214476723008666
# differential_evolution step 540: f(x)= 0.1819558871967146
# differential_evolution step 541: f(x)= 0.1819558871967146
# differential_evolution step 542: f(x)= 0.1819558871967146
# differential_evolution step 543: f(x)= 0.1819558871967146
# differential_evolution step 544: f(x)= 0.1819558871967146
# differential_evolution step 545: f(x)= 0.1819558871967146
# differential_evolution step 546: f(x)= 0.1819558871967146
# differential_evolution step 547: f(x)= 0.1819558871967146
# differential_evolution step 548: f(x)= 0.1819558871967146
# differential_evolution step 549: f(x)= 0.1819558871967146
# differential_evolution step 550: f(x)= 0.1819558871967146
# differential_evolution step 551: f(x)= 0.1819558871967146
# differential_evolution step 552: f(x)= 0.1819558871967146
# differential_evolution step 553: f(x)= 0.1819558871967146
# differential_evolution step 554: f(x)= 0.1819558871967146
# differential_evolution step 555: f(x)= 0.1819558871967146
# differential_evolution step 556: f(x)= 0.1819558871967146
# differential_evolution step 557: f(x)= 0.1819558871967146
# differential_evolution step 558: f(x)= 0.181851362383096
# differential_evolution step 559: f(x)= 0.181851362383096
# differential_evolution step 560: f(x)= 0.181851362383096
# differential_evolution step 561: f(x)= 0.181851362383096
# differential_evolution step 562: f(x)= 0.181851362383096
# differential_evolution step 563: f(x)= 0.181851362383096
# differential_evolution step 564: f(x)= 0.181851362383096
# differential_evolution step 565: f(x)= 0.181851362383096
# differential_evolution step 566: f(x)= 0.181851362383096
# differential_evolution step 567: f(x)= 0.181851362383096
# differential_evolution step 568: f(x)= 0.181851362383096
# differential_evolution step 569: f(x)= 0.181851362383096
# differential_evolution step 570: f(x)= 0.181851362383096
# differential_evolution step 571: f(x)= 0.181851362383096
# differential_evolution step 572: f(x)= 0.181851362383096
# differential_evolution step 573: f(x)= 0.181851362383096
# differential_evolution step 574: f(x)= 0.181851362383096
# differential_evolution step 575: f(x)= 0.181851362383096
# differential_evolution step 576: f(x)= 0.18158354822859987
# differential_evolution step 577: f(x)= 0.18158354822859987
# differential_evolution step 578: f(x)= 0.18158354822859987
# differential_evolution step 579: f(x)= 0.18158354822859987
# differential_evolution step 580: f(x)= 0.18158354822859987
# differential_evolution step 581: f(x)= 0.18158354822859987
# differential_evolution step 582: f(x)= 0.18158354822859987
# differential_evolution step 583: f(x)= 0.18158354822859987
# differential_evolution step 584: f(x)= 0.18158354822859987
# differential_evolution step 585: f(x)= 0.18158354822859987
# differential_evolution step 586: f(x)= 0.18158354822859987
# differential_evolution step 587: f(x)= 0.18158354822859987
# differential_evolution step 588: f(x)= 0.18158354822859987
# differential_evolution step 589: f(x)= 0.18158354822859987
# differential_evolution step 590: f(x)= 0.18158354822859987
# differential_evolution step 591: f(x)= 0.18147343392546444
# differential_evolution step 592: f(x)= 0.18147343392546444
# differential_evolution step 593: f(x)= 0.18147343392546444
# differential_evolution step 594: f(x)= 0.18124647988112286
# differential_evolution step 595: f(x)= 0.18124647988112286
# differential_evolution step 596: f(x)= 0.18124647988112286
# differential_evolution step 597: f(x)= 0.18122405243368003
# differential_evolution step 598: f(x)= 0.18122405243368003
# differential_evolution step 599: f(x)= 0.18122405243368003
# differential_evolution step 600: f(x)= 0.18122405243368003
# differential_evolution step 601: f(x)= 0.18122405243368003
# differential_evolution step 602: f(x)= 0.18122405243368003
# differential_evolution step 603: f(x)= 0.18122405243368003
# differential_evolution step 604: f(x)= 0.18122405243368003
# differential_evolution step 605: f(x)= 0.18122405243368003
# differential_evolution step 606: f(x)= 0.18122405243368003
# differential_evolution step 607: f(x)= 0.18122405243368003
# differential_evolution step 608: f(x)= 0.18122405243368003
# differential_evolution step 609: f(x)= 0.18122405243368003
# differential_evolution step 610: f(x)= 0.18122405243368003
# differential_evolution step 611: f(x)= 0.18122405243368003
# differential_evolution step 612: f(x)= 0.18122405243368003
# differential_evolution step 613: f(x)= 0.18122405243368003
# differential_evolution step 614: f(x)= 0.18122405243368003
# differential_evolution step 615: f(x)= 0.18122405243368003
# differential_evolution step 616: f(x)= 0.18122405243368003
# differential_evolution step 617: f(x)= 0.18122405243368003
# differential_evolution step 618: f(x)= 0.18122405243368003
# differential_evolution step 619: f(x)= 0.18122405243368003
# differential_evolution step 620: f(x)= 0.18122405243368003
# differential_evolution step 621: f(x)= 0.18122405243368003
# differential_evolution step 622: f(x)= 0.18122405243368003
# differential_evolution step 623: f(x)= 0.18122405243368003
# differential_evolution step 624: f(x)= 0.18122405243368003
# differential_evolution step 625: f(x)= 0.18122405243368003
# differential_evolution step 626: f(x)= 0.18122405243368003
# differential_evolution step 627: f(x)= 0.18122405243368003
# differential_evolution step 628: f(x)= 0.18122405243368003
# differential_evolution step 629: f(x)= 0.18122405243368003
# differential_evolution step 630: f(x)= 0.18122405243368003
# differential_evolution step 631: f(x)= 0.18122405243368003
# differential_evolution step 632: f(x)= 0.18120110249969448
# differential_evolution step 633: f(x)= 0.18120110249969448
# differential_evolution step 634: f(x)= 0.1811277099625916
# differential_evolution step 635: f(x)= 0.1811277099625916
# differential_evolution step 636: f(x)= 0.1811277099625916
# differential_evolution step 637: f(x)= 0.1811277099625916
# differential_evolution step 638: f(x)= 0.1811277099625916
# differential_evolution step 639: f(x)= 0.1811277099625916
# differential_evolution step 640: f(x)= 0.1811277099625916
# differential_evolution step 641: f(x)= 0.1811277099625916
# differential_evolution step 642: f(x)= 0.1811277099625916
# differential_evolution step 643: f(x)= 0.1811277099625916
# differential_evolution step 644: f(x)= 0.18086526157407432
# differential_evolution step 645: f(x)= 0.18086526157407432
# differential_evolution step 646: f(x)= 0.18086526157407432
# differential_evolution step 647: f(x)= 0.18086526157407432
# differential_evolution step 648: f(x)= 0.18085760514993193
# differential_evolution step 649: f(x)= 0.18085760514993193
# differential_evolution step 650: f(x)= 0.18085760514993193
# differential_evolution step 651: f(x)= 0.18085760514993193
# differential_evolution step 652: f(x)= 0.18085760514993193
# differential_evolution step 653: f(x)= 0.18085760514993193
# differential_evolution step 654: f(x)= 0.18085760514993193
# differential_evolution step 655: f(x)= 0.18085760514993193
# differential_evolution step 656: f(x)= 0.18085760514993193
# differential_evolution step 657: f(x)= 0.18085760514993193
# differential_evolution step 658: f(x)= 0.18085760514993193
# differential_evolution step 659: f(x)= 0.18085760514993193
# differential_evolution step 660: f(x)= 0.18085760514993193
# differential_evolution step 661: f(x)= 0.18085760514993193
# differential_evolution step 662: f(x)= 0.18085760514993193
# differential_evolution step 663: f(x)= 0.18085760514993193
# differential_evolution step 664: f(x)= 0.18085760514993193
# differential_evolution step 665: f(x)= 0.18085760514993193
# differential_evolution step 666: f(x)= 0.18085760514993193
# differential_evolution step 667: f(x)= 0.18085760514993193
# differential_evolution step 668: f(x)= 0.18085760514993193
# differential_evolution step 669: f(x)= 0.18085760514993193
# differential_evolution step 670: f(x)= 0.18085760514993193
# differential_evolution step 671: f(x)= 0.18085760514993193
# differential_evolution step 672: f(x)= 0.18085760514993193
# differential_evolution step 673: f(x)= 0.18085760514993193
# differential_evolution step 674: f(x)= 0.18085760514993193
# differential_evolution step 675: f(x)= 0.1807271468567024
# differential_evolution step 676: f(x)= 0.1807271468567024
# differential_evolution step 677: f(x)= 0.1807271468567024
# differential_evolution step 678: f(x)= 0.1807271468567024
# differential_evolution step 679: f(x)= 0.1807271468567024
# differential_evolution step 680: f(x)= 0.1807271468567024
# differential_evolution step 681: f(x)= 0.18071794972615923
# differential_evolution step 682: f(x)= 0.1806604325970198
# differential_evolution step 683: f(x)= 0.1806604325970198
# differential_evolution step 684: f(x)= 0.1806604325970198
# differential_evolution step 685: f(x)= 0.1806604325970198
# differential_evolution step 686: f(x)= 0.1806604325970198
# differential_evolution step 687: f(x)= 0.1806518525102498
# differential_evolution step 688: f(x)= 0.1806518525102498
# differential_evolution step 689: f(x)= 0.1804775301261647
# differential_evolution step 690: f(x)= 0.18044992753765454
# differential_evolution step 691: f(x)= 0.18028044304295435
# differential_evolution step 692: f(x)= 0.18028044304295435
# differential_evolution step 693: f(x)= 0.18028044304295435
# differential_evolution step 694: f(x)= 0.1801292552760421
# differential_evolution step 695: f(x)= 0.1801292552760421
# differential_evolution step 696: f(x)= 0.1801292552760421
# differential_evolution step 697: f(x)= 0.1801292552760421
# differential_evolution step 698: f(x)= 0.1801292552760421
# differential_evolution step 699: f(x)= 0.17993959472327428
# differential_evolution step 700: f(x)= 0.17993959472327428
# differential_evolution step 701: f(x)= 0.17945780226436395
# differential_evolution step 702: f(x)= 0.17945780226436395
# differential_evolution step 703: f(x)= 0.17945780226436395
# differential_evolution step 704: f(x)= 0.17945780226436395
# differential_evolution step 705: f(x)= 0.17919124606342882
# differential_evolution step 706: f(x)= 0.17919124606342882
# differential_evolution step 707: f(x)= 0.17818847625695924
# differential_evolution step 708: f(x)= 0.17818847625695924
# differential_evolution step 709: f(x)= 0.17706982846713415
# differential_evolution step 710: f(x)= 0.1764740848279895
# differential_evolution step 711: f(x)= 0.1764740848279895
# differential_evolution step 712: f(x)= 0.1763436677114466
# differential_evolution step 713: f(x)= 0.17631149391333048
# differential_evolution step 714: f(x)= 0.17631149391333048
# differential_evolution step 715: f(x)= 0.17631149391333048
# differential_evolution step 716: f(x)= 0.17631149391333048
# differential_evolution step 717: f(x)= 0.17631149391333048
# differential_evolution step 718: f(x)= 0.17631149391333048
# differential_evolution step 719: f(x)= 0.17631149391333048
# differential_evolution step 720: f(x)= 0.17631149391333048
# differential_evolution step 721: f(x)= 0.17631149391333048
# differential_evolution step 722: f(x)= 0.17631149391333048
# differential_evolution step 723: f(x)= 0.17631149391333048
# differential_evolution step 724: f(x)= 0.17631149391333048
# differential_evolution step 725: f(x)= 0.17631149391333048
# differential_evolution step 726: f(x)= 0.17631149391333048
# differential_evolution step 727: f(x)= 0.17631149391333048
# differential_evolution step 728: f(x)= 0.17631149391333048
# differential_evolution step 729: f(x)= 0.17631149391333048
# differential_evolution step 730: f(x)= 0.1762253707195979
# differential_evolution step 731: f(x)= 0.1762253707195979
# differential_evolution step 732: f(x)= 0.1762253707195979
# differential_evolution step 733: f(x)= 0.1762253707195979
# differential_evolution step 734: f(x)= 0.1762253707195979
# differential_evolution step 735: f(x)= 0.17522706940115945
# differential_evolution step 736: f(x)= 0.17522706940115945
# differential_evolution step 737: f(x)= 0.17522706940115945
# differential_evolution step 738: f(x)= 0.17522706940115945
# differential_evolution step 739: f(x)= 0.17522706940115945
# differential_evolution step 740: f(x)= 0.17522706940115945
# differential_evolution step 741: f(x)= 0.17522706940115945
# differential_evolution step 742: f(x)= 0.17522706940115945
# differential_evolution step 743: f(x)= 0.17498209031029383
# differential_evolution step 744: f(x)= 0.17464236060971636
# differential_evolution step 745: f(x)= 0.17464236060971636
# differential_evolution step 746: f(x)= 0.17464236060971636
# differential_evolution step 747: f(x)= 0.17464236060971636
# differential_evolution step 748: f(x)= 0.17464236060971636
# differential_evolution step 749: f(x)= 0.17464236060971636
# differential_evolution step 750: f(x)= 0.17464236060971636
# differential_evolution step 751: f(x)= 0.17464236060971636
# differential_evolution step 752: f(x)= 0.17464236060971636
# differential_evolution step 753: f(x)= 0.17464236060971636
# differential_evolution step 754: f(x)= 0.17464236060971636
# differential_evolution step 755: f(x)= 0.17464236060971636
# differential_evolution step 756: f(x)= 0.17464236060971636
# differential_evolution step 757: f(x)= 0.17464236060971636
# differential_evolution step 758: f(x)= 0.17464236060971636
# differential_evolution step 759: f(x)= 0.17464236060971636
# differential_evolution step 760: f(x)= 0.17464236060971636
# differential_evolution step 761: f(x)= 0.17464236060971636
# differential_evolution step 762: f(x)= 0.17464236060971636
# differential_evolution step 763: f(x)= 0.17464236060971636
# differential_evolution step 764: f(x)= 0.17464236060971636
# differential_evolution step 765: f(x)= 0.17429960898217284
# differential_evolution step 766: f(x)= 0.17429960898217284
# differential_evolution step 767: f(x)= 0.17429960898217284
# differential_evolution step 768: f(x)= 0.17429960898217284
# differential_evolution step 769: f(x)= 0.17429960898217284
# differential_evolution step 770: f(x)= 0.17429960898217284
# differential_evolution step 771: f(x)= 0.17429960898217284
# differential_evolution step 772: f(x)= 0.17429960898217284
# differential_evolution step 773: f(x)= 0.17429960898217284
# differential_evolution step 774: f(x)= 0.17429960898217284
# differential_evolution step 775: f(x)= 0.17429960898217284
# differential_evolution step 776: f(x)= 0.17429960898217284
# differential_evolution step 777: f(x)= 0.17429960898217284
# differential_evolution step 778: f(x)= 0.17429960898217284
# differential_evolution step 779: f(x)= 0.17429960898217284
# differential_evolution step 780: f(x)= 0.17429960898217284
# differential_evolution step 781: f(x)= 0.17429960898217284
# differential_evolution step 782: f(x)= 0.17429960898217284
# differential_evolution step 783: f(x)= 0.17429960898217284
# differential_evolution step 784: f(x)= 0.17007421474633885
# differential_evolution step 785: f(x)= 0.17007421474633885
# differential_evolution step 786: f(x)= 0.17007421474633885
# differential_evolution step 787: f(x)= 0.1689333924771719
# differential_evolution step 788: f(x)= 0.1689333924771719
# differential_evolution step 789: f(x)= 0.1689333924771719
# differential_evolution step 790: f(x)= 0.1689333924771719
# differential_evolution step 791: f(x)= 0.16764412495675793
# differential_evolution step 792: f(x)= 0.16764412495675793
# differential_evolution step 793: f(x)= 0.16764412495675793
# differential_evolution step 794: f(x)= 0.16764412495675793
# differential_evolution step 795: f(x)= 0.16764412495675793
# differential_evolution step 796: f(x)= 0.16764412495675793
# differential_evolution step 797: f(x)= 0.16764412495675793
# differential_evolution step 798: f(x)= 0.1667931001529653
# differential_evolution step 799: f(x)= 0.1667931001529653
# differential_evolution step 800: f(x)= 0.1667931001529653
# differential_evolution step 801: f(x)= 0.1667931001529653
# differential_evolution step 802: f(x)= 0.1667931001529653
# differential_evolution step 803: f(x)= 0.1667931001529653
# differential_evolution step 804: f(x)= 0.1667931001529653
# differential_evolution step 805: f(x)= 0.1667931001529653
# differential_evolution step 806: f(x)= 0.16609236552030335
# differential_evolution step 807: f(x)= 0.16609236552030335
# differential_evolution step 808: f(x)= 0.16609236552030335
# differential_evolution step 809: f(x)= 0.16609236552030335
# differential_evolution step 810: f(x)= 0.16609236552030335
# differential_evolution step 811: f(x)= 0.16609236552030335
# differential_evolution step 812: f(x)= 0.16609236552030335
# differential_evolution step 813: f(x)= 0.16609236552030335
# differential_evolution step 814: f(x)= 0.16609236552030335
# differential_evolution step 815: f(x)= 0.16609236552030335
# differential_evolution step 816: f(x)= 0.16393071742362209
# differential_evolution step 817: f(x)= 0.16393071742362209
# differential_evolution step 818: f(x)= 0.16315394106667094
# differential_evolution step 819: f(x)= 0.15993265332833606
# differential_evolution step 820: f(x)= 0.15993265332833606
# differential_evolution step 821: f(x)= 0.15993265332833606
# differential_evolution step 822: f(x)= 0.15802548755315446
# differential_evolution step 823: f(x)= 0.15802548755315446
# differential_evolution step 824: f(x)= 0.15802548755315446
# differential_evolution step 825: f(x)= 0.15802548755315446
# differential_evolution step 826: f(x)= 0.15802548755315446
# differential_evolution step 827: f(x)= 0.15802548755315446
# differential_evolution step 828: f(x)= 0.15745838305356485
# differential_evolution step 829: f(x)= 0.15745838305356485
# differential_evolution step 830: f(x)= 0.15745838305356485
# differential_evolution step 831: f(x)= 0.15745838305356485
# differential_evolution step 832: f(x)= 0.15745838305356485
# differential_evolution step 833: f(x)= 0.15718332944523314
# differential_evolution step 834: f(x)= 0.15530872335672077
# differential_evolution step 835: f(x)= 0.15530872335672077
# differential_evolution step 836: f(x)= 0.15530872335672077
# differential_evolution step 837: f(x)= 0.15530872335672077
# differential_evolution step 838: f(x)= 0.1504658892324198
# differential_evolution step 839: f(x)= 0.1504658892324198
# differential_evolution step 840: f(x)= 0.1451749417800577
# differential_evolution step 841: f(x)= 0.1451749417800577
# differential_evolution step 842: f(x)= 0.1451749417800577
# differential_evolution step 843: f(x)= 0.13914696180148137
# differential_evolution step 844: f(x)= 0.13914696180148137
# differential_evolution step 845: f(x)= 0.13715120484768412
# differential_evolution step 846: f(x)= 0.13715120484768412
# differential_evolution step 847: f(x)= 0.13715120484768412
# differential_evolution step 848: f(x)= 0.13715120484768412
# differential_evolution step 849: f(x)= 0.13715120484768412
# differential_evolution step 850: f(x)= 0.13715120484768412
# differential_evolution step 851: f(x)= 0.13715120484768412
# differential_evolution step 852: f(x)= 0.13715120484768412
# differential_evolution step 853: f(x)= 0.13715120484768412
# differential_evolution step 854: f(x)= 0.13542103983096368
# differential_evolution step 855: f(x)= 0.13542103983096368
# differential_evolution step 856: f(x)= 0.1289887780735933
# differential_evolution step 857: f(x)= 0.1289887780735933
# differential_evolution step 858: f(x)= 0.1289887780735933
# differential_evolution step 859: f(x)= 0.12505335149360738
# differential_evolution step 860: f(x)= 0.12505335149360738
# differential_evolution step 861: f(x)= 0.12505335149360738
# differential_evolution step 862: f(x)= 0.1244912981648609
# differential_evolution step 863: f(x)= 0.1244912981648609
# differential_evolution step 864: f(x)= 0.12367105697038212
# differential_evolution step 865: f(x)= 0.12193715886498754
# differential_evolution step 866: f(x)= 0.12193715886498754
# differential_evolution step 867: f(x)= 0.11970739270719451
# differential_evolution step 868: f(x)= 0.11970739270719451
# differential_evolution step 869: f(x)= 0.11970739270719451
# differential_evolution step 870: f(x)= 0.11030599575500576
# differential_evolution step 871: f(x)= 0.11030599575500576
# differential_evolution step 872: f(x)= 0.11030599575500576
# differential_evolution step 873: f(x)= 0.11030599575500576
# differential_evolution step 874: f(x)= 0.11030599575500576
# differential_evolution step 875: f(x)= 0.11030599575500576
# differential_evolution step 876: f(x)= 0.11030599575500576
# differential_evolution step 877: f(x)= 0.10495275719888844
# differential_evolution step 878: f(x)= 0.10495275719888844
# differential_evolution step 879: f(x)= 0.10495275719888844
# differential_evolution step 880: f(x)= 0.10495275719888844
# differential_evolution step 881: f(x)= 0.10495275719888844
# differential_evolution step 882: f(x)= 0.10495275719888844
# differential_evolution step 883: f(x)= 0.10495275719888844
# differential_evolution step 884: f(x)= 0.10495275719888844
# differential_evolution step 885: f(x)= 0.10495275719888844
# differential_evolution step 886: f(x)= 0.10495275719888844
# differential_evolution step 887: f(x)= 0.10495275719888844
# differential_evolution step 888: f(x)= 0.10495275719888844
# differential_evolution step 889: f(x)= 0.10495275719888844
# differential_evolution step 890: f(x)= 0.1048429218180324
# differential_evolution step 891: f(x)= 0.1048429218180324
# differential_evolution step 892: f(x)= 0.09879550188263704
# differential_evolution step 893: f(x)= 0.09879550188263704
# differential_evolution step 894: f(x)= 0.09879550188263704
# differential_evolution step 895: f(x)= 0.09879550188263704
# differential_evolution step 896: f(x)= 0.09879550188263704
# differential_evolution step 897: f(x)= 0.0946099315951613
# differential_evolution step 898: f(x)= 0.0946099315951613
# differential_evolution step 899: f(x)= 0.0946099315951613
# differential_evolution step 900: f(x)= 0.0946099315951613
# differential_evolution step 901: f(x)= 0.0946099315951613
# differential_evolution step 902: f(x)= 0.0946099315951613
# differential_evolution step 903: f(x)= 0.0946099315951613
# differential_evolution step 904: f(x)= 0.0946099315951613
# differential_evolution step 905: f(x)= 0.0946099315951613
# differential_evolution step 906: f(x)= 0.0946099315951613
# differential_evolution step 907: f(x)= 0.0946099315951613
# differential_evolution step 908: f(x)= 0.0946099315951613
# differential_evolution step 909: f(x)= 0.0946099315951613
# differential_evolution step 910: f(x)= 0.0946099315951613
# differential_evolution step 911: f(x)= 0.0946099315951613
# differential_evolution step 912: f(x)= 0.0946099315951613
# differential_evolution step 913: f(x)= 0.0946099315951613
# differential_evolution step 914: f(x)= 0.08907707326507437
# differential_evolution step 915: f(x)= 0.0882055159715112
# differential_evolution step 916: f(x)= 0.0882055159715112
# differential_evolution step 917: f(x)= 0.0882055159715112
# differential_evolution step 918: f(x)= 0.0882055159715112
# differential_evolution step 919: f(x)= 0.0882055159715112
# differential_evolution step 920: f(x)= 0.0882055159715112
# differential_evolution step 921: f(x)= 0.0882055159715112
# differential_evolution step 922: f(x)= 0.0882055159715112
# differential_evolution step 923: f(x)= 0.0882055159715112
# differential_evolution step 924: f(x)= 0.08796307141069107
# differential_evolution step 925: f(x)= 0.08578138080073934
# differential_evolution step 926: f(x)= 0.08578138080073934
# differential_evolution step 927: f(x)= 0.08578138080073934
# differential_evolution step 928: f(x)= 0.08578138080073934
# differential_evolution step 929: f(x)= 0.08578138080073934
# differential_evolution step 930: f(x)= 0.08578138080073934
# differential_evolution step 931: f(x)= 0.08578138080073934
# differential_evolution step 932: f(x)= 0.08578138080073934
# differential_evolution step 933: f(x)= 0.08578138080073934
# differential_evolution step 934: f(x)= 0.08308684822989837
# differential_evolution step 935: f(x)= 0.08308684822989837
# differential_evolution step 936: f(x)= 0.08308684822989837
# differential_evolution step 937: f(x)= 0.08308684822989837
# differential_evolution step 938: f(x)= 0.08308684822989837
# differential_evolution step 939: f(x)= 0.08308684822989837
# differential_evolution step 940: f(x)= 0.08308684822989837
# differential_evolution step 941: f(x)= 0.08308684822989837
# differential_evolution step 942: f(x)= 0.08308684822989837
# differential_evolution step 943: f(x)= 0.08184962285910365
# differential_evolution step 944: f(x)= 0.08184962285910365
# differential_evolution step 945: f(x)= 0.08041792892366148
# differential_evolution step 946: f(x)= 0.06701759568946948
# differential_evolution step 947: f(x)= 0.06701759568946948
# differential_evolution step 948: f(x)= 0.06701759568946948
# differential_evolution step 949: f(x)= 0.06701759568946948
# differential_evolution step 950: f(x)= 0.06701759568946948
# differential_evolution step 951: f(x)= 0.06701759568946948
# differential_evolution step 952: f(x)= 0.06701759568946948
# differential_evolution step 953: f(x)= 0.06701759568946948
# differential_evolution step 954: f(x)= 0.06701759568946948
# differential_evolution step 955: f(x)= 0.06701759568946948
# differential_evolution step 956: f(x)= 0.06701759568946948
# differential_evolution step 957: f(x)= 0.06701759568946948
# differential_evolution step 958: f(x)= 0.06701759568946948
# differential_evolution step 959: f(x)= 0.06701759568946948
# differential_evolution step 960: f(x)= 0.06701759568946948
# differential_evolution step 961: f(x)= 0.06701759568946948
# differential_evolution step 962: f(x)= 0.06701759568946948
# differential_evolution step 963: f(x)= 0.06686183801401063
# differential_evolution step 964: f(x)= 0.06686183801401063
# differential_evolution step 965: f(x)= 0.06686183801401063
# differential_evolution step 966: f(x)= 0.06686183801401063
# differential_evolution step 967: f(x)= 0.06532747748779062
# differential_evolution step 968: f(x)= 0.06532747748779062
# differential_evolution step 969: f(x)= 0.06532747748779062
# differential_evolution step 970: f(x)= 0.06532747748779062
# differential_evolution step 971: f(x)= 0.06532747748779062
# differential_evolution step 972: f(x)= 0.06532747748779062
# differential_evolution step 973: f(x)= 0.06532747748779062
# differential_evolution step 974: f(x)= 0.06532747748779062
# differential_evolution step 975: f(x)= 0.06532747748779062
# differential_evolution step 976: f(x)= 0.06532747748779062
# differential_evolution step 977: f(x)= 0.06532747748779062
# differential_evolution step 978: f(x)= 0.06532747748779062
# differential_evolution step 979: f(x)= 0.06532747748779062
# differential_evolution step 980: f(x)= 0.06532747748779062
# differential_evolution step 981: f(x)= 0.06532747748779062
# differential_evolution step 982: f(x)= 0.06532747748779062
# differential_evolution step 983: f(x)= 0.06532747748779062
# differential_evolution step 984: f(x)= 0.06532747748779062
# differential_evolution step 985: f(x)= 0.06532747748779062
# differential_evolution step 986: f(x)= 0.06532747748779062
# differential_evolution step 987: f(x)= 0.06532747748779062
# differential_evolution step 988: f(x)= 0.06532747748779062
# differential_evolution step 989: f(x)= 0.06532747748779062
# differential_evolution step 990: f(x)= 0.06532747748779062
# differential_evolution step 991: f(x)= 0.06532747748779062
# differential_evolution step 992: f(x)= 0.06532747748779062
# differential_evolution step 993: f(x)= 0.06532747748779062
# differential_evolution step 994: f(x)= 0.05649991556822806
# differential_evolution step 995: f(x)= 0.05649991556822806
# differential_evolution step 996: f(x)= 0.05649991556822806
# differential_evolution step 997: f(x)= 0.05649991556822806
# differential_evolution step 998: f(x)= 0.05649991556822806
# differential_evolution step 999: f(x)= 0.05649991556822806
# differential_evolution step 1000: f(x)= 0.05649991556822806
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=0.0194, r_e=48.4729, n=2.0830, x_0=35.2776
# Sérsic 2: I_e=0.4025, r_e=4.1833, n=1.2661, x_0=48.2700
# Sérsic 3: I_e=0.0359, r_e=26.1444, n=1.8539, x_0=55.0000
# Sérsic 4: I_e=0.0651, r_e=7.1726, n=0.8625, x_0=67.4561
# Chi quadro minimo: 0.05101668543374262
# False

# %%
save_params_diff(best_params, radial_profile_OIII, real_errors_OIII, sigmas[4],
    x_axes, n_component, line_name="OIII", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_diff')
# Out:
# Sérsic 1: I_e=0.0194, r_e=48.4729, n=2.0830, x_0=35.2776
# Sérsic 2: I_e=0.4025, r_e=4.1833, n=1.2661, x_0=48.2700
# Sérsic 3: I_e=0.0359, r_e=26.1444, n=1.8539, x_0=55.0000
# Sérsic 4: I_e=0.0651, r_e=7.1726, n=0.8625, x_0=67.4561
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#lower_bounds, upper_bounds = zip(*bounds)
#bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_OIII, covariance_OIII = curve_fit(lambda x, *params: model_convolved(x, sigmas[4], *params), x_axes, radial_profile_OIII, 
                                               p0=result.x, sigma = real_errors_OIII) #, bounds = bounds_list, maxfev=10000)

print("Optimize parameters with curve fit:")
chi2_reduced_OIII, dof_OIII, chi2_OIII = save_params(params_curve_OIII, covariance_OIII, radial_profile_OIII, real_errors_OIII, sigmas[4],
    x_axes, n_component, line_name="OIII", output_prefix="fit")
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_4612\568277273.py:11: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_4612\568277273.py:24: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.0315, r_e=35.9381, n=1.7891, x_0=35.2528
# Sérsic 2: I_e=0.3770, r_e=4.8950, n=1.3149, x_0=48.2809
# Sérsic 3: I_e=0.1450, r_e=3.7615, n=0.9448, x_0=55.1656
# Sérsic 4: I_e=0.0566, r_e=17.6186, n=1.1374, x_0=66.3031
# [0.0094994  8.44057521 0.2275524  0.04293093 0.04719487 0.4301808
#  0.09494443 0.03712425 0.05026817 1.05374845 0.24381297 0.1129913
#  0.01100647 2.59561774 0.11944658 0.31590443]
# 0.316637595646064

# %%
plot_curve(x_axes, params_curve_OIII, radial_profile_OIII, real_errors_OIII, sigmas[4], r"Radial profile [OIII]")
plt.savefig('Radial_profile_OIII_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
chi_red = [chi2_reduced_HA, chi2_reduced_HB, chi2_reduced_NII, chi2_reduced_SII, chi2_reduced_OIII]
dof = [dof_HA, dof_HB, dof_NII, dof_SII, dof_OIII]
chi = [chi2_HA, chi2_HB, chi2_NII, chi2_SII, chi2_OIII]

d1 = {'Name': ['Halpha', 'Hbeta', 'NII', 'SII', 'OIII'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit.csv", index= False)

# %% [markdown]
# ## Continuum 1

# %%
mask_continuum_1 = (wv > 4500)*(wv < 4800)
image_continuum_1 = image_cut[:, mask_continuum_1]
image_error_continuum_1 = image_error_cut[:, mask_continuum_1]
radial_profile_continuum_1 = np.sum(image_continuum_1, axis = 1)
radial_profile_error_continuum_1 = np.sqrt(np.sum(image_error_continuum_1**2, axis = 1))
real_errors_c1 = np.sqrt(radial_profile_error_continuum_1**2+(sky_err[2])**2+(0.04*radial_profile_continuum_1)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_1)
plt.plot(x_axes, radial_profile_error_continuum_1)
plt.title(r'Continuum 1')
# Out:
# Text(0.5, 1.0, 'Continuum 1')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_1, sigmas[1])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 7123.342746530659
# differential_evolution step 2: f(x)= 7123.342746530659
# differential_evolution step 3: f(x)= 6406.253810631796
# differential_evolution step 4: f(x)= 4452.6848435015745
# differential_evolution step 5: f(x)= 3619.940953747582
# differential_evolution step 6: f(x)= 3619.940953747582
# differential_evolution step 7: f(x)= 3013.766612350376
# differential_evolution step 8: f(x)= 3013.766612350376
# differential_evolution step 9: f(x)= 3013.766612350376
# differential_evolution step 10: f(x)= 3013.766612350376
# differential_evolution step 11: f(x)= 3013.766612350376
# differential_evolution step 12: f(x)= 3013.766612350376
# differential_evolution step 13: f(x)= 1191.313622254286
# differential_evolution step 14: f(x)= 1191.313622254286
# differential_evolution step 15: f(x)= 1163.5832689030271
# differential_evolution step 16: f(x)= 1163.5832689030271
# differential_evolution step 17: f(x)= 1163.5832689030271
# differential_evolution step 18: f(x)= 1163.5832689030271
# differential_evolution step 19: f(x)= 1163.5832689030271
# differential_evolution step 20: f(x)= 1163.5832689030271
# differential_evolution step 21: f(x)= 1163.5832689030271
# differential_evolution step 22: f(x)= 1163.5832689030271
# differential_evolution step 23: f(x)= 965.2186083381524
# differential_evolution step 24: f(x)= 817.8690757763279
# differential_evolution step 25: f(x)= 817.8690757763279
# differential_evolution step 26: f(x)= 817.8690757763279
# differential_evolution step 27: f(x)= 810.5672445388526
# differential_evolution step 28: f(x)= 810.5672445388526
# differential_evolution step 29: f(x)= 542.9718819607986
# differential_evolution step 30: f(x)= 188.56499540063575
# differential_evolution step 31: f(x)= 188.56499540063575
# differential_evolution step 32: f(x)= 188.56499540063575
# differential_evolution step 33: f(x)= 188.56499540063575
# differential_evolution step 34: f(x)= 188.56499540063575
# differential_evolution step 35: f(x)= 188.56499540063575
# differential_evolution step 36: f(x)= 188.56499540063575
# differential_evolution step 37: f(x)= 188.56499540063575
# differential_evolution step 38: f(x)= 128.92507173649693
# differential_evolution step 39: f(x)= 128.92507173649693
# differential_evolution step 40: f(x)= 128.92507173649693
# differential_evolution step 41: f(x)= 128.92507173649693
# differential_evolution step 42: f(x)= 128.92507173649693
# differential_evolution step 43: f(x)= 128.92507173649693
# differential_evolution step 44: f(x)= 128.92507173649693
# differential_evolution step 45: f(x)= 128.92507173649693
# differential_evolution step 46: f(x)= 128.92507173649693
# differential_evolution step 47: f(x)= 128.92507173649693
# differential_evolution step 48: f(x)= 128.92507173649693
# differential_evolution step 49: f(x)= 128.92507173649693
# differential_evolution step 50: f(x)= 128.92507173649693
# differential_evolution step 51: f(x)= 128.92507173649693
# differential_evolution step 52: f(x)= 128.92507173649693
# differential_evolution step 53: f(x)= 128.92507173649693
# differential_evolution step 54: f(x)= 128.92507173649693
# differential_evolution step 55: f(x)= 128.92507173649693
# differential_evolution step 56: f(x)= 128.92507173649693
# differential_evolution step 57: f(x)= 128.92507173649693
# differential_evolution step 58: f(x)= 128.92507173649693
# differential_evolution step 59: f(x)= 128.92507173649693
# differential_evolution step 60: f(x)= 128.92507173649693
# differential_evolution step 61: f(x)= 128.92507173649693
# differential_evolution step 62: f(x)= 128.92507173649693
# differential_evolution step 63: f(x)= 128.92507173649693
# differential_evolution step 64: f(x)= 128.92507173649693
# differential_evolution step 65: f(x)= 117.61990255722631
# differential_evolution step 66: f(x)= 117.61990255722631
# differential_evolution step 67: f(x)= 98.42022068257317
# differential_evolution step 68: f(x)= 98.42022068257317
# differential_evolution step 69: f(x)= 98.42022068257317
# differential_evolution step 70: f(x)= 98.42022068257317
# differential_evolution step 71: f(x)= 98.42022068257317
# differential_evolution step 72: f(x)= 98.42022068257317
# differential_evolution step 73: f(x)= 71.11957608951174
# differential_evolution step 74: f(x)= 71.11957608951174
# differential_evolution step 75: f(x)= 71.11957608951174
# differential_evolution step 76: f(x)= 71.11957608951174
# differential_evolution step 77: f(x)= 71.11957608951174
# differential_evolution step 78: f(x)= 71.11957608951174
# differential_evolution step 79: f(x)= 71.11957608951174
# differential_evolution step 80: f(x)= 71.11957608951174
# differential_evolution step 81: f(x)= 63.688628091161554
# differential_evolution step 82: f(x)= 63.688628091161554
# differential_evolution step 83: f(x)= 63.688628091161554
# differential_evolution step 84: f(x)= 63.688628091161554
# differential_evolution step 85: f(x)= 63.688628091161554
# differential_evolution step 86: f(x)= 63.688628091161554
# differential_evolution step 87: f(x)= 63.688628091161554
# differential_evolution step 88: f(x)= 59.53381048783379
# differential_evolution step 89: f(x)= 59.53381048783379
# differential_evolution step 90: f(x)= 59.53381048783379
# differential_evolution step 91: f(x)= 59.53381048783379
# differential_evolution step 92: f(x)= 59.53381048783379
# differential_evolution step 93: f(x)= 59.53381048783379
# differential_evolution step 94: f(x)= 59.53381048783379
# differential_evolution step 95: f(x)= 44.061488932930146
# differential_evolution step 96: f(x)= 42.433453012248556
# differential_evolution step 97: f(x)= 42.433453012248556
# differential_evolution step 98: f(x)= 42.433453012248556
# differential_evolution step 99: f(x)= 42.433453012248556
# differential_evolution step 100: f(x)= 42.433453012248556
# differential_evolution step 101: f(x)= 42.433453012248556
# differential_evolution step 102: f(x)= 42.433453012248556
# differential_evolution step 103: f(x)= 42.433453012248556
# differential_evolution step 104: f(x)= 42.433453012248556
# differential_evolution step 105: f(x)= 42.433453012248556
# differential_evolution step 106: f(x)= 42.433453012248556
# differential_evolution step 107: f(x)= 42.433453012248556
# differential_evolution step 108: f(x)= 42.433453012248556
# differential_evolution step 109: f(x)= 42.433453012248556
# differential_evolution step 110: f(x)= 42.433453012248556
# differential_evolution step 111: f(x)= 42.433453012248556
# differential_evolution step 112: f(x)= 42.433453012248556
# differential_evolution step 113: f(x)= 42.433453012248556
# differential_evolution step 114: f(x)= 42.433453012248556
# differential_evolution step 115: f(x)= 42.433453012248556
# differential_evolution step 116: f(x)= 42.433453012248556
# differential_evolution step 117: f(x)= 42.433453012248556
# differential_evolution step 118: f(x)= 42.433453012248556
# differential_evolution step 119: f(x)= 42.433453012248556
# differential_evolution step 120: f(x)= 42.433453012248556
# differential_evolution step 121: f(x)= 39.37188323417521
# differential_evolution step 122: f(x)= 39.37188323417521
# differential_evolution step 123: f(x)= 39.37188323417521
# differential_evolution step 124: f(x)= 39.37188323417521
# differential_evolution step 125: f(x)= 39.37188323417521
# differential_evolution step 126: f(x)= 37.006958441851125
# differential_evolution step 127: f(x)= 37.006958441851125
# differential_evolution step 128: f(x)= 37.006958441851125
# differential_evolution step 129: f(x)= 37.006958441851125
# differential_evolution step 130: f(x)= 37.006958441851125
# differential_evolution step 131: f(x)= 37.006958441851125
# differential_evolution step 132: f(x)= 37.006958441851125
# differential_evolution step 133: f(x)= 37.006958441851125
# differential_evolution step 134: f(x)= 37.006958441851125
# differential_evolution step 135: f(x)= 37.006958441851125
# differential_evolution step 136: f(x)= 37.006958441851125
# differential_evolution step 137: f(x)= 37.006958441851125
# differential_evolution step 138: f(x)= 37.006958441851125
# differential_evolution step 139: f(x)= 37.006958441851125
# differential_evolution step 140: f(x)= 37.006958441851125
# differential_evolution step 141: f(x)= 36.22740136706868
# differential_evolution step 142: f(x)= 34.69144551087278
# differential_evolution step 143: f(x)= 34.69144551087278
# differential_evolution step 144: f(x)= 34.69144551087278
# differential_evolution step 145: f(x)= 32.79660606735557
# differential_evolution step 146: f(x)= 32.79660606735557
# differential_evolution step 147: f(x)= 32.79660606735557
# differential_evolution step 148: f(x)= 32.79660606735557
# differential_evolution step 149: f(x)= 32.79660606735557
# differential_evolution step 150: f(x)= 32.79660606735557
# differential_evolution step 151: f(x)= 32.79660606735557
# differential_evolution step 152: f(x)= 32.79660606735557
# differential_evolution step 153: f(x)= 32.79660606735557
# differential_evolution step 154: f(x)= 32.79660606735557
# differential_evolution step 155: f(x)= 32.79660606735557
# differential_evolution step 156: f(x)= 32.79660606735557
# differential_evolution step 157: f(x)= 32.79660606735557
# differential_evolution step 158: f(x)= 32.79660606735557
# differential_evolution step 159: f(x)= 31.807945132489035
# differential_evolution step 160: f(x)= 31.807945132489035
# differential_evolution step 161: f(x)= 31.807945132489035
# differential_evolution step 162: f(x)= 31.807945132489035
# differential_evolution step 163: f(x)= 31.807945132489035
# differential_evolution step 164: f(x)= 31.807945132489035
# differential_evolution step 165: f(x)= 31.807945132489035
# differential_evolution step 166: f(x)= 31.807945132489035
# differential_evolution step 167: f(x)= 31.807945132489035
# differential_evolution step 168: f(x)= 31.807945132489035
# differential_evolution step 169: f(x)= 31.807945132489035
# differential_evolution step 170: f(x)= 31.807945132489035
# differential_evolution step 171: f(x)= 31.807945132489035
# differential_evolution step 172: f(x)= 31.807945132489035
# differential_evolution step 173: f(x)= 31.807945132489035
# differential_evolution step 174: f(x)= 31.33083180576243
# differential_evolution step 175: f(x)= 31.33083180576243
# differential_evolution step 176: f(x)= 31.33083180576243
# differential_evolution step 177: f(x)= 31.33083180576243
# differential_evolution step 178: f(x)= 31.33083180576243
# differential_evolution step 179: f(x)= 31.33083180576243
# differential_evolution step 180: f(x)= 31.29028732475492
# differential_evolution step 181: f(x)= 31.274548699415412
# differential_evolution step 182: f(x)= 31.274548699415412
# differential_evolution step 183: f(x)= 30.323066199929595
# differential_evolution step 184: f(x)= 30.323066199929595
# differential_evolution step 185: f(x)= 30.323066199929595
# differential_evolution step 186: f(x)= 30.323066199929595
# differential_evolution step 187: f(x)= 28.78458026228949
# differential_evolution step 188: f(x)= 28.78458026228949
# differential_evolution step 189: f(x)= 28.78458026228949
# differential_evolution step 190: f(x)= 28.78458026228949
# differential_evolution step 191: f(x)= 28.78458026228949
# differential_evolution step 192: f(x)= 28.78458026228949
# differential_evolution step 193: f(x)= 28.78458026228949
# differential_evolution step 194: f(x)= 28.78458026228949
# differential_evolution step 195: f(x)= 28.78458026228949
# differential_evolution step 196: f(x)= 28.78458026228949
# differential_evolution step 197: f(x)= 28.461356137514976
# differential_evolution step 198: f(x)= 28.461356137514976
# differential_evolution step 199: f(x)= 28.461356137514976
# differential_evolution step 200: f(x)= 28.461356137514976
# differential_evolution step 201: f(x)= 28.461356137514976
# differential_evolution step 202: f(x)= 28.461356137514976
# differential_evolution step 203: f(x)= 28.22530092953411
# differential_evolution step 204: f(x)= 28.22530092953411
# differential_evolution step 205: f(x)= 28.22530092953411
# differential_evolution step 206: f(x)= 28.22530092953411
# differential_evolution step 207: f(x)= 28.22530092953411
# differential_evolution step 208: f(x)= 28.22530092953411
# differential_evolution step 209: f(x)= 28.22530092953411
# differential_evolution step 210: f(x)= 28.22530092953411
# differential_evolution step 211: f(x)= 28.22530092953411
# differential_evolution step 212: f(x)= 28.22530092953411
# differential_evolution step 213: f(x)= 28.22530092953411
# differential_evolution step 214: f(x)= 28.22530092953411
# differential_evolution step 215: f(x)= 28.22530092953411
# differential_evolution step 216: f(x)= 28.22530092953411
# differential_evolution step 217: f(x)= 28.22530092953411
# differential_evolution step 218: f(x)= 28.22530092953411
# differential_evolution step 219: f(x)= 28.22530092953411
# differential_evolution step 220: f(x)= 28.22530092953411
# differential_evolution step 221: f(x)= 28.22530092953411
# differential_evolution step 222: f(x)= 28.068105146883937
# differential_evolution step 223: f(x)= 28.068105146883937
# differential_evolution step 224: f(x)= 28.068105146883937
# differential_evolution step 225: f(x)= 28.068105146883937
# differential_evolution step 226: f(x)= 28.068105146883937
# differential_evolution step 227: f(x)= 28.068105146883937
# differential_evolution step 228: f(x)= 28.068105146883937
# differential_evolution step 229: f(x)= 28.068105146883937
# differential_evolution step 230: f(x)= 28.068105146883937
# differential_evolution step 231: f(x)= 28.068105146883937
# differential_evolution step 232: f(x)= 28.068105146883937
# differential_evolution step 233: f(x)= 28.068105146883937
# differential_evolution step 234: f(x)= 28.068105146883937
# differential_evolution step 235: f(x)= 27.317614439547455
# differential_evolution step 236: f(x)= 27.317614439547455
# differential_evolution step 237: f(x)= 27.317614439547455
# differential_evolution step 238: f(x)= 27.317614439547455
# differential_evolution step 239: f(x)= 27.317614439547455
# differential_evolution step 240: f(x)= 27.317614439547455
# differential_evolution step 241: f(x)= 27.317614439547455
# differential_evolution step 242: f(x)= 27.317614439547455
# differential_evolution step 243: f(x)= 27.317614439547455
# differential_evolution step 244: f(x)= 27.317614439547455
# differential_evolution step 245: f(x)= 27.317614439547455
# differential_evolution step 246: f(x)= 27.317614439547455
# differential_evolution step 247: f(x)= 27.317614439547455
# differential_evolution step 248: f(x)= 27.317614439547455
# differential_evolution step 249: f(x)= 27.317614439547455
# differential_evolution step 250: f(x)= 27.317614439547455
# differential_evolution step 251: f(x)= 27.317614439547455
# differential_evolution step 252: f(x)= 27.317614439547455
# differential_evolution step 253: f(x)= 27.317614439547455
# differential_evolution step 254: f(x)= 27.317614439547455
# differential_evolution step 255: f(x)= 27.317614439547455
# differential_evolution step 256: f(x)= 27.170315611913395
# differential_evolution step 257: f(x)= 27.170315611913395
# differential_evolution step 258: f(x)= 26.28932276166016
# differential_evolution step 259: f(x)= 26.28932276166016
# differential_evolution step 260: f(x)= 26.28932276166016
# differential_evolution step 261: f(x)= 26.28932276166016
# differential_evolution step 262: f(x)= 26.28932276166016
# differential_evolution step 263: f(x)= 26.28932276166016
# differential_evolution step 264: f(x)= 26.28932276166016
# differential_evolution step 265: f(x)= 26.28932276166016
# differential_evolution step 266: f(x)= 26.28932276166016
# differential_evolution step 267: f(x)= 26.28932276166016
# differential_evolution step 268: f(x)= 26.28932276166016
# differential_evolution step 269: f(x)= 26.28932276166016
# differential_evolution step 270: f(x)= 26.28932276166016
# differential_evolution step 271: f(x)= 26.28932276166016
# differential_evolution step 272: f(x)= 26.28932276166016
# differential_evolution step 273: f(x)= 26.28932276166016
# differential_evolution step 274: f(x)= 26.28932276166016
# differential_evolution step 275: f(x)= 26.28932276166016
# differential_evolution step 276: f(x)= 26.28932276166016
# differential_evolution step 277: f(x)= 26.28932276166016
# differential_evolution step 278: f(x)= 26.28932276166016
# differential_evolution step 279: f(x)= 26.28932276166016
# differential_evolution step 280: f(x)= 26.28932276166016
# differential_evolution step 281: f(x)= 26.28932276166016
# differential_evolution step 282: f(x)= 26.28932276166016
# differential_evolution step 283: f(x)= 26.28932276166016
# differential_evolution step 284: f(x)= 26.28932276166016
# differential_evolution step 285: f(x)= 26.269382031294935
# differential_evolution step 286: f(x)= 26.269382031294935
# differential_evolution step 287: f(x)= 26.269382031294935
# differential_evolution step 288: f(x)= 26.269382031294935
# differential_evolution step 289: f(x)= 26.269382031294935
# differential_evolution step 290: f(x)= 26.269382031294935
# differential_evolution step 291: f(x)= 26.269382031294935
# differential_evolution step 292: f(x)= 26.269382031294935
# differential_evolution step 293: f(x)= 26.269382031294935
# differential_evolution step 294: f(x)= 26.269382031294935
# differential_evolution step 295: f(x)= 26.269382031294935
# differential_evolution step 296: f(x)= 26.269382031294935
# differential_evolution step 297: f(x)= 26.269382031294935
# differential_evolution step 298: f(x)= 26.269382031294935
# differential_evolution step 299: f(x)= 26.269382031294935
# differential_evolution step 300: f(x)= 26.269382031294935
# differential_evolution step 301: f(x)= 26.269382031294935
# differential_evolution step 302: f(x)= 26.269382031294935
# differential_evolution step 303: f(x)= 26.269382031294935
# differential_evolution step 304: f(x)= 26.269382031294935
# differential_evolution step 305: f(x)= 26.269382031294935
# differential_evolution step 306: f(x)= 26.269382031294935
# differential_evolution step 307: f(x)= 26.269382031294935
# differential_evolution step 308: f(x)= 26.269382031294935
# differential_evolution step 309: f(x)= 26.269382031294935
# differential_evolution step 310: f(x)= 26.269382031294935
# differential_evolution step 311: f(x)= 26.269382031294935
# differential_evolution step 312: f(x)= 26.269382031294935
# differential_evolution step 313: f(x)= 26.269382031294935
# differential_evolution step 314: f(x)= 26.269382031294935
# differential_evolution step 315: f(x)= 26.269382031294935
# differential_evolution step 316: f(x)= 26.269382031294935
# differential_evolution step 317: f(x)= 26.269382031294935
# differential_evolution step 318: f(x)= 26.269382031294935
# differential_evolution step 319: f(x)= 26.269382031294935
# differential_evolution step 320: f(x)= 26.269382031294935
# differential_evolution step 321: f(x)= 26.269382031294935
# differential_evolution step 322: f(x)= 26.210688038305733
# differential_evolution step 323: f(x)= 26.210688038305733
# differential_evolution step 324: f(x)= 26.210688038305733
# differential_evolution step 325: f(x)= 25.270549552690035
# differential_evolution step 326: f(x)= 25.270549552690035
# differential_evolution step 327: f(x)= 25.270549552690035
# differential_evolution step 328: f(x)= 25.270549552690035
# differential_evolution step 329: f(x)= 25.270549552690035
# differential_evolution step 330: f(x)= 25.270549552690035
# differential_evolution step 331: f(x)= 25.270549552690035
# differential_evolution step 332: f(x)= 25.270549552690035
# differential_evolution step 333: f(x)= 25.270549552690035
# differential_evolution step 334: f(x)= 25.270549552690035
# differential_evolution step 335: f(x)= 25.270549552690035
# differential_evolution step 336: f(x)= 25.270549552690035
# differential_evolution step 337: f(x)= 25.270549552690035
# differential_evolution step 338: f(x)= 25.270549552690035
# differential_evolution step 339: f(x)= 25.270549552690035
# differential_evolution step 340: f(x)= 25.270549552690035
# differential_evolution step 341: f(x)= 25.270549552690035
# differential_evolution step 342: f(x)= 25.270549552690035
# differential_evolution step 343: f(x)= 25.270549552690035
# differential_evolution step 344: f(x)= 25.270549552690035
# differential_evolution step 345: f(x)= 25.270549552690035
# differential_evolution step 346: f(x)= 25.270549552690035
# differential_evolution step 347: f(x)= 25.270549552690035
# differential_evolution step 348: f(x)= 25.270549552690035
# differential_evolution step 349: f(x)= 25.26172993860807
# differential_evolution step 350: f(x)= 25.26172993860807
# differential_evolution step 351: f(x)= 25.26172993860807
# differential_evolution step 352: f(x)= 24.44850173467895
# differential_evolution step 353: f(x)= 24.44850173467895
# differential_evolution step 354: f(x)= 24.44850173467895
# differential_evolution step 355: f(x)= 24.24490387614715
# differential_evolution step 356: f(x)= 24.24490387614715
# differential_evolution step 357: f(x)= 23.905442979289877
# differential_evolution step 358: f(x)= 23.905442979289877
# differential_evolution step 359: f(x)= 23.905442979289877
# differential_evolution step 360: f(x)= 23.905442979289877
# differential_evolution step 361: f(x)= 23.905442979289877
# differential_evolution step 362: f(x)= 23.905442979289877
# differential_evolution step 363: f(x)= 23.905442979289877
# differential_evolution step 364: f(x)= 23.905442979289877
# differential_evolution step 365: f(x)= 23.905442979289877
# differential_evolution step 366: f(x)= 23.905442979289877
# differential_evolution step 367: f(x)= 23.352790754060262
# differential_evolution step 368: f(x)= 23.352790754060262
# differential_evolution step 369: f(x)= 23.352790754060262
# differential_evolution step 370: f(x)= 23.352790754060262
# differential_evolution step 371: f(x)= 23.352790754060262
# differential_evolution step 372: f(x)= 23.352790754060262
# differential_evolution step 373: f(x)= 23.352790754060262
# differential_evolution step 374: f(x)= 23.352790754060262
# differential_evolution step 375: f(x)= 23.352790754060262
# differential_evolution step 376: f(x)= 23.352790754060262
# differential_evolution step 377: f(x)= 23.352790754060262
# differential_evolution step 378: f(x)= 23.352790754060262
# differential_evolution step 379: f(x)= 23.352790754060262
# differential_evolution step 380: f(x)= 23.352790754060262
# differential_evolution step 381: f(x)= 23.352790754060262
# differential_evolution step 382: f(x)= 23.352790754060262
# differential_evolution step 383: f(x)= 23.352790754060262
# differential_evolution step 384: f(x)= 23.352790754060262
# differential_evolution step 385: f(x)= 22.674591972155618
# differential_evolution step 386: f(x)= 22.674591972155618
# differential_evolution step 387: f(x)= 22.674591972155618
# differential_evolution step 388: f(x)= 22.674591972155618
# differential_evolution step 389: f(x)= 22.674591972155618
# differential_evolution step 390: f(x)= 22.674591972155618
# differential_evolution step 391: f(x)= 22.674591972155618
# differential_evolution step 392: f(x)= 22.674591972155618
# differential_evolution step 393: f(x)= 22.674591972155618
# differential_evolution step 394: f(x)= 22.674591972155618
# differential_evolution step 395: f(x)= 22.674591972155618
# differential_evolution step 396: f(x)= 22.674591972155618
# differential_evolution step 397: f(x)= 22.674591972155618
# differential_evolution step 398: f(x)= 22.674591972155618
# differential_evolution step 399: f(x)= 22.674591972155618
# differential_evolution step 400: f(x)= 22.674591972155618
# differential_evolution step 401: f(x)= 22.674591972155618
# differential_evolution step 402: f(x)= 22.674591972155618
# differential_evolution step 403: f(x)= 22.674591972155618
# differential_evolution step 404: f(x)= 22.674591972155618
# differential_evolution step 405: f(x)= 22.674591972155618
# differential_evolution step 406: f(x)= 22.674591972155618
# differential_evolution step 407: f(x)= 22.674591972155618
# differential_evolution step 408: f(x)= 22.674591972155618
# differential_evolution step 409: f(x)= 22.674591972155618
# differential_evolution step 410: f(x)= 22.674591972155618
# differential_evolution step 411: f(x)= 22.674591972155618
# differential_evolution step 412: f(x)= 22.674591972155618
# differential_evolution step 413: f(x)= 22.674591972155618
# differential_evolution step 414: f(x)= 22.674591972155618
# differential_evolution step 415: f(x)= 22.674591972155618
# differential_evolution step 416: f(x)= 22.674591972155618
# differential_evolution step 417: f(x)= 22.674591972155618
# differential_evolution step 418: f(x)= 22.674591972155618
# differential_evolution step 419: f(x)= 22.674591972155618
# differential_evolution step 420: f(x)= 22.674591972155618
# differential_evolution step 421: f(x)= 22.674591972155618
# differential_evolution step 422: f(x)= 22.674591972155618
# differential_evolution step 423: f(x)= 22.674591972155618
# differential_evolution step 424: f(x)= 22.674591972155618
# differential_evolution step 425: f(x)= 22.674591972155618
# differential_evolution step 426: f(x)= 22.674591972155618
# differential_evolution step 427: f(x)= 22.674591972155618
# differential_evolution step 428: f(x)= 22.674591972155618
# differential_evolution step 429: f(x)= 22.674591972155618
# differential_evolution step 430: f(x)= 22.674591972155618
# differential_evolution step 431: f(x)= 22.674591972155618
# differential_evolution step 432: f(x)= 22.674591972155618
# differential_evolution step 433: f(x)= 22.674591972155618
# differential_evolution step 434: f(x)= 22.674591972155618
# differential_evolution step 435: f(x)= 22.674591972155618
# differential_evolution step 436: f(x)= 22.674591972155618
# differential_evolution step 437: f(x)= 22.674591972155618
# differential_evolution step 438: f(x)= 22.674591972155618
# differential_evolution step 439: f(x)= 22.674591972155618
# differential_evolution step 440: f(x)= 22.674591972155618
# differential_evolution step 441: f(x)= 22.674591972155618
# differential_evolution step 442: f(x)= 22.674591972155618
# differential_evolution step 443: f(x)= 22.674591972155618
# differential_evolution step 444: f(x)= 22.674591972155618
# differential_evolution step 445: f(x)= 22.674591972155618
# differential_evolution step 446: f(x)= 22.674591972155618
# differential_evolution step 447: f(x)= 22.674591972155618
# differential_evolution step 448: f(x)= 22.674591972155618
# differential_evolution step 449: f(x)= 22.674591972155618
# differential_evolution step 450: f(x)= 22.674591972155618
# differential_evolution step 451: f(x)= 22.674591972155618
# differential_evolution step 452: f(x)= 22.674591972155618
# differential_evolution step 453: f(x)= 22.674591972155618
# differential_evolution step 454: f(x)= 22.674591972155618
# differential_evolution step 455: f(x)= 22.674591972155618
# differential_evolution step 456: f(x)= 22.199722957776675
# differential_evolution step 457: f(x)= 22.199722957776675
# differential_evolution step 458: f(x)= 22.199722957776675
# differential_evolution step 459: f(x)= 22.199722957776675
# differential_evolution step 460: f(x)= 22.199722957776675
# differential_evolution step 461: f(x)= 22.199722957776675
# differential_evolution step 462: f(x)= 22.199722957776675
# differential_evolution step 463: f(x)= 22.199722957776675
# differential_evolution step 464: f(x)= 22.199722957776675
# differential_evolution step 465: f(x)= 22.199722957776675
# differential_evolution step 466: f(x)= 22.199722957776675
# differential_evolution step 467: f(x)= 22.199722957776675
# differential_evolution step 468: f(x)= 22.199722957776675
# differential_evolution step 469: f(x)= 22.199722957776675
# differential_evolution step 470: f(x)= 22.199722957776675
# differential_evolution step 471: f(x)= 22.199722957776675
# differential_evolution step 472: f(x)= 22.199722957776675
# differential_evolution step 473: f(x)= 22.199722957776675
# differential_evolution step 474: f(x)= 22.199722957776675
# differential_evolution step 475: f(x)= 22.199722957776675
# differential_evolution step 476: f(x)= 22.199722957776675
# differential_evolution step 477: f(x)= 22.162043232806774
# differential_evolution step 478: f(x)= 22.162043232806774
# differential_evolution step 479: f(x)= 22.162043232806774
# differential_evolution step 480: f(x)= 22.162043232806774
# differential_evolution step 481: f(x)= 22.162043232806774
# differential_evolution step 482: f(x)= 22.162043232806774
# differential_evolution step 483: f(x)= 22.162043232806774
# differential_evolution step 484: f(x)= 22.162043232806774
# differential_evolution step 485: f(x)= 22.162043232806774
# differential_evolution step 486: f(x)= 22.04692136251302
# differential_evolution step 487: f(x)= 22.04692136251302
# differential_evolution step 488: f(x)= 22.04692136251302
# differential_evolution step 489: f(x)= 22.04692136251302
# differential_evolution step 490: f(x)= 21.906004510891908
# differential_evolution step 491: f(x)= 21.906004510891908
# differential_evolution step 492: f(x)= 21.906004510891908
# differential_evolution step 493: f(x)= 21.906004510891908
# differential_evolution step 494: f(x)= 21.906004510891908
# differential_evolution step 495: f(x)= 21.906004510891908
# differential_evolution step 496: f(x)= 21.906004510891908
# differential_evolution step 497: f(x)= 21.906004510891908
# differential_evolution step 498: f(x)= 21.08800137221495
# differential_evolution step 499: f(x)= 21.08800137221495
# differential_evolution step 500: f(x)= 21.08800137221495
# differential_evolution step 501: f(x)= 21.08800137221495
# differential_evolution step 502: f(x)= 21.08800137221495
# differential_evolution step 503: f(x)= 21.08800137221495
# differential_evolution step 504: f(x)= 21.08800137221495
# differential_evolution step 505: f(x)= 21.08800137221495
# differential_evolution step 506: f(x)= 21.08800137221495
# differential_evolution step 507: f(x)= 21.08800137221495
# differential_evolution step 508: f(x)= 21.08800137221495
# differential_evolution step 509: f(x)= 21.08800137221495
# differential_evolution step 510: f(x)= 21.08800137221495
# differential_evolution step 511: f(x)= 21.08800137221495
# differential_evolution step 512: f(x)= 21.08800137221495
# differential_evolution step 513: f(x)= 21.08800137221495
# differential_evolution step 514: f(x)= 21.08800137221495
# differential_evolution step 515: f(x)= 21.08800137221495
# differential_evolution step 516: f(x)= 21.08800137221495
# differential_evolution step 517: f(x)= 21.08800137221495
# differential_evolution step 518: f(x)= 21.08800137221495
# differential_evolution step 519: f(x)= 21.08800137221495
# differential_evolution step 520: f(x)= 21.08800137221495
# differential_evolution step 521: f(x)= 21.08800137221495
# differential_evolution step 522: f(x)= 21.08800137221495
# differential_evolution step 523: f(x)= 21.08800137221495
# differential_evolution step 524: f(x)= 21.08800137221495
# differential_evolution step 525: f(x)= 21.08800137221495
# differential_evolution step 526: f(x)= 21.08800137221495
# differential_evolution step 527: f(x)= 21.08800137221495
# differential_evolution step 528: f(x)= 21.08800137221495
# differential_evolution step 529: f(x)= 21.08800137221495
# differential_evolution step 530: f(x)= 21.08800137221495
# differential_evolution step 531: f(x)= 21.08800137221495
# differential_evolution step 532: f(x)= 21.08800137221495
# differential_evolution step 533: f(x)= 21.08800137221495
# differential_evolution step 534: f(x)= 21.08800137221495
# differential_evolution step 535: f(x)= 21.08800137221495
# differential_evolution step 536: f(x)= 21.08800137221495
# differential_evolution step 537: f(x)= 21.08800137221495
# differential_evolution step 538: f(x)= 21.08800137221495
# differential_evolution step 539: f(x)= 21.030552249284504
# differential_evolution step 540: f(x)= 21.030552249284504
# differential_evolution step 541: f(x)= 21.030552249284504
# differential_evolution step 542: f(x)= 21.030552249284504
# differential_evolution step 543: f(x)= 21.030552249284504
# differential_evolution step 544: f(x)= 21.030552249284504
# differential_evolution step 545: f(x)= 21.030552249284504
# differential_evolution step 546: f(x)= 21.030552249284504
# differential_evolution step 547: f(x)= 21.030552249284504
# differential_evolution step 548: f(x)= 21.030552249284504
# differential_evolution step 549: f(x)= 21.030552249284504
# differential_evolution step 550: f(x)= 21.030552249284504
# differential_evolution step 551: f(x)= 21.030552249284504
# differential_evolution step 552: f(x)= 21.030552249284504
# differential_evolution step 553: f(x)= 21.030552249284504
# differential_evolution step 554: f(x)= 21.030552249284504
# differential_evolution step 555: f(x)= 21.030552249284504
# differential_evolution step 556: f(x)= 21.030552249284504
# differential_evolution step 557: f(x)= 21.030552249284504
# differential_evolution step 558: f(x)= 21.030552249284504
# differential_evolution step 559: f(x)= 20.980640655139798
# differential_evolution step 560: f(x)= 20.980640655139798
# differential_evolution step 561: f(x)= 20.980640655139798
# differential_evolution step 562: f(x)= 20.980640655139798
# differential_evolution step 563: f(x)= 20.980640655139798
# differential_evolution step 564: f(x)= 20.980640655139798
# differential_evolution step 565: f(x)= 20.980640655139798
# differential_evolution step 566: f(x)= 20.980640655139798
# differential_evolution step 567: f(x)= 20.980640655139798
# differential_evolution step 568: f(x)= 20.980640655139798
# differential_evolution step 569: f(x)= 20.980640655139798
# differential_evolution step 570: f(x)= 20.980640655139798
# differential_evolution step 571: f(x)= 20.980640655139798
# differential_evolution step 572: f(x)= 20.980640655139798
# differential_evolution step 573: f(x)= 20.980640655139798
# differential_evolution step 574: f(x)= 20.980640655139798
# differential_evolution step 575: f(x)= 20.980640655139798
# differential_evolution step 576: f(x)= 20.980640655139798
# differential_evolution step 577: f(x)= 20.980640655139798
# differential_evolution step 578: f(x)= 20.980640655139798
# differential_evolution step 579: f(x)= 20.980640655139798
# differential_evolution step 580: f(x)= 20.92548011981533
# differential_evolution step 581: f(x)= 20.92548011981533
# differential_evolution step 582: f(x)= 20.85670516425146
# differential_evolution step 583: f(x)= 20.85670516425146
# differential_evolution step 584: f(x)= 20.85670516425146
# differential_evolution step 585: f(x)= 20.85670516425146
# differential_evolution step 586: f(x)= 20.85670516425146
# differential_evolution step 587: f(x)= 20.85670516425146
# differential_evolution step 588: f(x)= 20.81609615421733
# differential_evolution step 589: f(x)= 20.81609615421733
# differential_evolution step 590: f(x)= 20.713261807632236
# differential_evolution step 591: f(x)= 20.713261807632236
# differential_evolution step 592: f(x)= 20.713261807632236
# differential_evolution step 593: f(x)= 20.713261807632236
# differential_evolution step 594: f(x)= 20.713261807632236
# differential_evolution step 595: f(x)= 20.713261807632236
# differential_evolution step 596: f(x)= 20.713261807632236
# differential_evolution step 597: f(x)= 20.713261807632236
# differential_evolution step 598: f(x)= 20.713261807632236
# differential_evolution step 599: f(x)= 20.713261807632236
# differential_evolution step 600: f(x)= 20.713261807632236
# differential_evolution step 601: f(x)= 20.713261807632236
# differential_evolution step 602: f(x)= 20.713261807632236
# differential_evolution step 603: f(x)= 20.713261807632236
# differential_evolution step 604: f(x)= 20.59023089298323
# differential_evolution step 605: f(x)= 20.59023089298323
# differential_evolution step 606: f(x)= 20.59023089298323
# differential_evolution step 607: f(x)= 20.59023089298323
# differential_evolution step 608: f(x)= 20.59023089298323
# differential_evolution step 609: f(x)= 20.59023089298323
# differential_evolution step 610: f(x)= 20.59023089298323
# differential_evolution step 611: f(x)= 20.59023089298323
# differential_evolution step 612: f(x)= 20.59023089298323
# differential_evolution step 613: f(x)= 20.52193831756004
# differential_evolution step 614: f(x)= 20.52193831756004
# differential_evolution step 615: f(x)= 20.52193831756004
# differential_evolution step 616: f(x)= 20.52193831756004
# differential_evolution step 617: f(x)= 20.52193831756004
# differential_evolution step 618: f(x)= 20.52193831756004
# differential_evolution step 619: f(x)= 20.52193831756004
# differential_evolution step 620: f(x)= 20.52193831756004
# differential_evolution step 621: f(x)= 20.52193831756004
# differential_evolution step 622: f(x)= 20.52193831756004
# differential_evolution step 623: f(x)= 20.457207441994363
# differential_evolution step 624: f(x)= 20.457207441994363
# differential_evolution step 625: f(x)= 20.457207441994363
# differential_evolution step 626: f(x)= 20.457207441994363
# differential_evolution step 627: f(x)= 20.457207441994363
# differential_evolution step 628: f(x)= 20.457207441994363
# differential_evolution step 629: f(x)= 20.457207441994363
# differential_evolution step 630: f(x)= 20.457207441994363
# differential_evolution step 631: f(x)= 20.457207441994363
# differential_evolution step 632: f(x)= 20.457207441994363
# differential_evolution step 633: f(x)= 20.457207441994363
# differential_evolution step 634: f(x)= 20.457207441994363
# differential_evolution step 635: f(x)= 20.457207441994363
# differential_evolution step 636: f(x)= 20.457207441994363
# differential_evolution step 637: f(x)= 20.457207441994363
# differential_evolution step 638: f(x)= 20.457207441994363
# differential_evolution step 639: f(x)= 20.457207441994363
# differential_evolution step 640: f(x)= 20.457207441994363
# differential_evolution step 641: f(x)= 20.457207441994363
# differential_evolution step 642: f(x)= 20.457207441994363
# differential_evolution step 643: f(x)= 20.457207441994363
# differential_evolution step 644: f(x)= 20.457207441994363
# differential_evolution step 645: f(x)= 20.457207441994363
# differential_evolution step 646: f(x)= 20.457207441994363
# differential_evolution step 647: f(x)= 20.457207441994363
# differential_evolution step 648: f(x)= 20.457207441994363
# differential_evolution step 649: f(x)= 20.457207441994363
# differential_evolution step 650: f(x)= 20.457207441994363
# differential_evolution step 651: f(x)= 20.457207441994363
# differential_evolution step 652: f(x)= 20.457207441994363
# differential_evolution step 653: f(x)= 20.457207441994363
# differential_evolution step 654: f(x)= 20.457207441994363
# differential_evolution step 655: f(x)= 20.457207441994363
# differential_evolution step 656: f(x)= 20.457207441994363
# differential_evolution step 657: f(x)= 20.457207441994363
# differential_evolution step 658: f(x)= 20.457207441994363
# differential_evolution step 659: f(x)= 20.457207441994363
# differential_evolution step 660: f(x)= 20.457207441994363
# differential_evolution step 661: f(x)= 20.457207441994363
# differential_evolution step 662: f(x)= 20.457207441994363
# differential_evolution step 663: f(x)= 20.440443558257204
# differential_evolution step 664: f(x)= 20.440443558257204
# differential_evolution step 665: f(x)= 20.440443558257204
# differential_evolution step 666: f(x)= 20.440443558257204
# differential_evolution step 667: f(x)= 20.440443558257204
# differential_evolution step 668: f(x)= 20.40311420211077
# differential_evolution step 669: f(x)= 20.40311420211077
# differential_evolution step 670: f(x)= 20.333308596093325
# differential_evolution step 671: f(x)= 20.333308596093325
# differential_evolution step 672: f(x)= 20.333308596093325
# differential_evolution step 673: f(x)= 20.333308596093325
# differential_evolution step 674: f(x)= 20.324956696422166
# differential_evolution step 675: f(x)= 20.324956696422166
# differential_evolution step 676: f(x)= 20.324956696422166
# differential_evolution step 677: f(x)= 20.324956696422166
# differential_evolution step 678: f(x)= 20.324956696422166
# differential_evolution step 679: f(x)= 20.20854943856663
# differential_evolution step 680: f(x)= 20.20854943856663
# differential_evolution step 681: f(x)= 20.20854943856663
# differential_evolution step 682: f(x)= 20.20854943856663
# differential_evolution step 683: f(x)= 20.1942531196374
# differential_evolution step 684: f(x)= 20.1942531196374
# differential_evolution step 685: f(x)= 20.1942531196374
# differential_evolution step 686: f(x)= 20.02947438118341
# differential_evolution step 687: f(x)= 20.02947438118341
# differential_evolution step 688: f(x)= 20.02947438118341
# differential_evolution step 689: f(x)= 20.02947438118341
# differential_evolution step 690: f(x)= 20.02947438118341
# differential_evolution step 691: f(x)= 20.02947438118341
# differential_evolution step 692: f(x)= 20.02947438118341
# differential_evolution step 693: f(x)= 20.027241428575458
# differential_evolution step 694: f(x)= 20.027241428575458
# differential_evolution step 695: f(x)= 20.027241428575458
# differential_evolution step 696: f(x)= 20.027241428575458
# differential_evolution step 697: f(x)= 20.027241428575458
# differential_evolution step 698: f(x)= 20.027241428575458
# differential_evolution step 699: f(x)= 20.027241428575458
# differential_evolution step 700: f(x)= 20.027241428575458
# differential_evolution step 701: f(x)= 20.027241428575458
# differential_evolution step 702: f(x)= 20.027241428575458
# differential_evolution step 703: f(x)= 20.027241428575458
# differential_evolution step 704: f(x)= 20.027241428575458
# differential_evolution step 705: f(x)= 20.027241428575458
# differential_evolution step 706: f(x)= 20.027241428575458
# differential_evolution step 707: f(x)= 20.027241428575458
# differential_evolution step 708: f(x)= 19.89701496115236
# differential_evolution step 709: f(x)= 19.89701496115236
# differential_evolution step 710: f(x)= 19.89701496115236
# differential_evolution step 711: f(x)= 19.89701496115236
# differential_evolution step 712: f(x)= 19.89701496115236
# differential_evolution step 713: f(x)= 19.89701496115236
# differential_evolution step 714: f(x)= 19.89701496115236
# differential_evolution step 715: f(x)= 19.89701496115236
# differential_evolution step 716: f(x)= 19.89701496115236
# differential_evolution step 717: f(x)= 19.89701496115236
# differential_evolution step 718: f(x)= 19.89701496115236
# differential_evolution step 719: f(x)= 19.89701496115236
# differential_evolution step 720: f(x)= 19.89701496115236
# differential_evolution step 721: f(x)= 19.89701496115236
# differential_evolution step 722: f(x)= 19.89701496115236
# differential_evolution step 723: f(x)= 19.89701496115236
# differential_evolution step 724: f(x)= 19.89701496115236
# differential_evolution step 725: f(x)= 19.89701496115236
# differential_evolution step 726: f(x)= 19.89701496115236
# differential_evolution step 727: f(x)= 19.89701496115236
# differential_evolution step 728: f(x)= 19.89701496115236
# differential_evolution step 729: f(x)= 19.89701496115236
# differential_evolution step 730: f(x)= 19.86606201101944
# differential_evolution step 731: f(x)= 19.86606201101944
# differential_evolution step 732: f(x)= 19.86606201101944
# differential_evolution step 733: f(x)= 19.86606201101944
# differential_evolution step 734: f(x)= 19.86606201101944
# differential_evolution step 735: f(x)= 19.86606201101944
# differential_evolution step 736: f(x)= 19.86606201101944
# differential_evolution step 737: f(x)= 19.86606201101944
# differential_evolution step 738: f(x)= 19.86606201101944
# differential_evolution step 739: f(x)= 19.86606201101944
# differential_evolution step 740: f(x)= 19.86606201101944
# differential_evolution step 741: f(x)= 19.86606201101944
# differential_evolution step 742: f(x)= 19.86606201101944
# differential_evolution step 743: f(x)= 19.86606201101944
# differential_evolution step 744: f(x)= 19.81542151843895
# differential_evolution step 745: f(x)= 19.81542151843895
# differential_evolution step 746: f(x)= 19.81542151843895
# differential_evolution step 747: f(x)= 19.81542151843895
# differential_evolution step 748: f(x)= 19.81542151843895
# differential_evolution step 749: f(x)= 19.81542151843895
# differential_evolution step 750: f(x)= 19.81542151843895
# differential_evolution step 751: f(x)= 19.81542151843895
# differential_evolution step 752: f(x)= 19.799808115088577
# differential_evolution step 753: f(x)= 19.799808115088577
# differential_evolution step 754: f(x)= 19.799808115088577
# differential_evolution step 755: f(x)= 19.799808115088577
# differential_evolution step 756: f(x)= 19.799808115088577
# differential_evolution step 757: f(x)= 19.799808115088577
# differential_evolution step 758: f(x)= 19.799808115088577
# differential_evolution step 759: f(x)= 19.799808115088577
# differential_evolution step 760: f(x)= 19.799808115088577
# differential_evolution step 761: f(x)= 19.799808115088577
# differential_evolution step 762: f(x)= 19.799808115088577
# differential_evolution step 763: f(x)= 19.799808115088577
# differential_evolution step 764: f(x)= 19.799808115088577
# differential_evolution step 765: f(x)= 19.799808115088577
# differential_evolution step 766: f(x)= 19.799808115088577
# differential_evolution step 767: f(x)= 19.799808115088577
# differential_evolution step 768: f(x)= 19.799808115088577
# differential_evolution step 769: f(x)= 19.732011698827783
# differential_evolution step 770: f(x)= 19.667099821919596
# differential_evolution step 771: f(x)= 19.667099821919596
# differential_evolution step 772: f(x)= 19.667099821919596
# differential_evolution step 773: f(x)= 19.667099821919596
# differential_evolution step 774: f(x)= 19.667099821919596
# differential_evolution step 775: f(x)= 19.667099821919596
# differential_evolution step 776: f(x)= 19.667099821919596
# differential_evolution step 777: f(x)= 19.667099821919596
# differential_evolution step 778: f(x)= 19.667099821919596
# differential_evolution step 779: f(x)= 19.667099821919596
# differential_evolution step 780: f(x)= 19.667099821919596
# differential_evolution step 781: f(x)= 19.623513807653254
# differential_evolution step 782: f(x)= 19.60449308713558
# differential_evolution step 783: f(x)= 19.60449308713558
# differential_evolution step 784: f(x)= 19.60449308713558
# differential_evolution step 785: f(x)= 19.60449308713558
# differential_evolution step 786: f(x)= 19.60449308713558
# differential_evolution step 787: f(x)= 19.60449308713558
# differential_evolution step 788: f(x)= 19.60449308713558
# differential_evolution step 789: f(x)= 19.60449308713558
# differential_evolution step 790: f(x)= 19.60449308713558
# differential_evolution step 791: f(x)= 19.60449308713558
# differential_evolution step 792: f(x)= 19.60449308713558
# differential_evolution step 793: f(x)= 19.60449308713558
# differential_evolution step 794: f(x)= 19.60449308713558
# differential_evolution step 795: f(x)= 19.60449308713558
# differential_evolution step 796: f(x)= 19.60449308713558
# differential_evolution step 797: f(x)= 19.60449308713558
# differential_evolution step 798: f(x)= 19.60449308713558
# differential_evolution step 799: f(x)= 19.57234497110225
# differential_evolution step 800: f(x)= 19.556715843752375
# differential_evolution step 801: f(x)= 19.51447951369138
# differential_evolution step 802: f(x)= 19.51447951369138
# differential_evolution step 803: f(x)= 19.51447951369138
# differential_evolution step 804: f(x)= 19.51447951369138
# differential_evolution step 805: f(x)= 19.51447951369138
# differential_evolution step 806: f(x)= 19.34920554640622
# differential_evolution step 807: f(x)= 19.34920554640622
# differential_evolution step 808: f(x)= 19.34920554640622
# differential_evolution step 809: f(x)= 19.34920554640622
# differential_evolution step 810: f(x)= 19.34920554640622
# differential_evolution step 811: f(x)= 19.34920554640622
# differential_evolution step 812: f(x)= 19.34920554640622
# differential_evolution step 813: f(x)= 19.34920554640622
# differential_evolution step 814: f(x)= 19.34920554640622
# differential_evolution step 815: f(x)= 19.34920554640622
# differential_evolution step 816: f(x)= 19.34920554640622
# differential_evolution step 817: f(x)= 19.34920554640622
# differential_evolution step 818: f(x)= 19.34920554640622
# differential_evolution step 819: f(x)= 19.34920554640622
# differential_evolution step 820: f(x)= 19.34920554640622
# differential_evolution step 821: f(x)= 19.34920554640622
# differential_evolution step 822: f(x)= 19.34920554640622
# differential_evolution step 823: f(x)= 19.34920554640622
# differential_evolution step 824: f(x)= 19.34920554640622
# differential_evolution step 825: f(x)= 19.34920554640622
# differential_evolution step 826: f(x)= 19.34920554640622
# differential_evolution step 827: f(x)= 19.34920554640622
# differential_evolution step 828: f(x)= 19.34920554640622
# differential_evolution step 829: f(x)= 19.34920554640622
# differential_evolution step 830: f(x)= 19.310061055757824
# differential_evolution step 831: f(x)= 19.310061055757824
# differential_evolution step 832: f(x)= 19.310061055757824
# differential_evolution step 833: f(x)= 19.310061055757824
# differential_evolution step 834: f(x)= 19.310061055757824
# differential_evolution step 835: f(x)= 19.310061055757824
# differential_evolution step 836: f(x)= 19.310061055757824
# differential_evolution step 837: f(x)= 19.310061055757824
# differential_evolution step 838: f(x)= 19.310061055757824
# differential_evolution step 839: f(x)= 19.310061055757824
# differential_evolution step 840: f(x)= 19.310061055757824
# differential_evolution step 841: f(x)= 19.310061055757824
# differential_evolution step 842: f(x)= 19.310061055757824
# differential_evolution step 843: f(x)= 19.310061055757824
# differential_evolution step 844: f(x)= 19.310061055757824
# differential_evolution step 845: f(x)= 19.310061055757824
# differential_evolution step 846: f(x)= 19.310061055757824
# differential_evolution step 847: f(x)= 19.243223087272842
# differential_evolution step 848: f(x)= 19.243223087272842
# differential_evolution step 849: f(x)= 19.243223087272842
# differential_evolution step 850: f(x)= 19.243223087272842
# differential_evolution step 851: f(x)= 19.243223087272842
# differential_evolution step 852: f(x)= 19.243223087272842
# differential_evolution step 853: f(x)= 19.243223087272842
# differential_evolution step 854: f(x)= 19.243223087272842
# differential_evolution step 855: f(x)= 19.243223087272842
# differential_evolution step 856: f(x)= 19.243223087272842
# differential_evolution step 857: f(x)= 19.243223087272842
# differential_evolution step 858: f(x)= 19.243223087272842
# differential_evolution step 859: f(x)= 19.243223087272842
# differential_evolution step 860: f(x)= 19.243223087272842
# differential_evolution step 861: f(x)= 19.243223087272842
# differential_evolution step 862: f(x)= 19.243223087272842
# differential_evolution step 863: f(x)= 19.243223087272842
# differential_evolution step 864: f(x)= 19.243223087272842
# differential_evolution step 865: f(x)= 19.243223087272842
# differential_evolution step 866: f(x)= 19.243223087272842
# differential_evolution step 867: f(x)= 19.243223087272842
# differential_evolution step 868: f(x)= 19.243223087272842
# differential_evolution step 869: f(x)= 19.243223087272842
# differential_evolution step 870: f(x)= 19.243223087272842
# differential_evolution step 871: f(x)= 19.243223087272842
# differential_evolution step 872: f(x)= 19.243223087272842
# differential_evolution step 873: f(x)= 19.243223087272842
# differential_evolution step 874: f(x)= 19.243223087272842
# differential_evolution step 875: f(x)= 19.243223087272842
# differential_evolution step 876: f(x)= 19.243223087272842
# differential_evolution step 877: f(x)= 19.243223087272842
# differential_evolution step 878: f(x)= 19.243223087272842
# differential_evolution step 879: f(x)= 19.243223087272842
# differential_evolution step 880: f(x)= 19.243223087272842
# differential_evolution step 881: f(x)= 19.18478472681459
# differential_evolution step 882: f(x)= 19.18478472681459
# differential_evolution step 883: f(x)= 19.18478472681459
# differential_evolution step 884: f(x)= 19.18478472681459
# differential_evolution step 885: f(x)= 19.18478472681459
# differential_evolution step 886: f(x)= 19.18478472681459
# differential_evolution step 887: f(x)= 19.18478472681459
# differential_evolution step 888: f(x)= 19.18478472681459
# differential_evolution step 889: f(x)= 19.18478472681459
# differential_evolution step 890: f(x)= 19.18478472681459
# differential_evolution step 891: f(x)= 19.18478472681459
# differential_evolution step 892: f(x)= 19.18478472681459
# differential_evolution step 893: f(x)= 19.18478472681459
# differential_evolution step 894: f(x)= 19.153182684335146
# differential_evolution step 895: f(x)= 19.153182684335146
# differential_evolution step 896: f(x)= 19.153182684335146
# differential_evolution step 897: f(x)= 19.153182684335146
# differential_evolution step 898: f(x)= 19.153182684335146
# differential_evolution step 899: f(x)= 19.153182684335146
# differential_evolution step 900: f(x)= 19.153182684335146
# differential_evolution step 901: f(x)= 19.153182684335146
# differential_evolution step 902: f(x)= 19.137845785896204
# differential_evolution step 903: f(x)= 19.137845785896204
# differential_evolution step 904: f(x)= 19.137845785896204
# differential_evolution step 905: f(x)= 19.137845785896204
# differential_evolution step 906: f(x)= 19.137845785896204
# differential_evolution step 907: f(x)= 19.137845785896204
# differential_evolution step 908: f(x)= 19.137845785896204
# differential_evolution step 909: f(x)= 19.137845785896204
# differential_evolution step 910: f(x)= 19.10827365087919
# differential_evolution step 911: f(x)= 19.10827365087919
# differential_evolution step 912: f(x)= 19.10827365087919
# differential_evolution step 913: f(x)= 19.10827365087919
# differential_evolution step 914: f(x)= 19.10827365087919
# differential_evolution step 915: f(x)= 19.10827365087919
# differential_evolution step 916: f(x)= 19.10827365087919
# differential_evolution step 917: f(x)= 19.10827365087919
# differential_evolution step 918: f(x)= 19.10827365087919
# differential_evolution step 919: f(x)= 19.10827365087919
# differential_evolution step 920: f(x)= 19.10827365087919
# differential_evolution step 921: f(x)= 19.10827365087919
# differential_evolution step 922: f(x)= 19.10827365087919
# differential_evolution step 923: f(x)= 19.10827365087919
# differential_evolution step 924: f(x)= 19.10827365087919
# differential_evolution step 925: f(x)= 19.10827365087919
# differential_evolution step 926: f(x)= 19.10827365087919
# differential_evolution step 927: f(x)= 19.10827365087919
# differential_evolution step 928: f(x)= 19.10827365087919
# differential_evolution step 929: f(x)= 19.10827365087919
# differential_evolution step 930: f(x)= 19.10827365087919
# differential_evolution step 931: f(x)= 19.10827365087919
# differential_evolution step 932: f(x)= 19.10827365087919
# differential_evolution step 933: f(x)= 19.10827365087919
# differential_evolution step 934: f(x)= 19.10827365087919
# differential_evolution step 935: f(x)= 19.10827365087919
# differential_evolution step 936: f(x)= 19.10827365087919
# differential_evolution step 937: f(x)= 19.10827365087919
# differential_evolution step 938: f(x)= 19.10827365087919
# differential_evolution step 939: f(x)= 19.10827365087919
# differential_evolution step 940: f(x)= 19.10827365087919
# differential_evolution step 941: f(x)= 19.10827365087919
# differential_evolution step 942: f(x)= 19.10827365087919
# differential_evolution step 943: f(x)= 19.10827365087919
# differential_evolution step 944: f(x)= 19.10827365087919
# differential_evolution step 945: f(x)= 19.10827365087919
# differential_evolution step 946: f(x)= 19.10827365087919
# differential_evolution step 947: f(x)= 19.10827365087919
# differential_evolution step 948: f(x)= 19.10827365087919
# differential_evolution step 949: f(x)= 19.10827365087919
# differential_evolution step 950: f(x)= 19.10827365087919
# differential_evolution step 951: f(x)= 19.10827365087919
# differential_evolution step 952: f(x)= 19.10827365087919
# differential_evolution step 953: f(x)= 19.10827365087919
# differential_evolution step 954: f(x)= 19.10827365087919
# differential_evolution step 955: f(x)= 19.10827365087919
# differential_evolution step 956: f(x)= 19.10827365087919
# differential_evolution step 957: f(x)= 19.10827365087919
# differential_evolution step 958: f(x)= 19.10827365087919
# differential_evolution step 959: f(x)= 19.10827365087919
# differential_evolution step 960: f(x)= 19.10827365087919
# differential_evolution step 961: f(x)= 19.10827365087919
# differential_evolution step 962: f(x)= 19.10827365087919
# differential_evolution step 963: f(x)= 19.10484068100799
# differential_evolution step 964: f(x)= 19.10484068100799
# differential_evolution step 965: f(x)= 19.10484068100799
# differential_evolution step 966: f(x)= 19.10484068100799
# differential_evolution step 967: f(x)= 19.10484068100799
# differential_evolution step 968: f(x)= 19.10484068100799
# differential_evolution step 969: f(x)= 19.10484068100799
# differential_evolution step 970: f(x)= 19.10484068100799
# differential_evolution step 971: f(x)= 19.10484068100799
# differential_evolution step 972: f(x)= 19.10484068100799
# differential_evolution step 973: f(x)= 19.10484068100799
# differential_evolution step 974: f(x)= 19.10484068100799
# differential_evolution step 975: f(x)= 19.099506202315986
# differential_evolution step 976: f(x)= 19.099506202315986
# differential_evolution step 977: f(x)= 19.099506202315986
# differential_evolution step 978: f(x)= 19.099506202315986
# differential_evolution step 979: f(x)= 19.099506202315986
# differential_evolution step 980: f(x)= 19.099506202315986
# differential_evolution step 981: f(x)= 19.099506202315986
# differential_evolution step 982: f(x)= 19.099506202315986
# differential_evolution step 983: f(x)= 19.099506202315986
# differential_evolution step 984: f(x)= 19.099506202315986
# differential_evolution step 985: f(x)= 19.08863332020625
# differential_evolution step 986: f(x)= 19.08863332020625
# differential_evolution step 987: f(x)= 19.08863332020625
# differential_evolution step 988: f(x)= 19.08863332020625
# differential_evolution step 989: f(x)= 19.08863332020625
# differential_evolution step 990: f(x)= 19.08863332020625
# differential_evolution step 991: f(x)= 19.08863332020625
# differential_evolution step 992: f(x)= 19.087537250939164
# differential_evolution step 993: f(x)= 19.087537250939164
# differential_evolution step 994: f(x)= 19.087537250939164
# differential_evolution step 995: f(x)= 19.087537250939164
# differential_evolution step 996: f(x)= 19.087537250939164
# differential_evolution step 997: f(x)= 19.087537250939164
# differential_evolution step 998: f(x)= 19.087537250939164
# differential_evolution step 999: f(x)= 19.077796412484684
# differential_evolution step 1000: f(x)= 19.077796412484684
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=2.2741, r_e=5.8475, n=0.1000, x_0=30.9476
# Sérsic 2: I_e=0.6776, r_e=41.5451, n=2.7719, x_0=48.5087
# Sérsic 3: I_e=2.6904, r_e=2.5293, n=0.5712, x_0=55.0000
# Sérsic 4: I_e=0.6576, r_e=13.9514, n=1.2074, x_0=66.3596
# Chi quadro minimo: 19.03161755337004
# False

# %%
def plot_curve(x_axes, params_curve, radial_profile, radial_profile_err, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *params_curve)
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].errorbar(x_axes, radial_profile, radial_profile_err, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[20:24], sigma), color = 'purple', linestyle='--', label='Sérsic 6')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *params_curve[24:28], sigma), color = 'deeppink', linestyle='--', label='Sérsic 7')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 30)
    #ax[0].tight_layout()
    
    ax[1].scatter(x_axes, (radial_profile - y_fit)/radial_profile_err, marker = '+')
    ax[1].axhline(0, color ='red', linestyle ='dashed')
    ax[1].set_ylabel(r'$\chi$')

def plot_diff(x_axes, best_params, radial_profile, sigma, title = ""):
    y_fit = model_convolved(x_axes, sigma, *best_params)

    fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

    ax[0].plot(x_axes, radial_profile, label='Data')
    ax[0].plot(x_axes, y_fit, 'r-', label='Fit')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[0:4], sigma), 'b--', label='Sérsic 1')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[4:8], sigma), 'g--', label='Sérsic 2')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[8:12], sigma), 'm--', label='Sérsic 3')
    ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[12:16], sigma), color='orange', linestyle='--', label='Sérsic 4')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[16:20], sigma), color = 'chocolate', linestyle='--', label='Sérsic 5')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[20:24], sigma), color = 'purple', linestyle='--', label='Sérsic 6')
    #ax[0].plot(x_axes, sersic_1d_convolved(x_axes, *best_params[24:28], sigma), color = 'deeppink', linestyle='--', label='Sérsic 7')

    ax[0].set_xlabel("Pixel")
    ax[0].set_ylabel(r'Flux [$10^{-16} erg/(cm^2 s \AA )$]')
    ax[0].set_title(title)
    ax[0].legend()
    ax[0].grid(True)
    #ax[0].set_ylim(0, 30)
    #ax[0].tight_layout()
    
    ax[1].plot(x_axes, radial_profile - y_fit)
    ax[1].set_ylim(-0.2, 0.2)

# %%
save_params_diff(best_params, radial_profile_continuum_1, real_errors_c1, sigmas[1],
    x_axes, n_component, line_name="Continuum_1", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_diff')
# Out:
# Sérsic 1: I_e=2.2741, r_e=5.8475, n=0.1000, x_0=30.9476
# Sérsic 2: I_e=0.6776, r_e=41.5451, n=2.7719, x_0=48.5087
# Sérsic 3: I_e=2.6904, r_e=2.5293, n=0.5712, x_0=55.0000
# Sérsic 4: I_e=0.6576, r_e=13.9514, n=1.2074, x_0=66.3596
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))

params_curve_continuum_1, covariance_continuum_1 = curve_fit(lambda x, *params: model_convolved(x, sigmas[1], *params), x_axes,
                                                             radial_profile_continuum_1, p0=result.x, sigma = real_errors_c1, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_1, dof_continuum_1, chi2_continuum_1 = save_params(params_curve_continuum_1, covariance_continuum_1, 
                                                                          radial_profile_continuum_1, real_errors_c1, sigmas[1],
                                                                          x_axes, n_component, line_name="Continuum_1", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.4321, r_e=18.9409, n=0.9115, x_0=34.9654
# Sérsic 2: I_e=6.9647, r_e=4.4578, n=1.2415, x_0=48.4419
# Sérsic 3: I_e=4.6792, r_e=2.4872, n=0.4060, x_0=55.0000
# Sérsic 4: I_e=1.8504, r_e=14.6061, n=0.7439, x_0=65.0000
# [0.23983011 1.2917028  0.09031308 1.07970549 3.56048792 1.54818542
#  0.39892918 0.19751107 2.11629644 0.75831798 0.346808   0.63690849
#  0.26447377 0.67821598 0.08747838 1.1418148 ]
# 8.360874000508318

# %%
# Plots:
plot_curve(x_axes, params_curve_continuum_1, radial_profile_continuum_1, real_errors_c1, sigmas[1], r"Radial profile Continuum 1")
plt.savefig('Radial_profile_continuum_1_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Continuum 2

# %%
mask_continuum_2 = (wv > 5300)*(wv < 5800)
image_continuum_2 = image_cut[:, mask_continuum_2]
image_error_continuum_2 = image_error_cut[:, mask_continuum_2]
radial_profile_continuum_2 = np.sum(image_continuum_2, axis = 1)
radial_profile_error_continuum_2 = np.sqrt(np.sum(image_error_continuum_2**2, axis = 1))
real_errors_c2 = np.sqrt(radial_profile_error_continuum_2**2+(sky_err[2])**2+(0.04*radial_profile_continuum_2)**2)

plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_2)
plt.plot(x_axes, radial_profile_error_continuum_2)
plt.title(r'Continuum 2')
# Out:
# Text(0.5, 1.0, 'Continuum 2')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_2, sigmas[5])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 11623.106927991945
# differential_evolution step 2: f(x)= 11623.106927991945
# differential_evolution step 3: f(x)= 7146.897679662442
# differential_evolution step 4: f(x)= 2856.546912374427
# differential_evolution step 5: f(x)= 2856.546912374427
# differential_evolution step 6: f(x)= 2856.546912374427
# differential_evolution step 7: f(x)= 2856.546912374427
# differential_evolution step 8: f(x)= 2856.546912374427
# differential_evolution step 9: f(x)= 1949.5671869514517
# differential_evolution step 10: f(x)= 1109.186035322138
# differential_evolution step 11: f(x)= 1109.186035322138
# differential_evolution step 12: f(x)= 1109.186035322138
# differential_evolution step 13: f(x)= 1035.61997367669
# differential_evolution step 14: f(x)= 1035.61997367669
# differential_evolution step 15: f(x)= 646.8752281436429
# differential_evolution step 16: f(x)= 646.8752281436429
# differential_evolution step 17: f(x)= 646.8752281436429
# differential_evolution step 18: f(x)= 486.95342428784096
# differential_evolution step 19: f(x)= 486.95342428784096
# differential_evolution step 20: f(x)= 486.95342428784096
# differential_evolution step 21: f(x)= 486.95342428784096
# differential_evolution step 22: f(x)= 486.95342428784096
# differential_evolution step 23: f(x)= 323.65854000656736
# differential_evolution step 24: f(x)= 323.65854000656736
# differential_evolution step 25: f(x)= 323.65854000656736
# differential_evolution step 26: f(x)= 323.65854000656736
# differential_evolution step 27: f(x)= 323.65854000656736
# differential_evolution step 28: f(x)= 289.3988823665846
# differential_evolution step 29: f(x)= 289.3988823665846
# differential_evolution step 30: f(x)= 271.1849854448973
# differential_evolution step 31: f(x)= 271.1849854448973
# differential_evolution step 32: f(x)= 271.1849854448973
# differential_evolution step 33: f(x)= 271.1849854448973
# differential_evolution step 34: f(x)= 271.1849854448973
# differential_evolution step 35: f(x)= 271.1849854448973
# differential_evolution step 36: f(x)= 271.1849854448973
# differential_evolution step 37: f(x)= 271.1849854448973
# differential_evolution step 38: f(x)= 271.1849854448973
# differential_evolution step 39: f(x)= 271.1849854448973
# differential_evolution step 40: f(x)= 271.1849854448973
# differential_evolution step 41: f(x)= 267.87708942201397
# differential_evolution step 42: f(x)= 224.56835565522084
# differential_evolution step 43: f(x)= 224.56835565522084
# differential_evolution step 44: f(x)= 224.56835565522084
# differential_evolution step 45: f(x)= 217.58591941633745
# differential_evolution step 46: f(x)= 217.58591941633745
# differential_evolution step 47: f(x)= 197.86368263867905
# differential_evolution step 48: f(x)= 197.86368263867905
# differential_evolution step 49: f(x)= 197.86368263867905
# differential_evolution step 50: f(x)= 197.86368263867905
# differential_evolution step 51: f(x)= 186.17767684675923
# differential_evolution step 52: f(x)= 186.17767684675923
# differential_evolution step 53: f(x)= 186.17767684675923
# differential_evolution step 54: f(x)= 186.17767684675923
# differential_evolution step 55: f(x)= 186.17767684675923
# differential_evolution step 56: f(x)= 186.17767684675923
# differential_evolution step 57: f(x)= 186.17767684675923
# differential_evolution step 58: f(x)= 186.17767684675923
# differential_evolution step 59: f(x)= 186.17767684675923
# differential_evolution step 60: f(x)= 186.17767684675923
# differential_evolution step 61: f(x)= 186.17767684675923
# differential_evolution step 62: f(x)= 180.6117366710425
# differential_evolution step 63: f(x)= 180.6117366710425
# differential_evolution step 64: f(x)= 153.79328385304692
# differential_evolution step 65: f(x)= 153.79328385304692
# differential_evolution step 66: f(x)= 153.79328385304692
# differential_evolution step 67: f(x)= 153.79328385304692
# differential_evolution step 68: f(x)= 153.79328385304692
# differential_evolution step 69: f(x)= 153.79328385304692
# differential_evolution step 70: f(x)= 153.79328385304692
# differential_evolution step 71: f(x)= 153.79328385304692
# differential_evolution step 72: f(x)= 153.79328385304692
# differential_evolution step 73: f(x)= 153.79328385304692
# differential_evolution step 74: f(x)= 153.79328385304692
# differential_evolution step 75: f(x)= 153.79328385304692
# differential_evolution step 76: f(x)= 153.79328385304692
# differential_evolution step 77: f(x)= 153.79328385304692
# differential_evolution step 78: f(x)= 153.79328385304692
# differential_evolution step 79: f(x)= 153.79328385304692
# differential_evolution step 80: f(x)= 153.79328385304692
# differential_evolution step 81: f(x)= 147.32262928813154
# differential_evolution step 82: f(x)= 147.32262928813154
# differential_evolution step 83: f(x)= 147.32262928813154
# differential_evolution step 84: f(x)= 147.32262928813154
# differential_evolution step 85: f(x)= 147.32262928813154
# differential_evolution step 86: f(x)= 147.32262928813154
# differential_evolution step 87: f(x)= 147.32262928813154
# differential_evolution step 88: f(x)= 147.32262928813154
# differential_evolution step 89: f(x)= 147.32262928813154
# differential_evolution step 90: f(x)= 147.32262928813154
# differential_evolution step 91: f(x)= 147.32262928813154
# differential_evolution step 92: f(x)= 143.1951412312576
# differential_evolution step 93: f(x)= 143.1951412312576
# differential_evolution step 94: f(x)= 143.1951412312576
# differential_evolution step 95: f(x)= 142.6327185605125
# differential_evolution step 96: f(x)= 142.6327185605125
# differential_evolution step 97: f(x)= 139.94936503070974
# differential_evolution step 98: f(x)= 124.14954840557607
# differential_evolution step 99: f(x)= 124.14954840557607
# differential_evolution step 100: f(x)= 124.14954840557607
# differential_evolution step 101: f(x)= 124.14954840557607
# differential_evolution step 102: f(x)= 124.14954840557607
# differential_evolution step 103: f(x)= 124.14954840557607
# differential_evolution step 104: f(x)= 124.14954840557607
# differential_evolution step 105: f(x)= 124.14954840557607
# differential_evolution step 106: f(x)= 124.14954840557607
# differential_evolution step 107: f(x)= 124.14954840557607
# differential_evolution step 108: f(x)= 124.14954840557607
# differential_evolution step 109: f(x)= 124.14954840557607
# differential_evolution step 110: f(x)= 124.14954840557607
# differential_evolution step 111: f(x)= 124.14954840557607
# differential_evolution step 112: f(x)= 124.14954840557607
# differential_evolution step 113: f(x)= 124.14954840557607
# differential_evolution step 114: f(x)= 124.14954840557607
# differential_evolution step 115: f(x)= 124.14954840557607
# differential_evolution step 116: f(x)= 124.14954840557607
# differential_evolution step 117: f(x)= 117.88178089373163
# differential_evolution step 118: f(x)= 117.88178089373163
# differential_evolution step 119: f(x)= 117.88178089373163
# differential_evolution step 120: f(x)= 117.88178089373163
# differential_evolution step 121: f(x)= 117.88178089373163
# differential_evolution step 122: f(x)= 117.88178089373163
# differential_evolution step 123: f(x)= 117.88178089373163
# differential_evolution step 124: f(x)= 113.53410824118248
# differential_evolution step 125: f(x)= 113.53410824118248
# differential_evolution step 126: f(x)= 113.53410824118248
# differential_evolution step 127: f(x)= 113.53410824118248
# differential_evolution step 128: f(x)= 113.53410824118248
# differential_evolution step 129: f(x)= 111.60619644427982
# differential_evolution step 130: f(x)= 111.60619644427982
# differential_evolution step 131: f(x)= 111.60619644427982
# differential_evolution step 132: f(x)= 111.60619644427982
# differential_evolution step 133: f(x)= 111.60619644427982
# differential_evolution step 134: f(x)= 111.60619644427982
# differential_evolution step 135: f(x)= 111.60619644427982
# differential_evolution step 136: f(x)= 111.60619644427982
# differential_evolution step 137: f(x)= 111.60619644427982
# differential_evolution step 138: f(x)= 111.60619644427982
# differential_evolution step 139: f(x)= 111.60619644427982
# differential_evolution step 140: f(x)= 111.60619644427982
# differential_evolution step 141: f(x)= 111.60619644427982
# differential_evolution step 142: f(x)= 111.60619644427982
# differential_evolution step 143: f(x)= 111.60619644427982
# differential_evolution step 144: f(x)= 111.60619644427982
# differential_evolution step 145: f(x)= 111.60619644427982
# differential_evolution step 146: f(x)= 111.60619644427982
# differential_evolution step 147: f(x)= 111.32879826467766
# differential_evolution step 148: f(x)= 111.32879826467766
# differential_evolution step 149: f(x)= 111.32879826467766
# differential_evolution step 150: f(x)= 111.32879826467766
# differential_evolution step 151: f(x)= 111.32879826467766
# differential_evolution step 152: f(x)= 111.32879826467766
# differential_evolution step 153: f(x)= 111.32879826467766
# differential_evolution step 154: f(x)= 111.32879826467766
# differential_evolution step 155: f(x)= 109.81592355058201
# differential_evolution step 156: f(x)= 109.81592355058201
# differential_evolution step 157: f(x)= 109.81592355058201
# differential_evolution step 158: f(x)= 109.81592355058201
# differential_evolution step 159: f(x)= 109.81592355058201
# differential_evolution step 160: f(x)= 105.36400492925944
# differential_evolution step 161: f(x)= 105.36400492925944
# differential_evolution step 162: f(x)= 105.36400492925944
# differential_evolution step 163: f(x)= 105.36400492925944
# differential_evolution step 164: f(x)= 105.36400492925944
# differential_evolution step 165: f(x)= 105.36400492925944
# differential_evolution step 166: f(x)= 105.36400492925944
# differential_evolution step 167: f(x)= 105.36400492925944
# differential_evolution step 168: f(x)= 105.36400492925944
# differential_evolution step 169: f(x)= 105.36400492925944
# differential_evolution step 170: f(x)= 105.36400492925944
# differential_evolution step 171: f(x)= 105.36400492925944
# differential_evolution step 172: f(x)= 105.36400492925944
# differential_evolution step 173: f(x)= 105.36400492925944
# differential_evolution step 174: f(x)= 105.36400492925944
# differential_evolution step 175: f(x)= 105.36400492925944
# differential_evolution step 176: f(x)= 105.36400492925944
# differential_evolution step 177: f(x)= 103.84597024386831
# differential_evolution step 178: f(x)= 103.84597024386831
# differential_evolution step 179: f(x)= 103.84597024386831
# differential_evolution step 180: f(x)= 103.84597024386831
# differential_evolution step 181: f(x)= 103.84597024386831
# differential_evolution step 182: f(x)= 103.84597024386831
# differential_evolution step 183: f(x)= 103.84597024386831
# differential_evolution step 184: f(x)= 103.84597024386831
# differential_evolution step 185: f(x)= 103.84597024386831
# differential_evolution step 186: f(x)= 103.84597024386831
# differential_evolution step 187: f(x)= 103.84597024386831
# differential_evolution step 188: f(x)= 103.84597024386831
# differential_evolution step 189: f(x)= 103.84597024386831
# differential_evolution step 190: f(x)= 103.84597024386831
# differential_evolution step 191: f(x)= 103.84597024386831
# differential_evolution step 192: f(x)= 103.84597024386831
# differential_evolution step 193: f(x)= 103.84597024386831
# differential_evolution step 194: f(x)= 103.84597024386831
# differential_evolution step 195: f(x)= 103.84597024386831
# differential_evolution step 196: f(x)= 102.51381046656225
# differential_evolution step 197: f(x)= 102.51381046656225
# differential_evolution step 198: f(x)= 102.51381046656225
# differential_evolution step 199: f(x)= 102.51381046656225
# differential_evolution step 200: f(x)= 102.51381046656225
# differential_evolution step 201: f(x)= 102.51381046656225
# differential_evolution step 202: f(x)= 102.51381046656225
# differential_evolution step 203: f(x)= 102.51381046656225
# differential_evolution step 204: f(x)= 102.51381046656225
# differential_evolution step 205: f(x)= 102.51381046656225
# differential_evolution step 206: f(x)= 102.51381046656225
# differential_evolution step 207: f(x)= 102.51381046656225
# differential_evolution step 208: f(x)= 102.51381046656225
# differential_evolution step 209: f(x)= 102.51381046656225
# differential_evolution step 210: f(x)= 102.51381046656225
# differential_evolution step 211: f(x)= 102.51381046656225
# differential_evolution step 212: f(x)= 102.51381046656225
# differential_evolution step 213: f(x)= 101.4298331417298
# differential_evolution step 214: f(x)= 101.4298331417298
# differential_evolution step 215: f(x)= 101.4298331417298
# differential_evolution step 216: f(x)= 101.4298331417298
# differential_evolution step 217: f(x)= 100.09951431349093
# differential_evolution step 218: f(x)= 100.09951431349093
# differential_evolution step 219: f(x)= 100.09951431349093
# differential_evolution step 220: f(x)= 100.09951431349093
# differential_evolution step 221: f(x)= 100.09951431349093
# differential_evolution step 222: f(x)= 100.09951431349093
# differential_evolution step 223: f(x)= 100.09951431349093
# differential_evolution step 224: f(x)= 100.09951431349093
# differential_evolution step 225: f(x)= 98.76619895170396
# differential_evolution step 226: f(x)= 98.76619895170396
# differential_evolution step 227: f(x)= 98.76619895170396
# differential_evolution step 228: f(x)= 98.76619895170396
# differential_evolution step 229: f(x)= 98.76619895170396
# differential_evolution step 230: f(x)= 98.76619895170396
# differential_evolution step 231: f(x)= 98.76619895170396
# differential_evolution step 232: f(x)= 98.76619895170396
# differential_evolution step 233: f(x)= 98.76619895170396
# differential_evolution step 234: f(x)= 98.408392732423
# differential_evolution step 235: f(x)= 97.1365269729566
# differential_evolution step 236: f(x)= 97.1365269729566
# differential_evolution step 237: f(x)= 97.1365269729566
# differential_evolution step 238: f(x)= 97.1365269729566
# differential_evolution step 239: f(x)= 97.1365269729566
# differential_evolution step 240: f(x)= 97.1365269729566
# differential_evolution step 241: f(x)= 97.1365269729566
# differential_evolution step 242: f(x)= 96.41436543700739
# differential_evolution step 243: f(x)= 96.41436543700739
# differential_evolution step 244: f(x)= 96.41436543700739
# differential_evolution step 245: f(x)= 94.3611323517871
# differential_evolution step 246: f(x)= 94.3611323517871
# differential_evolution step 247: f(x)= 94.3611323517871
# differential_evolution step 248: f(x)= 94.3611323517871
# differential_evolution step 249: f(x)= 94.3611323517871
# differential_evolution step 250: f(x)= 94.3611323517871
# differential_evolution step 251: f(x)= 94.3611323517871
# differential_evolution step 252: f(x)= 94.3611323517871
# differential_evolution step 253: f(x)= 94.3611323517871
# differential_evolution step 254: f(x)= 94.3611323517871
# differential_evolution step 255: f(x)= 93.77562030439648
# differential_evolution step 256: f(x)= 93.77562030439648
# differential_evolution step 257: f(x)= 93.77562030439648
# differential_evolution step 258: f(x)= 93.77562030439648
# differential_evolution step 259: f(x)= 93.77562030439648
# differential_evolution step 260: f(x)= 93.77562030439648
# differential_evolution step 261: f(x)= 93.77562030439648
# differential_evolution step 262: f(x)= 93.77562030439648
# differential_evolution step 263: f(x)= 93.77562030439648
# differential_evolution step 264: f(x)= 93.77562030439648
# differential_evolution step 265: f(x)= 93.77562030439648
# differential_evolution step 266: f(x)= 93.77562030439648
# differential_evolution step 267: f(x)= 93.77562030439648
# differential_evolution step 268: f(x)= 93.1767157469362
# differential_evolution step 269: f(x)= 93.1767157469362
# differential_evolution step 270: f(x)= 93.1767157469362
# differential_evolution step 271: f(x)= 93.1767157469362
# differential_evolution step 272: f(x)= 93.1767157469362
# differential_evolution step 273: f(x)= 93.1767157469362
# differential_evolution step 274: f(x)= 92.76518782265225
# differential_evolution step 275: f(x)= 92.76518782265225
# differential_evolution step 276: f(x)= 92.76518782265225
# differential_evolution step 277: f(x)= 92.76518782265225
# differential_evolution step 278: f(x)= 92.76518782265225
# differential_evolution step 279: f(x)= 92.76518782265225
# differential_evolution step 280: f(x)= 92.76518782265225
# differential_evolution step 281: f(x)= 92.44224819020552
# differential_evolution step 282: f(x)= 92.44224819020552
# differential_evolution step 283: f(x)= 92.44224819020552
# differential_evolution step 284: f(x)= 92.44224819020552
# differential_evolution step 285: f(x)= 92.44224819020552
# differential_evolution step 286: f(x)= 92.44224819020552
# differential_evolution step 287: f(x)= 92.44224819020552
# differential_evolution step 288: f(x)= 92.44224819020552
# differential_evolution step 289: f(x)= 92.44224819020552
# differential_evolution step 290: f(x)= 92.44224819020552
# differential_evolution step 291: f(x)= 92.44224819020552
# differential_evolution step 292: f(x)= 92.44224819020552
# differential_evolution step 293: f(x)= 91.89667097504075
# differential_evolution step 294: f(x)= 91.89667097504075
# differential_evolution step 295: f(x)= 91.89667097504075
# differential_evolution step 296: f(x)= 91.89667097504075
# differential_evolution step 297: f(x)= 91.89667097504075
# differential_evolution step 298: f(x)= 91.89667097504075
# differential_evolution step 299: f(x)= 91.89667097504075
# differential_evolution step 300: f(x)= 91.89667097504075
# differential_evolution step 301: f(x)= 91.89667097504075
# differential_evolution step 302: f(x)= 91.89667097504075
# differential_evolution step 303: f(x)= 91.87569743203284
# differential_evolution step 304: f(x)= 91.35174586865644
# differential_evolution step 305: f(x)= 91.35174586865644
# differential_evolution step 306: f(x)= 91.35174586865644
# differential_evolution step 307: f(x)= 91.35174586865644
# differential_evolution step 308: f(x)= 91.35174586865644
# differential_evolution step 309: f(x)= 90.91567976737072
# differential_evolution step 310: f(x)= 90.91567976737072
# differential_evolution step 311: f(x)= 90.91567976737072
# differential_evolution step 312: f(x)= 90.91567976737072
# differential_evolution step 313: f(x)= 90.91567976737072
# differential_evolution step 314: f(x)= 90.91567976737072
# differential_evolution step 315: f(x)= 90.91567976737072
# differential_evolution step 316: f(x)= 90.4109824231253
# differential_evolution step 317: f(x)= 90.27791759735028
# differential_evolution step 318: f(x)= 90.27791759735028
# differential_evolution step 319: f(x)= 90.27791759735028
# differential_evolution step 320: f(x)= 89.91897592059445
# differential_evolution step 321: f(x)= 89.91897592059445
# differential_evolution step 322: f(x)= 89.91897592059445
# differential_evolution step 323: f(x)= 89.91897592059445
# differential_evolution step 324: f(x)= 89.91897592059445
# differential_evolution step 325: f(x)= 89.91897592059445
# differential_evolution step 326: f(x)= 89.91897592059445
# differential_evolution step 327: f(x)= 89.91897592059445
# differential_evolution step 328: f(x)= 89.91897592059445
# differential_evolution step 329: f(x)= 89.91897592059445
# differential_evolution step 330: f(x)= 89.91897592059445
# differential_evolution step 331: f(x)= 89.91897592059445
# differential_evolution step 332: f(x)= 89.91897592059445
# differential_evolution step 333: f(x)= 89.91897592059445
# differential_evolution step 334: f(x)= 89.91897592059445
# differential_evolution step 335: f(x)= 89.91897592059445
# differential_evolution step 336: f(x)= 89.91897592059445
# differential_evolution step 337: f(x)= 89.91897592059445
# differential_evolution step 338: f(x)= 89.91897592059445
# differential_evolution step 339: f(x)= 89.91897592059445
# differential_evolution step 340: f(x)= 89.91897592059445
# differential_evolution step 341: f(x)= 89.91897592059445
# differential_evolution step 342: f(x)= 89.91897592059445
# differential_evolution step 343: f(x)= 89.91897592059445
# differential_evolution step 344: f(x)= 89.91897592059445
# differential_evolution step 345: f(x)= 89.91897592059445
# differential_evolution step 346: f(x)= 89.91897592059445
# differential_evolution step 347: f(x)= 89.91897592059445
# differential_evolution step 348: f(x)= 89.91897592059445
# differential_evolution step 349: f(x)= 89.7835181143497
# differential_evolution step 350: f(x)= 89.7835181143497
# differential_evolution step 351: f(x)= 89.7835181143497
# differential_evolution step 352: f(x)= 89.7835181143497
# differential_evolution step 353: f(x)= 89.7835181143497
# differential_evolution step 354: f(x)= 89.7835181143497
# differential_evolution step 355: f(x)= 89.7835181143497
# differential_evolution step 356: f(x)= 89.7835181143497
# differential_evolution step 357: f(x)= 89.7835181143497
# differential_evolution step 358: f(x)= 89.7835181143497
# differential_evolution step 359: f(x)= 89.7835181143497
# differential_evolution step 360: f(x)= 89.7835181143497
# differential_evolution step 361: f(x)= 89.7835181143497
# differential_evolution step 362: f(x)= 89.7835181143497
# differential_evolution step 363: f(x)= 89.26827496999127
# differential_evolution step 364: f(x)= 89.26827496999127
# differential_evolution step 365: f(x)= 89.26827496999127
# differential_evolution step 366: f(x)= 89.26827496999127
# differential_evolution step 367: f(x)= 89.26827496999127
# differential_evolution step 368: f(x)= 89.26827496999127
# differential_evolution step 369: f(x)= 89.26827496999127
# differential_evolution step 370: f(x)= 89.26827496999127
# differential_evolution step 371: f(x)= 89.26827496999127
# differential_evolution step 372: f(x)= 89.26827496999127
# differential_evolution step 373: f(x)= 89.26827496999127
# differential_evolution step 374: f(x)= 89.26827496999127
# differential_evolution step 375: f(x)= 88.66996066714906
# differential_evolution step 376: f(x)= 88.66996066714906
# differential_evolution step 377: f(x)= 88.66996066714906
# differential_evolution step 378: f(x)= 88.66996066714906
# differential_evolution step 379: f(x)= 88.66996066714906
# differential_evolution step 380: f(x)= 88.66996066714906
# differential_evolution step 381: f(x)= 88.66996066714906
# differential_evolution step 382: f(x)= 88.66996066714906
# differential_evolution step 383: f(x)= 88.3832487955177
# differential_evolution step 384: f(x)= 87.82999536953726
# differential_evolution step 385: f(x)= 87.82999536953726
# differential_evolution step 386: f(x)= 87.82999536953726
# differential_evolution step 387: f(x)= 87.82999536953726
# differential_evolution step 388: f(x)= 87.82999536953726
# differential_evolution step 389: f(x)= 87.82999536953726
# differential_evolution step 390: f(x)= 87.26526277674935
# differential_evolution step 391: f(x)= 87.26526277674935
# differential_evolution step 392: f(x)= 87.26526277674935
# differential_evolution step 393: f(x)= 87.26526277674935
# differential_evolution step 394: f(x)= 87.26526277674935
# differential_evolution step 395: f(x)= 87.26526277674935
# differential_evolution step 396: f(x)= 87.26526277674935
# differential_evolution step 397: f(x)= 87.26526277674935
# differential_evolution step 398: f(x)= 87.26526277674935
# differential_evolution step 399: f(x)= 87.26526277674935
# differential_evolution step 400: f(x)= 87.26526277674935
# differential_evolution step 401: f(x)= 87.26526277674935
# differential_evolution step 402: f(x)= 87.26526277674935
# differential_evolution step 403: f(x)= 87.26526277674935
# differential_evolution step 404: f(x)= 87.26526277674935
# differential_evolution step 405: f(x)= 87.12858867998418
# differential_evolution step 406: f(x)= 87.12858867998418
# differential_evolution step 407: f(x)= 87.12858867998418
# differential_evolution step 408: f(x)= 86.87785710844405
# differential_evolution step 409: f(x)= 86.87785710844405
# differential_evolution step 410: f(x)= 86.87785710844405
# differential_evolution step 411: f(x)= 86.87785710844405
# differential_evolution step 412: f(x)= 86.87785710844405
# differential_evolution step 413: f(x)= 86.76858224078798
# differential_evolution step 414: f(x)= 86.76858224078798
# differential_evolution step 415: f(x)= 86.76858224078798
# differential_evolution step 416: f(x)= 86.76858224078798
# differential_evolution step 417: f(x)= 86.5445299509327
# differential_evolution step 418: f(x)= 86.5445299509327
# differential_evolution step 419: f(x)= 86.5445299509327
# differential_evolution step 420: f(x)= 86.5445299509327
# differential_evolution step 421: f(x)= 86.5445299509327
# differential_evolution step 422: f(x)= 86.40529076149498
# differential_evolution step 423: f(x)= 86.40529076149498
# differential_evolution step 424: f(x)= 86.40529076149498
# differential_evolution step 425: f(x)= 86.40529076149498
# differential_evolution step 426: f(x)= 86.40529076149498
# differential_evolution step 427: f(x)= 86.40529076149498
# differential_evolution step 428: f(x)= 86.40529076149498
# differential_evolution step 429: f(x)= 86.40529076149498
# differential_evolution step 430: f(x)= 86.40529076149498
# differential_evolution step 431: f(x)= 86.40529076149498
# differential_evolution step 432: f(x)= 86.40529076149498
# differential_evolution step 433: f(x)= 86.40529076149498
# differential_evolution step 434: f(x)= 86.33882985653472
# differential_evolution step 435: f(x)= 86.33882985653472
# differential_evolution step 436: f(x)= 86.32132326752249
# differential_evolution step 437: f(x)= 86.32132326752249
# differential_evolution step 438: f(x)= 86.32132326752249
# differential_evolution step 439: f(x)= 86.32132326752249
# differential_evolution step 440: f(x)= 86.32132326752249
# differential_evolution step 441: f(x)= 86.32132326752249
# differential_evolution step 442: f(x)= 86.32132326752249
# differential_evolution step 443: f(x)= 85.49624407991976
# differential_evolution step 444: f(x)= 85.49624407991976
# differential_evolution step 445: f(x)= 85.49624407991976
# differential_evolution step 446: f(x)= 85.49624407991976
# differential_evolution step 447: f(x)= 85.4596020174686
# differential_evolution step 448: f(x)= 85.4596020174686
# differential_evolution step 449: f(x)= 85.4596020174686
# differential_evolution step 450: f(x)= 85.4596020174686
# differential_evolution step 451: f(x)= 85.3217995872517
# differential_evolution step 452: f(x)= 85.3217995872517
# differential_evolution step 453: f(x)= 85.3217995872517
# differential_evolution step 454: f(x)= 85.3217995872517
# differential_evolution step 455: f(x)= 85.3217995872517
# differential_evolution step 456: f(x)= 85.3217995872517
# differential_evolution step 457: f(x)= 85.3217995872517
# differential_evolution step 458: f(x)= 85.3217995872517
# differential_evolution step 459: f(x)= 85.3217995872517
# differential_evolution step 460: f(x)= 85.3217995872517
# differential_evolution step 461: f(x)= 85.3217995872517
# differential_evolution step 462: f(x)= 85.3217995872517
# differential_evolution step 463: f(x)= 85.3217995872517
# differential_evolution step 464: f(x)= 85.3217995872517
# differential_evolution step 465: f(x)= 85.3217995872517
# differential_evolution step 466: f(x)= 85.3217995872517
# differential_evolution step 467: f(x)= 85.3217995872517
# differential_evolution step 468: f(x)= 85.3217995872517
# differential_evolution step 469: f(x)= 85.3217995872517
# differential_evolution step 470: f(x)= 85.3217995872517
# differential_evolution step 471: f(x)= 85.3217995872517
# differential_evolution step 472: f(x)= 85.3217995872517
# differential_evolution step 473: f(x)= 85.3217995872517
# differential_evolution step 474: f(x)= 85.3217995872517
# differential_evolution step 475: f(x)= 84.96669151337923
# differential_evolution step 476: f(x)= 84.96669151337923
# differential_evolution step 477: f(x)= 84.96669151337923
# differential_evolution step 478: f(x)= 84.96669151337923
# differential_evolution step 479: f(x)= 84.96669151337923
# differential_evolution step 480: f(x)= 84.81982909957235
# differential_evolution step 481: f(x)= 84.78426252987109
# differential_evolution step 482: f(x)= 84.78426252987109
# differential_evolution step 483: f(x)= 84.78426252987109
# differential_evolution step 484: f(x)= 84.78426252987109
# differential_evolution step 485: f(x)= 84.78426252987109
# differential_evolution step 486: f(x)= 84.78426252987109
# differential_evolution step 487: f(x)= 84.78426252987109
# differential_evolution step 488: f(x)= 84.78426252987109
# differential_evolution step 489: f(x)= 84.78426252987109
# differential_evolution step 490: f(x)= 84.78426252987109
# differential_evolution step 491: f(x)= 84.78426252987109
# differential_evolution step 492: f(x)= 84.78426252987109
# differential_evolution step 493: f(x)= 84.78426252987109
# differential_evolution step 494: f(x)= 84.78426252987109
# differential_evolution step 495: f(x)= 84.78426252987109
# differential_evolution step 496: f(x)= 84.78426252987109
# differential_evolution step 497: f(x)= 84.78426252987109
# differential_evolution step 498: f(x)= 84.61694865712428
# differential_evolution step 499: f(x)= 84.61694865712428
# differential_evolution step 500: f(x)= 84.45679085675773
# differential_evolution step 501: f(x)= 84.45679085675773
# differential_evolution step 502: f(x)= 84.45679085675773
# differential_evolution step 503: f(x)= 84.45679085675773
# differential_evolution step 504: f(x)= 84.45679085675773
# differential_evolution step 505: f(x)= 84.45679085675773
# differential_evolution step 506: f(x)= 84.45679085675773
# differential_evolution step 507: f(x)= 84.43206714384856
# differential_evolution step 508: f(x)= 84.43206714384856
# differential_evolution step 509: f(x)= 84.43206714384856
# differential_evolution step 510: f(x)= 84.43206714384856
# differential_evolution step 511: f(x)= 84.43206714384856
# differential_evolution step 512: f(x)= 84.43206714384856
# differential_evolution step 513: f(x)= 84.43206714384856
# differential_evolution step 514: f(x)= 84.43206714384856
# differential_evolution step 515: f(x)= 84.43206714384856
# differential_evolution step 516: f(x)= 84.43206714384856
# differential_evolution step 517: f(x)= 84.43206714384856
# differential_evolution step 518: f(x)= 84.43206714384856
# differential_evolution step 519: f(x)= 84.43206714384856
# differential_evolution step 520: f(x)= 84.28040877568303
# differential_evolution step 521: f(x)= 83.88244937478395
# differential_evolution step 522: f(x)= 83.88244937478395
# differential_evolution step 523: f(x)= 83.88244937478395
# differential_evolution step 524: f(x)= 83.88244937478395
# differential_evolution step 525: f(x)= 83.88244937478395
# differential_evolution step 526: f(x)= 83.88244937478395
# differential_evolution step 527: f(x)= 83.88244937478395
# differential_evolution step 528: f(x)= 83.59314343892021
# differential_evolution step 529: f(x)= 83.59314343892021
# differential_evolution step 530: f(x)= 83.59314343892021
# differential_evolution step 531: f(x)= 83.59314343892021
# differential_evolution step 532: f(x)= 83.59314343892021
# differential_evolution step 533: f(x)= 83.59314343892021
# differential_evolution step 534: f(x)= 83.59314343892021
# differential_evolution step 535: f(x)= 83.59314343892021
# differential_evolution step 536: f(x)= 83.59314343892021
# differential_evolution step 537: f(x)= 83.59314343892021
# differential_evolution step 538: f(x)= 83.59314343892021
# differential_evolution step 539: f(x)= 83.59314343892021
# differential_evolution step 540: f(x)= 83.59314343892021
# differential_evolution step 541: f(x)= 83.59314343892021
# differential_evolution step 542: f(x)= 83.59314343892021
# differential_evolution step 543: f(x)= 83.59314343892021
# differential_evolution step 544: f(x)= 83.59314343892021
# differential_evolution step 545: f(x)= 83.59314343892021
# differential_evolution step 546: f(x)= 83.59314343892021
# differential_evolution step 547: f(x)= 83.59314343892021
# differential_evolution step 548: f(x)= 83.59314343892021
# differential_evolution step 549: f(x)= 83.59314343892021
# differential_evolution step 550: f(x)= 83.0844251908314
# differential_evolution step 551: f(x)= 83.0844251908314
# differential_evolution step 552: f(x)= 83.0844251908314
# differential_evolution step 553: f(x)= 83.0844251908314
# differential_evolution step 554: f(x)= 83.0844251908314
# differential_evolution step 555: f(x)= 82.99878997506042
# differential_evolution step 556: f(x)= 82.99878997506042
# differential_evolution step 557: f(x)= 82.99878997506042
# differential_evolution step 558: f(x)= 82.96326367428796
# differential_evolution step 559: f(x)= 82.96326367428796
# differential_evolution step 560: f(x)= 82.96326367428796
# differential_evolution step 561: f(x)= 82.96326367428796
# differential_evolution step 562: f(x)= 82.96326367428796
# differential_evolution step 563: f(x)= 82.93816481277244
# differential_evolution step 564: f(x)= 82.89384893111178
# differential_evolution step 565: f(x)= 82.89384893111178
# differential_evolution step 566: f(x)= 82.89384893111178
# differential_evolution step 567: f(x)= 82.75614095476901
# differential_evolution step 568: f(x)= 82.75614095476901
# differential_evolution step 569: f(x)= 82.75614095476901
# differential_evolution step 570: f(x)= 82.75614095476901
# differential_evolution step 571: f(x)= 82.75614095476901
# differential_evolution step 572: f(x)= 82.75614095476901
# differential_evolution step 573: f(x)= 82.75614095476901
# differential_evolution step 574: f(x)= 82.75614095476901
# differential_evolution step 575: f(x)= 82.75614095476901
# differential_evolution step 576: f(x)= 82.75614095476901
# differential_evolution step 577: f(x)= 82.75614095476901
# differential_evolution step 578: f(x)= 82.75614095476901
# differential_evolution step 579: f(x)= 82.75614095476901
# differential_evolution step 580: f(x)= 82.60289310996103
# differential_evolution step 581: f(x)= 82.60289310996103
# differential_evolution step 582: f(x)= 82.60289310996103
# differential_evolution step 583: f(x)= 82.60289310996103
# differential_evolution step 584: f(x)= 82.60289310996103
# differential_evolution step 585: f(x)= 82.60289310996103
# differential_evolution step 586: f(x)= 82.60289310996103
# differential_evolution step 587: f(x)= 82.60289310996103
# differential_evolution step 588: f(x)= 82.60289310996103
# differential_evolution step 589: f(x)= 82.60289310996103
# differential_evolution step 590: f(x)= 82.60289310996103
# differential_evolution step 591: f(x)= 82.60289310996103
# differential_evolution step 592: f(x)= 82.47756713895454
# differential_evolution step 593: f(x)= 82.47756713895454
# differential_evolution step 594: f(x)= 82.47756713895454
# differential_evolution step 595: f(x)= 82.47756713895454
# differential_evolution step 596: f(x)= 82.47756713895454
# differential_evolution step 597: f(x)= 82.47756713895454
# differential_evolution step 598: f(x)= 82.47756713895454
# differential_evolution step 599: f(x)= 82.47756713895454
# differential_evolution step 600: f(x)= 82.47756713895454
# differential_evolution step 601: f(x)= 82.47756713895454
# differential_evolution step 602: f(x)= 82.47756713895454
# differential_evolution step 603: f(x)= 82.47756713895454
# differential_evolution step 604: f(x)= 82.47756713895454
# differential_evolution step 605: f(x)= 82.47756713895454
# differential_evolution step 606: f(x)= 82.4333319750836
# differential_evolution step 607: f(x)= 82.4333319750836
# differential_evolution step 608: f(x)= 82.4333319750836
# differential_evolution step 609: f(x)= 82.4333319750836
# differential_evolution step 610: f(x)= 82.4333319750836
# differential_evolution step 611: f(x)= 82.4333319750836
# differential_evolution step 612: f(x)= 82.4333319750836
# differential_evolution step 613: f(x)= 82.4333319750836
# differential_evolution step 614: f(x)= 82.4333319750836
# differential_evolution step 615: f(x)= 82.29102249396965
# differential_evolution step 616: f(x)= 82.29102249396965
# differential_evolution step 617: f(x)= 82.29102249396965
# differential_evolution step 618: f(x)= 82.29102249396965
# differential_evolution step 619: f(x)= 82.29102249396965
# differential_evolution step 620: f(x)= 82.29102249396965
# differential_evolution step 621: f(x)= 82.29102249396965
# differential_evolution step 622: f(x)= 82.29102249396965
# differential_evolution step 623: f(x)= 82.29102249396965
# differential_evolution step 624: f(x)= 82.29102249396965
# differential_evolution step 625: f(x)= 82.29102249396965
# differential_evolution step 626: f(x)= 82.29102249396965
# differential_evolution step 627: f(x)= 82.29102249396965
# differential_evolution step 628: f(x)= 82.29102249396965
# differential_evolution step 629: f(x)= 82.29102249396965
# differential_evolution step 630: f(x)= 82.29102249396965
# differential_evolution step 631: f(x)= 82.29102249396965
# differential_evolution step 632: f(x)= 82.29102249396965
# differential_evolution step 633: f(x)= 82.29102249396965
# differential_evolution step 634: f(x)= 82.29102249396965
# differential_evolution step 635: f(x)= 82.29102249396965
# differential_evolution step 636: f(x)= 82.29102249396965
# differential_evolution step 637: f(x)= 82.29102249396965
# differential_evolution step 638: f(x)= 82.29102249396965
# differential_evolution step 639: f(x)= 82.10388950625445
# differential_evolution step 640: f(x)= 82.10388950625445
# differential_evolution step 641: f(x)= 82.10388950625445
# differential_evolution step 642: f(x)= 82.10388950625445
# differential_evolution step 643: f(x)= 82.10388950625445
# differential_evolution step 644: f(x)= 82.10388950625445
# differential_evolution step 645: f(x)= 82.08043850960374
# differential_evolution step 646: f(x)= 82.08043850960374
# differential_evolution step 647: f(x)= 82.08043850960374
# differential_evolution step 648: f(x)= 82.08043850960374
# differential_evolution step 649: f(x)= 82.08043850960374
# differential_evolution step 650: f(x)= 82.08043850960374
# differential_evolution step 651: f(x)= 82.08043850960374
# differential_evolution step 652: f(x)= 82.08043850960374
# differential_evolution step 653: f(x)= 82.08043850960374
# differential_evolution step 654: f(x)= 82.08043850960374
# differential_evolution step 655: f(x)= 82.08043850960374
# differential_evolution step 656: f(x)= 82.08043850960374
# differential_evolution step 657: f(x)= 82.08043850960374
# differential_evolution step 658: f(x)= 82.08043850960374
# differential_evolution step 659: f(x)= 82.08043850960374
# differential_evolution step 660: f(x)= 82.08043850960374
# differential_evolution step 661: f(x)= 82.08043850960374
# differential_evolution step 662: f(x)= 82.08043850960374
# differential_evolution step 663: f(x)= 82.08043850960374
# differential_evolution step 664: f(x)= 82.08043850960374
# differential_evolution step 665: f(x)= 81.98850212088882
# differential_evolution step 666: f(x)= 81.98850212088882
# differential_evolution step 667: f(x)= 81.98850212088882
# differential_evolution step 668: f(x)= 81.98850212088882
# differential_evolution step 669: f(x)= 81.98850212088882
# differential_evolution step 670: f(x)= 81.98850212088882
# differential_evolution step 671: f(x)= 81.98850212088882
# differential_evolution step 672: f(x)= 81.98850212088882
# differential_evolution step 673: f(x)= 81.98850212088882
# differential_evolution step 674: f(x)= 81.98850212088882
# differential_evolution step 675: f(x)= 81.98850212088882
# differential_evolution step 676: f(x)= 81.98850212088882
# differential_evolution step 677: f(x)= 81.98850212088882
# differential_evolution step 678: f(x)= 81.98850212088882
# differential_evolution step 679: f(x)= 81.98850212088882
# differential_evolution step 680: f(x)= 81.98850212088882
# differential_evolution step 681: f(x)= 81.98850212088882
# differential_evolution step 682: f(x)= 81.98850212088882
# differential_evolution step 683: f(x)= 81.98850212088882
# differential_evolution step 684: f(x)= 81.98850212088882
# differential_evolution step 685: f(x)= 81.98850212088882
# differential_evolution step 686: f(x)= 81.98850212088882
# differential_evolution step 687: f(x)= 81.98850212088882
# differential_evolution step 688: f(x)= 81.98850212088882
# differential_evolution step 689: f(x)= 81.98850212088882
# differential_evolution step 690: f(x)= 81.98850212088882
# differential_evolution step 691: f(x)= 81.9392021117693
# differential_evolution step 692: f(x)= 81.9392021117693
# differential_evolution step 693: f(x)= 81.9392021117693
# differential_evolution step 694: f(x)= 81.9392021117693
# differential_evolution step 695: f(x)= 81.9392021117693
# differential_evolution step 696: f(x)= 81.9392021117693
# differential_evolution step 697: f(x)= 81.9392021117693
# differential_evolution step 698: f(x)= 81.9392021117693
# differential_evolution step 699: f(x)= 81.9392021117693
# differential_evolution step 700: f(x)= 81.9392021117693
# differential_evolution step 701: f(x)= 81.9392021117693
# differential_evolution step 702: f(x)= 81.9392021117693
# differential_evolution step 703: f(x)= 81.9392021117693
# differential_evolution step 704: f(x)= 81.9392021117693
# differential_evolution step 705: f(x)= 81.9392021117693
# differential_evolution step 706: f(x)= 81.9392021117693
# differential_evolution step 707: f(x)= 81.9392021117693
# differential_evolution step 708: f(x)= 81.9392021117693
# differential_evolution step 709: f(x)= 81.9392021117693
# differential_evolution step 710: f(x)= 81.9392021117693
# differential_evolution step 711: f(x)= 81.9392021117693
# differential_evolution step 712: f(x)= 81.9392021117693
# differential_evolution step 713: f(x)= 81.9392021117693
# differential_evolution step 714: f(x)= 81.9392021117693
# differential_evolution step 715: f(x)= 81.88358762144095
# differential_evolution step 716: f(x)= 81.88358762144095
# differential_evolution step 717: f(x)= 81.88358762144095
# differential_evolution step 718: f(x)= 81.88358762144095
# differential_evolution step 719: f(x)= 81.82228407846748
# differential_evolution step 720: f(x)= 81.82228407846748
# differential_evolution step 721: f(x)= 81.82228407846748
# differential_evolution step 722: f(x)= 81.81961536006155
# differential_evolution step 723: f(x)= 81.81961536006155
# differential_evolution step 724: f(x)= 81.81961536006155
# differential_evolution step 725: f(x)= 81.81961536006155
# differential_evolution step 726: f(x)= 81.81961536006155
# differential_evolution step 727: f(x)= 81.81961536006155
# differential_evolution step 728: f(x)= 81.81961536006155
# differential_evolution step 729: f(x)= 81.81961536006155
# differential_evolution step 730: f(x)= 81.81961536006155
# differential_evolution step 731: f(x)= 81.81961536006155
# differential_evolution step 732: f(x)= 81.81961536006155
# differential_evolution step 733: f(x)= 81.81961536006155
# differential_evolution step 734: f(x)= 81.81961536006155
# differential_evolution step 735: f(x)= 81.81961536006155
# differential_evolution step 736: f(x)= 81.81961536006155
# differential_evolution step 737: f(x)= 81.81961536006155
# differential_evolution step 738: f(x)= 81.81961536006155
# differential_evolution step 739: f(x)= 81.81961536006155
# differential_evolution step 740: f(x)= 81.81961536006155
# differential_evolution step 741: f(x)= 81.81961536006155
# differential_evolution step 742: f(x)= 81.81961536006155
# differential_evolution step 743: f(x)= 81.81961536006155
# differential_evolution step 744: f(x)= 81.81961536006155
# differential_evolution step 745: f(x)= 81.7636529469254
# differential_evolution step 746: f(x)= 81.7636529469254
# differential_evolution step 747: f(x)= 81.7636529469254
# differential_evolution step 748: f(x)= 81.7636529469254
# differential_evolution step 749: f(x)= 81.7636529469254
# differential_evolution step 750: f(x)= 81.7636529469254
# differential_evolution step 751: f(x)= 81.7636529469254
# differential_evolution step 752: f(x)= 81.7636529469254
# differential_evolution step 753: f(x)= 81.7636529469254
# differential_evolution step 754: f(x)= 81.7636529469254
# differential_evolution step 755: f(x)= 81.7636529469254
# differential_evolution step 756: f(x)= 81.7636529469254
# differential_evolution step 757: f(x)= 81.7636529469254
# differential_evolution step 758: f(x)= 81.7636529469254
# differential_evolution step 759: f(x)= 81.7636529469254
# differential_evolution step 760: f(x)= 81.7636529469254
# differential_evolution step 761: f(x)= 81.7636529469254
# differential_evolution step 762: f(x)= 81.7636529469254
# differential_evolution step 763: f(x)= 81.7636529469254
# differential_evolution step 764: f(x)= 81.7636529469254
# differential_evolution step 765: f(x)= 81.7636529469254
# differential_evolution step 766: f(x)= 81.7636529469254
# differential_evolution step 767: f(x)= 81.7636529469254
# differential_evolution step 768: f(x)= 81.7636529469254
# differential_evolution step 769: f(x)= 81.7636529469254
# differential_evolution step 770: f(x)= 81.7636529469254
# differential_evolution step 771: f(x)= 81.7636529469254
# differential_evolution step 772: f(x)= 81.7636529469254
# differential_evolution step 773: f(x)= 81.7636529469254
# differential_evolution step 774: f(x)= 81.7636529469254
# differential_evolution step 775: f(x)= 81.7636529469254
# differential_evolution step 776: f(x)= 81.7636529469254
# differential_evolution step 777: f(x)= 81.7636529469254
# differential_evolution step 778: f(x)= 81.7636529469254
# differential_evolution step 779: f(x)= 81.7636529469254
# differential_evolution step 780: f(x)= 81.7636529469254
# differential_evolution step 781: f(x)= 81.7636529469254
# differential_evolution step 782: f(x)= 81.7636529469254
# differential_evolution step 783: f(x)= 81.7636529469254
# differential_evolution step 784: f(x)= 81.7636529469254
# differential_evolution step 785: f(x)= 81.7636529469254
# differential_evolution step 786: f(x)= 81.7636529469254
# differential_evolution step 787: f(x)= 81.7636529469254
# differential_evolution step 788: f(x)= 81.7636529469254
# differential_evolution step 789: f(x)= 81.7636529469254
# differential_evolution step 790: f(x)= 81.7636529469254
# differential_evolution step 791: f(x)= 81.7457745300717
# differential_evolution step 792: f(x)= 81.74299774578168
# differential_evolution step 793: f(x)= 81.74299774578168
# differential_evolution step 794: f(x)= 81.74299774578168
# differential_evolution step 795: f(x)= 81.74299774578168
# differential_evolution step 796: f(x)= 81.74299774578168
# differential_evolution step 797: f(x)= 81.74299774578168
# differential_evolution step 798: f(x)= 81.74299774578168
# differential_evolution step 799: f(x)= 81.69956936237007
# differential_evolution step 800: f(x)= 81.69956936237007
# differential_evolution step 801: f(x)= 81.69956936237007
# differential_evolution step 802: f(x)= 81.69956936237007
# differential_evolution step 803: f(x)= 81.69956936237007
# differential_evolution step 804: f(x)= 81.69956936237007
# differential_evolution step 805: f(x)= 81.69956936237007
# differential_evolution step 806: f(x)= 81.69956936237007
# differential_evolution step 807: f(x)= 81.69956936237007
# differential_evolution step 808: f(x)= 81.69956936237007
# differential_evolution step 809: f(x)= 81.69956936237007
# differential_evolution step 810: f(x)= 81.69956936237007
# differential_evolution step 811: f(x)= 81.69956936237007
# differential_evolution step 812: f(x)= 81.69956936237007
# differential_evolution step 813: f(x)= 81.66808186753224
# differential_evolution step 814: f(x)= 81.66808186753224
# differential_evolution step 815: f(x)= 81.66808186753224
# differential_evolution step 816: f(x)= 81.66808186753224
# differential_evolution step 817: f(x)= 81.66808186753224
# differential_evolution step 818: f(x)= 81.66808186753224
# differential_evolution step 819: f(x)= 81.66808186753224
# differential_evolution step 820: f(x)= 81.62168275759487
# differential_evolution step 821: f(x)= 81.62168275759487
# differential_evolution step 822: f(x)= 81.62168275759487
# differential_evolution step 823: f(x)= 81.62168275759487
# differential_evolution step 824: f(x)= 81.62168275759487
# differential_evolution step 825: f(x)= 81.62168275759487
# differential_evolution step 826: f(x)= 81.62168275759487
# differential_evolution step 827: f(x)= 81.62168275759487
# differential_evolution step 828: f(x)= 81.62168275759487
# differential_evolution step 829: f(x)= 81.62168275759487
# differential_evolution step 830: f(x)= 81.62168275759487
# differential_evolution step 831: f(x)= 81.62168275759487
# differential_evolution step 832: f(x)= 81.62168275759487
# differential_evolution step 833: f(x)= 81.62168275759487
# differential_evolution step 834: f(x)= 81.62168275759487
# differential_evolution step 835: f(x)= 81.62168275759487
# differential_evolution step 836: f(x)= 81.5324006069072
# differential_evolution step 837: f(x)= 81.5324006069072
# differential_evolution step 838: f(x)= 81.5324006069072
# differential_evolution step 839: f(x)= 81.5324006069072
# differential_evolution step 840: f(x)= 81.5324006069072
# differential_evolution step 841: f(x)= 81.5324006069072
# differential_evolution step 842: f(x)= 81.5324006069072
# differential_evolution step 843: f(x)= 81.5324006069072
# differential_evolution step 844: f(x)= 81.5324006069072
# differential_evolution step 845: f(x)= 81.5324006069072
# differential_evolution step 846: f(x)= 81.5324006069072
# differential_evolution step 847: f(x)= 81.5324006069072
# differential_evolution step 848: f(x)= 81.5324006069072
# differential_evolution step 849: f(x)= 81.5324006069072
# differential_evolution step 850: f(x)= 81.5324006069072
# differential_evolution step 851: f(x)= 81.5324006069072
# differential_evolution step 852: f(x)= 81.5324006069072
# differential_evolution step 853: f(x)= 81.5324006069072
# differential_evolution step 854: f(x)= 81.5324006069072
# differential_evolution step 855: f(x)= 81.5324006069072
# differential_evolution step 856: f(x)= 81.5324006069072
# differential_evolution step 857: f(x)= 81.5324006069072
# differential_evolution step 858: f(x)= 81.5324006069072
# differential_evolution step 859: f(x)= 81.5324006069072
# differential_evolution step 860: f(x)= 81.5324006069072
# differential_evolution step 861: f(x)= 81.5324006069072
# differential_evolution step 862: f(x)= 81.5324006069072
# differential_evolution step 863: f(x)= 81.5324006069072
# differential_evolution step 864: f(x)= 81.5324006069072
# differential_evolution step 865: f(x)= 81.5324006069072
# differential_evolution step 866: f(x)= 81.5324006069072
# differential_evolution step 867: f(x)= 81.5324006069072
# differential_evolution step 868: f(x)= 81.5324006069072
# differential_evolution step 869: f(x)= 81.5324006069072
# differential_evolution step 870: f(x)= 81.5324006069072
# differential_evolution step 871: f(x)= 81.5324006069072
# differential_evolution step 872: f(x)= 81.5324006069072
# differential_evolution step 873: f(x)= 81.5324006069072
# differential_evolution step 874: f(x)= 81.5324006069072
# differential_evolution step 875: f(x)= 81.5324006069072
# differential_evolution step 876: f(x)= 81.5324006069072
# differential_evolution step 877: f(x)= 81.5324006069072
# differential_evolution step 878: f(x)= 81.5324006069072
# differential_evolution step 879: f(x)= 81.5324006069072
# differential_evolution step 880: f(x)= 81.5324006069072
# differential_evolution step 881: f(x)= 81.5324006069072
# differential_evolution step 882: f(x)= 81.5324006069072
# differential_evolution step 883: f(x)= 81.5324006069072
# differential_evolution step 884: f(x)= 81.5324006069072
# differential_evolution step 885: f(x)= 81.5324006069072
# differential_evolution step 886: f(x)= 81.5324006069072
# differential_evolution step 887: f(x)= 81.5324006069072
# differential_evolution step 888: f(x)= 81.5324006069072
# differential_evolution step 889: f(x)= 81.5324006069072
# differential_evolution step 890: f(x)= 81.5324006069072
# differential_evolution step 891: f(x)= 81.5324006069072
# differential_evolution step 892: f(x)= 81.5324006069072
# differential_evolution step 893: f(x)= 81.5324006069072
# differential_evolution step 894: f(x)= 81.5324006069072
# differential_evolution step 895: f(x)= 81.5324006069072
# differential_evolution step 896: f(x)= 81.5324006069072
# differential_evolution step 897: f(x)= 81.5324006069072
# differential_evolution step 898: f(x)= 81.5324006069072
# differential_evolution step 899: f(x)= 81.5324006069072
# differential_evolution step 900: f(x)= 81.5324006069072
# differential_evolution step 901: f(x)= 81.5324006069072
# differential_evolution step 902: f(x)= 81.5324006069072
# differential_evolution step 903: f(x)= 81.5324006069072
# differential_evolution step 904: f(x)= 81.5324006069072
# differential_evolution step 905: f(x)= 81.5324006069072
# differential_evolution step 906: f(x)= 81.5324006069072
# differential_evolution step 907: f(x)= 81.5324006069072
# differential_evolution step 908: f(x)= 81.5324006069072
# differential_evolution step 909: f(x)= 81.5324006069072
# differential_evolution step 910: f(x)= 81.5324006069072
# differential_evolution step 911: f(x)= 81.5324006069072
# differential_evolution step 912: f(x)= 81.5324006069072
# differential_evolution step 913: f(x)= 81.5324006069072
# differential_evolution step 914: f(x)= 81.5324006069072
# differential_evolution step 915: f(x)= 81.5324006069072
# differential_evolution step 916: f(x)= 81.5324006069072
# differential_evolution step 917: f(x)= 81.5324006069072
# differential_evolution step 918: f(x)= 81.5324006069072
# differential_evolution step 919: f(x)= 81.5324006069072
# differential_evolution step 920: f(x)= 81.5324006069072
# differential_evolution step 921: f(x)= 81.5324006069072
# differential_evolution step 922: f(x)= 81.5324006069072
# differential_evolution step 923: f(x)= 81.5324006069072
# differential_evolution step 924: f(x)= 81.5324006069072
# differential_evolution step 925: f(x)= 81.5324006069072
# differential_evolution step 926: f(x)= 81.5324006069072
# differential_evolution step 927: f(x)= 81.5324006069072
# differential_evolution step 928: f(x)= 81.5324006069072
# differential_evolution step 929: f(x)= 81.5324006069072
# differential_evolution step 930: f(x)= 81.5324006069072
# differential_evolution step 931: f(x)= 81.5324006069072
# differential_evolution step 932: f(x)= 81.5324006069072
# differential_evolution step 933: f(x)= 81.5324006069072
# differential_evolution step 934: f(x)= 81.5324006069072
# differential_evolution step 935: f(x)= 81.5324006069072
# differential_evolution step 936: f(x)= 81.5324006069072
# differential_evolution step 937: f(x)= 81.5324006069072
# differential_evolution step 938: f(x)= 81.5324006069072
# differential_evolution step 939: f(x)= 81.5324006069072
# differential_evolution step 940: f(x)= 81.5324006069072
# differential_evolution step 941: f(x)= 81.5324006069072
# differential_evolution step 942: f(x)= 81.5324006069072
# differential_evolution step 943: f(x)= 81.5324006069072
# differential_evolution step 944: f(x)= 81.5324006069072
# differential_evolution step 945: f(x)= 81.5324006069072
# differential_evolution step 946: f(x)= 81.5324006069072
# differential_evolution step 947: f(x)= 81.5324006069072
# differential_evolution step 948: f(x)= 81.5324006069072
# differential_evolution step 949: f(x)= 81.5324006069072
# differential_evolution step 950: f(x)= 81.5324006069072
# differential_evolution step 951: f(x)= 81.5324006069072
# differential_evolution step 952: f(x)= 81.5324006069072
# differential_evolution step 953: f(x)= 81.5324006069072
# differential_evolution step 954: f(x)= 81.5324006069072
# differential_evolution step 955: f(x)= 81.5324006069072
# differential_evolution step 956: f(x)= 81.5324006069072
# differential_evolution step 957: f(x)= 81.5324006069072
# differential_evolution step 958: f(x)= 81.5324006069072
# differential_evolution step 959: f(x)= 81.5324006069072
# differential_evolution step 960: f(x)= 81.5324006069072
# differential_evolution step 961: f(x)= 81.5324006069072
# differential_evolution step 962: f(x)= 81.5324006069072
# differential_evolution step 963: f(x)= 81.5324006069072
# differential_evolution step 964: f(x)= 81.5324006069072
# differential_evolution step 965: f(x)= 81.5324006069072
# differential_evolution step 966: f(x)= 81.5324006069072
# differential_evolution step 967: f(x)= 81.5324006069072
# differential_evolution step 968: f(x)= 81.5324006069072
# differential_evolution step 969: f(x)= 81.5324006069072
# differential_evolution step 970: f(x)= 81.5324006069072
# differential_evolution step 971: f(x)= 81.5324006069072
# differential_evolution step 972: f(x)= 81.52726115226976
# differential_evolution step 973: f(x)= 81.52726115226976
# differential_evolution step 974: f(x)= 81.5021431498071
# differential_evolution step 975: f(x)= 81.5021431498071
# differential_evolution step 976: f(x)= 81.5021431498071
# differential_evolution step 977: f(x)= 81.5021431498071
# differential_evolution step 978: f(x)= 81.5021431498071
# differential_evolution step 979: f(x)= 81.5021431498071
# differential_evolution step 980: f(x)= 81.5021431498071
# differential_evolution step 981: f(x)= 81.5021431498071
# differential_evolution step 982: f(x)= 81.5021431498071
# differential_evolution step 983: f(x)= 81.5021431498071
# differential_evolution step 984: f(x)= 81.5021431498071
# differential_evolution step 985: f(x)= 81.5021431498071
# differential_evolution step 986: f(x)= 81.5021431498071
# differential_evolution step 987: f(x)= 81.5021431498071
# differential_evolution step 988: f(x)= 81.5021431498071
# differential_evolution step 989: f(x)= 81.5021431498071
# differential_evolution step 990: f(x)= 81.5021431498071
# differential_evolution step 991: f(x)= 81.5021431498071
# differential_evolution step 992: f(x)= 81.5021431498071
# differential_evolution step 993: f(x)= 81.5021431498071
# differential_evolution step 994: f(x)= 81.5021431498071
# differential_evolution step 995: f(x)= 81.5021431498071
# differential_evolution step 996: f(x)= 81.5021431498071
# differential_evolution step 997: f(x)= 81.5021431498071
# differential_evolution step 998: f(x)= 81.5021431498071
# differential_evolution step 999: f(x)= 81.5021431498071
# differential_evolution step 1000: f(x)= 81.5021431498071
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=2.9078, r_e=0.8423, n=1.9546, x_0=35.5004
# Sérsic 2: I_e=10.0000, r_e=2.7455, n=1.2201, x_0=48.1481
# Sérsic 3: I_e=4.6272, r_e=24.5505, n=1.0117, x_0=50.0007
# Sérsic 4: I_e=2.3000, r_e=1.6568, n=0.1036, x_0=66.4189
# Chi quadro minimo: 81.19153780714781
# False

# %%
save_params_diff(best_params, radial_profile_continuum_2, real_errors_c2, sigmas[-1],
    x_axes, n_component, line_name="Continuum_2", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_2, sigmas[-1], r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_diff')
# Out:
# Sérsic 1: I_e=2.9078, r_e=0.8423, n=1.9546, x_0=35.5004
# Sérsic 2: I_e=10.0000, r_e=2.7455, n=1.2201, x_0=48.1481
# Sérsic 3: I_e=4.6272, r_e=24.5505, n=1.0117, x_0=50.0007
# Sérsic 4: I_e=2.3000, r_e=1.6568, n=0.1036, x_0=66.4189
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_continuum_2, covariance_continuum_2 = curve_fit(lambda x, *params: model_convolved(x, sigmas[-1], *params), x_axes, radial_profile_continuum_2, p0=result.x, 
                                                             sigma = real_errors_c2, bounds = bounds_list, maxfev=15000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_2, dof_continuum_2, chi2_continuum_2 = save_params(params_curve_continuum_2, covariance_continuum_2, radial_profile_continuum_2,
                                                                          real_errors_c2, sigmas[-1], x_axes, n_component, line_name="Continuum_2", output_prefix="fit")
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=9.9998, r_e=0.5711, n=0.6377, x_0=35.4799
# Sérsic 2: I_e=10.0000, r_e=3.9242, n=1.2222, x_0=48.4046
# Sérsic 3: I_e=5.7588, r_e=22.0983, n=0.6295, x_0=50.0000
# Sérsic 4: I_e=2.2688, r_e=1.4013, n=0.1477, x_0=66.2344
# [87.637814    0.86032709  8.8378566   0.21925208  6.49691333  1.99156896
#   0.5232702   0.19921931  0.4849489   0.75898113  0.08844378  0.31166472
#   1.44034405  6.84582033  3.09769607  0.7820291 ]
# 15.290701885179807

# %%
plot_curve(x_axes, params_curve_continuum_2, radial_profile_continuum_2, real_errors_c2, sigmas[-1], r"Radial profile Continuum 2")
plt.savefig('Radial_profile_continuum_2_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ##  Continuum 3

# %%
mask_continuum_3 = (wv > 6400)*(wv < 6700)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))
real_errors_c3 = np.sqrt(radial_profile_error_continuum_3**2+(sky_err[2])**2+(0.04*radial_profile_continuum_3)**2)

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_continuum_3)
plt.plot(x_axes, radial_profile_error_continuum_3)
plt.title(r'Continuum 3')
# Out:
# Text(0.5, 1.0, 'Continuum 3')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Bounds:
bounds = bounds_HA

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_continuum_3, sigmas[0])

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params = result.x

print("Optimize parameters with differential_evolution:")
for i in range(n_component):
    I_e, r_e, n, x_0 = best_params[i*4:(i+1)*4]
    print(f"Sérsic {i+1}: I_e={I_e:.4f}, r_e={r_e:.4f}, n={n:.4f}, x_0={x_0:.4f}")

print("Chi quadro minimo:", result.fun)
print(result.success)
# Out:
# differential_evolution step 1: f(x)= 8473.802938721768
# differential_evolution step 2: f(x)= 4854.564849158121
# differential_evolution step 3: f(x)= 3442.79278941798
# differential_evolution step 4: f(x)= 3442.79278941798
# differential_evolution step 5: f(x)= 3442.79278941798
# differential_evolution step 6: f(x)= 3263.748108512001
# differential_evolution step 7: f(x)= 2323.254184840954
# differential_evolution step 8: f(x)= 1683.5854763982168
# differential_evolution step 9: f(x)= 1683.5854763982168
# differential_evolution step 10: f(x)= 643.1398150715921
# differential_evolution step 11: f(x)= 643.1398150715921
# differential_evolution step 12: f(x)= 603.8470252489155
# differential_evolution step 13: f(x)= 603.8470252489155
# differential_evolution step 14: f(x)= 503.2601775751002
# differential_evolution step 15: f(x)= 503.2601775751002
# differential_evolution step 16: f(x)= 503.2601775751002
# differential_evolution step 17: f(x)= 503.2601775751002
# differential_evolution step 18: f(x)= 503.2601775751002
# differential_evolution step 19: f(x)= 503.2601775751002
# differential_evolution step 20: f(x)= 503.2601775751002
# differential_evolution step 21: f(x)= 503.2601775751002
# differential_evolution step 22: f(x)= 494.2653992390833
# differential_evolution step 23: f(x)= 494.2653992390833
# differential_evolution step 24: f(x)= 286.4888821920297
# differential_evolution step 25: f(x)= 286.4888821920297
# differential_evolution step 26: f(x)= 286.4888821920297
# differential_evolution step 27: f(x)= 286.4888821920297
# differential_evolution step 28: f(x)= 286.4888821920297
# differential_evolution step 29: f(x)= 286.4888821920297
# differential_evolution step 30: f(x)= 286.4888821920297
# differential_evolution step 31: f(x)= 286.4888821920297
# differential_evolution step 32: f(x)= 286.4888821920297
# differential_evolution step 33: f(x)= 254.0332502579945
# differential_evolution step 34: f(x)= 254.0332502579945
# differential_evolution step 35: f(x)= 171.5570306254756
# differential_evolution step 36: f(x)= 171.5570306254756
# differential_evolution step 37: f(x)= 164.24973161530744
# differential_evolution step 38: f(x)= 164.24973161530744
# differential_evolution step 39: f(x)= 164.24973161530744
# differential_evolution step 40: f(x)= 108.88232868716048
# differential_evolution step 41: f(x)= 108.88232868716048
# differential_evolution step 42: f(x)= 108.88232868716048
# differential_evolution step 43: f(x)= 108.88232868716048
# differential_evolution step 44: f(x)= 72.54894277293269
# differential_evolution step 45: f(x)= 72.54894277293269
# differential_evolution step 46: f(x)= 72.54894277293269
# differential_evolution step 47: f(x)= 72.54894277293269
# differential_evolution step 48: f(x)= 72.54894277293269
# differential_evolution step 49: f(x)= 72.54894277293269
# differential_evolution step 50: f(x)= 72.54894277293269
# differential_evolution step 51: f(x)= 72.54894277293269
# differential_evolution step 52: f(x)= 72.54894277293269
# differential_evolution step 53: f(x)= 72.54894277293269
# differential_evolution step 54: f(x)= 72.54894277293269
# differential_evolution step 55: f(x)= 72.54894277293269
# differential_evolution step 56: f(x)= 72.54894277293269
# differential_evolution step 57: f(x)= 72.54894277293269
# differential_evolution step 58: f(x)= 72.54894277293269
# differential_evolution step 59: f(x)= 72.54894277293269
# differential_evolution step 60: f(x)= 72.54894277293269
# differential_evolution step 61: f(x)= 72.54894277293269
# differential_evolution step 62: f(x)= 61.56588863221375
# differential_evolution step 63: f(x)= 61.56588863221375
# differential_evolution step 64: f(x)= 61.56588863221375
# differential_evolution step 65: f(x)= 61.56588863221375
# differential_evolution step 66: f(x)= 61.56588863221375
# differential_evolution step 67: f(x)= 61.56588863221375
# differential_evolution step 68: f(x)= 55.09810053355205
# differential_evolution step 69: f(x)= 42.216558401459025
# differential_evolution step 70: f(x)= 42.216558401459025
# differential_evolution step 71: f(x)= 42.216558401459025
# differential_evolution step 72: f(x)= 42.216558401459025
# differential_evolution step 73: f(x)= 42.216558401459025
# differential_evolution step 74: f(x)= 42.216558401459025
# differential_evolution step 75: f(x)= 42.216558401459025
# differential_evolution step 76: f(x)= 42.216558401459025
# differential_evolution step 77: f(x)= 42.216558401459025
# differential_evolution step 78: f(x)= 42.216558401459025
# differential_evolution step 79: f(x)= 42.216558401459025
# differential_evolution step 80: f(x)= 42.216558401459025
# differential_evolution step 81: f(x)= 42.216558401459025
# differential_evolution step 82: f(x)= 42.216558401459025
# differential_evolution step 83: f(x)= 42.216558401459025
# differential_evolution step 84: f(x)= 41.499624321703784
# differential_evolution step 85: f(x)= 41.499624321703784
# differential_evolution step 86: f(x)= 41.499624321703784
# differential_evolution step 87: f(x)= 41.499624321703784
# differential_evolution step 88: f(x)= 41.499624321703784
# differential_evolution step 89: f(x)= 41.499624321703784
# differential_evolution step 90: f(x)= 41.499624321703784
# differential_evolution step 91: f(x)= 41.499624321703784
# differential_evolution step 92: f(x)= 41.499624321703784
# differential_evolution step 93: f(x)= 40.52955849936204
# differential_evolution step 94: f(x)= 40.52955849936204
# differential_evolution step 95: f(x)= 40.52955849936204
# differential_evolution step 96: f(x)= 35.492541404069854
# differential_evolution step 97: f(x)= 35.492541404069854
# differential_evolution step 98: f(x)= 35.492541404069854
# differential_evolution step 99: f(x)= 35.492541404069854
# differential_evolution step 100: f(x)= 35.492541404069854
# differential_evolution step 101: f(x)= 35.492541404069854
# differential_evolution step 102: f(x)= 35.492541404069854
# differential_evolution step 103: f(x)= 35.492541404069854
# differential_evolution step 104: f(x)= 35.492541404069854
# differential_evolution step 105: f(x)= 35.492541404069854
# differential_evolution step 106: f(x)= 34.713066295994935
# differential_evolution step 107: f(x)= 34.713066295994935
# differential_evolution step 108: f(x)= 34.713066295994935
# differential_evolution step 109: f(x)= 34.713066295994935
# differential_evolution step 110: f(x)= 34.713066295994935
# differential_evolution step 111: f(x)= 34.713066295994935
# differential_evolution step 112: f(x)= 34.713066295994935
# differential_evolution step 113: f(x)= 34.713066295994935
# differential_evolution step 114: f(x)= 34.713066295994935
# differential_evolution step 115: f(x)= 34.713066295994935
# differential_evolution step 116: f(x)= 34.713066295994935
# differential_evolution step 117: f(x)= 34.713066295994935
# differential_evolution step 118: f(x)= 34.713066295994935
# differential_evolution step 119: f(x)= 34.128045652069105
# differential_evolution step 120: f(x)= 31.264819665540173
# differential_evolution step 121: f(x)= 31.264819665540173
# differential_evolution step 122: f(x)= 30.26057686938101
# differential_evolution step 123: f(x)= 29.89830740364206
# differential_evolution step 124: f(x)= 29.89830740364206
# differential_evolution step 125: f(x)= 29.89830740364206
# differential_evolution step 126: f(x)= 29.89830740364206
# differential_evolution step 127: f(x)= 29.89830740364206
# differential_evolution step 128: f(x)= 29.89830740364206
# differential_evolution step 129: f(x)= 29.89830740364206
# differential_evolution step 130: f(x)= 29.89830740364206
# differential_evolution step 131: f(x)= 29.74719402043587
# differential_evolution step 132: f(x)= 29.74719402043587
# differential_evolution step 133: f(x)= 29.74719402043587
# differential_evolution step 134: f(x)= 29.342764611851187
# differential_evolution step 135: f(x)= 29.342764611851187
# differential_evolution step 136: f(x)= 29.342764611851187
# differential_evolution step 137: f(x)= 29.342764611851187
# differential_evolution step 138: f(x)= 27.39701352239816
# differential_evolution step 139: f(x)= 27.39701352239816
# differential_evolution step 140: f(x)= 27.39701352239816
# differential_evolution step 141: f(x)= 27.39701352239816
# differential_evolution step 142: f(x)= 27.39701352239816
# differential_evolution step 143: f(x)= 27.39701352239816
# differential_evolution step 144: f(x)= 27.39701352239816
# differential_evolution step 145: f(x)= 27.39701352239816
# differential_evolution step 146: f(x)= 27.39701352239816
# differential_evolution step 147: f(x)= 27.39701352239816
# differential_evolution step 148: f(x)= 27.39701352239816
# differential_evolution step 149: f(x)= 27.39701352239816
# differential_evolution step 150: f(x)= 27.39701352239816
# differential_evolution step 151: f(x)= 27.39701352239816
# differential_evolution step 152: f(x)= 27.39701352239816
# differential_evolution step 153: f(x)= 27.39701352239816
# differential_evolution step 154: f(x)= 27.39701352239816
# differential_evolution step 155: f(x)= 27.39701352239816
# differential_evolution step 156: f(x)= 27.39701352239816
# differential_evolution step 157: f(x)= 27.39701352239816
# differential_evolution step 158: f(x)= 27.39701352239816
# differential_evolution step 159: f(x)= 27.39701352239816
# differential_evolution step 160: f(x)= 25.67264728542905
# differential_evolution step 161: f(x)= 25.67264728542905
# differential_evolution step 162: f(x)= 25.67264728542905
# differential_evolution step 163: f(x)= 25.67264728542905
# differential_evolution step 164: f(x)= 25.67264728542905
# differential_evolution step 165: f(x)= 25.67264728542905
# differential_evolution step 166: f(x)= 25.67264728542905
# differential_evolution step 167: f(x)= 25.67264728542905
# differential_evolution step 168: f(x)= 25.67264728542905
# differential_evolution step 169: f(x)= 25.67264728542905
# differential_evolution step 170: f(x)= 25.67264728542905
# differential_evolution step 171: f(x)= 25.67264728542905
# differential_evolution step 172: f(x)= 25.67264728542905
# differential_evolution step 173: f(x)= 25.67264728542905
# differential_evolution step 174: f(x)= 25.67264728542905
# differential_evolution step 175: f(x)= 25.368214777636556
# differential_evolution step 176: f(x)= 25.368214777636556
# differential_evolution step 177: f(x)= 25.368214777636556
# differential_evolution step 178: f(x)= 25.368214777636556
# differential_evolution step 179: f(x)= 25.368214777636556
# differential_evolution step 180: f(x)= 23.67549183207559
# differential_evolution step 181: f(x)= 23.67549183207559
# differential_evolution step 182: f(x)= 23.67549183207559
# differential_evolution step 183: f(x)= 23.67549183207559
# differential_evolution step 184: f(x)= 23.67549183207559
# differential_evolution step 185: f(x)= 23.67549183207559
# differential_evolution step 186: f(x)= 23.67549183207559
# differential_evolution step 187: f(x)= 23.67549183207559
# differential_evolution step 188: f(x)= 23.67549183207559
# differential_evolution step 189: f(x)= 23.066110634216788
# differential_evolution step 190: f(x)= 23.066110634216788
# differential_evolution step 191: f(x)= 23.066110634216788
# differential_evolution step 192: f(x)= 23.066110634216788
# differential_evolution step 193: f(x)= 23.066110634216788
# differential_evolution step 194: f(x)= 23.066110634216788
# differential_evolution step 195: f(x)= 23.066110634216788
# differential_evolution step 196: f(x)= 22.99004750533195
# differential_evolution step 197: f(x)= 22.99004750533195
# differential_evolution step 198: f(x)= 22.99004750533195
# differential_evolution step 199: f(x)= 22.148471182716566
# differential_evolution step 200: f(x)= 22.148471182716566
# differential_evolution step 201: f(x)= 22.148471182716566
# differential_evolution step 202: f(x)= 22.148471182716566
# differential_evolution step 203: f(x)= 22.148471182716566
# differential_evolution step 204: f(x)= 22.148471182716566
# differential_evolution step 205: f(x)= 22.148471182716566
# differential_evolution step 206: f(x)= 22.148471182716566
# differential_evolution step 207: f(x)= 22.148471182716566
# differential_evolution step 208: f(x)= 22.148471182716566
# differential_evolution step 209: f(x)= 22.148471182716566
# differential_evolution step 210: f(x)= 22.148471182716566
# differential_evolution step 211: f(x)= 22.10801752917458
# differential_evolution step 212: f(x)= 22.10801752917458
# differential_evolution step 213: f(x)= 22.10801752917458
# differential_evolution step 214: f(x)= 22.10801752917458
# differential_evolution step 215: f(x)= 22.10801752917458
# differential_evolution step 216: f(x)= 22.10801752917458
# differential_evolution step 217: f(x)= 22.10801752917458
# differential_evolution step 218: f(x)= 22.10801752917458
# differential_evolution step 219: f(x)= 22.10801752917458
# differential_evolution step 220: f(x)= 22.10801752917458
# differential_evolution step 221: f(x)= 21.751646970373624
# differential_evolution step 222: f(x)= 21.751646970373624
# differential_evolution step 223: f(x)= 21.751646970373624
# differential_evolution step 224: f(x)= 21.751646970373624
# differential_evolution step 225: f(x)= 21.047206210177187
# differential_evolution step 226: f(x)= 21.047206210177187
# differential_evolution step 227: f(x)= 21.047206210177187
# differential_evolution step 228: f(x)= 21.047206210177187
# differential_evolution step 229: f(x)= 21.047206210177187
# differential_evolution step 230: f(x)= 21.047206210177187
# differential_evolution step 231: f(x)= 21.047206210177187
# differential_evolution step 232: f(x)= 21.047206210177187
# differential_evolution step 233: f(x)= 21.035009097686892
# differential_evolution step 234: f(x)= 21.035009097686892
# differential_evolution step 235: f(x)= 21.035009097686892
# differential_evolution step 236: f(x)= 21.035009097686892
# differential_evolution step 237: f(x)= 21.035009097686892
# differential_evolution step 238: f(x)= 21.035009097686892
# differential_evolution step 239: f(x)= 21.035009097686892
# differential_evolution step 240: f(x)= 21.035009097686892
# differential_evolution step 241: f(x)= 21.035009097686892
# differential_evolution step 242: f(x)= 21.035009097686892
# differential_evolution step 243: f(x)= 21.035009097686892
# differential_evolution step 244: f(x)= 21.035009097686892
# differential_evolution step 245: f(x)= 21.035009097686892
# differential_evolution step 246: f(x)= 21.035009097686892
# differential_evolution step 247: f(x)= 21.035009097686892
# differential_evolution step 248: f(x)= 21.035009097686892
# differential_evolution step 249: f(x)= 21.031516116680006
# differential_evolution step 250: f(x)= 21.031516116680006
# differential_evolution step 251: f(x)= 21.031516116680006
# differential_evolution step 252: f(x)= 21.031516116680006
# differential_evolution step 253: f(x)= 21.031516116680006
# differential_evolution step 254: f(x)= 20.999894687222938
# differential_evolution step 255: f(x)= 20.9146578702515
# differential_evolution step 256: f(x)= 20.9146578702515
# differential_evolution step 257: f(x)= 20.9146578702515
# differential_evolution step 258: f(x)= 20.9146578702515
# differential_evolution step 259: f(x)= 20.83291300532243
# differential_evolution step 260: f(x)= 20.83291300532243
# differential_evolution step 261: f(x)= 20.19352866206141
# differential_evolution step 262: f(x)= 20.19352866206141
# differential_evolution step 263: f(x)= 20.19352866206141
# differential_evolution step 264: f(x)= 20.19352866206141
# differential_evolution step 265: f(x)= 20.19352866206141
# differential_evolution step 266: f(x)= 20.19352866206141
# differential_evolution step 267: f(x)= 20.19352866206141
# differential_evolution step 268: f(x)= 20.19352866206141
# differential_evolution step 269: f(x)= 20.19352866206141
# differential_evolution step 270: f(x)= 20.19352866206141
# differential_evolution step 271: f(x)= 20.19352866206141
# differential_evolution step 272: f(x)= 20.19352866206141
# differential_evolution step 273: f(x)= 20.19352866206141
# differential_evolution step 274: f(x)= 20.19352866206141
# differential_evolution step 275: f(x)= 20.19352866206141
# differential_evolution step 276: f(x)= 20.104476325234724
# differential_evolution step 277: f(x)= 19.824862161441178
# differential_evolution step 278: f(x)= 19.824862161441178
# differential_evolution step 279: f(x)= 19.824862161441178
# differential_evolution step 280: f(x)= 19.824862161441178
# differential_evolution step 281: f(x)= 19.824862161441178
# differential_evolution step 282: f(x)= 19.824862161441178
# differential_evolution step 283: f(x)= 19.824862161441178
# differential_evolution step 284: f(x)= 19.824862161441178
# differential_evolution step 285: f(x)= 19.824862161441178
# differential_evolution step 286: f(x)= 19.824862161441178
# differential_evolution step 287: f(x)= 19.824862161441178
# differential_evolution step 288: f(x)= 19.824862161441178
# differential_evolution step 289: f(x)= 19.824862161441178
# differential_evolution step 290: f(x)= 19.824862161441178
# differential_evolution step 291: f(x)= 19.824862161441178
# differential_evolution step 292: f(x)= 19.824862161441178
# differential_evolution step 293: f(x)= 19.824862161441178
# differential_evolution step 294: f(x)= 19.824862161441178
# differential_evolution step 295: f(x)= 19.824862161441178
# differential_evolution step 296: f(x)= 19.824862161441178
# differential_evolution step 297: f(x)= 19.824862161441178
# differential_evolution step 298: f(x)= 19.824862161441178
# differential_evolution step 299: f(x)= 19.824862161441178
# differential_evolution step 300: f(x)= 19.824862161441178
# differential_evolution step 301: f(x)= 19.824862161441178
# differential_evolution step 302: f(x)= 19.74872491543725
# differential_evolution step 303: f(x)= 19.562987705793265
# differential_evolution step 304: f(x)= 19.562987705793265
# differential_evolution step 305: f(x)= 19.498551356111836
# differential_evolution step 306: f(x)= 19.498551356111836
# differential_evolution step 307: f(x)= 19.498551356111836
# differential_evolution step 308: f(x)= 19.259695340510692
# differential_evolution step 309: f(x)= 19.259695340510692
# differential_evolution step 310: f(x)= 19.10835804892633
# differential_evolution step 311: f(x)= 19.10835804892633
# differential_evolution step 312: f(x)= 19.10835804892633
# differential_evolution step 313: f(x)= 19.10835804892633
# differential_evolution step 314: f(x)= 19.10835804892633
# differential_evolution step 315: f(x)= 19.10835804892633
# differential_evolution step 316: f(x)= 19.10835804892633
# differential_evolution step 317: f(x)= 19.10835804892633
# differential_evolution step 318: f(x)= 19.10835804892633
# differential_evolution step 319: f(x)= 19.10835804892633
# differential_evolution step 320: f(x)= 19.10835804892633
# differential_evolution step 321: f(x)= 19.10835804892633
# differential_evolution step 322: f(x)= 19.10835804892633
# differential_evolution step 323: f(x)= 19.10835804892633
# differential_evolution step 324: f(x)= 19.10835804892633
# differential_evolution step 325: f(x)= 19.05229603391028
# differential_evolution step 326: f(x)= 19.05229603391028
# differential_evolution step 327: f(x)= 19.05229603391028
# differential_evolution step 328: f(x)= 19.05229603391028
# differential_evolution step 329: f(x)= 19.05229603391028
# differential_evolution step 330: f(x)= 19.001610011222063
# differential_evolution step 331: f(x)= 19.001610011222063
# differential_evolution step 332: f(x)= 19.001610011222063
# differential_evolution step 333: f(x)= 19.001610011222063
# differential_evolution step 334: f(x)= 19.001610011222063
# differential_evolution step 335: f(x)= 18.64092480549793
# differential_evolution step 336: f(x)= 18.64092480549793
# differential_evolution step 337: f(x)= 18.64092480549793
# differential_evolution step 338: f(x)= 18.64092480549793
# differential_evolution step 339: f(x)= 18.64092480549793
# differential_evolution step 340: f(x)= 18.64092480549793
# differential_evolution step 341: f(x)= 18.64092480549793
# differential_evolution step 342: f(x)= 18.64092480549793
# differential_evolution step 343: f(x)= 18.64092480549793
# differential_evolution step 344: f(x)= 18.55747049958647
# differential_evolution step 345: f(x)= 18.55747049958647
# differential_evolution step 346: f(x)= 18.55747049958647
# differential_evolution step 347: f(x)= 18.55747049958647
# differential_evolution step 348: f(x)= 18.55747049958647
# differential_evolution step 349: f(x)= 18.55747049958647
# differential_evolution step 350: f(x)= 18.55747049958647
# differential_evolution step 351: f(x)= 18.55747049958647
# differential_evolution step 352: f(x)= 18.55747049958647
# differential_evolution step 353: f(x)= 18.55747049958647
# differential_evolution step 354: f(x)= 18.55747049958647
# differential_evolution step 355: f(x)= 18.55747049958647
# differential_evolution step 356: f(x)= 18.552013552831
# differential_evolution step 357: f(x)= 18.552013552831
# differential_evolution step 358: f(x)= 18.552013552831
# differential_evolution step 359: f(x)= 18.248682715990117
# differential_evolution step 360: f(x)= 18.248682715990117
# differential_evolution step 361: f(x)= 18.248682715990117
# differential_evolution step 362: f(x)= 18.248682715990117
# differential_evolution step 363: f(x)= 18.248682715990117
# differential_evolution step 364: f(x)= 18.248682715990117
# differential_evolution step 365: f(x)= 18.248682715990117
# differential_evolution step 366: f(x)= 18.248682715990117
# differential_evolution step 367: f(x)= 18.248682715990117
# differential_evolution step 368: f(x)= 17.9253498252412
# differential_evolution step 369: f(x)= 17.9253498252412
# differential_evolution step 370: f(x)= 17.9253498252412
# differential_evolution step 371: f(x)= 17.725325119173
# differential_evolution step 372: f(x)= 17.725325119173
# differential_evolution step 373: f(x)= 17.725325119173
# differential_evolution step 374: f(x)= 17.725325119173
# differential_evolution step 375: f(x)= 17.725325119173
# differential_evolution step 376: f(x)= 17.725325119173
# differential_evolution step 377: f(x)= 17.725325119173
# differential_evolution step 378: f(x)= 17.725325119173
# differential_evolution step 379: f(x)= 17.725325119173
# differential_evolution step 380: f(x)= 17.725325119173
# differential_evolution step 381: f(x)= 17.725325119173
# differential_evolution step 382: f(x)= 17.725325119173
# differential_evolution step 383: f(x)= 17.625286157283234
# differential_evolution step 384: f(x)= 17.085502554487686
# differential_evolution step 385: f(x)= 17.085502554487686
# differential_evolution step 386: f(x)= 17.085502554487686
# differential_evolution step 387: f(x)= 17.085502554487686
# differential_evolution step 388: f(x)= 17.085502554487686
# differential_evolution step 389: f(x)= 16.675104040398775
# differential_evolution step 390: f(x)= 16.675104040398775
# differential_evolution step 391: f(x)= 16.675104040398775
# differential_evolution step 392: f(x)= 16.675104040398775
# differential_evolution step 393: f(x)= 16.675104040398775
# differential_evolution step 394: f(x)= 16.675104040398775
# differential_evolution step 395: f(x)= 16.675104040398775
# differential_evolution step 396: f(x)= 16.675104040398775
# differential_evolution step 397: f(x)= 16.675104040398775
# differential_evolution step 398: f(x)= 16.675104040398775
# differential_evolution step 399: f(x)= 16.675104040398775
# differential_evolution step 400: f(x)= 16.675104040398775
# differential_evolution step 401: f(x)= 16.675104040398775
# differential_evolution step 402: f(x)= 16.484800697211547
# differential_evolution step 403: f(x)= 16.484800697211547
# differential_evolution step 404: f(x)= 16.484800697211547
# differential_evolution step 405: f(x)= 16.484800697211547
# differential_evolution step 406: f(x)= 16.484800697211547
# differential_evolution step 407: f(x)= 16.484800697211547
# differential_evolution step 408: f(x)= 16.484800697211547
# differential_evolution step 409: f(x)= 16.484800697211547
# differential_evolution step 410: f(x)= 16.462438081659208
# differential_evolution step 411: f(x)= 16.462438081659208
# differential_evolution step 412: f(x)= 16.462438081659208
# differential_evolution step 413: f(x)= 16.462438081659208
# differential_evolution step 414: f(x)= 16.462438081659208
# differential_evolution step 415: f(x)= 16.462438081659208
# differential_evolution step 416: f(x)= 16.462438081659208
# differential_evolution step 417: f(x)= 16.42240973144226
# differential_evolution step 418: f(x)= 16.42240973144226
# differential_evolution step 419: f(x)= 16.42240973144226
# differential_evolution step 420: f(x)= 16.42240973144226
# differential_evolution step 421: f(x)= 16.42240973144226
# differential_evolution step 422: f(x)= 16.42240973144226
# differential_evolution step 423: f(x)= 16.343743795485757
# differential_evolution step 424: f(x)= 16.343743795485757
# differential_evolution step 425: f(x)= 16.343743795485757
# differential_evolution step 426: f(x)= 16.343743795485757
# differential_evolution step 427: f(x)= 16.343743795485757
# differential_evolution step 428: f(x)= 16.343743795485757
# differential_evolution step 429: f(x)= 16.15185679648269
# differential_evolution step 430: f(x)= 16.15185679648269
# differential_evolution step 431: f(x)= 16.15185679648269
# differential_evolution step 432: f(x)= 16.15185679648269
# differential_evolution step 433: f(x)= 16.15185679648269
# differential_evolution step 434: f(x)= 16.15185679648269
# differential_evolution step 435: f(x)= 16.15185679648269
# differential_evolution step 436: f(x)= 16.15185679648269
# differential_evolution step 437: f(x)= 16.15185679648269
# differential_evolution step 438: f(x)= 16.15185679648269
# differential_evolution step 439: f(x)= 16.15185679648269
# differential_evolution step 440: f(x)= 16.15185679648269
# differential_evolution step 441: f(x)= 16.15185679648269
# differential_evolution step 442: f(x)= 16.15185679648269
# differential_evolution step 443: f(x)= 16.085802282327208
# differential_evolution step 444: f(x)= 16.085802282327208
# differential_evolution step 445: f(x)= 16.085802282327208
# differential_evolution step 446: f(x)= 16.085802282327208
# differential_evolution step 447: f(x)= 16.085802282327208
# differential_evolution step 448: f(x)= 16.085802282327208
# differential_evolution step 449: f(x)= 15.916811755580307
# differential_evolution step 450: f(x)= 15.916811755580307
# differential_evolution step 451: f(x)= 15.916811755580307
# differential_evolution step 452: f(x)= 15.916811755580307
# differential_evolution step 453: f(x)= 15.916811755580307
# differential_evolution step 454: f(x)= 15.78359943894154
# differential_evolution step 455: f(x)= 15.78359943894154
# differential_evolution step 456: f(x)= 15.78359943894154
# differential_evolution step 457: f(x)= 15.78359943894154
# differential_evolution step 458: f(x)= 15.71611353173031
# differential_evolution step 459: f(x)= 15.71611353173031
# differential_evolution step 460: f(x)= 15.71611353173031
# differential_evolution step 461: f(x)= 15.71611353173031
# differential_evolution step 462: f(x)= 15.71611353173031
# differential_evolution step 463: f(x)= 15.71611353173031
# differential_evolution step 464: f(x)= 15.71611353173031
# differential_evolution step 465: f(x)= 15.71611353173031
# differential_evolution step 466: f(x)= 15.71611353173031
# differential_evolution step 467: f(x)= 15.71611353173031
# differential_evolution step 468: f(x)= 15.71611353173031
# differential_evolution step 469: f(x)= 15.71611353173031
# differential_evolution step 470: f(x)= 15.71611353173031
# differential_evolution step 471: f(x)= 15.71611353173031
# differential_evolution step 472: f(x)= 15.71611353173031
# differential_evolution step 473: f(x)= 15.71611353173031
# differential_evolution step 474: f(x)= 15.311606140530866
# differential_evolution step 475: f(x)= 15.311606140530866
# differential_evolution step 476: f(x)= 15.311606140530866
# differential_evolution step 477: f(x)= 15.311606140530866
# differential_evolution step 478: f(x)= 15.3027354584666
# differential_evolution step 479: f(x)= 15.3027354584666
# differential_evolution step 480: f(x)= 15.3027354584666
# differential_evolution step 481: f(x)= 15.3027354584666
# differential_evolution step 482: f(x)= 15.3027354584666
# differential_evolution step 483: f(x)= 15.3027354584666
# differential_evolution step 484: f(x)= 15.3027354584666
# differential_evolution step 485: f(x)= 15.3027354584666
# differential_evolution step 486: f(x)= 15.194251859871017
# differential_evolution step 487: f(x)= 15.194251859871017
# differential_evolution step 488: f(x)= 15.194251859871017
# differential_evolution step 489: f(x)= 15.194251859871017
# differential_evolution step 490: f(x)= 15.194251859871017
# differential_evolution step 491: f(x)= 15.194251859871017
# differential_evolution step 492: f(x)= 15.129554213022782
# differential_evolution step 493: f(x)= 15.129554213022782
# differential_evolution step 494: f(x)= 15.129554213022782
# differential_evolution step 495: f(x)= 15.129554213022782
# differential_evolution step 496: f(x)= 15.129554213022782
# differential_evolution step 497: f(x)= 15.129554213022782
# differential_evolution step 498: f(x)= 14.91505630865995
# differential_evolution step 499: f(x)= 14.91505630865995
# differential_evolution step 500: f(x)= 14.895856348262605
# differential_evolution step 501: f(x)= 14.895856348262605
# differential_evolution step 502: f(x)= 14.895856348262605
# differential_evolution step 503: f(x)= 14.895856348262605
# differential_evolution step 504: f(x)= 14.895856348262605
# differential_evolution step 505: f(x)= 14.895856348262605
# differential_evolution step 506: f(x)= 14.895856348262605
# differential_evolution step 507: f(x)= 14.645422380198434
# differential_evolution step 508: f(x)= 14.645422380198434
# differential_evolution step 509: f(x)= 14.645422380198434
# differential_evolution step 510: f(x)= 14.645422380198434
# differential_evolution step 511: f(x)= 14.645422380198434
# differential_evolution step 512: f(x)= 14.645422380198434
# differential_evolution step 513: f(x)= 14.645422380198434
# differential_evolution step 514: f(x)= 14.645422380198434
# differential_evolution step 515: f(x)= 14.645422380198434
# differential_evolution step 516: f(x)= 14.645422380198434
# differential_evolution step 517: f(x)= 14.645422380198434
# differential_evolution step 518: f(x)= 14.645422380198434
# differential_evolution step 519: f(x)= 14.645422380198434
# differential_evolution step 520: f(x)= 14.645422380198434
# differential_evolution step 521: f(x)= 14.645422380198434
# differential_evolution step 522: f(x)= 14.645422380198434
# differential_evolution step 523: f(x)= 14.645422380198434
# differential_evolution step 524: f(x)= 14.645422380198434
# differential_evolution step 525: f(x)= 14.645422380198434
# differential_evolution step 526: f(x)= 14.645422380198434
# differential_evolution step 527: f(x)= 14.645422380198434
# differential_evolution step 528: f(x)= 14.645422380198434
# differential_evolution step 529: f(x)= 14.645422380198434
# differential_evolution step 530: f(x)= 14.645422380198434
# differential_evolution step 531: f(x)= 14.645422380198434
# differential_evolution step 532: f(x)= 14.645422380198434
# differential_evolution step 533: f(x)= 14.645422380198434
# differential_evolution step 534: f(x)= 14.645422380198434
# differential_evolution step 535: f(x)= 14.645422380198434
# differential_evolution step 536: f(x)= 14.645422380198434
# differential_evolution step 537: f(x)= 14.645422380198434
# differential_evolution step 538: f(x)= 14.645422380198434
# differential_evolution step 539: f(x)= 14.645422380198434
# differential_evolution step 540: f(x)= 14.645422380198434
# differential_evolution step 541: f(x)= 14.645422380198434
# differential_evolution step 542: f(x)= 14.645422380198434
# differential_evolution step 543: f(x)= 14.645422380198434
# differential_evolution step 544: f(x)= 14.645422380198434
# differential_evolution step 545: f(x)= 14.610377816561092
# differential_evolution step 546: f(x)= 14.610377816561092
# differential_evolution step 547: f(x)= 14.610377816561092
# differential_evolution step 548: f(x)= 14.610377816561092
# differential_evolution step 549: f(x)= 14.610377816561092
# differential_evolution step 550: f(x)= 14.610377816561092
# differential_evolution step 551: f(x)= 14.610377816561092
# differential_evolution step 552: f(x)= 14.610377816561092
# differential_evolution step 553: f(x)= 14.610377816561092
# differential_evolution step 554: f(x)= 14.610377816561092
# differential_evolution step 555: f(x)= 14.610377816561092
# differential_evolution step 556: f(x)= 14.610377816561092
# differential_evolution step 557: f(x)= 14.610377816561092
# differential_evolution step 558: f(x)= 14.610377816561092
# differential_evolution step 559: f(x)= 14.610377816561092
# differential_evolution step 560: f(x)= 14.610377816561092
# differential_evolution step 561: f(x)= 14.610377816561092
# differential_evolution step 562: f(x)= 14.610377816561092
# differential_evolution step 563: f(x)= 14.610377816561092
# differential_evolution step 564: f(x)= 14.610377816561092
# differential_evolution step 565: f(x)= 14.610377816561092
# differential_evolution step 566: f(x)= 14.610377816561092
# differential_evolution step 567: f(x)= 14.610377816561092
# differential_evolution step 568: f(x)= 14.610377816561092
# differential_evolution step 569: f(x)= 14.575288114243582
# differential_evolution step 570: f(x)= 14.547336439951271
# differential_evolution step 571: f(x)= 14.547336439951271
# differential_evolution step 572: f(x)= 14.547336439951271
# differential_evolution step 573: f(x)= 14.547336439951271
# differential_evolution step 574: f(x)= 14.547336439951271
# differential_evolution step 575: f(x)= 14.547336439951271
# differential_evolution step 576: f(x)= 14.547336439951271
# differential_evolution step 577: f(x)= 14.547336439951271
# differential_evolution step 578: f(x)= 14.547336439951271
# differential_evolution step 579: f(x)= 14.547336439951271
# differential_evolution step 580: f(x)= 14.547336439951271
# differential_evolution step 581: f(x)= 14.547336439951271
# differential_evolution step 582: f(x)= 14.547336439951271
# differential_evolution step 583: f(x)= 14.415299313172353
# differential_evolution step 584: f(x)= 14.415299313172353
# differential_evolution step 585: f(x)= 14.415299313172353
# differential_evolution step 586: f(x)= 14.415299313172353
# differential_evolution step 587: f(x)= 14.415299313172353
# differential_evolution step 588: f(x)= 14.413495498629796
# differential_evolution step 589: f(x)= 14.413495498629796
# differential_evolution step 590: f(x)= 14.398440976668459
# differential_evolution step 591: f(x)= 14.398440976668459
# differential_evolution step 592: f(x)= 14.398440976668459
# differential_evolution step 593: f(x)= 14.398440976668459
# differential_evolution step 594: f(x)= 14.398440976668459
# differential_evolution step 595: f(x)= 14.398440976668459
# differential_evolution step 596: f(x)= 14.398440976668459
# differential_evolution step 597: f(x)= 14.398440976668459
# differential_evolution step 598: f(x)= 14.398440976668459
# differential_evolution step 599: f(x)= 14.398440976668459
# differential_evolution step 600: f(x)= 14.398440976668459
# differential_evolution step 601: f(x)= 14.398440976668459
# differential_evolution step 602: f(x)= 14.398440976668459
# differential_evolution step 603: f(x)= 14.398440976668459
# differential_evolution step 604: f(x)= 14.386418011404126
# differential_evolution step 605: f(x)= 14.386418011404126
# differential_evolution step 606: f(x)= 14.386418011404126
# differential_evolution step 607: f(x)= 14.386418011404126
# differential_evolution step 608: f(x)= 14.386418011404126
# differential_evolution step 609: f(x)= 14.386418011404126
# differential_evolution step 610: f(x)= 14.386418011404126
# differential_evolution step 611: f(x)= 14.386418011404126
# differential_evolution step 612: f(x)= 14.386418011404126
# differential_evolution step 613: f(x)= 14.386418011404126
# differential_evolution step 614: f(x)= 14.386418011404126
# differential_evolution step 615: f(x)= 14.386418011404126
# differential_evolution step 616: f(x)= 14.386418011404126
# differential_evolution step 617: f(x)= 14.334322231738494
# differential_evolution step 618: f(x)= 14.334322231738494
# differential_evolution step 619: f(x)= 14.334322231738494
# differential_evolution step 620: f(x)= 14.334322231738494
# differential_evolution step 621: f(x)= 14.334322231738494
# differential_evolution step 622: f(x)= 14.334322231738494
# differential_evolution step 623: f(x)= 14.319764174301826
# differential_evolution step 624: f(x)= 14.319764174301826
# differential_evolution step 625: f(x)= 14.319764174301826
# differential_evolution step 626: f(x)= 14.319764174301826
# differential_evolution step 627: f(x)= 14.300381662088926
# differential_evolution step 628: f(x)= 14.300381662088926
# differential_evolution step 629: f(x)= 14.300381662088926
# differential_evolution step 630: f(x)= 14.300381662088926
# differential_evolution step 631: f(x)= 14.300381662088926
# differential_evolution step 632: f(x)= 14.300381662088926
# differential_evolution step 633: f(x)= 14.168666498350408
# differential_evolution step 634: f(x)= 14.168666498350408
# differential_evolution step 635: f(x)= 14.168666498350408
# differential_evolution step 636: f(x)= 14.168666498350408
# differential_evolution step 637: f(x)= 14.168666498350408
# differential_evolution step 638: f(x)= 14.168666498350408
# differential_evolution step 639: f(x)= 14.168666498350408
# differential_evolution step 640: f(x)= 14.168666498350408
# differential_evolution step 641: f(x)= 14.168666498350408
# differential_evolution step 642: f(x)= 14.168666498350408
# differential_evolution step 643: f(x)= 14.153425782420593
# differential_evolution step 644: f(x)= 14.153425782420593
# differential_evolution step 645: f(x)= 14.153425782420593
# differential_evolution step 646: f(x)= 14.153425782420593
# differential_evolution step 647: f(x)= 14.140758777385209
# differential_evolution step 648: f(x)= 14.140758777385209
# differential_evolution step 649: f(x)= 14.140758777385209
# differential_evolution step 650: f(x)= 14.140758777385209
# differential_evolution step 651: f(x)= 14.140758777385209
# differential_evolution step 652: f(x)= 14.114686190567035
# differential_evolution step 653: f(x)= 14.114686190567035
# differential_evolution step 654: f(x)= 14.114686190567035
# differential_evolution step 655: f(x)= 14.114686190567035
# differential_evolution step 656: f(x)= 14.114686190567035
# differential_evolution step 657: f(x)= 14.114686190567035
# differential_evolution step 658: f(x)= 14.114686190567035
# differential_evolution step 659: f(x)= 14.095257646380361
# differential_evolution step 660: f(x)= 14.095257646380361
# differential_evolution step 661: f(x)= 14.095257646380361
# differential_evolution step 662: f(x)= 14.095257646380361
# differential_evolution step 663: f(x)= 14.032513975834764
# differential_evolution step 664: f(x)= 14.032513975834764
# differential_evolution step 665: f(x)= 14.032513975834764
# differential_evolution step 666: f(x)= 14.032513975834764
# differential_evolution step 667: f(x)= 14.032513975834764
# differential_evolution step 668: f(x)= 14.032513975834764
# differential_evolution step 669: f(x)= 14.032513975834764
# differential_evolution step 670: f(x)= 14.032513975834764
# differential_evolution step 671: f(x)= 14.032513975834764
# differential_evolution step 672: f(x)= 14.032513975834764
# differential_evolution step 673: f(x)= 14.032513975834764
# differential_evolution step 674: f(x)= 14.032513975834764
# differential_evolution step 675: f(x)= 14.032513975834764
# differential_evolution step 676: f(x)= 14.032513975834764
# differential_evolution step 677: f(x)= 14.032513975834764
# differential_evolution step 678: f(x)= 14.032513975834764
# differential_evolution step 679: f(x)= 14.032513975834764
# differential_evolution step 680: f(x)= 14.032513975834764
# differential_evolution step 681: f(x)= 14.032513975834764
# differential_evolution step 682: f(x)= 14.032513975834764
# differential_evolution step 683: f(x)= 14.032513975834764
# differential_evolution step 684: f(x)= 14.032513975834764
# differential_evolution step 685: f(x)= 14.032513975834764
# differential_evolution step 686: f(x)= 14.032513975834764
# differential_evolution step 687: f(x)= 14.032513975834764
# differential_evolution step 688: f(x)= 14.032513975834764
# differential_evolution step 689: f(x)= 14.030766308570508
# differential_evolution step 690: f(x)= 14.030766308570508
# differential_evolution step 691: f(x)= 14.027331909218095
# differential_evolution step 692: f(x)= 14.027331909218095
# differential_evolution step 693: f(x)= 14.027331909218095
# differential_evolution step 694: f(x)= 14.027331909218095
# differential_evolution step 695: f(x)= 14.027331909218095
# differential_evolution step 696: f(x)= 14.027331909218095
# differential_evolution step 697: f(x)= 13.948911114212953
# differential_evolution step 698: f(x)= 13.948911114212953
# differential_evolution step 699: f(x)= 13.948911114212953
# differential_evolution step 700: f(x)= 13.948911114212953
# differential_evolution step 701: f(x)= 13.948911114212953
# differential_evolution step 702: f(x)= 13.948911114212953
# differential_evolution step 703: f(x)= 13.948911114212953
# differential_evolution step 704: f(x)= 13.948911114212953
# differential_evolution step 705: f(x)= 13.948911114212953
# differential_evolution step 706: f(x)= 13.948911114212953
# differential_evolution step 707: f(x)= 13.948911114212953
# differential_evolution step 708: f(x)= 13.948911114212953
# differential_evolution step 709: f(x)= 13.948911114212953
# differential_evolution step 710: f(x)= 13.948911114212953
# differential_evolution step 711: f(x)= 13.948911114212953
# differential_evolution step 712: f(x)= 13.948911114212953
# differential_evolution step 713: f(x)= 13.948911114212953
# differential_evolution step 714: f(x)= 13.948911114212953
# differential_evolution step 715: f(x)= 13.948911114212953
# differential_evolution step 716: f(x)= 13.948911114212953
# differential_evolution step 717: f(x)= 13.948911114212953
# differential_evolution step 718: f(x)= 13.948911114212953
# differential_evolution step 719: f(x)= 13.948911114212953
# differential_evolution step 720: f(x)= 13.948911114212953
# differential_evolution step 721: f(x)= 13.948911114212953
# differential_evolution step 722: f(x)= 13.948911114212953
# differential_evolution step 723: f(x)= 13.948911114212953
# differential_evolution step 724: f(x)= 13.948911114212953
# differential_evolution step 725: f(x)= 13.948911114212953
# differential_evolution step 726: f(x)= 13.948911114212953
# differential_evolution step 727: f(x)= 13.94775846382443
# differential_evolution step 728: f(x)= 13.94775846382443
# differential_evolution step 729: f(x)= 13.94775846382443
# differential_evolution step 730: f(x)= 13.94775846382443
# differential_evolution step 731: f(x)= 13.94775846382443
# differential_evolution step 732: f(x)= 13.94775846382443
# differential_evolution step 733: f(x)= 13.94775846382443
# differential_evolution step 734: f(x)= 13.94775846382443
# differential_evolution step 735: f(x)= 13.94775846382443
# differential_evolution step 736: f(x)= 13.94775846382443
# differential_evolution step 737: f(x)= 13.938713660830299
# differential_evolution step 738: f(x)= 13.938713660830299
# differential_evolution step 739: f(x)= 13.938713660830299
# differential_evolution step 740: f(x)= 13.923826651650016
# differential_evolution step 741: f(x)= 13.923826651650016
# differential_evolution step 742: f(x)= 13.923826651650016
# differential_evolution step 743: f(x)= 13.923826651650016
# differential_evolution step 744: f(x)= 13.923826651650016
# differential_evolution step 745: f(x)= 13.923826651650016
# differential_evolution step 746: f(x)= 13.906584431597375
# differential_evolution step 747: f(x)= 13.906584431597375
# differential_evolution step 748: f(x)= 13.906584431597375
# differential_evolution step 749: f(x)= 13.906584431597375
# differential_evolution step 750: f(x)= 13.906584431597375
# differential_evolution step 751: f(x)= 13.906584431597375
# differential_evolution step 752: f(x)= 13.906584431597375
# differential_evolution step 753: f(x)= 13.906584431597375
# differential_evolution step 754: f(x)= 13.906584431597375
# differential_evolution step 755: f(x)= 13.906584431597375
# differential_evolution step 756: f(x)= 13.906584431597375
# differential_evolution step 757: f(x)= 13.906584431597375
# differential_evolution step 758: f(x)= 13.906584431597375
# differential_evolution step 759: f(x)= 13.906584431597375
# differential_evolution step 760: f(x)= 13.906584431597375
# differential_evolution step 761: f(x)= 13.906584431597375
# differential_evolution step 762: f(x)= 13.902470942444404
# differential_evolution step 763: f(x)= 13.902470942444404
# differential_evolution step 764: f(x)= 13.902470942444404
# differential_evolution step 765: f(x)= 13.902470942444404
# differential_evolution step 766: f(x)= 13.902470942444404
# differential_evolution step 767: f(x)= 13.902470942444404
# differential_evolution step 768: f(x)= 13.902470942444404
# differential_evolution step 769: f(x)= 13.902470942444404
# differential_evolution step 770: f(x)= 13.902470942444404
# differential_evolution step 771: f(x)= 13.902470942444404
# differential_evolution step 772: f(x)= 13.900708031046953
# differential_evolution step 773: f(x)= 13.900708031046953
# differential_evolution step 774: f(x)= 13.900708031046953
# differential_evolution step 775: f(x)= 13.900708031046953
# differential_evolution step 776: f(x)= 13.900708031046953
# differential_evolution step 777: f(x)= 13.900708031046953
# differential_evolution step 778: f(x)= 13.900708031046953
# differential_evolution step 779: f(x)= 13.895460611485824
# differential_evolution step 780: f(x)= 13.895460611485824
# differential_evolution step 781: f(x)= 13.895460611485824
# differential_evolution step 782: f(x)= 13.894123132801042
# differential_evolution step 783: f(x)= 13.894123132801042
# differential_evolution step 784: f(x)= 13.894123132801042
# differential_evolution step 785: f(x)= 13.894123132801042
# differential_evolution step 786: f(x)= 13.894123132801042
# differential_evolution step 787: f(x)= 13.894123132801042
# differential_evolution step 788: f(x)= 13.894123132801042
# differential_evolution step 789: f(x)= 13.894123132801042
# differential_evolution step 790: f(x)= 13.894123132801042
# differential_evolution step 791: f(x)= 13.894123132801042
# differential_evolution step 792: f(x)= 13.894123132801042
# differential_evolution step 793: f(x)= 13.894123132801042
# differential_evolution step 794: f(x)= 13.894123132801042
# differential_evolution step 795: f(x)= 13.894123132801042
# differential_evolution step 796: f(x)= 13.894123132801042
# differential_evolution step 797: f(x)= 13.894123132801042
# differential_evolution step 798: f(x)= 13.894123132801042
# differential_evolution step 799: f(x)= 13.894123132801042
# differential_evolution step 800: f(x)= 13.894123132801042
# differential_evolution step 801: f(x)= 13.894123132801042
# differential_evolution step 802: f(x)= 13.894123132801042
# differential_evolution step 803: f(x)= 13.894123132801042
# differential_evolution step 804: f(x)= 13.894123132801042
# differential_evolution step 805: f(x)= 13.894123132801042
# differential_evolution step 806: f(x)= 13.894123132801042
# differential_evolution step 807: f(x)= 13.894123132801042
# differential_evolution step 808: f(x)= 13.894123132801042
# differential_evolution step 809: f(x)= 13.894123132801042
# differential_evolution step 810: f(x)= 13.891003455923704
# differential_evolution step 811: f(x)= 13.891003455923704
# differential_evolution step 812: f(x)= 13.891003455923704
# differential_evolution step 813: f(x)= 13.891003455923704
# differential_evolution step 814: f(x)= 13.891003455923704
# differential_evolution step 815: f(x)= 13.891003455923704
# differential_evolution step 816: f(x)= 13.891003455923704
# differential_evolution step 817: f(x)= 13.891003455923704
# differential_evolution step 818: f(x)= 13.891003455923704
# differential_evolution step 819: f(x)= 13.891003455923704
# differential_evolution step 820: f(x)= 13.891003455923704
# differential_evolution step 821: f(x)= 13.891003455923704
# differential_evolution step 822: f(x)= 13.891003455923704
# differential_evolution step 823: f(x)= 13.891003455923704
# differential_evolution step 824: f(x)= 13.891003455923704
# differential_evolution step 825: f(x)= 13.891003455923704
# differential_evolution step 826: f(x)= 13.891003455923704
# differential_evolution step 827: f(x)= 13.891003455923704
# differential_evolution step 828: f(x)= 13.891003455923704
# differential_evolution step 829: f(x)= 13.891003455923704
# differential_evolution step 830: f(x)= 13.891003455923704
# differential_evolution step 831: f(x)= 13.890859751521587
# differential_evolution step 832: f(x)= 13.890859751521587
# differential_evolution step 833: f(x)= 13.890859751521587
# differential_evolution step 834: f(x)= 13.890859751521587
# differential_evolution step 835: f(x)= 13.890859751521587
# differential_evolution step 836: f(x)= 13.889622092603169
# differential_evolution step 837: f(x)= 13.889622092603169
# differential_evolution step 838: f(x)= 13.889622092603169
# differential_evolution step 839: f(x)= 13.887845337663745
# differential_evolution step 840: f(x)= 13.887845337663745
# differential_evolution step 841: f(x)= 13.887845337663745
# differential_evolution step 842: f(x)= 13.887845337663745
# differential_evolution step 843: f(x)= 13.887845337663745
# differential_evolution step 844: f(x)= 13.887845337663745
# differential_evolution step 845: f(x)= 13.887845337663745
# differential_evolution step 846: f(x)= 13.887845337663745
# differential_evolution step 847: f(x)= 13.887845337663745
# differential_evolution step 848: f(x)= 13.887845337663745
# differential_evolution step 849: f(x)= 13.887845337663745
# differential_evolution step 850: f(x)= 13.887845337663745
# differential_evolution step 851: f(x)= 13.887845337663745
# differential_evolution step 852: f(x)= 13.887845337663745
# differential_evolution step 853: f(x)= 13.887845337663745
# differential_evolution step 854: f(x)= 13.887845337663745
# differential_evolution step 855: f(x)= 13.887845337663745
# differential_evolution step 856: f(x)= 13.887845337663745
# differential_evolution step 857: f(x)= 13.887321032298031
# differential_evolution step 858: f(x)= 13.887321032298031
# differential_evolution step 859: f(x)= 13.887321032298031
# differential_evolution step 860: f(x)= 13.887321032298031
# differential_evolution step 861: f(x)= 13.887321032298031
# differential_evolution step 862: f(x)= 13.887321032298031
# differential_evolution step 863: f(x)= 13.887321032298031
# differential_evolution step 864: f(x)= 13.887321032298031
# differential_evolution step 865: f(x)= 13.887321032298031
# differential_evolution step 866: f(x)= 13.887321032298031
# differential_evolution step 867: f(x)= 13.887321032298031
# differential_evolution step 868: f(x)= 13.887321032298031
# differential_evolution step 869: f(x)= 13.887321032298031
# differential_evolution step 870: f(x)= 13.887321032298031
# differential_evolution step 871: f(x)= 13.887321032298031
# differential_evolution step 872: f(x)= 13.884423104645903
# differential_evolution step 873: f(x)= 13.884423104645903
# differential_evolution step 874: f(x)= 13.884423104645903
# differential_evolution step 875: f(x)= 13.884423104645903
# differential_evolution step 876: f(x)= 13.884423104645903
# differential_evolution step 877: f(x)= 13.884423104645903
# differential_evolution step 878: f(x)= 13.884423104645903
# differential_evolution step 879: f(x)= 13.884423104645903
# differential_evolution step 880: f(x)= 13.884423104645903
# differential_evolution step 881: f(x)= 13.884423104645903
# differential_evolution step 882: f(x)= 13.884423104645903
# differential_evolution step 883: f(x)= 13.884423104645903
# differential_evolution step 884: f(x)= 13.884423104645903
# differential_evolution step 885: f(x)= 13.884423104645903
# differential_evolution step 886: f(x)= 13.884423104645903
# differential_evolution step 887: f(x)= 13.884423104645903
# differential_evolution step 888: f(x)= 13.884423104645903
# differential_evolution step 889: f(x)= 13.884423104645903
# differential_evolution step 890: f(x)= 13.879662683476793
# differential_evolution step 891: f(x)= 13.879662683476793
# differential_evolution step 892: f(x)= 13.879662683476793
# differential_evolution step 893: f(x)= 13.879662683476793
# differential_evolution step 894: f(x)= 13.879662683476793
# differential_evolution step 895: f(x)= 13.879662683476793
# differential_evolution step 896: f(x)= 13.879662683476793
# differential_evolution step 897: f(x)= 13.879662683476793
# differential_evolution step 898: f(x)= 13.879662683476793
# differential_evolution step 899: f(x)= 13.879662683476793
# differential_evolution step 900: f(x)= 13.879662683476793
# differential_evolution step 901: f(x)= 13.879662683476793
# differential_evolution step 902: f(x)= 13.879662683476793
# differential_evolution step 903: f(x)= 13.879662683476793
# differential_evolution step 904: f(x)= 13.879662683476793
# differential_evolution step 905: f(x)= 13.875180183925139
# differential_evolution step 906: f(x)= 13.875180183925139
# differential_evolution step 907: f(x)= 13.875180183925139
# differential_evolution step 908: f(x)= 13.872230043594362
# differential_evolution step 909: f(x)= 13.872230043594362
# differential_evolution step 910: f(x)= 13.872230043594362
# differential_evolution step 911: f(x)= 13.872230043594362
# differential_evolution step 912: f(x)= 13.870973362649849
# differential_evolution step 913: f(x)= 13.870973362649849
# differential_evolution step 914: f(x)= 13.870973362649849
# differential_evolution step 915: f(x)= 13.870973362649849
# differential_evolution step 916: f(x)= 13.870973362649849
# differential_evolution step 917: f(x)= 13.870973362649849
# differential_evolution step 918: f(x)= 13.870973362649849
# differential_evolution step 919: f(x)= 13.870973362649849
# differential_evolution step 920: f(x)= 13.870973362649849
# differential_evolution step 921: f(x)= 13.870973362649849
# differential_evolution step 922: f(x)= 13.870973362649849
# differential_evolution step 923: f(x)= 13.870973362649849
# differential_evolution step 924: f(x)= 13.870973362649849
# differential_evolution step 925: f(x)= 13.870973362649849
# differential_evolution step 926: f(x)= 13.870973362649849
# differential_evolution step 927: f(x)= 13.864057767635943
# differential_evolution step 928: f(x)= 13.864057767635943
# differential_evolution step 929: f(x)= 13.864057767635943
# differential_evolution step 930: f(x)= 13.864057767635943
# differential_evolution step 931: f(x)= 13.864057767635943
# differential_evolution step 932: f(x)= 13.864057767635943
# differential_evolution step 933: f(x)= 13.864057767635943
# differential_evolution step 934: f(x)= 13.864057767635943
# differential_evolution step 935: f(x)= 13.864057767635943
# differential_evolution step 936: f(x)= 13.864057767635943
# differential_evolution step 937: f(x)= 13.864057767635943
# differential_evolution step 938: f(x)= 13.864057767635943
# differential_evolution step 939: f(x)= 13.864057767635943
# differential_evolution step 940: f(x)= 13.864057767635943
# differential_evolution step 941: f(x)= 13.864057767635943
# differential_evolution step 942: f(x)= 13.864057767635943
# differential_evolution step 943: f(x)= 13.864057767635943
# differential_evolution step 944: f(x)= 13.864057767635943
# differential_evolution step 945: f(x)= 13.864057767635943
# differential_evolution step 946: f(x)= 13.864057767635943
# differential_evolution step 947: f(x)= 13.864057767635943
# differential_evolution step 948: f(x)= 13.864057767635943
# differential_evolution step 949: f(x)= 13.864057767635943
# differential_evolution step 950: f(x)= 13.864057767635943
# differential_evolution step 951: f(x)= 13.864057767635943
# differential_evolution step 952: f(x)= 13.864057767635943
# differential_evolution step 953: f(x)= 13.864057767635943
# differential_evolution step 954: f(x)= 13.864057767635943
# differential_evolution step 955: f(x)= 13.864057767635943
# differential_evolution step 956: f(x)= 13.864057767635943
# differential_evolution step 957: f(x)= 13.864057767635943
# differential_evolution step 958: f(x)= 13.864057767635943
# differential_evolution step 959: f(x)= 13.864057767635943
# differential_evolution step 960: f(x)= 13.864057767635943
# differential_evolution step 961: f(x)= 13.864057767635943
# differential_evolution step 962: f(x)= 13.864057767635943
# differential_evolution step 963: f(x)= 13.864057767635943
# differential_evolution step 964: f(x)= 13.864057767635943
# differential_evolution step 965: f(x)= 13.864057767635943
# differential_evolution step 966: f(x)= 13.864057767635943
# differential_evolution step 967: f(x)= 13.864057767635943
# differential_evolution step 968: f(x)= 13.864057767635943
# differential_evolution step 969: f(x)= 13.864057767635943
# differential_evolution step 970: f(x)= 13.864057767635943
# differential_evolution step 971: f(x)= 13.864057767635943
# differential_evolution step 972: f(x)= 13.863044100956381
# differential_evolution step 973: f(x)= 13.863044100956381
# differential_evolution step 974: f(x)= 13.863044100956381
# differential_evolution step 975: f(x)= 13.863044100956381
# differential_evolution step 976: f(x)= 13.863044100956381
# differential_evolution step 977: f(x)= 13.863044100956381
# differential_evolution step 978: f(x)= 13.863044100956381
# differential_evolution step 979: f(x)= 13.863044100956381
# differential_evolution step 980: f(x)= 13.863044100956381
# differential_evolution step 981: f(x)= 13.863044100956381
# differential_evolution step 982: f(x)= 13.863044100956381
# differential_evolution step 983: f(x)= 13.863044100956381
# differential_evolution step 984: f(x)= 13.862276672753454
# differential_evolution step 985: f(x)= 13.859351976003733
# differential_evolution step 986: f(x)= 13.85631617918648
# differential_evolution step 987: f(x)= 13.85631617918648
# differential_evolution step 988: f(x)= 13.85631617918648
# differential_evolution step 989: f(x)= 13.85631617918648
# differential_evolution step 990: f(x)= 13.85631617918648
# differential_evolution step 991: f(x)= 13.85631617918648
# differential_evolution step 992: f(x)= 13.854201657048712
# differential_evolution step 993: f(x)= 13.854201657048712
# differential_evolution step 994: f(x)= 13.854201657048712
# differential_evolution step 995: f(x)= 13.854201657048712
# differential_evolution step 996: f(x)= 13.854201657048712
# differential_evolution step 997: f(x)= 13.854201657048712
# differential_evolution step 998: f(x)= 13.854201657048712
# differential_evolution step 999: f(x)= 13.854201657048712
# differential_evolution step 1000: f(x)= 13.854201657048712
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution:
# Sérsic 1: I_e=1.6005, r_e=1.3202, n=2.0111, x_0=35.1785
# Sérsic 2: I_e=0.6270, r_e=49.8673, n=2.6273, x_0=47.9133
# Sérsic 3: I_e=0.1820, r_e=4.6937, n=2.4968, x_0=54.7519
# Sérsic 4: I_e=0.3425, r_e=8.7683, n=1.3769, x_0=65.7153
# Chi quadro minimo: 13.788073331647606
# False

# %%
save_params_diff(best_params, radial_profile_continuum_3, real_errors_c3, sigmas[0],
    x_axes, n_component, line_name="Continuum_3", output_prefix="fit")
plot_diff(x_axes, best_params, radial_profile_continuum_3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_diff')
# Out:
# Sérsic 1: I_e=1.6005, r_e=1.3202, n=2.0111, x_0=35.1785
# Sérsic 2: I_e=0.6270, r_e=49.8673, n=2.6273, x_0=47.9133
# Sérsic 3: I_e=0.1820, r_e=4.6937, n=2.4968, x_0=54.7519
# Sérsic 4: I_e=0.3425, r_e=8.7683, n=1.3769, x_0=65.7153
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#lower_bounds, upper_bounds = zip(*bounds)
#bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_continuum_3, covariance_continuum_3 = curve_fit(lambda x, *params: model_convolved(x, sigmas[0], *params), x_axes,
                                                             radial_profile_continuum_3, p0=result.x, sigma = real_errors_c3) #, bounds = bounds_list, maxfev = 10000)
print("Optimize parameters with curve fit:")
chi2_reduced_continuum_3, dof_continuum_3, chi2_continuum_3 = save_params(params_curve_continuum_3, covariance_continuum_3, radial_profile_continuum_3,
                                                                          real_errors_c3, sigmas[0], x_axes, n_component, line_name="Continuum_3", output_prefix="fit")
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_4612\568277273.py:11: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_4612\568277273.py:24: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.1560, r_e=8.9419, n=3.3877, x_0=35.1785
# Sérsic 2: I_e=1.0638, r_e=33.4320, n=2.1918, x_0=47.8549
# Sérsic 3: I_e=0.6179, r_e=1.7694, n=1.5656, x_0=54.7370
# Sérsic 4: I_e=0.5895, r_e=9.1528, n=0.8896, x_0=65.9159
# [1.40010788e+00 5.11420437e+01 1.21281593e+01 9.83641962e-04
#  3.31821034e-01 5.48496128e+00 2.73797593e-01 2.33867657e-01
#  6.19584877e+00 1.04291781e+01 8.71726243e+00 6.61127162e-01
#  3.09157303e-01 3.71673801e+00 3.88373746e-01 1.11832482e+00]
# 14.099916890215184

# %%
plot_curve(x_axes, params_curve_continuum_3, radial_profile_continuum_3, real_errors_c3, sigmas[0], r"Radial profile Continuum 3")
plt.savefig('Radial_profile_continuum_3_curve')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Chi squared save

# %%
chi_red = [chi2_reduced_continuum_1, chi2_reduced_continuum_2, chi2_reduced_continuum_3]
dof = [dof_continuum_1, dof_continuum_2, dof_continuum_3]
chi = [chi2_continuum_1, chi2_continuum_2, chi2_continuum_3]

d1 = {'Name': ['Continuum 1', 'Continuum 2', 'Continuum 3'], 'Chi squared': chi,
      'Dof': dof, 'Chi reduced': chi_red}
df1 = pd.DataFrame(data=d1)
df1.to_csv("Chi_squared_curve_fit_continuum.csv", index= False)

# %% [markdown]
# ## Halpha and continuum

# %%
mask_continuum_3 = (wv > 6550)*(wv < 6600)
image_continuum_3 = image_cut[:, mask_continuum_3]
image_error_continuum_3 = image_error_cut[:, mask_continuum_3]
radial_profile_continuum_3 = np.sum(image_continuum_3, axis = 1)
radial_profile_error_continuum_3 = np.sqrt(np.sum(image_error_continuum_3**2, axis = 1))
real_errors_c3 = np.sqrt(radial_profile_error_continuum_3**2+(sky_err[2])**2+(0.04*radial_profile_continuum_3)**2)
plt.figure(figsize=(8,6))
plt.plot(x_axes, radial_profile_HA, label = 'Halpha') 
plt.plot(x_axes, radial_profile_continuum_3, label = 'Continuum')
plt.title(r'Halpha and Continuum NGC3217_2')
plt.legend()
plt.xlabel('Pixel')
plt.ylabel(r'Flux [$10^{-16}$ erg/(cm$^2$ s Å)]')
plt.grid(alpha = 0.3)
plt.savefig('Halpha_continuum_NGC3217_2')
