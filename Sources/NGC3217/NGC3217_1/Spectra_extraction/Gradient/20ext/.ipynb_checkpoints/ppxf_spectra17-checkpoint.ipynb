# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_17.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_17']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4314.03901503 4315.47324864 4316.90748224 ... 6874.1460011  6875.58023471
#  6877.01446832] [0.06431502 0.04534898 0.05325389 ... 0.03064079 0.03209579 0.02806928] [0.00619146 0.00619146 0.00619146 ... 0.00619146 0.00619146 0.00619146]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -193       183
# chi2/DOF: 0.02686; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/150
#  Best Fit:       Vel     sigma
#  comp.  0:      -168       180
# chi2/DOF: 0.01793; DOF: 1890; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-167.81687099,  179.88770003])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -107       192
#  comp.  1:       -39        43
#  comp.  2:       -20        72
# chi2/DOF: 0.9049; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.35     -39    43
# Comp:  1                 Hbeta      1.061      0.35     -39    43
# Comp:  1                Halpha      4.376      0.35     -39    43
# Comp:  2             [SII]6716      1.527      0.39     -20    72
# Comp:  2             [SII]6731      1.489      0.39     -20    72
# Comp:  2              HeII4687      0.000      0.39     -20    72
# Comp:  2               HeI5876      0.000      0.39     -20    72
# Comp:  2          [OIII]5007_d      1.860      0.50     -20    72
# Comp:  2            [OI]6300_d     0.1783      0.50     -20    72
# Comp:  2           [NII]6583_d      2.627      0.50     -20    72
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  2.415; gas flux:      1 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  10.19; gas flux:      6 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  2.803; gas flux:      2 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  2.739; gas flux:      2 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  2.644; gas flux:      2 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise: 0.2496; gas flux:      0 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  3.552; gas flux:      4 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -90       146
#  comp.  1:       -42        25
#  comp.  2:       -34        68
# chi2/DOF: 0.8993; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3242      0.34     -42    25
# Comp:  1                 Hbeta      1.210      0.34     -42    25
# Comp:  1                Halpha      3.965      0.34     -42    25
# Comp:  2             [SII]6716      1.620      0.39     -34    68
# Comp:  2             [SII]6731      1.609      0.39     -34    68
# Comp:  2              HeII4687      0.000      0.39     -34    68
# Comp:  2               HeI5876      0.000      0.39     -34    68
# Comp:  2          [OIII]5007_d      1.868      0.49     -34    68
# Comp:  2            [OI]6300_d     0.2306      0.49     -34    68
# Comp:  2           [NII]6583_d      2.657      0.49     -34    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -128       317
#  comp.  1:       -37        28
#  comp.  2:       -23        60
# chi2/DOF: 0.8956; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma   0.005179      0.34     -37    28
# Comp:  1                 Hbeta     0.9177      0.34     -37    28
# Comp:  1                Halpha      4.197      0.34     -37    28
# Comp:  2             [SII]6716      1.015      0.38     -23    60
# Comp:  2             [SII]6731      1.356      0.38     -23    60
# Comp:  2              HeII4687      0.000      0.38     -23    60
# Comp:  2               HeI5876     0.1876      0.38     -23    60
# Comp:  2          [OIII]5007_d      2.087      0.48     -23    60
# Comp:  2            [OI]6300_d     0.4373      0.48     -23    60
# Comp:  2           [NII]6583_d      2.668      0.48     -23    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -45       188
#  comp.  1:       -39        36
#  comp.  2:       -23        74
# chi2/DOF: 0.8956; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1957      0.35     -39    36
# Comp:  1                 Hbeta      1.265      0.35     -39    36
# Comp:  1                Halpha      4.110      0.35     -39    36
# Comp:  2             [SII]6716      1.361      0.40     -23    74
# Comp:  2             [SII]6731     0.9278      0.40     -23    74
# Comp:  2              HeII4687      0.000      0.40     -23    74
# Comp:  2               HeI5876      0.000      0.40     -23    74
# Comp:  2          [OIII]5007_d      1.843      0.50     -23    74
# Comp:  2            [OI]6300_d    0.04070      0.50     -23    74
# Comp:  2           [NII]6583_d      2.705      0.50     -23    74
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -115       278
#  comp.  1:       -41        37
#  comp.  2:       -41        40
# chi2/DOF: 0.8943; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma    0.04972      0.35     -41    37
# Comp:  1                 Hbeta      1.217      0.35     -41    37
# Comp:  1                Halpha      4.481      0.35     -41    37
# Comp:  2             [SII]6716     0.8486      0.35     -41    40
# Comp:  2             [SII]6731      1.319      0.35     -41    40
# Comp:  2              HeII4687      0.000      0.35     -41    40
# Comp:  2               HeI5876      0.000      0.35     -41    40
# Comp:  2          [OIII]5007_d      1.861      0.44     -41    40
# Comp:  2            [OI]6300_d     0.1738      0.44     -41    40
# Comp:  2           [NII]6583_d      2.445      0.44     -41    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -135       249
#  comp.  1:       -37        36
#  comp.  2:       -36        48
# chi2/DOF: 0.8975; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.35     -37    36
# Comp:  1                 Hbeta     0.9377      0.35     -37    36
# Comp:  1                Halpha      4.431      0.35     -37    36
# Comp:  2             [SII]6716      1.317      0.36     -36    48
# Comp:  2             [SII]6731      1.345      0.36     -36    48
# Comp:  2              HeII4687     0.1923      0.36     -36    48
# Comp:  2               HeI5876     0.1965      0.36     -36    48
# Comp:  2          [OIII]5007_d      2.371      0.46     -36    48
# Comp:  2            [OI]6300_d     0.4340      0.46     -36    48
# Comp:  2           [NII]6583_d      2.016      0.46     -36    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -102       263
#  comp.  1:       -36        43
#  comp.  2:        -9        97
# chi2/DOF: 0.8944; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1327      0.35     -36    43
# Comp:  1                 Hbeta      1.246      0.35     -36    43
# Comp:  1                Halpha      4.592      0.35     -36    43
# Comp:  2             [SII]6716      1.153      0.43      -9    97
# Comp:  2             [SII]6731      2.196      0.43      -9    97
# Comp:  2              HeII4687     0.3289      0.43      -9    97
# Comp:  2               HeI5876    0.03652      0.43      -9    97
# Comp:  2          [OIII]5007_d      2.023      0.55      -9    97
# Comp:  2            [OI]6300_d     0.5616      0.55      -9    97
# Comp:  2           [NII]6583_d      3.248      0.55      -9    97
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100       257
#  comp.  1:       -35        48
#  comp.  2:        12        89
# chi2/DOF: 0.8931; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1360      0.36     -35    48
# Comp:  1                 Hbeta      1.336      0.36     -35    48
# Comp:  1                Halpha      4.760      0.36     -35    48
# Comp:  2             [SII]6716      1.575      0.42      12    89
# Comp:  2             [SII]6731      2.055      0.42      12    89
# Comp:  2              HeII4687     0.9497      0.42      12    89
# Comp:  2               HeI5876      0.000      0.42      12    89
# Comp:  2          [OIII]5007_d      1.451      0.53      12    89
# Comp:  2            [OI]6300_d      0.000      0.53      12    89
# Comp:  2           [NII]6583_d      3.085      0.53      12    89
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -209       150
#  comp.  1:       -41        37
#  comp.  2:         6       125
# chi2/DOF: 0.8907; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.35     -41    37
# Comp:  1                 Hbeta      1.210      0.35     -41    37
# Comp:  1                Halpha      4.266      0.35     -41    37
# Comp:  2             [SII]6716      1.022      0.48       6   125
# Comp:  2             [SII]6731      2.888      0.48       6   125
# Comp:  2              HeII4687      0.000      0.48       6   125
# Comp:  2               HeI5876     0.7604      0.48       6   125
# Comp:  2          [OIII]5007_d      2.596      0.60       6   125
# Comp:  2            [OI]6300_d     0.4719      0.60       6   125
# Comp:  2           [NII]6583_d      2.760      0.60       6   125
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -157       154
#  comp.  1:       -48        40
#  comp.  2:       -12        66
# chi2/DOF: 0.8960; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.35     -48    40
# Comp:  1                 Hbeta     0.8682      0.35     -48    40
# Comp:  1                Halpha      4.166      0.35     -48    40
# Comp:  2             [SII]6716      1.859      0.39     -12    66
# Comp:  2             [SII]6731      1.862      0.39     -12    66
# Comp:  2              HeII4687     0.4614      0.39     -12    66
# Comp:  2               HeI5876     0.1854      0.39     -12    66
# Comp:  2          [OIII]5007_d      1.413      0.49     -12    66
# Comp:  2            [OI]6300_d     0.1763      0.49     -12    66
# Comp:  2           [NII]6583_d      2.781      0.49     -12    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -114       129
#  comp.  1:       -39        63
#  comp.  2:        -0        76
# chi2/DOF: 0.8895; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma    0.06968      0.38     -39    63
# Comp:  1                 Hbeta      1.515      0.38     -39    63
# Comp:  1                Halpha      5.045      0.38     -39    63
# Comp:  2             [SII]6716      1.470      0.40      -0    76
# Comp:  2             [SII]6731     0.5980      0.40      -0    76
# Comp:  2              HeII4687      1.150      0.40      -0    76
# Comp:  2               HeI5876      0.000      0.40      -0    76
# Comp:  2          [OIII]5007_d      1.973      0.51      -0    76
# Comp:  2            [OI]6300_d     0.6869      0.51      -0    76
# Comp:  2           [NII]6583_d      2.762      0.51      -0    76
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98       201
#  comp.  1:       -42        41
#  comp.  2:         2        63
# chi2/DOF: 0.8932; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 17/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1944      0.35     -42    41
# Comp:  1                 Hbeta      1.184      0.35     -42    41
# Comp:  1                Halpha      4.723      0.35     -42    41
# Comp:  2             [SII]6716      1.751      0.38       2    63
# Comp:  2             [SII]6731      1.536      0.38       2    63
# Comp:  2              HeII4687     0.7052      0.38       2    63
# Comp:  2               HeI5876     0.3027      0.38       2    63
# Comp:  2          [OIII]5007_d      1.774      0.48       2    63
# Comp:  2            [OI]6300_d     0.1444      0.48       2    63
# Comp:  2           [NII]6583_d      2.446      0.48       2    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -131        70
#  comp.  1:       -38        50
#  comp.  2:        -2       127
# chi2/DOF: 0.8931; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1961      0.36     -38    50
# Comp:  1                 Hbeta      1.249      0.36     -38    50
# Comp:  1                Halpha      4.721      0.36     -38    50
# Comp:  2             [SII]6716      2.050      0.48      -2   127
# Comp:  2             [SII]6731      1.629      0.48      -2   127
# Comp:  2              HeII4687     0.9804      0.48      -2   127
# Comp:  2               HeI5876     0.1157      0.48      -2   127
# Comp:  2          [OIII]5007_d      2.327      0.60      -2   127
# Comp:  2            [OI]6300_d      0.000      0.60      -2   127
# Comp:  2           [NII]6583_d      3.081      0.60      -2   127
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -157       205
#  comp.  1:       -35        57
#  comp.  2:        -2        92
# chi2/DOF: 0.8957; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.2027      0.37     -35    57
# Comp:  1                 Hbeta      1.234      0.37     -35    57
# Comp:  1                Halpha      4.866      0.37     -35    57
# Comp:  2             [SII]6716      1.179      0.42      -2    92
# Comp:  2             [SII]6731      2.271      0.42      -2    92
# Comp:  2              HeII4687    0.03288      0.42      -2    92
# Comp:  2               HeI5876     0.2806      0.42      -2    92
# Comp:  2          [OIII]5007_d      1.580      0.54      -2    92
# Comp:  2            [OI]6300_d     0.7445      0.54      -2    92
# Comp:  2           [NII]6583_d      3.577      0.54      -2    92
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100       182
#  comp.  1:       -36        53
#  comp.  2:       -13        69
# chi2/DOF: 0.8932; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.37     -36    53
# Comp:  1                 Hbeta      1.407      0.37     -36    53
# Comp:  1                Halpha      5.006      0.37     -36    53
# Comp:  2             [SII]6716      1.997      0.39     -13    69
# Comp:  2             [SII]6731      1.028      0.39     -13    69
# Comp:  2              HeII4687      0.000      0.39     -13    69
# Comp:  2               HeI5876     0.2158      0.39     -13    69
# Comp:  2          [OIII]5007_d      1.581      0.49     -13    69
# Comp:  2            [OI]6300_d      0.000      0.49     -13    69
# Comp:  2           [NII]6583_d      2.208      0.49     -13    69
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -93       174
#  comp.  1:       -42        48
#  comp.  2:        -3        81
# chi2/DOF: 0.8936; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.5318      0.36     -42    48
# Comp:  1                 Hbeta      1.208      0.36     -42    48
# Comp:  1                Halpha      4.708      0.36     -42    48
# Comp:  2             [SII]6716      1.658      0.41      -3    81
# Comp:  2             [SII]6731      2.059      0.41      -3    81
# Comp:  2              HeII4687      1.123      0.41      -3    81
# Comp:  2               HeI5876      0.000      0.41      -3    81
# Comp:  2          [OIII]5007_d      2.321      0.51      -3    81
# Comp:  2            [OI]6300_d     0.2448      0.51      -3    81
# Comp:  2           [NII]6583_d      2.059      0.51      -3    81
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -120       158
#  comp.  1:       -42        55
#  comp.  2:        11       105
# chi2/DOF: 0.8946; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.37     -42    55
# Comp:  1                 Hbeta      1.343      0.37     -42    55
# Comp:  1                Halpha      4.929      0.37     -42    55
# Comp:  2             [SII]6716      1.868      0.45      11   105
# Comp:  2             [SII]6731      2.822      0.45      11   105
# Comp:  2              HeII4687      0.000      0.45      11   105
# Comp:  2               HeI5876      0.000      0.45      11   105
# Comp:  2          [OIII]5007_d      1.593      0.56      11   105
# Comp:  2            [OI]6300_d     0.1126      0.56      11   105
# Comp:  2           [NII]6583_d      3.474      0.56      11   105
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -107       202
#  comp.  1:       -41        26
#  comp.  2:       -13        82
# chi2/DOF: 0.8987; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.4388      0.34     -41    26
# Comp:  1                 Hbeta      1.195      0.34     -41    26
# Comp:  1                Halpha      4.236      0.34     -41    26
# Comp:  2             [SII]6716      1.965      0.41     -13    82
# Comp:  2             [SII]6731      1.673      0.41     -13    82
# Comp:  2              HeII4687      0.000      0.41     -13    82
# Comp:  2               HeI5876      0.000      0.41     -13    82
# Comp:  2          [OIII]5007_d      1.530      0.52     -13    82
# Comp:  2            [OI]6300_d      0.000      0.52     -13    82
# Comp:  2           [NII]6583_d      2.674      0.52     -13    82
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96       195
#  comp.  1:       -41        54
#  comp.  2:        10        86
# chi2/DOF: 0.8975; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.2619      0.37     -41    54
# Comp:  1                 Hbeta      1.258      0.37     -41    54
# Comp:  1                Halpha      4.746      0.37     -41    54
# Comp:  2             [SII]6716      1.972      0.42      10    86
# Comp:  2             [SII]6731      1.561      0.42      10    86
# Comp:  2              HeII4687      0.000      0.42      10    86
# Comp:  2               HeI5876      0.000      0.42      10    86
# Comp:  2          [OIII]5007_d      1.806      0.52      10    86
# Comp:  2            [OI]6300_d      0.000      0.52      10    86
# Comp:  2           [NII]6583_d      3.213      0.52      10    86
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63       210
#  comp.  1:       -35        53
#  comp.  2:        -8        67
# chi2/DOF: 0.8971; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1304      0.37     -35    53
# Comp:  1                 Hbeta      1.533      0.37     -35    53
# Comp:  1                Halpha      4.638      0.37     -35    53
# Comp:  2             [SII]6716      1.867      0.39      -8    67
# Comp:  2             [SII]6731      2.022      0.39      -8    67
# Comp:  2              HeII4687      0.000      0.39      -8    67
# Comp:  2               HeI5876      0.000      0.39      -8    67
# Comp:  2          [OIII]5007_d      1.363      0.49      -8    67
# Comp:  2            [OI]6300_d     0.1233      0.49      -8    67
# Comp:  2           [NII]6583_d      2.871      0.49      -8    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -74       236
#  comp.  1:       -36        44
#  comp.  2:       -24       129
# chi2/DOF: 0.8953; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.36     -36    44
# Comp:  1                 Hbeta      1.123      0.36     -36    44
# Comp:  1                Halpha      4.491      0.36     -36    44
# Comp:  2             [SII]6716      1.910      0.48     -24   129
# Comp:  2             [SII]6731      2.648      0.48     -24   129
# Comp:  2              HeII4687     0.9790      0.48     -24   129
# Comp:  2               HeI5876     0.7297      0.48     -24   129
# Comp:  2          [OIII]5007_d      2.318      0.61     -24   129
# Comp:  2            [OI]6300_d     0.2188      0.61     -24   129
# Comp:  2           [NII]6583_d      2.653      0.61     -24   129
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -167       210
#  comp.  1:       -43        41
#  comp.  2:       -35        24
# chi2/DOF: 0.8923; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.35     -43    41
# Comp:  1                 Hbeta     0.8890      0.35     -43    41
# Comp:  1                Halpha      4.575      0.35     -43    41
# Comp:  2             [SII]6716      1.269      0.34     -35    24
# Comp:  2             [SII]6731      1.291      0.34     -35    24
# Comp:  2              HeII4687     0.2056      0.34     -35    24
# Comp:  2               HeI5876      0.000      0.34     -35    24
# Comp:  2          [OIII]5007_d      1.757      0.42     -35    24
# Comp:  2            [OI]6300_d     0.1006      0.42     -35    24
# Comp:  2           [NII]6583_d      2.186      0.42     -35    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57       186
#  comp.  1:       -44        37
#  comp.  2:        -3        64
# chi2/DOF: 0.8971; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1213      0.35     -44    37
# Comp:  1                 Hbeta      1.180      0.35     -44    37
# Comp:  1                Halpha      4.487      0.35     -44    37
# Comp:  2             [SII]6716      1.765      0.38      -3    64
# Comp:  2             [SII]6731      1.236      0.38      -3    64
# Comp:  2              HeII4687     0.4213      0.38      -3    64
# Comp:  2               HeI5876     0.3255      0.38      -3    64
# Comp:  2          [OIII]5007_d      1.654      0.48      -3    64
# Comp:  2            [OI]6300_d      0.000      0.48      -3    64
# Comp:  2           [NII]6583_d      2.820      0.48      -3    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80       200
#  comp.  1:       -34        50
#  comp.  2:       -35        71
# chi2/DOF: 0.8959; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.36     -34    50
# Comp:  1                 Hbeta      1.364      0.36     -34    50
# Comp:  1                Halpha      4.946      0.36     -34    50
# Comp:  2             [SII]6716      1.522      0.39     -35    71
# Comp:  2             [SII]6731      1.114      0.39     -35    71
# Comp:  2              HeII4687      0.000      0.39     -35    71
# Comp:  2               HeI5876      0.000      0.39     -35    71
# Comp:  2          [OIII]5007_d      1.700      0.50     -35    71
# Comp:  2            [OI]6300_d      0.000      0.50     -35    71
# Comp:  2           [NII]6583_d      2.784      0.50     -35    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -152       186
#  comp.  1:       -38        28
#  comp.  2:       -26        67
# chi2/DOF: 0.8960; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma    0.02024      0.34     -38    28
# Comp:  1                 Hbeta     0.9514      0.34     -38    28
# Comp:  1                Halpha      4.168      0.34     -38    28
# Comp:  2             [SII]6716      1.729      0.39     -26    67
# Comp:  2             [SII]6731      2.005      0.39     -26    67
# Comp:  2              HeII4687      0.000      0.39     -26    67
# Comp:  2               HeI5876    0.06369      0.39     -26    67
# Comp:  2          [OIII]5007_d      2.143      0.49     -26    67
# Comp:  2            [OI]6300_d      0.000      0.49     -26    67
# Comp:  2           [NII]6583_d      2.892      0.49     -26    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100       149
#  comp.  1:       -41        51
#  comp.  2:       -25        56
# chi2/DOF: 0.8913; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3236      0.37     -41    51
# Comp:  1                 Hbeta      1.427      0.37     -41    51
# Comp:  1                Halpha      4.884      0.37     -41    51
# Comp:  2             [SII]6716     0.9808      0.37     -25    56
# Comp:  2             [SII]6731      1.749      0.37     -25    56
# Comp:  2              HeII4687     0.2958      0.37     -25    56
# Comp:  2               HeI5876     0.2905      0.37     -25    56
# Comp:  2          [OIII]5007_d      1.800      0.47     -25    56
# Comp:  2            [OI]6300_d     0.5844      0.47     -25    56
# Comp:  2           [NII]6583_d      2.388      0.47     -25    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -155        68
#  comp.  1:       -44        34
#  comp.  2:       -48        67
# chi2/DOF: 0.8939; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma    0.07848      0.34     -44    34
# Comp:  1                 Hbeta     0.9018      0.34     -44    34
# Comp:  1                Halpha      4.266      0.34     -44    34
# Comp:  2             [SII]6716      1.821      0.39     -48    67
# Comp:  2             [SII]6731      1.043      0.39     -48    67
# Comp:  2              HeII4687     0.2623      0.39     -48    67
# Comp:  2               HeI5876     0.1366      0.39     -48    67
# Comp:  2          [OIII]5007_d      1.579      0.49     -48    67
# Comp:  2            [OI]6300_d     0.2264      0.49     -48    67
# Comp:  2           [NII]6583_d      2.571      0.49     -48    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59       212
#  comp.  1:       -36        70
#  comp.  2:       -17        98
# chi2/DOF: 0.8958; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.7900      0.39     -36    70
# Comp:  1                 Hbeta      1.876      0.39     -36    70
# Comp:  1                Halpha      5.349      0.39     -36    70
# Comp:  2             [SII]6716      1.029      0.43     -17    98
# Comp:  2             [SII]6731      1.208      0.43     -17    98
# Comp:  2              HeII4687      0.000      0.43     -17    98
# Comp:  2               HeI5876     0.1690      0.43     -17    98
# Comp:  2          [OIII]5007_d      1.711      0.55     -17    98
# Comp:  2            [OI]6300_d     0.4566      0.55     -17    98
# Comp:  2           [NII]6583_d      3.223      0.55     -17    98
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        96
#  comp.  1:       -35        56
#  comp.  2:         1        70
# chi2/DOF: 0.8926; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      1.434      0.37     -35    56
# Comp:  1                 Hbeta      1.814      0.37     -35    56
# Comp:  1                Halpha      4.927      0.37     -35    56
# Comp:  2             [SII]6716      1.512      0.39       1    70
# Comp:  2             [SII]6731      1.649      0.39       1    70
# Comp:  2              HeII4687      0.000      0.39       1    70
# Comp:  2               HeI5876    0.05121      0.39       1    70
# Comp:  2          [OIII]5007_d      1.525      0.50       1    70
# Comp:  2            [OI]6300_d     0.1281      0.50       1    70
# Comp:  2           [NII]6583_d      3.229      0.50       1    70
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -70       243
#  comp.  1:       -44        50
#  comp.  2:         1        77
# chi2/DOF: 0.8966; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1283      0.36     -44    50
# Comp:  1                 Hbeta      1.249      0.36     -44    50
# Comp:  1                Halpha      4.624      0.36     -44    50
# Comp:  2             [SII]6716      1.536      0.40       1    77
# Comp:  2             [SII]6731      1.665      0.40       1    77
# Comp:  2              HeII4687      0.000      0.40       1    77
# Comp:  2               HeI5876    0.04101      0.40       1    77
# Comp:  2          [OIII]5007_d      1.847      0.51       1    77
# Comp:  2            [OI]6300_d      0.000      0.51       1    77
# Comp:  2           [NII]6583_d      3.201      0.51       1    77
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -110       146
#  comp.  1:       -41        41
#  comp.  2:       -31        78
# chi2/DOF: 0.9014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1761      0.35     -41    41
# Comp:  1                 Hbeta     0.9796      0.35     -41    41
# Comp:  1                Halpha      4.243      0.35     -41    41
# Comp:  2             [SII]6716      1.527      0.40     -31    78
# Comp:  2             [SII]6731      1.648      0.40     -31    78
# Comp:  2              HeII4687      0.000      0.40     -31    78
# Comp:  2               HeI5876     0.2205      0.40     -31    78
# Comp:  2          [OIII]5007_d      2.328      0.51     -31    78
# Comp:  2            [OI]6300_d     0.1000      0.51     -31    78
# Comp:  2           [NII]6583_d      2.515      0.51     -31    78
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80       163
#  comp.  1:       -37        45
#  comp.  2:       -24        99
# chi2/DOF: 0.8961; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.5936      0.36     -37    45
# Comp:  1                 Hbeta      1.118      0.36     -37    45
# Comp:  1                Halpha      4.627      0.36     -37    45
# Comp:  2             [SII]6716      1.362      0.44     -24    99
# Comp:  2             [SII]6731      1.311      0.44     -24    99
# Comp:  2              HeII4687      0.000      0.44     -24    99
# Comp:  2               HeI5876      0.000      0.44     -24    99
# Comp:  2          [OIII]5007_d      2.780      0.55     -24    99
# Comp:  2            [OI]6300_d    0.06599      0.55     -24    99
# Comp:  2           [NII]6583_d      2.522      0.55     -24    99
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -112       193
#  comp.  1:       -46        41
#  comp.  2:       -14        63
# chi2/DOF: 0.8971; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1121      0.35     -46    41
# Comp:  1                 Hbeta      1.121      0.35     -46    41
# Comp:  1                Halpha      4.145      0.35     -46    41
# Comp:  2             [SII]6716      1.722      0.38     -14    63
# Comp:  2             [SII]6731      1.805      0.38     -14    63
# Comp:  2              HeII4687     0.2117      0.38     -14    63
# Comp:  2               HeI5876      0.000      0.38     -14    63
# Comp:  2          [OIII]5007_d      1.872      0.48     -14    63
# Comp:  2            [OI]6300_d      0.000      0.48     -14    63
# Comp:  2           [NII]6583_d      3.077      0.48     -14    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46       159
#  comp.  1:       -44        46
#  comp.  2:       -29        66
# chi2/DOF: 0.8940; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6798      0.36     -44    46
# Comp:  1                 Hbeta      1.450      0.36     -44    46
# Comp:  1                Halpha      4.694      0.36     -44    46
# Comp:  2             [SII]6716      1.523      0.39     -29    66
# Comp:  2             [SII]6731      2.052      0.39     -29    66
# Comp:  2              HeII4687      0.000      0.39     -29    66
# Comp:  2               HeI5876      0.000      0.39     -29    66
# Comp:  2          [OIII]5007_d      1.762      0.49     -29    66
# Comp:  2            [OI]6300_d     0.5155      0.49     -29    66
# Comp:  2           [NII]6583_d      2.806      0.49     -29    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -95       144
#  comp.  1:       -46        50
#  comp.  2:        13        97
# chi2/DOF: 0.8885; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.4795      0.36     -46    50
# Comp:  1                 Hbeta      1.524      0.36     -46    50
# Comp:  1                Halpha      4.645      0.36     -46    50
# Comp:  2             [SII]6716      1.839      0.43      13    97
# Comp:  2             [SII]6731      1.091      0.43      13    97
# Comp:  2              HeII4687     0.9502      0.43      13    97
# Comp:  2               HeI5876     0.2023      0.43      13    97
# Comp:  2          [OIII]5007_d      1.844      0.55      13    97
# Comp:  2            [OI]6300_d     0.4317      0.55      13    97
# Comp:  2           [NII]6583_d      2.648      0.55      13    97
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -148       193
#  comp.  1:       -42        56
#  comp.  2:        -1        72
# chi2/DOF: 0.8976; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma    0.07961      0.37     -42    56
# Comp:  1                 Hbeta      1.345      0.37     -42    56
# Comp:  1                Halpha      4.935      0.37     -42    56
# Comp:  2             [SII]6716      1.505      0.39      -1    72
# Comp:  2             [SII]6731      1.959      0.39      -1    72
# Comp:  2              HeII4687      0.000      0.39      -1    72
# Comp:  2               HeI5876      0.000      0.39      -1    72
# Comp:  2          [OIII]5007_d      1.426      0.50      -1    72
# Comp:  2            [OI]6300_d    0.04377      0.50      -1    72
# Comp:  2           [NII]6583_d      2.822      0.50      -1    72
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -120       231
#  comp.  1:       -35        49
#  comp.  2:         4       132
# chi2/DOF: 0.8978; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.36     -35    49
# Comp:  1                 Hbeta      1.104      0.36     -35    49
# Comp:  1                Halpha      4.567      0.36     -35    49
# Comp:  2             [SII]6716      1.838      0.49       4   132
# Comp:  2             [SII]6731      2.168      0.49       4   132
# Comp:  2              HeII4687     0.3059      0.49       4   132
# Comp:  2               HeI5876      0.000      0.49       4   132
# Comp:  2          [OIII]5007_d      2.201      0.61       4   132
# Comp:  2            [OI]6300_d     0.2569      0.61       4   132
# Comp:  2           [NII]6583_d      2.938      0.61       4   132
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -115       199
#  comp.  1:       -45        40
#  comp.  2:       -24        61
# chi2/DOF: 0.8985; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.35     -45    40
# Comp:  1                 Hbeta      1.091      0.35     -45    40
# Comp:  1                Halpha      4.457      0.35     -45    40
# Comp:  2             [SII]6716      1.573      0.38     -24    61
# Comp:  2             [SII]6731      2.026      0.38     -24    61
# Comp:  2              HeII4687      0.000      0.38     -24    61
# Comp:  2               HeI5876     0.1052      0.38     -24    61
# Comp:  2          [OIII]5007_d      1.822      0.48     -24    61
# Comp:  2            [OI]6300_d     0.2278      0.48     -24    61
# Comp:  2           [NII]6583_d      2.782      0.48     -24    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33       201
#  comp.  1:       -39        41
#  comp.  2:       -30        48
# chi2/DOF: 0.8961; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.6380      0.35     -39    41
# Comp:  1                 Hbeta      1.213      0.35     -39    41
# Comp:  1                Halpha      4.520      0.35     -39    41
# Comp:  2             [SII]6716      1.558      0.36     -30    48
# Comp:  2             [SII]6731      1.754      0.36     -30    48
# Comp:  2              HeII4687      0.000      0.36     -30    48
# Comp:  2               HeI5876     0.1124      0.36     -30    48
# Comp:  2          [OIII]5007_d      1.395      0.46     -30    48
# Comp:  2            [OI]6300_d     0.1757      0.46     -30    48
# Comp:  2           [NII]6583_d      2.402      0.46     -30    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -102       208
#  comp.  1:       -42        40
#  comp.  2:       -28        44
# chi2/DOF: 0.8979; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma    0.09487      0.35     -42    40
# Comp:  1                 Hbeta      1.015      0.35     -42    40
# Comp:  1                Halpha      4.413      0.35     -42    40
# Comp:  2             [SII]6716      1.044      0.36     -28    44
# Comp:  2             [SII]6731      1.293      0.36     -28    44
# Comp:  2              HeII4687      0.000      0.36     -28    44
# Comp:  2               HeI5876      0.000      0.36     -28    44
# Comp:  2          [OIII]5007_d      1.405      0.45     -28    44
# Comp:  2            [OI]6300_d    0.04957      0.45     -28    44
# Comp:  2           [NII]6583_d      2.432      0.45     -28    44
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -134       200
#  comp.  1:       -42        45
#  comp.  2:        -6       110
# chi2/DOF: 0.8992; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -180       209
#  comp.  1:       -39        35
#  comp.  2:       -25        65
# chi2/DOF: 0.8970; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.34     -39    35
# Comp:  1                 Hbeta     0.8027      0.34     -39    35
# Comp:  1                Halpha      4.072      0.34     -39    35
# Comp:  2             [SII]6716      1.374      0.38     -25    65
# Comp:  2             [SII]6731      1.424      0.38     -25    65
# Comp:  2              HeII4687     0.5899      0.38     -25    65
# Comp:  2               HeI5876     0.2746      0.38     -25    65
# Comp:  2          [OIII]5007_d      2.214      0.49     -25    65
# Comp:  2            [OI]6300_d      0.000      0.49     -25    65
# Comp:  2           [NII]6583_d      2.305      0.49     -25    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81       223
#  comp.  1:       -43        39
#  comp.  2:       -18        81
# chi2/DOF: 0.8950; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.35     -43    39
# Comp:  1                 Hbeta      1.464      0.35     -43    39
# Comp:  1                Halpha      4.261      0.35     -43    39
# Comp:  2             [SII]6716      1.226      0.41     -18    81
# Comp:  2             [SII]6731      1.433      0.41     -18    81
# Comp:  2              HeII4687      0.000      0.41     -18    81
# Comp:  2               HeI5876     0.2927      0.41     -18    81
# Comp:  2          [OIII]5007_d      2.160      0.51     -18    81
# Comp:  2            [OI]6300_d      0.000      0.51     -18    81
# Comp:  2           [NII]6583_d      2.811      0.51     -18    81
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -87       145
#  comp.  1:       -42        64
#  comp.  2:        18       112
# chi2/DOF: 0.8954; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.5821      0.38     -42    64
# Comp:  1                 Hbeta      1.508      0.38     -42    64
# Comp:  1                Halpha      5.122      0.38     -42    64
# Comp:  2             [SII]6716      2.029      0.45      18   112
# Comp:  2             [SII]6731      2.226      0.45      18   112
# Comp:  2              HeII4687      0.000      0.45      18   112
# Comp:  2               HeI5876      0.000      0.45      18   112
# Comp:  2          [OIII]5007_d      2.249      0.57      18   112
# Comp:  2            [OI]6300_d     0.6025      0.57      18   112
# Comp:  2           [NII]6583_d      3.628      0.57      18   112
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96       202
#  comp.  1:       -34        50
#  comp.  2:       -14        52
# chi2/DOF: 0.8966; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1690      0.36     -34    50
# Comp:  1                 Hbeta      1.201      0.36     -34    50
# Comp:  1                Halpha      4.693      0.36     -34    50
# Comp:  2             [SII]6716      1.285      0.37     -14    52
# Comp:  2             [SII]6731     0.8474      0.37     -14    52
# Comp:  2              HeII4687      0.000      0.37     -14    52
# Comp:  2               HeI5876    0.07697      0.37     -14    52
# Comp:  2          [OIII]5007_d      1.935      0.46     -14    52
# Comp:  2            [OI]6300_d      0.000      0.46     -14    52
# Comp:  2           [NII]6583_d      2.311      0.46     -14    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75       194
#  comp.  1:       -33        34
#  comp.  2:        -6        69
# chi2/DOF: 0.8964; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.34     -33    34
# Comp:  1                 Hbeta      1.070      0.34     -33    34
# Comp:  1                Halpha      4.225      0.34     -33    34
# Comp:  2             [SII]6716      1.296      0.39      -6    69
# Comp:  2             [SII]6731      1.452      0.39      -6    69
# Comp:  2              HeII4687     0.4634      0.39      -6    69
# Comp:  2               HeI5876    0.06618      0.39      -6    69
# Comp:  2          [OIII]5007_d      2.034      0.49      -6    69
# Comp:  2            [OI]6300_d    0.09261      0.49      -6    69
# Comp:  2           [NII]6583_d      2.694      0.49      -6    69
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -85       226
#  comp.  1:       -37        50
#  comp.  2:       -37        57
# chi2/DOF: 0.8955; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.3127      0.36     -37    50
# Comp:  1                 Hbeta      1.295      0.36     -37    50
# Comp:  1                Halpha      4.445      0.36     -37    50
# Comp:  2             [SII]6716      1.059      0.37     -37    57
# Comp:  2             [SII]6731      1.408      0.37     -37    57
# Comp:  2              HeII4687     0.8670      0.37     -37    57
# Comp:  2               HeI5876     0.1357      0.37     -37    57
# Comp:  2          [OIII]5007_d      1.342      0.47     -37    57
# Comp:  2            [OI]6300_d     0.1938      0.47     -37    57
# Comp:  2           [NII]6583_d      2.226      0.47     -37    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -111       156
#  comp.  1:       -40        48
#  comp.  2:       -23        54
# chi2/DOF: 0.8973; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.36     -40    48
# Comp:  1                 Hbeta      1.402      0.36     -40    48
# Comp:  1                Halpha      4.811      0.36     -40    48
# Comp:  2             [SII]6716      1.205      0.37     -23    54
# Comp:  2             [SII]6731      1.205      0.37     -23    54
# Comp:  2              HeII4687      0.000      0.37     -23    54
# Comp:  2               HeI5876      0.000      0.37     -23    54
# Comp:  2          [OIII]5007_d      1.655      0.47     -23    54
# Comp:  2            [OI]6300_d    0.08164      0.47     -23    54
# Comp:  2           [NII]6583_d      2.537      0.47     -23    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -136       163
#  comp.  1:       -36        62
#  comp.  2:       -32        91
# chi2/DOF: 0.8972; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma    0.03236      0.38     -36    62
# Comp:  1                 Hbeta      1.257      0.38     -36    62
# Comp:  1                Halpha      4.939      0.38     -36    62
# Comp:  2             [SII]6716      2.170      0.42     -32    91
# Comp:  2             [SII]6731      1.378      0.42     -32    91
# Comp:  2              HeII4687      0.000      0.42     -32    91
# Comp:  2               HeI5876     0.1982      0.42     -32    91
# Comp:  2          [OIII]5007_d      2.515      0.53     -32    91
# Comp:  2            [OI]6300_d    0.04076      0.53     -32    91
# Comp:  2           [NII]6583_d      2.767      0.53     -32    91
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -89       189
#  comp.  1:       -38        39
#  comp.  2:         1       108
# chi2/DOF: 0.8880; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.2594      0.35     -38    39
# Comp:  1                 Hbeta      1.304      0.35     -38    39
# Comp:  1                Halpha      4.189      0.35     -38    39
# Comp:  2             [SII]6716      1.574      0.45       1   108
# Comp:  2             [SII]6731      2.624      0.45       1   108
# Comp:  2              HeII4687      0.000      0.45       1   108
# Comp:  2               HeI5876     0.3068      0.45       1   108
# Comp:  2          [OIII]5007_d      2.429      0.57       1   108
# Comp:  2            [OI]6300_d      0.000      0.57       1   108
# Comp:  2           [NII]6583_d      2.415      0.57       1   108
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        77
#  comp.  1:       -45        49
#  comp.  2:       -22        56
# chi2/DOF: 0.8936; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.5821      0.36     -45    49
# Comp:  1                 Hbeta      1.320      0.36     -45    49
# Comp:  1                Halpha      4.665      0.36     -45    49
# Comp:  2             [SII]6716      1.523      0.37     -22    56
# Comp:  2             [SII]6731      1.306      0.37     -22    56
# Comp:  2              HeII4687      0.000      0.37     -22    56
# Comp:  2               HeI5876      0.000      0.37     -22    56
# Comp:  2          [OIII]5007_d      1.352      0.47     -22    56
# Comp:  2            [OI]6300_d      0.000      0.47     -22    56
# Comp:  2           [NII]6583_d      2.560      0.47     -22    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -102       182
#  comp.  1:       -41        50
#  comp.  2:       -19        68
# chi2/DOF: 0.8986; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.36     -41    50
# Comp:  1                 Hbeta      1.289      0.36     -41    50
# Comp:  1                Halpha      4.567      0.36     -41    50
# Comp:  2             [SII]6716      1.516      0.39     -19    68
# Comp:  2             [SII]6731      1.282      0.39     -19    68
# Comp:  2              HeII4687     0.4192      0.39     -19    68
# Comp:  2               HeI5876      0.000      0.39     -19    68
# Comp:  2          [OIII]5007_d      2.184      0.49     -19    68
# Comp:  2            [OI]6300_d     0.4066      0.49     -19    68
# Comp:  2           [NII]6583_d      2.764      0.49     -19    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99       168
#  comp.  1:       -40        37
#  comp.  2:       -12        83
# chi2/DOF: 0.9004; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 16/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma     0.1726      0.35     -40    37
# Comp:  1                 Hbeta      1.036      0.35     -40    37
# Comp:  1                Halpha      4.410      0.35     -40    37
# Comp:  2             [SII]6716      1.022      0.41     -12    83
# Comp:  2             [SII]6731      1.844      0.41     -12    83
# Comp:  2              HeII4687      0.000      0.41     -12    83
# Comp:  2               HeI5876    0.05367      0.41     -12    83
# Comp:  2          [OIII]5007_d      1.809      0.52     -12    83
# Comp:  2            [OI]6300_d     0.1345      0.52     -12    83
# Comp:  2           [NII]6583_d      2.661      0.52     -12    83
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -122       150
#  comp.  1:       -39        29
#  comp.  2:       -39        43
# chi2/DOF: 0.8928; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      0.000      0.34     -39    29
# Comp:  1                 Hbeta     0.6999      0.34     -39    29
# Comp:  1                Halpha      4.218      0.34     -39    29
# Comp:  2             [SII]6716      1.097      0.35     -39    43
# Comp:  2             [SII]6731      1.291      0.35     -39    43
# Comp:  2              HeII4687      0.000      0.35     -39    43
# Comp:  2               HeI5876     0.1453      0.35     -39    43
# Comp:  2          [OIII]5007_d      2.207      0.45     -39    43
# Comp:  2            [OI]6300_d   0.007386      0.45     -39    43
# Comp:  2           [NII]6583_d      2.665      0.45     -39    43
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.20822421, 0.22550979, 0.37061148, 0.45230018, 0.71448718,
#        0.37154235, 0.14537778, 0.34197957, 0.24473185, 0.54064544])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_17_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_17", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_17_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_17_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_17_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
