# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_3.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_3']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4314.03901503 4315.47324864 4316.90748224 ... 6874.1460011  6875.58023471
#  6877.01446832] [0.00605571 0.01530831 0.01547806 ... 0.0219139  0.01821839 0.01112783] [0.00619146 0.00619146 0.00619146 ... 0.00619146 0.00619146 0.00619146]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -13         1
# chi2/DOF: 0.1634; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
# chi2/DOF: 0.07466; DOF: 1888; degree = 4; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-19.43389011,   0.62529643])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:        -7         1
#  comp.  1:       -74        35
#  comp.  2:       -92        61
# chi2/DOF: 1.028; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.590      0.79     -74    35
# Comp:  1                 Hbeta      6.465      0.79     -74    35
# Comp:  1                Halpha      31.36      0.79     -74    35
# Comp:  2             [SII]6716      9.313      0.86     -92    61
# Comp:  2             [SII]6731      6.129      0.86     -92    61
# Comp:  2              HeII4687      0.000      0.86     -92    61
# Comp:  2               HeI5876      2.120      0.86     -92    61
# Comp:  2          [OIII]5007_d      11.80       1.1     -92    61
# Comp:  2            [OI]6300_d      3.983       1.1     -92    61
# Comp:  2           [NII]6583_d      10.27       1.1     -92    61
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  5.208; gas flux:      4 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  7.569; gas flux:      7 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  35.34; gas flux:     43 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  9.151; gas flux:     13 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  5.773; gas flux:      9 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:     -0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  2.108; gas flux:      3 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:   8.78; gas flux:     12 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  2.848; gas flux:      5 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  7.469; gas flux:     14 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -25         1
#  comp.  1:       -78        38
#  comp.  2:       -94        63
# chi2/DOF: 1.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.708      0.80     -78    38
# Comp:  1                 Hbeta      7.538      0.80     -78    38
# Comp:  1                Halpha      30.85      0.80     -78    38
# Comp:  2             [SII]6716      9.621      0.87     -94    63
# Comp:  2             [SII]6731      5.894      0.87     -94    63
# Comp:  2              HeII4687      0.000      0.87     -94    63
# Comp:  2               HeI5876      2.201      0.87     -94    63
# Comp:  2          [OIII]5007_d      12.44       1.1     -94    63
# Comp:  2            [OI]6300_d      3.275       1.1     -94    63
# Comp:  2           [NII]6583_d      10.15       1.1     -94    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        44
#  comp.  1:       -74        35
#  comp.  2:       -92        60
# chi2/DOF: 1.021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.702      0.79     -74    35
# Comp:  1                 Hbeta      6.760      0.79     -74    35
# Comp:  1                Halpha      31.03      0.79     -74    35
# Comp:  2             [SII]6716      9.039      0.86     -92    60
# Comp:  2             [SII]6731      6.214      0.86     -92    60
# Comp:  2              HeII4687      0.000      0.86     -92    60
# Comp:  2               HeI5876      2.467      0.86     -92    60
# Comp:  2          [OIII]5007_d      11.56       1.1     -92    60
# Comp:  2            [OI]6300_d      4.444       1.1     -92    60
# Comp:  2           [NII]6583_d      10.33       1.1     -92    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        78        80
#  comp.  1:       -76        33
#  comp.  2:       -90        47
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.429      0.78     -76    33
# Comp:  1                 Hbeta      6.309      0.78     -76    33
# Comp:  1                Halpha      30.89      0.78     -76    33
# Comp:  2             [SII]6716      9.080      0.82     -90    47
# Comp:  2             [SII]6731      5.758      0.82     -90    47
# Comp:  2              HeII4687      0.000      0.82     -90    47
# Comp:  2               HeI5876      2.571      0.82     -90    47
# Comp:  2          [OIII]5007_d      10.91       1.0     -90    47
# Comp:  2            [OI]6300_d      4.324       1.0     -90    47
# Comp:  2           [NII]6583_d      9.679       1.0     -90    47
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -9         1
#  comp.  1:       -73        27
#  comp.  2:       -95        63
# chi2/DOF: 1.019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.124      0.77     -73    27
# Comp:  1                 Hbeta      6.664      0.77     -73    27
# Comp:  1                Halpha      30.53      0.77     -73    27
# Comp:  2             [SII]6716      9.029      0.87     -95    63
# Comp:  2             [SII]6731      5.840      0.87     -95    63
# Comp:  2              HeII4687    0.05627      0.87     -95    63
# Comp:  2               HeI5876      2.650      0.87     -95    63
# Comp:  2          [OIII]5007_d      12.16       1.1     -95    63
# Comp:  2            [OI]6300_d      5.016       1.1     -95    63
# Comp:  2           [NII]6583_d      10.20       1.1     -95    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        61
#  comp.  1:       -74        41
#  comp.  2:       -94        56
# chi2/DOF: 1.018; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 57; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.143      0.80     -74    41
# Comp:  1                 Hbeta      6.506      0.80     -74    41
# Comp:  1                Halpha      32.42      0.80     -74    41
# Comp:  2             [SII]6716      9.037      0.85     -94    56
# Comp:  2             [SII]6731      5.967      0.85     -94    56
# Comp:  2              HeII4687      0.000      0.85     -94    56
# Comp:  2               HeI5876      1.764      0.85     -94    56
# Comp:  2          [OIII]5007_d      12.08       1.1     -94    56
# Comp:  2            [OI]6300_d      4.620       1.1     -94    56
# Comp:  2           [NII]6583_d      9.899       1.1     -94    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41         1
#  comp.  1:       -71        36
#  comp.  2:       -96        62
# chi2/DOF: 1.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.989      0.79     -71    36
# Comp:  1                 Hbeta      7.479      0.79     -71    36
# Comp:  1                Halpha      32.02      0.79     -71    36
# Comp:  2             [SII]6716      9.273      0.87     -96    62
# Comp:  2             [SII]6731      6.334      0.87     -96    62
# Comp:  2              HeII4687     0.1835      0.87     -96    62
# Comp:  2               HeI5876      2.113      0.87     -96    62
# Comp:  2          [OIII]5007_d      11.90       1.1     -96    62
# Comp:  2            [OI]6300_d      4.303       1.1     -96    62
# Comp:  2           [NII]6583_d      9.929       1.1     -96    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         5         1
#  comp.  1:       -72        42
#  comp.  2:       -90        71
# chi2/DOF: 1.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.797      0.80     -72    42
# Comp:  1                 Hbeta      7.491      0.80     -72    42
# Comp:  1                Halpha      32.21      0.80     -72    42
# Comp:  2             [SII]6716      9.697      0.90     -90    71
# Comp:  2             [SII]6731      6.680      0.90     -90    71
# Comp:  2              HeII4687     0.8259      0.90     -90    71
# Comp:  2               HeI5876      2.059      0.90     -90    71
# Comp:  2          [OIII]5007_d      12.49       1.1     -90    71
# Comp:  2            [OI]6300_d      4.399       1.1     -90    71
# Comp:  2           [NII]6583_d      10.74       1.1     -90    71
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -21         1
#  comp.  1:       -74        30
#  comp.  2:       -93        64
# chi2/DOF: 1.021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.937      0.78     -74    30
# Comp:  1                 Hbeta      6.759      0.78     -74    30
# Comp:  1                Halpha      30.09      0.78     -74    30
# Comp:  2             [SII]6716      8.987      0.87     -93    64
# Comp:  2             [SII]6731      6.571      0.87     -93    64
# Comp:  2              HeII4687      0.000      0.87     -93    64
# Comp:  2               HeI5876      1.913      0.87     -93    64
# Comp:  2          [OIII]5007_d      12.25       1.1     -93    64
# Comp:  2            [OI]6300_d      3.707       1.1     -93    64
# Comp:  2           [NII]6583_d      10.59       1.1     -93    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25         1
#  comp.  1:       -75        31
#  comp.  2:       -90        57
# chi2/DOF: 1.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.524      0.78     -75    31
# Comp:  1                 Hbeta      6.495      0.78     -75    31
# Comp:  1                Halpha      31.03      0.78     -75    31
# Comp:  2             [SII]6716      8.960      0.85     -90    57
# Comp:  2             [SII]6731      5.821      0.85     -90    57
# Comp:  2              HeII4687     0.9629      0.85     -90    57
# Comp:  2               HeI5876      1.774      0.85     -90    57
# Comp:  2          [OIII]5007_d      11.10       1.1     -90    57
# Comp:  2            [OI]6300_d      4.375       1.1     -90    57
# Comp:  2           [NII]6583_d      10.93       1.1     -90    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         3         1
#  comp.  1:       -73        37
#  comp.  2:       -90        64
# chi2/DOF: 1.018; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.896      0.79     -73    37
# Comp:  1                 Hbeta      6.581      0.79     -73    37
# Comp:  1                Halpha      32.18      0.79     -73    37
# Comp:  2             [SII]6716      8.761      0.87     -90    64
# Comp:  2             [SII]6731      6.181      0.87     -90    64
# Comp:  2              HeII4687      2.021      0.87     -90    64
# Comp:  2               HeI5876      2.646      0.87     -90    64
# Comp:  2          [OIII]5007_d      12.52       1.1     -90    64
# Comp:  2            [OI]6300_d      5.106       1.1     -90    64
# Comp:  2           [NII]6583_d      10.22       1.1     -90    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        33        55
#  comp.  1:       -78        35
#  comp.  2:       -88        58
# chi2/DOF: 1.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.050      0.79     -78    35
# Comp:  1                 Hbeta      6.396      0.79     -78    35
# Comp:  1                Halpha      31.21      0.79     -78    35
# Comp:  2             [SII]6716      9.095      0.85     -88    58
# Comp:  2             [SII]6731      6.226      0.85     -88    58
# Comp:  2              HeII4687      0.000      0.85     -88    58
# Comp:  2               HeI5876      1.731      0.85     -88    58
# Comp:  2          [OIII]5007_d      11.23       1.1     -88    58
# Comp:  2            [OI]6300_d      4.538       1.1     -88    58
# Comp:  2           [NII]6583_d      10.62       1.1     -88    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        19        98
#  comp.  1:       -70        41
#  comp.  2:       -91        66
# chi2/DOF: 1.021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.975      0.80     -70    41
# Comp:  1                 Hbeta      7.274      0.80     -70    41
# Comp:  1                Halpha      32.83      0.80     -70    41
# Comp:  2             [SII]6716      8.613      0.88     -91    66
# Comp:  2             [SII]6731      6.511      0.88     -91    66
# Comp:  2              HeII4687     0.1160      0.88     -91    66
# Comp:  2               HeI5876      2.088      0.88     -91    66
# Comp:  2          [OIII]5007_d      12.40       1.1     -91    66
# Comp:  2            [OI]6300_d      3.506       1.1     -91    66
# Comp:  2           [NII]6583_d      10.74       1.1     -91    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        84
#  comp.  1:       -74        35
#  comp.  2:       -92        61
# chi2/DOF: 1.015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.310      0.79     -74    35
# Comp:  1                 Hbeta      6.520      0.79     -74    35
# Comp:  1                Halpha      32.33      0.79     -74    35
# Comp:  2             [SII]6716      8.814      0.86     -92    61
# Comp:  2             [SII]6731      5.694      0.86     -92    61
# Comp:  2              HeII4687      1.073      0.86     -92    61
# Comp:  2               HeI5876      1.943      0.86     -92    61
# Comp:  2          [OIII]5007_d      10.92       1.1     -92    61
# Comp:  2            [OI]6300_d      4.285       1.1     -92    61
# Comp:  2           [NII]6583_d      10.82       1.1     -92    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -19         1
#  comp.  1:       -70        42
#  comp.  2:       -91        61
# chi2/DOF: 1.021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.102      0.81     -70    42
# Comp:  1                 Hbeta      7.626      0.81     -70    42
# Comp:  1                Halpha      31.81      0.81     -70    42
# Comp:  2             [SII]6716      9.776      0.86     -91    61
# Comp:  2             [SII]6731      6.951      0.86     -91    61
# Comp:  2              HeII4687      0.000      0.86     -91    61
# Comp:  2               HeI5876      1.840      0.86     -91    61
# Comp:  2          [OIII]5007_d      11.51       1.1     -91    61
# Comp:  2            [OI]6300_d      3.535       1.1     -91    61
# Comp:  2           [NII]6583_d      10.17       1.1     -91    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        29
#  comp.  1:       -74        35
#  comp.  2:       -92        62
# chi2/DOF: 1.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.876      0.79     -74    35
# Comp:  1                 Hbeta      7.141      0.79     -74    35
# Comp:  1                Halpha      31.57      0.79     -74    35
# Comp:  2             [SII]6716      8.963      0.87     -92    62
# Comp:  2             [SII]6731      6.178      0.87     -92    62
# Comp:  2              HeII4687      1.571      0.87     -92    62
# Comp:  2               HeI5876      2.685      0.87     -92    62
# Comp:  2          [OIII]5007_d      12.39       1.1     -92    62
# Comp:  2            [OI]6300_d      4.066       1.1     -92    62
# Comp:  2           [NII]6583_d      9.811       1.1     -92    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -73        36
#  comp.  2:       -89        63
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.787      0.79     -73    36
# Comp:  1                 Hbeta      7.348      0.79     -73    36
# Comp:  1                Halpha      32.50      0.79     -73    36
# Comp:  2             [SII]6716      8.980      0.87     -89    63
# Comp:  2             [SII]6731      6.116      0.87     -89    63
# Comp:  2              HeII4687      0.000      0.87     -89    63
# Comp:  2               HeI5876      2.933      0.87     -89    63
# Comp:  2          [OIII]5007_d      11.27       1.1     -89    63
# Comp:  2            [OI]6300_d      4.970       1.1     -89    63
# Comp:  2           [NII]6583_d      9.612       1.1     -89    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -12         1
#  comp.  1:       -77        33
#  comp.  2:       -92        64
# chi2/DOF: 1.021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.884      0.78     -77    33
# Comp:  1                 Hbeta      7.398      0.78     -77    33
# Comp:  1                Halpha      31.28      0.78     -77    33
# Comp:  2             [SII]6716      10.14      0.87     -92    64
# Comp:  2             [SII]6731      6.372      0.87     -92    64
# Comp:  2              HeII4687      0.000      0.87     -92    64
# Comp:  2               HeI5876      2.503      0.87     -92    64
# Comp:  2          [OIII]5007_d      11.53       1.1     -92    64
# Comp:  2            [OI]6300_d      4.832       1.1     -92    64
# Comp:  2           [NII]6583_d      11.02       1.1     -92    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46         1
#  comp.  1:       -72        31
#  comp.  2:       -90        61
# chi2/DOF: 1.015; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.066      0.78     -72    31
# Comp:  1                 Hbeta      7.216      0.78     -72    31
# Comp:  1                Halpha      31.83      0.78     -72    31
# Comp:  2             [SII]6716      8.953      0.86     -90    61
# Comp:  2             [SII]6731      5.907      0.86     -90    61
# Comp:  2              HeII4687     0.3710      0.86     -90    61
# Comp:  2               HeI5876      2.890      0.86     -90    61
# Comp:  2          [OIII]5007_d      11.43       1.1     -90    61
# Comp:  2            [OI]6300_d      3.822       1.1     -90    61
# Comp:  2           [NII]6583_d      9.586       1.1     -90    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38         1
#  comp.  1:       -76        33
#  comp.  2:       -89        66
# chi2/DOF: 1.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.411      0.78     -76    33
# Comp:  1                 Hbeta      7.637      0.78     -76    33
# Comp:  1                Halpha      32.08      0.78     -76    33
# Comp:  2             [SII]6716      9.698      0.88     -89    66
# Comp:  2             [SII]6731      6.072      0.88     -89    66
# Comp:  2              HeII4687      0.000      0.88     -89    66
# Comp:  2               HeI5876      2.215      0.88     -89    66
# Comp:  2          [OIII]5007_d      12.02       1.1     -89    66
# Comp:  2            [OI]6300_d      4.035       1.1     -89    66
# Comp:  2           [NII]6583_d      10.23       1.1     -89    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:       -76        29
#  comp.  2:       -97        68
# chi2/DOF: 1.021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.371      0.77     -76    29
# Comp:  1                 Hbeta      6.057      0.77     -76    29
# Comp:  1                Halpha      31.46      0.77     -76    29
# Comp:  2             [SII]6716      10.02      0.89     -97    68
# Comp:  2             [SII]6731      6.707      0.89     -97    68
# Comp:  2              HeII4687      0.000      0.89     -97    68
# Comp:  2               HeI5876      2.504      0.89     -97    68
# Comp:  2          [OIII]5007_d      12.44       1.1     -97    68
# Comp:  2            [OI]6300_d      4.521       1.1     -97    68
# Comp:  2           [NII]6583_d      10.74       1.1     -97    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82       981
#  comp.  1:       -77        27
#  comp.  2:       -91        61
# chi2/DOF: 1.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.803      0.77     -77    27
# Comp:  1                 Hbeta      6.026      0.77     -77    27
# Comp:  1                Halpha      29.88      0.77     -77    27
# Comp:  2             [SII]6716      9.427      0.86     -91    61
# Comp:  2             [SII]6731      6.477      0.86     -91    61
# Comp:  2              HeII4687      0.000      0.86     -91    61
# Comp:  2               HeI5876      2.932      0.86     -91    61
# Comp:  2          [OIII]5007_d      11.19       1.1     -91    61
# Comp:  2            [OI]6300_d      2.616       1.1     -91    61
# Comp:  2           [NII]6583_d      11.30       1.1     -91    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -33        17
#  comp.  1:       -76        33
#  comp.  2:       -92        55
# chi2/DOF: 1.021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.853      0.78     -76    33
# Comp:  1                 Hbeta      8.325      0.78     -76    33
# Comp:  1                Halpha      31.77      0.78     -76    33
# Comp:  2             [SII]6716      9.096      0.84     -92    55
# Comp:  2             [SII]6731      6.070      0.84     -92    55
# Comp:  2              HeII4687     0.2591      0.84     -92    55
# Comp:  2               HeI5876      2.117      0.84     -92    55
# Comp:  2          [OIII]5007_d      11.61       1.1     -92    55
# Comp:  2            [OI]6300_d      3.556       1.1     -92    55
# Comp:  2           [NII]6583_d      10.56       1.1     -92    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         2        94
#  comp.  1:       -72        42
#  comp.  2:       -89        56
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 49; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.886      0.81     -72    42
# Comp:  1                 Hbeta      7.419      0.81     -72    42
# Comp:  1                Halpha      31.58      0.81     -72    42
# Comp:  2             [SII]6716      9.557      0.85     -89    56
# Comp:  2             [SII]6731      5.739      0.85     -89    56
# Comp:  2              HeII4687      0.000      0.85     -89    56
# Comp:  2               HeI5876      1.967      0.85     -89    56
# Comp:  2          [OIII]5007_d      11.22       1.1     -89    56
# Comp:  2            [OI]6300_d      3.172       1.1     -89    56
# Comp:  2           [NII]6583_d      10.95       1.1     -89    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -46       133
#  comp.  1:       -74        30
#  comp.  2:       -89        65
# chi2/DOF: 1.018; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.376      0.78     -74    30
# Comp:  1                 Hbeta      6.311      0.78     -74    30
# Comp:  1                Halpha      31.23      0.78     -74    30
# Comp:  2             [SII]6716      9.308      0.88     -89    65
# Comp:  2             [SII]6731      6.827      0.88     -89    65
# Comp:  2              HeII4687      0.000      0.88     -89    65
# Comp:  2               HeI5876      2.167      0.88     -89    65
# Comp:  2          [OIII]5007_d      12.05       1.1     -89    65
# Comp:  2            [OI]6300_d      3.665       1.1     -89    65
# Comp:  2           [NII]6583_d      11.10       1.1     -89    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -24        40
#  comp.  1:       -75        27
#  comp.  2:       -97        65
# chi2/DOF: 1.019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.130      0.77     -75    27
# Comp:  1                 Hbeta      6.052      0.77     -75    27
# Comp:  1                Halpha      31.13      0.77     -75    27
# Comp:  2             [SII]6716      8.784      0.88     -97    65
# Comp:  2             [SII]6731      6.068      0.88     -97    65
# Comp:  2              HeII4687      0.000      0.88     -97    65
# Comp:  2               HeI5876      1.782      0.88     -97    65
# Comp:  2          [OIII]5007_d      12.22       1.1     -97    65
# Comp:  2            [OI]6300_d      4.634       1.1     -97    65
# Comp:  2           [NII]6583_d      11.04       1.1     -97    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        16         1
#  comp.  1:       -74        29
#  comp.  2:       -91        58
# chi2/DOF: 1.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.184      0.77     -74    29
# Comp:  1                 Hbeta      5.988      0.77     -74    29
# Comp:  1                Halpha      29.94      0.77     -74    29
# Comp:  2             [SII]6716      9.385      0.85     -91    58
# Comp:  2             [SII]6731      6.279      0.85     -91    58
# Comp:  2              HeII4687      0.000      0.85     -91    58
# Comp:  2               HeI5876      2.218      0.85     -91    58
# Comp:  2          [OIII]5007_d      11.48       1.1     -91    58
# Comp:  2            [OI]6300_d      3.672       1.1     -91    58
# Comp:  2           [NII]6583_d      11.02       1.1     -91    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -17        32
#  comp.  1:       -71        40
#  comp.  2:       -96        60
# chi2/DOF: 1.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.737      0.80     -71    40
# Comp:  1                 Hbeta      7.817      0.80     -71    40
# Comp:  1                Halpha      32.76      0.80     -71    40
# Comp:  2             [SII]6716      8.930      0.86     -96    60
# Comp:  2             [SII]6731      6.301      0.86     -96    60
# Comp:  2              HeII4687      0.000      0.86     -96    60
# Comp:  2               HeI5876      2.386      0.86     -96    60
# Comp:  2          [OIII]5007_d      11.37       1.1     -96    60
# Comp:  2            [OI]6300_d      4.594       1.1     -96    60
# Comp:  2           [NII]6583_d      10.32       1.1     -96    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5         1
#  comp.  1:       -72        42
#  comp.  2:       -94        67
# chi2/DOF: 1.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.837      0.81     -72    42
# Comp:  1                 Hbeta      7.752      0.81     -72    42
# Comp:  1                Halpha      32.61      0.81     -72    42
# Comp:  2             [SII]6716      9.277      0.88     -94    67
# Comp:  2             [SII]6731      6.844      0.88     -94    67
# Comp:  2              HeII4687     0.7131      0.88     -94    67
# Comp:  2               HeI5876      1.775      0.88     -94    67
# Comp:  2          [OIII]5007_d      12.17       1.1     -94    67
# Comp:  2            [OI]6300_d      4.546       1.1     -94    67
# Comp:  2           [NII]6583_d      11.26       1.1     -94    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -14         1
#  comp.  1:       -76        31
#  comp.  2:       -92        59
# chi2/DOF: 1.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.342      0.78     -76    31
# Comp:  1                 Hbeta      7.252      0.78     -76    31
# Comp:  1                Halpha      30.73      0.78     -76    31
# Comp:  2             [SII]6716      9.433      0.86     -92    59
# Comp:  2             [SII]6731      5.867      0.86     -92    59
# Comp:  2              HeII4687      0.000      0.86     -92    59
# Comp:  2               HeI5876      1.437      0.86     -92    59
# Comp:  2          [OIII]5007_d      11.33       1.1     -92    59
# Comp:  2            [OI]6300_d      4.055       1.1     -92    59
# Comp:  2           [NII]6583_d      10.25       1.1     -92    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5         1
#  comp.  1:       -72        39
#  comp.  2:       -95        61
# chi2/DOF: 1.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.307      0.80     -72    39
# Comp:  1                 Hbeta      6.063      0.80     -72    39
# Comp:  1                Halpha      31.07      0.80     -72    39
# Comp:  2             [SII]6716      9.495      0.86     -95    61
# Comp:  2             [SII]6731      6.038      0.86     -95    61
# Comp:  2              HeII4687      0.000      0.86     -95    61
# Comp:  2               HeI5876      1.549      0.86     -95    61
# Comp:  2          [OIII]5007_d      11.59       1.1     -95    61
# Comp:  2            [OI]6300_d      4.546       1.1     -95    61
# Comp:  2           [NII]6583_d      10.20       1.1     -95    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        20       981
#  comp.  1:       -77        43
#  comp.  2:       -98        61
# chi2/DOF: 1.018; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.573      0.81     -77    43
# Comp:  1                 Hbeta      6.385      0.81     -77    43
# Comp:  1                Halpha      32.05      0.81     -77    43
# Comp:  2             [SII]6716      8.636      0.86     -98    61
# Comp:  2             [SII]6731      6.540      0.86     -98    61
# Comp:  2              HeII4687      0.000      0.86     -98    61
# Comp:  2               HeI5876      2.229      0.86     -98    61
# Comp:  2          [OIII]5007_d      11.83       1.1     -98    61
# Comp:  2            [OI]6300_d      3.454       1.1     -98    61
# Comp:  2           [NII]6583_d      10.39       1.1     -98    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -1         1
#  comp.  1:       -75        30
#  comp.  2:       -88        63
# chi2/DOF: 1.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.110      0.78     -75    30
# Comp:  1                 Hbeta      6.449      0.78     -75    30
# Comp:  1                Halpha      31.39      0.78     -75    30
# Comp:  2             [SII]6716      9.469      0.87     -88    63
# Comp:  2             [SII]6731      6.502      0.87     -88    63
# Comp:  2              HeII4687    0.06550      0.87     -88    63
# Comp:  2               HeI5876      2.609      0.87     -88    63
# Comp:  2          [OIII]5007_d      11.89       1.1     -88    63
# Comp:  2            [OI]6300_d      3.993       1.1     -88    63
# Comp:  2           [NII]6583_d      11.04       1.1     -88    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        47       102
#  comp.  1:       -77        31
#  comp.  2:       -94        64
# chi2/DOF: 1.019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.994      0.78     -77    31
# Comp:  1                 Hbeta      6.847      0.78     -77    31
# Comp:  1                Halpha      30.43      0.78     -77    31
# Comp:  2             [SII]6716      9.324      0.87     -94    64
# Comp:  2             [SII]6731      5.997      0.87     -94    64
# Comp:  2              HeII4687      0.000      0.87     -94    64
# Comp:  2               HeI5876      1.973      0.87     -94    64
# Comp:  2          [OIII]5007_d      12.07       1.1     -94    64
# Comp:  2            [OI]6300_d      4.203       1.1     -94    64
# Comp:  2           [NII]6583_d      10.77       1.1     -94    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        28         1
#  comp.  1:       -77        35
#  comp.  2:       -91        65
# chi2/DOF: 1.019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.453      0.79     -77    35
# Comp:  1                 Hbeta      6.606      0.79     -77    35
# Comp:  1                Halpha      30.96      0.79     -77    35
# Comp:  2             [SII]6716      9.744      0.88     -91    65
# Comp:  2             [SII]6731      6.215      0.88     -91    65
# Comp:  2              HeII4687      0.000      0.88     -91    65
# Comp:  2               HeI5876      1.996      0.88     -91    65
# Comp:  2          [OIII]5007_d      11.87       1.1     -91    65
# Comp:  2            [OI]6300_d      4.220       1.1     -91    65
# Comp:  2           [NII]6583_d      9.672       1.1     -91    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38         1
#  comp.  1:       -73        37
#  comp.  2:       -97        68
# chi2/DOF: 1.019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.113      0.79     -73    37
# Comp:  1                 Hbeta      6.797      0.79     -73    37
# Comp:  1                Halpha      32.67      0.79     -73    37
# Comp:  2             [SII]6716      9.776      0.89     -97    68
# Comp:  2             [SII]6731      6.559      0.89     -97    68
# Comp:  2              HeII4687      0.000      0.89     -97    68
# Comp:  2               HeI5876      1.817      0.89     -97    68
# Comp:  2          [OIII]5007_d      12.11       1.1     -97    68
# Comp:  2            [OI]6300_d      4.109       1.1     -97    68
# Comp:  2           [NII]6583_d      10.31       1.1     -97    68
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -6        61
#  comp.  1:       -74        35
#  comp.  2:       -93        61
# chi2/DOF: 1.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.202      0.79     -74    35
# Comp:  1                 Hbeta      6.108      0.79     -74    35
# Comp:  1                Halpha      30.50      0.79     -74    35
# Comp:  2             [SII]6716      9.118      0.86     -93    61
# Comp:  2             [SII]6731      5.993      0.86     -93    61
# Comp:  2              HeII4687     0.6641      0.86     -93    61
# Comp:  2               HeI5876      1.943      0.86     -93    61
# Comp:  2          [OIII]5007_d      12.17       1.1     -93    61
# Comp:  2            [OI]6300_d      5.198       1.1     -93    61
# Comp:  2           [NII]6583_d      9.693       1.1     -93    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        36
#  comp.  1:       -75        27
#  comp.  2:       -92        69
# chi2/DOF: 1.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.144      0.77     -75    27
# Comp:  1                 Hbeta      6.580      0.77     -75    27
# Comp:  1                Halpha      31.45      0.77     -75    27
# Comp:  2             [SII]6716      10.13      0.89     -92    69
# Comp:  2             [SII]6731      6.430      0.89     -92    69
# Comp:  2              HeII4687      0.000      0.89     -92    69
# Comp:  2               HeI5876      2.446      0.89     -92    69
# Comp:  2          [OIII]5007_d      12.13       1.1     -92    69
# Comp:  2            [OI]6300_d      3.627       1.1     -92    69
# Comp:  2           [NII]6583_d      10.93       1.1     -92    69
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23         1
#  comp.  1:       -78        35
#  comp.  2:       -95        63
# chi2/DOF: 1.024; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.434      0.79     -78    35
# Comp:  1                 Hbeta      5.947      0.79     -78    35
# Comp:  1                Halpha      31.38      0.79     -78    35
# Comp:  2             [SII]6716      9.330      0.87     -95    63
# Comp:  2             [SII]6731      5.950      0.87     -95    63
# Comp:  2              HeII4687      0.000      0.87     -95    63
# Comp:  2               HeI5876      2.288      0.87     -95    63
# Comp:  2          [OIII]5007_d      11.74       1.1     -95    63
# Comp:  2            [OI]6300_d      3.235       1.1     -95    63
# Comp:  2           [NII]6583_d      11.20       1.1     -95    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -4         1
#  comp.  1:       -75        42
#  comp.  2:       -92        63
# chi2/DOF: 1.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.615      0.80     -75    42
# Comp:  1                 Hbeta      7.500      0.80     -75    42
# Comp:  1                Halpha      32.33      0.80     -75    42
# Comp:  2             [SII]6716      9.635      0.87     -92    63
# Comp:  2             [SII]6731      6.586      0.87     -92    63
# Comp:  2              HeII4687      0.000      0.87     -92    63
# Comp:  2               HeI5876      2.797      0.87     -92    63
# Comp:  2          [OIII]5007_d      11.33       1.1     -92    63
# Comp:  2            [OI]6300_d      4.745       1.1     -92    63
# Comp:  2           [NII]6583_d      10.82       1.1     -92    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        45
#  comp.  1:       -74        35
#  comp.  2:       -92        62
# chi2/DOF: 1.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 21; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.389      0.79     -74    35
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40         1
#  comp.  1:       -75        41
#  comp.  2:       -91        63
# chi2/DOF: 1.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.687      0.80     -75    41
# Comp:  1                 Hbeta      6.455      0.80     -75    41
# Comp:  1                Halpha      31.40      0.80     -75    41
# Comp:  2             [SII]6716      9.579      0.87     -91    63
# Comp:  2             [SII]6731      5.938      0.87     -91    63
# Comp:  2              HeII4687      0.000      0.87     -91    63
# Comp:  2               HeI5876      1.824      0.87     -91    63
# Comp:  2          [OIII]5007_d      12.45       1.1     -91    63
# Comp:  2            [OI]6300_d      3.643       1.1     -91    63
# Comp:  2           [NII]6583_d      9.435       1.1     -91    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14        31
#  comp.  1:       -73        30
#  comp.  2:       -93        56
# chi2/DOF: 1.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.738      0.78     -73    30
# Comp:  1                 Hbeta      6.857      0.78     -73    30
# Comp:  1                Halpha      30.83      0.78     -73    30
# Comp:  2             [SII]6716      8.808      0.85     -93    56
# Comp:  2             [SII]6731      5.392      0.85     -93    56
# Comp:  2              HeII4687      0.000      0.85     -93    56
# Comp:  2               HeI5876      1.820      0.85     -93    56
# Comp:  2          [OIII]5007_d      11.74       1.1     -93    56
# Comp:  2            [OI]6300_d      2.918       1.1     -93    56
# Comp:  2           [NII]6583_d      9.753       1.1     -93    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7         1
#  comp.  1:       -74        46
#  comp.  2:       -92        66
# chi2/DOF: 1.023; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.062      0.82     -74    46
# Comp:  1                 Hbeta      6.804      0.82     -74    46
# Comp:  1                Halpha      32.74      0.82     -74    46
# Comp:  2             [SII]6716      10.05      0.88     -92    66
# Comp:  2             [SII]6731      5.945      0.88     -92    66
# Comp:  2              HeII4687     0.8892      0.88     -92    66
# Comp:  2               HeI5876      2.525      0.88     -92    66
# Comp:  2          [OIII]5007_d      11.76       1.1     -92    66
# Comp:  2            [OI]6300_d      4.226       1.1     -92    66
# Comp:  2           [NII]6583_d      11.46       1.1     -92    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -140       203
#  comp.  1:       -71        35
#  comp.  2:       -91        60
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.632      0.79     -71    35
# Comp:  1                 Hbeta      6.482      0.79     -71    35
# Comp:  1                Halpha      31.48      0.79     -71    35
# Comp:  2             [SII]6716      9.170      0.86     -91    60
# Comp:  2             [SII]6731      6.897      0.86     -91    60
# Comp:  2              HeII4687     0.6245      0.86     -91    60
# Comp:  2               HeI5876      1.388      0.86     -91    60
# Comp:  2          [OIII]5007_d      11.07       1.1     -91    60
# Comp:  2            [OI]6300_d      3.320       1.1     -91    60
# Comp:  2           [NII]6583_d      10.25       1.1     -91    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        14         1
#  comp.  1:       -71        39
#  comp.  2:       -91        65
# chi2/DOF: 1.021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.498      0.80     -71    39
# Comp:  1                 Hbeta      6.844      0.80     -71    39
# Comp:  1                Halpha      32.23      0.80     -71    39
# Comp:  2             [SII]6716      9.724      0.88     -91    65
# Comp:  2             [SII]6731      6.847      0.88     -91    65
# Comp:  2              HeII4687     0.9698      0.88     -91    65
# Comp:  2               HeI5876      2.119      0.88     -91    65
# Comp:  2          [OIII]5007_d      11.82       1.1     -91    65
# Comp:  2            [OI]6300_d      3.481       1.1     -91    65
# Comp:  2           [NII]6583_d      11.22       1.1     -91    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        12        25
#  comp.  1:       -75        43
#  comp.  2:       -97        61
# chi2/DOF: 1.022; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 26; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.818      0.81     -75    43
# Comp:  1                 Hbeta      6.525      0.81     -75    43
# Comp:  1                Halpha      33.02      0.81     -75    43
# Comp:  2             [SII]6716      9.100      0.86     -97    61
# Comp:  2             [SII]6731      5.472      0.86     -97    61
# Comp:  2              HeII4687      0.000      0.86     -97    61
# Comp:  2               HeI5876      2.201      0.86     -97    61
# Comp:  2          [OIII]5007_d      11.86       1.1     -97    61
# Comp:  2            [OI]6300_d      4.373       1.1     -97    61
# Comp:  2           [NII]6583_d      10.05       1.1     -97    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7         1
#  comp.  1:       -72        38
#  comp.  2:       -89        53
# chi2/DOF: 1.019; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.179      0.80     -72    38
# Comp:  1                 Hbeta      7.546      0.80     -72    38
# Comp:  1                Halpha      32.04      0.80     -72    38
# Comp:  2             [SII]6716      8.937      0.84     -89    53
# Comp:  2             [SII]6731      6.536      0.84     -89    53
# Comp:  2              HeII4687     0.4197      0.84     -89    53
# Comp:  2               HeI5876      1.814      0.84     -89    53
# Comp:  2          [OIII]5007_d      10.98       1.1     -89    53
# Comp:  2            [OI]6300_d      3.682       1.1     -89    53
# Comp:  2           [NII]6583_d      10.48       1.1     -89    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        58
#  comp.  1:       -74        35
#  comp.  2:       -92        61
# chi2/DOF: 1.021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 22; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.388      0.79     -74    35
# Comp:  1                 Hbeta      6.791      0.79     -74    35
# Comp:  1                Halpha      32.07      0.79     -74    35
# Comp:  2             [SII]6716      8.995      0.86     -92    61
# Comp:  2             [SII]6731      5.761      0.86     -92    61
# Comp:  2              HeII4687      0.000      0.86     -92    61
# Comp:  2               HeI5876      1.749      0.86     -92    61
# Comp:  2          [OIII]5007_d      12.18       1.1     -92    61
# Comp:  2            [OI]6300_d      3.376       1.1     -92    61
# Comp:  2           [NII]6583_d      11.15       1.1     -92    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        72        90
#  comp.  1:       -74        43
#  comp.  2:       -90        52
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.888      0.81     -74    43
# Comp:  1                 Hbeta      6.530      0.81     -74    43
# Comp:  1                Halpha      31.24      0.81     -74    43
# Comp:  2             [SII]6716      8.344      0.84     -90    52
# Comp:  2             [SII]6731      5.619      0.84     -90    52
# Comp:  2              HeII4687     0.8786      0.84     -90    52
# Comp:  2               HeI5876      2.059      0.84     -90    52
# Comp:  2          [OIII]5007_d      11.29       1.1     -90    52
# Comp:  2            [OI]6300_d      4.555       1.1     -90    52
# Comp:  2           [NII]6583_d      8.965       1.1     -90    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11         1
#  comp.  1:       -73        39
#  comp.  2:       -92        64
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.950      0.80     -73    39
# Comp:  1                 Hbeta      6.214      0.80     -73    39
# Comp:  1                Halpha      32.60      0.80     -73    39
# Comp:  2             [SII]6716      10.29      0.87     -92    64
# Comp:  2             [SII]6731      7.067      0.87     -92    64
# Comp:  2              HeII4687      0.000      0.87     -92    64
# Comp:  2               HeI5876      1.644      0.87     -92    64
# Comp:  2          [OIII]5007_d      11.68       1.1     -92    64
# Comp:  2            [OI]6300_d      4.014       1.1     -92    64
# Comp:  2           [NII]6583_d      10.54       1.1     -92    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        60        30
#  comp.  1:       -72        37
#  comp.  2:       -91        60
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.199      0.79     -72    37
# Comp:  1                 Hbeta      6.641      0.79     -72    37
# Comp:  1                Halpha      32.09      0.79     -72    37
# Comp:  2             [SII]6716      8.847      0.86     -91    60
# Comp:  2             [SII]6731      6.205      0.86     -91    60
# Comp:  2              HeII4687      0.000      0.86     -91    60
# Comp:  2               HeI5876      2.006      0.86     -91    60
# Comp:  2          [OIII]5007_d      12.22       1.1     -91    60
# Comp:  2            [OI]6300_d      4.515       1.1     -91    60
# Comp:  2           [NII]6583_d      11.03       1.1     -91    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         7         1
#  comp.  1:       -77        38
#  comp.  2:       -94        66
# chi2/DOF: 1.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.593      0.79     -77    38
# Comp:  1                 Hbeta      6.835      0.79     -77    38
# Comp:  1                Halpha      31.90      0.79     -77    38
# Comp:  2             [SII]6716      9.398      0.88     -94    66
# Comp:  2             [SII]6731      6.072      0.88     -94    66
# Comp:  2              HeII4687     0.8188      0.88     -94    66
# Comp:  2               HeI5876      2.026      0.88     -94    66
# Comp:  2          [OIII]5007_d      11.93       1.1     -94    66
# Comp:  2            [OI]6300_d      5.302       1.1     -94    66
# Comp:  2           [NII]6583_d      11.28       1.1     -94    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -2         1
#  comp.  1:       -74        31
#  comp.  2:       -95        60
# chi2/DOF: 1.021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.452      0.78     -74    31
# Comp:  1                 Hbeta      5.895      0.78     -74    31
# Comp:  1                Halpha      31.27      0.78     -74    31
# Comp:  2             [SII]6716      9.328      0.86     -95    60
# Comp:  2             [SII]6731      5.799      0.86     -95    60
# Comp:  2              HeII4687     0.3533      0.86     -95    60
# Comp:  2               HeI5876      1.568      0.86     -95    60
# Comp:  2          [OIII]5007_d      12.15       1.1     -95    60
# Comp:  2            [OI]6300_d      3.989       1.1     -95    60
# Comp:  2           [NII]6583_d      11.12       1.1     -95    60
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.64128824, 0.55196331, 1.06645156, 0.68792928, 0.603803  ,
#        0.42578443, 0.42925142, 0.46001233, 0.71641382, 0.78980381])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 4.15585526,  6.5550064 , 42.92259444, 13.04655158,  8.60449186,
#         0.        ,  2.5980736 , 12.32278573,  5.2341943 , 14.10599784])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_3_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_3", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_3_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_3_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_3_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0        Hgamma  0.067304    0.010386
# 1         Hbeta  0.106159    0.008939
# 2        Halpha  0.695134    0.017271
# 3     [SII]6716  0.211290    0.011141
# 4     [SII]6731  0.139350    0.009779
# 5      HeII4687  0.000000    0.006896
# 6       HeI5876  0.042076    0.006952
# 7  [OIII]5007_d  0.199568    0.007450
# 8    [OI]6300_d  0.084768    0.011602
# 9   [NII]6583_d  0.228447    0.012791
#           Name      Flux  Error_flux
# 0       Hgamma  0.067304    0.010386
# 1        Hbeta  0.106159    0.008939
# 2       Halpha  0.695134    0.017271
# 3    [SII]6716  0.211290    0.011141
# 4    [SII]6731  0.139350    0.009779
# 5     HeII4687  0.000000    0.006896
# 6      HeI5876  0.042076    0.006952
# 7   [OIII]4959  0.049892    0.007450
# 8   [OIII]5007  0.149676    0.007450
# 9     [OI]6300  0.063576    0.011602
# 10    [OI]6364  0.021192    0.011602
# 11   [NII]6548  0.057112    0.012791
# 12   [NII]6583  0.171336    0.012791

# %%
np.median(flux_rf_rebin)
# Out:
# 0.016195057332376042
