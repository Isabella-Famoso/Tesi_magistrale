# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_6.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_6']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4314.03901503 4315.47324864 4316.90748224 ... 6874.1460011  6875.58023471
#  6877.01446832] [0.50047335 0.46657613 0.48911412 ... 0.20828503 0.21165919 0.21779016] [0.0206382 0.0206382 0.0206382 ... 0.0206382 0.0206382 0.0206382]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -72        68
# chi2/DOF: 0.001276; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        53
# chi2/DOF: 0.0008468; DOF: 1864; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-76.07209677,  52.72736529])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -146         1
#  comp.  1:       -86        38
#  comp.  2:       -81        58
# chi2/DOF: 1.500; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.621      0.12     -86    38
# Comp:  1                 Hbeta      14.91      0.12     -86    38
# Comp:  1                Halpha      43.78      0.12     -86    38
# Comp:  2             [SII]6716      6.355      0.13     -81    58
# Comp:  2             [SII]6731      4.761      0.13     -81    58
# Comp:  2              HeII4687     0.1589      0.13     -81    58
# Comp:  2               HeI5876      1.675      0.13     -81    58
# Comp:  2          [OIII]5007_d      18.10      0.17     -81    58
# Comp:  2            [OI]6300_d      1.096      0.17     -81    58
# Comp:  2           [NII]6583_d      13.60      0.17     -81    58
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  60.64; gas flux:      6 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  130.1; gas flux:     15 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  385.7; gas flux:     60 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  49.01; gas flux:      9 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  37.23; gas flux:      7 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:  1.263; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  13.38; gas flux:      2 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  109.5; gas flux:     19 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  6.532; gas flux:      1 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  77.79; gas flux:     19 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -142         1
#  comp.  1:       -84        33
#  comp.  2:       -84        59
# chi2/DOF: 1.262; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.189      0.12     -84    33
# Comp:  1                 Hbeta      11.98      0.12     -84    33
# Comp:  1                Halpha      42.97      0.12     -84    33
# Comp:  2             [SII]6716      6.612      0.13     -84    59
# Comp:  2             [SII]6731      4.726      0.13     -84    59
# Comp:  2              HeII4687    0.07036      0.13     -84    59
# Comp:  2               HeI5876      1.753      0.13     -84    59
# Comp:  2          [OIII]5007_d      19.58      0.17     -84    59
# Comp:  2            [OI]6300_d      1.130      0.17     -84    59
# Comp:  2           [NII]6583_d      13.74      0.17     -84    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -138         1
#  comp.  1:       -84        32
#  comp.  2:       -80        50
# chi2/DOF: 1.424; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.010      0.12     -84    32
# Comp:  1                 Hbeta      14.68      0.12     -84    32
# Comp:  1                Halpha      42.71      0.12     -84    32
# Comp:  2             [SII]6716      6.080      0.13     -80    50
# Comp:  2             [SII]6731      5.034      0.13     -80    50
# Comp:  2              HeII4687    0.06734      0.13     -80    50
# Comp:  2               HeI5876      1.652      0.13     -80    50
# Comp:  2          [OIII]5007_d      17.33      0.16     -80    50
# Comp:  2            [OI]6300_d      1.042      0.16     -80    50
# Comp:  2           [NII]6583_d      13.16      0.16     -80    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -141         1
#  comp.  1:       -84        32
#  comp.  2:       -80        49
# chi2/DOF: 1.241; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.364      0.12     -84    32
# Comp:  1                 Hbeta      13.35      0.12     -84    32
# Comp:  1                Halpha      42.96      0.12     -84    32
# Comp:  2             [SII]6716      5.730      0.13     -80    49
# Comp:  2             [SII]6731      4.751      0.13     -80    49
# Comp:  2              HeII4687     0.1076      0.13     -80    49
# Comp:  2               HeI5876      1.824      0.13     -80    49
# Comp:  2          [OIII]5007_d      17.78      0.16     -80    49
# Comp:  2            [OI]6300_d      1.134      0.16     -80    49
# Comp:  2           [NII]6583_d      13.76      0.16     -80    49
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -156         1
#  comp.  1:       -87        36
#  comp.  2:       -84        63
# chi2/DOF: 1.373; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.328      0.12     -87    36
# Comp:  1                 Hbeta      13.18      0.12     -87    36
# Comp:  1                Halpha      43.63      0.12     -87    36
# Comp:  2             [SII]6716      6.192      0.13     -84    63
# Comp:  2             [SII]6731      4.962      0.13     -84    63
# Comp:  2              HeII4687     0.1211      0.13     -84    63
# Comp:  2               HeI5876      1.947      0.13     -84    63
# Comp:  2          [OIII]5007_d      18.87      0.17     -84    63
# Comp:  2            [OI]6300_d      1.256      0.17     -84    63
# Comp:  2           [NII]6583_d      13.95      0.17     -84    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -127         1
#  comp.  1:       -84        37
#  comp.  2:       -80        51
# chi2/DOF: 1.358; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.095      0.12     -84    37
# Comp:  1                 Hbeta      13.81      0.12     -84    37
# Comp:  1                Halpha      43.32      0.12     -84    37
# Comp:  2             [SII]6716      5.853      0.13     -80    51
# Comp:  2             [SII]6731      4.998      0.13     -80    51
# Comp:  2              HeII4687     0.2368      0.13     -80    51
# Comp:  2               HeI5876      1.503      0.13     -80    51
# Comp:  2          [OIII]5007_d      18.79      0.16     -80    51
# Comp:  2            [OI]6300_d      1.056      0.16     -80    51
# Comp:  2           [NII]6583_d      13.39      0.16     -80    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -143         1
#  comp.  1:       -87        40
#  comp.  2:       -84        56
# chi2/DOF: 1.212; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.038      0.12     -87    40
# Comp:  1                 Hbeta      12.50      0.12     -87    40
# Comp:  1                Halpha      44.39      0.12     -87    40
# Comp:  2             [SII]6716      5.920      0.13     -84    56
# Comp:  2             [SII]6731      4.971      0.13     -84    56
# Comp:  2              HeII4687     0.1958      0.13     -84    56
# Comp:  2               HeI5876      1.647      0.13     -84    56
# Comp:  2          [OIII]5007_d      18.54      0.17     -84    56
# Comp:  2            [OI]6300_d      1.075      0.17     -84    56
# Comp:  2           [NII]6583_d      14.12      0.17     -84    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -170        32
#  comp.  1:       -87        41
#  comp.  2:       -80        62
# chi2/DOF: 1.431; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.062      0.12     -87    41
# Comp:  1                 Hbeta      15.34      0.12     -87    41
# Comp:  1                Halpha      44.44      0.12     -87    41
# Comp:  2             [SII]6716      6.790      0.13     -80    62
# Comp:  2             [SII]6731      4.761      0.13     -80    62
# Comp:  2              HeII4687     0.2201      0.13     -80    62
# Comp:  2               HeI5876      1.593      0.13     -80    62
# Comp:  2          [OIII]5007_d      18.73      0.17     -80    62
# Comp:  2            [OI]6300_d      1.143      0.17     -80    62
# Comp:  2           [NII]6583_d      14.52      0.17     -80    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -147         3
#  comp.  1:       -88        35
#  comp.  2:       -78        50
# chi2/DOF: 1.237; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 39; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.984      0.12     -88    35
# Comp:  1                 Hbeta      12.48      0.12     -88    35
# Comp:  1                Halpha      43.65      0.12     -88    35
# Comp:  2             [SII]6716      6.219      0.13     -78    50
# Comp:  2             [SII]6731      4.882      0.13     -78    50
# Comp:  2              HeII4687    0.05006      0.13     -78    50
# Comp:  2               HeI5876      1.599      0.13     -78    50
# Comp:  2          [OIII]5007_d      18.74      0.16     -78    50
# Comp:  2            [OI]6300_d      1.019      0.16     -78    50
# Comp:  2           [NII]6583_d      12.53      0.16     -78    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        90
#  comp.  1:       -86        36
#  comp.  2:       -82        53
# chi2/DOF: 1.232; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.432      0.12     -86    36
# Comp:  1                 Hbeta      14.03      0.12     -86    36
# Comp:  1                Halpha      44.14      0.12     -86    36
# Comp:  2             [SII]6716      6.329      0.13     -82    53
# Comp:  2             [SII]6731      4.589      0.13     -82    53
# Comp:  2              HeII4687    0.09961      0.13     -82    53
# Comp:  2               HeI5876      1.572      0.13     -82    53
# Comp:  2          [OIII]5007_d      16.66      0.16     -82    53
# Comp:  2            [OI]6300_d      1.110      0.16     -82    53
# Comp:  2           [NII]6583_d      12.67      0.16     -82    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -114        68
#  comp.  1:       -85        43
#  comp.  2:       -84        53
# chi2/DOF: 1.364; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.295      0.12     -85    43
# Comp:  1                 Hbeta      16.94      0.12     -85    43
# Comp:  1                Halpha      44.85      0.12     -85    43
# Comp:  2             [SII]6716      6.248      0.13     -84    53
# Comp:  2             [SII]6731      4.677      0.13     -84    53
# Comp:  2              HeII4687     0.1441      0.13     -84    53
# Comp:  2               HeI5876      1.814      0.13     -84    53
# Comp:  2          [OIII]5007_d      18.14      0.16     -84    53
# Comp:  2            [OI]6300_d      1.107      0.16     -84    53
# Comp:  2           [NII]6583_d      13.46      0.16     -84    53
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        91
#  comp.  1:       -85        32
#  comp.  2:       -79        56
# chi2/DOF: 1.127; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.392      0.12     -85    32
# Comp:  1                 Hbeta      16.49      0.12     -85    32
# Comp:  1                Halpha      42.51      0.12     -85    32
# Comp:  2             [SII]6716      6.382      0.13     -79    56
# Comp:  2             [SII]6731      4.653      0.13     -79    56
# Comp:  2              HeII4687     0.2157      0.13     -79    56
# Comp:  2               HeI5876      1.542      0.13     -79    56
# Comp:  2          [OIII]5007_d      16.37      0.16     -79    56
# Comp:  2            [OI]6300_d      1.166      0.16     -79    56
# Comp:  2           [NII]6583_d      13.75      0.16     -79    56
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -157        45
#  comp.  1:       -88        39
#  comp.  2:       -85        54
# chi2/DOF: 1.343; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.554      0.12     -88    39
# Comp:  1                 Hbeta      16.34      0.12     -88    39
# Comp:  1                Halpha      44.07      0.12     -88    39
# Comp:  2             [SII]6716      6.637      0.13     -85    54
# Comp:  2             [SII]6731      4.753      0.13     -85    54
# Comp:  2              HeII4687    0.07261      0.13     -85    54
# Comp:  2               HeI5876      1.671      0.13     -85    54
# Comp:  2          [OIII]5007_d      18.26      0.16     -85    54
# Comp:  2            [OI]6300_d      1.053      0.16     -85    54
# Comp:  2           [NII]6583_d      12.80      0.16     -85    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -140        47
#  comp.  1:       -87        39
#  comp.  2:       -83        54
# chi2/DOF: 1.282; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.910      0.12     -87    39
# Comp:  1                 Hbeta      13.00      0.12     -87    39
# Comp:  1                Halpha      43.63      0.12     -87    39
# Comp:  2             [SII]6716      6.302      0.13     -83    54
# Comp:  2             [SII]6731      4.178      0.13     -83    54
# Comp:  2              HeII4687     0.2154      0.13     -83    54
# Comp:  2               HeI5876      1.503      0.13     -83    54
# Comp:  2          [OIII]5007_d      16.67      0.16     -83    54
# Comp:  2            [OI]6300_d      1.061      0.16     -83    54
# Comp:  2           [NII]6583_d      13.21      0.16     -83    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -151         1
#  comp.  1:       -85        45
#  comp.  2:       -83        60
# chi2/DOF: 1.353; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.325      0.13     -85    45
# Comp:  1                 Hbeta      14.63      0.13     -85    45
# Comp:  1                Halpha      45.54      0.13     -85    45
# Comp:  2             [SII]6716      6.527      0.13     -83    60
# Comp:  2             [SII]6731      5.421      0.13     -83    60
# Comp:  2              HeII4687     0.1519      0.13     -83    60
# Comp:  2               HeI5876      1.635      0.13     -83    60
# Comp:  2          [OIII]5007_d      17.22      0.17     -83    60
# Comp:  2            [OI]6300_d      1.056      0.17     -83    60
# Comp:  2           [NII]6583_d      13.54      0.17     -83    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80        77
#  comp.  1:       -87        32
#  comp.  2:       -85        58
# chi2/DOF: 1.204; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.052      0.12     -87    32
# Comp:  1                 Hbeta      13.76      0.12     -87    32
# Comp:  1                Halpha      43.14      0.12     -87    32
# Comp:  2             [SII]6716      6.672      0.13     -85    58
# Comp:  2             [SII]6731      4.589      0.13     -85    58
# Comp:  2              HeII4687     0.2090      0.13     -85    58
# Comp:  2               HeI5876      1.966      0.13     -85    58
# Comp:  2          [OIII]5007_d      19.36      0.17     -85    58
# Comp:  2            [OI]6300_d      1.061      0.17     -85    58
# Comp:  2           [NII]6583_d      13.48      0.17     -85    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -154        45
#  comp.  1:       -87        41
#  comp.  2:       -75        63
# chi2/DOF: 1.176; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.128      0.12     -87    41
# Comp:  1                 Hbeta      12.14      0.12     -87    41
# Comp:  1                Halpha      43.87      0.12     -87    41
# Comp:  2             [SII]6716      6.520      0.13     -75    63
# Comp:  2             [SII]6731      4.660      0.13     -75    63
# Comp:  2              HeII4687     0.2184      0.13     -75    63
# Comp:  2               HeI5876      1.971      0.13     -75    63
# Comp:  2          [OIII]5007_d      17.32      0.17     -75    63
# Comp:  2            [OI]6300_d      1.165      0.17     -75    63
# Comp:  2           [NII]6583_d      13.68      0.17     -75    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -135        29
#  comp.  1:       -86        30
#  comp.  2:       -79        63
# chi2/DOF: 1.138; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.719      0.12     -86    30
# Comp:  1                 Hbeta      11.91      0.12     -86    30
# Comp:  1                Halpha      42.12      0.12     -86    30
# Comp:  2             [SII]6716      6.175      0.13     -79    63
# Comp:  2             [SII]6731      5.318      0.13     -79    63
# Comp:  2              HeII4687     0.1329      0.13     -79    63
# Comp:  2               HeI5876      1.877      0.13     -79    63
# Comp:  2          [OIII]5007_d      17.60      0.17     -79    63
# Comp:  2            [OI]6300_d      1.234      0.17     -79    63
# Comp:  2           [NII]6583_d      13.72      0.17     -79    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -51        96
#  comp.  1:       -84        44
#  comp.  2:       -79        67
# chi2/DOF: 1.152; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 62; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.265      0.13     -84    44
# Comp:  1                 Hbeta      13.06      0.13     -84    44
# Comp:  1                Halpha      45.17      0.13     -84    44
# Comp:  2             [SII]6716      6.666      0.14     -79    67
# Comp:  2             [SII]6731      4.937      0.14     -79    67
# Comp:  2              HeII4687    0.07059      0.14     -79    67
# Comp:  2               HeI5876      1.988      0.14     -79    67
# Comp:  2          [OIII]5007_d      17.87      0.17     -79    67
# Comp:  2            [OI]6300_d      1.106      0.17     -79    67
# Comp:  2           [NII]6583_d      14.52      0.17     -79    67
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -161        20
#  comp.  1:       -86        32
#  comp.  2:       -74        57
# chi2/DOF: 1.356; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 42; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.130      0.12     -86    32
# Comp:  1                 Hbeta      14.15      0.12     -86    32
# Comp:  1                Halpha      41.70      0.12     -86    32
# Comp:  2             [SII]6716      6.416      0.13     -74    57
# Comp:  2             [SII]6731      4.575      0.13     -74    57
# Comp:  2              HeII4687     0.1107      0.13     -74    57
# Comp:  2               HeI5876      1.622      0.13     -74    57
# Comp:  2          [OIII]5007_d      18.51      0.17     -74    57
# Comp:  2            [OI]6300_d      1.143      0.17     -74    57
# Comp:  2           [NII]6583_d      13.66      0.17     -74    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -143         1
#  comp.  1:       -87        28
#  comp.  2:       -82        64
# chi2/DOF: 1.245; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.057      0.12     -87    28
# Comp:  1                 Hbeta      15.41      0.12     -87    28
# Comp:  1                Halpha      41.63      0.12     -87    28
# Comp:  2             [SII]6716      6.743      0.13     -82    64
# Comp:  2             [SII]6731      5.156      0.13     -82    64
# Comp:  2              HeII4687     0.2832      0.13     -82    64
# Comp:  2               HeI5876      1.724      0.13     -82    64
# Comp:  2          [OIII]5007_d      20.26      0.17     -82    64
# Comp:  2            [OI]6300_d      1.179      0.17     -82    64
# Comp:  2           [NII]6583_d      13.13      0.17     -82    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -142         1
#  comp.  1:       -88        35
#  comp.  2:       -80        61
# chi2/DOF: 1.375; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.831      0.12     -88    35
# Comp:  1                 Hbeta      16.33      0.12     -88    35
# Comp:  1                Halpha      43.44      0.12     -88    35
# Comp:  2             [SII]6716      6.067      0.13     -80    61
# Comp:  2             [SII]6731      5.256      0.13     -80    61
# Comp:  2              HeII4687     0.2498      0.13     -80    61
# Comp:  2               HeI5876      1.966      0.13     -80    61
# Comp:  2          [OIII]5007_d      18.34      0.17     -80    61
# Comp:  2            [OI]6300_d      1.013      0.17     -80    61
# Comp:  2           [NII]6583_d      12.93      0.17     -80    61
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -137         1
#  comp.  1:       -86        36
#  comp.  2:       -85        57
# chi2/DOF: 1.383; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.806      0.12     -86    36
# Comp:  1                 Hbeta      13.08      0.12     -86    36
# Comp:  1                Halpha      43.43      0.12     -86    36
# Comp:  2             [SII]6716      6.393      0.13     -85    57
# Comp:  2             [SII]6731      4.792      0.13     -85    57
# Comp:  2              HeII4687     0.1553      0.13     -85    57
# Comp:  2               HeI5876      1.557      0.13     -85    57
# Comp:  2          [OIII]5007_d      18.46      0.17     -85    57
# Comp:  2            [OI]6300_d      1.096      0.17     -85    57
# Comp:  2           [NII]6583_d      13.65      0.17     -85    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -167         1
#  comp.  1:       -86        43
#  comp.  2:       -75        51
# chi2/DOF: 1.270; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.723      0.12     -86    43
# Comp:  1                 Hbeta      17.08      0.12     -86    43
# Comp:  1                Halpha      45.25      0.12     -86    43
# Comp:  2             [SII]6716      6.162      0.13     -75    51
# Comp:  2             [SII]6731      4.371      0.13     -75    51
# Comp:  2              HeII4687    0.07392      0.13     -75    51
# Comp:  2               HeI5876      1.761      0.13     -75    51
# Comp:  2          [OIII]5007_d      18.14      0.16     -75    51
# Comp:  2            [OI]6300_d      1.033      0.16     -75    51
# Comp:  2           [NII]6583_d      12.65      0.16     -75    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -140         1
#  comp.  1:       -87        30
#  comp.  2:       -81        57
# chi2/DOF: 1.286; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.801      0.12     -87    30
# Comp:  1                 Hbeta      16.00      0.12     -87    30
# Comp:  1                Halpha      42.06      0.12     -87    30
# Comp:  2             [SII]6716      6.663      0.13     -81    57
# Comp:  2             [SII]6731      5.040      0.13     -81    57
# Comp:  2              HeII4687     0.1671      0.13     -81    57
# Comp:  2               HeI5876      1.720      0.13     -81    57
# Comp:  2          [OIII]5007_d      17.55      0.17     -81    57
# Comp:  2            [OI]6300_d      1.006      0.17     -81    57
# Comp:  2           [NII]6583_d      12.92      0.17     -81    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -137        16
#  comp.  1:       -88        33
#  comp.  2:       -84        58
# chi2/DOF: 1.278; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.223      0.12     -88    33
# Comp:  1                 Hbeta      13.54      0.12     -88    33
# Comp:  1                Halpha      43.03      0.12     -88    33
# Comp:  2             [SII]6716      6.680      0.13     -84    58
# Comp:  2             [SII]6731      4.600      0.13     -84    58
# Comp:  2              HeII4687     0.1649      0.13     -84    58
# Comp:  2               HeI5876      1.437      0.13     -84    58
# Comp:  2          [OIII]5007_d      19.26      0.17     -84    58
# Comp:  2            [OI]6300_d      1.104      0.17     -84    58
# Comp:  2           [NII]6583_d      13.86      0.17     -84    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -42        89
#  comp.  1:       -87        32
#  comp.  2:       -81        50
# chi2/DOF: 1.155; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.207      0.12     -87    32
# Comp:  1                 Hbeta      13.99      0.12     -87    32
# Comp:  1                Halpha      43.50      0.12     -87    32
# Comp:  2             [SII]6716      6.368      0.13     -81    50
# Comp:  2             [SII]6731      4.682      0.13     -81    50
# Comp:  2              HeII4687     0.2060      0.13     -81    50
# Comp:  2               HeI5876      1.776      0.13     -81    50
# Comp:  2          [OIII]5007_d      17.51      0.16     -81    50
# Comp:  2            [OI]6300_d     0.9928      0.16     -81    50
# Comp:  2           [NII]6583_d      12.45      0.16     -81    50
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -169        60
#  comp.  1:       -85        45
#  comp.  2:       -86        63
# chi2/DOF: 1.205; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 58; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.020      0.13     -85    45
# Comp:  1                 Hbeta      12.72      0.13     -85    45
# Comp:  1                Halpha      45.30      0.13     -85    45
# Comp:  2             [SII]6716      6.162      0.13     -86    63
# Comp:  2             [SII]6731      5.273      0.13     -86    63
# Comp:  2              HeII4687     0.1927      0.13     -86    63
# Comp:  2               HeI5876      1.746      0.13     -86    63
# Comp:  2          [OIII]5007_d      17.53      0.17     -86    63
# Comp:  2            [OI]6300_d      1.122      0.17     -86    63
# Comp:  2           [NII]6583_d      13.83      0.17     -86    63
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        74
#  comp.  1:       -88        38
#  comp.  2:       -81        65
# chi2/DOF: 1.121; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.878      0.12     -88    38
# Comp:  1                 Hbeta      15.57      0.12     -88    38
# Comp:  1                Halpha      44.18      0.12     -88    38
# Comp:  2             [SII]6716      6.274      0.14     -81    65
# Comp:  2             [SII]6731      5.262      0.14     -81    65
# Comp:  2              HeII4687     0.1344      0.14     -81    65
# Comp:  2               HeI5876      1.750      0.14     -81    65
# Comp:  2          [OIII]5007_d      17.30      0.17     -81    65
# Comp:  2            [OI]6300_d      1.232      0.17     -81    65
# Comp:  2           [NII]6583_d      13.58      0.17     -81    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -166         1
#  comp.  1:       -86        40
#  comp.  2:       -79        64
# chi2/DOF: 1.324; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.973      0.12     -86    40
# Comp:  1                 Hbeta      16.01      0.12     -86    40
# Comp:  1                Halpha      44.21      0.12     -86    40
# Comp:  2             [SII]6716      6.546      0.13     -79    64
# Comp:  2             [SII]6731      4.460      0.13     -79    64
# Comp:  2              HeII4687    0.04361      0.13     -79    64
# Comp:  2               HeI5876      1.414      0.13     -79    64
# Comp:  2          [OIII]5007_d      17.02      0.17     -79    64
# Comp:  2            [OI]6300_d      1.154      0.17     -79    64
# Comp:  2           [NII]6583_d      14.18      0.17     -79    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -108        76
#  comp.  1:       -86        40
#  comp.  2:       -76        62
# chi2/DOF: 1.326; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.753      0.12     -86    40
# Comp:  1                 Hbeta      16.41      0.12     -86    40
# Comp:  1                Halpha      45.08      0.12     -86    40
# Comp:  2             [SII]6716      6.477      0.13     -76    62
# Comp:  2             [SII]6731      4.834      0.13     -76    62
# Comp:  2              HeII4687     0.1239      0.13     -76    62
# Comp:  2               HeI5876      1.505      0.13     -76    62
# Comp:  2          [OIII]5007_d      17.75      0.17     -76    62
# Comp:  2            [OI]6300_d      1.130      0.17     -76    62
# Comp:  2           [NII]6583_d      13.75      0.17     -76    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83        68
#  comp.  1:       -83        35
#  comp.  2:       -82        51
# chi2/DOF: 1.155; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.339      0.12     -83    35
# Comp:  1                 Hbeta      13.72      0.12     -83    35
# Comp:  1                Halpha      43.18      0.12     -83    35
# Comp:  2             [SII]6716      6.222      0.13     -82    51
# Comp:  2             [SII]6731      4.830      0.13     -82    51
# Comp:  2              HeII4687      0.000      0.13     -82    51
# Comp:  2               HeI5876      1.646      0.13     -82    51
# Comp:  2          [OIII]5007_d      19.23      0.16     -82    51
# Comp:  2            [OI]6300_d      1.037      0.16     -82    51
# Comp:  2           [NII]6583_d      13.38      0.16     -82    51
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -177        19
#  comp.  1:       -87        37
#  comp.  2:       -77        59
# chi2/DOF: 1.344; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.817      0.12     -87    37
# Comp:  1                 Hbeta      15.75      0.12     -87    37
# Comp:  1                Halpha      43.47      0.12     -87    37
# Comp:  2             [SII]6716      6.110      0.13     -77    59
# Comp:  2             [SII]6731      5.004      0.13     -77    59
# Comp:  2              HeII4687     0.2881      0.13     -77    59
# Comp:  2               HeI5876      1.827      0.13     -77    59
# Comp:  2          [OIII]5007_d      17.87      0.17     -77    59
# Comp:  2            [OI]6300_d      1.162      0.17     -77    59
# Comp:  2           [NII]6583_d      14.29      0.17     -77    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71        94
#  comp.  1:       -86        37
#  comp.  2:       -85        48
# chi2/DOF: 0.9865; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 61; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.353      0.12     -86    37
# Comp:  1                 Hbeta      12.77      0.12     -86    37
# Comp:  1                Halpha      44.18      0.12     -86    37
# Comp:  2             [SII]6716      6.174      0.13     -85    48
# Comp:  2             [SII]6731      4.398      0.13     -85    48
# Comp:  2              HeII4687    0.09740      0.13     -85    48
# Comp:  2               HeI5876      1.533      0.13     -85    48
# Comp:  2          [OIII]5007_d      17.98      0.16     -85    48
# Comp:  2            [OI]6300_d      1.016      0.16     -85    48
# Comp:  2           [NII]6583_d      13.51      0.16     -85    48
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -166         1
#  comp.  1:       -86        39
#  comp.  2:       -81        66
# chi2/DOF: 1.373; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.333      0.12     -86    39
# Comp:  1                 Hbeta      13.42      0.12     -86    39
# Comp:  1                Halpha      44.17      0.12     -86    39
# Comp:  2             [SII]6716      6.593      0.14     -81    66
# Comp:  2             [SII]6731      5.051      0.14     -81    66
# Comp:  2              HeII4687     0.1819      0.14     -81    66
# Comp:  2               HeI5876      1.589      0.14     -81    66
# Comp:  2          [OIII]5007_d      17.71      0.17     -81    66
# Comp:  2            [OI]6300_d      1.121      0.17     -81    66
# Comp:  2           [NII]6583_d      14.14      0.17     -81    66
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -109        58
#  comp.  1:       -85        42
#  comp.  2:       -81        64
# chi2/DOF: 1.358; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.875      0.12     -85    42
# Comp:  1                 Hbeta      14.07      0.12     -85    42
# Comp:  1                Halpha      44.42      0.12     -85    42
# Comp:  2             [SII]6716      6.494      0.13     -81    64
# Comp:  2             [SII]6731      5.139      0.13     -81    64
# Comp:  2              HeII4687     0.1138      0.13     -81    64
# Comp:  2               HeI5876      1.625      0.13     -81    64
# Comp:  2          [OIII]5007_d      17.36      0.17     -81    64
# Comp:  2            [OI]6300_d      1.097      0.17     -81    64
# Comp:  2           [NII]6583_d      14.70      0.17     -81    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -169         1
#  comp.  1:       -86        38
#  comp.  2:       -82        62
# chi2/DOF: 1.442; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.889      0.12     -86    38
# Comp:  1                 Hbeta      14.75      0.12     -86    38
# Comp:  1                Halpha      43.94      0.12     -86    38
# Comp:  2             [SII]6716      6.560      0.13     -82    62
# Comp:  2             [SII]6731      4.956      0.13     -82    62
# Comp:  2              HeII4687     0.1929      0.13     -82    62
# Comp:  2               HeI5876      1.636      0.13     -82    62
# Comp:  2          [OIII]5007_d      19.27      0.17     -82    62
# Comp:  2            [OI]6300_d      1.194      0.17     -82    62
# Comp:  2           [NII]6583_d      13.79      0.17     -82    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -145         1
#  comp.  1:       -87        36
#  comp.  2:       -77        55
# chi2/DOF: 1.328; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.236      0.12     -87    36
# Comp:  1                 Hbeta      13.08      0.12     -87    36
# Comp:  1                Halpha      43.13      0.12     -87    36
# Comp:  2             [SII]6716      6.234      0.13     -77    55
# Comp:  2             [SII]6731      4.583      0.13     -77    55
# Comp:  2              HeII4687    0.07794      0.13     -77    55
# Comp:  2               HeI5876      1.700      0.13     -77    55
# Comp:  2          [OIII]5007_d      19.00      0.16     -77    55
# Comp:  2            [OI]6300_d      1.030      0.16     -77    55
# Comp:  2           [NII]6583_d      13.02      0.16     -77    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -134         1
#  comp.  1:       -84        32
#  comp.  2:       -85        57
# chi2/DOF: 1.343; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.283      0.12     -84    32
# Comp:  1                 Hbeta      14.55      0.12     -84    32
# Comp:  1                Halpha      42.35      0.12     -84    32
# Comp:  2             [SII]6716      6.629      0.13     -85    57
# Comp:  2             [SII]6731      4.645      0.13     -85    57
# Comp:  2              HeII4687     0.1080      0.13     -85    57
# Comp:  2               HeI5876      1.682      0.13     -85    57
# Comp:  2          [OIII]5007_d      17.32      0.17     -85    57
# Comp:  2            [OI]6300_d      1.049      0.17     -85    57
# Comp:  2           [NII]6583_d      13.28      0.17     -85    57
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -104       109
#  comp.  1:       -84        38
#  comp.  2:       -82        60
# chi2/DOF: 1.358; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.887      0.12     -84    38
# Comp:  1                 Hbeta      14.47      0.12     -84    38
# Comp:  1                Halpha      43.68      0.12     -84    38
# Comp:  2             [SII]6716      6.281      0.13     -82    60
# Comp:  2             [SII]6731      5.250      0.13     -82    60
# Comp:  2              HeII4687     0.2381      0.13     -82    60
# Comp:  2               HeI5876      1.936      0.13     -82    60
# Comp:  2          [OIII]5007_d      17.18      0.17     -82    60
# Comp:  2            [OI]6300_d      1.203      0.17     -82    60
# Comp:  2           [NII]6583_d      13.28      0.17     -82    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80        80
#  comp.  1:       -84        42
#  comp.  2:       -82        48
# chi2/DOF: 1.249; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 61; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.991      0.12     -84    42
# ...
# Comp:  2           [NII]6583_d      13.93      0.17     -81    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -135        43
#  comp.  1:       -86        39
#  comp.  2:       -73        58
# chi2/DOF: 1.269; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.853      0.12     -86    39
# Comp:  1                 Hbeta      17.14      0.12     -86    39
# Comp:  1                Halpha      44.19      0.12     -86    39
# Comp:  2             [SII]6716      6.469      0.13     -73    58
# Comp:  2             [SII]6731      4.323      0.13     -73    58
# Comp:  2              HeII4687     0.1572      0.13     -73    58
# Comp:  2               HeI5876      1.740      0.13     -73    58
# Comp:  2          [OIII]5007_d      18.55      0.17     -73    58
# Comp:  2            [OI]6300_d      1.092      0.17     -73    58
# Comp:  2           [NII]6583_d      13.58      0.17     -73    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -121        48
#  comp.  1:       -86        37
#  comp.  2:       -76        60
# chi2/DOF: 1.219; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.727      0.12     -86    37
# Comp:  1                 Hbeta      17.88      0.12     -86    37
# Comp:  1                Halpha      43.95      0.12     -86    37
# Comp:  2             [SII]6716      6.541      0.13     -76    60
# Comp:  2             [SII]6731      4.759      0.13     -76    60
# Comp:  2              HeII4687     0.1607      0.13     -76    60
# Comp:  2               HeI5876      1.433      0.13     -76    60
# Comp:  2          [OIII]5007_d      19.90      0.17     -76    60
# Comp:  2            [OI]6300_d      1.100      0.17     -76    60
# Comp:  2           [NII]6583_d      14.27      0.17     -76    60
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -124         1
#  comp.  1:       -86        32
#  comp.  2:       -85        45
# chi2/DOF: 1.128; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.756      0.12     -86    32
# Comp:  1                 Hbeta      12.00      0.12     -86    32
# Comp:  1                Halpha      41.76      0.12     -86    32
# Comp:  2             [SII]6716      5.694      0.13     -85    45
# Comp:  2             [SII]6731      4.558      0.13     -85    45
# Comp:  2              HeII4687     0.1106      0.13     -85    45
# Comp:  2               HeI5876      1.611      0.13     -85    45
# Comp:  2          [OIII]5007_d      17.88      0.16     -85    45
# Comp:  2            [OI]6300_d      1.072      0.16     -85    45
# Comp:  2           [NII]6583_d      13.17      0.16     -85    45
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -138         7
#  comp.  1:       -88        33
#  comp.  2:       -77        55
# chi2/DOF: 1.194; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.739      0.12     -88    33
# Comp:  1                 Hbeta      16.99      0.12     -88    33
# Comp:  1                Halpha      43.25      0.12     -88    33
# Comp:  2             [SII]6716      5.971      0.13     -77    55
# Comp:  2             [SII]6731      5.229      0.13     -77    55
# Comp:  2              HeII4687     0.2132      0.13     -77    55
# Comp:  2               HeI5876      1.557      0.13     -77    55
# Comp:  2          [OIII]5007_d      16.42      0.16     -77    55
# Comp:  2            [OI]6300_d      1.217      0.16     -77    55
# Comp:  2           [NII]6583_d      13.32      0.16     -77    55
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -146         1
#  comp.  1:       -80        44
#  comp.  2:       -85        54
# chi2/DOF: 1.157; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.706      0.13     -80    44
# Comp:  1                 Hbeta      15.68      0.13     -80    44
# Comp:  1                Halpha      44.88      0.13     -80    44
# Comp:  2             [SII]6716      6.060      0.13     -85    54
# Comp:  2             [SII]6731      4.294      0.13     -85    54
# Comp:  2              HeII4687     0.1257      0.13     -85    54
# Comp:  2               HeI5876      1.796      0.13     -85    54
# Comp:  2          [OIII]5007_d      18.65      0.16     -85    54
# Comp:  2            [OI]6300_d     0.9819      0.16     -85    54
# Comp:  2           [NII]6583_d      13.55      0.16     -85    54
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -174        30
#  comp.  1:       -86        43
#  comp.  2:       -76        59
# chi2/DOF: 1.227; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 46; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.282      0.12     -86    43
# Comp:  1                 Hbeta      13.80      0.12     -86    43
# Comp:  1                Halpha      44.35      0.12     -86    43
# Comp:  2             [SII]6716      6.744      0.13     -76    59
# Comp:  2             [SII]6731      4.368      0.13     -76    59
# Comp:  2              HeII4687     0.1770      0.13     -76    59
# Comp:  2               HeI5876      1.689      0.13     -76    59
# Comp:  2          [OIII]5007_d      19.87      0.17     -76    59
# Comp:  2            [OI]6300_d      1.103      0.17     -76    59
# Comp:  2           [NII]6583_d      13.40      0.17     -76    59
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -144         1
#  comp.  1:       -86        37
#  comp.  2:       -81        65
# chi2/DOF: 1.433; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.802      0.12     -86    37
# Comp:  1                 Hbeta      15.21      0.12     -86    37
# Comp:  1                Halpha      43.40      0.12     -86    37
# Comp:  2             [SII]6716      6.253      0.14     -81    65
# Comp:  2             [SII]6731      4.827      0.14     -81    65
# Comp:  2              HeII4687  0.0005609      0.14     -81    65
# Comp:  2               HeI5876      1.878      0.14     -81    65
# Comp:  2          [OIII]5007_d      18.05      0.17     -81    65
# Comp:  2            [OI]6300_d      1.071      0.17     -81    65
# Comp:  2           [NII]6583_d      13.91      0.17     -81    65
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -143        49
#  comp.  1:       -88        33
#  comp.  2:       -79        58
# chi2/DOF: 1.316; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.522      0.12     -88    33
# Comp:  1                 Hbeta      16.06      0.12     -88    33
# Comp:  1                Halpha      42.87      0.12     -88    33
# Comp:  2             [SII]6716      6.689      0.13     -79    58
# Comp:  2             [SII]6731      5.066      0.13     -79    58
# Comp:  2              HeII4687    0.08090      0.13     -79    58
# Comp:  2               HeI5876      1.560      0.13     -79    58
# Comp:  2          [OIII]5007_d      18.58      0.17     -79    58
# Comp:  2            [OI]6300_d      1.091      0.17     -79    58
# Comp:  2           [NII]6583_d      13.08      0.17     -79    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -154         1
#  comp.  1:       -84        45
#  comp.  2:       -85        58
# chi2/DOF: 1.201; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.683      0.13     -84    45
# Comp:  1                 Hbeta      13.55      0.13     -84    45
# Comp:  1                Halpha      45.31      0.13     -84    45
# Comp:  2             [SII]6716      6.688      0.13     -85    58
# Comp:  2             [SII]6731      5.332      0.13     -85    58
# Comp:  2              HeII4687     0.2506      0.13     -85    58
# Comp:  2               HeI5876      1.652      0.13     -85    58
# Comp:  2          [OIII]5007_d      17.85      0.17     -85    58
# Comp:  2            [OI]6300_d      1.065      0.17     -85    58
# Comp:  2           [NII]6583_d      13.81      0.17     -85    58
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -115        74
#  comp.  1:       -89        29
#  comp.  2:       -78        64
# chi2/DOF: 1.196; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 65; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.001      0.12     -89    29
# Comp:  1                 Hbeta      15.93      0.12     -89    29
# Comp:  1                Halpha      43.07      0.12     -89    29
# Comp:  2             [SII]6716      6.395      0.13     -78    64
# Comp:  2             [SII]6731      4.840      0.13     -78    64
# Comp:  2              HeII4687     0.2737      0.13     -78    64
# Comp:  2               HeI5876      1.902      0.13     -78    64
# Comp:  2          [OIII]5007_d      17.68      0.17     -78    64
# Comp:  2            [OI]6300_d      1.086      0.17     -78    64
# Comp:  2           [NII]6583_d      14.60      0.17     -78    64
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97        60
#  comp.  1:       -86        30
#  comp.  2:       -77        52
# chi2/DOF: 1.323; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.830      0.12     -86    30
# Comp:  1                 Hbeta      15.10      0.12     -86    30
# Comp:  1                Halpha      42.04      0.12     -86    30
# Comp:  2             [SII]6716      6.360      0.13     -77    52
# Comp:  2             [SII]6731      4.575      0.13     -77    52
# Comp:  2              HeII4687     0.1978      0.13     -77    52
# Comp:  2               HeI5876      1.590      0.13     -77    52
# Comp:  2          [OIII]5007_d      18.34      0.16     -77    52
# Comp:  2            [OI]6300_d      1.143      0.16     -77    52
# Comp:  2           [NII]6583_d      13.58      0.16     -77    52
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -143         1
#  comp.  1:       -83        38
#  comp.  2:       -76        62
# chi2/DOF: 1.416; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.832      0.12     -83    38
# Comp:  1                 Hbeta      14.91      0.12     -83    38
# Comp:  1                Halpha      43.96      0.12     -83    38
# Comp:  2             [SII]6716      6.572      0.13     -76    62
# Comp:  2             [SII]6731      4.902      0.13     -76    62
# Comp:  2              HeII4687     0.2360      0.13     -76    62
# Comp:  2               HeI5876      1.660      0.13     -76    62
# Comp:  2          [OIII]5007_d      19.55      0.17     -76    62
# Comp:  2            [OI]6300_d      1.144      0.17     -76    62
# Comp:  2           [NII]6583_d      14.31      0.17     -76    62
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -160         1
#  comp.  1:       -83        47
#  comp.  2:       -80        62
# chi2/DOF: 1.205; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.133      0.13     -83    47
# Comp:  1                 Hbeta      14.86      0.13     -83    47
# Comp:  1                Halpha      46.25      0.13     -83    47
# Comp:  2             [SII]6716      6.561      0.13     -80    62
# Comp:  2             [SII]6731      4.393      0.13     -80    62
# Comp:  2              HeII4687    0.07885      0.13     -80    62
# Comp:  2               HeI5876      1.763      0.13     -80    62
# Comp:  2          [OIII]5007_d      16.73      0.17     -80    62
# Comp:  2            [OI]6300_d      1.150      0.17     -80    62
# Comp:  2           [NII]6583_d      14.29      0.17     -80    62
# -----------------------------------------------------------------

# %%
flux_err_boot

# %%
2.14*0.19

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_6_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_6", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_6_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_6_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_6_gas_exp.csv")
print(read2)

# %%
np.median(flux_rf_rebin)
