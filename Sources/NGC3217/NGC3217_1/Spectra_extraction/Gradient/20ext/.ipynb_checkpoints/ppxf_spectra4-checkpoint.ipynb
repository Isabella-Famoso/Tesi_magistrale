# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_4.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC5058/FORS2.2022-01-28T08_17_47.181/Spectra_extraction/Gradient/redshift_grad.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_4']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -92        80
# chi2/DOF: 0.03085; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
#  Best Fit:       Vel     sigma
#  comp.  0:      -110        46
# chi2/DOF: 0.01616; DOF: 1875; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-109.68083184,   45.95577952])

# %%
z
# Out:
# 0.03191

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        63
#  comp.  1:       -87        30
#  comp.  2:       -89        36
# chi2/DOF: 0.9998; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 12; Func calls: 86; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.708      0.35     -87    30
# Comp:  1                 Hbeta      9.655      0.35     -87    30
# Comp:  1                Halpha      36.16      0.35     -87    30
# Comp:  2             [SII]6716      9.431      0.36     -89    36
# Comp:  2             [SII]6731      6.539      0.36     -89    36
# Comp:  2              HeII4687    0.02524      0.36     -89    36
# Comp:  2               HeI5876     0.6437      0.36     -89    36
# Comp:  2          [OIII]5007_d      11.98      0.45     -89    36
# Comp:  2            [OI]6300_d      2.706      0.45     -89    36
# Comp:  2           [NII]6583_d      12.95      0.45     -89    36
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:   11.9; gas flux:      4 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  22.83; gas flux:     10 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  87.95; gas flux:     49 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  22.69; gas flux:     13 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  14.92; gas flux:      9 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise: 0.06214; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  1.588; gas flux:      1 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  22.16; gas flux:     13 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:   4.77; gas flux:      4 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:  22.81; gas flux:     18 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -87        13
#  comp.  1:       -89        33
#  comp.  2:       -90        41
# chi2/DOF: 0.9885; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.916      0.35     -89    33
# Comp:  1                 Hbeta      9.496      0.35     -89    33
# Comp:  1                Halpha      36.30      0.35     -89    33
# Comp:  2             [SII]6716      9.876      0.36     -90    41
# Comp:  2             [SII]6731      6.554      0.36     -90    41
# Comp:  2              HeII4687     0.3549      0.36     -90    41
# Comp:  2               HeI5876     0.6856      0.36     -90    41
# Comp:  2          [OIII]5007_d      12.40      0.46     -90    41
# Comp:  2            [OI]6300_d      2.670      0.46     -90    41
# Comp:  2           [NII]6583_d      13.39      0.46     -90    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -31        74
#  comp.  1:       -88        28
#  comp.  2:       -89        37
# chi2/DOF: 0.9845; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.793      0.35     -88    28
# Comp:  1                 Hbeta      9.476      0.35     -88    28
# Comp:  1                Halpha      35.61      0.35     -88    28
# Comp:  2             [SII]6716      9.365      0.36     -89    37
# Comp:  2             [SII]6731      6.736      0.36     -89    37
# Comp:  2              HeII4687      0.000      0.36     -89    37
# Comp:  2               HeI5876     0.5723      0.36     -89    37
# Comp:  2          [OIII]5007_d      10.98      0.45     -89    37
# Comp:  2            [OI]6300_d      2.988      0.45     -89    37
# Comp:  2           [NII]6583_d      12.84      0.45     -89    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80        47
#  comp.  1:       -86        29
#  comp.  2:       -93        32
# chi2/DOF: 0.9874; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.042      0.35     -86    29
# Comp:  1                 Hbeta      9.506      0.35     -86    29
# Comp:  1                Halpha      36.35      0.35     -86    29
# Comp:  2             [SII]6716      8.805      0.35     -93    32
# Comp:  2             [SII]6731      6.551      0.35     -93    32
# Comp:  2              HeII4687      0.000      0.35     -93    32
# Comp:  2               HeI5876     0.5496      0.35     -93    32
# Comp:  2          [OIII]5007_d      10.92      0.44     -93    32
# Comp:  2            [OI]6300_d      3.063      0.44     -93    32
# Comp:  2           [NII]6583_d      12.54      0.44     -93    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -98        44
#  comp.  1:       -87        24
#  comp.  2:       -93        34
# chi2/DOF: 0.9882; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.667      0.34     -87    24
# Comp:  1                 Hbeta      9.305      0.34     -87    24
# Comp:  1                Halpha      35.52      0.34     -87    24
# Comp:  2             [SII]6716      9.009      0.35     -93    34
# Comp:  2             [SII]6731      6.538      0.35     -93    34
# Comp:  2              HeII4687     0.2983      0.35     -93    34
# Comp:  2               HeI5876     0.7470      0.35     -93    34
# Comp:  2          [OIII]5007_d      12.40      0.45     -93    34
# Comp:  2            [OI]6300_d      3.131      0.45     -93    34
# Comp:  2           [NII]6583_d      12.68      0.45     -93    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        71
#  comp.  1:       -87        30
#  comp.  2:       -90        34
# chi2/DOF: 0.9867; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.861      0.35     -87    30
# Comp:  1                 Hbeta      9.387      0.35     -87    30
# Comp:  1                Halpha      36.22      0.35     -87    30
# Comp:  2             [SII]6716      8.956      0.35     -90    34
# Comp:  2             [SII]6731      6.697      0.35     -90    34
# Comp:  2              HeII4687      0.000      0.35     -90    34
# Comp:  2               HeI5876     0.7441      0.35     -90    34
# Comp:  2          [OIII]5007_d      10.98      0.45     -90    34
# Comp:  2            [OI]6300_d      3.009      0.45     -90    34
# Comp:  2           [NII]6583_d      12.89      0.45     -90    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -114        41
#  comp.  1:       -86        29
#  comp.  2:       -91        36
# chi2/DOF: 0.9902; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.971      0.35     -86    29
# Comp:  1                 Hbeta      9.557      0.35     -86    29
# Comp:  1                Halpha      36.19      0.35     -86    29
# Comp:  2             [SII]6716      9.198      0.36     -91    36
# Comp:  2             [SII]6731      6.823      0.36     -91    36
# Comp:  2              HeII4687     0.1854      0.36     -91    36
# Comp:  2               HeI5876     0.6892      0.36     -91    36
# Comp:  2          [OIII]5007_d      12.37      0.45     -91    36
# Comp:  2            [OI]6300_d      2.737      0.45     -91    36
# Comp:  2           [NII]6583_d      13.16      0.45     -91    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76        70
#  comp.  1:       -87        30
#  comp.  2:       -87        42
# chi2/DOF: 0.9922; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.704      0.35     -87    30
# Comp:  1                 Hbeta      10.33      0.35     -87    30
# Comp:  1                Halpha      36.00      0.35     -87    30
# Comp:  2             [SII]6716      10.09      0.36     -87    42
# Comp:  2             [SII]6731      6.769      0.36     -87    42
# Comp:  2              HeII4687      0.000      0.36     -87    42
# Comp:  2               HeI5876     0.6003      0.36     -87    42
# Comp:  2          [OIII]5007_d      11.89      0.46     -87    42
# Comp:  2            [OI]6300_d      2.649      0.46     -87    42
# Comp:  2           [NII]6583_d      13.15      0.46     -87    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -92        83
#  comp.  1:       -88        25
#  comp.  2:       -87        33
# chi2/DOF: 0.9813; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.408      0.34     -88    25
# Comp:  1                 Hbeta      9.360      0.34     -88    25
# Comp:  1                Halpha      35.21      0.34     -88    25
# Comp:  2             [SII]6716      9.602      0.35     -87    33
# Comp:  2             [SII]6731      6.801      0.35     -87    33
# Comp:  2              HeII4687     0.3266      0.35     -87    33
# Comp:  2               HeI5876     0.6910      0.35     -87    33
# Comp:  2          [OIII]5007_d      10.76      0.44     -87    33
# Comp:  2            [OI]6300_d      2.706      0.44     -87    33
# Comp:  2           [NII]6583_d      12.71      0.44     -87    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99        52
#  comp.  1:       -87        30
#  comp.  2:       -93        29
# chi2/DOF: 0.9858; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.282      0.35     -87    30
# Comp:  1                 Hbeta      9.950      0.35     -87    30
# Comp:  1                Halpha      36.42      0.35     -87    30
# Comp:  2             [SII]6716      9.329      0.35     -93    29
# Comp:  2             [SII]6731      6.330      0.35     -93    29
# Comp:  2              HeII4687      0.000      0.35     -93    29
# Comp:  2               HeI5876     0.6215      0.35     -93    29
# Comp:  2          [OIII]5007_d      12.64      0.44     -93    29
# Comp:  2            [OI]6300_d      2.887      0.44     -93    29
# Comp:  2           [NII]6583_d      12.32      0.44     -93    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28       123
#  comp.  1:       -86        32
#  comp.  2:       -90        39
# chi2/DOF: 0.9853; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.909      0.35     -86    32
# Comp:  1                 Hbeta      10.41      0.35     -86    32
# Comp:  1                Halpha      36.98      0.35     -86    32
# Comp:  2             [SII]6716      9.584      0.36     -90    39
# Comp:  2             [SII]6731      6.544      0.36     -90    39
# Comp:  2              HeII4687     0.1058      0.36     -90    39
# Comp:  2               HeI5876     0.7260      0.36     -90    39
# Comp:  2          [OIII]5007_d      12.29      0.45     -90    39
# Comp:  2            [OI]6300_d      3.342      0.45     -90    39
# Comp:  2           [NII]6583_d      13.08      0.45     -90    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -53        97
#  comp.  1:       -89        30
#  comp.  2:       -89        29
# chi2/DOF: 0.9788; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.116      0.35     -89    30
# Comp:  1                 Hbeta      10.56      0.35     -89    30
# Comp:  1                Halpha      36.48      0.35     -89    30
# Comp:  2             [SII]6716      9.226      0.35     -89    29
# Comp:  2             [SII]6731      6.286      0.35     -89    29
# Comp:  2              HeII4687     0.4358      0.35     -89    29
# Comp:  2               HeI5876     0.6588      0.35     -89    29
# Comp:  2          [OIII]5007_d      11.74      0.44     -89    29
# Comp:  2            [OI]6300_d      2.889      0.44     -89    29
# Comp:  2           [NII]6583_d      12.47      0.44     -89    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -81        66
#  comp.  1:       -86        27
#  comp.  2:       -90        38
# chi2/DOF: 0.9902; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.490      0.35     -86    27
# Comp:  1                 Hbeta      9.635      0.35     -86    27
# Comp:  1                Halpha      36.03      0.35     -86    27
# Comp:  2             [SII]6716      10.09      0.36     -90    38
# Comp:  2             [SII]6731      6.670      0.36     -90    38
# Comp:  2              HeII4687      0.000      0.36     -90    38
# Comp:  2               HeI5876     0.6759      0.36     -90    38
# Comp:  2          [OIII]5007_d      11.98      0.45     -90    38
# Comp:  2            [OI]6300_d      2.553      0.45     -90    38
# Comp:  2           [NII]6583_d      12.98      0.45     -90    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -47       144
#  comp.  1:       -86        28
#  comp.  2:       -93        27
# chi2/DOF: 0.9785; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.855      0.35     -86    28
# Comp:  1                 Hbeta      9.568      0.35     -86    28
# Comp:  1                Halpha      36.24      0.35     -86    28
# Comp:  2             [SII]6716      9.334      0.35     -93    27
# Comp:  2             [SII]6731      5.963      0.35     -93    27
# Comp:  2              HeII4687     0.1782      0.35     -93    27
# Comp:  2               HeI5876     0.6594      0.35     -93    27
# Comp:  2          [OIII]5007_d      12.50      0.44     -93    27
# Comp:  2            [OI]6300_d      2.896      0.44     -93    27
# Comp:  2           [NII]6583_d      12.54      0.44     -93    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84        18
#  comp.  1:       -86        31
#  comp.  2:       -88        31
# chi2/DOF: 0.9917; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.121      0.35     -86    31
# Comp:  1                 Hbeta      9.608      0.35     -86    31
# Comp:  1                Halpha      35.87      0.35     -86    31
# Comp:  2             [SII]6716      9.121      0.35     -88    31
# Comp:  2             [SII]6731      6.818      0.35     -88    31
# Comp:  2              HeII4687      0.000      0.35     -88    31
# Comp:  2               HeI5876     0.7774      0.35     -88    31
# Comp:  2          [OIII]5007_d      12.31      0.44     -88    31
# Comp:  2            [OI]6300_d      2.360      0.44     -88    31
# Comp:  2           [NII]6583_d      12.70      0.44     -88    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57         1
#  comp.  1:       -89        27
#  comp.  2:       -92        39
# chi2/DOF: 0.9835; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.678      0.35     -89    27
# Comp:  1                 Hbeta      10.07      0.35     -89    27
# Comp:  1                Halpha      35.75      0.35     -89    27
# Comp:  2             [SII]6716      9.937      0.36     -92    39
# Comp:  2             [SII]6731      6.559      0.36     -92    39
# Comp:  2              HeII4687     0.1351      0.36     -92    39
# Comp:  2               HeI5876     0.8325      0.36     -92    39
# Comp:  2          [OIII]5007_d      12.12      0.45     -92    39
# Comp:  2            [OI]6300_d      2.565      0.45     -92    39
# Comp:  2           [NII]6583_d      13.34      0.45     -92    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -97        29
#  comp.  1:       -87        32
#  comp.  2:       -88        37
# chi2/DOF: 0.9881; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.679      0.35     -87    32
# Comp:  1                 Hbeta      9.505      0.35     -87    32
# Comp:  1                Halpha      36.97      0.35     -87    32
# Comp:  2             [SII]6716      9.759      0.36     -88    37
# Comp:  2             [SII]6731      6.663      0.36     -88    37
# Comp:  2              HeII4687      0.000      0.36     -88    37
# Comp:  2               HeI5876     0.6279      0.36     -88    37
# Comp:  2          [OIII]5007_d      12.39      0.45     -88    37
# Comp:  2            [OI]6300_d      2.974      0.45     -88    37
# Comp:  2           [NII]6583_d      13.30      0.45     -88    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -114        85
#  comp.  1:       -89        26
#  comp.  2:       -86        34
# chi2/DOF: 0.9851; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.995      0.34     -89    26
# Comp:  1                 Hbeta      9.406      0.34     -89    26
# Comp:  1                Halpha      35.56      0.34     -89    26
# Comp:  2             [SII]6716      8.878      0.35     -86    34
# Comp:  2             [SII]6731      6.712      0.35     -86    34
# Comp:  2              HeII4687      0.000      0.35     -86    34
# Comp:  2               HeI5876     0.6488      0.35     -86    34
# Comp:  2          [OIII]5007_d      11.83      0.45     -86    34
# Comp:  2            [OI]6300_d      2.959      0.45     -86    34
# Comp:  2           [NII]6583_d      12.40      0.45     -86    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -99        69
#  comp.  1:       -85        30
#  comp.  2:       -91        32
# chi2/DOF: 0.9849; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.803      0.35     -85    30
# Comp:  1                 Hbeta      9.426      0.35     -85    30
# Comp:  1                Halpha      36.74      0.35     -85    30
# Comp:  2             [SII]6716      9.247      0.35     -91    32
# Comp:  2             [SII]6731      6.321      0.35     -91    32
# Comp:  2              HeII4687      0.000      0.35     -91    32
# Comp:  2               HeI5876     0.5717      0.35     -91    32
# Comp:  2          [OIII]5007_d      12.45      0.44     -91    32
# Comp:  2            [OI]6300_d      2.353      0.44     -91    32
# Comp:  2           [NII]6583_d      13.08      0.44     -91    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -71        39
#  comp.  1:       -89        29
#  comp.  2:       -84        39
# chi2/DOF: 0.9870; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.773      0.35     -89    29
# Comp:  1                 Hbeta      9.871      0.35     -89    29
# Comp:  1                Halpha      36.39      0.35     -89    29
# Comp:  2             [SII]6716      9.318      0.36     -84    39
# Comp:  2             [SII]6731      6.468      0.36     -84    39
# Comp:  2              HeII4687     0.3527      0.36     -84    39
# Comp:  2               HeI5876     0.6441      0.36     -84    39
# Comp:  2          [OIII]5007_d      11.93      0.45     -84    39
# Comp:  2            [OI]6300_d      2.843      0.45     -84    39
# Comp:  2           [NII]6583_d      13.02      0.45     -84    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75        47
#  comp.  1:       -88        24
#  comp.  2:       -89        41
# chi2/DOF: 0.9892; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.505      0.34     -88    24
# Comp:  1                 Hbeta      9.903      0.34     -88    24
# Comp:  1                Halpha      35.88      0.34     -88    24
# Comp:  2             [SII]6716      9.852      0.36     -89    41
# Comp:  2             [SII]6731      7.125      0.36     -89    41
# Comp:  2              HeII4687    0.03089      0.36     -89    41
# Comp:  2               HeI5876     0.7235      0.36     -89    41
# Comp:  2          [OIII]5007_d      12.61      0.46     -89    41
# Comp:  2            [OI]6300_d      2.981      0.46     -89    41
# Comp:  2           [NII]6583_d      13.16      0.46     -89    41
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -100        23
#  comp.  1:       -88        23
#  comp.  2:       -91        34
# chi2/DOF: 0.9856; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.572      0.34     -88    23
# Comp:  1                 Hbeta      9.718      0.34     -88    23
# Comp:  1                Halpha      35.16      0.34     -88    23
# Comp:  2             [SII]6716      8.876      0.35     -91    34
# Comp:  2             [SII]6731      6.810      0.35     -91    34
# Comp:  2              HeII4687      0.000      0.35     -91    34
# Comp:  2               HeI5876     0.6334      0.35     -91    34
# Comp:  2          [OIII]5007_d      12.70      0.45     -91    34
# Comp:  2            [OI]6300_d      2.212      0.45     -91    34
# Comp:  2           [NII]6583_d      12.53      0.45     -91    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -96        25
#  comp.  1:       -89        28
#  comp.  2:       -90        40
# chi2/DOF: 0.9940; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.757      0.35     -89    28
# Comp:  1                 Hbeta      9.281      0.35     -89    28
# Comp:  1                Halpha      35.52      0.35     -89    28
# Comp:  2             [SII]6716      9.404      0.36     -90    40
# Comp:  2             [SII]6731      6.760      0.36     -90    40
# Comp:  2              HeII4687     0.2783      0.36     -90    40
# Comp:  2               HeI5876     0.6340      0.36     -90    40
# Comp:  2          [OIII]5007_d      11.58      0.45     -90    40
# Comp:  2            [OI]6300_d      2.871      0.45     -90    40
# Comp:  2           [NII]6583_d      12.59      0.45     -90    40
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -121        71
#  comp.  1:       -87        31
#  comp.  2:       -86        37
# chi2/DOF: 0.9836; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.050      0.35     -87    31
# Comp:  1                 Hbeta      10.52      0.35     -87    31
# Comp:  1                Halpha      35.89      0.35     -87    31
# Comp:  2             [SII]6716      9.244      0.36     -86    37
# Comp:  2             [SII]6731      6.221      0.36     -86    37
# Comp:  2              HeII4687      0.000      0.36     -86    37
# Comp:  2               HeI5876     0.6720      0.36     -86    37
# Comp:  2          [OIII]5007_d      11.56      0.45     -86    37
# Comp:  2            [OI]6300_d      2.377      0.45     -86    37
# Comp:  2           [NII]6583_d      12.78      0.45     -86    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -83        87
#  comp.  1:       -87        24
#  comp.  2:       -88        36
# chi2/DOF: 0.9866; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.383      0.34     -87    24
# Comp:  1                 Hbeta      9.888      0.34     -87    24
# Comp:  1                Halpha      35.69      0.34     -87    24
# Comp:  2             [SII]6716      9.775      0.36     -88    36
# Comp:  2             [SII]6731      6.916      0.36     -88    36
# Comp:  2              HeII4687    0.05994      0.36     -88    36
# Comp:  2               HeI5876     0.7626      0.36     -88    36
# Comp:  2          [OIII]5007_d      11.62      0.45     -88    36
# Comp:  2            [OI]6300_d      2.315      0.45     -88    36
# Comp:  2           [NII]6583_d      12.63      0.45     -88    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        77
#  comp.  1:       -87        24
#  comp.  2:       -90        38
# chi2/DOF: 0.9846; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.300      0.34     -87    24
# Comp:  1                 Hbeta      9.796      0.34     -87    24
# Comp:  1                Halpha      36.05      0.34     -87    24
# Comp:  2             [SII]6716      9.867      0.36     -90    38
# Comp:  2             [SII]6731      6.584      0.36     -90    38
# Comp:  2              HeII4687     0.2543      0.36     -90    38
# Comp:  2               HeI5876     0.6633      0.36     -90    38
# Comp:  2          [OIII]5007_d      12.19      0.45     -90    38
# Comp:  2            [OI]6300_d      3.019      0.45     -90    38
# Comp:  2           [NII]6583_d      12.82      0.45     -90    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        81
#  comp.  1:       -88        25
#  comp.  2:       -87        36
# chi2/DOF: 0.9771; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.333      0.34     -88    25
# Comp:  1                 Hbeta      9.814      0.34     -88    25
# Comp:  1                Halpha      35.40      0.34     -88    25
# Comp:  2             [SII]6716      9.712      0.36     -87    36
# Comp:  2             [SII]6731      6.663      0.36     -87    36
# Comp:  2              HeII4687     0.4897      0.36     -87    36
# Comp:  2               HeI5876     0.7318      0.36     -87    36
# Comp:  2          [OIII]5007_d      11.06      0.45     -87    36
# Comp:  2            [OI]6300_d      2.586      0.45     -87    36
# Comp:  2           [NII]6583_d      12.79      0.45     -87    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -64         1
#  comp.  1:       -85        33
#  comp.  2:       -90        29
# chi2/DOF: 0.9880; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.604      0.35     -85    33
# Comp:  1                 Hbeta      9.081      0.35     -85    33
# Comp:  1                Halpha      36.77      0.35     -85    33
# Comp:  2             [SII]6716      8.908      0.35     -90    29
# Comp:  2             [SII]6731      6.599      0.35     -90    29
# Comp:  2              HeII4687      0.000      0.35     -90    29
# Comp:  2               HeI5876     0.5745      0.35     -90    29
# Comp:  2          [OIII]5007_d      12.35      0.44     -90    29
# Comp:  2            [OI]6300_d      2.790      0.44     -90    29
# Comp:  2           [NII]6583_d      12.52      0.44     -90    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        96
#  comp.  1:       -87        33
#  comp.  2:       -87        36
# chi2/DOF: 0.9858; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.109      0.35     -87    33
# Comp:  1                 Hbeta      10.47      0.35     -87    33
# Comp:  1                Halpha      36.73      0.35     -87    33
# Comp:  2             [SII]6716      9.174      0.36     -87    36
# Comp:  2             [SII]6731      6.784      0.36     -87    36
# Comp:  2              HeII4687     0.2069      0.36     -87    36
# Comp:  2               HeI5876     0.8087      0.36     -87    36
# Comp:  2          [OIII]5007_d      12.19      0.45     -87    36
# Comp:  2            [OI]6300_d      3.018      0.45     -87    36
# Comp:  2           [NII]6583_d      12.89      0.45     -87    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -106         1
#  comp.  1:       -89        31
#  comp.  2:       -90        35
# chi2/DOF: 0.9889; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.318      0.35     -89    31
# Comp:  1                 Hbeta      10.35      0.35     -89    31
# Comp:  1                Halpha      36.34      0.35     -89    31
# Comp:  2             [SII]6716      9.369      0.35     -90    35
# Comp:  2             [SII]6731      6.353      0.35     -90    35
# Comp:  2              HeII4687      0.000      0.35     -90    35
# Comp:  2               HeI5876     0.6523      0.35     -90    35
# Comp:  2          [OIII]5007_d      11.58      0.45     -90    35
# Comp:  2            [OI]6300_d      2.875      0.45     -90    35
# Comp:  2           [NII]6583_d      13.01      0.45     -90    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -63        23
#  comp.  1:       -86        32
#  comp.  2:       -86        38
# chi2/DOF: 0.9902; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.106      0.35     -86    32
# Comp:  1                 Hbeta      9.876      0.35     -86    32
# Comp:  1                Halpha      36.02      0.35     -86    32
# Comp:  2             [SII]6716      9.529      0.36     -86    38
# Comp:  2             [SII]6731      6.632      0.36     -86    38
# Comp:  2              HeII4687      0.000      0.36     -86    38
# Comp:  2               HeI5876     0.7094      0.36     -86    38
# Comp:  2          [OIII]5007_d      11.54      0.45     -86    38
# Comp:  2            [OI]6300_d      2.995      0.45     -86    38
# Comp:  2           [NII]6583_d      13.03      0.45     -86    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -67        87
#  comp.  1:       -89        34
#  comp.  2:       -93        33
# chi2/DOF: 0.9769; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.413      0.35     -89    34
# Comp:  1                 Hbeta      10.20      0.35     -89    34
# Comp:  1                Halpha      36.65      0.35     -89    34
# Comp:  2             [SII]6716      9.661      0.35     -93    33
# Comp:  2             [SII]6731      6.630      0.35     -93    33
# Comp:  2              HeII4687     0.3354      0.35     -93    33
# Comp:  2               HeI5876     0.7792      0.35     -93    33
# Comp:  2          [OIII]5007_d      11.98      0.44     -93    33
# Comp:  2            [OI]6300_d      2.776      0.44     -93    33
# Comp:  2           [NII]6583_d      12.82      0.44     -93    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -75       139
#  comp.  1:       -87        30
#  comp.  2:       -90        42
# chi2/DOF: 0.9853; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.823      0.35     -87    30
# Comp:  1                 Hbeta      10.18      0.35     -87    30
# Comp:  1                Halpha      36.63      0.35     -87    30
# Comp:  2             [SII]6716      9.167      0.36     -90    42
# Comp:  2             [SII]6731      7.009      0.36     -90    42
# Comp:  2              HeII4687     0.3026      0.36     -90    42
# Comp:  2               HeI5876     0.5817      0.36     -90    42
# Comp:  2          [OIII]5007_d      13.05      0.46     -90    42
# Comp:  2            [OI]6300_d      2.929      0.46     -90    42
# Comp:  2           [NII]6583_d      12.90      0.46     -90    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23       147
#  comp.  1:       -87        29
#  comp.  2:       -91        32
# chi2/DOF: 0.9817; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.231      0.35     -87    29
# Comp:  1                 Hbeta      9.210      0.35     -87    29
# Comp:  1                Halpha      35.82      0.35     -87    29
# Comp:  2             [SII]6716      9.379      0.35     -91    32
# Comp:  2             [SII]6731      6.417      0.35     -91    32
# Comp:  2              HeII4687      0.000      0.35     -91    32
# Comp:  2               HeI5876     0.6919      0.35     -91    32
# Comp:  2          [OIII]5007_d      11.85      0.44     -91    32
# Comp:  2            [OI]6300_d      2.587      0.44     -91    32
# Comp:  2           [NII]6583_d      12.57      0.44     -91    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -76       106
#  comp.  1:       -88        32
#  comp.  2:       -90        31
# chi2/DOF: 0.9902; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 10/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.107      0.35     -88    32
# Comp:  1                 Hbeta      9.698      0.35     -88    32
# Comp:  1                Halpha      36.29      0.35     -88    32
# Comp:  2             [SII]6716      9.218      0.35     -90    31
# Comp:  2             [SII]6731      6.279      0.35     -90    31
# Comp:  2              HeII4687      0.000      0.35     -90    31
# Comp:  2               HeI5876     0.6477      0.35     -90    31
# Comp:  2          [OIII]5007_d      12.47      0.44     -90    31
# Comp:  2            [OI]6300_d      2.470      0.44     -90    31
# Comp:  2           [NII]6583_d      12.92      0.44     -90    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -73        53
#  comp.  1:       -87        32
#  comp.  2:       -86        35
# chi2/DOF: 0.9909; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.104      0.35     -87    32
# Comp:  1                 Hbeta      9.593      0.35     -87    32
# Comp:  1                Halpha      36.75      0.35     -87    32
# Comp:  2             [SII]6716      9.346      0.35     -86    35
# Comp:  2             [SII]6731      6.743      0.35     -86    35
# Comp:  2              HeII4687     0.3866      0.35     -86    35
# Comp:  2               HeI5876     0.6817      0.35     -86    35
# Comp:  2          [OIII]5007_d      12.19      0.45     -86    35
# Comp:  2            [OI]6300_d      2.551      0.45     -86    35
# Comp:  2           [NII]6583_d      12.92      0.45     -86    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -78        52
#  comp.  1:       -88        26
#  comp.  2:       -91        43
# chi2/DOF: 0.9908; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.935      0.34     -88    26
# Comp:  1                 Hbeta      9.250      0.34     -88    26
# Comp:  1                Halpha      35.12      0.34     -88    26
# Comp:  2             [SII]6716      9.652      0.36     -91    43
# Comp:  2             [SII]6731      6.755      0.36     -91    43
# Comp:  2              HeII4687      0.000      0.36     -91    43
# Comp:  2               HeI5876     0.5703      0.36     -91    43
# Comp:  2          [OIII]5007_d      12.78      0.46     -91    43
# Comp:  2            [OI]6300_d      3.262      0.46     -91    43
# Comp:  2           [NII]6583_d      13.36      0.46     -91    43
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        88
#  comp.  1:       -88        28
#  comp.  2:       -88        38
# chi2/DOF: 0.9884; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      3.904      0.35     -88    28
# Comp:  1                 Hbeta      9.102      0.35     -88    28
# Comp:  1                Halpha      36.29      0.35     -88    28
# Comp:  2             [SII]6716      9.505      0.36     -88    38
# Comp:  2             [SII]6731      6.690      0.36     -88    38
# Comp:  2              HeII4687     0.3670      0.36     -88    38
# Comp:  2               HeI5876     0.6296      0.36     -88    38
# Comp:  2          [OIII]5007_d      11.39      0.45     -88    38
# Comp:  2            [OI]6300_d      2.200      0.45     -88    38
# Comp:  2           [NII]6583_d      13.30      0.45     -88    38
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -59        85
#  comp.  1:       -89        30
#  comp.  2:       -91        30
# chi2/DOF: 0.9843; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.271      0.35     -89    30
# Comp:  1                 Hbeta      9.732      0.35     -89    30
# Comp:  1                Halpha      36.10      0.35     -89    30
# Comp:  2             [SII]6716      9.464      0.35     -91    30
# Comp:  2             [SII]6731      6.363      0.35     -91    30
# Comp:  2              HeII4687     0.3505      0.35     -91    30
# Comp:  2               HeI5876     0.5861      0.35     -91    30
# Comp:  2          [OIII]5007_d      12.57      0.44     -91    30
# Comp:  2            [OI]6300_d      2.432      0.44     -91    30
# Comp:  2           [NII]6583_d      12.31      0.44     -91    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79        83
#  comp.  1:       -88        36
#  comp.  2:       -91        33
# chi2/DOF: 0.9852; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.012      0.36     -88    36
# Comp:  1                 Hbeta      10.50      0.36     -88    36
# Comp:  1                Halpha      37.37      0.36     -88    36
# Comp:  2             [SII]6716      9.260      0.35     -91    33
# Comp:  2             [SII]6731      6.845      0.35     -91    33
# Comp:  2              HeII4687      0.000      0.35     -91    33
# Comp:  2               HeI5876     0.5879      0.35     -91    33
# Comp:  2          [OIII]5007_d      12.60      0.44     -91    33
# Comp:  2            [OI]6300_d      3.270      0.44     -91    33
# Comp:  2           [NII]6583_d      12.83      0.44     -91    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -77        82
#  comp.  1:       -85        31
#  comp.  2:       -88        40
# chi2/DOF: 0.9849; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -88        52
#  comp.  1:       -87        34
#  comp.  2:       -90        42
# chi2/DOF: 0.9837; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.785      0.35     -87    34
# Comp:  1                 Hbeta      11.01      0.35     -87    34
# Comp:  1                Halpha      36.57      0.35     -87    34
# Comp:  2             [SII]6716      9.109      0.36     -90    42
# Comp:  2             [SII]6731      6.581      0.36     -90    42
# Comp:  2              HeII4687    0.02591      0.36     -90    42
# Comp:  2               HeI5876     0.7326      0.36     -90    42
# Comp:  2          [OIII]5007_d      12.26      0.46     -90    42
# Comp:  2            [OI]6300_d      2.676      0.46     -90    42
# Comp:  2           [NII]6583_d      13.59      0.46     -90    42
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -57        75
#  comp.  1:       -85        27
#  comp.  2:       -90        33
# chi2/DOF: 0.9900; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.451      0.35     -85    27
# Comp:  1                 Hbeta      8.753      0.35     -85    27
# Comp:  1                Halpha      35.85      0.35     -85    27
# Comp:  2             [SII]6716      9.751      0.35     -90    33
# Comp:  2             [SII]6731      6.047      0.35     -90    33
# Comp:  2              HeII4687     0.3295      0.35     -90    33
# Comp:  2               HeI5876     0.6165      0.35     -90    33
# Comp:  2          [OIII]5007_d      11.93      0.44     -90    33
# Comp:  2            [OI]6300_d      2.448      0.44     -90    33
# Comp:  2           [NII]6583_d      12.96      0.44     -90    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        54
#  comp.  1:       -87        36
#  comp.  2:       -91        31
# chi2/DOF: 0.9866; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.494      0.36     -87    36
# Comp:  1                 Hbeta      9.684      0.36     -87    36
# Comp:  1                Halpha      36.84      0.36     -87    36
# Comp:  2             [SII]6716      9.251      0.35     -91    31
# Comp:  2             [SII]6731      6.050      0.35     -91    31
# Comp:  2              HeII4687     0.1112      0.35     -91    31
# Comp:  2               HeI5876     0.7023      0.35     -91    31
# Comp:  2          [OIII]5007_d      12.42      0.44     -91    31
# Comp:  2            [OI]6300_d      2.541      0.44     -91    31
# Comp:  2           [NII]6583_d      12.31      0.44     -91    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -91        24
#  comp.  1:       -86        27
#  comp.  2:       -89        34
# chi2/DOF: 0.9890; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 32; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.506      0.35     -86    27
# Comp:  1                 Hbeta      9.151      0.35     -86    27
# Comp:  1                Halpha      35.84      0.35     -86    27
# Comp:  2             [SII]6716      9.096      0.35     -89    34
# Comp:  2             [SII]6731      6.882      0.35     -89    34
# Comp:  2              HeII4687      0.000      0.35     -89    34
# Comp:  2               HeI5876     0.7157      0.35     -89    34
# Comp:  2          [OIII]5007_d      11.44      0.45     -89    34
# Comp:  2            [OI]6300_d      2.761      0.45     -89    34
# Comp:  2           [NII]6583_d      12.81      0.45     -89    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -60        10
#  comp.  1:       -86        29
#  comp.  2:       -90        34
# chi2/DOF: 0.9867; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.174      0.35     -86    29
# Comp:  1                 Hbeta      10.23      0.35     -86    29
# Comp:  1                Halpha      36.29      0.35     -86    29
# Comp:  2             [SII]6716      8.860      0.35     -90    34
# Comp:  2             [SII]6731      6.855      0.35     -90    34
# Comp:  2              HeII4687      0.000      0.35     -90    34
# Comp:  2               HeI5876     0.6189      0.35     -90    34
# Comp:  2          [OIII]5007_d      12.48      0.45     -90    34
# Comp:  2            [OI]6300_d      2.331      0.45     -90    34
# Comp:  2           [NII]6583_d      12.41      0.45     -90    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        68
#  comp.  1:       -87        37
#  comp.  2:       -87        39
# chi2/DOF: 0.9833; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.730      0.36     -87    37
# Comp:  1                 Hbeta      11.15      0.36     -87    37
# Comp:  1                Halpha      38.03      0.36     -87    37
# Comp:  2             [SII]6716      9.523      0.36     -87    39
# Comp:  2             [SII]6731      6.344      0.36     -87    39
# Comp:  2              HeII4687      0.000      0.36     -87    39
# Comp:  2               HeI5876     0.7588      0.36     -87    39
# Comp:  2          [OIII]5007_d      12.49      0.45     -87    39
# Comp:  2            [OI]6300_d      2.831      0.45     -87    39
# Comp:  2           [NII]6583_d      13.24      0.45     -87    39
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -79         1
#  comp.  1:       -87        28
#  comp.  2:       -92        30
# chi2/DOF: 0.9821; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      6.496      0.35     -87    28
# Comp:  1                 Hbeta      10.29      0.35     -87    28
# Comp:  1                Halpha      35.93      0.35     -87    28
# Comp:  2             [SII]6716      8.827      0.35     -92    30
# Comp:  2             [SII]6731      6.825      0.35     -92    30
# Comp:  2              HeII4687      0.000      0.35     -92    30
# Comp:  2               HeI5876     0.6866      0.35     -92    30
# Comp:  2          [OIII]5007_d      12.51      0.44     -92    30
# Comp:  2            [OI]6300_d      2.513      0.44     -92    30
# Comp:  2           [NII]6583_d      12.38      0.44     -92    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:      -108         1
#  comp.  1:       -88        34
#  comp.  2:       -94        35
# chi2/DOF: 0.9893; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.108      0.35     -88    34
# Comp:  1                 Hbeta      10.37      0.35     -88    34
# Comp:  1                Halpha      36.99      0.35     -88    34
# Comp:  2             [SII]6716      9.552      0.35     -94    35
# Comp:  2             [SII]6731      6.343      0.35     -94    35
# Comp:  2              HeII4687     0.2588      0.35     -94    35
# Comp:  2               HeI5876     0.7266      0.35     -94    35
# Comp:  2          [OIII]5007_d      11.91      0.45     -94    35
# Comp:  2            [OI]6300_d      2.577      0.45     -94    35
# Comp:  2           [NII]6583_d      12.69      0.45     -94    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -90        92
#  comp.  1:       -88        37
#  comp.  2:       -91        37
# chi2/DOF: 0.9820; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.128      0.36     -88    37
# Comp:  1                 Hbeta      10.34      0.36     -88    37
# Comp:  1                Halpha      36.89      0.36     -88    37
# Comp:  2             [SII]6716      9.373      0.36     -91    37
# Comp:  2             [SII]6731      6.558      0.36     -91    37
# Comp:  2              HeII4687      0.000      0.36     -91    37
# Comp:  2               HeI5876     0.6585      0.36     -91    37
# Comp:  2          [OIII]5007_d      11.62      0.45     -91    37
# Comp:  2            [OI]6300_d      3.240      0.45     -91    37
# Comp:  2           [NII]6583_d      13.49      0.45     -91    37
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -82        30
#  comp.  1:       -86        32
#  comp.  2:       -88        34
# chi2/DOF: 0.9856; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.800      0.35     -86    32
# Comp:  1                 Hbeta      10.28      0.35     -86    32
# Comp:  1                Halpha      36.98      0.35     -86    32
# Comp:  2             [SII]6716      9.096      0.35     -88    34
# Comp:  2             [SII]6731      6.908      0.35     -88    34
# Comp:  2              HeII4687      0.000      0.35     -88    34
# Comp:  2               HeI5876     0.5686      0.35     -88    34
# Comp:  2          [OIII]5007_d      11.33      0.45     -88    34
# Comp:  2            [OI]6300_d      2.630      0.45     -88    34
# Comp:  2           [NII]6583_d      12.86      0.45     -88    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52       121
#  comp.  1:       -85        32
#  comp.  2:       -94        35
# chi2/DOF: 0.9832; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      5.134      0.35     -85    32
# Comp:  1                 Hbeta      9.353      0.35     -85    32
# Comp:  1                Halpha      36.75      0.35     -85    32
# Comp:  2             [SII]6716      9.587      0.35     -94    35
# Comp:  2             [SII]6731      6.397      0.35     -94    35
# Comp:  2              HeII4687    0.01071      0.35     -94    35
# Comp:  2               HeI5876     0.6237      0.35     -94    35
# Comp:  2          [OIII]5007_d      12.06      0.45     -94    35
# Comp:  2            [OI]6300_d      2.942      0.45     -94    35
# Comp:  2           [NII]6583_d      12.29      0.45     -94    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -84        84
#  comp.  1:       -90        29
#  comp.  2:       -88        32
# chi2/DOF: 0.9869; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.349      0.35     -90    29
# Comp:  1                 Hbeta      10.09      0.35     -90    29
# Comp:  1                Halpha      35.93      0.35     -90    29
# Comp:  2             [SII]6716      9.294      0.35     -88    32
# Comp:  2             [SII]6731      6.281      0.35     -88    32
# Comp:  2              HeII4687     0.1049      0.35     -88    32
# Comp:  2               HeI5876     0.7259      0.35     -88    32
# Comp:  2          [OIII]5007_d      11.50      0.44     -88    32
# Comp:  2            [OI]6300_d      3.068      0.44     -88    32
# Comp:  2           [NII]6583_d      12.52      0.44     -88    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        64
#  comp.  1:       -87        25
#  comp.  2:       -90        31
# chi2/DOF: 0.9883; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      4.579      0.34     -87    25
# Comp:  1                 Hbeta      9.285      0.34     -87    25
# Comp:  1                Halpha      35.82      0.34     -87    25
# Comp:  2             [SII]6716      9.623      0.35     -90    31
# Comp:  2             [SII]6731      6.397      0.35     -90    31
# Comp:  2              HeII4687     0.1765      0.35     -90    31
# Comp:  2               HeI5876     0.5751      0.35     -90    31
# Comp:  2          [OIII]5007_d      11.36      0.44     -90    31
# Comp:  2            [OI]6300_d      2.452      0.44     -90    31
# Comp:  2           [NII]6583_d      12.59      0.44     -90    31
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.75370413, 0.48850374, 0.79669763, 0.45922495, 0.38972091,
#        0.14868483, 0.0953122 , 0.62915122, 0.33632752, 0.45806706])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([4.26266087e+00, 9.78936613e+00, 4.94990360e+01, 1.32118020e+01,
#        9.17934515e+00, 2.46698069e-02, 7.88857505e-01, 1.25154710e+01,
#        3.55529023e+00, 1.77785773e+01])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_4_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_4", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_4_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_4_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_4_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0        Hgamma  0.153642    0.027166
# 1         Hbeta  0.352846    0.017608
# 2        Halpha  1.784132    0.028716
# 3     [SII]6716  0.476203    0.016552
# 4     [SII]6731  0.330858    0.014047
# 5      HeII4687  0.000889    0.005359
# 6       HeI5876  0.028433    0.003435
# 7  [OIII]5007_d  0.451105    0.022677
# 8    [OI]6300_d  0.128146    0.012123
# 9   [NII]6583_d  0.640807    0.016510
#           Name      Flux  Error_flux
# 0       Hgamma  0.153642    0.027166
# 1        Hbeta  0.352846    0.017608
# 2       Halpha  1.784132    0.028716
# 3    [SII]6716  0.476203    0.016552
# 4    [SII]6731  0.330858    0.014047
# 5     HeII4687  0.000889    0.005359
# 6      HeI5876  0.028433    0.003435
# 7   [OIII]4959  0.112776    0.022677
# 8   [OIII]5007  0.338329    0.022677
# 9     [OI]6300  0.096110    0.012123
# 10    [OI]6364  0.032037    0.012123
# 11   [NII]6548  0.160202    0.016510
# 12   [NII]6583  0.480605    0.016510

# %%
np.median(flux_rf_rebin)
# Out:
# 0.03604377862644535
