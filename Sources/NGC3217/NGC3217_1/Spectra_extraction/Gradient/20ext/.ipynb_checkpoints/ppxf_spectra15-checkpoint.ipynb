# %%
# %matplotlib widget

# %%
from pathlib import Path
from urllib import request

from astropy.io import fits
import numpy as np

import matplotlib.pyplot as plt

from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from ppxf.ppxf import losvd_rfft, rebin

import pandas as pd

# %% [markdown]
# ### Function to iteratively clip the outliers

# %%
def clip_outliers(galaxy, bestfit, mask):
    """
    Repeat the fit after clipping bins deviants more than 3*sigma in relative
    error until the bad bins don't change any more. This function uses eq.(34)
    of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    while True:
        scale = galaxy[mask] @ bestfit[mask]/np.sum(bestfit[mask]**2)
        resid = scale*bestfit[mask] - galaxy[mask]                   #Evaluate the residuals and the dispersion of them  
        err = robust_sigma(resid, zero=1)
        ok_old = mask
        mask = np.abs(bestfit - galaxy) < 3*err
        if np.array_equal(mask, ok_old):
            break
            
    return mask

# %% [markdown]
# ### Function to fit the stellar kinematics without outliers

# %%
def ppxf_fit_and_clean(templates, galaxy, velscale, start, mask0, lam, lam_temp, plot=True, quiet=False):
    """
    This is a simple pPXF wrapper. It perform two pPXF fits: the first one
    serves to estimate the scatter in the spectrum and identify the outlier
    pixels. The second fit uses the mask obtained from the first fit to exclude
    the outliers. The general approach used in this function is described in
    Sec.6.5 of Cappellari (2023) https://ui.adsabs.harvard.edu/abs/2023MNRAS.526.3273C
    """
    mask = mask0.copy()     #Initial mask 
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,      #Fit without the mask
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)              

    if plot:
        plt.figure(figsize=(20, 3))
        plt.subplot(121)
        pp.plot()
        plt.title("Initial pPXF fit before outliers removal")

    mask = clip_outliers(galaxy, pp.bestfit, mask)

    # Add clipped pixels to the original masked emission lines regions and repeat the fit
    mask &= mask0     #To mask also the outliers together with the emission lines
    pp = ppxf(templates, galaxy, np.ones_like(galaxy), velscale, start,
              moments=2, degree=4, mdegree=-1, lam=lam, lam_temp=lam_temp,
              mask=mask, quiet=quiet)
    
    pp.optimal_template = templates.reshape(templates.shape[0], -1) @ pp.weights #Combined weighted templates to obtain the best template
    
    resid = (pp.galaxy - pp.bestfit)[pp.goodpixels]
    pp.sn = np.nanmedian(pp.galaxy[pp.goodpixels])/robust_sigma(resid)  #S/N of the residual spectrum (after the fit), only of the good pixels

    if plot:
        plt.subplot(122)
        pp.plot()
        plt.title("pPXF fit after outliers removal")

    return pp

# %%
wv, flux, error = np.loadtxt('Spectrum_15.txt', unpack = True)
#red = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_553/FORS2.2021-08-21T06_02_18.000/Spectra_extraction/redshift.txt", unpack = True)
z = 0.03191
wv_mask = wv > 4451
wv_filtered = wv[wv_mask]
wv_rf = wv_filtered/(1+z)
flux_rf = flux[wv_mask]*(1+z)
#error_rf = error[wv_mask]*(1+z)
noises = pd.read_csv("Noise_20ext_continuum.csv", index_col=0)
noise = np.round(np.mean(noises['Spectrum_15']), 3)
error = np.ones(len(wv_rf))*noise
error_rf = error*(1+z)

# %%
print(wv_rf, flux_rf, error_rf)
# Out:
# [4314.03901503 4315.47324864 4316.90748224 ... 6874.1460011  6875.58023471
#  6877.01446832] [0.09892132 0.12732172 0.11348751 ... 0.10216488 0.10004029 0.09938755] [0.00928719 0.00928719 0.00928719 ... 0.00928719 0.00928719 0.00928719]

# %%
# sps_name = 'fsps'
# sps_name = 'galaxev'
sps_name = 'emiles'
# sps_name = 'xsl'

# %%
ppxf_dir = Path(lib.__file__).parent
basename = f"spectra_{sps_name}_9.0.npz"
filename = ppxf_dir / 'sps_models' / basename
if not filename.is_file():
    url = "https://raw.githubusercontent.com/micappe/ppxf_data/main/" + basename
    request.urlretrieve(url, filename)

# %%
c = 299792.458  # speed of light in km/s
velscale = np.min(c*np.diff(np.log(wv_rf))) #velocity scale to quantify the galaxy velocity dispersion
flux_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, flux_rf, velscale = velscale) #We need to rebin the flux and the other things to work with the code
norm = np.median(flux_rf_rebin)
galaxy = flux_rf_rebin/norm #Normalization
error_rf_rebin, wv_rf_rebin, velscale = util.log_rebin(wv_rf, error_rf, velscale = velscale)
error_gal = error_rf_rebin/norm

# %%
velscale
# Out:
# 62.52964314399511

# %%
R = 2000 #risoluzione FORS2
fwhm_gal = (wv_rf/R)
print(fwhm_gal)
# Out:
# [2.15701951 2.15773662 2.15845374 ... 3.437073   3.43779012 3.43850723]

# %%
fwhm_gal_dic = {"lam": wv_rf, "fwhm": fwhm_gal}
sps = lib.sps_lib(filename, velscale, fwhm_gal_dic)

# %%
reg_dim = sps.templates.shape[1:]
stars_templates = sps.templates.reshape(sps.templates.shape[0], -1)
ln_lam_pop_stars = sps.ln_lam_temp

mask = (np.exp(ln_lam_pop_stars) > (np.min(wv_rf)-500))*(np.exp(ln_lam_pop_stars) < (np.max(wv_rf)+500))
stars_templates = stars_templates[mask, :]
lam_temp = sps.lam_temp
lam_temp = lam_temp[mask]

stars_templates /= np.median(stars_templates, axis=0)
ln_lam_pop_stars = ln_lam_pop_stars[mask]

plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, 0])
plt.plot(np.exp(ln_lam_pop_stars), stars_templates[:, -1])
plt.xlim(4000, 7000)
stars_templates.shape
# Out:
# (3162, 150)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.mean(c*np.diff((ln_lam_pop_stars)))
# Out:
# 62.529643143995116

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
lam_range_temp = np.exp(sps.ln_lam_temp[[0, -1]])
mask0 = util.determine_mask(wv_rf_rebin, lam_range_temp, 0, width=1000)


#def determine_mask(ln_lam, lam_range_temp, redshift=0, width=800):
#    Generates a mask to avoid fitting the region possibly contaminated by a
#    given set of gas emission lines. This is meant to be used as input for pPXF.
#    Here ``mask = True`` for the pixels to include in the fit.
#
#    :param ln_lam: Natural logarithm np.log(wave) of the wavelength in
#        Angstrom of each pixel of the log rebinned *galaxy* spectrum.
#    :param lam_range_temp: Two elements vectors [lam_min_temp, lam_max_temp]
#        with the minimum and maximum wavelength in Angstrom in the stellar
#        *template* used in pPXF.
#    :param z: Estimate of the galaxy redshift.
#    :width: width of the emission line in km/s to mask it
#    :return: boolean vector mask to be used as input for pPXF

# %%
stars_templates.shape
# Out:
# (3162, 150)

# %%
sps.lam_temp.shape
# Out:
# (16269,)

# %%
start = [20, 180.] 
pp_stars = ppxf_fit_and_clean(stars_templates, galaxy, velscale, start, mask0, np.exp(wv_rf_rebin), lam_temp)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        16
# chi2/DOF: 0.005034; DOF: 1910; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/150
#  Best Fit:       Vel     sigma
#  comp.  0:       -21        23
# chi2/DOF: 0.003495; DOF: 1885; degree = 4; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/150
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pp_stars.sol
# Out:
# array([-21.17271125,  22.73893452])

# %% [markdown]
# ## Fit with emission lines

# %%
tie_balmer = False  #Set this to ``True`` to tie the Balmer lines according to a theoretical decrement
limit_doublets = False #Set this to True to limit the ratio of the [OII] and [SII] doublets to the ranges allowed by atomic physics.

lam_range_gal = np.array([np.min(wv_rf), np.max(wv_rf)]) #Range of wv for the data
gas_templates, gas_names, line_wave = util.emission_lines(
    ln_lam_pop_stars, lam_range_gal, fwhm_gal_dic, tie_balmer=tie_balmer,
    limit_doublets=limit_doublets)
# Out:
# Emission lines included in gas templates:
# ['Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687' 'HeI5876'
#  '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
templates = np.column_stack([stars_templates, gas_templates])
start = [20, 180.] 
results = [pp_stars.sol[0], pp_stars.sol[1]]

# %%
n_temps = stars_templates.shape[1]
n_forbidden = np.sum(["[" in a for a in gas_names])+ np.sum(["He" in a for a in gas_names]) # forbidden lines contain "[*]" AND He!!!
n_balmer = len(gas_names) - n_forbidden

# %%
n_forbidden
# Out:
# 7

# %%
component = [0]*n_temps + [1]*n_balmer + [2]*n_forbidden #When fitting more than one kinematic component, this keyword should contain the component number of each input template. 
                                                         #In principle, every template can belong to a different kinematic component.

gas_component = np.array(component) > 0  # gas_component=True for gas templates
                                         #Boolean vector, of the same size as component, set to True where the given component describes a gas emission line. 
                                         #If given, pPXF provides the pp.gas_flux and pp.gas_flux_error in output.

# %%
moments = [2, 2, 2]
start = [results, start, start]
gas_reddening = 0 if tie_balmer else None

# %%
pp = ppxf(templates, galaxy, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening)
#print(f"Elapsed time in pPXF: {(clock() - t):.2f}")
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -36         1
#  comp.  1:       -16        14
#  comp.  2:       -19        29
# chi2/DOF: 1.075; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.217      0.16     -16    14
# Comp:  1                 Hbeta      18.30      0.16     -16    14
# Comp:  1                Halpha      37.13      0.16     -16    14
# Comp:  2             [SII]6716      6.506      0.16     -19    29
# Comp:  2             [SII]6731      4.679      0.16     -19    29
# Comp:  2              HeII4687      0.000      0.16     -19    29
# Comp:  2               HeI5876      1.724      0.16     -19    29
# Comp:  2          [OIII]5007_d      13.13      0.21     -19    29
# Comp:  2            [OI]6300_d      1.665      0.21     -19    29
# Comp:  2           [NII]6583_d      14.37      0.21     -19    29
# -----------------------------------------------------------------

# %% [markdown]
# Ricordati che i d contengono il flusso di entrambi i doppietti.

# %%
plt.figure(figsize=(15, 5))
pp.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Conversion from ergs/(cm^2 s A) to ergs/(cm^2 s)

# %%
rms = robust_sigma(galaxy - pp.bestfit, zero=1)
real_flux = np.zeros(len(gas_names))
dlam = np.zeros(len(gas_names))
for kk in range(len(gas_names)):
    dlam[kk] = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
    #print(dlam)
    real_flux[kk] = (pp.gas_flux[kk]*dlam[kk])  # Convert to ergs/(cm^2 s)
    an = np.max(pp.gas_bestfit_templates[:, kk])/rms
    print(f"{gas_names[kk]:12s} - Amplitude/Noise: {an:6.4g}; gas flux: {real_flux[kk]:6.0f} ergs/(cm^2 s)")
# Out:
# Hgamma       - Amplitude/Noise:  46.77; gas flux:      7 ergs/(cm^2 s)
# Hbeta        - Amplitude/Noise:  104.3; gas flux:     19 ergs/(cm^2 s)
# Halpha       - Amplitude/Noise:  200.1; gas flux:     51 ergs/(cm^2 s)
# [SII]6716    - Amplitude/Noise:  34.17; gas flux:      9 ergs/(cm^2 s)
# [SII]6731    - Amplitude/Noise:  24.99; gas flux:      7 ergs/(cm^2 s)
# HeII4687     - Amplitude/Noise:      0; gas flux:      0 ergs/(cm^2 s)
# HeI5876      - Amplitude/Noise:  9.528; gas flux:      2 ergs/(cm^2 s)
# [OIII]5007_d - Amplitude/Noise:  55.08; gas flux:     14 ergs/(cm^2 s)
# [OI]6300_d   - Amplitude/Noise:  6.825; gas flux:      2 ergs/(cm^2 s)
# [NII]6583_d  - Amplitude/Noise:   55.4; gas flux:     20 ergs/(cm^2 s)

# %%
dlam
# Out:
# array([0.90531991, 1.01395952, 1.36884942, 1.40089107, 1.4038896 ,
#        0.97732735, 1.22551473, 1.04430955, 1.31409362, 1.37315307])

# %%
line_wave
# Out:
# array([4340.47067429, 4861.33297684, 6562.81902144, 6716.43970813,
#        6730.81584054, 4685.70352776, 5875.61444265, 5006.8433303 ,
#        6300.29755334, 6583.45247411])

# %% [markdown]
# ### Bootstrapping to find the real errors

# %%
def bootstrap_residuals(model, resid, wild=True):
    """
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Resampling_residuals
    https://en.wikipedia.org/wiki/Bootstrapping_(statistics)#Wild_bootstrap

    Davidson & Flachaire (2008) eq.(12) gives the recommended form
    of the wild bootstrapping probability used here.

    https://doi.org/10.1016/j.jeconom.2008.08.003

    :param spec: model (e.g. best fitting spectrum)
    :param res: residuals (best_fit - observed)
    :param wild: use wild bootstrap to allow for variable errors
    :return: new model with bootstrapped residuals

    """
    if wild:    # Wild Bootstrapping: generates -resid or resid with prob=1/2
        eps = resid*(2*np.random.randint(2, size=resid.size) - 1)
    else:       # Standard Bootstrapping: random selection with repetition
        eps = np.random.choice(resid, size=resid.size)

    return model + eps

# %%
bestfit0 = pp.bestfit.copy()
resid = galaxy - bestfit0
start = pp.sol.copy()

# %%
np.random.seed(123)

plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5, 2))
plt.subplots_adjust(hspace=0.04)
plt.subplots_adjust(wspace=0.02)

nboot = 500
flux_i = np.empty((nboot, pp.gas_flux.size))
for j in range(nboot):

    galaxy1 = bootstrap_residuals(bestfit0, resid)

    pp_b = ppxf(templates, galaxy1, error_gal, velscale, start, moments=moments,     #We put what we had set here to do the ppxf procedure
          degree=7, mdegree=-1, lam=np.exp(wv_rf_rebin), lam_temp=np.exp(ln_lam_pop_stars), component=component,
          gas_component=gas_component, gas_names=gas_names,
          gas_reddening=gas_reddening, bias = 0)

    real_flux_b = np.zeros(len(gas_names))
    for kk in range(len(gas_names)):
        dlam = line_wave[kk]*velscale/c  # Angstrom per pixel at line wavelength (dlam/lam = dv/c)
        real_flux_b[kk] = (pp_b.gas_flux[kk]*dlam)
    flux_i[j] = real_flux_b

flux_err_boot = flux_i.std(axis=0)
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       -45         1
#  comp.  1:       -16        11
#  comp.  2:       -21        26
# chi2/DOF: 0.9949; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.095      0.16     -16    11
# Comp:  1                 Hbeta      19.89      0.16     -16    11
# Comp:  1                Halpha      36.45      0.16     -16    11
# Comp:  2             [SII]6716      6.492      0.16     -21    26
# Comp:  2             [SII]6731      4.600      0.16     -21    26
# Comp:  2              HeII4687      0.000      0.16     -21    26
# Comp:  2               HeI5876      1.546      0.16     -21    26
# Comp:  2          [OIII]5007_d      13.02      0.21     -21    26
# Comp:  2            [OI]6300_d      1.636      0.21     -21    26
# Comp:  2           [NII]6583_d      14.28      0.21     -21    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -22        44
#  comp.  1:       -17         6
#  comp.  2:       -19        28
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.595      0.16     -17     6
# Comp:  1                 Hbeta      18.29      0.16     -17     6
# Comp:  1                Halpha      36.75      0.16     -17     6
# Comp:  2             [SII]6716      6.393      0.16     -19    28
# Comp:  2             [SII]6731      4.560      0.16     -19    28
# Comp:  2              HeII4687      0.000      0.16     -19    28
# Comp:  2               HeI5876      2.353      0.16     -19    28
# Comp:  2          [OIII]5007_d      13.31      0.21     -19    28
# Comp:  2            [OI]6300_d      1.677      0.21     -19    28
# Comp:  2           [NII]6583_d      14.46      0.21     -19    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43        17
#  comp.  1:       -18         7
#  comp.  2:       -20        23
# chi2/DOF: 1.037; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.079      0.16     -18     7
# Comp:  1                 Hbeta      17.94      0.16     -18     7
# Comp:  1                Halpha      36.47      0.16     -18     7
# Comp:  2             [SII]6716      6.289      0.16     -20    23
# Comp:  2             [SII]6731      4.735      0.16     -20    23
# Comp:  2              HeII4687      0.000      0.16     -20    23
# Comp:  2               HeI5876      1.817      0.16     -20    23
# Comp:  2          [OIII]5007_d      13.17      0.20     -20    23
# Comp:  2            [OI]6300_d      1.649      0.20     -20    23
# Comp:  2           [NII]6583_d      14.22      0.20     -20    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
#  comp.  1:       -19         1
#  comp.  2:       -17        33
# chi2/DOF: 0.9549; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 20; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.921      0.16     -19     1
# Comp:  1                 Hbeta      16.22      0.16     -19     1
# Comp:  1                Halpha      36.65      0.16     -19     1
# Comp:  2             [SII]6716      6.510      0.17     -17    33
# Comp:  2             [SII]6731      4.869      0.17     -17    33
# Comp:  2              HeII4687      0.000      0.17     -17    33
# Comp:  2               HeI5876      1.616      0.17     -17    33
# Comp:  2          [OIII]5007_d      13.15      0.21     -17    33
# Comp:  2            [OI]6300_d      1.730      0.21     -17    33
# Comp:  2           [NII]6583_d      14.55      0.21     -17    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -8        51
#  comp.  1:       -15         1
#  comp.  2:       -19        33
# chi2/DOF: 1.010; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.919      0.16     -15     1
# Comp:  1                 Hbeta      18.41      0.16     -15     1
# Comp:  1                Halpha      37.23      0.16     -15     1
# Comp:  2             [SII]6716      6.539      0.17     -19    33
# Comp:  2             [SII]6731      4.686      0.17     -19    33
# Comp:  2              HeII4687    0.07149      0.17     -19    33
# Comp:  2               HeI5876      1.510      0.17     -19    33
# Comp:  2          [OIII]5007_d      13.79      0.21     -19    33
# Comp:  2            [OI]6300_d      1.727      0.21     -19    33
# Comp:  2           [NII]6583_d      14.45      0.21     -19    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -5        43
#  comp.  1:       -16         3
#  comp.  2:       -18        30
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 84; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.864      0.16     -16     3
# Comp:  1                 Hbeta      18.34      0.16     -16     3
# Comp:  1                Halpha      37.48      0.16     -16     3
# Comp:  2             [SII]6716      6.466      0.16     -18    30
# Comp:  2             [SII]6731      4.490      0.16     -18    30
# Comp:  2              HeII4687      0.000      0.16     -18    30
# Comp:  2               HeI5876      2.346      0.16     -18    30
# Comp:  2          [OIII]5007_d      13.31      0.21     -18    30
# Comp:  2            [OI]6300_d      1.644      0.21     -18    30
# Comp:  2           [NII]6583_d      14.57      0.21     -18    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        48
#  comp.  1:       -12        20
#  comp.  2:       -21        25
# chi2/DOF: 0.9403; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 44; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.112      0.16     -12    20
# Comp:  1                 Hbeta      20.23      0.16     -12    20
# Comp:  1                Halpha      37.78      0.16     -12    20
# Comp:  2             [SII]6716      6.514      0.16     -21    25
# Comp:  2             [SII]6731      4.553      0.16     -21    25
# Comp:  2              HeII4687     0.1524      0.16     -21    25
# Comp:  2               HeI5876      2.222      0.16     -21    25
# Comp:  2          [OIII]5007_d      12.86      0.20     -21    25
# Comp:  2            [OI]6300_d      1.658      0.20     -21    25
# Comp:  2           [NII]6583_d      14.36      0.20     -21    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
#  comp.  1:       -16         1
#  comp.  2:       -21        28
# chi2/DOF: 1.002; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.530      0.16     -16     1
# Comp:  1                 Hbeta      19.93      0.16     -16     1
# Comp:  1                Halpha      36.78      0.16     -16     1
# Comp:  2             [SII]6716      6.492      0.16     -21    28
# Comp:  2             [SII]6731      4.432      0.16     -21    28
# Comp:  2              HeII4687      0.000      0.16     -21    28
# Comp:  2               HeI5876      1.895      0.16     -21    28
# Comp:  2          [OIII]5007_d      13.09      0.21     -21    28
# Comp:  2            [OI]6300_d      1.614      0.21     -21    28
# Comp:  2           [NII]6583_d      14.18      0.21     -21    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        49
#  comp.  1:       -19         1
#  comp.  2:       -19        24
# chi2/DOF: 0.9556; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 15/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.857      0.16     -19     1
# Comp:  1                 Hbeta      18.53      0.16     -19     1
# Comp:  1                Halpha      36.56      0.16     -19     1
# Comp:  2             [SII]6716      6.478      0.16     -19    24
# Comp:  2             [SII]6731      4.546      0.16     -19    24
# Comp:  2              HeII4687     0.1228      0.16     -19    24
# Comp:  2               HeI5876      1.745      0.16     -19    24
# Comp:  2          [OIII]5007_d      12.60      0.20     -19    24
# Comp:  2            [OI]6300_d      1.678      0.20     -19    24
# Comp:  2           [NII]6583_d      14.28      0.20     -19    24
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -16        20
#  comp.  1:       -13        27
#  comp.  2:       -18        30
# chi2/DOF: 0.9267; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.387      0.16     -13    27
# Comp:  1                 Hbeta      21.34      0.16     -13    27
# Comp:  1                Halpha      38.48      0.16     -13    27
# Comp:  2             [SII]6716      6.466      0.16     -18    30
# Comp:  2             [SII]6731      4.764      0.16     -18    30
# Comp:  2              HeII4687   0.006176      0.16     -18    30
# Comp:  2               HeI5876      1.878      0.16     -18    30
# Comp:  2          [OIII]5007_d      13.22      0.21     -18    30
# Comp:  2            [OI]6300_d      1.707      0.21     -18    30
# Comp:  2           [NII]6583_d      14.39      0.21     -18    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        47
#  comp.  1:       -19         1
#  comp.  2:       -18        34
# chi2/DOF: 0.9460; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 48; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.632      0.16     -19     1
# Comp:  1                 Hbeta      17.13      0.16     -19     1
# Comp:  1                Halpha      36.75      0.16     -19     1
# Comp:  2             [SII]6716      6.638      0.17     -18    34
# Comp:  2             [SII]6731      4.620      0.17     -18    34
# Comp:  2              HeII4687      0.000      0.17     -18    34
# Comp:  2               HeI5876      1.920      0.17     -18    34
# Comp:  2          [OIII]5007_d      13.34      0.21     -18    34
# Comp:  2            [OI]6300_d      1.701      0.21     -18    34
# Comp:  2           [NII]6583_d      14.78      0.21     -18    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -58        35
#  comp.  1:       -13        28
#  comp.  2:       -20        25
# chi2/DOF: 0.8856; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.606      0.16     -13    28
# Comp:  1                 Hbeta      20.87      0.16     -13    28
# Comp:  1                Halpha      39.33      0.16     -13    28
# Comp:  2             [SII]6716      6.490      0.16     -20    25
# Comp:  2             [SII]6731      4.709      0.16     -20    25
# Comp:  2              HeII4687    0.01064      0.16     -20    25
# Comp:  2               HeI5876      1.372      0.16     -20    25
# Comp:  2          [OIII]5007_d      12.98      0.21     -20    25
# Comp:  2            [OI]6300_d      1.697      0.21     -20    25
# Comp:  2           [NII]6583_d      14.12      0.21     -20    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35        36
#  comp.  1:       -14        17
#  comp.  2:       -18        25
# chi2/DOF: 1.033; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.886      0.16     -14    17
# Comp:  1                 Hbeta      18.07      0.16     -14    17
# Comp:  1                Halpha      37.84      0.16     -14    17
# Comp:  2             [SII]6716      6.407      0.16     -18    25
# Comp:  2             [SII]6731      4.541      0.16     -18    25
# Comp:  2              HeII4687    0.06449      0.16     -18    25
# Comp:  2               HeI5876      1.819      0.16     -18    25
# Comp:  2          [OIII]5007_d      12.55      0.20     -18    25
# Comp:  2            [OI]6300_d      1.643      0.20     -18    25
# Comp:  2           [NII]6583_d      14.25      0.20     -18    25
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44        43
#  comp.  1:       -14        20
#  comp.  2:       -18        33
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.474      0.16     -14    20
# Comp:  1                 Hbeta      18.70      0.16     -14    20
# Comp:  1                Halpha      38.32      0.16     -14    20
# Comp:  2             [SII]6716      6.657      0.17     -18    33
# Comp:  2             [SII]6731      4.886      0.17     -18    33
# Comp:  2              HeII4687    0.05387      0.17     -18    33
# Comp:  2               HeI5876      1.658      0.17     -18    33
# Comp:  2          [OIII]5007_d      13.15      0.21     -18    33
# Comp:  2            [OI]6300_d      1.671      0.21     -18    33
# Comp:  2           [NII]6583_d      14.48      0.21     -18    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -11         1
#  comp.  1:       -17         1
#  comp.  2:       -20        22
# chi2/DOF: 1.014; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.961      0.16     -17     1
# Comp:  1                 Hbeta      18.44      0.16     -17     1
# Comp:  1                Halpha      36.63      0.16     -17     1
# Comp:  2             [SII]6716      6.398      0.16     -20    22
# Comp:  2             [SII]6731      4.358      0.16     -20    22
# Comp:  2              HeII4687    0.02472      0.16     -20    22
# Comp:  2               HeI5876      1.648      0.16     -20    22
# Comp:  2          [OIII]5007_d      13.16      0.20     -20    22
# Comp:  2            [OI]6300_d      1.661      0.20     -20    22
# Comp:  2           [NII]6583_d      13.85      0.20     -20    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        15
#  comp.  1:       -15         3
#  comp.  2:       -18        28
# chi2/DOF: 1.030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.140      0.16     -15     3
# Comp:  1                 Hbeta      18.14      0.16     -15     3
# Comp:  1                Halpha      37.39      0.16     -15     3
# Comp:  2             [SII]6716      6.536      0.16     -18    28
# Comp:  2             [SII]6731      4.410      0.16     -18    28
# Comp:  2              HeII4687    0.04269      0.16     -18    28
# Comp:  2               HeI5876      2.027      0.16     -18    28
# Comp:  2          [OIII]5007_d      12.68      0.21     -18    28
# Comp:  2            [OI]6300_d      1.703      0.21     -18    28
# Comp:  2           [NII]6583_d      14.23      0.21     -18    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -39         1
#  comp.  1:       -18         1
#  comp.  2:       -19        29
# chi2/DOF: 1.003; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.081      0.16     -18     1
# Comp:  1                 Hbeta      17.98      0.16     -18     1
# Comp:  1                Halpha      36.45      0.16     -18     1
# Comp:  2             [SII]6716      6.524      0.16     -19    29
# Comp:  2             [SII]6731      4.614      0.16     -19    29
# Comp:  2              HeII4687      0.000      0.16     -19    29
# Comp:  2               HeI5876      1.766      0.16     -19    29
# Comp:  2          [OIII]5007_d      12.73      0.21     -19    29
# Comp:  2            [OI]6300_d      1.699      0.21     -19    29
# Comp:  2           [NII]6583_d      14.50      0.21     -19    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -40        47
#  comp.  1:       -16        15
#  comp.  2:       -18        26
# chi2/DOF: 1.035; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.407      0.16     -16    15
# Comp:  1                 Hbeta      18.39      0.16     -16    15
# Comp:  1                Halpha      37.54      0.16     -16    15
# Comp:  2             [SII]6716      6.475      0.16     -18    26
# Comp:  2             [SII]6731      4.666      0.16     -18    26
# Comp:  2              HeII4687    0.05964      0.16     -18    26
# Comp:  2               HeI5876      2.032      0.16     -18    26
# Comp:  2          [OIII]5007_d      12.78      0.21     -18    26
# Comp:  2            [OI]6300_d      1.642      0.21     -18    26
# Comp:  2           [NII]6583_d      14.19      0.21     -18    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -43         1
#  comp.  1:       -14        19
#  comp.  2:       -20        27
# chi2/DOF: 0.9726; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.997      0.16     -14    19
# Comp:  1                 Hbeta      20.14      0.16     -14    19
# Comp:  1                Halpha      37.43      0.16     -14    19
# Comp:  2             [SII]6716      6.448      0.16     -20    27
# Comp:  2             [SII]6731      4.446      0.16     -20    27
# Comp:  2              HeII4687      0.000      0.16     -20    27
# Comp:  2               HeI5876      2.251      0.16     -20    27
# Comp:  2          [OIII]5007_d      12.77      0.21     -20    27
# Comp:  2            [OI]6300_d      1.658      0.21     -20    27
# Comp:  2           [NII]6583_d      14.20      0.21     -20    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52         1
#  comp.  1:       -17         1
#  comp.  2:       -19        33
# chi2/DOF: 1.048; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 4; Func calls: 30; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.683      0.16     -17     1
# Comp:  1                 Hbeta      17.94      0.16     -17     1
# Comp:  1                Halpha      36.56      0.16     -17     1
# Comp:  2             [SII]6716      6.585      0.17     -19    33
# Comp:  2             [SII]6731      4.527      0.17     -19    33
# Comp:  2              HeII4687    0.05975      0.17     -19    33
# Comp:  2               HeI5876      1.919      0.17     -19    33
# Comp:  2          [OIII]5007_d      13.38      0.21     -19    33
# Comp:  2            [OI]6300_d      1.728      0.21     -19    33
# Comp:  2           [NII]6583_d      14.21      0.21     -19    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38        17
#  comp.  1:       -18         1
#  comp.  2:       -19        22
# chi2/DOF: 0.9737; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.411      0.16     -18     1
# Comp:  1                 Hbeta      16.70      0.16     -18     1
# Comp:  1                Halpha      36.50      0.16     -18     1
# Comp:  2             [SII]6716      6.295      0.16     -19    22
# Comp:  2             [SII]6731      4.481      0.16     -19    22
# Comp:  2              HeII4687    0.07501      0.16     -19    22
# Comp:  2               HeI5876      1.714      0.16     -19    22
# Comp:  2          [OIII]5007_d      12.63      0.20     -19    22
# Comp:  2            [OI]6300_d      1.611      0.20     -19    22
# Comp:  2           [NII]6583_d      14.01      0.20     -19    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28        49
#  comp.  1:       -18         1
#  comp.  2:       -20        30
# chi2/DOF: 0.9675; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.858      0.16     -18     1
# Comp:  1                 Hbeta      16.29      0.16     -18     1
# Comp:  1                Halpha      36.35      0.16     -18     1
# Comp:  2             [SII]6716      6.503      0.16     -20    30
# Comp:  2             [SII]6731      4.753      0.16     -20    30
# Comp:  2              HeII4687      0.000      0.16     -20    30
# Comp:  2               HeI5876      1.737      0.16     -20    30
# Comp:  2          [OIII]5007_d      13.03      0.21     -20    30
# Comp:  2            [OI]6300_d      1.638      0.21     -20    30
# Comp:  2           [NII]6583_d      14.62      0.21     -20    30
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -18        35
#  comp.  1:       -14        23
#  comp.  2:       -20        23
# chi2/DOF: 1.020; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 6; Func calls: 46; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.620      0.16     -14    23
# Comp:  1                 Hbeta      18.96      0.16     -14    23
# Comp:  1                Halpha      38.38      0.16     -14    23
# Comp:  2             [SII]6716      6.373      0.16     -20    23
# Comp:  2             [SII]6731      4.822      0.16     -20    23
# Comp:  2              HeII4687    0.02749      0.16     -20    23
# Comp:  2               HeI5876      1.676      0.16     -20    23
# Comp:  2          [OIII]5007_d      12.74      0.20     -20    23
# Comp:  2            [OI]6300_d      1.600      0.20     -20    23
# Comp:  2           [NII]6583_d      14.17      0.20     -20    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -37        35
#  comp.  1:       -16         4
#  comp.  2:       -17        36
# chi2/DOF: 0.9787; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 84; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.470      0.16     -16     4
# Comp:  1                 Hbeta      20.00      0.16     -16     4
# Comp:  1                Halpha      36.89      0.16     -16     4
# Comp:  2             [SII]6716      6.645      0.17     -17    36
# Comp:  2             [SII]6731      4.578      0.17     -17    36
# Comp:  2              HeII4687      0.000      0.17     -17    36
# Comp:  2               HeI5876      2.100      0.17     -17    36
# Comp:  2          [OIII]5007_d      13.57      0.21     -17    36
# Comp:  2            [OI]6300_d      1.712      0.21     -17    36
# Comp:  2           [NII]6583_d      14.73      0.21     -17    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0         1
#  comp.  1:       -17         1
#  comp.  2:       -20        28
# chi2/DOF: 1.021; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.018      0.16     -17     1
# Comp:  1                 Hbeta      18.64      0.16     -17     1
# Comp:  1                Halpha      37.04      0.16     -17     1
# Comp:  2             [SII]6716      6.453      0.16     -20    28
# Comp:  2             [SII]6731      4.462      0.16     -20    28
# Comp:  2              HeII4687      0.000      0.16     -20    28
# Comp:  2               HeI5876      1.914      0.16     -20    28
# Comp:  2          [OIII]5007_d      13.09      0.21     -20    28
# Comp:  2            [OI]6300_d      1.604      0.21     -20    28
# Comp:  2           [NII]6583_d      14.46      0.21     -20    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        60
#  comp.  1:       -18         1
#  comp.  2:       -20        27
# chi2/DOF: 0.9684; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.104      0.16     -18     1
# Comp:  1                 Hbeta      18.66      0.16     -18     1
# Comp:  1                Halpha      36.92      0.16     -18     1
# Comp:  2             [SII]6716      6.500      0.16     -20    27
# Comp:  2             [SII]6731      4.806      0.16     -20    27
# Comp:  2              HeII4687      0.000      0.16     -20    27
# Comp:  2               HeI5876      1.344      0.16     -20    27
# Comp:  2          [OIII]5007_d      13.25      0.21     -20    27
# Comp:  2            [OI]6300_d      1.607      0.21     -20    27
# Comp:  2           [NII]6583_d      14.30      0.21     -20    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -44         1
#  comp.  1:       -13        27
#  comp.  2:       -18        31
# chi2/DOF: 0.9201; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.821      0.16     -13    27
# Comp:  1                 Hbeta      20.79      0.16     -13    27
# Comp:  1                Halpha      38.80      0.16     -13    27
# Comp:  2             [SII]6716      6.440      0.16     -18    31
# Comp:  2             [SII]6731      4.659      0.16     -18    31
# Comp:  2              HeII4687      0.000      0.16     -18    31
# Comp:  2               HeI5876      1.639      0.16     -18    31
# Comp:  2          [OIII]5007_d      12.98      0.21     -18    31
# Comp:  2            [OI]6300_d      1.637      0.21     -18    31
# Comp:  2           [NII]6583_d      14.46      0.21     -18    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -13        30
#  comp.  1:       -17         9
#  comp.  2:       -19        27
# chi2/DOF: 1.032; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.714      0.16     -17     9
# Comp:  1                 Hbeta      18.59      0.16     -17     9
# Comp:  1                Halpha      37.59      0.16     -17     9
# Comp:  2             [SII]6716      6.449      0.16     -19    27
# Comp:  2             [SII]6731      4.544      0.16     -19    27
# Comp:  2              HeII4687      0.000      0.16     -19    27
# Comp:  2               HeI5876      1.186      0.16     -19    27
# Comp:  2          [OIII]5007_d      12.75      0.21     -19    27
# Comp:  2            [OI]6300_d      1.621      0.21     -19    27
# Comp:  2           [NII]6583_d      14.48      0.21     -19    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41         1
#  comp.  1:       -15        23
#  comp.  2:       -16        33
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.099      0.16     -15    23
# Comp:  1                 Hbeta      18.68      0.16     -15    23
# Comp:  1                Halpha      37.04      0.16     -15    23
# Comp:  2             [SII]6716      6.621      0.17     -16    33
# Comp:  2             [SII]6731      4.850      0.17     -16    33
# Comp:  2              HeII4687      0.000      0.17     -16    33
# Comp:  2               HeI5876      1.616      0.17     -16    33
# Comp:  2          [OIII]5007_d      13.54      0.21     -16    33
# Comp:  2            [OI]6300_d      1.631      0.21     -16    33
# Comp:  2           [NII]6583_d      14.72      0.21     -16    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         0        47
#  comp.  1:       -17        12
#  comp.  2:       -17        35
# chi2/DOF: 1.040; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.898      0.16     -17    12
# Comp:  1                 Hbeta      18.83      0.16     -17    12
# Comp:  1                Halpha      37.19      0.16     -17    12
# Comp:  2             [SII]6716      6.642      0.17     -17    35
# Comp:  2             [SII]6731      4.732      0.17     -17    35
# Comp:  2              HeII4687      0.000      0.17     -17    35
# Comp:  2               HeI5876      1.725      0.17     -17    35
# Comp:  2          [OIII]5007_d      13.66      0.21     -17    35
# Comp:  2            [OI]6300_d      1.611      0.21     -17    35
# Comp:  2           [NII]6583_d      14.57      0.21     -17    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -0        49
#  comp.  1:       -15         1
#  comp.  2:       -18        32
# chi2/DOF: 1.027; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 11; Func calls: 84; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.637      0.16     -15     1
# Comp:  1                 Hbeta      18.46      0.16     -15     1
# Comp:  1                Halpha      37.28      0.16     -15     1
# Comp:  2             [SII]6716      6.572      0.17     -18    32
# Comp:  2             [SII]6731      4.933      0.17     -18    32
# Comp:  2              HeII4687      0.000      0.17     -18    32
# Comp:  2               HeI5876      1.151      0.17     -18    32
# Comp:  2          [OIII]5007_d      13.72      0.21     -18    32
# Comp:  2            [OI]6300_d      1.583      0.21     -18    32
# Comp:  2           [NII]6583_d      14.42      0.21     -18    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -16         9
#  comp.  2:       -19        28
# chi2/DOF: 0.9745; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.497      0.16     -16     9
# Comp:  1                 Hbeta      19.60      0.16     -16     9
# Comp:  1                Halpha      36.10      0.16     -16     9
# Comp:  2             [SII]6716      6.459      0.16     -19    28
# Comp:  2             [SII]6731      4.452      0.16     -19    28
# Comp:  2              HeII4687  0.0007885      0.16     -19    28
# Comp:  2               HeI5876      1.770      0.16     -19    28
# Comp:  2          [OIII]5007_d      12.66      0.21     -19    28
# Comp:  2            [OI]6300_d      1.647      0.21     -19    28
# Comp:  2           [NII]6583_d      14.60      0.21     -19    28
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        56
#  comp.  1:       -18         1
#  comp.  2:       -21        26
# chi2/DOF: 0.9971; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.706      0.16     -18     1
# Comp:  1                 Hbeta      18.36      0.16     -18     1
# Comp:  1                Halpha      36.09      0.16     -18     1
# Comp:  2             [SII]6716      6.429      0.16     -21    26
# Comp:  2             [SII]6731      4.383      0.16     -21    26
# Comp:  2              HeII4687      0.000      0.16     -21    26
# Comp:  2               HeI5876      1.194      0.16     -21    26
# Comp:  2          [OIII]5007_d      13.04      0.21     -21    26
# Comp:  2            [OI]6300_d      1.581      0.21     -21    26
# Comp:  2           [NII]6583_d      14.36      0.21     -21    26
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -41         1
#  comp.  1:       -14        18
#  comp.  2:       -16        31
# chi2/DOF: 0.9880; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.224      0.16     -14    18
# Comp:  1                 Hbeta      20.20      0.16     -14    18
# Comp:  1                Halpha      36.83      0.16     -14    18
# Comp:  2             [SII]6716      6.558      0.16     -16    31
# Comp:  2             [SII]6731      4.731      0.16     -16    31
# Comp:  2              HeII4687    0.07650      0.16     -16    31
# Comp:  2               HeI5876      1.860      0.16     -16    31
# Comp:  2          [OIII]5007_d      13.35      0.21     -16    31
# Comp:  2            [OI]6300_d      1.715      0.21     -16    31
# Comp:  2           [NII]6583_d      14.31      0.21     -16    31
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -10        33
#  comp.  1:       -16         7
#  comp.  2:       -19        27
# chi2/DOF: 0.9622; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.872      0.16     -16     7
# Comp:  1                 Hbeta      17.06      0.16     -16     7
# Comp:  1                Halpha      37.71      0.16     -16     7
# Comp:  2             [SII]6716      6.453      0.16     -19    27
# Comp:  2             [SII]6731      4.441      0.16     -19    27
# Comp:  2              HeII4687      0.000      0.16     -19    27
# Comp:  2               HeI5876      1.580      0.16     -19    27
# Comp:  2          [OIII]5007_d      12.73      0.21     -19    27
# Comp:  2            [OI]6300_d      1.658      0.21     -19    27
# Comp:  2           [NII]6583_d      14.38      0.21     -19    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -80        48
#  comp.  1:       -15        24
#  comp.  2:       -19        23
# chi2/DOF: 1.017; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.379      0.16     -15    24
# Comp:  1                 Hbeta      18.77      0.16     -15    24
# Comp:  1                Halpha      37.92      0.16     -15    24
# Comp:  2             [SII]6716      6.389      0.16     -19    23
# Comp:  2             [SII]6731      4.673      0.16     -19    23
# Comp:  2              HeII4687     0.1294      0.16     -19    23
# Comp:  2               HeI5876      1.376      0.16     -19    23
# Comp:  2          [OIII]5007_d      12.83      0.20     -19    23
# Comp:  2            [OI]6300_d      1.618      0.20     -19    23
# Comp:  2           [NII]6583_d      13.97      0.20     -19    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -55        55
#  comp.  1:       -18         1
#  comp.  2:       -18        33
# chi2/DOF: 0.9392; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 9; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 11/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.893      0.16     -18     1
# Comp:  1                 Hbeta      16.41      0.16     -18     1
# Comp:  1                Halpha      36.68      0.16     -18     1
# Comp:  2             [SII]6716      6.639      0.17     -18    33
# Comp:  2             [SII]6731      4.592      0.17     -18    33
# Comp:  2              HeII4687      0.000      0.17     -18    33
# Comp:  2               HeI5876      2.068      0.17     -18    33
# Comp:  2          [OIII]5007_d      13.39      0.21     -18    33
# Comp:  2            [OI]6300_d      1.690      0.21     -18    33
# Comp:  2           [NII]6583_d      14.66      0.21     -18    33
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -20        68
#  comp.  1:       -19         1
#  comp.  2:       -20        23
# chi2/DOF: 0.9192; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.793      0.16     -19     1
# Comp:  1                 Hbeta      16.99      0.16     -19     1
# Comp:  1                Halpha      36.76      0.16     -19     1
# Comp:  2             [SII]6716      6.389      0.16     -20    23
# Comp:  2             [SII]6731      4.520      0.16     -20    23
# Comp:  2              HeII4687      0.000      0.16     -20    23
# Comp:  2               HeI5876      2.131      0.16     -20    23
# Comp:  2          [OIII]5007_d      12.52      0.20     -20    23
# Comp:  2            [OI]6300_d      1.673      0.20     -20    23
# Comp:  2           [NII]6583_d      14.15      0.20     -20    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -28         1
#  comp.  1:       -16        10
#  comp.  2:       -18        23
# chi2/DOF: 1.046; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.833      0.16     -16    10
# Comp:  1                 Hbeta      18.30      0.16     -16    10
# Comp:  1                Halpha      36.82      0.16     -16    10
# Comp:  2             [SII]6716      6.344      0.16     -18    23
# Comp:  2             [SII]6731      4.563      0.16     -18    23
# Comp:  2              HeII4687    0.07216      0.16     -18    23
# Comp:  2               HeI5876      1.801      0.16     -18    23
# Comp:  2          [OIII]5007_d      12.56      0.20     -18    23
# Comp:  2            [OI]6300_d      1.711      0.20     -18    23
# Comp:  2           [NII]6583_d      14.17      0.20     -18    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -3        47
#  comp.  1:       -16         5
#  comp.  2:       -21        23
# chi2/DOF: 1.032; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:        -7        27
#  comp.  1:       -18        16
#  comp.  2:       -17        32
# chi2/DOF: 1.001; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.885      0.16     -18    16
# Comp:  1                 Hbeta      17.31      0.16     -18    16
# Comp:  1                Halpha      37.45      0.16     -18    16
# Comp:  2             [SII]6716      6.513      0.17     -17    32
# Comp:  2             [SII]6731      4.729      0.17     -17    32
# Comp:  2              HeII4687    0.01927      0.17     -17    32
# Comp:  2               HeI5876      1.693      0.17     -17    32
# Comp:  2          [OIII]5007_d      13.68      0.21     -17    32
# Comp:  2            [OI]6300_d      1.683      0.21     -17    32
# Comp:  2           [NII]6583_d      14.52      0.21     -17    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -50         1
#  comp.  1:       -16        10
#  comp.  2:       -16        35
# chi2/DOF: 1.016; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 2; Func calls: 16; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.302      0.16     -16    10
# Comp:  1                 Hbeta      19.85      0.16     -16    10
# Comp:  1                Halpha      36.61      0.16     -16    10
# Comp:  2             [SII]6716      6.609      0.17     -16    35
# Comp:  2             [SII]6731      4.889      0.17     -16    35
# Comp:  2              HeII4687      0.000      0.17     -16    35
# Comp:  2               HeI5876      1.743      0.17     -16    35
# Comp:  2          [OIII]5007_d      13.68      0.21     -16    35
# Comp:  2            [OI]6300_d      1.676      0.21     -16    35
# Comp:  2           [NII]6583_d      14.58      0.21     -16    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -27        23
#  comp.  1:       -12        23
#  comp.  2:       -17        35
# chi2/DOF: 0.9601; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 64; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 12/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.134      0.16     -12    23
# Comp:  1                 Hbeta      20.71      0.16     -12    23
# Comp:  1                Halpha      38.03      0.16     -12    23
# Comp:  2             [SII]6716      6.671      0.17     -17    35
# Comp:  2             [SII]6731      4.755      0.17     -17    35
# Comp:  2              HeII4687      0.000      0.17     -17    35
# Comp:  2               HeI5876      2.095      0.17     -17    35
# Comp:  2          [OIII]5007_d      13.32      0.21     -17    35
# Comp:  2            [OI]6300_d      1.745      0.21     -17    35
# Comp:  2           [NII]6583_d      14.78      0.21     -17    35
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        45
#  comp.  1:       -15        23
#  comp.  2:       -17        29
# chi2/DOF: 0.9772; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.498      0.16     -15    23
# Comp:  1                 Hbeta      16.80      0.16     -15    23
# Comp:  1                Halpha      38.60      0.16     -15    23
# Comp:  2             [SII]6716      6.487      0.16     -17    29
# Comp:  2             [SII]6731      4.726      0.16     -17    29
# Comp:  2              HeII4687    0.06395      0.16     -17    29
# Comp:  2               HeI5876      1.418      0.16     -17    29
# Comp:  2          [OIII]5007_d      13.19      0.21     -17    29
# Comp:  2            [OI]6300_d      1.653      0.21     -17    29
# Comp:  2           [NII]6583_d      14.34      0.21     -17    29
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -25        57
#  comp.  1:       -15        22
#  comp.  2:       -18        34
# chi2/DOF: 1.030; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 7; Func calls: 56; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.154      0.16     -15    22
# Comp:  1                 Hbeta      19.24      0.16     -15    22
# Comp:  1                Halpha      38.62      0.16     -15    22
# Comp:  2             [SII]6716      6.530      0.17     -18    34
# Comp:  2             [SII]6731      4.614      0.17     -18    34
# Comp:  2              HeII4687     0.1078      0.17     -18    34
# Comp:  2               HeI5876      1.445      0.17     -18    34
# Comp:  2          [OIII]5007_d      13.26      0.21     -18    34
# Comp:  2            [OI]6300_d      1.714      0.21     -18    34
# Comp:  2           [NII]6583_d      14.82      0.21     -18    34
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -35         1
#  comp.  1:       -14        18
#  comp.  2:       -17        36
# chi2/DOF: 0.9826; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 14/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.883      0.16     -14    18
# Comp:  1                 Hbeta      20.62      0.16     -14    18
# Comp:  1                Halpha      37.49      0.16     -14    18
# Comp:  2             [SII]6716      6.552      0.17     -17    36
# Comp:  2             [SII]6731      4.885      0.17     -17    36
# Comp:  2              HeII4687     0.1424      0.17     -17    36
# Comp:  2               HeI5876      2.126      0.17     -17    36
# Comp:  2          [OIII]5007_d      13.41      0.21     -17    36
# Comp:  2            [OI]6300_d      1.777      0.21     -17    36
# Comp:  2           [NII]6583_d      14.67      0.21     -17    36
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -26        17
#  comp.  1:       -16        11
#  comp.  2:       -17        27
# chi2/DOF: 1.005; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 29; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.785      0.16     -16    11
# Comp:  1                 Hbeta      16.90      0.16     -16    11
# Comp:  1                Halpha      37.30      0.16     -16    11
# Comp:  2             [SII]6716      6.385      0.16     -17    27
# Comp:  2             [SII]6731      4.498      0.16     -17    27
# Comp:  2              HeII4687    0.04746      0.16     -17    27
# Comp:  2               HeI5876      1.832      0.16     -17    27
# Comp:  2          [OIII]5007_d      13.24      0.21     -17    27
# Comp:  2            [OI]6300_d      1.607      0.21     -17    27
# Comp:  2           [NII]6583_d      14.23      0.21     -17    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -12        29
#  comp.  2:       -19        32
# chi2/DOF: 0.9313; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 37; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.373      0.16     -12    29
# Comp:  1                 Hbeta      19.33      0.16     -12    29
# Comp:  1                Halpha      39.21      0.16     -12    29
# Comp:  2             [SII]6716      6.654      0.17     -19    32
# Comp:  2             [SII]6731      4.952      0.17     -19    32
# Comp:  2              HeII4687      0.000      0.17     -19    32
# Comp:  2               HeI5876      1.643      0.17     -19    32
# Comp:  2          [OIII]5007_d      13.59      0.21     -19    32
# Comp:  2            [OI]6300_d      1.685      0.21     -19    32
# Comp:  2           [NII]6583_d      14.45      0.21     -19    32
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:         4        78
#  comp.  1:       -14        21
#  comp.  2:       -20        21
# chi2/DOF: 0.9766; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 63; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      9.090      0.16     -14    21
# Comp:  1                 Hbeta      21.09      0.16     -14    21
# Comp:  1                Halpha      37.97      0.16     -14    21
# Comp:  2             [SII]6716      6.325      0.16     -20    21
# Comp:  2             [SII]6731      4.460      0.16     -20    21
# Comp:  2              HeII4687     0.1435      0.16     -20    21
# Comp:  2               HeI5876      1.883      0.16     -20    21
# Comp:  2          [OIII]5007_d      12.80      0.20     -20    21
# Comp:  2            [OI]6300_d      1.621      0.20     -20    21
# Comp:  2           [NII]6583_d      13.87      0.20     -20    21
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -52        55
#  comp.  1:       -14        24
#  comp.  2:       -20        27
# chi2/DOF: 1.028; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 8; Func calls: 61; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.626      0.16     -14    24
# Comp:  1                 Hbeta      18.98      0.16     -14    24
# Comp:  1                Halpha      38.09      0.16     -14    24
# Comp:  2             [SII]6716      6.435      0.16     -20    27
# Comp:  2             [SII]6731      4.602      0.16     -20    27
# Comp:  2              HeII4687      0.000      0.16     -20    27
# Comp:  2               HeI5876      2.084      0.16     -20    27
# Comp:  2          [OIII]5007_d      13.05      0.21     -20    27
# Comp:  2            [OI]6300_d      1.645      0.21     -20    27
# Comp:  2           [NII]6583_d      14.35      0.21     -20    27
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -48         1
#  comp.  1:       -15        19
#  comp.  2:       -20        23
# chi2/DOF: 1.042; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 5; Func calls: 41; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      8.841      0.16     -15    19
# Comp:  1                 Hbeta      18.78      0.16     -15    19
# Comp:  1                Halpha      37.55      0.16     -15    19
# Comp:  2             [SII]6716      6.359      0.16     -20    23
# Comp:  2             [SII]6731      4.622      0.16     -20    23
# Comp:  2              HeII4687    0.04055      0.16     -20    23
# Comp:  2               HeI5876      1.403      0.16     -20    23
# Comp:  2          [OIII]5007_d      13.03      0.20     -20    23
# Comp:  2            [OI]6300_d      1.643      0.20     -20    23
# Comp:  2           [NII]6583_d      14.24      0.20     -20    23
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -38         1
#  comp.  1:       -17         1
#  comp.  2:       -21        22
# chi2/DOF: 1.049; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 3; Func calls: 23; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.946      0.16     -17     1
# Comp:  1                 Hbeta      18.13      0.16     -17     1
# Comp:  1                Halpha      36.45      0.16     -17     1
# Comp:  2             [SII]6716      6.296      0.16     -21    22
# Comp:  2             [SII]6731      4.600      0.16     -21    22
# Comp:  2              HeII4687      0.000      0.16     -21    22
# Comp:  2               HeI5876      1.282      0.16     -21    22
# Comp:  2          [OIII]5007_d      12.81      0.20     -21    22
# Comp:  2            [OI]6300_d      1.661      0.20     -21    22
# Comp:  2           [NII]6583_d      14.11      0.20     -21    22
# -----------------------------------------------------------------
#  Best Fit:       Vel     sigma
#  comp.  0:       -23        50
#  comp.  1:       -19         1
#  comp.  2:       -20        26
# chi2/DOF: 0.9120; DOF: 2230; degree = 7; mdegree = 0
# method = capfit; Jac calls: 10; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 13/160
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Hgamma      7.783      0.16     -19     1
# Comp:  1                 Hbeta      16.98      0.16     -19     1
# Comp:  1                Halpha      37.16      0.16     -19     1
# Comp:  2             [SII]6716      6.449      0.16     -20    26
# Comp:  2             [SII]6731      4.735      0.16     -20    26
# Comp:  2              HeII4687      0.000      0.16     -20    26
# Comp:  2               HeI5876      1.707      0.16     -20    26
# Comp:  2          [OIII]5007_d      13.06      0.21     -20    26
# Comp:  2            [OI]6300_d      1.664      0.21     -20    26
# Comp:  2           [NII]6583_d      14.40      0.21     -20    26
# -----------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flux_err_boot
# Out:
# array([0.53208778, 1.34182185, 1.14913832, 0.1419162 , 0.21863525,
#        0.04710458, 0.3827949 , 0.37231637, 0.05882927, 0.3402209 ])

# %%
2.14*0.19
# Out:
# 0.4066

# %% [markdown]
# ### Bootstrap distribution

# %%
for i in range(flux_i.shape[1]):
    plt.figure(figsize=(8, 6))
    plt.hist(flux_i[:, i], density = True, bins = 20, edgecolor='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def process_ppxf_results(pp, gas_names, spectrum_name="spectrum", output_dir="./"):
    """
    Automatizza l'elaborazione dei risultati PPXF
    
    Parameters:
    -----------
    pp : oggetto PPXF con risultati del fit
    gas_names : list, nomi delle righe/doppietti dal fit PPXF
    spectrum_name : str, nome base per i file di output
    output_dir : str, directory di output
    
    Returns:
    --------
    dict con i 3 DataFrame creati
    """
    
    # Configurazione doppietti - definisce come separare le righe
    doublet_config = {
        # Nome nel fit PPXF : [nome_riga_blu, nome_riga_rossa, rapporto_blu:rossa]
        '[OIII]5007_d': ['[OIII]4959', '[OIII]5007', '1:3'],  
        '[NII]6583_d': ['[NII]6548', '[NII]6583', '1:3'],       
        '[OI]6300_d': ['[OI]6300', '[OI]6364', '3:1'],        #blu forte, rosso debole (caso speciale)
     #   '[SII]6731_d1': '[SII]6716',
     #   '[SII]6731_d2': '[SII]6731'
    }
    
    def separate_doublet(flux_total, ratio_type):
        if ratio_type == '1:3':  
            flux_blue = flux_total * (1/4)
            flux_red = flux_total * (3/4)
        elif ratio_type == '3:1':  
            flux_blue = flux_total * (3/4)
            flux_red = flux_total * (1/4)
        else:
            raise ValueError(f"Ratio type {ratio_type} not supported")
        
        return flux_blue, flux_red
    
    # 2. DataFrame con righe separate  
    expanded_names = []
    expanded_fluxes = []
    expanded_errors = []
    
    for i, name in enumerate(gas_names):
        flux = real_flux[i]*norm
        error = flux_err_boot[i]*norm
        
        if name in doublet_config:
            config = doublet_config[name]
            blue_name, red_name, ratio = config

            flux_blue, flux_red = separate_doublet(flux, ratio)
                
            expanded_names.extend([blue_name, red_name])
            expanded_fluxes.extend([flux_blue, flux_red])
            expanded_errors.extend([error, error])
            
        else:
            expanded_names.append(name)
            expanded_fluxes.append(flux)
            expanded_errors.append(error)
    
    df_expanded = pd.DataFrame({
        'Name': expanded_names,
        'Flux': expanded_fluxes,
        'Error_flux': expanded_errors})
    
    # Salva i file CSV
    output_files = {'expanded': f"{output_dir}/{spectrum_name}_gas_exp.csv", }
    df_expanded.to_csv(output_files['expanded'], index=False)

# %%
real_flux
# Out:
# array([ 7.43873322, 18.55495224, 50.82002635,  9.11357622,  6.56833814,
#         0.        ,  2.11301385, 13.71058501,  2.18797196, 19.73536838])

# %%
d1 = {'Flux': real_flux*norm, 'Error flux': flux_err_boot*norm}
df1 = pd.DataFrame(data=d1, index=gas_names)
df1.index.name = 'Line'
df1.to_csv("Spectrum_15_gas_ppxf.csv", index=True) 
process_ppxf_results(pp, gas_names, spectrum_name="Spectrum_15", output_dir="./")

d3 = {'Vel': [pp.sol[0][0], pp.sol[1][0], pp.sol[2][0]], 'Sigma': [pp.sol[0][1], pp.sol[1][1], pp.sol[2][1]]}
df3 = pd.DataFrame(data=d3, index=[0, 1, 2])
df3.index.name = 'Component'
df3.to_csv("Spectrum_15_kin.csv", index=True)

# %%
read = pd.read_csv("Spectrum_15_gas_ppxf.csv")
print(read)
read2 = pd.read_csv("Spectrum_15_gas_exp.csv")
print(read2)
# Out:
#            Line      Flux  Error flux
# 0        Hgamma  0.852939    0.061010
# 1         Hbeta  2.127544    0.153856
# 2        Halpha  5.827116    0.131762
# 3     [SII]6716  1.044979    0.016272
# 4     [SII]6731  0.753137    0.025069
# 5      HeII4687  0.000000    0.005401
# 6       HeI5876  0.242282    0.043892
# 7  [OIII]5007_d  1.572080    0.042690
# 8    [OI]6300_d  0.250877    0.006745
# 9   [NII]6583_d  2.262893    0.039010
#           Name      Flux  Error_flux
# 0       Hgamma  0.852939    0.061010
# 1        Hbeta  2.127544    0.153856
# 2       Halpha  5.827116    0.131762
# 3    [SII]6716  1.044979    0.016272
# 4    [SII]6731  0.753137    0.025069
# 5     HeII4687  0.000000    0.005401
# 6      HeI5876  0.242282    0.043892
# 7   [OIII]4959  0.393020    0.042690
# 8   [OIII]5007  1.179060    0.042690
# 9     [OI]6300  0.188158    0.006745
# 10    [OI]6364  0.062719    0.006745
# 11   [NII]6548  0.565723    0.039010
# 12   [NII]6583  1.697170    0.039010

# %%
np.median(flux_rf_rebin)
# Out:
# 0.11466179936035308
