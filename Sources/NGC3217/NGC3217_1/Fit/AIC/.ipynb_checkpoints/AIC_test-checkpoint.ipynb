# %%
# %matplotlib widget

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_1/NGC-3217_1_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_1/NGC-3217_1_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     367   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        48   (2094, 964)   float32

# %%
image_cut = image[67:167, 0:1890]
image_error_cut = image_error[67:167, 0:1890]

# %%
wavelengths = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wavelengths, y)
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
z = 0.03191
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC3217/NGC3217_1/PSF/Real_seeing_NGC3217_1.txt")
sigma = seeing[0] / 2.35

# %%
l_OIII
# Out:
# 5166.773370000001

# %%
#Ogni punto del flusso è il risultato della somma di 20 lunghezze d'onda 
mask_HA = (wavelengths > l_HA-8)*(wavelengths < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

#Define the function for the aic
#Per l'AIC test usiamo il chi quadro perchè il numero di conteggi è elevato (S/N grande) 
#quindi Poisson --> Gauss
#def chi_quad(x, y, y_err, params):
#    return np.sum((((y - model_convolved(x, *params)) / y_err)**2))
    
def AIC(x, y, chi, params): #k=number of model parameter, N=number of data points
    return chi + 2*len(params) +((2*len(params)*(len(params)+1))/(len(y)-len(params)-1))

def BIC(x, y, chi, params):
        return chi + len(params)*np.log(len(y))
    
def sersic_1d_convolved(x, I_e, r_e, n, x_0):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def save_params(params_curve, covariance, radial_profile, radial_profile_error, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, chi2

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params) 
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (25, 35),  # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params1 = result.x

print("Optimize parameters with differential_evolution:", best_params1)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 121.74313545245535
# differential_evolution step 2: f(x)= 121.74313545245535
# differential_evolution step 3: f(x)= 118.39244460525236
# differential_evolution step 4: f(x)= 114.66720570555376
# differential_evolution step 5: f(x)= 112.82889016637783
# differential_evolution step 6: f(x)= 112.82889016637783
# differential_evolution step 7: f(x)= 112.82889016637783
# differential_evolution step 8: f(x)= 109.0118692500401
# differential_evolution step 9: f(x)= 108.0548922257081
# differential_evolution step 10: f(x)= 106.82234864294531
# differential_evolution step 11: f(x)= 106.82234864294531
# differential_evolution step 12: f(x)= 104.97585193745067
# differential_evolution step 13: f(x)= 104.97585193745067
# differential_evolution step 14: f(x)= 104.97585193745067
# differential_evolution step 15: f(x)= 104.51120489157248
# differential_evolution step 16: f(x)= 101.34575955036075
# differential_evolution step 17: f(x)= 101.01036646316425
# differential_evolution step 18: f(x)= 100.7542824492606
# differential_evolution step 19: f(x)= 100.7542824492606
# differential_evolution step 20: f(x)= 100.41766301109513
# differential_evolution step 21: f(x)= 99.39275705565356
# differential_evolution step 22: f(x)= 99.39275705565356
# differential_evolution step 23: f(x)= 99.39275705565356
# differential_evolution step 24: f(x)= 99.39275705565356
# differential_evolution step 25: f(x)= 99.39275705565356
# differential_evolution step 26: f(x)= 99.38640085636398
# differential_evolution step 27: f(x)= 99.36706055053159
# differential_evolution step 28: f(x)= 99.36706055053159
# differential_evolution step 29: f(x)= 99.36706055053159
# differential_evolution step 30: f(x)= 99.22194997740549
# differential_evolution step 31: f(x)= 99.22194997740549
# differential_evolution step 32: f(x)= 99.1718950354651
# differential_evolution step 33: f(x)= 99.15637546209481
# differential_evolution step 34: f(x)= 99.15314910099072
# differential_evolution step 35: f(x)= 99.15314910099072
# differential_evolution step 36: f(x)= 99.09674781110654
# differential_evolution step 37: f(x)= 99.09674781110654
# differential_evolution step 38: f(x)= 99.09674781110654
# differential_evolution step 39: f(x)= 99.09674781110654
# differential_evolution step 40: f(x)= 99.09674781110654
# differential_evolution step 41: f(x)= 99.09674781110654
# differential_evolution step 42: f(x)= 99.09674781110654
# differential_evolution step 43: f(x)= 99.09674781110654
# differential_evolution step 44: f(x)= 99.09294514311055
# differential_evolution step 45: f(x)= 99.09294514311055
# differential_evolution step 46: f(x)= 99.09294514311055
# differential_evolution step 47: f(x)= 99.09294514311055
# differential_evolution step 48: f(x)= 99.090264958125
# differential_evolution step 49: f(x)= 99.0877632003146
# differential_evolution step 50: f(x)= 99.08743525341299
# differential_evolution step 51: f(x)= 99.08629593288782
# differential_evolution step 52: f(x)= 99.08629593288782
# differential_evolution step 53: f(x)= 99.08629593288782
# differential_evolution step 54: f(x)= 99.08629593288782
# differential_evolution step 55: f(x)= 99.08585374854297
# differential_evolution step 56: f(x)= 99.08585374854297
# differential_evolution step 57: f(x)= 99.08585374854297
# differential_evolution step 58: f(x)= 99.08585374854297
# differential_evolution step 59: f(x)= 99.08585374854297
# differential_evolution step 60: f(x)= 99.08556163052599
# differential_evolution step 61: f(x)= 99.08556163052599
# differential_evolution step 62: f(x)= 99.08538210665098
# differential_evolution step 63: f(x)= 99.08538210665098
# differential_evolution step 64: f(x)= 99.08538210665098
# differential_evolution step 65: f(x)= 99.08536822769729
# differential_evolution step 66: f(x)= 99.08528543556737
# differential_evolution step 67: f(x)= 99.08528543556737
# differential_evolution step 68: f(x)= 99.08522811470401
# differential_evolution step 69: f(x)= 99.08522811470401
# differential_evolution step 70: f(x)= 99.08522811470401
# differential_evolution step 71: f(x)= 99.08522811470401
# differential_evolution step 72: f(x)= 99.08522811470401
# differential_evolution step 73: f(x)= 99.08522811470401
# differential_evolution step 74: f(x)= 99.08521212382722
# differential_evolution step 75: f(x)= 99.08521212382722
# differential_evolution step 76: f(x)= 99.08521212382722
# differential_evolution step 77: f(x)= 99.08521212382722
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [ 1.38399142 20.32562494  0.34318989 35.        ]
# Chi quadro minimo: 99.08520560501485

# %%
# Plots:
aic = np.zeros(7)
bic = np.zeros(7)
chi_quadr = np.zeros(7)
chi_quadro = np.zeros(7)
red_chi = np.zeros(7)

params_curve_1, covariance_1 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params1,
                                         sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[0], red_chi[0] = save_params(params_curve_1, covariance_1, radial_profile_HA, radial_profile_error_HA, x_axes, 1, line_name="One", 
                                           output_prefix="fit")

aic[0] = AIC(x_axes, radial_profile_HA, chi_quadr[0], params_curve_1)
bic[0] = BIC(x_axes, radial_profile_HA, chi_quadr[0], params_curve_1)
print(aic[0], chi_quadro[0], bic[0], len(params_curve_1))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_1)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_1), 'b--', label='Sérsic 1')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)
plt.savefig('AIC_1', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.1698, r_e=22.4740, n=0.1222, x_0=46.4523
# [0.11502181 3.47576546 0.04905853 0.84328095]
# 1202.725971615537
# 1211.147024247116 0.0 1221.1466523594893 4
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =  [
     (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (25, 35),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (40, 50),
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params2 = result.x

print("Optimize parameters with differential_evolution:", best_params2)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 158.24629411151582
# differential_evolution step 2: f(x)= 102.66294195983967
# differential_evolution step 3: f(x)= 102.66294195983967
# differential_evolution step 4: f(x)= 102.66294195983967
# differential_evolution step 5: f(x)= 102.66294195983967
# differential_evolution step 6: f(x)= 89.6335787617677
# differential_evolution step 7: f(x)= 78.85105517748482
# differential_evolution step 8: f(x)= 57.30695223269922
# differential_evolution step 9: f(x)= 57.30695223269922
# differential_evolution step 10: f(x)= 54.34059824959352
# differential_evolution step 11: f(x)= 54.34059824959352
# differential_evolution step 12: f(x)= 54.34059824959352
# differential_evolution step 13: f(x)= 42.70650126354799
# differential_evolution step 14: f(x)= 42.70650126354799
# differential_evolution step 15: f(x)= 42.70650126354799
# differential_evolution step 16: f(x)= 42.70650126354799
# differential_evolution step 17: f(x)= 33.22253279481652
# differential_evolution step 18: f(x)= 33.22253279481652
# differential_evolution step 19: f(x)= 32.4419131858471
# differential_evolution step 20: f(x)= 32.4419131858471
# differential_evolution step 21: f(x)= 29.857209446491826
# differential_evolution step 22: f(x)= 26.357157452424904
# differential_evolution step 23: f(x)= 21.178349187809847
# differential_evolution step 24: f(x)= 21.178349187809847
# differential_evolution step 25: f(x)= 21.178349187809847
# differential_evolution step 26: f(x)= 21.178349187809847
# differential_evolution step 27: f(x)= 19.511855182225762
# differential_evolution step 28: f(x)= 19.511855182225762
# differential_evolution step 29: f(x)= 19.511855182225762
# differential_evolution step 30: f(x)= 19.511855182225762
# differential_evolution step 31: f(x)= 19.511855182225762
# differential_evolution step 32: f(x)= 19.511855182225762
# differential_evolution step 33: f(x)= 19.511855182225762
# differential_evolution step 34: f(x)= 18.763679609603503
# differential_evolution step 35: f(x)= 17.575546931907937
# differential_evolution step 36: f(x)= 17.575546931907937
# differential_evolution step 37: f(x)= 17.498627476226638
# differential_evolution step 38: f(x)= 17.498627476226638
# differential_evolution step 39: f(x)= 15.880149261771233
# differential_evolution step 40: f(x)= 15.880149261771233
# differential_evolution step 41: f(x)= 15.880149261771233
# differential_evolution step 42: f(x)= 15.880149261771233
# differential_evolution step 43: f(x)= 15.880149261771233
# differential_evolution step 44: f(x)= 15.880149261771233
# differential_evolution step 45: f(x)= 15.880149261771233
# differential_evolution step 46: f(x)= 15.880149261771233
# differential_evolution step 47: f(x)= 15.880149261771233
# differential_evolution step 48: f(x)= 15.862638918204196
# differential_evolution step 49: f(x)= 15.862638918204196
# differential_evolution step 50: f(x)= 15.862638918204196
# differential_evolution step 51: f(x)= 15.862638918204196
# differential_evolution step 52: f(x)= 15.862638918204196
# differential_evolution step 53: f(x)= 14.993693837898897
# differential_evolution step 54: f(x)= 14.993693837898897
# differential_evolution step 55: f(x)= 14.993693837898897
# differential_evolution step 56: f(x)= 14.993693837898897
# differential_evolution step 57: f(x)= 14.993693837898897
# differential_evolution step 58: f(x)= 14.993693837898897
# differential_evolution step 59: f(x)= 14.993693837898897
# differential_evolution step 60: f(x)= 14.993693837898897
# differential_evolution step 61: f(x)= 14.993693837898897
# differential_evolution step 62: f(x)= 14.993693837898897
# differential_evolution step 63: f(x)= 14.993693837898897
# differential_evolution step 64: f(x)= 14.993693837898897
# differential_evolution step 65: f(x)= 14.993693837898897
# differential_evolution step 66: f(x)= 14.993693837898897
# differential_evolution step 67: f(x)= 14.943224090963781
# differential_evolution step 68: f(x)= 14.943224090963781
# differential_evolution step 69: f(x)= 14.943224090963781
# differential_evolution step 70: f(x)= 14.943224090963781
# differential_evolution step 71: f(x)= 14.943224090963781
# differential_evolution step 72: f(x)= 14.926296994684124
# differential_evolution step 73: f(x)= 14.926296994684124
# differential_evolution step 74: f(x)= 14.926296994684124
# differential_evolution step 75: f(x)= 14.926296994684124
# differential_evolution step 76: f(x)= 14.926296994684124
# differential_evolution step 77: f(x)= 14.877057451481948
# differential_evolution step 78: f(x)= 14.877057451481948
# differential_evolution step 79: f(x)= 14.877057451481948
# differential_evolution step 80: f(x)= 14.876786331964302
# differential_evolution step 81: f(x)= 14.876786331964302
# differential_evolution step 82: f(x)= 14.84805707877964
# differential_evolution step 83: f(x)= 14.84805707877964
# differential_evolution step 84: f(x)= 14.84805707877964
# differential_evolution step 85: f(x)= 14.835386712748498
# differential_evolution step 86: f(x)= 14.835386712748498
# differential_evolution step 87: f(x)= 14.816920937143461
# differential_evolution step 88: f(x)= 14.816210654535514
# differential_evolution step 89: f(x)= 14.816210654535514
# differential_evolution step 90: f(x)= 14.8025009248409
# differential_evolution step 91: f(x)= 14.8025009248409
# differential_evolution step 92: f(x)= 14.8025009248409
# differential_evolution step 93: f(x)= 14.8025009248409
# differential_evolution step 94: f(x)= 14.8025009248409
# differential_evolution step 95: f(x)= 14.8025009248409
# differential_evolution step 96: f(x)= 14.8025009248409
# differential_evolution step 97: f(x)= 14.8025009248409
# differential_evolution step 98: f(x)= 14.800478608481447
# differential_evolution step 99: f(x)= 14.800478608481447
# differential_evolution step 100: f(x)= 14.800401284660358
# differential_evolution step 101: f(x)= 14.80011103580106
# differential_evolution step 102: f(x)= 14.80011103580106
# differential_evolution step 103: f(x)= 14.798460686149252
# differential_evolution step 104: f(x)= 14.798460686149252
# differential_evolution step 105: f(x)= 14.798460686149252
# differential_evolution step 106: f(x)= 14.795751723084734
# differential_evolution step 107: f(x)= 14.795751723084734
# differential_evolution step 108: f(x)= 14.795751723084734
# differential_evolution step 109: f(x)= 14.795751723084734
# differential_evolution step 110: f(x)= 14.795751723084734
# differential_evolution step 111: f(x)= 14.792289842941678
# differential_evolution step 112: f(x)= 14.792289842941678
# differential_evolution step 113: f(x)= 14.792289842941678
# differential_evolution step 114: f(x)= 14.792289842941678
# differential_evolution step 115: f(x)= 14.792289842941678
# differential_evolution step 116: f(x)= 14.792289842941678
# differential_evolution step 117: f(x)= 14.792289842941678
# differential_evolution step 118: f(x)= 14.791685364891086
# differential_evolution step 119: f(x)= 14.791611910521498
# differential_evolution step 120: f(x)= 14.791611910521498
# differential_evolution step 121: f(x)= 14.791611910521498
# differential_evolution step 122: f(x)= 14.791611910521498
# differential_evolution step 123: f(x)= 14.791611910521498
# differential_evolution step 124: f(x)= 14.791611910521498
# differential_evolution step 125: f(x)= 14.790923161250733
# differential_evolution step 126: f(x)= 14.790923161250733
# differential_evolution step 127: f(x)= 14.790923161250733
# differential_evolution step 128: f(x)= 14.790923161250733
# differential_evolution step 129: f(x)= 14.790923161250733
# differential_evolution step 130: f(x)= 14.790923161250733
# differential_evolution step 131: f(x)= 14.790923161250733
# differential_evolution step 132: f(x)= 14.790923161250733
# differential_evolution step 133: f(x)= 14.790923161250733
# differential_evolution step 134: f(x)= 14.790923161250733
# differential_evolution step 135: f(x)= 14.790923161250733
# differential_evolution step 136: f(x)= 14.790923161250733
# differential_evolution step 137: f(x)= 14.790923161250733
# differential_evolution step 138: f(x)= 14.790923161250733
# differential_evolution step 139: f(x)= 14.79073020471902
# differential_evolution step 140: f(x)= 14.79073020471902
# differential_evolution step 141: f(x)= 14.79073020471902
# differential_evolution step 142: f(x)= 14.79073020471902
# differential_evolution step 143: f(x)= 14.79073020471902
# differential_evolution step 144: f(x)= 14.79073020471902
# differential_evolution step 145: f(x)= 14.79073020471902
# differential_evolution step 146: f(x)= 14.79073020471902
# differential_evolution step 147: f(x)= 14.79073020471902
# differential_evolution step 148: f(x)= 14.79073020471902
# differential_evolution step 149: f(x)= 14.79073020471902
# differential_evolution step 150: f(x)= 14.79073020471902
# differential_evolution step 151: f(x)= 14.79073020471902
# differential_evolution step 152: f(x)= 14.79073020471902
# differential_evolution step 153: f(x)= 14.79073020471902
# differential_evolution step 154: f(x)= 14.79073020471902
# differential_evolution step 155: f(x)= 14.79073020471902
# differential_evolution step 156: f(x)= 14.79073020471902
# differential_evolution step 157: f(x)= 14.79073020471902
# differential_evolution step 158: f(x)= 14.790557310501354
# differential_evolution step 159: f(x)= 14.790557310501354
# differential_evolution step 160: f(x)= 14.790557310501354
# differential_evolution step 161: f(x)= 14.790557310501354
# differential_evolution step 162: f(x)= 14.790557310501354
# differential_evolution step 163: f(x)= 14.790544754475507
# differential_evolution step 164: f(x)= 14.790506439824854
# differential_evolution step 165: f(x)= 14.79049744009283
# differential_evolution step 166: f(x)= 14.79049744009283
# differential_evolution step 167: f(x)= 14.79049744009283
# differential_evolution step 168: f(x)= 14.79049744009283
# differential_evolution step 169: f(x)= 14.79049744009283
# differential_evolution step 170: f(x)= 14.79049744009283
# differential_evolution step 171: f(x)= 14.79049744009283
# differential_evolution step 172: f(x)= 14.790441887600757
# differential_evolution step 173: f(x)= 14.790441887600757
# differential_evolution step 174: f(x)= 14.790441887600757
# differential_evolution step 175: f(x)= 14.790441887600757
# differential_evolution step 176: f(x)= 14.790441887600757
# differential_evolution step 177: f(x)= 14.790437103598451
# differential_evolution step 178: f(x)= 14.790437103598451
# differential_evolution step 179: f(x)= 14.790410057516864
# differential_evolution step 180: f(x)= 14.790410057516864
# differential_evolution step 181: f(x)= 14.790410057516864
# differential_evolution step 182: f(x)= 14.790410057516864
# differential_evolution step 183: f(x)= 14.790410057516864
# differential_evolution step 184: f(x)= 14.790410057516864
# differential_evolution step 185: f(x)= 14.790410057516864
# differential_evolution step 186: f(x)= 14.790410057516864
# differential_evolution step 187: f(x)= 14.790410057516864
# differential_evolution step 188: f(x)= 14.790410057516864
# differential_evolution step 189: f(x)= 14.790410057516864
# differential_evolution step 190: f(x)= 14.790410057516864
# differential_evolution step 191: f(x)= 14.790410057516864
# differential_evolution step 192: f(x)= 14.790410057516864
# differential_evolution step 193: f(x)= 14.790410057516864
# differential_evolution step 194: f(x)= 14.790406758601176
# differential_evolution step 195: f(x)= 14.790406758601176
# differential_evolution step 196: f(x)= 14.790406758601176
# differential_evolution step 197: f(x)= 14.790406758601176
# differential_evolution step 198: f(x)= 14.790406758601176
# differential_evolution step 199: f(x)= 14.790406758601176
# differential_evolution step 200: f(x)= 14.790406561436482
# differential_evolution step 201: f(x)= 14.790406146720418
# differential_evolution step 202: f(x)= 14.790403431659689
# differential_evolution step 203: f(x)= 14.790403431659689
# differential_evolution step 204: f(x)= 14.790403431659689
# differential_evolution step 205: f(x)= 14.790403431659689
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [ 1.43126678  3.57711467  0.72909181 26.98826675  0.17232462 41.93722912
#   2.06277331 48.75774335]
# Chi quadro minimo: 14.790402116718555

# %%
# Plots:
params_curve_2, covariance_2 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params2, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[1], red_chi[1] = save_params(params_curve_2, covariance_2, radial_profile_HA, radial_profile_error_HA,
    x_axes, 2, line_name="Two", output_prefix="fit")

aic[1] = AIC(x_axes, radial_profile_HA, chi_quadr[1], params_curve_2)
bic[1] = BIC(x_axes, radial_profile_HA, chi_quadr[1], params_curve_2)
print(aic[1], chi_quadr[1], bic[1], len(params_curve_2))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_2)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_2[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_2[4:8]), 'g--', label='Sérsic 2')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_2', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.2562, r_e=4.3757, n=0.8238, x_0=26.9884
# Sérsic 2: I_e=0.3744, r_e=19.9322, n=1.5266, x_0=49.8938
# [0.32318721 0.64051849 0.19581735 0.23478605 0.08643713 3.0536605
#  0.17710521 0.3062948 ]
# 371.88897095659917
# 389.47138853901674 371.88897095659917 408.7303324445039 8
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
     (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (25, 35),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (40, 50),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (65, 75),
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params3 = result.x

print("Optimize parameters with differential_evolution:", best_params3)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 3941.5205074975156
# differential_evolution step 2: f(x)= 3648.3587335073394
# differential_evolution step 3: f(x)= 3648.3587335073394
# differential_evolution step 4: f(x)= 1902.9814516207489
# differential_evolution step 5: f(x)= 283.4978746659589
# differential_evolution step 6: f(x)= 130.36588661345107
# differential_evolution step 7: f(x)= 130.36588661345107
# differential_evolution step 8: f(x)= 130.36588661345107
# differential_evolution step 9: f(x)= 96.71324624261004
# differential_evolution step 10: f(x)= 96.71324624261004
# differential_evolution step 11: f(x)= 61.97884800988707
# differential_evolution step 12: f(x)= 61.97884800988707
# differential_evolution step 13: f(x)= 61.97884800988707
# differential_evolution step 14: f(x)= 61.97884800988707
# differential_evolution step 15: f(x)= 59.45291692911612
# differential_evolution step 16: f(x)= 47.64072052414837
# differential_evolution step 17: f(x)= 38.656205962086894
# differential_evolution step 18: f(x)= 34.165592917696614
# differential_evolution step 19: f(x)= 29.485508065179193
# differential_evolution step 20: f(x)= 29.485508065179193
# differential_evolution step 21: f(x)= 26.986399490331728
# differential_evolution step 22: f(x)= 26.986399490331728
# differential_evolution step 23: f(x)= 26.986399490331728
# differential_evolution step 24: f(x)= 23.075950526262215
# differential_evolution step 25: f(x)= 23.075950526262215
# differential_evolution step 26: f(x)= 23.075950526262215
# differential_evolution step 27: f(x)= 22.388551948765933
# differential_evolution step 28: f(x)= 22.388551948765933
# differential_evolution step 29: f(x)= 16.787775340117626
# differential_evolution step 30: f(x)= 16.787775340117626
# differential_evolution step 31: f(x)= 16.787775340117626
# differential_evolution step 32: f(x)= 16.787775340117626
# differential_evolution step 33: f(x)= 15.28031357587088
# differential_evolution step 34: f(x)= 15.28031357587088
# differential_evolution step 35: f(x)= 15.28031357587088
# differential_evolution step 36: f(x)= 13.509478515567107
# differential_evolution step 37: f(x)= 10.56695532634479
# differential_evolution step 38: f(x)= 10.18686900971665
# differential_evolution step 39: f(x)= 10.18686900971665
# differential_evolution step 40: f(x)= 10.18686900971665
# differential_evolution step 41: f(x)= 10.18686900971665
# differential_evolution step 42: f(x)= 9.972633535422407
# differential_evolution step 43: f(x)= 9.972633535422407
# differential_evolution step 44: f(x)= 9.972633535422407
# differential_evolution step 45: f(x)= 9.972633535422407
# differential_evolution step 46: f(x)= 9.972633535422407
# differential_evolution step 47: f(x)= 9.972633535422407
# differential_evolution step 48: f(x)= 9.972633535422407
# differential_evolution step 49: f(x)= 9.972633535422407
# differential_evolution step 50: f(x)= 9.972633535422407
# differential_evolution step 51: f(x)= 9.972633535422407
# differential_evolution step 52: f(x)= 9.972633535422407
# differential_evolution step 53: f(x)= 9.972633535422407
# differential_evolution step 54: f(x)= 9.972633535422407
# differential_evolution step 55: f(x)= 9.972633535422407
# differential_evolution step 56: f(x)= 9.972633535422407
# differential_evolution step 57: f(x)= 9.972633535422407
# differential_evolution step 58: f(x)= 9.972633535422407
# differential_evolution step 59: f(x)= 9.972633535422407
# differential_evolution step 60: f(x)= 9.972633535422407
# differential_evolution step 61: f(x)= 7.892825341723254
# differential_evolution step 62: f(x)= 7.892825341723254
# differential_evolution step 63: f(x)= 7.892825341723254
# differential_evolution step 64: f(x)= 7.892825341723254
# differential_evolution step 65: f(x)= 7.892825341723254
# differential_evolution step 66: f(x)= 7.892825341723254
# differential_evolution step 67: f(x)= 7.892825341723254
# differential_evolution step 68: f(x)= 7.386240442073723
# differential_evolution step 69: f(x)= 7.386240442073723
# differential_evolution step 70: f(x)= 7.386240442073723
# differential_evolution step 71: f(x)= 7.386240442073723
# differential_evolution step 72: f(x)= 7.386240442073723
# differential_evolution step 73: f(x)= 7.386240442073723
# differential_evolution step 74: f(x)= 7.386240442073723
# differential_evolution step 75: f(x)= 7.386240442073723
# differential_evolution step 76: f(x)= 7.386240442073723
# differential_evolution step 77: f(x)= 7.096772090866775
# differential_evolution step 78: f(x)= 6.752224507143362
# differential_evolution step 79: f(x)= 6.752224507143362
# differential_evolution step 80: f(x)= 6.752224507143362
# differential_evolution step 81: f(x)= 6.752224507143362
# differential_evolution step 82: f(x)= 6.752224507143362
# differential_evolution step 83: f(x)= 6.752224507143362
# differential_evolution step 84: f(x)= 6.752224507143362
# differential_evolution step 85: f(x)= 6.752224507143362
# differential_evolution step 86: f(x)= 6.752224507143362
# differential_evolution step 87: f(x)= 6.752224507143362
# differential_evolution step 88: f(x)= 6.427776633895259
# differential_evolution step 89: f(x)= 6.427776633895259
# differential_evolution step 90: f(x)= 6.427776633895259
# differential_evolution step 91: f(x)= 6.427776633895259
# differential_evolution step 92: f(x)= 6.092674793523043
# differential_evolution step 93: f(x)= 6.092674793523043
# differential_evolution step 94: f(x)= 6.092674793523043
# differential_evolution step 95: f(x)= 6.092674793523043
# differential_evolution step 96: f(x)= 6.092674793523043
# differential_evolution step 97: f(x)= 6.092674793523043
# differential_evolution step 98: f(x)= 5.876584241158992
# differential_evolution step 99: f(x)= 5.876584241158992
# differential_evolution step 100: f(x)= 5.876584241158992
# differential_evolution step 101: f(x)= 5.794311313113491
# differential_evolution step 102: f(x)= 5.794311313113491
# differential_evolution step 103: f(x)= 5.794311313113491
# differential_evolution step 104: f(x)= 5.794311313113491
# differential_evolution step 105: f(x)= 5.60431912121681
# differential_evolution step 106: f(x)= 5.561326575690799
# differential_evolution step 107: f(x)= 5.561326575690799
# differential_evolution step 108: f(x)= 5.561326575690799
# differential_evolution step 109: f(x)= 5.561326575690799
# differential_evolution step 110: f(x)= 5.561326575690799
# differential_evolution step 111: f(x)= 5.561326575690799
# differential_evolution step 112: f(x)= 5.561326575690799
# differential_evolution step 113: f(x)= 5.561326575690799
# differential_evolution step 114: f(x)= 5.561326575690799
# differential_evolution step 115: f(x)= 5.426262467134983
# differential_evolution step 116: f(x)= 5.426262467134983
# differential_evolution step 117: f(x)= 5.426262467134983
# differential_evolution step 118: f(x)= 5.426262467134983
# differential_evolution step 119: f(x)= 5.426262467134983
# differential_evolution step 120: f(x)= 5.426262467134983
# differential_evolution step 121: f(x)= 5.426262467134983
# differential_evolution step 122: f(x)= 5.426262467134983
# differential_evolution step 123: f(x)= 5.426262467134983
# differential_evolution step 124: f(x)= 5.426262467134983
# differential_evolution step 125: f(x)= 5.417410173604851
# differential_evolution step 126: f(x)= 5.417410173604851
# differential_evolution step 127: f(x)= 5.417410173604851
# differential_evolution step 128: f(x)= 5.417410173604851
# differential_evolution step 129: f(x)= 5.417410173604851
# differential_evolution step 130: f(x)= 5.417410173604851
# differential_evolution step 131: f(x)= 5.417410173604851
# differential_evolution step 132: f(x)= 5.417410173604851
# differential_evolution step 133: f(x)= 5.364143695756463
# differential_evolution step 134: f(x)= 5.362863253442955
# differential_evolution step 135: f(x)= 5.362863253442955
# differential_evolution step 136: f(x)= 5.362863253442955
# differential_evolution step 137: f(x)= 5.3313775427851855
# differential_evolution step 138: f(x)= 5.3313775427851855
# differential_evolution step 139: f(x)= 5.3313775427851855
# differential_evolution step 140: f(x)= 5.3313775427851855
# differential_evolution step 141: f(x)= 5.3313775427851855
# differential_evolution step 142: f(x)= 5.3313775427851855
# differential_evolution step 143: f(x)= 5.327325293789527
# differential_evolution step 144: f(x)= 5.327325293789527
# differential_evolution step 145: f(x)= 5.287062658276108
# differential_evolution step 146: f(x)= 5.287062658276108
# differential_evolution step 147: f(x)= 5.287062658276108
# differential_evolution step 148: f(x)= 5.287062658276108
# differential_evolution step 149: f(x)= 5.287062658276108
# differential_evolution step 150: f(x)= 5.287062658276108
# differential_evolution step 151: f(x)= 5.287062658276108
# differential_evolution step 152: f(x)= 5.287062658276108
# differential_evolution step 153: f(x)= 5.287062658276108
# differential_evolution step 154: f(x)= 5.172658185871398
# differential_evolution step 155: f(x)= 5.172658185871398
# differential_evolution step 156: f(x)= 5.172658185871398
# differential_evolution step 157: f(x)= 5.172658185871398
# differential_evolution step 158: f(x)= 5.172658185871398
# differential_evolution step 159: f(x)= 5.172658185871398
# differential_evolution step 160: f(x)= 5.154329173026744
# differential_evolution step 161: f(x)= 5.154329173026744
# differential_evolution step 162: f(x)= 5.154329173026744
# differential_evolution step 163: f(x)= 5.154329173026744
# differential_evolution step 164: f(x)= 5.154329173026744
# differential_evolution step 165: f(x)= 5.154329173026744
# differential_evolution step 166: f(x)= 5.154329173026744
# differential_evolution step 167: f(x)= 5.154329173026744
# differential_evolution step 168: f(x)= 5.154329173026744
# differential_evolution step 169: f(x)= 5.154329173026744
# differential_evolution step 170: f(x)= 5.154329173026744
# differential_evolution step 171: f(x)= 5.132372835088491
# differential_evolution step 172: f(x)= 5.132372835088491
# differential_evolution step 173: f(x)= 5.132372835088491
# differential_evolution step 174: f(x)= 5.127329287207144
# differential_evolution step 175: f(x)= 5.127329287207144
# differential_evolution step 176: f(x)= 5.127329287207144
# differential_evolution step 177: f(x)= 5.10452612372157
# differential_evolution step 178: f(x)= 5.10452612372157
# differential_evolution step 179: f(x)= 5.10452612372157
# differential_evolution step 180: f(x)= 5.10452612372157
# differential_evolution step 181: f(x)= 5.10452612372157
# differential_evolution step 182: f(x)= 5.10452612372157
# differential_evolution step 183: f(x)= 5.10452612372157
# differential_evolution step 184: f(x)= 5.10452612372157
# differential_evolution step 185: f(x)= 5.06296630243374
# differential_evolution step 186: f(x)= 5.06296630243374
# differential_evolution step 187: f(x)= 5.06296630243374
# differential_evolution step 188: f(x)= 5.06296630243374
# differential_evolution step 189: f(x)= 5.062821120195458
# differential_evolution step 190: f(x)= 5.062821120195458
# differential_evolution step 191: f(x)= 5.062821120195458
# differential_evolution step 192: f(x)= 5.062821120195458
# differential_evolution step 193: f(x)= 5.062821120195458
# differential_evolution step 194: f(x)= 5.062821120195458
# differential_evolution step 195: f(x)= 5.062821120195458
# differential_evolution step 196: f(x)= 5.062821120195458
# differential_evolution step 197: f(x)= 5.062821120195458
# differential_evolution step 198: f(x)= 5.062821120195458
# differential_evolution step 199: f(x)= 5.062821120195458
# differential_evolution step 200: f(x)= 5.062821120195458
# differential_evolution step 201: f(x)= 5.062821120195458
# differential_evolution step 202: f(x)= 5.062821120195458
# differential_evolution step 203: f(x)= 5.062821120195458
# differential_evolution step 204: f(x)= 5.062821120195458
# differential_evolution step 205: f(x)= 5.047345035262943
# differential_evolution step 206: f(x)= 5.041069279211902
# differential_evolution step 207: f(x)= 5.041069279211902
# differential_evolution step 208: f(x)= 5.041069279211902
# differential_evolution step 209: f(x)= 5.041069279211902
# differential_evolution step 210: f(x)= 5.041069279211902
# differential_evolution step 211: f(x)= 5.034961215135454
# differential_evolution step 212: f(x)= 5.034961215135454
# differential_evolution step 213: f(x)= 5.0317531009322485
# differential_evolution step 214: f(x)= 5.022825523383082
# differential_evolution step 215: f(x)= 5.022825523383082
# differential_evolution step 216: f(x)= 4.999836424289862
# differential_evolution step 217: f(x)= 4.999836424289862
# differential_evolution step 218: f(x)= 4.999836424289862
# differential_evolution step 219: f(x)= 4.999836424289862
# differential_evolution step 220: f(x)= 4.999836424289862
# differential_evolution step 221: f(x)= 4.999836424289862
# differential_evolution step 222: f(x)= 4.999836424289862
# differential_evolution step 223: f(x)= 4.999836424289862
# differential_evolution step 224: f(x)= 4.999836424289862
# differential_evolution step 225: f(x)= 4.995567056871378
# differential_evolution step 226: f(x)= 4.995567056871378
# differential_evolution step 227: f(x)= 4.995567056871378
# differential_evolution step 228: f(x)= 4.995567056871378
# differential_evolution step 229: f(x)= 4.991745053518428
# differential_evolution step 230: f(x)= 4.991745053518428
# differential_evolution step 231: f(x)= 4.991745053518428
# differential_evolution step 232: f(x)= 4.9855320487483
# differential_evolution step 233: f(x)= 4.98172033963833
# differential_evolution step 234: f(x)= 4.98172033963833
# differential_evolution step 235: f(x)= 4.98172033963833
# differential_evolution step 236: f(x)= 4.98172033963833
# differential_evolution step 237: f(x)= 4.98172033963833
# differential_evolution step 238: f(x)= 4.9791786206375495
# differential_evolution step 239: f(x)= 4.9791786206375495
# differential_evolution step 240: f(x)= 4.9791786206375495
# differential_evolution step 241: f(x)= 4.9791786206375495
# differential_evolution step 242: f(x)= 4.9791786206375495
# differential_evolution step 243: f(x)= 4.954534346400333
# differential_evolution step 244: f(x)= 4.954534346400333
# differential_evolution step 245: f(x)= 4.954534346400333
# differential_evolution step 246: f(x)= 4.954534346400333
# differential_evolution step 247: f(x)= 4.954534346400333
# differential_evolution step 248: f(x)= 4.954534346400333
# differential_evolution step 249: f(x)= 4.954534346400333
# differential_evolution step 250: f(x)= 4.954534346400333
# differential_evolution step 251: f(x)= 4.954534346400333
# differential_evolution step 252: f(x)= 4.954534346400333
# differential_evolution step 253: f(x)= 4.954534346400333
# differential_evolution step 254: f(x)= 4.954534346400333
# differential_evolution step 255: f(x)= 4.954534346400333
# differential_evolution step 256: f(x)= 4.954534346400333
# differential_evolution step 257: f(x)= 4.954534346400333
# differential_evolution step 258: f(x)= 4.954534346400333
# differential_evolution step 259: f(x)= 4.954534346400333
# differential_evolution step 260: f(x)= 4.954534346400333
# differential_evolution step 261: f(x)= 4.954534346400333
# differential_evolution step 262: f(x)= 4.954534346400333
# differential_evolution step 263: f(x)= 4.954534346400333
# differential_evolution step 264: f(x)= 4.954534346400333
# differential_evolution step 265: f(x)= 4.954534346400333
# differential_evolution step 266: f(x)= 4.954534346400333
# differential_evolution step 267: f(x)= 4.954534346400333
# differential_evolution step 268: f(x)= 4.954534346400333
# differential_evolution step 269: f(x)= 4.954534346400333
# differential_evolution step 270: f(x)= 4.954534346400333
# differential_evolution step 271: f(x)= 4.954534346400333
# differential_evolution step 272: f(x)= 4.954534346400333
# differential_evolution step 273: f(x)= 4.954534346400333
# differential_evolution step 274: f(x)= 4.954534346400333
# differential_evolution step 275: f(x)= 4.954534346400333
# differential_evolution step 276: f(x)= 4.954534346400333
# differential_evolution step 277: f(x)= 4.954534346400333
# differential_evolution step 278: f(x)= 4.954534346400333
# differential_evolution step 279: f(x)= 4.951645950227891
# differential_evolution step 280: f(x)= 4.951645950227891
# differential_evolution step 281: f(x)= 4.951645950227891
# differential_evolution step 282: f(x)= 4.951645950227891
# differential_evolution step 283: f(x)= 4.9484628168604665
# differential_evolution step 284: f(x)= 4.9484628168604665
# differential_evolution step 285: f(x)= 4.9484628168604665
# differential_evolution step 286: f(x)= 4.9484628168604665
# differential_evolution step 287: f(x)= 4.9484628168604665
# differential_evolution step 288: f(x)= 4.9484628168604665
# differential_evolution step 289: f(x)= 4.9484628168604665
# differential_evolution step 290: f(x)= 4.947688790471631
# differential_evolution step 291: f(x)= 4.947688790471631
# differential_evolution step 292: f(x)= 4.947688790471631
# differential_evolution step 293: f(x)= 4.945754242482835
# differential_evolution step 294: f(x)= 4.945754242482835
# differential_evolution step 295: f(x)= 4.945754242482835
# differential_evolution step 296: f(x)= 4.945754242482835
# differential_evolution step 297: f(x)= 4.945754242482835
# differential_evolution step 298: f(x)= 4.945754242482835
# differential_evolution step 299: f(x)= 4.945754242482835
# differential_evolution step 300: f(x)= 4.945754242482835
# differential_evolution step 301: f(x)= 4.945754242482835
# differential_evolution step 302: f(x)= 4.945754242482835
# differential_evolution step 303: f(x)= 4.945754242482835
# differential_evolution step 304: f(x)= 4.944958207894251
# differential_evolution step 305: f(x)= 4.944958207894251
# differential_evolution step 306: f(x)= 4.944958207894251
# differential_evolution step 307: f(x)= 4.944958207894251
# differential_evolution step 308: f(x)= 4.94471462475297
# differential_evolution step 309: f(x)= 4.94471462475297
# differential_evolution step 310: f(x)= 4.94471462475297
# differential_evolution step 311: f(x)= 4.943642706236507
# differential_evolution step 312: f(x)= 4.943642706236507
# differential_evolution step 313: f(x)= 4.943642706236507
# differential_evolution step 314: f(x)= 4.942016700518379
# differential_evolution step 315: f(x)= 4.942016700518379
# differential_evolution step 316: f(x)= 4.942016700518379
# differential_evolution step 317: f(x)= 4.941442572269395
# differential_evolution step 318: f(x)= 4.941442572269395
# differential_evolution step 319: f(x)= 4.941442572269395
# differential_evolution step 320: f(x)= 4.941442572269395
# differential_evolution step 321: f(x)= 4.941442572269395
# differential_evolution step 322: f(x)= 4.941442572269395
# differential_evolution step 323: f(x)= 4.941442572269395
# differential_evolution step 324: f(x)= 4.937732680548885
# differential_evolution step 325: f(x)= 4.937732680548885
# differential_evolution step 326: f(x)= 4.937732680548885
# differential_evolution step 327: f(x)= 4.937732680548885
# differential_evolution step 328: f(x)= 4.937732680548885
# differential_evolution step 329: f(x)= 4.937732680548885
# differential_evolution step 330: f(x)= 4.937732680548885
# differential_evolution step 331: f(x)= 4.937505499469024
# differential_evolution step 332: f(x)= 4.937505499469024
# differential_evolution step 333: f(x)= 4.937505499469024
# differential_evolution step 334: f(x)= 4.937505499469024
# differential_evolution step 335: f(x)= 4.937505499469024
# differential_evolution step 336: f(x)= 4.937505499469024
# differential_evolution step 337: f(x)= 4.937505499469024
# differential_evolution step 338: f(x)= 4.937505499469024
# differential_evolution step 339: f(x)= 4.937505499469024
# differential_evolution step 340: f(x)= 4.937505499469024
# differential_evolution step 341: f(x)= 4.937505499469024
# differential_evolution step 342: f(x)= 4.937505499469024
# differential_evolution step 343: f(x)= 4.937505499469024
# differential_evolution step 344: f(x)= 4.937505499469024
# differential_evolution step 345: f(x)= 4.937505499469024
# differential_evolution step 346: f(x)= 4.937505499469024
# differential_evolution step 347: f(x)= 4.937505499469024
# differential_evolution step 348: f(x)= 4.937505499469024
# differential_evolution step 349: f(x)= 4.937505499469024
# differential_evolution step 350: f(x)= 4.937505499469024
# differential_evolution step 351: f(x)= 4.937505499469024
# differential_evolution step 352: f(x)= 4.937505499469024
# differential_evolution step 353: f(x)= 4.937179483965337
# differential_evolution step 354: f(x)= 4.937179483965337
# differential_evolution step 355: f(x)= 4.937179483965337
# differential_evolution step 356: f(x)= 4.937179483965337
# differential_evolution step 357: f(x)= 4.937134883605249
# differential_evolution step 358: f(x)= 4.937134883605249
# differential_evolution step 359: f(x)= 4.936904336388298
# differential_evolution step 360: f(x)= 4.936904336388298
# differential_evolution step 361: f(x)= 4.936904336388298
# differential_evolution step 362: f(x)= 4.936904336388298
# differential_evolution step 363: f(x)= 4.936904336388298
# differential_evolution step 364: f(x)= 4.936904336388298
# differential_evolution step 365: f(x)= 4.936904336388298
# differential_evolution step 366: f(x)= 4.936904336388298
# differential_evolution step 367: f(x)= 4.936620116148744
# differential_evolution step 368: f(x)= 4.936620116148744
# differential_evolution step 369: f(x)= 4.936620116148744
# differential_evolution step 370: f(x)= 4.936620116148744
# differential_evolution step 371: f(x)= 4.936620116148744
# differential_evolution step 372: f(x)= 4.936620116148744
# differential_evolution step 373: f(x)= 4.936620116148744
# differential_evolution step 374: f(x)= 4.936620116148744
# differential_evolution step 375: f(x)= 4.936620116148744
# differential_evolution step 376: f(x)= 4.936276357242177
# differential_evolution step 377: f(x)= 4.936276357242177
# differential_evolution step 378: f(x)= 4.936276357242177
# differential_evolution step 379: f(x)= 4.936276357242177
# differential_evolution step 380: f(x)= 4.936276357242177
# differential_evolution step 381: f(x)= 4.936276357242177
# differential_evolution step 382: f(x)= 4.936272529082208
# differential_evolution step 383: f(x)= 4.936272529082208
# differential_evolution step 384: f(x)= 4.936272529082208
# differential_evolution step 385: f(x)= 4.936091436399036
# differential_evolution step 386: f(x)= 4.936091436399036
# differential_evolution step 387: f(x)= 4.936091436399036
# differential_evolution step 388: f(x)= 4.93564806041224
# differential_evolution step 389: f(x)= 4.93564806041224
# differential_evolution step 390: f(x)= 4.93564806041224
# differential_evolution step 391: f(x)= 4.935643884669045
# differential_evolution step 392: f(x)= 4.935643884669045
# differential_evolution step 393: f(x)= 4.935643884669045
# differential_evolution step 394: f(x)= 4.935643884669045
# differential_evolution step 395: f(x)= 4.935643884669045
# differential_evolution step 396: f(x)= 4.935643884669045
# differential_evolution step 397: f(x)= 4.935643884669045
# differential_evolution step 398: f(x)= 4.935642139763992
# differential_evolution step 399: f(x)= 4.935642139763992
# differential_evolution step 400: f(x)= 4.935642139763992
# differential_evolution step 401: f(x)= 4.935642139763992
# differential_evolution step 402: f(x)= 4.935642139763992
# differential_evolution step 403: f(x)= 4.935642139763992
# differential_evolution step 404: f(x)= 4.935625735421236
# differential_evolution step 405: f(x)= 4.935625735421236
# differential_evolution step 406: f(x)= 4.93553513501288
# differential_evolution step 407: f(x)= 4.93553513501288
# differential_evolution step 408: f(x)= 4.93553513501288
# differential_evolution step 409: f(x)= 4.93553513501288
# differential_evolution step 410: f(x)= 4.93553513501288
# differential_evolution step 411: f(x)= 4.93553513501288
# differential_evolution step 412: f(x)= 4.935498893239852
# differential_evolution step 413: f(x)= 4.935456463976091
# differential_evolution step 414: f(x)= 4.935456463976091
# differential_evolution step 415: f(x)= 4.935456463976091
# differential_evolution step 416: f(x)= 4.935456463976091
# differential_evolution step 417: f(x)= 4.935456463976091
# differential_evolution step 418: f(x)= 4.935456463976091
# differential_evolution step 419: f(x)= 4.935456463976091
# differential_evolution step 420: f(x)= 4.935456463976091
# differential_evolution step 421: f(x)= 4.935396422068997
# differential_evolution step 422: f(x)= 4.935396422068997
# differential_evolution step 423: f(x)= 4.935396422068997
# differential_evolution step 424: f(x)= 4.935396422068997
# differential_evolution step 425: f(x)= 4.935396422068997
# differential_evolution step 426: f(x)= 4.935396422068997
# differential_evolution step 427: f(x)= 4.935396422068997
# differential_evolution step 428: f(x)= 4.935396422068997
# differential_evolution step 429: f(x)= 4.935396422068997
# differential_evolution step 430: f(x)= 4.935396422068997
# differential_evolution step 431: f(x)= 4.935396422068997
# differential_evolution step 432: f(x)= 4.935396422068997
# differential_evolution step 433: f(x)= 4.935396422068997
# differential_evolution step 434: f(x)= 4.935396422068997
# differential_evolution step 435: f(x)= 4.935396422068997
# differential_evolution step 436: f(x)= 4.935396422068997
# differential_evolution step 437: f(x)= 4.935396422068997
# differential_evolution step 438: f(x)= 4.935381764030661
# differential_evolution step 439: f(x)= 4.935381764030661
# differential_evolution step 440: f(x)= 4.935381764030661
# differential_evolution step 441: f(x)= 4.935381764030661
# differential_evolution step 442: f(x)= 4.935381764030661
# differential_evolution step 443: f(x)= 4.9353287804700186
# differential_evolution step 444: f(x)= 4.935253033197697
# differential_evolution step 445: f(x)= 4.935253033197697
# differential_evolution step 446: f(x)= 4.935253033197697
# differential_evolution step 447: f(x)= 4.935253033197697
# differential_evolution step 448: f(x)= 4.935253033197697
# differential_evolution step 449: f(x)= 4.9352014260901775
# differential_evolution step 450: f(x)= 4.9352014260901775
# differential_evolution step 451: f(x)= 4.9352014260901775
# differential_evolution step 452: f(x)= 4.9352014260901775
# differential_evolution step 453: f(x)= 4.9352014260901775
# differential_evolution step 454: f(x)= 4.9352014260901775
# differential_evolution step 455: f(x)= 4.9352014260901775
# differential_evolution step 456: f(x)= 4.9352014260901775
# differential_evolution step 457: f(x)= 4.9352014260901775
# differential_evolution step 458: f(x)= 4.9352014260901775
# differential_evolution step 459: f(x)= 4.9352014260901775
# differential_evolution step 460: f(x)= 4.9352014260901775
# differential_evolution step 461: f(x)= 4.9352014260901775
# differential_evolution step 462: f(x)= 4.935185938031116
# differential_evolution step 463: f(x)= 4.935185938031116
# differential_evolution step 464: f(x)= 4.935185938031116
# differential_evolution step 465: f(x)= 4.935185938031116
# differential_evolution step 466: f(x)= 4.935185938031116
# differential_evolution step 467: f(x)= 4.935185938031116
# differential_evolution step 468: f(x)= 4.935185938031116
# differential_evolution step 469: f(x)= 4.935185938031116
# differential_evolution step 470: f(x)= 4.935185938031116
# differential_evolution step 471: f(x)= 4.935185938031116
# differential_evolution step 472: f(x)= 4.935185938031116
# differential_evolution step 473: f(x)= 4.935185938031116
# differential_evolution step 474: f(x)= 4.935185938031116
# differential_evolution step 475: f(x)= 4.935185938031116
# differential_evolution step 476: f(x)= 4.935185938031116
# differential_evolution step 477: f(x)= 4.935185938031116
# differential_evolution step 478: f(x)= 4.935185938031116
# differential_evolution step 479: f(x)= 4.935185938031116
# differential_evolution step 480: f(x)= 4.935185938031116
# differential_evolution step 481: f(x)= 4.935185938031116
# differential_evolution step 482: f(x)= 4.935185938031116
# differential_evolution step 483: f(x)= 4.935177676831731
# differential_evolution step 484: f(x)= 4.935177676831731
# differential_evolution step 485: f(x)= 4.935177676831731
# differential_evolution step 486: f(x)= 4.935177676831731
# differential_evolution step 487: f(x)= 4.935177676831731
# differential_evolution step 488: f(x)= 4.935177676831731
# differential_evolution step 489: f(x)= 4.935177676831731
# differential_evolution step 490: f(x)= 4.935177676831731
# differential_evolution step 491: f(x)= 4.935177676831731
# differential_evolution step 492: f(x)= 4.935177676831731
# differential_evolution step 493: f(x)= 4.935177676831731
# differential_evolution step 494: f(x)= 4.935177676831731
# differential_evolution step 495: f(x)= 4.935177676831731
# differential_evolution step 496: f(x)= 4.935177676831731
# differential_evolution step 497: f(x)= 4.935177676831731
# differential_evolution step 498: f(x)= 4.935177676831731
# differential_evolution step 499: f(x)= 4.935177676831731
# differential_evolution step 500: f(x)= 4.935177676831731
# differential_evolution step 501: f(x)= 4.935177676831731
# differential_evolution step 502: f(x)= 4.935177676831731
# differential_evolution step 503: f(x)= 4.935158572674865
# differential_evolution step 504: f(x)= 4.935158572674865
# differential_evolution step 505: f(x)= 4.935158572674865
# differential_evolution step 506: f(x)= 4.935158572674865
# differential_evolution step 507: f(x)= 4.9351324724920955
# differential_evolution step 508: f(x)= 4.9351324724920955
# differential_evolution step 509: f(x)= 4.9351324724920955
# differential_evolution step 510: f(x)= 4.9351324724920955
# differential_evolution step 511: f(x)= 4.9351324724920955
# differential_evolution step 512: f(x)= 4.9351324724920955
# differential_evolution step 513: f(x)= 4.9351324724920955
# differential_evolution step 514: f(x)= 4.9351324724920955
# differential_evolution step 515: f(x)= 4.9351324724920955
# differential_evolution step 516: f(x)= 4.9351324724920955
# differential_evolution step 517: f(x)= 4.9351324724920955
# differential_evolution step 518: f(x)= 4.9351324724920955
# differential_evolution step 519: f(x)= 4.9351324724920955
# differential_evolution step 520: f(x)= 4.9351324724920955
# differential_evolution step 521: f(x)= 4.9351324724920955
# differential_evolution step 522: f(x)= 4.9351324724920955
# differential_evolution step 523: f(x)= 4.9351324724920955
# differential_evolution step 524: f(x)= 4.9351324724920955
# differential_evolution step 525: f(x)= 4.9351324724920955
# differential_evolution step 526: f(x)= 4.9351324724920955
# differential_evolution step 527: f(x)= 4.935120181793071
# differential_evolution step 528: f(x)= 4.935120181793071
# differential_evolution step 529: f(x)= 4.935120181793071
# differential_evolution step 530: f(x)= 4.9351153736892455
# differential_evolution step 531: f(x)= 4.9351153736892455
# differential_evolution step 532: f(x)= 4.9351153736892455
# differential_evolution step 533: f(x)= 4.9351153736892455
# differential_evolution step 534: f(x)= 4.9351153736892455
# differential_evolution step 535: f(x)= 4.9351153736892455
# differential_evolution step 536: f(x)= 4.9351153736892455
# differential_evolution step 537: f(x)= 4.9351153736892455
# differential_evolution step 538: f(x)= 4.9351153736892455
# differential_evolution step 539: f(x)= 4.9351153736892455
# differential_evolution step 540: f(x)= 4.9351153736892455
# differential_evolution step 541: f(x)= 4.9351153736892455
# differential_evolution step 542: f(x)= 4.9351153736892455
# differential_evolution step 543: f(x)= 4.9351153736892455
# differential_evolution step 544: f(x)= 4.9351153736892455
# differential_evolution step 545: f(x)= 4.9351153736892455
# differential_evolution step 546: f(x)= 4.9351153736892455
# differential_evolution step 547: f(x)= 4.9351153736892455
# differential_evolution step 548: f(x)= 4.9351153736892455
# differential_evolution step 549: f(x)= 4.9351153736892455
# differential_evolution step 550: f(x)= 4.9351153736892455
# differential_evolution step 551: f(x)= 4.9351153736892455
# differential_evolution step 552: f(x)= 4.9351153736892455
# differential_evolution step 553: f(x)= 4.9351153736892455
# differential_evolution step 554: f(x)= 4.9351153736892455
# differential_evolution step 555: f(x)= 4.9351153736892455
# differential_evolution step 556: f(x)= 4.9351153736892455
# differential_evolution step 557: f(x)= 4.9351153736892455
# differential_evolution step 558: f(x)= 4.9351153736892455
# differential_evolution step 559: f(x)= 4.9351153736892455
# differential_evolution step 560: f(x)= 4.9351153736892455
# differential_evolution step 561: f(x)= 4.9351153736892455
# differential_evolution step 562: f(x)= 4.9351153736892455
# differential_evolution step 563: f(x)= 4.9351153736892455
# differential_evolution step 564: f(x)= 4.9351153736892455
# differential_evolution step 565: f(x)= 4.9351153736892455
# differential_evolution step 566: f(x)= 4.9351153736892455
# differential_evolution step 567: f(x)= 4.935108525305314
# differential_evolution step 568: f(x)= 4.935108525305314
# differential_evolution step 569: f(x)= 4.935108525305314
# differential_evolution step 570: f(x)= 4.935108525305314
# differential_evolution step 571: f(x)= 4.935108525305314
# differential_evolution step 572: f(x)= 4.935108525305314
# differential_evolution step 573: f(x)= 4.935108525305314
# differential_evolution step 574: f(x)= 4.935108525305314
# differential_evolution step 575: f(x)= 4.935108525305314
# differential_evolution step 576: f(x)= 4.935099149128711
# differential_evolution step 577: f(x)= 4.935099149128711
# differential_evolution step 578: f(x)= 4.935099149128711
# differential_evolution step 579: f(x)= 4.935099149128711
# differential_evolution step 580: f(x)= 4.935099149128711
# differential_evolution step 581: f(x)= 4.935099149128711
# differential_evolution step 582: f(x)= 4.935099149128711
# differential_evolution step 583: f(x)= 4.935099149128711
# differential_evolution step 584: f(x)= 4.935099149128711
# differential_evolution step 585: f(x)= 4.935099149128711
# differential_evolution step 586: f(x)= 4.935099149128711
# differential_evolution step 587: f(x)= 4.935099149128711
# differential_evolution step 588: f(x)= 4.935098061193194
# differential_evolution step 589: f(x)= 4.935098061193194
# differential_evolution step 590: f(x)= 4.935098061193194
# differential_evolution step 591: f(x)= 4.935098061193194
# differential_evolution step 592: f(x)= 4.935098061193194
# differential_evolution step 593: f(x)= 4.935098061193194
# differential_evolution step 594: f(x)= 4.935098061193194
# differential_evolution step 595: f(x)= 4.935098061193194
# differential_evolution step 596: f(x)= 4.935098061193194
# differential_evolution step 597: f(x)= 4.935098061193194
# differential_evolution step 598: f(x)= 4.935094323777373
# differential_evolution step 599: f(x)= 4.935094323777373
# differential_evolution step 600: f(x)= 4.935094323777373
# differential_evolution step 601: f(x)= 4.935094323777373
# differential_evolution step 602: f(x)= 4.935094323777373
# differential_evolution step 603: f(x)= 4.935094323777373
# differential_evolution step 604: f(x)= 4.935094323777373
# differential_evolution step 605: f(x)= 4.935094323777373
# differential_evolution step 606: f(x)= 4.935094323777373
# differential_evolution step 607: f(x)= 4.935094323777373
# differential_evolution step 608: f(x)= 4.935094323777373
# differential_evolution step 609: f(x)= 4.93509264708816
# differential_evolution step 610: f(x)= 4.93509264708816
# differential_evolution step 611: f(x)= 4.93509264708816
# differential_evolution step 612: f(x)= 4.93509264708816
# differential_evolution step 613: f(x)= 4.935091488424437
# differential_evolution step 614: f(x)= 4.9350896230085795
# differential_evolution step 615: f(x)= 4.9350896230085795
# differential_evolution step 616: f(x)= 4.9350896230085795
# differential_evolution step 617: f(x)= 4.9350896230085795
# differential_evolution step 618: f(x)= 4.9350879756079555
# differential_evolution step 619: f(x)= 4.9350879756079555
# differential_evolution step 620: f(x)= 4.9350879756079555
# differential_evolution step 621: f(x)= 4.9350879756079555
# differential_evolution step 622: f(x)= 4.9350879756079555
# differential_evolution step 623: f(x)= 4.9350879756079555
# differential_evolution step 624: f(x)= 4.9350879756079555
# differential_evolution step 625: f(x)= 4.9350879756079555
# differential_evolution step 626: f(x)= 4.9350879756079555
# differential_evolution step 627: f(x)= 4.9350879756079555
# differential_evolution step 628: f(x)= 4.9350879756079555
# differential_evolution step 629: f(x)= 4.9350879756079555
# differential_evolution step 630: f(x)= 4.9350879756079555
# differential_evolution step 631: f(x)= 4.9350879756079555
# differential_evolution step 632: f(x)= 4.9350879756079555
# differential_evolution step 633: f(x)= 4.9350879756079555
# differential_evolution step 634: f(x)= 4.935087520594579
# differential_evolution step 635: f(x)= 4.935087520594579
# differential_evolution step 636: f(x)= 4.935087520594579
# differential_evolution step 637: f(x)= 4.935083380191923
# differential_evolution step 638: f(x)= 4.935083380191923
# differential_evolution step 639: f(x)= 4.935083380191923
# differential_evolution step 640: f(x)= 4.935083380191923
# differential_evolution step 641: f(x)= 4.935083380191923
# differential_evolution step 642: f(x)= 4.935083380191923
# differential_evolution step 643: f(x)= 4.935083380191923
# differential_evolution step 644: f(x)= 4.935083380191923
# differential_evolution step 645: f(x)= 4.935083380191923
# differential_evolution step 646: f(x)= 4.935083380191923
# differential_evolution step 647: f(x)= 4.935083380191923
# differential_evolution step 648: f(x)= 4.935083380191923
# differential_evolution step 649: f(x)= 4.935083380191923
# differential_evolution step 650: f(x)= 4.935083380191923
# differential_evolution step 651: f(x)= 4.935083380191923
# differential_evolution step 652: f(x)= 4.935083380191923
# differential_evolution step 653: f(x)= 4.935083380191923
# differential_evolution step 654: f(x)= 4.935083380191923
# differential_evolution step 655: f(x)= 4.935083380191923
# differential_evolution step 656: f(x)= 4.935083380191923
# differential_evolution step 657: f(x)= 4.935083380191923
# differential_evolution step 658: f(x)= 4.935083380191923
# differential_evolution step 659: f(x)= 4.935083380191923
# differential_evolution step 660: f(x)= 4.935083380191923
# differential_evolution step 661: f(x)= 4.935083380191923
# differential_evolution step 662: f(x)= 4.935083380191923
# differential_evolution step 663: f(x)= 4.935083380191923
# differential_evolution step 664: f(x)= 4.935083380191923
# differential_evolution step 665: f(x)= 4.935083380191923
# differential_evolution step 666: f(x)= 4.935083380191923
# differential_evolution step 667: f(x)= 4.935081870410601
# differential_evolution step 668: f(x)= 4.935081870410601
# differential_evolution step 669: f(x)= 4.935081870410601
# differential_evolution step 670: f(x)= 4.935081870410601
# differential_evolution step 671: f(x)= 4.935081870410601
# differential_evolution step 672: f(x)= 4.935081870410601
# differential_evolution step 673: f(x)= 4.935081870410601
# differential_evolution step 674: f(x)= 4.935081870410601
# differential_evolution step 675: f(x)= 4.935081870410601
# differential_evolution step 676: f(x)= 4.935081870410601
# differential_evolution step 677: f(x)= 4.935081870410601
# differential_evolution step 678: f(x)= 4.935081870410601
# differential_evolution step 679: f(x)= 4.935081870410601
# differential_evolution step 680: f(x)= 4.935081870410601
# differential_evolution step 681: f(x)= 4.935081870410601
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [1.11429274e+00 5.39387202e+00 9.28419283e-01 2.70944065e+01
#  1.12162351e+00 7.47049378e+00 9.08785726e-01 4.90644121e+01
#  6.27053639e-02 2.26646103e+01 2.34516702e+00 7.01095274e+01]
# Chi quadro minimo: 4.935081870410601

# %%
# Plots:
params_curve_3, covariance_3 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params3, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[2], red_chi[2] = save_params(params_curve_3, covariance_3, radial_profile_HA, radial_profile_error_HA,x_axes, 3,  
                                       line_name="Three", output_prefix="fit")

aic[2] = AIC(x_axes, radial_profile_HA, chi_quadr[2], params_curve_3)
bic[2] = BIC(x_axes, radial_profile_HA, chi_quadr[2], params_curve_3)
print(aic[2], chi_quadr[2], bic[2], len(params_curve_3))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_3)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[8:12]), 'm--', label='Sérsic 3')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_3', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.8855, r_e=6.4375, n=1.0821, x_0=27.1734
# Sérsic 2: I_e=1.1950, r_e=7.1722, n=0.8342, x_0=49.8374
# Sérsic 3: I_e=0.1616, r_e=9.6533, n=1.7415, x_0=70.1838
# [0.11649754 0.50218399 0.10185893 0.1262569  0.15748057 0.58470108
#  0.09199536 0.15176224 0.08309046 2.89714153 0.56726628 0.09117861]
# 104.17933021039194
# 131.76553710694364 104.17933021039194 159.44137244224905 12
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (25, 35),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (40, 50),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (65, 75),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (45, 55),   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params4 = result.x

print("Optimize parameters with differential_evolution:", best_params4)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 58354.47922165476
# differential_evolution step 2: f(x)= 4026.938760795517
# differential_evolution step 3: f(x)= 4026.938760795517
# differential_evolution step 4: f(x)= 2592.1324952384716
# differential_evolution step 5: f(x)= 2592.1324952384716
# differential_evolution step 6: f(x)= 2592.1324952384716
# differential_evolution step 7: f(x)= 2486.359865193909
# differential_evolution step 8: f(x)= 2486.359865193909
# differential_evolution step 9: f(x)= 2486.359865193909
# differential_evolution step 10: f(x)= 875.7397196632496
# differential_evolution step 11: f(x)= 875.7397196632496
# differential_evolution step 12: f(x)= 875.7397196632496
# differential_evolution step 13: f(x)= 875.7397196632496
# differential_evolution step 14: f(x)= 875.7397196632496
# differential_evolution step 15: f(x)= 875.7397196632496
# differential_evolution step 16: f(x)= 147.3835826684953
# differential_evolution step 17: f(x)= 147.3835826684953
# differential_evolution step 18: f(x)= 147.3835826684953
# differential_evolution step 19: f(x)= 89.61106828275135
# differential_evolution step 20: f(x)= 40.747197573010766
# differential_evolution step 21: f(x)= 40.747197573010766
# differential_evolution step 22: f(x)= 40.747197573010766
# differential_evolution step 23: f(x)= 40.747197573010766
# differential_evolution step 24: f(x)= 40.747197573010766
# differential_evolution step 25: f(x)= 40.747197573010766
# differential_evolution step 26: f(x)= 40.747197573010766
# differential_evolution step 27: f(x)= 40.747197573010766
# differential_evolution step 28: f(x)= 40.747197573010766
# differential_evolution step 29: f(x)= 40.747197573010766
# differential_evolution step 30: f(x)= 40.747197573010766
# differential_evolution step 31: f(x)= 40.747197573010766
# differential_evolution step 32: f(x)= 26.29151603231923
# differential_evolution step 33: f(x)= 26.29151603231923
# differential_evolution step 34: f(x)= 26.29151603231923
# differential_evolution step 35: f(x)= 26.011280741628905
# differential_evolution step 36: f(x)= 26.011280741628905
# differential_evolution step 37: f(x)= 26.011280741628905
# differential_evolution step 38: f(x)= 26.011280741628905
# differential_evolution step 39: f(x)= 24.523029404121555
# differential_evolution step 40: f(x)= 22.75940877092906
# differential_evolution step 41: f(x)= 22.75940877092906
# differential_evolution step 42: f(x)= 22.75940877092906
# differential_evolution step 43: f(x)= 22.75940877092906
# differential_evolution step 44: f(x)= 22.75940877092906
# differential_evolution step 45: f(x)= 22.75940877092906
# differential_evolution step 46: f(x)= 22.75940877092906
# differential_evolution step 47: f(x)= 22.75940877092906
# differential_evolution step 48: f(x)= 21.64513141626591
# differential_evolution step 49: f(x)= 14.796665127603474
# differential_evolution step 50: f(x)= 14.748326651019353
# differential_evolution step 51: f(x)= 14.748326651019353
# differential_evolution step 52: f(x)= 14.748326651019353
# differential_evolution step 53: f(x)= 14.748326651019353
# differential_evolution step 54: f(x)= 14.748326651019353
# differential_evolution step 55: f(x)= 14.748326651019353
# differential_evolution step 56: f(x)= 14.748326651019353
# differential_evolution step 57: f(x)= 14.748326651019353
# differential_evolution step 58: f(x)= 14.480969996465953
# differential_evolution step 59: f(x)= 14.480969996465953
# differential_evolution step 60: f(x)= 11.420621573079544
# differential_evolution step 61: f(x)= 11.420621573079544
# differential_evolution step 62: f(x)= 11.420621573079544
# differential_evolution step 63: f(x)= 11.420621573079544
# differential_evolution step 64: f(x)= 11.420621573079544
# differential_evolution step 65: f(x)= 11.420621573079544
# differential_evolution step 66: f(x)= 11.420621573079544
# differential_evolution step 67: f(x)= 11.420621573079544
# differential_evolution step 68: f(x)= 11.420621573079544
# differential_evolution step 69: f(x)= 11.420621573079544
# differential_evolution step 70: f(x)= 11.420621573079544
# differential_evolution step 71: f(x)= 11.420621573079544
# differential_evolution step 72: f(x)= 11.420621573079544
# differential_evolution step 73: f(x)= 10.51481338740837
# differential_evolution step 74: f(x)= 10.51481338740837
# differential_evolution step 75: f(x)= 10.51481338740837
# differential_evolution step 76: f(x)= 10.51481338740837
# differential_evolution step 77: f(x)= 10.51481338740837
# differential_evolution step 78: f(x)= 10.51481338740837
# differential_evolution step 79: f(x)= 10.51481338740837
# differential_evolution step 80: f(x)= 10.51481338740837
# differential_evolution step 81: f(x)= 10.036578825776763
# differential_evolution step 82: f(x)= 10.036578825776763
# differential_evolution step 83: f(x)= 10.036578825776763
# differential_evolution step 84: f(x)= 10.036578825776763
# differential_evolution step 85: f(x)= 7.471893985991118
# differential_evolution step 86: f(x)= 7.471893985991118
# differential_evolution step 87: f(x)= 7.471893985991118
# differential_evolution step 88: f(x)= 7.471893985991118
# differential_evolution step 89: f(x)= 5.201434497024096
# differential_evolution step 90: f(x)= 5.201434497024096
# differential_evolution step 91: f(x)= 5.201434497024096
# differential_evolution step 92: f(x)= 5.201434497024096
# differential_evolution step 93: f(x)= 5.201434497024096
# differential_evolution step 94: f(x)= 5.201434497024096
# differential_evolution step 95: f(x)= 5.201434497024096
# differential_evolution step 96: f(x)= 5.201434497024096
# differential_evolution step 97: f(x)= 5.201434497024096
# differential_evolution step 98: f(x)= 5.201434497024096
# differential_evolution step 99: f(x)= 5.201434497024096
# differential_evolution step 100: f(x)= 5.201434497024096
# differential_evolution step 101: f(x)= 4.303913680848117
# differential_evolution step 102: f(x)= 4.303913680848117
# differential_evolution step 103: f(x)= 4.303913680848117
# differential_evolution step 104: f(x)= 4.303913680848117
# differential_evolution step 105: f(x)= 4.303913680848117
# differential_evolution step 106: f(x)= 4.303913680848117
# differential_evolution step 107: f(x)= 4.303913680848117
# differential_evolution step 108: f(x)= 3.9322764633597647
# differential_evolution step 109: f(x)= 3.008788229893514
# differential_evolution step 110: f(x)= 3.008788229893514
# differential_evolution step 111: f(x)= 3.008788229893514
# differential_evolution step 112: f(x)= 3.008788229893514
# differential_evolution step 113: f(x)= 3.008788229893514
# differential_evolution step 114: f(x)= 3.008788229893514
# differential_evolution step 115: f(x)= 3.008788229893514
# differential_evolution step 116: f(x)= 3.008788229893514
# differential_evolution step 117: f(x)= 3.008788229893514
# differential_evolution step 118: f(x)= 3.008788229893514
# differential_evolution step 119: f(x)= 3.006479405775421
# differential_evolution step 120: f(x)= 3.006479405775421
# differential_evolution step 121: f(x)= 3.006479405775421
# differential_evolution step 122: f(x)= 3.006479405775421
# differential_evolution step 123: f(x)= 2.8604481193244977
# differential_evolution step 124: f(x)= 2.8604481193244977
# differential_evolution step 125: f(x)= 2.802133483840328
# differential_evolution step 126: f(x)= 2.802133483840328
# differential_evolution step 127: f(x)= 2.802133483840328
# differential_evolution step 128: f(x)= 2.802133483840328
# differential_evolution step 129: f(x)= 2.802133483840328
# differential_evolution step 130: f(x)= 2.802133483840328
# differential_evolution step 131: f(x)= 2.442436425507112
# differential_evolution step 132: f(x)= 2.442436425507112
# differential_evolution step 133: f(x)= 1.7604435434871644
# differential_evolution step 134: f(x)= 1.7604435434871644
# differential_evolution step 135: f(x)= 1.7604435434871644
# differential_evolution step 136: f(x)= 1.7604435434871644
# differential_evolution step 137: f(x)= 1.530053454160156
# differential_evolution step 138: f(x)= 1.530053454160156
# differential_evolution step 139: f(x)= 1.530053454160156
# differential_evolution step 140: f(x)= 1.530053454160156
# differential_evolution step 141: f(x)= 1.530053454160156
# differential_evolution step 142: f(x)= 1.530053454160156
# differential_evolution step 143: f(x)= 1.530053454160156
# differential_evolution step 144: f(x)= 1.530053454160156
# differential_evolution step 145: f(x)= 1.530053454160156
# differential_evolution step 146: f(x)= 1.530053454160156
# differential_evolution step 147: f(x)= 1.530053454160156
# differential_evolution step 148: f(x)= 1.530053454160156
# differential_evolution step 149: f(x)= 1.530053454160156
# differential_evolution step 150: f(x)= 1.530053454160156
# differential_evolution step 151: f(x)= 1.530053454160156
# differential_evolution step 152: f(x)= 1.530053454160156
# differential_evolution step 153: f(x)= 1.530053454160156
# differential_evolution step 154: f(x)= 1.530053454160156
# differential_evolution step 155: f(x)= 1.530053454160156
# differential_evolution step 156: f(x)= 1.530053454160156
# differential_evolution step 157: f(x)= 1.530053454160156
# differential_evolution step 158: f(x)= 1.530053454160156
# differential_evolution step 159: f(x)= 1.530053454160156
# differential_evolution step 160: f(x)= 1.530053454160156
# differential_evolution step 161: f(x)= 1.530053454160156
# differential_evolution step 162: f(x)= 1.530053454160156
# differential_evolution step 163: f(x)= 1.530053454160156
# differential_evolution step 164: f(x)= 1.530053454160156
# differential_evolution step 165: f(x)= 1.530053454160156
# differential_evolution step 166: f(x)= 1.493804157276236
# differential_evolution step 167: f(x)= 1.493804157276236
# differential_evolution step 168: f(x)= 1.493804157276236
# differential_evolution step 169: f(x)= 1.3448034626418217
# differential_evolution step 170: f(x)= 1.3448034626418217
# differential_evolution step 171: f(x)= 1.3448034626418217
# differential_evolution step 172: f(x)= 1.3448034626418217
# differential_evolution step 173: f(x)= 1.3448034626418217
# differential_evolution step 174: f(x)= 1.318279947738902
# differential_evolution step 175: f(x)= 1.318279947738902
# differential_evolution step 176: f(x)= 1.318279947738902
# differential_evolution step 177: f(x)= 1.29825186659088
# differential_evolution step 178: f(x)= 1.29825186659088
# differential_evolution step 179: f(x)= 1.29825186659088
# differential_evolution step 180: f(x)= 1.29825186659088
# differential_evolution step 181: f(x)= 1.29825186659088
# differential_evolution step 182: f(x)= 1.29825186659088
# differential_evolution step 183: f(x)= 1.29825186659088
# differential_evolution step 184: f(x)= 1.29825186659088
# differential_evolution step 185: f(x)= 1.2848540667952852
# differential_evolution step 186: f(x)= 1.2848540667952852
# differential_evolution step 187: f(x)= 1.1784941887550338
# differential_evolution step 188: f(x)= 1.1659010410009274
# differential_evolution step 189: f(x)= 1.1464332028894546
# differential_evolution step 190: f(x)= 1.1464332028894546
# differential_evolution step 191: f(x)= 1.1257205385126081
# differential_evolution step 192: f(x)= 1.1257205385126081
# differential_evolution step 193: f(x)= 1.1257205385126081
# differential_evolution step 194: f(x)= 1.1257205385126081
# differential_evolution step 195: f(x)= 1.1257205385126081
# differential_evolution step 196: f(x)= 1.1257205385126081
# differential_evolution step 197: f(x)= 1.1257205385126081
# differential_evolution step 198: f(x)= 1.066372265704687
# differential_evolution step 199: f(x)= 1.066372265704687
# differential_evolution step 200: f(x)= 1.066372265704687
# differential_evolution step 201: f(x)= 1.066372265704687
# differential_evolution step 202: f(x)= 1.066372265704687
# differential_evolution step 203: f(x)= 1.0440236774514184
# differential_evolution step 204: f(x)= 1.0440236774514184
# differential_evolution step 205: f(x)= 1.0440236774514184
# differential_evolution step 206: f(x)= 1.0440236774514184
# differential_evolution step 207: f(x)= 1.0440236774514184
# differential_evolution step 208: f(x)= 1.0440236774514184
# differential_evolution step 209: f(x)= 1.0440236774514184
# differential_evolution step 210: f(x)= 1.0251708091981486
# differential_evolution step 211: f(x)= 1.0251708091981486
# differential_evolution step 212: f(x)= 1.0251708091981486
# differential_evolution step 213: f(x)= 1.0251708091981486
# differential_evolution step 214: f(x)= 1.0251708091981486
# differential_evolution step 215: f(x)= 1.0251708091981486
# differential_evolution step 216: f(x)= 1.0251708091981486
# differential_evolution step 217: f(x)= 0.9415220215065119
# differential_evolution step 218: f(x)= 0.9415220215065119
# differential_evolution step 219: f(x)= 0.9268555950021011
# differential_evolution step 220: f(x)= 0.9268555950021011
# differential_evolution step 221: f(x)= 0.9268555950021011
# differential_evolution step 222: f(x)= 0.9268555950021011
# differential_evolution step 223: f(x)= 0.9268555950021011
# differential_evolution step 224: f(x)= 0.9268555950021011
# differential_evolution step 225: f(x)= 0.9268555950021011
# differential_evolution step 226: f(x)= 0.9268555950021011
# differential_evolution step 227: f(x)= 0.9268555950021011
# differential_evolution step 228: f(x)= 0.9253567814570032
# differential_evolution step 229: f(x)= 0.9253567814570032
# differential_evolution step 230: f(x)= 0.9253567814570032
# differential_evolution step 231: f(x)= 0.9253567814570032
# differential_evolution step 232: f(x)= 0.9253567814570032
# differential_evolution step 233: f(x)= 0.9253567814570032
# differential_evolution step 234: f(x)= 0.9253567814570032
# differential_evolution step 235: f(x)= 0.9182027189972568
# differential_evolution step 236: f(x)= 0.9081505006723244
# differential_evolution step 237: f(x)= 0.9081505006723244
# differential_evolution step 238: f(x)= 0.9081505006723244
# differential_evolution step 239: f(x)= 0.9081505006723244
# differential_evolution step 240: f(x)= 0.9081505006723244
# differential_evolution step 241: f(x)= 0.9081505006723244
# differential_evolution step 242: f(x)= 0.9081505006723244
# differential_evolution step 243: f(x)= 0.9081505006723244
# differential_evolution step 244: f(x)= 0.9081505006723244
# differential_evolution step 245: f(x)= 0.9081505006723244
# differential_evolution step 246: f(x)= 0.9081505006723244
# differential_evolution step 247: f(x)= 0.9081505006723244
# differential_evolution step 248: f(x)= 0.9004055364306331
# differential_evolution step 249: f(x)= 0.9004055364306331
# differential_evolution step 250: f(x)= 0.9004055364306331
# differential_evolution step 251: f(x)= 0.9004055364306331
# differential_evolution step 252: f(x)= 0.9004055364306331
# differential_evolution step 253: f(x)= 0.9004055364306331
# differential_evolution step 254: f(x)= 0.9004055364306331
# differential_evolution step 255: f(x)= 0.9004055364306331
# differential_evolution step 256: f(x)= 0.9004055364306331
# differential_evolution step 257: f(x)= 0.9004055364306331
# differential_evolution step 258: f(x)= 0.9004055364306331
# differential_evolution step 259: f(x)= 0.9004055364306331
# differential_evolution step 260: f(x)= 0.9004055364306331
# differential_evolution step 261: f(x)= 0.9004055364306331
# differential_evolution step 262: f(x)= 0.9004055364306331
# differential_evolution step 263: f(x)= 0.9004055364306331
# differential_evolution step 264: f(x)= 0.9004055364306331
# differential_evolution step 265: f(x)= 0.9004055364306331
# differential_evolution step 266: f(x)= 0.9004055364306331
# differential_evolution step 267: f(x)= 0.9004055364306331
# differential_evolution step 268: f(x)= 0.9004055364306331
# differential_evolution step 269: f(x)= 0.9004055364306331
# differential_evolution step 270: f(x)= 0.9004055364306331
# differential_evolution step 271: f(x)= 0.9004055364306331
# differential_evolution step 272: f(x)= 0.8838239658048804
# differential_evolution step 273: f(x)= 0.8838239658048804
# differential_evolution step 274: f(x)= 0.8838239658048804
# differential_evolution step 275: f(x)= 0.8838239658048804
# differential_evolution step 276: f(x)= 0.8838239658048804
# differential_evolution step 277: f(x)= 0.8838239658048804
# differential_evolution step 278: f(x)= 0.8838239658048804
# differential_evolution step 279: f(x)= 0.8838239658048804
# differential_evolution step 280: f(x)= 0.8838239658048804
# differential_evolution step 281: f(x)= 0.8621656101951891
# differential_evolution step 282: f(x)= 0.8621656101951891
# differential_evolution step 283: f(x)= 0.8590646556496693
# differential_evolution step 284: f(x)= 0.8590646556496693
# differential_evolution step 285: f(x)= 0.8590646556496693
# differential_evolution step 286: f(x)= 0.8509728097759409
# differential_evolution step 287: f(x)= 0.8509728097759409
# differential_evolution step 288: f(x)= 0.8509728097759409
# differential_evolution step 289: f(x)= 0.8509728097759409
# differential_evolution step 290: f(x)= 0.8509728097759409
# differential_evolution step 291: f(x)= 0.8509728097759409
# differential_evolution step 292: f(x)= 0.8486920333607532
# differential_evolution step 293: f(x)= 0.8486920333607532
# differential_evolution step 294: f(x)= 0.8486920333607532
# differential_evolution step 295: f(x)= 0.8486920333607532
# differential_evolution step 296: f(x)= 0.8486920333607532
# differential_evolution step 297: f(x)= 0.8486920333607532
# differential_evolution step 298: f(x)= 0.8486920333607532
# differential_evolution step 299: f(x)= 0.8328011994919636
# differential_evolution step 300: f(x)= 0.8328011994919636
# differential_evolution step 301: f(x)= 0.8328011994919636
# differential_evolution step 302: f(x)= 0.8236068595251506
# differential_evolution step 303: f(x)= 0.8236068595251506
# differential_evolution step 304: f(x)= 0.8236068595251506
# differential_evolution step 305: f(x)= 0.8236068595251506
# differential_evolution step 306: f(x)= 0.8236068595251506
# differential_evolution step 307: f(x)= 0.8236068595251506
# differential_evolution step 308: f(x)= 0.8236068595251506
# differential_evolution step 309: f(x)= 0.8236068595251506
# differential_evolution step 310: f(x)= 0.8236068595251506
# differential_evolution step 311: f(x)= 0.8055359267115954
# differential_evolution step 312: f(x)= 0.8055359267115954
# differential_evolution step 313: f(x)= 0.8055359267115954
# differential_evolution step 314: f(x)= 0.8055359267115954
# differential_evolution step 315: f(x)= 0.8055359267115954
# differential_evolution step 316: f(x)= 0.8055359267115954
# differential_evolution step 317: f(x)= 0.8055359267115954
# differential_evolution step 318: f(x)= 0.8055359267115954
# differential_evolution step 319: f(x)= 0.8055359267115954
# differential_evolution step 320: f(x)= 0.8055359267115954
# differential_evolution step 321: f(x)= 0.8055359267115954
# differential_evolution step 322: f(x)= 0.8055359267115954
# differential_evolution step 323: f(x)= 0.8055359267115954
# differential_evolution step 324: f(x)= 0.8055359267115954
# differential_evolution step 325: f(x)= 0.8055359267115954
# differential_evolution step 326: f(x)= 0.8055359267115954
# differential_evolution step 327: f(x)= 0.8055359267115954
# differential_evolution step 328: f(x)= 0.8055359267115954
# differential_evolution step 329: f(x)= 0.8055359267115954
# differential_evolution step 330: f(x)= 0.8055359267115954
# differential_evolution step 331: f(x)= 0.8055359267115954
# differential_evolution step 332: f(x)= 0.8055359267115954
# differential_evolution step 333: f(x)= 0.8055359267115954
# differential_evolution step 334: f(x)= 0.8055359267115954
# differential_evolution step 335: f(x)= 0.8055359267115954
# differential_evolution step 336: f(x)= 0.8055359267115954
# differential_evolution step 337: f(x)= 0.8055359267115954
# differential_evolution step 338: f(x)= 0.8055359267115954
# differential_evolution step 339: f(x)= 0.8055359267115954
# differential_evolution step 340: f(x)= 0.8055359267115954
# differential_evolution step 341: f(x)= 0.7981765877175917
# differential_evolution step 342: f(x)= 0.7981765877175917
# differential_evolution step 343: f(x)= 0.7981765877175917
# differential_evolution step 344: f(x)= 0.7981765877175917
# differential_evolution step 345: f(x)= 0.7981765877175917
# differential_evolution step 346: f(x)= 0.7981765877175917
# differential_evolution step 347: f(x)= 0.7981765877175917
# differential_evolution step 348: f(x)= 0.7981765877175917
# differential_evolution step 349: f(x)= 0.7981765877175917
# differential_evolution step 350: f(x)= 0.7981765877175917
# differential_evolution step 351: f(x)= 0.7981765877175917
# differential_evolution step 352: f(x)= 0.7981765877175917
# differential_evolution step 353: f(x)= 0.7981765877175917
# differential_evolution step 354: f(x)= 0.7981765877175917
# differential_evolution step 355: f(x)= 0.7981765877175917
# differential_evolution step 356: f(x)= 0.7981765877175917
# differential_evolution step 357: f(x)= 0.7981765877175917
# differential_evolution step 358: f(x)= 0.7981765877175917
# differential_evolution step 359: f(x)= 0.7981765877175917
# differential_evolution step 360: f(x)= 0.7981765877175917
# differential_evolution step 361: f(x)= 0.7981765877175917
# differential_evolution step 362: f(x)= 0.7981765877175917
# differential_evolution step 363: f(x)= 0.7981765877175917
# differential_evolution step 364: f(x)= 0.7981765877175917
# differential_evolution step 365: f(x)= 0.7981765877175917
# differential_evolution step 366: f(x)= 0.7981765877175917
# differential_evolution step 367: f(x)= 0.7981765877175917
# differential_evolution step 368: f(x)= 0.7981765877175917
# differential_evolution step 369: f(x)= 0.7981765877175917
# differential_evolution step 370: f(x)= 0.7981765877175917
# differential_evolution step 371: f(x)= 0.7981765877175917
# differential_evolution step 372: f(x)= 0.7981765877175917
# differential_evolution step 373: f(x)= 0.7964579476868036
# differential_evolution step 374: f(x)= 0.7964579476868036
# differential_evolution step 375: f(x)= 0.7964579476868036
# differential_evolution step 376: f(x)= 0.7964579476868036
# differential_evolution step 377: f(x)= 0.7964579476868036
# differential_evolution step 378: f(x)= 0.7933241852374445
# differential_evolution step 379: f(x)= 0.7933241852374445
# differential_evolution step 380: f(x)= 0.7933241852374445
# differential_evolution step 381: f(x)= 0.7933241852374445
# differential_evolution step 382: f(x)= 0.7933241852374445
# differential_evolution step 383: f(x)= 0.7933241852374445
# differential_evolution step 384: f(x)= 0.7933241852374445
# differential_evolution step 385: f(x)= 0.7857748975700098
# differential_evolution step 386: f(x)= 0.7857748975700098
# differential_evolution step 387: f(x)= 0.7857748975700098
# differential_evolution step 388: f(x)= 0.7857748975700098
# differential_evolution step 389: f(x)= 0.7857748975700098
# differential_evolution step 390: f(x)= 0.7857748975700098
# differential_evolution step 391: f(x)= 0.7857748975700098
# differential_evolution step 392: f(x)= 0.7857748975700098
# differential_evolution step 393: f(x)= 0.7857748975700098
# differential_evolution step 394: f(x)= 0.7857748975700098
# differential_evolution step 395: f(x)= 0.7857748975700098
# differential_evolution step 396: f(x)= 0.7857748975700098
# differential_evolution step 397: f(x)= 0.7857748975700098
# differential_evolution step 398: f(x)= 0.7857748975700098
# differential_evolution step 399: f(x)= 0.7857748975700098
# differential_evolution step 400: f(x)= 0.7857748975700098
# differential_evolution step 401: f(x)= 0.7857748975700098
# differential_evolution step 402: f(x)= 0.7857748975700098
# differential_evolution step 403: f(x)= 0.7857748975700098
# differential_evolution step 404: f(x)= 0.7857748975700098
# differential_evolution step 405: f(x)= 0.7857748975700098
# differential_evolution step 406: f(x)= 0.7857748975700098
# differential_evolution step 407: f(x)= 0.7808005683801007
# differential_evolution step 408: f(x)= 0.7808005683801007
# differential_evolution step 409: f(x)= 0.7808005683801007
# differential_evolution step 410: f(x)= 0.7808005683801007
# differential_evolution step 411: f(x)= 0.7808005683801007
# differential_evolution step 412: f(x)= 0.7808005683801007
# differential_evolution step 413: f(x)= 0.7808005683801007
# differential_evolution step 414: f(x)= 0.7808005683801007
# differential_evolution step 415: f(x)= 0.7808005683801007
# differential_evolution step 416: f(x)= 0.7780175153655158
# differential_evolution step 417: f(x)= 0.7780175153655158
# differential_evolution step 418: f(x)= 0.7780175153655158
# differential_evolution step 419: f(x)= 0.7777712864252396
# differential_evolution step 420: f(x)= 0.7777712864252396
# differential_evolution step 421: f(x)= 0.7777712864252396
# differential_evolution step 422: f(x)= 0.7777712864252396
# differential_evolution step 423: f(x)= 0.7777712864252396
# differential_evolution step 424: f(x)= 0.7777712864252396
# differential_evolution step 425: f(x)= 0.7777712864252396
# differential_evolution step 426: f(x)= 0.7777712864252396
# differential_evolution step 427: f(x)= 0.7777712864252396
# differential_evolution step 428: f(x)= 0.7777712864252396
# differential_evolution step 429: f(x)= 0.7777712864252396
# differential_evolution step 430: f(x)= 0.7777712864252396
# differential_evolution step 431: f(x)= 0.7777712864252396
# differential_evolution step 432: f(x)= 0.7777712864252396
# differential_evolution step 433: f(x)= 0.7777712864252396
# differential_evolution step 434: f(x)= 0.7777712864252396
# differential_evolution step 435: f(x)= 0.7717275824936227
# differential_evolution step 436: f(x)= 0.7717275824936227
# differential_evolution step 437: f(x)= 0.7717275824936227
# differential_evolution step 438: f(x)= 0.7717275824936227
# differential_evolution step 439: f(x)= 0.7717275824936227
# differential_evolution step 440: f(x)= 0.7717275824936227
# differential_evolution step 441: f(x)= 0.7717275824936227
# differential_evolution step 442: f(x)= 0.7717275824936227
# differential_evolution step 443: f(x)= 0.7717275824936227
# differential_evolution step 444: f(x)= 0.7717275824936227
# differential_evolution step 445: f(x)= 0.7717275824936227
# differential_evolution step 446: f(x)= 0.7717275824936227
# differential_evolution step 447: f(x)= 0.7717275824936227
# differential_evolution step 448: f(x)= 0.7717275824936227
# differential_evolution step 449: f(x)= 0.7717275824936227
# differential_evolution step 450: f(x)= 0.7717275824936227
# differential_evolution step 451: f(x)= 0.7717275824936227
# differential_evolution step 452: f(x)= 0.7717275824936227
# differential_evolution step 453: f(x)= 0.7717275824936227
# differential_evolution step 454: f(x)= 0.7717275824936227
# differential_evolution step 455: f(x)= 0.7717275824936227
# differential_evolution step 456: f(x)= 0.7717275824936227
# differential_evolution step 457: f(x)= 0.7717275824936227
# differential_evolution step 458: f(x)= 0.7717275824936227
# differential_evolution step 459: f(x)= 0.7708581542562172
# differential_evolution step 460: f(x)= 0.7708581542562172
# differential_evolution step 461: f(x)= 0.7708581542562172
# differential_evolution step 462: f(x)= 0.7708581542562172
# differential_evolution step 463: f(x)= 0.7708581542562172
# differential_evolution step 464: f(x)= 0.7708581542562172
# differential_evolution step 465: f(x)= 0.7708581542562172
# differential_evolution step 466: f(x)= 0.7708581542562172
# differential_evolution step 467: f(x)= 0.7708581542562172
# differential_evolution step 468: f(x)= 0.7708581542562172
# differential_evolution step 469: f(x)= 0.7708581542562172
# differential_evolution step 470: f(x)= 0.7708581542562172
# differential_evolution step 471: f(x)= 0.7708581542562172
# differential_evolution step 472: f(x)= 0.7708581542562172
# differential_evolution step 473: f(x)= 0.7708581542562172
# differential_evolution step 474: f(x)= 0.7708581542562172
# differential_evolution step 475: f(x)= 0.7708581542562172
# differential_evolution step 476: f(x)= 0.7708581542562172
# differential_evolution step 477: f(x)= 0.770567196937381
# differential_evolution step 478: f(x)= 0.770567196937381
# differential_evolution step 479: f(x)= 0.7666524479860108
# differential_evolution step 480: f(x)= 0.7666524479860108
# differential_evolution step 481: f(x)= 0.7666524479860108
# differential_evolution step 482: f(x)= 0.7666524479860108
# differential_evolution step 483: f(x)= 0.7666524479860108
# differential_evolution step 484: f(x)= 0.7666524479860108
# differential_evolution step 485: f(x)= 0.7666524479860108
# differential_evolution step 486: f(x)= 0.7666524479860108
# differential_evolution step 487: f(x)= 0.7666524479860108
# differential_evolution step 488: f(x)= 0.7666524479860108
# differential_evolution step 489: f(x)= 0.7666524479860108
# differential_evolution step 490: f(x)= 0.7666524479860108
# differential_evolution step 491: f(x)= 0.7666524479860108
# differential_evolution step 492: f(x)= 0.7666524479860108
# differential_evolution step 493: f(x)= 0.7666524479860108
# differential_evolution step 494: f(x)= 0.7666524479860108
# differential_evolution step 495: f(x)= 0.7666524479860108
# differential_evolution step 496: f(x)= 0.763795980148784
# differential_evolution step 497: f(x)= 0.763795980148784
# differential_evolution step 498: f(x)= 0.763795980148784
# differential_evolution step 499: f(x)= 0.763795980148784
# differential_evolution step 500: f(x)= 0.763795980148784
# differential_evolution step 501: f(x)= 0.763795980148784
# differential_evolution step 502: f(x)= 0.763795980148784
# differential_evolution step 503: f(x)= 0.763795980148784
# differential_evolution step 504: f(x)= 0.763795980148784
# differential_evolution step 505: f(x)= 0.763795980148784
# differential_evolution step 506: f(x)= 0.763795980148784
# differential_evolution step 507: f(x)= 0.763795980148784
# differential_evolution step 508: f(x)= 0.763795980148784
# differential_evolution step 509: f(x)= 0.7606196587809126
# differential_evolution step 510: f(x)= 0.7606196587809126
# differential_evolution step 511: f(x)= 0.7604082223715551
# differential_evolution step 512: f(x)= 0.7604082223715551
# differential_evolution step 513: f(x)= 0.7604082223715551
# differential_evolution step 514: f(x)= 0.7604082223715551
# differential_evolution step 515: f(x)= 0.7604082223715551
# differential_evolution step 516: f(x)= 0.7604082223715551
# differential_evolution step 517: f(x)= 0.7604082223715551
# differential_evolution step 518: f(x)= 0.7604082223715551
# differential_evolution step 519: f(x)= 0.7604082223715551
# differential_evolution step 520: f(x)= 0.7604082223715551
# differential_evolution step 521: f(x)= 0.7604082223715551
# differential_evolution step 522: f(x)= 0.7604082223715551
# differential_evolution step 523: f(x)= 0.7604082223715551
# differential_evolution step 524: f(x)= 0.7604082223715551
# differential_evolution step 525: f(x)= 0.7604082223715551
# differential_evolution step 526: f(x)= 0.7554428862144316
# differential_evolution step 527: f(x)= 0.7554428862144316
# differential_evolution step 528: f(x)= 0.7554428862144316
# differential_evolution step 529: f(x)= 0.7554428862144316
# differential_evolution step 530: f(x)= 0.7554428862144316
# differential_evolution step 531: f(x)= 0.7554428862144316
# differential_evolution step 532: f(x)= 0.7554428862144316
# differential_evolution step 533: f(x)= 0.7554428862144316
# differential_evolution step 534: f(x)= 0.7554428862144316
# differential_evolution step 535: f(x)= 0.7554428862144316
# differential_evolution step 536: f(x)= 0.7554428862144316
# differential_evolution step 537: f(x)= 0.7554428862144316
# differential_evolution step 538: f(x)= 0.7554428862144316
# differential_evolution step 539: f(x)= 0.7551386972906443
# differential_evolution step 540: f(x)= 0.7551386972906443
# differential_evolution step 541: f(x)= 0.7551386972906443
# differential_evolution step 542: f(x)= 0.7551386972906443
# differential_evolution step 543: f(x)= 0.7521521956490371
# differential_evolution step 544: f(x)= 0.7521521956490371
# differential_evolution step 545: f(x)= 0.7521521956490371
# differential_evolution step 546: f(x)= 0.7521521956490371
# differential_evolution step 547: f(x)= 0.7521521956490371
# differential_evolution step 548: f(x)= 0.7521521956490371
# differential_evolution step 549: f(x)= 0.7521521956490371
# differential_evolution step 550: f(x)= 0.7521521956490371
# differential_evolution step 551: f(x)= 0.7521521956490371
# differential_evolution step 552: f(x)= 0.7521521956490371
# differential_evolution step 553: f(x)= 0.7521521956490371
# differential_evolution step 554: f(x)= 0.7521521956490371
# differential_evolution step 555: f(x)= 0.7521521956490371
# differential_evolution step 556: f(x)= 0.7521521956490371
# differential_evolution step 557: f(x)= 0.7521521956490371
# differential_evolution step 558: f(x)= 0.7521521956490371
# differential_evolution step 559: f(x)= 0.7521521956490371
# differential_evolution step 560: f(x)= 0.7521521956490371
# differential_evolution step 561: f(x)= 0.7521521956490371
# differential_evolution step 562: f(x)= 0.7521521956490371
# differential_evolution step 563: f(x)= 0.7521521956490371
# differential_evolution step 564: f(x)= 0.7521521956490371
# differential_evolution step 565: f(x)= 0.7521521956490371
# differential_evolution step 566: f(x)= 0.7521521956490371
# differential_evolution step 567: f(x)= 0.7521521956490371
# differential_evolution step 568: f(x)= 0.7521521956490371
# differential_evolution step 569: f(x)= 0.7521521956490371
# differential_evolution step 570: f(x)= 0.7521521956490371
# differential_evolution step 571: f(x)= 0.7521521956490371
# differential_evolution step 572: f(x)= 0.7521521956490371
# differential_evolution step 573: f(x)= 0.7521521956490371
# differential_evolution step 574: f(x)= 0.7521521956490371
# differential_evolution step 575: f(x)= 0.7521521956490371
# differential_evolution step 576: f(x)= 0.7521521956490371
# differential_evolution step 577: f(x)= 0.7521521956490371
# differential_evolution step 578: f(x)= 0.7521521956490371
# differential_evolution step 579: f(x)= 0.7521521956490371
# differential_evolution step 580: f(x)= 0.7521521956490371
# differential_evolution step 581: f(x)= 0.7521521956490371
# differential_evolution step 582: f(x)= 0.7518600262542194
# differential_evolution step 583: f(x)= 0.7518600262542194
# differential_evolution step 584: f(x)= 0.7518600262542194
# differential_evolution step 585: f(x)= 0.7518600262542194
# differential_evolution step 586: f(x)= 0.7518600262542194
# differential_evolution step 587: f(x)= 0.7518600262542194
# differential_evolution step 588: f(x)= 0.7518600262542194
# differential_evolution step 589: f(x)= 0.7518600262542194
# differential_evolution step 590: f(x)= 0.7518600262542194
# differential_evolution step 591: f(x)= 0.7518600262542194
# differential_evolution step 592: f(x)= 0.7518600262542194
# differential_evolution step 593: f(x)= 0.7518600262542194
# differential_evolution step 594: f(x)= 0.7518600262542194
# differential_evolution step 595: f(x)= 0.7518600262542194
# differential_evolution step 596: f(x)= 0.7518600262542194
# differential_evolution step 597: f(x)= 0.7518600262542194
# differential_evolution step 598: f(x)= 0.7518600262542194
# differential_evolution step 599: f(x)= 0.7518600262542194
# differential_evolution step 600: f(x)= 0.7518600262542194
# differential_evolution step 601: f(x)= 0.7518600262542194
# differential_evolution step 602: f(x)= 0.7518600262542194
# differential_evolution step 603: f(x)= 0.7518600262542194
# differential_evolution step 604: f(x)= 0.7518600262542194
# differential_evolution step 605: f(x)= 0.7518600262542194
# differential_evolution step 606: f(x)= 0.7518600262542194
# differential_evolution step 607: f(x)= 0.7506928676604273
# differential_evolution step 608: f(x)= 0.7506928676604273
# differential_evolution step 609: f(x)= 0.7506928676604273
# differential_evolution step 610: f(x)= 0.7506928676604273
# differential_evolution step 611: f(x)= 0.7506928676604273
# differential_evolution step 612: f(x)= 0.7506928676604273
# differential_evolution step 613: f(x)= 0.7506928676604273
# differential_evolution step 614: f(x)= 0.7506928676604273
# differential_evolution step 615: f(x)= 0.7506928676604273
# differential_evolution step 616: f(x)= 0.7506928676604273
# differential_evolution step 617: f(x)= 0.7506928676604273
# differential_evolution step 618: f(x)= 0.7506928676604273
# differential_evolution step 619: f(x)= 0.7506928676604273
# differential_evolution step 620: f(x)= 0.7506928676604273
# differential_evolution step 621: f(x)= 0.7506928676604273
# differential_evolution step 622: f(x)= 0.7506928676604273
# differential_evolution step 623: f(x)= 0.7506928676604273
# differential_evolution step 624: f(x)= 0.7506928676604273
# differential_evolution step 625: f(x)= 0.7506928676604273
# differential_evolution step 626: f(x)= 0.7506928676604273
# differential_evolution step 627: f(x)= 0.7506928676604273
# differential_evolution step 628: f(x)= 0.7506928676604273
# differential_evolution step 629: f(x)= 0.7506928676604273
# differential_evolution step 630: f(x)= 0.7506928676604273
# differential_evolution step 631: f(x)= 0.7506928676604273
# differential_evolution step 632: f(x)= 0.7506928676604273
# differential_evolution step 633: f(x)= 0.7506928676604273
# differential_evolution step 634: f(x)= 0.7506928676604273
# differential_evolution step 635: f(x)= 0.7506928676604273
# differential_evolution step 636: f(x)= 0.7497393426648508
# differential_evolution step 637: f(x)= 0.7497393426648508
# differential_evolution step 638: f(x)= 0.7497393426648508
# differential_evolution step 639: f(x)= 0.7497393426648508
# differential_evolution step 640: f(x)= 0.7497393426648508
# differential_evolution step 641: f(x)= 0.7497393426648508
# differential_evolution step 642: f(x)= 0.7497393426648508
# differential_evolution step 643: f(x)= 0.7497393426648508
# differential_evolution step 644: f(x)= 0.7497393426648508
# differential_evolution step 645: f(x)= 0.7497393426648508
# differential_evolution step 646: f(x)= 0.7493638469818084
# differential_evolution step 647: f(x)= 0.7493638469818084
# differential_evolution step 648: f(x)= 0.7493638469818084
# differential_evolution step 649: f(x)= 0.7493638469818084
# differential_evolution step 650: f(x)= 0.7493638469818084
# differential_evolution step 651: f(x)= 0.7493638469818084
# differential_evolution step 652: f(x)= 0.7493638469818084
# differential_evolution step 653: f(x)= 0.7474249208851603
# differential_evolution step 654: f(x)= 0.7474249208851603
# differential_evolution step 655: f(x)= 0.7474249208851603
# differential_evolution step 656: f(x)= 0.7474249208851603
# differential_evolution step 657: f(x)= 0.7474249208851603
# differential_evolution step 658: f(x)= 0.7474249208851603
# differential_evolution step 659: f(x)= 0.7474249208851603
# differential_evolution step 660: f(x)= 0.7474249208851603
# differential_evolution step 661: f(x)= 0.7474249208851603
# differential_evolution step 662: f(x)= 0.7474249208851603
# differential_evolution step 663: f(x)= 0.7474249208851603
# differential_evolution step 664: f(x)= 0.7474249208851603
# differential_evolution step 665: f(x)= 0.7474249208851603
# differential_evolution step 666: f(x)= 0.7474249208851603
# differential_evolution step 667: f(x)= 0.7474249208851603
# differential_evolution step 668: f(x)= 0.7474249208851603
# differential_evolution step 669: f(x)= 0.7474249208851603
# differential_evolution step 670: f(x)= 0.7474249208851603
# differential_evolution step 671: f(x)= 0.7474249208851603
# differential_evolution step 672: f(x)= 0.7474249208851603
# differential_evolution step 673: f(x)= 0.7474249208851603
# differential_evolution step 674: f(x)= 0.7474249208851603
# differential_evolution step 675: f(x)= 0.7459825749754055
# differential_evolution step 676: f(x)= 0.7459825749754055
# differential_evolution step 677: f(x)= 0.7459825749754055
# differential_evolution step 678: f(x)= 0.7459825749754055
# differential_evolution step 679: f(x)= 0.7424209565644011
# differential_evolution step 680: f(x)= 0.7424209565644011
# differential_evolution step 681: f(x)= 0.7424209565644011
# differential_evolution step 682: f(x)= 0.7424209565644011
# differential_evolution step 683: f(x)= 0.7424209565644011
# differential_evolution step 684: f(x)= 0.7424209565644011
# differential_evolution step 685: f(x)= 0.7424209565644011
# differential_evolution step 686: f(x)= 0.7424209565644011
# differential_evolution step 687: f(x)= 0.7424209565644011
# differential_evolution step 688: f(x)= 0.7424209565644011
# differential_evolution step 689: f(x)= 0.7424209565644011
# differential_evolution step 690: f(x)= 0.7424209565644011
# differential_evolution step 691: f(x)= 0.7424209565644011
# differential_evolution step 692: f(x)= 0.7424209565644011
# differential_evolution step 693: f(x)= 0.7424209565644011
# differential_evolution step 694: f(x)= 0.7424209565644011
# differential_evolution step 695: f(x)= 0.7424209565644011
# differential_evolution step 696: f(x)= 0.7424209565644011
# differential_evolution step 697: f(x)= 0.7424209565644011
# differential_evolution step 698: f(x)= 0.7424209565644011
# differential_evolution step 699: f(x)= 0.7424209565644011
# differential_evolution step 700: f(x)= 0.7424209565644011
# differential_evolution step 701: f(x)= 0.7424209565644011
# differential_evolution step 702: f(x)= 0.7424209565644011
# differential_evolution step 703: f(x)= 0.7424209565644011
# differential_evolution step 704: f(x)= 0.7424209565644011
# differential_evolution step 705: f(x)= 0.7424209565644011
# differential_evolution step 706: f(x)= 0.7424209565644011
# differential_evolution step 707: f(x)= 0.7424209565644011
# differential_evolution step 708: f(x)= 0.7424209565644011
# differential_evolution step 709: f(x)= 0.7424209565644011
# differential_evolution step 710: f(x)= 0.7424209565644011
# differential_evolution step 711: f(x)= 0.7424209565644011
# differential_evolution step 712: f(x)= 0.7424209565644011
# differential_evolution step 713: f(x)= 0.7424209565644011
# differential_evolution step 714: f(x)= 0.7424209565644011
# differential_evolution step 715: f(x)= 0.7424209565644011
# differential_evolution step 716: f(x)= 0.7424209565644011
# differential_evolution step 717: f(x)= 0.7424209565644011
# differential_evolution step 718: f(x)= 0.7424209565644011
# differential_evolution step 719: f(x)= 0.7424209565644011
# differential_evolution step 720: f(x)= 0.7424209565644011
# differential_evolution step 721: f(x)= 0.7424209565644011
# differential_evolution step 722: f(x)= 0.7424209565644011
# differential_evolution step 723: f(x)= 0.7424209565644011
# differential_evolution step 724: f(x)= 0.7424209565644011
# differential_evolution step 725: f(x)= 0.7424209565644011
# differential_evolution step 726: f(x)= 0.7424209565644011
# differential_evolution step 727: f(x)= 0.7424209565644011
# differential_evolution step 728: f(x)= 0.7424209565644011
# differential_evolution step 729: f(x)= 0.7424209565644011
# differential_evolution step 730: f(x)= 0.7424209565644011
# differential_evolution step 731: f(x)= 0.7424209565644011
# differential_evolution step 732: f(x)= 0.7424209565644011
# differential_evolution step 733: f(x)= 0.7424209565644011
# differential_evolution step 734: f(x)= 0.7424209565644011
# differential_evolution step 735: f(x)= 0.7424209565644011
# differential_evolution step 736: f(x)= 0.7424209565644011
# differential_evolution step 737: f(x)= 0.7421364645472743
# differential_evolution step 738: f(x)= 0.7421364645472743
# differential_evolution step 739: f(x)= 0.7421364645472743
# differential_evolution step 740: f(x)= 0.7421364645472743
# differential_evolution step 741: f(x)= 0.7421364645472743
# differential_evolution step 742: f(x)= 0.7391743613557198
# differential_evolution step 743: f(x)= 0.7391743613557198
# differential_evolution step 744: f(x)= 0.7391743613557198
# differential_evolution step 745: f(x)= 0.7391743613557198
# differential_evolution step 746: f(x)= 0.7391743613557198
# differential_evolution step 747: f(x)= 0.7391743613557198
# differential_evolution step 748: f(x)= 0.7391743613557198
# differential_evolution step 749: f(x)= 0.7391743613557198
# differential_evolution step 750: f(x)= 0.7391743613557198
# differential_evolution step 751: f(x)= 0.7391743613557198
# differential_evolution step 752: f(x)= 0.7391743613557198
# differential_evolution step 753: f(x)= 0.7391743613557198
# differential_evolution step 754: f(x)= 0.7391743613557198
# differential_evolution step 755: f(x)= 0.7391743613557198
# differential_evolution step 756: f(x)= 0.7391743613557198
# differential_evolution step 757: f(x)= 0.7391743613557198
# differential_evolution step 758: f(x)= 0.7391743613557198
# differential_evolution step 759: f(x)= 0.7391743613557198
# differential_evolution step 760: f(x)= 0.7391743613557198
# differential_evolution step 761: f(x)= 0.7391743613557198
# differential_evolution step 762: f(x)= 0.7391743613557198
# differential_evolution step 763: f(x)= 0.7391743613557198
# differential_evolution step 764: f(x)= 0.7391743613557198
# differential_evolution step 765: f(x)= 0.7391743613557198
# differential_evolution step 766: f(x)= 0.7391743613557198
# differential_evolution step 767: f(x)= 0.7391743613557198
# differential_evolution step 768: f(x)= 0.7391743613557198
# differential_evolution step 769: f(x)= 0.7391743613557198
# differential_evolution step 770: f(x)= 0.7391743613557198
# differential_evolution step 771: f(x)= 0.7391743613557198
# differential_evolution step 772: f(x)= 0.7391743613557198
# differential_evolution step 773: f(x)= 0.7391743613557198
# differential_evolution step 774: f(x)= 0.7391743613557198
# differential_evolution step 775: f(x)= 0.7391743613557198
# differential_evolution step 776: f(x)= 0.7391743613557198
# differential_evolution step 777: f(x)= 0.7391743613557198
# differential_evolution step 778: f(x)= 0.7391743613557198
# differential_evolution step 779: f(x)= 0.7391743613557198
# differential_evolution step 780: f(x)= 0.7388981827108488
# differential_evolution step 781: f(x)= 0.7388981827108488
# differential_evolution step 782: f(x)= 0.7388981827108488
# differential_evolution step 783: f(x)= 0.7388981827108488
# differential_evolution step 784: f(x)= 0.7388981827108488
# differential_evolution step 785: f(x)= 0.7388981827108488
# differential_evolution step 786: f(x)= 0.7388981827108488
# differential_evolution step 787: f(x)= 0.7388981827108488
# differential_evolution step 788: f(x)= 0.7388981827108488
# differential_evolution step 789: f(x)= 0.7388981827108488
# differential_evolution step 790: f(x)= 0.7388981827108488
# differential_evolution step 791: f(x)= 0.7388981827108488
# differential_evolution step 792: f(x)= 0.7388981827108488
# differential_evolution step 793: f(x)= 0.7388981827108488
# differential_evolution step 794: f(x)= 0.7388981827108488
# differential_evolution step 795: f(x)= 0.7388981827108488
# differential_evolution step 796: f(x)= 0.7388981827108488
# differential_evolution step 797: f(x)= 0.7388981827108488
# differential_evolution step 798: f(x)= 0.7388981827108488
# differential_evolution step 799: f(x)= 0.7388981827108488
# differential_evolution step 800: f(x)= 0.7388981827108488
# differential_evolution step 801: f(x)= 0.7388981827108488
# differential_evolution step 802: f(x)= 0.7388981827108488
# differential_evolution step 803: f(x)= 0.7388981827108488
# differential_evolution step 804: f(x)= 0.7388981827108488
# differential_evolution step 805: f(x)= 0.7388981827108488
# differential_evolution step 806: f(x)= 0.7388981827108488
# differential_evolution step 807: f(x)= 0.7388981827108488
# differential_evolution step 808: f(x)= 0.7388981827108488
# differential_evolution step 809: f(x)= 0.7388981827108488
# differential_evolution step 810: f(x)= 0.7378662366115851
# differential_evolution step 811: f(x)= 0.7378662366115851
# differential_evolution step 812: f(x)= 0.7378662366115851
# differential_evolution step 813: f(x)= 0.7378662366115851
# differential_evolution step 814: f(x)= 0.7378662366115851
# differential_evolution step 815: f(x)= 0.7378662366115851
# differential_evolution step 816: f(x)= 0.7378662366115851
# differential_evolution step 817: f(x)= 0.7378662366115851
# differential_evolution step 818: f(x)= 0.7378662366115851
# differential_evolution step 819: f(x)= 0.7378662366115851
# differential_evolution step 820: f(x)= 0.7378662366115851
# differential_evolution step 821: f(x)= 0.7378662366115851
# differential_evolution step 822: f(x)= 0.7378662366115851
# differential_evolution step 823: f(x)= 0.7378662366115851
# differential_evolution step 824: f(x)= 0.7378662366115851
# differential_evolution step 825: f(x)= 0.7378662366115851
# differential_evolution step 826: f(x)= 0.7378662366115851
# differential_evolution step 827: f(x)= 0.7378662366115851
# differential_evolution step 828: f(x)= 0.7369507098194306
# differential_evolution step 829: f(x)= 0.7369507098194306
# differential_evolution step 830: f(x)= 0.7369507098194306
# differential_evolution step 831: f(x)= 0.7369507098194306
# differential_evolution step 832: f(x)= 0.7369507098194306
# differential_evolution step 833: f(x)= 0.7369507098194306
# differential_evolution step 834: f(x)= 0.7369507098194306
# differential_evolution step 835: f(x)= 0.7369507098194306
# differential_evolution step 836: f(x)= 0.7369507098194306
# differential_evolution step 837: f(x)= 0.7369507098194306
# differential_evolution step 838: f(x)= 0.7369507098194306
# differential_evolution step 839: f(x)= 0.7369507098194306
# differential_evolution step 840: f(x)= 0.7369507098194306
# differential_evolution step 841: f(x)= 0.7369507098194306
# differential_evolution step 842: f(x)= 0.7367453247103424
# differential_evolution step 843: f(x)= 0.7367453247103424
# differential_evolution step 844: f(x)= 0.7367453247103424
# differential_evolution step 845: f(x)= 0.7367453247103424
# differential_evolution step 846: f(x)= 0.7367453247103424
# differential_evolution step 847: f(x)= 0.7367453247103424
# differential_evolution step 848: f(x)= 0.7367453247103424
# differential_evolution step 849: f(x)= 0.7367453247103424
# differential_evolution step 850: f(x)= 0.7367453247103424
# differential_evolution step 851: f(x)= 0.7367453247103424
# differential_evolution step 852: f(x)= 0.7367453247103424
# differential_evolution step 853: f(x)= 0.7367453247103424
# differential_evolution step 854: f(x)= 0.7367453247103424
# differential_evolution step 855: f(x)= 0.7367453247103424
# differential_evolution step 856: f(x)= 0.7367350044325162
# differential_evolution step 857: f(x)= 0.7367350044325162
# differential_evolution step 858: f(x)= 0.7367350044325162
# differential_evolution step 859: f(x)= 0.7367350044325162
# differential_evolution step 860: f(x)= 0.7367350044325162
# differential_evolution step 861: f(x)= 0.7367350044325162
# differential_evolution step 862: f(x)= 0.7367350044325162
# differential_evolution step 863: f(x)= 0.7367350044325162
# differential_evolution step 864: f(x)= 0.7367350044325162
# differential_evolution step 865: f(x)= 0.7367350044325162
# differential_evolution step 866: f(x)= 0.7367350044325162
# differential_evolution step 867: f(x)= 0.7367350044325162
# differential_evolution step 868: f(x)= 0.7367350044325162
# differential_evolution step 869: f(x)= 0.7367350044325162
# differential_evolution step 870: f(x)= 0.7367350044325162
# differential_evolution step 871: f(x)= 0.7367350044325162
# differential_evolution step 872: f(x)= 0.7367350044325162
# differential_evolution step 873: f(x)= 0.7367350044325162
# differential_evolution step 874: f(x)= 0.7362816850393719
# differential_evolution step 875: f(x)= 0.7362816850393719
# differential_evolution step 876: f(x)= 0.7362816850393719
# differential_evolution step 877: f(x)= 0.7362816850393719
# differential_evolution step 878: f(x)= 0.7356607268528421
# differential_evolution step 879: f(x)= 0.7356607268528421
# differential_evolution step 880: f(x)= 0.7356607268528421
# differential_evolution step 881: f(x)= 0.7356607268528421
# differential_evolution step 882: f(x)= 0.7356607268528421
# differential_evolution step 883: f(x)= 0.7356607268528421
# differential_evolution step 884: f(x)= 0.7356607268528421
# differential_evolution step 885: f(x)= 0.7356607268528421
# differential_evolution step 886: f(x)= 0.7354104838142845
# differential_evolution step 887: f(x)= 0.7354104838142845
# differential_evolution step 888: f(x)= 0.7354104838142845
# differential_evolution step 889: f(x)= 0.7354104838142845
# differential_evolution step 890: f(x)= 0.7354104838142845
# differential_evolution step 891: f(x)= 0.7354104838142845
# differential_evolution step 892: f(x)= 0.7354104838142845
# differential_evolution step 893: f(x)= 0.7354104838142845
# differential_evolution step 894: f(x)= 0.7354104838142845
# differential_evolution step 895: f(x)= 0.7354104838142845
# differential_evolution step 896: f(x)= 0.7354104838142845
# differential_evolution step 897: f(x)= 0.7354104838142845
# differential_evolution step 898: f(x)= 0.7354104838142845
# differential_evolution step 899: f(x)= 0.7354104838142845
# differential_evolution step 900: f(x)= 0.7354104838142845
# differential_evolution step 901: f(x)= 0.7354104838142845
# differential_evolution step 902: f(x)= 0.7354104838142845
# differential_evolution step 903: f(x)= 0.7354104838142845
# differential_evolution step 904: f(x)= 0.7354104838142845
# differential_evolution step 905: f(x)= 0.7354104838142845
# differential_evolution step 906: f(x)= 0.7354104838142845
# differential_evolution step 907: f(x)= 0.7354104838142845
# differential_evolution step 908: f(x)= 0.7354037302901139
# differential_evolution step 909: f(x)= 0.7354037302901139
# differential_evolution step 910: f(x)= 0.7354037302901139
# differential_evolution step 911: f(x)= 0.7354037302901139
# differential_evolution step 912: f(x)= 0.7354037302901139
# differential_evolution step 913: f(x)= 0.7354037302901139
# differential_evolution step 914: f(x)= 0.7354037302901139
# differential_evolution step 915: f(x)= 0.7354037302901139
# differential_evolution step 916: f(x)= 0.7354037302901139
# differential_evolution step 917: f(x)= 0.7354037302901139
# differential_evolution step 918: f(x)= 0.7354037302901139
# differential_evolution step 919: f(x)= 0.7354037302901139
# differential_evolution step 920: f(x)= 0.7354037302901139
# differential_evolution step 921: f(x)= 0.7354037302901139
# differential_evolution step 922: f(x)= 0.7354037302901139
# differential_evolution step 923: f(x)= 0.7354037302901139
# differential_evolution step 924: f(x)= 0.7354037302901139
# differential_evolution step 925: f(x)= 0.7354037302901139
# differential_evolution step 926: f(x)= 0.7352953151396734
# differential_evolution step 927: f(x)= 0.7352953151396734
# differential_evolution step 928: f(x)= 0.7352953151396734
# differential_evolution step 929: f(x)= 0.7352953151396734
# differential_evolution step 930: f(x)= 0.7352008121435971
# differential_evolution step 931: f(x)= 0.7352008121435971
# differential_evolution step 932: f(x)= 0.7352008121435971
# differential_evolution step 933: f(x)= 0.7352008121435971
# differential_evolution step 934: f(x)= 0.7352008121435971
# differential_evolution step 935: f(x)= 0.7352008121435971
# differential_evolution step 936: f(x)= 0.7352008121435971
# differential_evolution step 937: f(x)= 0.7352008121435971
# differential_evolution step 938: f(x)= 0.7348862305204589
# differential_evolution step 939: f(x)= 0.7348862305204589
# differential_evolution step 940: f(x)= 0.7348862305204589
# differential_evolution step 941: f(x)= 0.7348862305204589
# differential_evolution step 942: f(x)= 0.7348862305204589
# differential_evolution step 943: f(x)= 0.7348862305204589
# differential_evolution step 944: f(x)= 0.7348862305204589
# differential_evolution step 945: f(x)= 0.7348862305204589
# differential_evolution step 946: f(x)= 0.7348862305204589
# differential_evolution step 947: f(x)= 0.7348862305204589
# differential_evolution step 948: f(x)= 0.7348862305204589
# differential_evolution step 949: f(x)= 0.7348862305204589
# differential_evolution step 950: f(x)= 0.7348862305204589
# differential_evolution step 951: f(x)= 0.7348862305204589
# differential_evolution step 952: f(x)= 0.7348862305204589
# differential_evolution step 953: f(x)= 0.7348862305204589
# differential_evolution step 954: f(x)= 0.7348862305204589
# differential_evolution step 955: f(x)= 0.7348862305204589
# differential_evolution step 956: f(x)= 0.7348862305204589
# differential_evolution step 957: f(x)= 0.7348862305204589
# differential_evolution step 958: f(x)= 0.7348862305204589
# differential_evolution step 959: f(x)= 0.7348862305204589
# differential_evolution step 960: f(x)= 0.7348862305204589
# differential_evolution step 961: f(x)= 0.7340831431722107
# differential_evolution step 962: f(x)= 0.7340831431722107
# differential_evolution step 963: f(x)= 0.7340831431722107
# differential_evolution step 964: f(x)= 0.7340831431722107
# differential_evolution step 965: f(x)= 0.7340831431722107
# differential_evolution step 966: f(x)= 0.7340831431722107
# differential_evolution step 967: f(x)= 0.7340831431722107
# differential_evolution step 968: f(x)= 0.7340831431722107
# differential_evolution step 969: f(x)= 0.7340831431722107
# differential_evolution step 970: f(x)= 0.7340831431722107
# differential_evolution step 971: f(x)= 0.7340831431722107
# differential_evolution step 972: f(x)= 0.7340831431722107
# differential_evolution step 973: f(x)= 0.7339191392213934
# differential_evolution step 974: f(x)= 0.7339191392213934
# differential_evolution step 975: f(x)= 0.7339191392213934
# differential_evolution step 976: f(x)= 0.7339191392213934
# differential_evolution step 977: f(x)= 0.7339191392213934
# differential_evolution step 978: f(x)= 0.7339191392213934
# differential_evolution step 979: f(x)= 0.7339191392213934
# differential_evolution step 980: f(x)= 0.7339191392213934
# differential_evolution step 981: f(x)= 0.7339191392213934
# differential_evolution step 982: f(x)= 0.7339191392213934
# differential_evolution step 983: f(x)= 0.7339191392213934
# differential_evolution step 984: f(x)= 0.7339191392213934
# differential_evolution step 985: f(x)= 0.7339191392213934
# differential_evolution step 986: f(x)= 0.7339191392213934
# differential_evolution step 987: f(x)= 0.7339191392213934
# differential_evolution step 988: f(x)= 0.7339191392213934
# differential_evolution step 989: f(x)= 0.7339191392213934
# differential_evolution step 990: f(x)= 0.7339191392213934
# differential_evolution step 991: f(x)= 0.7339191392213934
# differential_evolution step 992: f(x)= 0.7339191392213934
# differential_evolution step 993: f(x)= 0.7339191392213934
# differential_evolution step 994: f(x)= 0.7339191392213934
# differential_evolution step 995: f(x)= 0.7339191392213934
# differential_evolution step 996: f(x)= 0.7339191392213934
# differential_evolution step 997: f(x)= 0.7339191392213934
# differential_evolution step 998: f(x)= 0.7339191392213934
# differential_evolution step 999: f(x)= 0.7339191392213934
# differential_evolution step 1000: f(x)= 0.7339191392213934
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [ 0.92451039  5.9903214   1.04401382 27.08789514  1.34704585  1.70316301
#   0.71838393 47.60716186  0.22781192  5.34028951  1.53974724 70.26999697
#   0.48475062 13.11083376  1.17928912 51.4548364 ]
# Chi quadro minimo: 0.7319113394935607

# %%
# Plots:
params_curve_4, covariance_4 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params4, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[3], red_chi[3] = save_params(params_curve_4, covariance_4, radial_profile_HA, radial_profile_error_HA, x_axes, 4, line_name="Four", output_prefix="fit")

aic[3] = AIC(x_axes, radial_profile_HA, chi_quadr[3], params_curve_4)
bic[3] = BIC(x_axes, radial_profile_HA, chi_quadr[3], params_curve_4)
print(aic[3], chi_quadr[3], bic[3], len(params_curve_4))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_4)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[12:16]), color='orange', linestyle='--', label='Sérsic 4')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_4', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.8017, r_e=6.6819, n=1.1446, x_0=27.1696
# Sérsic 2: I_e=1.3691, r_e=1.8505, n=0.7038, x_0=47.6453
# Sérsic 3: I_e=0.1713, r_e=6.8497, n=1.7446, x_0=70.3542
# Sérsic 4: I_e=0.5265, r_e=11.6205, n=1.1082, x_0=51.6856
# [0.05992646 0.38294196 0.05794534 0.06450491 0.32582762 0.33350492
#  0.1884294  0.10908369 0.07255436 2.58097045 0.3138767  0.08203129
#  0.14047206 2.31555546 0.1497902  0.34021761]
# 25.51703034983078
# 64.07124721730065 25.51703034983078 99.19975332564024 16
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (25, 35),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (40, 50),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (65, 75),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (45, 55), 

    (0, 10),
    (0, 50),
    (0.1, 10),
    (55, 65)
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params5 = result.x

print("Optimize parameters with differential_evolution:", best_params5)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 8432.56987608014
# differential_evolution step 2: f(x)= 8432.56987608014
# differential_evolution step 3: f(x)= 8432.56987608014
# differential_evolution step 4: f(x)= 8205.600113455175
# differential_evolution step 5: f(x)= 5350.75282104686
# differential_evolution step 6: f(x)= 5350.75282104686
# differential_evolution step 7: f(x)= 2721.991461764326
# differential_evolution step 8: f(x)= 748.4829732468683
# differential_evolution step 9: f(x)= 748.4829732468683
# differential_evolution step 10: f(x)= 748.4829732468683
# differential_evolution step 11: f(x)= 748.4829732468683
# differential_evolution step 12: f(x)= 486.60011866691184
# differential_evolution step 13: f(x)= 486.60011866691184
# differential_evolution step 14: f(x)= 486.60011866691184
# differential_evolution step 15: f(x)= 486.60011866691184
# differential_evolution step 16: f(x)= 486.60011866691184
# differential_evolution step 17: f(x)= 486.60011866691184
# differential_evolution step 18: f(x)= 100.15226133821169
# differential_evolution step 19: f(x)= 100.15226133821169
# differential_evolution step 20: f(x)= 100.15226133821169
# differential_evolution step 21: f(x)= 100.15226133821169
# differential_evolution step 22: f(x)= 100.15226133821169
# differential_evolution step 23: f(x)= 100.15226133821169
# differential_evolution step 24: f(x)= 100.15226133821169
# differential_evolution step 25: f(x)= 100.15226133821169
# differential_evolution step 26: f(x)= 100.15226133821169
# differential_evolution step 27: f(x)= 100.15226133821169
# differential_evolution step 28: f(x)= 100.15226133821169
# differential_evolution step 29: f(x)= 100.15226133821169
# differential_evolution step 30: f(x)= 100.15226133821169
# differential_evolution step 31: f(x)= 100.15226133821169
# differential_evolution step 32: f(x)= 100.15226133821169
# differential_evolution step 33: f(x)= 100.15226133821169
# differential_evolution step 34: f(x)= 100.15226133821169
# differential_evolution step 35: f(x)= 65.58796919926004
# differential_evolution step 36: f(x)= 65.58796919926004
# differential_evolution step 37: f(x)= 50.069953788287364
# differential_evolution step 38: f(x)= 50.069953788287364
# differential_evolution step 39: f(x)= 50.069953788287364
# differential_evolution step 40: f(x)= 50.069953788287364
# differential_evolution step 41: f(x)= 50.069953788287364
# differential_evolution step 42: f(x)= 50.069953788287364
# differential_evolution step 43: f(x)= 50.069953788287364
# differential_evolution step 44: f(x)= 50.069953788287364
# differential_evolution step 45: f(x)= 50.069953788287364
# differential_evolution step 46: f(x)= 50.069953788287364
# differential_evolution step 47: f(x)= 50.069953788287364
# differential_evolution step 48: f(x)= 50.069953788287364
# differential_evolution step 49: f(x)= 50.069953788287364
# differential_evolution step 50: f(x)= 50.069953788287364
# differential_evolution step 51: f(x)= 50.069953788287364
# differential_evolution step 52: f(x)= 50.069953788287364
# differential_evolution step 53: f(x)= 50.069953788287364
# differential_evolution step 54: f(x)= 50.069953788287364
# differential_evolution step 55: f(x)= 50.069953788287364
# differential_evolution step 56: f(x)= 50.069953788287364
# differential_evolution step 57: f(x)= 50.069953788287364
# differential_evolution step 58: f(x)= 42.04660489906742
# differential_evolution step 59: f(x)= 42.04660489906742
# differential_evolution step 60: f(x)= 42.04660489906742
# differential_evolution step 61: f(x)= 29.21089628202919
# differential_evolution step 62: f(x)= 29.21089628202919
# differential_evolution step 63: f(x)= 29.21089628202919
# differential_evolution step 64: f(x)= 29.21089628202919
# differential_evolution step 65: f(x)= 29.21089628202919
# differential_evolution step 66: f(x)= 29.21089628202919
# differential_evolution step 67: f(x)= 29.21089628202919
# differential_evolution step 68: f(x)= 29.21089628202919
# differential_evolution step 69: f(x)= 29.21089628202919
# differential_evolution step 70: f(x)= 29.21089628202919
# differential_evolution step 71: f(x)= 20.498980383130082
# differential_evolution step 72: f(x)= 20.498980383130082
# differential_evolution step 73: f(x)= 20.498980383130082
# differential_evolution step 74: f(x)= 20.498980383130082
# differential_evolution step 75: f(x)= 20.498980383130082
# differential_evolution step 76: f(x)= 20.498980383130082
# differential_evolution step 77: f(x)= 20.498980383130082
# differential_evolution step 78: f(x)= 20.498980383130082
# differential_evolution step 79: f(x)= 20.498980383130082
# differential_evolution step 80: f(x)= 20.498980383130082
# differential_evolution step 81: f(x)= 20.498980383130082
# differential_evolution step 82: f(x)= 20.498980383130082
# differential_evolution step 83: f(x)= 20.498980383130082
# differential_evolution step 84: f(x)= 20.498980383130082
# differential_evolution step 85: f(x)= 20.498980383130082
# differential_evolution step 86: f(x)= 20.498980383130082
# differential_evolution step 87: f(x)= 20.498980383130082
# differential_evolution step 88: f(x)= 20.498980383130082
# differential_evolution step 89: f(x)= 20.498980383130082
# differential_evolution step 90: f(x)= 20.498980383130082
# differential_evolution step 91: f(x)= 20.498980383130082
# differential_evolution step 92: f(x)= 20.498980383130082
# differential_evolution step 93: f(x)= 20.498980383130082
# differential_evolution step 94: f(x)= 20.498980383130082
# differential_evolution step 95: f(x)= 20.498980383130082
# differential_evolution step 96: f(x)= 20.498980383130082
# differential_evolution step 97: f(x)= 20.498980383130082
# differential_evolution step 98: f(x)= 20.498980383130082
# differential_evolution step 99: f(x)= 20.498980383130082
# differential_evolution step 100: f(x)= 20.498980383130082
# differential_evolution step 101: f(x)= 20.498980383130082
# differential_evolution step 102: f(x)= 20.498980383130082
# differential_evolution step 103: f(x)= 20.498980383130082
# differential_evolution step 104: f(x)= 20.498980383130082
# differential_evolution step 105: f(x)= 20.498980383130082
# differential_evolution step 106: f(x)= 20.498980383130082
# differential_evolution step 107: f(x)= 20.498980383130082
# differential_evolution step 108: f(x)= 20.498980383130082
# differential_evolution step 109: f(x)= 20.498980383130082
# differential_evolution step 110: f(x)= 20.498980383130082
# differential_evolution step 111: f(x)= 20.498980383130082
# differential_evolution step 112: f(x)= 20.498980383130082
# differential_evolution step 113: f(x)= 20.498980383130082
# differential_evolution step 114: f(x)= 20.498980383130082
# differential_evolution step 115: f(x)= 20.498980383130082
# differential_evolution step 116: f(x)= 20.498980383130082
# differential_evolution step 117: f(x)= 20.498980383130082
# differential_evolution step 118: f(x)= 20.498980383130082
# differential_evolution step 119: f(x)= 20.498980383130082
# differential_evolution step 120: f(x)= 20.498980383130082
# differential_evolution step 121: f(x)= 20.498980383130082
# differential_evolution step 122: f(x)= 20.498980383130082
# differential_evolution step 123: f(x)= 20.498980383130082
# differential_evolution step 124: f(x)= 20.498980383130082
# differential_evolution step 125: f(x)= 20.498980383130082
# differential_evolution step 126: f(x)= 20.498980383130082
# differential_evolution step 127: f(x)= 20.498980383130082
# differential_evolution step 128: f(x)= 18.948424756668274
# differential_evolution step 129: f(x)= 18.948424756668274
# differential_evolution step 130: f(x)= 18.948424756668274
# differential_evolution step 131: f(x)= 18.948424756668274
# differential_evolution step 132: f(x)= 18.495365509057592
# differential_evolution step 133: f(x)= 17.248719244038714
# differential_evolution step 134: f(x)= 17.248719244038714
# differential_evolution step 135: f(x)= 17.248719244038714
# differential_evolution step 136: f(x)= 17.248719244038714
# differential_evolution step 137: f(x)= 17.248719244038714
# differential_evolution step 138: f(x)= 17.248719244038714
# differential_evolution step 139: f(x)= 17.248719244038714
# differential_evolution step 140: f(x)= 17.248719244038714
# differential_evolution step 141: f(x)= 17.013645080673406
# differential_evolution step 142: f(x)= 17.013645080673406
# differential_evolution step 143: f(x)= 17.013645080673406
# differential_evolution step 144: f(x)= 17.013645080673406
# differential_evolution step 145: f(x)= 17.013645080673406
# differential_evolution step 146: f(x)= 17.013645080673406
# differential_evolution step 147: f(x)= 17.013645080673406
# differential_evolution step 148: f(x)= 17.013645080673406
# differential_evolution step 149: f(x)= 17.013645080673406
# differential_evolution step 150: f(x)= 14.152251935737588
# differential_evolution step 151: f(x)= 14.152251935737588
# differential_evolution step 152: f(x)= 14.152251935737588
# differential_evolution step 153: f(x)= 14.152251935737588
# differential_evolution step 154: f(x)= 14.152251935737588
# differential_evolution step 155: f(x)= 14.152251935737588
# differential_evolution step 156: f(x)= 14.152251935737588
# differential_evolution step 157: f(x)= 14.152251935737588
# differential_evolution step 158: f(x)= 14.152251935737588
# differential_evolution step 159: f(x)= 14.152251935737588
# differential_evolution step 160: f(x)= 14.152251935737588
# differential_evolution step 161: f(x)= 14.152251935737588
# differential_evolution step 162: f(x)= 14.152251935737588
# differential_evolution step 163: f(x)= 14.152251935737588
# differential_evolution step 164: f(x)= 14.152251935737588
# differential_evolution step 165: f(x)= 14.152251935737588
# differential_evolution step 166: f(x)= 14.152251935737588
# differential_evolution step 167: f(x)= 14.152251935737588
# differential_evolution step 168: f(x)= 14.152251935737588
# differential_evolution step 169: f(x)= 14.152251935737588
# differential_evolution step 170: f(x)= 14.152251935737588
# differential_evolution step 171: f(x)= 14.152251935737588
# differential_evolution step 172: f(x)= 14.152251935737588
# differential_evolution step 173: f(x)= 14.152251935737588
# differential_evolution step 174: f(x)= 14.152251935737588
# differential_evolution step 175: f(x)= 14.152251935737588
# differential_evolution step 176: f(x)= 14.152251935737588
# differential_evolution step 177: f(x)= 14.152251935737588
# differential_evolution step 178: f(x)= 14.152251935737588
# differential_evolution step 179: f(x)= 14.141230806447693
# differential_evolution step 180: f(x)= 14.141230806447693
# differential_evolution step 181: f(x)= 13.59326183270837
# differential_evolution step 182: f(x)= 9.772528454840424
# differential_evolution step 183: f(x)= 9.772528454840424
# differential_evolution step 184: f(x)= 9.772528454840424
# differential_evolution step 185: f(x)= 9.772528454840424
# differential_evolution step 186: f(x)= 9.772528454840424
# differential_evolution step 187: f(x)= 9.772528454840424
# differential_evolution step 188: f(x)= 9.473827144079033
# differential_evolution step 189: f(x)= 9.473827144079033
# differential_evolution step 190: f(x)= 9.473827144079033
# differential_evolution step 191: f(x)= 9.473827144079033
# differential_evolution step 192: f(x)= 9.473827144079033
# differential_evolution step 193: f(x)= 9.473827144079033
# differential_evolution step 194: f(x)= 9.473827144079033
# differential_evolution step 195: f(x)= 9.473827144079033
# differential_evolution step 196: f(x)= 9.473827144079033
# differential_evolution step 197: f(x)= 9.473827144079033
# differential_evolution step 198: f(x)= 9.473827144079033
# differential_evolution step 199: f(x)= 9.473827144079033
# differential_evolution step 200: f(x)= 9.07800894642189
# differential_evolution step 201: f(x)= 9.07800894642189
# differential_evolution step 202: f(x)= 9.07800894642189
# differential_evolution step 203: f(x)= 9.07800894642189
# differential_evolution step 204: f(x)= 9.07800894642189
# differential_evolution step 205: f(x)= 9.07800894642189
# differential_evolution step 206: f(x)= 9.07800894642189
# differential_evolution step 207: f(x)= 9.07800894642189
# differential_evolution step 208: f(x)= 9.07800894642189
# differential_evolution step 209: f(x)= 9.07800894642189
# differential_evolution step 210: f(x)= 9.07800894642189
# differential_evolution step 211: f(x)= 9.07800894642189
# differential_evolution step 212: f(x)= 9.07800894642189
# differential_evolution step 213: f(x)= 9.07800894642189
# differential_evolution step 214: f(x)= 7.723285422108408
# differential_evolution step 215: f(x)= 7.723285422108408
# differential_evolution step 216: f(x)= 7.723285422108408
# differential_evolution step 217: f(x)= 7.084780819290411
# differential_evolution step 218: f(x)= 7.084780819290411
# differential_evolution step 219: f(x)= 7.084780819290411
# differential_evolution step 220: f(x)= 7.084780819290411
# differential_evolution step 221: f(x)= 7.084780819290411
# differential_evolution step 222: f(x)= 7.084780819290411
# differential_evolution step 223: f(x)= 7.084780819290411
# differential_evolution step 224: f(x)= 7.084780819290411
# differential_evolution step 225: f(x)= 6.195411377494774
# differential_evolution step 226: f(x)= 6.195411377494774
# differential_evolution step 227: f(x)= 6.195411377494774
# differential_evolution step 228: f(x)= 6.195411377494774
# differential_evolution step 229: f(x)= 5.524404817177865
# differential_evolution step 230: f(x)= 5.107024950605815
# differential_evolution step 231: f(x)= 5.107024950605815
# differential_evolution step 232: f(x)= 5.107024950605815
# differential_evolution step 233: f(x)= 5.107024950605815
# differential_evolution step 234: f(x)= 5.107024950605815
# differential_evolution step 235: f(x)= 5.107024950605815
# differential_evolution step 236: f(x)= 5.107024950605815
# differential_evolution step 237: f(x)= 4.263944909836982
# differential_evolution step 238: f(x)= 4.263944909836982
# differential_evolution step 239: f(x)= 4.263944909836982
# differential_evolution step 240: f(x)= 4.263944909836982
# differential_evolution step 241: f(x)= 4.263944909836982
# differential_evolution step 242: f(x)= 4.263944909836982
# differential_evolution step 243: f(x)= 4.263944909836982
# differential_evolution step 244: f(x)= 4.263944909836982
# differential_evolution step 245: f(x)= 2.9407178325781307
# differential_evolution step 246: f(x)= 2.9407178325781307
# differential_evolution step 247: f(x)= 2.9407178325781307
# differential_evolution step 248: f(x)= 2.9407178325781307
# differential_evolution step 249: f(x)= 2.9407178325781307
# differential_evolution step 250: f(x)= 2.9407178325781307
# differential_evolution step 251: f(x)= 2.9407178325781307
# differential_evolution step 252: f(x)= 2.9407178325781307
# differential_evolution step 253: f(x)= 2.9407178325781307
# differential_evolution step 254: f(x)= 2.9407178325781307
# differential_evolution step 255: f(x)= 2.9407178325781307
# differential_evolution step 256: f(x)= 2.9407178325781307
# differential_evolution step 257: f(x)= 2.9407178325781307
# differential_evolution step 258: f(x)= 2.9407178325781307
# differential_evolution step 259: f(x)= 2.9407178325781307
# differential_evolution step 260: f(x)= 2.9407178325781307
# differential_evolution step 261: f(x)= 2.9407178325781307
# differential_evolution step 262: f(x)= 2.9407178325781307
# differential_evolution step 263: f(x)= 2.7838851533771316
# differential_evolution step 264: f(x)= 2.7838851533771316
# differential_evolution step 265: f(x)= 2.7838851533771316
# differential_evolution step 266: f(x)= 2.7838851533771316
# differential_evolution step 267: f(x)= 2.7838851533771316
# differential_evolution step 268: f(x)= 2.7838851533771316
# differential_evolution step 269: f(x)= 2.7838851533771316
# differential_evolution step 270: f(x)= 2.7838851533771316
# differential_evolution step 271: f(x)= 2.7838851533771316
# differential_evolution step 272: f(x)= 2.7838851533771316
# differential_evolution step 273: f(x)= 2.7838851533771316
# differential_evolution step 274: f(x)= 2.7838851533771316
# differential_evolution step 275: f(x)= 2.7838851533771316
# differential_evolution step 276: f(x)= 2.7838851533771316
# differential_evolution step 277: f(x)= 2.7838851533771316
# differential_evolution step 278: f(x)= 2.7335937192297664
# differential_evolution step 279: f(x)= 2.7335937192297664
# differential_evolution step 280: f(x)= 2.7335937192297664
# differential_evolution step 281: f(x)= 2.7335937192297664
# differential_evolution step 282: f(x)= 2.7335937192297664
# differential_evolution step 283: f(x)= 2.649100583682679
# differential_evolution step 284: f(x)= 2.649100583682679
# differential_evolution step 285: f(x)= 2.649100583682679
# differential_evolution step 286: f(x)= 2.649100583682679
# differential_evolution step 287: f(x)= 2.649100583682679
# differential_evolution step 288: f(x)= 2.6432569697976565
# differential_evolution step 289: f(x)= 2.6432569697976565
# differential_evolution step 290: f(x)= 2.6432569697976565
# differential_evolution step 291: f(x)= 2.1960705551611777
# differential_evolution step 292: f(x)= 2.0901303269860447
# differential_evolution step 293: f(x)= 2.0901303269860447
# differential_evolution step 294: f(x)= 2.0901303269860447
# differential_evolution step 295: f(x)= 2.0901303269860447
# differential_evolution step 296: f(x)= 2.0901303269860447
# differential_evolution step 297: f(x)= 2.0901303269860447
# differential_evolution step 298: f(x)= 2.0901303269860447
# differential_evolution step 299: f(x)= 1.9540403332812948
# differential_evolution step 300: f(x)= 1.9296500600593447
# differential_evolution step 301: f(x)= 1.9296500600593447
# differential_evolution step 302: f(x)= 1.9296500600593447
# differential_evolution step 303: f(x)= 1.9296500600593447
# differential_evolution step 304: f(x)= 1.9296500600593447
# differential_evolution step 305: f(x)= 1.9296500600593447
# differential_evolution step 306: f(x)= 1.9296500600593447
# differential_evolution step 307: f(x)= 1.9296500600593447
# differential_evolution step 308: f(x)= 1.9296500600593447
# differential_evolution step 309: f(x)= 1.9296500600593447
# differential_evolution step 310: f(x)= 1.9296500600593447
# differential_evolution step 311: f(x)= 1.9296500600593447
# differential_evolution step 312: f(x)= 1.9296500600593447
# differential_evolution step 313: f(x)= 1.8841021365413781
# differential_evolution step 314: f(x)= 1.8841021365413781
# differential_evolution step 315: f(x)= 1.6514657542170508
# differential_evolution step 316: f(x)= 1.6514657542170508
# differential_evolution step 317: f(x)= 1.6514657542170508
# differential_evolution step 318: f(x)= 1.6514657542170508
# differential_evolution step 319: f(x)= 1.6514657542170508
# differential_evolution step 320: f(x)= 1.6514657542170508
# differential_evolution step 321: f(x)= 1.6514657542170508
# differential_evolution step 322: f(x)= 1.6514657542170508
# differential_evolution step 323: f(x)= 1.6514657542170508
# differential_evolution step 324: f(x)= 1.6514657542170508
# differential_evolution step 325: f(x)= 1.5205654915006503
# differential_evolution step 326: f(x)= 1.5205654915006503
# differential_evolution step 327: f(x)= 1.5205654915006503
# differential_evolution step 328: f(x)= 1.5205654915006503
# differential_evolution step 329: f(x)= 1.5205654915006503
# differential_evolution step 330: f(x)= 1.5205654915006503
# differential_evolution step 331: f(x)= 1.5205654915006503
# differential_evolution step 332: f(x)= 1.5149980459590429
# differential_evolution step 333: f(x)= 1.5149980459590429
# differential_evolution step 334: f(x)= 1.4473311019464203
# differential_evolution step 335: f(x)= 1.4473311019464203
# differential_evolution step 336: f(x)= 1.4473311019464203
# differential_evolution step 337: f(x)= 1.4473311019464203
# differential_evolution step 338: f(x)= 1.4473311019464203
# differential_evolution step 339: f(x)= 1.4473311019464203
# differential_evolution step 340: f(x)= 1.4473311019464203
# differential_evolution step 341: f(x)= 1.4046453458450203
# differential_evolution step 342: f(x)= 1.4046453458450203
# differential_evolution step 343: f(x)= 1.4046453458450203
# differential_evolution step 344: f(x)= 1.4046453458450203
# differential_evolution step 345: f(x)= 1.4046453458450203
# differential_evolution step 346: f(x)= 1.4046453458450203
# differential_evolution step 347: f(x)= 1.4046453458450203
# differential_evolution step 348: f(x)= 1.4046453458450203
# differential_evolution step 349: f(x)= 1.4046453458450203
# differential_evolution step 350: f(x)= 1.4046453458450203
# differential_evolution step 351: f(x)= 1.4046453458450203
# differential_evolution step 352: f(x)= 1.4046453458450203
# differential_evolution step 353: f(x)= 1.395726786438863
# differential_evolution step 354: f(x)= 1.395726786438863
# differential_evolution step 355: f(x)= 1.395726786438863
# differential_evolution step 356: f(x)= 1.395726786438863
# differential_evolution step 357: f(x)= 1.395726786438863
# differential_evolution step 358: f(x)= 1.395726786438863
# differential_evolution step 359: f(x)= 1.395726786438863
# differential_evolution step 360: f(x)= 1.395726786438863
# differential_evolution step 361: f(x)= 1.395726786438863
# differential_evolution step 362: f(x)= 1.395726786438863
# differential_evolution step 363: f(x)= 1.395726786438863
# differential_evolution step 364: f(x)= 1.395726786438863
# differential_evolution step 365: f(x)= 1.395726786438863
# differential_evolution step 366: f(x)= 1.395726786438863
# differential_evolution step 367: f(x)= 1.395726786438863
# differential_evolution step 368: f(x)= 1.395726786438863
# differential_evolution step 369: f(x)= 1.3659065371425536
# differential_evolution step 370: f(x)= 1.3659065371425536
# differential_evolution step 371: f(x)= 1.3659065371425536
# differential_evolution step 372: f(x)= 1.3659065371425536
# differential_evolution step 373: f(x)= 1.3659065371425536
# differential_evolution step 374: f(x)= 1.3659065371425536
# differential_evolution step 375: f(x)= 1.3659065371425536
# differential_evolution step 376: f(x)= 1.3659065371425536
# differential_evolution step 377: f(x)= 1.3659065371425536
# differential_evolution step 378: f(x)= 1.3659065371425536
# differential_evolution step 379: f(x)= 1.3659065371425536
# differential_evolution step 380: f(x)= 1.3659065371425536
# differential_evolution step 381: f(x)= 1.3659065371425536
# differential_evolution step 382: f(x)= 1.3659065371425536
# differential_evolution step 383: f(x)= 1.3659065371425536
# differential_evolution step 384: f(x)= 1.3659065371425536
# differential_evolution step 385: f(x)= 1.3659065371425536
# differential_evolution step 386: f(x)= 1.3659065371425536
# differential_evolution step 387: f(x)= 1.3659065371425536
# differential_evolution step 388: f(x)= 1.3659065371425536
# differential_evolution step 389: f(x)= 1.3659065371425536
# differential_evolution step 390: f(x)= 1.3659065371425536
# differential_evolution step 391: f(x)= 1.3659065371425536
# differential_evolution step 392: f(x)= 1.3659065371425536
# differential_evolution step 393: f(x)= 1.3659065371425536
# differential_evolution step 394: f(x)= 1.3659065371425536
# differential_evolution step 395: f(x)= 1.3659065371425536
# differential_evolution step 396: f(x)= 1.3659065371425536
# differential_evolution step 397: f(x)= 1.3659065371425536
# differential_evolution step 398: f(x)= 1.3659065371425536
# differential_evolution step 399: f(x)= 1.3659065371425536
# differential_evolution step 400: f(x)= 1.3659065371425536
# differential_evolution step 401: f(x)= 1.3438772765510363
# differential_evolution step 402: f(x)= 1.1434273165984616
# differential_evolution step 403: f(x)= 1.1434273165984616
# differential_evolution step 404: f(x)= 1.1434273165984616
# differential_evolution step 405: f(x)= 1.1434273165984616
# differential_evolution step 406: f(x)= 1.1434273165984616
# differential_evolution step 407: f(x)= 1.1434273165984616
# differential_evolution step 408: f(x)= 1.1434273165984616
# differential_evolution step 409: f(x)= 1.1434273165984616
# differential_evolution step 410: f(x)= 1.1315949375975314
# differential_evolution step 411: f(x)= 1.1315949375975314
# differential_evolution step 412: f(x)= 1.1315949375975314
# differential_evolution step 413: f(x)= 1.1315949375975314
# differential_evolution step 414: f(x)= 1.1315949375975314
# differential_evolution step 415: f(x)= 1.1315949375975314
# differential_evolution step 416: f(x)= 1.1315949375975314
# differential_evolution step 417: f(x)= 1.1315949375975314
# differential_evolution step 418: f(x)= 1.1315949375975314
# differential_evolution step 419: f(x)= 1.1315949375975314
# differential_evolution step 420: f(x)= 1.1315949375975314
# differential_evolution step 421: f(x)= 1.1315949375975314
# differential_evolution step 422: f(x)= 1.1315949375975314
# differential_evolution step 423: f(x)= 1.1315949375975314
# differential_evolution step 424: f(x)= 1.1315949375975314
# differential_evolution step 425: f(x)= 1.1315949375975314
# differential_evolution step 426: f(x)= 1.1315949375975314
# differential_evolution step 427: f(x)= 1.1315949375975314
# differential_evolution step 428: f(x)= 1.1315949375975314
# differential_evolution step 429: f(x)= 1.1315949375975314
# differential_evolution step 430: f(x)= 1.1315949375975314
# differential_evolution step 431: f(x)= 1.1315949375975314
# differential_evolution step 432: f(x)= 1.1315949375975314
# differential_evolution step 433: f(x)= 1.1315949375975314
# differential_evolution step 434: f(x)= 1.1315949375975314
# differential_evolution step 435: f(x)= 1.1315949375975314
# differential_evolution step 436: f(x)= 1.1315949375975314
# differential_evolution step 437: f(x)= 1.1315949375975314
# differential_evolution step 438: f(x)= 1.1315949375975314
# differential_evolution step 439: f(x)= 1.1315949375975314
# differential_evolution step 440: f(x)= 1.1315949375975314
# differential_evolution step 441: f(x)= 1.044232685365429
# differential_evolution step 442: f(x)= 1.044232685365429
# differential_evolution step 443: f(x)= 1.044232685365429
# differential_evolution step 444: f(x)= 1.044232685365429
# differential_evolution step 445: f(x)= 1.044232685365429
# differential_evolution step 446: f(x)= 1.044232685365429
# differential_evolution step 447: f(x)= 1.044232685365429
# differential_evolution step 448: f(x)= 1.044232685365429
# differential_evolution step 449: f(x)= 1.044232685365429
# differential_evolution step 450: f(x)= 1.044232685365429
# differential_evolution step 451: f(x)= 1.044232685365429
# differential_evolution step 452: f(x)= 1.044232685365429
# differential_evolution step 453: f(x)= 1.044232685365429
# differential_evolution step 454: f(x)= 1.044232685365429
# differential_evolution step 455: f(x)= 1.044232685365429
# differential_evolution step 456: f(x)= 1.044232685365429
# differential_evolution step 457: f(x)= 1.044232685365429
# differential_evolution step 458: f(x)= 1.044232685365429
# differential_evolution step 459: f(x)= 1.0262514660509139
# differential_evolution step 460: f(x)= 1.0262514660509139
# differential_evolution step 461: f(x)= 1.0262514660509139
# differential_evolution step 462: f(x)= 1.0262514660509139
# differential_evolution step 463: f(x)= 1.0262514660509139
# differential_evolution step 464: f(x)= 1.0262514660509139
# differential_evolution step 465: f(x)= 1.0262514660509139
# differential_evolution step 466: f(x)= 1.0170000630525546
# differential_evolution step 467: f(x)= 1.0170000630525546
# differential_evolution step 468: f(x)= 1.0170000630525546
# differential_evolution step 469: f(x)= 1.0170000630525546
# differential_evolution step 470: f(x)= 1.0170000630525546
# differential_evolution step 471: f(x)= 1.0170000630525546
# differential_evolution step 472: f(x)= 1.0170000630525546
# differential_evolution step 473: f(x)= 1.0170000630525546
# differential_evolution step 474: f(x)= 1.0170000630525546
# differential_evolution step 475: f(x)= 1.0170000630525546
# differential_evolution step 476: f(x)= 1.0170000630525546
# differential_evolution step 477: f(x)= 1.0170000630525546
# differential_evolution step 478: f(x)= 0.9990601818787125
# differential_evolution step 479: f(x)= 0.9652316535783827
# differential_evolution step 480: f(x)= 0.9652316535783827
# differential_evolution step 481: f(x)= 0.9652316535783827
# differential_evolution step 482: f(x)= 0.9652316535783827
# differential_evolution step 483: f(x)= 0.9497924937854014
# differential_evolution step 484: f(x)= 0.9497924937854014
# differential_evolution step 485: f(x)= 0.9497924937854014
# differential_evolution step 486: f(x)= 0.9480372504568029
# differential_evolution step 487: f(x)= 0.9480372504568029
# differential_evolution step 488: f(x)= 0.9480372504568029
# differential_evolution step 489: f(x)= 0.9480372504568029
# differential_evolution step 490: f(x)= 0.9480372504568029
# differential_evolution step 491: f(x)= 0.8861972112677242
# differential_evolution step 492: f(x)= 0.8861972112677242
# differential_evolution step 493: f(x)= 0.8861972112677242
# differential_evolution step 494: f(x)= 0.8861972112677242
# differential_evolution step 495: f(x)= 0.8861972112677242
# differential_evolution step 496: f(x)= 0.8861972112677242
# differential_evolution step 497: f(x)= 0.8861972112677242
# differential_evolution step 498: f(x)= 0.8861972112677242
# differential_evolution step 499: f(x)= 0.8861972112677242
# differential_evolution step 500: f(x)= 0.8861972112677242
# differential_evolution step 501: f(x)= 0.8861972112677242
# differential_evolution step 502: f(x)= 0.8861972112677242
# differential_evolution step 503: f(x)= 0.8861972112677242
# differential_evolution step 504: f(x)= 0.8861972112677242
# differential_evolution step 505: f(x)= 0.8861972112677242
# differential_evolution step 506: f(x)= 0.8861972112677242
# differential_evolution step 507: f(x)= 0.8861972112677242
# differential_evolution step 508: f(x)= 0.8861972112677242
# differential_evolution step 509: f(x)= 0.8861972112677242
# differential_evolution step 510: f(x)= 0.8861972112677242
# differential_evolution step 511: f(x)= 0.8861972112677242
# differential_evolution step 512: f(x)= 0.8861972112677242
# differential_evolution step 513: f(x)= 0.8861972112677242
# differential_evolution step 514: f(x)= 0.8861972112677242
# differential_evolution step 515: f(x)= 0.8861972112677242
# differential_evolution step 516: f(x)= 0.8861972112677242
# differential_evolution step 517: f(x)= 0.8861972112677242
# differential_evolution step 518: f(x)= 0.8861972112677242
# differential_evolution step 519: f(x)= 0.8861972112677242
# differential_evolution step 520: f(x)= 0.8861972112677242
# differential_evolution step 521: f(x)= 0.8861972112677242
# differential_evolution step 522: f(x)= 0.8861972112677242
# differential_evolution step 523: f(x)= 0.8861972112677242
# differential_evolution step 524: f(x)= 0.8861972112677242
# differential_evolution step 525: f(x)= 0.8861972112677242
# differential_evolution step 526: f(x)= 0.8861972112677242
# differential_evolution step 527: f(x)= 0.8861972112677242
# differential_evolution step 528: f(x)= 0.8861972112677242
# differential_evolution step 529: f(x)= 0.8861972112677242
# differential_evolution step 530: f(x)= 0.8861972112677242
# differential_evolution step 531: f(x)= 0.8861972112677242
# differential_evolution step 532: f(x)= 0.8861972112677242
# differential_evolution step 533: f(x)= 0.8861972112677242
# differential_evolution step 534: f(x)= 0.8861972112677242
# differential_evolution step 535: f(x)= 0.8861972112677242
# differential_evolution step 536: f(x)= 0.8861972112677242
# differential_evolution step 537: f(x)= 0.8861972112677242
# differential_evolution step 538: f(x)= 0.8861972112677242
# differential_evolution step 539: f(x)= 0.8861972112677242
# differential_evolution step 540: f(x)= 0.8861972112677242
# differential_evolution step 541: f(x)= 0.8861972112677242
# differential_evolution step 542: f(x)= 0.8861972112677242
# differential_evolution step 543: f(x)= 0.8861972112677242
# differential_evolution step 544: f(x)= 0.8861972112677242
# differential_evolution step 545: f(x)= 0.8861972112677242
# differential_evolution step 546: f(x)= 0.8861972112677242
# differential_evolution step 547: f(x)= 0.8861972112677242
# differential_evolution step 548: f(x)= 0.8861972112677242
# differential_evolution step 549: f(x)= 0.8861972112677242
# differential_evolution step 550: f(x)= 0.8861972112677242
# differential_evolution step 551: f(x)= 0.8861972112677242
# differential_evolution step 552: f(x)= 0.8861972112677242
# differential_evolution step 553: f(x)= 0.8861972112677242
# differential_evolution step 554: f(x)= 0.8861972112677242
# differential_evolution step 555: f(x)= 0.8861972112677242
# differential_evolution step 556: f(x)= 0.8861972112677242
# differential_evolution step 557: f(x)= 0.8861972112677242
# differential_evolution step 558: f(x)= 0.8861972112677242
# differential_evolution step 559: f(x)= 0.8861972112677242
# differential_evolution step 560: f(x)= 0.8861972112677242
# differential_evolution step 561: f(x)= 0.8861972112677242
# differential_evolution step 562: f(x)= 0.8861972112677242
# differential_evolution step 563: f(x)= 0.8861972112677242
# differential_evolution step 564: f(x)= 0.8861972112677242
# differential_evolution step 565: f(x)= 0.8861972112677242
# differential_evolution step 566: f(x)= 0.8861972112677242
# differential_evolution step 567: f(x)= 0.8861972112677242
# differential_evolution step 568: f(x)= 0.8861972112677242
# differential_evolution step 569: f(x)= 0.8861972112677242
# differential_evolution step 570: f(x)= 0.8861972112677242
# differential_evolution step 571: f(x)= 0.8861972112677242
# differential_evolution step 572: f(x)= 0.8861972112677242
# differential_evolution step 573: f(x)= 0.8861972112677242
# differential_evolution step 574: f(x)= 0.8861972112677242
# differential_evolution step 575: f(x)= 0.8861972112677242
# differential_evolution step 576: f(x)= 0.8861972112677242
# differential_evolution step 577: f(x)= 0.8861972112677242
# differential_evolution step 578: f(x)= 0.885671561444107
# differential_evolution step 579: f(x)= 0.885671561444107
# differential_evolution step 580: f(x)= 0.885671561444107
# differential_evolution step 581: f(x)= 0.885671561444107
# differential_evolution step 582: f(x)= 0.885671561444107
# differential_evolution step 583: f(x)= 0.885671561444107
# differential_evolution step 584: f(x)= 0.885671561444107
# differential_evolution step 585: f(x)= 0.885671561444107
# differential_evolution step 586: f(x)= 0.885671561444107
# differential_evolution step 587: f(x)= 0.8809414905076363
# differential_evolution step 588: f(x)= 0.8809414905076363
# differential_evolution step 589: f(x)= 0.8809414905076363
# differential_evolution step 590: f(x)= 0.8809414905076363
# differential_evolution step 591: f(x)= 0.8809414905076363
# differential_evolution step 592: f(x)= 0.8809414905076363
# differential_evolution step 593: f(x)= 0.8809414905076363
# differential_evolution step 594: f(x)= 0.8809414905076363
# differential_evolution step 595: f(x)= 0.8809414905076363
# differential_evolution step 596: f(x)= 0.8809414905076363
# differential_evolution step 597: f(x)= 0.8809414905076363
# differential_evolution step 598: f(x)= 0.8809414905076363
# differential_evolution step 599: f(x)= 0.8809414905076363
# differential_evolution step 600: f(x)= 0.8809414905076363
# differential_evolution step 601: f(x)= 0.8809414905076363
# differential_evolution step 602: f(x)= 0.8809414905076363
# differential_evolution step 603: f(x)= 0.8809376570946218
# differential_evolution step 604: f(x)= 0.8809376570946218
# differential_evolution step 605: f(x)= 0.8809376570946218
# differential_evolution step 606: f(x)= 0.8809376570946218
# differential_evolution step 607: f(x)= 0.8644503156465421
# differential_evolution step 608: f(x)= 0.8496200528360647
# differential_evolution step 609: f(x)= 0.8496200528360647
# differential_evolution step 610: f(x)= 0.8496200528360647
# differential_evolution step 611: f(x)= 0.8496200528360647
# differential_evolution step 612: f(x)= 0.8496200528360647
# differential_evolution step 613: f(x)= 0.8496200528360647
# differential_evolution step 614: f(x)= 0.8496200528360647
# differential_evolution step 615: f(x)= 0.8496200528360647
# differential_evolution step 616: f(x)= 0.8496200528360647
# differential_evolution step 617: f(x)= 0.8496200528360647
# differential_evolution step 618: f(x)= 0.8496200528360647
# differential_evolution step 619: f(x)= 0.8496200528360647
# differential_evolution step 620: f(x)= 0.8496200528360647
# differential_evolution step 621: f(x)= 0.8496200528360647
# differential_evolution step 622: f(x)= 0.8431537775870296
# differential_evolution step 623: f(x)= 0.8431537775870296
# differential_evolution step 624: f(x)= 0.8431537775870296
# differential_evolution step 625: f(x)= 0.8431537775870296
# differential_evolution step 626: f(x)= 0.8431537775870296
# differential_evolution step 627: f(x)= 0.8431537775870296
# differential_evolution step 628: f(x)= 0.8431537775870296
# differential_evolution step 629: f(x)= 0.8431537775870296
# differential_evolution step 630: f(x)= 0.8431537775870296
# differential_evolution step 631: f(x)= 0.8299658509187259
# differential_evolution step 632: f(x)= 0.8255463313682957
# differential_evolution step 633: f(x)= 0.8255463313682957
# differential_evolution step 634: f(x)= 0.8255463313682957
# differential_evolution step 635: f(x)= 0.8255463313682957
# differential_evolution step 636: f(x)= 0.8255463313682957
# differential_evolution step 637: f(x)= 0.8255463313682957
# differential_evolution step 638: f(x)= 0.8244113675901884
# differential_evolution step 639: f(x)= 0.8244113675901884
# differential_evolution step 640: f(x)= 0.8244113675901884
# differential_evolution step 641: f(x)= 0.8244113675901884
# differential_evolution step 642: f(x)= 0.8244113675901884
# differential_evolution step 643: f(x)= 0.8244113675901884
# differential_evolution step 644: f(x)= 0.8244113675901884
# differential_evolution step 645: f(x)= 0.8244113675901884
# differential_evolution step 646: f(x)= 0.8244113675901884
# differential_evolution step 647: f(x)= 0.8244113675901884
# differential_evolution step 648: f(x)= 0.8244113675901884
# differential_evolution step 649: f(x)= 0.8244113675901884
# differential_evolution step 650: f(x)= 0.8244113675901884
# differential_evolution step 651: f(x)= 0.8244113675901884
# differential_evolution step 652: f(x)= 0.8244113675901884
# differential_evolution step 653: f(x)= 0.8244113675901884
# differential_evolution step 654: f(x)= 0.8244113675901884
# differential_evolution step 655: f(x)= 0.8244113675901884
# differential_evolution step 656: f(x)= 0.8244113675901884
# differential_evolution step 657: f(x)= 0.8244113675901884
# differential_evolution step 658: f(x)= 0.8244113675901884
# differential_evolution step 659: f(x)= 0.8244113675901884
# differential_evolution step 660: f(x)= 0.8244113675901884
# differential_evolution step 661: f(x)= 0.8244113675901884
# differential_evolution step 662: f(x)= 0.8244113675901884
# differential_evolution step 663: f(x)= 0.8244113675901884
# differential_evolution step 664: f(x)= 0.8244113675901884
# differential_evolution step 665: f(x)= 0.8244113675901884
# differential_evolution step 666: f(x)= 0.8244113675901884
# differential_evolution step 667: f(x)= 0.8244113675901884
# differential_evolution step 668: f(x)= 0.8244113675901884
# differential_evolution step 669: f(x)= 0.8244113675901884
# differential_evolution step 670: f(x)= 0.7948470499686779
# differential_evolution step 671: f(x)= 0.7948470499686779
# differential_evolution step 672: f(x)= 0.7948470499686779
# differential_evolution step 673: f(x)= 0.7948470499686779
# differential_evolution step 674: f(x)= 0.7948470499686779
# differential_evolution step 675: f(x)= 0.7948470499686779
# differential_evolution step 676: f(x)= 0.7948470499686779
# differential_evolution step 677: f(x)= 0.7710066915673263
# differential_evolution step 678: f(x)= 0.7710066915673263
# differential_evolution step 679: f(x)= 0.7710066915673263
# differential_evolution step 680: f(x)= 0.7710066915673263
# differential_evolution step 681: f(x)= 0.7710066915673263
# differential_evolution step 682: f(x)= 0.7710066915673263
# differential_evolution step 683: f(x)= 0.7710066915673263
# differential_evolution step 684: f(x)= 0.7710066915673263
# differential_evolution step 685: f(x)= 0.7710066915673263
# differential_evolution step 686: f(x)= 0.7710066915673263
# differential_evolution step 687: f(x)= 0.7710066915673263
# differential_evolution step 688: f(x)= 0.7710066915673263
# differential_evolution step 689: f(x)= 0.7710066915673263
# differential_evolution step 690: f(x)= 0.7710066915673263
# differential_evolution step 691: f(x)= 0.7710066915673263
# differential_evolution step 692: f(x)= 0.7710066915673263
# differential_evolution step 693: f(x)= 0.7710066915673263
# differential_evolution step 694: f(x)= 0.7710066915673263
# differential_evolution step 695: f(x)= 0.7710066915673263
# differential_evolution step 696: f(x)= 0.7710066915673263
# differential_evolution step 697: f(x)= 0.7710066915673263
# differential_evolution step 698: f(x)= 0.7710066915673263
# differential_evolution step 699: f(x)= 0.7710066915673263
# differential_evolution step 700: f(x)= 0.7710066915673263
# differential_evolution step 701: f(x)= 0.7710066915673263
# differential_evolution step 702: f(x)= 0.7710066915673263
# differential_evolution step 703: f(x)= 0.7710066915673263
# differential_evolution step 704: f(x)= 0.7710066915673263
# differential_evolution step 705: f(x)= 0.7710066915673263
# differential_evolution step 706: f(x)= 0.7710066915673263
# differential_evolution step 707: f(x)= 0.7710066915673263
# differential_evolution step 708: f(x)= 0.7710066915673263
# differential_evolution step 709: f(x)= 0.7710066915673263
# differential_evolution step 710: f(x)= 0.7710066915673263
# differential_evolution step 711: f(x)= 0.7710066915673263
# differential_evolution step 712: f(x)= 0.7710066915673263
# differential_evolution step 713: f(x)= 0.7710066915673263
# differential_evolution step 714: f(x)= 0.7710066915673263
# differential_evolution step 715: f(x)= 0.7710066915673263
# differential_evolution step 716: f(x)= 0.7710066915673263
# differential_evolution step 717: f(x)= 0.7710066915673263
# differential_evolution step 718: f(x)= 0.7710066915673263
# differential_evolution step 719: f(x)= 0.7710066915673263
# differential_evolution step 720: f(x)= 0.7710066915673263
# differential_evolution step 721: f(x)= 0.7710066915673263
# differential_evolution step 722: f(x)= 0.7710066915673263
# differential_evolution step 723: f(x)= 0.7710066915673263
# differential_evolution step 724: f(x)= 0.7710066915673263
# differential_evolution step 725: f(x)= 0.7710066915673263
# differential_evolution step 726: f(x)= 0.7710066915673263
# differential_evolution step 727: f(x)= 0.7710066915673263
# differential_evolution step 728: f(x)= 0.7710066915673263
# differential_evolution step 729: f(x)= 0.7710066915673263
# differential_evolution step 730: f(x)= 0.7710066915673263
# differential_evolution step 731: f(x)= 0.7710066915673263
# differential_evolution step 732: f(x)= 0.7710066915673263
# differential_evolution step 733: f(x)= 0.7710066915673263
# differential_evolution step 734: f(x)= 0.7710066915673263
# differential_evolution step 735: f(x)= 0.7710066915673263
# differential_evolution step 736: f(x)= 0.7710066915673263
# differential_evolution step 737: f(x)= 0.7710066915673263
# differential_evolution step 738: f(x)= 0.7710066915673263
# differential_evolution step 739: f(x)= 0.7710066915673263
# differential_evolution step 740: f(x)= 0.7700053839167955
# differential_evolution step 741: f(x)= 0.7700053839167955
# differential_evolution step 742: f(x)= 0.7700053839167955
# differential_evolution step 743: f(x)= 0.7700053839167955
# differential_evolution step 744: f(x)= 0.7700053839167955
# differential_evolution step 745: f(x)= 0.7700053839167955
# differential_evolution step 746: f(x)= 0.7700053839167955
# differential_evolution step 747: f(x)= 0.7700053839167955
# differential_evolution step 748: f(x)= 0.7700053839167955
# differential_evolution step 749: f(x)= 0.7700053839167955
# differential_evolution step 750: f(x)= 0.7700053839167955
# differential_evolution step 751: f(x)= 0.7700053839167955
# differential_evolution step 752: f(x)= 0.7700053839167955
# differential_evolution step 753: f(x)= 0.7700053839167955
# differential_evolution step 754: f(x)= 0.7700053839167955
# differential_evolution step 755: f(x)= 0.7700053839167955
# differential_evolution step 756: f(x)= 0.7700053839167955
# differential_evolution step 757: f(x)= 0.7700053839167955
# differential_evolution step 758: f(x)= 0.7700053839167955
# differential_evolution step 759: f(x)= 0.7700053839167955
# differential_evolution step 760: f(x)= 0.7700053839167955
# differential_evolution step 761: f(x)= 0.7700053839167955
# differential_evolution step 762: f(x)= 0.7700053839167955
# differential_evolution step 763: f(x)= 0.7700053839167955
# differential_evolution step 764: f(x)= 0.7700053839167955
# differential_evolution step 765: f(x)= 0.7700053839167955
# differential_evolution step 766: f(x)= 0.7700053839167955
# differential_evolution step 767: f(x)= 0.7700053839167955
# differential_evolution step 768: f(x)= 0.7700053839167955
# differential_evolution step 769: f(x)= 0.7700053839167955
# differential_evolution step 770: f(x)= 0.7687880366176938
# differential_evolution step 771: f(x)= 0.7687880366176938
# differential_evolution step 772: f(x)= 0.7687880366176938
# differential_evolution step 773: f(x)= 0.7687880366176938
# differential_evolution step 774: f(x)= 0.7687880366176938
# differential_evolution step 775: f(x)= 0.7687880366176938
# differential_evolution step 776: f(x)= 0.7687880366176938
# differential_evolution step 777: f(x)= 0.7687880366176938
# differential_evolution step 778: f(x)= 0.7687880366176938
# differential_evolution step 779: f(x)= 0.7687880366176938
# differential_evolution step 780: f(x)= 0.7687880366176938
# differential_evolution step 781: f(x)= 0.7687880366176938
# differential_evolution step 782: f(x)= 0.7687880366176938
# differential_evolution step 783: f(x)= 0.7687880366176938
# differential_evolution step 784: f(x)= 0.7687880366176938
# differential_evolution step 785: f(x)= 0.7687880366176938
# differential_evolution step 786: f(x)= 0.7687880366176938
# differential_evolution step 787: f(x)= 0.7687880366176938
# differential_evolution step 788: f(x)= 0.7687880366176938
# differential_evolution step 789: f(x)= 0.7687880366176938
# differential_evolution step 790: f(x)= 0.7687880366176938
# differential_evolution step 791: f(x)= 0.7687880366176938
# differential_evolution step 792: f(x)= 0.7687880366176938
# differential_evolution step 793: f(x)= 0.7687880366176938
# differential_evolution step 794: f(x)= 0.7687880366176938
# differential_evolution step 795: f(x)= 0.7687880366176938
# differential_evolution step 796: f(x)= 0.7687880366176938
# differential_evolution step 797: f(x)= 0.7687880366176938
# differential_evolution step 798: f(x)= 0.7687880366176938
# differential_evolution step 799: f(x)= 0.7687880366176938
# differential_evolution step 800: f(x)= 0.7687880366176938
# differential_evolution step 801: f(x)= 0.7687880366176938
# differential_evolution step 802: f(x)= 0.7687880366176938
# differential_evolution step 803: f(x)= 0.7687880366176938
# differential_evolution step 804: f(x)= 0.7687880366176938
# differential_evolution step 805: f(x)= 0.7687880366176938
# differential_evolution step 806: f(x)= 0.7687880366176938
# differential_evolution step 807: f(x)= 0.7687880366176938
# differential_evolution step 808: f(x)= 0.7687880366176938
# differential_evolution step 809: f(x)= 0.7687880366176938
# differential_evolution step 810: f(x)= 0.7687880366176938
# differential_evolution step 811: f(x)= 0.7687880366176938
# differential_evolution step 812: f(x)= 0.7687880366176938
# differential_evolution step 813: f(x)= 0.7687880366176938
# differential_evolution step 814: f(x)= 0.7687880366176938
# differential_evolution step 815: f(x)= 0.7687880366176938
# differential_evolution step 816: f(x)= 0.7687880366176938
# differential_evolution step 817: f(x)= 0.7687880366176938
# differential_evolution step 818: f(x)= 0.7687880366176938
# differential_evolution step 819: f(x)= 0.7687880366176938
# differential_evolution step 820: f(x)= 0.7687880366176938
# differential_evolution step 821: f(x)= 0.7687880366176938
# differential_evolution step 822: f(x)= 0.7687880366176938
# differential_evolution step 823: f(x)= 0.7687880366176938
# differential_evolution step 824: f(x)= 0.7687880366176938
# differential_evolution step 825: f(x)= 0.7687880366176938
# differential_evolution step 826: f(x)= 0.7687880366176938
# differential_evolution step 827: f(x)= 0.7635760826671194
# differential_evolution step 828: f(x)= 0.7635760826671194
# differential_evolution step 829: f(x)= 0.7635760826671194
# differential_evolution step 830: f(x)= 0.7635760826671194
# differential_evolution step 831: f(x)= 0.7635760826671194
# differential_evolution step 832: f(x)= 0.7635760826671194
# differential_evolution step 833: f(x)= 0.7635760826671194
# differential_evolution step 834: f(x)= 0.7635760826671194
# differential_evolution step 835: f(x)= 0.7635760826671194
# differential_evolution step 836: f(x)= 0.7635760826671194
# differential_evolution step 837: f(x)= 0.7398207533790055
# differential_evolution step 838: f(x)= 0.7398207533790055
# differential_evolution step 839: f(x)= 0.7398207533790055
# differential_evolution step 840: f(x)= 0.7398207533790055
# differential_evolution step 841: f(x)= 0.7398207533790055
# differential_evolution step 842: f(x)= 0.7398207533790055
# differential_evolution step 843: f(x)= 0.7398207533790055
# differential_evolution step 844: f(x)= 0.7398207533790055
# differential_evolution step 845: f(x)= 0.7398207533790055
# differential_evolution step 846: f(x)= 0.7398207533790055
# differential_evolution step 847: f(x)= 0.7398207533790055
# differential_evolution step 848: f(x)= 0.7398207533790055
# differential_evolution step 849: f(x)= 0.7398207533790055
# differential_evolution step 850: f(x)= 0.7398207533790055
# differential_evolution step 851: f(x)= 0.7398207533790055
# differential_evolution step 852: f(x)= 0.7398207533790055
# differential_evolution step 853: f(x)= 0.7398207533790055
# differential_evolution step 854: f(x)= 0.7398207533790055
# differential_evolution step 855: f(x)= 0.7398207533790055
# differential_evolution step 856: f(x)= 0.7398207533790055
# differential_evolution step 857: f(x)= 0.7398207533790055
# differential_evolution step 858: f(x)= 0.7398207533790055
# differential_evolution step 859: f(x)= 0.7398207533790055
# differential_evolution step 860: f(x)= 0.7398207533790055
# differential_evolution step 861: f(x)= 0.7398207533790055
# differential_evolution step 862: f(x)= 0.7398207533790055
# differential_evolution step 863: f(x)= 0.7398207533790055
# differential_evolution step 864: f(x)= 0.7398207533790055
# differential_evolution step 865: f(x)= 0.7398207533790055
# differential_evolution step 866: f(x)= 0.7398207533790055
# differential_evolution step 867: f(x)= 0.7398207533790055
# differential_evolution step 868: f(x)= 0.7398207533790055
# differential_evolution step 869: f(x)= 0.7398207533790055
# differential_evolution step 870: f(x)= 0.7398207533790055
# differential_evolution step 871: f(x)= 0.7398207533790055
# differential_evolution step 872: f(x)= 0.7398207533790055
# differential_evolution step 873: f(x)= 0.7398207533790055
# differential_evolution step 874: f(x)= 0.7398207533790055
# differential_evolution step 875: f(x)= 0.7398207533790055
# differential_evolution step 876: f(x)= 0.7398207533790055
# differential_evolution step 877: f(x)= 0.7398207533790055
# differential_evolution step 878: f(x)= 0.7398207533790055
# differential_evolution step 879: f(x)= 0.7398207533790055
# differential_evolution step 880: f(x)= 0.7398207533790055
# differential_evolution step 881: f(x)= 0.7398207533790055
# differential_evolution step 882: f(x)= 0.7398207533790055
# differential_evolution step 883: f(x)= 0.7398207533790055
# differential_evolution step 884: f(x)= 0.7398207533790055
# differential_evolution step 885: f(x)= 0.7398207533790055
# differential_evolution step 886: f(x)= 0.7398207533790055
# differential_evolution step 887: f(x)= 0.7398207533790055
# differential_evolution step 888: f(x)= 0.7398207533790055
# differential_evolution step 889: f(x)= 0.7398207533790055
# differential_evolution step 890: f(x)= 0.7398207533790055
# differential_evolution step 891: f(x)= 0.7398207533790055
# differential_evolution step 892: f(x)= 0.7398207533790055
# differential_evolution step 893: f(x)= 0.7398207533790055
# differential_evolution step 894: f(x)= 0.7398207533790055
# differential_evolution step 895: f(x)= 0.7398207533790055
# differential_evolution step 896: f(x)= 0.7398207533790055
# differential_evolution step 897: f(x)= 0.7398207533790055
# differential_evolution step 898: f(x)= 0.7398207533790055
# differential_evolution step 899: f(x)= 0.7398207533790055
# differential_evolution step 900: f(x)= 0.7398207533790055
# differential_evolution step 901: f(x)= 0.7398207533790055
# differential_evolution step 902: f(x)= 0.7398207533790055
# differential_evolution step 903: f(x)= 0.7398207533790055
# differential_evolution step 904: f(x)= 0.7398207533790055
# differential_evolution step 905: f(x)= 0.7398207533790055
# differential_evolution step 906: f(x)= 0.7398207533790055
# differential_evolution step 907: f(x)= 0.7398207533790055
# differential_evolution step 908: f(x)= 0.7398207533790055
# differential_evolution step 909: f(x)= 0.7398207533790055
# differential_evolution step 910: f(x)= 0.7398207533790055
# differential_evolution step 911: f(x)= 0.7398207533790055
# differential_evolution step 912: f(x)= 0.7398207533790055
# differential_evolution step 913: f(x)= 0.7398207533790055
# differential_evolution step 914: f(x)= 0.7398207533790055
# differential_evolution step 915: f(x)= 0.7398207533790055
# differential_evolution step 916: f(x)= 0.7398207533790055
# differential_evolution step 917: f(x)= 0.7398207533790055
# differential_evolution step 918: f(x)= 0.7398207533790055
# differential_evolution step 919: f(x)= 0.7398207533790055
# differential_evolution step 920: f(x)= 0.7398207533790055
# differential_evolution step 921: f(x)= 0.7398207533790055
# differential_evolution step 922: f(x)= 0.7398207533790055
# differential_evolution step 923: f(x)= 0.7398207533790055
# differential_evolution step 924: f(x)= 0.7398207533790055
# differential_evolution step 925: f(x)= 0.7398207533790055
# differential_evolution step 926: f(x)= 0.7398207533790055
# differential_evolution step 927: f(x)= 0.7398207533790055
# differential_evolution step 928: f(x)= 0.7398207533790055
# differential_evolution step 929: f(x)= 0.7398207533790055
# differential_evolution step 930: f(x)= 0.7398207533790055
# differential_evolution step 931: f(x)= 0.7398207533790055
# differential_evolution step 932: f(x)= 0.7398207533790055
# differential_evolution step 933: f(x)= 0.7398207533790055
# differential_evolution step 934: f(x)= 0.7398207533790055
# differential_evolution step 935: f(x)= 0.7398207533790055
# differential_evolution step 936: f(x)= 0.7398207533790055
# differential_evolution step 937: f(x)= 0.7398207533790055
# differential_evolution step 938: f(x)= 0.7398207533790055
# differential_evolution step 939: f(x)= 0.7398207533790055
# differential_evolution step 940: f(x)= 0.7398207533790055
# differential_evolution step 941: f(x)= 0.7398207533790055
# differential_evolution step 942: f(x)= 0.7398207533790055
# differential_evolution step 943: f(x)= 0.7398207533790055
# differential_evolution step 944: f(x)= 0.7398207533790055
# differential_evolution step 945: f(x)= 0.7398207533790055
# differential_evolution step 946: f(x)= 0.7398207533790055
# differential_evolution step 947: f(x)= 0.7398207533790055
# differential_evolution step 948: f(x)= 0.7398207533790055
# differential_evolution step 949: f(x)= 0.7398207533790055
# differential_evolution step 950: f(x)= 0.7398207533790055
# differential_evolution step 951: f(x)= 0.7398207533790055
# differential_evolution step 952: f(x)= 0.7398207533790055
# differential_evolution step 953: f(x)= 0.7398207533790055
# differential_evolution step 954: f(x)= 0.7398207533790055
# differential_evolution step 955: f(x)= 0.7398207533790055
# differential_evolution step 956: f(x)= 0.7398207533790055
# differential_evolution step 957: f(x)= 0.7398207533790055
# differential_evolution step 958: f(x)= 0.7398207533790055
# differential_evolution step 959: f(x)= 0.7398207533790055
# differential_evolution step 960: f(x)= 0.7398207533790055
# differential_evolution step 961: f(x)= 0.7398207533790055
# differential_evolution step 962: f(x)= 0.7398207533790055
# differential_evolution step 963: f(x)= 0.7398207533790055
# differential_evolution step 964: f(x)= 0.7398207533790055
# differential_evolution step 965: f(x)= 0.7398207533790055
# differential_evolution step 966: f(x)= 0.7398207533790055
# differential_evolution step 967: f(x)= 0.7398207533790055
# differential_evolution step 968: f(x)= 0.7398207533790055
# differential_evolution step 969: f(x)= 0.7398207533790055
# differential_evolution step 970: f(x)= 0.7398207533790055
# differential_evolution step 971: f(x)= 0.7398207533790055
# differential_evolution step 972: f(x)= 0.7398207533790055
# differential_evolution step 973: f(x)= 0.7398207533790055
# differential_evolution step 974: f(x)= 0.7398207533790055
# differential_evolution step 975: f(x)= 0.7398207533790055
# differential_evolution step 976: f(x)= 0.7398207533790055
# differential_evolution step 977: f(x)= 0.7398207533790055
# differential_evolution step 978: f(x)= 0.7398207533790055
# differential_evolution step 979: f(x)= 0.7398207533790055
# differential_evolution step 980: f(x)= 0.7398207533790055
# differential_evolution step 981: f(x)= 0.7398207533790055
# differential_evolution step 982: f(x)= 0.7398207533790055
# differential_evolution step 983: f(x)= 0.7398207533790055
# differential_evolution step 984: f(x)= 0.7398207533790055
# differential_evolution step 985: f(x)= 0.7398207533790055
# differential_evolution step 986: f(x)= 0.7398207533790055
# differential_evolution step 987: f(x)= 0.7398207533790055
# differential_evolution step 988: f(x)= 0.7398207533790055
# differential_evolution step 989: f(x)= 0.7398207533790055
# differential_evolution step 990: f(x)= 0.7398207533790055
# differential_evolution step 991: f(x)= 0.7398207533790055
# differential_evolution step 992: f(x)= 0.7398207533790055
# differential_evolution step 993: f(x)= 0.7398207533790055
# differential_evolution step 994: f(x)= 0.7398207533790055
# differential_evolution step 995: f(x)= 0.7398207533790055
# differential_evolution step 996: f(x)= 0.7398207533790055
# differential_evolution step 997: f(x)= 0.7398207533790055
# differential_evolution step 998: f(x)= 0.7398207533790055
# differential_evolution step 999: f(x)= 0.7398207533790055
# differential_evolution step 1000: f(x)= 0.7398207533790055
# Polishing solution with 'L-BFGS-B'
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_10724\111436280.py:9: RuntimeWarning: divide by zero encountered in divide
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# Optimize parameters with differential_evolution: [8.92353734e-01 6.29584178e+00 1.07494966e+00 2.71185811e+01
#  9.58669508e-01 1.87363741e+00 9.76519625e-01 4.75565468e+01
#  3.48527098e-02 2.41498645e+01 2.91625343e+00 7.01872065e+01
#  6.25236035e-01 1.00653528e+01 1.03331483e+00 5.12132519e+01
#  2.28532228e-01 4.65929807e-02 7.48743343e+00 6.06246401e+01]
# Chi quadro minimo: 0.7398207533790055

# %%
# Plots:
bounds = [
    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (26, 28),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (46, 48),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (69, 71),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (50, 52), 

    (0, 10),
    (0, 50),
    (0.1, 10),
    (59, 61)
]
lower_bounds, upper_bounds = zip(*bounds)
bounds_list = (list(lower_bounds), list(upper_bounds))
params_curve_5, covariance_5 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params5, 
                                         sigma = radial_profile_error_HA, maxfev = 10000, bounds = bounds_list)

print("Optimize parameters with curve fit:")

chi_quadr[4], red_chi[4] = save_params(params_curve_5, covariance_5, radial_profile_HA, radial_profile_error_HA, x_axes, 5, line_name="Five", output_prefix="fit")

aic[4] = AIC(x_axes, radial_profile_HA, chi_quadr[4], params_curve_5)
bic[4] = BIC(x_axes, radial_profile_HA, chi_quadr[4], params_curve_5)
print(aic[4], chi_quadr[4], bic[4], len(params_curve_5))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_5)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[16:20]),  linestyle='--', label='Sérsic 5')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)
plt.savefig('AIC_5', bbox_inches='tight')
# Out:
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.7881, r_e=7.0172, n=1.1564, x_0=27.2268
# Sérsic 2: I_e=1.2068, r_e=1.5661, n=0.7623, x_0=47.4980
# Sérsic 3: I_e=0.1635, r_e=8.4440, n=1.7677, x_0=70.3151
# Sérsic 4: I_e=0.8085, r_e=8.3012, n=0.9054, x_0=51.0317
# Sérsic 5: I_e=0.2534, r_e=1.7561, n=0.1000, x_0=60.8719
# [0.049518   0.26611286 0.04867155 0.05982244 0.43971617 0.45245416
#  0.30287792 0.10506094 0.0353414  1.1286968  0.1711184  0.0776958
#  0.16137235 0.9924505  0.0995996  0.34674311 0.9308213  7.681758
#  1.27231885 0.35055943]
# 21.438875443746525
# 72.07178683615159 21.438875443746525 113.54227916350837 20
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20]) +
        sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =[
     (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (25, 35),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (40, 50),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (65, 75),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (45, 55), 

    (0, 10),
    (0, 50),
    (0.1, 10),
    (55, 65),   # x_0: posizione da 0 a 100

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100)   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params6 = result.x

print("Optimize parameters with differential_evolution:", best_params6)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 74105.8976503894
# differential_evolution step 2: f(x)= 20263.34153643399
# differential_evolution step 3: f(x)= 20263.34153643399
# differential_evolution step 4: f(x)= 20263.34153643399
# differential_evolution step 5: f(x)= 20263.34153643399
# differential_evolution step 6: f(x)= 20263.34153643399
# differential_evolution step 7: f(x)= 12800.62650550578
# differential_evolution step 8: f(x)= 5524.813927514162
# differential_evolution step 9: f(x)= 5524.813927514162
# differential_evolution step 10: f(x)= 5524.813927514162
# differential_evolution step 11: f(x)= 5524.813927514162
# differential_evolution step 12: f(x)= 5524.813927514162
# differential_evolution step 13: f(x)= 2228.771827098002
# differential_evolution step 14: f(x)= 2228.771827098002
# differential_evolution step 15: f(x)= 2228.771827098002
# differential_evolution step 16: f(x)= 2228.771827098002
# differential_evolution step 17: f(x)= 2228.771827098002
# differential_evolution step 18: f(x)= 2228.771827098002
# differential_evolution step 19: f(x)= 2228.771827098002
# differential_evolution step 20: f(x)= 2228.771827098002
# differential_evolution step 21: f(x)= 2228.771827098002
# differential_evolution step 22: f(x)= 1807.4676104723567
# differential_evolution step 23: f(x)= 1807.4676104723567
# differential_evolution step 24: f(x)= 1284.8986322171916
# differential_evolution step 25: f(x)= 1284.8986322171916
# differential_evolution step 26: f(x)= 359.6240366405575
# differential_evolution step 27: f(x)= 359.6240366405575
# differential_evolution step 28: f(x)= 359.6240366405575
# differential_evolution step 29: f(x)= 359.6240366405575
# differential_evolution step 30: f(x)= 359.6240366405575
# differential_evolution step 31: f(x)= 359.6240366405575
# differential_evolution step 32: f(x)= 359.6240366405575
# differential_evolution step 33: f(x)= 359.6240366405575
# differential_evolution step 34: f(x)= 359.6240366405575
# differential_evolution step 35: f(x)= 359.6240366405575
# differential_evolution step 36: f(x)= 199.34675516702123
# differential_evolution step 37: f(x)= 199.34675516702123
# differential_evolution step 38: f(x)= 199.34675516702123
# differential_evolution step 39: f(x)= 199.34675516702123
# differential_evolution step 40: f(x)= 199.34675516702123
# differential_evolution step 41: f(x)= 199.34675516702123
# differential_evolution step 42: f(x)= 199.34675516702123
# differential_evolution step 43: f(x)= 199.34675516702123
# differential_evolution step 44: f(x)= 179.45462052938348
# differential_evolution step 45: f(x)= 167.35416623031026
# differential_evolution step 46: f(x)= 167.35416623031026
# differential_evolution step 47: f(x)= 167.35416623031026
# differential_evolution step 48: f(x)= 91.88550906956121
# differential_evolution step 49: f(x)= 91.88550906956121
# differential_evolution step 50: f(x)= 91.88550906956121
# differential_evolution step 51: f(x)= 91.88550906956121
# differential_evolution step 52: f(x)= 91.88550906956121
# differential_evolution step 53: f(x)= 91.88550906956121
# differential_evolution step 54: f(x)= 91.88550906956121
# differential_evolution step 55: f(x)= 91.88550906956121
# differential_evolution step 56: f(x)= 87.70614103384654
# differential_evolution step 57: f(x)= 72.18499406959165
# differential_evolution step 58: f(x)= 38.467811857040736
# differential_evolution step 59: f(x)= 36.693156410062976
# differential_evolution step 60: f(x)= 36.693156410062976
# differential_evolution step 61: f(x)= 36.693156410062976
# differential_evolution step 62: f(x)= 36.693156410062976
# differential_evolution step 63: f(x)= 36.693156410062976
# differential_evolution step 64: f(x)= 36.693156410062976
# differential_evolution step 65: f(x)= 36.693156410062976
# differential_evolution step 66: f(x)= 36.693156410062976
# differential_evolution step 67: f(x)= 36.693156410062976
# differential_evolution step 68: f(x)= 36.693156410062976
# differential_evolution step 69: f(x)= 36.693156410062976
# differential_evolution step 70: f(x)= 36.693156410062976
# differential_evolution step 71: f(x)= 36.693156410062976
# differential_evolution step 72: f(x)= 36.693156410062976
# differential_evolution step 73: f(x)= 36.693156410062976
# differential_evolution step 74: f(x)= 36.693156410062976
# differential_evolution step 75: f(x)= 36.693156410062976
# differential_evolution step 76: f(x)= 36.693156410062976
# differential_evolution step 77: f(x)= 36.693156410062976
# differential_evolution step 78: f(x)= 36.693156410062976
# differential_evolution step 79: f(x)= 36.693156410062976
# differential_evolution step 80: f(x)= 36.693156410062976
# differential_evolution step 81: f(x)= 36.693156410062976
# differential_evolution step 82: f(x)= 36.693156410062976
# differential_evolution step 83: f(x)= 36.693156410062976
# differential_evolution step 84: f(x)= 36.693156410062976
# differential_evolution step 85: f(x)= 36.693156410062976
# differential_evolution step 86: f(x)= 36.693156410062976
# differential_evolution step 87: f(x)= 36.693156410062976
# differential_evolution step 88: f(x)= 36.693156410062976
# differential_evolution step 89: f(x)= 36.693156410062976
# differential_evolution step 90: f(x)= 33.40157307801998
# differential_evolution step 91: f(x)= 24.382057871031652
# differential_evolution step 92: f(x)= 24.382057871031652
# differential_evolution step 93: f(x)= 24.382057871031652
# differential_evolution step 94: f(x)= 24.382057871031652
# differential_evolution step 95: f(x)= 24.382057871031652
# differential_evolution step 96: f(x)= 24.382057871031652
# differential_evolution step 97: f(x)= 24.382057871031652
# differential_evolution step 98: f(x)= 24.382057871031652
# differential_evolution step 99: f(x)= 24.382057871031652
# differential_evolution step 100: f(x)= 24.382057871031652
# differential_evolution step 101: f(x)= 24.382057871031652
# differential_evolution step 102: f(x)= 24.382057871031652
# differential_evolution step 103: f(x)= 24.31083176453993
# differential_evolution step 104: f(x)= 24.31083176453993
# differential_evolution step 105: f(x)= 24.31083176453993
# differential_evolution step 106: f(x)= 24.31083176453993
# differential_evolution step 107: f(x)= 19.844524512542186
# differential_evolution step 108: f(x)= 19.844524512542186
# differential_evolution step 109: f(x)= 19.844524512542186
# differential_evolution step 110: f(x)= 19.844524512542186
# differential_evolution step 111: f(x)= 19.844524512542186
# differential_evolution step 112: f(x)= 19.844524512542186
# differential_evolution step 113: f(x)= 19.844524512542186
# differential_evolution step 114: f(x)= 19.844524512542186
# differential_evolution step 115: f(x)= 19.844524512542186
# differential_evolution step 116: f(x)= 19.844524512542186
# differential_evolution step 117: f(x)= 19.844524512542186
# differential_evolution step 118: f(x)= 19.844524512542186
# differential_evolution step 119: f(x)= 19.844524512542186
# differential_evolution step 120: f(x)= 19.844524512542186
# differential_evolution step 121: f(x)= 19.844524512542186
# differential_evolution step 122: f(x)= 17.22779233062373
# differential_evolution step 123: f(x)= 17.22779233062373
# differential_evolution step 124: f(x)= 17.22779233062373
# differential_evolution step 125: f(x)= 13.745854483466667
# differential_evolution step 126: f(x)= 13.745854483466667
# differential_evolution step 127: f(x)= 13.745854483466667
# differential_evolution step 128: f(x)= 13.745854483466667
# differential_evolution step 129: f(x)= 13.745854483466667
# differential_evolution step 130: f(x)= 13.745854483466667
# differential_evolution step 131: f(x)= 13.745854483466667
# differential_evolution step 132: f(x)= 12.114608826879145
# differential_evolution step 133: f(x)= 12.114608826879145
# differential_evolution step 134: f(x)= 12.114608826879145
# differential_evolution step 135: f(x)= 12.114608826879145
# differential_evolution step 136: f(x)= 12.114608826879145
# differential_evolution step 137: f(x)= 12.114608826879145
# differential_evolution step 138: f(x)= 12.114608826879145
# differential_evolution step 139: f(x)= 12.114608826879145
# differential_evolution step 140: f(x)= 12.114608826879145
# differential_evolution step 141: f(x)= 12.114608826879145
# differential_evolution step 142: f(x)= 12.114608826879145
# differential_evolution step 143: f(x)= 12.114608826879145
# differential_evolution step 144: f(x)= 12.114608826879145
# differential_evolution step 145: f(x)= 12.114608826879145
# differential_evolution step 146: f(x)= 12.114608826879145
# differential_evolution step 147: f(x)= 12.114608826879145
# differential_evolution step 148: f(x)= 12.114608826879145
# differential_evolution step 149: f(x)= 12.114608826879145
# differential_evolution step 150: f(x)= 10.833283068881435
# differential_evolution step 151: f(x)= 10.833283068881435
# differential_evolution step 152: f(x)= 10.833283068881435
# differential_evolution step 153: f(x)= 10.833283068881435
# differential_evolution step 154: f(x)= 10.833283068881435
# differential_evolution step 155: f(x)= 9.515309461311585
# differential_evolution step 156: f(x)= 9.515309461311585
# differential_evolution step 157: f(x)= 9.293296048322658
# differential_evolution step 158: f(x)= 9.293296048322658
# differential_evolution step 159: f(x)= 9.293296048322658
# differential_evolution step 160: f(x)= 9.293296048322658
# differential_evolution step 161: f(x)= 9.293296048322658
# differential_evolution step 162: f(x)= 9.293296048322658
# differential_evolution step 163: f(x)= 9.293296048322658
# differential_evolution step 164: f(x)= 9.293296048322658
# differential_evolution step 165: f(x)= 9.293296048322658
# differential_evolution step 166: f(x)= 9.293296048322658
# differential_evolution step 167: f(x)= 9.293296048322658
# differential_evolution step 168: f(x)= 9.293296048322658
# differential_evolution step 169: f(x)= 9.293296048322658
# differential_evolution step 170: f(x)= 9.293296048322658
# differential_evolution step 171: f(x)= 9.293296048322658
# differential_evolution step 172: f(x)= 9.293296048322658
# differential_evolution step 173: f(x)= 9.293296048322658
# differential_evolution step 174: f(x)= 9.293296048322658
# differential_evolution step 175: f(x)= 9.293296048322658
# differential_evolution step 176: f(x)= 8.753664425459178
# differential_evolution step 177: f(x)= 8.753664425459178
# differential_evolution step 178: f(x)= 8.753664425459178
# differential_evolution step 179: f(x)= 8.753664425459178
# differential_evolution step 180: f(x)= 8.753664425459178
# differential_evolution step 181: f(x)= 8.753664425459178
# differential_evolution step 182: f(x)= 8.753664425459178
# differential_evolution step 183: f(x)= 8.753664425459178
# differential_evolution step 184: f(x)= 8.753664425459178
# differential_evolution step 185: f(x)= 8.500901223641883
# differential_evolution step 186: f(x)= 8.500901223641883
# differential_evolution step 187: f(x)= 7.420402926269766
# differential_evolution step 188: f(x)= 7.420402926269766
# differential_evolution step 189: f(x)= 7.420402926269766
# differential_evolution step 190: f(x)= 7.420402926269766
# differential_evolution step 191: f(x)= 7.420402926269766
# differential_evolution step 192: f(x)= 7.420402926269766
# differential_evolution step 193: f(x)= 7.420402926269766
# differential_evolution step 194: f(x)= 7.420402926269766
# differential_evolution step 195: f(x)= 7.420402926269766
# differential_evolution step 196: f(x)= 7.420402926269766
# differential_evolution step 197: f(x)= 7.420402926269766
# differential_evolution step 198: f(x)= 7.420402926269766
# differential_evolution step 199: f(x)= 7.420402926269766
# differential_evolution step 200: f(x)= 7.420402926269766
# differential_evolution step 201: f(x)= 7.420402926269766
# differential_evolution step 202: f(x)= 7.420402926269766
# differential_evolution step 203: f(x)= 7.420402926269766
# differential_evolution step 204: f(x)= 7.420402926269766
# differential_evolution step 205: f(x)= 6.344691052665914
# differential_evolution step 206: f(x)= 6.344691052665914
# differential_evolution step 207: f(x)= 6.344691052665914
# differential_evolution step 208: f(x)= 6.344691052665914
# differential_evolution step 209: f(x)= 6.344691052665914
# differential_evolution step 210: f(x)= 5.677408369027366
# differential_evolution step 211: f(x)= 5.677408369027366
# differential_evolution step 212: f(x)= 5.677408369027366
# differential_evolution step 213: f(x)= 5.677408369027366
# differential_evolution step 214: f(x)= 5.677408369027366
# differential_evolution step 215: f(x)= 5.677408369027366
# differential_evolution step 216: f(x)= 5.677408369027366
# differential_evolution step 217: f(x)= 5.677408369027366
# differential_evolution step 218: f(x)= 5.347796193170255
# differential_evolution step 219: f(x)= 5.347796193170255
# differential_evolution step 220: f(x)= 5.347796193170255
# differential_evolution step 221: f(x)= 5.347796193170255
# differential_evolution step 222: f(x)= 5.347796193170255
# differential_evolution step 223: f(x)= 5.347796193170255
# differential_evolution step 224: f(x)= 5.347796193170255
# differential_evolution step 225: f(x)= 5.347796193170255
# differential_evolution step 226: f(x)= 5.347796193170255
# differential_evolution step 227: f(x)= 5.347796193170255
# differential_evolution step 228: f(x)= 4.758010641172031
# differential_evolution step 229: f(x)= 4.758010641172031
# differential_evolution step 230: f(x)= 4.343020877184974
# differential_evolution step 231: f(x)= 4.343020877184974
# differential_evolution step 232: f(x)= 4.343020877184974
# differential_evolution step 233: f(x)= 4.343020877184974
# differential_evolution step 234: f(x)= 4.343020877184974
# differential_evolution step 235: f(x)= 4.343020877184974
# differential_evolution step 236: f(x)= 4.343020877184974
# differential_evolution step 237: f(x)= 4.29596153101362
# differential_evolution step 238: f(x)= 4.29596153101362
# differential_evolution step 239: f(x)= 4.022052680650542
# differential_evolution step 240: f(x)= 4.022052680650542
# differential_evolution step 241: f(x)= 4.022052680650542
# differential_evolution step 242: f(x)= 4.022052680650542
# differential_evolution step 243: f(x)= 4.022052680650542
# differential_evolution step 244: f(x)= 4.022052680650542
# differential_evolution step 245: f(x)= 4.022052680650542
# differential_evolution step 246: f(x)= 4.022052680650542
# differential_evolution step 247: f(x)= 4.022052680650542
# differential_evolution step 248: f(x)= 4.022052680650542
# differential_evolution step 249: f(x)= 3.9229653244099114
# differential_evolution step 250: f(x)= 3.377561306465896
# differential_evolution step 251: f(x)= 3.377561306465896
# differential_evolution step 252: f(x)= 3.377561306465896
# differential_evolution step 253: f(x)= 3.377561306465896
# differential_evolution step 254: f(x)= 3.377561306465896
# differential_evolution step 255: f(x)= 3.377561306465896
# differential_evolution step 256: f(x)= 3.377561306465896
# differential_evolution step 257: f(x)= 3.377561306465896
# differential_evolution step 258: f(x)= 3.377561306465896
# differential_evolution step 259: f(x)= 3.377561306465896
# differential_evolution step 260: f(x)= 3.377561306465896
# differential_evolution step 261: f(x)= 3.377561306465896
# differential_evolution step 262: f(x)= 3.377561306465896
# differential_evolution step 263: f(x)= 3.2748047614812097
# differential_evolution step 264: f(x)= 3.2748047614812097
# differential_evolution step 265: f(x)= 3.2748047614812097
# differential_evolution step 266: f(x)= 3.2748047614812097
# differential_evolution step 267: f(x)= 3.2529520737225064
# differential_evolution step 268: f(x)= 3.2529520737225064
# differential_evolution step 269: f(x)= 3.2529520737225064
# differential_evolution step 270: f(x)= 3.2529520737225064
# differential_evolution step 271: f(x)= 3.2529520737225064
# differential_evolution step 272: f(x)= 3.2529520737225064
# differential_evolution step 273: f(x)= 3.2529520737225064
# differential_evolution step 274: f(x)= 3.2529520737225064
# differential_evolution step 275: f(x)= 3.2529520737225064
# differential_evolution step 276: f(x)= 3.2529520737225064
# differential_evolution step 277: f(x)= 2.737855694539086
# differential_evolution step 278: f(x)= 2.737855694539086
# differential_evolution step 279: f(x)= 2.737855694539086
# differential_evolution step 280: f(x)= 2.737855694539086
# differential_evolution step 281: f(x)= 2.737855694539086
# differential_evolution step 282: f(x)= 2.737855694539086
# differential_evolution step 283: f(x)= 2.6754678175371307
# differential_evolution step 284: f(x)= 2.6754678175371307
# differential_evolution step 285: f(x)= 2.6754678175371307
# differential_evolution step 286: f(x)= 2.6754678175371307
# differential_evolution step 287: f(x)= 2.6754678175371307
# differential_evolution step 288: f(x)= 2.6754678175371307
# differential_evolution step 289: f(x)= 2.6754678175371307
# differential_evolution step 290: f(x)= 2.6754678175371307
# differential_evolution step 291: f(x)= 2.6754678175371307
# differential_evolution step 292: f(x)= 2.6754678175371307
# differential_evolution step 293: f(x)= 2.6754678175371307
# differential_evolution step 294: f(x)= 2.6754678175371307
# differential_evolution step 295: f(x)= 2.6754678175371307
# differential_evolution step 296: f(x)= 2.6754678175371307
# differential_evolution step 297: f(x)= 2.6754678175371307
# differential_evolution step 298: f(x)= 2.6754678175371307
# differential_evolution step 299: f(x)= 2.6754678175371307
# differential_evolution step 300: f(x)= 2.6754678175371307
# differential_evolution step 301: f(x)= 2.6754678175371307
# differential_evolution step 302: f(x)= 2.6754678175371307
# differential_evolution step 303: f(x)= 2.6754678175371307
# differential_evolution step 304: f(x)= 2.6754678175371307
# differential_evolution step 305: f(x)= 2.6754678175371307
# differential_evolution step 306: f(x)= 2.6754678175371307
# differential_evolution step 307: f(x)= 2.6754678175371307
# differential_evolution step 308: f(x)= 2.6754678175371307
# differential_evolution step 309: f(x)= 2.6754678175371307
# differential_evolution step 310: f(x)= 2.6754678175371307
# differential_evolution step 311: f(x)= 2.6754678175371307
# differential_evolution step 312: f(x)= 2.6754678175371307
# differential_evolution step 313: f(x)= 2.6754678175371307
# differential_evolution step 314: f(x)= 2.6754678175371307
# differential_evolution step 315: f(x)= 2.6754678175371307
# differential_evolution step 316: f(x)= 2.6754678175371307
# differential_evolution step 317: f(x)= 2.6754678175371307
# differential_evolution step 318: f(x)= 2.6754678175371307
# differential_evolution step 319: f(x)= 2.6729239663457003
# differential_evolution step 320: f(x)= 2.637842831489579
# differential_evolution step 321: f(x)= 2.4906041587538077
# differential_evolution step 322: f(x)= 2.4906041587538077
# differential_evolution step 323: f(x)= 2.4906041587538077
# differential_evolution step 324: f(x)= 2.4906041587538077
# differential_evolution step 325: f(x)= 2.4906041587538077
# differential_evolution step 326: f(x)= 2.4906041587538077
# differential_evolution step 327: f(x)= 2.4906041587538077
# differential_evolution step 328: f(x)= 2.4906041587538077
# differential_evolution step 329: f(x)= 2.4906041587538077
# differential_evolution step 330: f(x)= 2.4906041587538077
# differential_evolution step 331: f(x)= 2.4906041587538077
# differential_evolution step 332: f(x)= 2.4906041587538077
# differential_evolution step 333: f(x)= 2.4906041587538077
# differential_evolution step 334: f(x)= 2.4906041587538077
# differential_evolution step 335: f(x)= 2.4906041587538077
# differential_evolution step 336: f(x)= 2.4906041587538077
# differential_evolution step 337: f(x)= 2.4906041587538077
# differential_evolution step 338: f(x)= 2.4906041587538077
# differential_evolution step 339: f(x)= 2.4906041587538077
# differential_evolution step 340: f(x)= 2.4906041587538077
# differential_evolution step 341: f(x)= 2.4906041587538077
# differential_evolution step 342: f(x)= 2.4906041587538077
# differential_evolution step 343: f(x)= 2.4906041587538077
# differential_evolution step 344: f(x)= 2.4906041587538077
# differential_evolution step 345: f(x)= 2.4906041587538077
# differential_evolution step 346: f(x)= 2.3530611685783858
# differential_evolution step 347: f(x)= 2.3530611685783858
# differential_evolution step 348: f(x)= 2.3530611685783858
# differential_evolution step 349: f(x)= 2.3530611685783858
# differential_evolution step 350: f(x)= 2.3530611685783858
# differential_evolution step 351: f(x)= 2.3530611685783858
# differential_evolution step 352: f(x)= 2.3530611685783858
# differential_evolution step 353: f(x)= 2.340094989828256
# differential_evolution step 354: f(x)= 2.340094989828256
# differential_evolution step 355: f(x)= 2.340094989828256
# differential_evolution step 356: f(x)= 2.340094989828256
# differential_evolution step 357: f(x)= 2.340094989828256
# differential_evolution step 358: f(x)= 2.340094989828256
# differential_evolution step 359: f(x)= 2.340094989828256
# differential_evolution step 360: f(x)= 2.340094989828256
# differential_evolution step 361: f(x)= 2.340094989828256
# differential_evolution step 362: f(x)= 2.340094989828256
# differential_evolution step 363: f(x)= 2.340094989828256
# differential_evolution step 364: f(x)= 2.340094989828256
# differential_evolution step 365: f(x)= 2.340094989828256
# differential_evolution step 366: f(x)= 2.340094989828256
# differential_evolution step 367: f(x)= 2.340094989828256
# differential_evolution step 368: f(x)= 2.340094989828256
# differential_evolution step 369: f(x)= 2.340094989828256
# differential_evolution step 370: f(x)= 2.340094989828256
# differential_evolution step 371: f(x)= 2.340094989828256
# differential_evolution step 372: f(x)= 2.340094989828256
# differential_evolution step 373: f(x)= 2.340094989828256
# differential_evolution step 374: f(x)= 2.340094989828256
# differential_evolution step 375: f(x)= 2.340094989828256
# differential_evolution step 376: f(x)= 2.340094989828256
# differential_evolution step 377: f(x)= 2.235495067338542
# differential_evolution step 378: f(x)= 2.235495067338542
# differential_evolution step 379: f(x)= 2.235495067338542
# differential_evolution step 380: f(x)= 2.235495067338542
# differential_evolution step 381: f(x)= 2.235495067338542
# differential_evolution step 382: f(x)= 2.1369747884681054
# differential_evolution step 383: f(x)= 2.1369747884681054
# differential_evolution step 384: f(x)= 2.1369747884681054
# differential_evolution step 385: f(x)= 2.1369747884681054
# differential_evolution step 386: f(x)= 2.1369747884681054
# differential_evolution step 387: f(x)= 2.1369747884681054
# differential_evolution step 388: f(x)= 2.1369747884681054
# differential_evolution step 389: f(x)= 2.1369747884681054
# differential_evolution step 390: f(x)= 2.1369747884681054
# differential_evolution step 391: f(x)= 2.1369747884681054
# differential_evolution step 392: f(x)= 2.1369747884681054
# differential_evolution step 393: f(x)= 2.1369747884681054
# differential_evolution step 394: f(x)= 2.1369747884681054
# differential_evolution step 395: f(x)= 2.1369747884681054
# differential_evolution step 396: f(x)= 2.1369747884681054
# differential_evolution step 397: f(x)= 2.1369747884681054
# differential_evolution step 398: f(x)= 2.1369747884681054
# differential_evolution step 399: f(x)= 2.1369747884681054
# differential_evolution step 400: f(x)= 2.1369747884681054
# differential_evolution step 401: f(x)= 2.1369747884681054
# differential_evolution step 402: f(x)= 2.1369747884681054
# differential_evolution step 403: f(x)= 2.1369747884681054
# differential_evolution step 404: f(x)= 2.1369747884681054
# differential_evolution step 405: f(x)= 2.1369747884681054
# differential_evolution step 406: f(x)= 2.1369747884681054
# differential_evolution step 407: f(x)= 2.1369747884681054
# differential_evolution step 408: f(x)= 2.1369747884681054
# differential_evolution step 409: f(x)= 2.1369747884681054
# differential_evolution step 410: f(x)= 2.1369747884681054
# differential_evolution step 411: f(x)= 2.1369747884681054
# differential_evolution step 412: f(x)= 2.1369747884681054
# differential_evolution step 413: f(x)= 2.1369747884681054
# differential_evolution step 414: f(x)= 2.1369747884681054
# differential_evolution step 415: f(x)= 2.1369747884681054
# differential_evolution step 416: f(x)= 2.1369747884681054
# differential_evolution step 417: f(x)= 2.1369747884681054
# differential_evolution step 418: f(x)= 2.1369747884681054
# differential_evolution step 419: f(x)= 2.1369747884681054
# differential_evolution step 420: f(x)= 2.1369747884681054
# differential_evolution step 421: f(x)= 2.1369747884681054
# differential_evolution step 422: f(x)= 2.1369747884681054
# differential_evolution step 423: f(x)= 2.1369747884681054
# differential_evolution step 424: f(x)= 2.1369747884681054
# differential_evolution step 425: f(x)= 2.1369747884681054
# differential_evolution step 426: f(x)= 2.1369747884681054
# differential_evolution step 427: f(x)= 2.1369747884681054
# differential_evolution step 428: f(x)= 2.1369747884681054
# differential_evolution step 429: f(x)= 2.1369747884681054
# differential_evolution step 430: f(x)= 2.1369747884681054
# differential_evolution step 431: f(x)= 2.1369747884681054
# differential_evolution step 432: f(x)= 2.1369747884681054
# differential_evolution step 433: f(x)= 2.1369747884681054
# differential_evolution step 434: f(x)= 2.1369747884681054
# differential_evolution step 435: f(x)= 2.1369747884681054
# differential_evolution step 436: f(x)= 2.125158540200378
# differential_evolution step 437: f(x)= 2.125158540200378
# differential_evolution step 438: f(x)= 2.125158540200378
# differential_evolution step 439: f(x)= 2.125158540200378
# differential_evolution step 440: f(x)= 2.125158540200378
# differential_evolution step 441: f(x)= 2.125158540200378
# differential_evolution step 442: f(x)= 2.125158540200378
# differential_evolution step 443: f(x)= 2.125158540200378
# differential_evolution step 444: f(x)= 2.125158540200378
# differential_evolution step 445: f(x)= 2.125158540200378
# differential_evolution step 446: f(x)= 2.125158540200378
# differential_evolution step 447: f(x)= 2.125158540200378
# differential_evolution step 448: f(x)= 2.125158540200378
# differential_evolution step 449: f(x)= 2.125158540200378
# differential_evolution step 450: f(x)= 2.1203157531327044
# differential_evolution step 451: f(x)= 2.1203157531327044
# differential_evolution step 452: f(x)= 2.1203157531327044
# differential_evolution step 453: f(x)= 2.1203157531327044
# differential_evolution step 454: f(x)= 2.1203157531327044
# differential_evolution step 455: f(x)= 2.1203157531327044
# differential_evolution step 456: f(x)= 2.1203157531327044
# differential_evolution step 457: f(x)= 2.1203157531327044
# differential_evolution step 458: f(x)= 2.1203157531327044
# differential_evolution step 459: f(x)= 2.1203157531327044
# differential_evolution step 460: f(x)= 2.00840464091695
# differential_evolution step 461: f(x)= 2.00840464091695
# differential_evolution step 462: f(x)= 2.00840464091695
# differential_evolution step 463: f(x)= 2.00840464091695
# differential_evolution step 464: f(x)= 2.00840464091695
# differential_evolution step 465: f(x)= 2.00840464091695
# differential_evolution step 466: f(x)= 2.00840464091695
# differential_evolution step 467: f(x)= 2.00840464091695
# differential_evolution step 468: f(x)= 2.00840464091695
# differential_evolution step 469: f(x)= 2.00840464091695
# differential_evolution step 470: f(x)= 2.00840464091695
# differential_evolution step 471: f(x)= 2.00840464091695
# differential_evolution step 472: f(x)= 2.00840464091695
# differential_evolution step 473: f(x)= 1.9986146774648041
# differential_evolution step 474: f(x)= 1.9986146774648041
# differential_evolution step 475: f(x)= 1.9986146774648041
# differential_evolution step 476: f(x)= 1.9986146774648041
# differential_evolution step 477: f(x)= 1.9986146774648041
# differential_evolution step 478: f(x)= 1.9986146774648041
# differential_evolution step 479: f(x)= 1.9986146774648041
# differential_evolution step 480: f(x)= 1.9986146774648041
# differential_evolution step 481: f(x)= 1.9986146774648041
# differential_evolution step 482: f(x)= 1.9701499235496664
# differential_evolution step 483: f(x)= 1.9701499235496664
# differential_evolution step 484: f(x)= 1.9701499235496664
# differential_evolution step 485: f(x)= 1.9701499235496664
# differential_evolution step 486: f(x)= 1.9701499235496664
# differential_evolution step 487: f(x)= 1.9701499235496664
# differential_evolution step 488: f(x)= 1.9129623707488261
# differential_evolution step 489: f(x)= 1.9129623707488261
# differential_evolution step 490: f(x)= 1.9129623707488261
# differential_evolution step 491: f(x)= 1.9129623707488261
# differential_evolution step 492: f(x)= 1.8929639778408
# differential_evolution step 493: f(x)= 1.8929639778408
# differential_evolution step 494: f(x)= 1.8929639778408
# differential_evolution step 495: f(x)= 1.8929639778408
# differential_evolution step 496: f(x)= 1.8929639778408
# differential_evolution step 497: f(x)= 1.8929639778408
# differential_evolution step 498: f(x)= 1.8929639778408
# differential_evolution step 499: f(x)= 1.8929639778408
# differential_evolution step 500: f(x)= 1.8929639778408
# differential_evolution step 501: f(x)= 1.8929639778408
# differential_evolution step 502: f(x)= 1.8929639778408
# differential_evolution step 503: f(x)= 1.8929639778408
# differential_evolution step 504: f(x)= 1.8929639778408
# differential_evolution step 505: f(x)= 1.8929639778408
# differential_evolution step 506: f(x)= 1.8929639778408
# differential_evolution step 507: f(x)= 1.8929639778408
# differential_evolution step 508: f(x)= 1.8929639778408
# differential_evolution step 509: f(x)= 1.8929639778408
# differential_evolution step 510: f(x)= 1.8929639778408
# differential_evolution step 511: f(x)= 1.8929639778408
# differential_evolution step 512: f(x)= 1.8929639778408
# differential_evolution step 513: f(x)= 1.8929639778408
# differential_evolution step 514: f(x)= 1.8929639778408
# differential_evolution step 515: f(x)= 1.8929639778408
# differential_evolution step 516: f(x)= 1.8929639778408
# differential_evolution step 517: f(x)= 1.8929639778408
# differential_evolution step 518: f(x)= 1.8929639778408
# differential_evolution step 519: f(x)= 1.8929639778408
# differential_evolution step 520: f(x)= 1.8877286707343925
# differential_evolution step 521: f(x)= 1.8877286707343925
# differential_evolution step 522: f(x)= 1.8877286707343925
# differential_evolution step 523: f(x)= 1.8877286707343925
# differential_evolution step 524: f(x)= 1.8877286707343925
# differential_evolution step 525: f(x)= 1.8877286707343925
# differential_evolution step 526: f(x)= 1.8877286707343925
# differential_evolution step 527: f(x)= 1.8055990180404051
# differential_evolution step 528: f(x)= 1.8055990180404051
# differential_evolution step 529: f(x)= 1.8055990180404051
# differential_evolution step 530: f(x)= 1.8055990180404051
# differential_evolution step 531: f(x)= 1.8055990180404051
# differential_evolution step 532: f(x)= 1.8055990180404051
# differential_evolution step 533: f(x)= 1.8055990180404051
# differential_evolution step 534: f(x)= 1.8055990180404051
# differential_evolution step 535: f(x)= 1.8055990180404051
# differential_evolution step 536: f(x)= 1.8055990180404051
# differential_evolution step 537: f(x)= 1.8055990180404051
# differential_evolution step 538: f(x)= 1.8055990180404051
# differential_evolution step 539: f(x)= 1.8055990180404051
# differential_evolution step 540: f(x)= 1.8055990180404051
# differential_evolution step 541: f(x)= 1.8055990180404051
# differential_evolution step 542: f(x)= 1.8055990180404051
# differential_evolution step 543: f(x)= 1.8055990180404051
# differential_evolution step 544: f(x)= 1.8055990180404051
# differential_evolution step 545: f(x)= 1.8055990180404051
# differential_evolution step 546: f(x)= 1.8055990180404051
# differential_evolution step 547: f(x)= 1.8055990180404051
# differential_evolution step 548: f(x)= 1.8055990180404051
# differential_evolution step 549: f(x)= 1.8055990180404051
# differential_evolution step 550: f(x)= 1.8055990180404051
# differential_evolution step 551: f(x)= 1.8055990180404051
# differential_evolution step 552: f(x)= 1.8055990180404051
# differential_evolution step 553: f(x)= 1.8055990180404051
# differential_evolution step 554: f(x)= 1.8055990180404051
# differential_evolution step 555: f(x)= 1.8055990180404051
# differential_evolution step 556: f(x)= 1.8055990180404051
# differential_evolution step 557: f(x)= 1.8055990180404051
# differential_evolution step 558: f(x)= 1.8055990180404051
# differential_evolution step 559: f(x)= 1.8055990180404051
# differential_evolution step 560: f(x)= 1.8055990180404051
# differential_evolution step 561: f(x)= 1.8055990180404051
# differential_evolution step 562: f(x)= 1.8055990180404051
# differential_evolution step 563: f(x)= 1.8055990180404051
# differential_evolution step 564: f(x)= 1.8055990180404051
# differential_evolution step 565: f(x)= 1.8055990180404051
# differential_evolution step 566: f(x)= 1.8055990180404051
# differential_evolution step 567: f(x)= 1.8055990180404051
# differential_evolution step 568: f(x)= 1.8055990180404051
# differential_evolution step 569: f(x)= 1.8055990180404051
# differential_evolution step 570: f(x)= 1.8055990180404051
# differential_evolution step 571: f(x)= 1.8055990180404051
# differential_evolution step 572: f(x)= 1.8055990180404051
# differential_evolution step 573: f(x)= 1.8055990180404051
# differential_evolution step 574: f(x)= 1.8055990180404051
# differential_evolution step 575: f(x)= 1.8055990180404051
# differential_evolution step 576: f(x)= 1.8055990180404051
# differential_evolution step 577: f(x)= 1.8055990180404051
# differential_evolution step 578: f(x)= 1.8055990180404051
# differential_evolution step 579: f(x)= 1.8055990180404051
# differential_evolution step 580: f(x)= 1.8055990180404051
# differential_evolution step 581: f(x)= 1.8055990180404051
# differential_evolution step 582: f(x)= 1.8055990180404051
# differential_evolution step 583: f(x)= 1.8055990180404051
# differential_evolution step 584: f(x)= 1.8055990180404051
# differential_evolution step 585: f(x)= 1.8055990180404051
# differential_evolution step 586: f(x)= 1.8021493804640913
# differential_evolution step 587: f(x)= 1.8021493804640913
# differential_evolution step 588: f(x)= 1.8021493804640913
# differential_evolution step 589: f(x)= 1.8021493804640913
# differential_evolution step 590: f(x)= 1.7862964306165101
# differential_evolution step 591: f(x)= 1.7862964306165101
# differential_evolution step 592: f(x)= 1.7862964306165101
# differential_evolution step 593: f(x)= 1.7862964306165101
# differential_evolution step 594: f(x)= 1.7862964306165101
# differential_evolution step 595: f(x)= 1.7862964306165101
# differential_evolution step 596: f(x)= 1.7862964306165101
# differential_evolution step 597: f(x)= 1.7862964306165101
# differential_evolution step 598: f(x)= 1.7862964306165101
# differential_evolution step 599: f(x)= 1.7862964306165101
# differential_evolution step 600: f(x)= 1.7862964306165101
# differential_evolution step 601: f(x)= 1.7862964306165101
# differential_evolution step 602: f(x)= 1.7862964306165101
# differential_evolution step 603: f(x)= 1.7862964306165101
# differential_evolution step 604: f(x)= 1.7862964306165101
# differential_evolution step 605: f(x)= 1.7862964306165101
# differential_evolution step 606: f(x)= 1.7862964306165101
# differential_evolution step 607: f(x)= 1.7862964306165101
# differential_evolution step 608: f(x)= 1.7862964306165101
# differential_evolution step 609: f(x)= 1.7862964306165101
# differential_evolution step 610: f(x)= 1.7862964306165101
# differential_evolution step 611: f(x)= 1.7862964306165101
# differential_evolution step 612: f(x)= 1.7862964306165101
# differential_evolution step 613: f(x)= 1.7862964306165101
# differential_evolution step 614: f(x)= 1.7862964306165101
# differential_evolution step 615: f(x)= 1.7862964306165101
# differential_evolution step 616: f(x)= 1.783593476938586
# differential_evolution step 617: f(x)= 1.783593476938586
# differential_evolution step 618: f(x)= 1.783593476938586
# differential_evolution step 619: f(x)= 1.783593476938586
# differential_evolution step 620: f(x)= 1.783593476938586
# differential_evolution step 621: f(x)= 1.783593476938586
# differential_evolution step 622: f(x)= 1.7783036962972605
# differential_evolution step 623: f(x)= 1.7783036962972605
# differential_evolution step 624: f(x)= 1.7783036962972605
# differential_evolution step 625: f(x)= 1.7783036962972605
# differential_evolution step 626: f(x)= 1.7783036962972605
# differential_evolution step 627: f(x)= 1.7783036962972605
# differential_evolution step 628: f(x)= 1.7783036962972605
# differential_evolution step 629: f(x)= 1.7695398320401106
# differential_evolution step 630: f(x)= 1.7695398320401106
# differential_evolution step 631: f(x)= 1.7695398320401106
# differential_evolution step 632: f(x)= 1.7695398320401106
# differential_evolution step 633: f(x)= 1.7695398320401106
# differential_evolution step 634: f(x)= 1.7695398320401106
# differential_evolution step 635: f(x)= 1.7695398320401106
# differential_evolution step 636: f(x)= 1.7695398320401106
# differential_evolution step 637: f(x)= 1.7695398320401106
# differential_evolution step 638: f(x)= 1.7695398320401106
# differential_evolution step 639: f(x)= 1.7695398320401106
# differential_evolution step 640: f(x)= 1.7695398320401106
# differential_evolution step 641: f(x)= 1.7695398320401106
# differential_evolution step 642: f(x)= 1.7664736982112903
# differential_evolution step 643: f(x)= 1.7664736982112903
# differential_evolution step 644: f(x)= 1.7664736982112903
# differential_evolution step 645: f(x)= 1.7664736982112903
# differential_evolution step 646: f(x)= 1.7664736982112903
# differential_evolution step 647: f(x)= 1.7664736982112903
# differential_evolution step 648: f(x)= 1.7664736982112903
# differential_evolution step 649: f(x)= 1.7664736982112903
# differential_evolution step 650: f(x)= 1.7664736982112903
# differential_evolution step 651: f(x)= 1.7664736982112903
# differential_evolution step 652: f(x)= 1.7664736982112903
# differential_evolution step 653: f(x)= 1.7664736982112903
# differential_evolution step 654: f(x)= 1.7664736982112903
# differential_evolution step 655: f(x)= 1.7664736982112903
# differential_evolution step 656: f(x)= 1.7664736982112903
# differential_evolution step 657: f(x)= 1.7365554481846146
# differential_evolution step 658: f(x)= 1.7365554481846146
# differential_evolution step 659: f(x)= 1.7365554481846146
# differential_evolution step 660: f(x)= 1.7365554481846146
# differential_evolution step 661: f(x)= 1.7365554481846146
# differential_evolution step 662: f(x)= 1.7365554481846146
# differential_evolution step 663: f(x)= 1.7365554481846146
# differential_evolution step 664: f(x)= 1.7365554481846146
# differential_evolution step 665: f(x)= 1.7365554481846146
# differential_evolution step 666: f(x)= 1.7365554481846146
# differential_evolution step 667: f(x)= 1.7365554481846146
# differential_evolution step 668: f(x)= 1.7365554481846146
# differential_evolution step 669: f(x)= 1.7365554481846146
# differential_evolution step 670: f(x)= 1.7365554481846146
# differential_evolution step 671: f(x)= 1.7365554481846146
# differential_evolution step 672: f(x)= 1.7365554481846146
# differential_evolution step 673: f(x)= 1.7365554481846146
# differential_evolution step 674: f(x)= 1.7365554481846146
# differential_evolution step 675: f(x)= 1.7365554481846146
# differential_evolution step 676: f(x)= 1.7183166591295957
# differential_evolution step 677: f(x)= 1.7183166591295957
# differential_evolution step 678: f(x)= 1.7183166591295957
# differential_evolution step 679: f(x)= 1.7183166591295957
# differential_evolution step 680: f(x)= 1.7183166591295957
# differential_evolution step 681: f(x)= 1.7183166591295957
# differential_evolution step 682: f(x)= 1.7183166591295957
# differential_evolution step 683: f(x)= 1.7183166591295957
# differential_evolution step 684: f(x)= 1.7183166591295957
# differential_evolution step 685: f(x)= 1.7183166591295957
# differential_evolution step 686: f(x)= 1.7183166591295957
# differential_evolution step 687: f(x)= 1.7183166591295957
# differential_evolution step 688: f(x)= 1.7183166591295957
# differential_evolution step 689: f(x)= 1.7183166591295957
# differential_evolution step 690: f(x)= 1.7183166591295957
# differential_evolution step 691: f(x)= 1.7133240835531387
# differential_evolution step 692: f(x)= 1.7133240835531387
# differential_evolution step 693: f(x)= 1.7133240835531387
# differential_evolution step 694: f(x)= 1.7133240835531387
# differential_evolution step 695: f(x)= 1.7133240835531387
# differential_evolution step 696: f(x)= 1.7133240835531387
# differential_evolution step 697: f(x)= 1.7133240835531387
# differential_evolution step 698: f(x)= 1.7133240835531387
# differential_evolution step 699: f(x)= 1.7133240835531387
# differential_evolution step 700: f(x)= 1.7133240835531387
# differential_evolution step 701: f(x)= 1.7133240835531387
# differential_evolution step 702: f(x)= 1.7133240835531387
# differential_evolution step 703: f(x)= 1.7133240835531387
# differential_evolution step 704: f(x)= 1.7133240835531387
# differential_evolution step 705: f(x)= 1.7133240835531387
# differential_evolution step 706: f(x)= 1.7133240835531387
# differential_evolution step 707: f(x)= 1.7133240835531387
# differential_evolution step 708: f(x)= 1.7133240835531387
# differential_evolution step 709: f(x)= 1.7133240835531387
# differential_evolution step 710: f(x)= 1.7133240835531387
# differential_evolution step 711: f(x)= 1.7133240835531387
# differential_evolution step 712: f(x)= 1.7133240835531387
# differential_evolution step 713: f(x)= 1.7133240835531387
# differential_evolution step 714: f(x)= 1.7133240835531387
# differential_evolution step 715: f(x)= 1.7133240835531387
# differential_evolution step 716: f(x)= 1.7133240835531387
# differential_evolution step 717: f(x)= 1.7133240835531387
# differential_evolution step 718: f(x)= 1.7133240835531387
# differential_evolution step 719: f(x)= 1.7133240835531387
# differential_evolution step 720: f(x)= 1.7133240835531387
# differential_evolution step 721: f(x)= 1.7133240835531387
# differential_evolution step 722: f(x)= 1.7133240835531387
# differential_evolution step 723: f(x)= 1.7133240835531387
# differential_evolution step 724: f(x)= 1.7133240835531387
# differential_evolution step 725: f(x)= 1.7133240835531387
# differential_evolution step 726: f(x)= 1.7133240835531387
# differential_evolution step 727: f(x)= 1.7133240835531387
# differential_evolution step 728: f(x)= 1.7133240835531387
# differential_evolution step 729: f(x)= 1.7133240835531387
# differential_evolution step 730: f(x)= 1.7133240835531387
# differential_evolution step 731: f(x)= 1.7133240835531387
# differential_evolution step 732: f(x)= 1.7133240835531387
# differential_evolution step 733: f(x)= 1.7133240835531387
# differential_evolution step 734: f(x)= 1.7133240835531387
# differential_evolution step 735: f(x)= 1.7133240835531387
# differential_evolution step 736: f(x)= 1.7133240835531387
# differential_evolution step 737: f(x)= 1.7133240835531387
# differential_evolution step 738: f(x)= 1.7133240835531387
# differential_evolution step 739: f(x)= 1.7133240835531387
# differential_evolution step 740: f(x)= 1.7061528903460663
# differential_evolution step 741: f(x)= 1.7061528903460663
# differential_evolution step 742: f(x)= 1.7061528903460663
# differential_evolution step 743: f(x)= 1.701549250484906
# differential_evolution step 744: f(x)= 1.701549250484906
# differential_evolution step 745: f(x)= 1.701549250484906
# differential_evolution step 746: f(x)= 1.701549250484906
# differential_evolution step 747: f(x)= 1.701549250484906
# differential_evolution step 748: f(x)= 1.701549250484906
# differential_evolution step 749: f(x)= 1.701549250484906
# differential_evolution step 750: f(x)= 1.701549250484906
# differential_evolution step 751: f(x)= 1.701549250484906
# differential_evolution step 752: f(x)= 1.701549250484906
# differential_evolution step 753: f(x)= 1.701549250484906
# differential_evolution step 754: f(x)= 1.701549250484906
# differential_evolution step 755: f(x)= 1.701549250484906
# differential_evolution step 756: f(x)= 1.701549250484906
# differential_evolution step 757: f(x)= 1.701549250484906
# differential_evolution step 758: f(x)= 1.701549250484906
# differential_evolution step 759: f(x)= 1.701549250484906
# differential_evolution step 760: f(x)= 1.701549250484906
# differential_evolution step 761: f(x)= 1.701549250484906
# differential_evolution step 762: f(x)= 1.701549250484906
# differential_evolution step 763: f(x)= 1.701549250484906
# differential_evolution step 764: f(x)= 1.701549250484906
# differential_evolution step 765: f(x)= 1.701549250484906
# differential_evolution step 766: f(x)= 1.701549250484906
# differential_evolution step 767: f(x)= 1.701549250484906
# differential_evolution step 768: f(x)= 1.701549250484906
# differential_evolution step 769: f(x)= 1.701549250484906
# differential_evolution step 770: f(x)= 1.701549250484906
# differential_evolution step 771: f(x)= 1.701549250484906
# differential_evolution step 772: f(x)= 1.701549250484906
# differential_evolution step 773: f(x)= 1.701549250484906
# differential_evolution step 774: f(x)= 1.6896569232020018
# differential_evolution step 775: f(x)= 1.6896569232020018
# differential_evolution step 776: f(x)= 1.6896569232020018
# differential_evolution step 777: f(x)= 1.6868868016309673
# differential_evolution step 778: f(x)= 1.6868868016309673
# differential_evolution step 779: f(x)= 1.6868868016309673
# differential_evolution step 780: f(x)= 1.6868868016309673
# differential_evolution step 781: f(x)= 1.6868868016309673
# differential_evolution step 782: f(x)= 1.6868868016309673
# differential_evolution step 783: f(x)= 1.6868868016309673
# differential_evolution step 784: f(x)= 1.6868868016309673
# differential_evolution step 785: f(x)= 1.6868868016309673
# differential_evolution step 786: f(x)= 1.6868868016309673
# differential_evolution step 787: f(x)= 1.6868868016309673
# differential_evolution step 788: f(x)= 1.6868868016309673
# differential_evolution step 789: f(x)= 1.6868868016309673
# differential_evolution step 790: f(x)= 1.6868868016309673
# differential_evolution step 791: f(x)= 1.6868868016309673
# differential_evolution step 792: f(x)= 1.6868868016309673
# differential_evolution step 793: f(x)= 1.6868868016309673
# differential_evolution step 794: f(x)= 1.6868868016309673
# differential_evolution step 795: f(x)= 1.6868868016309673
# differential_evolution step 796: f(x)= 1.6868868016309673
# differential_evolution step 797: f(x)= 1.6868868016309673
# differential_evolution step 798: f(x)= 1.6830143102259971
# differential_evolution step 799: f(x)= 1.6830143102259971
# differential_evolution step 800: f(x)= 1.6830143102259971
# differential_evolution step 801: f(x)= 1.6830143102259971
# differential_evolution step 802: f(x)= 1.6830143102259971
# differential_evolution step 803: f(x)= 1.6830143102259971
# differential_evolution step 804: f(x)= 1.6830143102259971
# differential_evolution step 805: f(x)= 1.671249078557659
# differential_evolution step 806: f(x)= 1.671249078557659
# differential_evolution step 807: f(x)= 1.6598826410393162
# differential_evolution step 808: f(x)= 1.6598826410393162
# differential_evolution step 809: f(x)= 1.6598826410393162
# differential_evolution step 810: f(x)= 1.6598826410393162
# differential_evolution step 811: f(x)= 1.6550613635085942
# differential_evolution step 812: f(x)= 1.6550613635085942
# differential_evolution step 813: f(x)= 1.6550613635085942
# differential_evolution step 814: f(x)= 1.6550613635085942
# differential_evolution step 815: f(x)= 1.6550613635085942
# differential_evolution step 816: f(x)= 1.6550613635085942
# differential_evolution step 817: f(x)= 1.6550613635085942
# differential_evolution step 818: f(x)= 1.6550613635085942
# differential_evolution step 819: f(x)= 1.6550613635085942
# differential_evolution step 820: f(x)= 1.6550613635085942
# differential_evolution step 821: f(x)= 1.6550613635085942
# differential_evolution step 822: f(x)= 1.6550613635085942
# differential_evolution step 823: f(x)= 1.6550613635085942
# differential_evolution step 824: f(x)= 1.6550613635085942
# differential_evolution step 825: f(x)= 1.6550613635085942
# differential_evolution step 826: f(x)= 1.6550613635085942
# differential_evolution step 827: f(x)= 1.6550613635085942
# differential_evolution step 828: f(x)= 1.6550613635085942
# differential_evolution step 829: f(x)= 1.6550613635085942
# differential_evolution step 830: f(x)= 1.6550613635085942
# differential_evolution step 831: f(x)= 1.6550613635085942
# differential_evolution step 832: f(x)= 1.6550613635085942
# differential_evolution step 833: f(x)= 1.6550613635085942
# differential_evolution step 834: f(x)= 1.6550613635085942
# differential_evolution step 835: f(x)= 1.6550613635085942
# differential_evolution step 836: f(x)= 1.6550613635085942
# differential_evolution step 837: f(x)= 1.6550613635085942
# differential_evolution step 838: f(x)= 1.6550613635085942
# differential_evolution step 839: f(x)= 1.6550613635085942
# differential_evolution step 840: f(x)= 1.6550613635085942
# differential_evolution step 841: f(x)= 1.6550613635085942
# differential_evolution step 842: f(x)= 1.6550613635085942
# differential_evolution step 843: f(x)= 1.6550613635085942
# differential_evolution step 844: f(x)= 1.6550613635085942
# differential_evolution step 845: f(x)= 1.6550613635085942
# differential_evolution step 846: f(x)= 1.6550613635085942
# differential_evolution step 847: f(x)= 1.6550613635085942
# differential_evolution step 848: f(x)= 1.6550613635085942
# differential_evolution step 849: f(x)= 1.6550613635085942
# differential_evolution step 850: f(x)= 1.6550613635085942
# differential_evolution step 851: f(x)= 1.6550613635085942
# differential_evolution step 852: f(x)= 1.6550613635085942
# differential_evolution step 853: f(x)= 1.6550613635085942
# differential_evolution step 854: f(x)= 1.6550613635085942
# differential_evolution step 855: f(x)= 1.6550613635085942
# differential_evolution step 856: f(x)= 1.6550613635085942
# differential_evolution step 857: f(x)= 1.6550613635085942
# differential_evolution step 858: f(x)= 1.6550613635085942
# differential_evolution step 859: f(x)= 1.6550613635085942
# differential_evolution step 860: f(x)= 1.6550613635085942
# differential_evolution step 861: f(x)= 1.6550613635085942
# differential_evolution step 862: f(x)= 1.6550613635085942
# differential_evolution step 863: f(x)= 1.6550613635085942
# differential_evolution step 864: f(x)= 1.6550613635085942
# differential_evolution step 865: f(x)= 1.6550613635085942
# differential_evolution step 866: f(x)= 1.6550613635085942
# differential_evolution step 867: f(x)= 1.6550613635085942
# differential_evolution step 868: f(x)= 1.6455266080861417
# differential_evolution step 869: f(x)= 1.6455266080861417
# differential_evolution step 870: f(x)= 1.6455266080861417
# differential_evolution step 871: f(x)= 1.6455266080861417
# differential_evolution step 872: f(x)= 1.6455266080861417
# differential_evolution step 873: f(x)= 1.6455266080861417
# differential_evolution step 874: f(x)= 1.6455266080861417
# differential_evolution step 875: f(x)= 1.6455266080861417
# differential_evolution step 876: f(x)= 1.6455266080861417
# differential_evolution step 877: f(x)= 1.6455266080861417
# differential_evolution step 878: f(x)= 1.6455266080861417
# differential_evolution step 879: f(x)= 1.6455266080861417
# differential_evolution step 880: f(x)= 1.6455266080861417
# differential_evolution step 881: f(x)= 1.6455266080861417
# differential_evolution step 882: f(x)= 1.6455266080861417
# differential_evolution step 883: f(x)= 1.6455266080861417
# differential_evolution step 884: f(x)= 1.6455266080861417
# differential_evolution step 885: f(x)= 1.6455266080861417
# differential_evolution step 886: f(x)= 1.6455266080861417
# differential_evolution step 887: f(x)= 1.6455266080861417
# differential_evolution step 888: f(x)= 1.6455266080861417
# differential_evolution step 889: f(x)= 1.6455266080861417
# differential_evolution step 890: f(x)= 1.6455266080861417
# differential_evolution step 891: f(x)= 1.6455266080861417
# differential_evolution step 892: f(x)= 1.6455266080861417
# differential_evolution step 893: f(x)= 1.6455266080861417
# differential_evolution step 894: f(x)= 1.6455266080861417
# differential_evolution step 895: f(x)= 1.6455266080861417
# differential_evolution step 896: f(x)= 1.6455266080861417
# differential_evolution step 897: f(x)= 1.6455266080861417
# differential_evolution step 898: f(x)= 1.6455266080861417
# differential_evolution step 899: f(x)= 1.6455266080861417
# differential_evolution step 900: f(x)= 1.6455266080861417
# differential_evolution step 901: f(x)= 1.6455266080861417
# differential_evolution step 902: f(x)= 1.6455266080861417
# differential_evolution step 903: f(x)= 1.6455266080861417
# differential_evolution step 904: f(x)= 1.6455266080861417
# differential_evolution step 905: f(x)= 1.6455266080861417
# differential_evolution step 906: f(x)= 1.6397607198769388
# differential_evolution step 907: f(x)= 1.6397607198769388
# differential_evolution step 908: f(x)= 1.6397607198769388
# differential_evolution step 909: f(x)= 1.6179273245695602
# differential_evolution step 910: f(x)= 1.6179273245695602
# differential_evolution step 911: f(x)= 1.6179273245695602
# differential_evolution step 912: f(x)= 1.6179273245695602
# differential_evolution step 913: f(x)= 1.6179273245695602
# differential_evolution step 914: f(x)= 1.6179273245695602
# differential_evolution step 915: f(x)= 1.6179273245695602
# differential_evolution step 916: f(x)= 1.6179273245695602
# differential_evolution step 917: f(x)= 1.6179273245695602
# differential_evolution step 918: f(x)= 1.6179273245695602
# differential_evolution step 919: f(x)= 1.6179273245695602
# differential_evolution step 920: f(x)= 1.6179273245695602
# differential_evolution step 921: f(x)= 1.6179273245695602
# differential_evolution step 922: f(x)= 1.6179273245695602
# differential_evolution step 923: f(x)= 1.6179273245695602
# differential_evolution step 924: f(x)= 1.6179273245695602
# differential_evolution step 925: f(x)= 1.6179273245695602
# differential_evolution step 926: f(x)= 1.6179273245695602
# differential_evolution step 927: f(x)= 1.6179273245695602
# differential_evolution step 928: f(x)= 1.6179273245695602
# differential_evolution step 929: f(x)= 1.6179273245695602
# differential_evolution step 930: f(x)= 1.6179273245695602
# differential_evolution step 931: f(x)= 1.6179273245695602
# differential_evolution step 932: f(x)= 1.6179273245695602
# differential_evolution step 933: f(x)= 1.6179273245695602
# differential_evolution step 934: f(x)= 1.6179273245695602
# differential_evolution step 935: f(x)= 1.6179273245695602
# differential_evolution step 936: f(x)= 1.6179273245695602
# differential_evolution step 937: f(x)= 1.6179273245695602
# differential_evolution step 938: f(x)= 1.6179273245695602
# differential_evolution step 939: f(x)= 1.6179273245695602
# differential_evolution step 940: f(x)= 1.6179273245695602
# differential_evolution step 941: f(x)= 1.6179273245695602
# differential_evolution step 942: f(x)= 1.6179273245695602
# differential_evolution step 943: f(x)= 1.6179273245695602
# differential_evolution step 944: f(x)= 1.6137379434392631
# differential_evolution step 945: f(x)= 1.6137379434392631
# differential_evolution step 946: f(x)= 1.6137379434392631
# differential_evolution step 947: f(x)= 1.6137379434392631
# differential_evolution step 948: f(x)= 1.6137379434392631
# differential_evolution step 949: f(x)= 1.6137379434392631
# differential_evolution step 950: f(x)= 1.6137379434392631
# differential_evolution step 951: f(x)= 1.6137379434392631
# differential_evolution step 952: f(x)= 1.6137379434392631
# differential_evolution step 953: f(x)= 1.6137379434392631
# differential_evolution step 954: f(x)= 1.6137379434392631
# differential_evolution step 955: f(x)= 1.6137379434392631
# differential_evolution step 956: f(x)= 1.6137379434392631
# differential_evolution step 957: f(x)= 1.6137379434392631
# differential_evolution step 958: f(x)= 1.6137379434392631
# differential_evolution step 959: f(x)= 1.6137379434392631
# differential_evolution step 960: f(x)= 1.6137379434392631
# differential_evolution step 961: f(x)= 1.6137379434392631
# differential_evolution step 962: f(x)= 1.6137379434392631
# differential_evolution step 963: f(x)= 1.6137379434392631
# differential_evolution step 964: f(x)= 1.6137379434392631
# differential_evolution step 965: f(x)= 1.6137379434392631
# differential_evolution step 966: f(x)= 1.6137379434392631
# differential_evolution step 967: f(x)= 1.6137379434392631
# differential_evolution step 968: f(x)= 1.6137379434392631
# differential_evolution step 969: f(x)= 1.6137379434392631
# differential_evolution step 970: f(x)= 1.6137379434392631
# differential_evolution step 971: f(x)= 1.6109475643378959
# differential_evolution step 972: f(x)= 1.6109475643378959
# differential_evolution step 973: f(x)= 1.6109475643378959
# differential_evolution step 974: f(x)= 1.6109475643378959
# differential_evolution step 975: f(x)= 1.6109475643378959
# differential_evolution step 976: f(x)= 1.6109475643378959
# differential_evolution step 977: f(x)= 1.6109475643378959
# differential_evolution step 978: f(x)= 1.6109475643378959
# differential_evolution step 979: f(x)= 1.6109475643378959
# differential_evolution step 980: f(x)= 1.6109475643378959
# differential_evolution step 981: f(x)= 1.6109475643378959
# differential_evolution step 982: f(x)= 1.6109475643378959
# differential_evolution step 983: f(x)= 1.6109475643378959
# differential_evolution step 984: f(x)= 1.6109475643378959
# differential_evolution step 985: f(x)= 1.6109475643378959
# differential_evolution step 986: f(x)= 1.6109475643378959
# differential_evolution step 987: f(x)= 1.6109475643378959
# differential_evolution step 988: f(x)= 1.6109475643378959
# differential_evolution step 989: f(x)= 1.6109475643378959
# differential_evolution step 990: f(x)= 1.6109475643378959
# differential_evolution step 991: f(x)= 1.6109475643378959
# differential_evolution step 992: f(x)= 1.6109475643378959
# differential_evolution step 993: f(x)= 1.6109475643378959
# differential_evolution step 994: f(x)= 1.6109475643378959
# differential_evolution step 995: f(x)= 1.6109475643378959
# differential_evolution step 996: f(x)= 1.6109475643378959
# differential_evolution step 997: f(x)= 1.6109475643378959
# differential_evolution step 998: f(x)= 1.6109475643378959
# differential_evolution step 999: f(x)= 1.6109475643378959
# differential_evolution step 1000: f(x)= 1.6109475643378959
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [8.01820865e-01 6.54851396e+00 1.10818051e+00 2.70254667e+01
#  3.00224701e-01 1.72167757e+01 1.27107814e-01 4.69101183e+01
#  2.62282033e-02 2.18201842e+01 2.15069977e+00 7.34620890e+01
#  1.81328117e+00 3.10827258e+00 5.74075984e-01 4.83312256e+01
#  4.48132769e-01 6.32741979e+00 8.06889736e-01 5.50024605e+01
#  1.01122743e+00 1.48395416e+00 5.13104067e-01 7.00154554e+01]
# Chi quadro minimo: 1.6109475643378959

# %%
# Plots:
params_curve_6, covariance_6 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params6, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[5], red_chi[5] = save_params(params_curve_6, covariance_6, radial_profile_HA, radial_profile_error_HA, x_axes, 6, line_name="Six", output_prefix="fit")

aic[5] = AIC(x_axes, radial_profile_HA, chi_quadr[5], params_curve_6)
bic[5] = BIC(x_axes, radial_profile_HA, chi_quadr[5], params_curve_6)
print(aic[5], chi_quadr[5], bic[5], len(best_params6))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_6)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[16:20]),  linestyle='--', label='Sérsic 5')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[20:24]),  linestyle='--', label='Sérsic 6')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)

plt.savefig('AIC_6', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_10724\111436280.py:9: RuntimeWarning: overflow encountered in exp
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_10724\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_10724\3123596373.py:12: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.6807, r_e=7.0877, n=1.2117, x_0=27.0234
# Sérsic 2: I_e=0.0327, r_e=21.0147, n=0.0281, x_0=44.0513
# Sérsic 3: I_e=0.1501, r_e=8.7956, n=1.4487, x_0=70.9051
# Sérsic 4: I_e=1.3288, r_e=2.1253, n=0.7300, x_0=47.7052
# Sérsic 5: I_e=0.6665, r_e=6.7578, n=0.8640, x_0=52.0214
# Sérsic 6: I_e=0.0993, r_e=2.9503, n=2.0441, x_0=69.5649
# [5.50965817e-02 2.97131910e-01 5.61159324e-02 7.93131895e-02
#  1.88604525e-01 9.42165964e-01 3.30163173e-02 5.74606720e-01
#  1.91485618e-01 1.71169574e+00 5.26084478e-01 6.79209920e-01
#  2.53481987e-01 2.96640904e-01 1.36112870e-01 1.05062399e-01
#  1.88712625e-01 1.51720471e+00 1.73204603e-01 4.13889884e-01
#  1.61223073e+00 3.45886716e+01 2.03410649e+01 8.04811692e-02]
# 15.243345209504918
# 79.24334520950492 15.243345209504918 125.76742967321913 24
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20]) +
        sersic_1d(x_hr, *params[20:24]) +
        sersic_1d(x_hr, *params[24:28])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =[
     (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (25, 35),   # x_0: posizione da 0 a 100

    (0, 10),
    (0, 50),
    (0.1, 10),
    (40, 50),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (65, 75),

    (0, 10),
    (0, 50),
    (0.1, 10),
    (45, 55), 

    (0, 10),
    (0, 50),
    (0.1, 10),
    (55, 65),   # x_0: posizione da 0 a 100

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100),   # x_0: posizione da 0 a 100

    (0, 10),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100)
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params7 = result.x

print("Optimize parameters with differential_evolution:", best_params7)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 293170.69578386913
# differential_evolution step 2: f(x)= 140766.88264954972
# differential_evolution step 3: f(x)= 64781.88336032384
# differential_evolution step 4: f(x)= 64781.88336032384
# differential_evolution step 5: f(x)= 64781.88336032384
# differential_evolution step 6: f(x)= 64781.88336032384
# differential_evolution step 7: f(x)= 39968.99184454725
# differential_evolution step 8: f(x)= 39968.99184454725
# differential_evolution step 9: f(x)= 39968.99184454725
# differential_evolution step 10: f(x)= 19738.380732775313
# differential_evolution step 11: f(x)= 19738.380732775313
# differential_evolution step 12: f(x)= 19738.380732775313
# differential_evolution step 13: f(x)= 11777.514457937243
# differential_evolution step 14: f(x)= 11777.514457937243
# differential_evolution step 15: f(x)= 4265.7776348208945
# differential_evolution step 16: f(x)= 4265.7776348208945
# differential_evolution step 17: f(x)= 2841.4457763002097
# differential_evolution step 18: f(x)= 2841.4457763002097
# differential_evolution step 19: f(x)= 2841.4457763002097
# differential_evolution step 20: f(x)= 2841.4457763002097
# differential_evolution step 21: f(x)= 2841.4457763002097
# differential_evolution step 22: f(x)= 2841.4457763002097
# differential_evolution step 23: f(x)= 2841.4457763002097
# differential_evolution step 24: f(x)= 2841.4457763002097
# differential_evolution step 25: f(x)= 1438.697937030726
# differential_evolution step 26: f(x)= 1438.697937030726
# differential_evolution step 27: f(x)= 1438.697937030726
# differential_evolution step 28: f(x)= 1438.697937030726
# differential_evolution step 29: f(x)= 1438.697937030726
# differential_evolution step 30: f(x)= 1438.697937030726
# differential_evolution step 31: f(x)= 1438.697937030726
# differential_evolution step 32: f(x)= 1438.697937030726
# differential_evolution step 33: f(x)= 1438.697937030726
# differential_evolution step 34: f(x)= 1438.697937030726
# differential_evolution step 35: f(x)= 1438.697937030726
# differential_evolution step 36: f(x)= 1438.697937030726
# differential_evolution step 37: f(x)= 1438.697937030726
# differential_evolution step 38: f(x)= 1438.697937030726
# differential_evolution step 39: f(x)= 1438.697937030726
# differential_evolution step 40: f(x)= 1438.697937030726
# differential_evolution step 41: f(x)= 1438.697937030726
# differential_evolution step 42: f(x)= 1438.697937030726
# differential_evolution step 43: f(x)= 1438.697937030726
# differential_evolution step 44: f(x)= 1124.1597360541925
# differential_evolution step 45: f(x)= 547.8136245049724
# differential_evolution step 46: f(x)= 547.8136245049724
# differential_evolution step 47: f(x)= 547.8136245049724
# differential_evolution step 48: f(x)= 547.8136245049724
# differential_evolution step 49: f(x)= 547.8136245049724
# differential_evolution step 50: f(x)= 547.8136245049724
# differential_evolution step 51: f(x)= 547.8136245049724
# differential_evolution step 52: f(x)= 547.8136245049724
# differential_evolution step 53: f(x)= 547.8136245049724
# differential_evolution step 54: f(x)= 547.8136245049724
# differential_evolution step 55: f(x)= 225.1086540774294
# differential_evolution step 56: f(x)= 225.1086540774294
# differential_evolution step 57: f(x)= 189.88739007407375
# differential_evolution step 58: f(x)= 189.88739007407375
# differential_evolution step 59: f(x)= 189.88739007407375
# differential_evolution step 60: f(x)= 189.88739007407375
# differential_evolution step 61: f(x)= 189.88739007407375
# differential_evolution step 62: f(x)= 189.88739007407375
# differential_evolution step 63: f(x)= 189.88739007407375
# differential_evolution step 64: f(x)= 189.88739007407375
# differential_evolution step 65: f(x)= 189.88739007407375
# differential_evolution step 66: f(x)= 189.88739007407375
# differential_evolution step 67: f(x)= 189.88739007407375
# differential_evolution step 68: f(x)= 189.88739007407375
# differential_evolution step 69: f(x)= 189.88739007407375
# differential_evolution step 70: f(x)= 111.92214218947582
# differential_evolution step 71: f(x)= 111.92214218947582
# differential_evolution step 72: f(x)= 111.92214218947582
# differential_evolution step 73: f(x)= 111.92214218947582
# differential_evolution step 74: f(x)= 111.92214218947582
# differential_evolution step 75: f(x)= 111.92214218947582
# differential_evolution step 76: f(x)= 111.92214218947582
# differential_evolution step 77: f(x)= 111.92214218947582
# differential_evolution step 78: f(x)= 111.92214218947582
# differential_evolution step 79: f(x)= 111.92214218947582
# differential_evolution step 80: f(x)= 111.92214218947582
# differential_evolution step 81: f(x)= 111.92214218947582
# differential_evolution step 82: f(x)= 111.92214218947582
# differential_evolution step 83: f(x)= 111.92214218947582
# differential_evolution step 84: f(x)= 111.92214218947582
# differential_evolution step 85: f(x)= 111.92214218947582
# differential_evolution step 86: f(x)= 111.92214218947582
# differential_evolution step 87: f(x)= 111.92214218947582
# differential_evolution step 88: f(x)= 111.92214218947582
# differential_evolution step 89: f(x)= 111.92214218947582
# differential_evolution step 90: f(x)= 111.92214218947582
# differential_evolution step 91: f(x)= 111.92214218947582
# differential_evolution step 92: f(x)= 111.92214218947582
# differential_evolution step 93: f(x)= 111.92214218947582
# differential_evolution step 94: f(x)= 111.92214218947582
# differential_evolution step 95: f(x)= 111.92214218947582
# differential_evolution step 96: f(x)= 111.92214218947582
# differential_evolution step 97: f(x)= 111.92214218947582
# differential_evolution step 98: f(x)= 111.92214218947582
# differential_evolution step 99: f(x)= 111.92214218947582
# differential_evolution step 100: f(x)= 111.92214218947582
# differential_evolution step 101: f(x)= 111.92214218947582
# differential_evolution step 102: f(x)= 98.52578171122744
# differential_evolution step 103: f(x)= 85.57276992474773
# differential_evolution step 104: f(x)= 85.57276992474773
# differential_evolution step 105: f(x)= 85.57276992474773
# differential_evolution step 106: f(x)= 76.48018676949006
# differential_evolution step 107: f(x)= 76.48018676949006
# differential_evolution step 108: f(x)= 76.48018676949006
# differential_evolution step 109: f(x)= 76.48018676949006
# differential_evolution step 110: f(x)= 57.60141733714484
# differential_evolution step 111: f(x)= 57.60141733714484
# differential_evolution step 112: f(x)= 57.60141733714484
# differential_evolution step 113: f(x)= 57.60141733714484
# differential_evolution step 114: f(x)= 57.60141733714484
# differential_evolution step 115: f(x)= 57.60141733714484
# differential_evolution step 116: f(x)= 57.60141733714484
# differential_evolution step 117: f(x)= 57.60141733714484
# differential_evolution step 118: f(x)= 57.60141733714484
# differential_evolution step 119: f(x)= 57.60141733714484
# differential_evolution step 120: f(x)= 57.60141733714484
# differential_evolution step 121: f(x)= 57.60141733714484
# differential_evolution step 122: f(x)= 57.60141733714484
# differential_evolution step 123: f(x)= 57.60141733714484
# differential_evolution step 124: f(x)= 57.60141733714484
# differential_evolution step 125: f(x)= 52.086820035884564
# differential_evolution step 126: f(x)= 36.44309093477779
# differential_evolution step 127: f(x)= 36.44309093477779
# differential_evolution step 128: f(x)= 36.44309093477779
# differential_evolution step 129: f(x)= 36.44309093477779
# differential_evolution step 130: f(x)= 36.44309093477779
# differential_evolution step 131: f(x)= 36.44309093477779
# differential_evolution step 132: f(x)= 36.44309093477779
# differential_evolution step 133: f(x)= 36.44309093477779
# differential_evolution step 134: f(x)= 36.44309093477779
# differential_evolution step 135: f(x)= 36.44309093477779
# differential_evolution step 136: f(x)= 36.44309093477779
# differential_evolution step 137: f(x)= 36.44309093477779
# differential_evolution step 138: f(x)= 36.44309093477779
# differential_evolution step 139: f(x)= 36.44309093477779
# differential_evolution step 140: f(x)= 36.44309093477779
# differential_evolution step 141: f(x)= 36.44309093477779
# differential_evolution step 142: f(x)= 36.44309093477779
# differential_evolution step 143: f(x)= 36.44309093477779
# differential_evolution step 144: f(x)= 36.44309093477779
# differential_evolution step 145: f(x)= 36.44309093477779
# differential_evolution step 146: f(x)= 36.44309093477779
# differential_evolution step 147: f(x)= 36.44309093477779
# differential_evolution step 148: f(x)= 36.44309093477779
# differential_evolution step 149: f(x)= 36.44309093477779
# differential_evolution step 150: f(x)= 36.44309093477779
# differential_evolution step 151: f(x)= 36.44309093477779
# differential_evolution step 152: f(x)= 36.44309093477779
# differential_evolution step 153: f(x)= 36.44309093477779
# differential_evolution step 154: f(x)= 36.44309093477779
# differential_evolution step 155: f(x)= 36.44309093477779
# differential_evolution step 156: f(x)= 36.44309093477779
# differential_evolution step 157: f(x)= 36.44309093477779
# differential_evolution step 158: f(x)= 36.44309093477779
# differential_evolution step 159: f(x)= 36.44309093477779
# differential_evolution step 160: f(x)= 36.44309093477779
# differential_evolution step 161: f(x)= 34.28668466805393
# differential_evolution step 162: f(x)= 34.28668466805393
# differential_evolution step 163: f(x)= 34.28668466805393
# differential_evolution step 164: f(x)= 34.28668466805393
# differential_evolution step 165: f(x)= 34.28668466805393
# differential_evolution step 166: f(x)= 16.83969346765877
# differential_evolution step 167: f(x)= 16.83969346765877
# differential_evolution step 168: f(x)= 16.83969346765877
# differential_evolution step 169: f(x)= 16.83969346765877
# differential_evolution step 170: f(x)= 16.83969346765877
# differential_evolution step 171: f(x)= 16.83969346765877
# differential_evolution step 172: f(x)= 16.83969346765877
# differential_evolution step 173: f(x)= 16.83969346765877
# differential_evolution step 174: f(x)= 16.83969346765877
# differential_evolution step 175: f(x)= 16.83969346765877
# differential_evolution step 176: f(x)= 16.83969346765877
# differential_evolution step 177: f(x)= 16.83969346765877
# differential_evolution step 178: f(x)= 16.83969346765877
# differential_evolution step 179: f(x)= 16.83969346765877
# differential_evolution step 180: f(x)= 16.83969346765877
# differential_evolution step 181: f(x)= 16.83969346765877
# differential_evolution step 182: f(x)= 16.83969346765877
# differential_evolution step 183: f(x)= 16.83969346765877
# differential_evolution step 184: f(x)= 16.83969346765877
# differential_evolution step 185: f(x)= 16.83969346765877
# differential_evolution step 186: f(x)= 16.83969346765877
# differential_evolution step 187: f(x)= 16.83969346765877
# differential_evolution step 188: f(x)= 16.83969346765877
# differential_evolution step 189: f(x)= 16.83969346765877
# differential_evolution step 190: f(x)= 16.83969346765877
# differential_evolution step 191: f(x)= 16.83969346765877
# differential_evolution step 192: f(x)= 16.83969346765877
# differential_evolution step 193: f(x)= 16.83969346765877
# differential_evolution step 194: f(x)= 16.83969346765877
# differential_evolution step 195: f(x)= 16.83969346765877
# differential_evolution step 196: f(x)= 16.83969346765877
# differential_evolution step 197: f(x)= 16.83969346765877
# differential_evolution step 198: f(x)= 16.83969346765877
# differential_evolution step 199: f(x)= 16.83969346765877
# differential_evolution step 200: f(x)= 16.83969346765877
# differential_evolution step 201: f(x)= 16.83969346765877
# differential_evolution step 202: f(x)= 16.83969346765877
# differential_evolution step 203: f(x)= 16.83969346765877
# differential_evolution step 204: f(x)= 16.83969346765877
# differential_evolution step 205: f(x)= 16.83969346765877
# differential_evolution step 206: f(x)= 16.83969346765877
# differential_evolution step 207: f(x)= 16.83969346765877
# differential_evolution step 208: f(x)= 16.83969346765877
# differential_evolution step 209: f(x)= 16.83969346765877
# differential_evolution step 210: f(x)= 16.83969346765877
# differential_evolution step 211: f(x)= 16.83969346765877
# differential_evolution step 212: f(x)= 16.83969346765877
# differential_evolution step 213: f(x)= 16.83969346765877
# differential_evolution step 214: f(x)= 16.83969346765877
# differential_evolution step 215: f(x)= 16.83969346765877
# differential_evolution step 216: f(x)= 16.83969346765877
# differential_evolution step 217: f(x)= 16.83969346765877
# differential_evolution step 218: f(x)= 16.83969346765877
# differential_evolution step 219: f(x)= 16.83969346765877
# differential_evolution step 220: f(x)= 16.83969346765877
# differential_evolution step 221: f(x)= 10.622833825673213
# differential_evolution step 222: f(x)= 10.622833825673213
# differential_evolution step 223: f(x)= 10.622833825673213
# differential_evolution step 224: f(x)= 10.622833825673213
# differential_evolution step 225: f(x)= 10.622833825673213
# differential_evolution step 226: f(x)= 10.622833825673213
# differential_evolution step 227: f(x)= 10.622833825673213
# differential_evolution step 228: f(x)= 10.622833825673213
# differential_evolution step 229: f(x)= 10.622833825673213
# differential_evolution step 230: f(x)= 10.622833825673213
# differential_evolution step 231: f(x)= 8.486749182363193
# differential_evolution step 232: f(x)= 8.486749182363193
# differential_evolution step 233: f(x)= 8.486749182363193
# differential_evolution step 234: f(x)= 8.486749182363193
# differential_evolution step 235: f(x)= 8.486749182363193
# differential_evolution step 236: f(x)= 8.486749182363193
# differential_evolution step 237: f(x)= 8.486749182363193
# differential_evolution step 238: f(x)= 8.486749182363193
# differential_evolution step 239: f(x)= 7.207704335085306
# differential_evolution step 240: f(x)= 7.207704335085306
# differential_evolution step 241: f(x)= 7.207704335085306
# differential_evolution step 242: f(x)= 7.207704335085306
# differential_evolution step 243: f(x)= 7.207704335085306
# differential_evolution step 244: f(x)= 7.207704335085306
# differential_evolution step 245: f(x)= 7.207704335085306
# differential_evolution step 246: f(x)= 7.207704335085306
# differential_evolution step 247: f(x)= 7.207704335085306
# differential_evolution step 248: f(x)= 7.207704335085306
# differential_evolution step 249: f(x)= 7.207704335085306
# differential_evolution step 250: f(x)= 7.207704335085306
# differential_evolution step 251: f(x)= 7.207704335085306
# differential_evolution step 252: f(x)= 7.207704335085306
# differential_evolution step 253: f(x)= 7.207704335085306
# differential_evolution step 254: f(x)= 7.207704335085306
# differential_evolution step 255: f(x)= 7.207704335085306
# differential_evolution step 256: f(x)= 7.207704335085306
# differential_evolution step 257: f(x)= 7.207704335085306
# differential_evolution step 258: f(x)= 7.207704335085306
# differential_evolution step 259: f(x)= 7.207704335085306
# differential_evolution step 260: f(x)= 5.625871365744785
# differential_evolution step 261: f(x)= 5.625871365744785
# differential_evolution step 262: f(x)= 5.625871365744785
# differential_evolution step 263: f(x)= 5.625871365744785
# differential_evolution step 264: f(x)= 5.625871365744785
# differential_evolution step 265: f(x)= 5.625871365744785
# differential_evolution step 266: f(x)= 5.625871365744785
# differential_evolution step 267: f(x)= 5.625871365744785
# differential_evolution step 268: f(x)= 5.625871365744785
# differential_evolution step 269: f(x)= 5.625871365744785
# differential_evolution step 270: f(x)= 4.163280585955291
# differential_evolution step 271: f(x)= 4.163280585955291
# differential_evolution step 272: f(x)= 4.163280585955291
# differential_evolution step 273: f(x)= 4.163280585955291
# differential_evolution step 274: f(x)= 4.163280585955291
# differential_evolution step 275: f(x)= 4.163280585955291
# differential_evolution step 276: f(x)= 4.163280585955291
# differential_evolution step 277: f(x)= 4.163280585955291
# differential_evolution step 278: f(x)= 4.163280585955291
# differential_evolution step 279: f(x)= 4.163280585955291
# differential_evolution step 280: f(x)= 4.163280585955291
# differential_evolution step 281: f(x)= 4.163280585955291
# differential_evolution step 282: f(x)= 4.163280585955291
# differential_evolution step 283: f(x)= 4.163280585955291
# differential_evolution step 284: f(x)= 4.163280585955291
# differential_evolution step 285: f(x)= 4.163280585955291
# differential_evolution step 286: f(x)= 3.877079659980671
# differential_evolution step 287: f(x)= 3.1267568317129704
# differential_evolution step 288: f(x)= 3.1267568317129704
# differential_evolution step 289: f(x)= 3.1267568317129704
# differential_evolution step 290: f(x)= 3.1267568317129704
# differential_evolution step 291: f(x)= 3.1267568317129704
# differential_evolution step 292: f(x)= 3.1267568317129704
# differential_evolution step 293: f(x)= 3.1267568317129704
# differential_evolution step 294: f(x)= 3.1267568317129704
# differential_evolution step 295: f(x)= 3.1267568317129704
# differential_evolution step 296: f(x)= 3.1267568317129704
# differential_evolution step 297: f(x)= 3.117340297631027
# differential_evolution step 298: f(x)= 3.117340297631027
# differential_evolution step 299: f(x)= 2.737046730663762
# differential_evolution step 300: f(x)= 2.737046730663762
# differential_evolution step 301: f(x)= 2.737046730663762
# differential_evolution step 302: f(x)= 2.582177382763038
# differential_evolution step 303: f(x)= 1.7011180381666842
# differential_evolution step 304: f(x)= 1.7011180381666842
# differential_evolution step 305: f(x)= 1.7011180381666842
# differential_evolution step 306: f(x)= 1.7011180381666842
# differential_evolution step 307: f(x)= 1.7011180381666842
# differential_evolution step 308: f(x)= 1.7011180381666842
# differential_evolution step 309: f(x)= 1.7011180381666842
# differential_evolution step 310: f(x)= 1.7011180381666842
# differential_evolution step 311: f(x)= 1.7011180381666842
# differential_evolution step 312: f(x)= 1.7011180381666842
# differential_evolution step 313: f(x)= 1.7011180381666842
# differential_evolution step 314: f(x)= 1.7011180381666842
# differential_evolution step 315: f(x)= 1.4947407521978917
# differential_evolution step 316: f(x)= 1.4947407521978917
# differential_evolution step 317: f(x)= 1.4947407521978917
# differential_evolution step 318: f(x)= 1.4947407521978917
# differential_evolution step 319: f(x)= 1.4947407521978917
# differential_evolution step 320: f(x)= 1.4947407521978917
# differential_evolution step 321: f(x)= 1.4947407521978917
# differential_evolution step 322: f(x)= 1.4947407521978917
# differential_evolution step 323: f(x)= 1.4947407521978917
# differential_evolution step 324: f(x)= 1.4947407521978917
# differential_evolution step 325: f(x)= 1.4947407521978917
# differential_evolution step 326: f(x)= 1.4947407521978917
# differential_evolution step 327: f(x)= 1.4947407521978917
# differential_evolution step 328: f(x)= 1.4947407521978917
# differential_evolution step 329: f(x)= 1.4947407521978917
# differential_evolution step 330: f(x)= 1.4947407521978917
# differential_evolution step 331: f(x)= 1.4947407521978917
# differential_evolution step 332: f(x)= 1.4947407521978917
# differential_evolution step 333: f(x)= 1.4947407521978917
# differential_evolution step 334: f(x)= 1.4947407521978917
# differential_evolution step 335: f(x)= 1.4947407521978917
# differential_evolution step 336: f(x)= 1.449623526390123
# differential_evolution step 337: f(x)= 1.449623526390123
# differential_evolution step 338: f(x)= 1.449623526390123
# differential_evolution step 339: f(x)= 1.449623526390123
# differential_evolution step 340: f(x)= 1.38471145422288
# differential_evolution step 341: f(x)= 1.338622595280379
# differential_evolution step 342: f(x)= 1.3155021578397084
# differential_evolution step 343: f(x)= 1.3155021578397084
# differential_evolution step 344: f(x)= 1.3155021578397084
# differential_evolution step 345: f(x)= 1.3155021578397084
# differential_evolution step 346: f(x)= 1.3155021578397084
# differential_evolution step 347: f(x)= 1.3155021578397084
# differential_evolution step 348: f(x)= 1.3155021578397084
# differential_evolution step 349: f(x)= 1.3155021578397084
# differential_evolution step 350: f(x)= 1.3155021578397084
# differential_evolution step 351: f(x)= 1.3155021578397084
# differential_evolution step 352: f(x)= 1.3155021578397084
# differential_evolution step 353: f(x)= 1.25479890137835
# differential_evolution step 354: f(x)= 1.25479890137835
# differential_evolution step 355: f(x)= 1.25479890137835
# differential_evolution step 356: f(x)= 1.25479890137835
# differential_evolution step 357: f(x)= 1.25479890137835
# differential_evolution step 358: f(x)= 1.25479890137835
# differential_evolution step 359: f(x)= 1.25479890137835
# differential_evolution step 360: f(x)= 1.1267125933657074
# differential_evolution step 361: f(x)= 1.1267125933657074
# differential_evolution step 362: f(x)= 1.1267125933657074
# differential_evolution step 363: f(x)= 1.1267125933657074
# differential_evolution step 364: f(x)= 1.1267125933657074
# differential_evolution step 365: f(x)= 1.1267125933657074
# differential_evolution step 366: f(x)= 1.1267125933657074
# differential_evolution step 367: f(x)= 1.063657057251994
# differential_evolution step 368: f(x)= 1.063657057251994
# differential_evolution step 369: f(x)= 1.063657057251994
# differential_evolution step 370: f(x)= 0.9995659366824924
# differential_evolution step 371: f(x)= 0.9995659366824924
# differential_evolution step 372: f(x)= 0.9125667558913945
# differential_evolution step 373: f(x)= 0.9125667558913945
# differential_evolution step 374: f(x)= 0.9125667558913945
# differential_evolution step 375: f(x)= 0.9125667558913945
# differential_evolution step 376: f(x)= 0.9125667558913945
# differential_evolution step 377: f(x)= 0.9125667558913945
# differential_evolution step 378: f(x)= 0.9125667558913945
# differential_evolution step 379: f(x)= 0.9125667558913945
# differential_evolution step 380: f(x)= 0.9125667558913945
# differential_evolution step 381: f(x)= 0.9125667558913945
# differential_evolution step 382: f(x)= 0.9125667558913945
# differential_evolution step 383: f(x)= 0.9125667558913945
# differential_evolution step 384: f(x)= 0.9125667558913945
# differential_evolution step 385: f(x)= 0.9125667558913945
# differential_evolution step 386: f(x)= 0.9125667558913945
# differential_evolution step 387: f(x)= 0.9125667558913945
# differential_evolution step 388: f(x)= 0.9125667558913945
# differential_evolution step 389: f(x)= 0.9125667558913945
# differential_evolution step 390: f(x)= 0.9125667558913945
# differential_evolution step 391: f(x)= 0.8897699625377081
# differential_evolution step 392: f(x)= 0.8897699625377081
# differential_evolution step 393: f(x)= 0.8897699625377081
# differential_evolution step 394: f(x)= 0.8622039675561345
# differential_evolution step 395: f(x)= 0.8622039675561345
# differential_evolution step 396: f(x)= 0.8622039675561345
# differential_evolution step 397: f(x)= 0.8622039675561345
# differential_evolution step 398: f(x)= 0.8622039675561345
# differential_evolution step 399: f(x)= 0.8622039675561345
# differential_evolution step 400: f(x)= 0.8622039675561345
# differential_evolution step 401: f(x)= 0.8622039675561345
# differential_evolution step 402: f(x)= 0.8622039675561345
# differential_evolution step 403: f(x)= 0.8622039675561345
# differential_evolution step 404: f(x)= 0.8622039675561345
# differential_evolution step 405: f(x)= 0.8622039675561345
# differential_evolution step 406: f(x)= 0.8622039675561345
# differential_evolution step 407: f(x)= 0.8622039675561345
# differential_evolution step 408: f(x)= 0.8622039675561345
# differential_evolution step 409: f(x)= 0.8622039675561345
# differential_evolution step 410: f(x)= 0.8622039675561345
# differential_evolution step 411: f(x)= 0.8534509815079887
# differential_evolution step 412: f(x)= 0.8534509815079887
# differential_evolution step 413: f(x)= 0.8534509815079887
# differential_evolution step 414: f(x)= 0.8534509815079887
# differential_evolution step 415: f(x)= 0.8534509815079887
# differential_evolution step 416: f(x)= 0.8534509815079887
# differential_evolution step 417: f(x)= 0.7254957617643721
# differential_evolution step 418: f(x)= 0.7254957617643721
# differential_evolution step 419: f(x)= 0.7254957617643721
# differential_evolution step 420: f(x)= 0.7254957617643721
# differential_evolution step 421: f(x)= 0.7254957617643721
# differential_evolution step 422: f(x)= 0.7254957617643721
# differential_evolution step 423: f(x)= 0.7254957617643721
# differential_evolution step 424: f(x)= 0.7254957617643721
# differential_evolution step 425: f(x)= 0.7254957617643721
# differential_evolution step 426: f(x)= 0.7254957617643721
# differential_evolution step 427: f(x)= 0.7254957617643721
# differential_evolution step 428: f(x)= 0.7254957617643721
# differential_evolution step 429: f(x)= 0.7254957617643721
# differential_evolution step 430: f(x)= 0.7254957617643721
# differential_evolution step 431: f(x)= 0.7254957617643721
# differential_evolution step 432: f(x)= 0.7254957617643721
# differential_evolution step 433: f(x)= 0.7254957617643721
# differential_evolution step 434: f(x)= 0.7254957617643721
# differential_evolution step 435: f(x)= 0.7254957617643721
# differential_evolution step 436: f(x)= 0.7254957617643721
# differential_evolution step 437: f(x)= 0.7254957617643721
# differential_evolution step 438: f(x)= 0.7254957617643721
# differential_evolution step 439: f(x)= 0.7254957617643721
# differential_evolution step 440: f(x)= 0.7254957617643721
# differential_evolution step 441: f(x)= 0.7254957617643721
# differential_evolution step 442: f(x)= 0.7254957617643721
# differential_evolution step 443: f(x)= 0.7254957617643721
# differential_evolution step 444: f(x)= 0.7254957617643721
# differential_evolution step 445: f(x)= 0.7254957617643721
# differential_evolution step 446: f(x)= 0.7254957617643721
# differential_evolution step 447: f(x)= 0.7254957617643721
# differential_evolution step 448: f(x)= 0.7254957617643721
# differential_evolution step 449: f(x)= 0.7254957617643721
# differential_evolution step 450: f(x)= 0.7254957617643721
# differential_evolution step 451: f(x)= 0.7254957617643721
# differential_evolution step 452: f(x)= 0.6728799065356952
# differential_evolution step 453: f(x)= 0.6728799065356952
# differential_evolution step 454: f(x)= 0.6728799065356952
# differential_evolution step 455: f(x)= 0.6728799065356952
# differential_evolution step 456: f(x)= 0.6728799065356952
# differential_evolution step 457: f(x)= 0.6728799065356952
# differential_evolution step 458: f(x)= 0.6728799065356952
# differential_evolution step 459: f(x)= 0.6728799065356952
# differential_evolution step 460: f(x)= 0.6728799065356952
# differential_evolution step 461: f(x)= 0.6617676155626631
# differential_evolution step 462: f(x)= 0.6617676155626631
# differential_evolution step 463: f(x)= 0.6617676155626631
# differential_evolution step 464: f(x)= 0.6617676155626631
# differential_evolution step 465: f(x)= 0.6617676155626631
# differential_evolution step 466: f(x)= 0.6617676155626631
# differential_evolution step 467: f(x)= 0.6617676155626631
# differential_evolution step 468: f(x)= 0.6617676155626631
# differential_evolution step 469: f(x)= 0.6617676155626631
# differential_evolution step 470: f(x)= 0.6617676155626631
# differential_evolution step 471: f(x)= 0.6617676155626631
# differential_evolution step 472: f(x)= 0.6617676155626631
# differential_evolution step 473: f(x)= 0.6617676155626631
# differential_evolution step 474: f(x)= 0.6617676155626631
# differential_evolution step 475: f(x)= 0.6617676155626631
# differential_evolution step 476: f(x)= 0.6617676155626631
# differential_evolution step 477: f(x)= 0.6227324344488034
# differential_evolution step 478: f(x)= 0.6227324344488034
# differential_evolution step 479: f(x)= 0.6227324344488034
# differential_evolution step 480: f(x)= 0.6227324344488034
# differential_evolution step 481: f(x)= 0.6046822354877764
# differential_evolution step 482: f(x)= 0.6046822354877764
# differential_evolution step 483: f(x)= 0.6046822354877764
# differential_evolution step 484: f(x)= 0.6046822354877764
# differential_evolution step 485: f(x)= 0.6046822354877764
# differential_evolution step 486: f(x)= 0.6046822354877764
# differential_evolution step 487: f(x)= 0.6046822354877764
# differential_evolution step 488: f(x)= 0.6046822354877764
# differential_evolution step 489: f(x)= 0.5332027194851794
# differential_evolution step 490: f(x)= 0.5332027194851794
# differential_evolution step 491: f(x)= 0.5332027194851794
# differential_evolution step 492: f(x)= 0.5332027194851794
# differential_evolution step 493: f(x)= 0.5332027194851794
# differential_evolution step 494: f(x)= 0.5332027194851794
# differential_evolution step 495: f(x)= 0.5332027194851794
# differential_evolution step 496: f(x)= 0.5332027194851794
# differential_evolution step 497: f(x)= 0.5332027194851794
# differential_evolution step 498: f(x)= 0.5332027194851794
# differential_evolution step 499: f(x)= 0.5332027194851794
# differential_evolution step 500: f(x)= 0.5332027194851794
# differential_evolution step 501: f(x)= 0.5332027194851794
# differential_evolution step 502: f(x)= 0.5332027194851794
# differential_evolution step 503: f(x)= 0.5332027194851794
# differential_evolution step 504: f(x)= 0.5332027194851794
# differential_evolution step 505: f(x)= 0.5332027194851794
# differential_evolution step 506: f(x)= 0.5332027194851794
# differential_evolution step 507: f(x)= 0.5332027194851794
# differential_evolution step 508: f(x)= 0.5332027194851794
# differential_evolution step 509: f(x)= 0.5332027194851794
# differential_evolution step 510: f(x)= 0.5332027194851794
# differential_evolution step 511: f(x)= 0.5332027194851794
# differential_evolution step 512: f(x)= 0.5332027194851794
# differential_evolution step 513: f(x)= 0.5332027194851794
# differential_evolution step 514: f(x)= 0.5332027194851794
# differential_evolution step 515: f(x)= 0.5270679438826812
# differential_evolution step 516: f(x)= 0.5270679438826812
# differential_evolution step 517: f(x)= 0.5270679438826812
# differential_evolution step 518: f(x)= 0.5270679438826812
# differential_evolution step 519: f(x)= 0.5270679438826812
# differential_evolution step 520: f(x)= 0.5270679438826812
# differential_evolution step 521: f(x)= 0.5125248822519207
# differential_evolution step 522: f(x)= 0.5125248822519207
# differential_evolution step 523: f(x)= 0.5125248822519207
# differential_evolution step 524: f(x)= 0.5125248822519207
# differential_evolution step 525: f(x)= 0.5125248822519207
# differential_evolution step 526: f(x)= 0.5125248822519207
# differential_evolution step 527: f(x)= 0.5125248822519207
# differential_evolution step 528: f(x)= 0.5125248822519207
# differential_evolution step 529: f(x)= 0.5125248822519207
# differential_evolution step 530: f(x)= 0.4912186874938824
# differential_evolution step 531: f(x)= 0.4912186874938824
# differential_evolution step 532: f(x)= 0.4912186874938824
# differential_evolution step 533: f(x)= 0.4912186874938824
# differential_evolution step 534: f(x)= 0.4912186874938824
# differential_evolution step 535: f(x)= 0.4912186874938824
# differential_evolution step 536: f(x)= 0.4912186874938824
# differential_evolution step 537: f(x)= 0.4912186874938824
# differential_evolution step 538: f(x)= 0.4833621336387929
# differential_evolution step 539: f(x)= 0.4833621336387929
# differential_evolution step 540: f(x)= 0.4833621336387929
# differential_evolution step 541: f(x)= 0.4833621336387929
# differential_evolution step 542: f(x)= 0.4833621336387929
# differential_evolution step 543: f(x)= 0.4833621336387929
# differential_evolution step 544: f(x)= 0.46870300819481436
# differential_evolution step 545: f(x)= 0.46870300819481436
# differential_evolution step 546: f(x)= 0.46870300819481436
# differential_evolution step 547: f(x)= 0.46870300819481436
# differential_evolution step 548: f(x)= 0.46870300819481436
# differential_evolution step 549: f(x)= 0.46870300819481436
# differential_evolution step 550: f(x)= 0.46870300819481436
# differential_evolution step 551: f(x)= 0.46870300819481436
# differential_evolution step 552: f(x)= 0.46870300819481436
# differential_evolution step 553: f(x)= 0.46870300819481436
# differential_evolution step 554: f(x)= 0.46870300819481436
# differential_evolution step 555: f(x)= 0.46870300819481436
# differential_evolution step 556: f(x)= 0.46870300819481436
# differential_evolution step 557: f(x)= 0.46870300819481436
# differential_evolution step 558: f(x)= 0.46870300819481436
# differential_evolution step 559: f(x)= 0.46870300819481436
# differential_evolution step 560: f(x)= 0.46870300819481436
# differential_evolution step 561: f(x)= 0.46870300819481436
# differential_evolution step 562: f(x)= 0.46870300819481436
# differential_evolution step 563: f(x)= 0.46870300819481436
# differential_evolution step 564: f(x)= 0.4426976785551286
# differential_evolution step 565: f(x)= 0.4426976785551286
# differential_evolution step 566: f(x)= 0.4426976785551286
# differential_evolution step 567: f(x)= 0.4426976785551286
# differential_evolution step 568: f(x)= 0.4426976785551286
# differential_evolution step 569: f(x)= 0.4426976785551286
# differential_evolution step 570: f(x)= 0.4426976785551286
# differential_evolution step 571: f(x)= 0.4426976785551286
# differential_evolution step 572: f(x)= 0.4426976785551286
# differential_evolution step 573: f(x)= 0.44123193228613694
# differential_evolution step 574: f(x)= 0.44123193228613694
# differential_evolution step 575: f(x)= 0.44123193228613694
# differential_evolution step 576: f(x)= 0.44123193228613694
# differential_evolution step 577: f(x)= 0.44123193228613694
# differential_evolution step 578: f(x)= 0.44123193228613694
# differential_evolution step 579: f(x)= 0.44123193228613694
# differential_evolution step 580: f(x)= 0.44123193228613694
# differential_evolution step 581: f(x)= 0.44123193228613694
# differential_evolution step 582: f(x)= 0.44123193228613694
# differential_evolution step 583: f(x)= 0.44123193228613694
# differential_evolution step 584: f(x)= 0.44123193228613694
# differential_evolution step 585: f(x)= 0.44123193228613694
# differential_evolution step 586: f(x)= 0.44123193228613694
# differential_evolution step 587: f(x)= 0.44123193228613694
# differential_evolution step 588: f(x)= 0.44123193228613694
# differential_evolution step 589: f(x)= 0.44123193228613694
# differential_evolution step 590: f(x)= 0.44123193228613694
# differential_evolution step 591: f(x)= 0.44123193228613694
# differential_evolution step 592: f(x)= 0.44123193228613694
# differential_evolution step 593: f(x)= 0.44123193228613694
# differential_evolution step 594: f(x)= 0.44123193228613694
# differential_evolution step 595: f(x)= 0.44123193228613694
# differential_evolution step 596: f(x)= 0.44123193228613694
# differential_evolution step 597: f(x)= 0.44123193228613694
# differential_evolution step 598: f(x)= 0.44123193228613694
# differential_evolution step 599: f(x)= 0.44123193228613694
# differential_evolution step 600: f(x)= 0.44123193228613694
# differential_evolution step 601: f(x)= 0.44123193228613694
# differential_evolution step 602: f(x)= 0.44123193228613694
# differential_evolution step 603: f(x)= 0.44059553628183484
# differential_evolution step 604: f(x)= 0.44059553628183484
# differential_evolution step 605: f(x)= 0.44059553628183484
# differential_evolution step 606: f(x)= 0.44059553628183484
# differential_evolution step 607: f(x)= 0.44059553628183484
# differential_evolution step 608: f(x)= 0.44059553628183484
# differential_evolution step 609: f(x)= 0.44059553628183484
# differential_evolution step 610: f(x)= 0.44059553628183484
# differential_evolution step 611: f(x)= 0.44059553628183484
# differential_evolution step 612: f(x)= 0.4364224756883372
# differential_evolution step 613: f(x)= 0.4364224756883372
# differential_evolution step 614: f(x)= 0.4364224756883372
# differential_evolution step 615: f(x)= 0.4364224756883372
# differential_evolution step 616: f(x)= 0.4364224756883372
# differential_evolution step 617: f(x)= 0.4364224756883372
# differential_evolution step 618: f(x)= 0.4364224756883372
# differential_evolution step 619: f(x)= 0.43615665325090064
# differential_evolution step 620: f(x)= 0.43615665325090064
# differential_evolution step 621: f(x)= 0.43615665325090064
# differential_evolution step 622: f(x)= 0.4163099377605767
# differential_evolution step 623: f(x)= 0.4163099377605767
# differential_evolution step 624: f(x)= 0.4065369199206945
# differential_evolution step 625: f(x)= 0.4065369199206945
# differential_evolution step 626: f(x)= 0.4065369199206945
# differential_evolution step 627: f(x)= 0.4065369199206945
# differential_evolution step 628: f(x)= 0.4065369199206945
# differential_evolution step 629: f(x)= 0.4065369199206945
# differential_evolution step 630: f(x)= 0.4065369199206945
# differential_evolution step 631: f(x)= 0.4065369199206945
# differential_evolution step 632: f(x)= 0.4065369199206945
# differential_evolution step 633: f(x)= 0.4065369199206945
# differential_evolution step 634: f(x)= 0.4065369199206945
# differential_evolution step 635: f(x)= 0.4065369199206945
# differential_evolution step 636: f(x)= 0.4065369199206945
# differential_evolution step 637: f(x)= 0.4065369199206945
# differential_evolution step 638: f(x)= 0.4065369199206945
# differential_evolution step 639: f(x)= 0.4065369199206945
# differential_evolution step 640: f(x)= 0.4065369199206945
# differential_evolution step 641: f(x)= 0.4065369199206945
# differential_evolution step 642: f(x)= 0.4065369199206945
# differential_evolution step 643: f(x)= 0.4065369199206945
# differential_evolution step 644: f(x)= 0.4065369199206945
# differential_evolution step 645: f(x)= 0.4065369199206945
# differential_evolution step 646: f(x)= 0.4065369199206945
# differential_evolution step 647: f(x)= 0.4065369199206945
# differential_evolution step 648: f(x)= 0.4065369199206945
# differential_evolution step 649: f(x)= 0.4065369199206945
# differential_evolution step 650: f(x)= 0.4065369199206945
# differential_evolution step 651: f(x)= 0.4065369199206945
# differential_evolution step 652: f(x)= 0.4065369199206945
# differential_evolution step 653: f(x)= 0.4065369199206945
# differential_evolution step 654: f(x)= 0.4065369199206945
# differential_evolution step 655: f(x)= 0.4065369199206945
# differential_evolution step 656: f(x)= 0.4065369199206945
# differential_evolution step 657: f(x)= 0.4065369199206945
# differential_evolution step 658: f(x)= 0.4065369199206945
# differential_evolution step 659: f(x)= 0.3957930855564516
# differential_evolution step 660: f(x)= 0.3957930855564516
# differential_evolution step 661: f(x)= 0.3957930855564516
# differential_evolution step 662: f(x)= 0.3957930855564516
# differential_evolution step 663: f(x)= 0.3957930855564516
# differential_evolution step 664: f(x)= 0.3957930855564516
# differential_evolution step 665: f(x)= 0.3957930855564516
# differential_evolution step 666: f(x)= 0.3957930855564516
# differential_evolution step 667: f(x)= 0.3957930855564516
# differential_evolution step 668: f(x)= 0.3957930855564516
# differential_evolution step 669: f(x)= 0.3957930855564516
# differential_evolution step 670: f(x)= 0.3957930855564516
# differential_evolution step 671: f(x)= 0.3957930855564516
# differential_evolution step 672: f(x)= 0.3957930855564516
# differential_evolution step 673: f(x)= 0.3957930855564516
# differential_evolution step 674: f(x)= 0.3957930855564516
# differential_evolution step 675: f(x)= 0.3957930855564516
# differential_evolution step 676: f(x)= 0.3957930855564516
# differential_evolution step 677: f(x)= 0.3957930855564516
# differential_evolution step 678: f(x)= 0.3957930855564516
# differential_evolution step 679: f(x)= 0.3957930855564516
# differential_evolution step 680: f(x)= 0.3957930855564516
# differential_evolution step 681: f(x)= 0.3957930855564516
# differential_evolution step 682: f(x)= 0.3957930855564516
# differential_evolution step 683: f(x)= 0.3957930855564516
# differential_evolution step 684: f(x)= 0.3957930855564516
# differential_evolution step 685: f(x)= 0.3957930855564516
# differential_evolution step 686: f(x)= 0.3957930855564516
# differential_evolution step 687: f(x)= 0.3957930855564516
# differential_evolution step 688: f(x)= 0.3957930855564516
# differential_evolution step 689: f(x)= 0.3957930855564516
# differential_evolution step 690: f(x)= 0.3957930855564516
# differential_evolution step 691: f(x)= 0.3957930855564516
# differential_evolution step 692: f(x)= 0.3957930855564516
# differential_evolution step 693: f(x)= 0.3957930855564516
# differential_evolution step 694: f(x)= 0.3957930855564516
# differential_evolution step 695: f(x)= 0.3957930855564516
# differential_evolution step 696: f(x)= 0.3957930855564516
# differential_evolution step 697: f(x)= 0.3957930855564516
# differential_evolution step 698: f(x)= 0.3957930855564516
# differential_evolution step 699: f(x)= 0.3957930855564516
# differential_evolution step 700: f(x)= 0.3957930855564516
# differential_evolution step 701: f(x)= 0.3957930855564516
# differential_evolution step 702: f(x)= 0.3957930855564516
# differential_evolution step 703: f(x)= 0.3957930855564516
# differential_evolution step 704: f(x)= 0.3957930855564516
# differential_evolution step 705: f(x)= 0.3957930855564516
# differential_evolution step 706: f(x)= 0.3957930855564516
# differential_evolution step 707: f(x)= 0.3957930855564516
# differential_evolution step 708: f(x)= 0.3957930855564516
# differential_evolution step 709: f(x)= 0.3957930855564516
# differential_evolution step 710: f(x)= 0.3957930855564516
# differential_evolution step 711: f(x)= 0.3957930855564516
# differential_evolution step 712: f(x)= 0.3957930855564516
# differential_evolution step 713: f(x)= 0.3957930855564516
# differential_evolution step 714: f(x)= 0.3957930855564516
# differential_evolution step 715: f(x)= 0.3957930855564516
# differential_evolution step 716: f(x)= 0.3957930855564516
# differential_evolution step 717: f(x)= 0.3957930855564516
# differential_evolution step 718: f(x)= 0.3957930855564516
# differential_evolution step 719: f(x)= 0.3957930855564516
# differential_evolution step 720: f(x)= 0.3957930855564516
# differential_evolution step 721: f(x)= 0.39407874045897523
# differential_evolution step 722: f(x)= 0.39407874045897523
# differential_evolution step 723: f(x)= 0.39407874045897523
# differential_evolution step 724: f(x)= 0.38810292913829914
# differential_evolution step 725: f(x)= 0.38810292913829914
# differential_evolution step 726: f(x)= 0.38810292913829914
# differential_evolution step 727: f(x)= 0.38810292913829914
# differential_evolution step 728: f(x)= 0.38810292913829914
# differential_evolution step 729: f(x)= 0.3869150393921119
# differential_evolution step 730: f(x)= 0.38642666269603354
# differential_evolution step 731: f(x)= 0.38642666269603354
# differential_evolution step 732: f(x)= 0.38642666269603354
# differential_evolution step 733: f(x)= 0.38642666269603354
# differential_evolution step 734: f(x)= 0.38642666269603354
# differential_evolution step 735: f(x)= 0.38642666269603354
# differential_evolution step 736: f(x)= 0.38642666269603354
# differential_evolution step 737: f(x)= 0.38642666269603354
# differential_evolution step 738: f(x)= 0.38642666269603354
# differential_evolution step 739: f(x)= 0.38642666269603354
# differential_evolution step 740: f(x)= 0.38642666269603354
# differential_evolution step 741: f(x)= 0.38642666269603354
# differential_evolution step 742: f(x)= 0.38642666269603354
# differential_evolution step 743: f(x)= 0.38642666269603354
# differential_evolution step 744: f(x)= 0.38642666269603354
# differential_evolution step 745: f(x)= 0.38642666269603354
# differential_evolution step 746: f(x)= 0.38642666269603354
# differential_evolution step 747: f(x)= 0.38642666269603354
# differential_evolution step 748: f(x)= 0.38642666269603354
# differential_evolution step 749: f(x)= 0.38548173207930314
# differential_evolution step 750: f(x)= 0.38548173207930314
# differential_evolution step 751: f(x)= 0.38548173207930314
# differential_evolution step 752: f(x)= 0.38548173207930314
# differential_evolution step 753: f(x)= 0.38548173207930314
# differential_evolution step 754: f(x)= 0.38548173207930314
# differential_evolution step 755: f(x)= 0.38548173207930314
# differential_evolution step 756: f(x)= 0.38548173207930314
# differential_evolution step 757: f(x)= 0.38548173207930314
# differential_evolution step 758: f(x)= 0.38548173207930314
# differential_evolution step 759: f(x)= 0.38548173207930314
# differential_evolution step 760: f(x)= 0.38548173207930314
# differential_evolution step 761: f(x)= 0.38548173207930314
# differential_evolution step 762: f(x)= 0.3791929921309342
# differential_evolution step 763: f(x)= 0.3791929921309342
# differential_evolution step 764: f(x)= 0.3791929921309342
# differential_evolution step 765: f(x)= 0.3791929921309342
# differential_evolution step 766: f(x)= 0.3791929921309342
# differential_evolution step 767: f(x)= 0.3791929921309342
# differential_evolution step 768: f(x)= 0.3791929921309342
# differential_evolution step 769: f(x)= 0.3791929921309342
# differential_evolution step 770: f(x)= 0.3791929921309342
# differential_evolution step 771: f(x)= 0.3791929921309342
# differential_evolution step 772: f(x)= 0.3791929921309342
# differential_evolution step 773: f(x)= 0.3791929921309342
# differential_evolution step 774: f(x)= 0.3791929921309342
# differential_evolution step 775: f(x)= 0.3791929921309342
# differential_evolution step 776: f(x)= 0.3791929921309342
# differential_evolution step 777: f(x)= 0.3791929921309342
# differential_evolution step 778: f(x)= 0.3791929921309342
# differential_evolution step 779: f(x)= 0.3791929921309342
# differential_evolution step 780: f(x)= 0.3791929921309342
# differential_evolution step 781: f(x)= 0.3791929921309342
# differential_evolution step 782: f(x)= 0.3791929921309342
# differential_evolution step 783: f(x)= 0.3791929921309342
# differential_evolution step 784: f(x)= 0.3791929921309342
# differential_evolution step 785: f(x)= 0.3791929921309342
# differential_evolution step 786: f(x)= 0.3791929921309342
# differential_evolution step 787: f(x)= 0.37735015375475583
# differential_evolution step 788: f(x)= 0.37735015375475583
# differential_evolution step 789: f(x)= 0.37735015375475583
# differential_evolution step 790: f(x)= 0.37735015375475583
# differential_evolution step 791: f(x)= 0.37735015375475583
# differential_evolution step 792: f(x)= 0.37735015375475583
# differential_evolution step 793: f(x)= 0.37735015375475583
# differential_evolution step 794: f(x)= 0.37735015375475583
# differential_evolution step 795: f(x)= 0.37735015375475583
# differential_evolution step 796: f(x)= 0.37735015375475583
# differential_evolution step 797: f(x)= 0.37735015375475583
# differential_evolution step 798: f(x)= 0.37735015375475583
# differential_evolution step 799: f(x)= 0.37735015375475583
# differential_evolution step 800: f(x)= 0.37735015375475583
# differential_evolution step 801: f(x)= 0.37735015375475583
# differential_evolution step 802: f(x)= 0.37735015375475583
# differential_evolution step 803: f(x)= 0.37735015375475583
# differential_evolution step 804: f(x)= 0.37735015375475583
# differential_evolution step 805: f(x)= 0.37735015375475583
# differential_evolution step 806: f(x)= 0.3746720982898949
# differential_evolution step 807: f(x)= 0.3746720982898949
# differential_evolution step 808: f(x)= 0.3746720982898949
# differential_evolution step 809: f(x)= 0.3746720982898949
# differential_evolution step 810: f(x)= 0.3746720982898949
# differential_evolution step 811: f(x)= 0.3746720982898949
# differential_evolution step 812: f(x)= 0.3746720982898949
# differential_evolution step 813: f(x)= 0.3746720982898949
# differential_evolution step 814: f(x)= 0.3746720982898949
# differential_evolution step 815: f(x)= 0.3746720982898949
# differential_evolution step 816: f(x)= 0.3746720982898949
# differential_evolution step 817: f(x)= 0.37243340973070416
# differential_evolution step 818: f(x)= 0.37243340973070416
# differential_evolution step 819: f(x)= 0.37243340973070416
# differential_evolution step 820: f(x)= 0.37243340973070416
# differential_evolution step 821: f(x)= 0.36826697179361007
# differential_evolution step 822: f(x)= 0.36826697179361007
# differential_evolution step 823: f(x)= 0.36826697179361007
# differential_evolution step 824: f(x)= 0.36826697179361007
# differential_evolution step 825: f(x)= 0.36826697179361007
# differential_evolution step 826: f(x)= 0.36826697179361007
# differential_evolution step 827: f(x)= 0.36826697179361007
# differential_evolution step 828: f(x)= 0.36826697179361007
# differential_evolution step 829: f(x)= 0.36826697179361007
# differential_evolution step 830: f(x)= 0.36826697179361007
# differential_evolution step 831: f(x)= 0.36826697179361007
# differential_evolution step 832: f(x)= 0.36798524534008914
# differential_evolution step 833: f(x)= 0.36798524534008914
# differential_evolution step 834: f(x)= 0.36798524534008914
# differential_evolution step 835: f(x)= 0.36798524534008914
# differential_evolution step 836: f(x)= 0.36798524534008914
# differential_evolution step 837: f(x)= 0.36798524534008914
# differential_evolution step 838: f(x)= 0.36798524534008914
# differential_evolution step 839: f(x)= 0.36798524534008914
# differential_evolution step 840: f(x)= 0.36798524534008914
# differential_evolution step 841: f(x)= 0.36798524534008914
# differential_evolution step 842: f(x)= 0.36798524534008914
# differential_evolution step 843: f(x)= 0.36798524534008914
# differential_evolution step 844: f(x)= 0.3627772696678742
# differential_evolution step 845: f(x)= 0.3627772696678742
# differential_evolution step 846: f(x)= 0.3627772696678742
# differential_evolution step 847: f(x)= 0.3627772696678742
# differential_evolution step 848: f(x)= 0.3627772696678742
# differential_evolution step 849: f(x)= 0.3627772696678742
# differential_evolution step 850: f(x)= 0.3627772696678742
# differential_evolution step 851: f(x)= 0.3627772696678742
# differential_evolution step 852: f(x)= 0.3627772696678742
# differential_evolution step 853: f(x)= 0.3627772696678742
# differential_evolution step 854: f(x)= 0.3627772696678742
# differential_evolution step 855: f(x)= 0.3627772696678742
# differential_evolution step 856: f(x)= 0.3627772696678742
# differential_evolution step 857: f(x)= 0.3627772696678742
# differential_evolution step 858: f(x)= 0.3627772696678742
# differential_evolution step 859: f(x)= 0.3627772696678742
# differential_evolution step 860: f(x)= 0.3627772696678742
# differential_evolution step 861: f(x)= 0.3627772696678742
# differential_evolution step 862: f(x)= 0.3627772696678742
# differential_evolution step 863: f(x)= 0.3614188221479626
# differential_evolution step 864: f(x)= 0.3614188221479626
# differential_evolution step 865: f(x)= 0.3614188221479626
# differential_evolution step 866: f(x)= 0.3614188221479626
# differential_evolution step 867: f(x)= 0.3614188221479626
# differential_evolution step 868: f(x)= 0.3614188221479626
# differential_evolution step 869: f(x)= 0.3585397770970482
# differential_evolution step 870: f(x)= 0.3585397770970482
# differential_evolution step 871: f(x)= 0.3585397770970482
# differential_evolution step 872: f(x)= 0.3585397770970482
# differential_evolution step 873: f(x)= 0.3585397770970482
# differential_evolution step 874: f(x)= 0.3585397770970482
# differential_evolution step 875: f(x)= 0.3585397770970482
# differential_evolution step 876: f(x)= 0.3585397770970482
# differential_evolution step 877: f(x)= 0.3585397770970482
# differential_evolution step 878: f(x)= 0.3585397770970482
# differential_evolution step 879: f(x)= 0.3585397770970482
# differential_evolution step 880: f(x)= 0.3585397770970482
# differential_evolution step 881: f(x)= 0.3585397770970482
# differential_evolution step 882: f(x)= 0.3585397770970482
# differential_evolution step 883: f(x)= 0.3585397770970482
# differential_evolution step 884: f(x)= 0.3585397770970482
# differential_evolution step 885: f(x)= 0.3585397770970482
# differential_evolution step 886: f(x)= 0.3585397770970482
# differential_evolution step 887: f(x)= 0.3585397770970482
# differential_evolution step 888: f(x)= 0.3585397770970482
# differential_evolution step 889: f(x)= 0.3585397770970482
# differential_evolution step 890: f(x)= 0.3585397770970482
# differential_evolution step 891: f(x)= 0.3585397770970482
# differential_evolution step 892: f(x)= 0.3585397770970482
# differential_evolution step 893: f(x)= 0.3585397770970482
# differential_evolution step 894: f(x)= 0.3585397770970482
# differential_evolution step 895: f(x)= 0.3585397770970482
# differential_evolution step 896: f(x)= 0.3585397770970482
# differential_evolution step 897: f(x)= 0.3585397770970482
# differential_evolution step 898: f(x)= 0.3585397770970482
# differential_evolution step 899: f(x)= 0.3585397770970482
# differential_evolution step 900: f(x)= 0.3585397770970482
# differential_evolution step 901: f(x)= 0.3585397770970482
# differential_evolution step 902: f(x)= 0.3585397770970482
# differential_evolution step 903: f(x)= 0.35644627400451306
# differential_evolution step 904: f(x)= 0.35644627400451306
# differential_evolution step 905: f(x)= 0.35644627400451306
# differential_evolution step 906: f(x)= 0.35644627400451306
# differential_evolution step 907: f(x)= 0.35644627400451306
# differential_evolution step 908: f(x)= 0.35644627400451306
# differential_evolution step 909: f(x)= 0.35644627400451306
# differential_evolution step 910: f(x)= 0.35644627400451306
# differential_evolution step 911: f(x)= 0.35644627400451306
# differential_evolution step 912: f(x)= 0.35644627400451306
# differential_evolution step 913: f(x)= 0.35644627400451306
# differential_evolution step 914: f(x)= 0.35644627400451306
# differential_evolution step 915: f(x)= 0.35644627400451306
# differential_evolution step 916: f(x)= 0.35644627400451306
# differential_evolution step 917: f(x)= 0.35644627400451306
# differential_evolution step 918: f(x)= 0.35644627400451306
# differential_evolution step 919: f(x)= 0.35644627400451306
# differential_evolution step 920: f(x)= 0.35644627400451306
# differential_evolution step 921: f(x)= 0.35644627400451306
# differential_evolution step 922: f(x)= 0.35644627400451306
# differential_evolution step 923: f(x)= 0.35644627400451306
# differential_evolution step 924: f(x)= 0.35644627400451306
# differential_evolution step 925: f(x)= 0.35644627400451306
# differential_evolution step 926: f(x)= 0.35426829324243586
# differential_evolution step 927: f(x)= 0.35426829324243586
# differential_evolution step 928: f(x)= 0.35426829324243586
# differential_evolution step 929: f(x)= 0.35426829324243586
# differential_evolution step 930: f(x)= 0.35426829324243586
# differential_evolution step 931: f(x)= 0.35426829324243586
# differential_evolution step 932: f(x)= 0.35426829324243586
# differential_evolution step 933: f(x)= 0.35426829324243586
# differential_evolution step 934: f(x)= 0.35426829324243586
# differential_evolution step 935: f(x)= 0.35426829324243586
# differential_evolution step 936: f(x)= 0.35426829324243586
# differential_evolution step 937: f(x)= 0.35426829324243586
# differential_evolution step 938: f(x)= 0.35426829324243586
# differential_evolution step 939: f(x)= 0.35426829324243586
# differential_evolution step 940: f(x)= 0.35426829324243586
# differential_evolution step 941: f(x)= 0.35426829324243586
# differential_evolution step 942: f(x)= 0.35426829324243586
# differential_evolution step 943: f(x)= 0.35426829324243586
# differential_evolution step 944: f(x)= 0.35426829324243586
# differential_evolution step 945: f(x)= 0.35426829324243586
# differential_evolution step 946: f(x)= 0.35426829324243586
# differential_evolution step 947: f(x)= 0.35426829324243586
# differential_evolution step 948: f(x)= 0.35426829324243586
# differential_evolution step 949: f(x)= 0.3512486385147632
# differential_evolution step 950: f(x)= 0.3512486385147632
# differential_evolution step 951: f(x)= 0.3512486385147632
# differential_evolution step 952: f(x)= 0.3512486385147632
# differential_evolution step 953: f(x)= 0.3512486385147632
# differential_evolution step 954: f(x)= 0.3512486385147632
# differential_evolution step 955: f(x)= 0.3512486385147632
# differential_evolution step 956: f(x)= 0.3512486385147632
# differential_evolution step 957: f(x)= 0.3512486385147632
# differential_evolution step 958: f(x)= 0.3512486385147632
# differential_evolution step 959: f(x)= 0.3512486385147632
# differential_evolution step 960: f(x)= 0.3512486385147632
# differential_evolution step 961: f(x)= 0.3512486385147632
# differential_evolution step 962: f(x)= 0.3512486385147632
# differential_evolution step 963: f(x)= 0.3512486385147632
# differential_evolution step 964: f(x)= 0.3512486385147632
# differential_evolution step 965: f(x)= 0.3512486385147632
# differential_evolution step 966: f(x)= 0.3512486385147632
# differential_evolution step 967: f(x)= 0.3512486385147632
# differential_evolution step 968: f(x)= 0.3512486385147632
# differential_evolution step 969: f(x)= 0.3512486385147632
# differential_evolution step 970: f(x)= 0.3512486385147632
# differential_evolution step 971: f(x)= 0.3512486385147632
# differential_evolution step 972: f(x)= 0.3512486385147632
# differential_evolution step 973: f(x)= 0.3512486385147632
# differential_evolution step 974: f(x)= 0.3512486385147632
# differential_evolution step 975: f(x)= 0.3512486385147632
# differential_evolution step 976: f(x)= 0.3512486385147632
# differential_evolution step 977: f(x)= 0.3512486385147632
# differential_evolution step 978: f(x)= 0.3512486385147632
# differential_evolution step 979: f(x)= 0.3512486385147632
# differential_evolution step 980: f(x)= 0.3512486385147632
# differential_evolution step 981: f(x)= 0.3512486385147632
# differential_evolution step 982: f(x)= 0.3512486385147632
# differential_evolution step 983: f(x)= 0.3512486385147632
# differential_evolution step 984: f(x)= 0.3512486385147632
# differential_evolution step 985: f(x)= 0.3512486385147632
# differential_evolution step 986: f(x)= 0.3512486385147632
# differential_evolution step 987: f(x)= 0.3512486385147632
# differential_evolution step 988: f(x)= 0.3512486385147632
# differential_evolution step 989: f(x)= 0.3512486385147632
# differential_evolution step 990: f(x)= 0.3512486385147632
# differential_evolution step 991: f(x)= 0.3512486385147632
# differential_evolution step 992: f(x)= 0.3512486385147632
# differential_evolution step 993: f(x)= 0.3512486385147632
# differential_evolution step 994: f(x)= 0.3512486385147632
# differential_evolution step 995: f(x)= 0.3512486385147632
# differential_evolution step 996: f(x)= 0.3512486385147632
# differential_evolution step 997: f(x)= 0.3512486385147632
# differential_evolution step 998: f(x)= 0.3512486385147632
# differential_evolution step 999: f(x)= 0.3512486385147632
# differential_evolution step 1000: f(x)= 0.3512486385147632
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [1.03665605e+00 5.04881467e+00 9.74486008e-01 2.70176848e+01
#  6.30222559e-02 2.91619173e+01 6.78001903e-01 4.02387369e+01
#  2.39697177e-01 6.37168093e+00 1.50744019e+00 7.02182774e+01
#  1.33955491e+00 5.54454407e+00 6.12881136e-01 5.05118417e+01
#  1.82275090e-01 2.99312127e+00 8.28385171e-01 6.06487397e+01
#  1.13295438e+00 1.24769204e+00 7.47584004e-01 4.75003579e+01
#  4.05213626e-02 1.00007052e+01 1.75718694e+00 3.40464981e+01]
# Chi quadro minimo: 0.3512486385147632

# %%
# Plots:
params_curve_7, covariance_7 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params7, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[6], red_chi[6] = save_params(params_curve_7, covariance_7, radial_profile_HA, radial_profile_error_HA, x_axes, 7, 
                                       line_name="Seven", output_prefix="fit")

aic[6] = AIC(x_axes, radial_profile_HA, chi_quadr[6], params_curve_7)
bic[6] = BIC(x_axes, radial_profile_HA, chi_quadr[6], params_curve_7)
print(aic[6], chi_quadr[6], bic[6], len(best_params7))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_7)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[16:20]),  linestyle='--', label='Sérsic 5')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[20:24]),  linestyle='--', label='Sérsic 6')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[24:28]),  linestyle='--', label='Sérsic 7')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)

ax[1].plot(x_axes, radial_profile_HA - y_fit)

plt.savefig('AIC_7', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_10724\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_10724\2732296734.py:13: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.9430, r_e=1.6570, n=0.8076, x_0=27.8055
# Sérsic 2: I_e=0.3204, r_e=8.1175, n=1.4265, x_0=25.5731
# Sérsic 3: I_e=0.2067, r_e=7.9952, n=1.6043, x_0=70.2047
# Sérsic 4: I_e=1.3994, r_e=5.6626, n=0.5879, x_0=50.6411
# Sérsic 5: I_e=0.3965, r_e=2.0754, n=0.2959, x_0=60.9678
# Sérsic 6: I_e=0.8940, r_e=1.5102, n=0.9152, x_0=47.5100
# Sérsic 7: I_e=0.2280, r_e=8.0240, n=0.9929, x_0=32.4486
# [0.90683821 1.04023728 0.66986107 0.15321666 0.05487291 1.42245096
#  0.16311473 0.28048824 0.01979726 0.48228698 0.07487235 0.04319046
#  0.23116799 0.58655048 0.07735294 0.36489247 0.07008281 0.33217966
#  0.16362542 0.21230193 0.46478146 0.69498219 0.43249459 0.05619766
#  0.14550599 5.09024814 0.35646084 0.76892087]
# 6.440240295246948
# 85.31347973186666 6.440240295246948 135.38500550291351 28
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Plot AIC vs N 
n = [1, 2, 3, 4, 5, 6, 7]

fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('AIC')
ax1.set_title('N vs AIC')
ax1.plot(n, aic, marker = 'o')
plt.savefig('AIC_vs_N', bbox_inches='tight')
np.savetxt('AIC', aic)
np.savetxt('Reduced_chi', red_chi)

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('BIC')
ax2.set_title('N vs BIC')
ax2.plot(n, bic, marker = 'o')
plt.savefig('BIC_vs_N', bbox_inches='tight')
np.savetxt('BIC', aic)

fig3 = plt.figure(figsize=(8,6))
ax3 = fig3.gca()
ax3.grid(alpha=0.3, c = 'grey')
ax3.set_xlabel('N')
ax3.set_ylabel('Reduced $\chi$')
ax3.set_title('N vs Reduced $\chi$')
ax3.plot(n, red_chi, marker = 'o')
plt.savefig('Reduced_chi_vs_N', bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('log(AIC)')
ax1.set_title('N vs AIC')
ax1.plot(n, np.log10(aic), marker = 'o')
plt.savefig('AIC_vs_N_log', bbox_inches='tight')

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('log(BIC)')
ax2.set_title('N vs BIC')
ax2.plot(n, np.log10(bic), marker = 'o')
plt.savefig('BIC_vs_N_log', bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
