# %%
# %matplotlib widget

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from astropy.modeling import models
from scipy.signal import convolve
from scipy.optimize import minimize
from astropy.convolution import Gaussian1DKernel
import scipy.integrate as integrate
from scipy.optimize import differential_evolution
import pandas as pd

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC5058/FORS2.2022-01-28T08_17_47.181/NGC-5058_MAPPED_FLUX_SCI_LSS_U1.fits")
hdul.info()
image = hdul[0].data
image_error = hdul[1].data
# Out:
# Filename: C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC5058/FORS2.2022-01-28T08_17_47.181/NGC-5058_MAPPED_FLUX_SCI_LSS_U1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     369   (2094, 964)   float32
#   1  IMAGE.ERR     1 ImageHDU        50   (2094, 964)   float32

# %%
image_cut = image[65:165, 0:1890]
image_error_cut = image_error[65:165, 0:1890]

# %%
wavelengths = np.arange(4300.74, 4300.74+1890*1.48, 1.48)
J, N = image_cut.data.shape
#x = np.arange(0, N, 1)
y = np.arange(0, J, 1)
arcsec_y = np.arange(-58*0.256, 42*0.256, 0.256)

x_grid, y_grid = np.meshgrid(wavelengths, y)
plt.pcolormesh(x_grid, y_grid, image_cut, shading='gouraud', vmin = np.percentile(image_cut, 20), vmax = 0.16)
plt.xlabel('wavelength')
# Out:
# Text(0.5, 0, 'wavelength')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
z = 0.00323
l_HA = 6563 * (1+z)
l_HB = 4861 * (1+z) 
l_NII = 6583 * (1+z)
l_SII = 6717 * (1+z)
l_OIII = 5007 * (1+z)

seeing = np.loadtxt("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/NGC5058/PSF/Real_seeing_NGC5058.txt")
sigma = seeing[0] / 2.35

# %%
l_HA
# Out:
# 6584.198490000001

# %%
#Ogni punto del flusso è il risultato della somma di 20 lunghezze d'onda 
mask_HA = (wavelengths > l_HA-8)*(wavelengths < l_HA+8)
image_HA = image_cut[:, mask_HA]
image_error_HA = image_error_cut[:, mask_HA]
radial_profile_HA = np.sum(image_HA, axis = 1)
radial_profile_error_HA = np.sqrt(np.sum(image_error_HA**2, axis = 1))

x_axes = np.arange(0, 100, 1)
plt.figure(figsize=(10, 6))
plt.plot(x_axes, radial_profile_HA)
plt.plot(x_axes, radial_profile_error_HA)
plt.title(r'H$\alpha$')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def calculate_bn(n):
    """ Calcola b_n per il profilo Sérsic """
    return 2*n - 1/3 + 4/(405*n) + 46/(25515*n**2)

def sersic_1d(x, I_e, r_e, n, x_0):
    """ Profilo Sérsic 1D centrato in x_0 """
    r = np.abs(x - x_0)
    b_n = calculate_bn(n)
    return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))

#Define the function for the aic
#Per l'AIC test usiamo il chi quadro perchè il numero di conteggi è elevato (S/N grande) 
#quindi Poisson --> Gauss
#def chi_quad(x, y, y_err, params):
#    return np.sum((((y - model_convolved(x, *params)) / y_err)**2))
    
def AIC(x, y, chi, params): #k=number of model parameter, N=number of data points
    return chi + 2*len(params) +((2*len(params)*(len(params)+1))/(len(y)-len(params)-1))

def BIC(x, y, chi, params):
        return chi + len(params)*np.log(len(y))
    
def sersic_1d_convolved(x, I_e, r_e, n, x_0):
    """ Sérsic convoluto con PSF gaussiana """
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = sersic_1d(x_hr, I_e, r_e, n, x_0)
    psf = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')
    conv_profile = convolve(profile, psf, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def save_params(params_curve, covariance, radial_profile, radial_profile_error, x_axes, n_component, line_name="", output_prefix="fit"):
    I_e = np.zeros(n_component)
    r_e = np.zeros(n_component)
    n = np.zeros(n_component)
    x_0 = np.zeros(n_component)

    I_e_err = np.zeros(n_component)
    r_e_err = np.zeros(n_component)
    n_err = np.zeros(n_component)
    x_0_err = np.zeros(n_component)

    for i in range(n_component):
        I_e[i], r_e[i], n[i], x_0[i] = params_curve[i*4:(i+1)*4]
        I_e_err[i] = np.sqrt(np.diag(covariance)[i*4])
        r_e_err[i] = np.sqrt(np.diag(covariance)[(i*4)+1])
        n_err[i] = np.sqrt(np.diag(covariance)[(i*4)+2])
        x_0_err[i] = np.sqrt(np.diag(covariance)[(i*4)+3])
        print(f"Sérsic {i+1}: I_e={I_e[i]:.4f}, r_e={r_e[i]:.4f}, n={n[i]:.4f}, x_0={x_0[i]:.4f}")

    print(np.sqrt(np.diag(covariance)))
    chi2 = np.sum((((radial_profile - model_convolved(x_axes, *params_curve)) / radial_profile_error)**2))
    dof = len(radial_profile) - len(params_curve)
    chi2_reduced = chi2 / dof
    print(chi2_reduced)

    param_dict = {}
    error_dict = {}
    
    for i in range(n_component):
        component_name = f'Component {i+1}'
        param_dict[component_name] = [I_e[i], r_e[i], n[i], x_0[i]]
        error_dict[component_name] = [I_e_err[i], r_e_err[i], n_err[i], x_0_err[i]]
    
    # Crea DataFrame
    df_params = pd.DataFrame(data=param_dict, index=['I_e', 'r_e', 'n', 'x_0'])
    df_errors = pd.DataFrame(data=error_dict, index=['I_e error', 'r_e error', 'n error', 'x_0 error'])
    
    # Salva file CSV
    if line_name:
        param_filename = f"{line_name}_{output_prefix}.csv"
        error_filename = f"{line_name}_{output_prefix}_errors.csv"
    
    df_params.to_csv(param_filename, float_format='%.4f')
    df_errors.to_csv(error_filename, float_format='%.4f')
    return chi2_reduced, chi2

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params) 
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [

    (0, 20),
    (0, 50),
    (0.1, 10),
    (13, 20),
]

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params1 = result.x

print("Optimize parameters with differential_evolution:", best_params1)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 589.2777614076248
# differential_evolution step 2: f(x)= 589.2777614076248
# differential_evolution step 3: f(x)= 545.3138670112437
# differential_evolution step 4: f(x)= 545.3138670112437
# differential_evolution step 5: f(x)= 538.2764284681541
# differential_evolution step 6: f(x)= 534.832227217601
# differential_evolution step 7: f(x)= 514.3396568618252
# differential_evolution step 8: f(x)= 510.8146458184194
# differential_evolution step 9: f(x)= 510.8146458184194
# differential_evolution step 10: f(x)= 501.2983260831762
# differential_evolution step 11: f(x)= 501.2983260831762
# differential_evolution step 12: f(x)= 493.9837347372682
# differential_evolution step 13: f(x)= 493.9837347372682
# differential_evolution step 14: f(x)= 493.9837347372682
# differential_evolution step 15: f(x)= 493.24285151565545
# differential_evolution step 16: f(x)= 490.3615771664132
# differential_evolution step 17: f(x)= 490.3615771664132
# differential_evolution step 18: f(x)= 490.3615771664132
# differential_evolution step 19: f(x)= 490.3615771664132
# differential_evolution step 20: f(x)= 490.3615771664132
# differential_evolution step 21: f(x)= 489.6256895298162
# differential_evolution step 22: f(x)= 489.4762849440406
# differential_evolution step 23: f(x)= 489.43249609923055
# differential_evolution step 24: f(x)= 489.43249609923055
# differential_evolution step 25: f(x)= 489.43249609923055
# differential_evolution step 26: f(x)= 489.1834252167164
# differential_evolution step 27: f(x)= 489.1834252167164
# differential_evolution step 28: f(x)= 489.1834252167164
# differential_evolution step 29: f(x)= 489.01014711354725
# differential_evolution step 30: f(x)= 489.01014711354725
# differential_evolution step 31: f(x)= 489.01014711354725
# differential_evolution step 32: f(x)= 488.95630896965923
# differential_evolution step 33: f(x)= 488.95630896965923
# differential_evolution step 34: f(x)= 488.95630896965923
# differential_evolution step 35: f(x)= 488.95630896965923
# differential_evolution step 36: f(x)= 488.95630896965923
# differential_evolution step 37: f(x)= 488.95630896965923
# differential_evolution step 38: f(x)= 488.95630896965923
# differential_evolution step 39: f(x)= 488.95630896965923
# differential_evolution step 40: f(x)= 488.95630896965923
# differential_evolution step 41: f(x)= 488.95612427125417
# differential_evolution step 42: f(x)= 488.9433938682015
# differential_evolution step 43: f(x)= 488.9405860785191
# differential_evolution step 44: f(x)= 488.9405860785191
# differential_evolution step 45: f(x)= 488.9405860785191
# differential_evolution step 46: f(x)= 488.9405860785191
# differential_evolution step 47: f(x)= 488.9405860785191
# differential_evolution step 48: f(x)= 488.93717546934647
# differential_evolution step 49: f(x)= 488.93717546934647
# differential_evolution step 50: f(x)= 488.93625891210036
# differential_evolution step 51: f(x)= 488.93399540667446
# differential_evolution step 52: f(x)= 488.93399540667446
# differential_evolution step 53: f(x)= 488.93399540667446
# differential_evolution step 54: f(x)= 488.93399540667446
# differential_evolution step 55: f(x)= 488.93339351080044
# differential_evolution step 56: f(x)= 488.93339351080044
# differential_evolution step 57: f(x)= 488.9332231569499
# differential_evolution step 58: f(x)= 488.9332231569499
# differential_evolution step 59: f(x)= 488.9332231569499
# differential_evolution step 60: f(x)= 488.9332231569499
# differential_evolution step 61: f(x)= 488.9328588707513
# differential_evolution step 62: f(x)= 488.9328588707513
# differential_evolution step 63: f(x)= 488.9328588707513
# differential_evolution step 64: f(x)= 488.9328423809884
# differential_evolution step 65: f(x)= 488.93280757884423
# differential_evolution step 66: f(x)= 488.93280757884423
# differential_evolution step 67: f(x)= 488.93280757884423
# differential_evolution step 68: f(x)= 488.93276730538673
# differential_evolution step 69: f(x)= 488.93276730538673
# differential_evolution step 70: f(x)= 488.93276730538673
# differential_evolution step 71: f(x)= 488.93276730538673
# differential_evolution step 72: f(x)= 488.93276730538673
# differential_evolution step 73: f(x)= 488.9327604557807
# differential_evolution step 74: f(x)= 488.9327604557807
# differential_evolution step 75: f(x)= 488.9327604557807
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [ 2.20220588 44.29538164  0.1        20.        ]
# Chi quadro minimo: 488.93265624293485

# %%
# Plots:
aic = np.zeros(7)
bic = np.zeros(7)
chi_quadr = np.zeros(7)
chi_quadro = np.zeros(7)
red_chi = np.zeros(7)

params_curve_1, covariance_1 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params1,
                                         sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[0], red_chi[0] = save_params(params_curve_1, covariance_1, radial_profile_HA, radial_profile_error_HA, x_axes, 1, line_name="One", 
                                           output_prefix="fit")

aic[0] = AIC(x_axes, radial_profile_HA, chi_quadr[0], params_curve_1)
bic[0] = BIC(x_axes, radial_profile_HA, chi_quadr[0], params_curve_1)
print(aic[0], chi_quadro[0], bic[0], len(params_curve_1))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_1)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_1), 'b--', label='Sérsic 1')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)
plt.savefig('AIC_1', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_10796\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_10796\1007007665.py:7: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.8566, r_e=21.7680, n=0.2327, x_0=39.8674
# [0.19710862 0.9735407  0.07440085 1.22869177]
# 1187.3604976810714
# 1195.7815503126503 0.0 1205.7811784250237 4
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =  [

    (0, 20),
    (0, 50),
    (0.1, 10),
    (13, 20),
    
    (0, 20),
    (0, 50),
    (0.1, 10),
    (55, 65),
]

# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params2 = result.x

print("Optimize parameters with differential_evolution:", best_params2)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 1771.3575304899443
# differential_evolution step 2: f(x)= 1469.631197253921
# differential_evolution step 3: f(x)= 341.1283602188487
# differential_evolution step 4: f(x)= 341.1283602188487
# differential_evolution step 5: f(x)= 341.1283602188487
# differential_evolution step 6: f(x)= 341.1283602188487
# differential_evolution step 7: f(x)= 175.99120129670249
# differential_evolution step 8: f(x)= 175.99120129670249
# differential_evolution step 9: f(x)= 175.99120129670249
# differential_evolution step 10: f(x)= 175.99120129670249
# differential_evolution step 11: f(x)= 175.99120129670249
# differential_evolution step 12: f(x)= 175.99120129670249
# differential_evolution step 13: f(x)= 175.99120129670249
# differential_evolution step 14: f(x)= 63.669769657552614
# differential_evolution step 15: f(x)= 63.669769657552614
# differential_evolution step 16: f(x)= 63.669769657552614
# differential_evolution step 17: f(x)= 63.669769657552614
# differential_evolution step 18: f(x)= 59.42913717873683
# differential_evolution step 19: f(x)= 59.196463407858175
# differential_evolution step 20: f(x)= 59.196463407858175
# differential_evolution step 21: f(x)= 55.49293693990457
# differential_evolution step 22: f(x)= 55.49293693990457
# differential_evolution step 23: f(x)= 55.49293693990457
# differential_evolution step 24: f(x)= 55.49293693990457
# differential_evolution step 25: f(x)= 55.49293693990457
# differential_evolution step 26: f(x)= 55.49293693990457
# differential_evolution step 27: f(x)= 47.29889024070576
# differential_evolution step 28: f(x)= 47.29889024070576
# differential_evolution step 29: f(x)= 47.29889024070576
# differential_evolution step 30: f(x)= 47.29889024070576
# differential_evolution step 31: f(x)= 45.48667040231416
# differential_evolution step 32: f(x)= 42.94061560025485
# differential_evolution step 33: f(x)= 42.94061560025485
# differential_evolution step 34: f(x)= 42.647319974253584
# differential_evolution step 35: f(x)= 42.647319974253584
# differential_evolution step 36: f(x)= 39.6583486824793
# differential_evolution step 37: f(x)= 39.6583486824793
# differential_evolution step 38: f(x)= 33.70601716797111
# differential_evolution step 39: f(x)= 33.70601716797111
# differential_evolution step 40: f(x)= 33.70601716797111
# differential_evolution step 41: f(x)= 33.70601716797111
# differential_evolution step 42: f(x)= 33.70601716797111
# differential_evolution step 43: f(x)= 33.70601716797111
# differential_evolution step 44: f(x)= 33.70601716797111
# differential_evolution step 45: f(x)= 33.70601716797111
# differential_evolution step 46: f(x)= 33.70601716797111
# differential_evolution step 47: f(x)= 33.70601716797111
# differential_evolution step 48: f(x)= 33.70601716797111
# differential_evolution step 49: f(x)= 31.19972139015295
# differential_evolution step 50: f(x)= 31.19972139015295
# differential_evolution step 51: f(x)= 31.19972139015295
# differential_evolution step 52: f(x)= 31.19972139015295
# differential_evolution step 53: f(x)= 31.19972139015295
# differential_evolution step 54: f(x)= 31.19972139015295
# differential_evolution step 55: f(x)= 31.19972139015295
# differential_evolution step 56: f(x)= 31.19972139015295
# differential_evolution step 57: f(x)= 31.19972139015295
# differential_evolution step 58: f(x)= 31.19972139015295
# differential_evolution step 59: f(x)= 31.19972139015295
# differential_evolution step 60: f(x)= 31.19972139015295
# differential_evolution step 61: f(x)= 31.19972139015295
# differential_evolution step 62: f(x)= 31.19972139015295
# differential_evolution step 63: f(x)= 30.962192917868173
# differential_evolution step 64: f(x)= 30.899454603852185
# differential_evolution step 65: f(x)= 30.51576963288869
# differential_evolution step 66: f(x)= 30.51576963288869
# differential_evolution step 67: f(x)= 30.51576963288869
# differential_evolution step 68: f(x)= 30.51576963288869
# differential_evolution step 69: f(x)= 30.51576963288869
# differential_evolution step 70: f(x)= 30.501058868983858
# differential_evolution step 71: f(x)= 30.501058868983858
# differential_evolution step 72: f(x)= 30.273690469155724
# differential_evolution step 73: f(x)= 30.273690469155724
# differential_evolution step 74: f(x)= 29.847549329822105
# differential_evolution step 75: f(x)= 29.847549329822105
# differential_evolution step 76: f(x)= 29.847549329822105
# differential_evolution step 77: f(x)= 29.847549329822105
# differential_evolution step 78: f(x)= 29.847549329822105
# differential_evolution step 79: f(x)= 29.847549329822105
# differential_evolution step 80: f(x)= 29.847549329822105
# differential_evolution step 81: f(x)= 29.847549329822105
# differential_evolution step 82: f(x)= 29.847549329822105
# differential_evolution step 83: f(x)= 29.847549329822105
# differential_evolution step 84: f(x)= 29.847549329822105
# differential_evolution step 85: f(x)= 29.847549329822105
# differential_evolution step 86: f(x)= 29.847549329822105
# differential_evolution step 87: f(x)= 29.769873060526205
# differential_evolution step 88: f(x)= 29.769873060526205
# differential_evolution step 89: f(x)= 29.769873060526205
# differential_evolution step 90: f(x)= 29.483597057360992
# differential_evolution step 91: f(x)= 29.483597057360992
# differential_evolution step 92: f(x)= 29.483597057360992
# differential_evolution step 93: f(x)= 29.36086661050088
# differential_evolution step 94: f(x)= 29.36086661050088
# differential_evolution step 95: f(x)= 29.356159795179604
# differential_evolution step 96: f(x)= 29.356159795179604
# differential_evolution step 97: f(x)= 29.356159795179604
# differential_evolution step 98: f(x)= 29.356159795179604
# differential_evolution step 99: f(x)= 29.356159795179604
# differential_evolution step 100: f(x)= 29.356159795179604
# differential_evolution step 101: f(x)= 29.356159795179604
# differential_evolution step 102: f(x)= 29.356159795179604
# differential_evolution step 103: f(x)= 29.255613550390677
# differential_evolution step 104: f(x)= 29.22098952884719
# differential_evolution step 105: f(x)= 29.22098952884719
# differential_evolution step 106: f(x)= 29.22098952884719
# differential_evolution step 107: f(x)= 28.84259699555624
# differential_evolution step 108: f(x)= 28.84259699555624
# differential_evolution step 109: f(x)= 28.84259699555624
# differential_evolution step 110: f(x)= 28.736430847304995
# differential_evolution step 111: f(x)= 28.736430847304995
# differential_evolution step 112: f(x)= 28.736430847304995
# differential_evolution step 113: f(x)= 28.689521992471462
# differential_evolution step 114: f(x)= 28.658207124046186
# differential_evolution step 115: f(x)= 28.658207124046186
# differential_evolution step 116: f(x)= 28.658207124046186
# differential_evolution step 117: f(x)= 28.658207124046186
# differential_evolution step 118: f(x)= 28.658207124046186
# differential_evolution step 119: f(x)= 28.658207124046186
# differential_evolution step 120: f(x)= 28.658207124046186
# differential_evolution step 121: f(x)= 28.658207124046186
# differential_evolution step 122: f(x)= 28.448547391833944
# differential_evolution step 123: f(x)= 28.448547391833944
# differential_evolution step 124: f(x)= 28.376328637498695
# differential_evolution step 125: f(x)= 28.376328637498695
# differential_evolution step 126: f(x)= 28.376328637498695
# differential_evolution step 127: f(x)= 28.376328637498695
# differential_evolution step 128: f(x)= 28.376328637498695
# differential_evolution step 129: f(x)= 28.056209371865716
# differential_evolution step 130: f(x)= 28.056209371865716
# differential_evolution step 131: f(x)= 28.056209371865716
# differential_evolution step 132: f(x)= 28.056209371865716
# differential_evolution step 133: f(x)= 28.056209371865716
# differential_evolution step 134: f(x)= 28.056209371865716
# differential_evolution step 135: f(x)= 28.056209371865716
# differential_evolution step 136: f(x)= 28.056209371865716
# differential_evolution step 137: f(x)= 27.873853255027466
# differential_evolution step 138: f(x)= 27.74198275646526
# differential_evolution step 139: f(x)= 27.620114826375747
# differential_evolution step 140: f(x)= 27.620114826375747
# differential_evolution step 141: f(x)= 27.620114826375747
# differential_evolution step 142: f(x)= 27.379868593034153
# differential_evolution step 143: f(x)= 26.849402057697453
# differential_evolution step 144: f(x)= 26.399168244330017
# differential_evolution step 145: f(x)= 26.399168244330017
# differential_evolution step 146: f(x)= 26.399168244330017
# differential_evolution step 147: f(x)= 26.399168244330017
# differential_evolution step 148: f(x)= 26.399168244330017
# differential_evolution step 149: f(x)= 26.399168244330017
# differential_evolution step 150: f(x)= 26.399168244330017
# differential_evolution step 151: f(x)= 26.399168244330017
# differential_evolution step 152: f(x)= 26.399168244330017
# differential_evolution step 153: f(x)= 26.399168244330017
# differential_evolution step 154: f(x)= 26.399168244330017
# differential_evolution step 155: f(x)= 26.399168244330017
# differential_evolution step 156: f(x)= 26.399168244330017
# differential_evolution step 157: f(x)= 26.399168244330017
# differential_evolution step 158: f(x)= 26.399168244330017
# differential_evolution step 159: f(x)= 26.399168244330017
# differential_evolution step 160: f(x)= 26.399168244330017
# differential_evolution step 161: f(x)= 26.399168244330017
# differential_evolution step 162: f(x)= 26.399168244330017
# differential_evolution step 163: f(x)= 26.399168244330017
# differential_evolution step 164: f(x)= 26.399168244330017
# differential_evolution step 165: f(x)= 26.399168244330017
# differential_evolution step 166: f(x)= 26.399168244330017
# differential_evolution step 167: f(x)= 26.399168244330017
# differential_evolution step 168: f(x)= 26.399168244330017
# differential_evolution step 169: f(x)= 26.399168244330017
# differential_evolution step 170: f(x)= 26.399168244330017
# differential_evolution step 171: f(x)= 26.399168244330017
# differential_evolution step 172: f(x)= 26.399168244330017
# differential_evolution step 173: f(x)= 26.34072082449435
# differential_evolution step 174: f(x)= 26.34072082449435
# differential_evolution step 175: f(x)= 26.307083076398968
# differential_evolution step 176: f(x)= 26.217659671031775
# differential_evolution step 177: f(x)= 26.111630058027256
# differential_evolution step 178: f(x)= 26.111630058027256
# differential_evolution step 179: f(x)= 26.111630058027256
# differential_evolution step 180: f(x)= 26.111630058027256
# differential_evolution step 181: f(x)= 26.111630058027256
# differential_evolution step 182: f(x)= 26.098587271261312
# differential_evolution step 183: f(x)= 26.098587271261312
# differential_evolution step 184: f(x)= 26.098587271261312
# differential_evolution step 185: f(x)= 26.098587271261312
# differential_evolution step 186: f(x)= 26.098587271261312
# differential_evolution step 187: f(x)= 25.99319339156091
# differential_evolution step 188: f(x)= 25.936291929291304
# differential_evolution step 189: f(x)= 25.936291929291304
# differential_evolution step 190: f(x)= 25.628133241960604
# differential_evolution step 191: f(x)= 25.628133241960604
# differential_evolution step 192: f(x)= 25.628133241960604
# differential_evolution step 193: f(x)= 25.604980048035436
# differential_evolution step 194: f(x)= 25.604980048035436
# differential_evolution step 195: f(x)= 25.604980048035436
# differential_evolution step 196: f(x)= 25.604980048035436
# differential_evolution step 197: f(x)= 25.604980048035436
# differential_evolution step 198: f(x)= 25.604980048035436
# differential_evolution step 199: f(x)= 25.604980048035436
# differential_evolution step 200: f(x)= 25.604980048035436
# differential_evolution step 201: f(x)= 25.604980048035436
# differential_evolution step 202: f(x)= 25.53186977898804
# differential_evolution step 203: f(x)= 25.53186977898804
# differential_evolution step 204: f(x)= 25.53186977898804
# differential_evolution step 205: f(x)= 25.504954162682385
# differential_evolution step 206: f(x)= 25.504954162682385
# differential_evolution step 207: f(x)= 25.43346279555028
# differential_evolution step 208: f(x)= 25.43346279555028
# differential_evolution step 209: f(x)= 25.43346279555028
# differential_evolution step 210: f(x)= 25.43346279555028
# differential_evolution step 211: f(x)= 25.43346279555028
# differential_evolution step 212: f(x)= 25.43346279555028
# differential_evolution step 213: f(x)= 25.43346279555028
# differential_evolution step 214: f(x)= 25.43346279555028
# differential_evolution step 215: f(x)= 25.43346279555028
# differential_evolution step 216: f(x)= 25.43346279555028
# differential_evolution step 217: f(x)= 25.371023911265695
# differential_evolution step 218: f(x)= 25.371023911265695
# differential_evolution step 219: f(x)= 25.371023911265695
# differential_evolution step 220: f(x)= 25.371023911265695
# differential_evolution step 221: f(x)= 25.36114641236713
# differential_evolution step 222: f(x)= 25.36114641236713
# differential_evolution step 223: f(x)= 25.338614707517216
# differential_evolution step 224: f(x)= 25.338614707517216
# differential_evolution step 225: f(x)= 25.338614707517216
# differential_evolution step 226: f(x)= 25.338614707517216
# differential_evolution step 227: f(x)= 25.338614707517216
# differential_evolution step 228: f(x)= 25.338614707517216
# differential_evolution step 229: f(x)= 25.338614707517216
# differential_evolution step 230: f(x)= 25.338614707517216
# differential_evolution step 231: f(x)= 25.338614707517216
# differential_evolution step 232: f(x)= 25.338614707517216
# differential_evolution step 233: f(x)= 25.338614707517216
# differential_evolution step 234: f(x)= 25.338614707517216
# differential_evolution step 235: f(x)= 25.291714654891045
# differential_evolution step 236: f(x)= 25.249685512113977
# differential_evolution step 237: f(x)= 25.249685512113977
# differential_evolution step 238: f(x)= 25.249685512113977
# differential_evolution step 239: f(x)= 25.249685512113977
# differential_evolution step 240: f(x)= 25.246458048469187
# differential_evolution step 241: f(x)= 25.18878067130551
# differential_evolution step 242: f(x)= 25.18878067130551
# differential_evolution step 243: f(x)= 25.18878067130551
# differential_evolution step 244: f(x)= 25.18878067130551
# differential_evolution step 245: f(x)= 25.18878067130551
# differential_evolution step 246: f(x)= 25.18878067130551
# differential_evolution step 247: f(x)= 25.18878067130551
# differential_evolution step 248: f(x)= 25.18878067130551
# differential_evolution step 249: f(x)= 25.15765581839092
# differential_evolution step 250: f(x)= 25.15765581839092
# differential_evolution step 251: f(x)= 25.094460294438626
# differential_evolution step 252: f(x)= 25.094460294438626
# differential_evolution step 253: f(x)= 25.094460294438626
# differential_evolution step 254: f(x)= 25.094460294438626
# differential_evolution step 255: f(x)= 25.094460294438626
# differential_evolution step 256: f(x)= 25.094460294438626
# differential_evolution step 257: f(x)= 25.094460294438626
# differential_evolution step 258: f(x)= 25.035285733471202
# differential_evolution step 259: f(x)= 25.035285733471202
# differential_evolution step 260: f(x)= 25.035285733471202
# differential_evolution step 261: f(x)= 25.035285733471202
# differential_evolution step 262: f(x)= 25.035285733471202
# differential_evolution step 263: f(x)= 25.035285733471202
# differential_evolution step 264: f(x)= 25.035285733471202
# differential_evolution step 265: f(x)= 25.035285733471202
# differential_evolution step 266: f(x)= 25.035285733471202
# differential_evolution step 267: f(x)= 25.035285733471202
# differential_evolution step 268: f(x)= 25.035285733471202
# differential_evolution step 269: f(x)= 25.035285733471202
# differential_evolution step 270: f(x)= 25.035285733471202
# differential_evolution step 271: f(x)= 25.035285733471202
# differential_evolution step 272: f(x)= 25.035285733471202
# differential_evolution step 273: f(x)= 25.035285733471202
# differential_evolution step 274: f(x)= 25.035285733471202
# differential_evolution step 275: f(x)= 25.035285733471202
# differential_evolution step 276: f(x)= 24.935728589159027
# differential_evolution step 277: f(x)= 24.935728589159027
# differential_evolution step 278: f(x)= 24.935728589159027
# differential_evolution step 279: f(x)= 24.935728589159027
# differential_evolution step 280: f(x)= 24.935728589159027
# differential_evolution step 281: f(x)= 24.935728589159027
# differential_evolution step 282: f(x)= 24.935728589159027
# differential_evolution step 283: f(x)= 24.935728589159027
# differential_evolution step 284: f(x)= 24.935728589159027
# differential_evolution step 285: f(x)= 24.935728589159027
# differential_evolution step 286: f(x)= 24.9282349088375
# differential_evolution step 287: f(x)= 24.9282349088375
# differential_evolution step 288: f(x)= 24.9282349088375
# differential_evolution step 289: f(x)= 24.9282349088375
# differential_evolution step 290: f(x)= 24.9282349088375
# differential_evolution step 291: f(x)= 24.9282349088375
# differential_evolution step 292: f(x)= 24.9282349088375
# differential_evolution step 293: f(x)= 24.821819858342934
# differential_evolution step 294: f(x)= 24.821819858342934
# differential_evolution step 295: f(x)= 24.821819858342934
# differential_evolution step 296: f(x)= 24.821819858342934
# differential_evolution step 297: f(x)= 24.821819858342934
# differential_evolution step 298: f(x)= 24.821819858342934
# differential_evolution step 299: f(x)= 24.821819858342934
# differential_evolution step 300: f(x)= 24.821819858342934
# differential_evolution step 301: f(x)= 24.821819858342934
# differential_evolution step 302: f(x)= 24.821819858342934
# differential_evolution step 303: f(x)= 24.821819858342934
# differential_evolution step 304: f(x)= 24.821819858342934
# differential_evolution step 305: f(x)= 24.782269720702658
# differential_evolution step 306: f(x)= 24.77697679434671
# differential_evolution step 307: f(x)= 24.77697679434671
# differential_evolution step 308: f(x)= 24.77697679434671
# differential_evolution step 309: f(x)= 24.6929796972386
# differential_evolution step 310: f(x)= 24.6929796972386
# differential_evolution step 311: f(x)= 24.6929796972386
# differential_evolution step 312: f(x)= 24.6929796972386
# differential_evolution step 313: f(x)= 24.6929796972386
# differential_evolution step 314: f(x)= 24.6929796972386
# differential_evolution step 315: f(x)= 24.6929796972386
# differential_evolution step 316: f(x)= 24.6929796972386
# differential_evolution step 317: f(x)= 24.6929796972386
# differential_evolution step 318: f(x)= 24.6929796972386
# differential_evolution step 319: f(x)= 24.678156877275402
# differential_evolution step 320: f(x)= 24.678156877275402
# differential_evolution step 321: f(x)= 24.678156877275402
# differential_evolution step 322: f(x)= 24.67186068498126
# differential_evolution step 323: f(x)= 24.67186068498126
# differential_evolution step 324: f(x)= 24.666160990715053
# differential_evolution step 325: f(x)= 24.666160990715053
# differential_evolution step 326: f(x)= 24.666160990715053
# differential_evolution step 327: f(x)= 24.666160990715053
# differential_evolution step 328: f(x)= 24.641790173322892
# differential_evolution step 329: f(x)= 24.580640175378264
# differential_evolution step 330: f(x)= 24.580640175378264
# differential_evolution step 331: f(x)= 24.580640175378264
# differential_evolution step 332: f(x)= 24.580640175378264
# differential_evolution step 333: f(x)= 24.534985230915936
# differential_evolution step 334: f(x)= 24.534985230915936
# differential_evolution step 335: f(x)= 24.534985230915936
# differential_evolution step 336: f(x)= 24.534985230915936
# differential_evolution step 337: f(x)= 24.534985230915936
# differential_evolution step 338: f(x)= 24.463144179198544
# differential_evolution step 339: f(x)= 24.463144179198544
# differential_evolution step 340: f(x)= 24.463144179198544
# differential_evolution step 341: f(x)= 24.462349407283362
# differential_evolution step 342: f(x)= 24.462349407283362
# differential_evolution step 343: f(x)= 24.462349407283362
# differential_evolution step 344: f(x)= 24.462349407283362
# differential_evolution step 345: f(x)= 24.462349407283362
# differential_evolution step 346: f(x)= 24.462349407283362
# differential_evolution step 347: f(x)= 24.462349407283362
# differential_evolution step 348: f(x)= 24.462349407283362
# differential_evolution step 349: f(x)= 24.462349407283362
# differential_evolution step 350: f(x)= 24.462349407283362
# differential_evolution step 351: f(x)= 24.462349407283362
# differential_evolution step 352: f(x)= 24.462349407283362
# differential_evolution step 353: f(x)= 24.462349407283362
# differential_evolution step 354: f(x)= 24.462349407283362
# differential_evolution step 355: f(x)= 24.462349407283362
# differential_evolution step 356: f(x)= 24.462349407283362
# differential_evolution step 357: f(x)= 24.456284288171787
# differential_evolution step 358: f(x)= 24.456284288171787
# differential_evolution step 359: f(x)= 24.456284288171787
# differential_evolution step 360: f(x)= 24.456284288171787
# differential_evolution step 361: f(x)= 24.445278138918912
# differential_evolution step 362: f(x)= 24.442976422454677
# differential_evolution step 363: f(x)= 24.442976422454677
# differential_evolution step 364: f(x)= 24.442976422454677
# differential_evolution step 365: f(x)= 24.421818207981406
# differential_evolution step 366: f(x)= 24.421818207981406
# differential_evolution step 367: f(x)= 24.421818207981406
# differential_evolution step 368: f(x)= 24.4155711105116
# differential_evolution step 369: f(x)= 24.4155711105116
# differential_evolution step 370: f(x)= 24.4155711105116
# differential_evolution step 371: f(x)= 24.4155711105116
# differential_evolution step 372: f(x)= 24.4155711105116
# differential_evolution step 373: f(x)= 24.4155711105116
# differential_evolution step 374: f(x)= 24.4155711105116
# differential_evolution step 375: f(x)= 24.4155711105116
# differential_evolution step 376: f(x)= 24.4155711105116
# differential_evolution step 377: f(x)= 24.4155711105116
# differential_evolution step 378: f(x)= 24.4155711105116
# differential_evolution step 379: f(x)= 24.4155711105116
# differential_evolution step 380: f(x)= 24.409434732264472
# differential_evolution step 381: f(x)= 24.3766378032738
# differential_evolution step 382: f(x)= 24.3766378032738
# differential_evolution step 383: f(x)= 24.3766378032738
# differential_evolution step 384: f(x)= 24.3766378032738
# differential_evolution step 385: f(x)= 24.3766378032738
# differential_evolution step 386: f(x)= 24.3766378032738
# differential_evolution step 387: f(x)= 24.3766378032738
# differential_evolution step 388: f(x)= 24.3766378032738
# differential_evolution step 389: f(x)= 24.3766378032738
# differential_evolution step 390: f(x)= 24.3766378032738
# differential_evolution step 391: f(x)= 24.371703275683853
# differential_evolution step 392: f(x)= 24.371703275683853
# differential_evolution step 393: f(x)= 24.371703275683853
# differential_evolution step 394: f(x)= 24.371703275683853
# differential_evolution step 395: f(x)= 24.371703275683853
# differential_evolution step 396: f(x)= 24.371703275683853
# differential_evolution step 397: f(x)= 24.371703275683853
# differential_evolution step 398: f(x)= 24.371703275683853
# differential_evolution step 399: f(x)= 24.371703275683853
# differential_evolution step 400: f(x)= 24.371703275683853
# differential_evolution step 401: f(x)= 24.371703275683853
# differential_evolution step 402: f(x)= 24.371703275683853
# differential_evolution step 403: f(x)= 24.371703275683853
# differential_evolution step 404: f(x)= 24.371703275683853
# differential_evolution step 405: f(x)= 24.371703275683853
# differential_evolution step 406: f(x)= 24.371703275683853
# differential_evolution step 407: f(x)= 24.371703275683853
# differential_evolution step 408: f(x)= 24.371703275683853
# differential_evolution step 409: f(x)= 24.371703275683853
# differential_evolution step 410: f(x)= 24.371703275683853
# differential_evolution step 411: f(x)= 24.36422116510534
# differential_evolution step 412: f(x)= 24.359225467279966
# differential_evolution step 413: f(x)= 24.356759439639717
# differential_evolution step 414: f(x)= 24.356759439639717
# differential_evolution step 415: f(x)= 24.356759439639717
# differential_evolution step 416: f(x)= 24.354602169396202
# differential_evolution step 417: f(x)= 24.354602169396202
# differential_evolution step 418: f(x)= 24.354602169396202
# differential_evolution step 419: f(x)= 24.354602169396202
# differential_evolution step 420: f(x)= 24.351762969526092
# differential_evolution step 421: f(x)= 24.351762969526092
# differential_evolution step 422: f(x)= 24.351762969526092
# differential_evolution step 423: f(x)= 24.351762969526092
# differential_evolution step 424: f(x)= 24.351007163489964
# differential_evolution step 425: f(x)= 24.346790546347272
# differential_evolution step 426: f(x)= 24.33858403565286
# differential_evolution step 427: f(x)= 24.33858403565286
# differential_evolution step 428: f(x)= 24.33858403565286
# differential_evolution step 429: f(x)= 24.334350659176934
# differential_evolution step 430: f(x)= 24.334350659176934
# differential_evolution step 431: f(x)= 24.334350659176934
# differential_evolution step 432: f(x)= 24.334350659176934
# differential_evolution step 433: f(x)= 24.334350659176934
# differential_evolution step 434: f(x)= 24.332211040223118
# differential_evolution step 435: f(x)= 24.332211040223118
# differential_evolution step 436: f(x)= 24.332211040223118
# differential_evolution step 437: f(x)= 24.330258995002325
# differential_evolution step 438: f(x)= 24.330258995002325
# differential_evolution step 439: f(x)= 24.330258995002325
# differential_evolution step 440: f(x)= 24.330258995002325
# differential_evolution step 441: f(x)= 24.330258995002325
# differential_evolution step 442: f(x)= 24.330258995002325
# differential_evolution step 443: f(x)= 24.330258995002325
# differential_evolution step 444: f(x)= 24.32831362538842
# differential_evolution step 445: f(x)= 24.32831362538842
# differential_evolution step 446: f(x)= 24.32831362538842
# differential_evolution step 447: f(x)= 24.32831362538842
# differential_evolution step 448: f(x)= 24.32831362538842
# differential_evolution step 449: f(x)= 24.32831362538842
# differential_evolution step 450: f(x)= 24.324462819069677
# differential_evolution step 451: f(x)= 24.321585432526383
# differential_evolution step 452: f(x)= 24.321585432526383
# differential_evolution step 453: f(x)= 24.321585432526383
# differential_evolution step 454: f(x)= 24.321585432526383
# differential_evolution step 455: f(x)= 24.321585432526383
# differential_evolution step 456: f(x)= 24.321585432526383
# differential_evolution step 457: f(x)= 24.321585432526383
# differential_evolution step 458: f(x)= 24.320275123031763
# differential_evolution step 459: f(x)= 24.320275123031763
# differential_evolution step 460: f(x)= 24.320275123031763
# differential_evolution step 461: f(x)= 24.320275123031763
# differential_evolution step 462: f(x)= 24.320275123031763
# differential_evolution step 463: f(x)= 24.320275123031763
# differential_evolution step 464: f(x)= 24.320275123031763
# differential_evolution step 465: f(x)= 24.32004899775369
# differential_evolution step 466: f(x)= 24.31810583507946
# differential_evolution step 467: f(x)= 24.31810583507946
# differential_evolution step 468: f(x)= 24.31810583507946
# differential_evolution step 469: f(x)= 24.31810583507946
# differential_evolution step 470: f(x)= 24.31810583507946
# differential_evolution step 471: f(x)= 24.31810583507946
# differential_evolution step 472: f(x)= 24.31810583507946
# differential_evolution step 473: f(x)= 24.31810583507946
# differential_evolution step 474: f(x)= 24.31737008456872
# differential_evolution step 475: f(x)= 24.316125594552283
# differential_evolution step 476: f(x)= 24.316125594552283
# differential_evolution step 477: f(x)= 24.316125594552283
# differential_evolution step 478: f(x)= 24.316125594552283
# differential_evolution step 479: f(x)= 24.316125594552283
# differential_evolution step 480: f(x)= 24.316125594552283
# differential_evolution step 481: f(x)= 24.316125594552283
# differential_evolution step 482: f(x)= 24.316125594552283
# differential_evolution step 483: f(x)= 24.316125594552283
# differential_evolution step 484: f(x)= 24.316125594552283
# differential_evolution step 485: f(x)= 24.316125594552283
# differential_evolution step 486: f(x)= 24.316125594552283
# differential_evolution step 487: f(x)= 24.31603623924674
# differential_evolution step 488: f(x)= 24.315182032961747
# differential_evolution step 489: f(x)= 24.315182032961747
# differential_evolution step 490: f(x)= 24.31513819661547
# differential_evolution step 491: f(x)= 24.314679875484746
# differential_evolution step 492: f(x)= 24.314679875484746
# differential_evolution step 493: f(x)= 24.31437561498586
# differential_evolution step 494: f(x)= 24.31380808503729
# differential_evolution step 495: f(x)= 24.31380808503729
# differential_evolution step 496: f(x)= 24.31380808503729
# differential_evolution step 497: f(x)= 24.31380808503729
# differential_evolution step 498: f(x)= 24.31380808503729
# differential_evolution step 499: f(x)= 24.31380808503729
# differential_evolution step 500: f(x)= 24.31380808503729
# differential_evolution step 501: f(x)= 24.31322164362754
# differential_evolution step 502: f(x)= 24.312711082314642
# differential_evolution step 503: f(x)= 24.312711082314642
# differential_evolution step 504: f(x)= 24.312711082314642
# differential_evolution step 505: f(x)= 24.312711082314642
# differential_evolution step 506: f(x)= 24.312711082314642
# differential_evolution step 507: f(x)= 24.312711082314642
# differential_evolution step 508: f(x)= 24.312711082314642
# differential_evolution step 509: f(x)= 24.312711082314642
# differential_evolution step 510: f(x)= 24.312711082314642
# differential_evolution step 511: f(x)= 24.312711082314642
# differential_evolution step 512: f(x)= 24.312711082314642
# differential_evolution step 513: f(x)= 24.3124580392711
# differential_evolution step 514: f(x)= 24.312271944274407
# differential_evolution step 515: f(x)= 24.312271944274407
# differential_evolution step 516: f(x)= 24.312271944274407
# differential_evolution step 517: f(x)= 24.312271944274407
# differential_evolution step 518: f(x)= 24.312271944274407
# differential_evolution step 519: f(x)= 24.312271944274407
# differential_evolution step 520: f(x)= 24.311870130806405
# differential_evolution step 521: f(x)= 24.311870130806405
# differential_evolution step 522: f(x)= 24.311870130806405
# differential_evolution step 523: f(x)= 24.311870130806405
# differential_evolution step 524: f(x)= 24.311870130806405
# differential_evolution step 525: f(x)= 24.311870130806405
# differential_evolution step 526: f(x)= 24.311870130806405
# differential_evolution step 527: f(x)= 24.311870130806405
# differential_evolution step 528: f(x)= 24.311870130806405
# differential_evolution step 529: f(x)= 24.311870130806405
# differential_evolution step 530: f(x)= 24.311870130806405
# differential_evolution step 531: f(x)= 24.311870130806405
# differential_evolution step 532: f(x)= 24.311870130806405
# differential_evolution step 533: f(x)= 24.311870130806405
# differential_evolution step 534: f(x)= 24.311870130806405
# differential_evolution step 535: f(x)= 24.31182058542904
# differential_evolution step 536: f(x)= 24.31182058542904
# differential_evolution step 537: f(x)= 24.31182058542904
# differential_evolution step 538: f(x)= 24.31182058542904
# differential_evolution step 539: f(x)= 24.31182058542904
# differential_evolution step 540: f(x)= 24.31178374186849
# differential_evolution step 541: f(x)= 24.31178374186849
# differential_evolution step 542: f(x)= 24.31178374186849
# differential_evolution step 543: f(x)= 24.31178374186849
# differential_evolution step 544: f(x)= 24.31178374186849
# differential_evolution step 545: f(x)= 24.31178374186849
# differential_evolution step 546: f(x)= 24.31178374186849
# differential_evolution step 547: f(x)= 24.31178374186849
# differential_evolution step 548: f(x)= 24.311758446247904
# differential_evolution step 549: f(x)= 24.311758446247904
# differential_evolution step 550: f(x)= 24.311758446247904
# differential_evolution step 551: f(x)= 24.311746488205827
# differential_evolution step 552: f(x)= 24.311746488205827
# differential_evolution step 553: f(x)= 24.311746488205827
# differential_evolution step 554: f(x)= 24.311746488205827
# differential_evolution step 555: f(x)= 24.311746488205827
# differential_evolution step 556: f(x)= 24.311727540546485
# differential_evolution step 557: f(x)= 24.311727540546485
# differential_evolution step 558: f(x)= 24.311727540546485
# differential_evolution step 559: f(x)= 24.31172680035364
# differential_evolution step 560: f(x)= 24.31172680035364
# differential_evolution step 561: f(x)= 24.31172680035364
# differential_evolution step 562: f(x)= 24.31172680035364
# differential_evolution step 563: f(x)= 24.311725405262205
# differential_evolution step 564: f(x)= 24.311725405262205
# differential_evolution step 565: f(x)= 24.311716242842163
# differential_evolution step 566: f(x)= 24.31170697927682
# differential_evolution step 567: f(x)= 24.31170697927682
# differential_evolution step 568: f(x)= 24.311698451234264
# differential_evolution step 569: f(x)= 24.311698451234264
# differential_evolution step 570: f(x)= 24.311698451234264
# differential_evolution step 571: f(x)= 24.311698451234264
# differential_evolution step 572: f(x)= 24.311698451234264
# differential_evolution step 573: f(x)= 24.311698451234264
# differential_evolution step 574: f(x)= 24.311690970378603
# differential_evolution step 575: f(x)= 24.311690970378603
# differential_evolution step 576: f(x)= 24.311690970378603
# differential_evolution step 577: f(x)= 24.311690970378603
# differential_evolution step 578: f(x)= 24.311690970378603
# differential_evolution step 579: f(x)= 24.31168571288945
# differential_evolution step 580: f(x)= 24.31168230580512
# differential_evolution step 581: f(x)= 24.31168230580512
# differential_evolution step 582: f(x)= 24.31168230580512
# differential_evolution step 583: f(x)= 24.31168230580512
# differential_evolution step 584: f(x)= 24.31168230580512
# differential_evolution step 585: f(x)= 24.31168230580512
# differential_evolution step 586: f(x)= 24.31168230580512
# differential_evolution step 587: f(x)= 24.311676317304602
# differential_evolution step 588: f(x)= 24.311676317304602
# differential_evolution step 589: f(x)= 24.311676317304602
# differential_evolution step 590: f(x)= 24.311676317304602
# differential_evolution step 591: f(x)= 24.311676317304602
# differential_evolution step 592: f(x)= 24.311676008286945
# differential_evolution step 593: f(x)= 24.311676008286945
# differential_evolution step 594: f(x)= 24.311676008286945
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [1.37644548e+00 3.24074789e+01 1.00000075e-01 1.99999436e+01
#  4.61089783e-02 4.99999996e+01 4.62506146e+00 5.96376594e+01]
# Chi quadro minimo: 24.311676008286945

# %%
# Plots:
params_curve_2, covariance_2 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params2, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[1], red_chi[1] = save_params(params_curve_2, covariance_2, radial_profile_HA, radial_profile_error_HA,
    x_axes, 2, line_name="Two", output_prefix="fit")

aic[1] = AIC(x_axes, radial_profile_HA, chi_quadr[1], params_curve_2)
bic[1] = BIC(x_axes, radial_profile_HA, chi_quadr[1], params_curve_2)
print(aic[1], chi_quadr[1], bic[1], len(params_curve_2))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_2)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_2[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_2[4:8]), 'g--', label='Sérsic 2')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_2', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_10796\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_10796\3441851671.py:8: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.3895, r_e=18.4525, n=0.2603, x_0=32.5417
# Sérsic 2: I_e=0.0299, r_e=67.0161, n=4.9656, x_0=59.6377
# [1.06505141e-01 1.93713080e+00 5.61645221e-02 2.54648363e+00
#  1.49496254e-01 2.05929508e+02 5.95235389e+00 1.01667019e-04]
# 182.57309197973944
# 200.15550956215702 182.57309197973944 219.4144534676442 8
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12])
        )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [

    (0, 20),
    (0, 50),
    (0.1, 10),
    (13, 20),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (55, 65),
    
    (0, 20),
    (0, 50),
    (0.1, 10),
    (23, 27),

]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params3 = result.x

print("Optimize parameters with differential_evolution:", best_params3)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 535.1657311663295
# differential_evolution step 2: f(x)= 535.1657311663295
# differential_evolution step 3: f(x)= 535.1657311663295
# differential_evolution step 4: f(x)= 535.1657311663295
# differential_evolution step 5: f(x)= 535.1657311663295
# differential_evolution step 6: f(x)= 535.1657311663295
# differential_evolution step 7: f(x)= 467.7260904617516
# differential_evolution step 8: f(x)= 467.7260904617516
# differential_evolution step 9: f(x)= 467.7260904617516
# differential_evolution step 10: f(x)= 467.7260904617516
# differential_evolution step 11: f(x)= 288.07506538614575
# differential_evolution step 12: f(x)= 288.07506538614575
# differential_evolution step 13: f(x)= 288.07506538614575
# differential_evolution step 14: f(x)= 288.07506538614575
# differential_evolution step 15: f(x)= 269.7530455554794
# differential_evolution step 16: f(x)= 269.7530455554794
# differential_evolution step 17: f(x)= 269.7530455554794
# differential_evolution step 18: f(x)= 269.7530455554794
# differential_evolution step 19: f(x)= 184.87916384657206
# differential_evolution step 20: f(x)= 184.87916384657206
# differential_evolution step 21: f(x)= 184.87916384657206
# differential_evolution step 22: f(x)= 114.57522622281543
# differential_evolution step 23: f(x)= 114.57522622281543
# differential_evolution step 24: f(x)= 114.57522622281543
# differential_evolution step 25: f(x)= 99.80260900359397
# differential_evolution step 26: f(x)= 99.80260900359397
# differential_evolution step 27: f(x)= 99.80260900359397
# differential_evolution step 28: f(x)= 99.80260900359397
# differential_evolution step 29: f(x)= 99.80260900359397
# differential_evolution step 30: f(x)= 99.80260900359397
# differential_evolution step 31: f(x)= 99.80260900359397
# differential_evolution step 32: f(x)= 99.12397922398378
# differential_evolution step 33: f(x)= 67.81440778950684
# differential_evolution step 34: f(x)= 67.08588689078606
# differential_evolution step 35: f(x)= 52.59516626039592
# differential_evolution step 36: f(x)= 52.59516626039592
# differential_evolution step 37: f(x)= 52.59516626039592
# differential_evolution step 38: f(x)= 35.04319811447545
# differential_evolution step 39: f(x)= 35.04319811447545
# differential_evolution step 40: f(x)= 35.04319811447545
# differential_evolution step 41: f(x)= 35.04319811447545
# differential_evolution step 42: f(x)= 35.04319811447545
# differential_evolution step 43: f(x)= 35.04319811447545
# differential_evolution step 44: f(x)= 35.04319811447545
# differential_evolution step 45: f(x)= 35.04319811447545
# differential_evolution step 46: f(x)= 24.985880120227886
# differential_evolution step 47: f(x)= 24.985880120227886
# differential_evolution step 48: f(x)= 24.985880120227886
# differential_evolution step 49: f(x)= 22.8031250136922
# differential_evolution step 50: f(x)= 22.8031250136922
# differential_evolution step 51: f(x)= 22.8031250136922
# differential_evolution step 52: f(x)= 22.297091976469865
# differential_evolution step 53: f(x)= 22.297091976469865
# differential_evolution step 54: f(x)= 22.297091976469865
# differential_evolution step 55: f(x)= 21.842465568143815
# differential_evolution step 56: f(x)= 21.842465568143815
# differential_evolution step 57: f(x)= 21.842465568143815
# differential_evolution step 58: f(x)= 20.27857176682607
# differential_evolution step 59: f(x)= 20.27857176682607
# differential_evolution step 60: f(x)= 19.828710111102666
# differential_evolution step 61: f(x)= 19.828710111102666
# differential_evolution step 62: f(x)= 19.828710111102666
# differential_evolution step 63: f(x)= 19.255376033892283
# differential_evolution step 64: f(x)= 19.255376033892283
# differential_evolution step 65: f(x)= 19.255376033892283
# differential_evolution step 66: f(x)= 19.255376033892283
# differential_evolution step 67: f(x)= 19.255376033892283
# differential_evolution step 68: f(x)= 19.255376033892283
# differential_evolution step 69: f(x)= 19.255376033892283
# differential_evolution step 70: f(x)= 19.255376033892283
# differential_evolution step 71: f(x)= 19.255376033892283
# differential_evolution step 72: f(x)= 19.255376033892283
# differential_evolution step 73: f(x)= 19.255376033892283
# differential_evolution step 74: f(x)= 16.74585891279759
# differential_evolution step 75: f(x)= 16.74585891279759
# differential_evolution step 76: f(x)= 16.74585891279759
# differential_evolution step 77: f(x)= 16.74585891279759
# differential_evolution step 78: f(x)= 15.881032416535147
# differential_evolution step 79: f(x)= 15.881032416535147
# differential_evolution step 80: f(x)= 15.881032416535147
# differential_evolution step 81: f(x)= 15.881032416535147
# differential_evolution step 82: f(x)= 15.881032416535147
# differential_evolution step 83: f(x)= 15.881032416535147
# differential_evolution step 84: f(x)= 15.881032416535147
# differential_evolution step 85: f(x)= 15.881032416535147
# differential_evolution step 86: f(x)= 15.881032416535147
# differential_evolution step 87: f(x)= 15.881032416535147
# differential_evolution step 88: f(x)= 15.881032416535147
# differential_evolution step 89: f(x)= 15.881032416535147
# differential_evolution step 90: f(x)= 15.881032416535147
# differential_evolution step 91: f(x)= 15.881032416535147
# differential_evolution step 92: f(x)= 15.881032416535147
# differential_evolution step 93: f(x)= 15.881032416535147
# differential_evolution step 94: f(x)= 15.881032416535147
# differential_evolution step 95: f(x)= 15.881032416535147
# differential_evolution step 96: f(x)= 15.881032416535147
# differential_evolution step 97: f(x)= 15.881032416535147
# differential_evolution step 98: f(x)= 15.881032416535147
# differential_evolution step 99: f(x)= 15.881032416535147
# differential_evolution step 100: f(x)= 15.881032416535147
# differential_evolution step 101: f(x)= 15.881032416535147
# differential_evolution step 102: f(x)= 15.881032416535147
# differential_evolution step 103: f(x)= 15.80519288735115
# differential_evolution step 104: f(x)= 15.80519288735115
# differential_evolution step 105: f(x)= 15.544590005655945
# differential_evolution step 106: f(x)= 15.544590005655945
# differential_evolution step 107: f(x)= 15.544590005655945
# differential_evolution step 108: f(x)= 15.544590005655945
# differential_evolution step 109: f(x)= 15.544590005655945
# differential_evolution step 110: f(x)= 15.544590005655945
# differential_evolution step 111: f(x)= 15.544590005655945
# differential_evolution step 112: f(x)= 15.544590005655945
# differential_evolution step 113: f(x)= 14.654135073829764
# differential_evolution step 114: f(x)= 14.654135073829764
# differential_evolution step 115: f(x)= 14.654135073829764
# differential_evolution step 116: f(x)= 14.654135073829764
# differential_evolution step 117: f(x)= 14.654135073829764
# differential_evolution step 118: f(x)= 14.654135073829764
# differential_evolution step 119: f(x)= 14.654135073829764
# differential_evolution step 120: f(x)= 14.654135073829764
# differential_evolution step 121: f(x)= 14.654135073829764
# differential_evolution step 122: f(x)= 14.654135073829764
# differential_evolution step 123: f(x)= 14.654135073829764
# differential_evolution step 124: f(x)= 14.654135073829764
# differential_evolution step 125: f(x)= 14.654135073829764
# differential_evolution step 126: f(x)= 14.654135073829764
# differential_evolution step 127: f(x)= 14.654135073829764
# differential_evolution step 128: f(x)= 14.654135073829764
# differential_evolution step 129: f(x)= 14.654135073829764
# differential_evolution step 130: f(x)= 14.654135073829764
# differential_evolution step 131: f(x)= 14.654135073829764
# differential_evolution step 132: f(x)= 14.654135073829764
# differential_evolution step 133: f(x)= 14.442291179400025
# differential_evolution step 134: f(x)= 14.442291179400025
# differential_evolution step 135: f(x)= 14.23509422414753
# differential_evolution step 136: f(x)= 14.23509422414753
# differential_evolution step 137: f(x)= 14.23509422414753
# differential_evolution step 138: f(x)= 14.23509422414753
# differential_evolution step 139: f(x)= 14.23509422414753
# differential_evolution step 140: f(x)= 14.23509422414753
# differential_evolution step 141: f(x)= 14.23509422414753
# differential_evolution step 142: f(x)= 14.23509422414753
# differential_evolution step 143: f(x)= 14.158825133951627
# differential_evolution step 144: f(x)= 14.158825133951627
# differential_evolution step 145: f(x)= 14.158825133951627
# differential_evolution step 146: f(x)= 14.158825133951627
# differential_evolution step 147: f(x)= 14.158825133951627
# differential_evolution step 148: f(x)= 14.158825133951627
# differential_evolution step 149: f(x)= 14.158825133951627
# differential_evolution step 150: f(x)= 14.158825133951627
# differential_evolution step 151: f(x)= 14.158825133951627
# differential_evolution step 152: f(x)= 13.733120846744624
# differential_evolution step 153: f(x)= 13.733120846744624
# differential_evolution step 154: f(x)= 13.733120846744624
# differential_evolution step 155: f(x)= 13.733120846744624
# differential_evolution step 156: f(x)= 13.33421550957086
# differential_evolution step 157: f(x)= 13.33421550957086
# differential_evolution step 158: f(x)= 13.33421550957086
# differential_evolution step 159: f(x)= 13.33421550957086
# differential_evolution step 160: f(x)= 13.33421550957086
# differential_evolution step 161: f(x)= 13.33421550957086
# differential_evolution step 162: f(x)= 13.211990391265443
# differential_evolution step 163: f(x)= 13.211990391265443
# differential_evolution step 164: f(x)= 13.211990391265443
# differential_evolution step 165: f(x)= 13.211990391265443
# differential_evolution step 166: f(x)= 13.211990391265443
# differential_evolution step 167: f(x)= 13.211990391265443
# differential_evolution step 168: f(x)= 13.211990391265443
# differential_evolution step 169: f(x)= 13.211990391265443
# differential_evolution step 170: f(x)= 13.211990391265443
# differential_evolution step 171: f(x)= 13.211990391265443
# differential_evolution step 172: f(x)= 13.037415192552954
# differential_evolution step 173: f(x)= 13.037415192552954
# differential_evolution step 174: f(x)= 13.037415192552954
# differential_evolution step 175: f(x)= 13.037415192552954
# differential_evolution step 176: f(x)= 13.037415192552954
# differential_evolution step 177: f(x)= 12.998835886572952
# differential_evolution step 178: f(x)= 12.947370399925374
# differential_evolution step 179: f(x)= 12.869808989869325
# differential_evolution step 180: f(x)= 12.869808989869325
# differential_evolution step 181: f(x)= 12.417640963045747
# differential_evolution step 182: f(x)= 12.417640963045747
# differential_evolution step 183: f(x)= 12.417640963045747
# differential_evolution step 184: f(x)= 12.417640963045747
# differential_evolution step 185: f(x)= 12.417640963045747
# differential_evolution step 186: f(x)= 12.417640963045747
# differential_evolution step 187: f(x)= 12.417640963045747
# differential_evolution step 188: f(x)= 12.417640963045747
# differential_evolution step 189: f(x)= 12.417640963045747
# differential_evolution step 190: f(x)= 12.417640963045747
# differential_evolution step 191: f(x)= 12.417640963045747
# differential_evolution step 192: f(x)= 12.417640963045747
# differential_evolution step 193: f(x)= 12.417640963045747
# differential_evolution step 194: f(x)= 12.417640963045747
# differential_evolution step 195: f(x)= 12.417640963045747
# differential_evolution step 196: f(x)= 12.417640963045747
# differential_evolution step 197: f(x)= 12.417640963045747
# differential_evolution step 198: f(x)= 12.417640963045747
# differential_evolution step 199: f(x)= 12.417640963045747
# differential_evolution step 200: f(x)= 12.417640963045747
# differential_evolution step 201: f(x)= 12.417640963045747
# differential_evolution step 202: f(x)= 12.417640963045747
# differential_evolution step 203: f(x)= 12.417640963045747
# differential_evolution step 204: f(x)= 12.417640963045747
# differential_evolution step 205: f(x)= 12.390887643910757
# differential_evolution step 206: f(x)= 12.390887643910757
# differential_evolution step 207: f(x)= 12.390887643910757
# differential_evolution step 208: f(x)= 12.390887643910757
# differential_evolution step 209: f(x)= 12.390887643910757
# differential_evolution step 210: f(x)= 12.390887643910757
# differential_evolution step 211: f(x)= 12.390887643910757
# differential_evolution step 212: f(x)= 12.390887643910757
# differential_evolution step 213: f(x)= 12.390887643910757
# differential_evolution step 214: f(x)= 12.390887643910757
# differential_evolution step 215: f(x)= 12.363023624602267
# differential_evolution step 216: f(x)= 12.363023624602267
# differential_evolution step 217: f(x)= 12.314175091513478
# differential_evolution step 218: f(x)= 12.314175091513478
# differential_evolution step 219: f(x)= 12.235494363594412
# differential_evolution step 220: f(x)= 12.235494363594412
# differential_evolution step 221: f(x)= 12.235494363594412
# differential_evolution step 222: f(x)= 12.235494363594412
# differential_evolution step 223: f(x)= 12.235494363594412
# differential_evolution step 224: f(x)= 12.235494363594412
# differential_evolution step 225: f(x)= 12.235494363594412
# differential_evolution step 226: f(x)= 12.084087305708445
# differential_evolution step 227: f(x)= 11.831726401778349
# differential_evolution step 228: f(x)= 11.831726401778349
# differential_evolution step 229: f(x)= 11.831726401778349
# differential_evolution step 230: f(x)= 11.831726401778349
# differential_evolution step 231: f(x)= 11.831726401778349
# differential_evolution step 232: f(x)= 11.831726401778349
# differential_evolution step 233: f(x)= 11.831726401778349
# differential_evolution step 234: f(x)= 11.831726401778349
# differential_evolution step 235: f(x)= 11.763601739534154
# differential_evolution step 236: f(x)= 11.763601739534154
# differential_evolution step 237: f(x)= 11.763601739534154
# differential_evolution step 238: f(x)= 11.763601739534154
# differential_evolution step 239: f(x)= 11.744042002986408
# differential_evolution step 240: f(x)= 11.744042002986408
# differential_evolution step 241: f(x)= 11.744042002986408
# differential_evolution step 242: f(x)= 11.744042002986408
# differential_evolution step 243: f(x)= 11.72087927007054
# differential_evolution step 244: f(x)= 11.699842646788207
# differential_evolution step 245: f(x)= 11.699842646788207
# differential_evolution step 246: f(x)= 11.699842646788207
# differential_evolution step 247: f(x)= 11.699842646788207
# differential_evolution step 248: f(x)= 11.699842646788207
# differential_evolution step 249: f(x)= 11.578776145340424
# differential_evolution step 250: f(x)= 11.578776145340424
# differential_evolution step 251: f(x)= 11.578776145340424
# differential_evolution step 252: f(x)= 11.453669183230588
# differential_evolution step 253: f(x)= 11.453669183230588
# differential_evolution step 254: f(x)= 11.453669183230588
# differential_evolution step 255: f(x)= 11.453669183230588
# differential_evolution step 256: f(x)= 11.453669183230588
# differential_evolution step 257: f(x)= 11.453669183230588
# differential_evolution step 258: f(x)= 11.453669183230588
# differential_evolution step 259: f(x)= 11.453669183230588
# differential_evolution step 260: f(x)= 11.453669183230588
# differential_evolution step 261: f(x)= 11.453669183230588
# differential_evolution step 262: f(x)= 11.453669183230588
# differential_evolution step 263: f(x)= 11.453669183230588
# differential_evolution step 264: f(x)= 11.453669183230588
# differential_evolution step 265: f(x)= 11.32062523487918
# differential_evolution step 266: f(x)= 11.047541045508243
# differential_evolution step 267: f(x)= 11.047541045508243
# differential_evolution step 268: f(x)= 11.047541045508243
# differential_evolution step 269: f(x)= 11.047541045508243
# differential_evolution step 270: f(x)= 11.047541045508243
# differential_evolution step 271: f(x)= 11.047541045508243
# differential_evolution step 272: f(x)= 11.047541045508243
# differential_evolution step 273: f(x)= 11.047541045508243
# differential_evolution step 274: f(x)= 11.047541045508243
# differential_evolution step 275: f(x)= 11.047541045508243
# differential_evolution step 276: f(x)= 11.047541045508243
# differential_evolution step 277: f(x)= 11.047541045508243
# differential_evolution step 278: f(x)= 11.047541045508243
# differential_evolution step 279: f(x)= 11.047541045508243
# differential_evolution step 280: f(x)= 11.047541045508243
# differential_evolution step 281: f(x)= 11.047541045508243
# differential_evolution step 282: f(x)= 11.047541045508243
# differential_evolution step 283: f(x)= 11.047541045508243
# differential_evolution step 284: f(x)= 11.047541045508243
# differential_evolution step 285: f(x)= 11.047541045508243
# differential_evolution step 286: f(x)= 11.047541045508243
# differential_evolution step 287: f(x)= 11.047541045508243
# differential_evolution step 288: f(x)= 11.047541045508243
# differential_evolution step 289: f(x)= 11.047541045508243
# differential_evolution step 290: f(x)= 11.047541045508243
# differential_evolution step 291: f(x)= 11.047541045508243
# differential_evolution step 292: f(x)= 11.047541045508243
# differential_evolution step 293: f(x)= 11.047541045508243
# differential_evolution step 294: f(x)= 11.047541045508243
# differential_evolution step 295: f(x)= 11.047541045508243
# differential_evolution step 296: f(x)= 11.047541045508243
# differential_evolution step 297: f(x)= 11.047541045508243
# differential_evolution step 298: f(x)= 11.047541045508243
# differential_evolution step 299: f(x)= 11.047541045508243
# differential_evolution step 300: f(x)= 11.047541045508243
# differential_evolution step 301: f(x)= 11.047541045508243
# differential_evolution step 302: f(x)= 11.03536307800651
# differential_evolution step 303: f(x)= 11.021005948720028
# differential_evolution step 304: f(x)= 11.021005948720028
# differential_evolution step 305: f(x)= 11.021005948720028
# differential_evolution step 306: f(x)= 11.021005948720028
# differential_evolution step 307: f(x)= 11.021005948720028
# differential_evolution step 308: f(x)= 11.021005948720028
# differential_evolution step 309: f(x)= 11.021005948720028
# differential_evolution step 310: f(x)= 10.992274225746623
# differential_evolution step 311: f(x)= 10.992274225746623
# differential_evolution step 312: f(x)= 10.992274225746623
# differential_evolution step 313: f(x)= 10.992274225746623
# differential_evolution step 314: f(x)= 10.992274225746623
# differential_evolution step 315: f(x)= 10.992274225746623
# differential_evolution step 316: f(x)= 10.992274225746623
# differential_evolution step 317: f(x)= 10.992274225746623
# differential_evolution step 318: f(x)= 10.992274225746623
# differential_evolution step 319: f(x)= 10.992274225746623
# differential_evolution step 320: f(x)= 10.992274225746623
# differential_evolution step 321: f(x)= 10.992274225746623
# differential_evolution step 322: f(x)= 10.992274225746623
# differential_evolution step 323: f(x)= 10.947820840818279
# differential_evolution step 324: f(x)= 10.847378743253683
# differential_evolution step 325: f(x)= 10.847378743253683
# differential_evolution step 326: f(x)= 10.847378743253683
# differential_evolution step 327: f(x)= 10.847378743253683
# differential_evolution step 328: f(x)= 10.847378743253683
# differential_evolution step 329: f(x)= 10.746758329001738
# differential_evolution step 330: f(x)= 10.746758329001738
# differential_evolution step 331: f(x)= 10.746758329001738
# differential_evolution step 332: f(x)= 10.746758329001738
# differential_evolution step 333: f(x)= 10.746758329001738
# differential_evolution step 334: f(x)= 10.746758329001738
# differential_evolution step 335: f(x)= 10.746758329001738
# differential_evolution step 336: f(x)= 10.746758329001738
# differential_evolution step 337: f(x)= 10.746758329001738
# differential_evolution step 338: f(x)= 10.746758329001738
# differential_evolution step 339: f(x)= 10.746758329001738
# differential_evolution step 340: f(x)= 10.746758329001738
# differential_evolution step 341: f(x)= 10.713791898304207
# differential_evolution step 342: f(x)= 10.713791898304207
# differential_evolution step 343: f(x)= 10.713791898304207
# differential_evolution step 344: f(x)= 10.713791898304207
# differential_evolution step 345: f(x)= 10.709199320219254
# differential_evolution step 346: f(x)= 10.709199320219254
# differential_evolution step 347: f(x)= 10.63174885415491
# differential_evolution step 348: f(x)= 10.63174885415491
# differential_evolution step 349: f(x)= 10.63174885415491
# differential_evolution step 350: f(x)= 10.615612144148653
# differential_evolution step 351: f(x)= 10.615612144148653
# differential_evolution step 352: f(x)= 10.613957621777997
# differential_evolution step 353: f(x)= 10.613957621777997
# differential_evolution step 354: f(x)= 10.613957621777997
# differential_evolution step 355: f(x)= 10.613957621777997
# differential_evolution step 356: f(x)= 10.613957621777997
# differential_evolution step 357: f(x)= 10.613957621777997
# differential_evolution step 358: f(x)= 10.488060435338191
# differential_evolution step 359: f(x)= 10.488060435338191
# differential_evolution step 360: f(x)= 10.488060435338191
# differential_evolution step 361: f(x)= 10.488060435338191
# differential_evolution step 362: f(x)= 10.488060435338191
# differential_evolution step 363: f(x)= 10.488060435338191
# differential_evolution step 364: f(x)= 10.488060435338191
# differential_evolution step 365: f(x)= 10.488060435338191
# differential_evolution step 366: f(x)= 10.488060435338191
# differential_evolution step 367: f(x)= 10.488060435338191
# differential_evolution step 368: f(x)= 10.488060435338191
# differential_evolution step 369: f(x)= 10.488060435338191
# differential_evolution step 370: f(x)= 10.488060435338191
# differential_evolution step 371: f(x)= 10.359439361201014
# differential_evolution step 372: f(x)= 10.359439361201014
# differential_evolution step 373: f(x)= 10.359439361201014
# differential_evolution step 374: f(x)= 10.359439361201014
# differential_evolution step 375: f(x)= 10.34832828203149
# differential_evolution step 376: f(x)= 10.317552403503727
# differential_evolution step 377: f(x)= 10.317552403503727
# differential_evolution step 378: f(x)= 10.317552403503727
# differential_evolution step 379: f(x)= 10.310066292662848
# differential_evolution step 380: f(x)= 10.310066292662848
# differential_evolution step 381: f(x)= 10.310066292662848
# differential_evolution step 382: f(x)= 10.310066292662848
# differential_evolution step 383: f(x)= 10.310066292662848
# differential_evolution step 384: f(x)= 10.310066292662848
# differential_evolution step 385: f(x)= 10.310066292662848
# differential_evolution step 386: f(x)= 10.310066292662848
# differential_evolution step 387: f(x)= 10.310066292662848
# differential_evolution step 388: f(x)= 10.310066292662848
# differential_evolution step 389: f(x)= 10.310066292662848
# differential_evolution step 390: f(x)= 10.310066292662848
# differential_evolution step 391: f(x)= 10.310066292662848
# differential_evolution step 392: f(x)= 10.290071434503888
# differential_evolution step 393: f(x)= 10.266899319661258
# differential_evolution step 394: f(x)= 10.259060926276574
# differential_evolution step 395: f(x)= 10.259060926276574
# differential_evolution step 396: f(x)= 10.259060926276574
# differential_evolution step 397: f(x)= 10.259060926276574
# differential_evolution step 398: f(x)= 10.259060926276574
# differential_evolution step 399: f(x)= 10.259060926276574
# differential_evolution step 400: f(x)= 10.259060926276574
# differential_evolution step 401: f(x)= 10.259060926276574
# differential_evolution step 402: f(x)= 10.22268660966486
# differential_evolution step 403: f(x)= 10.22268660966486
# differential_evolution step 404: f(x)= 10.22268660966486
# differential_evolution step 405: f(x)= 10.22268660966486
# differential_evolution step 406: f(x)= 10.22268660966486
# differential_evolution step 407: f(x)= 10.22268660966486
# differential_evolution step 408: f(x)= 10.22268660966486
# differential_evolution step 409: f(x)= 10.22268660966486
# differential_evolution step 410: f(x)= 10.168855425010012
# differential_evolution step 411: f(x)= 10.168855425010012
# differential_evolution step 412: f(x)= 10.168855425010012
# differential_evolution step 413: f(x)= 10.168855425010012
# differential_evolution step 414: f(x)= 10.168855425010012
# differential_evolution step 415: f(x)= 10.168855425010012
# differential_evolution step 416: f(x)= 10.168855425010012
# differential_evolution step 417: f(x)= 10.168855425010012
# differential_evolution step 418: f(x)= 10.168855425010012
# differential_evolution step 419: f(x)= 10.168855425010012
# differential_evolution step 420: f(x)= 10.168855425010012
# differential_evolution step 421: f(x)= 10.168855425010012
# differential_evolution step 422: f(x)= 10.168855425010012
# differential_evolution step 423: f(x)= 10.168855425010012
# differential_evolution step 424: f(x)= 10.168855425010012
# differential_evolution step 425: f(x)= 10.168855425010012
# differential_evolution step 426: f(x)= 10.168855425010012
# differential_evolution step 427: f(x)= 10.168855425010012
# differential_evolution step 428: f(x)= 10.168855425010012
# differential_evolution step 429: f(x)= 10.168855425010012
# differential_evolution step 430: f(x)= 10.168855425010012
# differential_evolution step 431: f(x)= 10.168855425010012
# differential_evolution step 432: f(x)= 10.08740993388192
# differential_evolution step 433: f(x)= 10.074775251914799
# differential_evolution step 434: f(x)= 10.074775251914799
# differential_evolution step 435: f(x)= 10.074775251914799
# differential_evolution step 436: f(x)= 10.074775251914799
# differential_evolution step 437: f(x)= 10.074775251914799
# differential_evolution step 438: f(x)= 10.062040273870178
# differential_evolution step 439: f(x)= 10.062040273870178
# differential_evolution step 440: f(x)= 10.062040273870178
# differential_evolution step 441: f(x)= 10.062040273870178
# differential_evolution step 442: f(x)= 10.062040273870178
# differential_evolution step 443: f(x)= 10.027992609085928
# differential_evolution step 444: f(x)= 10.027992609085928
# differential_evolution step 445: f(x)= 10.027992609085928
# differential_evolution step 446: f(x)= 10.027992609085928
# differential_evolution step 447: f(x)= 10.027992609085928
# differential_evolution step 448: f(x)= 10.027992609085928
# differential_evolution step 449: f(x)= 10.027992609085928
# differential_evolution step 450: f(x)= 10.027992609085928
# differential_evolution step 451: f(x)= 9.95128885495621
# differential_evolution step 452: f(x)= 9.95128885495621
# differential_evolution step 453: f(x)= 9.95128885495621
# differential_evolution step 454: f(x)= 9.95128885495621
# differential_evolution step 455: f(x)= 9.95128885495621
# differential_evolution step 456: f(x)= 9.95128885495621
# differential_evolution step 457: f(x)= 9.95128885495621
# differential_evolution step 458: f(x)= 9.95128885495621
# differential_evolution step 459: f(x)= 9.95128885495621
# differential_evolution step 460: f(x)= 9.95128885495621
# differential_evolution step 461: f(x)= 9.95128885495621
# differential_evolution step 462: f(x)= 9.95128885495621
# differential_evolution step 463: f(x)= 9.890060526364739
# differential_evolution step 464: f(x)= 9.890060526364739
# differential_evolution step 465: f(x)= 9.890060526364739
# differential_evolution step 466: f(x)= 9.890060526364739
# differential_evolution step 467: f(x)= 9.890060526364739
# differential_evolution step 468: f(x)= 9.890060526364739
# differential_evolution step 469: f(x)= 9.890060526364739
# differential_evolution step 470: f(x)= 9.890060526364739
# differential_evolution step 471: f(x)= 9.890060526364739
# differential_evolution step 472: f(x)= 9.890060526364739
# differential_evolution step 473: f(x)= 9.890060526364739
# differential_evolution step 474: f(x)= 9.890060526364739
# differential_evolution step 475: f(x)= 9.890060526364739
# differential_evolution step 476: f(x)= 9.890060526364739
# differential_evolution step 477: f(x)= 9.890060526364739
# differential_evolution step 478: f(x)= 9.890060526364739
# differential_evolution step 479: f(x)= 9.890060526364739
# differential_evolution step 480: f(x)= 9.890060526364739
# differential_evolution step 481: f(x)= 9.890060526364739
# differential_evolution step 482: f(x)= 9.890060526364739
# differential_evolution step 483: f(x)= 9.890060526364739
# differential_evolution step 484: f(x)= 9.890060526364739
# differential_evolution step 485: f(x)= 9.890060526364739
# differential_evolution step 486: f(x)= 9.890060526364739
# differential_evolution step 487: f(x)= 9.890060526364739
# differential_evolution step 488: f(x)= 9.890060526364739
# differential_evolution step 489: f(x)= 9.890060526364739
# differential_evolution step 490: f(x)= 9.890060526364739
# differential_evolution step 491: f(x)= 9.890060526364739
# differential_evolution step 492: f(x)= 9.87151712176631
# differential_evolution step 493: f(x)= 9.87151712176631
# differential_evolution step 494: f(x)= 9.87151712176631
# differential_evolution step 495: f(x)= 9.87151712176631
# differential_evolution step 496: f(x)= 9.87151712176631
# differential_evolution step 497: f(x)= 9.87151712176631
# differential_evolution step 498: f(x)= 9.87151712176631
# differential_evolution step 499: f(x)= 9.87151712176631
# differential_evolution step 500: f(x)= 9.87151712176631
# differential_evolution step 501: f(x)= 9.87151712176631
# differential_evolution step 502: f(x)= 9.87151712176631
# differential_evolution step 503: f(x)= 9.87151712176631
# differential_evolution step 504: f(x)= 9.87151712176631
# differential_evolution step 505: f(x)= 9.87151712176631
# differential_evolution step 506: f(x)= 9.87151712176631
# differential_evolution step 507: f(x)= 9.87151712176631
# differential_evolution step 508: f(x)= 9.853901920049388
# differential_evolution step 509: f(x)= 9.853901920049388
# differential_evolution step 510: f(x)= 9.853901920049388
# differential_evolution step 511: f(x)= 9.853901920049388
# differential_evolution step 512: f(x)= 9.853901920049388
# differential_evolution step 513: f(x)= 9.853901920049388
# differential_evolution step 514: f(x)= 9.853901920049388
# differential_evolution step 515: f(x)= 9.853901920049388
# differential_evolution step 516: f(x)= 9.853901920049388
# differential_evolution step 517: f(x)= 9.853901920049388
# differential_evolution step 518: f(x)= 9.853901920049388
# differential_evolution step 519: f(x)= 9.853901920049388
# differential_evolution step 520: f(x)= 9.853901920049388
# differential_evolution step 521: f(x)= 9.853901920049388
# differential_evolution step 522: f(x)= 9.853901920049388
# differential_evolution step 523: f(x)= 9.853901920049388
# differential_evolution step 524: f(x)= 9.843753826904894
# differential_evolution step 525: f(x)= 9.843753826904894
# differential_evolution step 526: f(x)= 9.843753826904894
# differential_evolution step 527: f(x)= 9.843753826904894
# differential_evolution step 528: f(x)= 9.83518691150574
# differential_evolution step 529: f(x)= 9.83518691150574
# differential_evolution step 530: f(x)= 9.83518691150574
# differential_evolution step 531: f(x)= 9.83518691150574
# differential_evolution step 532: f(x)= 9.826816505872028
# differential_evolution step 533: f(x)= 9.826816505872028
# differential_evolution step 534: f(x)= 9.826816505872028
# differential_evolution step 535: f(x)= 9.826816505872028
# differential_evolution step 536: f(x)= 9.826816505872028
# differential_evolution step 537: f(x)= 9.826816505872028
# differential_evolution step 538: f(x)= 9.826816505872028
# differential_evolution step 539: f(x)= 9.826816505872028
# differential_evolution step 540: f(x)= 9.805538004275231
# differential_evolution step 541: f(x)= 9.805538004275231
# differential_evolution step 542: f(x)= 9.805538004275231
# differential_evolution step 543: f(x)= 9.805538004275231
# differential_evolution step 544: f(x)= 9.805538004275231
# differential_evolution step 545: f(x)= 9.805538004275231
# differential_evolution step 546: f(x)= 9.805538004275231
# differential_evolution step 547: f(x)= 9.805538004275231
# differential_evolution step 548: f(x)= 9.805538004275231
# differential_evolution step 549: f(x)= 9.805538004275231
# differential_evolution step 550: f(x)= 9.805538004275231
# differential_evolution step 551: f(x)= 9.805538004275231
# differential_evolution step 552: f(x)= 9.805538004275231
# differential_evolution step 553: f(x)= 9.792298518784609
# differential_evolution step 554: f(x)= 9.792298518784609
# differential_evolution step 555: f(x)= 9.792298518784609
# differential_evolution step 556: f(x)= 9.783550520812426
# differential_evolution step 557: f(x)= 9.783550520812426
# differential_evolution step 558: f(x)= 9.783550520812426
# differential_evolution step 559: f(x)= 9.783550520812426
# differential_evolution step 560: f(x)= 9.783550520812426
# differential_evolution step 561: f(x)= 9.783550520812426
# differential_evolution step 562: f(x)= 9.783550520812426
# differential_evolution step 563: f(x)= 9.783550520812426
# differential_evolution step 564: f(x)= 9.783550520812426
# differential_evolution step 565: f(x)= 9.783550520812426
# differential_evolution step 566: f(x)= 9.783550520812426
# differential_evolution step 567: f(x)= 9.783550520812426
# differential_evolution step 568: f(x)= 9.783550520812426
# differential_evolution step 569: f(x)= 9.783550520812426
# differential_evolution step 570: f(x)= 9.783550520812426
# differential_evolution step 571: f(x)= 9.783550520812426
# differential_evolution step 572: f(x)= 9.783550520812426
# differential_evolution step 573: f(x)= 9.783550520812426
# differential_evolution step 574: f(x)= 9.783550520812426
# differential_evolution step 575: f(x)= 9.783550520812426
# differential_evolution step 576: f(x)= 9.783550520812426
# differential_evolution step 577: f(x)= 9.783550520812426
# differential_evolution step 578: f(x)= 9.783550520812426
# differential_evolution step 579: f(x)= 9.783550520812426
# differential_evolution step 580: f(x)= 9.783550520812426
# differential_evolution step 581: f(x)= 9.783550520812426
# differential_evolution step 582: f(x)= 9.778255958466914
# differential_evolution step 583: f(x)= 9.778255958466914
# differential_evolution step 584: f(x)= 9.778255958466914
# differential_evolution step 585: f(x)= 9.778255958466914
# differential_evolution step 586: f(x)= 9.778255958466914
# differential_evolution step 587: f(x)= 9.778255958466914
# differential_evolution step 588: f(x)= 9.778255958466914
# differential_evolution step 589: f(x)= 9.778255958466914
# differential_evolution step 590: f(x)= 9.778255958466914
# differential_evolution step 591: f(x)= 9.778255958466914
# differential_evolution step 592: f(x)= 9.778255958466914
# differential_evolution step 593: f(x)= 9.778255958466914
# differential_evolution step 594: f(x)= 9.778255958466914
# differential_evolution step 595: f(x)= 9.778255958466914
# differential_evolution step 596: f(x)= 9.778255958466914
# differential_evolution step 597: f(x)= 9.778255958466914
# differential_evolution step 598: f(x)= 9.778255958466914
# differential_evolution step 599: f(x)= 9.778255958466914
# differential_evolution step 600: f(x)= 9.778255958466914
# differential_evolution step 601: f(x)= 9.778255958466914
# differential_evolution step 602: f(x)= 9.778255958466914
# differential_evolution step 603: f(x)= 9.778255958466914
# differential_evolution step 604: f(x)= 9.778255958466914
# differential_evolution step 605: f(x)= 9.778255958466914
# differential_evolution step 606: f(x)= 9.778255958466914
# differential_evolution step 607: f(x)= 9.778255958466914
# differential_evolution step 608: f(x)= 9.778255958466914
# differential_evolution step 609: f(x)= 9.77665838776595
# differential_evolution step 610: f(x)= 9.77665838776595
# differential_evolution step 611: f(x)= 9.77665838776595
# differential_evolution step 612: f(x)= 9.77665838776595
# differential_evolution step 613: f(x)= 9.77665838776595
# differential_evolution step 614: f(x)= 9.77665838776595
# differential_evolution step 615: f(x)= 9.77665838776595
# differential_evolution step 616: f(x)= 9.77665838776595
# differential_evolution step 617: f(x)= 9.77665838776595
# differential_evolution step 618: f(x)= 9.77665838776595
# differential_evolution step 619: f(x)= 9.753240222962807
# differential_evolution step 620: f(x)= 9.753240222962807
# differential_evolution step 621: f(x)= 9.753240222962807
# differential_evolution step 622: f(x)= 9.753240222962807
# differential_evolution step 623: f(x)= 9.753240222962807
# differential_evolution step 624: f(x)= 9.753240222962807
# differential_evolution step 625: f(x)= 9.753240222962807
# differential_evolution step 626: f(x)= 9.753240222962807
# differential_evolution step 627: f(x)= 9.753240222962807
# differential_evolution step 628: f(x)= 9.753240222962807
# differential_evolution step 629: f(x)= 9.753240222962807
# differential_evolution step 630: f(x)= 9.753240222962807
# differential_evolution step 631: f(x)= 9.753240222962807
# differential_evolution step 632: f(x)= 9.753240222962807
# differential_evolution step 633: f(x)= 9.753240222962807
# differential_evolution step 634: f(x)= 9.753240222962807
# differential_evolution step 635: f(x)= 9.753240222962807
# differential_evolution step 636: f(x)= 9.753240222962807
# differential_evolution step 637: f(x)= 9.747995431897431
# differential_evolution step 638: f(x)= 9.747995431897431
# differential_evolution step 639: f(x)= 9.747995431897431
# differential_evolution step 640: f(x)= 9.747995431897431
# differential_evolution step 641: f(x)= 9.747995431897431
# differential_evolution step 642: f(x)= 9.747995431897431
# differential_evolution step 643: f(x)= 9.747995431897431
# differential_evolution step 644: f(x)= 9.747995431897431
# differential_evolution step 645: f(x)= 9.747995431897431
# differential_evolution step 646: f(x)= 9.747995431897431
# differential_evolution step 647: f(x)= 9.747995431897431
# differential_evolution step 648: f(x)= 9.747995431897431
# differential_evolution step 649: f(x)= 9.747995431897431
# differential_evolution step 650: f(x)= 9.747995431897431
# differential_evolution step 651: f(x)= 9.747995431897431
# differential_evolution step 652: f(x)= 9.747995431897431
# differential_evolution step 653: f(x)= 9.747995431897431
# differential_evolution step 654: f(x)= 9.747995431897431
# differential_evolution step 655: f(x)= 9.747995431897431
# differential_evolution step 656: f(x)= 9.747995431897431
# differential_evolution step 657: f(x)= 9.747995431897431
# differential_evolution step 658: f(x)= 9.743869015438568
# differential_evolution step 659: f(x)= 9.743869015438568
# differential_evolution step 660: f(x)= 9.743869015438568
# differential_evolution step 661: f(x)= 9.743869015438568
# differential_evolution step 662: f(x)= 9.743869015438568
# differential_evolution step 663: f(x)= 9.743869015438568
# differential_evolution step 664: f(x)= 9.739011692115113
# differential_evolution step 665: f(x)= 9.739011692115113
# differential_evolution step 666: f(x)= 9.739011692115113
# differential_evolution step 667: f(x)= 9.739011692115113
# differential_evolution step 668: f(x)= 9.739011692115113
# differential_evolution step 669: f(x)= 9.724530748868249
# differential_evolution step 670: f(x)= 9.724530748868249
# differential_evolution step 671: f(x)= 9.724530748868249
# differential_evolution step 672: f(x)= 9.724530748868249
# differential_evolution step 673: f(x)= 9.724530748868249
# differential_evolution step 674: f(x)= 9.724530748868249
# differential_evolution step 675: f(x)= 9.724530748868249
# differential_evolution step 676: f(x)= 9.724530748868249
# differential_evolution step 677: f(x)= 9.724530748868249
# differential_evolution step 678: f(x)= 9.721581875665626
# differential_evolution step 679: f(x)= 9.721581875665626
# differential_evolution step 680: f(x)= 9.721581875665626
# differential_evolution step 681: f(x)= 9.721581875665626
# differential_evolution step 682: f(x)= 9.721581875665626
# differential_evolution step 683: f(x)= 9.721581875665626
# differential_evolution step 684: f(x)= 9.721581875665626
# differential_evolution step 685: f(x)= 9.721581875665626
# differential_evolution step 686: f(x)= 9.721581875665626
# differential_evolution step 687: f(x)= 9.721581875665626
# differential_evolution step 688: f(x)= 9.721581875665626
# differential_evolution step 689: f(x)= 9.721581875665626
# differential_evolution step 690: f(x)= 9.721581875665626
# differential_evolution step 691: f(x)= 9.721581875665626
# differential_evolution step 692: f(x)= 9.721581875665626
# differential_evolution step 693: f(x)= 9.718203023011375
# differential_evolution step 694: f(x)= 9.718203023011375
# differential_evolution step 695: f(x)= 9.718203023011375
# differential_evolution step 696: f(x)= 9.714689284429896
# differential_evolution step 697: f(x)= 9.714689284429896
# differential_evolution step 698: f(x)= 9.714689284429896
# differential_evolution step 699: f(x)= 9.714375769477893
# differential_evolution step 700: f(x)= 9.714375769477893
# differential_evolution step 701: f(x)= 9.714375769477893
# differential_evolution step 702: f(x)= 9.714375769477893
# differential_evolution step 703: f(x)= 9.714375769477893
# differential_evolution step 704: f(x)= 9.714375769477893
# differential_evolution step 705: f(x)= 9.714375769477893
# differential_evolution step 706: f(x)= 9.714375769477893
# differential_evolution step 707: f(x)= 9.712278988175777
# differential_evolution step 708: f(x)= 9.712278988175777
# differential_evolution step 709: f(x)= 9.712278988175777
# differential_evolution step 710: f(x)= 9.712278988175777
# differential_evolution step 711: f(x)= 9.712278988175777
# differential_evolution step 712: f(x)= 9.712278988175777
# differential_evolution step 713: f(x)= 9.712278988175777
# differential_evolution step 714: f(x)= 9.712278988175777
# differential_evolution step 715: f(x)= 9.712278988175777
# differential_evolution step 716: f(x)= 9.712278988175777
# differential_evolution step 717: f(x)= 9.712278988175777
# differential_evolution step 718: f(x)= 9.712278988175777
# differential_evolution step 719: f(x)= 9.711197126375263
# differential_evolution step 720: f(x)= 9.711197126375263
# differential_evolution step 721: f(x)= 9.711197126375263
# differential_evolution step 722: f(x)= 9.711197126375263
# differential_evolution step 723: f(x)= 9.711197126375263
# differential_evolution step 724: f(x)= 9.711197126375263
# differential_evolution step 725: f(x)= 9.711197126375263
# differential_evolution step 726: f(x)= 9.711197126375263
# differential_evolution step 727: f(x)= 9.711197126375263
# differential_evolution step 728: f(x)= 9.711197126375263
# differential_evolution step 729: f(x)= 9.706826660725383
# differential_evolution step 730: f(x)= 9.706826660725383
# differential_evolution step 731: f(x)= 9.706826660725383
# differential_evolution step 732: f(x)= 9.706826660725383
# differential_evolution step 733: f(x)= 9.706826660725383
# differential_evolution step 734: f(x)= 9.706826660725383
# differential_evolution step 735: f(x)= 9.706826660725383
# differential_evolution step 736: f(x)= 9.706826660725383
# differential_evolution step 737: f(x)= 9.706826660725383
# differential_evolution step 738: f(x)= 9.706826660725383
# differential_evolution step 739: f(x)= 9.706826660725383
# differential_evolution step 740: f(x)= 9.706826660725383
# differential_evolution step 741: f(x)= 9.706826660725383
# differential_evolution step 742: f(x)= 9.706826660725383
# differential_evolution step 743: f(x)= 9.706826660725383
# differential_evolution step 744: f(x)= 9.706826660725383
# differential_evolution step 745: f(x)= 9.706826660725383
# differential_evolution step 746: f(x)= 9.706826660725383
# differential_evolution step 747: f(x)= 9.706826660725383
# differential_evolution step 748: f(x)= 9.706454311957334
# differential_evolution step 749: f(x)= 9.706454311957334
# differential_evolution step 750: f(x)= 9.706454311957334
# differential_evolution step 751: f(x)= 9.706454311957334
# differential_evolution step 752: f(x)= 9.706454311957334
# differential_evolution step 753: f(x)= 9.706454311957334
# differential_evolution step 754: f(x)= 9.704506788273612
# differential_evolution step 755: f(x)= 9.704506788273612
# differential_evolution step 756: f(x)= 9.704506788273612
# differential_evolution step 757: f(x)= 9.704506788273612
# differential_evolution step 758: f(x)= 9.704506788273612
# differential_evolution step 759: f(x)= 9.704506788273612
# differential_evolution step 760: f(x)= 9.704506788273612
# differential_evolution step 761: f(x)= 9.704506788273612
# differential_evolution step 762: f(x)= 9.704506788273612
# differential_evolution step 763: f(x)= 9.704506788273612
# differential_evolution step 764: f(x)= 9.704087252836425
# differential_evolution step 765: f(x)= 9.704087252836425
# differential_evolution step 766: f(x)= 9.704087252836425
# differential_evolution step 767: f(x)= 9.701575325945816
# differential_evolution step 768: f(x)= 9.700978386232094
# differential_evolution step 769: f(x)= 9.700978386232094
# differential_evolution step 770: f(x)= 9.700682873241913
# differential_evolution step 771: f(x)= 9.700682873241913
# differential_evolution step 772: f(x)= 9.700682873241913
# differential_evolution step 773: f(x)= 9.700682873241913
# differential_evolution step 774: f(x)= 9.700682873241913
# differential_evolution step 775: f(x)= 9.700682873241913
# differential_evolution step 776: f(x)= 9.700682873241913
# differential_evolution step 777: f(x)= 9.700513386952505
# differential_evolution step 778: f(x)= 9.700513386952505
# differential_evolution step 779: f(x)= 9.700513386952505
# differential_evolution step 780: f(x)= 9.700513386952505
# differential_evolution step 781: f(x)= 9.700513386952505
# differential_evolution step 782: f(x)= 9.699537720194558
# differential_evolution step 783: f(x)= 9.699537720194558
# differential_evolution step 784: f(x)= 9.699537720194558
# differential_evolution step 785: f(x)= 9.699537720194558
# differential_evolution step 786: f(x)= 9.699537720194558
# differential_evolution step 787: f(x)= 9.699537720194558
# differential_evolution step 788: f(x)= 9.699537720194558
# differential_evolution step 789: f(x)= 9.699537720194558
# differential_evolution step 790: f(x)= 9.699537720194558
# differential_evolution step 791: f(x)= 9.698089071648326
# differential_evolution step 792: f(x)= 9.698089071648326
# differential_evolution step 793: f(x)= 9.698089071648326
# differential_evolution step 794: f(x)= 9.698089071648326
# differential_evolution step 795: f(x)= 9.698089071648326
# differential_evolution step 796: f(x)= 9.698089071648326
# differential_evolution step 797: f(x)= 9.698089071648326
# differential_evolution step 798: f(x)= 9.698089071648326
# differential_evolution step 799: f(x)= 9.698089071648326
# differential_evolution step 800: f(x)= 9.696484157975709
# differential_evolution step 801: f(x)= 9.696484157975709
# differential_evolution step 802: f(x)= 9.696484157975709
# differential_evolution step 803: f(x)= 9.696484157975709
# differential_evolution step 804: f(x)= 9.696484157975709
# differential_evolution step 805: f(x)= 9.696484157975709
# differential_evolution step 806: f(x)= 9.696484157975709
# differential_evolution step 807: f(x)= 9.696484157975709
# differential_evolution step 808: f(x)= 9.696484157975709
# differential_evolution step 809: f(x)= 9.696484157975709
# differential_evolution step 810: f(x)= 9.696484157975709
# differential_evolution step 811: f(x)= 9.696484157975709
# differential_evolution step 812: f(x)= 9.696484157975709
# differential_evolution step 813: f(x)= 9.696484157975709
# differential_evolution step 814: f(x)= 9.696484157975709
# differential_evolution step 815: f(x)= 9.696484157975709
# differential_evolution step 816: f(x)= 9.696484157975709
# differential_evolution step 817: f(x)= 9.696484157975709
# differential_evolution step 818: f(x)= 9.696484157975709
# differential_evolution step 819: f(x)= 9.696484157975709
# differential_evolution step 820: f(x)= 9.696484157975709
# differential_evolution step 821: f(x)= 9.696484157975709
# differential_evolution step 822: f(x)= 9.696484157975709
# differential_evolution step 823: f(x)= 9.696484157975709
# differential_evolution step 824: f(x)= 9.696484157975709
# differential_evolution step 825: f(x)= 9.696484157975709
# differential_evolution step 826: f(x)= 9.696484157975709
# differential_evolution step 827: f(x)= 9.696484157975709
# differential_evolution step 828: f(x)= 9.696484157975709
# differential_evolution step 829: f(x)= 9.696484157975709
# differential_evolution step 830: f(x)= 9.696484157975709
# differential_evolution step 831: f(x)= 9.696484157975709
# differential_evolution step 832: f(x)= 9.695518310282647
# differential_evolution step 833: f(x)= 9.695518310282647
# differential_evolution step 834: f(x)= 9.695518310282647
# differential_evolution step 835: f(x)= 9.695518310282647
# differential_evolution step 836: f(x)= 9.695518310282647
# differential_evolution step 837: f(x)= 9.695518310282647
# differential_evolution step 838: f(x)= 9.695518310282647
# differential_evolution step 839: f(x)= 9.695518310282647
# differential_evolution step 840: f(x)= 9.695518310282647
# differential_evolution step 841: f(x)= 9.695518310282647
# differential_evolution step 842: f(x)= 9.695518310282647
# differential_evolution step 843: f(x)= 9.695518310282647
# differential_evolution step 844: f(x)= 9.695518310282647
# differential_evolution step 845: f(x)= 9.694536566907978
# differential_evolution step 846: f(x)= 9.694536566907978
# differential_evolution step 847: f(x)= 9.694536566907978
# differential_evolution step 848: f(x)= 9.694536566907978
# differential_evolution step 849: f(x)= 9.694536566907978
# differential_evolution step 850: f(x)= 9.694536566907978
# differential_evolution step 851: f(x)= 9.694536566907978
# differential_evolution step 852: f(x)= 9.694139072917297
# differential_evolution step 853: f(x)= 9.694139072917297
# differential_evolution step 854: f(x)= 9.694139072917297
# differential_evolution step 855: f(x)= 9.694139072917297
# differential_evolution step 856: f(x)= 9.694139072917297
# differential_evolution step 857: f(x)= 9.694139072917297
# differential_evolution step 858: f(x)= 9.694139072917297
# differential_evolution step 859: f(x)= 9.694139072917297
# differential_evolution step 860: f(x)= 9.694139072917297
# differential_evolution step 861: f(x)= 9.694139072917297
# differential_evolution step 862: f(x)= 9.694139072917297
# differential_evolution step 863: f(x)= 9.694139072917297
# differential_evolution step 864: f(x)= 9.694139072917297
# differential_evolution step 865: f(x)= 9.693898499729372
# differential_evolution step 866: f(x)= 9.693898499729372
# differential_evolution step 867: f(x)= 9.693898499729372
# differential_evolution step 868: f(x)= 9.693898499729372
# differential_evolution step 869: f(x)= 9.693898499729372
# differential_evolution step 870: f(x)= 9.693898499729372
# differential_evolution step 871: f(x)= 9.6912787913154
# differential_evolution step 872: f(x)= 9.6912787913154
# differential_evolution step 873: f(x)= 9.6912787913154
# differential_evolution step 874: f(x)= 9.6912787913154
# differential_evolution step 875: f(x)= 9.6912787913154
# differential_evolution step 876: f(x)= 9.6912787913154
# differential_evolution step 877: f(x)= 9.6912787913154
# differential_evolution step 878: f(x)= 9.6912787913154
# differential_evolution step 879: f(x)= 9.6912787913154
# differential_evolution step 880: f(x)= 9.6912787913154
# differential_evolution step 881: f(x)= 9.6912787913154
# differential_evolution step 882: f(x)= 9.6912787913154
# differential_evolution step 883: f(x)= 9.6912787913154
# differential_evolution step 884: f(x)= 9.6912787913154
# differential_evolution step 885: f(x)= 9.6912787913154
# differential_evolution step 886: f(x)= 9.6912787913154
# differential_evolution step 887: f(x)= 9.6912787913154
# differential_evolution step 888: f(x)= 9.691227994559505
# differential_evolution step 889: f(x)= 9.691227994559505
# differential_evolution step 890: f(x)= 9.691227994559505
# differential_evolution step 891: f(x)= 9.691227994559505
# differential_evolution step 892: f(x)= 9.691227994559505
# differential_evolution step 893: f(x)= 9.691227994559505
# differential_evolution step 894: f(x)= 9.691227994559505
# differential_evolution step 895: f(x)= 9.691227994559505
# differential_evolution step 896: f(x)= 9.691227994559505
# differential_evolution step 897: f(x)= 9.691227994559505
# differential_evolution step 898: f(x)= 9.691227994559505
# differential_evolution step 899: f(x)= 9.691227994559505
# differential_evolution step 900: f(x)= 9.690600868575814
# differential_evolution step 901: f(x)= 9.690600868575814
# differential_evolution step 902: f(x)= 9.690600868575814
# differential_evolution step 903: f(x)= 9.690600868575814
# differential_evolution step 904: f(x)= 9.690600868575814
# differential_evolution step 905: f(x)= 9.690600868575814
# differential_evolution step 906: f(x)= 9.690600868575814
# differential_evolution step 907: f(x)= 9.690600868575814
# differential_evolution step 908: f(x)= 9.690600868575814
# differential_evolution step 909: f(x)= 9.690600868575814
# differential_evolution step 910: f(x)= 9.690600868575814
# differential_evolution step 911: f(x)= 9.690600868575814
# differential_evolution step 912: f(x)= 9.690600868575814
# differential_evolution step 913: f(x)= 9.690600868575814
# differential_evolution step 914: f(x)= 9.690600868575814
# differential_evolution step 915: f(x)= 9.690600868575814
# differential_evolution step 916: f(x)= 9.690600868575814
# differential_evolution step 917: f(x)= 9.690600868575814
# differential_evolution step 918: f(x)= 9.690600868575814
# differential_evolution step 919: f(x)= 9.690600868575814
# differential_evolution step 920: f(x)= 9.690600868575814
# differential_evolution step 921: f(x)= 9.690600868575814
# differential_evolution step 922: f(x)= 9.690600868575814
# differential_evolution step 923: f(x)= 9.690600868575814
# differential_evolution step 924: f(x)= 9.690600868575814
# differential_evolution step 925: f(x)= 9.690600868575814
# differential_evolution step 926: f(x)= 9.690600868575814
# differential_evolution step 927: f(x)= 9.690600868575814
# differential_evolution step 928: f(x)= 9.690600868575814
# differential_evolution step 929: f(x)= 9.690600868575814
# differential_evolution step 930: f(x)= 9.690600868575814
# differential_evolution step 931: f(x)= 9.690600868575814
# differential_evolution step 932: f(x)= 9.690600868575814
# differential_evolution step 933: f(x)= 9.690600868575814
# differential_evolution step 934: f(x)= 9.690600868575814
# differential_evolution step 935: f(x)= 9.690600868575814
# differential_evolution step 936: f(x)= 9.690600868575814
# differential_evolution step 937: f(x)= 9.690600868575814
# differential_evolution step 938: f(x)= 9.690600868575814
# differential_evolution step 939: f(x)= 9.690600868575814
# differential_evolution step 940: f(x)= 9.690600868575814
# differential_evolution step 941: f(x)= 9.690600868575814
# differential_evolution step 942: f(x)= 9.690600868575814
# differential_evolution step 943: f(x)= 9.690600868575814
# differential_evolution step 944: f(x)= 9.690600868575814
# differential_evolution step 945: f(x)= 9.690600868575814
# differential_evolution step 946: f(x)= 9.690600868575814
# differential_evolution step 947: f(x)= 9.690600868575814
# differential_evolution step 948: f(x)= 9.690600868575814
# differential_evolution step 949: f(x)= 9.690600868575814
# differential_evolution step 950: f(x)= 9.690600868575814
# differential_evolution step 951: f(x)= 9.690600868575814
# differential_evolution step 952: f(x)= 9.690600868575814
# differential_evolution step 953: f(x)= 9.690600868575814
# differential_evolution step 954: f(x)= 9.690600868575814
# differential_evolution step 955: f(x)= 9.690186444349145
# differential_evolution step 956: f(x)= 9.690186444349145
# differential_evolution step 957: f(x)= 9.690186444349145
# differential_evolution step 958: f(x)= 9.690146163227215
# differential_evolution step 959: f(x)= 9.690146163227215
# differential_evolution step 960: f(x)= 9.690146163227215
# differential_evolution step 961: f(x)= 9.690146163227215
# differential_evolution step 962: f(x)= 9.690146163227215
# differential_evolution step 963: f(x)= 9.690146163227215
# differential_evolution step 964: f(x)= 9.690146163227215
# differential_evolution step 965: f(x)= 9.690146163227215
# differential_evolution step 966: f(x)= 9.690146163227215
# differential_evolution step 967: f(x)= 9.690146163227215
# differential_evolution step 968: f(x)= 9.689800277447665
# differential_evolution step 969: f(x)= 9.689800277447665
# differential_evolution step 970: f(x)= 9.689800277447665
# differential_evolution step 971: f(x)= 9.689800277447665
# differential_evolution step 972: f(x)= 9.689800277447665
# differential_evolution step 973: f(x)= 9.689800277447665
# differential_evolution step 974: f(x)= 9.689800277447665
# differential_evolution step 975: f(x)= 9.689800277447665
# differential_evolution step 976: f(x)= 9.689800277447665
# differential_evolution step 977: f(x)= 9.689800277447665
# differential_evolution step 978: f(x)= 9.689800277447665
# differential_evolution step 979: f(x)= 9.689800277447665
# differential_evolution step 980: f(x)= 9.689800277447665
# differential_evolution step 981: f(x)= 9.689800277447665
# differential_evolution step 982: f(x)= 9.689611103546799
# differential_evolution step 983: f(x)= 9.689205365661735
# differential_evolution step 984: f(x)= 9.689205365661735
# differential_evolution step 985: f(x)= 9.688839473448018
# differential_evolution step 986: f(x)= 9.688737081549688
# differential_evolution step 987: f(x)= 9.688737081549688
# differential_evolution step 988: f(x)= 9.688737081549688
# differential_evolution step 989: f(x)= 9.688737081549688
# differential_evolution step 990: f(x)= 9.688737081549688
# differential_evolution step 991: f(x)= 9.688737081549688
# differential_evolution step 992: f(x)= 9.688737081549688
# differential_evolution step 993: f(x)= 9.688737081549688
# differential_evolution step 994: f(x)= 9.688737081549688
# differential_evolution step 995: f(x)= 9.688737081549688
# differential_evolution step 996: f(x)= 9.688665112714597
# differential_evolution step 997: f(x)= 9.688645417927304
# differential_evolution step 998: f(x)= 9.688645417927304
# differential_evolution step 999: f(x)= 9.688645417927304
# differential_evolution step 1000: f(x)= 9.688645417927304
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [1.03161726e+00 3.26935998e+01 1.00007561e-01 1.99978924e+01
#  5.21069756e-02 4.99980320e+01 4.48445014e+00 5.95881470e+01
#  3.35362286e-01 7.51215295e+00 1.26488742e+00 2.60470686e+01]
# Chi quadro minimo: 9.688645417927304

# %%
# Plots:
params_curve_3, covariance_3 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params3, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[2], red_chi[2] = save_params(params_curve_3, covariance_3, radial_profile_HA, radial_profile_error_HA,x_axes, 3,  
                                       line_name="Three", output_prefix="fit")

aic[2] = AIC(x_axes, radial_profile_HA, chi_quadr[2], params_curve_3)
bic[2] = BIC(x_axes, radial_profile_HA, chi_quadr[2], params_curve_3)
print(aic[2], chi_quadr[2], bic[2], len(params_curve_3))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_3)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_3[8:12]), 'm--', label='Sérsic 3')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_3', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_10796\111436280.py:9: RuntimeWarning: invalid value encountered in power
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_10796\2884389266.py:9: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=1.0691, r_e=22.0334, n=0.1290, x_0=30.7820
# Sérsic 2: I_e=0.0399, r_e=61.5205, n=4.6651, x_0=59.5881
# Sérsic 3: I_e=0.4563, r_e=6.0317, n=1.0329, x_0=26.1380
# [1.63197149e-01 4.43581179e+00 5.82429278e-02 3.65872811e+00
#  9.85215347e-02 9.58740843e+01 2.87601720e+00 6.64442761e-05
#  4.46286999e-01 4.86151047e+00 7.14111161e-01 4.00577447e-01]
# 118.54543879787008
# 146.1316456944218 118.54543879787008 173.80748102972717 12
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [

    (0, 20),
    (0, 50),
    (0.1, 10),
    (13, 20),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (55, 65),
    
    (0, 20),
    (0, 50),
    (0.1, 10),
    (20, 28),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (30, 38),

]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params4 = result.x

print("Optimize parameters with differential_evolution:", best_params4)

print("Chi quadro minimo:", result.fun)
# Out:
# differential_evolution step 1: f(x)= 56195.33241331543
# differential_evolution step 2: f(x)= 8270.250911242332
# differential_evolution step 3: f(x)= 5982.436727491562
# differential_evolution step 4: f(x)= 5982.436727491562
# differential_evolution step 5: f(x)= 5982.436727491562
# differential_evolution step 6: f(x)= 5982.436727491562
# differential_evolution step 7: f(x)= 5982.436727491562
# differential_evolution step 8: f(x)= 5982.436727491562
# differential_evolution step 9: f(x)= 1933.4610563255105
# differential_evolution step 10: f(x)= 1933.4610563255105
# differential_evolution step 11: f(x)= 1933.4610563255105
# differential_evolution step 12: f(x)= 1933.4610563255105
# differential_evolution step 13: f(x)= 1933.4610563255105
# differential_evolution step 14: f(x)= 1933.4610563255105
# differential_evolution step 15: f(x)= 1933.4610563255105
# differential_evolution step 16: f(x)= 1933.4610563255105
# differential_evolution step 17: f(x)= 1933.4610563255105
# differential_evolution step 18: f(x)= 1933.4610563255105
# differential_evolution step 19: f(x)= 1933.4610563255105
# differential_evolution step 20: f(x)= 1933.4610563255105
# differential_evolution step 21: f(x)= 1933.4610563255105
# differential_evolution step 22: f(x)= 1174.3218359353073
# differential_evolution step 23: f(x)= 1174.3218359353073
# differential_evolution step 24: f(x)= 1029.4805427136655
# differential_evolution step 25: f(x)= 1029.4805427136655
# differential_evolution step 26: f(x)= 1029.4805427136655
# differential_evolution step 27: f(x)= 1029.4805427136655
# differential_evolution step 28: f(x)= 1029.4805427136655
# differential_evolution step 29: f(x)= 1029.4805427136655
# differential_evolution step 30: f(x)= 865.0719497487219
# differential_evolution step 31: f(x)= 270.6278367157378
# differential_evolution step 32: f(x)= 270.6278367157378
# differential_evolution step 33: f(x)= 270.6278367157378
# differential_evolution step 34: f(x)= 270.6278367157378
# differential_evolution step 35: f(x)= 270.6278367157378
# differential_evolution step 36: f(x)= 270.6278367157378
# differential_evolution step 37: f(x)= 270.6278367157378
# differential_evolution step 38: f(x)= 270.6278367157378
# differential_evolution step 39: f(x)= 270.6278367157378
# differential_evolution step 40: f(x)= 207.67826704892033
# differential_evolution step 41: f(x)= 137.95700785783217
# differential_evolution step 42: f(x)= 110.84722554997306
# differential_evolution step 43: f(x)= 110.84722554997306
# differential_evolution step 44: f(x)= 110.84722554997306
# differential_evolution step 45: f(x)= 110.84722554997306
# differential_evolution step 46: f(x)= 110.84722554997306
# differential_evolution step 47: f(x)= 110.84722554997306
# differential_evolution step 48: f(x)= 110.84722554997306
# differential_evolution step 49: f(x)= 110.84722554997306
# differential_evolution step 50: f(x)= 110.84722554997306
# differential_evolution step 51: f(x)= 110.84722554997306
# differential_evolution step 52: f(x)= 110.84722554997306
# differential_evolution step 53: f(x)= 110.84722554997306
# differential_evolution step 54: f(x)= 110.84722554997306
# differential_evolution step 55: f(x)= 110.84722554997306
# differential_evolution step 56: f(x)= 110.84722554997306
# differential_evolution step 57: f(x)= 110.84722554997306
# differential_evolution step 58: f(x)= 110.84722554997306
# differential_evolution step 59: f(x)= 110.84722554997306
# differential_evolution step 60: f(x)= 110.84722554997306
# differential_evolution step 61: f(x)= 110.84722554997306
# differential_evolution step 62: f(x)= 86.79388939448106
# differential_evolution step 63: f(x)= 86.79388939448106
# differential_evolution step 64: f(x)= 86.79388939448106
# differential_evolution step 65: f(x)= 86.79388939448106
# differential_evolution step 66: f(x)= 86.79388939448106
# differential_evolution step 67: f(x)= 86.79388939448106
# differential_evolution step 68: f(x)= 86.79388939448106
# differential_evolution step 69: f(x)= 86.79388939448106
# differential_evolution step 70: f(x)= 86.79388939448106
# differential_evolution step 71: f(x)= 86.79388939448106
# differential_evolution step 72: f(x)= 86.79388939448106
# differential_evolution step 73: f(x)= 86.79388939448106
# differential_evolution step 74: f(x)= 86.79388939448106
# differential_evolution step 75: f(x)= 86.79388939448106
# differential_evolution step 76: f(x)= 86.79388939448106
# differential_evolution step 77: f(x)= 86.79388939448106
# differential_evolution step 78: f(x)= 86.79388939448106
# differential_evolution step 79: f(x)= 86.79388939448106
# differential_evolution step 80: f(x)= 86.79388939448106
# differential_evolution step 81: f(x)= 86.79388939448106
# differential_evolution step 82: f(x)= 86.79388939448106
# differential_evolution step 83: f(x)= 86.79388939448106
# differential_evolution step 84: f(x)= 86.79388939448106
# differential_evolution step 85: f(x)= 86.79388939448106
# differential_evolution step 86: f(x)= 86.79388939448106
# differential_evolution step 87: f(x)= 86.79388939448106
# differential_evolution step 88: f(x)= 86.79388939448106
# differential_evolution step 89: f(x)= 61.89675684528755
# differential_evolution step 90: f(x)= 61.89675684528755
# differential_evolution step 91: f(x)= 61.89675684528755
# differential_evolution step 92: f(x)= 61.89675684528755
# differential_evolution step 93: f(x)= 61.89675684528755
# differential_evolution step 94: f(x)= 61.89675684528755
# differential_evolution step 95: f(x)= 61.89675684528755
# differential_evolution step 96: f(x)= 61.89675684528755
# differential_evolution step 97: f(x)= 61.89675684528755
# differential_evolution step 98: f(x)= 61.89675684528755
# differential_evolution step 99: f(x)= 58.031693138906334
# differential_evolution step 100: f(x)= 58.031693138906334
# differential_evolution step 101: f(x)= 58.031693138906334
# differential_evolution step 102: f(x)= 58.031693138906334
# differential_evolution step 103: f(x)= 58.031693138906334
# differential_evolution step 104: f(x)= 58.031693138906334
# differential_evolution step 105: f(x)= 58.031693138906334
# differential_evolution step 106: f(x)= 58.031693138906334
# differential_evolution step 107: f(x)= 58.031693138906334
# differential_evolution step 108: f(x)= 57.07173434218764
# differential_evolution step 109: f(x)= 57.07173434218764
# differential_evolution step 110: f(x)= 57.07173434218764
# differential_evolution step 111: f(x)= 57.07173434218764
# differential_evolution step 112: f(x)= 57.07173434218764
# differential_evolution step 113: f(x)= 48.62401407274055
# differential_evolution step 114: f(x)= 48.62401407274055
# differential_evolution step 115: f(x)= 48.62401407274055
# differential_evolution step 116: f(x)= 40.12391220989573
# differential_evolution step 117: f(x)= 40.12391220989573
# differential_evolution step 118: f(x)= 40.12391220989573
# differential_evolution step 119: f(x)= 40.12391220989573
# differential_evolution step 120: f(x)= 40.12391220989573
# differential_evolution step 121: f(x)= 40.12391220989573
# differential_evolution step 122: f(x)= 40.12391220989573
# differential_evolution step 123: f(x)= 40.12391220989573
# differential_evolution step 124: f(x)= 40.12391220989573
# differential_evolution step 125: f(x)= 36.48743259817388
# differential_evolution step 126: f(x)= 36.48743259817388
# differential_evolution step 127: f(x)= 33.61711396897266
# differential_evolution step 128: f(x)= 33.61711396897266
# differential_evolution step 129: f(x)= 33.61711396897266
# differential_evolution step 130: f(x)= 33.299564885501816
# differential_evolution step 131: f(x)= 33.20001150739441
# differential_evolution step 132: f(x)= 33.20001150739441
# differential_evolution step 133: f(x)= 33.20001150739441
# differential_evolution step 134: f(x)= 33.20001150739441
# differential_evolution step 135: f(x)= 33.20001150739441
# differential_evolution step 136: f(x)= 33.20001150739441
# differential_evolution step 137: f(x)= 33.14980518579152
# differential_evolution step 138: f(x)= 28.76541926517849
# differential_evolution step 139: f(x)= 28.76541926517849
# differential_evolution step 140: f(x)= 28.76541926517849
# differential_evolution step 141: f(x)= 28.76541926517849
# differential_evolution step 142: f(x)= 28.76541926517849
# differential_evolution step 143: f(x)= 26.68071282696502
# differential_evolution step 144: f(x)= 26.68071282696502
# differential_evolution step 145: f(x)= 26.68071282696502
# differential_evolution step 146: f(x)= 26.68071282696502
# differential_evolution step 147: f(x)= 26.68071282696502
# differential_evolution step 148: f(x)= 26.68071282696502
# differential_evolution step 149: f(x)= 26.68071282696502
# differential_evolution step 150: f(x)= 26.68071282696502
# differential_evolution step 151: f(x)= 24.713918578291217
# differential_evolution step 152: f(x)= 24.713918578291217
# differential_evolution step 153: f(x)= 24.713918578291217
# differential_evolution step 154: f(x)= 24.713918578291217
# differential_evolution step 155: f(x)= 24.713918578291217
# differential_evolution step 156: f(x)= 24.713918578291217
# differential_evolution step 157: f(x)= 24.235261475786803
# differential_evolution step 158: f(x)= 24.235261475786803
# differential_evolution step 159: f(x)= 24.235261475786803
# differential_evolution step 160: f(x)= 24.235261475786803
# differential_evolution step 161: f(x)= 24.235261475786803
# differential_evolution step 162: f(x)= 22.479095239797026
# differential_evolution step 163: f(x)= 22.479095239797026
# differential_evolution step 164: f(x)= 22.479095239797026
# differential_evolution step 165: f(x)= 18.967924701758047
# differential_evolution step 166: f(x)= 18.967924701758047
# differential_evolution step 167: f(x)= 18.967924701758047
# differential_evolution step 168: f(x)= 18.967924701758047
# differential_evolution step 169: f(x)= 18.967924701758047
# differential_evolution step 170: f(x)= 17.671603819270373
# differential_evolution step 171: f(x)= 17.671603819270373
# differential_evolution step 172: f(x)= 17.671603819270373
# differential_evolution step 173: f(x)= 17.671603819270373
# differential_evolution step 174: f(x)= 17.671603819270373
# differential_evolution step 175: f(x)= 17.671603819270373
# differential_evolution step 176: f(x)= 17.671603819270373
# differential_evolution step 177: f(x)= 17.671603819270373
# differential_evolution step 178: f(x)= 17.671603819270373
# differential_evolution step 179: f(x)= 17.671603819270373
# differential_evolution step 180: f(x)= 16.298147776486214
# differential_evolution step 181: f(x)= 14.622209166623291
# differential_evolution step 182: f(x)= 14.622209166623291
# differential_evolution step 183: f(x)= 13.580573139467608
# differential_evolution step 184: f(x)= 13.580573139467608
# differential_evolution step 185: f(x)= 13.580573139467608
# differential_evolution step 186: f(x)= 13.580573139467608
# differential_evolution step 187: f(x)= 13.580573139467608
# differential_evolution step 188: f(x)= 13.580573139467608
# differential_evolution step 189: f(x)= 13.580573139467608
# differential_evolution step 190: f(x)= 13.580573139467608
# differential_evolution step 191: f(x)= 13.580573139467608
# differential_evolution step 192: f(x)= 13.580573139467608
# differential_evolution step 193: f(x)= 13.580573139467608
# differential_evolution step 194: f(x)= 13.25123484965844
# differential_evolution step 195: f(x)= 13.25123484965844
# differential_evolution step 196: f(x)= 13.25123484965844
# differential_evolution step 197: f(x)= 13.25123484965844
# differential_evolution step 198: f(x)= 13.25123484965844
# differential_evolution step 199: f(x)= 13.25123484965844
# differential_evolution step 200: f(x)= 13.25123484965844
# differential_evolution step 201: f(x)= 13.25123484965844
# differential_evolution step 202: f(x)= 13.25123484965844
# differential_evolution step 203: f(x)= 13.25123484965844
# differential_evolution step 204: f(x)= 13.25123484965844
# differential_evolution step 205: f(x)= 13.25123484965844
# differential_evolution step 206: f(x)= 13.25123484965844
# differential_evolution step 207: f(x)= 13.25123484965844
# differential_evolution step 208: f(x)= 13.25123484965844
# differential_evolution step 209: f(x)= 13.25123484965844
# differential_evolution step 210: f(x)= 13.25123484965844
# differential_evolution step 211: f(x)= 13.25123484965844
# differential_evolution step 212: f(x)= 13.25123484965844
# differential_evolution step 213: f(x)= 13.25123484965844
# differential_evolution step 214: f(x)= 13.25123484965844
# differential_evolution step 215: f(x)= 13.25123484965844
# differential_evolution step 216: f(x)= 13.25123484965844
# differential_evolution step 217: f(x)= 13.25123484965844
# differential_evolution step 218: f(x)= 13.25123484965844
# differential_evolution step 219: f(x)= 13.25123484965844
# differential_evolution step 220: f(x)= 13.25123484965844
# differential_evolution step 221: f(x)= 12.211375061904194
# differential_evolution step 222: f(x)= 12.211375061904194
# differential_evolution step 223: f(x)= 12.211375061904194
# differential_evolution step 224: f(x)= 12.211375061904194
# differential_evolution step 225: f(x)= 12.211375061904194
# differential_evolution step 226: f(x)= 11.879597943836131
# differential_evolution step 227: f(x)= 11.879597943836131
# differential_evolution step 228: f(x)= 11.879597943836131
# differential_evolution step 229: f(x)= 11.879597943836131
# differential_evolution step 230: f(x)= 11.879597943836131
# differential_evolution step 231: f(x)= 11.879597943836131
# differential_evolution step 232: f(x)= 11.879597943836131
# differential_evolution step 233: f(x)= 11.879597943836131
# differential_evolution step 234: f(x)= 11.879597943836131
# differential_evolution step 235: f(x)= 11.879597943836131
# differential_evolution step 236: f(x)= 11.879597943836131
# differential_evolution step 237: f(x)= 11.879597943836131
# differential_evolution step 238: f(x)= 11.879597943836131
# differential_evolution step 239: f(x)= 11.879597943836131
# differential_evolution step 240: f(x)= 11.879597943836131
# differential_evolution step 241: f(x)= 11.508672476227613
# differential_evolution step 242: f(x)= 11.508672476227613
# differential_evolution step 243: f(x)= 11.508672476227613
# differential_evolution step 244: f(x)= 11.508672476227613
# differential_evolution step 245: f(x)= 10.91778076729007
# differential_evolution step 246: f(x)= 10.91778076729007
# differential_evolution step 247: f(x)= 10.91778076729007
# differential_evolution step 248: f(x)= 10.91778076729007
# differential_evolution step 249: f(x)= 10.91778076729007
# differential_evolution step 250: f(x)= 10.91778076729007
# differential_evolution step 251: f(x)= 10.91778076729007
# differential_evolution step 252: f(x)= 10.91778076729007
# differential_evolution step 253: f(x)= 10.91778076729007
# differential_evolution step 254: f(x)= 10.91778076729007
# differential_evolution step 255: f(x)= 10.91778076729007
# differential_evolution step 256: f(x)= 9.874116805553156
# differential_evolution step 257: f(x)= 9.874116805553156
# differential_evolution step 258: f(x)= 9.874116805553156
# differential_evolution step 259: f(x)= 9.874116805553156
# differential_evolution step 260: f(x)= 9.874116805553156
# differential_evolution step 261: f(x)= 9.874116805553156
# differential_evolution step 262: f(x)= 9.874116805553156
# differential_evolution step 263: f(x)= 9.874116805553156
# differential_evolution step 264: f(x)= 9.874116805553156
# differential_evolution step 265: f(x)= 9.874116805553156
# differential_evolution step 266: f(x)= 9.874116805553156
# differential_evolution step 267: f(x)= 9.874116805553156
# differential_evolution step 268: f(x)= 9.874116805553156
# differential_evolution step 269: f(x)= 9.874116805553156
# differential_evolution step 270: f(x)= 9.874116805553156
# differential_evolution step 271: f(x)= 9.874116805553156
# differential_evolution step 272: f(x)= 9.874116805553156
# differential_evolution step 273: f(x)= 9.874116805553156
# differential_evolution step 274: f(x)= 9.874116805553156
# differential_evolution step 275: f(x)= 9.874116805553156
# differential_evolution step 276: f(x)= 9.874116805553156
# differential_evolution step 277: f(x)= 9.760484577913044
# differential_evolution step 278: f(x)= 9.384784398949646
# differential_evolution step 279: f(x)= 9.384784398949646
# differential_evolution step 280: f(x)= 9.384784398949646
# differential_evolution step 281: f(x)= 9.384784398949646
# differential_evolution step 282: f(x)= 9.384784398949646
# differential_evolution step 283: f(x)= 9.384784398949646
# differential_evolution step 284: f(x)= 9.384784398949646
# differential_evolution step 285: f(x)= 9.384784398949646
# differential_evolution step 286: f(x)= 9.384784398949646
# differential_evolution step 287: f(x)= 9.384784398949646
# differential_evolution step 288: f(x)= 9.384784398949646
# differential_evolution step 289: f(x)= 9.384784398949646
# differential_evolution step 290: f(x)= 9.384784398949646
# differential_evolution step 291: f(x)= 9.384784398949646
# differential_evolution step 292: f(x)= 9.384784398949646
# differential_evolution step 293: f(x)= 9.384784398949646
# differential_evolution step 294: f(x)= 9.384784398949646
# differential_evolution step 295: f(x)= 9.384784398949646
# differential_evolution step 296: f(x)= 9.2107364842698
# differential_evolution step 297: f(x)= 9.2107364842698
# differential_evolution step 298: f(x)= 9.2107364842698
# differential_evolution step 299: f(x)= 8.994753305525084
# differential_evolution step 300: f(x)= 8.468246846504318
# differential_evolution step 301: f(x)= 8.468246846504318
# differential_evolution step 302: f(x)= 8.468246846504318
# differential_evolution step 303: f(x)= 8.468246846504318
# differential_evolution step 304: f(x)= 8.468246846504318
# differential_evolution step 305: f(x)= 8.468246846504318
# differential_evolution step 306: f(x)= 7.941806785002051
# differential_evolution step 307: f(x)= 7.941806785002051
# differential_evolution step 308: f(x)= 7.941806785002051
# differential_evolution step 309: f(x)= 7.941806785002051
# differential_evolution step 310: f(x)= 7.941806785002051
# differential_evolution step 311: f(x)= 7.941806785002051
# differential_evolution step 312: f(x)= 7.941806785002051
# differential_evolution step 313: f(x)= 7.941806785002051
# differential_evolution step 314: f(x)= 7.941806785002051
# differential_evolution step 315: f(x)= 7.941806785002051
# differential_evolution step 316: f(x)= 7.941806785002051
# differential_evolution step 317: f(x)= 7.941806785002051
# differential_evolution step 318: f(x)= 7.941806785002051
# differential_evolution step 319: f(x)= 7.941806785002051
# differential_evolution step 320: f(x)= 7.941806785002051
# differential_evolution step 321: f(x)= 7.941806785002051
# differential_evolution step 322: f(x)= 7.941806785002051
# differential_evolution step 323: f(x)= 7.909267347864186
# differential_evolution step 324: f(x)= 7.909267347864186
# differential_evolution step 325: f(x)= 7.909267347864186
# differential_evolution step 326: f(x)= 7.909267347864186
# differential_evolution step 327: f(x)= 7.909267347864186
# differential_evolution step 328: f(x)= 7.909267347864186
# differential_evolution step 329: f(x)= 7.909267347864186
# differential_evolution step 330: f(x)= 7.909267347864186
# differential_evolution step 331: f(x)= 7.603899440062308
# differential_evolution step 332: f(x)= 7.603899440062308
# differential_evolution step 333: f(x)= 7.30512782363225
# differential_evolution step 334: f(x)= 7.30512782363225
# differential_evolution step 335: f(x)= 7.30512782363225
# differential_evolution step 336: f(x)= 7.30512782363225
# differential_evolution step 337: f(x)= 7.184169215572021
# differential_evolution step 338: f(x)= 6.944679851841166
# differential_evolution step 339: f(x)= 6.944679851841166
# differential_evolution step 340: f(x)= 6.944679851841166
# differential_evolution step 341: f(x)= 6.944679851841166
# differential_evolution step 342: f(x)= 6.891970971260364
# differential_evolution step 343: f(x)= 6.891970971260364
# differential_evolution step 344: f(x)= 6.891970971260364
# differential_evolution step 345: f(x)= 6.891970971260364
# differential_evolution step 346: f(x)= 6.891970971260364
# differential_evolution step 347: f(x)= 6.891970971260364
# differential_evolution step 348: f(x)= 6.891970971260364
# differential_evolution step 349: f(x)= 6.853795602754694
# differential_evolution step 350: f(x)= 6.853795602754694
# differential_evolution step 351: f(x)= 6.853795602754694
# differential_evolution step 352: f(x)= 6.853795602754694
# differential_evolution step 353: f(x)= 6.853795602754694
# differential_evolution step 354: f(x)= 6.853795602754694
# differential_evolution step 355: f(x)= 6.853795602754694
# differential_evolution step 356: f(x)= 6.8387722433974645
# differential_evolution step 357: f(x)= 6.8387722433974645
# differential_evolution step 358: f(x)= 6.8387722433974645
# differential_evolution step 359: f(x)= 6.8387722433974645
# differential_evolution step 360: f(x)= 6.8387722433974645
# differential_evolution step 361: f(x)= 6.549130346565329
# differential_evolution step 362: f(x)= 6.549130346565329
# differential_evolution step 363: f(x)= 6.549130346565329
# differential_evolution step 364: f(x)= 6.549130346565329
# differential_evolution step 365: f(x)= 6.549130346565329
# differential_evolution step 366: f(x)= 6.549130346565329
# differential_evolution step 367: f(x)= 6.549130346565329
# differential_evolution step 368: f(x)= 6.549130346565329
# differential_evolution step 369: f(x)= 6.549130346565329
# differential_evolution step 370: f(x)= 6.549130346565329
# differential_evolution step 371: f(x)= 6.549130346565329
# differential_evolution step 372: f(x)= 6.549130346565329
# differential_evolution step 373: f(x)= 6.549130346565329
# differential_evolution step 374: f(x)= 6.549130346565329
# differential_evolution step 375: f(x)= 6.549130346565329
# differential_evolution step 376: f(x)= 6.549130346565329
# differential_evolution step 377: f(x)= 6.549130346565329
# differential_evolution step 378: f(x)= 6.549130346565329
# differential_evolution step 379: f(x)= 6.549130346565329
# differential_evolution step 380: f(x)= 6.549130346565329
# differential_evolution step 381: f(x)= 6.549130346565329
# differential_evolution step 382: f(x)= 6.514092699342978
# differential_evolution step 383: f(x)= 6.514092699342978
# differential_evolution step 384: f(x)= 6.332293960239689
# differential_evolution step 385: f(x)= 6.332293960239689
# differential_evolution step 386: f(x)= 6.332293960239689
# differential_evolution step 387: f(x)= 6.332293960239689
# differential_evolution step 388: f(x)= 6.332293960239689
# differential_evolution step 389: f(x)= 6.332293960239689
# differential_evolution step 390: f(x)= 6.332293960239689
# differential_evolution step 391: f(x)= 6.332293960239689
# differential_evolution step 392: f(x)= 6.332293960239689
# differential_evolution step 393: f(x)= 6.332293960239689
# differential_evolution step 394: f(x)= 6.332293960239689
# differential_evolution step 395: f(x)= 6.332293960239689
# differential_evolution step 396: f(x)= 6.332293960239689
# differential_evolution step 397: f(x)= 6.332293960239689
# differential_evolution step 398: f(x)= 6.332293960239689
# differential_evolution step 399: f(x)= 6.332293960239689
# differential_evolution step 400: f(x)= 6.213500914775263
# differential_evolution step 401: f(x)= 6.18849378601287
# differential_evolution step 402: f(x)= 6.18849378601287
# differential_evolution step 403: f(x)= 6.18849378601287
# differential_evolution step 404: f(x)= 6.18849378601287
# differential_evolution step 405: f(x)= 6.053902511229269
# differential_evolution step 406: f(x)= 6.053902511229269
# differential_evolution step 407: f(x)= 6.053902511229269
# differential_evolution step 408: f(x)= 6.053902511229269
# differential_evolution step 409: f(x)= 6.053902511229269
# differential_evolution step 410: f(x)= 6.043541929652304
# differential_evolution step 411: f(x)= 6.043541929652304
# differential_evolution step 412: f(x)= 6.043541929652304
# differential_evolution step 413: f(x)= 6.043541929652304
# differential_evolution step 414: f(x)= 6.043541929652304
# differential_evolution step 415: f(x)= 6.043541929652304
# differential_evolution step 416: f(x)= 6.043541929652304
# differential_evolution step 417: f(x)= 6.043541929652304
# differential_evolution step 418: f(x)= 6.043541929652304
# differential_evolution step 419: f(x)= 6.043541929652304
# differential_evolution step 420: f(x)= 6.043541929652304
# differential_evolution step 421: f(x)= 6.043541929652304
# differential_evolution step 422: f(x)= 6.043541929652304
# differential_evolution step 423: f(x)= 6.043541929652304
# differential_evolution step 424: f(x)= 6.043541929652304
# differential_evolution step 425: f(x)= 6.043541929652304
# differential_evolution step 426: f(x)= 6.043541929652304
# differential_evolution step 427: f(x)= 6.043541929652304
# differential_evolution step 428: f(x)= 6.043541929652304
# differential_evolution step 429: f(x)= 6.043541929652304
# differential_evolution step 430: f(x)= 6.043541929652304
# differential_evolution step 431: f(x)= 6.043541929652304
# differential_evolution step 432: f(x)= 6.043541929652304
# differential_evolution step 433: f(x)= 6.043541929652304
# differential_evolution step 434: f(x)= 6.043541929652304
# differential_evolution step 435: f(x)= 6.043541929652304
# differential_evolution step 436: f(x)= 6.0412096878566315
# differential_evolution step 437: f(x)= 6.0412096878566315
# differential_evolution step 438: f(x)= 6.0412096878566315
# differential_evolution step 439: f(x)= 5.97174272198038
# differential_evolution step 440: f(x)= 5.97174272198038
# differential_evolution step 441: f(x)= 5.97174272198038
# differential_evolution step 442: f(x)= 5.97174272198038
# differential_evolution step 443: f(x)= 5.97174272198038
# differential_evolution step 444: f(x)= 5.97174272198038
# differential_evolution step 445: f(x)= 5.97174272198038
# differential_evolution step 446: f(x)= 5.90768050297592
# differential_evolution step 447: f(x)= 5.90768050297592
# differential_evolution step 448: f(x)= 5.90768050297592
# differential_evolution step 449: f(x)= 5.90768050297592
# differential_evolution step 450: f(x)= 5.90768050297592
# differential_evolution step 451: f(x)= 5.848125214864589
# differential_evolution step 452: f(x)= 5.848125214864589
# differential_evolution step 453: f(x)= 5.848125214864589
# differential_evolution step 454: f(x)= 5.848125214864589
# differential_evolution step 455: f(x)= 5.848125214864589
# differential_evolution step 456: f(x)= 5.84668580417247
# differential_evolution step 457: f(x)= 5.84668580417247
# differential_evolution step 458: f(x)= 5.81295403915745
# differential_evolution step 459: f(x)= 5.81295403915745
# differential_evolution step 460: f(x)= 5.81295403915745
# differential_evolution step 461: f(x)= 5.81295403915745
# differential_evolution step 462: f(x)= 5.81295403915745
# differential_evolution step 463: f(x)= 5.81295403915745
# differential_evolution step 464: f(x)= 5.81295403915745
# differential_evolution step 465: f(x)= 5.81295403915745
# differential_evolution step 466: f(x)= 5.81295403915745
# differential_evolution step 467: f(x)= 5.81295403915745
# differential_evolution step 468: f(x)= 5.81295403915745
# differential_evolution step 469: f(x)= 5.81295403915745
# differential_evolution step 470: f(x)= 5.81295403915745
# differential_evolution step 471: f(x)= 5.81295403915745
# differential_evolution step 472: f(x)= 5.81295403915745
# differential_evolution step 473: f(x)= 5.81295403915745
# differential_evolution step 474: f(x)= 5.81295403915745
# differential_evolution step 475: f(x)= 5.81295403915745
# differential_evolution step 476: f(x)= 5.81295403915745
# differential_evolution step 477: f(x)= 5.81295403915745
# differential_evolution step 478: f(x)= 5.796234429666225
# differential_evolution step 479: f(x)= 5.796234429666225
# differential_evolution step 480: f(x)= 5.796234429666225
# differential_evolution step 481: f(x)= 5.796234429666225
# differential_evolution step 482: f(x)= 5.796234429666225
# differential_evolution step 483: f(x)= 5.796234429666225
# differential_evolution step 484: f(x)= 5.7746219626403
# differential_evolution step 485: f(x)= 5.728893481795816
# differential_evolution step 486: f(x)= 5.712419878557871
# differential_evolution step 487: f(x)= 5.712419878557871
# differential_evolution step 488: f(x)= 5.712419878557871
# differential_evolution step 489: f(x)= 5.710256883735444
# differential_evolution step 490: f(x)= 5.710256883735444
# differential_evolution step 491: f(x)= 5.710256883735444
# differential_evolution step 492: f(x)= 5.710256883735444
# differential_evolution step 493: f(x)= 5.710256883735444
# differential_evolution step 494: f(x)= 5.710256883735444
# differential_evolution step 495: f(x)= 5.710256883735444
# differential_evolution step 496: f(x)= 5.710256883735444
# differential_evolution step 497: f(x)= 5.675344378575372
# differential_evolution step 498: f(x)= 5.675344378575372
# differential_evolution step 499: f(x)= 5.675344378575372
# differential_evolution step 500: f(x)= 5.675344378575372
# differential_evolution step 501: f(x)= 5.665597766078709
# differential_evolution step 502: f(x)= 5.665597766078709
# differential_evolution step 503: f(x)= 5.63795478743793
# differential_evolution step 504: f(x)= 5.63795478743793
# differential_evolution step 505: f(x)= 5.63795478743793
# differential_evolution step 506: f(x)= 5.570802084897315
# differential_evolution step 507: f(x)= 5.570802084897315
# differential_evolution step 508: f(x)= 5.570802084897315
# differential_evolution step 509: f(x)= 5.570802084897315
# differential_evolution step 510: f(x)= 5.570802084897315
# differential_evolution step 511: f(x)= 5.570802084897315
# differential_evolution step 512: f(x)= 5.570802084897315
# differential_evolution step 513: f(x)= 5.570802084897315
# differential_evolution step 514: f(x)= 5.515280546533524
# differential_evolution step 515: f(x)= 5.515280546533524
# differential_evolution step 516: f(x)= 5.515280546533524
# differential_evolution step 517: f(x)= 5.515280546533524
# differential_evolution step 518: f(x)= 5.515280546533524
# differential_evolution step 519: f(x)= 5.515280546533524
# differential_evolution step 520: f(x)= 5.515280546533524
# differential_evolution step 521: f(x)= 5.515280546533524
# differential_evolution step 522: f(x)= 5.515280546533524
# differential_evolution step 523: f(x)= 5.515280546533524
# differential_evolution step 524: f(x)= 5.515280546533524
# differential_evolution step 525: f(x)= 5.515280546533524
# differential_evolution step 526: f(x)= 5.515280546533524
# differential_evolution step 527: f(x)= 5.515280546533524
# differential_evolution step 528: f(x)= 5.515280546533524
# differential_evolution step 529: f(x)= 5.515280546533524
# differential_evolution step 530: f(x)= 5.515280546533524
# differential_evolution step 531: f(x)= 5.515280546533524
# differential_evolution step 532: f(x)= 5.515280546533524
# differential_evolution step 533: f(x)= 5.515280546533524
# differential_evolution step 534: f(x)= 5.515280546533524
# differential_evolution step 535: f(x)= 5.515280546533524
# differential_evolution step 536: f(x)= 5.515280546533524
# differential_evolution step 537: f(x)= 5.515280546533524
# differential_evolution step 538: f(x)= 5.487990684332219
# differential_evolution step 539: f(x)= 5.487990684332219
# differential_evolution step 540: f(x)= 5.461187319404212
# differential_evolution step 541: f(x)= 5.461187319404212
# differential_evolution step 542: f(x)= 5.461187319404212
# differential_evolution step 543: f(x)= 5.439027428401981
# differential_evolution step 544: f(x)= 5.439027428401981
# differential_evolution step 545: f(x)= 5.439027428401981
# differential_evolution step 546: f(x)= 5.439027428401981
# differential_evolution step 547: f(x)= 5.439027428401981
# differential_evolution step 548: f(x)= 5.439027428401981
# differential_evolution step 549: f(x)= 5.439027428401981
# differential_evolution step 550: f(x)= 5.439027428401981
# differential_evolution step 551: f(x)= 5.439027428401981
# differential_evolution step 552: f(x)= 5.439027428401981
# differential_evolution step 553: f(x)= 5.439027428401981
# differential_evolution step 554: f(x)= 5.439027428401981
# differential_evolution step 555: f(x)= 5.439027428401981
# differential_evolution step 556: f(x)= 5.439027428401981
# differential_evolution step 557: f(x)= 5.439027428401981
# differential_evolution step 558: f(x)= 5.439027428401981
# differential_evolution step 559: f(x)= 5.409132200895424
# differential_evolution step 560: f(x)= 5.409132200895424
# differential_evolution step 561: f(x)= 5.409132200895424
# differential_evolution step 562: f(x)= 5.409132200895424
# differential_evolution step 563: f(x)= 5.409132200895424
# differential_evolution step 564: f(x)= 5.344623216825285
# differential_evolution step 565: f(x)= 5.344623216825285
# differential_evolution step 566: f(x)= 5.344623216825285
# differential_evolution step 567: f(x)= 5.344623216825285
# differential_evolution step 568: f(x)= 5.344623216825285
# differential_evolution step 569: f(x)= 5.344623216825285
# differential_evolution step 570: f(x)= 5.344623216825285
# differential_evolution step 571: f(x)= 5.344623216825285
# differential_evolution step 572: f(x)= 5.344623216825285
# differential_evolution step 573: f(x)= 5.344623216825285
# differential_evolution step 574: f(x)= 5.344623216825285
# differential_evolution step 575: f(x)= 5.344623216825285
# differential_evolution step 576: f(x)= 5.344623216825285
# differential_evolution step 577: f(x)= 5.344623216825285
# differential_evolution step 578: f(x)= 5.344623216825285
# differential_evolution step 579: f(x)= 5.344623216825285
# differential_evolution step 580: f(x)= 5.344623216825285
# differential_evolution step 581: f(x)= 5.344623216825285
# differential_evolution step 582: f(x)= 5.344623216825285
# differential_evolution step 583: f(x)= 5.344623216825285
# differential_evolution step 584: f(x)= 5.344623216825285
# differential_evolution step 585: f(x)= 5.344623216825285
# differential_evolution step 586: f(x)= 5.344623216825285
# differential_evolution step 587: f(x)= 5.344623216825285
# differential_evolution step 588: f(x)= 5.344623216825285
# differential_evolution step 589: f(x)= 5.344623216825285
# differential_evolution step 590: f(x)= 5.336684124924591
# differential_evolution step 591: f(x)= 5.336684124924591
# differential_evolution step 592: f(x)= 5.336684124924591
# differential_evolution step 593: f(x)= 5.336684124924591
# differential_evolution step 594: f(x)= 5.336684124924591
# differential_evolution step 595: f(x)= 5.336684124924591
# differential_evolution step 596: f(x)= 5.336684124924591
# differential_evolution step 597: f(x)= 5.336684124924591
# differential_evolution step 598: f(x)= 5.336684124924591
# differential_evolution step 599: f(x)= 5.336684124924591
# differential_evolution step 600: f(x)= 5.336684124924591
# differential_evolution step 601: f(x)= 5.336684124924591
# differential_evolution step 602: f(x)= 5.336684124924591
# differential_evolution step 603: f(x)= 5.336684124924591
# differential_evolution step 604: f(x)= 5.336684124924591
# differential_evolution step 605: f(x)= 5.336684124924591
# differential_evolution step 606: f(x)= 5.336684124924591
# differential_evolution step 607: f(x)= 5.336684124924591
# differential_evolution step 608: f(x)= 5.336684124924591
# differential_evolution step 609: f(x)= 5.336684124924591
# differential_evolution step 610: f(x)= 5.336684124924591
# differential_evolution step 611: f(x)= 5.336684124924591
# differential_evolution step 612: f(x)= 5.336684124924591
# differential_evolution step 613: f(x)= 5.336684124924591
# differential_evolution step 614: f(x)= 5.336684124924591
# differential_evolution step 615: f(x)= 5.336684124924591
# differential_evolution step 616: f(x)= 5.336684124924591
# differential_evolution step 617: f(x)= 5.336684124924591
# differential_evolution step 618: f(x)= 5.336684124924591
# differential_evolution step 619: f(x)= 5.313022402758894
# differential_evolution step 620: f(x)= 5.313022402758894
# differential_evolution step 621: f(x)= 5.313022402758894
# differential_evolution step 622: f(x)= 5.313022402758894
# differential_evolution step 623: f(x)= 5.313022402758894
# differential_evolution step 624: f(x)= 5.313022402758894
# differential_evolution step 625: f(x)= 5.313022402758894
# differential_evolution step 626: f(x)= 5.313022402758894
# differential_evolution step 627: f(x)= 5.313022402758894
# differential_evolution step 628: f(x)= 5.313022402758894
# differential_evolution step 629: f(x)= 5.28407337400557
# differential_evolution step 630: f(x)= 5.28407337400557
# differential_evolution step 631: f(x)= 5.28407337400557
# differential_evolution step 632: f(x)= 5.28407337400557
# differential_evolution step 633: f(x)= 5.28407337400557
# differential_evolution step 634: f(x)= 5.28407337400557
# differential_evolution step 635: f(x)= 5.28407337400557
# differential_evolution step 636: f(x)= 5.28407337400557
# differential_evolution step 637: f(x)= 5.2839285078280005
# differential_evolution step 638: f(x)= 5.2839285078280005
# differential_evolution step 639: f(x)= 5.275859036429152
# differential_evolution step 640: f(x)= 5.275859036429152
# differential_evolution step 641: f(x)= 5.275859036429152
# differential_evolution step 642: f(x)= 5.265061315797483
# differential_evolution step 643: f(x)= 5.265061315797483
# differential_evolution step 644: f(x)= 5.265061315797483
# differential_evolution step 645: f(x)= 5.2600653967114015
# differential_evolution step 646: f(x)= 5.2600653967114015
# differential_evolution step 681: f(x)= 5.240685625887407
# differential_evolution step 682: f(x)= 5.240685625887407
# differential_evolution step 683: f(x)= 5.240685625887407
# differential_evolution step 684: f(x)= 5.240685625887407
# differential_evolution step 685: f(x)= 5.227161088974216
# differential_evolution step 686: f(x)= 5.213832157752302
# differential_evolution step 687: f(x)= 5.213832157752302
# differential_evolution step 688: f(x)= 5.213832157752302
# differential_evolution step 689: f(x)= 5.213832157752302
# differential_evolution step 690: f(x)= 5.1738031696629365
# differential_evolution step 691: f(x)= 5.1738031696629365
# differential_evolution step 692: f(x)= 5.1738031696629365
# differential_evolution step 693: f(x)= 5.1738031696629365
# differential_evolution step 694: f(x)= 5.1738031696629365
# differential_evolution step 695: f(x)= 5.1738031696629365
# differential_evolution step 696: f(x)= 5.1738031696629365
# differential_evolution step 697: f(x)= 5.1738031696629365
# differential_evolution step 698: f(x)= 5.1738031696629365
# differential_evolution step 699: f(x)= 5.16138058447769
# differential_evolution step 700: f(x)= 5.16138058447769
# differential_evolution step 701: f(x)= 5.16138058447769
# differential_evolution step 702: f(x)= 5.16138058447769
# differential_evolution step 703: f(x)= 5.16138058447769
# differential_evolution step 704: f(x)= 5.16138058447769
# differential_evolution step 705: f(x)= 5.16138058447769
# differential_evolution step 706: f(x)= 5.16138058447769
# differential_evolution step 707: f(x)= 5.16138058447769
# differential_evolution step 708: f(x)= 5.16138058447769
# differential_evolution step 709: f(x)= 5.16138058447769
# differential_evolution step 710: f(x)= 5.16138058447769
# differential_evolution step 711: f(x)= 5.16138058447769
# differential_evolution step 712: f(x)= 5.16138058447769
# differential_evolution step 713: f(x)= 5.16138058447769
# differential_evolution step 714: f(x)= 5.16138058447769
# differential_evolution step 715: f(x)= 5.16138058447769
# differential_evolution step 716: f(x)= 5.16138058447769
# differential_evolution step 717: f(x)= 5.16138058447769
# differential_evolution step 718: f(x)= 5.160772988598803
# differential_evolution step 719: f(x)= 5.160772988598803
# differential_evolution step 720: f(x)= 5.160772988598803
# differential_evolution step 721: f(x)= 5.160772988598803
# differential_evolution step 722: f(x)= 5.154322512615905
# differential_evolution step 723: f(x)= 5.154322512615905
# differential_evolution step 724: f(x)= 5.154322512615905
# differential_evolution step 725: f(x)= 5.154322512615905
# differential_evolution step 726: f(x)= 5.154322512615905
# differential_evolution step 727: f(x)= 5.154322512615905
# differential_evolution step 728: f(x)= 5.145464498547129
# differential_evolution step 729: f(x)= 5.145464498547129
# differential_evolution step 730: f(x)= 5.145464498547129
# differential_evolution step 731: f(x)= 5.141203884208328
# differential_evolution step 732: f(x)= 5.141203884208328
# differential_evolution step 733: f(x)= 5.141203884208328
# differential_evolution step 734: f(x)= 5.141203884208328
# differential_evolution step 735: f(x)= 5.141203884208328
# differential_evolution step 736: f(x)= 5.141203884208328
# differential_evolution step 737: f(x)= 5.141203884208328
# differential_evolution step 738: f(x)= 5.141203884208328
# differential_evolution step 739: f(x)= 5.141203884208328
# differential_evolution step 740: f(x)= 5.141203884208328
# differential_evolution step 741: f(x)= 5.141203884208328
# differential_evolution step 742: f(x)= 5.141203884208328
# differential_evolution step 743: f(x)= 5.141203884208328
# differential_evolution step 744: f(x)= 5.141203884208328
# differential_evolution step 745: f(x)= 5.141203884208328
# differential_evolution step 746: f(x)= 5.136530693756266
# differential_evolution step 747: f(x)= 5.124174575521593
# differential_evolution step 748: f(x)= 5.1069395431519204
# differential_evolution step 749: f(x)= 5.1069395431519204
# differential_evolution step 750: f(x)= 5.1069395431519204
# differential_evolution step 751: f(x)= 5.1069395431519204
# differential_evolution step 752: f(x)= 5.1069395431519204
# differential_evolution step 753: f(x)= 5.1069395431519204
# differential_evolution step 754: f(x)= 5.1069395431519204
# differential_evolution step 755: f(x)= 5.1069395431519204
# differential_evolution step 756: f(x)= 5.1069395431519204
# differential_evolution step 757: f(x)= 5.1069395431519204
# differential_evolution step 758: f(x)= 5.1069395431519204
# differential_evolution step 759: f(x)= 5.1069395431519204
# differential_evolution step 760: f(x)= 5.1069395431519204
# differential_evolution step 761: f(x)= 5.1069395431519204
# differential_evolution step 762: f(x)= 5.1069395431519204
# differential_evolution step 763: f(x)= 5.1069395431519204
# differential_evolution step 764: f(x)= 5.1069395431519204
# differential_evolution step 765: f(x)= 5.1069395431519204
# differential_evolution step 766: f(x)= 5.1069395431519204
# differential_evolution step 767: f(x)= 5.1069395431519204
# differential_evolution step 768: f(x)= 5.1069395431519204
# differential_evolution step 769: f(x)= 5.1069395431519204
# differential_evolution step 770: f(x)= 5.1069395431519204
# differential_evolution step 771: f(x)= 5.1069395431519204
# differential_evolution step 772: f(x)= 5.1069395431519204
# differential_evolution step 773: f(x)= 5.1069395431519204
# differential_evolution step 774: f(x)= 5.1069395431519204
# differential_evolution step 775: f(x)= 5.1069395431519204
# differential_evolution step 776: f(x)= 5.1069395431519204
# differential_evolution step 777: f(x)= 5.1069395431519204
# differential_evolution step 778: f(x)= 5.1069395431519204
# differential_evolution step 779: f(x)= 5.1069395431519204
# differential_evolution step 780: f(x)= 5.1069395431519204
# differential_evolution step 781: f(x)= 5.1069395431519204
# differential_evolution step 782: f(x)= 5.1069395431519204
# differential_evolution step 783: f(x)= 5.1069395431519204
# differential_evolution step 784: f(x)= 5.1069395431519204
# differential_evolution step 785: f(x)= 5.1069395431519204
# differential_evolution step 786: f(x)= 5.1069395431519204
# differential_evolution step 787: f(x)= 5.1069395431519204
# differential_evolution step 788: f(x)= 5.1069395431519204
# differential_evolution step 789: f(x)= 5.1069395431519204
# differential_evolution step 790: f(x)= 5.1069395431519204
# differential_evolution step 791: f(x)= 5.1069395431519204
# differential_evolution step 792: f(x)= 5.1069395431519204
# differential_evolution step 793: f(x)= 5.1069395431519204
# differential_evolution step 794: f(x)= 5.1069395431519204
# differential_evolution step 795: f(x)= 5.1069395431519204
# differential_evolution step 796: f(x)= 5.1069395431519204
# differential_evolution step 797: f(x)= 5.1069395431519204
# differential_evolution step 798: f(x)= 5.1069395431519204
# differential_evolution step 799: f(x)= 5.1069395431519204
# differential_evolution step 800: f(x)= 5.1069395431519204
# differential_evolution step 801: f(x)= 5.1069395431519204
# differential_evolution step 802: f(x)= 5.1069395431519204
# differential_evolution step 803: f(x)= 5.104908786777846
# differential_evolution step 804: f(x)= 5.104908786777846
# differential_evolution step 805: f(x)= 5.104908786777846
# differential_evolution step 806: f(x)= 5.104908786777846
# differential_evolution step 807: f(x)= 5.104908786777846
# differential_evolution step 808: f(x)= 5.104908786777846
# differential_evolution step 809: f(x)= 5.104908786777846
# differential_evolution step 810: f(x)= 5.104908786777846
# differential_evolution step 811: f(x)= 5.104908786777846
# differential_evolution step 812: f(x)= 5.104908786777846
# differential_evolution step 813: f(x)= 5.104908786777846
# differential_evolution step 814: f(x)= 5.095851755867207
# differential_evolution step 815: f(x)= 5.095851755867207
# differential_evolution step 816: f(x)= 5.095851755867207
# differential_evolution step 817: f(x)= 5.092992968397116
# differential_evolution step 818: f(x)= 5.092992968397116
# differential_evolution step 819: f(x)= 5.092992968397116
# differential_evolution step 820: f(x)= 5.092992968397116
# differential_evolution step 821: f(x)= 5.092992968397116
# differential_evolution step 822: f(x)= 5.092992968397116
# differential_evolution step 823: f(x)= 5.092992968397116
# differential_evolution step 824: f(x)= 5.061891631188229
# differential_evolution step 825: f(x)= 5.061891631188229
# differential_evolution step 826: f(x)= 5.061891631188229
# differential_evolution step 827: f(x)= 5.061891631188229
# differential_evolution step 828: f(x)= 5.061891631188229
# differential_evolution step 829: f(x)= 5.056133949899039
# differential_evolution step 830: f(x)= 5.056133949899039
# differential_evolution step 831: f(x)= 5.056133949899039
# differential_evolution step 832: f(x)= 5.056133949899039
# differential_evolution step 833: f(x)= 5.056133949899039
# differential_evolution step 834: f(x)= 5.056133949899039
# differential_evolution step 835: f(x)= 5.056133949899039
# differential_evolution step 836: f(x)= 5.056133949899039
# differential_evolution step 837: f(x)= 5.056133949899039
# differential_evolution step 838: f(x)= 5.056133949899039
# differential_evolution step 839: f(x)= 5.056133949899039
# differential_evolution step 840: f(x)= 5.056133949899039
# differential_evolution step 841: f(x)= 5.056133949899039
# differential_evolution step 842: f(x)= 5.056133949899039
# differential_evolution step 843: f(x)= 5.056133949899039
# differential_evolution step 844: f(x)= 5.056133949899039
# differential_evolution step 845: f(x)= 5.056133949899039
# differential_evolution step 846: f(x)= 5.056133949899039
# differential_evolution step 847: f(x)= 5.056133949899039
# differential_evolution step 848: f(x)= 5.056133949899039
# differential_evolution step 849: f(x)= 5.056133949899039
# differential_evolution step 850: f(x)= 5.0555148786510244
# differential_evolution step 851: f(x)= 5.0555148786510244
# differential_evolution step 852: f(x)= 5.0555148786510244
# differential_evolution step 853: f(x)= 5.0555148786510244
# differential_evolution step 854: f(x)= 5.0555148786510244
# differential_evolution step 855: f(x)= 5.052988697952349
# differential_evolution step 856: f(x)= 5.052988697952349
# differential_evolution step 857: f(x)= 5.052988697952349
# differential_evolution step 858: f(x)= 5.052988697952349
# differential_evolution step 859: f(x)= 5.052988697952349
# differential_evolution step 860: f(x)= 5.052988697952349
# differential_evolution step 861: f(x)= 5.052988697952349
# differential_evolution step 862: f(x)= 5.039352462890232
# differential_evolution step 863: f(x)= 5.039352462890232
# differential_evolution step 864: f(x)= 5.039352462890232
# differential_evolution step 865: f(x)= 5.039352462890232
# differential_evolution step 866: f(x)= 5.039352462890232
# differential_evolution step 867: f(x)= 5.039352462890232
# differential_evolution step 868: f(x)= 5.039352462890232
# differential_evolution step 869: f(x)= 5.039352462890232
# differential_evolution step 870: f(x)= 5.039352462890232
# differential_evolution step 871: f(x)= 5.039352462890232
# differential_evolution step 872: f(x)= 5.039352462890232
# differential_evolution step 873: f(x)= 5.039352462890232
# differential_evolution step 874: f(x)= 5.039352462890232
# differential_evolution step 875: f(x)= 5.039352462890232
# differential_evolution step 876: f(x)= 5.039352462890232
# differential_evolution step 877: f(x)= 5.039352462890232
# differential_evolution step 878: f(x)= 5.039352462890232
# differential_evolution step 879: f(x)= 5.039352462890232
# differential_evolution step 880: f(x)= 5.039352462890232
# differential_evolution step 881: f(x)= 5.039352462890232
# differential_evolution step 882: f(x)= 5.039352462890232
# differential_evolution step 883: f(x)= 5.039352462890232
# differential_evolution step 884: f(x)= 5.039352462890232
# differential_evolution step 885: f(x)= 5.039352462890232
# differential_evolution step 886: f(x)= 5.039352462890232
# differential_evolution step 887: f(x)= 5.039352462890232
# differential_evolution step 888: f(x)= 5.039352462890232
# differential_evolution step 889: f(x)= 5.039352462890232
# differential_evolution step 890: f(x)= 5.039352462890232
# differential_evolution step 891: f(x)= 5.039352462890232
# differential_evolution step 892: f(x)= 5.035961959771888
# differential_evolution step 893: f(x)= 5.035961959771888
# differential_evolution step 894: f(x)= 5.035961959771888
# differential_evolution step 895: f(x)= 5.035961959771888
# differential_evolution step 896: f(x)= 5.035961959771888
# differential_evolution step 897: f(x)= 5.035961959771888
# differential_evolution step 898: f(x)= 5.035961959771888
# differential_evolution step 899: f(x)= 5.035961959771888
# differential_evolution step 900: f(x)= 5.035961959771888
# differential_evolution step 901: f(x)= 5.035961959771888
# differential_evolution step 902: f(x)= 5.035961959771888
# differential_evolution step 903: f(x)= 5.035961959771888
# differential_evolution step 904: f(x)= 5.029461680018048
# differential_evolution step 905: f(x)= 5.029461680018048
# differential_evolution step 906: f(x)= 5.029461680018048
# differential_evolution step 907: f(x)= 5.026098054780157
# differential_evolution step 908: f(x)= 5.026098054780157
# differential_evolution step 909: f(x)= 5.026098054780157
# differential_evolution step 910: f(x)= 5.02316553723911
# differential_evolution step 911: f(x)= 5.02316553723911
# differential_evolution step 912: f(x)= 5.020980562267128
# differential_evolution step 913: f(x)= 5.020980562267128
# differential_evolution step 914: f(x)= 5.020980562267128
# differential_evolution step 915: f(x)= 5.020980562267128
# differential_evolution step 916: f(x)= 5.020980562267128
# differential_evolution step 917: f(x)= 5.020980562267128
# differential_evolution step 918: f(x)= 5.020980562267128
# differential_evolution step 919: f(x)= 5.020980562267128
# differential_evolution step 920: f(x)= 5.020980562267128
# differential_evolution step 921: f(x)= 5.020980562267128
# differential_evolution step 922: f(x)= 5.020980562267128
# differential_evolution step 923: f(x)= 5.020980562267128
# differential_evolution step 924: f(x)= 5.020980562267128
# differential_evolution step 925: f(x)= 5.020980562267128
# differential_evolution step 926: f(x)= 5.020980562267128
# differential_evolution step 927: f(x)= 5.020980562267128
# differential_evolution step 928: f(x)= 5.020980562267128
# differential_evolution step 929: f(x)= 5.019378290748369
# differential_evolution step 930: f(x)= 5.019378290748369
# differential_evolution step 931: f(x)= 5.019378290748369
# differential_evolution step 932: f(x)= 5.019378290748369
# differential_evolution step 933: f(x)= 5.019378290748369
# differential_evolution step 934: f(x)= 5.019378290748369
# differential_evolution step 935: f(x)= 5.019378290748369
# differential_evolution step 936: f(x)= 5.016748103311192
# differential_evolution step 937: f(x)= 5.016748103311192
# differential_evolution step 938: f(x)= 5.016748103311192
# differential_evolution step 939: f(x)= 5.013284868083872
# differential_evolution step 940: f(x)= 5.004909167331709
# differential_evolution step 941: f(x)= 4.996647756008475
# differential_evolution step 942: f(x)= 4.996647756008475
# differential_evolution step 943: f(x)= 4.996647756008475
# differential_evolution step 944: f(x)= 4.986609458507989
# differential_evolution step 945: f(x)= 4.975246975424172
# differential_evolution step 946: f(x)= 4.975246975424172
# differential_evolution step 947: f(x)= 4.975246975424172
# differential_evolution step 948: f(x)= 4.975246975424172
# differential_evolution step 949: f(x)= 4.975246975424172
# differential_evolution step 950: f(x)= 4.975246975424172
# differential_evolution step 951: f(x)= 4.975246975424172
# differential_evolution step 952: f(x)= 4.975246975424172
# differential_evolution step 953: f(x)= 4.975246975424172
# differential_evolution step 954: f(x)= 4.975246975424172
# differential_evolution step 955: f(x)= 4.975246975424172
# differential_evolution step 956: f(x)= 4.975246975424172
# differential_evolution step 957: f(x)= 4.975246975424172
# differential_evolution step 958: f(x)= 4.975246975424172
# differential_evolution step 959: f(x)= 4.975246975424172
# differential_evolution step 960: f(x)= 4.975246975424172
# differential_evolution step 961: f(x)= 4.975246975424172
# differential_evolution step 962: f(x)= 4.975246975424172
# differential_evolution step 963: f(x)= 4.975246975424172
# differential_evolution step 964: f(x)= 4.975246975424172
# differential_evolution step 965: f(x)= 4.970863834246528
# differential_evolution step 966: f(x)= 4.970863834246528
# differential_evolution step 967: f(x)= 4.970863834246528
# differential_evolution step 968: f(x)= 4.970863834246528
# differential_evolution step 969: f(x)= 4.970863834246528
# differential_evolution step 970: f(x)= 4.970863834246528
# differential_evolution step 971: f(x)= 4.970863834246528
# differential_evolution step 972: f(x)= 4.970863834246528
# differential_evolution step 973: f(x)= 4.970863834246528
# differential_evolution step 974: f(x)= 4.970863834246528
# differential_evolution step 975: f(x)= 4.970863834246528
# differential_evolution step 976: f(x)= 4.960163436265398
# differential_evolution step 977: f(x)= 4.960163436265398
# differential_evolution step 978: f(x)= 4.960163436265398
# differential_evolution step 979: f(x)= 4.960163436265398
# differential_evolution step 980: f(x)= 4.960163436265398
# differential_evolution step 981: f(x)= 4.960163436265398
# differential_evolution step 982: f(x)= 4.960163436265398
# differential_evolution step 983: f(x)= 4.960163436265398
# differential_evolution step 984: f(x)= 4.952908707159248
# differential_evolution step 985: f(x)= 4.952908707159248
# differential_evolution step 986: f(x)= 4.952908707159248
# differential_evolution step 987: f(x)= 4.952908707159248
# differential_evolution step 988: f(x)= 4.952908707159248
# differential_evolution step 989: f(x)= 4.952908707159248
# differential_evolution step 990: f(x)= 4.952908707159248
# differential_evolution step 991: f(x)= 4.952908707159248
# differential_evolution step 992: f(x)= 4.942072863389025
# differential_evolution step 993: f(x)= 4.942072863389025
# differential_evolution step 994: f(x)= 4.942072863389025
# differential_evolution step 995: f(x)= 4.942072863389025
# differential_evolution step 996: f(x)= 4.942072863389025
# differential_evolution step 997: f(x)= 4.942072863389025
# differential_evolution step 998: f(x)= 4.942072863389025
# differential_evolution step 999: f(x)= 4.942072863389025
# differential_evolution step 1000: f(x)= 4.942072863389025
# Polishing solution with 'L-BFGS-B'
# Optimize parameters with differential_evolution: [ 0.43352155 49.40661409  0.35958325 13.79932095  0.21406809 12.76165794
#   3.71126706 59.63765886  1.31859126  1.52052902  0.31816007 25.90834464
#   1.05574667 19.18188203  0.1        36.18497069]
# Chi quadro minimo: 4.9310303380843346

# %%
# Plots:
params_curve_4, covariance_4 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params4, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[3], red_chi[3] = save_params(params_curve_4, covariance_4, radial_profile_HA, radial_profile_error_HA, x_axes, 4, line_name="Four", output_prefix="fit")

aic[3] = AIC(x_axes, radial_profile_HA, chi_quadr[3], params_curve_4)
bic[3] = BIC(x_axes, radial_profile_HA, chi_quadr[3], params_curve_4)
print(aic[3], chi_quadr[3], bic[3], len(params_curve_4))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_4)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_4[12:16]), color='orange', linestyle='--', label='Sérsic 4')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)

plt.savefig('AIC_4', bbox_inches='tight')
# Out:
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_10796\111436280.py:9: RuntimeWarning: overflow encountered in exp
#   return I_e * np.exp(-b_n * ((r / r_e)**(1 / n) - 1))
# C:\Users\ISAFA\anaconda3\Lib\site-packages\scipy\signal\_signaltools.py:568: RuntimeWarning: invalid value encountered in multiply
#   ret = ifft(sp1 * sp2, fshape, axes=axes)
# C:\Users\ISAFA\AppData\Local\Temp\ipykernel_10796\2574878502.py:10: RuntimeWarning: Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#   conv_profile = convolve(profile, kernel, mode='same')
# Optimize parameters with curve fit:
# Sérsic 1: I_e=0.2384, r_e=88.8623, n=0.9124, x_0=-18.7049
# Sérsic 2: I_e=0.2095, r_e=14.3719, n=3.6562, x_0=59.6377
# Sérsic 3: I_e=1.3785, r_e=1.6664, n=0.2685, x_0=25.9367
# Sérsic 4: I_e=0.9481, r_e=20.7695, n=0.0721, x_0=35.8941
# [1.78714313e+01 1.95996243e+02 7.86029611e+00 4.17857763e+03
#  9.36683104e-01 4.15020950e+01 5.65426555e+00 8.34396646e-04
#  1.87424241e+00 4.03729380e-01 1.20829885e+00 2.75315354e-01
#  4.25898477e-01 2.65287471e+00 3.75676175e-02 1.01256773e+00]
# 63.46272407288316
# 102.01694094035304 63.46272407288316 137.14544704869263 16
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds = [

    (0, 20),
    (0, 50),
    (0.1, 10),
    (13, 20),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (55, 65),
    
    (0, 20),
    (0, 50),
    (0.1, 10),
    (20, 28),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (30, 38),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (45, 55),
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params5 = result.x

print("Optimize parameters with differential_evolution:", best_params5)

print("Chi quadro minimo:", result.fun)

# %%
# Plots:
params_curve_5, covariance_5 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params5, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[4], red_chi[4] = save_params(params_curve_5, covariance_5, radial_profile_HA, radial_profile_error_HA, x_axes, 5, line_name="Five", output_prefix="fit")

aic[4] = AIC(x_axes, radial_profile_HA, chi_quadr[4], params_curve_5)
bic[4] = BIC(x_axes, radial_profile_HA, chi_quadr[4], params_curve_5)
print(aic[4], chi_quadr[4], bic[4], len(params_curve_5))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_5)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_5[16:20]),  linestyle='--', label='Sérsic 5')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)
#ax[1].set_ylim(-0.2, 0.2)
plt.savefig('AIC_5', bbox_inches='tight')

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20]) +
        sersic_1d(x_hr, *params[20:24])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =[

    (0, 20),
    (0, 50),
    (0.1, 10),
    (13, 20),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (55, 65),
    
    (0, 20),
    (0, 50),
    (0.1, 10),
    (20, 28),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (30, 38),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (45, 55),
    
    (0, 20),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100)   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params6 = result.x

print("Optimize parameters with differential_evolution:", best_params6)

print("Chi quadro minimo:", result.fun)

# %%
# Plots:
params_curve_6, covariance_6 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params6, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[5], red_chi[5] = save_params(params_curve_6, covariance_6, radial_profile_HA, radial_profile_error_HA, x_axes, 6, line_name="Six", output_prefix="fit")

aic[5] = AIC(x_axes, radial_profile_HA, chi_quadr[5], params_curve_6)
bic[5] = BIC(x_axes, radial_profile_HA, chi_quadr[5], params_curve_6)
print(aic[5], chi_quadr[5], bic[5], len(best_params6))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_6)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[16:20]),  linestyle='--', label='Sérsic 5')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_6[20:24]),  linestyle='--', label='Sérsic 6')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)
#ax[0].tight_layout()

ax[1].plot(x_axes, radial_profile_HA - y_fit)

plt.savefig('AIC_6', bbox_inches='tight')

# %%
def model_convolved(x, *params):
    x_hr = np.linspace(min(x), max(x), 4000)
    profile = (
        sersic_1d(x_hr, *params[0:4]) +
        sersic_1d(x_hr, *params[4:8]) +
        sersic_1d(x_hr, *params[8:12]) +
        sersic_1d(x_hr, *params[12:16]) +
        sersic_1d(x_hr, *params[16:20]) +
        sersic_1d(x_hr, *params[20:24]) +
        sersic_1d(x_hr, *params[24:28])
    )
    kernel = Gaussian1DKernel(stddev=(sigma*len(x_hr))/len(x), x_size=len(x_hr), mode='center')   
    conv_profile = convolve(profile, kernel, mode='same')
    conv_profile_out = np.interp(x, x_hr, conv_profile)
    return conv_profile_out

def chi_squared(params, x, y_obs): #per diff evolution
    y_model = model_convolved(x, *params)
    return np.sum((y_obs - y_model)**2)

# Bounds:
bounds =[
   (0, 20),
    (0, 50),
    (0.1, 10),
    (13, 20),
    
    (0, 20),
    (0, 50),
    (0.1, 10),
    (20, 28),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (30, 38),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (45, 55),

    (0, 20),
    (0, 50),
    (0.1, 10),
    (56, 64),
    
    (0, 20),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100),   # x_0: posizione da 0 a 100

     (0, 20),    # I_e: da 0 a 10 (o un valore ragionevole)
    (0, 50),  # r_e: da 0.1 a 50
    (0.1, 10),  # n: da 0.1 a 10
    (0, 100)   # x_0: posizione da 0 a 100
]
# objective function for differential_evolution
def objective(params):
    return chi_squared(params, x_axes, radial_profile_HA)

# Global fit:
result = differential_evolution(
    objective,
    bounds,
    strategy='best1bin',
    maxiter=1000,
    popsize=20,
    tol=1e-6,
    disp=True,
    polish=True
)

best_params7 = result.x

print("Optimize parameters with differential_evolution:", best_params7)

print("Chi quadro minimo:", result.fun)

# %%
# Plots:
params_curve_7, covariance_7 = curve_fit(lambda x, *params: model_convolved(x, *params), x_axes, radial_profile_HA, p0=best_params7, sigma = radial_profile_error_HA)

print("Optimize parameters with curve fit:")

chi_quadr[6], red_chi[6] = save_params(params_curve_7, covariance_7, radial_profile_HA, radial_profile_error_HA, x_axes, 7, 
                                       line_name="Seven", output_prefix="fit")

aic[6] = AIC(x_axes, radial_profile_HA, chi_quadr[6], params_curve_7)
bic[6] = BIC(x_axes, radial_profile_HA, chi_quadr[6], params_curve_7)
print(aic[6], chi_quadr[6], bic[6], len(best_params7))

# Plots:
xgrid = np.linspace(min(x_axes), max(x_axes), 100)
y_fit = model_convolved(xgrid, *params_curve_7)

fig, ax = plt.subplots(2, 1, figsize=(10, 10), height_ratios=[3, 1])

ax[0].plot(x_axes, radial_profile_HA, label='Data')
ax[0].plot(xgrid, y_fit, 'r-', label='Fit')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[0:4]), 'b--', label='Sérsic 1')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[4:8]), 'g--', label='Sérsic 2')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[8:12]), 'm--', label='Sérsic 3')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[12:16]), color='orange', linestyle='--', label='Sérsic 4')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[16:20]),  linestyle='--', label='Sérsic 5')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[20:24]),  linestyle='--', label='Sérsic 6')
ax[0].plot(xgrid, sersic_1d_convolved(xgrid, *params_curve_7[24:28]),  linestyle='--', label='Sérsic 7')

ax[0].set_xlabel("Pixel")
ax[0].set_ylabel("Intensity")
ax[0].set_title(r"Radial profile H$\alpha$")
ax[0].legend()
ax[0].grid(True)

ax[1].plot(x_axes, radial_profile_HA - y_fit)

plt.savefig('AIC_7', bbox_inches='tight')

# %%
#Plot AIC vs N 
n = [1, 2, 3, 4, 5, 6, 7]

fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('AIC')
ax1.set_title('N vs AIC')
ax1.plot(n, aic, marker = 'o')
plt.savefig('AIC_vs_N', bbox_inches='tight')
np.savetxt('AIC', aic)
np.savetxt('Reduced_chi', red_chi)

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('BIC')
ax2.set_title('N vs BIC')
ax2.plot(n, bic, marker = 'o')
plt.savefig('BIC_vs_N', bbox_inches='tight')
np.savetxt('BIC', aic)

fig3 = plt.figure(figsize=(8,6))
ax3 = fig3.gca()
ax3.grid(alpha=0.3, c = 'grey')
ax3.set_xlabel('N')
ax3.set_ylabel('Reduced $\chi$')
ax3.set_title('N vs Reduced $\chi$')
ax3.plot(n, red_chi, marker = 'o')
plt.savefig('Reduced_chi_vs_N', bbox_inches='tight')

# %%
fig1 = plt.figure(figsize=(8,6))
ax1 = fig1.gca()
ax1.grid(alpha=0.3, c = 'grey')
ax1.set_xlabel('N')
ax1.set_ylabel('log(AIC)')
ax1.set_title('N vs AIC')
ax1.plot(n, np.log10(aic), marker = 'o')
plt.savefig('AIC_vs_N_log', bbox_inches='tight')

fig2 = plt.figure(figsize=(8,6))
ax2 = fig2.gca()
ax2.grid(alpha=0.3, c = 'grey')
ax2.set_xlabel('N')
ax2.set_ylabel('log(BIC)')
ax2.set_title('N vs BIC')
ax2.plot(n, np.log10(bic), marker = 'o')
plt.savefig('BIC_vs_N_log', bbox_inches='tight')
