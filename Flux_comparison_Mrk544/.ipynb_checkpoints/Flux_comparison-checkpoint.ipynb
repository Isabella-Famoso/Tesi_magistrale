# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np

# %%
hdul = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_544/Flux_comparison/Mrk-544_MAPPED_FLUX_SCI_LSS_U1_12.fits")
hdul2 = fits.open("C:/Users/ISAFA/Desktop/Tesi magistrale/Sources/Mrk_544/Flux_comparison/Mrk-544_MAPPED_FLUX_SCI_LSS_U1_9.fits")

image_12 = hdul[0].data
image_9 = hdul2[0].data

# %%
difference = image_12 - image_9
plt.imshow(difference)

# %%
difference_cut = difference[55:155, 0:1800]
flux = difference_cut[58, 0:]
wavelenghts = np.arange(4300.74, 4300.74+1800*1.48, 1.48)
plt.plot(wavelenghts, flux)
plt.xlabel('wavelenght')
plt.ylabel('Flux')
plt.ylim(-1e-3, 1e-3)
# Out:
# (-0.001, 0.001)
